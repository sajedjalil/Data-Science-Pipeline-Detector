# %% [markdown]
# ## PLEAS UPVOTE NOTEBOOK

# %%
import pandas as pd

sub_sample = pd.read_csv('../input/tabular-playground-series-mar-2022/sample_submission.csv')
sub_top_ens = pd.read_csv('../input/tps-mar-22-blending-submissions-lb-4-734/submission_ensemble.csv')
sub_top2 = pd.read_csv('../input/tabular-playground-dataset/submission.csv')
sub_lama = pd.read_csv('../input/lightautoml-with-fe-tps-mar-22/LightAutoML_TabularAutoML_with_spec_v2.csv')

sub_sample.congestion = sub_top_ens.congestion * 1 + sub_top2.congestion * 0 + sub_lama.congestion * 0
sub_sample.congestion = sub_sample.congestion.astype(int)
sub_sample.to_csv('submission.csv', index=False)
sub_sample
