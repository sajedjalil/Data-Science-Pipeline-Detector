# %% [markdown]
# **PLEASE UPVOTE https://www.kaggle.com/code/kotrying/tps-2022-03-lgbm**

# %%
import pandas as pd

sub_sample = pd.read_csv('../input/tabular-playground-series-mar-2022/sample_submission.csv')
sub_kotrying = pd.read_csv('../input/tps-2022-03-lgbm/submission_emsemble.csv')
sub_martynov = pd.read_csv('../input/tps-mar-22-fe-model-selection/submission_blend_corrected_rounded 2080.csv')
sub_borisova = pd.read_csv('../input/submission-rounded/submission_rounded.csv')

sub_sample.congestion = sub_kotrying.congestion * 0.8 + sub_martynov.congestion * 0.1 + sub_borisova.congestion * 0.1
sub_sample.to_csv('submission_ensemble.csv', index=False)
sub_sample
