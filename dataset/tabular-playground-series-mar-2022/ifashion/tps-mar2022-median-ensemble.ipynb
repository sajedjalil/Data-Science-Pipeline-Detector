# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
tab = pd.read_csv('../input/tps-mar2022-tabnet/submission.csv')
lgb = pd.read_csv('../input/tps-mar2022-single-lgbm-lb-4-91-run-time-91s/submission.csv')
xgb = pd.read_csv('../input/tps-mar2022-single-xgb-lb-4-95-run-time-60s/submission.csv')
nomdl = pd.read_csv('../input/tps-mar22-mean-by-segments-no-model/submission_no_machine_learning.csv')

# %%
sub = pd.read_csv('../input/tabular-playground-series-mar-2022/sample_submission.csv')
sub

# %%
sub['lgb'] = lgb['congestion']
sub['xgb'] = xgb['congestion']
sub['tab'] = tab['congestion']
sub['nomdl'] = nomdl['congestion']
sub['congestion'] = np.median(sub[['lgb','xgb','tab','nomdl']], axis = 1).astype('int')

sub

# %%
sub = sub[['row_id','congestion']]
sub.to_csv('sub_ens.csv', index = False)
sub
