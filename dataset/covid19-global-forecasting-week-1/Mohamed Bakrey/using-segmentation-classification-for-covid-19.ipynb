# %% [markdown]
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfdC1_t2mjBUkLyM9Um2kk0d9XDE65hRYmiQ&usqp=CAU)
#
# <div class="list-group" id="list-tab" role="tablist">
# <h3 class="list-group-item list-group-item-action active" data-toggle="list" style='background:black; border:0; color:white' role="tab" aria-controls="home"><center>If you find this notebook useful, do give me an upvote, it helps to keep up my motivation. This notebook will be updated frequently so keep checking for furthur developments.</center></h3>

# %% [markdown]
# ## **<span style="color:orange;">Description</span>**
# About this disease:
# At this time, you will project the cumulative number of confirmed COVID19 cases in various locations around the world, as well as the number of deaths resulting, for future dates.
#
# We understand that this is a serious situation, and in no way do we want to underestimate the human impact of this crisis by anticipating deaths. Our goal is to provide better methods for estimations that can help medical and government institutions prepare for and adapt to epidemic outbreaks.

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
# <h3 class="list-group-item list-group-item-action active" data-toggle="list" style='background:green; border:0; color:black' role="tab" aria-controls="home">Soon we will see the code for those results.</h3>

# %% [markdown]
# <a id="libraries"></a>
# <div class="list-group" id="list-tab" role="tablist">
# <h2 class="list-group-item list-group-item-action active" data-toggle="list" style='background:Tomato; border:0; color:white' role="tab" aria-controls="home"><center> Libraries</center></h2>

# %% [markdown]
# # One-Stop-for-COVID-19-Infection-and-Lung-Segmentation-plus-Classification

# %%
import cv2
from pylab import rcParams
import matplotlib.pyplot as plt
rcParams['figure.figsize'] =40,50

img = cv2.imread("../input/results/Results/1.PNG")
plt.imshow(img)

# %% [markdown]
# # Following are the details about the scripts/notebooks

# %%
img = cv2.imread("../input/results/Results/2.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/3.PNG")
plt.imshow(img)

# %% [markdown]
# # Preprocessing Stage

# %%
img = cv2.imread("../input/results/Results/4.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/5.PNG")
plt.imshow(img)

# %% [markdown]
# # DICE v/s IOU and some relationship

# %%
img = cv2.imread("../input/results/Results/6.PNG")
plt.imshow(img)

# %% [markdown]
# # Training Stage

# %%
img = cv2.imread("../input/results/Results/7.PNG")
plt.imshow(img)

# %% [markdown]
# # Results with UNet (Task: 1)

# %%
img = cv2.imread("../input/results/Results/8.PNG")
plt.imshow(img)

# %% [markdown]
# # Precision and recall curves v/s thresholds

# %%
img = cv2.imread("../input/results/Results/9.PNG")
plt.imshow(img)

# %% [markdown]
# # Some Actual Vs Predicted Masks

# %%
img = cv2.imread("../input/results/Results/10.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/11.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/12.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/13.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/14.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/15.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/16.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/16.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/17.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/18.PNG")
plt.imshow(img)

# %%
img = cv2.imread("../input/results/Results/19.PNG")
plt.imshow(img)

# %% [markdown]
# ## Referance:
# [Here](https://github.com/deadskull7/One-Stop-for-COVID-19-Infection-and-Lung-Segmentation-plus-Classification)

# %% [markdown]
# <h1><center>More Plots and Models coming soon!</center></h1>
#
# <center><img src = "https://static.wixstatic.com/media/5f8fae_7581e21a24a1483085024f88b0949a9d~mv2.jpg/v1/fill/w_934,h_379,al_c,q_90/5f8fae_7581e21a24a1483085024f88b0949a9d~mv2.jpg" width = "750" height = "500"/></center>

# %% [markdown]
# ---
#
# ## **<span style="color:orange;">Let's have a Talk!</span>**
# > ### Reach out to me on [LinkedIn](https://www.linkedin.com/in/mohamed-bakrey-2aba281b2/)
#
# ---
