# %% [markdown]
# In the name of Allah
#
# Project Report Evaluation of Performance and Accuracy of Machine Learning Models on Corona Database
# Mohammad Reza Dorafshani
# Id:976169008
# Qazvin Imam Khomeini International University

# %% [markdown]
# Data set description:
# According to the following code, we generally have two folders, one for people with coronavirus and the other for people without coronavirus.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Figure 1 - Two folders containing information on people with and without coronavirus

# %% [markdown]
# Each folder contains two Excel files, one containing the person's profile, including the person's ID, age, and gender (Figure 2), and the other file containing the test information, including the test name, test amount, test time, and Is an individual ID (Figure 3).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Figure 2 - Excel file containing people's information

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Figure 3 - Excel file containing test specifications

# %% [markdown]
# Combine these two files using the common column that exists in both (individual ID) and create a new file.
# To do this, we first consider the test specification file. From the profile file of the two columns, the age of the people and their gender should be transferred to the profile file of the test and the values of peer-to-peer characteristics should be put together using the person ID key. Create two age and gender columns in the test profile file and then transfer the values according to the person's ID key using the lockup table and the following formula.

# %%
VLOOKUP($D2,'[Lookup table]Worksheet'!$A$2:$B$101,2,FALSE)    =

# %% [markdown]
# Note that this formula is for transferring the age column and another proportional formula should be used to transfer the other columns.
# In the above formula, the first component, D2, represents the column that is shared between the files (key). The second component represents the columns in the profile file that we want to move to the test profile file (start cell: A2 and end cell: B101). The third component, whose value in this example is 2, also represents the second column we want to move (the age column).
# We do the same for the gender column and pass it on. Our two Excel files are now a file that contains both the information of the people and the information of the experiments performed on them (Figure 4).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Figure 4 - Information merged into an Excel file

# %% [markdown]
# We do this for both people with viruses and people without viruses. In this step, 4 excel files are divided into two excel files including all the information of people and their tests that have corona virus and do not have corona virus.
#
# Now we will merge these two files to become an Excel file. In this Excel file, we add a column named target that indicates whether the person has the corona virus (Figure 5).
