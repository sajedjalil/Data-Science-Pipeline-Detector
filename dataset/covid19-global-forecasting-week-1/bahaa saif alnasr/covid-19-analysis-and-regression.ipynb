# %% [markdown]
# # this code is a new approach to understand CIVID19 with respect to [Deepak Deepu](http://www.kaggle.com/deepakdeepu8978) who made a great approach for COVID19:Analysis+EDA+Forecasting and his approach and data was very useful for my work.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import statistics as st #to get some statics for data

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# # first import (covid_19_clean_complete.csv) data which contains

# %%
data=pd.read_csv('../input/corona-virus-report/covid_19_clean_complete.csv')

# %% [markdown]
# # data describtion contain 19220 rows × 8 columns and the features are
# # 1-Province/State
# # 2-Country/Region
# # 3-lat(Latitude)
# # 4-long(Longitude)
# # 5-Date
# # 6-Confirmed(Cumulative count of Confirmed cases till this data)
# # 7-Deaths(Cumulative count of Confirmed cases till this data)
# # 8-Recovered

# %%
data

# %% [markdown]
# # presenting the confirmed cases all over world

# %%
Confirmed=data.Confirmed

# %%
Confirmed

# %% [markdown]
# # next presenting confirmed Deaths cases

# %%
Deaths=data.Deaths

# %%
Deaths

# %% [markdown]
# # import matplotlib library

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # plotting Deaths and Confirmed cases

# %%
plt.plot(Confirmed,Deaths,marker='o')
plt.xlabel('Confirmed')
plt.ylabel('Deaths')
