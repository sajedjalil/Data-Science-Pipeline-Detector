# %%
import pandas as pd
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
train.shape, test.shape

# %%
train.head()

# %%
# !git clone https://github.com/4paradigm/autox.git
# !pip install ./autox

# %%
from autox.autox_competition.process_data import get_pseudo_label

id_ = 'id'
target = 'target'
used_cols = [col for col in test.columns if col not in [id_, target]]

pseudo_label = get_pseudo_label(train, test, id_ = id_, target = target, used_cols = used_cols)

# %%
print("train.shape: ", train.shape)
print("pseudo_label.shape: ", pseudo_label.shape)
pseudo_label.head()
