# %%
import numpy as np
import pandas as pd
import pickle

# %%
with open('../input/predictions/prediction.pkl', 'rb') as f:
    preds = pickle.load(f)

# %%
sub = pd.read_csv('../input/instant-gratification/sample_submission.csv')
print(preds)
preds = pd.DataFrame(preds)
preds = preds[:131074]
# if sub.shape[0] != 131073:
sub['target'] = preds
sub.to_csv('submission.csv',index=False)
# Out:
# [0.80663452 0.99999825 0.02839745 ... 0.99349751 0.08457693 0.94485286]

# %%
sub.head()
# Out:
#                                  id    target
# 0  1c13f2701648e0b0d46d8a2a5a131a53  0.806635
# 1  ba88c155ba898fc8b5099893036ef205  0.999998
# 2  7cbab5cea99169139e7e6d8ff74ebb77  0.028397
# 3  ca820ad57809f62eb7b4d13f5d4371a0  0.025101
# 4  7baaf361537fbd8a1aaa2c97a6d4ccc7  1.000000

# %%
sub['target'].head()
# Out:
# 0    0.5
# 1    0.5
# 2    0.5
# 3    0.5
# 4    0.5
# Name: target, dtype: float64

# %%
preds= list(preds)

# %%
preds
# Out:
# [0]

# %%
|
