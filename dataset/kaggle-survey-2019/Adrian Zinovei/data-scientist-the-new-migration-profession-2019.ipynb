# %%
import pandas as pd
After_tax = pd.read_csv("../input/average-monthly-salary-after-taxes-by-country/After tax plus year gross.csv")
SurveySchema = pd.read_csv("../input/kaggle-survey-2018/SurveySchema.csv")
freeFormResponses = pd.read_csv("../input/kaggle-survey-2018/freeFormResponses.csv")
multipleChoiceResponses = pd.read_csv("../input/kaggle-survey-2018/multipleChoiceResponses.csv")

# %% [markdown]
# <div align='center'><font size="6" color='#47494d'> Data Science New Migration Profession in 2019 </font></div>
# <div align='center'><font size="4" color="#47494d">Everyone wants a better job, in a better company and in a better place </font></div>
# <hr>
#
# <p> &ensp; Data Science is the most wished and wanted profession in 2019. For the past few years most of the specialists like Data Analysts, BI developers, Statisticians, Mathematicians, Technical Engineers are pursuing new profession and learning hard Data Science and Machine Learning. One of the best battlefield for learning and practicing DS and ML is KAGGLE, an easy to use platform with web-based environment.
# </p>
# 	<p> &ensp;Data Scientist is the new migration profession. Professionals from all over the world are looking for better paid jobs in better companies and located in best countries, which will offer a better life for them and their families. People are inspired by Kaggle grand masters and their career paths, learning new ML and DS techniques. </p>
# 	<p> &ensp;In this story we will analyze the Kaggle Survey from 3 points:</p>
# <p> &ensp;Money: salary, spending, etc.</p>
# <p> &ensp;Knowledge: programming languages, libraries, algorithms, etc.</p>
# <p> &ensp;Destination: countries, platforms, courses etc.</p>
# <p> &ensp;Let’s try to analyze each chapter of our story, interact with data and make your own conclusions. </p>
#  </p>
#
# <hr>
#
# <div align='center'><font size="6" color='#47494d'> Chapter 1 | Follow the Money </font></div>
# <hr>
# <p> &ensp;Salary is the biggest motivator in learning and pursuing a new profession. One of the sexiest professions nowadays is the Data Scientist or any related to Machine Learning. Kaggle offer us the possibility to have a combination of skills and being famous in the world and wanted by head-hunters. One of my friends told me somehow that his dream is to become a competition Grandmaster and his next step will be deleting his entire resume and just write just 3 words in the middle “Kaggle Competition Grandmaster”.</p>
# <p> &ensp;But enough lyrics, let’s start our journey by discovering new insights in the data.</p>
# <p> &ensp;All charts are highly interactive and you can filter by clicking on charts and drill down to expected level.
# </p>

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1575202052924' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey20191_Money&#47;KaggleSurvey20191_Money&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='KaggleSurvey20191_Money&#47;KaggleSurvey20191_Money' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey20191_Money&#47;KaggleSurvey20191_Money&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1575202052924');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='750px';vizElement.style.height='1527px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# <p>&ensp;Interesting information:</p>
# <p> &ensp; - There are 100 users with age 70+ years old and 5 of them have the salary 500,000; could one of those AI father’s? </p>
# <p> &ensp; - Users who didn’t answer the salary questions have they average gross yearly salary around 20,000 in their home countries. </p>
# <p> &ensp; Sometimes data is generating more questions, like: Is it H2O paying those 500K salaries? Let's move on.</p>
# </p>
#
# <hr>
# <div align='center'><font size="6" color='#47494d'> Chapter 2 | Knowledge </font></div>
# <hr>
# <p> &ensp;Data Science it’s all about knowledge. The way we learn it, the sources we use and the speed we react to new technologies. For every Not working, Student to an experienced Data Scientist, this is what Kaggle is offering in their platform, a competition of mind and knowledge exchange. Kaggle in this case is the Blind Audition of world Data Science community, independently where you are from you have same chances to win and learn. </p>
# <p> &ensp; Let’s get back to interactivity and start finding new insights about Knowledge in the Kaggle world.
#
# </p>

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1575202080383' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey20192_Knowledge&#47;KaggleSurvey20192_Knowledge&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='KaggleSurvey20192_Knowledge&#47;KaggleSurvey20192_Knowledge' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey20192_Knowledge&#47;KaggleSurvey20192_Knowledge&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1575202080383');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='750px';vizElement.style.height='2527px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# <hr>
# <div align='center'><font size="6" color='#47494d'> Chapter 3 | Destination </font></div>
# <hr>
# <p> &ensp;In the end we need to analyze our data in space and best way to do this is to see where your country versus the rest of the countries is.  </p>
# <p> &ensp; In the data we are about to analyze there are 2462 answers with empty answers for not-filtered questions. For those answers are available only main filters like position, age and country. In the following dashboard you can select each country and have almost all data on the same chart compared and easy to analyze.
# </p>
#
#   <div align='center'><font size="4" color="#47494d">The data science motto: If at first you don’t succeed; call it version 1.0 </font></div>

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1575202098318' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey20193_Profile&#47;KaggleSurvey20193Destination&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='KaggleSurvey20193_Profile&#47;KaggleSurvey20193Destination' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey20193_Profile&#47;KaggleSurvey20193Destination&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1575202098318');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='750px';vizElement.style.height='1227px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# <hr>
# <div align='center'><font size="6" color='#47494d'> Final Chapter | Take the Survey!!! </font></div>
# <hr>
# <p> &ensp;In the end, who said you could not try to take the survey one more time and check if we can predict your country. You need to answer all the questions in order to reveal your country prediction. You are also able to select how many countries you want to see in the result prediction. </p>
# <p> &ensp; Results are based on ranking all questions by countries and point based. You can easy download it on your laptop and check how it was developed. </p>

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1575328693044' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey2019Whereareyoufrom&#47;KaggleSurvey2019Wereareyoufrom&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='KaggleSurvey2019Whereareyoufrom&#47;KaggleSurvey2019Wereareyoufrom' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ka&#47;KaggleSurvey2019Whereareyoufrom&#47;KaggleSurvey2019Wereareyoufrom&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1575328693044');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='750px';vizElement.style.height='1227px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# <p> &ensp;PLEASE SHARE YOUR FEEBACK IF YOUR COUNTRY WILL BE ON THE LIST </p>

# %% [markdown]
# <p> &ensp; All datasets are available on Kaggle datasets.
# Interactive dashboards are available on <a href="https://public.tableau.com">https://public.tableau.com</a> You can easily register and install Tableau Public for free and even have your own Tableau Public profile where you can share your work with others.
# Feel free to add me you your favorites, so you can easily find me and review my work as well.
#
# </p>
# <p> &ensp; In the following dashboard you can select each country and have almost all data on the same chart compared and easy to analyze. </p>
# <p> &ensp; <a href="https://public.tableau.com/profile/adrian.zinovei#!/"> https://public.tableau.com/profile/adrian.zinovei#!/</a> </p>
# <p> &ensp; Most of the dashboards are downloadable and you can easy start in 15 min.</p>
