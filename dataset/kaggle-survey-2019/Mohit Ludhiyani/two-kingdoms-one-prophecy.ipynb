# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Two Kingdoms:
#
# ## Group of Seven (G7):
# ### The Group of Seven (G7) is an inter-governmental political forum consisting of Canada, France, Germany, Italy, Japan, the United Kingdom and the United States. Its members are the world's largest IMF advanced economies and wealthiest liberal democracies; the group is officially organized around shared values of pluralism and representative government. As of 2018, the G7 nations account for close to 60 percent of global net wealth, 32 to 46 percent of global gross domestic product, and about 770 million people or 10 percent of the world's population. Most members are great powers in global affairs and maintain mutually close economic, military, and diplomatic relations. [1]
#
#
#
# ## Emerging Seven (E7):
# ### The E7 (short for "Emerging 7") is the seven countries China, India, Brazil, Turkey, Russia, Mexico and Indonesia, grouped together because of their major emerging economies. The growth of the E7 countries has been characterized in comparison with its size versus the Group of Seven countries, which had made up many of the largest economies in the world in the 20th century.[2]
#
# ***
# #### References
# 1. [G7 Wiki ](https://en.wikipedia.org/wiki/Group_of_Seven)
# 2. [E7 Wiki ](https://en.wikipedia.org/wiki/E7_(countries)#:~:text=The%20E7%20)
# 3. [Image Source](https://www.reddit.com/r/MapPorn/comments/qplbim/g7_countries_vs_e7_countries/)

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/g7e7.png?raw=true)

# %% [markdown]
# # One Prophecy:
#
# ## "*Emerging economies will dominate the world's top 10 economies in 2050*."
# ## Top 10 economies in 2050, according to PwC’s The World in 2050 report
# 1. **China (E7)**
# 2. **India (E7)**
# 3.  **US (G7)**
# 4. **Indonesia (E7)**
# 5. **Brazil (E7)**
# 6. **Russia (E7)**
# 7. **Mexico (E7)**
# 8. **Japan (G7)**
# 9. **Germany (G7)**
# 10. **UK (G7)**
#
# ***
# #### References
# 1. [BBC 2020 Article](https://www.bbc.com/travel/article/20200419-coronavirus-five-countries-with-the-best-healthcare-systems)
# 2. [PWC Report](https://www.pwc.com/world2050)

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/pwc_projections.png?raw=true)

# %% [markdown]
# # Must have Elixir: Technology
#
# ## Technology has become one of the key drivers of economic growth of countries, regions and cities, specially in covid times. Technological progress allows for the more efficient production of more and better goods and services, which is what prosperity depends on. There is no doubt that the countries that leads in technologies will be ahead in race to fullfill the prophecy.  If you don't agree with me i will leave you with an article to convince you.
#
# [Hope this will convince you.](https://www.brookings.edu/blog/future-development/2020/01/17/whoever-leads-in-artificial-intelligence-in-2030-will-rule-the-world-until-2100/)

# %% [markdown]
# # Will Prophecy come True?? Are emerging economies (E7) ready for the challenge from stable and wealthy G7 economies. Lets try to find out !!!

# %% [markdown]
# ##  Test of Time and Covid:
# ## Last few years have shaken the foundations of most of the economies. Let's see how the potential candidates of prophecy have performed in last few years (2017-2021). We analyze last four year's notebooks to draw different insights (Kaggle survey data science 2017-2021). And we only consider economies which are expected to dominate by projections as per PWC's report.
#
# #### Important Note: Dear Kagglers, before I move forward, We (the authors of this notebook) have nothing against any country/community, the analysis is done just for learning purpose. So we hope you will see this as an education project. Also, if you are reading this and like our work dont forget say hi and upvote :-p

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/covid.png?raw=true)

# %% [markdown]
# # Participation over the Years

# %% [markdown]
# 1. **Assumption** Change of Participation gives indirect estimate of how many people from across the globe are getting connected to Machine Learning, Data science and AI community.
#
# 2. **Plot** We plot how % participation has changed in 2018, 2019, 2020, and 2021 w.r.t participation in 2017.
#
# 3. **Insights**
#    - Lets first analyze the potential candidates of G7 economies(first 4 in plot) in prophecy, all except Japan have shown very *less or even negative/reduced change* in participation compared to 2017.
#    - On ther other hand, most of the E7 economies(last 6 in plot), except China all show positive/increased participation w.r.t 2017. Specially, check participation spikes in India, Indonesia and Mexico in years 2020 and 2021.
#    - **What can be reason for sudden high participation spike from India, Indonesia and Mexico in 2020 and 2021, can it increase in unemployement?? To checkout lets move to next section.**

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/participation_change.png?raw=true)

# %% [markdown]
# # Unemployement

# %% [markdown]
# 1. **Assumption** % of unemployed members will provide some idea on the unemployment status of economy
#
# 2. **Plot** We plot % of total members unemployed each year
#
# 3. **Insights**
#    - Plot clearly shows higher unemployment in E7 economies compared to G7, however, checkout China which is part of E7 showing least unemployment of all economies plotted.
#    - Let's compare the 2020 unemployment with 2019 unemployment for all the economies(G7 and E7 both), it is evident that covid has left its signature on all the economies i.e. high rise in unemployment.
#    - **Coming back to our earlier argument in last section, about can unemployment be the reason for high participation from India, Indonesia and Mexico in 2020 and 2021, from plot we can observe that there was high unemployment in the same years in all the three economies. Hence this reason can't be discarded. However, same reason doesnt go with Russia, which had high unemployment in same years but still participation was low.**
#    - All the E7 economies have shown reduction/recovery in unemployment in 2021 compared to 2020.
#    - US and Germany (part of G7) are also showing of recovery, however Japan and United Kingdom still showing rise in unemployment

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/unemployed1.png?raw=true)

# %% [markdown]
# # Technology Peneteration/Awareness into Economies

# %% [markdown]
# 1. **Assumption** % of people/buisnesses using well established Machine learning products will provide some idea on about peneteration of these tecnology into buisnesses
#
# 2. **Plot** We plot % of total members(or their employers/buisnesses) using well established Machine Learning products
#
# 3. **Insights**
#    - Plot clearly shows higher adaptation of Machine learning products in G7 economies compared to E7 economies.

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/ML_peneteration.png?raw=true)

# %% [markdown]
# 1. **Assumption** % of people/buisnesses using/aware about cloud computing and related tools will also provide some idea on about peneteration of these tecnology into economies
#
# 2. **Plot** We plot % of total members(or their employers/buisnesses) using some cloud computing tools.
#
# 3. **Insights**
#    - Similar to Machine learning plot we saw earlier, this plot shows higher awarenes towards cloud computing in G7 economies compared to E7 economies.
#    - Check out the green bar for all economies, it shows high rise in cloud usage/awareness in 2020, can you guess the reason ?? Tell me in comments.

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/Cloud_awareness.png?raw=true)

# %% [markdown]
# # Money Spent on Technology Products

# %% [markdown]
# 1. **Assumption** % of people/buisnesses participated in survey are spending money on some cloud/ML products. This will also provide idea about technology peneteration/dependence into economies
#
# 2. **Plot** We plot % of total members(or their employers/buisnesses) spending some money on cloud/ML tools.
#
# 3. **Insights**
#    - Higher money spent by G7 economies compared to E7.

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/money1.png?raw=true)

# %% [markdown]
# # Technology Expertise/Familiarity in Economies

# %% [markdown]
# 1. **Assumption** Programming languages play critical role in interacting with any technology. Without knowledge/expertise of programming language, it becomes difficult to use any technology for betterment. Hence, here we use expertise/familarity of programming language as barometer for expertise in technologies.
#
# 2. **Plot** We plot % of total participants familiar with specific programming language.
#
# 3. **Insights**
#    - Javascript and Java: E7 economies show more familiar(%) compared to G7, specially Indonesia, Mexico, India, China
#    - R, SQL & python: Both G7 and E7 groups show almost similar familiar scores.
#    - Check out the familiarity scores(> 60%) of python for all economies, no doubt it is one of the hottest languages of our times.

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/javascript.png?raw=true)

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/java.png?raw=true)

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/r.png?raw=true)

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/sql.png?raw=true)

# %% [markdown]
# ![](https://github.com/mohit-ludhiyani/data/blob/main/python.png?raw=true)

# %% [markdown]
# # Lets Summarize !!!
#
# High unemployment rate shown by E7 (except China) compared to G7, in uncertain times, may be sign of relatively less stablity. compared to G7. In addition, the technology peneteration into economies can be seen more in case of G7 economies. However, in terms of technology expertise/familiarity the E7 and G7 economies seem to be at same spot. Though less positives seems to be in favor of E7, but then thats why they are part of emerging economies. Lack of techonolgy peneteration shows scope of improvement and growth. Also, expertise/familiarity which seems similar to the G7 shows that E7 are on right track. And, don't forget 2050 is still approx 30 years far in timeline.
#
# - Some key observations, that are worth highlighting:
#     - China participants show least unemployment rate.
#     - Machine Learning peneteration seems to be highest into USA and least in Indonesia.
#     - Python seems to be most popular among participants from various economies.
#     - Cloud Computing has gained more familarity post Covid.

# %% [markdown]
# # Behind the scenes
# #### Below this cells show how the data has been processed and graphs have been generated

# %%
#!pip install seaborn
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib 
import chardet
#!pip list

# %%
countries = ['China','India','US','Indonesia','Brazil','Russia','Mexico','Japan','Germany','UK']
countries

# %%
file = '/kaggle/input/kaggle-survey-2017/multipleChoiceResponses.csv'
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result

# %%
survey_2021 = pd.read_csv('/kaggle/input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')
#survey_2021 = pd.read_csv('/kaggle/input/survey-files/kaggle_survey_2021_responses.csv')
survey_2020 = pd.read_csv('/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv')
#survey_2020 = pd.read_csv('/kaggle/input/survey-files/kaggle_survey_2020_responses.csv')
survey_2019 = pd.read_csv('/kaggle/input/kaggle-survey-2019/multiple_choice_responses.csv')
#survey_2019 = pd.read_csv('/kaggle/input/survey-files/multiple_choice_responses_2019.csv')
survey_2018 = pd.read_csv('/kaggle/input/kaggle-survey-2018/multipleChoiceResponses.csv')
#survey_2018 = pd.read_csv('/kaggle/input/survey-files/multipleChoiceResponses_2018.csv')
survey_2017 = pd.read_csv('/kaggle/input/kaggle-survey-2017/multipleChoiceResponses.csv',encoding='latin-1')

# %%
survey_2021.head(3)

# %%
survey_2020.head(3)

# %%
survey_2019.head(3)

# %%
survey_2018.head(3)

# %%
survey_2017.head(3)

# %%
all_survey_data = pd.DataFrame()

# %% [markdown]
# # Participation over the years

# %%
survey_2017.Country.unique()

# %%
survey_2017.Country =survey_2017.Country.map(lambda x: 'China' if x in ["People 's Republic of China",'Republic of China'] else x )
survey_2017.Country.unique()

# %%
participation_count_2017 = survey_2017.groupby(['Country']).size()
participation_count_2017

# %%
countries = ['China','India','United States','Indonesia','Brazil','Russia','Mexico','Japan','Germany','United Kingdom']
all_survey_data['participation_2017'] = participation_count_2017[['China','India','United States','Indonesia','Brazil','Russia','Mexico','Japan','Germany','United Kingdom']]

# %%
survey_2018.Q3.unique()

# %%
survey_2018.Q3 =survey_2018.Q3.map(lambda x: 'United States' if x in ['United States of America'] else x )
survey_2018.Q3 =survey_2018.Q3.map(lambda x: 'United Kingdom' if x in ['United Kingdom of Great Britain and Northern Ireland'] else x )
survey_2018.Q3.unique()

# %%
participation_count_2018 = survey_2018.groupby(['Q3']).size()
participation_count_2018

# %%
countries = ['China','India','United States','Indonesia','Brazil','Russia','Mexico','Japan','Germany','United Kingdom']
all_survey_data['participation_2018'] = participation_count_2018[countries]

# %%
all_survey_data.head(10)

# %%
survey_2019.Q3.unique()

# %%
survey_2019.Q3 =survey_2019.Q3.map(lambda x: 'United States' if x in ['United States of America'] else x )
survey_2019.Q3 =survey_2019.Q3.map(lambda x: 'United Kingdom' if x in ['United Kingdom of Great Britain and Northern Ireland'] else x )
survey_2019.Q3.unique()

# %%
participation_count_2019 = survey_2019.groupby(['Q3']).size()
participation_count_2019

# %%
countries = ['China','India','United States','Indonesia','Brazil','Russia','Mexico','Japan','Germany','United Kingdom']
all_survey_data['participation_2019'] = participation_count_2019[countries]

# %%
all_survey_data.head(10)

# %%
survey_2020.Q3.unique()

# %%
survey_2020.Q3 =survey_2020.Q3.map(lambda x: 'United States' if x in ['United States of America'] else x )
survey_2020.Q3 =survey_2020.Q3.map(lambda x: 'United Kingdom' if x in ['United Kingdom of Great Britain and Northern Ireland'] else x )
survey_2020.Q3.unique()

# %%
participation_count_2020 = survey_2020.groupby(['Q3']).size()
participation_count_2020

# %%
countries = ['China','India','United States','Indonesia','Brazil','Russia','Mexico','Japan','Germany','United Kingdom']
all_survey_data['participation_2020'] = participation_count_2020[countries]

# %%
all_survey_data.head(10)

# %%
survey_2021.Q3.unique()

# %%
survey_2021.Q3 =survey_2021.Q3.map(lambda x: 'United States' if x in ['United States of America'] else x )
survey_2021.Q3 =survey_2021.Q3.map(lambda x: 'United Kingdom' if x in ['United Kingdom of Great Britain and Northern Ireland'] else x )
survey_2021.Q3.unique()

# %%
participation_count_2021 = survey_2021.groupby(['Q3']).size()
participation_count_2021

# %%
countries = ['China','India','United States','Indonesia','Brazil','Russia','Mexico','Japan','Germany','United Kingdom']
all_survey_data['participation_2021'] = participation_count_2021[countries]

# %%
all_survey_data.head(10)

# %%
participation_YoY = pd.DataFrame() 
participation_YoY['2018'] = all_survey_data.apply(lambda x: (x['participation_2018']-x['participation_2017'])/x['participation_2017']*100,axis=1)
participation_YoY['2019'] = all_survey_data.apply(lambda x: (x['participation_2019']-x['participation_2017'])/x['participation_2017']*100,axis=1)
participation_YoY['2020'] = all_survey_data.apply(lambda x: (x['participation_2020']-x['participation_2017'])/x['participation_2017']*100,axis=1)
participation_YoY['2021'] = all_survey_data.apply(lambda x: (x['participation_2021']-x['participation_2017'])/x['participation_2017']*100,axis=1)
participation_YoY =participation_YoY.reset_index()
participation_YoY.head(10)

# %%
# Insert plot ==> x axis = years, y axis = ratio,  hue= country names
#sns.lineplot(x=['2018','2019','2020','2021'],y=[participation_YoY.loc['China'],participation_YoY.loc['India']])
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = participation_YoY.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=2,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('Change in Participation w.r.t 2017',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("participation_change.png", bbox_inches = 'tight',figsize=(20, 10))

# %% [markdown]
# #  Gender participation over the years

# %%
sex_2021 = survey_2021.groupby(['Q3','Q2']).size()
Gender_all_survey_data = pd.DataFrame()
lst_male = []
lst_woman = []
lst_ratio = []
for cntry in countries:
    lst_male.append(sex_2021[cntry]['Man'])
    lst_woman.append(sex_2021[cntry]['Woman'])
    lst_ratio.append(sex_2021[cntry]['Woman']/(sex_2021[cntry]['Man']+sex_2021[cntry]['Woman']))
Gender_all_survey_data['Country'] = countries    
Gender_all_survey_data['Male_2021'] =  lst_male
Gender_all_survey_data['Woman_2021'] =  lst_woman
Gender_all_survey_data['Sex_ratio_2021'] =  lst_ratio

# %%
Gender_all_survey_data.head(10)
# others and missing values have been ignored

# %%
sex_2020 = survey_2020.groupby(['Q3','Q2']).size()
sex_2020
lst_male = []
lst_woman = []
lst_ratio = []
for cntry in countries:
    lst_male.append(sex_2020[cntry]['Man'])
    lst_woman.append(sex_2020[cntry]['Woman'])
    lst_ratio.append(sex_2020[cntry]['Woman']/(sex_2020[cntry]['Man']+sex_2020[cntry]['Woman']))
#Gender_all_survey_data['Country'] = countries    
Gender_all_survey_data['Male_2020'] =  lst_male
Gender_all_survey_data['Woman_2020'] =  lst_woman
Gender_all_survey_data['Sex_ratio_2020'] =  lst_ratio
Gender_all_survey_data.head(10)

# %%
sex_2019 = survey_2019.groupby(['Q3','Q2']).size()
sex_2019
lst_male = []
lst_woman = []
lst_ratio = []
for cntry in countries:
    lst_male.append(sex_2019[cntry]['Male'])
    lst_woman.append(sex_2019[cntry]['Female'])
    lst_ratio.append(sex_2019[cntry]['Female']/(sex_2019[cntry]['Male']+sex_2019[cntry]['Female']))
#Gender_all_survey_data['Country'] = countries    
Gender_all_survey_data['Male_2019'] =  lst_male
Gender_all_survey_data['Woman_2019'] =  lst_woman
Gender_all_survey_data['Sex_ratio_2019'] =  lst_ratio
Gender_all_survey_data.head(10)

# %%
sex_2018 = survey_2018.groupby(['Q3','Q1']).size()
sex_2018
lst_male = []
lst_woman = []
lst_ratio = []
for cntry in countries:
    lst_male.append(sex_2018[cntry]['Male'])
    lst_woman.append(sex_2018[cntry]['Female'])
    lst_ratio.append(sex_2018[cntry]['Female']/(sex_2018[cntry]['Male'] + sex_2018[cntry]['Female']))
#Gender_all_survey_data['Country'] = countries    
Gender_all_survey_data['Male_2018'] =  lst_male
Gender_all_survey_data['Woman_2018'] =  lst_woman
Gender_all_survey_data['Sex_ratio_2018'] =  lst_ratio
Gender_all_survey_data.head(10)

# %%
sex_2017 = survey_2017.groupby(['Country','GenderSelect']).size()
sex_2017
lst_male = []
lst_woman = []
lst_ratio = []
for cntry in countries:
    lst_male.append(sex_2017[cntry]['Male'])
    lst_woman.append(sex_2017[cntry]['Female'])
    lst_ratio.append(sex_2017[cntry]['Female']/(sex_2017[cntry]['Male']+sex_2017[cntry]['Female']))
#Gender_all_survey_data['Country'] = countries    
Gender_all_survey_data['Male_2017'] =  lst_male
Gender_all_survey_data['Woman_2017'] =  lst_woman
Gender_all_survey_data['Sex_ratio_2017'] =  lst_ratio
Gender_all_survey_data.head(10)

# %%
Female_participation_YoY = pd.DataFrame() 
Female_participation_YoY['Country'] = countries
Female_participation_YoY['2018'] = Gender_all_survey_data.apply(lambda x: (x['Sex_ratio_2018']-x['Sex_ratio_2017'])/x['Sex_ratio_2017'],axis=1)
Female_participation_YoY['2019'] = Gender_all_survey_data.apply(lambda x: (x['Sex_ratio_2019']-x['Sex_ratio_2017'])/x['Sex_ratio_2017'],axis=1)
Female_participation_YoY['2020'] = Gender_all_survey_data.apply(lambda x: (x['Sex_ratio_2020']-x['Sex_ratio_2017'])/x['Sex_ratio_2017'],axis=1)
Female_participation_YoY['2021'] = Gender_all_survey_data.apply(lambda x: (x['Sex_ratio_2021']-x['Sex_ratio_2017'])/x['Sex_ratio_2017'],axis=1)
Female_participation_YoY.head(10)

# %%
Male_participation_YoY = pd.DataFrame() 
Male_participation_YoY['Country'] = countries
Male_participation_YoY['2018'] = Gender_all_survey_data.apply(lambda x: (1-x['Sex_ratio_2018'])/(1-x['Sex_ratio_2017']),axis=1)
Male_participation_YoY['2019'] = Gender_all_survey_data.apply(lambda x: (1-x['Sex_ratio_2019'])/(1-x['Sex_ratio_2018']),axis=1)
Male_participation_YoY['2020'] = Gender_all_survey_data.apply(lambda x: (1-x['Sex_ratio_2020'])/(1-x['Sex_ratio_2019']),axis=1)
Male_participation_YoY['2021'] = Gender_all_survey_data.apply(lambda x: (1-x['Sex_ratio_2021'])/(1-x['Sex_ratio_2020']),axis=1)
Male_participation_YoY.head(10)

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = Female_participation_YoY.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=2,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('Female % change w.r.t 2017',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("Female_participation_change.png", bbox_inches = 'tight',figsize=(20, 10))

# %% [markdown]
# # Technology Advancement

# %% [markdown]
# ## Machine Learning Peneteration into Buisnesses

# %%
ML_peneteration = pd.DataFrame()
ML_peneteration['Country'] = countries

# %%
survey_2018.Q10.unique()

# %%
peneteration = survey_2018.groupby(['Q3','Q10']).size()
lst_well_estbd = []
for cntry in countries:
    #lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/peneteration[cntry][:].sum() )
    lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/all_survey_data.participation_2018[cntry]*100 )
ML_peneteration['Well_estbd_2018(%)'] = lst_well_estbd    
ML_peneteration

# %%
survey_2019.Q8.unique()

# %%
peneteration = survey_2019.groupby(['Q3','Q8']).size()
lst_well_estbd = []
for cntry in countries:
    #lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/peneteration[cntry][:].sum() )
    lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/all_survey_data.participation_2019[cntry]*100 )
ML_peneteration['Well_estbd_2019(%)'] = lst_well_estbd    
ML_peneteration

# %%
survey_2020.Q22.unique()

# %%
peneteration = survey_2020.groupby(['Q3','Q22']).size()
lst_well_estbd = []
for cntry in countries:
    #lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/peneteration[cntry][:].sum() )
    lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/all_survey_data.participation_2020[cntry]*100 )
ML_peneteration['Well_estbd_2020(%)'] = lst_well_estbd    
ML_peneteration

# %%
survey_2021.Q23.unique()

# %%
peneteration = survey_2021.groupby(['Q3','Q23']).size()
lst_well_estbd = []
for cntry in countries:
    #lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/peneteration[cntry][:].sum() )
    lst_well_estbd.append(peneteration[cntry]['We have well established ML methods (i.e., models in production for more than 2 years)']/all_survey_data.participation_2021[cntry]*100 )
ML_peneteration['Well_estbd_2021(%)'] = lst_well_estbd    
ML_peneteration

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = ML_peneteration.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=1,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('ML Peneteration into Buisnesses',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("ML_peneteration.png", bbox_inches = 'tight',figsize=(20, 10))

# %% [markdown]
# ## Cloud Technology Peneteration

# %%
cloud_peneteration = pd.DataFrame()
cloud_peneteration['Country']=countries

# %%
survey_2018.Q12_MULTIPLE_CHOICE.unique()

# %%
peneteration = survey_2018.groupby(['Q3','Q12_MULTIPLE_CHOICE']).size()
peneteration
lst_cloud = []
for cntry in countries:
    lst_cloud.append(peneteration[cntry]['Cloud-based data software & APIs (AWS, GCP, Azure, etc.)']/all_survey_data.participation_2018[cntry]*100 )
cloud_peneteration['cloud_comp_usage_2018(%)'] = lst_cloud   
cloud_peneteration

# %%
survey_2019.Q14.unique()

# %%
peneteration = survey_2019.groupby(['Q3','Q14']).size()
peneteration
lst_cloud = []
for cntry in countries:
    lst_cloud.append(peneteration[cntry]['Cloud-based data software & APIs (AWS, GCP, Azure, etc.)']/all_survey_data.participation_2019[cntry]*100 )
cloud_peneteration['cloud_comp_usage_2019(%)'] = lst_cloud   
cloud_peneteration

# %%
survey_2020.Q11.unique()

# %%
peneteration = survey_2020.groupby(['Q3','Q11']).size()
#peneteration
lst_cloud = []
for cntry in countries:
    lst_cloud.append(peneteration[cntry]['A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)']/all_survey_data.participation_2020[cntry]*100 )
cloud_peneteration['cloud_comp_usage_2020(%)'] = lst_cloud   
cloud_peneteration

# %%
survey_2021.Q11.unique()

# %%
peneteration = survey_2021.groupby(['Q3','Q11']).size()
#peneteration
lst_cloud = []
for cntry in countries:
    lst_cloud.append(peneteration[cntry]['A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)']/all_survey_data.participation_2021[cntry]*100 )
cloud_peneteration['cloud_comp_usage_2021(%)'] = lst_cloud   
cloud_peneteration

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = cloud_peneteration.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=1,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('Cloud Computing Awareness',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("Cloud_awareness.png", bbox_inches = 'tight',figsize=(20, 10))

# %% [markdown]
# # Familarity with Programing Languages

# %%
# Python Growth

# %%
pythn_familarity = pd.DataFrame()
pythn_familarity['Country'] = countries

# %%
pythn_peneteration = survey_2018.groupby(['Q3','Q16_Part_1']).size()
#pythn_familarity
lst_python = []
for cntry in countries:
    lst_python.append(pythn_peneteration[cntry]['Python']/all_survey_data.participation_2018[cntry]*100 )
pythn_familarity['python_familiar_2018(%)'] = lst_python   
pythn_familarity

# %%
survey_2019.Q18_Part_1.unique()

# %%
pythn_peneteration = survey_2019.groupby(['Q3','Q18_Part_1']).size()
#pythn_familarity
lst_python = []
for cntry in countries:
    lst_python.append(pythn_peneteration[cntry]['Python']/all_survey_data.participation_2019[cntry]*100 )
pythn_familarity['python_familiar_2019(%)'] = lst_python   
pythn_familarity

# %%
survey_2020.Q7_Part_1.unique()

# %%
pythn_peneteration = survey_2020.groupby(['Q3','Q7_Part_1']).size()
pythn_peneteration
lst_python = []
for cntry in countries:
    lst_python.append(pythn_peneteration[cntry]['Python']/all_survey_data.participation_2020[cntry]*100 )
pythn_familarity['python_familiar_2020(%)'] = lst_python   
pythn_familarity

# %%
survey_2021.Q7_Part_1.unique()

# %%
pythn_peneteration = survey_2021.groupby(['Q3','Q7_Part_1']).size()
pythn_peneteration
lst_python = []
for cntry in countries:
    lst_python.append(pythn_peneteration[cntry]['Python']/all_survey_data.participation_2021[cntry]*100 )
pythn_familarity['python_familiar_2021(%)'] = lst_python   
pythn_familarity

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = pythn_familarity.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=2,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('% participants familar to Python',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("python.png", bbox_inches = 'tight',figsize=(20, 10))

# %%
# R growth

# %%
R_familarity = pd.DataFrame()
R_familarity['Country'] = countries

# %%
R_peneteration = survey_2018.groupby(['Q3','Q16_Part_2']).size()
R_peneteration
lst_R = []
for cntry in countries:
    lst_R.append(R_peneteration[cntry]['R']/all_survey_data.participation_2018[cntry]*100 )
R_familarity['R_familiar_2018(%)'] = lst_R   
R_familarity

# %%
R_peneteration = survey_2019.groupby(['Q3','Q18_Part_2']).size()
R_peneteration
lst_R = []
for cntry in countries:
    lst_R.append(R_peneteration[cntry]['R']/all_survey_data.participation_2019[cntry]*100 )
R_familarity['R_familiar_2019(%)'] = lst_R   
R_familarity

# %%
R_peneteration = survey_2020.groupby(['Q3','Q7_Part_2']).size()
R_peneteration
lst_R = []
for cntry in countries:
    lst_R.append(R_peneteration[cntry]['R']/all_survey_data.participation_2020[cntry]*100 )
R_familarity['R_familiar_2020(%)'] = lst_R   
R_familarity

# %%
R_peneteration = survey_2021.groupby(['Q3','Q7_Part_2']).size()
R_peneteration
lst_R = []
for cntry in countries:
    lst_R.append(R_peneteration[cntry]['R']/all_survey_data.participation_2021[cntry]*100 )
R_familarity['R_familiar_2021(%)'] = lst_R   
R_familarity

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = R_familarity.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=2,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('% participants familar to R',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("r.png", bbox_inches = 'tight',figsize=(20, 10))

# %%
# SQL growth

# %%
SQL_familarity = pd.DataFrame()
SQL_familarity['Country'] = countries

# %%
SQL_peneteration = survey_2018.groupby(['Q3','Q16_Part_3']).size()
SQL_peneteration
lst_SQL = []
for cntry in countries:
    lst_SQL.append(SQL_peneteration[cntry]['SQL']/all_survey_data.participation_2018[cntry]*100 )
SQL_familarity['SQL_familiar_2018(%)'] = lst_SQL   
SQL_familarity

# %%
SQL_peneteration = survey_2019.groupby(['Q3','Q18_Part_3']).size()
SQL_peneteration
lst_SQL = []
for cntry in countries:
    lst_SQL.append(SQL_peneteration[cntry]['SQL']/all_survey_data.participation_2019[cntry]*100 )
SQL_familarity['SQL_familiar_2019(%)'] = lst_SQL   
SQL_familarity

# %%
SQL_peneteration = survey_2020.groupby(['Q3','Q7_Part_3']).size()
SQL_peneteration
lst_SQL = []
for cntry in countries:
    lst_SQL.append(SQL_peneteration[cntry]['SQL']/all_survey_data.participation_2020[cntry]*100 )
SQL_familarity['SQL_familiar_2020(%)'] = lst_SQL   
SQL_familarity

# %%
SQL_peneteration = survey_2021.groupby(['Q3','Q7_Part_3']).size()
SQL_peneteration
lst_SQL = []
for cntry in countries:
    lst_SQL.append(SQL_peneteration[cntry]['SQL']/all_survey_data.participation_2021[cntry]*100 )
SQL_familarity['SQL_familiar_2021(%)'] = lst_SQL   
SQL_familarity

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = SQL_familarity.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=2,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('% participants familar to SQL',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("sql.png", bbox_inches = 'tight',figsize=(20, 10))

# %%
# Java Growth

# %%
Java_familarity = pd.DataFrame()
Java_familarity['Country'] = countries

# %%
Java_peneteration = survey_2018.groupby(['Q3','Q16_Part_5']).size()
Java_peneteration
lst_Java = []
for cntry in countries:
    lst_Java.append(Java_peneteration[cntry]['Java']/all_survey_data.participation_2018[cntry]*100 )
Java_familarity['Java_familiar_2018(%)'] = lst_Java   
Java_familarity

# %%
Java_peneteration = survey_2019.groupby(['Q3','Q18_Part_6']).size()
Java_peneteration
lst_Java = []
for cntry in countries:
    lst_Java.append(Java_peneteration[cntry]['Java']/all_survey_data.participation_2019[cntry]*100 )
Java_familarity['Java_familiar_2019(%)'] = lst_Java   
Java_familarity

# %%
Java_peneteration = survey_2020.groupby(['Q3','Q7_Part_6']).size()
Java_peneteration
lst_Java = []
for cntry in countries:
    lst_Java.append(Java_peneteration[cntry]['Java']/all_survey_data.participation_2020[cntry]*100 )
Java_familarity['Java_familiar_2020(%)'] = lst_Java   
Java_familarity

# %%
Java_peneteration = survey_2021.groupby(['Q3','Q7_Part_6']).size()
Java_peneteration
lst_Java = []
for cntry in countries:
    lst_Java.append(Java_peneteration[cntry]['Java']/all_survey_data.participation_2021[cntry]*100)
Java_familarity['Java_familiar_2021(%)'] = lst_Java   
Java_familarity

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = Java_familarity.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=2,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('% participants familar to Java',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("java.png", bbox_inches = 'tight',figsize=(20, 10))

# %%
Javascript_familarity = pd.DataFrame()
Javascript_familarity['Country'] = countries

# %%
Javascript_peneteration = survey_2018.groupby(['Q3','Q16_Part_6']).size()
Javascript_peneteration
lst_Javascript = []
for cntry in countries:
    lst_Javascript.append(Javascript_peneteration[cntry]['Javascript/Typescript']/all_survey_data.participation_2018[cntry]*100 )
Javascript_familarity['Javascript_familiar_2018(%)'] = lst_Javascript   
Javascript_familarity

# %%
Javascript_peneteration = survey_2019.groupby(['Q3','Q18_Part_7']).size()
Javascript_peneteration
lst_Javascript = []
for cntry in countries:
    lst_Javascript.append(Javascript_peneteration[cntry]['Javascript']/all_survey_data.participation_2019[cntry]*100 )
Javascript_familarity['Javascript_familiar_2019(%)'] = lst_Javascript   
Javascript_familarity

# %%
Javascript_peneteration = survey_2020.groupby(['Q3','Q7_Part_7']).size()
Javascript_peneteration
lst_Javascript = []
for cntry in countries:
    lst_Javascript.append(Javascript_peneteration[cntry]['Javascript']/all_survey_data.participation_2020[cntry]*100 )
Javascript_familarity['Javascript_familiar_2020(%)'] = lst_Javascript   
Javascript_familarity

# %%
Javascript_peneteration = survey_2021.groupby(['Q3','Q7_Part_7']).size()
Javascript_peneteration
lst_Javascript = []
for cntry in countries:
    lst_Javascript.append(Javascript_peneteration[cntry]['Javascript']/all_survey_data.participation_2021[cntry]*100 )
Javascript_familarity['Javascript_familiar_2021(%)'] = lst_Javascript   
Javascript_familarity

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = Javascript_familarity.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Javascript_familarity.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=2,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('% participants familar to Javascript',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("javascript.png", bbox_inches = 'tight',figsize=(20, 10))

# %%
Money_spent_count = pd.DataFrame()
Money_spent_count['Country'] = countries

# %%
survey_2019.Q11.unique()

# %%
Money = survey_2019.groupby(['Q3','Q11']).size()
Money
lst_Money_spent = []
for cntry in countries:
    money_people = (Money[cntry][:].sum() - Money[cntry]['$0 (USD)'])
    lst_Money_spent.append(money_people/all_survey_data.participation_2019[cntry]*100 )
Money_spent_count['Money_spent_2019(%)'] = lst_Money_spent   
Money_spent_count

# %%
survey_2020['Q25'].unique()

# %%
Money = survey_2020.groupby(['Q3','Q25']).size()
Money
lst_Money_spent = []
for cntry in countries:
    money_people = (Money[cntry][:].sum() - Money[cntry]['$0 ($USD)'])
    lst_Money_spent.append(money_people/all_survey_data.participation_2020[cntry]*100 )
Money_spent_count['Money_spent_2020(%)'] = lst_Money_spent   
Money_spent_count

# %%
Money = survey_2021.groupby(['Q3','Q26']).size()
Money
lst_Money_spent = []
for cntry in countries:
    money_people = (Money[cntry][:].sum() - Money[cntry]['$0 ($USD)'])
    lst_Money_spent.append(money_people/all_survey_data.participation_2021[cntry]*100 )
Money_spent_count['Money_spent_2021(%)'] = lst_Money_spent   
Money_spent_count

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = Money_spent_count.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Money_spent_count.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=1,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('% of People/Companies spending money on Cloud/ ML products',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("money1.png", bbox_inches = 'tight',figsize=(20, 10))

# %% [markdown]
# # Unemployment

# %%
survey_2018.Q6.unique()

# %%
Unemployed_count = pd.DataFrame()
Unemployed_count["Country"] = countries

# %%
Unemployed = survey_2018.groupby(['Q3','Q6']).size()
Unemployed
lst_Unemployed = []
for cntry in countries:
    lst_Unemployed.append(Unemployed[cntry]['Not employed']/all_survey_data.participation_2018[cntry]*100 )
Unemployed_count['Unemployed_2018(%)'] = lst_Unemployed   
Unemployed_count

# %%
Unemployed = survey_2019.groupby(['Q3','Q5']).size()
Unemployed
lst_Unemployed = []
for cntry in countries:
    lst_Unemployed.append(Unemployed[cntry]['Not employed']/all_survey_data.participation_2019[cntry]*100 )
Unemployed_count['Unemployed_2019(%)'] = lst_Unemployed   
Unemployed_count

# %%
Unemployed = survey_2020.groupby(['Q3','Q5']).size()
Unemployed
lst_Unemployed = []
for cntry in countries:
    lst_Unemployed.append(Unemployed[cntry]['Currently not employed']/all_survey_data.participation_2020[cntry]*100 )
Unemployed_count['Unemployed_2020(%)'] = lst_Unemployed   
Unemployed_count

# %%
Unemployed = survey_2021.groupby(['Q3','Q5']).size()
Unemployed
lst_Unemployed = []
for cntry in countries:
    lst_Unemployed.append(Unemployed[cntry]['Currently not employed']/all_survey_data.participation_2021[cntry]*100 )
Unemployed_count['Unemployed_2021(%)'] = lst_Unemployed  
Unemployed_count

# %%
order = ['United States','Japan','Germany','United Kingdom','China', 'India','Indonesia','Brazil','Russia','Mexico']
ax1 = Unemployed_count.set_index('Country').loc[order].plot(kind="bar", figsize=(20,10),grid=True)
#ax1 = Unemployed_count.plot(x='Country',figsize=(20,10),kind='bar',grid=True,fontsize=20)
ax = ax1.axes
ax1.set_facecolor("white")
ax1.spines['top'].set_color('black')
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_color('black')
ax1.grid('on', which='major', axis='x',color='black' )
ax1.grid('on', which='major', axis='y' ,color='black')
ax1.legend(loc=1,fontsize=20)
ax1.set_ylabel('%',fontdict={'fontsize':24})
ax1.set_xlabel('Country',fontdict={'fontsize':24})
ax1.set_title('% Unemployed',fontdict={'fontsize':24})
fig = ax1.get_figure()
fig.savefig("unemployed1.png", bbox_inches = 'tight',figsize=(20, 10))

# %% [markdown]
# # The End
