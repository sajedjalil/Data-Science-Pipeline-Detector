# %% [markdown]
# The following links are the analysis for this issue.
#
# Link: [🏈NFL 1st and Future - NFL Injury Study](https://github.com/ericahuang0516/football_analytics/blob/master/%F0%9F%8F%88NFL%201st%20and%20Future%20-%20NFL%20Injury%20Study.ipynb)
#
# Link: [🏈NFL 1st and Future - NFL Injury Study - InjuriedPlayerMovement](https://public.tableau.com/views/NFL1standFuture-NFLInjuryStudy-PlayerMovement/PlayerMovement?:display_count=y&:origin=viz_share_link)
#
# Link: [🏈NFL 1st and Future - NFL Injury Study - InjuryStat](https://public.tableau.com/views/NFL1standFuture-NFLInjuryStudy-InjuryStat/InjuryStat?:display_count=y&publish=yes&:origin=viz_share_link)
#
# More details and discussions are provided in my attached slides.
