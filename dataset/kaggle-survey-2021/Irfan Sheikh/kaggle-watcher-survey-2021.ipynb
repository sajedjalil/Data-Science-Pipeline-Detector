# %% [markdown]
# # *Hello, I am **The Watcher** and I have be assigned to guide you to the advancement of Data Science and Machine Learning. I have taken an oath to not intervene in the matters of human civilization. Lets get started to watch each survey one by one*

# %% [markdown]
# Let us start by adding some libraries who will help us in watching the data and explore it.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # So here we import the stories we want to see and explore

# %%
df = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')
df

# %%
df.info()

# %%
df.head()

# %%
df.describe()

# %%
df.isnull()

# %%
df['Q1']

# %%
df['Q2']

# %%
df1= df.drop(index=0)
df1

# %% [markdown]
# # **Chapter 1: Human Civilization**

# %% [markdown]
# ## In the following chapter, we see the advancement of human civilization in the field of Data Science and Machine Learning

# %%
df1['Q1']

# %%
df1.head()

# %% [markdown]
# ## The **Age** of people working on Data Science and Machine Leaning

# %%
plt.figure(figsize=(10,10))
plt.hist(df1['Q1'],width= 0.5,color='r')
plt.show()

# %% [markdown]
# ## As you can see, the youngest of the these species is in this field. God I remember my days as the lead scientist of my civilization.
#
# ## The most number of Data Scientist and ML Engineers are of the age from **25 years to 29 years of age**

# %% [markdown]
# # **Let us see the number of Males and Females in this Area**

# %%
df1['Q2'].head()

# %%
plt.figure(figsize=(10,10))
plt.hist(df1['Q2'],width = 0.2, color='purple', rwidth= 10)
plt.show()

# %% [markdown]
# ## As we can see, it consists of more of male than female. But that doesn't mean female are less, their contribution is more than that of male.

# %%
df1['Q3']

# %%
plt.figure(figsize=(90,30))

plt.hist(df1['Q3'],width=0.5, color='pink')

plt.show()

# %% [markdown]
# ## The most of Kaggler Data Scientists are from **India** with highest population participating in the site, with **Brazil** coming second on the list.

# %%
df1['Q4'].head()

# %%
plt.figure(figsize=(40,10))
plt.hist(df1['Q4'],width=0.3,color='black')
plt.show()

# %% [markdown]
# ## As you can see, the basic qualification is of the **Master's Degree**. With **Bachelor's Degree** in second place. This means that the most qualified population is there in this field

# %%
df1['Q5'].head()

# %%
plt.figure(figsize=(40,20))
plt.hist(df1['Q5'], width=0.4,color='y')
plt.show()

# %% [markdown]
# ## The most population of the Data Scientist is of the **Unemployed** data scientist, working full time on kaggle competitions. With **Data Analysts** coming the second highest crowd in the field of data science and machine learning

# %%
df1['Q6'].head()

# %%
plt.figure(figsize=(40,20))
plt.hist(df1['Q6'],width=0.4,color='magenta')
plt.show()

# %% [markdown]
# ## About 7800, kagglers have **1-3 years** of experience in the field of data scientist and machine learning. Secondly, there is increase in the number of people with **less than 1 year** of experience.

# %% [markdown]
# ### *In the recent times, humans have developed knowledge which is ahead of which they previously possessed, the example is the development in the field of Data Science and Machine Learning. With the help of these fields, much of the human tasks and work load can be reduced. It provides state of the art explanation and results which help in better understanding of the subject and the given task.*

# %% [markdown]
# # **Chapter 2: Mediums**

# %% [markdown]
# ### *In this chapter we will go through the mediums through which humans enforece machine learning and data science algorithms. We look closely to each and every aspect of the mediums and find the best aspect according to human civilization.*

# %% [markdown]
# ### In this we will see the programming languages recommended for applying Data Science and Machine Learning Algorithm.

# %%
Q7=(df1['Q8']).astype(str)

# %%
Q7

# %%
plt.figure(figsize=(20,10))
plt.hist(Q7,width=0.4,color='#0000CD')
plt.show()

# %% [markdown]
# # Therefore, **Python** is the most used language to implement Data Science and Machine Learning Algorithms

# %% [markdown]
# ### Now we see different integrated development environment(IDE)

# %%
jpl=df1['Q9_Part_1'].astype(str)
rs=df1['Q9_Part_2'].astype(str)
vs=df1['Q9_Part_3'].astype(str)
vsc=df1['Q9_Part_4'].astype(str)
pyc=df1['Q9_Part_5'].astype(str)
spy=df1['Q9_Part_6'].astype(str)
nplus=df1['Q9_Part_7'].astype(str)
subt=df1['Q9_Part_8'].astype(str)
vim=df1['Q9_Part_9'].astype(str)
matl=df1['Q9_Part_10'].astype(str)
jpn=df1['Q9_Part_11'].astype(str)

# %%
plt.figure(figsize=(50,10))
plt.hist(jpl,width=0.3)
plt.hist(rs,width=0.3)
plt.hist(vs,width=0.3)
plt.hist(vsc,width=0.3)
plt.hist(pyc,width=0.3)
plt.hist(spy,width=0.3)
plt.hist(nplus,width=0.3)
plt.hist(subt,width=0.3)
plt.hist(vim,width=0.3)
plt.hist(matl,width=0.3)
plt.hist(jpn,width=0.3)
plt.show()

# %% [markdown]
# # As we can see the **MATLAB**, is the most used IDE in enforcing Data Science and Machine Learning Algorithms

# %% [markdown]
# # **Chapter 3: Services**

# %% [markdown]
# ### *In this chapter, we will see the differnet notebooks which are used to develop machine learning algorithms. The devices which we use to implement them, the specialized software for deep learning and neural networks.Then we see the visualization libraries which are favourite of this civilization.*

# %% [markdown]
# ### Let now see the different types of Notebooks that are used to develop these algorithms

# %%
knb=df1['Q10_Part_1'].astype(str)
cnb=df1['Q10_Part_2'].astype(str)
azn=df1['Q10_Part_3'].astype(str)
pg=df1['Q10_Part_4'].astype(str)
bjh=df1['Q10_Part_5'].astype(str)
co=df1['Q10_Part_6'].astype(str)
iws=df1['Q10_Part_7'].astype(str)
asn=df1['Q10_Part_8'].astype(str)
aen=df1['Q10_Part_9'].astype(str)
gcn=df1['Q10_Part_10'].astype(str)
gcd=df1['Q10_Part_11'].astype(str)
dcn=df1['Q10_Part_12'].astype(str)
zn=df1['Q10_Part_13'].astype(str)
dn=df1['Q10_Part_14'].astype(str)
on=df1['Q10_Part_15'].astype(str)

# %%
plt.figure(figsize=(50,10))
plt.hist(knb,width=0.3)
plt.hist(cnb,width=0.3)
plt.hist(azn,width=0.3)
plt.hist(pg,width=0.3)
plt.hist(bjh,width=0.3)
plt.hist(co,width=0.3)
plt.hist(iws,width=0.3)
plt.hist(asn,width=0.3)
plt.hist(aen,width=0.3)
plt.hist(gcn,width=0.3)
plt.hist(gcd,width=0.3)
plt.hist(dcn,width=0.3)
plt.hist(zn,width=0.3)
plt.hist(dn,width=0.3)
plt.hist(on,width=0.3)
plt.show()

# %% [markdown]
# ### As we can see, the **Colab Notebooks** are the most prefered by Data Scientist and Machine Learning Engineers. With **Kaggle Notebooks** coming second in this stats

# %% [markdown]
# ### Let us see the device which is most used by the Data Scientist and Machine Learning Engineers

# %%
dev=df1['Q11'].astype(str)

# %%
plt.figure(figsize=(30,10))
plt.hist(dev,width=0.4,color='#00C957')
plt.show()

# %% [markdown]
# ### As we can see, the most preferred is a **Laptop** with a **Desktop** running in second

# %% [markdown]
# ### Now let us see the different specialized hardware, which is used in deep learning and neural networks.

# %%
ngpu=df1['Q12_Part_1'].astype(str)
gtpu=df1['Q12_Part_2'].astype(str)
atc=df1['Q12_Part_3'].astype(str)
aic=df1['Q12_Part_4'].astype(str)
no=df1['Q12_Part_5'].astype(str)

# %%
plt.figure(figsize=(30,10))
plt.hist(ngpu,width=0.3)
plt.hist(gtpu,width=0.3)
plt.hist(atc,width=0.3)
plt.hist(aic,width=0.3)
plt.hist(no,width=0.3)
plt.show()

# %% [markdown]
# ### As we can see, most of machine learning engineers and data scientist don't use much of the specialized hardware for deep learning and neural networks. But still most of the use **NVIDIA GPUs**. Which is also among the best of the specilized softwares

# %% [markdown]
# ## Now let's see how much time each Machine Learning Engineer uses the **Tensor Procressing Unit (TPU)**

# %%
tpu=df1['Q13'].astype(str)

# %%
plt.figure(figsize=(20,10))
plt.hist(tpu,width=0.3,color='#FF6103',align='left')
plt.show()

# %% [markdown]
# ### As this histogram shows, most of the machine learning engineers and data scientists don't use tensor processing unit at all to do their work.

# %% [markdown]
# ### Now let is see the favourite visual library of the Data Scientist and Machine Learning Engineers

# %%
matb=df1['Q14_Part_1'].astype(str)
seb=df1['Q14_Part_2'].astype(str)
plo=df1['Q14_Part_3'].astype(str)
ggp=df1['Q14_Part_4'].astype(str)
shin=df1['Q14_Part_5'].astype(str)
d3j=df1['Q14_Part_6'].astype(str)
alt=df1['Q14_Part_7'].astype(str)
bok=df1['Q14_Part_8'].astype(str)
geo=df1['Q14_Part_9'].astype(str)
lea=df1['Q14_Part_10'].astype(str)

# %%
plt.figure(figsize=(20,10))
plt.hist(matb,width=0.3)
plt.hist(seb,width=0.3)
plt.hist(plo,width=0.3)
plt.hist(ggp,width=0.3)
plt.hist(shin,width=0.3)
plt.hist(d3j,width=0.3)
plt.hist(alt,width=0.3)
plt.hist(bok,width=0.3)
plt.hist(geo,width=0.3)
plt.hist(lea,width=0.3)
plt.show()

# %% [markdown]
# ### As it shows, Matplotlib is the most used visiual library used for Data Scientist and Machine Learning Engineers

# %% [markdown]
# ### Let's see how many years Data Scientists and Machine Learning Engineers have used these algorithms

# %%
yrs=df1['Q15'].astype(str)

# %%
plt.figure(figsize=(30,10))
plt.hist(yrs,width=0.3,color='#8A2BE2')
plt.show()

# %% [markdown]
# ### As we get this, Machine Learning and Data Science is the field of the completely enthusiasts.

# %% [markdown]
# # **Chapter 4: Machine Learning**

# %% [markdown]
# ### *In this chapter, we will see the different machine learning algorithms, which ML algorithm is the popular of this civilization. The methods of implementing computer vision(CV) and Natural Language Processing (NLP)*

# %% [markdown]
# ### Let's begin with the most strong machine learning framework of the civilization.

# %%
skl=df1['Q16_Part_1'].astype(str)
tef=df1['Q16_Part_2'].astype(str)
ke=df1['Q16_Part_3'].astype(str)
pyt=df1['Q16_Part_4'].astype(str)
fas=df1['Q16_Part_5'].astype(str)
mxn=df1['Q16_Part_6'].astype(str)
xgb=df1['Q16_Part_7'].astype(str)
lgbm=df1['Q16_Part_8'].astype(str)
cb=df1['Q16_Part_9'].astype(str)
pro=df1['Q16_Part_10'].astype(str)
h2o=df1['Q16_Part_11'].astype(str)
car=df1['Q16_Part_12'].astype(str)
tid=df1['Q16_Part_13'].astype(str)
jax=df1['Q16_Part_14'].astype(str)
pytl=df1['Q16_Part_15'].astype(str)
huf=df1['Q16_Part_16'].astype(str)

# %%
plt.figure(figsize=(20,10))
plt.hist(skl,width=0.3,color='#3D59AB')
plt.hist(tef,width=0.3,color='#68228B')
plt.hist(ke,width=0.3,color='#006400')
plt.hist(pyt,width=0.3,color='#00EEEE')
plt.hist(fas,width=0.3,color='#DC143C')
plt.hist(mxn,width=0.3,color='#483D8B')
plt.hist(xgb,width=0.3,color='#00688B')
plt.hist(lgbm,width=0.3,color='#FFD700')
plt.hist(cb,width=0.3,color='#FFFF00')
plt.hist(pro,width=0.3,color='#FF69B4')
plt.hist(h2o,width=0.3,color='#8968CD')
plt.hist(car,width=0.3,color='#191970')
plt.hist(tid,width=0.3,color='#FF4500')
plt.hist(jax,width=0.3,color='#33A1C9')
plt.hist(pytl,width=0.3,color='#CD0000')
plt.hist(huf,width=0.3,color='#FF3E96')
plt.show()

# %% [markdown]
# ### As you can, **Scikit-learn** is the most preferred framework by machine learning engineers, with **TensorFlow** and **Keras** following.

# %% [markdown]
# ### Now let's see the favourite ML Algorithm among the Data Scientist and Machine Learning Engineer. This is the most important and crucial analysis as it becomes to the basis which is the best among the best and people's favourite

# %%
llr=df1['Q17_Part_1'].astype(str)
dtf=df1['Q17_Part_2'].astype(str)
gbm=df1['Q17_Part_3'].astype(str)
baye=df1['Q17_Part_4'].astype(str)
evo=df1['Q17_Part_5'].astype(str)
dnn=df1['Q17_Part_6'].astype(str)
cnn=df1['Q17_Part_7'].astype(str)
gan=df1['Q17_Part_8'].astype(str)
rnn=df1['Q17_Part_9'].astype(str)
tn=df1['Q17_Part_10'].astype(str)

# %%
plt.figure(figsize=(40,10))
plt.hist(llr,width=0.3)
plt.hist(dtf,width=0.3)
plt.hist(gbm,width=0.3)
plt.hist(baye,width=0.3)
plt.hist(evo,width=0.3)
plt.hist(dnn,width=0.3)
plt.hist(cnn,width=0.3)
plt.hist(gan,width=0.3)
plt.hist(rnn,width=0.3)
plt.hist(tn,width=0.3)
plt.show()

# %% [markdown]
# ### As we see, the most favourite ML algorithm is **Linear or Logistic Regression**, followed by **Decission Tree or Random Forest** and then **Gradient Boosting Machines**

# %% [markdown]
# ### Let's now see the which is the best Computer Vision Methods used by the Engineers of this civilization

# %%
gp=df1['Q18_Part_1'].astype(str)
ims=df1['Q18_Part_2'].astype(str)
odm=df1['Q18_Part_3'].astype(str)
ic=df1['Q18_Part_4'].astype(str)
gn=df1['Q18_Part_5'].astype(str)

# %%
plt.figure(figsize=(20,10))
plt.hist(gp,width=0.3)
plt.hist(ims,width=0.3)
plt.hist(odm,width=0.3)
plt.hist(ic,width=0.3)
plt.hist(gn,width=0.3)
plt.show()

# %% [markdown]
# ### **Image Classification** is the best method used in the Computer Vision

# %% [markdown]
# ### Let us now see the Natural Language Processing tools which are preferred by the machine learning engineers

# %%
we=df1['Q19_Part_1'].astype(str)
ed=df1['Q19_Part_2'].astype(str)
ce=df1['Q19_Part_3'].astype(str)
tlm=df1['Q19_Part_4'].astype(str)

# %%
plt.figure(figsize=(20,10))
plt.hist(we,width=0.3)
plt.hist(ed,width=0.3)
plt.hist(ce,width=0.3)
plt.hist(tlm,width=0.3)
plt.show()

# %% [markdown]
# ### **Word embedding** is the most preferred NLP tool by machine learning engineers

# %% [markdown]
# # **Chapter 5: Employment**

# %% [markdown]
# ### *In this chapter, we see the employment of the Machine Learning Engineers and Data Scientists. Their workplace siza and their Salary*

# %% [markdown]
# ### Let us see the industry where the machine learning is applied

# %%
ind=df1['Q20'].astype(str)

# %%
plt.figure(figsize=(20,10))
plt.hist(ind,width=0.3,color='#FF34B3')
plt.show()

# %% [markdown]
# ### As we see, machine learning is most used in **Academics and Education**

# %% [markdown]
# ### Let's see the company size in which the Data Scientist and Machine Learning Engineers work

# %%
siz=df1['Q21'].astype(str)

# %%
plt.figure(figsize=(20,10))
plt.hist(siz,width=0.3,color='#7CFC00')
plt.show()

# %% [markdown]
# ### As we can see there are only few employees in the industry about **0-49 employees** in the industry

# %% [markdown]
# ### Let us see the yearly compensation given to Data Scientist and Machine Learning Engineers in $USD

# %%
usd=df1['Q25'].astype(str)

# %%
plt.figure(figsize=(40,20))
plt.hist(usd,width=0.3,color='#FFD700')
plt.show()

# %% [markdown]
# ### As stated in the graph, an average yearly compensation to a Data Scientist and a Machine Learning Engineer is about **30,000 to 39,000 USD**

# %% [markdown]
# # To be Continued.......
