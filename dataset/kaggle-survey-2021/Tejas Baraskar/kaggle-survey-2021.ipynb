# %% [markdown]
# # Kaggle Survey 2021

# %%
# Importing libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Importing the dataset

# %%
df = pd.read_csv("../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv")
df.head(10)

# %%
# 0th row was discribing question columns for that we are preffering metadata file
df=df.iloc[1:,:]
df.head()

# %%
print('number of rows are',df.shape[0],'and number of columns are',df.shape[1])

# %% [markdown]
# # Questions

# %% [markdown]
# # 1 What is your age (# years)?

# %%
plt.figure(figsize =(20, 10))
sb.set_style('whitegrid')
sb.countplot(x='Q1',data=df,palette='rainbow')
plt.xlabel('Ages')
plt.show()

# %% [markdown]
# we can clearly see that majority of Kagglers are between 21 to 29 years of age. Very less are above 50

# %% [markdown]
# #2 What is your gender?

# %% [markdown]
# Displaying unique values in Q2 (gender) column

# %%
df['Q2'].unique()

# %% [markdown]
# Displaying the count

# %%
df['Q2'].value_counts()

# %%
fig = plt.figure(figsize =(20, 10))

#setting labels
gender = ['Man','Woman','Other']

#putting value count
gender_count = [20598,4890,485]

explode = (0.05, 0.05, 0.2)

plt.pie(gender_count,autopct='%1.1f%%', pctdistance=1.2,
        explode=explode,)
plt.legend(gender, loc = "upper right",title="Genders", prop={'size': 15})

plt.show()

# %% [markdown]
# There are 79.3% Male Kaggler,18.8% Female and 1.9% Other participants in 171 different countries and territories

# %% [markdown]
# # 3 Where is everyone from?

# %% [markdown]
# Displaying unique values in Q3 (Country) column

# %%
df['Q3'].unique()

# %% [markdown]
# Displaying count

# %%
df['Q3'].value_counts()

# %%
# Installing geopandas

# %%
# !pip install geopandas

# %%
#Importing the Geopandas

# %%
import geopandas as gpd

#Reading geopandas file

countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
countries.head()

# %%
Countries_list=['India', 'Indonesia', 'Pakistan', 'Mexico', 'Russia', 'Turkey',
       'Australia', 'Nigeria', 'Greece', 'Belgium', 'Japan', 'Egypt',
       'Singapore', 'Brazil', 'Poland', 'China',
       'Iran, Islamic Republic of...', 'United States of America',
       'Italy', 'Viet Nam', 'Israel', 'Peru', 'South Africa', 'Other',
       'Spain', 'Bangladesh',
       'United Kingdom of Great Britain and Northern Ireland', 'France',
       'Switzerland', 'Algeria', 'Tunisia', 'Argentina', 'Sweden',
       'Colombia', 'I do not wish to disclose my location', 'Canada',
       'Chile', 'Netherlands', 'Ukraine', 'Saudi Arabia', 'Romania',
       'Morocco', 'Austria', 'Taiwan', 'Kenya', 'Belarus', 'Ireland',
       'Portugal', 'Hong Kong (S.A.R.)', 'Denmark', 'Germany',
       'South Korea', 'Philippines', 'Sri Lanka', 'United Arab Emirates',
       'Uganda', 'Ghana', 'Malaysia', 'Thailand', 'Nepal', 'Kazakhstan',
       'Ethiopia', 'Iraq', 'Ecuador', 'Norway', 'Czech Republic']

# %%
# Listing Number of Kagglers

Number_of_kagglers=[7434,2650,1270,921,814,751,742,702,550,530,482,470,454,444,416,401,359,334,331,317,311,279,277,264,248,225,219,195,186,182,
                    182,156,153,146,140,138,123,119,117,111,109,108,106,102,102,99,89,84,81,79,75,71,69,65,63,61,51,51,50,48,47,45,45,44,43,43]

# %%
# we have to make dataframe

# %%
country_df=pd.DataFrame(Countries_list,columns=['Country'])

# %%
country_df['Count_of_kagglers']=Number_of_kagglers

# %% [markdown]
# Joining country_df with gpd dataset

# %%
Group = countries.set_index('name').join(country_df.set_index('Country')).reset_index()

# %%
C_O_K = 'Count_of_kagglers'
low, high = 0,10000
figure, axis = plt.subplots(1, figsize=(20,10))

Group.dropna().plot(column=C_O_K, cmap='cividis', linewidth=0.8, ax=axis, edgecolors='1', alpha=0.7)

smap = plt.cm.ScalarMappable(cmap='cividis', norm=plt.Normalize(vmin=low, vmax=high))
cbar = figure.colorbar(smap, orientation='vertical', shrink= 0.70)

# %% [markdown]
# It looks like more number of kagglers from India,USA and less number of kagglers from Norway

# %% [markdown]
# # 4 What is the highest level of formal education that you have attained or plan to attain within the next 2 years?

# %% [markdown]
# Displaying unique the highest level of formal education

# %%
df['Q4'].unique()

# %%
plt.figure(figsize =(20, 10))
sb.set_style('whitegrid')
df = df.replace('I prefer not to answer', 'No Answer')
df = df.replace('Some college/university study without earning a bachelor’s degree', 'Other')
df = df.replace('No formal education past high school', 'High School')
sb.countplot(x='Q4',data=df,palette='rainbow')
plt.xlabel('Education')
plt.show()

# %% [markdown]
# # 5 Select the title most similar to your current role (or most recent title if retired):

# %% [markdown]
# Displaying unique roles

# %%
df['Q5'].unique()

# %%
plt.figure(figsize =(20, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q5',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Current role')
plt.show()

# %% [markdown]
# We can see that mejority of kagglers are Students followed by Data Scientist,Software Engineer,Others,Data Analyst

# %% [markdown]
# # 6 For how many years have you been writing code and/or programming?
#
#
# > Indented block

# %% [markdown]
# Displaying unique years

# %%
df['Q6'].unique()

# %%
plt.figure(figsize =(20, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q6',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Years')
plt.show()

# %% [markdown]
# It is showing majority of kagglers have been writing code for 1-3 years followed by less than 1 year,3-5 years,5-10 years.
# Also 1000 kagglers have never written code.

# %% [markdown]
# # 7 What programming languages do you use on a regular basis? (Select all that apply)

# %% [markdown]
# Displaying unique programming languages

# %%
df['Q7_Part_1'].value_counts()

# %%
df['Q7_Part_2'].value_counts()

# %%
df['Q7_Part_3'].value_counts()

# %%
df['Q7_Part_4'].value_counts()

# %%
df['Q7_Part_5'].value_counts()

# %%
df['Q7_Part_6'].value_counts()

# %%
df['Q7_Part_7'].value_counts()

# %%
df['Q7_Part_8'].value_counts()

# %%
df['Q7_Part_9'].value_counts()

# %%
df['Q7_Part_10'].value_counts()

# %%
df['Q7_Part_11'].value_counts()

# %%
df['Q7_Part_12'].value_counts()

# %%
df['Q7_OTHER'].value_counts()

# %%
fig = plt.figure(figsize =(20, 10))

#setting labels
Language = ['Python','R','SQL','C','C++','Java','Javascript','Julia','Swift','Bash','MATLAB','None','Other']

#putting value count
Language_count = [21860,5334,10756,4709,5535,4769,4332,305,242,2216,2935,319,2575]

explode = (0.05, 0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05, 0.5,0.05)

plt.pie(Language_count,autopct='%1.1f%%', pctdistance=1.2,
        explode=explode,)
plt.legend(Language,title="Programming Languages", prop={'size': 10})

plt.show()

# %% [markdown]
# Figure shows that 33.2% kagglers (majority) use Python programming language followed by SQL (16.3%), R (8.1%).

# %% [markdown]
# # 8 What programming language would you recommend an aspiring data scientist to learn first?

# %%
fig = plt.figure(figsize =(20, 10))

#setting labels
Language1 = ['Python','R','SQL','C++','Other']

#putting value count
Language_count1 = [21860,5334,10756,5535,2575]

explode = (0.05, 0.05, 0.05, 0.05, 0.05)

plt.pie(Language_count1,autopct='%1.1f%%', pctdistance=1.2,
        explode=explode,)
plt.legend(Language1,title="Programming Languages", prop={'size': 9})

plt.show()

# %% [markdown]
# As a fresher i will recommend first to learn Python programming language followed by SQL for data science

# %% [markdown]
# # 9 Which of the following integrated development environments (IDE's) do you use on a regular basis?

# %%
#setting labels
IDE = ['JupyterLab','RStudio','Visual Studio','VS Code','PyCharm','Spyder','Notepad++','Sublime Text','Vim/Emacs','MATLAB','Jupyter Notebook','None','Other']

#putting value count
IDE_count = [5488,4771,4110,10040,7468,3794,3937,2839,1646,2203,16233,526,1491]

#explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

#plt.pie(IDE_count,autopct='%1.1f%%', pctdistance=1.2,explode=explode,)
#plt.legend(IDE,title="Programming Languages", prop={'size': 9})

#plt.show()

# %%
fig = plt.figure(figsize =(15, 10))

ax=plt.bar(IDE,IDE_count,color ='maroon',width = 0.4)
plt.tight_layout()
plt.xlabel('IDE Name')
plt.ylabel('IDE Count')
plt.show()

# %% [markdown]
# Plot shows majority of kagglers use Jupyter Notebook followed by VS Code ,PyCharm

# %% [markdown]
# # 10 Which of the following hosted notebook products do you use on a regular basis?

# %%
print(df['Q10_Part_1'].value_counts())
print(df['Q10_Part_2'].value_counts())
print(df['Q10_Part_3'].value_counts())
print(df['Q10_Part_4'].value_counts())
print(df['Q10_Part_5'].value_counts())
print(df['Q10_Part_6'].value_counts())
print(df['Q10_Part_7'].value_counts())
print(df['Q10_Part_8'].value_counts())
print(df['Q10_Part_9'].value_counts())
print(df['Q10_Part_10'].value_counts())

# %%
H_note = ['Colab Notebook','Kaggle Notebook','None']
H_note_cnt = [9792,9507,7174]

# %%
fig = plt.figure(figsize =(10, 5))
ax=plt.bar(H_note,H_note_cnt,color ='green',width = 0.4)
plt.tight_layout()
plt.xlabel('Host IDE Name')
plt.ylabel('Host IDE Count')
plt.show()

# %% [markdown]
# More than 9000 of kagglers use Colab hosted notebook product on regular basis followed by Kaggle hosted notebook.

# %% [markdown]
# # 11 What type of computing platform do you use most often for your data science projects?

# %% [markdown]
# Displaying count of computing platform

# %%
df['Q11'].value_counts()

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q11',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Computing Platform')
plt.show()

# %% [markdown]
# Most of the kagglers use laptops as a computing platform for their datascience projects.

# %% [markdown]
# # 12 Which types of specialized hardware do you use on a regular basis? (Select all that apply)

# %%
Hard = ["None","NVIDIA GPUs","Google Cloud TPUs","Other","AWS Inferentia Chips","AWS Trainium Chips"]
Hard_count = [13234,8036,3451,867,416,414]
plt.figure(figsize =(10, 15))

explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

plt.pie(Hard_count,autopct='%1.1f%%', pctdistance=1.2,
        explode=explode,)
plt.legend(Hard,title="Specialized Hardware", prop={'size': 9})

plt.show()

# %% [markdown]
# Half of kagglers use non of the secialized hardware.
# 30.4% kagglers use NVDIA GPU's and 13.1% kagglers use Google cloud TPU's.

# %% [markdown]
# # 13 Approximately how many times have you used a TPU (tensor processing unit)?

# %% [markdown]
# Count of TPU users

# %%
df['Q13'].value_counts()

# %%
plt.figure(figsize =(10, 5))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q13',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Times Use TPU')
plt.show()

# %% [markdown]
# Looks like larger number of kagglers never use TPU.
# More than 3000 kagglers use TPU 2-5 times also there are less than 1000 kagglers who use TPU more than 25 times.

# %% [markdown]
# # 14 What data visualization libraries or tools do you use on a regular basis?

# %% [markdown]
# Count of visualization libraries users

# %%
print(df['Q14_Part_1'].value_counts())
print(df['Q14_Part_2'].value_counts())
print(df['Q14_Part_3'].value_counts())
print(df['Q14_Part_4'].value_counts())
print(df['Q14_Part_5'].value_counts())
print(df['Q14_Part_6'].value_counts())
print(df['Q14_Part_7'].value_counts())
print(df['Q14_Part_8'].value_counts())
print(df['Q14_Part_9'].value_counts())
print(df['Q14_Part_10'].value_counts())
print(df['Q14_Part_11'].value_counts())
print(df['Q14_OTHER'].value_counts())

# %%
Libraries=['Matplotlib','Seaborn','Plotly / Plotly Express','Ggplot / ggplot2','Shiny','D3 js','Altair','Bokeh','Geoplotlib','Leaflet / Folium','None','Other']

# %%
Libraries_cnt=[17595,12586,5778,5100,1322,978,309,1050,1148,716,3479,776]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(Libraries,Libraries_cnt,color ='green',width = 0.4)
plt.tight_layout()
plt.xlabel('Libraries Name')
plt.ylabel('Libraries Count')
plt.show()

# %% [markdown]
# Most of the users use Matplotlib library followed by Seaborn, Plotly/Plotly Express. Also 3000 kagglers are not using any visualization libraries.

# %% [markdown]
# # 15 For how many years have you used machine learning methods?

# %% [markdown]
# Count of machine learning method users

# %%
df['Q15'].value_counts()

# %%
plt.figure(figsize =(10, 5))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q15',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Years')
plt.show()

# %% [markdown]
# There is large count of kagglers who use machine learning methods less than 1 year.Second place has taken by kagglers  who use machine learning methods 1-2 years.Also there is less count of kagglers who use machine learning methods 20 or more years.

# %% [markdown]
# # 16 Which of the following machine learning frameworks do you use on a regular basis?

# %%
print(df['Q16_Part_1'].value_counts())
print(df['Q16_Part_2'].value_counts())
print(df['Q16_Part_3'].value_counts())
print(df['Q16_Part_4'].value_counts())
print(df['Q16_Part_5'].value_counts())
print(df['Q16_Part_6'].value_counts())
print(df['Q16_Part_7'].value_counts())
print(df['Q16_Part_8'].value_counts())
print(df['Q16_Part_9'].value_counts())
print(df['Q16_Part_10'].value_counts())
print(df['Q16_Part_11'].value_counts())
print(df['Q16_Part_12'].value_counts())
print(df['Q16_Part_13'].value_counts())
print(df['Q16_Part_14'].value_counts())
print(df['Q16_Part_15'].value_counts())
print(df['Q16_Part_16'].value_counts())
print(df['Q16_Part_17'].value_counts())
print(df['Q14_OTHER'].value_counts())

# %%
Frameworks=['Scikit-learn','TensorFlow','Keras','PyTorch','Fast.ai','MXNet','Xgboost','LightGBM','CatBoost','Prophet','H2O 3','Caret','Tidymodels','JAX','Scikit-learn','PyTorch Lightning ','None','Other']

# %%
Frameworks_cnt=[13987,9371,7975,6088,824,252,5974,2635,1512,800,488,1009,678,190,1060,1122,1916,776]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(Frameworks,Frameworks_cnt,color ='green',width = 0.4)
plt.tight_layout()
plt.xlabel('Frameworks Name')
plt.ylabel('Frameworks Count')
plt.show()

# %% [markdown]
# Kagglers preffer to use Scikit-learn followed by TensorFlow,Keras,PyTorch

# %% [markdown]
# # 17 Which of the following ML algorithms do you use on a regular basis?

# %% [markdown]
# Displaying count of algorithms user

# %%
print(df['Q17_Part_1'].value_counts())
print(df['Q17_Part_2'].value_counts())
print(df['Q17_Part_3'].value_counts())
print(df['Q17_Part_4'].value_counts())
print(df['Q17_Part_5'].value_counts())
print(df['Q17_Part_6'].value_counts())
print(df['Q17_Part_7'].value_counts())
print(df['Q17_Part_8'].value_counts())
print(df['Q17_Part_9'].value_counts())
print(df['Q17_Part_10'].value_counts())
print(df['Q17_Part_11'].value_counts())
print(df['Q17_OTHER'].value_counts())

# %%
Algo=['L/L Regression','DT/RF','G B M','Bayesian Approaches','Evolutionaty App','DNN','CNN','ADN','RNN','TN','None','Other']

# %%
Algo_cnt=[13852,11863,7566,4392,963,4468,7410,1353,4228,2273,1470,483]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(Algo,Algo_cnt,color ='green',width = 0.4)
plt.tight_layout()
plt.xlabel('Algorithms Name')
plt.ylabel('Algorithms Count')
plt.show()

# %% [markdown]
# Most of the times Kagglers preferred Linear/Logistic regression followed by Decision Tree/ Random Forest

# %% [markdown]
# # 18 Which categories of computer vision methods do you use on a regular basis? (Select all that apply)

# %%
v_methods = ['VGG/Inception/ResNet','Object Detection Method','Image Segmentation Method','General Purpose Img/Vid Tools','GAN','None','Other']
v_methods_cnt = [4373,2716,2740,2662,1492,1439,119]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(v_methods,v_methods_cnt,color ='blue',width = 0.4)
plt.tight_layout()
plt.xlabel(' Computer vision methods Name')
plt.ylabel('Computer vision methods Count')
plt.show()

# %% [markdown]
# VGG/Inception/ResNet categories of computer vision methods use on a regular basis followed by Image Segmentation,Object Detection methods.

# %% [markdown]
# # 19 Which of the following natural language processing (NLP) methods do you use on a regular basis?

# %%
NLP_methods = ['Encoder-Decoder Models','Word Embeddings/Vectors','Transformer Lang Tools','None','Contextualized Embeddings']
NLP_methods_cnt = [2023,2643,2351,1331,748]
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(NLP_methods,NLP_methods_cnt,color ='blue',width = 0.4)
plt.tight_layout()
plt.xlabel('NLP_methods Name')
plt.ylabel('NLP_methods Count')
plt.show()

# %% [markdown]
# Word Embedding , Transformer Lang Tools NLP methods use on regular basis.

# %% [markdown]
# # 20 In what industry is your current employer/contract (or your most recent employer if retired)?

# %%
df['Q20'].value_counts()

# %%
plt.figure(figsize =(18, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q20',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Current Employer')
plt.show()

# %% [markdown]
# Plot shows Computers/Technology as highest current employer.Second is Academics/Education.

# %% [markdown]
# # 21 What is the size of the company where you are employed?

# %%
plt.figure(figsize =(10, 5))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q21',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('size of the company')
plt.show()

# %% [markdown]
# # 22 Approximately how many individuals are responsible for data science workloads at your place of business?

# %%
plt.figure(figsize =(10, 5))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q22',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel(' Individuals are responsible')
plt.show()

# %% [markdown]
# # 23 Does your current employer incorporate machine learning methods into their business?

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q23',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('employer incorporate')
plt.show()

# %% [markdown]
# # 24 Select any activities that make up an important part of your role at work: (Select all that apply)

# %% [markdown]
# Displaying count of important roles at work

# %%
print(df['Q24_Part_1'].value_counts())
print(df['Q24_Part_2'].value_counts())
print(df['Q24_Part_3'].value_counts())
print(df['Q24_Part_4'].value_counts())
print(df['Q24_Part_5'].value_counts())
print(df['Q24_Part_6'].value_counts())
print(df['Q24_Part_7'].value_counts())
print(df['Q24_OTHER'].value_counts())

# %%
Role=['Analyze & understand data ','Build Data infrastructure','Build prototypes','Build/run a ML service','Experimentation','Do research',
      'None','Other']
Role_cnt=[9108,4562,5150,3694,3974,3160,2825,677]

plt.figure(figsize =(10, 10))

plt.barh(Role, Role_cnt)
# setting label of y-axis
plt.ylabel("Role At Work")
 
# setting label of x-axis
plt.xlabel("Role Count At Work ")
plt.title(" An Important Part Of Your Role At Work")
plt.show()

# %% [markdown]
# Most of the kagglers have analyze and understand data to influence product or business decisions role at work followed by build data infrastructure role.

# %% [markdown]
# # 25 What is your current yearly compensation (approximate $USD)?

# %% [markdown]
# Displaying compensation and count of kagglers

# %%
df['Q25'].value_counts()

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q25',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Yearly Compensation')
plt.show()

# %% [markdown]
# # 26 Approximately how much money have you (or your team) spent on machine learning and/or cloud computing services at home (or at work) in the past 5 years (approximate $USD)?

# %%
df['Q26'].value_counts()

# %%
money = ['$0','$100-$999','$1000-$9,999','$1-$99','$10,000-$99,999','$100,000 or more']
money_cnt = [5903,2534,2491,1929,1309,1017]

plt.figure(figsize =(10, 15))

explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

plt.pie(money_cnt,autopct='%1.1f%%', pctdistance=1.2,
        explode=explode,)
plt.legend(money,title="Money Spent ($USD)", prop={'size': 9})

plt.show()

# %% [markdown]
# 38.9% kagglers did not spend money on Machine Learning and Cloud Computing services. 16.7% spent 100-999 $'USD' and  6.7% spent 100000-more $'USD' on ML and Cloud Computing Services.

# %% [markdown]
# # 27 Which of the following cloud computing platforms do you use on a regular basis? (Select all that apply)

# %% [markdown]
# Cloud Services and count of users

# %%
print(df['Q27_A_Part_1'].value_counts())
print(df['Q27_A_Part_2'].value_counts())
print(df['Q27_A_Part_3'].value_counts())
print(df['Q27_A_Part_4'].value_counts())
print(df['Q27_A_Part_5'].value_counts())
print(df['Q27_A_Part_6'].value_counts())
print(df['Q27_A_Part_7'].value_counts())
print(df['Q27_A_Part_8'].value_counts())
print(df['Q27_A_Part_9'].value_counts())
print(df['Q27_A_Part_10'].value_counts())
print(df['Q27_A_Part_11'].value_counts())
print(df['Q27_A_OTHER'].value_counts())

# %%
cloud_ser = ['AWS',' Microsoft Azure ','GCP','IBM Cloud/Red Hat','Oracle','SAP','Salesforce',' VMware','Alibaba','Tencent','None','Other']

# %%
cloud_ser_cnt=[3721,2450,3142,572,454,290,275,390,259,172,2689,337]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(cloud_ser,cloud_ser_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Cloud Services Name')
plt.xlabel('Cloud Services Users Count')
plt.title('Cloud Services And Users')
plt.show()

# %% [markdown]
# Most of the kagglers preferred AWS cloud service followed by CGP, Microsoft Azure. Also there is large count of kagglers who did not use cloud services.

# %% [markdown]
# # 28 Of the cloud platforms that you are familiar with, which has the best developer experience (most enjoyable to use)?

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q28',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Cloud Platforms')
plt.show()

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q28',hue='Q1',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel('Cloud Platforms')
plt.show()

# %% [markdown]
# # 29 Do you use any of the following cloud computing products on a regular basis? (Select all that apply)

# %%
print(df['Q29_A_Part_1'].value_counts())
print(df['Q29_A_Part_2'].value_counts())
print(df['Q29_A_Part_3'].value_counts())
print(df['Q29_A_Part_4'].value_counts())
print(df['Q29_A_OTHER'].value_counts())

# %%
CP = ['EC2','Microsoft Azure Virtual Machines','Google Cloud Compute Engine','None','Other']
CP_cnt = [2270,1503,1960,1795,98]

plt.figure(figsize =(10, 15))

explode = (0.05, 0.05, 0.05, 0.05, 0.05)

plt.pie(CP_cnt,autopct='%1.1f%%', pctdistance=1.2,
        explode=explode,)
plt.legend(CP,title="Computing Products", prop={'size': 9})

# %% [markdown]
# Kagglers use EC2 on regular basis followed by google cloud compute Engine.

# %% [markdown]
# # 30 Do you use any of the following data storage products on a regular basis? (Select all that apply)

# %% [markdown]
# Storage products

# %%
print(df['Q30_A_Part_1'].value_counts())
print(df['Q30_A_Part_2'].value_counts())
print(df['Q30_A_Part_3'].value_counts())
print(df['Q30_A_Part_4'].value_counts())
print(df['Q30_A_Part_5'].value_counts())
print(df['Q30_A_Part_6'].value_counts())
print(df['Q30_A_Part_7'].value_counts())
print(df['Q30_A_OTHER'].value_counts())

# %%
prod = ['Microsoft Azure Data Lake Storage','Microsoft Azure Disk Storage','S3','EFS','GCS','Google Cloud Filestore','None','Other']
prod_cnt=[908,841,2308,685,1950,772,1510,92]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(prod,prod_cnt,color ='yellow',width = 0.4)
plt.tight_layout()
plt.xlabel(' Product Name')
plt.ylabel('Product Users Count')
plt.show()

# %% [markdown]
# # 31 Do you use any of the following managed machine learning products on a regular basis? (Select all that apply)

# %% [markdown]
# ML products

# %%
print(df['Q31_A_Part_1'].value_counts())
print(df['Q31_A_Part_2'].value_counts())
print(df['Q31_A_Part_3'].value_counts())
print(df['Q31_A_Part_4'].value_counts())
print(df['Q31_A_Part_5'].value_counts())
print(df['Q31_A_Part_6'].value_counts())
print(df['Q31_A_Part_7'].value_counts())
print(df['Q31_A_Part_8'].value_counts())
print(df['Q31_A_Part_9'].value_counts())
print(df['Q31_A_OTHER'].value_counts())

# %%
ML_P=['Amazon SageMaker','Azure ML Studio','Google Cloud Vertex AI','DataRobot','Databricks','Dataiku','Alteryx','Rapidminer','None','Other']
MLcnt=[991,945,714,332,825,203,254,293,6381,275]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(ML_P,MLcnt,color ='yellow',width = 0.4)
plt.tight_layout()
plt.xlabel(' ML Product Name')
plt.ylabel('ML Product Users Count')
plt.show()

# %% [markdown]
# # 32 Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis? (Select all that apply)

# %% [markdown]
# Big Data Products

# %%
print(df['Q32_A_Part_1'].value_counts())
print(df['Q32_A_Part_2'].value_counts())
print(df['Q32_A_Part_3'].value_counts())
print(df['Q32_A_Part_4'].value_counts())
print(df['Q32_A_Part_5'].value_counts())
print(df['Q32_A_Part_6'].value_counts())
print(df['Q32_A_Part_7'].value_counts())
print(df['Q32_A_Part_8'].value_counts())
print(df['Q32_A_Part_9'].value_counts())
print(df['Q32_A_Part_10'].value_counts())
print(df['Q32_A_Part_11'].value_counts())
print(df['Q32_A_Part_12'].value_counts())
print(df['Q32_A_Part_13'].value_counts())
print(df['Q32_A_Part_14'].value_counts())
print(df['Q32_A_Part_15'].value_counts())
print(df['Q32_A_Part_16'].value_counts())
print(df['Q32_A_Part_17'].value_counts())
print(df['Q32_A_Part_18'].value_counts())
print(df['Q32_A_Part_19'].value_counts())
print(df['Q32_A_Part_20'].value_counts())
print(df['Q32_A_OTHER'].value_counts())

# %%
BDP=['MySQL','PostgreSQL','SQLite','Oracle','MongoDB','Snowflake','IBM Db2','M. SQL','M. AzureSQL','M. Azure Cosmos','Amazon Redshift',
     'Amazon Aurora','Amazon RDS','Amazon DynamoDB','Google Cloud BigQuery','Google Cloud SQL','Google Cloud Firestore','Google Cloud BigTable',
     'Google Cloud Spanner','None','Other']
BPDCnt=[3576,2260,1640,1103,1658,490,352,1906,778,369,582,289,607,464,889,583,361,347,197,2297,359]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(BDP,BPDCnt,color ='green')
plt.tight_layout()
plt.ylabel('Big Data Product Name')
plt.xlabel('Big Data Product Users Count')
plt.title('Big Data Product And Users')
plt.show()

# %% [markdown]
# Most of the kagglers preferred MySQL

# %% [markdown]
# # 33 Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often?

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q33',hue='Q1',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel(' Big Data Products')
plt.show()

# %% [markdown]
# # 34 Which of the following business intelligence tools do you use on a regular basis? (Select all that apply)

# %%
print(df['Q34_A_Part_1'].value_counts())
print(df['Q34_A_Part_2'].value_counts())
print(df['Q34_A_Part_3'].value_counts())
print(df['Q34_A_Part_4'].value_counts())
print(df['Q34_A_Part_5'].value_counts())
print(df['Q34_A_Part_6'].value_counts())
print(df['Q34_A_Part_7'].value_counts())
print(df['Q34_A_Part_8'].value_counts())
print(df['Q34_A_Part_9'].value_counts())
print(df['Q34_A_Part_10'].value_counts())
print(df['Q34_A_Part_11'].value_counts())
print(df['Q34_A_Part_12'].value_counts())
print(df['Q34_A_Part_13'].value_counts())
print(df['Q34_A_Part_14'].value_counts())
print(df['Q34_A_Part_15'].value_counts())
print(df['Q34_A_Part_16'].value_counts())
print(df['Q32_A_OTHER'].value_counts())

# %%
Bit=['Amazon QuickSight','Microsoft Power BI','Google Data Studio','Looker','Tableau','Salesforce','Tableau CRM','Qlik','Domo','TIBCO Spotfire','Alteryx',
     'Sisense','SAP Analytics Cloud','Microsoft Azure Synapse','Thoughtspot','None','Other']
Bit_cnt=[246,2405,919,195,2564,391,380,432,78,108,212,85,231,279,50,4123,359]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Bit,Bit_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Business Intelligence Tools Name')
plt.xlabel('Business Intelligence Tools Users Count')
plt.title('Business Intelligence Tools And Users')
plt.show()

# %% [markdown]
# # 35 Which of the following business intelligence tools do you use most often?

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q35',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel(' Business Intelligence Tools')
plt.show()

# %% [markdown]
# # 36 Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis?

# %%
print(df['Q36_A_Part_1'].value_counts())
print(df['Q36_A_Part_2'].value_counts())
print(df['Q36_A_Part_3'].value_counts())
print(df['Q36_A_Part_4'].value_counts())
print(df['Q36_A_Part_5'].value_counts())
print(df['Q36_A_Part_6'].value_counts())
print(df['Q36_A_Part_7'].value_counts())
print(df['Q36_A_OTHER'].value_counts())

# %%
Auto_ML_tools=['Automated data augmentation','Automated feature engineering','Automated model selection','Automated model architecture searches','Automated hyperparameter tuning','Automation of full ML pipelines','None','Other']
Auto_ML_tools_cnt=[1009,781,1186,344,952,893,6338,214]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Auto_ML_tools,Auto_ML_tools_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Automated Machine Learning Tools Name')
plt.xlabel('Automated Machine Learning Tools Users Count')
plt.title('Automated Machine Learning Tools And Users')
plt.show()

# %% [markdown]
# # 37 Which of the following automated machine learning tools (or partial AutoML tools) do you use on a regular basis?

# %%
print(df['Q37_A_Part_1'].value_counts())
print(df['Q37_A_Part_2'].value_counts())
print(df['Q37_A_Part_3'].value_counts())
print(df['Q37_A_Part_4'].value_counts())
print(df['Q37_A_Part_5'].value_counts())
print(df['Q37_A_Part_6'].value_counts())
print(df['Q37_A_Part_7'].value_counts())
print(df['Q37_A_OTHER'].value_counts())

# %%
pAuto_ML_tools=['Automated data augmentation','Automated feature engineering','Automated model selection','Automated model architecture searches','Automated hyperparameter tuning','Automation of full ML pipelines','None','Other']
pAuto_ML_tools_cnt=[751,316,321,271,377,449,1196,223]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(pAuto_ML_tools,pAuto_ML_tools_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Partial Automated Machine Learning Tools Name')
plt.xlabel('Partial Automated Machine Learning Tools Users Count')
plt.title('Partial Automated Machine Learning Tools And Users')
plt.show()

# %% [markdown]
# # 38 Do you use any tools to help manage machine learning experiments? (Select all that apply)

# %%
print(df['Q38_A_Part_1'].value_counts())
print(df['Q38_A_Part_2'].value_counts())
print(df['Q38_A_Part_3'].value_counts())
print(df['Q38_A_Part_4'].value_counts())
print(df['Q38_A_Part_5'].value_counts())
print(df['Q38_A_Part_6'].value_counts())
print(df['Q38_A_Part_7'].value_counts())
print(df['Q38_A_Part_8'].value_counts())
print(df['Q38_A_Part_9'].value_counts())
print(df['Q38_A_Part_10'].value_counts())
print(df['Q38_A_Part_11'].value_counts())
print(df['Q38_A_OTHER'].value_counts())

# %%
Any_tools=['Neptune.ai','Weights & Biases','Comet.ml','Sacred + Omniboard','TensorBoard','Guild.ai','Polyaxon','ClearML','Domino Model Monitor','MLflow','None','Other']
Any_tools_cnt=[217,538,106,98,1726,119,110,177,91,1067,6239,225]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Any_tools,Any_tools_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Any Machine Learning Tools Name')
plt.xlabel('Any Machine Learning Tools Users Count')
plt.title('Any Machine Learning Tools And Users')
plt.show()

# %% [markdown]
# # 39 Where do you publicly share or deploy your data analysis or machine learning applications?

# %%
print(df['Q39_Part_1'].value_counts())
print(df['Q39_Part_2'].value_counts())
print(df['Q39_Part_3'].value_counts())
print(df['Q39_Part_4'].value_counts())
print(df['Q39_Part_5'].value_counts())
print(df['Q39_Part_6'].value_counts())
print(df['Q39_Part_7'].value_counts())
print(df['Q39_Part_8'].value_counts())
print(df['Q39_Part_9'].value_counts())
print(df['Q39_OTHER'].value_counts())

# %%
Deploy=['Plotly Dash','Streamlit','NBViewer','GitHub','Personal blog','Kaggle','Colab','Shiny','None','Other']
Deploy_cnt=[293,387,136,4586,705,3065,1848,305,3167,306]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Deploy,Deploy_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Publicly share or deploy your data analysis or machine learning applications Name')
plt.xlabel('Publicly share or deploy your data analysis or machine learning applications Users Count')
plt.title('Publicly share or deploy your data analysis or machine learning applications And Users')
plt.show()

# %% [markdown]
# Kagglers use GitHub for deploying data analysis and machine learning applications followed by Kaggle.

# %% [markdown]
# # 40 On which platforms have you begun or completed data science courses? (Select all that apply)

# %%
print(df['Q40_Part_1'].value_counts())
print(df['Q40_Part_2'].value_counts())
print(df['Q40_Part_3'].value_counts())
print(df['Q40_Part_4'].value_counts())
print(df['Q40_Part_5'].value_counts())
print(df['Q40_Part_6'].value_counts())
print(df['Q40_Part_7'].value_counts())
print(df['Q40_Part_8'].value_counts())
print(df['Q40_Part_9'].value_counts())
print(df['Q40_Part_10'].value_counts())
print(df['Q40_Part_11'].value_counts())
print(df['Q40_OTHER'].value_counts())

# %%
Platforms=['Coursera','edX','Kaggle Learn Courses','DataCamp','Fast.ai','Udacity','Udemy','LinkedIn Learning','Cloud-certification programs','University Courses','None','Other']
Platforms_cnt=[9649,3028,8670,3996,1157,2803,6440,2693,1804,4882,1762,2081]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Platforms,Platforms_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Platforms have you begun or completed data science courses Name')
plt.xlabel('Platforms have you begun or completed data science courses Users Count')
plt.title('Platforms have you begun or completed data science courses And Users')
plt.show()

# %% [markdown]
# Most of the kagglers use Coursera followed by Kaggle Learn Courses to complete data science courses.

# %% [markdown]
# # 41 What is the primary tool that you use at work or school to analyze data?

# %%
plt.figure(figsize =(15, 10))
sb.set_style('whitegrid')
ax=sb.countplot(x='Q41',data=df,palette='rainbow')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.xlabel(' Primary tool that you use at work or school to analyze data')
plt.show()

# %% [markdown]
# # 42 Who/what are your favorite media sources that report on data science topics?

# %%
print(df['Q42_Part_1'].value_counts())
print(df['Q42_Part_2'].value_counts())
print(df['Q42_Part_3'].value_counts())
print(df['Q42_Part_4'].value_counts())
print(df['Q42_Part_5'].value_counts())
print(df['Q42_Part_6'].value_counts())
print(df['Q42_Part_7'].value_counts())
print(df['Q42_Part_8'].value_counts())
print(df['Q42_Part_9'].value_counts())
print(df['Q42_Part_10'].value_counts())
print(df['Q42_Part_11'].value_counts())
print(df['Q42_OTHER'].value_counts())

# %%
media_src=['Twitter','Email newsletters','Reddit','Kaggle','Course Forums','YouTube','Podcasts','Blogs','Journal Publications','Slack Communities','None','Other']
media_src_cnt=[3747,3441,2939,11373,2996,10401,2022,7977,3350,1995,1007,583]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(media_src,media_src_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Favorite media sources Name')
plt.xlabel('Favorite media sources Users Count')
plt.title('Favorite media sources And Users')
plt.show()

# %% [markdown]
# # Supplementary Questions:

# %% [markdown]
# # 27B Which of the following cloud computing platforms do you hope to become more familiar with in the next 2 years?

# %%
print(df['Q27_B_Part_1'].value_counts())
print(df['Q27_B_Part_2'].value_counts())
print(df['Q27_B_Part_3'].value_counts())
print(df['Q27_B_Part_4'].value_counts())
print(df['Q27_B_Part_5'].value_counts())
print(df['Q27_B_Part_6'].value_counts())
print(df['Q27_B_Part_7'].value_counts())
print(df['Q27_B_Part_8'].value_counts())
print(df['Q27_B_Part_9'].value_counts())
print(df['Q27_B_Part_10'].value_counts())
print(df['Q27_B_Part_11'].value_counts())
print(df['Q27_B_OTHER'].value_counts())

# %%
c_pl=['AWS','Microsoft Azure','GCP','IBM','Oracle','SAP','VMware','Salesforce',' Alibaba','Tencent','None','Other']
c_pl_cnt=[7494,5648,7484,2589,1712,910,784,792,632,550,2238,269]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(c_pl,c_pl_cnt,color ='green')
plt.tight_layout()
plt.ylabel('Cloud Computing Platform Name')
plt.xlabel('Cloud Computing Platform Users Count')
plt.title('Cloud Computing Platform And Users')
plt.show()

# %% [markdown]
# # 29B In the next 2 years, do you hope to become more familiar with any of these specific cloud computing products?

# %%
print(df['Q29_B_Part_1'].value_counts())
print(df['Q29_B_Part_2'].value_counts())
print(df['Q29_B_Part_3'].value_counts())
print(df['Q29_B_Part_4'].value_counts())
print(df['Q29_B_OTHER'].value_counts())

# %%
CP2 = ['EC2','Microsoft Azure Virtual Machines','Google Cloud Compute Engine','None','Other']
CP_cnt2 = [5378,5793,7497,970,78]

plt.figure(figsize =(10, 15))

explode = (0.05, 0.05, 0.05, 0.05, 0.05)

plt.pie(CP_cnt2,autopct='%1.1f%%', pctdistance=1.2,
        explode=explode,)
plt.legend(CP2,title="Computing Products", prop={'size': 9})

# %% [markdown]
# 38% kagglers selected yes for Google cloud computing engine.29.4% selected Microsoft Azure and 27.3% selected EC2.

# %% [markdown]
# # 30B In the next 2 years, do you hope to become more familiar with any of these specific data storage products?

# %%
print(df['Q30_B_Part_1'].value_counts())
print(df['Q30_B_Part_2'].value_counts())
print(df['Q30_B_Part_3'].value_counts())
print(df['Q30_B_Part_4'].value_counts())
print(df['Q30_B_Part_5'].value_counts())
print(df['Q30_B_Part_6'].value_counts())
print(df['Q30_B_Part_7'].value_counts())
print(df['Q30_B_OTHER'].value_counts())

# %%
df['Q30_B_Part_7'].nunique()

# %%
prod2 = ['Microsoft Azure Data Lake Storage','Microsoft Azure Disk Storage','S3','EFS','GCS','Google Cloud Filestore','None','Other']
prod_cnt2=[0,0,0,0,0,0,0,0]
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(prod2,prod_cnt2,color ='yellow',width = 0.4)
plt.tight_layout()
plt.xlabel(' Product Name')
plt.ylabel('Product Users Count')
plt.show()

# %% [markdown]
# kagglers have selected nothing.

# %% [markdown]
# # 31B In the next 2 years, do you hope to become more familiar with any of these managed machine learning products?

# %%
print(df['Q31_B_Part_1'].value_counts())
print(df['Q31_B_Part_2'].value_counts())
print(df['Q31_B_Part_3'].value_counts())
print(df['Q31_B_Part_4'].value_counts())
print(df['Q31_B_Part_5'].value_counts())
print(df['Q31_B_Part_6'].value_counts())
print(df['Q31_B_Part_7'].value_counts())
print(df['Q31_B_Part_8'].value_counts())
print(df['Q31_B_Part_9'].value_counts())
print(df['Q31_B_OTHER'].value_counts())

# %%
ML_P2=['Amazon SageMaker','Azure ML Studio','Google Cloud Vertex AI','DataRobot','Databricks','Dataiku','Alteryx','Rapidminer','None','Other']
MLcnt2=[3649,5029,5304,1832,2202,763,792,1019,4111,349]

# %%
fig = plt.figure(figsize =(18, 5))
ax=plt.bar(ML_P2,MLcnt2,color ='yellow',width = 0.4)
plt.tight_layout()
plt.xlabel(' ML Product Name')
plt.ylabel('ML Product Users Count')
plt.show()

# %% [markdown]
# Kagglers selected Google Cloud Vertex AI followed by Azure ML Studio,Amazon SageMaker

# %% [markdown]
# # 32B Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years?

# %%
print(df['Q32_B_Part_1'].value_counts())
print(df['Q32_B_Part_2'].value_counts())
print(df['Q32_B_Part_3'].value_counts())
print(df['Q32_B_Part_4'].value_counts())
print(df['Q32_B_Part_5'].value_counts())
print(df['Q32_B_Part_6'].value_counts())
print(df['Q32_B_Part_7'].value_counts())
print(df['Q32_B_Part_8'].value_counts())
print(df['Q32_B_Part_9'].value_counts())
print(df['Q32_B_Part_10'].value_counts())
print(df['Q32_B_Part_11'].value_counts())
print(df['Q32_B_Part_12'].value_counts())
print(df['Q32_B_Part_13'].value_counts())
print(df['Q32_B_Part_14'].value_counts())
print(df['Q32_B_Part_15'].value_counts())
print(df['Q32_B_Part_16'].value_counts())
print(df['Q32_B_Part_17'].value_counts())
print(df['Q32_B_Part_18'].value_counts())
print(df['Q32_B_Part_19'].value_counts())
print(df['Q32_B_Part_20'].value_counts())
print(df['Q32_B_OTHER'].value_counts())

# %%
BDP2=['MySQL','PostgreSQL','SQLite','Oracle','MongoDB','Snowflake','IBM Db2','M. SQL','M. AzureSQL','M. Azure Cosmos','Amazon Redshift',
     'Amazon Aurora','Amazon RDS','Amazon DynamoDB','Google Cloud BigQuery','Google Cloud SQL','Google Cloud Firestore','Google Cloud BigTable',
     'Google Cloud Spanner','None','Other']
BPDCnt2=[6135,3289,3036,2304,4288,1086,1195,3143,2680,1551,1211,1182,1493,2245,2844,3284,1627,2050,1253,1872,255]

fig = plt.figure(figsize =(18, 5))
ax=plt.barh(BDP2,BPDCnt2,color ='green')
plt.tight_layout()
plt.ylabel('Big Data Product Name')
plt.xlabel('Big Data Product Users Count')
plt.title('Big Data Product And Users')
plt.show()

# %% [markdown]
# Most of the times Kagglers selected MySQL followed by MongoDB,PostgreSQL.

# %% [markdown]
# # 34B Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years?

# %%
print(df['Q34_B_Part_1'].value_counts())
print(df['Q34_B_Part_2'].value_counts())
print(df['Q34_B_Part_3'].value_counts())
print(df['Q34_B_Part_4'].value_counts())
print(df['Q34_B_Part_5'].value_counts())
print(df['Q34_B_Part_6'].value_counts())
print(df['Q34_B_Part_7'].value_counts())
print(df['Q34_B_Part_8'].value_counts())
print(df['Q34_B_Part_9'].value_counts())
print(df['Q34_B_Part_10'].value_counts())
print(df['Q34_B_Part_11'].value_counts())
print(df['Q34_B_Part_12'].value_counts())
print(df['Q34_B_Part_13'].value_counts())
print(df['Q34_B_Part_14'].value_counts())
print(df['Q34_B_Part_15'].value_counts())
print(df['Q34_B_Part_16'].value_counts())
print(df['Q32_B_OTHER'].value_counts())

# %%
Bit2=['Amazon QuickSight','Microsoft Power BI','Google Data Studio','Looker','Tableau','Salesforce','Tableau CRM','Qlik','Domo','TIBCO Spotfire','Alteryx',
     'Sisense','SAP Analytics Cloud','Microsoft Azure Synapse','Thoughtspot','None','Other']
Bit_cnt2=[4923,1267,4090,559,5421,1264,1699,783,276,268,526,315,1343,1695,262,3056,255]

fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Bit2,Bit_cnt2,color ='green')
plt.tight_layout()
plt.ylabel('Business Intelligence Tools Name')
plt.xlabel('Business Intelligence Tools Users Count')
plt.title('Business Intelligence Tools And Users')
plt.show()

# %% [markdown]
# # 36B Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?

# %%
print(df['Q36_B_Part_1'].value_counts())
print(df['Q36_B_Part_2'].value_counts())
print(df['Q36_B_Part_3'].value_counts())
print(df['Q36_B_Part_4'].value_counts())
print(df['Q36_B_Part_5'].value_counts())
print(df['Q36_B_Part_6'].value_counts())
print(df['Q36_B_Part_7'].value_counts())
print(df['Q36_B_OTHER'].value_counts())

# %%
Auto_ML_tools2=['Automated data augmentation','Automated feature engineering','Automated model selection','Automated model architecture searches','Automated hyperparameter tuning','Automation of full ML pipelines','None','Other']
Auto_ML_tools_cnt2=[3496,3648,4761,2183,3331,4752,3221,323]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Auto_ML_tools2,Auto_ML_tools_cnt2,color ='green')
plt.tight_layout()
plt.ylabel('Automated Machine Learning Tools Name')
plt.xlabel('Automated Machine Learning Tools Users Count')
plt.title('Automated Machine Learning Tools And Users')
plt.show()

# %% [markdown]
# # 37B Which specific automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?

# %%
print(df['Q37_B_Part_1'].value_counts())
print(df['Q37_B_Part_2'].value_counts())
print(df['Q37_B_Part_3'].value_counts())
print(df['Q37_B_Part_4'].value_counts())
print(df['Q37_B_Part_5'].value_counts())
print(df['Q37_B_Part_6'].value_counts())
print(df['Q37_B_Part_7'].value_counts())
print(df['Q37_B_OTHER'].value_counts())

# %%
pAuto_ML_tools2=['Automated data augmentation','Automated feature engineering','Automated model selection','Automated model architecture searches','Automated hyperparameter tuning','Automation of full ML pipelines','None','Other']
pAuto_ML_tools_cnt2=[4817,1387,1649,1545,2683,3152,1398,280]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(pAuto_ML_tools2,pAuto_ML_tools_cnt2,color ='green')
plt.tight_layout()
plt.ylabel('Partial Automated Machine Learning Tools Name')
plt.xlabel('Partial Automated Machine Learning Tools Users Count')
plt.title('Partial Automated Machine Learning Tools And Users')
plt.show()

# %% [markdown]
# # 38B In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments?

# %%
print(df['Q38_B_Part_1'].value_counts())
print(df['Q38_B_Part_2'].value_counts())
print(df['Q38_B_Part_3'].value_counts())
print(df['Q38_B_Part_4'].value_counts())
print(df['Q38_B_Part_5'].value_counts())
print(df['Q38_B_Part_6'].value_counts())
print(df['Q38_B_Part_7'].value_counts())
print(df['Q38_B_Part_8'].value_counts())
print(df['Q38_B_Part_9'].value_counts())
print(df['Q38_B_Part_10'].value_counts())
print(df['Q38_B_Part_11'].value_counts())
print(df['Q38_B_OTHER'].value_counts())

# %%
Any_tools2=['Neptune.ai','Weights & Biases','Comet.ml','Sacred + Omniboard','TensorBoard','Guild.ai','Polyaxon','ClearML','Domino Model Monitor','MLflow','None','Other']
Any_tools_cnt2=[1276,1583,633,591,4239,729,737,1020,666,2747,4542,377]
fig = plt.figure(figsize =(18, 5))
ax=plt.barh(Any_tools2,Any_tools_cnt2,color ='green')
plt.tight_layout()
plt.ylabel('Any Machine Learning Tools Name')
plt.xlabel('Any Machine Learning Tools Users Count')
plt.title('Any Machine Learning Tools And Users')
plt.show()
