# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
sns.set_style('white')
warnings.filterwarnings('ignore')

# %%
kaggle_survey=pd.read_csv("../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv")
kaggle_survey = kaggle_survey.iloc[1:,:]

# %%
continents_df = pd.read_csv("../input/2020-kaggle-survey-supporting/2020 Continents.csv")
continents_dict = {k:v for k,v in zip(continents_df["Country"],continents_df["Continents"])}
kaggle_survey["Continents"] = kaggle_survey["Q3"].map(continents_dict)

# %%
country_long_name_dict = {"United States of America": "USA", 
                          "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",}
kaggle_survey["Q3"] = kaggle_survey["Q3"].replace(country_long_name_dict)

education_categorical_dict={
    "No formal education past high school":"Below high school",
    "Some college/university study without earning a bachelor’s degree":"University study w/o bachelor",
    "I prefer not to answer":"No answer",
}
kaggle_survey["Q4"] = kaggle_survey["Q4"].replace(education_categorical_dict)

# %% [markdown]
# # **1.World**

# %%
continents_count_df = pd.DataFrame(kaggle_survey["Q4"].value_counts())
continents_count_df = continents_count_df.reset_index(drop=False)
continents_count_df.columns = ["Education","Count"]

# %%
fig = plt.figure(figsize=(10,8))
color_map = ["#112A86", "#f04fc5", "#bdbdbd",'#f4acb7','#9d8189','#E63946','#8D99AE']
plt.text(0, 1.2, 'World', fontsize=18, fontweight='bold', fontfamily='serif', horizontalalignment='center')
plt.pie(x=continents_count_df['Count'], colors=color_map, wedgeprops=dict(width=0.2),autopct='%1.0f%%')
plt.legend(continents_count_df["Education"], loc="lower center", bbox_to_anchor=(-1, 1))

# %% [markdown]
# * **39% of Kagglers have Master degree followed by 38% Bachelor degree.**
# * **11% of Kagglers have Doctoral degree.**

# %% [markdown]
# # **2.Continents**

# %%
survey_asia_df = kaggle_survey[kaggle_survey["Continents"]=="Asia"]
survey_america_df = kaggle_survey[kaggle_survey["Continents"]=="America"]
survey_europe_df = kaggle_survey[kaggle_survey["Continents"]=="Europe"]
survey_africa_df = kaggle_survey[kaggle_survey["Continents"]=="Africa"]
survey_australia_df = kaggle_survey[kaggle_survey["Continents"]=="Australia"]
survey_others_df = kaggle_survey[kaggle_survey["Continents"]=="Others"]

# %% [markdown]
# * **Most of Kagglers have Master degree followed by Bachelor degree. Master degree is the most education Kagglers had in every continents except for Asia and Africa.**
# * **While most of Asian and African Kagglers have a bachelor degree.**

# %% [markdown]
# # **2.1.Asian**

# %%
asia_count_df = pd.DataFrame(survey_asia_df["Q4"].value_counts())
asia_count_df = asia_count_df.reset_index(drop=False)
asia_count_df.columns = ["Education","Count"]

# %%
fig = plt.figure(figsize=(10,8))
color_map = ["#112A86", "#f04fc5", "#bdbdbd",'#f4acb7','#9d8189','#E63946','#8D99AE']
plt.text(0, 1.2, 'Asia', fontsize=18, fontweight='bold', fontfamily='serif', horizontalalignment='center')
plt.pie(x=asia_count_df['Count'], colors=color_map, wedgeprops=dict(width=0.2),autopct='%1.0f%%')
plt.legend(asia_count_df["Education"], loc="lower center", bbox_to_anchor=(-1, 1))

# %% [markdown]
# **45% of Kagglers in Asia have Bachelor degree followed by 35% Master degree in Asia.**

# %% [markdown]
# # **2.2.America**

# %%
america_count_df = pd.DataFrame(survey_america_df["Q4"].value_counts())
america_count_df = america_count_df.reset_index(drop=False)
america_count_df.columns = ["Education","Count"]

# %%
fig = plt.figure(figsize=(10,8))
color_map = ["#112A86", "#f04fc5", "#bdbdbd",'#f4acb7','#9d8189','#E63946','#8D99AE']
plt.text(0, 1.2, 'America', fontsize=18, fontweight='bold', fontfamily='serif', horizontalalignment='center')
plt.pie(x=america_count_df['Count'], colors=color_map, wedgeprops=dict(width=0.2),autopct='%1.0f%%')
plt.legend(america_count_df["Education"], loc="lower center", bbox_to_anchor=(-1, 1))

# %% [markdown]
# **43% of Kagglers in America have Master degree followed by 30% Bachelor degree in America.**

# %% [markdown]
# # **2.3.Europe**

# %%
europe_count_df = pd.DataFrame(survey_europe_df["Q4"].value_counts())
europe_count_df = europe_count_df.reset_index(drop=False)
europe_count_df.columns = ["Education","Count"]

# %%
fig = plt.figure(figsize=(10,8))
color_map = ["#112A86", "#f04fc5", "#bdbdbd",'#f4acb7','#9d8189','#E63946','#8D99AE']
plt.text(0, 1.2, 'Europe', fontsize=18, fontweight='bold', fontfamily='serif', horizontalalignment='center')
plt.pie(x=europe_count_df['Count'], colors=color_map, wedgeprops=dict(width=0.2),autopct='%1.0f%%')
plt.legend(europe_count_df["Education"], loc="lower center", bbox_to_anchor=(-1, 1))

# %% [markdown]
# **53% of Kagglers in Europe have Master degree followed by 19% Doctoral degree and 17% Bachelor degree in Europe.**

# %% [markdown]
# # **2.4.Africa**

# %%
africa_count_df = pd.DataFrame(survey_africa_df["Q4"].value_counts())
africa_count_df = africa_count_df.reset_index(drop=False)
africa_count_df.columns = ["Education","Count"]

# %%
fig = plt.figure(figsize=(10,8))
color_map = ["#112A86", "#f04fc5", "#bdbdbd",'#f4acb7','#9d8189','#E63946','#8D99AE']
plt.text(0, 1.2, 'Africa', fontsize=18, fontweight='bold', fontfamily='serif', horizontalalignment='center')
plt.pie(x=africa_count_df['Count'], colors=color_map, wedgeprops=dict(width=0.2),autopct='%1.0f%%')
plt.legend(africa_count_df["Education"], loc="lower center", bbox_to_anchor=(-1, 1))

# %% [markdown]
# **50% of Kagglers in Africa have Bachelor degree followed by 31% Master degree in Africa.**

# %% [markdown]
# # **2.5.Australia**

# %%
australia_count_df = pd.DataFrame(survey_australia_df["Q4"].value_counts())
australia_count_df = australia_count_df.reset_index(drop=False)
australia_count_df.columns = ["Education","Count"]

# %%
fig = plt.figure(figsize=(10,8))
color_map = ["#112A86", "#f04fc5", "#bdbdbd",'#f4acb7','#9d8189','#E63946','#8D99AE']
plt.text(0, 1.2, 'Australia', fontsize=18, fontweight='bold', fontfamily='serif', horizontalalignment='center')
plt.pie(x=australia_count_df['Count'], colors=color_map, wedgeprops=dict(width=0.2),autopct='%1.0f%%')
plt.legend(australia_count_df["Education"], loc="lower center", bbox_to_anchor=(-1, 1))

# %% [markdown]
# **45% of Kagglers in Australia have Master degree followed by 30% Bachelor degree in Australia.**

# %% [markdown]
# # **2.6.Others**

# %%
others_count_df = pd.DataFrame(survey_others_df["Q4"].value_counts())
others_count_df = others_count_df.reset_index(drop=False)
others_count_df.columns = ["Education","Count"]

# %%
fig = plt.figure(figsize=(10,8))
color_map = ["#112A86", "#f04fc5", "#bdbdbd",'#f4acb7','#9d8189','#E63946','#8D99AE']
plt.text(0, 1.2, 'Other', fontsize=18, fontweight='bold', fontfamily='serif', horizontalalignment='center')
plt.pie(x=others_count_df['Count'], colors=color_map, wedgeprops=dict(width=0.2),autopct='%1.0f%%')
plt.legend(others_count_df["Education"], loc="lower center", bbox_to_anchor=(-1, 1))

# %% [markdown]
# **38% of Kagglers in Other Countries have Master degree followed by 33% Bachelor degree in Other Countries.**

# %% [markdown]
# # **3.Asian Countries**

# %%
#Top 10 countries in asia
survey_asia_df['Q3'].value_counts().head(10)

# %%
India_df = survey_asia_df[survey_asia_df["Q3"]=="India"]
Japan_df = survey_asia_df[survey_asia_df["Q3"]=="Japan"]
China_df = survey_asia_df[survey_asia_df["Q3"]=="China"]
Russia_df = survey_asia_df[survey_asia_df["Q3"]=="Russia"]
Pakistan_df = survey_asia_df[survey_asia_df["Q3"]=="Pakistan"]
Indonesia_df = survey_asia_df[survey_asia_df["Q3"]=="Indonesia"]
Turkey_df = survey_asia_df[survey_asia_df["Q3"]=="Turkey"]
South_Korea_df = survey_asia_df[survey_asia_df["Q3"]=="South Korea"]
Taiwan_df = survey_asia_df[survey_asia_df["Q3"]=="Taiwan"]
Bangladesh_df = survey_asia_df[survey_asia_df["Q3"]=="Bangladesh"]

# %% [markdown]
# # **3.1.India**

# %%
India_count_df = pd.DataFrame(India_df["Q4"].value_counts())
India_count_df = India_count_df.reset_index(drop=False)
India_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(India_count_df["Education"], India_count_df['Count'],color=color_map, zorder=1)
plt.text(3,4500,'India',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in India have Bachelor degree followed by Master degree**

# %% [markdown]
# # **3.2.Japan**

# %%
Japan_count_df = pd.DataFrame(Japan_df["Q4"].value_counts())
Japan_count_df = Japan_count_df.reset_index(drop=False)
Japan_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(Japan_count_df["Education"], Japan_count_df['Count'],color=color_map, zorder=1)
plt.text(3,420,'Japan',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in Japan have Master degree followed by Bachelor degree.**

# %% [markdown]
# # **3.3.China**

# %%
China_count_df = pd.DataFrame(China_df["Q4"].value_counts())
China_count_df = China_count_df.reset_index(drop=False)
China_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(China_count_df["Education"], China_count_df['Count'],color=color_map, zorder=1)
plt.text(3,430,'China',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in China have Master degree followed by Bachelor degree.**

# %% [markdown]
# # **3.4.Russia**

# %%
Russia_count_df = pd.DataFrame(Russia_df["Q4"].value_counts())
Russia_count_df = Russia_count_df.reset_index(drop=False)
Russia_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(Russia_count_df["Education"], Russia_count_df['Count'],color=color_map, zorder=1)
plt.text(3,350,'Russia',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in Russia have Master degree followed by Bachelor degree.**

# %% [markdown]
# # **3.5.Pakistan**

# %%
Pakistan_count_df = pd.DataFrame(Pakistan_df["Q4"].value_counts())
Pakistan_count_df = Pakistan_count_df.reset_index(drop=False)
Pakistan_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(Pakistan_count_df["Education"], Pakistan_count_df['Count'],color=color_map, zorder=1)
plt.text(3,260,'Pakistan',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in Pakistan have Bachelor degree followed by Master degree**

# %% [markdown]
# # **3.6.Indonesia**

# %%
Indonesia_count_df = pd.DataFrame(Indonesia_df["Q4"].value_counts())
Indonesia_count_df = Indonesia_count_df.reset_index(drop=False)
Indonesia_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(Indonesia_count_df["Education"], Indonesia_count_df['Count'],color=color_map, zorder=1)
plt.text(3,250,'Indonesia',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in Indonesia have Bachelor degree followed by Master degree**

# %% [markdown]
# # **3.7.Turkey**

# %%
Turkey_count_df = pd.DataFrame(Turkey_df["Q4"].value_counts())
Turkey_count_df = Turkey_count_df.reset_index(drop=False)
Turkey_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(Turkey_count_df["Education"], Turkey_count_df['Count'],color=color_map, zorder=1)
plt.text(3,160,'Turkey',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in Turkey have Master degree followed by Bachelor degree.**

# %% [markdown]
# # **3.8.South Korea**

# %%
South_Korea_count_df = pd.DataFrame(South_Korea_df["Q4"].value_counts())
South_Korea_count_df = South_Korea_count_df.reset_index(drop=False)
South_Korea_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(South_Korea_count_df["Education"], South_Korea_count_df['Count'],color=color_map, zorder=1)
plt.text(3,140,'South Korea',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in South Korea have Bachelor degree followed by Master degree**

# %% [markdown]
# # **3.9.Taiwan**

# %%
Taiwan_count_df = pd.DataFrame(Taiwan_df["Q4"].value_counts())
Taiwan_count_df = Taiwan_count_df.reset_index(drop=False)
Taiwan_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(Taiwan_count_df["Education"], Taiwan_count_df['Count'],color=color_map, zorder=1)
plt.text(3,200,'Taiwan',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in Taiwan have Master degree followed by Bachelor degree.**

# %% [markdown]
# # **3.10.Bangladesh**

# %%
Bangladesh_count_df = pd.DataFrame(Bangladesh_df["Q4"].value_counts())
Bangladesh_count_df = Bangladesh_count_df.reset_index(drop=False)
Bangladesh_count_df.columns = ["Education","Count"]

# %%
color_map = ["#4A4655" for _ in range(7)]
color_map[0] = "#4898EF"
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
plt.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))
plt.bar(Bangladesh_count_df["Education"], Bangladesh_count_df['Count'],color=color_map, zorder=3)
plt.text(3,190,'Bangladesh',fontsize=20,fontweight='bold',fontfamily='Arial')

# %% [markdown]
# **Most of Kagglers in Bangladesh have Bachelor degree followed by Master degree**
