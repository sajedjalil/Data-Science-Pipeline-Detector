# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
style.use('fivethirtyeight')

# %%
df = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')
df

# %% [markdown]
# # **India**

# %%
df2 = df[(df['Q3'] == 'India')]
df2.head()

# %% [markdown]
# # **What is your gender?**

# %%
Q2=df2["Q2"]
Q2=Q2.to_frame()
Q2.columns = ['count']
Q2['Name'] = Q2.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q2)
plt.xticks(rotation = 90)
plt.xlabel("Counts")
plt.ylabel("Gender")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **What is the highest level of formal education that you have attained or plan to attain within the next 2 years?**

# %%
Q4=df2["Q4"]
Q4=Q4.to_frame()
Q4.columns = ['count']
Q4['Name'] = Q4.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q4)
plt.xticks(rotation = 90)
plt.ylabel("Formal Education")
plt.xlabel("count")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Select the title most similar to your current role (or most recent title if retired):**

# %%
Q5=df2["Q5"]
Q5=Q5.to_frame()
Q5.columns = ['count']
Q5['Name'] = Q5.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q5)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("Similar to your current role ")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **For how many years have you been writing code and/or programming?**

# %%
Q6=df2["Q6"]
Q6=Q6.to_frame()
Q6.columns = ['count']
Q6['Name'] = Q6.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q6)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("Years")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **What programming languages do you use on a regular basis?**

# %%
Q7= {}
for i in range(1,13):
    Q7.update(dict(df2[f"Q7_Part_{i}"].value_counts()))
Q7 = pd.DataFrame(Q7.items(), columns = ['languague', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x="languague", y="counts", data=Q7)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("Languague")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **What programming language would you recommend an aspiring data scientist to learn first?**

# %%
Q8=df2["Q8"]
Q8=Q8.to_frame()
Q8.columns = ['count']
Q8['Name'] = Q8.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q8)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("Recommend Languague")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which of the following integrated development environments (IDE's) do you use on a regular basis?**

# %%
Q9= {}
for i in range(1,13):
    Q9.update(dict(df2[f"Q9_Part_{i}"].value_counts()))
Q9 = pd.DataFrame(Q9.items(), columns = ['ide', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'ide', y = 'counts', data=Q9)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("IDE's")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which of the following hosted notebook products do you use on a regular basis?**

# %%
Q10 = {}
for i in range(1,14):
    Q10.update(dict(df2[f"Q10_Part_{i}"].value_counts()))
Q10 = pd.DataFrame(Q10.items(), columns = ['ide', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'ide', y = 'counts', data=Q10)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("ide")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **What type of computing platform do you use most often for your data science projects?**

# %%
Q11=df2["Q11"]
Q11=Q11.to_frame()
Q11.columns = ['count']
Q11['Name'] = Q11.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q11)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("Computing Platform")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which types of specialized hardware do you use on a regular basis?**

# %%
q12_columns = [column for column in df.columns if 'Q12' in column]
Q12 = {}

for column in q12_columns:
    Q12.update(dict(df2[column].value_counts()))

Q12 = pd.DataFrame(Q12.items(), columns = ['hardware', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'hardware', y = 'counts', data=Q12)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("Hardware")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Approximately how many times have you used a TPU (tensor processing unit)?**

# %%
Q13=df2["Q13"]
Q13=Q13.to_frame()
Q13.columns = ['count']
Q13['Name'] = Q13.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q13)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("number of times used a TPU ")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **What data visualization libraries or tools do you use on a regular basis?**

# %%
Q14= {}
for i in range(1,12):
    Q14.update(dict(df2[f"Q14_Part_{i}"].value_counts()))
Q14 = pd.DataFrame(Q14.items(), columns = ['visualization', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'visualization', y = 'counts', data=Q14)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("visualization libraries")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **For how many years have you used machine learning methods?**

# %%
Q15=df2["Q15"]
Q15=Q15.to_frame()
Q15.columns = ['count']
Q15['Name'] = Q15.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q15)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("years")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which of the following machine learning frameworks do you use on a regular basis?**

# %%
Q16= {}
for i in range(1,16):
    Q16.update(dict(df2[f"Q16_Part_{i}"].value_counts()))
Q16 = pd.DataFrame(Q16.items(), columns = ['frameworks', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'frameworks', y = 'counts', data=Q16)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("frameworks")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which of the following ML algorithms do you use on a regular basis?**

# %%
Q17= {}
for i in range(1,12):
    Q17.update(dict(df2[f"Q17_Part_{i}"].value_counts()))
Q17 = pd.DataFrame(Q17.items(), columns = ['algorithms', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'algorithms', y = 'counts', data=Q17)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("ML algorithms")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which categories of computer vision methods do you use on a regular basis?**

# %%
Q18= {}
for i in range(1,7):
    Q18.update(dict(df2[f"Q18_Part_{i}"].value_counts()))
Q18 = pd.DataFrame(Q18.items(), columns = ['vision', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'vision', y = 'counts', data=Q18)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("computer vision methods")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which of the following natural language processing (NLP) methods do you use on a regular basis?**

# %%
Q19= {}
for i in range(1,6):
    Q19.update(dict(df2[f"Q19_Part_{i}"].value_counts()))
Q19 = pd.DataFrame(Q19.items(), columns = ['NLP', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'NLP', y = 'counts', data=Q19)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("(NLP) methods")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **In what industry is your current employer/contract (or your most recent employer if retired)?**

# %%
Q20=df2["Q20"]
Q20=Q20.to_frame()
Q20.columns = ['count']
Q20['Name'] = Q20.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q20)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("current employer")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **What is the size of the company where you are employed?**

# %%
Q21=df2["Q21"]
Q21=Q21.to_frame()
Q21.columns = ['count']
Q21['Name'] = Q21.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q21)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("size of the company")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Approximately how many individuals are responsible for data science workloads at your place of business?**

# %%
Q22=df2["Q22"]
Q22=Q22.to_frame()
Q22.columns = ['count']
Q22['Name'] = Q22.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q22)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("Employee")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Does your current employer incorporate machine learning methods into their business?**

# %%
Q23=df2["Q23"]
Q23=Q23.to_frame()
Q23.columns = ['count']
Q23['Name'] = Q23.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q23)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("machine learning methods")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Select any activities that make up an important part of your role at work:**

# %%
Q24= {}
for i in range(1,8):
    Q24.update(dict(df2[f"Q24_Part_{i}"].value_counts()))
Q24 = pd.DataFrame(Q24.items(), columns = ['important', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'important', y = 'counts', data=Q24)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("Activities")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **What is your current yearly compensation (approximate $USD)?**

# %%
Q25=df2["Q25"]
Q25=Q25.to_frame()
Q25.columns = ['count']
Q25['Name'] = Q25.index

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Name', y = 'count', data=Q25)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.xlabel("count")
plt.ylabel("$USD")
plt.gcf().set_size_inches(12,6)

# %% [markdown]
# # **Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years?**

# %%
Q32= {}
for i in range(1,8):
    Q32.update(dict(df2[f"Q32_B_Part_{i}"].value_counts()))
Q32 = pd.DataFrame(Q32.items(), columns = ['important', 'counts'])

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'important', y = 'counts', data=Q32)
plt.xticks(rotation = 90)
plt.style.use("fivethirtyeight")
plt.ylabel("count")
plt.xlabel("big data products")
plt.gcf().set_size_inches(12,6)
