# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **<font color = DarkSlateBlue size = 5 >Table of Contents</font>**

# %% [markdown]
# * [**<font color = SteelBlue size = 4>Introduction</font>**](#section-one)
#
# * [**<font color = SteelBlue size = 4>Import related libraries</font>**](#section-two)
#
# * [**<font color = SteelBlue size = 4>Read data and Inspect data</font>**](#section-three)
#
# * [**<font color = SteelBlue size = 4>Data Analysis</font>**](#section-four)
#
#     - [**<font color = CadetBlue size = 4>Background</font>**](#subsection-one)
#
#     - [**<font color = CadetBlue size = 4>Occupation</font>**](#subsection-two)
#
#     - [**<font color = CadetBlue size = 4>Experience & Skills</font>**](#subsection-three)
#     - [**<font color =CadetBlue size = 4>Computing Platforms</font>**](#subsection-four)
#
#     - [**<font color =CadetBlue size = 4>Machine Learning</font>**](#subsection-five)
#
#     - [**<font color =CadetBlue size = 4>Course Platforms & Media Sources</font>**](#subsection-six)

# %% [markdown]
# <a id="section-one"></a>
# **<font color = DarkSlateBlue size = 5>Introduction</font>**

# %% [markdown]
# **This data is about the survey of the state of data science and machine learning which was live from 09/01/2021 to 10/04/2021. More than 25,000 kagglers around the world participated in this survey. This notebook will explore the results of this survey from six countries, including China, Japan, South Korea, Hong Kong, Taiwan and Singapore. However, I will not choose the results of all questions for my analysis. In other words, I will focus on the results of some questions which I want to explore.**
#
# **The presentation of this notebook is different from the past, I will use the way which is ”Dropdown Menu” to show the analysis. Finally, this notebook is divided into six sections which are Background, Occupation, Experience & Skills, Computing Platforms, Machine Learning and Course Platforms & Media Sources, respectively.**
#
# **Now, let’s get started to explore the results of this survey.**

# %% [markdown]
# <a id="section-two"></a>
# **<font color = DarkSlateBlue size = 5>Import related libraries</font>**

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go

# %% [markdown]
# <a id="section-three"></a>
# **<font color = DarkSlateBlue size = 5>Read data and Inspect data</font>**

# %%
# Read data 
df = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv', low_memory=False)

# %%
# Show first five rows of data
df.head()

# %%
# Information about data
df.info()

# %% [markdown]
# <a id="section-four"></a>
# **<font color = DarkSlateBlue size = 5>Data Analysis📊</font>**

# %% [markdown]
# **<font color = MediumPurple size = 4 >- Six Countries: China, Japan, South Korea, Hong Kong, Taiwan and Singapore -</font>**

# %%
# Six Countries => China, Japan, South Korea, Hong Kong, Taiwan and Singarpore 
dfc = df[(df['Q3']=='China')|(df['Q3']=='Japan')|(df['Q3']=='South Korea')|(df['Q3']=='Hong Kong (S.A.R.)')|(df['Q3']=='Taiwan')|(df['Q3']=='Singapore')]

# %% [markdown]
# <a id="subsection-one"></a>
# **<font color = CadetBlue size = 4 >- Background -</font>**

# %% [markdown]
# **In the first section, I will discuss the background of kagglers, including age, gender, country and education.**

# %%
# Age
df1 = dfc['Q1'].value_counts().sort_values(ascending = True).reset_index()
df1 = df1.rename(columns={'index':'Age', 'Q1':'Count'})
df1['percent'] = (df1['Count']*100 / df1['Count'].sum()).round(1).astype(str) + '%'

# Gender
df2 = dfc['Q2'].value_counts().sort_values(ascending = True).reset_index()
df2 = df2.rename(columns={'index':'Gender', 'Q2':'Count'})
df2['percent'] = (df2['Count']*100 / df2['Count'].sum()).round(1).astype(str) + '%'

# Country
df3 = dfc['Q3'].value_counts().sort_values(ascending = True).reset_index()
df3 = df3.rename(columns={'index':'Country', 'Q3':'Count'})
df3['percent'] = (df3['Count']*100 / df3['Count'].sum()).round(1).astype(str) + '%'

# Education
df4 = dfc['Q4'].value_counts().sort_values(ascending = True).reset_index()
df4 = df4.rename(columns={'index':'Education', 'Q4':'Count'})
df4['percent'] = (df4['Count']*100 / df4['Count'].sum()).round(1).astype(str) + '%'
df4['Education'] = df4['Education'].replace("Some college/university study without earning a bachelor’s degree","Some college without a degree")

fig = go.Figure()

fig.add_trace(go.Bar(x = df1['Count'],
                     y = df1['Age'],
                     orientation='h',
                     name = 'Age',
                     text= df1['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Age: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'LightCoral')))

fig.add_trace(go.Bar(x = df2['Count'],
                     y = df2['Gender'],
                     orientation='h',
                     name = 'Gender',
                     text= df2['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Gender: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'MediumPurple')))

fig.add_trace(go.Bar(x = df3['Count'],
                     y = df3['Country'],
                     orientation='h',
                     name = 'Country',
                     text= df3['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Country: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'CadetBlue')))

fig.add_trace(go.Bar(x = df4['Count'],
                     y = df4['Education'],
                     orientation='h',
                     name = 'Education',
                     text= df4['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Education: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'SteelBlue')))

fig.update_layout( 
    updatemenus=[ 
        dict( 
            direction="down", 
            pad={"r": 10, "t": 10},
            showactive=True, 
            x=0.155, 
            xanchor="left",
            y=1.09, 
            yanchor="top",
            font = dict(color = 'Indigo',size = 14),
            buttons=list([ 
                dict(label="All", 
                     method="update", 
                     args=[ {"visible": [True,True,True,True]}, 
                            {'showlegend' : True} 
                        ]),
                dict(label="Age", 
                     method="update", 
                     args=[ {"visible": [True,False,False,False]}, 
                            {'showlegend' : False} 
                        ]), 
                dict(label="Gender", 
                     method="update", 
                     args=[ {"visible": [False,True,False,False]}, 
                            {'showlegend' : False} 
                        ]),
                dict(label='Country', 
                     method="update", 
                     args=[ {"visible": [False,False,True,False]}, 
                            {'showlegend' : False} 
                     ]), 
                dict(label='Education', 
                     method="update", 
                     args=[ {"visible": [False, False,False,True]}, 
                            {'showlegend' : False}]),
            ]),
        )])

fig.update_layout(
    annotations=[
        dict(text="Choose:", showarrow=False,
             x=0.1, y=1.065, yref="paper", align="right",
             font=dict(size=16,color = 'DarkSlateBlue'))])

fig.update_layout(title ="The Distribution of <b>Ages,Gender,Countries and Educations<b>",
                  title_x = 0.5,
                  title_font = dict(size = 20, color = 'MidnightBlue'),
                  height = 700)

fig.show()

# %% [markdown]
# **From the above charts, we can see that :**
# * **More than 80% of kagglers are man. However, there are few kagglers are woman in these countries.**
# * **Most of kagglers are between 22 to 29 years of age, but the proportion of kagglers aged 55 years or older is under 6%.**
# * **Most of kagglers live in Japan. It is interested that the population of China is much more than Japan, but the number of kagglers in Japan is more than in China. It is worth exploring the reasons further if it is possible.**
# * **Most of kagglers possess a Master's degree. As we can see that over 70% of kagglers possess a Master's degree or a Bachelor’s degree.**

# %% [markdown]
# <a id="subsection-two"></a>
# **<font color = CadetBlue size = 4 >- Occupation -</font>**

# %% [markdown]
# **In the second section, I will discuss the state of occupation of kagglers, including current role, industry of current employer and compensation.**

# %%
# Job title
df5 = dfc['Q5'].value_counts().sort_values(ascending = True).reset_index()
df5 = df5.rename(columns={'index':'Job Title', 'Q5':'Count'})
df5['percent'] = (df5['Count']*100 / df5['Count'].sum()).round(1).astype(str) + '%'

# Industry
df20 = dfc['Q20'].value_counts().sort_values(ascending = True).reset_index()
df20 = df20.rename(columns={'index':'Industry', 'Q20':'Count'})
df20['percent'] = (df20['Count']*100 / df20['Count'].sum()).round(1).astype(str) + '%'

# Compensation
df25 = dfc['Q25'].value_counts().sort_values(ascending = True).reset_index()
df25 = df25.rename(columns={'index':'Compensation', 'Q25':'Count'})
df25['percent'] = (df25['Count']*100 / df25['Count'].sum()).round(1).astype(str) + '%'

fig = go.Figure()

fig.add_trace(go.Bar(x = df5['Count'],
                     y = df5['Job Title'],
                     orientation='h',
                     name = 'Job Title',
                     text= df5['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Job Title: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'LightCoral')))


fig.add_trace(go.Bar(x = df20['Count'],
                     y = df20['Industry'],
                     orientation='h',
                     name = 'Industry',
                     text= df20['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Industry: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'SteelBlue')))

fig.add_trace(go.Bar(x = df25['Count'],
                     y = df25['Compensation'],
                     orientation='h',
                     name = 'Compensation',
                     text= df25['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Compensation: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'MediumSlateBlue')))
                                   
                                   

fig.update_layout( 
    updatemenus=[ 
        dict( 
            direction="down", 
            pad={"r": 10, "t": 10},
            showactive=True, 
            x=0.17, 
            xanchor="left",
            y=1.09, 
            yanchor="top",
            font = dict(color = 'Indigo',size = 14),
            buttons=list([ 
                dict(label="All", 
                     method="update", 
                     args=[ {"visible": [True,True,True,]}, 
                            {'showlegend' : True} 
                        ]),
                dict(label="Job Title", 
                     method="update", 
                     args=[ {"visible": [True,False,False,]}, 
                            {'showlegend' : False} 
                        ]),  
                dict(label='Industry', 
                     method="update", 
                     args=[ {"visible": [False,True,False]}, 
                            {'showlegend' : False}
                          ]),
                dict(label='Compensation', 
                     method="update", 
                     args=[ {"visible": [False,False,True]}, 
                            {'showlegend' : False}]),
            ]),
        )])

fig.update_layout(
    annotations=[
        dict(text="Choose:", showarrow=False,
             x=0.1, y=1.065, yref="paper", align="right",
             font=dict(size=16,color = 'DarkSlateBlue'))])

fig.update_layout(title ="The Distribution of <b>Job Titles,Industries and Compensation<b>",
                  title_x = 0.5,
                  title_font = dict(size = 20, color = 'MidnightBlue'),
                  height = 700)

fig.show()

# %% [markdown]
# **From the above charts, we can see that :**
# * **Most of kagglers are "Students". There are 2X more than Software Engineer, Data Scientist and Data Analyst.**
# * **Most of kagglers which is more than 27% are work in the industry about Computer/Technology. It is interested that the second type of industry with the most kagglers is Acadamics/Education.**
# * **The compensation of most kagglers is between 0 and 999. It is not unexpected because that most of kagglers are students. However, under 10% of kagglers with the compensation which is over 100,000.**

# %% [markdown]
# <a id="subsection-three"></a>
# **<font color = CadetBlue size = 4 >- Experience & Skills -</font>**

# %% [markdown]
# **Let's move onto the section which is about coding experience and skills of kagglers.**

# %%
# Experience(Year) 
df6 = dfc['Q6'].value_counts().sort_values(ascending = True).reset_index()
df6 = df6.rename(columns={'index':'Experience', 'Q6':'Count'})
df6['percent'] = (df6['Count']*100 / df6['Count'].sum()).round(1).astype(str) + '%'

# Programming language
df7= dfc[[col for col in dfc if col.startswith('Q7')]]
df7.columns = ["Python", "R", "SQL", "C", "C++", "Java", "Javascript", "Julia", "Swift", "Bash",
               "MATLAB", "None", "Other"]
df7 = df7.notnull().sum().to_frame().reset_index()
df7 = df7.rename(columns = {"index":"Programming Language",0:"Count"})
df7 = df7.sort_values(by = ['Count'],ascending = True)
df7['percent'] = (df7['Count']*100 / df7['Count'].sum()).round(1).astype(str) + '%'

# IDE's
df9= dfc[[col for col in dfc if col.startswith('Q9')]]
df9.columns = ["Jupyter", "RStudio", "Visual Studio", "VSCode", "PyCharm", 
               "Spyder", "Notepad++", "Sublime Text", "Vim/Emacs", 
               "MATLAB", "Jupyter Notebook", "None", "Other"]
df9 = df9.notnull().sum().to_frame().reset_index()
df9 = df9.rename(columns = {"index":"IDE's",0:"Count"})
df9 = df9.sort_values(by = ['Count'],ascending = True)
df9['percent'] = (df9['Count']*100 / df9['Count'].sum()).round(1).astype(str) + '%'

# Hosted notebook product
df10= dfc[[col for col in dfc if col.startswith('Q10')]]
df10.columns = ["Kaggle Notebooks", "Colab Notebooks", "Azure Notebooks", 
                "Paperspace/Gradient","Binder/JupyterHub","Code Ocean",
                "IBM Watson Studio","Amazon Sagemaker Studio Notebooks",
                "Amazon EMR Notebooks","Google Cloud Notebooks",
                "Google Cloud Datalab","Databricks Collaborative Notebooks",
                "Zeppelin/Zepl Notebooks","Deepnote Notebooks",
                "Observable Notebooks","None","Other"]
df10 = df10.notnull().sum().to_frame().reset_index()
df10 = df10.rename(columns = {"index":"Hostsd Notebook",0:"Count"})
df10 = df10.sort_values(by = ['Count'],ascending = True)
df10['percent'] = (df10['Count']*100 / df10['Count'].sum()).round(1).astype(str) + '%'

                                                         
# Visualization library
df14= dfc[[col for col in dfc if col.startswith('Q14')]]
df14.columns = ["Matplotlib", "Seaborn", "Plotly", "Ggplot/ggplot2", "Shiny", 
               "D3 js", "Altair", "Bokeh", "Geoplotlib", 
               "Leaflet/Folium", "None", "Other"]
df14 = df14.notnull().sum().to_frame().reset_index()
df14 = df14.rename(columns = {"index":"Viz Library",0:"Count"})
df14 = df14.sort_values(by = ['Count'],ascending = True)
df14['percent'] = (df14['Count']*100 / df14['Count'].sum()).round(1).astype(str) + '%'

fig = go.Figure()

fig.add_trace(go.Bar(x = df6['Count'],
                     y = df6['Experience'],
                     orientation='h',
                     name = 'Experience',
                     text= df6['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Experience: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'CadetBlue')))

fig.add_trace(go.Bar(x = df7['Count'],
                     y = df7['Programming Language'],
                     orientation='h',
                     name = 'Programming Language',
                     text= df7['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Programming Language: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'LightCoral')))

fig.add_trace(go.Bar(x = df9['Count'],
                     y = df9["IDE's"],
                     orientation='h',
                     name = "IDE's",
                     text= df9['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = "IDE's: <b>%{y}</b><br>Count: <b>%{x}</b><br>",
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'MediumPurple')))

fig.add_trace(go.Bar(x = df10['Count'],
                     y = df10['Hostsd Notebook'],
                     orientation='h',
                     name = 'Hostsd Notebook',
                     text= df10['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Hostsd Notebook: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'Gold')))

fig.add_trace(go.Bar(x = df14['Count'],
                     y = df14['Viz Library'],
                     orientation='h',
                     name = 'Viz Library',
                     text= df14['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Viz Library: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'SteelBlue')))

                                   
fig.update_layout( 
    updatemenus=[ 
        dict( 
            direction="down", 
            pad={"r": 10, "t": 10},
            showactive=True, 
            x=0.185, 
            xanchor="left",
            y=1.09, 
            yanchor="top",
            font = dict(color = 'Indigo',size = 14),
            buttons=list([ 
                dict(label="All", 
                     method="update", 
                     args=[ {"visible": [True,True,True,True,True]}, 
                            {'showlegend' : True} 
                        ]),
                dict(label="Experience", 
                     method="update", 
                     args=[ {"visible": [True,False,False,False,False]}, 
                            {'showlegend' : False} 
                        ]),
                dict(label="Programming Language", 
                     method="update", 
                     args=[ {"visible": [False,True,False,False,False]}, 
                            {'showlegend' : False} 
                        ]), 
                dict(label="IDE's", 
                     method="update", 
                     args=[ {"visible": [False,False,True,False,False]}, 
                            {'showlegend' : False} 
                     ]), 
                dict(label="Hostsd Notebook", 
                     method="update", 
                     args=[ {"visible": [False,False,False,True,False]}, 
                            {'showlegend' : False} 
                     ]),
                dict(label='Viz Library', 
                     method="update", 
                     args=[ {"visible": [False,False,False,False,True]}, 
                            {'showlegend' : False}
                          ]),
            ]),
        )])

fig.update_layout(
    annotations=[
        dict(text="Choose:", showarrow=False,
             x=0.1, y=1.065, yref="paper", align="right",
             font=dict(size=16,color = 'DarkSlateBlue'))])

fig.update_layout(title ="The Distribution of <b>Experience,Programming Languages,IDE's,Hostsd Notebooks and Viz libraries<b>",
                  title_x = 0.5,
                  title_font = dict(size = 14, color = 'MidnightBlue'),
                  height = 700)

fig.show()

# %% [markdown]
# **From the above charts, we can see that :**
# * **More than 50% of kagglers possess 1-3 years or under 1 year coding experience. It is expected because that most of kagglers are "Students". On the other hand, only 16.2% of kagglers with more than 10 years coding experience.**
# * **Kagglers most often use Python and there are 2X more than SQL which is the second programming Language kagglers most often used. As we can see that Python is the most popular programming language for kagglers.**
# * **Jupyter Notebook is favorite integrated development environments for kagglers. VSCode and PyChram are also integrated development environments kagglers prefer using.**
# * **Kagglers most commonly use Colab Notebooks and Kaggle Notebooks.**
# * **Data Visualization plays an important role for Data Analysis. More than 60% of kagglers prefer using visualization libraries for analysis are Matplotlib and Seaborn. The number of kagglers who use Matplotlib are 1.7X more than using Seaborn.**

# %% [markdown]
# <a id="subsection-four"></a>
# **<font color = CadetBlue size = 4 >- Computing Platforms -</font>**

# %% [markdown]
# **In this section, I will discuss which of computing platforms and cloud computing platforms do kagglers most often use.**

# %%
# Computing platform
df11 = dfc['Q11'].iloc[1:].dropna()
df11 = dfc['Q11'].value_counts().sort_values(ascending = True).reset_index()
df11 = df11.rename(columns={'index':'Computing Platform', 'Q11':'Count'})
df11['percent'] = (df11['Count']*100 / df11['Count'].sum()).round(1).astype(str) + '%'
df11['Computing Platform'] = df11['Computing Platform'].replace("A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)","A cloud computing platform")
df11['Computing Platform'] = df11['Computing Platform'].replace("A deep learning workstation (NVIDIA GTX, LambdaLabs, etc)","A deep learning workstation")

# Cloud computing platform 
df27= dfc[[col for col in dfc if col.startswith('Q27_A')]]
df27.columns = ["AWS","Microsoft Azure","GCP","IBM Cloud/Red Hat","Oracle Cloud",
                "SAP Cloud","Salesforce Cloud","VMware Cloud",
                "Alibaba Cloud","Tencent Cloud","None","Other"]
df27 = df27.notnull().sum().to_frame().reset_index()
df27 = df27.rename(columns = {"index":"Cloud Computing Platform",0:"Count"})
df27 = df27.sort_values(by = ['Count'],ascending = True).reset_index()
df27['percent'] = (df27['Count']*100 / df27['Count'].sum()).round(1).astype(str) + '%'


fig = go.Figure()

fig.add_trace(go.Bar(x = df11['Count'],
                     y = df11['Computing Platform'],
                     orientation='h',
                     name = 'Computing Platform',
                     text= df11['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Computing Platform: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'LightCoral')))    

fig.add_trace(go.Bar(x = df27['Count'],
                     y = df27["Cloud Computing Platform"],
                     orientation='h',
                     name = "Cloud Computing Platform",
                     text= df27['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = "Cloud Computing Platform: <b>%{y}</b><br>Count: <b>%{x}</b><br>",
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'CadetBlue')))

fig.update_layout( 
    updatemenus=[ 
        dict( 
            direction="down", 
            pad={"r": 10, "t": 10},
            showactive=True, 
            x=0.18, 
            xanchor="left",
            y=1.09, 
            yanchor="top",
            font = dict(color = 'Indigo',size = 14),
            buttons=list([ 
                dict(label="All", 
                     method="update", 
                     args=[ {"visible": [True,True]}, 
                            {'showlegend' : True} 
                        ]),
                dict(label="Computing Platform", 
                     method="update", 
                     args=[ {"visible": [True,False]}, 
                            {'showlegend' : False} 
                        ]), 
                dict(label="Cloud Computing Platform", 
                     method="update", 
                     args=[ {"visible": [False,True]}, 
                            {'showlegend' : False} 
                     ]), 
            ]),
        )])

fig.update_layout(
    annotations=[
        dict(text="Choose:", showarrow=False,
             x=0.1, y=1.065, yref="paper", align="right",
             font=dict(size=16,color = 'DarkSlateBlue'))])

fig.update_layout(title ="The Distribution of <b>Computing Platforms and Cloud Computing Platforms<b>",
                  title_x = 0.5,
                  title_font = dict(size = 16, color = 'MidnightBlue'),
                  height = 700)

fig.show()

# %% [markdown]
# **From the above charts, we can see that :**
# * **Nearly 80% of kagglers most often use laptop or desktop, but few kagglers use cloud computing platform and deep learning workstation.**
# * **Kagglers most commonly use Google Cloud Platform (GCP) and Amazon Web Services (AWS).**

# %% [markdown]
# <a id="subsection-five"></a>
# **<font color = CadetBlue size = 4 >- Machine Learning -</font>**

# %% [markdown]
# **Next, I will talk about using experience and skills of machine learning of kagglers.**

# %%
# Machine learning experience(Year) 
df15 = dfc['Q15'].value_counts().sort_values(ascending = True).reset_index()
df15 = df15.rename(columns={'index':'ML Experience', 'Q15':'Count'})
df15['percent'] = (df15['Count']*100 / df15['Count'].sum()).round(1).astype(str) + '%'
df15['ML Experience'] = df15['ML Experience'].replace("I do not use machine learning methods","I do not use ML methods")

# Machine learning framework
df16= dfc[[col for col in dfc if col.startswith('Q16')]]
df16.columns = ["Scikit-learn","TensorFlow","Keras","PyTorch",
                "Fast.ai", "MXNet", "Xgboost", "LightGBM", "CatBoost", "Prophet",
                "H2O 3", "Caret", "Tidymodels","JAX","PyTorch Lightning","Huggingface",
                "None","Other"]

df16 = df16.notnull().sum().to_frame().reset_index()
df16 = df16.rename(columns = {"index":"ML Framework",0:"Count"})
df16 = df16.sort_values(by = ['Count'],ascending = True)
df16['percent'] = (df16['Count']*100 / df16['Count'].sum()).round(1).astype(str) + '%'

# Machine learning algorithm
df17= dfc[[col for col in dfc if col.startswith('Q17')]]
df17.columns = ["Linear/Logistic Regression", "Decision Trees/Random Forests", 
                "Gradient Boosting Machines", 
                "Bayesian Approaches", "Evolutionary Approaches", 
                "Dense Neural Networks","Convolutional Neural Networks", 
                "Generative Adversarial Networks","Recurrent Neural Networks", 
                "Transformer Networks", "None", "Other"]
df17 = df17.notnull().sum().to_frame().reset_index()
df17 = df17.rename(columns = {"index":"ML Algorithm",0:"Count"})
df17 = df17.sort_values(by = ['Count'],ascending = True)
df17['percent'] = (df17['Count']*100 / df17['Count'].sum()).round(1).astype(str) + '%'

    
fig = go.Figure()

fig.add_trace(go.Bar(x = df15['Count'],
                     y = df15['ML Experience'],
                     orientation='h',
                     name = 'ML Experience',
                     text= df15['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'ML Experience: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'CadetBlue')))

fig.add_trace(go.Bar(x = df16['Count'],
                     y = df16['ML Framework'],
                     orientation='h',
                     name = 'ML Framework',
                     text= df16['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'ML Framework: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'LightCoral')))

fig.add_trace(go.Bar(x = df17['Count'],
                     y = df17["ML Algorithm"],
                     orientation='h',
                     name = "ML Algorithm",
                     text= df17['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = "ML Algorithm: <b>%{y}</b><br>Count: <b>%{x}</b><br>",
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'SteelBlue')))

                                   
fig.update_layout( 
    updatemenus=[ 
        dict( 
            direction="down", 
            pad={"r": 10, "t": 10},
            showactive=True, 
            x=0.16, 
            xanchor="left",
            y=1.09, 
            yanchor="top",
            font = dict(color = 'Indigo',size = 14),
            buttons=list([ 
                dict(label="All", 
                     method="update", 
                     args=[ {"visible": [True,True,True]}, 
                            {'showlegend' : True} 
                        ]),
                dict(label="ML Experience", 
                     method="update", 
                     args=[ {"visible": [True,False,False]}, 
                            {'showlegend' : False} 
                        ]),
                dict(label="ML Framework", 
                     method="update", 
                     args=[ {"visible": [False,True,False]}, 
                            {'showlegend' : False} 
                        ]), 
                dict(label="ML Algorithm", 
                     method="update", 
                     args=[ {"visible": [False,False,True]}, 
                            {'showlegend' : False} 
                     ]),  
            ]),
        )])

fig.update_layout(
    annotations=[
        dict(text="Choose:", showarrow=False,
             x=0.1, y=1.065, yref="paper", align="right",
             font=dict(size=16,color = 'DarkSlateBlue'))])

fig.update_layout(title ="The Distribution of <b>ML Experience,ML Frameworks and ML Algorithms<b>",
                  title_x = 0.5,
                  title_font = dict(size = 16, color = 'MidnightBlue'),
                  height = 700)

fig.show()

# %% [markdown]
# **From the above charts, we can see that :**
# * **Over 60% of kagglers possess under 1 year or 1-2 years machine learning experience, and 12.7% of kagglers do not use machine learning methods. However, only 5.4% of kagglers possess over 5 years machine learning experience. As we can see that most of kagglers do not possess much experience in machine learning.**
# * **Scikit-learn and TensorFlow are machine learning frameworks do kagglers most commonly use.**
# * **Kagglers most commonly use algorithms which are Linear, Logistic Regression, Decision Trees and Random Forests.**

# %% [markdown]
# <a id="subsection-six"></a>
# **<font color = CadetBlue size = 4 >- Course Platforms & Media Sources -</font>**

# %% [markdown]
# **Finally, the last section is Course Platforms and Media Sources. In this section, I will talk about two questions. One is "Which platform have kagglers begun or completed data science courses ?", and the other is "Which media source do kagglers prefer reporting on data science topics ?".**

# %%
# Course platform 
df40= dfc[[col for col in dfc if col.startswith('Q40')]]
df40.columns = ["Coursera","edX","Kaggle Learn Courses","DataCamp","Fast.ai","Udacity","Udemy", 
                "LinkedIn Learning","Cloud-certification programs","University Courses","None","Other"]
df40 = df40.notnull().sum().to_frame().reset_index()
df40 = df40.rename(columns = {"index":"Course Platform",0:"Count"})
df40 = df40.sort_values(by = ['Count'],ascending = True).reset_index()
df40['percent'] = (df40['Count']*100 / df40['Count'].sum()).round(1).astype(str) + '%'

# Media source
df42= dfc[[col for col in dfc if col.startswith('Q42')]]
df42.columns = ["Twitter","Email newsletters","Reddit","Kaggle","Course Forums", 
                "YouTube","Podcasts","Blogs","Journal Publications",
                "Slack Communities","None","Other"]
df42 = df42.notnull().sum().to_frame().reset_index()
df42 = df42.rename(columns = {"index":"Media Source",0:"Count"})
df42 = df42.sort_values(by = ['Count'],ascending = True).reset_index()
df42['percent'] = (df42['Count']*100 / df42['Count'].sum()).round(1).astype(str) + '%'

fig = go.Figure()

fig.add_trace(go.Bar(x = df40['Count'],
                     y = df40["Course Platform"],
                     orientation='h',
                     name = "Course Platform",
                     text= df40['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = "Course Platform: <b>%{y}</b><br>Count: <b>%{x}</b><br>",
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'CadetBlue')))


fig.add_trace(go.Bar(x = df42['Count'],
                     y = df42['Media Source'],
                     orientation='h',
                     name = 'Media Source',
                     text= df42['percent'],
                     texttemplate='<b>%{text}<b>', 
                     hovertemplate = 'Media Source: <b>%{y}</b><br>Count: <b>%{x}</b><br>',
                     textposition='outside',
                     textfont_size=11,
                     cliponaxis = False,
                     marker = dict(color = 'SteelBlue')))


                                   
fig.update_layout( 
    updatemenus=[ 
        dict( 
            direction="down", 
            pad={"r": 10, "t": 10},
            showactive=True, 
            x=0.15, 
            xanchor="left",
            y=1.09, 
            yanchor="top",
            font = dict(color = 'Indigo',size = 14),
            buttons=list([ 
                dict(label="All", 
                     method="update", 
                     args=[ {"visible": [True,True]}, 
                            {'showlegend' : True} 
                        ]), 
                dict(label="Course Platform", 
                     method="update", 
                     args=[ {"visible": [True,False]}, 
                            {'showlegend' : False} 
                     ]), 
                dict(label='Media Source', 
                     method="update", 
                     args=[ {"visible": [False,True]}, 
                            {'showlegend' : False}
                          ]),
            ]),
        )])

fig.update_layout(
    annotations=[
        dict(text="Choose:", showarrow=False,
             x=0.1, y=1.065, yref="paper", align="right",
             font=dict(size=16,color = 'DarkSlateBlue'))])

fig.update_layout(title ="The Distribution of <b>Course Platforms and Media Sources<b>",
                  title_x = 0.5,
                  title_font = dict(size = 16, color = 'MidnightBlue'),
                  height = 700)

fig.show()

# %% [markdown]
# **From the above charts, we can see that :**
# * **Most of kagglers choose the platforms which are Kaggle Learn Course and Cousera to complete data science courses for improving the knowledge and skills about data science. In addition, as unexpected, most of kagglers are students, but only 10.6% of kagglers complete data science courses from university.**
# * **As expected, Kaggle is the most popular media source for kagglers reporting on data science topics. Youtube and Blogs are often used media sources for kagglers.**

# %% [markdown]
# **<font color = DarkSlateBlue size = 5 >Thank you for reading!😄</font>**

# %% [markdown]
# **Please consider upvoting & checking out more of my work if you found this interesting & valuable! Thanks so much!**

# %% [markdown]
# [Link to My Kaggle](http://www.kaggle.com/carriech)
