# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
def count_then_return_percent(dataframe,column_name):
    '''
    A helper function to return value counts as percentages.
    '''
    counts = dataframe[column_name].value_counts(dropna=False, sort = True)
    percentages = counts
    #percentages = round(counts*100/(dataframe[column_name].count()),1)
    return percentages


def plotly_bar_chart(response_counts,title,y_axis_title,orientation):
    '''
    This function creates a bar chart.
    '''
    response_counts_series = pd.Series(response_counts)
    fig = px.bar(response_counts_series,
             labels={"index": '',"value": y_axis_title},
             text=response_counts_series.values,
             orientation=orientation,)
    fig.update_layout(showlegend=False,
                      title={'text': title+' in 2021',
                             'y':0.95,
                             'x':0.5,})
    fig.show()

def list_to_plot(name_list,response_counts,title,y_axis_title,orientation):
    
    n = len(name_list)
    
    fig = make_subplots(rows = n // 2, cols = 2)
    
    
    unsorted_percentages = count_then_return_percent(df.loc[df['Q20'] == 'Computers/Technology'], 'Q25')

    title_for_chart = 'Salary Distributions on Kaggle'
    title_for_y_axis = '% of respondents'
    orientation_for_chart = 'h'

# %%
df = pd.read_csv('/kaggle/input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')

# %%
list(df['Q20'].value_counts().index)[:-1]

# %%
dataframe = df.loc[df['Q20'] == 'Computers/Technology']
column_name = 'Q25'
counts = dataframe[column_name].value_counts(dropna=True, sort = True)
percentages = round(counts*100/(dataframe[column_name].count()),1)
counts

# %%
responses_in_order = [#'$0-999',
                        #'1,000-1,999',
                        #'2,000-2,999',
                        #'3,000-3,999',
                        #'4,000-4,999',
                        '5,000-7,499',
                        '7,500-9,999',
                        '10,000-14,999',
                        '15,000-19,999',
                        '20,000-24,999',
                        '25,000-29,999',
                        '30,000-39,999',
                        '40,000-49,999',
                        '50,000-59,999',
                        '60,000-69,999',
                        '70,000-79,999',
                        '80,000-89,999',
                        '90,000-99,999',
                        '100,000-124,999',
                        '125,000-149,999',
                        '150,000-199,999',
                        '200,000-249,999',
                        '250,000-299,999',
                        '300,000-499,999',
                        '$500,000-999,999',
                        '>$1,000,000']
title_for_y_axis = 'Number of Respondents'

plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == 'Computers/Technology'], 'Q25')[responses_in_order], 
                 'Computers/Technology', title_for_y_axis, 'h')

# %%
name_var =  'Academics/Education'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var =   'Accounting/Finance'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Other'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var =   'Manufacturing/Fabrication'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var =   'Medical/Pharmaceutical'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var =   'Government/Public Service'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-3] + [responses_in_order[-1]]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var =   'Online Service/Internet-based Services'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-2] + [responses_in_order[-1]]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var =   'Energy/Mining'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-2] + [responses_in_order[-1]]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Retail/Sales'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-3] + [responses_in_order[-1]]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Insurance/Risk Assessment'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Marketing/CRM'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-3] + responses_in_order[-2:]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Broadcasting/Communications'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-3]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Shipping/Transportation'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-4]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Non-profit/Service'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-4] + [responses_in_order[-1]]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Online Business/Internet-based Sales'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-2] + [responses_in_order[-1]]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Military/Security/Defense'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-2]], 
                  name_var, title_for_y_axis, 'h')

# %%
name_var = 'Hospitality/Entertainment/Sports'
plotly_bar_chart(count_then_return_percent(df.loc[df['Q20'] == name_var], 'Q25')[responses_in_order[:-4] + responses_in_order[-3:-1]], 
                  name_var, title_for_y_axis, 'h')
