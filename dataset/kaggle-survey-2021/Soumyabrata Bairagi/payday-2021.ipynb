# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from warnings import filterwarnings
filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Loading and viewing the dataset
df = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv', low_memory=False)

# Removing the first row (it contains the survew questions)
df = df.drop(0)

df.head()

# %%
req_cols = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6',
                'Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3', 'Q7_Part_4', 'Q7_Part_5', 'Q7_Part_6', 'Q7_Part_7', 'Q7_Part_8', 'Q7_Part_9', 'Q7_Part_10', 'Q7_Part_11', 'Q7_Part_12', 'Q7_OTHER',
                'Q9_Part_1','Q9_Part_2','Q9_Part_3','Q9_Part_4','Q9_Part_5','Q9_Part_6','Q9_Part_7','Q9_Part_8','Q9_Part_9', 'Q9_Part_10','Q9_Part_11','Q9_Part_12','Q9_OTHER',
                'Q10_Part_1','Q10_Part_2','Q10_Part_3','Q10_Part_4','Q10_Part_5','Q10_Part_6','Q10_Part_7','Q10_Part_8','Q10_Part_9','Q10_Part_10','Q10_Part_11','Q10_Part_12','Q10_Part_13','Q10_Part_14','Q10_Part_15','Q10_Part_16','Q10_OTHER',
                'Q12_Part_1','Q12_Part_2','Q12_Part_3','Q12_Part_4','Q12_Part_5','Q12_OTHER',
                'Q13', 
                'Q14_Part_1', 'Q14_Part_2', 'Q14_Part_3', 'Q14_Part_4', 'Q14_Part_5', 'Q14_Part_6', 'Q14_Part_7', 'Q14_Part_8', 'Q14_Part_9', 'Q14_Part_10', 'Q14_Part_11', 'Q14_OTHER',
                'Q15',
                'Q16_Part_1', 'Q16_Part_2', 'Q16_Part_3', 'Q16_Part_4', 'Q16_Part_5', 'Q16_Part_6', 'Q16_Part_7', 'Q16_Part_8', 'Q16_Part_9', 'Q16_Part_10', 'Q16_Part_11', 'Q16_Part_12', 'Q16_Part_13', 'Q16_Part_14', 'Q16_Part_15', 'Q16_Part_16', 'Q16_Part_17', 'Q16_OTHER',
                'Q17_Part_1', 'Q17_Part_2', 'Q17_Part_3', 'Q17_Part_4', 'Q17_Part_5', 'Q17_Part_6', 'Q17_Part_7', 'Q17_Part_8', 'Q17_Part_9', 'Q17_Part_10', 'Q17_Part_11', 'Q17_OTHER',
                'Q20', 'Q21',
                'Q24_Part_1', 'Q24_Part_2', 'Q24_Part_3', 'Q24_Part_4', 'Q24_Part_5', 'Q24_Part_6', 'Q24_Part_7', 'Q24_OTHER', 
                'Q25',
                'Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3', 'Q27_A_Part_4','Q27_A_Part_5', 'Q27_A_Part_6', 'Q27_A_Part_7', 'Q27_A_Part_8', 'Q27_A_Part_9', 'Q27_A_Part_10', 'Q27_A_Part_11', 'Q27_A_OTHER',
                'Q31_A_Part_1', 'Q31_A_Part_2', 'Q31_A_Part_3', 'Q31_A_Part_4', 'Q31_A_Part_5', 'Q31_A_Part_6', 'Q31_A_Part_7', 'Q31_A_Part_8', 'Q31_A_Part_9', 'Q31_A_OTHER',
                'Q32_A_Part_1', 'Q32_A_Part_2', 'Q32_A_Part_3', 'Q32_A_Part_4', 'Q32_A_Part_5', 'Q32_A_Part_6', 'Q32_A_Part_7', 'Q32_A_Part_8', 'Q32_A_Part_9', 'Q32_A_Part_10', 'Q32_A_Part_11', 'Q32_A_Part_12', 'Q32_A_Part_13', 'Q32_A_Part_14', 'Q32_A_Part_15', 'Q32_A_Part_16', 'Q32_A_Part_17', 'Q32_A_Part_18', 'Q32_A_Part_19', 'Q32_A_Part_20', 'Q32_A_OTHER',
                'Q34_A_Part_1', 'Q34_A_Part_2', 'Q34_A_Part_3', 'Q34_A_Part_4', 'Q34_A_Part_5', 'Q34_A_Part_6', 'Q34_A_Part_7', 'Q34_A_Part_8', 'Q34_A_Part_9', 'Q34_A_Part_10', 'Q34_A_Part_11', 'Q34_A_Part_12', 'Q34_A_Part_13', 'Q34_A_Part_14', 'Q34_A_Part_15', 'Q34_A_Part_16', 'Q34_A_OTHER',
                'Q36_A_Part_1', 'Q36_A_Part_2', 'Q36_A_Part_3', 'Q36_A_Part_4', 'Q36_A_Part_5', 'Q36_A_Part_6', 'Q36_A_Part_7', 'Q36_A_OTHER',
                'Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4', 'Q40_Part_5', 'Q40_Part_6', 'Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10', 'Q40_Part_11', 'Q40_OTHER',
                'Q41']

df = df[req_cols]

# %%
single_choice = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q13', 'Q15', 'Q20','Q21', 'Q25', 'Q41']
# multi_choice
single_df = df[single_choice]
multiple_df = df.drop(columns = single_choice)

multiple_df = multiple_df.notnull().astype('int')
df = pd.merge(single_df, multiple_df, 
              on=single_df.index, 
              right_index=False).drop(columns='key_0')

# single_df

# %%
langs = ['Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3', 'Q7_Part_4', 'Q7_Part_5', 'Q7_Part_6', 'Q7_Part_7', 'Q7_Part_8', 'Q7_Part_9', 'Q7_Part_10', 'Q7_Part_11', 'Q7_Part_12', 'Q7_OTHER']
df['total_langs'] = df[langs].sum(axis=1)

ides = ['Q9_Part_1','Q9_Part_2','Q9_Part_3','Q9_Part_4','Q9_Part_5','Q9_Part_6','Q9_Part_7','Q9_Part_8','Q9_Part_9', 'Q9_Part_10','Q9_Part_11','Q9_Part_12','Q9_OTHER']
df['total_ides'] = df[ides].sum(axis=1)

nbs = ['Q10_Part_1','Q10_Part_2','Q10_Part_3','Q10_Part_4','Q10_Part_5','Q10_Part_6','Q10_Part_7','Q10_Part_8','Q10_Part_9','Q10_Part_10','Q10_Part_11','Q10_Part_12','Q10_Part_13','Q10_Part_14','Q10_Part_15','Q10_Part_16','Q10_OTHER']
df['total_nbs'] = df[nbs].sum(axis=1)

hws = ['Q12_Part_1','Q12_Part_2','Q12_Part_3','Q12_Part_4','Q12_Part_5','Q12_OTHER']
df['total_hws'] = df[hws].sum(axis=1)

viz = ['Q14_Part_1', 'Q14_Part_2', 'Q14_Part_3', 'Q14_Part_4', 'Q14_Part_5', 'Q14_Part_6', 'Q14_Part_7', 'Q14_Part_8', 'Q14_Part_9', 'Q14_Part_10', 'Q14_Part_11', 'Q14_OTHER']
df['total_viz'] = df[viz].sum(axis=1)

frameworks = ['Q16_Part_1', 'Q16_Part_2', 'Q16_Part_3', 'Q16_Part_4', 'Q16_Part_5', 'Q16_Part_6', 'Q16_Part_7', 'Q16_Part_8', 'Q16_Part_9', 'Q16_Part_10', 'Q16_Part_11', 'Q16_Part_12', 'Q16_Part_13', 'Q16_Part_14', 'Q16_Part_15', 'Q16_Part_16', 'Q16_Part_17', 'Q16_OTHER']
df['total_frameworks'] = df[frameworks].sum(axis=1)

algos = ['Q17_Part_1', 'Q17_Part_2', 'Q17_Part_3', 'Q17_Part_4', 'Q17_Part_5', 'Q17_Part_6', 'Q17_Part_7', 'Q17_Part_8', 'Q17_Part_9', 'Q17_Part_10', 'Q17_Part_11', 'Q17_OTHER']
df['total_algos'] = df[algos].sum(axis=1)

activs = ['Q24_Part_1', 'Q24_Part_2', 'Q24_Part_3', 'Q24_Part_4', 'Q24_Part_5', 'Q24_Part_6', 'Q24_Part_7', 'Q24_OTHER']
df['total_activs'] = df[activs].sum(axis=1)

cloudps = ['Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3', 'Q27_A_Part_4','Q27_A_Part_5', 'Q27_A_Part_6', 'Q27_A_Part_7', 'Q27_A_Part_8', 'Q27_A_Part_9', 'Q27_A_Part_10', 'Q27_A_Part_11', 'Q27_A_OTHER']
df['total_cloudps'] = df[cloudps].sum(axis=1)

mlps = ['Q31_A_Part_1', 'Q31_A_Part_2', 'Q31_A_Part_3', 'Q31_A_Part_4', 'Q31_A_Part_5', 'Q31_A_Part_6', 'Q31_A_Part_7', 'Q31_A_Part_8', 'Q31_A_Part_9', 'Q31_A_OTHER']
df['total_mlps'] = df[mlps].sum(axis=1)

bigdata = ['Q32_A_Part_1', 'Q32_A_Part_2', 'Q32_A_Part_3', 'Q32_A_Part_4', 'Q32_A_Part_5', 'Q32_A_Part_6', 'Q32_A_Part_7', 'Q32_A_Part_8', 'Q32_A_Part_9', 'Q32_A_Part_10', 'Q32_A_Part_11', 'Q32_A_Part_12', 'Q32_A_Part_13', 'Q32_A_Part_14', 'Q32_A_Part_15', 'Q32_A_Part_16', 'Q32_A_Part_17', 'Q32_A_Part_18', 'Q32_A_Part_19', 'Q32_A_Part_20', 'Q32_A_OTHER']
df['total_bigdata'] = df[bigdata].sum(axis=1)

bitools = ['Q34_A_Part_1', 'Q34_A_Part_2', 'Q34_A_Part_3', 'Q34_A_Part_4', 'Q34_A_Part_5', 'Q34_A_Part_6', 'Q34_A_Part_7', 'Q34_A_Part_8', 'Q34_A_Part_9', 'Q34_A_Part_10', 'Q34_A_Part_11', 'Q34_A_Part_12', 'Q34_A_Part_13', 'Q34_A_Part_14', 'Q34_A_Part_15', 'Q34_A_Part_16', 'Q34_A_OTHER']
df['total_bitools'] = df[bitools].sum(axis=1)

automl = ['Q36_A_Part_1', 'Q36_A_Part_2', 'Q36_A_Part_3', 'Q36_A_Part_4', 'Q36_A_Part_5', 'Q36_A_Part_6', 'Q36_A_Part_7', 'Q36_A_OTHER']
df['total_automl'] = df[automl].sum(axis=1)

courses = ['Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4', 'Q40_Part_5', 'Q40_Part_6', 'Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10', 'Q40_Part_11', 'Q40_OTHER']
df['total_courses'] = df[courses].sum(axis=1)

# %%
# Yearly Compensation
s_df = pd.DataFrame()
s_df['Compensation'] = df['Q25'].value_counts().index
s_df['Count'] = df['Q25'].value_counts().values
s_df['percent'] = ((s_df['Count'] / s_df['Count'].sum())*100).round(2).astype(str) + '%'
s_df = s_df.sort_values(by='Count', ascending=True)
fig = px.bar(s_df, x='Count', y='Compensation', text='percent', orientation='h')
fig.update_traces(textposition='outside')
fig.show()

# %%
avg = {
     '0-999':500,
     '7,500-9,999':8750,
     '4,000-4,999':4500,
     '40,000-49,999':45000,
     '50,000-59,999':55000,
     '3,000-3,999':3500,
     '2,000-2,999':2500,
     '10,000-14,999':12500,
     '5,000-7,499':6250,
     '20,000-24,999':22500,
     '100,000-124,999':112500,
     '150,000-199,999':175000,
     '>$1,000,000':1000000,
     '$500,000-999,999':750000,
     '25,000-29,999':27500,
     '60,000-69,999':65000,
     '30,000-39,999':35000,
     '15,000-19,999':17500,
     '70,000-79,999':75000,
     '300,000-499,999':400000,
     '200,000-249,999':225000,
     '125,000-149,999':137500,
     '250,000-299,999':275000,
     '80,000-89,999':85000,
     '90,000-99,999':95000,
     np.nan:0
}
df['Q25'] = df['Q25'].map(avg)

# %%
# Age
age_df = pd.DataFrame()
age_df['age'] = df['Q1'].value_counts().index
age_df['count'] = df['Q1'].value_counts().values
age_df = age_df.sort_values(by=['age'])

fig = px.pie(age_df, values=age_df['count'],
             names=age_df['age'],
             labels=age_df['age'],
             color_discrete_sequence=px.colors.sequential.Mint,
             hole=0.4, 
             title='Age of Respondents')
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  showlegend=False)
fig.show()

# %%
# Gender
gdf = df.replace(['Man', 'Woman'], ['Male', 'Female'])
fig = px.pie(gdf, values=gdf['Q2'].value_counts().values,
             names=gdf['Q2'].value_counts().index,
             labels=gdf['Q2'].value_counts().index,
             color_discrete_sequence=px.colors.sequential.Sunset,
             hole=0.4,
             title='Gender of Respondents')
fig.update_traces(textposition='outside',
                  textinfo='percent+label',
                  showlegend=False)
fig.show()

# %%
# Country
c_df = pd.DataFrame()
c_df['country'] = df['Q3'].value_counts().index
c_df['count'] = df['Q3'].value_counts().values
c_df['country'] = c_df['country'].str.replace(', Islamic Republic of...', '')
fig = px.choropleth(c_df, locations="country",
                    locationmode='country names',
                    color='count', 
                    hover_name='country',
                    color_continuous_scale=px.colors.sequential.deep)
fig.show()

# %%
# Education
e_df = pd.DataFrame()
e_df['degree'] = df['Q4'].value_counts().index
e_df['count'] = df['Q4'].value_counts().values
fig = px.treemap(e_df, path=[px.Constant("Degrees"), 'degree'], 
                 values='count', 
                 labels='degree', 
                 color='count', 
                 color_continuous_scale=px.colors.sequential.Sunset)
fig.update_traces(root_color="lightgrey",
                  textinfo='label+value+percent entry')
fig.show()

# %%
evs = df.groupby('Q4')['Q25'].median()
evs = evs.sort_values(ascending=True)
fig = px.bar(x=evs.values, y=evs.index, orientation='h', text=evs.values.round(2))
fig.show()

# %%
ovs = df.groupby('Q5')['Q25'].median()
ovs = ovs.sort_values(ascending=True)
fig = px.bar(x=ovs.values, y=ovs.index, orientation='h', text=ovs.values.round(2))
fig.show()

# %%
xvs = df.groupby('Q6')['Q25'].median()
xvs = xvs.sort_values(ascending=True)
fig = px.bar(x=xvs.values, y=xvs.index, orientation='h', text=xvs.values.round(2))
fig.show()

# %%
# Language (Multiple Correct)
# lg_df = pd.DataFrame()
# lg_df['language'] = [df[col].value_counts().index[0] for col in df.columns[7:20]]
# lg_df['count'] = [df[col].value_counts().values[0] for col in df.columns[7:20]]
# lg_df['percent'] = ((lg_df['count']/lg_df['count'].sum())*100).round(2).astype(str)+'%'
# fig = px.bar(lg_df, x='count', y='language', text='percent', orientation='h')
# fig.show()
lvs = {}
lvs['lang'] = []
lvs['salary'] = []

for lang in langs:
    temp = df[df[lang] == 1]
    lvs['lang'].append(lang)
    lvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=lvs)
temp = temp.rename(columns={'Q7_Part_1':'Python',
                            'Q7_Part_2':'R',
                            'Q7_Part_3':'SQL',
                            'Q7_Part_4':'C',
                            'Q7_Part_5':'C++', 
                            'Q7_Part_6':'Java',
                            'Q7_Part_7':'Javascript',
                            'Q7_Part_8':'Julia',
                            'Q7_Part_9':'Swift',
                            'Q7_Part_10':'Bash',
                            'Q7_Part_11':'Matlab',
                            'Q7_Part_12':'None', 'Q7_OTHER':'Other'})

px.bar(temp, x='lang', y='salary',title='Average Salary of Each Programming Language', text=round(temp.salary, 2))

# %%
# Notebooks (multiple choice)
nvs = {}
nvs['nb'] = []
nvs['salary'] = []

for nb in nbs:
    temp = df[df[nb] == 1]
    nvs['nb'].append(nb)
    nvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=nvs)

px.bar(temp, x='nb', y='salary',title='Average Salary of Each Notebook', text=round(temp.salary, 2))

# %%
# Specialized hw (multiple choice)
hvs = {}
hvs['hw'] = []
hvs['salary'] = []

for hw in hws:
    temp = df[df[hw] == 1]
    hvs['hw'].append(hw)
    hvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=hvs)

px.bar(temp, x='hw', y='salary',title='Average Salary of specialised h/w', text=round(temp.salary, 2))

# %%
# TPU
tvs = df.groupby('Q13')['Q25'].median()
tvs = tvs.sort_values(ascending=True)
fig = px.bar(x=tvs.values, y=tvs.index, orientation='h', text=tvs.values.round(2))
fig.show()

# %%
# Data viz tools (multiple)
vvs = {}
vvs['vis'] = []
vvs['salary'] = []

for vis in viz:
    temp = df[df[vis] == 1]
    vvs['vis'].append(viz)
    vvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=vvs)

px.bar(temp, x='vis', y='salary',title='Average Salary of Data Visualization tools', text=round(temp.salary, 2))

# %%
# Experience with ML methods
mvs = df.groupby('Q15')['Q25'].median()
mvs = mvs.sort_values(ascending=True)
fig = px.bar(x=mvs.values, y=mvs.index, orientation='h', text=mvs.values.round(2))
fig.show()

# %%
# ML Frameworks (multiple)
mfvs = {}
mfvs['mfw'] = []
mfvs['salary'] = []

for mfw in frameworks:
    temp = df[df[mfw] == 1]
    mfvs['mfw'].append(viz)
    mfvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=mfvs)

px.bar(temp, x='mfw', y='salary',title='Average Salary of ML Frameworks', text=round(temp.salary, 2))

# %%
# ML algos (multiple)
mavs = {}
mavs['ma'] = []
mavs['salary'] = []

for ma in algos:
    temp = df[df[ma] == 1]
    mavs['ma'].append(ma)
    mavs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=mavs)

px.bar(temp, x='ma', y='salary',title='Average Salary of ML Algorithms', text=round(temp.salary, 2))

# %%
# Industry
ivs = df.groupby('Q20')['Q25'].median()
ivs = ivs.sort_values(ascending=True)
fig = px.bar(x=ivs.values, y=ivs.index, orientation='h', text=ivs.values.round(2))
fig.show()

# %%
# Size of Company
svs = df.groupby('Q21')['Q25'].median()
svs = svs.sort_values(ascending=True)
fig = px.bar(x=svs.values, y=svs.index, orientation='h', text=svs.values.round(2))
fig.show()

# %%
# Activities (multiple)
avs = {}
avs['act'] = []
avs['salary'] = []

for act in activs:
    temp = df[df[act] == 1]
    avs['act'].append(act)
    avs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=avs)

px.bar(temp, x='act', y='salary',title='Average Salary of Activities', text=round(temp.salary, 2))

# %%
# Cloud Platforms
cvs = {}
cvs['cp'] = []
cvs['salary'] = []

for cp in cloudps:
    temp = df[df[cp] == 1]
    cvs['cp'].append(cp)
    cvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=cvs)

px.bar(temp, x='cp', y='salary',title='Average Salary of Cloud Platforms', text=round(temp.salary, 2))

# %%
# ML Products
mpvs = {}
mpvs['mlp'] = []
mpvs['salary'] = []

for mlp in mlps:
    temp = df[df[mlp] == 1]
    mpvs['mlp'].append(mlp)
    mpvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=mpvs)

px.bar(temp, x='mlp', y='salary',title='Average Salary of ML Products', text=round(temp.salary, 2))

# %%
# Big Data
bvs = {}
bvs['bd'] = []
bvs['salary'] = []

for bd in bigdata:
    temp = df[df[bd] == 1]
    bvs['bd'].append(bd)
    bvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=bvs)

px.bar(temp, x='bd', y='salary',title='Average Salary of Big Data', text=round(temp.salary, 2))

# %%
# BI tools
bivs = {}
bivs['bi'] = []
bivs['salary'] = []

for bi in bitools:
    temp = df[df[bi] == 1]
    bivs['bi'].append(bi)
    bivs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=bivs)

px.bar(temp, x='bi', y='salary',title='Average Salary of BI tools', text=round(temp.salary, 2))

# %%
# Do you use AutoML
amvs = {}
amvs['am'] = []
amvs['salary'] = []

for am in automl:
    temp = df[df[am] == 1]
    amvs['am'].append(am)
    amvs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=amvs)

px.bar(temp, x='am', y='salary',title='Average Salary of AutoML tools', text=round(temp.salary, 2))

# %%
# Online Courses
covs = {}
covs['c'] = []
covs['salary'] = []

for c in courses:
    temp = df[df[c] == 1]
    covs['c'].append(c)
    covs['salary'].append(temp.Q25.mean())


temp = pd.DataFrame(data=covs)

px.bar(temp, x='c', y='salary',title='Average Salary of Courses', text=round(temp.salary, 2))

# %%
# Primary Tools used at work/school
ptvs = df.groupby('Q41')['Q25'].median()
ptvs = ptvs.sort_values(ascending=True)
fig = px.bar(x=ptvs.values, y=ptvs.index, orientation='h', text=ptvs.values.round(2))
fig.show()
