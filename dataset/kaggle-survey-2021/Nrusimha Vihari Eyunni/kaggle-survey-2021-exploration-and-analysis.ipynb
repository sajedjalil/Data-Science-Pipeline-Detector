# %% [markdown]
# <div style="display:fill;
#             border-radius: False;
#             border-style: solid;
#             border-color:#800000;
#             border-style: false;
#             border-width: 3px;
#             color: white;
#             font-size:15px;
#             font-family: Sans-Serif;
#             background-color:#800000;
#             text-align:center;
#             letter-spacing:0.5px;
#             padding: 0.7em;
#             text-align:left">
#
# **To Begin with..**
#
# I would like to tell a story about the data science community represented in this survey, through a combination of both narrative text and data exploration. I plan to deeply explore the data, its priorities, or discrepancies in a specific group of data science and machine learning practitioners.
#
# *This is a wonderful opportunity to tell a story of the community that you feel included in and are passionate about!*

# %% [markdown]
# <blockquote> <span style="font-family:Sans-serif;color:white;font-weight:bold;background:#800000">Introduction:</span>
#
# I look up to many people here and learned a lot in the past few months and want to get involved in the most creative competition of Kaggle's 5th Survey. Starting from my first few lines of code in data science to pursuing Masters in Data Science, Kaggle and the wonderful community has been my backbone. So, thank you.
#
# Now, lets dive into the world of Analysis and Story Telling!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
colors = ["#121212","#CF673A","#E4C56F","#97A37B","#BABABA","#E8DCCC"]

import warnings
warnings.filterwarnings("ignore")

# %%
dataframe = pd.read_csv("../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv")
dataframe = dataframe[1:]
dataframe.head()

# %%
dataframe.info()

# %% [markdown]
# <blockquote><p><strong> 📌 Takeaway :</strong></p>
# <ul>
# <li>The Dataset contains the Questions and Survey results.</li>
# </ul>

# %% [markdown]
# <h3>Data Definition
#
# <table class="Data_Definition">
#   <thead>
#     <tr>
#       <th class="header">Number</th>
#       <th class="header">Question</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Q1</td>
#       <td>What is your age (# years)?</td>
#     </tr>
#     <tr>
#       <td>Q2</td>
#       <td>What is your gender?</td>
#     </tr>
#     <tr>
#       <td>Q3</td>
#       <td>In which country do you currently reside?</td>
#     </tr>
#     <tr>
#       <td>Q4</td>
#       <td>What is the highest level of formal education that you have attained or plan to attain within the next 2 years?</td>
#     </tr>
#     <tr>
#       <td>Q5</td>
#       <td>Select the title most similar to your current role (or most recent title if retired)</td>
#     </tr>
#     <tr>
#       <td>Q6</td>
#       <td>For how many years have you been writing code and/or programming?</td>
#     </tr>
#     <tr>
#       <td>Q7</td>
#       <td>What programming languages do you use on a regular basis?</td>
#     </tr>
#     <tr>
#       <td>Q8</td>
#       <td>What programming language would you recommend an aspiring data scientist to learn first?</td>
#     </tr>
#     <tr>
#       <td>Q9</td>
#       <td>Which of the following integrated development environments (IDE's) do you use on a regular basis?</td>
#     </tr>
#     <tr>
#       <td>Q10</td>
#       <td>Which of the following hosted notebook products do you use on a regular basis? </td>
#     </tr>
#     <tr>
#       <td>Q11</td>
#       <td>What type of computing platform do you use most often for your data science projects?</td>
#     </tr>
#        <tr>
#       <td>Q12</td>
#       <td>Which types of specialized hardware do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q13</td>
#       <td>Approximately how many times have you used a TPU</td>
#     </tr>
#           <tr>
#       <td>Q14</td>
#       <td>What data visualization libraries or tools do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q15</td>
#       <td>For how many years have you used machine learning methods?</td>
#     </tr>
#       <tr>
#           <td>Q16</td>
#           <td>Which of the following machine learning frameworks do you use on a regular basis?</td>
#            </tr>
#        <tr>
#           <td>Q17</td>
#           <td>Which of the following ML algorithms do you use on a regular basis?</td>
#        </tr>
#           <tr>
#       <td>Q18</td>
#       <td>Which categories of computer vision methods do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q19</td>
#       <td>Which of the following natural language processing (NLP) methods do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q20</td>
#       <td>In what industry is your current employer/contract (or your most recent employer if retired)?</td>
#     </tr>
#           <tr>
#       <td>Q21</td>
#       <td>What is the size of the company where you are employed?</td>
#     </tr>
#           <tr>
#       <td>Q22</td>
#       <td>Approximately how many individuals are responsible for data science workloads at your place of business?</td>
#     </tr>
#           <tr>
#       <td>Q23</td>
#       <td>Does your current employer incorporate machine learning methods into their business?</td>
#     </tr>
#           <tr>
#       <td>Q24</td>
#       <td>Select any activities that make up an important part of your role at work.</td>
#     </tr>
#           <tr>
#       <td>Q25</td>
#       <td>What is your current yearly compensation?</td>
#     </tr>
#           <tr>
#       <td>Q26</td>
#       <td>Approximately how much money have you (or your team) spent on machine learning and/or cloud computing services at home (or at work) in the past 5 years?</td>
#     </tr>
#           <tr>
#       <td>Q27</td>
#       <td>Which of the following cloud computing platforms do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q28</td>
#       <td>Of the cloud platforms that you are familiar with, which has the best developer experience (most enjoyable to use)?</td>
#     </tr>
#           <tr>
#       <td>Q29</td>
#       <td>Do you use any of the following cloud computing products on a regular basis? </td>
#     </tr>
#           <tr>
#       <td>Q30</td>
#       <td>Do you use any of the following data storage products on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q31</td>
#       <td>In the next 2 years, do you hope to become more familiar with any of these managed machine learning products?</td>
#     </tr>
#           <tr>
#       <td>Q32</td>
#       <td>Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#           <tr>
#       <td>Q34</td>
#       <td>Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#           <tr>
#       <td>Q36</td>
#       <td>Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#           <tr>
#       <td>Q37</td>
#       <td>Which specific automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#           <tr>
#       <td>Q38</td>
#       <td>In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments?</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h1><center><span style="font-family:Georgia;color:white;font-weight:bold;background:#800000"> 🔍Exploratory Data Analysis

# %% [markdown]
# <h3> 2.1 Age Distribution

# %%
plt.rcParams['figure.figsize'] = (16,9)
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['figure.frameon'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams["font.family"] = "monospace"

# %%
sns.countplot(x = dataframe['Q1'].sort_values(),
              color=colors[2],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Age Group', weight='semibold', fontname = 'Georgia')
plt.tick_params(axis='x', which='major', labelsize=10)

plt.suptitle('Age Distribution', fontname = 'Georgia', weight='bold')
plt.show()

# %% [markdown]
# <blockquote><p><strong> 📌 Takeaway :</strong></p>
# <ul>
# <li>The data realated field is popular among 18-29.</li>
# <li>The reason for the lower distribution as the age increases must be due to popularity of data jobs in recent years.
# </ul>

# %% [markdown]
# <h3> 2.2 Gender Distribution

# %%
import plotly.express as px

pie_col = ["#CF673A","#E4C56F","#97A37B","#BABABA","#E8DCCC","#1274A1"]

fig = px.pie(values= dataframe['Q2'].value_counts().values, names= dataframe['Q2'].value_counts().index)

fig.update_traces(hoverinfo='label+percent',
                  textinfo='value',
                  textfont_size=20,
                  marker=dict(colors=pie_col,
                              line=dict(color='#000000', width=1)))
fig.show()

# %% [markdown]
# <blockquote><p><strong> 📌 Takeaway :</strong></p>
# <ul>
# <li>There are Large number of men on data science field.</li>
# <li>As expected from the previous surveys thre small number of female kagglers than male.</li>
# </ul>

# %% [markdown]
# <h3> 2.3 Countries Participated

# %%
scale =[[0, '#E4C56F'],
             [0.5,'#455C4F'],
             [1.0, '#CF673A']]


settings = [ dict(
        type = 'choropleth',
        autocolorscale = False,
        colorscale = scale,
        showscale = True,
        locations = dataframe.Q3.value_counts().index,
        z = dataframe.Q3.value_counts().values,
        locationmode = 'country names',
        text = dataframe.Q3.value_counts().index,
        marker = dict(
            line = dict(color = '#E4C56F', width = 0.5)),
            colorbar = dict(autotick = True, tickprefix = '', 
            title = 'Participants')
            )
       ]

layout = dict(
    title = 'Number of People Participated in Survey',
    geo = dict(
        showframe = True,
        showocean = True,
        oceancolor = '#1274A1',
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 60,
                    lat = 10),
        ),
        lonaxis =  dict(
                showgrid = False,
                gridcolor = '#6e6d6d'
            ),
        lataxis = dict(
                showgrid = False,
                gridcolor = '#6e6d6d'
                )
            ),
        )
fig = dict(data=settings, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')

# %% [markdown]
# <h3> 2.4 Level of Formal Education

# %%
from textwrap import wrap

A = sns.countplot(x= dataframe['Q4'],
              color=colors[2],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

labels = [ '\n'.join(wrap(l, 12)) for l in dataframe['Q4'].unique()]

plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Education', weight='semibold', fontname = 'Georgia')

plt.suptitle('Formal Education', fontname = 'Georgia', weight='bold')

plt.tick_params(axis='x', which='major', labelsize=10)

A.set_xticklabels(labels, fontsize=10)

plt.show()

# %% [markdown]
# <h3> 2.5 Current Role

# %%
import plotly.graph_objs as go

edu = dataframe['Q5'].value_counts()

trace = go.Scatter(
    x=edu.index,
    y=edu.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 30,
        size = edu.values,
        color = edu.values,
        colorscale='Fall',
        showscale=True
    ),
)

layout = go.Layout(
    title='Current Role'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="Current Role")

# %% [markdown]
# <h3> 2.6 Coding Experience

# %%
import plotly.graph_objs as go

edu = dataframe['Q6'].value_counts()

trace = go.Scatter(
    x=edu.index,
    y=edu.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 30,
        size = edu.values,
        #color = np.random.randn(500), #set color equal to a variable
        color = edu.values,
        colorscale='Fall',
        showscale=True
    ),
)

layout = go.Layout(
    title='Coding Experience'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="LearningDataScience")

# %% [markdown]
# <h3> 2.7 Programming on Regular Basis

# %%
q7 = dataframe[['Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3', 'Q7_Part_4', 'Q7_Part_5', 'Q7_Part_6', 'Q7_Part_7', 'Q7_Part_8', 'Q7_Part_9', 'Q7_Part_10','Q7_Part_11','Q7_Part_12', 'Q7_OTHER']]

q7.columns = ['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia', 'Swift', 'Bash', 'MATLAB', 'None', 'Other']

q7.count().sort_values(ascending=True).plot(kind='barh',color=colors[2])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Languages', weight='semibold', fontname = 'Georgia')
plt.suptitle('Programming on Regular Basis', fontname = 'Georgia', weight='bold')


plt.show()

# %% [markdown]
# <h3> 2.8 Programming Language Recommended

# %%
A = sns.countplot(x= dataframe['Q8'],
              color=colors[2],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Languages', weight='semibold', fontname = 'Georgia')
plt.suptitle('Programming Language Recommended', fontname = 'Georgia', weight='bold')



plt.show()

# %% [markdown]
# <h3> 2.9 IDE on Regular Basis

# %%
q9 = dataframe[['Q9_Part_1',
         'Q9_Part_2',
        'Q9_Part_3',
        'Q9_Part_4',
         'Q9_Part_5',
        'Q9_Part_6',
         'Q9_Part_7',
         'Q9_Part_8',
         'Q9_Part_9',
         'Q9_Part_10',
         'Q9_Part_11',
         'Q9_Part_12',
         'Q9_OTHER']]

q9.columns = ['Jupyter (JupyterLab, Jupyter Notebooks, etc)',
              ' RStudio',
              'Visual Studio',
              'Visual Studio Code (VSCode)',
              'PyCharm',
              'Spyder',
             'Notepad++',
              'Sublime Text',
              'Vim / Emacs',
              'MATLAB',
              'Jupyter Notebook',
              'None',
              'Other']

q9.count().sort_values().plot(kind='barh',color=colors[2])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('IDE', weight='semibold', fontname = 'Georgia')
plt.suptitle('IDE on Regular Basis', fontname = 'Georgia', weight='bold')


plt.show()

# %% [markdown]
# <h3> 2.10 Use of Notebooks of Regular Basis

# %%
q10 = dataframe[['Q10_Part_1',
         'Q10_Part_2',
        'Q10_Part_3',
        'Q10_Part_4',
         'Q10_Part_5',
        'Q10_Part_6',
         'Q10_Part_7',
         'Q10_Part_8',
         'Q10_Part_9',
         'Q10_Part_10',
         'Q10_Part_11',
         'Q10_Part_12',
         'Q10_Part_13',
         'Q10_Part_14',
         'Q10_Part_15',
         'Q10_Part_16',
         'Q10_OTHER']]

q10.columns = ['Kaggle Notebooks',
              'Colab Notebooks',
              'Azure Notebooks',
              'Paperspace / Gradient',
              'Binder / JupyterHub',
              'Code Ocean',
             'IBM Watson Studio',
              'Amazon Sagemaker Studio Notebooks',
              'Amazon EMR Notebooks',
              'Google Cloud Notebooks (AI Platform / Vertex AI)',
              'Google Cloud Datalab',
              'Databricks Collaborative Notebooks',
              'Zeppelin / Zepl Notebooks',
              'Deepnote Notebooks',
              'Observable Notebooks',
               'None',
               'Other']

q10.count().sort_values().plot(kind='barh',color=colors[2])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Notebooks', weight='semibold', fontname = 'Georgia')
plt.suptitle('Notebooks', fontname = 'Georgia', weight='bold')


plt.show()

# %% [markdown]
# <div style="display:fill;
#             border-radius: false;
#             border-style: solid;
#             border-color:#000000;
#             border-style: false;
#             border-width: 2px;
#             color:white;
#             font-size:15px;
#             font-family: Sans-serif;
#             background-color:#800000;
#             text-align:center;
#             letter-spacing:0.1px;
#             padding: 0.1em;">
#
# **<h2>⌛ Work In Progress**
