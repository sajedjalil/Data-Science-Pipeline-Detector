# %%
from IPython.core.display import display, HTML
html_contents ="""
<!DOCTYPE html>
<html lang="en">
    <head>
    <style>
    
    .section{
        font-family:Georgia;
        color:black;
        font-weight:bold;
        background:#EBE3DB;
    }

    </style>
    </head>
    
</html>
"""

HTML(html_contents)

# %% [markdown]
# <div class="text_cell_render border-box-sizing rendered_html">
# <p><img src="https://raw.githubusercontent.com/heyrobin/DS-ML-2021-Kaggle-Survey/main/DSML.gif"></p>
#
# </div>

# %% [markdown]
# <div style="display:fill;
#             border-radius: False;
#             border-style: solid;
#             border-color:#CF673A;
#             border-style: false;
#             border-width: 3px;
#             color:#121212;
#             font-size:15px;
#             font-family: Georgia;
#             background-color:#E4C56F;
#             text-align:center;
#             letter-spacing:0.5px;
#             padding: 0.7em;
#             text-align:left">
#
# **About Competition**
#
#  tell a data story about a subset of the data science community represented in this survey, through a combination of both narrative text and data exploration. A “story” could be defined any number of ways, and that’s deliberate. The challenge is to deeply explore (through data) the impact, priorities, or concerns of a specific group of data science and machine learning practitioners. That group can be defined in the macro (for example: anyone who does most of their coding in Python) or the micro (for example: female data science students studying machine learning in masters programs).
#
# *This is an opportunity to be creative and tell the story of a community you identify with or are passionate about!*

# %% [markdown]
# <blockquote> <span style="font-family:Georgia;color:#CF673A;font-weight:bold;background:#E8DCCC">Introduction:</span>
#
# Hey! It's a great opportunity to get involved in the best and coolest community of Data Scientists, Statisticians, Coders, and Creatives. I look up to many people here and learned a lot in the past few months and want to get involved in the most creative competition of Kaggle's 5th Survey.
#
# I will try to do my best here with creativity and analysis. I am working on ideas on how I am going to tell the story, but I started with my favorite season of the year autumn so my colors are inspired by it. I will keep updating the notebook with new Ideas and hopefully will complete it before submission.
#
# Let's get started and Enjoy!

# %% [markdown]
# <h1><center><span style="font-family:Georgia;color:#E8DCCC;font-weight:bold;background:#97A37B"> 📕Importing Libraries & Datasets

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py

import warnings
warnings.filterwarnings("ignore")

import seaborn as sns
colors = ["#121212","#CF673A","#E4C56F","#97A37B","#BABABA","#E8DCCC"]
#sns.palplot(sns.color_palette(colors))

# %%
df = pd.read_csv("../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv")
#df = df[1:]
df.head()

# %%
questions = df.iloc[0]
questions

# %%
df = df.drop([0])
df

# %%
df.info()

# %% [markdown]
# <blockquote><p><strong> 📌 Takeaway :</strong></p>
# <ul>
# <li>The Dataset contains the Questions and Survey results.</li>
# </ul>

# %% [markdown]
# <h3>Data Definition
#
# <table class="Data_Definition">
#   <thead>
#     <tr>
#       <th class="header">Number</th>
#       <th class="header">Question</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Q1</td>
#       <td>What is your age (# years)?</td>
#     </tr>
#     <tr>
#       <td>Q2</td>
#       <td>What is your gender?</td>
#     </tr>
#     <tr>
#       <td>Q3</td>
#       <td>In which country do you currently reside?</td>
#     </tr>
#     <tr>
#       <td>Q4</td>
#       <td>What is the highest level of formal education that you have attained or plan to attain within the next 2 years?</td>
#     </tr>
#     <tr>
#       <td>Q5</td>
#       <td>Select the title most similar to your current role (or most recent title if retired)</td>
#     </tr>
#     <tr>
#       <td>Q6</td>
#       <td>For how many years have you been writing code and/or programming?</td>
#     </tr>
#     <tr>
#       <td>Q7</td>
#       <td>What programming languages do you use on a regular basis?</td>
#     </tr>
#     <tr>
#       <td>Q8</td>
#       <td>What programming language would you recommend an aspiring data scientist to learn first?</td>
#     </tr>
#     <tr>
#       <td>Q9</td>
#       <td>Which of the following integrated development environments (IDE's) do you use on a regular basis?</td>
#     </tr>
#     <tr>
#       <td>Q10</td>
#       <td>Which of the following hosted notebook products do you use on a regular basis? </td>
#     </tr>
#     <tr>
#       <td>Q11</td>
#       <td>What type of computing platform do you use most often for your data science projects?</td>
#     </tr>
#        <tr>
#       <td>Q12</td>
#       <td>Which types of specialized hardware do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q13</td>
#       <td>Approximately how many times have you used a TPU</td>
#     </tr>
#           <tr>
#       <td>Q14</td>
#       <td>What data visualization libraries or tools do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q15</td>
#       <td>For how many years have you used machine learning methods?</td>
#     </tr>
#       <tr>
#           <td>Q16</td>
#           <td>Which of the following machine learning frameworks do you use on a regular basis?</td>
#            </tr>
#        <tr>
#           <td>Q17</td>
#           <td>Which of the following ML algorithms do you use on a regular basis?</td>
#        </tr>
#           <tr>
#       <td>Q18</td>
#       <td>Which categories of computer vision methods do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q19</td>
#       <td>Which of the following natural language processing (NLP) methods do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q20</td>
#       <td>In what industry is your current employer/contract (or your most recent employer if retired)?</td>
#     </tr>
#           <tr>
#       <td>Q21</td>
#       <td>What is the size of the company where you are employed?</td>
#     </tr>
#           <tr>
#       <td>Q22</td>
#       <td>Approximately how many individuals are responsible for data science workloads at your place of business?</td>
#     </tr>
#           <tr>
#       <td>Q23</td>
#       <td>Does your current employer incorporate machine learning methods into their business?</td>
#     </tr>
#           <tr>
#       <td>Q24</td>
#       <td>Select any activities that make up an important part of your role at work.</td>
#     </tr>
#           <tr>
#       <td>Q25</td>
#       <td>What is your current yearly compensation?</td>
#     </tr>
#           <tr>
#       <td>Q26</td>
#       <td>Approximately how much money have you (or your team) spent on machine learning and/or cloud computing services at home (or at work) in the past 5 years?</td>
#     </tr>
#           <tr>
#       <td>Q27</td>
#       <td>Which of the following cloud computing platforms do you use on a regular basis?</td>
#     </tr>
#           <tr>
#       <td>Q28</td>
#       <td>Of the cloud platforms that you are familiar with, which has the best developer experience (most enjoyable to use)?</td>
#     </tr>
#           <tr>
#       <td>Q29</td>
#       <td>Do you use any of the following cloud computing products on a regular basis? </td>
#     </tr>
#           <tr>
#       <td>Q30</td>
#       <td>Do you use any of the following data storage products on a regular basis?</td>
#      </tr>
#           <tr>
#       <td>Q31</td>
#       <td>In the next 2 years, do you hope to become more familiar with any of these managed machine learning products?</td>
#     </tr>
#           <tr>
#       <td>Q32</td>
#       <td>Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#       <tr>
#       <td>Q33</td>
#       <td>Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often?</td>
#     </tr>
#           <tr>
#       <td>Q34</td>
#       <td>Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#           <tr>
#       <td>Q35</td>
#       <td>Which of the following business intelligence tools do you use most often?</td>
#     </tr>
#           <tr>
#       <td>Q36</td>
#       <td>Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#           <tr>
#       <td>Q37</td>
#       <td>Which specific automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?</td>
#     </tr>
#           <tr>
#       <td>Q38</td>
#       <td>In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments?</td>
#     </tr>
#           <tr>
#       <td>Q39</td>
#       <td>Where do you publicly share your data analysis or machine learning applications?</td>
#     </tr>
#           <tr>
#       <td>Q40</td>
#       <td>On which platforms have you begun or completed data science courses?</td>
#     </tr>
#           <tr>
#       <td>Q41</td>
#       <td>What is the primary tool that you use at work or school to analyze data?</td>
#     </tr>
#           <tr>
#       <td>Q42</td>
#       <td>Who/what are your favorite media sources that report on data science topics?</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h1><center><span style="font-family:Georgia;color:#E8DCCC;font-weight:bold;background:#97A37B"> 🔍Exploratory Data Analysis

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB">2.1 What is your age (# years)?

# %%
#plt.rcParams["axes.grid"] = True
#plt.rcParams["grid.color"] = colors[3]
#plt.rcParams["grid.alpha"] = 0.5
#plt.rcParams["grid.linestyle"] = '--'

# %%
plt.rcParams['figure.figsize'] = (16,9)
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['figure.frameon'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams["font.family"] = "monospace"

# %%
sns.countplot(x = df['Q1'].sort_values(),
              color=colors[2],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Age Group', weight='semibold', fontname = 'Georgia')
plt.tick_params(axis='x', which='major', labelsize=10)

plt.suptitle('What is your age (# years)?', fontname = 'Georgia', weight='bold')
plt.show()

# %% [markdown]
# <blockquote><p><strong> 📌 Takeaway :</strong></p>
# <ul>
# <li>The data realated field is popular among 18-29.</li>
# <li>The reason for the lower distribution as the age increases must be due to popularity of data jobs in recent years.
# </ul>

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.2 What is your gender?

# %%
import plotly.express as px

pie_col = ["#CF673A","#E4C56F","#97A37B","#BABABA","#E8DCCC","#1274A1"]

fig = px.pie(values= df['Q2'].value_counts().values, names= df['Q2'].value_counts().index)

fig.update_traces(hoverinfo='label+percent',
                  textinfo='value',
                  textfont_size=20,
                  marker=dict(colors=pie_col,
                              line=dict(color='#000000', width=1)))
fig.show()

# %% [markdown]
# <blockquote><p><strong> 📌 Takeaway :</strong></p>
# <ul>
# <li>There are Large number of men on data science field.</li>
# <li>As expected from the previous surveys thre small number of female kagglers than male.</li>
# </ul>

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.3 In which country do you currently reside?

# %%
scale =[[0, '#E4C56F'],
             [0.5,'#455C4F'],
             [1.0, '#CF673A']]


settings = [ dict(
        type = 'choropleth',
        autocolorscale = False,
        colorscale = scale,
        showscale = True,
        locations = df.Q3.value_counts().index,
        z = df.Q3.value_counts().values,
        locationmode = 'country names',
        text = df.Q3.value_counts().index,
        marker = dict(
            line = dict(color = '#E4C56F', width = 0.5)),
            colorbar = dict(autotick = True, tickprefix = '', 
            title = 'Participants')
            )
       ]

layout = dict(
    title = 'In which country do you currently reside?',
    geo = dict(
        showframe = True,
        showocean = True,
        oceancolor = '#1274A1',
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 60,
                    lat = 10),
        ),
        lonaxis =  dict(
                showgrid = False,
                gridcolor = '#6e6d6d'
            ),
        lataxis = dict(
                showgrid = False,
                gridcolor = '#6e6d6d'
                )
            ),
        )
fig = dict(data=settings, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.4 What is the highest level of formal education that you have attained or plan to attain within the next 2 years?

# %%
from textwrap import wrap

A = sns.countplot(x= df['Q4'],
              color=colors[2],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

labels = [ '\n'.join(wrap(l, 12)) for l in df['Q4'].unique()]

plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Education', weight='semibold', fontname = 'Georgia')

plt.suptitle('What is the highest level of formal education that you have attained or plan to attain within the next 2 years?', fontname = 'Georgia', weight='bold')

plt.tick_params(axis='x', which='major', labelsize=10)

A.set_xticklabels(labels, fontsize=10)

plt.show()

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.5 Select the title most similar to your current role (or most recent title if retired)

# %%
import plotly.graph_objs as go

edu = df['Q5'].value_counts()

trace = go.Scatter(
    x=edu.index,
    y=edu.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 30,
        size = edu.values,
        color = edu.values,
        colorscale='Fall',
        showscale=True
    ),
)

layout = go.Layout(
    title='Select the title most similar to your current role (or most recent title if retired)'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="Current Role")

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB">2.6 For how many years have you been writing code and/or programming?

# %%
import plotly.graph_objs as go

edu = df['Q6'].value_counts()

trace = go.Scatter(
    x=edu.index,
    y=edu.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 30,
        size = edu.values,
        #color = np.random.randn(500), #set color equal to a variable
        color = edu.values,
        colorscale='Fall',
        showscale=True
    ),
)

layout = go.Layout(
    title='For how many years have you been writing code and/or programming?'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="LearningDataScience")

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.7 What programming languages do you use on a regular basis?

# %%
def ques_title(ques):
    title = questions.filter(regex = ques)[0].split("?")[0]+'?'
    return title
ques_title('Q7')

# %%
def plot(ques,lab, fsize = (16, 9)):
    a = df.filter(regex = ques)
    answer_desc = a.describe()
    answergot = answer_desc.loc[['top', 'count']].T
    answergot = answergot.set_index('top')
    answergot = answergot.sort_values(by="count", ascending = False)
    
    plt.figure(figsize = fsize)
    A = sns.barplot(data = answergot,
                 x='count',
                 y = answergot.index,
              color=colors[2],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
    plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
    plt.ylabel(lab, weight='semibold', fontname = 'Georgia')
    plt.suptitle(ques_title(ques), fontname = 'Georgia', weight='bold')
    
    A.bar_label(A.containers[0])
    
    plt.show

# %%
plot('Q7','Language')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.8 What programming language would you recommend an aspiring data scientist to learn first?

# %%
def plotcount(ques,lab):
    A = sns.countplot(y= df[ques],
              color=colors[2],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
    #from textwrap import wrap
    #labels = [ '\n'.join(wrap(l, 12)) for l in df[ques].unique()]
    #plt.tick_params(axis='x', which='major', labelsize=10)

    

    plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
    plt.ylabel(lab, weight='semibold', fontname = 'Georgia')
    plt.suptitle(ques_title(ques), fontname = 'Georgia', weight='bold')
    A.bar_label(A.containers[0])
    
    #A.set_xticklabels(labels, fontsize=10)
    
    plt.show

# %%
plotcount('Q8','language')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.9 Which of the following integrated development environments (IDE's) do you use on a regular basis?

# %%
plot('Q9','IDE')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.10 Which of the following hosted notebook products do you use on a regular basis?

# %%
plot('Q10','Notebooks')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.11 What type of computing platform do you use most often for your data science projects?

# %%
plotcount('Q11','Platform')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.12 Which types of specialized hardware do you use on a regular basis?

# %%
plot('Q12','Hardware')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.13 Approximately how many times have you used a TPU

# %%
plotcount('Q13','TPU Usage')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.14 What data visualization libraries or tools do you use on a regular basis?

# %%
plot('Q14','Libraries')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.15 For how many years have you used machine learning methods?

# %%
plotcount('Q15','Years')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.16 Which of the following machine learning frameworks do you use on a regular basis?

# %%
plot('Q16','ML Frameworks')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.17 Which of the following ML algorithms do you use on a regular basis?

# %%
plot('Q17','ML Algorhythm')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.18 Which categories of computer vision methods do you use on a regular basis?

# %%
plot('Q18','Computer Vision Methods')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.19 Which of the following natural language processing (NLP) methods do you use on a regular basis?

# %%
plot('Q19','NLP')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.20 In what industry is your current employer/contract (or your most recent employer if retired)?

# %%
plotcount('Q20','Employer/Contract')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.21 What is the size of the company where you are employed?

# %%
plotcount('Q21','Company Size')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.22 Approximately how many individuals are responsible for data science workloads at your place of business?

# %%
plotcount('Q22','Individuals')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.23 Does your current employer incorporate machine learning methods into their business?

# %%
plotcount('Q23','Machine Learning Methods')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.24 Select any activities that make up an important part of your role at work.

# %%
plot('Q24','Important Role')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.25 What is your current yearly compensation?

# %%
plotcount('Q25','Computing Platform')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.26 Approximately how much money have you (or your team) spent on machine learning and/or cloud computing services at home (or at work) in the past 5 years?

# %%
plotcount('Q26','Amount Spent')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.27 Which of the following cloud computing platforms do you use on a regular basis?

# %%
plot('Q27_A','Cloud Computing Platforms')

# %%
plot('Q27_B','Cloud Computing Platforms')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.28 Of the cloud platforms that you are familiar with, which has the best developer experience (most enjoyable to use)?

# %%
plotcount('Q28','Cloud Platform')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.29 Do you use any of the following cloud computing products on a regular basis?

# %%
plot('Q29_A','Cloud Computing Products')

# %%
plot('Q29_B','Cloud Computing Products')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.30 Do you use any of the following data storage products on a regular basis?

# %%
plot('Q30_A','Storage Products')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.31 In the next 2 years, do you hope to become more familiar with any of these managed machine learning products?

# %%
plot('Q31_A','ML Products')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.32 Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years?

# %%
plot('Q32_A','Big Data Products')

# %%
plot('Q32_B','Big Data Products')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.33 Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often?

# %%
plotcount('Q33','Big Data Products')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.34 Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years?

# %%
plot('Q34_A','BI Tools')

# %%
plot('Q34_B','BI Tools')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.35 Which of the following business intelligence tools do you use most often?

# %%
plotcount('Q35','BI Tools')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.36 Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?

# %%
plot('Q36_A','Tools')

# %%
plot('Q36_B','Tools')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.37 Which specific automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?

# %%
plot('Q37_A','Learning Tools')

# %%
plot('Q37_B','Learning Tools')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.38 In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments?

# %%
plot('Q38_A','Tools')

# %%
plot('Q38_B','Tools')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.39 Where do you publicly share your data analysis or machine learning applications?

# %%
plot('Q39','Public Sharing Platforms')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.40 On which platforms have you begun or completed data science courses?

# %%
plot('Q40','Platforms')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.41 What is the primary tool that you use at work or school to analyze data?

# %%
plotcount('Q41','Primary Tools')

# %% [markdown]
# <h3> <span style="font-family:Georgia;color:black;font-weight:bold;background:#EBE3DB"> 2.42 Who/what are your favorite media sources that report on data science topics?

# %%
plot('Q42','Media Sources')

# %% [markdown]
# <div style="display:fill;
#             border-radius: false;
#             border-style: solid;
#             border-color:#000000;
#             border-style: false;
#             border-width: 2px;
#             color:#CF673A;
#             font-size:15px;
#             font-family: Georgia;
#             background-color:#E8DCCC;
#             text-align:center;
#             letter-spacing:0.1px;
#             padding: 0.1em;">
#
# **<h2>⌛ Work In Progress**
