# %%
from IPython.core.display import display, HTML, Javascript

html_contents ="""
<!DOCTYPE html>
<html lang="en">
    <head>
    
    <style>
    @import url('https://fonts.googleapis.com/css2?family=MedievalSharp&display=swap');
    
    .Banner_Intro{
        display:fill;
        border-radius: 255px 15px 225px 15px/15px 225px 15px 255px;
        border-color:#8F480F;
        border-style: dashed;
        border-width: 3px; 
        
        color:#121212;
        
        font-size:15px;
        font-weight: bold;
        font-family: 'MedievalSharp', cursive;
        
        background-color:#E9C990;
        text-align:center;
        letter-spacing:0.5px;
        padding: 0.7em;
        text-align:left">        
    }
    
    hr { border: 1px solid #a8b7b79;
             color: #a8b7b7;
             background: #a8b7b7;
           }


    .Banner_Intro2{
        display:fill;
        border-radius: 255px 15px 225px 15px/15px 225px 15px 255px;
        border-color:#627d81;
        border-style: dashed;
        border-width: 3px; 
        
        color:#a8b7b7";
        
        font-size:15px;
        font-weight: bold;
        font-family: 'MedievalSharp', cursive;
        
        background-color:#a8b7b7;
        text-align:center;
        letter-spacing:0.5px;
        padding: 0.7em;
        text-align:left">        
    }
    
    .thing {
       padding: 1rem;
       width: 420px;
       box-shadow: 0 15px 30px 0 rgba(0,0,0,0.11),
       0 5px 15px 0 rgba(0,0,0,0.08);
       border-color:#8F480F;
  
       border-radius: 254px 15px 225px 15px/15px 225px 15px 255px;
       border-style: dashed;
       border-left: 0 solid #680E04;
       transition: border-left 300ms ease-in-out, padding-left 300ms ease-in-out;
  
       background-color:#E9C990;
  
       font-size:15px;
       font-family: 'MedievalSharp', cursive;
  
       font-weight: bold;
  
       letter-spacing:0.5px;
       padding: 0.7em;
       text-align: left;>
  
}

.thing:hover {
  padding-left: 0.5rem;
  border-left: 0.5rem solid #8F480F;
}

.thing > :first-child {
  margin-top: 0;
}

.thing > :last-child {
  margin-bottom: 0;
}

.heading {
  color: #fff;
}

body {
  display: flex;
  flex-direction: column;
  align-items: center;
  justify-content: center;
  width: 100vw;
  height: 100vh;
  font-family: 'MedievalSharp', cursive;
}

.chapters {
    font-family: 'MedievalSharp', cursive;
    font-weight: bold;
    color:#3c3d1a;
    text-align: center;
    font-size:25px;
}

.section {
    font-family: 'MedievalSharp', cursive;
    font-weight: bold;
    color:#3c3d1a;
    text-align: left;
    font-size:23px;
}

.index {
    font-family: 'MedievalSharp', cursive;
    font-size:15px;
    font-weight: bold;
    color:#3c3d1a;
    text-align: left;
}

.banner_head {
    font-family: 'MedievalSharp', cursive;
    font-weight: bold;
    font-size:35px;
    color:black;
}


    </style>
    </head>
    
</html>
"""

HTML(html_contents)

# %% [markdown]
# <p><img src="https://github.com/heyrobin/DS-ML-2021-Kaggle-Survey/blob/main/Banner.png?raw=true"></p>

# %% [markdown]
# <div class="Banner_Intro"><div class="banner_head">🗡️ Story of Keg - The Warrior Journey Towards Data Scientist</div>
#     <br>📜 There is a world where people fight from the bottom to the top of the hierarchy to become the ultimate warrior called the data scientist.
#     <br>To become one of the greatest warriors you have to take challenges, adventures, and travel across the land to gain knowledge and skills.
#     <br> There was a boy who looked up to these warriors and ever since childhood he wanted to become a warrior.
#     <br>The path of the data scientist is no ordinary journey to anyone.
#     <br>The journey consist of many difficulties and one has to master all the art forms like fighting the data, mastering the code,
#     <br>concuring the fear of machine learning, and learning mystic arts of Prediction 🔮.
#     <br>So its a story of the boy who wanted to become one of the greatest Data Scientists.

# %% [markdown]
# <div class="index">Chapters
#
# 1. [Demographics](#1)
#     - 1.1 [Age ](#1.1)
#     - 1.2 [Gender](#1.2)
#     - 1.3 [Countries ](#1.3)
# 2. [Academics and Education](#2)
#     - 2.1 [Education](#2.1)
#     - 2.2 [ Roll](#2.2)
#     - 2.3 [ Industry](#2.3)
#     - 2.4 [ Courses Platform](#2.4)
# 3. [Skills](#3)
#     - 3.1 [Languages](#3.1)
#     - 3.2 [ Languages Recommended](#3.2)
#     - 3.3 [ IDE Enviroment](#3.3)
#     - 3.4 [ Data Vizualization Tools](#3.4)
#     - 3.5 [ML Frameworks](#3.5)
#     - 3.6 [ML Algorithms](#3.6)
#     - 3.7 [ Size of Company](#3.7)
#     - 3.8 [Important Rolls](#3.8)
#     - 3.9[Yearly Earnings](#3.9)
#     - 3.10 [ Cloud Platforms](#3.10)
#     - 3.11[ Business Intelligence Tools](#3.11)
# 4. [Experience](#4)
#     - 4.1 [Experience of ML](#4.1)
#     - 4.2  [Experience of Coding](#4.2)
# 5. [Platforms](#5)
#     - 5.1 [Notebooks](#5.1)
#     - 5.2 [Cloud Computing Platforms](#5.2)
#     - 5.3 [Public Sharing Platforms](#5.3)
#     - 5.4 [Online Reporting Media and Sources](#5.4)
#     - 5.5  [Python vs R](#5.5)
# 6. [Conclusion](#6)

# %% [markdown]
# <hr>

# %% [markdown]
# <a id="0"></a>
# <div class="chapters">📕Importing Libraries &amp; Datasets

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

from textwrap import wrap

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.offline as py
import plotly.graph_objs as go
import plotly.express as px

import matplotlib as mlb
import matplotlib.image as mpimg
from matplotlib.offsetbox import AnnotationBbox, OffsetImage

plt.rcParams['figure.figsize'] = (16,9)
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['figure.frameon'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams["font.family"] = "monospace";


import seaborn as sns
colors = ["#a8b7b7","#627d81","#7c8459","#3c3d1a","#cfb78a","#be9b6b","#977b4c","#5d5739","#382f17"]
sns.palplot(sns.color_palette(colors))

# %%
df = pd.read_csv("../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv")
questions = df.iloc[0]
df = df.drop([0])

# %%
def implot(name,X,Y,z):
    url = 'https://raw.githubusercontent.com/heyrobin/DS-ML-2021-Kaggle-Survey/main/'+ name +'.png'
    name = mpimg.imread(url)
    box = OffsetImage(name , zoom=z)
    xy = (0.5, 0.7)
    b = AnnotationBbox(box, xy, frameon=False, pad=1, xybox=(X, Y*1000))
    A.add_artist(b)

# %% [markdown]
# <p><img src="https://github.com/heyrobin/DS-ML-2021-Kaggle-Survey/blob/main/Tranao%20Republic.gif?raw=true"></p>

# %% [markdown]
# <div class="Banner_Intro2"> The Great Journey of Keg the Warrior Starts with Cisan Village where he grew up. He is about to meet Oracle lady in the Ropia City.

# %% [markdown]
# <div class="Banner_Intro"> 🔮 The Great Oracle told the boy about the difficulties before going towards the journey the oracle gave him some books, scripts, and data telling him that it will guide him towards the destiny.

# %% [markdown]
# <hr>

# %% [markdown]
#  <div class="chapters">Chapter 1 : Demographics<a id="1"></a>

# %% [markdown]
# ## <div class="section">1.1 Age <a id="1.1"></a>

# %%
#plot
A = sns.countplot(x= df['Q1'],
                      order = df['Q1'].value_counts().index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    

#Patch
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)    
A.patches[idx_tallest].set_facecolor(colors[7])



#Lables
plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Age', weight='semibold', fontname = 'Georgia')
plt.suptitle('Age of Warriors', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0], label_type='edge')

#Annot
A.annotate('Age',
                    fontsize=10, fontweight='bold',
                    xy=(2.6, 4000.1), xycoords='data',
                    xytext=(0.60, 0.95), textcoords='axes fraction',
                    arrowprops=dict(
                    facecolor=colors[1], shrink=0.025, 
                    connectionstyle='arc3, rad=0.40'),
                    horizontalalignment='left', verticalalignment='top');

# %% [markdown]
# <div class="thing">
#     ⚔️ Most of the warriors are between 18 and 29 years of age.<br>⚔️ Data Science became very poplular in last few years.

# %% [markdown]
# ## <div class="section">1.2 Gender <a id="1.2"></a>

# %%
ques='Q2'
xlab='Count'
ylab='Gender'

A = sns.countplot(x= df[ques],
                      order = df[ques].value_counts().index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading) 
idx_tallest = np.argmax(patch_h)   
A.patches[idx_tallest].set_facecolor(colors[7])  

    
plt.ylabel(xlab, weight='semibold', fontname = 'Georgia')
plt.xlabel(ylab, weight='semibold', fontname = 'Georgia')
plt.suptitle('Gender of Warriors', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0])
    
implot('Male',0,14,0.3)    
implot('Female',1,10,0.3) 
implot('unknown',2,6,0.3) 
implot('unknown',3,4.8,0.3) 
implot('unknown',4,4.6,0.3) 

#Annot
A.annotate('Male',
                    fontsize=10, fontweight='bold',
                    xy=(0.5, 16000.1), xycoords='data',
                    xytext=(0.60, 0.80), textcoords='axes fraction',
                    arrowprops=dict(
                    facecolor=colors[1], shrink=0.025, 
                    connectionstyle='arc3, rad=0.40'),
                    horizontalalignment='left', verticalalignment='top');

# %% [markdown]
# <div class="thing">
#     ⚔️ Majority count of warriors are 79% and There are only 18% Warrioress Participated.<br>

# %% [markdown]
# ## <div class="section">1.3 Countries <a id="1.3"></a>

# %%
scale =[[0, colors[2]],
        [0.5,colors[6]],
        [1.0, colors[7]]]


settings = [ dict(
        type = 'choropleth',
        autocolorscale = False,
        colorscale = scale,
        showscale = True,
        locations = df.Q3.value_counts().index,
        z = df.Q3.value_counts().values,
        locationmode = 'country names',
        text = df.Q3.value_counts().index,
        marker = dict(
            line = dict(color = '#E4C56F', width = 0.5)),
            colorbar = dict(autotick = True, tickprefix = '', 
            title = 'Recorded')
            )
       ]

layout = dict(
    title = '<b>Countries of Warriors</b>', 
    title_x=0.5,
    titlefont=dict(size =24, color=colors[7], family='MedievalSharp'),
    geo = dict(
        showframe = True,
        showocean = True,
        oceancolor = colors[1],
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 60,
                    lat = 10),
        ),
        lonaxis =  dict(
                showgrid = False,
                gridcolor = colors[3]
            ),
        lataxis = dict(
                showgrid = False,
                gridcolor = colors[3]
                )
            ),
        )


fig = dict(data=settings, layout=layout)
py.iplot(fig, validate=False, filename='GlobMap')

# %% [markdown]
# <div class="thing">⚔️ Most of the warriors comes from India 28%, followed by the United States with 10%.

# %% [markdown]
# <div class="Banner_Intro2"> After Understanding the demographics Keg The Warrior got some ideas to start. Now he has to continue his journey towards Barren Lands where the books and data leads him.

# %% [markdown]
# <hr>

# %% [markdown]
# <p><img src="https://github.com/heyrobin/DS-ML-2021-Kaggle-Survey/blob/main/Barren%20Lands.gif?raw=true"></p>

# %% [markdown]
# <div class="chapters"> Chapter 2 : Academics and Education <a id="2"></a>

# %% [markdown]
# <div class="section">2.1 Education <a id="2.1"></a>

# %%
#plot
A = sns.countplot(x= df['Q4'],
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

#Patch
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)    
A.patches[idx_tallest].set_facecolor(colors[7]) 

#TextWrap
from textwrap import wrap
labels = [ '\n'.join(wrap(l, 12)) for l in df['Q4'].unique()]
plt.tick_params(axis='x', which='major', labelsize=10)
A.set_xticklabels(labels, fontsize=10)

#image
implot('Male',1,7,0.26)
implot('Artemes',0,5,0.21) 

#labels
plt.ylabel('count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Education', weight='semibold', fontname = 'Georgia')
plt.suptitle('Education of Warriors', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing"> ⚔️ Over 77% of Warriors participated have a Bachelor's and/or a Master's degree.

# %% [markdown]
# <div class="section">2.2 Roll <a id="2.2"></a>

# %%
ylab='Count'
xlab='Roll'

A = sns.countplot(x= df['Q5'],
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

#Patch
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)   
A.patches[idx_tallest].set_facecolor(colors[7]) 


#TextWrap
labels = [ '\n'.join(wrap(l, 8)) for l in df['Q5'].unique()]
plt.tick_params(axis='x', which='major', labelsize=10)
A.set_xticklabels(labels, fontsize=10)


#Label
plt.xlabel(xlab, weight='semibold', fontname = 'Georgia')
plt.ylabel(ylab, weight='semibold', fontname = 'Georgia')
plt.suptitle('Roll of Warriors', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0])

#Annot
A.annotate('26.1% Students',
                    fontsize=10, fontweight='bold',
                    xy=(5.0, 4000.1), xycoords='data',
                    xytext=(0.60, 0.95), textcoords='axes fraction',
                    arrowprops=dict(
                    facecolor=colors[2], shrink=0.025, 
                    connectionstyle='arc3, rad=0.40'),
                    horizontalalignment='left', verticalalignment='top');

#(df['Q5'].value_counts() / df['Q5'].shape[0]*100)[:2]

# %% [markdown]
# <div class="thing">⚔️  There are 26.1% Students and 13.9% Data Scientist records given by Oracle.

# %% [markdown]
# <div class="section">2.3 Industry <a id="2.3"></a>

# %%
scale =[[0, colors[2]],
        [0.5,colors[6]],
        [1.0, colors[7]]]




Data_src = df['Q20'].value_counts()


trace = go.Scatter(
    x=Data_src.index,
    y=Data_src.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 20,
        size = Data_src.values,
        color = Data_src.values,
        colorscale=scale,
        showscale=True
    ),
)

layout = go.Layout(
    title='<b>Industries of Warriors</b>', 
    title_x=0.5,
    titlefont=dict(size =24, color=colors[7], family='MedievalSharp'),
    plot_bgcolor='rgba(0,0,0,0)'
)



data = [trace]
fig = go.Figure(data=data, layout=layout)
fig.update_xaxes(showline=True, linewidth=2, linecolor=colors[3])
fig.update_yaxes(showline=True, linewidth=2, linecolor=colors[3])
py.iplot(fig, filename="Industries of Warriors")

#(df['Q20'].value_counts() / df['Q20'].shape[0]*100)[:2]

# %% [markdown]
# <div class="thing">⚔️  Technology industry is the common industy among 15% warriors and 12% of warriors works on Academics/Education Industry

# %% [markdown]
# <div class="section">2.4 Courses Platform <a id="2.4"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q40')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)   
    
A.patches[idx_tallest].set_facecolor(colors[7]) 
    
plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Courses Platform', weight='semibold', fontname = 'Georgia')
plt.suptitle('Warriors Choice of Courses Platform', fontname = 'Georgia', weight='bold')
    
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing">⚔️  Data scientists' most commonly used course platforms are Coursera and Kaggle, respectively, with 20% and 18% .

# %% [markdown]
# <div class="Banner_Intro2"> Keg got more knowlege through the barren Lands in Glean Farms he read about Education, Roll, Industry and Courses Platform.

# %% [markdown]
# <hr>

# %% [markdown]
# <p><img src="https://github.com/heyrobin/DS-ML-2021-Kaggle-Survey/blob/main/Ice%20Zeadel.gif?raw=true"></p>

# %% [markdown]
# <div class="chapters">Chapter 3 : Skills <a id="3"></a>

# %% [markdown]
# <div class="Banner_Intro"> Drotor Castle has so many hidden secrets about becoming a Data Scientist but journey isn't easy now. 🥶 The cold and chill winds.

# %% [markdown]
# <div class="section">3.1 Languages <a id="3.1"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q7')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 y='count',
                 x= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)   
    
A.patches[idx_tallest].set_facecolor(colors[7])

#image
#implot('Poseidon',7,12,0.4)
    
plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Programming Languages', weight='semibold', fontname = 'Georgia')
plt.suptitle('Warriors Choice of Weapons', fontname = 'Georgia', weight='bold')
    
A.bar_label(A.containers[0]);

#(df['Q5'].value_counts() / df['Q5'].shape[0]*100)[:2]

# %% [markdown]
# <div class="thing">⚔️  Python is the common weapon Used by 33% Warriors, followed by SQL with 16%.

# %% [markdown]
# <div class="section">3.2 Languages Recommended <a id="3.2"></a>

# %%
A = sns.countplot(x= df['Q8'],
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])




plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Languages', weight='semibold', fontname = 'Georgia')
plt.suptitle('Language Recommended by Data Scientists', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing">⚔️  Python is the best language recommended by the Data scientist and then comes are.

# %% [markdown]
# <div class="section">3.3 IDE Enviroment <a id="3.3"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q9')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('IDE', weight='semibold', fontname = 'Georgia')
plt.suptitle('Commonly Used IDE', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing">⚔️  The IDEs used by participants are Jupiter Notebook 25%, Visual Studio Code 15% then Pycham 11.5%.

# %% [markdown]
# <div class="section">3.4 Data Vizualization Tools <a id="3.4"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q14')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Data Vizualization', weight='semibold', fontname = 'Georgia')
plt.suptitle('Mystic Data Visualization', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing">⚔️  The types of mystic Data Vizualization famous among participants are Matplotlib 34.6%, Seaborn 24.7%. Plotly/ Plotly express 11.3%

# %% [markdown]
# <div class="section">3.5 ML Frameworks <a id="3.5"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q16')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('ML Frameworks', weight='semibold', fontname = 'Georgia')
plt.suptitle('ML Fight Styles', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

#answergot / answergot.sum() *100

# %% [markdown]
# <div class="thing">⚔️  Most preferred fighting style is Scikit learn 24.8%, TensorFlow 16.6%. Keras 14.1%

# %% [markdown]
# <div class="section">3.6 ML Algorithms <a id="3.6"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q17')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('ML Algorithms', weight='semibold', fontname = 'Georgia')
plt.suptitle('ML Fight Moves', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

#answergot / answergot.sum() *100

# %% [markdown]
# <div class="thing">⚔️  The best fighting moves among data scientists are Linear or Logistic Regression 22.9%, Decision Trees/ Random Forests 19.6% and GBMs 12.5%

# %% [markdown]
# <div class="section">3.7 Size of Company <a id="3.7"></a>

# %%
cnt_srs = df['Q21'].value_counts().head(30)

trace = go.Scatter(
    x=cnt_srs.index,
    y=cnt_srs.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 20,
        size = cnt_srs.values,
        #color = np.random.randn(500), #set color equal to a variable
        color = cnt_srs.values,
        colorscale=scale,
        showscale=True
    ),
)

layout = go.Layout(
    title='<b>Size of The Company/Clan</b>', 
    title_x=0.5,
    titlefont=dict(size =24, color=colors[8], family='MedievalSharp'),
    plot_bgcolor='rgba(0,0,0,0)'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
fig.update_xaxes(showline=True, linewidth=2, linecolor=colors[3])
fig.update_yaxes(showline=True, linewidth=2, linecolor=colors[3])
py.iplot(fig, filename="Size of the Company/Clan")

# %% [markdown]
# <div class="thing">⚔️  There are 19.4% working under 50 employees size and 13.15% for more than 10,000 employees size

# %% [markdown]
# <div class="section">3.8 Important Rolls <a id="3.8"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q24')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Roles', weight='semibold', fontname = 'Georgia')
plt.suptitle('Important Roles of Warrior', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

#answergot / answergot.sum() *100

# %% [markdown]
# <div class="thing">⚔️  The rolls preferred by scientists is to Analyze and understand data to influence product or business decisions 27.4% and Build prototypes to explore applying machine learning to new areas 15.5%

# %% [markdown]
# <div class="section">3.9 Yearly Earnings <a id="3.9"></a>

# %%
Data_src = df['Q25'].value_counts().head(30)

trace = go.Scatter(
    x=Data_src.index,
    y=Data_src.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 20,
        size = Data_src.values,
        color = Data_src.values,
        colorscale=scale,
        showscale=True
    ),
)

layout = go.Layout(
    title='<b>Earning of Warriors(Annual)</b>', 
    title_x=0.5,
    titlefont=dict(size =24, color=colors[8], family='MedievalSharp'),
    plot_bgcolor='rgba(0,0,0,0)'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
fig.update_xaxes(showline=True, linewidth=2, linecolor=colors[3])
fig.update_yaxes(showline=True, linewidth=2, linecolor=colors[3])
py.iplot(fig, filename="Current yearly Compensation")

# %% [markdown]
# <div class="thing">⚔️  The highest count of annual earning is between 0-999$

# %% [markdown]
# <div class="section">3.10 Cloud Platforms <a id="3.10"></a>

# %%
#plot
A = sns.countplot(y= df['Q28'],
                order = df['Q28'].value_counts().index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)
A.patches[idx_tallest].set_facecolor(colors[7])



'''
#TextWrap
labels = [ '\n'.join(wrap(l, 8)) for l in df['Q28'].unique()]
plt.tick_params(axis='x', which='major', labelsize=10)
A.set_xticklabels(labels, fontsize=10)'''

#label
plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Cloud Platforms', weight='semibold', fontname = 'Georgia')
plt.suptitle('Best Familiarity with Magic Platform', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);
    
    
    
plt.show;

# %% [markdown]
# <div class="thing">⚔️  AWS highest among all cloud platforms used by participants then comes Google Cloud.

# %% [markdown]
# <div class="section">3.11 Business Intelligence Tools <a id="3.11"></a>

# %%
#plot
A = sns.countplot(y= df['Q35'],
                order = df['Q35'].value_counts().index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)
A.patches[idx_tallest].set_facecolor(colors[7])

'''
#TextWrap
labels = [ '\n'.join(wrap(l, 8)) for l in df['Q28'].unique()]
plt.tick_params(axis='x', which='major', labelsize=10)
A.set_xticklabels(labels, fontsize=10)'''


#label
plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('BI tool', weight='semibold', fontname = 'Georgia')
plt.suptitle('Most used Magical Tool', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing">⚔️  Power BI and Tableau is most preferred Business Intelligence tools.

# %% [markdown]
# <div class="Banner_Intro2"> From Drotor Castle Keg The Warrior found the hidden truths about Programming Languages,Recommendation,IDE Enviroment, Data Vizualization Tools, ML Framework, ML Algorhythm, Team size of a company, Important Rolls, Yearly Eanings, Etc. Now the journey ends here, or is it?. The king of Drotor Castle offered his boat to travel across the sea towards High Harbor where the Journey of the ⛰️ Stosha Mountains Begins.

# %% [markdown]
# <hr>

# %% [markdown]
# <p><img src="https://github.com/heyrobin/DS-ML-2021-Kaggle-Survey/blob/main/Bay.gif?raw=true"></p>

# %% [markdown]
# <div class="chapters"> Chapter 4 :  Experience <a id="4"></a>

# %% [markdown]
# <div class="section">4.1 Experience of ML <a id="4.1"></a>

# %%
A = sns.countplot(x= df['Q15'],
                order = df['Q15'].value_counts().index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)   
A.patches[idx_tallest].set_facecolor(colors[7]) 



plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Experience', weight='semibold', fontname = 'Georgia')
plt.suptitle('Experiences of Warriors in Arts of ML', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0])

plt.xticks(rotation=90);

# %% [markdown]
# <div class="thing">⚔️  There are lots of under 1 year with ML experience followed by years.

# %% [markdown]
# <div class="section">4.2 Experience of Coding <a id="4.2"></a>

# %%
A = sns.countplot(x= df['Q6'],
                order = df['Q6'].value_counts().index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)   
    
A.patches[idx_tallest].set_facecolor(colors[7]) 

from textwrap import wrap
labels = [ '\n'.join(wrap(l, 8)) for l in df['Q6'].unique()]
plt.tick_params(axis='x', which='major', labelsize=10)
A.set_xticklabels(labels, fontsize=10)

plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.xlabel('Coding Years', weight='semibold', fontname = 'Georgia')
plt.suptitle('Coding Skill Experience of Warriors', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing">⚔️  The coding experience of are highest between 5-10 Years.

# %% [markdown]
# <hr>

# %% [markdown]
# <p><img src="https://github.com/heyrobin/DS-ML-2021-Kaggle-Survey/blob/main/Stosha%20mountains.gif?raw=true"></p>

# %% [markdown]
# <div class="Banner_Intro2"> After crossing the roaring waves of Nitia Bay through a ship we heard whispers and info about years of experience in ML and coding. The Journey of ⛰️ Stosha Mountains Begins next.

# %% [markdown]
# <div class="chapters"> Chapter 5 : Platforms/ Battleground <a id="5"></a>

# %% [markdown]
# <div class="section">5.1 Notebooks <a id="5.1"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q10')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Notebook Products', weight='semibold', fontname = 'Georgia')
plt.suptitle('Notebook of Warrior', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

#answergot / answergot.sum() *100

# %% [markdown]
# <div class="thing">⚔️  Over 25.9% of Warriors use Colab Notebooks and 25.2% using Kaggle Notebooks.

# %% [markdown]
# <div class="section">5.2 Cloud Computing Platforms <a id="5.2"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q27_A')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
    
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])


plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Cloud Computing Platforms', weight='semibold', fontname = 'Georgia')
plt.suptitle('Magic of Cloud Computing', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

#answergot / answergot.sum() *100

# %% [markdown]
# <div class="thing">⚔️  The most popular used cloud platforms are Amazon Web Services (14%), Google Cloud Platform (12%) and Microsoft Azure (9%).

# %% [markdown]
# <div class="section">5.3 Public Sharing Platforms <a id="5.3"></a>

# %%
#data tangle
fsize = (16, 9)
a = df.filter(regex = 'Q39')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

#plot
plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

#patch
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])

#lables
plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Sharing platforms', weight='semibold', fontname = 'Georgia')
plt.suptitle('Sharing Wisdom Camp Platform', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

#answergot / answergot.sum() *100

# %% [markdown]
# <div class="thing">⚔️  30.9% of them share it on Github , 20.7% in Kaggle and 21.4% do not share my work publicly.

# %% [markdown]
# <div class="section">5.4 Online Reporting Media and Sources <a id="5.4"></a>

# %%
#data tangle
fsize = (16, 9)
a = df.filter(regex = 'Q42')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)

#plot
plt.figure(figsize = fsize)
A = sns.barplot(data = answergot,
                 x='count',
                 y= answergot.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)

#patch
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)    
idx_tallest = np.argmax(patch_h)       
A.patches[idx_tallest].set_facecolor(colors[7])

#lables
plt.xlabel('Count', weight='semibold', fontname = 'Georgia')
plt.ylabel('Platforms', weight='semibold', fontname = 'Georgia')
plt.suptitle('Warriors Favourit place to learn', fontname = 'Georgia', weight='bold')
A.bar_label(A.containers[0]);

#(answergot / answergot.sum() *100)

# %% [markdown]
# <div class="thing">⚔️  The favourite place to learn and read reports: Kaggle 21.9%, YouTube 20% and Blogs 15.3%.

# %% [markdown]
# <div class="section">5.5 Python vs R <a id="5.5"></a>

# %%
fsize = (16, 9)
a = df.filter(regex = 'Q7')
answer_desc = a.describe()
answergot = answer_desc.loc[['top', 'count']].T
answergot = answergot.set_index('top')
answergot = answergot.sort_values(by="count", ascending = False)


Df = answergot.iloc[[0,3],:]
    
plt.figure(figsize = fsize)
A = sns.barplot(data = Df,
                 y='count',
                 x= Df.index,
              color=colors[4],
              edgecolor='white',
              linewidth=1.5,
              saturation=1.5)
patch_h = []    
for patch in A.patches:
    reading = patch.get_height()
    patch_h.append(reading)
    
idx_tallest = np.argmax(patch_h)   
    
A.patches[idx_tallest].set_facecolor(colors[7])      


#image
implot('Roman',1,12,0.4)
implot('Samurai',0,12,0.6) 
    
    
plt.xlabel('Languages', weight='semibold', fontname = 'Georgia')
plt.ylabel('Count', weight='semibold', fontname = 'Georgia')
plt.suptitle('Python Vs R', fontname = 'Georgia', weight='bold')
    
A.bar_label(A.containers[0]);

# %% [markdown]
# <div class="thing">⚔️  The Python is the clear winner here in terms of data scientists favourit language to use.

# %% [markdown]
# <div class="Banner_Intro2"> In Rosha Castle King Rosha told us about Cloud Computing, Public Sharing platforms, Media Sources and Notebooks. We also figure out the great battle between the python and R. We almost reached our destination and we got all the ideas of being a data scientist.

# %% [markdown]
# <hr>

# %% [markdown]
# <p><img src="https://github.com/heyrobin/DS-ML-2021-Kaggle-Survey/blob/main/Sislion%20Kingdom.gif?raw=true"></p>

# %% [markdown]
# <div class="chapters"> Final Chapter : Destination/ Conclusion <a id="6"></a>

# %% [markdown]
#  <div class="Banner_Intro2"> <b>  <div class="chapters">📔 Narrator</div><br><br><br>I Still have a lots of work to do on this data. But the deadline is up but I Will continously update more on this notebook "Legend of Keg". Would love to know your oppinion on my notebooks and viz your feedback, knowledge suggestions will push me forward for new tasks.

# %% [markdown]
# <hr>

# %% [markdown]
# <div class="Banner_Intro"> See Ya! Its Not the end
