# %% [markdown]
# **Analytics Competition**
#
# 2021 Kaggle Machine Learning & Data Science Survey
# The most comprehensive dataset available on the state of ML and data science
#
# Competition Steps:
#
# * Import the required Python libraries
# * Load and explore data (Exploration Data) (EDA)
# * Cleaning Data / Null Values
# * Data analysis, Visualization and histograms

# %% [markdown]
# # Import the required Python libraries

# %%
import numpy as np 
import pandas as pd 

import seaborn as sns
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly.express as px

import matplotlib.pyplot as plt
import dateutil
from copy import deepcopy

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Exploring Data (EDA) 📊

# %%
survey_data = pd.read_csv('/kaggle/input/kaggle-survey-2021/kaggle_survey_2021_responses.csv', low_memory=False)

survey_data

# %%
# Get Total (rows, cols) using shape

survey_data.shape

# %% [markdown]
# # Cleaning Data / Null Values 📄

# %%
# Check null values
null_values = survey_data.isnull().sum()
null_values

# %% [markdown]
# # Data Analysis, Visualization & Histograms

# %%
plt.figure(figsize=(18,8))
ax = sns.countplot(survey_data['Q5'], order = survey_data['Q5'].value_counts().iloc[:15].index)
ax.set(title = 'Current Role', xlabel = '', ylabel = '')
for item in ax.get_xticklabels():
    item.set_rotation(90)
plt.show()

# %% [markdown]
# # **Data Scientists Age**

# %%
data_scientist_age = survey_data[survey_data['Q5']=='Data Scientist']
fig = px.histogram(data_scientist_age, x="Q1", title = 'Data Scientists Age').update_xaxes(categoryorder='total descending')
fig.show()

# %% [markdown]
# # Data Scientists Gender

# %%
data_scientist_gender = survey_data[survey_data['Q5']=='Data Scientist']
fig = px.histogram(data_scientist_gender, x="Q2", title = 'Data Scientists Gender').update_xaxes(categoryorder='total descending')
fig.show()

# %% [markdown]
# 🎩  Men Win ^_^"

# %% [markdown]
# # Data Scientists Country 🏁

# %%
data_scientist_country = survey_data[survey_data['Q5']=='Data Scientist']
fig = px.histogram(data_scientist_country, x="Q3", title = 'Data Scientists Country').update_xaxes(categoryorder='total descending')
fig.show()

# %% [markdown]
# India   No.1 Greetings to India :)
#
# ![](data:image/png;base64,...)

# %% [markdown]
# # Data Scientists Education

# %%
data_scientist_cert = survey_data[survey_data['Q5']=='Data Scientist']
fig = px.histogram(data_scientist_cert, x="Q4", title = 'Data Scientists Education').update_xaxes(categoryorder='total descending')
fig.show()

# %%
df_cert_percent = survey_data['Q4'].value_counts()
fig = px.pie(df_cert_percent, values=df_cert_percent.values, names=df_cert_percent.index, title='Data Scientists Education')
fig.show()

# %% [markdown]
# 🎓 I have Bachelor degree ^_^

# %% [markdown]
# Please consider voting if you find it useful  👍
#
# Thanks
