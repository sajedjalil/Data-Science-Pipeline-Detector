# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv")

# %%
df.head()

# %%
df['Q3'].unique()

# %% [markdown]
# # America

# %%
df=df.loc[df['Q3']=='United States of America']

# %%
df.head()

# %%
df.reset_index(drop=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Q2. What is your gender?

# %%
labels=df['Q2'].value_counts().index
total=df['Q2'].value_counts()
plt.gcf().set_size_inches(18,9)
plt.pie(total,labels=labels,wedgeprops={'edgecolor':'black'},autopct="%1.1f%%",explode=[0,0,0,0,0.2])
plt.show()

# %%
df['Q4'].unique()

# %% [markdown]
# # Q4. What is the highest level of formal education that you have attained or plan to attain within the next 2 years?

# %%
index=df['Q4'].value_counts().index
value=df['Q4'].value_counts()
plt.barh(index,value,color="#650021")
plt.show()

# %% [markdown]
# # Q5. Select the title most similar to your current role (or most recent title if retired):

# %%
index=df['Q5'].value_counts().index
value=df['Q5'].value_counts()
bar=plt.barh(index,value,color="#929591")
bar[1].set_color("#01153E")
plt.show()

# %% [markdown]
# # Q6. For how many years have you been writing code and/or programming?

# %%
index=df['Q6'].value_counts().index
value=df['Q6'].value_counts()
sns.barplot(x =index,y =value)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q7. What programming languages do you use on a regular basis?

# %%
Q7={}
for i in range(1,13):
    Q7.update(dict(df[f"Q7_Part_{i}"].value_counts()))
Q7=pd.DataFrame(Q7.items(), columns = ['language', 'counts'])

# %%
sns.barplot(x=Q7['language'],y=Q7['counts'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q8. What programming language would you recommend an aspiring data scientist to learn first?

# %%
labels=df['Q8'].value_counts().index
total=df['Q8'].value_counts()
sns.barplot(x=labels,y=total)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q9. Which of the following integrated development environments (IDE's) do you use on a regular basis?

# %%
Q9={}
for i in range(1,12):
    Q9.update(dict(df[f"Q9_Part_{i}"].value_counts()))
Q9=pd.DataFrame(Q9.items(),columns=["IDEs","counts"])

# %%
plt.barh(Q9['IDEs'],Q9['counts'])
plt.style.use("classic")
plt.show()

# %% [markdown]
# # Q10. Which of the following hosted notebook products do you use on a regular basis?

# %%
Q10={}
for i in range(1,17):
    Q10.update(dict(df[f"Q10_Part_{i}"].value_counts()))
Q10=pd.DataFrame(Q10.items(),columns=['Notebook Prod.','counts'])

# %%
sns.barplot(x=Q10['Notebook Prod.'],y=Q10['counts'])
plt.style.use("seaborn-pastel")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q11. What type of computing platform do you use most often for your data science projects?

# %%
labels=df['Q11'].value_counts().index
total=df['Q11'].value_counts()
plt.figure(figsize=(12,6))
plt.style.use("classic")
plt.pie(total,labels=labels,explode=[0.1,0,0,0,0,0])
plt.show()

# %% [markdown]
# # Q12. Which types of specialized hardware do you use on a regular basis?

# %%
Q12={}
for i in range(1,6):
    Q12.update(dict(df[f"Q12_Part_{i}"].value_counts()))
Q12=pd.DataFrame(Q12.items(),columns=["hardware","counts"])

# %%
plt.pie(Q12['counts'],labels=Q12['hardware'],autopct="%1.1f%%",explode=[0,0,0,0.4,0])
plt.show()

# %% [markdown]
# # Q13. Approximately how many times have you used a TPU (tensor processing unit)?

# %%
index=df['Q13'].value_counts().index
value=df['Q13'].value_counts()
plt.style.use('dark_background')
plt.bar(index,value)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q14. What data visualization libraries or tools do you use on a regular basis?

# %%
Q14={}
for i in range(1,12):
    Q14.update(dict(df[f"Q14_Part_{i}"].value_counts()))
Q14=pd.DataFrame(Q14.items(),columns=["tools","counts"])

# %%
color=['#F5DEB3']
plt.bar(Q14["tools"],Q14['counts'],color=color)
plt.xticks(rotation=90)
plt.xlabel("Libraries or tools")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# # Q15. For how many years have you used machine learning methods?

# %%
index=df['Q15'].value_counts().index
value=df['Q15'].value_counts()
plt.style.use("seaborn-white")
plt.barh(index,value)
plt.show()

# %% [markdown]
# # Q16.Which of the following machine learning frameworks do you use on a regular basis?

# %%
Q16={}
for i in range(1,18):
    Q16.update(dict(df[f"Q16_Part_{i}"].value_counts()))
Q16=pd.DataFrame(Q16.items(),columns=["Frameworks","Count"])

# %%
plt.barh(Q16["Frameworks"],Q16["Count"],color="#D2691E")
plt.style.use('ggplot')
plt.xlabel("Count")
plt.ylabel("Frameworks")
plt.show()

# %% [markdown]
# # Q17. Which of the following ML algorithms do you use on a regular basis?

# %%
Q17={}
for i in range(1,12):
    Q17.update(dict(df[f"Q17_Part_{i}"].value_counts()))
Q17=pd.DataFrame(Q17.items(),columns=['algorithms','count'])

# %%
plt.barh(Q17['algorithms'],Q17['count'])
plt.show()

# %% [markdown]
# # Q18. Which categories of computer vision methods do you use on a regular basis?

# %%
Q18={}
for i in range(1,7):
    Q18.update(dict(df[f"Q18_Part_{i}"].value_counts()))
Q18=pd.DataFrame(Q18.items(),columns=["Methods","Count"])

# %%
plt.style.use("seaborn-darkgrid")
plt.pie(Q18['Count'],labels=Q18['Methods'],autopct="%1.1f%%")
plt.show()

# %% [markdown]
# # Q19. Which of the following natural language processing (NLP) methods do you use on a regular basis?

# %%
Q19={}
for i in range(1,6):
    Q19.update(dict(df[f"Q19_Part_{i}"].value_counts()))
Q19=pd.DataFrame(Q19.items(),columns=["NLP methods","Count"])

# %%
plt.barh(Q19["NLP methods"],Q19["Count"],color="#800000")
plt.show()

# %% [markdown]
# # Q20. In what industry is your current employer/contract (or your most recent employer if retired)?

# %%
index=df['Q20'].value_counts().index
values=df['Q20'].value_counts()
plt.style.use("seaborn")
plt.barh(index,values)
plt.show()

# %% [markdown]
# # Q21. What is the size of the company where you are employed?

# %%
labels=df['Q21'].value_counts().index
total=df['Q21'].value_counts()
plt.style.use("fivethirtyeight")
plt.pie(total,labels=labels,autopct="%1.1f%%",shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # Q22. Approximately how many individuals are responsible for data science workloads at your place of business?

# %%
index=df['Q22'].value_counts().index
values=df['Q22'].value_counts()
ax=sns.barplot(x=index,y=values)
ax.grid(False)
plt.show()

# %% [markdown]
# # Q23. Does your current employer incorporate machine learning methods into their business?

# %%
index=df['Q23'].value_counts().index
values=df['Q23'].value_counts()
plt.style.use("bmh")
plt.barh(index,values)
plt.show()

# %% [markdown]
# # Q24. Select any activities that make up an important part of your role at work:

# %%
Q24={}
for i in range(1,8):
    Q24.update(dict(df[f"Q24_Part_{i}"].value_counts()))
Q24=pd.DataFrame(Q24.items(),columns=["activities","count"])

# %%
plt.pie(Q24["count"],labels=Q24["activities"],autopct="%1.1f%%",shadow=True,explode=[0.1,0,0,0,0,0,0])
plt.show()

# %% [markdown]
# # Q25.What is your current yearly compensation (approximate $USD)?

# %%
plt.style.use("ggplot")
df['Q25'].value_counts().plot(color="#800000")
plt.xlabel("$USD")
plt.show()

# %% [markdown]
# # India

# %%
df=pd.read_csv("../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv")
df2=df.loc[df['Q3']=='India']

# %%
df2.head()

# %%
df2.reset_index(drop=True)

# %% [markdown]
# # Q2. What is your gender?

# %%
labels=df2['Q2'].value_counts().index
total=df2['Q2'].value_counts()
plt.gcf().set_size_inches(18,9)
plt.pie(total,labels=labels,wedgeprops={'edgecolor':'black'},autopct="%1.1f%%",explode=[0,0,0.2,0.4,0])
plt.style.use("fivethirtyeight")
plt.show()

# %% [markdown]
# # Q4. What is the highest level of formal education that you have attained or plan to attain within the next 2 years?

# %%
index=df2['Q4'].value_counts().index
value=df2['Q4'].value_counts()
plt.barh(index,value,color="#650021")
plt.show()

# %% [markdown]
# # Q5. Select the title most similar to your current role (or most recent title if retired):

# %%
index=df2['Q5'].value_counts().index
value=df2['Q5'].value_counts()
bar=plt.barh(index,value,color="#929591")
bar[1].set_color("#01153E")
plt.show()

# %% [markdown]
# # Q6. For how many years have you been writing code and/or programming?

# %%
index=df2['Q6'].value_counts().index
value=df2['Q6'].value_counts()
sns.barplot(x =index,y =value)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q7. What programming languages do you use on a regular basis?

# %%
Q7={}
for i in range(1,13):
    Q7.update(dict(df2[f"Q7_Part_{i}"].value_counts()))
Q7=pd.DataFrame(Q7.items(), columns = ['language', 'counts'])

# %%
sns.barplot(x=Q7['language'],y=Q7['counts'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q8. What programming language would you recommend an aspiring data scientist to learn first?

# %%
labels=df2['Q8'].value_counts().index
total=df2['Q8'].value_counts()
sns.barplot(x=labels,y=total)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q9. Which of the following integrated development environments (IDE's) do you use on a regular basis?

# %%
Q9={}
for i in range(1,12):
    Q9.update(dict(df2[f"Q9_Part_{i}"].value_counts()))
Q9=pd.DataFrame(Q9.items(),columns=["IDEs","counts"])

# %%
plt.barh(Q9['IDEs'],Q9['counts'])
plt.style.use("classic")
plt.show()

# %% [markdown]
# # Q10. Which of the following hosted notebook products do you use on a regular basis?

# %%
Q10={}
for i in range(1,17):
    Q10.update(dict(df2[f"Q10_Part_{i}"].value_counts()))
Q10=pd.DataFrame(Q10.items(),columns=['Notebook Prod.','counts'])

# %%
sns.barplot(x=Q10['Notebook Prod.'],y=Q10['counts'])
plt.style.use("seaborn-pastel")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q11. What type of computing platform do you use most often for your data science projects?

# %%
labels=df2['Q11'].value_counts().index
total=df2['Q11'].value_counts()
plt.figure(figsize=(12,6))
plt.style.use("classic")
plt.pie(total,labels=labels,explode=[0.1,0,0,0,0,0])
plt.show()

# %% [markdown]
# # Q12. Which types of specialized hardware do you use on a regular basis?

# %%
Q12={}
for i in range(1,6):
    Q12.update(dict(df2[f"Q12_Part_{i}"].value_counts()))
Q12=pd.DataFrame(Q12.items(),columns=["hardware","counts"])

# %%
plt.pie(Q12['counts'],labels=Q12['hardware'],autopct="%1.1f%%",explode=[0,0,0,0.4,0])
plt.show()

# %% [markdown]
# # Q13. Approximately how many times have you used a TPU (tensor processing unit)?

# %%
index=df2['Q13'].value_counts().index
value=df2['Q13'].value_counts()
plt.style.use('dark_background')
plt.bar(index,value)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q14. What data visualization libraries or tools do you use on a regular basis?

# %%
Q14={}
for i in range(1,12):
    Q14.update(dict(df2[f"Q14_Part_{i}"].value_counts()))
Q14=pd.DataFrame(Q14.items(),columns=["tools","counts"])

# %%
color=['#F5DEB3']
plt.bar(Q14["tools"],Q14['counts'],color=color)
plt.xticks(rotation=90)
plt.xlabel("Libraries or tools")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# # Q15. For how many years have you used machine learning methods?

# %%
index=df2['Q15'].value_counts().index
value=df2['Q15'].value_counts()
plt.style.use("seaborn-white")
plt.barh(index,value)
plt.show()

# %% [markdown]
# # Q16. Which of the following machine learning frameworks do you use on a regular basis?

# %%
Q16={}
for i in range(1,18):
    Q16.update(dict(df2[f"Q16_Part_{i}"].value_counts()))
Q16=pd.DataFrame(Q16.items(),columns=["Frameworks","Count"])

# %%
plt.barh(Q16["Frameworks"],Q16["Count"],color="#D2691E")
plt.style.use('ggplot')
plt.xlabel("Count")
plt.ylabel("Frameworks")
plt.show()

# %% [markdown]
# # Q17. Which of the following ML algorithms do you use on a regular basis?

# %%
Q17={}
for i in range(1,12):
    Q17.update(dict(df2[f"Q17_Part_{i}"].value_counts()))
Q17=pd.DataFrame(Q17.items(),columns=['algorithms','count'])

# %%
plt.barh(Q17['algorithms'],Q17['count'])
plt.show()

# %% [markdown]
# # Q18. Which categories of computer vision methods do you use on a regular basis?

# %%
Q18={}
for i in range(1,7):
    Q18.update(dict(df2[f"Q18_Part_{i}"].value_counts()))
Q18=pd.DataFrame(Q18.items(),columns=["Methods","Count"])

# %%
plt.style.use("seaborn-darkgrid")
plt.pie(Q18['Count'],labels=Q18['Methods'],autopct="%1.1f%%")
plt.show()

# %% [markdown]
# # Q19. Which of the following natural language processing (NLP) methods do you use on a regular basis?

# %%
Q19={}
for i in range(1,6):
    Q19.update(dict(df2[f"Q19_Part_{i}"].value_counts()))
Q19=pd.DataFrame(Q19.items(),columns=["NLP methods","Count"])

# %%
plt.barh(Q19["NLP methods"],Q19["Count"],color="#800000")
plt.show()

# %% [markdown]
# # Q20. In what industry is your current employer/contract (or your most recent employer if retired)?

# %%
index=df2['Q20'].value_counts().index
values=df2['Q20'].value_counts()
plt.style.use("seaborn")
plt.barh(index,values)
plt.show()

# %% [markdown]
# # Q21. What is the size of the company where you are employed?

# %%
labels=df2['Q21'].value_counts().index
total=df2['Q21'].value_counts()
plt.style.use("fivethirtyeight")
plt.pie(total,labels=labels,autopct="%1.1f%%",shadow=True,startangle=90)
plt.show()

# %% [markdown]
# # Q22. Approximately how many individuals are responsible for data science workloads at your place of business?

# %%
index=df2['Q22'].value_counts().index
values=df2['Q22'].value_counts()
ax=sns.barplot(x=index,y=values)
ax.grid(False)
plt.show()

# %% [markdown]
# # Q23. Does your current employer incorporate machine learning methods into their business?

# %%
index=df2['Q23'].value_counts().index
values=df2['Q23'].value_counts()
plt.style.use("bmh")
plt.barh(index,values)
plt.show()

# %% [markdown]
# # Q24. Select any activities that make up an important part of your role at work:

# %%
Q24={}
for i in range(1,8):
    Q24.update(dict(df2[f"Q24_Part_{i}"].value_counts()))
Q24=pd.DataFrame(Q24.items(),columns=["activities","count"])

# %%
plt.pie(Q24["count"],labels=Q24["activities"],autopct="%1.1f%%",shadow=True,explode=[0.1,0,0,0,0,0,0])
plt.show()

# %% [markdown]
# # Q25. What is your current yearly compensation (approximate $USD)?

# %%
plt.style.use("ggplot")
df2['Q25'].value_counts().plot(color="#800000")
plt.xlabel("$USD")
plt.show()

# %% [markdown]
# # Conclusions:-
#
# 1.There is not a lot of difference in kaggle users on the basis of gender. 3% men are using kaggle more in America.
#
# 2.Highest level of formal education is master's degree in America whereas bachelor's degree in India.
#   **It tells us various points:-**
#    1.America is a rich country due to which people in America pursue study at a very high level.
#    2.America has a large number of students studying or pursued Master's degree and Indian students are also going abroad for their masters.
#
# 3.A large number of people are using Kaggle from india as we all know that kaggle is a very famous free platform to learn data science and indians have less platforms to learn than America that's why a large number of people from India especially students are using kaggle.
#
# 4.In both countries, the most number of people are writing codes or programming from 1-3 years but in America there are more people who are writing codes for 20 years whereas least in India means U.S people have more coding skills than India.
#
# 5.In both countries python is used as a programming language on the regular basis as we know its an easy language with simple syntax and included with vast libraries.
#
# 6.Python is the most recommeded language for aspiring data science for both countries and R comes after that as it is little more complex than python.
#
# 7.In both countries jupyter notebook is the most using IDE as it is simple and easy to use connecting to our PC's Kernal and we can use all libraries manually according to our need after installing with pip in our PC.
#
# 8.Collab notebooks are more used in India and Kaggle notebooks are used little more in America.
#
# 9.Laptops are more frequently used in India for data science projects than America.
#
# 10.The use of specialized hardwares(such as nividia GPU's or AWS) on a regular basis in both countries is mostly same.
#
# 11.**TPU(Tensor Processing Unit) is an AI accelerator application-specific integrated circuit developed by Google specifically for neural network machine learning, particularly using Google's own TensorFlow software.**
# In both countries it is used as never.
#
# 12.Matplotlib and seaborn are the major libraries used for data visulization in both countries and matplotlib at max. rate as it is easy to use and has a large number of editing options.
#
# 13.Machine learning mathods experience is very less in both the countries which is quite shocking and even a large number of people are not using machine learning methods as well.
#
# 14.Scikit-Learn and Tensorflow are the major machine-learning frameworks used on a regular basis.
#
# 15.Linear and Logistic regression are the most used ML algorithms as when we start to learn Machine learning we learn these at our first priority and as we know from **point 13** there is lack of experience in ML in both countries due to which they might be using Linear and
# logistic at max.
#
# 16.The use of computer vision and NLP methods on a regular basis is mostly same in both.
#
# 17.The most are related to Computer and Technology field and the size of the company where they are employed is almost same in both as in all countries the companies have almost the same methods or rules to run a company.
#
# 18.The data science workload at their place of business seems to be more in America.
#
# 19.In both countries they don't even know that whether their current employer is incorporate machine learning methods into their business.
#
# 20.Both countries have the same activities that makeup an important part of their work.
#
# 21.Max. people in America have more amount in yearly compensation as America is developed and very rich country than India.
