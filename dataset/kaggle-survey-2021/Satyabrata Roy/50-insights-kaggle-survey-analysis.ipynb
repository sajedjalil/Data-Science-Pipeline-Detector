# %% [markdown]
# <center><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1NLM83Sw3V3jzNfeVD4AsC4BiYtytIV6d" align="center" hspace="10px" vspace="10px" width="900" height="1100" ></center>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="300" height="600"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:50px;color:  #6468e8">Hello Kagglers !!</li>
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;color:  #5cbeff">This Survey is about Us.</li>
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;color:  #ff6f5c">42 Questions</li>
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;color:  #ffa05c">25,973 Records</li>
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;color:  #27e85b">50+ Insights</li>
# </ul>

# %% [markdown]
# <ul style="list-style-type:none; text-align: center;">
#     <li style="font-family:Microsoft JhengHei UI Light;font-size:20px;color: #6468e8">To See all the <b>imported libraries</b>, Click On Show <b>hidden code</b></li>
# </ul>

# %%
# import all necesary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches
# %matplotlib inline
import seaborn as sns
import calendar
import plotly as pt
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from pylab import *
import matplotlib.patheffects as PathEffects

import descartes
import geopandas as gpd
from Levenshtein import distance
from itertools import product
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from scipy.spatial.distance import pdist, squareform
from shapely.geometry import Point, Polygon

import geoplot
from geopy.geocoders import Nominatim

import warnings
warnings.filterwarnings('ignore')


plt.rcParams['font.family'] = "Microsoft JhengHei UI Light"
plt.rcParams['font.serif'] = ["Microsoft JhengHei UI Light"]

# %% [markdown]
# <center>
#     <img src="https://media.giphy.com/media/4JU7XEjnSjW9qH5YTc/giphy.gif" />
# </center>

# %%
df = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')

# %%
df.shape

# %% [markdown]
# <ul style="list-style-type:none; text-align: center;">
#     <li style="font-family:Microsoft JhengHei UI Light;font-size:20px;color: #6468e8">We've wrote a <b>Customized Bar Plot </b>, Click On Show <b>hidden code</b></li>
# </ul>

# %%
def bar_plot(df, x, y, color, get_width, get_x, y_lim, rotation, title, xlabel, ylabel, annot_size, xticks_size, legend):
    fig, ax = plt.subplots(figsize = (12,7), dpi = 80)

#     cmap = cm.get_cmap(color, df.shape[0])   
#     clrs = [matplotlib.colors.rgb2hex(cmap(i)) for i in range(cmap.N)]

    ax=sns.barplot(x=df[x], y=df[y], palette=color)

    total = sum(df[y])
    for i in ax.patches:
        ax.text(i.get_x()+get_x, i.get_height()+get_width, \
                str(round((i.get_height()/total)*100, 2))+'%', fontsize=annot_size, weight='bold',
                    color='black')

    plt.title(title, size=20, weight='bold', color='#1b515e')
    plt.xlabel(xlabel, fontsize=15, weight='bold', color='#1b515e')
    plt.ylabel(ylabel, fontsize=15, weight='bold', color='#1b515e')
    plt.xticks(rotation=rotation, fontsize=xticks_size)
    plt.yticks(fontsize=12)
    plt.ylim(y_lim)

    for i in ['bottom', 'left']:
        ax.spines[i].set_color('white')
        ax.spines[i].set_linewidth(1.5)
    
    right_side = ax.spines["right"]
    right_side.set_visible(False)
    top_side = ax.spines["top"]
    top_side.set_visible(False)

    ax.set_axisbelow(True)
    ax.grid(color='#b2d6c7', linewidth=1, axis='y', alpha=.3)
#     MA = mpatches.Patch(color=clrs[0], label=legend)
#     ax.legend(handles=[MA], prop={'size': 10.5}, loc='best', borderpad=1, 
#               labelcolor=clrs[0], edgecolor='white');
    
    plt.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:40px;color:  #6468e8">Q1. What is your <span style="color:black;">Age</span> (# years) ?</li></strong>
# </ul>

# %%
q1_df = pd.DataFrame(df['Q1'].value_counts()).reset_index().rename(columns={'index':'Age-Group', 'Q1':'Users'})[:11]

bar_plot(q1_df, 'Age-Group', 'Users', 'rainbow', 100, -.05, (0, 6000), 0,
        '\nDifferent Age-Groups in Kaggle\n', '\nAge-Groups\n', '\nUsers\n',
        15, 13, 'Age-Group with Maximum\n no. of Users')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>1. Approximately <span style="font-weight: bold; color:#122ecc;">56%</span> of the total Kaggle Users are aged in between <span style="font-weight: bold; color:#122ecc;">18-29</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:40px;color:  #6468e8">Q2. What is your <span style="color:black;">Gender</span> ?</li></strong>
# </ul>

# %%
q2_df = pd.DataFrame(df['Q2'].value_counts()).reset_index().rename(columns={'index':'Gender', 'Q2':'Records'})[:5]

fig = px.pie(q2_df, values='Records', names='Gender', 
             color_discrete_sequence=px.colors.sequential.Purp)

fig.update_layout(
            title={'font_size':23, 'text': "<b>Overall Gender Distribution in Kaggle</b>",'y':0.95,'x':0.5,'xanchor': 'center','yanchor': 'top'}
)
fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>2. There are around <span style="font-weight: bold; color:#122ecc;">79% Male</span> Kaggle Users and <span style="font-weight: bold; color:#122ecc;">19% Female</span> Users.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:40px;color:  #6468e8">Q3. In which <span style="color:black;">Country</span> do you currently<span style="color:black;"> reside</span> ?</li></strong>
# </ul>

# %%
q3_df = pd.DataFrame(df['Q3'].value_counts()).reset_index().rename(columns={'index':'Country', 'Q3':'Users'})[:66]

q3_df['Percentage'] = [str(int(i))+'%' for i in round(q3_df['Users']*100/sum(q3_df['Users']))]

# %%
fig = px.choropleth(data_frame= q3_df, locations = 'Country', locationmode = 'country names', 
               color = 'Users', scope = 'world', color_continuous_scale=px.colors.sequential.Sunsetdark )

fig.update_geos(fitbounds="locations", visible=False)

fig.add_scattergeo(
  locations = q3_df['Country'][:5],
  text = q3_df['Percentage'][:5],
  featureidkey="properties.NAME_3",
  locationmode = 'country names',
  mode = 'text',
 textfont=dict(
        family='Arial, sans-serif',
        size=18,
        color="#fff200"
    )) 
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.update_layout(
            title={'font_size':25, 'text': "<b>Visualization of Kaggle Users across the World</b>",'y':0.95,'x':0.5,'xanchor': 'center','yanchor': 'top'}
)

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>3. In Kaggle around <span style="font-weight: bold; color:#122ecc;">29%</span> Users are from <span style="font-weight: bold; color:#122ecc;">INDIA</span>.</li>
#     <br>
#     <li>4. Approximately <span style="font-weight: bold; color:#122ecc;">10%</span> Kaggle Users are from <span style="font-weight: bold; color:#122ecc;">USA</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:40px;color:  #6468e8">Q4. What is the <span style="color:black;">highest</span> level of formal <span style="color:black;">education</span> ?</li></strong>
# </ul>

# %%
q4_df = pd.DataFrame(df['Q4'].value_counts()).reset_index().rename(columns={'index':'Education_level', 'Q4':'Records'})[:7]

fig = go.Figure(go.Funnelarea(
    text = q4_df['Education_level'],values = q4_df.Records,
    marker = {"colors": px.colors.sequential.Sunsetdark},aspectratio =0.7, baseratio=0.6
    ))
fig.update_layout(
            title={'font_size':23,'text': "<b>Kagglers from different Education Levels</b>",'y':0.92,'x':0.5,'xanchor': 'center','yanchor': 'top'}
)
fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>5. <span style="font-weight: bold; color:#122ecc;">39%</span> of the total Kaggle Users have Completed <span style="font-weight: bold; color:#122ecc;">Master's Degree</span>.</li>
#     <br>
#     <li>6. Around <span style="font-weight: bold; color:#122ecc;">38%</span> of the Kaggle Users have <span style="font-weight: bold; color:#122ecc;">Bachelor's Degree</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <ul style="list-style-type:none; text-align: center;">
#     <li style="font-family:Microsoft JhengHei UI Light;font-size:20px;color: #6468e8">We've wrote a <b>Customized Horizontal Bar Plot </b>, Click On Show <b>hidden code</b></li>
# </ul>

# %%
def horizontal_bar_plot(df, x, y, color, get_width, get_y, x_lim, x_spine, plot_size, title, xlabel, ylabel, annot_size, legend, legend_loc):
    fig, ax = plt.subplots(figsize = plot_size, dpi = 80)

#     cmap = cm.get_cmap(color, df.shape[0])   
#     clrs = [matplotlib.colors.rgb2hex(cmap(i)) for i in range(cmap.N)]

    ax=sns.barplot(x=df[x], y=df[y], palette=color)

    total = sum(df[x])
    for p in ax.patches:
        plt.text(p.get_width()+get_width, p.get_y()+get_y,
                '{:.2f}%'.format(p.get_width()*100/total),ha='center', va='center', fontsize=annot_size, color='black', weight='bold')

    plt.title(title, size=20, weight='bold', color='#1b515e')
    plt.xlabel(xlabel, fontsize=15, weight='bold', color='#1b515e')
    plt.ylabel(ylabel, fontsize=15, weight='bold', color='#1b515e')
    plt.xticks(fontsize=13)
    plt.yticks(fontsize=12)
    plt.xlim(x_lim)

    for i in ['top', 'left', 'right']:
        side = ax.spines[i]
        side.set_visible(False)

    ax.set_axisbelow(True)
    ax.spines['bottom'].set_bounds(x_spine)
    ax.grid(color='#b2d6c7', linewidth=1, axis='y', alpha=.3)

#     MA = mpatches.Patch(color=clrs[0], label=legend)
#     ax.legend(handles=[MA], prop={'size': 10.5}, loc=legend_loc, borderpad=1, 
#               labelcolor=[clrs[0]], edgecolor='white');

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:40px;color:  #6468e8">Q5. What is your <span style="color:black;">current role</span> ?</li></strong>
# </ul>

# %%
q5_df = pd.DataFrame(df['Q5'].value_counts()).reset_index().rename(columns={'index':'Current_role', 'Q5':'Users'})[:15]

horizontal_bar_plot(q5_df, 'Users', 'Current_role', 'winter', 600, 0.4, (0, 10000), 
                    (0, 10000), (10, 8), '\n Different Current Roles of Kaggle Users\n', 
                    '\nUsers', 'Current Roles', 15, 'Role with maximum Records', 'best')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>7. <span style="font-weight: bold; color:#122ecc;">Majority (26%)</span> of the Kaggle Users are Currently <span style="font-weight: bold; color:#122ecc;">Student</span>.</li>
#     <br>
#     <li>8. Around <span style="font-weight: bold; color:#122ecc;">14%</span> of the whole Kaggle Community are Currently working as a <span style="font-weight: bold; color:#122ecc;">Data Scientist</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:40px;color:  #6468e8">Q6. For how many <span style="color:black;">years</span>  have you been <span style="color:black;">programming</span> ?</li></strong>
# </ul>

# %%
q6_df = pd.DataFrame(df['Q6'].value_counts()).reset_index().rename(columns={'index':'experience_of_coding', 'Q6':'Records'})[:7]

fig = go.Figure(
    data=[go.Pie(values=q6_df['Records'], labels=q6_df['experience_of_coding'], hole=.5,
                marker = {"colors": ['#3700ff', '#8457ff', '#cd7cf2', '#fa70b3', '#ff5e86', '#ff1732', '#fff86e']})]
)

fig.update_layout(
            title={'font_size':23,'text': "<b>Experience in Coding</b>",'y':0.9,'x':0.43,'xanchor': 'center','yanchor': 'top'}
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>9. <span style="font-weight: bold; color:#122ecc;">Most (30%)</span> of the Kaggle Users have the <span style="font-weight: bold; color:#122ecc;">Coding Experience of (1-3) years</span>.</li>
#     <br>
#     <li>10. Around <span style="font-weight: bold; color:#122ecc;">22%</span> Users of the Kaggle Community have the coding experience of <span style="font-weight: bold; color:#122ecc;">less than 1 year</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:40px;color:  #6468e8">Q7. What <span style="color:black;">programming languages</span>  do you use on a <span style="color:black;">regular</span> basis ?</li></strong>
# </ul>

# %%
q7_df = df[df.columns[7:20]].describe().T.iloc[:, 2:].reset_index(drop=True)

bar_plot(q7_df, 'top', 'freq', 'cool', 500, -.05, (0, 25000), 0,
        '\nDifferent Programming Language used by the Kagglers\n', '\nProgramming Languages\n', 
         '\nUsers\n', 14, 13, 'Maximum Used Programming Language')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>11. From this Survey, we can observe that <span style="font-weight: bold; color:#122ecc;">around 33%</span> of the Kaggle Users use <span style="font-weight: bold; color:#122ecc;">Python</span> as a programming language on a regular basis.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q8. What <span style="color:black;">programming languages</span>  would you <span style="color:black;">recommend</span> an aspiring data scientist to learn first ?</li></strong>
# </ul>

# %%
q8_df = pd.DataFrame(df['Q8'].value_counts()).reset_index().rename(columns={'index':'Recomended_Language', 'Q8':'Records'})[:13]

fig = px.pie(q8_df, values='Records', names='Recomended_Language', 
             color_discrete_sequence=px.colors.sequential.Plotly3)

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(
            title={'font_size':18,'text': "<b>Recommended Programming Languages for Aspiring Data Scientist</b>",'y':0.95,'x':0.47,'xanchor': 'center','yanchor': 'top'}
)
fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>12. <span style="font-weight: bold; color:#122ecc;">Most (81%)</span> of the Kagglers recommend <span style="font-weight: bold; color:#122ecc;">Python</span> to the aspiring data scientist to learn first.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q9. Which <span style="color:black;">integrated development environments (IDE's)</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q9_df = df[df.columns[21:34]].describe().T.iloc[:, 2:].reset_index(drop=True)

q9_df['top'][0] = 'Jupyter'
q9_df['freq'][0] = q9_df['freq'][0] + q9_df['freq'][10]
q9_df.drop(10, inplace=True)


horizontal_bar_plot(q9_df, 'freq', 'top', 'spring', 1500, 0.4, (0, 25000), 
                    (0, 25000), (10, 8),'\n Different IDEs used by Kagglers\n', 
                    '\nUsers', 'IDEs', 15, 'Maximum used IDE', 'best')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>13. From the Survey, we can say that <span style="font-weight: bold; color:#122ecc;">majority (33%)</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Jupyter</span> as their <span style="font-weight: bold; color:#122ecc;">IDE</span> on a regular basis.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q10. Which <span style="color:black;">hosted notebook products</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q10_df = df[df.columns[34:51]].describe().T.iloc[:, 2:].reset_index(drop=True)

horizontal_bar_plot(q10_df, 'freq', 'top', 'gnuplot2', 1000, 0.4, (0, 14000), 
                    (0, 14000), (8, 8),'\n Different Hosted Notebooks used by Kagglers\n', 
                    '\nUsers', 'Hosted Notebooks', 14,'Role with maximum Records', 'best')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>14. From the above figure, it's clear that among the Kagglers, <span style="font-weight: bold; color:#122ecc;">Kaggle Notebook & Colab Notebook</span> are most <span style="font-weight: bold; color:#122ecc;">popular</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q11. What type of <span style="color:black;">computing platform</span>  do you use most often for your <span style="color:black;">data science projects</span> ?</li></strong>
# </ul>

# %%
q11_df = pd.DataFrame(df['Q11'].value_counts()).reset_index().rename(columns={'index':'Computing_Platform', 'Q11':'Records'})[:6]

fig = go.Figure(
    data=[go.Pie(values=q11_df['Records'], 
                 labels=q11_df['Computing_Platform'], 
                 pull=[0.2, 0, 0, 0, 0, 0],
                 marker = {"colors": ['#14a3ee', '#b4e6ee', '#fdf4b8', '#ff4f4e', '#ff8887', '#ffc0bf']}
                )]
)

fig.update_layout(
            title={'font_size':18, 'text': "<b>Different types of Computing Platforms used for Data Science Projects</b>",'y':0.95,'x':0.47,'xanchor': 'center','yanchor': 'top'}
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>15. <span style="font-weight: bold; color:#122ecc;">Majority (65%)</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Laptop</span> for their Data Science Projects.</li>
#     <br>
#     <li>16. <span style="font-weight: bold; color:#122ecc;">Around (10%)</span> Kaggle Users are using <span style="font-weight: bold; color:#122ecc;">Cloud Computing Platforms</span> for their Data Science Projects.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q12. What types of <span style="color:black;">specialized hardware</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q12_df = df[df.columns[52:58]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[
        go.Pie(values=q12_df['freq'], labels=q12_df['top'], 
               pull=[0.2, 0, 0, 0, 0.2, 0],
               marker = {"colors": ['#9a90e8', '#5d82de', '#40ff53','#2ee88e', '#95ff82', '#3ee6e0']})
    ])

fig.update_layout(
            title={'font_size':20, 'text': "<b>Different types of Specialized Hardwares regularly Used</b>",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'}
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>17. From the Survey, we are able to know that <span style="font-weight: bold; color:#122ecc;">around 30%</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">NVIDIA GPU</span> on a regular basis for their Data Science work.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q13. Approximately how many <span style="color:black;">times</span>  have you used a <span style="color:black;">TPU</span> (tensor processing unit) ?</li></strong>
# </ul>

# %%
q13_df = pd.DataFrame(df['Q13'].value_counts()).reset_index().rename(columns={'index':'TPU_Used', 'Q13':'Records'})[:5]

fig = go.Figure(
    data=[
        go.Pie(values=q13_df['Records'], labels=q13_df['TPU_Used'], hole=0.6,
              marker = {"colors": ['#ffff4d', '#ffab36', '#ff894a', '#ff513b', '#ed2626']})
    ])

fig.update_layout(
            title={'font_size':23, 'text': "<b>TPU Usage by Kagglers</b>",'y':0.9,'x':0.45,'xanchor': 'center','yanchor': 'top'}
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>18. The Survey shows that <span style="font-weight: bold; color:#122ecc;">majority (67%)</span> of the Kagglers have <span style="font-weight: bold; color:#122ecc;">never used TPU</span> for their work.</li>
#     <br>
#     <li>19. Around <span style="font-weight: bold; color:#122ecc;">14%</span> Kaggle Users have <span style="font-weight: bold; color:#122ecc;">used TPU 2-5 times</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q14. What <span style="color:black;">data visualization libraries</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q14_df = df[df.columns[59:71]].describe().T.iloc[:, 2:].reset_index(drop=True)

q14_df['top'][2] = 'Plotly'
q14_df['top'][3] = 'Ggplot'
q14_df['top'][9] = 'Folium'

bar_plot(q14_df, 'top', 'freq', 'bwr', 500, -.05, (0, 20000), 0,
        '\nDifferent Data Visualization Libraries\n used by the Kagglers\n', '\nData Visualization Libraries\n', 
         '\nUsers\n', 15, 12, 'Data Visualization Libraries\n with Maximum no. of Records')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>20. From the Survey, it's clear that <span style="font-weight: bold; color:#122ecc;">majority (35%)</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Matplotlib</span> for Data Visualization on a regular basis.</li>
#     <br>
#     <li>21. Apart from Matplotlib the <span style="font-weight: bold; color:#122ecc;">Seaborn</span> is also a popular library with <span style="font-weight: bold; color:#122ecc;">25%</span> Users in kaggle.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q15. For how many <span style="color:black;">years</span>  have you used <span style="color:black;">machine learning methods</span> ?</li></strong>
# </ul>

# %%
q15_df = pd.DataFrame(df['Q15'].value_counts()).reset_index().rename(columns={'index':'No_Years_Using_ML', 'Q15':'Users'})[:9]

q15_df['No_Years_Using_ML'][2] = 'I do not use ML methods'

horizontal_bar_plot(q15_df, 'Users', 'No_Years_Using_ML', 'plasma', 1000, 0.4, (0, 12000), 
                    (0, 12000), (10, 8), '\nNo. of Years Kagglers using ML\n', 
                    '\nUsers', 'No_Years_Using_ML\n', 15, 'Maximum Records', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>22. From the above plot, it seems that <span style="font-weight: bold; color:#122ecc;">majority (39%)</span> of the Kagglers are in the ML field for <span style="font-weight: bold; color:#122ecc;">less than 1 year</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q16. Which <span style="color:black;">machine learning frameworks</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q16_df = df[df.columns[72:90]].describe().T.iloc[:, 2:].reset_index(drop=True)

bar_plot(q16_df, 'top', 'freq', 'gist_ncar_r', 400, -.05, (0, 16000), 16,
        '\nDifferent Machine Learning Framework\n used by the Kagglers\n', '\nML Frameworks\n', 
         '\nUsers\n', 11, 10, 'ML Framework with maximum Users')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>23. From the Survey, we can conclude that <span style="font-weight: bold; color:#122ecc;">Scikit learn</span> is <span style="font-weight: bold; color:#122ecc;">most popular (25% Users)</span> Machine Learning Framework.</li>
#     <br>
#     <li>24. <span style="font-weight: bold; color:#122ecc;">TensorFlow</span> is <span style="font-weight: bold; color:#122ecc;">2nd most popular (17% Users)</span> Machine Learning Framework among Kagglers.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q17. Which <span style="color:black;">ML algorithms</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q17_df = df[df.columns[90:102]].describe().T.iloc[:, 2:].reset_index(drop=True)

for i in range(11):
    if '(' in q17_df['top'][i]:
        q17_df['top'][i] = q17_df['top'][i].split('(')[0] + '\n(' + q17_df['top'][i].split('(')[1]
        
horizontal_bar_plot(q17_df, 'freq', 'top', 'magma_r', 1200, 0.4, (0, 16000), 
                    (0, 16000), (8, 8),'\n Different ML algorithms used by Kagglers\n', 
                    '\nUsers', 'ML algorithms', 15, 'Maximum used ML algorithms', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>25. Our Survey says that Kagglers use <span style="font-weight: bold; color:#122ecc;">Linear Regression, Logistic Regression, Decision Tree, Random Forest </span> as Machine Learning Algorithm on a regular basis.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q18. Which categories of <span style="color:black;">computer vision methods</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q18_df = df[df.columns[102:109]].describe().T.iloc[:, 2:].reset_index(drop=True)

for i in range(5):
    q18_df['top'][i] = q18_df['top'][i].split('(')[0] + ' \n(' + q18_df['top'][i].split('(')[1]
    
horizontal_bar_plot(q18_df, 'freq', 'top', 'turbo', 500, 0.4, (0, 5000), 
                    (0, 5000), (6, 8),'\n Different Computer Vision methods\n used by Kagglers\n', 
                    '\nUsers', 'Computer Vision methods', 15, 'Maximum used Computer Vision methods', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>26. Our Survey says that among different computer vision methods, Kagglers mostly use <span style="font-weight: bold; color:#122ecc;">VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet</span> for Image classification and other general purpose networks.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q19. Which <span style="color:black;">NLP methods</span>  do you use on a regular basis ?</li></strong>
# </ul>

# %%
q19_df = df[df.columns[109:115]].describe().T.iloc[:, 2:].reset_index(drop=True)

for i in range(4):
    q19_df['top'][i] = q19_df['top'][i].split('(')[0] + ' \n(' + q19_df['top'][i].split('(')[1]
    
horizontal_bar_plot(q19_df, 'freq', 'top', 'inferno_r', 300, 0.4, (0, 4000), 
                    (0, 4000), (10, 8), '\n Different NLP methods used by Kagglers\n', 
                    '\nUsers', 'NLP methods\n', 15, 'Maximum used NLP methods', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>27. In NLP among various methods, Kagglers mostly use <span style="font-weight: bold; color:#122ecc;">
# GLoVe, fastText, word2vec</span> for Word embeddings/vectors.</li>
#     <br>
#     <li>28. The <span style="font-weight: bold; color:#122ecc;"> Transformer Language Model (GPT-3, BERT, XLnet)</span> are also getting popular among Kagglers.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q20. In what <span style="color:black;">industry</span>  is your current <span style="color:black;">employer/contract</span> ?</li></strong>
# </ul>

# %%
q20_df = pd.DataFrame(df['Q20'].value_counts()).reset_index().rename(columns={'index':'Current_Industry_domain', 'Q20':'Users'})[:18]


horizontal_bar_plot(q20_df, 'Users', 'Current_Industry_domain', 'rainbow_r', 350, 0.4, (0, 5000), 
                    (0, 5000), (8, 8), '\nKagglers from different Industries\n', 
                    '\nUsers', 'Industries\n', 14, 'Industry with Maximum Records', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>29. <span style="font-weight: bold; color:#122ecc;">Most (25%)</span> of the Kaggle Users are currently working in <span style="font-weight: bold; color:#122ecc;">computer technology-based industry</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q21. What is the <span style="color:black;">size</span> of the <span style="color:black;">company</span> where you are employed ?</li></strong>
# </ul>

# %%
q21_df = pd.DataFrame(df['Q21'].value_counts()).reset_index().rename(columns={'index':'Employee_Size', 'Q21':'Records'})[:5]

fig = px.pie(q21_df, values='Records', names='Employee_Size', 
             color_discrete_sequence=px.colors.sequential.Oryel)

fig.update_layout(
            title={'font_size':23, 'text': "<b>Company Sizes</b>",'y':0.97,'x':0.43,'xanchor': 'center','yanchor': 'top'}
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>30. <span style="font-weight: bold; color:#122ecc;">Majority (31%)</span> of the Kagglers are currently employed in companies with<span style="font-weight: bold; color:#122ecc;"> employee size equal to 0-49 </span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q22. Approximately how many <span style="color:black;">individuals</span> are <span style="color:black;">responsible</span> for data science workloads at your place of business ?</li></strong>
# </ul>

# %%
q22_df = pd.DataFrame(df['Q22'].value_counts()).reset_index().rename(columns={'index':'No_Employees_for_DS', 'Q22':'Records'})[:7]

fig = go.Figure(
    data=[
        go.Pie(values=q22_df['Records'], labels=q22_df['No_Employees_for_DS'], hole=0.4, pull=[0, 0.25, 0.35, 0, 0, 0, 0],
              marker = {"colors": ['#6b1cfb','#981cfd','#bf1cfd','#dd2bfd','#f246fe','#fc67fd','#fec3fe']})
    ])

fig.update_layout(
             annotations=[dict(text='<b>Data Science Team Size</b>', x=0.34, y=0.56, font_size=20, showarrow=False)]
)


fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>31. From the Survey study, we can see that <span style="font-weight: bold; color:#122ecc;">22%</span> Users of Kaggle community are currently working in such companies where the <span style="font-weight: bold; color:#122ecc;">Data Science Team-Size is more than 20</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q23. Does your current employer <span style="color:black;">incorporate ML methods</span> into their business ?</li></strong>
# </ul>

# %%
q23_df = pd.DataFrame(df['Q23'].value_counts()).reset_index().rename(columns={'index':'Incorporate_ML', 'Q23':'Users'})[:6]


for i in range(6):
    if '(' in q23_df['Incorporate_ML'][i]:
        q23_df['Incorporate_ML'][i] = q23_df['Incorporate_ML'][i].split('(')[0] + ' \n(' + q23_df['Incorporate_ML'][i].split('(')[1]
        
horizontal_bar_plot(q23_df, 'Users', 'Incorporate_ML', 'mako_r', 400, 0.4, (0, 5000), 
                    (0, 5000), (8, 8),'\nState of the Employers regarding ML Usage\n', 
                    '\nUsers', 'States\n', 15, 'State with Maximum Records', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>32. Regarding the incorporation of ML methods in business survey, we came to know that <span style="font-weight: bold; color:#122ecc;">≈ 17%</span> Users of Kaggle community <span style="font-weight: bold; color:#122ecc;">have well established ML methods (i.e., models in production for more than 2 years)</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q24. <span style="color:black;">Activities</span> that make up an important part of <span style="color:black;">your role</span> at work ?</li></strong>
# </ul>

# %%
q24_df = df[df.columns[119:127]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(go.Funnelarea(
    text = q24_df['top'],
    values = q24_df['freq'],
    marker = {"colors": px.colors.sequential.Oryel},
    aspectratio =0.7, baseratio=0.75
    ))

fig.update_layout(
            title={'font_size':18, 'text': "<b>Kaggler's different Activities that make up an important role at their work</b>",'y':0.92,'x':0.5,'xanchor': 'center','yanchor': 'top'}
)
fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:37px;color:  #6468e8">Q25. What is your current <span style="color:black;">yearly compensation</span> (approximate $USD) ?</li></strong>
# </ul>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insights:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>33. Based on the Survey, we can conclude that <span style="font-weight: bold; color:#122ecc;">majority (≈22%)</span> of the Kagglers are earning <span style="font-weight: bold; color:#122ecc;">0 - 999(USD)</span> as their yearly compensation.</li>
#     <br>
#     <li>34. There are <span style="font-weight: bold; color:#122ecc;">only 0.38%</span> Kagglers whose Yearly Compensation is <span style="font-weight: bold; color:#122ecc;"> greater than 1,000,000 USD</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q26. Approximately how much <span style="color:black;">money</span> have you/your team spent on <span style="color:black;">ML</span> and/or <span style="color:black;">cloud computing services</span> ?</li></strong>
# </ul>

# %%
q26_df = pd.DataFrame(df['Q26'].value_counts()).reset_index().rename(columns={'index':'Spent_Money_On_ML', 'Q26':'Records'})[:6]

for i in range(6):
    var = str(q26_df['Spent_Money_On_ML'][i]).replace('$', '')
    q26_df['Spent_Money_On_ML'][i] = var
    
fig = go.Figure(
    data=[
        go.Pie(values=q26_df['Records'], labels=q26_df['Spent_Money_On_ML'], pull=[0, 0, 0, 0, 0, 0.2],
              marker = {"colors": ['#FF1744', '#FF5252', '#ff7530', '#ffa245', '#50fa9d', '#7eedb0']})
    ])

fig.update_layout(
             annotations=[dict(text='<b>Spent Amount on ML/Cloud Services</b>', x=0.5, y=1.15, font_size=20, showarrow=False)]
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>35. The survey says that <span style="font-weight: bold; color:#122ecc;">6.7%</span> Users of the whole Kaggle community spend <span style="font-weight: bold; color:#122ecc;">1,00,000 or more USD</span> for ML and/or Cloud Computing related Services.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q27.A. Which <span style="color:black;">cloud computing platforms</span> do you use on a regular basis ?</li></strong>
# </ul>

# %%
q27_df = df[df.columns[129:141]].describe().T.iloc[:, 2:].reset_index(drop=True)

q27_df['top'][0] = 'AWS'
q27_df['top'][1] = 'Microsoft\nAzure'
q27_df['top'][2] = 'GCP'

for i in range(3, 10):
    q27_df['top'][i] = q27_df['top'][i].replace('Cloud', '')
    
q27_df['top'][3] = 'IBM\nor Red Hat'

bar_plot(q27_df, 'top', 'freq', 'seismic', 100, -.05, (0, 5000), 0,
        '\nPopularity of Different \nCloud Computing Platforms among Kagglers\n', '\nCloud Computing Platforms\n', 
         'Users\n', 14, 12, 'Most Popular \nCloud Computing Platform')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>36. From survey, we can see that <span style="font-weight: bold; color:#122ecc;">majority (≈25%)</span> Users of Kaggle use <span style="font-weight: bold; color:#122ecc;">Amazon Web Services (AWS)</span> on a regular basis as a Cloud Computing platform.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q27.B. Which <span style="color:black;">cloud computing platforms</span> do you hope to <span style="color:black;">become more familiar</span> with in the next 2 years ?</li></strong>
# </ul>

# %%
q27b_df = df[df.columns[268:280]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(go.Funnelarea(
    text = q27b_df['top'],
    values = q27b_df['freq'],
    marker = {"colors": px.colors.sequential.Plotly3},
    aspectratio =1, baseratio=0.5
    ))

fig.update_layout(
            title={'font_size':20, 'text': "<b>Cloud Platforms Kagglers willing to Explore</b>",'y':0.92,'x':0.5,'xanchor': 'center','yanchor': 'top'}
)
fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>37. From above plot we can see that <span style="font-weight: bold; color:#122ecc;">most</span> of the Kaggle Users are willing to get <span style="font-weight: bold; color:#122ecc;">familiar</span> with <span style="font-weight: bold; color:#122ecc;">Amazon Web Services(AWS) & Google Cloud Platform(GCP)</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q28. Which <span style="color:black;">cloud platforms</span>  that you are familiar with, has the <span style="color:black;">best developer experience</span> ?</li></strong>
# </ul>

# %%
q28_df = pd.DataFrame(df['Q28'].value_counts()).reset_index().rename(columns={'index':'Best_familiarized_Cloud_Platform', 'Q28':'Users'})[:13]

horizontal_bar_plot(q28_df, 'Users', 'Best_familiarized_Cloud_Platform', 'vlag', 80, 0.4, (0, 900), 
                    (0, 900), (6, 8),'\nCloud Platforms with \nBest Developer Experience among Kagglers\n', 
                    '\nUsers', 'Cloud Computing Platforms\n', 14, 'Most Popular Platform', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>38. From the Survey, we came to know that <span style="font-weight: bold; color:#122ecc;">majority (≈27%)</span> of the Kagglers prefers <span style="font-weight: bold; color:#122ecc;">AWS</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q29.A. Do you use any <span style="color:black;">cloud computing products</span>  on a regular basis ?</li></strong>
# </ul>

# %%
q29_df = df[df.columns[142:147]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[
        go.Pie(values=q29_df['freq'], labels=q29_df['top'], hole=0.8,
              marker = {"colors": ['#ffb13d', '#ff743d', '#d5ff3d', '#3dff47', '#fff700']})
    ])

fig.update_layout(
             annotations=[dict(text='<b>Regularly used Cloud Products by the Kagglers</b>', x=0.5, y=1.18, font_size=20, showarrow=False)]
)
fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>39. The Survey says that <span style="font-weight: bold; color:#122ecc;">≈30%</span> Users of Kaggle, use <span style="font-weight: bold; color:#122ecc;">Amazon Elastic Computing Cloud (EC2) </span> on a regular basis.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q29.B In the next 2 years, do you hope to <span style="color:black;">become more familiar</span> with any of these specific <span style="color:black;">cloud computing products</span> ?</li></strong>
# </ul>

# %%
q29b_df = df[df.columns[280:285]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[
        go.Pie(values=q29b_df['freq'], labels=q29b_df['top'], pull=[0, 0, 0.2],
              marker = {"colors": ['#ffb74b', '#ffd6a4', '#ceb1f2', '#a071ff', '#6f71f7']})
    ])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(
             annotations=[dict(text='<b>Cloud Products Kagglers Willing to Explore</b>', x=0.5, y=1.15, font_size=20, showarrow=False)],
             showlegend=False
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>40. From the above figure, it seems that <span style="font-weight: bold; color:#122ecc;">maximum (38%)</span> Kaggle Users are willing to learn <span style="font-weight: bold; color:#122ecc;">Google Cloud Compute Engine</span> in the next 2 years.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q30. Do you use any <span style="color:black;">data storage products</span> on a regular basis ?</li></strong>
# </ul>

# %%
q30_df = df[df.columns[147:155]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[
        go.Pie(values=q30_df['freq'], labels=q30_df['top'], hole=0.4, pull=[0, 0, 0.2, 0, 0, 0, 0, 0,],
              marker = {"colors": ['#00E676', '#69F0AE', '#64FFDA', '#CCFF90', '#6f71f7', '#B2FF59', '#B388FF', 'black']})
    ])

fig.update_layout(
             annotations=[dict(text='<b>Data Storage Services regularly Used by Kagglers</b>', x=0.5, y=1.1, font_size=20, showarrow=False)],
             margin = dict(t=0, l=0, r=0, b=0)
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>41. For <span style="font-weight: bold; color:#122ecc;">data storage service</span> around <span style="font-weight: bold; color:#122ecc;">25%</span> Kagglers use <span style="font-weight: bold; color:#122ecc;">AWS S3</span> on a regular basis.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q31.A. Do you use any <span style="color:black;">managed machine learning products</span> on a regular basis ?</li></strong>
# </ul>

# %%
q31_df = df[df.columns[155:165]].describe().T.iloc[:, 2:].reset_index(drop=True)

q31_df['top'][0] = 'Amazon\nSageMaker'
q31_df['top'][1] = 'Azure\nML Studio'
q31_df['top'][2] = 'Google\nCloud\nVertex AI'

bar_plot(q31_df, 'top', 'freq', 'autumn', 100, +.01, (0, 8000), 0,
        '\nRegularly Used Managed ML Products among Kagglers\n', '\nManaged ML Products\n', 
         'Users\n', 14, 11, 'Most Popular Managed ML Product')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>42. Approximately <span style="font-weight: bold; color:#122ecc;">9%</span> Kagglers use <span style="font-weight: bold; color:#122ecc;">AWS Sagemaker service</span> for managing their Machine learning works.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q31.B. In the next 2 years, do you hope to <span style="color:black;">become more familiar</span> with any of these <span style="color:black;">managed machine learning products</span> ?</li></strong>
# </ul>

# %%
q31b_df = df[df.columns[293:303]].describe().T.iloc[:, 2:].reset_index(drop=True)

q31b_df['top'][0] = 'Amazon\nSageMaker'
q31b_df['top'][1] = 'Azure\nML Studio'
q31b_df['top'][2] = 'Google\nCloud\nVertex AI'

bar_plot(q31b_df, 'top', 'freq', 'Wistia', 50, +.01, (0, 6000), 0,
        '\nManaged ML Products which Kagglers \nhope to become familiar with\n', '\nManaged ML Products\n', 
         'Users\n', 14, 11, 'Most Popular Managed ML Product')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>43. From our Survey, we can see <span style="font-weight: bold; color:#122ecc;">21%</span> Kaggle Users are willing to explore <span style="font-weight: bold; color:#122ecc;">Google Cloud Vertex AI</span> for managing their Machine learning works.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q32.A. Which <span style="color:black;">big data products</span> (relational databases, data warehouses, data lakes, or similar) do you use on a <span style="color:black;">regular basis</span> ?</li></strong>
# </ul>

# %%
q32_df = df[df.columns[165:186]].describe().T.iloc[:, 2:].reset_index(drop=True)

horizontal_bar_plot(q32_df, 'freq', 'top', 'flare', 250, 0.4, (0, 5000), 
                    (0, 5000), (10, 8), '\nRegularly Used Big Data Products by Kagglers\n', 
                    '\nUsers', 'Big Data Products\n', 13, 'Most Popular Big Data Product', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>44. The above figure says that <span style="font-weight: bold; color:#122ecc;">most (≈17%)</span> of the Kaggle Users use <span style="font-weight: bold; color:#122ecc;">MySQL</span> for database related purpose.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q32.B. Which <span style="color:black;">big data products</span> (relational databases, data warehouses, data lakes, or similar) do you hope to <span style="color:black;">become more familiar</span> with in the next 2 years ?</li></strong>
# </ul>

# %%
q32b_df = df[df.columns[303:324]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[
        go.Pie(values=q32b_df['freq'], labels=q32b_df['top'])
    ])
fig.update_layout(
             annotations=[dict(text='<b>Big Data Products Kagglers willing to Explore</b>', x=0.5, y=1.2, font_size=20, showarrow=False)],
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>45. <span style="font-weight: bold; color:#122ecc;">Most (≈13%)</span> of the Kagglers are willing to learn <span style="font-weight: bold; color:#122ecc;">MySQL</span> for database related purpose in the next 2 years.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q33. Which <span style="color:black;">big data products</span> (relational databases, data warehouses, data lakes, or similar) do you <span style="color:black;">use most often</span> ?</li></strong>
# </ul>

# %%
q33_df = pd.DataFrame(df['Q33'].value_counts()).reset_index().rename(columns={'index':'Big_Data_Products', 'Q33':'Users'})[:13]

for i in range(13):
    if len(q33_df['Big_Data_Products'][i]) > 1:
        q33_df['Big_Data_Products'][i] = '\n'.join(q33_df['Big_Data_Products'][i].split())
        
bar_plot(q33_df, 'Big_Data_Products', 'Users', 'icefire', 30, +.01, (0, 1500), 0,
        '\nBig Data Products Used most often\n', '\nBig Data Products\n', 
         'Users\n', 13, 10, 'Most Popular Big Data Product')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>46. <span style="font-weight: bold; color:#122ecc;">Most often (≈26%)</span> Kagglers use <span style="font-weight: bold; color:#122ecc;">MySQL</span> for database related work.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q34.A. Which <span style="color:black;">business intelligence tools</span> do you use on a <span style="color:black;">regular basis</span> ?</li></strong>
# </ul>

# %%
q34_df = df[df.columns[187:204]].describe().T.iloc[:, 2:].reset_index(drop=True)

horizontal_bar_plot(q34_df, 'freq', 'top', 'copper_r', 250, 0.4, (0, 5000), 
                    (0, 5000), (10, 8), '\nRegularly Used Business Intelligence Tools by Kagglers\n', 
                    '\nUsers', 'Business Intelligence Tools\n', 13, 'Most Popular BI Tool', 'best')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>47. From the Survey, we can see that <span style="font-weight: bold; color:#122ecc;">majority</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Tableau & Microsoft power BI</span> as a business intelligence tool.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q34.B. Which <span style="color:black;">business intelligence tools</span> do you hope to <span style="color:black;">become more familiar</span> with in the next 2 years ?</li></strong>
# </ul>

# %%
q34b_df = df[df.columns[324:341]].describe().T.iloc[:, 2:].reset_index(drop=True)

for i in range(16):
    if len(q34b_df['top'][i]) > 1:
        q34b_df['top'][i] = '\n'.join(q34b_df['top'][i].split())
        
        
bar_plot(q34b_df, 'top', 'freq', 'crest', 50, +.01, (0, 6000), 0,
        '\nBusiness Intelligence Tools which Kagglers \nhope to become familiar with\n', '\nBusiness Intelligence Tools\n', 
         'Users\n', 11, 8, 'Most Popular Business Intelligence Tool')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>48. <span style="font-weight: bold; color:#122ecc;">Most (≈20%)</span> of the Kagglers are willing to learn <span style="font-weight: bold; color:#122ecc;">Tableau</span> as a business intelligence tool.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q35. Which <span style="color:black;">business intelligence tools</span> do you <span style="color:black;">use most often</span> ?</li></strong>
# </ul>

# %%
q35_df = pd.DataFrame(df['Q35'].value_counts()).reset_index().rename(columns={'index':'Business_Intelligence_Tools', 'Q35':'Users'})[:16]

for i in range(12):
    if len(q35_df['Business_Intelligence_Tools'][i]) > 1:
        q35_df['Business_Intelligence_Tools'][i] = '\n'.join(q35_df['Business_Intelligence_Tools'][i].split())
        
        
bar_plot(q35_df, 'Business_Intelligence_Tools', 'Users', 'PuOr_r', 10, +.01, (0, 1000), 0,
        '\nBusiness Intelligence Tools used most often by the Kagglers\n', '\nBusiness Intelligence Tools\n', 
         'Users\n', 11, 9, 'Most Popular Business Intelligence Tool')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>49. From Survey, we can observe that <span style="font-weight: bold; color:#122ecc;">most often (≈35%)</span>  Kagglers use <span style="font-weight: bold; color:#122ecc;">Microsoft Power BI</span> as their business intelligence tool.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q36.A. Do you use any <span style="color:black;">automated machine learning tools</span> (or partial AutoML tools) on a regular basis ?</li></strong>
# </ul>

# %%
q36_df = df[df.columns[205:213]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[
        go.Pie(values=q36_df['freq'], labels=q36_df['top'], pull=[0, 0, 0, 0, 0, 0, 0.2, 0],
              marker = {"colors": ['#FFAB91', '#FFEE58', '#FF7043', '#FFD54F', '#FFD180', '#FFCA28', '#FF1744', 'black']}
              )
    ])

fig.update_layout(
             annotations=[dict(text='<b>Regular Usage of AutoML Tools by Kagglers</b>', x=0.5, y=1.2, font_size=20, showarrow=False)],
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>50. From Survey, we came to know that <span style="font-weight: bold; color:#122ecc;">majority (≈54%)</span> Users of Kaggle community are <span style="font-weight: bold; color:#122ecc;">not using AutoML Tools</span> on a regular basis.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q36.B. Which categories of <span style="color:black;">automated machine learning tools</span> do you hope to <span style="color:black;">become more familiar</span> with in the next 2 years ?</li></strong>
# </ul>

# %%
q36b_df = df[df.columns[341:349]].describe().T.iloc[:, 2:].reset_index(drop=True)


for i in range(6):
    if '(' in q36b_df['top'][i]:
        q36b_df['top'][i] = q36b_df['top'][i].split('(')[0] + ' \n(' + q36b_df['top'][i].split('(')[1]
        
        
horizontal_bar_plot(q36b_df, 'freq', 'top', 'CMRmap', 500, 0.4, (0, 6000), 
                    (0, 6000), (8, 8),'\nDifferent Categories of Automated ML Tools \nKagglers willing to explore\n', 
                    '\nUsers', 'Tools\n', 14, 'Most Popular Tool', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q37.A. Which <span style="color:black;">automated machine learning tools</span> (or partial AutoML tools) do you use on a <span style="color:black;">regular basis</span> ?</li></strong>
# </ul>

# %%
q37_df = df[df.columns[213:221]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[go.Pie(values=q37_df['freq'], labels=q37_df['top'], hole=0.5,
                marker = {"colors": ['#FF8A65', '#FFEE58', '#FFFF00', '#58ff87', '#ff1f1f', '#ff7728', '#4938ff', 'black']})]
)

fig.update_layout(
    annotations=[dict(text='<b>Automated ML Tools regularly Used by Kagglers</b>', x=0.5, y=1.2, font_size=20, showarrow=False)],      
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>51. We can see that <span style="font-weight: bold; color:#122ecc;">majority (≈19%)</span> Users of Kaggle, use <span style="font-weight: bold; color:#122ecc;">Google Cloud AutoML</span> on a regular basis for automated machine learning.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q37.B. Which specific <span style="color:black;">automated machine learning tools</span> do you hope to <span style="color:black;">become more familiar</span> with in the next 2 years ?</li></strong>
# </ul>

# %%
q37b_df = df[df.columns[349:357]].describe().T.iloc[:, 2:].reset_index(drop=True)

horizontal_bar_plot(q37b_df, 'freq', 'top', 'gist_heat', 400, 0.4, (0, 7000), 
                    (0, 7000), (10, 8),'\nDifferent Automated ML Tools\n Kagglers willing to Learn\n', 
                    '\nUsers', 'Tools\n', 14, 'Most Popular Tool', 'lower right')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>52. <span style="font-weight: bold; color:#122ecc;">Most (≈29%)</span> of the Kagglers are willing to explore <span style="font-weight: bold; color:#122ecc;">Google Cloud AutoML</span> in the next 2 years.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q38.A. Do you use any <span style="color:black;">tools</span> to help manage <span style="color:black;">machine learning experiments</span>  ?</li></strong>
# </ul>

# %%
q38_df = df[df.columns[221:233]].describe().T.iloc[:, 2:].reset_index(drop=True)

for i in range(12):
    if len(q38_df['top'][i]) > 1:
        q38_df['top'][i] = '\n'.join(q38_df['top'][i].split())
        
bar_plot(q38_df, 'top', 'freq', 'flag', 50, +.01, (0, 7000), 0,
        '\nDifferent Tools for managing ML Experiments\n', '\nTools\n', 
         'Users\n', 14, 11, 'Most Popular Tool')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>53. Around <span style="font-weight: bold; color:#122ecc;">16%</span> Users of Kaggle, use <span style="font-weight: bold; color:#122ecc;">Tensor Board</span> for managing <span style="font-weight: bold; color:#122ecc;">machine learning experiments</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q38.B In the next 2 years, do you hope to <span style="color:black;">become more familiar</span> with any of these <span style="color:black;">tools</span> for managing ML experiments ?</li></strong>
# </ul>

# %%
q38b_df = df[df.columns[357:]].describe().T.iloc[:, 2:].reset_index(drop=True)

fig = go.Figure(
    data=[
        go.Pie(values=q38b_df['freq'], labels=q38b_df['top'], hole=0.7,
               marker = {"colors": ['#00C853', '#64DD17', '#AEEA00', '#C6FF00', '#EEFF41', '#FFEB3B', '#FFC107', '#FFA726', '#FFB74D', '#FFE082']})
    ])

fig.update_layout(
             annotations=[dict(text='<b>Tools Kagglers willing to learn for managing ML experiments</b>', x=0.5, y=1.2, font_size=20, showarrow=False)],
        
)

fig.show()

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>54. <span style="font-weight: bold; color:#122ecc;">Most (22%)</span> of the Kagglers are willing to get  <span style="font-weight: bold; color:#122ecc;">familiar with Tensor Board</span> in the next 2 years for managing <span style="font-weight: bold; color:#122ecc;">machine learning experiments</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q39. Where do you <span style="color:black;">publicly share</span> your data analysis or machine learning applications ?</li></strong>
# </ul>

# %%
q39_df = df[df.columns[233:243]].describe().T.iloc[:, 2:].reset_index(drop=True)

q39_df['top'][8] = 'Publicaly\nnot Shared'

bar_plot(q39_df, 'top', 'freq', 'coolwarm', 50, +.01, (0, 5000), 0,
        '\nDifferent Public Platforms for Sharing ML Works\n', 
        '\nSharing Platforms\n','Users\n', 14, 11, 
         'Most Popular Platform')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>55. From the Survey, we came to know that <span style="font-weight: bold; color:#122ecc;">majority (31%)</span> Users of Kaggle share their ML related work in <span style="font-weight: bold; color:#122ecc;">Github</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q40. On which <span style="color:black;">platforms</span> have you <span style="color:black;">begun/completed</span> data science courses ?</li></strong>
# </ul>

# %%
q40_df = df[df.columns[243:255]].describe().T.iloc[:, 2:].reset_index(drop=True)

for i in range(12):
    if '(' in q40_df['top'][i]:
        q40_df['top'][i] = q40_df['top'][i].split('(')[0] + ' \n(' + q40_df['top'][i].split('(')[1]
        
horizontal_bar_plot(q40_df, 'freq', 'top', 'rainbow_r', -650, 0.4, (0, 10000), 
                    (0, 10000), (8, 8),'\nDifferent Platforms for Data Science Courses\n', 
                    '\nUsers', 'Course Platforms\n', 14, 'Most Popular Platform', 'best')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>56. <span style="font-weight: bold; color:#122ecc;">Coursera</span> is the <span style="font-weight: bold; color:#122ecc;">most popular platform</span> among the new learners for Data science related courses.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q41. What is the <span style="color:black;">primary tool</span> that you use at work or school to <span style="color:black;">analyze data</span> ?</li></strong>
# </ul>

# %%
q41_df = pd.DataFrame(df['Q41'].value_counts()).reset_index().rename(columns={'index':'EDA_Tool', 'Q41':'Users'})[:6]

for i in range(6):
    if '(' in q41_df['EDA_Tool'][i]:
        q41_df['EDA_Tool'][i] = q41_df['EDA_Tool'][i].split('(')[0] + ' \n(' + q41_df['EDA_Tool'][i].split('(')[1]
        
horizontal_bar_plot(q41_df, 'Users', 'EDA_Tool', 'cool_r', -500, 0.4, (0, 8000), 
                    (0, 8000), (8, 8),'\nDifferent primary tools for Data Analysis\n', 
                    '\nUsers', 'Tools\n', 14, 'Most Popular Tool', 'best')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1dA4TrpVoP4KTIWODmMr8xA09Zr-XHgRQ" align="left" hspace="10px" vspace="0px" width="65" height="75"></p>
#
# <ul style="list-style-type:none;">
#   <strong><li style="font-size:35px;color:  #6468e8">Q42. Who/what are your <span style="color:black;">favourite media sources</span> that report on data science topics ?</li></strong>
# </ul>

# %%
q42_df = df[df.columns[256:268]].describe().T.iloc[:, 2:].reset_index(drop=True)

for i in range(12):
    if '(' in q42_df['top'][i]:
        q42_df['top'][i] = q42_df['top'][i].split('(')[0] + ' \n(' + q42_df['top'][i].split('(')[1]
        
horizontal_bar_plot(q42_df, 'freq', 'top', 'rainbow', 1100, 0.4, (0, 12000), 
                    (0, 12000), (6, 8),'\nDifferent favourite media sources\n of Data Science topics\n', 
                    '\nUsers', 'Media Sources\n', 14, 'Most Popular Media Source', 'best')

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="50" height="60"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:35px;font-style: italic;color:  #53d94c">Survey Insight:</li>
# </ul>
#
# <div class="alert alert-info" role="alert">
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>57. From the above figure, we can say undoubtedly that <span style="font-weight: bold; color:#122ecc;">Kaggle</span> is the <span style="font-weight: bold; color:#122ecc;">most favourite 😊 platform</span> among the learners for Data science, Machine Learning related topics.</li>
# </ul>
# </div>

# %% [markdown]
# <p><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=1ebumq4uOeWCh0LUUe_bq86Jk8s4Gz2pC" align="left" hspace="10px" vspace="10px" width="70" height="80"></p>
#
# <ul style="list-style-type:none;">
#   <li style="font-weight: bold;font-family:'Times New Roman';font-size:50px;font-style: italic;color:  #53d94c">All Insights:</li>
# </ul>
#
# <ul style="list-style-type:none;font-family:Yu Mincho Demibold;font-size:25px;color:black">
#     <li>1. Approximately <span style="font-weight: bold; color:#122ecc;">56%</span> of the total Kaggle Users are aged in between <span style="font-weight: bold; color:#122ecc;">18-29</span>.</li>
#     ---
#     <br>
#     <li>2. There are around <span style="font-weight: bold; color:#122ecc;">79% Male</span> Kaggle Users and <span style="font-weight: bold; color:#122ecc;">19% Female</span> Users.</li>
#     ---
#     <br>
#     <li>3. In Kaggle around <span style="font-weight: bold; color:#122ecc;">29%</span> Users are from <span style="font-weight: bold; color:#122ecc;">INDIA</span>.</li>
#     <br>
#     <li>4. Approximately <span style="font-weight: bold; color:#122ecc;">10%</span> Kaggle Users are from <span style="font-weight: bold; color:#122ecc;">USA</span>.</li>
#     ---
#     <br>
#     <li>5. <span style="font-weight: bold; color:#122ecc;">39%</span> of the total Kaggle Users have Completed <span style="font-weight: bold; color:#122ecc;">Master's Degree</span>.</li>
#     <br>
#     <li>6. Around <span style="font-weight: bold; color:#122ecc;">38%</span> of the Kaggle Users have <span style="font-weight: bold; color:#122ecc;">Bachelor's Degree</span>.</li>
#     ---
#     <br>
#     <li>7. <span style="font-weight: bold; color:#122ecc;">Majority (26%)</span> of the Kaggle Users are Currently <span style="font-weight: bold; color:#122ecc;">Student</span>.</li>
#     <br>
#     <li>8. Around <span style="font-weight: bold; color:#122ecc;">14%</span> of the whole Kaggle Community are Currently working as a <span style="font-weight: bold; color:#122ecc;">Data Scientist</span>.</li>
#     ---
#     <br>
#     <li>9. <span style="font-weight: bold; color:#122ecc;">Most (30%)</span> of the Kaggle Users have the <span style="font-weight: bold; color:#122ecc;">Coding Experience of (1-3) years</span>.</li>
#     <br>
#     <li>10. Around <span style="font-weight: bold; color:#122ecc;">22%</span> Users of the Kaggle Community have the coding experience of <span style="font-weight: bold; color:#122ecc;">less than 1 year</span>.</li>
#     ---
#     <br>
#     <li>11. From this Survey, we can observe that <span style="font-weight: bold; color:#122ecc;">around 33%</span> of the Kaggle Users use <span style="font-weight: bold; color:#122ecc;">Python</span> as a programming language on a regular basis.</li>
#     ---
#     <br>
#     <li>12. <span style="font-weight: bold; color:#122ecc;">Most (81%)</span> of the Kagglers recommend <span style="font-weight: bold; color:#122ecc;">Python</span> to the aspiring data scientist to learn first.</li>
#     ---
#     <br>
#     <li>13. From the Survey, we can say that <span style="font-weight: bold; color:#122ecc;">majority (33%)</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Jupyter</span> as their <span style="font-weight: bold; color:#122ecc;">IDE</span> on a regular basis.</li>
#     ---
#     <br>
#     <li>14. From the above figure, it's clear that among the Kagglers, <span style="font-weight: bold; color:#122ecc;">Kaggle Notebook & Colab Notebook</span> are most <span style="font-weight: bold; color:#122ecc;">popular</span>.</li>
#     ---
#     <br>
#     <li>15. <span style="font-weight: bold; color:#122ecc;">Majority (65%)</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Laptop</span> for their Data Science Projects.</li>
#     ---
#     <br>
#     <li>16. <span style="font-weight: bold; color:#122ecc;">Around (10%)</span> Kaggle Users are using <span style="font-weight: bold; color:#122ecc;">Cloud Computing Platforms</span> for their Data Science Projects.</li>
#     ---
#     <br>
#     <li>17. From the Survey, we are able to know that <span style="font-weight: bold; color:#122ecc;">around 30%</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">NVIDIA GPU</span> on a regular basis for their Data Science work.</li>
#     ---
#     <br>
#     <li>18. The Survey shows that <span style="font-weight: bold; color:#122ecc;">majority (67%)</span> of the Kagglers have <span style="font-weight: bold; color:#122ecc;">never used TPU</span> for their work.</li>
#     <br>
#     <li>19. Around <span style="font-weight: bold; color:#122ecc;">14%</span> Kaggle Users have <span style="font-weight: bold; color:#122ecc;">used TPU 2-5 times</span>.</li>
#     ---
#     <br>
#     <li>20. From the Survey, it's clear that <span style="font-weight: bold; color:#122ecc;">majority (35%)</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Matplotlib</span> for Data Visualization on a regular basis.</li>
#     <br>
#     <li>21. Apart from Matplotlib the <span style="font-weight: bold; color:#122ecc;">Seaborn</span> is also a popular library with <span style="font-weight: bold; color:#122ecc;">25%</span> Users in kaggle.</li>
#     ---
#     <br>
#     <li>22. From the above plot, it seems that <span style="font-weight: bold; color:#122ecc;">majority (39%)</span> of the Kagglers are in the ML field for <span style="font-weight: bold; color:#122ecc;">less than 1 year</span>.</li>
#     ---
#     <br>
#     <li>23. From the Survey, we can conclude that <span style="font-weight: bold; color:#122ecc;">Scikit learn</span> is <span style="font-weight: bold; color:#122ecc;">most popular (25% Users)</span> Machine Learning Framework.</li>
#     <br>
#     <li>24. <span style="font-weight: bold; color:#122ecc;">TensorFlow</span> is <span style="font-weight: bold; color:#122ecc;">2nd most popular (17% Users)</span> Machine Learning Framework among Kagglers.</li>
#     ---
#     <br>
#     <li>25. Our Survey says that Kagglers use <span style="font-weight: bold; color:#122ecc;">Linear Regression, Logistic Regression, Decision Tree, Random Forest </span> as Machine Learning Algorithm on a regular basis.</li>
#     ---
#     <br>
#     <li>26. Our Survey says that among different computer vision methods, Kagglers mostly use <span style="font-weight: bold; color:#122ecc;">VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet</span> for Image classification and other general purpose networks.</li>
#     ---
#     <br>
#     <li>27. In NLP among various methods, Kagglers mostly use <span style="font-weight: bold; color:#122ecc;">
# GLoVe, fastText, word2vec</span> for Word embeddings/vectors.</li>
#     <br>
#     <li>28. The <span style="font-weight: bold; color:#122ecc;"> Transformer Language Model (GPT-3, BERT, XLnet)</span> are also getting popular among Kagglers.</li>
#     ---
#     <br>
#     <li>29. <span style="font-weight: bold; color:#122ecc;">Most (25%)</span> of the Kaggle Users are currently working in <span style="font-weight: bold; color:#122ecc;">computer technology-based industry</span>.</li>
#     ---
#     <br>
#     <li>30. <span style="font-weight: bold; color:#122ecc;">Majority (31%)</span> of the Kagglers are currently employed in companies with<span style="font-weight: bold; color:#122ecc;"> employee size equal to 0-49 </span>.</li>
#     ---
#     <br>
#     <li>31. From the Survey study, we can see that <span style="font-weight: bold; color:#122ecc;">22%</span> Users of Kaggle community are currently working in such companies where the <span style="font-weight: bold; color:#122ecc;">Data Science Team-Size is more than 20</span>.</li>
#     ---
#     <br>
#     <li>32. Regarding the incorporation of ML methods in business survey, we came to know that <span style="font-weight: bold; color:#122ecc;">≈ 17%</span> Users of Kaggle community <span style="font-weight: bold; color:#122ecc;">have well established ML methods (i.e., models in production for more than 2 years)</span>.</li>
#     ---
#     <br>
#     <li>33. Based on the Survey, we can conclude that <span style="font-weight: bold; color:#122ecc;">majority (≈22%)</span> of the Kagglers are earning <span style="font-weight: bold; color:#122ecc;">0 - 999(USD)</span> as their yearly compensation.</li>
#     <br>
#     <li>34. There are <span style="font-weight: bold; color:#122ecc;">only 0.38%</span> Kagglers whose Yearly Compensation is <span style="font-weight: bold; color:#122ecc;"> greater than 1,000,000 USD</span>.</li>
#     ---
#     <br>
#     <li>35. The survey says that <span style="font-weight: bold; color:#122ecc;">6.7%</span> Users of the whole Kaggle community spend <span style="font-weight: bold; color:#122ecc;">1,00,000 or more USD</span> for ML and/or Cloud Computing related Services.</li>
#     ---
#     <br>
#     <li>36. From survey, we can see that <span style="font-weight: bold; color:#122ecc;">majority (≈25%)</span> Users of Kaggle use <span style="font-weight: bold; color:#122ecc;">Amazon Web Services (AWS)</span> on a regular basis as a Cloud Computing platform.</li>
#     ---
#     <br>
#     <li>37. From above plot we can see that <span style="font-weight: bold; color:#122ecc;">most</span> of the Kaggle Users are willing to get <span style="font-weight: bold; color:#122ecc;">familiar</span> with <span style="font-weight: bold; color:#122ecc;">Amazon Web Services(AWS) & Google Cloud Platform(GCP)</span>.</li>
#     ---
#     <br>
#     <li>38. From the Survey, we came to know that <span style="font-weight: bold; color:#122ecc;">majority (≈27%)</span> of the Kagglers prefers <span style="font-weight: bold; color:#122ecc;">AWS</span>.</li>
#     ---
#     <br>
#     <li>39. The Survey says that <span style="font-weight: bold; color:#122ecc;">≈30%</span> Users of Kaggle use <span style="font-weight: bold; color:#122ecc;">Amazon Elastic Computing Cloud (EC2) </span> on a regular basis.</li>
#     ---
#     <br>
#     <li>40. From the above figure, it seems that <span style="font-weight: bold; color:#122ecc;">maximum (38%)</span> Kaggle Users are willing to learn <span style="font-weight: bold; color:#122ecc;">Google Cloud Compute Engine</span> in the next 2 years.</li>
#     ---
#     <br>
#     <li>41. For <span style="font-weight: bold; color:#122ecc;">data storage service</span> around <span style="font-weight: bold; color:#122ecc;">25%</span> Kagglers use <span style="font-weight: bold; color:#122ecc;">AWS S3</span> on a regular basis.</li>
#     ---
#     <br>
#     <li>42. Approximately <span style="font-weight: bold; color:#122ecc;">9%</span> Kagglers use <span style="font-weight: bold; color:#122ecc;">AWS Sagemaker service</span> for managing their Machine learning works.</li>
#     ---
#     <br>
#     <li>43. From our Survey, we can see <span style="font-weight: bold; color:#122ecc;">21%</span> Kaggle Users are willing to explore <span style="font-weight: bold; color:#122ecc;">Google Cloud Vertex AI</span> for managing their Machine learning works.</li>
#     ---
#     <br>
#     <li>44. The above figure says that <span style="font-weight: bold; color:#122ecc;">most (≈17%)</span> of the Kaggle Users use <span style="font-weight: bold; color:#122ecc;">MySQL</span> for database related purpose.</li>
#     ---
#     <br>
#     <li>45. <span style="font-weight: bold; color:#122ecc;">Most (≈13%)</span> of the Kagglers are willing to learn <span style="font-weight: bold; color:#122ecc;">MySQL</span> for database related purpose in the next 2 years.</li>
#     ---
#     <br>
#     <li>46. <span style="font-weight: bold; color:#122ecc;">Most often (≈26%)</span> Kagglers use <span style="font-weight: bold; color:#122ecc;">MySQL</span> for database related work.</li>
#     ---
#     <br>
#     <li>47. From the Survey, we can see that <span style="font-weight: bold; color:#122ecc;">majority</span> of the Kagglers use <span style="font-weight: bold; color:#122ecc;">Tableau & Microsoft power BI</span> as a business intelligence tool.</li>
#     ---
#     <br>
#     <li>48. <span style="font-weight: bold; color:#122ecc;">Most (≈20%)</span> of the Kagglers are willing to learn <span style="font-weight: bold; color:#122ecc;">Tableau</span> as a business intelligence tool.</li>
#     ---
#     <br>
#     <li>49. From Survey, we can observe that <span style="font-weight: bold; color:#122ecc;">most often (≈35%)</span>  Kagglers use <span style="font-weight: bold; color:#122ecc;">Microsoft Power BI</span> as their business intelligence tool.</li>
#     ---
#     <br>
#     <li>50. From Survey, we came to know that <span style="font-weight: bold; color:#122ecc;">majority (≈54%)</span> Users of Kaggle community are <span style="font-weight: bold; color:#122ecc;">not using AutoML Tools</span> on a regular basis.</li>
#     ---
#     <br>
#     <li>51. We can see that <span style="font-weight: bold; color:#122ecc;">majority (≈19%)</span> Users of Kaggle, use <span style="font-weight: bold; color:#122ecc;">Google Cloud AutoML</span> on a regular basis for automated machine learning.</li>
#     ---
#     <br>
#     <li>52. <span style="font-weight: bold; color:#122ecc;">Most (≈29%)</span> of the Kagglers are willing to explore <span style="font-weight: bold; color:#122ecc;">Google Cloud AutoML</span> in the next 2 years.</li>
#     ---
#     <br>
#     <li>53. Around <span style="font-weight: bold; color:#122ecc;">16%</span> Users of Kaggle, use <span style="font-weight: bold; color:#122ecc;">Tensor Board</span> for managing <span style="font-weight: bold; color:#122ecc;">machine learning experiments</span>.</li>
#     ---
#     <br>
#     <li>54. <span style="font-weight: bold; color:#122ecc;">Most (22%)</span> of the Kagglers are willing to get  <span style="font-weight: bold; color:#122ecc;">familiar with Tensor Board</span> in the next 2 years for managing <span style="font-weight: bold; color:#122ecc;">machine learning experiments</span>.</li>
#     ---
#     <br>
#     <li>55. From the Survey, we came to know that <span style="font-weight: bold; color:#122ecc;">majority (31%)</span> Users of Kaggle share their ML related work in <span style="font-weight: bold; color:#122ecc;">Github</span>.</li>
#     ---
#     <br>
#     <li>56. <span style="font-weight: bold; color:#122ecc;">Coursera</span> is the <span style="font-weight: bold; color:#122ecc;">most popular platform</span> among the new learners for Data science related courses.</li>
#     ---
#     <br>
#     <li>57. From the above figure, we can say undoubtedly that <span style="font-weight: bold; color:#122ecc;">Kaggle</span> is the <span style="font-weight: bold; color:#122ecc;">most favourite 😊 platform</span> among the learners for Data science, Machine Learning related topics.</li>
# </ul>

# %% [markdown]
# <center><img alt="Insight logo" src="https://drive.google.com/uc?export=view&id=19TTqZx_aOiMPPhpmopFSPezgTzf0QkUa" align="center" hspace="10px" vspace="10px" width="400" height="800" ></center>
