# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# Essential libraries
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')
df.head()

# %%
df1= df.copy()

# %%
df = df.drop(0)

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# # Ages of the survey participants

# %%
fig = px.histogram(df, x='Q1')
fig.show()

# %%
# Gender of the participants
fig = px.histogram(df, x= 'Q2')
fig.show()

# %% [markdown]
# This doesn't surprise me. Only dudes are there in kaggle.

# %% [markdown]
# # Country

# %%
fig = px.histogram(df, x='Q3')
fig.show()

# %% [markdown]
# # Past Educational qualifications or currently pursuing

# %%
fig = px.histogram(df, x='Q4')
fig.show()

# %% [markdown]
# # What participants do?

# %%
fig= px.histogram(df, x= 'Q5')
fig.show()

# %% [markdown]
# As expected jobless people (Students) are ones who are on this platform. That includes me too!

# %% [markdown]
# # Years of coding experience

# %%
fig = px.histogram(df, x= 'Q6')
fig.show()

# %% [markdown]
# Almost normally distributed.

# %% [markdown]
# # Most used Language

# %%
lang_cols = df[["Q7_Part_1","Q7_Part_2","Q7_Part_3","Q7_Part_4","Q7_Part_5", "Q7_Part_6",
             "Q7_Part_7","Q7_Part_8","Q7_Part_9","Q7_Part_10","Q7_Part_11","Q7_Part_12","Q7_OTHER"]]

# %%
lang_cols

# %%
lang = pd.DataFrame(zip(lang_cols.stack().tolist()), columns = ["Languages"])

# %%
fig = px.histogram(lang, x= 'Languages')
fig.show()

# %% [markdown]
# # Most recommended language by the participants

# %%
fig = px.histogram(df, x='Q8')
fig.show()

# %% [markdown]
# High correlation between the above two graphs.

# %%
ide = df[['Q9_Part_1','Q9_Part_2','Q9_Part_3','Q9_Part_4','Q9_Part_5','Q9_Part_6','Q9_Part_7','Q9_Part_8',
        'Q9_Part_9','Q9_Part_10','Q9_Part_11','Q9_Part_12','Q9_OTHER']]

# %%
ide_df = pd.DataFrame(zip(ide.stack().tolist()), columns = ["ides"])

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=ide_df, x='ides')
plt.xticks(rotation=85)

# %% [markdown]
# Jupyter Notebook is still is still the favourite. Mine is VS code. What's yours?

# %% [markdown]
# # Hosted notebook products

# %%
nb = df[['Q10_Part_1','Q10_Part_2','Q10_Part_3','Q10_Part_4','Q10_Part_5','Q10_Part_6','Q10_Part_7',
'Q10_Part_8','Q10_Part_9','Q10_Part_10','Q10_Part_11','Q10_Part_12','Q10_Part_13','Q10_Part_14',
'Q10_Part_15','Q10_Part_16','Q10_OTHER']]

# %%
nb_df = pd.DataFrame(zip(nb.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=nb_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# # Most used computing platform

# %%
fig = px.histogram(df, x= 'Q11')
fig.show()

# %% [markdown]
# # Most used hardware

# %%
hardware = df[['Q12_Part_1','Q12_Part_2','Q12_Part_3','Q12_Part_4','Q12_Part_5','Q12_OTHER']]
hard_df = pd.DataFrame(zip(hardware.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=hard_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# Most of us don't use any hardwares.

# %% [markdown]
# # Data Visualization libraries.

# %%
viz = df[['Q14_Part_1','Q14_Part_2','Q14_Part_3','Q14_Part_4','Q14_Part_5','Q14_Part_6','Q14_Part_7','Q14_Part_8',
       'Q14_Part_9','Q14_Part_10','Q14_Part_11','Q14_OTHER']]
viz_df = pd.DataFrame(zip(viz.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=viz_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# The usual suspects here. Matplotlib, seaborn and plotly rule here.

# %% [markdown]
# # ML experience

# %%
fig = px.histogram(df, x='Q15')
fig.show()

# %% [markdown]
# Newbies tend be more on kaggle.

# %% [markdown]
# # most used ML frameworks

# %%
ml_frame=df[['Q16_Part_1','Q16_Part_2','Q16_Part_3','Q16_Part_4','Q16_Part_5','Q16_Part_6','Q16_Part_7',
             'Q16_Part_8','Q16_Part_9','Q16_Part_10','Q16_Part_11','Q16_Part_12','Q16_Part_13','Q16_Part_14','Q16_Part_15',
             'Q16_Part_16','Q16_Part_17','Q16_OTHER']]
ml_frame_df = pd.DataFrame(zip(ml_frame.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=ml_frame_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# Usal suspects. Anything new that is great here, that is underated?

# %% [markdown]
# # Most popular ML algorothms

# %%
algo = df[['Q17_Part_1','Q17_Part_2','Q17_Part_3','Q17_Part_4','Q17_Part_5','Q17_Part_6','Q17_Part_7',
           'Q17_Part_8','Q17_Part_9','Q17_Part_10','Q17_Part_11','Q17_OTHER']]
algo_df = pd.DataFrame(zip(algo.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=algo_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# The most popular ML algorithms are:
# * Linear/ Logistic Regression
# * Decision tree and Random Forests
# * Gradient boosting machines

# %% [markdown]
# # Computer vision methods

# %%
cv= df[['Q18_Part_1','Q18_Part_2','Q18_Part_3','Q18_Part_4','Q18_Part_5','Q18_Part_6','Q18_OTHER']]
cv_df = pd.DataFrame(zip(cv.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=cv_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# # Popular NLP methods

# %%
nlp=df[['Q19_Part_1','Q19_Part_2','Q19_Part_3','Q19_Part_4','Q19_Part_5','Q19_OTHER']]
nlp_df = pd.DataFrame(zip(nlp.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=nlp_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# # Corresponding Industry of the participants

# %%
fig = px.histogram(df, x='Q20')
fig.show()

# %% [markdown]
# Most of the participants were from
# 1. Tech
# 2. Academia

# %% [markdown]
# # Size of their company

# %%
fig = px.histogram(df, x='Q21')
fig.show()

# %% [markdown]
# Mostly smaller firms.

# %% [markdown]
# # State of ML at the corporates

# %%
fig = px.histogram(df, x='Q23')
fig.show()

# %% [markdown]
# Mixed reaction there.

# %% [markdown]
# # Yearly compensation

# %%
fig = px.histogram(df, x='Q25')
fig.show()

# %% [markdown]
# # Most used cloud platforms

# %%
cloud =df[['Q27_A_Part_1','Q27_A_Part_2','Q27_A_Part_3','Q27_A_Part_4','Q27_A_Part_5','Q27_A_Part_6',
  'Q27_A_Part_7','Q27_A_Part_8','Q27_A_Part_9','Q27_A_Part_10','Q27_A_Part_11','Q27_A_OTHER']]
cloud_df = pd.DataFrame(zip(cloud.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=cloud_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# The most popular Cloud services are
# 1. Google Cloud Platform
# 2. Amazon Web services

# %% [markdown]
# # Cloud platform with best developer experience

# %%
fig = px.histogram(df, x='Q28')
fig.show()

# %% [markdown]
# What people said:
# * most of the people said AWS had the best experience
# * Some said GCP
# * There was no differentiation in experience

# %% [markdown]
# # Managed ML products usage

# %%
mml = df[['Q31_A_Part_1','Q31_A_Part_2','Q31_A_Part_3','Q31_A_Part_4','Q31_A_Part_5','Q31_A_Part_6',
'Q31_A_Part_7','Q31_A_Part_8','Q31_A_Part_9','Q31_A_OTHER']]
mml_df = pd.DataFrame(zip(mml.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=mml_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# These results are skewed because most of the participants are students. Students don't really use these unless they get for free.

# %% [markdown]
# # Most used BI tools

# %%
bi =df[['Q34_A_Part_1','Q34_A_Part_2','Q34_A_Part_3','Q34_A_Part_4','Q34_A_Part_5','Q34_A_Part_6',
  'Q34_A_Part_7','Q34_A_Part_8','Q34_A_Part_9','Q34_A_Part_10','Q34_A_Part_11','Q34_A_Part_12','Q34_A_Part_13',
  'Q34_A_Part_14','Q34_A_Part_15','Q34_A_Part_16','Q34_A_OTHER'
]]
bi_df = pd.DataFrame(zip(bi.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=bi_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# The most used products are:
# 1. Tableau
# 2. Power BI

# %% [markdown]
# # Most often used BI tools

# %%
fig = px.histogram(df, x='Q35')
fig.show()

# %% [markdown]
# Power BI leads in this may due to the cost factors.
#
# https://www.acxtron.com/power-bi-vs-tableau-cost-calculator#:~:text=Comparatively%2C%20Power%20BI%20can%20range%20anywhere%20between%2025%25,creators%20and%20explorers%2C%20you%20can%20expect%20more%20savings.

# %%
auto_ml =df[['Q37_A_Part_1','Q37_A_Part_2','Q37_A_Part_3','Q37_A_Part_4','Q37_A_Part_5','Q37_A_Part_6','Q37_A_Part_7','Q37_A_OTHER']]
auto_ml_df =  pd.DataFrame(zip(auto_ml.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=auto_ml_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# Beefed up responses for google cloud AutoMl because of kaggle, I guess.

# %% [markdown]
# # Managing experiments

# %%
ml_exp = df[['Q38_A_Part_1','Q38_A_Part_2','Q38_A_Part_3','Q38_A_Part_4','Q38_A_Part_5',
             'Q38_A_Part_6','Q38_A_Part_7','Q38_A_Part_8','Q38_A_Part_9','Q38_A_Part_10','Q38_A_Part_11','Q38_A_OTHER']]
ml_exp_df =  pd.DataFrame(zip(ml_exp.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=ml_exp_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# I've used weights and biases.

# %%
ds_courses = df[['Q40_Part_1','Q40_Part_2','Q40_Part_3','Q40_Part_4','Q40_Part_5','Q40_Part_6','Q40_Part_7',
                 'Q40_Part_8','Q40_Part_9','Q40_Part_10','Q40_Part_11','Q40_OTHER']]
ds_courses_df = pd.DataFrame(zip(ds_courses.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=ds_courses_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# Most visited DS learning websites are
# 1. Coursera
# 2. EDX
# 3. Kaggle
# 4. Udemy
# 5. University courses

# %% [markdown]
# # Favourite social media sources

# %%
sm = df[['Q42_Part_1','Q42_Part_2','Q42_Part_3','Q42_Part_4','Q42_Part_5','Q42_Part_6',
         'Q42_Part_7','Q42_Part_8','Q42_Part_9','Q42_Part_10','Q42_Part_11','Q42_OTHER']]
sm_df = pd.DataFrame(zip(sm.stack().tolist()), columns = ["columns"])
plt.figure(figsize=(16,7))
sns.countplot(data=sm_df, x='columns')
plt.xticks(rotation=85)

# %% [markdown]
# Incomplete now.
# More charts and analysis coming up.
