# %% [markdown]
# ### Do Non-Professional minds think like Professionals on tools?👓

# %% [markdown]
# ##### Importing required stuffs...

# %%
# !pip install --upgrade plotly

import pandas as pd
import numpy as np
import plotly.express as px

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 500)

d = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv', low_memory=False)

# %% [markdown]
# ##### Tampering with the data...

# %%
#segregating professionals and non-professionals

non_pro_index = d.loc[(d.Q5 =='Student') | (d.Q5 =='Currently not employed')].index
pro_index = np.setdiff1d(np.array(range(1,d.shape[0])), np.array(non_pro_index))

# %%
# Selecting columns related to answers on tools for both professionals and non-professionals

# professionals set of questions

d_27A = d.loc[list(pro_index)].filter(regex='Q27_A.*')
d_29A = d.loc[list(pro_index)].filter(regex='Q29_A.*')
d_30A = d.loc[list(pro_index)].filter(regex='Q30_A.*')
d_31A = d.loc[list(pro_index)].filter(regex='Q31_A.*')
d_32A = d.loc[list(pro_index)].filter(regex='Q32_A.*')
d_34A = d.loc[list(pro_index)].filter(regex='Q34_A.*')
d_36A = d.loc[list(pro_index)].filter(regex='Q36_A.*')
d_37A = d.loc[list(pro_index)].filter(regex='Q37_A.*')
d_38A = d.loc[list(pro_index)].filter(regex='Q38_A.*')

# non-professionals set of questions

d_27B = d.loc[list(pro_index)].filter(regex='Q27_B.*')
d_29B = d.loc[list(pro_index)].filter(regex='Q29_B.*')
d_30B = d.loc[list(pro_index)].filter(regex='Q30_B.*')
d_31B = d.loc[list(pro_index)].filter(regex='Q31_B.*')
d_32B = d.loc[list(pro_index)].filter(regex='Q32_B.*')
d_34B = d.loc[list(pro_index)].filter(regex='Q34_B.*')
d_36B = d.loc[list(pro_index)].filter(regex='Q36_B.*')
d_37B = d.loc[list(pro_index)].filter(regex='Q37_B.*')
d_38B = d.loc[list(pro_index)].filter(regex='Q38_B.*')

# %%
#dropping rows with all NaN 

d_27A.dropna(how='all', inplace=True)
d_27B.dropna(how='all', inplace=True)

d_29A.dropna(how='all', inplace=True)
d_29B.dropna(how='all', inplace=True)

d_31A.dropna(how='all', inplace=True)
d_31B.dropna(how='all', inplace=True)

d_32A.dropna(how='all', inplace=True)
d_32B.dropna(how='all', inplace=True)

d_34A.dropna(how='all', inplace=True)
d_34B.dropna(how='all', inplace=True)

d_36A.dropna(how='all', inplace=True)
d_36B.dropna(how='all', inplace=True)

d_37A.dropna(how='all', inplace=True)
d_37B.dropna(how='all', inplace=True)

d_38A.dropna(how='all', inplace=True)
d_38B.dropna(how='all', inplace=True)

# %%
# Mapping

cloud_platform_pro_map = {'Q27_A_Part_1': 'AWS',
        'Q27_A_Part_2': 'Azure',
        'Q27_A_Part_3': 'GCP',
        'Q27_A_Part_4': 'IBM',
        'Q27_A_Part_5': 'Oracle',
        'Q27_A_Part_6': 'SAP',
        'Q27_A_Part_7': 'Salesforce',
        'Q27_A_Part_8': 'VMware',
        'Q27_A_Part_9': 'Alibaba',
        'Q27_A_Part_10': 'Tencent',
        'Q27_A_Part_11': 'None',
        'Q27_A_OTHER': 'Other'}

cloud_platform_non_pro_map = {'Q27_B_Part_1': 'AWS',
        'Q27_B_Part_2': 'Azure',
        'Q27_B_Part_3': 'GCP',
        'Q27_B_Part_4': 'IBM',
        'Q27_B_Part_5': 'Oracle',
        'Q27_B_Part_6': 'SAP',
        'Q27_B_Part_7': 'Salesforce',
        'Q27_B_Part_8': 'VMware',
        'Q27_B_Part_9': 'Alibaba',
        'Q27_B_Part_10': 'Tencent',
        'Q27_B_Part_11': 'None',
        'Q27_B_OTHER': 'Other'}

cloud_computing_pro_map = {'Q29_A_Part_1': 'EC2',
        'Q29_A_Part_2': 'Azure VM',
        'Q29_A_Part_3': 'GCE',
        'Q29_A_Part_4': 'None',
        'Q29_A_OTHER': 'Other'}

cloud_computing_non_pro_map = {'Q29_B_Part_1': 'EC2',
        'Q29_B_Part_2': 'Azure VM',
        'Q29_B_Part_3': 'GCE',
        'Q29_B_Part_4': 'None',
        'Q29_B_OTHER': 'Other'}

ML_products_pro_map = {'Q31_A_Part_1': 'Sagemaker',
        'Q31_A_Part_2': 'Azure ML Studio',
        'Q31_A_Part_3': 'Vertex AI',
        'Q31_A_Part_4': 'DataRobot',
        'Q31_A_Part_5': 'DataBricks',
        'Q31_A_Part_6': 'Dataiku',
        'Q31_A_Part_7': 'Alteryx',
        'Q31_A_Part_8': 'Rapidminer',
        'Q31_A_Part_9': 'None',
        'Q31_A_OTHER': 'Other'}

ML_products_non_pro_map = {'Q31_B_Part_1': 'Sagemaker',
        'Q31_B_Part_2': 'Azure ML Studio',
        'Q31_B_Part_3': 'Vertex AI',
        'Q31_B_Part_4': 'DataRobot',
        'Q31_B_Part_5': 'DataBricks',
        'Q31_B_Part_6': 'Dataiku',
        'Q31_B_Part_7': 'Alteryx',
        'Q31_B_Part_8': 'Rapidminer',
        'Q31_B_Part_9': 'None',
        'Q31_B_OTHER': 'Other'}

big_data_products_pro_map = {'Q32_A_Part_1': 'MySQL',
        'Q32_A_Part_2': 'PostgreSQL',
        'Q32_A_Part_3': 'SQLite',
        'Q32_A_Part_4': 'Oracle',
        'Q32_A_Part_5': 'MongoDB',
        'Q32_A_Part_6': 'Snowflake',
        'Q32_A_Part_7': 'IBM Db2',
        'Q32_A_Part_8': 'SQL',
        'Q32_A_Part_9': 'Azure SQL',
        'Q32_A_Part_10': 'Azure Cosmos',
        'Q32_A_Part_11': 'Redshift',
        'Q32_A_Part_12': 'Aurora',
        'Q32_A_Part_13': 'RDS',
        'Q32_A_Part_14': 'DynamoDB',
        'Q32_A_Part_15': 'BigQuery',
        'Q32_A_Part_16': 'Google SQL',
        'Q32_A_Part_17': 'Firestore',
        'Q32_A_Part_18': 'BigTable',
        'Q32_A_Part_19': 'Spanner',
        'Q32_A_Part_20': 'None',
        'Q32_A_OTHER': 'Other'}

big_data_products_non_pro_map = {'Q32_B_Part_1': 'MySQL',
        'Q32_B_Part_2': 'PostgreSQL',
        'Q32_B_Part_3': 'SQLite',
        'Q32_B_Part_4': 'Oracle',
        'Q32_B_Part_5': 'MongoDB',
        'Q32_B_Part_6': 'Snowflake',
        'Q32_B_Part_7': 'IBM Db2',
        'Q32_B_Part_8': 'SQL',
        'Q32_B_Part_9': 'Azure SQL',
        'Q32_B_Part_10': 'Azure Cosmos',
        'Q32_B_Part_11': 'Redshift',
        'Q32_B_Part_12': 'Aurora',
        'Q32_B_Part_13': 'RDS',
        'Q32_B_Part_14': 'DynamoDB',
        'Q32_B_Part_15': 'BigQuery',
        'Q32_B_Part_16': 'Google SQL',
        'Q32_B_Part_17': 'Firestore',
        'Q32_B_Part_18': 'BigTable',
        'Q32_B_Part_19': 'Spanner',
        'Q32_B_Part_20': 'None',
        'Q32_B_OTHER': 'Other'}

bi_tools_pro_map = {'Q34_A_Part_1': 'QuickSight',
        'Q34_A_Part_2': 'Power BI',
        'Q34_A_Part_3': 'Data Studio',
        'Q34_A_Part_4': 'Looker',
        'Q34_A_Part_5': 'Tableau',
        'Q34_A_Part_6': 'Salesforce',
        'Q34_A_Part_7': 'Einstein Analytics',
        'Q34_A_Part_8': 'Qlik',
        'Q34_A_Part_9': 'Domo',
        'Q34_A_Part_10': 'Spotfire',
        'Q34_A_Part_11': 'Alteryx',
        'Q34_A_Part_12': 'Sisense',
        'Q34_A_Part_13': 'SAP',
        'Q34_A_Part_14': 'Synapse',
        'Q34_A_Part_15': 'Thoughtspot',
        'Q34_A_Part_16': 'None',
        'Q34_A_OTHER': 'Other'}

bi_tools_non_pro_map = {'Q34_B_Part_1': 'QuickSight',
        'Q34_B_Part_2': 'Power BI',
        'Q34_B_Part_3': 'Data Studio',
        'Q34_B_Part_4': 'Looker',
        'Q34_B_Part_5': 'Tableau',
        'Q34_B_Part_6': 'Salesforce',
        'Q34_B_Part_7': 'Einstein Analytics',
        'Q34_B_Part_8': 'Qlik',
        'Q34_B_Part_9': 'Domo',
        'Q34_B_Part_10': 'Spotfire',
        'Q34_B_Part_11': 'Alteryx',
        'Q34_B_Part_12': 'Sisense',
        'Q34_B_Part_13': 'SAP',
        'Q34_B_Part_14': 'Synapse',
        'Q34_B_Part_15': 'Thoughtspot',
        'Q34_B_Part_16': 'None',
        'Q34_B_OTHER': 'Other'}

auto_ml_pro_map = {'Q36_A_Part_1': 'Data augmentation',
        'Q36_A_Part_2': 'Feature sel/engg',
        'Q36_A_Part_3': 'Model selection',
        'Q36_A_Part_4': 'Model arch searches',
        'Q36_A_Part_5': 'Hyperparameter tuning',
        'Q36_A_Part_6': 'Full pipeline',
        'Q36_A_Part_7': 'None',
        'Q36_A_OTHER': 'Other'}

auto_ml_non_pro_map = {'Q36_B_Part_1': 'Data augmentation',
        'Q36_B_Part_2': 'Feature sel/engg',
        'Q36_B_Part_3': 'Model selection',
        'Q36_B_Part_4': 'Model arch searches',
        'Q36_B_Part_5': 'Hyperparameter tuning',
        'Q36_B_Part_6': 'Full pipeline',
        'Q36_B_Part_7': 'None',
        'Q36_B_OTHER': 'Other'}

auto_ml_tools_pro_map = {'Q37_A_Part_1': 'Google',
        'Q37_A_Part_2': 'H2O',
        'Q37_A_Part_3': 'Databricks',
        'Q37_A_Part_4': 'DataRobot',
        'Q37_A_Part_5': 'SageMaker',
        'Q37_A_Part_6': 'Azure',
        'Q37_A_Part_7': 'None',
        'Q37_A_OTHER': 'Other'}

auto_ml_tools_non_pro_map = {'Q37_B_Part_1': 'Google',
        'Q37_B_Part_2': 'H2O',
        'Q37_B_Part_3': 'Databricks',
        'Q37_B_Part_4': 'DataRobot',
        'Q37_B_Part_5': 'SageMaker',
        'Q37_B_Part_6': 'Azure',
        'Q37_B_Part_7': 'None',
        'Q37_B_OTHER': 'Other'}

tools_manage_ml_pro_map = {'Q38_A_Part_1': 'Neptune.ai',
        'Q38_A_Part_2': 'Weights & Biases',
        'Q38_A_Part_3': 'Comet.ml',
        'Q38_A_Part_4': 'Sacred + Omniboard',
        'Q38_A_Part_5': 'TensorBoard',
        'Q38_A_Part_6': 'Guild.ai',
        'Q38_A_Part_7': 'Polyaxon',
        'Q38_A_Part_8': 'Trains',
        'Q38_A_Part_9': 'Domino',
        'Q38_A_Part_10': 'MLflow',
        'Q38_A_Part_11': 'None',
        'Q38_A_OTHER': 'Other'}

tools_manage_ml_non_pro_map = {'Q38_B_Part_1': 'Neptune.ai',
        'Q38_B_Part_2': 'Weights & Biases',
        'Q38_B_Part_3': 'Comet.ml',
        'Q38_B_Part_4': 'Sacred + Omniboard',
        'Q38_B_Part_5': 'TensorBoard',
        'Q38_B_Part_6': 'Guild.ai',
        'Q38_B_Part_7': 'Polyaxon',
        'Q38_B_Part_8': 'Trains',
        'Q38_B_Part_9': 'Domino',
        'Q38_B_Part_10': 'MLflow',
        'Q38_B_Part_11': 'None',
        'Q38_B_OTHER': 'Other'}

# %%
# Replacing required column names

d_27A.rename(columns=cloud_platform_pro_map,
          inplace=True)

d_27B.rename(columns=cloud_platform_non_pro_map,
          inplace=True)

d_29A.rename(columns=cloud_computing_pro_map,
          inplace=True)

d_29B.rename(columns=cloud_computing_non_pro_map,
          inplace=True)

d_31A.rename(columns=ML_products_pro_map,
          inplace=True)

d_31B.rename(columns=ML_products_non_pro_map,
          inplace=True)

d_32A.rename(columns=big_data_products_pro_map,
          inplace=True)

d_32B.rename(columns=big_data_products_non_pro_map,
          inplace=True)

d_34A.rename(columns=bi_tools_pro_map,
          inplace=True)

d_34B.rename(columns=bi_tools_non_pro_map,
          inplace=True)

d_36A.rename(columns=auto_ml_pro_map,
          inplace=True)

d_36B.rename(columns=auto_ml_non_pro_map,
          inplace=True)

d_37A.rename(columns=auto_ml_tools_pro_map,
          inplace=True)

d_37B.rename(columns=auto_ml_tools_non_pro_map,
          inplace=True)

d_38A.rename(columns=tools_manage_ml_pro_map,
          inplace=True)

d_38B.rename(columns=tools_manage_ml_non_pro_map,
          inplace=True)

# %%
# function to generate dataframe for plotly sunburst

def generate_dataframe_sunburst(df,col_name,experience):
  col_values=[]
  for col, values in df.iteritems():
    col_values+=[col]*(values.notnull().sum())
  data_column = pd.Series(col_values)
  experience_column = pd.Series([experience]*data_column.shape[0])

  df_sunburst = pd.DataFrame({col_name:data_column,
                                    "Experience":experience_column})
  return df_sunburst

# %%
#generating dataframes from different questions for plotly sunburst

cloud_platform_pro_df = generate_dataframe_sunburst(d_27A,'Cloud Platform','Professional')
cloud_platform_non_pro_df = generate_dataframe_sunburst(d_27B,'Cloud Platform','Non-Professional')
cloud_platform_sunburst_df = pd.concat([cloud_platform_pro_df,cloud_platform_non_pro_df],ignore_index=True)

cloud_computing_pro_df = generate_dataframe_sunburst(d_29A,'Cloud Computing','Professional')
cloud_computing_non_pro_df = generate_dataframe_sunburst(d_29B,'Cloud Computing','Non-Professional')
cloud_computing_sunburst_df = pd.concat([cloud_computing_pro_df,cloud_computing_non_pro_df],ignore_index=True)

ml_products_pro_df = generate_dataframe_sunburst(d_31A,'ML Products','Professional')
ml_products_non_pro_df = generate_dataframe_sunburst(d_31B,'ML Products','Non-Professional')
ml_products_sunburst_df = pd.concat([ml_products_pro_df,ml_products_non_pro_df],ignore_index=True)

bigdata_pro_df = generate_dataframe_sunburst(d_32A,'BigData Products','Professional')
bigdata_non_pro_df = generate_dataframe_sunburst(d_32B,'BigData Products','Non-Professional')
bigdata_sunburst_df = pd.concat([bigdata_pro_df,bigdata_non_pro_df],ignore_index=True)

bi_tools_pro_df = generate_dataframe_sunburst(d_34A,'BI tools','Professional')
bi_tools_non_pro_df = generate_dataframe_sunburst(d_34B,'BI tools','Non-Professional')
bi_tools_sunburst_df = pd.concat([bi_tools_pro_df,bi_tools_non_pro_df],ignore_index=True)

auto_ml_pro_df = generate_dataframe_sunburst(d_36A,'Auto ML','Professional')
auto_ml_non_pro_df = generate_dataframe_sunburst(d_36B,'Auto ML','Non-Professional')
auto_ml_sunburst_df = pd.concat([auto_ml_pro_df,auto_ml_non_pro_df],ignore_index=True)

auto_ml_tools_pro_df = generate_dataframe_sunburst(d_37A,'Auto ML tools','Professional')
auto_ml_tools_non_pro_df = generate_dataframe_sunburst(d_37B,'Auto ML tools','Non-Professional')
auto_ml_tools_sunburst_df = pd.concat([auto_ml_tools_pro_df,auto_ml_tools_non_pro_df],ignore_index=True)

manage_ml_pro_df = generate_dataframe_sunburst(d_38A,'Manage ML','Professional')
manage_ml_non_pro_df = generate_dataframe_sunburst(d_38B,'Manage ML','Non-Professional')
manage_ml_sunburst_df = pd.concat([manage_ml_pro_df,manage_ml_non_pro_df],ignore_index=True)

# %%
#plotting sunburst for cloud platforms

fig = px.sunburst(cloud_platform_sunburst_df, path=['Experience','Cloud Platform'],template='ggplot2',height=600,
                  hover_name='Cloud Platform',title='Popular Cloud Platforms')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * Number of non-professionals wanting to use Amazon Web Services (AWS), Google Cloud Platform (GCP), Microsoft Azure is approximately similar to number of professionals.
# * There is a slight increase in number of non-professionals wanting to use IBM, Oracle, SAP compared to professionals.

# %%
#plotting sunburst for cloud computing products

fig = px.sunburst(cloud_computing_sunburst_df, path=['Experience','Cloud Computing'],template='ggplot2',height=600,
                  hover_name='Cloud Computing',title='Popular Cloud Computing Products')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * There is a significant increase in number of non-professionals wanting to use Google Cloud Compute Engine and Azure VM compared to professionals
# * Amount is similar in case of Amazon Elastic Compute Cloud

# %%
#plotting sunburst for managed ML products

fig = px.sunburst(ml_products_sunburst_df, path=['Experience','ML Products'],template='ggplot2',height=600,
                  hover_name='ML Products',title='Popular Managed ML Products')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * Most of the professionals opted for none.
# * The leading among non-professionals is Google Cloud Vertex AI which is at 3rd place among professionals with a huge difference of nearly 1500 votes.

# %%
#plotting sunburst for BigData products

fig = px.sunburst(bigdata_sunburst_df, path=['Experience','BigData Products'],template='ggplot2',height=600,
                  hover_name='BigData Products',title='Popular BigData Products')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * There is a difference here in PostgreSQL, SQL, MongoDB and SQLite

# %%
#plotting sunburst for BI tools

fig = px.sunburst(bi_tools_sunburst_df, path=['Experience','BI tools'],template='ggplot2',height=600,
                  hover_name='BI tools',title='Popular BI Tools')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * Number of non-professionals who opted for Power BI are way less compared to professionals with a difference of around 2000
# * Another noticeable difference is number of non-professionals who opted for QuickSight are way Higher compared to professionals with a difference of around 2000

# %%
#plotting sunburst for categories of automated machine learning tools

fig = px.sunburst(auto_ml_sunburst_df, path=['Experience','Auto ML'],template='ggplot2',height=600,
                  hover_name='Auto ML',title='Popular categories of automated machine learning tools')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * Most of the professionals have opted None for the categories of Auto ML.
# * Other than that there are small difference around the categories of AutoML.

# %%
#plotting sunburst for automated machine learning tools

fig = px.sunburst(auto_ml_tools_sunburst_df, path=['Experience','Auto ML tools'],template='ggplot2',height=600,
                  hover_name='Auto ML tools',title='Popular automated machine learning tools')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * More non-professionals have opted for the AutoML tools with Google Cloud AutoML leading following that is Azure Automated Machine Learning in second place.

# %%
#plotting sunburst for managing ML experiments

fig = px.sunburst(manage_ml_sunburst_df, path=['Experience','Manage ML'],template='ggplot2',height=600,
                  hover_name='Manage ML',title='Popular tools for managing ML experiments')
fig.update_traces(textinfo='label+percent entry')
fig.show()

# %% [markdown]
# * This category is pretty similar from both the end execpt for more professionals have opted none.

# %% [markdown]
# ## Conclusion
#
# * As seen from the above plots it is evident that non-professionals have a bit of different thoughts on tools to use in upcoming future.
# * Maybe Kaggle can add in some more questions regarding why the non-professionals are selecting the tools that they are wanting to get familiarized themselves, in the upcoming 2022 survey.
#
# Until then BYE all, remeber stay safe and wash your hands, cover your mouth and nose.
#
# Maintain social distance. Have fun :)
