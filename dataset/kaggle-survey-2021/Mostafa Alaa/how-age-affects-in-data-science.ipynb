# %% [markdown]
# ![data-science-python-course-in-bangalore.jpg](attachment:b7dd4d2a-bf80-444e-8330-160c9b05795f.jpg)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-family:Verdana;
#            padding:10px;">
#     <h1 style="text-align:center;
#                color:white;
#                font-size:20px;">Table of Content</h1>
# </div>

# %% [markdown]
# 1. [**Introduction**](#section-zero)
# 2. [**Some Info before we start**](#section-one):
#
#     - [*Age Distribution*](#section-two)
#     - [*Degree Distribution*](#section-three)
#     - [*Experience Distribution*](#section-four)
#     - [*Annual Compensation Distribution*](#section-five)
#
# 3. [**Questions about age effects with other vars**](#section-six):
#
#    - [*How age affects the college degree?*](#section-seven)
#    - [*How age affects the Coding Experience?*](#section-eight)
#    - [*How age affects the Annual Compensation?*](#section-nine)
#
# 4. [**Questions about relations among other vars**](#section-ten):
#
#    - [*Is coding experience have a huge effect on Annual Compensation?*](#section-eleven)
#    - [*Is college degree have a huge effect on Annual Compensation?*](#section-twelve)
#
# 5. [**Let's reveal the facts. (Multivariate Analysis)**](#section-thirteen):
#
#    - [*Age, Experience and Annual Compensation (To know is this experience affects young people and they make money or not.)*](#section-fourteen)
#    - [*Age, Education and Annual Compensation (To know is this degree affects young people and they make money or not.)*](#section-fifteen)
#    - [*When does degrees higher than Master's degree increase the annual compensation for a person?*](#section-sixteen)
#    - [*Why Master's degree students in general get more than students with higher than Master's degree?*](#section-seventeen)
#
# 6. [**Your Duty to children and youth(Conclusion and Recommendations)**](#section-eighteen)
#
#    - [*Our duty as parents*](#section-nineteen)
#    - [*Our duty as government*](#section-twenty)
#
# 7. [**References**](#section-twenty-one)

# %% [markdown]
# <a id='section-zero'></a>
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-size:15px;
#            font-family:Verdana;
#            padding:20px">
#     <h1 style="text-align:center;
#                color:white;">Introduction</h1>
# </div>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;<span style="font-size:40px; font-family: sans-serif">Over</span> the years around the world, the demand for data scientists has been increasing. Some people think about completing their university studies and then thinking about working in this field while there are those who study through the electronic platforms available and then try to get any work available in the field but of course there is an important factor absent from those who will not wait to finish their university studies, which is the <strong>age</strong>. Is it really an influential factor to be afraid of? Or is this just fear for them because they are different from their colleagues who are waiting to finish their university. I think I'll be able to talk about it very focusedly because I belong to the second category, so I understand what they're thinking about.
# <br>
# <br>
# <br>
# &nbsp;&nbsp;&nbsp;Whether you're in the first or second category or even just want to work in data science, you'll often have some questions like: What are the requirements of companies to work in this field? Are there some of these requirements that I cannot get because they are beyond my means? The most important factor here is the age because it often comes with the educational degree and the Customer's trust in you and all of them are beyond our means(things we can do), so the question comes here: Is there a specific age to start working as a data scientist? Or is experience alone enough? Or rather, what is the right age to work in this field?ِ We're going to try to answer all these questions through Kaggle's 5th annual survey.
# <br>
# <br>
# <br>
# &nbsp;&nbsp;&nbsp;If you are an employer, a company manager, or even a government, remember that when you make the requirements to work for people beyond their means, such as age, you are involved in the destruction or suppression of talents that may contribute significantly to the development of your country, company or business, and then the world, because if they don't have such requirements, it's not their business. They did their best to work and had the skill to work in this job.<mark>I speak about those who are ready to work ;)</mark>
# <br>
# <br>
# <br>
# &nbsp;&nbsp;&nbsp;Age is usually associated with some other factors such as university degree and experience, all of which are in the interest of the annual salary, which is the goal and criterion that we will use to measure the effectiveness of each of these factors to see the whole picture of the effect of the age. It's known that money isn't all thing in the world and there are a lot of things better than money like religion, work-life balance, family and friends, but all of them don't relate to data science with an effective effect and we can't measure them for a person. We'll see the distribution of each variable of our interest to know what data do we have in depth and to know if there is a trend and to what part does the audience belong to, then we'll see what the important variables have to do with age and annual compensation, and also between each other using bivariate and multivariate analysis. Highlighting all of the important results we will find out and use them to make some helpful recommendations in the conclusion & recommendation part.
# <br>
# <br>
# <br>
# &nbsp;&nbsp;&nbsp;We'll use Python for analysis along with additional libraries. The libraries we'll use for data visualization are "Matplotlib", "seaborn" and "Plotly" because they are very wide and necessary tools for data visualization. The libraries we'll use for data analysis and data processing are "Numpy" and "Pandas" because they make it easy to manipulate the data and they are familiar with the majority of data scientists who use Python. In the most of our analysis we will use exactly "Plotly" because Plotly is an interactive, open-source plotting library that supports many unique chart types covering a wide range of area such as statistical, financial, geographic, scientific, and 3-dimensional use-cases. (All resources are at the end of the notebook don't forget to check them out)

# %% [markdown]
# <h1 style="color:#FF7F50">Datasets:</h1>
# <p>&nbsp;&nbsp;&nbsp;Here the data have been used are Kaggle annual survey datasets over the last three years; 2019, 2020 and 2021. Kaggle sets out to conduct an industry-wide survey that presents a truly comprehensive view of the state of data science and machine learning. 2021 annual survey was live from 09/01/2021 to 10/04/2021, and after cleaning the data they finished with 25,973 responses! 2020 annual survey was live for 3.5 weeks in October, and after cleaning the data they finished with 20,036 responses!2019 annual survey was live for three weeks in October, and after cleaning the data they finished with 19,717 responses!</p>
# <br>
# <p>&nbsp;&nbsp;&nbsp;In this article the data has been cleaned again and merged such that all the values that are refer to the same values in all of them have been set to a fixed common value in all of them and have been put in a single dataframe (without removing each single dataframe). Also in all of them some ranges wasn't fixed with the same values as others, so they also have been set to fixed ranges such that those ranges would be fixed for all of them </p>

# %%
# !pip install pywaffle

# %%
# Data Analysis
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
from pywaffle import Waffle
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Setting up
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# Data
survey21 = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')
survey20 = pd.read_csv('../input/kaggle-survey-2020/kaggle_survey_2020_responses.csv')
survey19 = pd.read_csv('../input/kaggle-survey-2019/multiple_choice_responses.csv')

# %%
# Here we want to select our features of interest and prepare them in this analysis which are:
# Most Important --> 'Age', 'University Degree', 'Annual compensation', 'Experience or years of writing code or dealing with data'
# Less Important --> 'platforms', 'country', 'Role name' and "Desktop or laptop"

# We will do that in two phases:
# First, we will select the columns and dealing with them if one of them has many columns
# Second, we will rename each column with appropriate name (putting same name in each survey dataframe through the years)


# Let's start in this cell with 2021

# 1st
# After some codes we found that and see the descriptive file:
# Q1 : 'Age'
# Q4 : 'Degree'
# Q25 : 'Annual compensation'
# Q6 : 'Experience'


# Q5 -> 'Role name' or 'Job title'
# Q3 -> 'Country'
# Q11 -> "Device" or 'Laptop or Computer'  We will speak about it in extra section, but with 2021 only 
# Q40 -> 'Platforms'  it has multiple columns and we may put it in the "Extra Section" in the article

# We will call the updated dataframe srv21

features_of_interest = ['Q1', 'Q3', 'Q4', 'Q5', 'Q6', 'Q25']
srv21 = survey21[features_of_interest]
srv21 = srv21[1:]  # To exclude first row
# 2nd
srv21.columns = ['Age', 'Country', 'College_degree', 'Job_title', 'Experience', 'Annual_compensation']

# %%
# Now with 2020
# After checking it, it seems exactly as survey21 (in the columns' places and names so we will do the same)
# The question here and the point that want to be checked is it the same choices or not because if it is not we must fix it.

features_of_interest = ['Q1', 'Q3', 'Q4', 'Q5', 'Q6', 'Q25']
srv20 = survey20[features_of_interest]
srv20 = srv20[1:]  # To exclude first row
# 2nd
srv20.columns = ['Age', 'Country', 'College_degree', 'Job_title', 'Experience', 'Annual_compensation']

# %%
# Now with 2019
# After checking it, it seems somewhat as survey20 (in the columns' places and names so we will do the same except some updates)
# The question here and the point that want to be checked is it the same choices or not because if it is not we must fix it all that after
# after updating it like what we'll do with 2020 dataframe.

features_of_interest = ['Q1', 'Q3', 'Q4', 'Q5', 'Q15', 'Q11']
srv19 = survey19[features_of_interest]
srv19 = srv19[1:]  # To exclude first row
# 2nd
srv19.columns = ['Age', 'Country', 'College_degree', 'Job_title', 'Experience', 'Annual_compensation']

# %%
# Ordinal vars before updating in 2021
Age_order = ['18-21', '22-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-69', '70+']
experience_order = ['I have never written code', '< 1 years', '1-3 years', '3-5 years', '5-10 years', '10-20 years', '20+ years']

money_order = ['$0-999', '1,000-1,999', '2,000-2,999', '3,000-3,999', '4,000-4,999', '5,000-7,499', '7,500-9,999', '10,000-14,999',
               '15,000-19,999', '20,000-24,999', '25,000-29,999', '30,000-39,999', '40,000-49,999', '50,000-59,999', '60,000-69,999',
               '70,000-79,999', '80,000-89,999', '90,000-99,999', '100,000-124,999', '125,000-149,999', '150,000-199,999', '200,000-249,999',
               '250,000-299,999', '300,000-499,999', '$500,000-999,999', '>$1,000,000']

degree_order = ['I prefer not to answer', 'No formal education past high school',
                "Some college/university study without earning a bachelor’s degree",
                "Bachelor’s degree", "Master’s degree", "Doctoral degree",
                'Professional doctorate']

# %%
# Now we want to fix the values in the values of each feature of interest
# 'Age', 'Country', 'College_degree', 'Job_title', 'Experience', 'Annual_compensation'


# Age
# we interested in those ranges : '18-21', '22-24', '25-29', '30-34', '35-39', '40+'
replace_me = ['40-44', '45-49', '50-54', '55-59', '60-69', '70+']
s19, s20 = srv19['Age'].replace(replace_me, '40+'), srv20['Age'].replace(replace_me, '40+')
s21 = srv21['Age'].replace(replace_me, '40+')
srv19['Age'], srv20['Age'], srv21['Age'] = s19, s20, s21





# Countries
# we will deal only with the common countries which are 50 countries
countries_of_interest = pd.Series(list(set(srv20['Country']).intersection(set(srv21['Country'])).intersection(set(srv19['Country']))))
# Those was countries we will use for the extra section not for the main topic








# College Degree
# To make the three sets equals we must fix the 'professional doctoral' in srv21 to 'professional degree'
s = srv21['College_degree'].replace(['Professional doctorate'], 'Professional degree')
srv21['College_degree'] = s

# We want to divide degrees into three ranges: under bachelor, bachelor, master and after master
replace_me = ['I prefer not to answer', 'No formal education past high school',
                "Some college/university study without earning a bachelor’s degree"]

# Less than Bachelor
s19, s20 = srv19['College_degree'].replace(replace_me, 'Less than bachelor'), srv20['College_degree'].replace(replace_me, 'Less than bachelor')
s21 = srv21['College_degree'].replace(replace_me, 'Less than bachelor')
srv19['College_degree'], srv20['College_degree'], srv21['College_degree'] = s19, s20, s21

# After Master
replace_me = ["Doctoral degree", 'Professional degree']
s19, s20 = srv19['College_degree'].replace(replace_me, 'After Master'), srv20['College_degree'].replace(replace_me, 'After Master')
s21 = srv21['College_degree'].replace(replace_me, 'After Master')
srv19['College_degree'], srv20['College_degree'], srv21['College_degree'] = s19, s20, s21







# Job title
# We will put any values but values of interest in the section 'Other'
values_of_interest = {'Student', 'Data Scientist', 'Data Analyst', 'Business Analyst', 'Software Engineer', 'Data Engineer', 'DBA/Database Engineer', 'Research Scientist', 'Statistician'}
s19 = srv19['Job_title'].replace([job for job in set(srv19['Job_title']) if job not in values_of_interest], 'Other')
s20 = srv20['Job_title'].replace([job for job in set(srv20['Job_title']) if job not in values_of_interest], 'Other')
s21 = srv21['Job_title'].replace([job for job in set(srv21['Job_title']) if job not in values_of_interest], 'Other')
srv19['Job_title'], srv20['Job_title'], srv21['Job_title'] = s19, s20, s21








# Experience
# We will be interested in some values only called 'values_of_interest'
# Years 1–3: Junior; Years 3–5: Mid-level; Years 5-10: Senior; Years 10+: Principal/Architect; 


values_of_interest = ['I have never written code', '< 1 years', '1-3 years', '3-5 years', '5-10 years', '10+ years']
# Range 1 and Range 2 is fixed itself we will start with Range 3
s19, s20 = srv19['Experience'].replace(['1-2 years'], '1-3 years'), srv20['Experience'].replace(['1-2 years'], '1-3 years')
srv19['Experience'], srv20['Experience'] = s19, s20
# srv21 fixed itself


# Range 4 and Range 5 are fixed let's go to Last Range
s19, s20 = srv19['Experience'].replace(['10-20 years', '20+ years'], '10+ years'), srv20['Experience'].replace(['10-20 years', '20+ years'], '10+ years')
s21 = srv21['Experience'].replace(['10-20 years', '20+ years'], '10+ years')
srv19['Experience'], srv20['Experience'], srv21['Experience'] = s19, s20, s21








# Annual Compensation
# we will set the annual compensation into four ranges <1000, 1000-9,999, 10,000-99,999, 100,000<=

# Range 1
s19, s20 = srv19['Annual_compensation'].replace(['$0 (USD)', '$1-$99', '$100-$999'], '< $1000'), srv20['Annual_compensation'].replace(['$0 ($USD)', '$1-$99', '$100-$999'], '< $1000')
srv19['Annual_compensation'], srv20['Annual_compensation'] = s19, s20
s21 = srv21['Annual_compensation'].replace(['$0-999'], '< $1000')
srv21['Annual_compensation'] = s21

# Range 2
s19, s20 = srv19['Annual_compensation'].replace(['$1000-$9,999'], '1,000-9,999'), srv20['Annual_compensation'].replace(['$1000-$9,999'], '1,000-9,999')
srv19['Annual_compensation'], srv20['Annual_compensation'] = s19, s20
s21 = srv21['Annual_compensation'].replace(['1,000-1,999', '2,000-2,999', '3,000-3,999', '4,000-4,999', '5,000-7,499', '7,500-9,999'], '1,000-9,999')
srv21['Annual_compensation'] = s21

# Range 3
s19, s20 = srv19['Annual_compensation'].replace(['$10,000-$99,999'], '10,000-99,999'), srv20['Annual_compensation'].replace(['$10,000-$99,999'], '10,000-99,999')
srv19['Annual_compensation'], srv20['Annual_compensation'] = s19, s20
s21 = srv21['Annual_compensation'].replace(['10,000-14,999',
               '15,000-19,999', '20,000-24,999', '25,000-29,999', '30,000-39,999', '40,000-49,999', '50,000-59,999', '60,000-69,999',
               '70,000-79,999', '80,000-89,999', '90,000-99,999'], '10,000-99,999')
srv21['Annual_compensation'] = s21

# Range 4
s19, s20 = srv19['Annual_compensation'].replace(['> $100,000 ($USD)'], '> $100,000'), srv20['Annual_compensation'].replace(['$100,000 or more ($USD)'], '> $100,000')
srv19['Annual_compensation'], srv20['Annual_compensation'] = s19, s20
s21 = srv21['Annual_compensation'].replace(['100,000-124,999', '125,000-149,999', '150,000-199,999', '200,000-249,999',
               '250,000-299,999', '300,000-499,999', '$500,000-999,999', '>$1,000,000'], '> $100,000')
srv21['Annual_compensation'] = s21


# So we finished fixing the values of each feature in all the wanted years

# %%
# Ordinal vars Agter updating in all years
age_order = ['18-21', '22-24', '25-29', '30-34', '35-39', '40+']

experience_order = ['< 1 years', '1-3 years', '3-5 years', '5-10 years', '10+ years']

money_order = ['< $1000', '1,000-9,999', '10,000-99,999', '> $100,000']

degree_order = ['Less than bachelor', "Bachelor’s degree", "Master’s degree", 'After Master']

# %%
# Merging the dataframes
srv19['year'] = 2019
srv20['year'] = 2020
srv21['year'] = 2021
srv_all = srv19.append(srv20).append(srv21)

# %%
# For plotting any categorical variable (to see the distribution)
class one_cat:
    
    def __init__(self, data, col, title, xlabel=None, ylabel=None, width=400, height=400):
        self.data = data
        self.col = col
        self.title = title
        self.xlabel = xlabel
        self.ylabel = ylabel
        self.width = width
        self.height = height
        
        
        
        
        
        
    # To plot a distribution for our catigorical variable if it has no specific order(nominal)
    def distribution_nominal(self , orientation='v',template='plotly'):
        
        '''
        Plotting your categorical variable if it is nominal (Has no order like Country names)
        orientation: To choose plottin the bars in a vertical representation or horizontal
        template: The template of your plotly graph
        '''
        
        # Figure itself
        
        # Vertical
        if orientation == 'v':
        
            fig = px.histogram(self.data, x=self.col,
                               width=600, 
                               height=500,
                               histnorm='percent',
                               template=template
                               )
            # Some Updates
            fig.update_layout(title=self.title, 
                          font_family="San Serif",
                          titlefont={'size': 20},
                          showlegend=True,
                          legend=dict(
                              orientation="v",
                              y=1.0, 
                              yanchor="top", 
                              x=1.0, 
                              xanchor="right"
                          )                 
                         ).update_xaxes(categoryorder='total descending')
            
            
            
            
        # Horizontal
        else:
            
            
            fig = px.histogram(self.data, 
                   y=self.col,
                   orientation='h',
                   width=600,
                   height=350,
                   histnorm='percent',
                   template=template
                   )
            
            # Some Updates
            fig.update_layout(title=self.title, 
                              font_family="San Serif",
                              titlefont={'size': 20},
                              showlegend=True,
                              legend=dict(
                                  orientation="v",
                                  y=1.0, 
                                  yanchor="top", 
                                  x=1.0, 
                                  xanchor="right"
                              )                 
                             ).update_yaxes(categoryorder='total ascending')
        
        
        
        
        
        
        # Traces Updates
        fig.update_traces(marker_color=None, marker_line_color='white',
                          marker_line_width=1.5, opacity=0.99)
        fig.show() 
        
      
    
    
    # To plot a distribution for our catigorical variable if it has specific order(ordinal)
    def distribution_ordinal(self, the_specific_order, orientation='v', template='plotly'):
        
        '''
        Plotting your categorical variable if it is ordianl (Has order eg: small, medium and large)
        the_specific_order: The right order of your categorical variable
        orientation: To choose plotting the bars in a vertical representation or horizontal
        template: The template of your plotly graph
        '''
        
        # Figure itself
        if orientation == 'v':
            
            # Vertical
            fig = px.histogram(self.data, x=self.col,
                               width=self.width, height=self.height,
                               histnorm='percent',
                               template=template,
                               category_orders={
                                   self.col: the_specific_order
                               }
                               )
            # Some Updates
            fig.update_layout(title=self.title, 
                          font_family="San Serif",
                          titlefont={'size': 20},
                          showlegend=True,
                          legend=dict(
                              orientation="v",
                              y=1.0, 
                              yanchor="top", 
                              x=1.0, 
                              xanchor="right"
                          )                 
                         )
            
            
        else:
            
            # Horizontal
            fig = px.histogram(self.data, 
                   y=self.col,
                   orientation='h',
                   width=self.width,height=self.height,
                   histnorm='percent',
                   template=template,
                   category_orders={
                                   self.col: the_specific_order
                               }
                   )
            
            # Some Updates
            fig.update_layout(title=self.title, 
                              font_family="San Serif",
                              titlefont={'size': 20},
                              showlegend=True,
                              legend=dict(
                                  orientation="v",
                                  y=1.0, 
                                  yanchor="top", 
                                  x=1.0, 
                                  xanchor="right"
                              )                 
                             )
        
        
        
        
        # Traces Updates
        fig.update_traces(marker_color=None, marker_line_color='white',
                          marker_line_width=1.5, opacity=0.99)
        fig.show() 
        
        
        
        
        
        
        
        
    def pie(self):
        
        '''
        Plotting Pie chart with the default colors
        '''
        
        fig = px.pie(self.data, self.col, 
                     title=self.title, 
                     hole=0.6)
        fig.update_traces(textposition='inside', textinfo='percent+label')
        fig.update_layout(uniformtext_minsize=10, uniformtext_mode='hide')
        fig.show()
        
        
        
        
        
        
        
        
        
        
        
        
    # As blocks
    def waffle(self, title):
        '''
        Plotting your categorical variable in blocks without specific shapes
        title: The title of your chart
        '''
        
        df = self.data
        var = self.col
        
        # Take as input a dataframe and variable, and return a Pandas series with
        # approximate percentage values for filling out a waffle plot.
      
        # compute base quotas
        percentages = 100 * df[var].value_counts() / df.shape[0]
        counts = np.floor(percentages).astype(int) # integer part = minimum quota
        decimal = (percentages - counts).sort_values(ascending = False)

        # add in additional counts to reach 100
        rem = 100 - counts.sum()
        for cat in decimal.index[:rem]:
            counts[cat] += 1

            
        waffle_counts = counts
        prev_count = 0
        # for each category,
        for cat in range(waffle_counts.shape[0]):
            # get the block indices
            blocks = np.arange(prev_count, prev_count + waffle_counts[cat])
            # and put a block at each index's location
            x = blocks % 10 # use mod operation to get ones digit
            y = blocks // 10 # use floor division to get tens digit
            plt.bar(x = y, height = 0.8, width = 0.8, bottom = x)
            prev_count += waffle_counts[cat]

        # aesthetic wrangling
        plt.legend(waffle_counts.index, bbox_to_anchor = (1, 0.5), loc = 6)
        plt.axis('off')
        plt.axis('square')
        plt.title(title, size=20)
        plt.show()
        
        
        
        
        
        
        
    def waffle_with_shape(self, order, shape='child'):
        
        '''
        Plotting your categorical variable in blocks with specific shapes
        title: The title of your chart
        shape: The shape name
        '''
        series = self.data[self.col].dropna().value_counts()
        series = 100*series // series.sum()
        d = {Range:value for Range, value in zip(series.index, series.values)}
        data = {Range:d[Range] if Range in d else 0 for Range in order}
        fig = plt.figure(
            FigureClass=Waffle, 
            rows=8, 
            values=data, 
            legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
            icons=shape, icon_size=20, 
            icon_legend=True,
            title={'label': self.title, 'loc': 'left', 'size':20}
        )
        fig.show()
        
        
        
        
        
    def updated_pie_chart(self, title, colors):
        '''
        Plotting your categorical variable with Pie chart having the variable name in it's center and with your specific colors
        title: The title of the graph
        colors: List of colors to each value of variable's values
        '''
        fig = go.Figure()
        fig.add_trace(
            go.Pie(
                labels=self.data[self.col],
                values=None,
                hole=.4,
                title=title,
                titlefont={'color':None, 'size':22},
                )
            )
        fig.update_traces(
            hoverinfo='label+value',
            textinfo='label+percent',
            textfont_size=14,
            marker=dict(
                colors=colors,
                line=dict(color='#000000',
                   
                          width=2)
                )
            )
        
        # Updating the layout
        fig.update_layout(title=self.title, 
                          font_family="San Serif",
                          bargap=0.2,
                          titlefont={'size': 24},
                          legend=dict(
                          orientation="v", y=1, yanchor="top", x=1.25, xanchor="right")                 
                          )
        fig.show()

# %%
# Two Categorical Values (color through each value)
class two_cat:
    
    def __init__(self, data, col, hue, title, width, height, xlabel=None, ylabel=None):
        self.data = data
        self.col = col
        self.hue = hue
        self.title = title
        self.width = width
        self.height = height
        self.xlabel = xlabel
        self.ylabel = ylabel
        
    def bar_group_nominal(self, orientation='v', template='plotly'):
        '''
        Plotting grouped bar graph if you have your variables nominal
        orientation: To choose plotting the bars in a vertical representation or horizontal
        template: The template of your plotly graph
        '''
        
        # Vertical
        if orientation == 'v':
            
            fig = px.histogram(self.data, x=self.col, y=None, color=self.hue,
                            width=self.width,height=self.height,
                            histnorm='percent', # By percentage not by counts
                            template=template)
                               
            fig.update_layout(title=self.title, 
                          font_family="San Serif",
                          bargap=0.2,
                          barmode='group',
                          titlefont={'size': 24},
                          legend=dict(
                          orientation="v", y=1, yanchor="top", x=1.25, xanchor="right")                 
                          ).update_xaxes(categoryorder='total descending')
                
        # Horizontal
        elif orientation == 'h':
            
            fig = px.histogram(self.data, y=self.col, x=None, color=self.hue,
                               orientation='h',
                               width=self.width, height=self.height,
                               histnorm='percent', # By percentage not by counts
                               template=template
                            )
            
            fig.update_layout(title=self.title, 
                              font_family="San Serif",
                              bargap=0.2,
                              barmode='group',
                              titlefont={'size': 24},
                              legend=dict(
                              orientation="v", y=1, yanchor="top", x=1.25, xanchor="right")                 
                              ).update_yaxes(categoryorder='total ascending')
            
        fig.show()
        
        
        
        
    def bar_group_ordinal(self, order, orientation='v', template='plotly'):
        '''
        Plotting grouped bar graph if you have your variables ordinal
        orientation: To choose plotting the bars in a vertical representation or horizontal
        template: The template of your plotly graph
        '''
        
        # The graph itself
        
        # Vertical
        if orientation == 'v':
            
            fig = px.histogram(self.data, x=self.col, y=None, color=self.hue,
                               width=self.width,height=self.height,
                               histnorm='percent', # By percentage not by counts
                               category_orders={
                                   self.col:order
                               },
                               template=template)
                      
            # Updating the layout
            fig.update_layout(title=self.title, 
                          font_family="San Serif",
                          bargap=0.2,
                          barmode='group',
                          titlefont={'size': 24},
                          legend=dict(
                          orientation="v", y=1, yanchor="top", x=1.25, xanchor="right")                 
                          )
                 
        # Horizontal                
        elif orientation == 'h':
            
            fig = px.histogram(self.data, y=self.col, x=None, color=self.hue, 
                               orientation='h',
                               width=self.width, height=self.height,
                               histnorm='percent', # By percentage not by counts
                               category_orders={
                                   self.col:order
                               },
                               template=template
                            )
            
            # Updating the layout
            fig.update_layout(title=self.title, 
                              font_family="San Serif",
                              bargap=0.2,
                              barmode='group',
                              titlefont={'size': 24},
                              legend=dict(
                              orientation="v", y=1, yanchor="top", x=1.25, xanchor="right")                 
                              )
            
        fig.show()
        
        
        
        
        
        
    # It's source will be in the appendix section Thanks "GEORGII VYSHNIA"
    def catscatter(self, colx_order, coly_order, color=['grey','black'], ratio=180, font='Helvetica'):
        '''
        It's name abbreviation for Categorical scatter, so from it's name it's very likely to scatter that you know but for categorical variables.
        The size of each point varies by the percentage of the existence of each value in variable1 in variable2
        colx_order: the order of variable1
        coly_order: the order of variable2
        color: the colors of them (Be careful it's not easy to be determined)
        ratio: the size of the points (overall not specific point)
        font: the font of your words
        '''
        agg_data = self.data.groupby([self.col, self.hue]).size().reset_index(name='respondent_count')
        # this will generate the count, but we want the ratio of each range in var1 in each range in var2 so we will use the following
        agg_data['ratio'] = 0
        
        for var1_val in colx_order:
            summ = agg_data[agg_data[self.col] == var1_val]['respondent_count'].sum()
            
            for var2_val in coly_order:

                row = agg_data[ (agg_data[self.col] == var1_val) & (agg_data[self.hue] == var2_val) ]
                value = row['respondent_count'].values[0]
                agg_data.loc[(agg_data[self.col] == var1_val) & (agg_data[self.hue] == var2_val), 'ratio'] = round(value / summ*100, 2)
               


        # this will prevent manifesting a little bug of catscatter 
        # casting age and gender to int64 as a result of the catscatter plotting below
        agg_data_copy = agg_data.copy()
        colx = self.col
        coly = self.hue
        df = agg_data_copy
        cols = 'ratio'
        # Create a dict to encode the categeories into numbers (sorted)
        colx_codes=dict(zip(colx_order,range(len(df[colx].unique()))))
        coly_codes=dict(zip(coly_order[::-1],range(len(df[coly].unique()))))

        # Apply the encoding
        df[colx]=df[colx].apply(lambda x: colx_codes[x])
        df[coly]=df[coly].apply(lambda x: coly_codes[x])


        # Prepare the aspect of the plot
        plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
        plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
        plt.rcParams['font.sans-serif']=font
        plt.rcParams['xtick.color']=color[-1]
        plt.rcParams['ytick.color']=color[-1]
        plt.box(False)


        # Plot all the lines for the background
        for num in range(len(coly_codes)):
            plt.hlines(num,-1,len(colx_codes)+1,linestyle='dashed',linewidth=1,color=color[num%2],alpha=0.5)
        for num in range(len(colx_codes)):
            plt.vlines(num,-1,len(coly_codes)+1,linestyle='dashed',linewidth=1,color=color[num%2],alpha=0.5)

        
        # Plot the scatter plot with the numbers
        plt.scatter(df[colx],
                   df[coly],
                   s=df[cols]*ratio,
                   zorder=2,
                   color=color[-1])
        
        # To annotate the scatter plot
        agg_data_copy = agg_data.copy()
        xmap = {order:val for order, val in zip(colx_order, range(len(colx_order)) ) }
        ymap = {order:val for order, val in zip(coly_order, range(len(coly_order))[::-1] ) }
        for var1_val in colx_order:
            x_place = xmap[var1_val]
            
            for var2_val in coly_order:
                y_place = ymap[var2_val]
                percentage = agg_data_copy.loc[ (agg_data_copy[colx] == var1_val) & (agg_data_copy[coly] == var2_val)  ,'ratio'].values[0]
                plt.annotate(str(percentage)+'%', (x_place+.1, y_place+.1), size=30)

        # Change the ticks numbers to categories and limit them
        plt.xticks(ticks=list(colx_codes.values()),labels=colx_codes.keys(),rotation=90)
        plt.yticks(ticks=list(coly_codes.values()),labels=coly_codes.keys())
        plt.xlim(xmin=-1,xmax=len(colx_codes))
        plt.ylim(ymin=-1,ymax=len(coly_codes))
        
        # Some updates
        plt.xticks(fontsize=30)
        plt.yticks(fontsize=30)
        if self.xlabel:
            plt.xlabel(self.xlabel, size=50, color='gray')
            
        if self.ylabel:
            plt.ylabel(self.ylabel, size=50, color='gray')
            
            
        plt.savefig('cat.png')
        plt.show()
        
        
        
        
        
    def stacked_plot(self, colx_order, coly_order, template='plotly', colors=None):
        
        '''
        Plotting stacked plot for your categorical variables if they are nominal
        colx_order: The order of values of your first variable
        coly_order : The order of values of your second variable
        '''
        
        agg_data = self.data.groupby([self.col, self.hue]).size().reset_index(name='respondent_count')
        # This will generate the count, but we want the ratio of each range in var1 in each range in var2 so we will use the following
        agg_data['ratio'] = 0
        
        for var1_val in colx_order:
            summ = agg_data[agg_data[self.col] == var1_val]['respondent_count'].sum()

            for var2_val in coly_order:
                row = agg_data[ (agg_data[self.col] == var1_val) & (agg_data[self.hue] == var2_val) ] # Data of interest
                value = row['respondent_count'].values[0] if row['respondent_count'].values else 0
                agg_data.loc[(agg_data[self.col] == var1_val) & (agg_data[self.hue] == var2_val), 'ratio'] = round(value / summ*100, 2) # Put the ratio of each value in variable1 due to each value in varibale 2
        
        
        # Plotting them as bar graph, but with the color argument
        fig = px.bar(
            agg_data,
            template=template,
            x=self.col, 
            y='ratio', 
            color=self.hue, 
            title=self.title, 
            height=400,
            category_orders={
                self.col: colx_order,
                self.hue: coly_order
            },
            color_discrete_map={
                value: colors[i] for value, i in zip(coly_order, range(len(colors)))
            })
        fig.show()
        
        
        
        
        
    def bar_group_ordinal_own_colors(self, colx_order, hue_order, colors, arrow_positions, template='plotly'):
        
        '''
        The grouped by graph is doing the same as the normal grouped bar graph but with your specific arrow and colors
        colx_order: The order of values of your first variable
        hue_order: The order of values of your second variable
        colors: List of colors having a color for each value in variable2 or the hue
        arrow_positions: List having four values to specify the start point (x0, y0) and the end point (x1, y1) for your arrow. Ex: [x0, y0, x1, y1] or [xtail, ytail, xhead, yhead]
        '''
        # Reverse the order for better representation
        colx_order = colx_order[::-1]
        
        fig = go.Figure()
        fig.update_layout(
            autosize=False,
            width=self.width,
            height=self.height,)
        
        # Plotting first var in each value of second var
        for val, color in zip(hue_order, colors):
            
            # To select values of interest and order them
            data_of_interest = self.data[self.data['year'] == val]
            y_values = data_of_interest[self.col].value_counts()
            y_values = y_values / y_values.sum()*100
            mapping = {y_values_index:y_values_value for y_values_index, y_values_value in zip(y_values.index, y_values.values)}
            y = [mapping[x_val] for x_val in colx_order]
            
            
            # Plot it
            fig.add_trace(go.Bar(
                y=colx_order,
                x=y,
                orientation='h',
                name=val,
                marker_color=color
            ))

        # Here we modify the tickangle of the xaxis, resulting in rotated labels.
        fig.update_layout(barmode='group', xaxis_tickangle=-45)
        
        
        # Those arrows are for this case you can change them for your graph
        # Arrow
        xtail, ytail, xhead, yhead = arrow_positions
        arrow = go.layout.Annotation(dict(
                        x= xhead, y= yhead, # Head of the arrow position
                        xref="x", yref="y",
                        
                        # Text
                        text="2021 to 2019",
                        textangle=90,
                        font_size=20,
                        xanchor='left',
                        yanchor='top',
            
                        showarrow=True,
                        axref = "x", ayref='y',
                        ax= xtail, ay= ytail, # Tail of the arrow position
                        arrowhead = 3,
                        arrowwidth=1.5,
                        arrowcolor='rgb(255,51,0)')
                    )

        fig.update_layout(
        annotations= [arrow],)
        
        
        # Updating the layout
        fig.update_layout(title=self.title, template=template,
                          font_family="San Serif",
                          bargap=0.2,
                          titlefont={'size': 24},
                          legend=dict(
                          orientation="v", y=1, yanchor="top", x=1.25, xanchor="right")                 
                          )
            
        fig.show()

# %% [markdown]
# <h2>All the comming ranges divided for a specific purpose:</h2>

# %% [markdown]
# <div style="display: flex;
#         width: 100%;
#         justify-content: center;">
#     <div class="card text-white bg-warning mb-3" style="max-width: 18rem;float:left; margin-right: 20px">
#       <div class="card-header" style="text-align:center; background-color:orange; color:white; border-radius:30% 30% 0% 0%">Age Ranges</div>
#       <div class="card-body" style="width:200px">
#         <br>
#         <ul>
#           <li><p class="card-text">18-21</p>
#           <li><p class="card-text">22-24</p>
#           <li><p class="card-text">25-29</p>
#           <li><p class="card-text">30-34</p>
#           <li><p class="card-text">35-39</p>
#           <li><p class="card-text">40+</p>
#         </ul>
#       </div>
#     </div>
#     <div class="card text-white bg-info mb-3" style="max-width: 18rem; float:left; margin-right:20px">
#       <div class="card-header" style="text-align:center; background-color: blue; color:white; border-radius:30% 30% 0% 0%">Experience Ranges</div>
#       <div class="card-body" style="width:260px">
#         <br>
#         <ul>
#           <li><p class="card-text">Never Code</p>
#           <li><p class="card-text">less than 1 year</p>
#           <li><p class="card-text">1-3 years (Junior)</p>
#           <li><p class="card-text">3-5(Mid-level)</p>
#           <li><p class="card-text">5-10 (Seniors)</p>
#           <li><p class="card-text">10+(Principal/Architect)</p>
#         </ul>
#       </div>
#     </div>
#     <div class="card text-white bg-danger mb-3" style="max-width: 18rem; float:left; margin-right:20px">
#       <div class="card-header" style="text-align:center; background-color:purple; color:white; border-radius:30% 30% 0% 0%">Salary Ranges</div>
#       <div class="card-body" style="width:200px">
#         <br>
#         <ul>
#           <li><p class="card-text">Less than 1000</p>
#           <li><p class="card-text">1,000-9,999</p>
#           <li><p class="card-text">10,000-99,999</p>
#           <li><p class="card-text">100,000+</p>
#         </ul>
#       </div>
#     </div>
#     <div class="card text-white bg-success mb-3" style="max-width: 18rem;float:left; margin-right:20px">
#       <div class="card-header" style="text-align:center; background-color:green; color:white; border-radius:30% 30% 0% 0%">Education Ranges</div>
#       <div class="card-body" style="width:200px">
#         <br>
#         <ul>
#           <li><p class="card-text">Less than Bachelor</p>
#           <li><p class="card-text">Bachelor's degree</p>
#           <li><p class="card-text">Master's degree</p>
#           <li><p class="card-text">After Master</p>
#         </ul>
#       </div>
#     </div>
# </div>

# %% [markdown]
# - **Age and Experience Ranges** are divided for the title in the parentheses
# - **Salary Ranges**: Divided as the first range is the those who earned less than the average salary even in the Low-income countries, second range for those who get the average salaries in the Low-income countries, third range for those who get the average salaries in the High-income countries and the last range for those who get above that average.
# - **Education Level**: Divided as the first range will be those who don't have or intend to have Bachelor's degree (There is no need to specify those because the most effective requirement in them is Bachelor as the majority of the jobs require having Bachelor's degree or more, some of them specify the higher than Bachelor's degree they require) then Bachelor's degree, Master's degree and Higher than Master's degree.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#   <b>Note:</b> we will exclude people who neven write code.
# </div>

# %%
srv_all = srv_all.query('Experience != "I have never written code"')
srv21 = srv21.query('Experience != "I have never written code"')

# %% [markdown]
# <a id='section-one'></a>
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-size:15px;
#            font-family:Verdana;
#            padding:20px">
#     <h1 style="text-align:center;
#                color:white;">Some info before we start✍</h1>
# </div>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;Here we will take a quick look about the most important variables Age, College degree, Coding Experience and Annual Compensation with a graph showing its distribution over the years in general then in 2021. Also the graph details will be discussed and interpreted including the unexpected scenarios that have happened. Also we will highlight the most important sentences or bold the important words. Some of them will be colored red to tell you that it is important and we will discuss some of those important sentences in the coming sections.

# %% [markdown]
# <a id='section-two'></a>
# # Age

# %%
age = two_cat(srv_all, 'Age', 'year', 'Age distribution over the years', 600, 800)
age.bar_group_ordinal_own_colors(age_order, [2019, 2020, 2021], ['#1B4157', '#437C9B', '#71A6C1'], [25, 5, 25, 1], template='plotly_white')
age = one_cat(srv21, 'Age', 'Age Distribution in 2021')
age.waffle_with_shape(age_order)

# %% [markdown]
# Ummm, we can see some important things:
# 1. The number of young undergraduates(or even high school) has increased over the years, which means that awareness of data science is spreading among adolescents and this may make competition stronger; because people interested in studying from a young age may be more serious than those who have learned and started just for their college. Of course, this is not all cases, some just learn it; only because it is a trend among young people so he want to be cool like them. (<mark><b>Work hard college students and graduates teens may compete you !</b></mark>)
#
# 2. Data Scientists in the range 22 to 24 has a fixed ratio over the years (**Be attention that is the range of people who get their first job at regular basis** or even work in general) and that isn't a good thing (not to increase their ratio of contribution in Kaggle community or even improve their skills ) because that maybe cause for them a huge problem which is at the 2024 if the ratio of the first range (18-21) still increasing they will have a hard competition with those people. and those people may take their jobs which makes them don't contribute a lot and finally end with unemployment, so it's a problem to consider.
#
# 3. Data Scientists in the range 25-39 has decreased over the years, <mark>it seems that over the years when the age gets bigger (under 40) data scientists ratio of contribution in Kaggle is decreasing</mark> and that is a good news for new kagglers (Experts contribution will not be so big maybe because they focus on their company or their own job and clients)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   <b>Expectation</b>: In 2025 Kaggle will have to welcome a huge amount of students at the age of 21 or even smaller!
# </div>

# %% [markdown]
# <a id='section-three'></a>
# # Degree

# %%
degree = two_cat(srv_all, 'College_degree', 'year', 'College Degree distribution over the years', 600, 800)
degree.bar_group_ordinal_own_colors(degree_order, [2019, 2020, 2021], ['#8A2429', '#C55564', '#F5CCB8'], [50, 3, 50, 1], template='plotly_white')
degree = one_cat(srv21.dropna(), 'College_degree', 'College Degree in 2021')
degree.updated_pie_chart('Degree', ['lightgray', 'lightseagreen', 'lightblue', 'skyblue'])

# %% [markdown]
# That gives us the following news:
#    1. <mark>About 75% of our respondents have/enroll Bachelor's or Master's degrees (or they intend to have it in the next two years)</mark> so we haven't so much people out of schools or university (I know that university isn't all thing in the world and that there are some people doesn't attend university and became very successful, but in general that doesn't happen for the majority of them and we will also see experience vs university degree and annual compensation Vs University degree to see more details).
#
#    2. Bachelor's degree students ratio has increased over the years that maybe because we've a jump also in the age range of 18-21 and this is the category in bachelor's.
#
#    3. We've a considerable decrease over the years for the high studies (studies after Master's degree) this is a good news for students to make the competition more easy (Is this category have no time to contribute in Kaggle because of their studies ? we will see)

# %% [markdown]
# <a id='section-four'></a>
# # Experience

# %%
ex = two_cat(srv_all, 'Experience', 'year', 'Experience distribution over the years', 600, 800)
ex.bar_group_ordinal_own_colors(experience_order[1:], [2019, 2020, 2021],
                                ['#594A72', '#9E6EAA', '#F994C1'], [35, 3, 35, 1], template='plotly_white') # From one to assure that we exclude 'I have never written code' Item 
ex = one_cat(srv21.dropna(), 'Experience', 'Experience in 2021')
ex.waffle('Experience Distribution in 2021')

# %% [markdown]
# - We have a little note here which is **"Half of Kagglers in 2021 and 2019 are Junior(or beginner) Data Scientists"**  <mark>I consider 'Junior' here as 1-3 years of writing code</mark>
#
# - In general, we noticed from this that the more experience the data scientist, the lower its participation rate in Kaggle that effect appears in 2019 and 2021. And that gives us the following information.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#   For data scientists less than 40 years old, Kaggle is used more in the period of gaining experience and therefore remains involved in it but to a lesser extent. This gives us a clear view of what most of those coming to Kaggle care about to focus on making the most of them by giving them an exceptional experience that will make them learn what is going on in this field on the real world.
# </div>

# %% [markdown]
# <a id='section-five'></a>
# # Annual Compensation

# %%
salary = two_cat(srv_all, 'Annual_compensation', 'year', 'Annual Compensation distribution over the years', 600, 800)
salary.bar_group_ordinal_own_colors(money_order, [2019, 2020, 2021], ['#482414', '#69422B', '#8E7158'], [70, 2.5, 70, 1], template='plotly_white')
salary = one_cat(srv21.dropna(), 'Annual_compensation', 'Annual Compensation in 2021')
salary.updated_pie_chart('Salary', ['lightgray', 'lightseagreen', 'lightblue', 'skyblue'])

# %% [markdown]
# - We have a very huge decrease in 2021 in the range <1000 dollars, but that's a good news because we also have a huge jump in the range 10,000-99,999 dollars so congrats to them.
#
# - 55.6% of kagglers have a salary bigger than 10,000 dollars and 42.6% of them in the range 10,000-99,999 dollars.

# %% [markdown]
# <h1 style="color:#FF7F50">Trends ↗</h1>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <ul>
#         <li>Over time, the spread of data science (In Kaggle) becomes popular among young people and vice versa with adults, except for those over 40 years old.
#         <li>University degrees less than a master's degree are becoming more widespread among data scientists and vice versa with masters and higher than it.
#         <li>Over time, the participation of experienced people of 3-5 years decreases.
#         <li>Huge increase in salary rates for data scientists in Kaggle.
#     </ul>
# </div>

# %% [markdown]
# <a id='section-six'></a>
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-size:15px;
#            font-family:Verdana;
#            padding:20px">
#     <h1 style="text-align:center;
#                color:white;">Questions about age effects</h1>
# </div>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;Here we'll see how age affects the variables of interest and state the most important findings bellow. Some of these findings will be used in the recommendation part as it helps in enriching our article for those who want to learn data science but don't know when to start, parents who want their children to learn or work in this field (if children want) and for the government that thinks in adding data science or programming subjects for children or scholarships for youth.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;Quick review about <b>Categorical Plot</b> used here: each column it's summation is 100% and each column represent the distribution of each value in x-axis on y-axis values by it's percentage or ratio and the exact ratio will be written and presented by it's size. Ex: If we have 100 master student 20 of them get less than 10,000 and 80 of them get higher the graph will show the below.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Master Student
#
# less than 10,000&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;20%
#
# higher than 10,000&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;80%

# %% [markdown]
# <a id='section-seven'></a>
# # How age affects the college degree?

# %%
colors=['blue', 'grey', 'green']
# create the plot
plt.figure(figsize=(50,20))
age_degree = two_cat(srv21, 'Age', 'College_degree', 'Age Vs Degree', 400, 400, xlabel='Age', ylabel='Degree')
age_degree.catscatter(age_order, degree_order, color=colors, ratio=180)
plt.savefig('catPlot.png')

# %% [markdown]
# So we can see from this graph the following:
# - In the range of 18-21 there are some people have a degree higher than or equals to Master's degree (**That's very strange!**, actually it's impossible in our regular life in my country, in Egypt, when someone gets at the same age a Master's degree he appears in the TV as a strange story to tell ^_^).  see this: <a href="https://thesiswhisperer.com/2013/10/16/doing-a-phd-in-your-early-20s/">about this strange information</a>
#
# - We can see that the older you become, the better your chance of getting a Master's degree or higher. (And vice versa with the Bachelor or lower)
#
# - It's not surprising news to see that the range 18-21 has the highest ratio on Bachelor's degree, but it's when we see that a considerable ratio of people in range 40+ have a degree less than Bachelor's degree.
#
# - We can see that about half of the people having 24 years or more have or intend to have Master's degree.

# %% [markdown]
# <a id='section-eight'></a>
# # How age affects the Coding Experience?

# %%
colors=['blue', 'grey', 'green']
# create the plot
plt.figure(figsize=(50,20))
age_degree = two_cat(srv21, 'Age', 'Experience', 'Age Vs Degree', 400, 400, xlabel='Age', ylabel='Coding Experience')
age_degree.catscatter(age_order, experience_order, color=colors, ratio=180)

# %% [markdown]
# Here I'll not speak about the normal things such as the higher age, the higher experience or similar. I'll speak about the most important information here:
# - <span style="color:red;">We've some people at the age range of 18-21 have experience from 5 to 10 years that means <mark>we've some people start writing code at least at the age of 12</mark> (I've calculated the average between 8 and 16). This point is very amazing we will speak about it again in the advices section and when we see it's effect on annual compensation.</span>
#
# - It's normal to see that people in range 22-24 has a big ratio on 1-3 years of coding writing I mean they might start that when they have enrolled in their university, but what is really strange is that this range of experience is the same in the range of 18 to 21 years. <mark>We have a lot of people who start coding before their 18 not just a few as we saw in the last point.</mark>

# %% [markdown]
# <a id='section-nine'></a>
# # How age affects the Annual Compensation?

# %%
colors=['blue', 'grey', 'green']
# create the plot
plt.figure(figsize=(50,20))
age_degree = two_cat(srv21, 'Age', 'Annual_compensation', 'Age Vs Degree', 400, 400, xlabel='Age', ylabel='Annual Compensation')
age_degree.catscatter(age_order, money_order, color=colors, ratio=180)

# %% [markdown]
# It's normal to see that the older you are, the higher salary you get, but let me show you what is really strange:
# - <span style="color:red;"><mark>There are some young people get more than 100,000 dollars at the age range of 18-21</mark> and those people maybe the people who start at 12 years old we will see in the coming sections as I've told, but at least we've seen that it is possible for young people to achieve that huge success.</span>
#
# - We've a considerable ratio (25%) of people at the age range of 40+ with 10,000 or less dollars as an annual compensation. It's about 35% when speaking about the range 30-39.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <b>Summary:</b> In general the older you are, the higher ratio to have salaries, but that happen only from 10,000+ (I meant it not a typo). And vice versa with <1,000 dollars. There are some abnormal things and we listed them above.
# </div>

# %% [markdown]
# <a id='section-ten'></a>
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-size:15px;
#            font-family:Verdana;
#            padding:20px">
#     <h1 style="text-align:center;
#                color:white;">Questions about relations among other vars</h1>
# </div>

# %% [markdown]
# <a id='section-eleven'></a>
# # Does coding experience have a huge effect on Annual Compensation?

# %%
colors=['blue', 'grey', 'blue']
# create the plot
plt.figure(figsize=(50,20))
age_degree = two_cat(srv21, 'Experience', 'Annual_compensation', 'Experience Vs Annual_compensation', 400, 400, xlabel='Experience', ylabel='Annual compensation')
age_degree.catscatter(experience_order, money_order, color=colors)

# %% [markdown]
# Sure it has a good effect, but is that a must for all data scientists or even is it extremely effective to focus on?:
# - We can see from the first range and the last range that low salary is being decreased when raising Experience and vice versa with high salaries.
# - We've some genius coders with <1 years of experience and huge annual compensation. <mark>That means if you've less than one year of experience you've a chance of getting salaries more than 10,000 dollars about 33.78%</mark>
# - The effect of experience doesn't appear in the range 1,000-9,999 dollars except for 5 years or more of experience.
# - Half of data scientists with 3 or more years of experience get salary in the range 10,000-99,999.
# - The probability of having more than 100,000 dollars increase only when you've more than 5 years of experience

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     <b>summary:</b> The probability of getting less than 1000 dollars decrease when increasing the experience. The effect of experience will not be significance in ranges 1,000-9,999 and +100,000 dollars except for experience more than 3 years.
# </div>

# %% [markdown]
# <a id='section-twelve'></a>
# # Does college degree have a huge effect on Annual Compensation?

# %%
colors=['blue', 'grey', 'blue']
# create the plot
plt.figure(figsize=(50,20))
age_degree = two_cat(srv21, 'College_degree', 'Annual_compensation', 'Degree Vs Annual_compensation', 400, 400, xlabel='Degree', ylabel='Annual compensation')
age_degree.catscatter(degree_order, money_order, color=colors)

# %% [markdown]
# Without much comments here it's clear that it has a good effect, but extremely low compared to coding experience's effect. We can see that clearly if we compare the salary range of >100,000 dollars it begans with 7% and increase to reach 20% in the range 'After Master' degrees, but coding experience starts with 4% and ends 27% in the "After Master" degrees. and the other good effect with degrees is that in the salary range of <1,000 dollars such as it started with 31% and ends with 14% (from lowest degrees to highest degrees). Otherwise we can say it's fixed in the salary ranges 1,000-9,999 and 10,000-99,999 dollars. Do you know what that means? <mark>It means if you've a degree less than bachelor and some one has a degree (or intend to have) after Master's degree your chances are close for getting a job with annual compensation in the range 10,000-99,999 dollars you can double this rate if you've 5-10 years of coding experience and his experience are Theoretical experience. </mark>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   It's very clear that experience is more important than university degree.
# </div>

# %% [markdown]
# <a id='section-thirteen'></a>
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-size:15px;
#            font-family:Verdana;
#            padding:20px">
#     <h1 style="text-align:center;
#                color:white;">Let's reveal the facts with Multivariate analysis</h1>
# </div>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;Here the facts and unambigious insights presented above will be discussed and revealed. In the above sections, some facts and benefits were not very clear because of other missing factor like age or salary in some cases so here the majority of the presented questions will be covered with extra information.

# %% [markdown]
# ![magnified-journey-map-760.jpg](attachment:f2c03774-f879-4bad-83a4-6df7cb8a8648.jpg)

# %% [markdown]
# <a id='section-fourteen'></a>
# # Did young people benefit financially from what they worked on in their childhood ?

# %% [markdown]
# This part speaks about the young people who have an experience of code writing from their childhood.

# %% [markdown]
# **Big Picture**

# %%
dimension_cats = ['Age', 'Experience', 'Annual_compensation']
agg_data = srv_all.groupby(dimension_cats).size().reset_index(name='count')
fig = px.treemap(agg_data, path=dimension_cats, values='count')
fig.show()

# %% [markdown]
# **Note: You can click on the range you want to zoom and see it clearly.**

# %% [markdown]
# Then let's see our group of interest which are the people who works a lot from their childhood we will consider them as following:
# - **Less than or equals 24 years old**
# - **Have experience greater than or equals 3 years if they are in the range 18-21 else they must have experience greater than or equals 5**

# %% [markdown]
# **Hard-working Youth**

# %%
cond1 = (srv_all['Experience'].isin(pd.Series(['5-10 years', '10+ years']))) & (srv_all['Age'] == '22-24')
cond2 = (srv_all['Experience'].isin(pd.Series(['3-5 years', '5-10 years', '10+ years']))) & (srv_all['Age'] == '18-21')

youth_worked_hard = srv_all[  (cond1)  |  (cond2)  ]
dimension_cats = ['Age', 'Experience', 'Annual_compensation']
agg_data = youth_worked_hard.groupby(dimension_cats).size().reset_index(name='count')
fig = px.treemap(agg_data, path=dimension_cats, values='count')
fig.show()

# %% [markdown]
# - <span style="color:red;">And Yes, their work has paid off and they made money even they are still youth !</span> there are some excluded cases from that success:
#
#   - Who gets <1000 dollars
#   - Who gets 1,000-9,000 dollars and has 5-10 years of experience
#
#
# - We can see that 33% of young people (18-21 years old) with experience 3-5 years in coding gets 1,000 dollars or more, 15.7% of them gets higher than 10,000 (not a typo) and 4% gets higher than 100,000 dollars.
#
# - 40% (about half) of the young people in the range 18-21 with experience 5-10 years in coding gets 1,000 dollars or more, 15.2% of them gets higher than 10,000 dollars and 5% gets higher than 100,000 dollars. Don't you notice something? the ratios are very close! So we can put a rule (with their average): <span style="color:red;"><b>If you exert an effort and learn coding from your childhood (about 3+ years before you reach your 18th) you will get at the age of 18 or 20 with a ratio of 36.5% more than 1,000 dollars a year, with a ratio of 15.4% more than 10,000 dollars and with a ratio of 4.5% higher than 100,000 dollars.
#
# - Last will happen also if we speaks about the age range of 22-24, but with better ratios. with experience of 5-10 years the ratios will be the following:
#     - 55.8% to have more than 1,000 dollars.
#     - 34.5% to have more than 10,000 dollars.
#     - 6.5% to have more than 100,000 dollars.
#
#
# - So the effect of age appears in the 5-10 years of experience in range 18-21 you will get 1,000 dollars or more with a ratio of 36.5% but 55.8% if you're in 22-24, get 10,000 dollars or more with a ratio of 15.4% but 34.5% if you're in 22-24 and 100,000 dollars or more with a ratio of 4.5% but 6.5% if in 22-24.

# %% [markdown]
# <a id='section-fifteen'></a>
# # Did young people benefit financially from what they learned(from College) in their teens ?

# %% [markdown]
# This part speaks about those young people who works on their master or above before or in they reach 24 year and also about some related questions.

# %%
dimension_cats = ['Age', 'College_degree', 'Annual_compensation']
agg_data = srv_all.groupby(dimension_cats).size().reset_index(name='count')
fig = px.treemap(agg_data, path=dimension_cats, values='count')
fig.show()

# %% [markdown]
# Here we've some questions:
# 1. Is the higher degree, the higher salary you get for all age ranges ?
# 2. Do degrees after Master's degree can really raise your annual compensation with a considerable ratio than Master's degree itself ?
# 3. What benefits did the young people(18-24) who gets the high degrees get ?

# %% [markdown]
# First let's read the graph to answer the questions:
# - Range 18-21:
#
#     - Less than Bachelor's: got more than 1,000 dollars with a ratio of **25%**, higher than 10,000 dollars **10%** and higher than 100,000 dollars **2%** .
#     - Bachelor's: got more than 1,000 dollars with a ratio of **25%**, higher than 10,000 dollars **9.7%** and higher than 100,000 dollars **2.7%** .
#     - Master's: got more than 1,000 dollars with a ratio of **29.2%**, higher than 10,000 dollars **9.8%** and higher than 100,000 dollars **2.3%** .
#     - After Master's: got more than 1,000 dollars with a ratio of **37.5%**, higher than 10,000 dollars **18.75%** and higher than 100,000 dollars **6.25%** (this isn't accurate because we don't have a lot of thos people who made this case so we can ignore it) .
#
#
# - Range 22-24:
#
#     - Less than Bachelor's: got more than 1,000 dollars with a ratio of **32%**, higher than 10,000 dollars **14.2%** and higher than 100,000 dollars **1.4%** .
#     - Bachelor's: got more than 1,000 dollars with a ratio of **38.5%**, higher than 10,000 dollars **16.8%** and higher than 100,000 dollars **2.9%** .
#     - Master's: got more than 1,000 dollars with a ratio of **38.6%**, higher than 10,000 dollars **18.2%** and higher than 100,000 dollars **4.1%** .
#     - After Master's: got more than 1,000 dollars with a ratio of **32.4%**, higher than 10,000 dollars **7.4%** and higher than 100,000 dollars **2.6%** (this isn't accurate because we don't have a lot of thos people who made this case so we can ignore it too)

# %%
# Prepare the aspect of the plot
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['font.sans-serif']='sans-serif'
plt.rcParams['xtick.color']='black'
plt.rcParams['ytick.color']='black'

def pointplot_salaries(df, age_range):
    
    sns.pointplot(data=df, x='Salary', y='Percentage', hue='Degree', hue_order=['Less than Bachelor', 'Bachelor', 'Master', 'Higher than Master'], palette=['yellow', 'orange', 'brown', 'black'])
    plt.xlabel('Annual Compensation')
    plt.ylabel('Percentage')
    plt.title(age_range)
    plt.savefig(f'{age_range}.png')
    plt.show()

# %%
# Percentages for range 18-21
percentages_less_than_bachelor = [25, 10, 2]
percentages_with_bachelor = [25, 9.7, 2.7]
percentages_with_master = [29.2, 9.8, 2.3]
percentages_higher_than_master = [37.5, 18.75, 6.25]

# Make DataFrame for this age range
d = {'Degree':['Less than Bachelor']*3 + ['Bachelor']*3 + ['Master']*3 + ['Higher than Master']*3, 'Percentage':percentages_less_than_bachelor + percentages_with_bachelor + percentages_with_master + percentages_higher_than_master, 'Salary':['>1k', '>10k', '>100k']*4}
age_percentage_degree_df = pd.DataFrame(data=d)

pointplot_salaries(age_percentage_degree_df, 'Range 18-21')

# Percentages for range 22-24
percentages_less_than_bachelor = [32, 14.2, 1.4]
percentages_with_bachelor = [38.5, 16.8, 2.9]
percentages_with_master = [38.6, 18.2, 4.1]
percentages_higher_than_master = [32.4, 7.4, 2.6]

# Make DataFrame for this age range
d = {'Degree':['Less than Bachelor']*3 + ['Bachelor']*3 + ['Master']*3 + ['Higher than Master']*3, 'Percentage':percentages_less_than_bachelor + percentages_with_bachelor + percentages_with_master + percentages_higher_than_master, 'Salary':['>1k', '>10k', '>100k']*4}
age_percentage_degree_df = pd.DataFrame(data=d)

pointplot_salaries(age_percentage_degree_df, 'Range 22-24')

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   Before we continue, we can answer question 3 from these information, so we can say yes, it will bring benefits for them specifically, having Master in range 18-21 will raise their ratio of having more than 1,000 dollars. For range 22-24 it will bring benefits for them also, specially, having Bachelor's degree at this range will raise your probability to get annual compensation in the range 1,000-9,999 dollars and having Master's degree will raise it for getting more than 100,000 dollars.
# </div>

# %% [markdown]
# - Range 25-29:
#     - Less than Bachelor's: got more than 1,000 dollars with a ratio of **45%**, higher than 10,000 dollars **24.3%** and higher than 100,000 dollars **3.2%** .
#     - Bachelor's: got more than 1,000 dollars with a ratio of **47.1%**, higher than 10,000 dollars **23.6%** and higher than 100,000 dollars **4.9%** .
#     - Master's: got more than 1,000 dollars with a ratio of **51%**, higher than 10,000 dollars **29%** and higher than 100,000 dollars **6%** .
#     - After Master's: got more than 1,000 dollars with a ratio of **44%**, higher than 10,000 dollars **23%** and higher than 100,000 dollars **4.5%** .

# %%
# Percentages for range 25-29
percentages_less_than_bachelor = [45, 24.3, 3.2]
percentages_with_bachelor = [47.1, 23.6, 4.9]
percentages_with_master = [51, 29, 6]
percentages_higher_than_master = [44, 23, 4.5]

# Make DataFrame for this age range
d = {'Degree':['Less than Bachelor']*3 + ['Bachelor']*3 + ['Master']*3 + ['Higher than Master']*3, 'Percentage':percentages_less_than_bachelor + percentages_with_bachelor + percentages_with_master + percentages_higher_than_master, 'Salary':['>1k', '>10k', '>100k']*4}
age_percentage_degree_df = pd.DataFrame(data=d)

pointplot_salaries(age_percentage_degree_df, 'Range 25-29')

# %% [markdown]
# <div class="alert alert-success" role="alert">
#    We will not do this for all we just want to see how it is like for small sample. We can answer question 2, the answer is no, having more than Master's degree in university will not make you made better annual compensation on the contrary, it decrease their probablity of having good compensations. (This problem called <a href="https://en.wikipedia.org/wiki/Overqualification">"Overqualification"</a>)
# </div>

# %% [markdown]
# - Let's make another one to answer question 1 with more accurate answer than what we have now.
#
# - Range 30-34:
#     - Less than Bachelor's: got more than 1,000 dollars with a ratio of **51%**, higher than 10,000 dollars **27.86%** and higher than 100,000 dollars **4.6%** .
#     - Bachelor's: got more than 1,000 dollars with a ratio of **55%**, higher than 10,000 dollars **33.7%** and higher than 100,000 dollars **7.7%** .
#     - Master's: got more than 1,000 dollars with a ratio of **57.7%**, higher than 10,000 dollars **37.7%** and higher than 100,000 dollars **10.9%** .
#     - After Master's: got more than 1,000 dollars with a ratio of **51.8%**, higher than 10,000 dollars **33.6%** and higher than 100,000 dollars **8.9%**

# %%
# Percentages for range 30-34
percentages_less_than_bachelor = [51, 27.86, 4.6]
percentages_with_bachelor = [55, 33.7, 7.7]
percentages_with_master = [57.7, 37.7, 10.9]
percentages_higher_than_master = [51.8, 33.6, 8.9]

# Make DataFrame for this age range
d = {'Degree':['Less than Bachelor']*3 + ['Bachelor']*3 + ['Master']*3 + ['Higher than Master']*3, 'Percentage':percentages_less_than_bachelor + percentages_with_bachelor + percentages_with_master + percentages_higher_than_master, 'Salary':['>1k', '>10k', '>100k']*4}
age_percentage_degree_df = pd.DataFrame(data=d)

pointplot_salaries(age_percentage_degree_df, 'Range 30-34')

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <b>So now it is clear</b>, having higher degree will bring higher compensation for you (Question 1 answer), but that stops untill Master's. This assure our answer for the second question which is more than Master's degree for more ranges will not bring you better results than Master's degree itself.
# </div>

# %% [markdown]
# <a id="section-bonus1"></a>
# # When does degrees higher than Master's degree increase the annual compensation for a person?

# %% [markdown]
# We want to see in which age range does having higher than Master's degree bring better annual compensations for those who have got it. We will do that because we saw that in the previous age ranges it doesn't give them any better results, so we will focus here on the last two age ranges so we may see that in these ranges it gives them better results. We will measure the increase of annual compensation by either the increase of getting more than 10,000 dollars or the decrease of getting less than 10,000 dollars

# %% [markdown]
# <div class="alert alert-warning" style="font-family: times-new-roman">
#   <h2 style="font-family: times-new-roman"><center>Don't forget to hover for more details!</center></h2>
# </div>

# %%
higher_degrees_only = srv_all.query('year == 2021 & (College_degree == "After Master" | College_degree == "Master’s degree") & Age == "35-39"')
deg_salary = two_cat(higher_degrees_only, 'College_degree', 'Annual_compensation', '<b>Range 35-39</b><br>Effect of having higher than Master\'s degree in 2021', 600, 800)
deg_salary.stacked_plot(degree_order, money_order, template='plotly_white', colors=['#8B0000', '#DC143C', '#F08080', '#FFA07A'])

higher_degrees_only = srv_all.query('year == 2021 & (College_degree == "After Master" | College_degree == "Master’s degree") & Age == "40+"')
deg_salary = two_cat(higher_degrees_only, 'College_degree', 'Annual_compensation', '<b>Range 40+</b><br>Effect of having higher than Master\'s degree in 2021', 600, 800)
deg_salary.stacked_plot(degree_order, money_order, template='plotly_white', colors=['#8B0000', '#DC143C', '#F08080', '#FFA07A'])

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#   So also in the last two ranges we've got the same results and we knew that there is no such age range will benefit financially from having a degree higher than Master's degree
# </div>

# %% [markdown]
# <a id="section-seventeen"></a>
# <div class="alert alert-info" role="alert">
#     <ul>
#     <li><b>Suggestion:</b> I recommend adding a question about which is the highest college degree do you have not intend or enrol in, because these people who intend to have it of course will not get better results in annual compensations like those who already have it, so that may be the factor who made this strange result. We can also add question for those who have higher than Master's degree are they suffer from "Overqualification" problem.
#     <li>If the last supposition isn't true and they will got close results there maybe another factors due to that. ex:
#         <ul>
#             <li>They might be more interested in achieving more scientific achievements not financial one (We can't check it)
#             <li>They maybe have a theoretical experience not practical one so they can't achieve more money like who have Master becuase he in general has a practical experience more than them "Don't forget that coding experience has the big effect on the annual compensation". (Let's see that from our dataset because if that true we knew a big reason for the problem we have "Non-significance of Higher than Master's degree")
#             <li>Overqualification problem (We can't check it)
#             <li>The majority of them doesn't participate in Kaggle ie: we've a small sample of them(We will check it)
#         </ul>
#     </ul>
# </div>

# %% [markdown]
# <h3>Does those who have Master's degree have a better coding experience than those who have or intend to have higher than Master?</h3>

# %%
higher_degrees_only = srv_all.query('year == 2021 & (College_degree == "After Master" | College_degree == "Master’s degree")')
deg_expert = two_cat(higher_degrees_only, 'College_degree', 'Experience', 'Effect of having higher than Master\'s degree in 2021', 600, 800)
deg_expert.stacked_plot(degree_order, experience_order, template='plotly_white', colors=['#8B0000', '#DC143C', '#F08080', '#FFA07A'])

# %% [markdown]
# That's not surprising news, who have higher than Master have more coding experience than those who have Master's degree, so we will exclude this reason and see the next one which is the participating in Kaggle Community.

# %% [markdown]
# <h3>Does those who have Master's degree have a better participating rate than those who have or intend to have higher than Master?</h3>

# %%
higher_degrees_only = srv_all.query('year == 2021')
higher_degrees_only.loc[(higher_degrees_only['College_degree'] != "After Master") & (higher_degrees_only['College_degree'] != "Master’s degree"), 'College_degree'] = 'Other'
high_deg = one_cat(higher_degrees_only, 'College_degree', 'Distribution of College Degree', width=400, height=400)
high_deg.updated_pie_chart('Degree', ['lightgray', 'lightseagreen', 'lightblue'])

# %% [markdown]
# Yes, they've a higher rate of participation, but also the sample of those data scientists who have/enroll in/intend higher than Master's degree isn't that small to be the problem. Then that also will not be the reason, <mark>so the last two reasons are "Seeking Scientific Achievements" and "Overqualification" So it will be a good addition to be put in Kaggle 2022 annual survey.</mark>

# %% [markdown]
# <a id='section-eighteen'></a>
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-size:15px;
#            font-family:Verdana;
#            padding:20px">
#     <h1 style="text-align:center;
#                color:white;">Conclusion & recommendations</h1>
# </div>

# %% [markdown]
# <a id="section-nineteen"></a>
# <span style="font-size:35px; font-family: sans-serif;">Our Duty As Parents</span>

# %% [markdown]
# ![Kids and Technology.jpg](attachment:db68895b-cd99-471a-922a-d210f7e9fb50.jpg)

# %% [markdown]
# &nbsp;&nbsp;&nbsp;<span style="font-size:35px; font-family: sans-serif; ">As</span> we've seen college degree, age and coding experience are important factor and all of them has an vital role on raising the annual compensation for the data scientist, but let's speak in a more practical way, we can't exert efforts to raise our children's age and it's also hard to raise the college degree as those factors fixed and also college degree doesn't have that huge effect on annual compensation to deserve our children's effort to improve it before it's time and it's very hard and strange to do like those student we've seen above (made doctorate in his 18 or 21), so we end up with improving coding experience!
# <br>
# <br>
# &nbsp;&nbsp;&nbsp;Coding experience is the only flexible factor we've seen and also it's the most effective one on annual compensation. so let's speak about what can we do for our children or even offer it to them as parents. We can use their free time to make them learn programming for data science or even programming basics in general like problem solving for some months then start with data science requirements like maths statistics, analytical skills and machine learning algorithms. I like speak now about the tools you will need to do that from this survey, like platforms to learn from, tools to use and the prgramming language to start with. see this: <a href="https://www.kaggle.com/questions-and-answers/275702">Programming Roadmap</a>, <a href="https://www.kaggle.com/questions-and-answers/273807#1522534">Data Science Sources</a>, <a href="https://www.kaggle.com/questions-and-answers/274008">Data Science Roadmap</a>

# %% [markdown]
# # Platforms

# %%
def put_an_end_to_multiple_choice(Qn, color, choice_name, n=3, horizontal=True): # Qn is the the question with its number like Q39
    
    '''
    plot bar graph to see the distribution of any categorical variable appears in multiple columns
    Qn: The number of the question
    color: Color of the bars
    choice_name: Name of this question (like title not Q + n such that n is the number of the question)
    n: put it 3 if the question number above 9 else 2
    horizontal: The presentation of the bars can be horizontal (True) or vertical(False) 
    '''
    survey = survey21
    Qn_cols = list(filter(lambda x: x[:n] == Qn, survey.columns))
    d = {}
    for q in Qn_cols:

        choice_selected = survey.loc[ survey[q].notnull() , q].unique()[1].strip()  # [1] to take the name without the question
        d[q] = [survey[q].count() - 1, choice_selected]  # -1 to remove the one for the question itself


    choices = list()
    counts = list()
    for count, choice in list(d.values()):
        choices.append(choice)
        counts.append(count)

    # The dataframe to be plotted
    choices_with_counts = pd.DataFrame({'Choice':choices, 'count':counts}).sort_values(by='count', ascending=False)
    whole_number = sum(choices_with_counts['count'])
    choices_with_counts['count'] = 100*choices_with_counts['count'] / whole_number

    # Plot it
    base_color = color
    if horizontal:
        sns.barplot(data=survey, y=choices_with_counts['Choice'], x=choices_with_counts['count'],
                    color=base_color)
    else:
        sns.barplot(data=survey, x=choices_with_counts['Choice'], y=choices_with_counts['count'],
                    color=base_color)

    plt.xlabel('Percentage')
    plt.ylabel(choice_name)
    plt.title('Most {}s For Data Scientists'.format(choice_name))
    plt.xticks(color='black')
    plt.yticks(color='black')
    plt.show()
    
    
    
def put_an_end_to_single_choice(Qn, choice_name, color, ordered=False, order=[]):
    
    '''
    plot bar graph to see the distribution of any categorical variable (nomianl or ordinal; has an order or not) appears in a single column 
    Qn: The number of the question
    choice_name: Name of this question (like title not Q + n such that n is the number of the question)
    color: Color of the bars
    ordered: Boolean value to determine whether your variable has an order or not
    order: List of the order of the values in the colummn
    '''
    survey = survey21
    counts = survey[Qn].value_counts()[:-1]  # [:-1] to exclude the one for the question itself
    whole_number = sum(counts.values)
    counts = 100*counts / whole_number

    # Plot it
    base_color = color
    if ordered:
        
        sns.barplot(data=survey, y=counts.index, x=counts.values,
                    color=base_color,
                    order=order)
    else:
        sns.barplot(data=survey, y=counts.index, x=counts.values,
                    color=base_color)

    plt.xlabel('Percentage')
    plt.ylabel(choice_name)
    plt.title('The distribution of {}'.format(choice_name))
    plt.xticks(color='black')
    plt.yticks(color='black')
    plt.show()

# %%
def Q_over_years(feature_name, colors, prepared_series=False, series_list=[], dfs=[], Qns=[], template='plotly'):
    '''
    It plots the distribution of your variable over the years with a dropdown menu
    feature_name: The formal name you want to make it appears (string)
    colors: The colors of the variable in each year (List of color codes each for each year)
    prepared_series: Boolean value to use your prepared series instead of extracting them
    series_list: List of series if prepared_series is True
    dfs: List of data frames if prepared_series is False
    Qns: List of Qns if prepared_series is False (To extract the needed feature from the dataframe)
    '''
    if not prepared_series:
        df19, df20, df21 = dfs
    # 2019
    if prepared_series:
        series = series_list[0]
        counts = series.value_counts()[::-1] # To reverse them
    else:
        series = df19[Qns[0]].dropna()[1:] # To exclude the question itself
        counts = series.value_counts()[::-1] # then reverse them
    whole_number = sum(counts.values)
    counts = 100*counts / whole_number
    x19 = counts.values
    y19 = counts.index
    
    
    # 2020
    if prepared_series:
        series = series_list[1]
        counts = series.value_counts()[::-1] # To reverse them
    else:
        series = df20[Qns[1]].dropna()[1:] # To exclude the question itself
        counts = series.value_counts()[::-1] # then reverse them
        
    whole_number = sum(counts.values)
    counts = 100*counts / whole_number
    x20 = counts.values
    y20 = counts.index
    
    
    # 2021
    if prepared_series:
        series = series_list[2]
        counts = series.value_counts()[::-1] # To reverse them
    else:
        series = df21[Qns[2]].dropna()[1:] # To exclude the question itself
        counts = series.value_counts()[::-1] # then reverse them
        
    whole_number = sum(counts.values)
    counts = 100*counts / whole_number
    x21 = counts.values
    y21 = counts.index
    
    
    plot = go.Figure(data=[go.Bar(
        name='2019',
        orientation='h',
        marker_color=colors[0],
        x=x19,
        y=y19
    ),
        go.Bar(
        name='2020',
        orientation='h',
        marker_color=colors[1],
        x=x20,
        y=y20
    ),
        go.Bar(
        name='2021',
        orientation='h',
        marker_color=colors[2],
        x=x21,
        y=y21
    )
])
  
  
    # Add dropdown
    plot.update_layout(template=template,
        updatemenus=[
            dict(active=0,
                buttons=list([
                    dict(label="All",
                         method="update",
                         args=[{"visible": [True, True, True]},
                               {"title": f"{feature_name}",
                                }]),
                    
                    dict(label="2019",
                         method="update",
                         args=[{"visible": [True, False, False]},
                               {"title": f"{feature_name} in 2019",
                                }]),
                    
                    dict(label="2020",
                         method="update",
                         args=[{"visible": [False, True, False]},
                               {"title": f"{feature_name} in 2020",
                                }]),
                    
                    dict(label="2021",
                         method="update",
                         args=[{"visible": [False, False, True]},
                               {"title": f"{feature_name} in 2021",
                                }])
                ]),
                direction="down",
                pad={"r": 10, "t": 10},
                showactive=False,
                x=1,
                xanchor="left",
                y=1.2,
                yanchor="top"
            )
        ])
    
    plot.show()

# %%
put_an_end_to_multiple_choice('Q40', '#7FFFD4', 'Learning Platforms', n=3, horizontal=True)

# %% [markdown]
# As we can see those are the most popular platforms.

# %% [markdown]
# # Can I work with my personal computer? (Tools)

# %%
put_an_end_to_single_choice('Q11', "Tools", '#7FFFD4', ordered=False, order=[])

# %% [markdown]
# So the answer is yes, you can use your personal computer or your laptop or even buy a new laptop for your children only for study.

# %% [markdown]
# <div class="alert alert-success" style="font-family: times-new-roman">
#   <h2 style="font-family: times-new-roman"><center>Use the dropdown menu to see what happen in each year!</center></h2>
# </div>

# %% [markdown]
# # Which Programming Language for Data Science?

# %% [markdown]
# I've made a programming language comparison check it for more details about this point. <a href="https://www.kaggle.com/mostafaalaa123/programming-languages-for-ds-fields">here</a><br>
# Here is a graph to see a quick overview about the popular ones.

# %%
# You can use this also
# put_an_end_to_multiple_choice('Q7', '#7FFFD4', 'Programming Language', n=2, horizontal=True)

# Programming Language:
# 2019 -> Q19
# 2020 -> Q8
# 2021 -> Q8
Q_over_years('Programming Languages', ['#B4FFFF', '#308FC1', '#005F91'], dfs=[survey19, survey20, survey21], Qns=['Q19', 'Q8', 'Q8'], template='plotly_white')

# %% [markdown]
# &nbsp;&nbsp;&nbsp;If you successed to make your children start writing code at their 15th year or before, you will get youth have their own work at 18 or 20 and that doesn't happen in non-manual work in normal cases, but also don't ask him for leaving college it's necessary as we've seen. It raise his probability of getting more annual compensation in all cases but above Master's degree . Let's take a look at the most popular job titles in Kaggle in 2021.

# %%
from wordcloud import WordCloud
titles = srv21.query('Job_title != "Student" & Job_title != "Other"')['Job_title']
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(titles))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('The most popular job titles in 2021', loc='Center', size=30, color='gray')
plt.savefig('wordcloud.png')
plt.show()

# %%
series19 = srv_all.query('year == 2019 & Job_title != "Student" & Job_title != "Other"')['Job_title']
series20 = srv_all.query('year == 2020 & Job_title != "Student" & Job_title != "Other"')['Job_title']
series21 = srv_all.query('year == 2021 & Job_title != "Student" & Job_title != "Other"')['Job_title']
Q_over_years('Job Titles', ['#FFD3FF', '#C997FB', '#69379B'], prepared_series=True, series_list=[series19, series20, series21], template='plotly_white')

# %% [markdown]
# <a id='section-twenty'></a>
# <span style="font-size:50px; font-family: sans-serif;">Government Perspective</span>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;<span style="font-size:30px; font-family: sans-serif">If</span> you're a government or someone who can make change, keep the last suggestions in mind. Instead of make your students wait all that time then go to their college and then start thinking about the work, try put some problem solving skills or a subject speaks about programming for AI and Data Science or even make some free courses for those who want to improve themselves because some people don't have the money to learn on the online platforms. This will create a generation of young people who can work on self-employment platforms alone in the early hours of their lives or before entering university, thereby reducing unemployment rates and making your country one of the first countries in the field of data science. yes, I'm still talking about data science and programming specifically because they're different from the rest of the science, and they're a few other fields like marketing, because anyone can work with them, even if they don't have a college degree as long as they have the skill. (My country -Egypt- did that with Udacity and Kaggle and provide for us-youth- free courses on those topics and it's work pays off ^_^)

# %% [markdown]
# <a id='section-twenty-one'></a>
# <div style="color:white;
#            display:fill;
#            border-color: #46ABFF;
#            background-color:#EE9A4D;
#            font-size:15px;
#            font-family:Verdana;
#            padding:20px">
#     <h1 style="text-align:center;
#                color:white;">References📋</h1>
# </div>

# %% [markdown]
# articles about salaries:
# - <a href="https://www.payscale.com/research/US/Job=Data_Scientist/Salary">High-income countries</a>
# - <a href="https://datamites.com/blog/what-is-the-salary-of-a-data-scientist-in-africa/">Low-income countries</a>

# %% [markdown]
# # Helpful Notebooks and articles

# %% [markdown]
# <div class="card" style="width: 18rem;">
#   <img src="https://blog.f1000.com/wp-content/uploads/2017/07/logo.png" class="card-img-top" alt="...">
#   <div class="card-body">
#     <h5 class="card-title"><br>Plotly Guide</h5>
#     <p class="card-text">Plotly functions explained with examples. This notebook has a very wide range of functions structured in an impressive manner.</p>
#     <a href="https://www.kaggle.com/desalegngeb/plotly-guide-customize-for-better-visualizations" class="btn btn-info btn-lg active" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Somewhere">Plotly Guide</a>
#   </div>
# </div>
# <br>
# <div class="card" style="width: 18rem;">
#   <img src="https://www.fireblazeaischool.in/blogs/wp-content/uploads/2020/06/matplotlib1.jpg" class="card-img-top" alt="...">
#   <div class="card-body">
#     <h5 class="card-title">Categorical Plots</h5>
#     <p class="card-text">Lots of categorical plots functions Implemented and well-documented</p>
#     <a href="https://www.kaggle.com/gvyshnya/kaggle-2021-ml-and-ds-survey-comprehensive-eda/notebook" class="btn btn-info btn-lg active" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Somewhere">Cat Plots</a>
#   </div>
# </div>
# <br>
# <div class="card" style="width: 18rem;">
#   <img src="https://i.pinimg.com/originals/13/52/c1/1352c10a00ee78e5f0e9486efc82cc91.jpg" class="card-img-top" alt="...">
#   <div class="card-body">
#     <h5 class="card-title">Waffle Plots</h5>
#     <p class="card-text">Implementation of waffle plots in a single smart article.</p>
#     <a href="https://newbedev.com/how-to-do-waffle-charts-in-python-square-piechart" class="btn btn-info btn-lg active" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Somewhere">Waffle Plots</a>
#   </div>
# </div>
# <br>
# <div class="card" style="width: 18rem;">
#   <img src="https://i.pinimg.com/originals/17/60/2e/17602ebebf6d29b110ed29f9ae3e2501.jpg" class="card-img-top" alt="...">
#   <div class="card-body">
#     <h5 class="card-title">Donut Chart</h5>
#     <p class="card-text">Implementation of Donut plot with helpful references to learn more in depth.</p>
#     <a href="https://www.kaggle.com/mpwolke/kaggle-survey-2021-brazil" class="btn btn-info btn-lg active" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Somewhere">Donut Chart</a>
#   </div>
# </div>
# <br>
# <div class="card" style="width: 18rem;">
#   <img src="https://joeltrammell.com/wp-content/uploads/2015/01/OrgChart-1024x807.jpg" class="card-img-top" alt="...">
#   <div class="card-body">
#     <h5 class="card-title">Notebook Structure</h5>
#     <p class="card-text">Workflow and structure of some paragraphs and the introduction.</p>
#     <a href="https://www.kaggle.com/michau96/education-level-affects-data-analysis" class="btn btn-info btn-lg active" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Somewhere">Notebook Structure</a>
#   </div>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <p style="text-align:center; font-size:20px"><b>Thanks to them all they helped me. Check their profiles they are very smart!</b></p>
# </div>
