# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/kaggle_survey_2021_responses.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Once upon a time there was a man named data science, he and his wife machine learning had 25,973 children. Every year at the new year dinner, they try to get to know their children better and share unforgettable family moments

# %% [markdown]
# # **let's go and discover them**

# %%
dataset = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')

# %%
dataset.head()

# %%
df = dataset.copy()

# %%
df.shape

# %%
df.dtypes.value_counts().plot.pie()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)

# %%
df = df[df.columns[df.isna().sum()/df.shape[0] <0.9]]
df.head()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)

# %%
for col in df.select_dtypes('object'):
    print(f'{col :-<50} {df[col].unique()}')

# %% [markdown]
# #  first of all it is necessary to know that the family of the daughters and sons of all different sex

# %%
df['Q2'].value_counts()

# %%
df['Q2'].value_counts().plot.pie()

# %% [markdown]
# #  And also of all age groups:

# %%
df['Q1'].value_counts()

# %%
df['Q1'].value_counts().plot.pie

# %% [markdown]
# # *the majority are young people under 30*

# %% [markdown]
# # They come from all over the world

# %%
df['Q3'].value_counts()

# %%
df['Q3'].value_counts().plot.pie()

# %% [markdown]
# # *apparently more than a quarter are installed in India, the second country that welcomes them is the USA (it is those who do not want to be far from their parents ;) )*

# %% [markdown]
# # they also have a different academic level

# %%
df['Q4'].value_counts()

# %%
df['Q4'].value_counts().plot.pie

# %% [markdown]
# # *the majority of them have a university degree*

# %% [markdown]
# # **and they hold different positions  **

# %%
df['Q5'].value_counts()

# %%
df['Q5'].value_counts().plot.pie

# %% [markdown]
# # *Emm apparently the family has an impressive future, more than a quarter of the children are students*

# %% [markdown]
# #  children have programming experience that is measured in years

# %%
df['Q6'].value_counts()

# %%
df['Q6'].value_counts().plot.pie()

# %% [markdown]
# # *I told you an impressive future!! powerful newbies*

# %% [markdown]
# # As always the father start asking

# %% [markdown]
# # He asked : What programming languages do you use on a regular basis?

# %% [markdown]
# # They answered

# %% [markdown]
# # But they recommended an aspiring data scientist to learn first

# %%
df['Q8'].value_counts()

# %%
df['Q8'].value_counts().plot.pie()

# %% [markdown]
# # The father while eating the a peace of Citrus-Roasted Salmon asked : Where do you write your Code?

# %% [markdown]
# # They answered : AH you mean IDE Okey

# %% [markdown]
# # Q9

# %% [markdown]
# # The mother : It's my turn now

# %% [markdown]
# # Do You use noteboooks?

# %% [markdown]
# # Yes they sad and we use :

# %% [markdown]
# # Q10

# %% [markdown]
# # Mother : OKey COOL and what do you use as acomputing platform

# %% [markdown]
# # They ansewed

# %%
df['Q11'].value_counts()

# %%
df['Q11'].value_counts().plot.pie()
