# %% [markdown]
# ## Question by Question Analysis - Kaggle Survey (2021)

# %% [markdown]
# ##### By Anunay Tripathi

# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# #### Importing CSV

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore') 

data = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')

# %%
print('Dataset :',data.shape)

# %%
data.head(10)

# %%
data.tail(10)

# %%
data = data.loc[1:, :]
data.head(10)

# %% [markdown]
# ## Age Analysis (Q1)

# %%
data["Q1"]

# %%
data.Q1.duplicated()

# %%
data.Q1.drop_duplicates()

# %%
sns.countplot(x='Q1',data=data)
plt.xlabel('Age')
plt.ylabel('Frequency')

# %%
# Age 18-29 dominate

# %% [markdown]
# ## Gender Analysis (Q2)

# %%
data["Q2"]

# %%
fig = plt.subplots(1, figsize=(7, 6))
counts = data["Q2"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %%
# Sector dominated heavily by men

# %% [markdown]
# ## Country Analysis (Q3)

# %%
data["Q3"]

# %%
data.Q3.duplicated()

# %%
data.Q3.drop_duplicates()

# %%
fig = plt.subplots(1, figsize=(22, 22))
counts = data["Q3"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %%
#Majority of polulation belonging from India, followed by USA

# %% [markdown]
# ## Education Analysis (Q4)

# %%
data["Q4"]

# %%
data.Q4.duplicated()

# %%
data.Q4.drop_duplicates()

# %%
fig = plt.subplots(1, figsize=(7, 7))
counts = data["Q4"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %%
#Sector dominated by master's and bachelor's degree

# %% [markdown]
# ## Title Analysis (Q5)

# %%
data["Q5"]
data.Q5.duplicated()
data.Q5.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q5"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Coding Experience (Q6)

# %%
data["Q6"]
data.Q6.duplicated()
data.Q6.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q6"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Language Analysis (Q7)

# %%
data['Q7'] = data['Q7_Part_1'].astype(str) + '+' + data['Q7_Part_2'].astype(str) + '+' + data['Q7_Part_3'].astype(str) + '+' + data['Q7_Part_4'].astype(str) + '+' + data['Q7_Part_5'].astype(str) + '+' + data['Q7_Part_6'].astype(str) + '+' + data['Q7_Part_7'].astype(str) + '+' + data['Q7_Part_8'].astype(str) + '+' + data['Q7_Part_9'].astype(str) + '+' + data['Q7_Part_10'].astype(str) + '+' + data['Q7_Part_11'].astype(str) + '+' + data['Q7_Part_12'].astype(str) + '+' + data['Q7_OTHER'].astype(str)
data.Q7.duplicated()
data.Q7.drop_duplicates()
data.dropna()
data.Q7

# %%
data["Q7"]

fig = plt.subplots(1, figsize=(38, 287))
counts = data["Q7"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q7.duplicated()
data.Q7.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Language Recommendation (Q8)

# %%
data["Q8"]
data.Q8.duplicated()
data.Q8.drop_duplicates()
fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q8"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## IDE Analysis (Q9)

# %%
data['Q9'] = data['Q9_Part_1'].astype(str) + '+' + data['Q9_Part_2'].astype(str) + '+' + data['Q9_Part_3'].astype(str) + '+' + data['Q9_Part_4'].astype(str) + '+' + data['Q9_Part_5'].astype(str) + '+' + data['Q9_Part_6'].astype(str) + '+' + data['Q9_Part_7'].astype(str) + '+' + data['Q9_Part_8'].astype(str) + '+' + data['Q9_Part_9'].astype(str) + '+' + data['Q9_Part_10'].astype(str) + '+' + data['Q9_Part_11'].astype(str) + '+' + data['Q9_Part_12'].astype(str) + '+' + data['Q9_OTHER'].astype(str)
data.Q9.duplicated()
data.Q9.drop_duplicates()
data.dropna()
data.Q9
data["Q9"]

fig = plt.subplots(1, figsize=(22, 389))
counts = data["Q9"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q9.duplicated()
data.Q9.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Notebook Analysis (Q10)

# %%
data['Q10'] = data['Q10_Part_1'].astype(str) + '+' + data['Q10_Part_2'].astype(str) + '+' + data['Q10_Part_3'].astype(str) + '+' + data['Q10_Part_4'].astype(str)
data.fillna("")

data["Q10"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q10"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Platform Analysis (Q11)

# %%
data["Q11"]
data.Q11.duplicated()
data.Q11.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q11"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Hardware Analysis (Q12)

# %%
data['Q12'] = data['Q12_Part_1'].astype(str) + '+' + data['Q12_Part_2'].astype(str) + '+' + data['Q12_Part_3'].astype(str) + '+' + data['Q12_Part_4'].astype(str)
data.fillna("")

data["Q12"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q12"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## TPU Usage Frequency (Q13)

# %%
data["Q13"]
data.Q13.duplicated()
data.Q13.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q13"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Library Analysis (Q14)

# %%
data['Q14'] = data['Q14_Part_1'].astype(str) + '+' + data['Q14_Part_2'].astype(str) + '+' + data['Q14_Part_3'].astype(str) + '+' + data['Q14_Part_4'].astype(str)
data.fillna("")

data["Q14"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q14"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Experience with ML (Q15)

# %%
data["Q15"]
data.Q15.duplicated()
data.Q15.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q15"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Framework Analysis (Q16)

# %%
data['Q16'] = data['Q16_Part_1'].astype(str) + '+' + data['Q16_Part_2'].astype(str) + '+' + data['Q16_Part_3'].astype(str) + '+' + data['Q16_Part_4'].astype(str)
data.fillna("")

data["Q16"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q16"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Algorithm Analysis (Q17)

# %%
data['Q17'] = data['Q17_Part_1'].astype(str) + '+' + data['Q17_Part_2'].astype(str) + '+' + data['Q17_Part_3'].astype(str) + '+' + data['Q17_Part_4'].astype(str)
data.fillna("")

data["Q17"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q17"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Computer Vision Method Analysis (Q18)

# %%
data['Q18'] = data['Q18_Part_1'].astype(str) + '+' + data['Q18_Part_2'].astype(str) + '+' + data['Q18_Part_3'].astype(str) + '+' + data['Q18_Part_4'].astype(str)
data.fillna("")

data["Q18"]

fig = plt.subplots(1, figsize=(8, 12))
counts = data["Q18"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## NLP Method Analysis (Q19)

# %%
data['Q19'] = data['Q19_Part_1'].astype(str) + '+' + data['Q19_Part_2'].astype(str) + '+' + data['Q19_Part_3'].astype(str) + '+' + data['Q19_Part_4'].astype(str)
data.fillna("")

data["Q19"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q19"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Employer Analysis (Q20)

# %%
data["Q20"]
data.Q20.duplicated()
data.Q20.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q20"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Company size Analysis (Q21)

# %%
data["Q21"]
data.Q21.duplicated()
data.Q21.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q21"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Individuals with data science workloads (Q22)

# %%
data["Q22"]
data.Q22.duplicated()
data.Q22.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q22"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Does your current employer incorporate machine learning methods into their business? (Q23)

# %%
data["Q23"]
data.Q23.duplicated()
data.Q23.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q23"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Activities that make up an important part of your role at work (Q24)

# %%
data['Q24'] = data['Q24_Part_1'].astype(str) + '+' + data['Q24_Part_2'].astype(str) + '+' + data['Q24_Part_3'].astype(str) + '+' + data['Q24_Part_4'].astype(str)
data.fillna("")

data["Q24"]

fig = plt.subplots(1, figsize=(18, 27))
counts = data["Q24"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Current yearly compensation (Q25)

# %%
data["Q25"]
data.Q25.duplicated()
data.Q25.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q25"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Money Spent on ML/Cloud (USD) (Q26)

# %%
data["Q26"]
data.Q26.duplicated()
data.Q26.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q26"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Cloud computing platform Analysis (Q27)

# %%
data['Q27'] = data['Q27_A_Part_1'].astype(str) + '+' + data['Q27_A_Part_2'].astype(str) + '+' + data['Q27_A_Part_3'].astype(str) + '+' + data['Q27_A_Part_4'].astype(str)
data.fillna("")

data["Q27"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q27"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Q28 Of the cloud platforms that you are familiar with, which has the best developer experience (most enjoyable to use)?

# %%
data["Q28"]
data.Q28.duplicated()
data.Q28.drop_duplicates()
fig = plt.subplots(1, figsize=(10, 7))
counts = data["Q28"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Q29-A Do you use any of the following cloud computing products on a regular basis?

# %%
data['Q29'] = data['Q29_A_Part_1'].astype(str) + '+' + data['Q29_A_Part_2'].astype(str) + '+' + data['Q29_A_Part_3'].astype(str) + '+' + data['Q29_A_Part_4'].astype(str)
data.fillna("")

data["Q29"]

fig = plt.subplots(1, figsize=(8, 7))
counts = data["Q29"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Q30-A Do you use any of the following data storage products on a regular basis?

# %%
data['Q30_A_'] = data['Q30_A_Part_1'].astype(str) + '+' + data['Q30_A_Part_2'].astype(str) + '+' + data['Q30_A_Part_3'].astype(str) + '+' + data['Q30_A_Part_4'].astype(str) + '+' + data['Q30_A_Part_5'].astype(str) + '+' + data['Q30_A_Part_6'].astype(str) + '+' + data['Q30_A_Part_7'].astype(str) + '+' + data['Q30_A_OTHER'].astype(str)
data.Q30_A_.duplicated()
data.Q30_A_.drop_duplicates()
data.dropna()
data.Q30_A_
data["Q30_A_"]

fig = plt.subplots(1, figsize=(38, 88))
counts = data["Q30_A_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q30_A_.duplicated()
data.Q30_A_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
sns.set(font_scale=25)
plt.show()

# %% [markdown]
# ## Q31-A Do you use any of the following managed machine learning products on a regular basis? (Select all that apply)

# %%
data['Q31_A_'] = data['Q31_A_Part_1'].astype(str) + '+' + data['Q31_A_Part_2'].astype(str)
data.Q31_A_.duplicated()
data.Q31_A_.drop_duplicates()
data.dropna()
data.Q31_A_
data["Q31_A_"]

fig = plt.subplots(1, figsize=(38, 88))
counts = data["Q31_A_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q31_A_.duplicated()
data.Q31_A_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)

plt.show()

# %% [markdown]
# ## Q32-A Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis?

# %%
data['Q32_A_'] = data['Q32_A_Part_1'].astype(str) + '+' + data['Q32_A_Part_2'].astype(str)
data.Q32_A_.duplicated()
data.Q32_A_.drop_duplicates()
data.dropna()
data.Q32_A_
data["Q32_A_"]

fig = plt.subplots(1, figsize=(38, 88))
counts = data["Q32_A_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q32_A_.duplicated()
data.Q32_A_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Q33 Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often?

# %%
data["Q33"]
data.Q33.duplicated()
data.Q33.drop_duplicates()
fig = plt.subplots(1, figsize=(30, 70))
counts = data["Q33"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Q34-A Which of the following business intelligence tools do you use on a regular basis?

# %%
data['Q34_A_'] = data['Q34_A_Part_1'].astype(str) + '+' + data['Q34_A_Part_2'].astype(str)
data.Q34_A_.duplicated()
data.Q34_A_.drop_duplicates()
data.dropna()
data.Q34_A_
data["Q34_A_"]

fig = plt.subplots(1, figsize=(30, 78))
counts = data["Q34_A_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q34_A_.duplicated()
data.Q34_A_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Q35 Which of the following business intelligence tools do you use most often?

# %%
data["Q35"]
data.Q35.duplicated()
data.Q35.drop_duplicates()
fig = plt.subplots(1, figsize=(7, 60))
counts = data["Q35"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Q36-A Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis?

# %%
data['Q36_A_'] = data['Q36_A_Part_1'].astype(str) + '+' + data['Q36_A_Part_2'].astype(str) + '+' + data['Q36_A_Part_3'].astype(str) + '+' + data['Q36_A_Part_4'].astype(str)
data.Q36_A_.duplicated()
data.Q36_A_.drop_duplicates()
data.dropna()
data.Q36_A_
data["Q36_A_"]

fig = plt.subplots(1, figsize=(38, 388))
counts = data["Q36_A_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q36_A_.duplicated()
data.Q36_A_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
sns.set(font_scale=25)
plt.show()

# %% [markdown]
# ## Q37-A Which of the following automated machine learning tools (or partial AutoML tools) do you use on a regular basis?

# %%
data['Q37_A_'] = data['Q37_A_Part_1'].astype(str) + '+' + data['Q37_A_Part_2'].astype(str) + '+' + data['Q37_A_Part_3'].astype(str) + '+' + data['Q37_A_Part_4'].astype(str) + '+' + data['Q37_A_Part_5'].astype(str)
data.Q37_A_.duplicated()
data.Q37_A_.drop_duplicates()
data.dropna()
data.Q37_A_
data["Q37_A_"]

fig = plt.subplots(1, figsize=(48, 388))
counts = data["Q37_A_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q37_A_.duplicated()
data.Q37_A_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Q38-A Do you use any tools to help manage machine learning experiments?

# %%
data['Q38_A_'] = data['Q38_A_Part_1'].astype(str) + '+' + data['Q38_A_Part_2'].astype(str) + '+' + data['Q38_A_Part_3'].astype(str) + '+' + data['Q38_A_Part_4'].astype(str) + '+' + data['Q38_A_Part_5'].astype(str)
data.Q38_A_.duplicated()
data.Q38_A_.drop_duplicates()
data.dropna()
data.Q38_A_
data["Q38_A_"]

fig = plt.subplots(1, figsize=(88, 348))
counts = data["Q38_A_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q38_A_.duplicated()
data.Q38_A_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)

plt.show()

# %% [markdown]
# ## Q39 Where do you publicly share or deploy your data analysis or machine learning applications?

# %%
data['Q39_'] = data['Q39_Part_1'].astype(str) + '+' + data['Q39_Part_2'].astype(str) + '+' + data['Q39_Part_3'].astype(str) + '+' + data['Q39_Part_4'].astype(str)
data.Q39_.duplicated()
data.Q39_.drop_duplicates()
data.dropna()
data.Q39_
data["Q39_"]

fig = plt.subplots(1, figsize=(89, 88))
counts = data["Q39_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q39_.duplicated()
data.Q39_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Q40 On which platforms have you begun or completed data science courses?

# %%
data['Q40_'] = data['Q40_Part_1'].astype(str) + '+' + data['Q40_Part_2'].astype(str) + '+' + data['Q40_Part_3'].astype(str) + '+' + data['Q40_Part_4'].astype(str)

data.Q40_.duplicated()
data.Q40_.drop_duplicates()
data.dropna()
data.Q40_
data["Q40_"]

fig = plt.subplots(1, figsize=(80, 88))
counts = data["Q40_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q40_.duplicated()
data.Q40_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()

# %% [markdown]
# ## Q41 What is the primary tool that you use at work or school to analyze data?

# %%
data["Q41"]
data.Q41.duplicated()
data.Q41.drop_duplicates()
fig = plt.subplots(1, figsize=(40, 40))
counts = data["Q41"].value_counts()
sns.barplot(x = counts.values, y=counts.index)


plt.show()

# %% [markdown]
# ## Q42 Who/what are your favorite media sources that report on data science topics?

# %%
data['Q42_'] = data['Q42_Part_1'].astype(str) + '+' + data['Q42_Part_2'].astype(str) + '+' + data['Q42_Part_3'].astype(str) + '+' + data['Q42_Part_4'].astype(str)
data.Q42_.drop_duplicates()
data.dropna()
data.Q42_
data["Q42_"]

fig = plt.subplots(1, figsize=(82, 328))
counts = data["Q42_"].value_counts()
sns.barplot(x = counts.values, y=counts.index)
data.Q42_.duplicated()
data.Q42_.drop_duplicates()
data.fillna(0)
data.isnull().sum()
data.replace(np.nan, 0)
plt.show()
