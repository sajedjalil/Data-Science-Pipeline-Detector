# %%
# %matplotlib inline
from IPython.core.display import display, HTML, Javascript

html_contents ="""
<!DOCTYPE html>
<html lang="en">
    <head>
        <link rel="stylesheet" href="https://www.w3schools.com/w3css/4/w3.css">
        <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto">
        <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Verdana">
        <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Open Sans">
        <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
        <style>
        .title-section{
            font-family: "Roboto", Verdana, sans-serif;
            font-weight: bold;
            color: "Magenta";
            letter-spacing: 6px;
        }
        hr { border: 1px solid #E58F65 !important;
             color: #E58F65 !important;
             background: #E58F65 !important;
           }
        body {
            font-family: "Roboto", sans-serif;
            }        
        </style>
    </head>    
</html>
"""

HTML(html_contents)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <p style="padding: 20px;  color:white;">
#               Welcome to the Great Data Science Survey from Kaggle - 2021 Edition
# </p>
# </div>
#
#
# <table style="width:100%">
#   <tr>
#     <td><img src="https://live.staticflickr.com/7187/6964774217_53d449288a_c.jpg" height=200></td>
#     <td><img src="https://upload.wikimedia.org/wikipedia/commons/7/7f/Data_scientist_Venn_diagram.png" height=200></td>
#   </tr>
#   <tr>
#      <td><img src="https://upload.wikimedia.org/wikipedia/commons/4/44/DataScienceDisciplines.png" height=200></td>
#     <td><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/10/Data-Science-Landscape.jpg/543px-Data-Science-Landscape.jpg" height=200></td>
#   </tr>
# </table>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;  color:white;">
#               This is a work in progress. Sharing the no code version!
# </p>
# </div>
#
#
# <a id="table-of-contents"></a>
# # <span class="title-section w3-xxlarge" style="color:#FF0080">2021 Kaggle Machine Learning & Data Science Survey - Analysis  </span>
#
#
# ### State of Machine Learning and Data Science 2021 Insights from Kaggle’s annual user survey focused on working data scientists.
# #### Kaggle's 5th year conducting an in-depth user survey of over 25,000 data scientists and ML engineers covering responses on their backgrounds and day to day experience – everything from educational details to salaries to preferred technologies and techniques.
#
# ## [1. Countries / Locations Analysis for 2021 Kaggle Machine Learning & Data Science Survey](#1)
# ## [2. Gender Analysis](#2)
# ## [3. Job Title / Role Analysis](#3)
# ## [4. Degree & Experience Analysis](#4)
# ## [5. Coding Skills Analysis](#5)
# ## [6. India Centric Analysis](#6)
# ## [7. Industry and Tools Analysis](#7)
# ## [8. Compensation Analysis](#8)
# ## [Work In Progress](#999)
#
# ## # <span class="title-section w3-xlarge" style="color:#FF0080">📌 All the analysis is performed using an external tool and images are loaded as an output. The tools used were  Microsoft Power BI and Excel </span>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">Let us first see the participating locations!</span>

# %% [markdown]
# [back to top](#table-of-contents)
#
# <a id="1"></a>
#
# # <span class="title-section w3-xxlarge" style="color:#FF0080">1. Countries / Locations Analysis for 2021 Kaggle Machine Learning & Data Science Survey</span>

# %% [markdown]
# ### <span class="title-section w3-large" style="color:#FF0080"> Let us see a map view of the responses along with the bubble for the size of the responses </span>
#
# * No Surprises here - India leads the number of respondents

# %%
import PIL # We will import the packages at "use-time (just for this kernel)

PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_01_map.PNG")

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">Another view of the respondeds based on Questions 2 & 3 </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_05.png")

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">📌   Not Surprising that India has the maximum responses</span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">Table and Bar Chart of Country Specific Responses</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_01_bar_chart_table.PNG")

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> 📌   India, US, China, Japan, Russia and Brazil have the maximum responses </span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">A Histogram Analysis</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_01_Histogram_Gender.png")

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">📌   Mostly younger professionals responded more - a symbolic representation of how young and novel this area is!</span>

# %% [markdown]
# ## <span class="title-section w3-large" style="color:#FF0080">A Treemap style view of the responses </span>

# %%
from PIL import Image
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_02_Treemap_Participating_Nations.png")

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">Another rendition of treemap</span>

# %% [markdown]
# ## <span class="title-section w3-large" style="color:#FF0080">A Bigger image</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_02.png")

# %% [markdown]
# ## <span class="title-section w3-large" style="color:#FF0080"> 📌  Same messages represented in a different format! </span>

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:#FF0080">A Funnel view of the country data </span>
# ####  <span class="title-section w3-medium" style="color:#FF0080">📌   Another rendition in a different view </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_03.png")

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="2"></a>
# #  <span class="title-section w3-xxlarge" style="color:#FF0080"> 2. Gender Analysis </span>

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080"> A Pie chart and a Donut Chart view of Gender </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_04.png")

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">📌   82% of the gender identify themselves as Men. More Men than Women. No surprises here. The question will be how can these numbers become on par in future surveys! </span>

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="3"></a>
# #  <span class="title-section w3-xxlarge" style="color:#FF0080">3. Job Title / Role Analysis</span>

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">Let us analyze the Job Title and Role for the data shared. </span>
#
# <div style="color:blue;
#            display:fill;
#            border-radius:5px;
#            background-color:white;
#            font-size:110%;
#            font-family:Roboto;
#            letter-spacing:0.5px">
#     <ol> 1. Chart-1 - A Ribbon Chart covering the job titles and the country </ol>
#     <ol> 2. Chart-2 - A Donut Chart covering the job titles and the country </ol>
#     <ol> 3. Chart-3 - A Treemap Chart covering the job titles and the country </ol>
#     <ol> 4. Chart-4 - A Funnel Chart covering the job titles and the country </ol>
# </div>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_06.png")

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="4"></a>
# #  <span class="title-section w3-xxlarge" style="color:#FF0080">4. Educational Qualifications & Experience Analysis </span>

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">Let us analyze the Educational Qualififcations & Experience for the data shared.</span>
#
# * 1. Chart-1 - A Ribbon Chart covering the Qualifications and Experience levels
# * 2. Chart-2 - A Donut Chart covering the Qualifications and Experience levels
# * 3. Chart-3 - A simple barchart covering the Job Title
# * 4. Chart-4 - A Ribbon Chart covering the Educational Qualification and Job Title

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_07.png")

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">A Simple Funnel Chart on educational qualification / degrees and Country specific bar chart</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_08.png")

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">A chart on educational qualification / degrees and Country specific bar chart</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_Q3_5_Experience_and_Job_Title.png")

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">A Simple Line Chart on educational qualification / degrees and Country specific bar chart</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_11.png")

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="5"></a>
# #  <span class="title-section w3-xxlarge" style="color:#FF0080">5. Coding Skills Analysis</span>

# %% [markdown]
# ## Let us analyze the Coding Experience - How long have you been programming

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_09.png")

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">Let us analyze the Coding Experience - How long have you been programming at a country level</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_10.png")

# %% [markdown]
# [back to top](#table-of-contents)

# %% [markdown]
# <a id="6"></a>
# #  <span class="title-section w3-xxlarge" style="color:#FF0080">6. India Centric Analysis</span>

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">Let us analyze from the Job Titles and Educational Levels</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_12.png")

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#1000FF">📌  Very Clear that mostly students use Kaggle during their studies - especially engineering students use the platform extensively for improving their knowledge, learning and get recognition for better campus placements and for higher studies! Most of the students start early in their bachelors. A lot of data scientists with Master's degree follow the bachelor's degree</span>

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#FF0080">Let us analyze a gender centric educational qualifications in India</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_14.png")

# %% [markdown]
# ###  <span class="title-section w3-xlarge" style="color:#1000FF"> 📌  It is very clear that the percentage of women with Master's is more than that of the Men. A clear indication of the quality of contribution made by women data scientists. While the number of students with bachelor's is more for men, the proportion reduces. May be many move to non-data science fields or lose interest in kaggle. It is most likely the latter as the attention span and interest levels can reduce and the focus moves onto other things for men after their graduation </span>

# %% [markdown]
# ##  <span class="title-section w3-xlarge" style="color:#1000FF"> Let us analyze a gender centric compensation in India</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_15.png")

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:#FF0080"> 📌 Not much disparity seen here. Diversity & Inclusion initiatives and a level playing field set contributes here. This is a good trend, especially when it comes to EPIC pledge etc. An age centric analysis can provide a better view </span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us analyze a job title centric compensation in India </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_16.png")

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:#FF0080"> 📌  It is very evident that students and unemployed do not make much money.Majority make in the range of 10K + USD salary which corresponds to about 750K INR or 7.5 Lakhs (or 750K/Thousand ) Plus. </span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us take a look at the job title and educational qualification correlation in India through a Ribbon Chart </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Page_17.png")

# %% [markdown]
# ###  <span class="title-section w3-xlarge" style="color:#1000FF">  📌  It is very evident that Students and majorly students doing their Bachelor's degree or fresh graduates working in their first job make up the majority of the respondents. This is applicable across the genders. There are limited number of statisticians, product managers, research scientists responding to the survey. The interesting piece of inference is that data engineers and machine learning engineers have not responded much as majority of the role/titles correspond to data scientist as it is considered to be more catchy, appealing and sexy job title </span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us take a map centric heatmap across gender types </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_03_Map_Gender.png")

# %% [markdown]
# [back to top](#table-of-contents)

# %% [markdown]
# <a id="7"> </a>
# # <span class="title-section w3-xlarge" style="color:#FF0080">7. Industry and Tools Analysis</span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us take a Industry centric view of the data</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_Q26_Industry_and_size.png")

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:#FF0080"> 📌  It is very clear from data that the Tech industry leads the respondents with most participants from either large or small firms - giving a spread and a view on the importance of this subject across the spectrum </span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us take a look at the tools preferred by the respondents </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_41_BI_Tools_Degree.png")

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_41_BI_Tools_Degree.png")

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_Q41_Primary_Tool_Used.png")

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:#FF0080"> 📌  It is very clear that Basic statistical software (Microsoft Excel, Google Sheets, etc.)lead the pack followed by Local development environments (RStudio, JupyterLab, etc.)and bit costlier Business intelligence software (Salesforce, Tableau, Spotfire, etc.). The Cloud-based data software & APIs (AWS, GCP, Azure, etc.) is picking up the trend. Traditional machine learning engineers and statisticians use Advanced statistical software (SPSS, SAS, etc.)for their day to day work.</span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us take a look at the Database preferred by the respondents </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_Q33_Primary_DB_Tool_Used.png")

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:#FF0080"> 📌  It is very clear that MySQL , PostgreSQL and MongoDB lead the pack. This is closely followed by traditional player such as Microsoft SQL Server and Oracle Database. Cloud based and new age tools such as Microsoft Azure SQL Database, Google Cloud BigQuery, Snowflake are picking up steam</span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us take a look at the Business Intelligence Tool preferred by the respondents </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_Q35_Primary_BI_Tool_Used.png")

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:lime"> 📌  It is very clear Tableau and Microsoft Power BI are the most preferred followed by Google Data Studio and QlikSense. Others are catching up!</span>

# %% [markdown]
# [back to top](#table-of-contents)

# %% [markdown]
# <a id="8"></a>
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> 8. Compensation Analysis</span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us take a look at the Salary Range and the correlation to Job Titles using a bar chart </span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_Q25_Salary_and_Title.png")

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> It is clear that there are many hobbyists and people not in active work are using Kaggle extensively. This includes Students majorly.</span>

# %%
PIL.Image.open("../input/2021-kaggle-machine-learning-data-science-survey/Kaggle Survey Analysis_Excel_Q25_Compensation_Salary.png")

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">Another view in a sorted manner on Salary Ranges</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q25_Compensation_Chart.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Salary Range with percentage distribution across ranges</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q25_Salary_Range.png')

# %% [markdown]
# ### <span class="title-section w3-large" style="color:#FF0080"> A Horizontal Bar chart view</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q3_USA_Salary_Range.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> The Salary Levels for the respondents from the USA is definitely on the opposite side compared to India due to obvious reasons - 1. Less Students responding and 2. Better Salary in terms of '$ value' </span>

# %% [markdown]
# ### <span class="title-section w3-xlarge" style="color:#FF0080"> 📌  Salary levels are on the lower side due to the participant profile being students, unemployed or waiting to enter the job market and doing entry level work in smaller firms.</span>

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:blue"> Part-II of the analysis </span>
#
# ### <span class="title-section w3-large" style="color:#FF0080"> Let us analyse the key questions from the survey in an analytical manner </span>

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q1 What is your age (# years)? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q1_Age_Bar_Chart.png')

# %% [markdown]
# #### <span class="title-section w3-medium" style="color:#FF0080"> It is clear that younger generation <30 years of age responded extensively to the survey and it highlights that mostly millenials and Gen-Z form the majority of the Kagglers</span>

# %% [markdown]
# ### <span class="title-section w3-large" style="color:#FF0080"> Let us see another view with the number of respondents and a barchart</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Age_Distribution_Summary.png.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q2 What is your gender? </span>
#
# ### <span class="title-section w3-large" style="color:#FF0080"> Let us see the gender analysis of the respondents</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Gender_horiz_bar_graph.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Let us see how age and gender compare in terms of respondents</span>
#
# ### <span class="title-section w3-xlarge" style="color:#FF0080"> It is clear that the numbers and percentage almost tally (albeit a fewer number from females) age-wise - almost </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Q3_Age_and_Gender_graph.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Q3_Age_Gender_Distribution.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080">💥Interesting fact Ages 22-24 have fewer respondents - It may correspond to the Kagglers graduating and joining the first job and getting very busy in their daily jobs to establish themselves and embark on Data Science extensively after few years of experience.</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Q3_Age_Gender_Horiz_Bar_Chart.png')

# %% [markdown]
# #### <span class="title-section w3-medium" style="color:#FF0080"># A Simple Horizontal Bar Chart</span>

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q3 In which country do you currently reside? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q3_show_countplot_by_qno.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Top-8 Nations with Respondents </span>
# * India
# * USA
# * Japan
# * China
# * Brazil
# * Russia
# * Nigeria
# * UK

# %% [markdown]
# ### Let us see a waffle chart

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q4_Country_Waffle_Chart.png')

# %% [markdown]
# ### <span class="title-section w3-large" style="color:#FF0080"> Let us see the proportion of gender , when it comes to the top respondents </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Q4_Country_Gender_Distribution.png')

# %% [markdown]
# ### <span class="title-section w3-large" style="color:#FF0080"> 📊 More Graphs 📊 </span>

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q4 🎓 What is the highest level of formal education that you have attained or plan to attain within the next 2 years? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q4_Qualification.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q5_Educational_Qualification.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q5 Select the title most similar to your current role </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q5_Role_QUalification.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Q14_Q15_Female_Position_ML_experience.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Q14_Q15_Male_Position_ML_experience.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q2_Q5_Q8_Gender__Position_ML_Experience.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q6 For how many years have you been writing code and/or programming?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q6_Programming_Experience.png')

# %% [markdown]
# ****

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q5_Q6_Education_Experience_Pivot.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q6_Experience_Distribution.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q15_ML_Experience.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q7 What programming languages 📝💥do you use on a regular basis? </span>
#
# ### 🐼

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q8_Programming_Skills.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q8_Q2_Programming_Languages_Gender.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q8 What programming language would you recommend an aspiring data scientist to learn first? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q8_Top_Programming_Languages_Recommended.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q9 Which of the following integrated development environments (IDE's) do you use on a regular basis?  </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q9_Top_IDE.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q10 Which of the following hosted notebook 📓📚📙products do you use on a regular basis? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q10_Top_Notebook_Products.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q11 What type of computing platform do you use most often for your data science projects? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q11_Computing_Platform.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q11_Top_Computing_Devices_Platform.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q12 Which types of specialized hardware 🧲💪do you use on a regular basis? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q12_Top_Special_Hardware.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q13 🧮 Approximately how many times have you used a TPU (tensor processing unit)?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q13_TPU_Usage.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q14 🎨 What data visualization libraries or tools do you use on a regular basis? (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q14_Top_Visualization_Tools.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q14_Visualization_Library.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q15 For how many years have you used machine learning methods?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q14_Q2_Earning_Gender_Distribution.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q15_Earning_Per_Role.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q16 Which of the following machine learning frameworks do you use on a regular basis? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q16_Top_MLFrameworks_Tools.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"># Q17 Which of the following ML algorithms do you use on a regular basis? </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q17_Top_ML_Algorithms.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q18 Which categories of computer vision methods do you use n a regular basis?  (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q18_Top_CV_Methods.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q19 📚 Which of the following natural language processing (NLP) methods do you use on a regular basis?  (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q19_Top_NLP_Methods_Tools.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q20 🏢 What is the size of the company where you are employed?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q20_Top_Companies.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q21 Approximately how many individuals are responsible for data science workloads at your place of business?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q21_Company_Sizes.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080">Q22 Does your current employer incorporate machine learning methods into their business?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q22_Size_ML_Team.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q23 Select any activities that make up an important part of your role at work: (Select all that apply) </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q23_Current_ML_Tools_Usage.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q24_How_You_Plan_to_use_Tools.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q26 cloud computing platforms</span>
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q26_A Which of the following cloud computing platforms do you use on a regular basis? (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q26_How_much_is_your_company_planning_to_spend.png')

# %% [markdown]
# # <span class="title-section w3-xlarge" style="color:#FF0080"> Next Set of Questions on Platforms 🚝🏎</span>

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q26_B Which of the following cloud computing platforms do you hope to become more familiar with in the next 2 years?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q27A_Top_Computing_Platform.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q27 Top Cloud computing products</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q27A_Top_Computing_Platform.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q27_A Do you use any of the following cloud computing products on a regular basis? (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q27B_Top_Computing_Platforms_in_next_2_Years.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q27_B In the next 2 years, do you hope to become more familiar with any of these specific cloud computing products? (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q28_Top_Cloud_Computing_Platform_In_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q28 Top machine learning products </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q29_Top_Cloud_Computing_Virtual_Machine_Platform_In_Use.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q28_A Do you use any of the following machine learning storage products on a regular basis? (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q30_Top_Cloud_Computing_Platform_Storage_In_Use.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q28_B In the next 2 years, do you hope to become more familiar with any of these specific machine learning products? (Select all that apply) </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q31_Top_ML_Products_Planned_For_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q29  big data products</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q32_Top_Big_Data_Products_Planned_For_Use.png')

# %% [markdown]
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q29_A Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis? (Select all that apply) </span>
#
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q29_B Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years? (Select all that apply)</span>
#
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q30 Which of the following big data products (relational database, data warehouse, data lake, or similar) do you use most often? - Selected Choice</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q33_Top_Database_Products_Planned_For_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q31 business intelligence tools</span>
#
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q31_A Which of the following business intelligence tools do you use on a regular basis? (Select all that apply)</span>
#
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q31_B Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years? (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q34_Top_BI_Products_Planned_For_Use.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q35_Top_BI_Tools_Products_Planned_For_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q32 Which of the following business intelligence tools do you use most often? - Selected Choice</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q36_Top_BI_Products_Planned_For_Future_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q33 automated machine learning tools (or partial AutoML tools)</span>
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q33_A Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis?  (Select all that apply)</span>
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q33_B Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?  (Select all that apply)</span>
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Q34 automated machine learning tools (or partial AutoML tools)</span>
# ## <span class="title-section w3-xlarge" style="color:#FF0080"> Q34_A Which of the following automated machine learning tools (or partial AutoML tools) do you use on a regular basis?  (Select all that apply)</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q37_Top_AutoML_Products_Planned_For_Use.png')

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q38_Top_Futuristic_ML_Products_Planned_For_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> What are the top sources you use for publishing your Data Science experiments</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q39_Top_DS_Publication_Products_Planned_For_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Which Learning Platforms do you use for learning Data Science </span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q40_Top_Learninig_Products_Planned_For_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> Which Analytical Tools are you planning to use?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q41_Top_Analytical_Tool_For_Use.png')

# %% [markdown]
# # <span class="title-section w3-xxlarge" style="color:#FF0080"> What are your top media sources for Data Science?</span>

# %%
PIL.Image.open('../input/2021-kaggle-machine-learning-data-science-survey/Q42_Top_Media_Sources_For_Use.png')

# %%
import pandas as pd
dummydata = {'ID':[1,2,3], 'Value': [0.5,0.1,0.2]}
df = pd.DataFrame(dummydata)
df.to_csv("submission.csv", index =False)

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="999"></a>
# # <span class="title-section w3-xxlarge" style="color:#FF0080">Work in Progress</span>

# %% [markdown]
# <img src= "https://raw.githubusercontent.com/ArctosDB/documentation-wiki/gh-pages/tutorial_images/Bear%20Work%20in%20Progress.JPG" alt ="Work In Progress">
#
# ### <span class="title-section w3-large" style="color:#FF0080">Thanks for viewing this notebook. More analysis and visualization will be added soon.</span>
