# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
survey = pd.read_csv('/kaggle/input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')
survey.shape

# %%
survey.head()

# %%
survey.columns.T

# %%
s = survey.copy()

# %%
with pd.option_context('display.max_colwidth', None):
    display(survey.iloc[:1 ].T)

# %%
s = s.iloc[1: , :]
s.head()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Age Distribution
s.Q1.value_counts()

# %% [markdown]
# # fsdfsdf #
# [Home](http://)

# %%
s.Q2.value_counts()

# %%
### Clean data
s['Q2'] = s['Q2'].replace({'Prefer not to say' : 'Other' , 'Nonbinary' : 'Other' , 'Prefer to self-describe' : 'Other'})
s.Q2.value_counts()

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(131)
sns.countplot(x="Q2", hue="Q1", palette="pastel", edgecolor=".8", data=s , ax=ax1 , dodge=True , order = s['Q2'].value_counts().index)

# %%
def plotcount(feat1,feat2):
    fig = plt.figure(20,20)
    sns.countplot(y=feat1, hue=feat2, palette="pastel", edgecolor=".8", data=s , ax=ax1 , dodge=True , order = df[f1].value_counts().index)

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(131)
sns.countplot(y="Q3", hue="Q2", palette="pastel", edgecolor=".8", data=s , ax=ax1 , dodge=True , order = s['Q3'].value_counts().index)

# %%
chk = s[s['Q3'] == 'India']
chk
#fig = plt.figure(figsize=(20,20))
#ax1 = fig.add_subplot(131)
#sns.countplot(y='Q3', hue="Q1", palette="pastel", edgecolor=".8", data=chk , ax=ax1 , dodge=True , order = s['Q3'].value_counts().index)

# %%
s.Q4.value_counts()

# %%
### Clean data
s['Q4'] = s['Q4'].replace({'Some college/university study without earning a bachelor’s degree' : 'Other' , 'I prefer not to answer' : 'Other' , 'No formal education past high school' : 'Other' , 
                          'Professional doctorate' : 'Doctoral degree' })
s.Q4.value_counts()

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(131)
sns.countplot(y="Q3", hue="Q4", palette="pastel", edgecolor=".8", data=s , ax=ax1 , dodge=True , order = s['Q3'].value_counts().index)

# %%
s.Q5.value_counts()

# %%
fig = plt.figure(figsize=(20,20))
sns.catplot(y="Q2", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(131)
sns.countplot(y="Q3", hue="Q6", palette="pastel", edgecolor=".8", data=s , ax=ax1 , dodge=True , order = s['Q3'].value_counts().index)

# %%
s.head(1)

# %%
with pd.option_context('display.max_colwidth', None):
  display(survey['Q7_Part_1'].head(1))
  display(survey['Q7_Part_2'].head(1))
  display(survey['Q7_Part_3'].head(1))
  display(survey['Q7_Part_4'].head(1))

# %%
cols = [cols for cols in s.columns if '_Part_' in cols]
#cols

# %%
cols = [cols for cols in s.columns if 'Q7_Part_' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ### Observations
# 1. Python is most popular language with 21K counts followed by SQL 10K and R 5K then comes C , C++ , JAVA etc.

# %%
fig = plt.figure(figsize=(20,20))
sns.catplot(y="Q7_Part_1", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Python Usages Amongst Population By Designation')

# %%
fig = plt.figure(figsize=(20,20))
sns.catplot(y="Q7_Part_3", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('SQL Usages Amongst Population By Designation')

# %%
fig = plt.figure(figsize=(20,20))
sns.catplot(y="Q7_Part_2", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('R Usages Amongst Population By Designation')

# %% [markdown]
# ### Observation : For top 3 skills
# 1. Python is more popular amongst student (may be due to technical easness and learning content availability) . Next it is popular with Data Scientists
# 2. SQL is more popular with Students & Data Scientists. Also it shows more popularity within Software engineers as they are mostly familier with syntax and tech details.
# 3. R is is more popular with Students & Data Scientists & Data Analyst.
#
# We can further drill down to check conuntry wise and age wise the popularity of technologies

# %%
pt = pd.pivot_table(s, values=['Q7_Part_1', 'Q7_Part_2' , 'Q7_Part_3'], index=['Q3'],
                    aggfunc={'Q7_Part_1': 'count',
                             'Q7_Part_2': 'count',
                            'Q7_Part_3' : 'count'})
pt

# %%
fig = plt.figure(figsize=(20,8))
pt['Q7_Part_1'].plot(kind="bar")
plt.title('Python Usage Country Wise')

# %%
fig = plt.figure(figsize=(20,8))
pt['Q7_Part_2'].plot(kind="bar")
plt.title('R Usage Country Wise')

# %%
fig = plt.figure(figsize=(20,8))
pt['Q7_Part_3'].plot(kind="bar")
plt.title('SQL Usage Country Wise')

# %%
pt_age = pd.pivot_table(s, values=['Q7_Part_1', 'Q7_Part_2' , 'Q7_Part_3'], index=['Q6'],
                    aggfunc={'Q7_Part_1': 'count',
                             'Q7_Part_2': 'count',
                            'Q7_Part_3' : 'count'})
pt_age

# %%
fig = plt.figure(figsize=(10,8))
pt_age['Q7_Part_1'].plot(kind="bar")
plt.title('Python Usage Age Wise')

# %%
fig = plt.figure(figsize=(10,8))
pt_age['Q7_Part_2'].plot(kind="bar")
plt.title('R Usage Age Wise')

# %%
fig = plt.figure(figsize=(10,8))
pt_age['Q7_Part_3'].plot(kind="bar")
plt.title('SQL Usage Age Wise')

# %%
fig = plt.figure(figsize=(10,8))
N = 7
ind = np.arange(N)

orange_bar = pt_age['Q7_Part_1']
blue_bar = pt_age['Q7_Part_3']
width = 0.3

plt.bar(ind, blue_bar , width, label='SQL')
plt.bar(ind + width, orange_bar, width, label='Python')
plt.xticks(ind + width / 2, ('1-3 years', '10-20 years', '20+ years' , '3-5 years' , '5-10 years' , '< 1 years' , 't'))

plt.legend(loc='best')

# %%
#cols = [cols for cols in s.columns if '_Part_' in cols]
#cols

# %%
def display_full(feature):
    with pd.option_context('display.max_colwidth', None):
        display(survey[feature].head(1))

# %%
display_full('Q8')

# %%
pd.pivot_table(s, values=['Q8'], index=['Q6'],aggfunc={'Q8': 'count'})

# %%
s['Q8'].value_counts()

# %%
chk_age_skill = s.groupby(['Q8' , 'Q6'])['Q8'].count()
chk_age_skill

# %%
chk_age_skill.sort_values().tail(40)

# %%
# = [cols for cols in s.columns if '_Part_' in cols ]
cols = ['Q9_Part_1', 'Q9_Part_2', 'Q9_Part_3', 'Q9_Part_4', 'Q9_Part_5', 'Q9_Part_6', 'Q9_Part_7', 'Q9_Part_8',
 'Q9_Part_9', 'Q9_Part_10', 'Q9_Part_11', 'Q9_Part_12']
for f in cols :
    display_full(f)

# %%
cols = [cols for cols in s.columns if 'Q9_Part_' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ### Observations for top 3 IDEs
# 1. Jupyter Notebook is most popular with 16K followed by isual Studio Code (VSCode) 10 k and PyCharm 7K

# %%
fig = plt.figure(figsize=(20,20))
sns.catplot(x="Q9_Part_11", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Jupyter Usages Amongst Population By Designation')

# %%
fig = plt.figure(figsize=(20,20))
sns.catplot(x="Q9_Part_4", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Visual Studio Usages Amongst Population By Designation')

# %%
fig = plt.figure(figsize=(20,20))
sns.catplot(x="Q9_Part_5", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Visual Studio Usages Amongst Population By Designation')

# %%
#c = [cols for cols in s.columns if '_Part_' in cols ]
cols = [cols for cols in s.columns if 'Q10_Part_' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ###  Observations
# 1. Kaggle notebook and Google colab are the most preffered notebook product with almost similar users of 9K

# %%
#c = [cols for cols in s.columns if '_Part_' in cols ]
cols = [cols for cols in s.columns if 'Q11' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q12_Part' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ### Observations
# 1. Most of the people 13K are not using any specilized hardware on regular basis . This links to fact that most of the population is from students.
# 2. NVIDIA GPUs is next in line with around 8K users
# 3.From cloud , GCP is leading where GCP TPU's are next with 3K users

# %%
cols = [cols for cols in s.columns if 'Q13' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# TPU's are generally needed to run huge volume data in deep learnings. These are costly as well so heighest count is users not using it

# %%
cols = [cols for cols in s.columns if 'Q14_Part' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ### Observation
# 1. It is very surprising that 3K users are ot using any visualizations as it is fundamental part of data analysis.
# 2. Matplotlib & Seaborn are most popular
# 3.  Plotly / Plotly & ggplot are most popular from R . As the R users are less than python this count is also low

# %%
cols = [cols for cols in s.columns if 'Q15' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
pd.crosstab(index= s['Q15'] , columns=s['Q2']).plot(kind="bar", 
                 figsize=(20,15),
                 stacked=True)

# %% [markdown]
# ### Observations
# Good thing is , more Woman are entering into Machine learning . Less than one year & 1-2 year has most of the woman population.

# %%
pd.crosstab(index= s['Q15'] , columns=s['Q11']).plot(kind="bar", 
                 figsize=(20,15),
                 stacked=True)

# %% [markdown]
# Cloud computing is more popular with population with 3 years or less experience than others

# %%
cols = [cols for cols in s.columns if 'Q16_Part' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# scikit-learn is most popular machine learning frameworks 14K followed by TensorFlow 9K and then Keras and Pytorch

# %%
cols = [cols for cols in s.columns if 'Q17_Part' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ### Observation
# 1. Linear or Logistic Regression is most popular ML Algo that is used by around 13K users
# 2. Decision Trees or Random Forests is second with 11K
# 3. Gradient Boosting Machines (xgboost, lightgbm, etc) &  Convolutional Neural Networks  are almost similarly used 7K
# 4. There are entries for None as well . Further checks can be applied on who are those users
# 5. Bayesian Approaches    4392 ,  Dense Neural Networks (MLPs, etc)    4468 , Recurrent Neural Networks    4228

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_1", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Logistic regression Usages Amongst Population By Designation')

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_2", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Decision Trees or Random Forests Usages Amongst Population By Designation')

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_4", hue="Q5", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Bayesian Approaches Usages Amongst Population By Designation')

# %%
cols = [cols for cols in s.columns if 'Q18_Part' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ### Observation - Computer Vision
# 1. computer vision method : Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc) is more in use 4373 followed by
# 2. Object detection methods (YOLOv3, RetinaNet, etc)  & Image segmentation methods (U-Net, Mask R-CNN, etc) & General purpose image/video tools (PIL, cv2, skimage, etc) around 2.7K
# 3.

# %%
cols = [cols for cols in s.columns if 'Q19_Part' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# ### Observation
# Word embeddings/vectors (GLoVe, fastText, word2vec) is most popular followed by Transformer language models (GPT-3, BERT, XLnet, etc)

# %%
cols = [cols for cols in s.columns if 'Q20' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_4", hue="Q20", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Industry Usages Amongst Population By Designation')

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_8", hue="Q20", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('GAN Usages Amongst Population By Industry')

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_10", hue="Q20", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Transformer Networks (BERT, gpt-3) Usages Amongst Population By Industry')

# %%
cols = [cols for cols in s.columns if 'Q21' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_10", hue="Q21", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Transformer Networks (BERT, gpt-3) Usages Amongst Population By Industry')

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_8", hue="Q21", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('GAN Usages Amongst Population By Industry')

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_9", hue="Q21", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('RNN Usages Amongst Population By Designation')

# %%
cols = [cols for cols in s.columns if 'Q22' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q22", hue="Q21", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('Individuals are responsible for data science Vs Company Size')

# %%
fig = plt.figure(figsize=(20,30))
sns.catplot(y="Q21", hue="Q5", kind="count", palette="pastel", edgecolor=".5", data=s )
plt.title('Designation Vs Company Size')

# %%
cols = [cols for cols in s.columns if 'Q23' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
fig = plt.figure(figsize=(10,10))
sns.catplot(x="Q17_Part_9", hue="Q23", kind="count",palette="pastel", edgecolor=".8", data=s )
plt.title('RNN Usages Amongst Population By Designation')

# %%
cols = [cols for cols in s.columns if 'Q17_Part' in cols]
for f in cols:
    fig = plt.figure(figsize=(10,10))
    sns.catplot(x=f, hue="Q23", kind="count",palette="pastel", edgecolor=".8", data=s )
    plt.title('incorporate ML INTO business Vs ML Algo usage')

# %%
pd.crosstab(index= s['Q5'] , columns=s['Q23']).plot(kind="bar", figsize=(20,20),stacked=False)
plt.title('incorporate ML INTO business Vs Designation')

# %%
cols = [cols for cols in s.columns if 'Q24_Part' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
pd.crosstab(index= s['Q24_Part_6'] , columns=s['Q23']).plot(kind="bar", figsize=(20,20),stacked=False)
plt.title('incorporate ML INTO business Vs Designation')

# %%
cols = [cols for cols in s.columns if 'Q25' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %%
list_of_values = ['$500,000-999,999' ,'>$1,000,000' , '250,000-299,999' , '300,000-499,999' , '200,000-249,999' , '150,000-199,999']
chk = s[s['Q25'].isin (list_of_values)]

pd.crosstab(index= s['Q5'] , columns=chk['Q25']).plot(kind="bar", figsize=(20,20),stacked=False)
plt.title('incorporate ML INTO business Vs Designation')

# %% [markdown]
# ### Observations
# 1. Data Scientists are the ones with hieghest income bracket also software engineers are next
# 2. maximum population is in 150 to 200K bracket
# 3. DBA has max 150K to 200K bracket
# 4. Data Engineers with 18K max bracket
# 5. On an average Data Analyst are in higher salary bucket than data engineer (At least w.r.t kaggle users)

# %%
cols = [cols for cols in s.columns if 'Q26' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %% [markdown]
# ***Users are spending goodf amound of money on machine learning services***

# %%
cols = [cols for cols in s.columns if 'Q27' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %% [markdown]
# ### Observation
# 1. Most popular cloud platform is AWS with 3.7K followed by GCP 3.1K and then Azure 2.4K
# 2. In next 2 years projection shows AWS and Google are equally competing with 7K ratings followed by Azure

# %%
cols = [cols for cols in s.columns if 'Q28' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %% [markdown]
# *** Most familier and with best developer experience is with AWS and GCP followed by Azure . This is inline with answers for Q27 ***

# %%
cols = [cols for cols in s.columns if 'Q29' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %% [markdown]
# Google cloud compute engines seems to be more popular in next 2 years

# %%
cols = [cols for cols in s.columns if 'Q30' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %% [markdown]
# As AWS and GCP are mpre popular cloud services so their data storage product are leading the market as well.
# mazon Simple Storage Service (S3) and Google Cloud Storage (GCS) are most popular

# %%
cols = [cols for cols in s.columns if 'Q31' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %% [markdown]
# ### Observations
# 1. on machine learning products usage perspective , AWS and Azure are leading -  Amazon SageMaker & Azure ML engine
# 2. in next 2 years , more users are focusing on Google Cloud Vertex AI leaving behind Azure and AWS products

# %%
cols = [cols for cols in s.columns if 'Q32' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_index())

# %% [markdown]
# ### Observation
# 1. big data products (relational databases, data warehouses, data lakes, or similar) - > MySQl is more used followed by Postgrey sql .
# 2. 2 years later as well MySQl will be leading
# 3. In next 2 years it appears GCP will be more popular so it is possible that Postgrey will lead in big data as well . However GCP aslso support mysql which is also in line with outcome

# %%
cols = [cols for cols in s.columns if 'Q33' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q34' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# 1. Tableau & Power BI are at top at current
# 2. In next 2 years , Google data studio is surpassing both tablue and power BI . It is in line with popularity of GCP over other cloud platforms

# %%
cols = [cols for cols in s.columns if 'Q35' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q36' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# Automated ML pipeline and Automated Model selection followed by automated hyperparamater tuning will be future of automation.

# %%
cols = [cols for cols in s.columns if 'Q37' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q38' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q39' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q40' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q41' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %%
cols = [cols for cols in s.columns if 'Q42' in cols]
for c in cols:
    with pd.option_context('display.max_colwidth', None):
        display(survey[c].head(1))
    print(s[c].value_counts().sort_values())

# %% [markdown]
# Kaggle is most popular source for learning ML
