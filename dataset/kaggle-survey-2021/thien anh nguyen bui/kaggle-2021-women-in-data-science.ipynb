# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Kaggle 2021 - Women In Data Science

# %% [markdown]
# Hi everyone, <br/>
# I'm Thien Anh, a Data Analyst from Ho Chi Minh city, Vietnam. <br/> Today I bring you another **Data Storytelling:** **Women in Data Science** from **Kaggle Survey 2021** <br/> Enjoy! <br/> <br/> <u>Note</u>: <br/> I use Power BI to do data explorations

# %% [markdown]
# # 1. Overview

# %% [markdown]
# # 1.1. About Gender:

# %% [markdown]
# **Women** only have **18.83%**, while **Men** dominate with **79.31%** <br/> We see **a big gap** between **Men** and **Women**.

# %%
from IPython.display import Image

# %%
Image("../input/my-result/1_Gender_Percentage.jpg")

# %% [markdown]
# # 1.2. About Role

# %% [markdown]
# We see **Student Role** dominate most **(26.2%**), followed by **Data Scientist** Role **(13.92%)** and **Software Engineer (9.42%)**.

# %%
Image("../input/my-result/2_Role_Percentage.jpg")

# %% [markdown]
# Then, we will focus on **Women in Data Science**. <br/> **Data Science** includes ***Data Analyst, Data Engineer, and Data Scientist***.

# %% [markdown]
# # 2. Deep-dive: Women in Data Science

# %% [markdown]
# We continue to see a **big gap** between **Women** and **Men** in **Data Science**.

# %%
Image("../input/my-result/3_2_Women_vs_Men_DS.jpg")

# %% [markdown]
# **Women in Data Science:**

# %%
Image("../input/my-result/4_1_Women_Role_DS.jpg")

# %% [markdown]
# And we see Women who work as **Data Scientist** dominate most **(49.2%)**, followed by Women who work as **Data Analyst (42.54%)**. Women who work as **Data Engineer** are fewest with **8.26%**.

# %%
Image("../input/my-result/4_2_Women_DS_Role_Percentage.jpg")

# %% [markdown]
# # 3. Women In Data Science: Age Group

# %% [markdown]
# We are happy to see there are **Women in Data Science** who are in the **[25-29] Age Group** dominate most **(26.28%)**, followed by Women who are in the **[22-24] Age Group** **(19.12%**).

# %%
Image("../input/my-result/5_1_Women_DS_Age.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/5_2_Women_DS_Percentage_Age.jpg")

# %% [markdown]
# # 4. Women In Data Science: Country

# %% [markdown]
# **Women in Data Science** that come from **India** dominate most **(25.44%)**, followed by Women come from the **United States of America (14.57%)**.

# %%
Image("../input/my-result/6_1_Women_DS_Country.jpg")

# %%
Image("../input/my-result/6_2_Women_DS_Country.jpg")

# %%
Image("../input/my-result/6_3_Women_DS_Country.jpg")

# %%
Image("../input/my-result/6_4_Women_DS_Country.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/7_1_Women_DS_Country_Percentage.jpg")

# %%
Image("../input/my-result/7_2_Women_DS_Country_Percentage.jpg")

# %%
Image("../input/my-result/7_3_Women_DS_Country_Percentage.jpg")

# %%
Image("../input/my-result/7_4_Women_DS_Country_Percentage.jpg")

# %%
Image("../input/my-result/7_5_Women_DS_Country_Percentage.jpg")

# %% [markdown]
# # 5. Women in Data Science: Highest Level of Education

# %% [markdown]
# We are happy to see there are **Women in Data Science** who have **Master's degree** dominate most **(49.45%)**, followed by Women who have **Bachelor's degree (30.33%)**, and Women who have **Doctoral degree (12.22%)**.

# %%
Image("../input/my-result/8_Women_DS_Highest_Edu.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/9_Women_DS_Percentage_Highest_Edu.jpg")

# %% [markdown]
# # 6. Women in Data Science: Years of Programming

# %% [markdown]
# We are happy to see there are **Women in Data Science** that have **[1-3] years of programming** dominate most **(29.23%)**, followed by Women who have **under [1] year of programming (24.68%)**, and Women who have **[3-5] years of programming (15.75%)**.

# %%
Image("../input/my-result/10_Women_DS_Years_Programming.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/11_Women_DS_Percentage_Yrs_Programming.jpg")

# %% [markdown]
# # 7. Women in Data Science: Recommended Language to Learn First

# %% [markdown]
# We see that **Python** is the **most recommended language to learn first (71.69%)**, followed by **SQL (9.86%)**, and **R (8.51%)**. <br/> <br/> This is easy to understand because **Python** is the easy and flexible language for both **Data Science** and Software Development.

# %%
Image("../input/my-result/12_1_Recommended_Lang.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/12_2_Percentage_Recommend_Lang.jpg")

# %% [markdown]
# # 8. Women in Data Science: Most Often Used Computing Platform

# %% [markdown]
# We see there are **Women in Data Scienc**e that use **a Laptop** dominate most **(63.1%)**, followed by Women who use **Personal Computer / Desktop (16.6%)**, and Women who use **Cloud Computing Platform (AWS, Azure, GCP) (11.46%)**.

# %% [markdown]
# This is easy to understand because the Hardware Price now is affordable for buying and using hardware products such as PC and Laptop.

# %% [markdown]
# **For Cloud Platform providers:** You need to have *more afforable pricing campaigns* for **Women in Data Science** to easy access your Cloud Computing Platform.

# %%
Image("../input/my-result/13_1_Most_Used_Comp_Platform.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/13_2_Percentage_Most_Used_Comp_Platform.jpg")

# %% [markdown]
# # 9. Women in Data Science: TPU Using Time

# %% [markdown]
# We see there are **Women in Data Science** that **NEVER use TPU** dominate most **(64.45%)**, followed by Women who use TPU **[2-5] times (13.98%)** , and Women who use TPU ONCE **[11.79%]**.

# %% [markdown]
# **For Cloud Computing Platform Providers:** You should open a survey about TPU usage to **get feedback to improve** *TPU using experiences*.

# %%
Image("../input/my-result/14_1_TPU_Using_Time.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/14_2_Percentage_TPU_Using_Time.jpg")

# %% [markdown]
# # 10. Women in Data Science: Years to Use ML Method

# %% [markdown]
# We see there are **Women in Data Science** that have **UNDER 1 year** to use Machine Learning (ML) Method **(32.43%)**, followed by Women who have **[1-2] years (19.04%)**.

# %%
Image("../input/my-result/15_Year_Use_ML_Method.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/16_Percentage_Year_Use_ML_Method.jpg")

# %% [markdown]
# # 11. Women in Data Science: Current Employer or Contract

# %% [markdown]
# We are happy to see there are **Women in Data Science** that work in **Computer/Technologies** dominate most **(23.08%)**, followed by Women who work in **Academics/Education (17.69%)** and Women who work in **Accounting/Finance (10.11%)**.

# %%
Image("../input/my-result/17_1_Current_Employer.jpg")

# %%
Image("../input/my-result/17_2.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/18_1_Percentage_Current_Employer.jpg")

# %%
Image("../input/my-result/18_2.jpg")

# %% [markdown]
# # 12. Women in Data Science: Company Size

# %% [markdown]
# We see there are **Women in Data Science** work at **Small Enterprises** **[0-49] employees** dominate most **(32.6%)**, followed by Women who work at **Large Enterprises** **[10,000 or more] employees (19.55%)**, and Women who work at **Medium Enterprises [1,000 - 9,999] employees (16.26%)**.

# %%
Image("../input/my-result/19_Company_Size.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/20_Percentage_Company_Size.jpg")

# %% [markdown]
# # 13. Women in Data Science: Individuals for DS Workload

# %% [markdown]
# We see there **Women in Data Science** that have **[1-2] people** for Data Science (DS) workload dominate most **(19.88%)**, followed by Women who have **[20 or more] people** **(19.38%)**, and Women who have **[3-4] people (17.02%)**.

# %%
Image("../input/my-result/21_1_Individual_DS_Workload.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/21_2_Percentage_Individual_DS_Workload.jpg")

# %% [markdown]
# # 14. Women in Data Science: Current Employer incorporate ML Methods into Business

# %% [markdown]
# We see there are **Women in Data Science** that say **"We are exploring ML Methods"** dominate most **(18.11%)**, followed by Women that say **"We have well established ML methods" (16.51%)**.

# %%
Image("../input/my-result/22_1_Women_Employer_Incorporate_ML_Method.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/22_2_Percentage_of_Women_Employer_Incorporate_ML.jpg")

# %% [markdown]
# # 15. Women in Data Science: Current Yearly Compensation (in USD)

# %% [markdown]
# We see there are **Women in Data Science** who received **[0-999] USD of yearly compensation** dominate most **(27.63%)**, followed by Women who received **[1,000 - 1,999] USD (6.23%)**, and Women who received **[10,000 - 14,999] USD (4.72%)**.

# %%
Image("../input/my-result/23_1_Women_Current_Yearly_Compensation.jpg")

# %%
Image("../input/my-result/23_2.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result-4/23_3_Percentage_Yearly_Compensation.jpg")

# %%
Image("../input/my-result-4/23_4.jpg")

# %% [markdown]
# # 16. Women in Data Science: Money Spent On Machine Learning

# %% [markdown]
# We see there are **Women in Data Science** that **don't spend** **for Machine Learning** **[0] USD** dominate most **(32.6%)**, followed by Women who spent **[100 - 999] USD (15.16%**), and Women who spent **[1000 - 9999] USD (13.73%**).

# %%
Image("../input/my-result-5/29_1_ML_Spending.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result-5/29_2_Percentage_ML_Spending.jpg")

# %% [markdown]
# # 17. Women in Data Science: Most Used Enjoyable Cloud Platform

# %% [markdown]
# We see there are **Amazone Web Services (AWS), Google Cloud Platform (GCP), and Microsoft Azure** are the Top Most Favorite Cloud Platform.

# %%
Image("../input/my-result/24_1_Women_Most_Enjoyable_Cloud_Platform.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/24_2_Percentage_Most_Enjoyable_Cloud_Platform.jpg")

# %% [markdown]
# # 18. Women in Data Science: Most Often Used Big Data Product

# %% [markdown]
# We see there are **MySQL, Microsoft SQL Server, and PostgreSQL** are the Top Most Often Used Big Data Product

# %%
Image("../input/my-result/25_1_Big_Data_Product.jpg")

# %%
Image("../input/my-result/25_2.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/26_Percentage_Big_Data_Product.jpg")

# %%
Image("../input/my-result/26_2.jpg")

# %% [markdown]
# # 19. Women in Data Science: Most Often Used BI Tool

# %% [markdown]
# We see there are **Microsoft Power BI and Tableau** are the Top Most Often Used BI Tool.

# %%
Image("../input/my-result/27_1_BI_Tool.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/27_2_Percentage_of_BI_tool.jpg")

# %% [markdown]
# # 20. Women in Data Science: Primary Data Analytical Tool

# %% [markdown]
# We see there are **Women in Data Science** that use **Local Development Environments (RStudio, JupyterLab, etc.)** dominate most **(29.06%)**, followed by **Women** who use **Basic Statistical Software (Microsoft Excel, Google Sheets, etc.) with (21.23%)**. Women who use **Cloud based Data Software & APIs (AWS, GCP, Azure)** are fewer with **(3.12%)**.

# %%
Image("../input/my-result/28_1_Primary_Data_Analytical_Tool.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-result/28_2_Percentage_of_Primary_Data_Analytical_Tool.jpg")

# %% [markdown]
# # 21. Conclusion & Recommendation

# %% [markdown]
# Although there is a **big gap** between **Women and Men in Data Science**, we see Women still have ***good level of education*** as well as ***good data science experiences***, such as: 49.45% Women have Master's degree, 29.23% Women have '1-3' years of programming, 35.81% Women work in Medium and Large Enterprises, 32.43% Women have about 1 year using ML methods ... <br/><br/> To erase the gap, I have some suggestions

# %% [markdown]
# **For Educators:** You can cooperate with Senior Women in Data Science to create more Data Science Classes for Female Students to learn about Data Science, as well as encourage them to apply for Data Science roles.

# %% [markdown]
# **For Cloud Platform Providers:** You can create more campaigns that offer more affordable prices to reach more **Women users** in *Data Science Roles*, for them to easily access your Cloud Computing Platform.

# %% [markdown]
# THANK'S FOR READING MY WORK!
