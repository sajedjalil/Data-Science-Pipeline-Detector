# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Kaggle 2021 - Women - Data Storytelling (No lines of Code)

# %% [markdown]
# Hi, I'm Thien Anh from Ho Chi Minh city, Vietnam. <br/> Today, I bring you <b>Women in Tech Storytelling</b> from Kaggle 2021 Survey. <br/> Enjoy the story! <br/><br/> <u>Note</u>: <br/> I use Power BI Desktop to do the Data Explorations.

# %% [markdown]
# # 1. Quick Overview

# %% [markdown]
# <b><u>About the Gender</u>:</b> <br/> <br/> <b>Women</b> only have <b>18.83%</b>, while Men dominate with 79.31%. <br/> We see there is a <b>big gap</b> between Men and Women.

# %%
from IPython.display import Image

# %%
Image("../input/my-results/1_Gender_Percentage.jpg")

# %% [markdown]
# <br/> <b><u>About the Roles</u>:</b> <br/><br/> <b>Student Role</b> dominates most <b>(26.2%)</b>, followed by <b>Data Scientist Role (13.92%)</b>.

# %%
Image("../input/my-results/2_Role_Percentage.jpg")

# %% [markdown]
# # 2.Deep-dive: Women Role

# %% [markdown]
# We have Women Role numbers of percantage as below:

# %%
Image("../input/my-results/3_Woman_Role_Percentage.jpg")

# %% [markdown]
# Women in the Student Role dominate most (32.19%), follow by Data Scientist (11.94%), and Data Analyst (10.93%)

# %% [markdown]
# And

# %%
Image("../input/my-results/4_Women_Role_2.jpg")

# %% [markdown]
# # 3. Women Ages:

# %% [markdown]
# Women in the age group [18-21] dominate most. <br/> We see there is a <b>big number</b> of <b>young women</b> in the Tech.

# %%
Image("../input/my-results/5_Women_Age_1.jpg")

# %%
Image("../input/my-results/5_Women_Age_2.jpg")

# %% [markdown]
# <br/>

# %% [markdown]
# # 4. Women's Country

# %% [markdown]
# There is a big number of **Women** that come from **India (33.87%)**, followed by Women come from **the United States of America (12.39%)**

# %%
Image("../input/my-results/6_Women_Country.jpg")

# %%
Image("../input/my-results-2/Q3_Country.jpg")

# %% [markdown]
# # 5. Women's highest level of Education

# %% [markdown]
# We see there is a big number of **Women** that have the **Master's degree (39.88%)**, followed by **Women** who have **Bachelor's degree (37.69%)**.

# %%
Image("../input/my-results/7_Women_highest_edu.jpg")

# %%
Image("../input/my-results-2/Q4_Women_Highest_Edu.jpg")

# %% [markdown]
# # 6. Women's Years of Programming

# %% [markdown]
# We see **Women** that have **[1-3] years of programming** dominate most **(32%)**, follow by **Women** who have ***under*** 1 year of programming **(29%)**, and Women who have **[3-5] years (14.72%)**. <br/> <br/> This is *easy to understand*, because we have a *big numbe*r of **newbie women in Tech**.

# %%
Image("../input/my-results/8_Women_Years_of_Programming.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q6_Women_Years_Programming.jpg")

# %% [markdown]
# # 7. Women's Recommended Language to Learn First

# %% [markdown]
# **Python (73.01%)** is still the Recommended Language that Women choose to **learn first**, followed by **SQL (6.56%)**, and **R (6.44%)**. <br/> This is easy to understand because Python is flexible and easy to use for Data Science and Software Development.

# %%
Image("../input/my-results/9_Womens Recommended_Lang.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q8_Women_Recommended_Lang.jpg")

# %% [markdown]
# # 8. Women's Most Used Computing Platform

# %% [markdown]
# We see **Women** use a **Laptop (68.45%)** as Computing Platform, follow by Women choose to use **PC or Desktop (14.56%)**, and Women use a **Cloud Computing platform (6.95%)** like Amazon, Azure ... <br/> <br/> This is easy to understand, because the Hardware products now are affordable and easy to access. <br/> <br/> **For the Cloud providers:** You need to have marketing campaigns to approach more women users like women startup founders, to spread more about your Cloud Computing platform.

# %%
Image("../input/my-results/10_Women_Most_Used_Computing_Platform.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q11_Women_Most_Used_Computing_Platform.jpg")

# %% [markdown]
# # 9. Women's TPU Using Time

# %% [markdown]
# We see **Women** with the Answer choice **'Never'** dominate most **(67.34%)**, follow by Women that have the Answer **'Once' (10.63%)**, and **'2-5 times' (10.12%)**.

# %%
Image("../input/my-results/11_Women_Times_To_Use_A_TPU.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q13_Women_TPU_Using_Time.jpg")

# %% [markdown]
# # 10. Women's Years of Using ML Methods

# %% [markdown]
# We see **Women** who have **under 1 year** of using **ML method** dominate most **(38.61%)**, followed by Women who **don't use** **ML method (18.24%)**, **'1-2 years' (15.4%)**, and **'2-3 years' (6.79%**). <br/> <br/> This is easy to understand because we have a big number of newbie women in Tech.

# %%
Image("../input/my-results/12_Women_Years_to_use_ML_Method.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q15_Women_ML_Using_Year.jpg")

# %% [markdown]
# # 11. Women's Current Employer or Contract

# %% [markdown]
# Among those *Women who answer the question*, we see **Women** who work in **Academics/Education** dominate most **(13.87%)**, followed by **Women** who work in **Computers/Technologies (13.23%)**, and **Women** who work in **Accounting/Finance (4.42%)**.

# %%
Image("../input/my-results/13_1_Women_Current_Employers_Contracts.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q20_Women_Employer.jpg")

# %%
Image("../input/my-results-2/Q20_2.jpg")

# %% [markdown]
# # 12. Women's Company Size

# %% [markdown]
# Among those *Women who answer the question*, we see **Women** who work in a **Small Company size '0-49 employees'** dominate most **(17.2%)**, followed by **Women** who work in a **Big Enterprise '10,000 or more employees' (11%)**, and **Women** who work in a **Medium Company size '1000 - 9,999 employees' (9.73%)**.

# %%
Image("../input/my-results/14_Women_Company_Size.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q21_Women_Company_Size.jpg")

# %% [markdown]
# # 13. Women's Individuals for Data Science workload

# %% [markdown]
# Among those *Women who answer the question*, we see **Women** who have **20 or more Individuals** for Data Science workload dominate most **(11.6%**), follow by **Women** who **don't have any Individual or have only 1 Individual** **(10.94%)**.

# %%
Image("../input/my-results/15_People_for_DS_workload.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q22_Women_Individual_for_DS_workload.jpg")

# %% [markdown]
# # 14. Women's Current Employer Incorporate ML Method

# %% [markdown]
# Among those *Women who answer the question*, we see **Women** who say **'No'** for Incorporate ML Method into Business dominate most **(11.92%)**, followed by **Women** who say **'Don't know' (11.76%)**. Only some **Women** say **'We are exploring ML method' (10.22%)**, and a small number of **Women** who say **'We have well established ML method' (7.42%)**.

# %%
Image("../input/my-results/16_Current_Employer_Incorporate_ML.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q23_Women_Current_Employer_Incorporate_ML.jpg")

# %% [markdown]
# # 15. Women's Current Yearly Compensation

# %% [markdown]
# Among those *Women who answer the question*, we see **Women** who have **'0-999 USD' Yearly Compensation** dominate most **(15.85%)**, followed by a *small number* of **Women** who have **'1,000 - 1,999 USD' (3.54%)**, and **Women** who have **'10,000 - 14,999 USD' (2.68%)**.

# %%
Image("../input/my-results/17_1_Women_Yearly_Compensation.jpg")

# %%
Image("../input/my-results/17_2.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q25_Women_Yearly_Compensation.jpg")

# %%
Image("../input/my-results-2/Q25_2.jpg")

# %% [markdown]
# # 16. Women's Spending Money on Machine Learning

# %% [markdown]
# Among those *Women who answer the question*, we see there are only **7.53% Women spent 100 - 999 USD**, and only **7.12% Women spent 1000 - 9,999 USD** on Machine Learning.

# %%
Image("../input/my-results/18_Money_Spent_for_ML.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q26_Money_Spent_on_ML.jpg")

# %% [markdown]
# # 17. Women's Most Enjoyable Cloud Platform

# %% [markdown]
# Among those *Women who answer the question*, we see there are **Amazon Web Services (AWS), Google Cloud, and Microsoft Azure** Top selected as Women's Most Enjoyable Cloud Platform.

# %%
Image("../input/my-results/19_Favorite_Cloud_Platform.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q28_Cloud_Platform.jpg")

# %% [markdown]
# # 18. Women's Most Often Used Big Data Product

# %% [markdown]
# Among *those Women who answer the question*, we see there are **MySQL, Microsoft SQL Server, PostgreSQL, and Oracle Database** Top selected as Women's Most Often Used Big Data Product.

# %%
Image("../input/my-results/20_Most_used_BigData_Tool.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q33_1_Big_Data_Product.jpg")

# %%
Image("../input/my-results-2/Q33_2.jpg")

# %% [markdown]
# # 19. Women's Most Often Used BI Tool

# %% [markdown]
# Among *those Women who answer the question*, we see there are **Tableau and Microsoft Power BI** dominate the ranking table as Top selected of Women's Most Often Used BI Tool.

# %%
Image("../input/my-results/21_Women_Most_Used_BI_Tool.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-3/Q35_BI_Tool.jpg")

# %% [markdown]
# # 20. Women's Primary Data Analytical Tool

# %% [markdown]
# Among *those Women who answer the question*, we see there are **Women** who use **Basic statistical software (like Microsoft Excel, Google Sheet)** dominate most, followed by **Women** who use **Local development environments (like RStudio, JupyterLab**). There is only a *small number* of **Women** who use Cloud-based Data software & API (AWS, GCP, Azure).

# %%
Image("../input/my-results/22_Women_Primary_Analytical_Tool.jpg")

# %% [markdown]
# And

# %%
Image("../input/my-results-2/Q41_Analytical_Tool.jpg")

# %% [markdown]
# # 21. Conclusion & Recommendation

# %% [markdown]
# Although there is a **big gap** between **Women** and **Men in Tech**, we see **Women** still have *good level of education* as well as *good programming experiences*. To erase the gap, I have some recommendations:

# %% [markdown]
# * **For Recruiters:** You can recruit more Women in Tech by taking advantage of their programming experiences and good level of education. (39.88% Women have Master's degree + 37.69% Women have Bachelor degree, and 32% Women have '1-3 years' of programming).

# %% [markdown]
# * **For Cloud Platform and Software Providers:** You can create more marketing campaigns to approach more Women, as well as offer more affordable prices for Women to access cloud computing platform.

# %% [markdown]
# THANK YOU FOR READING MY WORK
