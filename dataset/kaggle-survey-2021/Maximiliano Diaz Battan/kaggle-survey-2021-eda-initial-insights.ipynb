# %% [markdown]
# <div style="color:White; display:fill; border-radius:10px;background-color:#000000;font-size:300%;font-family:sans-serif;letter-spacing:0.5px;text-align: center">
# Kaggle Data Science Survey 2021
# </div>

# %% [markdown]
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#000000;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%"> - | Table of Contents</div>
#
# * [Introduction](#section-one)
# * [Data loading](#section-two)
# * [Questions:](#section-three)
#     * [Q1 - What is the age of Kaggle users?](#subsection-three-one)
#     * [Q2 - What is the gender of Kaggle users?](#subsection-three-two)
#     * [Q3 - Where is everyone from?](#subsection-three-three)
#     * [Q4 - Highest level of education achieve by Kagglers?](#subsection-three-four)
#     * [Q5 - Current role or position of the Kagglers?](#subsection-three-five)
#     * [Q6 - Coding experience?](#subsection-three-six)
#     * [Q7 - What is the most popular programming language?](#subsection-three-seven)
#     * [Q8 - Most recommended programming language?](#subsection-three-eight)
#     * [Q9 - Most popular IDE's?](#subsection-three-nine)
#     * [Q10 - Kaggle notebooks vs the competition?](#subsection-three-ten)
#     * [Q11 - Most popular visualization tools?](#subsection-three-eleven)
#     * [Q12 -  Most popular Machine Learning Frameworks?](#subsection-three-twelve)
#     * [Q13 - Most popular Machine Learning Algorithms?](#subsection-three-thirteen)
#     * [Q14 - Sectors where kagglers work?](#subsection-three-fourteen)
#     * [Q15 - The advancement of data in the workplace](#subsection-three-fifteen)

# %% [markdown]
# <a id="section-one"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#000000;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%"> 1 | Introduction</div>
#
#
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em; margin-left:20px">
# Throughout this notebook I will try to answer some questions about the kaggle survey and draw some conclusions, I hope you like it.
# <br><br>

# %% [markdown]
# <a id="section-two"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#000000;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%"> 2 | Data loading</div>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import plotly.offline as offline
import plotly.graph_objs as go
offline.init_notebook_mode(connected = True)

# %%
df = pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv', low_memory=False)

# %%
df_questions = df.iloc[0,:].reset_index().rename(columns={'index': 'Question #', 0:'Question'})[1:]
df_questions.head()

# %%
df_data = df.iloc[1:,:]
df_data.head()

# %% [markdown]
# <a id="section-three"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#000000;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%"> 3 | Questions</div>
#
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.1 | Q1 - What is the age of Kaggle users?</div>

# %%
ages = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q1'}}).reset_index().rename(columns={'index':'Age_Bin','Q1':'Users'})

# %%
age_hist = px.histogram(ages, y= ages.Users, x = ages.Age_Bin, title='Kaggle users Age', color=ages.Age_Bin)
age_hist.update_xaxes(showgrid=False)
age_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
age_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40), showlegend=False,
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93') )

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; Here, we can clearly see that majority of Kagglers are young people between 18 to 29 years of age, and also the 78% of the users are below 40 years old.
# </div>

# %% [markdown]
# <a id="subsection-three-two"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.2 | Q2 - What is the gender of Kaggle users?</div>

# %%
gender = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q2'}}).reset_index().rename(columns={'index':'Gender', 'Q2':'Users'})

# %%
donut_gender = px.pie(gender, names=gender.Gender, values=gender.Users, width=800, height=400, hole=0.7, title='Gender of Kagglers',color=gender.Gender)
donut_gender.update_traces(hovertemplate=None, textposition='outside', textinfo='percent+label', rotation=45)
donut_gender.update_layout(margin=dict(t=60, b=30, l=0, r=0), showlegend=False,
                    title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                    font=dict(size=17, color='#8a8d93'),
                    hoverlabel=dict(bgcolor="#444", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; The mayority of the kagglers are man, I hope to see more women and all the other genders in the future. Despite the fact that women are a minority, their work is quite remarkable, you can see it in a daily basis.
# </div>

# %% [markdown]
# <a id="subsection-three-three"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.3 | Q3 - Where is everyone from?</div>

# %%
countries = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q3'}}).reset_index().rename(columns={'index':'Countries', 'Q3':'Users'})

# %%
fun_countries = px.funnel(countries[:10], x='Users', y='Countries',
                #title='Top 10 Popular countries in Kaggle',
                color='Countries',
                width=800, height=400)
fun_countries.update_yaxes(categoryorder='total descending')
fun_countries.update_traces(textposition='auto', textfont=dict(color='#fff'))
fun_countries.update_layout(title={'text': "Top 10 Popular countries in Kaggle",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                            margin=dict(t=110, b=50, l=70, r=40),
                            xaxis_title=' ', yaxis_title=" ",
                            showlegend=False,
                            title_font=dict(size=25, color='#a5a7ab',family="Lato, sans-serif"),
                            font=dict(color='#8a8d93'))

# %%
px.choropleth (data_frame= countries, locations = 'Countries', locationmode = 'country names', color = 'Users', scope = 'world' )

# %% [markdown]
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em; margin-left:20px">
# <b> What about the Kagglers from South America? (My region) </b>  </p>

# %%
country = ['Argentina', 'Brazil', 'Bolivia', 'Colombia','Chile','Ecuador', 'Peru', 'Paraguay','Uruguay','Venezuela']
df_la_kagglers = countries[countries['Countries'].isin(country)]
df_la_kagglers['% of Total Kagglers'] = ((df_la_kagglers['Users'] / countries['Users'].sum()) * 100).round(2)
colors = {'Argentina': 'lightblue','Brazil':'greenyellow','Colombia': 'yellow','Peru':'orangered','Chile':'red', 'Ecuador':'limegreen'}
df_la_kagglers['color'] = df_la_kagglers['Countries'].map(colors)

fig = make_subplots(rows=1, cols=2, 
                    specs=[[{"type": "bar"}, {"type": "pie"}]],
                    column_widths=[0.5, 0.5], vertical_spacing=0, horizontal_spacing=0.02,
                    subplot_titles=("Top 5 Countries by Users in SA", "Percentage of Total Kagglers"))

fig.add_trace(go.Bar(x=df_la_kagglers['Users'], y=df_la_kagglers['Countries'][:5], marker=dict(color=df_la_kagglers['color']),
                     name='# Kagglers', orientation='h', text=df_la_kagglers['Users']), 
                     row=1, col=1)

fig.add_trace(go.Pie(values=df_la_kagglers['% of Total Kagglers'], labels=df_la_kagglers['Countries'][:5], name='% Kagglers',
                     marker=dict(colors=['greenyellow','yellow','lightblue','orangered','red']), hole=0.7,
                     hoverinfo='label', text=df_la_kagglers['% of Total Kagglers'], textinfo='label'), 
                    row=1, col=2)

fig.update_yaxes(showgrid=False, ticksuffix=' ', categoryorder='total ascending', row=1, col=1)
fig.update_yaxes(showgrid=False, ticksuffix=' ', categoryorder='total ascending', row=1, col=2)
fig.update_traces(texttemplate='%{text}', textposition='inside', row=1, col=1)
fig.update_traces(texttemplate='%{text}', textposition='inside', row=1, col=2)
fig.update_xaxes(visible=False, row=1, col=1)
fig.update_xaxes(visible=False, row=1, col=2)
fig.update_layout(#title={'text': "Kagglers users comparassion South America vs the World",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                  template="plotly_white",
                  title_font=dict(size=29, color='#8a8d93', family="Lato, sans-serif"),
                  font=dict(color='#8a8d93'), 
                  hoverlabel=dict(bgcolor="#f2f2f2", font_size=13, font_family="Lato, sans-serif"),
                  showlegend=False)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; We can see how Kaggle it's present in all the continents, Asia it's were more Kagglers from, with India ahead. Also in Latin America Brazil it's where the mayority of the kagglers from, and my country (Argentina), it's in the thrid place. But since we can see that they represent a tiny part of the total kagglers, there is a lot of room for growth.
# </div>

# %% [markdown]
# <a id="subsection-three-four"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.4 | Q4 - Highest level of education achieve by Kagglers?</div>

# %%
educ = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q4'}}).reset_index().rename(columns={'index':'Education_Level','Q4':'Users'})

# %%
educ_bar = px.bar(educ, x='Education_Level', y='Users',
             title='Education level of Kagglers',text='Users',
             color='Education_Level')
educ_bar.update_yaxes(visible=False, categoryorder='total ascending')
educ_bar.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
educ_bar.update_layout(margin=dict(t=80, b=50, l=70, r=40),
                  xaxis_title=' ', yaxis_title=" ",
                  showlegend=False,
                  title_font=dict(size=25, color='#a5a7ab',
                                  family="Lato, sans-serif"),
                  font=dict(color='#8a8d93'))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; Here, we can see how Kaggle users are highly educated, the majority of them have a master o bachelor degree.
# </div>

# %% [markdown]
# <a id="subsection-three-five"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.5 | Q5 - Current role or position of the Kagglers?</div>

# %%
pos = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q5'}}).reset_index().rename(columns={'index':'Position','Q5':'Users'})

# %%
pos_hist = px.histogram(pos, y= pos.Position, x = pos.Users, title='Current position', color=pos.Position)
pos_hist.update_xaxes(showgrid=False)
pos_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
pos_hist.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
pos_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       showlegend=False,
                       xaxis_title=' ', yaxis_title=" ",
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp;This was a great surprise for me, because I've tought the majority of kagglers were gonna be Data Scientists, Analyst or ML engineers, but no, are students. I think this   make sense because the data science it's a new carrer and Kaggle it's a great place to start learning about this topic.
# </div>

# %% [markdown]
# <a id="subsection-three-six"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.6 | Q6 - Coding experience?</div>

# %%
yrs_code = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q6'}}).reset_index().rename(columns={'index':'Years_Coding', 'Q6':'Users'})

# %%
yrs_bar = px.bar(yrs_code, x='Years_Coding', y='Users',
             title='Coding experience of Kagglers',text='Users',
             color='Years_Coding')
yrs_bar.update_yaxes(visible=False, categoryorder='total ascending')
yrs_bar.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
yrs_bar.update_layout(margin=dict(t=80, b=50, l=70, r=40),
                  xaxis_title=' ', yaxis_title=" ",
                  showlegend=False,
                  title_font=dict(size=25, color='#a5a7ab',
                                  family="Lato, sans-serif"),
                  font=dict(color='#8a8d93'))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; Given that most of the users are students, it makes sense that the code experience of most of them is less than 3 years.
# </div>

# %% [markdown]
# <a id="subsection-three-seven"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.7 | Q7 - What is the most popular programming language?</div>

# %%
lang = pd.DataFrame({c : df_data[c].value_counts() for c in df_data.columns if c.startswith('Q7')}).sum(axis=1).reset_index().rename(columns={'index':'Language',0:'Users'})

# %%
lang_hist = px.histogram(lang, y= lang.Language, x = lang.Users, title='Most popular programming languages', color=lang.Language)
lang_hist.update_xaxes(showgrid=False)
lang_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
lang_hist.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
lang_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       showlegend=False,
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; Python and SQL are the most popular programming languages among Kaggle users, make sense because this 2 languages are quite popular in the data field.
# </div>

# %% [markdown]
# <a id="subsection-three-eight"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.8 | Q8 - Most recommended programming language?</div>

# %%
rec_lang = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q8'}}).reset_index().rename(columns={'index':'Language','Q8':'Users'})

# %%
rec_lang_hist = px.histogram(rec_lang, y= rec_lang.Language, x = rec_lang.Users, title='Most recommended programing languages', color=rec_lang.Language)
rec_lang_hist.update_xaxes(showgrid=False)
rec_lang_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
rec_lang_hist.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
rec_lang_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       showlegend=False,
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; By far python it's the most recommended language from the kagglers, it make sense it's easy to read, undestood,  and code with him. And also there is alot of Machine Learning frameworks base on that language.
# </div>

# %% [markdown]
# <a id="subsection-three-nine"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.9 | Q9 - Most popular IDE's?</div>

# %%
ides = pd.DataFrame({c : df_data[c].value_counts() for c in df_data.columns if c.startswith('Q9')}).sum(axis=1).reset_index().rename(columns={'index':'IDE', 0:'Users'})

# %%
ides_hist = px.histogram(ides, y= ides.IDE, x = ides.Users, title='Most popular IDE', color=ides.IDE)
ides_hist.update_xaxes(showgrid=False)
ides_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
ides_hist.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
ides_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       showlegend=False,
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; Jupyter Notebook is the most common used IDE, make sense because it's very user friendly, and also almost everybody starts with this IDE.
# </div>

# %% [markdown]
# <a id="subsection-three-ten"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.10 | Q10 - Kaggle notebooks vs the competition?</div>

# %%
note = pd.DataFrame({c : df_data[c].value_counts() for c in df_data.columns if c.startswith('Q10')}).sum(axis=1).reset_index().rename(columns={'index':'Platform', 0:'Users'})

# %%
note_bar = px.bar(note.sort_values(by='Users', ascending=False), x='Platform', y='Users',
             title='Kaggle notebooks vs the competition',text='Users',
             color='Platform')
note_bar.update_yaxes(visible=False)
note_bar.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
note_bar.update_layout(margin=dict(t=80, b=50, l=70, r=40),
                  xaxis_title=' ', yaxis_title=" ",
                  showlegend=False,
                  title_font=dict(size=25, color='#a5a7ab',
                                  family="Lato, sans-serif"),
                  font=dict(color='#8a8d93'))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
# 📌 &nbsp; By far, Colab and Kaggle are the most used platforms, in my opinion it makes sense because they are very easy to use, and also give the user the possibility of free access to a GPU and TPU.
# </div>

# %% [markdown]
# <a id="subsection-three-eleven"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.11 | Q11 - Most popular visualization tools?</div>

# %%
viz_libs = pd.DataFrame({c : df_data[c].value_counts() for c in df_data.columns if c.startswith('Q14')}).sum(axis=1).reset_index().rename(columns={'index':'Libraries', 0:'Users'})

# %%
ides_hist = px.histogram(viz_libs, y= viz_libs.Libraries, x = viz_libs.Users, title='Most popular Visualization Libraries', color=viz_libs.Libraries)
ides_hist.update_xaxes(showgrid=False)
ides_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
ides_hist.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
ides_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       showlegend=False,
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
# 📌 &nbsp; Matplotlib, Seaborn and Plotly are the most popular choices among many Kagglers. They are so user friendly, I think thats the reason for his popularity.
# </div>

# %% [markdown]
# <a id="subsection-three-twelve"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.12 | Q12 -  Most popular Machine Learning Frameworks?</div>

# %%
frames = pd.DataFrame({c : df_data[c].value_counts() for c in df_data.columns if c.startswith('Q16')}).sum(axis=1).reset_index().rename(columns={'index':'Frameworks', 0:'Users'})

# %%
frames_hist = px.histogram(frames, y= frames.Frameworks, x = frames.Users, title='Most popular ML Frameworks', color=frames.Frameworks)
frames_hist.update_xaxes(showgrid=False)
frames_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
frames_hist.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
frames_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       showlegend=False,
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#  📌 &nbsp; Sklearn and tensorflow are the most popular frameworks, they make sense because they are the 2 most robust packages that exist and have been there for many years. Pytorch is another very good framework, I hope to see it continue to grow as time goes by.
# </div>

# %% [markdown]
# <a id="subsection-three-thirteen"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.13 | Q13 - Most popular Machine Learning Algorithms?</div>

# %%
algos = pd.DataFrame({c : df_data[c].value_counts() for c in df_data.columns if c.startswith('Q17')}).sum(axis=1).reset_index().rename(columns={'index':'Algorithms', 0:'Users'})

# %%
algos_hist = px.histogram(algos, y= algos.Algorithms, x = algos.Users, title='Most popular ML Algorithms', color=algos.Algorithms)
algos_hist.update_xaxes(showgrid=False)
algos_hist.update_yaxes(showgrid=False, categoryorder='total ascending', ticksuffix=' ', showline=False)
algos_hist.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
algos_hist.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       showlegend=False,
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
# 📌 &nbsp; We can clearly see that Linear, Tree and Boosting models are the most widely preferred Algorithms here on Kaggle. The popularity of linear and tree based models make sense because usualy are the models who someone new to ML start to learn about this topic. The boosting algorithms are quite popular because the competitions I guess, are very reliables.
# </div>

# %% [markdown]
# <a id="subsection-three-fourteen"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.14 | Q14 - Sectors where kagglers work?</div>

# %%
jobs = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q20'}}).reset_index().rename(columns={'index':'Industry','Q20':'Users'})

# %%
jobs_pie = px.pie(jobs, values= jobs.Users, names = jobs.Industry, title='Most popular sectors where Kagglers work', color=jobs.Industry)
jobs_pie.update_traces(hovertemplate=None, marker=dict(line=dict(width=0)))
jobs_pie.update_layout(margin=dict(t=80, b=0, l=70, r=40),
                       hovermode="y unified", 
                       xaxis_title=' ', yaxis_title=" ",
                       showlegend=True,
                       title_font=dict(size=25, color='#8a8d93', family="Lato, sans-serif"),
                       font=dict(color='#8a8d93'),
                       hoverlabel=dict(bgcolor="white", font_size=13, font_family="Lato, sans-serif"))

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
# 📌 &nbsp; As we can saw most of the Kagglers works on the Computer/Technology and Academics industries.
# </div>

# %% [markdown]
# <a id="subsection-three-fifteen"></a>
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#303030;text-align:left;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%; margin-left:20px"> 3.15 | Q15 - The advancement of data in the workplace</div>

# %%
ds_work = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q22'}}).reset_index().rename(columns={'index':'Data Scientist at workplace','Q22':'Count'}).sort_values(by='Count', ascending=False)
ml_methods = pd.DataFrame({c : df_data[c].value_counts() for c in {'Q23'}}).reset_index().rename(columns={'index':'ML methods at workplace','Q23':'Count'})

# %%
ml_methods['ML methods at workplace'][0] = 'Exploring the idea'
ml_methods['ML methods at workplace'][3] = 'Well established'
ml_methods['ML methods at workplace'][4] = 'Recently started'
ml_methods['ML methods at workplace'][5] = 'For insights purposes only'

# %%
colors1 = {'1-2':'darkgreen','20+':'forestgreen','0': 'lime','3-4':'orange','5-9':'yellow', '10-14':'red', '15-19':'darkred'}
ds_work['color'] = ds_work['Data Scientist at workplace'].map(colors1)
colors2 = {'Exploring the idea':'darkgreen','No (we do not use ML methods)':'forestgreen','I do not know': 'lime','Well established':'yellow',
           'Recently started':'red', 'For insights purposes only':'darkred'}
ml_methods['color'] = ml_methods['ML methods at workplace'].map(colors2)

fig = make_subplots(rows=1, cols=2, 
                    specs=[[{"type": "bar"}, {"type": "bar"}]],
                    column_widths=[0.5, 0.5], vertical_spacing=0, horizontal_spacing=0.2,
                    subplot_titles=("Data scientist at Workplace", "ML methods al workplace"))

fig.add_trace(go.Bar(x=ds_work['Count'], y=ds_work['Data Scientist at workplace'], marker=dict(color=ds_work['color']),
                     name='# Data Scientist', orientation='h', text=ds_work['Count']), 
                     row=1, col=1)

fig.add_trace(go.Bar(x=ml_methods['Count'], y=ml_methods['ML methods at workplace'], marker=dict(color=ml_methods['color']),
                     name='Method type', orientation='h', text=ml_methods['Count']), 
                     row=1, col=2)

fig.update_yaxes(showgrid=False, ticksuffix=' ', categoryorder='total ascending', row=1, col=1)
fig.update_yaxes(showgrid=False, ticksuffix=' ', categoryorder='total ascending', row=1, col=2)
fig.update_traces(texttemplate='%{text}', textposition='inside', row=1, col=1)
fig.update_traces(texttemplate='%{text}', textposition='inside', row=1, col=2)
fig.update_xaxes(visible=False, row=1, col=1)
fig.update_xaxes(visible=False, row=1, col=2)
fig.update_layout(title={'text': "The advancement of data in the workplace",'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'},
                  template="plotly_white",
                  title_font=dict(size=29, color='#8a8d93', family="Lato, sans-serif"),
                  font=dict(color='#8a8d93'), 
                  hoverlabel=dict(bgcolor="#f2f2f2", font_size=13, font_family="Lato, sans-serif"),
                  showlegend=False)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
# 📌 &nbsp; Still has a lot of work to do when it comes to data and ML in general within organizations. So I imagine that this branch of work (Data in general) will be highly demanded in the coming years.
# </div>

# %% [markdown]
# <p style="font-size:18px; font-family:verdana; line-height: 1.7em; margin-left: 20px">
#  More plots coming soon, thanks for taking the time to see my notebook. Greetings! </p>
