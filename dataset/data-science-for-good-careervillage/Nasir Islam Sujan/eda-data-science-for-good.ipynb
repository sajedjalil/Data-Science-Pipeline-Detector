# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_palette("Set2")
from wordcloud import WordCloud, STOPWORDS

# %%
# load dataset
questions = pd.read_csv('../input/questions.csv')
answers = pd.read_csv('../input/answers.csv')
students = pd.read_csv("../input/students.csv")
professionals = pd.read_csv('../input/professionals.csv')

# %%
students.head(2)

# %%
professionals.head(2)

# %%
answers.head(2)

# %%
questions.head(2)

# %% [markdown]
# ## Student's with particular questions

# %%
student_question = students.merge(right = questions, how = 'inner', left_on='students_id', right_on='questions_author_id')

# %%
student_question.head(2).T

# %% [markdown]
# ## Student's Questions with Answers

# %%
sq_answers = student_question.merge(right=answers, how='inner', left_on='questions_id', right_on='answers_question_id')

# %%
sq_answers.head(2).T

# %% [markdown]
# ## Student's Questions answerd by Professionals

# %%
final_df = sq_answers.merge(right=professionals, how='inner', left_on='answers_author_id', right_on='professionals_id')

# %%
final_df.head(2).T

# %%
final_df.describe().T

# %% [markdown]
# ## Where most of the student resides 🏡

# %%
final_df['students_location'].fillna("N/A", inplace=True)

# %%
all_locations = ','.join(final_df['students_location'].values)

wordcloud = WordCloud(width=1500, height=800).generate(all_locations)

plt.figure(figsize=(20, 8))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# > __Most of students are from `New York`, `North Carolina`, `San Jose, California`, `Rhode Island`.__

# %% [markdown]
# ## Question's Topics 💭

# %%
final_df["questions_title"].isnull().values.any()

# %%
all_question_titles = ','.join(final_df['questions_title'].values)

wordcloud = WordCloud(width=1500, height=800).generate(all_question_titles)

plt.figure(figsize=(20, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# > __Most of the questions are based on `college`, `job`, `career`.__

# %% [markdown]
# ## Author Who answer's most questions 📜

# %%
all_author = ','.join(final_df['answers_author_id'].values)

wordcloud = WordCloud(width=1500, height=800).generate(all_author)

plt.figure(figsize=(20, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# >__ Most answered author `36ff3b3666df400f956f8335cf53e09e`__

# %% [markdown]
# ## Where are from the professionals 🌎

# %%
final_df["professionals_location"].fillna("N/A", inplace=True)

# %%
professionals_locations = ','.join(final_df['professionals_location'].values)

wordcloud = WordCloud(width=1500, height=800).generate(professionals_locations)

plt.figure(figsize=(20, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# >__Most authors are from `Greater Detroit Area`, `New York`, `Bengaluru, Karnataka, India`.__

# %% [markdown]
# ## Most common professional industry 🏢

# %%
final_df['professionals_industry'].fillna("N/A", inplace=True)

# %%
all_industries = ','.join(final_df['professionals_industry'].values)

wordcloud = WordCloud(width=1500, height=800).generate(all_industries)

plt.figure(figsize=(20, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# >__Most professionals are worked on `Information Technology and Services`, `Hospital and Health Care` and `Telecommunications` based industries.__

# %% [markdown]
# ## Professional are from which field ? 💻📡💉📱

# %%
final_df.professionals_headline.fillna("N/A", inplace=True)

# %%
professional_fields = ','.join(final_df['professionals_headline'].values)

wordcloud = WordCloud(width=1500, height=800).generate(professional_fields)

plt.figure(figsize=(20, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# > ## __That's all for this kernel. Hope you enjoyed it. If so, then give a upvote. 😍__
