# %%
import pandas as pd

# %%
submission = pd.read_csv("../input/tabular-playground-series-dec-2021/sample_submission.csv")
submission.loc[:, 'Cover_Type'] = 5
submission.head()

# %%
submission.to_csv("submission.csv", index=False)
