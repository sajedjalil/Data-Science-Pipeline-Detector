# %%
! pip install scikit-learn --upgrade --force-reinstall

# %%
! pip install --no-deps autoxgb

# %%
import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv('../input/tabular-playground-series-dec-2021/train.csv')
df_train

# %%
df_train.isnull().sum().sum()

# %%
df_train['Cover_Type'].unique()

# %%
df_train['Cover_Type'].value_counts()

# %%
#df_train = 
df_train[df_train['Cover_Type'] == 5]

# %%
df_train = df_train[df_train['Cover_Type'] != 5]
df_train.to_csv('New_train.csv', index = False)

# %%
df_train = pd.read_csv('./New_train.csv')
df_train

# %%
train_filename = "./New_train.csv"
test_filename = "../input/tabular-playground-series-dec-2021/test.csv"
output = "autoxgb9"


idx = 'Id'
targets = ["Cover_Type"]

task = 'classification'


num_folds = 5
seed = 42
num_trials = 1000
time_limit = 6000
fast = False
use_gpu = True

# %%
# Model

from autoxgb import AutoXGB

axgb = AutoXGB(
    train_filename = train_filename,
    output=output,
    test_filename=test_filename,
    task=task,
    idx = idx,
    targets=targets,
   #features=features,
   #categorical_features=categorical_features,
    use_gpu=use_gpu,
    num_folds=num_folds,
    seed=seed,
    num_trials=num_trials,
    time_limit=time_limit,
    fast=fast
)

# %%
axgb.train()

# %%
test_preds = pd.read_csv("/kaggle/working/autoxgb9/test_predictions.csv")
sample_submission = pd.read_csv("../input/tabular-playground-series-dec-2021/sample_submission.csv")
sample_submission.target = test_preds["1"].values
sample_submission.to_csv("submission.csv", index=False)
