# %% [markdown]
# This is my first submission to the competition. I have also done some EDA for the data and will use the insights generated from the EDA further in the competition.
#
# Link to EDA notebook: https://www.kaggle.com/aniketsharma00411/tpsdec21-exploratory-data-analysis/

# %%
import pandas as pd

# %%
sample_submission = pd.read_csv('/kaggle/input/tabular-playground-series-dec-2021/sample_submission.csv')
sample_submission.head()

# %%
sample_submission.to_csv('submission.csv', index=False)
