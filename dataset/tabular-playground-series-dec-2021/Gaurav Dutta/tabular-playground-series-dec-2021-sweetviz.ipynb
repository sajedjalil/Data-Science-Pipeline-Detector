# %%
import pandas as pd
train=pd.read_csv("../input/tabular-playground-series-dec-2021/train.csv")
train.head()

# %%
train=train.drop(['Id'],axis=1)
train.head()

# %%
round(train.Cover_Type.value_counts()*100/len(train),2)

# %%
train.Cover_Type.value_counts()

# %%
train.info()

# %%
# !pip install sweetviz

# %%
import sweetviz
feature_config =  sweetviz.FeatureConfig(force_num=["Cover_Type"])
my_report  = sweetviz.analyze(train, target_feat='Cover_Type',feat_cfg=feature_config)
my_report.show_notebook()
