# %%
import pandas as pd
covtype = pd.read_csv('../input/forest-covertype-dataset/dataset/covtype.csv')
CTGAN = pd.read_csv('../input/tabular-playground-series-dec-2021/train.csv')

covtype.insert(0, 'id', 0)

# %%
pd.set_option('display.float_format', str)
covtype.columns = CTGAN.columns
display(covtype.describe())
display(CTGAN.describe())
