# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Install D-Tale

# %%
from IPython.display import clear_output
# !pip install dtale
clear_output()

# %% [markdown]
# # Import D-Tale

# %%
import dtale
import dtale.app as dtale_app

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv("../input/tabular-playground-series-dec-2021/train.csv")

# %% [markdown]
# # Analyze Data

# %%
dtale_app.USE_NGROK = True

d=dtale.show(train_df)

# %% [markdown]
# # Show link and Click link and Show Analyze Data at the webpage

# %%
d.main_url()
