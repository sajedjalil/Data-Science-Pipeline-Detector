# %% [markdown]
# # Will be updating this notebook from time to time.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../input/jane-street-market-prediction/train.csv")

# %%
df2 = pd.read_csv("../input/jane-street-market-prediction/features.csv")

# %%
df.iloc[:10,:20]

# %%
df.describe()

# %%
for i in range(130):
    sns.lineplot(data=df,x='date',y='feature_'+str(i))

# %%
# import janestreet
# env = janestreet.make_env() # initialize the environment
# iter_test = env.iter_test() # an iterator which loops over the test set

# for (test_df, sample_prediction_df) in iter_test:
#     sample_prediction_df.action = 0 #make your 0/1 prediction here
#     env.predict(sample_prediction_df)

# %% [markdown]
# # HAPPY CODING
