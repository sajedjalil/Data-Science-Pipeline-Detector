# %% [markdown]
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:180%; text-align:center"> Jane Street Market Prediction - SweetViz 📊 </p>

# %% [markdown]
# ## <p style="background-color:skyblue; font-family:newtimeroman; font-size:120%; text-align:center">Table of Content</p>
#
# * [1. Install SweetViz](#1)
# * [2. Import Libs](#2)
# * [3. Parameters](#3)
# * [4. Visualizations](#4)
# * [5. Final Notes](#5)

# %% [markdown]
# SweetViz is an automatic visualization tool that helps new competitors in kaggle to understand the data without much effort.
#
#
#
# ![SweetViz](https://warehouse-camo.ingress.cmh1.psfhosted.org/a488ecd36ce307df2949bf839872d2fb3917f5cc/687474703a2f2f636f6f6c74696d696e672e636f6d2f53562f6c6f676f2e706e67)
#
#
#
# > In-depth EDA (target analysis, comparison, feature analysis, correlation) in two lines of code! Sweetviz is an open source Python library that generates beautiful, high-density visualizations to kickstart EDA (Exploratory Data Analysis) with just two lines of code. Output is a fully self-contained HTML application.
#
# For more information: https://pypi.org/project/sweetviz/
#
#
# ![SweetViz](https://warehouse-camo.ingress.cmh1.psfhosted.org/9eb20dbdb87a70b5e8e117088be7bd153cbc6b3d/687474703a2f2f636f6f6c74696d696e672e636f6d2f53562f66656174757265732e706e67)

# %% [markdown]
# <a id='1'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">1. Install SweetViz </p>

# %%
# !pip install sweetviz

# %% [markdown]
# <a id='2'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">2. Import Libs </p>

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sweetviz as sv
from IPython.display import IFrame

# %% [markdown]
# <a id='3'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">3. Parameters </p>

# %%
TRAIN_INPUT = "/kaggle/input/jane-street-market-prediction/train.csv"
TRAIN_NROWS = 100000
IFRAME_SRC = "test.html"
IFRAME_WIDTH = 1920
IFRAME_HEIGHT = 1080

# %% [markdown]
# <a id='4'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">4. Visualizations </p>

# %%
df = pd.read_csv(TRAIN_INPUT, nrows = TRAIN_NROWS)
df.head(1)

# %%
analyze = sv.analyze(df)
analyze.show_html(IFRAME_SRC)

# %%
IFrame(src=IFRAME_SRC, width=IFRAME_WIDTH, height=IFRAME_HEIGHT)

# %% [markdown]
# <a id='5'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">5. Final Notes </p>
#
#
# ## If you liked this notebook, please consider upvote to motivate me to improve my work! Thanks!
#
# - In the "Associations" button, you can see the correlation of the features.
# - In each interactive row is described the features with many statistics!
#
# ## If you want to see my other visualization work: [Jane Street AutoViz](https://www.kaggle.com/rapela/jane-street-autoviz)
