# %%
# !pip install autoviz

# %% [markdown]
# # > **Hello, I am sharing this automatic visualization notebook to help new competitors understand the data without much effort.
# > **Autoviz: Automatically Visualize any Dataset****
# > *Visualize dataset of any size with just one line of code*

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV = AutoViz_Class()
df = AV.AutoViz('/kaggle/input/jane-street-market-prediction/train.csv')

# %%
# !pip install -U dataprep

# %%
from dataprep.eda import plot, plot_correlation, plot_missing
import pandas as pd
df = pd.read_csv("/kaggle/input/jane-street-market-prediction/train.csv", nrows = 100000)
plot(df)

# %%
plot_correlation(df)

# %%
plot_missing(df)
