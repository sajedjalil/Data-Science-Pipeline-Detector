# %% [markdown]
# This notebook plots a visualization of the last 30000 rows in the the train csv.

# %%
import numpy as np
import pandas as pd
import janestreet

# %%
train = pd.read_csv('../input/jane-street-market-prediction/train.csv', nrows=100000)

# %%
#train=train.dropna()
train=train.drop(['resp_1','resp_2','resp_3','resp_4','ts_id'], axis=1)
train

# %%
train_sample=train.tail(30000)
train_sample.plot(kind='line', subplots=True, grid=True, title="visulaize ", sharex=True, sharey=False, legend=True,figsize=(15,200))
