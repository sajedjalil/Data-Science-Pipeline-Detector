# %% [markdown]
# # What's this
# - 情報のキャッチアップのために評価の高いnotebookについて読んでまとめていく

# %% [markdown]
# ## EDA系

# %% [markdown]
# [
# Jane Street: EDA of day 0 and feature importance](https://www.kaggle.com/carlmcbrideellis/jane-street-eda-of-day-0-and-feature-importance)
# - 基礎的なedaが網羅されているので最初に目を通しておく
#
#
#
# [Jane_street_Extensive_EDA & PCA starter](https://www.kaggle.com/muhammadmelsherbini/jane-street-extensive-eda-pca-starter)
# - 前半は多分↑と同じ内容
# - PCA & Clustering から先だけ読む
#
#
# [Utility Function and Patterns in Missing Values](https://www.kaggle.com/iamleonie/utility-function-and-patterns-in-missing-values)
# - 評価に使われる UtilityFunctinの分析と、欠損値の扱いについて
#
#
# [Jane Street Market Prediction. Fast understanding.](https://www.kaggle.com/isaienkov/jane-street-market-prediction-fast-understanding)
# - 各featureのdistribtuonやheatmapなど
#
#
# [
# Feature 0, beyond feature 0](https://www.kaggle.com/nanomathias/feature-0-beyond-feature-0)
#
# - feature_0についての分析
#  - feature_0は他のfeatureとは違い-1,1の2値の値
#
# [Jane Street Market 📈 [EDA, Viz, Prediction]](https://www.kaggle.com/blurredmachine/jane-street-market-eda-viz-prediction)
#
#  - こちらも各featureのdistributionやheatmapなど

# %% [markdown]
# ## モデリング

# %% [markdown]
# [Market Prediction: XGBoost with GPU (Fit in 1min)](https://www.kaggle.com/hamditarek/market-prediction-xgboost-with-gpu-fit-in-1min)
#
# - XGBoostによるfit
# - Public Score 693.331
#
# - parametor
# ```
# clf = xgb.XGBClassifier(
#     n_estimators=400,
#     max_depth=7,
#     eta=0.5,
#     missing=None,
#     random_state=42,
#     tree_method='gpu_hist',
#     subsample=0.8,
#     colsample_bytree=1,
#     verbosity=2
# )
# ```

# %% [markdown]
# [
# Jane Street: Neural Network Starter](https://www.kaggle.com/gogo827jz/jane-street-neural-network-starter)
# - tensolfrowを使ったNNのサンプル

# %% [markdown]
# ## Validation

# %% [markdown]
# [Purged Time Series CV, XGBoost, Optuna](https://www.kaggle.com/marketneutral/purged-time-series-cv-xgboost-optuna)
# - time leakを起こさないcross validationについて
