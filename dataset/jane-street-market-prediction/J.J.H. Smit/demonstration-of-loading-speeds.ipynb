# %%
import pandas as pd

# %%
# %%timeit

pd.read_csv('../input/jane-street-market-prediction/train.csv').describe()

# %%
# %%timeit

pd.read_parquet('../input/jane-street-parquet/dtrain.parquet').describe()
