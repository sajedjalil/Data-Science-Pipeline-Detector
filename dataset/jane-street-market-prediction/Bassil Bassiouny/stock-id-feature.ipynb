# %% [markdown]
# Hello All,
# I know that some of kagglers think that feature_41 (feature_42 / feature_43) is correspoding to stock ID.
# but here I will discuss this issue and try to answer (what is the feature correspoding to stock ID? )

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train = pd.read_csv('../input/jane-street-market-prediction/train.csv')

train = train.astype({c: np.float32 for c in train.select_dtypes(include='float64').columns})

train = train.query('weight > 0').reset_index(drop = True)

# %% [markdown]
# if we conseder feature_41 = stock ID
# then

# %%
number_of_stocks = train['feature_41'].nunique()
list_of_stocks = train['feature_41'].unique()

# %%
number_of_stocks

# %% [markdown]
# ![](http://)319294 stocks is very large number!!!!, but let's complete

# %% [markdown]
# now I am going to ckeck how many working days for each stock ?

# %%
no_of_working_days_per_stock = train.groupby('feature_41').date.nunique()

# %% [markdown]
# if we check max working days we will find:

# %%
max(no_of_working_days_per_stock)

# %% [markdown]
# maximum working days is 6 days only !!!!!!!!!!!!!!!!!
# so feature_41 is not good one.

# %% [markdown]
# # Let us check feature_42

# %%
no_of_working_days_per_stock = train.groupby('feature_42').date.nunique()

# %%
max(no_of_working_days_per_stock)

# %% [markdown]
# 61 working days from 500 working days
# also feature_42 is not good one

# %% [markdown]
# # Let us check feature_43

# %%
no_of_working_days_per_stock = train.groupby('feature_43').date.nunique()

# %%
max(no_of_working_days_per_stock)

# %% [markdown]
# the same as feature_41 & feature_42

# %% [markdown]
# # check feature_52

# %%
no_of_working_days_per_stock = train.groupby('feature_52').date.nunique()

# %%
max(no_of_working_days_per_stock)

# %%
no_of_working_days_per_stock.sort_values(ascending=False).iloc[0:60]

# %%
no_of_working_days_per_stock.sort_values(ascending=False).iloc[60:120]

# %%
train['feature_52'].nunique()## number of stocks

# %% [markdown]
# so if we conseder feature_52 is coresponding to stock ID then:
#
#     1- number of stocks = 33336 which is resonable number
#     2- list of numbers of working day per stock has alot of resonable numbers

# %%
############################# check feature_69 ################

# %%
no_of_working_days_per_stock = train.groupby('feature_69').date.nunique()

# %%
max(no_of_working_days_per_stock)

# %%
no_of_working_days_per_stock.sort_values(ascending=False).iloc[0:60]

# %%
no_of_working_days_per_stock.sort_values(ascending=False).iloc[60:120]

# %%
train['feature_69'].nunique()## number of stocks

# %% [markdown]
# so if we conseder feature_69 is coresponding to stock ID then:
#    1. number of stocks = 65284 which is lettel bit high
#    2. list of numbers of working day per stock has alot of resonable numbers but not like feature_52 (only 7 stocks have working days from 400 to 500 which is not normal)

# %% [markdown]
# **Conclusion**
#
# 1. feature_41 & feature_42 & feature_43 are not represinting stock ID.
# 2. feature_52 is most probably sock ID
# 3. feature_69 is second choise for sock ID
