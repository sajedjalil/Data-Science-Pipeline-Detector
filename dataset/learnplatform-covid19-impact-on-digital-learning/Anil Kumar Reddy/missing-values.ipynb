# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # will start with districts_info csv file to understand each columns

# %%
di = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv")
print(di.shape)
di.head()

# %%
# unique column to get engagement_data
di["district_id"].value_counts().sum()

# %%
states = di["state"].value_counts()
plt.figure(figsize=(12,15))
plt.pie(x=states, autopct="%.1f%%",  labels=list(states.to_dict().keys()), pctdistance=0.5)
plt.show()

# %%
di["locale"].value_counts().plot.bar()

# %% [markdown]
# # columns - pct_black/hispanic, pct_free/reduced, county_connections_ratio and pp_total_raw
#
# # ]a,b[ = { x∈R : a<x<b}
#
# # [a,b[ = {x∈R:a≤x<b}
#
# # all values are in this format ex: [0.2, 0.4[ -> 0.2<= x < 0.4
#
# # ]a,b] = {x∈R:a<x≤b}
#
# # https://www.kaggle.com/c/learnplatform-covid19-impact-on-digital-learning/discussion/268430

# %% [markdown]
# #  products_info csv file to understand each columns

# %%
pi = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/products_info.csv")
print(pi.shape)
pi.head()
