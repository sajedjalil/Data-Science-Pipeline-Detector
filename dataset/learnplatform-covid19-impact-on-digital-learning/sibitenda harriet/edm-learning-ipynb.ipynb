# %% [markdown]
# # **Analyzing digital learning**

# %% [markdown]
# ## Introduction

# %% [markdown]
# Education was perceived as most important field to change the world by Nelson mandela, but effectiveness of education policy has been questioned with unmeasurable impacts until the occurance of COVID-19 since education has now been anticipated as a cause of inequity
#
# Access to online learning platforms with tools like LearnPlatform is a solution identified to reduce this gap. learning Platform uses evidence basis strategy that is adopted to all stakeholders involved to monitor feedback. This is anicipated to improve safety, equity and effeciveness
#
# Task activities aim at uncovering trends from digital learning by analysing data from LearnPlatform. A number of policies ad activities will be numbered to close the digital gap

# %% [markdown]
# ## Challenge Activities

# %%
# Explore the state of digital learning in the U.S by 2020
# Explore impact of different factors on digital learning
# Suggest recomendation policies

# %% [markdown]
# **Steps to follow**

# %%
# Study the picture of digital connectivitiy and engagemnt in 2020
# Study effect of pandemic on online and distance learning for future relation
# Study student ability to engage in a given type of educationa technology change
# Study relation of digital learning to geography
# Study relation of digital learning to demographic context of factors like: race/ethinicity, ESL, learning disability
# Study relation of digital learning to socioeconmic status
# Perform state interventions, practices or policies like: stimulus, reopening, eviction, moratorium
# Perform state interventions to correlate with the increase or decrease online student engament

# %% [markdown]
# **Sumary plan **

# %% [markdown]
# 1. Understanding the shape of data and structure (value counts, hitograms, shape, null records)
# 2. Perform Data cleaning
# 3. Exploration of cleaned data for differen factors that ipact digital learning
# 4. Preprocessing
# 5. Feature extraction and engineering (scaling, transformation)
# 6. Model building and training
# 7. Model evaluations
# 8. Prediction of results

# %% [markdown]
# ### Setting up environment for data nalyis

# %%
import os
import glob
import tqdm
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import missingno as msno
import plotly as py
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import statistics as stat
import folium

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Reading data

# %%
# setiing environment to read data

df = pd.read_csv('../input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv')
df.head() # viewing top records of the data

# %% [markdown]
# Spliting added values fin each cell

# %%
#we define a couple of scripts that we shall implement
def null_values(df):
    
    #get the number of null values in the system
    try:
        print(" #### Calculating Missing Values ##### \n")
        for i in tq(range(1),desc="Fetching data"):
        
            
            
            sumofNull=df.isna().sum()
            percentage=sumofNull/len(df)*100
        print(" #### Done #### \n ")
            
            
        
        print("#### Creating data frame #### \n ")
        
        for i in tq(range(1),desc="Creating DataFrame"):
            valuesdf=pd.DataFrame(data=[sumofNull,percentage])
            valuesdf=valuesdf.T
            valuesdf.columns=["Total Missing","Percentage Missing"]
        print(" #### Done #### ")
        

        return valuesdf
            
    except Exception as e:
        
        print(" !!! Error File Not Found  !!!!! \n")
        print(" !!! Program Failed !!!!! \n")
        
        print("Safely exiting the program")
        sys.exit(1)

def dropDuplicates(data):
        try:
            
            for i in tq(range(1),desc="Detecting duplicates"):
                data=data.drop_duplicates()
            for i in tq(range(1),desc="Report on Duplicates "):
                dupCount=len(data)-len(data.drop_duplicates())
                
            print ("There are {} duplicates in the dataset\n".format(dupCount))
            logging.info("Number of duplicates in the datset are {} ".format(dupCount))

            

            return data 
        except Exception as e:

            print("The following error occured {} ".format(e.__class__))

# %%
df.info()

# %%
import sys
from tqdm.notebook import tqdm_notebook as tq
null_values(df)

# %%
#we get the state abbrevations to use in potting graphs
state_abb = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District Of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

df['state_abb'] = df['state'].map(state_abb)

# %%
def count_plot(data,colr,title):
    plt.figure(figsize=(10,8))
    ax=sns.countplot(x=data,palette=colr,order=data.value_counts().index)
    plt.xticks(rotation=90)
    plt.title(title)
    for p in ax.patches:
        ax.text (p.get_x() + p.get_width()  / 2,p.get_height()+ 0.75,p.get_height(), fontsize = 11)
#         ax.text('%{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

# %%
import plotly.graph_objects as go
fig = go.Figure()
layout = dict(
    title_text = "Count of districts in the available States",
    title_font = dict(
            family = "monospace",
            size = 25,
            color = "black"
            ),
    geo_scope = 'usa'
)

fig.add_trace(
    go.Choropleth(
        locations = df['state_abb'].value_counts().to_frame().reset_index()['index'],
        zmax = 1,
        z = df['state_abb'].value_counts().to_frame().reset_index()['state_abb'],
        locationmode = 'USA-states',
        marker_line_color = 'white',
        geo = 'geo',
        colorscale = "cividis", 
    )
)
            
fig.update_layout(layout)   
fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
count_plot(df['state'],'RdYlGn',"State count display")

# %%
df2 = pd.read_csv('../input/learnplatform-covid19-impact-on-digital-learning/products_info.csv')
df2  # viewing top and  bottom records of the data

# %% [markdown]
# ## 1. Understanding the shape of data and structure

# %%
# Understanding the data types and null counts
df.info()

# %% [markdown]
# ### Description of features

# %% [markdown]
# 1. district_id expalins the unique identfier of the school district
# 2. state explains the state where the school district is located
# 3. locale includes the U.S territory types of areas: City, Town, Subtown,and Rural
# 4. pct_black/hispanic explains the percentage os students in districts of Black or Hispanic
# 5. pct_free/reduced explains percentage of students who are eligigible to acquire free or reduced price lunch
# 6. country_connections_ratio explains the residential fixed high speed connection of data over 200kbps
# 7. pp_total_raw explains the rate of pupil per total expenditure (sum of local and federal expenditure data)

# %%
# Identify the shape of data
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")

# %%
# there is need to understand the numeric data
df.describe()

# %% [markdown]
# The district_id is identified as the only numeric data sice others have the object data type

# %%
#slipting numerical and categorical data 
df_num = df[['district_id']]
df_cat = df[['state','locale', 'pct_black/hispanic', 'pct_free/reduced', 'county_connections_ratio', 'pp_total_raw']]

# %%
# Visualization of data structure
import matplotlib.pyplot as plt 

for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
df.head()

# %% [markdown]
# According to what we observe data for district id gives a normalised graph thus no need of normaliszing this data

# %% [markdown]
# Understandaing the structure of table2

# %%
#Outline the datatypes and null counts 
df2.info()

# %% [markdown]
# ### Description of features

# %% [markdown]
# 1. LP ID explains the unique identifier of the product
# 2. URL explains the web link to the specific product
# 3. Product Name explains the name of a gven product
# 4. Provider/Company Name explains the name of company providing the product
# 5. Sector(s) explains the sector of education where the product is being used
# 5. Primary Essential Function explains the basic fucnction of the product. The LC is for Learning & Curriculum and CM is for Classroom Management, and SDO is for School & District Operations.Each of these three has other lables identifying the products)

# %%
# Identify the shape of data
print(f"There are {df2.shape[0]} rows and {df2.shape[1]} columns")

# %%
df2.describe()

# %%
#slipting numerical and categorical data 
df2_num = df2[['LP ID']]
df2_cat = df2[['URL','Product Name', 'Provider/Company Name', 'Sector(s)', 'Primary Essential Function']]

# %%
#Visualization of data structure 
import matplotlib.pyplot as plt 
# %matplotlib inline

for i in df2_num.columns:
    plt.hist(df2_num[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# The columns with missing values have to be cleaned and renaming column names is also import for easy integration of the records into other tools like MySQL

# %%
# Handling columns with missing values 
df.isna().sum()

# %%
df.dtypes

# %%
# checking for null values if there is any empty column
check_null = df.columns.isnull().any()
check_null

# %%
# Identfying the percentage of null values 
def null_analysis(df):
    total_values = np.product(df.shape)
    total_null = (df.isnull().sum()).sum()
    proportion_null = (total_null / total_values)*100
    
    print("The district info dataset has ", proportion_null,"% null values.")

null_analysis(df)

# %%
# Identifying duplicated rows
df = df[df.duplicated()]
print("Number of duplicate rows: ", df.shape)

# %%
# fill missing with ffill method for columns (pct_free/reduced , pp_total_raw )

def fix_missing_ffill(df2, col):
    df2[col] = df2[col].fillna(method='ffill')
    return df2[col]
# fill missing with ffill method for columns (pct_free/reduced , pp_total_raw )

def fix_missing_ffill(df2, col):
    df2[col] = df2[col].fillna(method='ffill')
    return df2[col]

# %%
msno.bar(df2,color='#924893', sort="ascending", figsize=(10,5), fontsize=12)
plt.show()

# %%
#using the foward ffill
df2['Sector(s)'] = fix_missing_ffill(df2, 'Sector(s)')
df2['Primary Essential Function'] = fix_missing_ffill(df2,'Primary Essential Function')

# %%
df2['primary_function_max'] = df2['Primary Essential Function'].apply(lambda x: x.split(' - ')[0] if x == x else x)
df2['primary_function_min'] = df2['Primary Essential Function'].apply(lambda x: x.split(' - ')[1] if x == x else x)

# Synchronize similar values
df2['primary_function_min'] = df2['primary_function_min'].replace({'Sites, Resources & References' : 'Sites, Resources & Reference'})
df2.drop("Primary Essential Function", axis=1, inplace=True)

# %%
df2.dtypes

# %%
# Handling columns with missing values 
df2.isna().sum()

# %%
df2=df2.dropna()

# %%
df2.head()

# %%
def bar_p(df:pd.DataFrame, column:str,title:str):
    plt.figure(figsize=(18, 9))
    sns.countplot(y=column, data=df2, order=df[column].value_counts().head(10).index,color = "#a265b8")
    plt.title(title,font="Tahoma", size=20)
    plt.show()
    
bar_p(df2,'Provider/Company Name','Showing 10 providers')

# %%
# removing spaces and other charcters between words for each column
df2.columns = df2.columns.str.replace(' ','_')
df2.columns = df2.columns.str.replace('/','_')

df2.columns.to_list()

# %%
# We rename the sector(s) column
df2.rename(columns={'Sector(s)': 'sector_s'}, inplace=True)

# %%
# checking for null values if there is any empty column
check_null = df2.columns.isnull().any()
check_null

# %%
df2.isna().sum()

# %%
# Identifying duplicated rows
df2 = df2[df2.duplicated()]
print("Number of duplicate rows: ", df2.shape)

# %%
import glob
import os
import pandas as pd

path = '../input/learnplatform-covid19-impact-on-digital-learning/engagement_data'
file_type = 'csv'
seperator=','
files = glob.glob(path + "/*.csv")# glob function to call diffrent files of csv
Updated_Df = []

for f in files:
    data = pd.read_csv(f, index_col=None, sep=seperator, header=0) #for f in glob.glob(folder_name + "/*."+file_type)],ignore_index=True)
    #generating a column from each csv file
    district_id = f.split("/")[4].split(".")[0] #print (district_id) 
    data['district_id'] = district_id
    Updated_Df.append(data)

data = pd.concat(Updated_Df)

data = data.reset_index(drop=True)

data.head()

# %%
data.isna().sum()

# %%
data.dtypes

# %%
msno.bar(data, color='#25c28b', sort="ascending", figsize=(10,5), fontsize=12)
plt.title("Number of non-null entries in engagement dataset", size=20)
plt.show()

# %%
plt.figure(figsize=(15,5))

sns.histplot(data.groupby('district_id').time.nunique(), bins=30, color = '#b3a42f')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Number of days', fontsize=20)
plt.ylabel('Number of district', fontsize=20)
plt.title('Districts with unique days of engagement ', fontsize = 20)

# %%
data.lp_id.head()

# %% [markdown]
# Filling the missing values can be done using two functions ffill (filing with a value at front) and bfill (filling with a value behind)
#
# This is done by considering the mode if data is not skewed or using the median if the data is skewed

# %%
df.dropna(inplace=True)

# %%
df = df.copy()

# %%
df['pct_black/hispanic'] = df['pct_black/hispanic'].apply(lambda x: (x.replace('[', '')).split(','))
df['pct_free/reduced'] = df['pct_free/reduced'].apply(lambda x: (x.replace('[', '')).split(','))
df['pp_total_raw'] = df['pp_total_raw'].apply(lambda x: (x.replace('[', '')).split(','))
df.drop(columns=['county_connections_ratio'],inplace=True)
for i in ['pct_black/hispanic','pct_free/reduced','pp_total_raw']:
    df[i] = df[i].apply(lambda x: (float(x[0])+float(x[1]))/2)
df

# %%
data_clean = data.copy()

# Replacing null values for float data types 
cols = ['lp_id','pct_access','engagement_index']

for i in cols:
    data_clean[i]=data_clean[i].fillna(data_clean[i].median())
    
(data_clean.isnull().sum()).sum()

# %%
data_clean.head()

# %% [markdown]
# ### Meging data

# %%
# merging all datsets into one 
data_clean['district_id'] = data_clean['district_id'].astype(int)
m = pd.merge(data_clean, df, on="district_id")
m.head()

# %%
df2 = df2.rename(columns={'LP_ID':'lp_id'})
df2['lp_id'] = df2['lp_id'].astype('float')

# %%
df_data = pd.merge(df2,m, on="lp_id")
df_data.head()

# %% [markdown]
# ## Exploration Data Analysis

# %% [markdown]
# Study effect of pandemic on online and distance learning for future relation

# %%
df_data.describe()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML, Javascript
import IPython.display as py_display
import plotly.express as px

# lets set plotting functions 
def plot_hist(df:pd.DataFrame, column: str, color: str) -> None:
    plt.figure(figsize=(9,7))
    sns.displot(data=df,x=column, color=color, kde=True, height=7, aspect=2)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()
    
def plot_dist(df:pd.DataFrame, column:str) -> None:
    plt.figure(figsize=(9,7))
    sns.displot(df).set_title(f'Distribution of {column}')
    plt.show()

def plot_count(df:pd.DataFrame, column:str) -> None:
    plt.figure(figsize=(12,7))
    sns.counterplot(data=df, x=column)
    plt.title(f'plot count of {column}', size=20, fontweight='bold')
    plt.show()
    
def plot_bar(df:pd.DataFrame, x_col:str, y_col:str, title: str, xlabel: str, ylabel: str) -> None:
    plt.figure(figsize=(9,7))
    sns.barplot(data=df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.show()
    
def plot_heatmap(f:pd.DataFrame, title: str, char=False) -> None:
    plt.figure(figsize=(12,7))
    sns.heatmap(title, size=18, fontweight='bold')
    plt.show()
    
def plot_box(df: pd.DataFrame, x_col: str, y_col: str, title: str) ->None:
    plt.figure(figsize=(12,7))
    sns.boxplot(data=df, x=x_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.show()
    
def plot_box_multi(df:pd.DataFrame, x_col: str, y_col: str, title: str) -> None:
    plt.figure(figsize=(12,7))
    sns.boxplot(data=df, x=x_col,y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks(fontsize=14)
    plt.show()
    
def plot_scatter(df:pd.DataFrame, x_col: str, y_col: str, title: str, hue: str, style: str) -> None:
    plt.figure(figsize=(10,8))
    sns.scatterplot(data=df, x=x_col, y=y_col, hue=hue, styles=style)
    plt.title(title, size=20)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.show()
        
    
import warnings    
# Environment check
warnings.filterwarnings("ignore")

# %%
    
#plot_count(df_data,"pct_black/hispanic")

# %%
#number states in the diastrict
#plot_count(df_data,"state")

# %%
# Study effect of pandemic on online and distance learning for future relation
#plot_bar(df_data,"locale","engagement_index", ylabel="engement_index", xlabel="locale", title=f'Engagement with state coverage')

# %% [markdown]
# It indicates high inovlment with distance learning from the rural areas

# %%
# Study effect of pandemic on online and distance learning for future relation
#plot_bar(df_data,"county_connections_ratio","engagement_index", ylabel="engement_index", xlabel="county_connections_ratio", title=f'Engagement with data connection ability')
