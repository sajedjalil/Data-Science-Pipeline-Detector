# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv")
df

# %%
df.head()

# %%
df.info()

# %%
import pandas as pd
df1=pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/products_info.csv")
df1

# %%
df.columns

# %%
df1.columns

# %%
df1.info()

# %%
df.head()

# %%
df.describe()

# %%
df1.describe()

# %%
df['district_id'].plot(kind='hist');

# %%
df1['LP ID'].plot(kind='hist');

# %%
df['district_id'].plot(kind='bar');

# %%
df1['LP ID'].plot(kind='bar');

# %%
df['state'].value_counts().plot.bar(color = 'black',figsize = (20,5))
