# %%
import os
import glob
import warnings
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
district = pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv")
product = pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/products_info.csv")

# %%
district

# %%
district.head()

# %%
product.head()

# %%
product

# %%
# missing values in the dataset?
def percent_missing(dm):

    # Calculate total number of cells in dataframe
    totalCells = np.product(dm.shape)

    # Count number of missing values per column
    missingCount = dm.isnull().sum()

    # Calculate total number of missing values
    totalMissing = missingCount.sum()

    # Calculate percentage of missing values
    print("The dataset contains", round(((totalMissing/totalCells) * 100), 2), "%", "missing values.")

percent_missing(district)

# %%
sns.countplot(x="pct_black/hispanic",hue="locale",data=district)

# %%
sns.countplot(x="pct_free/reduced",hue="locale",data=district)

# %%
sns.pairplot(product)

# %%
sns.catplot(x="county_connections_ratio",y="state",data=district)
