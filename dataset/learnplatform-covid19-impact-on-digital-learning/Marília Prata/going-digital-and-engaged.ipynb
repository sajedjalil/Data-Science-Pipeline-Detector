# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background:#001f3f;"><b style="color:#03e8fc;">Digital Transformation in the Age of COVID-19</b></h1></center>
#
#
#
# Citation: OECD (2020), Digital Transformation in the Age of COVID-19: Building Resilience and Bridging Divides, Digital Economy
#
# Outlook 2020 Supplement, OECD, Paris, www.oecd.org/digital/digital-economy-outlook-covid.pd
#
# "When the COVID-19 pandemic broke out in 2019, much of the world moved online, accelerating
# a digital transformation that has been underway for decades. Children with at-home Internet access
# began attending class remotely; many employees started working from home; and numerous firms
# adopted digital business models to maintain operations and preserve some revenue flows.
#
# "Meanwhile, mobile applications were developed to help “track and trace” the development of the pandemic; and researchers employed artificial intelligence (AI) to learn more about the virus and accelerate the search for a vaccine."
#
# "Internet traffic in some countries increased by up to 60% shortly after the outbreak (OECD,
# 2020), underscoring the digital acceleration that the pandemic sparked.
#
# https://www.oecd.org/digital/digital-economy-outlook-covid.pdf

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Home Computer</span></h1><br>

# %%
df = pd.read_csv("/kaggle/input/cusersmarildownloadspccsv/pc.csv", encoding ='utf8',sep=";")
print(df.shape)
df.head().style.set_properties(**{'background-color':'#001f3f',
                                     'color': '#03e8fc'})

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Internet</span></h1><br>

# %%
df1 = pd.read_csv("/kaggle/input/cusersmarildownloadsinternetcsv/internet.csv", encoding ='utf8',sep=";")
print(df1.shape)
df1.head().style.set_properties(**{'background-color':'#001f3f',
                                     'color': '#03e8fc'})

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Engagement</span></h1><br>

# %%
df2 = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/engagement_data/5802.csv",  low_memory=False)
print(df2.shape)
df2.head().style.set_properties(**{'background-color':'#001f3f',
                                     'color': '#03e8fc'})

# %% [markdown]
# #Extract data from one year (e.g 2020)

# %%
# extract data from one year (2020)  ##No need to reset index
df1_2020 = df1[df1.year==2020]
df1_2020.head()

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Internet Usage</span></h1><br>
#
# "Internet users ranged from over 95% to less than 70% of the adult population in 2019, and there are important demographic differences in Internet use. Although 58% of those aged 50-74 used the Internet daily in 2019 – up from only 30% in 2010 – this remains well below the average share of daily Internet users aged 16-24 (the so-called “digital natives”), which was close to 95%."
#
# "There are also persistent skills gaps across demographic groups and countries, with people of higher skill or income levels making better use of the Internet and online activities, and being better able to access knowledge, job opportunities, and health and education services."
#
# https://www.oecd.org/digital/digital-economy-outlook-covid.pdf

# %% [markdown]
# #Combining Datasets (with quite the same features)

# %% [markdown]
# #Merge to  combine Datasets
#
# Merge DataFrame or named Series objects with a database-style join.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge.html

# %%
#Code by Babyoda https://www.kaggle.com/babyoda/merge

#Combining the Datasets (with quite the same features)

df3 = pd.merge(df, df1, on=["location","year"])
df3.head()

# %% [markdown]
# #In 2020, we don't have data from all the Countries yet.

# %%
#Code by  Chris X https://www.kaggle.com/docxian/internet-access-development-oecd

# we can quickly check this by counting/plotting the frequencies

fig = plt.figure(figsize=(12,5))
df3.location.value_counts().plot(kind='bar')
plt.grid()
plt.title('Home Computer Access 2017 -2020')
plt.show()

# %%
# visualize development using scatter plot
fig = px.scatter(df1, x='year', y='value', color='location',
             title='Internet Access 2019-2020')
fig.show()

# %% [markdown]
# #Above, I think it's quite the same till the beginning of 2020, when the Pandemic changed everything.

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Then COVID-19 has raised the bar.</span></h1><br>
#
# "With the swell of digitally enabled economic and social activity, COVID-19 has raised the stakes around digital access and engagement, reinforcing the fact that connectivity and use of digital technologies are dynamic goals. Although some online activity may decline as COVID-19 treatments begin to emerge and enable greater in-person interactions, it is likely to remain high in areas for which the pandemic has acted as a catalyst, including telework, e-commerce, e-health and e-payments."
#
# "This maintains pressure on establishing high-quality connectivity as well as boosting the ability of people and firms to use increasingly sophisticated digital solutions."
#
# https://www.oecd.org/digital/digital-economy-outlook-covid.pdf

# %%
#In the beginning of 2020 don't have data from all the countries.

fig = px.parallel_categories(df3, color="year", color_continuous_scale=px.colors.sequential.OrRd)
#plt.title('Internet in Digital Learning')# Didn't work here.
fig.show()

# %% [markdown]
# #pandas.DataFrame.append  returns a new DataFrame consisting of the rows of caller and the rows of other.

# %%
df2.append(df3, ignore_index=True)

# %% [markdown]
# #Above, it returned many NaN since the Dataframe can't be aligned.

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Build an inclusive digital future</span></h1><br>
#
# "Governments are increasingly putting the digital transformation at front and centre of policy agendas. Many governments had strengthened their strategic approach to the digital transformation prior to the COVID-19 pandemic."
#
# "The virtuous circle between digital innovation and digital transformation is a fundamental driver of
# new business models and markets, and digital technologies hold the potential to strengthen the science and research systems that are proving so critical to countries’ COVID-19 response and recovery"
#
# "This strategic trend is encouraging, but may not be enough to ensure a resilient and more inclusive
# digital future. The COVID-19 crisis reinforces the need for a co-ordinated, whole-of-government policy approach to digital transformation. This requires a balancing act that will Not be the same for all countries, as cultural, social and economic factors influence the most suitable policy environment."
#
# https://www.oecd.org/digital/digital-economy-outlook-covid.pdf

# %%
fig = px.line(df3, x="year", y="value_y", color_discrete_sequence=['darksalmon'], 
              title="Internet Access 2019-2020")
fig.show()

# %% [markdown]
# #Append df1 (Internet) with df2 (Engagement index)
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html#pandas.DataFrame.append

# %%
df4=df1.append(df2, ignore_index=True)
df4.head()

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Go Digital</span></h1><br>
#
# "The pillars, and the indicators and policy guidance that underpin them, have become even more critical to policy decisions in light of the COVID-19 crisis."
#
# <font color="#2ECC71">Access</font>
#
# <font color="#2ECC71">Use</font>
#
# <font color="#2ECC71">Innovation</font>
#
# <font color="#2ECC71">Trust</font>
#
# <font color="#2ECC71">Jobs</font>
#
# "We will need to take a fresh look at labour market structures and regulations, while working to ensure that displaced workers are not left behind."
#
# <font color="#2ECC71">Market</font>
#
# <font color="#2ECC71">Society</font>
#
# "As people spend more time online during the pandemic – whether for work, school, or social
# interaction, extra attention is needed to support their well-being. Governments should seize this
# opportunity to address the diverse range of social issues that the digital transformation raises, including questions around data-driven healthcare, disinformation and screen addiction, among many others."
#
# https://www.oecd.org/digital/digital-economy-outlook-covid.pdf

# %%
fig = px.scatter(df, x="year", y="value", color="location")
fig.update_layout(
    title='Home Computer Access 2017-2020')
fig.show()

# %% [markdown]
# #In 2020, we don't have many (Home Computer data) from all the countries.

# %%
#Code by Shrikant3542  https://www.kaggle.com/shreekant009/computer-internet-usage/notebook

fig = px.area(df3, x="year", y="value_y", color="location", line_group="indicator_y")
fig.update_layout(
    title='Internet Access in 2019-2020')
fig.show()

# %% [markdown]
# #Only the 6 countries have Internet 2020 data.

# %%
fig = px.line(df1, x="year", y="value", color_discrete_sequence=['darkgreen'], 
              title="Internet in Remote Learning 2019-2020")
fig.show()

# %% [markdown]
# <h1><span class="label label-default" style="background-color:#001f3f;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Internet Access</span></h1><br>
#
# "With lockdowns and social distancing measures forcing many businesses and schools online, the COVID-19 crisis has reinforced the importance of communications infrastructures and services, as well as access to and robust governance of data. Addressing rural/urban divides in access to broadband and underserved socio-economic groups, upgrading networks to the next evolution of fixed and wireless broadband, and enhancing access to and the sharing of data can help spur economic and social benefits."
#
# https://www.oecd.org/digital/digital-economy-outlook-covid.pdf

# %%
fig = px.bar(df1, 
             x='location', y='year',color_discrete_sequence=['purple'],
             title='Going Digital - Internet data 2019-2020', text='indicator')
fig.show()

# %% [markdown]
# USA shows in 2019 value: 79.88.  Why? I don't know.

# %%
fig = px.bar(df3, 
             x='location', y='year',color_discrete_sequence=['blue'],
             title='Go Digital 2019-2020', text='indicator_y')
fig.show()

# %%
fig = px.bar(df, 
             x='location', y='year',color_discrete_sequence=['#DC143C'],
             title='Home Computers 2017-2020', text='indicator')
fig.show()

# %% [markdown]
# The chart above presents that "plateau" because not all countries are in the 2019-2020 list. Only in 2017 and years before.
#
# Seems that Costa Rica is doing well with Internet access. Japan and Korea are already expected to have high Internet Access.

# %%
fig = px.bar(df,
             y='year',
             x='location',
             orientation='h',
             color='value',
             title='Home Computer 2017-2020',
             opacity=0.8,
             color_discrete_sequence=px.colors.diverging.Temps,
             template='plotly_dark'
            )
fig.update_xaxes(range=[0,35])
fig.show()

# %%
fig = px.bar(df2,
             y='time',
             x='pct_access',
             orientation='h',
             color='engagement_index',
             title='Engagement in Digital Learning 2020',
             opacity=0.8,
             color_discrete_sequence=px.colors.diverging.Tealrose,
             template='plotly_white'
            )
fig.update_xaxes(range=[0,35])
fig.show()

# %% [markdown]
# #For beginners, it's Not easy to work with 3 files. Then try to merge, concatenate and append Dataframes. Just in the middle, I was making a mess.

# %%
# %%html
# <marquee style='width: 90% ;height:70%; color: #DC143C ;'>
#     <b>Be Patient MPWolke was here</b></marquee>
#
# #Code by Udbhav Pangotra  https://www.kaggle.com/udbhavpangotra/how-did-covid-19-impact-digital-learning-edac/notebook
