# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv")
d

# %%
d1=pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/products_info.csv")
d1

# %%
d.columns

# %%
d1.columns

# %%
d.describe()

# %%
d1.describe()

# %%
d.info()

# %%
d1.info()

# %%
d[["state","district_id"]].groupby(["state"], as_index = False).mean().sort_values(by="district_id",ascending = False)

# %%
df3=d1[["Product Name","LP ID"]].groupby(["Product Name"],as_index=False).mean().sort_values(by="LP ID",ascending=False)
df3

# %%
d.plot(x='state',y='district_id',kind='hist')

# %%
d.plot(x='state',y='district_id',kind='bar')

# %%
d1.plot(x='Product Name',y='LP ID',kind='hist')

# %%
d1.plot(x='Product Name',y='LP ID',kind='bar')

# %%
d.plot(x='state',y='district_id',kind='hist',bins=9)
