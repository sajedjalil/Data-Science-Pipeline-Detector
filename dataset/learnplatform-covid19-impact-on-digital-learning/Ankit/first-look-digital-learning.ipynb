# %% [markdown]
# ## Data Analysis
#
# We want to understand what type of data we have and what we are dealing with

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %% [markdown]
# Data files
#     /kaggle/input/learnplatform-covid19-impact-on-digital-learning/products_info.csv
#     /kaggle/input/learnplatform-covid19-impact-on-digital-learning/README.md
#     /kaggle/input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv
#     /kaggle/input/learnplatform-covid19-impact-on-digital-learning/engagement_data/6345.csv

# %% [markdown]
# # Product Info

# %%
## product Info
product_info = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/products_info.csv")
print(product_info.shape)
product_info.head()

# %%
## what is the distrubutionof the Sectors, Primary Essential Function, Provider/Company Name
import seaborn as sns
import matplotlib.pyplot as plt

# how many products we have 
product_info['Product Name'].value_counts()

# %%
# how many products we have 
product_info['Sector(s)'].value_counts()

# %%
product_info['Primary Essential Function'].value_counts()

# %%
product_info['Provider/Company Name'].value_counts()

# %% [markdown]
# # District Information

# %%
dist = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv")
print(dist.shape)
dist.head()

# %%
# there are nulls where ?
dist.info()

# %%
sns.countplot(y = dist['state'])

# %% [markdown]
# # Engagement Data
# We need to join all data  later on but as of now, lets look only at on

# %%
engagement = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/engagement_data/6345.csv")
print(engagement.shape)
engagement.head()

# %%
# are there any null value s
engagement.info() ## there are missing values in engagement index

# %%
engagement.describe().T

# %%
###
