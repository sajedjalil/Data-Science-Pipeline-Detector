# %% [markdown]
# <h1 style="font-family:Comic Sans MS; text-align:center; font-size:36pt">COVID-19<br>Impact on Digital Learning</h1>
# <img src="https://ymca-central-assets.s3-eu-west-1.amazonaws.com/s3fs-public/styles/omega_large/public/news-image/CEN_future-digital_v3.jpg?itok=O_VpCdss&timestamp=1471592522"/>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h2 style="font-family:Comic Sans MS; font-size:22pt ;color:#E13014; text-align:center;color:black">Table of CONTENTS</h2>
# <hr></div>
#
# <p style="font-family:Comic Sans MS; font-size:16pt ;color:#E13014;color:black">Below are the Hyperlinks for shortcut</p>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left;  line-height: 0.5"><a href="#A" style="color:#515A5A">A. Introduction </a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#B" style="color:#515A5A ">B. The PROBLEM we have </a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left;line-height: 0.5"><a href="#C" style="color:#515A5A">C. Our OBJECTIVE</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left;line-height: 0.5"><a href="#D" style="color:#515A5A">D. TOOLS and TACKLES</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#E" style="color:#515A5A">E. The DISTRICTS data</a></h3>
#
# <h3 style="text-indent:25px;font-family: Comic Sans MS; font-size: 18pt; text-align: left; line-height: 0.5"><a href="#E.1" style="color:#515A5A ">E.1. Data CLEANING</a></h3>
#
# <h3 style="text-indent:25px;font-family: Comic Sans MS; font-size: 18pt; text-align: left; line-height: 0.5"><a href="#E.2" style="color:#515A5A ">E.2. Exploratory Data Analysis</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#F" style="color:#515A5A">F. The PRODUCTS data</a></h3>
#
# <h3 style="text-indent:25px;font-family: Comic Sans MS; font-size: 18pt; text-align: left; line-height: 0.5"><a href="#F.1" style="color:#515A5A ">F.1. Exploratory Data Analysis</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#G" style="color:#515A5A">G. The ENGAGEMENT data</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#H" style="color:#515A5A">H. The MERGED data</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#I" style="color:#515A5A">I. States and Locale - Analysis</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#J" style="color:#515A5A">J. Products - Analysis</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#K" style="color:#515A5A">K. Products in States - Analysis</a></h3>
#
# <h3 style="font-family: Comic Sans MS; font-size: 20pt; text-align: left; line-height: 0.5"><a href="#L" style="color:#515A5A">L. Looking at some Aspects</a></h3>

# %% [markdown]
# <p id="A"></p>
# <h3 style="font-family: Comic Sans MS; font-size: 18pt; text-align: left;color:#ce2029; line-height: 0.5;font-weight:bold">A. Introduction</h3>
# <hr style="color:#ce2029; height:0.5px">
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"> Nelson Mandela believed education was the most powerful weapon to change the world. But not every student has equal opportunities to learn. Effective policies and plans need to be enacted in order to make education more equitable—and perhaps your innovative data analysis will help reveal the solution.<br><br>Current research shows educational outcomes are far from equitable. The imbalance was exacerbated by the COVID-19 pandemic. There's an urgent need to better understand and measure the scope and impact of the pandemic on these inequities.

# %% [markdown]
# <p id="B"></p>
# <h3 style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold">B. The PROBLEM we have</h3>
# <hr style="color:#ce2029; height:0.5px">
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 16pt; color:black">Education technology company LearnPlatform was founded in 2014 with a mission to expand equitable access to education technology for all students and teachers. LearnPlatform’s comprehensive edtech effectiveness system is used by districts and states to continuously improve the safety, equity, and effectiveness of their educational technology. LearnPlatform does so by generating an evidence basis for what’s working and enacting it to benefit students, teachers, and budgets.

# %% [markdown]
# <p id="C"></p>
# <h3 style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold">C. Our Objective</h3>
# <hr style="color:#ce2029; height:0.5px">
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 16pt; color:black">We will work to uncover trends in digital learning. Accomplish this with data analysis about how engagement with digital learning relates to factors like district demographics, broadband access, and state/national level policies and events. Then, we will propose a solution to these educational inequities.<br><br>It will be about policies and practices that close the digital divide. With a better understanding of digital learning trends, we may help reverse the long-term learning loss among America’s most vulnerable, making education more equitable.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <p id="D"></p>
# <h3 style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold">D. TOOLS and TACKLES</h3>
# <hr style="color:#ce2029; height:0.5px">

# %%
# Importing the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
import glob
import datetime as dt
from wordcloud import WordCloud
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

from scipy.stats import boxcox
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from datetime import timedelta
from sklearn.metrics import mean_squared_error

from pylab import rcParams
import statsmodels.api as sm

# %%
# Defining the templates for seaborn, matplotlib and plotly
pio.templates.default = "plotly_white"

plt.style.use("seaborn-paper")
plt.rc("figure", autolayout=True)
plt.rc("font", **{"family":"Comic Sans MS"})
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 16pt; color:black">Functions that we use throught our analysis.

# %%
def count_plot(dataframe, feature):
    if len(feature)==1 and dataframe[feature[0]].nunique()<6:
        fig = px.bar(x=dataframe[feature[0]].value_counts().index, y=dataframe[feature[0]].value_counts().values)
        fig.update_layout(font_family="Comic Sans MS")
        fig.update_xaxes(tickangle=270, title=None, tickfont_size=16)
        fig.update_yaxes(title="Counts")
        return fig
    else:
        fig = px.bar(y=dataframe[feature[0]].value_counts().index, x=dataframe[feature[0]].value_counts().values, 
                    orientation="h")
        fig.update_layout(font_family="Comic Sans MS")
        fig.update_xaxes(title="Counts", tickfont_size=14)
        fig.update_yaxes(title=None)
        return fig
        
    
def bar_plot(dataframe, feature1, feature2):
    if len(feature2)>1:
        fig = make_subplots(rows=1, cols=len(feature2), subplot_titles=feature2)
        for i in range(len(feature2)):
            fig.add_trace(go.Bar(x=dataframe[feature1[0]], y=dataframe[feature2[i]], name=feature2[i]), row=1, col=i+1)
        fig.update_layout(font_family="Comic Sans MS", showlegend=False, margin=dict(l=0, r=0, t=100, b=50), height=400)
        return fig

def pie_plot(dataframe, feature):
    fig = go.Figure()
    fig.add_trace(go.Pie(values=dataframe[feature].value_counts().values, labels=dataframe[feature].value_counts().index,
                        pull=[0,0.1,0,0.1],textinfo='percent+value'))
    fig.update_layout(font_family="Comic Sans MS", margin=dict(t=100, b=50))
    return fig

def map_plot(dataframe, location, color, hover):
    fig = px.choropleth(data_frame=dataframe, locations=location, locationmode="USA-states",
                    color=color, scope="usa", hover_name=hover, color_continuous_scale="viridis_r")
    fig.update_layout(font_family="Comic Sans MS",)
    return fig

def path_plot(dataframe, path, values, plot_type):
    if plot_type=="treemap":
        fig = px.treemap(data_frame=dataframe, path=path, values=values,
                       color_discrete_sequence=px.colors.qualitative.G10)
        fig.update_layout(font_family="Comic Sans MS", font_size=16, margin=dict(t=50, b=0))
        return fig
    elif plot_type=="sunburst":
        fig = px.sunburst(data_frame=dataframe, path=path, values=values,
                       color_discrete_sequence=px.colors.qualitative.G10)
        fig.update_layout(font_family="Comic Sans MS", font_size=16, margin=dict(t=50, b=0))
        return fig

def time_plot(df, factor, label):
    for i in ["pct_access","engagement_index"]:
        fig = px.line(data_frame=df, x="week", y=i, color=factor)
        fig.update_layout(font_family="Comic Sans MS",title=dict(text="<b>"+i+" - "+factor+" wise - "+label,  
                                                                 x=0.5, font_size=20), 
                          height=300, margin=dict(b=0))
        fig.update_xaxes(title=None)
        fig.update_yaxes(title=None)
        fig.show()
        
def comparison_bar_plot(df):
    fig = make_subplots(rows=1, cols=2, shared_yaxes=True, horizontal_spacing=0.01,
                    subplot_titles=["<b>Based on PCT Access", "<b>Based on Enagagement Index"])

    fig.add_trace(go.Bar(x=df["pct_access"], y=df["Product Name"], 
                         text=df.pct_rank, textposition="outside",orientation="h"), row=1, col=1)
    fig.add_trace(go.Bar(x=df.engagement_index, y=df["Product Name"], 
                         text=df.engagement_rank, textposition="outside", orientation="h"), row=1, col=2)
    fig.add_annotation(x=250000000, y=3, font_size=16,
                text="<b>Number</b> over the Bars <br>depicts their <b>Overall Rank</b> in<br> Products List", 
                       row=1, col=2, showarrow=False)
    return fig

def month_map_comparison(df, name):
    
    months_map = {1:"January",2:"February",3:"March",4:"April",
              5:"May",6:"June",7:"July",8:"August",9:"September",
              10:"October",11:"November",12:"December"}
    
    temp = df.copy()
    temp["month"] = temp.time.dt.month
    temp = temp.groupby(["state","state_code","month"])[["pct_access","engagement_index"]].mean().reset_index()
    temp["Month_2020"] = temp.month.map(months_map)
    
    
    pct_min = temp.pct_access.min()
    pct_max = np.round(temp.pct_access.max(),0)
    #pct_access over the time
    fig = px.choropleth(data_frame=temp, locations="state_code", locationmode="USA-states",
                        color="pct_access", scope="usa",
                        color_continuous_scale="Portland_r", animation_frame="Month_2020", hover_name="state", \
                        range_color=[pct_min, pct_max])
    fig.update_layout(font_family="Comic Sans MS", 
                      title=dict(text="<b>PCT Access over Time - "+name, font_size=20, x=0.5))
    fig.show()

    
    eng_min = temp.engagement_index.min()
    eng_max = np.round(temp.engagement_index.max(),0)
    # Enagagement Index over the time
    fig = px.choropleth(data_frame=temp, locations="state_code", locationmode="USA-states",
                        color="engagement_index", scope="usa",
                        color_continuous_scale="Portland_r", animation_frame="Month_2020", hover_name="state",
                        range_color=[eng_min, eng_max])
    fig.update_layout(font_family="Comic Sans MS", 
                      title=dict(text="<b>Engagement Index over Time - "+name, font_size=20, x=0.5))
    fig.show()
    
def time_analysis(df, title):
    df2 = pd.Series(boxcox(df, lmbda=0), index=df.index)
    
    train = df2.iloc[:301]
    test = df2.iloc[301:]
    
    model = SARIMAX(train, order=(1,1,1), seasonal_order=(1,1,1,14), exog=holiday.iloc[:301]).fit()
    
    predictions = df.copy()
    predictions["forecast_box_cox"] = model.predict(df.index.max(), holiday.index.max(),
                                                    exog=holiday.loc[test.index.min():holiday.index.max()])
    
    predictions["forecast"] = np.exp(predictions["forecast_box_cox"])
    
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df.index, y=df.values, name="Original"))
    fig.add_trace(go.Scatter(x=predictions["forecast"].index, y=predictions["forecast"].values, name="Forecast",
                            line_color="lightblue"))
    fig.update_layout(title=dict(text=title, font_size=20, x=0.5, font_family="Comic Sans MS"),
                      margin=dict(b=20, t=50, r=0), height=400)
    fig.show()

# %% [markdown]
# <p id="E"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold">E. The DISTRICTS data</p>
# <hr style="color:#ce2029; height:0.5px">
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">The district data includes information about the characteristics of school districts that are spread across the states.</p>

# %%
# the Districts data
# /kaggle/input/learnplatform-covid19-impact-on-digital-learning/
districts = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv")
districts.head()

# %% [markdown]
# | Name | Description |
# | :--- | :----------- |
# | district_id | The unique identifier of the school district |
# | state | The state where the district resides in |
# | locale | NCES locale classification that categorizes U.S. territory into four types of areas: City, Suburban, Town, and Rural. See [Locale Boundaries User's Manual](https://eric.ed.gov/?id=ED577162) for more information. |
# | pct_black/hispanic | Percentage of students in the districts identified as Black or Hispanic based on 2018-19 NCES data |
# | pct_free/reduced | Percentage of students in the districts eligible for free or reduced-price lunch based on 2018-19 NCES data |
# | county_connections_ratio | `ratio` (residential fixed high-speed connections over 200 kbps in at least one direction/households) based on the county level data from FCC From 477 (December 2018 version). See [FCC data](https://www.fcc.gov/form-477-county-data-internet-access-services) for more information. |
# | pp_total_raw | Per-pupil total expenditure (sum of local and federal expenditure) from Edunomics Lab's National Education Resource Database on Schools (NERD$) project. The expenditure data are school-by-school, and we use the median value to represent the expenditure of a given school district. |

# %%
# Null check
print("Percentage of Nulls present in the Districts data are as follows")
districts.isnull().sum()*100/districts.shape[0]

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">There are many rows in districts database having all null values. Our aim is to determine the affect of Covid-19 on digital Learning State and District wise. Therefore, lets drop the rows having null values for State and Locale Columns.
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">After some cleaning, Its time to import some <b>other useful data</b> about the states like <b>Poverty Rate and Median Household Income.</b>
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>Median Household Income</b>

# %%
# importing household income table from below url
household_income = pd.read_html("https://fred.stlouisfed.org/release/tables?eid=259515&rid=249")[0]

# extracting useful data
household_income.columns = ["unknown","state","Income","preceding_period","year_ago_period"]    #renaming the columns
household_income.drop(["unknown","preceding_period","year_ago_period"], axis=1, inplace=True)    #removing not reuired features
household_income.replace("District of Columbia","District Of Columbia", inplace=True)
household_income.head()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>Poverty Rates</b>

# %%
# Poverty level of States - using information from wikipedia - using below url
poverty = pd.read_html("https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_poverty_rate")[1]

# Extracting useful columns from the poverty and cleaning it
poverty.columns = ["rank","state","poverty_rate","poverty_rate_2014","poverty_measure"]    #renaming the columns
poverty.drop(["rank","poverty_rate_2014","poverty_measure"], axis=1, inplace=True)        #droppimg not so reuired columns
poverty.replace("District of Columbia","District Of Columbia", inplace=True)

# cleaning the poverty percentage column
poverty.poverty_rate = poverty.poverty_rate.apply(lambda x: float(x.split("%")[0]))    #cleaning the poverty_rate column
poverty.head()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>Merging the Poverty and household income dataframes with the districts.</b>

# %%
# combining the dataframes
districts = pd.merge(districts, poverty, how="left", on="state")      # merging poverty with districts
districts = pd.merge(districts, household_income, how="left", on="state")    #merging household income with districts
districts.head()

# %% [markdown]
# <p id="E.1"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold; text-indent:25pt">E.1. Data CLEANING</p>
# <hr style="color:#ce2029; height:0.5pt">

# %%
# Data cleaning 
districts.dropna(axis=0, subset=["state"], inplace=True)

#Null check
print("Percentage of Nulls present in the Districts data after Cleaning")
districts.isnull().sum()*100/districts.shape[0]

# %%
# checking the distribution of county_connections_ratio
districts.county_connections_ratio.value_counts()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">County connections ratio is monotonoic in nature and have same value for each data point. Therefore, we will not use County connections Ratio in our Analysis. Therefore lets drop the connections columns.

# %%
# dropping connections columns
districts.drop(["county_connections_ratio"], axis=1, inplace=True)

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>Missing value treatment.</b>

# %%
#pct_free_reduced
districts[districts["pct_free/reduced"].isnull()].state.value_counts()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Students whom are eligible for free reduced lunch are based on average household incomes. Students who belong to household where income is 130% or below poverty are eligible for free lunches. On other hand Students who belong to household with income from 130% to 185% of poverty line are eligible for reduced lunched.

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 16pt; color:black"><b>For this Analysis, </b>we will assume that USA only comprises of States and districts that are present in districts data. No other State or district is part of USA apart from these.

# %%
# Average Household Income of States of USA
USA_household_income = districts.Income.mean()
USA_household_income

# %%
# Average poverty level of States of USA
USA_poverty_line = districts.poverty_rate.mean()
USA_poverty_line

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Based on above Indexes and data from NCES website we will replace the missing data with values as below:</p>
#     <ol style="font-family: Comic Sans MS; line-height:2; font-size: 12pt; color:black">
#     <li><b>Massachusetts -</b>Average household income is much greater than USA average and also poverty level is also lower. Also based on information from NCES data, the missing values can be replaced with range [0.2, 0.4[.</li>
#     <li><b>District Of Columbia -</b>Average household income is much greater than USA average but poverty level is in range of USA's average. Based on this and information from NCES , we will impute the missing data with [0.6, 0.8[.</li>
#     <li><b>Arizona -</b>Household income and poverty level are in range of USA average, therefore replacing missing with range [0.4, 0.6[.</li>
#     <li><b>Tennessee -</b>Household income and poverty level are in range of USA average, therefore replacing missing with range [0.4, 0.6[.</li>
#     <li><b>Ohio -</b>Household income and poverty level are in range of USA average, therefore replacing missing with range [0.4, 0.6[.</li>

# %%
# imputing missing values in State column
districts.loc[districts.state=="Massachusetts", "pct_free/reduced"] = districts.loc[districts.state=="Massachusetts", "pct_free/reduced"].fillna("[0.2, 0.4[")
districts.loc[districts.state=="District Of Columbia", "pct_free/reduced"] = districts.loc[districts.state=="District Of Columbia", "pct_free/reduced"].fillna("[0.6, 0.8[")
districts.loc[districts.state=="Arizona", "pct_free/reduced"] = districts.loc[districts.state=="Arizona", "pct_free/reduced"].fillna("[0.4, 0.6[")
districts.loc[districts.state=="Tennessee", "pct_free/reduced"] = districts.loc[districts.state=="Tennessee", "pct_free/reduced"].fillna("[0.4, 0.6[")
districts.loc[districts.state=="Ohio", "pct_free/reduced"] = districts.loc[districts.state=="Ohio", "pct_free/reduced"].fillna("[0.4, 0.6[")

# %%
# expenditure per pupil
districts[districts["pp_total_raw"].isnull()].state.value_counts()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Based on the data from internet, we will impute the missing values for the expenditure per pupil as below. <br>Source: https://worldpopulationreview.com/state-rankings/per-pupil-spending-by-state

# %%
# imputing missing values in State column
districts.loc[districts.state=="Connecticut", "pp_total_raw"] = districts.loc[districts.state=="Connecticut", "pp_total_raw"].fillna("[20000, 22000[")
districts.loc[districts.state=="California", "pp_total_raw"] = districts.loc[districts.state=="California", "pp_total_raw"].fillna("[12000, 14000[")
districts.loc[districts.state=="Ohio", "pp_total_raw"] = districts.loc[districts.state=="Ohio", "pp_total_raw"].fillna("[12000, 14000[")
districts.loc[districts.state=="New Hampshire", "pp_total_raw"] = districts.loc[districts.state=="New Hampshire", "pp_total_raw"].fillna("[16000, 18000[")
districts.loc[districts.state=="New York", "pp_total_raw"] = districts.loc[districts.state=="New York", "pp_total_raw"].fillna("[24000, 26000[")
districts.loc[districts.state=="North Dakota", "pp_total_raw"] = districts.loc[districts.state=="North Dakota", "pp_total_raw"].fillna("[12000, 14000[")
districts.loc[districts.state=="Arizona", "pp_total_raw"] = districts.loc[districts.state=="Arizona", "pp_total_raw"].fillna("[8000, 10000[")

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">We have seen that Columns like pct_black/hispanic, pp_total_raw etc. are present in range format for which interpretation is difficult. Therefore, lets make new columns with considering the average value of these ranges.

# %%
# function for extracting the average of the values from the ranges
def avg_ranges(x):
    return np.array(str(x).strip("[").split(",")).astype(float).mean()

# Creating the averages for all ranges columns
districts['avg_black_hispanic'] = districts['pct_black/hispanic'].apply(avg_ranges)
districts['avg_reduced_lunch'] = districts['pct_free/reduced'].apply(avg_ranges)
districts['avg_spent_per_pupil'] = districts['pp_total_raw'].apply(avg_ranges)


# dropping the range columns
districts.drop(["pct_black/hispanic",'pct_free/reduced','pp_total_raw'], axis=1, inplace=True)
districts.head()

# %%
#Final Null check
print("Percentage of Nulls present in the Districts data after Cleaning")
districts.isnull().sum()*100/districts.shape[0]

# %% [markdown]
# <p id="E.2"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold; text-indent:25pt">E.2. Exploratory Data Analysis</p>
# <hr style="color:#ce2029; height:0.5pt">

# %%
# Number of Districts per State
fig = count_plot(districts, ["state"])
fig.update_layout(title=dict(text="<b>Count of Districts per State</b>", x=0.5, font_size=20))
fig.show()

# %%
# Locale Distribution
fig = pie_plot(districts, "locale")
fig.update_layout(title=dict(text="<b>Locale Distribution", font_size=20, x=0.5))
fig.show()

# %%
# Temporary Dataframe for Checking the Distribution of Locale in every State
temp = pd.crosstab(districts.state, districts.locale)
temp["summation"] = temp.sum(axis=1)
temp["city_percent"] = temp.City*100/temp.summation
temp["rural_percent"] = temp.Rural*100/temp.summation
temp["suburb_percent"] = temp.Suburb*100/temp.summation
temp["town_percent"] = temp.Town*100/temp.summation

# State and locale Distribution Plot
fig = go.Figure()
fig.add_trace(go.Bar(x=temp.index, y=temp.city_percent, name="Percentage City"))
fig.add_trace(go.Bar(x=temp.index, y=temp.rural_percent, name="Percentage Rural"))
fig.add_trace(go.Bar(x=temp.index, y=temp.suburb_percent, name="Percentage Suburb"))
fig.add_trace(go.Bar(x=temp.index, y=temp.town_percent, name="Percentage Town"))

# fig.update_traces(texttemplate='%{text:.2s}')
fig.update_xaxes(tickfont_size=16, tickangle=270)
fig.update_layout(font_family="Comic Sans MS", title=dict(text="<b>Locale Distribution per State", font_size=20, x=0.5),
                  barmode='stack', height=600,
                  legend=dict(orientation="h",
                              yanchor="bottom",
                              y=1.02,xanchor="right",
                              x=1
                ))
fig.show()
del temp

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Observations about Districts data:-
# <ol style="font-family: Comic Sans MS; line-height:2; font-size: 12pt; color:black">
#     <li>Most Districts belong to Connecticut followed by Utah and Massachusetts.
#     <li>Most of Data is about the suburb locale.
#     <li>Florida, Michigan, Minnesota, New Jersey and Wisconsin have 100% suburbs coverage.
#     <li>On other hand Arizona, District of Columbia have 100% of the data about City.
#     <li>lastly, New Hamsphire and North Dakota have Rural coverage only.

# %%
# BLack/Hispanic, Free/Reduced Lunch and Expenditure per Pupil Distributions
cols = ["avg_black_hispanic","avg_reduced_lunch","avg_spent_per_pupil"]

temp = districts.groupby("locale")[cols].mean().reset_index() 

fig = bar_plot(temp, ["locale"], cols)
fig.update_layout(title=dict(text="<b>Distributions over Locale</b>", x=0.5, font_size=20))
fig.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">On an Average, Black/hispanic people are mostly present in Cities, also Students whom are eligible for free/reduced lunch are maximum in cities. Count of Black/hispanic and Students whom are eligible for free/reduced luch might have some correlation.<br>On other hand Government is spending the mostly in Rural Areas, for development of students in Rural areas.<br><br>Now lets group the Districts dataframe based on State to compute the averages of black/hispanic percentage, expediture on Pupil and percentage eligible for free/reduced lunch

# %%
# Gropued Data for States
grouped_districts = districts.groupby(by=["state"])[['avg_black_hispanic','avg_reduced_lunch','avg_spent_per_pupil',
                                                    "poverty_rate","Income"]].mean()

# Cretaing Variables for computing Averages across various States
grouped_districts["above_avg_hispanic"] = grouped_districts.avg_black_hispanic.apply(lambda x: 1 if x>grouped_districts.avg_black_hispanic.mean() else 0)
grouped_districts["above_avg_lunch"] = grouped_districts.avg_reduced_lunch.apply(lambda x: 1 if x>grouped_districts.avg_reduced_lunch.mean() else 0)
grouped_districts["above_avg_pupil"] = grouped_districts.avg_spent_per_pupil.apply(lambda x: 1 if x>grouped_districts.avg_spent_per_pupil.mean() else 0)
grouped_districts["above_poverty_line"] = grouped_districts.poverty_rate.apply(lambda x: 1 if x>grouped_districts.poverty_rate.mean() else 0)
grouped_districts["above_household_income"] = grouped_districts.Income.apply(lambda x: 1 if x>grouped_districts.Income.mean() else 0)

grouped_districts.head()

# %%
fig = make_subplots(rows=5,cols=1, shared_xaxes=True, vertical_spacing=0.07,
                   subplot_titles=["<b>Black/Hispanic Distribution acroess various States",
                                   "<b>Students Eligible for Free/Reduced lunch in States",
                                  "<b>Expenditure per Person by States",
                                  "<b>Poverty Measure of States","<b>Median Household Income across States"])

cols = ["avg_black_hispanic","avg_reduced_lunch","avg_spent_per_pupil", "poverty_rate","Income"]
cols1 = ["above_avg_hispanic", "above_avg_lunch","above_avg_pupil","above_poverty_line","above_household_income"]

for i in range(len(cols)):
    fig.add_trace(go.Bar(x=grouped_districts.index, y=grouped_districts[cols[i]],
                        marker_color=grouped_districts[cols1[i]], marker_colorscale="Rdbu", 
                        text=grouped_districts[cols[i]], textposition="auto"), row=i+1, col=1)
    fig.add_hline(grouped_districts[cols[i]].mean(), line_dash="dot",
                annotation =dict(text="USA "+cols[i]+" = "+str(round(grouped_districts[cols[i]].mean(),2)), 
                                font_size=16, font_color="orange"), row=i+1, col=1)
    
fig.update_layout(title=dict(text="<b>Demographic Details of the States</b>", x=0.5, font_size=20),
                  font_family="Comic Sans MS",showlegend=False, height=1400, margin=dict(t=100, b=100))
fig.update_xaxes(tickangle=270, tickfont_size=14)
fig.update_traces(texttemplate='%{value:.1f}')
fig.show()

# %%
# Correlation between various Indexes
plt.figure(figsize=(10,8))
sns.heatmap(districts.corr(), annot=True, cmap="viridis_r")
plt.xticks(size=12, rotation=45)
plt.yticks(size=12, rotation=45)
plt.title("Corrleation between Districts Data", size=20)
plt.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">There are some quite clear correlations like Average Income of House hold has inverse relation with Poverty Percentage. Poverty among people are increasing with with lower household incomes.<br> Black/Hispanic and Free/Reduced Lunch are also having large direct Correlation.

# %%
# State Abbreviations
us_state_abbrev = {
    'Alabama': 'AL','Alaska': 'AK','American Samoa': 'AS','Arizona': 'AZ','Arkansas': 'AR','California': 'CA',
    'Colorado': 'CO','Connecticut': 'CT','Delaware': 'DE','District Of Columbia': 'DC','Florida': 'FL','Georgia': 'GA',
    'Guam': 'GU','Hawaii': 'HI','Idaho': 'ID','Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS','Kentucky': 'KY',
    'Louisiana': 'LA','Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN',
    'Mississippi': 'MS','Missouri': 'MO','Montana': 'MT','Nebraska': 'NE','Nevada': 'NV','New Hampshire': 'NH',
    'New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC','North Dakota': 'ND',
    'Northern Mariana Islands':'MP','Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR','Pennsylvania': 'PA','Puerto Rico': 'PR',
    'Rhode Island': 'RI','South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX','Utah': 'UT',
    'Vermont': 'VT','Virgin Islands': 'VI','Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI',
    'Wyoming': 'WY'
}
districts["state_code"] = districts.state.map(us_state_abbrev)
grouped_districts = grouped_districts.reset_index()
grouped_districts["state_abv"] = grouped_districts.state.map(us_state_abbrev)

# %%
# States poverty level comparison
fig = map_plot(grouped_districts, "state_abv", "above_poverty_line", "state")
fig.update_layout(title=dict(text="<b>Comparison of State's Poverty levels", font_size=20, x=0.5))
fig.show()

# %% [markdown]
# <p id="F"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold">F. The PRODUCTS data</p>
# <hr style="color:#ce2029; height:0.5px">
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">The product file includes information about the characteristics of the top 372 products with most users in 2020. The categories listed in this file are part of LearnPlatform's product taxonomy.

# %%
# the products dataframe
# /kaggle/input/learnplatform-covid19-impact-on-digital-learning/
products = pd.read_csv("/kaggle/input/learnplatform-covid19-impact-on-digital-learning/products_info.csv")
products.head()

# %% [markdown]
# | Name | Description |
# | :--- | :----------- |
# | LP ID| The unique identifier of the product |
# | URL | Web Link to the specific product |
# | Product Name | Name of the specific product |
# | Provider/Company Name | Name of the product provider |
# | Sector(s) | Sector of education where the product is used |
# | Primary Essential Function | The basic function of the product. There are two layers of labels here. Products are first labeled as one of these three categories: LC = Learning & Curriculum, CM = Classroom Management, and SDO = School & District Operations. Each of these categories have multiple sub-categories with which the products were labeled |

# %%
# Lets check the products info
products.info()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Observations:-
# <ol style="font-family: Comic Sans MS; line-height:2; font-size: 12pt; color:black">
#     <li>Sectors have 20 missing values and their corresponding Primary Essential Function is also null. There is a relation between null values of Sectors and Primary Essential Function. So lets keep the null values as it is.
#     <li>Around 10% of data values are missing for Sector and Primary Essential function. Only 1 is missing for Provider.
#     <li>Lets bifurcate the Primary Essential Function column.

# %%
# Function for creating Sub_Category feature
def sub_category(x):
    a = str(x).split("-")
    if len(a)<2:
        return x
    else:
        return "-".join(a[1:])

# biufurcating the Primary Essential Column into Category and Sub_Category
products["Category"] = products["Primary Essential Function"].apply(lambda x: str(x).split("-")[0])
products["Sub_Category"] = products["Primary Essential Function"].apply(sub_category)

# Segrregating the Sub-Categories
products["Sub_Category"] = products["Sub_Category"].apply(lambda x: str(x).split("-")[0])

# Replacing the string type nan values in Category and Sub-Category columns with np.nan 
products[["Category","Sub_Category"]] = products[["Category","Sub_Category"]].replace("nan",np.nan)
products.head()

# %% [markdown]
# <p id="F.1"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5;font-weight:bold; text-indent:25pt">F.1. Exploratory Data Analysis</h3>
# <hr style="color:#ce2029; height:0.5px">

# %%
# Product Sector Wise Distribution
fig = pie_plot(products, ["Sector(s)"])
fig.update_layout(title=dict(text="<b>Sector wise Products Distribution", x=0.5, font_size=20))
fig.show()

# %%
# Category wise Product Distribution
fig = pie_plot(products, ["Category"])
fig.update_layout(title=dict(text="<b>Category wise Products Distribution", x=0.5, font_size=20))
fig.show()

# %%
# Cleaning the Sub_Category
products.Sub_Category = products.Sub_Category.replace([" Sites, Resources & Reference ",
                                                               " Sites, Resources & Reference",
                                                               " Sites, Resources & References "], 
                                                                  "Sites, Resources & References")
products.Sub_Category = products.Sub_Category.replace([" Data, Analytics & Reporting ",
                                                               " Data, Analytics & Reporting"], 
                                                                  "Data, Analytics & Reporting")
products.Sub_Category = products.Sub_Category.replace([" Study Tools "," Study Tools"], 
                                                                  "Study Tools")

# Plotting Sub_Category
fig = count_plot(products, ["Sub_Category"])
fig.update_layout(title=dict(text="<b>Distribution of Products among Sub Categories", x=0.5, font_size=20))
fig.show()

# %%
# temporary dataframe
temp = products.groupby(["Category", "Sub_Category"]).size().reset_index()
temp.columns = ["Category", "Sub_Category", "Counts"]

#plot for Distribution of Category and Seg_Sub_Catgroy
fig = path_plot(temp, ["Category", "Sub_Category"], "Counts", "treemap")
fig.update_layout(title=dict(text="<b>Distribution of Sub Category among Categories", x=0.5, font_size=20))
fig.show()

# %%
# temporary dataframe
temp = products.groupby(["Sector(s)", "Category"])["URL"].count().reset_index()
temp.columns = ["Sector", "Category", "Counts"]

#plot for Distribution of Category and Seg_Sub_Catgroy
fig = path_plot(temp, ["Sector", "Category"], "Counts", "sunburst")
fig.update_layout(title=dict(text="<b>Distribution of Categories among various Sectors", x=0.5, font_size=20))
fig.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Observations:-
# <ol style="font-family: Comic Sans MS; line-height:2; font-size: 12pt; color:black">
#     <li>Major Products belong to Corporate Sector followed by prek12; higher edu; corporate sector.
#     <li>Similarly Most of the products belong to Learning and Curriculum Category.
#     <li>Sites, Rsources and References have highest number of products when we look at the Segregated Sub Category.

# %% [markdown]
# <p id="G"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>G. The ENGAGEMENT data</b></p>
# <hr style="color:#ce2029; height:0.5px">
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">The engagement data are aggregated at school district level and each file of `engagement_data` represents data from one school district. The 4-digit file name represents `district_id`.

# %%
# /kaggle/input/learnplatform-covid19-impact-on-digital-learning/
# the Engagement Dataframe
path = r"/kaggle/input/learnplatform-covid19-impact-on-digital-learning/engagement_data"
filenames = glob.glob(path+"/*.csv")

engagement = pd.DataFrame()
for file in filenames:
    b = pd.read_csv(file)
    b["district_id"] = int(file.split("/")[-1].split(".")[0])
    engagement = pd.concat([engagement,b])

engagement.reset_index(drop=True)
engagement.head()

# %% [markdown]
# | Name | Description |
# | :--- | :----------- |
# | time | date in "YYYY-MM-DD" |
# | lp_id | The unique identifier of the product |
# | pct_access | Percentage of students in the district have at least one page-load event of a given product and on a given day |
# | engagement_index | Total page-load events per one thousand students of a given product and on a given day |

# %%
# percenatteg of Null values in Engagement Data
engagement.isnull().sum()*100/engagement.shape[0]

# %%
# correcting the dtype of time variable in engagement dataframe
engagement.time = pd.to_datetime(engagement.time)
engagement.info()

# %% [markdown]
# <p id="G.1"></p>
# <p style="font-family: Comic Sans MS; text-indent: 25pt;font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>G.1 Data Cleaning</b></p>
# <hr style="color:#ce2029; height:0.5px">

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Replacing the missing values in engagement_index and pct_access with 0.

# %%
# cleaning missing values
engagement.engagement_index.fillna(0, inplace=True)
engagement.pct_access.fillna(0, inplace=True)
engagement.isnull().sum()*100/engagement.shape[0]

# %% [markdown]
# <p id="G.2"></p>
# <p style="font-family: Comic Sans MS; text-indent: 25pt;font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>G.2 Exploratory Data Analysis</b></p>
# <hr style="color:#ce2029; height:0.5px">

# %%
# temp dataframe for computing enagement index and pct_access across all USA.
temp = engagement.groupby("time")[["engagement_index","pct_access"]].mean().reset_index()

# Plot showing overall enegamenet index and pct _access
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.1, 
                    subplot_titles=["<b>% Atleast 1 page Load Event <br> ", "<b>Page Loads per 1000 Students <br> "])

fig.add_trace(go.Scatter(x=temp.time, y=temp.pct_access), row=1, col=1)
fig.add_trace(go.Scatter(x=temp.time, y=temp.engagement_index), row=2, col=1)
fig.add_vrect(x0="2020-05-20", x1="2020-08-30",
              fillcolor="yellow", opacity=0.2, line_width=0)
fig.add_vrect(x0="2020-03-19", x1="2020-04-07",
              fillcolor="red", opacity=0.2, line_width=0)
fig.add_vline(x="2020-01-21", line_dash="dot")
fig.add_vline(x="2020-02-03", line_dash="dot")
fig.add_vline(x="2020-07-16", line_dash="dot")


fig.add_annotation(x="2020-01-21", y=150, text="First Case in USA<br>dated 2020-01-21", 
                   ax=-40, ay=-50, row=2, col=1, arrowsize=2, arrowhead=2)
fig.add_annotation(x="2020-06-25", y=0.6, text="Summer Break", row=1, col=1, showarrow=False, font_color="orange")
fig.add_annotation(x="2020-06-25", y=200, text="Summer Break", row=2, col=1, showarrow=False, font_color="orange")
fig.add_annotation(x="2020-03-30", y=230, row=2, col=1, showarrow=False, font_color="red",
                   text="Start of Lockdowns<br>in USA <br>from 2020-03-19 to 2020-04-07")
fig.add_annotation(x="2020-02-03", y=0.8, text="Public Health Emergency <br>Declared in USA<br> dated 2020-02-03", 
                   ax=80, ay=-40, row=1, col=1, arrowsize=2, arrowhead=2)
fig.add_annotation(x="2020-07-16", y=0.8, text="New Record of Daily Cases - 76,000<br>in USA dated 2020-07-16", 
                   ax=130, ay=-30, row=1, col=1, arrowsize=2, arrowhead=2)

fig.update_layout(font_family="Comic Sans MS", showlegend=False, margin=dict(l=0, r=0, t=50), height=700)
fig.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">End of year 2019 covid was spread across the Globle. Many countries start seeing its affect. USA among other countries start seeing the affects of Covid-19.<br> USA saw its first case on 2020-01-21 in which a Washington resident was diagnosed as covid positive. <br>National health Emergency was declared in USA on 2020-02-03 which made public aware of the virus and its affects.<br> After seeing the affects of Covid-19, states of USA start imposing lockdowns. California was the first to impose lockdown starting from 2020-03-19 and South Carolina was last which imposed lockdown starting from 2020-04-07.<br> It can be seen from above that overall engagement index of USA starts rising after public health emergency was declared in USA. Students started shifting towards the Digital Platforms. During the Summer break both Engagement Index and pct_access saw its major decline. After summer break was over. USA saw its peek in cases during this period. Cases rise to approx 76,000 daily cases. This led to more and more students and schools shiting towards the Digital Platforms for learning only. Many Online platforms gained popularity during this period.

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Lets look at the time series information about pct_access and enagememt_index

# %%
# time series breakdown for pct_access
rcParams['figure.figsize'] = 16,10

temp = engagement.groupby("time")[["engagement_index","pct_access"]].mean()

decomposition = sm.tsa.seasonal_decompose(temp.pct_access, model="additive")
fig = decomposition.plot()
plt.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Our Data clearly has seasonal/weekly patterns. Weekends seeing the huge drops in pct_access as well as enagement_index. Although, the trend showing decline when there are holidays it showing tendency to move up towards the year progresses.

# %%
# extracting week of the year from time
engagement["week"] = pd.to_datetime(engagement.time).dt.weekofyear

# extracting day of week from time
engagement["day_of_week"] = pd.to_datetime(engagement.time).dt.dayofweek

# %%
# analysing the affect of day of the week on engagement_index and pct_access 
temp = engagement.groupby("day_of_week")[["engagement_index","pct_access"]].mean().reset_index()

# visulaizing the affect of day of the week on engagement_index and pct_access 
fig = bar_plot(temp, ["day_of_week"], ["engagement_index","pct_access"])
fig.update_layout(title=dict(text="<b>Day of the WEEK affect</b>", x=0.5, font_size=20))
fig.show()

# %% [markdown]
# <p id="H"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>H. The MERGED data</b></p>
# <hr style="color:#ce2029; height:0.5px">

# %% [markdown]
# <p style="font-family: Comic Sans Ms; line-height:2; font-size: 14pt; color:black">Covid-19 has led to students and corporates shifting from Offline Classrooms to Digital Learning. <br>
# Although offline Classrooms have their advantages like student interactivity extracurricular activities, interaction with teachers etc. On other hand Digital Learning has its own advantages like 24/7 access to learning, wide range of Learning platforms and students can choose their own teachers whom they are comfortable with.
# <br><br>
# By combining the data frames, we will compare the impact of covid-19 on various Digital Platforms for various providers across various categories for the Year 2020.
# <br>
# Covid was its peak in the year 2020 and claimed many lives, affected many businesses as well as learning of the students. To prevent loss of lives we made more hospitals, made vaccines. For affected businesses, new business plans were introduced. For Students Digital Learning Platforms gained popularity<br><br>
# Now we will look at some of the aspects on Digital Learning. Digital Learning has seen its major boom during the Covid period when students explored various Digital learning platforms across various categories like online classrooms, digital learning platforms, study tools materials etc.

# %%
# Combining all the Dataframes
df = pd.merge(engagement,districts, on="district_id", how="inner")
df = pd.merge(df,products, left_on="lp_id", right_on="LP ID", how="inner")
df.head()

# %% [markdown]
# <p style="font-family: Comic Sans Ms; line-height:2; font-size: 14pt; color:black">Now lets Start Analysing the effect of Covid of Page Load events and Number of Page Loads from Broader aspects like Locale and then we will narrow down the aspects to States, Sectors, Category and Products.

# %% [markdown]
# <p id="I"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>I. States and Locale - Analysis</b></p>
# <hr style="color:#ce2029; height:0.5px">

# %%
# temporary dataframe
temp = df.groupby(["locale","week"])[["pct_access","engagement_index"]].mean().reset_index()

# time plot for pct_access and engagement_index locale wise
time_plot(temp, "locale","All")

# %% [markdown]
# <p style="font-family: Comic Sans Ms; line-height:2; font-size: 14pt; color:black">Comparison of States performance vs USA's average performance.

# %%
# temp dataframe for comparing States pct_access and engagement index
# temp = df.groupby(["state","state_code","week"])[["pct_access", "engagement_index"]].mean().reset_index()
# cols = temp.state.value_counts().index.tolist()

# fig, ax = plt.subplots(len(cols),2,figsize=(16,70))

# for i in range(len(cols)):
    
#     # pct_access plots
#     sns.lineplot(ax=ax[i,0], data = temp.groupby("week")[["pct_access"]].mean(), x="week", y="pct_access", 
#                  color="lightgray", label="USA Average")
#     sns.lineplot(ax=ax[i,0], data=temp[temp.state==cols[i]], x="week", y="pct_access", 
#                  label=cols[i]+"'s Average", color="orange")
#     ax[i,0].set_xlabel(None)
#     ax[i,0].set_ylabel(None)
#     ax[i,0].set_title(cols[i]+"-Pct access")
#     ax[i,0].legend(fontsize=12)
    
    
#     # Engagement Index plots
#     sns.lineplot(ax=ax[i,1], data = temp.groupby("week")[["engagement_index"]].mean(), x="week", y="engagement_index", 
#                  color="lightgray", label="USA Average")
#     sns.lineplot(ax=ax[i,1], data=temp[temp.state==cols[i]], x="week", y="engagement_index", 
#                  label=cols[i]+"'s Average", color="orange")
#     ax[i,1].set_xlabel(None)
#     ax[i,1].set_ylabel(None)
#     ax[i,1].set_title(cols[i]+"-Engagement index")
#     ax[i,1].legend(fontsize=12)

# plt.show()

# %%
#State wise affect of Covid on Page Load events - best performing states
temp = df.groupby(["state","week"])[["pct_access","engagement_index"]].mean().reset_index()
temp = temp[~temp.state.isin(["Minnesota","North Dakota"])]           # data is not complete for these states

top_10_states = temp.groupby(["state"])["engagement_index"].sum().reset_index().sort_values("engagement_index",ascending=False).head(10).state.values

temp = temp[temp.state.isin(top_10_states)]

time_plot(temp, "state", "Top 10")

# %%
#State wise affect of Covid on Page Load events - least performing states
temp = df.groupby(["state","week"])[["pct_access","engagement_index"]].mean().reset_index()
temp = temp[~temp.state.isin(["Minnesota","North Dakota"])]           # data is not complete for these states

bottom_10_states = temp.groupby(["state"])["engagement_index"].sum().reset_index().sort_values("engagement_index").head(10).state.values

temp = temp[temp.state.isin(bottom_10_states)]

time_plot(temp, "state" , "Bottom 10")

# %%
# Page Load events and 100 Page loads for all products across the States
temp = df.groupby(["state","state_code","time"])[["pct_access", "engagement_index"]].mean().reset_index()

# comaring states performance on monthly basis
month_map_comparison(temp, "In Total")

# %% [markdown]
# <p id="J"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>J. Products - Analysis</b></p>
# <hr style="color:#ce2029; height:0.5px">

# %%
# temporary dataframe 
temp = df.groupby(["Category","week"])[["pct_access","engagement_index"]].mean().reset_index()

# pct_access and engagement_index over time among different category of products
time_plot(temp,"Category", "All")

# %%
# temporary dataframe 
temp = df.groupby(["Sector(s)","week"])[["pct_access","engagement_index"]].mean().reset_index()

# pct_access and engagement_index over time among different Sectors products present in
time_plot(temp,"Sector(s)","All")

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">State wise pct_access and engagement_index observations:-
# <ol style="font-family: Comic Sans MS; line-height:2; font-size: 12pt; color:black">
#     <li>School and District Operations are having most number of page load events per day. Their enagagment in also much higher than other Categories.</li>
#     <li>On Other hand Learning and Curriculum have the least page load events. </li>
#     <li>Prek-12 followed by Corporate are showing high Engagement Levels. </li>
# </ol>
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Lets first have a look at the top products and rank them based on their average pct_access and average engagement_index.</p>

# %%
# Products with the ranks
ranked_products = df.groupby(["Product Name","Category"])[["pct_access", "engagement_index"]].sum().reset_index()
ranked_products["pct_rank"] = ranked_products.pct_access.rank(ascending=False, method="max")
ranked_products["engagement_rank"] = ranked_products.engagement_index.rank(ascending=False, method="max")
ranked_products.head()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Although Learning Curriculum (LC) catgeory have most number of products but School and District Operations (SDO) being a popular Category have large Page load events. Lets have look at the products in the SDO catgeory.

# %%
# Top SDO Products and their overall Rank
SDO_products = ranked_products[ranked_products.Category=="SDO "].sort_values("pct_access").tail(10)

fig = comparison_bar_plot(SDO_products)

fig.update_layout(title=dict(text="<b>TOP 10 School and District Operations(SDO) Products", font_size=20, x=0.55), 
                      font_family="Comic Sans MS",font_size=14,height=400,
                      showlegend=False, margin=dict(t=80,l=0, r=0, b=50))
fig.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Now lets have a look at the top products of <b>Learning Curriculum</b> Category as it has very large number of Products to offer.

# %%
# Top LC Products and their overall Rank
LC_products = ranked_products[ranked_products.Category=="LC "].sort_values("pct_access").tail(10)

fig = comparison_bar_plot(LC_products)

fig.update_layout(title=dict(text="<b>TOP 10 Learning Curriculum(LC) Products", font_size=20, x=0.55), 
                      font_family="Comic Sans MS",font_size=14,height=400,
                      showlegend=False, margin=dict(t=80,l=0, r=0, b=50))
fig.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>Google Classroom</b> is the most poplar product for SDO category. Schools prefered to teach their children on Google Classroom in lockdowns. <b>ClassLink, Clever and Google Sites</b> are also among top products. <br>On other Hand, Google Docs is the most popular product under Learning Curriculum category. Students like to share their notes or study material over google docs. Youtube,  and Canvas are also popular among LC category. Youtube providing lots of video material for free to students.
#
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Lastly we have another Category called <b>Classroom Management(CM)</b>. Lets look at the top products in CM category and their standing in overall products list.

# %%
# Top CM Products and their overall Rank
CM_products = ranked_products[ranked_products.Category=="CM "].sort_values("pct_access").tail(10)

fig = comparison_bar_plot(CM_products)

fig.update_layout(title=dict(text="<b>TOP 10 Classroom Management(CM) Products", font_size=20, x=0.55), 
                      font_family="Comic Sans MS",font_size=14,height=400,
                      showlegend=False, margin=dict(t=80,l=0, r=0, b=50))
fig.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">From above its clear that Google products are performing the best and are among most popular proucts among students. It time to analyse the the Page load events and 100 Page loads for the best performing products and not so good performing products.

# %%
# Top 10 Products
top_10_products = ranked_products.sort_values("engagement_rank").head(10)["Product Name"].values

temp = df[df["Product Name"].isin(top_10_products)]
temp = temp.groupby(["Product Name","week"])[["pct_access","engagement_index"]].mean().reset_index()

time_plot(temp, "Product Name", "Top 10 Products")

# %%
# Bottom 10 Products
bottom_10_products = ranked_products.sort_values("engagement_rank").tail(10)["Product Name"].values

temp = df[df["Product Name"].isin(bottom_10_products)]
temp = temp.groupby(["Product Name","week"])[["pct_access","engagement_index"]].mean().reset_index()

time_plot(temp, "Product Name", "Bottom 10 Products")

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">The Top products except YouTube are following the same patterns as of States Engagement level and Pct Access also same as Locale. On ther hand the bottom products are just following a random pattern. This shows that Top Products Contributes much towards the State's and Local's Engagement and Pct levels. <br><br>Google Products among the Top products. it time to analyse their affect on States and how its increasing and decreasing with time.

# %% [markdown]
# <p id="K"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>K. Products in States - Analysis</b></p>
# <hr style="color:#ce2029; height:0.5px">

# %%
# Google Docs Page Load events across the year in various States
product_name = "Google Docs"
temp = df[df["Product Name"] == product_name]
temp = temp.groupby(["state","state_code","time"])[["pct_access","engagement_index"]].sum().reset_index()

month_map_comparison(temp, product_name)

# %%
# Google Classrooms Page Load events across the year in various States
product_name = "Google Classroom"
temp = df[df["Product Name"] == product_name]
temp = temp.groupby(["state","state_code","time"])[["pct_access","engagement_index"]].sum().reset_index()

month_map_comparison(temp, product_name)

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">YouTube is among the top products which is showing a different trend. lets Analyse its affect in Different States month wise.

# %%
# YouTube Page Load events across the year in various States
product_name = "YouTube"
temp = df[df["Product Name"] == product_name]
temp = temp.groupby(["state","state_code","time"])[["pct_access","engagement_index"]].sum().reset_index()

month_map_comparison(temp, product_name)

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Till Now we have seen the Top performing States as well Low performing States, Popular Products amomg Students and Corporates. We have also seen the Poverty levels as well Income of States. <br><br>Now its time to answer few questions.

# %% [markdown]
# <p id="L"></p>
# <p style="font-family: Comic Sans MS; font-size: 18pt; text-align: left; color:#ce2029; line-height: 0.5"><b>L. Looking at some Aspects</b></p>
# <hr style="color:#ce2029; height:0.5px">

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>What is the Picture of Digital Connectivity and Engagement in 2020.</b><br>
# As per the Data all districts of the states were showing same Connection Speeds in the range of 0.18 to 1 except for Rural Area of North Dakota which are having connections in the range of 1 to 2. Cleary here, Connections cannot be a criteria to decide the Page load events of students for districts. However, lets verify this lets compare the pct_access and engagement_index of North Dakota with Country average.

# %%
temp = df.groupby(["week"])[["pct_access","engagement_index"]].mean().reset_index()
temp2 = df[df.state=="North Dakota"].groupby(["state","week"])[["pct_access","engagement_index"]].mean().reset_index()


for i in ["pct_access","engagement_index"]:
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=temp.week, y=temp[i], name="USA Average", mode='lines'))
    fig.add_trace(go.Scatter(x=temp2.week, y=temp2[i], name="North Dakota", mode='lines'))
    fig.update_layout(height=250, margin=dict(b=0, r=0, t=50), 
                      title=dict(text="North Dakota vs USA - "+i, x=0.5, font_size=20, font_family="Comic Sans MS"))
    fig.show()

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Ohh.., It can be observed that Connections Ratio plays an important role in districts Page Load Events. Districts of All other states are having same connections_ratio in range of 0.18-1. So as suggestion, connection ratio of these states can be improved to encourage students to shift more towards digital platforms in the covid era. Although data for North Dakota is not available after Public Health Emergency was declared in USA, but North Dakota is performing at par in comarison with other states. <br>'Arizona', 'New York', 'New Hampshire', 'District Of Columbia', 'Connecticut', 'Illinois', 'Wisconsin', 'Indiana', 'Massachusetts' and 'Ohio' are observed to be best performing states.<br><br>Now lets look at another question.

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>What is the effect of the COVID-19 pandemic on online and distance learning, and how might this also evolve in the future?</b><br>
# For answering this question, Lets import some Covid Data

# %%
# # # USA's covid data
# covid_data = pd.read_csv("us-states -covid cases.csv")
# covid_data.drop(["fips"], axis=1, inplace=True)
# covid_data.date = pd.to_datetime(covid_data.date, format="%Y-%m-%d")   # correcting the datetime format
# covid_data.state = covid_data.state.replace("District of Columbia", "District Of Columbia")
# covid_data = covid_data.groupby(["state","date"])[["cases","deaths"]].mean().reset_index()

# # Final Covid Data dataframe
# covid_final = pd.DataFrame(columns=["state","date","cases","deaths","daily_cases","daily_deaths"]) 
# for s in df.state.value_counts().index:
#     temp = covid_data[covid_data.state==s]
#     temp["daily_cases"] = temp.cases-temp.cases.shift()
#     temp["daily_deaths"] = temp.deaths-temp.deaths.shift()
#     covid_final = pd.concat([covid_final, temp], axis=0)

# covid_final.drop(["cases","deaths"], axis=1, inplace=True)    
# covid_final.head()

# %%
engagement = df.groupby("time")["engagement_index"].mean()

# creating a dataframe for holidays in schools 
holiday = pd.DataFrame(columns=["Date"])
holiday.Date = engagement.index

for i in range(366, 366+181):
    holiday.loc[i] = holiday.loc[i-1,]+timedelta(days=1)
    
holiday["holiday"] = holiday.Date.apply(lambda x: 1 if (x>dt.datetime(2021,6,20) and x<dt.datetime(2021,8,10)) 
                                        or (x>dt.datetime(2020,6,20) and x<dt.datetime(2020,8,9))
                                        or (x.month==12 and x.day>24) 
                                        or (x.month==1 and x.day<2) 
                                        or (x>dt.datetime(2020,11,26) and x<dt.datetime(2020,11,28)) else 0)
holiday = holiday.set_index("Date")

# %%
# Engagement_index Forecast taking the clustered holidays into account for All States and Locale
time_analysis(engagement, "1000 page Load Events - Forecast")

# %%
# Pct_access Forecast taking the clustered holidays into account for All States and Locale
pct = df.groupby("time")["pct_access"].mean()
time_analysis(pct, "% for Atleast 1 page Load - Forecast")

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:red"><b>CAUTION: </b>The function used above for forecastings is only tuned for Overall Engagement_Index only. Therfore, forecast for pct_access or % for Atleast 1 page load might be different from above plot.<br>

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">From above Forecastings we can see that engagement level and pct_access will increase in year 2021. Although, it might have some dips during the holidays seasons but it is having a increasing trend. Introduction of vaccines and many peoples getting vaccinated which might result in reopening of schools which might affect the digital learning platforms/products.<br>
# For the year 2020, may states stated emphasizing on digital learning products, as a results these products gained popularity over the time. Some states also started implementing policies to encourage students/teachers to adopt digital platforms for teaching in covid era. If COVID-19 does not ease in year 2021. The similar increasing will be observed in 2021 also, with probable forecast as seen above.<br><br>Time for next question:-

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>How does student engagement with different types of education technology change over the course of the pandemic?</b><br>
# For this, we have seen that School and District Operations (SDO) Products were the most favoured products among the students. Some of the Top Products under SDO category are Google Classroom, Clever, other Google sites, Classlink , Schoology. After starting of Lockdowns, schools used these sites to teach/guide the students. However, Classroom Management(CM) products gained popularity over the course of covid period in 2020 specially at later phase. Some of the Popular Products among this category were Google Forms, Meet, Zoom, hangouts etc. These platforms provide much interactive features while teaching/discussions between teachers and students. Therefore, teachers preferred these products for interacting with their students.<br>It can be seen that during the holidays like summer break, thanksgiving holidays, winter break etc. there was a significant drop in Engagement level of Students and teachers.<br><br>
# Now lets have a look at another important aspect.

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>How does student engagement with online learning platforms relate to different geography? Demographic context (e.g., race/ethnicity, ESL, learning disability)? Learning context? Socioeconomic status?</b><br>We have seen the Demographic Comparison of all States, in which Black/Hispanic, Eligibility for free/reduced lunch, expenditure per pupil, poverty level of state and median household income of states. Lets make some inferences about the Top performing States as well as not so good performing States and comapre these indexes of these states.
# <ol style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">
#     <li><b>Arizona- </b>This is among the Top Performing State having page load events much higher as compared to other states. Percentage of Black/Hispanic is much above the Country’s average. Similarly, Students eligible for free/reduced lunches are also high than Country’s average. However, State is spending less on its students. Also poverty level is state is also on higher side with median household income on lower side. On Contrary, Arizona is all covered with City only. </li>
#     <li><b>New York- </b>New York also among the top States with page load events higher as compared to some states. There was slight drop in Page load events as we progressed through the year, with lesser on later phase of the year. Surprisingly, New York’s average household income is less than Country’s average and is slightly having more poverty level among people. But State is spending much higher on its students for their development. Black/Hispanic percentage is very less as compared to other states and students eligible for free/reduced lunch were comparable to Country’s average. </li>
#     </ol>
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">We have seen some Top performing states. Now lets have alook at Not so good performmg states such as</p>
# <ol style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">
#     <li><b>Utah- </b>Utah is among the states performing bad on page load events index.  Although it is performing bad on page load indexes, but median household income of state is higher as compared as compared to Country’s average with least amount of people living in poverty next to New Hampshire. Keeping in view of average household income, state also spends less on the people. Therefore, students eligible for free/reduced lunches are also very less. Also, Black/Hispanic percentage is also less compared to other states. State is mostly covered with suburb with least amount of rural areas. </li>
# <li><b>Tennessee- </b>This state is also among the states performing bad on page load events index. On contrary to Utah, median household income is less and people living in poverty are more. Expenditure by State on its students is also less. Because more people are living in poverty with less median household income, students eligible for free/reduced lunch are more. Tennessee also having very less amount of Black/Hispanic people. State is equally covered with Rural and Suburb.</li>
#     </ol>
#
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Based on observations form few states above we can see that It's the states policies which determines the engagement level of students. Demographics also playing a role but we can see that some states being on poorer side (New York) based on data, performing good whereas Utah among the richer state with higher household income in performing bad on page load events.
#
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">Now its time to look at another probale aspect which can determine engagement_level of students.

# %% [markdown]
# <p style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black"><b>Do certain state interventions, practices or policies (e.g., stimulus, reopening, eviction moratorium) correlate with the increase or decrease online engagement?</b><br>
# For this lets look at an example of State:</p>

# %%
doc = df[df.state=="District Of Columbia"]
doc = doc.groupby("time")["engagement_index"].mean().reset_index()

fig = px.line(x=doc.time, y=doc.engagement_index)
fig.update_layout(title=dict(text="<b>District of Columbia - Engagement Index</b>", x=0.5, font_family="Comic Sans MS", 
                            font_size=20),
                  height=400, margin=dict(t=100, b=0, r=0))
fig.update_xaxes(title=None)
fig.update_yaxes(title=None)
fig.show()

# %% [markdown]
# <ol style="font-family: Comic Sans MS; line-height:2; font-size: 14pt; color:black">
# <b>District of Columbia - </b>The state was observing very less Engagement level of students till the summer break. Seeing the low engagement level of students, State implemented some measure such as distribution of laptops and tablets among the students. Also, provided hotsopts to students who lacked wifi. Local organizations also stepped in to help bridge the digital divide. They distributed funds in terms of grants for student technology and has reserved some funds to help fill technology gaps.<br>These measures by State and local organizations helped the students in closing the digital divide, as a result after September, the time at which usually schools reopens, have seen a considerable amount of increase in Engagement level of students in the State. This is a leading example of States interventions to tackle digital divide and encourage Digital learning among students.
