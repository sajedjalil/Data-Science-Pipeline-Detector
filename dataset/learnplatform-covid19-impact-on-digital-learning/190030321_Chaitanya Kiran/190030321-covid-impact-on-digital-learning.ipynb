# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/districts_info.csv")
df

# %%
df1=pd.read_csv("../input/learnplatform-covid19-impact-on-digital-learning/products_info.csv")
df1

# %%
df.columns

# %%
df1.columns

# %%
df.describe()

# %%
df1.describe()

# %%
df.info()

# %%
df1.info()

# %%
df[["state","district_id"]].groupby(["state"], as_index = False).mean().sort_values(by="district_id",ascending = False)

# %%
df3=df1[["Product Name","LP ID"]].groupby(["Product Name"],as_index=False).mean().sort_values(by="LP ID",ascending=False)
df3

# %%
df.plot(x='state',y='district_id',kind='hist')

# %%
df1.plot(x='Product Name',y='LP ID',kind='hist')

# %%
df.plot(x='state',y='district_id',kind='hist',bins=9)

# %%
df1.plot(x='Product Name',y='LP ID',kind='hist',bins=9)

# %%
df.set_index('state')['district_id'].plot.bar

# %%
df1.set_index('Product Name')['LP ID'].plot.bar()

# %%
df1.plot.pie(x='district_id'),fig.size(10,20)
