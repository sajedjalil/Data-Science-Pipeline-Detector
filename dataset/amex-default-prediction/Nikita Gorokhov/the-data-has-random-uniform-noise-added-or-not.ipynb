# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

feat = 'B_1'
x = pd.read_csv('../input/amex-default-prediction/train_data.csv', usecols=[feat])[feat]

# %% [markdown]
# Some noise distributions are not so obvious

# %%
sns.distplot(x[(x >= 0) & (x <= 0.03)], bins=1000, kde=False)
plt.show()
