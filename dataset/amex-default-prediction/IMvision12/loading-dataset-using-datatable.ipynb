# %% [markdown]
# # Datatable
#
# <p style="text-align:center">
#   <img src="https://miro.medium.com/max/446/0*w7dsjAY9CKNY7owL.png" width="300" />
# </p>
#
# Datatable is a python library for manipulating tabular data. It supports out-of-memory datasets, multi-threaded data processing, and flexible API.fread is the fucntion to read the files in datatable module. From the documentation,fread provides fast and convenient parsing of text (csv) files.
#
# Documentation : [Datatable](https://datatable.readthedocs.io/en/latest/)

# %%
import datatable as dt
import time

# %%
# %%time
df = dt.fread("../input/amex-default-prediction/train_data.csv")

# %%
df.shape

# %%
df.head()
