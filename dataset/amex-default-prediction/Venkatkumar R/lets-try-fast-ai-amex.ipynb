# %% [markdown]
# # <h1><center> ⭐️⭐️American Express - Default Prediction⭐️⭐️ </center></h1>
#
# <img src='https://www.underconsideration.com/brandnew/archives/american_express_logo_wordmark_detail.png'>
#
# ## **Problem:**
#
# The objective of this competition is to predict the probability that a customer does not pay back their credit card balance amount in the future based on their monthly customer profile. The target binary variable is calculated by observing 18 months performance window after the latest credit card statement, and if the customer does not pay due amount in 120 days after their latest statement date it is considered a default event.
#
# The dataset contains aggregated profile features for each customer at each statement date. Features are anonymized and normalized, and fall into the following general categories:
#
# - D_* = Delinquency variables
# - S_* = Spend variables
# - P_* = Payment variables
# - B_* = Balance variables
# - R_* = Risk variables

# %% [markdown]
# ## **This Competition is very large amount data - so i was using (.parquet format) of data**
#
# ### ***Now I am trying in one of my favorite Fast.ai - Tabular Data***
#
# <img src='https://www.thebalancecareers.com/thmb/6VdCQZNeEcX8M5ysvhZJszDwZV8=/1185x320/filters:no_upscale():max_bytes(150000):strip_icc()/fastai-336cfe963d544d3aa71e195b8485d075.jpg'>
#
# ## ***Steps:***
#
# **1. Import Necessary Library**
#
# **2. Try Fast.ai**

# %% [markdown]
# # **1. Import Necessary Library**

# %%
from pathlib import Path
import numpy as np 
import pandas as pd

# %% [markdown]
# # **2. Load the Data**

# %%
root = "../input/amexfeather"
train = Path(root)/"train_data.ftr"
test = Path(root)/"test_data.ftr"
train_label = pd.read_csv("../input/amex-default-prediction/train_labels.csv")
sample = pd.read_csv("../input/amex-default-prediction/sample_submission.csv")
print('Shape of sample',sample.shape)

# %% [markdown]
# # **Taking sample only 50_000 data**

# %%
df = pd.read_feather(train,use_threads=True).sample(50_000)
print('Shape of Train data',df.shape)
display(df.head())

# %% [markdown]
# ## **EDA**

# %%
df.describe().T

# %%
#identify the null data
pd.DataFrame(df.isnull().sum(), columns=['isnull'])

# %%
display(df.duplicated().sum())

# %%
display(df['target'].value_counts(normalize=True))

# %% [markdown]
# # **Start with Fast.ai**

# %%
# !pip install --upgrade fastai

# %%
# !pip install fast_tabnet

# %%
from fastai.tabular.all import *
from fast_tabnet.core import *

# %% [markdown]
# # **Feature Selection**

# %%
dep_var  = 'target'
cont_names = ['P_2',
     'D_39',
     'B_1',
     'B_2',
     'R_1',
     'S_3',
     'D_41',
     'B_3',
     'D_42',
     'D_43',
     'D_44',
     'B_4',
     'D_45',
     'B_5',
     'R_2',
     'D_46',
     'D_47',
     'D_48',
     'D_49',
     'B_6',
     'B_7',
     'B_8',
     'D_50',
     'D_51',
     'B_9',
     'R_3',
     'D_52',
     'P_3',
     'B_10',
     'D_53',
     'S_5',
     'B_11',
     'S_6',
     'D_54',
     'R_4',
     'S_7',
     'B_12',
     'S_8',
     'D_55',
     'D_56',
     'B_13',
     'R_5',
     'D_58',
     'S_9',
     'B_14',
     'D_59',
     'D_60',
     'D_61',
     'B_15',
     'S_11',
     'D_62',
     'D_65',
     'B_16',
     'B_17',
     'B_18',
     'B_19',
     'B_20',
     'R_6',
     'S_13',
     'B_21',
     'D_69',
     'B_22',
     'D_70',
     'D_71',
     'D_72',
     'S_15',
     'B_23',
     'D_73',
     'P_4',
     'D_74',
     'D_75',
     'D_76',
     'B_24',
     'R_7',
     'D_77',
     'B_25',
     'B_26',
     'D_78',
     'D_79',
     'R_8',
     'R_9',
     'S_16',
     'D_80',
     'R_10',
     'R_11',
     'B_27',
     'D_81',
     'D_82',
     'S_17',
     'R_12',
     'B_28',
     'R_13',
     'D_83',
     'R_14',
     'R_15',
     'D_84',
     'R_16',
     'B_29',
     'S_18',
     'D_86',
     'D_87',
     'R_17',
     'R_18',
     'D_88',
     'B_31',
     'S_19',
     'R_19',
     'B_32',
     'S_20',
     'R_20',
     'R_21',
     'B_33',
     'D_89',
     'R_22',
     'R_23',
     'D_91',
     'D_92',
     'D_93',
     'D_94',
     'R_24',
     'R_25',
     'D_96',
     'S_22',
     'S_23',
     'S_24',
     'S_25',
     'S_26',
     'D_102',
     'D_103',
     'D_104',
     'D_105',
     'D_106',
     'D_107',
     'B_36',
     'B_37',
     'R_26',
     'R_27',
     'D_108',
     'D_109',
     'D_110',
     'D_111',
     'B_39',
     'D_112',
     'B_40',
     'S_27',
     'D_113',
     'D_115',
     'D_118',
     'D_119',
     'D_121',
     'D_122',
     'D_123',
     'D_124',
     'D_125',
     'D_127',
     'D_128',
     'D_129',
     'B_41',
     'B_42',
     'D_130',
     'D_131',
     'D_132',
     'D_133',
     'R_28',
     'D_134',
     'D_135',
     'D_136',
     'D_137',
     'D_138',
     'D_139',
     'D_140',
     'D_141',
     'D_142',
     'D_143',
     'D_144',
     'D_145',
    ]

cat_names = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68'] 
procs = [Categorify,FillMissing,Normalize]

# %%
#Random sample
split_sample = np.random.choice(df.shape[0],200)

# %% [markdown]
# # **Build the Model**

# %%
dls = TabularDataLoaders.from_df(df,root,procs,cat_names,cont_names,y_names=dep_var,valid_idx=split_sample,bs=64,y_block=CategoryBlock)

# %%
learn = tabular_learner(dls, model_dir="/tmp/model/", metrics=[accuracy]).to_fp16()

# %%
dls.valid.show_batch()

# %%
learn.lr_find()

# %%
learn.fine_tune(4,1e-3)

# %% [markdown]
# # **Confusion Matrix**

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(5,5), dpi=60)

# %% [markdown]
# ## ***⭐️⭐️Thankyou for visiting guys⭐️⭐️***
#
# Reference:
#
# 1. https://www.kaggle.com/competitions/amex-default-prediction/discussion/327612
# 2. https://www.kaggle.com/code/venkatkumar001/fast-ai-1
