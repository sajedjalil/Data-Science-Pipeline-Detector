# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('../input/amex-default-prediction/sample_submission.csv')

# %%
data

# %%
data.columns

# %%
data.describe()

# %%
data.dtypes

# %%
data.info()

# %%
na_cols = data.isna().any()
na_cols = na_cols[na_cols == True].reset_index()
na_cols = na_cols["index"].tolist()
for col in data.columns[1:]:
     if col in na_cols:
        if data[col].dtype != 'object':
             data[col] =  data[col].fillna(data[col].mean()).round(0)

# %%
data.isnull().any()

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
le = LabelEncoder()

# %%
values=[]
le_count = 0
for col in data.columns[1:]:
    if data[col].dtype == 'object':
        if len(list(data[col].unique())) <= 2:
            le.fit(data[col])
            data[col] = le.transform(data[col])
            le_count += 1
print('{} columns were label encoded.'.format(le_count))

# %%
fig = plt.figure(figsize=(15, 12))
plt.suptitle('Amex Prediction\n',horizontalalignment="center",fontstyle = "normal", fontsize = 24, fontfamily = "sans-serif")
for i in range(data.shape[1]):
    plt.subplot(6, 3, i + 1)
    f = plt.gca()
    f.set_title(data.columns.values[i])
vals = np.size(data.iloc[:, i].unique())
if vals >= 100:
        vals = 100
    
plt.hist(data.iloc[:, i], bins=vals, color = '#93E2EB')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
data.to_csv('submission.csv', index=False)
