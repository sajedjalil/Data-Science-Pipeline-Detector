# %% [markdown]
# # The True Cost
#
# Copyright (c) 2022 John Kim. The Creative Commons.
#
# A credit card default is an unfortunate event with some important data weights.
#
# The distribution and the placement are necessary to solve the problem of imbalance.
#
# KNN, logistics, SVM, random forest, tree, and k-Means BP neural network [4].
#
# How much is the bus fare? What if the phone had run out of battery?
#
# Kunama~ Kunama~ Hello! What? Where is my AUC fare proof?
#
# The P of a default is 2 when there is no proof.
#
# Always inside or outside and how often? Union intersections.
#
# The economy of medium large cities and their bank locations.
#
# A different set of phones and what numbers are being used for the diacritic social layers.

# %% [markdown]
# ![chamfer.png](attachment:158220b8-1205-49f2-af18-eff392e1ad1e.png)

# %% [markdown]
# # Tree layered highlights chamfer, sawmill, and no labels.
#
# Just pour the highlights.
#
# Automate and scale them.
#
# Why make the tax payer pay the billion? Pay 30 illu bucks per agent.
#
# S. Pink and Y. Blue, "Force-directed highlights," the golden placement, pp. 1-1, 2020 [1]

# %% [markdown]
# ![The lattice.png](attachment:c6c5184c-c140-4a92-8898-0369119789ba.png)

# %% [markdown]
# # Up Down Simulator
#
# Over under the hybrid mathmatical data sample reshaping simulation.

# %% [markdown]
# # Why poverty exists
#
# Before exiting into a dataset on consumer credits, it is important to take a picture of myself and see my digital portrait [1].
#
#   First, the poverty and inequality are not due to a lack of money, limitations, or diversity of our economy.
#
#   The poverty persists because the world is just huge~! No face. No voice.
#
#   Second, our leading digital social networking is an absolute garbage.
#
# The network is a very important piece to be a group-sufficient.

# %%
# The github.com/kaggle/docker-python
import os
import warnings
warnings.filterwarnings('ignore')

# The package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# The datatable
import datatable as dt
# df = dt.fread("../input/amex-default-prediction/train_data.csv")
# df.nrows
# df.ncols
# df[5531450,189]
# df[2781450,95]

# The path
SAMPLE_DATA_PATH = "../input/amex-default-prediction/sample_submission.csv"
TEST_DATA_PATH = "../input/amex-default-prediction/test_data.csv"
TRAIN_DATA_PATH = "../input/amex-default-prediction/train_data.csv"
TRAIN_LABELS_PATH = "../input/amex-default-prediction/train_labels.csv"

# The chunk
the_chunksize = 14
the_train_data = pd.read_csv(TRAIN_DATA_PATH, chunksize=the_chunksize)
the_train_labels = pd.read_csv(TRAIN_LABELS_PATH)
the_train_next = the_train_data.__next__()

# The customer
the_customer_id = the_train_next.customer_ID.iat[13]
the_customer_data = the_train_next[the_train_next["customer_ID"] == the_customer_id]
the_customer_id
the_customer_data

# %%
# A baker's dozen
the_customer_id = the_train_next.customer_ID.iat[0]
the_customer_data = the_train_next[the_train_next["customer_ID"] == the_customer_id]
the_customer_id
the_customer_data

# %% [markdown]
# # The optimization model
#
# Primary index sets are countries, currencies, plants, raw materials, plant classes, sites, products, and time preiods. CQFRGSPT. [2]
#
# Induces index sets are export, no export, belongings, capable, potential, and ... CE CNE F F FSA FSE FSN PE PI Pf Pt PFSE PSC R SI Se SNE SU.
#
# Production system parameters. scupstat. scupvol.
#
# Financial and market parameters. tariff. trcost.
#
# Calculated parameters. BigM.
#
# Decision variables are dext dint prvol u v w x y z.

# %% [markdown]
# # Friends and Family
#
# Friends and family are your trust to deal with the financial decision making [3].
#
# Yet, they can also create tension, especially when your goats are outta control.
#
# Cost of Money
#
# Fundraising Expenses
#
# Depth of Pocket
#
# Collateral Requirements
#
# Risk-Bearing Abilities
#
# Reputation and Signaling
#
# Management Skills
#
# Speed of Decisions
#
# Industry Knowledge
#
# Flexibility
#
# Other Resources
#
# Control Tendencies

# %% [markdown]
# # Foreigner Discovery Day
#
# Vapnick SVM support-vector machine.
#
# Cluster Multiclass SVM Transductive Regression.
#
# NEC Laboratories in Princeton, New Jersey.

# %% [markdown]
# # References
#
# [1] Bellamy, M. "Selling Daylight," A Commercial Strategy to Address Global Energy Poverty, Second Edition, pp.145-157, 2019. <doi/10.3362/9781788530705.14>
#
# [2] Hübner, R. "Strategic Supply Chain Management in Process Industires," An Application to Specialty Chemicals Production Network Design, pp.89-125, 2007.
#
# [3] R.W.Seifert, B.F.Leleux, and C.L.Tucci. "Nurturing Science-based Ventures," An International Case Perspective, pp.219-240, 2008.
#
# [4] Y.Chen and R.Zhang. "the k-Means SMOTE and BP Neural Network," Research on Credit Card Default Prediction, pp.1-13, 2021. <doi/10.1155/2021/6618841>
#
# [5] Yat, S. "The Goat," the golden kale and four advanced promises, pp. 1-1, 2023.
