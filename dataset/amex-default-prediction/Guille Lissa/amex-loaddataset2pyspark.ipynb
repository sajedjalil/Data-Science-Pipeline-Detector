# %% [markdown]
# ### Install Pyspark

# %%
# !pip install pyspark

# %% [markdown]
# ### Create a Spark Session

# %%
from pyspark.sql import SparkSession
 
spark = SparkSession.builder.appName(
    'AmexChallenger').getOrCreate()

# %%
spark

# %% [markdown]
# ### Load csv to pyspark dataframe and define schema

# %%
from pyspark.sql.types import FloatType, IntegerType, StringType, StructType, StructField

 # define the schema, corresponding to a line in the csv data file.
schema = StructType([
StructField("customer_ID", StringType(), nullable = True),
StructField("S_2", StringType(), nullable = True),
StructField("P_2", FloatType(), nullable = True),
StructField("D_39", FloatType(), nullable = True),
StructField("B_1", FloatType(), nullable = True),
StructField("B_2", FloatType(), nullable = True),
StructField("R_1", FloatType(), nullable = True),
StructField("S_3", FloatType(), nullable = True),
StructField("D_41", FloatType(), nullable = True),
StructField("B_3", FloatType(), nullable = True),
StructField("D_42", FloatType(), nullable = True),
StructField("D_43", FloatType(), nullable = True),
StructField("D_44", FloatType(), nullable = True),
StructField("B_4", FloatType(), nullable = True),
StructField("D_45", FloatType(), nullable = True),
StructField("B_5", FloatType(), nullable = True),
StructField("R_2", FloatType(), nullable = True),
StructField("D_46", FloatType(), nullable = True),
StructField("D_47", FloatType(), nullable = True),
StructField("D_48", FloatType(), nullable = True),
StructField("D_49", FloatType(), nullable = True),
StructField("B_6", FloatType(), nullable = True),
StructField("B_7", FloatType(), nullable = True),
StructField("B_8", FloatType(), nullable = True),
StructField("D_50", FloatType(), nullable = True),
StructField("D_51", FloatType(), nullable = True),
StructField("B_9", FloatType(), nullable = True),
StructField("R_3", FloatType(), nullable = True),
StructField("D_52", FloatType(), nullable = True),
StructField("P_3", FloatType(), nullable = True),
StructField("B_10", FloatType(), nullable = True),
StructField("D_53", FloatType(), nullable = True),
StructField("S_5", FloatType(), nullable = True),
StructField("B_11", FloatType(), nullable = True),
StructField("S_6", FloatType(), nullable = True),
StructField("D_54", FloatType(), nullable = True),
StructField("R_4", FloatType(), nullable = True),
StructField("S_7", FloatType(), nullable = True),
StructField("B_12", FloatType(), nullable = True),
StructField("S_8", FloatType(), nullable = True),
StructField("D_55", FloatType(), nullable = True),
StructField("D_56", FloatType(), nullable = True),
StructField("B_13", FloatType(), nullable = True),
StructField("R_5", FloatType(), nullable = True),
StructField("D_58", FloatType(), nullable = True),
StructField("S_9", FloatType(), nullable = True),
StructField("B_14", FloatType(), nullable = True),
StructField("D_59", FloatType(), nullable = True),
StructField("D_60", FloatType(), nullable = True),
StructField("D_61", FloatType(), nullable = True),
StructField("B_15", FloatType(), nullable = True),
StructField("S_11", FloatType(), nullable = True),
StructField("D_62", FloatType(), nullable = True),
StructField("D_63", StringType(), nullable = True),
StructField("D_64", StringType(), nullable = True),
StructField("D_65", FloatType(), nullable = True),
StructField("B_16", FloatType(), nullable = True),
StructField("B_17", FloatType(), nullable = True),
StructField("B_18", FloatType(), nullable = True),
StructField("B_19", FloatType(), nullable = True),
StructField("D_66", FloatType(), nullable = True),
StructField("B_20", FloatType(), nullable = True),
StructField("D_68", FloatType(), nullable = True),
StructField("S_12", FloatType(), nullable = True),
StructField("R_6", FloatType(), nullable = True),
StructField("S_13", FloatType(), nullable = True),
StructField("B_21", FloatType(), nullable = True),
StructField("D_69", FloatType(), nullable = True),
StructField("B_22", FloatType(), nullable = True),
StructField("D_70", FloatType(), nullable = True),
StructField("D_71", FloatType(), nullable = True),
StructField("D_72", FloatType(), nullable = True),
StructField("S_15", FloatType(), nullable = True),
StructField("B_23", FloatType(), nullable = True),
StructField("D_73", FloatType(), nullable = True),
StructField("P_4", FloatType(), nullable = True),
StructField("D_74", FloatType(), nullable = True),
StructField("D_75", FloatType(), nullable = True),
StructField("D_76", FloatType(), nullable = True),
StructField("B_24", FloatType(), nullable = True),
StructField("R_7", FloatType(), nullable = True),
StructField("D_77", FloatType(), nullable = True),
StructField("B_25", FloatType(), nullable = True),
StructField("B_26", FloatType(), nullable = True),
StructField("D_78", FloatType(), nullable = True),
StructField("D_79", FloatType(), nullable = True),
StructField("R_8", FloatType(), nullable = True),
StructField("R_9", FloatType(), nullable = True),
StructField("S_16", FloatType(), nullable = True),
StructField("D_80", FloatType(), nullable = True),
StructField("R_10", FloatType(), nullable = True),
StructField("R_11", FloatType(), nullable = True),
StructField("B_27", FloatType(), nullable = True),
StructField("D_81", FloatType(), nullable = True),
StructField("D_82", FloatType(), nullable = True),
StructField("S_17", FloatType(), nullable = True),
StructField("R_12", FloatType(), nullable = True),
StructField("B_28", FloatType(), nullable = True),
StructField("R_13", FloatType(), nullable = True),
StructField("D_83", FloatType(), nullable = True),
StructField("R_14", FloatType(), nullable = True),
StructField("R_15", FloatType(), nullable = True),
StructField("D_84", FloatType(), nullable = True),
StructField("R_16", FloatType(), nullable = True),
StructField("B_29", FloatType(), nullable = True),
StructField("B_30", FloatType(), nullable = True),
StructField("S_18", FloatType(), nullable = True),
StructField("D_86", FloatType(), nullable = True),
StructField("D_87", FloatType(), nullable = True),
StructField("R_17", FloatType(), nullable = True),
StructField("R_18", FloatType(), nullable = True),
StructField("D_88", FloatType(), nullable = True),
StructField("B_31", IntegerType(), nullable = True),
StructField("S_19", FloatType(), nullable = True),
StructField("R_19", FloatType(), nullable = True),
StructField("B_32", FloatType(), nullable = True),
StructField("S_20", FloatType(), nullable = True),
StructField("R_20", FloatType(), nullable = True),
StructField("R_21", FloatType(), nullable = True),
StructField("B_33", FloatType(), nullable = True),
StructField("D_89", FloatType(), nullable = True),
StructField("R_22", FloatType(), nullable = True),
StructField("R_23", FloatType(), nullable = True),
StructField("D_91", FloatType(), nullable = True),
StructField("D_92", FloatType(), nullable = True),
StructField("D_93", FloatType(), nullable = True),
StructField("D_94", FloatType(), nullable = True),
StructField("R_24", FloatType(), nullable = True),
StructField("R_25", FloatType(), nullable = True),
StructField("D_96", FloatType(), nullable = True),
StructField("S_22", FloatType(), nullable = True),
StructField("S_23", FloatType(), nullable = True),
StructField("S_24", FloatType(), nullable = True),
StructField("S_25", FloatType(), nullable = True),
StructField("S_26", FloatType(), nullable = True),
StructField("D_102", FloatType(), nullable = True),
StructField("D_103", FloatType(), nullable = True),
StructField("D_104", FloatType(), nullable = True),
StructField("D_105", FloatType(), nullable = True),
StructField("D_106", FloatType(), nullable = True),
StructField("D_107", FloatType(), nullable = True),
StructField("B_36", FloatType(), nullable = True),
StructField("B_37", FloatType(), nullable = True),
StructField("R_26", FloatType(), nullable = True),
StructField("R_27", FloatType(), nullable = True),
StructField("B_38", FloatType(), nullable = True),
StructField("D_108", FloatType(), nullable = True),
StructField("D_109", FloatType(), nullable = True),
StructField("D_110", FloatType(), nullable = True),
StructField("D_111", FloatType(), nullable = True),
StructField("B_39", FloatType(), nullable = True),
StructField("D_112", FloatType(), nullable = True),
StructField("B_40", FloatType(), nullable = True),
StructField("S_27", FloatType(), nullable = True),
StructField("D_113", FloatType(), nullable = True),
StructField("D_114", FloatType(), nullable = True),
StructField("D_115", FloatType(), nullable = True),
StructField("D_116", FloatType(), nullable = True),
StructField("D_117", FloatType(), nullable = True),
StructField("D_118", FloatType(), nullable = True),
StructField("D_119", FloatType(), nullable = True),
StructField("D_120", FloatType(), nullable = True),
StructField("D_121", FloatType(), nullable = True),
StructField("D_122", FloatType(), nullable = True),
StructField("D_123", FloatType(), nullable = True),
StructField("D_124", FloatType(), nullable = True),
StructField("D_125", FloatType(), nullable = True),
StructField("D_126", FloatType(), nullable = True),
StructField("D_127", FloatType(), nullable = True),
StructField("D_128", FloatType(), nullable = True),
StructField("D_129", FloatType(), nullable = True),
StructField("B_41", FloatType(), nullable = True),
StructField("B_42", FloatType(), nullable = True),
StructField("D_130", FloatType(), nullable = True),
StructField("D_131", FloatType(), nullable = True),
StructField("D_132", FloatType(), nullable = True),
StructField("D_133", FloatType(), nullable = True),
StructField("R_28", FloatType(), nullable = True),
StructField("D_134", FloatType(), nullable = True),
StructField("D_135", FloatType(), nullable = True),
StructField("D_136", FloatType(), nullable = True),
StructField("D_137", FloatType(), nullable = True),
StructField("D_138", FloatType(), nullable = True),
StructField("D_139", FloatType(), nullable = True),
StructField("D_140", FloatType(), nullable = True),
StructField("D_141", FloatType(), nullable = True),
StructField("D_142", FloatType(), nullable = True),
StructField("D_143", FloatType(), nullable = True),
StructField("D_144", FloatType(), nullable = True),
StructField("D_145", FloatType(), nullable = True)]
)

# %%
train_df = spark.read.csv('../input/amex-default-prediction/train_data.csv', sep=',',
                         header=True, schema=schema).cache()
 
train_df.printSchema()

# %%
print("train shape: ", train_df.count(), len(train_df.columns))

# %%
# Inspect first five rows
train_df.take(5)

# %%
spark.stop()
