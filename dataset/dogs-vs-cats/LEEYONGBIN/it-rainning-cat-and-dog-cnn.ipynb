# %% [markdown]
# # 0. Introduction
# > Cats vs Dogs Dataset
#
# <img src="https://user-images.githubusercontent.com/54783158/168794846-6a2d82ff-3f3f-43b3-be7d-adb73167e563.png" width="300" height="300">
#
#
#
# This dataset is very easy to start CNN.
# So our study group select this to practice convolutinal modeling.
# ## EDA
# The purpose of this competition is classifier which is cat, and which is dog by using deeplearning models
# this dataset produce 2 Zip files, (sampleSubmission is just sample)
# ### Train.zip
# number_train.jpg
# ### test.zip
# label

# %% [markdown]
# # 1. Data Preprocessing

# %% [markdown]
# ## 1.1 Data load

# %%
import pandas as pd # data preprocessing
import numpy as np # linear algebra
import os

import matplotlib.pyplot as plt
from tqdm import tqdm
import cv2

import tensorflow as tf
from keras.datasets import mnist
from keras import models
from keras import layers
from keras import optimizers
from keras import Sequential
from keras.layers import Dense,MaxPooling2D,Conv2D,Flatten,Dropout, Activation, BatchNormalization

from keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator

# First we find which files are included
print("Root directory contains: ")
print(os.listdir("../input/dogs-vs-cats"))

# %% [markdown]
# ## library
# 1. matplotlib - data visualization
# 2. tqdm - check process learning
# 3. tensorflow.keras - deeplearning library
# 4. cv2 - image

# %%
# file path
train_path = "../input/dogs-vs-cats/train.zip"
test_path = "../input/dogs-vs-cats/test1.zip"

# %%
# unzip file
# %time
import zipfile

zip_files = ['test1', 'train']

for zip_file in tqdm(zip_files):
    with zipfile.ZipFile("../input/dogs-vs-cats/{}.zip".format(zip_file), "r") as z:
        z.extractall('.') # unzip
        print("{} unzipped".format(zip_file))

# %% [markdown]
# ### If input file is provided zip?
# you can use ```ZipFile()``` to unzip
# 1. ```import zipfile```
# 2. ```ZipFile(filepath, 'r')```
# 3. ```extractall(directory_path)```

# %% [markdown]
# ### If you want to use tqdm
#  tqdm library show process easy to understand
# 1. ```import tqdm```
# 2. find Sequence datatype
# 3. wrap it in a function like this
# ```tqdm(range(10))```
#
# then you can make process bar easily

# %%
WIDTH=128
HEIGHT=128
image_size = (WIDTH, HEIGHT)
image_channel =3

# %%
# train_df 
filenames=os.listdir("./train")
categories=[]
for filename in filenames:
    # class dog, cat 
    category=filename.split('.')[0]
    if category=='dog':
        categories.append(1) # dog = 1
    else:
        categories.append(0) # cat = 0
train_df = pd.DataFrame({
    'filename':filenames,
    'category':categories
})

# %%
train_df.head()

# %%
# test_df 
test_filenames = os.listdir("./test1")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_df.head()

# %%
print('train:{}\n test:{}'.format(train_df.shape[0], test_df.shape[0]))

# %% [markdown]
# ## Split dataset

# %%
## next time

# %% [markdown]
# # 2. Visualization

# %%
# %matplotlib inline
from keras.preprocessing.image import load_img
import random

sample = random.choice(filenames)
image = load_img("/kaggle/working/train/"+sample)
plt.imshow(image)

# %% [markdown]
# # 3. Modeling

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,\
    Dropout, Flatten, Dense, Activation,\
    BatchNormalization

# %%
'''
WIDTH=128
HEIGHT=128
image_size = (WIDTH, HEIGHT)
image_channel =3
'''

model = Sequential()

# layer 1
model.add(Conv2D(32,(3,3), activation='relu',input_shape=(WIDTH, HEIGHT, image_channel)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# layer 2
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# layer 3
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#layer 4
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2,activation='softmax')) 

model.compile(loss='categorical_crossentropy',
  optimizer='rmsprop',metrics=['accuracy'])

# %%
model.summary()

# %% [markdown]
# - Conv2D
# - BatchNormalization
# - MaxPooling
# - Dropout
# - Flatten

# %% [markdown]
# # 4. accuracy
