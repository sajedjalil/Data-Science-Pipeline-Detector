# %% [markdown]
# # Convolutional Neural Networks in TensorFlow DeepLearning.AI

# %% [markdown]
# ## Week 1: exploring large datasets

# %% [markdown]
# ### Cat vs Dog dataset

# %%
test_dir = "../input/dogs-vs-cats/test1.zip"
train_dir = "../input/dogs-vs-cats/train.zip"

from zipfile import ZipFile

train = ZipFile(train_dir, "r")
test = ZipFile(test_dir, "r")

train.extractall()
test.extractall()

train.close()
test.close()

# %%
import os, sys

train_files = os.listdir("train")
test_files = os.listdir("test1")

# print first 10 filenames in the ../working/train/ and ../working/test1/ dirrectory
for i in range(10): print(train_files[i], end=", ")
print()
for i in range(10): print(test_files[i],  end=", ")
