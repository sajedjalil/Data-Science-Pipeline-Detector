# %% [markdown]
# The data quality has big impact on the model. My observation is the lower quality factor the easier to detect.
#
# It is challenge to get high accuracy on images have high quality factor.
#
# Here I share the estimated quality fact csv files, and I will keep updating my observations.
#
# https://www.kaggle.com/mohaoran93/alaska2-image-quality-factor
