# %%
                                                                                                                                                                                                                                                                                                                    # This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb

# %% [markdown]
# **oil_data set**

# %% [markdown]
# //Displays no.of columns//

# %%
oil_data = pd.read_csv('../input/store-sales-time-series-forecasting/oil.csv')
oil_data

# %% [markdown]
# //Displays first 5 Rows in the data set//

# %%
oil_data.rename(columns={'dcoilwtico':'oilPrice'}, inplace=True)

# %%
oil_data.head()

# %% [markdown]
# //Displays no.of entries from the total data set//

# %%
oil_data.info()

# %% [markdown]
# //Displays no.of missing values from the total data set//

# %%
print(f'Number of rows: {oil_data.shape[0]};  Number of columns: {oil_data.shape[1]}; No of missing values: {sum(oil_data.isna().sum())}')

# %% [markdown]
# //Displays total no.of missing values in each column//

# %%
print('Number of missing Values in every column:')
print(oil_data.isna().sum())

# %% [markdown]
# //Gives the statistics for the given data set//

# %%
oil_data.describe()

# %%
oil_data['oilPrice'] = oil_data['oilPrice'].replace(np.NaN, oil_data['oilPrice'].std())
print(oil_data['oilPrice'])

# %% [markdown]
# **sample_submission data set**

# %% [markdown]
# //Displaying no.of rows and no.of columns//

# %%
sample_submission = pd.read_csv('../input/store-sales-time-series-forecasting/sample_submission.csv')
sample_submission

# %% [markdown]
# //Displays first 5 rows of data set//

# %%
sample_submission.head()

# %% [markdown]
# //displays total no.of entries in the data set//

# %%
sample_submission.info()

# %% [markdown]
# //Displays no.of missing values from the total data set//

# %%
print(f'Number of rows: {sample_submission.shape[0]};  Number of columns: {sample_submission.shape[1]}; No of missing values: {sum(sample_submission.isna().sum())}')

# %% [markdown]
# //Displays no.of missing values from each column//

# %%
print('Number of missing Values in every column:')
print(sample_submission.isna().sum())

# %% [markdown]
# //Displays the statistics from the data set//

# %%
sample_submission.describe()

# %% [markdown]
# **Holidays_event data set**

# %% [markdown]
# //Displays total no.of rows and columns//

# %%
holidays_events = pd.read_csv('../input/store-sales-time-series-forecasting/holidays_events.csv')
holidays_events

# %% [markdown]
# //Displays first 5 rows from the data_set//

# %%
holidays_events.head()

# %% [markdown]
# //Displays total no.of entries//

# %%
holidays_events.info()

# %% [markdown]
# //Displays no.of missing values from the data set//

# %%
print(f'Number of rows: {holidays_events.shape[0]};  Number of columns: {holidays_events.shape[1]}; No of missing values: {sum(holidays_events.isna().sum())}')

# %% [markdown]
# //Displays no.of missing values from each column of the data set

# %%
print('Number of missing Values in every column:')
print(holidays_events.isna().sum())

# %% [markdown]
# //Displays the statistics of the data set//

# %%
holidays_events.describe()

# %% [markdown]
# **stores data set**

# %% [markdown]
# //diplays the total number of rows and coloumns for the given data set//

# %%
stores_data = pd.read_csv('../input/store-sales-time-series-forecasting/stores.csv')
stores_data

# %% [markdown]
# //diplays the first five rows of the data set//

# %%
stores_data.head()

# %% [markdown]
# //displays the total number of rows and coloums and entries in the data set //

# %%
stores_data.info()

# %% [markdown]
# //displays the number of rows and columns and the missing values from the data set//

# %%
print(f'Number of rows: {stores_data.shape[0]};  Number of columns: {stores_data.shape[1]}; No of missing values: {sum(stores_data.isna().sum())}')

# %% [markdown]
# //displays the statistics//

# %%
stores_data.describe()

# %% [markdown]
# **train dataset**

# %% [markdown]
# //displays the total number of rows and colomns for train dataset//

# %%
train_data = pd.read_csv('../input/store-sales-time-series-forecasting/train.csv')
train_data

# %% [markdown]
# //displays the first five rows of the data set//

# %%
train_data.head()

# %% [markdown]
# //displays the total number of rows and colomns and entries of the dataset//

# %%
train_data.info()

# %% [markdown]
# //displays the number of rows and colomns and the missing values from the dataset//

# %%
print(f'Number of rows: {train_data.shape[0]};  Number of columns: {train_data.shape[1]}; No of missing values: {sum(train_data.isna().sum())}')

# %% [markdown]
# //displays the total number of null values from every coloumn//

# %%
print('Number of missing Values in every column:')
print(train_data.isna().sum())

# %% [markdown]
# //displays the statistics//

# %%
train_data.describe()

# %% [markdown]
# **test dataset**

# %% [markdown]
# //displays the rows and colomns of test dataset//

# %%
test_data = pd.read_csv('../input/store-sales-time-series-forecasting/test.csv')
test_data

# %% [markdown]
# /displays the first five rows of the data set//

# %%
test_data.head()

# %% [markdown]
# //displays the total number of rows and colomns and entries of the dataset//

# %%
test_data.info()

# %% [markdown]
# //displays the number of rows and colomns and the missing values from the dataset//

# %%
print(f'Number of rows: {test_data.shape[0]};  Number of columns: {test_data.shape[1]}; No of missing values: {sum(test_data.isna().sum())}')

# %% [markdown]
# //displays the null values in every column of the dataset//

# %%
print('Number of missing Values in every column:')
print(test_data.isna().sum())

# %% [markdown]
# //displays the statistics of the dataset//

# %%
test_data.describe()

# %% [markdown]
# **transaction dataset**

# %% [markdown]
# //displays the total number of rows and columns of transaction dataset//

# %%
transaction_data = pd.read_csv('../input/store-sales-time-series-forecasting/transactions.csv')
transaction_data

# %% [markdown]
# //displays the first five rows of the dataset//

# %%
transaction_data.head()

# %% [markdown]
# //displays the total number of rows and columns and entries of the dataset//

# %%
transaction_data.info()

# %% [markdown]
# //displays the number of rows and columns and missing values of the dataset//

# %%
print(f'Number of rows: {transaction_data.shape[0]};  Number of columns: {transaction_data.shape[1]}; No of missing values: {sum(transaction_data.isna().sum())}')

# %% [markdown]
# //displays the total number of null values from the dataset//

# %%
print('Number of missing Values in every column:')
print(transaction_data.isna().sum())

# %% [markdown]
# //displays the statistics of the data set//

# %%
transaction_data.describe()

# %%
# using merge function by setting how='inner'

train_new = pd.merge(holidays_events, train_data, 
                   on='date',
                   how='inner')
  
# displaying result
print(train_new)

# %%
# using merge function by setting how='inner'
train = pd.merge(train_new, oil_data, 
                   on='date',
                   how='inner')
  
# displaying result
print(train)

# %%
#label encoding
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
train['family']= label_encoder.fit_transform(train['family'])
  
train['family'].unique()

# %%
#label encoding
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
train['type']= label_encoder.fit_transform(train['type'])
  
train['type'].unique()

# %%
#label encoding
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
train['locale']= label_encoder.fit_transform(train['locale'])
  
train['locale'].unique()

# %%
#label encoding
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
train['locale_name']= label_encoder.fit_transform(train['locale_name'])
  
train['locale_name'].unique()

# %%
#label encoding
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
train['description']= label_encoder.fit_transform(train['description'])
  
train['description'].unique()

# %%
#label encoding
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
train['transferred']= label_encoder.fit_transform(train['transferred'])
  
train['transferred'].unique()

# %%
#heat map
# prints data that will be plotted
# columns shown here are selected by corr() since
# they are ideal for the plot
print(train.corr())
  
# plotting correlation heatmap
dataplot = sns.heatmap(train.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()

# %%
train['date'] = train['date'].str.replace('-','')

# %%
train['date'] = train['date'].str.replace(' '' ','')

# %%
#output vector
y = train.date
 
#input vector
x=train.drop('date',axis=1)
 
#split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_test = le.fit_transform(y_test)
#verify
print("shape of original dataset :", train.shape)
print("shape of input - training set", x_train.shape)
print("shape of output - training set", y_train.shape)
print("shape of input - testing set", x_test.shape)
print("shape of output - testing set", y_test.shape)

# %%
print(train)

# %%
print(x_train)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# %%
print(y_train)

# %%
print(x_test)

# %%
x_test.info()

# %%
print(y_test)

# %%
print(train)

# %% [markdown]
# **XgBoost**

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %%
from catboost import CatBoostRegressor
model = CatBoostRegressor(verbose=0, n_estimators=100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ##### accuracy = accuracy_score(test_data, accuracy)
# type(y_test)
# type(predicions)

# %%
from lightgbm import LGBMRegressor
model = LGBMRegressor()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
