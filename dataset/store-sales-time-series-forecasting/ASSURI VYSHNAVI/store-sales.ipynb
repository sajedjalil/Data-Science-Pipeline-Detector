# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np

import pandas as pd

from sklearn import datasets
import squarify

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import ticker

import seaborn as sns

# %%
oil_data = pd.read_csv('../input/store-sales-time-series-forecasting/oil.csv')
oil_data

# %%
oil_data.head()

# %%
oil_data.info()

# %%
print(f'Number of rows: {oil_data.shape[0]};  Number of columns: {oil_data.shape[1]}; No of missing values: {sum(oil_data.isna().sum())}')

# %%
print('Number of missing Values in every column:')
print(oil_data.isna().sum())

# %%
oil_data.describe()

# %%
sample_submission = pd.read_csv('../input/store-sales-time-series-forecasting/sample_submission.csv')
sample_submission

# %%
sample_submission.head()

# %%
sample_submission.info()

# %%
print(f'Number of rows: {sample_submission.shape[0]};  Number of columns: {sample_submission.shape[1]}; No of missing values: {sum(sample_submission.isna().sum())}')

# %%
print('Number of missing Values in every column:')
print(sample_submission.isna().sum())

# %%
sample_submission.describe()

# %%
holidays_events = pd.read_csv('../input/store-sales-time-series-forecasting/holidays_events.csv')
holidays_events

# %%
holidays_events.head()

# %%
holidays_events.info()

# %%
print(f'Number of rows: {holidays_events.shape[0]};  Number of columns: {holidays_events.shape[1]}; No of missing values: {sum(holidays_events.isna().sum())}')

# %%
print('Number of missing Values in every column:')
print(holidays_events.isna().sum())

# %%
holidays_events.describe()

# %%
stores_data = pd.read_csv('../input/store-sales-time-series-forecasting/stores.csv')
stores_data

# %%
stores_data.head()

# %%
stores_data.info()

# %%
print(f'Number of rows: {stores_data.shape[0]};  Number of columns: {stores_data.shape[1]}; No of missing values: {sum(stores_data.isna().sum())}')

# %%
stores_data.describe()

# %%
train_data = pd.read_csv('../input/store-sales-time-series-forecasting/train.csv')
train_data

# %%
train_data.head()

# %%
train_data.info()

# %%
print(f'Number of rows: {train_data.shape[0]};  Number of columns: {train_data.shape[1]}; No of missing values: {sum(train_data.isna().sum())}')

# %%
print('Number of missing Values in every column:')
print(train_data.isna().sum())

# %%
train_data.describe()

# %%
test_data = pd.read_csv('../input/store-sales-time-series-forecasting/test.csv')
test_data

# %%
test_data.head()

# %%
test_data.info()

# %%
print(f'Number of rows: {test_data.shape[0]};  Number of columns: {test_data.shape[1]}; No of missing values: {sum(test_data.isna().sum())}')

# %%
print('Number of missing Values in every column:')
print(test_data.isna().sum())

# %%
test_data.describe()

# %%
transaction_data = pd.read_csv('../input/store-sales-time-series-forecasting/transactions.csv')
transaction_data

# %%
transaction_data.head()

# %%
transaction_data.info()

# %%
print(f'Number of rows: {transaction_data.shape[0]};  Number of columns: {transaction_data.shape[1]}; No of missing values: {sum(transaction_data.isna().sum())}')

# %%
print('Number of missing Values in every column:')
print(transaction_data.isna().sum())

# %%
transaction_data.describe()
