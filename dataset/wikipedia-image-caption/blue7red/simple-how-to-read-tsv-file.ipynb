# %% [markdown]
# # Load tsv file data

# %%
import datatable as dt
train0 = dt.fread('../input/wikipedia-image-caption/train-00000-of-00005.tsv')

# %% [markdown]
# # View head data (10)

# %%
train0.head()

# %% [markdown]
# # show Keys

# %%
train0.keys()

# %% [markdown]
# # View all data

# %%
train0.view()

# %% [markdown]
# # Shape

# %%
train0.shape
