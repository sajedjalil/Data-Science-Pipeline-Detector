# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQl_Xw2rwx38Ee_wM9OfH5NVYzU1em0Fs6qTg&usqp=CAU)github.com

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px
import altair as alt

from sklearn.neighbors import LocalOutlierFactor

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Code by Vopani https://www.kaggle.com/rohanrao/tutorial-on-reading-large-datasets

# %time

df = pd.read_feather("../input/train-tsv-file-to-feather-files/train-00004-of-00005")

print("df size:", df.shape)

# %%
df.head()

# %%
#Spoiler Alert: No Missing Values 

df.isnull().sum()

# %%
df['language'].value_counts()

# %% [markdown]
# #Hindi Language

# %%
hi = df[(df['language']=='hi')].reset_index(drop=True)
hi.head()

# %% [markdown]
# Since dtypes are all string I couldn't make the Hindi WordCloud applying gargi.ttf" font.

# %%
de = df[(df['language']=='de')].reset_index(drop=True)
de.head(3)

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'salmon',
                      height =2000,
                      width = 2000
                     ).generate(str(de["caption_attribution_description"]))
plt.rcParams['figure.figsize'] = (10,10)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Bezeichnungen auf Deutsch")
plt.show()

# %%
#All are String!

df.dtypes

# %%
#Code by Niharika Pandit https://www.kaggle.com/niharika41298/netflix-vs-books-recommender-analysis-eda

#Ascending order False
top_rated=df.sort_values('original_width', ascending=True)
top10=top_rated.head(10)
f=['page_title','image_url']
displ=(top10[f])
displ.set_index('page_title', inplace=True)

# %%
#Code by Niharika Pandit https://www.kaggle.com/niharika41298/netflix-vs-books-recommender-analysis-eda

from IPython.display import Image, HTML

def path_to_image_html(path):
    '''
     This function essentially convert the image url to 
     '<img src="'+ path + '"/>' format. And one can put any
     formatting adjustments to control the height, aspect ratio, size etc.
     within as in the below example. 
    '''

    return '<img src="'+ path + '""/width="200" height="40" alt="Computer Hope">'

HTML(displ.to_html(escape=False ,formatters=dict(image_url=path_to_image_html),justify='center'))

# %%
#Code by Niharika Pandit https://www.kaggle.com/niharika41298/netflix-vs-books-recommender-analysis-eda

#Ascending order False
top_rated=df.sort_values('original_height', ascending=True)
top10=top_rated.head(10)
f=['page_title','image_url']
displ=(top10[f])
displ.set_index('page_title', inplace=True)

# %%
#Code by Niharika Pandit https://www.kaggle.com/niharika41298/netflix-vs-books-recommender-analysis-eda

from IPython.display import Image, HTML

def path_to_image_html(path):
    '''
     This function essentially convert the image url to 
     '<img src="'+ path + '"/>' format. And one can put any
     formatting adjustments to control the height, aspect ratio, size etc.
     within as in the below example. 
    '''

    return '<img src="'+ path + '""/width="200" height="40" alt="Computer Hope">'

HTML(displ.to_html(escape=False ,formatters=dict(image_url=path_to_image_html),justify='center'))

# %% [markdown]
# #Thanks to Msafi04 for the Dataset https://www.kaggle.com/msafi04/train-tsv-file-to-feather-files
