# %%
import numpy as np 
import pandas as pd 
import cv2
import matplotlib as plt
import random
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/kaggle/input/vinbigdata-chest-xray-abnormalities-detection/train.csv')
print(df.count())
df.head(3)

# %%
print(df['image_id'][df['class_id']==14].count())
df.isna().sum()

# %% [markdown]
# There is no missing values.
#
# (14 is the class ID for no finding, and this provides a one-pixel bounding box with a confidence of 1.0)

# %%
sns.countplot(x='class_id',data=df)

# %%
del df['image_id'],df['rad_id']
sns.pairplot(df, hue='class_id')

# %%
df['x_diff'] = df['x_max'] - df['x_min']
df['y_diff'] = df['y_max'] - df['y_min']

# %%
df.groupby('class_id').agg(['min', 'max', 'mean'])
