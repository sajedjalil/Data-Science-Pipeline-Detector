# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# %%
tiko=pd.read_csv('../input/chest-xray-csv/chest_csv')

# %%
adnane=pd.read_csv('../input/d/kheyduzoomryou/chest-xray-csv/final.csv')

# %%
adnane

# %%
tiko

# %%
txt = "welcome to. the jungle"

x = txt.split('.')

# %%
txt.split('.')[0]

# %%
x

# %%
df = pd.DataFrame()
filenames = []
directory = []
label = []
for filename in os.listdir('../input/new-pneumonia'):
    x=filename.split('.')[0]
    filenames.append(x)
    label.append('Pneumonia')
df['image_id'] = filenames
df['class_name'] = label


df1 = pd.DataFrame()
filenames1 = []
directory1 = []
label1 = []
for filename1 in os.listdir('../input/pneumothorax-new'):
    x=filename1.split('.')[0]
    filenames1.append(x)
    label1.append('Pneumothorax')
df1['image_id'] = filenames1
df1['class_name'] = label1

df2 = pd.DataFrame()
filenames2 = []
directory2 = []
label2 = []
for filename2 in os.listdir('../input/edema-2020/Edema'):
    x=filename2.split('.')[0]
    filenames2.append(x)
    label2.append('Edema')
df2['image_id'] = filenames2
df2['class_name'] = label2


df3 = pd.DataFrame()
filenames3 = []
directory3 = []
label3 = []
for filename3 in os.listdir('../input/atelectasis/Atelectasis'):
    x=filename3.split('.')[0]
    filenames3.append(x)
    label3.append('Atelectasis')
df3['image_id'] = filenames3
df3['class_name'] = label3

# %%
df2

# %%
df1

# %%
df

# %%
frames = [tiko,df,df1,df2,df3]
result = pd.concat(frames)

# %%
result=result.reset_index(drop=True)

# %%
result

# %%
len(result)

# %%
result.to_csv(r'chest_xray.csv')
