# %%
import pandas as pd

# %%
# open dataset
input_data = pd.read_csv('../input/train.csv')
input_data.shape

# %%
# this dataset have 3 collumn: id, url, landmark_id
input_data.head()

# %%
i = 0
print('index', 'id', 'url', 'landmark_id')
print(i, input_data.iloc[i][0], input_data.iloc[i][1], input_data.iloc[i][2])

# %% [markdown]
# ![example test image](http://static.panoramio.com/photos/original/70761397.jpg)
