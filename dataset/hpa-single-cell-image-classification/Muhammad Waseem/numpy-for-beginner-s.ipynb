# %% [markdown]
# Numpy is a python Library

# %% [markdown]
# It's used almost in every field of science and engineering.

# %%
#Importing Numpy
import numpy as np

# %%
#To create a NumPy array, you can use the function np.array().
a = np.array([1,2,3,4,5,6])
a

# %%
print (a[0])

# %%
a = np.array([[1,2,3,4,5,6], [5,6,7,8,9,10], [1,2,3,4,5,6]])

# %%
print([a[0]])

# %%
In NumPy, dimensions are called axes. This means that if you have a 2D array that looks like this:

# %%
[[0., 0., 0.],
 [1., 1., 1.]]

# %%
# Create an empty array with 2 el
np.empty(2)

# %%
#You can create an array with a range of elements:

# %%
np.arange(4)

# %%
#You can also use np.linspace() to create an array with values that are spaced linearly in a specified interval:

# %%
np.linspace(0, 10, num=5)

# %%
#Recommended Convention to import numpy is
import numpy as np

# %% [markdown]
# **Creating Array**

# %%
a = np.array([1,2,3,4])
a

# %%
a.ndim

# %%
a.shape

# %%
len(a)

# %% [markdown]
# # **Creating 2D And 3D Array**

# %%
b = np.array([[1,2,3], [4,5,6]])
b

# %%
b.ndim

# %%
b.shape

# %%
len(b)

# %%
c = np.array([[[1],[2]],[[3],[4]]])
c

# %%
c.shape
