# %%
from fastai.vision.all import *

# %%
path = Path("../input/hpa-single-cell-image-classification")

# %%
df = pd.read_csv(path/'train.csv')
df.head()

# %%
# !mkdir 512_RGB

# %%
def get_x(row):
    ID = row["ID"]
    r = np.array(Image.open(path/'train'/(ID + "_red.png")))
    g = np.array(Image.open(path/'train'/(ID + "_green.png")))
    b = np.array(Image.open(path/'train'/(ID + "_blue.png")))
    rgb = Image.fromarray(np.dstack([r, g, b])).resize((512, 512)).save('512_RGB/' + ID + ".png")

# %%
# df.iloc[:10,:].apply(get_x, axis=1)
df.apply(get_x, axis = 1)

# %%
# !zip -r HPA_512_RGB.zip ./512_RGB
