# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import imageio
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames[:10]:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import matplotlib.pyplot as plt

# %%
# !pip install "../input/pycocotools/pycocotools-2.0-cp37-cp37m-linux_x86_64.whl"

# %%
# !pip install "../input/hpapytorchzoozip/pytorch_zoo-master"

# %%
# !pip install "../input/hpacellsegmentatormaster/HPA-Cell-Segmentation-master"

# %%
def build_image_names_test(image_id: str) -> list:
    # mt is the mitchondria
    mt = f'/kaggle/input/hpa-single-cell-image-classification/test/{image_id}_red.png'
    
    # er is the endoplasmic reticulum
    er = f'/kaggle/input/hpa-single-cell-image-classification/test/{image_id}_yellow.png'
    
    # nu is the nuclei
    nu = f'/kaggle/input/hpa-single-cell-image-classification/test/{image_id}_blue.png'
    
    # the protein of interest
    poi = f'/kaggle/input/hpa-single-cell-image-classification/test/{image_id}_green.png'
    
    #return [mt], [er], [nu], [poi], [[mt], [er], [nu], [poi]]
    return [mt], [er], [nu], [[mt], [er], [nu]]

# %%
def build_image_names_train(image_id: str) -> list:
    # mt is the mitchondria
    mt = f'/kaggle/input/hpa-single-cell-image-classification/train/{image_id}_red.png'
    
    # er is the endoplasmic reticulum
    er = f'/kaggle/input/hpa-single-cell-image-classification/train/{image_id}_yellow.png'
    
    # nu is the nuclei
    nu = f'/kaggle/input/hpa-single-cell-image-classification/train/{image_id}_blue.png'
    
    # the protein of interest
    poi = f'/kaggle/input/hpa-single-cell-image-classification/train/{image_id}_green.png'
    
    #return [mt], [er], [nu], [poi], [[mt], [er], [nu], [poi]]
    return [mt], [er], [nu], [poi], [[mt], [er], [nu]]

# %%
import hpacellseg.cellsegmentator as cellsegmentator
from hpacellseg.utils import label_cell, label_nuclei

NUC_MODEL = '../input/hpacellsegmentatormodelweights/dpn_unet_nuclei_v1.pth'
CELL_MODEL = '../input/hpacellsegmentatormodelweights/dpn_unet_cell_3ch_v1.pth'

segmentator = cellsegmentator.CellSegmentator(
    NUC_MODEL,
    CELL_MODEL,
    scale_factor=0.25,
    device='cuda',
    padding=False,
    multi_channel_model=True
)

# %%
# so this is showing the yellow part
j = 0
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
# this is showing the first cell
j = 1
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
# this is showing the second cell?
j = 2
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 3
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 4
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 5
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 6
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 7
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 8
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 9
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 10
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 11
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 12
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 13
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 14
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 15
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 16
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 17
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 18
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 19
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 20
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 21
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 22
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 23
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 25
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 26
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 27
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
# so the cell masks correspond to j = 1, ..., np.max(cell_mask)

# %%
# Plot of just the mask
plt.imshow(mask, alpha=0.6)

# %%
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = nuclei_mask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
# Plot of just the mask
plt.imshow(mask, alpha=0.6)

# %%
# now do a classification for all testing and training images
TEST_IMGS_FOLDER = '../input/hpa-single-cell-image-classification/test/'
TRAIN_IMGS_FOLDER = '../input/hpa-single-cell-image-classification/train/'

# %%
# read all IDs of training images from train.csv
train_csv = pd.read_csv('../input/hpa-single-cell-image-classification/train.csv')
train_IDs = train_csv['ID'].tolist()

# %%
len(train_IDs)

# %%
# produce nuclei mask and cell mask for each training image
#for i in range(len(train_IDs)):
for i in range(1):
    cell_mask_lst = []
    train_id = train_IDs[i]
    if i % 100 == 0:
        print(i)
    mt, er, nu, poi, images = build_image_names_train(image_id=train_id)
    # For nuclei (blue channel)
    nuc_segmentations = segmentator.pred_nuclei(images[2])
    # For full cells (all channels)
    cell_segmentations = segmentator.pred_cells(images)
    nuclei_mask, cell_mask = label_cell(nuc_segmentations[0], cell_segmentations[0])
    microtubule = plt.imread(mt[0])    
    endoplasmicrec = plt.imread(er[0])    
    nuclei = plt.imread(nu[0])
    protein = plt.imread(poi[0])
    print(i)
    plt.figure(figsize=(20, 10))
    mask = cell_mask
    img = np.dstack((microtubule, endoplasmicrec, nuclei))
    plt.imshow(img)
    #plt.imshow(mask, alpha=0.6)
    plt.show()
    for j in range(np.max(cell_mask) + 1):
        print(j)
        bmask = (cell_mask == j)
        row_ranges = [min(np.nonzero(bmask)[0]), max(np.nonzero(bmask)[0])]
        col_ranges = [min(np.nonzero(bmask)[1]), max(np.nonzero(bmask)[1])]
        seg_bmask = bmask[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]]
        seg_img = np.dstack((np.multiply(microtubule[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask), 
                     np.multiply(endoplasmicrec[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask), 
                     np.multiply(nuclei[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask)))#, 
                     #np.multiply(protein[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask)))
        cell_mask_lst.append(seg_img)
        plt.figure(figsize=(20, 10))
        mask = seg_bmask
        img = seg_img
        plt.imshow(img)
        #plt.imshow(mask, alpha=0.6)
        plt.show()
    np.savez(train_id + '_cell_mask_lst.npz', cell_mask_lst)

# %%
np.max(cell_mask)

# %%
i = 0
cell_mask_lst = []
train_id = train_IDs[i]
mt, er, nu, poi, images = build_image_names_train(image_id=train_id)
# For nuclei (blue channel)
nuc_segmentations = segmentator.pred_nuclei(images[2])
# For full cells (all channels)
cell_segmentations = segmentator.pred_cells(images)
nuclei_mask, cell_mask = label_cell(nuc_segmentations[0], cell_segmentations[0])
microtubule = plt.imread(mt[0])    
endoplasmicrec = plt.imread(er[0])    
nuclei = plt.imread(nu[0])
protein = plt.imread(poi[0])

# %%
# thhis one looks cropped because it was cropped in the picture
j = 7
bmask = (cell_mask == j)
row_ranges = [min(np.nonzero(bmask)[0]), max(np.nonzero(bmask)[0])]
col_ranges = [min(np.nonzero(bmask)[1]), max(np.nonzero(bmask)[1])]
seg_bmask = bmask[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]]
seg_img = np.dstack((np.multiply(microtubule[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask), 
             np.multiply(endoplasmicrec[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask), 
             np.multiply(nuclei[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask), 
             np.multiply(protein[row_ranges[0]:row_ranges[1], col_ranges[0]:col_ranges[1]], seg_bmask)))
cell_mask_lst.append(seg_img)
plt.figure(figsize=(20, 10))
mask = seg_bmask
img = seg_img
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = cell_mask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
# it gets this weird one
j = 1
bmask = (cell_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
np.max(nuclei_mask)

# %%
# no need to keep nuclei_mask == 0?
j = 0
bmask = (nuclei_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 1
bmask = (nuclei_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()

# %%
j = 8
bmask = (nuclei_mask == j)
i = 0
plt.figure(figsize=(20, 10))
microtubule = plt.imread(mt[i])    
endoplasmicrec = plt.imread(er[i])    
nuclei = plt.imread(nu[i])
mask = bmask
img = np.dstack((microtubule, endoplasmicrec, nuclei))
plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.show()
