# %% [markdown]
# # Solution of ASHRAE - Great Energy-by-lightwave-wang   Top 5%

# %% [markdown]
# Contest  [ASHRAE - Great Energy](https://www.kaggle.com/c/ashrae-energy-prediction)

# %% [markdown]
# Exploratory data analysis [EDA](https://www.kaggle.com/findyou/ashrae-great-energy-eda-lightwave-wang)

# %% [markdown]
# `EDA include:`
# * checking missing data<br>
# * checking outlier data and abnormal data<br>
# * Data distribution diagram<br>
# * checking timestamp
# * Missing values fill the exploration
# * and so force

# %% [markdown]
# `final scheme`

# %% [markdown]
#  <img src="https://s1.ax1x.com/2020/05/10/Y1xfvF.png"  width="620"/>

# %% [markdown]
# Two lightGBM [code](https://www.kaggle.com/findyou/clean-and-divide-half-by-month?rvi=1)

# %% [markdown]
# separte modeling and simple data clean baseline [code](https://www.kaggle.com/findyou/clean-up-separate-modeling-lightwave-wang)
