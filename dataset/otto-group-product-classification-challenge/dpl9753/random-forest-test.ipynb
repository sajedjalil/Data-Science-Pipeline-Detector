# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_train = pd.read_csv("../input/otto-group-product-classification-challenge/train.csv")
df_train.head()

# %%
df_train.shape

# %%
df_train['id'] == 12376

# %%
df_train.corr()

# %%
df_train = df_train.drop(['id'], axis = 1)

# %%
df_train.shape

# %%
df_train['target'] = df_train['target'].map({'Class_1': 1, 'Class_2': 2, 'Class_3': 3, 'Class_4': 4, 'Class_5': 5, 'Class_6': 6, 'Class_7': 7, 'Class_8': 8, 'Class_9': 9})

# %%
df_train.head()

# %%
X = df_train[df_train.columns[0:-1]]
y = df_train['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=10)

# %%
classifier = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', max_depth=5, random_state = 10)
model1 = classifier.fit(X_train, y_train)

prediction1 = model1.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction1))

# %%
classifier = RandomForestClassifier(n_estimators = 20, criterion = 'gini', max_depth=5, random_state = 10)
model2 = classifier.fit(X_train, y_train)

prediction2 = model2.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction2))

# %%
classifier = RandomForestClassifier(n_estimators = 20, criterion = 'gini', max_depth=10, random_state = 10)
model3 = classifier.fit(X_train, y_train)

prediction3 = model3.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction3))

# %%
classifier = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', max_depth=10, random_state = 10)
model4 = classifier.fit(X_train, y_train)

prediction4 = model4.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction4))

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', max_depth=10, random_state = 10)
model5 = classifier.fit(X_train, y_train)

prediction5 = model5.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction5))

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'gini', max_depth=10, random_state = 10)
model6 = classifier.fit(X_train, y_train)

prediction6 = model6.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction6))

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', max_depth=50, random_state = 10)
model7 = classifier.fit(X_train, y_train)

prediction7 = model7.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction7))

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'gini', max_depth=50, random_state = 10)
model8 = classifier.fit(X_train, y_train)

prediction8 = model8.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction8))

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'gini', max_depth=100, random_state = 10)
model8 = classifier.fit(X_train, y_train)

prediction8 = model8.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction8))

# %%
classifier = RandomForestClassifier(n_estimators = 300, criterion = 'gini', max_depth=100, random_state = 10)
model8 = classifier.fit(X_train, y_train)

prediction8 = model8.predict(X_test)
print('정확도 :', accuracy_score(y_test, prediction8))
