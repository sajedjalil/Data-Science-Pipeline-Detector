# %%
print("hello world")

# %%
import pandas as pd

import re

data2=pd.read_csv("../input/siim-isic-2019/ISIC_2019_Training_GroundTruth.csv")
#print(data1.target)
data2targetlist=data2["MEL"].tolist()
#print(data1targetlist)
data2imagelist=data2["image"].tolist()

print(data2targetlist)
print(data2imagelist)
#print(len(data1targetlist))
#print(data1imagelist[1])
t=0
j=0
mel2imagelist=[]
for i in data2targetlist:
    if i>0:
        j+=1
        #print(data1imagelist[t])
        mel2imagelist.append(data2imagelist[t])
     
    t+=1
    

#print((mel2imagelist))

# %%
j

# %%
import pandas as pd

import re

data1=pd.read_csv("../input/siim-isic-melanoma-classification/train.csv")
#print(data1.target)
data1targetlist=data1["target"].tolist()
#print(data1targetlist)
data1imagelist=data1["image_name"].tolist()

print(data1targetlist)
print(data1imagelist)
#print(len(data1targetlist))
#print(data1imagelist[1])
t=0
j=0
melimagelist=[]
for i in data1targetlist:
    if i==1:
        j+=1
        #print(data1imagelist[t])
        melimagelist.append(data1imagelist[t])
     
    t+=1
    

#print((mel2imagelist))

# %%
j

# %%
import os
os.mkdir("./mel")

# %%
import glob
import shutil
import os
import time

src_dir = "../input/siim-isic-melanoma-classification/jpeg/train/"
dst_dir = "./mel"
t=0
for i in melimagelist:
    shutil.copy((src_dir+i+".jpg"), dst_dir)
    t=t+1
    print(t)

# %%
import time
time.sleep(10)

# %%
import glob
import shutil
import os
import time
t=0
src_dir = "../input/siim-isic-2019/train/"
dst_dir = "./mel"
for i in mel2imagelist:
    #time.sleep(0.2)
    shutil.copy((src_dir+i+".jpg"), dst_dir)
    t=t+1
    print(t)

# %%
import os
os.chdir("./")
list2=os.listdir("./")
len(list2)
list2

# %%
import os
list=os.listdir("./mel")
len(list)

# %%
import os
list=os.listdir("./")
(list)

# %%
import time
time.sleep(10)

# %%
import shutil
dir1="../input/isic-2019-and-2020-melanoma-dataset/isic19_20/nevus"
dir2="./nevus"
shutil.copytree(dir1, dir2)

# %%
import os
list=os.listdir("./")
(list)

# %%
import os
list=os.listdir("./nevus")
len(list)
