# %% [markdown]
# # f1 score: 0.960872 | recall: 0.978045 | precision: 0.945134 | acc: 0.988291
# # specificity: 0.990192 | sensitivity: 0.965897
#
# # if some one need my work contact me on this @  (tikobigboss@gmail.com)
