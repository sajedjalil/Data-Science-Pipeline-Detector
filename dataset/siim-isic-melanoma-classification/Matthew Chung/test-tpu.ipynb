# %% [markdown]
# #### TPU based on https://www.youtube.com/watch?v=DEuvGh4ZwaY&feature=youtu.be

# %%
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
# !python pytorch-xla-env-setup.py --version nightly --apt-packages libomp5 libopenblas-dev

# %%
# !pip install -q efficientnet_pytorch torchtoolbox ipdb

# %%
import torch
import torchvision
import torch.nn.functional as F
import torch.nn as nn
import torchtoolbox.transform as transforms
import torch_xla.core.xla_model as xm
import torch_xla.distributed.parallel_loader as pl
import torch_xla.distributed.xla_multiprocessing as xmp

from torch.utils.data import Dataset, DataLoader, Subset
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold, GroupKFold
import pandas as pd
import numpy as np
import gc
import os
import cv2
import time
import datetime
import warnings
import random
import matplotlib.pyplot as plt
import seaborn as sns
from efficientnet_pytorch import EfficientNet
from sklearn.preprocessing import LabelEncoder

import ipdb
from tqdm import tqdm

# %% [markdown]
# #### TPU

# %%
try:
    import torch_xla.core.xla_model as xm
    import torch_xla.distributed.parallel_loader as pl
    _xla_available = True
except ImportError:
    _xla_available = False
print(f"_xla_available: {_xla_available}")

# %%
if _xla_available:
    device = xm.xla_device()
else:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

device

# %%
IMFOLDER_TRAIN='/kaggle/input/melanoma-external-malignant-256/train/train/'
IMFOLDER_TEST='/kaggle/input/melanoma-external-malignant-256/test/test/'
# # cont and cat features
cont_features = ['sex', 'age_approx']
cat_features = ['anatom_site_general_challenge']

# %%
# read in csvs
train_df = pd.read_csv('/kaggle/input/melanoma-external-malignant-256/train_concat.csv')
test_df = pd.read_csv('/kaggle/input/siim-isic-melanoma-classification/test.csv')

# %%
def foo1():
    foo2 = torch.ones(3,3).to(device)
    ipdb.set_trace()
    print(foo2)
foo1()
