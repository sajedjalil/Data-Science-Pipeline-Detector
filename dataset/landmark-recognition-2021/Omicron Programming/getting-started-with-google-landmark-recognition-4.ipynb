# %% [markdown]
# This is a simple notebook for beginners to start with making submission. You will find the notebook useful if you want to submit your prediction.

# %% [markdown]
# **Essential libraries**

# %%
import pandas as pd
import os

# %% [markdown]
# Get test file names thanks to:
# https://www.kaggle.com/hdsk38/pytorch-starter-inference-efficientnet

# %%
test_filenames=[]
for dirname, _, filenames in os.walk('../input/landmark-recognition-2021/test'):
    for filename in filenames:
        test_filenames.append(filename.split(".")[0])
test=pd.DataFrame({"id":test_filenames,"landmarks":""})

# %% [markdown]
# write submission file

# %%
test.to_csv("submission.csv", index=False)
