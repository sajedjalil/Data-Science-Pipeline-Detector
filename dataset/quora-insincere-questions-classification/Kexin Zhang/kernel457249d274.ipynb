# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# import csv

# qid = []
# with open('//kaggle/input/quora-insincere-questions-classification/test.csv', 'r') as read_obj:
#     reader = csv.reader(read_obj)
#     # writer = csv.writer(write_obj, lineterminator='\n')
    
#     for rr in reader:
#         if rr[1] == '1':
#             qid.append(rr[0])

# qid[24000:]

#     all_lines = []
#     row = []
#     row.append('qid')
#     row.append('prediction')
#     all_lines.append(row)

#     line = next(reader)
#     i = 0 
#     for rr in reader:
#       print(rr)
#       new_row = []
#       new_row.append(rr[0])
#       new_row.append(flat_predictions[i])
#       i+=1
#       all_lines.append(new_row)

#     writer.writerows(all_lines)

# %%
qids_1 = ['0000163e3ea7c7a74cd7',
 '00022821df8a68a75506',
 '00025f4a23df8d58e6ff',
 '000383e4ebd22f6ede04',
 '00046c9db89b3d758708',
 '00077e9f6f1069806a96',
 '000e0b7f33650a320964',
 '00119f4b87fa5c1d2b00',
 '00128617c44fbc12064e',
 '001457749528fa6b5c95',
 '0014f5a87fe4c3a3275d',
 '0016446a2eb6a47ed650',
 '001d1f28b0627b3b5186',
 '002249cfbc29aef5211c',
 '00252bc32725ca81a493',
 '00267d4c23debc4f18e3',
 '0028dbfb52497714e3ce',
 '00302fe694a5b40e4c18',
 '003069ba70645b15c3ba',
 '0030959cd3a9a4b4eb05',
 '0031122d8bb9b9c1247f',
 '00318757148011529305',
 '003192bff7e25cb85774',
 '003271077e63edb79338',
 '0032e304b8bb1163267e',
 '0033c7263cce830e76bf',
 '0039457910b8a802121b',
 '00394725b89f58c655e8',
 '003effb596d5c6f3846d',
 '0042c5ba2a6f53805640',
 '004ae9a37f00453c21fb',
 '004b1c4ec1171f2d76aa',
 '0050d1bad98017755427',
 '0051fdb89097d6ceda2e',
 '0054d756f89ad96277ca',
 '005a83f467376da69e9e',
 '005a97f5d339f5a9d940',
 '005cd377c8ff9789de22',
 '005dd3ea24fb89b397c2',
 '0061c39bba71f03ac780',
 '00631a2fa210a68963ff',
 '0064a214d83d197ce328',
 '0065a918a1bf2fc122bc',
 '0066907ab7112ea3288e',
 '00670d51dabae14d1c51',
 '006c2a8079ef0b8dc9bc',
 '006cc1172bd4d3b3bbb1',
 '006e18e8d4edb397a7c0',
 '006fd0a7b434c877900e',
 '0071c2ce77440e5a1d22',
 '0073363cb798c1251207',
 '007450f45c1db580f97e',
 '007e65e4441890f4416b',
 '00811c78c47801b5700c',
 '00878b7a46e866d18c9d',
 '00888dc5bfb277276e36',
 '008c09d908a175160cd2',
 '0090faa0f005311e79bd',
 '009cd2b8d3e22c4cddc6',
 '009cf62985ead054a8ad',
 '009ddb99e9bb982e7c30',
 '00a1de079178499e2baa',
 '00a408ef863c9a1e1373',
 '00ab684f788bebd5b8f2',
 '00ae76dc4b0fcfe01ad5',
 '00aea41d7cc2155bf5b3',
 '00aede95105f73f1e431',
 '00afe6b7b2d4a245a57e',
 '00b1937e743725fb5ea6',
 '00b20cc94e2fe7c75b6b',
 '00b88cbc0f16df51c0d0',
 '00be60dbcb8cd0516a9b',
 '00bf3f35a6d090c70534',
 '00c11db0acb0a57b6760',
 '00c37df6ac6c583da8f9',
 '00c7d959eae5e92313c0',
 '00c7e431fe2f4bdbc063',
 '00cc2900b9eecee93434',
 '00cc528ea9385027d066',
 '00cd2a9ddf79d313a8f8',
 '00d2925dd74f0074a364',
 '00d2bef0df771b0511d5',
 '00d41cdfe59571ee3467',
 '00d6b3c3e9267f280d11',
 '00d7a08a3d1aeac0b262',
 '00d9da44319cc001bf0a',
 '00dba5475fb686719e46',
 '00dc4259284a151a293d',
 '00e01df74fe392613035',
 '00e0a85940fc714bf221',
 '00e31d9167c2e97bb194',
 '00e410edce33a600cff6',
 '00e59218efb4d82c816a',
 '00e6aad042d3a588cf90',
 '00e8e397dab5f2c02478',
 '00e9d69f3f8e949d85f3',
 '00f04c501899ff7fb6f5',
 '00f0f9fb0d16b2bebe96',
 '00f395deffe61e591d44',
 '00f58250250afb9adf17',
 '00f5a35003a01c76ce1c',
 '00f74ea380df52412f21',
 '00fb0cc1efdc102c661f',
 '00fd7bfcaacd053d9a9a',
 '00fe46e5753e7160aa11',
 '0103127c03e365138544',
 '01050b3cd304f1e0f528',
 '010586c1ccd21d1e970c',
 '0107e342190e4cd379a6',
 '010a58425a9184d0996f',
 '010a8dddaa14a80b73c7',
 '011036ebf50ecb44ce43',
 '0112af78798b8693add2',
 '0114eec3e5189bd1bbf5',
 '011cbf7d0c3e8d514789',
 '01258f662fdf19b0c4f7',
 '01286131b91ed5199847',
 '0129d27ef260837eba6a',
 '0130a98dab4078e68ec7',
 '01312372fcfbd079831b',
 '01318ff649962f24878d',
 '0135d2e0888fe9ea80a5',
 '013771519b67a8f127dd',
 '01391ec18231f5e1ced4',
 '0139ef9506845dc02575',
 '013ac13125102fb35e82',
 '013b4427d6219700ef08',
 '013c29225b2996cc8532',
 '013ce451075ad47c65e8',
 '013ec3258d14dfaa302d',
 '01407b92fa9402d2d179',
 '01482c40a2268063ce9e',
 '01498fa4d8ce4f696fe2',
 '014c51e19ab0cdcdc1e3',
 '014c7250b9c301e51c84',
 '01586ff15999ee40ecc3',
 '01587b8ab2d226099341',
 '015b3478009d6cd05d60',
 '015daf17f40e870eb81f',
 '015e008d105086af83ab',
 '015eae832c4e23d04206',
 '0164e00147e6994b06af',
 '01650d3b2f7c1813f1f7',
 '016757bc195299b8e003',
 '016958b5ab18a57281a9',
 '016dcd0ac3634376e6fa',
 '016eaf1d76c7a8a288b0',
 '0172e171d30f5b600e0e',
 '0173663cd6df1a713110',
 '017670f38b8fbe6c497a',
 '017841f4a6311b3b3c0e',
 '01790259d10378ca9921',
 '017a34f151ad59f1eab6',
 '017db6f94b908ac67a7c',
 '017e12676e5be12d398f',
 '017e19fe9094d6ca60c0',
 '018267ed37d204b4d007',
 '018849d9ec1669388a48',
 '018968dde24b55941be6',
 '01896b452f3006b23c39',
 '018af7b3498954798245',
 '018d46278ae02ee8c147',
 '018e6da2fef05b568fec',
 '0192157b416c66bb5210',
 '0194851530db462a763b',
 '01954c06ba67e22d013c',
 '0196f2da78989e3a8fb3',
 '019b36c8abd1c3549e93',
 '01a0a28dac0718d77a99',
 '01a0a87a584426bd33e2',
 '01a2e721484d222a0088',
 '01a3b5c02b6eea8ebeca',
 '01a469838b0a24203000',
 '01a46a2c35858467fb3e',
 '01a50498d3edd3edbe50',
 '01a63b0703da6acaf382',
 '01a724daa9add5d5c7db',
 '01a73e8a474eb1443021',
 '01aba6ab5d74e6763a5b',
 '01b3702d030d5d4f6746',
 '01b4f7a82ec780deea17',
 '01b89fdef759651494b2',
 '01bc2b72533b4e765297',
 '01c5f5ea723c68afccc1',
 '01cc082948f6ee314234',
 '01cc78debec1cce6789f',
 '01d0ce38b1631722e95f',
 '01d395014a13568042f2',
 '01d58b9b6cdd0eeda5ae',
 '01dde3bbb59597985e49',
 '01df6cc82adcbac2f32e',
 '01e19bbae954b8a3e71d',
 '01e1b649828b146ee930',
 '01e3405783e19841fd1e',
 '01e5600ca8314a322987',
 '01e65e0a433c2eda64de',
 '01eb718df2a0123631d9',
 '01ed902a198846f12dcd',
 '01ee4ade6f76b3279553',
 '01ee8f7b68408e95c65b',
 '01f053d48d8412481925',
 '01f1d4035b9c47ce8f2e',
 '01f3449e981f11723f1e',
 '01f353abf2ddab578e98',
 '01f58ac5f8bee37173fa',
 '01f69ffe20af7bf0ef41',
 '01f7f6feb6e7d35fec09',
 '01f9771f108b29c6b09f',
 '01fd48ae079bedfff90d',
 '01fe89ce2ed14134a130',
 '0202dfcc6e7361b33dac',
 '020c180b087c4b340968',
 '020d52504e03d9b76150',
 '020faff1996a187c8827',
 '02119796acaf48410eb6',
 '0211bfa827579ef97d5c',
 '021453119f6265598ad1',
 '0214e09779447451b382',
 '02157ce442a316f5b6b4',
 '021595a5aca648423937',
 '02180700dfd455cbc86b',
 '021d1a0a289b38bb5f22',
 '0224d9feb435469eab89',
 '022aa0936199d8c6dd95',
 '022aacc8a897346c2ae3',
 '022b56a47d049aa3e97f',
 '022e195e536f9a3b320c',
 '022ec1b7c5faeb09fc5b',
 '0230b54be2b35768b4b4',
 '023530c16b35de3ae39f',
 '023612adb243e0085d1a',
 '0237cdecd355bb3501e5',
 '023b7188330aec01a538',
 '023bb85a09e5edc42cbb',
 '023d81c66bf254acec4e',
 '0243b437313c6d43f83b',
 '0250fea71ce272ddff0f',
 '02518ca78e8259dce674',
 '0251f9a7fe7073b52b97',
 '0257c953282bbbaad10c',
 '025ae310203547935a93',
 '025be31fdf1d9177c808',
 '025d7cbf4cca9fdca60e',
 '025f91c3c23269deb808',
 '02608971fb4e5f52bcea',
 '0262bc669598589b8cd9',
 '0262c5734c1bef1800a9',
 '026799710a3079815b5e',
 '0268a67d380d0e24a666',
 '026c99bd9faacbc0a201',
 '026f3638e565dd591600',
 '026f412d670c760b819c',
 '0272466962d74e022dcf',
 '0274731b1ef07be69972',
 '027585e9c359f20f730a',
 '027783a6d46bf3a2a2e2',
 '0277ee00fa7db7862b5d',
 '027d25a48c2ecb976c82',
 '0280c075a9b0f9de1428',
 '02812ba2315f074e1a47',
 '0282234b267fca70687e',
 '02862138ca75bc8d0791',
 '0286efed898e156b1855',
 '02874843aaf69d5153c6',
 '028b4db31f4533ba4c67',
 '029598bf54d3b12ab1c8',
 '029a67dedd1c11eae4d3',
 '029b3e40a9769a53fe1e',
 '029c05f255064347c575',
 '02a3048e61832fe5028f',
 '02a35085e4f8dfc45c25',
 '02a53937fdb7914df824',
 '02a5f133df0e1412fe1f',
 '02aa4efa3626bd81dd00',
 '02ac7493635c8802bc76',
 '02b1757ec7bb71de1b1d',
 '02b8913f6d321aebcc98',
 '02b8fc0c3b4c18f3a151',
 '02bb22b38b82f74a0850',
 '02bc5b5401934d9b37ec',
 '02bca4b6808c71632412',
 '02beb39fd81fb9c1546d',
 '02c14ff70d26f371d5f3',
 '02c29647e2b03b74a4ce',
 '02c436f10c279ef33458',
 '02cc8005422f2ca7bb01',
 '02cee5f439cf63dd8c03',
 '02d0e5d3d3425fba2312',
 '02d10fa8d546d5b1f144',
 '02d351c86fccde0f0dcb',
 '02d5d28439310811795e',
 '02d8071f29304f91ef8f',
 '02d82d56926b9edb1b7c',
 '02d83f287f4cae2c623e',
 '02dacea8e376368e36e7',
 '02dc41fd23b5c6c15ca8',
 '02dcc932f7a144098b6f',
 '02dde45b6149ae427c57',
 '02de0d900e04d9a14b91',
 '02e0a6357c85e530376c',
 '02e67f571c2a6152592c',
 '02ea334970834d84e152',
 '02ea82b1105d28c4f3a4',
 '02eca7cc51eb303e1a57',
 '02eccbe1acbc378b537a',
 '02ed71caa48864c45929',
 '02f1e0862063322a082f',
 '02f786ddfc4b924cc48a',
 '02f9d25be05cb5be346c',
 '02fc7c9c4d43771b3608',
 '030014fe85041fd3b16c',
 '0303117110ab81f5d9e8',
 '03039ba7aaa490b30463',
 '0303b5ab02ca7424b6df',
 '0303eeb8501107d77062',
 '0304e9a89e821fbaa891',
 '0306424fb91db7f1a391',
 '0307dc50b3012857e7c6',
 '0310524f3f7214b133f0',
 '0312da03beeba5fa51de',
 '03162657b14d2de04818',
 '03181ae64eaa4b6a4c02',
 '0318c6981e72d93417c2',
 '031eab1bfd1ac03ff154',
 '0327d14061a0559b29c7',
 '0328b9fb589bd224ff87',
 '032c41842a63240b8fc5',
 '032d9a352e843ddb43d1',
 '0331c9cad0d96bfd9110',
 '0334d1d517983c68fe75',
 '033517e0c3c6c79f8afd',
 '033bcfa3a03f114bb4dd',
 '033cd10f531d247798ec',
 '0340b662f7eb5261f168',
 '0343f0128556a65a31c9',
 '0349a44365f3fc95c9b3',
 '034b21d039750d9391e8',
 '034c0efe6eae686b51f2',
 '03518a5e955df9640abc',
 '035b46fef8c9e3c088d4',
 '035c4b25692238e3da72',
 '035c9ce3f9ce9d749c35',
 '035d60eee171237ccf16',
 '0365b7483a493ae08c9c',
 '036b5dc734a4cca526a8',
 '036c3568e5a5834f25c1',
 '036f23df38a5130781a3',
 '0375772ca364174b3e0f',
 '037a73bf3ca8c09361da',
 '037daa106b9ae01dc9f9',
 '038c72d3d0e7d32d8ed0',
 '038eac5f70a9d2ebb552',
 '038ed283cba4334aa0ca',
 '038f7b7a71992023272d',
 '038fc5e5580cfc52a798',
 '0392168c006fd3031e34',
 '0392f93f9467451feef6',
 '0393a401f70b80c83efa',
 '03963c45173b0927faed',
 '039d683f76d12e7a2cc3',
 '039e4b44233bd67612f1',
 '039e863f6e1b4cd406ed',
 '039ea33e39d597efe263',
 '039faf2692bc150949ec',
 '03a2ad3985575d92c52b',
 '03b23245fa02f1bd82fc',
 '03b29ffe2ab35d23d835',
 '03b2f58b5076bc1ef7dc',
 '03b40676abb65f1ef002',
 '03bf67b343f0e851a352',
 '03c16e44ec603a4261df',
 '03c66255c6c040897c59',
 '03cd6c555f8b0d4f8722',
 '03cf2945719811759cb0',
 '03d1b6e4fb8c246d3771',
 '03d382e327749747c5a2',
 '03d74803777e9d51339b',
 '03dc19d817d1668a372c',
 '03dd6e682209eb8f2fda',
 '03ddb4db64ad6bc63f2d',
 '03e00094e64e2494eed3',
 '03e189b7e53accd30fb1',
 '03e321a6455b5ddb9a1b',
 '03e344753f10f059ead2',
 '03e99e19d9faca5dfdc3',
 '03ee6f03d4998784939e',
 '03ef6389207a74fee05f',
 '03f2a573de8d549c8656',
 '03f4222d228179eae09d',
 '03f6024000cbf379b046',
 '03f614328b071ee35c1f',
 '03ff96674afb1359a370',
 '03ffafd9dc2c9cab4366',
 '0400bd7d8a38b933b52f',
 '04034126862f4680a35f',
 '0403dfaf8a21968e7371',
 '04068b1639205222225f',
 '040729d6f4a86ad23a6f',
 '040c42a91a664938be22',
 '040ce4c6fd406e7e259f',
 '041874ce95c7ac74cefa',
 '041c9491cb2d88ccd803',
 '041d97771b92e33e9411',
 '04235e3d6573a2d3f09c',
 '0423b8dfaa40bf811793',
 '043197fb2157edcc9121',
 '0433eb889ed39d46c278',
 '0437eab3a5a861c9a4e1',
 '043854b9019833eb9dd0',
 '043d54e72ea7c087b6f1',
 '043fc9e01fd0b5e78172',
 '04419d709dba7f6861a3',
 '0446d9c4fac6a3cf3ba5',
 '0449f5931e33a023d7a9',
 '044aa3d1fcae617079c5',
 '044d6aea041bead8836e',
 '0451b5fa114876c9c7d7',
 '045d24a07823b7c2b762',
 '045f155100816f0bcf6c',
 '04623178a2a91d37b36a',
 '046388f7a0e97d436964',
 '0464b9a7b883a2088d33',
 '04667ab41da4b00dccf1',
 '0468720e72deeddae382',
 '046a503132f05649746c',
 '046b84604283697ce136',
 '046fe1dbeb573992fcc3',
 '04767f13395c998d0371',
 '04796690231e7a5a2bd1',
 '047c8b06e169c35f0312',
 '047cc2f33a355c5f6df5',
 '047e3f4ef9ec3825d4ef',
 '047ec27824b10353ef9e',
 '048192fa7bddabab2b5a',
 '04849bf6ae84bf26c9be',
 '048cd41240ccec1ee1bc',
 '04902e404cc640ff98f3',
 '04927b97c6f68e7ada98',
 '0494cf5e254ff6e605a5',
 '049630e7e7b90b8265f2',
 '0498073f0e65a0732ca2',
 '049fe4799135da92d85f',
 '04a120405172dcafb9a0',
 '04a151d09ada23a549d0',
 '04a7445676d9ab1123fa',
 '04a9b10f4cf416e47d99',
 '04acedb61db4f4ac0e01',
 '04adf94be097c2e5ff7b',
 '04b327f14bc227b5b30d',
 '04cb4bc4a820fc715c7d',
 '04d88e9326fe9b9cb8dc',
 '04d917bc90c4c95898e0',
 '04ddbe41bfeaabb16579',
 '04de8391833b929dd905',
 '04e5e5e751fae6bc8437',
 '04e9ddd4af93f898cd25',
 '04edf9c9142063e06131',
 '04f20c239bc5d4968031',
 '04f67c4819f48e522046',
 '04f92e5751176d0a3142',
 '04f9a2c58abc1bef2fcd',
 '04ff65fd5a36e333ab2d',
 '05040c77923ae90e4a88',
 '0509df3dc88352e55c66',
 '050a637b3bc24fd8a672',
 '050b7fbb3a31a4daac4a',
 '05100f5f702335648719',
 '05104efbaeb80540579c',
 '05108be9200dc693d0d0',
 '05138ec346c1edc9bd11',
 '0515a44e8d652071575e',
 '051f6a7864453c9d94a7',
 '051fe7ad3b3beb13c7c8',
 '0521e5b8e55a69ebe4aa',
 '052224ecd5a14684a959',
 '05224644888d09c9df91',
 '0522e9da542c6ddc22ba',
 '0525319f05df48178f21',
 '0525a5a5463ced38bd5e',
 '05275601a4bd8833b82c',
 '05275f7885753dbb0eb5',
 '0529bf5a5980f9962089',
 '0533602f3912ec7f5af9',
 '053973b3db7ab47aac8b',
 '0541fd6f8a432d8613b5',
 '0542304a9cae021856ff',
 '05426f49867ba5d5b96e',
 '0545aad3da19182b521e',
 '0546d127f8bfc1f10102',
 '05492a25524c0d84d2aa',
 '054a329e92a89d6b035d',
 '054a6c1f24e3067dd21a',
 '054fe82f262f126e04b4',
 '05518f4ec8c4c80bcd12',
 '05518fbceea806e948e6',
 '05549cc7c99574b07ea1',
 '055a462fd1ea777f92a2',
 '055b92aed90a8c3cf733',
 '055f4b7171bfa0f0de09',
 '055ff46a9feb413ca85f',
 '05607a0dc87cb15f7f9e',
 '05608f5a2f551e489570',
 '0561eea183323ff05c71',
 '0563116668149e2e289a',
 '05640bc7b26089442cf6',
 '056923d90c9d8e0adec4',
 '056eb4d40cb526da2055',
 '056eb719fc5da86d15f4',
 '05733fcfede2617694ff',
 '0575b97b7143c5c6697c',
 '057c4ddf83d174ca213d',
 '057d6e1ce7f989d661e5',
 '057e50eb9751f82e28fd',
 '057fa64c993e6570e44d',
 '057fce86472a1e336fea',
 '0582940e2d8ef11e47cd',
 '05839fa4a62511401262',
 '058547e25b809d0ad64f',
 '05855401c1682f7ad08b',
 '05876dbdc9dfc91dc33d',
 '05887484718761f30790',
 '058adc14b59a5a833a10',
 '058d548e0828ae0e2954',
 '059292a0437237ec34ee',
 '059578d94f047e6bb26a',
 '0598e3ceb0d5d8945d57',
 '059910954e602de3201d',
 '059aff32cbcdd27b0a2d',
 '059d256bac5c9468318b',
 '05a166bccb6c1264ebb8',
 '05a19680bdf8bb7321c5',
 '05a3491f2911a5da4e17',
 '05a855958f3ad99c8ad4',
 '05a8d61fe1af3d45fc2e',
 '05a9e7c26410e87454b9',
 '05b3581a56b3e41803ef',
 '05b45b1871008381c3bc',
 '05bb36bf79e9f8ca1abb',
 '05bd60aa2a27c8c9e035',
 '05bd7aa13e34021db712',
 '05c19e11b343fbeb117b',
 '05c25fda6be53372d112',
 '05c2b9e32a9f7d3e69a6',
 '05c3be92bbcec3dc11a3',
 '05c75a1fa27bdca8520a',
 '05c9ac3d9217065c3fe9',
 '05d02b3d7d9f439caa23',
 '05d0e83cd9581a2b1bdc',
 '05d2a9a14fc0cb45e08c',
 '05d746c6711e5013bcb1',
 '05d868fe63671040a014',
 '05dc060e77e0fdff1975',
 '05e825e0e890fe3726a9',
 '05eadbaee9563855550b',
 '05eae10753b3da4dd5d9',
 '05eb4364445a56b179e9',
 '05ed146e3a59a3b3b914',
 '05f2356d70dbaf765217',
 '05f7009c3afa7778f536',
 '05f92f283ed0b331c8c6',
 '05facae3d73d62bf9992',
 '0600ec8ba9591fe0c105',
 '0603574209a8313912ae',
 '060444e14588eec3dc1d',
 '0605adafd37243fe8cba',
 '0606aee96b45dd9b0c8e',
 '0606e10f22f4b9e65e5b',
 '060822f71e4f260d950d',
 '0608fe81a49824ac509b',
 '060cc2724cbec41aa87b',
 '060ed31a4fba77305bbe',
 '061484633a53d1c9e62f',
 '0618a97ddae02c942506',
 '0619ec90645a50d7def7',
 '061caf8ee8897112ab38',
 '061ff73d2c77778a7ad2',
 '062235354a56eb416239',
 '0622c7f3a98ee2ae9baf',
 '0626786ec1abdd84c2c4',
 '0627c0941fba3d0d61af',
 '062bf21d679d958c7a6b',
 '062c44a87200fbf986dc',
 '062d8a2b8e041f2c9a63',
 '062fe8e28a68af66377e',
 '06301d4b8abf39b29d96',
 '06317249d75cedea3913',
 '0631cd1e4f175912c412',
 '06391f2ed4261a525d7a',
 '063a7b8b7a077243abfc',
 '063a96952e45f0b45988',
 '063cd8167b378e135b90',
 '063d09523d56934d3f12',
 '063d45c69198b4aa6a2a',
 '0640ce9faa2168f7fe91',
 '06489f75c62cdb87b2c3',
 '064901a8503a2dcdf08b',
 '064a0081c6ec4e6d5723',
 '064bf9a1f25488e9ca66',
 '064dcfe4865970a587da',
 '0650339c94ab09aa1575',
 '0650f72900c975de3b9c',
 '06531be4349f23b59259',
 '065592feb8518ded9474',
 '0656685c770f165d9c3d',
 '0656a03b2cabe70b6c62',
 '0657decb49b91a8bef4e',
 '06587f8449c87a75446f',
 '06588d2c8d06f359680f',
 '065a8f52bf99ac8d8a3b',
 '065adfe6c7fb974ad960',
 '0660e193af0ab8e74211',
 '06619ced000871f00139',
 '0663902b0bc248a15a99',
 '0665059ebe4190779571',
 '0666e56d1e1f972e1812',
 '0667348dbfa171b93968',
 '06688278c3544f8c251a',
 '066933cc884e3d22eae0',
 '066f7029e748c5f291a0',
 '06727e85f0dd3d123d0b',
 '067511977ee81375aee3',
 '0676675ce846e3778988',
 '067890b26f5a14ce9231',
 '0687f211683921c2e236',
 '0689711a8355aa4be394',
 '068e02c6273e8dacc605',
 '068e270d0ca0d9c4184d',
 '068f7ea28f613e8858e8',
 '06980a9184fc73a35d0f',
 '069817774b92d8e76ccf',
 '06993bcfc780a464cbd9',
 '069c78c6f852a6b44924',
 '06a3a801119a165484db',
 '06a5e992c2a5f7db5cbd',
 '06acceeae0a6de201096',
 '06af268fccf830650008',
 '06af99960112376c8096',
 '06b0b0ae306cba49a9e0',
 '06c1ee39599ec16dc7e5',
 '06c5a3f1186d3f9b4f85',
 '06c9c78db21ae69e0e47',
 '06c9eae8c3e61edd19a3',
 '06cb10d62ab4b377176f',
 '06d2a091bf17d96ea8d9',
 '06d4bd39f061983cde25',
 '06d5922e6a28acab1f9a',
 '06d66bd5336a6404e0d0',
 '06d87af9e6ce0e5aac15',
 '06d9e523414461323abe',
 '06db9e3d3a6c977d70cb',
 '06dec40ce2ebc7be73da',
 '06e04fdfa6587e950a09',
 '06e10d9bc6aff4d6302b',
 '06e1514e0fa4d61b0079',
 '06e3f338c24cbbc23ac9',
 '06e550d55bb156c82248',
 '06e63113a04b461b8729',
 '06e894da7832aea898e7',
 '06ec72732008b4e52f50',
 '06ec8d5303d6f7162f37',
 '06eed5e623e6a246431c',
 '06f23f9fef531334c298',
 '06f8b4de4b62ccda516f',
 '06fb9f372cffec1bb9d2',
 '06fda95f79e8a5a96a81',
 '06fe1c600ea874915247',
 '06fe8045e7b4cf3f49b1',
 '06ff9e7fe14b6ed158fb',
 '0706088a159be9441732',
 '070ba5026b3bfa4fdf3d',
 '070cbb0983f923d83a14',
 '070d1bed461316b05302',
 '070fc4a3f4de8d25b96d',
 '071261d11bac4d8fb2c0',
 '071446c3799c47c3b2ed',
 '07189e9a7f01406e622b',
 '071997637dc195af200b',
 '071bbafae58a061b293c',
 '071c4a0c6f72e58bd1ef',
 '07205192cc6f55246cdf',
 '0721ca79cab5b41c5f9f',
 '07220ce9da77f159c214',
 '07222923a32231f73570',
 '072c3100859f2b1182f7',
 '072d66fdacd08fcdee1c',
 '072f593ad9c468a8c9b5',
 '072f5f6553a087a83e87',
 '0732a202da5b78ab4a2f',
 '07367a49fbc59eb4bcfd',
 '0736808c0bb042d263d1',
 '073879689ade2460c6bf',
 '0739b49e759004b28f19',
 '073c422d990c8c1c18c0',
 '07449ac08c59cdaa39c4',
 '074bd50962aab8a9832b',
 '074c5fe1b228d1d018ac',
 '074c7985cf5ed1c2131f',
 '074f83a43038ed1f9779',
 '0752eed8c54f012b11e4',
 '0757106bfdf58c129640',
 '075794becc71998f4fae',
 '075b24e8ddde079ef6af',
 '075b3c8da7d58f94e6f8',
 '075d50b466ba8b843083',
 '076372e49e955c92d45d',
 '0765f61658d3ddae658c',
 '0766bb81eff099ef584d',
 '0770ae715985b7fc67a4',
 '0770bc9c1fdc8fb3b7c5',
 '07716c0cd09807d2d2cb',
 '07796ae722b45a5727e9',
 '077ada096fd8422dd441',
 '077de3dd3f3caeb0602b',
 '077e0734421e16761767',
 '077e8eb4c1c6b150f55b',
 '077f6f988e4c776f8ab1',
 '0780994ca776d27c7618',
 '078175ddae9e54579025',
 '078af81105123874631d',
 '078ba2f6ddb533df0946',
 '0796ac73b533a46617f8',
 '079717cbb4492f505b05',
 '079a9021899b65c15c5a',
 '079ccbe5fc97dfb3ec25',
 '079f529bed9ceb37d2ce',
 '07a7c828fab57976460c',
 '07aeb595ba1057a3d0d6',
 '07b523492e1c567566d5',
 '07b6855d32e750df28c9',
 '07b7625af8578fafddfc',
 '07b9ff0de4d5238a4da8',
 '07ba8adf7115cc9d9501',
 '07bdd286e68240168d4e',
 '07bef80851401284ef36',
 '07c7ff84d0af2a42b794',
 '07c9cf462ff1a062369d',
 '07cb519ffa784ac259a7',
 '07cee396c1f63ab9a6a4',
 '07d0eef16377b3aeb552',
 '07d1cb16119123dee142',
 '07d2b727277affb4b5f2',
 '07d4090849d46f2768f3',
 '07d656fdf53856d31a0d',
 '07d958c8d912f22fbbce',
 '07d9631c330c369a5468',
 '07dc324792430ee32728',
 '07ded7f48b75d1c48781',
 '07dfbd7659845aad48f8',
 '07e3772d7adb0f82a1ad',
 '07e58c2deee77c14a7ed',
 '07e62c7eb1ee1669a7d5',
 '07ebc20e5730ac62cef9',
 '07ebc25406b5c58f5167',
 '07f0ca62f1ea6145c42f',
 '07f249a9fda3bb673de1',
 '07f2c442ced41a28034d',
 '07f4d973f45e6565847e',
 '07ff5eb0a977d02a7b5d',
 '080894d994d99159fa3a',
 '0808b60d620156dc54dc',
 '080cee9ea3c0b5cc1c23',
 '080e133240ab440f747e',
 '080f46ab57d884771d1b',
 '08112e17e6e1bfe082c4',
 '08121f18ab23788f8a32',
 '081512886423b27a1280',
 '08181a94ed48c3c196c5',
 '0819feebff45dbd3f89f',
 '081e24ae9bf960ab5af3',
 '08204d4247249c2cb55d',
 '0821adb6538dd4436aaa',
 '0828e57d0a5a1075e484',
 '0829ef7614e2bb0f6c05',
 '082bfa2527393f5fc8dd',
 '082e4f380191499034bb',
 '082f773c7bbb19d80511',
 '083016fc14da1ae2ab35',
 '0830e4958571fc3b1158',
 '083698452895fda7f23c',
 '0838705e3a7c402dcdff',
 '083c6882fbce3fe16c2f',
 '083ce5cd3cc3860dd606',
 '083e24e45959189d5b73',
 '083fb9d5ba7b53f615b4',
 '084232e210257fd202de',
 '0845050180e44e2ef67a',
 '08483702c3b96645cc27',
 '084a6b69f45e4d0d8e38',
 '084cc741aa37b0e69686',
 '084f44ef9c6db54594f6',
 '085217d197b42ce7b486',
 '08527d0f1f5f32b4e707',
 '0853c693bb3fc8cab58b',
 '0854aa1e6922200c41d3',
 '0855af0cbee824647c97',
 '0858ebabcc58460c2c2d',
 '0860ba1eb5d9e07103b3',
 '0860d8cd51742c1ad5ce',
 '0866338acb26889c8fc5',
 '08675f78b7d4aa0eca4a',
 '086abff1f4ef1d7309c6',
 '086b0e8436a33610bda8',
 '086b747737fdd2c7fecf',
 '086c707c8b601b85c448',
 '086d0862e1b8bac6289a',
 '08704f34d80d18dab931',
 '087192cec5a532464287',
 '0872adeb77a2f92596c0',
 '087ae3f30eca7d1697e5',
 '087bf9ca7c56403d3a3e',
 '0881ed0fde8bc804fa45',
 '08840ad37f805ae5cdf3',
 '0886edf493f577ae9a8e',
 '0888402fc3a41857630a',
 '0891e011c48adac6c7e4',
 '0892b1f8efd2f8a4a709',
 '0892de3c9d72540ac635',
 '08958901d23a1095fe49',
 '089610f01fd59f3f199b',
 '0897071d67af3be455ac',
 '0899c6dfd83c1ef52306',
 '089d26fb88569a9917bb',
 '08a0f1fea94dd985770f',
 '08a6aa399708bd8c326b',
 '08a8bd0fb0dc5ba29816',
 '08a9784e038f2aa0af9a',
 '08ab8227f1e215b28492',
 '08b84466d09ba9b2412b',
 '08ba3e8f553488fb7eb1',
 '08bea637a9cfd50a036c',
 '08bfdb637287b132875e',
 '08c5eac85b765716ec12',
 '08c7b45a20f36ce56d2d',
 '08ca5db09595bdc3d9ec',
 '08cabc37c462d2d4fa52',
 '08cbacf48281b6d01a3e',
 '08cc71e15906afe995e4',
 '08cd199ad8004183f160',
 '08ce5fae0d0d7535918b',
 '08ce90fef5f8c865e169',
 '08d20cd998eca9aeaddd',
 '08d240c6a6764c3cc72e',
 '08d44c61cca24624d92f',
 '08d7915d978ac04e4d7b',
 '08d9e5956956967e3df7',
 '08dd63ff8cf25ce59dc6',
 '08e02db72f95b34ecbab',
 '08e32a16730d33a40b42',
 '08e349d836a07a81bdb8',
 '08e55748b3f46fb68b61',
 '08e59db82d43a4790e84',
 '08e5a63c4fa2b9914778',
 '08e73e781cb3b000c9b5',
 '08ec80a8713c5b166a1a',
 '08f0f5866d32241b01c8',
 '08f522b3233926fb391d',
 '08f5f813f595d4f73d89',
 '08fcb68618b40e3d0278',
 '09053f143e529f7a1519',
 '091257eae53f88a51104',
 '091286af7164f543775e',
 '0918477685876a6b7cc8',
 '091983534667a3b71edc',
 '091cc99aeee40d01ecb9',
 '091d79b5b61436ef8e70',
 '092552c009d7d9492768',
 '0925dae99034b3aacb21',
 '0926124855aaa9783c24',
 '0926c21bbfbbd028e27b',
 '09293f90e16b7ab25c78',
 '092d524a7a73aa0a37c4',
 '093077ebf6ebb88e13a7',
 '09313cd071b793b5534c',
 '09316d9ebd493451db82',
 '093486816e097c5b7051',
 '09365b8248c1eb3d7c0f',
 '0938d32874b4a518a74c',
 '0939b6f8bf05020778a9',
 '093aa870ed6c601076f0',
 '094077b93bc962b6fca5',
 '094910184a3d37dac815',
 '094c50dd7b977e72bc80',
 '094d7439c42cdd38e4ba',
 '095153bbf4a826ffd973',
 '0953e1e44802c7e29f76',
 '095600be2712c3d97981',
 '095696e8c7511596edbc',
 '0958c0308f7e66f127dd',
 '095e4502d3efe65c8f11',
 '096016947e2d15bbc693',
 '0962da295dbad77ca471',
 '09690adabad02507cb44',
 '096975f73ce7465776e4',
 '0969d176318c30771aa2',
 '096c159df05682819546',
 '096fc17b2236c5a97efa',
 '0970c3f8328223b498f5',
 '097196f434c364efdd64',
 '0972d5859f1a9bd98189',
 '09734aac466a1ed5c7b9',
 '0975cbebbd79a34a1ed5',
 '0975fa0cf74c96805739',
 '0979e857404c99d765e8',
 '097d4c4fa9184ef4a0d3',
 '097debefb8dc8ff2ed3f',
 '097e4bc6a37ebf5a0455',
 '098350b9a44dd9cd5a43',
 '09848b8d75a49c95d871',
 '098b1ff91df0ef2e65cc',
 '098b4e55e82229fcc30e',
 '098b958e4f5cf89e6548',
 '098e47b66dd83467cbd8',
 '0990b9e35516bcb040d4',
 '0993daa4950c52f75202',
 '09976521693d40ef2fb9',
 '099cc9070c4cd00678f4',
 '099d8fc7917b1b1302c6',
 '099f6d338f5144a2fdb5',
 '09a1d83ce08a6485c08b',
 '09a5bc77b2218f193bc9',
 '09a75098fa421bd9c844',
 '09a7ac9095f12385190f',
 '09a7bf2d425ffffecea9',
 '09ac9dd2b3e868aa1069',
 '09af37413f67b3b89269',
 '09b03b95915efe016b6e',
 '09b0b982fd58b8dbbdc8',
 '09b1813115b500f0e001',
 '09b2a338b44833090149',
 '09b2dba2532dca659049',
 '09b33542d29e13cfbc08',
 '09b4ec131ae5a373c983',
 '09b6ddc653cd0ad0bc9e',
 '09b7d328dd3c8c2477d8',
 '09b83f534f069eb5f487',
 '09b966814204cb1c64ec',
 '09bb294b0e70f3fc3d91',
 '09beed69c1a8c3b747e3',
 '09c05ae8fcaa884b2fc3',
 '09c61a8b476510565fe8',
 '09ca274d82362a585861',
 '09cb53b1ea93bdf2e9d9',
 '09cdbfeb48598fa08a7a',
 '09cdff4771cb77524fee',
 '09d29c2db1d9921fceb8',
 '09d4776466467eee9fef',
 '09db15a414297d0f268c',
 '09db1c2d0792b8cc40f0',
 '09db39cf02b961f6cbdf',
 '09db8757e9f9d3b2e8dc',
 '09dfb5e105160f9a637b',
 '09dffce9097bc0c1daac',
 '09e1b518929be3242450',
 '09e27c7cc88dfdd17d02',
 '09e4e26aa15b95c00cfe',
 '09ecfb859ba0e3dcabf3',
 '09ed83f55f634f7c2117',
 '09effce3e4228d1b03b5',
 '09f3b845aa50f8c5070c',
 '09f63891648f5614d0fa',
 '09f7d5a54e447a69622a',
 '09f95425171f5dbafbdf',
 '09fca25b50b3dda98c6d',
 '09fcf0cf4fbc4c664dc0',
 '09fd99cbcdc0fabd690e',
 '09ff99cf14114f29b7cd',
 '0a007d7bdb3049519ba5',
 '0a04047e06579ca35835',
 '0a06f42a7b81f61c890b',
 '0a07d9d4c9f162821fa9',
 '0a0997da4330a851a7a6',
 '0a0a02f328ff3b4e38ca',
 '0a0abc88ce385a732d9b',
 '0a0b953ea1352695566f',
 '0a0db95031f5f1121246',
 '0a107d95eff33d014067',
 '0a177ed56e347610f271',
 '0a178450103b0a9b69e2',
 '0a18274bb76aa4d89624',
 '0a20a4a70eac6dd32c6a',
 '0a213d7b9eb81e26e7e4',
 '0a289b6054ca7148018e',
 '0a28c45462932e4de216',
 '0a28d39ea332d133fcac',
 '0a29936ef726fa2b7231',
 '0a2aab94ffa3e59f736b',
 '0a2ac608be05e90d4c4a',
 '0a35b5b8b6c9185b6f94',
 '0a378b07890ed55a44af',
 '0a3793720d89f457a09a',
 '0a380c15852acde6b227',
 '0a38b5616dcd797eb181',
 '0a38c04ae38bed58673f',
 '0a3b98fa2d66cf751cf1',
 '0a3e43c0e2e208f56f29',
 '0a3e7992422734f777ee',
 '0a46e4524e04409c1dca',
 '0a4767e7bc8bb7cb20cc',
 '0a4ef1adf26bdbef106f',
 '0a519d21ac1135f2be61']

# %%
qids_2 = ['0a52b9e1b98589577a31',
 '0a537c9f4263d4c46f3c',
 '0a538cc84a6c8569a596',
 '0a54a9b63fb83d700011',
 '0a55af2345d7f54ef45f',
 '0a5614570e92ed3be483',
 '0a56d7fc8083688dccce',
 '0a57e8e249315de4bb65',
 '0a5e013b34c4d597dd13',
 '0a5e2da8fe37f674102b',
 '0a66a6820374f242bbd9',
 '0a677c725e90f092f1c3',
 '0a6ec421ffaca886e902',
 '0a6f3694f413a41d7d32',
 '0a753b76e94a89849eb3',
 '0a75a264de2aa1b27d1d',
 '0a764646f209d0b9d4b8',
 '0a7d71475d20bea5f71a',
 '0a7db19bbe1c2110152e',
 '0a80d3a30d211710e849',
 '0a82bcfe03666c8676b3',
 '0a8556713053a7c7f11a',
 '0a871882765c383dff25',
 '0a87ce70bb697cefbf23',
 '0a8a14081d38ad6f73fc',
 '0a8b1cf28561ef50230d',
 '0a8cd72b361da98c5e5c',
 '0a8f177e1b914f834cd1',
 '0a9445408237f500e544',
 '0a97dcbaa4c5e28bcc55',
 '0a981f352dcf12f75a18',
 '0a9b30d01fba51131978',
 '0a9ef222dfeae972ff39',
 '0aa038093133cda60de9',
 '0aa8f84e49c8caa4816f',
 '0aa914884d099d863bab',
 '0aaeb57e1d73c2f28571',
 '0aaffca715894a8bde0f',
 '0ab116e7680f50a901dd',
 '0ab43f91885d82ea84fa',
 '0ab567f648bbca6ad50c',
 '0ab6ef36289cb76e6dc7',
 '0ab754436a30b3c0d0ab',
 '0abc101ab439d67fa73e',
 '0ac8933d49812b1a8ca6',
 '0acf5588770a8c5b7fe6',
 '0ad3f4662fc3c246d951',
 '0ad5db801c8c8e3c849d',
 '0ad6d293e34a1ecc4c87',
 '0ad868a23a6191fca236',
 '0ad9039bfa403120678e',
 '0adaceb3e2ca9e02e24c',
 '0add8fc96efc316e4968',
 '0adec67798f91749ae54',
 '0ae1900b3ae6f723d9d9',
 '0ae5d784fad248540e29',
 '0aeb2db692a8b011f0ae',
 '0aef9e07c5c6c8c5f93c',
 '0af11afd22de348d61a4',
 '0af14379690ae43bd859',
 '0af199e4768fd1d05c2a',
 '0af1c0f345bfd2ff9ba6',
 '0af77f1cb5b4f00581e6',
 '0b01339c7aa1ad984694',
 '0b0195ee148c3e82c86e',
 '0b04e5e538ae0fa00146',
 '0b04f3b232523e314df9',
 '0b066c571f2a5805aea3',
 '0b07b5432fc614ca6cae',
 '0b0899cca543b7622e93',
 '0b1016059fa2521d3166',
 '0b10273be5a189e170b2',
 '0b1187687e1a046c516e',
 '0b129a5b414f8760f8d9',
 '0b13d7a0d4b76a0a1fcf',
 '0b198e54143ab7bf2e33',
 '0b1a3c38e9e8869b051d',
 '0b2118093756d246e6e2',
 '0b24b49b93d47005eec8',
 '0b24cbf957171e468ef6',
 '0b25220f40fd3cd85b5d',
 '0b26550881e2664957e0',
 '0b27f43123f82b4c8caf',
 '0b295f1f4d6a2be5a8a1',
 '0b2c49d60fe7c0360e9a',
 '0b2e43c1965fdfc696f1',
 '0b2f4365173488fb7460',
 '0b2f648ad363b2aedb13',
 '0b30cb2f0806b1389e55',
 '0b31a075bc5e21040f29',
 '0b32f586bcf3d2e6495e',
 '0b3f9571dd4c0230e4d0',
 '0b3fed4fdacb70217316',
 '0b449cf99cfd493d6a60',
 '0b44bd18fe0c2c08ee17',
 '0b44f8537f7513ab157c',
 '0b4b2f321132f5c776f1',
 '0b51fda16bdf70566294',
 '0b53c8c12ddc717a02df',
 '0b54349c27a66f20f3d9',
 '0b567aa4ee8dff8f13e2',
 '0b591b56bb276b60c1bc',
 '0b5a91b2d6445c498cec',
 '0b5abc8ec7efeebe9c8d',
 '0b5b4ddeb1ce45ff2aeb',
 '0b5e2d8b910ff654323c',
 '0b5f14861cb27de27190',
 '0b610f9b29b4b76307cb',
 '0b66810a38dc1009f368',
 '0b69ddffaccf35e40543',
 '0b6e5b62ef5ed9cb5bca',
 '0b6f017510b3bcd84178',
 '0b721264f6810a32d741',
 '0b751a45c01ea883ba61',
 '0b76d8355a802020d383',
 '0b7737997dbe7982e44e',
 '0b782bc08ae860911760',
 '0b7dd285d788d5518cd4',
 '0b7f3bab716d33caac60',
 '0b8020091e227862f26b',
 '0b830933b31c9c804a2b',
 '0b83af02da948b5349d7',
 '0b857c612bb7bec1cd98',
 '0b887abac89f54d547f6',
 '0b903119136b0da02c07',
 '0b95b263904c991dae9a',
 '0b9af37c2d424b742fc8',
 '0b9e755f8ad4124f8cca',
 '0b9f6ac8e93b6fcf4151',
 '0ba14f1ca923baa00cb2',
 '0ba30fe8a921eaadb865',
 '0ba7f0691142d1d072cc',
 '0ba9790713ef5dab34ae',
 '0ba9dbdea2119c405017',
 '0bab6ece33c3a619191a',
 '0bafbda82ada068a18f4',
 '0bb8ed8cba2c7ab773cf',
 '0bbaa9f196ac410af140',
 '0bbab1cc7bf98f1f9b45',
 '0bbac34e3cfa0a0c321b',
 '0bbae4b8c9c649ad97d6',
 '0bbdee6a8860d8d62afb',
 '0bbf8277456b02e1ee06',
 '0bc2d8f4b4edd36b5cb3',
 '0bc3f28d9747dc41f293',
 '0bcde9ddfe41e05b156f',
 '0bd29819558c83209eca',
 '0bd67552fe49a4371cc2',
 '0be4184ad07713d6b1f7',
 '0be64ab436593e0fcd63',
 '0be9b07d5685e4d2a324',
 '0be9baed1b1f2caa83e9',
 '0bea04a7965d68314712',
 '0bea58baee1b65eb9466',
 '0beb68a0459105207761',
 '0beb7e281bb99ffe2f35',
 '0bf156d4ef455997379a',
 '0bf506ad68a9f5e59126',
 '0bf61c7c0ffc22163e82',
 '0bfe5692cd796bbcbc2c',
 '0bffbc97db2275e58f44',
 '0c014f522ecd820253b5',
 '0c0287897f72676886ac',
 '0c02f2167d23a7ddfcfe',
 '0c07d99d5b7cf25d4972',
 '0c0fe1a61bc9c5a94f41',
 '0c11efec57456f856654',
 '0c136029ef9ce0dfd0ea',
 '0c13a8f9c462c0a91f0d',
 '0c13ac072c486dd30e9c',
 '0c1502d20092a8fdfb51',
 '0c179b59e83474608e31',
 '0c187054dec29e8075c0',
 '0c18a57c3d3eb46a16bf',
 '0c1cba2630b46987e628',
 '0c1cea0beaa455b25a19',
 '0c21b0fdbda1b0df02eb',
 '0c28c2f8c9f82215d619',
 '0c293af59415bb54f3a9',
 '0c2c4d0ff185960ffe01',
 '0c2e4b95d48852cf92e2',
 '0c3010c8c36ab325a8f0',
 '0c31744a42ebf86b77b2',
 '0c33adae8f49bbf664fa',
 '0c3ab11e85f9452af9a2',
 '0c3bb916acaa9173325f',
 '0c42cee074f7d17380dc',
 '0c452fc2e8eedeea0272',
 '0c4dd4a87e246bfb8576',
 '0c4fe6f4a12c990713da',
 '0c502724e5b8a8decd89',
 '0c5a84149a19b38fdc00',
 '0c5b7e2010fc69b6e34f',
 '0c5bf7512ae52d3cfa6b',
 '0c5dd0138909a31aca14',
 '0c5feda959a0fd2752f3',
 '0c66c4ca1fd490c0fa70',
 '0c6836210ab9a87d3b29',
 '0c6848ffdbd5c61441c9',
 '0c6c8115cbd02f4d1122',
 '0c71993f360e375fc457',
 '0c73e91e390890a1741b',
 '0c73ff9e7e784192da6d',
 '0c74f6466113c72f246e',
 '0c7674bd004924eb07c9',
 '0c775bb4c9f47cd55584',
 '0c7db04567023ae20b55',
 '0c853eef4b085c39caba',
 '0c8f03eee47682b9ea2b',
 '0c8f7f5dcd710f33e059',
 '0c9114429d7ef0cd64ba',
 '0c925309331705ee9773',
 '0c9279fe2228d01aeb44',
 '0c956e0852ba40cbe19f',
 '0c9818c0fd975cb56bb4',
 '0c9a91cd0723659ef0ca',
 '0c9cb72c57a752ebdd73',
 '0c9e44da5c29cbd861fa',
 '0ca13ec1fee110f3beb8',
 '0cab8e4fcbb53ad26a40',
 '0cae1bd6e76a1585f527',
 '0cafad524523f55ab45e',
 '0cb734c0f5b1b5799ef9',
 '0cbb6bc6f63831e29685',
 '0cbc37c7b1c369503285',
 '0cc154e157ce8c3c55a8',
 '0cc1b0929a40d5b7e913',
 '0cc356a08305f05c0e15',
 '0cc59d47c4e7cd011d66',
 '0ccfca659aceb3855c37',
 '0cd35e962c626782aa8e',
 '0cd4878a38e3a36145cd',
 '0cd880c2903bb534689c',
 '0cde0da65963d3a64979',
 '0cde41d4489d1a32e5d4',
 '0ce7e43302b9d217a6b8',
 '0cec0323296d4f567f8d',
 '0cf4e3842d2e127a93cd',
 '0cf7f3f13d9df79936db',
 '0cfa5158430853a1d30d',
 '0cfbb9b79cd99e79d534',
 '0cfca937755fc0bdc1f6',
 '0cfcc53e35b54d31e7f4',
 '0cfdbd656ad75fcf8c54',
 '0d020dd4c1c326fb9b9f',
 '0d03483a9713a80b6d55',
 '0d039eba6d7b7bc8f4db',
 '0d04f7c24bf70bc6588e',
 '0d067bd4110f17512427',
 '0d0b7348a4ce58a78f17',
 '0d0de8aef22e4406deb1',
 '0d0f3999f9be269ab367',
 '0d0fb58218dcfb70a790',
 '0d110ae5578992620647',
 '0d1591e5d3e664e8bcfa',
 '0d15d467efbd19d1f9fe',
 '0d184f48fc86e9fcd8b8',
 '0d1b43192b1ba2bb3d10',
 '0d1d696e8c2326b0c9b4',
 '0d1dcbd2deed993db560',
 '0d288eaf3571e8e87860',
 '0d2bd44acf3af336dda5',
 '0d2c3a8e0d578dae85f0',
 '0d2d444a741653387505',
 '0d2f53324b5b978f8771',
 '0d3152edf303efa0a604',
 '0d36b056aff5b74cc6db',
 '0d3c035aa4df2b657b50',
 '0d3fab59d9856c0b0ed1',
 '0d40653f0c6bba475363',
 '0d42cd3ce82841bde6cf',
 '0d49a9c2371e1012772d',
 '0d4c882232c3d204337f',
 '0d546ece2dc53de1b84a',
 '0d57ab0c50e62f94b9f2',
 '0d5822e7b7c755a7bd91',
 '0d6040956b9ee421675a',
 '0d6063527ca0b9a87010',
 '0d62cd9cf5e564d49d52',
 '0d66a18d69e36dd9d7f2',
 '0d6ce4618f2e8c08deff',
 '0d70d0ccd630c71955ba',
 '0d7679e160affa951a84',
 '0d76e3e2c85b739fd1dc',
 '0d791cebc44d13b128d7',
 '0d7a3c16e6adea6a0ae4',
 '0d7b8d5ffb871c18fb71',
 '0d817a2e8a5753fc9983',
 '0d82344955044868b4ca',
 '0d82b04497176facfb72',
 '0d8e37ec792c1bdecd48',
 '0d8f277584df2bc7280f',
 '0d9219fa374b46f590c1',
 '0d953db094558c45abde',
 '0d967eb9a24284b4b28d',
 '0d9864c7e40021d4852c',
 '0d99c16cf0d9b97b5b6c',
 '0d9a7a28280167f52932',
 '0da11b315d720f39a874',
 '0da268a7b617bf73ded7',
 '0da5278f3d46f36f7102',
 '0dac1af392571aabdd7d',
 '0dad268f015d447c4326',
 '0dad7522f4e7645abda9',
 '0db3f275b38413ec6a04',
 '0db618077e263621c152',
 '0db85f8cc2bb2a54a751',
 '0dba199881ecb27aa19f',
 '0dbd935ff47698d4101d',
 '0dbfd73185c210c1f07e',
 '0dc20a81290054187ce5',
 '0dc641eb73501accda5c',
 '0dc64d84f06d9062c21b',
 '0dc76ee516d947c0cd41',
 '0dc8ea9d760f286020e7',
 '0dcaf308f55beff58fdc',
 '0dd06f3d6aff083baa71',
 '0dd0a6975ce583f062f3',
 '0dd180d3d7dfe0480c2d',
 '0dd3d6dd5525e65ca2b0',
 '0dd5b122b54de8f7a733',
 '0dd6d32fc5d46b344301',
 '0ddb2d629f880c5f5c4f',
 '0ddbe46e94b61efa3071',
 '0ddc6a06a179fb6e42be',
 '0ddc80cd1edc74229fcf',
 '0ddd22ba54b4ed166d80',
 '0ddd8b23532cf7789150',
 '0ddfcedc6ca317d38724',
 '0de0124845c040b804b5',
 '0de025642ecc1b49b2db',
 '0de0443a4f5115e15e3f',
 '0de0b43d1a11d53cdefa',
 '0de2ba7c64641b056ece',
 '0de56b356d77c8c1c889',
 '0de64b135c3e6b4b8c7d',
 '0de9b2aa2c40cdde3896',
 '0df26fec200bf9896fd2',
 '0df3ea9b4a24078b7077',
 '0df6465b03bed3ba8eb0',
 '0dfac408da0252d6e07b',
 '0dfc31beb3ff1a12fb46',
 '0dfc3f01d21ca394cb2a',
 '0e03784fa1fb0c799135',
 '0e03b8d56a9a19de4ad1',
 '0e04bfcea02228f0921d',
 '0e0a7b6a3cf2001cef0c',
 '0e0bb92025d86c36ddc4',
 '0e0cc014ab4a3fbe2114',
 '0e0e92224e3882577e7a',
 '0e109756890377043ec1',
 '0e12cbad15f76d6cc98a',
 '0e196121502ddaafa728',
 '0e1a5515eefa29884ddb',
 '0e2364df86ae20f0500b',
 '0e27454a9a4a736373dc',
 '0e37a9b5088fb4a27c0d',
 '0e3840a90e0e9cce3631',
 '0e443004885e047e048a',
 '0e4550b3d54278f059e5',
 '0e4562f79b0b107091c4',
 '0e4952cc36cd8a48943d',
 '0e49fc77c59bc2cb599c',
 '0e4d79f0a3a8f3834c06',
 '0e4dae2fabf180e7cf98',
 '0e50dbda1b1ba42cf9b3',
 '0e52e940e97435fb21b9',
 '0e59eb15080cd6cb6ab9',
 '0e5d75d1fd75042b6559',
 '0e612f49943059800579',
 '0e61ce92083a0cd1de76',
 '0e624c86e812486e42d5',
 '0e62a46994dcdc183531',
 '0e6414e253442084e263',
 '0e654f0034921d3442a4',
 '0e6720e2e9aff0981f19',
 '0e690a91cf93b2211318',
 '0e6b90cf0e0dda74c2e3',
 '0e6e9edaaed4b3c3a269',
 '0e6eac4acc22188200e0',
 '0e704a021123ea75738e',
 '0e717198df076722ccdf',
 '0e747fcba3fea8e88c13',
 '0e75053824701edb40c1',
 '0e769747c62c2a7b624b',
 '0e7a97bba1bfc260e292',
 '0e7b98076aa6fc276d1f',
 '0e7c39add02420ab04a1',
 '0e7d6d2bf03d4b666734',
 '0e81c231c0119a2370df',
 '0e8440dcadc1a59c207e',
 '0e8917528d4666552154',
 '0e8990acb8955d8f560a',
 '0e8aaf127578fd25e5f9',
 '0e8afc48fe0c0649c570',
 '0e8c1888935a44d8c960',
 '0e8dea56d138977d42ca',
 '0e90499e8cc7078c295e',
 '0e946513d436886c08e0',
 '0e99220b2ab687360158',
 '0e99f94d207f43d1b96c',
 '0e9b7d03a90ee74f95e4',
 '0e9c8bd6cc63a208615b',
 '0e9eef88d6465a104ead',
 '0ea3dc2dbff8697f76ea',
 '0ea743048960f272a7b5',
 '0ea7d34fbba7631cfb28',
 '0eb7250ce5a71ddcd4c5',
 '0eb8a6f49a55906f3f11',
 '0eb98d4b470d77e90e00',
 '0ebb3eeaf5033b16935d',
 '0ebbb02f3367657f4135',
 '0ebd5b09489decf5a5c9',
 '0ec2ba8a6959bcde5dc0',
 '0ec4dcde8c01a06b1474',
 '0ecd5de83ea0134e60ec',
 '0ecfb66daaf9047b603b',
 '0ed02a225106f31d2228',
 '0ed2d403ab757dc19483',
 '0ed30b753246be89aaec',
 '0ed3f619c453410dc3db',
 '0ed70f9cb3b2b0af777b',
 '0ed808b6100cd184b401',
 '0ed88d4c1bd5ac73b7bc',
 '0edb09e5e89b72168eeb',
 '0edbf42d5a410c95d413',
 '0edd180a84ed6a5dfabd',
 '0ee28dc55fd12bbd24ab',
 '0ee86369980978f5cbde',
 '0ef0fb59bbed310b1c0b',
 '0ef1dd1d0100ebc24f9b',
 '0ef6179dda7fb6941cb8',
 '0ef62d77d25280afd7ae',
 '0efa40c1a95c8161c9ce',
 '0efca81eb866970016f5',
 '0efd40475110d2554111',
 '0f00248bd0f4b0fd6629',
 '0f01da8807e9659d5ba5',
 '0f0444930f68f3dab0fb',
 '0f092580d8993ac1194e',
 '0f0955b5da8c6f2fe622',
 '0f09d1cab6436ca5ce63',
 '0f0e6457b04a388948ba',
 '0f0e893921b5982824cf',
 '0f126be013fec9a1cac2',
 '0f1a5cbd08dd4f94cd4b',
 '0f1bde8610940e466d73',
 '0f248b89237eaffccea8',
 '0f249bfa72dc88d3c35a',
 '0f24ed3234ee3038f037',
 '0f2e88aba2659aef011c',
 '0f30311abd16db375f44',
 '0f31a36b83fe12048fa5',
 '0f3213c7c69831f7278b',
 '0f326eb4dee39fb5a144',
 '0f35ff2c2bbeea1346b8',
 '0f3ac621be7a215e769d',
 '0f44feb0d40e2112db98',
 '0f4526ef8cd975d62f62',
 '0f466f30c6efd1d88770',
 '0f4712af2518cfc63517',
 '0f494b0528ec4ca7ed54',
 '0f4e210d6323f5b3829a',
 '0f59f3fc58ac64e252b6',
 '0f5c427f37e8bd2cf315',
 '0f5f90fc3f8c19e2625a',
 '0f603de5290042122107',
 '0f608e4b6a25ec3d650f',
 '0f624f31917af360bec6',
 '0f63100060f5d241c8cc',
 '0f653125bb4636678d80',
 '0f6645bc468950781236',
 '0f665bb7c5d99add1f02',
 '0f675df1a8994e70bbbd',
 '0f6b17e6d719cd103749',
 '0f6cc8fcb8952a09252e',
 '0f6dbf363835700b7f2b',
 '0f7077018fcb2a5f9fab',
 '0f72c54856cecfaa2177',
 '0f7bc6b2e202de0b8579',
 '0f7c880819b028adcba2',
 '0f7d891311c07cfcbc05',
 '0f7e3dd4c9f0d4238903',
 '0f82f6d30ecc23ba4261',
 '0f87e141a4e6279d0be7',
 '0f891f0e581431039ffa',
 '0f8943bdfebfa1cc46fd',
 '0f89a19cc36a0f6f441b',
 '0f8d6d58ac903719a783',
 '0f8df3f3ce1d85ec4e60',
 '0f928ec6bae5ff409d72',
 '0f938e3be858d27ee5a0',
 '0f9542f60642b6d0f99b',
 '0f969ce62cdea0a5e58a',
 '0f97d3e37b770740e4e1',
 '0f9859dd799adf3aa0a8',
 '0f993cf0104b48e5b2cd',
 '0f9a99c1b748ae7893f2',
 '0f9b0844721a05793b42',
 '0fa0bc8bf3ab24685613',
 '0fa25b2e7c61417acd72',
 '0fa291ab2875cd1a0ba5',
 '0fa2eace477cd5b5f9a6',
 '0facdce52cde7a97f897',
 '0fad29b3a2fe94c39fb6',
 '0fb3e1b1443191068fa1',
 '0fb572ffb325212b3c6b',
 '0fb5dab08b78a5c07673',
 '0fbe8431319206f41c57',
 '0fc38d1cfb389e0f31d7',
 '0fc51eb13f54424fea82',
 '0fc5bdd443f843f9908f',
 '0fc6db88cc02034cebef',
 '0fc90d4a81c5d33ad855',
 '0fca20e8bb1049aec231',
 '0fcccc88406286787ccd',
 '0fcdec52d8c30936bb06',
 '0fd0d64dfe15be8edfee',
 '0fd3fe4f010ab50d179e',
 '0fd6152797e8998ad8ff',
 '0fd89fd338b0fef73282',
 '0fdb0bce6408775e5132',
 '0fdb7c4a1b206a6fc9c4',
 '0fdd8dd8ce1c8e617cd8',
 '0fdf90b0a3f5b6680d9a',
 '0fe5ee7c66c05ec72ac2',
 '0fe775f1e0bb909563df',
 '0ff307cff349cb842ce8',
 '0ff48fd6f66f6f32d5ad',
 '1004115427bd7b73157b',
 '100608e3ae7c0f8419ef',
 '10097b309e6f475883d4',
 '100eef209e140a25d033',
 '10106b6240df8f51ea82',
 '10114a20f01d6073a7f8',
 '101b402dedfc44524352',
 '1021297d8e63f3c9b57e',
 '1025fe25e2f4b580f5f5',
 '1026b5ec38a83f4c19b1',
 '102b1045767da9735196',
 '102f151c35d27a0849e7',
 '102fe9e7804b51e79e04',
 '1031d4c522af41eff5ff',
 '103991e0e4b490b724c5',
 '10420e50d7a555ae4155',
 '1044baaed95f5d04cfe6',
 '1046efd25c751ef96cf6',
 '1048a1ab4c48343a9dfa',
 '1048a68a616ef87317cb',
 '104987f5db2cc2251823',
 '104a7ac852428140daff',
 '104bfbd6c772b4b09e62',
 '104dc07c1438db5ad910',
 '104e84e7c218e26c7578',
 '104f1655626e9de22733',
 '1054c3116544c628eb76',
 '1057932ecddff8077651',
 '10584a63a0b165d756cb',
 '105b522184af91673745',
 '105d7639d6b8486949be',
 '1063413b59cba74744bd',
 '106627a84dd0459d914f',
 '1071f3f993f156291873',
 '107377c2256d79a9c126',
 '107feb131c6b153119ff',
 '1081dc85484a3d2c3d7b',
 '108300fb7b1a9e9c8a88',
 '108c6a323ea54ca9da16',
 '1095e3aac79a4cafcbf3',
 '1097e2392464a9079e88',
 '1099dda482c2ada0d27f',
 '109da1ad6a385d641a52',
 '109f6aec6adfefd84617',
 '10a2297eb7c1626de4de',
 '10a28b1b0c4237f45f47',
 '10a35b9e7eb91ad36aaf',
 '10ad44be4cc041c33b94',
 '10ae446a472cff11c463',
 '10b019f596d0ddb40ce9',
 '10b06b2b7560bf98f324',
 '10b316b624f088113d72',
 '10b4cc4140e04d7775d9',
 '10b5bb6408de60c50e11',
 '10b827b0c2ec2a8d160d',
 '10b87f15ee54c4ec6f6c',
 '10b91beccba2c4fdb6de',
 '10bdda2d050f2110f48d',
 '10be7c566b46188d0ace',
 '10c15151cfaf9bd4918d',
 '10cec05497a5d41b5413',
 '10d3ee6a8f35075c6998',
 '10d45d8bd1a9e5bed025',
 '10d963a838d6555ef2c4',
 '10d96433013a1108a749',
 '10dc0a248391a1cc3972',
 '10df8a5ce95e90dc110f',
 '10e0a543c6cebc942fdc',
 '10e1b3ebaa6cb998d75d',
 '10e7a9272606ca1b3c0b',
 '10e8ed719a02704ce49e',
 '10ea1b816c8f0b9bfd90',
 '10eeeed7640019ca99ca',
 '10f3a6e06340cf3c2e57',
 '10f52786e5ed27f5ca19',
 '10f92c10a271aa4da756',
 '10fa1a9f9a1c2aeba811',
 '10fc13903876b558ed6a',
 '10fc98db166079fdaaf7',
 '10fcd725584c02d32ddf',
 '10fe058859eade515d07',
 '10fe62a0e6a4312dd61b',
 '11041730a2980f2b5111',
 '11046150e1a2a9032b88',
 '11079812b58b0335e3f4',
 '1108b3e528e3f547a02d',
 '110dca2d382869045e39',
 '1117882cb66b8c7c5c6e',
 '1118aeba6fe1d4cdc3b9',
 '111e97598e0525aed68e',
 '11247b8f7bdafbccb080',
 '11275f0cafaa61d00a0f',
 '1128dfc7ed0ba92b3470',
 '112941d8ad3be2959200',
 '112aab4d9fa939c7d04f',
 '112f23de439418e61430',
 '1133a43dfeddfd387ca8',
 '11379b95a06486b28bbf',
 '113c5fb758e7b1b6bea3',
 '113e823e8ae707340972',
 '1144da58ca9fd40f109a',
 '11458b2be290b141cfa0',
 '1147a23693c7c97814c0',
 '1149b6072a035097a1e6',
 '114a3b6fdb8be6b04708',
 '114d28053c4bceffc35d',
 '114dd5aab3129b81755f',
 '114ed6c2660c914bf19a',
 '11523e63b4c49bf089b3',
 '1154096f87151b1e1483',
 '11579fe7766f3eb457dc',
 '1158362fd06c3408e803',
 '115b9f2a06360116c080',
 '115cc8098e654c471c0e',
 '115cd72cf662949c6265',
 '115cde66cfddcc601d6b',
 '11603c552c02a74c72dc',
 '116375b9bc6998f65271',
 '1164ec796fb497e21cb3',
 '116867d1bcd4e90c746f',
 '116c9328f2be8c54b5c9',
 '11703091f19537b54c29',
 '11728e4db57350e9f61d',
 '11754ad531c3b6f63451',
 '117a9dfff3d7f9c6b969',
 '117b9b50553cdf4f9766',
 '118029d5fd4d1df35b32',
 '1182412bdeec60790d05',
 '1182b40af6680033b8fd',
 '1188b27f7937ccaa0c81',
 '118ba9d796038956b778',
 '118e985d954c1f2f2f80',
 '118ea85d725806f1b34e',
 '118ec605122324397631',
 '1191923ded1b3ccefaf9',
 '1196ef35a22091030579',
 '1198b3ffd283ea56e5a2',
 '119929b9e1c434a12d4e',
 '119a3dea2b77cf835d75',
 '119cde8c834c1b0a1bab',
 '119e4c698b3074a10652',
 '11a537b3b54e83493d98',
 '11a719ca61c2c4e2034f',
 '11a78470c3608479f9b0',
 '11a7b9f1245fd27e551a',
 '11ab4e8d8e589cf3c303',
 '11b4fec9983e830e25d7',
 '11b615b5374e170d6871',
 '11b6bb07240fd0da7204',
 '11b95a2c0b6433b502a6',
 '11bd215c7b117210fbea',
 '11bd565948299fd975af',
 '11c1279b5d0211a0fba4',
 '11c627a204194f0e3406',
 '11d191053b78370d01ec',
 '11d9afab8d0dcc6c39c0',
 '11d9ebe268353ed5d5e2',
 '11df42718d63bd39e6f4',
 '11e2521b0a19d711d365',
 '11e7993d2f14602b788b',
 '11f6623f10e944da72eb',
 '11f9911e5b229e1544d3',
 '11fab95a6c9293ea7d8f',
 '11fc7e81674bbfe378bc',
 '1200cc03ed7da95435cf',
 '1205626a999339c4b8e7',
 '1206e0d153478d2e6c49',
 '1207817ed12d59340f9c',
 '12093bd0d56f43df3309',
 '120d0e404165b19f402f',
 '1211bb2abbc63d5344a8',
 '12130de919d1be51285d',
 '121536316c576561d468',
 '1216252d0ad3c1d00d88',
 '121bf42bf2c204cdbb5f',
 '121c638a03fcc0fe1e5b',
 '121cbe158432ee54cb41',
 '121cd089ea376bbc5870',
 '121cf408aca29d22e9c5',
 '121d7eda02a686cfdb90',
 '121dd36c999ba7260e45',
 '121dfcc0069cdea49279',
 '121e5910e722a7ff6578',
 '121fa8bed02ffdea499a',
 '1222eefb0586f464e922',
 '1226797abc33fa76f83c',
 '1226932d20e5e3cb97f7',
 '12290678406b7595a087',
 '122b87e8ab621f7cf05f',
 '122dc7d8f61ebb90baea',
 '1230adf97f37a8d0414d',
 '1236203c203d1e71637a',
 '123a76080c6131b18f17',
 '1240b37ab12d46a810f9',
 '1241c6644de569346e2c',
 '12421586a2b431fa2c71',
 '12427d95eba8b6f12138',
 '124289d3c044e28e168d',
 '12433eac224909986e0a',
 '1243924a33a313e1a560',
 '1245ac31dc7177e3a4a5',
 '12477c7391d5171e0470',
 '124a093b98b2d4694831',
 '124a0fee79a2f81c47d1',
 '124cc444d6c6053e24ef',
 '124d0f1fcce3e431460d',
 '12532873e9cf666ad116',
 '125bc389d1d3a1157e9a',
 '125df5ef2f0f969604ae',
 '125e4c83cb9d1ca806e2',
 '1261c2f6be4ef74563d6',
 '126213e6e8df90e0e337',
 '1264428b9f1277ed4849',
 '12649eebc521488eeb34',
 '12651c9cb7699616fa98',
 '1266dd87ee362e0778ac',
 '126a423778aac4964010',
 '126f04271cf1c2229d59',
 '126fdfa5a2ba993d83ad',
 '1270ea6556b6a5d4e09a',
 '1275c6f7b9f9b82a6c72',
 '12776846a596a49f0c27',
 '127c37fe5a6aabd660e7',
 '127e4e6ee539ab0814b5',
 '127eb48ba737caf23c36',
 '127eb97693eb7a804e9b',
 '127f215b388b328b1b23',
 '127f8ebdccbe159b63e0',
 '1281be415c01594d2f28',
 '128257b36c03f5df4546',
 '1286abfaa35921344740',
 '128820a2c040e4444ed8',
 '128bf8a5874b3d94d70a',
 '128bfb3bdc6f321363b4',
 '128e737ac19712f666cb',
 '1292192d075b6792580a',
 '129464aaede214930f93',
 '1295abac8915046ec7b2',
 '1299280299db622a8894',
 '12a0cf6f58ae0f14bb12',
 '12a54f5db3c45398fec1',
 '12a771dbb3f34184714b',
 '12aa2b918c4cd1c7051a',
 '12ab709acb11c82735d0',
 '12ac5c3a312ba8e70ada',
 '12aec17b1d908c78fd7e',
 '12b0387547dd4c43d12a',
 '12b0624ac49717f3b10d',
 '12b14005674014b19e8f',
 '12b30b6e4cfb33c0ae50',
 '12b4319ed544f5c23874',
 '12b81259244a7cde83b4',
 '12b8da7c9964f99777d6',
 '12b93aee5f001a39a23f',
 '12bedf70024b47b2971e',
 '12c2ac3426250251e212',
 '12c4a92785e8cd14d5cb',
 '12c627eff7c2c6572146',
 '12cbd141eb1e4980c8e4',
 '12ccde249d87835b27ed',
 '12cf10738846dff755a3',
 '12d0c2038644c49aa33c',
 '12d9964ec5d5810398e7',
 '12d9f54bf8a56dfb3f55',
 '12e3ac00ed1734544684',
 '12e4d0c35c06cd448047',
 '12ec519d5acaa64c3278',
 '12f1c206211b6f1354ea',
 '12f49f0fa771b7d3fdb0',
 '12f8077676542d203d9f',
 '12fb1744c789e5624ac5',
 '12fb64cea8a099bcf050',
 '12fcc02ec312f36ff1be',
 '12fd66f9ec38e305f1b7',
 '12ff5f4da3bb33dc8c1f',
 '1303148c2d54e9178878',
 '13044a1e66c76fb0eec7',
 '1305dfff3d39ae81514e',
 '13067b1ecabc5878462b',
 '13072407d2c9975bf1fa',
 '1314415f2d0c3a4f344d',
 '1314b98f08c1c7225804',
 '1316de8664d52504db04',
 '131a677271ea52ad8e24',
 '131b83925a49edc6dcef',
 '1322a5563a9bfb95df5e',
 '1328a2778d845da3b81a',
 '132a354965429e4b9ec1',
 '132b906f862299a655c8',
 '132e4c7b05d93a2aec06',
 '132f9b7b9ddaf5fd0e0b',
 '13307eaf016ee8b04323',
 '1332f1851799da98a710',
 '13330e126aaeb5d3ec7c',
 '13377a0e37ac7225eba9',
 '1337b72028a7617cee15',
 '1338bd4aab56f45b8d97',
 '13399a31a04dbc24336a',
 '133ae9b962917e9f0431',
 '134053b75682228a381b',
 '134103eee687771da59a',
 '13458caf3e3440861110',
 '1348974e5166a889cac7',
 '134aa2eaf166a0010040',
 '134cae50f48989adc088',
 '1352d6056dc86d77a36c',
 '13542d702aae421007b1',
 '1356833262208b31607b',
 '135800888cf7802b9eb6',
 '135819793d6458faac77',
 '135aeba6bb945c47812f',
 '136717062e9f6eed82ee',
 '1367fcb3fb9d11d27d34',
 '136803f34d63cbf21f85',
 '1370fcba8d82d45259ab',
 '13718bd627561325bc04',
 '137242bb95af55c0b26e',
 '1372f9fab16e9e7495ac',
 '1376e74204c8667b3d01',
 '137a7339bd33b0cb39ab',
 '137af85a40d11e1a7260',
 '13800204bfa6e5c1303b',
 '1380c627d9a7cd23a1c9',
 '1382bbe14bfcd2119083',
 '1385082f1c83f396ec27',
 '1385968409cc0d385134',
 '138750499082b9d5206a',
 '1388315afeef76df43ad',
 '1389236feab441913c35',
 '138aedcd340b242cb8e5',
 '138b0644364337d88977',
 '1390404729308d411320',
 '1395294929d6ca454dfa',
 '13954362f5ef2081ee73',
 '1396b52801427b26b225',
 '139aa3446c18080cb40b',
 '13a22b461912ffa90459',
 '13a2ea23e72074df9295',
 '13a5149d3ecc711d58b0',
 '13a6c05e5d238c18d73b',
 '13a990ab20b73dff32a1',
 '13abb10e94f924937665',
 '13b0544d10fb72866917',
 '13b0cb394c667a9c8c1e',
 '13b178fff4dcc60c53d0',
 '13b4a92a387710e1b100',
 '13b5e4942798d4bbfd21',
 '13b627d76b1084039a33',
 '13b8908624f171731544',
 '13c04de75241fe181001',
 '13c05856fd35849d293f',
 '13c39258739ba2d32a59',
 '13c3c4857afffc8f629b',
 '13c491ceeb474d521cfc',
 '13c58a48655cc2f40070',
 '13c7c493478d5e85b110',
 '13c819df3cf827d0311f',
 '13cad16f4972082aa6cd',
 '13ce2861729bc6f077dd',
 '13d40c9bb9fa8e7967c3',
 '13d4740a82d08661d56e',
 '13d6cf1e79e41dfc87d6',
 '13dc3f01f6c10de7cc90',
 '13dc7aabbaed85fd6a95',
 '13e1fa68a53c13684aab',
 '13e6197d60715a6b176b',
 '13ea723d2666284d1c38',
 '13ef28bd4a06c692003b',
 '13f016216d1de440ef43',
 '13f28ce2f437cdf2bb52',
 '13fe093b52c21aae4131',
 '13fe98ffe7c8d9aa312e',
 '1403a3e6f04af512a3ae',
 '14098e3ab2576a48f41c',
 '140aae53e49a312d7401',
 '140bbc900a7b0e4d455c',
 '140c131a4eb6e060593f',
 '140d061a4e830654ca0a',
 '1410aac8accea8dfb625',
 '1411ac4a812e58d8d419',
 '1416407fee0112d98703',
 '14171a02eb99d332035d',
 '141856db230aa5645695',
 '1422d95600932101208d',
 '142cd84b70d4ccd470c6',
 '142f7a5710187d9e13f2',
 '1430b35063cfeeefe07c',
 '14354381ac4fab5660a1',
 '1436149b601fdace1bfd',
 '1437ff5555fbb887f679',
 '1438d3e340651aadaa16',
 '143aa87f99bb1feaa973',
 '143e469c915b90dc37b1',
 '1447ff91d11da0efe5f2',
 '144acccc8b06a0d355a6',
 '144c49c4a64d34392a5a',
 '1452b142c3e7377d7187',
 '1453db0fd0c31cf3a25e',
 '1455fcc2e4b75a25f6eb',
 '145b27d21e2639207c3a',
 '145b76113e4a3c72d1df',
 '145c70460bd6facd1d3e',
 '145cc4cea35fa75a6acb',
 '14601158a89d4d893c69',
 '14618c5f334620b05bd8',
 '146325c7c2810972f70a',
 '14634ce0d07b46a66c88',
 '146402e62720645b9bf3',
 '146729e3547b5d8efba2',
 '146b7da11c8f1952ca34',
 '146ba20fd4e5a7d1d4fb',
 '146d76ca95c0c24ce5e9',
 '146dc429faab09ec0cc9',
 '146df3de043464901431',
 '146fae8b7fa37e4d72d1',
 '147383f0933a55502ba9',
 '14769a2d080ae259a228',
 '1480638d33d8fab4e324',
 '1483387e3c796ba44f3d',
 '1487f4f53a5286bfa26c',
 '148882d6758387e82038',
 '148aceae044092ea0633',
 '148c43c55877d05a0948',
 '148e59960a2f97c3d05e',
 '14919b04b1d9c052587f',
 '14967a5abf7f00adfa52',
 '14975dc4760fb21c98d0',
 '149e37ac07f0332b87e4',
 '14a21180c3871e09177d',
 '14a3a0b6c477bc548ca8',
 '14a7f1338a0872487be6',
 '14a911f7abe53ddbc9ad',
 '14a9f58439e336f28d4a',
 '14abc0bbef4a86c3d4d7',
 '14b33d9061b861cfdb09',
 '14b34639e241ed2bc581',
 '14b55b6a87eeaa282a31',
 '14b6d2b9a523d4c80430',
 '14b8166a52b28e6c5c2d',
 '14b8be8e6eb065c986c8',
 '14b91c78c5677b6c545c',
 '14beb008f8456a79e156',
 '14bf7cd553c7e0dcf680',
 '14c106286614194573ff',
 '14c18c5cdc319c376379',
 '14c3b9460cf44e8a6ad0',
 '14c55c0c6f6d2652a02b',
 '14c8a84e79624de2aa7a',
 '14ca253843bdb9d19616',
 '14cabf9f06d71f6f671a',
 '14ce0fa02d3b45ece5cb',
 '14d34433eac17cfd8fce',
 '14d7004787f441b61810',
 '14db2b6fad5c2458ab5f',
 '14e089285f462e82abf6',
 '14e176d3a2030bf2bb12',
 '14e6a9abb6eb364f631d',
 '14e8b507145e4b522095',
 '14eb9aee8a9ed0413fba',
 '14f15717cea7539f0a70',
 '14f1dedb13745d12bb1c',
 '14f22504ba62f28829b9',
 '14ffd1a77f25cb3fe5e7',
 '1500568c230e69992787',
 '1501affd9b8fc07a7390',
 '15026f7576e53bf49ab9',
 '150a453b2a235245fd18',
 '150d0792ce06332654c2',
 '150ddcb2e0d0f36531a8',
 '151544f97e9e4da51e07',
 '1516b5d16d256d22536d']

# %%
qids_3=['151b0c7c7be02f402a91',
 '151cdd6b9aea1ad8e96a',
 '151de649946416ea88d3',
 '1520c7a27ca20d5fea5e',
 '152148d5fdda88331be1',
 '1526bc5781b689381f1f',
 '15271b49e41af218f775',
 '15283aa53c40871c44c5',
 '152aca688a306d3350ad',
 '152e61d238f2efde9beb',
 '152f8a324a9e3f18adca',
 '15303ac7ce2c802aeb4e',
 '15305262fd84fd0797df',
 '153293a9f753293756e2',
 '153c6dec329c61dbf7e8',
 '15470a53ebe7fc29b593',
 '1548bd435be7c6a65cb1',
 '154b30693a40811d640d',
 '154bbee09f800bd0c63e',
 '154bdeb562f86a44bb3b',
 '155106177469dcc426d6',
 '15528fad597ae0eba6ad',
 '155552f91f86303ecf46',
 '1556e4b191db87f79f62',
 '15572c9bc25153a83537',
 '15582fb985118ef1a255',
 '155f7b5d72e69027581b',
 '156213a19f5b49e9226f',
 '156395da589b3b3115fe',
 '1564ded8fb5b1ebdc266',
 '1568727faba71989c32b',
 '15696ca0a39e64737901',
 '156a257fca6f0162bd60',
 '156b8a5c6b9ce5393232',
 '156eae5c47bbc632199b',
 '157107ab4dfa605c0ccf',
 '1573c45082947d2633ec',
 '1575144a4dd4fb1923a0',
 '157b157aa120799379aa',
 '157ec88b19464ec5b117',
 '157f145e896811fceacd',
 '158153bfc9c4c594632d',
 '1582b0072ceaa55d0a73',
 '1583b30dffd27d49dbe8',
 '15855ed08b7a2a696afc',
 '158908639404c7df5182',
 '158ba9f39639b1e82f43',
 '158e8b3bb0de413bca9c',
 '158ee1f3eece59a05850',
 '158f5a9df5b37c667172',
 '1593424649fb7ea60f23',
 '15970e5f8d3b3b9cc4aa',
 '159978f8ba1892607c46',
 '159ac01612e2de35d098',
 '15a183bb9935bb1a69a5',
 '15a1a2e9f9c5403485b2',
 '15a4a7a34c3810e71041',
 '15a6d10af127627b06e8',
 '15ab2f2ec99ba4c6f59b',
 '15acaba06198f927982b',
 '15b051b0b41fe4d7aef3',
 '15b6551a687c9c98bb00',
 '15b8e9e2acad90b49a44',
 '15bcb14300f9c3807805',
 '15bcbe249922e435e95e',
 '15be5982567129241b9e',
 '15c291fa1bfeb88f4782',
 '15c5b718f9421fb9c989',
 '15c661719eacf4eba889',
 '15cb289ca532a476eac7',
 '15cb8955b0fbf44a6575',
 '15cc739b352c96cc037f',
 '15d5c95fee357e152dcf',
 '15df0db22a7b21e01411',
 '15df8c435ebd567e4597',
 '15e1b7deb04e2c9a8067',
 '15e2e574299b1242e19b',
 '15e34635975ecf94ad29',
 '15e4fe04a8c1029a8965',
 '15e5e17947c76bbdc1c0',
 '15ecf850984ef0ad4694',
 '15eecf484e90bce490ff',
 '15f0966204891a780858',
 '15f2ffa7a79f8cc5ef91',
 '15f383b816f9a66fb9a7',
 '15f3e3f1cbc5033eb1eb',
 '15f66f6ab6234cc14416',
 '15fbd5a2f300a8f5e0e7',
 '15fcce93b5d9401a73e2',
 '15fdade0a7712462be06',
 '16098ee1f699b7a7840e',
 '160a1344743c98e6e7bb',
 '160be29d37bce02dd076',
 '16117d5051de11ded908',
 '161223f0e91fc3d26075',
 '1619b09a0c952dd3547e',
 '1625610f062ccf30bc78',
 '1625e6e40714b8d371f7',
 '1626825a642e8e9310d1',
 '162b274cd36cd542461e',
 '163249f11dde31c93ba7',
 '1632ed03dc14c08a9381',
 '163aa1669179e15b86de',
 '163d384794370ed8705f',
 '1641f30304eef0a0e196',
 '1645ff9bbd98ac10d8d2',
 '1646501ce87359ccc7fe',
 '1648e7bfcff1f13264fc',
 '1649dd760f93f703ceb6',
 '1650a3ef137aee065d26',
 '1650e295792e0bf6c801',
 '1654790f87547a3fb21b',
 '1658e0eb550d99e63803',
 '165b37c36f5de61dbcdd',
 '165bd26f711965f76931',
 '16618633b2d831292115',
 '1662e1b914d48c881362',
 '1669201dfb20d1223a1b',
 '166922bb6003771de1fa',
 '1669d3d1d704385e146d',
 '166c9650d246923c40db',
 '166d08adf18c36b56bcc',
 '167004ad814334fa37bd',
 '1672993eac348c19e06a',
 '1673ec3a51fe99fababa',
 '16740ca5ef4e7463baca',
 '1674443c87cde451a2f7',
 '1674b762a5ff85269e9e',
 '167c779ea49304de6b1c',
 '167d5b89026d65d643b8',
 '167d7da83a6471c0edc2',
 '168011bfd3c01da2958c',
 '16825383ecdcf3e330ae',
 '16883c8cf0091c57c7d1',
 '1691d5dde4abb3f4bd4f',
 '169598a43f0e04a6eb3c',
 '169b8862f96ddf59508f',
 '169c062508911be426c2',
 '169c7c95324f30ccbe7c',
 '169ce94a3811cfa6d08e',
 '169e1c4141d1d0720d03',
 '169eb5f8ac326039a96b',
 '16a03aca5345e57b0854',
 '16a14fecc9da9b3f1aa7',
 '16a383f74fbd9507dc94',
 '16a9130c3e966aa8f138',
 '16aacc6951bb444ee674',
 '16ad39316eefa309e270',
 '16ae5acf54b088ec4caf',
 '16aff6f52544bafccec8',
 '16b2f88ccad5e53d12a6',
 '16b460391e98959983d4',
 '16b50cf140d05eacd792',
 '16b7b130c4e26ba77c4f',
 '16b7bb04127d6f695fe9',
 '16b9768c0120ae24ab78',
 '16b98eb5bfa54e761a09',
 '16bc169351ef9f4f9af8',
 '16c00d1bd7ee0dfff8a3',
 '16c53bc63805d99aedfd',
 '16c5f608375145c4fbe8',
 '16cfc8213bbe0434b45f',
 '16d2ea34c35ed16db59d',
 '16d5a5c205bc640266e1',
 '16d5d25a9eeedf390a27',
 '16d8ab8dd1974c935904',
 '16d9c9cc21da09a04388',
 '16da1d78ddba1a2b3bfa',
 '16db3c5337e845030e12',
 '16dbeedb7cf888182b0c',
 '16dea47bd19624469865',
 '16e73788cf9f79fda4f8',
 '16eb0b1e5e72832ba841',
 '16ed4fc492afcee22437',
 '16ed729a1bac20f59f13',
 '16edb80d9feecc48165f',
 '16f02bcefd343740560c',
 '16f47245c1a7bb16f9dd',
 '16f4a71fd215e4107c5c',
 '16f56783ea7deed12b57',
 '16f85950babb4db63b5f',
 '16f9389448b0ef7bcb04',
 '16fa2a6fdf0d910af1df',
 '1700e49eab70a54f8fcc',
 '17012ec0df794a6b7e7b',
 '17036fd2575fe1e6014c',
 '17083ee73697d6c0775e',
 '170ada8b4878a4f2e2c7',
 '170d548b34e00dd12fd7',
 '170fff2603f1bc3423d7',
 '1711455f9af455b15524',
 '171356398141e78327f7',
 '17140a827ce4fa93eda3',
 '1717f840553f4fae123e',
 '171e1e45d60f8de901f5',
 '171fe5d61d2d38333f9a',
 '17227b3b14a054a0b02e',
 '1725a7f183873b359314',
 '1729ce3d4ba54720786f',
 '172c0a3bd1c7561a4b1d',
 '1732f6e233bd5b7bf1b5',
 '17372bd491fa59b2b19f',
 '1737cdf87181f9e0a463',
 '173c3b640b18a16cbb88',
 '1741542dbdbc81804616',
 '1743334d911f91e6b86f',
 '1743dfb5fb329b8718da',
 '174b8ac7fd9dff46c196',
 '174c56d3a63f66aa1617',
 '17521001ea6f17fe85d1',
 '1755d801d6d9b57b8e5d',
 '175657ec3ee239c0f924',
 '1756c9f8cc797265fae3',
 '17582e80bfbc3ddd0377',
 '1759bc5c2eb9f55afb6d',
 '1759e90166258adbbaf5',
 '175ab4e9e23a5c23aa36',
 '176005c647a95163290e',
 '176228e36476632f775c',
 '1762eaa28a29f95932d8',
 '1766c1e9e302ffe75b68',
 '176735cab9de29f2b578',
 '176af5d32cc7221e7e39',
 '176bd5173bdb83f0cace',
 '176c4544b1eff1c95d21',
 '176cd182882039dec7ab',
 '176d511f3619404f384c',
 '176f57787f47ccd78be6',
 '177426724045a4e220ba',
 '17777cdb275ca19eb13d',
 '1779b2a1f3c7759921bf',
 '177cb074fdf641dd6bcf',
 '17833f3755ef694bb755',
 '178360ded5a2fafb757f',
 '178482fecc5d749c4991',
 '178b3dbe01ba7f393c30',
 '178bc62154e66efac0d8',
 '178c27289b75c43ccffd',
 '179637d3a14fbf42d99b',
 '17990247ea3b3bb8f311',
 '179a3e4f93fed6cfcae9',
 '179dbac0a259af57389e',
 '179ee7a96eadd85f917b',
 '17a2348b1e274e01e1aa',
 '17a688635c857632d24b',
 '17a7c38a8206483b9d5f',
 '17a8673679950fecfa2e',
 '17af80c58c63242320be',
 '17b0b3d12f74eadc57e9',
 '17b0b42e252a95359d40',
 '17b15b6af60d4e64b3a6',
 '17b40ad0dbf96258e37b',
 '17b63e4ad272ac76dec7',
 '17b936bda3af0e741132',
 '17b9bc83dda8c3d60e9c',
 '17bc30cdb708456dcea7',
 '17c983a4e658ddc1e0d3',
 '17d73f7ec98908f0a4c1',
 '17dab32b08de2ceae8b3',
 '17db0e908c85aaf377cc',
 '17db835a8080fb2470af',
 '17db8f35675de746eb3b',
 '17dce2b6f49b4ac90c5f',
 '17e73251e0d8484127bc',
 '17e9713621d4051bc1e7',
 '17eab2a4d5a5dbf8e57e',
 '17ee6cf8b28f1e6b8dc8',
 '17f398f325389788137c',
 '17f415b80aa9a907fb6c',
 '17f5958d98bc8632dbb1',
 '17f622dd9bc6271d190c',
 '17fa16b0a1ccfe52005b',
 '17fb717182711b5220f0',
 '17fc23e3304d769f09be',
 '1803fd46c793354d5c50',
 '1804739afacbb8358e59',
 '1808189eb7ea6ba52f5e',
 '180e7884aa9eb0c6fa69',
 '18152912c81c87e7c563',
 '181a9c34392d22fd6410',
 '181a9d348741b710caaf',
 '1820a75a7924014e8228',
 '1822d3e8ff928fa52d8a',
 '18242261badc0a3b9302',
 '182a0c4de143a2f950cd',
 '182c7ce5e6802fa458ad',
 '18307865c07643da4635',
 '1836fd4f6bbfa7a6cc92',
 '183859a8f00cf8905904',
 '183b95239dd0d1e68775',
 '183c9545f781c45b3092',
 '183cd9967dd972eb5d51',
 '183e96faacf39329a3a9',
 '18413e87471748f2c69a',
 '1841df904c9ce3836d96',
 '1842d44570d9def0bae4',
 '18447cfea7e4fc3aca87',
 '1845d6155aa63a60021e',
 '184715e2c75afc8e2114',
 '1847dfb6c1f5ac30d6d3',
 '18481e62c2c8cf0ce446',
 '18494331272c759ce8d0',
 '184c223822d26c1ff877',
 '1850ca51d1f09a05af86',
 '1855128cabbe0d0320c2',
 '18564dfba925be9b7df3',
 '18574426d2f3375e821c',
 '185897bcc496992d5d24',
 '18592ec6a242b549c500',
 '185bb1ff0522fe35a189',
 '185c9a65193cb5a76e87',
 '185d6b57d39a690c3808',
 '185f144ec377eb9b1803',
 '1860014a0108e68f00b8',
 '18657780cb36d56cdba5',
 '18687e428932f2c065d6',
 '1868ef5a9d172958b82f',
 '1872807cb8dc73c94d81',
 '187425abed29339bb4f2',
 '187b0525b1c5819edd37',
 '187ce46371c59fe549dd',
 '187d74e910b153b37aae',
 '1880b61eaf2616420c59',
 '1880b695594f0f52e988',
 '1883d37fbaf94954233c',
 '1883f7e0649a085f05ae',
 '188a5fee9ebfb296e38f',
 '188bada9384d9ad83a47',
 '188c3e8d6fb96ed3a298',
 '188de14d9c9af79ea1e5',
 '189008c4d92dc4f14137',
 '18901b50946f812ef92b',
 '1891fed0922f27705de1',
 '1894ee89588797c07e0f',
 '18955e3f7a8ec1532b05',
 '18971dcc166671fb46e8',
 '18996455ac6f6dd7c7e7',
 '189e29b95e1d97a06d9e',
 '189e96dcc71758e6d63c',
 '18a04b3313674ab9f7f0',
 '18a06a575b5ae3d95c9c',
 '18a19a42888714773e80',
 '18a4981aeb54ca8afc1d',
 '18a72f233942cc8d648c',
 '18aba3bbb40bc0214315',
 '18ae15471c6b6c7e8b24',
 '18b607192f2078598dd0',
 '18b99a0826eb30c9a189',
 '18bb29d3f0a756cc08d5',
 '18c11515e47669c71861',
 '18c5e141d2f3757368ba',
 '18c8a6f0f03580797a57',
 '18c94a959c2a6b21d269',
 '18caf8ace45175b5df28',
 '18cce0164a2cc2bed067',
 '18cf0b26fee8a3372ca7',
 '18d4177f66f86dc606d6',
 '18d8e8870023caa423bf',
 '18dc4c85c2d732bc28af',
 '18dcaf65fdd3441f93e7',
 '18de14cd6452a39ec158',
 '18dea3f8dd9ed65c4a15',
 '18e0208b28ae1d28067e',
 '18f37de2531235a31d73',
 '18f51bb5f51b7c068f18',
 '18f7a0851f8fc3e72a68',
 '18f7dd50ab6242f307be',
 '18fc55ff8466186ad2aa',
 '1901fa5015cc88d2395b',
 '1903b507eb1fa438364c',
 '19054e7b173961e7d8b1',
 '190705f92db63215448c',
 '190847d4262543609dfa',
 '1909395054f48ee250d7',
 '190b5a429bcf8febf264',
 '190f927f0008ed3597b1',
 '19122e229fc0e3eb9b3d',
 '191260e913f9ee2fe571',
 '1913c7f06ce7e596cc91',
 '19145502ee7bead6aa3a',
 '19167a87268a61ea1608',
 '191ab6c92614006d4495',
 '191ae87d559964d51671',
 '192188639c877e15f549',
 '19233f0ccfb508cc7f57',
 '1927e95cfc21d362466c',
 '19294111de1045c54ac0',
 '192a4e76433f9b3fe8a5',
 '1931bb391439f97848bd',
 '19336a3a0a731001ab10',
 '19339cb834c56c8488c8',
 '1936325a9151b9b88ad5',
 '1936c47e37e846d3b344',
 '193c7c82b24e63bf1cbe',
 '193d69eb232628d6ac1d',
 '193e59048440ee7d25b9',
 '19410f4a8feb0117131c',
 '194152bb51bdd16f9cb0',
 '1943678fd2079b7126be',
 '194408c901b6f5362bae',
 '19481ea277c12bf923c0',
 '194862d0691d2b0b68e1',
 '19489cb828f57a25936e',
 '1948ad73a1c1c5ae01f0',
 '1949d89dc81eaf191a75',
 '1950fd5f57feb948c3ab',
 '195182b26e7bd493bd81',
 '1956d8ef2fc186732813',
 '195a9369084847a59d1c',
 '1960161fca0a1b6c799c',
 '19636bcf1b045c483a4c',
 '19670c5d9a64c072c9ee',
 '19683b0f2362f5328d0a',
 '1969a606151dcde4e52f',
 '1969a8b30dea82b8582c',
 '196cdcb0dc9422428e82',
 '196dbbf8ac9513827c88',
 '196e5255b3905ba29299',
 '1970be4d4ace01c1edb2',
 '1974b14a76d1ff1aeb8c',
 '1974e21dd3a85d1cb929',
 '1978535539f5e6e3f63c',
 '197ccec8d92528b6752f',
 '197d1337904e68a1340f',
 '197fcf7c5433f287b4a0',
 '19805cec5a36be9ae6d6',
 '1981d60e1351d62bcdbe',
 '19848dc49df109e82695',
 '19885826ba36107118ff',
 '1989d63a84e2d869a88d',
 '198c37f1f5722eefcd49',
 '198f8341669fa8aecbea',
 '198fe23ac959a604a758',
 '1992ea3425b054f215d9',
 '199423f57a034d1f8e9f',
 '1994f84a5d2b5c30df72',
 '199a0eed2974d1cac688',
 '199e46dbb2bc65af842c',
 '19a289e967b424672d3b',
 '19a2ba0f3d75042132a6',
 '19a6ed0e424e9f8b76bb',
 '19a72d065d46ad8021ba',
 '19b04cb585bb5f4bada9',
 '19b06e02abb37d741fb2',
 '19b074b171dd88c7c565',
 '19b317f6e53361f9de41',
 '19b3b9855663fcfded15',
 '19b888b2ab9789d43b40',
 '19b8ae12bf589d6f30e0',
 '19bf0b2e032d4fd92afa',
 '19bf13bbd61b39b70fa7',
 '19c34aba1a1206b4fc51',
 '19c3edc30932ec970512',
 '19c6854917b07a342099',
 '19c80342f530fe27fce2',
 '19c8254328d983f5b174',
 '19cc8ea3ce69521f56d5',
 '19cf11b1674cca61fdff',
 '19d0961606f71ecdc30b',
 '19d0ed3d9e77f76d2baf',
 '19d207291af32aba2687',
 '19d2b81f284bc1e0153a',
 '19d8b9818fa04f226fbe',
 '19e1294053684aecf042',
 '19e3f5f6a72572d74906',
 '19e8f68c4f16401fe429',
 '19edc5600fdd3d1fc461',
 '19ee5fe5c59d35793c18',
 '19f20ac12530d1fb3a52',
 '19f52528af955e39c821',
 '19f52eab09bc232541f5',
 '19f9b5281fe5b4890719',
 '19fad6e5e3fdd7017e97',
 '19fce00fe49b8dccc62c',
 '19fd18e919624e5d9869',
 '19fdcce7b47f1002ec5d',
 '1a04e8bedd137a54c8ca',
 '1a092c59594db5b86f45',
 '1a0ae33ae2ef844c1e70',
 '1a0c7f0a30db6f9dd2b5',
 '1a0e64eb615c490e1ace',
 '1a127e621a7f4764ea81',
 '1a159d1cca243aa85993',
 '1a15f33951228cd869b9',
 '1a1672f580f0cd2034ff',
 '1a16b9356c13828a576d',
 '1a1b4fa78cc4ae7e9bfa',
 '1a1ccbc88fd690a5c8d2',
 '1a1d8be65222013f5546',
 '1a1f019160f37ee673cf',
 '1a21cf7c7aa4ddb9cbe8',
 '1a23669457245fce56ec',
 '1a23db6fe58998e2cabf',
 '1a253514083654f7dd96',
 '1a292a8f86203e11d65e',
 '1a292f6ea9abe959370c',
 '1a298a677c93ad27fe57',
 '1a2b614653647e0b0b18',
 '1a2be0b89fa83669645c',
 '1a334ad69b1df557a4c9',
 '1a33bee357aa356bac4a',
 '1a360dd222ec3f62d9cb',
 '1a361760adae8a3dcf16',
 '1a3bcc8b357e8a33f7ab',
 '1a3e5341a7e2b04f1c88',
 '1a3f666a52bd3fee1495',
 '1a429304d11a6b6cede5',
 '1a441c921e891e628b9e',
 '1a4e58007425b9e25ece',
 '1a4fab0d1673333ab45c',
 '1a502a08c76122c9b640',
 '1a549658943ac80c15e7',
 '1a57caf3ab4c87a369ac',
 '1a601c6ceec5d191abc3',
 '1a618a107e05d1a78f0d',
 '1a61eebd1d5205ca07a8',
 '1a6364a413e278b6bbe3',
 '1a63d62ad05d6ee02a69',
 '1a64034e8e91cb6e5496',
 '1a6753131bbaddd4e4f2',
 '1a691170ad082a47750a',
 '1a6fb0aed1555b9506a0',
 '1a7136ce263962cd4716',
 '1a74074e42177a5cf0d6',
 '1a7919eba26537d9884a',
 '1a7c2dd45c127a2c0bac',
 '1a7cfbf849350daf8cc3',
 '1a89271be259407b1857',
 '1a89400b4638e3ee7f27',
 '1a8e822e1ff6f3a0ef37',
 '1a9470b6e7feb9eb152e',
 '1a96474417b828f32177',
 '1a9721db493626a6492a',
 '1a9fb9d60c0cfbae981d',
 '1aa0bc334046c64a0fa2',
 '1aa4486afb593a0853dd',
 '1aa72ee40726d20a86ee',
 '1aa923f6b243a5d54453',
 '1aa969fecc8470f885d9',
 '1aa9b8c620c58b7fde60',
 '1aaabeb119ded732d089',
 '1aac77639f27bbc0b0f2',
 '1ab1777cfa0a47da3ae6',
 '1ab5d0ebfc2b4ab0f7ce',
 '1ab7504e3be5f7918538',
 '1abb21c0d6b2639b51f6',
 '1ac30103f8be5d74dd89',
 '1ac7e2d11b4ce53ff482',
 '1ac87e5910d09f7a21b7',
 '1ac9a849c23a6d2ac744',
 '1ac9cf61e4ace0bac319',
 '1acd934d6a33629efb3d',
 '1ace75c5f0a470588540',
 '1ad580a2bfa6e39f24f4',
 '1ad5848e8287dfa3015d',
 '1ad67f7617eedd894bef',
 '1ad82831db0945f39b29',
 '1ad8db74ec4a4df1ec3a',
 '1ad9a797a692152d3778',
 '1adc6e5b201aaf1c6847',
 '1adfb2ddace37b7664ee',
 '1ae2ee2d94c275936d1f',
 '1ae4059036acedeecdde',
 '1aeab432fde7cb8caec9',
 '1af06720da5461159527',
 '1af36cfd041aa506c34a',
 '1af4954dbbbf694fe7f9',
 '1af71cb2aef6741143d4',
 '1af777dcfb8a6d78051b',
 '1afcd82e22b8f286723f',
 '1afd8ce541081a08d1e2',
 '1b003916468f3f58244b',
 '1b05e28a6271b46492d3',
 '1b06561ab4e187ac5445',
 '1b085a7e1f5f0e655eff',
 '1b0ff81e1d053bfefa9d',
 '1b118fd48e8053ccd21f',
 '1b11fb61e29af312f27d',
 '1b15e31010782b0d965e',
 '1b1a759eb71d16a64afa',
 '1b1bce0e5d7b26ff5889',
 '1b1cee95a72d17975bae',
 '1b1dbca99758a969ae59',
 '1b1ec97e22ff12d700bd',
 '1b1f58b6e9ef2d36e6ec',
 '1b206e4387866c681db7',
 '1b2278d3ad908bbe9ac0',
 '1b2365f0e396d8b8c920',
 '1b24450dca22c7ac654b',
 '1b27897005638b5f730f',
 '1b2d63fb29dacf402b82',
 '1b2dd2c822073087545d',
 '1b2e430b361290dd422a',
 '1b2f210c1dea3654e63b',
 '1b31445388c8fb4a8b69',
 '1b368ebc2fcde527d686',
 '1b36988421bfbcc2dc0b',
 '1b37a13171cd0eef5365',
 '1b37b65482f43097d1f3',
 '1b3a7406c7931b21d2be',
 '1b3b9b852f72be6c4c30',
 '1b3ca4b3aad387edde29',
 '1b3f24c145211a5bff3a',
 '1b45b281a6a16775e09f',
 '1b4850df6b532c878a04',
 '1b4c1188f04eb4fe2f3c',
 '1b51f0b9eed37c4c6b5e',
 '1b5afcb1ec70eaa99cc9',
 '1b5b3ed1338f492a7c72',
 '1b5f5ae4962c3f5f4894',
 '1b5f8f08b6b3715a1e20',
 '1b5fbe8df9890a0beadf',
 '1b60eab3ad0d52cdb543',
 '1b6133366271b1d38584',
 '1b6706afa15dfb642c59',
 '1b67ac4dca135a48b73a',
 '1b70cc4524c69feb31c5',
 '1b758050b310f216d74a',
 '1b7c8a98b87fcf088f3b',
 '1b80534f6da973a6e14c',
 '1b8227a919e2eac3e8ee',
 '1b82356f46acc4e7e0ad',
 '1b84038ed191bb47fed6',
 '1b8431be0bd6c107ccae',
 '1b888fefe446f7ae24b1',
 '1b8b1fa87777515edcac',
 '1b8b6c4ffa8b8d3e2fba',
 '1b8fc92523972e4547dc',
 '1b8ff320349fbd62a576',
 '1b91249b98c9eb23c728',
 '1b93f398d5134efcc729',
 '1b9913a17267dc73d519',
 '1b9aaf8a7671eeb71703',
 '1baa57df148fc7931fae',
 '1babc05b573021b6fa18',
 '1bb1105ae95867d6e0e3',
 '1bb483f80b78979a7b04',
 '1bba8e2ee1e7e6815907',
 '1bbbcade1a129305658a',
 '1bc26fde96090e1e3a0e',
 '1bcd4d0f5b6c72043a78',
 '1bcd5ad9a67b6ede35a6',
 '1be36f440d984e78cddc',
 '1be42c28733867a76a68',
 '1be452f352eb717b9027',
 '1be63764ded259bca3c7',
 '1be88aba1c346b4df467',
 '1beaaccbe5799745869a',
 '1becc989da9cf4492934',
 '1bf0747d713fda1d257d',
 '1bf31e9f2399251cd155',
 '1bf3aec13573e5bec4d9',
 '1bf74995f8036303d79c',
 '1bf7b56b20962468c3ff',
 '1bf81b1bed95674d5e50',
 '1bf9ebe697445509f148',
 '1bfcb8c88ce3ccfda834',
 '1c01f51f70a6aa679c2b',
 '1c0687c4006aa5294d98',
 '1c06aec383d70dd2ed63',
 '1c0990996c93bd12d4fa',
 '1c0b7bb5985e79e87d7c',
 '1c0c47d83aba2f002899',
 '1c0ed44e7e65737a162a',
 '1c0ef9a40ba3c0b0ff5f',
 '1c0ff38a453f5d0f09fd',
 '1c1092d3df513656a83d',
 '1c109ddcf47c1386227e',
 '1c11c6275ec3573dd9f0',
 '1c124d71e54048ae4902',
 '1c128b4fa0a392263d9d',
 '1c1ac857770d3381bf7c',
 '1c1daa619cb42c041ac6',
 '1c238d1f9b5c7221a387',
 '1c26b0f32febde153f46',
 '1c27109f0188162a0d74',
 '1c2810e659ebf258acb8',
 '1c2aa604e51f84f27d6f',
 '1c2bba7064532dc61014',
 '1c2c97cd270469b0a97f',
 '1c2e4a20c9bfafdf7c35',
 '1c2f16e7ae8ebae1803c',
 '1c3345227f67cd7dffcf',
 '1c4265257e49fe2b0ac2',
 '1c42ac5ed146129a43a8',
 '1c4444b28e3c94431e31',
 '1c4448dd0844031ae8ea',
 '1c4aba022993cf9a4010',
 '1c4cd67b0c8d8b2c6653',
 '1c4dd1f4fdfc3a41cdc7',
 '1c4f45d42dcf5614d701',
 '1c50774882145f9513ef',
 '1c52af9d2be34253b634',
 '1c54a84fd921bd44c10c',
 '1c55671490517dcae4dd',
 '1c5b606df01efd2d8cc6',
 '1c5c44dfe266a02907d7',
 '1c5d60b6142b929d62c9',
 '1c5f085f454fc3048984',
 '1c60da03c4d3cb75ed79',
 '1c62f7a1d6f8b2c33e1e',
 '1c63c0e260c8b6774ccb',
 '1c6871ae0d4d258cc541',
 '1c69c22e5993bed99e2c',
 '1c6a18990ac816c2c610',
 '1c6b6b7add301f7335a1',
 '1c6c8466516abb646fbb',
 '1c6e97fbbbc426ad9e66',
 '1c71263a4ef9a697da25',
 '1c72f5d8dbcfecc6720f',
 '1c78427d7f03a76cca22',
 '1c785d0bcaf98ebc9e39',
 '1c7d3841e9f1dc8472fa',
 '1c7de136de3084c30d69',
 '1c7e85001212b5096fe8',
 '1c7ffd721133c6579d5c',
 '1c805885f2bd5fd39c45',
 '1c81b82607af02c4a154',
 '1c8365621fdc26db050b',
 '1c8618a1b827b96a3405',
 '1c86d62aa7630c94cba0',
 '1c8bbeed3244ed1d64bc',
 '1c8f463ee7210f7179ec',
 '1c8f5a98c7020ae0aa3d',
 '1c90471aadc22571003e',
 '1c906e668a36d02551fc',
 '1c91e451848a8596fa2f',
 '1c9279b3ddd718e76ae2',
 '1c941160c8b226a8d8ba',
 '1c94b3762d0c04d88349',
 '1c9522ec482c3ccfdd25',
 '1c99f66bde4eb9f497a7',
 '1c9a9a5f42ee810d1c05',
 '1c9c6e3ef28461161e17',
 '1c9d1e0621b26e9dd1f7',
 '1c9ff6de4e5bf4c9ffe2',
 '1ca041ba770882a22181',
 '1ca73025fb12038a5db7',
 '1ca764056f9f4a4bdf26',
 '1caaf03b9d6b73ed9c8c',
 '1cb1adb257bab311d78f',
 '1cb5e8e4a11b0b4c1e9f',
 '1cb6ffd05a86b2c4d6af',
 '1cb8d498704f7d279d7c',
 '1cba0d02a0e818e08f71',
 '1cbb3a11139b8b7a7016',
 '1cbe6c06970f1ee79fd0',
 '1cbf4a8eb5a2722c82b6',
 '1cc06bfeec5399d4687f',
 '1cc1cf4557c9f4a4cb58',
 '1cc5b6e84f473d1477ea',
 '1cc69744813db40af00e',
 '1cce4eb274181ca51784',
 '1cd35a000622355b4014',
 '1cd617a676a000232476',
 '1cdd59bb0d8c854a2f65',
 '1cde986c4570cb5e25a0',
 '1cdf949db2ae46eb12f8',
 '1ce0578d87d971813135',
 '1ce0a3d43313f5cddda9',
 '1ce47b223594cc18145f',
 '1ce70a8a729271097cd8',
 '1ce945e86a4d1e4ea092',
 '1ce9ac6ae6a7069124e3',
 '1cebcf72242995b83f4e',
 '1cef6357352d120acc50',
 '1cf7a2789c0abcfbc5ab',
 '1cf80951a12bc342fe53',
 '1cfad74a895e508dad96',
 '1cfbcd7d957179794b4b',
 '1cff4bca9e6601f7cb3b',
 '1d00a852dbc7aefd9ebf',
 '1d00abf63b11db093f9c',
 '1d0399afc1848aaa928d',
 '1d069274a65b5b9382ac',
 '1d078102db191c76926a',
 '1d0ac1744aef7f3aaec8',
 '1d0e6ca2a248cd92ef1c',
 '1d1443351749ebc02929',
 '1d14c609ba70cead3065',
 '1d164a628fe0a94c1450',
 '1d172559233d2d3460f9',
 '1d19a81555355e21629f',
 '1d1c240474f78b4f1ae7',
 '1d1e8b417edb8da77c26',
 '1d1f6d02ea110988975e',
 '1d239b434e878e4e50d3',
 '1d246e67b72456fdb436',
 '1d27cd334f076d161338',
 '1d29bb2ef148df418a15',
 '1d34f468a91815e194fe',
 '1d35af173dc22739f49a',
 '1d396d6b4565ee1236dc',
 '1d3b53d74690bd6d2c74',
 '1d42afcdf184e2ce3791',
 '1d45d61537e244e64ec0',
 '1d4ba33bd0347645122c',
 '1d4eeef7fb5b8c6bfeed',
 '1d59edb57c63c4dc7dae',
 '1d5eaf5d5ea07b8cf7cc',
 '1d6122c0d4b74c8787d9',
 '1d693bd760e9f2609ea7',
 '1d70f8b181784d72200b',
 '1d712b9b0decda56119a',
 '1d8167bc9f7401a18559',
 '1d8710419bfd11929b0f',
 '1d88d541ad642aa742a9',
 '1d8a51592212ff9b739d',
 '1d8f6d3b9738612c43ec',
 '1d94f64b0e6bdb93e23d',
 '1d95ffe978c794f7d1d5',
 '1d962efcba034e21143c',
 '1d96ce3f2806f3fb12b7',
 '1d9c8db61394ec80d2fc',
 '1d9ca43ca2c1902cec21',
 '1d9d53874112d2a07a54',
 '1da3cb041ac52cf867a4',
 '1da605ffb00a26f78075',
 '1da655aaaea9ec5bd6ff',
 '1da97f620e397a98aadb',
 '1dacdd80f24dd557edb9',
 '1dad29dcb4039af71c76',
 '1dad57934cf6fcba2b0c',
 '1dafd24b47c6754e76f3',
 '1db7693a92d9a20f4c7e',
 '1db98406b2f0c9624677',
 '1dbae8fca0f54cc34a30',
 '1dc1edc30f17f1de6532',
 '1dc629e9aa0538266cb4',
 '1dcadddf6bcb44b4633a',
 '1dd2fcb6c76877b7728a',
 '1dd64f13e8491a1b6f7b',
 '1dd76dc2207d96360d89',
 '1dd77f26df7c604bcb2d',
 '1ddc0cdc6d51c7c18079',
 '1ddf1f243ed053c5c57a',
 '1de5332c33d93cd5b591',
 '1de546dfd6ad8fc1fc5d',
 '1de9eb9e1c19b91a93a4',
 '1deb73a15134a31798bb',
 '1debac54e4fdcdc880da',
 '1debc86afd34481a1d70',
 '1ded15208948002a0bbc',
 '1df0048c81463317fd88',
 '1df23de2d30ab9ce811e',
 '1df65242e663e5d22f62',
 '1df7e49c274847387caa',
 '1df992f162e0ca23de9a',
 '1df9e4cad2893ae3e49e',
 '1e00fb3118f1f6bfbbea',
 '1e02790be864b45783ea',
 '1e036a603f6ce9ceb601',
 '1e069c72f9aab1203daf',
 '1e08727f260de3f1f94c',
 '1e08e7960e21626e2abe',
 '1e0d3b307045e21a0981',
 '1e0fb202f98e67d49e24',
 '1e10c5dd208ddf97cb3b',
 '1e1112db071d96e02507',
 '1e118cd4b2fdd17f7acd',
 '1e12edb436a7e9708899',
 '1e13c462d636461fe6be',
 '1e1800238af3894ab672',
 '1e1a1af35df09e7a8239',
 '1e1a538eee2f8a031a62',
 '1e1d117a40e1e92c1bd7',
 '1e1ff4ff9ffe59753e9c',
 '1e234775911579e04c3d',
 '1e23da7f8e8e71cbc785',
 '1e269aba3708812d4ea7',
 '1e274a233420830faf42',
 '1e29195859f10eaa8c80',
 '1e29c3484845301ec7aa',
 '1e2a17ccbbb0a543bb1f',
 '1e2c2c90b28d4c0bfcf1',
 '1e2d5ab87cc1462917c1',
 '1e304be3e9356ea526b9',
 '1e3620b6aafb830959d2',
 '1e369274f0e2dc058d46',
 '1e37050962f3522e4826',
 '1e3d933cef8d822c4adb',
 '1e3e025cde6abac8a597',
 '1e424e51b9447e1d5799',
 '1e443adcda302431835b',
 '1e4dd7cb3c4d12344333',
 '1e4f23abb624be964378',
 '1e53b28fdf551b8116c2',
 '1e58df9651a869f048dc',
 '1e5a67cbc55b3048e885',
 '1e65834f8508f6fb353f',
 '1e69a6326ec05e270db1',
 '1e6a5bd02067fd0f3a3e',
 '1e6b5cdd1cdca1511e5b',
 '1e71a63aa4e9c961f42e',
 '1e7275b86c07bf8742d9',
 '1e77777619de9a5e4086',
 '1e785c25f65dc8acfb5e',
 '1e7bd87ce723e9b5f1e7',
 '1e7ce5215c03a20540f6',
 '1e7e415cd337e4d861ad',
 '1e7f403306b63eef88bc',
 '1e83eb6d7419f750ce44',
 '1e870b420170961e6f9e',
 '1e89d1aaa7acd9ed0723',
 '1e925c9251e58891b4cc',
 '1e92bce07fac59fc8af9',
 '1e9c41dcd372d9f0fc69',
 '1e9f578266aad58abb30',
 '1ea0b0874b5c8535bd79',
 '1eaae314dd21fa51458d',
 '1eabc6ef42874a7f655c',
 '1ead4c8b9cf4e64523a5',
 '1eae4b37247240b8a4bd',
 '1eaf24a6cc38eeae4723',
 '1eafd6c3ca87971d0545',
 '1ebbd271e807c5e3bc0d',
 '1ebd0123b33530284d89',
 '1ec5e1837df15c4c7f2f',
 '1ec7560358fef7145d3a',
 '1ecc779cf958e1dcd292',
 '1ecc872ea002b2793401',
 '1ece3171579f0253981e',
 '1ece58806db209d0961d',
 '1ed01813ce0ada6fb61d',
 '1ed1bea885d81ab1207c',
 '1ed859f20da4033e7ceb',
 '1edc16680c7cbcf40acf',
 '1edd722ad3dc3f3cc3dd',
 '1edebd2acebe3662f987',
 '1ee1d8b15bac5d607c70',
 '1ee2b8a229c97c181662',
 '1ee4817be16dad274e86',
 '1ee60ff6bf47f1c9abc1',
 '1eeaa82b5e6926214df9',
 '1eee44c685929d789038',
 '1eee6a39acbd2a89ef1d',
 '1ef127ce545c56583dce',
 '1ef32514f9a2a4b36be6',
 '1ef741bb397b0572f958',
 '1ef8595545b725f29f08',
 '1f032e56930ee5c19991',
 '1f0918c7476bfadfb589',
 '1f0944451e1a4cd96dd1',
 '1f0ac3c8a61033e6dfb7',
 '1f0f33b75d3acc663be7',
 '1f14aa8ad635f806d2f5',
 '1f157dce5b8908a1a6e8',
 '1f16608590a7f748d642',
 '1f198174658b7674335c',
 '1f19934ab309e26505d2',
 '1f1b1f7750d189c1942b',
 '1f25c72bb37141ef7a8f',
 '1f26ffc6e9608ad811c3',
 '1f2a16420ac275d2e8f9',
 '1f2dc9d6dc60d596d69c',
 '1f2e8addd0363619a08b',
 '1f33f3cbfc3ad1a53208',
 '1f3542525e6b24aa3b09',
 '1f36a3dfadb8c4ff615e',
 '1f3b9f295176f1f27621',
 '1f413fa15cc0825b4f1a',
 '1f4d3136edf098c223c6',
 '1f4dc7ddf768e562f8d5',
 '1f4dcc91c8d5b798b513',
 '1f4e27db528c973b52d6',
 '1f4e6fb5b262f23ec974',
 '1f4edb76a0e490fea246',
 '1f50090ebdd166d52692',
 '1f556ccb1a97b1e5445f',
 '1f576b1bf2c35e3fb008',
 '1f585a46190e45febad7',
 '1f5e64eb303806a6f22c',
 '1f617bd8616333362443',
 '1f64b42d93256387ec9c',
 '1f653287b7dfbe3d9705',
 '1f6758ea42871f0d6e36',
 '1f6943faf7d3f74ab563',
 '1f6cbc5fba918831f711',
 '1f6d41f107597de2ac36',
 '1f6f9ef031f2d5e93811',
 '1f6facfa72bddf757273',
 '1f716d260617ae3a9afe',
 '1f75992e73416cb80fd1',
 '1f767760ff738acf7ccd',
 '1f7869cda9549488db76',
 '1f787730831b5ef01520',
 '1f78c0ca65ca1b8d16d2',
 '1f7998c31d040b61d5cd',
 '1f7a0c0a6ad0f975b324',
 '1f7a850776775567eaf7',
 '1f7a9d917c4837a17a57',
 '1f7ce3a3c71406c46a3c',
 '1f7dc5d2078e2880a373',
 '1f84ff36987317ac41ae',
 '1f89a0cb4d51702e543d',
 '1f8cd3dcd2b60cbffcb1',
 '1f8db9e9b0d69b1a22f1',
 '1f8efa62f5648d651a97',
 '1f954180910769327e6c',
 '1f968394bbc94a4c3e63']

# %%
qids_4 = ['1f97f1551ff5dc504fc6',
 '1f98b92fc5ed7cc6ba3d',
 '1f99aec291ff79100a77',
 '1f9baa681a27bbe4b99b',
 '1f9c565e4f79e17bdd6b',
 '1f9e8bc9eb7e7c03c4db',
 '1fa12962315b9f66bffa',
 '1fa231283b43fd21219c',
 '1fa3eeb54d837ce44b65',
 '1faec426159c7db8a0d3',
 '1fb0546772dcb8cf1c16',
 '1fb0c4d3d935502a86db',
 '1fb3a00ccc0211c719b1',
 '1fb76b5158d1424b9dd0',
 '1fb8cf65eed953966d5c',
 '1fbf805ace26a08ffbe8',
 '1fc5fc3e821ebcd70ec0',
 '1fc61f90b835c46c4ab9',
 '1fca635b2f2649c0ffa8',
 '1fd076c562bb6f4adc08',
 '1fd1d221947d0f9b43f7',
 '1fd510d9e2be2d815088',
 '1fd6fd600edced869bea',
 '1fdc8c6f497a832843b0',
 '1fe027ebc6cdd247b6f1',
 '1fe33d3e899d3ae5d012',
 '1fe51cda88822f00d168',
 '1fe69d8ae0c96ee82e7c',
 '1fe6ccccd89af57cacf7',
 '1fe70dcd3838478d5a3a',
 '1fe8ade104ef2edf828d',
 '1fec7cc84567741426e5',
 '1fef14cd17f930ca5e7c',
 '1ff0474010f973b28eed',
 '1ff24809ff71556f0a58',
 '1ff36bb9972276126a3e',
 '1ff5fcb80af542190831',
 '1ff9879868f53ec20b16',
 '20006e0a4237b0250fe7',
 '2001610bc99b4a4a6598',
 '2004f8210be969c29eec',
 '2008b26e30d29cb8142b',
 '20093d88ed83b413505a',
 '200e4ce5e43b0f9f58d6',
 '20109a2d15aa44eb5805',
 '2016a9a91ae8ce4030ff',
 '201b232efda4bfb97e34',
 '201e0f6e9d2dc51282eb',
 '20215f713a6309b35429',
 '2021a5ddaefc8ab28e08',
 '20240bed10c6f0e9aade',
 '20267100d71c14499c92',
 '2027aec11c48be386cb8',
 '20290b0f09e5cfc669cf',
 '2029a99d08a99fb01957',
 '202b73416dbe55c4925c',
 '202e5e078661c21ab5a2',
 '2030b805d2c711fcf310',
 '2032b3075a8a7b3ef5b2',
 '203af4f4c2ca7ad3063b',
 '203b4ed4dfafdbc04c0d',
 '203d0721341e23c09c96',
 '203eb88fb7563377139b',
 '20404c8cab99e1063786',
 '20484c6c910077daf118',
 '2048c858917a04f14f72',
 '204d74ef30724aa28682',
 '204e46c97f5e95892dfc',
 '204ff6e348a255f1ee94',
 '205403b3e7e251a35f69',
 '205763cb70173ea307fc',
 '2059364cf7f9894a20b0',
 '205b99d053ca396f231a',
 '205c7db8320a4eb53cf2',
 '205ff0c143b59fdea41e',
 '206b369680eeea8b40f3',
 '20717d276731707d46f3',
 '2078be2cb3111c8e2715',
 '20796bfbd073ee74c851',
 '2079ece5ef4ff62778a0',
 '207d886f3ca9dd22975b',
 '207e0c01f3fe3a7bcada',
 '2086721e09473f70e6a9',
 '20879017573a62582163',
 '208a821aa313e5007d35',
 '208b4af64df218517c29',
 '20930b09e920fb72f56f',
 '20930d462ebede1e8468',
 '20933d2a12ffda57c862',
 '209360404d92ae822fd6',
 '2094b46a1a8466cb0761',
 '2094ce021b59851551ee',
 '20958bab525a90abdb51',
 '20a3aee081d06254502a',
 '20a8c330d90e942a857a',
 '20a8d6441f3178231dd5',
 '20aada15b9e9fdeed961',
 '20ac087de06e204aa5ad',
 '20add8b3afcc2f40fb77',
 '20afef2d3ab5f1cac633',
 '20b0f64feaee642e141e',
 '20b362a73c8a18b37059',
 '20b66fb957d8f81721d3',
 '20b688ef6d5519afbae0',
 '20bca4fe33c4c06295d6',
 '20c0eeea0171a6fc3753',
 '20c628d273453d21f4d7',
 '20c82882f1334205d1cb',
 '20c860acd1fb928c04a3',
 '20cad057616253b5163e',
 '20cbdec09b45329ad2ec',
 '20cfb84e67c4237e84a8',
 '20cfe2d603a83cda8ecc',
 '20d12ebc787ffe388c9d',
 '20d26eb40e3964ba90df',
 '20da91f52515f36c5905',
 '20dce50d7b999fd224a2',
 '20dee8d3a5ab8803b7bd',
 '20e92a20f15751d76e38',
 '20e94102558f1263ccc9',
 '20eb240a484c5df3685e',
 '20f407fdaf819bbccd5c',
 '20f42e758af1ced4138b',
 '20f6137ccf767ce900dd',
 '20f6542f978d7b0f125e',
 '20f773caf6c937d148ac',
 '20fc05c4cf75568c16c9',
 '20ff8eb03daeafbf6989',
 '2100c9732eb8083f1482',
 '210484628510d7eb1a1a',
 '21097e85c154895434de',
 '210ac835160b7f829c04',
 '210ff6747fb7de3bf0c7',
 '21165f1312eeb8b9edd4',
 '211be11b85264d17bd39',
 '211c41af2580b56cfe3c',
 '211cbdeb940792381829',
 '211d03903ab3b84ce215',
 '211d4b1193f2397953b1',
 '21201dbdfacfc65039f1',
 '2125ab0340fab9b59ec5',
 '21271617eb73ea5be56b',
 '2128d20179867502c2e7',
 '21316c49d0ceb1d2a127',
 '213a94d3aed35879d9b0',
 '213e94e4ac393153a3c2',
 '2143c66636876981c91a',
 '2143e44d92d9f9dd57fa',
 '214b5ce36f8ab4984ceb',
 '215050fa63b7f2d33d9a',
 '21537b7ba47015b1f801',
 '21560070b97769c72583',
 '2159b7b162de5f66176f',
 '215b4f4cbe1c5c198aa5',
 '21601e2553292d5f1b84',
 '2163d6e1b29bc0c1f5d4',
 '216502dcab7959d08103',
 '2165ce3a9b6e6f0604f9',
 '21699f201852c185dea4',
 '216d2bbc86518e22ed32',
 '216f00827eb3dea9bb24',
 '216f85f3d00866361cea',
 '216fb9dea85705feaafe',
 '2171721ba71d51b7ae58',
 '21764b47abe816d6feaa',
 '217750d94e150a7fd1df',
 '21786f354409b4d09088',
 '217a8ef578852cac0b62',
 '217ad4d0f63262502832',
 '217b27b559471f18bc13',
 '217ca72655d6066a6c09',
 '217d5d2a28558bad5372',
 '2183301a729676545151',
 '21845f17512fcd39f033',
 '21846d6f3bd7ee039359',
 '21859b540804c54844e3',
 '218709f3bb7ce8bfa3ee',
 '21878eb6c98b9b26cdd1',
 '218ca52d9e38f5ecd3b4',
 '2191910271aad350ef86',
 '21934a7fd24d6f25979d',
 '2195125b7a951dd7e033',
 '2196d01d6a692543594b',
 '219800def4f9f389e75d',
 '21983c31d7d44ad31bd2',
 '219989eea048c208eff6',
 '219c598a9a28a4016602',
 '21a13235a4d958100c60',
 '21a1dc8b9405a4e197e8',
 '21a2462e471e3e912e8c',
 '21a4e13a4973512f4df8',
 '21a7974a274dab19e02b',
 '21a9269c7e0f5d9e8320',
 '21a9a196540e4ecf8fa7',
 '21aa4fd893da5ede2867',
 '21aa557f9cf178e487a4',
 '21aa651c658a4b514263',
 '21aa704364b4739e0dc4',
 '21ab57ab06c3548a933b',
 '21ad1e954e94cc2083f6',
 '21b0227a006b0dd3213f',
 '21b05f676683dd00a18c',
 '21b2fd2c32987e62f9c5',
 '21b4942b4de7c5e15140',
 '21b4ffa7215f40ecc174',
 '21bb2444f0895f892593',
 '21bc1f5e207cdbe24f88',
 '21be4871dd7b4ec7acfe',
 '21bfb0fab9987f15706b',
 '21c300916197d015c52f',
 '21c5dc4382dbb838fad6',
 '21c96a63c7c9f8fdd843',
 '21cbc048aa694933efc0',
 '21cd68ceae297f2d8ca4',
 '21cedcb673c69961b9bf',
 '21cf7a27fe9981e62699',
 '21cf923cc883c323bca7',
 '21d16287245634209cc8',
 '21d291202cb8e6cf91a2',
 '21d56c36d719bb98fb3a',
 '21d7cb46e9dcda5c5927',
 '21dace55f7037e2cf238',
 '21e5e62912f78cde9dea',
 '21e6c77102e76972d331',
 '21e9e0447bff7ea8ed7a',
 '21efa4ce2aee6fa524f6',
 '21fade7c029623c82692',
 '21febc3306a52a0d7a54',
 '21ff82fae659542c3449',
 '22011e54b890d30d98c1',
 '22099a4ad3841349982c',
 '220a479128c7a8db2707',
 '221160cf46d32631ca3d',
 '2217670ef18c4548a50a',
 '2217c77b8428d2dbe811',
 '221950373031671690ef',
 '221ad45b0bf32ff6a28b',
 '221af648542c057911c6',
 '2220d940934b0889b767',
 '222655b23aba0b9a61b4',
 '2228224fb404bd3f660f',
 '222af2e3b4c5b1412a3f',
 '22372a0ef1a5d51a703e',
 '223f96601dde98cd7c95',
 '223febe6a8919dbe4cbe',
 '224057974af0de2c0ca1',
 '22434ba723d7b52b925d',
 '2243b3cc1f43b7ef2d5b',
 '22498df9275810e0a027',
 '2252deb49d90a695ccc5',
 '225311d40f6f2d453627',
 '225432345b1dbcf8b12f',
 '22548c61494b8fd73e6d',
 '22582dc117b76a537568',
 '2259a4ce200b1f6f596f',
 '225d367a32ae489b2de2',
 '225f877882979b1937eb',
 '22623017689a8dedcf9e',
 '2263f9853439228696d2',
 '226bffbafe2def54f620',
 '226cfedb92ddf9d66db1',
 '226dc532c7fa4b1818c1',
 '226fd2bb682958003703',
 '2276c02f1ec97ad9dfe7',
 '227838d0d877d4c12414',
 '22787ac7476668010c9e',
 '227e9f93bd9ab11c883f',
 '22852156e012c7db7364',
 '228856d0571d45773cb1',
 '22896ee3bab2fa9c75a5',
 '228f017b7f42b419ea27',
 '229208486135ca64aab7',
 '229385a78aae8d6517f5',
 '2295bd1ecc63c551878c',
 '229860d5f5735d84180b',
 '229a46797114d94b51cd',
 '229db2c0a98a4f47c350',
 '229ef7b33146f94b1033',
 '229f11339e51513ad77f',
 '22a001c2c71d5af7d645',
 '22a055aca4891108ce83',
 '22aa8e337620928552de',
 '22aecfb16c25beae9b2b',
 '22b2916d7f91c6f1d79a',
 '22b4e58968ba3a2a1d62',
 '22b70f776fcbc6206cda',
 '22b870f0f6677a977479',
 '22b981e32384320c6722',
 '22be220554190055d1d7',
 '22c0e45857f135d70b87',
 '22c181adf25fcf7618f4',
 '22c794ca9418d91e7d79',
 '22cf9e107e9157dab76c',
 '22d7edfe9c332e5afdac',
 '22dbf1b44a08c3384116',
 '22e14a57a0476d8a1ea8',
 '22e26d8666216fa162ce',
 '22e480f1b5467ae19e25',
 '22e51c8f3b5b2934ef06',
 '22e7cd8d6165b03434cf',
 '22e8c1b2c71c28dc6a03',
 '22ec2e3cedcef907385e',
 '22ef84c700a1fccd2fc8',
 '22f0f9e5ac079746ebb1',
 '22f101a877655433fc72',
 '22f125679cacd0ec526d',
 '22f2fdec1814f827b21d',
 '22f37a7e3f3c4bfe449d',
 '22f5c264f92a89a9365c',
 '22fadc4695b8a4dec507',
 '22fd8fcbb54413ef1150',
 '23010c93c4120eb3583c',
 '2302b11301d4f2b0b58f',
 '230519f78080ad4a76d2',
 '23055097465b827c5747',
 '2307f2fa8805936be273',
 '230935ea2ef97abdb1ca',
 '230a76dac713c8171a5d',
 '230f73dabcc7abbd958b',
 '2310b94ce2f64049cc64',
 '2312cdb93adca36652a0',
 '23139033438bbb0613d8',
 '23153dfe74495d2d98ef',
 '231bac720dbd8f0caf43',
 '231bace438988b0f37a1',
 '231bf3765ef74fafd998',
 '231ce75ea4de0d530aad',
 '231f6576e3393cf1180c',
 '23222c8ee9e38a416a6e',
 '232266a1e662e4bd9986',
 '23285994145a1f6db6d6',
 '232ccea0e6ad0b9f0959',
 '233281d7a157338165e5',
 '2335cf572870d395eefa',
 '23379378135d05568877',
 '23386e0d9d610dd9ed5a',
 '233d8c81b4288603da8c',
 '23429b1e77676c27bd03',
 '2349d4854aec76ce7857',
 '234c5a2e1db786d80019',
 '234cb38918d3d5649f60',
 '234d4d2372e72d9ef124',
 '234f02d345c15a85297c',
 '2353f71cd55340254d58',
 '23598159af4bd3188984',
 '235b39fba8c5da80c518',
 '235bd30d757f519c7b8f',
 '235efcaeadd3a3681683',
 '235f2f2289977cfaaee9',
 '2362f4617409c450b996',
 '2368e20e6793da1b6a2f',
 '236b258cfcf41585743b',
 '236f098244836fe40f5e',
 '236fddedd31b9e07eb1a',
 '2370ebccb034fe219097',
 '23732157c77b1ec0f91d',
 '2376823f257e3dd5597a',
 '23792eb38f68f01e224b',
 '237c01ff34ad05bd243e',
 '2383db07bfef6ee7cc81',
 '238da7294653016e70fa',
 '238fc234f6b421c1cfe8',
 '239175a193200bf5f3d9',
 '23923308d0d81819a13d',
 '2393207c6158404a6979',
 '23949b57cd7139ef897b',
 '23986d42e1f46585f8fd',
 '2399bfe1df817e1489fe',
 '239fadd251aa361639ed',
 '23a1b0c10310a99ad6bb',
 '23a1e4560447af53dd07',
 '23a1f14f145c1bc67ea8',
 '23a5052333bedcfe1465',
 '23ac21616c8da2aea8e0',
 '23ad86c95384b90cd110',
 '23afb17de0036288e2b8',
 '23b1f26e3fbb3f67ac95',
 '23b4af38e6142f83aaf0',
 '23bc8b9414751d371128',
 '23be6d13e2b0cecd916c',
 '23bee7d9378acf461bf9',
 '23c320ed8eff927c152e',
 '23c52d1c4eb7501965e4',
 '23cebd9d3545c540576f',
 '23cff55a64b78f5fb03d',
 '23d1b4063c4463e7832e',
 '23dc763467c8a0a2b8c8',
 '23dc9026ce87a5c48c90',
 '23ded0e42b8efdaae404',
 '23e6ecf126ede2cba9ea',
 '23e856310cf3a869bc4a',
 '23ecfcd2bdf024ecd079',
 '23ed48762ceb32747c38',
 '23ee3291ffb98f7c2ce7',
 '23ef67de32a0d18fafef',
 '23f1bc10c7a6f14001f9',
 '23f4f6df922c486e4a65',
 '23f9586ab41212c57ee7',
 '23fb83cae7111922dc78',
 '23fff296faf37335b3a7',
 '2400a83cdc26601d508e',
 '2400efff3bffaecfb5af',
 '2408841de1f455498562',
 '2412eddcf7119f252756',
 '2414231d5801c3d10f44',
 '2416bfe392f6a1c94429',
 '241ae7350c06ff3c591a',
 '241b98a5b60db3ce8c56',
 '24271c07d14496f83f12',
 '2428a0541bbd37e0f49d',
 '242de006858c58b9412a',
 '242e297fe6280bba5bd1',
 '243134c65fc70398e443',
 '2431985db788ef2ef154',
 '2432df74a6f5e14449e9',
 '243798e6c72d9fcf78e5',
 '2438758b8e6d9d498f1c',
 '2438928b464a3083005f',
 '2438daf62c92c932e43f',
 '243a955ecdda3c459f45',
 '243b277487ea718bd383',
 '243d016f3927424174bc',
 '243f7864b0d32c1e4bba',
 '2445a46b57cadc3b7121',
 '24470f5b1d067a0747c3',
 '244c54a6af73d6679a65',
 '244edc241e4072e24d4e',
 '2450f178c98f5fdb6e5a',
 '24571a3c18be8788cdc3',
 '2457c99591e3dbf8e9c4',
 '24592da0f6eebc87567d',
 '245d77eb4b069d234921',
 '2467ca7f7d518eb83263',
 '246de2e6a2979a84492a',
 '246f05dff069ba5076c7',
 '24711ce73b6f8b392693',
 '24748d9035fb4fe9b68b',
 '24778344ccee14939f79',
 '247c29175ff74c56c179',
 '247c7a75ec58473b6952',
 '247d5e8b7dbcca4b3da8',
 '247fa9128a4afb90a9d2',
 '2482365daebafb6a20b3',
 '2485224302e8a4c62a9d',
 '24859ee1b84975d89611',
 '248f781a5de93dde0519',
 '24912421654a88fdb2b8',
 '24915eefcc13b2f0e187',
 '24951e4d238b2efc3fd8',
 '249f9a298f43511ad6ea',
 '24a1b67fb432846e22e8',
 '24a20c51b8938463915f',
 '24a2423d015e35b87932',
 '24a2a0e0b3b265a0ad03',
 '24a65f6c81a418301830',
 '24ae6383d789174e6acf',
 '24b45995705896fb461c',
 '24b5be92f616e3b0f52e',
 '24b6a201f2befc3b34e2',
 '24b895793de954d778e0',
 '24c259354b7a388484a5',
 '24c7ecc1f365a4581dad',
 '24cce791c2857fe79d8b',
 '24d1aced364052081b0b',
 '24d1f9362d3aa7946e91',
 '24d22309bf4a5a7b92e4',
 '24d44191fd3873c81a55',
 '24d6fb0f7f7ee1f305b4',
 '24db8d29dba791a0183f',
 '24e530fa44ddbe976d3d',
 '24e715a60702424387d0',
 '24e7d4716a03bf19ae1e',
 '24eb1c54543fd8576d1f',
 '24ee4e073d641826ed6a',
 '24ef5e8b054fd1fd2b8c',
 '24f0513b4548ce9fc456',
 '24f05445491bf87a2d7f',
 '24f08799d2140c9c9488',
 '24f16d5b25a9c980148f',
 '24f293d2e56dcd733d6a',
 '24f2c907c836e41a24ee',
 '24f3e972e06ee0eebc2f',
 '24f4848101f87eee9d7b',
 '24f81f6ace74df2c66f2',
 '24fe59d687f266e8a58b',
 '24fef4c7c1a858d6a63e',
 '24ff74a2702d68d512dd',
 '250366f7b953c5fc822b',
 '2505a046337e0cf643f3',
 '250a019365dc7d530ba4',
 '250b51b4032ea2d6b0ed',
 '251419dc76969a5572b4',
 '2519c6aea6b8093ab4e9',
 '251addb97a90fc409a5f',
 '251dee1626d7a396f02e',
 '251e1a2869cd88394e09',
 '25238c82cfcdf5cc9496',
 '2528726a308ab5da47c6',
 '25299eca9ce930828cb8',
 '252d9cc4aae23ba4b887',
 '252e172bab9c8884830f',
 '252ed8c980877c937c41',
 '253164ad489042aa15d2',
 '25358be6b9de47e71df1',
 '2536f78662ecd60a9f69',
 '253de38d3f3999a5c385',
 '253df910f558193c9981',
 '253f93b548530fd7ac5b',
 '253f9c6dc02372b5086f',
 '253fb8c3a95c9f06d558',
 '2540c562d5f3cb88026c',
 '25445208d24639c43a81',
 '25501c3bb23d7d5a0f4c',
 '2552065d2300d9775afe',
 '255285224d010e8f64a6',
 '2555e62577ce880b2f5c',
 '255b2ff1d3386417ddb5',
 '255d4e422b73a69bd057',
 '25615464911b2aab493c',
 '256211a2a90876adc01d',
 '2563a5a8059ecfc6cc08',
 '25641beee98574fb5caa',
 '256695c72cb0129a54fa',
 '256c0cececf46ad4a301',
 '256e7b8a94208216d86a',
 '2571cd403a5ca64026e1',
 '2575e167f8688f2ad051',
 '257691f1bd6fd1e7c23c',
 '2578e5e5847857920dfd',
 '257ad1780a40ba3b90b2',
 '257b22b03bd27da65964',
 '257ecdc32b358104b850',
 '25802aa4dbcf8105a2e1',
 '2582f726df2f7c99110f',
 '2586c6ef9ed7a14c6d69',
 '25891bf082406a28761f',
 '258c1d088930b8c97705',
 '258e02efbe530a84fafa',
 '258e38b26b305f908246',
 '258e6b2da96ba19e2d40',
 '2597053ce95702aa7105',
 '259a538b3b572075c503',
 '259aba555a04cdd0e583',
 '259e111dc75fa29a6be4',
 '259fa4bc17ee71d5542a',
 '259fc0f458ba0b339ffa',
 '25a06421c8eefebb3cbd',
 '25a15e63f7a12fe4adb3',
 '25a1658f2ab473933d85',
 '25a28678d51709cffd01',
 '25a65239bef2c16b3cee',
 '25a770c7ed08978533e0',
 '25a8db4c8dd50e5d8cc9',
 '25ad6d01d710223f8756',
 '25adf88400a1ad9751f5',
 '25af3b81fbee0fb9cc0f',
 '25b187c03e2bf2fe0240',
 '25b3565181e7739c535e',
 '25b537a860990d43e368',
 '25b57dc01c2affa0cb52',
 '25b691ba84b19d2441ae',
 '25b8d40e6d417ad28ef2',
 '25b96898bc392ad4202b',
 '25ba7617d42521cb76ac',
 '25bd36896cc1e86d9313',
 '25c21212a3f8c788559e',
 '25c386f0184fd4287c53',
 '25c467c88eadbf2dd7a2',
 '25c545a5449058760b1d',
 '25c5f745f644bda9e1a9',
 '25c763626be8db04a882',
 '25cc22559e46acfdf36a',
 '25cd9b7413a226c36bc4',
 '25ce52f62d8c500b0cd3',
 '25d10f5791fc02aea5dd',
 '25d32f0fb358e37ba77b',
 '25d4699888c3120e98fe',
 '25d565747812285833d5',
 '25df89cceffb33ac4897',
 '25e35eb8c80fc1b50d01',
 '25e67e724bcb117ec686',
 '25e7028287f659572544',
 '25e72b4e480ceb63a1dc',
 '25e7ba2bfab563dde64f',
 '25eb2b25e9f415ce1b7d',
 '25eb84f109db9f37b620',
 '25f0870fe202f97a1ade',
 '25f3a026c977ec02b06a',
 '25f6e43f43d0502ab6c4',
 '25f8369c53d8596635c3',
 '2606434018ad8a799395',
 '2606b234ff23a410026c',
 '2607509b048f720689fc',
 '260af9bb219eef3932dc',
 '260d12d4a61dae1c750d',
 '260d4fcf1e39803e4e44',
 '261099a9e658acf40c98',
 '261cfa5db9061027106e',
 '261ed8d2ad79d1ba8380',
 '2620791f5c553ef31781',
 '2625bcfdb2a38eebf4eb',
 '2625e1041b7994b71ea6',
 '262742d8306a13254624',
 '262ae5089fea423fe554',
 '26333b2d5918a102741d',
 '26342d21785849e11a20',
 '26362a8e62dd75ed0881',
 '2636b1f379064948f7cc',
 '2638af00164d0727fda4',
 '263b1bb59664e9d6b70f',
 '263d925fb37906dd43f3',
 '2640ad2bf404561fca22',
 '2642b05180ecafdc6557',
 '26444fe5f2f9f7293714',
 '264679c569c99d51148b',
 '264a7756128e9fb2e384',
 '264c10dfbf186d21fabe',
 '264d2041939beb45b3c5',
 '265243098ecf19d740e7',
 '26576e7b759aa0557884',
 '265b51f83572859136ad',
 '265bf3863dab98c62552',
 '265ecc8283a288bb8363',
 '265fcce99a8bf964deb3',
 '2664df4a40b742dadbec',
 '266607cadfb829e45e61',
 '2668d6e58d567f73a996',
 '266eaed18f7392bafd77',
 '266f7992eb06e49cba04',
 '26762afa3c431c396581',
 '267730f48feeaea6a517',
 '267cd9a371c5ff58a130',
 '267f43a19fe9c49bf239',
 '2682f0e204ca7f08fb8b',
 '2686a3118d7f036684cb',
 '268b7f0a7ddf591c5ef5',
 '26917b3289a7e71aff83',
 '26974c6964e93ba50cb1',
 '269785295f020e60c969',
 '2698ab672c7d88d13744',
 '269945456d4e588e58e8',
 '26a044b4d588dfe5bf7a',
 '26a75af84e810c5a9010',
 '26aa1b234bdbeeecb859',
 '26ab2b07af9082675f9e',
 '26ad2b2e983aac743cba',
 '26ae0b645763847745b9',
 '26af9ec85747073959d3',
 '26b180ce9bccccc0608d',
 '26b71c467f7b84419db9',
 '26b73d02ec3f7b242a2f',
 '26b8fa24393cf8b0a88a',
 '26ba6dfdce5d4b80e239',
 '26c1750cc9071e213ed4',
 '26c82acc3445f202e01a',
 '26ca99402038e7b3aa70',
 '26cb95985b9aa4cf8983',
 '26ccb5b4ab7542e16a9d',
 '26ccd425edc4216f647a',
 '26cd59927c80423cce24',
 '26ce697a6ef64a9b5cdf',
 '26d0fccf083bab58a2df',
 '26d28d240c0fe1bb3a94',
 '26d2cb86ad74a6e134f4',
 '26d649d6090bd130b7ee',
 '26d6afe4bbc6fa0d1a5b',
 '26de9c08d34bc47fc308',
 '26e1b81dec5a3ef91782',
 '26e6edf4905c44d7a194',
 '26e78cddf60d54356a7f',
 '26ed109c327fae3c21af',
 '26f02b4f4ca05dd2ccfe',
 '26f151b23516435e3631',
 '26f2e2d01cf96121e54c',
 '26f54282d282070b504e',
 '26f63ba6092cb68f3d08',
 '26ff6c6f3d5b2adeba58',
 '270695de8d707b2b0c66',
 '2707b52b7e3071646edf',
 '270f2387faf975b61e37',
 '2711208b45829fa17e9a',
 '2713730c40c5e58e0aff',
 '271390eecc58ba598622',
 '2715bd9e5c5a9554e801',
 '271954fa623bb4b1cb53',
 '2719a0d27b21b605caaf',
 '27238b23ab164555766c',
 '2726466e4479945311ad',
 '272c067b82eaefecde74',
 '272c53bc30f5efa06d2b',
 '272fd5406c8792cd1649',
 '273cb1417e9acc304ee0',
 '273d2cd8b42a964b9f3d',
 '273d7d019bb12ac07e45',
 '273f019d66b484ef1b1e',
 '274330462927c45d0e69',
 '274b67458668f834f1dc',
 '274bf8087e4acaebf285',
 '274cab5d0082b4fbbaa6',
 '274d0e771f17284f059c',
 '275324a03c789b0d98a1',
 '2754e0ad0bf757f94087',
 '2757fa8979dc446ce9c7',
 '275a512ebb01ab7f2c37',
 '275b981fae8facd395ba',
 '275be6749bb7d2302afc',
 '275cb6974daa52574bef',
 '275cdf7f8a8c35d969cf',
 '275f35309c8ad97255ad',
 '2763d9ab93c1ecf926e7',
 '27667a3b95fabcf8e43d',
 '2767fb27bb94277973fc',
 '2768870bf89a9ed7b3b6',
 '276d0ecc373196ec6c08',
 '276d73a5691819147abb',
 '276ee77707a2e021f28e',
 '27795f79b2c30e90950e',
 '27797bfcc50e3426301b',
 '2781ac0deb2703e09927',
 '27825e23829ac49b3b91',
 '2782e8513a1725c8cf7a',
 '278557e13ef38e3b5bbf',
 '27879a1178eff99a25fc',
 '278d1351d849f9fd39b7',
 '279040a0955e8f972ac0',
 '27905d5f8e5dff9a8a43',
 '279173b5e7e331830d46',
 '2793f5703b7161b55f9c',
 '279757f12c78201c2952',
 '279ba4ccffdab84ef1fe',
 '279efb08631e0df38920',
 '27a919c9abbbe1ba7192',
 '27b2bec7bc93269563ff',
 '27b353711b942244a538',
 '27b55c3a5455a8db1a85',
 '27b86a517e549103aaff',
 '27bc357d883772a6f812',
 '27bd24c471b05c62472f',
 '27bfb36fd7a96405e82a',
 '27c2d93b8bd8992ebeff',
 '27c7e3f69bd7503fe4e5',
 '27ca49e82f60142192aa',
 '27ccd3e8ac0658b5688d',
 '27d252c7a49ad1a2ae1c',
 '27d8b3b3a2ca5922cf4c',
 '27d9d0ccab48da0e28a8',
 '27de58a4f36264579131',
 '27dff7673fb1795effbc',
 '27e38f5a6053ffee3183',
 '27e54fc943f6f03d040e',
 '27e5a5dc828d3bf08485',
 '27e6457d63103f3af49b',
 '27e8d583bfdbab45dbe3',
 '27f07af0630bfaed76c8',
 '27f283c5214c0b7419b3',
 '27f29c6655e47ac78eca',
 '27f2ef03785d1f96cd6d',
 '27f362bb6dbc6168bd17',
 '27f3a21b822cecd65ee8',
 '27f85109ec35bd66be8b',
 '27f943b496e5e6c697d9',
 '27fd9abce71f90d73a56',
 '28017388db03199ab791',
 '2806692d20ee45b594b7',
 '2808f3778edda2859b0c',
 '280a568a949c00b13c07',
 '280e5d66e9109e9eb961',
 '28122d354a1e7d5c67ea',
 '281461d53e748b935b4f',
 '281489d9c55a909e3f86',
 '2816ae4fc37167e4bdf9',
 '2816f1945e8dfc9fbf14',
 '2819c6876ba39633d1be',
 '281f261a748eebaad6e8',
 '28215fd942a4f4b7d463',
 '282384ddc7547ee65edd',
 '2823c39c1ce1e8e56f0a',
 '2827418852799dde6fce',
 '282c47f003ccff97c943',
 '282c7c4818e05e4c6c2b',
 '282dc68ad414dc1f1137',
 '28303d16c2f9a9848457',
 '28305bde0314f1db51df',
 '2830b19df12a79337795',
 '283427d15c27109e85df',
 '283640c084d87a2f88fa',
 '283737d88c5a1d6b6de0',
 '283a0d2974aecb6b6f87',
 '283a757b4f6a5ad2602c',
 '283d7292ca5d71049dfe',
 '283e1fe8a977ceb8e018',
 '283fbd41b9e4e5b0af62',
 '284588702b89cf8359a4',
 '2846036f81442da22530',
 '28490c57a0e7f27393bd',
 '284b0e990c4215cee8cf',
 '284d65f5bda93d58a0dd',
 '284de15687d12016f470',
 '28549f0cddf21583f49b',
 '2856459125b3cd3e9648',
 '28595411040e8ec7124b',
 '2864a696c659e8bd5655',
 '2864e7c1ce92c41cbde0',
 '2867045a492b63538638',
 '28685f30cc44cc256771',
 '286960c7e1c5bb31d4bb',
 '28697384be931a1bf5e2',
 '28708232f5d6c51c8808',
 '28718e4dbc813f3d82a7',
 '2873e647b7e95c5a9ba0',
 '287441b762c8b601bd9d',
 '2878c6708407ff4359cf',
 '287a51584a144ea6f909',
 '287e52de4e0284780365',
 '287fc65534976cbd92ed',
 '2882ffba134d4626957b',
 '288318a9182d188cd8af',
 '2885a191520cbeb1bcc8',
 '28879f9c720e1b93b3af',
 '288d503ff4b8a3a24dd3',
 '288dd79c89594ad4d584',
 '288e24428e2b9aa86a5d',
 '289187d1d533bab0b3f8',
 '28933f844b1c087ab227',
 '2895fc992fd93e029c5a',
 '28a0d66e35bb4323b33b',
 '28a1062f951e6c48a2fe',
 '28a240749be9302c5ba5',
 '28a41862911b97f521a3',
 '28a419cc91e04ad73039',
 '28a6e3ac1f5a78885c29',
 '28a9821ac5f099606181',
 '28aca8effc1cf5b91c84',
 '28ace4ee1ce1a62d3d24',
 '28b3702235d3e0e3a602',
 '28b3a0b855fda2bf3bc9',
 '28b7b24fb2a5bea252c6',
 '28b8ca3ce03cdf31a7c8',
 '28bd6497efe0c41526ae',
 '28bfdacd59d7e44ad074',
 '28c1a0ee819be04049e1',
 '28c201262c7161853d82',
 '28cc3d53e5b8edc45069',
 '28cf35062cdfdf7defbf',
 '28d478acbff7e1589d68',
 '28d9a790411495d4d097',
 '28da2c9c8b5bb2c7d821',
 '28db9ac85cc5eb23d53b',
 '28dc9c33232b6f32d340',
 '28e1ac42ef4f1dd33e59',
 '28e3ff7b2990515b9503',
 '28e4ed14797d23e23727',
 '28e554d1e5758003296f',
 '28e598434fd3f51eea1e',
 '28e5c074f3612eeabcb2',
 '28e63fb177e39e502599',
 '28e716467ed1e935b422',
 '28e71ed91791c822cd5b',
 '28e7e21c11d5b44bbd13',
 '28e7fcbd7cba426e5784',
 '28e8701fcd9b2dd26bf7',
 '28e90e1ba0e7f05fb09f',
 '28ec4c8fbb9aa6065e36',
 '28edcd490a86c0ae0656',
 '28f13e880f1a8ec2a822',
 '28f2bc784562988b1b61',
 '28f3add6fc9192b0d306',
 '28f3d239a10c92011546',
 '28f40bf314885a41a748',
 '28f4654c3d835e6fb4e2',
 '28fd09ce691ef01a2109',
 '2900e35b8f093adba4a2',
 '29049b3d9782b5e4c5f0',
 '2904bac5eb23960075a7',
 '2906b6ec370691473a21',
 '290a2db5c7d429a4dfb4',
 '2913e4e51287e1d1e960',
 '2914b609ce0efbd344e0',
 '291d5fa4be23fd9fdcd2',
 '291dd140f26f78052bbd',
 '291e4f521985503f7241',
 '291fd87fb50db99dc2ca',
 '2921cd33543c08b4b57d',
 '29223a8e176fc7851217',
 '292b2e012d8efd76cb8b',
 '2935ed7677682aa3e1a4',
 '2939701a275f49bee9ba',
 '293e834d1c30f9f08194',
 '29404c51d20a33ad01f5',
 '2941ab3883661d372823',
 '294c634c5a0db3f825da',
 '294cb6853554935e7cb8',
 '295b2e916a6567d8540a',
 '295c604a37d02868f211',
 '295d245d2135e0d18f8c',
 '295deef1d3aadcebb9e0',
 '29648e34ddee1f02ab6e',
 '2964923c2d12a3a39743',
 '29656880982a1d03a976',
 '29661c253c31bde877b9',
 '2966f23f711ebecbff83',
 '2969999a504679d3738f',
 '296de2c3886284638dd6',
 '296eba8ea6682f7c829e',
 '29706dbb1fca388e3f12',
 '29715045a06016aab7a6',
 '29740cdd4daf676d5671',
 '2974311959f21e3cd8c1',
 '29799813a5943df56b59',
 '298198d677b96c855bb0',
 '2981cc0bbc08dd640180',
 '2984f96feca5eb963543',
 '29864450604efd1ef2ad',
 '298654f26ca3d00bbefa',
 '298693adce1ca3c7c212',
 '298ae7bd7d08d2673166',
 '299232aedb89684a9226',
 '2998b3220f881b0d08e0',
 '2999a0170f25499e32a8',
 '299ae04030ef071c34fd',
 '299b2e4bb50eff5319a4',
 '299e41c41e4bde3d8f51',
 '29a024d2ba229f9bd9dc',
 '29a5cd24242a37e5fa7a',
 '29a5f0762016cdff5a73',
 '29a5fa4f55484a92e319',
 '29a9579c8cf47cec2870',
 '29ae6088b49b20fa0ff5',
 '29aee04c485ed57a622b',
 '29b34c599b41200a452f',
 '29b4c2520d430f8e2c3a',
 '29b5175355055a810d0f',
 '29b5ccf8e4cd8cad761b',
 '29b5d61c6eaa3db1ecc5',
 '29b60fdda8f1c0aec816',
 '29c630544f9976707e2a',
 '29cb3a1448fbb2f8f93c',
 '29ccfc1ab5c973c57c00',
 '29d096deaf4936ecc7c5',
 '29d418053584a8ff4dc2',
 '29da9fda6fad265ad1c0',
 '29de800d737a94ce9cd7',
 '29ded85bc790cb96014c',
 '29e1733a5482550e84a3',
 '29e32784b46f720e97f4',
 '29e6fb80b109fe603680',
 '29e817ee50b1e013c2a3',
 '29e8be65c9765b687026',
 '29eb2890ebcdf61473e3',
 '29ee25e39982b6160d29',
 '29ee7e05a2eea25c89cc',
 '29f07c40e0142778f20e',
 '29f268054f9a248c9678',
 '29f77e95530dbff60256',
 '29ffb628a078984328c1',
 '2a0129cf228732686017',
 '2a050c1779c5d139eeee',
 '2a0600da088a1f79e611',
 '2a14aff411b3ffcf6f52',
 '2a15b26516e4c1a6f92f',
 '2a16983bc4d2ad49c65a',
 '2a18aba2b6e694ee5741',
 '2a18ecaf5ffe828181fa',
 '2a1bffce6662a79fb5cf',
 '2a1d0b49f250797bdc8d',
 '2a1e83fe34ed617edfb8',
 '2a23d7c80c0583245b44',
 '2a282a4737f06a067775',
 '2a29eb4baef0d2ecc6e2',
 '2a2d0553dda0f14495a9',
 '2a2d47c368f89fb28009',
 '2a2f99ce52d3a13e1064',
 '2a30ac009d877a08a1cf',
 '2a4826ca47793dbc63ed',
 '2a50657411325f37658a',
 '2a50a5c905ad611beb77',
 '2a557bf19af24495872a',
 '2a56c16b8fb0d1442b75',
 '2a63050ce81e28156f47',
 '2a63a2f3f3ad70cb24cb',
 '2a6538f8fe29fb4de7e0',
 '2a6da71b9433dd3f6ad6',
 '2a72a1d9ee446260ae12',
 '2a76c17921f18315d3c6',
 '2a790f70fe0e9b5e4e68',
 '2a7d0eecfa6921c6e46d',
 '2a7dd17e4b9085f86c22',
 '2a7f6da443a271490d71',
 '2a8280e28c058c5a54a1',
 '2a83580552ed96bc8be5',
 '2a8512bab444050fd9f0',
 '2a86dfeab72bb9fc890e',
 '2a883e4450debd990760',
 '2a8ec91c60f8de5438e5',
 '2a8f646373b4d4f96c95',
 '2a9833bd946ccf5cff5b',
 '2aa6235e9f47290aefa2',
 '2aa9279bcc010cf3c522',
 '2aab697d7912202ac6d6',
 '2aaf90152e60ca84a79a']

# %%
qids_5=['2ab12e1485d0163faf7d',
 '2ab558f3588762d8bf18',
 '2abb89f81874f9138c6c',
 '2ac09f638801002b2830',
 '2ac58b2b051f159563f1',
 '2ad2ec51f48cfef525a2',
 '2ad53afd19ae8b08ddf2',
 '2ad6dfb842b9dce709fb',
 '2ad7c43f626d0f354bdb',
 '2ad8e1d517ddbce3f947',
 '2ad91b5cd3c83ff3dec6',
 '2ad9625cb50b25e4a273',
 '2ad99226925bbfa1153f',
 '2ad9d03dc66eb386965d',
 '2adcb56a8715cff326eb',
 '2add9875390fc0138700',
 '2ade898a7f81ec3ec6e4',
 '2adf3642ad510f621cc8',
 '2ae217b7748448fcbc66',
 '2ae2e822995dc589bfd8',
 '2ae3475245e3979ca8fe',
 '2ae62fd476e409b09b58',
 '2ae6d5bd3e20794115c5',
 '2ae735034c59b4b68b40',
 '2ae77aaf2c0405415c96',
 '2ae86300d6c8962f3d2a',
 '2aeb1545c49390d3d89b',
 '2aeb3f7d14979e44e87b',
 '2aef1962561b49430bb0',
 '2af2a6159752fc9ea610',
 '2af8bc6b3e6713ba6777',
 '2afb335d26c4c45eed7e',
 '2b002be17666ef14e9a2',
 '2b0406192886242cacf3',
 '2b065fc73e7a6b98f003',
 '2b06f6708f402221ed67',
 '2b088142d198c984f13b',
 '2b0a2b94e2397b630e0b',
 '2b0b7c5e405068eeb151',
 '2b0f5e31bc624d7c3f0b',
 '2b119e19bda4c9d85e77',
 '2b15adba6e0ce951dc01',
 '2b195654366add581abc',
 '2b1b5becac68e87505db',
 '2b1f8e28d16d74082b39',
 '2b258d89bf50caee7a6b',
 '2b266408faa0237d4ebb',
 '2b2698568e4b3185e8df',
 '2b27856326d4f0f7c553',
 '2b29774f1576359dc2b4',
 '2b29de9c128001cf4dab',
 '2b31702237d93ed213fb',
 '2b3371b6bc4770ca773d',
 '2b34201167698d9d1652',
 '2b3cb7db28260b4f68e5',
 '2b3fc4274935586b6780',
 '2b42d06a1c746cfff800',
 '2b4ad98dc56020ef1912',
 '2b4bbb1586f5d5e4e39a',
 '2b4d0c45c1cee536d6fa',
 '2b4d0df6e2fe6302f29f',
 '2b4d176044a18ad03c41',
 '2b4db7bc2e3fe5f2751e',
 '2b51aec9d8209cdcc92a',
 '2b52b9569792e5e7aed5',
 '2b52e0981c37bf7364d4',
 '2b545ac1c2a60a873f9d',
 '2b567b0bb031c6c81385',
 '2b56b213d898c5bbfb11',
 '2b56eb3f5fee6785bb38',
 '2b574c7039b3adb2441d',
 '2b68bc59d683b2be6aad',
 '2b735217022187fdd089',
 '2b73f9f28d73472f38dc',
 '2b78598de50f448dd21b',
 '2b78ce4a29fc3a7b9668',
 '2b798f158e2fa71af0c0',
 '2b7cc88c2d53f2400cb3',
 '2b7ceb0e9945319e1e7f',
 '2b803e5df38fdaf43be6',
 '2b806d6aba1a69a52c70',
 '2b8196b64632ea0d55bb',
 '2b8328eb9fa2546c6704',
 '2b8b8be91a580cbf73cf',
 '2b8ba290c6ace375a8ce',
 '2b8c69ce105271e980b1',
 '2b8ef004477824f89dc4',
 '2b8f17332f43e814b7c2',
 '2b925388e72f024f7848',
 '2b974ae2c5528e73868a',
 '2b976d78cb9a229109e2',
 '2b98648715a404b68419',
 '2ba1da8c3eb951af259d',
 '2ba34140b949a1dd6121',
 '2bab14eaa49ba122720c',
 '2bae3694ab7098d57272',
 '2bb0c1c5713184fc565f',
 '2bb3e0bdd1081232b7ed',
 '2bb7788f09da06ff535d',
 '2bba6542e4a03310a64e',
 '2bbb2dd0f2ecf60ff330',
 '2bbe36e0917acd6bb2e2',
 '2bc06df3e737b2690384',
 '2bc28dc60d9408be06fb',
 '2bc56082b6fa687783e4',
 '2bc7ae3ac276c0ca755c',
 '2bc8441529b1e2de82b8',
 '2bca672be85956da9247',
 '2bcad62829d0a3cb0531',
 '2bcc3e99e6646666ad27',
 '2bcd84c4e15aabe00d97',
 '2bcd90860175785d7340',
 '2bd0b17eaca8fab3d637',
 '2bd93bbc41f5205c6e4a',
 '2bdb3e93a0ccda8aab8a',
 '2bdd89a7d35a1135dcf5',
 '2bdfe0e27d31826d6b64',
 '2be150d5e818d0e3a6ac',
 '2be335baaabb40058cca',
 '2bea0752b7ab4af203c8',
 '2bebd72d78b82bf98c64',
 '2bf4893364d8c79fb1e3',
 '2bf6fa60c38c34c349e5',
 '2bfac166f57c977f538e',
 '2bfe52c9c1ee3ee60016',
 '2c03bf04f2f3cf657dbd',
 '2c0884f50b3b2e0e5c48',
 '2c093fba402d15834fa7',
 '2c0a610adb1d80500480',
 '2c0da67ff0809e9fd57e',
 '2c114b1cbe6010cfd8ff',
 '2c11de97d7a16124a348',
 '2c12ed460ee4605d992b',
 '2c1623d4d874e7b2062c',
 '2c1a34808fe03417f334',
 '2c1a537eef9dfd8b3bfe',
 '2c1c6fd08367a46ed629',
 '2c1d6bf51edd7c5f9415',
 '2c1dd5eee875cc1ccfe1',
 '2c202f15ae64a851c3f9',
 '2c25d3f9ea38f811e5a0',
 '2c2be6d02e229d061508',
 '2c38e1c71677bcaf2937',
 '2c3952a91399949f51f3',
 '2c396a7eb8b243274ae1',
 '2c3a5b18a562100dd53d',
 '2c3b90c33c88da75d050',
 '2c3c7817163711d600fc',
 '2c3d8f1d98c2b0bf1eca',
 '2c4042db245af9870c9f',
 '2c45ef6d448461e8e9ae',
 '2c4b4fb097ae7cc3e4ed',
 '2c544e8e8c4dd74edcd5',
 '2c55bc5d75bbe1470e88',
 '2c55e3e4f3d719c76bf9',
 '2c56ef97af106a0ef0a9',
 '2c572e5f7b03af2260f0',
 '2c592f3c986aea16da82',
 '2c5b168737dd03a1d85c',
 '2c6577bfdb4648df93be',
 '2c698283ff74980006f8',
 '2c6bfd7e5aa60f601928',
 '2c7bfef3978e9f48f900',
 '2c7c2af67c30161bfb6e',
 '2c80b341a94a824a2a3d',
 '2c812f1a8fe9effb617c',
 '2c82aa01c7ba2247e20e',
 '2c8428198bf7e6b81542',
 '2c8eb737d2c5699a71a3',
 '2c911b778ab11f2a7621',
 '2c92f90a4fbbf0875e18',
 '2c949974f1c3788ae00a',
 '2c9aa21e54a214e582b6',
 '2c9ae64c2963101123b3',
 '2c9edb641855a2271db3',
 '2ca1c04d388e9d59b856',
 '2ca21516e26036562333',
 '2ca556bfe251479833cd',
 '2ca5f3d02721c5fcf418',
 '2ca8c408d5d3f54cefcc',
 '2cab4595f3321fd33657',
 '2cada19b93cba3058873',
 '2cae3040badffa0e499b',
 '2cafa6f1933d0a7ff19d',
 '2cb04612039be4b8fe77',
 '2cb0b2e692e0f3442548',
 '2cb12bcc38ae8a94d2d9',
 '2cb3800d4e0c8a5f9b08',
 '2cb476ca922b3a5272bc',
 '2cb4e9459f4365924fb2',
 '2cb788efb6bcb1ff32e9',
 '2cb804972ef0006708ae',
 '2cbb954999dc88d8bbd7',
 '2cbc0c45d9ddb05bdce8',
 '2cbf1575deb422df310f',
 '2cc6e90d81f899eeca67',
 '2cc780eeae0920082a0e',
 '2cca7928e95b66249410',
 '2ccaf5f5afade53292d5',
 '2cd3b718869c4a20cdfc',
 '2cda6a39b1ef38da2faa',
 '2cdada6ca4dae885feeb',
 '2ce3267b3bcf94699594',
 '2ce4f98bc69bfa4e6312',
 '2ce5cd98998a0f94ff9e',
 '2ceaa55d8564b374d675',
 '2ced837ed4364735fd56',
 '2cf047ee5dcae9f770e1',
 '2cf17efe3a5be3e28c03',
 '2cf4f6b270d869f736fa',
 '2cf52829a6bd9ac02430',
 '2cf8ac67546e7c9ade00',
 '2cfaaac609bf5db74e08',
 '2cfd4f508add4bd4b884',
 '2d01546eb7b713224bea',
 '2d06558df926b1f44acb',
 '2d07cb0deb2b6a9ab23c',
 '2d09e80cc77e27c1bf77',
 '2d12647e22f6ad0e254d',
 '2d13daef2a7ad7b331c1',
 '2d1494f96d9af33d2602',
 '2d1d3b2af28a69c8b4ae',
 '2d22447adc50ef852e32',
 '2d2a7141256197b8e9dc',
 '2d2b1119fdcb08f68ea2',
 '2d330276dcb59a8aec97',
 '2d36fb094a0dfe9a2c72',
 '2d37c036e1e9bef60589',
 '2d398002236b9290182d',
 '2d3d8ebfaf92af0446fe',
 '2d413357d6317afb4835',
 '2d415fe4a296948bbd38',
 '2d42341fc51ecaa49c8a',
 '2d44bed34433694b70ea',
 '2d4646bfe2b11f791997',
 '2d4906385c4647820e86',
 '2d49ef86b90bf2b499c1',
 '2d4cf80dccaae11949bc',
 '2d523cb3aa7c16666dea',
 '2d59649f39611477dd3d',
 '2d5ba511b0d881dc1c66',
 '2d5e3d28fbdddf968f27',
 '2d60b6dcfee6eb8cdbdf',
 '2d60fdd0e979d4f8a9fc',
 '2d644259be1dbc27eb43',
 '2d654ef3d453f1e2019a',
 '2d656971b0fa30a0a3f4',
 '2d69f215ad046cfe78eb',
 '2d6a3c2b5d3b337ae1d3',
 '2d6df01299786ee866ae',
 '2d6fd3d00830d2a90986',
 '2d7370b07416d72d67a0',
 '2d741d955354317b5c12',
 '2d770afcd6246f908ce0',
 '2d77b5b9cab986079129',
 '2d791feeb8b808755153',
 '2d792395c18f19410893',
 '2d799ca44a67d085955a',
 '2d7b2ae02ff627fb935b',
 '2d7eb28c3c5890957181',
 '2d85025a4ec6f10d1529',
 '2d85126d1d3bd563b257',
 '2d86335ddcf97868bef5',
 '2d86675ad97b9f64f58c',
 '2d868d32c97d2691457a',
 '2d8a88ef14fd294cdf07',
 '2d8c0250a52df9e89d60',
 '2d8ccd83f47b12be7de0',
 '2d8cec9203dfc78bc649',
 '2d8fb93350e5db5454e0',
 '2d93331a01bd3fc8b27f',
 '2d93cd14bd31789eea51',
 '2d95670d59908dad4bf7',
 '2d95fb3039584ab9705f',
 '2d9b241f6ea7c7299ff1',
 '2d9d30a7c288af6819ac',
 '2d9daa355c1e55b49cf7',
 '2da1676e0f63da4e7f54',
 '2da39699c3a43b4f2e55',
 '2da47a364abe028a69b9',
 '2da6f387613b6ee63b05',
 '2da734648b4cad1d65f9',
 '2da756a80264cd02562c',
 '2da87866dd3bd1b7d2fa',
 '2dadf7fdfc6061b0a96f',
 '2db494adeaf3ee745d4f',
 '2db5aaf665b2d662f9d9',
 '2db6f5e1b3c44d6978b2',
 '2dbdb687893cef529043',
 '2dc3e2645571d11b959e',
 '2dc74ad0a28bc94dbe5c',
 '2dc7d17857e9bffc13db',
 '2dc9a2519f1b9401523d',
 '2dcb37dd4663e9559c0d',
 '2dcbb52a701d62f4dbae',
 '2dce86803df51d1a7beb',
 '2dd015741c376d5a534d',
 '2dd141f06d0f83151ee2',
 '2dd1a8792cbcb73c0d91',
 '2dd73ccefa26836fc654',
 '2dd85e6216683ffee146',
 '2dd8f6cb4ebdf551ecdc',
 '2ddefd36107727e94d28',
 '2de05d4208f1f63f53dc',
 '2de1ad302c7dd207e1b7',
 '2de4b725af948b61146f',
 '2de84800369e403aa183',
 '2de9d501340e03236333',
 '2dec11948b4a5b387bd4',
 '2dedb73e469dfa4dc8c6',
 '2deeb0ead4bfdc2bcfce',
 '2df0dd8d4a7a66f60e57',
 '2df25f8ec9bfc536891a',
 '2df57a201e7b1ef49bcf',
 '2df71426c7a78aa35d86',
 '2df72af4359b84de38ee',
 '2df83c8c13db58201c51',
 '2dfa3d3cdfd16010bb56',
 '2dfb8194d4f0c481bc9d',
 '2dfdbc9263ed69bed78a',
 '2dfec389c92c8547875d',
 '2dff6b35ef2f6c064af0',
 '2dffd063bfee3f36268b',
 '2e01769fb3d69d58abea',
 '2e064fc01f3523ec0680',
 '2e07dc5922beea2c63b6',
 '2e084a227a1a39cf378c',
 '2e0cb99219b860ffd7a9',
 '2e10c9d1972958e1630e',
 '2e11a8a51daaafdd0c5b',
 '2e161af3aa3590c81945',
 '2e1806f68f3079e98552',
 '2e1883d4a4cf9e1148ea',
 '2e19b04a481b6a7b41b3',
 '2e1e45a463a15725048e',
 '2e223d945ce001e6bf58',
 '2e239dd74ff6f5ecea95',
 '2e25683e9bab1fa6a69c',
 '2e260ae70c207e69c79e',
 '2e2660596a76605e2e67',
 '2e27e78ec710141d3d38',
 '2e2ee9d4a195ac7bfb0f',
 '2e32bc3f782f57a154b2',
 '2e34c5798e59a28ba518',
 '2e3586f3e445f470ffec',
 '2e391f1116f4e865d4e7',
 '2e3c3081002104944788',
 '2e3cffd22446461e431d',
 '2e3d89407664c4d2d229',
 '2e3ffcf99ca870b34b2b',
 '2e43fdf41f13084cd74e',
 '2e47fab6ff013e737c32',
 '2e496fb515bbf3e3e967',
 '2e4e40f6a74633295ac9',
 '2e4e6b97c839862e6342',
 '2e4f77963c1a02cd7bb0',
 '2e524f5e598bb53a58fc',
 '2e531269734ca544a9a0',
 '2e565d3387d9f27b4b8e',
 '2e57c5547f81356b0d04',
 '2e5daf20742b73ccba2b',
 '2e5f6ee844c2ec1fc9ee',
 '2e61a100630b535f2e07',
 '2e676a8b2225de486846',
 '2e693ea790eec3153cfa',
 '2e6cacf0776c0a9c08db',
 '2e7071c9f285e1376922',
 '2e71c861b22e09a5b569',
 '2e76135c9c2959fd1488',
 '2e767489b7bd0d10e74e',
 '2e76f3ed4df67fc71d4b',
 '2e77c523500c32d3cb3d',
 '2e83019bf716cc661fb5',
 '2e87f221e8090286adb8',
 '2e895e7d67881bac83df',
 '2e898d3983abd709c56e',
 '2e8ca41656da944473a0',
 '2e8cbc6d32c45c139df1',
 '2e91fdb1efe3d45d0484',
 '2e993812b8e8196f76ec',
 '2e9b146b4c75228092a4',
 '2ea180affb2549744933',
 '2ea3b8b0aa7918e4ff46',
 '2ea643a561bc6eb9d102',
 '2ea9db8e64f551912786',
 '2eaafa8ba7593c097950',
 '2eacf13a810907525724',
 '2eb5e1ecb54a3fd40443',
 '2eb7eab6dc669f6605a8',
 '2eb8a676da1b7384a325',
 '2eb8ff93b3272c47f07c',
 '2ebc3a11164283087f2e',
 '2ebcac60fa07c2475d97',
 '2ec1bc2e0625b5adbf9e',
 '2ec69c973bff6b27e6d4',
 '2ec9f040509566a3aea8',
 '2ecf6cacaa4e414aa257',
 '2ed21564e9c96311a529',
 '2ed43d74cefcc6b33146',
 '2ed6ccf6e783c596fc9a',
 '2ed9e64f8d43d046081a',
 '2ee043f6060dc3dec76c',
 '2ee4534db87ac630a501',
 '2ee93a28f61bb1d50b7e',
 '2eeba0612d1db3f1dde8',
 '2ef0e0079baef25b6469',
 '2ef0ec0ee061a4f1605b',
 '2ef498fd4649ce818cc8',
 '2ef58ea1df20be1e6fe7',
 '2efab5416efa9cc12b38',
 '2f0217dcffa099255ed5',
 '2f0222d05f3a51a31231',
 '2f0562dfa9a45793cf31',
 '2f08a028b085cbfddc40',
 '2f0ba0782d97328ebb92',
 '2f0c5210b2b24f8c7b66',
 '2f0e104542965980a6de',
 '2f0e55f674e2b86237d1',
 '2f16aba87dc4480da097',
 '2f1c4cbb475a0671fb94',
 '2f1e209ff0d7ce3670ff',
 '2f2974c996aee4db01d9',
 '2f2ad717bd3b5d263b63',
 '2f3541d132086ac130b5',
 '2f38129f981e548514d7',
 '2f3823536cee03eeae66',
 '2f42c958844f9ffd9e7e',
 '2f446957dca8f0a9150f',
 '2f470cf79e16ff491636',
 '2f47aff9f5404bc01b5e',
 '2f4d8044461e1b43f8b8',
 '2f547b4e7ae45829cb08',
 '2f575a4ef2fad7063dfa',
 '2f5af887c65f86c26d08',
 '2f5c540dc0abe67bcdbd',
 '2f5ddb55a9b9f4bf7305',
 '2f5e05cdb3036a0cdb99',
 '2f684c8d802f81a3ee4d',
 '2f68bf6b1c4a45e59019',
 '2f690af81d5d0928f8f9',
 '2f6b85341f94112db5d6',
 '2f6cde7ff80ba471baf2',
 '2f72e2bc6a35da9546d8',
 '2f7d2831fa8e82502d0e',
 '2f7e2d99a0cd592e5a58',
 '2f7edc4dc402963bbabf',
 '2f80d4fd86e37227b733',
 '2f834b1bac7fbf0b3a10',
 '2f86fa09f1c046949db5',
 '2f8b534e70fd8e7e9b7c',
 '2f8e99e7e2bc3dc3c410',
 '2f91537b3c5647df0879',
 '2f9286672a6ca9668b4a',
 '2f936d4e909344d7b629',
 '2f9641492cc69b25666a',
 '2f9b023469bb8f315c45',
 '2fa087ec0eb205fce3fc',
 '2fa7135df52d9761d90d',
 '2facbd64119cfab84e32',
 '2faef013b74f2e32357b',
 '2fb0b590c6fa01c7ad29',
 '2fb6ac4bc8a80fed7dac',
 '2fc34691329e07664d13',
 '2fc4f552f2a205f3dc5e',
 '2fc83779c95ccf91d6cd',
 '2fc89d8426646387b2ba',
 '2fcc1df5f1ad25dfbc11',
 '2fd49193a2ea6b8561c6',
 '2fdf05aab1a5097bfe9e',
 '2fe02a852c34451c1d42',
 '2fe1426d6af2a7a12bac',
 '2fe2d2a9842817b388a1',
 '2fe3515d1812816847d2',
 '2fe5bde22ad6b1633e34',
 '2feb80075b034742c8c3',
 '2fee0837464ce6c144c9',
 '2fee173e5ce872ab9d61',
 '2ff2c75fb14aec25bbf1',
 '2ffa2cc70deb65b10b90',
 '2ffa8edfff3e4f69ea97',
 '2ffb7d7e574541d97a61',
 '3000e5e85fe988462a50',
 '3001f56f65ad31d6f0ee',
 '3006790d44dd157368bd',
 '300a3aea12e7608c3bc0',
 '300ac1bb68c3dfe16865',
 '3010ad98a5e1eb8792d7',
 '3015fc0d05df6425bde4',
 '301e483affcdd921cef9',
 '3022d3fdccc4776de294',
 '302b21496a5c4045727f',
 '302c9d5fb1e57987f316',
 '302d1c63f8702e97cec8',
 '302ea158bd9267e97813',
 '3030502d6668da1b5eca',
 '3032fefb41f571e01580',
 '303468042aeb9d110288',
 '3037282bdf8fa83c5563',
 '3038f419e374fa7d1fc2',
 '303a8dcc89a832042fab',
 '303caba7ef8ab48dc8f0',
 '3040ef49dad1dc443444',
 '3046ee21de1393f37cdf',
 '304b1937aad32c21488e',
 '305639fc849d7279942e',
 '3057a67d008ac099e974',
 '305849f8fe777e6accef',
 '30590f33078166f12ff2',
 '305933843b98ebf2b9e7',
 '305ed76e62c5db1e2f13',
 '306061b3a3da740852fe',
 '3060a54f152976027d2a',
 '3060ace125211275b3ff',
 '30637bac79e4cba1788e',
 '30646964385d10c84673',
 '3064af4a7e536781f97e',
 '306ec181f407fd064fed',
 '307065b1dba296e578cf',
 '30708df4a01c97a45eb6',
 '3071282495b4d2e5c741',
 '3072cd7be1a5c4704158',
 '307b2c7b0c9b53e97ee6',
 '307c3ad1f64959500abf',
 '3080b84882d32d99cb42',
 '3084831ae711c332dd09',
 '3087c94df44786acad22',
 '3087d73885dd58f8a205',
 '308a9fc0afbafdca1a4f',
 '308ad473599060d6a27d',
 '308f95617f4b790dbcf5',
 '3094257fe2349ee39078',
 '30976e94154378acfca9',
 '3098be8b3a811043fdc4',
 '30992692473f9b467619',
 '3099df1f3f6b2fb521cd',
 '309f2f72a94ec440de46',
 '30a1f60766df202c3cc4',
 '30a3cab667400bc5c422',
 '30a83b96be3e3c9998cf',
 '30a93a4d8f4621dceb1a',
 '30a95189ecaaabbd40ed',
 '30abae8d538ceb02962c',
 '30afd1b10c489d736974',
 '30c16ca1419dafc34cae',
 '30c4d418c0ce7f0e2c03',
 '30c653b5124202b0625e',
 '30c74e8cc6c457d36601',
 '30ce1ee1c2cb1edd7eba',
 '30cf2b00b38ac9965364',
 '30d242f7238d16c91066',
 '30d2e995f5bf29b6dd1e',
 '30d4466553ad898f915c',
 '30d461846a40b32007ed',
 '30d8215223030b51ccbd',
 '30da7b8f4b7f2da06d6b',
 '30db7193b72114d35869',
 '30de0dc010a24ee9ad62',
 '30def8a11c0aee75f8cd',
 '30e62b1f0a1a97f22552',
 '30e80f2679cecbcaed5b',
 '30ec462cc99eab79f6b6',
 '30ed4ba9226f059ded83',
 '30f717ae51549c6cf82e',
 '30f82666a1a2071e9ffa',
 '30f974bec041a7795665',
 '30ff2732c2f720ea0cdd',
 '30ffbe9d96cc658bb035',
 '31024db41cac68cc137b',
 '3103c3d2f640565fcfd0',
 '310746335b2ce576f589',
 '31085a03923060107583',
 '310c96f14cd3d0d7c2aa',
 '310eb6bcd9ee014221bb',
 '3112121fe3bc861a6d14',
 '3114321a28b5c4c37cc2',
 '31185fb5b0fcad539ef4',
 '31188ed0600c81eff527',
 '3119c81a3e9e1cab76f2',
 '311aae6f0b6a36d989a4',
 '311db8868beeea5d712a',
 '31236aced8dac7fb33a5',
 '3129b40ab5282639a63c',
 '312bebaaa85397202b22',
 '31307c3aebd409d36f50',
 '3131a2107fd296080d90',
 '3134c2c9e9e5df430ca8',
 '3135e967ae7f6c7fb9ea',
 '31369be668130c96dabd',
 '3139e1b6e8cd7da494e6',
 '313e4a6c68867558616c',
 '313e6149e7fd9173e524',
 '314085de7cd2aa1db9f6',
 '31437b1e9f49986c15f9',
 '31499a14fce209f16b4a',
 '3149ccade444c0a59c8a',
 '314fc12a964f49ad2b86',
 '315218f11de2f04746db',
 '3152f120b06225e095d0',
 '3154038617451f0edaf1',
 '3154c76f91bfc1226f18',
 '3156d0ee3f12f7a68c45',
 '315b2793f6b7593ceb1b',
 '315c9753f165a6b093e1',
 '315e2aff2b06e1c5b7c9',
 '31641d6cca8cf7066559',
 '3164debef3993253d177',
 '31656c29a31d8765c2cb',
 '31671ffc5d6956a46291',
 '3168282c658b2555446b',
 '316ca06aca98b79525ce',
 '316dd483a734c4679962',
 '316efc28d331b96444d3',
 '31714fbf6191d33d6d67',
 '31718e3a998ca5bd4040',
 '31773c5a0d74962aa3bf',
 '317ce1595c0d2be8fb11',
 '317ed4463c95bfabb507',
 '317f0b1498bd8f0a4681',
 '317f7c318d4ea46a8a40',
 '318135b2bc5ef6a52f70',
 '31832c31c1b248d3c108',
 '319296671707c2654b3e',
 '31945acfd45c0c601775',
 '3197e537f1e389500b37',
 '3198e0b3ee14119af312',
 '319973a65234534e5ef6',
 '319c7d6a48fb4cb3cfa2',
 '31a008a520e168e699ff',
 '31a3af7be3bdf24cbbe7',
 '31aa7073be9604e7a1b4',
 '31ab5d1f4d455a16f23e',
 '31af8243d847428859b6',
 '31b0dd03f7f107e59208',
 '31b1e4aa7ccc86f9e608',
 '31b2a8927c03173ed2e3',
 '31b72d04d6c20bd0b80f',
 '31b89a778e48f5d5fc98',
 '31b8decf90f97cf0931a',
 '31b8f75fdb9ed6c379a4',
 '31bbee67045fa80e5474',
 '31c423b9f34790a4efeb',
 '31d0db84c0509d7695f6',
 '31d4cb6ae13825a757d2',
 '31d85eb25591ebeba141',
 '31dbad7cb6d8227c8244',
 '31dc50ac18c94db25a52',
 '31dc83fa75f0d82b1683',
 '31dfcfdddfc2dc72b398',
 '31dfff324cdb9010f0e4',
 '31e017e8fa10297018a6',
 '31e3b23cfbc15089e025',
 '31e50ace290da1835103',
 '31eab2d01a8e320f26ef',
 '31eb4a5f9e7e1d68189c',
 '31ecf95fb2d0398e82f2',
 '31ee5afa6be2061a374e',
 '31f1c2ef9b6187a66c39',
 '31f1ddc09375ac58b43e',
 '31f43560a37740544cd5',
 '31fa15dba64adedd0a97',
 '31fa2294bec65ca8f196',
 '31fa73c812a69347b497',
 '31fc6a47b01850092ae1',
 '320319e1595f702c111f',
 '3203b810c51eaef0ea24',
 '3205aae0b09784d64555',
 '3206586684ef1d4762e3',
 '32078c0735bc85a66716',
 '320b7fd1df10669ae4fb',
 '320cf917693f1ec41392',
 '3213760b67e51f4610f3',
 '32148b682d775ae37498',
 '3214c37b1a0467cd9103',
 '3224d3ad816995d9cf74',
 '322a397a9e92177ca024',
 '322a3e5a64f69373bde0',
 '322b5d537b6f345af04c',
 '322c3ec6c564ca9a9422',
 '322cf9788b814de4deb0',
 '323110e246c0a3767d00',
 '3239028273de87bd4b8b',
 '323a302cab3cb7d64e0d',
 '323e9c3ad2936bb09d89',
 '323ea3f23e64c111e8ff',
 '323f78eff4df93e926b1',
 '3244d9988739652759ac',
 '3249b97765655cfe1df8',
 '324ae5b0b070c5c3af91',
 '325ab905785cd6aa9582',
 '325cf3da3cf39b5fda94',
 '325e44019e80bfd12d53',
 '325f341242f5f00160fa',
 '325f4b5baf5e10b51104',
 '3260d57fbebac9286604',
 '3260efe39f51e68e4e42',
 '3264f6d4819dab33b6aa',
 '3267d5dcae1b42b48e94',
 '326b73d851c44ee1c86b',
 '326c8c03eea37fb42dca',
 '326e3e6eeb4839efd21a',
 '327044caa24ed6c34902',
 '3270a29f4001371bb00d',
 '327196c222bad6f5fe56',
 '327326de2ddb00e1cbba',
 '327344d632715ca16f03',
 '327434d72f7424b43b2e',
 '32765ac25991526b91a3',
 '327a56eedd2c3cc043d0',
 '327f62be864ce22bea0b',
 '327f65aa82ed38c11e67',
 '327fa05309b3817413df',
 '32808449fbcd853b63ba',
 '328140cf863dd99f5d08',
 '32826d202195ef8e9a04',
 '32882f7b8728bb8bffd9',
 '328868306567b98c6a35',
 '328b1c1ef923586dcbc4',
 '328d7db36ef7d5f4ed9c',
 '329223b3ddc804388473',
 '3292ae024f3382be7970',
 '329467ae4819ad866eb6',
 '3294b2f3288bf5d0413a',
 '3294bfdc8ed1500c37be',
 '3295a5c846120ebac089',
 '3299f8b54b018a0f1e60',
 '329ad65262f0958e49db',
 '32a0398179061e4dc984',
 '32a6897bd0a50566b8bc',
 '32a8597dae395c62cef4',
 '32ab0d1a26cb3f02ad72',
 '32ac5f1a1e865142dde0',
 '32ad5c502efe57e7c3c2',
 '32ae39ecf31930217d55',
 '32b1960d76763a1e168d',
 '32b1f701def59683b601',
 '32b4a8172525824524b2',
 '32b4c82472d9366cc3b1',
 '32b6409332c8fb3fe0e1',
 '32b6a0c6daf2b2e4eb67',
 '32b702c0bcd87930a503',
 '32bac11f07cb0fcee7ad',
 '32c3e79432a6f769a465',
 '32c940c0274bba40a684',
 '32cb672ecf19fafe2fb1',
 '32cc9a0264df3a5754af',
 '32ce8c514f83930eca1a',
 '32d4c6a5a3b88183cc66',
 '32d791c863801426d3fc',
 '32d988d7ad8456e57e53',
 '32dd30903474a78cab91',
 '32df6269cf64eb08ab95',
 '32e003c758ad3b245641',
 '32e079b45e912da6f1cb',
 '32e08717166b23007389',
 '32e1fb1efc8d349356a3',
 '32e323376449f931f8e7',
 '32e4230e9ce8d7dd4462',
 '32e5a73fa5af133ba0f5',
 '32e611e4007f2ed4ebab',
 '32e8ed950385d20310c4',
 '32ea10164ab8685ae4c8',
 '32ec4b4e22bc49bf5bc5',
 '32ef710bcf7b22a1b9c2',
 '32efed951f5fcd23e3b0',
 '32f157b8f6b56ad3b969',
 '32f2e075dc1127880bf3',
 '32f63806535faba9f7c9',
 '32fb417082d7fff19b64',
 '32fcbf1ca74887be92a7',
 '32ff3f58120da97e4659',
 '33011d9d29c63684764d',
 '33016155c6142ddffd7a',
 '3302d61dec4b674befed',
 '330347bbffe47c30e545',
 '33035396f8597afa9f63',
 '33055f43212ad6eb7b24',
 '3305851b011611a30b49',
 '3306a3b4c8ad8900b597',
 '3307efca1eb308e6fe6e',
 '330b31fb23a370d6aea4',
 '330b4bf7793024847089',
 '3314ee4ddcde83c5e0b9',
 '33181aa1b746121faab1',
 '331b1a3e05a3c721e2bf',
 '331d9e0ce0857e7517b4',
 '3324bc578b9af300d6d1',
 '3329562649548abeae86',
 '3330e162970cb6eda2a6',
 '333128135cc86fe274a0',
 '3331c13dbda232c25723',
 '3332ac36413f111243ae',
 '333360911502732ee43a',
 '33393a14adec4da75316',
 '333a7fdd76917214346f',
 '33402689fa1923880824',
 '33432e760489315d618f',
 '3343bc3ccf9479169be7',
 '3344072f0539f717ed7d',
 '334532ffe56b2f718585',
 '33487d5184f50bc8a614',
 '334ac619423542e57070',
 '334c530915de1f5f27b1',
 '334e6fddfa1d7580197d',
 '33535743eebc72313db8',
 '33543a2d75f10528555a',
 '3357209cd1475d8229a8',
 '335845f1fa674765397b',
 '3359cdceeced6b4e6d2f',
 '335ccb5b959b18581209',
 '335ee4adb4e17f2c53f6',
 '335f97acbe6cb1c0fdc8',
 '33655a4d7c4d88f5fc6a',
 '3365965fb4e4e2d6a648',
 '336787e34a258d87ee61',
 '3368707afaeb5829f655',
 '336872f911f04f5609bb',
 '336df06f09f4906990b1',
 '3371e0d1fa1c9883d611',
 '3372b24b4d0f2fc45ac2',
 '3373ce2bace102dbbb01',
 '33746d0d0f5ba713b1c6',
 '3375f12fac2faf9db18c',
 '337b5ebdac46c49d5b47',
 '337fd70fd47881219f1b',
 '3380f1a5f95b9884e9fa',
 '33810d0b1a436d8b77b6',
 '33815065e165902e5c41',
 '3382e706f1a140342b84',
 '338481d5d9922dacb784',
 '338872eae439fff09c98',
 '338df09576305e7dfaa2',
 '339480950abb022c6cbc',
 '3394d20ce31aa666cc15',
 '33959b095f73da20e391',
 '3396141128774f59a024',
 '33975471405594392090',
 '3399b0473aeb0ca5b104',
 '339b0aff2c6ce30e2639',
 '339b876491af89ea884b',
 '339bde2cc17506f322c6',
 '339d503a1408d5a01d34',
 '339f2d1cc349caedf2c5',
 '33a17e0bcc6f48f667c5',
 '33a203d81c627399be57',
 '33a2d1c5e690446bac01',
 '33a49d83ab8bec92a04a',
 '33a97f6ee46cb98b10a4',
 '33a9fe4ee5a821efee35',
 '33ac7a69561703095c86',
 '33acf66cd86b6e629a8c',
 '33ae4cfc552701710e48',
 '33b5e97c9ed93f0d63dd',
 '33b648d6421c59a0e01b',
 '33b71fb6e3d3438b299b',
 '33b794a3ac7d205f7dac',
 '33bbeb349674709fb2fd',
 '33bd214e60630d769cd6',
 '33bf875df8a56143255e',
 '33c09698e1bfec0d8cf2',
 '33c2b64bddbdb318099d',
 '33c484f11938840c3652',
 '33d1e59df24bc717010e',
 '33d3fa8f29200413bb68',
 '33d79802c92a819675d2',
 '33db51a8b1cc60eedb59',
 '33dc1bf2e1a0f0bd0e6f',
 '33de02eb596467762e18',
 '33df0d22ebbe377c5483',
 '33e481059d88aeb74bd1',
 '33e68ffbd07ffa3418fd',
 '33e82dd977e778f2b2ab',
 '33e8f8cb9cd6a5056e32',
 '33ea1efa59346e1978c3',
 '33eaee8a8cd31de1e841',
 '33eb17d896d67b391530',
 '33f2df5c5c3d6bcfd741',
 '33f426760b68a293f70c',
 '33f5a002ddf8c001a5aa',
 '33f805d6c7dffd254807',
 '33fc04031f1f59174bc6',
 '33fc2e7fe0004bd7bc95',
 '33fefc1fe87953bfaf30',
 '3402c5ca671d524f298c',
 '340730e0b5436f0f2192',
 '3407a31c98820f0ec8da',
 '34083848e014f1715d74',
 '3409ab8f7438ee13ff77',
 '340a4bcdb5b43c25b6ee',
 '340ae6699456d1e63c72',
 '340d6076ff48c4a025d3',
 '340d86e1b5912ea9a454',
 '340f4aa17db68289c86d',
 '3410fe287bcd0bd08207',
 '341aaa5e57f371880bf6',
 '341c4809df20a62e6d39',
 '341e357d7bc0248f3d81',
 '342336f6939efc6ba8b0',
 '3423fc3499572806ee9a',
 '342ce5f0092fd7cb8eff',
 '342fbb37cde543b04ae7',
 '34343c853edf7d5db4d9',
 '34383c96a029d4a87afc',
 '3438d85d283dbd933870',
 '343be5111f5908d35337',
 '3440c5fa651af24a8073',
 '344be9aef37712b6c6e7',
 '344df261dda7ea64a686',
 '34584380dd95fe3503ce',
 '3459ff073a29705d9610',
 '345a9d0f4e334dcfe71f',
 '345cdeb4396e84feaf25',
 '346159fc7616aba1485f',
 '3461c24e45c14104ad86',
 '34638b8de13c249e95f9',
 '346490dcd02c158fc737',
 '346aa88bdd6bdb03fe16',
 '346ba9e9e4b1e37f972e',
 '346eb6ffb952c2418065',
 '346fda71454229be6da0',
 '3472f8be16497fbdeb79',
 '3473f05bdab2781fe4c3',
 '347e0769d0009705cdc4',
 '347e1f361bbc4e2b38bc',
 '347e3610b8b97cba5f76',
 '3480329e80764fda56c0',
 '3483bda4995c816e1df7',
 '34854aa3b4c95b74964d',
 '348be4e00b8ea9d9881e',
 '348c729d3664d61cdff3',
 '348cc5ccbfd3ee4e9fcb',
 '348d9a19c164f3ec03e0',
 '348e76832b5e04449242',
 '348f0b8733cbec4dd44c',
 '349087cc153b9abf9541',
 '3497d7f8b7e084f27092',
 '349b7b190abe05d44bdc',
 '349d51dd6a363f7af67b',
 '349f18f01063c40dea7d',
 '349f51261aacdec57f00',
 '34a23e4e687cfe451bd1',
 '34a26aa60b21b128dd80',
 '34a33de096bf1a0094bc',
 '34a4733f9e82875f190f',
 '34a7c9d32d1e1a0a526e',
 '34a8c10d134de69b8ac2',
 '34a94fa0ed3efdeeb196',
 '34ac818b509be82c7c29',
 '34b10f43f88a0ba5a4c5',
 '34b5da18d77178767d98',
 '34b864a2308fa0bffe99',
 '34c13f76aab22c97032f',
 '34c3cab8011617f342c5',
 '34c8b7768b8b213ade4e',
 '34ca0b6e2a2cff2d740e',
 '34ca12ef67d467753de9',
 '34cd06c000bbf99edee7',
 '34cd671a4ddb49227b67',
 '34ce6bd3362267b9f1e6',
 '34d4e364ff48d36e30a9',
 '34d5957189bb770778fe',
 '34d889ba9f06ac69e84d',
 '34d8a89667959451da82',
 '34d97127bdbd755c4d4b',
 '34dc86a4ae764023b2fe',
 '34e1b03f31f1d8a0a239',
 '34e269d6de8fa49dcd40',
 '34ef113d74c78654bf3c',
 '34f3e5bfc7d35220de5a',
 '34f6c049074e8056d413',
 '34fc36e8fe9f8c73b34b',
 '34fcc637d9a2d0e37a86',
 '34fd3760167378f29b46',
 '34ff9ddb5e5cd8f4f82a',
 '3505bb08938780da76bb',
 '350c8bcc052ff5c865cf',
 '350cbce840c8cb84f81c',
 '350ecddd5fc533dc6420',
 '350f9c3aebadcb8c1561',
 '35116d4ac7ed90740055',
 '35180b992ea234edcc0f',
 '35189890824c576bb804',
 '351ad27c0ec3974a71f8',
 '351af89174d2fb4faaac',
 '351ccda498a7c790dfee',
 '351dd54d97089d4cc1f8',
 '351fc85acd81c6911e79',
 '3521427042f6668ab5ae',
 '352325bc7e9115e706f3',
 '35256f5699855421828c',
 '35271602286ab721d524',
 '35299e8567e0a071d001',
 '352c1bcd98bed02fc9c1',
 '352ef4830f0ab00a9b4d',
 '3531dc76cd7c064e5fb5',
 '35395e040eb0d3ff1ec9',
 '353ba85494a9acc3a1ce',
 '353e7b871adfcda09198',
 '35415637a4457da20d32',
 '3543ab66a866853d0a8c',
 '354a58710791ec1ed648']

# %%
qids_6 = ['354e5064bb6911377195',
 '3550d55150cf75ece5ae',
 '3551af4743bec07bd729',
 '35533601b179ba06cdcf',
 '3554023922514dfcced6',
 '35583c5ed7bd5db9f338',
 '3558f98365630df16b2d',
 '355e715e8e1bbb5a3934',
 '355fc5c5be81b8dece62',
 '35621d1d6aabc9174587',
 '35623f22052c90937671',
 '356490ab3757012c0ac9',
 '356c033c81195dc6c3cd',
 '356dedb42041f823ad1d',
 '356df7de76f2bebbd663',
 '356f68e419bffaa34f4b',
 '35750bc5562078eb5ed5',
 '357bb33b2e879845e91a',
 '357f9b2f0a495e3505f4',
 '3580949a5a3be927411b',
 '3582ef09e118ee526108',
 '358330a73a75219e837d',
 '358d04f351ebb5fe4a0f',
 '358f9fc38cc479ad575b',
 '359a868ca32532dd1340',
 '35a33a093321a19e755c',
 '35a60daf6a5adeaca761',
 '35a8a028ed465e2150a8',
 '35a910e2da807d2c8d67',
 '35ad44246c0169726620',
 '35ad92714a6c99d13136',
 '35afdd1b50c03c4b0324',
 '35b045813347e8529101',
 '35b50f063e944825614f',
 '35b6984de8dfca8528a9',
 '35b6f10d0ba8cc565ea0',
 '35ba330bfb25ff2d5dd3',
 '35bb81b909c3a039568c',
 '35bccfc4fc83461e664c',
 '35bec969e22a46c58977',
 '35bf82c65e5bb1c3d358',
 '35c07abba848dc6bab9a',
 '35c609f5ce4463f7fbd9',
 '35cc607269bea61625de',
 '35ce2129140c662077a1',
 '35d1df3879264848ad7b',
 '35d53ac37e36f5dc975c',
 '35d6d71b359bfc9460a3',
 '35d981e9da1fc1a0c413',
 '35dde0ead2ccb8acd358',
 '35e3c4f9ec71b212180d',
 '35e463b0675b673235aa',
 '35e624da9b070279bbc9',
 '35e85be5f1df79b71235',
 '35ed8506627d85ab8480',
 '35ee6b03ec58ae9b448a',
 '35f3c6ed824fdbd47c0b',
 '35f9925fb1afa6cd0e19',
 '35f9aed3313947647a01',
 '3604e39a048108df4ede',
 '3605581def70917ded6e',
 '3608b2bba97db0bbff98',
 '36118c240808ae3a2e81',
 '361200406d155baee3dd',
 '36135bf528e259c1d971',
 '36145a93f9ebf3c504ea',
 '3616e6610fd31e288cd4',
 '36242b4bd027830b9c58',
 '36282961f4229cbdf9e0',
 '362e8eee328bd271b734',
 '362efe6ceac743f85ee5',
 '362fb003cba69a5d5d4c',
 '3636e377d3eb87bf473c',
 '36385b5ff1d0389dae3d',
 '3638d381bb285c569fe9',
 '36393136477369e3d79f',
 '363eef188be6c6026771',
 '36434c718495f662079e',
 '364b86f2659d8f07ff3d',
 '364e383c13bc0035b88c',
 '364fbb55e8b432de37d9',
 '365155a5cce2c51ebfdc',
 '36577fe24e22d1f5aa1e',
 '36595a1225eb01d0d153',
 '365a6391f5ccacd86bf7',
 '365b8bf9873547f8dd1d',
 '365e722a8ffbc2a8ed36',
 '365e75da5c15acc6c31e',
 '365f7d034137f5f9d07e',
 '3660fbccfd30f6e1d3f3',
 '366221c0139cd321ea8e',
 '36674a7ce842c6b93d91',
 '36679613a98731b0bdf4',
 '3668fba33911c89caa25',
 '36695daf6f730c2a6457',
 '366dc7a0d3d41788d55b',
 '366fac406946fd7d882c',
 '367062f2778afafb5592',
 '367b322edae209ccef99',
 '367e2f41c019bbdca49c',
 '367ee6cbac98881cef65',
 '367f8ce1d1407654f127',
 '368278de3f158ef64c42',
 '3684df0cad351570a3d7',
 '36893131188f5f5a414d',
 '368adc89ce0b7a2604bc',
 '368da38299c5be8a2dbd',
 '369418f9f5b1b4665cca',
 '3694a2aa6102172b788f',
 '36975c607868e43e4949',
 '369a261dc40566df35b0',
 '369c46b384787cf3f951',
 '369c89e93c93417e9af5',
 '36a259896be486fa2c93',
 '36a7753634018de8ddd2',
 '36abeb34d5d598003a42',
 '36abedc508d7945e04d7',
 '36ada268d439c2fb5c18',
 '36b7a7a84768fca71163',
 '36b8c649d6cbec5d0404',
 '36b8daf48a88307c49e3',
 '36be87de095c2e877ae1',
 '36c04565da03b319c975',
 '36c3de034a3e3914ba89',
 '36c7de2137cfecac2c40',
 '36ce26ca260d86221c9b',
 '36ce7667a2b6d34e369c',
 '36d1231088f7d46e7177',
 '36dc2a90ee9f40f2d62b',
 '36dc3447a0814da4d75c',
 '36dc379ae625b1353138',
 '36dc3b426d1c49f84255',
 '36ddda3023652708281a',
 '36e2ef9a3a0cbc1d62ec',
 '36e463c6c61dffd185c7',
 '36e61e6ee16bd3e479bc',
 '36e924db092bec8c7172',
 '36eeb27d058267686ced',
 '36efcc4187b89751b248',
 '36f34b34e946fd613a82',
 '36f5a3d2d0f7ee9c9883',
 '36f6d4807d6104402c85',
 '36f97eb20a564045f32a',
 '36fd2a1ba5038f088c26',
 '36fd42496a49b58f7ec9',
 '36fe1722ac2d0fad7581',
 '37016fbdf60ea2f9a753',
 '37177b993f3ae5d43c51',
 '371bd7baf1eba4f5ca34',
 '371e0995b48e005736df',
 '371ea99e0045bfa56b19',
 '371f15a8b4458c2645f0',
 '371f8eca53513dc7498f',
 '37200711374f53a337f4',
 '37200d11a23ef2962b9d',
 '372186fae277a27be60b',
 '3725d55521e991b52758',
 '37273b8dbb630172348e',
 '3729e766a7a6280ab310',
 '372a4dee1ed8221c7549',
 '372ae46cfde8bf737a74',
 '372c2649893c5d8db8bc',
 '3733b689470e8568f01f',
 '37352eea29999241478c',
 '373ae4dfb391448b246b',
 '373af302f6884b7a1d67',
 '373b0d3de43be50d3019',
 '3741de15c13fbce0ef8f',
 '3742af03b0296bfee9d7',
 '3744d4aeb73ce209ca4f',
 '374674ec2e58f8d6e53b',
 '3748a154abae193e7670',
 '374c23c1fd49de06b6be',
 '374c9cff20fdb315a0e2',
 '37546e88e108abda023d',
 '375617f4a8c0dc6e2f45',
 '3758643e70880eb3bb24',
 '375a1413f11bef962db2',
 '375b3d098723216034e6',
 '375d5e5e07c7d880808c',
 '37611beca5f9ce8520d3',
 '3762525c57e8d85469de',
 '376360a26178ad5c9b1d',
 '376361e05e10ef9f26bd',
 '3768a3242124fee8570e',
 '376ac4785abdd2548a2f',
 '376d77f2d40500199077',
 '376f538fbf074d7c5b53',
 '376fb2221cfd83120be8',
 '3772de639943bf3ed671',
 '37764426757cab2c3159',
 '378197650bd998e3622c',
 '378241e527a9cab5653a',
 '37829853ec5358730ef0',
 '378405db0d273375c2b6',
 '3786c9d90a450d040528',
 '378b85ecc61623f6b6fc',
 '378bf8a0834bb29cb7b1',
 '378c75f58a51a83fbfe4',
 '3790cd1429c2083c7f92',
 '3791427c647cd46eb393',
 '37914ebd7ba58552de11',
 '37950791b58d872c1109',
 '37958c0d7e5a58da6e47',
 '3797c13d575bfddfbb3f',
 '3797dabeda4ea4ff6de6',
 '379b425424f863bc89cc',
 '379da50ff9fa23702817',
 '379edc600b6dc795b0d1',
 '37a00b10a5be550e13ac',
 '37a33df2dccc5f64b7fa',
 '37a7222c69a8f5a40e55',
 '37a76b6dff8a44861a1a',
 '37ae0b8e2e46a5d39fea',
 '37af1f43e1d47353cb04',
 '37b3314b3e696d9b8736',
 '37b37f451eea262b6c0d',
 '37b5631e8ceefbf14481',
 '37b7bc03c80c2f6b1f13',
 '37b839c127216a6e1fe4',
 '37b99c4738eb5d8f5f29',
 '37bbb06cc77c052e862a',
 '37c5aa12edd504129614',
 '37c7ebe0490bd6adc651',
 '37cd99fbf5082d3af49d',
 '37d8bca5ec79afad3a32',
 '37dbcb750592431d8f33',
 '37dc26891edfebea5f1b',
 '37e0fcb7f6f32c5459de',
 '37e2d56cea2a86e26341',
 '37e7bc6c73df00cb81a0',
 '37e9a9167b835a660358',
 '37e9c5864f95685183cb',
 '37eb6a16521028ffa3f5',
 '37f0745df777e1100225',
 '37f255d7160b2f361849',
 '37f3e7a7f4aa9554b4ff',
 '37f41e6dd48b749c4635',
 '37f4da28bb79698cbf23',
 '37f8530448e427cee216',
 '37f9ac232e9367f48f2b',
 '37fab3e2ba757ae9ca01',
 '37fe25567dced3daf75a',
 '3801385366186ac019f6',
 '3801da83312b96c0abef',
 '3803b365551ddfe719c6',
 '3805e6e3f6fb617f20f4',
 '3806008338906dca4d97',
 '380652b835b0f3dc7aad',
 '38102dc3acba348d8e8e',
 '3810b26715899047bce2',
 '3814f33dbf61e54dc830',
 '381741d7cbccf89e081c',
 '38174f4a7efe9bd9039c',
 '381d32c6c7474ffc78ba',
 '381f89913628ade5706b',
 '382215057e85f038fe23',
 '38248fb4929bc7af5820',
 '38262eb8e33d7b6e49b1',
 '382b70f2f094420ebd32',
 '382e991c89788fa75212',
 '382f9a0fec78aacec189',
 '3834788a52da9221ca83',
 '3834aa51c45ad7aeca67',
 '383d08d01a0e69934f6b',
 '383e16f9b21bd24cc733',
 '383fbed4be460f008cef',
 '383fdbfd9b7a0e82325e',
 '384889adc14655cbabea',
 '3848e745e0835ebaefa5',
 '384a4d6e945e0ea71eec',
 '384b8c744116666f2062',
 '384d7e1d64655fd71814',
 '384f0eef14537493118e',
 '38548404f04e08a52605',
 '3854cfda39bc95af87f4',
 '38558af7e44722dcafe8',
 '385708628d180d2ade83',
 '385b492fad570fb4d238',
 '385b8ce03f039ee9e188',
 '385ca66d0038962cf170',
 '3863adb756fc5fd69fe2',
 '386606995c4f6dd7306e',
 '38673388d02aba67c88d',
 '3867e873cf26486003fb',
 '386e390911bf8791af97',
 '386e4bdec035de076e2b',
 '387043f9c911dc7470e2',
 '3872d9c0dca91ec17f32',
 '387577eac2d4f4dbea74',
 '38779c93e1aaaf613507',
 '3878d773c52b3841e016',
 '387b4f6b09d6a516f50a',
 '3883fd9727f1515dd121',
 '388433076f0e7c607836',
 '388760d1d1a9ff6f2bfa',
 '388819d922486690ea1b',
 '388863a4ab96f0cf681c',
 '388c24e9495f8b1a6b68',
 '38988727456f60789813',
 '38992989e77742886c28',
 '389ca1fd2c1261453b84',
 '389dbd567ff9fc84bef5',
 '389f9626bb989b8bfedc',
 '38a1dd6cd60c6a6cd375',
 '38a53809e9f41e424397',
 '38a691e16ef7ece2ddb4',
 '38a759006a17a8fcda4f',
 '38afab43026131b909f7',
 '38afb2be3946b13458a1',
 '38b0c56a1cdb5af3947a',
 '38b12b06fa8637fdaac8',
 '38b1c402a9878c23663a',
 '38b26fbe94b7275c4b00',
 '38b316d5b2fe6234046d',
 '38b4e75b328c5a95b797',
 '38b7974143e524bd779f',
 '38b8aa46f888ec894747',
 '38b97daf75a9cd6a9b95',
 '38ba1ebb058bfb20ed32',
 '38ba62e18f690a335395',
 '38bf49f5567f1812ebff',
 '38c3663603450e1ce4b8',
 '38c9b5edc97b6d9154c6',
 '38cc96add3d81b20e7c8',
 '38ccdef31b90d71eb4a5',
 '38d1597f9e8c9f761b24',
 '38d1aee7a56e41930db5',
 '38d71174848bdfc47f7f',
 '38e19a92b9d2068aa0dd',
 '38e584568024c08e2df1',
 '38e60efdb4db268f6b82',
 '38e80932a6ed67a1a6d9',
 '38ea8964bdc388343e68',
 '38ebabccd24b6f86e192',
 '38ed4284001eb278f950',
 '38f0991155fe2ebaa708',
 '38f525f5035eb3e763d9',
 '38f70f6108e7bac9a733',
 '38f8bf03476983251b06',
 '38f93f3693435e496934',
 '38fa9ec5768bced065de',
 '38fc9d16e5821f65365f',
 '38fe61d695e662b045fb',
 '3900e4bb16a0a01c4d6d',
 '39019630cb3b6e4f1b5c',
 '3903335b13370031ce0e',
 '39057b2d68da0c2c1dc5',
 '3907f5e00e80d4481cd1',
 '3914396f8d1fbddc391b',
 '391472ff2a8dea5e6749',
 '391953e41793c2be7e4d',
 '39197211ceb2301ea9ba',
 '391ea843e393376be1e4',
 '391f602bdfb11b17d8a9',
 '392087b04dcb99415161',
 '3920a30894e2538db5e9',
 '3920d844060044d05021',
 '39229c2ca7d9642ec92e',
 '392cc0195c8ac246ec12',
 '393041a607862c9562e1',
 '393bc728c743997db9f5',
 '393bd857192b922db630',
 '393c492805ca3c4388c4',
 '393d531ad700b61cb10d',
 '3943c20bf2c7b2ee365f',
 '394a9071877645ff3f43',
 '394ccaf1e4d65fb76333',
 '394d4c10402922300ba4',
 '39507de326745a0fa932',
 '3952111f7047b557c646',
 '39544ec470bc40bfc3cc',
 '39546afcad13ff4518ab',
 '3954b40e76add27b015a',
 '395cefae0be04a2b914a',
 '39607c242e4e2fad237d',
 '39625addaf519fc297d3',
 '396a883eeefcca444ae7',
 '39721aa343fbcb1f5cff',
 '39748c196a76f335dd46',
 '397af78f80bf22ddc4dc',
 '397b410fec2ab0526bef',
 '397ea5df649a747a4f32',
 '3982a723f4ae0de20979',
 '398d09a8bb8923fbb1cd',
 '398dee7c6c71d4c0cab7',
 '398f52724d51d2589b8e',
 '398fbbd85f37681e6bf3',
 '39905005fe32da6e0202',
 '3993e5b0fdd1f628a382',
 '3995210d8011ee0847a4',
 '3997f510907c7b8debda',
 '399b56339defd5ad14f5',
 '399f7a582c7afc043a4e',
 '39a5ac672d6b61213d9a',
 '39a6d630143ddfd32899',
 '39a87ae41d44b1c7e29a',
 '39a9a492ba18b1037e0a',
 '39a9c5760804141e0474',
 '39aa3d76d50fdcf2a77d',
 '39b83d8b0a7e1d612344',
 '39baec2918c10c8e40ec',
 '39bc6ed2ec4c1274db1b',
 '39c4f7cdeaf888168609',
 '39c6a4fc03442284e7b8',
 '39c970e02ec54a039fe1',
 '39c97181172287579e9e',
 '39c98741937b279a0cce',
 '39cf41566b2eac187eb0',
 '39d3678f34edbfc72e17',
 '39d4b8f548e6374deebf',
 '39d516db61e1a3e5aaee',
 '39d54d58a16f6e615ff4',
 '39d7ade3864b9eedd6cb',
 '39d8e176c49eac23c83b',
 '39da99ba53e2f7e1f31c',
 '39dc3f0bb1530254f75d',
 '39dc4afeadae82daa933',
 '39dd4a9dff877f414a56',
 '39de1761eaef7f75b2ce',
 '39df62546edda10ba4e7',
 '39e0a97ef029239692c7',
 '39e4e787081251c2b744',
 '39eb1bdcf43af9953a2d',
 '39ebe5feb2e5a2879150',
 '39f2a036921c145b72d0',
 '39f2c85b6ad68e1e14b5',
 '39f4d993bd1a24421ed3',
 '39f7b6f1e36548dd38e3',
 '39f8d84422488020b7a5',
 '39ffbec55b557e685f43',
 '3a06ded76074565a5a20',
 '3a081e0ce6e673134162',
 '3a0b09b784365afd030e',
 '3a10cce9695615cb09be',
 '3a10f8f66707412677a8',
 '3a11bce5cbf94c40adb8',
 '3a1808f0d660d99b44a8',
 '3a198a1ab5e71cae1812',
 '3a19b04aae135eeaac9b',
 '3a21755466e4bb959e7b',
 '3a285343ff43462e0d3f',
 '3a2b94b60532b22b5053',
 '3a2bc72a9189435b4ddd',
 '3a313bdd8bdce4497b24',
 '3a3373ceff9159edace6',
 '3a3374b9b00b1ad77c65',
 '3a33b83c8e641606ad82',
 '3a381042d802caab9c4d',
 '3a3886215ff83c7b0667',
 '3a3a10f9985af43d8fb8',
 '3a3b386075781761b487',
 '3a3b9cc247db962d2fad',
 '3a3bf572df3afc2e1559',
 '3a4180601fc5319dbd10',
 '3a477413fac8f01beccd',
 '3a4783e787780d472a76',
 '3a4797229077637d6def',
 '3a480a9c837e36066b3e',
 '3a496444fbce2d2abb05',
 '3a4af30935ddcc1b99ab',
 '3a4b50a76242a0af3256',
 '3a4e34f59ce5ecdcaaaa',
 '3a509a356d32f477a752',
 '3a51c6ad5250860e196f',
 '3a543b2270ef8a1dec6c',
 '3a54cabfe37babf92d4a',
 '3a561008e7230970c7b9',
 '3a5a6dca3b2bb7dd767f',
 '3a5cafa9688607c52649',
 '3a623f35f9c59da4915c',
 '3a63051650ec84ca362a',
 '3a68adfc99bd19e8d54c',
 '3a68c9d22a778cbe843d',
 '3a6ad38a0707692920d2',
 '3a71d6257b8489369dbd',
 '3a748e51bd104bd66823',
 '3a753f56feb5dcf54327',
 '3a7666aa80b9d1a8d13f',
 '3a788caab07c84b262d2',
 '3a7aca8882b419a7d927',
 '3a7f295f95a88aba1678',
 '3a80ac1295823bd20df0',
 '3a88f1d055dc6fde4097',
 '3a890bf07b381ea1b208',
 '3a89dc52efcf85053a7c',
 '3a8ceb482d140bbc58d5',
 '3a921f00d63774245d6b',
 '3a92d227a290f7c81c8b',
 '3a9474508e97ec716fe7',
 '3a95477c2327b1b16278',
 '3a9589044fd76d0f370c',
 '3a95db8c777adc54c39f',
 '3a98f5abb34c0b4bd979',
 '3a9962dfd3a0cd291310',
 '3a999651a5651cbcd8c2',
 '3a99f6d3240ad10d85f2',
 '3a9b1d3098e95cc3e6b8',
 '3aa081508f768e5f9999',
 '3aa172272d79a5092003',
 '3aabb210bf60bb526c0f',
 '3aad27ec7f8584386548',
 '3aae8470ec2a9265e6c0',
 '3ab081a24b4828d24d9b',
 '3ab2b9dea742b16b584b',
 '3ab3337aad32e0867b0c',
 '3ab581c1fff071db379a',
 '3aba2e631e222e06b4ea',
 '3abeb92de34b903a9990',
 '3ac05fb222cb2658a062',
 '3ac319cf289daef02d4a',
 '3ac6d4efcbb4a86cd6fd',
 '3ac852c1023ae0e83fe1',
 '3acb479353588f687cfa',
 '3ad611c03559dcd9afe7',
 '3ad6795815227cfa5486',
 '3ad8b23a2b1d225c5dc8',
 '3adae79cae07dbe1f10f',
 '3adea6dc1d35171f5bd8',
 '3ae084c685b80fa96c08',
 '3ae44b76213f8f6009f9',
 '3ae624cb4ac19345f13b',
 '3ae7c3d93cb18ac9990b',
 '3ae9a446bc0f5da60f59',
 '3aecc1ea9a3ed03d04dd',
 '3aee0d17c6c2127beeab',
 '3aee3ecde56909c74132',
 '3af23df472c1a395dd5f',
 '3af31d196fbe0d7c9b7f',
 '3af5c8e486c85738b18e',
 '3af6107ff64410c5d42d',
 '3af6f3a088ec9c1c08d3',
 '3af95c7922d04a9b5829',
 '3afaee7314696978972e',
 '3afc331c1665c91ae1e2',
 '3b03a81cc6a6286aab43',
 '3b05a74047d643e97a5b',
 '3b09f9916fce503beca1',
 '3b0e0dd4ecedba884de3',
 '3b130809822fd494d6d1',
 '3b1324ea1b0d39fb5cc1',
 '3b1516416de880e1d2b2',
 '3b1835656d1554e1959b',
 '3b184b3e027daa7f2efd',
 '3b196ca6cabc5eac7707',
 '3b1bb3c6cc7266d4faa0',
 '3b1c41629da3314abc47',
 '3b1ccfda82bed0a4ae71',
 '3b1d18732863d4e13f6f',
 '3b24fc3fe928e59dd298',
 '3b25eca3d96dbe3b17b2',
 '3b28ecdd98d4be1904b1',
 '3b299768e1c615f31438',
 '3b2be661ee2fdfd8fa5d',
 '3b2e86c54f3d05f9f8de',
 '3b3b4566ac1744d209bb',
 '3b3c8d0bc6a843109ef3',
 '3b3e14cb2bd75d79b735',
 '3b3e5462ad5b6ad41945',
 '3b412a39e4d7aea428e4',
 '3b449a4ff98a4380dce0',
 '3b4fd19071e55aded65f',
 '3b50fecc6c174acc2e6e',
 '3b556772ce2100cf69a3',
 '3b58216e5ccca3c26ba3',
 '3b582298ef50fab3891e',
 '3b5a9db64e14dd5ca015',
 '3b5aa52deab7a2c2ec9a',
 '3b654677324e12574cbc',
 '3b6a7ecd2b02ee71e007',
 '3b6f16bd1a18d031730b',
 '3b706004c99058f192f3',
 '3b728141ae33cf891564',
 '3b73bde361ad5b516215',
 '3b7c024afdb23037c067',
 '3b7fe175c116d109bb36',
 '3b800d5370cd819c5ec7',
 '3b8074e77d90888c6dd6',
 '3b80cb4e807541e88c04',
 '3b84215a1040e188cd0d',
 '3b86100e342bb00325ab',
 '3b8652f378012d2ff263',
 '3b89b1f00e019abbb338',
 '3b8afb69812ab314544e',
 '3b8cfe5de63b02d443ca',
 '3b8d0e313e3a600b3992',
 '3b8f58ce0800589273d7',
 '3b901a71bbd6c129e514',
 '3b9bce81ccbae5a2c94c',
 '3ba0d49d391c76a3cab9',
 '3ba11875b0b963449d80',
 '3ba22743acc3bbff609b',
 '3ba31447951d8c15d220',
 '3ba321f31fcf7c3c874d',
 '3ba45dd2e867b97d5cc1',
 '3ba56ea0235637605117',
 '3ba603c8bde27973fa30',
 '3ba8f5dd62d1bf749cb4',
 '3baa18fbca98a6135587',
 '3baae3296b756a577e65',
 '3bad4f36df918a3140b2',
 '3baddecd7397542b3fd0',
 '3bb31e67cd9768863d27',
 '3bb530e3c3c5730676cd',
 '3bba1a7dc117f8a6e3a8',
 '3bbaef93ade1508ff16a',
 '3bbc128aae420d325067',
 '3bbcacadfe7f2489ab2f',
 '3bc36f385e3bb419fc0c',
 '3bc59a8fea2e527873bc',
 '3bc731b29453e1ff240f',
 '3bcafed523ce2424ad29',
 '3bcc3e6b775ba060836a',
 '3bd8880e553096475638',
 '3bde3e7410b92bb25d1f',
 '3be064b157a21f52b4c8',
 '3be06b76045cd7b3c0b8',
 '3be35b0967838c71674d',
 '3be63c42340857e4a8a0',
 '3be71e8f012d1294e88e',
 '3be8600bb068ae64d756',
 '3be88d3f24429aff5d42',
 '3beecd8707c68706f083',
 '3bf2764daf94f58d91b8',
 '3bf2f7d5d75fc92e2eed',
 '3bf462cd26a58846480a',
 '3bf5880b553564619232',
 '3c00666ccc1b08b3ba7b',
 '3c0160997ed9ac36bf94',
 '3c05004fad29dbcf4ef1',
 '3c056bba2ba07d8d36f2',
 '3c05902a99aeca788825',
 '3c0c55c09a09e82ff0d3',
 '3c10e6736b57e8cb9bac',
 '3c1276b79099b88c81b1',
 '3c1341066052eab5ac50',
 '3c149565631f13b08903',
 '3c166b00acdb59a1ed79',
 '3c17df8ba8d5bc5862fd',
 '3c18ce4aceec48b5c438',
 '3c1b8b520d1c15abd93c',
 '3c1e69275ce19c0cf8d9',
 '3c2225813647d1125650',
 '3c2399419f6018821b1f',
 '3c268044ab53020d25c0',
 '3c278970d64e32a134ab',
 '3c2a1b10155183b07bb6',
 '3c2a63dc1c225635c7de',
 '3c39af9107b6e3a52a15',
 '3c3b07e6bff2ecd29838',
 '3c3c3480967bb2bb337b',
 '3c41808722d3fb284c2a',
 '3c434275e223bb51712a',
 '3c4567b3783e36f1ee51',
 '3c48a9df778adae3b698',
 '3c4911a6e3080fbe7bf0',
 '3c4ac77ffb0d88b0b981',
 '3c505e297a46679f46d1',
 '3c536d747bd10e9043a2',
 '3c579ac9281209ca5b2a',
 '3c598ecd6a691b2e5e6a',
 '3c5a1a1943758a2a02b1',
 '3c5e2f8365d41c211e08',
 '3c64928d8914815c024c',
 '3c68698e36798b68d0ce',
 '3c6c7c5abc43ec4b4c7b',
 '3c6ea330f285e5e1ba14',
 '3c7161291f77acb9f26b',
 '3c719210fbb1677f196f',
 '3c71c9a1b2fa7b0366ef',
 '3c724f761527a29a155c',
 '3c72c44861002b675f23',
 '3c7a2bfb48a5cab20611',
 '3c7c06e6c650ee098777',
 '3c81c71b577fdf93fb67',
 '3c81f196df2389e791ae',
 '3c8545bc4fc2110bb206',
 '3c85912fb2b6f658bf4c',
 '3c87810f21a06a5a0a74',
 '3c9148a406f18b387ddd',
 '3c92944eb293dd5627fb',
 '3c936ff2a2267161d935',
 '3c9433f2ae6ea56115b9',
 '3c96cb99d38f49a9188b',
 '3c97542a6c07f3c64e75',
 '3c9c9e35bc760a8191c1',
 '3c9f5ccff370edaa52fa',
 '3ca66d279df910aa84ac',
 '3cae49a06489e6c64b92',
 '3caf8059bdaa976e360a',
 '3cb1e070721f63d9cedb',
 '3cb5f58ce939ba352769',
 '3cbc40125ff91b74aff8',
 '3cbf4d8ea56258b92903',
 '3cc06dc0dbf4312038f4',
 '3cc28d451fa132999efb',
 '3cc5576dc9d186a92b00',
 '3cc6a67f723e4dc2171d',
 '3ccaebd7bef62ecf92f0',
 '3ccb48f38acf915ce6a7',
 '3ccd3537e565523a3775',
 '3cd18d10d1a08a2cfe52',
 '3cd1f7bf9ce5cf2488ca',
 '3cd20f3815f9a00f44dd',
 '3cd27320a555ed9ab984',
 '3cd2806259072348bfd6',
 '3cd2a1ad9c096643e564',
 '3cd4c8209db1220d9661',
 '3cd565cfe9499dded927',
 '3cd85c8aca02693b7c88',
 '3cd8a6ecfc813434a6ab',
 '3cdb363864ac8b6057d1',
 '3cdd59e58c6e92f0f25f',
 '3cde4bc4ad9f0d9a40c7',
 '3ce26a57a13ed1d685db',
 '3ce4d1e1b7b22ad0fb69',
 '3ce4e507bfbee00e5c31',
 '3ce515db43b6536bb9b2',
 '3ce6344edcad9bb63d97',
 '3ceaa48bd37cd2323dfb',
 '3cef987f8b5fd9aeaf44',
 '3cf433e19157f7af9631',
 '3cf750cfc33cb43b340b',
 '3cf768df58be101aa902',
 '3cf99206541deeea9d86',
 '3cfb87d8d91a3e89bccd',
 '3d009618548f49b16877',
 '3d01fb2c25cfe928ced5',
 '3d03abfb1ddab487c046',
 '3d071b247542d863cec2',
 '3d08d98cbc41d10aa4ab',
 '3d10c065773366192e14',
 '3d126b8482f5c894a2d9',
 '3d16ffe8f0ecf15f5026',
 '3d203d14d620116d68f6',
 '3d20bdfa56cafefcd0b4',
 '3d222453735bd9951705',
 '3d29ff614fc915e79ddd',
 '3d30e4c75bf0583710ff',
 '3d31705ba1f807c07a21',
 '3d317f4c1907021aa986',
 '3d34150af8ce6f9d243f',
 '3d37246e0a9e7f729297',
 '3d382c907e6468196650',
 '3d3d27ecc74d6613c868',
 '3d3ec38aea0e9df1c20e',
 '3d3f95460c422bc82fa6',
 '3d40b045e5b273148edc',
 '3d48a7bcdbdeeec81319',
 '3d4d7acf3a8ece3d2d28',
 '3d4ffc47111a2e2e8ffc',
 '3d53d19dccfe16844d79',
 '3d54d8abe7272ff9b3e3',
 '3d59ffdf7493a989e0d9',
 '3d5a2cf6522bd9a01933',
 '3d5c5af6fcd4ecee36a8',
 '3d5f70670635105f74a5',
 '3d629cba30b1470a8347',
 '3d62ae61e9d9ecc27df1',
 '3d656108d27a94170b36',
 '3d6b9b38b70095ad5b4b',
 '3d6c4804be2fea48e74e',
 '3d6d63ae4262df16940b',
 '3d7310056d31a547813d',
 '3d73257568b350d8447d',
 '3d739d170a3473cbb7dd',
 '3d76f6e77883422c4a5e',
 '3d7a289ea526e9a933f7',
 '3d7f515ea9e0c187df2c',
 '3d81a5c2e7a7616bc888',
 '3d8a29e18733bc7955ad',
 '3d8b1c6720709218cacf',
 '3d922c89e2dc0f4cb82c',
 '3d9e514b907fbb3f6688',
 '3da2eee0a217894348cd',
 '3da3d607bc4e527e7b5d',
 '3da414d032338b7f2546',
 '3da54fe6908869c88e37',
 '3da74e296758080fc8f7',
 '3da798fe37681ceac45d',
 '3dab215630561961b856',
 '3dac174021c37fe90080',
 '3db1da54be3899bfa048',
 '3dbcd9da2bf621d16b6e',
 '3dc170c062c647f89eac',
 '3dc34aefc0b0e75c03e0',
 '3dc630e18ee5f1c8c49e',
 '3dc71ff87b512e2492e8',
 '3dc9e1baa2d222664521',
 '3dce2f08e005f26d2af5',
 '3dd2c2d78ae9362773a0',
 '3dd46a5a53c595d1a222',
 '3ddbbb36ed171cb7a20b',
 '3ddf4f06e3a8a7c1ba37',
 '3ddfd6cf6e51ff505dea',
 '3de091877c8e3a00e30c',
 '3de098425dca6e9fac9b',
 '3de0d4a2a3eb0175b29a',
 '3de0e175c8796c63cd36',
 '3de21b37b394d6be18ef',
 '3de3963401b1699db422',
 '3de411e216a4049c546d',
 '3de44a85108a1feb2a39',
 '3de4d3d357da5b66fb46',
 '3de6f94d0a953b26143b',
 '3de9f6423589fecc9c6d',
 '3dea9f9598060ef417fa',
 '3dead2fceb20d1782853',
 '3df16d880a99510109a6',
 '3df1d7db51fc02258ee0',
 '3df1dadfaa7ebc58de70',
 '3df6c95ed4d878d06a3b',
 '3df73616fc4140381283',
 '3df79305e3093842df4a',
 '3df7b5768dd4b4d4eb9b',
 '3df87bde39e3c75d2586',
 '3dfdad72b63bac7584cc',
 '3e025391b9dc416fbd16',
 '3e05fbac45bd714a111f',
 '3e0cffaaaa17e56db155',
 '3e0da1c7175b28e59918',
 '3e13a09f05d26791536c',
 '3e14a563d0f74ba0d2e0',
 '3e196302587edb7131d9',
 '3e1b3cf270edff90213d',
 '3e1ecefaf05ad819d8d9',
 '3e23a668224a4b1ae4cb',
 '3e2581f503ac9d41da95',
 '3e27bbefc746ae8c6aae',
 '3e280705366efb545766',
 '3e29d56ca21a157c6c19',
 '3e2fc817888982181861',
 '3e359da29cbc8f5aef5f',
 '3e36fa390024b8c0e372',
 '3e3793c846fde72cae2c',
 '3e3d515ed512d9ced799',
 '3e3e35ceed87e04b37a5',
 '3e3f48deb149189ee764',
 '3e40fd2a8b1cb82331f1',
 '3e47a784a1076e59e1c0',
 '3e48b71088cad31976b9',
 '3e54582026dd6cb53e2d',
 '3e5c59fd2ece9408788a',
 '3e5ce0b24b2ad2948aa5',
 '3e613a0df3af1555acd9',
 '3e62906abcd1454e9a1f',
 '3e62ed7a780076a91f04',
 '3e671749339889699d35',
 '3e676c6272aebf933a54',
 '3e69609f351161eaef3b',
 '3e6a0f134c0d5d66890a',
 '3e6a427d567b8769feb3',
 '3e6bcda1218c23e796c1',
 '3e6c4d4f6ac2890eb5cb',
 '3e6ca8c10c72582c1570',
 '3e6d28dbe84f0390e53e',
 '3e6e6c8a7cb73be29b8a',
 '3e744231b667d32094e6',
 '3e754cbd5282e3ac107f',
 '3e7907180f059d9c1437',
 '3e79756066565279d69f',
 '3e7a6ae6697e2c306e85',
 '3e7c15cb50342e4d9d20',
 '3e8aeebbb4068ae60c42',
 '3e9103b0cfe5ab2033cc',
 '3e99b9d38fe9a0d9cd70',
 '3e9f7c8c8e4d8ab04b9b',
 '3eac70c0448502704b0e',
 '3eb406eff7441d73926b',
 '3eb44ccdb625f6d5fc16',
 '3ebbbbf1c0e72d625aaa',
 '3ebf5b9523993351ccf6',
 '3ec204f47f74bd58dec9',
 '3ec54123c4b5871483a5',
 '3ec55f4b1372ca553305',
 '3ecf6d5121481467e6da',
 '3ed04af2eb28b26013f9',
 '3ed15c47ddf7954a8e67',
 '3edb116e92eabcfb1d6a',
 '3eddb092092c5221c258',
 '3eddd21b55cf20ad6e0a',
 '3ee16d34206171b0824f',
 '3ee7330fa3de0e55fd75',
 '3ee78427dd5ce4ef53ed',
 '3eea2a6b1b66f3ceb099',
 '3eece72d42ffe0193bc5',
 '3eef4adbd4c5189f3c92',
 '3ef4c02565ed5b1b6125',
 '3efb74cf0e153859efe0',
 '3efc46e0fc3dab7daff4',
 '3efdd08d5883782f1fad',
 '3f0579d14110325832ab',
 '3f066ed830ddecab31f5',
 '3f078419776e1cb25d20',
 '3f080f10311fffaa6918',
 '3f12cf236b4538f8fcb9',
 '3f1a5da1f12179413127',
 '3f1b67f226a90dc6cdce',
 '3f1c0555ae99ed963970',
 '3f1ca42feefda1341638',
 '3f200f34a1604b0a8457',
 '3f20cc757f3f77575aca',
 '3f2700c2a3ab9da32125',
 '3f2b646cc369a5639dc8',
 '3f2dde35785121a7359e',
 '3f307dd08a07e3a74504',
 '3f32cb97d35e9313144c',
 '3f3564fa216b8ba24565',
 '3f3677efffe7092ad11f',
 '3f378099e95e37a654cf',
 '3f380235a27e8bb38bf5',
 '3f41619c42d4e294c630',
 '3f41a5a67feb8a4b829c',
 '3f4339711fed70f4774a',
 '3f445069ae980cee2bd8',
 '3f47bd196313139abebc',
 '3f4a37d808dd1640faac',
 '3f4bcce313a127fab58d',
 '3f4f08e468336904abb4',
 '3f5107e0740dca4b545c',
 '3f521d05b5fbcd5be0d1',
 '3f525a8a859bf745145f',
 '3f55d0a9b6e41ccc75a4',
 '3f592c4e6808ab240a8a',
 '3f59da5f9d00d4ee684d',
 '3f5dc7dae12253a4df0f',
 '3f609df7ab95c54ecd77',
 '3f6219875b18c7a6f41c',
 '3f65f773cfaa55f1663a',
 '3f66cea760b8072738a1',
 '3f67362e901335f661a5',
 '3f692677a66e3dc0d6b9',
 '3f6dd4fd04c723630be0',
 '3f71547045e78c60fedc',
 '3f814120841a78927faa',
 '3f81501c220c7a0666ce',
 '3f84f0bbda8ec4317b53',
 '3f863f00f5f923ca8085',
 '3f867835c3511426747f',
 '3f8899420844fe3511d5',
 '3f8bd3bcd44e3a8370e0',
 '3f8f0ca443f5b9156e2e',
 '3f92dcf9ca3ef07cdf55',
 '3f92f790e9dc6602afbb',
 '3f99a0cc694aa228fcff',
 '3f9d208b07ad15b9a474',
 '3fa0ff1df5186c46feb0',
 '3fa19c41a96eab3e8bb4',
 '3fa2d9aafc1907aaf585',
 '3fa771adff82046b415d',
 '3fa885346883e9a083a9',
 '3fa88d207b035a6ac34b',
 '3facc458315ff823a958',
 '3faeec6181fded6dc6c7',
 '3faf3cec8ddbb1a350e2',
 '3fb5e091b5d2692d4ff1',
 '3fb655ad042f1e31d6ac',
 '3fb88ca9a16fe0637d00',
 '3fbaf9614680a02930bc',
 '3fbe22e5d960f6881b1c',
 '3fc55e6980b8a8a06df7',
 '3fc71927878d32c9d97b',
 '3fc756e000e16198f728',
 '3fcb4696e39cda6983b4',
 '3fcd5c3f1c1b9c0d2f0f',
 '3fd1abc4b0e9b130dee5',
 '3fd3212b8502b261929b',
 '3fd5ab445ff2d2cd8967',
 '3fd8351ee29b129c3fc9',
 '3fd8b2a8648fda01386e',
 '3fd96fe32fe5f5857218',
 '3fde5a4f6adf3421e09c',
 '3fe2f862cf61b045fe37',
 '3fe600f6cf2d021e60d9',
 '3fe7d2b540127dbf30b7',
 '3fe890c28bf3f90ff1e9',
 '3fef49861758d4bf8a0f',
 '3fef68a28653f65bc978',
 '3ff1e863b614c826a84a',
 '3ff294ab82dd55305f03',
 '3ff6fb677a7c77b2bc2d',
 '3ffc063310efeee57fdd',
 '4000a166e0a84fb470ee',
 '4002ade3b5f99f2c53c2',
 '4004db4e8a0aebd4faac',
 '40061b5d1bfda8869b4a',
 '40098b10280b2404efcc',
 '400b186ce6114f93817a',
 '400d0e2cb1932365af1c',
 '400e77c93075a2540d36',
 '400ee42463c8fdb0fc8a',
 '4010f57670f7d51bba7a',
 '40128424ba777ad7dfca',
 '401751d84cdb713a4143',
 '401a7b65fe31a10597fb',
 '401c47428ce98e053ea5',
 '401cf47b5914a13f122a',
 '401f311b917e17e68cef',
 '4029edd07be81ac717e6',
 '402bd4b2aac1541fce5e']

# %% [markdown]
# 7

# %%
qids_7 =['403384e69c5ca9896772',
 '4033c5186c31d4f67000',
 '4035457ab2b15e2f2b59',
 '403933417859ce2a05c0',
 '403983cff173118a65f3',
 '403a6e7690a8babc949c',
 '403c559a96137895faa2',
 '403dc5f52e75c87886ab',
 '40451380f933bb6b7a86',
 '4046bb896758e812bacd',
 '4047a2b1ac30123572b8',
 '4049c79d2e177e41126d',
 '404cee09767c60e394ca',
 '404db1a385e4cf844546',
 '404db9fc4fe5e0e83c21',
 '404eaf5ae750b54aff75',
 '4052a9dc412a13f26ae0',
 '4055d4f7fd569f874864',
 '405ae3e077f6860c63af',
 '405ebc7333081701b342',
 '4062df0fc149de2dae1d',
 '40655d3acefaaa54c180',
 '40674cf3a66a23d35fa1',
 '40690ac4b3ca0983cdb0',
 '406ab301fcc996eb50bb',
 '406b1968f4d7e9fff5df',
 '406c4f99bf6711f83c23',
 '40706dfde85b4161bcfe',
 '407098b56e39350b54aa',
 '4072053d1df5ce798ffd',
 '4073bb6426aa3bf8ba7f',
 '4075762898755194f9d7',
 '4079d16a4b312667e7e4',
 '407e894bfcf4e29ff58f',
 '407f6c1e21235f5715c3',
 '40862c8112b2420d02fd',
 '40872ce5c8ee03f068e9',
 '408ca640c68b19393bf6',
 '408e3326b8c9beeb5d13',
 '40914432ad241761e164',
 '4093cb56fd3afcccb0f9',
 '4096ce0d6f6eef1d31aa',
 '40975dddb4baf6450bd0',
 '409af398fb8e493ed2cb',
 '409b436b4584b61b178b',
 '409c5e6b17d3e3b059b4',
 '409d957813fae1ad967e',
 '40a41b4d1c868a3c44dd',
 '40a7cbc740011946235c',
 '40a81e7649bff894e971',
 '40ac2c8bd82b7f7ba30e',
 '40ad03eadc3b24c551d9',
 '40b10519e2d8cb30b8c2',
 '40b166237e855532b8fe',
 '40b7afbea7ba70a2d601',
 '40b7bc5db0cfc19ef00e',
 '40bc801529d74db936bc',
 '40bd552a5f62608f0f98',
 '40bdea11d15605fdcb03',
 '40c1e51b9ec14a5fde07',
 '40c6397503466bb83351',
 '40c8c90b5d79fd06c731',
 '40cd380a9e0efd782b9a',
 '40cf19d535a23a6cfd66',
 '40d0223b6445b717c540',
 '40d0a95724d9b28a5e3f',
 '40d359482889b195d5da',
 '40d59da29913e02ba456',
 '40e477fc94c2649d7541',
 '40e48624b95432169a4a',
 '40e4b71e3fb384ffb96b',
 '40e4e440ca9a3e6abd31',
 '40e56ab5476cae7f256f',
 '40e64f9113c13d67d35a',
 '40eb6527a4a1d465e3d2',
 '40f161cd88c480ec51cf',
 '40f31fd2e5854ba14e3a',
 '40f634e0aaa7f3d33d93',
 '40f880e08e6a042a7642',
 '40f9aec4958973c09f31',
 '40fa8722bf5ebef0c158',
 '4100e5069205a63d5b62',
 '41010fcf54db5c436d7f',
 '4101c72c89f84ae25107',
 '410229cd2b74b99a22ee',
 '41026ee2a6de45fa3aea',
 '41047eaef2a628267c40',
 '41075b5ee1395e04c66d',
 '4109e6a35ade4f718e31',
 '410b6aa32d84eab68477',
 '410ebf9f3fd44a7ec6c0',
 '410f8a54b4f72b656640',
 '4117e50e76a1453f7300',
 '411b64befbbf0fea9587',
 '4121764b9fdc1baac8b6',
 '4122c6eda4354c661a1b',
 '41261adc77b8c46d394c',
 '412965853bf2bf121bb2',
 '412b6e3dc115c8a73d5e',
 '412ba6ed4510071084d6',
 '413039c5d3351b73ea94',
 '41368c9a1928983c349e',
 '413726831e7cf47277f1',
 '4137449a89145333a906',
 '413a2d00e2502d114621',
 '413a965ef9f312f194fd',
 '413aae757a89a47605ea',
 '413e80565085bfdbe9c9',
 '41484d8d2afab5f14995',
 '41490401ed767ddc4d40',
 '41517bdf16877ab0c0ee',
 '41526df84d9f7ff4cfdc',
 '4155906acbfcc84f4b25',
 '41574d7feb877797f442',
 '415a0269c0474ef2a691',
 '415e0ded3c739cdd57f0',
 '415e4311ac1d6c20ae4f',
 '41620ae196b5985cd09a',
 '4164737119e1348adf0c',
 '4165e64b0177551e2884',
 '416836391abd5d3de05b',
 '416b2d7951e3c4fbe3a1',
 '416de20465c2e139212f',
 '416e0cab3e45edc19f73',
 '4173908d74dd9340dae3',
 '4176c7ddc2c4eb578d33',
 '41772165f3e92ead242b',
 '41774fbc8e13dbd880ae',
 '417e5c6bdeb36c785868',
 '41828ed62dc8a20e7c23',
 '4185002d57fe0df7ab00',
 '41897d1c43897d3f2aad',
 '418c5141ff61d4dd1a6d',
 '418d0bb61b52dffaa0eb',
 '418d77260036d6a555d3',
 '418fa15b22fd11b76da1',
 '4194bb72e6704ebfbcfa',
 '4197562a06a228c37c46',
 '4198d599354961e019aa',
 '419b0619731bde8bede5',
 '419df2219e9537012019',
 '41a108f76eed460fdcc9',
 '41a5faf66f45a5a40519',
 '41a70187ce892bf22e6c',
 '41a79a5226c93e21b452',
 '41aaa280153d57f821af',
 '41ad6dad4452e29b27a2',
 '41b30149d699e6e26f73',
 '41b311eb09ca06296db9',
 '41b68fd1040401939b88',
 '41b8701ba170d4a857e0',
 '41c63fb9a9d804345758',
 '41c6c0ab88e9f8445f61',
 '41c7852da5652d0b0b2d',
 '41c88a8661c6144e62bf',
 '41da0df5a7709ffab75f',
 '41dcae868bcc33d07233',
 '41dfaa8cb45c2f593555',
 '41e0e48fe1b42fcdb037',
 '41e11db96e4f006c5492',
 '41e13eb8566413516f45',
 '41e3e04775025b80a403',
 '41e4c6b8c678988b0cc8',
 '41e6b04b2eab5866924c',
 '41ecbc1984ee9c526e59',
 '41ef2a4f4c1149f71db3',
 '41f39fb5609d36792275',
 '41f683f7586432684d20',
 '41f71771367caa1eb91d',
 '41f8fc6046f8b6db882c',
 '41f918003f9eced52587',
 '41fb2600628f7f034947',
 '4200e46522edde08e5b1',
 '42013fd6979bf57d7a18',
 '4203047674865105c32d',
 '42044340fc0c61972fee',
 '420532a3f9e4feabf241',
 '4205b08edc618e3dad0d',
 '42078719b4c0ee498e43',
 '4207e361f9da53c55d07',
 '42120de0328d4057967b',
 '4213fbb6f78aa96d3cfb',
 '4217b25c1765b7a8a574',
 '4218091a8f2deb4e21e0',
 '421810be865cacc7519b',
 '422658c9e2a75e72d2db',
 '422b8d603cd62d1ab61e',
 '422ca6b0a74b88393778',
 '4233c2cc5ad242f5d551',
 '4236ca64de9027342745',
 '42376754305476c72b40',
 '42376a34d357a05d4d5b',
 '424c49f3d4723a38a060',
 '424e0558b5177e4ca34d',
 '424e812a3d9a086c43f1',
 '424f4f2ba2ea05e41ef4',
 '425060861f3b4a617d1c',
 '425a5e5ee94b8327f139',
 '425acf5675145ecdfe13',
 '425cfb831fbfc0ad379c',
 '42617e8ea651244bb5ba',
 '4267933740e20a059936',
 '4268391b54875ce9004a',
 '427183b923bbb8b891f5',
 '4277e6652c111076825e',
 '427ac8f3b3a2b409c227',
 '427f2030a026affc640b',
 '42814152f947c75e0b72',
 '4282729df17d313fdc13',
 '4285056baa5e347d8936',
 '4289c2605d4cb7938baf',
 '428f2ba7db1032010bad',
 '42955e13e4682157acce',
 '42973eb261156d2a98fc',
 '429887e01d2545f92850',
 '429e7aff0a8ab2ab5c95',
 '429feb55d891be227846',
 '42a148f3e1d2e30fbb15',
 '42b01dfd2f1b5858eef5',
 '42bcf381780c1571cf09',
 '42be0004fd2d22d43a29',
 '42c00af0c6eb4b7872d7',
 '42c35e3952e6470a8c62',
 '42c631e96ffded909318',
 '42cd5b73f248656769d8',
 '42cf7bd97eab76af5013',
 '42d57155cd05bb30f1fc',
 '42d61f5499f781667e2a',
 '42d6690dc2aed63e33fc',
 '42d6804df0db64e5b080',
 '42e504eb44d2bc41d969',
 '42e69f7803629c07c127',
 '42e75274b273f274c0b5',
 '42eb0a006ebcc14049d1',
 '42f3464fa2a351cb5e41',
 '42f7ea88974644acafe8',
 '42fb4a919f155e49e9e6',
 '42fc12321df06f014ea9',
 '42fe82debb1c506ff9d5',
 '43078f41be2be16c14b7',
 '4307cfb0bd1a37634247',
 '4307e3baf546961bfcaa',
 '430876f4a612b5fa7ba1',
 '430ea115861009eceae7',
 '430f542d67f7a38f5415',
 '431154f01f71d67b2034',
 '43164118b406a8681036',
 '431b7899fe66b1cf0843',
 '431cef183850227fe10b',
 '431d93416501b30fcb00',
 '431e141719a8e61a5912',
 '431fada6179f87e0b137',
 '4326c117fa7d492bdec0',
 '4328ca058746f234b8e9',
 '432c7c00158908da4880',
 '432c9838cb653fc13b44',
 '432f3b59a881b60854b6',
 '43308f957c1c8a2de3ad',
 '4331fd0befc16bec77dd',
 '43345919565ff835b7d1',
 '433d26d48efdeeb1d4a7',
 '433fb6958bf210184ee1',
 '434aa3c7ff2170c97160',
 '434db9424acd283c3adf',
 '435103430c53b78dad59',
 '4352b4d6c4a25d6baef4',
 '4353908f6347edde0ca8',
 '43554a4f08c0e50b127f',
 '435685b10a3e72170fa1',
 '4357766d34b698d0fd51',
 '435b9cfc55fbf589965c',
 '435c591cfc9dd294c1c1',
 '435c6695bccd9b65dc23',
 '435ddc577d7827a8bff6',
 '43690cd9cfc519aabdeb',
 '436ae67af038b49e90aa',
 '436cb9d5391804bc4cd4',
 '436cc6f34ecb3f0d53cf',
 '43761edf3ab0c510cc11',
 '437822686fc14796d572',
 '437998e717b7acb4bb7d',
 '4379a4842e8b5c903bbd',
 '4379eba60687e5ad6c50',
 '437d6ea191a7e112fd93',
 '437e9f34deb2bb469a2a',
 '438056a6362cdb0e66ce',
 '4380ce9bdd0d735083f0',
 '438170bccabe4f8c0379',
 '4386e542126ae41f2afb',
 '4389c5537bdaa98bd998',
 '438a52c6043dbd271a4d',
 '438b43bc4ee9523bce04',
 '4390fc0132ba8d7e05e5',
 '4394ae1232f116bef757',
 '4395fa70aca2ee0d81d3',
 '4397b81b55b23a228ee9',
 '439c9aedcb2b972484b7',
 '439f8d5533296e1d1223',
 '43a068eecf87dc7b1f09',
 '43a7703106fc8dc06fd8',
 '43aec61be1f5dec8a637',
 '43b0a1e60c255a1a0eee',
 '43b26c595af7be2ffa11',
 '43b27d11ba6fede185ac',
 '43b467f01d85ec4b7b35',
 '43bb48c96edd9ccfb3f9',
 '43bd39a054ee8eba6e79',
 '43bd6e6f230d88a7cfc3',
 '43be2a47faee30a14a95',
 '43bf2aca0feefb71eb8b',
 '43c00895e27367c48ac9',
 '43c2d3b61c1a6a634c9f',
 '43c3c9c61bf3e5fb9bef',
 '43c4c81d1c8477d33e0c',
 '43d15850cf1632174bea',
 '43d3e5a669b40fed9092',
 '43d64e4e4b636acc3f4c',
 '43d803d54df1c710861f',
 '43d8eb3bf03c8ca4fb36',
 '43dbccfa77917641bf7d',
 '43de7d14f95cec2fba46',
 '43decfa576abe29b49bf',
 '43ee4c6c5685e5c3275b',
 '43f0b2ddc52d457aaa1d',
 '43f4cb4e782a0664201a',
 '43f50d63652f774f5702',
 '43f8ca5fafea74618730',
 '440906168e67fc643861',
 '44092355200c4788dfec',
 '4409faf969f626ad7f79',
 '440c4c1f77c4e3aafee7',
 '440dbe46c28bc867ff22',
 '4410f161a799b5dd7158',
 '441112a44832ad8ec797',
 '4415d078ee7582094218',
 '4417e66c12113c904a20',
 '4417fdf29adad6dc2789',
 '4425670c4fbe9de1159a',
 '442a0956ea0a31647a80',
 '442a4c85d9ee5e7306ae',
 '442ba17fb13fd031d157',
 '442ea3a3f2bbe7c138ef',
 '44309ba21b63cd1499d4',
 '4430c318b14550dd1b59',
 '44313954ca7244c659ad',
 '443161da2e77dce10897',
 '4436de32ede3893ae646',
 '44381461e731e62d46a5',
 '443d4948bcb62a0f6b66',
 '443daba86f591856446b',
 '4440fae4c092060256bb',
 '4441a46259ba485a873a',
 '44423d2da52fd5285da8',
 '444385afff975aa43e6e',
 '444540964988865c68d7',
 '444a95e6d7eee2d7f627',
 '444bf22a77d003bd1960',
 '4453fe296a5f15f9135d',
 '445add09aa72a1510727',
 '445af24ede9e5673a5e9',
 '445df4f858b117e27630',
 '44697fed9ef9565c32f8',
 '446b8882764a1c03b4de',
 '446bed10563b20e1e322',
 '446fd59adf132d94d627',
 '4473fc58af4f1b2e8b71',
 '447485560ae505d890cd',
 '4474ff5a6c00e1aa8ecd',
 '447529be17d42d284bec',
 '447a1fcb509cb0fd6340',
 '447c27d4a5f39fcdc4ca',
 '447db8230e928e6e0d75',
 '447e967d0b2b703b81c1',
 '4489368318be88f30f50',
 '4489ee434ee61a9f72ee',
 '4495740e93b5e813a6f4',
 '449a8a3620b36324e3db',
 '449c93811c69e175f703',
 '449d5b445ccc1f69eb4e',
 '44a1c522b234d0fe9aab',
 '44a47e5ad00c84fe6c0e',
 '44a776360737f068569c',
 '44a7c4d2a269839279ec',
 '44a979a31216bbc24137',
 '44abd8a18354a9442c2c',
 '44ae125e86f66758db4f',
 '44af633981c2ec856a42',
 '44b0f3054833ec051817',
 '44b1bf34c9df19273e2b',
 '44b554538ef5f70b33bd',
 '44b7359281844b10413e',
 '44bbedbfd5293c106570',
 '44c798f387107dde6c1e',
 '44c94873fdd7ac65b6b5',
 '44caacf1c28fa1c37fc2',
 '44cbf702a3f546093535',
 '44cce5d956740230a20a',
 '44cefcfda036b472a168',
 '44cf8474a8c6c2c73e02',
 '44d028602c01fa0d8477',
 '44d08b599bc5240d726e',
 '44d7e2e3340c72e5080d',
 '44d83709bac5e589921e',
 '44da3e87c526b04901ba',
 '44e491ad16518d3a558f',
 '44e585fb831dd0183262',
 '44e98d954478adea54d9',
 '44eb259a1f615e2cf249',
 '44ee4a55f371ea669594',
 '44fd574ec63cea1e35e6',
 '44ff74f572de74cd4239',
 '4503ed49962876ac81ba',
 '450aea7b81728ea4e388',
 '450c5b13358eafd2a528',
 '451040dbae28c5776e7c',
 '45178008b29bc420eeb3',
 '451b7db5c0fa375c9d7a',
 '451e92f0efa9944cf68c',
 '451ed2a4154233047269',
 '4524f95bc2f742fc8441',
 '45256e712bdafe570c93',
 '452a7d1347fd76e53615',
 '452df08bb72866fdf973',
 '4530ac1eb4d0d58c91c7',
 '4532747d07802fd79c74',
 '4534fedb22920adb6e3b',
 '4537f96b3df4e0d62bc7',
 '4538baf4826dadf60edd',
 '453a409c62ef2dc05d94',
 '454254add98be9724aa5',
 '4542e9ef3985bd1518d7',
 '454832dd9214fd9ee2f2',
 '454e7504cbd4d8a38e4b',
 '454f15f1ddc5437bb0e9',
 '45548b0134245b966663',
 '4555235069496a4ce814',
 '4555ef4beca343429b20',
 '45594a8951fafc5b687f',
 '455f02e15c23c8a3af1a',
 '4560565e40e2a7c34f96',
 '45690c003012497872a5',
 '456a8fdbf539a4eafb9f',
 '456cb340fdcfd859e43b',
 '456e8b0ac053de2e07cc',
 '4579d9f676d271511eaa',
 '457a011ccc24258f44bf',
 '457d68e28de903716082',
 '458912814059cf9afe9d',
 '45896d4515b2ca63e690',
 '4589d3221af2718a75b9',
 '458a66c215317bb4c095',
 '458d1dae3d6d236cd696',
 '458fce595bf70b9bdaeb',
 '4597c8540420dded56a1',
 '459ba2c5ef3b5df35b7c',
 '459d6806311d7c20182c',
 '459d9b398280037fa2b4',
 '45a2ae127e9db904856c',
 '45a72c19257cac74d668',
 '45a79a61880ca7c75331',
 '45ac3ce1f1013ac9a889',
 '45ae88539a9c550bfa5d',
 '45aece03eaac5018532e',
 '45b12ed28f7adcda17de',
 '45b2ef1d493b14c3810a',
 '45b375d1a20267af7fcd',
 '45b54acbeec91b457803',
 '45b7b601efc378e8d004',
 '45b7b9ce4324985cb7b5',
 '45b93ef193ea0cdb398a',
 '45bc53209fad58e5db90',
 '45bfac2e50636fb7736f',
 '45c2d3055185cb520711',
 '45c85feb78cefd67bf42',
 '45cfb6aa94729339576e',
 '45d0571e8912ea33680f',
 '45d6ae77628734b9c2ab',
 '45d8578816000aea2a37',
 '45dcee113cb6ef4d662e',
 '45dd392b20bf6a193b43',
 '45dd855dc6c684338127',
 '45def311a75340ee65ad',
 '45e060c8fa2b9dca3982',
 '45e12a974eba5ff7f811',
 '45e14939a53e9d623cb5',
 '45e76fcc709fc09455b2',
 '45e994dca09e63335611',
 '45ed8f6d9cec171d3e9f',
 '45efb84c5f618b61371a',
 '45f04a08389ca761c148',
 '45f17ac6e2e468a97c50',
 '45f4a69dab315f727543',
 '460173cff55872b8f125',
 '4605add3706437b9d14e',
 '460714e4406626fd993b',
 '460ac1e93e6acc078814',
 '460b0227f08264efe355',
 '461262f67efe724331ee',
 '461540f989ae183ccb16',
 '4615ddfc202dba7568a7',
 '461b0a7d7131681ee20d',
 '461b6db4d5581614651a',
 '461b8d2e784c5c0e528e',
 '462337f9d4b3840b75cc',
 '46284053da6f6f7fc17c',
 '462d06396c6468d4c20f',
 '463037b9f74626205aba',
 '463341da381fc364f1f5',
 '46351a6d046774218c3e',
 '4635742a0f88323ffc72',
 '46367fd5eb2207b6df5e',
 '4637f998f4011f3144dd',
 '463cc1bd0637a9e2972c',
 '463e3d37fd8e9366f38f',
 '46405de336a1eef30ca3',
 '4646048da91536cf3592',
 '4647441a8b577577d905',
 '464a431891f29e3b02a6',
 '464b0c4929f2c5db5e55',
 '46503182ef820a80ac2e',
 '4651d2486b83e0188496',
 '465445f7fcea7a0b56be',
 '4654628551e3c481babd',
 '465480cd59623cc8e649',
 '4655da6a0585c92e4ae5',
 '466097471c96b188056e',
 '4662408f3d33d2cb9430',
 '4663606f940c3ffed57e',
 '4666a68ba676e0f37cb9',
 '466825ec37c8a7282a70',
 '4669c8e71059a9fb52aa',
 '466af1b7998b36b1ee7f',
 '4676f1e4b60dc2d2fa51',
 '4679f9f079b0aab71f0c',
 '467dccedebaaf8e652ed',
 '467f634f6d540c4671ca',
 '46857017ed8213c9e789',
 '468a8afd9cd9adf15dce',
 '468b22fa3979f9a040be',
 '468ee4f3493490132177',
 '468f2fb60e9f255aec81',
 '4694c6707f3e0c821e42',
 '469e3485870f3fd6c372',
 '46a29b13d7136e725c8a',
 '46a94b4af790b7328414',
 '46aa1814b820b3d5eaeb',
 '46acceb287df88b02ba8',
 '46acd7eb2a14607c4bd6',
 '46ae3ca8855ca2795dbe',
 '46af1c12a884d255b3d3',
 '46b1191848a8a672815c',
 '46b4f89bed7236ed9ca3',
 '46b6d19e440ef75aaf47',
 '46c0d620d5cd20a50bed',
 '46c43a8e72ac869829b3',
 '46c4d360470a3586824c',
 '46c5ce65c3f05c7b998c',
 '46c7f500b9c1e4662a43',
 '46c885568afa02d0973c',
 '46cb2d7fd802d2949d46',
 '46cb50bffc82e7fc252e',
 '46cc452b7be5d2d89bb7',
 '46ccaabf9dc3b1d121d8',
 '46ccbf3f6d0ad95fa962',
 '46d2c8ee2eb5e6908c44',
 '46d39eba2063c1bd033a',
 '46daa639773efd55c7ee',
 '46dade722c9069389442',
 '46dc0031fc975163e253',
 '46de5f58483968e784da',
 '46e064b602afdfd3db6a',
 '46e25425813d445d4e7e',
 '46e459b3468c5a8f01df',
 '46e5118f30800e466d38',
 '46e65eb2c0b548f1df9d',
 '46e7be68860d0ca914ce',
 '46e8a06207034086baae',
 '46ef5947638d7028127e',
 '46f21e69e00af4b214d1',
 '46f87d143d860ac719ec',
 '46f8cd15815f24393a31',
 '46f8d02097cebd8dce00',
 '46fb04682a5cf8019404',
 '46fba0e852f2cf72e90f',
 '46fc6334daf74b38a3e0',
 '46fe82660b896db82346',
 '46ffd8a6b8da968d70de',
 '47015b68e8ebbbb2ef6a',
 '4706487900916ebcc73f',
 '47066ec1ba40e033bd12',
 '4706fdcbb926e5628c4f',
 '4708420673b1fda87e01',
 '4709c2ea8b6289ab6b15',
 '470ab3567cef6c5fa1fa',
 '470daa7f72b628c50c74',
 '4716800cd4b909d3879d',
 '4716af435fe3f2968995',
 '471d6a92996da92d48c2',
 '47202aa22f9d1de6a32b',
 '47210d40a32c2678180c',
 '47226b95ffc3a542cbb9',
 '47232cb27ace982d8037',
 '4729b1f5a4705c92c0b5',
 '472a8df72249f9a67e92',
 '472dc47df1707dc518d7',
 '472ec2340d9915db4b5c',
 '47301ae7752e2b7d56db',
 '4733249eba60140c2720',
 '473aaa3062daef9ee870',
 '473f26b49124d906363a',
 '4740853bb997b81e6a13',
 '474629c0bbab74e9aa3a',
 '474669ba73d0753ab7f5',
 '474990a85b65ebe2f67a',
 '474a21d89873a12cb113',
 '47507b1ead54772c6c36',
 '4750ab3c4222f8f5f1b9',
 '475c5595884e5468618e',
 '476270603d8903270128',
 '4765e85841cb5ad2a7e9',
 '476dfe2e273775953834',
 '47756ea82f54036055fa',
 '477675bc3d3f05a3a004',
 '4777890347e7248fbbce',
 '47787c83a3450f6f0d16',
 '477907017ff7458bed79',
 '477a0bfd066bf04ff2ac',
 '477bacb0dee7702a98c9',
 '478080615ecff1c362ec',
 '4780941cfa3e7a1c5e74',
 '4782705948eff10d4fdf',
 '4788f05fbf72ac381b4a',
 '47902ab9104e899a700f',
 '479153c43c64c7c82185',
 '479983bf6c388d60a23b',
 '479de98dac419a9b61b8',
 '47a2991c5a7a784cfdd5',
 '47a46d44ccd658caee5f',
 '47a555bbe5e8d371ec74',
 '47a581fdeebda3b4ae42',
 '47a6d2abb082348df333',
 '47aa44a499b72019a1d8',
 '47aa4ec69ba151ed7f3e',
 '47ac5c790ae2a08ab250',
 '47ad134f85bb966a2137',
 '47ad9ca42985334a69aa',
 '47ada39ea9aa1e23f5c7',
 '47b367d825cff25847d2',
 '47b3fa8605f8aad6f92a',
 '47b599737974973f4d1d',
 '47b5c043e792e387928b',
 '47b5f74f573d1a305871',
 '47b65bb0fb63ba1b0884',
 '47b688704074b76e5593',
 '47b9994f48fbb94bfeb9',
 '47b9a92599627331c08b',
 '47b9feeb5ba4995d182a',
 '47bdfb7f7b9bbdc2fdd0',
 '47bf530a848bab2e8c07',
 '47bff41bddea81e8abd4',
 '47c81c155ee8b1d25064',
 '47cd5145eb13c78643b9',
 '47ce4874563517067b7c',
 '47d0b057b24c82e230b8',
 '47d241477b77e657f9d4',
 '47d731b3339abf1d04bf',
 '47d751505bb520859131',
 '47dfb8220ef7a826de06',
 '47e3883ae1852f2f7d09',
 '47e7ad6e4a74bacd5ddc',
 '47f0c619c0f6b9f378d7',
 '47f1b2bc506d3ce5d706',
 '47f34aeda80fb5156a7c',
 '47f36a55c946b5bf1044',
 '47f54a6064cb4d496545',
 '47f749ba59f5a5173c11',
 '47fd0e1af330863a6683',
 '48004d567958315ed8cb',
 '4800b34397b67556a9ba',
 '48043c9b421d775ec42b',
 '48060f4c825abe50ef3c',
 '4808c517c698c59fa6d9',
 '4809fcc5321fccf646ff',
 '480bc67a6dc429b66db0',
 '480bdf68581b619fe1fb',
 '480e18ab43584f1a2c74',
 '48150c5b2606d1fca053',
 '481613da9460a48aee60',
 '4818c8b7da9f5465bf5c',
 '4819ae2689939bba37e2',
 '481a26ff3a44ab990915',
 '482609881a8f97e49752',
 '48273872330df8159c9b',
 '483645777a7ac6ddcb0c',
 '483723f3de7eacc6e0c4',
 '483f179d212c7c0aa108',
 '4844d47503bdb7177032',
 '48488f155ea293dc8138',
 '4848bc6a1778215830b2',
 '484920cd1901ea549c93',
 '484a4db6eff225e36035',
 '484cabd6edb7da2526da',
 '484fa178762764749a39',
 '484fa6580cb195beadf2',
 '485071ffd1d0915df2d2',
 '485269ce4c58f36c4ebc',
 '4857934cd2340e76493a',
 '4857aecc778eb1330615',
 '485dd2a0b089aae47f4f',
 '48604f4bc698c534bd56',
 '48642d8cdf029a8c5327',
 '48658f1e4513120fb0b1',
 '4866ec0dc99d02eda4e6',
 '4869098c5999c159ea74',
 '486b54633c3170bd58ee',
 '4870b53dbd0c7499501a',
 '48786afd842514524e47',
 '487a356c2f5ba70530db',
 '487b6b7248c387c61d84',
 '487b77dfe8eb77ec682e',
 '487e1cf6ab6268cccab9',
 '488319f469e7881b1b75',
 '48841b844b576f85dc9b',
 '48846684c784a3c580ee',
 '4886401b240d86b2c578',
 '4886b58f7becd5914421',
 '488c421d76a09cb914e9',
 '488dabb86445e4e9ac6a',
 '48938050c1740ba5e89a',
 '489549c963882e0fb5f4',
 '489ae69e2c74d0a717f6',
 '489b8093964f4b21812d',
 '48a2c09408347d51cf8f',
 '48a3e589d3df0fc745a6',
 '48a45097dd25106cbb36',
 '48adbad4e6e24d32d579',
 '48b24709e98a2832e216',
 '48b67ab70dd933bf1490',
 '48b6fbc083b20202956b',
 '48b73b41f9d899aff267',
 '48b77fd57136875178e6',
 '48b9099cf9359db9f411',
 '48bde684b1792cd0326d',
 '48c089d02fdf6b24e3ee',
 '48c3d187c99eb71361b2',
 '48c3ddaf6106fcbaa4b1',
 '48c57da1d4edb120b297',
 '48c57df8973eb47238ff',
 '48cd4e5ff087ad02eec5',
 '48cf9e6320a81a255745',
 '48d18ce9d581bae0662c',
 '48d19c211c4c9089ffff',
 '48d2c06fed3d6f349b67',
 '48d6e1e698e54129b387',
 '48d7b99ee4d8ad506af0',
 '48d8733842da8b4664b5',
 '48d8aa7d27ff10c75f0b',
 '48d92f2072e5e1d03694',
 '48da52d08d3a20b2f610',
 '48dd3ed211049a489d44',
 '48de1ee7ca1c4e64c782',
 '48df86afd22d37392dde',
 '48e486b524cc596bd851',
 '48e6402e9d840c2dfc2c',
 '48eb0b5df1d26cb06742',
 '48eb4ae656b80b69f776',
 '48f2c71575d1434d5f99',
 '48f3e24b72a181b207cf',
 '48f5fef2222f8fe4df8b',
 '48f7068f28e9891e06b9',
 '48f72b0807236207b0d0',
 '48f75346fa85c9e3e50e',
 '48fcd1bd1837bf3b2758',
 '48fd66b0bfc97173ebd5',
 '490530cc39a455ea2dfe',
 '4905c8db865ff2b2c2cb',
 '4906a1b643ff80df384e',
 '490788681467f9e21c0f',
 '490dde2e078232da56ac',
 '491021db7fc2a023d2d4',
 '4910c7a2ab51188281c5',
 '49113225cc0e0f78d7a3',
 '49169648f84111285cae',
 '4916a9d67c9eb38e3fbb',
 '49170d180625f8b5d061',
 '491dbed8ca42a7821484',
 '491ed07de146dab31f51',
 '49210a8bdb7eff410b5d',
 '49213f7ce79b4bfd0fed',
 '492c40728fa64296a8f8',
 '492d289b815a731e7108',
 '492e7ac375ad62fd37c0',
 '49315633269e5b9eec60',
 '49334ba90c3dce49e67e',
 '4937a3bcff184c6095ed',
 '493b585e0768c89963ab',
 '493c8824fb564f80c9bd',
 '493d2bb4d9286b7e7ed9',
 '493d4213a0c136d627c0',
 '493fa04801b6246b98ea',
 '49407869e672ba81e70a',
 '4942f8ced31cc06ab9be',
 '4945c82d51d544d8b901',
 '494656c03f723eea7949',
 '494887335952194d7fd0',
 '494fac8ef28c34b05db5',
 '4954575f438ab343539a',
 '49576df7e6f17f62e859',
 '4957bf3729e47fa705c6',
 '4958fbc58b9cdfc56268',
 '495f5870e8698e7ad910',
 '4962a77710d24823170d',
 '4962cf216b5b975299e4',
 '49636ff4114e7eee92ed',
 '496376a1d8ca903141f3',
 '496474b184696aa20693',
 '496845c7aa7a03b1fda5',
 '496a5643aa1d07c65326',
 '496acbed1b69f72fe880',
 '496d1f56210e1d9ef178',
 '4971867853db950a5172',
 '4973db45eda980ed5a72',
 '497637a751cea0c9666d',
 '49770889d3f778946338',
 '497a875fb155954a1ccc',
 '497aa77ca2841448689b',
 '497cfa81b4fef280a243',
 '49803513c2942c4aa567',
 '498312c373a0aef9d329',
 '49892c4c5ec76929289e',
 '49897993dec859d5339f',
 '498a7257d238dc0e55d2',
 '498fb30a62a73a735a2a',
 '4990f8f41f27d679e0af',
 '499594194cbb7d707a9e',
 '49959565f7c7088e5d56',
 '4997f03357a26cde7ad2',
 '4998cadd74042a133d1e',
 '499c283129b814462bd0',
 '499c5027400d66372688',
 '49a7421a5ece0d9b4f92',
 '49a8521a9679bf78e1cf',
 '49a8c73cf586946df2d4',
 '49ae81444e6d2d91b260',
 '49afebf01af54c5c5f85',
 '49b124e307d3ac06e3fd',
 '49b5f0829779bc1e44d5',
 '49b9756140cd8a3566df',
 '49bdab852ba4844ef1cd',
 '49c3a0662aa85514ad57',
 '49c5389a0bf059fca158',
 '49ca89dd9028178e7d8f',
 '49cb936c11648941b88f',
 '49cf0adf364f08fbfcc4',
 '49d0aa1f2dffb4b40e96',
 '49d54113fff28a5cf1de',
 '49d5a0a4ec5bd321a9e7',
 '49dd06fcb942393fc3e6',
 '49dd209760fb93648ae0',
 '49df98aad63c782a734c',
 '49e0d8ab1807ef235bc6',
 '49e589757ff6d198e748',
 '49e98f24474dfc6d8e7a',
 '49eb629836dfebe92535',
 '49ebd1913966b2386e76',
 '49f1df7580f29c07f975',
 '49f40cd888638a43406b',
 '49f6f1cb65c2ad8e1f88',
 '49f7cd5f562139c7fca4',
 '49f8ba4bf7611ef17a4a',
 '49fcc5eb862b30a8a7a0',
 '4a00bceafb420f4966f5',
 '4a01a37795a646b02ab5',
 '4a027d6d87ba437e4418',
 '4a03a53af917199cdda3',
 '4a06bd8a85d688c068f7',
 '4a0b0c9a298312e9a0e2',
 '4a0ea6bfe7d0ebcc8fe3',
 '4a119ac132975fc21d20',
 '4a12555bf5500cdc4d7f',
 '4a14953292f1d4ed0520',
 '4a179c422961c7813a14',
 '4a188e8cd42a71b98618',
 '4a20f093260a745777b8',
 '4a21525abd9e88bf652f',
 '4a2a622ad7b2943a1e48',
 '4a2e2afbfd33d9142911',
 '4a30020e467ebda8e265',
 '4a307db59dbd7379242e',
 '4a31c54889f90455d099',
 '4a34cff9d7f057c266c3',
 '4a3b190bafb2452f4bba',
 '4a3bb833fc1008117b89',
 '4a45e199b34b922806b0',
 '4a4c240d6d49101a7f0f',
 '4a4e170aaa8a68ab7b53',
 '4a5cc4fa648460845347',
 '4a5e50906c65afb61849',
 '4a60224f12b830f3ef36',
 '4a60cb26dcb6b97a653d',
 '4a668beda393921e7b86',
 '4a6b35f116cdb551974c',
 '4a6dffdd6dd6bd41ba4b',
 '4a7853735a4b25663fd6',
 '4a790f4197231c0755b9',
 '4a7c07986d52dc3a7625',
 '4a8005c42d1b50d3363d',
 '4a82bae1a95b83c9b3e5',
 '4a846866e74b9378badf',
 '4a85d0bdce9cbdf865a7',
 '4a87a4247e875d02c1a6',
 '4a87d8f6d3b828bf85bd',
 '4a8d79456592613f727f',
 '4a954ff64b17bd462659',
 '4a966d36e7b02cca37af',
 '4a985a916e0470e62127',
 '4a9be727391a6ece177b',
 '4a9e21337e17ac12d34a',
 '4a9e32f33b9d37608f7a',
 '4a9fe9ee71c50881354a',
 '4aa3452eb5611de07e28',
 '4aa35805cb2d0586c7dc',
 '4aa9b7c0490175ddde79',
 '4aaafed9f2dab7852ebc',
 '4aad190cd6da8656c24a',
 '4ab12765e2bd014f314f',
 '4ab20f80fc72d9c9776d',
 '4ab3309acf62b47a721f',
 '4ab47b0f80d543ef0bc8',
 '4ab5ec2d5740e7623d13',
 '4ab7f3d68fa2bdb28030',
 '4abc6eb5bc250ccffc35',
 '4abf8a1a186e160da827',
 '4ac2bd65d8642951b7d2',
 '4ac54957fa2297082448',
 '4ac63d4bff0f8bb97382',
 '4acc35254fcacafc174d',
 '4accc931ff5feaec08f3',
 '4adc7928052cb536b449',
 '4adcabdb425ae501ffb6',
 '4ae1c563b75bc67f9601',
 '4ae41af90b56bd77db56',
 '4ae4f0a512bc2cb45613',
 '4aea4eb54c9c3cb50b5f',
 '4aee85eddbc1e5dddfea',
 '4aeee8e3d53fa3fd9020',
 '4aef5d9ad6341676a372',
 '4aefb0619cc18eb154df',
 '4af5ad7228257ed657db',
 '4afc57ae90181c4736a0',
 '4afc65482944e55f2c7c',
 '4afc9252c803eab58c83',
 '4afcf4c6eeb38e49d3ec',
 '4afdd8fa954e818381b6',
 '4afe9c2c1e594d270aa7',
 '4aff15ab1900477685ea',
 '4aff91205cf34ab3271d',
 '4affe86e43fc2e6ba084',
 '4b007a58808f9325cff5',
 '4b02cb9611e97a9fd471',
 '4b02fed5a39ed4d6bb38',
 '4b03ab6c5e29fd82ff01',
 '4b0dcf8eb40e4f2dfb5d',
 '4b0e78eff9986e9b2190',
 '4b10aaf649853f68f1d6',
 '4b11300090eb53fdf18a',
 '4b14ec73fbc2cbf66486',
 '4b1e9178fcfc1ea1b3f5',
 '4b1f06bcafc3634fb5dd',
 '4b1f7aeb04e5c5a08038',
 '4b20e89bf94b5497a818',
 '4b2b24f9ab1e2ef491e1',
 '4b2d4f4d9b178ace0cac',
 '4b2f86e745710770fbf2',
 '4b30602297abff7c678e',
 '4b321b4485a89e6f73d5',
 '4b375b7481fa59006ca9',
 '4b3784a3084ad6ea2a8c',
 '4b398428c98596f512c1',
 '4b3a11dc59fc5d39d251',
 '4b3a23d21ae5bc800e4d',
 '4b3af2a4291a5ba4f8b1',
 '4b4861aa95789473f40e',
 '4b49c3181700ec781c10',
 '4b4b8b6cfada98d3041e',
 '4b4d1f0266457a1a4d56',
 '4b4e82c56ebec363d460',
 '4b521c9c9200841da812',
 '4b52b72a12c0dd611ffc',
 '4b558bee1f8c09749246',
 '4b57808bc9cc7cf25adc',
 '4b5f391924f71d066302',
 '4b60b5879571f59c9a1e',
 '4b62fea2a1a081a4afcd',
 '4b6b7169d1ddbf3af75a',
 '4b6dd12a727954cbccf1',
 '4b7387c79769597a2589',
 '4b77a88f93b9845c4cd7',
 '4b794dff45c10f05cffe',
 '4b7aa1ab2375458dc186']

# %% [markdown]
# 8

# %%
qids_8=['4b7e849c93d24d5e7e8b',
 '4b81e3d1b1fc1ec4ebdc',
 '4b8275ac4ec92f935c82',
 '4b86d16f9812965850af',
 '4b878064bcc859888c93',
 '4b87b0f5a3f065e612cf',
 '4b91c0050f12d74dec4b',
 '4b92a90453ca04239918',
 '4b98d7b3df64e7dd18dd',
 '4b99b4a303b5a4c6f53d',
 '4b9fa89169ce97b8b814',
 '4ba02e19af0348668ec4',
 '4ba0e1f8fb9adfcb7026',
 '4ba5e26dbe7aca8a6ab1',
 '4ba7ea1c22ca303b13af',
 '4bb1ca108c6e96ede630',
 '4bb20d00026e5e6a7d39',
 '4bb2e18f1766824f3c06',
 '4bb5e94136954f2cd220',
 '4bb6869f50f9821cefc3',
 '4bb8975bbc3322f744a4',
 '4bbbf282c2f7ed737802',
 '4bbd1a6246bbfa402855',
 '4bc0b3b3750a29b38b5a',
 '4bc11930d75bfb850e9b',
 '4bc1ec803b13e03ffc03',
 '4bc2027bab0279012aa4',
 '4bc3495698ddedf5b55c',
 '4bc36ec9230c81fa8009',
 '4bc787f0bbf2220ee9a4',
 '4bc92827eb8d7e300bd0',
 '4bca9e2e0f975fa211fc',
 '4bcaa83adf26e277b350',
 '4bcf657adc798cf5c865',
 '4bd1582cc628e7ed4804',
 '4bd2ee84edfe85485e00',
 '4bd32d6014b53512810b',
 '4bd7dc592c007a3974f4',
 '4bd880e2503c7a01287f',
 '4bda4de478d41e757046',
 '4bdedc5b6cc2c11f376f',
 '4be2b0a99879494d4ba6',
 '4be408c0ec09afd89898',
 '4be7689f6f29a03042bb',
 '4be7ca6f1f258b3ad9d0',
 '4be7f2596605c1f77122',
 '4be929b42d976c00dbb3',
 '4bea9c240d108220048b',
 '4beb97f95b7a6462ea19',
 '4bebd0f46959694ea56c',
 '4bf36e6a5b7306ef5fe4',
 '4bf5278af6e46464eff2',
 '4bf5c99586d17af26b13',
 '4bf895c2f11ea7fca21a',
 '4bf9aab17bd08ec11c3f',
 '4bfc3bc4185af363c958',
 '4bff7f445225f10ac68c',
 '4c04f1d00f1dd6324336',
 '4c09cfca37b84f0e3e3b',
 '4c09ed018c043222034c',
 '4c0b7ab70d7a2c65b1ee',
 '4c0d7bb1c88a3f2ee05b',
 '4c137619b6268a6f7cea',
 '4c1400c7da4d30ce243f',
 '4c15a48eefa54374f61f',
 '4c16c38d598c0d442b10',
 '4c1765a69199ddb4385f',
 '4c1990f4127d70ac6031',
 '4c1a92bd414533439ed0',
 '4c1f6e089111659d4338',
 '4c23feb2f42c60b34cd5',
 '4c26c55491b8b1950104',
 '4c2742dd7d8d2edf4446',
 '4c27c4cdc1fce69fa519',
 '4c2bbc78180d9f3dd7af',
 '4c2c1e3e8716fda5d160',
 '4c2d143b8885fe8055bf',
 '4c3210d3d77f13e26638',
 '4c3d638fc4e8c4171f0c',
 '4c411ecdf6a49d9f7e8b',
 '4c49ae2df2a48098aa92',
 '4c4a7b3234a5a05737d5',
 '4c4aaa0460bcb27288fa',
 '4c4f1a0cae0370d40a11',
 '4c5084578af4890360e8',
 '4c5eb6e3f461274c19f7',
 '4c64c58c47d4348978a8',
 '4c65af464a8514c82a0f',
 '4c665ec3e41f4b1ea85e',
 '4c70e2a11dc8e6c92c62',
 '4c72078e64b09fe90f39',
 '4c74ac47c32a8a87ae6a',
 '4c75518a1550b3f0c1df',
 '4c7e86ae062a56dbd441',
 '4c803430d477d665e9e2',
 '4c80f1b3dfcb60279d19',
 '4c82bd8d474ef366bfc1',
 '4c83da739a484f97d13e',
 '4c84dfdc05774ce029ab',
 '4c85047c0e8632b0820d',
 '4c863dc96926fb6af87f',
 '4c876d45d0630dfa430e',
 '4c8ad9a62d72b9ef5a18',
 '4c8b00d17018706b4220',
 '4c8c71a4abb005aa7489',
 '4c8cc6835fc5b2db8315',
 '4c8ce9fa3f19672f46a6',
 '4c8f4e1668561d841bb6',
 '4c9061e07b710420196c',
 '4c909be86c9fa7c539a5',
 '4c96ae2a7f835777d9c6',
 '4c9e2d7cb4247eb2035b',
 '4ca410441179014f899b',
 '4ca6d4adf9d88612b839',
 '4caa682c3842ffc10747',
 '4caaf0368cd3a1755e3c',
 '4caee1908df7bbcd97c8',
 '4cb48192ec9000f4e1b6',
 '4cb9f7e52b63704cecb2',
 '4cc173257ffaa599acc4',
 '4cc3300765671060d44c',
 '4cc4213e418caf5427ef',
 '4cc914e0c682097a948e',
 '4cce3f3fb6c7efbc0790',
 '4cd63006e47199cce3f0',
 '4cd90bfd16e88ea5a869',
 '4cdfae50150d45ffe4e8',
 '4ce06532cacdf3ef8315',
 '4ce1364f5fd5931467e0',
 '4ce280aa6aa95136d437',
 '4ce2bbd668b606b16764',
 '4ce4ee405014f2c01e21',
 '4ceafe9b85b4899504af',
 '4ceb8720d284e3dc2850',
 '4cecb8455974a5987f2d',
 '4cede5bd3cd0779f5225',
 '4cf8bd25cf39436d07c8',
 '4cfc38c7f8ef4ba343b4',
 '4d002fbb2b3a1a155bab',
 '4d003f0cf3201cb387c9',
 '4d037fe48be07e95d890',
 '4d06a3e8ca21f92f7d40',
 '4d0b75ba1e0e0bc53ffc',
 '4d0b9e7ed6e660a2b2bb',
 '4d0c02d90102bd67767d',
 '4d0e7446839565cb4c83',
 '4d11fc51c97b9b5b6f23',
 '4d17b7610a4a0c2e249c',
 '4d1867b1796e3687b034',
 '4d1b058b33bca274f750',
 '4d2461bdf825d8c923c4',
 '4d29f40dd8895e553c43',
 '4d2d987a775159896fe6',
 '4d3d588c01eeacc54875',
 '4d3dd507ef57a0271936',
 '4d40e51e9726099e78cb',
 '4d483993862f7d25c7dd',
 '4d4a715c2e218e3edc2f',
 '4d4b9d681d0f3faeb8fe',
 '4d4d95871cf330e657b4',
 '4d500f9b38936922036c',
 '4d5063e53b9042eaa16e',
 '4d5536797382a2074879',
 '4d57057b91dff492cbab',
 '4d5bcc5166e631f607e2',
 '4d6203fea15e4109d90a',
 '4d62f11c53ca6d932ad7',
 '4d6b7e887924339ac276',
 '4d6b7eb57e017dd54ba1',
 '4d6c259d58525e13702b',
 '4d731efa45fdc2099792',
 '4d740d237f83674dfb33',
 '4d79a87d8a08e42bb215',
 '4d7c44e541c9cca87622',
 '4d8cf9926486e5b42b4d',
 '4d8f5bc47d51e1531cdb',
 '4d91ca7a4e4f9a15020d',
 '4d9715908b5f0da0d870',
 '4d9be610e588331ecd94',
 '4d9d370591bad16e62b4',
 '4da587d833bf8c254319',
 '4da5b1e0ad247ea7c57a',
 '4da676e59d9d6234095c',
 '4dabac6cca691e8f1038',
 '4dacbbf65fd1c3d6352f',
 '4db14c56e68c4776ea5c',
 '4db1d8f10c4b7eb324b0',
 '4db5c2d7aad80ac09ff0',
 '4db6da773963d8eb0d12',
 '4dbbb110f55d818cea94',
 '4dbd005748372006abf8',
 '4dc1cbb4799c1c915c62',
 '4dc2602b77ed5bf4e9c2',
 '4dc402530540e080733a',
 '4dc48d8acacd13b426bb',
 '4dc7d229dc1606ef9444',
 '4dcd1096631aea3b1a45',
 '4dcf51b7d6a8eb731279',
 '4dd3eae3284ae09026f8',
 '4ddd2dc877427d0d0cb9',
 '4ddf66d11dfa87ea02af',
 '4ddf7d2589bca1545ae6',
 '4de14126b9e4211f8883',
 '4de3bd7f07bd7d0ee105',
 '4de8189769c26f1bc4da',
 '4dea0cf357b86d41623c',
 '4dea79486376e2f3cdf1',
 '4df048547c7f6b364d27',
 '4df4df385fd811c5abd0',
 '4df8b2ada43dc397ec0d',
 '4df99bb11311553fa594',
 '4dfb7344bd8fbaecdbce',
 '4dfca4446cc8bc0a0a92',
 '4dfce487e494e0f386ff',
 '4e05527362987cd5bbfe',
 '4e0766b54a32178cb8ac',
 '4e0de8b4a93e4f673372',
 '4e10d6329ff62d24a1f3',
 '4e1157e3aacf9276045e',
 '4e11c58b90fba3e4b206',
 '4e12013d35bba586fb03',
 '4e13078532e913430472',
 '4e1488a9426a963e44b9',
 '4e19357a210f92d5babe',
 '4e2110efa57d5778a40b',
 '4e225640e62faa2a4ee7',
 '4e2a11a4c68a82614868',
 '4e2c0d8e381c16c09372',
 '4e2d6a46b5d9832f90e8',
 '4e2db7f183b9832b569a',
 '4e2eb5e12e6bd8e95e01',
 '4e2feb1bfad721afc7bd',
 '4e30dfcc9ceb9505396c',
 '4e32dfd7c3ac82604b8f',
 '4e330f0f2a1e5875b5f9',
 '4e37a87cb0a31eb4c950',
 '4e3afd07d94a90ac9a66',
 '4e3ca61d6c52bd107b8f',
 '4e400e537470454116ed',
 '4e41e7b35bf69ca3c8ee',
 '4e52eef769b3bb61470f',
 '4e54ca9517f9d0c4a82c',
 '4e5e06a3e0f21e47d3cd',
 '4e5e8a6a56ffea2593d2',
 '4e5fee5b9256f9325fa5',
 '4e6067405d8cdd26f596',
 '4e62839ee20235295c81',
 '4e62d55839352d6926a4',
 '4e633c66e934defde9ce',
 '4e6423c7764ca14bf0d3',
 '4e68b1fa6cdf4f338431',
 '4e6a6a73f3bc343afdce',
 '4e6b1837506923e810f6',
 '4e6c592e3ae9168e5671',
 '4e71abf0700b7af8d12f',
 '4e72f70c6c7540414629',
 '4e74c91a25be9ac81f13',
 '4e76750ed74257d1f1bd',
 '4e7709c5d2557f9803de',
 '4e7710845dd278df96a1',
 '4e7842061b29142e0175',
 '4e79428bf98c76819db0',
 '4e7f59769e1c91a8c2b2',
 '4e7fda41ac5df467e55a',
 '4e8ab535d977578ab5d0',
 '4e8f45a5fddc69aa99b6',
 '4e8fea57a59b7ef03932',
 '4e90f44309b81078c572',
 '4e95121f4d86807f7440',
 '4e96fc878098a3ea551d',
 '4e98baceea54a6921138',
 '4e9a619e621193fc1b39',
 '4e9afbc5995072cfe41e',
 '4e9b6906b63b3db1eb34',
 '4e9c54eb1c96834586cd',
 '4e9d37840c80759276c6',
 '4e9e70093823fbe8b639',
 '4eadb769b7babffc79d7',
 '4eadc28a1b9487bb7930',
 '4eaeabfcbe5a6f4a9fac',
 '4eb0f8282a97fd91fd3b',
 '4eb19452ecf91301c820',
 '4eb21381e5de507b446d',
 '4eb4d5abc8b9cbbac69a',
 '4eb9580b83adadd90439',
 '4eba74b351b26c1b0c0a',
 '4ec09ba5facb1650ef7b',
 '4ec09d97ce2508e1656a',
 '4ec223a3bea361d40e34',
 '4ec382c0383d3d8a2ff4',
 '4ec92fe1e3efd2b91cfc',
 '4ed5ac03ce6c6bba1a29',
 '4ed5f16ba11485789bda',
 '4ed8320fcefda3669a04',
 '4edc5c1327e49c8bafd4',
 '4edd8f7c30f3ec8ab3f1',
 '4ee17bb74a540e46bfa2',
 '4ee22cd9709404fbecdd',
 '4eefb0840832af63a232',
 '4ef0a5f225177d3993c4',
 '4ef0ad8417f03468198e',
 '4ef0edbf2a522a028e50',
 '4ef3def07509f95e9036',
 '4ef45a45aa0cb758906d',
 '4ef7bf16e39c21433612',
 '4ef9019b944a62d537f5',
 '4ef953fd89ed69750fe5',
 '4ef9fa0b264f53f7e547',
 '4efd50063442d2154aa9',
 '4f015460e05b57998888',
 '4f0184c085dd95f593c3',
 '4f059c62e0ad59fa3cc1',
 '4f096e2aad03a9e61544',
 '4f0d2459af1051976754',
 '4f0f22ef1a148b4cdda7',
 '4f0fa64dd92eeb7941ad',
 '4f1498f43ea9e2ae5ff6',
 '4f1802f4a8a98f2e69a5',
 '4f1bfc78bc20b21419c3',
 '4f1e32c8908fecb60847',
 '4f1ec7c1ad3d9fa37e3b',
 '4f1f9bcb6a8da9bb4fdf',
 '4f2b1034b0fbb206b7cd',
 '4f2bba7a71486c54bb18',
 '4f2eabffac0b49a79bec',
 '4f2f751b4f6a5712276c',
 '4f34c2f491486da92748',
 '4f3614a21934127373aa',
 '4f3aa0b6d9a6d187702b',
 '4f3ab3aa64badc512c34',
 '4f3df7f0e3f26c48fe17',
 '4f3eebf1924370af6660',
 '4f3fe98442333dbf4462',
 '4f40462562a8c534b690',
 '4f41b48f0bea6bdb3488',
 '4f426604979764cb590d',
 '4f464ade45b1fd5ef945',
 '4f4ddd6113eac22a2170',
 '4f4e53b7593f119c7042',
 '4f516ff340a590e588c6',
 '4f55d53e41467968ff86',
 '4f562b2c85e09a485175',
 '4f5f1f30bb466aa3d770',
 '4f60e742f065573dc990',
 '4f61809f83fc0a736068',
 '4f63a6e82192fca314a9',
 '4f6986bf4f8a58d8bfb8',
 '4f699ab99e5cf676b84f',
 '4f6b144538a822613722',
 '4f6e09e7a649ca79dd22',
 '4f6e53f6b0b97b3f297d',
 '4f71e5fe8a597cd72b75',
 '4f7b0a7d11bac90380ed',
 '4f7eff584da38a4c4fdf',
 '4f841242132d2b2feb90',
 '4f87d36368b946e6a9e7',
 '4f88daad70a6c14d809d',
 '4f8aa2a3cfc18e8b91ae',
 '4f8bc809f907f6ddfb1a',
 '4f8e99844b4a32c7e082',
 '4f910f527cb91713d41a',
 '4f954df2ebe2d1eb1c14',
 '4f96bf437594b62dd978',
 '4f9a9b22c3f308ea98ad',
 '4f9b41d7fed2de7b663e',
 '4f9e6bf474c8276cda1e',
 '4f9fb42435ec7cb05062',
 '4f9fba4354c3c1ccae0d',
 '4fb2360da99f2a72fb35',
 '4fb4acfef254bf05ce0e',
 '4fb8a4c0776dd799618b',
 '4fbc809a0f5bcc65463b',
 '4fbce2cdffd618031822',
 '4fbdcf78451eaa2e57c2',
 '4fbdd88ba5028825b931',
 '4fbe23ab743147cc2e22',
 '4fc54709706fa1773b9c',
 '4fc8908cce47e6b31b98',
 '4fc98395d7ac705e1294',
 '4fcc59d0d499bdcef1e2',
 '4fcf93ab6c1258d07319',
 '4fd487cc823a667ecdec',
 '4fd77015775dea012501',
 '4fd7f183a4840b491d4b',
 '4fd81f17f68a0dcf2381',
 '4fd85ceeed07e250d3b3',
 '4fd8731212229282b445',
 '4fdb0145fb620d2b56f1',
 '4fe26dda489f051cde0d',
 '4fe44e97b7f4393cb148',
 '4fe6e7c34c70a4b6baf3',
 '4fee37f2eea76c7ef5ac',
 '4ff1c4711bad5bf47b29',
 '4ff209397be3f85e9537',
 '4ff5504272a39a45953b',
 '4ff6585ff936c1751c44',
 '4ff7c6887bd8ecc5057f',
 '4ff901f444290012931b',
 '4ffc1f8a87c83adfa980',
 '4ffd22fb4082f75afd4a',
 '4ffe0e8bb4e5567323d3',
 '4fffcc3c5787db961f3d',
 '5003242851d31c8532e0',
 '50044e901a174cf144e0',
 '500730660bea773e9ef9',
 '500a9379df032a5756e3',
 '500b9f2ca3e92fafb0aa',
 '500f57dca8a1e79fde54',
 '5012f9466df1968771f9',
 '5014d88105d420d2b06d',
 '50191160d01e8b61d7c6',
 '501a484be8de575ae686',
 '501a9135d4e0a74d5d88',
 '501cf7482f6bc538acd2',
 '50203dd77c5ed641c5a6',
 '5022620c62b85d301b51',
 '5027fbe71d138c5beab2',
 '5028cce5c8b7d684ddb1',
 '502b1aaec4b55767405a',
 '502bde615e8b043771a6',
 '502c71091b26ace231c7',
 '502d14f5e1cd1448d758',
 '502de615b18778487285',
 '502e962fd163ce23cb80',
 '50346513403eed104497',
 '50361cb7475b6ff8a8ff',
 '503acdf94a069c4f6802',
 '503fa46a1d75439b9268',
 '5041bd8d1f123ecde3af',
 '5045e25da786fd10b469',
 '5046754e1c1a170bbd62',
 '504e41503e9b5ec18751',
 '504ff6b1180efc507279',
 '505b23e27331ee4e36d3',
 '505e1f0b5d6a61844410',
 '506359380d2fb2c716f4',
 '506477ee0106371cfc54',
 '5066357d945202d4931b',
 '5067acf5fb33980cd650',
 '506d0d65d9247389d151',
 '5071a589525bb6b03928',
 '5071ef61d4ba8d5837c3',
 '507702e8505d80a45eca',
 '50778d4280fd5d2857b7',
 '507c56e32241825b0ed0',
 '507c6d4f4dbec252b503',
 '507d0e3fc85e7cb91029',
 '507d1bd2f8b6cb79df74',
 '50804b9d98cb64157b8a',
 '5080b4b1c046ff3ada2a',
 '5081833e98386c5c90a4',
 '5082339b5c00eea37b53',
 '5083ee4f403d58b90e16',
 '50851ca69c09d63800c1',
 '50854ba3be53eed04a56',
 '508592e9c97a73ba78e9',
 '508796152e80c21df0e6',
 '5087d622b4324b26d228',
 '5090897a1f4eaeac61d8',
 '5091d28a7ca1df01b271',
 '50925e7499b832bfe943',
 '50929630141b4d29d1e2',
 '5093534f5a13cea77cd5',
 '5094b437f4b6ab6623e1',
 '50983c55a0d3ae86cfcc',
 '5098bfe0ee2f8eb1e358',
 '5098d3944467ed3679c2',
 '5099efcfd186aa94bb3a',
 '509c542b93ceda8f0667',
 '509e1462e1393460b338',
 '50a097cb5c9d4be72b3b',
 '50a5de6afe6be398320f',
 '50a8c2cf70ea3e5b139e',
 '50aa85e5c7f2e3bf71a2',
 '50ad6f412e21b8a37918',
 '50ad7bdf1daa4b976d38',
 '50ade77c8c7b04cbccf1',
 '50b242b82ec5fe99ac9e',
 '50b4fa5354ea119aae84',
 '50b4ff2aabfcb35d15f0',
 '50b603663789df7038cb',
 '50b7be3f1d04f76d5990',
 '50b86239656b957f92c9',
 '50ba1f4fe4f7316a9599',
 '50befe5edfc3732eaddd',
 '50bf467e8a8915f67aad',
 '50bf94f11ce55556ae43',
 '50c04ad7833c52e60e27',
 '50c16dbcebc2e78ba8ea',
 '50cac3b71170b7bc00cb',
 '50caf7abba1927904733',
 '50ccdfd9657a1a2593e3',
 '50ce9bef4135c2c922c3',
 '50d03e05efa01d6f44a0',
 '50d16e3b48c07a5f02c6',
 '50d19f9e41b209bf7c77',
 '50d45417fb9e992f1b3b',
 '50d4862f130caccdff59',
 '50d53c05d405441506f3',
 '50d73be7ae79a81ee0dd',
 '50da5e2a85b6c72455a9',
 '50deb0ed8af2610e33a2',
 '50e14d5eb4b27494663f',
 '50e16725b3bd6dfd5cda',
 '50e3187e929031ff7bf0',
 '50e7a220bab689a5a1d7',
 '50e7f79a3188674d2b18',
 '50e7f8a9e121fd35200b',
 '50e9c28d3c7f12e0afa2',
 '50f239007e3b9e9bd53c',
 '50f28e631850ae2fe7ee',
 '50f2a4d6c68e54c9a6d7',
 '50f50a633ac239bd2ce5',
 '50f6de53c846ba97ce8a',
 '50fdefc215e57bd5a193',
 '510a353b3975b02e8d12',
 '510a46d658766e9deb10',
 '510b6f16ff14349ea8a7',
 '510be07d1c5873a0ec91',
 '510c406391bc4397ccd7',
 '510d66a7cdd7280bcac7',
 '510efd23f88d125e203c',
 '51152eaf3828a206ddde',
 '5115a4ffa89d53afa156',
 '5118f6a7f8294b3064cd',
 '511b7ead619aaa5aa6f7',
 '511d4a525d6232dbacaf',
 '511ff8e6da7e1906376e',
 '51216fbe76a8ae8a1894',
 '5125a2edcfe694e4aa60',
 '5127139432bb129722dd',
 '5128cccb69b7e5eac577',
 '512c1778feffd741742c',
 '512eff061b5670f11f65',
 '51316bd5c64811583355',
 '51350c5c8e51aaf07cc1',
 '513767ee7f540bf0224d',
 '513a693fd62496ed1e15',
 '513c243e35e982548796',
 '513ede208a11043176a7',
 '513f52c2f8c10f006486',
 '51431725fa3e55a4a33e',
 '5149226981a3c71fc95b',
 '5149404f1a5edefa8c60',
 '514c64a191ccac7fdf93',
 '514d3f9f824706d98335',
 '514d629f16551ebdb755',
 '5151ecd50d554c95d9f1',
 '515299bc0da56469dec0',
 '51545e4bb5d8145eb2b1',
 '5158bde1f5056dcea35a',
 '5159776a74975b5acaa9',
 '516166c52f6737f98a29',
 '5162338e6a105312b9a8',
 '51638a9a3172dbb9749f',
 '5164d69f3373ad77535e',
 '5167a94f2e424c8f1839',
 '51696f7f4025418b1a5c',
 '516a17cbdcd2c1e227f3',
 '516f1c9e1d1d93130514',
 '5170f5dba4db91f9e8e7',
 '51725c932dc4a5898230',
 '517394d017af2953a776',
 '5173f8a3f39151425f35',
 '517898341af12b65ff28',
 '51790350e8421ee1c51e',
 '51791de914114b1f81a0',
 '517d5eea0ce6389f7c2f',
 '5182d1e142b58c21b68c',
 '51833f86a12b0aeec372',
 '518349c86c7a3608d35e',
 '518349fc308fae885bd0',
 '5187d6848800e35748ce',
 '518c2efb6ebb6a5587ec',
 '518d4c9ce581908ca8cb',
 '518de4699f9c19f2527f',
 '518e986390bade80a875',
 '51921fd50b64b21ae085',
 '51922c68c4addd4bac9f',
 '51940ea7513158bbd682',
 '519658d708f05f985c0a',
 '51989e2f7b05753cecc8',
 '519b058ad258273c9cf1',
 '519c5a47ffaf0a00d5bd',
 '519d5c689bb2b5a2a811',
 '519e669634aa5b87760d',
 '51a386b0813b8f1521aa',
 '51a9d2502e9792d2621a',
 '51aaccd84810a6e90afe',
 '51b48f7887b4a05db491',
 '51b81b7ba20b160e698e',
 '51bc5f6b05255302ca6d',
 '51be25a690ad3fa7dd65',
 '51bee4ca314abe3d346a',
 '51c0a8050c6fb5b34d8c',
 '51c346fc5daaad43838f',
 '51c4e80faaf29854738e',
 '51d1fab74f81880e6178',
 '51d4bcb9c81296563d84',
 '51d507a9e451c399a803',
 '51d7760f1085ba05479c',
 '51d7a7fa5a1eab806edd',
 '51db326dd217dd4103c1',
 '51db531196b715ce17d6',
 '51df33ac1e563512722d',
 '51ec4d89d2d11d86a0b9',
 '51ef8f4ea94d75543720',
 '51f09022b008f4989ef3',
 '51f2d71ff99a87bc2324',
 '51fdfc0ffb993f13b362',
 '51ff6195d6bc24990e13',
 '5207400533cca32a7730',
 '5209953c123b7f84f37a',
 '520a4b98c4c9afd9f97a',
 '52101eabbbcfa2358350',
 '521083139508d5ea85b9',
 '5211d2df27dc948cc2d8',
 '5214689534798aaa4df1',
 '52157d488416146e9564',
 '52190d306c4ae0e27fba',
 '521b6b2c0e81696f2f30',
 '521d249f4c3a7cc98c75',
 '522045cdab405e118e9b',
 '5225c18dfb3bd33b47e3',
 '52275970f0f79101cbe7',
 '522a1c3978a7ef7c3c0d',
 '522f1a6d1e856643cfbb',
 '522ff24533b092c44c6e',
 '52309f717f6071866a15',
 '52318752a6940eadd9c7',
 '5231968fa1133abbcf1e',
 '5231fb826616054e5337',
 '52374bd346390faf51a2',
 '52383c187d4e95e53bb4',
 '523a7b5b09c9ddd1204f',
 '523aaa869784a14246e6',
 '523d2c7c6efae53cc52d',
 '52409f6aa7f80bf6ef78',
 '5242475a73794b89a857',
 '5244ce076fb216a5e14b',
 '5244ee96b528ff0e4355',
 '5245615f22b0138da04c',
 '524588abda578f45a243',
 '52489a6f070156f861d3',
 '524bf105d321d461513a',
 '524e21dd103cb019f9b7',
 '5251cf3e321c2d4843a1',
 '525221bd5f68783b295e',
 '5254778a84d378ff5022',
 '5256ba10ea6d4d1a6542',
 '525a9834b7e651f0c1cc',
 '525ae9fa5eadda525974',
 '525ba24ae51386a4c903',
 '525de16d934e886598d1',
 '525f11683b7870f5887f',
 '5260e417493b312f4424',
 '5261f186904d315bb24a',
 '526288ed50024c59dd31',
 '5263af67b2fb9071d8bb',
 '5263fd1ba651d385b78d',
 '5269db476b67949dd0eb',
 '526ee73869b29ba9152c',
 '5274717a2de5e0117e90',
 '52776223a70807fc1746',
 '52781e659505a013e123',
 '527841c312fa7c394d9f',
 '527be282c30d19050a3c',
 '527d6a216d319a53d1dd',
 '527df034178012089be2',
 '527efe532335fa3fcb6a',
 '52817023dc526daa6291',
 '52877f0cf7ad3168e57c',
 '528818cd4fbed9d6e166',
 '528a49f494d8a5d21994',
 '528dc645797daf389039',
 '529232ada198e43c7f40',
 '52974c158063c1f0f919',
 '5297722be9e66fbf0c0a',
 '529ceb2f4772445e5144',
 '529d7dedbd8186596d13',
 '52a040bc1f929af037bc',
 '52a474d8648a18e1886a',
 '52a4959fb42825a3e29e',
 '52b01462f7b89ab4d688',
 '52b04ed963e7476d82a4',
 '52b32b9037025963c5ba',
 '52b346f249c196b24be2',
 '52b3996b7be83ef12527',
 '52b44fd1adc38f14f02b',
 '52b5528a8c789986e2ac',
 '52b59afd67bd2177db6c',
 '52b6c21b82ba1c84681f',
 '52b7ae0b651e4861c2ab',
 '52bd457c29492518241b',
 '52bd93e2f4ff0b52af0d',
 '52bfd75bb7b691139363',
 '52c195aa4e0b6e26e2ae',
 '52c43f34b9a58d38e5dc',
 '52c5584ca594225702c3',
 '52cad7db122b667a0456',
 '52cbf6d23ab6451268e1',
 '52ce6ff9b248dbc5035a',
 '52cf7b30f52b49f9c039',
 '52d1f20fcc20189ddf7a',
 '52d2b28ac3c10477aa9a',
 '52dcf9bbab076d54e624',
 '52de5ba6ca77fc2c6fc1',
 '52de93400bc21733ac74',
 '52dfc1f45117e35fa579',
 '52e486fe43a6a7ac7a1a',
 '52eb85d6ab141568c2e5',
 '52ed1808780b9b5b7542',
 '52ee1e27d42821153670',
 '52f1956827d851ea008c',
 '52f2893dab5c6d8ceaa6',
 '52fa483cf74f4c4753d6',
 '52fcc355a1407159e156',
 '5303fbf70d65c0543b62',
 '530ed569e83b3e433599',
 '53137168569f94cee75d',
 '531f26ae5af37f536cbd',
 '53209342f209035dc286',
 '532143b67cda2595cc1c',
 '5322d1c0686c30a215fd',
 '5325fbb9dd0ceac9c1a8',
 '5326d094597ff25f3279',
 '532cc39a27319b14afcc',
 '532e03567f5e212a7502',
 '532e6ec86426ea680fb2',
 '532fa3fe81da50e9020f',
 '533087b7f3a60e0144f1',
 '5332c48eb4ec1c2fc35f',
 '53349322d01af723f4f9',
 '5335e8fc13b45fb2b700',
 '5337e4ff52ac5bd1dee1',
 '5338595639a99f193847',
 '533b5407eb261c6ecada',
 '533c6d3f94c39cb9620b',
 '533fde5913e0ca56c6ce',
 '53402bad68eade8ad0d2',
 '5343f4ef9bfca0627edc',
 '534722a2ab260ca37b8f',
 '53486a4a3113d4b6da54',
 '534891cbf54076329668',
 '534e460956c147b79095',
 '534f3a72f34f78fff000',
 '5356062b6efabe53b743',
 '5356d9c886902d205505',
 '535976228ac6223ee5ff',
 '535a3d420eee59429da2',
 '535ccdcf177f5223f80d',
 '535d76183d8e9d932b4b',
 '535dd95462f232cee9ca',
 '535f69aed659aecf081e',
 '53627cf09d7a187e0633',
 '53681ac99b9438df0192',
 '536db9022d6f1dd7e1fc',
 '53736675d0deb8030ced',
 '53755d84f9ea545b3e13',
 '53756e04355137bff9d8',
 '5376ecf7bbb90b2751a9',
 '53783cb1d77c49ad3a5a',
 '537e1a7886a08fd8ccaa',
 '537f679aef7cec355235',
 '537fb924fc9f7f098d9f',
 '537ffe25805f4836a7fe',
 '538005872dc25cb79b2d',
 '53856335bab4d9c73410',
 '5385e7a650b6a91c17be',
 '5386e8775aec6d0d8982',
 '5389a7a2411f2721cd53',
 '538aebb555dc7c706055',
 '538b11091d3d46894a7c',
 '538cd60b15fa7517876e',
 '538dc1ea4a06bf802145',
 '5390e13b7357ea36fc98',
 '53913b0a3195fcd87010',
 '5395a1266335c36a496a',
 '5398f7c86c1cdb28ca23',
 '539aa7ab2e202e3e9b8e',
 '539aec4a6dd162e8e1a6',
 '539b46a51c9480fb0f8c',
 '539cf40100f043b6f8bb',
 '53a0d62f0db5b5bd1252',
 '53a0d75cdf78a7cac2cf',
 '53a4b725c9cb59527f39',
 '53a5fc90e2b0c9262304',
 '53a766c7ce186cfc8b8b',
 '53ae0d3b3e2018c1ce9e',
 '53b6bf27015777a47a05',
 '53ba9a41027718914b3a',
 '53c05064c5b59f2246c3',
 '53c1858e609f2e783b4e',
 '53c233527ac2d9be5885',
 '53d16aca212d76a84259',
 '53d5de3fcda62a588f40',
 '53d6a91aa054558f6169',
 '53dac5e4aa4937d1325b',
 '53dd2c154af62a6669c8',
 '53e622c54faccea159d9',
 '53e764819610b28f0df5',
 '53e7a12b9df0f37f215d',
 '53ec2fbbd0f29e31aec5',
 '53ee25a6fa47ba5c5954',
 '53ef2969468b5b1179bf',
 '53f2d2f3524fe859363c',
 '53f50da5a7de683f89d5',
 '53f92a49596f0d32895e',
 '53fdb2983292d7609041',
 '53fe3912417326aa581c',
 '5400b6142cd269d62343',
 '5402ec30cb5cdc34f0d6',
 '5403eed22704a765ba8e',
 '54061cb552328bda47ff',
 '5406c2d030e1b3f8d8a4',
 '540d25e777dc8838b1ec',
 '5410b415a4252bb1e80c',
 '541761c16255daa9adc7',
 '54181d1cf31cee908e6e',
 '541910fe9f3e170b0d43',
 '541a042e4bda51fc4121',
 '541c7f6860ce5eb95777',
 '541d2c19673bcfbe8f55',
 '541d5a7d44b1b5d01b69',
 '541ea1999c4dbe858684',
 '5423fcb2fc2330fc2f6c',
 '5427e88242b7d84ffaa3',
 '54290a7d5a651864e380',
 '542c8df8815aa9cbc29b',
 '542ce9f0bf5b5649de66',
 '542f142823216e65e649',
 '5431f7686b54b71348c4',
 '5432716234086b563411',
 '5435839f4ea6436fe8da',
 '5435ac6ce5aae075999a',
 '5436dd658780090667b9',
 '543a16b93dedd6594f04',
 '543d931b51a48ae58b31',
 '543e7813990340b928bf',
 '54446dd2af2e346ad705',
 '5445732cbe2763165fd4',
 '544792076bc95a504b79',
 '544bd67d9576ca48cff5',
 '544c3ea1b8e521a75a81',
 '544ed750a34d1fbfd0be',
 '5455f41f8c2062820b8e',
 '545e472740a6bf049881',
 '5462d68952d009e77bc5',
 '5467f4d40a4386ef3e0b',
 '546a71487bc016f155a6',
 '546ae9de931430f48233',
 '546beb84849ba8a3a447',
 '546bf07540502f30efd8',
 '546c99682656188767a8',
 '54766958f760ee9ea22b',
 '547888fbddc5f8f40236',
 '5478e1a4f80af067746b',
 '547b983c994074172175',
 '547bd5568563ddb6adba',
 '5481d4fca700cbd62c29',
 '54821dc31f00c54eb8f6',
 '548292ed7c0fc23a910d',
 '5483423dfa2ce12811af',
 '5483435f1393d390d76c',
 '54836deddd50452aa394',
 '548385cb34d53284102b',
 '5483924f01be536de7df',
 '5489797ec1d4b2bcef41',
 '548a9332a17bb5528e79',
 '548d27ac52e4e512931e',
 '548e641feb153a45ccb4',
 '549665d42b5027188fa9',
 '54989430233eb06fa1d8',
 '549aeecd1da3e8b9249b',
 '54a3938c4e604d8191b4',
 '54a730ec8b7e6af0ec8e',
 '54b0edc321dcd7779c8a',
 '54b1072c278c7b67f122',
 '54b503785e43b8e3086d',
 '54bc921323317a638ac7',
 '54c404957200ba6d0d55',
 '54c79d72bc3809f43988',
 '54c9d92f66b25fac8762',
 '54ca0291fc2b58db1624',
 '54cb3e3a493d57f3eb7a',
 '54d1e5e5850eee606347',
 '54d29183e4b3f31c7bef',
 '54d2b1e86265d7cf68ce',
 '54d6fb0ef5fb3b0b3aa9',
 '54e0a4f07a981e1659df',
 '54e50a966a4581c08a1d',
 '54e602ab2a4d39f3c885',
 '54e62775915502444220',
 '54f47cd63edc3bb22b84',
 '54f4d7c4c91c130ad011',
 '54f4fc686236d2952d02',
 '5500744a612dc3bb44dc',
 '5506fb28427c8b0a1c1d',
 '5509c00f8736f25249c9',
 '551028c5ac405326c4ce',
 '55108dbff916c3e161f7',
 '5510b555602ac7e1b9ec',
 '5513d79b9794a4f3a647',
 '5514e87d7a0af5f62257',
 '55150fcb519a0506901f',
 '55218bbbd574fb837ab9',
 '5522e8493a49a6fd2387',
 '5523e34e332525cbc31a',
 '5524d7dfebb86c311a7e',
 '5525cec7cdb12ba742ea',
 '55262554cd5d14bdfd1b',
 '5526366d5a47cc98882a',
 '5528a0d3a614bfbd3fc1',
 '5529efb492aeb41e56bc',
 '552cf1c40f9a76ef64c8',
 '553157e0de871804c895',
 '553168005e4f78ce304f',
 '5532e8a0d01c757f7674',
 '5535bb52634d01c34d8d',
 '55368969e3ccd8cccc72',
 '553819ddd453469a6dc9',
 '5539b6cb6e1cd241be15',
 '553cb8770d18cd1e4a4c',
 '553d777194e7c0cb92ff',
 '55435a2a35ae928f831b',
 '5548b5e21eaff92c45f8',
 '5549151017d23abc364a',
 '554965ea3c35a0a01db4',
 '554a194e6b6de43fde61',
 '554be627f42719922ed9',
 '554c6677d376dcf6aa18',
 '555020ffdc5e6d4ff45b',
 '5550355b259ad622c32b',
 '555207af49ac68bcfb9c',
 '5552df24355ebf084762',
 '5553c99a987029b9207d',
 '5553f33dd98194e41174',
 '5555bc6fee889b10f2cc',
 '555807b618ee5825a9fb',
 '5558ea72e28eb329eb04',
 '5558f61aa2df9b743f97',
 '555b1c09c9c311c5c274',
 '555b334200205f9d0c8f',
 '5560ce048d1eb9fcecf1',
 '55628b52fcf21333be20',
 '55683211580410e1fc76',
 '556cb74445da848952b0',
 '556cff8464d29db406af',
 '556e1894117dc6beb814',
 '55743faeff3186fc148a',
 '557b84de707c31bd8578',
 '557b944eea33367dff8d',
 '557d71c97040709ac2e0',
 '557e69ca07a4b98ffdf0',
 '55805ce04687c49a2ba3',
 '558129581525381705e4',
 '5584d38c9e7a00ab5e98',
 '558602404486774dfeea',
 '5586e50233f6da417d9a',
 '558788f0ec9b4fcba9b1',
 '55880884c2c0ef4c4865',
 '558c92e899002969d642',
 '558ec1f9ee3a47b632be',
 '55920bf922569312835c',
 '559301f3df1f0d108018',
 '5593cb3e3d43e8f74ed0',
 '5599960a82bbc8b9de00',
 '559cb46ddbca77e17842',
 '559ff1c908ca2c656725',
 '55a2f3771c79c6db9d3f',
 '55a77f3f01b4a39aa8cb',
 '55abb1b8a0d13714d79b',
 '55b491365e83c09f29c0',
 '55b5dfa99229f4b9d7ae',
 '55b93332f1ec86d34621',
 '55bb0ad505830f14208e',
 '55be0356ab1942b4a695',
 '55be2b8f6dc2dc08865a',
 '55bee4e331b10e4bfb10',
 '55c18dcc8b0847a7b859',
 '55c39c4b33e6134e981a',
 '55c6aba78e2ca7a05790',
 '55c878de0423eb13138c',
 '55c8bd64e149ae5025de',
 '55c8dbcaec6687e73f52',
 '55ca6b7b8d285acc2fac',
 '55d469e635f9c478aa5d',
 '55dc3c6b79e4e3534a0e',
 '55e448d4bc4153ccfc0e',
 '55e459f8ea76caf1c172',
 '55e765f829995da0596f',
 '55e92f53407790bf3bfa',
 '55f01c3f73bb01635141',
 '55f0c8c83d5a2507395f',
 '55f0f7c344055766d2e2',
 '55f20dcf71566a27a77b',
 '55f5e770f4a8b56f1fac',
 '55f89fe5694abd7d11c5',
 '55fb446acf88e3d0bbf0',
 '55fbe908561b979f25f9']

# %% [markdown]
# 9

# %%
qids_9=['55fc34e5facc2aa6badc',
 '55fe26f7ed2ebbf6d3be',
 '55fedca2517944412989',
 '560008d589dead2c6a5b',
 '5600c0662517b62c4772',
 '560196641f334f58e150',
 '560396ff736483fda098',
 '5603dcc1676e9b2c886b',
 '5605ac824e9815d344bf',
 '5607afa80ce3c68d99a9',
 '560ba7bfc5614a25e580',
 '560d20336cebb8095520',
 '5610932c5eabe1617379',
 '56180f40de71da429b2a',
 '5619facf642de7c23b8e',
 '561adae74b24145994fe',
 '561fc78d3e8f854e374a',
 '5623a119d72475f1cb2f',
 '56241d06e16bdef69dab',
 '562563c0af6750ec48d2',
 '56262b6592d4187c33ed',
 '562934d52ec768a6c1b3',
 '5629ae23afb5b84f5941',
 '562c1ca61efde463a1e3',
 '562c930d8ffe660edd8f',
 '562cd299d360b8ba8e5a',
 '56301f5c78c3e0b1d0ef',
 '5632ae2b5f0d87d6a3f2',
 '56330c188c6bee89e93b',
 '56398886a9e3c31bcf00',
 '563a6910c3928bd2db02',
 '563b2f1bb0941026369d',
 '563c47a54b7055371878',
 '5640bade7d52bbe11496',
 '564145009e44e5717467',
 '5641b22234223b101fac',
 '5649b1eecf3e10b69e44',
 '564acc17869c500133f8',
 '5651b8d6b4322ae5db17',
 '565247a7dd7a14d033f4',
 '5656709161bb38967f27',
 '5658d672de077c379dd8',
 '565b7b2e2ecf50336e5e',
 '5667370c1f48d4c02d55',
 '5669fd68c8405f551ac5',
 '566d68c511fb7de37a65',
 '56708d5aaa4aef60248a',
 '5672fffb493855945b5d',
 '5674eff474e93e3f33cb',
 '56759202cf25690c5265',
 '567982f811ab22be9ebe',
 '567cfb5517c0393a0f57',
 '567f14ecdeb81e2cdaa0',
 '56843a53f1285afb7d83',
 '568745a47b04ff396db3',
 '56885f5cc981893dd48d',
 '568b2ea2b400bee82df0',
 '568c60845de46b9b8ea4',
 '568dd16fa22fe79435ae',
 '568f89c821246fd4ae69',
 '568fcf5129622d51b15c',
 '5690747e46abe683ea67',
 '5693e25523fd80ac316c',
 '56950e795815a3823e3d',
 '5695db1be23d46e9ec41',
 '5697c403db0dc76ab839',
 '569c59e0c929ea177924',
 '569cd98536c6e169c824',
 '569dc44dde80579ad4ef',
 '569e940a0cad154352c0',
 '56a4602bbe5f829cac27',
 '56aaef5d3dd569dd71bf',
 '56b3c25221280d4d5ab6',
 '56b70de8f9c086488d2f',
 '56b87352f935c9930329',
 '56b8a5ce5aecef03399d',
 '56bfdcb4d0414fd4574e',
 '56c59cd47a289c7ebfc9',
 '56d18cf7340fda5ccf88',
 '56dcb62b749a3aee8783',
 '56dd1cc19e671455c90e',
 '56de1af525c2c07720e4',
 '56dfb5a2f028161471ef',
 '56e10f48946405f8c08d',
 '56e2a3b96e216d76d22f',
 '56e609c32a0941ce530f',
 '56ea24423a5c954272f8',
 '56eaf1dd82312bce095e',
 '56ef48ed19a0db2933a7',
 '56f0a02e657c45ef936a',
 '56f4650e01f182a7edfc',
 '56f8c3bdc43362f3394c',
 '56fba4217e2b064968cd',
 '56fccac77195676db702',
 '5700ece029ce270a976d',
 '5704c75eb75787ca7cde',
 '5705f0938c67551fee52',
 '571365c15038a6f613f9',
 '5715fca9dda545538255',
 '5716e9fe1d9fce07e01e',
 '571989b6b9afb0996f99',
 '571e06d34cc4c1fefb39',
 '57217cd10c18594abdad',
 '572296159c4efed759a3',
 '5724500fb40f5cd683dd',
 '57360a4dfec902e877d6',
 '5736c7a77d0e2647998e',
 '5740e6f5baf67af99daa',
 '57474ba20e8a1b776c84',
 '574a35cfd61ede3aeb05',
 '574b67c13fbb7d1ac301',
 '574c9ffc4e724bfd054c',
 '574d08f78356175a743b',
 '574d8164ef1ab16514f5',
 '574f2efcb2e19c9f8a2c',
 '57503b566cb1a5bf8661',
 '57535e73e6d0c1b9fb9e',
 '57544e6957fc85132f71',
 '57639e5bc4e7bd5a122c',
 '5763ff124dd41a96d9f9',
 '57652da87e1c2d86cb1e',
 '5768be3042c1932ee3ac',
 '576cf240d047bf482e65',
 '577337f17427e66bdc9a',
 '57758ac04d1f1b571a87',
 '577674f48ff09e4ee768',
 '5778527cf19eaf7e9f06',
 '57816a7475ca5e7a4143',
 '578595321d2e58bd6367',
 '578ababb7f4d44e9b7cc',
 '57911f949bd80bac08ba',
 '57914824322670f5c3be',
 '57922a0383e2ad4e62b5',
 '579974b6d912614f4308',
 '579d51c2c7478d5cccbc',
 '579d9b592eff309d5299',
 '579e4ef366857029cbc6',
 '579f2cf6c539e9167ca3',
 '57a119e98652e2984e86',
 '57a3b57fca63b35927aa',
 '57a445c42404c54401f9',
 '57a7787e977c0eaec739',
 '57addc398c285c50d9a5',
 '57b6639a023776a0e927',
 '57b6ca66e15639b55630',
 '57b7e58e9001c1817595',
 '57bc82cc2d2459911a40',
 '57bd16bd9095af51240f',
 '57bda6304c2c52a2ddb5',
 '57c0adc2450ef70e8140',
 '57c0fc1a1a4a2285fd77',
 '57c22717bee53de1d4ed',
 '57c31e4bfa39931e43e3',
 '57c69a535e0dc89e62a9',
 '57c89876dfc01ae8cb49',
 '57cd6dfff87956bf2a38',
 '57d04d7edf5a183d8adf',
 '57d1e5cdeceea36074a8',
 '57df551e14e5847ce02a',
 '57e05768bfea8517e24b',
 '57e33b9761c9252db029',
 '57e570d88eea9d109884',
 '57e775029c10a81763e1',
 '57ed509badf30e0af27e',
 '57ee003be65a02e0e30d',
 '57f01b92dd33607c0b9e',
 '57f354f59a6aebec76bd',
 '57f89913cc9e2247602b',
 '57fd874526d78d427d07',
 '57ff22c71081a7794c01',
 '57ff801cfac9c0e160ef',
 '58028e657514f9e3f99e',
 '580445f915b38581409b',
 '5808b1c68c2ee1497418',
 '580becd537bcaa52d988',
 '580c9fe1063a81a590b6',
 '581c7d1e01a73a60bbf6',
 '581fa8ce7b382adc589b',
 '5825a576fcb582dc3c0e',
 '5826ef46b48db8d4c63f',
 '582b99e7cbb69388ae32',
 '582d92771ceec7cfff6c',
 '583148cfc2a30b809ea9',
 '58368562dbf389219413',
 '58397a06b83590658ea3',
 '583a15e43475f85e2d1e',
 '583a1d0e3f504ac1fb85',
 '583ca731b7829c481bf5',
 '58436c8b7b9bc40b87ed',
 '58464659bc65d2da82f4',
 '58481c315fcfcaac1cd2',
 '5848b4319ed61743f965',
 '584a59d4e1cad903f2d0',
 '584c55753653a7fd835f',
 '584ef1d954c5cd46c3cd',
 '5851f9202c039737f336',
 '58531f7d8e19c9c963d2',
 '5853684443d5c7e116d5',
 '5858d062bc950d056b5a',
 '5859d16cfa94faeed72b',
 '585c6f08c7336c0b9bd8',
 '5863cae44dc47e671632',
 '5865e52e706a7078b392',
 '5867cc5a30b73d4d4c7b',
 '58696a41406bf447a766',
 '586da2e79c7c4492e818',
 '586dca668ce9161ed334',
 '5873f6e31b93f3c38328',
 '58762dd83996f89509c1',
 '5878b61aaf8aff1ba634',
 '5881954bb0147962a307',
 '58850cc9499371835c8c',
 '5885ca22205c1de3e99b',
 '5886234a395da40c1545',
 '5886c0f50b6cb2af1ebd',
 '5887ffcbfc4044349be0',
 '58886ec33512438e9896',
 '588ad59d58a6d768e3ce',
 '5891fcfb91866c5c33d0',
 '58943c5f4a8f293f330a',
 '5894883c91b10ca89eba',
 '589706c3a46e7ced11ef',
 '589e26c48118730984f0',
 '589e94619b6e89ea3ec6',
 '58a29aadbb2b724fa392',
 '58a2fc9c8ecb3c9e2c57',
 '58a50c5b7162f319499a',
 '58aa730df70a24a2c4b2',
 '58acf605cfae020dcd68',
 '58bcb1c642b65e488f4c',
 '58bebe2c35505045adb0',
 '58bece72bdfa13d8f8cf',
 '58c05716a256522cc569',
 '58c0c44ff5b002645a90',
 '58c32df2562ec197380b',
 '58c3822561cd8463c83a',
 '58c5758662fa7f413913',
 '58c7ec9abddd3167aa61',
 '58c9c508892fac826104',
 '58cb1e4333b1fe55f61a',
 '58ce6cc34fcf222cb8b4',
 '58d1df33742103d22e9c',
 '58db58922b4ff79ed65b',
 '58ddbb8cebea8bdaa9cf',
 '58dff35508d8cabb3b9a',
 '58e28182035f45bf01c6',
 '58e574e09eea87499a10',
 '58e8b010c230c364eed2',
 '58ea126880d609e54203',
 '58ecd18523acdbb94c19',
 '58ef178b7dd22263a924',
 '58f1a7291afafa9c7368',
 '58f3ae4e2ac16307873b',
 '58f5c5096e45ecae19d8',
 '58f924ee5b7fabac5cb6',
 '58fb1494a8fe133c86ce',
 '5900ced9328c814bf38d',
 '5906ad3f4127990e9697',
 '5906b694c0fcd9f738e5',
 '59071e0a11c688ec2b5d',
 '590b8920b2c37dffe331',
 '590ca883d7a83f35dfb7',
 '5910a4669a351e275b48',
 '5914c444c229bb05f879',
 '5915fa05925b2e0e2cf2',
 '59183d24d1ca4742b202',
 '591eb21e0c9dbb0f289c',
 '591f67f31a0b4bc3a3b0',
 '591fc4dd7cf2aa6a1237',
 '5924c9baa0b7487e0d3c',
 '59270c76b724faf03d8c',
 '592723dfb62a19878127',
 '592903def4869996a9b8',
 '592a7fe7d82b5cf91168',
 '592c3b8eb4aeb511130b',
 '592f2cd89bee436fb460',
 '5935aa0cc4704d00ac82',
 '593825677061fbe44952',
 '5938e2cf3c82073e1f65',
 '5939a930ab3428a9bf56',
 '5939ae351cd9e072d934',
 '59431267ec5db3e3e1cf',
 '59458c86da78875f4dfa',
 '59477415326c73fea11a',
 '5948214886271472d435',
 '59491a01b2cbc05a4cd1',
 '594c11da1e9eb8c30921',
 '594cc8b8dd9da9eaa082',
 '594db9eae14c24442201',
 '594df002a36971bdb956',
 '594f1de391706249b2eb',
 '594f4b086c7ca972c018',
 '5954670eb34ed43911f4',
 '595a4431b2e9e43c0b23',
 '595b905613c6e25427c8',
 '595d8d22dde2b327f7c6',
 '595dacbcf8fd6971c2e8',
 '59614be4b20126238ea5',
 '5963fc685dba76cafe5c',
 '59644f4985fc7179f6d9',
 '59646592ab2548671be9',
 '596932499dc3d7c7204a',
 '5973e26ac494f8941fe5',
 '597fb389448f7fc69bed',
 '5988e34140ed973db778',
 '598e1bc6e1bf84a5aab6',
 '598ff60094ca19cbc372',
 '599466a9a2abf36ac985',
 '599643df4bd5d10b3522',
 '59993200f22f2082480b',
 '599946f326c274cd55c1',
 '599a068bbb1247db4b78',
 '599a411696ed2a1c13a9',
 '599de5098a314a2397c4',
 '59a3b8775d6e72f47007',
 '59a4e80d081161f0ff12',
 '59ad4a8d37c9ccf12095',
 '59adb3a55d5050e86c0e',
 '59b0817b3b2549815d9c',
 '59b437257902eebaae7f',
 '59b6d0bb8b35e407561f',
 '59b99961e77a8e45dd9e',
 '59ba2d5204f4d1c725c2',
 '59c0d7c0eff76ebc035f',
 '59c201fecdd1f1ac3c81',
 '59c40aa642355dacf526',
 '59c538511d4934fab4d0',
 '59c90f31d4451cbbd213',
 '59cb8c615c5cb2b2fac9',
 '59cd22b396836a3521b7',
 '59d1bcda326776a14287',
 '59d5443aee70bba9f8e4',
 '59d87971fce1c4a3bc71',
 '59df6208a63e51a9f86a',
 '59e0bb8208b5a347fb26',
 '59e10ea21d844083f507',
 '59e4ea7ba232d4e39ae6',
 '59eaab84e133e025fcac',
 '59eefb174682ffc56035',
 '59f084d405c50701bb0c',
 '59f3918d5ece1158844c',
 '59f48ff9698d03bebd82',
 '59f50d6cd85c524dda51',
 '59f6aef3cc5f7e2f0c67',
 '59f6c1504ce5d839c380',
 '59fe5d21a46e0ae9da04',
 '59ff203409e8d193e9b6',
 '59fff0de501771acd848',
 '5a03423f085ffcddb69d',
 '5a03550d9346389cbb8f',
 '5a0a29c25b52dddd9c20',
 '5a0cb4441e9fe4dce072',
 '5a0cf32fb9f5f0f17c2e',
 '5a0dec1a2e492974ed5c',
 '5a10fe0e2f9eb6db2c32',
 '5a12ef5a20359133253a',
 '5a13677ce37f332c31ab',
 '5a22751d44b721ecc3d1',
 '5a282de32e45264ce47f',
 '5a2a72c711289c5c5011',
 '5a2d17bb2d0c6dc8ca26',
 '5a2dce897d0f7eb91193',
 '5a30a71c48dd1eb99c8f',
 '5a3175e95b380adbbce6',
 '5a376920588bf6c120bd',
 '5a3895a0b413a85dd81b',
 '5a3ae1cf0a1ea80dfbdf',
 '5a3c7801d4d6ecc94660',
 '5a3c81653c43ab451f57',
 '5a3cb603cb55227ae540',
 '5a44b1cdffa02e53bc64',
 '5a4548ed99f32875e1d1',
 '5a454aab85101f2b2d82',
 '5a45e3c96b97a84a3593',
 '5a462fca7d78ea484ada',
 '5a489d537610af306754',
 '5a49127619cc0bfefb30',
 '5a54b5f2fd53e1f907a9',
 '5a566c4e48223e121c5e',
 '5a575c09c06df94a897d',
 '5a594ccd3a8a2851ee6f',
 '5a599134ef5fe3f59551',
 '5a59b9cc4c5eb25f2098',
 '5a5a05dc4be4a6ba3882',
 '5a5c612bec0519fefa18',
 '5a5e28ffc821b4189a72',
 '5a5f67859bd92a1bf3c6',
 '5a61f73e4d993361f366',
 '5a66e5cb5d2be2565e87',
 '5a68b2aed811b19aa2ce',
 '5a691471b7980976bc4d',
 '5a694ebf1c50a0298202',
 '5a698d937cd2181ba6a6',
 '5a6da1a077f873213c1f',
 '5a7648ea29217535c95e',
 '5a7adffbeac3e1998ad2',
 '5a80a0d3ac6d327467be',
 '5a8343683b5ab80d2d54',
 '5a84bf488af1fa2bc12c',
 '5a84d5ed9f72a6001b6a',
 '5a87af73b345518453b6',
 '5a8f7e5a256789549bef',
 '5a914dc741a6e2c8e766',
 '5a92a79b229128ee1831',
 '5a9595936606b0252bdd',
 '5a971231cc54a61d475c',
 '5a97d44431f3a7a44046',
 '5a9c10267a749f948ced',
 '5a9df16e716ef681fd11',
 '5a9ff236649d850d6965',
 '5aa77f56c0ccb8a73de0',
 '5aa854d89b94330f6fff',
 '5aa98b3a72449ceafdc0',
 '5aaa18f7e9d973b7e12d',
 '5aabf2651e2748acf283',
 '5aac529b658fe0c9a319',
 '5aaeb32afe8bbf877c4b',
 '5ab25233d51d3e248d08',
 '5ab356bfb626e0a699be',
 '5ab50ba93e20cfc16e2a',
 '5ab8105cc18a77d01246',
 '5ab93f183d7cd584190d',
 '5ab9ecc6dc43844a7670',
 '5ac06b780e14b81392e1',
 '5ac24ebe530f9715df1a',
 '5ac348f2f19f598723b9',
 '5ac3499155cfb2e66dd5',
 '5ac4f50dd3976c6ffff1',
 '5ac8799b056077e45d15',
 '5ad191cf0c6e4810d943',
 '5ad42b86b3140eea5b8b',
 '5ad49c24e271adf1894e',
 '5ada069c5f2b61bfb563',
 '5ada7b5eedff483e49b9',
 '5adc70e5f688ba6b4eb2',
 '5ae004addee85479da19',
 '5ae3849256caa5d83d1f',
 '5ae4a946ff089a6e404a',
 '5ae63bdc222a12dccdcb',
 '5ae90038c2ab2552b713',
 '5ae9d3bf889b49cca6a6',
 '5aea7f41854e107cc7d8',
 '5af08caf733950ba1a01',
 '5af51a436a6c7766b2e4',
 '5af544d5fe4f66ce95c5',
 '5af7ebbe36909bc6652b',
 '5af9b30334b29ce8c150',
 '5b02ecc6f7b42c1acef0',
 '5b02f921f2f78884959d',
 '5b03f45af69182a6d795',
 '5b098a8abdb19faa33d1',
 '5b0d5c5994d7e7450d92',
 '5b0e76f1b18d77e651f5',
 '5b11f86ddf3929ff795a',
 '5b13c777ced7d2bece00',
 '5b13f437f27e9ab4793a',
 '5b17f929fde7d541498f',
 '5b1c209dcdd98c225ac7',
 '5b2117211cedf700d4ff',
 '5b27226c9019530b4f2f',
 '5b2cf3e9b26d341cb36f',
 '5b3279275ca559b681ba',
 '5b3706a7269107ef66da',
 '5b39734c0b21d00fc5d6',
 '5b3c6ef2684fc55b4f5f',
 '5b3c7312fbabc86dd76c',
 '5b3d6186b7753cbd7975',
 '5b3f87763407ebf088fc',
 '5b40d6d3ebde3f33eb5e',
 '5b41f27fa9822cadf85d',
 '5b446992610efe262a8b',
 '5b46d6863413782c9e73',
 '5b4a50b48756a3275ee2',
 '5b4d85c2ea2ba4ae9549',
 '5b4df20b4ed92ec4a1ac',
 '5b4e8fbd7cacf10cecd8',
 '5b503b005e226dfd6683',
 '5b51ce03ebd938563327',
 '5b5553405e72f7271d64',
 '5b5b4fb7c4912260757a',
 '5b5e8feb87a7331f51aa',
 '5b5f6f9328ca7263e070',
 '5b61f0c3dd5c634081e5',
 '5b632a4750d29071c709',
 '5b6984696ac106719eb4',
 '5b6befc0d058af7a5b53',
 '5b6ddc65671e652f37b6',
 '5b6fae2fa955037f8c4c',
 '5b71165d86b0cb17227f',
 '5b75875caec9afae7212',
 '5b7d98ccc92c0fba4407',
 '5b7dec2943d26f82c017',
 '5b7e24c28d230a2d986b',
 '5b7ec50fa3c6f27d2acd',
 '5b81bdc8ad489a5406a4',
 '5b81ccb16e0d70df94c4',
 '5b84d4133b0f477aabb7',
 '5b8528fdd0bf4206f823',
 '5b8a20c1b588b5efb9ea',
 '5b8d4d80fdc44a39da34',
 '5b8e3fe8fac66d6e195a',
 '5b93cbdccce4826db5c8',
 '5b93f53e0ff0253a6736',
 '5b9533412b5932164a5d',
 '5b9789486d6456eb1bf8',
 '5b97fc34a75ee33667fc',
 '5b99e44aaf9eef0c75a5',
 '5b9b44d1f9be034263ec',
 '5b9be9635af67c19ac71',
 '5ba43442128bf0955383',
 '5ba43e6248f32f8ba52f',
 '5ba8c5de13777eabea8b',
 '5bac0a66bef1a1d5dd33',
 '5bb6b2b32cd8045b0e56',
 '5bb96eb501b67efadb08',
 '5bc0210853d170d5a033',
 '5bc593ddb3c72f1c2396',
 '5bc7093ffec13453a101',
 '5bc8fb9db5ce51f6b054',
 '5bc9a63d466219e25418',
 '5bcf39d043523763cbe1',
 '5bd14d95c8c85a3e73c0',
 '5bd28af8b5b173104d07',
 '5bd3f11e63c8f0698ff1',
 '5bd57044d356b1dbc226',
 '5bd582446282cd0a5013',
 '5bd5c9c5eba7ceb58c97',
 '5bdb19952d2f9998c6fc',
 '5bdba22d1e22a7c23458',
 '5bdc29e242b2a3924190',
 '5bde8fe93eb20ba412b2',
 '5bde922e0c81c7859026',
 '5bdfbe3c7b8c598c2fb1',
 '5be30a7b1d754d1f87e8',
 '5be4999aabfddc887a19',
 '5be700139e0cc831e3ff',
 '5be80110f8ebd8bd7926',
 '5be826add26aacf4f076',
 '5bea2e06908a58dea22e',
 '5beb57480cb447223868',
 '5bec5ddf3154116b7f36',
 '5beec6808e6be254a8bb',
 '5bf51b32085f0b6165c1',
 '5bfaa3328a4da965f4b4',
 '5bfde452103238f35375',
 '5bff0a878b0b0c1007db',
 '5bff7b16936a41ffe221',
 '5c012909cea705550576',
 '5c06d3a5f6de610197c2',
 '5c076e4a59b8719702bc',
 '5c084533cfccce635d40',
 '5c0c2ba51572623e4216',
 '5c0d20739fc40fe05fe3',
 '5c0ddc05981588d8b146',
 '5c0eaef5995c7f7e1997',
 '5c1608a2ce9fab02232f',
 '5c1df3f85d300ee71d42',
 '5c1e26e8b6595da3e9a9',
 '5c1f0f3f8e13ec3fca86',
 '5c223bdbd09ba793fbc0',
 '5c2420aa75e422f39bcc',
 '5c26a48a6d9176c8766a',
 '5c273973dc458cb2a270',
 '5c2901912b819a2f38ea',
 '5c2c25f7947ae0fd6cbb',
 '5c2c541f975d499df723',
 '5c314060a5e4cb25ebe2',
 '5c32bb1e9f6306d64986',
 '5c33edac027ab7665e5d',
 '5c38ac437ba05497cc07',
 '5c38dedda6826de08609',
 '5c3d51edc7f682b08a7d',
 '5c41bfde62ec10922ca6',
 '5c42dc68f7bc80a6a301',
 '5c4417808eadeed2fbab',
 '5c47ed472d8cddd4a424',
 '5c487af9ec48b0e2cc21',
 '5c49423d71baa7248885',
 '5c49768378e0fe1e2c13',
 '5c4b06536f5ac8a7afb7',
 '5c53e7dd596d6186a73a',
 '5c5628b4440280e953b3',
 '5c5aaa5d52e70a5fe628',
 '5c5bd135654084b3eee5',
 '5c5cbde26dd372a76c1d',
 '5c5eda52d6221714facd',
 '5c5fcbc5f7f949f90fe9',
 '5c6368b773d16a32cd8d',
 '5c65b66350819ec10fb6',
 '5c6800a0219ea090b56f',
 '5c69a7e0703cea120654',
 '5c766617805928903b2e',
 '5c7719babc53b0401138',
 '5c7cb6c13742026f3abe',
 '5c7d8c75e7bc4cd95f6e',
 '5c7f206fdefe160cec5b',
 '5c829edac174ebb5389f',
 '5c855610f27c3e7b5ae9',
 '5c8656e21a50e3cc89a3',
 '5c8caf1d9d1dc2097b8e',
 '5c8d052a8cc5a9f832b9',
 '5c8dfb89cea9362e20f3',
 '5c8f13be4bdeef6646c8',
 '5c8fe0ca396a3053adf2',
 '5c91136ce3c9df1e32e5',
 '5c927d6762823b2107a4',
 '5c92dbd4dfcc424bd7d8',
 '5c98c9729755dfbc7973',
 '5c9b40b4c9afb225e23c',
 '5c9de7474ae51388ef0e',
 '5c9f1a1aee2aa2c0c8b9',
 '5ca2e8f8925a1eed4450',
 '5ca79df7818bf4600a3a',
 '5ca7fa89d18d9418182c',
 '5ca921e3e6c539ba4753',
 '5cae16893dff9cf5ddb8',
 '5cb03c85a52035cc517a',
 '5cb23d217f62c74ff00b',
 '5cb3e4dcf1addbf633b4',
 '5cb704d6ffb615051c97',
 '5cb7f034ff4827e8bdfa',
 '5cb826f57184db221397',
 '5cbacc8c8732c6844fb3',
 '5cbcfb723598e1f7d4bd',
 '5cbe151c913d39b2c144',
 '5cc087e567574e79290d',
 '5cc32799140b66a5f2fe',
 '5cc49c676f7321d859a6',
 '5cc6558c2d6abb501ce5',
 '5cc9aea4ba0bb5e6977b',
 '5ccf4a9ab9382e5cadfc',
 '5cd0e640b7eb61df5cf6',
 '5cd3105acdd3358cb37b',
 '5cd852e6a1d3fb3039e9',
 '5cd8b518391636c8aa0c',
 '5cdd0f624cfd2e73c62b',
 '5ce71207f803dc1e80e4',
 '5ce9c40d04bff74a4493',
 '5ceac63e4024a9c5aa73',
 '5ceafa9a65e0604387e1',
 '5cef2230edc0fc9f72d8',
 '5cf819d87a12bd31adbc',
 '5cf8c4de162f0ac8ea6e',
 '5d00d2d15ebf0b1ad038',
 '5d011a41d317a856e85d',
 '5d084ca4f82e6bdb22d9',
 '5d084ff13042808d171d',
 '5d0941f2020a958c66a9',
 '5d0c75948a6f1eba3305',
 '5d0f103d4c7274755cb4',
 '5d0faea3f0e4b514a1e0',
 '5d10548595b4ceed96fc',
 '5d105b41a793f8fcee5a',
 '5d10eef1b8c5b43140dc',
 '5d11cedfb7e15b307e12',
 '5d19641c66a7b8005e40',
 '5d19d6eeb33cb0e964a8',
 '5d1a9e17680d18a879da',
 '5d1ea80fd4d95d839ae8',
 '5d2261a6d399f191204a',
 '5d2487d320bcdd56d52f',
 '5d2508f857e67eea0d7d',
 '5d2815a19c6c3974b8c7',
 '5d2c613c07456b9ac04f',
 '5d2e6248ad875e5f09cc',
 '5d2ef806f50ba0364e55',
 '5d32ba878cf6b7a9af53',
 '5d3638783921ba4d6596',
 '5d39a8375d0958651fc1',
 '5d3b6637e865e8383e4d',
 '5d3d077645d835c4176a',
 '5d41b38a419c8f8f3a77',
 '5d41d50e712e74f6dd26',
 '5d4694feb5eea5bc23db',
 '5d4a01db150f088be00e',
 '5d51977231cb93bdee0d',
 '5d577f0f3c328d91e5f9',
 '5d5b5d68185b1ad6a2bc',
 '5d5cc0ee600118b23b76',
 '5d600c08aa8c62d6b043',
 '5d6552c9461199bcc14e',
 '5d6b76d8c728e2fe9e5c',
 '5d71ec519c33fd6e7612',
 '5d792b7a201e8c0c363c',
 '5d79ab8f8a7af819060d',
 '5d7acce64417707919d8',
 '5d836538e87e21ace147',
 '5d83b8f0500c56fae90a',
 '5d84d63a033380dde3e8',
 '5d88334fb1010b0e0869',
 '5d885c7228e3cf1f864e',
 '5d8af0c794a9991dfb1a',
 '5d8bb86df67214a89f21',
 '5d8eae9c956a5d5cd248',
 '5d8f311825f970645177',
 '5d9f9cf1a890da985217',
 '5da037a4467be90ec2d1',
 '5da42641f075125e3a30',
 '5da95d453a0a6bf6aa60',
 '5da9c8f5f95a50fee93a',
 '5dab8d7f1bfab2f7e51c',
 '5daf51fb51cdebf7a3b7',
 '5db0174f602b3989b683',
 '5db71960918caeb2f183',
 '5dc00f226fc3e61ccda7',
 '5dc0d9b0cf69f5975eda',
 '5dc144ae29684bf40429',
 '5dc2b2f4e2955b4b6308',
 '5dd14f05eefc41b1d10d',
 '5dd327205ed7459ba2f5',
 '5dd34c5c2f1a55db0692',
 '5ddbf2532dfc0923d9e4',
 '5ddced340f44d846a006',
 '5ddeb00c496695dcda20',
 '5ddf8ed1be3ce1fe90da',
 '5de285c44e4564541268',
 '5de2e1cf6a238de74f03',
 '5de4f8249936a01a3cbe',
 '5de922eb4f1d8463ade1',
 '5de94544ab3fe03d678b',
 '5dea0466d05f26efaa3a',
 '5df2079ff04f484ae984',
 '5df556fa7ec03cbae14b',
 '5df5fff289297dbd57a7',
 '5df7c330df70deb5504b',
 '5df8348bd880c40235c9',
 '5df9793ccce0a7eced71',
 '5dfbb953a3035c1ee6cf',
 '5e00827fa67f674513c4',
 '5e033e65af9e3fc5ef0f',
 '5e03ca59a9e808bde80a',
 '5e05aa1a346f88153f99',
 '5e0917cabdbd1809a608',
 '5e0b792ecb594f10f29c',
 '5e14ee9b98a7769baa05',
 '5e15ec51cfa5d8a36339',
 '5e1df58adaec847b50de',
 '5e1e2db0163d267576ea',
 '5e1e999298ed70d6ccc9',
 '5e1fbbdc8e1ab1dd5998',
 '5e2060766af239ae97d3',
 '5e219704b972296bde72',
 '5e26597a3354c3caedb8',
 '5e28edf27f9b8e18c1c1',
 '5e2aa474263ff29e8dbc',
 '5e2d79b7b53e67be860d',
 '5e36ed8cf16d91fc5e79',
 '5e380a53ea4a1fd52507',
 '5e390d7f571e365b67af',
 '5e3a0af5fbada51f69aa',
 '5e3a2de97049661fa55d',
 '5e3d5d3b2b2d53f32f2a',
 '5e40412db9341200beb7',
 '5e41c7314daa5e60633c',
 '5e44a5c42b65792c19b9',
 '5e46474b5c94d187cee0',
 '5e4710b0d35567885447',
 '5e4b485b7c433d07bf68',
 '5e4cc29e01aae95fb2eb',
 '5e4f10ca4e292efea9b9',
 '5e57164bc8d1400bdb1a',
 '5e5740f22aef1bb1cd8b',
 '5e589034be3914a5edae',
 '5e5a2d7588e413185d45',
 '5e5aedc98cf8cd1aa706',
 '5e5b47b0b2a31fe30d38',
 '5e63e7f9b1835701d66e',
 '5e64c015773ece165d4c',
 '5e67d90b593366a88997',
 '5e694a72793042373208',
 '5e6f3510543595d4f0f3',
 '5e6f45a25b92472fc9bd',
 '5e71db6a4ff7a080777f',
 '5e73e274b476cbe69cd3',
 '5e7a2aaf63e1b872e239',
 '5e859d85158fd1617525',
 '5e88fdaeabd559c5ab5e',
 '5e8a726af36dfe856326',
 '5e8ae7fe8660f769f21a',
 '5e8bc9ce342a0dfe643c',
 '5e8da4cae62e9e15e783',
 '5e9076a7ffc2f22be862',
 '5e96dac364d093a964b4',
 '5e9b113e5cc0d867e394',
 '5ea05b0576ebde56ef3f',
 '5ea427ea1cf2b32bb5a9',
 '5eab46e4215eb9d4a141',
 '5eb37f5d29fcbc5a013a',
 '5eb5026a80e3864a32ca',
 '5eb5d5a249c4939987af',
 '5eb65627137effeae436',
 '5eb9cca67e9b1445cd2b',
 '5ebbc78e508ba37a68b8',
 '5ebc19f45bdd864467a8',
 '5ebf8e475eafca2db928',
 '5ec0547be7a3260fb72c',
 '5ec2a96244822b5ed0d3',
 '5ec82082be026d4df137',
 '5ec842a254e03392d1fe',
 '5ec8e8de78e0de258283',
 '5ec91766492c00129891',
 '5ecd263ccd4525b12215',
 '5ed0d7cc3dd6df95c1af',
 '5ed38ec17e8c4bb67701',
 '5ed42dec67bb665f77dd',
 '5ed8ab72ee6b6ccb1994',
 '5ed8d74b6f9b0347226f',
 '5edccf7e768f7665fcc8',
 '5ee2f678d400866f3a55',
 '5ee4bc69df4c5143897f',
 '5ee6d9c3f93be7eb0379',
 '5ee8fc33f2c2c72e150f',
 '5eeb65a1760e08c0ebaf',
 '5ef0f923038335e73399',
 '5ef197ee7031390e21eb',
 '5ef5cbd71181c04bd68f',
 '5ef81b1a633abffb1fea',
 '5efa117a16438a00f943',
 '5efc7b4af56984cc8eed',
 '5efcb9204c7184be892a',
 '5f0052b93dc0069c8d78',
 '5f045f97cc80e086d27d',
 '5f0595b402a47a46808b',
 '5f0831e665f889421a9d',
 '5f09432cb9543190a1ad',
 '5f0c2930b653c87b7fc5',
 '5f0c45d52a454d793811',
 '5f12ff1d93cbd7be2506',
 '5f13fa901e80edf8709c',
 '5f171c72b3afa68fbf24',
 '5f1fa22e3cf535c6df16',
 '5f1faab56504342bc132',
 '5f204fd3a79a64e2e915',
 '5f24da8d16dbe3ef9c40',
 '5f262105eec10c60416c',
 '5f26286c1b972a29c460',
 '5f26a017224c427af00b',
 '5f2a02643dde1956afd3',
 '5f2d9dce3dc61d513cfc',
 '5f2df9ef8d7a8d8b5e96',
 '5f2fea7b21503587e229',
 '5f32ac6eac4cebae9657',
 '5f34fdfa233dad5b6d86',
 '5f35514536b844579982',
 '5f35763f4c84cf24cacb',
 '5f3a2bee290f39507e0b',
 '5f3ad4bd0841c5ea4e72',
 '5f41f2116a0b425f12a2',
 '5f4519ef41fa530c261d',
 '5f47e832d57c9c637416',
 '5f4ec5ac8b17ef36ed06',
 '5f50749e1d161296eef7',
 '5f5149fe67dff2d5d8e4',
 '5f551bf4d141b5d17bae',
 '5f5648fd6fc22914e938',
 '5f5dc487a48a40b62a83',
 '5f618c1867d4fcf7e3b2',
 '5f68d99e4549107ebbd4',
 '5f6c48722c9df76e5b54',
 '5f70f130c79a54ea21f2',
 '5f71b671ce86964a0318',
 '5f734a43f07553d57b20',
 '5f77a109897d9c260812',
 '5f7929a41f659f50f397',
 '5f7fa58d75004316ea44',
 '5f8a855586d42823c722',
 '5f8c829e411b6efaea92',
 '5f8d381959ec8c770162',
 '5f8e9c8d26c2ddcf134f',
 '5f91c29ba38af5985ffe',
 '5f93c7e462ba9dc45c6c',
 '5f998764b4faf318aed8',
 '5f9e1fea4243f9e22bf4',
 '5f9ee13fbbfc5c1eda72',
 '5fa576166f2eaf34954b',
 '5fa6ab82272228e1bf14',
 '5fa92019e7f8cb472634',
 '5faa2d403dbc37d05d8a',
 '5faf25f51f89f6c0b582',
 '5faf8191d436ecb65d95',
 '5fb1a900ebdd0a6f3da0',
 '5fb475c48c0c8569ab16',
 '5fb765202eac612cfe32',
 '5fbd4493f8957d29bd96',
 '5fc0c0131f0573542ee5',
 '5fc48ab6f60631d2fdd5',
 '5fc7365b0c02a2d0685c',
 '5fc76d55719f07b428d4',
 '5fc887e9321db114176e',
 '5fc9275f5f79c48587d3',
 '5fcc730a18072d67c58e',
 '5fcc9d02451f53cb5a0d',
 '5fcf6cd681bd291285b1',
 '5fcfc614c196d4fc2fa3',
 '5fd081fd162a5f4e2545',
 '5fd14767881aaa750b92',
 '5fd22660b4ae31a19519',
 '5fd2b081e7f54a01cff8',
 '5fd3ce365acf674d11ce',
 '5fd43f19c5d6e2c09027',
 '5fd7225bef4490bec8ee',
 '5fd7350c328f28ef03aa',
 '5fd866ecf8555fdad9c8',
 '5fd88b7d07ec4fefe0a3',
 '5fd98274eedb4e55bb70',
 '5fdb4f95c77cc666ccca',
 '5fdbb8ead041d20afc08',
 '5fdea8b4d53080ddc46a',
 '5fe0723398828a5563ff',
 '5fe2e59e0cb99e05e726',
 '5fe3935479d70696e5a2',
 '5fe49a45f9a7f3e335d7',
 '5fe53a00b3670ed688bf',
 '5feb0d118a1df02ef358',
 '5ff2674216aec33fb8eb',
 '5ff51686a4612da13a34',
 '5ff74a5b794deb28e894',
 '5ff8c32327dce3ca9533',
 '5ffc07680922ceb646e3',
 '5ffc563eed244557d5eb',
 '5ffe2d1693152d7873c5',
 '5ffe95b4025e82471021',
 '60039f49a98954cf1654',
 '600559247764b9acc5e8',
 '6007143701b8000e5520',
 '60087b5abbb1358e4c30',
 '600ed356f20286e66eb1',
 '601908a20cf0253a508a',
 '6023c783715635585cbc',
 '6024359374561b3be217',
 '6026cd6a9cd3b6ed8f8b',
 '602b8395781b759eb7be',
 '602f6aff90162bf438f9',
 '6033a07e6cc2c0166c66',
 '603526c4da607de0baa4',
 '60360a02d62ccc0db8db',
 '6039659bd239b7ba0822',
 '603e58b083fe3ae70845',
 '6048f8874369c49b15d7',
 '604e4df20ca28ba7d79d',
 '604f04ea8dc961a10105',
 '6054ae5651c7bee90622',
 '6054bb9ae64c1602672e',
 '6057d7a29222546b0aa0',
 '605981797c9760c8293d',
 '605a251e1767216c9b9f',
 '605e849fa8d2557a88ab',
 '605fa4aa66eab979fbaa',
 '60614727a4d348677f27',
 '6061ad50ed36c120a4ab',
 '60621a1b1a43e6a0e47a',
 '606807b5fdd11cb36edc',
 '606a09566fc5e5faa91f',
 '606c9147615071aba170',
 '606dc12af5e702d298ca',
 '606dc588c5f467d840ba',
 '60758299a53b588f4be8',
 '6075ffc9f6cfc7e4387c',
 '607cd05dae355ba1988b',
 '607ebf3272ea7963e834',
 '608a7a70058b9ca1d937',
 '608ac7e02b61f0d4d976',
 '608dc220937d215cf445',
 '609173939d4705b89b40',
 '60920a2a56c7990b51db',
 '60923c90d0e53bcfff57',
 '60977a7e412e5c4eb022',
 '609931ce3cf7bcfdb7e3',
 '60a1d11491c920e0b801',
 '60a25919d3f94fa35131',
 '60a2678af0a51ecf92a1',
 '60a3cfb476da41b16738',
 '60a3f137869995b00766',
 '60a565e64298424c5a96',
 '60a5e083b518983446bb',
 '60a7ac5a90bb11b10800',
 '60a812c46f4bd960a00a',
 '60ad774c314f0dee7dfd',
 '60addda24e992a446e2f',
 '60af10d1e545e7ccba51',
 '60b0ef4fb7569adf843d',
 '60b332978bb17aac7d0b',
 '60bbfd61206176b3afcd',
 '60bc4783768a202cf7d2',
 '60bd48cc895eccd020d3',
 '60d83995c7ff1e923584',
 '60d97fec5744383f2d64',
 '60d9ef2a1c86062765d6',
 '60da54b586f8170e390c',
 '60da68d362cc497394cd',
 '60dc206db56a78c30c87',
 '60e26473d541e9140ebd',
 '60e2d6b39cb51ef6b7ea',
 '60e42697062435b5d136',
 '60e4834a9c0311b88135',
 '60e4e41973e751166838',
 '60e61b82d4ca643ec41e',
 '60e6f87dafc744020725',
 '60e8dd00a4fbcc23dbf2',
 '60ed71aa50c3da27e7dd']

# %% [markdown]
# 10

# %%
qids_10 =['60ef89944838f13be61f',
 '60f10a38a6e7c1c97c72',
 '60f1ce6ff99b543a4dc9',
 '60f3b6dfde2d7bbc1300',
 '60fa1d431db3aba8c1cd',
 '61066a02be221c913909',
 '6106fe4f4472b83381a5',
 '610df28c0286fdd5960c',
 '610f91fa3e8f775e6c31',
 '6111d6b4261384b45c86',
 '6112a0317b7d1e1ca016',
 '6116ec772e6248acb058',
 '611a82d0b51f3369db60',
 '611c8c3dee62c0b2f0e1',
 '611cd42cd64359958e00',
 '612483e834938b24690b',
 '612988f140e9ecfcce3d',
 '612f027cb1652d81359e',
 '612fc264345df3e1b0d0',
 '613b55d5369390eea443',
 '613dfa1e28667a98cbae',
 '6141bea8fd40335c4bbe',
 '6143c33d3fb2b483a419',
 '6143ce7c8a215f4cb391',
 '61468cfbe6193cb0b1ee',
 '6147a65da96098fb7e30',
 '6148d0fd2a951b2c0138',
 '6148e53bf453b7c55092',
 '614b81f04c2d3fe69ae3',
 '614bcdb6706db57fd9cb',
 '614bd73f92e0978ca7e8',
 '614fe79f0a5c4fdf8259',
 '61533f3fdff090e3478d',
 '61564f4ddf0679839b5f',
 '61592e340f29f8bae2d8',
 '615b0313686016558431',
 '615bba5220b0d4b5a3cc',
 '615bcfdf0d8f20f5855e',
 '615cf8a243520c66f252',
 '615d7214f37cf22afdec',
 '61635ff6f5328e959490',
 '6163f3b618805b63e6c6',
 '6164657dcda309ad8c7c',
 '61657a5fc325840f4e33',
 '6165f102fc6a6868db55',
 '6166de270d80fe04a0a8',
 '6167fa221611f4bcc0fe',
 '616b6795f5ea1f4d71aa',
 '616d4573cf3920c34dc4',
 '617351ca51414c93e0db',
 '617410be5236ac976bb3',
 '6174701e6103c6d4168b',
 '617bc449fba5d165fdda',
 '6180ae03a45654fa2773',
 '6182c4f84156f0b52a78',
 '6183f43dff821b2a5ff2',
 '61848d8c3f7b959f2a92',
 '6185d3e7a1a5329c48dc',
 '618775ac8e3f2016895a',
 '618db282eabbac888279',
 '618e347680aafa6b5ef7',
 '6192478d702ef1545348',
 '6196dc6239bed888e6b5',
 '619a038b3589d00021b4',
 '61a0f8cd4e726101ff10',
 '61a46b26ad7e656bbde7',
 '61a4ecf7c356664c062c',
 '61a534d09bdcaf7d567b',
 '61b160626d3636ef1c6f',
 '61b41c7f59f41fad2f9b',
 '61b9528430e6a96e1244',
 '61bf52238e5af5061fda',
 '61c0cd9e5ff905dfe5c4',
 '61c46fc0297ba215a8d8',
 '61c5722840d222200272',
 '61c683dd527519c8ecb2',
 '61d4a731039ce7ce8a05',
 '61d80cfe687ffa607321',
 '61d8261780e731b12bea',
 '61d9f14a7997c28a2c8d',
 '61da351605a5318926d8',
 '61daf552f56289d14cd7',
 '61dbfcbc91a1bace05fc',
 '61dccc6fa91b17bedb05',
 '61e1178b4d8957f6b0ab',
 '61e1782e97a8c178efc9',
 '61e44f90fcd1c5c282cc',
 '61e4f050f8cf855489b0',
 '61e53c60462264d5f8ad',
 '61eb4c0bc30a3e9c0a65',
 '61f06f17f17f025a5f10',
 '61f21d72df5641606ed5',
 '61f21f22b33e3540d62e',
 '61f30333a619c5d24a01',
 '61f5255c93b471f89da4',
 '61faafce6ea0765546bd',
 '61fec73881ccd134ad67',
 '62008c5dd8149faf46eb',
 '6201074bf5e35426e8f9',
 '62016619ca6a5f62c4a0',
 '620373796941583fae7e',
 '620aa4bae2c70503d404',
 '620c6bfa36b18ce24ae3',
 '620eeda87d19c15b64c3',
 '620fb113e9de3ebd9b5b',
 '621200e2453d3ed16fe3',
 '62176859bb566920ac9e',
 '62188860774c773af943',
 '621e79ec0dfdda0b866d',
 '62208851a3e28efe01cc',
 '62215fe4710dabd032d4',
 '6228b84e0935fbf655cc',
 '622a579ee0c47c2710bf',
 '622c95a9af6319334a6f',
 '62306c3f89fce2ae311f',
 '623189deb8bdd5d815b4',
 '623269bdc95a346e6f5f',
 '6233620356882fc8ee7e',
 '62353c594610e69206f3',
 '62354298f186e005c3ba',
 '62370e878296962f338e',
 '6237b5ffa9c5c30b3f04',
 '623a45519f39c20d7742',
 '623c18b4030b9a402e36',
 '623eb380a319e77be5c6',
 '6240ee0505367da34bac',
 '6241c2e0462dd9a8d18b',
 '6243457ce4a3e065cb34',
 '6244030021c0d7ffa82a',
 '6246a71150830613b228',
 '624ccc1be83408792f78',
 '624de16e216b58fe1b2e',
 '6254b1d428ed334958e5',
 '625a006edd8f140398b8',
 '625a4d1b51c7b32ee986',
 '625b359ae50a399aa765',
 '625db7fcc1ebd279b1b8',
 '6264ecb38eda9ac64dd0',
 '62684bf4f9ecc55be355',
 '6269e3e620cad224998d',
 '626c2fea410f95a81183',
 '6275fae9e303afa8340f',
 '6278472fba42f7e7cbe9',
 '627998daa8ec41189346',
 '627c75eabedaa3ef8cfc',
 '627cc3bb4aee01627e9a',
 '62879651216aa0a721b9',
 '628a21b1120a10a242e0',
 '628b6343a955dd952bcf',
 '628f301cce030acd2c13',
 '6291b911e2e9e2d49150',
 '6293039a417d8ede596a',
 '6293b4b752e98f7f5e60',
 '62946a78fba6e5f29796',
 '6299d01bceb06a930a40',
 '629e3a372a865f5d667d',
 '629fefbc53bbcc6fe695',
 '62a004a57f7179ee15b0',
 '62a094300392c9acc632',
 '62a34285d55b5a8c53a5',
 '62a8e16fa013a3888720',
 '62a90ec831e5901e3ada',
 '62ab121aee1e5b7b925f',
 '62b0f5fb16921b0a628a',
 '62b24d7431d1235df938',
 '62b81f27d51225c70cc5',
 '62b9cc7462d8a0c8f415',
 '62c3975b40f3a753f172',
 '62c3d88e46c64f74a5c6',
 '62c3e8ca5fe1dcf9b1cc',
 '62c7c9b961a69df4a915',
 '62c82f5bd04addd9a03f',
 '62c92c46e2dd852f4407',
 '62cc4cc9bbc2ace6a286',
 '62d369d2c067fd6d84ab',
 '62da5c997aa058e2ff29',
 '62ddb7e51686af686668',
 '62e0c430b6624ed0e010',
 '62e502ed93ee7712d9cf',
 '62e5305b0cdf5ca128cd',
 '62e57e2324bf62daf6ce',
 '62ec07b98245d6196c65',
 '62ee568032f7b0f24acc',
 '62f01ce8da863a0a5aa2',
 '62f2b69f8a2d28081ee1',
 '62f39deb128aa5ea18d4',
 '62f6f7e507bd50336547',
 '62f89636b155bed24e81',
 '62fa571b6df69b0b1c9f',
 '62fb3972796fd8b8e035',
 '62fc38f68b4962a410cb',
 '630096f18082391642a8',
 '6302d67bdd7a281aea9b',
 '6303f0d79725bf3525b7',
 '630ce93bb75ea26f6d09',
 '630f2e5028e9f625da77',
 '6310ea270be85dfe4aa9',
 '63121fdacc8169b338a0',
 '6312656f2c598d6d18ef',
 '631615388b2e78d32e72',
 '6316afc94a41617fd89d',
 '63194f4eb0b38d8d6ae2',
 '6319ca47ce3a22bae658',
 '6319e3291e77a3db96fd',
 '631ac4cad5e6f89f5083',
 '631b62c3287825a836cb',
 '631bbff88b97efa63d5f',
 '631d4cce717b85f6d31e',
 '631e9abedefe48c9cc8a',
 '6322d069d6b141db6a0e',
 '632463e4f31d408c0d6c',
 '632564e2f7b0cbf01ace',
 '632943a0f9b1bf2c3880',
 '632bfe82a8b6baee9018',
 '632e2a41285b7cc7ecd7',
 '63331919f907d9971503',
 '633bb62f960b397200f9',
 '633be65ec018e57fac25',
 '633c11077c7abf181696',
 '633c49e46f5b6120d529',
 '6340cae7a8d89c070e19',
 '63440bfb836d8cdb96e0',
 '63449967eda502408d3f',
 '634684f57eb650a0c278',
 '6346f22f194116a36a0d',
 '63470c5bd421f19d671a',
 '634a1c3799c937418b13',
 '634f1a7b29eef794622f',
 '6353b2c77def59a2cef1',
 '6353f85e2b8b75e59bb5',
 '63544df8f39a42c295a7',
 '6356b9b80c64c3427bd9',
 '6356cb849a487748da25',
 '6357f957cdd474d05235',
 '635973a0bc8395716c34',
 '63598befdeea103e34f5',
 '635d520aa8b25ffdf8db',
 '635dee805ee4078e91ed',
 '63631aa078a730eec2a1',
 '63635b2f2bf6ff253f22',
 '63643d2d1dc9c9443fca',
 '63678a97abecf505cbeb',
 '636ac8625685ea4f7b02',
 '6374e8ac36d3b6336105',
 '6375c4bc1cb0a787e980',
 '637e8c1022956245df1c',
 '638118c11ab9d2a5da40',
 '6383a7b42e2df9982eff',
 '63883a247afaa551ce84',
 '638a44587fb2448e5d93',
 '638cb5da3e6d661c57da',
 '638e184f98d3a9e5c5fd',
 '6393b9d4a864ad011cb2',
 '6394f6b943c18035b565',
 '6396e4fa5fecc4873a5f',
 '639984d20afede006dce',
 '639993dd861a31e4e5cd',
 '639cdd60da651a3cb14a',
 '63a7195dfb027833ce3e',
 '63a8c05cb2b9ba58c3ea',
 '63adca31721364d79a94',
 '63b224668b3c1d0d0b26',
 '63b47693ed9a920ed324',
 '63b58b962adbae42bda2',
 '63b5b40f983153ae941e',
 '63bc3eff51da7ae4a948',
 '63be613a0a41d483807a',
 '63c3a416bc081fc0e7b7',
 '63c55d3e92473cb4f126',
 '63cd85ca86220cb151ec',
 '63d0f0db33bdc6b54af1',
 '63d1e680be81ca6cf63a',
 '63d28704553f6dc149f1',
 '63d411a62caa77e3e1b6',
 '63d7959684e1bc9144b9',
 '63dbc1512b3526a98dd4',
 '63dc8134c49ff497bebc',
 '63de09b3e497669ac9d5',
 '63e1bc6ced64557ad59b',
 '63e5184405c94707d2c0',
 '63ea236b090d98ba69eb',
 '63ed944b8bddb31f360e',
 '63f06fe4a245202152bc',
 '63f447e5706145c3bef2',
 '63f636266bcdfc4273d4',
 '63f8e8485363014a76c7',
 '63f997486c1c075e5216',
 '63fb2c82afd9632502bb',
 '63fd8734329e64ce90f0',
 '63fff827ad2985ae031a',
 '640032238c5b48ac9e77',
 '64068da86f13f7b97124',
 '64084e2bd5be2b963d3e',
 '64097082b62b0ea796ec',
 '640974235b7d2d04361a',
 '640a1d1cb60193750185',
 '640f1aa4fb855d308b80',
 '64105b407a5b57448d11',
 '641221209cd8e0f563a8',
 '6417df17b81dac61d6a0',
 '641d43f32b43c258d12a',
 '641e3f7d3df9376a6289',
 '6423efde8d4632c6caa7',
 '642abf0ab82af58f3eac',
 '643846bc31efea64ab94',
 '643d4b9067ce61331308',
 '643e15500796f447ea2a',
 '64410f0ba3b4c8e60e1e',
 '64506f401c9c540f6158',
 '6451af2af7fcd9835ba8',
 '6456b23958ee24bfb082',
 '64586b376ec4987f4a2c',
 '645ca84b7bfbd3e0f20d',
 '645d2520a2b2cabc7948',
 '6467d31b94100e1af9aa',
 '646b3ffc41cea54a0927',
 '646bdb8d74ef812bdcfc',
 '646bf8e0500de8b88e5f',
 '64712f498e84a2b9c7f4',
 '64738d2712135658af07',
 '6476a79d9fc6d86d5b52',
 '647712dbcb860fa87f07',
 '64785308270f30afec5b',
 '647a78a8ad956c657c48',
 '647ba04148a8c502d9cc',
 '647cfd88fc1b139b85ff',
 '64806bf8e98c45d1a8ec',
 '648072264d943a33b7a7',
 '6483a1b4e7f178b9df6b',
 '64870e9bf37f0fa6f82b',
 '64885de5efc6a89213aa',
 '64897281a0093e79bd03',
 '648a087b3fc4383d0791',
 '648d439dd9040eecf4c6',
 '648e860efedce3128f67',
 '64956190b95f1b835aab',
 '64972f8af25c8590fc9b',
 '649c4d281477a73fab45',
 '649cd365949afb683d8c',
 '649cff8d37bd6b8ecabb',
 '649dbbf6254b45db82e5',
 '64a0d2038f84cb90edff',
 '64a71fa01ced9902462a',
 '64ab922b92eeddbbfb0a',
 '64ae60cbc89ec36bef75',
 '64aeea768d608acd93c0',
 '64b0031db420908dae78',
 '64b4a7c49bf14cbafd1e',
 '64b4fa9a9d40d1309a3b',
 '64b680a8c3d2475ad3f1',
 '64c140f1a693badf0ab7',
 '64c1a9c448c46d47cd51',
 '64c422281dbd11319434',
 '64c4e48ab181383647ec',
 '64ca8604c790b4446b8f',
 '64cad34ddfe9ae3b6920',
 '64cdf51c2b733081d4f3',
 '64cef52eb338aef517ca',
 '64d523c8497ceed05702',
 '64dc2e2e4f7d51055cb0',
 '64dcc8ce6fe0ce04939d',
 '64ddf78a51ec775825a8',
 '64dec9c1fc687d5d4358',
 '64df1f204a95e01eeeb5',
 '64e1ba152cb7a75daa87',
 '64e210ca9d84538e61c5',
 '64e2a8d625f566f73c3d',
 '64e4c89ddd6890265b80',
 '64ea534d1068f9e8e4ab',
 '64eacfb0e288af3f490b',
 '64efc895aabcc3f2f115',
 '64f118167b25877b6473',
 '64f24b7745f3c0e59572',
 '64f711c8aaf587f3863d',
 '64f72a355780a5c04d52',
 '64fcc3d7f71434b6831a',
 '650bf60e9ffa97749a40',
 '650cc33b705a44d6f10d',
 '6512b38d5c21dc97dc0e',
 '65137a781c529c91635a',
 '65151032a19fe0af5c54',
 '65151c00b860e10f7361',
 '6516128e07fdb92f50e2',
 '651c5ac46ba1e7f5d87a',
 '651d88e8c822d3d0e61e',
 '651dc6aa80fb77b73bce',
 '651f9dc859f13e71e97b',
 '6520199dc775282e9b22',
 '6528393fd9f9afac3bdf',
 '65293f505f62076df636',
 '6529b8122266cd05859f',
 '652cd017e3d84efa13d3',
 '653427397e4dbac64cb3',
 '65375c38e802959d4c94',
 '6537c13e7143d94c5010',
 '6537cfec4e4590eef4b9',
 '653869c705b5f80c29ff',
 '653b1391de6ad2d1183f',
 '653cda74c08884be177a',
 '654088c23100b7eba96f',
 '65410478b103611420f3',
 '654af8ec04f487682521',
 '654b2326bd8bdae02023',
 '6552cb043a92b841ab0a',
 '6557bc50c54c612269f4',
 '6559737d5a0966131f0f',
 '655c381c8fc8cc803eae',
 '655ca71f081a4c706b1c',
 '655ddf44890d1e36dc10',
 '655eb237da811c0f5b23',
 '655f5e87fb9144331c13',
 '6560ced4228032cb3c0e',
 '6560e77efea347e259b0',
 '6562be12bf7a1ceb94aa',
 '6567f0e93b17c30d6bab',
 '656ec6c8091498877c01',
 '656ed15ec078339feb71',
 '656effcc1fe034b795aa',
 '65728b786dcecac79de4',
 '65798058084711e045ed',
 '6583219701e7f9d82bea',
 '65839161ebfe3c5f599c',
 '65883814e7468cd227c2',
 '658841ab9bd5c5fdbdb5',
 '6588daf61a12c5bc3c57',
 '658aaf81d2ea368d61d7',
 '658c6e29af11aff1d752',
 '65996ce1a31b0bd387fc',
 '6599e946d5f75a040870',
 '659b69914123954ac8a1',
 '659c4d8eeb02b1b296c6',
 '659e2da58e8c704ec693',
 '659e65ce2fe7200f95bc',
 '65a0df320a292c8287a9',
 '65a39d4b3dcd5a382bae',
 '65a7e21677ff34da0137',
 '65aa355f10035d0b7d9a',
 '65aff2a049cc4b09d4aa',
 '65b23cf93f128d0b6304',
 '65b4993c6aa916c1c559',
 '65b7c6b3fea0731a30b7',
 '65b95d8b57c15b11c583',
 '65bb228a731eb5eb7afc',
 '65bf75472bd270003f83',
 '65bfdff42575f2f87bca',
 '65c0474479bcac30cd85',
 '65c404657a9812ad057c',
 '65c5cb96c654012f836b',
 '65c99f839979ee7284c2',
 '65ce44f1de380cb5f777',
 '65d7f6d90143975c06b2',
 '65e2086dbb344850f3bf',
 '65e3366d0e83a23f92fc',
 '65e70d1869b3383d6c49',
 '65e7cd566beabbd89c1b',
 '65e843558449154bdde2',
 '65ea8d4996ed744203c4',
 '65eaf0fbd85128a4ff21',
 '65ed7036fe100ea5c69b',
 '65f00ae5790d080b5501',
 '65f09f2bc8b6f891c3a5',
 '65f21b650eb0ef5fe4c4',
 '65f3ee135b104b9d5964',
 '65f533c594a3ea773b6f',
 '65f6591c8aeac9ca2cd6',
 '65f909236367578c7094',
 '65f9926ae5ef83673507',
 '65fa3ab5ced91539ab11',
 '65fc0a4b794a50028980',
 '65ff1c9581920ab3f077',
 '65ff38bfa89d50f6df55',
 '66051f83774bb48f5147',
 '6606a08da7e849fa4e53',
 '6608f0bf8e5d1e122a90',
 '660b6b7f52257f6c5005',
 '66159b43f4293b81c6d7',
 '6619c856e1a1ae298786',
 '661c4143f8ddefa8522c',
 '6620b6c2d517ceba410b',
 '66242633a8a33280eae7',
 '662453f33aa0ddd00764',
 '662bc2bae57e11da320c',
 '662f14c6e1cf53de8120',
 '6632aec269e073550403',
 '66334f74b9e9231aac64',
 '663545223564ad4f6f68',
 '66356e4b7132809fcaab',
 '66379144d73af2f3085c',
 '6637d258ed113396bab0',
 '663b379008b571439103',
 '663da89858d75f684fe5',
 '663f100b92cfdfe0e101',
 '66448f6d6f06676dd721',
 '6646aa3deefc3abddc26',
 '664d437ca18b01fe0b0a',
 '664e537037ebda315ffe',
 '6652a03e68c47d30730a',
 '6656f6b0e875ecdc9c5d',
 '66579afeb269b747bdd4',
 '66589bf86d2c77c4dfe0',
 '665d163cd8427fea423d',
 '665de508f8260f30c7ec',
 '6661197e0d4b3b0439be',
 '66623ed76b15d60e893c',
 '6668994284a52efe1f84',
 '666a9a2ba542e637eaab',
 '666cf784831071d92ea7',
 '666e9ef64c5eed4676e2',
 '6672be866cedcddf396e',
 '667716487475cfb58963',
 '6679551d335bc00e32a5',
 '6679f07cfd6a7c501943',
 '667e75b8291e2f3c4084',
 '667eb0c63d2dad51b046',
 '6685a0162e3db1918fda',
 '66866f56f928be6d5454',
 '668881b52a1413c3b890',
 '668925a8dfaa9f347790',
 '668a0a5a09e92480f3ff',
 '668a7f78e11b6d8c739a',
 '668e56510e2bfbce048a',
 '668eab87edc7058b76a2',
 '6690902227fb72a0a1de',
 '669256ca691a9a4648e1',
 '66950b6189e8e12c3642',
 '669650941736c62a6bc6',
 '669a05fc4bcf3538b2b5',
 '669c5321a138e8d643b4',
 '669cd75a0a318be7f07c',
 '669cfa7aac0eb8b30299',
 '669ef24f839ad26d80a0',
 '66a0fd53b91bb8d60ac4',
 '66a5b19678f85ee9a960',
 '66a89e291bd64dc84c32',
 '66acbc7c98afa90e7ee9',
 '66ae190e5713b276a66e',
 '66b9a576e574878b0b91',
 '66b9fa4825908226ef9b',
 '66bb09f8479c7704f4c6',
 '66be1c8dad7d32fc4651',
 '66caf0399379d89bc151',
 '66cb815c349a52ab4b20',
 '66ce393a371737a3da98',
 '66cf0195983899274b65',
 '66cf3307a60c7eb5a220',
 '66d1bc71c65960ea8f9e',
 '66d293f40b23f66736c2',
 '66d322b1b31e67e0f031',
 '66d41e693e1d9074dc58',
 '66d558259977aecaf5c6',
 '66d6cc0338dd6d79bca5',
 '66d8d4acb83eccaf3762',
 '66e2c7a410e4144791b1',
 '66e404b283cdcb7b9be5',
 '66e408bdae272ff40bde',
 '66e49a24739fab2b9c5b',
 '66e4ca3a2c76d4ef658e',
 '66e9f005b022719f875f',
 '66e9f23a715813d16b89',
 '66ebb706f0286c1f95ee',
 '66ebc212436b9561cb38',
 '66ecb2471151df8e0bf9',
 '66f083fa500c744df960',
 '66f196f39eac4f96ad48',
 '66f267494a0c67410e61',
 '66f3e544b14d0fdd807b',
 '66f5599507b3bd0e8cdb',
 '66f7e47c2a460e0c788f',
 '66fbd8aa28ff707ea6f9',
 '66fe006506aa98a4d4df',
 '66ff4409f4a6df9f9343',
 '66ff9857dfb0809d64bc',
 '6705e41e83c5b49ca97c',
 '6708d49fd4cbafa74875',
 '6709efd289394efebf84',
 '670c674c7ddb8ca4a7c1',
 '6711733e75bcc7b8dd6b',
 '6713d832539bfced34a0',
 '671577b9714970e1843e',
 '67180708015ab23be6d1',
 '671dc0ffe3d77b7b0b80',
 '671dfd9ddbcdfb4ebc5d',
 '671e2104ac6bb2a99694',
 '671f5146cf815c693800',
 '672e14024af4b338fbd0',
 '6732875e5a5636f1315d',
 '67335773059200ac67a5',
 '67382fd6a9871d51f01e',
 '673a214abb6c8b9be55e',
 '674136a9d43d750fd8f2',
 '674551c13460503da844',
 '67457084c9e3104b4152',
 '6745cbfb782d96595e27',
 '6745ec6404473c94b2dd',
 '67471666ab4bb7cc896c',
 '67476a707692e494bc71',
 '674e348ef12e953d203a',
 '67509e7dfc2c29773a54',
 '6752cc60a397837fd4e4',
 '675a17e178feb9235d53',
 '675acebd272c322a8f39',
 '675b43e15dfe63d7e01b',
 '675e2c2d4973639e8584',
 '67613f1086284578812c',
 '6763234473a9def3ff11',
 '6763d12a4320aa215466',
 '676a9974c9f261200ce3',
 '676b1b26cd18f3eb0a19',
 '676b987f104f50a82712',
 '677575ee7118dc242835',
 '67793cef2bd1af6505f6',
 '677bd0490db1c17fed68',
 '677ddfd3776a58335334',
 '677ede44da2b6ab14edd',
 '677f431dd777387ea228',
 '6781cff7a45efed10d33',
 '6788407a1c37b36ddf5f',
 '67921c351d1b19cfb857',
 '67924d0e53c907860515',
 '67943f1ab2cc3710ed49',
 '67947fc4e83864e2ce5b',
 '6796f6edc534c624c944',
 '679e4741fb66f7a921f2',
 '67a0305b1b0d085ad463',
 '67a0dd0b79b0dd3e8d6d',
 '67a1443565673bbc5c3a',
 '67a17a5b629925d69d0e',
 '67a263bc3af3dda0b213',
 '67a332f63b2e9d2d81e7',
 '67a84c34064fc134bb21',
 '67a8e4116906d721b7bb',
 '67a9cf909670a423b6ab',
 '67ac516c01614f36039c',
 '67af4f45ee6e6fbd7a7c',
 '67b35df23cdf92589db0',
 '67b381b616a0eac56859',
 '67b51340ecefa7f9c78b',
 '67b9f716246cb92740eb',
 '67bbeb7e1dc306fce606',
 '67c56767a3eda2c2f135',
 '67c5d57b11fec4c33d79',
 '67cd3f91a3585ca322ef',
 '67d25988047e78e9818d',
 '67d3ed8314abecd10dff',
 '67d7d864023183ce4261',
 '67dda7afd7e43aafb5ad',
 '67e1d82bd8841221300e',
 '67e426c0c5446fb4e24d',
 '67e4689eb1ddf8efc40e',
 '67ea4c5ca8bc925a5e07',
 '67ea947921e760ad601a',
 '67ecc76b0f5a82b95e76',
 '67f238adb97a1ed24de6',
 '67f24b54ba0619296db1',
 '67f3cd4a2bfe73a037c8',
 '67f4569b9e44fb707434',
 '67f58eb7d252c2069841',
 '68024db9855273c050f4',
 '68024ed74d760b6d7fe2',
 '6806552d7b61928f2778',
 '680a2b2f18f098d67345',
 '680b94091985c011c6da',
 '68146cbe184dd0e2d65d',
 '681a33c1d6f1424f9aa8',
 '681e7a38a0d3358c18a5',
 '6821e19e2b9162918cd8',
 '68254360824c825da867',
 '68296581c82099770c6f',
 '683117e455f99fa1a165',
 '683383d7ad0481692503',
 '68354c7504ffcae9647b',
 '683b03e95d882edbeaad',
 '683e2d86d9e3d1340a57',
 '683ea7a20ae4da32d46b',
 '683f338ff87c43e03706',
 '68401db3c77f4c4bdcee',
 '684598615ad65d1866c4',
 '68479975254fd26d43c0',
 '684984ea04da3ad3d890',
 '684acf8dcbbf4df6d7ba',
 '684c91f130b393c28502',
 '684f19aa89a7a74ac482',
 '684f9d5135cedf4902f4',
 '6852d199927d6ecfdfc2',
 '68553c4490643b4647bd',
 '68571f745cf49989de49',
 '685f37fa524794a14593',
 '686540b5140c70afb8bf',
 '6868c118c2fd379a37a9',
 '686955d42da92c125fd4',
 '686c916ba6a9a407d075',
 '686cc165d7a09a1dfb1e',
 '68724b4adeb2a4554901',
 '68727388ae226ae6a1be',
 '6874f68c6ff85ef162ad',
 '6875cab7ecfc1a1858dd',
 '6876e1be98b8f324d391',
 '687961c2703e79887ebd',
 '687fb7ddf898b074dba6',
 '6880e48694ab208057ad',
 '6881fe21b34103198c33',
 '6884ce505ac10a2f2166',
 '6885dbd60ef194534a30',
 '68885c5d505b986f2a8c',
 '688b3fb80fa837a6058e',
 '688d42f3ffb953357926',
 '689058acf5ad284468d9',
 '689409bb76ff13a88b1e',
 '68954b8c62fac10d6e49',
 '6897ebe9a5805303b744',
 '689bf4f083c4094f32f9',
 '689cc2dc92af1ba37293',
 '68a13a709e36df0f7a83',
 '68a3c3787484617315a5',
 '68a4c30b92915c683656',
 '68a887065cef677b767c',
 '68a8f1bfb9ae33438f60',
 '68aa9e2add3cc0d30e42',
 '68ab0d3166470216655f',
 '68aff8e39a87ee205028',
 '68ba90cd7bd45d186f37',
 '68beffc5bc4dc08c8fb7',
 '68c041fae6c3b565c28f',
 '68c0a311f37c44b9be24',
 '68c4049f3ff6bb037e20',
 '68c5e691ae8daa2b6a57',
 '68c6ca8f3cf84f13c69b',
 '68cf71427ae283a30482',
 '68d007c42d5deb596229',
 '68d4deae1ab3a20d475c',
 '68d4ff4a1c7b7173ae9f',
 '68d9c48e5410c5709db6',
 '68daf3f6c15b6e4b0b2a',
 '68db4802ab6875e98fe6',
 '68dbf785cc25d168829d',
 '68dc6226e1f111603b24',
 '68dccadabef43f3febe9',
 '68e7575a7ffcc0b86c16',
 '68e9b921adbb28d29786',
 '68eff0c08232db2c500a',
 '68f1319b68a5df23c6e7',
 '68f31665b9c4b96c8ffd',
 '68f3885b8c360a593eeb',
 '68f3da870fb68a928fb5',
 '68f53944ce2247aaf987',
 '68fa55f3a2428cca0883',
 '68fb1d891b4b0e1b24e7',
 '68fbe1c8db14971ffc4a',
 '6904e233683f99a96e76',
 '69071752b1c96d132faa',
 '6907742ae7122c28c69c',
 '690a4d0b99bfb892f470',
 '690c6dae579039eb894b',
 '69100d894fea38888822',
 '6911eaf07ec9629bba01',
 '691e1d0cf5846fa5e897',
 '691fb4750ccb9974602e',
 '69213c38fe43c246fa4f',
 '6927b365dbf0baa3e9ba',
 '6928c60e485487d05441',
 '69291fcaf4080e93254b',
 '692b7576a8e72ca7cd34',
 '692c07a5acf98f3766b3',
 '692c31bb6c5e09c2a10f',
 '69343c5b39e03566d114',
 '693d5e451ee2a11e96c5',
 '693dcd0275032788ab31',
 '69419f0a051e6424a654',
 '6946ebf9e2a61a979990',
 '6948138b85b5a94a0fda',
 '6948314382323fae47a9',
 '694934d93462a551ee90',
 '694ad6c1512c1aa87986',
 '694c6c4fcc0f87966a3e',
 '694ce1fd447b98c82563',
 '694dad74aa2ddc36f182',
 '69501aa8f21eddb542cc',
 '6954f2dc9980b6fe4314',
 '6955dfcc5c7ac9d931e0',
 '695fcd39d0a6447194a8',
 '69614a95d00b0c1553ea',
 '6961e70f22089e0c81da',
 '6962f66036915a9e4267',
 '69636754470a5c73b789',
 '69637540ed911b5a6920',
 '696991faa8342581798c',
 '696c6aaa30fe03b3b441',
 '696cf4badf94ed0be9b0',
 '6971a3e15da0d4ca5111',
 '69726b7057d423688e64',
 '6976b2df2d5d484b6bf5',
 '697b5944a1a1aebc5252',
 '69833f42447b39598ab6',
 '6988bfe01bc1cb2fd143',
 '6988ee8df50b78a08f04',
 '698a17895c7cf6e8e4de',
 '69904290bcc8511a911b',
 '6991f361881843604b9b',
 '69920671cff4899f9205',
 '69982aa8a37c47019fae',
 '69993fa6c6633bc89e46',
 '69a2d7ecf59a5df7a85a',
 '69a57da787c8489bdd6e',
 '69ab0cc0e4eda5f41277',
 '69ae0bf81471ef33166b',
 '69ae4c3e85d9c28241e0',
 '69b17a9feca4fbb7a649',
 '69b24b3b71379c2e48c5',
 '69b326bc988c13078e8f',
 '69b490725efb3ef7354c',
 '69b58823a34b233940b7',
 '69be9098d6aba9464b74',
 '69bed55a7b1df9eeaeba',
 '69c20eefa5aea5558f2a',
 '69cfb959de613e3481af',
 '69d0628fd4fecc8568c8',
 '69d1ae350e2f20533757',
 '69d656c790e220755937',
 '69d6a331ab8bc56d35b4',
 '69de6e102f85894a093c',
 '69e2fcb2379c68593fda',
 '69e85012ccb0272e7f7f',
 '69e9a7bc85b35787d670',
 '69ec07443fab94aa2fd0',
 '69ed6b16f7e80a0432db',
 '69f921a1d40c4b697304',
 '69fc19887a7ff37ba5b5',
 '69fd0e4954b1c6652c46',
 '6a01b65ee188fc4f5d67',
 '6a0962a00674d69f441b',
 '6a0973c3a22440aa51c0',
 '6a0b81d3eb02bb980669',
 '6a0e5082e4747e836342',
 '6a10bb95e69d20759069',
 '6a10defb44760dde120a',
 '6a14f470dff25a0d5cd3',
 '6a1a3fa755968917ac11',
 '6a1d56e6ebbb35453729',
 '6a2051dac1e4c531956b',
 '6a20ce25c7ccc7ad21b9',
 '6a214be11fcc0f6c51c9',
 '6a25bc64afeaa2441d8d',
 '6a2765859758d6382b16',
 '6a2864fd20e12ba35798',
 '6a30c5acb9bc01941b8f',
 '6a349e33ceb5c1d2b3b7',
 '6a34c6d9b3d894b51278',
 '6a364f128be5c054913f',
 '6a3b8ca60b847e1ea36d',
 '6a3fde67ff8f52896f8a',
 '6a447e33f3ec153bc73c',
 '6a46c1c51f92420cd917',
 '6a481d3f0c6c7c9a56fc',
 '6a491379a224c5f7eb86',
 '6a49bf5c89999aa900a1',
 '6a4b7c081b0027a797fd',
 '6a4d25a8b2eb4654edc2',
 '6a4edfa1798a9998eea5',
 '6a513a60417bc970e8d7',
 '6a521419fd20aa9f27fb',
 '6a5332dd7b75123dac1c',
 '6a61267511ddb0890cfd',
 '6a694696052d97c23d37',
 '6a6b586a52b97aa72afa',
 '6a6dbf0b0af689534c9f',
 '6a708b0f2b6481e76c27',
 '6a72763286c07727007b',
 '6a738be5bba0ca0b2b15',
 '6a7423e9d2f9541d385b',
 '6a752829f1fa51f94068',
 '6a7563f33bf7a531f721',
 '6a773b889299fad4d597',
 '6a7773b305f0970544ca',
 '6a7ad269ac546e276498',
 '6a81148e1db06a4a520d',
 '6a817b8cf7ff0bba1d0d',
 '6a81a154100e0b3ca39e',
 '6a854185b3c76485129c',
 '6a8847378de911e210b3',
 '6a8a47442cac54a8f924',
 '6a906e894977e941878c',
 '6a910953ce2598044e06',
 '6a914f236baefd3fd772',
 '6a91f351a755af1ab8d1',
 '6a954fda82805fb4072d',
 '6a979125a616185ae855',
 '6a9a85a05af9953441dc',
 '6a9c15d0e3e5af2358c7',
 '6a9d0a88f5d4e8fa976a',
 '6aa204874b79f62d5597',
 '6aa26d8b792949736f65',
 '6aaae184d78ec14bff6d',
 '6aabfc46d67f427f87ee',
 '6aacfbdcbed9d1160431',
 '6aad56ef5ee8f6fbea15',
 '6aad9b1fdd3b850cd100',
 '6ab6df0920ca2f4656fb',
 '6ab98a533acd03011aaa',
 '6abc1a8d1c8f1f473cf0',
 '6abe8e917f2882f422d5',
 '6ac006dc3d1ea3eb9b87',
 '6ac18e943b8d6b3e2031',
 '6ac25b3c98e23c8a813c',
 '6ac5aab2ef5932b24b6f',
 '6ac9f0ef8404ea455330',
 '6aca10c7e1b57441384b',
 '6acdabf89c07b2aeb979',
 '6ace79a2e247c35b7266',
 '6aced0a81a8688cb1a42',
 '6ad37a0267368cc5ca41',
 '6ad6bbfd332fefdaf056',
 '6adc7ed350375cf44c82',
 '6ae21ab28609dfd1c9fd',
 '6ae4d563b8cf2dd25f46',
 '6ae50f9b5b6e5373caaa',
 '6ae5d0ecae7beb3e32e9',
 '6ae641f286531a355059',
 '6ae99b3b6120055695f9',
 '6aea5be4a57ca14a4fba',
 '6aeaad82e9712645e4b4',
 '6aee8e603dab31f95994',
 '6aef2c30df36b8b98568',
 '6af89af65f0dad564cf7',
 '6b0222ade7eb54315ef8',
 '6b02bebbc37cf3721e83',
 '6b06331d0155f347e704',
 '6b08fa5ef14d5d738735',
 '6b0a589be72a402dfade',
 '6b0aaf8674e56c3500ec',
 '6b0aed6568ccbf7b9fd1',
 '6b0f2b9d763fe640bfe6',
 '6b0f321bf3311c3f2330',
 '6b16bab657a848943da1',
 '6b183edbc03662d9bb3d',
 '6b1a5cfca66b1a655af6',
 '6b1c0bfdcebee9d142ba',
 '6b1dfee2dc624aa54613',
 '6b1e060d9e8d1a7d53be',
 '6b1f5549cd3adf1ccb6e',
 '6b24c56f54441b0bc5dc',
 '6b29781e81f79111d530',
 '6b31e559d81f1d603e16',
 '6b37fbb60c6de1a609bd',
 '6b3c319b9e1bb14cdcb2',
 '6b42d2f6700d0e76091a',
 '6b454960212a065fe2f5',
 '6b470cac68b61a1936cd',
 '6b4bc7c2737b0a042a84',
 '6b4e8d10f5e86956fc38',
 '6b50aba2cccbd14440b1',
 '6b50bcbebef51ee07876',
 '6b53a64251ae9b1b012b',
 '6b559ed7c0b361e043ed',
 '6b5961013b50568920cc',
 '6b596499695f9aaf0fd8',
 '6b59d898cc9798283ff4',
 '6b5a3dd0108bdbce1aa7',
 '6b5fabbcbe4ddb5bd558',
 '6b70924f51e3955bb056',
 '6b74d6e68bb0fe167d5f',
 '6b7796585c007e98eaf0',
 '6b80e0e24f8126831cb4',
 '6b83177ea60a6d4a51ac',
 '6b847d409df54cb7ec6b',
 '6b863f8ee7436eec735d',
 '6b87224fead01074beb3',
 '6b89eacb4c77889b57c6',
 '6b8a8de4ad3eef5ea750',
 '6b8c36940d889fcc2e6b',
 '6b8cabeddb73e6a9abd9',
 '6b8d2b5510e25c0d09c2',
 '6b8db85afd4a5fe29614',
 '6b8dfa16df6fbcd79b5a',
 '6b8ecddffbff9cec55ba',
 '6b9151dc1081edc207b3',
 '6b96ac69df8629ef347b',
 '6b96b17d343b84372c4a',
 '6b98ab8fec8551b73ee0',
 '6b991101373bae092fae',
 '6b9922e724283fcfc3b7',
 '6b9c261b1365264b437a',
 '6b9cdea062d0cb33aa49',
 '6b9fe6d07f4c23d19273',
 '6ba56870a36ea6877396',
 '6ba743385bfa3b6a92ae',
 '6ba7d59d1ee6e86fc201',
 '6baa70f471730d638ef3',
 '6baa8fa94ff272e1cde3',
 '6babbfa7d1fad98308fe',
 '6bb4e854b4b98b1f8968',
 '6bb633daaa9a538a2322',
 '6bb845b4de8d9b54ff31',
 '6bb9609b9a6494334483',
 '6bbc4fbf9673c0ec9f66',
 '6bbcf3110e4be3f32ed3',
 '6bc0a840eb46d94e6dbc',
 '6bc219f2d278e52802f7',
 '6bc2b169b19200f5d2d1',
 '6bc50cc5eb8aacfb3a49',
 '6bc5e9924b0210feb61b']

# %% [markdown]
# 11

# %%
qids_11 =['6bc76a7edf7687a60846',
 '6bc90c011933e6722f17',
 '6bcc10bffe7f3425b25c',
 '6bcd35e2fefdc314f55d',
 '6bcd6ceb39f144386a09',
 '6bcf589c024f8eb5bcc6',
 '6bcf78e8990d6c29f890',
 '6bd0ccb7a2f8e949d556',
 '6bdb64313b19e48d7194',
 '6bdd40625fad66a9d35f',
 '6be070ad293ea0de5816',
 '6be17bd28c99db5303f9',
 '6be6ea07a8ef7a545de9',
 '6be99599ab7418dcc3ed',
 '6bec165f56fb0b708031',
 '6bf05f8a11c40f6a5cc6',
 '6bf177aad9e97c7bc8ac',
 '6bf3ad87dceada2d5ebf',
 '6bf6547ef39c055c729c',
 '6bf78d78a8f3a221cf64',
 '6bf8f6cef4a3c468d357',
 '6bf9b05306420f5f443f',
 '6bfd997cac9fa7bc06a2',
 '6c0864741135276ac52b',
 '6c0bcb9cab80b365942e',
 '6c0e00765bbddff52a82',
 '6c0e9e6474d07d72cf9a',
 '6c10924a151e0be139fc',
 '6c11145741616a9b78d2',
 '6c11bc877e9c6ec4ab4c',
 '6c150c917f597d981283',
 '6c15849cd93368adcf86',
 '6c17b9a2559da272a149',
 '6c1b4dc44edb54fa1581',
 '6c1d3181559b4ae24ba5',
 '6c1db1b53e78dad27fc8',
 '6c1de81d31b343c0fc9e',
 '6c21e21abdb270626ff2',
 '6c21e418eda696a963e7',
 '6c2685beeea36364c43b',
 '6c3369a0718e9c58b6cb',
 '6c3401ca7217cac46a05',
 '6c37837d6a9e86a0032d',
 '6c3857697c5f6d93f919',
 '6c3887cb32cdf760f946',
 '6c38f723e5534f975b38',
 '6c408ba74273d78fbb52',
 '6c40f4605678686ef500',
 '6c4d0ed9ca0322c0cd7f',
 '6c501010d6cf10475974',
 '6c58ccf82b7112dcc6a8',
 '6c59fadd3a14715de448',
 '6c61017c83d0165961a9',
 '6c6104833bef1bc3691f',
 '6c62513926e72848ac07',
 '6c642782237e30a9bd8d',
 '6c67d83a19a9c6881fb9',
 '6c6f2c881ca56a5d86c0',
 '6c71cf1d4b4a5064a1f7',
 '6c724b9200b9defb4fc8',
 '6c7cc22509730e995f28',
 '6c7eefa22bf47f06033a',
 '6c7fb297bb85060420ee',
 '6c808f58725df83f5f94',
 '6c8157e1ddf932f75adf',
 '6c84a849e972bb5e5c43',
 '6c858a91baedc8abac16',
 '6c93ac385c5f0125fd30',
 '6c9a80b359a4822527f7',
 '6c9c2e7b2eaf7e2a8048',
 '6c9cc8fccefc39c66bb5',
 '6ca75ec8affead4c6826',
 '6cabccd9df9f0930a96d',
 '6cb5563a09fe86c8c619',
 '6cbac7e857de37aff9e9',
 '6cbda89cda5ce5635739',
 '6cc2d9945071516daad9',
 '6cc3256cb2d65a57ec4f',
 '6cc47c14da240d7944ee',
 '6cc484771b4175e72813',
 '6cc64da7d6e167340f80',
 '6cca075bfd7e0878db52',
 '6ccba086d3e48c99e69c',
 '6ccd13ff10a058e61fb3',
 '6ccebca38c05060b01b8',
 '6cd581190b4367b024c0',
 '6cd897d7a356d992e65c',
 '6cdb35d90d57b4a03c35',
 '6cdbd497bc5125688498',
 '6cdde0aef9296e53fda5',
 '6cdf178227b43affbd6d',
 '6ce41520b322faa57aad',
 '6ce5d470392acd7c8e10',
 '6ce60da5b97ac0f5bbbb',
 '6ce67cabd50393adffda',
 '6ce6db3e1d8175f4ad08',
 '6ce9438d12c0591cca3d',
 '6ce9c254e008df404a37',
 '6cf0b27054c0426b49c7',
 '6cf49189d437ab8f2aef',
 '6cf7340cf6737eb61370',
 '6cf81e047d90a405fbf4',
 '6cfa1da0cf6996b39678',
 '6cfa78bf21ebc4d45b48',
 '6cfeaa577bb749edef95',
 '6d02ca2b5b1547b7a2b8',
 '6d0403dce17c12f091f6',
 '6d064250775292432f2c',
 '6d09b46859c103044b7e',
 '6d0da1d32be3aa49c592',
 '6d10a3cbeca98b728573',
 '6d10f424cb1babe788fc',
 '6d1150ed34d9297c93c7',
 '6d11c950bf204407023c',
 '6d12d871f90e06d71a2b',
 '6d13c79d3853bdd4292a',
 '6d17b9506105807941e4',
 '6d196bf19bd4b5ca8e8a',
 '6d1ca9a3ba00251b2054',
 '6d1cd94b3c8c970704ce',
 '6d260607079224ced001',
 '6d26518d200bd7c86ecb',
 '6d26525c65011ceb225a',
 '6d2be95c0a56fc997b36',
 '6d2d16535b59d6f9b233',
 '6d32a9c1d95f03f2eb8a',
 '6d356dbbbf78d12daf33',
 '6d37be3fae0a1e64e6d0',
 '6d38eeffde163a4e63a7',
 '6d3adc2674582b22f986',
 '6d3bda8218e56bebf8bd',
 '6d3d0be2a532da53c2a7',
 '6d3e1dc96adc0f250f7c',
 '6d41717dda3556c2a45f',
 '6d433dff76ed4ea87e3a',
 '6d44c207f017362245d9',
 '6d46ff21e6c4da72347c',
 '6d476a33b1a4653bc141',
 '6d49b8364b3f9a29402f',
 '6d4a9d065a91171f626c',
 '6d4f0c58fdce8f4f0a7d',
 '6d511e595f9792a14103',
 '6d5120e8c993ad86be67',
 '6d533804583847a14ab5',
 '6d53e888aa07c7f7712b',
 '6d57d0428c4e1d65373b',
 '6d58c9449fb49db5f7cc',
 '6d5a6f2a5947c04fffdd',
 '6d5af561b44c43860bd6',
 '6d5eca3b18f39bbb8122',
 '6d61951eaa998a3bee21',
 '6d619d63858a15f180dd',
 '6d6524a1b57e26425a7e',
 '6d6890bc9cf1be0d5a2a',
 '6d6e96fa4190ddbaf7c4',
 '6d6f7b3b39da207ec29c',
 '6d70b3c724e125ff1f53',
 '6d719b35f58351bf8958',
 '6d756fbf5bbcdefb651d',
 '6d764e4989e707da70b5',
 '6d797adc76e32143d699',
 '6d79f2d0c7668a9ab82b',
 '6d7d42f755a07b101836',
 '6d7f2ca4ee4eec8f4218',
 '6d813dd8fc0bb4830a14',
 '6d933e221d3c3404186f',
 '6d95abdafe0d4c72ac0c',
 '6d98fad809deed4e376c',
 '6d9910800878059f822f',
 '6d9b245535e0f40ee627',
 '6da143bb3169aaa03055',
 '6da2469b61168d3c8521',
 '6da3e05347e8e66edf14',
 '6da597926b664a6aa365',
 '6da77c55c3dbeea7b05b',
 '6daa835efaa5bc9cb631',
 '6dac4c98afebdb303839',
 '6dae386f8eb25afe24f8',
 '6daecf53dd18ddf2aaa9',
 '6db990807994025844f2',
 '6dbf7764c6e88ddc1627',
 '6dc1b4ed3428d4bff74c',
 '6dc2d3bc7e4a8e4938fd',
 '6dc741958aa7e97eea45',
 '6dcbdabfd163e260757a',
 '6dce07fdbb9310295881',
 '6dce586ce3b3f455953b',
 '6dd32314f8cd8120eaa5',
 '6dd4165f2ba2a17b3b97',
 '6dd4860d100efdef8921',
 '6dd94ebd926e7f63f42e',
 '6ddf169d4c8bd875abee',
 '6de4aa453d39ef489173',
 '6de51606d3115d0d052b',
 '6de5f40fab3b3b57225a',
 '6de5f994a86260a26400',
 '6de620c31ed24d310583',
 '6de83bcb02bb7d311818',
 '6de9ceeb1f198b11fefa',
 '6de9dd3eb517c359afbf',
 '6deabe2e1e42f47ed9d5',
 '6debe6d3fb990127150c',
 '6df30d551a2cc49ec359',
 '6df31e62554c8f05a1a4',
 '6df42628aa62d0c7c39b',
 '6df6731443f020252c9b',
 '6e00245fe383f5dd2d72',
 '6e00f57688a204970ac6',
 '6e06b2b7a4cfae108c6d',
 '6e0707044ed25afc768b',
 '6e0d41e2bcc6966629a1',
 '6e0efec0badb8018e7fa',
 '6e16f907e8e4336897f9',
 '6e1717617a09045bd131',
 '6e176a7779c32a219a66',
 '6e20ac320bbbbb92bc9c',
 '6e219dfb68b8d9b6f4fb',
 '6e252abe47d94bc4450b',
 '6e2bc9a51e1b6cd84bfc',
 '6e2def57be30a7b22a59',
 '6e2f389d9e3641624135',
 '6e304087e0057d2abfd9',
 '6e365f8e5d00a2eff1c0',
 '6e36dca1c18925c7cf60',
 '6e4184838b9642098000',
 '6e4257b7568f6526de7f',
 '6e42701fb360dd4a4c2b',
 '6e44100b4a3e1693cf43',
 '6e492e6e08f4a0689824',
 '6e4b72c3f3bbe5a2d35d',
 '6e4c86c17e93e8adf5da',
 '6e4f151ea2388962dfba',
 '6e533b464f606fcc9848',
 '6e56499ac84ee524ae07',
 '6e57879a8514172e387c',
 '6e5a74b15656802a2057',
 '6e62a20f877274c28488',
 '6e631f834f201b631b71',
 '6e63d315f157ccd74958',
 '6e667f9eedd0ea0ee7f8',
 '6e6962ab59ee0317ced2',
 '6e6a02ea3fc04ef6dc1c',
 '6e6ea33160ba58c283df',
 '6e73a26626357796f9a5',
 '6e7783b353a68aacb314',
 '6e77967c1b57fe460a99',
 '6e79f78b582c31a5bf0d',
 '6e7c4ba25ce0cb45ed2c',
 '6e7e31c1af72e7348606',
 '6e7f7889ad39e3062329',
 '6e873d8312ac9ba628de',
 '6e8d7f1747dab9d656ee',
 '6e93a2fdd652ab7bae7d',
 '6e9a36f01f77359fa99a',
 '6e9b5e7ef8c55a1df2ed',
 '6e9c28f29832f7504e3a',
 '6e9d9ebed87f98842954',
 '6ea01ac571cc837a4e63',
 '6ea0b14e29788c42e7d0',
 '6ea1289062a8b43f9fbe',
 '6ea1b26f25e51703e08b',
 '6ea1d7d631f77e567796',
 '6ea22c403e3b2f19b143',
 '6ea3c8a396f865c1e3ee',
 '6ea9f29d59fb6c9a4b97',
 '6eaac7af6ffa57074481',
 '6ead173d886076e94a6f',
 '6eb095d7a4a5a1500dd4',
 '6eb31689838b991e5d9d',
 '6eb5715ddfeca399bbc1',
 '6eba64a26c685e388262',
 '6ebbf63d018b966dd002',
 '6ec483fa25ba12a42a55',
 '6ec4dee334591ca709b4',
 '6ec5ad73c3eb8b79f740',
 '6ed0f4356da4334353e8',
 '6ed26d6f23b4ee8e7f93',
 '6ed6ee7b3ebeee944d4b',
 '6ed816292d7bca6fb4ab',
 '6ed85bc1123a5a853106',
 '6ed88234890f019f409b',
 '6ed9dd17261a6bb8e076',
 '6edcf00605aaad8cef28',
 '6edeb96aae9f49cb7d33',
 '6edf629a41337f3da31c',
 '6ee11c5dd502dbefb4b9',
 '6ee2eb51c27d8add5e62',
 '6ee34fda543a7cb6cb34',
 '6ee37d8a3e4a588a60d5',
 '6ee50bb918f5c613d48f',
 '6ee5d14db853554df9b9',
 '6eea088cfe04957f38c3',
 '6eebf7972cd7442b7ccf',
 '6eed380970f488175931',
 '6ef0f99327e5336e350a',
 '6ef2f182f091f45ef12a',
 '6ef3a5417e8165a809ba',
 '6ef50ce9d12cfd40b6da',
 '6ef559f408371775f5d7',
 '6efcb72b3f870598869a',
 '6efcd03937eeece710d6',
 '6efd2ebad2c9d0f11faa',
 '6eff3e9f7e8631de7a19',
 '6f01c3b416ec62cc1685',
 '6f02f61f157d16886580',
 '6f05e3769a6074a5c58d',
 '6f072f6cd6fd874eb7cb',
 '6f07f6327cec4ccd6bd2',
 '6f090bb69e62287cb7a5',
 '6f0a1d85486b3127b73f',
 '6f115a16fbf2dfe1b484',
 '6f1642e0ddbc21fe7bd7',
 '6f17089f7bafb3151c03',
 '6f193ed9f1671e8f5cc7',
 '6f1c8196533f51e1f89a',
 '6f219164c4e3c3f4221a',
 '6f2901a29c507fd04f26',
 '6f34561c191d336ade61',
 '6f35968da8b11aa40873',
 '6f3613df3904710c86cf',
 '6f3984ad044e017b7014',
 '6f3a2cd550ab504cdfb6',
 '6f3a88a0225ed2a827ff',
 '6f3ea379ccbb93ac0085',
 '6f4966df9c605dfcb0d7',
 '6f4f681cdcfbc660262a',
 '6f50d78c82f62e5ac2ff',
 '6f52450f2f4adad0fbbf',
 '6f528d767b9c7c0ff615',
 '6f5360c0e8dcac14b33c',
 '6f56a6befa9668477f8d',
 '6f5738a40f4b5e266b44',
 '6f5d336f227dbf2948dc',
 '6f617f6104bb52a9d33f',
 '6f63ba7bdc103c199989',
 '6f68f9ee45aa69ac1151',
 '6f69c18ce312d11f91c7',
 '6f7178d2a62465c740c0',
 '6f73b96f24fe4ff1a6b4',
 '6f73d824a9c2c880bc70',
 '6f77a0a231572649f318',
 '6f7b1f7a9a50240bd504',
 '6f7b7f103805f1bdf08e',
 '6f7d8ef44fe447f80295',
 '6f7e57df04bafffafe98',
 '6f7e9d7069d783979bd5',
 '6f837be74c61cb85941b',
 '6f8a1402f051d215cb1c',
 '6f9132889fe48e85dac6',
 '6f9231022361a63684a2',
 '6f929ef5aec9019839a5',
 '6f945bfc04d0792fe2fa',
 '6f9c7c479b8986be2bcb',
 '6f9f00084906e0a8ffa2',
 '6fa38c3a7c276a3a597c',
 '6fa4a815c38250ecd0f6',
 '6fa7f8a09f2f7fd6ec57',
 '6fa80556d74fd2ae7f29',
 '6faa540f9bce670ea4e6',
 '6fb09c45579662acfcfb',
 '6fb202f233a4c57c68e1',
 '6fb562de33217c276705',
 '6fbc41f4f84969554d96',
 '6fc0eba6457d4b1d842c',
 '6fc12bd211acb90af527',
 '6fc43e55e9facfc87252',
 '6fc4581ca259df877349',
 '6fc45e547ce271019f00',
 '6fc9fe9ab1fc19e56129',
 '6fcca0a67b6cf598a882',
 '6fcffbe75292a7892676',
 '6fd60546d10dd82de9f3',
 '6fd668772018e41c944b',
 '6fd72fe4dccadf9045a6',
 '6fda878554bb319df9c5',
 '6fdccd1bee05d3cfc57f',
 '6fdd0b3ff5ffbeb129fd',
 '6fe238f1a8ada4a304ae',
 '6fe284c6bf130458c8c2',
 '6fe4a778e5515c3edb01',
 '6fe5441091ebdff4ed65',
 '6fe79aae2f972a4fe2fb',
 '6fe80bd6bbefc2bc47a8',
 '6fea66866dfc451d389a',
 '6fea7ad9761c2f5541ae',
 '6fea82ecdd778ee9a613',
 '6febde081fe7839f70dc',
 '6febe5c83d4a2f5fe210',
 '6ff4bef42dfc1a474d81',
 '6ff66952284e607bc2fe',
 '6ff799db0f2029cd544d',
 '6ffdc4d3bf58e7b1fce5',
 '6ffe4360a99e320db815',
 '70015a53f94c05da1b5d',
 '70036ccce06b66709f2b',
 '70046f341404c5eb70e8',
 '7006b3eb02be738b8c9a',
 '7008199386fe6912de41',
 '700b3bb0f9897aaab05b',
 '700e04b6eec672c9ff3d',
 '700e7529dedd1d308196',
 '700f47f981535577f0df',
 '7012293453c4ea68a917',
 '701464178ecccf364cb4',
 '7016177a11340f6af57d',
 '70174e24dd2f880d44e5',
 '7018b24158ec3b58d579',
 '701bf97afe10607dd9e0',
 '7020b267a3268e5b78bc',
 '70238fbcab4ecebb5c0d',
 '7024719e00346262f236',
 '7024a422115927d1f542',
 '7025388b54a124adf732',
 '70261abf73154749e432',
 '7027aaa0af2150f15fb0',
 '7029b59ca388c3b21a64',
 '702d5aec5f4a52f9f139',
 '702dcb028f3755de62cc',
 '7033f55577aa34ff56c0',
 '7038737bfa440bb7a983',
 '7039e7197a54da19b0b4',
 '703afdd3a513618e30de',
 '703b4f8b0d10d86e40ec',
 '703c27496304cb40ba04',
 '703d36dad22b837a55c2',
 '703ea4470e8b93f32bbf',
 '7042f937838159249d46',
 '7043b0044c61f2e577b2',
 '70454a79c7b3eb6ca8f8',
 '70458e931851e9343031',
 '70476f858cd147cda9e3',
 '70498f6eff9efbcab964',
 '704aff4a1bb3c478248a',
 '705713af7707f94b4079',
 '70585767390d48c11262',
 '705d5d43dbefeb4c352f',
 '705dd4422508521993b9',
 '705e355399a9786dc278',
 '7060ea8bfa291e49b8ef',
 '7061488ba8d4dec08f4f',
 '7061a0819685eba0cf6c',
 '706737458674e9949d89',
 '706ab326cb709c32369d',
 '706d810354f65ce8a871',
 '706e921b2d4b6adddf93',
 '706f158a0c0792aa0f53',
 '70711e4d5694f22d9af6',
 '70715f268535de29cd97',
 '7072f14968d37b62b65f',
 '7075490b1fb80f2d146c',
 '70767bd0ffc3165ec1bc',
 '7089596a1efe781b9645',
 '708ba3037505d07053d1',
 '708da251ff0e22b5594b',
 '708e972d3225d077dcfe',
 '708e9fe83252838db576',
 '708fc14518a4aceb8068',
 '7090471fad42e46a1577',
 '709371e861b88aa07fa7',
 '70964e5ea10569f61ad2',
 '70968f2b857abbbd6aa7',
 '709a2c5d64c3957398c1',
 '709fa63259e61fb03de3',
 '70a916c38cbda316b20e',
 '70ac70d87eecf11dea09',
 '70b572d4bad22dea45d2',
 '70b8b3a17c00f0142563',
 '70bc87886f0534e5b929',
 '70be4edfc59ea4b01891',
 '70bed2e9fbb8a81a02b2',
 '70c1f20b4ce8eed0a78a',
 '70c2b3c2622ee5290d75',
 '70c3ee9994bf44dc5e13',
 '70c44d88324029e863d5',
 '70c584b15d5e18c2e3bc',
 '70c5ba619031327ebc8c',
 '70ca5433432dc385e41a',
 '70cc0c8c5226e0749ab3',
 '70d0a23b4b8e8c8f9ff2',
 '70d561d2daf9ed3715e3',
 '70d6b82b4e0e38517a19',
 '70da3379f0066e70cb9a',
 '70da97288654966a4810',
 '70dbea780df79d0e4288',
 '70dcd7f48af7b6f259ac',
 '70e59d9e1b5a5a9fdc6e',
 '70e5dc8329ec5ffa5e10',
 '70ec7c460914d65e6d86',
 '70efb07ed3c318f9eeef',
 '70f6852c6ef874c3e05d',
 '70f73b5548e2ff43bd7e',
 '70f7cbd0d2522c9d5a15',
 '70fc159de247619478cf',
 '710247985f30e95d273d',
 '7103254f0028aa6f1c03',
 '71060ac72f88771fa60c',
 '7106273518d2fea57852',
 '710fa1bc99a5cdff5dde',
 '711a45fd7ddeab4ff399',
 '711d0850f6999c696f36',
 '711f8490f220586ec909',
 '712237558d6f041fe79a',
 '712539a0032f4d6ec817',
 '71253ed1afd85cccf54f',
 '7125b0528b5708a9a6eb',
 '71267fa2b0182422f94a',
 '7129dd85db66567d7216',
 '712adfacd92d48bbbb8a',
 '712b88a9e51aee693d80',
 '712f15683d7d60a2aaea',
 '712ff229f121e17d0aa2',
 '713c7917c883a70e4dbd',
 '713caeb7e000b2114e97',
 '713d097481be2e54567e',
 '713dc647cd8fe3e2b8a6',
 '7143ec3ec1b8d3944e38',
 '7145dcf8656dd5f177a8',
 '714a8bd768e5806899b4',
 '714d0fb5146880a602b4',
 '714ddedb953233e34a9c',
 '7153a9720d0598754a05',
 '715459609d55cdddae10',
 '715852e86c2658c5e35b',
 '71591dabdce7b18be69a',
 '715a2bb173cbd21383b6',
 '715a3177545c9b200d72',
 '715bf0acc0eedb85c3dd',
 '715c0a2fe826fd951b41',
 '715cc45b2e9dc60cbc08',
 '715d836da8bb33e4ce44',
 '715dce3740b95d0e75bd',
 '71621f4e6a470ef99bd9',
 '71670a76fd7adc0146ba',
 '71676d5dff09e238ff73',
 '716b2de670821d0c9675',
 '716c0a2b788414f54312',
 '716c3b81ef3cfa18ce6e',
 '71712f24818cd6838430',
 '7171b0820ff313a84b3c',
 '7175d0fad899feb2e9db',
 '7179a09bb5787583aad8',
 '7179ace915baa70ce152',
 '717bb9e61c52b9af011b',
 '71810b866bdcdaa1298e',
 '71818de606ef1f0a0789',
 '7182d0ab5afe51e30bef',
 '71844b45e05aab680df4',
 '718708bf099f97e2a1e1',
 '71886e4c4d31a3f09bcd',
 '7188a7240971086b7539',
 '718c27fb6d95fe82322b',
 '718f780c0710a556fba7',
 '7196250c178ecac99297',
 '719a808dd1fff8b39dea',
 '71a395575cefa9ca2e55',
 '71a58a5f923e9ed92a0f',
 '71a82c2c042a3654e095',
 '71ac4b5324175a8064b0',
 '71affaacd11ecb911334',
 '71b199464f2cfd808d8a',
 '71b5022bb917716f6e6c',
 '71b99c802a9ebaba22fc',
 '71ba0b8ca5089545a595',
 '71bceefadeddbc97a1f0',
 '71bd2426e8336322810a',
 '71bdaa706064850a4aa6',
 '71c152c98c77634bbc8f',
 '71c5da9abbd18ce0422f',
 '71cbf24f9b7555ac43df',
 '71d00a0da952bdad9a56',
 '71d1086a13ba18714bb2',
 '71d424e6de58a5c00606',
 '71d5d702fb4a777f0030',
 '71ddb63134393af6c5c6',
 '71de98cadf0fd773eed6',
 '71e0a57f4723df1087a5',
 '71e3a7f2e43700d0f92f',
 '71e7dbcb28766c8b7884',
 '71eb3172298afb803f49',
 '71ed1052d384d54eccbe',
 '71f03f5ee31b3c322cca',
 '71f14cdfcd9f151480de',
 '71f2673e71f33c6621de',
 '71f344abf3ce506c637e',
 '7204072319ae342a20cc',
 '720502b249c42097d5a2',
 '720dc37f7fc6043017f3',
 '720e22ce0a79a1ef2b6e',
 '7211b84bb7f7a64e13cd',
 '721f2f86a9dbaa289c76',
 '72211f8c5b3f97b21448',
 '72253775f634e24d8e6b',
 '72277f736c950f8375e8',
 '722c7fadf44c7939ea0d',
 '722ca02424a78e6947cc',
 '722f18ab5c6b0f6aec6b',
 '722fe7dab88e4fc2c9eb',
 '7238b8610a426433fd64',
 '723d75e6cff1b31acc72',
 '724278daeb30b616ac41',
 '72468060d7d7deb8ff07',
 '72471db9e6d02764a960',
 '724bef70a911bb9d0c2b',
 '724d12a031f8fe2e552d',
 '724da42c9e4ad8d66ece',
 '724e3c8f2ab31b66240a',
 '7251b858036c75c43f0b',
 '725ee1b29df64fcb7b45',
 '726019435253167362f6',
 '7262784aaa07608059c6',
 '72674170547f171af12e',
 '7268e2217e7d07811f67',
 '72697961e90bf8fe8b3f',
 '726d0848ad83155b5b7b',
 '726f4d939051da73d495',
 '726fb42918cc052cadb2',
 '72728a0a356d9eda3c14',
 '727302271195f9317453',
 '727729a08afe1b380fef',
 '7277d6613cf753f7c728',
 '7278923d5355aa1ed1e9',
 '7279f9b86219e7d33369',
 '727b60ab38be13003d8d',
 '727c3ae877de1d190a36',
 '727fd2cbfe8ab2d06511',
 '72808e7ecfe300c2622e',
 '728368fbd70107c70720',
 '7285bb7a2db3fe7bd276',
 '728a9961440a1316cca3',
 '728b637859211a90621d',
 '7292fe2d87bad43e688b',
 '72961cd2e6b6b8cd55af',
 '729990b9171cf70872df',
 '729d40f7922ca66e5bf0',
 '729e5fceb6668a0d6b95',
 '72a25c1e1e45be8bc745',
 '72a6aa40f0df71d1f8ea',
 '72a7bbdfb170fb70026d',
 '72a8a0ecf9f586530c72',
 '72b6a6297f99592acf01',
 '72b6de510afff3780177',
 '72b7223155b8d9308bfb',
 '72c0d0d1f83c226a35bd',
 '72c2edd09c9c76f07560',
 '72c31bfae0861977b653',
 '72c42345c12db7a02e9e',
 '72c4e239cb72770d190a',
 '72c689e38ebd0831f019',
 '72c69501a20edf227f1f',
 '72c71bcfab5e152794b4',
 '72c941f814b2abea6463',
 '72cb42891c71012cfe79',
 '72d2597e142cc5ff24d7',
 '72d32cc28a42e218d424',
 '72d570d779e0f2d85b35',
 '72d929da4a898dafd183',
 '72d9baf002b4b9a76840',
 '72dc21ee8fe6ceed62b0',
 '72dcc8ba575dbc0e6ab9',
 '72dd0c711e357aac868d',
 '72ddae067723f97b5304',
 '72def47cdfa24e51ce2a',
 '72e05ac7be19a95601cf',
 '72e5a7e944b365ba0040',
 '72e86a671b7b6c2594c4',
 '72efa993677191fb296e',
 '72f01f505ec722b4cb9a',
 '72f122c5b9002dc8ca62',
 '72f2b27d502cf2811cb3',
 '72f5cd13e7977a0e92c2',
 '72f9668bb465ae648734',
 '73009a33b31e0929efde',
 '730229be2184b93282d2',
 '73036cf5c91508bb67c3',
 '7303be4269e311c2fdac',
 '730a02af764b014ad13a',
 '730dc6f041e071823194',
 '73100f7b2950d6124f06',
 '73112bd17dd6af6cae76',
 '7312bb5ad9eb7421f8fa',
 '7316ea9b87e6571b6cb5',
 '731ab5fa27ed870601a6',
 '7322ccc30983926fe5af',
 '73287b5b9b760a365399',
 '732d3bc88a3800616099',
 '7335beafc6bd74eda525',
 '73379f74d9827ec58953',
 '733a9640ab315b63eb36',
 '733b34ab7a61d5d84e84',
 '733e650a0b12ef6c7aa2',
 '733ede5c24f3a6468af5',
 '733fbc253f4503c78229',
 '73416cee45deeb9153a8',
 '7342d4a5c5640b7e8576',
 '73446e29d23be26e4f0c',
 '734483c0146180fecdd9',
 '73476e77c5a4378d459f',
 '7347c080dde4057ac02b',
 '734c0921a9c3423f6dde',
 '734cd4b1c60dc445e2d5',
 '734d43283af398d66543',
 '734e7867719385092d75',
 '73540d423d569955a0d9',
 '73559eb6a153e24b9eca',
 '735afdb5ce6980d64e98',
 '735b0cc17eb36da0174c',
 '735b1b8932cbbf0921c2',
 '735e8cd775515d38dea1',
 '735f5a654a0ad3559460',
 '7360342c57e986326f6a',
 '73634d7443d197a849af',
 '73639a95838e0eca0b04',
 '7365292b521e376084fa',
 '73663d2156a437dfcb80',
 '73667807a182ff28c820',
 '7369099025371ac57ab7',
 '73691a087b210d7f69a0',
 '7369a7df4e24da97df4b',
 '736c3b4829d8da4334e7',
 '736c73bab799c7daf589',
 '736ca3305819306d8728',
 '736ec159468ddb745754',
 '737037741c5ef43fc754',
 '737292bfb33e3f9542f7',
 '7374bf2b7aee22711850',
 '7378f7b347bf953034ab',
 '737cc287e22166f00403',
 '737e9a37fd0d6cef89af',
 '737fa26ab572fcc89b63',
 '738185663f3346fc954d',
 '7385fb721c8bfedab5fe',
 '738b0741330675746c51',
 '738b72d699920cbea003',
 '738d0c019dc59bc7bda3',
 '7390ed504d407214a555',
 '73910c5f9977fc51d176',
 '73a06b668c2feedcf99f',
 '73a3193aec5a2bbde3a7',
 '73a68fb3620f0a98af71',
 '73a87a36ca4c0f5b12ea',
 '73ab39c6c69a89fbb3a9',
 '73ba39d9f0630739dd4b',
 '73c2f4be71308fe5e50f',
 '73c40cc90f116544d9a5',
 '73c6ea241101c911ded2',
 '73c993d0eab0bf0a92c0',
 '73ca4f53cbc635bb9c27',
 '73cb7c25f0c42337728c',
 '73cbc07a5643b643bf76',
 '73cda03b9c6af4f93261',
 '73ce45d9861130381512',
 '73d4446464215d6d31bc',
 '73d50ec08f6743db9d86',
 '73d5ee9b33fb8dc829de',
 '73d6ff871570042e0306',
 '73d964283ac272bf5728',
 '73db9a079e58e1d6224e',
 '73dc0cc2fc142ad5e04a',
 '73ddafeff2e519c70510',
 '73e58bfe0b6ff739be1b',
 '73e6f2d05e544691e741',
 '73e80e254df8a4614fce',
 '73eb0dc5cdfb620d1199',
 '73eb90c5e8b7e9593456',
 '73ec469337a23a9d0187',
 '73ef1e016d470bba7934',
 '73efeff012643fdf4569',
 '73f5923f9a089760b101',
 '73f89bbd14bfe1deb6a7',
 '73f9d410c1c51abcad56',
 '73f9e021e02edabee827',
 '73fbb10fb69d7e563b55',
 '7403d725e351deb02eab',
 '7403f4737f07437328f1',
 '7404c92baf6d722593d5',
 '74053fab1b25087b2a08',
 '7406970ce57a9072ab1a',
 '7407391d10b73f63ed02',
 '7407cdd640c03c4aa330',
 '74081b78f3a0d9a324c6',
 '740ef3608477c494955b',
 '7411890cd9da964d2ee5',
 '7418ae61295a942f22e3',
 '742115d76076bf519bc1',
 '74228308cff1793cdaa1',
 '74252b5ec3c4d6386e92',
 '742751af4e3ce1a80147',
 '7430576d78fc34b6d0bb',
 '7431e83b6c246452c1cf',
 '7433a127c01b7e94be42',
 '7434e72bdcf8fd063065',
 '7435f8ec5bb016da1938',
 '74366975729d00806916',
 '743c1fdd53102c6b536e',
 '7440e969e7f8be84ebc6',
 '74513be59e2678165a73',
 '7451a8cbf52772ded83f',
 '7455de933fd301fb42a4',
 '74570f1fa2509787fed5',
 '745aea65f0f07d314516',
 '745c6b1180d9be9e09b0',
 '745e62a5a732e7a5925b',
 '746b7d0f5fa0f977c2ab',
 '74701415eb714d4871cb',
 '7470abec2ee39262f042',
 '74716d999d4bfbb9a70b',
 '7474e4de856212252817',
 '7475086fda0044ffc810',
 '74765d339b37eaff314f',
 '7477812938520d51e03d',
 '747b9c957efeaf04e387',
 '747d971a42121e832903',
 '747db319c02b8381ef6d',
 '747f492d3b71f5b5ec29',
 '7482db1045605672ca2c',
 '74830802079efc592b16',
 '7488c7b2a348deed8d9e',
 '748af09ba190b38aefd7',
 '748b22a3ecd658e50189',
 '748ddee34e2084efdfd8',
 '748fcc03795a0bd80ce8',
 '7491f5a799b3f8ce6a73',
 '74985e40d6da63e27371',
 '749964766c531eda2b2d',
 '749a92de1ef426753d37',
 '749d266d61517418f4f0',
 '749d89740c1fb05bc5e8',
 '74a3ba0ecf90f838e441',
 '74a402a8f6bb097b0a77',
 '74a485f7527ecc3909bf',
 '74a4a4b58b8301a5120e',
 '74a5ccab240238ed150a',
 '74a85a5ce199c3df888c',
 '74aa1db919097c74b693',
 '74ab170e7a4c9a53e75b',
 '74ab45900972d0aacb8c',
 '74ab50b1f796f1cc2b74',
 '74ad322eb7e623c5a7e4',
 '74af131947216556a1e7',
 '74af9ef7d1041d4957d8',
 '74b16c7dde9a51133462',
 '74b21f9d96217fbf0228',
 '74b6467c118d0dcf02ae',
 '74b7bb3dd7afeab67e1a',
 '74bc5b4774818391e5b7',
 '74be9511b3637f47dbd0',
 '74beb46f3c1d89e79649',
 '74bf7ee568af8eafdd93',
 '74bfd9f4da850bbf93d2',
 '74bfea5ba9a43616c709',
 '74c0f4c2289baecb6f91',
 '74c19132b28fcf18345d',
 '74c603caa6d4cd8d938e',
 '74ca9259f8a550e82e4c',
 '74cc361eaf3a0f2a0fc6',
 '74ce4c2b7466c824e3db',
 '74d3bfa0bc1db085847d',
 '74d4bff207ddeb74a6b4',
 '74ddc833d6513f0faefd',
 '74e98f948de0d056f460',
 '74ee7ac82d9f4e61d9c1',
 '74ee9dde17967f797ecf',
 '74f22c62f0a2ec41ccfc',
 '74f57d2223182c662cc0',
 '74f57d66eb9ff4e9618b',
 '74f5ce9340b25c55b932',
 '74fa4ed9fa5a70741a33',
 '74fc16599ee4fc6a71fe',
 '74fcd65871081d460f70',
 '74fdb7fa7363b13e74e8',
 '74fe61771ff08c94c263',
 '7501a37b0a0ca5f25f15',
 '75065f73b4e5ffc42cb4',
 '75076c16ca890c040078',
 '7509e42a626d71b1bf48',
 '750ca317d6fdca899e56',
 '750dc81878f7ad8e86cf',
 '751133e4b46a8dec7c78',
 '7511af00699d16796d85',
 '7513a6f89ced1ecb4ec8',
 '7515cee7ce29ea395ccf',
 '751c548a0bd560f54d4f',
 '752176ee87f2c20b45fa',
 '752a4a4e301d95ace89f',
 '752b4bded9980bdb630f',
 '7535ada07b32ec777055',
 '753936f5670ca7a0b49f',
 '753b6b718e193ca5e6d7',
 '753c86fcc1d3b6e74c9a',
 '754391b6f601d6f3642c',
 '754524de6229a6fde9b3',
 '7545971ec38f8c72bf59',
 '75489da05af57c6621e3',
 '754d9f500640fa747c2e',
 '754e78401c8c37084b6a',
 '7550d5b7a045d68f3624',
 '755292b5f456bb354ff2',
 '7555ca600357e4e4b81b',
 '7558805ca041f7a6b2fa',
 '75594b61ae9f2f572b8f',
 '7559be851bd0a8922a7c',
 '755ad1a45a38c1c28433',
 '755c16c4d86c2b19ace5',
 '755e2e531a48ef5fdb3a',
 '755ec1c391f4a83f93c2',
 '75657902315577ce744c',
 '7565ac01cc3d45dcd915',
 '7571fdaeecdf02c7bf2d',
 '75739c4d53e809438028',
 '75746333480f0cb32e56',
 '75753915a04d21df9d87',
 '757ed643fd5bf28cb902',
 '757f0ccd8152072bb7c1',
 '7580bedc481cd2276884',
 '75813d94885c0519060c',
 '758ad5fe967a15d08e47',
 '758ca8adf5d5386df923',
 '758dcb71197f11133614',
 '7591bfe187af39f8c250',
 '75931a09d310ee2f1b16',
 '7593e3805b6c0fb4c851',
 '75994d779d5f8b2c2919',
 '759960117b13a7af5b8c',
 '75a053bc536d1e616924',
 '75a356d3da38dba08724',
 '75ac51c29ebaa727e04a',
 '75af7d4cd9b8ac8b77dc',
 '75b0d6111ae2d56a7be6',
 '75b46d719b3fb4a92796',
 '75b87dc3ceb4df96b1c7',
 '75bac8848d7691d8d21a',
 '75beb51968bbc76c2bcd',
 '75c48c7b842d3b4fc21e',
 '75c8afc49a573cb041b7',
 '75cc4198a56bb3414935',
 '75d4407c660177617cb6',
 '75d46475ee782479cb8c',
 '75d6d66878c907611e02',
 '75d79c94a68931ff7288',
 '75d7d57ef4a771225159',
 '75dc947af7807e8c26c6',
 '75df6c91b6dc30e29ac1',
 '75e16425eac795176458',
 '75e2a73147851a10d824',
 '75e2aceed85e6e841539',
 '75e30c9aac5443fca09b',
 '75e3a3df613d9fb877ae',
 '75f09459247c851bde5f',
 '75f187dbc4d7d90cabdd',
 '75f1e0d9c7d0ad80704f',
 '75f36bf195dfebae4f18',
 '75f3fd72d1d0004ca2a2',
 '75fddfa22d3b3e6c1db3',
 '75fe58e42832ac8c746d',
 '76069cc7e7e98edcfdc2',
 '7607097c46ca27c67438',
 '7607915a7e04b2368654',
 '7609aff4c33cec17717f',
 '760ba3495d20236021b4',
 '760c6a4ad11655861de4',
 '7618874674bb9796ed35',
 '761d793d52b1584a6a7d',
 '761fd5a2ab638a8128b5',
 '7628c96d4efa03832ff8',
 '762ca28b6c957c7db253',
 '763021b317dd2f002aa5',
 '7634dae3357b9bac9730',
 '763aae369b8b6917c82b',
 '763b8c69efe6c5d4240a',
 '763bcadf0f8d886e9729',
 '763ce950a431c77b35fa',
 '764074264170930dd154',
 '7644bd0070c8f1961b22',
 '764d7de22cc4eaf4d663',
 '765215fe576b8085fd7b',
 '7652a2936566fa2f8745',
 '76543fa053e9faeb8681',
 '765759683780736abfd0',
 '765b1b8cabbbd0091a03',
 '766a501062f70f49a447',
 '766cab510125f9c66c33',
 '766cad65bbe0c9ff3def',
 '767211d53e3e406049ec',
 '767d422bb11257dd5215',
 '767e92e81cfe24daddbf',
 '767f8ece545c78d19820',
 '768074f3e8faf6ac1087',
 '7683cab2e9ade81b5cc0',
 '76899e645f096e3ed156',
 '768c2e7cedbd7a468261',
 '768ead52a40fcc28c401',
 '768f048f2c5c4cb1f962',
 '76927e288b908a92791b',
 '769283e1220f833ec502',
 '76952d3a137be65751af',
 '769644bf733289c0bbc9',
 '769b4572691840a52945',
 '76a0011183ba0c8f77cf',
 '76a280eb7c5e39582b05',
 '76a4353aed8eedf8096f']

# %% [markdown]
# 12

# %%
qids_12=['76a5bef7da872b0d9900',
 '76aaa719fa95fad1314f',
 '76ae7a189a2341b326cd',
 '76b0f26e715f6bff4d5b',
 '76b5c27d5486b6ad8ae0',
 '76bae1941b4b2a8db0a6',
 '76bcf6f2409961397df1',
 '76bf62e35e70dfcb0bb2',
 '76bfddd868da964594d3',
 '76c22d2f528f56266b23',
 '76c654a52973bf79a730',
 '76d3f8e7d3df982ee3b7',
 '76d621d30c0fde9a3ed3',
 '76d6c46a31a1ae22ddaf',
 '76db997fb945e8e1cc02',
 '76dd231f976a14aa43e5',
 '76dda66da0d4434b5eec',
 '76df93365d41fff2ea1a',
 '76e203fe37817148cf04',
 '76e8071325c31f9f5add',
 '76eb7db9d9c353505224',
 '76eddf26aaa3047dfa61',
 '76ee22ea627ddd385e03',
 '76ee7d2e31ea6f13cb40',
 '76f99178c74d33510aae',
 '76fd099fb7ad0c500ab1',
 '76fd700147292bbb1390',
 '7704bf4537d8f5a66101',
 '7708fd2ae1bed154e8d3',
 '770c04a9cd58bc2b03fe',
 '770c8ef390cc1371314d',
 '770fd0f6ad910ca08839',
 '7711deb98804c15eab26',
 '771224d32e76c35e6e98',
 '7717f85cf266948c68df',
 '77198a133c83abc5e9ff',
 '771c9ceb87e941f60b76',
 '771d7ac9aff81c319efd',
 '771d903e081ccd77fae8',
 '77248baf0339370e2dad',
 '7724e8c9b09131b64481',
 '772d8d8abb835307cbdf',
 '7732ac945bfdc748c597',
 '7734baca1351a84e6d1d',
 '7736709c013feb0e7bc6',
 '773ef262b148db0efc6a',
 '77404a00487265cc6c27',
 '7743ac9c76097428596c',
 '7744fe49f4655f08c860',
 '774713d061485827c4b2',
 '774865026952f53fd7e2',
 '774b0fd6fdee6c201a85',
 '775096586fd6e1718208',
 '7751c5bfaaeee4c6b4e5',
 '7752e8906e7ab60e3462',
 '7753141c4da7325026fe',
 '7754504e4b7518f46028',
 '7754a680d132e2bb56a3',
 '77568e684900bcfde169',
 '7760186cdd2cb100292f',
 '7768c9f85c28f6af5ad3',
 '776948d6464e8532fab2',
 '776a691db22aae24b558',
 '776afd5c4eabb1ad0924',
 '776d304e0383c834455f',
 '776ede5b48b7f1601818',
 '7771cd0113eb2cb02f85',
 '7771f60638c71966d1ff',
 '77777fed6957e852332e',
 '777d63dfe4faba9cfa89',
 '777e7d0d052091b0e072',
 '777ff7b88c0301955041',
 '7782a431ca5aa4681d9d',
 '7786448c6b9db3138c76',
 '778bc8cd97efd4a7e552',
 '778c63692fc175dc04ff',
 '778c8aba371aa7a8107f',
 '778fb0989d5321fe9d57',
 '7794324e254a1296e353',
 '7795d7bd0ff6a7008154',
 '77971080ce9cd03a0698',
 '7799637bd20c7dc11c80',
 '77a19bc6e29420c6ca38',
 '77a1f6cef9a499c442ab',
 '77a2f3606d71c7f657f3',
 '77a3cfe925298fcf1c75',
 '77a44080babc0d1fef7c',
 '77a4cbb4794a3dfb5e37',
 '77a56626a8370c621ac7',
 '77a6022896222593649f',
 '77ab08554f823b2095a7',
 '77ab8fe447bd614c25b3',
 '77abf956937b22ea5617',
 '77b11f9bc381396f0fa5',
 '77b507e12e7e13a45d85',
 '77b95a8b53e2243498d6',
 '77b963c4d33c4c119627',
 '77bb58719a0fc942884c',
 '77bdede3a0b36dd748b6',
 '77c07d13e63c69cc946e',
 '77c31e8b0b996d04d663',
 '77c66a48c56abe52d9f2',
 '77c7c85be47121b4d3f0',
 '77cc3eb7e9cd6cf59f9c',
 '77cd6ec3955af713bcb4',
 '77ce185e9d44eccd2284',
 '77d0fe14dd91bddf3b3c',
 '77d636b5d97f36024910',
 '77d7b0fbf8065fbd8b63',
 '77daeff3f7959010aca0',
 '77dfb67313a2803bba02',
 '77e10929cc8761a4446a',
 '77e2c235539aa6b8af1e',
 '77e4086a83cfe64d6012',
 '77e434d695249499c2f3',
 '77e508748189a841311a',
 '77e77dc02dc498062a18',
 '77eaa468359b1936c598',
 '77eb497eddabf2ff46d3',
 '77eb796119d425d971bf',
 '77ec62013e9b26b1175f',
 '77eddf268c7e5a30b32c',
 '77f06b29a5d919ced524',
 '77f0d6d72243cf0bf733',
 '77f1928db727b3315594',
 '77f2fc5cbaeb76447a0b',
 '77f7411543e1ed8676cd',
 '77f86f53d566680499f8',
 '77f9ad981c14f2e35e1b',
 '77fbcbbb82643837c8ed',
 '77fedb529f5bdbcdb8c8',
 '78033ce473504285da10',
 '78051d1248c25565dc42',
 '780713884d1ed252c063',
 '7807b5a12ec77f9810c8',
 '7807ecdbc804558e9c73',
 '780b17ef91a65808057b',
 '780eaeaf9ff3fbaedff3',
 '780ee1e14cf53c55f89b',
 '780f813bc9fa3479c2b6',
 '78104beca4f1aca78c19',
 '78108136a583ea3f63f7',
 '7811a390ceb979b6b8ae',
 '7817a47d14d5180b902a',
 '78182f1fd06ca88a9054',
 '781a7215df15b53cc21f',
 '7825994c72032b4d62e9',
 '78284d894473d3c51de6',
 '782aba516c6aff70072e',
 '783f6147e8f35c88f457',
 '783f93b7982ec85cc1da',
 '7844232cc6f22b7d4920',
 '7844acc2ab3cee5493b9',
 '78463ea7817aa2145d52',
 '78496120bc47a1449bca',
 '784b9c815ff3544d6fec',
 '784cc01ad906cdb00ba5',
 '784d49ffb6c123335a5d',
 '7857c2a8befe77753da0',
 '785ce9261b20e43f166e',
 '785e016857b4bc54cdf1',
 '7860a93b6401f2442aea',
 '7865848cb8a5ca0eaad8',
 '78668705061224f62c79',
 '78691813fe0087df84d5',
 '786beec6bda48275eacf',
 '786cf082c56fd6d7f816',
 '786d683349305ba41009',
 '786f86aa6066746fcce8',
 '787141e7706be9597318',
 '787c7e159544dbee90e5',
 '78801695ebbd12e79f4d',
 '7880c102924bbc60675a',
 '7887bd7344650b12b27e',
 '788ae52543200f4f4a0a',
 '788af9f91f8c7f5e9373',
 '788b2f960b9b3026c378',
 '788db7e07b39c51c42a1',
 '78908f8324a4861fb555',
 '789ad994d1d7123a1213',
 '789c03511d4a14e867f7',
 '789db0c7902393cb8f47',
 '789f0e0f3d170939c829',
 '789fd0f2d71c879e7139',
 '78a15b90e507c962ec8c',
 '78a59a1470e0b9b209ac',
 '78a73aa090e4329e1168',
 '78a7453c907848edfd52',
 '78a83ea0b184e69eca75',
 '78abe7aceac9e37a5398',
 '78b08ae4f01d276560cb',
 '78b203c865fd17193eb1',
 '78b3d82d197ad115b656',
 '78b5a9004c0f38646b3d',
 '78bb1ee5943a165977a3',
 '78bc25a000c2490d83f3',
 '78bd22c032e8aa5febd9',
 '78c1075691c363240a31',
 '78c371d5e665299d6bce',
 '78c630295c53bc5b4b91',
 '78cadbe7a3f6623c41e2',
 '78cdeb07c286ac424061',
 '78d53c017dab9824e9df',
 '78d6c112a27daf99443f',
 '78dcff64f682166b523c',
 '78e0f79e430c2ac397f6',
 '78e4a0e221fafa8fc90a',
 '78e6ad18bbdc16c07289',
 '78e729022f4085e18e84',
 '78ea6371367b34596d0d',
 '78ec3a3450ce2187da82',
 '78f03949d48c9352f15b',
 '78f143539b85d37ff746',
 '78f7095f348085720dd8',
 '78f91ae3a4e1a088cdde',
 '78f9395fc07312c89734',
 '78fb326b1f64636131b0',
 '78ffd66e4394e07ba570',
 '79027d41240a18f92ef3',
 '790949227ee34b02c398',
 '790cc06641366c866955',
 '790e927b9aaf81821746',
 '7914efefb4b66c83efe3',
 '7917e90e8d1cbbb81552',
 '791853dd2560f5f65609',
 '791861efb083a476b617',
 '7918a3df0fe5d9004b26',
 '7926fbcc29da645efec3',
 '792846ebf41e5d49f931',
 '792e64dc3b6e50d0552e',
 '7930ae7871c523ff3053',
 '7939f7039ea5921c4c30',
 '793d7a3fca83f62eb241',
 '793dcfa54164e12b0489',
 '79419d8697a1951e4296',
 '79490b69343f6b74435b',
 '794b472a2f1c0b4f2344',
 '794f32ff3f4577fccb2a',
 '794f33b19839f8cd04c9',
 '7951601c0ace4d5818f1',
 '7953aa81307c7b75a196',
 '7954abdf72adbed03896',
 '7955cc44d8f7357d5878',
 '7956ef4f57ee957d6020',
 '7958d81f9b3dc1430df4',
 '795a0f5af4c39f1806f5',
 '795adfb76ee30f8b220d',
 '795b5ba4c9038314289c',
 '795bcb6a54449408644f',
 '79652cb9f07fea8e1a28',
 '79671973b7f6cab8e4ca',
 '796dd8641b62e0ce040d',
 '796ef2c3884b6adcf645',
 '797e8abfbfb72898dab8',
 '797ee04b5f9c2bcfa8a8',
 '79818aa4b8eacf6c910c',
 '798986b2fc32c4f5f0a9',
 '798d41860883803cfc26',
 '7990417453c35de9ca18',
 '7990feca98976dd3a9c6',
 '79924c974c04d01b8f35',
 '7992acb28599493b8ba9',
 '79999f9eb0c820748bfd',
 '799ccbfcec615c0f38a4',
 '799fe97c8c9a52ebcc0c',
 '79a8f27e82252743cd9c',
 '79a9d9c91cfcbc1702ba',
 '79af97603c990f817791',
 '79b370b524dab57cf92e',
 '79b3b1b71ce16d9459fd',
 '79b68088f66c3ee686ca',
 '79b6a56d3ef0351baa4c',
 '79b7ffdd6aa7ea814c27',
 '79bfded3fcc404f6fa8f',
 '79c03414c55c4e122bae',
 '79c29f1bf2e9a66481d2',
 '79c5c5fd541ca2776fb7',
 '79c6bd416a5f84dd7bf7',
 '79c7c324ab4efad6f1ce',
 '79ce98e987cd36bb1017',
 '79d5f35b25179fa2a7ad',
 '79d6d11e2c173c68240b',
 '79d90f67c56988df489c',
 '79db88c8c6f436a4878e',
 '79dd08bcbac4ea78a382',
 '79de2a67154a049c6f83',
 '79de9d7fa71bc7640f58',
 '79e15a24360a8c9a211b',
 '79e1e01ca72d20e272cf',
 '79e470d65f0af65e9c7a',
 '79e5722d84b4c0a26573',
 '79eb10a0edeade1500d8',
 '79ec929064c98ee70053',
 '79edb085780f801349c4',
 '79f098aed0404773dce1',
 '79f1492493d7b18eab9c',
 '79f9895d1b4341cca6ef',
 '79fae76268f02d0ad208',
 '79fbb59d73d4343b202f',
 '79fd3eb481e0efac0656',
 '79fdf535169915c618e5',
 '79fe7ad28d6a0b95bbb4',
 '7a035f2d9e8d176f86de',
 '7a04f3d68472648ebd98',
 '7a05d37350b86e11452b',
 '7a071fda800c096da17f',
 '7a09239c5f7050860a95',
 '7a09f79a8e9c0a95b044',
 '7a09fd82d53cd6cd0d57',
 '7a0d961ce3ca55fb32f6',
 '7a113e5d66c7fd7ec1eb',
 '7a1342beb0668e01bdea',
 '7a138271e445264e6592',
 '7a187a5e7ec282b65150',
 '7a19f2007a8d35e63b0d',
 '7a1cf1188176cbcc8fb3',
 '7a1ee1e5b482ddaf3c3d',
 '7a2061841c4b05882ceb',
 '7a26dbb22bfacb9b499a',
 '7a28a0ac966326c0d447',
 '7a2e54013b589b7fc347',
 '7a2fb65fb06bc5bdac02',
 '7a34262dceeb143c231e',
 '7a34687e4fea06b2c97b',
 '7a3ae1caefc0d2716fa5',
 '7a3f3f91ee8d128fc326',
 '7a412b947a689b84b0cb',
 '7a41fc872b1464c9e9bc',
 '7a4377244911249b1e48',
 '7a46be9702aa0a93729c',
 '7a4aa965a1e123947877',
 '7a4ae5ab02aa2a286680',
 '7a4bfd767a28d6695b55',
 '7a4ced334967c86e3b37',
 '7a56d90b7e5f0332a510',
 '7a58f21df4461dd648a7',
 '7a59538598af63807a93',
 '7a5a32bfcff1ef462e32',
 '7a5a5232dbe55462752b',
 '7a5c26777e5558f4a4d8',
 '7a61d0e2d3db37343489',
 '7a620b285ce737b5d265',
 '7a6834bab4396c96df23',
 '7a698a23c8cc2417fa43',
 '7a70b3d04f4776a91940',
 '7a7149edac8936250c99',
 '7a74832e619c2f30ecd7',
 '7a77c487cf7b20b3c31f',
 '7a79396428c5cfd2c566',
 '7a8469a9764bdfb87e00',
 '7a8469b6d7b3e5c80339',
 '7a8522b2a424264de3c3',
 '7a87c942740f5ac98ecf',
 '7a8eae5b116eafa81ab6',
 '7a9286913d65711aa36e',
 '7a92b6de22283f1643f4',
 '7a93b75f63b3632cf254',
 '7a95c390f7561f9fb3f0',
 '7a968e5abe8695cf7d05',
 '7a9a02d1184761fd8842',
 '7a9d50f62ed4bb542e3f',
 '7aa39d7879d2e5f4f5f3',
 '7aa6fbbb7d67ae7ae15d',
 '7aad36b05216432d1285',
 '7ab09762901522beebd2',
 '7ab2616bb730a111695d',
 '7ab27fbe43f063df3cd1',
 '7ab2f30fa5580a3c4694',
 '7ab7077c86439a03b988',
 '7abbfd44952031362d9a',
 '7abda226bc14d40353c7',
 '7ad4df673828b4bd15a8',
 '7ad5e358efa362d89495',
 '7ad9debcf304a2ea2899',
 '7ae081c103eebefbdece',
 '7ae6fcdd71ccda17d00a',
 '7ae7617270149e593fe7',
 '7ae81175bdddce15eaef',
 '7ae9b38efcb0a2234f44',
 '7aea7bc7c5d59e1a1aba',
 '7aef35f32af337eae5b9',
 '7af1e5ebde2439736e3a',
 '7af38b88e45ef3e2091c',
 '7af4b5a711f90ed16b0f',
 '7af6490e6b9a59c5556e',
 '7afa0dcecbe81d55851d',
 '7afa8186a51690caf530',
 '7afdc09e6a5e92f98b29',
 '7b012a30f2b3cc796bd9',
 '7b0821eb69e5a50841fb',
 '7b08b6c291ff7c14805f',
 '7b11215aed291952c512',
 '7b112600ccc77c085b79',
 '7b15ed34c88f07750e32',
 '7b1c4e55977e24e40ddd',
 '7b2063622d4d51559ee0',
 '7b2073dd5c1fd927d887',
 '7b256aa4564e28fc0e55',
 '7b2991af1b58c2ab4ce9',
 '7b2b9caf4bf764aba34e',
 '7b2bedaab950446c5a44',
 '7b2d7d0def08f1a74161',
 '7b2e6b0682c718a0f607',
 '7b30d0b1bba632184f69',
 '7b3179bbcf2f0edb9855',
 '7b377e5b0243a38dc2a9',
 '7b38964bc438087a04fa',
 '7b3fadc7a0624cfd9a41',
 '7b56576b96a1b7b834d7',
 '7b56bf9f4bc19c84da92',
 '7b5d5c5074215b1e4deb',
 '7b5e166af0f6766ae93c',
 '7b5e9b09ba7a646ca9eb',
 '7b5ec27a8ce38672e6a4',
 '7b60b936102bf54feb50',
 '7b661653b4c36fc37d19',
 '7b6a12e742c5f81b1710',
 '7b6a7321b921d8d0e4e7',
 '7b6ed54c8f3fed91495c',
 '7b72eb942a99ca8062cb',
 '7b733ee09fc71c618f7c',
 '7b7546d28a4465500517',
 '7b76fd201da0a731cc55',
 '7b7788e3cbad44d9ff50',
 '7b779a07b49172d3207d',
 '7b78181f9bb8a3b6e31d',
 '7b78d6ca5b4f4048423e',
 '7b79aa4d138198206d21',
 '7b80a748372f98646435',
 '7b80ac2a8570ac5d823b',
 '7b80b09d17ad8870040c',
 '7b8fda2e45e241cd5dc0',
 '7b91561e3b48df4c11df',
 '7b984134c31aefff5795',
 '7b98512d3027d37113ee',
 '7b9da7470db9396458e4',
 '7b9e6f42b2f14cb6f34b',
 '7b9f6835f6b52dac3073',
 '7b9f8fc5aad51ccdedc6',
 '7ba213969b188e8cc215',
 '7ba365f4f640999852be',
 '7ba4e865d0f330dc02c2',
 '7ba668908088ed52f136',
 '7bb3447ec89202da4f1e',
 '7bb39f521a1907539f69',
 '7bb6c679fb2c31270b5e',
 '7bb8bbbe3773ba7ad9ed',
 '7bbe8aca4d682a7f657d',
 '7bc036ab58e513a72369',
 '7bc58c402ac890c5a300',
 '7bc68a1cd4b6a98f75ec',
 '7bc7708527ecb1a413f9',
 '7bc8e8b049a0b2e70847',
 '7bd1d6c318bfa538feef',
 '7bd301663195b77a8288',
 '7bd354879b4ff7fbc2e5',
 '7bd972ad803747804a2e',
 '7bdad3964cb7b33b6126',
 '7bddcc518724d358c09d',
 '7be6c27835bb4d419c00',
 '7beb0729f3f77d4bb369',
 '7bf67daaf10e7d72c159',
 '7c03ed101065aa7453ce',
 '7c06e92f39deb777db18',
 '7c08932f73f23b7862f1',
 '7c0e540491b27085ada6',
 '7c114239438890ebc500',
 '7c12181d8af7661fc914',
 '7c1787d132da1344581e',
 '7c19f0e7827c370321bc',
 '7c1baa13df17988ba725',
 '7c1bf6e86a737487cdb7',
 '7c1e0be943fd0373c3cb',
 '7c1fc4db4535914dcea9',
 '7c203448d56af83b067a',
 '7c2173a33a55fee60051',
 '7c247f8b0b8ef83be3de',
 '7c2520f011ac0c90c656',
 '7c2628b03d258bcbbd59',
 '7c2808306523e449294e',
 '7c2a8437076efb50a091',
 '7c2dfe5053b661fcbfb9',
 '7c31b55cc7508bc1e9d1',
 '7c339da81fccc99386d6',
 '7c39a3e253f7729de6a6',
 '7c3b4dc466212d10bd70',
 '7c3d8539836540389826',
 '7c42601e888ef9d5aec6',
 '7c42990dd4ccb80d3287',
 '7c49f1d312c8ae8a3a45',
 '7c506c3d10cc37df945e',
 '7c56655904519ea1915a',
 '7c56e2e8573496614be5',
 '7c5c2c19997f04330680',
 '7c5cdd7ce353a231773d',
 '7c5d8a394ec617f2aaf0',
 '7c5e1e9a6c4c5315b007',
 '7c5f2a8ae252003f3c33',
 '7c679d8603edb4720df0',
 '7c694e8f9d8b489caa4b',
 '7c697ae0650db329b327',
 '7c69ab8b8a249e716b1a',
 '7c6bee53a8a0841b9735',
 '7c72c0a93d10ff0598a6',
 '7c74aabcf1da1ae799da',
 '7c74ea782315f82bb812',
 '7c7634044e5f6001c660',
 '7c79cf9de99659e16660',
 '7c79d56be88897ea85c5',
 '7c7a9c219df2151fcffb',
 '7c7d43f0a073c0c1911a',
 '7c7e38a2743e65d6ffea',
 '7c7e4dd871581bf47c6a',
 '7c8381d53111afdd6f15',
 '7c90bff44d96dc03f2bd',
 '7c93ecca65d1eadf6d2f',
 '7c96975c472b1e14668d',
 '7ca2553c023d315f3ec2',
 '7cae9effb9594ca7855c',
 '7cb45434dbf7decd430d',
 '7cbd270e138381f0d66b',
 '7cbe369ac9d7487df600',
 '7cbec6c86d3b2b18cc8e',
 '7cc5ffed79af93b7e306',
 '7cc8af06db433f0c522f',
 '7cca633ea094a6550974',
 '7ccb3b76e0737165dcb8',
 '7ccd9b069877324ee251',
 '7cce8455faeca52773c2',
 '7cd120591eb2a0158960',
 '7cd12f3b98eba1e26c97',
 '7cd3e60dd0aee28af16d',
 '7cd41d0bdd58fbf26d02',
 '7cd420caa85895fb3e65',
 '7cd6702cd5aca62d5dbc',
 '7cd798de19b5cb4f82c8',
 '7cda3d66b9a401b995d6',
 '7cdb32e6fe6a32ead3fa',
 '7cdd0e31b9a9ebf7455c',
 '7cdd695984a0adf3ee98',
 '7cde0b503516b050f51f',
 '7ce0c9b2dfeb520c12dd',
 '7ce337698da350b34903',
 '7ce357f3b3c9ce89b602',
 '7ce8f2e0f0cf7ee9dfd7',
 '7ce9c6d3103325e4b940',
 '7ce9cdb936d32c5aa30b',
 '7ce9dc34eebdafb5400d',
 '7cefc6b3d3b8bd7fe2a3',
 '7cf21c6e6b510e5eb761',
 '7cf22570c172ee91ec0c',
 '7cf3fe66af783ff71915',
 '7cf584f1037b07f8ce64',
 '7cfa0809e113b257a29a',
 '7cfcffce8b8fe0f8a8a8',
 '7cfd9a46739e0baeadb4',
 '7d01b468cc7d80bb7457',
 '7d01e9e450b86de068d3',
 '7d03eb1c951a053c4b0f',
 '7d04d2d3bfd8599963c1',
 '7d070c6400fcbc059d01',
 '7d078dba6f42777a1758',
 '7d0862db58b412636c85',
 '7d0ba84856f92b3249bc',
 '7d0cb8fa1e9b544fbd51',
 '7d0f757c239260847bc2',
 '7d11596881df6a19c208',
 '7d11bdd9d12e1eb54b6c',
 '7d13c96ea1c1f4fa3164',
 '7d19355953dc04396935',
 '7d1c52b44f7585bd1e1e',
 '7d229332e8f95f779309',
 '7d31a1b0a34f0d8c9f34',
 '7d32f278d4d8075fbf35',
 '7d3670f2dfe77c39f562',
 '7d373f1d46d87a8ee6ec',
 '7d3fdc7badb6e21f411a',
 '7d4184a6912e86a57fb5',
 '7d4678b7e503ffbb54e5',
 '7d48071cdaf3a9cae882',
 '7d4b6796c9ce3010978a',
 '7d4b988cd1b4a06e1458',
 '7d51e021748886db126f',
 '7d5bfc74d972b04b47c2',
 '7d5c3a76f1020c9ea0a6',
 '7d6342b4623c23912ca9',
 '7d63c0c962ec4271be86',
 '7d64088ed04f1d6c5229',
 '7d6746241351f0efffd0',
 '7d70f59992f196d1c669',
 '7d7340d814b55d177e88',
 '7d73550aa8711c25c934',
 '7d74bfff50c8008923d2',
 '7d7544757b40f9725386',
 '7d7888d5aa2edf3f6bd2',
 '7d7bb8b75340f7f93707',
 '7d7bba87043611bb0fbd',
 '7d7dabbeb073f6da42b7',
 '7d8055c340209198e78c',
 '7d8365baaf3b3373d8dd',
 '7d89d4ef82a2ad89e109',
 '7d8ad712d2b9c673050d',
 '7d8c5ba15a1e9bc858e6',
 '7d8d904e29190d79a5d4',
 '7d91e87d66a50a485fb2',
 '7d936c70d0b325e130da',
 '7d939cff9f6ddbab186b',
 '7d94e183f506eff8548c',
 '7d94e785456c62bdac6e',
 '7d969dbdc9be31a86bad',
 '7d9bcc02a30907f2eb68',
 '7d9d1c7c539966c6aa72',
 '7d9e1475c743b9c4dd85',
 '7da0c17c6aa890f048c7',
 '7da1fd84c14dba036aba',
 '7da2e755c858f53c56dd',
 '7dac6cd1dc0ecf136453',
 '7dac82bdcbf56169c85f',
 '7daed614aae3b3292fac',
 '7db380bd1b7a67e42bcc',
 '7db78d4c7fe8b3d6ced3',
 '7dba19029dec89d39b7b',
 '7dba573510590aa7a445',
 '7dbcc3af049f311d669e',
 '7dc33dc28a72cc041f97',
 '7dc6f68aecc61c363e14',
 '7dcb86726d75c5933942',
 '7dce833113c52d4b3455',
 '7ddb3afcf3d628ec1ce1',
 '7ddc1a0b311674a3c14f',
 '7ddc9777ba942b515453',
 '7dde54db642ef1aa2e6f',
 '7de50aa259cdcd9c4595',
 '7de68d7d7cc636b40150',
 '7dea0f40cd44839986f8',
 '7deaa5e4f064e58fbd38',
 '7deb7d0576eec50a985a',
 '7dec7ecd86ed73302576',
 '7df18a49b331c06d0526',
 '7df57c87b8c41a0ff475',
 '7df594f8005254359acd',
 '7df90eb4173bd2beb68a',
 '7df97d800b61545b9795',
 '7df9e2aa217958b89b4b',
 '7dfa61a74565a29cbdd3',
 '7dfc049a1009636ae18a',
 '7dfc95cad378dfbb1fae',
 '7e01139353340f2017d6',
 '7e01f640a697e7925f61',
 '7e04437d3d06d53d1cb8',
 '7e04c40f1f0a0e422567',
 '7e054545102e40ef06d7',
 '7e0613e8b17e9a532bd8',
 '7e063f6f3ac782964900',
 '7e06af6e9cb0b1102bab',
 '7e07fa7bdf82205083ed',
 '7e0929c2e4faa4e6f37e',
 '7e09dfc217bd190d43ed',
 '7e0b386bb4db3d635771',
 '7e0da9de7a272bee9759',
 '7e11b52f5e26b6275d19',
 '7e14aa52eec1bce5da97',
 '7e1de6dea0260d1c4f02',
 '7e208574a23aba959740',
 '7e27bbffff33872fd89e',
 '7e290bdbed44684a5371',
 '7e29a01dc2c79d05e312',
 '7e2b81f581d9500bc0f9',
 '7e2c5049273f418e37ef',
 '7e2dd1afbac059d4c28e',
 '7e310315e9a05e7ca1c5',
 '7e318c27063a53b1ae43',
 '7e337da62a3da668d7bf',
 '7e350e9afbcf329d4726',
 '7e361b67b2ae9a2e7a2a',
 '7e36d152e18054abce60',
 '7e3a5e7183b17ffc3a88',
 '7e3b924cf89adeb2a290',
 '7e3c22d2957c8d8f5080',
 '7e4305908fadcd68bc08',
 '7e4337258d72455da696',
 '7e44eef4649dce4c77f0',
 '7e46be598d4fdb0fec10',
 '7e499cd5b66371031f8e',
 '7e49f4d4a6894436422e',
 '7e57d067186896d42dff',
 '7e5a029aa875334c4209',
 '7e5dc5ee24da5904b098',
 '7e5ebdd35ce83053e03a',
 '7e5f48adade3e996a2db',
 '7e6037da77b32c95e057',
 '7e61006eb025dadef8da',
 '7e628ffda773762f50ef',
 '7e62c3baee235ee174aa',
 '7e6d07b2458adcf442bf',
 '7e7081ca8329915e6f9c',
 '7e7383698a75a986a18c',
 '7e7418144c83cffda109',
 '7e780ec0b324b1de1f7f',
 '7e78ec167e68d6d7338a',
 '7e79bd4dcd1570a794a5',
 '7e79bd6131ba166f51c0',
 '7e7a58d7921a09fb4710',
 '7e7bf84ea6a36723f864',
 '7e80c193a9b53bc4e6a6',
 '7e891915d70be9d70ee8',
 '7e8f58b5ab2c6aae9144',
 '7e8f839037ef1c3760d2',
 '7e95b6c42afbe3a32dc4',
 '7e99e096364a3e1ad857',
 '7e9ff111abe4c87fff86',
 '7ea3dc7a25d7493d6056',
 '7ea68888490a630d2fa5',
 '7ea7bede5d10d555c3c1',
 '7ea9e90db69c420ca570',
 '7eaa22bc88478f93326c',
 '7eaa67fd544775ad2947',
 '7eac555e0a9229f1c4b5',
 '7eacb6c98472aa8f781f',
 '7eaf6eac0ee0b1690b89',
 '7eb26b2e253e36c79ff2',
 '7eb3254a7e54649b3319',
 '7eb444cb674764e6df02',
 '7eb53d71bf65943ab144',
 '7eb7d996092ce321ebfd',
 '7eb90d18d4518011b5e4',
 '7eba376cd6123882c374',
 '7ebcc99aed345feebf18',
 '7ebe387355d266e58113',
 '7ebe9985d4f5db412f01',
 '7ec2ce3727c06d20ee9d',
 '7ec488afcb58a262316d',
 '7ec6805dadf1f1215f35',
 '7ec74e23bed5c9ca3a84',
 '7ec762dc61085068d2b0',
 '7ecbbd1b69521dcd7ee5',
 '7ecd11edc663053b9ee8',
 '7ece5bab834099ce300f',
 '7ed1288b26bfe45a4475',
 '7ed15cc147f413ff894a',
 '7ed35ad223fdb145be6b',
 '7ed45222acb95504d4e6',
 '7ed47627da6c66a78c0f',
 '7ed4768c69a6d1b3d888',
 '7ed4892673130e147330',
 '7ee1b50c197b2e16d8f4',
 '7ee3c9f5c50cd0813723',
 '7ee52195a72eff0997da',
 '7ee81c959718059a8a6c',
 '7ee94120aeff0ea5c2fd',
 '7eed1096c3e282faaf46',
 '7eee71bbf4063c393ffd',
 '7ef33f26ea72c83d90e9',
 '7ef573aed3c29d1c45db',
 '7ef75820f25820f045fc',
 '7f03cfa1836c11c6c7f1',
 '7f053412432caecfa9d7',
 '7f08288872b71efcd7c2',
 '7f0b8ce3c47cbdc89d90',
 '7f127b71b91d890218c4',
 '7f12d71aba3ded5d475d',
 '7f16954f58446a4c6a95',
 '7f17e8b0bab1a520ea11',
 '7f1941be662bcf06f030',
 '7f19f934a35f524285fc',
 '7f1a383d75b54a157643',
 '7f1aff0e7ac7aa3a636f',
 '7f1cd8ebffc5c4c6632f',
 '7f208eee0ecb7187f748',
 '7f275b5d7fd4a347afc5',
 '7f27d9a246ae42eba4f5',
 '7f28e42ecb376773aa0c',
 '7f2934901663bacd6b12',
 '7f29f078ce9d5271b022',
 '7f2ace242931554e72e3',
 '7f2b374ee3d5f642f1af',
 '7f2bbb37ed4a22f61b9b',
 '7f2bcf28383a13a5ab83',
 '7f2d98e8be298f73a2b6',
 '7f30aac7e273b5bca5f9',
 '7f3111abe89110f0e052',
 '7f316c47c975e3acd4fa',
 '7f357a3b2490ecd55ff4',
 '7f36514a1584e2559b6d',
 '7f37da2735b724819b60',
 '7f3941d6c2c238511a43',
 '7f397948e605736c07a0',
 '7f3d1caa1a4aeda1156b',
 '7f3e8af10830ad1bae2d',
 '7f4379b97b9fbc6897e6',
 '7f46043fb224006c6b9b',
 '7f46c3a93aad467bdd62',
 '7f4a5cd940e1861d022a',
 '7f4a7c639ae24610ed91',
 '7f4b2f0e1a8956a14b4d',
 '7f4b34554ce079adcf1f',
 '7f4f4d3ce7cda2773403',
 '7f50a8b53eecd362b0a3',
 '7f54f012fbd146c56e79',
 '7f5aafc30f62d8b5a34a',
 '7f605ba1697e69b873ba',
 '7f614dc2ce3169a8da49',
 '7f63fa981756230256ed',
 '7f645442a25c96ddb141',
 '7f6b571911c102f8dce9',
 '7f6c1df6eceddf4de3f2',
 '7f6c8b14e4d15aa283fa',
 '7f6faef06dbe75cda0ad',
 '7f826c63a2db2be0cfcf',
 '7f86cd2a5ff040cccd6b',
 '7f8823382863378822ca',
 '7f88a7d54e882ae65398',
 '7f8ea11b5fec72268e7a',
 '7f8efc323f08c4d8691f',
 '7f8f00c73db1d84bad0b',
 '7f91f0556bf53cbe8986',
 '7f97cbbd2cbcdbbfbe88',
 '7f98522c65a1fc857355',
 '7f9a2a0c7d04af91eabe',
 '7f9c4b803feabcf7ea15',
 '7f9e3298f682fd7a71bc',
 '7fa40d65d4e50076e083',
 '7fa425adde64d97eb645',
 '7fa4d52435ddde3e95bc',
 '7fa5a93d2d005eecd70d',
 '7fa83459c88fc88564a6',
 '7fb393381421f78d6a9f',
 '7fb3bfad810ec665d8a2',
 '7fb51c658ee78d70fe5f',
 '7fbb99e26ca6a777b98d',
 '7fbb9e16a33c250dcaf6',
 '7fd2a3445cef92cb66cb',
 '7fd614bc6850dcdc7cbb',
 '7fd7e8a5cddea5182f78',
 '7fd8beccd126d16c37bf',
 '7fd952a20522ff03eb3a',
 '7fdab8f93c3ca32bcef8',
 '7fdb334d25dc16316d77',
 '7fdf72c0cef8d8387b57',
 '7fe1825d07b6c73ab18f',
 '7fe809aa840ec64ad0a9',
 '7ff05591964297e01546',
 '7ff26069dd015b1c7367',
 '7ff2d97805613fca7f95',
 '7ff348b20ecde03d4985',
 '7ff4873f52e44f520d16',
 '7ff4fc62ad9ffd8e54eb',
 '7ff516038d70fe5cb7fb',
 '7ff63df2b22bfc8b8db7',
 '7ff8302761d4c9e690e6',
 '7ffb09d0759b785c8554',
 '7ffc554a1b2243b6ba3a',
 '7ffd0af7f169474bec72',
 '7fffffa9b214356ecc3d',
 '8003ae4f64363dd241bd',
 '8004ec7cc14a337adbc5',
 '8004f81b9a5d7438bf03',
 '80061e46524c263b9ee0',
 '80098000effda8d454db',
 '800d6565a871b06618e7',
 '800fdfaac9cce88125a1',
 '801858e509ed38cd2efb',
 '80199cb3dadb3cc5a8df',
 '801ace85a3dba41a5b44',
 '801ae5a35e2f3d6a6a13',
 '801b8bab349b02c15a3e',
 '801c1eab44084fece613',
 '801e8fd4ed0a0385cee6',
 '801f841d7c24cadfed21',
 '80207f3473d73b8dcd98',
 '8021b94674913ba3e3ff',
 '8021e1657292ae738f67',
 '8024381e836edb681fde',
 '802713fac1c898f1b360',
 '802a505f0589e1136778',
 '803029994c40fdb1648e',
 '80305979dfc72d24af3d',
 '8030ae988c49bf70f8fa',
 '80331ebd3f62e85cb11b',
 '8035a60de15a6315052b',
 '8036037773edba1c927a',
 '803688ae27cd9256de75',
 '80368e424ae7588f580a',
 '803adc70c95e0cd7e961',
 '803c7ca20d58fc6a0111',
 '803c81c94c294d4966c7',
 '80411dacccae1136edb5',
 '804231f7b2f0d0c799dc',
 '80436e8d599d1f5de66d',
 '8044096c9ecfbcf581f3',
 '80491c514355e91509fb',
 '804ee0f15c1656e67680',
 '8050e389a052d8153f25',
 '805c2403d46f69cbaee6',
 '805ce6342e574fe56ae6',
 '805ea44dca8d2a0ed24a',
 '806159217fc37011837e',
 '8064bf293e58ae0382df',
 '806587ffe3e4e7c22e34',
 '8066fd1ab0bb77125cfa',
 '8068a5da9a1a44acc191',
 '806a65a03c7485b31e32',
 '806a7ca8c55b4e024ed5',
 '806eeb01c593c17e1567',
 '806f565def05d172dd8d',
 '807105547adb9eca99d8',
 '807404aa649b603a973e',
 '8075517bb422add9f994',
 '8075ddc355d63fc960d5',
 '8079e0d3175ae223081f',
 '80836bf4b3b82639581d',
 '8084b30048b55dc741fe',
 '808843e319b3e93d700c',
 '8089b46fecf3acb84081',
 '808e94bf7e70d0f29ad4',
 '808e94ffbf3eb84c542c',
 '8091796e566109bca4e7',
 '8097060638645df8d41d',
 '809a9a41363a48e8e649',
 '809ab236b8a15cec8ed4',
 '809eb3f8fa97c7742098',
 '809fa4dd04ad74d93508',
 '80a8c1d729259ba60670',
 '80a957476336509a4ede',
 '80ab1fe068bad9ea85e4',
 '80ab4640dee74e4c0d93',
 '80ab4670206bfaa0269a',
 '80ac4c712e2d7f2f427f',
 '80afc726898a53c2094c',
 '80b0376809fd12522a4c',
 '80b098e8a41af8b669b9',
 '80b0d364746d9498665e',
 '80b1bccf0812b71adebe',
 '80b35af274d70ea7b43f',
 '80b91129d9f0b04d5a69',
 '80b9cdf58ebd024f299f',
 '80baaf694a4106e9e1c6',
 '80bb7e01dbc46876ec4c',
 '80bdde12ac9218fec8d9',
 '80bdf4b6631b651f143f',
 '80bf47ca2ddc4a8c2086',
 '80c2063f48d03db97253',
 '80c2c11ae38b138aba76',
 '80c4eb7e8c149555701f',
 '80c578a1ff5861074c3a',
 '80c93da76bc973295ba8',
 '80d0a987facb622dc046',
 '80d1f81d75fc1cef3343',
 '80d2ad32d441dd65696a',
 '80d3977e8da9de0ab0ed',
 '80d7ed56f76ab5c3f789',
 '80d97dfa11380379b4e6',
 '80daafc8f2a0abc0ab0b',
 '80dd0f35d561c9d3768e',
 '80e5abe29c9e0d6ea324',
 '80ea0639627a15abc7fb',
 '80ea5574624d4daf1158',
 '80ebfa53b057d75acab6',
 '80ee3ee65772a5f100fa',
 '80efdf698dda4225567a',
 '80f22a96377e1b5e8ab6',
 '80f34b78d96483bff9ab',
 '80fada6078c4d561f3e3',
 '80fd4dbc95ef92e38418',
 '80ff84382c8288127fca',
 '8102894ef44601c3dd55',
 '810441499d5614e3d41f',
 '8109e4210587f620fcfd',
 '810cee88428be72ffdff',
 '810cffe08e93c2e5fe36',
 '810e1a09f1c5880feda5',
 '810eb13a5fc5dba10930',
 '8117e3cf59d9d78137e8',
 '81182be1e315bd3453d0',
 '8118317dcc960b4e5c25',
 '8118e83547dbade82c84',
 '811c1e105d5de8ae4937',
 '812447491c02ebb605e1',
 '8126bb8d1622cb28315c',
 '8128499fe842bc17b52f',
 '8129c70d1be0a1f57e77',
 '812ae3f7d513bdc5f0ea',
 '812bd1a3897417236a5d',
 '812be7e245cafbec2d09',
 '812c22c8280cde222ad1',
 '812d4e60911e227b462c',
 '812e541f378a5ef1c8b6',
 '812e63d145abbd426a15',
 '813424289d562cd02fa7',
 '8134bad0ec5183dbdc13',
 '8137e8cd2caa1c80e7e8',
 '8139a102891f00494b15',
 '8139a3fb63fabde60205',
 '813a11e0bf0a16b3cf4f',
 '813b5c989ec83942a081',
 '813bd7ed7bd2e991bbf2',
 '8146fcdbdd9f9c897800',
 '8148ce279bba7f7bc996',
 '81498fc5ba7458b88cbb',
 '81534f6dfcc71e389035']

# %% [markdown]
# 13

# %%
qids_13=['81539b292a30cd8ff2fa',
 '8154f6b2710661a16be3',
 '8157add288fef7546ddf',
 '81587a7b5c30bdaa2e3a',
 '8158863a238a19914051',
 '815b00ed934c3540fcef',
 '8167f6ec7f4cdf0a905b',
 '81702912e88c922dbf2e',
 '817201cc26d11c226e8f',
 '81723e70f267af9b7f8c',
 '8173ca5260e28f50a6ce',
 '8177b3b1c0dbfe99f4f1',
 '8178aa1baa91c10883d3',
 '8181556a1b5c7f3b985a',
 '8183e5dad28c8238f4f4',
 '818403429da16fa60964',
 '8186f36f4bbfeac4dc8e',
 '81882690c5bcb65dfca3',
 '81899d350e1e8bc9d3ff',
 '818babab9654bd5d593d',
 '818c14fbb1e27d285e65',
 '818ee18131545f935d3a',
 '8197934420dd29fa1a89',
 '8197ce3f0740cd7496a3',
 '8198b0a004429e8745d0',
 '819977b645a9969f5ef8',
 '819dd4a9b4fa41522a77',
 '819ee2f630365750a36e',
 '819f269eb291ff82de57',
 '81a7cb198f1a4a60b058',
 '81a8ce3ca6f631268166',
 '81ab3b18890f00684607',
 '81ab8949acadd29d5944',
 '81acc2c17be203fd9d97',
 '81b0412eef57da9454e4',
 '81b995c5400b2d2c9c53',
 '81bc5403f1066a8c63e4',
 '81bf279f75f921da5ba0',
 '81c02ad673d2ac4cced3',
 '81c0af26fe482c6febd9',
 '81cc7e771b3523c43e1a',
 '81cd76a5ebd7b552ca2c',
 '81d0bc2f3b0b2491b341',
 '81d2cebc437c324e237e',
 '81d442d7bfc0f394f1f9',
 '81d6e248d48c9d363c6f',
 '81d7b8c63c0f0bd5ea70',
 '81dc54716e2ba58a4fba',
 '81de7ec93c07d15c7190',
 '81e1a3d8bf69305190ea',
 '81e3b39136143bc8fbd5',
 '81e6066224aa99712e7b',
 '81eaf275042848abd3d0',
 '81eb57e6eb29a1e2fdc8',
 '81ecffd22c060ef85256',
 '81eeb49f829aa2ac4e0a',
 '81f41b072687311636eb',
 '81f94e41f8c841b155c5',
 '81f9bd5446038218f4c5',
 '81ff26b9bdc92b6b5f4e',
 '820094099b9645674c3a',
 '8202f61adb91ae0695d5',
 '8204a6f1152559f1abc5',
 '820c341872877b6fe1cb',
 '8213666f7cd8fb915789',
 '82184f0ef1f34f0bd7e6',
 '82195dc91850da07a0a5',
 '821b65c8219e2d0d8847',
 '821f265be91b917374b6',
 '821f73e6cc508b427d41',
 '8221206f8a72f017a405',
 '822158f5ae3d9cf6d993',
 '8222c06a8dd7161a8b11',
 '8222ddd455ecd794a8a3',
 '8226ec2bf7a2053d32eb',
 '822ca58c2e7dbc36696f',
 '822ff75138d82ab805fb',
 '8234bafebdebd1128856',
 '82350e3f03bfbb16d244',
 '823545a7fdf5666b048d',
 '823e55e5122faf539e85',
 '823f9ab581a42d9f656d',
 '8240c1ff03fcef341173',
 '8241e0a74a25f8d37630',
 '82420325ff27641bc95a',
 '8242caa3f59618b2e171',
 '824464906bb3b4b6a9a0',
 '82530f3c354612be7940',
 '8255381d1584711c7dc3',
 '825602978b6b8575c666',
 '8256899b79b8f004ed38',
 '8257f2a86637a1bf1900',
 '8259ffe38f67706eb5dd',
 '825d8faca04d578bdc91',
 '825f1a45aad1325d6f22',
 '826000cbc611c5c57994',
 '8260c05d5e0858269ed1',
 '826472424e2a99fc374e',
 '826b78b7af94adc8023e',
 '826d8a7dde1ff5732f06',
 '826dc62609244577b630',
 '826f7ec8c570c49d27be',
 '82733bbc1072e30b260e',
 '827a8a2ef36366106cd9',
 '827b7e2c7f082d3eeeb5',
 '827b9c4a807aed62aaac',
 '827ce4d61ccfd4261abb',
 '827d127eef10b5d40a8c',
 '827ec2ae52dca9090adb',
 '827fc146386133267dcb',
 '82823bd757767002b4cd',
 '82877edcb16b3abb6547',
 '8294145c3a86bf929753',
 '829471f8e789fcbe6f74',
 '8294a754a05cb418a291',
 '829503d78f136bc95f58',
 '829703d1429890658164',
 '829a233bdedcd0fdf7c9',
 '829e34abf5e4d4f3f488',
 '82a0c2cecbef5099ab7a',
 '82a39c6d7c022e54cc3f',
 '82a5fb45a440234d5e58',
 '82a73124a73f26185433',
 '82a7d315d59a8124a02f',
 '82ac888257f8d946dee5',
 '82ad58dab19a7469620d',
 '82ad5f5ddb3a7b19984a',
 '82b0314ec9cef549575b',
 '82b89fabda61cc1bc101',
 '82bb94a6432db9d4a907',
 '82c1d679fa8b4a3778a4',
 '82c36f3ada842ec04707',
 '82c5f9888d11e0d0a593',
 '82c699d969988f9095d1',
 '82d02f4dccd0a46f3f66',
 '82da37f1ce40f032dbe2',
 '82e01c75e6ee2157d255',
 '82e15444096a1d6184b4',
 '82e77e4f3137b8c16be8',
 '82ec3f02d612ae080119',
 '82eefd36497faa18fa0c',
 '82eff454f00e8ca2f6b2',
 '82f3d79d3d845ec74151',
 '82f4817f9356539bce90',
 '82f8d8ee48e0bd74090d',
 '82fa424ecee159a0f67c',
 '82fd5ac2039286eb9588',
 '82fdafbbc6838fde92b7',
 '82fff0cd1e12399b1d25',
 '83017149ec15dd4bd6e7',
 '83037f5b346a6ab07748',
 '83048f07bb3c5957b9b4',
 '830630a8bcd9b8e3e702',
 '8306679b1b22bc5b4eb3',
 '8306d67675504cc1f8c1',
 '830c08f10bc0609bce7c',
 '830ecf3b480e5fd3c850',
 '830f5020361f54a2002c',
 '83105b45dd7815f7938c',
 '831267b425bdfb71fd2c',
 '83133db1600b5a5bcca5',
 '83160a550ab140d8829e',
 '8317cc5cf09ad581281e',
 '8323f2e692a4a3f436b8',
 '832a9fea362fbc4265e4',
 '832e654e25e0f63ce76a',
 '8332448d8d9798dad79e',
 '8333514fed9d1e06274b',
 '833521f14e148d514ed6',
 '83389fd672cd24a49b0a',
 '833a1fa3ed23853df839',
 '83402264178d440aee77',
 '83455b0f215fe7cb0df2',
 '83457dd923778b2c448b',
 '834aa7be5282765cbd26',
 '83517c31b4d32e4ef630',
 '835624f2cf7e3da44c95',
 '83583f7c2ab385c55c67',
 '835bcea1c114e89e1fce',
 '835d2773c33f9de43004',
 '83604f3aed1156927cd2',
 '8362f59334d2dc0c858b',
 '83659a39065c270421a7',
 '8366839708cc04465dfe',
 '8366e44aed31cf5f4e4b',
 '836e37ae68d9713db9a8',
 '8372aa8b6145a4df699e',
 '837622264b741b43af14',
 '83792f5d55cd1ea5f243',
 '8379988f31d88642f4e6',
 '837ab6efc09e77c3ddb8',
 '837e25039451e960e862',
 '8381b6c2dabe85fd1413',
 '8383a23f5a309239c7d3',
 '8386006a2f743b385326',
 '8387e8bb33c3a7c37aae',
 '8389662a49ad188b1fc4',
 '838bbb3514ddc9ceae8c',
 '838d0196a71cd2c17f42',
 '838e3e8a9a2a3a9e34d6',
 '838fe5517fae827ee416',
 '839540c22ad4f9d7c092',
 '8396f63880d9f2f20982',
 '83976ba1ddb22857a2a4',
 '839a3470fe47529e6203',
 '839a80381a9a82b5d9f5',
 '839f1d3bd4deb177f0b0',
 '83a30a8da78bff92b48d',
 '83a576269d306ea24f74',
 '83a710edcc1dc054ccce',
 '83a7c4c18cfc684ed3dc',
 '83aa00786e6fba7802fa',
 '83b4192972070c583602',
 '83b6770757c0eeb48b81',
 '83b7c0fd9f42bf716f14',
 '83b80397f1c0702ff89c',
 '83b90463a7e3d131c896',
 '83bab15ef65c36eeeb4e',
 '83bb1a4ce240128e8bc7',
 '83bd0ae1423330dbf396',
 '83bf93691999298903b4',
 '83c02e345eb2f0031d86',
 '83c0b5236475e2ea433f',
 '83c19b5650b0935f829e',
 '83c31a64eec74a5d85dc',
 '83c5515680397bb254fb',
 '83cd336f5740733995f0',
 '83cfdabab99273ce9f40',
 '83d27e46a0e8d308dff7',
 '83d4594e803ff368922b',
 '83d5dcd6a524f08fc712',
 '83df1cf7df6cdf75335b',
 '83e05e97b3c508f3f2b9',
 '83e1b2840cda16adbeb9',
 '83e35330ec3f6eb8a655',
 '83e39bc17d16df553aa4',
 '83e6685058a6cd2647d4',
 '83e76f2629d62f541819',
 '83e8132455675a7b0e58',
 '83e898f7d483f1f973eb',
 '83eb5fa9a97e37509382',
 '83ee5f9e90aa36392de0',
 '83f295b6c764f38f24ac',
 '83f4a01596935aacef32',
 '83f7a40a41e67541da74',
 '83f7e78d57a6c05e6543',
 '83f8580f28896edd761a',
 '83f8d9412846c43481d1',
 '83fa13aee1c4e4cd9afd',
 '83faaa5ce293b57f7cdf',
 '83fb4d737eb55f5819af',
 '83fb5731db8d9b2c46c3',
 '83fc3cb92f2611c966d4',
 '840404fbee707e93307a',
 '8404486b1d540726c403',
 '8406377781e3e11651fd',
 '84083f68db35a46699b8',
 '8409e1d514d5ada47b4c',
 '840a4633c4c2509e4b0b',
 '84156d6bd1ee9a02c7cd',
 '8416acdb71828db67b5a',
 '841711d613f08d284a68',
 '84174bb63886dbaad4bc',
 '841814bca14907fb215a',
 '841842cbeda31f848ce8',
 '8418665598558a03a996',
 '841b0d09bf5d7b9cd3ac',
 '841c2cbb2b6a649bada7',
 '841cca7ebad82fe21ac9',
 '841e7eacb7dda8da5274',
 '841ef0912137342bef01',
 '842053354e805a92e072',
 '84220b7db6d6a3b237cc',
 '842274ebc5b21fa7f33b',
 '8425019720590521f851',
 '842981df0b3346d24d7f',
 '842fc79876c8bb9372cf',
 '843060429b77a4c37c71',
 '84339ce048ea194ddccd',
 '84384b9c5c8ad31f2f2a',
 '843aeee4b96a90dd312d',
 '843cec443c84aa6e3bd9',
 '84405475f9e7298d93ca',
 '8440bc9ae30167292957',
 '8441c2c9f20018e00c24',
 '8441d748df319731d7f0',
 '844518a6adacd0fde055',
 '844d1c869ad4610910a2',
 '84531af05e82f105b7ee',
 '845a531dd575e6923a35',
 '845de8b40dcdf191cc01',
 '846a954b1199b05d16c0',
 '846b59b30b35bbc9d50c',
 '846b8da5ab454a96ada2',
 '846ecae4fec0b9d0efcf',
 '846eee7bbcebd265dfdd',
 '846f0d42184030e1730c',
 '8474758e5fe45f8efd63',
 '84796f55fd98e1db637a',
 '8480aaebe36dd1743cee',
 '8484ae77b4c351bbcb63',
 '8486b1f657fe8e43f8ed',
 '848d7831cefaff6db401',
 '848e0686868ff05c0e45',
 '848e743f124f8dfabc9b',
 '848fa38dd28119c274fd',
 '849902d3312ed2ed890d',
 '849af84aa32c6ab63f0b',
 '849cf054ef41d3d77a3c',
 '849f6c09aeccaf9317e1',
 '849f6c17f19677d1f559',
 '84aebee9a3c368c05889',
 '84b7ffd1a1a1eb8f9fed',
 '84b932798741d07f04e6',
 '84b97c6ae9c2998c006c',
 '84ba6d8d7722bac12cec',
 '84bb1f49a818e811925c',
 '84c015fd191eb7a1b6a6',
 '84c223bb89afdc23420b',
 '84c32195c90388f400f9',
 '84c811f4199cd434a743',
 '84cc531c226ca77d5f79',
 '84cca968ac87a86cd3ae',
 '84d3d5a544bd3ef44c39',
 '84d5cff08e039f7406d4',
 '84d88955494f5066d57b',
 '84dd1d5894e5682f4307',
 '84dd5599558a6ce2ca80',
 '84ddcff45f443c23c719',
 '84ddd7684da49af88080',
 '84e367216d1d24e6500b',
 '84e38343acca9a1a7429',
 '84eca7245a9e42ed40f4',
 '84f2d8ed38bc297f4521',
 '84f3f300d4810e320bb7',
 '84f463f6d15afe9be475',
 '84f659de8f11930969fe',
 '84f807eefd02c2266a5e',
 '84f9e6a9db44a0517f2a',
 '84fcbd9edec963680ab7',
 '8502022fc2e3480de61e',
 '85032b4e48ba48be6081',
 '85045464fc210fe2ee7c',
 '850c10cd3eb4e3d36b0f',
 '8510ee14b856016fd57d',
 '8517bf8eb477131c02b9',
 '851a2f9ba0a7cc5abb4a',
 '851c7770aba2f451809f',
 '851e513121c459667c42',
 '851f53e0d827ac115130',
 '852080eda8629d6bc26d',
 '852d95c5794bf9f89e91',
 '85318624b2558ada7ee0',
 '85343c9286568d844f43',
 '8535df1080d18fe8ed9d',
 '853a5e9ffe6777275fc7',
 '853a9e3788ff76e239d5',
 '854093cacdfba295d31f',
 '85419bef99b198393c96',
 '854207a109e2077660c6',
 '8543c58369ef5f981252',
 '8546c425e4d8d8f0903a',
 '8547def8ed3e8f3b02c0',
 '854dc9c131c54f42a0ad',
 '854e9c7186870e90fe49',
 '854ff6d84aafecd4f147',
 '8552c0dd93f74b211638',
 '85562337cff5a97925cd',
 '8558f828cb913d0737a8',
 '8559445b07b4be93da4e',
 '855c127569dfa27b8676',
 '855d0ab5ff5553afa6fa',
 '855e5723d4759374a7eb',
 '85618396a3bed54056ab',
 '8561f6a6c86e7d3e82c4',
 '85655d80e06d63ec3880',
 '8567073254c922615f32',
 '8567eae27d4791b89ea3',
 '856a2c8d26b75af9a854',
 '856b3136563b9981d38d',
 '856c141abd0bc03a1ed9',
 '856cb1769bdb646edc0b',
 '856f22b3f35e70e1ccf9',
 '856f7736f8c3ad04fc84',
 '85703771fd3683cd27c2',
 '85705396029e8e3f07f5',
 '85711c46e2eaeee13d13',
 '8571c031fb8026eb652a',
 '85734e03fed86fe6bc81',
 '85741b4349ab9db0f9be',
 '8574f97e8bececfda8f5',
 '85758968ff29f458c10d',
 '85792da84877b4b75c63',
 '8579907a23ab1b034ce9',
 '857a8ed725066d679964',
 '857c0581a30e0617bd04',
 '857d2d1fe85271d918c0',
 '857e7c864753ef3ae06d',
 '857f8dd9fa64ea034411',
 '85835b305805678cffe9',
 '8589ae43c923b4233ba5',
 '858b0cbf0128f21b28f4',
 '858b887042c398f26fcb',
 '858c1d0d811d78596dba',
 '858e24a438f2ea576eb3',
 '858ea0b3075151948b02',
 '8594172fd77d5a315669',
 '85970cec6eaba9df9fd9',
 '859927c7690c2b3e6a30',
 '859a673b237088cda2ed',
 '859c003574b2eb04c1d8',
 '859cd22e66aaaab7a873',
 '859e27b28f42ea512ae5',
 '85a1467f1055067f5071',
 '85add9d97a7109a66333',
 '85ade44956336975bd71',
 '85b641f9cb24233c4260',
 '85bac01b1ed9f8a8249e',
 '85bb2ecb7f655a8fc81a',
 '85c12ff7d9272656d84e',
 '85c36468257dee6f8344',
 '85c3eeb9114c82e5bf2d',
 '85c471ccd1070397095d',
 '85c59d4aa7e8e4e45e43',
 '85c8181f350a402a4952',
 '85c9c487d2442ed06fb1',
 '85d0ed499055cfa1ebcb',
 '85d12bbf38d3a5b97880',
 '85d1e8d183c542ab649c',
 '85d30ba21c05bde9c2f1',
 '85d3d5f2c225ab4ba4c3',
 '85dc6165c932d2312466',
 '85ea773e647739ee8182',
 '85ee6527d4fd66617f6b',
 '85f29d79c962310b2ef5',
 '85f40e05c49d91b1f0ce',
 '85fcf52f022b15944bf5',
 '86048e2e58f2951e96f5',
 '86060a97fd35eab53650',
 '86081ad157d7f654c387',
 '86088c52d4941813e302',
 '860b4c5a8a989038af00',
 '860c92de870cd401071f',
 '8613a028889e547762cf',
 '8613d72f4623d1c270d0',
 '861ad5a2ba83f8c7fd62',
 '86254fd19083252a5a11',
 '8627e3fb50635912f852',
 '862b885800a0400e0a54',
 '862cd81cc1a3461c84f1',
 '8630672c2229a04fdce6',
 '8632d4e435a9a6a2af4b',
 '86331b92ad9a4a983cb8',
 '86353bf45583a471e0b8',
 '86376ac0dc64368807f1',
 '86382358f79684fe3e62',
 '863b38adcf587aac1f5d',
 '863f75da3f3e83449811',
 '86433e0e5c5d9ee7ba7e',
 '8645507b4be2a8fe9004',
 '8645d1725d46adb22c00',
 '864c1577ceefdc144ec6',
 '864ef3f586d6e3d865f3',
 '865999ededba18194f2b',
 '8661df5086339ba9f189',
 '8669b9a7239aa1245ebf',
 '866ccb097cbe5c4f300a',
 '866fd0b7744c1e723963',
 '8671b2e620e1fe505007',
 '8671c126a8dc0d203259',
 '8674da2c119123634de0',
 '8675027970a6d04310d5',
 '867685894bf8635ca91c',
 '867cbfe3d5e27b8e7c92',
 '868288ce82aab61713a1',
 '868cf52d76891ecfc8ba',
 '868d7ed92ad4731cd905',
 '8690251bc8e86ce2afbf',
 '86917ab632ae36ea7bca',
 '86944f05a82950f13c35',
 '869633aa0d295b6c3d3e',
 '869a4a9fe68b865b7a55',
 '86a3a42f1bbaf6874f55',
 '86a484cbe9410f7c1055',
 '86a55373a75bc651c915',
 '86a59b8d61d7925e6259',
 '86a5ab4e6c514dd2feb5',
 '86a70cc16354a2e4f410',
 '86a8aa904254b953e558',
 '86ab0cd4c19ad8898a24',
 '86acbd22180dba69094b',
 '86b3b8db088f3c902b14',
 '86b4716b831f35f324e5',
 '86b5798817190ef62bdb',
 '86b6dca89fa35c57541f',
 '86b73bc4bebdfe056cc3',
 '86bafd674c2efb9dcc64',
 '86c148e4711742d192c8',
 '86c422782abeadc433ff',
 '86c508b76d499feb63fe',
 '86c5dfbabf258b81c881',
 '86c6b1d285c7a966a17a',
 '86c81dd7a9c9bbda0373',
 '86d0afe68dfb67d679e7',
 '86d31839c98abf91e072',
 '86d742d03c17c8d3b916',
 '86dca1a53e72bded0568',
 '86dd3b330858cdb7980b',
 '86ddd25ee8eacbcd5705',
 '86df4cd46016fb238dc0',
 '86e04f3f20d65b6f1466',
 '86e0e888cbbb036d5617',
 '86e12e4b945c9e1860a7',
 '86e2bc576819a321c376',
 '86ea7c22f4478e39a14a',
 '86ede10a0f7bb0b97bc6',
 '86f168e5b6e8777fa28f',
 '86f7f7fddf540a94ec37',
 '86f9c569c81bebb6a2ef',
 '86fc27e32ee0f7932c81',
 '86fc966f74bcfa22adbf',
 '8701f4d5b58211e29df4',
 '8702366b4af1ce854cae',
 '870db3ac51f32bcc95b4',
 '870e22b8b8fb9a6e3733',
 '8716623bc4d30aeff192',
 '871749a8fbcfa5869251',
 '87187fe8b8e13330bbf1',
 '871afc117daebb263917',
 '871b2852c13ff1b20a9b',
 '871f06712c5e29c9b099',
 '871fd1210d3dd4366cd3',
 '8725598a31762b983c2c',
 '872785c27215f1bf7f92',
 '8728229aa852e7e52790',
 '8729a5cdbf2145e1722e',
 '872dc9264ed37bf70f0c',
 '872e35326c9786cc6a92',
 '872f10eaadf52b7dc19e',
 '872fc2e656af97459f3e',
 '873194aec0ef676d1425',
 '87349781c8f180a146fa',
 '87359d6295823ef203ab',
 '87361e98ec1c02d424e8',
 '873975659b5cd9fc967f',
 '873a50a69ffe2b58f550',
 '873f728d75e5db9b9b68',
 '8744c8f581a6c369a6d9',
 '8749b2bdeb42418aabc2',
 '874ad421b39eaa045739',
 '874aefeac6bbf4619554',
 '874ea55157f34c04f2a1',
 '874f0e5ed0d0bf6a6673',
 '87547138e40bf9363582',
 '8755d393bd7ca24d1c69',
 '8756331a2bd657120e02',
 '875683353c75db3fd2f8',
 '87579f7956f751570ea9',
 '8757eb7c217f427fe4ae',
 '87601d64a4ed5243e0b4',
 '876400d5c35c93548614',
 '87686c4a6d32ea38bf4a',
 '87689317f69e1e0e7a6c',
 '8773281ce1e6a5231c05',
 '8779677315b06d9480b0',
 '877a66573c92e780afbd',
 '878078a7db36fcd4fce8',
 '8780c950e0ef2d2db6c7',
 '8784750c54d07a2d6ea3',
 '8786220125d244563d1f',
 '87868f9814aaaf9fc5db',
 '8787eb2b35d44e77a5c4',
 '8788a93676f2a7d75585',
 '8791b6f33cba5e24589b',
 '8791d0ed0ca3ad12c947',
 '8791f13fca6dc1dd38e2',
 '87959793fe381bd441a4',
 '8798736fb4644ac81cc0',
 '879d5afd9574ccd04595',
 '879dba5e42bed4b9cdaa',
 '879e274d5cfee5c2e691',
 '879f729c5690e940bcd3',
 '87a31b6854ca5944f500',
 '87a3c1fa56eb2d0d6df7',
 '87a821581179826606f7',
 '87a9082a21b0bff1497a',
 '87aaf98eb517eda08d62',
 '87ab7b0a08eb93669976',
 '87b053ca177564684571',
 '87b0e05145677fbdf155',
 '87b121599e172b544fa4',
 '87b4ec6cf3e63799d68a',
 '87ba234c651aa0a4c1a3',
 '87babe159407e50f9dd7',
 '87bdb8585d6d3ff370e1',
 '87c167585d545f00d1f5',
 '87c2664c7e4993b8db02',
 '87c39cbe5a484563f7f3',
 '87c3e956cd5ce1763b6e',
 '87c442f53e29f37bb329',
 '87c691e33945512faa71',
 '87c9f21380c84787b129',
 '87cb318a8c87c58482d0',
 '87cb90042a7d325dfbec',
 '87cd75a6fa7123f69557',
 '87d57ea5dd07c2fce5e9',
 '87d86e1269127f32e3d4',
 '87daa22391ecb633e6d5',
 '87de081418d9eee47094',
 '87e2de5b8dd5bbb757a2',
 '87e2ef61be90b75c505a',
 '87e86b453132b92214fd',
 '87e9338c47e44980323a',
 '87ea3d5129c24560220c',
 '87ebaf722de5b41b0973',
 '87f2117c44ddee4697f2',
 '87f2cb888045c1dbf2e2',
 '87f421bfc3977e1a824e',
 '87fad11badb106dd7bab',
 '87fd7c9230442306e1bf',
 '87fe2dfa9f238f518847',
 '88025704d73ab8871862',
 '8806018d3a3563fa09af',
 '8807026abf3e9cfdbcb3',
 '8808963dd86181bcbead',
 '880a742121d9547bbaa3',
 '880aac3fe3df9d43f356',
 '880dd4902858df87edc2',
 '88129a22382361128ef9',
 '881655c89d45e30cbeb6',
 '881734882893ed08b03b',
 '881b0e1796ba86f614a8',
 '881d773518c83f76f874',
 '88216e205678ef76cdab',
 '8821d14502e9ac8bd761',
 '882296b922a40c242d14',
 '8825667bfa13726b4c1d',
 '8825e3c9e58e8ac6c58d',
 '882624ba05038afbd50d',
 '8828e50beb7b7f107f42',
 '882e769c692461e33b0a',
 '882f71577d2c75de90f4',
 '883007fd4a3716b2906a',
 '88303dedf0c20ca8ec19',
 '883112a105215304226b',
 '8835fb0891d868dafa54',
 '88368f35792ab9aad1dc',
 '883889a9d85f06598138',
 '883c6118d3dd13e953db',
 '8847c0ea08756925efb4',
 '884d863129b58e10f250',
 '884e7fb6ed2679ea540f',
 '88527620ba9a6670c765',
 '88558a6d8b258490845e',
 '8859b61cc80caffb7858',
 '885cb5d573f3d6f9b579',
 '885e94bfecefb1431fa6',
 '885faf874a0b32ac6dc7',
 '88631bebcf236d0214e3',
 '886d04afb1a346cf5592',
 '886d318b3ee06543a33c',
 '88707c2ff9d3c7b6be80',
 '8871c42bafc9d4075239',
 '8873c7625183359dda0d',
 '88764f09f935a9b7d873',
 '887a38e74404397a1dbd',
 '887b291d39eb6a7528d6',
 '887e2f2dcdb0d432de5a',
 '887ff2a3c8cf28d5d893',
 '8881d12b13dc08dac593',
 '88831c8b589e1c25527f',
 '8883a7e59903c359725c',
 '888cde1170a7b34737bf',
 '888d184295ab4bfd848f',
 '888e6e4a0a054cf98bc5',
 '8890152f31da84c86a2b',
 '88919f18a62cba9d55df',
 '8892a673f0aee37e6b9a',
 '8897fb6f160d0c68d3c6',
 '889a9ab25b15bded6c06',
 '889d7f986bcd89914926',
 '88a9a98bad695e0a5959',
 '88aa694b4b0f7b689faa',
 '88ab145a99e4a57d3ac2',
 '88ad3b0ca8e4535301b7',
 '88ae3120e084b74ec586',
 '88ae97d5f36b6261ef34',
 '88af222c955624d6c90c',
 '88b1f8c183766fd5e8d5',
 '88b34d22062b24e2af31',
 '88bae2812c7222dbd634',
 '88c11d24468a881d3167',
 '88c144eabbde04936461',
 '88c16ea086d445e59bd0',
 '88c50f6567783bebcbeb',
 '88c5cc47acb352877746',
 '88c6cd696673ab3f60d1',
 '88c706fa15bd254e79e0',
 '88cc0b9597ffdc57d5d2',
 '88cdd2b1c81eee0e5ace',
 '88d2ecdb3dc8a3cef241',
 '88d7080ab79d94a3bd8f',
 '88da33538bee0ac37f56',
 '88deea4d0cfbfe71d7fc',
 '88defd22bc24fe628860',
 '88e10af59b0ada51f5f0',
 '88e196d3ac253777d5f4',
 '88e2198e4d761df725af',
 '88e481136ec75a6b6f8b',
 '88e5e459786e843577da',
 '88e6a204e70b9cc9eec4',
 '88e6a5cbfce4d76594a8',
 '88ea48a04e2cbe1737b7',
 '88eaa662c7762b1fec31',
 '88eade198da31eb67ee1',
 '88eb4bc5815c913b62ef',
 '88ecf93cbb4fa590528f',
 '88f00caf2156d2dc455c',
 '88f09dbabd2bf4e11279',
 '88f4a8abe4d7d1a3f7cf',
 '88f9b3222de2658dded1',
 '88faf60cb4a0113eab76',
 '88fc7b0433fb416d17cc',
 '89009d74ae9302aaa483',
 '8900e5b1455bb165f5da',
 '890337ec1cc065b2e493',
 '89064d6ebd38682f3eca',
 '890802abd618c14b79b3',
 '89086e61c5a31e8d7daa',
 '890bf5a3a2c546375def',
 '890c7b1f30087b26563e',
 '890c96d31840c8c5bfb5',
 '89101a816988e170ec18',
 '89106dc42d471cce5341',
 '8912f326185812837d94',
 '8916345054a57bc76395',
 '891cf098b26152b04d2a',
 '891f096594516f7d9a75',
 '891f43f60b837fac87bb',
 '892126e4160efb36ea25',
 '89226760265138ff19fc',
 '8924cfc1323fd8da20fe',
 '892722942eccd12b968e',
 '89276b5b0736930dddf5',
 '892ee208813b61a265f7',
 '892f50ea00a0382ecc9d',
 '892fcc1ac8edf92e861b',
 '8938cb3b2c4c233cfef4',
 '89424437b1273c3a2015',
 '8943c593cdfe4ed8d697',
 '894e27edeae986215909',
 '8950f03c4cf735e3fa78',
 '8958032e0c47432ab16a',
 '8958079e937f9cd7e13f',
 '895e5837408e3a73cbac',
 '895f573ee49bb0a29d13',
 '895fa695b66271233632',
 '896291e81e1cd3b8f687',
 '8963a2fc1d806ef1b558',
 '896690c415fd4301e7b8',
 '8968abb079d164e7f7ff',
 '896be5265ecbd90809e6',
 '896cd8923ce683f63d29',
 '896d1a6693f32e7d1ed7',
 '896e5470532352773173',
 '896f1c268ad1169bb83f',
 '897c5ea26a943c93a6fc',
 '898186659fef9b502311',
 '89863957113de81414bd',
 '8988454f1203113d26a8',
 '89885cd7040d28794f69',
 '898b44e00640dab5791c',
 '898b9b985e9d247ca7cf',
 '89904a797b37cd3376f2',
 '899096e8eb57dd46879d',
 '8992c0f0f938b693bf64',
 '8999468eac4762024f34',
 '89a3830d77dc9e05740c',
 '89a582fc35f907cf8526',
 '89a69f02772103c60f5b',
 '89a82c398047a40937ac',
 '89a88da4cedc34827f65',
 '89aaa754edd2cbab224f',
 '89ad742ee605ff79eb33',
 '89b38ba8e239f1f7ab81',
 '89bd79869811cbd25c7d',
 '89bffbab907ca7c29978',
 '89c1d77953806f670b0c',
 '89c49719644f951e655d',
 '89cc395617f18180a98b',
 '89ceaf0a18afeb4fe99b',
 '89d960c2836acfafc0bf',
 '89ea200641d9eeadea72',
 '89eac6e6c8c158246964',
 '89ec94e32bd05cd9b7c2',
 '89ef22cd862500498179',
 '89f1c631426ce325cd22',
 '89f610646b884d6aa3af',
 '89f670f404e15c3e1fb3',
 '89f910092bf0c9738446',
 '89f9edf354fb386fce6f',
 '89fa6f4f96baa6384839',
 '89fc4ee05066989c8c9a',
 '89ffd82ad5b58d5705b6',
 '8a0d89a0ca5fdf9e9fdb',
 '8a0e705a3d5edb47ea65',
 '8a10109f69f9555d6898',
 '8a1c27509b74d48e338c',
 '8a2604785c4bba9e96f8',
 '8a26f5ba59cdf99b2290',
 '8a318bec4ba05d2a28e8',
 '8a31f0b91e3bf9ac83da',
 '8a34db74b4fafe418b9d',
 '8a37c896521b8c2e5fee',
 '8a3f7dc2330717a37d25',
 '8a4577a39b0748646341',
 '8a45c3db39c803c14963',
 '8a46caa5c68e07d64fc4',
 '8a49cb2cf5c8ecf96e3b',
 '8a4ebab229ffb9477607',
 '8a4fc3540475b0c55952',
 '8a555253111dbab3ea7e',
 '8a5c0b6611fa53f84fce',
 '8a6386ea3374fd89e214',
 '8a67cb057d67dcfbd058',
 '8a6961e115e813739c73',
 '8a6c6b0af3efa53852a6',
 '8a6cb77cd5c5a591d083',
 '8a6f2bef485c8a5643d6',
 '8a7094168a31b2750bcb',
 '8a70f90ff619bb8e4d45',
 '8a72242696382c52a5a3',
 '8a73af7c49e89f40fbf1',
 '8a75a4f7a004fd3757a7',
 '8a76bc89bb39751652d6',
 '8a7a23d10dbb7d6325db',
 '8a805952ef63db7bf8db',
 '8a814909d12cfb2c7334',
 '8a820e375dbd15dcdf0c',
 '8a83e2575c2144781616',
 '8a85ba4ad15648489070',
 '8a85c756c2a516c396b9',
 '8a8d3b043fee1df56a97',
 '8a8d48b0a74851e154fb',
 '8a92e4729e41958fc922',
 '8a99f7eb9ad4f66edb59',
 '8a9cd9096923a215c486',
 '8a9f217d1e3575c09b98',
 '8aa176e9c5e6ce3e4fad',
 '8aaa0abf87698a5e07be',
 '8aab31f5ae0d431d26cf',
 '8aade06dee2dd056c53f',
 '8ab102578e9c2eb7d35f',
 '8ab21da720e15ba1e5fc',
 '8ab36ececd882b634a62',
 '8ab4b345dc1224bd305d',
 '8ab6320615121e6902cc',
 '8ab818509b113f9a207a',
 '8ab82b40c924405dc649',
 '8abf9b911b53d861a1cf',
 '8abfcc152264821b49bc',
 '8ac29eb70bc2852cc48d',
 '8ac322f79a953a395d8e',
 '8ac57e384adc5c27db36',
 '8ac64a49d709ae7f920a',
 '8aca542f98367b5c23b4',
 '8ace57f0fef85c9aceaf',
 '8acf3679344fac7fe0ee',
 '8ad107d51f7030de29b7',
 '8ad19a68ed0a85458d8b',
 '8ad25915020666191b33',
 '8ad3463bf7274898c251',
 '8ad552f40f9554dd9db9',
 '8ad7996f8e637b7d44df',
 '8ad86ee0918e30e9f09b',
 '8adcd7fc18ba8e1409bd',
 '8adee34f0bab8be3a83e',
 '8ae24fd95dd3c5b1e139',
 '8ae316ab4d1123f91d2a',
 '8ae6943a235ec43a3be7',
 '8ae6bc91c10ea9be37b7',
 '8aea14da5a1b39cd1bf5',
 '8aed000baa19c739a7b1',
 '8aee397327112ea1ad2c',
 '8aef8e59b1087b43aa5c',
 '8afa35027d712018ca06',
 '8afbca86791a3b0d8d38',
 '8b003ee65630a35cd944',
 '8b090f175aea53bb2c12',
 '8b09c5be80c043716333',
 '8b0eb427bc4434b4bbe0',
 '8b0f209e9ffb776b4644',
 '8b0f33ffe80735ae869f',
 '8b1646925c3ef2ccd2aa',
 '8b17aa4892822beee5b5',
 '8b1ae20221bc875f4441',
 '8b1b1b51b946a4ac39d5',
 '8b1c07bb7ae272dc901d',
 '8b20be3294747be76b09',
 '8b2416358a5f83ba422c',
 '8b25fee000a7079aa941',
 '8b2bb35705b815406a99',
 '8b2cf873582d6009866b',
 '8b2fa21c1cd91ba44d4d',
 '8b300e32b63ee2150130',
 '8b307b0dbc7a8e8c63e3',
 '8b309baaf0e8c2704eaf',
 '8b35463b5e173921688f',
 '8b381b6e838d6127415b',
 '8b383a7708528eb87959',
 '8b38533d59e00d848be2',
 '8b392e836e99c756a812',
 '8b3ad1da732444cd2a19',
 '8b3bd93b1e6e31e7f539',
 '8b3ec9fd6cd85da3706b',
 '8b3f57c1d03db96174f0',
 '8b497d9f2afeb426f8ab',
 '8b4b64536f43b4e80a64',
 '8b4c1237b8454b220c79',
 '8b4cafe5e5236f91134a',
 '8b4dc6fb3839092675e4',
 '8b536fb0983112abe57d',
 '8b53a5e98f0495046534',
 '8b55cf0fb0e7091b05dc',
 '8b56a1d8679f260fbb12',
 '8b58409f4d7347555822',
 '8b594503cf7ce8321250',
 '8b59a7238e4ac569de4c',
 '8b5a67fc158bbceb8fb5',
 '8b6437ceaa35cbca6a71',
 '8b6e41fb53fb6d50fd87',
 '8b7266b62197e5e57db5',
 '8b73b020f3c84813b5a6',
 '8b7c3dec3ef381f5f9a7',
 '8b829b8f634da5884f62',
 '8b8d5fa45a1c884440d6',
 '8b8da7ae57db3dcf3e3d',
 '8b9039ea4a814430abb6',
 '8b92b49738aa3c88c38d',
 '8b981f1b46d614c0091f',
 '8b9856a77f81bff715f6',
 '8ba3b57e58b18656d60d',
 '8ba4b4f21b3f7e4244ca',
 '8ba4c4d5c14d79b4a0fe',
 '8ba78261937f1cfa8318',
 '8ba87a87dddc89541613',
 '8ba8df6fcfa01d394e70',
 '8baebf131e25bc0d3fde',
 '8baee47701444be386df',
 '8bb36b9355d5569abb4e',
 '8bb3d213f203c872615f',
 '8bb673460d8ce0803172',
 '8bb7f4a62c3b6b35905c',
 '8bb85a48b90b040a0d4c',
 '8bbe33612a07c425d634',
 '8bbf134f8d4a6ca44e32',
 '8bc12e4a1109f817847e',
 '8bc3cd3fc1b7f8aab423',
 '8bc4fa649396ba276f37',
 '8bc702d36f6e4e6fb622',
 '8bcc16cfbdd6fb5d64b6',
 '8bd0169eefe2db0c664b',
 '8bddcf427b8ece2cec93',
 '8be0c7dee628c461c931',
 '8be5d0bb830dc318d1af',
 '8be9fd5e537239447992',
 '8bed8bb34662122cce62',
 '8bf15797e9d19d7d1580',
 '8c014546b81762552be6',
 '8c034af5e4ce0f9a5d20',
 '8c04732f8fa3f2e4af1b',
 '8c050df6e38da41f7ac7',
 '8c076061f35a63112a8e',
 '8c0b9e5321ab44ab876a',
 '8c0bed5d33eff2f9565c',
 '8c10ba4c1e361c64f953',
 '8c120acd853d307e1839',
 '8c1866d70acf5f128047',
 '8c1b6139eae947da4f43',
 '8c229941a7c7eb497eb1',
 '8c2317aa73f699d3557c',
 '8c236f5c76fb2935457d',
 '8c23f4d1c8dfd625419c',
 '8c24a2db74ac01906a8f',
 '8c24fb57765d0e24d891',
 '8c2610f0139f94789f59',
 '8c2699a9cc46ae7cc27d',
 '8c27c20f4bf9170a893e',
 '8c2a5c3efb8b02114c6e',
 '8c2e0321731a159dffbe',
 '8c37710bfcada628ec26',
 '8c3b8a3b728ad037ddca',
 '8c40077c50db9714cd77',
 '8c4055926724a892cfec',
 '8c42664c76a88b06b60a',
 '8c42ac61e6380d2c4089',
 '8c42fae5adc8e37866e5',
 '8c454d469257ae8f86d0',
 '8c47d6bd4722bad9f5fe',
 '8c4808238f42a564e0b7']

# %% [markdown]
# 14

# %%
qids_14=['8c4e54a01db37cd06270',
 '8c4f08f12be7d50f0db4',
 '8c5006c8a6a1ed7e975b',
 '8c555d838cc8a560dcf8',
 '8c56ae9f1cadcce5df0e',
 '8c578fe712ebd692c249',
 '8c5e5b3a3f50b0ff71bc',
 '8c5ea545d94e62600b47',
 '8c61c2576f76d53f2365',
 '8c6510cc54fca34f85a5',
 '8c68313251e2bfa2e65c',
 '8c6d7bbd65c3b484499d',
 '8c6f51130d7f322c396b',
 '8c72ffa6bb97e6276fb8',
 '8c752d251ebd7918686c',
 '8c764015d74798e737c6',
 '8c78a251754b78b5f2a4',
 '8c7caefcd5b4a9cc4625',
 '8c89782f41e7e4796e98',
 '8c8c37686a3c036cbd04',
 '8c8c677716c5ac6b72e5',
 '8c9241dcea2330218da9',
 '8c9430ebb97561204531',
 '8c94dd4029e9866a5705',
 '8c982ad16dcc82afc18e',
 '8c9bc02db705aaf4ada4',
 '8c9ef342c7925c15e480',
 '8c9fb690ba9f645e1464',
 '8ca3a0fff0acfeb51f04',
 '8ca405b894abe0764619',
 '8ca4ae8457dcf44df8e5',
 '8cadafb78cfe2db9080d',
 '8cb69f38108dd8f95981',
 '8cbaceec3a0d0c2ed2a1',
 '8cc070ea982b4cbd313e',
 '8cc16dc911217a6e5f84',
 '8cc47739861ee68a173b',
 '8cc49b4b716c4008c696',
 '8cc6faa4280f7556e2f8',
 '8cce9962fca128763cb8',
 '8cd10d9c61fb2bfb084d',
 '8cd21574e4eef3ab04bd',
 '8cd4969f93b29f89c9cb',
 '8cd67ddc1b0292824d93',
 '8cd680078dcdeecd64bb',
 '8cdb6787859ad5a79221',
 '8cddf3d3db97b74024fc',
 '8cdfbcdc61f00911e497',
 '8ce0081e73a499de9048',
 '8ce0b8cffcc0ef02e11f',
 '8ce491ec095fa13d407b',
 '8ce54a8a7877fb3b66a8',
 '8ce5d47e35994155e312',
 '8ce663f26a37fd00af54',
 '8ce73b6a5786b7507a50',
 '8ce8c5e7377dbd3eb6ca',
 '8ceab6fcb01a94d658b5',
 '8ceb2c86e1d28c8816d2',
 '8cec88358befccd2ad2e',
 '8cee35ac63f36d4e03d9',
 '8cee562c7b210de5edc2',
 '8cf732a9e6ed8a8fae8d',
 '8cf75b926b0b98f61e9b',
 '8cf83e465d4e75d68e7f',
 '8cfc79f73f3950eebf2d',
 '8cfd2299e508d1361c6c',
 '8cfd6a5183a16f7f37a2',
 '8cfe379f2d6c3bf15e16',
 '8cff18a50782db4775ab',
 '8d03d0c677dc5f037785',
 '8d03d4a06ffc7368a4bf',
 '8d051b9d9ec1a5e46ff9',
 '8d062a12a0b65d265f84',
 '8d09aa1aa675cc5ddd27',
 '8d0ced8f7fc1b18d4b7f',
 '8d13aee31e2c81821805',
 '8d1460ea9c71dd642b68',
 '8d157acbd54c53a3fa28',
 '8d16119dff80f3c67b15',
 '8d1af5e76ed6b83804e1',
 '8d202a84c711d88062ce',
 '8d2167b8361054043868',
 '8d220763a218489142cd',
 '8d22b62ed62e464e8eb2',
 '8d237676848d77ca6932',
 '8d2531993fa56423b0b1',
 '8d257755b7bf9f76cdf6',
 '8d29f4cbef5bb265a3c3',
 '8d2ae63aeb374a22ba66',
 '8d2b389065998544418c',
 '8d333cbba9b9627f2ca0',
 '8d37e17c550c703a5e04',
 '8d38165aed369b763c5a',
 '8d3ce8932710dee6eb6c',
 '8d41ec51a0e06448edfd',
 '8d49aa04376a2acf4515',
 '8d49f671c26c979c94ab',
 '8d4d806f2281e2515af7',
 '8d4e96e2348f020d4313',
 '8d52193aa0dced9e8526',
 '8d56b952615ff4df3bf6',
 '8d5910e8ff5bc2d0455e',
 '8d5915f61b065bd3020f',
 '8d5b21c746671f866c4a',
 '8d5cf740536273d46e71',
 '8d6351e7b45cfc0c46fd',
 '8d6bd2cfa0ce12b487d1',
 '8d748735b5bfc75cad31',
 '8d751c092377a035bc2d',
 '8d76c1d37759bd78c9ac',
 '8d78a7d24c5a4959643b',
 '8d7bb90975a082daef37',
 '8d83ca1a713593f13482',
 '8d8afd852e42209fc7fd',
 '8d8c9c24aac0ea5f8d5e',
 '8d8d2721ecdc42f6ae7a',
 '8d909e1699a9987ad1b7',
 '8d9168469538a6363f0b',
 '8d94baa1bb46029b94ec',
 '8d955fffb8551960ca94',
 '8d9c9f4122a28e6df69e',
 '8da13cbf5a1f22af0e76',
 '8dab1336df2a416620bb',
 '8dacc91f0f07ccfd8463',
 '8db13a53cb0a8f9df71c',
 '8db157d6bb24c84b045d',
 '8db4121582767ff38fa2',
 '8db876625d43822a4c6a',
 '8db885e2596ddac7780c',
 '8dbb6d8c0cb0d05e5ac9',
 '8dbbba4932026a958238',
 '8dbc84dc19e21f49605f',
 '8dbe093a1077dc2bd4c3',
 '8dbf664a89214af1d525',
 '8dc1ab25897e5f16ba9c',
 '8dc1b364b5c85aced08b',
 '8dc2bef33b1e76891bd1',
 '8dc545b5333cf452054f',
 '8dc6360282f11d6cd52f',
 '8dc6874464f661c3de6c',
 '8dc8685a921c557af376',
 '8dca1c6543618e9c045a',
 '8dcd4a0f559179be6a48',
 '8dd31730d3a214b5d058',
 '8dd497e935b5d4a99538',
 '8dd6eb7705de64b85ba0',
 '8ddb0e4da2040c5c53e1',
 '8ddff911167c162f7a13',
 '8de251e5f40aab2861a3',
 '8de7332e6650b9c4b874',
 '8dea0f89471dfb7dd4ab',
 '8deb937321cdc3180c9b',
 '8def5c38ad0578cacf9b',
 '8df1daa113461d3a6db1',
 '8df2ceac7a76a3529b96',
 '8df4558de25436de6fb4',
 '8dfa7781bf0914288296',
 '8dfd0c107d84600f9075',
 '8dfe6fb852864f420a6e',
 '8dffdc9393e9b1e37764',
 '8e0197542db2c487e105',
 '8e0b27b3da2038847db8',
 '8e0bf17dcb330ee7418a',
 '8e0ce1f0a47500a7e8c5',
 '8e13d84dd7eade5a3071',
 '8e14ae8fb57f50beb86f',
 '8e176cbeb06b4808a4c8',
 '8e1f9a1e4b4646d46201',
 '8e21e8c3b7420dc474f8',
 '8e28117b420cb448eaff',
 '8e292cdb39468921ae29',
 '8e294372f406be9360a4',
 '8e2ba1978bde701c9d5e',
 '8e327056a73f75d1c1cd',
 '8e33b3c7b536ba80eaf3',
 '8e34b942ad9008deaea5',
 '8e35adb39a8bce8a6d3a',
 '8e3e9f1e13115ec3a0a0',
 '8e45c7d9af43a07ee858',
 '8e4669528bd833fb3882',
 '8e46b8d0d4fef031019e',
 '8e47bb1f9236895b0f50',
 '8e4b1fcac8876b565457',
 '8e4b7ea387a6a13e5b69',
 '8e52d8dd5fa5afaadf19',
 '8e532ecace5f8dba13c5',
 '8e53f861b779b9ddf237',
 '8e5503e4fe86b781c324',
 '8e5c33d3b96a4beaf7f9',
 '8e6068a8a4f44f4f9eaf',
 '8e640f7284e9eb2bb11d',
 '8e65246ec5102e18a393',
 '8e65f1578b84733afa67',
 '8e6b693ce0266c8b1fb9',
 '8e6f0beed946ebe281b3',
 '8e705ded38f4f1901b63',
 '8e70db45be0598dec5fe',
 '8e71247c874a7f395899',
 '8e78e953b6b2a1a53f5b',
 '8e7a75f75676bf8bba89',
 '8e8085b978e3966c7537',
 '8e80a0ff2745f8b40c9c',
 '8e88c2c8960adb5e16c0',
 '8e8951af2ee0017e6ee8',
 '8e89ba0f0171d72fc9c9',
 '8e8a6ac4322a99479319',
 '8e8a74bce320aa5e459a',
 '8e8cb121cd3ca5f74184',
 '8e8fc45641b5cd26ad0a',
 '8e9298690d2f6573ee7a',
 '8e92d7e017b1565afc42',
 '8e939aa74f992843ca39',
 '8e94d5391855a3421c0a',
 '8e977489648ae1714581',
 '8e981af36af50fd51d86',
 '8e9886e509c4281cdce1',
 '8e9e351e24113f0294fe',
 '8e9f0ded4aaa05b0b626',
 '8ea15601ab430b02a806',
 '8ea85955906d3901cacb',
 '8ea938970b6e57fd9d61',
 '8ea94c50a83072a7e5e2',
 '8eaab952d3063d8ee1a2',
 '8eacb6a9992d8d925176',
 '8ead075e2b99c6fe2d7d',
 '8ead7534a22d45b695c3',
 '8eaea2792a9bbcf4521c',
 '8eb26045d498ce98a34b',
 '8eb3b7cb5e8db163d670',
 '8eb3c07ab1a3b41a0c20',
 '8eb4839d1675781ed850',
 '8eb8d3753d1bb553be66',
 '8eb8f963e8455b08be87',
 '8ebe6eeea40282a58421',
 '8ebee1849addc50cd934',
 '8ebf4d10260b63cba90e',
 '8ec9990f8cc67040389e',
 '8eca7c47c2f3119588ac',
 '8ecbaf99261d1ee05a6c',
 '8ecc188322493abe9b02',
 '8ecd2bbe5486d0fa10c7',
 '8ece737340c26ca3c6b3',
 '8ed340555e432e78e2b5',
 '8ed64e04b0a27ad909a9',
 '8ed89540116e3ae2dee6',
 '8ed8d6a3d4d3b2146c87',
 '8edaffc45f3c512555d5',
 '8edd43143d46dd92ef63',
 '8edece854ccf9d78d7d0',
 '8edf7ed025d0d9e85e73',
 '8ee40921ddd9c949d646',
 '8ee736b7ddfe0f08884f',
 '8ee8d885c25afaffb96d',
 '8eeed2484514de592a62',
 '8ef4f7d391f6d65d5f8e',
 '8ef648b5102fc99f2a69',
 '8ef7bb6bcd7f19a3fb83',
 '8ef8ca423bbc011b76a3',
 '8efa578712e3aed31825',
 '8efd286e492416272371',
 '8efd4a4640e172ca5af2',
 '8efdd07133dff25babce',
 '8f006a8f6b08bc1fdf41',
 '8f07b3338f2e63ffde24',
 '8f08855ea14d510de091',
 '8f0933e43ca7866f070b',
 '8f0adc892af2681288dc',
 '8f0d9a43666049810b3f',
 '8f0dac115dcdd591e66c',
 '8f10936099a4f92e3b15',
 '8f10c70797b5d1336e64',
 '8f11c29b4ff05238c70f',
 '8f16372989246b224d8d',
 '8f17286569a82bfa78a3',
 '8f21f2809936d9b05247',
 '8f22aeed7e1233be49a2',
 '8f26f360f9f81196cbd2',
 '8f34683aaed7c99c9c1a',
 '8f399bd848ca3aaaf1e6',
 '8f3bf92ef3c03e449d98',
 '8f4484916d9cab306dab',
 '8f45883ef37e7f83219c',
 '8f45a3766edf2d292db3',
 '8f4a62143d45e3fd79e4',
 '8f5179b2338fc533a63d',
 '8f51a07e5b1b1c55a145',
 '8f5439f910c0808d80c7',
 '8f54b131df615904136e',
 '8f56afe96cce3695994f',
 '8f586124e79bfe440993',
 '8f59423d5ac1034703d2',
 '8f5a08e3100657c235b5',
 '8f5b9ac514690cacc852',
 '8f5c94777aec5f9dff98',
 '8f5f2a88d96da581601a',
 '8f5f7a5744ec41df3444',
 '8f60539ec9fcc3a82c70',
 '8f6545db2d14e276259a',
 '8f669c0d756e1170b831',
 '8f6becb1b815258c6015',
 '8f70045cd961f0359668',
 '8f70c5e427c6adbf2574',
 '8f725e2a06f17a74465d',
 '8f78d3f0bff4de35df18',
 '8f7a4672dec373d9b714',
 '8f7d957a27c2f6722b16',
 '8f8181da1cec82ed3b2b',
 '8f842900be37e1fef6ea',
 '8f8a7193530d2f798727',
 '8f90b2317d756dd18135',
 '8f90cece319b18f77961',
 '8f933a881aa9e7716d78',
 '8f950a9fa5b2a7de6b2a',
 '8f95997acd21a308dc80',
 '8f9a1ea50f519c1b5878',
 '8f9ba9e35e36a3ad26a0',
 '8fb012bba8a685450cf9',
 '8fb29081b476799d8aee',
 '8fb42c351b269b5fc6fc',
 '8fb59b3573239c3ee464',
 '8fb8a8ae74398c033738',
 '8fc16a0b71268d32a69b',
 '8fc1d1bc949cdaf641bf',
 '8fc5685199d880bbec55',
 '8fc61e19dbe71e9c79de',
 '8fc656956a3aacc0233f',
 '8fc808ec3f05b3a59d08',
 '8fccc271c65d8cecd1d8',
 '8fdb41333eba20c1360b',
 '8fe44a74d1c94e3cb0d7',
 '8fe71171d302b9023b69',
 '8fe93d9075ef9369c8ed',
 '8fe96125fc7fe3ec9c5a',
 '8ff0ca40296463ee581a',
 '8ff2c2ffefdcddbfc4bd',
 '8ff7a078cddcee996cf5',
 '8ff90e982187b23c814e',
 '8ffb86603c35fdfd1103',
 '9001c9709a418f3007e0',
 '90024dce4a5ef6adc58a',
 '90035f0f73bf3dfc9056',
 '900498d33c3a01aafc26',
 '9004f2a2efcceb493cee',
 '90080c5e058f44b3b23a',
 '9008dc3a440d3c5c321f',
 '90098cd3231a826abe50',
 '900e360fcd979f51b164',
 '901072b3e98ac2b06cd5',
 '90159f1677a037fd8572',
 '901a55eed67a73697c58',
 '90210eba2350eb89b49d',
 '902636b489d4825a12df',
 '90292fd667c528dd613a',
 '902994b4fae9fa6f9f6c',
 '902a374e1d92554ee168',
 '902ab4ae574b3ca308c0',
 '902f5f3688445a7ed8ea',
 '9033fd52881025383ffa',
 '9034486f85d68b51c582',
 '9034845cd772169b16d3',
 '9036334fca52ac1299f7',
 '90375c70ee984e1ec67f',
 '9042af672308d0fbbc25',
 '9045d4ac4fdcf98d048d',
 '9046219f9d25dda6e556',
 '90478cde032b4e687fe9',
 '9048661c07f63f314d12',
 '904f3423a4c04f110f24',
 '904ffe11bb3693af1299',
 '905d0c439676e0497e80',
 '905fcc115d9c5680ebf5',
 '9063cdb44144b1b4199a',
 '9064a1fce06d71eaf3d5',
 '9065e9228045eaa9d9ab',
 '9066e6f9a7a50c4f6625',
 '906842eb18b689d444c9',
 '906e618ce8617f04ac07',
 '907058f2c4d8e236ed96',
 '907127236e9f1b1d61f9',
 '9071c5f358980e757cae',
 '9072288075eab977d005',
 '9073f3734df42b4dc738',
 '9075996a936d9bf76ac7',
 '907615533a22cce53a42',
 '907c3919b9ba5bf466ea',
 '907de5c85f89063caa27',
 '907dfc62db84cc4ba738',
 '9080123598c0d11eca6c',
 '9084262072ce2ab126ba',
 '90854796eda4e3f2b503',
 '9085649c6a359d6727fb',
 '9087811d02733f7b11b8',
 '908854925f91cde94add',
 '908e2b711b6be4639734',
 '908fe0ead6cae628f2ef',
 '909bb70e044b46e2345f',
 '90a0ac4937c1609957b1',
 '90a3e841d98f80e4ad47',
 '90a5b660a01658454daf',
 '90a5e7fc8404eb4b3ff8',
 '90a626201f8b207c95a9',
 '90a806752b026394bbb5',
 '90a9f23e9d76755e5457',
 '90aacf0dbcdfe124ba67',
 '90ae16863db298e7f799',
 '90af158b18ae1a702102',
 '90ba1d3084a660d1a3b4',
 '90bb023c36fa39f94cdc',
 '90bd4b149d6cfa7efe23',
 '90c0275eaa2753d29cdb',
 '90c07ef27e149c6f44df',
 '90c8a6504800877c3e61',
 '90c8d71d65bce1746050',
 '90d199f64662c4cb9a43',
 '90d34b7ba2535db613f5',
 '90d88ab4b64f4205e93b',
 '90e0e4429580cf485c79',
 '90e0f5daaf4d9f4f47bd',
 '90e15d5435a400f929ab',
 '90e462fb18da75ae2157',
 '90ecd9c52cf1548b9e9f',
 '90ee8299bf6aeadafe88',
 '90f2cbe3311677e81798',
 '90f44554b64c220012cd',
 '90f755903d58d71b442c',
 '90f798dcb0009ba24d31',
 '90f7ac54399ff171ce96',
 '90f7d0800404b6206ded',
 '90febd2cd1ff23bb5ad0',
 '90ffb69b3f2472c6c441',
 '910131b3035956874933',
 '910277f1fb0405edded9',
 '910330fcc8edd23fa804',
 '91033a80839b110072dd',
 '9107bb7cc9549583d115',
 '910bc41c3bd6ae204029',
 '910e628c71e3891b7aeb',
 '9111a2f433752db6e0f7',
 '911a69a91e30aae56904',
 '911ce97c4feda09232f9',
 '911ff0f1a4103bd0a105',
 '91211fef69dc4d2f31d0',
 '91217eace040dc2d4aeb',
 '9128d8a4e36af574e51a',
 '91292935d54a392a3235',
 '9129e613637046d129a7',
 '912e587062f15e3d4718',
 '9131df7bb45d9c3aa927',
 '91343a881304450c78cc',
 '9135ea8a2c7c198613cb',
 '91369aa8772a57d3c51f',
 '9138c64500bfa3742e20',
 '9139fd5be6a0e38ea087',
 '913b18fbe2e07345a78e',
 '913b47b723ba7f55b3f9',
 '91434cade72f0f53628f',
 '9144471ea7679d083b17',
 '9144a0c0f5b69373c444',
 '9146a6e7e355dd5d93f6',
 '9148ba44254001ec124f',
 '914ab2445d7e29856418',
 '914d723cf1a86a0579ac',
 '914dc655816a4af86d71',
 '9154be2d673e18b02e34',
 '915611fb307b42495abd',
 '91596022f438a886def9',
 '915bf5ccf4c75fa16a9b',
 '915c6197758d3a7a695e',
 '915e0659dde15cb0dc47',
 '915e7bf94d7acb6d5489',
 '9169ab28abcad249614e',
 '916c23976f278c6407f6',
 '916e042da36e6772941a',
 '9171bffe6bb27ec7b9e7',
 '9176311f25bee00a7b8b',
 '9176e9d53bc806562d7f',
 '9178159aa1d23df6c341',
 '917884f4db7aed4619c6',
 '9178b34409df16b700f6',
 '9179ef8ed6f4f7f19cab',
 '917ac77dc8840715e358',
 '917c0331d2118c11f9c1',
 '917fd46a4dfd0eee00af',
 '9180451b3758cccc7fb9',
 '9184d332ad26e95a1391',
 '9184fa5345052b0155bc',
 '9186c6ec041500d92cbd',
 '9188519e3d78e98f5a42',
 '918b31efa6aa8b9943eb',
 '91911fce12d48f8c3d0f',
 '9192a96b29098dae3c1a',
 '9193c5bfa58aaaafbd1e',
 '9194c68fb1cac8c827f7',
 '919725150633662c9d23',
 '9199a960e83d050a9911',
 '919b40b04f767d5fbe7a',
 '919b740219b25306db36',
 '919e64b77db837677c4c',
 '919eadee8b2aebcd96f2',
 '91a4f126bfe8c1e0ae5e',
 '91a99a5dd7df54c9d67e',
 '91ab449b1631666dce53',
 '91ab5d28393525d35e5b',
 '91b1c751d02ddc1e66f4',
 '91b44a1205f42409226f',
 '91b64449abf377411777',
 '91b7cc168c618d6b1be2',
 '91ba215c3c8064d326fb',
 '91bf76d3066fb01f3c42',
 '91c3dbed7070776d3e0a',
 '91c4cd84ed20cd2c635a',
 '91c4d76d356f3dd0144f',
 '91c5f2535dd324806fbc',
 '91c6b0942d73877b0dce',
 '91d01ef1dcecc11d180d',
 '91d03b0081701ee84d72',
 '91d94c1be546f62758cc',
 '91db2bd98bf13d47f7c5',
 '91dd8443600b5200c56e',
 '91e60fe65cf340112efd',
 '91eaa698beb87ce3cf8b',
 '91eeb5462cc54e8483ce',
 '91ef747416ce208cc6a0',
 '91effe15211ac052ba45',
 '91f2d80b74097a9c8fe6',
 '91f777359ce2063e36e6',
 '91fe870eab74cfb2b154',
 '9201dc4d2b5315f8bde2',
 '92027cb627d926026bca',
 '9202df5483b468bdefdd',
 '92052e5e086915567f69',
 '92081e76df44a29a261e',
 '920b93c4fc1562dd7e15',
 '92101fdd487c514275db',
 '9211aa9ad476e3966491',
 '9216c45bb774c856de79',
 '9217df1b581ad939fc88',
 '921c704ee1bbdbddd409',
 '921cbef09ddc97e6902a',
 '921d43de9997ccc896b1',
 '921dd9c32565d57a2bb4',
 '92218fd6fb3fa42f9cd0',
 '9222ac5c83017a969262',
 '9222f02fe17e7aef2313',
 '92235b9863447a1059eb',
 '92270236ca6579cfc5b8',
 '9228cb269a42be01816b',
 '922c5a45a01137df5e76',
 '922c5ecc595856c4d49f',
 '922e85b83ecc1a016025',
 '92319f4438c446e4da50',
 '9236291e8f0e1bf03a81',
 '923a7ca767a7dc53183b',
 '923c50f16dc2cd282e2d',
 '923cbf704ccfeaca9fc7',
 '923fa6dcce791c8fc06c',
 '9243408becaa77921c7f',
 '924447bedbe1f2b99b4f',
 '9247fb23136c2d4c1a83',
 '924f1d0ef54d22cf07a4',
 '9251881c5fef394703ff',
 '9251c217b6a3cfc8f54e',
 '9258705ca43c54e6ac73',
 '92589c6235e75b0d0686',
 '925cce6a48e8c80df688',
 '926497ca33cde4b6a7bd',
 '9269554faa6b603c458a',
 '926e138187ba01718134',
 '9272f5d406664bbcefe5',
 '92744edbc345fef574f9',
 '927582fac73ebb40633a',
 '92766a610794c3fde0b9',
 '92773709cc36c5b73c59',
 '9277a1681500d68cf21c',
 '92795344f325cd3a7fd8',
 '927b4dfc721bc175b95f',
 '927ce58be4a198538d89',
 '9286036a13371aaab985',
 '928b3b548b621056974c',
 '928bd905aeb88ce296b2',
 '929010078fba4fb6bbb0',
 '9294c233be9f5e82ca9f',
 '9297041a35f0cf71c48b',
 '9299bfb0892e6d73cdd3',
 '929db8c0bfb797784410',
 '92a0312f0c72b1d40d89',
 '92a432cb686c8bd72a51',
 '92a46f5734ad0d63068b',
 '92ac0968719a31800583',
 '92ac72b8cc5d600dfc08',
 '92b34f68afa270235ab9',
 '92b783daa0ce6cd6af40',
 '92bc4d213a88914c433f',
 '92becfb88bae5475a3c4',
 '92beec50f81aede8c785',
 '92c317ca4a53c07acd04',
 '92c65b86da993f207554',
 '92c95c39e65aa41e8399',
 '92d4446145c76af91f9a',
 '92d5d1825344428335f3',
 '92d7ac94f1560acc9c78',
 '92dc2810574c14d618e1',
 '92dca7593dacdbd386db',
 '92de241c0c1fd4e56675',
 '92de2a4a5e963018d288',
 '92e26ec3193112bcb964',
 '92e72fc36f4e63f89fb2',
 '92ef4b586ae8c0869076',
 '92f17c92212442304383',
 '92f1b35b50b29643ae0e',
 '92f423cb5a1edf1bb775',
 '92f7d85d7d6de238f07b',
 '92fa9296c1e98814ef63',
 '92fbc1e55585d5c6a7d0',
 '92fe1fc819b7ee587c85',
 '92ff1b516f7e9f853529',
 '9300fa24404e87a03638',
 '930254c7b4bc93d6692a',
 '930314714ffe551018bb',
 '930543d5d6ff77306af1',
 '9305b32eef19c06a6490',
 '9309996d91465e052c86',
 '9310c67660e74b07eacb',
 '9310ffc88395d4576afb',
 '9311b9e58f95c25514c8',
 '9311ef12eb637c26dba7',
 '931349dcf3c5870db6e3',
 '93134dd6e99302764490',
 '9314405b93ad0a5501db',
 '931afebcf14a1d33976e',
 '931b63d2d93f3de06cad',
 '931bda29945651460fb6',
 '931e860287c6bc93e9d9',
 '93232582b1680b225354',
 '9323268aaf9606bc357d',
 '93233fa2689eb9763f3e',
 '932c8a0940f27cfce0bd',
 '933300b9acdee36f1ead',
 '93370e6a5e3df7121fca',
 '9338f87e6d277fa0929d',
 '93486f15c5f010399b08',
 '9348fc3368129b2c356b',
 '934a48b9857f5b64007d',
 '934b14141a2369cba71a',
 '934e78fa868fd95e3189',
 '93505faaeabee6cf6a0d',
 '93577e5b4cf1f9064636',
 '9358ab167dc096bc7c3a',
 '9359a0ee189db747da0a',
 '936379b171dab58ab39f',
 '936424f362ec8a7d6225',
 '9364c04d359f1463a1dd',
 '9366416acb0435e2158b',
 '93692919709288f782da',
 '936aab5aee0273425cee',
 '93719a51dfb08f8b1d1a',
 '9371a66f2cff74f80733',
 '9377c11c3e5fefddf9d1',
 '9377caf24b56e4281f11',
 '937b3cd14805402f2b38',
 '937b729d06b454129abd',
 '937b7901c284201a43b1',
 '937c39db3ef5391a2e39',
 '937dc502365429f64d14',
 '938eb3841b6d1564bdd8',
 '938f70e41641d8dc3536',
 '9391350145c09cc198ca',
 '93915191a313a164eceb',
 '9393d5c9054b54e320f1',
 '939fa83b7d9c1436546d',
 '93a6b870bb66c19ceb02',
 '93abf1d2dbf85a447a22',
 '93add0151841506eedca',
 '93af6e1c4fad534a911f',
 '93afdd114d5aaf55eafc',
 '93b07ec34941a7bb0c7b',
 '93b4a9cf0ef6d63dea43',
 '93b764ecc37fdffe0aba',
 '93bd3dc92f2dbee10c96',
 '93bd643f6dcfae9d8e3f',
 '93c110f49597450317b3',
 '93c1a0cfdc9a21aaa7be',
 '93c35cf5abb27dd024e3',
 '93c643b83ccb48e158dc',
 '93c65cec9cbb53274514',
 '93c6eceda9375cfb5f29',
 '93c9048fd5372708c8f0',
 '93c98c45975ea82554e2',
 '93d03e5a60aa094e6c98',
 '93d22b0a409e4d2114fc',
 '93d7901c2e88ad5ec710',
 '93d7cf842987a90090a5',
 '93d8c47feccd617da1c3',
 '93dbfc9af72abbab224c',
 '93dd2bc0b19c3e556767',
 '93e6de3e453d3dce6a6d',
 '93f2eeb17198564ca91d',
 '93f4068e536d1171deb8',
 '93f794131d43e4f631a9',
 '93f8768c8ae276837695',
 '93f986a9c237740fe116',
 '93f998b5535a0ac87135',
 '93fdeb41f3f3be91b274',
 '94011acac3acc118ca2f',
 '9402e1580ef7a4de485f',
 '94080a610dfc1f82dbb6',
 '941017ec3df44d73c354',
 '9410d099bfb92ac54d3a',
 '9418c734b5a314c0aa23',
 '941c1f33f359aaebe8db',
 '941c8570d1730a7dc978',
 '941cecfa517573f56fd2',
 '941ddabe76508e1b61e2',
 '9420ff47e6defcae2cce',
 '942621988da61081e529',
 '942a01ce4b0cc40214ee',
 '94341d428e1ae00933d4',
 '94364cd5418a33d5efc8',
 '9438dad113f074a1d5d7',
 '943a1b082f4b4b5e8435',
 '943aca4df0c56a8cbe10',
 '943b537bd8daa1371010',
 '943ca078d6df03bce558',
 '9444c26426b6ccd27b8e',
 '944a25fbee7d210370cd',
 '9452834bc0ad6431f1e7',
 '9452fd96cf4e5696ef83',
 '9454bbc9048420ad1dcf',
 '9454ebdde5ff6b3f0e68',
 '945aae9e6d1512c53d78',
 '945c8a6a7194c5e8725e',
 '945edc4809ca62d0a118',
 '946a717764e6ae3f3391',
 '946aaa452daff73bd02c',
 '946ba2279dc07b8148c6',
 '947379d952957f088c9e',
 '947597e85aa97c314427',
 '947677aaf5e9d9853cdf',
 '94771f309026831ae2f0',
 '947e97ac94f4a366293d',
 '948381dcb26e14e47496',
 '948aa851627d0a5ebe58',
 '948c159dfafaf54f1155',
 '948eb1860150abd6c09b',
 '94908586a522647dfbd1',
 '9495325360914acf5840',
 '94954615149bfcbfac63',
 '94960604478b26979ec6',
 '9498f8305d7a4e50295d',
 '949a303dd6b918206d2b',
 '949af116c0a9f01e7c8d',
 '94a12d40a6ce62d7eb82',
 '94a3b5e5de742c4acefe',
 '94a5848f19c490d90d7c',
 '94ab2978b154b6787a34',
 '94ab8b7a6039e134e0e3',
 '94adaa60d288ce135c05',
 '94ae151468802b63b3aa',
 '94b33d9ab7a212b57856',
 '94bd041cb66aba1f5348',
 '94bd2d98936c218b3df2',
 '94be4675c45f900880b9',
 '94c7e8ebd762b8a1e840',
 '94c9ebfd1a575147c762',
 '94cbbc25594fb0a98ec6',
 '94cde347a79c3f651d01',
 '94ce8762b243ce398490',
 '94d09c9522f8c37d3554',
 '94d1cc9f35f7eace7032',
 '94d222b7d530284e2e68',
 '94d2346961b002423c4f',
 '94d52492c1ebee2bb172',
 '94d606854cffbedfe03e',
 '94d66740fdbcbcc91ab1',
 '94dd32d0e8728008ca0b',
 '94df0b8fb518986b47fb',
 '94e04dd4a70bd3ab389d',
 '94e2d78c93bb390dbde0',
 '94e315e5e60e4c73fdaa',
 '94e8062c11c07809bc90',
 '94e866fd54b95b3a9b86',
 '94e941bafb87e5e2b9b8',
 '94eeb3cabb57be5d613f',
 '94f04c2c64d83b9ad0fa',
 '94f0ce50d7350066eb71',
 '94f14240d0e7bbd32a0d',
 '94f48a989113391230b3',
 '94f4d6a079e5c5e99d2a',
 '94f61406d7f4ab05df00',
 '94f6c104cb7cf7211c94',
 '94f93f1a0b9ae62a793c',
 '94fb3c7b93ec241ce43c',
 '94fc25629a54f5b1b542',
 '95000a36427622e6a32d',
 '9503c9f09032ffb2700d',
 '95046a465e55607fc93c',
 '9505225db57c14da9c78',
 '9506b8d391d6a7f5aa27',
 '9507f393f34797d8f3b3',
 '95082776cac2b5cdbc76',
 '95086e09d8116e6ac6b2',
 '950891a2e5f7302b2891',
 '9509d806636714952a88',
 '950bce6be775fa4aba33',
 '950d09202b65897c885d',
 '950dac32b80616946503',
 '950e4d8d68b80a647903',
 '950fb36685cc7591b2c9',
 '951054f4081a41f8fff3',
 '9510d167bd58168b0392',
 '9510d4f9707381ed1376',
 '9512cb051738cc299032',
 '951332da6b932bf2161e',
 '951397dfe2167fae87fb',
 '951475d8120d7ed1b739',
 '95155fef65b0c3df7141',
 '95195ec5a2aa5eddf4f8',
 '95197be1986779e67f52',
 '951ac09edb5cfb74de8e',
 '951f7848bacd883bd4a9',
 '9520849991b03511b0d4',
 '9527a85d89408b492212',
 '952b14b311219dd2228b',
 '952f914b90ed16f68fb6',
 '95343f1c4caa3991c41b',
 '953d809320ae3822ac5d',
 '953f0d654e15c9f368ee',
 '9540b654d2a79acf4149',
 '954545a2570003606a19',
 '9545ad13bc97a3a920f2',
 '95460972bcaa82e0078f',
 '9548ba3217c33ed9e5be',
 '9548d7552c45fc170368',
 '954988c0aebb3d705d83',
 '95532883feeb49193ad9',
 '9553a7aa3e81f5a4b0fa',
 '9553e8c8af4ad1738f87',
 '9554ee8b5b2f01ee9885',
 '9559c8d5d6f19e0a3991',
 '955c43d7c177dcc033ca',
 '955c9d13c26557a979e4',
 '955f64cc8c1078b6d361',
 '956264332f0997473731',
 '956a06462b6eee15ea26',
 '956e5360131daee977ec',
 '956e8bede36d38f99f91',
 '956f7d5ff84d79660044',
 '957378e08b1aeb8a0c25',
 '957765a79bb057a10b6d',
 '9579e583e46b26a82ebf',
 '957af38197b985da8588',
 '957e166dacf0dd8faeeb',
 '9583459ab7f99ce47942',
 '95856a043970e5237e60',
 '958888ef99f5b3c0381f',
 '9589d82283b579627490',
 '958c60140fdf33c9e285',
 '958c9239f12fb5df9c5f',
 '958d6a41daa8462df119',
 '958e072adfac923a5eae',
 '958e2a39bfc5d73c0fe5',
 '958fe54de3650996c5e4',
 '95907b3c0a1f44941722',
 '9591bc5821215a1e475c',
 '959232488abbe52b7cf0',
 '959362458e6d05fb5ae9',
 '9594184e9148248a8df5',
 '9598b4b7482999b32d1c',
 '959e0e9de74008b56f0f',
 '959eedd9c188269afc24',
 '95a1f2845b09da13019a',
 '95a2bcb7119527c3d80e',
 '95a2d6c17f274406fdb2',
 '95a2d8c1265454c40dd6',
 '95ad7ccbed3115e14cc2',
 '95b0d8e55c105403dbc0',
 '95b7dde97dbc30037344',
 '95b8f618328fcaba21ac',
 '95bb7e4ed5847b591416',
 '95bc6268594f8a75a600',
 '95bc8feb4f535f3b5e50',
 '95bd3eb7527d4bcb4ce1',
 '95bfaf6d411b8373ea8b',
 '95c1bad1346380b5c874',
 '95c676fc94ddb3d86708',
 '95c7fad41bcff3a5d563',
 '95c9a66180843ce8ae9a',
 '95cdae1cfd07db2c8c75',
 '95ce87e21adb7e5ed486',
 '95d1d7280b3771dc6dcd',
 '95d7e15e1a31c0c613d6',
 '95da321b3d29567cf70e',
 '95dcf52a5fe1ce5c9047',
 '95dd013f7681133db0e9',
 '95f069b7b5a74e60a85d',
 '95f62f5773beafb5df78',
 '95f8a9c643dea8bed4d1',
 '95f9705a89e29c4d328b',
 '9602ecf40573b4b3d143',
 '960434724fc87b144186',
 '9607eaa675e94f7690b1',
 '96084fdfc8f65dcde18e',
 '9609df26ca0ad20b07f6',
 '960a47437cf29182fd07',
 '960cc02887fb752434a1',
 '9610ca32b93fa57af2cb',
 '96141a7b99f7d98febc1',
 '96185a6b29a9788bbeb2',
 '961bcda472813ae90c90',
 '961e62acb70647f850f0',
 '961e846d269befdb7c26',
 '961ebc0426300ec20078',
 '961f97f312acddeb88be',
 '9620ced1d03ab20d6fbe',
 '96224dab88b1dfef82e4',
 '962614fe101698fa93dd',
 '9629a3fd498d4208f56d',
 '962b6efa0241e3bfb090',
 '9630a8a78802984f4783',
 '963271f8c271289620b5',
 '9638b5f9358d7ffde605',
 '963be9c0640e3a169631',
 '963c2405879621a9f40b',
 '963f08769be4e65eaf52',
 '9643272c4ef5589dbe73',
 '9644600f83ffc3248043',
 '96449cc79b8b9f5285f0',
 '964be1e16bcdb37ee212',
 '964c9b92c3fd2f81b7e7',
 '964f49e688e8a4ad25f6',
 '964fb1b4cb75059312f3',
 '96501c4a3f0a2c2013d0',
 '9650b3230503ef7ba9fb',
 '96510afe6e99798db6f2',
 '96514afeac94be063ca8',
 '9658df6c17a9e1d9653d',
 '965a83d47b31ab97f4f2',
 '9663d8a6e9a89f4cd28a',
 '966649154fc3b09948ef',
 '966ffc05f17249629137',
 '96701738ae94cd375ccc',
 '96709af585ba547917e6',
 '967113ea70f44afa9e28',
 '9673891022760a49d6c8',
 '9675b996a7cb0b1d6144',
 '9677b7c87902f3c817e4',
 '967a3ef4ce559508e54b',
 '967a9f346a83a6624ba1',
 '967db78dd13c74f779e1',
 '968103775e7739239242',
 '9681a2f8f47a4f4ea7d2',
 '96821d46775d3566c60e',
 '968245beaaadff4b60d9',
 '968e1c2a0c9e13184cfc',
 '968e8df83cf011a45302',
 '969374cf902176a3aa17',
 '9693c4ec87e53e2c6b9a',
 '969c24deca7022828263',
 '969f431a06541f6cf0bb',
 '96a2e7f6b6ec6f754b39',
 '96a89efd0f21647ddacc',
 '96a8d38b09740586424b',
 '96ab761ab378ef82871c',
 '96ac28b04c45640e216b',
 '96aedbb3e497e2e8fee1',
 '96b294e88a625062ef40',
 '96b3eca16be21d04f562',
 '96b4996f8aab87dc1bf1',
 '96b774d2c4478d1cd4f0',
 '96bba83e3fa88dbfe083',
 '96bc99179560c7f9bbdc',
 '96bdd1e83bddc2a3e2f8',
 '96c1d47935163357f7af',
 '96c21384e04d34c25176',
 '96c21913dcee4e4a08ba',
 '96c75ebd972d329f284a',
 '96c8d82fec2b3e791c2d',
 '96ca40cc28297110d836',
 '96cf165e4af3b635df31',
 '96cfefd6978a3affd4ba',
 '96d13922d5174112f018',
 '96d3dc96dfbf0a2ebc5d',
 '96da2058cefc4800648e',
 '96daf44d0fb40c8f972b',
 '96dc65c71748102b352c',
 '96dc7117ec0e4e4eee1f',
 '96e14243f635fdec937a',
 '96e1d7b08e6508378bb5',
 '96e483ab6956bbf06660',
 '96e4f92a2cdb7758c7b3',
 '96e5abea5e154d243aa1',
 '96e8487ae993176561df',
 '96e8ea43b6290cc106e2',
 '96eaa16e2652780136dc',
 '96f00c261b29fd7ad3b4',
 '96f235d52a550b21d0f5',
 '96f23e893c2dad5e54ec',
 '96f2a834a82b97781257',
 '96f399ceb79a3a509ce1',
 '96f6281c3f576c377cc1']

# %% [markdown]
# 15

# %%
qids_15=['96f7ea16cb86d581ca52',
 '96f82f4e162b8333ab4c',
 '9704c504d676f8db3186',
 '970eda706ffd32e8404c',
 '9712a1739d5a14d088f9',
 '9714e623c42401d1d8f8',
 '971a1688e9a01a212e11',
 '971b0c984811fdaa4e2d',
 '9720ccc5a5b84bccc2a7',
 '972189ac713627d948d2',
 '9721a1098dfe9a59c30b',
 '9723bfba65b27fdd09db',
 '97294ea318994a750dc6',
 '972b455cc4bce1afa642',
 '972ddfb0723db7f27a9d',
 '972e00a11196ff20d3c2',
 '973090541a7cfe012137',
 '9731bedaecca62119c94',
 '9732c6ccc7e3785d191a',
 '973543e98e98f3d71b50',
 '973b4c67daea3c118588',
 '973e3b37c9840d7e8942',
 '9748cfbae2fb8acbdf6d',
 '974a73e348ae271cb35a',
 '974e7213c1d5cead1816',
 '9751d741cb4dab59deb0',
 '975275fead6012dc02ab',
 '97535c09961f6d4a507a',
 '9754606c7f7b9a16ff77',
 '9756bd4ca91c1d4a52d8',
 '9756d02f71352b25fd58',
 '975977ccf83b352fe589',
 '975becf59d7ebbd983db',
 '975d6222b4a6eaa80b00',
 '975dddcd52180017934a',
 '9760360de730be343698',
 '976e7c9f6b5f8d652e40',
 '977a7e1eaf6ba164666d',
 '977d6d1dc1e2bcd5ed70',
 '97826b7f16e2ea06a9b5',
 '978af77e65c669fb375f',
 '978fb88cc76733601c99',
 '9790e1a6face5eb68b83',
 '9792b4f9e6afe3f1a088',
 '97953cd56c9a498de0d2',
 '9795735a4e068b389175',
 '979c47399b5b9de6f817',
 '979d88b8286fcd2c11ec',
 '979f29bb71ebb64fc765',
 '97a1e2f3d9345cbf8ee9',
 '97a5e0b15d07204c629e',
 '97a733dbfcb32ddbdec3',
 '97a8026708b84723e768',
 '97a99aa09fd1f78834a2',
 '97aa2ee96bcd6752d52d',
 '97aaa28208c78cd47bae',
 '97b2532222f0e716bc16',
 '97bb73e59e5d4fbc6443',
 '97bc34304b11b38a3fb9',
 '97bf6dff7d87bfffb65e',
 '97c4293f1bfbd882b922',
 '97c6ce82e4db640fb386',
 '97c75e0db9710503bd8c',
 '97c7aed52aa7fea3b5e7',
 '97c95366ffd079cac9f3',
 '97ccea81ea1ce9d61ca4',
 '97cfee5435927c3bddda',
 '97d033517cf5b78ec7a9',
 '97d3d27aecfed3ac77a7',
 '97d5ffb25690934338c6',
 '97d6bdf0551865075504',
 '97d94cc84c76165516b1',
 '97d9c163302dbf60cad4',
 '97d9f7f4eed628e09703',
 '97e2c15947a5097c01d6',
 '97e54e355d0b2b7f4231',
 '97e80e2d00f637a6aa6a',
 '97efd206f1aa28e79f15',
 '97f3e4402f2501e70436',
 '97f5bd88df4b5768e876',
 '97f95612b069d8bd7e2f',
 '97fc18b08982919e1b86',
 '97ff63d40e1b327e6f2e',
 '9803657ee5d01d97b551',
 '98088337165b6bfa641b',
 '980af9b3c66db7458d89',
 '980d8665a4479aa7c22d',
 '980dadca96d623e68dcd',
 '980fc3bd9bcde14a60c7',
 '981b0e570fb0ec61b3c8',
 '981b739ae22a4bb3e61a',
 '981cded8ca83fb8203d8',
 '981ed2284a3fb89b968b',
 '98266413a343036a0a10',
 '982962d9cf93eb787b0a',
 '983114abaab3232ef1bc',
 '98319e6612b382917057',
 '98326eee2cea28a4e917',
 '98339098b028edd5b1af',
 '984c9b0f94ff22b28114',
 '984d155f51cf83b4fa3e',
 '984fa818bce5d4dcb6a3',
 '9851901bad308cc77570',
 '98526b645fe45e9f6118',
 '9855c034c3027b91b801',
 '98570cad5301850d893e',
 '985771536193823a3c20',
 '9858fe0c3c270675a131',
 '985a13ebe8b773292552',
 '985c753b1d237891ff9c',
 '9864dc7b483c894ce534',
 '98678a728ed3784066ac',
 '9868b46fbb88217d6527',
 '986ad9b0f46854d25df8',
 '986d4d8a7a0ed3afcbad',
 '987387119364a72e6a16',
 '987439bc1670d6bf72a5',
 '9877ec40654dd5ed8d0c',
 '987bb0d68ff8be91272f',
 '987ff8c600ac5471b62f',
 '9882814aebc6ca7d6499',
 '9883d1d3ed3dfdc4d2a7',
 '98844dc41a2ed6a67623',
 '9884c4fbdb22c019b1a2',
 '988500e5f08e79468a76',
 '98851dfc9e81b5d00b94',
 '9886a16b20d16ede2447',
 '988b67f9e951834671c2',
 '988e22b3054d995eefb6',
 '988eb3da886a381833b7',
 '988f33591beb0bfee770',
 '989222868ea5340b7ea6',
 '9892fe0521433c584193',
 '9895cb0fbb1b793daf24',
 '989872e8d68f08a34631',
 '9898f206591c04bd0bea',
 '989985a4e3df9aa5ce7e',
 '989d3dc5ebd3826bd388',
 '98a0729599b2a221b768',
 '98a2131cfbd26ae8633d',
 '98a2c019158b49452235',
 '98a3c9f66c0ac0680aa9',
 '98a7273c6813e6a00fa1',
 '98a8ac95982b15383dd0',
 '98a9a884af1988a8f515',
 '98a9c036f3b2be6249a8',
 '98aa283e51e1a47fa04e',
 '98acaa36ba6960bce47e',
 '98add1644f4ff4fae268',
 '98b0d042a24bc22fc7d3',
 '98b1a77b0b507d417468',
 '98b2401d16e708a42887',
 '98b56dbb06dc9a72f7a2',
 '98ba3f75373c4efcd304',
 '98bbaf3ad88549006efd',
 '98c2caa331962acfdc91',
 '98c7d75d9b9e0f5fccc2',
 '98caca27f4f767a454de',
 '98cc807c0585866fd8b6',
 '98d012f710d8aa7c2163',
 '98d0bd86ffc173520944',
 '98d2b1ea06c4892694a9',
 '98d47b813bdbaaedb48b',
 '98d4b1b409d167c93129',
 '98d59e46326d7ed4b272',
 '98d748d31b0625d5b6cd',
 '98db8e55813c6065b320',
 '98dcd13282b39a49028a',
 '98de4b64fc3b2a32b017',
 '98de5364bfd67c3186cc',
 '98dea0bdfd26a7f75eaa',
 '98dfdd16e34df25c7ff3',
 '98e28856f790f8d8482d',
 '98e579e265a4309367ae',
 '98e68b2df8cc2a910c4c',
 '98e6a13c73e9002690f3',
 '98ebc83ee9686977f88e',
 '98ecdcda02879eed533a',
 '98f531cc2837e841e918',
 '98f65d0bfc9d5f8a2e75',
 '98f85570946a119b617d',
 '9909c930697428474156',
 '9909e03efb4bc34f65b1',
 '990da8b073a8b1bdff96',
 '990e923ba3d3cede925f',
 '990f57005cddc134a7e0',
 '990f5ed6c1c497dd2234',
 '9919f9db29777a6cdc91',
 '991a945e6312e3ce1795',
 '991bee83ffccecb1f231',
 '991f056c479e3ccb53a6',
 '9928a00d2c970859bbe6',
 '992915a7af7a1aaed1bb',
 '992af51a125c2b555edd',
 '992e20a41bbc0ad17f76',
 '9933c3d8e94aaeef07b6',
 '9935d6c105096823e239',
 '993b8f7899b4b254c0bf',
 '993f3a1c62c8b5b7cbe5',
 '99406af26f37f72389af',
 '9940958a6fbb5c8af9fe',
 '99452cf5c9ae4e2b1331',
 '9946963e7aef8382711d',
 '9947bd5124e7e3ada6f0',
 '9948a265877e4729e10f',
 '9949a3084f6c09fa07e2',
 '9949c6eec219ccac0272',
 '994b498ad0c8f6c5a68d',
 '994c4c9cfb525eb60867',
 '994c95382b3742b2e318',
 '994dc2c8cc791059fd65',
 '994eb208915900b5b7fc',
 '994eccd7d3ff8c17cc8e',
 '995059593169ac71966a',
 '99577eeabaead63fc248',
 '995bf8936b4e94aa7336',
 '9962e8844bc6ada0f54e',
 '9968db2e24a482652881',
 '99693b4b7bf4edb9d3e7',
 '996b895202c226b0b31d',
 '996bb6ae1891e7949e9a',
 '996c447201162f131800',
 '996dc2a123825201679e',
 '9972a6b55ec5e931193c',
 '9979f7599180789803ef',
 '997a96c81497601bfbea',
 '997c78f381002a2f23ee',
 '997cddf64abe6263cd1c',
 '997edeac0e10f154e382',
 '99862e371ab109e2db14',
 '99891d1a6a9f7da3e4c7',
 '9989fd314f65a2fec8f1',
 '999014c96d660dd233d3',
 '9994f24f989c0359ab5d',
 '9995784b91294bdb635f',
 '999a3603b5d4d64c658c',
 '99a5e75af132376f3b40',
 '99adbbb110b34e1763e6',
 '99b0053a4c75429cbfb4',
 '99b249806aa99477c3e0',
 '99b473626a9c80668eb0',
 '99b47aa1718fad3392b0',
 '99b4b298e08a30065dd5',
 '99b4ba0ab21c86e89a80',
 '99b678ea6ea0d0333b74',
 '99bbe1d0a39f7c1f88c3',
 '99bcbf0fca37863cbd05',
 '99be24cec0e27973a715',
 '99be3a125b3998ff26e5',
 '99c0cdaedeceb4a24876',
 '99c287ff5bc0552498b8',
 '99c6b1e96940e7a36093',
 '99c970e9e2bd67f6b173',
 '99cb05f466ea33f16c8a',
 '99d4d4d9d4755246f23f',
 '99d9cc1386570b36cc4f',
 '99dabc4c63061bf95997',
 '99df3c72c70e53e2aa82',
 '99e100d04a8bb1fce380',
 '99e130472e1f8efbdc72',
 '99e7a7e03caf525c4f1e',
 '99f2806cb51c60e0b927',
 '99f522fdd14db9a720fb',
 '99f8d5a2a139fedfebcf',
 '99fe42b2fe5c82eb981c',
 '9a001a78c01baff94b5b',
 '9a0069be3c148937ce96',
 '9a01e21c213d2ba0aae7',
 '9a026374a7b08ba5456a',
 '9a058608a659b9068511',
 '9a06185508320b3a8e50',
 '9a07e57de4a5d0ec63a3',
 '9a088fdd757694358516',
 '9a09afe1fbeaa4b47396',
 '9a09ea6d387af17e0109',
 '9a09ed3f1a2890711254',
 '9a0c47776170a59d00c6',
 '9a0f209c936c07016cef',
 '9a0f3decc34bfb94a8a0',
 '9a123a74d425aa602fc1',
 '9a1269b97cd68a98e63d',
 '9a1480ebba8e8c711ec9',
 '9a16c2425270922bbffa',
 '9a17e563784b0e1e685f',
 '9a1989b057a1fce03756',
 '9a1e83d889ec3a01f38c',
 '9a220f8ba81fc87a6874',
 '9a22dc2e943fbd380356',
 '9a2315c3655619980d4a',
 '9a2494212ba4324d91e0',
 '9a2895333cbd2d1d6981',
 '9a2c1e05c44c5135d0e5',
 '9a2dd66880bcaf25182a',
 '9a34e22028010d5f722b',
 '9a374bf0f90bdc7160dd',
 '9a380ba34128035f4343',
 '9a3861a64f37300547b2',
 '9a39ceec72e3443bd65b',
 '9a3da3f0968afef1b9bf',
 '9a411b2fa9727428d153',
 '9a4a28bf36cb06f91e82',
 '9a4b3f29318c7189d738',
 '9a4b54c82ddda1652c10',
 '9a4da4e432e9d06e944c',
 '9a52d5f7f611a82da2fc',
 '9a535d4ba522bcf36daf',
 '9a5c4a08df7c42f5d77d',
 '9a5dbb33ad67d9ffa39d',
 '9a5e11f5b3a697b3d4c3',
 '9a5e1b53587c6aebb63d',
 '9a66dcad0257d8febaf0',
 '9a6ad8f4ecba6a3626fa',
 '9a6c458f344cd55a9229',
 '9a6c545d9b4c4068b9a1',
 '9a6d0fdd1e851bd4ee86',
 '9a721f38e256ace3d2ab',
 '9a7498d61c20f8929c57',
 '9a789d0b153c1ef23573',
 '9a7c8a8346eb694baff3',
 '9a819b8d4eef15f58e2b',
 '9a85bc738e48db8fa36b',
 '9a8ec101a3b6b32d5fa5',
 '9a9072452c9ef96751b5',
 '9a9790c1eae9eee00e57',
 '9a98ac18b41c0aa9379f',
 '9a9b537ceafb30f9a9c4',
 '9aa0a3d6479beae7d3d2',
 '9aa5354aea6197d89789',
 '9aa836306a59d65a55b3',
 '9aab6345b3a40fd8b775',
 '9aad3745b27c58b84f79',
 '9ab1d3fa0bca48a6b567',
 '9ab260e488fc7c1530ee',
 '9ab5825c0f1dd94094ed',
 '9ab66bb1b15070748665',
 '9ab85d35016d47ae7493',
 '9abaa18c90b66f0db181',
 '9abc460049ce0ed34cc0',
 '9abea1650469041fccfc',
 '9ad17968346210052df3',
 '9ad27f058952e59a046e',
 '9ad397148e7311d700c5',
 '9ad6e9e7423e302d559c',
 '9ad77d0c70e6844bf3a2',
 '9ad840cd1ac4197c1150',
 '9ad87ae20a209835f741',
 '9adbdec0f1b173cc940f',
 '9ade910b670bfd68ff38',
 '9adf47c31ba85922fe19',
 '9ae25f854e3898f17aaa',
 '9ae8fac7939575a39719',
 '9ae964428d73d7e32730',
 '9aeb2e735cda4524a5ba',
 '9aebda37250710da4b90',
 '9aee9536ef51edb91ddd',
 '9af0dd52a2ae18169f52',
 '9af147a5e9a623891213',
 '9af2a76e7725f0c16dcc',
 '9af3fd97e6884e724031',
 '9af9a54e31d73edf5e81',
 '9afa6ab8a7923045573f',
 '9b05e151a2c2e840967c',
 '9b06a25fa48853d07693',
 '9b095c1c16bf45428490',
 '9b0cb0c95ca1c5634b86',
 '9b0e1be204b55ff250e9',
 '9b0feeaeab61f2b2491b',
 '9b143386e8d1618fa25e',
 '9b19ef9f4c026ba43f8b',
 '9b1c55ad4f2095f1c3dc',
 '9b1ed1ff00c9340bd668',
 '9b2015ca1a515aeb87a1',
 '9b286a3a058fed9bee87',
 '9b29acbfbcbe9606349a',
 '9b30fdba4b49a4c82b11',
 '9b3e4841c3c45c428601',
 '9b3fd506b2379a2c99a9',
 '9b40044cecb35fdefd4a',
 '9b4077b656f0fa7cd31d',
 '9b41d7f5713414ae2ddb',
 '9b43fd27e3057096ebc2',
 '9b4c3c8268ff5e05d9b3',
 '9b4d205aefe06eefab11',
 '9b4eb95c7994cf6f56aa',
 '9b4ed467e7dd2153cabd',
 '9b5039710366b9ffdf93',
 '9b51c312de072944b4d9',
 '9b57b4ab2844e07476c2',
 '9b59426a2a65a5462ada',
 '9b59cf997a328241ca3f',
 '9b5bc22aabde2195c664',
 '9b5d48d59b627d84a3e6',
 '9b5edcbdef0e71182da9',
 '9b60cd8399e5fecc13ae',
 '9b673305474303f8b2d0',
 '9b6a4df406427acb75ec',
 '9b6ba031df664f482964',
 '9b7000653233a50743a9',
 '9b78efbf7ee03ede02df',
 '9b796dc50462175583a9',
 '9b7d82d233ed52d872eb',
 '9b7d88fb43b03f7cf9f6',
 '9b8469dcb2f1954f3a27',
 '9b892522c6693fef1639',
 '9b8ab2d27bf941790fa5',
 '9b8e84be265c57add82e',
 '9b93717a7c99405f890d',
 '9b9429ea4d74b3ec61d4',
 '9b94af702f3f13c45744',
 '9b981592f88afde98a0c',
 '9ba0e1d88dfd82211475',
 '9ba313932820748e0694',
 '9ba3ad9d79c6ab21feba',
 '9ba4008d7267448cd690',
 '9ba54ecbd564f72794b1',
 '9ba63175af25d342ad9c',
 '9ba7072292052f17538f',
 '9baa6cb593ff312b9263',
 '9baad2a4fc09bea73377',
 '9bab01508b49a065e5c8',
 '9bac46de88155618a30b',
 '9bac8d5cc15e02426825',
 '9baed6fed2b020428b2a',
 '9bb0f3ea05d02de004d9',
 '9bb144ad62d2acf00747',
 '9bb305d8482fad02347e',
 '9bb31ba5905206a69bac',
 '9bb36f30f9285b5e873a',
 '9bb46616134b248612ae',
 '9bb96b758a1944809485',
 '9bba26500ee8834b00d2',
 '9bba990c82db5255d3bb',
 '9bbb3d87df184a5cdbf9',
 '9bbe83f4f899e705c5db',
 '9bc0da63ec32ebcb68eb',
 '9bc33f8b6b64ba1d8401',
 '9bc56c9aad77d399809e',
 '9bc72bba8b6179c287fb',
 '9bc9082e900653bfc839',
 '9bca21cbba69ae136579',
 '9bce98864db3b1348755',
 '9bceea677ec1ae9bb2bd',
 '9bcffa96d9b5a03dfd88',
 '9bd0563653303860b5b1',
 '9bd19fa3e6052eea1a92',
 '9bd1b527ad30bab12b0d',
 '9bd1cf10139ae3c29e8e',
 '9bd8fd963e033f0c8d18',
 '9bdfee7011d1652a955c',
 '9be0c6a35e67c1f0f335',
 '9be4f581986c330b788f',
 '9be6691d566f0539abb7',
 '9be8e9bcbc40be67ecae',
 '9becb6c1114dd8e87d9c',
 '9bf8ad9130e5568c8f14',
 '9bf8c711a07316ff7bd2',
 '9bf9cecfbc3b6846ff0f',
 '9bfa42248b70b35792f6',
 '9c01d9e9784c445e6c91',
 '9c0389fd868dcd2d4ed5',
 '9c03ae1be5e303624f0d',
 '9c047f37627e3f57b579',
 '9c06444321ab6e0ab3eb',
 '9c0b6c0510f53d951829',
 '9c0d28449b4dea42871d',
 '9c0e7cd74bacaa26185a',
 '9c11bdbbeb87bc5518d0',
 '9c1216e13707d06d67af',
 '9c172fa4ab3864c43742',
 '9c18b860a745ab078f02',
 '9c1bde203efd68a6171f',
 '9c20c1cb8436f9fa0223',
 '9c26f3b3570df62ddcf3',
 '9c2a5411a2814a2e37b8',
 '9c3220c946228c65bc53',
 '9c3297d5dfb222e8332b',
 '9c345af809438beb114c',
 '9c390d1c219389269ecd',
 '9c3beee8848fe42464af',
 '9c3bf44fa99beb141e9f',
 '9c3d958961450f43273e',
 '9c420f1974a5474478a8',
 '9c47227aa77abbc7f7ce',
 '9c4762b5796a1423843d',
 '9c4824d9d1e1159b78b6',
 '9c4990293916e6ea3355',
 '9c49fa5bd725b88b3cf6',
 '9c4f616d4de91bf993fd',
 '9c4f8a93c25a591070b3',
 '9c4fa98b9dcb88ae001a',
 '9c50eec0e8e27e199aff',
 '9c524ad02b93f9f77d0c',
 '9c55d7d0c872856a6b2a',
 '9c5662a7431929ddf09f',
 '9c5813286cd43e0ab566',
 '9c58d3df18815c7aa3db',
 '9c5d38ba2e21d38fea99',
 '9c5e606120ee168899d5',
 '9c61d87f28990fea0842',
 '9c632cc8da9aae9fbe1f',
 '9c6351d29863d8959071',
 '9c64b6d7ee3ab5519503',
 '9c695c406a8641a5df6e',
 '9c699b67046170fc7f6a',
 '9c6ab58bc519bdfc6d5a',
 '9c6e0b434e3c598c7ca7',
 '9c6f7be2293bc3540d12',
 '9c724c8e480d7a6f5ce8',
 '9c761f6dd70b30183c83',
 '9c76c2f8b45e65e41f4a',
 '9c7702108f15eaa7f861',
 '9c7837ca2e0c59a2c8f3',
 '9c79c208cca67408e198',
 '9c7b28886c95575eab16',
 '9c7c5e61f778560dc6c8',
 '9c7ca2397b24113d04cc',
 '9c7caa1b694894322ddb',
 '9c809a218ecedfb420f9',
 '9c80c36da9aa49bfb57b',
 '9c8122e32fdfdecc1d4f',
 '9c821a53e45dc3ae4936',
 '9c87e59e825662bb7683',
 '9c8b4c1b87834b9b407e',
 '9c8bc1ae68c5f15e38f7',
 '9c8c64acd8742879b7ad',
 '9c904a3f97fb1793e34d',
 '9c926ed7054029e0fde6',
 '9c97236c285e22d92e3d',
 '9c9dc092a7c21afe330c',
 '9ca18098a0b44f086ab6',
 '9ca3de690075962b7767',
 '9caaafd971b04b8609d8',
 '9cadb221f993c4c66865',
 '9caec2178455fe47f250',
 '9cb04a5b64db2a82ea14',
 '9cb1c316fdeb820650f9',
 '9cb4b109d42c71abf31a',
 '9cb7749dea2050673837',
 '9cbcf54792c9e6526286',
 '9cbd6eedb24bd938500d',
 '9cbf2e3be3bd538b4ad9',
 '9cc0f44f102d0af20faa',
 '9cc92eddfe5983e9e5ba',
 '9ccf159cafff04ab8b49',
 '9cd01c15816124e68e8c',
 '9cd152eac1eb67c5a573',
 '9cd2ab78a4b6463f7ef1',
 '9cd5b5f5f32c2c48dff6',
 '9cd7a154cb1b86ec16a1',
 '9cdd3b50d656de31aa4d',
 '9cdd3e6e36a75e195728',
 '9ce2643d1edca5a90bac',
 '9ce6d467a8a67da4efe5',
 '9cedc7e49e2eb22dbe9e',
 '9cee41062e3fd8427ad6',
 '9cf10884fe0255f062f3',
 '9cf2db4e5629825bf219',
 '9cf68b1cfc767ce3cfd6',
 '9cfa1330a3f7fb6696a5',
 '9cfb9fd00e8ff2e91365',
 '9d0177cc3deef0d430ca',
 '9d026e8bcb0dd07ded21',
 '9d08185e119e309d834b',
 '9d0ec1585a857e7f0d39',
 '9d14e95a337e8d55fcb3',
 '9d15727a34c03a46dc43',
 '9d16d251ce2933a3132e',
 '9d1c38e286a87d5ce615',
 '9d1d2554c57b581ab25d',
 '9d23dcb118c9cef5b606',
 '9d24caa9643e3e8874c0',
 '9d282bd5332c79811abb',
 '9d2ae016fe3ae4c618a1',
 '9d2bb86e5f0ba35ebeb3',
 '9d2f0a5c3e47a794566d',
 '9d2f35bef058584666b3',
 '9d338933a051d475f4cc',
 '9d3d558fe3b32b16a229',
 '9d3e379abaebe71ca87d',
 '9d3ec5890f633ea9f407',
 '9d3f14bbdfa9376a0ba6',
 '9d414ddef32a6f326774',
 '9d45bc72fe7c4f8731ba',
 '9d47084ab791ff240662',
 '9d470935dbdc8b142bca',
 '9d4b8ee73319a126ac85',
 '9d4bca1d323a8d63ea3a',
 '9d4d606b787c09313a39',
 '9d4e0128b206ffc6f17d',
 '9d4f5452d3e07fbce3af',
 '9d563e665846253eaaf3',
 '9d5b18c3ce9a0dea92ca',
 '9d5f68618e15d0dce786',
 '9d673e51d7c1af1a6331',
 '9d67beb6f32ffaf4f828',
 '9d681c293f901b4166c4',
 '9d6ab206e409e1b9752f',
 '9d6dce4f161549df7273',
 '9d6e0154adf2808b370b',
 '9d721724c91b69f4c659',
 '9d7220d990f145f39d1d',
 '9d736743b9e1cc369a23',
 '9d73d0bfed6a1601e436',
 '9d73e1d31350a35ad438',
 '9d7743aa8a61ecc58537',
 '9d79058ba882d8a01db7',
 '9d7b8e44b6dc58a23ee1',
 '9d7dc1d1073fbcc75ff2',
 '9d7df8b079747554cf33',
 '9d82af8fb38f16400b8a',
 '9d845a940f3031875e28',
 '9d8b74c5bd4595ac055e',
 '9d8fb1b2a36c8fcfe3fa',
 '9d933e556736e312c664',
 '9d9442002b3fbd1df5e3',
 '9d95a31b68190fe20aaf',
 '9d9903b37b1e5848f313',
 '9d9bb9ec0e5eaebc1fcc',
 '9d9ce81f9e8babdb7762',
 '9d9fd2f7f83c2581ba94',
 '9da28afe8b023b9142f2',
 '9da355ad451fc2bf209d',
 '9da47aff3361eb6f5d63',
 '9da8f452e2385af5be08',
 '9dab772df60ed05def6e',
 '9dae437c1419e8c4d7af',
 '9daf6f21d3f707a97b42',
 '9dafbfaef1dde4e6ce0c',
 '9dbc965811bd73f844fd',
 '9dc4548da3830681fffd',
 '9dd69c244ff49c7baf5d',
 '9dd96b0e24cb07a8dc1d',
 '9ddd216d33b168402e37',
 '9dddabc7b56e045dead1',
 '9ddf3ae642ac2266b0e2',
 '9ddf5c768793fd148c3f',
 '9de19a71de1ba5a3dbe4',
 '9de2d1b854ead3a164a8',
 '9ded2543a5567ef98fe7',
 '9deddb6c383c6f0dbccc',
 '9defdc49ecc4edab0896',
 '9df22153e3357ef5ffd6',
 '9df98182f5e28543d23c',
 '9dfb823063aa5bb88542',
 '9dfc5859bcc097a65a97',
 '9e010c6cab34e68cb73a',
 '9e0317697e2523569967',
 '9e03b0c2e0868e0e59a0',
 '9e097c62ba43cb4163fa',
 '9e09b04a9460ac50e509',
 '9e0a15dc8ed8d9b487d5',
 '9e0a6c3b0360e2f4aa89',
 '9e0a98954b1b67b46da1',
 '9e0bb6ec3ca9fb8e0f0f',
 '9e0c2a93adc66490cce1',
 '9e0e2a74a2f73c61dd92',
 '9e13c31c22405fb6692b',
 '9e18a5883ab99f812362',
 '9e1a6ddd2253e7b94f0f',
 '9e1faf27ae45e9e24ece',
 '9e1fcb00478a03c8331f',
 '9e2021af26532dccecd0',
 '9e232dead004cd3252be',
 '9e253e2a4c6d75ab5b8c',
 '9e26fb40306191c8d4f6',
 '9e2daef89929ca834753',
 '9e2dc71e5202e198e05e',
 '9e2e5746bfd43e738350',
 '9e34b6efb54a55b2de72',
 '9e34f61bf0cb02081181',
 '9e396f29acb6fea1a28c',
 '9e3c9f992bb2b480cfeb',
 '9e42f88bbd8808268ab8',
 '9e43ba2f549cc20a7ad4',
 '9e446777ae0934b807f9',
 '9e4e408de4708611099c',
 '9e4f934ab5d2d86227ff',
 '9e504494a4727aa36a04',
 '9e50b116b878d42018f4',
 '9e517e0305d32e215f2f',
 '9e51ba05d38fee75b8ec',
 '9e546382e66d85901d3f',
 '9e547c090deb948af4ad',
 '9e56449532ba863b4cb7',
 '9e5795e85cf4dd887f2c',
 '9e5885d3e75a4fd463fc',
 '9e5d6e99a9f98898fdd5',
 '9e5f19778f1e13c519e7',
 '9e5fe8b20eb358b5ef24',
 '9e609d6432c8ee749bf8',
 '9e6d18e0b4bc4f768ca7',
 '9e6d4cfe78ee8ea961fd',
 '9e70e5a3d89ef22eb056',
 '9e72caa90801a8353f78',
 '9e73461ed2bca020182d',
 '9e77714c5d90db568f4b',
 '9e7c138d986a91f1c636',
 '9e865460c6b343729ca8',
 '9e87f45845da74b66546',
 '9e88aee902265f4428a1',
 '9e89896688aa14db2359',
 '9e89a423ffe3840a8702',
 '9e8af6048fc0cd68fc24',
 '9e8df2846a226e74b922',
 '9e8f8588582d60aebaf0',
 '9e9155af3455cfaf791c',
 '9e928bd8030e5ce13b87',
 '9e92fe6ff002f023e057',
 '9e95600caa5b1155df7a',
 '9e9672e5288838ecfcdb',
 '9e984acdc9992481378f',
 '9e99ce92fd74a95f9757',
 '9e9a068266b3e094c14f',
 '9e9a374a457221fa6e2c',
 '9e9a7afd5613a8df8bbe',
 '9e9c602d3e265dbe76af',
 '9e9f549cd8d1c7aa095c',
 '9ea40f123fc7f5f7c1be',
 '9ea81e93c6b7366297a7',
 '9eaa1660d1eb941bcbf3',
 '9ead1a16474432b6be94',
 '9eb5ff14c98a10101ea2',
 '9eb67d9ac2592268d01e',
 '9eb6d614412dc8961ef8',
 '9eb70708a4d7bcb3c209',
 '9eb7cbaf4668149d0efb',
 '9eb820cee14dc46cd606',
 '9eb94dcc3bccd2405619',
 '9eba2e2b0052fe49a1c5',
 '9ebb893f14623ce901ca',
 '9ebbc6985b09547b42bc',
 '9ebe25ebdd67321558b5',
 '9ec0a67d08b586977914',
 '9ec0ad9443e540b71550',
 '9ec5eac6179297c05ff7',
 '9ec641dc4fef24ac3b08',
 '9ecaabc4ed9563bb7406',
 '9eccd43a41f88748342b',
 '9ecdc09f46d733516d3c',
 '9ecf168ae7588b095562',
 '9edc7b00a72ede7e5504',
 '9edd1e68509d6a6253bf',
 '9edfaec755b82624a688',
 '9ee327327f1074d77742',
 '9ee456e18c6eaae4ce3a',
 '9ee6795ff0c28c52086f',
 '9ee6a0610c94a29a18f8',
 '9eec6617c62c68d6171c',
 '9eef182666dc93fb6e7c',
 '9eef9faa3776311abfd8',
 '9eefd1e4e3b403fee1ab',
 '9ef5daa60b3511cb60e0',
 '9ef75e3614c43e270d93',
 '9ef89ec0e28ebe32fe23',
 '9efc02b69494cd06bd07',
 '9efd7a10f77ff42264ef',
 '9efe1c7f636378192e65',
 '9f00d23ea8c08f3f3a9e',
 '9f0b345d565c3de1d672',
 '9f0c2daac37f486e896d',
 '9f0e3dc4850c4f0d00bc',
 '9f10587806f71bc393bc',
 '9f147f19ef5ff0e2594c',
 '9f176dd29456944bc5c9',
 '9f20a8900b052defb5e0',
 '9f217067cc4c43a54b0f',
 '9f227ec7556865e45b22',
 '9f29f26fd2f5782f984c',
 '9f2c118f61ed984f0e09',
 '9f346aadac424a109eb9',
 '9f38568c7a97e884075f',
 '9f38c255a4252146c609',
 '9f3a25a68da6598bf0f5',
 '9f3c6a2e3fca9dd4036a',
 '9f3ea1e0fe7057ae3cf2',
 '9f44f9128c3a6f0f8b51',
 '9f4520fc871c24c3aa9e',
 '9f49dcb24465e5d1399e',
 '9f4e1888d9054e37d9ae',
 '9f50b2104cc10b597368',
 '9f52454b53bec50ae723',
 '9f5accefa593ff9b33cc',
 '9f5f486c28e89628c429',
 '9f6527596c70564b576d',
 '9f73f44582d336ad809f',
 '9f76a03953a2cbf8aec7',
 '9f7ff4eb17ea902ea48a',
 '9f8477b9b798c83b423e',
 '9f89a9a735866f0099fe',
 '9f8b1d2f6cd0d2875e72',
 '9f9192b5dc7f65dd0b8b',
 '9f98278e41271262fe70',
 '9f9a9cf88fa7d52ab314',
 '9f9bddc8c1cf30701eb3',
 '9f9e8dd326187947911f',
 '9faa28113a4041abf3ce',
 '9faa3d23579fa85b9390',
 '9fab2ab7c77063ae4d3f',
 '9fab856d9a764ce3fd16',
 '9fac0c73e7b53aa9a0b4',
 '9fac8c3d2c7584173dd4',
 '9facff1fefd6f437a608',
 '9fb13c633eb347de1bba',
 '9fb2e35d074107d18d0c',
 '9fb36bfd25e7bb6585ce',
 '9fb38a87ca068078e49e',
 '9fb3a3e22127e3641d0c',
 '9fb43fd9a1f00f855fa1',
 '9fb523aecc215b878bb2',
 '9fb61438b4a4a42e9870',
 '9fb9d567da0f470c0ce9',
 '9fbad5460cd0d5e87a7d',
 '9fbef6a656840588ab8b',
 '9fc3b381d0204e2baa70',
 '9fc54c8793d1089ecc9a',
 '9fc57aab4bea72419aea',
 '9fcb1265ad574d50019b',
 '9fce1d27243ea1e4c2ac',
 '9fcef13d850d564713eb',
 '9fcf395531f72c2bf3b8',
 '9fcf5517b1749df06119',
 '9fd9229c107f01aa70af',
 '9fdb4481032369804a00',
 '9fddc797f8e6fb97545d',
 '9fde4e6059dde4e6222f',
 '9fe57cc98c6767b1fc2e',
 '9ff13b02fee4892b9f90',
 '9ff143d4ebd399cb7567',
 '9ff5ca889b0f546905ff',
 '9ff7f6606e60b6318619',
 '9ff834dd9972496b75ed',
 '9ff86eb72c3d9355dec6',
 '9ff90a368e60992c4e06',
 '9ffa7ca6eca82c3a00f8',
 '9ffc852ce4f14bb751eb',
 '9ffce35b9a9a965f2f9c',
 '9ffdc5aec9e06709e8c0',
 '9fff59fa09c6d8c78d06',
 'a001568bae37ab97f809',
 'a0038afdf406e6b9110b',
 'a005829f7bca8fd0af0e',
 'a006b6384c374d44bb4a',
 'a0087b60473fb410f621',
 'a00d12508e84aa945ffd',
 'a00e07df82bce1123aee',
 'a00ef58c98d534ea6cf5',
 'a0118390ad276823a9ba',
 'a012d5308e9635d242b9',
 'a0171cffe1d592aa1b94',
 'a019e65e038b4c64a7f9',
 'a01c050262271291c494',
 'a01ed2ca334f72c0f7d9',
 'a02360fe541e22279ecd',
 'a027f42bb179a71a15f3',
 'a02b25a8ac8f744afc3d',
 'a0320cdb865fa4a965f1',
 'a03396ea2859ca7dfdd5',
 'a036dd686dfe4fe3e754',
 'a04063d2d4957147fbaa',
 'a040fdba64db6eb0ca52',
 'a04229267b10c7e6a5fc',
 'a0464df59928ee19df55',
 'a04859321cc8541a59bd',
 'a0494e86a6a6f5f53ad7',
 'a04df3f2082a54c532c7',
 'a056110b156919324d97',
 'a058d5efcba4dc596a9e',
 'a058f8070338253c535d',
 'a064f7dab428415341d2',
 'a0653719398a68ba6e9b',
 'a067d0b0298443c976cb',
 'a069944a99866559d04a',
 'a06a0445e090bd2ad507',
 'a06d4e0529fabcf63141',
 'a073d28c07deda696a6e',
 'a0741ea7255257603437',
 'a07578fa28cf2f763fc5',
 'a076d2202a8eca14cd4f',
 'a079853bb4b7517d2f7b',
 'a07bac62bdf46ea1404f',
 'a0832f5d70fa1a972768',
 'a083fbd6fc9303a0b24f',
 'a08bcc95601b559a4548',
 'a08ed0fa9ea4ce6f3e91',
 'a08eef86249243db1ce7',
 'a08fd8e59fb273bbae68',
 'a09016a63d710d746fce',
 'a095794676ba8e1c0522',
 'a095ce1a0380c99f19f6',
 'a0985952ed0ed38f6dfa',
 'a09a6acbee8ccf36542b',
 'a09c4864160a205dce41',
 'a0a611c060a207f2f1ce',
 'a0a700404bf92cee41e6',
 'a0a79e7a6d7f7b0710e6',
 'a0a9f443af9db4b81377',
 'a0aa2e397ce28c0d95b4',
 'a0aa3de4df42011b61d2',
 'a0ab6c72d8564b998ea8',
 'a0ad4b4400d2a499028c',
 'a0b4077249ffcb3ba152',
 'a0b4249f9f0fc85b10fb',
 'a0b5db5a1993daa26394',
 'a0b5ec72f5e05d53996d',
 'a0b89428f16d9368e368',
 'a0bb6a2dca4daa7be734',
 'a0bd6bbcc2424b03cb09',
 'a0c0158a6abc7d58aea5',
 'a0c1c83a14ff62e3ad26',
 'a0c64e4a4c4e76085562',
 'a0c8eaddbde48f7b55d4',
 'a0ca44e19db024f8b926',
 'a0cc9d2310d19bf3310b',
 'a0cdd06fbd409916b337',
 'a0d2f8121b545b7f5e10',
 'a0d316261f22468f5cb9',
 'a0d3217792e9d33f0c52',
 'a0d8f5ad1ce92548c721',
 'a0d9acf0f933ebfe0b4c',
 'a0db903fde09feebba02',
 'a0dbb099a0f171fdbde6',
 'a0e0b7a5125ac6b55557',
 'a0e1c72bf24f18d12234',
 'a0e5a738af3c79def2d3',
 'a0e8e59a7ef08b2c7449',
 'a0eb656a921e2cc3731c',
 'a0eb79eb6037747b57b2',
 'a0ece098dd9ee241030e',
 'a0ed3fd7b7164868b2fa',
 'a0ef14d697f650c2a805',
 'a0ef8d518a5d7ab92ea7',
 'a0f2b1d6921b18e6a5c9',
 'a0f5e5a40d24113c329d',
 'a0f9219ee0015df0111e',
 'a0ff767bcce03ec70526',
 'a10bfc914a8357793f40',
 'a10ecefa99ae791e7760',
 'a1139f4b2200d0378892',
 'a116061f04d97afdc396',
 'a11a4a700354302bc67b',
 'a11b27ccb2ab7032aff4',
 'a11cda27d214c5016d30',
 'a11de2e8703ac8a6d17a',
 'a11f082add2694c041fd',
 'a12065db8fe0cc295212',
 'a121080aabde8e811b0d',
 'a128c79d63017e0e755b',
 'a129580bdc63c8c58117',
 'a12a59862cdfc5d9dd38',
 'a12a921a4ad693bb680c',
 'a12b7be6a426136a8276',
 'a12d497638e3af96b346',
 'a12fa495fbaaebbfede8',
 'a131bf5e035ef97ec1fd',
 'a134922aeb91ab814450',
 'a13a4b73b2ea0e2a4664',
 'a13d6bf809603ced5914',
 'a13feff9d19433df0b93',
 'a143f6b7bc10814e49d8',
 'a145478cefb247eaa34c',
 'a145762400cb177d9795',
 'a14770133cb04bc7124a',
 'a14998b800283f6a4f44',
 'a14bda21469cfad5f914',
 'a14ce975c9981152d958',
 'a1503de836499eae1135',
 'a1525bef424900b0feaa',
 'a152ab4beb152c1fb733',
 'a1546377596936cafee0',
 'a159438914314776d273',
 'a15b9dbdacfe1c21da40',
 'a161271b626d3d7e3e5e',
 'a16cdd74b9c5479ed920',
 'a16cff74f007dad27f9c',
 'a16fb8e20f0b90719bb3',
 'a171d504477133be1834',
 'a17397809ba07dc8c2ac',
 'a173b747a8649d743bc3',
 'a173ea3306ba22d28b60',
 'a174b36b8113ab8c6f3a',
 'a17cc7d63e92edbf93fc',
 'a1839f0e2cccdfbeab76',
 'a185404492d60cf42976',
 'a1882b2dfb4aa7c7cf22',
 'a1898bf0a514a8ea28d0',
 'a189af270dba54c7b938',
 'a189efb812d174c5598b',
 'a18a71cfe37696e1c502',
 'a18aa855c67055d5bd3f',
 'a18b31aa4b6a5d09d1ac',
 'a19160e1e626a85eecfb',
 'a1950d51f61fc0827a7c',
 'a19a6d2cabab58ce89f8',
 'a19ae412a27b943cf5a6',
 'a19cb0934b0562350e43',
 'a1a81e32346485b233bd',
 'a1b081280e3bf2d2a0ba',
 'a1b15f8279d23f9af608',
 'a1b1e5607f1991ea0d99',
 'a1b255f906cef6490bde']

# %% [markdown]
# 16

# %%
qids_16=['a1b3148fdb28bf56d02f',
 'a1be2a23cca9a8dff98f',
 'a1beae6bfad7e9337e1c',
 'a1c32e6799161044955c',
 'a1c352c62f5802524c9e',
 'a1c84b22ce4c67c3b506',
 'a1c8a13b86fc8b29dcaf',
 'a1ca3675b5fdd6317640',
 'a1d106801eb78da8babb',
 'a1d97a7a198bb74220d9',
 'a1d9cfc4ff1591358727',
 'a1e0f3dc32243c413c77',
 'a1e77133bf2adf663b7f',
 'a1ed28097d08cf427d5f',
 'a1f1a68baa5d79f70a12',
 'a1f3bb054eeff602b66e',
 'a1f41d7b6d962aad57d0',
 'a1f4dce94af23abe5bd7',
 'a1f5f3aee5ed8dbeaf3d',
 'a1f7a133e68436501465',
 'a1f7c0c70444fa93b750',
 'a1f8324fc1e2728cab07',
 'a1fd3f14a6d8fe8ea9e4',
 'a1fd6eb76460ac97ba56',
 'a203cfc98c98ef6dac1c',
 'a206806d4fd85db90237',
 'a2093f6d6d0ad74552f0',
 'a20b77dad11826234b2d',
 'a20ed2b1ce6c6676b781',
 'a21003f5a1e2eedc26dc',
 'a213e01dc5b70e87103b',
 'a2252a50e1242a5f737c',
 'a22c60a51fa5ee4bd1f5',
 'a22ce6566e2a6cd72e42',
 'a22df9119c3f499c3ee0',
 'a22f2279f5aeeb576db3',
 'a231678ed896af55df61',
 'a232b2c381d5f8bda47a',
 'a235127e01c00c52a747',
 'a235cf1c17a353786a21',
 'a23781d6597379750be4',
 'a238f4fc6e3c112dc8cb',
 'a23a67b8471a71b545dd',
 'a240126d5502bc5ee05e',
 'a2438d377226b6f5ce3c',
 'a2449dcf70cfd9459bf5',
 'a24a98de5f5b110d1b95',
 'a24b7c4d0697808dee12',
 'a25042408dbc25ba29c8',
 'a250c9e4baacdad01247',
 'a25118c50ce1b7f35cf4',
 'a2569d02f1c074fa6ac3',
 'a260d75fcf7c327a5e43',
 'a26b79ca0fd869d8bac8',
 'a26ceece8ff398e37e76',
 'a26e1860d676f7331ff5',
 'a271746563fdeaf1ab54',
 'a2773c6c923b44d8b697',
 'a27dfda2355f38e1d2c4',
 'a27fdb31b33b9496febc',
 'a28473c27aecd0501c54',
 'a2888237920edc284154',
 'a288ab8fb3520bbb95aa',
 'a28951a35ebf65524403',
 'a28b69fcd15f6ee7ec7d',
 'a28f79314d20c639ae07',
 'a2903294ffc71bbdfe64',
 'a2928cc6a15f1ab4234b',
 'a296e15fc8fa844ebb06',
 'a29c308471c5e5353efc',
 'a29ea1cfb2cc055bf8b1',
 'a2a517ea8ef65787f11e',
 'a2a5c73767af3852d291',
 'a2a614abc2b38c1a2ef4',
 'a2a82410f25c5500a63d',
 'a2a8d439687b3d31e5ea',
 'a2ab759eff936978a493',
 'a2aea290d98c34c500be',
 'a2b12d26b380b0163760',
 'a2b4b6cd89ccba20dd4c',
 'a2b89451c2466e85113a',
 'a2bf449d4c579adb948f',
 'a2c1b9a87db1a5ba55b2',
 'a2c4875cf7831aff1a64',
 'a2c6bef1b08c7566e4a4',
 'a2c71c9d52adc317c900',
 'a2c745a45fa3832fb72b',
 'a2cbc8c04a609210434c',
 'a2cf1a0d152227bbf5cc',
 'a2cf7e206793a8e67cde',
 'a2d21cb27f2b0b74a6ee',
 'a2d2553ce8804f1c8285',
 'a2d499f0d4a038693a6b',
 'a2d4ebc77e7663ee93a2',
 'a2d605071123a6f9c195',
 'a2d925b97192a6e24f37',
 'a2da4f469c88eab725b7',
 'a2dc09a5c40babe0f1d5',
 'a2dc0caf3f00fb16ceb5',
 'a2ee505d5493f43b509f',
 'a2efed7391f4b0238b56',
 'a2f0f69052d39822132c',
 'a2f3c3ff84996264ce7c',
 'a2f451dc25c690ff03d8',
 'a2f452dc07a9dc2eb555',
 'a2f4f4878a50324390f6',
 'a2f546cfe99c86eec593',
 'a2f7847df546e857cf22',
 'a2f83cf05e82edb20adf',
 'a2f85bbf252255db0739',
 'a2f953ae254b7738d7c5',
 'a2faff3e5449072bc76b',
 'a2fee9b4db9795f0b17c',
 'a3027817ed904206db68',
 'a305b617f1317d9563c6',
 'a309e7603c23dead2136',
 'a30ada90f5ea222b8bc2',
 'a30bf8b00c02ef47ddc5',
 'a30d1e9ac2ea50999c60',
 'a30fc4a44265559459b5',
 'a312b4a4cfcb89033bee',
 'a3131bd4b9aff58265d7',
 'a31332ac6a2dabd6af16',
 'a31e10b1e1c5b0a3d686',
 'a31e6f3d7477ba7d3de9',
 'a326f12890eb06cf92ca',
 'a32b8f65d78f1b02e994',
 'a32d5011bc65b70b227a',
 'a32e8a2a974f83071672',
 'a33312fdec2d0b18b32b',
 'a3363d4f98c8aadb48db',
 'a337d02f76a2de36a885',
 'a33a169efc1d8d2bda29',
 'a33a3400c9b01bd936c4',
 'a33d92b4886a41dd7880',
 'a33ec8c02a98b22d0983',
 'a342265ca98027a40177',
 'a344feffec1004ece49e',
 'a3488a041b77cda7f260',
 'a34da82586f9c132fba3',
 'a35352eddf7467a1887b',
 'a353e20e81df19ddcb96',
 'a35807312d9eac5c9318',
 'a35a46d024c6e8aeaa84',
 'a35aa3ffb5aeef64f1ae',
 'a35b647bb052d16910b3',
 'a35e8d92c1c471d32534',
 'a3614475f19150cf9ac1',
 'a3629cc3754f8ae8b87f',
 'a3673953c9ba0be89976',
 'a3675683b30cec54d6b8',
 'a36b1ac4f1c6db4669af',
 'a372d943298c03c93fe6',
 'a3750b7d45c4479ae53a',
 'a375cfe246163fcd2dd3',
 'a377c388fba59c8b2165',
 'a37b790351f4c25af98f',
 'a37dd200e0d4b76fa7af',
 'a38028aa86378b311e18',
 'a381db6f78982ef7abf1',
 'a3852c555762e1cfc873',
 'a386e4dd881a1ac32723',
 'a3890399d506656b122b',
 'a39026e7e2a23a37a556',
 'a394977dbf39da127b1f',
 'a395cde7b4a3a99e563c',
 'a39a8f8fef7673892f60',
 'a39c1ff87b2195f2ca13',
 'a39fe1cb61bc73376fd7',
 'a39feb210430f008cf63',
 'a3a1d5a06901c7963872',
 'a3af6c4c6f799030adfa',
 'a3b2b083c4acfa77b20c',
 'a3b82751a10f3d35cbac',
 'a3b884a2234f3bd98133',
 'a3be95aa12e2ff40bc34',
 'a3c1213d28e116ec6f90',
 'a3c12d0d0d9347ea0e8c',
 'a3c50aed9f7df25ac31f',
 'a3c53a2d7e3c2a64fd1f',
 'a3c9b1be2926b42329f9',
 'a3ce916b8ced78df8b6f',
 'a3d0458b4732267775d8',
 'a3d28dd4c09f9e4591bb',
 'a3d47d464623a303294b',
 'a3d51148827bc05532fa',
 'a3d5224127e4d59955cb',
 'a3da92713ac1fdfdd1c1',
 'a3dd57b2caf56f4aa5a7',
 'a3de68bb0ffb6214657f',
 'a3e092c79f18c78fb0c1',
 'a3e4ccafdbad8c8bd6bf',
 'a3e4f7b3c8931db50642',
 'a3e773dcc490d2803fa3',
 'a3e78ec1d1bc63915ec3',
 'a3e9dad7fbfd8d3e132a',
 'a3ea2eac399e5dc706fc',
 'a3eb0ce0eeaf35286be1',
 'a3ee11500c482154cf9a',
 'a3efd57ce64c5410b6f0',
 'a3f91ef3cddc5c06ff66',
 'a3f98d99d43696756f5b',
 'a3fac8d59ee84ff82019',
 'a3fe5ca73f7d8688d281',
 'a401456497e772694bfb',
 'a4021491446d3912675e',
 'a4052eff7f9545e5e756',
 'a40564045472da1ff6b5',
 'a40e55d0c8305c435995',
 'a40e6aa0a2d29c31d590',
 'a40eae7856f8e279639e',
 'a40fcda1642c4d0ae912',
 'a41c02ebd5869eb6d7c8',
 'a41dcc95808cc30a618e',
 'a41f78fe3b31b242cf7d',
 'a42098c2f3eda8f0e0f6',
 'a420e39f6a348612af05',
 'a42315a26cebc1fd6617',
 'a423bc781b11c5cf115e',
 'a42b732f47153c608f50',
 'a42c4fcffed6d1a0b0b4',
 'a42f2ce25526c915e638',
 'a42f59cf3eda95d7ec11',
 'a431457820ace15c3c7c',
 'a43b7e7272c3592d9d9c',
 'a43bad9e7f4c3726b498',
 'a43c580227da7fe77274',
 'a43d0a990d250c21648c',
 'a43deb68169413ae004c',
 'a4415a8dea8c19c2ec9e',
 'a4417177e60f39196a79',
 'a4441ad27ab76a3a317b',
 'a448dd1c2a5c8ac9c1bb',
 'a44e53c68d52677c0e5f',
 'a44e5d2955f56c01f920',
 'a44f1d97c4c6881f370a',
 'a44feb6f674f059b6c5b',
 'a452992d90176e77e117',
 'a452d31f713fe90b794d',
 'a453f637c256a21f8807',
 'a45409e227fc6b945582',
 'a4560d1924581db49876',
 'a456350806313192c284',
 'a456de2d98436b57429e',
 'a457491555ca6cb794b6',
 'a45a5574759f6aa282f8',
 'a45e2ed1c7656d27de71',
 'a4626d7c4c7df4b825d0',
 'a463000b91438b786ed0',
 'a463bca93889ea9c7c6f',
 'a46422269a1c8213937f',
 'a4657f681356316de6ee',
 'a467ae11a135a955688f',
 'a4689fa3fc2d99eb674e',
 'a46a486e45a9c03a45e6',
 'a46c317fdc691d53d8db',
 'a46cb574267fe178aed5',
 'a4727103a85997834535',
 'a473c6adc1b00b8e21c4',
 'a47f3a75a01b6697d880',
 'a4813d5321133508de9e',
 'a48e26cbf617a0fbf81f',
 'a48fe0aded349ed05e81',
 'a491f8718214d11d39a4',
 'a49555b26bed4748effc',
 'a496fc118c1452b3d909',
 'a49954e07e9b5b37fa9e',
 'a49e98d4cb7308802cc0',
 'a4a3efd330205f822ff2',
 'a4a61357959226a9fa5f',
 'a4a7da02d166daca6b48',
 'a4b5ac6b6c4df8b1769e',
 'a4b8a2cb43f9fdc61c02',
 'a4bd8f4d20ba7b1e9f95',
 'a4c7fdd6f6faa0f36e0a',
 'a4ca416bc370a13d0d68',
 'a4cd340eb652589cb755',
 'a4d7e1c5c6505f57c96a',
 'a4d8d291c6fba92b3cc0',
 'a4da9b4595041079ceef',
 'a4e0c92c39e6e7836a45',
 'a4e130d78d40c0dcb353',
 'a4e6529e46712bc1a7ca',
 'a4e9c5b0652e385582cf',
 'a4ebbb6e38563349cac4',
 'a4ebe4ac763023547e48',
 'a4eec132479fd3871e92',
 'a4ef4bc10a98f27c8c96',
 'a4f0542b854c11e371de',
 'a4f1b9dce2b818573853',
 'a4f37adebbe818900a0c',
 'a4f6afdeb07762cb91f5',
 'a4f8ad602cde08c202ca',
 'a4faeb5f7bb0f770e132',
 'a4fc8d63325d644b1fe4',
 'a4fd54ff4052ff52e0c4',
 'a501fcce45a13a92b806',
 'a5020b892f2421cc80c3',
 'a5042216409719e67018',
 'a5063e1a12912cc583f2',
 'a50bbe1fd9e229813f41',
 'a50d5808ebe68f0d3acf',
 'a510a9f2d788ba2ac5ba',
 'a51de331b256444ecbc0',
 'a51f0472f9359a253e4c',
 'a526a566939e616289c2',
 'a52eb53718d4d8a96207',
 'a52f06740eba442dc556',
 'a532ffa97d6441ec9435',
 'a53327cb5632a5b2f5bc',
 'a535efdb922c01f04906',
 'a538bd65faa4bfbfc5fb',
 'a53c168b2bb7646f7f57',
 'a5405a5f77857a9aa3a1',
 'a5438ada68276692ab95',
 'a54492c075d91704661c',
 'a54ba8170351a7beb3f6',
 'a54c12df274fc41713a9',
 'a54ca2887be47d535259',
 'a54ef3f2f72434583df9',
 'a554561d1f1999606783',
 'a556903508da60abae47',
 'a5569b9891dfb2ff1bed',
 'a557af1d9144e37de21d',
 'a561b0ef5ab5ced89ef5',
 'a569f308554167fdf03f',
 'a56bd7bf0f50e6de79ce',
 'a56c1899528018765051',
 'a56dd3c9bc0daf735c96',
 'a570eb60848492b0d895',
 'a5770ec4b4df0186854b',
 'a57b96ca0171800dbdc1',
 'a583683dd6bfddd9473a',
 'a58fe91893fb15fa160d',
 'a590f49e9089102a5228',
 'a59ab8a067992856b65d',
 'a59b6dd5ba3578b645e4',
 'a59cffb0cd9add6a1791',
 'a59ffd782e9f7f0fdf6a',
 'a5a26ecd4c44fb43e02a',
 'a5a37db5f60d9d457a21',
 'a5a4d406151045b59951',
 'a5ab72f5ee9ba7239deb',
 'a5ab9a7919d68ae0e219',
 'a5acb1d1ab6c6a2e5f4f',
 'a5af3526a3147f9add59',
 'a5b037a59a7e94d08687',
 'a5b163a4788cb9a5cf0c',
 'a5b67b925d20b06b80ad',
 'a5b996f55d93c152d6c3',
 'a5bc7d598cc76a537d3c',
 'a5c25d498bc8dc9f844c',
 'a5c5ec037a39e67faa01',
 'a5c70d8f9551472f3fe1',
 'a5cb514c9970c110a78d',
 'a5cbc5203cade7a281ea',
 'a5cd0a86dcc144d473b4',
 'a5cd68517684004f811e',
 'a5d3c08035082c43f0c5',
 'a5d48b7e47d179fd04ab',
 'a5d5891e30f0802627fd',
 'a5d6c4204be33d30e45b',
 'a5d7044b83f5d1fd7505',
 'a5d9f5bb72cee9587076',
 'a5dcc1eb6dc209073180',
 'a5e3ed3eefaf1ef5fab6',
 'a5e41196ec472c4e44ff',
 'a5e4cba2a795acb9ad65',
 'a5e57691ec638af9a106',
 'a5e809ab0ba4a6f01f69',
 'a5eabcb97ecccebfa952',
 'a5ee92ec6c505568c92f',
 'a5ef7a70b4f7a6bb14f3',
 'a5f2821a708b906955f5',
 'a5f57f106cacfc49f8f1',
 'a5f67877c12083da6771',
 'a5f70da0372e62f62ec9',
 'a5fd163f26d3de459fe1',
 'a5fd20412414fe5612f0',
 'a602c6799c0e62095d53',
 'a60345da5c56bdec43d1',
 'a60918dbca84cd00f2a3',
 'a60a81adb5de33fde182',
 'a60eed35d6e38d82e074',
 'a613192824283da5fad6',
 'a6145c0f679865a859d1',
 'a614b1e59b9d498a87ea',
 'a61a20b5c2e9df5c491d',
 'a61c54ee08076eff9207',
 'a62335218c51493a877c',
 'a6246d707e212e711fc7',
 'a626e8f9e59b7b7eaf24',
 'a628c53181eaf19d730e',
 'a628e70d69b4773cc3ad',
 'a62c406705aecdbe4b60',
 'a62e45d39a00ee0fe8e4',
 'a62f7842707d03378d7d',
 'a6320268cd11be86b9e4',
 'a635dfe0a2b4f84d9806',
 'a63855996c4c027c1ecc',
 'a63926cc4075dd409e05',
 'a639f6cfd1e656325851',
 'a63ab166c6c6dc61d0d2',
 'a63cb466316f62816797',
 'a64069f87217ceefeeb4',
 'a640f0617cb322237c6d',
 'a6427b50275896c59fbb',
 'a642d0335a0e76b961d9',
 'a6447673bfefc6227a6f',
 'a64abea327d81d9cad68',
 'a6519022a6e1d6df9cd4',
 'a6564d62349cf35394f1',
 'a6566d70c256bf3c4571',
 'a65730b7ecec61032b17',
 'a6577d185f5de4a36f2a',
 'a65b5db3a402be24e8c1',
 'a65ba9faf848ffe02d04',
 'a6698d0ff912f69d1cfd',
 'a669979673153b964747',
 'a66acb52ebbf76f41cdc',
 'a66e4e238a2fe5734fb6',
 'a6737790fe7a38ed7b0f',
 'a675ff119db2f9ba7912',
 'a67a00634ba6e9128bc2',
 'a67a39ac54ab6de33d35',
 'a67b9b03d21441608046',
 'a680daf7a049fc8987f0',
 'a681463c79281127a00b',
 'a6816f4e8f3346aba091',
 'a682ad7668e3aadcc69c',
 'a686894284561378680d',
 'a686d167db706cc847be',
 'a68953b6faf3bf9bb73a',
 'a68c2f32a6a1ebc07fce',
 'a69092d092c5a261f0e1',
 'a6935e23bc80e6d4c449',
 'a695a3e5df2806a060b2',
 'a69be9314a345eebf544',
 'a69f0f577d193bad4ae4',
 'a6a11958de35a323d5bf',
 'a6a6f9c489cc38eab29b',
 'a6a829f280cd04169198',
 'a6a8cbd103dfd81905c8',
 'a6a9094d4a26c77aad87',
 'a6ac52970e7fcc35ee20',
 'a6b2a9ae719a44270273',
 'a6bef3f7b5eef338a076',
 'a6c0832a8d93bc4f19fe',
 'a6c288db7d917fbeff60',
 'a6c594a959bd8d0e8c9e',
 'a6c945ff927da59953c3',
 'a6ccaaf0b3d6b40a6071',
 'a6d4a86bbfa44aeb860e',
 'a6d4beefeeaa10ccb9c7',
 'a6d5f0c55e257ee4035c',
 'a6da28484c40953bd809',
 'a6e54169a9fd4bdfa110',
 'a6e6f4df8a21e1ec8ea0',
 'a6ea32fc7496eb14f114',
 'a6eb63106ecfec485e75',
 'a6ec13664eec736158a5',
 'a6eccebd6646e9b93a44',
 'a6f2d02d1015fb87a528',
 'a6f3efe1afef12e6e0d5',
 'a6fe1e6e69b5fd1cd6b3',
 'a700f63badb006823584',
 'a701c1fe71392eb2a602',
 'a70319ca4ac8d25fac0b',
 'a7056775292c2b8c3253',
 'a708445a808e72b4a7fb',
 'a70ac050eabd4ceccbcb',
 'a70b9e5edcc80f0c465c',
 'a70c529f30247a4a177d',
 'a713f37fac6aad64ced1',
 'a718abf12bf7e12f8748',
 'a718c75518742cfaa2a8',
 'a71f5f9566fd1f6f18ef',
 'a720d8a4d80fc628045c',
 'a7268a0b48299940c8c2',
 'a726fd99b1e3b864c511',
 'a727105f57eee0853358',
 'a728f24e1f8b7e68aa3c',
 'a7297985401a3939714b',
 'a72b2adeb75fef6431ed',
 'a72b9187556896af6aca',
 'a72c6f797bc15ca22c47',
 'a73060a818713074431f',
 'a7322629598b1fc664da',
 'a73638538f673470f7fe',
 'a7367e3e3da1d551eee9',
 'a73bbab828ce24865c25',
 'a73cceb935143bee15ad',
 'a74158ab88ca758c8c32',
 'a743362ac2d96f5dc942',
 'a74446206c5c76adf86e',
 'a74579f57503750769b9',
 'a7459407e68df4a49124',
 'a7465aa1b808559ca4b9',
 'a7473f78ab9c947d3dc7',
 'a7476ba7c30382d0acdf',
 'a7488a9b2b6336d4ef5b',
 'a74e1a2710cec1953028',
 'a7529049dec9e1a1b220',
 'a75463b3ecb294e98ec4',
 'a7551c75e0ddee82a4cb',
 'a757293bc5430137795f',
 'a757960d3ef04ca5826d',
 'a760498096b3e0265766',
 'a7622f693984fdd73d87',
 'a762cba33712ef93f5f7',
 'a7667be32af2b5b65fab',
 'a76d0bbc41289bd1bc16',
 'a76d3a2786e07bae6b96',
 'a76e9bed68628b99de87',
 'a76eb1c084182991b8b8',
 'a76fc4b1051a00714560',
 'a76fd1930b29abe4b04b',
 'a776c17ca6c256de2aac',
 'a778da52692287f947dc',
 'a77aa32322b7ba0b60a5',
 'a77c13da0c081b3110e3',
 'a77c73acd57cac3815b3',
 'a77e551abcf2960787da',
 'a780c8da8aeca88a29a1',
 'a78874d5f2a8a8e8d659',
 'a78b2f41654cb713e534',
 'a78b3f97efbcf5562cb9',
 'a791744d94460bbed4a5',
 'a792843386bbf6ab4ea2',
 'a794c4762431f0c616b6',
 'a796a44394be9520fd39',
 'a797f1d1b87eaef35d89',
 'a79cebbfa33f6111573f',
 'a79f8faee7545b6c345f',
 'a7a31238e4b7721b338f',
 'a7a7d001ac9eed514856',
 'a7a8615a6d12286244bf',
 'a7acb7c293a782e5a409',
 'a7ad3c7735c8ba6be4a4',
 'a7af7f020a6a3e19d948',
 'a7b3d2f2b77426e4285d',
 'a7b40c5009307ae57dcb',
 'a7b61d75db09ad1adbd8',
 'a7b80460c9ea28f1417c',
 'a7b8b15f87e05e5f078a',
 'a7bb861646fa80cda467',
 'a7bc552accf2ebcd23e1',
 'a7bcf46c0f9611851a7a',
 'a7be03562caed3f2fba6',
 'a7be30467d40d77712c9',
 'a7be4f4d4e37d5a916b9',
 'a7bf714be32b5943c6a8',
 'a7bf71f1562c76f9b438',
 'a7c018e88e592141350b',
 'a7c22e5d921eb2b2574f',
 'a7c6b2b47c6a772d1da0',
 'a7c8507c33736ab05c68',
 'a7c8581cd99f3f16c9b1',
 'a7c9ca32367dc66c07e8',
 'a7ce42d1979e3ecad64b',
 'a7d018711acbb0bdb765',
 'a7d58f1a152121650d3f',
 'a7d7c92d3791fb6301eb',
 'a7d8206d7141b35c46c8',
 'a7dac54db9cb3cf187f1',
 'a7dd950fb3861034ef46',
 'a7e4cc7d6ad17fa1ae76',
 'a7e54f3c9f162b0e2b9e',
 'a7e7977c1c26dcb5c87b',
 'a7e91b85ebb2bbd6a508',
 'a7eba07647c2448fa7b8',
 'a7f6523823511500bbf9',
 'a7f8831dc31bec55d222',
 'a7fd330bfc49b9ebc9b2',
 'a7fdeebcd3e9b7c0d68f',
 'a7fdf91f7f0d5c1a8910',
 'a7ff094471b8ea2fe027',
 'a7ff774a07fa874a91d3',
 'a8023e8253aeefa8f11a',
 'a80a88844ea9508e245d',
 'a80b594805ee437008e0',
 'a80d479bdb7ed43dc43f',
 'a80e793fbd109208b3b4',
 'a80ef2f8248a7a1f5257',
 'a8128ac72782e861914b',
 'a8179b2174f99458d945',
 'a818df067ed546402c11',
 'a81eea316f3c26a958ac',
 'a820a1f0a6ee0a250420',
 'a825c50d0869bb728cb1',
 'a82606339adc345f5027',
 'a827e6e8aa43dbd70f3c',
 'a82816674502f2fa376f',
 'a82963afc289e47c0004',
 'a829c7305146e393909b',
 'a82cec441667f252a1a5',
 'a8318f5075dd3cc6f5a4',
 'a8337bc90fa5c42824b5',
 'a8359684c68604c3adf8',
 'a8361d28f99f734d50ad',
 'a836c7a8a8707adad61b',
 'a836df02cee5364d552e',
 'a83d2cd128c754903de3',
 'a83d8a03d6ff4dd29c87',
 'a8406f28d38ed1714df2',
 'a841970b3a9b18b0ae09',
 'a842859decaa8fed8fcd',
 'a84387b7d92b074982a2',
 'a8451655eaa0aa18151d',
 'a845cd3c45f8727cc3f5',
 'a847ab50610f1a447290',
 'a85e4a6fd14454215082',
 'a85e6d622e67190864a2',
 'a85f48fe8a3f041cd97d',
 'a868fd7f3a8b220dcc90',
 'a872b3e146623c3d288a',
 'a8751c5eb59872bdbca1',
 'a87753e82adb9b07e297',
 'a878744404a55e8f65d1',
 'a87d649576979f0189ce',
 'a87f3914e5918a15d958',
 'a8862b9f0c49f1b9feb8',
 'a88ba910ae69cef9948d',
 'a890539b9d09505b0f23',
 'a890af2a42e429423cb1',
 'a890ffd76ab08a0ef274',
 'a8914c10409d8e394abf',
 'a892d069fd8f7289bf9f',
 'a894a93aeb9626e18289',
 'a89a0548e4871b90b6bc',
 'a89a8c0cb8c31d95debe',
 'a89b7212e2d39f16dfa4',
 'a8a6ba8bd5a3abda0d4c',
 'a8a6c0cfa1a0f683fdb7',
 'a8a7c79e48851f53c8be',
 'a8ae0de4785412e3c681',
 'a8b071ee4b89a540a3d6',
 'a8b1b1954acdafad40d8',
 'a8b31c3ea157c665eed4',
 'a8b58aa78c9d8215ee39',
 'a8b7cef70be2cff0c481',
 'a8bbaa5bb35bb1f58063',
 'a8bca982fd86d630339a',
 'a8bf3529eddf484c9ba9',
 'a8bf8bb748d848e60199',
 'a8c10e9b8787ab5caaaa',
 'a8c7e4bbab444f3cb9ba',
 'a8c94da284a82adaa1fd',
 'a8cc874002b771ba3b19',
 'a8ce37ed39fd9221be96',
 'a8ce535425f304df67ec',
 'a8d4c76f5d0bb039bd4d',
 'a8d64fb246e97c154f39',
 'a8d6ead217caa8942a93',
 'a8d942f8d24a0c38d02b',
 'a8db0af80675696206a4',
 'a8dea8f6b088054b214b',
 'a8dfcfc91b5be64d59e3',
 'a8dfd23b6fc2b571a2c8',
 'a8e321056bee283d2016',
 'a8e35afd5709658de69f',
 'a8e36e9a671983035e12',
 'a8e47315351a12fce212',
 'a8e52d3f6570079fd1dd',
 'a8e6b02e403116426b1a',
 'a8eb001e2a7e41bd1792',
 'a8ebf164c5462fa8f46a',
 'a8edbc4c71274cfdaa36',
 'a8f0448af75e3c9ca328',
 'a8f4327211e923b1d40b',
 'a8f49e519f12c6f42848',
 'a8f6ff6ed2628096fe5e',
 'a8f86530fa6e83b30a39',
 'a8fa8ed4ca1ef46f3f08',
 'a8ff410f968e0369dc22',
 'a900dd87a8d5551b626b',
 'a90235a1582fc6bea671',
 'a904488c5fe45ca1a20c',
 'a9061916bfb826013139',
 'a909183d918d18c3617e',
 'a90b8d2b50df089103c6',
 'a9106e03dc16f68c52e5',
 'a911379257ec998cffe2',
 'a911bfff88d1b57b75cb',
 'a915b9716a8d7c350461',
 'a9162edca72c3024d889',
 'a9164544bb1563b9304e',
 'a9205931018188fd07d5',
 'a92173fe6c7eb706b8f9',
 'a921d687ae2a4340e1aa',
 'a92e27de80afcb92c284',
 'a92e756937fd72f3903b',
 'a930a15d26adde5c7422',
 'a93680cbed03fa825809',
 'a937e6109ade1f59c3c1',
 'a93836d864b9b80fa1a3',
 'a93c8e43e016e08d7842',
 'a93f0023561c634f464d',
 'a943b6810efa6dd13741',
 'a94758efc8f0821700e1',
 'a951d13e1a028aba5e6b',
 'a9538df12e86cd080181',
 'a9543cb4c70322fd45e7',
 'a958d1793d26360e7ada',
 'a95914c04ba31f174d2e',
 'a959b7901d74b5c0cc88',
 'a95b0b3de54afb7dd201',
 'a95c20bf4ece3d89075a',
 'a95dcac0962e31b96ffb',
 'a95e7b433560e7ca6a98',
 'a95f077f2a467b205aba',
 'a961d24e2557f659288d',
 'a9642f685a064d5e2f77',
 'a96e906d9446a380a818',
 'a96f694352f5624f728a',
 'a972dac7a5eea9aca7ab',
 'a97515fa42f305c145ee',
 'a976fb3c652aef575fa4',
 'a978276e0897988ea0b5',
 'a97a94add2a81be0bb30',
 'a97c5e9a4dee80fbd5c7',
 'a97e2f6885afcdf49067',
 'a97e38e2afe185bab555',
 'a97ea07f64a83b1f7b45',
 'a97f0f4d546c28c0dc7f',
 'a97f921aed362a613c1d',
 'a98566304d8342f617df',
 'a985cfe2f6c25ddb476f',
 'a98747576d37deb5c15c',
 'a987b941b4a8fe24294b',
 'a99299f636abb5154400',
 'a992a8b08cab6dc99ead',
 'a99411dec55ee83b2d4b',
 'a9989317d3c1e4c0c6b0',
 'a999e3857a0dfbcdaf57',
 'a99b0c73abf90c3a2144',
 'a99d79fad7705eed9bdf',
 'a99d9f319cc2ddc4086f',
 'a99f2d84dc294153bf0c',
 'a9a7789adbf9ec61bdcf',
 'a9ab92eaaff9eb0e1906',
 'a9ac8c008e86ec36d67c',
 'a9b06ef7319d025e0ce1',
 'a9b36c4f99e6edf055d2',
 'a9b483ae35ab26595c15',
 'a9b67f19d12529ea5669',
 'a9b73a6cb6c2ba9176fe',
 'a9b7e906963fbdd8c13c',
 'a9bc142f7d9247945f35',
 'a9bce74908f44d610c9e',
 'a9be34724823d33ea03d',
 'a9c364bf55b698f4acc3',
 'a9c61428750bc53296c2',
 'a9c692ecadb3bfef3681',
 'a9c923f3bd6d1ad3bc45',
 'a9cad92571cd15655a78',
 'a9cb734198dd012758d5',
 'a9d35e01a62412a75aa9',
 'a9d73bee140e5dcc346d',
 'a9d8178733e645f0fff1',
 'a9d8b74ba312393aa184',
 'a9e0582ca58ae7b82397',
 'a9e1df7f0b80342f7121',
 'a9ebccb2e58ce96afe7b',
 'a9edd89dbb942dd737f3',
 'a9eeeed3717265ee5f6f',
 'a9f0f99cd37897a6885b',
 'a9f525b499d80cd09828',
 'a9f608f33566d5895ef0',
 'aa0058efcb669cca276b',
 'aa0203b1b80eb955a3ea',
 'aa03a2d84f6aa6d66ba2',
 'aa043d1506743c470ddc',
 'aa04537e2f7f5d0bbbad',
 'aa04c44fe4d766f73070',
 'aa06ce94383501916a27',
 'aa07c602e83ceae7e674',
 'aa0cf95bfc58c916c1c0',
 'aa0fea0bb59410c82638',
 'aa14f05cfd7723c18d20',
 'aa1653959db3977de863',
 'aa23e04ed14d4c893ff9',
 'aa25d36027ac0c2b8727',
 'aa3454feb9efe93a8860',
 'aa3bb521ac70df7b8b9e',
 'aa3d6a2b66b6c95d401e',
 'aa402211e0a638f5af82',
 'aa402261e588f9c4a957',
 'aa403916f22e4717d58f',
 'aa43fdb99096e7f3175a',
 'aa480b1384b8f4706a62',
 'aa485efbc4c10f5750b7',
 'aa49cb10028ffc57b49e',
 'aa4d545b951c422399e8',
 'aa5232a05d2d0e102538',
 'aa53f7c5564028181fe4',
 'aa5407231c128e08bcfe',
 'aa566e8cbd0882ca0d52',
 'aa57ca7c0f4d7654b756',
 'aa59a0dd9d66b0adcc3b',
 'aa5c9524a046920c3eaa',
 'aa61b3f0e82363b8973e',
 'aa657092331f5c2d5cd6',
 'aa674340fc1fa7372d2e',
 'aa67886d4640aebd93d0',
 'aa6acc1dc460e602f4c5',
 'aa6bd03f7a610f7e7cab',
 'aa6e0eea5b5d376a32f7',
 'aa7091c58d80a10b168d',
 'aa7108b38c377960d595',
 'aa78c6776afcc0b5a246',
 'aa7ca8392603b8a2bfbd',
 'aa7ef00cbfe8898bfbdb',
 'aa818c76a2259d5daee9',
 'aa8632561df8176761c2',
 'aa8914cf77226db69d24',
 'aa891f2b2f833b30b3bd',
 'aa8960c236373d05c7e7',
 'aa8aeb68145fb712f320',
 'aa8cc3ba73ddc1a1cca1',
 'aa8d592a17af94d1403f',
 'aa8f903dcf080d2b15ad',
 'aa9089ee80772270bccc',
 'aa9385cba65b527a26c2',
 'aa9627e6d5f5ddf0f8e3',
 'aa9a0aa1f8c26b34ac90',
 'aa9aa663d22c3247ef4d',
 'aaa25e2602ab02d26589',
 'aaa4a1b17cb43980a567',
 'aaa999835758da39ecf7',
 'aaaa6371811f797d40f3',
 'aaab663c2b3feaf986c0',
 'aab1f987d5a06f1143c8',
 'aab3d721b5730b42f63d',
 'aab5686d7ba0142ad273',
 'aac4ec01971e66aa4098',
 'aac6e83c48e6f12c7be7',
 'aac84fdd10206d6cbbc9',
 'aacf59446e42459268d2',
 'aacff7c194b866c9ed4e',
 'aad0a75a01ba842204bd',
 'aad4c5ae5aa763680af7',
 'aad73f9cefbebd407d06',
 'aad83a1e8b7d69a513ff',
 'aada0afcbba179efc43a',
 'aadf6428fb9fcdb66fcb',
 'aae05d19f322cf4bf82f',
 'aae59627a7c7ccda6432',
 'aae5fd45c5ddc51216c3',
 'aae60f47d2557017b07f',
 'aaec70b01a5143a3579c',
 'aaefef9d7bc019be2b43',
 'aaf2bbdd60866cc31aa5',
 'aaf33d16fe6db5545d54',
 'aaf4c77b4f2454810d7f',
 'aaf9226e208092cae225',
 'aafe3afd33cdef635472',
 'ab00bce6fa9ee43e9c7e',
 'ab05cf3583bea229eb66',
 'ab0917bee95c89ffb8c4',
 'ab09cbe2609b142c6141',
 'ab0af54b64b4debe1bd4',
 'ab0fc6e8719fe14215e8',
 'ab11a3d8db0a61545cae',
 'ab16db47ae6749c0706d',
 'ab1d49cb0246da86f6be',
 'ab1f97fb44621b3269a6',
 'ab253819182839f30258',
 'ab2afd31c32ebc3de5d9',
 'ab2b6f74d43894a3a879',
 'ab2c4e135e6286ba94f2',
 'ab2d9782db5d4abe49b3',
 'ab303890ff0ef0e9b847',
 'ab30550fbef40f9020fa',
 'ab338756fe443d21a295',
 'ab33a5b06ec341babef6',
 'ab39b2554d343be2e90a',
 'ab3e24f75c1d40f0d1e2',
 'ab4000af41a483f328e1',
 'ab43daa979503bb6829e',
 'ab458ceb1251d385dd93',
 'ab4613da85bacd06d740',
 'ab48f93ba9dc457a5b89',
 'ab4e6644799d555fbb65',
 'ab535e15971890a86fc7',
 'ab54b952e52bbb0ca5d0',
 'ab5af300b8bfa916cf43',
 'ab5cf53935e0777916cf',
 'ab6b892f4a6ae1be1b99',
 'ab6beb35b5b3e6e544f4',
 'ab6ec45570a1422b4259',
 'ab6ee3c505045454bf7c',
 'ab6f693f6f9be7f7d859',
 'ab6fbf70a893cf631466',
 'ab7000691aa274306ed8',
 'ab700b2b06f5bdea78bd',
 'ab72c3f223340ab2b919',
 'ab736ad4925f9f0a64f2',
 'ab7d90563209eb56122e',
 'ab813177f02dafdd096e',
 'ab8a880764be91db62dc',
 'ab8e669cd9f356106b46',
 'ab8f6a81a0486e258e2e',
 'ab90ecda073ef79b40a9',
 'ab93a6279fe8277192c1',
 'ab94a702f9389ecfe027',
 'ab9b93286430043e9288',
 'ab9e86afaa0185612969',
 'aba5718745d498cc9b2a',
 'aba8ff4fa69f6fa62bdc',
 'abaa362ac21f11101e37',
 'abaab179266b0203cfa5',
 'ababd53e5719d4a03c3b',
 'abad93a3220ba554d496',
 'abb1d94b413b5883ac2f',
 'abb35d39266a72d3abef',
 'abb69d39f04ce9eddea6',
 'abbfc085e483b25bc92a',
 'abc027272b0e57885c7a',
 'abc029952081540e5a49',
 'abc034703b801ec98983',
 'abc24e42280042f61b6d',
 'abc35dc650684e155da0',
 'abc4a1d58085ec79c4a3',
 'abcc7bce590958c262ab',
 'abd12196c5f7eeda12ca',
 'abd3377e954b8518ab95',
 'abd49813ab3775859c21',
 'abd52faa90b785e5bde3',
 'abd5429e9cf5f8f19653',
 'abde0c86dc24a826aeb8',
 'abe4092f8d6b642ed81e',
 'abea2ff6920c85615f07',
 'abf0d05642cafb65df57',
 'abf21f0d18e9887d3176',
 'abfb2e46e95acce0700e',
 'abffe36d4fed832a40e4',
 'ac00af4baa3165401cab',
 'ac0250be203973a9b05e',
 'ac0ab73f0eb696c47211',
 'ac117c0a083008a70c61',
 'ac126478b748c62f2fed',
 'ac130106ca50bdc8f741',
 'ac139ee4deed0f0a701e',
 'ac1571c470b695b1c044',
 'ac1854b76ef5535c51e7',
 'ac1e43ca203fd71951c2',
 'ac1eff40b67dc16e1407',
 'ac1eff6072a095450343',
 'ac23a3853a32b1b0194c',
 'ac23a6167d027649e8c8',
 'ac26b1cec552c9228595',
 'ac2ea70dcf6aab1c8a63',
 'ac2edb671c692bb744fb',
 'ac2edd6a2a9dd4342d0d',
 'ac3019deedf2f90f8ee9',
 'ac301e8e2d64a2e6d550',
 'ac31186f34047c872de1',
 'ac32e27778a760d132ea',
 'ac35611fc241c8d95719',
 'ac35829edeed1a145334',
 'ac364e42d8644ef50b13',
 'ac369fab36e0da318da9',
 'ac3a551f8e259fab1d44',
 'ac3cdcdea9fc67af9074',
 'ac3e30a85633360bfff8',
 'ac3ee595eff57a0b22e9',
 'ac43ef767fa955b8a6bf',
 'ac4567bef87580481e63',
 'ac461208f52cd24b8b85',
 'ac4844bb309979dbdb3f',
 'ac4a02af59be701e1927',
 'ac54027d66c71851d7c7',
 'ac5446db96a215b98a5f',
 'ac59ff2e9254cff2ced2',
 'ac5e0eb30928938c9c91',
 'ac5f4a40730607a35ecd',
 'ac625b4d66a479c3a382',
 'ac62850bcbdd938ed724',
 'ac65fcda343045418116',
 'ac676df3c665d3e58a0a',
 'ac68f029ab55187fca61',
 'ac6a2a05b2d98768e970',
 'ac6ad229d25a6b5ec2cd',
 'ac6b2d7ddb3396246bac',
 'ac726cd15c15f8979eeb',
 'ac72bc7bcedca37ad463',
 'ac7ba10ebf1b52c09f39',
 'ac7c7b481cc1b2caf75f',
 'ac7cdd8b64c5f72611fd',
 'ac8115a6582c502afcb8',
 'ac871f383093012d5e91',
 'ac8820070496bcb658bc',
 'ac89ca4069e5b54af3f3',
 'ac8e642b4e3842e1175b',
 'ac8ef31fbe9273add5b0',
 'ac8fd49258ad2c4a166f',
 'ac92c7a13ab9d2eb8cc1',
 'ac939e60f2f599f18e41',
 'ac95a93ab75534a44a8d']

# %% [markdown]
# 17

# %%
qids_17=['ac97a0b565ad43f6133c',
 'ac9f274dad355b13489d',
 'aca116cbea10c80e6669',
 'aca35c334b1f6520b873',
 'aca48baa036cff39ff61',
 'aca603baf88866914943',
 'aca6f1ff3dcbf307fbed',
 'acaac1546e3def7abfcb',
 'acae77b914b8c65427c5',
 'acb02e76947861a994ef',
 'acb3181880790cd33c74',
 'acb4a6d9863dcd1a8bb5',
 'acb9a6293f8a02ffdbdd',
 'acb9c57348cdfd172afd',
 'acc41d78b94cff17f20f',
 'acc75d85b5ac66bfeeb3',
 'accd852e6c3028fd7292',
 'accde45f4500197117cd',
 'accf421cba269d45afda',
 'acd00fff91628910307c',
 'acd6c39b2cac5fd27348',
 'acd722ff46f15ba2d83e',
 'acda51cb135db072a06e',
 'acdc0744dff7ba543d00',
 'acddcce6fa0f29620831',
 'ace37412ba9cbc47073c',
 'ace5741e856d1e88b33c',
 'ace68f1878345504ba24',
 'acea7ddbadcd02880fc1',
 'aceaaafc766d3b366530',
 'acee35443d61367eeafe',
 'acee63ee61a4cd16a51e',
 'acf2a4c4d11ee59eb685',
 'acf5789064c4379d9427',
 'acf63a0d60c599458e46',
 'acf65dba0ea727b7fcd7',
 'acf7947317adc290ff1c',
 'ad02140be906e7b7b9fc',
 'ad04d1c2da2d963c61e5',
 'ad087d4b8e7818a78362',
 'ad0ab60258b15eb9b148',
 'ad0c6a7b8dd7475f9a10',
 'ad0ccea2c97e40a02673',
 'ad0d7d9d48b61f6dbfb3',
 'ad0ee15aa3da0b078541',
 'ad12552ca578c1563040',
 'ad15568f416c6b87a2c8',
 'ad18629b756b666c71a7',
 'ad1b13f3905f11c11315',
 'ad1b6d781c92d8c27603',
 'ad1c67914927e71dd827',
 'ad1cf9aa1c18dd84318b',
 'ad207b10d4a23971d3ca',
 'ad20dc7d634e49ac5d93',
 'ad22875642604f7ce2ae',
 'ad2319b2fdc8cc0c0557',
 'ad2324c4607c1325b2a1',
 'ad2a88feb4b6ecbd55a6',
 'ad2be9157921eacfe132',
 'ad2c2071c0b9d3069532',
 'ad2f317fded1ace00f13',
 'ad300ec3930296cd6339',
 'ad3757bd26b4913f6a71',
 'ad389f141ec0e4ed4d74',
 'ad38d1ae9dc1e48cbbd1',
 'ad3b2e0027a52f5df286',
 'ad3b5fe61d15062a6846',
 'ad3c3fa51856c58d54f2',
 'ad3e35be4d8f5a3d43d7',
 'ad3f31a3243d6d9dd589',
 'ad3fccdff3caff376cf0',
 'ad41872cc7da5ce58143',
 'ad46a135b8aed4324ef4',
 'ad4b5fb2066d09fb8bf9',
 'ad4f32f772e596fba23d',
 'ad5519dc8a02fb196072',
 'ad58d7130be608162daf',
 'ad5b5f162ad242545236',
 'ad5d7ce8b09e4927a098',
 'ad62ec21564d3775e8a7',
 'ad685d1392729cfb7f5a',
 'ad711ac98c60df0716ca',
 'ad75600736f60940a3f9',
 'ad77bedfe25c3374f234',
 'ad780f6b4534b69914ec',
 'ad7939df35508a6eb4e5',
 'ad7acb814a5cffe5381c',
 'ad7b036c7189e99a3397',
 'ad7b3d2ff1e7f2cb7b49',
 'ad7e719c5b1b7398e61f',
 'ad7ecc14bb74f44c5ddc',
 'ad82d5b008dd2f9d856a',
 'ad87c2d3e8951fc8f3ef',
 'ad8a140254d0b2adfb9c',
 'ad8d88c188b2ca4b5215',
 'ad8e35caa36094e8aed1',
 'ad8e6bd2c21378893e17',
 'ad93ed4de1122078854e',
 'ad9631add3bf5135757d',
 'ad969444522e1057c5d5',
 'ad986cc0a5176e522339',
 'ad98c7c5ac0fee98885e',
 'ad9c26a5b3c012b8f938',
 'ad9db04de20e1a94fb0e',
 'ad9decb84d7a4cbacd98',
 'ad9e530242ab88ce4533',
 'ada3817a92c8992e8a48',
 'ada4dc920fe994bc741c',
 'ada736dd570babe6de40',
 'ada94148dbba96d6519e',
 'ada991a49059dee26992',
 'adaa6ba78eeb07c7ade6',
 'adaa911286ddd001e6cb',
 'adaabf41febd21b32248',
 'adab8392487ca82c1dbf',
 'adae51ead8b7eb8b1cc8',
 'adb7d09e075a8cf7f212',
 'adc0061e896a9ea4869a',
 'adc8f231f74212d650b1',
 'adc92d1214ebde7f323f',
 'adcafa942e40ec96ca65',
 'add001b36da10000d02a',
 'add46fa2d9f48eeed939',
 'add68b56598e2ad7b679',
 'add7a822918899250b26',
 'add7ddb61e2e7db76a88',
 'ade531208aa7fd7a969f',
 'adebeba579953b10d96f',
 'adf0f271b290abaac5c0',
 'adf1a05198a1ea71d91a',
 'adf1ae42551d02f13a8e',
 'adfb87617cc219819f89',
 'ae020fc2c0b35126291a',
 'ae02140ef0af02fc4293',
 'ae02f49ad01e17e6cda4',
 'ae0307cb8fb12417586f',
 'ae0442d93828a8a79eb1',
 'ae0873edcc74a67665ac',
 'ae08b0e66f87588d6cff',
 'ae0a24ac7ad6ed65737f',
 'ae0fec7650fd7ad0fa62',
 'ae1aa5a57db7be555922',
 'ae1aaf913616afe7486a',
 'ae1b735562d2af804bd1',
 'ae1d5a59b76a31397400',
 'ae269735f99a26e7b826',
 'ae2ff210bd521101d759',
 'ae32bedac3ac5f76da7d',
 'ae34de18a808b32a6217',
 'ae3c267350fd40a33243',
 'ae3c92f6232792f8f91c',
 'ae3d09a6a80323ccd4b0',
 'ae3d74e9253c224637ff',
 'ae41b5243c249b2c09d8',
 'ae42c599360a00a18df9',
 'ae466e8c0dde9fec99dd',
 'ae4682b7ee817375acbf',
 'ae46d4914fb9214addda',
 'ae4a0d6363e9f242185c',
 'ae5075b315888ff565db',
 'ae50fd7b35afd78a508f',
 'ae5173fef9ab3d4d16e4',
 'ae51a436114be715359d',
 'ae543091d1e60d9bf4e2',
 'ae546c911562bf0f4309',
 'ae55d93be0935ad98fc2',
 'ae57aa8b196b95d616af',
 'ae5f90f61f352f2284ae',
 'ae617832a1802edb98a0',
 'ae6246162063579b2e8c',
 'ae648e9470314c908912',
 'ae662db730944bffc3a5',
 'ae679940962898fa5d73',
 'ae6967d86e5e6d5a1de6',
 'ae6a8160ae5220e8cace',
 'ae6e82646e01db521a20',
 'ae72e635fb06fa40637f',
 'ae7870ccb161a959e781',
 'ae792921e419a3e2d764',
 'ae7aac6974aaf562dcaa',
 'ae7bd3e3fd3001f2bb3c',
 'ae7c4d1bdf9f388fe015',
 'ae7d58d0559a2e64db4c',
 'ae7ea183548dd73e0fbb',
 'ae7f4923b86f78df2cac',
 'ae80df089aca53b3a483',
 'ae814782aed925a357dc',
 'ae82363175dfecdee471',
 'ae84d56583c3ba153efc',
 'ae866bfa1ef301cb92ca',
 'ae878c9c03c53a7b361d',
 'ae8a0a02c9035cb1738f',
 'ae8a0c68a7fb25bd478e',
 'ae91ce6e000061b3f3ec',
 'ae9d02ce619d17d25f55',
 'aea0a28de2930ae07c65',
 'aea442026953260ab49b',
 'aea5f50610cd2c6a2270',
 'aea81cc3a4ef3f295fa8',
 'aea9cc6ff7056f6ab87a',
 'aeac15bd9d992b9df375',
 'aead0f3df855fda2ae18',
 'aeb34d656fb4d81aa74f',
 'aeb360dbff2b8f16fc0f',
 'aeb529b827a39f288160',
 'aeb6040678e2f7cefb45',
 'aeb6e03c7ef08cfbe772',
 'aeb6e99adfbd076c8639',
 'aeba165746ae9bf18c6a',
 'aec398e4f56c6a043b0e',
 'aec62bde674652dd522b',
 'aec64b3139cb02283fd9',
 'aec6a60d603ede930548',
 'aec6c9b5bb6973e92ec3',
 'aeca8a545c1bcf98e527',
 'aed504e0840303f5bb0e',
 'aed684d5932c99f1ddb5',
 'aedcbd748070c034e988',
 'aedf4a104af105491a32',
 'aee05e9ae88712877abb',
 'aee11d0bd12054bf0d1c',
 'aee2e041de3139b689b4',
 'aee47e99d8d1e71418b2',
 'aee4cfe893150a80c201',
 'aee9a018b82c972c9d41',
 'aee9ffa325971dde89f8',
 'aeef82e8c01de088158e',
 'aef40c08c55bcf2f15c2',
 'aef47b8388b9c872703f',
 'aef6803247762114b302',
 'aef8e87ef1815e63b29d',
 'aeffdb1c85515541f881',
 'af005c3977c93fe48cf4',
 'af022a94ec6596548032',
 'af0304c30df8f9892309',
 'af08e51ed7fd6da56e84',
 'af0aed2e34c27517f5b8',
 'af102fb333d968357549',
 'af114dd0f2b912b8e79f',
 'af15d5d5600009ac4638',
 'af17591ed8bb6c4fa8c2',
 'af17f2e1f919eeb703c0',
 'af18e6a2442c83a1d798',
 'af1a7ed22f844c419d9e',
 'af1c09e8cb86ba9a2f2f',
 'af1f60f5a26d02f64b32',
 'af225600647255448d79',
 'af23e2f3a3b19137d447',
 'af23f5da985810cb1494',
 'af287bb2d7ca22daedad',
 'af2b37cbdb201b27f8e8',
 'af2c7e41fba07948d35f',
 'af2da1022a0b7da747e8',
 'af2f276ac8799538070b',
 'af2f7c6a908d115c4607',
 'af343af9d370dec36963',
 'af382fa140b93d42e49a',
 'af3c4950e901ad559580',
 'af4076508e8051ecdfcf',
 'af4206c45b959c4340f4',
 'af436bd8ed22d762fd08',
 'af46ce204db946cc7f69',
 'af4a5e354f12ea2ef56f',
 'af4a94483fd5aa05a9d7',
 'af4ac4e7da67d934b891',
 'af4bad13474dd33652f4',
 'af5299d5c1f192569c97',
 'af55299274794526ba5f',
 'af55c3ef47e6a8f9a0a5',
 'af59c5edcefc88be8614',
 'af5a642777687670162b',
 'af5b0a3822e760ea75dd',
 'af5bdc4e6c1a46a1d2a3',
 'af6175a27707a094e0e5',
 'af682af18deca904f9f7',
 'af68dd17c62b516d0657',
 'af6a4ea1ce0448ca3c58',
 'af6c224c5c7725f1e98b',
 'af6c94a8a38cf18a6c83',
 'af742f555550f3626948',
 'af75d171016c58a39c6f',
 'af7816a8ea39dbfd4de7',
 'af7c62b8c452a7bbc2b9',
 'af7e5892fdf9415dcbe2',
 'af8115a13c6dc9fa59c8',
 'af817a6102dfa8cd800a',
 'af8ab0cef7c566035244',
 'af8c8b06063a6c70d67f',
 'af940ffb75d5249480e6',
 'af97026d23c7afb98eda',
 'af9a0c3ce88637d345c4',
 'af9c165e2e91a14fb8ba',
 'af9f9b141b5dd110ff85',
 'afa0491f1086716e86f7',
 'afa056c88a69cf92d8a8',
 'afa19d07275c681ee286',
 'afa64eb1340878986a3b',
 'afa8d4facbfafd7af920',
 'afaad17441ec64ee99e6',
 'afaec3b195e7f5316606',
 'afb16e0526ce28fd2ba9',
 'afb47d531e0573617c9d',
 'afbbafd3d759cdd94879',
 'afbd5e48d4e5af4bd811',
 'afc1bc7ddce0775dc3ed',
 'afc2d2155c3922e591eb',
 'afc5764f540daadd2f14',
 'afcda46b8d4d0602e735',
 'afd0b3064a21a3c0919d',
 'afd1e04bc741afe73d44',
 'afd506de944ad80b29ad',
 'afd5efbca36c02e62003',
 'afd88d97eb4cc84950a9',
 'afd92c44212205b396fe',
 'afdb8dc8d3cf3e6a3dc6',
 'afdd297408e66608db12',
 'afe17b4eeb0761913d18',
 'afe3ec1f14b3bee6373b',
 'afedbf94e10669f86737',
 'afef2ed20eede5e2375b',
 'aff0c63dbc5237938351',
 'aff245926cb656c15aa0',
 'aff25097e162ea76098e',
 'aff7fa471c51a0fd2782',
 'affb2d666329d2544900',
 'b001e2206d9f28527a8a',
 'b005615684f523729fb5',
 'b00a9545159fc254527a',
 'b014545af215b1b2e488',
 'b01542f54587641b2eba',
 'b0184dcd798e85da1daa',
 'b0207835392eff3f979a',
 'b020d16f4dc0fb925d46',
 'b0264dcb7d5be9463f57',
 'b02c96e99d8bdf3744f5',
 'b0324bd8dc0a4165f578',
 'b036703614db01c4a647',
 'b0374173dee60de0c698',
 'b038b8bff21a797be146',
 'b03be5654b467b83bdcf',
 'b03df0e3f106b85c949d',
 'b0426b5c0edc567a186d',
 'b044e40322dc68879cef',
 'b0450ad3e5fc484a5f8d',
 'b0464e63323d9bc2138c',
 'b0484662853b5c808612',
 'b048f5f2bcddcba6ce45',
 'b04c93a626d0da360ba1',
 'b04d23eb50148ccf8d84',
 'b04fb127223aac841c1a',
 'b05391c1be5d82e56a4c',
 'b05685d5f97f98169e09',
 'b05e232de74de709e9b7',
 'b05ecebc9cbaadf73e42',
 'b064b8e77517d9f6f367',
 'b06756d8e3db7488b5c2',
 'b06c02b95d4e267441c7',
 'b06eb08d9e2358a32d4a',
 'b06ed506ae102b861f43',
 'b06f4d939fbfa4880559',
 'b0711787933f9a8e0e07',
 'b0734cc7b603528bc988',
 'b07542cd6a757b8b48d2',
 'b076e65f7d2b44dc59aa',
 'b07b2b21f90c5bfb2842',
 'b07e1b778ebe5a306b70',
 'b07ec0d18111d57694ae',
 'b083da457583ea359fc4',
 'b08566399004f5f183cc',
 'b085c7336c0f95617177',
 'b0868e99899593688063',
 'b086c42f0d860ae87f49',
 'b08781853efea938eff4',
 'b0902902d0af9b6a33bc',
 'b090655fd275e4484d52',
 'b0930faf21bcf651726b',
 'b09590b0716acdade25b',
 'b09755bed464e7c5e29d',
 'b09ac72071c08a1bca97',
 'b09dae182d40796f8ec3',
 'b09ef6f21f7a109a6047',
 'b0a2d5dcf7739d8ee060',
 'b0a77bb8fae48ef240dc',
 'b0a7c1ddf3b7dc15601a',
 'b0ae912d202347816caa',
 'b0b4be6c7d81f4cac3f6',
 'b0ba26d7a73736aa92a3',
 'b0baa4c89954d6ae6e08',
 'b0c056874078e91eca4a',
 'b0c2ba9f71a03ca65db0',
 'b0c4e97784a86c79a4a4',
 'b0c627402f1be56a0ee1',
 'b0c835b195fa295387f3',
 'b0ca2ef2c94dd61d957f',
 'b0ccac907e936d179055',
 'b0cd17e903d01f3c3907',
 'b0cd332e63315287f204',
 'b0cdbd55e2f0d0098b74',
 'b0ced9c57f4bbfd988f0',
 'b0d06f6f94b9717a305b',
 'b0d26dbaa5ced0a21e33',
 'b0d37af7e35168e638a4',
 'b0d77a96e1a42185aac9',
 'b0ddee1733dc18d54859',
 'b0dfd4786a6548489d3c',
 'b0e02888769d40447109',
 'b0e38094b65a5e10f376',
 'b0e58d9447e38dd06a31',
 'b0e6e9ff933f80b0d928',
 'b0e75ead65896fa5937b',
 'b0e7d5a3d571aeb28fe8',
 'b0ed0efef2101d097828',
 'b0ed3b179b256aa6c713',
 'b0ed62581f6f6a94a871',
 'b0f0120c80bb16fac3a6',
 'b0f03d973ce52d04c19b',
 'b0f2fb25f8ab231586d7',
 'b0f510d2a37f6844a4e2',
 'b0f888e6ae2340921441',
 'b0f95f42e5274bafb8e5',
 'b0fa583124a24e00e0a8',
 'b100b01ce9ed1ffaf40e',
 'b1043d47c4b789b44fa4',
 'b104992e10a25c278315',
 'b1060cf43b239fdf562f',
 'b10831c96a90b0276742',
 'b10e8cd6897e8f14f95a',
 'b112873ece0901ebbbf3',
 'b11812a3fae9425c11c7',
 'b118463762e892fc8816',
 'b118f52840d0ae6b406a',
 'b11a5da8914a5452f94d',
 'b1261b2e6acce92d1029',
 'b12733d5f768eeda014e',
 'b1338b6676dc9828010a',
 'b13893c94baf230d0101',
 'b1389758e2ac8cbdad3b',
 'b1400cf2d859a00933ef',
 'b146b464c3a36dede13f',
 'b147ce2739633f51cb2b',
 'b148717627b0ece9f310',
 'b149941823fb343d75cf',
 'b15121ce117ceda732f6',
 'b1526aceee549fee7362',
 'b154c94a121196f341d8',
 'b1564a08547b728a3c12',
 'b156899ae89b1df17d85',
 'b158af1ccd39ab684162',
 'b15bbdea3190f624fef6',
 'b15cc7e155484d8526d6',
 'b15dfd7fbb6df804b5a8',
 'b15f2f474198fc439bf3',
 'b162a1c7efed3f8bcc5d',
 'b16532165350e537fb97',
 'b165e73ba966c06b7718',
 'b16657945ee08605a8a0',
 'b169e932e957334784d1',
 'b16c6474f76af1f7389a',
 'b1752924c3b7494b549c',
 'b17c50dc161c7eb6ea1f',
 'b17c91c2c4b10d871b9e',
 'b17d0574d470009adad1',
 'b17ff4585fc2afb33633',
 'b181647d2b11e2c1e2dc',
 'b1838df3d242685456c8',
 'b183eaa9c95d44e9ea36',
 'b185c47fa251960fd218',
 'b188140555df21d04d0e',
 'b18b14c02dde4cf0938a',
 'b18c94c20ef9b4bf9933',
 'b18e4529fe030b05716c',
 'b190949226ba0c7ed52e',
 'b190d2e16f2296d7d782',
 'b194a40a0a9b652f09f0',
 'b1979097e7d9c6d58c98',
 'b19d59e215f04785bbc8',
 'b19f2c65da7f71ef89d9',
 'b1ae9371ed9d00bbb16a',
 'b1aeff17def31d56fec4',
 'b1b4d71bcec6d2e9209a',
 'b1b9945914e85769b80d',
 'b1b9abe272e486f969d5',
 'b1bfcb83ce706b04a1e1',
 'b1c1e239236d6be7382c',
 'b1c7ec69286e2c931700',
 'b1c84400cfd145b7b3f5',
 'b1c8de8bfa86e8558609',
 'b1c9c70ce1ee3f261799',
 'b1d04293628089c0a9ad',
 'b1d045a5bf252ae35a9f',
 'b1d047bdf136ec5cd026',
 'b1d2113be9e60fa0354f',
 'b1d7a6870ca348314ef0',
 'b1db8480b73c769e9569',
 'b1de96c84ec11a35f548',
 'b1e0b9119dcb479d2ec0',
 'b1e1b776de28a960c6e1',
 'b1ec9045b0611023b584',
 'b1ed25c81e250dfe5f77',
 'b1f5289701691d7647d4',
 'b1f6527bce88951e49a3',
 'b1f910a30a57272450c4',
 'b1fb2961d6a68f0ab024',
 'b1fc899ab4fc960ae478',
 'b1fd53c29e41ddd76716',
 'b1fd98868a2db6a20ca1',
 'b1feee778e70662fce0d',
 'b200c47af00d6d0f9775',
 'b201bf456ec08ffad4d0',
 'b203ba17e4bcbb699617',
 'b2074635aa20dcdfe861',
 'b20b12bf4bbc422e69da',
 'b21194acc0cca9ee101e',
 'b21d61a45880b7d965ce',
 'b224cb8d37df45f48e39',
 'b228be27920bf9864ad3',
 'b2293bb4a23e749fd14f',
 'b22f96e1a6f7be3e264d',
 'b2302cc2673bfc7175a8',
 'b23080e58a7384a4b312',
 'b233e138ccf459cfd915',
 'b23688f600a5e5bec738',
 'b239092d7620bbf0b95d',
 'b23e26c9417597557e3a',
 'b23ed025b7ba39a44b56',
 'b241a4843ce459f4295b',
 'b24478c1525f18aef8cd',
 'b244e351b2ef5c19f59a',
 'b244f242450626146ab9',
 'b2463cc628d203e79792',
 'b2466227ab7ac44f1a2f',
 'b257aa8b76cb84ef5348',
 'b258721cdfd8259d304e',
 'b25c07ce4ca0e61ca157',
 'b260e78bfc3473323480',
 'b2693adc7d07f10fce17',
 'b2699d5f1935494bad5c',
 'b28053ccd96cfc4d7888',
 'b2817d970f7610dd3e4e',
 'b281d25d05a854560c73',
 'b28214a1a719bb50d7a4',
 'b2864edccc8dfcd560e1',
 'b286a3d72a452fa670dd',
 'b29a25ccad9951a13aed',
 'b29a268afc37635102b5',
 'b29d7639ce092ec79b8c',
 'b29f46d1ce3e32cf1ebb',
 'b2a3dffa39411347d78e',
 'b2a6be681ed23dc826b4',
 'b2ab19c99fea5620b398',
 'b2ac0aad22a39eb9333d',
 'b2b4b63c28bb2e1264d9',
 'b2bbc7495ed8dc2d0f09',
 'b2bef5bb88516adee269',
 'b2bf6e3cfb452d3407d9',
 'b2bfaed0031120151539',
 'b2c17da8a1dcf5ec85e6',
 'b2cb28b7720ad686f1b6',
 'b2cd17eb9187afdc2dd7',
 'b2cd5128023a910a50c2',
 'b2ced0be9b31adbc73e6',
 'b2cf343b19f1ee0934dc',
 'b2d1286893c11dc46498',
 'b2d2cd57884a2e0bed6e',
 'b2d4f3cfc41e8980e163',
 'b2dfccefe3fb080ef5df',
 'b2e20b4b1a6033420bbf',
 'b2e458d74cc9b0dc5fb3',
 'b2e67b8f264473cf6e89',
 'b2e6ec89631cd61cb036',
 'b2ed46cf9f7e27ea94b6',
 'b2f132a459fa4be01ebb',
 'b2f23e950a0ed50a22bb',
 'b2f546541817df9ae8be',
 'b2fbbab46e4ca17bb2bc',
 'b2fc2935056b474cd253',
 'b304ff20f774be29b692',
 'b30c932b8f72c79565a3',
 'b30c9c335524368a1c8d',
 'b30d55379991c6690f4c',
 'b30f2ad416e15e512981',
 'b313a71b281095339003',
 'b314bac0fab2f9ad6032',
 'b314ca89088c8568a43e',
 'b31719f2884164e57cdc',
 'b319f7217a7ef056ac83',
 'b31fd433cd497eead9c2',
 'b3205ff2d7bee728d9d9',
 'b3208fd76a6e6b6b27f9',
 'b327cc025a28f0dd5e87',
 'b327cd4ecf23a3068ab4',
 'b328e77ea0aeb775ac7f',
 'b32984c8a5c48fedf25e',
 'b32a54b6fe26f95b890e',
 'b32b8e183569f2829249',
 'b32d5d28af9f834c2849',
 'b33186e8ac0593279e17',
 'b33264005a765abc5b6a',
 'b3332fa817203c6ab4d8',
 'b338edee7017263ac756',
 'b33dbc2438ec0dc8c4ac',
 'b34834da65ac0d73aafb',
 'b3490e1414d1ad50a7d6',
 'b34ce97ad1030972f8ab',
 'b34f8fead81420109015',
 'b3502015dd73bbf54557',
 'b350ff2fb00bd2d80993',
 'b3529ccb99b71b3ab359',
 'b354929185f96a691707',
 'b35cfc35a818aa782e61',
 'b35d8805570c7c1e568e',
 'b35dc6e042b9f9c1162a',
 'b36030971e06cc56d0bc',
 'b362f1d0c9a3e257f054',
 'b3662f6b36cbd779b543',
 'b36acef351616bcd94b8',
 'b36cd22473deb98f5dd2',
 'b37090e9aa2625a4adc4',
 'b374e0069d725ba5e6ac',
 'b37c19cc6eedd2c41afc',
 'b37c2b45ccd194ffb6ce',
 'b37d17d890131b791abf',
 'b3863570b2c95ca76c86',
 'b386e4266c999f23b4c2',
 'b38c56e8a812ef094baf',
 'b38eb049715eba145516',
 'b38f6547cd55f53ebf27',
 'b38fc7557a249afa0d08',
 'b38fd1c89d6f043eb2db',
 'b390e3f7dea4350de2e7',
 'b3934868f682c5f19da1',
 'b39359dbf2a3b8252115',
 'b39ab19efa4a1da40981',
 'b39ff28d223f17d4d779',
 'b3a9f5fe5ad3d0fadc77',
 'b3b0db2cf5e7d1ff43f2',
 'b3b26056e4df445a988a',
 'b3b43bb8e83f98c7165e',
 'b3bd12a3f7c6b6a651cd',
 'b3bf7a03a4a6018dc054',
 'b3c04be3e721789038c0',
 'b3c11191346e43c7017d',
 'b3cbcf189d3563d95f42',
 'b3cc310d29bb8ba9dbfe',
 'b3d33cde9166e387adaf',
 'b3d3a2ca6dd5b58a252c',
 'b3d5f3ebd2ab73e7b2ad',
 'b3db6663c60b676dd648',
 'b3dc887680b5ebca80d1',
 'b3dd2ec106ce2c0ac402',
 'b3e0dbf078a718d65f70',
 'b3e3a8ef2f9709982d6c',
 'b3e4473a46532cfc0403',
 'b3ebc5852e0a4242c52d',
 'b3ed827c8527b7d5b988',
 'b3ee3ec844db31fb3166',
 'b3f3bdfce2dbe88576e1',
 'b3f767da8ff9fe6515af',
 'b3f7b2e2c14ad3cfcb90',
 'b3f883cb6be603755f8a',
 'b3f8a1319fba5d67d02b',
 'b3f9e6796c3f0cfcea10',
 'b3fbc4bdce97e08141e6',
 'b3fc4973bf1978aeb291',
 'b3fd3c8d24675cd45fdc',
 'b3fe71392e36e5660802',
 'b4036f4e6359cb4c2997',
 'b407a52de8547a8fae0c',
 'b4098d0f70613da9898a',
 'b40b3f1d8b033d2936ec',
 'b40da111f85bd67c7ef4',
 'b40dd0c2af0875e0e25e',
 'b40f648cc6efee1303a6',
 'b4109c852e00a6afde00',
 'b411273f5732743698fb',
 'b413ff0537e85df53fd0',
 'b418e7b958c520c033bc',
 'b41b50a6f9d260bf5fe3',
 'b41c6aa779f101c5e9b9',
 'b41c6d1fe9c5cefdc2da',
 'b41cc959f0e771ec1069',
 'b4204a54e7ec31cc7d31',
 'b42270bb7e7c16325249',
 'b4261b8571b09f534729',
 'b42b76c9b89c59c42855',
 'b42c3aec6bb5ce5fd663',
 'b42cfac788372311a229',
 'b42d9f79b1d578e571dd',
 'b436093952cf55513f80',
 'b436e615622ffa7098e4',
 'b437274ea9f257343467',
 'b4373608c12d423a2901',
 'b437567d3110919a5aac',
 'b439aff04cde70a56eec',
 'b43c62bed97874ce147e',
 'b43dce24e7fd51582457',
 'b441ecd5cd1a05c7bade',
 'b4433a980181475a374c',
 'b4455cbf49f6d8c3fbd3',
 'b44c9bf45a98d3ef67d1',
 'b44e8ff861202b4981ae',
 'b451ae3a248c9d154d6c',
 'b451faa5b9f902d86349',
 'b453f77f28d7a2328300',
 'b4551728cb16c4430f0b',
 'b4552dfede3cf70de62d',
 'b455f77a36a248c1a6a7',
 'b456136a9796720fe167',
 'b45691b354304a7976e2',
 'b456f6b91161ea210dc5',
 'b4577ca8e8ab84067762',
 'b45b79ee7c1cb5fbc2fc',
 'b45c9a0c34704ca83324',
 'b45f10a7699a2f46ce18',
 'b4651d368ed3426a5d59',
 'b46e2653b7940977fab4',
 'b46fbfb10ff49eb35b98',
 'b473a7f8f6210bc248c6',
 'b47435208f882fb462ec',
 'b47e2a19099d912708e1',
 'b4866b8c7b98fc95f93a',
 'b48edb4cc6d8839c5671',
 'b48fc8c5016f5c6d90e2',
 'b4903e73b931c0f27f02',
 'b490a5695d4c40febec8',
 'b49156deadd3d124d212',
 'b492a400f0d986f1ed84',
 'b498d22df3003d87f799',
 'b49f0c57a44f9c1126e4',
 'b49f594aef40735f543f',
 'b4a53d41693a4a36657f',
 'b4a54ef28d045a053cb1',
 'b4a874b23134991536bf',
 'b4b3fc8893f32e448a47',
 'b4b560bec60e9a690f07',
 'b4ba136ac7fa724b477e',
 'b4baa9631c40afe3efa2',
 'b4bea919f1be5fb1d9cd',
 'b4c0a7cb3fa6c6182a1b',
 'b4c48f100dfc87360690',
 'b4c4ff1849a524aca37d',
 'b4c8859e4636fcab526a',
 'b4cb704ab05caab4effe',
 'b4d0414f75b0274726a5',
 'b4d2a742c5b56dd311eb',
 'b4d3741817b26c55642b',
 'b4d54cfad96ac9c8ff07',
 'b4d600d89571c13d866d',
 'b4d6e61a33581202baba',
 'b4d9fb4c5ad45d743d0e',
 'b4da1b0cb1c8f86a7581',
 'b4daabc02f3993a705b9',
 'b4dabd32a4576aa80fc4',
 'b4dbda01f1acdb6c8d01',
 'b4deb32fe8285d3c0f61',
 'b4e0b5614557cc638086',
 'b4e3a0b758d3fa412bb9',
 'b4e5c65d1b44027b7dd2',
 'b4e7eea1caf4d7235d66',
 'b4e8167ebea640f57472',
 'b4eb13adac3bf1ebab86',
 'b4ebc86296303a66293e',
 'b4f3aaef0f7e7455cb96',
 'b4f47c84cc2785e38560',
 'b4f4fc539198180840fc',
 'b4f5af601c98442edaa2',
 'b4f5feb384c638bcb849',
 'b4f76971323e8ddc67eb',
 'b4fb5b8423c0e6fdcd2d',
 'b4fc845c27f261db60f0',
 'b5019311cfac3ea20919',
 'b5032ddae69084a15aa5',
 'b503f6dad5980f8205fa',
 'b509a972b093f4971385',
 'b50aa3493b123ebec9a6',
 'b50e026d06fe2efa1770',
 'b50e564408e88b41d0e3',
 'b5137f7f87461d65c1be',
 'b5158d5b98a6c463f954',
 'b515b099f8bd17d77766',
 'b51d4adfa5bcc2f2fb93',
 'b51f39bfd979cc6b9400',
 'b51fb18e1999360ced19',
 'b523fae2414d28a5996b',
 'b524dda3b4cc75545e59',
 'b524e26396e454771342',
 'b5269c4353a6982611db',
 'b5278974b40e5880e19a',
 'b52cf97eccd2716167ba',
 'b52d5a49703d8ede6d97',
 'b5322253608e89e48930',
 'b532d2767fbe64a1397b',
 'b533a34731b9860d4027',
 'b534f8a094e05a8a6718',
 'b537dcd62468ea2d987e',
 'b53f21c42f9d4c3d9c31',
 'b540b1ab1c57f4c2d0e3',
 'b540f104d83da3589790',
 'b54419b33dc243265d72',
 'b5486f7dc887ea601f7c',
 'b54a6dcaf55bacd2048e',
 'b55099756523aeb31602',
 'b5517f000e80064bcddf',
 'b552971159f3d311a07d',
 'b555340ad67357d261c4',
 'b55716885d009ad8a991',
 'b559f245e39ba3e0d201',
 'b55a113807515df02a13',
 'b55f77b63f5ad0248a38',
 'b56650db84fa07a18ef3',
 'b56690814f53a3ea6df9',
 'b566dde2e84751d7ec79',
 'b573a69c63bd04486c02',
 'b5765c9fc8056ca846e8',
 'b577568a1f327c884409',
 'b577d161aa3007c04687',
 'b57866aceab06bf06453',
 'b57b11e4dc074e98cb34',
 'b5850682c32a2fdedae2',
 'b5893b3deef12d360a21',
 'b58c8a1fce99565ed508',
 'b59273482c9d2bec64c7',
 'b59636606d76fe2eff5e',
 'b59ca59b479ccae9077f',
 'b59db5a8f5172cafeb11',
 'b59e95406206a855fe4e',
 'b59f238a4a36c42e677e',
 'b5a02d0bd86d73bfab14',
 'b5a118f61ad6a7613074',
 'b5a6d187c898eac14cac',
 'b5a7af223ce63b7680bb',
 'b5aa52e141782a68542a',
 'b5ab39239c2dac3cb659',
 'b5ad3002cb48ce662399',
 'b5adcf6ff87301dc9636',
 'b5af13da4840795e64d9',
 'b5b8e9381335d6322c01',
 'b5baaac0779e5a4ca43a',
 'b5bbb34f3bad3272a32a',
 'b5bc823e6a57eeb83d42',
 'b5c432d8c6715a73a8fc',
 'b5c5d19f8651c5ab5fe5',
 'b5c6355beb3e4a0216ae',
 'b5cce6791c21ae6635ba',
 'b5cf5fa692951c58f785',
 'b5d1606e727cee58a811',
 'b5d7933c59133ff31743',
 'b5da32b2a94c4b78f7af',
 'b5dc4128160923660b8e',
 'b5e078bb702c1c22dbf8',
 'b5e1fa7be9232e717160',
 'b5e6674121a68d8856d4',
 'b5f29eca6a4c2e678565',
 'b5f73ef6fbab2f920131',
 'b5f81d090cbdeecac8a1',
 'b5fe34b2525f970c5d96',
 'b5feff5d3a411c0f35e8',
 'b602c5d72103a386296a',
 'b614b23c556fd76b389c',
 'b61dd3bf7de090dfd2bd',
 'b62342622550e4796c69',
 'b6255dcc562d0e848563',
 'b62bb9fed8dffca2ff73',
 'b62c430c2bb04c9a4934',
 'b62ec167a99a26a5e5fa',
 'b632c97ac93e0e4ed2b8',
 'b6343db197c5622bc9ba',
 'b6376052a0457e77b5af',
 'b63b3f321a0179f76745',
 'b63e09df541cfa51de3e',
 'b642b4fe07a77fd7656b',
 'b645daa8258258ba8674',
 'b6495419ff723ebf778c',
 'b64a15ce77b9152909d0',
 'b64b679b12f82dd6ce56',
 'b6554982dabf50480531',
 'b655618d61bf142e0cf8',
 'b6576988f8bf4be30b89',
 'b65a5c1ad526a8d5e64d',
 'b65daae0e24aec9bee0f',
 'b65f08d4d15cf893873a',
 'b661fbbe6260c8ceb608',
 'b6633a95ff6159447485',
 'b66399f8f67876370cca',
 'b6647c58561516ec918a',
 'b665250066aa6f7df795',
 'b66a24850e74a6dd8dd3',
 'b66b1a2a1adac960c4ac',
 'b66d02c4eb24b33fb737',
 'b675c83ef9abca8c75b2',
 'b676b5c0eecea1efcb3b',
 'b67dae934a73a1c259c9',
 'b67dba84f29757d9d299',
 'b67e5d481c224c1c671c',
 'b67fb57d5c9b0577fc61',
 'b683c7ef2ad1a16ff32b',
 'b6890015e03ac95ec9fb',
 'b692e4b6a41002e09f7b',
 'b698f77d49e21b43e9d6',
 'b69a7cc02cab1b27a4ca',
 'b69be1338e2129b069cf',
 'b69ec58cdc6f0057b96b',
 'b6a0f1a7db46c903e87a',
 'b6a28811dbecd2c779a8',
 'b6a32376e7da755a3642',
 'b6a4767d94e6984bc6e0',
 'b6a6c19c79c4ec5c5c4f',
 'b6ac75ea12a184b13db1',
 'b6b100823259f1cd2ae5',
 'b6b55ea863bff37e110f',
 'b6b5ffc38d67a3b3cad3',
 'b6bf571b7cebc9f7e012',
 'b6c1806724a7bc813e89',
 'b6c206186370d24e973c',
 'b6c2b4b35103e07fe424',
 'b6ccb59824cc033bc393',
 'b6ce802ac947f37ec97a',
 'b6cedb17fc672a547c5b',
 'b6d0fa58ceb93ec6a336',
 'b6d59752dfaba90e1ab2',
 'b6d74aef404de75c5778',
 'b6ded134b414ecb84020',
 'b6e050e32fc32b6a4334',
 'b6e26b6940221f59cc66',
 'b6e75e72fb2c71da18e6',
 'b6ed700f1eaf29c148fa',
 'b6f45773806b37afece8',
 'b6f4fde50dd0b8de3692',
 'b6f63b9d951a7f7d9fd9',
 'b6f7100540d7f683373e',
 'b6f8efe0552e4e934b7e',
 'b7024b9e64cdf9876750',
 'b7030cabd9b5e96d526d',
 'b707197ac4c7cf59d58d',
 'b70d660bf1f5183f934b',
 'b70d8ef43f439d36db62',
 'b711e54718fc2913b95e',
 'b7137244a4906053bd87',
 'b715b37f29d815320217',
 'b7166b231dd97210db89',
 'b716bcbf8dae01b6cead',
 'b719d489fe101fd450d0',
 'b71c8b1dc298341fc558',
 'b71d112bb3eb2c73c151',
 'b71e4e227aa1db84a75d',
 'b720f58f649fa2230f79',
 'b722b55b90bbbdb1c244',
 'b72b0a88ebb568f667e7',
 'b72e63a38e93f559124e',
 'b736b9bfb2f281188e9b',
 'b73c0a148a910361cabc',
 'b7404db23d0d68abf7c8',
 'b740eb5ae29cae5d75c2',
 'b741b22db69b744ccfec',
 'b741c83ce20066cd634a',
 'b744ad6915e2abdf3673',
 'b745e1454f145586da15',
 'b7479f1570d8ca14de05',
 'b74df4710b977a6f284d',
 'b750645601832659af07',
 'b753b7dd0134613b8983',
 'b756f672bcffec07137a',
 'b7575d9a63dfd702cd07',
 'b759751ef08f5a2bb04a',
 'b75bbec38ebb95caba46',
 'b75bf4f3c9eda29e77d1',
 'b75c3f91e82eda1ee0db',
 'b75c467b9c6c06af466e',
 'b75cffdbdef48ce3541e',
 'b75dd23d60d987a6cb92',
 'b760155a844159e3d59d',
 'b7617f074d6c62d211bd',
 'b766648a22274d6d9898',
 'b767b614a25d7ab57a67',
 'b76ac9fbcf2f9c3345f8',
 'b76f400a0f6d5bdbdd93',
 'b770240a314726aa19aa',
 'b7719b1072c248c6770d',
 'b7762ddb5103a53b3586',
 'b776bf0585ecceac44f3',
 'b7772b4eaa5a2a84e13c',
 'b779367252e778f557d7',
 'b77acb6afe61c7ccf83e',
 'b77f4d7c6ca795199fcb',
 'b780858c852d4d33c1c9',
 'b784b6a1b1b63786ea0a',
 'b789101ec495d80afbde',
 'b78a45ffe8f9a34d8bba',
 'b78b56b0bdd021d268e3',
 'b7a0e5e4c63ded33ea8b',
 'b7a26ef6efe419756d03',
 'b7a6e71866e11e764de6',
 'b7a8c3db9acf88399910',
 'b7a9c544f62fac8b6518',
 'b7abe83ddf2fe61a6b7c',
 'b7abee2e977326e7adc8',
 'b7ac9d924617a2e3cd10',
 'b7ae4de7070725f8438f',
 'b7b2e80ebbfbc0d677e2',
 'b7b41f1b3460a7ac381c']

# %% [markdown]
# 18

# %%
qids_18= ['b7b62ee04de1a2f61679',
 'b7b9a6fbec4dfc0231b0',
 'b7bb4fc55df868598b1b',
 'b7bc8a72eec33318154d',
 'b7bd25775f4887977ea7',
 'b7bd5560644ddefe3974',
 'b7c09c306f1762d3e357',
 'b7c37befeaca1e6bd496',
 'b7c47654aceb1a7eef34',
 'b7c8e3b88bade1b93866',
 'b7d0506570ee1e62ce70',
 'b7d2f0c27cfc91f55263',
 'b7d381c1c2d7e02ded95',
 'b7d38bb56cfb780515dd',
 'b7d410b1fea3bbe4257c',
 'b7d98f0eae5c24dd53d3',
 'b7dff0940da702d51661',
 'b7e05112e3b74d56db31',
 'b7e173f014abcaa25918',
 'b7e35acbe2bff2ff3c39',
 'b7e74f8140920d50d335',
 'b7ee7fcbfa56bcf477f5',
 'b7f1f6b1ab84d76e95cb',
 'b7f4079b5323fee9263f',
 'b7f5c7359abf0addd3ce',
 'b7f6aadc492b79142851',
 'b7f89a9779aa24447954',
 'b800da6c10b39c63808b',
 'b803821defc354471fe9',
 'b804607badf1c3434e6b',
 'b8079d21a3bc63757e62',
 'b808cbe1415ea0f6b1f2',
 'b809ed356c0036f529e9',
 'b80a88e75dca28519bef',
 'b80c1d9e73fda8a88d44',
 'b80ef3ee59fdde45ead3',
 'b81250faf50cc0344d4f',
 'b81628edb5dd13d3870c',
 'b816e34be983bbd49c45',
 'b816e8391eaa842ad22d',
 'b81bf9c2df2e0853873c',
 'b81cb2a1c914e888d6cb',
 'b824477fad25c157e6b1',
 'b82c6be1f68ec0bb868d',
 'b82d5ebb03190510102c',
 'b82f78cf0bd995b45600',
 'b830daf06e23649ab040',
 'b8311c59ea1b4d89a647',
 'b83a328b4f0971c774b5',
 'b83c1cb0f75c39fd8dba',
 'b8466210bc7d3d80a055',
 'b84880322a05e400f1b3',
 'b8492211192d57ed1ff3',
 'b84b07612d8910027299',
 'b84c8d8a26d9b1252a14',
 'b851be362b402c04a457',
 'b858798cc49c3241196d',
 'b858b131725baa687bc4',
 'b85c2a4b53eea8ecd2bb',
 'b85c583ddf386d815894',
 'b85cb6b2168642154ce5',
 'b85cc9426f9d685e92e0',
 'b85d1c0d9618724bdb4f',
 'b8620f7aeacbf938f5ee',
 'b86474fbc3944d528625',
 'b86550f3bc15e396e6e9',
 'b86cff20d7a3b601f38b',
 'b86e2bab86d5e3581a33',
 'b87cdbe0bb786e894dee',
 'b87ce5825bc5950c9e65',
 'b87e631df8a0b6e71636',
 'b881664fad91e360ebf6',
 'b8835896c7a695b83cfe',
 'b8845372ee63ee3cacf9',
 'b8885eaa86d2eb5d5b2c',
 'b88d63b8ddfa207a6044',
 'b88da11e96ff86f7398d',
 'b88e6c0b897495f33cda',
 'b88f641a51907c1b7459',
 'b89049c5e52ea96d05b3',
 'b8909e3c3aa3140b43b5',
 'b891c5913c6fc78fc192',
 'b892c96a32350a4ce661',
 'b89510b9dd8ac6ea4311',
 'b8977c35b9c8c09097d0',
 'b8977ff25d9d93a34488',
 'b89b24ed6d794b230b4a',
 'b89cbf26122aa1e5dd2e',
 'b89f36a01f6dc5161b14',
 'b8a60d37c23a5e8d5218',
 'b8a8054aa05ab8aae8b1',
 'b8aa61c287f13beacae6',
 'b8aad424a7e0f34f0272',
 'b8aec85029a9dbc894cd',
 'b8afb71937fb4d31c3a4',
 'b8b6a2df5a4963988f0a',
 'b8b6fe0c7b5e598836aa',
 'b8bd51d1b9cfbef95c75',
 'b8be057f04a7d2bb6ca6',
 'b8be8ded52b1bc2ad655',
 'b8c32cf88e7b35b0cd9c',
 'b8c439c55845d8abf211',
 'b8cb819af8e005ea696b',
 'b8ce2a191ee795084125',
 'b8cf9bef95eb69484020',
 'b8d015b351ed3a306bff',
 'b8d15d36a5551b3a9811',
 'b8d38acb126224a6ae8e',
 'b8d471aea8c5fee8a2e7',
 'b8d4f01de0e02ae91814',
 'b8d72daaab66749fd6de',
 'b8d9af55cf9866f8265e',
 'b8e19e267e7e301c9d7c',
 'b8e2b5af7cb5cc26bc4c',
 'b8e334a2593352df43e2',
 'b8e4bba6ad819aebf1db',
 'b8e546965e57e3da90f3',
 'b8e795a80dc93349a80d',
 'b8e876e8dbe0c012b589',
 'b8eb4bad06d014982e11',
 'b8ee567bd11300e10fa3',
 'b8ef39c9108aeaea1fb6',
 'b8f1b7f3832fc2c6d893',
 'b8f3bede8534173543f8',
 'b8f3fe1afa8ef34a33e2',
 'b8f6f8d8647c18a208d9',
 'b8f85f62c9b812005c65',
 'b8f8c166fbf314b01ce4',
 'b8fac00911be463ff793',
 'b8fbe1166693a414156d',
 'b8fe3b1c4e93e256ede6',
 'b9004be2629056236aa0',
 'b9051c5255535b3823ae',
 'b90881943892bc80b6b7',
 'b9098bcfc6ed472b9470',
 'b9135684934117c02571',
 'b91ae9c6a7403c8d39d6',
 'b91b24b948a34013a8e3',
 'b91f06b90fb7530ae407',
 'b91f5989a54a845644a0',
 'b923925e1135c4f3f8b1',
 'b925b93e3d51f810d2d9',
 'b926ad7c1d7254ce6139',
 'b926f083150a7766bda0',
 'b92e6b26a8b5fdcf6bf7',
 'b92fa1c9a1f94204c1b5',
 'b931edd95132b107aab4',
 'b931fd40922381ba2036',
 'b933e7664d5930e5fe4b',
 'b9365edfb9e8c8c62e6e',
 'b936c56126dd433bdfde',
 'b93d5725a0f83e083a7d',
 'b946f833d8eb5e60bd1c',
 'b947beb6084a8d5e0d23',
 'b948a814aaae3df04962',
 'b9496995995530e173eb',
 'b94a09d233f69b98ca85',
 'b94c1aca4a67355a8413',
 'b94c5803ccaa46b428c9',
 'b94cc3895d989755de49',
 'b94e27c1c53a4793d06e',
 'b95171c0f1bf07ca0113',
 'b952259dabab7c289e08',
 'b95265352195c8479625',
 'b95696f13c533257df1f',
 'b958385d815b086b4e8f',
 'b95bfa479a760dd49c38',
 'b95e452734eac23eeed0',
 'b962236dbb069b38e2df',
 'b96433d4ba4b5e5cf8a9',
 'b96629e7708037bfad6c',
 'b9672fabbbdd006b60b6',
 'b96bf334835e27676755',
 'b96cb2c8500666719a68',
 'b9755cc2f82d8392efb8',
 'b9762ec549aa1ef04687',
 'b977a75a91fe3c8c9e08',
 'b977d2535b1d81b1f243',
 'b97accfe2aac28654867',
 'b97f66124e31646efbb0',
 'b986f9fcf6ce649f1371',
 'b98a7779767414cbdee7',
 'b98c6cd6c13ee0f1d8fb',
 'b98cf8ad0aa848d65220',
 'b990742e855b85f45ac8',
 'b9990c200cbd667d286d',
 'b99ac50d0d1c9732917e',
 'b99e23952701ce9c788e',
 'b9a0a48fe8ada4dbc58a',
 'b9a0f80a5c9bc8885f0f',
 'b9a1f8174e9afd264747',
 'b9a5476e96c5974f3db0',
 'b9aae4fa407e0094e930',
 'b9ad83770fbd056571be',
 'b9b0d37fe91a4b9eb8bb',
 'b9b151c90d23a3486ec4',
 'b9b254db96346ad03095',
 'b9b491e507b649f70ddc',
 'b9b4ba400ff07b49c63a',
 'b9b8b46595f6cfa2ba3c',
 'b9ba6440485c41ef3c1b',
 'b9baa45740daa17457f5',
 'b9bc41c74f2a10cb28c5',
 'b9bcf421b4c1d9e47afc',
 'b9bdafb9d939652add13',
 'b9be5b9682253470fe8f',
 'b9bff11ec4de1a4fc766',
 'b9c04f8cf29c7134998a',
 'b9c4ae26e94a6dc1e1c1',
 'b9cc11378c27c343dfb0',
 'b9d8fbb50ac7e0156164',
 'b9e274f1abe234397133',
 'b9e3f76d297353ae2564',
 'b9e4d1316723fc80cb31',
 'b9e9ecc1d639841a83e9',
 'b9eddf9ffd1de9c53f03',
 'b9f314fa721e3c53618c',
 'b9f35f061b59fe8d4b71',
 'b9f79bab7ba197fd0ee1',
 'b9f8505758291a9cc054',
 'b9f95f9567a65bf178bc',
 'b9fabb1d36bd330a2c16',
 'b9fe69bf291763b3598c',
 'b9fedf7e070ddb3dc90f',
 'ba011f74152bdac7f17e',
 'ba01f464dc2bc97ccec9',
 'ba0276a68294c861cc11',
 'ba02b0fc48df52a3d22b',
 'ba055ba6b813c0985d51',
 'ba06aaa9344c85e5f598',
 'ba0b238bfc99b6fdef96',
 'ba0d4aa7c38b33cd6cd7',
 'ba0e45822cf8cdc061df',
 'ba1101e4e46e2114585d',
 'ba134589c986b2f9923b',
 'ba14369782080c8e810e',
 'ba17df0ccdc6c88587fe',
 'ba186561717faeffb15c',
 'ba1876662f617ab144d4',
 'ba1de9ee92789d95dc21',
 'ba1e1a08d1321d132c9a',
 'ba1e88f4fb4a881bbd45',
 'ba2045f268e71acb97c9',
 'ba24af382af9b6f36c6e',
 'ba2885086c6e27083c85',
 'ba2ba927ecc5c28c57c9',
 'ba2cabd97b0e29a6595f',
 'ba2d3c91bfd9c7c32002',
 'ba2eaf4c36a3ef42d803',
 'ba32181fe10a20aabb13',
 'ba32d7e990d36136751d',
 'ba3341c8b62078ee6b1e',
 'ba337898477d569bcd14',
 'ba3395ed806632944175',
 'ba3516478dfb81bcce5a',
 'ba3cda82fc16fd2af688',
 'ba3ec71a748f68b24a72',
 'ba3ef0ac024c166283db',
 'ba444fed51040acb6f31',
 'ba457a222ef6eff2ff8a',
 'ba470214471fb15fe5d0',
 'ba47e37df5dafb4f8590',
 'ba4a3fde32f1720fbc28',
 'ba4e5e3bad7c04ba346e',
 'ba50ae44dab113402380',
 'ba51a519507bfc3fd225',
 'ba5437b97445456794f8',
 'ba57a2044690efe1b3e3',
 'ba588156afea87c32a8c',
 'ba5bd4c790c74a1427e8',
 'ba69a3b87185d6ff8d55',
 'ba6a4a4356b9b3e72fc5',
 'ba6a4add102f0f212b12',
 'ba6bb9d0752c7e3d0b45',
 'ba6d321b45c1da492668',
 'ba6f51a386b7246ee905',
 'ba721db27cfb61900079',
 'ba73ac434b10d0a95f39',
 'ba79b366d406d3d408f3',
 'ba7ab30c07aae2db2766',
 'ba7b49089be5469296a5',
 'ba8297034e787d42d820',
 'ba83629417b2ee5fdc7c',
 'ba843dd50898cedde4b4',
 'ba84d25f80122daa29a5',
 'ba868363ca94f090204b',
 'ba8c65638ddd6553210f',
 'ba961b6925615f77f748',
 'ba9822cd421150b4721c',
 'ba98cfb12194559416f4',
 'ba98e342bbcaf2e3c192',
 'ba99bc370121be9cd173',
 'ba9eb96ac5433cb1071d',
 'ba9ed28be05a876d7d9e',
 'baa4347963074bf38649',
 'baad6e3eb9cff5d5fcf7',
 'baad986e9ee60c83ac6a',
 'bab844dd8ed666186a95',
 'babaf7e6f07a9252c9e1',
 'babe6421b6dff7471c20',
 'bac43aa5a6cf6b7c6a65',
 'bac4dd55958ecf6056c6',
 'bacb70110eaec90395fa',
 'bace22ec399f8a7d6843',
 'bad3e70079f2e1a72ff7',
 'bad4a7967da0e153e8d9',
 'bad8aec72e6222151586',
 'bad95509d7ffebca4190',
 'bade47e1526b8073a3cc',
 'bade67438a31bc1d0510',
 'badfac60f63a366d653a',
 'bae16da9fe04b25be085',
 'bae18ee6eb8de8a79d17',
 'baeb0e377958142931cd',
 'baeb529cedc24039e602',
 'baee984ac0ec98222554',
 'baeeb5d34058638bc448',
 'baf312ad556b45f940b2',
 'baf5847f160fb867b660',
 'baf9eb33ceb5eb3f1413',
 'bafba163a0c45da100db',
 'bb00492a8e389e666d45',
 'bb02f1889b7a79e8978a',
 'bb0c9367d3001b6ed9ef',
 'bb0d70849ac79aa8bf86',
 'bb0de2e6bce91d051c5a',
 'bb0ff21e3109cb3d4516',
 'bb123004c8f0a44995a7',
 'bb13617d39bd8931f8c1',
 'bb13d952d5a3e9d0d074',
 'bb14b65af703b6164c79',
 'bb19cc3d5444aa9929bc',
 'bb1cb9c2e0aa41907d91',
 'bb1cbbf9f630da4f2cff',
 'bb1ce81106cd25b22eb1',
 'bb1e1f93af9cdf38658a',
 'bb1f0a628b4056cb62e7',
 'bb21023dc99146504244',
 'bb22879a1562bb7150f9',
 'bb22cc18b7d373379440',
 'bb22fa675fe0c26592f8',
 'bb25cada912c68c3f6a1',
 'bb2793bc9e6ee03d505a',
 'bb29c07014ee7de5ef39',
 'bb2a0060dd9d9642395f',
 'bb33b9e1063135cdaa68',
 'bb3708e854fd51a72409',
 'bb42c0ce7d19ee5fa2bc',
 'bb45f4a427275e3ff163',
 'bb469d5072815c860ca9',
 'bb4b4c7899a15bd0743f',
 'bb4b745d65ae3b475868',
 'bb4f060e1fc4deba251c',
 'bb5088139b1eea7e8350',
 'bb51320ab5d83ad92ba8',
 'bb536d673e24ae659fc4',
 'bb56d0ea05fe4a3db769',
 'bb5704e5e31396141d02',
 'bb599bb158d713038086',
 'bb59f89906a6bf15230c',
 'bb5f63c21d564d43416e',
 'bb602f07c10ddd3f8414',
 'bb6114e7b630e9e168f6',
 'bb62b71226add8eb9aa3',
 'bb68908d2f433a6b0fe4',
 'bb68c45f4eb365124678',
 'bb69d470250aaa5d6036',
 'bb73b9db01b870f5c5f5',
 'bb81c24c8163b6bc8b03',
 'bb823d8d9b34a68ebbc6',
 'bb864b6abb5a0da0d114',
 'bb8742402f174596ba56',
 'bb8b8087ad11c5148b3b',
 'bb8ba44feeb8d96c5776',
 'bb99690ec14a864c99ef',
 'bba10ffd525109dfbffd',
 'bba117c534c19e7c5da0',
 'bba1d19a4423d930ad22',
 'bba4a72518debbc9e37d',
 'bba5dfea5fc2d0ef87b0',
 'bba8745d2621bce40c6d',
 'bbaa2500efa67384c8af',
 'bbaac1f12de2929468f3',
 'bbabadb7121e9915081d',
 'bbacff052f93ac8e8e8e',
 'bbaf0f4f1893dd00bcb9',
 'bbaf499032334623415b',
 'bbb250f10ad01810adf5',
 'bbb29af58e1f68ef00da',
 'bbb398310295520b0e2c',
 'bbb3b8c39a4d7ee5bc46',
 'bbb3bcfeb735e98518e1',
 'bbb51955d390aab91ed8',
 'bbb556565ae0652df99b',
 'bbb671bbf3563d4dd3f4',
 'bbb749dd5eed197ef77a',
 'bbb8ec9ce648c9bfdf72',
 'bbccde2f20e031b1de14',
 'bbcd717f3d6da105b7ac',
 'bbcd8947f597b92863f3',
 'bbce7ef6f9dd852ce173',
 'bbd1e0f60de491709ee8',
 'bbd85b62073d7b8eb3f1',
 'bbd8cf4be1dcdd69e466',
 'bbd9fc77fb748e45b0cb',
 'bbdb9673c7423122341c',
 'bbdc68df621791d0a7f4',
 'bbe18cd901f4ea2bc65d',
 'bbe22699842a4390e873',
 'bbe3aa7cb440e71b5f81',
 'bbe6344123c8baf9dd88',
 'bbe6392c274ce325ed8c',
 'bbe7678823b74ed73844',
 'bbe7cc777fa850ca990d',
 'bbe8104aee903b483a49',
 'bbf15271edd00134120a',
 'bbf4b457e2b5017294b6',
 'bbfb03a3cbad251096fd',
 'bbfb6383f4e597115497',
 'bbffd1a1c2b27062befe',
 'bc05eaf8e6ad4ec1c53c',
 'bc0abb31dfd6e1d05d07',
 'bc0bdd233b1a61762c45',
 'bc0d49f8dc4baa7d415a',
 'bc0ebd0e4432e00b0ffb',
 'bc14a3905140e2c1b99d',
 'bc158119a40eef9dc1bc',
 'bc158592d64b99cde3cb',
 'bc17e079fe912f02090c',
 'bc186376d7105d97ac9f',
 'bc192f9bfec7965b796c',
 'bc1c8334b76a021ea9b9',
 'bc1d084d2be0f47f04fd',
 'bc1e58b7934715188866',
 'bc24f8c67ad5675881df',
 'bc258e93fe39c275f99d',
 'bc2a66e2243cd387c56f',
 'bc2cbaaa87b318b5d082',
 'bc2df87cd9c605866141',
 'bc2e9a938553f0d85836',
 'bc3053496c1369039d86',
 'bc3731bd70c13662586f',
 'bc3aeffa34afc3751e00',
 'bc3b4d44fb67d681ae1c',
 'bc3ce2d37f027f8e3559',
 'bc3e3dc28ee05a5c963a',
 'bc3ea1c5c48c806284e5',
 'bc4191f5ec9b2bee6cc0',
 'bc44535fe5feba29d8dc',
 'bc445a45c043840a9f58',
 'bc5107eb7151fb5cbd41',
 'bc53a261ce095cb9c332',
 'bc557d3f0fed1509c9d6',
 'bc566d0aa5c6f46fc4fb',
 'bc5da88df71986b12737',
 'bc5f795d50a031c4a55b',
 'bc62d021fac268f32aee',
 'bc640dfc15589d0d0935',
 'bc694963c989bc10625e',
 'bc6cf1a1b2d01c22f045',
 'bc7123afb28b16924a51',
 'bc713daf0ea9dacd44e1',
 'bc73722e8a361e85270d',
 'bc7769414eca3b1c361a',
 'bc79c79bdf334781ec88',
 'bc7ae9e951de86c8bd5a',
 'bc82b6c8bdfc3c79d92f',
 'bc87fe3f7b427f2ce389',
 'bc885a47326ab6dbcf12',
 'bc88b7b24ef261f598e0',
 'bc892fe1421b3e46595e',
 'bc8b6f60682dadc43205',
 'bc904cc775a38de1aa9d',
 'bc929230de2ea1fce23f',
 'bc92d0de412b596b1f1e',
 'bc950eec23f663d93d89',
 'bc97555ee03ffa82247a',
 'bc99c7124b4efd8eae1f',
 'bc9cd7dc6b656faa85a7',
 'bc9f904a7f034b7dd9fc',
 'bca143ea7dfe969caacf',
 'bca1735789ef9fd1a132',
 'bca360aa5fa4c85077b4',
 'bca447a4f77edad315c0',
 'bca83498986a9aeb8281',
 'bcaa573349c89f50be48',
 'bcace7d57d22ba58684d',
 'bcb27f1da6c1a13345e4',
 'bcb75556d88dd05afbf0',
 'bcc136193676c68a1d60',
 'bcc1557eb1e4c8d3a671',
 'bcc18269b2cf88bf123f',
 'bcc7116b08064da0616d',
 'bccbdc878dcfa44df1e0',
 'bccc552d83e06839c893',
 'bccff9908cc9b0c2ce73',
 'bcd00947a034d3c9e7b2',
 'bcd115542e4732ae3192',
 'bcd22845252c5dd1be6e',
 'bcd664e0bb9711951fe2',
 'bcdcba3b9fd406dde7a7',
 'bce18e5f98c41ec58c40',
 'bce363d75016aa40c442',
 'bce3a93c79663ff6aa1d',
 'bce4c3261aee10e088e9',
 'bce5a8ae2edadd9574d1',
 'bcf83f0c89c4ed7b949d',
 'bcf99793fb1dc58a9f22',
 'bcfaa45813b2e29c8f38',
 'bcfe143185ec7a9d0938',
 'bcfe9676aa3d5879f4af',
 'bcffe2bbeb7dd9d8f5da',
 'bd0059b918be543a14ec',
 'bd03136c04df025a3b43',
 'bd03c0bb49de10a2c07f',
 'bd04a3da1b1e6a4dec32',
 'bd062db60560ab34fa75',
 'bd0eb9addf6ddb00a6b5',
 'bd14895b7ac26225ccef',
 'bd18622832c1d5acb4ab',
 'bd19b485dc6163ae7224',
 'bd1ab064909fdb0fa8af',
 'bd1fbe748d06de04ecb3',
 'bd1fd7fa27f3fa2bc67a',
 'bd20f77982f8d07d0b87',
 'bd30331b1b7aefdc6eb5',
 'bd33bcc2f67f48033ba0',
 'bd37d8b0ffe1ddf8ba2f',
 'bd3a4d42c3509d9ee3a9',
 'bd3b07afadde9adea5db',
 'bd3c9b8add1eb39c6a04',
 'bd3f286a343d4ac7f73a',
 'bd48ae288ead8808ac46',
 'bd4d99f82d346931f159',
 'bd538ecc32e65ba1fce3',
 'bd56e7101e4cfaf128d1',
 'bd574f3cf3aec1878503',
 'bd629c104f2740d56100',
 'bd62b8816511f09d3693',
 'bd635bcaf22a70ca53cd',
 'bd673022977084bb21fd',
 'bd67c82ea32e4a2fa10a',
 'bd6b303de4e7942d7df8',
 'bd6c427ab6012042f54f',
 'bd74065daa141578fd6d',
 'bd765f87d8349303cce9',
 'bd7770fda667b25e8c14',
 'bd79ff892e72c46c0c1d',
 'bd7e7cea766e98798a6d',
 'bd8b69bdc21d0d73c2bf',
 'bd8cc5b21709f2bb6454',
 'bd8db53ca3622ad6cff9',
 'bd90f23aa2ccae0ea324',
 'bd967bc500b3f831c2d2',
 'bd975a063d668ab8afc5',
 'bd9a576e97eb09db1b28',
 'bd9b06db983bf1f30828',
 'bd9bf7487d7c2c928276',
 'bda3f225f56441d1b24f',
 'bdaac7d5aaff920f5795',
 'bdaad12feb2cb8c112f1',
 'bdabc31bda5dbf982239',
 'bdad59591283bbdf2e04',
 'bdae6c7c0ab934d9ca48',
 'bdb12f87c1dc0ec964f6',
 'bdb5a89460a0cfc7d52f',
 'bdb881950c2fe05d99de',
 'bdbb8640b9a819f7b73b',
 'bdbf8596ef6b591f6932',
 'bdc2bf26d7b0f8f2cd2f',
 'bdc3df388718633a4d7c',
 'bdc66848a6f75af1c399',
 'bdc98d6fa7c7f8e0a62c',
 'bdce5317973f2bdd961c',
 'bdcf81fb5053bc3435fd',
 'bdd1a75f1d46c2a3be63',
 'bdd4e6e9492f439e215a',
 'bdd8e14e0c0a12eb2647',
 'bdda12b49e204495086c',
 'bdda2e876ce3f44fe3a0',
 'bddd9218b0b83d634708',
 'bdddee2ab9dd07f2fb54',
 'bddfa1133089e5c01748',
 'bde857da49289ba4e1d3',
 'bde87ed0be71e1138899',
 'bde8d9b96999eb5a49d6',
 'bdeca27508cfec83b6b1',
 'bded4d1cba43cd87cd73',
 'bded64786334d095e0d7',
 'bdedfb4b4b30a6645136',
 'bdf0a5a3ac64c8c51cc0',
 'bdf29b1f6aeacfa69a15',
 'bdf6756588d07243f08a',
 'bdf831c437994c486bd1',
 'bdf869a27d28b0a1dae1',
 'bdfb5f4ff3e7f3364651',
 'bdfc5cdf0153ed128db0',
 'be0185cde207824adfad',
 'be02598a6ac0eab9a393',
 'be03cec9270375d387e2',
 'be04a8fbbcb0090e3367',
 'be04dbffa10b2360af9b',
 'be05e8d1b37386b4915e',
 'be0753a462d6de214edc',
 'be0b8313a69d990568ef',
 'be0d384c837028ae3bc7',
 'be147bafdff22fd35034',
 'be1836171c039e585155',
 'be1a3b59640fb9a90d01',
 'be1de24f7128488eb666',
 'be1e209b137a6aa0e7fd',
 'be2227f18d5156123531',
 'be24c8b037426101bfdd',
 'be2a0cad27615d29b502',
 'be30afc6baf9aa5703e8',
 'be346813d085a5a6e60a',
 'be35eb9a15ac1ab90fa3',
 'be36322f86ae3c01f238',
 'be373c5ebf29bd6bb915',
 'be3ae55a4809cdab19c4',
 'be3ec9a82761cb2a2307',
 'be4077f9531ae08da793',
 'be425ab0edd147b22a75',
 'be439cd4599bff7e6559',
 'be44b65f00f5dd035f63',
 'be4902fc5f8c4632cf4f',
 'be4b54db96bbe11db2b9',
 'be4fa19113a35e93aebd',
 'be512f6e542ff6cb3972',
 'be555cd537b24bfc10cb',
 'be58d9a3762db3cc616b',
 'be6400e967e57e63c722',
 'be6410938f4f2f7f5cd5',
 'be6470022355675055da',
 'be653ad39df58eb11eac',
 'be67b5792fc02e1f9733',
 'be681723dc7d704a203c',
 'be6a690e730d32950acc',
 'be6b918d3f33b3ba568b',
 'be729d978da2374d891e',
 'be77a4a35ed06d89eaf4',
 'be7940c42c9b7741fd95',
 'be7d1b0e8740258d5090',
 'be8491eb4227cbfe6c2e',
 'be8636f4b2631adea94d',
 'be88900584fa6f066d45',
 'be8897a8a0d0b2455a44',
 'be90edec1e8ea113db7c',
 'be965e46cc0ba29bf0e2',
 'be99898aa2acff0e04c3',
 'be9d9a2a23993872a71e',
 'bea0c70df3a1e81e506d',
 'bea148c76a2138306ad1',
 'bea509ce5f7440c0bc7e',
 'bea81cac47610fdb1c2a',
 'bead1d6b42a9a3013a70',
 'bead33d2eb9c96b82e74',
 'beaf86f6c15ccc9149d0',
 'beb7023ddf0ef1ee9cb3',
 'bec6d9776ff42d96e660',
 'bec79c5137b595114ce9',
 'beca8d98e174fcc63673',
 'becd05aa5b7856dd5a81',
 'becd2ee1b32106c648ac',
 'becf7c1accfb9d599a69',
 'bed0696dea687bdf5c0c',
 'bed2ce5d0eeed83f935f',
 'bed337241bcb34228e4a',
 'bed7fefe562eb50b268c',
 'bedcd8984292da2f245b',
 'bee5a13a447b4e1fb0b7',
 'bee7ceeefcd6584890b4',
 'bee98736f7384562fb7c',
 'beebb2f3a87549067f69',
 'beeebffbd512795a8999',
 'beef76ca525ce3454826',
 'beef9b1b28bb831eefae',
 'bef1acc348453fb8f98a',
 'bef3fa5499a293fd8284',
 'bef9353357ba2b78dd1a',
 'befb912075879cd34515',
 'befbe92ddebce958dbda',
 'bf022b8497ca580aa942',
 'bf0395511c32792510e8',
 'bf09a2919e7d08db6a23',
 'bf09c553d467a1329f58',
 'bf0af67f49fe5eb7bdd2',
 'bf1087a70262dd492853',
 'bf119a5f8849bcabb57b',
 'bf1545de5a0df7e43eae',
 'bf17178c998b6b3a72e4',
 'bf1e17e2d6debca1a808',
 'bf22ad5375d817a1994f',
 'bf2486803b11e79b9fce',
 'bf256f1c976929dd3a22',
 'bf25a1d3b64e42149bc6',
 'bf2bd2b72b189ace5a3a',
 'bf2e0a703163544650f6',
 'bf2ea08805ea0500a14c',
 'bf2ef4ab06dc056c5f97',
 'bf3094046a1fdbb1df1b',
 'bf30aa9dadd6848d0abf',
 'bf324f126166a77e5f13',
 'bf3795310175d777dc86',
 'bf39fcb74f5abe2757f0',
 'bf3c46c6f89b450b039b',
 'bf42944d1b544a484952',
 'bf444d8a83771f6b7b8e',
 'bf47c4f4c91225d4b375',
 'bf48158ec0c01c4097ef',
 'bf4c03c8e127c037e5fe',
 'bf4e3fb347f69eab7345',
 'bf524f8061575c73a0c9',
 'bf52b25650ae18e4ad77',
 'bf552893851045fac57c',
 'bf554e960eca10399435',
 'bf559ddc1afd97c5c8f7',
 'bf55b1acb76d935f950d',
 'bf592b5ff64453ee922e',
 'bf59ed2816b34625f03b',
 'bf5bd01903b3f99bf5ec',
 'bf5c9954792ce4821936',
 'bf5dcea7811a68247fff',
 'bf5e36ef61005566a784',
 'bf5f2d88d95ea709baf9',
 'bf5fb26a9bc1125a83f0',
 'bf679eab9c2d612a25b8',
 'bf6d5d610949736402c9',
 'bf6e5f5d527914d2119e',
 'bf70607c44bf62da24ea',
 'bf7171a8ce7259bcc303',
 'bf77957392c7a3d5906e',
 'bf7a49f5213f2ea0b595',
 'bf7c7733ad0199495061',
 'bf7d45a4ae4895dae9e0',
 'bf801b2c67d878d7c9d0',
 'bf83873340cabf3f149b',
 'bf89038d7f02d21d5ecc',
 'bf893cf1d9a716b40b89',
 'bf89cd872d02b14b5e1b',
 'bf8c16732aacb8eb3c2a',
 'bf8c74a2449d341be084',
 'bf92a344b5dc687be2f8',
 'bf9383c51b97b4e154d5',
 'bf9460573a4d17a6ea1f',
 'bf9aad821a3c3aef45b1',
 'bf9f3e49d57f8ce6cef8',
 'bfae17a09dee3718481b',
 'bfb04c8a17da9f82e65b',
 'bfb077c00e1fae17a9f4',
 'bfb30c6f758e22e328b4',
 'bfb5ead5b450faebfce6',
 'bfbc28657f36ff77d863',
 'bfbf88d825e3c597548f',
 'bfc4cb8bd95b6f8f64c2',
 'bfc558dd5c2ad3f1201a',
 'bfccb6964fc87013d869',
 'bfcd1c2f3d00eafcbab8',
 'bfce3791229965bc4711',
 'bfd2528b5c2930b61fd6',
 'bfd434fbc98397b80c9e',
 'bfda7c6277ec463c7606',
 'bfdb4cf2a418235d290d',
 'bfde7386936454aecbc5',
 'bfe33b2e15f068c59c6f',
 'bfe8e095f9ea2e45402c',
 'bfe9f45c64cd674e6f92',
 'bff6cbbdc1b557e60017',
 'bff9a30b00d305458204',
 'bff9d221691a72e48f0e',
 'bff9d7cc31d218a26b91',
 'bffa349a19ba9b40a0db',
 'bffefa8984a035e4a87e',
 'c0014908833a095cbde3',
 'c00333eaf365f5b74175',
 'c0051a4753a62978f9e1',
 'c008895350db100c309f',
 'c0095fd3305743b26313',
 'c0097ebe0e64bc672411',
 'c00b732233bfec3c02fd',
 'c012fc68a217ddba3dd5',
 'c0151f84cec8f1133bfb',
 'c0178b5a3c69455a0117',
 'c0198ee1ef3c4e6d7ea8',
 'c01a2d5f654f374413cd',
 'c01a84004292b28315cd',
 'c01aa8ecba472bbfb790',
 'c027cc7944efc2cec936',
 'c028f3d7cf570bf919a4',
 'c02addbaa23d1b110f75',
 'c02b30441dd3477f007a',
 'c02d8267958a5300f9d8',
 'c02e89996121559270f5',
 'c0302feb48c3db8a4b53',
 'c031e3d282f8e12782a1',
 'c03584ad6946401619ad',
 'c03711defc68cb16f55c',
 'c03fec59e3618d238653',
 'c04093b77e4926ce3ad3',
 'c041a0e74d7d74a440af',
 'c0424df6b4534e92d290',
 'c04340ccab80c0fba2ee',
 'c047911af1089f49c7fb',
 'c04b1333221c1f22d8be',
 'c04d9693ead3cbcbdc0c',
 'c04edc93c7b27775bcd8',
 'c04f78495060bc75ed8d',
 'c050bfa40cc3428bbd3b',
 'c0522aeabdc697ed5c73',
 'c0525d2db79422e0097b',
 'c0561152a14798999a2b',
 'c05b1bca50640ab92f79',
 'c05d996feee9bae3c322',
 'c05f48b0c9c872395954',
 'c060a871ff260b5defcb',
 'c062b8ea775f98b6a6a1',
 'c0661671dc4e4ae0d857',
 'c06f7d098e733959565b',
 'c0700cbd5328fa4ff073',
 'c07258e39f148cdabb89',
 'c07336de45bf5e5dd45d',
 'c0781a6bfbeea50caa69',
 'c078a7baf137e124e978',
 'c079166d8b697d8ffe5e',
 'c07b28332b0121b9a95b',
 'c07bc6c89563cbed0e6b',
 'c08267c3c6f8c9b20fbf',
 'c08b0dae67e3e5518ab1',
 'c08b5972d7f290706944',
 'c08b6f22ba3a63e8c9aa',
 'c08cbfe0cbe8098f9b8d',
 'c08dca2ec15383abcb5f',
 'c08febe05b8b2b181a6b',
 'c0936b60e3b577383d45',
 'c0938d2654137a6655ca',
 'c0941bb5114baaaa0b59',
 'c094602371cf9d0a8e59',
 'c09532c66ecdbd8000b5',
 'c09604ba11cd3d74b323',
 'c0983a7d24eb10315386',
 'c0994d409f52c2c0408b',
 'c0a068aa20230adca2e2',
 'c0a318cdeed32a2faf71',
 'c0a56f79a21ff7e91338',
 'c0a61a7f425de678de2d',
 'c0b03e8f4c3b28bc8219',
 'c0b5c2309a6f0054a242',
 'c0b76e8d68fb1f96236d',
 'c0b8809d20f67e37ab3d',
 'c0bb42e6208511c437fa',
 'c0c133a66ee084420a93',
 'c0c3169391611cad9700',
 'c0c4436608e5083356e4',
 'c0c87896470931ad0059',
 'c0c94c223e0711febaa3',
 'c0ca140c47c6d1eb36b5',
 'c0cbdf964edce85d071a',
 'c0cc2224eaed4c75995a',
 'c0cceb7b46d8de1a6161',
 'c0d2516bea61daa25d89',
 'c0d43ca7568779577193',
 'c0d7aa39b9dea0ae0109',
 'c0dc57a77299784287e5',
 'c0de98194a3dfd952f02',
 'c0dfe1a15b475e665453',
 'c0e4c566d1325a050110',
 'c0e5b868c8ca589b39f2',
 'c0f215e35e50d0fd2618',
 'c0f4d7a2a113c824c447',
 'c0f839525d41828975b0',
 'c0fcbdf483133a84ef32',
 'c105f360c4c038c09925',
 'c1068d251cf8f2221376',
 'c10718c2e30cc61300fb',
 'c1091d4f9d30d358a57c',
 'c10958e94e96c6aa6542',
 'c10cc44542e580965852',
 'c10d5128b10a634f8dda',
 'c10f148e7e71fad9c97d',
 'c11455068653eab40933',
 'c1171521db511e9342cd',
 'c11a6c002f3b1414f4ae',
 'c11b27d9892d3bbb5531',
 'c11c3b183bda0634927e',
 'c12360e9713315977481',
 'c123ee53cd2f9f497212',
 'c124a061bc7b0782fc78',
 'c1261967e86be50b1302',
 'c12b5366da43e6902714',
 'c12d5dc5c28a85421e32',
 'c12e500359e9e18d8456',
 'c1324a99f1e3f3e25862',
 'c1325674110f90bc78cf',
 'c132e0855c6cc4bc036e',
 'c132fcf05cad31d42d00',
 'c1347908b95d5535201d',
 'c1360f4ab8534cc02d5b',
 'c136191d305c8589a39e',
 'c13dec8134a094cdde75',
 'c142a11cdc8938ad6296',
 'c1435e39672232b1dbdf',
 'c14872f8a09501b2b6b9',
 'c14a1793813872053926',
 'c14a27de43c161e18bb6',
 'c14eb7d3b002a558f0ea',
 'c1521475a64e37ff3edb',
 'c154a7a4f4de4e0dd2d3',
 'c154cffce0d7d7005f6f',
 'c15646f22ab4321f71e2',
 'c158db05e9892db9f81d',
 'c1599ef99bbb9875e9ff',
 'c15aeebc7c96c11f5e24',
 'c15dcfa48fa57557f34a',
 'c165540f1789075498ec',
 'c16b8aa355d600560250',
 'c16c5e04673b5ccf8f05',
 'c1708f0bf77e3ee271e0',
 'c172d03f64c25f292585',
 'c175106cdbfd2137a247',
 'c178f770e34a51a2e829',
 'c17bf7a582e05fadfeda',
 'c17d20827f3823a88aa7',
 'c1809e0691dcb9292cf7',
 'c181c912abcb2a6e1615',
 'c189e1db5141f4f89f78',
 'c18eeafea73b2ad6d304',
 'c1903ed615e04a36f9ba',
 'c193c4435fe420507796',
 'c199f5962996d8a730e9',
 'c19f4e2cda3ef5f925ef',
 'c1a2d7b7329a92a5d20f',
 'c1a515bc79f02afb9647',
 'c1a7009809c6f2fb4251',
 'c1a8156ef9881810649f',
 'c1a92de568ea0c1ff466',
 'c1aacd9671938e102e35',
 'c1aefaf326ce07afadb1',
 'c1af16664074b039234d',
 'c1af6efaf3941463cb45',
 'c1bc2f48907e8bacd372',
 'c1bdbb4c6dc1627871a1',
 'c1be1d58068a434565b6',
 'c1bee608e1671c3b84d8',
 'c1c1600b05f9eba9dce5',
 'c1c463119222328e839d',
 'c1c5aa8d8532ef1255d6',
 'c1c6e0205a5ada8e8e7b',
 'c1c73dadebd8fb5cb7b2',
 'c1c7b29e9298c0844f02',
 'c1c93edfe53db5f80c90',
 'c1cfe3c31883d71af8af',
 'c1d05ae6e7d0692aa952',
 'c1d3d046694285c931b3',
 'c1d7a686b804b890a162',
 'c1d9d2d7fc33fa9db89b',
 'c1da9669a990933faa9e',
 'c1db11f9b265544db853',
 'c1de02a9135f6d484ce0',
 'c1df9a64044ce8f9d56b',
 'c1e00c5cb3ae2b7fde43',
 'c1e24e21590771fa7260',
 'c1e2fb5adfba92a411d1',
 'c1e3e346ccd3885303d1',
 'c1e55ff7064f7683ab79',
 'c1e5e8b7a6ebfbe6329f',
 'c1e7829d4db121d5a9fb',
 'c1e8f68efe2be92a6dd7',
 'c1ed8339b42712784f7a',
 'c1fc83ea0b7ff7955741',
 'c1fd04fc59e862a2ffb3',
 'c1fee023c55ae8b96330',
 'c1ff39831a6af842d03b',
 'c2042117f45f197ed623',
 'c208ab56afa6b088f62c',
 'c20b9e7eccdf84b308f3',
 'c20c3789d97997a89d73',
 'c20defa64dc87625278b',
 'c2101878e7a04589eafe',
 'c213aff85625fb3148cc',
 'c21b38240366169add27',
 'c21e8ac1d61a7b34c29e',
 'c21eefd82cac0b3daf20',
 'c2200c08266abf4b24b4',
 'c22095d0788f339e6c1b',
 'c2271f215756182f7665',
 'c22b342c49278e16b52f',
 'c22d88485bf8084143c7',
 'c230c62840990d1b4ac5',
 'c2321eb144418b79f3dc',
 'c232b4635a14d22c1158',
 'c23389d2379c7b8473f4',
 'c24018f3ab69f95197ce',
 'c240eb5bb314bd807e46',
 'c24140af2bdfbf015be7',
 'c246cba9a18a62bc17a1',
 'c248697d0a5b37e7ce36',
 'c249a0812d077e24c986',
 'c24a2c7e306d75486eb5',
 'c24bee609f7d36cfce91',
 'c252e57a127394cdc670']

# %% [markdown]
# 19

# %%
qids_19 = ['c2542370907e65b45b9d',
 'c25ad0fce30ac8ce6e69',
 'c263fbcf45d5d4c49be2',
 'c2675895099730c8a28e',
 'c26f59fbd29750ecfe89',
 'c27f54d15cd126390cbd',
 'c284dd54426230d270b4',
 'c2899537d66fdb0063a1',
 'c28d2e0f1537102b5f4e',
 'c28ef7686da8e6b385ac',
 'c297cf133fd0fa32c871',
 'c29fb3d62777649906e9',
 'c2a0a06831f2554f5790',
 'c2a1043daab4af2cd1bb',
 'c2a41ce0cec91f4f4aa2',
 'c2a7e5380a4e928f7993',
 'c2a8ddc003d47d0d238a',
 'c2ac8bb0e8c876c829d9',
 'c2afc27259e5d471f857',
 'c2b80d30665f64daa002',
 'c2c34bcc7545dfcbe026',
 'c2c43866927026d1a9bf',
 'c2c8d94d74e6f3b6c0d2',
 'c2c9a523c6aced595b8d',
 'c2ca81df7122ecc3766a',
 'c2cb397af056c608d02f',
 'c2cc8e1bf23e7c942b49',
 'c2d273600e077c392055',
 'c2da356c81bba0d43b8a',
 'c2dae6f3062356ccc2dc',
 'c2dd84ffa76580ac1960',
 'c2e064a4397654b53ab4',
 'c2e088cf084694170b29',
 'c2e20d5c34536d8d0d6c',
 'c2e2b667a659ad16063e',
 'c2e33a60e30d469bd419',
 'c2e60996a433d1c23aa2',
 'c2e65eaf6b2d5cd72a8d',
 'c2e99f6221a2c00cf337',
 'c2ec16057d14df70995d',
 'c2ed622adfa95a62d078',
 'c2f44fe80d190c740bd7',
 'c2f57fed7b50d8ed0159',
 'c2f6448f7547fb723443',
 'c2f7a2259db4a7b329ca',
 'c2f8b33132be07186b5c',
 'c2fa0b3ce78c4f5956e2',
 'c2fc2b298e23867b7c74',
 'c2fe49b4041651d20aae',
 'c300c1f904f1c3abcb93',
 'c30297e370a70742f5fa',
 'c30349f4d7fe86a1ad4f',
 'c30506183df6aa5661ce',
 'c3063d45bc1c7afe3301',
 'c307ec570692430edf7e',
 'c30b912dfc3b60c27be9',
 'c30df343a94138a87bfe',
 'c312130da574e2a5cee0',
 'c312f2ae9587faafa90b',
 'c3264b0ddd982b1e3398',
 'c3279959544aa89b6c94',
 'c333241bf6f12a602eae',
 'c33433f7a9fa20b6c5ee',
 'c3351ea82adc2c25d226',
 'c335d687ec71001b6db7',
 'c3384a8dfae4cb006648',
 'c33ba4c1f1ad44f2ec55',
 'c33f13a291fa4254ce4a',
 'c34103325eca718f030c',
 'c34206d28d04685141bf',
 'c342ce21ed923ce43b7a',
 'c34b98ab65e628beadf1',
 'c34d1037f6e6d946c1b6',
 'c34d888db13056b5dc75',
 'c351a9f0bd43f2551871',
 'c352798bef23104ecb81',
 'c35626fb008f5ffe9576',
 'c3565dacb3bcf09aedc4',
 'c3574ed521afb61ed788',
 'c359b82765ae615f2265',
 'c35dae3f7650acd92961',
 'c35eff8c168def4d8d52',
 'c35ff9045c053afdd372',
 'c36568d64cd0db89455c',
 'c368c1ef25329c627670',
 'c36a6144979b5a5df8d2',
 'c36c8b762f3f04fdff35',
 'c36e6fbb9faf0919baab',
 'c370ad6c99187478eb14',
 'c37128a8f675918ec397',
 'c37361c97ae8be34797b',
 'c37545834b0ec0141940',
 'c377594d6a98ca2ac4ef',
 'c3782316a25553043ad5',
 'c37d03a2e7174792fdf6',
 'c37defe758c89f15e311',
 'c38219f9a7bdc1a57fed',
 'c38257af1ef34f7b26be',
 'c382bf6af5807d8c78a7',
 'c383a293ebed330d85cb',
 'c384cede1a8d6b44b15d',
 'c388f98c3b91b66a0ccb',
 'c38bd884f68cf171681e',
 'c38ede3635e40f6a03ff',
 'c3922a358871383485b0',
 'c3944aef4c1c39c84b6e',
 'c395bf3aab32fbe759e0',
 'c395f8535f628dd3ec93',
 'c3963fc50e3ad607f2b3',
 'c39822cec25a6e7c285f',
 'c3988d724a75018c68b9',
 'c39e5354af048bd920c7',
 'c3a0e4c9365f76b09390',
 'c3a632673be635072d3b',
 'c3a66f5b3b4ca9840b52',
 'c3a8c6af43d7e662eb5c',
 'c3af1c5e18bb7eac0b75',
 'c3b061b4d61339e4b0b6',
 'c3b1373c8cfc11f6b5e5',
 'c3b6363236bd98b86b9e',
 'c3b750e7069b790d91c2',
 'c3bd8172ee5cc7788d5a',
 'c3be98c6a6d8f6ca1eda',
 'c3bf7d6a444acd20476f',
 'c3c6f9f28a86911b110e',
 'c3c7299be753ac912fd5',
 'c3c86f480ddfb7f8d9fd',
 'c3c8ed072b67dc7659c7',
 'c3d07d70d461b8b36a48',
 'c3d123dbe623bc932d7e',
 'c3d2891a6afb04390665',
 'c3d4229c2d97b342dcca',
 'c3d53df7f2a4f879686e',
 'c3d661481f1ce228b958',
 'c3d7e9de19dbbb99c008',
 'c3d84d4bef001da1dc73',
 'c3d913761030615f85e5',
 'c3dadc660955dc17ec3c',
 'c3dd644758b7dd69f396',
 'c3ddbfa3ea6bc58e4eca',
 'c3de1ac78d08095ad1f3',
 'c3ded4956157393c39d1',
 'c3e1ab13e7fdc8f69c6a',
 'c3e3698eb6978501b55b',
 'c3e9113ba71d4ba986a2',
 'c3eb18b4ed6eb0b6724c',
 'c3eebd276040a9e6d3d2',
 'c3eece38a2c94217fac5',
 'c3ef4327436c56c21894',
 'c3efed1b065a45785303',
 'c3f2765dfa2486367a69',
 'c3faee05e645a9ca4026',
 'c3fb8329188163d00f9c',
 'c3fbdb461cb4a097ea6b',
 'c404902cace4dfc0242c',
 'c407282d9c5a367f9fc9',
 'c407e5b1869cae0563e0',
 'c40e5e094ec38402ca52',
 'c4116ab4ee84d092e447',
 'c412299773f3d8a9c207',
 'c41b68095f0c124e64f6',
 'c41c27221776a4e95e9d',
 'c41d0098c517adab903f',
 'c41dffb8a3918124d744',
 'c41f8826f5183a165b97',
 'c42060f08b04b1a62327',
 'c4210efbc9c329506c4f',
 'c421b77306e067513819',
 'c421db0cb76579e873dd',
 'c423f0c0341c27822dfe',
 'c4311f5d7a23149c38de',
 'c431c05295fb35d53877',
 'c4324b3d532344992c18',
 'c433bc1f72932b21cdf9',
 'c4343c7ed0a9dc3b2628',
 'c43737b61f970073af29',
 'c437fb5f10c60117e4bd',
 'c4426ab91cc2e887d685',
 'c4460f6eae2dd66bb7f7',
 'c448736a14333e71d2bc',
 'c44b9cd8fdb19198c3e3',
 'c452f3d94eabc8a3b5e7',
 'c45695a7bb5cd7ee88b6',
 'c459e88f7b1f4185d0bd',
 'c45fd9cfedc148d56550',
 'c4631549dde08e930628',
 'c4640e68e0feed507dd2',
 'c46577f04caa1514b2c2',
 'c4657b4939701ca1863c',
 'c474b5528dfbf8955dc1',
 'c474b688341a0e1bb25f',
 'c474f636bc7e336f06c9',
 'c47a8990518c09a871e1',
 'c47d6496d82f5085c367',
 'c47d936752833d094a8e',
 'c485a177d8a9fe2b4062',
 'c48659284f707eebb47d',
 'c4876978ebee5fdeeb9d',
 'c48b1e6cc3b585161541',
 'c48b3505c3f739c49234',
 'c48bd022b2cf370f072a',
 'c48ca192fadca4b205b3',
 'c48d526730db2ec24b74',
 'c48d5b2a1c7aaa8d1520',
 'c4905fc88983045b3280',
 'c49256878014152a5548',
 'c498133ce2f426686de1',
 'c4983bccde5af637e33a',
 'c4985f5796551a8ff0c0',
 'c498e86f59eb8cc63d00',
 'c49e28dde662a97ebca2',
 'c4a21f18c29e51104365',
 'c4a3dee826a491bc2330',
 'c4a546aaf717fb8dfc17',
 'c4a71e0ffe31ba57b1bc',
 'c4a96ba7c636b6f57d40',
 'c4a9f4b95a36e1eafa83',
 'c4aa18ebcd03c6956604',
 'c4abda12f85cae705391',
 'c4ac715ded32be1d908a',
 'c4b08285f8f40712c1a3',
 'c4b1be3605a5b8770a3c',
 'c4b7a7223130a7da22dd',
 'c4bbe3d1a887327e86c3',
 'c4bce5a3ba41856ba009',
 'c4bd0befeea94e929bbd',
 'c4be334e48dadd0450fc',
 'c4bf4fb0975e9dc556d4',
 'c4c04972e029c2ee0f7c',
 'c4c267d5802f9087eff2',
 'c4c4771867452270087f',
 'c4c73adfcc58aea89f3a',
 'c4c91cf32a5b2222aa48',
 'c4c997908e45021440c2',
 'c4ca404553cb9b8718b0',
 'c4cd8234cf2f9b4ace16',
 'c4d0a4464bf4a0bc6d25',
 'c4d15f1e78c00fefd065',
 'c4d267aadde15d8b7718',
 'c4d28ed463e60af1d7a8',
 'c4d3beb2e42179cddff7',
 'c4d4683685552c28a540',
 'c4d5052cb8ca9ac76a76',
 'c4d8e5f0dd1b67d1e7a6',
 'c4dac9b5c6f186add871',
 'c4dc7d78aaf2064c2888',
 'c4ddad49f01b00b11c99',
 'c4e4a287dcb24b1eb10f',
 'c4e87b6b40dbd23cc50d',
 'c4edfe9163fb1169384f',
 'c4f3609bdfcbaa09bce3',
 'c4f4c35538565a4effeb',
 'c4f4eb2766b79d9e1da1',
 'c4f892fd4ca72289a198',
 'c4f992b1a919a313bb84',
 'c4faa0855cec740a6773',
 'c4fca29c5ade9899eee8',
 'c4ff374a1827ca042322',
 'c50417b83b8809bd2b73',
 'c50923676931dd0b4966',
 'c50acb251dfef527705a',
 'c50af5ea2bd69edf7cef',
 'c50be9fbdeed8209b20e',
 'c50f516c37e0d3ec54d2',
 'c50fe77f918d9733da3d',
 'c512a01fc40f1ee50f74',
 'c514bef7d85c39d63b2c',
 'c5197b33e1213ed85877',
 'c51a0b556ee73bc69c5e',
 'c52365f6ed94bccd7ace',
 'c52a870e67e22430c183',
 'c52f25a41552dad86473',
 'c52f2826ed70a47d5cb9',
 'c5346d552955990e65c1',
 'c5370242c503c781b606',
 'c53740934125ac7a93ef',
 'c53e9902694acd7d9c37',
 'c53f1e35da3d0b16d2d6',
 'c540556e29ba03cd1f56',
 'c541eab036d913962dcb',
 'c54383a98bce4b18aa26',
 'c5453f79ddc0d4e15dfb',
 'c549ee734b16e4ddf6b0',
 'c54c22db85c5abf73ec6',
 'c551ce42b499cd390221',
 'c5524de9f9335f86b15a',
 'c556ff248aaa9cefdb73',
 'c55981c46181f73491f4',
 'c55e86fdef2181302dd1',
 'c564171793a4febf2054',
 'c571e4deb7f7efd6ef3f',
 'c57437c6491743901332',
 'c574a3290e7662187d93',
 'c576944010f5144fc943',
 'c578a70034e6941f59b6',
 'c578e539993a554b53cb',
 'c5795b23c62bd82294a0',
 'c57b42a41b9f53f4688a',
 'c57cd95602d66c86fad6',
 'c57d385948620c824ac5',
 'c5800479678176c56665',
 'c5829951afbe963445c1',
 'c586e6b401e2cba0cdff',
 'c58f9fd5a507e114cd25',
 'c5901f6cb8d81a4d3bb2',
 'c5906265748f6fd01029',
 'c59205a10d9be59f0bc5',
 'c595b6d9e12779bb043d',
 'c598755cf1df5ca7e361',
 'c59aed7d93825d17d620',
 'c59c08964659f4ee77b9',
 'c59e171e8df4c0b0ae3e',
 'c59fc4069b34e2447079',
 'c5a4394683396660e4d0',
 'c5a4ecd7de8662c036c4',
 'c5a681c1d50c497b651a',
 'c5abdaebe99cda9b99bb',
 'c5acd1c264266391a1c0',
 'c5af9d23dbfcd39467ae',
 'c5b5a5090cf8b93a16d2',
 'c5b633fa85ac29949578',
 'c5b747ead2efb3579123',
 'c5b90007fd44ff1cb374',
 'c5bac20407492d9a1e30',
 'c5bb03d2fe1c94ef60c5',
 'c5bc3501171415f2a413',
 'c5bdde83efb314bef2f6',
 'c5bde23af61d189c8321',
 'c5bfd7ba6dfc3203a9de',
 'c5c26078d6ead5e6eee3',
 'c5c318994e4dbe7d469e',
 'c5c51e091d1e2ecdc41d',
 'c5c53cbadcf15aaaf1d4',
 'c5c700c75501257a2cd6',
 'c5c79e268455fe62ff92',
 'c5c9808142406971f790',
 'c5ca8f5e65600d409909',
 'c5cbb26f8b78dd17193f',
 'c5cbfb446eeef746e88f',
 'c5cdcda077a516726d31',
 'c5d015098d39f17c748d',
 'c5d27e6458aeb13da30e',
 'c5d59658c98221ab1a05',
 'c5d77e11ff9e7d1cbfa3',
 'c5d869dbc75117f4f1a1',
 'c5d9d3363809c0eb99d7',
 'c5dc10c96bd9d80ec597',
 'c5ddb2a2f4e280e2ce1d',
 'c5e3d983bc468f4f0bda',
 'c5e5e8dc7212ab1b4539',
 'c5e7ac2c0a174ba162d4',
 'c5ea4666c51990d187ec',
 'c5eadce925652eba95b8',
 'c5ef3c34d3e761da2299',
 'c5ef7c558be56e22b50d',
 'c5f1b3714468bccfd069',
 'c5f575bb82884a8cf892',
 'c5f5f4958472c9d37b6d',
 'c5fdb9dc8a57838b3438',
 'c600acb09971258af804',
 'c600b744ae27f786947b',
 'c60265372f43b77a7224',
 'c60584712f90f5a33f18',
 'c6065b4de16ac4aa408a',
 'c60bc82a325869a90aa9',
 'c614499530eb36c346f2',
 'c615c2f97a8593662dc8',
 'c615e60b5126795f1301',
 'c6180fd464c8cd8409e1',
 'c6195da6302519e11429',
 'c61d9096a0f8d79f7cfd',
 'c628d7eff28f3a7628e1',
 'c62b34da35e72f0cd985',
 'c62c5abe9626f17e6c8c',
 'c6326cb7d094bf831095',
 'c632d4956682261bf42a',
 'c63443ef83bebcd01b4e',
 'c63a5f3216906cbe02dd',
 'c63bfa2187e60b973d4b',
 'c63d023cb302f5ddfd16',
 'c63e86526f7a74061d85',
 'c63fe5c557f969e6cb6f',
 'c64067d7f6cf0291d837',
 'c6408a6d55ce2e056fdf',
 'c6413dba6da0bbae7219',
 'c6486690234446ffa950',
 'c64a3a38f8b50fe0d1ae',
 'c64a56f482fe54fb88e2',
 'c64c4fde8700f355d814',
 'c64fd203b7bf8c6986cd',
 'c651455de4cd9760b6aa',
 'c6516d11a808c965d0c4',
 'c656ef9ee8e740041e46',
 'c657ef351a1135c19202',
 'c65d4ee865a6eb566f95',
 'c65ec4f34128c8f46287',
 'c6673b525ce686d34d9d',
 'c667eed274451228ee10',
 'c668e0c6814e4b417e1d',
 'c66babc3bbc782dd7447',
 'c6701c6c45660ac27de7',
 'c67214e41bab5603effe',
 'c6736d278f2363339c7a',
 'c674c8381e7647a14362',
 'c6762ae33fbfe45da319',
 'c676f288885b48f7091f',
 'c679e6198ba7e53a4230',
 'c67c8ba47c74abc65b87',
 'c67ea13fc4977b2a03c2',
 'c67f4904abab804b972d',
 'c6800319c8057ef3ce8d',
 'c682bdfb6ce0ec0631ce',
 'c6878da3e310d4675001',
 'c68919ce32436cda30ed',
 'c68d6e3e6233e201ad46',
 'c68e83ae52c9706dac48',
 'c69283560b6569c26763',
 'c6979e40dd92e5881ed7',
 'c698b9c8b98165694b3a',
 'c6997bf6750c4da8a33e',
 'c69d87434ed6d0665bf1',
 'c6aaaaf59b748857743f',
 'c6b0854e8224c3e4b112',
 'c6b1c276aa2c860d5150',
 'c6b312d8f290c3f44854',
 'c6b4a49d1c975034f8cf',
 'c6b7868dfdbe1eba57cc',
 'c6ba8ba37f68da12363f',
 'c6ba9b86213149c9521a',
 'c6bb700e0de2994ce8e1',
 'c6bb720fd1ef55919aac',
 'c6bdb6f42a7a7ca52d62',
 'c6be75914eba34d5a018',
 'c6c01e730dc7ebca5d98',
 'c6c93beb7e45c2333048',
 'c6c971e42f56e7c90dc0',
 'c6cd367914a66d12177c',
 'c6cf405550be8f1c1733',
 'c6cfead36f781085cb7a',
 'c6d0a6d6d1b85ce6cb3b',
 'c6d393ecb8c332f85327',
 'c6d3c9a094fcd56f9457',
 'c6d4fdb6a105e7b12a93',
 'c6dbb739f6824c17c21a',
 'c6dbcd143c6705417ef7',
 'c6dc1bf43704878d4307',
 'c6e013e15be4faa3036f',
 'c6e2ecb3182746919010',
 'c6e31e286748b7f00364',
 'c6e40eefe7e1c32ee154',
 'c6e48915e75560b9284e',
 'c6e81bd1c8fe7fce0a52',
 'c6e85d479522e76ad7e0',
 'c6ecd80b35125f798c4e',
 'c6f0b000385a8a967d12',
 'c6f7336edb98d6c5d1d3',
 'c6f854ac557f2e7b4bbb',
 'c6fa62e79aaf8a0cc26b',
 'c6fb63dcaf2a984d5420',
 'c6fdc661bd285f8355a8',
 'c701e4e4c3ef48118444',
 'c7082fc708027a6a59aa',
 'c711e3d50239dea1d64a',
 'c71658d23559cfcf4ac9',
 'c717397253e60beb055a',
 'c717ef403d9c676b567c',
 'c71d12a489cb4ccce1ed',
 'c71e6d8bba2715e989a1',
 'c71edf51a808a28e85e8',
 'c7221d9ef543b700a366',
 'c7236913db60f89f6c29',
 'c7260c6d002605222ff4',
 'c7271ab4f9348af6e827',
 'c72c6de7b59f2980125b',
 'c72ce51ea0f252ab0210',
 'c73453649c140ab2590d',
 'c73aa707d1120e42b9d2',
 'c73bcabac49f5010555d',
 'c742e7a771b2fe8b429e',
 'c746390623bfed71ffa0',
 'c74a15c7f0f60d0b1b4b',
 'c74a1dd87caeb1f08b13',
 'c74e2f2a3ad96727a904',
 'c750e78775e317dd25be',
 'c751d0c5b31d7420b561',
 'c754701894f63cdb1065',
 'c754f08d3cd1ca559dfd',
 'c755afba3c0a44fc77ce',
 'c755f678ee8e9b13f2cf',
 'c75600a182a34d0b53b7',
 'c75887fb085238321348',
 'c7588e305f3c82597f33',
 'c75b11860803b6f43dc2',
 'c761e426e49e284dd1ac',
 'c761f2c5655f7512f242',
 'c7640ad342c56afc846a',
 'c76440f6ea298fcd3468',
 'c77d91b4c589aa7f446b',
 'c78703bfc26e35f734e0',
 'c787c710d9283b70c16c',
 'c78c5904f901b59210e8',
 'c78d03118a461e61e2c9',
 'c7914c862ca8d53fed5d',
 'c79c18acc4306fb4d19c',
 'c7a6d847f08b627b129a',
 'c7aa5a470142dc304690',
 'c7abc83de2810e978c70',
 'c7afe0aeef3c0a1c0408',
 'c7afe0fcda7a67fc85ef',
 'c7b416f13d2cb8bb94c5',
 'c7b53f26553e1694d839',
 'c7b617326d6575cb58f3',
 'c7b9187f70cf200140ca',
 'c7bac821cf7cc8b475c6',
 'c7bd6a89d987a3c3a3ff',
 'c7c3ddcbf75bbf28e9a1',
 'c7c60f1b311246871bcd',
 'c7c9d37cb358480d27fa',
 'c7d067ff40d3c097d90a',
 'c7d11e0ef0c5f913fa37',
 'c7d2ef2b6c32c4469b37',
 'c7e1ad4b6ae9e2b75b13',
 'c7e34650c7988ca29ccc',
 'c7e5fffe574f7ce5cc47',
 'c7e7560481d4b7549f37',
 'c7ed171f8cbf9357b737',
 'c7efc6ceaf16abbc5b5f',
 'c7f45d62300aa892dba2',
 'c7f605a05e0dba071eac',
 'c80b995e607a2a2b4a89',
 'c810e39f1c92e5b16e51',
 'c812f273c998b783b9b4',
 'c8187f2deaa2ac6fdc21',
 'c818cd3fba751d432142',
 'c819d3edb8d6b5e53674',
 'c820ab9be6f08639c67e',
 'c82477f4df6c46645a63',
 'c826e0c56cb8541557dc',
 'c829ed4d039da5240f49',
 'c82cc1a0baeaa5ba0ab3',
 'c82fdcfca52ec11a95fe',
 'c833e18572b6e8a2d14a',
 'c836813f9c7b38577874',
 'c8368a13c56481557252',
 'c8368cacc24b8fd9479d',
 'c836cc75ee0aad8585c0',
 'c8370c7b8afc80871a5a',
 'c83af1a06ae797cbb7f5',
 'c83b2e05e264ceb1f4fa',
 'c83def987f70ca2240bd',
 'c83e877f8c0272aa9d90',
 'c83f16cf1ceac1559058',
 'c84955cf15fdf2a40a82',
 'c849eab7a036885a08a4',
 'c84cbff5b578df64633a',
 'c84cf81fcf988a1318dc',
 'c84fc63ba849f3640596',
 'c851205c5d0eb36f449a',
 'c8521f5ebd2f0b0c5be4',
 'c856b7cf15d40fc0ffd0',
 'c858b695ecb712681e35',
 'c8591e33a35028723109',
 'c85ea947a13a7d7c12b0',
 'c85eb88b350cc5943ac4',
 'c85fb7ea93df43d135ba',
 'c862c31f5e76139d3de8',
 'c863b42505e3bfa65ec2',
 'c867c8a0ee64fdb4c5e8',
 'c86821e0291cbd67f20f',
 'c86d8b6114fecab94e26',
 'c8732b737a31a55fc2e5',
 'c877bb0f2b0fa49b025f',
 'c87e6d548795ca72a222',
 'c87f9a6c9f86cbec7732',
 'c881b613a3b2bb36052c',
 'c884fa35c13f648d6ee2',
 'c88538bee6d225e1612f',
 'c886c87410b043eab007',
 'c88b81595075a7094b3a',
 'c88fdb9184ad41b7b301',
 'c89125c3d49318ac32e4',
 'c892ab3562c260de0a2a',
 'c899175187e12bf426c4',
 'c89a2b6b2d9fb42ec40e',
 'c89cbc51c0b3c5678020',
 'c89da2769ec9c6a0689d',
 'c8a0f7f5c66047e27859',
 'c8a27205d7f9e044d857',
 'c8a41a12ef1455530803',
 'c8ab39d027fbf4d2719b',
 'c8ad5c88e4e56e59c5b0',
 'c8ae2665739b4e14b017',
 'c8aecdef3aea08a30390',
 'c8b03e62d0c47754fd67',
 'c8b0c4f2376fa9bf2ca3',
 'c8b181a17aec0a3e34ef',
 'c8b3df90a9c5b5332f35',
 'c8b4872ec73f22e6c112',
 'c8b94d5b783afcf3e145',
 'c8ba436d3365bca83f86',
 'c8bc28edad7f24459a5b',
 'c8bcd61baaebd45ecdde',
 'c8bd0de7e90f43904b9c',
 'c8c0a487fec7b7cdba02',
 'c8c1c5ccfa87da908e39',
 'c8c34c6af28b17af3029',
 'c8c6d2e99fcc9582e0bf',
 'c8c857237bed9ab6d844',
 'c8c9b8f40cbcc6e86130',
 'c8cb5f3be046da2d77ac',
 'c8ccca0a802f2a9b67ee',
 'c8d02206e388de868159',
 'c8d4fd75ff82eb605030',
 'c8d57d66cf26a7a7cd21',
 'c8d80d2a4b7c5a478195',
 'c8d87990a7c8345aa617',
 'c8d8b632b92b418d1248',
 'c8da80ccf37526c38ecb',
 'c8e09d42052b5281ff76',
 'c8e44e1455ad04070241',
 'c8e5616e07c5a1398d0b',
 'c8e9774501152fc263c4',
 'c8e995d62da870d4fe4b',
 'c8e9ba690b40a0a541ba',
 'c8ec05317217490f0d5b',
 'c8ec4687c49961bebe76',
 'c8ed59ab2275ade692c3',
 'c8efcb7a10ba561aa306',
 'c8f2d6c8db8f26f4918e',
 'c8f39896d56d9dbff0f6',
 'c8f44451da404d5f2efd',
 'c8f673e25ba51268ff14',
 'c8f673eea0f2ff261636',
 'c8f7bdaf9253bc9f2fdc',
 'c8f81f27324b1c4a28ff',
 'c8fc3d8ebdcbcfc5c82c',
 'c8fcdd7b6f498f26be5c',
 'c8fcea3c7426c8c7d38d',
 'c8fecca5ab3ce0e3dd70',
 'c90161e6b1a456aeaf03',
 'c9029fee9c3aeaca0825',
 'c9047e4bd326221178e5',
 'c904bb424824ecb2d885',
 'c90c46d0031a30c1470c',
 'c90cbd4f799ff52744ce',
 'c90d97bb4da598c94dba',
 'c90eb5a487e5d400f565',
 'c90ef876c3fa47839dd5',
 'c90f926a71411d3e2b46',
 'c910081bdb0cb6bae567',
 'c9111226e72fa065b732',
 'c911c17a7dcc9b69aef4',
 'c91476b63a7ad3ecfc28',
 'c915e9dbaf6da57042c9',
 'c917b4f57edb2703045f',
 'c917f45a8495bf0f7165',
 'c917f6af44f1745e9575',
 'c91861399c8b379c0bcb',
 'c91972f32d6b8222e639',
 'c91a2409d2e2f043c5d0',
 'c91fe3d8ae4155126143',
 'c920b432f8c79b6bf1df',
 'c923d68eadb2d21f5522',
 'c925938b2bf02ba91c7e',
 'c9285c048648649e7cde',
 'c92a75a48d6275ee8911',
 'c930414ccabee58793e6',
 'c932f5276c93b2339aac',
 'c9349cd68a684c8abf6e',
 'c938555b42a2dfa7ea3c',
 'c9399e0e6ce28c9368c4',
 'c93bd65fc1376e5e1b9f',
 'c93c206354747b714607',
 'c93e818951ce48465c97',
 'c9423c4658594cdd50f6',
 'c9442d6dd707e996c0ba',
 'c944382ea9934bff16fd',
 'c94552aec874c1d4bbe5',
 'c94b173894a4c4564ed8',
 'c94b9adc72fdf417cc18',
 'c94d7ea8ac4c0995969b',
 'c94f0755530fba650b4f',
 'c94f7d31aea8da26f404',
 'c950311965ea75e4dc95',
 'c950ec1208a1f2e71130',
 'c95297e721b833978321',
 'c9547d8f50f1a653f432',
 'c954ba4a1dede97efdf1',
 'c956e6676728bf6f8678',
 'c960fd825173727c3d86',
 'c963503cb366386369f4',
 'c9651c808233f2f89a94',
 'c96ba625b3044ce2d4fe',
 'c96d2ceeddcf1eee16cb',
 'c96d9d3614df32213e31',
 'c96e392b1840703d8e60',
 'c96f71f7e5bfb753b4d5',
 'c9716c32a020f0ae5d1e',
 'c971ef0dce8dc4b7da7a',
 'c974b9255d41f60e4a1c',
 'c97540449005574981fc',
 'c976fd33e9f7f951ff79',
 'c977cc06288ef4116b0c',
 'c978c0f2e1c6700e4c38',
 'c979cf9a67ddacd887af',
 'c97f669d057febe10434',
 'c98ac30f131e0f24df13',
 'c98d2bd41e647bc93f30',
 'c98ee5c057f1ff1d71c9',
 'c99183dba2f4369ad329',
 'c9952310d3438bc32c47',
 'c996c73c3d4767bd74a6',
 'c999b3e32fcc8a6db315',
 'c99ba9750e993913f421',
 'c99c29bb5267f66ccff0',
 'c99d28bb22cc471f2761',
 'c99f6d44adb13dd6ba53',
 'c9a01b60e1cb5115128a',
 'c9a17aac6bada1204416',
 'c9a2f5444d58052f4c48',
 'c9a3103e60c23c179289',
 'c9a9b8841284be16ed49',
 'c9ad94b1c7f10324813a',
 'c9b07e86379ba3841397',
 'c9b261aabb82fd1fd7a7',
 'c9b2710c6bdbfe7143bd',
 'c9b3873e79950d362b4b',
 'c9b58821c2f5b533e014',
 'c9b7b5584c85a376749c',
 'c9c735600c702bb957a2',
 'c9c767731b1a96be57e6',
 'c9c7b97a45b766cba319',
 'c9cc60594abd3b8ab9c9',
 'c9ce932a2a1a3fd5eb58',
 'c9cf6f160270a6e67323',
 'c9d02726c42f0a171d7d',
 'c9d97564886e0cde31bf',
 'c9deb281f5e6b7cd61ab',
 'c9df0c2087e1ba6d8435',
 'c9dfb5c7fe9e1f729e70',
 'c9e02c26684011c59e7a',
 'c9e0bb754e16d86d3405',
 'c9e4a7eaee14086373d2',
 'c9e9394812883dd8dafc',
 'c9eb745192bf6b5eee6b',
 'c9ec290b810653b2fa20',
 'c9efa369f6d634428139',
 'c9f5b585cbdcdca08c7a',
 'c9f5dca4c1edc4bc6651',
 'c9f7ba02796d379c30bd',
 'c9fcdf793cdde024411d',
 'ca04106ded829811349a',
 'ca047411f7b518c55f0f',
 'ca062d4696e9d258a974',
 'ca07e81a9c01137cd649',
 'ca0a4eb6b7fe2fc2abd7',
 'ca0c64cc50b2d584dbed',
 'ca0c6a79b71ee994f4a3',
 'ca0fd71dd8c025ea5138',
 'ca11d95c4da35aadf4da',
 'ca1210b6052759dfb631',
 'ca14a04bb5e173762bd3',
 'ca1b18c18218b717da46',
 'ca1bc3150964713e263c',
 'ca1cc43beea3c8a0bc31',
 'ca1d30d64a101c6ae3ff',
 'ca1dd3872e363312d658',
 'ca1ee4490809f6c05a30',
 'ca215835908d8a5b0584',
 'ca258e05df5503b9caa1',
 'ca267132a0dc4f4e78a4',
 'ca2824a9e68081ed0488',
 'ca28cd175f9f924a196f',
 'ca2aeb613bc7a6d99707',
 'ca2b1c6ddd24a3d03ffa',
 'ca2c45aa656d6146cdd3',
 'ca2fa192da6ce6341e85',
 'ca339bca3b98a7bbafed',
 'ca33c787638d8c3bda03',
 'ca374afde20f5556c0d6',
 'ca3c59ac202aa4dd1b06',
 'ca3e6d98cd45b7078cfd',
 'ca43e22502351f9b9e35',
 'ca44d3569eea70eb1fd9',
 'ca486f96565c01861b73',
 'ca4b8fa82c8d6b937d73',
 'ca518fbcd4a1890095b0',
 'ca57652b059f670f3302',
 'ca57790c85077de7739e',
 'ca6022f905b3c38da08d',
 'ca6128db2d52bf8814b9',
 'ca6433c11c8a1b1d29d8',
 'ca6a3ec296babe38d002',
 'ca6a789c032444e541ec',
 'ca6ece8cc23d4ac769be',
 'ca70cd72a47aff15ab5a',
 'ca7cc6fc276f04fae03d',
 'ca7dec88bda9ada173da',
 'ca7f9633d4c373f6cf8c',
 'ca8517c8a066fde62b0e',
 'ca90a657412b006c7454',
 'ca957b4ec3d753560994',
 'ca9744691c3b66a4f6a1',
 'ca97891f9466a98abc3d',
 'ca9981542ad25e4d03bc',
 'ca9aa9b4d1045fa3913d',
 'ca9bf7e7834d186c619a',
 'ca9fadd773fb2469c46b',
 'ca9fbe03c227085ac777',
 'caa279f720d6575bb03d',
 'caa2c737c2ef694bbea9',
 'caa611197daf4003d440',
 'caa954e1debff14526d3',
 'caad2928e3cc15f270d5',
 'caaf091f5801a547a2cc',
 'cab24edb6c44935a9b56',
 'cab4cb0100efc3be9af7',
 'cab99748159f020bae2c',
 'cabc0a8f00e819a26b84',
 'cabc66dfeebf7c3b1cff',
 'cabe4ee73e6d69ff52c4',
 'cac0c60ed24b4d1c20d4',
 'cac665aa644bb72bea7b',
 'cac90ae5c2eeb3690c0b',
 'cacab7d95efd26c6f1e6',
 'cacc735ca8095d105d7e',
 'cacee2896a7e3a210565',
 'cad04e4c4eb133a6e95b',
 'cad279723c0bfcdf2bed',
 'cad4077c13118b44f375',
 'cada734bacc2cd0e6e32',
 'cadcd4ba3e6d3ef57605',
 'cade4107189a4b371a2a',
 'cadfe5e06790d38a0da2',
 'cae3301f5cf87c3ab65f',
 'cae35e58ee2a66f85eed',
 'cae4df95db0a20fec465',
 'caf0d04815936523a3f6',
 'caf15a944a6414e55110',
 'caf5965de8acd6ba443e',
 'cafafe94327dcbfe759a',
 'cafb74715f1f81a3284d',
 'cafd12bab0f21cda85f1',
 'cafff023bc458036b6f2',
 'cb0247fa2a3f02c8496e',
 'cb0257be3b4e73eb97a6',
 'cb02939d1bdd3403c3c3',
 'cb0c225b33425a979098',
 'cb0c94a12555bde86eb7',
 'cb0ea3a972599d3ce22d',
 'cb1256ace61d00d99f53',
 'cb140899f48b515af7c6',
 'cb15909879fbad0f5565',
 'cb1626545a01ce544ffa',
 'cb1665a3f11141a348f9',
 'cb17bee8c0b9f2e2c816',
 'cb1a5b07ada88f461d0f',
 'cb1e9b8b323ace93d4d1',
 'cb247b7663051ee963c0',
 'cb24e52c31b7fb663184',
 'cb2610c2fd3fc10459da',
 'cb262874d3fa2aaa5af0',
 'cb270b2a44c986353677',
 'cb2975e6c13502269a94',
 'cb2ff3e70c51073bbee0',
 'cb30c71f6be7eb1e7b01',
 'cb35ef161c4d333a23c6',
 'cb38369c38c22171ba18',
 'cb3847512679bc253d3a',
 'cb3d03fd30acf0c1881e',
 'cb3d44cbdae5bcb81701',
 'cb3fdd143f8ff1723b1b',
 'cb40b4e783c92afbab91',
 'cb43a95e21dcb52e5ac3',
 'cb456883b4b9bac4a09b',
 'cb45a63e054e0b854d46',
 'cb47cb3656bcc2a53a5d',
 'cb4a7cbfe6c1444895d3',
 'cb5757036b6f86bb2557',
 'cb5e84a9f6c5b15a3573',
 'cb62ffb0db48e7c4aa94',
 'cb63ed9587f9c82ebb59',
 'cb6489fe6e953b24ada1',
 'cb65e53fd5713c4f41c5',
 'cb67a011611727f38fea',
 'cb6af9eece504219852b',
 'cb6f85fe98eae21f7ade',
 'cb707e2b326d43eb4d94',
 'cb74c5831a596b3145bd',
 'cb7829cad4389df51b8a',
 'cb794c2dd232a88368fd',
 'cb79791fab39cdfcf527',
 'cb7c53bcf1560d2b3f4e',
 'cb7ec76413d120b7a00b',
 'cb82caf09dc084325f6e',
 'cb82de8bda0e2adf3a87',
 'cb842ac95dddef2b905e',
 'cb85639540ff9150dfe8',
 'cb86078bac7728d033ba',
 'cb8c73fd0a03d1e0dcad',
 'cb951014d4b031a90b44',
 'cb97f8861c1a27d26583',
 'cb9cd586b2158445b056',
 'cba2bdfa04b0158feaee',
 'cbaac582ed4a38948782',
 'cbabbbeeda8c3f251577',
 'cbac12345517272d38de',
 'cbac8ff0869e1f63ebed',
 'cbad6fcbe5c95682906a',
 'cbaf39168bf6e4af5dbd',
 'cbb0eb5ee13d15f71be3',
 'cbb345d2a775072d8128',
 'cbb3cb0f22209e8dafc6',
 'cbb8b66f9852784f597c',
 'cbc6c43fc355888ef952',
 'cbc74c2c4daf670b8879',
 'cbcb6ffbf5491f4fd0d1',
 'cbcf20e876a5ba610fa7',
 'cbd1f1ef7dd9ef217e60',
 'cbd7c2176498b74afc67',
 'cbd8780c581eea1fa787',
 'cbd8f4f34751c89209ae',
 'cbd954e5c9f411c9cd71',
 'cbdcc56d9105f2f45920',
 'cbddcd9875e17a6f6014',
 'cbdf81a5f40a7739df25',
 'cbe5fa7ed7dc7c2be030',
 'cbe9976fe9ebf6219ded',
 'cbe9cfdef4a177768c83',
 'cbeb0ad76ea88181d35b',
 'cbedf4e2ac7a301a0865',
 'cbf07e82ad2c8f9ab8db',
 'cbf1736e9bd57a26bba2',
 'cbf56db831a0bc47e16b',
 'cbf56fecb360f5683bc3',
 'cbf613f07284cbcc23f0',
 'cbf6fc78c7c0d42208aa',
 'cbf92c7cb2c538d0e02f',
 'cbfc2e96cdced1b10cef',
 'cbfd9e515f4bb90ee230',
 'cc00ec89dd7d37829be9',
 'cc04d23cfe09d1d7d3a1',
 'cc0a76dcc24300c73ee5',
 'cc0b4caccc9575d0b635',
 'cc0b82fbe5f559de0bdb',
 'cc1021fd039fa9205820',
 'cc1029c39ae1fcc1739f',
 'cc1162b928d4f11c5d6a',
 'cc12c571b67aedce4858',
 'cc130d9d6d1ebc1f4abb',
 'cc16ce03cc79ea92ae2c',
 'cc1f82e458a2424325ab',
 'cc2025af5a1da1b623f1',
 'cc25678c5159f362a3e7',
 'cc29682d96f51544e1f7',
 'cc2dff9b10dcd6fe012d',
 'cc3ab69868757118d381',
 'cc3dff47e3061dce5299',
 'cc4069c442f819f2bf42',
 'cc4107ba042c0e15b5aa',
 'cc42a43fb4975e0cd280',
 'cc4409dec3ac7d8acc22',
 'cc4420029c793ae3048e',
 'cc46c69d5c6257fdb77c',
 'cc46e18f8dfd5fbc91f0',
 'cc48d6e829d214acfa07',
 'cc4c9970bbdf85f38310',
 'cc517add38e5d89efa40',
 'cc52a35b1d5e50c32f5a',
 'cc53983b98375817f960',
 'cc558beb8102b4de90af',
 'cc5931a53d4fc2479e2d',
 'cc59c7ebd65b5fae8ee6',
 'cc649d65ecf9f6cee84d',
 'cc65d6d145643b9443f4',
 'cc65f6f4dc686d60a24c',
 'cc6723e932290b4c92cb',
 'cc6928391f7701b49c1b',
 'cc6a741adfe008aec007',
 'cc6b7d75f7ce8263cc10',
 'cc6ea0c158ae15dcaf5e',
 'cc6eb053a0637723a9bb',
 'cc6edef2d54cd029405c',
 'cc6f701a34856e5518d0',
 'cc7127158ee2fd95da83',
 'cc742f1d1c2e2d6850fc',
 'cc7452042f83546a44d7',
 'cc74990509b2744f39ca',
 'cc7737056ae06e28e289',
 'cc77a0b7a8f3b813dd46',
 'cc785d946d53d9f73899',
 'cc78bd39fbc23daaae64',
 'cc7d0ec3f80d81c013bd',
 'cc7ec38d3be2be9f52fb',
 'cc846b2326717f8d1c19',
 'cc85631e329c6a98d1f9',
 'cc869d004512f6896506',
 'cc8b19ad02ce1afbd180',
 'cc8c29a5479ca7c8d7ef',
 'cc8e109ea6da2140cfa4']

# %% [markdown]
# 20

# %%
qids_20=['cc8fe31d6c57f66e1c23',
 'cc912e3caf18265dccfe',
 'cc9efc01e55652b4c5d3',
 'cc9f9b494fbc59de584e',
 'cca53894a08dc1432a77',
 'cca741a93dc41b61a792',
 'ccabee941a1756723f33',
 'ccae4da0457582d0e83c',
 'ccaf7b1e551a0f56764c',
 'ccb94ba9c434e33f7fac',
 'ccc1506bec39ed6fac47',
 'ccc3966b60aa3d8696e0',
 'ccc51120d7f90155627d',
 'ccc8fc0384d32b28c009',
 'ccc935245d9cfa2c2c81',
 'cccb32e0ae5d9729b26f',
 'cccce0dedbf0f51e3e62',
 'cccd91bdb018f4118cd8',
 'ccd7b70cf45fd6233d6e',
 'ccd7c7ffb020ef5a99b8',
 'ccd8964f820061d76668',
 'ccdba80936f6cbe59843',
 'cce20581df66e165e7cd',
 'cce28aa8f06e24bc0e23',
 'cce2f1fa953710896991',
 'cce3fcfd3ac210e6ffa7',
 'cce67941f0c4b5c763ad',
 'cce6a0054f616631519d',
 'cce7d98e9e7d105bc8a5',
 'cce883d3844b4b2f7231',
 'ccebc005ffa51fd8c95b',
 'ccec34303f2754e716d9',
 'ccecc0a212637d2669be',
 'ccf4aa0b942af00f432a',
 'ccf6076e7ccea85fe1cc',
 'ccf6f2705b3e198573fa',
 'ccf80126ddcbff928aee',
 'ccf97e785a2db54b804b',
 'cd02b8841b22fae8855d',
 'cd038cea368728f54078',
 'cd03d98954b1b8927cfd',
 'cd04a0cc847fadd78ac9',
 'cd064c74ef229aee370c',
 'cd069d5828cc270321f4',
 'cd07255228d7eba4cc66',
 'cd073630436c253cb586',
 'cd0a4fd774afeab31dc8',
 'cd0b2caee186fa3219a2',
 'cd0cf60de472b2ae0490',
 'cd1080b24b2f9cfca4f0',
 'cd10fdf7093fd7c2908b',
 'cd14a7ce982507e49635',
 'cd19ff94f96396e324b3',
 'cd208563fcf19d8d8d08',
 'cd214a2c6b64f4996783',
 'cd22c26cdbd249f6b32f',
 'cd26369639ba96605b35',
 'cd280c2177ad7f065caf',
 'cd2893469031f14ecb73',
 'cd2be83ba45005877080',
 'cd2dcc72c339ecb2ddad',
 'cd34f63c937dc26e37fe',
 'cd3b9543f9d920046928',
 'cd3bca93c5d568862a73',
 'cd3ccc2d736d6539ce3f',
 'cd40ad03ecd033fa10c9',
 'cd4134ec258abfb97f9b',
 'cd46b9663fc8e20ec57d',
 'cd47e8177f880862f155',
 'cd4db85b4bc4792ef165',
 'cd4eb4636f669d145f51',
 'cd4ed1825c4c9944077e',
 'cd50747b00eac1e6a1aa',
 'cd50b9684527b19c58e3',
 'cd50c6882119e5f8a829',
 'cd5291c82e7fcae19bad',
 'cd5e6e6f96cad2c7761c',
 'cd63d22d73baf64313b2',
 'cd653ff2ab30ec0978b9',
 'cd6599cb58ac8dbfcfc9',
 'cd678fee3b91a1896adb',
 'cd69335277ba76578e25',
 'cd69663cf4e7bda9f2cf',
 'cd69700263c0d02d3054',
 'cd69a4bfaaa4a41f433b',
 'cd6c3f7a7c5d0b63e144',
 'cd709a2816d4af4377ac',
 'cd754716a7ae8c5316c6',
 'cd765f8c46c2654bc2e6',
 'cd782bbdbcfbf0a99e76',
 'cd82dd8f08ac6685d59b',
 'cd88619c0b45494d7938',
 'cd89407b7ec657d2735e',
 'cd898c180abb5ac6121d',
 'cd8bb941f8241bb2ba56',
 'cd8e751b1a469485f1b1',
 'cd9583cedf2455401ab3',
 'cd95cc127d5446e50ddf',
 'cd9dad8b9cd53b5022a7',
 'cd9ea8ebca03820b5678',
 'cd9f1c409f9275d8802a',
 'cda1c6b28b548d6006b1',
 'cda232aff4c60dbecd30',
 'cda5add6726747a8c216',
 'cdaaf6cde81258939676',
 'cdaca44465e869b8e341',
 'cdb2d2fb4f1636909d16',
 'cdb39811bc66c2b3cc2b',
 'cdb5b2b94e3acdc4a2eb',
 'cdb5c09c8597967114ec',
 'cdbb2af629b5bf46de21',
 'cdbc9aa79fd3882398f0',
 'cdbce1809066040739b8',
 'cdbe9c633656e24951a6',
 'cdbf03d5b4b028c3d8ec',
 'cdc1a4b6dc8f0153c833',
 'cdc69f1ca4ef4ee456c0',
 'cdc6d29d04076bc6436f',
 'cdc9afa2bd388d03c199',
 'cdcef86704a51fd47a22',
 'cdd23a3eec95a13ae650',
 'cdd46fceacd0c90f8666',
 'cdd8b317d137e2684241',
 'cde0151bb396442a0a03',
 'cde4127f518cd892b0db',
 'cde5709f33ae624b7ccb',
 'cde5bbab76a8aa2cb574',
 'cde640a6e553f7088b2a',
 'cdecdd5891cffa16483e',
 'cded6d316e71c1e53161',
 'cdee0cf0bf0a1d8c8971',
 'cdeedf162f3d886c0749',
 'cdef3c717846f0f2c430',
 'cdef9e7d312c64666ffb',
 'cdf43c4637e53bd8625e',
 'cdf64e11c964b503c306',
 'cdf725879ad2e57e84fc',
 'cdfab0937c1bc1376f32',
 'cdfe08a77233c12ffa7b',
 'cdfedcfc0d4695808a96',
 'ce03aac2ff0231a31b88',
 'ce054a4a02ea4456498d',
 'ce07198b5300e7d1f504',
 'ce07c1c98c2d5009e2fd',
 'ce0b5f2b7a19a4628f3b',
 'ce0f92c742bf1aabc0a4',
 'ce18e41eb0b88f31b4ef',
 'ce19328b7ce8f530bab9',
 'ce1e9f9849994f53e940',
 'ce1fa161a2bd3793f3a6',
 'ce20a48f12d317bee377',
 'ce222be8b4c4f21354fc',
 'ce269d081480f769be13',
 'ce2c94fdae82d0048b4c',
 'ce2e31372cb6c6686977',
 'ce3021151d08af413209',
 'ce3479317126514e7200',
 'ce34848c623ea71f47eb',
 'ce39666a349e1602faf2',
 'ce3eafdd0a9b0ea9ba3f',
 'ce40d699041afac4ae79',
 'ce44973035bf09d2aeec',
 'ce44aa2cef236d06a1cd',
 'ce475640368fc9fbea28',
 'ce4803e4393e112aab54',
 'ce4959fe774b1163e8ab',
 'ce497da14c0f5888457f',
 'ce4b08156059eeaf2ebc',
 'ce4dee6217905c2543dd',
 'ce50ab28f21a2832c1b3',
 'ce50bddc1d961021352c',
 'ce51b6c812ec2c5a0b47',
 'ce529c3bf4ecc54a375b',
 'ce5e4d790a6dc4b9d9af',
 'ce64605ace7a58668d74',
 'ce655ff26aa2f36de2ac',
 'ce6f91334103ee5f284b',
 'ce72d2d9445a0e22b9d0',
 'ce7666808791b1d53d1d',
 'ce77553b5dfb72955ead',
 'ce783fe6e4d7f057a64f',
 'ce7b8fcc94bb11b1ca07',
 'ce7e13094ee1749f8e38',
 'ce7e19ad63f309cf5ef4',
 'ce802b66c70c6cbca778',
 'ce803ab942af63efc5d6',
 'ce843ad391fddfcd0da0',
 'ce84d9e30a3288ce58c8',
 'ce85a5237a75640a2050',
 'ce8624c5ba9fe05b72c0',
 'ce86f445ccbbe28d955a',
 'ce89d207b56941eeda34',
 'ce89d71e1cae575da620',
 'ce8efb0dac44b34fad73',
 'ce8f9051ee6c66a2b0f5',
 'ce94376f71b2a5fc1bd2',
 'ce97150b5373421af876',
 'ce9a4f90c6774992923f',
 'ce9a72f4abde41b91302',
 'ce9bff24c494bac271ce',
 'ce9c264668ca935d17f7',
 'ce9c619fd778ccc4df8a',
 'cea0404c85fbc88c2c79',
 'cea1740cdce7a9e7e4ee',
 'cea23d3876008ef71552',
 'cea3773b790ec4632aaa',
 'cea6cf7218d747c94af8',
 'ceb06279dfe0fa66f3fb',
 'ceb194f9e7fa47fa58e8',
 'ceb40de5de43353b89c9',
 'ceb64250725c95e4bbde',
 'cebc4885dc6cfae86610',
 'cebf6a4ea9e9c7760f6a',
 'cec25d46315cce8af7fd',
 'cec2fe346077d91c9314',
 'cec82feceb5e7d36b5d3',
 'cecde4ad7fdcdd2b09c2',
 'cecff6e18ac8f266b978',
 'ced2aa8c64dc0a658dff',
 'cedaa95cd4205a961460',
 'cedc27b523ba34eff6ce',
 'cedf3f7ad4d27afe4e84',
 'cedf67691b5dcb3d264b',
 'cedfaece4501f31ea483',
 'cee24e5603b568f27d13',
 'cee33aafcd97984531fb',
 'cee46ddc980e33fc5d6f',
 'ceea0184cbb0cf17ba28',
 'ceedd751eb7872396e11',
 'ceef9a83b320343928d1',
 'ceefa98375143c6235c0',
 'cef27c1c666c39d4bcf8',
 'cef3b15bcf0f719a2035',
 'cef960aec7b2b754679f',
 'cefda94900b05fa67f45',
 'cefde4e7d7330f45124a',
 'ceff2d43e2a8e3ae8c18',
 'cf028fbc33601a2f4c43',
 'cf033bd97344efc4ecdd',
 'cf0349890f6b4c3e4a5b',
 'cf06a662060ffa4ef2a1',
 'cf07f03818d8407b090e',
 'cf0a49f358ac07f2f3bf',
 'cf129563b4a46862d72e',
 'cf17508c9237a44df15d',
 'cf18b18bb1797cd0808f',
 'cf19e2bcbd57dfcac3e3',
 'cf1c213ed1a6d7239b74',
 'cf1ce6dd4d786da6af8d',
 'cf216ad86ecf9f94f166',
 'cf27a8750dbb6ca67d35',
 'cf28af371d1b00bf79f9',
 'cf29c135e21b1957d8e6',
 'cf2a70b6b01eb2b67e62',
 'cf2ca9ad87b388f48490',
 'cf3396ffb54ce78aa3b2',
 'cf367649fe29ada2ee4c',
 'cf381a561b5f1306ed2a',
 'cf39c8287abcbf77dff0',
 'cf3b5222947fbbb073cc',
 'cf3ef29e231a0446ab00',
 'cf3f1a6e5afe6136b38d',
 'cf4052b37cad6942c793',
 'cf40e8be03017c34ff96',
 'cf44da4024416a746bd3',
 'cf453441a585d0c42925',
 'cf472a746839a3c29a8d',
 'cf48c7b9882d757365bf',
 'cf4ae78534c533fc307b',
 'cf4e99137ab3f8fa239c',
 'cf4ebc9691f50a902c4c',
 'cf4fd05f18492af3d6b9',
 'cf54a78ed6996cc9111d',
 'cf5a16f79db8071003fc',
 'cf5ef0fc6de795de2f96',
 'cf5f0252447ecc8ff1d2',
 'cf626f387d3d86900f29',
 'cf634b58a0c21d1f5ddc',
 'cf6496ee8fc55fc27711',
 'cf665c567920e8a752c3',
 'cf676a9df55782897dd1',
 'cf69331491254f944c57',
 'cf6c7e29ee5b2a554b46',
 'cf71dc2d23d7507d7dc1',
 'cf739fe0f3579b8819da',
 'cf78393598005b1c820d',
 'cf79946e1a180d96b31c',
 'cf79e1506d052f2daa47',
 'cf7b7c53456ca90d5e71',
 'cf7de6b8d7d5660c1baf',
 'cf8ae07fbb35e04b1ba2',
 'cf92a92d3731681d26f4',
 'cf93a8d22e19ebf41f77',
 'cf995f0d3ff9c94ca38b',
 'cf9964af0753e0ca5185',
 'cf9c8a8ca37a9c3c5132',
 'cf9fedcf05b97c59d58b',
 'cfa1b6163dcfbd5da6dc',
 'cfa3b698a7e6b07d5448',
 'cfa8d15dadccc0243985',
 'cfab3e66f0ea271030f8',
 'cfaf2f75aca8d7340e67',
 'cfb008e28a61eaf867d6',
 'cfb51d825a1fca586582',
 'cfb741a5aac553ae520a',
 'cfba3bf08177414091d1',
 'cfbcdbd6a805c15c394a',
 'cfc0d051aa650e54214f',
 'cfc2b5927688d226a913',
 'cfca31502b98e9f2c5c1',
 'cfcf8027425f5dbe11ee',
 'cfd07bf68ac47cdb2d42',
 'cfd152303507733609bc',
 'cfd22d755ca8d6a4d125',
 'cfd2be9d56aba7cdb597',
 'cfd42ecce5d2f9a90192',
 'cfd7c500e78f2bc8c81b',
 'cfd9b169c685109e4ce4',
 'cfdd0e9f7e2849615f5e',
 'cfe29a1be6c89def7385',
 'cfe30ad6faec0c1920f0',
 'cfe4d2f58f4a7db8eb8a',
 'cfe9b09450377c414745',
 'cfed25ea150072dc169a',
 'cff20dcfa43717fa42c6',
 'cff6ab05f1fb1cfc2e2f',
 'd005977ba5d6217ce194',
 'd005acb0367130434a3d',
 'd008f8c6aafc51875216',
 'd0099b041db8fe85871a',
 'd00a97cd21c634ac6fa8',
 'd011720c8063e3f822f6',
 'd012544177868190ceb5',
 'd0186c56d43ee8a78299',
 'd01acf417094da9f598e',
 'd01b14318bae1260d283',
 'd01bf0de21d150cbc598',
 'd023370bf2c33fd8dbbe',
 'd025fdc0fa84e5eebb06',
 'd026d6be243be0929a5d',
 'd030377a719261d32afb',
 'd030bc6235c052962986',
 'd0341005c6b2a1f31f06',
 'd034c59f91fa6efa97ef',
 'd03b4311b6ef7fb8274a',
 'd03f5ce37d8843fb778e',
 'd040bf012141b0a0cf21',
 'd04412b5db3e7dd6dcbc',
 'd045141ec03aae684688',
 'd045dd4a642eb671b979',
 'd045ee05f0f96826f0f7',
 'd04653230cb24542b3cf',
 'd046a68d2f3833f6c225',
 'd0470aec68385cdb8c60',
 'd047e63df67c0873c72e',
 'd049a8cb4b7a77eaf171',
 'd04e5f563a6f2f7adaaf',
 'd0548bbf4c1fde6d209e',
 'd055e3f59bea1d26a0c5',
 'd057475001e5a3556fbb',
 'd057ff3d49d414c06878',
 'd05d82e3736ae9149b1a',
 'd05f56687075311bf589',
 'd05fa21206b892382cbf',
 'd0625ce7f77589489afb',
 'd0630318967bbc54c1b6',
 'd063347dfcd923bab920',
 'd066bedcc956c6e0fa10',
 'd06856bfb78bd80fe00e',
 'd068bc895c10ef0e0348',
 'd068ece7dc29936a9849',
 'd06c5297905eafc9e39a',
 'd06e0862238e4f055be7',
 'd072dd60cb20a9b3e551',
 'd073758fe09ef05bea4c',
 'd07acbf442ecf2d95197',
 'd084db2006ad45b1c523',
 'd08aa82eadc2597dd374',
 'd08b1e42d943c3125e29',
 'd094f8551ab47e279469',
 'd097f2bca77ce8617cf5',
 'd0991169f15857f08e61',
 'd09a53b0a58d185dfc18',
 'd09b26020dcb5958e2be',
 'd09b58a80d8c649f273f',
 'd09dadbe3df1c207c250',
 'd0a30afa424957da5f51',
 'd0b135ae298625ef0d90',
 'd0b20a8b58527ddc4f31',
 'd0b819d9b5f2e461b71f',
 'd0c17c09ab214e950b2c',
 'd0c4f5ece3bdc49427f0',
 'd0c6d57783431fe7393c',
 'd0c85c72eebae9bc6cd1',
 'd0cae4766ce8f795b0ae',
 'd0ce4cd550b7d6279aaa',
 'd0cf7e920e83ece08cf0',
 'd0d35975049b8b49a43f',
 'd0d590d59c3a124540ea',
 'd0d5bd8dff6f9761a653',
 'd0d7b71de09c6eb9d5b4',
 'd0d87be8a6b024e0e78e',
 'd0d98223bba17df19df8',
 'd0db00e28b9242fa295d',
 'd0db51c29a028394261b',
 'd0dbddc53bc457739935',
 'd0dc8c3755b29178d923',
 'd0de965c98464c8b8237',
 'd0e4d602a7b870a5bad7',
 'd0e574ad3a19970d7a2e',
 'd0e616c111b2f00fbf37',
 'd0e78acff70951d0b042',
 'd0e95540f9eb4cc164f9',
 'd0ea37cab41fa4c5d395',
 'd0eb97515404a1231f8d',
 'd0ec00784573e86fbae1',
 'd0ecb4c9143246a4f561',
 'd0ee3e73b9b94e563d94',
 'd0ef216ab888c039069c',
 'd0f5062c50cf3ebfcde0',
 'd0f529d272a296f9a6f4',
 'd0fda4f4e05e3f9b5774',
 'd1015d4d706ec6018ae1',
 'd10166cd2c707e4cfebe',
 'd10363e88d94908f2b1c',
 'd105e25cd951b823106d',
 'd10752fac76868fadb28',
 'd10a9986280903c6179f',
 'd10c9b22d92aaed41072',
 'd1109c52ee8b7b7051ed',
 'd114d86071fde6da91fe',
 'd115909f3edd786f682d',
 'd116c2bef8e5754181ac',
 'd119bf48763deb5b96e0',
 'd11a20b02c05af446934',
 'd11d3e33ac1c7b6867e1',
 'd11d431a6e1f346c7cbe',
 'd11de775d2936a652a81',
 'd1203c94e207c7f2337a',
 'd12266c02a56f718e197',
 'd127ca891c1481ca6444',
 'd12c1cd819c6ce2525ba',
 'd12c7633c4c054fe812c',
 'd12f1ebd8009213e7f15',
 'd12fc5b2202c84ca4d52',
 'd13035903e4bd71248c6',
 'd1318d7e9724dd2e3a0a',
 'd132dd1ce2c054315437',
 'd13cf571073f3189e8d5',
 'd140b510183916cde6fa',
 'd143479f1240436b34d1',
 'd147928b987f585425c6',
 'd147e6fce22b6357f75f',
 'd148fdeefa9f904a8494',
 'd1490bd085a47bd585b4',
 'd149503bf6f202f7e88b',
 'd14b3d8e4e35c9268d23',
 'd14bee5ad2036c5e0d3d',
 'd14e06f2d1fd88183b15',
 'd14e20d8ed75769a2833',
 'd14f29f1eea79c89ba74',
 'd14f4701ce65f02f32a2',
 'd14fa55c3fea5f78a1f8',
 'd150981009758be28621',
 'd150e9681e772196b289',
 'd159e188eb966c89ace6',
 'd159fd52d1491710086b',
 'd1602953bdd36f2f5473',
 'd16ae75112af2240a22a',
 'd170dc5b23e2501fe6c1',
 'd172014a472ec453cd13',
 'd173fea282f848ecdbf4',
 'd177131f3b12bac56674',
 'd17cf836251d84861f07',
 'd17f9a70f0b94f5b89eb',
 'd1822e81d62dedd0faf8',
 'd183a214e3cf041a75e9',
 'd186e1a98ca9887d06e2',
 'd187e14c5d1fb8499acf',
 'd188b1cdb274b0c240c6',
 'd18b8eca622731cb4a72',
 'd19a34c2c1732856da67',
 'd19d6f2f871dfaf8f90a',
 'd19e38c0c3d5c5591521',
 'd1a4acc8a24e66858815',
 'd1a6464c4a8ab3c3f6e6',
 'd1aaf349698788d2ff9f',
 'd1acf10a1d8f742ad3e3',
 'd1b053cc71b9e03e7ee7',
 'd1b383d7fcae98023098',
 'd1b76cf08034a8dee107',
 'd1b867915c79866a882c',
 'd1bc1f0f73e6da445b0a',
 'd1bcd9fbe5497a00f83b',
 'd1bfe37c8887287141e3',
 'd1bffd4e9a11029b1750',
 'd1c73566005ba5c1755b',
 'd1c8370dc1936fb7adc0',
 'd1caa6cbaed084ecf261',
 'd1cb97eb750c9f23af27',
 'd1cbeca9391ab6c6e9da',
 'd1ceb7a38ccc032a4590',
 'd1cf1b8d0e6434c723c6',
 'd1d019ce2094359f219f',
 'd1d284fc12b9cf747dca',
 'd1d2c8095d1c7bee8d4b',
 'd1d3cd6a9ea12245874d',
 'd1d81ce621a17f447321',
 'd1dbaaf4d3186b199130',
 'd1dcd53c3f6354506283',
 'd1df57d9c1fed0b74f82',
 'd1e1d86ec06a7f1ff850',
 'd1e3be806382d9fad8e9',
 'd1f020e12e8a10bb139e',
 'd1f074e3416f1bcd9eac',
 'd1f380cc1c7b6a6f2619',
 'd1f59580063694103a8e',
 'd1f7b121fadf7ed29e29',
 'd1f868c2963684342220',
 'd1f929510a6fccd0ca54',
 'd1fb0f2211c58bcc69b8',
 'd1fd82f72e1846f67189',
 'd1fee671b8efb89997d0',
 'd1ff477dde9f8876006f',
 'd1ffe05e3c3bc43f6ed6',
 'd203a0971d29fcd424cb',
 'd208145864dda1b5df6f',
 'd20818b378aec023b70f',
 'd2089089ef03b45f0c40',
 'd20ad0973d96d2e0076f',
 'd20be8a0b9e0ddc887e8',
 'd20d5bf79ac5b8eb3635',
 'd20dacc790bb67621d11',
 'd211d988271c53f3cb28',
 'd21291affa22352e6362',
 'd212dfa34190ac99e3e5',
 'd213af7e3666474881b4',
 'd213af8d829335853f93',
 'd213f16aa8e82afa2437',
 'd214df66e2cac7e050c7',
 'd215f8a44878ba10ee92',
 'd216faf0e8a05c9776e8',
 'd219c6b8fd89a5f4f8f0',
 'd21d943217102fa76f95',
 'd21e0ac9d1c1ee1c3919',
 'd21e722e34d57c4ac735',
 'd2205d2c1f0511a7204c',
 'd223d6ec8756ecbe7c65',
 'd225b00e0e519fab27b7',
 'd228dd8a6094f6b1d890',
 'd22a7ba0eb305fac6e91',
 'd22d540c27bc8bdd3cbc',
 'd22f7e99e9851eddb535',
 'd2305fcddf9c6e41384f',
 'd232f41439e2ac487c8d',
 'd2346b4a7c6bfbb13c51',
 'd234b5c042f5ad060bc9',
 'd23b3d06e4639b8496eb',
 'd23f6a16828d6d3db9d4',
 'd23f8c26e34f9dc15804',
 'd2405b396e6e4cdc5a99',
 'd24cec878b3635e47093',
 'd24f4bd979dcbd4ec806',
 'd2503c3df531fb0c4bc6',
 'd2520a72c53434488f37',
 'd255be4f425ff0b4415c',
 'd256a502e98728326b8a',
 'd2594608e40891e319c3',
 'd25ba3b6cfc26a2963e1',
 'd25e3896bf25cd0b5eba',
 'd25e43ea61dc008896e0',
 'd25f8e05a06d299da24e',
 'd272673a5652f6672fe1',
 'd276b21c6ce2e0e16f32',
 'd2771259589db6dc5b5d',
 'd27714b59d740a5c5218',
 'd2794b1914e810d7b642',
 'd279af14b6754f602918',
 'd279b903df9b1233db08',
 'd27c28728bd32a3c5a4c',
 'd27f952ac35a4bffb4da',
 'd2839fb19c7e09709d28',
 'd283f4f180f5edd51671',
 'd287c5224914d0647fdd',
 'd287f0ad58cab026ad76',
 'd2887556869261992395',
 'd29387d18e7ca64fe09a',
 'd296cd967bb1d4e741c3',
 'd2977b8147250e1dac35',
 'd29c564bb5a66f714daf',
 'd29c74988419a9d37dee',
 'd29d39539fb2182cd9d7',
 'd29edcb3265f515fee72',
 'd2a58bcea4e5db852222',
 'd2a8e4a6dddacaa9421a',
 'd2a9c3fc6341542b2f93',
 'd2aa157df3d309abb243',
 'd2aa7ce88cfc021125b4',
 'd2af7c28738871b4a913',
 'd2b0a4d775fdb0cf82dc',
 'd2b10cbba6c5341d13fe',
 'd2b89ba748093768cbfc',
 'd2b9e4e5d1182358754b',
 'd2bb6189426d76d9a333',
 'd2bf9853956d0157bc36',
 'd2c39f031679584195c7',
 'd2c43e10c339967480ba',
 'd2c51b6fe40d848a92c5',
 'd2c66e316d3802017585',
 'd2c7afa748ac26e22ae4',
 'd2c7c46cde97d16bcf1c',
 'd2c8a6a6696a82d755d0',
 'd2cd0b50ff111d972f32',
 'd2cd9de129ac8ea1515f',
 'd2ce962b8beb93101ee4',
 'd2cf6d9221332a4efb8d',
 'd2d0cea42d1bba88f2c0',
 'd2d0d5af0eab40d63215',
 'd2d14c90c750cf023f31',
 'd2d254857e32f9176790',
 'd2d4d0e444789408817e',
 'd2d8b4da37ab2ffe2ec5',
 'd2dacb0153482fc92452',
 'd2e0cf18774a1fbb6141',
 'd2e37d879bbd084f6800',
 'd2e4fc0354bfa0723a6f',
 'd2e7cf9adc553f974a9b',
 'd2e83824a57190654a72',
 'd2eb1a64b95ca80a3d0e',
 'd2ed1ac049809e8ff06b',
 'd2f0936ed0f6e751a6e4',
 'd2f7735486b5ae570aaf',
 'd2f7b40be0e7d695f794',
 'd2fbf508f1b42d096942',
 'd2fd1d0c95299f98a9fb',
 'd2fd97dd93130b736da4',
 'd30069db8532c184c74b',
 'd30358dc393a6e3c2cb3',
 'd30a5e5bedd8456e2f26',
 'd30b04530114b74e4d7b',
 'd30c648ef1b8cb15c940',
 'd30df3b4dc8216ac771e',
 'd312698f03069def6ead',
 'd3146a456d9434b9bad4',
 'd31c02b690ccdf0aa51f',
 'd31c517cdba0620e115e',
 'd31caec3ed1bdab2f211',
 'd31fae6ba9cb5d3a7dbc',
 'd31ff12b349f77e0b7ff',
 'd3213a6bac82b7760272',
 'd32336e240282125f758',
 'd3244b273056f6f4eb56',
 'd325964b11b21c40a9b3',
 'd3282fcab5319052dbe1',
 'd32a17d11f9c103c40fd',
 'd330152219c0ab7d3cab',
 'd33065bb9d9a447f28f2',
 'd332ea14bf5b5fca9d4c',
 'd333086bc18b7ade2c52',
 'd337a6a6f8f23b52a960',
 'd33a0325e5758282b9c6',
 'd33a1dd76f7d1bcdb0e5',
 'd33acaf77d1f2cecd29e',
 'd33bb08be907f6969c73',
 'd33d09964582cc4aee04',
 'd33d1300f11e5bfcb602',
 'd33fed120eeb31b15c84',
 'd3427ca2d9b4826fbe69',
 'd344551442a7311530da',
 'd34591d00c53a4ab92df',
 'd346b19ed0bde2b54bc5',
 'd34e371677b86d70feab',
 'd35077e4d8f9e640ca80',
 'd3543cf286ce6b3f29c2',
 'd3595020a9846ef85741',
 'd35abbaa519b8027fe61',
 'd36983fba2298486c168',
 'd36bacfa17c0e3cebcf6',
 'd3739487af654dbc3cd5',
 'd3748d4cc44537c5903c',
 'd37528d08a8413f1cf72',
 'd38bfeb1bfce768f596d',
 'd38ea32ce1200bf666f9',
 'd395d08cfb2bbacd9040',
 'd3972a88d1debb390bcf',
 'd397a106a92c80eedb3a',
 'd39c26f797718a312d9a',
 'd39ef558f9b6676d2826',
 'd39f63c8d820937cb812',
 'd3a443709b971cac7b76',
 'd3a6f60082fd41352f7b',
 'd3ad98e385ebcbf6587a',
 'd3b2209dada435fbe4b7',
 'd3ba3e43f6d6d72f7f4a',
 'd3ba53fa8de64dcc5f74',
 'd3bd17b33c57dfdbe16e',
 'd3bd6e16520e51ed096e',
 'd3c0efdd97a2f47d9f5a',
 'd3c3e02474f73c1f5779',
 'd3c750d75267c380f733',
 'd3c7ede905d9a76c9a6b',
 'd3c962d5af419513e3cf',
 'd3c97919e56e3391fa82',
 'd3ca7d853802dae9275f',
 'd3ce914a5896e4f16ce3',
 'd3cfa37d7cad10a4d5e1',
 'd3d2f5583b387ba5d4ad',
 'd3da37bb54fb50a1cb8b',
 'd3e134642ddb2e42ec88',
 'd3e252307e330b5a9145',
 'd3e4bb6b22e7c7a77c79',
 'd3e820a50f5b37a1290b',
 'd3e95536b78935ca6777',
 'd3e9d3b6f3ca4eb9e34d',
 'd3ed04cfcf8060691c5b',
 'd3eea3d2ff7236f4eff5',
 'd3f4474a8cb1d391fd06',
 'd3f61a5327f40fdf6b51',
 'd3f9a6690bc9945fc1c7',
 'd3f9c225f3b921a2bdec',
 'd3fd45db9f14fdcc88da',
 'd4020335ab65580d2823',
 'd40332dff8ebb16d0450',
 'd405e0052a75cc86ec30',
 'd406ab6069b3499bb9ac',
 'd406e59d2264d607e1f2',
 'd40fb91cedddec7b04dc',
 'd4119a304871b6ddef00',
 'd4132283d50d12efb361',
 'd4146595dd9352c3ad2a',
 'd418e952176ace0bedfe',
 'd41f3a4164ed36693d2d',
 'd423ca89723083a5edb1',
 'd4271c29ad83669ba486',
 'd428d4f1acc5792f5969',
 'd42bd692b3070d86f269',
 'd42cb025598e0be1f1b2',
 'd42de26ddd1d0280f6d0',
 'd42f3f72843eeada086f',
 'd42fcf4af1c814f32268',
 'd4370c5b400fd3c3e252',
 'd43c9499d113d32b571e',
 'd43e65829e347f297131',
 'd43f1bb17942eedc80cb',
 'd44bfc62652163cb1b8c',
 'd44d01201340cd614e8f',
 'd44d0a3a058bd2517ee9',
 'd453df2691c58b59ae8c',
 'd456830d2d55238efacc',
 'd4585ffa27e7bcb29b31',
 'd45ffef54a0943d2d195',
 'd46066d2e2b09bb845d3',
 'd46158a525553f3201fb',
 'd462666e23375348a439',
 'd4628bb158d39526d73f',
 'd463b7dccc5c0f5d33b2',
 'd467462cc553a49edc90',
 'd467d8c55a4c456b2b31',
 'd468b156c2cd16991e0c',
 'd47090f5b1193b4b362a',
 'd476b5070f10eed190bf',
 'd47a4807cadd0236e29e',
 'd480dd817344181b66ce',
 'd483e9d62726fbb1fb97',
 'd48c230012e56b557589',
 'd48de3529ab0d209d1ee',
 'd48f8535305f3f9880a3',
 'd49130d2701535ab3fa1',
 'd49393cc3621d16ad2d4',
 'd4973d5037b8fa8dab5f',
 'd499065be897dbcc9101',
 'd4998b79a6e1933c714b',
 'd49a61d5970b4a742861',
 'd49b2148088d74b9cee6',
 'd49f78e3140402f47686',
 'd4a177f12f903b4ada51',
 'd4a3c21dacda36edaf5d',
 'd4a4e3ed2a73fb0d7463',
 'd4a5d86a96bf64906bef',
 'd4a89e4b0263ee805de6',
 'd4a9341ce2e75bd5c748',
 'd4affe616ca704627668',
 'd4b1920ef5cbd5278968',
 'd4b2411176a2c2a83351',
 'd4b2eb2a1219bee02c9a',
 'd4b305955ab14f95e207',
 'd4b38cf8d940b877da54',
 'd4b4af71f953ce3f2555',
 'd4b6e30289d99ea0c37c',
 'd4b8288e8dd391ea9b1f',
 'd4bb8778a456a7ab7ada',
 'd4bed52ab1aef1b8282f',
 'd4befd3ee7bb30c4ab98',
 'd4bf6b07c4b4507b9cbd',
 'd4c54ba03491863bab53',
 'd4c96b7e1c2c389b5a6e',
 'd4c99c7ab9672e2cd223',
 'd4c9e25e4d2438aab872',
 'd4ca708977e9f4e89d5a',
 'd4cd757d4e0da991db39',
 'd4ce834797d8fe4a7d1a',
 'd4ce85dc3cf77c89e56b',
 'd4d005b8194234c10ee7',
 'd4d0d70ccd33a81074c2',
 'd4d16403308585482bab',
 'd4d1ec298fc07e6dcbb8',
 'd4d2861d2bdf9727bea6',
 'd4d2a8d050410b6b0233',
 'd4d2ac8abb3b72f81c86',
 'd4d85cba7f1303f3e28f',
 'd4d8d10708e3be18b572',
 'd4dd69149821187fbdad',
 'd4de65a17c0d3756adf9',
 'd4dff6a3ddaf9ee73ed1',
 'd4e0a3cf1fccb476bf36',
 'd4e49f5747602f0490ad',
 'd4e50d7ecb463c4d27cd',
 'd4e5ab82295c6e1f9933',
 'd4e75fb3d85ed020479b',
 'd4e7c83b4afb5d4dbaaf',
 'd4efb760a0294d48d6d2',
 'd4f8a16407566cb94ba8',
 'd4f8dc8c3844431ed835',
 'd4fbafd58eb1385d0db8',
 'd4fbd864dc923173717c',
 'd4fd643ec386feedaa43',
 'd4fd6696d1a36096ca09',
 'd4ff4a101b4c466d3078',
 'd4fff898f013dc153892',
 'd5025d4dc25f73476ea5',
 'd5096ba01abbe12b8905',
 'd50a873f047ef238ebe1',
 'd514dc30ee901c410930',
 'd51660e6fb61a1b35608',
 'd5167fe6cd47943a0bb5',
 'd51b5460f7ea6d0dfc98',
 'd51ca6dbe08fb726792f',
 'd52666d5d772ac570f49',
 'd52b298178eee8b6f9c6',
 'd52ec711636e7a44a2fe',
 'd530edece2e2d0fa03e3',
 'd535fe6fe81be98da123',
 'd538bf92b6caa6e8a59d',
 'd53e39ef7e93b9b34ee3',
 'd54477811deb735b60a1',
 'd549462c9dd4557703c9',
 'd54a9091a118260b2db5',
 'd54c4d0f587f48b65f3a',
 'd550bd36f8cbcb94ae1e',
 'd550d9c273705783b128',
 'd5520ababce49d5d6036',
 'd557ae301a03f87aae38',
 'd55e0d4dbc585a7db681',
 'd55e315ae8fab9f863b8',
 'd5606833fcd4a537ce1f',
 'd5638bc0008360ffb81a',
 'd5672345aafee0c74713',
 'd56a825f7096635a07b5',
 'd56bb2399fd8864f641f',
 'd56be9cd57f10bad0c78',
 'd577a2c888357d0d421b',
 'd5788b93abed46fdfa30',
 'd579345ae4eec85bdee8',
 'd57a9538b8d36675979f',
 'd57c307ed6a1ca5996ce',
 'd57e53407302f0816628',
 'd57e722d32dbf4ec0169',
 'd57f7e2511e6726b910f',
 'd584f215abcd899feda2',
 'd58753e0fc7dc0b9ff1d',
 'd587fd39d28dafb7d2d0',
 'd58973d4dd0f1ca13f00',
 'd58bcf22837a4fcfc5fc',
 'd596ff0e6bad36bfd16f',
 'd5990a9961ec51037e11',
 'd599be9dffa0bf37197e',
 'd599c68c425cb22c43ef',
 'd59a2ede5a2edee9bc81',
 'd59f773d669d947d8199',
 'd59f8cb26c00ea5f948f',
 'd5a21c9fd438507f5fa0',
 'd5a40acc772b48f09316',
 'd5a813f429d9052391f2',
 'd5a93cd82b826cfbc0f7',
 'd5b0e6f40ce497f3b91c',
 'd5b18abaf1d3a9318a4c',
 'd5b24e20692a05c118c9',
 'd5b352b38abfff47b49c',
 'd5b5e760cff9ccdf8edf',
 'd5bd02a0c3d2c967a892',
 'd5bdf5889e5058a4e409',
 'd5c2033c2c4388d7a4a6',
 'd5c611002079ca71559e',
 'd5c9909d237d6ca88f93',
 'd5cd9240d32914f2a580',
 'd5d299581b33e02665b4',
 'd5d36b1f34f7f065be87',
 'd5d495072f4a099940ab',
 'd5d7ee67aeec7102cb4f',
 'd5d82ca1fecc336127cd',
 'd5daa88bc80b6a7fc95b',
 'd5dbc9e0f1a34eb0d05c',
 'd5e3979f4cd996f723c2',
 'd5e4bd14efa43f378c95',
 'd5e4c6d2e4eccadf30d7',
 'd5e5327c8565553d2489',
 'd5e7e0dc2b9ef82bf8ea',
 'd5edfc5d21529408ee89',
 'd5eed1db3048c96dcbfc',
 'd5ef5517f97ddc15f02f',
 'd5f1eb4cfd62488e0536',
 'd5f2ccdcad252329c3df',
 'd5fa6fb9a818628f8802',
 'd5fd1f6d31693163145f',
 'd5fe11e1ac0a4c4c6294',
 'd6032cf524d01517ef00',
 'd60415a92ac9876ecb01',
 'd606f218b7b710b4d0c8',
 'd6096e83504ab9072bec',
 'd60c617770f650171a8e',
 'd60ce115940f662cfaa4',
 'd60d7a22deda11e69590',
 'd611497af16f564e47e5',
 'd6130b97ed18f21cecbd',
 'd6130f5e8b157a021c30',
 'd6194ba9247c78ba4941',
 'd61ab795478e322cda7c',
 'd61d4efb43ef1df60c70',
 'd61d8ae7689b390c77c9',
 'd61f959564ac000aada8',
 'd61fbe4271a40a0ad780',
 'd6253d04120ec60d1624',
 'd626b4b68f0dae0aba99',
 'd62b3a2ab7b3d360548e',
 'd62d78b7208dd6e23491',
 'd62d8afc420df389d326',
 'd630c82ce2251eee2170',
 'd638631112f18b8c7076',
 'd63b34291f43e1714457',
 'd63d4b1b7d031985d69d',
 'd640c341e5b774301174',
 'd64beeac04ae9a676e3f',
 'd64f24ead42eca47b108',
 'd64fed6c8131c0daa52a',
 'd65423cead3cfa6f5be0',
 'd65939a5c8900870fe6e',
 'd65acf395d8fe1732c44',
 'd65b69e582223da6d22e',
 'd65db832d0a434397b97',
 'd65f231c32090da42405',
 'd66283b92b7d7d6bae23',
 'd663f6385266f75f14d4',
 'd66c878c1ced37771c33',
 'd671372320fe48c1bde1',
 'd6724b9c9aee444ad185',
 'd67508840e12d3832c01',
 'd678207b4b62e1b2fe52',
 'd67877f2980df9f6345d',
 'd67eaebeb5f81df24b4e',
 'd681b880fcc906dfda03',
 'd682e56ad2aa34f2481e',
 'd683c7dc4829e7620ba5',
 'd684642bb8d595acc457',
 'd685c7b35ac388875c31',
 'd6892fccb7f978bf0e9d',
 'd6895d0d0e92b5004290',
 'd68a985785d7710f3974',
 'd68dffaa595d92a6027c',
 'd6961c9a80ff1dd8c795',
 'd696ff4557b2c728ebee',
 'd69dfbf306f82fba1780',
 'd69e871ea42290cb7996',
 'd6a67bc21f475a394cf3',
 'd6a6cc6f6fba1facd36e',
 'd6ab12983d1381890cdb',
 'd6ac2532a5e96189aa3b',
 'd6afe1cdad239bad183b',
 'd6b03e01a1c98fe311b9',
 'd6b0525be4c81592a072',
 'd6b0c4b16e1b286d1435',
 'd6ba00e9391f59507cf2',
 'd6ba02fb791781a55b3a',
 'd6c4ff563cbcfae1f455',
 'd6c58c3dfa96a4ac91a1',
 'd6c61effae26914ce82f',
 'd6c8a33cfdf6221748dd',
 'd6c9a927d2300d5c7f01',
 'd6cc0c0b6b709f680337',
 'd6cc9485556fbd40a74f',
 'd6cdb398b2a57e21d75a',
 'd6ce896fe90c8b5cff34',
 'd6d04df005fd8658f39c',
 'd6d14a34e04fc613a4c2',
 'd6d2960ae294304f38ef',
 'd6d39c97bec00394a874',
 'd6d3ba3f9cfefdd3f780',
 'd6d63dafca18652a49ea',
 'd6d967b3281d7a6d6e56',
 'd6dfc5ff35287eee5383',
 'd6e07b9130bf2fa7257b']

# %% [markdown]
# 21

# %%
qids_21=['d6e394adbe473d21d39f',
 'd6e833ba1aab350eb78a',
 'd6ed57452aa835622e74',
 'd6f3c7aa767a0cf232de',
 'd6f421b0f93b29897998',
 'd6f6ce482f1cd61e51e4',
 'd6fbdbfa324373df71ec',
 'd707c28840a26b5c0cf6',
 'd70801defed5bedbd6a4',
 'd7084f6931569fc5eff9',
 'd7087c8cfe10d7434058',
 'd70cba0cf1888d2749c9',
 'd70d13087ce88f235b4c',
 'd71398bbd5a63e3e975b',
 'd7156f2a23001519a168',
 'd716b2757cfc85d92236',
 'd71abdc6647cc2323fc3',
 'd71b623c43e1f271d926',
 'd71f9f358f865a5b0291',
 'd722c64c372b66e218e6',
 'd72316c165480349a8c4',
 'd723f29d3126b75211c5',
 'd72404b612ba408ad1a1',
 'd7243b7f5ec2dd85c883',
 'd724b0e038e8861b5df6',
 'd72c358a40efb814c5b2',
 'd72cd1000ea9d656dbea',
 'd72edf620372dab89820',
 'd732b4fa6917eb09b482',
 'd734ae2aded538e520ba',
 'd734ccfa83283fa66f41',
 'd7370d262315e28ab213',
 'd738c865910dcb5bac63',
 'd73cbe5192f82dcd050b',
 'd73d046fcebf1bab8301',
 'd73dfdf4ddddcd5e1e4f',
 'd74eb67bff8eef3aea9c',
 'd7571f9ec609ea6d0efd',
 'd75b40aee392e7b6a053',
 'd75c35baa90482f16cfb',
 'd75c53d4f9ea6ba2d144',
 'd75e1a4f36d3c23ab48f',
 'd75fc9129fb64dc17e9a',
 'd761e5b222262cd3cfa3',
 'd76859310bc90518d787',
 'd76a48682b5d06a5a415',
 'd771ba11c5ac44699590',
 'd7754a90150af2129a86',
 'd777647129749d358b72',
 'd779b639dded3be4d025',
 'd77a8b183b78b7e2ceb4',
 'd780174692261abc4342',
 'd7817d45ece883f7c61f',
 'd7843253b108dd018f5d',
 'd7847bea732d7c19046e',
 'd789a0ef3ea39486c45a',
 'd78aa72d8664d5cd6c52',
 'd79a5d43d13905b91c20',
 'd79d34488f7bb3b405ac',
 'd79d883f19f4aecf6690',
 'd7a20d0ea6683d47762d',
 'd7a48c20bd3cfc6049b5',
 'd7a4aa02517877a4fb28',
 'd7a60eef291def24c263',
 'd7a7d88066a4b1575931',
 'd7a81713f0db35bc4f53',
 'd7afb5d545363977b07e',
 'd7b1c4a58142c7bd17da',
 'd7b8f6de758b357da5bf',
 'd7bb105e77a063f7cd08',
 'd7bba23ec45008217b87',
 'd7bf96edcf687ec8234f',
 'd7c09ec1b8876dd159ed',
 'd7c468916be6b34b2dcc',
 'd7c6f9d1cab359f65e4b',
 'd7cb0aae4eb8cfab9923',
 'd7d0097a8acc326a6066',
 'd7d7470e936893751672',
 'd7d7ab377f366ca5fb44',
 'd7dc64cb89480a118f4d',
 'd7e302cc45f091ae8892',
 'd7e59b2ac0c93047f2fe',
 'd7e692c703803eb496be',
 'd7e872bd9a04ff42aaf4',
 'd7e9f393b422672c43b0',
 'd7ea63c41fb785254a73',
 'd7f14e921a2d216e9892',
 'd7f64d49715b5d20e9ad',
 'd7f6f2176443bef3d5fd',
 'd7f9973232f82845738e',
 'd7fcbdd226ffd76c4cdc',
 'd8000f9bf5b0af8e5193',
 'd80716136adae6721fa3',
 'd80801fac090883b03ae',
 'd809fb669e3570a3b97a',
 'd80b271e63e14f717653',
 'd8139a0ed1d7e44642de',
 'd817f578e025a9a00b87',
 'd81b7ae9fed39a709755',
 'd81bcfc832b7ea25ebd7',
 'd81dbf1b378c9621b8ca',
 'd81f6197b74c50106aa6',
 'd81fa502ee8de64e70ad',
 'd825a9508601d09b2bc6',
 'd828db339b23f6c80ac1',
 'd82a6edae22a042d1635',
 'd82bdd0e2253cf7f37aa',
 'd8303377318270332340',
 'd83154e52428bf34d70f',
 'd835e16d3fcdbdb4957c',
 'd83a4ade5bc9fbf8bf9e',
 'd83d95719d0442ca8db4',
 'd83f563186e9aa0046b8',
 'd83f62a81bb0b9037c1a',
 'd83f8b479d322b98ad6d',
 'd84154d06c5bf98e5596',
 'd8435241f54634252444',
 'd8474ded2bc19bb99dcf',
 'd848650dfea1877e7386',
 'd84974de8d50791f50f5',
 'd84c9ccfad507538acc3',
 'd84f9a9a45160a1e4f73',
 'd85008b492a89bbb1e55',
 'd850465da6aa8900946d',
 'd8510d5f90ace259c728',
 'd852618d64a280723b74',
 'd8583bd567e54adc92f1',
 'd858d153061ed8e5e07f',
 'd859a7915952fa02436a',
 'd85a652cc096b7f6b161',
 'd860d463742b77962d6f',
 'd865651780b392b01e0b',
 'd86674074924c68a174b',
 'd8674c45f26acdff2c22',
 'd868f0f9525ff202cf17',
 'd86c795d9bd9dde5abcd',
 'd87dd55c662fca016bd7',
 'd88133628e96bccd3f2f',
 'd88373f0fb9d8d65b332',
 'd88e189a501c526a7bf3',
 'd89071b3b38f2cfd6cc1',
 'd8941e5569fb6cd65fbb',
 'd8985dc8e863210bf63b',
 'd8a26ec87b20cc76e477',
 'd8a455a0ccedb6664f4d',
 'd8a468171de04a58e8fe',
 'd8a69da6bcc57e60d674',
 'd8a78beb58bb36c2ae74',
 'd8a850399d0c42b41122',
 'd8aa6bfabf637e096f36',
 'd8aadcdc6a4a9adf5114',
 'd8ac73975506cae89e2e',
 'd8adf9436afe4eb53081',
 'd8b042984da8be11f31e',
 'd8b1afd353972aa1e58c',
 'd8b4f6bae9348b8b48d4',
 'd8b6ceac93dc2b0c3d7c',
 'd8ba72f335fabe6f7b59',
 'd8bac0944ca99365f8b5',
 'd8bae9bcdb520ca5f15c',
 'd8bdd9ac82634473b1c9',
 'd8bdfd976b69b560f53a',
 'd8c1ef14690767bb17b3',
 'd8c25a2af269dd6f2c8e',
 'd8c6144c346e40779888',
 'd8c83f43e2c62379fea0',
 'd8ca69da7238efcba6c3',
 'd8cbe37d4b5cf448e732',
 'd8cd4e52ab40550385e7',
 'd8d14c6d04e389861638',
 'd8d21334b1786cd6d18a',
 'd8d5c64cde8aeb0811db',
 'd8d664201c9249e74dc2',
 'd8d6c009da47cf52083d',
 'd8d73429ce8175acc964',
 'd8d91a3e82c95a9c207b',
 'd8de809767a2bb4b117a',
 'd8e093b28b60a5ac24cc',
 'd8e19dded37a4be537b1',
 'd8e29047ba17892fcb5e',
 'd8e3603b1ae422592968',
 'd8e547bf45ab8b6abfff',
 'd8e595e85247fa19a001',
 'd8e971668f69b5cc7fa5',
 'd8ee892e54293513775b',
 'd8f54315d2561226c14b',
 'd8f59bae0827092a37fb',
 'd8f918115e3c21c8d90a',
 'd8fa80b015e1eb7f84f0',
 'd8ff6a9b979e1f0d16d9',
 'd902d73ce8661e0a9887',
 'd90327edfcb9d1fe9e66',
 'd903c7380b4bab7c584f',
 'd905b54af0502e06471a',
 'd906877c62205d7d4e65',
 'd90de0e94d178cebd298',
 'd90e1e72bddfb7e2fa13',
 'd913bb5a9a6cb30d1d64',
 'd915bb1abba542c0c2a1',
 'd915e97a436c0fb9f6bf',
 'd91809a0edf9125bdc17',
 'd919c8b01e50386a145c',
 'd91cde091a00623eb339',
 'd91dbcbc1c01cc9e0045',
 'd91dc57d2fbf1deaa4ce',
 'd92628b71910e8c14bf4',
 'd926c293ce8f47358b39',
 'd928928bd3d21527e15d',
 'd92b3db44000692ea204',
 'd934aa468133e06e4bb6',
 'd93aa4780143814e7b80',
 'd93fe5c4965656497ae0',
 'd9406134e2883bd428f9',
 'd9495e7fa497b7b4044e',
 'd950c1fad64c5af91f75',
 'd952c1b402dde114b101',
 'd9569bf7ad8a4bb119f2',
 'd95bea9fe755ecf717c9',
 'd95c458aaf266298449b',
 'd95c581d6886a5edf4a6',
 'd95d2716d9f01d633e8b',
 'd95e36425f3e6a0cb757',
 'd9680538bc172bf8164b',
 'd9700047ae9bac6268dc',
 'd971eab6cadc13f0c520',
 'd9749541b15b711aed3d',
 'd97b8fa8d32c00089a6b',
 'd97f70b194b58d1448bd',
 'd9801306382ca031882d',
 'd98250a9f9bcae486e98',
 'd983e66eaa5d7d454bde',
 'd9885289a1e2e296ae2f',
 'd9896aeae8f38dfe11f1',
 'd98c69cfbaeb6e268adf',
 'd99105113ad3ac693269',
 'd994a421952c9ce31848',
 'd997295a75d834a8b0f9',
 'd99a7e94a7dd17719bb5',
 'd9a0eea64c3bfd3f709b',
 'd9a108346ab80e16a845',
 'd9a13cc79d7af1c36d31',
 'd9a52fb39de6dd9a836d',
 'd9aad391d5b0cb0fb1e5',
 'd9ad5da0e37416487d9b',
 'd9ae696e01cbfc6eb493',
 'd9ae697da08a37a59e04',
 'd9b1f5434a7a900d26e3',
 'd9b2a76c70f96273a14c',
 'd9b303fd1cd6d816d811',
 'd9b3a07121b2d27b001b',
 'd9b5e096c335da17a968',
 'd9b6ecbfb8ade8bb53d2',
 'd9b7041eaf4e36d527dc',
 'd9be9d99f239d5299db0',
 'd9bed44bf4741908721c',
 'd9c6c81fcc802b49868d',
 'd9c7cf5bb938e32bfd4a',
 'd9cfe12dcabd5c27d028',
 'd9d0352ca46803e38d50',
 'd9d80fc1cf8fa68ad055',
 'd9dd1038a7be9284e9dc',
 'd9dd3263077bdfffdfc9',
 'd9de934367ace6691779',
 'd9dfcdbc5040c5f872f5',
 'd9e1a26ba8dbcf39723c',
 'd9f05deb0b7ac5fec927',
 'd9f4a1e97eda944bab56',
 'd9f674190b65217f64c7',
 'd9f7868b18ea36d7e6e2',
 'd9f8fffe1504a1aa9a64',
 'd9fbedb6a79d76e0d4f4',
 'd9fc6e54625ad5422d4a',
 'da013e020c59f1b52fd0',
 'da01540467fa41aec721',
 'da01558133d2a263c245',
 'da06639a2ffae53b5303',
 'da08896775516d6e2ea1',
 'da13f390412cea2e0ba5',
 'da185e8ceca91f278561',
 'da18aa78b3e92965e2b9',
 'da1db8c8bf56f43f5fcd',
 'da207a4b30272c694d96',
 'da25d2882446c67aaf96',
 'da2961d37eece8bc607e',
 'da2a29ac60d434882d51',
 'da2a7093110b088d1ca7',
 'da2d03a1ab6ee75f3bac',
 'da2da4bb651b47cf2d84',
 'da336565a9b593c36632',
 'da33b9b3538643b81bb8',
 'da383b61add4da693a13',
 'da3b15bb48c7cb49f35e',
 'da3b834690477866f461',
 'da3db23488f44b55d753',
 'da41c7f9973a250f6971',
 'da4b8b263f3353c1b60f',
 'da4da9fee616152b4522',
 'da4e9b8120074a977e15',
 'da52624ca0fb0548caa5',
 'da52b03d9e6e64adf358',
 'da5593b5364815b1d8e7',
 'da5d55060a5f0375b634',
 'da5e10137766821903b1',
 'da653d9867befa54ff54',
 'da664f528e6dfca3b766',
 'da6c02168ef527970237',
 'da6e8ee96f7e1c14506c',
 'da6fe166bac71cb07e4e',
 'da746f5180c4a481f150',
 'da74cb58a7aac05ea74c',
 'da76d4e339f55b003c03',
 'da76e77f2952c07bd8d3',
 'da7ac38e1b7ea7663902',
 'da7d24c92969290d72f9',
 'da7fcaefb75d7d7b4166',
 'da8580ca5f7a723a36ae',
 'da887a62e98e05cf48b9',
 'da89ad30b2f851eda85e',
 'da8fbad5b7f877e314c9',
 'da90096c51727336c32c',
 'da907ed5443eb114da5d',
 'da94e8416ddc28ed28a4',
 'da978a0df23de571d79d',
 'da9aeddf32332e2dd9ed',
 'da9e3c7cd6124cd5099e',
 'da9ecacef1a43405c41e',
 'daa0988d6d92c6497f23',
 'daa93b2b9dcb95fb3a31',
 'daaf198deb57c856cb7f',
 'dab1a1af3838e37c1e0b',
 'dab1fa448dd678fb9951',
 'dab68ebf580a130feae4',
 'dab7d047b90e0c4ca272',
 'dab85bfbd95b5962f4ad',
 'dabb3723288b21e0b8a3',
 'dabb760676d69789bae0',
 'dabe5666baa6d9eef39c',
 'dabe8928cc8200803eb5',
 'dac4dc5b29f291f6714d',
 'dac776d26fb22f5c5c95',
 'dacb9922fab3bb0f7248',
 'dacc28a95bcb65986b11',
 'dad32fdfd93e83baa4d4',
 'dad50ac6eb64949592e9',
 'daddb609de5b74b63207',
 'dae226c311d2bd21e16c',
 'dae26b5945491a3c2b26',
 'dae2afbf25d9e82867cf',
 'dae30077fe9a2df49ab5',
 'dae65d9226eb5af6dda4',
 'daeb9303ff5f696f4650',
 'daefbeae1cd6fd4fc8b3',
 'daf32912bf589b455830',
 'daf5ddd4c85caa925702',
 'daf8df8349897c238d7c',
 'dafd4931f89ae95f635f',
 'dafd7e97869b883d2839',
 'dafe3ddc06bc1a7d3888',
 'db00b382185621f946b7',
 'db0262b3a95636b95953',
 'db02b6f186fc8745da16',
 'db0a34eb736052339323',
 'db1000c3a01e7144fae7',
 'db103a82f648d7d299e5',
 'db136e066e5538e24ab0',
 'db14b33d4d55b3fcadb4',
 'db18db6b2e31c27198ab',
 'db19ac834891eddfdb16',
 'db1b1aa1fa8c3e321935',
 'db1bd4caa95bf400fd69',
 'db1bd8dbf1aad9a30a18',
 'db228ce6c5e045f5219b',
 'db239a8f4cb8426fb2b7',
 'db23e35bdc0c009164d8',
 'db2726233d365f872abc',
 'db28a43aa995d54fdf8e',
 'db29ff58beacf6156f2e',
 'db2ab636f79c040fc794',
 'db321e716e32f5a4cba2',
 'db3c31f1d01f720f6edf',
 'db3f58a815fa78d7c87a',
 'db42bde713c985102b81',
 'db470f90ec1f79c394e8',
 'db4e1735926885b343a8',
 'db4f40cc6029662714ad',
 'db50b04f10f49d9a44d2',
 'db50ea2955a706a4e66b',
 'db590d49f2d3ac99ae61',
 'db5a17876f876904749c',
 'db5b56d4b43c587d4fc2',
 'db5bce7ba84a2059d54d',
 'db6251680d380e59839d',
 'db67b3141294420fc9fc',
 'db68a042bf48c894d721',
 'db69027167c906a1e721',
 'db6e0c50c3d0f479ec08',
 'db6ef9eeb641c5e6b895',
 'db70c0bdd494b498623d',
 'db7167568e6486fdb1cb',
 'db71d66d4d1b288d70ed',
 'db733e69b4dd111a7e3b',
 'db790972b4d83fcb2ef2',
 'db7aec09ccf426045512',
 'db7c4902fa99776e8c05',
 'db826328494d2b7e05bf',
 'db84ecf920537c0fcbed',
 'db8584f65a0cdb32bfa1',
 'db8b69815b64fcaf26f8',
 'db8b8b24042d78b5ae8d',
 'db8f02856e0386a8271c',
 'db965025307566c6c960',
 'db9999aeebb91b499ecf',
 'dba4ac45421a98b5abac',
 'dba51719c65dd343b80a',
 'dba678762638f4327650',
 'dbad27cd678f4ce7b6a1',
 'dbaf4434f210a3857d7c',
 'dbb29f4051fa0e10566e',
 'dbb6f8ea4cb90ed8c283',
 'dbb77114a81d78b0a5ac',
 'dbb94ca136229e4054d5',
 'dbbda008371ca4187bfb',
 'dbbe0759fc8e33c5acfe',
 'dbc9fa9c6ad093e52ebe',
 'dbcd02aec611011fb912',
 'dbcfbabd03f838662915',
 'dbd69e8a5aff6a4fff6f',
 'dbd78a9c88c4f8d5d015',
 'dbd8133fad5b1c11985b',
 'dbd8fe3a6f521f5dfd9f',
 'dbdcfa55d1e353725c98',
 'dbdeb05696417ccd5c2e',
 'dbe01a1b64d5f3af7ba3',
 'dbe04e25cfe4b65f8124',
 'dbe414192950781e89b0',
 'dbe5d94fbde895b2788b',
 'dbecab440a6b371d7215',
 'dbed7ec3a3e7d2c0414d',
 'dbef22c87c4a0dc4c157',
 'dbef66cca8de26fc0d3a',
 'dbf2bc1a1b20ac589778',
 'dbf4930a07332fd9e880',
 'dbf9181d56a42c3df32d',
 'dbfbacbec04d8a81ca35',
 'dbfe320258eb51a1dbc0',
 'dbfedf80f595dcd939e9',
 'dc0386e8e74b4efc51b8',
 'dc051662b70798dafe6d',
 'dc052e0ac3e293314871',
 'dc05e7a974bc7cbd295a',
 'dc080ccfd3adc50d8544',
 'dc08935dfeea609c2dfa',
 'dc095855f22ce7ece9a2',
 'dc0e4902350c072f11ba',
 'dc111e31db2eabd65416',
 'dc131c7053ff79a45d39',
 'dc1366dee37579cd24eb',
 'dc15691566262038e9d3',
 'dc1691cc330c496c0afe',
 'dc18a726ea3dad2c21e2',
 'dc199210eb905724e7c2',
 'dc19f7d2312feec16ad0',
 'dc1d0283708c29effb7b',
 'dc23e5f1ee84c1b8b880',
 'dc26b2e4d5901c4f80c6',
 'dc2b25a4fe51795c9a8b',
 'dc2d24820233cb3160bd',
 'dc333d893def52a6eaf4',
 'dc34c81985a3fa291a13',
 'dc39b41d050ef56c2b8a',
 'dc3b26a179054cde2436',
 'dc3ddea740192f231481',
 'dc3ffb8fb561da0fbe2e',
 'dc44fe2ca48d04ce5a1c',
 'dc4c6105d726cba32bab',
 'dc4c7da2c43438ee2386',
 'dc4e94cedb82b971c646',
 'dc54c4cd29bc3a7e8c70',
 'dc61a15498713c0f16c7',
 'dc626139e41a3a3067e4',
 'dc6288eee615171bd420',
 'dc66ecadc20f58f8c3d3',
 'dc6de276b9e6e5e76c49',
 'dc72e1ada4e13bce577b',
 'dc73f1c57b63a5447765',
 'dc742a887aaa21b90d21',
 'dc7752c3d93cce1b0712',
 'dc780f21e8cc490d5c1e',
 'dc7c2d52b910f1a6e4fc',
 'dc7e58ab690d4b438baf',
 'dc7e955f731c5086de59',
 'dc807aeaf8e060948356',
 'dc8084a02d1cb894f960',
 'dc8202b746df06c5f314',
 'dc84673be38ab0e84aa4',
 'dc86568d0f22088937d9',
 'dc870b6890b4d1e65190',
 'dc87e2a4a928b6643ad3',
 'dc8a5c9a1f9ca89a02da',
 'dc8c74ea8e4d9a20040f',
 'dc9042141740eacd4b15',
 'dc95d2548d126a4f11e0',
 'dc97b868df72cfce9157',
 'dc9f631c716f055eca66',
 'dc9f95efd1f50d28b369',
 'dca2488403e75b5ef5b5',
 'dcab64efb56f4bcd2612',
 'dcabc1a37ee0acaf6482',
 'dcadc9e5da048dbbe6a7',
 'dcae1a76743f73aac132',
 'dcaf327b9948adb8eb23',
 'dcaf558521b672e7e4e5',
 'dcaf7268b07cbf624e30',
 'dcb5d44d43d7f8c2b56d',
 'dcbba1267bc94266c214',
 'dcbdd39cf929d81cccc6',
 'dcbf013ab53c93754d4a',
 'dcc6f26dba91dabcebfb',
 'dcc9806a939b45e7abc1',
 'dccc68383a4e2ff36465',
 'dcd0d8b11dafc0f08151',
 'dcd1716d96279b678fd7',
 'dcd1ca7271447ab62e8a',
 'dcd42f3b949f22d3fcb4',
 'dcd8a0b644d49abc39d2',
 'dcd9ccdd138b1512ee1f',
 'dcdbf30cf1da25c65623',
 'dcdd5200b4a9aac02544',
 'dce22d5f8eef2578cf67',
 'dce7cf8a44124bd202e5',
 'dce96a0743cc0a2bf070',
 'dceacf6e6527967c4874',
 'dcf14ba652c87b30498f',
 'dcf529e8dfd4ad878dc2',
 'dcf6cb7a091ede04722e',
 'dcf7446893629b1613ed',
 'dcfbf5f6a18a75aae698',
 'dcfe182c4de505017e8e',
 'dcfef4a968cca22d6e11',
 'dd00e11f80ea03d0253a',
 'dd05e314f11f103fcea2',
 'dd079485dc9e03812d43',
 'dd0c7c8255b61ed78c22',
 'dd0cabfae3417cbe8bda',
 'dd1443af3760caa98b2f',
 'dd15b6e0239778ea4a52',
 'dd19ad5b6be688a12770',
 'dd1d7bea651b0b9582f1',
 'dd2212496d0650b65bb7',
 'dd231ec9411f257eab24',
 'dd23fcc5e2475cc32bfb',
 'dd248bc11b8e4d5ef72b',
 'dd2a2da208b4bb439177',
 'dd2d19f3528308259897',
 'dd2e8f74ba1848962dc4',
 'dd336879e12489514bce',
 'dd38d42cfc9ade620188',
 'dd3a6cfd1bdd00db1751',
 'dd3f7a033ddc3b345f8b',
 'dd42badeedaeb06466d5',
 'dd44cbf066449f5346dc',
 'dd4ecd6709659d2c13a4',
 'dd51e1c3d87032ecc480',
 'dd5310d6267ff6240a7b',
 'dd536ce262065c9b447b',
 'dd538c2adf2384c50927',
 'dd54b57fcbc5b89b95c6',
 'dd5b3dbffaec8ee12715',
 'dd5cf6cfd61d1f0325cc',
 'dd6899eb70385d3f8b67',
 'dd69046cb508efd33c22',
 'dd6d9167f8507a6e9463',
 'dd7098908abe0d6fa486',
 'dd7c079bb69bb33b2e19',
 'dd7d3ab4e5e5ad6c7491',
 'dd8042c3c828292ffe48',
 'dd815f0815f9dbcf6686',
 'dd83e6c8277022a3fe43',
 'dd84fd316d76faf5e9d8',
 'dd85461079c671fae13d',
 'dd874689d124756db940',
 'dd8ce22a848f61ba48fe',
 'dd8da1eaf6fa8a8b7fc4',
 'dd8e20a467062dc6f9ef',
 'dd91e69b5d4a710f83bc',
 'dd966e0272d6fc8c448b',
 'dd96fed205ff4e788315',
 'dd9cc43285718e8df6b7',
 'dd9de179b260d89a6d5d',
 'dd9ff99f0d036b471a36',
 'dda2fcd29296282a6568',
 'dda6c2105451fc219c84',
 'ddac26ae707f6b716812',
 'ddafd320477f64679d5d',
 'ddb0799c8d45ff26313f',
 'ddbf8bb9925b7b72202c',
 'ddc82c6d330b27f0bf67',
 'ddcb1bce1fc5bb54e2cb',
 'ddcd72f8bd4f5eff39ee',
 'ddcfabb1b0235c53a3cd',
 'ddd53a323544add73bb6',
 'ddd8c621556430b0be9b',
 'dddaf39ad6004b60c67b',
 'dddc4d05dafbf9f87bf7',
 'dddca1207c01032ef71f',
 'dddf2439e0d6e915bb24',
 'dddf6646213dbd5102a3',
 'dde306d1d16e2ebc01b4',
 'dde620c7965cb15ef683',
 'ddee31cbc58f4214dedf',
 'ddee8760eb88355fdd0c',
 'ddef89ef4544f9d6fb3c',
 'ddf20340ba559fb69911',
 'ddf2a720c6c96ed641f5',
 'ddf31c1b8b0396e4bbf4',
 'ddf35f1c3669cd5aba64',
 'ddf39e21dde2bbae306e',
 'ddf52d9eaea5a050773c',
 'ddf6bec2f4ee32e15f02',
 'ddfd6c57325e1c03796a',
 'de00232f2c6954487969',
 'de0231c5fe0d8c2fc481',
 'de02716a93e5b21fc490',
 'de0293407df43aad291b',
 'de0771fe68173d0b4108',
 'de0a6641e347587aef8d',
 'de0e3e3d089525bba7fb',
 'de13f7544776de535057',
 'de15c20927737aa60a0f',
 'de198b41cbe5fb79abd6',
 'de1d6d894182942beecd',
 'de1e742e520c8b90c8b1',
 'de205856d7da0ab41497',
 'de21aa8eb81eea5d21c9',
 'de22215860aac03514e4',
 'de263c33eb2fe837d6da',
 'de26424edd9661028984',
 'de283991ec4a9cc87d8f',
 'de29cb073a5329262b60',
 'de2e47cb5ae365cfa5df',
 'de2f17d2c9f88f6272db',
 'de2fd7934b0c590c60b7',
 'de3371f0d140b7b167a8',
 'de3379343dbc6bae5b97',
 'de3563766f6171834360',
 'de3577f42ee0164062f4',
 'de36d3011fa6adcaa103',
 'de38ac8244976b78b16e',
 'de3c499f87b3a8a6e933',
 'de407661ee2fcc4f4df0',
 'de4153096394690a7833',
 'de42cbcc1cab0e8d074f',
 'de4349fc5eb7e85b469d',
 'de4479fac601e75e0b7a',
 'de4abe084079c9a0abc9',
 'de4d27b35cbb2d555d52',
 'de5228df1343cd0090f0',
 'de5300fe8b60fb9e917e',
 'de53b4afecfe25fabe38',
 'de5492a5874c93b5db88',
 'de55d24bc460376e9a0f',
 'de57e129ec9c0ab30dde',
 'de5a200783ed2477d4cc',
 'de617af1d3a0283d002c',
 'de6490564241783a541d',
 'de68cd61d02c57835d1b',
 'de6c1d630b1b18c38539',
 'de714eecc07e4dd65533',
 'de71cd524c2d7b92df61',
 'de747d84456e451eec93',
 'de74a7f5ac11b9997ca0',
 'de81eb2921c240cb1274',
 'de875fca4d7f435bc0b8',
 'de883faa587aa7eda4f5',
 'de8938f11eb606d57ec6',
 'de8bdfb7f8e44f0cde5a',
 'de8d30434cf9ceb97b01',
 'de93ad1f285c0d4bc6b3',
 'de98f5a3fa135a0db163',
 'dea0c41da9a4b2297ca9',
 'dea1b96dc7a05a507f26',
 'dea3dad33848a5f0fc80',
 'dea8f67ba5e570ffe635',
 'dea9371664986a2ea24f',
 'deac4b4c8f8e34297eed',
 'deacd7ec0eb758a8a1ce',
 'dead4f773ad45f905f06',
 'dead9ba34facf28ea9ac',
 'deb41176619137da2f09',
 'deb65eb95b871ae12cf3',
 'deb695fe0fa8b9356098',
 'deb90a9ccb95012812d9',
 'debaeee24da5e0e063c8',
 'debb12c66257b7dc4948',
 'debb6a1eaa244b244300',
 'debb743cae8680f6a3db',
 'debbb2208dc14d27c336',
 'debd84d921fcc1fd60c6',
 'dec98dad50e2f0e1aa51',
 'deca13ca37694099a40b',
 'deccd5a7e691da09402d',
 'decf08e4810d7c3ce267',
 'ded32fee7633a0b60235',
 'ded6f59ad800402daf77',
 'ded8c189c071539b265d',
 'dede3c5c477dcf352e74',
 'dedf3c42460f0ccbe687',
 'dee007dd03c7ce1bf4cc',
 'dee06f6d3f319a9fd2e6',
 'dee5bd6ea6be198f8b23',
 'dee6cf84de0dcffac86b',
 'deea8b70aa30c9eb1685',
 'deea93fd646d7f777a61',
 'def695ed90f04a112129',
 'def6fed1bb2e22c16af8',
 'def8e4a3570b0750f42b',
 'defb44abdcccd29bddaf',
 'df0643cf0c21c45df6e5',
 'df08aa41613194d6baca',
 'df0d0d2cac104e595dd9',
 'df0e1884fe764efa94f7',
 'df171a26f6a5b0161b84',
 'df2476e47b08f7442403',
 'df26d3e7b3f535ee98dc',
 'df339de364561a393487',
 'df33e4814b7bd1a5788c',
 'df35cec7c9230e55b6d0',
 'df36708186a95404c035',
 'df3d865427f4b08b57a7',
 'df4127761331d0f2cd76',
 'df42b58a20cf1ca7e975',
 'df4489604dec3406d56f',
 'df48df32d744d085bec4',
 'df49d777401183387af8',
 'df4ec241c6a2da036e0c',
 'df4eee265ecc4d5bb488',
 'df53c63863719cb7c962',
 'df54d20ed971afeee6d4',
 'df551e2f3847056c2991',
 'df56349371f84def50dc',
 'df563e757221bc64b36d',
 'df5789fe7730b2d56295',
 'df63babb196f8448a067',
 'df652488cb771a770962',
 'df67fda05bc8902e5027',
 'df707285da8a71d8298e',
 'df718d543d782b23d0a4',
 'df77775791929f8aa8e3',
 'df7a525f928248d705b2',
 'df7decb9a00ca7ff2c5b',
 'df80a87cf3303c660593',
 'df89f25a5f29051980a4',
 'df8b1525d771ff690ed4',
 'df8b32f8f4517186fc11',
 'df8da36ab90005aa35e5',
 'df8f747b95eabb485024',
 'df8fb88a6ad37076a86c',
 'df91e32383faae86f541',
 'df9c1ebadb65c872c8f4',
 'dfa3aa99aabb0f44d511',
 'dfa5c2a5dafd24b21969',
 'dfaa0e342633824dbce9',
 'dfaa448915bdc1ca535e',
 'dfac09e86e6e8b76e176',
 'dfac76816d85f2e5e881',
 'dface5fb3cdf02fb4bf4',
 'dfae77d8e7c17652f598',
 'dfaed1be847adf9df99a',
 'dfaef48731a740a3397c',
 'dfaf65d57be8b2db1d2f',
 'dfb52245a51b81269437',
 'dfc1df3127b40d50edf4',
 'dfc7339406bee7ca8aae',
 'dfc993da9ab1919c927e',
 'dfcc00abe4834ac89f00',
 'dfcd9ee2626784a287ee',
 'dfce721115d6f41da771',
 'dfd3b818780ddac9c2c6',
 'dfd5e540f8f5722ee718',
 'dfd6306958b2fbc2e8b8',
 'dfd89c0b72e0efe08b20',
 'dfd8af44be8a387131b9',
 'dfde60e2e10676396a38',
 'dfe233b0d5479347a37a',
 'dfe3ef40ef5ac298026d',
 'dfe42f15372b9b1190fb',
 'dfe4b82ca1ecd10b5893',
 'dfe577309ded468ac13f',
 'dfec197d70863dd381ae',
 'dff1f37e09cec9879aa1',
 'dff2502b938d5073913c',
 'dff3c9cf4944011fb859',
 'dff66f939749927aa2d6',
 'dff991d54730fbfb9003',
 'dffb7330caf47a8fe996',
 'dffc5ec057096d502d9f',
 'dffe4313fd7e3d24bfa5',
 'e0011383f41a7bc702f7',
 'e0039a980e01917a1594',
 'e0054ea16a7e7b6bb7fa',
 'e005db96e9b3f4d8f95a',
 'e006d7b43a538bc2f05c',
 'e0074eeaa371e8be303a',
 'e00828320984fdacd440',
 'e01455859db4fc91f372',
 'e01bacccc8018810c42e',
 'e01d07c245975a72b94a',
 'e01ff1f8b3aead251ff4',
 'e0265ef6f59c68fa7a6d',
 'e02b2c4b0df98115baef',
 'e0300ad56a196aa0428c',
 'e034adb70bf72a7140e7',
 'e038beedb24aa0ae6129',
 'e03d4f32a80aa2bd790a',
 'e040c837d84d0a2e30b8',
 'e04218dd83eb411b6207',
 'e0442bf60487ca75c548',
 'e0453aef804d04ddc288',
 'e0464e1d8960726562d4',
 'e04d6566c66c893b7e76',
 'e04f325fe193544cf667',
 'e0500da87c66c07a5c38',
 'e05408daf584091d0052',
 'e054168c69c20fe82d57',
 'e0593f626b2763f6982f',
 'e05db224398049d8a2dc',
 'e061d3ebd4648d9fb46d',
 'e069a5bf0f0e819c18de',
 'e06ed7b93ed060ff38bf',
 'e06f8012bf91c24ca39f',
 'e070db4c0b51a8329fcd',
 'e072e4ac92b853ca32b5',
 'e073d6521a4722cc358a',
 'e078fb5d14096f9fbc90',
 'e07b99c524b2e4c678c7',
 'e07bfc3f3387bb642ff4',
 'e07cfdd1d4795cc6d1c6',
 'e07d2a20021c7483247d',
 'e08048ff942ea2a6447c',
 'e0821220f3a08d588e68',
 'e08ae2d6296497ef826c',
 'e0937ca4d7881a7ccee2',
 'e0962aa24bd82942b663',
 'e097a9b0dbd4325c8b07',
 'e09ad07d3c53c424af19',
 'e09f4d69fba79ffa7b78',
 'e0a08d18402539c78888',
 'e0a2b07162092abcb3d8',
 'e0a3d935228c950687e7',
 'e0a65163d7985fb00458',
 'e0ab584752271d41149e',
 'e0aff404cffee44668c3',
 'e0b07b505e606bc4ebeb',
 'e0b11e69ae10fa1cc194',
 'e0b956b1882d957c9288',
 'e0b9faf2fad5d0b296e8',
 'e0bc6394e150673322ee',
 'e0bce8f46d32f2339b53',
 'e0bef5b2f9b22ed2e91f',
 'e0bf6bb70c393a3af6b5',
 'e0bfa61f0e4edfddb7e3',
 'e0bfb3ff4c34056dc6aa',
 'e0c18d0297217f70e5a2',
 'e0c1bd5cec038499cfd9',
 'e0c2889306ba79e9a90e',
 'e0c34358634974fc1cb0',
 'e0c540a80534784e1d1e',
 'e0cbf1626603391eb732',
 'e0cd83fc39ee7dabe2df',
 'e0cf43002ace00afccd2',
 'e0d095fa09181a79c8e5',
 'e0d2cef70624d2a79b6f',
 'e0d788040fd5b0e5497b',
 'e0db2fd0f3f0498ae197',
 'e0ded6797dc58de3d21c',
 'e0e0709a5397f0c01502',
 'e0e3903eab3c65a05d4c',
 'e0eb3e7382b61b347a64',
 'e0efa149e03678b8520d',
 'e0f2ecd6b44c89a25b6b',
 'e0f4c314ab767b13b8fd',
 'e0f5c3c8dca4e5c9075b',
 'e0f7724e31ac2048c667',
 'e0f8be413c8a29ec8ef1',
 'e0fdcebeb2db2f9cd9ca',
 'e102c61a1eb6696dd537',
 'e102db294e39f72b9bae',
 'e103bddc88fbe887679a',
 'e1060f93c9d7ecf934e6',
 'e1088da23d8656211803',
 'e108e4888b35126ddc15',
 'e1099b0b749396ced649',
 'e109d71c0c50bf559a20',
 'e110278d82c9ec86ff9f',
 'e1118bbc76f7b0c65381',
 'e113a97cd124252492da',
 'e11940cb0d014afa42c5',
 'e11a9669370bf117126d',
 'e11e6f27c85339b42b0d',
 'e12037b953c9e460917f',
 'e120dfa253adda8bfe1a',
 'e122269f823128cfe539',
 'e125d97336f56c0df7c0',
 'e126770c3bbaa0c20ede',
 'e1294a755e147bcf73f2',
 'e12c95dde39d2c4d3b79',
 'e12dc3cf3d911fb8c352',
 'e12e688553eee8050930',
 'e12f9d1e9ef9414ba241',
 'e134494f3d672abbd0b0',
 'e1350c05fe0c8bc821bd',
 'e136c73691e7a87ea17c',
 'e1373de0b884a0bafaba',
 'e1376f4b28b190b2f81b',
 'e13ac3a622d0a68e8c4c',
 'e13d898b0fae63d90c97',
 'e13daf194f37c22db241',
 'e13e6f99217b53b5fdcb',
 'e13e77084ffca47dad44',
 'e1410cd09d8d1b4f0e4b',
 'e147f12d82a90e38386c',
 'e14a62682ac4c858deb1',
 'e14b2983a399d58d3e2a',
 'e14c72542defc6afd01b',
 'e14df423c66cb1759974',
 'e14e8c5b947affe0ee5e',
 'e1509a32ad63caf5665e',
 'e1533944f23cc70315e2',
 'e153f0a3ee768f959cef',
 'e156db8da98d4d85ae2a',
 'e15744760335d49caac7',
 'e158e6a3988280c8b282',
 'e161a024c5a688a5f7c1',
 'e161b11145dd1b6549f6',
 'e1683baa4433e7f92b3f',
 'e169b944398c9be36314',
 'e16c69f27f83d837fdc0',
 'e16e0d58b63607d5d995',
 'e16eae8b2613f4dbb1dd',
 'e1714c3640af95d629f1',
 'e172783cf65fa74463ed',
 'e173980e04aa040d979f',
 'e175bb5958de3ceeb0e2',
 'e177f7a8ce53f3bc455b',
 'e1838a733d2934d657e0',
 'e18476a2f123deba0acb',
 'e18523409d6444979058',
 'e185655bea082d0b815c',
 'e18bdc483412890be062',
 'e18ffa7ca9a77917c16f',
 'e192a6ae28f2802ac57e',
 'e1942a1a4fd505a6e14a',
 'e194eea7489f7219039c',
 'e1977804210fe4430165',
 'e1989e0552990f346d8e',
 'e1a52b4fb44e63aebe5e',
 'e1a595e6d012aa4a6b8f',
 'e1a5d94d3414ff6c472c',
 'e1a800dd9d0da42e63b7',
 'e1aa42974eb09fd9bbc3',
 'e1af62c2f5fb78c3e502',
 'e1b866e388d235f1e8b9',
 'e1b8f7e62bff20d1f175',
 'e1bd09200d61fc157145',
 'e1c1dc0eaf584851060c',
 'e1c2bc60dbfe8e2e266b',
 'e1c4e8a6e20bf04446f4',
 'e1c6885f9ab9b4d448ea',
 'e1ca9a234b2726265938',
 'e1cc05c8a1706e319160',
 'e1ce617bff1a20b91c7f',
 'e1d083402bface8473f8',
 'e1d730d2708bb7a239de',
 'e1db3db84a6b579318d8',
 'e1deaae349727d30f569',
 'e1def5bec8418a4e1064',
 'e1e053b852ee6cec5a50',
 'e1e431e505ea36f55f5c',
 'e1e62285db2187ebbc06',
 'e1e7053a647d087ab66e',
 'e1ea65c0dac90a6f195a',
 'e1eac0f7b98e82899934',
 'e1ee689642c94fd13870',
 'e1f62995e278440103b5',
 'e1f7bef72856d19c2f94',
 'e1f8286eac7cb4b5e563',
 'e1fb9451174220e3eabf',
 'e1fe4c74d9c17f93db28',
 'e207510d8bd879521eee',
 'e20dee3dc546b766f038',
 'e214ccafaeeacd7ad0ce',
 'e2159c6309a6295c9566',
 'e2168c5804c73319784b',
 'e21adaed56f2bfc93a60',
 'e21c09924c3fc5af80e3',
 'e21d014f3539e2811482',
 'e2204dc3287ef0222447',
 'e220eaf84d2f3dcd9388',
 'e221092558beda09f06e',
 'e22240f2fb8a8bb06aaa']

# %% [markdown]
# 22

# %%
qids_22=['e226b2fd842549fd06ea',
 'e228a98c35721a1b2c68',
 'e22fc78064d59be88bce',
 'e23582680b55ee28b737',
 'e2382b29f09292bf8bec',
 'e23b1036ae86bb620bac',
 'e23b1c4df79db7fb2b9b',
 'e23e469eebe218710011',
 'e24084cb613ee074812d',
 'e2420fb66d338049109e',
 'e244d92c913292e356f7',
 'e24553cbc160c9701e03',
 'e2479951eb08c57ba6c5',
 'e2489f1cc53d9320fb0c',
 'e25341d142ec73f563ce',
 'e256832f2923be9d3911',
 'e257909368da3cd15ae8',
 'e25b447fbebc3d705f0a',
 'e25b8864165b58b0abb2',
 'e26268d44a9440552f4f',
 'e262d7d88794ebd5b4ae',
 'e263bb51993f145cafdc',
 'e264e618af226fafee8d',
 'e26741f06a007d21fce6',
 'e26b240abd0e52f87a44',
 'e26e1c66bee9b78aad2e',
 'e270f2ab82c7d988015a',
 'e27356d04103907c8daf',
 'e273a593785ad96e9db4',
 'e276813ad17159ae2104',
 'e27bc9d103083323e114',
 'e2832ccc7663aca6d4e3',
 'e285cef61e62abb127ee',
 'e28becd454ba13e457b1',
 'e28d4e48ba89756114d3',
 'e28d728c1e45589f73ad',
 'e28eae41a17ba5721f0f',
 'e292c95f2d98f72a9230',
 'e293d1db78deab557d78',
 'e29bab2e24233ffb055a',
 'e29d6d10b78baae55c11',
 'e2a4447cdf53a70d47e1',
 'e2a600459da8f4c66eaf',
 'e2a9f44d1e193e77dc09',
 'e2ab5411fff0bfc544a4',
 'e2ac83e9b9d54e62412f',
 'e2b4b236ea3868c89ca5',
 'e2b68bd2aa67b11fc9e5',
 'e2b754fe29b010dfc042',
 'e2b79f83872b880d9931',
 'e2bb34315ce70938bc6f',
 'e2bc75a5133672a10400',
 'e2bdb5fc9e4da696e8f4',
 'e2c06062d045299a834f',
 'e2c4516d321d50af9335',
 'e2c6fca42296162dfdcd',
 'e2ccd41996cacd92a89a',
 'e2cd38fb99e2a5124830',
 'e2cdc0d23793e024e3d1',
 'e2d220baa18e6905539b',
 'e2d5b1edb8430333c23d',
 'e2d7a57f5f27a895358d',
 'e2d9ee53a2b09bb669d1',
 'e2dc33b504857543c3c0',
 'e2dc76594a1972eaab90',
 'e2ddd7596e014d2d7c75',
 'e2de69e138d639a2be8c',
 'e2e019f6b080228b11e2',
 'e2e0fc79aeac62e23b0a',
 'e2e1927d7f96e2a07448',
 'e2e2c27e899975945d22',
 'e2e59df45bc85822e6b7',
 'e2e5e69444f04ba20dde',
 'e2e8274631d678fe5d02',
 'e2ea651057a03d148a15',
 'e2eaf177e90b978c9215',
 'e2ed825d6f45406dc597',
 'e2f007c3888e0521f8dd',
 'e2f0b1d23fe67d27aa73',
 'e2f0e13ffe79d530869d',
 'e2f20194bf7c29558796',
 'e2f2c01100dade576fa1',
 'e2f2c0ff267d31a81c92',
 'e2f3c79400ee80322815',
 'e2f996b3b348f2aa1b8e',
 'e2fbe831721d69e3276f',
 'e3007882a4d687c879c2',
 'e301945025ddb9c57bd3',
 'e30579a722111444dd56',
 'e305d87b5fb51c23cdfd',
 'e30774a96084d3f63c20',
 'e308024ec3479b134a39',
 'e30d5211a64d1a88f844',
 'e30fc33a084ff7d86832',
 'e317a02c34531dab7c49',
 'e31ab59866373890ae87',
 'e31aec586a84f1cdc4cc',
 'e31f1bc3ae1dd905dc80',
 'e3218d57616b41788949',
 'e322c77516c56b736e81',
 'e32f76442f890975bea4',
 'e334a4f3fbc108b387a2',
 'e334dea14fdbb4b7988c',
 'e3357db3489aaecdb7bb',
 'e336b45f1d445fc4d0cb',
 'e338d56dc91094fe681a',
 'e33c30f073b7b8628114',
 'e345aeadcd1fea285a44',
 'e3460a4a4c6662ef9e06',
 'e34b3b9b3e0bde3c5aa5',
 'e34bb7fd75556a7be0d6',
 'e34deecd6cf5b26794a7',
 'e3511707dccb73cc2143',
 'e351e7dadf25d3269edc',
 'e353a68a49210844f313',
 'e356b71af4ec9c86ad52',
 'e358f6de049947c5babb',
 'e35b89d943db977ad9ae',
 'e3600b69d9c776a9bc96',
 'e36445f9ffca7a2297ce',
 'e36986ac342ea2968ebe',
 'e36ac099c7080da47daa',
 'e370bacb96c2f62a846b',
 'e371ece6e79af6f1a4da',
 'e372a83578cb68479413',
 'e3772a2572ca776713f1',
 'e378872e2ffdb902f0fc',
 'e3788b1ac683648e3ddf',
 'e3796bf683c37bc7539a',
 'e37972d22c7a3e50e48f',
 'e37d5c294fa97b194b31',
 'e380f02d40597119ba61',
 'e383170a51598af749f2',
 'e38d501e825aa7e45774',
 'e38dae404ea2e64ef2a5',
 'e3936c87cdee4ae0e6ee',
 'e3942543b2a7661975c4',
 'e39820f0e1cf43abb3d5',
 'e3999e3eba7bd31354a1',
 'e39b5ee54ef2674c0990',
 'e39bb8aa95b089ce22a6',
 'e39de88bb98833e3468b',
 'e39e35b665bd0bb4e1b4',
 'e39f7e37c974eea5f43a',
 'e3a3bde70369b7e6928e',
 'e3a4bad23aeb24e48d55',
 'e3a6ed9205824cb1cac8',
 'e3a929a6b945b15c4ee0',
 'e3ac6b9a7cfca97efdd9',
 'e3b1ca34b7a74ce046dd',
 'e3b2afeffae9e50ccdb6',
 'e3b3c1b5fee425b083fe',
 'e3b81b724908ef09d022',
 'e3bede1133bb93c339e1',
 'e3bf3c8c1b0cb32dcc7a',
 'e3c04e259eee6af93363',
 'e3c2e6355e9ff2ce6e94',
 'e3cc4509d608b601573e',
 'e3cd1d28aecee1ea67ed',
 'e3d2371acea412a32f01',
 'e3d239eae6137d401bb2',
 'e3d5a617803c618efd85',
 'e3d999c785a885748daa',
 'e3d99c69247134340e99',
 'e3dd243e39967c378675',
 'e3de62e76f9d6eb281de',
 'e3dfb961a8a7169a2b08',
 'e3e205c091d11feacba4',
 'e3e3608ebae38e56a916',
 'e3e9dd884656fecc2aaf',
 'e3ea8f48fd94cdee8ecf',
 'e3ee7c690ad9c96cc740',
 'e3ef2533c48bda631694',
 'e3f65d62a3d2396b02f1',
 'e3f779b4da9faa9cc237',
 'e3f8e1210da897485742',
 'e400331185e1ec20db9d',
 'e401d816cccc4f29a322',
 'e40433a1bf7b79f50fc7',
 'e4091cf44da03eaf3b65',
 'e40eda3eae932ff1fa21',
 'e414590798967c9f1278',
 'e419d009a81c128fedf7',
 'e41a5029e5e5062785a7',
 'e41abe58ca42b762aa46',
 'e426b68b3f6603625fab',
 'e4282899597a9dbbc165',
 'e43613d41d10de094970',
 'e436cc6f3fabc103ff66',
 'e43d73f4920d2eb5a5c3',
 'e43fee385d28f537db19',
 'e4410f0cdbd6dc3c4022',
 'e44199e6342f24b5e194',
 'e44333c9e61fb4a09d9b',
 'e4488199b36db38c8212',
 'e449a788fcb56547fe7a',
 'e44ca7789d018794b0ef',
 'e44d049e0eaea655b3d9',
 'e44e3c392217638965fb',
 'e44ecfbeb50b0033190d',
 'e44f06cc54f794bd8f22',
 'e451c5825420c37320cb',
 'e45222ff8e26979f0eeb',
 'e457741ce696222d6da4',
 'e45a4697ac0b785ec0e9',
 'e45d185b9c3c6e5d77c6',
 'e45dd600fedfe4b12e72',
 'e45e6183770df73db3b7',
 'e45fa16eae57e4880f7e',
 'e464d8923b18003c80ed',
 'e467ce10eb0cdd77dd46',
 'e46a5b02509e8aae24c5',
 'e46a706b789559807552',
 'e46ee2e5cddc4082bad7',
 'e47273442f31ac17b6ea',
 'e4728f5a841ccf2253be',
 'e47501b511f7b4a9a462',
 'e4789888ca30b589a1b0',
 'e47d17395372b95f8ada',
 'e483b8c544fafa0e24f9',
 'e484172d61fd7bf61e52',
 'e4853a3df1393fa2a63a',
 'e4888c89542240086925',
 'e4888d28b05c2c88f707',
 'e48ad1dc70110dfdc043',
 'e4953036ceada166685c',
 'e498a8d026dd042cc23b',
 'e49a4ec82f38d35162af',
 'e49bcac53a76782ec91f',
 'e4a16752f27d45d0b743',
 'e4a3daf81d60a5228f76',
 'e4a45a46b0d7936e0b96',
 'e4a841291dc32a0c4ddc',
 'e4aeef0096a37e2fc599',
 'e4b41f9b7705d731d443',
 'e4b73e20b2764e4c9ea7',
 'e4ba0e7f657445755130',
 'e4bb21db981aedadee89',
 'e4bd33a21c9bbef0602b',
 'e4bfbc4c559c48ca9d66',
 'e4c05aea649ef922ded0',
 'e4c583e2626b3d50d9c3',
 'e4c6a9d9050b07150abc',
 'e4c6cf6846bdc5e4d8a5',
 'e4c70f687c80055a5e02',
 'e4c72437e2787c1c21e3',
 'e4c8721125efdedb7ce2',
 'e4cb83058e4e99ab09c6',
 'e4d3ec44a114b8156329',
 'e4d675b56c297f03ee46',
 'e4d860d129ec200caa72',
 'e4d9829b18a93a1fd369',
 'e4da1617fb357b85bc69',
 'e4daf39a841b14aa4a96',
 'e4daff46ae847026fd11',
 'e4dd3122adecf6365c59',
 'e4e001ee36c5e51bf4db',
 'e4e090b49a21409d4ecb',
 'e4e3a5dabe5bf408cbd6',
 'e4e4cf286d7fea70d36b',
 'e4e634ac6b67c028ad55',
 'e4e65b7efc80c9e07ecb',
 'e4e7739e021a6c3b090a',
 'e4e904a2e7d6506dd6ff',
 'e4e9a2f0bb8dd95c18d4',
 'e4e9a84f42f6b04199f7',
 'e4f1ee36a93425adad60',
 'e4f863d5aa1249d92528',
 'e4f87a0e7f1fffa552b2',
 'e4f9803b91b98213829f',
 'e4faed2b57c807d2cc47',
 'e4fd5173d155eb977b9a',
 'e4fda5e7458bc78501f2',
 'e4ff962736bad74c2f3d',
 'e4ffdd40d11131f1032e',
 'e502127366fbfd7324af',
 'e502142ae01dafc89e9c',
 'e503fdc1e4e832415b88',
 'e5093a300c31e9a7f9c8',
 'e50982d1cc6d12265dda',
 'e50ad41b03e695af59f7',
 'e50fb3f0b155c9aead7b',
 'e5130e287a3e39170fd3',
 'e517b1f2e3150fc0fcdf',
 'e5181ae9ea1e28bdccc1',
 'e51dba13cf4f511618b3',
 'e51e9e40c22f063c6caa',
 'e51f5834af2571e7fe4d',
 'e520d6a55b7e7c24b1f3',
 'e52554bdafef58ce7f57',
 'e5268bbd45cba822013f',
 'e52e380f7483245aba82',
 'e5309291323f5cc23de5',
 'e5343ed896ec7f5a0629',
 'e53722b598df379d5343',
 'e537b7c40346f18f60c4',
 'e53b39fbb42429f7d9f7',
 'e53c7110b5bd97a5827e',
 'e53ed5aeebcc708f129c',
 'e543f8391e0d722e2766',
 'e545781bd10c1051fc85',
 'e54c14713561097d702c',
 'e54cabd48ce5276cd078',
 'e54e7a47bbe675c10f46',
 'e54eb1fe8d9358929b97',
 'e5515f4f50e4eb59bc5f',
 'e5523def30e03073210d',
 'e553faab6860b04cdc3d',
 'e555bb4f6a22b5f18f4d',
 'e557562d41d275b46105',
 'e55796f3e8c37e64c846',
 'e55ba09948883a453d16',
 'e55f6737df84a3a8725f',
 'e564d1520899ee9234f8',
 'e56784e551f384120d3b',
 'e56cbd1c9254d0e1dafa',
 'e56d239af31f7b6780c3',
 'e56d606826637fa4e384',
 'e57015dd03ce03d64ea8',
 'e574ac3ce1ef630a4550',
 'e577b06dceb6e5bf9a8f',
 'e57c98a984bfb4f674ef',
 'e57c9daac169b95756ab',
 'e57e7e40692ad2b84b64',
 'e57e882a2abe338ea6b8',
 'e5815e7d74070f555c01',
 'e581fa334666f535ab7c',
 'e58deddce7c7015089e2',
 'e59602b3076f2139b0f4',
 'e59fb6474f3db008a4e7',
 'e5a0d5c276d7c63d9132',
 'e5a13952a11adc1a6adc',
 'e5a1e9782022de9ed0f5',
 'e5a4726d33280a01e02f',
 'e5aab65b30dedc77500f',
 'e5ac490ec05a014175d3',
 'e5ae5d3cf432d5372073',
 'e5aff8b715b970cf907b',
 'e5b56eb2638910ca01fd',
 'e5b5fd9dd37a002d1703',
 'e5b66e420e5d6de983b4',
 'e5b7119d400e95692566',
 'e5b91b791a701e0f25b0',
 'e5ba7d17b034278ba352',
 'e5c136fc1c0abce8b5e4',
 'e5c1470d324f55ed79b4',
 'e5c34f73c9123f6624fa',
 'e5c7ffe486e0e360c4d5',
 'e5c8e8e752e0359a7cee',
 'e5c976999cd557cfb150',
 'e5d00c13c57086c608f4',
 'e5dcf7d043c4a7bb7755',
 'e5dd18deb802b3ffa4ec',
 'e5dd597a135f718cc0c3',
 'e5dd83f82a95a4593f4b',
 'e5e176572d63cc58d85c',
 'e5e4aff76904a951532a',
 'e5e63bf6c8a6bb83e01f',
 'e5e64770d2f310dcf2aa',
 'e5e73aa21fc32b3bf344',
 'e5ea5ef8c8963c0658ba',
 'e5ea8a7b9288a3c93f6d',
 'e5ef38929bb58d10f8c5',
 'e5f157a02598db52604f',
 'e5f653df0ad20ce391fe',
 'e5f74829208eef5f2e18',
 'e5f7c0d83d3e093983e7',
 'e604278b46f54c64e7aa',
 'e60992fe4e6276e291cf',
 'e60c1a9c0d70f9b4d145',
 'e60e0b01f8b0ab616f8c',
 'e61a9ccaaee10eb20276',
 'e61ce7b88324d2cd05cf',
 'e620fa3e6de9324fbb0a',
 'e625c01c749160e37ed6',
 'e629112f1a8cf238cb26',
 'e62d0e8db256f7c82554',
 'e6318ceb50d56edbf21e',
 'e635099a1ff513c4c2c5',
 'e637a427910f30321d0a',
 'e63a4cd0f5ba104b1879',
 'e63c0d787a295f56a7b2',
 'e63ccca930c33d78561f',
 'e63d3a77150632f62390',
 'e63f328441c3dacd1511',
 'e64088600ae3d99ee698',
 'e6473a16b52cedf11b0d',
 'e64f79346fb829632c87',
 'e656ad71147670008ece',
 'e65711a6450fac0d23f9',
 'e659eb0144912e2d05ea',
 'e65ac412bc20b048f413',
 'e65cad3f1abfa51398e5',
 'e660825f69af4e41505f',
 'e6624adf830d96bd5c94',
 'e667b4924e3db22426b3',
 'e667d22fe1752c817e51',
 'e66a275893891b2bb326',
 'e66ab1779e9a2c3211f2',
 'e66bdef4694532605df1',
 'e66c204e1d13e516b9d4',
 'e671bbad0ea048e225fd',
 'e676cf27d3ed8df5c30c',
 'e676d1c4008457cc5903',
 'e67b8748416dca836989',
 'e682f4c531e6ba7a8bd2',
 'e68342007d252e4110a8',
 'e6845602cbebf980541e',
 'e68b3f7d53f1b7c24946',
 'e68be95d853ea80675b1',
 'e68f904547ec37a2a002',
 'e6907179d203d72c1cd1',
 'e6956419427e5989705c',
 'e6969e7a8ee450572b77',
 'e696a7705b8ea733d8aa',
 'e6971954d40ce7a21eb2',
 'e69f033182e969cf3424',
 'e6a15ad82ef9055adf26',
 'e6a3b97f8aa1dc0a4574',
 'e6a42464cc004176ddd1',
 'e6a6d4c27cc5e64ec5f9',
 'e6a9adf199424d3c7610',
 'e6abb3a855d595fc1642',
 'e6ae2ef4a8ed16e35e80',
 'e6af2dd87767c1d6d90a',
 'e6b0e0c68a9955e43842',
 'e6b1378b39c044289d77',
 'e6b1660fc5634cad3b78',
 'e6b6fc378a851ee7c162',
 'e6b71a0445295fa18d8e',
 'e6bab8c4360fde33531a',
 'e6bb5846c0dbf35d4d1f',
 'e6c954c5166e38e737e5',
 'e6c9cac27699c69aeb2f',
 'e6ca4fbb18b62aad5fa4',
 'e6d027f74fa258b45b0a',
 'e6d2afd32f2b5c180136',
 'e6d6db7e2a1776880ce8',
 'e6db99dcd8a5c2960a85',
 'e6e686d6971049782cfe',
 'e6eaf66edb6ed1769840',
 'e6efcd2c77f5546e04e1',
 'e6efdf6e255690b2a727',
 'e6f2ac2adbe2fad4e8b9',
 'e6f58b99b4cd28a43d14',
 'e6f76dca326c31359d9c',
 'e6f97130311c25113f63',
 'e6fb7891654646bafad4',
 'e6fd4a22f3aa36fccfbe',
 'e6fe80de7245ab8f326b',
 'e7072a2c07ea188f108d',
 'e70973a37ebfdda92ffb',
 'e70b40fec5b63398c2a3',
 'e70d323c225c1c4336b2',
 'e70e6d09fd8dc6d1eea3',
 'e7177c65bf9ee407e26a',
 'e718e32520719a3ca8ff',
 'e719852f19881e20e7a5',
 'e71a8eecea8d13936198',
 'e725292a389dc7a7fb2a',
 'e727b4de69ba64d3d168',
 'e727bef1d0696ba8a565',
 'e728195037cd874c4d2a',
 'e72f2ac15b68c6107559',
 'e7308d4751a5609174e9',
 'e7344bb2f22960c245d0',
 'e7351a187d55f4cf16a5',
 'e735cefb4f539353ec8c',
 'e73876c4b99e1999660c',
 'e73a744c3bb2bad68788',
 'e73cdf6cbc8977565b19',
 'e740ed0325db201cba9a',
 'e74735cb7cb687bf93c5',
 'e74bba98107306ebddb4',
 'e751bc42b41f4dcde255',
 'e754391c8856c12ee9d2',
 'e7566eaf7a39137c45e2',
 'e75717fc82babe680be9',
 'e75730300453910c7a2c',
 'e75db80efd99f9531cbd',
 'e75eec1ba2b5eb5a6301',
 'e7629824c583c0818e53',
 'e76a91f1176a04e0a914',
 'e76d981e6236787b9325',
 'e76dc316ebb17dfcc992',
 'e76ed52ad79c9faf29d8',
 'e7742f5de5c140d8608b',
 'e774c578294e2142cbb1',
 'e77a728c234b7fc65d41',
 'e77ba4392f7abb263bef',
 'e77bd49c5be585d66ad5',
 'e77bf67280cc594d7d1d',
 'e77efdb27f281eb16770',
 'e78094cb3a6395b4d64e',
 'e7831849f236ad69e26e',
 'e7860d02a97877a4c7c4',
 'e7884e73dd54a8885e96',
 'e7909a8756186a8bb769',
 'e79290d565511bd736be',
 'e7929ab2df90367cf735',
 'e7964a64588524ba46a4',
 'e796cea8a4aaf91408ea',
 'e7979a8e80f4cf5cb2bc',
 'e797c3ce56166acbbe0d',
 'e798fb33a6119433dde9',
 'e79d87f1c867ec8af2d0',
 'e79d89594d102b3fc481',
 'e79dcb969f452a026fb1',
 'e79ecff3ebe6fe5f429f',
 'e7a134fe5aa110077c13',
 'e7a3f3113406af5b01db',
 'e7a47c9ec6e4044fa3c6',
 'e7ab13c8f384579d1cf5',
 'e7ac349bde3004c3f7ee',
 'e7ad6121f600ca83e5a7',
 'e7aec7dc1e94844ce960',
 'e7b14d6cf5731eacd47c',
 'e7b1b503e1dee3ba8e60',
 'e7b3e23aec2d0b706b2b',
 'e7b7f1a11ff08c8f5297',
 'e7bae52417c8c23093b7',
 'e7baeafa31c06e8b8eb6',
 'e7bd6f5395cad745831c',
 'e7bf43ff40e3e38de271',
 'e7c2820c7718ebcacbeb',
 'e7c3e27b89f7513995df',
 'e7c46258480067a29a9c',
 'e7cfbf2b4397ebd98a66',
 'e7d468690f6be9c092d0',
 'e7d619a74223786cb886',
 'e7d9ecff3d853de8786c',
 'e7e2d9b9d5512b474889',
 'e7e3e85fe33ce3e7612a',
 'e7e59c3f244f5c84d0b9',
 'e7e6076f172e6633db65',
 'e7e61d30d11c893ff699',
 'e7e814b3d6ce340ddd34',
 'e7ef113cbfa54a2ae83b',
 'e7ef96d66e35c879043a',
 'e7efadd17b340bba64bb',
 'e7f2ecc27b6af560740d',
 'e7f6ad03a7669b87a3f3',
 'e7f96542630bc915f7a8',
 'e7ff7caa9be475d0d9be',
 'e8035d25305a6d5debbd',
 'e803c57b54880e2da0e8',
 'e806c77c880e763b730e',
 'e80713365f7bcc2425a3',
 'e80722d8c5880b63fe05',
 'e80748efb559df802ebb',
 'e8081c3ab57bbc70c4bb',
 'e8090673b396e772f898',
 'e80e0c8bc1d6f4f5c533',
 'e8142d6e370e5acdb799',
 'e81c74daacfe8195027c',
 'e81f873cc7809e58c92b',
 'e820b9a26c5c52aec747',
 'e821e70a6dc7aa960363',
 'e8247b7ecdf8d424a180',
 'e827d23ed7bc381cdf9b',
 'e82b28425f45a16a650c',
 'e830ec6cba2db1919ec8',
 'e8341c2a760991ec9109',
 'e8346171f99744132fc0',
 'e8382a6dc4366e9a1521',
 'e83af45c257b1e8405cc',
 'e83dc94681a8ae042819',
 'e8476c6953ddb9890632',
 'e84b70f1693d0fd91ec0',
 'e84e6a30b410d3e9a792',
 'e84f0b319f1f6b79bf31',
 'e84f8c9cc36e7200a62d',
 'e84ff1219b9d59ae3173',
 'e85624097bc447f1cd65',
 'e85755b34fa5b7b0d204',
 'e85b42bbc7a9252392fe',
 'e85d3a8c2b108f5c9b9a',
 'e8644df1b40fb047be73',
 'e86582e95956db184b44',
 'e86713f0a5a54d758ea1',
 'e86d5f55387e6bf23e6f',
 'e86dbefb2e9da6072f43',
 'e875be60ce5288cc2ba5',
 'e8770f91eb6143a2b19d',
 'e877396468695476cf13',
 'e87dac6c322a2c782f60',
 'e8802d51150d1e2f30c6',
 'e8869621393b8c3e7b82',
 'e88c65740e512773660e',
 'e88d08e03e2d8e7ad4c1',
 'e88d3031618c65abff40',
 'e89122cc3c1ed7d595fe',
 'e8930511c6b88dd908ec',
 'e898a87d8bb80c803538',
 'e899631b91d4dad705a4',
 'e89bfaf1aed8ee67103d',
 'e89ede3fb4612aa8158a',
 'e8a5a7822442f460af5c',
 'e8a7cad4d2386db4dca5',
 'e8ace6a86ab3a1b1eaab',
 'e8afa04f385b83a775b9',
 'e8b4193514960b3af177',
 'e8ba7e6d82b8e32c2628',
 'e8bf8d271ad9fa256ad0',
 'e8bfbcbaec66748f7d57',
 'e8bfbcc795fc03abcbc6',
 'e8c0fe61a2d1a5172ef8',
 'e8c2b9baa54eb166d96a',
 'e8c618948e6547675eaa',
 'e8c8c4ca09b156274741',
 'e8cfb13d1a678b62acff',
 'e8d2df573066563f38c8',
 'e8d38ca6586c0b7f5425',
 'e8d97f13f5d5d0a1f77e',
 'e8d9b415f24f59330cb3',
 'e8dae4bec4cc8231a707',
 'e8dc6988767de595c3f4',
 'e8dcbb435bacd7d64b7a',
 'e8de331f9932170216ac',
 'e8df89753d955b823f38',
 'e8e2af3596c31eb427ae',
 'e8eaa8f1b9e16abef558',
 'e8f2c2161d011ce0d527',
 'e8fc450fafe0a6975bec',
 'e8ffd1dc6f95c8991b8e',
 'e90298a92e1951041906',
 'e90554d9cd343af37358',
 'e906122ad886baf531e2',
 'e907694de3ab885aaeb4',
 'e90cf2a2224fcafe3a90',
 'e90f2fdf46951bb1cecf',
 'e90f5bcf9e29196cf9db',
 'e91099a25d26f85728e0',
 'e9144935e20af04e4be6',
 'e9167b58f45245c51e1b',
 'e91ee4c6b068beffe487',
 'e922ac553cdd8add2813',
 'e92545beceeeeaf311ed',
 'e9259b15363c28bd32d0',
 'e926102721b0e9a14fe3',
 'e926d7a46fb3954e885a',
 'e927107fa9b42834d2a9',
 'e92a24ef00ea8919e913',
 'e92a9a087aea790e27b6',
 'e932a59bcec7980f3a02',
 'e933d35516ecd67f054b',
 'e9344e1b4c3ac3e861be',
 'e9371ff07c2832561340',
 'e937c214407813e61284',
 'e93af0bb5c5f58f1821a',
 'e93ca791176894a193ec',
 'e94371104554ebbcb0e3',
 'e943eb67a670507123d4',
 'e9477f329c2435fcae0a',
 'e951bbdd355b42ae6f98',
 'e9557f6b8896895f543d',
 'e956003673ae97958a67',
 'e9566ee567e0eea89722',
 'e9574a40aa5b9b369816',
 'e95ff0113ab89ab18d8d',
 'e9619172560c95e0f431',
 'e9629570d4eb1334aba5',
 'e9647943a944579e4343',
 'e969a1406576232c1eab',
 'e96f5671f2431f62130e',
 'e972ba2dc87f35b85c39',
 'e973761c45f166d46001',
 'e979b19a3a93c5d2547a',
 'e97c005f2d85da87ab4c',
 'e97e4099ee6d8ccb022c',
 'e980ba88cbb59ac7b9f9',
 'e980e31cd48e3b607223',
 'e982cdb75408e585d58d',
 'e98663c92ff23ce13001',
 'e9876f8bca1ea8a7ab41',
 'e98afa87ba4d5f1fecac',
 'e993a428898441dc7c2d',
 'e993eece127ba5313126',
 'e99456332924ad247e46',
 'e99606c25b5953e4c077',
 'e99bb9d71a881561484e',
 'e99eacf1f2cf52f8a95e',
 'e9a0909406ba148638cd',
 'e9a6cdcfda01b77cd102',
 'e9a767dd39df3f006866',
 'e9ab2a08a6b9c19d8ad5',
 'e9ab75199f2be7249309',
 'e9adaa8cdcf01170cfc4',
 'e9b00f0b23ad0e46a592',
 'e9b46947088d7e68a84f',
 'e9b4b1418fd3de9043b0',
 'e9b6d84c82ae0c91aa9a',
 'e9b8afd86090276ad4ce',
 'e9b98e5c727abc011af2',
 'e9bda07c21d7a510098d',
 'e9bf92651f6642ebc981',
 'e9c305fc3f844ce28649',
 'e9c3569747f7e17ab6f9',
 'e9c47af0306198b7ec1e',
 'e9c8ab6492e5dcabe3e8',
 'e9d2f2e4e6cbb15e3bef',
 'e9d55382431452604d0c',
 'e9d7ee1160f05b15797c',
 'e9dd7726c850f980d9f2',
 'e9e04d17366520cb6b05',
 'e9ebba0b19c3687559dd',
 'e9ed7a7df95775fe4b34',
 'e9edd7392d3d1dc9e99d',
 'e9ee6095633ec289d3fe',
 'e9f074e3de26f44269ec',
 'e9f6452e775df1ca8c8e',
 'e9fd5cf35ba317002ca7',
 'e9fdc6f6698d68eed218',
 'e9ff25cc20ae21acd6a9',
 'ea021a3e91a1ea116cc9',
 'ea07c2aedb1101cd2f06',
 'ea0820255039c05c56cb',
 'ea09573d62a7a0e3a7b8',
 'ea09dfcb7841b2be37aa',
 'ea0c014dca785f6d8266',
 'ea0c7147d6056add51ba',
 'ea0c801e4bd3266ee0e2',
 'ea11e6852585938baa2e',
 'ea120a55bbc987030e74',
 'ea148888c86fa62758c9',
 'ea1aac6ef8263a8a7ac0',
 'ea1e2e2f3abde83c6e1e',
 'ea1ebb8d30109cbbf549',
 'ea20638d4f1853f81281',
 'ea36c6fd2052f2e089b0',
 'ea3962426626ffdb5856',
 'ea3cd3ec785a7e7ba468',
 'ea3d6f9f41daf8d6ff47',
 'ea3de5aeec0b86abe02d',
 'ea3ea31ebb714ffc3232',
 'ea3f5bae0c434818f34b',
 'ea40654d622c74913479',
 'ea42b90107d03ded3880',
 'ea457d917d89a43af7f5',
 'ea4598da3e8d141a9ccd',
 'ea47b9f40753f6f366a8',
 'ea480e405d1e5469a3e6',
 'ea4816e0e72c621a9b77',
 'ea49e271487932859233',
 'ea4a6d631685633b2953',
 'ea4b9f01d2aa5d6ecede',
 'ea4de09a83cf4b985abb',
 'ea5e2f0c35b3b38baed5',
 'ea60323cdc730647cd85',
 'ea657dae57d33a36b308',
 'ea674843196af87217fa',
 'ea686b89307c8a972167',
 'ea6904f3cf75f47bf198',
 'ea6ed3c0a3a5bb907c49',
 'ea77899cdc4118659c2c',
 'ea77c6bd7378693f9120',
 'ea7a67a2b6815135afb6',
 'ea80eb8e5c4b607c2704',
 'ea82b34d8aef81aeb486',
 'ea834d96c4be1642fc90',
 'ea866eda8c552be22a5f',
 'ea8932ee33db8b225db1',
 'ea89d9385a2e6c15da84',
 'ea8d940d579f79f22c1a',
 'ea8ec9aecf43025e1759',
 'ea8f6dd42b75d5e30984',
 'ea90606a6bb417aa12ae',
 'ea95979af947e11a51f6',
 'ea97a5acb667cc294acf',
 'ea98540fb2bbf7f831ee',
 'ea9a60f0be8752ce098a',
 'eaa72ee281f821ccc8ab',
 'eaab4499a14f3c427bbc',
 'eaab658787d634417c65',
 'eaaf76d66517d13d24c5',
 'eaaffc35de4f71d7fba7',
 'eab0a5cce4acc7e378c9',
 'eab1508a2a4bd642af65',
 'eab1e613f47ff380a89e',
 'eab22d8d7b890d3e03cb',
 'eab94b3aa9246115709c',
 'eab957efe6cb2224ad1d',
 'eabafc99bb18bff0b283',
 'eabf399599274b166b9d',
 'eac1c6aa9b41017c77dd',
 'eac5833a6415e5ab796a',
 'eac6ddc03bf2086396ce',
 'eac9ff5e276051628a8d',
 'eaccddb64ef8c8b8d6dd',
 'eacfc39cb487a1603232',
 'eacff78161bd4469f2e9',
 'ead1aba6af15803b2257',
 'ead66de12ef18c5da08c',
 'eadb883678383f535953',
 'eae1e55d73be2a433c5c',
 'eae39be602bcb88ef94c',
 'eae64375aeb7a99b5dd9',
 'eae87a8a64263e53b293',
 'eae9b0beee4a67adaf3c',
 'eaec5ffcd0929c2fe917',
 'eaeee0f629e59bee51a2',
 'eaeff3eb9c77680d71c7',
 'eaf3b5c55c50774fcac0',
 'eaf73a0b4d20315e5ad9',
 'eaf8e1ad1cd3dbe8356e',
 'eaf910a00857c0b26d8a',
 'eafaa498cbba6c9e8eea',
 'eafd3a079b37078c386c',
 'eafe9aad49d6166a95dc',
 'eaff75249e9fb9e8ebd2',
 'eb0231f51de5f0b32c3a',
 'eb04d92c733cf407a35d',
 'eb056b4318bf1fc577a4',
 'eb095238325c2c8ffa78',
 'eb0b35da24e71b3bf00d',
 'eb10bc05320bacdb3dba',
 'eb13aef8bba23c613882',
 'eb14a53c28f0b15bbdda',
 'eb162b22c0209dc966ec',
 'eb1d13dbf1898e02cfdf',
 'eb1dba3deac91eb2bb3c',
 'eb1e4808b34d1a2d5a4a',
 'eb1f3ca009c5be95c418',
 'eb2673de565e86a238fc',
 'eb281db11bece3b433fc',
 'eb2b1c6acec0423395ce',
 'eb2bbf8b29597e59b675',
 'eb2cc4df539b8d9a8dc4',
 'eb31bd4705da6cc43d0c',
 'eb34623cc4b14140a667',
 'eb3751d6bbadc8863548',
 'eb3a7f04ac9690270d75',
 'eb3c08a8e84253f95cad',
 'eb3e9da491dab7544e81',
 'eb3ea5dee1f3e1ae7894',
 'eb3f7046ed37a153bf68',
 'eb4140ec68eb3fa42f57',
 'eb42ee6a5df42070eae7',
 'eb4fc75ab2d53beb53a1',
 'eb539269a6a3725f42e0',
 'eb5afab0563bce25378b',
 'eb5bd04b4de288cb5ceb',
 'eb5f5ecf103b7b061edd',
 'eb61613b788eabe5d44e',
 'eb645618db7526da1095',
 'eb649ed7300d99164d0b',
 'eb66a29f196d304ccc1d',
 'eb684659f1a1fcc98929',
 'eb6fc1800ab7a2f4aa0e',
 'eb72ed0b730955ad0c96',
 'eb765694dac7c3db3c80',
 'eb7abce46c2788b92a31',
 'eb7bcec9c6ed2a180cbd',
 'eb7c0744a80809754945',
 'eb7cc0a36bdfbd7bd312',
 'eb7db79c5eb5ffe4b9b2',
 'eb815551d659982c0b08',
 'eb83e4a943acba1001e1',
 'eb868eab397a18d55a6e',
 'eb8aab770b8051e7a764',
 'eb8c1c6789167c3d3580',
 'eb917368a92e80f1ac22',
 'eb95637a10fdb530821f',
 'eb979e20840634fad673',
 'eb9b0e06a0262a774581',
 'eb9d5597619e3d6d75f3',
 'eb9f8807097355f4cb18',
 'eb9f8a50ba50c8a408a4',
 'eb9f8b8a3c5fdeeab5d9',
 'eba0f7c2ba6bdf4be2e6',
 'eba13c922618bd7ee6d6',
 'eba83f0db52f1f2f0985',
 'ebaf6fd6ba22114d3259',
 'ebb2ca6026590909a567',
 'ebb60f2280270f5c42e4',
 'ebb709dc36567583321c',
 'ebb9c15b624fccc0ee68',
 'ebbc0cae7fe0b2103bf3',
 'ebbc8d96f56fb22639b8',
 'ebbca61b8e760e81a1c5',
 'ebbd29dcd7c248733b2f',
 'ebc2903c48c6cf79ddd4',
 'ebc407e6a0cb08710fea',
 'ebc7dc85208f9ddbe8fb',
 'ebc7ec1622d87a6df489',
 'ebcd1b5eae9ff76a5fe2',
 'ebcf96f52f4d2d6464e9',
 'ebd3f32729485111e9a7',
 'ebd851733863ae45827c',
 'ebdae2857d66ddc5de9c',
 'ebdd42ad72df325ff006',
 'ebdf89b7f1e14fa23ec1',
 'ebe0bf548b25cdef42a1',
 'ebe5211fe6fa77d57783',
 'ebe650aa5fc247556cf2',
 'ebe73466dba850c02c32',
 'ebe73a3ddaf1fdeed219',
 'ebe7edf793816c64ed02',
 'ebe88671d720373f8cc4',
 'ebeaaa66c9d7049e2910',
 'ebed82619ac33bc1c74d',
 'ebf0c22fe2293a699b0e',
 'ebf0deb9189948fffd46',
 'ebf4ce2ae8a085d1e7d1',
 'ebf73a03ad7d3378f00a',
 'ebf8051ca3ebccf64b11',
 'ebfaf489ea7525b9e972',
 'ebfe856a51a3bcf03662',
 'ec00be5935b9d921fb08',
 'ec0395ceacfa34b5d553',
 'ec0eca13c1d0593c7c93',
 'ec0f37399e70dc26351d',
 'ec11fa9e7b6bed78c5a6',
 'ec1498087fa50b5c1d8f',
 'ec1aea3ba45b4686def6',
 'ec29f3dca3f7742d3f13',
 'ec2a49dd35f7864ce206',
 'ec2d32c441694e0eea50',
 'ec30c0fca89827c723d0',
 'ec30d60e788e5ce46e68',
 'ec3238af8f6190a93252',
 'ec38082d37332fe227ee',
 'ec38ba1f4e327df195b8',
 'ec396f015475bf07280a',
 'ec3c33972291f6c6d481',
 'ec403f59ba0121ee03f6',
 'ec45ab906b0cc03975db',
 'ec46faf2c43fed8bfaf4',
 'ec4bf16e6ed2fed4edd8',
 'ec4ed02fc2e21f0c0070',
 'ec501a5c5347e21a0ad5',
 'ec517a2da3ba9288c260',
 'ec5183b6f248d43256f3',
 'ec536816a52c7c062bef',
 'ec53a442f1e618a2d08b',
 'ec5450f689c56f0af882',
 'ec56ec5479e56a7994db',
 'ec57c35b0d6e2ddb60a0',
 'ec588d8bbe8f109d71db',
 'ec58fceda183cc94c123',
 'ec67064ba7ac42bdc21d',
 'ec68d4c3040770386a5a',
 'ec6b55dc505c1af02833',
 'ec70e58a946d13344dff',
 'ec7382b4c84bddf2a23a',
 'ec7491e28dd77304915b',
 'ec7af52571c3bc7beade',
 'ec7fd571023fbd7046de',
 'ec80685ca6a068f685af',
 'ec8266f82ab6ef34d57a',
 'ec827e560338b824d37a',
 'ec87d1b27984fb6f8f35',
 'ec8cbdd27f262e1c71de',
 'ec8e9e96fee44d86f55a',
 'ec94af4490b254a89a5c',
 'ec96dd149bcc885f7931',
 'ec98be6a6cb9b27bf441',
 'ec98e281e81b3f49aa79',
 'ec99aeac712532909c4a',
 'ec99c7ada3e0ef5d0596',
 'ec9a78f879b26b5c4862',
 'ec9aa779edc1caf8ae4c',
 'ec9bc45d439bbf8968f6',
 'ec9d08208ea54b25c39b',
 'eca0b4b67148d311f869',
 'eca2efe1e6e8f998fa00',
 'eca3f68b96ead768dc7e',
 'eca45c7683f491496a55',
 'ecadf3411f8e67b12c45',
 'ecb6604a07fa9fd1f283',
 'ecb7bbedd056661b4da9',
 'ecba4d5a936c4374c95f',
 'ecbb7b4a1f91eba00f8c',
 'ecc4f846cc744945953a',
 'ecc9720b1a51428decdb',
 'eccc3cc9be844466c170',
 'ecd4234b1c56e7e49143',
 'ecd50b349c61b521c1a3',
 'ecd642d527ef8541416a',
 'ecd66652eb1a87004a63',
 'ecd9fedc4ecaf8731d47',
 'ecde9eabc225ba58f5c9',
 'ece08dbef2e269727fb1',
 'ece339d68487349665f2',
 'ece38454f6d61fa6a19c',
 'ecec5c8b8fba4a0cb789',
 'eced38bcf63066bdffda',
 'ecf0a4073f1dbf48c142',
 'ecf25fed9e662904968d',
 'ecf2b172494b611025ef',
 'ecf2cb196225dc24902a',
 'ecf2d424c27277bd0fb1',
 'ecf53456ec65e383c20b',
 'ecf6061509d500823a3b',
 'ecf6539b2f316446976d',
 'ecfc824107ea490f6081',
 'ecfcdea781c54332a200',
 'ed031f1c2bbfa1162d13',
 'ed0a64f9f8bd6e2d1648',
 'ed0e60d75f136f20baba']

# %% [markdown]
# 23

# %%
qids_23=['ed0f5064f3c67b2df91f',
 'ed11ba2c41c26927f9d9',
 'ed165d431802c6d74f3c',
 'ed16ae71d5d9b311c5c5',
 'ed18f8fa08559bed9857',
 'ed1afdf9798640d543f6',
 'ed1b1826c6ea0ecf8f8d',
 'ed24b7520687f257e1e8',
 'ed28f891b7e548ce7419',
 'ed2ec3e9784915cdd9fe',
 'ed2f6e5afc3bffaec51e',
 'ed30749a85155d5db622',
 'ed3717c53b2ca809e0dc',
 'ed3a43b5a31ea652d8ce',
 'ed3d5bbcbab7fa2e5b3d',
 'ed40ce428726808c44d0',
 'ed40eda1443572482e4d',
 'ed432a833a61c2de7604',
 'ed44a4a6a21241b91d23',
 'ed4a37cd45e0baf0ed6f',
 'ed4a5cdc4cae6ed12d6b',
 'ed51a2ef2ec87d3ff79a',
 'ed538050aaa361a10810',
 'ed57dbbab5c9bd4ca877',
 'ed5b63a1ce542607a6d5',
 'ed5c08cc9f6dac01b16b',
 'ed5f22d069b8867374e1',
 'ed62697e5face778dcc0',
 'ed63548d84d88548bfb5',
 'ed676fcb5511f842f148',
 'ed6d1fe593c1018308b4',
 'ed6fa083055401e4fbab',
 'ed70ea749a094fd7ceec',
 'ed74011903f8dd6c98b8',
 'ed7d1afd06d279df5c36',
 'ed853eefe6dd1780c575',
 'ed8a764915899da9ae70',
 'ed8b3cce8b9ea8e7d8ed',
 'ed8fa02867e3e32c6423',
 'ed91e8cf90fbdf9e8062',
 'ed968f4ab718c6e369ac',
 'ed988e256385300cfc30',
 'ed9c1f38e2ddeaa9bc53',
 'eda427e2742e68e8678e',
 'eda817ed40a2e4659c2c',
 'eda9c390a30f8fa892dc',
 'edaa76989927d8be744c',
 'edac53bca2f052b7b9a6',
 'edad24f5a5708f6267b3',
 'edb0374a7c70097c528b',
 'edb45d909a072dbea7b5',
 'edb52673fffad9318bd2',
 'edb740ce058d2650de2c',
 'edb7617192207fa4bc12',
 'edc1ed67b67ee6c9f44a',
 'edc2c7c91090da33b7bb',
 'edc3bce2f65728868efa',
 'edc4228adbd3005cefdf',
 'edc5511bf658099af0db',
 'edc91d20ee6e1f928e4f',
 'edc9c079f380925e7875',
 'edcb6135853073b12482',
 'edcf929ed27b86e9cb88',
 'edd39a2fc29ddc656899',
 'edd57d15bbd6acc56966',
 'edd644c5aca7aa2e82a1',
 'edd7f4da493c2003d536',
 'edd8e99198ce8cb77528',
 'eddbdb6e92379ba65637',
 'eddbfd0be3cd15be2234',
 'ede3e47ad8c3b5118614',
 'ede9346070f1d7d17a61',
 'ede9a80608a37c827a2c',
 'edecac5a93a64c40aa6d',
 'edef274066e7f18083e6',
 'edef2ee3a0bbd5e6f019',
 'edef51654eff958ee837',
 'edf28d39ecb088466835',
 'edf49ff037a6227ee4d2',
 'edf558e845655190d185',
 'edf5d39a5940b25e3f6a',
 'edfa68f84a52978f08aa',
 'ee016765b1fa7145cf21',
 'ee0331b180527b621213',
 'ee03e0ea48200b1f637b',
 'ee05779e72288a79dd4d',
 'ee0ae8bf07440eaf99b4',
 'ee0ff2f91b3fd710e311',
 'ee1007f4d2c904636239',
 'ee14da79ed76e8101a8b',
 'ee18066fb84b59b3156e',
 'ee1ada8708fa4a871d2c',
 'ee1b2f91e90314a21956',
 'ee223d437813fef6f2f6',
 'ee263f5f093a6d0145d0',
 'ee2776e850692480a0c1',
 'ee29496aceaf682d222b',
 'ee2abeba0997b52d0282',
 'ee2f0cc6421817490810',
 'ee33b99d1486f7d69c92',
 'ee34f81c6456ea0226d7',
 'ee3d14e032647587221a',
 'ee3d99ffab38dfd8d213',
 'ee3dc412fc45520fde3d',
 'ee3ff1ee5ce2385c8275',
 'ee4178771feed98f633d',
 'ee460b3bef1324cf998a',
 'ee483559513a6029d897',
 'ee49bd811629d95ac5ac',
 'ee4bccabbddbf6f4caf8',
 'ee55e911587ba6932e81',
 'ee568072f22ba20b3218',
 'ee5a53cfe1ad9097fb7a',
 'ee5beb639ffca883179f',
 'ee646557adf0fa5fee29',
 'ee6507df3c5de1f3ef95',
 'ee6542c56fa362fcf2c7',
 'ee66354d83affd15e1e1',
 'ee6877d13c37c6a18faa',
 'ee6c0b766bf68761f287',
 'ee6e2b76f8984d11e236',
 'ee75ad91afaf75e5d0b7',
 'ee78215d2b0f8ac23333',
 'ee78f956c7f67d094d3a',
 'ee815799d1dc4647b5e7',
 'ee87fd17e0bac3c9337c',
 'ee89f1064c87d72c4526',
 'ee8cb1460d8e50e16554',
 'ee8d6ea7b717afa05686',
 'ee91e41dc76a34fa2ec2',
 'ee920a9457a5f358b2b2',
 'ee9405df68466cceac55',
 'ee96ddf03b59f075d058',
 'ee98f80bbcfed161e571',
 'eea23e20ef524fc0bb20',
 'eea278b238e3f784533a',
 'eeadb32add7265846591',
 'eeb23322672f5b765b3f',
 'eeb313473dce085ebd36',
 'eeb5afecfe31fc13985a',
 'eeb8c01730a503ae4c07',
 'eeba17f1b10aff7e0588',
 'eebaf9645ae17260f365',
 'eebbb1befb851b9e7f22',
 'eec05e1fe306b3a88757',
 'eec278c3ef1a13071f10',
 'eec5b111c705fd35cc31',
 'eec955840b7b76657de1',
 'eece2c580166d06dd2cf',
 'eed1810475883c6243f2',
 'eed3ac8fee9a0bf12b42',
 'eed7a888a61960e0c6c1',
 'eedd84c229390719716a',
 'eee40ca593edb304528c',
 'eee45a9db6958e5d3334',
 'eee55578803e188eabe6',
 'eee96058f64e34c7324e',
 'eeebae82d13cc4477411',
 'eeed8a4d5c17a7bdb33d',
 'eeefb694180a82b5b720',
 'eef0521d31942b34538c',
 'eef2c0d7930bf9a3277c',
 'eef9b75aaadb3a1ecc18',
 'eefa27fa3218c051738e',
 'eefa6021f1d906c2a633',
 'eefccb995a263b266f1d',
 'eeffafb8af00c676acc8',
 'ef017efe8d506accc7c3',
 'ef02aa47c33278bd956b',
 'ef046a7e91e26a0fe4ed',
 'ef08016701922eebd21a',
 'ef095c531cf7006c29cf',
 'ef0ca82e9e1c1e2b35aa',
 'ef10773ef0d29a465850',
 'ef11f7225489d433869f',
 'ef1401c1506414681be2',
 'ef17a56b728f2c08e813',
 'ef211069abd5549d5cf7',
 'ef21acab8ba295c44e03',
 'ef22035c0c4fe23ad625',
 'ef235340d07bfa6f24f5',
 'ef25835a2bee5e0ade42',
 'ef2a0d1d473c2aa35f85',
 'ef2a4bd1da8f8be8107d',
 'ef311044fced656a9171',
 'ef3465d8ae1193860d96',
 'ef392be82a66bbc133fb',
 'ef3bfd1db55967457907',
 'ef41802129be6eeac66c',
 'ef42c8de3ca68f1187ac',
 'ef462a5d838693c1b2b4',
 'ef48d3df64db69023384',
 'ef49ce0c342cbfd6220e',
 'ef4d0d83577329531f8a',
 'ef4d2c331bdae9b99c3f',
 'ef5275ebb69512bba8c6',
 'ef52c91aa49317521685',
 'ef552df9e47073b51919',
 'ef56da5e667366ce4c3f',
 'ef5d56eb1a1868b0f689',
 'ef61e0385d379e7dff62',
 'ef61efc729b170c765b7',
 'ef6cc10318a9ee9b098e',
 'ef718b74b57c2850d508',
 'ef75efc853453f6d6852',
 'ef769eff3c70e40ab3e8',
 'ef7a54ac8d30813c42a9',
 'ef8134b60af7f1cd4898',
 'ef8195f245e67afcbf10',
 'ef82a0fb96f974fcfc74',
 'ef82f21326004b50cd0e',
 'ef83f16ab040ab45b322',
 'ef8444f36f08d7b59ddc',
 'ef892c119f1e749dd9b8',
 'ef892f3978bdefcb310f',
 'ef89dbafcc859659e01b',
 'ef8f42bd7f090fd61cbe',
 'ef91a78913c1c634e2fd',
 'ef9ba2ce92c64162f743',
 'ef9c02577357a3e873b4',
 'ef9cb19e4679bdd66ba6',
 'efa08c7efed2afb5fd7d',
 'efa21d26a32d1a86de2a',
 'efa6569b392f33af8955',
 'efa91a4ad8035b2cf8de',
 'efaeb10f21e3a8169553',
 'efb2f160ae6c5ce5121e',
 'efb6f26f235a895415d4',
 'efbda6d22645d4191a96',
 'efbe9f73bdf5a1750180',
 'efbfe6096139a0322981',
 'efc1c78e7dd21c98a94a',
 'efc441c6d9ac50c09cdc',
 'efcd187a77d836d31648',
 'efd2ff317136e94c99f6',
 'efd35781d669ff0cde52',
 'efd62f64100918fa5058',
 'efd897be0d8866065e6a',
 'efd95927cbd304a77954',
 'efd9c78bcf1bc3f7eba5',
 'efddd0424a79672fbaaf',
 'efde28684b26d208bc0e',
 'efde2b85e4fce57324b8',
 'efe3fb1e67d2c5b9628a',
 'efe766b5903bcc825b08',
 'efe9596cfe344ec90f4f',
 'efee4bea011f628d35e4',
 'efee517eb859d8f53315',
 'efee6f2890cdda299b54',
 'eff0763be7c6dba8b01a',
 'eff929061dd6bf80ff9b',
 'eff98affcd25b4d8d906',
 'effa03ad789bf2e35118',
 'effa51771402a2fcc74d',
 'effb756ea8a84c307c85',
 'effbb80ec466f842bd4d',
 'effbea0d833eb906f3cc',
 'f0043a4fdeb660e5e36b',
 'f0098dd792249a89fe78',
 'f00b55f5cf6a2c888902',
 'f00bb20a98a906bb4c5e',
 'f00db9150ff76d53ff8c',
 'f015bfe7e1ed3d8c2522',
 'f01e9c31069e66e98ec1',
 'f025494db143f7b8b17b',
 'f02ae4a2fffdc456dddb',
 'f02ae83e3df8a64dbdc7',
 'f02e48b995206645331f',
 'f02fec84f5c8b1acd116',
 'f030f90c5e5a3640cf0d',
 'f035dae2eff1d7018a6b',
 'f036bc2de8c832d0cbd9',
 'f037290c800a2bee5570',
 'f0391e459fb0a676fc28',
 'f03b8837fbd4afb4fcb1',
 'f03d39a27a9c98db760c',
 'f03f2763a3c4db9a4fbb',
 'f044cb7034791216ef7f',
 'f04c0d4237260d9992f6',
 'f04e9041fef5a1ed6415',
 'f04ed9e7e69a754e8a4e',
 'f0503b155a16ff8c16b5',
 'f054c02c3264a129a907',
 'f056403812839e19ed89',
 'f05670d9c7cff3056e12',
 'f0598aace20435e68def',
 'f05ac022632a0a261c4b',
 'f05b5137ce811d784f3f',
 'f067e91749bde47c30a0',
 'f06c412e932c1fc5836d',
 'f06ddc95335c83e836fe',
 'f071386ad74f30b230eb',
 'f071f7698217a1ef0404',
 'f073090e9076b0a738eb',
 'f073b88ec8d0d94bb87e',
 'f07610571d1acef31435',
 'f07bb8294700dc75427e',
 'f088acdf39c7886a410e',
 'f09270624a56eebb9220',
 'f094938fa7e5056fc3e2',
 'f09810b453d5077036f7',
 'f098855d9596a5fcae78',
 'f0a2aa2343b56421b517',
 'f0a3fd9278c5a3f388ca',
 'f0a6683584c750330749',
 'f0a886a74a4811d06524',
 'f0ac17bbd4d51b25d4f1',
 'f0ae5491add5598b214e',
 'f0aea365d6779fdc8c1e',
 'f0aed34a3ab1bb1153df',
 'f0afe56b0f97e260acca',
 'f0b0037394717b0144cb',
 'f0b1e4d38b0dcfda787d',
 'f0b28924b0b0c5ec06f7',
 'f0bb0134876f4381040d',
 'f0bd4deefba6cff5c1ea',
 'f0c080d552c736068d58',
 'f0c1379b6cb9a1ff69bc',
 'f0c6273bdb408c789c56',
 'f0c845898e2ba9268b43',
 'f0c851ef28098e7d7517',
 'f0c8fe0ef48e961d9f8b',
 'f0c9252410ef9939462d',
 'f0ccf74b256a26a1d880',
 'f0cfb585af22ac6bc695',
 'f0d095ee1f5d9a4b5de7',
 'f0d2fe04813fc35307ce',
 'f0d5571ede77ae6cfee7',
 'f0d58bb5b552f669631c',
 'f0d5eb6eb8b45216e22b',
 'f0d8298cada9baec4c82',
 'f0da6783fc29d3d2f6e1',
 'f0dafbebacfc9b61618f',
 'f0dc234a8731da86680d',
 'f0dcdf4e45e0a69dc933',
 'f0df1234b734c56d5952',
 'f0e04ab2a5a91f1fce68',
 'f0e362110262d34fdbed',
 'f0e3dd0199724d740ea6',
 'f0ebb1fabedd7439a6fd',
 'f0eec0f2d5dd19ebb0b0',
 'f0f02f45be3a77b6d403',
 'f0f0eb341f416fbf8c69',
 'f0f737bc14c36800116f',
 'f0f759ad3afa7b17f461',
 'f1043d5940c2218502bc',
 'f104d72762125fb8fafd',
 'f10619a03bc1317bcfd1',
 'f1078cf2e89d8bc2f0b6',
 'f1091fdf8aec363eac30',
 'f10c3b821f012d815a58',
 'f10e79246f87059d608c',
 'f10f69e34839da21aeb5',
 'f112672a189971c1a24b',
 'f11453c77cd2b59dfea1',
 'f117954f4ce16e91770c',
 'f1188ad184252e8f9854',
 'f11921ed3811fe4f5ba7',
 'f11ecfeab5e269cfbff2',
 'f123f672f426625d562f',
 'f1242d55e784d3895cc9',
 'f126d7223fdedfb1b5ac',
 'f128d69f7665c9764be7',
 'f12a407f4ac5a9e0d0f7',
 'f12cb651aa15d27a8ee7',
 'f12cc3d217b912dc282c',
 'f12db81cb1bfb230a807',
 'f12fd3a205a55f7acbbd',
 'f132e4b930543b0e7a89',
 'f132f658c211048b1c83',
 'f1379415cf17556e9287',
 'f14056d9538a3e99130b',
 'f14136faba8804dfee06',
 'f146169642d00ddb13f3',
 'f146ec1f0ad0dd09cdb5',
 'f14a169fbc691f71b016',
 'f14a1a47bd9e8b277167',
 'f14bdd0d904b42d1fd07',
 'f14dfd7c5779fb19e7d1',
 'f15238e6f45c24211e98',
 'f1531abb334636e0994c',
 'f158cb47988536b5777a',
 'f15c1a1b39063a8c079f',
 'f15e2bc493fd6159f10e',
 'f15e3ceddf6125d1f273',
 'f16188c979cd978035e7',
 'f1623bcd058ea2bd0bd1',
 'f163de889508c9a45f22',
 'f1677e93417f98b62992',
 'f1690aed7a445d56861a',
 'f169161d5e0180f2ae64',
 'f1699d17a39ab739dd15',
 'f169ff1001121be5fd47',
 'f16c2e1e4fd56027ccb5',
 'f16cdf5dc46bf6f327ee',
 'f16d5f22853bb07c9d3e',
 'f16fda308c8ff9db1144',
 'f17b0c8c7f7bf3d477b6',
 'f1805a3f3d186396789a',
 'f1814cabd604fe972fd2',
 'f181ead90b5d01a1c79e',
 'f1827ea58abb160f7760',
 'f184400515d5ad1364cb',
 'f18a448b91a91abd4fb7',
 'f18a511813e91b86ca04',
 'f18caca6ef5b3c52408a',
 'f1906c050b21539d3e00',
 'f19b67ed818dd1cdffaa',
 'f1a0e533a64aa3f32b59',
 'f1a3ba05b8fc75a2f902',
 'f1a792324db757f2d928',
 'f1a89da6334deaf28bde',
 'f1aa935348200bfc9ab2',
 'f1ad2a3c161c5da6ffe6',
 'f1ae225b829b581cff39',
 'f1b154c5ee72f3225cc5',
 'f1b1af9c5a0518ee3f97',
 'f1b537a502ff4756bb7c',
 'f1b812d9d733c1879dcb',
 'f1b9e885a0a855be8976',
 'f1ba1fc112e18f8b7a3d',
 'f1bd3fe80fd3b3ae580d',
 'f1bea166221e348934a8',
 'f1c16eb89c3745424ed0',
 'f1c4c2bd861863f79b66',
 'f1c8247f7747c543f278',
 'f1c9e3935b2cb1c9f7b3',
 'f1cd60a2395e392f5bf5',
 'f1d1914a0039f4446792',
 'f1d63a6eb64ed789e983',
 'f1d7cb6d33e57760642d',
 'f1dc9c3cd4281d165dfb',
 'f1e1056f2f56e73b76f1',
 'f1e2336df77746b248c2',
 'f1ed50bf9b13a49853bc',
 'f1edd972575d2a7981db',
 'f1eea328fa007f4cb9e0',
 'f1fbecc72dbaffa761da',
 'f1fec7e4b024b4160f84',
 'f2041a0fc2be58411ac7',
 'f204e8f5de096c8e6873',
 'f206d3288117d649b7e4',
 'f2070e12b68b1554a93b',
 'f2072ab209f097966210',
 'f2092e3898674d0b00fb',
 'f20eca6c8f9b040ee865',
 'f211692677719c807f4b',
 'f214d95bfe7a60468152',
 'f21972e3a15e968d9682',
 'f21afd16254fce0a4464',
 'f221cd9cee044dc9d371',
 'f22254b4e363a29f40af',
 'f2231fe48e1cf0df56d9',
 'f2234d1e612d08267550',
 'f229747b51aa64e2c47e',
 'f22cb4a74ac3cd58f184',
 'f22f174107860f473e86',
 'f2465c0a5e228444ac18',
 'f24d678d6d23441b9c5b',
 'f24ed19bbcd223e017ce',
 'f2533d9895bc0b6a1eeb',
 'f25893408e43e8255964',
 'f25b7c86d93dde3fb57d',
 'f25c2e75b37968ccd27f',
 'f25f559d41a947fb434b',
 'f261dc5e60c9f1e8028f',
 'f262616a119f06d2186c',
 'f262622a72f08e4523a0',
 'f262ec7a47913b39c062',
 'f2635ddb3f3b5e1526ea',
 'f265b6af578d4ea87f4b',
 'f266021e128a414762ed',
 'f26641cccd46343f676c',
 'f269aedaa25c0309de73',
 'f26bf2ced2ac62d70812',
 'f26cbbae917188f5947a',
 'f26e44fcc218cd98570f',
 'f26eafcf46e92e179a7a',
 'f27258824db7eb864fa2',
 'f2739a8b7770eda5f076',
 'f2744f14e82bfacd4402',
 'f278b8a4f9da60ab4138',
 'f278c91d0451731a14f2',
 'f279a6e3e04faebbb09b',
 'f279fa39800a498d4838',
 'f27aa6e4eafdde829007',
 'f27c75e7c5ae6d632ff4',
 'f27da7948644f56f9294',
 'f27de2ca9d823086987c',
 'f27e3aef41204c3c6573',
 'f27ecb9b8ff1356cc352',
 'f28914e76895477d257b',
 'f28cf30a18d615c6d9bb',
 'f29833fec8161d63e1a7',
 'f298bac56085858e8a26',
 'f29991d7054080cf0a60',
 'f299f4af44c9ed8fbcb5',
 'f29b13b43b6d67522444',
 'f29ee44472b0dec7921d',
 'f2a3246829c300dfb233',
 'f2aaff40aa3e74968ac8',
 'f2ab2fc6cdb2a2a06c18',
 'f2aeced7d11f78d7e4c2',
 'f2b19b88c4bd7dedca1e',
 'f2b3fe9206ef22be70a5',
 'f2b52451847ad1f31c14',
 'f2bb70e400305b46e293',
 'f2bc1914ab9979385557',
 'f2bda66a0b07ec29ab92',
 'f2bfc4fb4897eef66bd3',
 'f2c1e58a20a6c95e48d7',
 'f2c492b56e78f4d523b7',
 'f2c4fd816a4044b1a69f',
 'f2cb6162aeb44058a540',
 'f2cedd4d1ccca3df3e0f',
 'f2d7be8a0ee0b418c6db',
 'f2d878852c6a482a31b7',
 'f2db09df111101e4245d',
 'f2dbafc3438abdaab5fd',
 'f2e16f100a3e1a0e9116',
 'f2e2e6edd252071807ee',
 'f2e4e3d8e4bf17f99dbb',
 'f2e767975e3e22b98313',
 'f2eb33713ada885efb6b',
 'f2ef9b844bcc69d5386f',
 'f2f0e6938be5ae8c1527',
 'f2f181f7a89f388a0c8f',
 'f2f501a96a982295acd3',
 'f2f6d8d3282e18b0f60a',
 'f2f754d4d1447e008963',
 'f2fe679b3249036a4060',
 'f2ffaf152334322cf153',
 'f30184b95bd392925177',
 'f304cd17b4b41432453e',
 'f306f93d48014981f37e',
 'f30edacc129f3e2611aa',
 'f3100ee95e7326e25a99',
 'f312464c655108aba1d4',
 'f3137a252a73286cb609',
 'f314c377344ccbd996f2',
 'f316a1a9d9b3680080af',
 'f31901c65b8128d8812c',
 'f31a3d15ed3f24009fc7',
 'f31adf663aa01f0a532d',
 'f31d9627aa4e31a80f2d',
 'f320c57fdbd40ddd44b9',
 'f32426988e20b97b78d8',
 'f325aab89155f3c6fb60',
 'f3278564dd7eac288dd1',
 'f32b33eb16621711db16',
 'f32d26efc962f02574b2',
 'f332b53fdc0ae75bc26a',
 'f332cb0ee648b1114e6a',
 'f333c369789be267bb6a',
 'f3364602c8f136d0d1e7',
 'f337cf969def38b96d44',
 'f33809c59af1b9dc0657',
 'f33f6f2c9fc1b7de4e4a',
 'f33f895e74b8161d67fa',
 'f3402a9f47db37675880',
 'f34346c4bb476642f9c5',
 'f344fcb4ad92db1e15fc',
 'f345f4e0594d45b47537',
 'f346356d0d5a2150278e',
 'f34c568f769e3df933c6',
 'f355fe8d2c27f2a5fc74',
 'f357876277fc89423116',
 'f357c0cc40d67608843a',
 'f35988d02b268b7c7c1b',
 'f35abd6a7765e47151a1',
 'f35f645bb93839f6d0ec',
 'f3639ba6a0d6ac50cefd',
 'f3655323f1a026785ff7',
 'f3661413545c6f977358',
 'f36fcd735eeb5ff4f01c',
 'f370ca2d46867cb70882',
 'f372bb37825766df7658',
 'f372e4e05ce784f72db3',
 'f379e4b11dc4c32b099e',
 'f37b73c431297d69b0c9',
 'f3804338c83c9c09e0f3',
 'f38163d20891048cc946',
 'f38325901f35ace787bf',
 'f39002d6e4986081524e',
 'f392b8566cc24634f71c',
 'f3947e25d2a8e3947785',
 'f398d2bcd84d11798640',
 'f39a759449248a2f3a85',
 'f3a3c590099191fe377e',
 'f3a49a25d82ccb0b066e',
 'f3a56219b474439314fe',
 'f3a6589e27475cb5ed13',
 'f3afa207381383dd6bf3',
 'f3b68c40fe61c3f9a614',
 'f3ba3b089564afa29fa8',
 'f3bb78c726e4c38fd92e',
 'f3bc4fe91c7c8b6d71ed',
 'f3bc52a1988628e76f72',
 'f3bc6cd37c04592805b6',
 'f3bc701e708c589792c7',
 'f3ccb572a2f03a015252',
 'f3cd95cf3bac88ef209a',
 'f3ce24a5d43999cdb54b',
 'f3cec73d07d6ef65aa04',
 'f3d291fade941b3fda8a',
 'f3d32d48f718c8afd7ff',
 'f3d9a7f02a8edaa9fd58',
 'f3dc97a9d6db8b86802d',
 'f3ddbe2b19c97dd12d1d',
 'f3deea704877aa1ee70d',
 'f3e6690263de6cb87027',
 'f3e6ea46228ace3587f0',
 'f3eb7eac6cf762e7a0c6',
 'f3eb8bf45255b5ea3604',
 'f3ed4ed89138481b58f2',
 'f3edb0d1627b57e53291',
 'f3f10057c073ae89b838',
 'f3f1d41966f1545db06f',
 'f3f1fff80bea9cbcbb6b',
 'f3fac1c4e8d2fe2748b7',
 'f3fdb09020cba4804c84',
 'f402cbf4a133b653ef4b',
 'f403333f82b81df5ed52',
 'f4041e615ba74bc94c18',
 'f40a9542fc796c645877',
 'f40b623e0c4d11a47850',
 'f40d012c42f33409f18d',
 'f411f96241cdc0c1cdcd',
 'f419645166b39908710f',
 'f41c73682c2208ed7d64',
 'f41f9ab8fe0c133c2139',
 'f420e57052b5ed09c6e4',
 'f4239d32a76db27f9bfe',
 'f425161855b69df12854',
 'f42646fdbf0d508e9da5',
 'f426b1eea117799da0d9',
 'f42ee6c51c64bee55e6d',
 'f43164a39e6b71e2c69b',
 'f433255f742e69ddc46e',
 'f434dbf0a25493f8dfa6',
 'f435e3549c83a48dad0f',
 'f43dbf39e6a11910e2c4',
 'f43fe0bb7a5668ade747',
 'f4424bb946a98e22caf0',
 'f442fd70369e0bd24257',
 'f4438be99a5805d7ba05',
 'f4445b2e21bb33cb50fc',
 'f446dffaee532b643388',
 'f448aca629ed88bb6578',
 'f44af40c2d47c6a6c6d3',
 'f44cb965a1cf891d46d0',
 'f45294b07661ae8fdc38',
 'f453adf9351f8cb804e8',
 'f4575f090e4249ccea61',
 'f458d5175545b3e24953',
 'f45a4d40aacdcc9c45fa',
 'f45cf06eee347672d1a3',
 'f45e32798e692c4a63ca',
 'f4611c96e5aa33545764',
 'f46196c94eeeb8afa848',
 'f4699e3becfdb460f00f',
 'f469f53a23ef3d017727',
 'f473c5c2e42e1a2e7ca8',
 'f479e88dd2ad180410d5',
 'f47e42b09c0676e3ec50',
 'f48024870e42926ca60c',
 'f48a2d67d6539af149b1',
 'f48f8909b971ab221f81',
 'f49052d243d30ac6a9fd',
 'f494078871d408f5f63f',
 'f497ac62180d803b62ff',
 'f49c9c9dc966e51f12a3',
 'f49cc6a59ce4a02389a6',
 'f49ce75eafa0ca89e606',
 'f4a02b221451d9845d56',
 'f4a39f8603e347b5fd21',
 'f4a9a4d740a3122e4e54',
 'f4ac4f3e50c288dc628f',
 'f4b18d9a473493ec947c',
 'f4b1fd0c10ec1ab54c46',
 'f4b2efbbab7e6b405c17',
 'f4b35ebbb3a2babd445e',
 'f4b4fc51a68916c63dc6',
 'f4b69b68f516761b4217',
 'f4ba19d5df4d2b1cc860',
 'f4c0b66075890f78f312',
 'f4c47d0be4ba74c293c4',
 'f4c4f5c27e96b8ee504f',
 'f4c64850151b894ca58d',
 'f4c74a88c2354945ada9',
 'f4c84cd8a9ae3591f39c',
 'f4c90d730c9ef57d50d8',
 'f4d23c3610cd9882b7a5',
 'f4dfa3a3e5964e87e2d9',
 'f4e0c2501c5ba106673c',
 'f4e6ecf4175630069004',
 'f4e751bdbc2faf5a48de',
 'f4ec727ea0cd1706ed40',
 'f4ef49794aea447cd723',
 'f4f0baf116a41c9eda55',
 'f4f2224acc2d5338450c',
 'f4f33f8b1cbcc3c10a3a',
 'f4f4d1a08d50788e3321',
 'f4fabe4b3440aef7611e',
 'f4fb003efa50da0b9227',
 'f4fd8246a34fd8e08c2e',
 'f501850f16391f1a5ee6',
 'f50186ad618c10df7d0c',
 'f504427e417cd7bc81e8',
 'f50c664a3cbda434ec3d',
 'f5135fbe047604f9e96b',
 'f514901859dd2cc9fdb1',
 'f517e5ca0ad5e9af9e91',
 'f51829bf85406728b9c6',
 'f51e0edd382f6df5e449',
 'f51ff95c6845cd0ff570',
 'f52110c8e92b2a9e7c8a',
 'f522fa7d35abe1a77558',
 'f527a69af10151a49328',
 'f528e70dc836ad3c9e25',
 'f529429f063c17f7295c',
 'f529d8f1eb20e120a26c',
 'f52d9e7a9708b9c110a9',
 'f533d99d48a865ed41b7',
 'f53853c5902c3dda55e2',
 'f53878d25e1b18b0f704',
 'f53b883f55046f5ae7fa',
 'f53cff6bd5c39fa4414b',
 'f53d888ea29a3981f200',
 'f53d93f12289ff2e7783',
 'f53e26ec2baac63749ce',
 'f53ea1c891e688468814',
 'f543617e82bec5e42df3',
 'f543c911fef232a8c6c2',
 'f545df10a2094d65f761',
 'f545e35003bd69af6ee9',
 'f5463689011dee2917d4',
 'f54b4caf7bca66321cd0',
 'f54ce46de0719d609b2d',
 'f551119acddc46ab5ab5',
 'f5538d960d674396963d',
 'f5566ddb3ee64901311e',
 'f55a174fc98238346f54',
 'f55d64f63b3868ec14ec',
 'f562435593b2112bac74',
 'f56557fe7901d7feb5e9',
 'f568bc57159729114607',
 'f568fb0297870c487a18',
 'f56971f1279e3ae59536',
 'f57439b8b8436104c75f',
 'f5768d4412cd469613e8',
 'f5795aeb873a355c8079',
 'f57c45fff07f630fe882',
 'f57cb731e3b7104f4253',
 'f580007a9ba4f879867f',
 'f587844976e16de85263',
 'f58a049c676f250eb287',
 'f58b5ac8dd3e33d03064',
 'f5912dcbafc96c213888',
 'f5955e7cb113586165af',
 'f598cb78e58ba4e63f1f',
 'f599865276eb0932e259',
 'f599e67db68c90072e59',
 'f59b273a73a0ddf6341b',
 'f59cec3fce4ea8167906',
 'f59da58499447a722573',
 'f59e7d9989a095006298',
 'f59ebdf384a4f3a73a12',
 'f5a2107e5e125e5148ec',
 'f5a67b492d1651257120',
 'f5aae5b4ecd9954949c5',
 'f5ac03f9e11a89150e25',
 'f5ace04d77bbfb39c861',
 'f5ad067a093dfa658d98',
 'f5ae0018ebb47b531dab',
 'f5b613424754d1833587',
 'f5b6a05d98b05ed4023c',
 'f5badeaf3f31a21011c5',
 'f5bdd688976ac35abacf',
 'f5beabb120ba9be78cf2',
 'f5bfda9797ee5c888d57',
 'f5c05d133dade20b205c',
 'f5c276a95d1ecc92b93f',
 'f5c4c2556a433f26ce6f',
 'f5c7f8d09e6bad410d06',
 'f5c99f84920fae20feda',
 'f5cd2a755cf1fd83839e',
 'f5cdcd4e9f573b49bf87',
 'f5cf107d999dadea57f6',
 'f5d18df5addab92a3f4d',
 'f5d9b3584294d08de67e',
 'f5dc29f104e06fe0ded3',
 'f5dd06fc61709cd37d6e',
 'f5e057622f544e47ae5e',
 'f5e3177918b0795da73c',
 'f5e35dfe0045cd5a0970',
 'f5e48ffbf5feee1d0a6e',
 'f5e9abe99cc40c4e144d',
 'f5eaacc6fc84f552ead9',
 'f5eae271adc470192ee8',
 'f5eb4ff81aca12c9c5cb',
 'f5ec6b00e725dc8a9506',
 'f5ed264a6433875a4bed',
 'f5f12ccfffafb0f3c5bd',
 'f5f63f7993e369a84e8a',
 'f5f74f533ebbd1e464a5',
 'f5fa32daa379d55edb6d',
 'f5fdfe6f36eeb60a8de0',
 'f5fe661f1fdd2547dd4b',
 'f604c9c2d4e924efd0e1',
 'f608a9a115188d1aad1c',
 'f60cbe3f543007397e15',
 'f60f4016e927953e0d0a',
 'f6116594b19c557e226a',
 'f613f42c7db44e45c43a',
 'f61c0f01e7c71cb8d33f',
 'f61f69285b813f17072a',
 'f623bf94ac5d1289b15e',
 'f6262002c518145d19e5',
 'f626ec1f886d76e15ae1',
 'f628519b3048a843f159',
 'f62a6c26f41dd25cc98a',
 'f62aef8979811efe09db',
 'f62b1b7e70fd846274a5',
 'f6324d1ce53b606589ce',
 'f6329e8290937a3f3609',
 'f634de044b0651541aa8',
 'f638fae2264db492e280',
 'f6392a6799c851c5e056',
 'f639516e8c6dc8ec8641',
 'f64e6c7c9a75d8283b95',
 'f653ce3443e23ec6bd13',
 'f6552bcb73cc2dbc367f',
 'f65a866af9ca97c7bd33',
 'f65b3c9ca129fb30b5a1',
 'f65bbf10638ddbbf22bb',
 'f65c209f900205a36b74',
 'f65dd4dcaf7b42190372',
 'f6619b52cdec896e0eae',
 'f66943b42e5b4d5d9930',
 'f66e19aea715df8d603c',
 'f671a14dd651fc43565e',
 'f673fea732c0f8ed2733',
 'f679ef81c85a4557724e',
 'f67d168293b9a5435413',
 'f6808def6bb56864ded8',
 'f681409e651a33bf2a23',
 'f6816408971861606d48',
 'f68205ae8e3f17b4d256',
 'f683ae7abb8724dbee23',
 'f687268f6728c7fc283b',
 'f68ea4035dd15873f742',
 'f69190e265edd4e5eba7',
 'f692a067c94224d71022',
 'f69318378b0eb07e248f',
 'f69b186667fa1ff55584',
 'f6a13b91162e2407170f',
 'f6a2a22834e9f8d3d00c',
 'f6a52014b6e3465f7207',
 'f6a6d2638b2980558ba6',
 'f6a919d503d8fd35eea3',
 'f6a91d56d71ce22bb71f',
 'f6b5a7adfac1134d6b20',
 'f6b88504d7596857879b',
 'f6b997a4d647becd31d1',
 'f6bb472a778948be2a69',
 'f6bbc544cace6913358f',
 'f6be91d17869b0bf0abf',
 'f6c3be80bcee8aa826f7',
 'f6c895f09eb056b191c5',
 'f6cc47d1bd6295d5cc37',
 'f6cf437c89e1dd2161f2',
 'f6d0ac5c3a49a4e409cf',
 'f6d1f01fc749be8cece8',
 'f6d2badae4c39b50396d',
 'f6d30db197a3b43d717b',
 'f6d33b0b098f6e27fd19',
 'f6d45d71860225800512',
 'f6d8d830771780388db6',
 'f6d9d847f5ccbc7b4e25',
 'f6e61f0d42cc812755de',
 'f6f22481dce11ad17de9',
 'f6f25f1d41da9fac1653',
 'f6f5c2ba24e5952ee488',
 'f6f633f2829e7e7e6334',
 'f6f7bb1c20e2b91f7823',
 'f6f8536e804258e26e03',
 'f6fb66e5954afcb4974a',
 'f6fbc9301bd1e86d9011',
 'f6fee562d3b5dae62daf',
 'f701b263dd6a8f83d3f7',
 'f705d7e3622a865296c8',
 'f7078efdd9703cf2451f',
 'f707ff6ac3a500b20b3a',
 'f708a57e748636c5ee61',
 'f70ae0cb9fa88048f34e',
 'f70db6d55f0a8d5ab4f7',
 'f70dc4d5117212a43f82',
 'f7108baee17f0e20e3de',
 'f710a20527612ddc92fb',
 'f7114491771e54da4b38',
 'f7139f9a7ad53bcfbc64',
 'f718e849ac5dc754202b',
 'f71c9097588318ca5b1f',
 'f72078081b1d7f5b80af',
 'f720e9c82fc3fcf52b76',
 'f7223f787d1ab1587ad5',
 'f72448788be36593f32d',
 'f733fa6cdb101be4fa9e',
 'f7388da4684e3dd13265',
 'f738a5b076369ad31fdb',
 'f73b53694433b51f17ae',
 'f73da934dd8583ee8408',
 'f73df9b0fec668c843ac',
 'f73f7face0877cf39a91',
 'f74062978011b1ca7539',
 'f742b35930aa016a1954',
 'f7454f15b02cae9e1ca7',
 'f745891d498b8e4c7251',
 'f74ab6e9b7aac6c224f5',
 'f74ad007ea66be21166c',
 'f7590825ce3dc2eefb3b',
 'f75c1d5cb779e59a81af',
 'f75f68e13f7bac558f84',
 'f75f7d031676fd102c22',
 'f7606d7c926b4f5088ca',
 'f768a0bdeb319687ecb4',
 'f77313c3bf4b71fc905a',
 'f777e172d01746469d83',
 'f779170343d61a3ab0c3',
 'f77e37b69fa5a41ded18',
 'f77f8828a70e9e766846',
 'f7878e3de5a6acaf4bc4',
 'f789602c6d9f00504d81',
 'f78cea23419360827a3d',
 'f792c49fd2d2a49c973d',
 'f795ba1fa4f4a587c1f9',
 'f79a30aa9bb3ae513eeb',
 'f7ae539dae11ed6983fb',
 'f7ae8d2694ff65e1f708',
 'f7af447304d201578824',
 'f7b029c0f52ade5010af',
 'f7b10b9591c848b0d941',
 'f7b2eeaa413eef0c7248',
 'f7b30f09679f59a23355',
 'f7b5ae71ddf5510fc48e',
 'f7bd61c4792e14409812',
 'f7bfdb86c4b08b2b47b6',
 'f7c04dcc7cdc1a06ed3b',
 'f7c155facb01346a275a',
 'f7c391214f8ccc32de03',
 'f7c9f87aa1bc3b3ad73e',
 'f7cba929e31bbc223ef7',
 'f7d1069e99af6dfda79e',
 'f7d4ae331943d31344c1',
 'f7db3c6308ce505a8d9f',
 'f7dd4c522c434f5652ec',
 'f7e6fe35aac12d2f0726',
 'f7e77643659f721f5de1',
 'f7ea0dd6ad6bd88aa4c1',
 'f7ec303c45c6a3cf7f86',
 'f7edcc2ed4da5aeb9279',
 'f7f5fae8366cc8a1f1e2',
 'f7fdcc6b935dab7b7a9b',
 'f7fdf2053a24c048ba61',
 'f80f28b97ea79f424697',
 'f80f52593dcf422cc887',
 'f811069b2b940b44839c',
 'f81961bd1ac01de90678',
 'f81a06b3f4d7113a66cb',
 'f81b07eb62ea4f819856',
 'f81b85940d81a1127498',
 'f81bb46ce62ebbd61b3a',
 'f81bb8cb1a988cd8ef5b',
 'f81cb5a055e6619b8d50',
 'f81f62fcfd5c3bda5770',
 'f820d219f301d3ecea3d',
 'f821bced8fa0d5770b04',
 'f821fc05f733cf8d7f98',
 'f82225581a1f5dfece58',
 'f825d22db9d144faa9a9',
 'f826250ac080c34a1c4b',
 'f828951c797efff5ec41',
 'f82f87bb7417a9cbed9e',
 'f8303085c0050835d2b9',
 'f8333660f3e88c8d13ed',
 'f835ae8bf03b051acec2',
 'f83bb592ba22b5dc9c6e',
 'f83cc12a8cfb13827db7',
 'f83e191ae7519e5647ff',
 'f83e1cf3d1767037f3fd',
 'f841dfc32f6357982419',
 'f848d26ba6dd1df85485',
 'f84daace8ea1fda7e7da',
 'f84de9b1e944117c82e1',
 'f8580d8edc3655050c3e',
 'f85e2419559f7b7b653b',
 'f860fe0e25ac86427686',
 'f861b2142ad6998605c4',
 'f862351578b51bb012a8']

# %% [markdown]
# 24

# %%
qids_24=['f8694f97583bf9ab2412',
 'f86c8298fda46d80e25c',
 'f86c93e3ce6408c0a5db',
 'f872b89c4e70ae3f0ced',
 'f874c0c7ad2bbf17536b',
 'f878ca54bf92b0728468',
 'f884238c5eee7a2fa59a',
 'f88432ebe2b9bf33abe2',
 'f885fffd4e53aa7cc4fb',
 'f88969245c16776c1d7d',
 'f88a6334ccee09114d21',
 'f88b1adec8487d123bec',
 'f88d10375b8faaa0aa5a',
 'f88dfa7634580f39cca6',
 'f88fec26f174891b4fc1',
 'f89dc1cb6052a0d1a330',
 'f8a4e6dc402af9a6e9b4',
 'f8a5750f2dc64d8daa83',
 'f8aa857cf74e6a87d526',
 'f8b4deb577fe8c3c0251',
 'f8b8cf9fbb9034dbc25a',
 'f8b988cfbb134a4604d4',
 'f8bbbd2af8a898f8324e',
 'f8bf458fca386865c56c',
 'f8c0c2645f1ef040f428',
 'f8c42c1ae343b675361e',
 'f8c84f55349db856e15e',
 'f8c88927f7a20ce43ea2',
 'f8cb5810ed147ccb511b',
 'f8cd4b33872f198d0f8c',
 'f8cdee7ef71784f23192',
 'f8ce91406bb32ab9427c',
 'f8d348dc6dbb76e772d1',
 'f8d48675a424db543e30',
 'f8dcecfcce723c37d8d2',
 'f8e1bc1f9ba38face7f2',
 'f8e6208f84d686f92af1',
 'f8e657975384644a42b2',
 'f8e7a4275a40c1a60ff7',
 'f8ee3706695206027439',
 'f8f24b3f6581a2d8339b',
 'f9023200e083ef1a2ea4',
 'f90608b425ea70f191cd',
 'f90aa05b8b8e89194aed',
 'f90b7cde0949c4e3a722',
 'f90c5a27b7479ea70315',
 'f9163bf08bef7eca7638',
 'f91aaca92d46f825b543',
 'f92450ccf8271328cd45',
 'f927ac5231ce15b7d3a5',
 'f92c34226c30df393566',
 'f92f15856ef7786a05fd',
 'f935ac2fd81958b99b76',
 'f936b5ec541f54d1fe59',
 'f9374555e2fb77907a16',
 'f93760064f5602e2fadd',
 'f93e323494ff70a07e42',
 'f94086a9a7a1f63e04f0',
 'f944b822c7f366fca188',
 'f946c64f9dc9701eb1f4',
 'f9510eb629ae71e70ac2',
 'f953dbb4b2ec62304b17',
 'f95816f64cabde0b81a4',
 'f95b5dfdf7049653b0a5',
 'f961b6923f8a1ce146b1',
 'f9687881d7cf3c9c5978',
 'f96af1f964f4502e89b6',
 'f96b2f5cbc67c7a26b7d',
 'f96e1a1f9920744625ea',
 'f96f0687bcb9acd20483',
 'f971a7a257f1a175252c',
 'f97253f84a232c808e0e',
 'f9745c87c85961aadbc5',
 'f9775ac040625ccaf8ba',
 'f9778b98224f6e7728a2',
 'f979ffb9a3c2a0e6641f',
 'f97dd91378dbfb75a318',
 'f982fd741af41a4a9e8c',
 'f9882fbc688be8310c80',
 'f98b1f5d906a69cc8742',
 'f98dad0ba4b9c2633b90',
 'f992c621ea98bd8d7a21',
 'f9932955078472f00b72',
 'f9a04cad6a10cd7c1909',
 'f9a061fc31b070b90059',
 'f9a0d87b78dd803bbb25',
 'f9a199d372ecd65300ec',
 'f9a1a4ee5f80ea8266e9',
 'f9a2070083f77e6866ff',
 'f9aae4764aa890cfecfd',
 'f9b0b6f3febc3c0611af',
 'f9b5c11e4647f26b7d38',
 'f9b6bc71867fb11a3d5b',
 'f9baa171f9cc6a5f8e4f',
 'f9bce36d07978fa8014d',
 'f9c15a7b39ab4809d047',
 'f9c63755c75e4175fb56',
 'f9c6d105cf8899ea9b95',
 'f9c7e280ba2cebddf6b1',
 'f9ca611215decb3451b9',
 'f9d0b27cf798d7ded1b0',
 'f9d51fb56569516ca122',
 'f9d8afcf733061252331',
 'f9dd40625124a98c3efe',
 'f9e02a3995e77d91df85',
 'f9e4814a4c46f2465289',
 'f9e5928aec0f8410dced',
 'f9e59c65f7abcc8a227b',
 'f9e82a6afb994e7c0028',
 'f9ec54d5212884ea7a27',
 'f9f09c0ae8f63c8f4c3b',
 'f9fb34fa90f9a85eadf4',
 'f9fb4d9fb69562cdca89',
 'f9fb58aad8ac7975fb15',
 'f9fba4bec91925b46cac',
 'f9ff110dffd8ca0beaf5',
 'fa00e074e9a15ff1dff0',
 'fa013b6aaf1ef5be0ecc',
 'fa016b82cd7e6a2546d5',
 'fa04c7d4b28e88e295f4',
 'fa07dc44089350589898',
 'fa09d917a7745ecafc97',
 'fa0a89f44626beccfe60',
 'fa0fa6f19c37c1147831',
 'fa113992f1025f0d0d23',
 'fa13a900ba60ff42dc24',
 'fa13aa28331cc915a6ec',
 'fa17f337df364f7144e3',
 'fa1cd6ea2ba8cac5f8a3',
 'fa2515576e2b6b7eeae6',
 'fa253bc48d54def3481d',
 'fa2d1de36cf7e0aaf16a',
 'fa2ed37ec87699b7ed6c',
 'fa2ff8f5a8d3ca7983b1',
 'fa30aa4b309606aed075',
 'fa3b8514a680d8ea71ed',
 'fa3cfbcc0d69980d4997',
 'fa3deba5119f3c766a49',
 'fa3e1ae2b5ce5b7cd101',
 'fa410a5b6277af62e510',
 'fa426a4c7b60b0585e02',
 'fa43b27cbabc30916c36',
 'fa44211d5a18adab8e8e',
 'fa48d93f77ed3abe22ac',
 'fa4d54bff309460ddbdb',
 'fa4f65d4e7532afc0fbf',
 'fa4f745e43b1e1b52a27',
 'fa51d4db350bec07a23d',
 'fa52ff4ea4780605a6cd',
 'fa5583437400b10db235',
 'fa569e8a909e379b8ed0',
 'fa58224cb377e9a192ba',
 'fa588a788ab8d0752401',
 'fa595693f94960aa621e',
 'fa6169f698acaff8bf7a',
 'fa62e92c6701471583ea',
 'fa630d2a6e18d596d6d9',
 'fa631568543465651b3d',
 'fa638ca26fe71e72ad40',
 'fa6490f4db5663c04fb4',
 'fa66d657044c1f48e40d',
 'fa69ac7c542d34fb4e93',
 'fa69d03a1109df9d1103',
 'fa6c10a79aae1e3627f1',
 'fa6e1e929a0fcfe3b465',
 'fa6e2c6a86467ad56813',
 'fa7197f9d8880af9f9fb',
 'fa7ba2ac2ad11aa4d0a4',
 'fa7ceb62ee1e9bb96dfd',
 'fa849a205c633006a1dc',
 'fa87886f5b3f7e231f16',
 'fa8f4653f508a479e398',
 'fa8fcccb8614ed584683',
 'fa91f68412187ed371ca',
 'fa93e6e68020831c3084',
 'fa95b54a582909fffdd8',
 'fa97e5914e13e0eacee1',
 'fa97fae06fd4ab07bfc7',
 'faa279a89482bcdf9f55',
 'faa37c33a8eb29f55160',
 'faa9d6ab5113b1db696c',
 'faab2e151b37d565bd1f',
 'faac84473456d7517780',
 'fabcca76f17306e459db',
 'fac8f08f9fb927acd9a6',
 'fac924f2171f3c30d60b',
 'faca065475d31189c7e4',
 'faca2ff4547c3a7bf5f1',
 'facaee1d30b4be277c5b',
 'facc75e76ab2437b9afa',
 'facca25f3cf860539ebe',
 'facd6042efb4769921c3',
 'facf8443c7c74e30628f',
 'fad61e197b828167d2c9',
 'fad6b06f6e639e4ab374',
 'fad71257c5c9b7169d24',
 'fada2567b21108c62528',
 'fae125a32b15f4e64a92',
 'fae5f4518ca6a4e1ab60',
 'fae68c5bc0932683f1bf',
 'faebdf3f69cf9b81161b',
 'faebebf469697fd8ea33',
 'faece6f6f761ff467488',
 'faed3b94af548d534fd9',
 'faefc81f820b83ed135f',
 'faf26c0e55c9b7f73eb5',
 'faf65919cf2ed83c88c5',
 'faf7772d5f11611e3184',
 'faf900cb31b834ee5334',
 'fafb1cfdaa4b557502eb',
 'fafd35e6c176bd2988ce',
 'fafe7ebb11d416ccde6a',
 'fb00c426b0d22ea8bae2',
 'fb07690555e0eb6e7ed6',
 'fb0b000211fcfb09dc19',
 'fb0b00406bf3e4dc9fa9',
 'fb1f280221760d5f52d9',
 'fb205c10dca2d8212994',
 'fb28d3c80c5bf23e7625',
 'fb294a9e682bc1f56b21',
 'fb29808c27cac7d5c418',
 'fb2cbafcc709796e0093',
 'fb33d6ade47f51ce0069',
 'fb38804041c7fa8777e2',
 'fb39884968fc2bc8f348',
 'fb3acdbd05d4381088cf',
 'fb3acec8b5bbfe2d7b3f',
 'fb3b4996159773ac6bc5',
 'fb3c0573285060998a86',
 'fb3e20e80ec8fe275632',
 'fb430e9c25a9247b6130',
 'fb46d5164343dc852615',
 'fb4708256f8c8295fa82',
 'fb47d9ca3c2924cca231',
 'fb487443a05ca2515600',
 'fb4ac0491705647ae537',
 'fb5057a01dabd1f74645',
 'fb508650f7623e747082',
 'fb52408300bc3fd5b8f0',
 'fb52be1b8cb2235f3f99',
 'fb58216e9fbd79d1c5f7',
 'fb59024d1ccd84608499',
 'fb59114e5af53bb5a4bd',
 'fb5aa86bf0a7d79c5cc1',
 'fb5bae1ec1ecf3f17545',
 'fb6013d1ce24d9dde009',
 'fb6292be15c9272e6e63',
 'fb655f0ec2f6587ed313',
 'fb65b3cff576e4352a7e',
 'fb6c06ca51c4d2189d8e',
 'fb6de4801b90ce64a37b',
 'fb721e6cd5c0ea6819d0',
 'fb7427d9a307ca42f270',
 'fb744eb14c03800884c3',
 'fb7985128bc5fbc5f2ed',
 'fb7b7f722f642b430582',
 'fb7d2012f9a63a6729a7',
 'fb7dd3e65c87dd587d66',
 'fb82b5b72d441c7c2c67',
 'fb89b67877a21ba82daa',
 'fb89ef192ba64242566b',
 'fb8d988128400dfa395f',
 'fb9056d30754adb18d71',
 'fb90bf0df82d245d3e74',
 'fb9791aaf7b9a5e76d58',
 'fb97a1f113b2f052933a',
 'fb98e560ef702b08ed0b',
 'fb9b14b16124ae0e72a9',
 'fb9dd8b7a81f2266efeb',
 'fba5167cb6e2653d7dfa',
 'fba6c7edbc13324c3a95',
 'fba9f1767378b302fc14',
 'fbab4d3a0c343eceb3ed',
 'fbabc74babced386fdab',
 'fbad45a95fa2e0e62e8f',
 'fbaea729ec5bc6178097',
 'fbb001bdc68d60afdd5f',
 'fbb153ce147f819296f8',
 'fbb55b862b6182a2a98f',
 'fbb86ee85eeab9a22add',
 'fbbb1b38918b8ca3f308',
 'fbbb3f42b6447d8a1983',
 'fbbc6f60e4405c22877d',
 'fbc05b83bc5eed8be833',
 'fbc69c21d36517fc0b88',
 'fbd1f2199a7efe24ea73',
 'fbdb4569f6bf41acdf1f',
 'fbdb8bab936fc9d26dc1',
 'fbdbc7caac4ba04eda17',
 'fbdc39d8adecc8fc4a35',
 'fbe2d4ebb5657e883bac',
 'fbe3a833495671929064',
 'fbe43056ba1ff6455f75',
 'fbe5ed1a0399c2d12313',
 'fbe6f0a3a79114fd9c1a',
 'fbe8d708f63f5720ad61',
 'fbe90047277fab93eb47',
 'fbe9c78f5b904e115382',
 'fbed17854ecf3a82de39',
 'fbed43f9dca298b24bee',
 'fbf0e105c89ece824c7d',
 'fbf29ff826a179bd28c9',
 'fbf40917ff9ad19e4f67',
 'fbf4d2cd1ae944523052',
 'fbf7d2c096ff339cbfee',
 'fbf9f67bba14ddf5a7ce',
 'fc04ece277157a485c5b',
 'fc09d576c0a0e36c0721',
 'fc09dd2371ebec75cd57',
 'fc0aeba6afc62412f99b',
 'fc0c100a17acdb2278a4',
 'fc0ef28b1dc85b224591',
 'fc0ef5b8dda569ff5f3d',
 'fc0f3136dd218889dfd4',
 'fc17002430697c63f9e5',
 'fc188a27b5c59936baf8',
 'fc1eb72436bc301726d3',
 'fc1f96644bdce8269f96',
 'fc2516911e6810d4f683',
 'fc26bd25112dc5542edd',
 'fc2e6aab8f940ff37ea3',
 'fc308987267ecc1542dc',
 'fc30eb995d0b1214941a',
 'fc3933a8c3383a114f87',
 'fc39bac215a2df9d185f',
 'fc3b0937385df3532f18',
 'fc3c21d282ba0ebe5b4a',
 'fc3d7ce05ac7d72aa25c',
 'fc3d872d11fe348afd25',
 'fc3f0f6ab8d79a586a28',
 'fc3f4d39fe053def1294',
 'fc3f9c46a7a83188ee04',
 'fc4273753f7d9738476a',
 'fc43d62336cc8b1a9dd5',
 'fc43dfd5e7e50fc098e8',
 'fc479ac830bb65d9e992',
 'fc4926c15262fb9ab4cc',
 'fc494b8cfe2f2a66b9c5',
 'fc4c387ed1185f665a13',
 'fc4d51b0669193c7973b',
 'fc4f8e15440339c3a9f9',
 'fc5a7efa62dfc76fa730',
 'fc5dc0fa368e831550d6',
 'fc5df0ec532f3876e129',
 'fc5e741649b8e6920adb',
 'fc6300402cba3c5f1bf4',
 'fc633f0d03b92f524efc',
 'fc67a9c8d57e96be0602',
 'fc68960a2e11e6f3c9dc',
 'fc6bfcb886cb3a8a1324',
 'fc6e73205225caa5fe71',
 'fc771747069c46c3e062',
 'fc791b06c6e6ecba4b40',
 'fc7eca584b8138bf639e',
 'fc7f5a0c6434ac9dad7f',
 'fc8214059331af86d318',
 'fc823443f40cce9ba5be',
 'fc879491cafa26317a01',
 'fc87db2b94977277243a',
 'fc8f1ca6c48766e74f86',
 'fc910a649e5baa342c42',
 'fc91dbce5ebb0b79c5d6',
 'fc95fc19a930a50d3957',
 'fc9974162d0e1fe4ee3c',
 'fc9dfcd6bbfb8907b443',
 'fca46fe05b302f762ff6',
 'fca4c1a8761f749b4940',
 'fca6522cbec5df86bb33',
 'fca6ea76cd5ce73af64f',
 'fcacd6d68ed81556bf56',
 'fcae214089666a05f610',
 'fcb25cb7a9378acfeab9',
 'fcb2b37624c2591bf479',
 'fcb3c12375b0bee8be99',
 'fcb444338b214488dec3',
 'fcb763b98102c1744099',
 'fcb7e459fb1fcff3c206',
 'fcb884f12faac3f124cf',
 'fcbef1281336bfb92a0a',
 'fcca234245ce02eabf41',
 'fccc32fab3e03c73ea81',
 'fccd6d0821c212295420',
 'fcd0274544a634c8f7a0',
 'fcd0472f14d125f8059b',
 'fcd0dc64a932b90cd347',
 'fcd3d2c0a2821b615c76',
 'fcdeece79d4dadaea682',
 'fce181c40c11f8fb6c56',
 'fce5aead5a398e811f19',
 'fcedc85e43c7d88cc20d',
 'fcf4325577f85d31421e',
 'fcf65f196653d0d37a48',
 'fcf70ff437eef3fedd5e',
 'fcfab3694b9cfcc656bb',
 'fcfc108a08913ed5fa0b',
 'fcfdf128f8525598297c',
 'fcfdf448467278696df5',
 'fd000e3ab2b305e871ca',
 'fd023548625044366a5c',
 'fd03b771f434ab62f39c',
 'fd049d5dbc4bd51c95ff',
 'fd06c236be86d691be5e',
 'fd094d06874648171b23',
 'fd0f00f1ff973cb4e168',
 'fd10f464605a3b63c91b',
 'fd11ff89ee7a13f3ca51',
 'fd126e12638e0e86fd23',
 'fd2152b0c3bc4c686ba2',
 'fd24843210dd2ff5e9f5',
 'fd3256c724692f0a31d6',
 'fd33754ad5ae6484026d',
 'fd34356caa84301cd535',
 'fd35e7c49b70ee0dc22b',
 'fd36247a53c466e5cf15',
 'fd3811ad0efbbc6da82b',
 'fd3c3d3833530c190d45',
 'fd3eea322876e35955dc',
 'fd404bb0723882bf5b4f',
 'fd40cac80857100cf782',
 'fd4280b4f6e1f4001d12',
 'fd42b1286ee7ac1b2ed7',
 'fd445606390840a9e4ac',
 'fd48150bbfe3fc721a97',
 'fd4c731a2651130a9636',
 'fd518a20be7203dee39a',
 'fd556db3db93680c4681',
 'fd5b9d5b035eedebd662',
 'fd604e84ba2b9e17d0a7',
 'fd6087388aad4549fcd6',
 'fd6099ffb09d84dd643d',
 'fd61fb4a322e11965ab4',
 'fd63dbad95969c0e7641',
 'fd6431d69db1e3b285a9',
 'fd661fbb426fc86c5cec',
 'fd6ba1515b598c74ce07',
 'fd6e6ed6ebe637e6fefa',
 'fd71108d83bfa8ac2b6b',
 'fd71e787bb7e3c830e49',
 'fd723d56f70700d4abea',
 'fd72e585e4aad7f008e7',
 'fd7418be592ad8ea3d6e',
 'fd76f25a763ba37bb4e0',
 'fd77bf6af03779d07c75',
 'fd7c3a41948763cad00d',
 'fd818c4f97b23505854d',
 'fd83a4f9209a12c5212c',
 'fd85814bd3743b5eb689',
 'fd874909d9f49b5224b6',
 'fd8d9a1d907341c8e88d',
 'fd8e88aa37c23e0a6f89',
 'fd94bc07b8bf58385911',
 'fd9a50f3504159da56e2',
 'fd9a7c2393f30d6bcafe',
 'fd9c209615304d58710b',
 'fd9d074a9869b9c422b2',
 'fd9e1c97989ab88a26eb',
 'fda0a9e68b5b7f0b79bc',
 'fda4ec264c3a59266b14',
 'fda6b345825be84f1f49',
 'fdabe488107217ba8fe9',
 'fdac58f84e1ff64a0b30',
 'fdae3e8dc04201a75d01',
 'fdb7ebedc05692abe0a9',
 'fdb8b02f2b38d844c554',
 'fdbb917a71156cad1054',
 'fdc43dae47b620e04bc6',
 'fdc5c76dfee63014e26b',
 'fdc636ce2cbc8f5372f0',
 'fdca3239506d7f1a29b8',
 'fdcd9a914b4d2c22f280',
 'fdd0c6987d45e1687acc',
 'fdd3ea028301834ba627',
 'fdd7594eaecd3707ffdf',
 'fdd779e3f0cf4b856a66',
 'fddc619d5ba5c33fe2e7',
 'fdde6bfc6311e8997c07',
 'fde00b6aca159b455636',
 'fde2ca48f28e33a6ce1a',
 'fde3ae2c1bcd32e2fff9',
 'fde421e9a15237598885',
 'fde72ed65436332f4564',
 'fdf293cef2f9215f6e17',
 'fdfaa2412498ad36583a',
 'fdffc2b6e6b6eae97b50',
 'fe028441b63611b191e8',
 'fe028cd492c240cbadbd',
 'fe02cc0e78d16027e14e',
 'fe0650eb2b94748c36c8',
 'fe0795d78145f8ed356c',
 'fe09a56c55e82ed2edc5',
 'fe0c048168a47ee05e55',
 'fe0d7273ce0f6c974a52',
 'fe14213841384a6d42be',
 'fe1489170218b4c6b53c',
 'fe179c02116436db7c3a',
 'fe17b179e42e6d962f44',
 'fe190f137e4e8619081f',
 'fe1b0af9f08dbb502d61',
 'fe1c34d2b816de95a08f',
 'fe1c78edadf71a6c6f4e',
 'fe1cc4cdf7602d416cdc',
 'fe1ec0bf4791c3d591dd',
 'fe2ada9d99f99f19ab8d',
 'fe2fe742fa48b2816104',
 'fe30c7b5b5a6c00f992f',
 'fe33e08513a20ed2c1ca',
 'fe36a7c2b5289e1f7ce1',
 'fe384d9e50f62da7efcf',
 'fe395eda5c469f759717',
 'fe3a494740a3bdb505f0',
 'fe3d1fabe2c5317d1c1f',
 'fe438cf56a742ca1ad9f',
 'fe4469126d6725c5b7c6',
 'fe47ad8a23bccbf8b9a3',
 'fe47bc344662b23367c8',
 'fe4958c3776fc84e3a87',
 'fe4abfcfb7b655ca9a6e',
 'fe4b44d9f542788cf484',
 'fe4be0569fa1029cd4bb',
 'fe4f6fa3480da8b6d53a',
 'fe5792e1ab0db77b55e5',
 'fe579a67e1f6473e902b',
 'fe5ee6edbee22daf996b',
 'fe61f0caf5950470c248',
 'fe6497557e41db1c5fc6',
 'fe650d4699989dbaf2ea',
 'fe694b354223784adca7',
 'fe69eba8305405d992e7',
 'fe6f72e77363d44481a8',
 'fe7383c87e8128abcb61',
 'fe767b32726593e01935',
 'fe7900677e1b851b12af',
 'fe7ae0ffb3d91e3f5424',
 'fe7b911704d6dee605e4',
 'fe7faf2ab0a4541097aa',
 'fe81224bf245970cb52f',
 'fe847b5bf1a9747f8f34',
 'fe8972b607a314aff6eb',
 'fe8a17980077cfd93619',
 'fe8a848877fa16f2fd70',
 'fe8aca4f86cd5e183906',
 'fe8b8ad39eedd9f2c0fd',
 'fe8bc63163e3e09a1ca4',
 'fe8be13b225240a9e7d0',
 'fe9455c46f6019857ec2',
 'fe95258b9de444f570a0',
 'fe9ac791bb6685349d47',
 'fe9fe05b471238edf2c1',
 'fea02478045f9dff2e69',
 'fea1ef0483ea97512dc6',
 'fea480972b64cf8c2181',
 'fea8f5f66166ffb9c3ea',
 'feacefa5eb8541a71337',
 'fead4d93ea64c1ed79f4',
 'fead80ace204627166bf',
 'feb43cf6a6834ebfa664',
 'feb940c21a6018355187',
 'feb95ec10f5aeeebe072',
 'febea5b53cd4b38bc894',
 'febec16d828f8ec3424a',
 'fec3e409a5dc406dee16',
 'fec416c4b8fd0ea1e091',
 'fec45db1d008957fd8bd',
 'fec7e82ead99b5f57511',
 'fec85cd011b3c623ce96',
 'fec92774eba58493e230',
 'fecd98f8faa0e6ef87d2',
 'fed81fec4123abda68bd',
 'fed83ffb87ed9d9e5816',
 'fedbb82019b656b29f59',
 'fede4ddbfb8577f70996',
 'fedebbe00a27ea505f63',
 'fee04112faec410c3948',
 'fee1731ba209e22b0a32',
 'fee1ad23a8c0b37c3e97',
 'fee3015d88724aca56b4',
 'fee4a77c31adada8a103',
 'fee4be1662e95738b4f7',
 'fee675615e9412effbd8',
 'fee9ecd2741c5817daa8',
 'feea57c478bf6b80de8d',
 'feed633ec64428d1e431',
 'fef07792fc7e086f28cb',
 'fef4d389bd4da57ae372',
 'fef549545c0212f93f5b',
 'fef6762d999530da4117',
 'fef8ca98ac1b3aef0dd3',
 'fefa6876dbb20bd2ca1c',
 'fefc7fbef0a079a019d0',
 'fefec48598fb898619fb',
 'ff00e0cf0f566fd67533',
 'ff04bc9d0263f7e2819a',
 'ff0620bd128970e4ac68',
 'ff0a131f6ef12c41c2aa',
 'ff0d56285f4d8c8eae20',
 'ff149af2fba5bdb0a51a',
 'ff17eb834d8cf58d71d3',
 'ff18885f20a7f433bbcf',
 'ff1b2a2d1edcf95e0fd9',
 'ff1e4459667cce0409f2',
 'ff20bcbe9f7b2b81a4a7',
 'ff217f613764f4330788',
 'ff25e6ba93d9fcc6d8ff',
 'ff2782b38978ab5c2612',
 'ff28e31e2615b52ec303',
 'ff2b480fb4030a4beeeb',
 'ff30002ec398edb01ca2',
 'ff32622335742565215b',
 'ff347490741f9d8920f9',
 'ff376c7a4d1383be57fa',
 'ff37c95144355220e557',
 'ff37e65d8a1549aa99b4',
 'ff39359767a7d48a58e0',
 'ff3b022658d812a60082',
 'ff41ad42c51e3f74fc87',
 'ff42f2a8c0ff47b6abea',
 'ff4b82e18b81ccb22993',
 'ff4f88fa141dc9b02927',
 'ff50349e51e992e47474',
 'ff5088bde1ec97a847e0',
 'ff51213410f3b97bae5e',
 'ff5323c2a82ecfeb81f4',
 'ff540cc97fcf9fea8290',
 'ff54f766c0aa3273e251',
 'ff56ce37d3e8a08174c6',
 'ff56f96e2c593f1b2ba3',
 'ff5bc161c2a188cec2c0',
 'ff602e5aa47f82e52fe0',
 'ff65dfaf9a0b631a2446',
 'ff6779d3a49f4cecc77d',
 'ff688d9bd2c4a706f8dd',
 'ff68954e62673d37d9d4',
 'ff6bb57c0abe68430d0b',
 'ff6bffe761e969554a83',
 'ff6d7c0092c1b6ba95e5',
 'ff71b34d6e59218b366b',
 'ff71e32310d013797275',
 'ff72793e61bb00f1ea1c',
 'ff73bff7e8fb01e3054f',
 'ff7c3a476673fa31ee5a',
 'ff7d138cb15d7065aedb',
 'ff814a1625033f5f2c85',
 'ff8188f961e3a5e3c19d',
 'ff87fe539df341266edf',
 'ff8f5502a683ab0586aa',
 'ff92c4499b03aa4076f9',
 'ff982bc4574926c950ab',
 'ff99d160453102a520f8',
 'ff9c6e82e40a4cbec1bd',
 'ffa2abc0fe824a1f22a3',
 'ffa2cc691b7621a5c0b5',
 'ffa596087c2ca72a3bc6',
 'ffb0c79f43ad09631e32',
 'ffb421a8c03240655794',
 'ffb4abfe4cda21abe409',
 'ffb63dcfcbac01a14f5f',
 'ffb70911a582fec46ce0',
 'ffb86d9bc1bd8b8c107f',
 'ffb8ded0b4901e79d148',
 'ffbc6ae4af2378df8aec',
 'ffbd2615e0a3636471c6',
 'ffc142fbce55e34b6986',
 'ffc442934d665b86ae05',
 'ffc864d300f626ec4a0e',
 'ffc8fc14d2f4c8d4de48',
 'ffcc15198ce46b1c67c9',
 'ffce3c857b736168a7b3',
 'ffcfed2ac96952bce656',
 'ffd011cb571d26dcfefc',
 'ffd60158ae1a32735bda',
 'ffdabb55e67bfc31e3ce',
 'ffdb38a8ff4e67e17bce',
 'ffdbe84185b1657d77c4',
 'ffde42fd65617b50f8f4',
 'ffe208a8f6a053ad990e',
 'ffe33b8c12038a564329',
 'ffe3e5dac8b60c486704',
 'ffe6d27092c43a2c1579',
 'ffe7a676812dfe4926c3',
 'ffeeee232322cd64009d',
 'fff9e27c3ed8e1bf4269',
 'fffa51d9e8887f51b751',
 'fffbf53cbe8d6b60ae51',
 'fffc0a5688ba2da6be91',
 'fffe22b68a6853b5b790',
 'fffed08be2626f74b139']

# %% [markdown]
# 25

# %%
qids_all = qids_1+qids_2+qids_3+qids_4+qids_5+qids_6+qids_7+qids_8+qids_9+qids_10+qids_11+qids_12+qids_13+qids_14+qids_15+qids_16+qids_17+qids_18+qids_19+qids_20+qids_21+qids_22+qids_23+qids_24

# %%
import csv

qid = []
with open('/kaggle/input/quora-insincere-questions-classification/test.csv', 'r') as read_obj,open('result.csv', 'w', newline='') as write_obj:
    reader = csv.reader(read_obj)
    writer = csv.writer(write_obj, lineterminator='\n')

    all_lines = []
    row = []
    row.append('qid')
    row.append('prediction')
    all_lines.append(row)

    line = next(reader)

    for rr in reader:
        new_row = []
        new_row.append(rr[0])
        if rr[0] in qids_all:
            new_row.append(1)
        else:
            new_row.append(0)
        all_lines.append(new_row)
    
    writer.writerows(all_lines)

# %%
sub = pd.read_csv('/kaggle/working/result.csv')




sub.to_csv('submission.csv',index=False)
