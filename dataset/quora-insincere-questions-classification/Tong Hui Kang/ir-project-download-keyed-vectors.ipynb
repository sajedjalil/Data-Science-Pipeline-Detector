# %%
# !python3 -m spacy download en_core_web_sm

import spacy
nlp = spacy.load("en_core_web_sm")
nlp.to_disk("en_core_web_lg.spacy")

# %%
# !python3 -m spacy download en_core_web_lg

import spacy
nlp2 = spacy.load("en_core_web_lg")
nlp2.to_disk("en_core_web_lg.spacy")

# %%
import gensim
import gensim.downloader

models_to_try = ['glove-wiki-gigaword-50', 'glove-wiki-gigaword-300', 'glove-twitter-50','word2vec-google-news-300','fasttext-wiki-news-subwords-300']

for m in models_to_try:
    model = gensim.downloader.load(m)
    model.save(f"/kaggle/working/{m}.keyedvectors")
