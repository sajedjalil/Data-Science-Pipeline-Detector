# %%
import numpy as np
import pandas as pd

# %%
b = pd.read_csv('../input/g2net-to-blend/to_blend/blend3.csv')

# %%
b.head()

# %%
output = pd.DataFrame({'id':b.id, 'target':b.target})

# %%
output.head(10)

# %%
output.to_csv('submission.csv', index=False);
