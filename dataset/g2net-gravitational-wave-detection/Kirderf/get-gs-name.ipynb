# %%
 from kaggle_datasets import KaggleDatasets

# %%
KaggleDatasets().get_gcs_path('g2net-gravitational-wave-detection')

# %%
#use this command to download the train or test data when using Colab or other cloud services
# GCS_DS_PATH = 'gs://kds-3e72e6682f329290f88dc99bf3e23068847f299afced96dfcd6902a3'
# !gsutil -q -m cp -r {GCS_DS_PATH}/"train" .
