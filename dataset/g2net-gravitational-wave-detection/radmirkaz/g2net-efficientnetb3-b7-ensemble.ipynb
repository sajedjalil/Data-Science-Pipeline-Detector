# %% [markdown]
# ### its my own models output, I fitted them by myself. just want to share the result. I use ensemble of EffnetB3-B7(0.8772 lb) and then ensemble it with my old one ensemble

# %% [markdown]
# * B7 solo score - 0.8768
# * B6 solo score - 0.8761
# * B5 solo score - 0.8762
# * B4 solo score - 0.8758
# * B3 solo score - 0.8752

# %% [markdown]
# Ensemble with old submission gives 0.8779

# %%
import numpy as np
import pandas as pd
np.random.seed(2021)

# %%
sub = pd.read_csv('../input/upvote/submission (27).csv').sort_values('id')

# %%
sub.to_csv('submission.csv', index=False)
