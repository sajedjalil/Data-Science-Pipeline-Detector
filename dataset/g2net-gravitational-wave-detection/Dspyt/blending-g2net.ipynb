# %%
import numpy as np
import pandas as pd
np.random.seed(2021)

# %% [markdown]
# ## My blog[ Data Science with Python](https://dspyt.com) is at [Dspyt.com](https://dspyt.com)
#
# ## The submission files are from https://www.kaggle.com/leolu1998/my-blend-for-g2net

# %%
df = pd.read_csv('../input/g2net/submission (1).csv')#.sort_values('id') 
df1 = pd.read_csv('../input/g2net/submission (2).csv')#.sort_values('id')

# %%
df.target = df.target.apply(lambda x: x+ np.random.normal(0, 0.00001))

# %%
df.to_csv('submission.csv', index=False)
