# %%
import pandas as pd
import numpy as np

# %%
train_labels = pd.read_csv(r"../input/g2net-gravitational-wave-detection/training_labels.csv")
train_labels.head()

# %%
train_labels.shape

# %%
train_labels['target'].value_counts()

# %%
e74ad = np.load('../input/g2net-gravitational-wave-detection/train/0/0/0/00000e74ad.npy')
e74ad

# %%
e74ad.shape

# %%
f4945 = np.load('../input/g2net-gravitational-wave-detection/train/0/0/0/00001f4945.npy')
f4945.shape

# %%
import itertools
e74ad_merged = list(itertools.chain(*e74ad))
len(e74ad_merged)
