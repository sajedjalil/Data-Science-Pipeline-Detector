# %%
ls ../input/kore2022topsubmissions/Kore\ 2022/Submission\ 26172298\ by\ aDg4b/

# %%
ls ../input/kore2022topsubmissions/Kore\ 2022/Submission\ 26183169\ by\ Shuntaro\ Tanaka/

# %%
cat ../input/kore2022topsubmissions/Kore\ 2022/Submission\ 26183169\ by\ Shuntaro\ Tanaka/36261770.json
