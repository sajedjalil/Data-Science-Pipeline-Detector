# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #DAA520;"><b style="color:white;">It's a Bovard Clone</b></h1></center>
#
# It's exactly what the title is telling us. I was inspired by Bovard's fantastic code and Alex title ("Clone my Notebook") Alexander Ryzhkov.
#
# And of course, I was attracted by the little Stars below too!

# %% [markdown]
# ![](https://i.ytimg.com/vi/SI-S_NldWTk/maxresdefault.jpg?v=624dc519)youtube.com

# %%
# %%capture
# install the latest version of kaggle_environments
# !pip install --upgrade kaggle_environments

# %%
from kaggle_environments import make
env = make("kore_fleets", debug=True)
print(env.name, env.version)

# %%
# %%writefile agent.py 
   
from kaggle_environments.envs.kore_fleets.helpers import *
from random import randint

def agent(obs, config):
    board = Board(obs, config)
    me=board.current_player

    me = board.current_player
    turn = board.step
    spawn_cost = board.configuration.spawn_cost
    kore_left = me.kore

    for shipyard in me.shipyards:
        if shipyard.ship_count > 10:
            direction = Direction.from_index(turn % 4)
            action = ShipyardAction.launch_fleet_with_flight_plan(2, direction.to_char())
            shipyard.next_action = action
        elif kore_left > spawn_cost * shipyard.max_spawn:
            action = ShipyardAction.spawn_ships(shipyard.max_spawn)
            shipyard.next_action = action
            kore_left -= spawn_cost * shipyard.max_spawn
        elif kore_left > spawn_cost:
            action = ShipyardAction.spawn_ships(1)
            shipyard.next_action = action
            kore_left -= spawn_cost

    return me.next_actions

# %%
env.run(["/kaggle/working/agent.py", "/kaggle/working/agent.py"])
env.render(mode="ipython", width=1000, height=800)

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #DAA520;"><b style="color:white;">Combat! Attack! Expand the Empire!</b></h1></center>
#
# Thank you Bovard for such a brilliant, literally and metaphorical, work.
#
# https://www.kaggle.com/code/bovard/kore-intro-iv-combat
#
# https://www.kaggle.com/code/bovard/kore-attacker-agent
#
# https://www.kaggle.com/code/bovard/kore-intro-iii-expanding-the-empire
#
# https://www.kaggle.com/code/bovard/kore-intro-i-the-basics
#
# https://www.kaggle.com/code/bovard/kore-intro-ii-mining-kore
#
# https://www.kaggle.com/code/bovard/kore-miner-agent
#
# https://www.kaggle.com/code/bovard/kore-attacker-agent

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #DAA520;"><b style="color:white;">If you could expand the Empire, that'll be great!</b></h1></center>
