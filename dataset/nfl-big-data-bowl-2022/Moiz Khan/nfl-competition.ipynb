# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import Packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# %% [markdown]
# # Loading Data and Descriptive Statistics

# %%
player_df = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/players.csv")
scout_df = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/PFFScoutingData.csv")

# %%
player_df.shape

# %%
player_df.info()

# %%
player_df.describe()

# %% [markdown]
# > * As we compared the 75% and maximum there is not as much outlier exist in the player data.

# %%
player_df.head(3)

# %%
player_df.boxplot()

# %%
player_df[["weight"]].boxplot()

# %%
scout_df.head(3)

# %%
scout_df.info()

# %%
scout_df.describe()

# %%
scout_df[['snapTime']].boxplot()

# %%
scout_df[['operationTime']].boxplot()

# %%
scout_df[['hangTime']].boxplot()

# %%
game_df = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/games.csv")

# %%
game_df.shape

# %%
game_df.head()

# %%
game_df.info()

# %% [markdown]
# > * There is no null value

# %%
game_df.describe()

# %% [markdown]
# > * There is no outlier exist in the dataframe

# %%
play_df = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/plays.csv")

# %%
play_df.shape

# %%
play_df.head()

# %%
play_df.info()

# %%
play_df.describe()

# %% [markdown]
# ---
# ## Tracking Data

# %%
track19_df = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/tracking2019.csv")

# %%
track19_df.shape

# %%
track19_df.head()

# %%
track19_df.describe()

# %%
track19_df.info()

# %%
track18_df = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/tracking2018.csv")

# %%
track18_df.head()

# %%
track18_df.info()

# %%
track18_df.describe()

# %%
track18_df[["x"]].boxplot()

# %%
track18_df[["y"]].boxplot()

# %% [markdown]
# > * x and y columns have outliers but we cannot change it because this is position of player in the ground.

# %%
track20_df = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/tracking2020.csv")

# %%
track20_df.head(3)

# %%
track20_df.info()

# %%
track20_df.describe()

# %%
track20_df[["a"]].boxplot()

# %% [markdown]
# ---
#
# # Analytics of Data
