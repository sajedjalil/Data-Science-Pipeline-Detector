# %% [markdown]
# ### Hi guys! This notebook will slowly enter into competition and achieve high scores.
#
# #### Please support and stay updated.
#
# ### This notebook holds analysis and visualization for tracking data of different years. To view analysis and visualizations of Games, Players, Plays, PffScouting data check this notebook -> [NFL complete analysis and visualization!! 🏈](https://www.kaggle.com/zwartfreak/nfl-complete-analysis-and-visualization)
#
# ##### P.S. This notebook is not completed yet, building it daily.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#players = pd.read_csv('../input/nfl-big-data-bowl-2022/players.csv')
#games = pd.read_csv('../input/nfl-big-data-bowl-2022/games.csv')
#plays = pd.read_csv('../input/nfl-big-data-bowl-2022/plays.csv')
#pffscouting = pd.read_csv('../input/nfl-big-data-bowl-2022/PFFScoutingData.csv')
tracking2018 = pd.read_csv('../input/nfl-big-data-bowl-2022/tracking2018.csv')
tracking2019 = pd.read_csv('../input/nfl-big-data-bowl-2022/tracking2019.csv')
tracking2020 = pd.read_csv('../input/nfl-big-data-bowl-2022/tracking2020.csv')

# %% [markdown]
# > ## Data anslysis

# %%
tracking2018.shape, tracking2019.shape,tracking2020.shape

# %% [markdown]
# ##### These datasets are very huge.
# #### There are different datasets year-wise so we will analyse them one by one.

# %% [markdown]
# ### 1. 2018

# %%
tracking2018.head()

# %%
tracking2018.isnull().sum()

# %% [markdown]
# ##### So there are lots of null values.
# ##### 'o' represents Player orientation (deg), 0 - 360 degrees (numeric)
# ##### 'dir' represents Angle of player motion (deg), 0 - 360 degrees (numeric)
# ##### 'nflId' represents Player identification number, unique across players (numeric)
# ##### 'position' represents Player position group (text)
#
# ##### Let's drop some data and check the remaining NULL values

# %%
tracking2018.dropna(subset=['o'], inplace=True)
tracking2018.isnull().sum().sum()

# %% [markdown]
# ##### As expected, same rows had NULL values to simply dropping will work for us as it is a huge dataset with over 1 crore values.

# %%
tracking2018.dtypes

# %% [markdown]
# ### 2. 2019

# %%
tracking2019.head()

# %%
tracking2019.isnull().sum()

# %%
tracking2019.dropna(subset=['o'], inplace=True)
tracking2019.isnull().sum().sum()

# %%
tracking2019.dtypes

# %% [markdown]
# ### 3. 2020

# %%
tracking2020.head()

# %%
tracking2020.isnull().sum()

# %%
tracking2020.dropna(subset=['o'], inplace=True)
tracking2020.isnull().sum().sum()

# %%
tracking2020.dtypes

# %% [markdown]
# > ### NULL values uccessfully treated
