# %%
# !pip install watermark
# !pip install nicaviz

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #001f3f;"><b style="color:#DEB887;">Nicaviz by Nick Brooks, aka: Nicapotato</b></h1></center>

# %% [markdown]
# #Code by Nicapotato https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook
#
# https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration
#
# Ventilator Pressure Prediction Nicaviz EDA
# By Nick Brooks, September 2021
#
# Resources:
#
# https://github.com/nicapotato/nicaviz
#
#
# https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

# %% [markdown]
# ![](https://avatars.githubusercontent.com/u/14944829?v=4)https://github.com/nicapotato

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nicaviz
import seaborn as sns
import time
import matplotlib.pyplot as plt
import itertools
import glob
import re
import math

sns.set_style("whitegrid")

# %load_ext watermark
# %watermark 

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.simplefilter(action='ignore', category=FutureWarning)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

notebookstart = time.time()
# %watermark --iversions

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

#Tracking 2020

track20 = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2022/tracking2020.csv")


display(track20.head())
display(track20.nica.categorical_describe())

# %%
players = pd.read_csv('../input/nfl-big-data-bowl-2022/players.csv')
players.head()

# %%
games = pd.read_csv('../input/nfl-big-data-bowl-2022/games.csv')
games.head()

# %%
games.dtypes

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Time Series</span></h1><br>

# %%
players['birthDate'] = pd.to_datetime(players['birthDate'])

# %%
games['gameDate'] = pd.to_datetime(games['gameDate'])

# %% [markdown]
# #Interval 1day (Players file)

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

with nicaviz.timer("Timeserie Resample Plot"):
    players.nica.mass_plot(
        plt_set= ["birthDate"],
        plottype = "ts_resample",
        resample=True,
        resample_interval="1D"
    )

# %% [markdown]
# #Interval 1 Week. (Players file)

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

with nicaviz.timer("Timeserie Resample Plot"):
    players.nica.mass_plot(
        plt_set= ["birthDate"],
        plottype = "ts_resample",
        resample=True,
        resample_interval="1W"
    )

# %% [markdown]
# #Interval 1 year (Players file)

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

with nicaviz.timer("Timeserie Resample Plot"):
    players.nica.mass_plot(
        plt_set= ["birthDate"],
        plottype = "ts_resample",
        resample=True,
        resample_interval="1Y"
    )

# %% [markdown]
# #Interval 1day (Games file)

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

with nicaviz.timer("Timeserie Resample Plot"):
    games.nica.mass_plot(
        plt_set= ["gameDate"],
        plottype = "ts_resample",
        resample=True,
        resample_interval="1D"
    )

# %% [markdown]
# #Interval 1Week (Games file)

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

with nicaviz.timer("Timeserie Resample Plot"):
    games.nica.mass_plot(
        plt_set= ["gameDate"],
        plottype = "ts_resample",
        resample=True,
        resample_interval="1W"
    )

# %% [markdown]
# #Interval 1year (Games file)

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

with nicaviz.timer("Timeserie Resample Plot"):
    games.nica.mass_plot(
        plt_set= ["gameDate"],
        plottype = "ts_resample",
        resample=True,
        resample_interval="1Y"
    )

# %%
playersInt = ['nflId', 'weight']

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

#Sample was reduced to 500. In the Original code was 500000

with nicaviz.timer("Timeserie Rolling Plot"):
    players.sample(500).nica.mass_plot(
        plt_set= playersInt,
        plottype = "ts_rolling",
        x_var="birthDate",
        rolling=True,
        r=30
    )

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Categorical Variables</span></h1><br>

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

with nicaviz.timer("Boxplots"):
    players.nica.mass_plot(
        plt_set= playersInt,
        plottype = "boxplot")

# %% [markdown]
# Save the chart below for the next Dataset

# %%
#Saved for the next Dataset since it was crammed. Too many values.

#Code by Nicapotato https://www.kaggle.com/nicapotato/covid-digital-learning-data-exploration

#categoricals = [
 #   "collegeName",
  #  "displayName",
   # "Position",
    #"height",
    
#]

#with nicaviz.timer("Small Hue Boxplots"):
 #   for hue_col in categoricals:
  #      players.nica.mass_plot(
           # plt_set= playersInt,
           # hue = hue_col,
            #columns = 2,
            #plottype = "boxplot")

# %% [markdown]
# #WordCloud

# %%
#Code by Nick Brooks https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

with nicaviz.timer("Wordcloud Plot"):
    track20.nica.mass_plot(
        plt_set= ["team", "playDirection"],
        plottype = "wordcloud")

# %%
#Code by Nick Brooks https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

with nicaviz.timer("Count Plot"):
    track20.nica.mass_plot(
        plt_set= ["gameId", "playId"],
        plottype = "countplot")

# %%
#Code by Nick Brooks https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

with nicaviz.timer("Bar Plot"):
    track20.nica.mass_plot(
        plt_set= ["x", "y"],
        x_var = "team",
        plottype = "bar")

# %%
#Code by Nick Brooks https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

with nicaviz.timer("Boxplots"):
    track20.nica.mass_plot(
        plt_set= ["x", "y"],
        plottype = "boxplot")

    track20.nica.mass_plot(
        plt_set= ["x", "y"],
        hue = "team",
        plottype = "boxplot")

# %%
#Code by Nick Brooks https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

with nicaviz.timer("Distplots"):
    track20.nica.mass_plot(
        plt_set= ["x", "y"],
        plottype = "distplot")

    track20.nica.mass_plot(
        plt_set= ["x", "y"],
        hue = "team",
        plottype = "distplot")

# %%
#Code by Nick Brooks https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

with nicaviz.timer("Distplots"):
    track20.nica.mass_plot(
        plt_set= ["s", "a"],
        hue = "frameId",
        plottype = "distplot")

# %%
#Code by Nick Brooks https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb

with nicaviz.timer("Countplot"):
    track20.nica.mass_plot(
        plt_set= ["gameId", "playId"],
        hue = "playDirection",
        plottype = "countplot")

    track20.nica.mass_plot(
        plt_set= ["gameId", "playId"],
        plottype = "countplot")

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

categoricals = ["event", "displayName", "position", "team", "playDirection"]
#continuous = ['x', 'y', "s", "a", "dis", "o", "dir", "nflId", "jerseyNumber"] #I reduced since it took many time
continuous = ["dir", "nflId", "jerseyNumber"]#Test below with only 3 continuous
integer = ['frameId', 'gameId', 'playId']
timevar = 'time'

# %%
with nicaviz.timer("Distplots"):
    track20.nica.mass_plot(
        plt_set= ["nflId", "jerseyNumber"],
        plottype = "distplot")

    track20.nica.mass_plot(
        plt_set= ["nflId", "jerseyNumber"],
        hue = "displayName",
        plottype = "distplot")

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

track20.nica.mass_plot(
    plt_set = categoricals,
    columns = 3,
    plottype = "countplot")

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

#It took 3 minutes to plot the reduced continuous features

track20.nica.mass_plot(
    plt_set = continuous,
    columns = 3,
    plottype = "distplot")

print("['nflId', 'jerseyNumber'] Correlation: {}".format(track20[['nflId', 'jerseyNumber']].corr().iloc[0,1]))

# %% [markdown]
# #Recommended by Nick using column = 1 for pivot plots if they get crammed.

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

for cont in continuous:
    track20.nica.pivot_plots(
        categoricalcols = categoricals,
        valuecol = cont,
        aggfunc = np.mean,
        columns = 1)

# %% [markdown]
# #To satisfy Nick curiousity about how the continuous variables differ with Team category.

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

track20.nica.mass_plot(
    plt_set = continuous,
    columns = 3,
    hue = 'team',
    plottype = "distplot");

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

track20.nica.mass_plot(
    plt_set = ["event", "displayName", "position", "playDirection"],
    columns = 3,
    hue = 'team',
    plottype = "countplot")

# %%
with nicaviz.timer("Correlation Plot"):
    games.nica.rank_correlations_plots(["season", "gameId", "week"], 9)

# %%
with nicaviz.timer("Pivot Heatmap Plot"):
    categorical = ['homeTeamAbbr', 'visitorTeamAbbr', 'gameTimeEastern']
    games.nica.pivot_plots(categorical, "gameId", np.sum)

# %%
#Code by Nick Brooks https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook

for cont in continuous:
    track20.nica.pivot_plots(categoricals, cont, np.mean)

# %%
print("Notebook Runtime: %0.2f Minutes"%((time.time() - notebookstart)/60))

# %% [markdown]
# #That's so cool Nick Brooks (a.k.a Nicapotato). Thank you.
#
# #Acknowledgement
#
# Code by Nicapotato https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook
#
# Ventilator Pressure Prediction Nicaviz EDA By Nick Brooks, September 2021
#
# Resources
#
# https://github.com/nicapotato/nicaviz https://github.com/nicapotato/nicaviz/blob/master/notebooks/Plot_Examples.ipynb
#
# #Vote Nicapotato code https://www.kaggle.com/nicapotato/ventilator-pressure-prediction-nicaviz-eda/notebook
