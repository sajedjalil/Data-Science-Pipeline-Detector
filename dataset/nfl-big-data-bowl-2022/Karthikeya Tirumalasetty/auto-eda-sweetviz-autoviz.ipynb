# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

# %%
df_players=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/players.csv')
df_pff=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/PFFScoutingData.csv')
df_tracking_2018=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/tracking2018.csv')
df_tracking_2019=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/tracking2019.csv')
df_tracking_2020=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/tracking2020.csv')
df_games=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/games.csv')
df_plays=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/plays.csv')

# %%
# !pip install autoviz # refer pure auto viz https://www.kaggle.com/hamzaghanmi/nfl-big-data-bowl-2022-autoviz-eda

# %%
# !pip install sweetviz

# %% [markdown]
# # 1.Players

# %%
import sweetviz as sv
sweet_report = sv.analyze(df_players)
sweet_report.show_html('sweet_report.html')

# %%
sweet_report.show_notebook()
sweet_report.show_notebook(w=1500, h=300, scale=0.8)
sweet_report.show_html(scale=0.9)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
filename = "/kaggle/input/nfl-big-data-bowl-2022/players.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg"
)

# %% [markdown]
# # PFFScoutingData

# %%
#df_pff=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/PFFScoutingData.csv')
sweet_report = sv.analyze(df_pff)
sweet_report.show_html('sweet_report.html')
sweet_report.show_notebook()
sweet_report.show_notebook(w=1500, h=300, scale=0.8)
sweet_report.show_html(scale=0.9)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
filename = "/kaggle/input/nfl-big-data-bowl-2022/PFFScoutingData.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg"
)

# %% [markdown]
# # Games

# %%
#df_games=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/games.csv')
sweet_report = sv.analyze(df_games)
sweet_report.show_html('sweet_report.html')
sweet_report.show_notebook()
sweet_report.show_notebook(w=1500, h=300, scale=0.8)
sweet_report.show_html(scale=0.9)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
filename = "/kaggle/input/nfl-big-data-bowl-2022/games.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg"
)

# %% [markdown]
# # Plays

# %%
#df_plays=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/plays.csv')
sweet_report = sv.analyze(df_plays)
sweet_report.show_html('sweet_report.html')
sweet_report.show_notebook()
sweet_report.show_notebook(w=1500, h=300, scale=0.8)
sweet_report.show_html(scale=0.9)

# %%
#df_plays=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/plays.csv')
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
filename = "/kaggle/input/nfl-big-data-bowl-2022/plays.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg"
)

# %% [markdown]
# # Tracking 2018

# %%
#df_tracking_2018=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/tracking2018.csv')
sweet_report = sv.analyze(df_tracking_2018)
sweet_report.show_html('sweet_report.html')
sweet_report.show_notebook()
sweet_report.show_notebook(w=1500, h=300, scale=0.8)
sweet_report.show_html(scale=0.9)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
filename = "/kaggle/input/nfl-big-data-bowl-2022/tracking2018.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg"
)

# %% [markdown]
# # Tracking 2019

# %%
#df_tracking_2019=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/tracking2019.csv')
sweet_report = sv.analyze(df_tracking_2019)
sweet_report.show_html('sweet_report.html')
sweet_report.show_notebook()
sweet_report.show_notebook(w=1500, h=300, scale=0.8)
sweet_report.show_html(scale=0.9)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
filename = "/kaggle/input/nfl-big-data-bowl-2022/tracking2019.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg"
)

# %% [markdown]
# # Tracking 2020

# %%
#df_tracking_2020=pd.read_csv('/kaggle/input/nfl-big-data-bowl-2022/tracking2020.csv')
sweet_report = sv.analyze(df_tracking_2020)
sweet_report.show_html('sweet_report.html')
sweet_report.show_notebook()
sweet_report.show_notebook(w=1500, h=300, scale=0.8)
sweet_report.show_html(scale=0.9)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
filename = "/kaggle/input/nfl-big-data-bowl-2022/tracking2020.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg"
)
