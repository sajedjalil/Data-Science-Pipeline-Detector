# %% [markdown]
# #### EDA process
#
# Work in Progress

# %%
# load libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
#### Data Understanding
items = pd.read_csv("/kaggle/input/competitive-data-science-predict-future-sales/items.csv")
print("shape of the items dataset", items.shape)
items.head()

# %%
item_categories = pd.read_csv("/kaggle/input/competitive-data-science-predict-future-sales/item_categories.csv")
print("shape of the item_categories dataset", item_categories.shape)
item_categories.head()

# %%
sales_train = pd.read_csv("/kaggle/input/competitive-data-science-predict-future-sales/sales_train.csv")
print("shape of the sales_train dataset", sales_train.shape)
sales_train.head()

# %%
shops = pd.read_csv("/kaggle/input/competitive-data-science-predict-future-sales/shops.csv")
print("shape of the shops dataset", shops.shape)
shops.head()
