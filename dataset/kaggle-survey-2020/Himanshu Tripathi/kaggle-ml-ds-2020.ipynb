# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(15,10)})
# Seaborn setting                                                                                                                                              
sns.set(style='whitegrid', rc={"grid.linewidth": 0.1})
sns.set_context("paper", font_scale=1.2)

# import plotly.express as px
# from plotly.subplots import make_subplots
# import plotly.graph_objs as go

# %%
data = pd.read_csv("/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")
data.head()

# %%
data.columns

# %%
questions = data.iloc[0]
questions

# %%
data.head()

# %%
data = data.iloc[1:,:]

# %%
data.head()

# %% [markdown]
# ## Q1: What is your age (#years)

# %%
ags = data['Q1']
ags.value_counts()

# %%
sns.countplot(ags)

# %% [markdown]
# ## Q2: What is your gender?

# %%
gender = data['Q2']
print(f"Null Values:- {gender.isnull().sum()}")
gender.head()

# %%
g = sns.countplot(gender)
g.set_xlabel("Gender")
plt.show()

# %% [markdown]
# ## Q3: In which country do you currently reside?

# %%
country = data['Q3']
print(f"Null values:- {country.isnull().sum()}")
country.value_counts()

# %%
c_d = country.value_counts().reset_index()
c_d.columns = ['count','country']
c_d.head()

# %%
# c_d.plot.barh()
c = sns.barplot(x='country',y='count',data=c_d)

# %% [markdown]
# ## Q4: What is the highest level of formal education that you have attained or plan to attain within the next 2 years?

# %%
edu = data['Q4']
edu.head()

# %%
edu_d = edu.value_counts().reset_index()
edu_d.columns = ['degree','count']
edu_d['degree'] = edu_d['degree'].replace({
    'Some college/university study without earning a bachelor’s degree':'collage with degree',
    "No formal education past high school":"past high school"
})
edu_d

# %%
c = sns.barplot(x='degree',y='count',data=edu_d)

# %% [markdown]
# ## Q5: Select the title most similar to your current role (or most recent title if retired):

# %%
current_role = data['Q5']
current_role.head()

# %%
current_roleD = current_role.value_counts().reset_index()
current_roleD.columns = ['role','count']
current_roleD.head()

# %%
c = sns.barplot(x='count',y='role',data=current_roleD)

# %% [markdown]
# ## Q6: For how many years have you been writing code and/or programming?

# %%
years_of_code = data['Q6']
years_of_code.head()

# %%
sns.countplot(years_of_code)

# %% [markdown]
# ## Q7: What programming languages do you use on a regular basis? (Select all that apply)

# %%
programming_lang = data[[
     'Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3', 'Q7_Part_4', 
    'Q7_Part_5', 'Q7_Part_6', 'Q7_Part_7', 'Q7_Part_8', 
    'Q7_Part_9', 'Q7_Part_10', 'Q7_Part_11', 
    'Q7_Part_12', 'Q7_OTHER'
]]
programming_lang.head()

# %%
# a lot of missing values
sns.heatmap(programming_lang.isnull())

# %%
programming_lang_d = pd.Series(dtype='int')
for i in df_ides.columns:
    programming_lang_d[programming_lang[i].value_counts().index[0]] = df_ides[i].count()

programming_lang_d = programming_lang_d.sort_values(ascending=True)
plt.figure(figsize=(12,8))
programming_lang_d.plot(kind='barh')
# plt.annotate('Jupyter is the most favorite IDE' , xy =(4500,5),fontsize=24,color='navy')
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.xlabel('Count',fontsize=14)
plt.title('What programming languages do you use on a regular basis?',fontsize=15,weight='bold');

# %% [markdown]
# ## Q8: What programming language would you recommend an aspiring data scientist to learn first?

# %%
recomm_lang = data['Q8']
recomm_lang.head()

# %%
sns.countplot(recomm_lang)

# %% [markdown]
# ## Q9 Which of the following integrated development environments (IDE's) do you use on a regular basis? (Select all that apply)

# %%
ide = data[[
    'Q9_Part_1', 'Q9_Part_2', 'Q9_Part_3', 'Q9_Part_4', 
    'Q9_Part_5', 'Q9_Part_6', 'Q9_Part_7', 'Q9_Part_8', 
    'Q9_Part_9', 'Q9_Part_10', 'Q9_Part_11', 'Q9_OTHER'
]]
ide.head()

# %%
ide_d = pd.Series(dtype='int')
for i in ide.columns:
    ide_d[ide[i].value_counts().index[0]] = ide[i].count()

ide_d = ide_d.sort_values(ascending=True)
plt.figure(figsize=(12,8))
ide_d.plot(kind='barh')
# plt.annotate('Jupyter is the most favorite IDE' , xy =(4500,5),fontsize=24,color='navy')
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.xlabel('Count',fontsize=14)
plt.title("Which of the following integrated development environments (IDE's) do you use on a regular basis?",fontsize=15,weight='bold');

# %% [markdown]
# ## Q10: Which of the following hosted notebook products do you use on a regular basis? (Select all that apply)

# %%
notebooks = data[[ 
    'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 
    'Q10_Part_5', 'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 
    'Q10_Part_9', 'Q10_Part_10', 'Q10_Part_11', 
    'Q10_Part_12', 'Q10_Part_13', 'Q10_OTHER'
]]

# %%
notebooks_d = pd.Series(dtype='int')
for i in notebooks.columns:
    notebooks_d[notebooks[i].value_counts().index[0]] = notebooks[i].count()

notebooks_d = notebooks_d.sort_values(ascending=True)
plt.figure(figsize=(12,8))
notebooks_d.plot(kind='barh')
# plt.annotate('Jupyter is the most favorite IDE' , xy =(4500,5),fontsize=24,color='navy')
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.xlabel('Count',fontsize=14)
plt.title("Which of the following hosted notebook products do you use on a regular basis?",fontsize=15,weight='bold');
