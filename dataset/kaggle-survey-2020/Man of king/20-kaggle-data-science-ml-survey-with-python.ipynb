# %% [markdown]
# # 2020 Kaggle Data Science & Machine Learning Survey
#
# * Every response to every question, no data filtering
# * Click on the "Copy & Edit" button if you want to explore the data on your own!

# %% [markdown]
# ## Kaggle Ds together!

# %% [markdown]
# ![](https://miro.medium.com/max/640/0*ftOal7fKVCNtJr4N.png)

# %% [markdown]
# * *Step 1: Import Python libraries and load the data*

# %% [markdown]
# # <b>1 <span style='color:#F76241'>|</span> INTRODUCTION</b>
#
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>1.1 | N</b></p>
# </div>
#
# - Tht the `median_house_value`, <code>target variable</code>

# %% [markdown]
# #### **<span style='color:#FF5733'>kNN Unsupervised Learning Imputation</span>**
# - Function to impuse missing data using an unsupervised model.

# %% [markdown]
# # <b>2 <span style='color:#F76241'>|</span> METHOD</b>
#
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>2.1 | N</b></p>
# </div>

# %% [markdown]
# </ul>
# <table style="margin-left:0px;">
#   <tr>
#     <th style="background-color:#cfcfcf;
#                color:black;
#                border-radius:8px"><b>Variable</b></th>
#     <th style="background-color:#cfcfcf;
#                color:black;
#                border-radius:8px"><b>Description</b></th>
#       <th style="background-color:#cfcfcf;
#                color:black;
#                  border-radius:8px"><b>Type</b></th>
#   </tr>
#   <tr>
#     <td style="background-color:#e3e3e3;
#                color:black;
#                border-radius:10px"><b>Lower respiratory infections</b></td>
#     <td>South Asia (WB), South-East Asian Region (WHO), Sub-Saharan Africa (WB), World Bank Lower Middle Income</td>
#     <td>4</td>
#   </tr>
#   <tr>
#     <td style="background-color:#e3e3e3;
#                color:black;
#                border-radius:10px"><b>Neonatal preterm birth</b></td>
#     <td>World Bank Lower Middle Income</td>
#     <td>1</td>
#   </tr>
#   <tr>
#     <td style="background-color:#e3e3e3;
#                color:black;
#                border-radius:10px"><b>Diarrheal diseases</b></td>
#     <td>African Region (WHO), Sub-Saharan Africa (WB), World Bank Lower Middle Income</td>
#     <td>3</td>
#   </tr>
#   <tr>
#     <td colspan="2" style="background-color:#cfcfcf;
#                            color:black;
#                            border-radius:10px;
#                            text-align:center"><b>Total</b></td>
#       <td style="background-color:#cfcfcf;
#                color:black;
#                  border-radius:10px"><b>8</b></td>
#   </tr>
# </table>
# <hr>
# <h3 style="color:red"><u><b>Graphssss </b></u></h3>
# <ul>
#     <li style="font-size:15px"><h4 style="line-height:25px">The below graphs shows that the diseases are <mark style="background-color:black;color:white;border-radius:4px;"><b>exponential decrease</b></mark> in every year.</h4></li>
# </ul>

# %% [markdown]
# # <b>3 <span style='color:#F76241'>|</span> RESULT</b>
#
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>3.1 | N</b></p>
# </div>

# %%
import os
import numpy as np 
import pandas as pd 
from pandas import Series
import seaborn as sns

# %%
import plotly.express as px

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams, pyplot as plt, style as style

# %%
pd.set_option('display.max_columns', 5000)
pd.set_option('display.max_rows', 190) 
pd.set_option('display.max_columns', 5000)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('../input/kaggle_survey_2020_responses.csv')
df.head(3)

# %%
print(df.info())

# %%
df1= df[1:20037]

# %%
print(df1.info())

# %%
df1.dtypes

# %%
df1.shape

# %%
df1.columns

# %%
df1.isnull().sum()

# %%
df1['Q1'].unique()

# %%
df1.Q1.value_counts()

# %%
df1['Q2'].unique()

# %%
df1.Q2.replace(["Prefer not to say", "Prefer to self-describe", "Nonbinary"], "other", inplace=True)

# %%
df1['Q2'].unique()

# %%
df1.Q2.value_counts()

# %%
c = df1.Q2.value_counts(dropna=False)
p = df1.Q2.value_counts(dropna=False, normalize=True)\
    .round(4)*100
cp = pd.concat([c,p], axis=1, keys=['counts', '%']) 
cp['index'] = cp.index
cp1 = pd.DataFrame(cp)
cp1

# %%
cp1.loc["ColTotal", :] = cp1.sum()
cp1
cp1.head(5)

# %%
 type(cp1)

# %%
cp1.columns

# %%
#cp2["Index"][3] = 2
#cp2.loc[4][3] = value_a
#cp2['index'] = cp2['index'].fillna("Total")
cp1.iloc[3,2] = 'total'

# %%
cp1.head(5)

# %%
df1.isnull().sum()

# %%
df1['status'] = df.apply(lambda x : 1 if df1['Q2']=='Man' else '3', axis = 1)

# %%
def singleval(row):
    if row['Q2'] == 'Man': 
        val = 1
    elif row['Q2'] == 'Woman':
        val = 2
    else:
        val = 3
    return val

# %%
df1['gender_new'] = df1.apply(singleval,axis=1)
df1.Q2.value_counts()

# %%
df1.gender_new.value_counts()

# %%
plt.rcParams['figure.figsize'] = (18, 7)
size = [15789, 3878, 369] 
colors = ['violet', 'magenta', 'pink']
labels = "Man", "Woman", "Others"
explode = [0, 0, 0.1]
#plt.subplot(1, 2, 1)
plt.pie(size, colors = colors, labels = labels, explode = explode, shadow = True, autopct = '%.2f%%') 
plt.title('Sex type', fontsize = 30)
plt.axis('off')
plt.legend()

# %%
fig = plt.figure(figsize = (13,3)) 
ax1 = fig.add_subplot(111)
ax = sns.countplot(df1['Q1'], ax = ax1) 
labels = (df1['Q1'].value_counts()) 
for i, v in enumerate(labels): 
    ax.text(i, v+11, str(v), horizontalalignment = 'center', size = 13, color = 'black') 
plt.title('Age group distribution')
plt.xlabel('Age group')
plt.ylabel('Number of age group')
plt.tight_layout()

# %%
fig = plt.figure(figsize = (8,4)) #fig = plt.figure(figsize = (15,4))
ax1 = fig.add_subplot(111)
ax = sns.countplot(df1['Q1'], ax = ax1) #x축은 df1테이블의 Q2문자변수이고, y축은 x축변수에 대한 개수/빈도/갯수 정보
labels = (df1['Q1'].value_counts()) # calculate passengers for each category
for i, v in enumerate(labels): # add result numbers on barchart/바 차트 위에 값 라벨을 달기
    ax.text(i, v+11, str(v), horizontalalignment = 'center', size = 13, color = 'black')         
plt.title('Age group distribution')
plt.xlabel('Age group')
plt.ylabel('Number of age group')
plt.tight_layout()

# %%
index_list = ["35-39", "30-34", "22-24", "25-29", "18-21", "55-59", "50-54", "40-44", "60-69", "45-49", "70+",]
data_list =  [1991,     2811,    3786,    4011,    3469,     411,     698,     1397,    398,     988,     76]
series = Series(data=data_list, index=index_list)
series

fig = plt.figure(figsize = (8,4)) 
ax1 = fig.add_subplot(111)
ax = sns.countplot(df1['Q1'], ax = ax1) 
labels = (df1['Q1'].value_counts()) 
for i, v in enumerate(series): 
    ax.text(i, v+11, str(v), horizontalalignment = 'center', size = 13, color = 'black')         
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number')
plt.tight_layout()

# %%
pd.crosstab(df1.Q2, df1.Q1, margins=True)

# %%
pd.crosstab(df1.Q2,df1.Q1, normalize='index').round(4)*100

# %%
pd.crosstab(df1.Q2,df1.Q1, margins=True, normalize='index').round(4)*100

# %%
plt.figure(figsize=[9,5])
plt.title('age group by Sex')
sns.countplot('Q1',data=df1, hue='Q2')  
plt.legend(['Man','Women', 'Other'],loc='best')

# %%
pd.crosstab(df1.Q2,df1.Q8, margins=True, normalize='index').round(4)*100

# %%
a= pd.crosstab(df1.Q2,df1.Q8, margins=True, normalize='index').round(4)*100 
a.T.style.background_gradient(cmap='Greys')

# %%
pd.crosstab(df1.Q2,df1.Q8, margins=True, normalize='index').T.style.background_gradient(cmap='summer_r')

# %%
pd.crosstab(df1['Q8'], df1['Q2'], normalize='index').T.style.background_gradient(cmap='summer_r')

# %%
pd.crosstab(df1.Q2,df1.Q8, margins=True, normalize='index').round(4)*100

# %%
pd.crosstab(index=[df1.Q2, df1.Q1], columns=df1.Q8)

# %%
pd.crosstab(df1.Q2,df1.Q8, margins=True, normalize='index').round(4)*100

# %%
pd.crosstab(index=[df1.Q2, df1.Q1], columns=df1.Q8, margins=True, normalize='index').round(4)*100

# %%
c = pd.crosstab(index=[df1.Q2, df1.Q1], columns=df1.Q8, margins=True, normalize='index').round(4)*100
c.T.style.background_gradient(cmap='Greys')

# %%
ax = sns.countplot(x='Q8', hue = 'Q2',  data = df1)

# %%
ax = sns.countplot(x='Q8', hue = 'Q1',  data = df1)

# %%
fig, ax = plt.subplots(1,1,figsize=(13,8))
#ax=df['Q5'].value_counts().plot(kind='bar')
ax=sns.countplot(y='Q5', palette='Set2',data=df1, order=df['Q5'].value_counts().index) 
for p in ax.patches: 
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate("{:.2f}%".format((p.get_width())*100/len(df['Q5'])),
                (x + width/2, y + height/2), ha='left', va='center',fontsize=10)
plt.ylabel("Kaggle User type", size=15)
plt.xlabel("Count and Percentage", size=15)
plt.title("Kaggle User Type")
plt.show()

# %%
import sys
#reload(sys)
sys.setdefaultencoding('utf-8')

# %%
import textwrap

# %%
education = df1['Q4'].value_counts()
plt.figure(figsize=(8, 8))
color = ['dodgerblue' if (y < max(education)) else 'firebrick' for y in education] 
ax = sns.countplot(y='Q4', data=df1, order=education.index, palette=color, saturation=1) 
max_width = 15
ax.set_yticklabels(textwrap.fill(y.get_text(), max_width) for y in ax.get_yticklabels())
plt.ylabel('education', size=15)
plt.xlabel("Count", size=15)
plt.yticks(rotation=25, fontsize=12)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate("{:.2f}%".format((p.get_width())*100/len(df1['Q4'])), 
                (x + width/2, y + height/2), ha='left', va='center', fontsize=10)
plt.title("Education status of Kaggle User", fontsize=12)

# %%
experience = df1['Q8'].value_counts()
plt.figure(figsize=(10, 10))
color = ['dodgerblue' if (y < max(experience)) else 'firebrick' for y in experience] 
ax= sns.countplot(y="Q8", data=df1, order=experience.index, palette=color, saturation=1) 
plt.ylabel('programming languages', size=15)
plt.xlabel("Count", size=15)
plt.yticks(fontsize=12)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate("{:.2f}%".format((p.get_width())*100/len(df1['Q8'])),  
                (x + width/2, y + height/2), ha='left', va='center',fontsize=12)
plt.title("Kaggle user's preferred programming language", fontsize=12)

# %%
experience = df1['Q8'].value_counts()
plt.figure(figsize=(10, 10))
color = ['dodgerblue' if (y < max(experience)) else 'firebrick' for y in experience] 
ax= sns.countplot(y="Q8", data=df1, order=experience.index, palette=color, saturation=1, hue='Q2',) 
plt.ylabel('programming languages', size=15)
plt.xlabel("Count", size=15)
plt.yticks(fontsize=12)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate("{:.2f}%".format((p.get_width())*100/len(df1['Q8'])),  
                (x + width/2, y + height/2), ha='left', va='center',fontsize=12)
plt.title("Kaggle user's preferred programming language", fontsize=12)

# %%
plt.rcParams['figure.figsize'] = (15, 9)
x = pd.crosstab(df1['Q8'], df1['Q2']) 
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = False)
plt.title('Gender vs Race', fontweight = 30, fontsize = 20)
plt.show()

# %% [markdown]
# # **<span style="color:#F7B2B0;">References</span>**
#
# ht
#
# https://

# %% [markdown]
# # Work in progress 🚧
