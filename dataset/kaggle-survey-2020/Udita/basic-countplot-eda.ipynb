# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pd.set_option('display.max_columns', 400)

# %%
survey = pd.read_csv('/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv',low_memory = False)
survey.head()

# %%
survey.drop(labels = 0, axis = 0, inplace = True)

# %%
def countplot(fig_x,fig_y,col,top_x,rotation,xlabel,title) :
    plt.figure(figsize=(fig_x,fig_y))
    total = float(len(survey))
    ax = sns.countplot(x=col,  data=survey, order = survey[col].value_counts().iloc[:top_x].index) 
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y),xytext = (x+0.05,y+20),ha = 'center',weight = 'bold',size = 11)
    plt.xticks(rotation = rotation,weight='bold',size = 10)
    plt.yticks(weight='bold',size = 10)
    plt.xlabel(xlabel,weight='bold',size = 12)
    plt.ylabel('count',weight='bold',size = 12)
    plt.title(title,weight='bold',size = 15)
    plt.show()

# %% [markdown]
# ## Age Group

# %%
countplot(12,8,'Q1',15,45,'Age Group','Age Distribution of Respondents')

# %% [markdown]
# A major portion of data science enthusiats are people in their 20's.

# %% [markdown]
# ## Gender

# %%
countplot(8,6,'Q2',15,45,'Gender','Gender Distribution of Respondents')

# %% [markdown]
# ## Country

# %%
survey.Q3 = survey.Q3.apply(lambda x : 'USA' if x == 'United States of America' else x)
survey.Q3 = survey.Q3.apply(lambda x : 'UK' if x == 'United Kingdom of Great Britain and Northern Ireland' else x)

# %%
countplot(20,8,'Q3',15,45,'Countries','Countries of Respondents')

# %% [markdown]
# ## Education

# %%
survey.Q4 = survey.Q4.apply(lambda x : 'w/o Bachelor\'s degree' if x == 'Some college/university study without earning a bachelor’s degree' else x)

# %%
countplot(20,10,'Q4',15,45,'Education','Educational Qualification of Respondents')

# %% [markdown]
# ## Job

# %%
countplot(20,10,'Q5',15,45,'Job','Job of Respondents')

# %% [markdown]
# ## Programming Exp.

# %%
countplot(12,10,'Q6',15,45,'Programming exp.','Programming exp. of Respondents')

# %% [markdown]
# ## Recommended Programming language

# %%
countplot(20,10,'Q8',15,45,'Recommended Programming Language','Recommended Programming Language')

# %% [markdown]
# ## Computing Platform

# %%
survey.Q11.value_counts()

# %%
survey.Q11 = survey.Q11.apply(lambda x : 'Cloud Computing Platform' if x == 'A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)' else x)
survey.Q11 = survey.Q11.apply(lambda x : 'Deep learning workstation' if x == 'A deep learning workstation (NVIDIA GTX, LambdaLabs, etc)' else x)

# %%
countplot(20,8,'Q11',15,15,'Computing Platform','Computing Platform')

# %% [markdown]
# ## TPU usage

# %%
countplot(10,8,'Q13',15,15,'Used TPU','TPU usage of Respondents')

# %% [markdown]
# ## ML Experience

# %%
survey.Q15 = survey.Q15.apply(lambda x : 'No experience' if x == 'I do not use machine learning methods' else x)

# %%
countplot(10,8,'Q15',15,15,'ML experience','ML Experience of Respondents')

# %% [markdown]
# ## Company Size

# %%
countplot(10,8,'Q20',15,15,'Company Size','Company Size')

# %% [markdown]
# ## No. of Data scientists

# %%
countplot(10,8,'Q21',15,15,'Data Scientists','No.of Data Scientists in the company')

# %% [markdown]
# ## ML incorporation level

# %%
survey.Q22.value_counts()

# %%
survey.Q22 = survey.Q22.apply(lambda x : 'May use in future' if x == 'We are exploring ML methods (and may one day put a model into production)' else x)
survey.Q22 = survey.Q22.apply(lambda x : 'Not in use' if x == 'No (we do not use ML methods)' else x)
survey.Q22 = survey.Q22.apply(lambda x : '>2 years' if x == 'We have well established ML methods (i.e., models in production for more than 2 years)' else x)
survey.Q22 = survey.Q22.apply(lambda x : '<2 years' if x == 'We recently started using ML methods (i.e., models in production for less than 2 years)' else x)
survey.Q22 = survey.Q22.apply(lambda x : 'Not sure' if x == 'I do not know ' else x)
survey.Q22 = survey.Q22.apply(lambda x : 'Only for gaining insights' if x == 'We use ML methods for generating insights (but do not put working models into production)' else x)

# %%
countplot(10,8,'Q22',15,15,'ML incorporation','ML incorporation level')

# %% [markdown]
# ## Compensation

# %%
countplot(20,8,'Q24',15,15,'Compensation(in $)','Compensation')

# %% [markdown]
# ## ML/Cloud funds(USD)

# %%
countplot(10,8,'Q25',15,15,'ML/Cloud funds(USD)','ML/Cloud funds(USD)')

# %% [markdown]
# ## Bigdata Products

# %%
survey.Q30.value_counts()

# %%
survey.Q30 = survey.Q30.apply(lambda x : 'MS Azure Data Lake Storage' if x == 'Microsoft Azure Data Lake Storage ' else x)

# %%
countplot(20,8,'Q30',15,55,'Bigdata Products','Bigdata Products')

# %% [markdown]
# ## Business Intelligence Tools

# %%
countplot(20,10,'Q32',15,55,'BI Tools','BI Tools')
