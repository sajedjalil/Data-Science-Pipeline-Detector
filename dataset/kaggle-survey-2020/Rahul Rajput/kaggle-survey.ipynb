# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Imports

# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Read Data

# %%
pd.set_option('display.max_columns',400)
df = pd.read_csv("../input/kaggle-survey-2020/kaggle_survey_2020_responses.csv" )

# %%
df.head(4)

# %%
list(df.columns)

# %%
df.info()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()

# %%
headers = {}
for col in df.columns:
    headers.update({col:f"{col} : {df.loc[0,col]}"})

# %%
headers

# %%
df = df.iloc[1:,:].copy()
df = df[['Time from Start to Finish (seconds)','Q1','Q2','Q3','Q4','Q5','Q6','Q7_Part_1',
       'Q8','Q9_Part_1','Q11','Q13','Q14_Part_1']]

# %%
df['Q1'].unique()

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q1'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q1'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q2'].unique()

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q2'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q2'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q3'].unique()

# %%
df['Q3'].value_counts()

# %%
plt.figure(figsize=(25,7))
ax = df['Q3'].value_counts()[:10].plot(kind='bar')
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q3'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q4'].unique()

# %%
df['Q4'].fillna("I prefer not to answer" , inplace=True)

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q4'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q4'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q5'].unique()

# %%
df['Q5'].fillna("Other" , inplace=True)

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q5'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q5'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q6'].unique()

# %%
df['Q6'].fillna("I have never written code" ,inplace=True)

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q6'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q6'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q7_Part_1'].unique()

# %%
df['Q7_Part_1'].fillna('others' ,inplace=True)

# %%
q7= df['Q7_Part_1'].value_counts()
plt.figure(figsize=(25,7))
plt.pie(q7.values ,labels=q7.index ,explode=[0,0.02], autopct="%.1f%%")
plt.xticks(rotation=90)
plt.xlabel(None)
plt.ylabel(None)
plt.title(headers['Q7_Part_1'])
plt.show()

# %%
df['Q8'].unique()

# %%
df['Q8'].fillna('Other',inplace=True)
df['Q8'].replace({'None':"Other"}, inplace=True)

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q8'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q8'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q9_Part_1'].unique()

# %%
df['Q9_Part_1'].fillna('Others' ,inplace=True)
df['Q9_Part_1'].replace({'Jupyter (JupyterLab, Jupyter Notebooks, etc) ':"Jupyter Notebooks"} , inplace=True)

# %%
q9 = df['Q9_Part_1'].value_counts()
plt.figure(figsize=(25,7))
plt.pie(q9.values ,labels=q9.index , explode=[0,0.02]  ,autopct='%.1f%%')
plt.xticks(rotation=90)
plt.xlabel(None)
plt.ylabel(None)
plt.title(headers['Q9_Part_1'])
plt.show()

# %%
df['Q11'].unique()

# %%
df['Q11'].fillna('Other',inplace=True)
df['Q11'].replace({"A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)":"Cloud Platform" ,
                    "A personal computer or laptop":"Personal Laptop" ,
                      "A deep learning workstation (NVIDIA GTX, LambdaLabs, etc)":"DL Workstations" , 
                        "None":"Other"},inplace=True)

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q11'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q11'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
headers['Q13']

# %%
df['Q13'].unique()

# %%
df['Q13'].fillna('Never',inplace=True)

# %%
plt.figure(figsize=(25,7))
ax = sns.countplot(df['Q13'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q13'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()

# %%
df['Q14_Part_1'].unique()

# %%
df['Q14_Part_1'].fillna('Other',inplace=True)

# %%
plt.figure(figsize=(10,7))
ax = sns.countplot(df['Q14_Part_1'])
plt.xticks(rotation=90)
plt.xlabel(None)
plt.title(headers['Q14_Part_1'])
for p in ax.patches:
    ax.annotate("%.1f%%" % (100*float(p.get_height()/df.shape[0])), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
                     ha='center', va='bottom', color='black', xytext=(0, 5),rotation = 'horizontal',
                     textcoords='offset points')
plt.show()
