# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sb
import matplotlib.pyplot as plt


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Making All Rows & Columns Visiable

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %% [markdown]
# ## Extraction of Data
# - kaggele_survey_2020_responses.csv

# %%
df=pd.read_csv("../input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")

# %% [markdown]
# ## Reading Data

# %%
df.head()

# %% [markdown]
# ## Removing 0th Row
# - Sutaible column header

# %%
df1=df.iloc[1:]
df1.head()

# %% [markdown]
# ## Claculating statistical values

# %%
df1.describe()

# %%
df1.columns

# %%
df1.shape

# %% [markdown]
# ## Looking on Time from Start to Finish (seconds) column

# %% [markdown]
# ## Looking for data type
# - Data type is object

# %%
df1["Time from Start to Finish (seconds)"].dtypes

# %% [markdown]
# ## Changing Data Type
# - Data type to integer

# %%
df1["Time from Start to Finish (seconds)"]=df1["Time from Start to Finish (seconds)"].astype(str).astype(int)

# %% [markdown]
# - Data type is integer(int) now

# %%
df1["Time from Start to Finish (seconds)"].dtypes

# %% [markdown]
# ## Checking Null Values
# - Zero null values

# %%
df1["Time from Start to Finish (seconds)"].isnull().sum()

# %% [markdown]
# ## Maximum and Minimum values
# - Maximum value is 1144493
# - Minimum value is 20

# %%
df1["Time from Start to Finish (seconds)"].max()

# %%
df1["Time from Start to Finish (seconds)"].min()

# %% [markdown]
# ## Mean & Median value
# - Mean value is 9155.864843282092
# - Median value is 626.0

# %%
print(df1["Time from Start to Finish (seconds)"].mean())
print(df1["Time from Start to Finish (seconds)"].median())

# %% [markdown]
# ## Percentiles
# - Value for 25 % is 398
# - Value for 50 % is 626
# - value for 75 % is 1030.25

# %%
print(np.percentile(df1["Time from Start to Finish (seconds)"],25))
print(np.percentile(df1["Time from Start to Finish (seconds)"],50))
print(np.percentile(df1["Time from Start to Finish (seconds)"],75))

# %% [markdown]
# ## Boxplot
# - Here we can see that most of the values that escapes the normality and can cause anomalies in the result.
# - On x-axis we have **"Age Group"** and on y-axis we have **"Time from Start to Finish (seconds)".**

# %%
plt.figure(figsize=(20,10))
sb.boxplot(x="Q1",y="Time from Start to Finish (seconds)",data=df1)
plt.show()

# %% [markdown]
# ## What is your age (# years)?

# %% [markdown]
# ## Barplot
# - On X-axis we have **"Age Group"** and on Y-axis we have **"Time from Start to Finish (seconds)"**
# - Here we can see that **"Age Group 55-59 and 60-69"** has taken more time to fill the survey form.
# - Where as ** "Age Group 18-21"** has taken less time to fill the survey form.
# - The black Line shows confidence intervals or the standard deviation.
# - We can say in **"Age Group 55-59 and 60-69"** has more number of the above both.

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=80)
sb.barplot(x="Q1",y="Time from Start to Finish (seconds)",data=df1)
plt.show()

# %% [markdown]
# ## What is your gender?

# %% [markdown]
# ## Looking for unique values in "Q2" i.e "Gender"

# %%
df1["Q2"].unique()

# %% [markdown]
# ## Barplot
# - Here on X-axis we have **"Gender"** and on Y-axis we have **"Time"**
# - We can say that the people who choose **"Prefer not to say"** have taken more time in filling the survey form.Also the Stander deviation/ error bar is high.

# %%
plt.figure(figsize=(30,20))

plt.xticks(rotation=80)
sb.barplot(x="Q2",y="Time from Start to Finish (seconds)",data=df1)
plt.show()

# %% [markdown]
# ## In which country do you currently reside?

# %% [markdown]
# ## Looking for unique values in "Q3" i.e "Country"

# %%
df1["Q3"].unique()

# %% [markdown]
# ## Barplot
# - Here on Xaxis we have **"Countries"** on Y-axis we have **"Time"**.
# - We can see that people from **"Republic of Korea"** have taken more time for survey form filing.Also has as high standard deviation/error bar.

# %%
plt.figure(figsize=(30,20))

plt.xticks(rotation=90)
sb.barplot(x="Q3",y="Time from Start to Finish (seconds)",data=df1)
plt.show()

# %% [markdown]
# ## What is the highest level of formal education that you have attained or plan to attain within the next 2years?

# %% [markdown]
# ## Looking for unique values in "Q4"  i.e "Degree's"

# %%
df1["Q4"].unique()

# %% [markdown]
# ## Barplot
# - On X-axis we have **"Q4"** that contains **"Degree's"** and Y-axis has **"Time from Start to Finish (seconds)"**
# - Here we can say that people who have **"Professional degree"** have take more time to fill the survey form.
# - The black Line shows confidence intervals or the standard deviation,We also call the line as error bar.
# - Here we can see that the Standard deviation is high in **No formal education past high school.**

# %%
plt.figure(figsize=(30,20))

plt.xticks(rotation=80)
sb.barplot(x="Q4",y="Time from Start to Finish (seconds)",data=df1)
plt.show()

# %% [markdown]
# ## Select the title most similar to your current role (or most recent title if retired)

# %% [markdown]
# ## Looking for unique in "Q5" i.e Title/current position
# - Student
# - Data Engineer
# - software Engineer
# - Data Scientist
# - Data Analyst
# - Research Scientist
# - Currently not employed
# - statistician
# - Product/project manager
# - Machine Learning Engineer
# - Business Analyst
# - DBA/Data Engineer
# - others

# %%
df1["Q5"].unique()

# %% [markdown]
# ## Barplot
# - Here on X-axis we have Titles/Current position peoples an on Y-axis we have Time.
# - Here we can see that "Product/Project manager" Titles peoples have taken more time to fill the survey form.
# - And also has the high standard deviation/Error bar.

# %%
plt.figure(figsize=(30,30))
plt.xticks(rotation=80)
sb.barplot(x="Q5",y="Time from Start to Finish (seconds)",data=df1)
plt.show()

# %% [markdown]
# ## What is your gender?

# %% [markdown]
# ## Looking at "Q2" Column
# ### That is "Gender"

# %% [markdown]
# ## Finding unique values
# - We have 5 unique values in Q2 column
# - 1. Man
# - 2. Woman
# - 3. Prefer to self-describe
# - 4. Prefer not to say
# - 5. Nonbinary

# %%
df1["Q2"].unique()

# %% [markdown]
# ## Replacing values
# - 1.Man to "0"
# - 2.Woman to "1"
# - 3.Prefer to self-describe to "2"
# - 4.Prefer not to say to "3"
# - 5.Nonbinary to "4"

# %%
df1_man_women=df1["Q2"].replace({"Man":0,"Woman":1,"Prefer to self-describe":2,"Prefer not to say":3,"Nonbinary":4})
print(df1_man_women)

# %% [markdown]
# ## Converted data into integer fromat

# %%
df1_man_women.dtypes

# %%
df1_man_women=df1_man_women.astype(str).astype(int)

# %%
df1_man_women.dtypes

# %% [markdown]
# ## Histogram "Q2" Column i.e "Gender"

# %%
df1_man_women.hist()# we have more no. of male who have fill the form

# %% [markdown]
# ## For how many years have you been writing code and/or programming?

# %% [markdown]
# ## Looking at unique values in "Q6" column i.e Years of code

# %%
df1["Q6"].unique()

# %% [markdown]
# ## Barplot
# - Here on X-axis we have **"Years of code"** and on Y-axis we have **"Time"**.
# - We can say that peoles who have **"5-10 years and 10-20 years"** have take same time to fill the survey form.
# - But the high error bar is at **"10-20 years"**.

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=80)
sb.barplot(x="Q6",y="Time from Start to Finish (seconds)",data=df1)
plt.show()

# %% [markdown]
# ## What programming languages do you use on a regular basis? (Select all that apply)

# %% [markdown]
# ## Looking for unique values in "Q7 part 1-12"

# %%
print("Unique value in Q7_Part_1:",df1["Q7_Part_1"].unique())
print("Unique value in Q7_Part_2:",df1["Q7_Part_2"].unique())
print("Unique value in Q7_Part_3:",df1["Q7_Part_3"].unique())
print("Unique value in Q7_Part_4:",df1["Q7_Part_4"].unique())
print("Unique value in Q7_Part_5:",df1["Q7_Part_5"].unique())
print("Unique value in Q7_Part_6:",df1["Q7_Part_6"].unique())
print("Unique value in Q7_Part_7:",df1["Q7_Part_7"].unique())
print("Unique value in Q7_Part_8:",df1["Q7_Part_8"].unique())
print("Unique value in Q7_Part_9:",df1["Q7_Part_9"].unique())
print("Unique value in Q7_Part_10:",df1["Q7_Part_10"].unique())
print("Unique value in Q7_Part_11:",df1["Q7_Part_11"].unique())
print("Unique value in Q7_Part_12:",df1["Q7_Part_12"].unique())

# %% [markdown]
# ## Looking for null values in "Q7 part 1-12"

# %%
print("The count of null values in Q7_Part_1:",df1["Q7_Part_1"].isnull().sum())
print("The count of null values is Q7_Part_2:",df1["Q7_Part_2"].isnull().sum())
print("The count of null values in Q7_Part_3:",df1["Q7_Part_3"].isnull().sum())
print("The count of null values is Q7_Part_4:",df1["Q7_Part_4"].isnull().sum())
print("The count of null values in Q7_Part_5:",df1["Q7_Part_5"].isnull().sum())
print("The count of null values is Q7_Part_6:",df1["Q7_Part_6"].isnull().sum())
print("The count of null values in Q7_Part_7:",df1["Q7_Part_7"].isnull().sum())
print("The count of null values is Q7_Part_8:",df1["Q7_Part_8"].isnull().sum())
print("The count of null values in Q7_Part_9:",df1["Q7_Part_9"].isnull().sum())
print("The count of null values is Q7_Part_10:",df1["Q7_Part_10"].isnull().sum())
print("The count of null values in Q7_Part_11:",df1["Q7_Part_11"].isnull().sum())
print("The count of null values is Q7_Part_12:",df1["Q7_Part_12"].isnull().sum())

# %%
df1_python=df1["Q7_Part_1"]
df1_r=df1["Q7_Part_2"]
df1_sql=df1["Q7_Part_3"]
df1_c=df1["Q7_Part_4"]
df1_cplus=df1["Q7_Part_5"]
df1_java=df1["Q7_Part_6"]
df1_js=df1["Q7_Part_7"]
df1_julia=df1["Q7_Part_8"]
df1_swift=df1["Q7_Part_9"]
df1_bash=df1["Q7_Part_10"]
df1_matlab=df1["Q7_Part_11"]
df1_none=df1["Q7_Part_12"]

# %% [markdown]
# ## Replacing Values
# - Python as 0
# - R as 1
# - SQL as 2
# - C as 3
# - C++ as 4
# - Java as 5
# - Javascript as 6
# - Julia as 7
# - Swift as 8
# - Bash as 9
# - Matlab as 10
# - None as 11

# %%
df1_python=df1_python.replace("Python",1)
df1_r=df1_r.replace("R",2)
df1_sql=df1_sql.replace("SQL",3)
df1_c=df1_c.replace("C",4)
df1_cplus=df1_cplus.replace("C++",5)
df1_java=df1_java.replace("Java",6)
df1_js=df1_js.replace("Javascript",7)
df1_julia=df1_julia.replace("Julia",8)
df1_swift=df1_swift.replace("Swift",9)
df1_bash=df1_bash.replace("Bash",10)
df1_matlab=df1_matlab.replace("MATLAB",11)
df1_none=df1_none.replace("None",12)

# %% [markdown]
# ## Checking Data type

# %%
print(df1_python.dtypes)
print(df1_r.dtypes)
print(df1_c.dtypes)
print(df1_cplus.dtypes)

# %%
print(df1_python.count())
print(df1_r.count())
print(df1_sql.count())
print(df1_c.count())
print(df1_cplus.count())
print(df1_java.count())
print(df1_js.count())
print(df1_julia.count())
print(df1_swift.count())
print(df1_bash.count())
print(df1_matlab.count())
print(df1_none.count())

# %%
df1_Lag_list=[df1_python,df1_r,df1_sql,df1_c,df1_cplus,df1_java,df1_js,df1_julia,df1_swift,df1_bash,df1_matlab,df1_none]
df1_Lag_list=pd.DataFrame(df1_Lag_list,index=["df1_python","df1_r","df1_sql","df1_c","df1_cplus","df1_java","df1_js","df1_julia","df1_swift","df1_bash","df1_matlab","df1_none"])

# %%
df1_Lag_list=df1_Lag_list.T
df1_Lag_list

# %%
df1_Lag_list.shape

# %%
df1_Lag_list.isnull().sum().sum()

# %%
df1_Lag_list.fillna(0)

# %% [markdown]
# ## Histogram
# - Here we have histogram of all the languages mention int survey.
# - We can see that **"PYTHON"** is the most use langugae which is use and then **"SQL"** is used.

# %%
plt.figure(figsize=(10,10))
df1_Lag_list.hist()
plt.show()

# %% [markdown]
# - As we have seen that **"Pyhton"** and **"SQL"** are two languages which people are using most.

# %% [markdown]
# - As we see more than 14000 people are using **"Pyhton"** language

# %%
df1_Lag_list["df1_python"].hist()

# %% [markdown]
# - Also **"SQL"** is the second most language which is used.

# %%
df1_Lag_list["df1_sql"].hist()

# %% [markdown]
# - Third most used language is **"R"**

# %%
df1_Lag_list["df1_r"].hist()

# %% [markdown]
# ## What programming language would you recommend an aspiring data scientist to learn first?

# %%
df1["Q8"].unique()

# %% [markdown]
# ## Histogram
# - The most recommended language is **"Python"** and **"R"**.

# %%
plt.figure(figsize=(10,8))
df1["Q8"].hist(histtype="bar",ec="black")
plt.show()

# %% [markdown]
# ## Which of the following integrated development environments (IDE's) do you use on a regular basis?

# %% [markdown]
# ## Looking at uniques values in Q9Part1 to Q9other

# %%
print("Unique value in Q9_Part_1:",df1["Q9_Part_1"].unique())
print("Unique value in Q9_Part_2:",df1["Q9_Part_2"].unique())
print("Unique value in Q9_Part_3:",df1["Q9_Part_3"].unique())
print("Unique value in Q9_Part_4:",df1["Q9_Part_4"].unique())
print("Unique value in Q9_Part_5:",df1["Q9_Part_5"].unique())
print("Unique value in Q9_Part_6:",df1["Q9_Part_6"].unique())
print("Unique value in Q9_Part_7:",df1["Q9_Part_7"].unique())
print("Unique value in Q9_Part_8:",df1["Q9_Part_8"].unique())
print("Unique value in Q9_Part_9:",df1["Q9_Part_9"].unique())
print("Unique value in Q9_Part_10:",df1["Q9_Part_10"].unique())
print("Unique value in Q9_Part_11:",df1["Q9_Part_11"].unique())
print("Unique value in Q9_OTHER:",df1["Q9_OTHER"].unique())

# %%
df1_jnote=df1["Q9_Part_1"]
df1_rstudio=df1["Q9_Part_2"]
df1_vs=df1["Q9_Part_3"]
df1_vsc=df1["Q9_Part_4"]
df1_pyc=df1["Q9_Part_5"]
df1_spy=df1["Q9_Part_6"]
df1_note=df1["Q9_Part_7"]
df1_st=df1["Q9_Part_8"]
df1_ve=df1["Q9_Part_9"]
df1_mat=df1["Q9_Part_10"]
df1_none=df1["Q9_Part_11"]
df1_other=df1["Q9_OTHER"]

# %% [markdown]
# ## Replacing values
# - JupyterLab (or products based off of Jupyter) replace as 1
# - RStudio replace as 2
# - Visual Studio replace as 3
# - Visual Studio Code (VSCode) replace as 4
# - PyCharm replace as 5
# - Spyder replace as 5
# - Notepad++ replace as 6
# - Sublime Text replace as 7
# - Vim, Emacs, or similar replace as 8
# - MATLAB replace as 9
# - None replace as 10
# - Other replace as 12

# %%
df1_jnote=df1_jnote.replace('Jupyter (JupyterLab, Jupyter Notebooks, etc) ',1)
df1_rstudio=df1_rstudio.replace(' RStudio ',2)
df1_vs=df1_vs.replace("Visual Studio",3)
df1_vsc=df1_vsc.replace('Visual Studio Code (VSCode)',4)
df1_pyc=df1_pyc.replace(' PyCharm ',5)
df1_spy=df1_spy.replace('  Spyder  ',6)
df1_note=df1_note.replace('  Notepad++  ',7)
df1_st=df1_st.replace('  Sublime Text  ',8)
df1_ve=df1_ve.replace('  Vim / Emacs  ',9)
df1_mat=df1_mat.replace(' MATLAB ',10)
df1_none=df1_none.replace('None',11)
df1_other=df1_other.replace('Other',12)

# %%
df1_idle_list=[df1_jnote,df1_rstudio,df1_vs,df1_pyc,df1_spy,df1_note,df1_st,df1_ve,df1_mat,df1_none,df1_other]
df1_idle_list=pd.DataFrame(df1_idle_list,index=["df1_jnote","df1_rstudio","df1_vs","df1_pyc","df1_spy","df1_note","df1_st","df1_ve","df1_mat","df1_none","df1_other"])

# %%
df1_idle_list=df1_idle_list.T
df1_idle_list.head()

# %% [markdown]
# ## Filling null values as zero

# %%
df1_idle_list=df1_idle_list.fillna(0)
df1_idle_list.head()

# %%
df1_jnote.dtype

# %%
df1_idle_list.hist()

# %% [markdown]
# - As we can see **"Jupyter (JupyterLab, Jupyter Notebook)"**  integrated development environments (IDE's) is used.

# %%
df1_idle_list["df1_jnote"].hist()

# %% [markdown]
# ## Which of the following hosted notebook products do you use on a regular basis? (Select all that apply)
# - Kaggle Notebooks
# - Colab Notebooks
# - Azure Notebooks
# - Paperspace / Gradient
# - Binder / JupyterHub
# - Code Ocean
# - IBM Watson Studio
# - Amazon Sagemaker Studio
# - Amazon EMR Notebooks
# - Google Cloud AI Platform Notebooks
# - Google Cloud Datalab Notebooks
# - Databricks Collaborative Notebooks
# - None
# - Other

# %% [markdown]
# ## Looking for unique values

# %%
print("Unique value in Q10_Part_1:",df1["Q10_Part_1"].unique())
print("Unique value in Q10_Part_2:",df1["Q10_Part_2"].unique())
print("Unique value in Q10_Part_3:",df1["Q10_Part_3"].unique())
print("Unique value in Q10_Part_4:",df1["Q10_Part_4"].unique())
print("Unique value in Q10_Part_5:",df1["Q10_Part_5"].unique())
print("Unique value in Q10_Part_6:",df1["Q10_Part_6"].unique())
print("Unique value in Q10_Part_7:",df1["Q10_Part_7"].unique())
print("Unique value in Q10_Part_8:",df1["Q10_Part_8"].unique())
print("Unique value in Q10_Part_9:",df1["Q10_Part_9"].unique())
print("Unique value in Q10_Part_10:",df1["Q10_Part_10"].unique())
print("Unique value in Q10_Part_11:",df1["Q10_Part_11"].unique())
print("Unique value in Q10_Part_12:",df1["Q10_Part_12"].unique())
print("Unique value in Q10_Part_13:",df1["Q10_Part_13"].unique())
print("Unique value in Q10_OTHER :",df1["Q10_OTHER"].unique())

# %%
df1_kn=df1["Q10_Part_1"]
df1_cn=df1["Q10_Part_2"]
df1_an=df1["Q10_Part_3"]
df1_pg=df1["Q10_Part_4"]
df1_bj=df1["Q10_Part_5"]
df1_co=df1["Q10_Part_6"]
df1_iws=df1["Q10_Part_7"]
df1_ass=df1["Q10_Part_8"]
df1_aer=df1["Q10_Part_9"]
df1_gca=df1["Q10_Part_10"]
df1_gcd=df1["Q10_Part_11"]
df1_dcn=df1["Q10_Part_12"]
df1_none=df1["Q10_Part_13"]
df1_other=df1["Q10_OTHER"]

# %% [markdown]
# ## Replacing the values
# - Kaggle Notebooks replace as 1.
# - Colab Notebooks replace as 2.
# - Azure Notebooks replace as 3.
# - Paperspace / Gradient replace as 4.
# - Binder / JupyterHub replace as 5.
# - Code Ocean replace as 6.
# - IBM Watson Studio replace as 7.
# - Amazon Sagemaker Studio replace as 8.
# - Amazon EMR Notebooks replace as 9.
# - Google Cloud AI Platform Notebooks replace as 10.
# - Google Cloud Datalab Notebooks replace as 11.
# - Databricks Collaborative Notebooks replace as 12.
# - None replace as 13.
# - Other replace as 14.

# %%
df1_kn=df1_kn.replace(' Kaggle Notebooks',1)
df1_cn=df1_cn.replace('Colab Notebooks',2)
df1_an=df1_an.replace('Azure Notebooks',3)
df1_pg=df1_pg.replace(' Paperspace / Gradient ',4)
df1_bj=df1_bj.replace(' Binder / JupyterHub ',5)
df1_co=df1_co.replace(' Code Ocean ',6)
df1_iws=df1_iws.replace(' IBM Watson Studio ',6)
df1_ass=df1_ass.replace(' Amazon Sagemaker Studio ',7)
df1_aer=df1_aer.replace(' Amazon EMR Notebooks ',8)
df1_gca=df1_gca.replace('Google Cloud AI Platform Notebooks ',9)
df1_gcd=df1_gcd.replace('Google Cloud Datalab Notebooks',10)
df1_dcn=df1_dcn.replace(' Databricks Collaborative Notebooks ',11)
df1_none=df1_none.replace('None',12)
df1_other=df1_other.replace('Other',13)

# %%
df1_nb_list=[df1_kn,df1_cn,df1_an,df1_pg,df1_bj,df1_co,df1_iws,df1_ass,df1_aer,df1_gca,df1_gcd,df1_dcn,df1_none,df1_other]
df1_nb_list=pd.DataFrame(df1_nb_list,index=["df1_kn","df1_cn","df1_an","df1_pg","df1_bj","df1_co","df1_iws","df1_ass","df1_aer","df1_gca","df1_gcd","df1_dcn","df1_none","df1_other"])
df1_nb_list.head()

# %%
df1_nb_list=df1_nb_list.T
df1_nb_list.head()

# %%
df1_nb_list=df1_nb_list.fillna(0)
df1_nb_list.head()

# %%
df1_nb_list.hist(sharex=False,sharey=True)

# %% [markdown]
# - As we can see that Colab notebook (Google colab) is been used more.
# - And then we have Kaggle notebooks at second place.

# %%
df1_nb_list["df1_cn"].hist()
plt.show()

# %%
df1_nb_list["df1_kn"].hist()
plt.show()

# %% [markdown]
# ## What type of computing platform do you use most often for your data science projects?
# - A personal computer or laptop
# - A deep learning workstation (NVIDIA GTX, LambdaLabs, etc)
# - A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc)
# - None
# - Other

# %%
df1["Q11"].unique()

# %% [markdown]
# - Here we can see that **"A personal computer or laptop"** is what the most you computing pltform for data science projects.

# %%
plt.figure(figsize=(8,8))
df1["Q11"].hist()
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Which types of specialized hardware do you use on a regular basis? (Select all that apply)
# - GPUs
# - TPUs
# - None
# - Othe

# %%
print("Unique value in Q12_Part_1:",df1["Q12_Part_1"].unique())
print("Unique value in Q12_Part_2:",df1["Q12_Part_2"].unique())
print("Unique value in Q12_Part_3:",df1["Q12_Part_3"].unique())
print("Unique value in Q12_OTHER :",df1["Q12_OTHER"].unique())

# %%
df1_gpu=df1["Q12_Part_1"]
df1_tpu=df1["Q12_Part_2"]
df1_none=df1["Q12_Part_3"]
df1_other=df1["Q12_OTHER"]

# %%
df1_gpu=df1_gpu.replace('GPUs',1)
df1_tpu=df1_tpu.replace('TPUs',2)
df1_none=df1_none.replace('None',3)
df1_other=df1_other.replace('Other',4)

# %%
df1_hw_list=[df1_gpu,df1_tpu,df1_none,df1_other]
df1_hw_list=pd.DataFrame(df1_hw_list,index=["df1_gpu","df1_tpu","df1_none","df1_other"])

# %%
df1_hw_list=df1_hw_list.fillna(0)

# %%
df1_hw_list=df1_hw_list.T
df1_hw_list.head()

# %%
df1_hw_list.hist()

# %% [markdown]
# - We have good number of population using **"GPUs"** .

# %%
df1_hw_list["df1_gpu"].hist()

# %% [markdown]
# - Very less population uses **"TPUs"**.

# %%
df1_hw_list["df1_tpu"].hist()

# %% [markdown]
# - And we also have some population which don't use any specialized hardware in regular basis.

# %%
df1_hw_list["df1_none"].hist()

# %%
df1_hw_list["df1_other"].hist()

# %% [markdown]
# ## Approximately how many times have you used a TPU (tensor processing unit)?
# - Never
# - Once
# - 2-5 times
# - 6-25 times
# - More than 25 times

# %%
df1["Q13"].unique()

# %% [markdown]
# - Most of the population says they have **"never"** use TPU.

# %%
df1["Q13"].hist()

# %% [markdown]
# ## What data visualization libraries or tools do you use on a regular basis?
# - Matplotlib
# - Seaborn
# - Plotly / Plotly Express
# - Ggplot / ggplot2
# - Shiny
# - D3 js
# - Altair
# - Bokeh
# - Geoplotlib
# - Leaflet / Folium
# - None
# - Other

# %%
print("Unique value in Q14_Part_1:",df1["Q14_Part_1"].unique())
print("Unique value in Q14_Part_2:",df1["Q14_Part_2"].unique())
print("Unique value in Q14_Part_3:",df1["Q14_Part_3"].unique())
print("Unique value in Q14_Part_4:",df1["Q14_Part_4"].unique())
print("Unique value in Q14_Part_5:",df1["Q14_Part_5"].unique())
print("Unique value in Q14_Part_6:",df1["Q14_Part_6"].unique())
print("Unique value in Q14_Part_7:",df1["Q14_Part_7"].unique())
print("Unique value in Q14_Part_8:",df1["Q14_Part_8"].unique())
print("Unique value in Q14_Part_9:",df1["Q14_Part_9"].unique())
print("Unique value in Q14_Part_10:",df1["Q14_Part_10"].unique())
print("Unique value in Q14_Part_11:",df1["Q14_Part_11"].unique())
print("Unique value in Q14_OTHER :",df1["Q14_OTHER"].unique())

# %%
matplot=df1["Q14_Part_1"]
seaborn=df1["Q14_Part_2"]
pltly=df1["Q14_Part_3"]
ggplot=df1["Q14_Part_4"]
shiny=df1["Q14_Part_5"]
d3js=df1["Q14_Part_6"]
altair=df1["Q14_Part_7"]
bokeh=df1["Q14_Part_8"]
geoplotlib=df1["Q14_Part_9"]
leaflet_folium=df1["Q14_Part_10"]
none=df1["Q14_Part_11"]
other=df1["Q14_OTHER"]

# %% [markdown]
# ## Replacing values
# -    Matplotlib replace as 1.
# -   Seaborn replace as 2.
# -    Plotly / Plotly Express replace as 3.
# -    Ggplot / ggplot2 replace as 4.
# -    Shiny replace as 5.
# -    D3 js replace as 6.
# -    Altair replace as 7.
# -    Bokeh replace as 8.
# -    Geoplotlib replace as 9.
# -    Leaflet / Folium replace as 10.
# -    None replace as 11.
# -    Other replace as 12.

# %%
matplot=matplot.replace(' Matplotlib ',1)
seaborn=seaborn.replace(' Seaborn ',2)
pltly=pltly.replace(' Plotly / Plotly Express ',3)
ggplot=ggplot.replace(' Ggplot / ggplot2 ',4)
shiny=shiny.replace(' Shiny ',5)
d3js=d3js.replace(' D3 js ',6)
altair=altair.replace(' Altair ',7)
bokeh=bokeh.replace(' Bokeh ',8)
geoplotlib=geoplotlib.replace(' Geoplotlib ',9)
leaflet_folium=leaflet_folium.replace(' Leaflet / Folium ',10)
none=none.replace('None',11)
other=other.replace('Other',12)

# %%
libraries_tools=[matplot,seaborn,pltly,ggplot,shiny,d3js,altair,bokeh,geoplotlib,leaflet_folium,none,other]
libraries_tools=pd.DataFrame(libraries_tools,index=["matplot","seaborn","pltly","ggplot","shiny","d3js","altair","bokeh","geoplotlib","leaflet_folium","none","other"])
#libraries_tools.head()

# %%
libraries_tools=libraries_tools.T
libraries_tools.head()

# %%
libraries_tools=libraries_tools.fillna(0)

# %%
libraries_tools.hist(sharey=True,sharex=False)

# %% [markdown]
# - The most use librariy is **"Matplotlib"**.

# %%
libraries_tools["matplot"].hist()

# %% [markdown]
# - The second most ised library is **"Seaborn"**.

# %%
libraries_tools["seaborn"].hist()

# %% [markdown]
#  ## For how many years have you used machine learning methods?
# - I do not use machine learning methods
# - Under 1 year
# - 1-2 years
# - 2-3 years
# - 3-4 years
# - 4-5 years
# - 5-10 years
# - 10-20 years
# - 20 or more years

# %%
df1["Q15"].unique()

# %%
plt.figure(figsize=(8,8))
df1["Q15"].hist(histtype="bar",ec="red")
plt.xticks(rotation=(85))
plt.show()

# %% [markdown]
# ## Which of the following machine learning frameworks do you use on a regular basis?
# - Scikit-learn
# - TensorFlow
# - Keras
# - PyTorch
# - Fast.ai
# - MXNet
# - Xgboost
# - LightGBM
# - CatBoost
# - Prophet
# - H2O 3
# - Caret
# - Tidymodels
# - JAX
# - None
# - Other

# %%
print("Unique value in Q16_Part_1:",df1["Q16_Part_1"].unique())
print("Unique value in Q16_Part_2:",df1["Q16_Part_2"].unique())
print("Unique value in Q16_Part_3:",df1["Q16_Part_3"].unique())
print("Unique value in Q16_Part_4:",df1["Q16_Part_4"].unique())
print("Unique value in Q16_Part_5:",df1["Q16_Part_5"].unique())
print("Unique value in Q16_Part_6:",df1["Q16_Part_6"].unique())
print("Unique value in Q16_Part_7:",df1["Q16_Part_7"].unique())
print("Unique value in Q16_Part_8:",df1["Q16_Part_8"].unique())
print("Unique value in Q16_Part_9:",df1["Q16_Part_9"].unique())
print("Unique value in Q16_Part_10:",df1["Q16_Part_10"].unique())
print("Unique value in Q16_Part_11:",df1["Q16_Part_11"].unique())
print("Unique value in Q16_Part_12:",df1["Q16_Part_12"].unique())
print("Unique value in Q16_Part_13:",df1["Q16_Part_13"].unique())
print("Unique value in Q16_Part_14:",df1["Q16_Part_14"].unique())
print("Unique value in Q16_Part_15:",df1["Q16_Part_15"].unique())
print("Unique value in Q16_OTHER :",df1["Q16_OTHER"].unique())

# %%
scikitlearn=df1["Q16_Part_1"]
tensor=df1["Q16_Part_2"]
keras=df1["Q16_Part_3"]
pytorch=df1["Q16_Part_4"]
fastai=df1["Q16_Part_5"]
mxnet=df1["Q16_Part_6"]
xgboost=df1["Q16_Part_7"]
lightgbm=df1["Q16_Part_8"]
catboost=df1["Q16_Part_9"]
prophet=df1["Q16_Part_10"]
h2o3=df1["Q16_Part_11"]
caret=df1["Q16_Part_12"]
tidymodel=df1["Q16_Part_13"]
jax=df1["Q16_Part_14"]
none=df1["Q16_Part_15"]
other=df1["Q16_OTHER"]

# %%
scikitlearn=scikitlearn.replace('  Scikit-learn ',1)
tensor=tensor.replace('  TensorFlow ',2)
keras=keras.replace(' Keras ',3)
pytorch=pytorch.replace(' PyTorch ',4)
fastai=fastai.replace(' Fast.ai ',5)
mxnet=mxnet.replace(' MXNet ',6)
xgboost=xgboost.replace(' Xgboost ',7)
lightgbm=lightgbm.replace(' LightGBM ',8)
catboost=catboost.replace(' CatBoost ',9)
prophet=prophet.replace(' Prophet ',10)
h2o3=h2o3.replace(' H2O 3 ',11)
caret=caret.replace(' Caret ',12)
tidymodel=tidymodel.replace(' Tidymodels ',13)
jax=jax.replace(' JAX ',14)
none=none.replace('None',15)
other=other.replace('Other',16)

# %%
mlframework=[scikitlearn,tensor,keras,pytorch,fastai,mxnet,xgboost,lightgbm,catboost,prophet,h2o3,caret,tidymodel,jax,none,other]
mlframework=pd.DataFrame(mlframework,index=["scikitlearn","tensor","keras","pytorch","fastai","maxnet","xgboost","lightgbm","catboost","prophet","h2o3","caret","tidymodel","jax","none","other"])
#mlframework.head()

# %%
mlframework=mlframework.T
mlframework=mlframework.fillna(0)
mlframework.head()

# %%
mlframework.hist(sharey=True,sharex=False)

# %% [markdown]
# - The most machine learning framework is **"scikit-learn"**.

# %%
plt.figure()
plt.xlabel("scikit-learn")
mlframework["scikitlearn"].hist()
plt.show()

# %% [markdown]
# - The **"second"** most machine learning framework is **"Tensorflow"**.

# %%
plt.figure()
plt.xlabel("Tensorflow")
mlframework["tensor"].hist()
plt.show()

# %% [markdown]
# - The **"Third"** most machine learning framework is  **"Keras"**.

# %%
plt.figure()
plt.xlabel("Keras")
mlframework["keras"].hist()
plt.show()

# %% [markdown]
# - The **"fourth"** most machine learning framework is **"PyTorch"**.

# %%
plt.figure()
plt.xlabel("PyTorch")
mlframework["pytorch"].hist()
plt.show()

# %% [markdown]
# - The **"fifth"** most machine learning framework is **"XgBoost"**.

# %%
plt.figure()
mlframework["xgboost"].hist()
plt.xlabel("XgBoost")
plt.show()

# %% [markdown]
# ## Which of the following ML algorithms do you use on a regular basis?
# - Linear or Logistic Regression
# - Decision Trees or Random Forests
# - Gradient Boosting Machines (xgboost, lightgbm, etc)
# - Bayesian Approaches
# - Evolutionary Approaches
# - Dense Neural Networks (MLPs, etc)
# - Convolutional Neural Networks
# - Generative Adversarial Networks
# - Recurrent Neural Networks
# - Transformer Networks (BERT, gpt-3, etc)
# - None
# - Other

# %%
print("Unique value in Q17_Part_1:",df1["Q17_Part_1"].unique())
print("Unique value in Q17_Part_2:",df1["Q17_Part_2"].unique())
print("Unique value in Q17_Part_3:",df1["Q17_Part_3"].unique())
print("Unique value in Q17_Part_4:",df1["Q17_Part_4"].unique())
print("Unique value in Q17_Part_5:",df1["Q17_Part_5"].unique())
print("Unique value in Q17_Part_6:",df1["Q17_Part_6"].unique())
print("Unique value in Q17_Part_7:",df1["Q17_Part_7"].unique())
print("Unique value in Q17_Part_8:",df1["Q17_Part_8"].unique())
print("Unique value in Q17_Part_9:",df1["Q17_Part_9"].unique())
print("Unique value in Q17_Part_10:",df1["Q17_Part_10"].unique())
print("Unique value in Q17_Part_11:",df1["Q17_Part_11"].unique())
print("Unique value in Q17_OTHER :",df1["Q17_OTHER"].unique())

# %%
llregression=df1["Q17_Part_1"]
dt_rm=df1["Q17_Part_2"]
gradient_bm=df1["Q17_Part_3"]
bayesian_app=df1["Q17_Part_4"]
evoluton_app=df1["Q17_Part_5"]
dense_nn=df1["Q17_Part_6"]
convolution_nn=df1["Q17_Part_7"]
genrative_an=df1["Q17_Part_8"]
recurrent_nn=df1["Q17_Part_9"]
transformer_n=df1["Q17_Part_10"]
none=df1["Q17_Part_11"]
other=df1["Q17_OTHER"]

# %% [markdown]
# ## Replacing values
#
# -    Linear or Logistic Regression as 1.
# -    Decision Trees or Random Forests as 2.
# -    Gradient Boosting Machines (xgboost, lightgbm, etc) as 3.
# -    Bayesian Approaches as 4.
# -    Evolutionary Approaches as 5.
# -    Dense Neural Networks (MLPs, etc) as 6.
# -    Convolutional Neural Networks as 7.
# -    Generative Adversarial Networks as 8.
# -    Recurrent Neural Networks as 9.
# -    Transformer Networks (BERT, gpt-3, etc) as 10.
# -    None as 11.
# -    Other as 12.

# %%
llregression=llregression.replace('Linear or Logistic Regression',1)
dt_rm=dt_rm.replace('Decision Trees or Random Forests',2)
gradient_bm=gradient_bm.replace('Gradient Boosting Machines (xgboost, lightgbm, etc)',3)
bayesian_app=bayesian_app.replace('Bayesian Approaches',4)
evolution_app=evoluton_app.replace('Evolutionary Approaches',5)
dense_nn=dense_nn.replace('Dense Neural Networks (MLPs, etc)',6)
convolution_nn=convolution_nn.replace('Convolutional Neural Networks',7)
genrative_an=genrative_an.replace('Generative Adversarial Networks',8)
recurrent_nn=recurrent_nn.replace('Recurrent Neural Networks',9)
transformer_n=transformer_n.replace('Transformer Networks (BERT, gpt-3, etc)',10)
none=none.replace('None',11)
other=other.replace('Other',12)

# %%
mlalgorithm=[llregression,dt_rm,gradient_bm,bayesian_app,evolution_app,dense_nn,convolution_nn,genrative_an,recurrent_nn,transformer_n,none,other]
mlalgorithm=pd.DataFrame(mlalgorithm,index=["llregression","dt_rm","gradient_bm","bayesian_app","evolution_app","dense_nn","convolution_nn","genrative_an","recurrent_nn","transformer_n","none","other"])
#mlalgorithm.head()

# %%
mlalgorithm=mlalgorithm.fillna(0)
mlalgorithm=mlalgorithm.T
mlalgorithm.head()

# %%
mlalgorithm.hist(sharey=True,sharex=False)

# %% [markdown]
# - At the **"first"** number we have **"Linear or Logistic Regression"**.

# %%
plt.figure()
plt.xlabel("Linear or Logistic Regression")
mlalgorithm["llregression"].hist()
plt.show()

# %% [markdown]
# - At **"second"** we have **"Decision Trees or Random Forests"**.

# %%
plt.figure()
plt.xlabel("Decision Trees or Random Forests")
mlalgorithm["dt_rm"].hist()
plt.show()

# %% [markdown]
# - At **"third"** we have **"Convolutional Neural Networks"**.

# %%
plt.figure()
mlalgorithm["convolution_nn"].hist()
plt.xlabel("Convolutional Neural Networks")
plt.show()

# %% [markdown]
# - At **fourth** we have **"Gradient Boosting Machines (xgboost, lightgbm, etc)"**.

# %%
plt.figure()
plt.xlabel("Gradient Boosting Machines (xgboost, lightgbm, etc)")
mlalgorithm["gradient_bm"].hist()
plt.show()

# %% [markdown]
# - At **"fifth"** we have **"Bayesian Approaches"**.

# %%
plt.figure()
plt.xlabel("Bayesian Approaches")
mlalgorithm["bayesian_app"].hist()
plt.show()

# %% [markdown]
# ## Which categories of computer vision methods do you use on a regular basis?
# - General purpose image/video tools (PIL, cv2, skimage, etc)
# - Image segmentation methods (U-Net, Mask R-CNN, etc)
# - Object detection methods (YOLOv3, RetinaNet, etc)
# - Image classification and other general purpose networks (VGG, Inception, ResNet,ResNeXt, NASNet, EfficientNet, etc)
# - Generative Networks (GAN, VAE, etc)
# - None
# - Other

# %%
print("Unique value in Q18_Part_1:",df1["Q18_Part_1"].unique())
print("Unique value in Q18_Part_2:",df1["Q18_Part_2"].unique())
print("Unique value in Q18_Part_3:",df1["Q18_Part_3"].unique())
print("Unique value in Q18_Part_4:",df1["Q18_Part_4"].unique())
print("Unique value in Q18_Part_5:",df1["Q18_Part_5"].unique())
print("Unique value in Q18_Part_6:",df1["Q18_Part_6"].unique())
print("Unique value in Q18_OTHER :",df1["Q18_OTHER"].unique())

# %%
general_purpose=df1["Q18_Part_1"]
imag_segmentation=df1["Q18_Part_2"]
object_detection=df1["Q18_Part_3"]
image_classification=df1["Q18_Part_4"]
generative_network=df1["Q18_Part_5"]
none=df1["Q18_Part_6"]
other=df1["Q18_OTHER"]

# %% [markdown]
# ## Replacing values
# - General purpose image/video tools (PIL, cv2, skimage, etc) as 1.
# - Image segmentation methods (U-Net, Mask R-CNN, etc) as 2.
# - Object detection methods (YOLOv3, RetinaNet, etc) as 3.
# - Image classification and other general purpose networks (VGG, Inception, ResNet,ResNeXt, NASNet, EfficientNet, etc) as 4.
# - Generative Networks (GAN, VAE, etc) as 5.
# - None as 6.
# - Other as 7.

# %%
general_purpose=general_purpose.replace('General purpose image/video tools (PIL, cv2, skimage, etc)',1)
imag_segmentation=imag_segmentation.replace('Image segmentation methods (U-Net, Mask R-CNN, etc)',2)
object_detection=object_detection.replace('Object detection methods (YOLOv3, RetinaNet, etc)',3)
image_classification=image_classification.replace('Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc)',4)
generative_network=generative_network.replace('Generative Networks (GAN, VAE, etc)',5)
none=none.replace('None',6)
other=other.replace('Other',7)

# %%
cv_methods=[general_purpose,imag_segmentation,object_detection,image_classification,generative_network,none,other]
cv_methods=pd.DataFrame(cv_methods,index=["general_purpose","imag_segmentation","object_detection","image_classification","generative_network","none","other"])
cv_methods=cv_methods.fillna(0)
cv_methods.head()

# %%
cv_methods=cv_methods.T
cv_methods.head()

# %%
cv_methods.hist(sharey=True,sharex=False)

# %% [markdown]
# -  Most of the  population uses **"Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc)"** compuert vision method.

# %%
plt.figure()
plt.xlabel("image_classification")
cv_methods["image_classification"].hist()
plt.show()

# %%
plt.figure()
cv_methods["general_purpose"].hist()
plt.xlabel("General purpose image/video tools (PIL, cv2, skimage, etc)")
plt.show()

# %%
plt.figure()
plt.xlabel("Image segmentation methods (U-Net, Mask R-CNN, etc)")
cv_methods["imag_segmentation"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel("Object detection methods (YOLOv3, RetinaNet, etc)")
cv_methods["object_detection"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel("Generative Networks (GAN, VAE, etc)")
cv_methods["generative_network"].hist()
plt.show()

# %% [markdown]
# ## Which of the following natural language processing (NLP) methods do you use on a regular basis?
# - Word embeddings/vectors (GLoVe, fastText, word2vec)
# - Encoder-decoder models (seq2seq, vanilla transformers)
# - Contextualized embeddings (ELMo, CoVe)
# - Transformer language models (GPT-3, BERT, XLnet, etc)
# - None
# - Other

# %%
print("Unique value in Q19_Part_1:",df1["Q19_Part_1"].unique())
print("Unique value in Q19_Part_2:",df1["Q19_Part_2"].unique())
print("Unique value in Q19_Part_3:",df1["Q19_Part_3"].unique())
print("Unique value in Q19_Part_4:",df1["Q19_Part_4"].unique())
print("Unique value in Q19_Part_5:",df1["Q19_Part_5"].unique())
print("Unique value in Q19_OTHER :",df1["Q19_OTHER"].unique())

# %%
word_embedding=df1["Q19_Part_1"]
encoder_decoder=df1["Q19_Part_2"]
contextual_em=df1["Q19_Part_3"]
transform_lan=df1["Q19_Part_4"]
none=df1["Q19_Part_5"]
other=df1["Q19_OTHER"]

# %% [markdown]
# ## Replacing values
#
# -    Word embeddings/vectors (GLoVe, fastText, word2vec) as 1.
# -    Encoder-decoder models (seq2seq, vanilla transformers) as 2.
# -    Contextualized embeddings (ELMo, CoVe) as 3.
# -    Transformer language models (GPT-3, BERT, XLnet, etc) as 4.
# -    None as 5.
# -    Other as 6.

# %%
word_embedding=word_embedding.replace('Word embeddings/vectors (GLoVe, fastText, word2vec)',1)
encoder_decoder=encoder_decoder.replace('Encoder-decorder models (seq2seq, vanilla transformers)',2)
contextual_em=contextual_em.replace('Contextualized embeddings (ELMo, CoVe)',3)
transform_lan=transform_lan.replace('Transformer language models (GPT-3, BERT, XLnet, etc)',4)
none=none.replace('None',5)
other=other.replace('Other',6)

# %%
nlp_methods=[word_embedding,encoder_decoder,contextual_em,transform_lan,none,other]
nlp_methods=pd.DataFrame(nlp_methods,index=["word_embedding","encoder_decoder","contextual_em","transform_lan","none","other"])
nlp_methods=nlp_methods.fillna(0)
nlp_methods=nlp_methods.T
nlp_methods.head()

# %%
nlp_methods.hist(sharey=True,sharex=False)

# %% [markdown]
# - Most used NLP method is **"Word embeddings/vectors (GLoVe, fastText, word2vec)"**.

# %%
plt.figure()
plt.xlabel('Word embeddings/vectors (GLoVe, fastText, word2vec)')
nlp_methods["word_embedding"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel('Encoder-decorder models (seq2seq, vanilla transformers)')
nlp_methods["encoder_decoder"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel('Transformer language models (GPT-3, BERT, XLnet, etc)')
nlp_methods["transform_lan"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel('Contextualized embeddings (ELMo, CoVe)')
nlp_methods["contextual_em"].hist()
plt.show()

# %% [markdown]
# ## What is the size of the company where you are employed?
# - 0-49 employees
# - 50-249 employees
# - 250-999 employees
# - 1000-9,999 employees
# - 10,000 or more employees

# %%
df1["Q20"].unique()

# %% [markdown]
# - The major size of company **"0-49 employee"**.

# %%
plt.figure()
plt.xticks(rotation=85)
df1["Q20"].hist(histtype="bar",ec="red",grid=False)
plt.show()

# %% [markdown]
# ## Approximately how many individuals are responsible for data science workloads at your place of business?
# - 0
# - 1-2
# - 3-4
# - 5-9
# - 10-14
# - 15-19
# - 20+

# %%
df["Q21"].unique()

# %% [markdown]
# - People responsible for data science workload in particular company is **"1-2"**.

# %%
plt.figure()
plt.xticks(rotation=85)
df1["Q21"].hist(histtype="bar",ec="red",grid=False)
plt.show()

# %% [markdown]
# ## Does your current employer incorporate machine learning methods into their business?
# - We are exploring ML methods (and may one day put a model into production)
# - We use ML methods for generating insights (but do not put working models into production)
# - We recently started using ML methods (i.e., models in production for less than 2 years)
# - We have well established ML methods (i.e., models in production for more than 2 years)
# - No (we do not use ML methods)
# - I do not know

# %% [markdown]
# - The more number of goes to **"We are exploring ML methods"**.

# %%
df1["Q22"].unique()

# %%
plt.figure()
plt.xticks(rotation=85)
df1["Q22"].hist(histtype="bar",ec="red",grid=False)
plt.show()

# %% [markdown]
# ## Select any activities that make up an important part of your role at work?
# - Analyze and understand data to influence product or business decisions
# - Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data
# - Build prototypes to explore applying machine learning to new areas
# - Build and/or run a machine learning service that operationally improves my product orworkflows
# - Experimentation and iteration to improve existing ML models
# - Do research that advances the state of the art of machine learning
# - None of these activities are an important part of my role at work
# - Other

# %%
print("Unique value in Q23_Part_1:",df1["Q23_Part_1"].unique())
print("Unique value in Q23_Part_2:",df1["Q23_Part_2"].unique())
print("Unique value in Q23_Part_3:",df1["Q23_Part_3"].unique())
print("Unique value in Q23_Part_4:",df1["Q23_Part_4"].unique())
print("Unique value in Q23_Part_5:",df1["Q23_Part_5"].unique())
print("Unique value in Q23_Part_6:",df1["Q23_Part_6"].unique())
print("Unique value in Q23_Part_7:",df1["Q23_Part_7"].unique())
print("Unique value in Q23_OTHER :",df1["Q23_OTHER"].unique())

# %%
analyze_understnd=df1["Q23_Part_1"]
br_datainfa=df1["Q23_Part_2"]
br_prototype=df1["Q23_Part_3"]
br_ml=df1["Q23_Part_4"]
exp_iter=df1["Q23_Part_5"]
research=df1["Q23_Part_6"]
none=df1["Q23_Part_7"]
other=df1["Q23_OTHER"]

# %%
analyze_understnd=analyze_understnd.replace('Analyze and understand data to influence product or business decisions',1)
br_datainfa=br_datainfa.replace('Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data',2)
br_prototype=br_prototype.replace('Build prototypes to explore applying machine learning to new areas',3)
br_ml=br_ml.replace('Build and/or run a machine learning service that operationally improves my product or workflows',4)
exp_iter=exp_iter.replace('Experimentation and iteration to improve existing ML models',5)
research=research.replace('Do research that advances the state of the art of machine learning',6)
none=none.replace('None of these activities are an important part of my role at work',7)
other=other.replace('Other',8)

# %%
imp_list=[analyze_understnd,br_datainfa,br_prototype,br_ml,exp_iter,research,none,other]
imp_list=pd.DataFrame(imp_list,index=["analyze_understnd","br_datainfa","br_prototype","br_ml","exp_iter","research","none","other"])

# %%
imp_list=imp_list.T
imp_list=imp_list.fillna(0)
imp_list.head()

# %%
imp_list.hist(sharey=True)

# %% [markdown]
# - Important part of your role at work is **"Analyze and understand data to influence product or business decisions"**

# %%
plt.figure()
plt.xlabel('Analyze and understand data to influence product or business decisions')
imp_list["analyze_understnd"].hist()
plt.show()

# %% [markdown]
# - **'Build prototypes to explore applying machine learning to new areas'**

# %%
plt.figure()
plt.xlabel('Build prototypes to explore applying machine learning to new areas')
imp_list["br_prototype"].hist()
plt.show()

# %% [markdown]
# - **'Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data'**

# %%
plt.figure()
plt.xlabel('Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data')
imp_list["br_datainfa"].hist()
plt.show()

# %% [markdown]
# - **'Experimentation and iteration to improve existing ML models'**

# %%
plt.figure()
plt.xlabel('Experimentation and iteration to improve existing ML models')
imp_list["exp_iter"].hist()
plt.show()

# %% [markdown]
# - **'Build and/or run a machine learning service that operationally improves my product or workflows'**

# %%
plt.figure()
plt.xlabel('Build and/or run a machine learning service that operationally improves my product or workflows')
imp_list["br_ml"].hist()
plt.show()

# %% [markdown]
# ## What is your current yearly compensation (approximate $USD)?

# %%
df1["Q24"].unique()

# %% [markdown]
# - **1,000-1,999** is the highest yearly compensation.

# %%
plt.figure()
plt.xticks(rotation=85)
df1["Q24"].hist(histtype="bar",ec="red",grid=False)
plt.show()

# %% [markdown]
# ## Approximately how much money have you (or your team) spent on machine learning and/or cloudcomputing services at home (or at work) in the past 5 years (approximate $USD)?

# %% [markdown]
# -  $0 ($USD)
# -  $1-$99
# -  $100-$999
# -  $1000-$9,999
# -  $10,000-$99,999
# -  $100,000 or more ($USD)

# %%
df1["Q25"].unique()

# %% [markdown]
# - Most of the population had spent **"0USD"** on ML or cloud services.

# %%
plt.figure()
plt.xticks(rotation=80)
df1["Q25"].hist(histtype="bar",ec="red",grid=False)
plt.show()

# %% [markdown]
# ## Which of the following cloud computing platforms do you use on a regular basis?
# - Amazon Web Services (AWS)
# - Microsoft Azure
# - Google Cloud Platform (GCP)
# - IBM Cloud / Red Hat
# - Oracle Cloud
# - SAP Cloud
# - Salesforce Cloud
# - VMware Cloud
# - Alibaba Cloud
# - Tencent Cloud
# - None
# - Other

# %%
print("Unique value in Q26_A_Part_1:",df1["Q26_A_Part_1"].unique())
print("Unique value in Q26_A_Part_2:",df1["Q26_A_Part_2"].unique())
print("Unique value in Q26_A_Part_3:",df1["Q26_A_Part_3"].unique())
print("Unique value in Q26_A_Part_4:",df1["Q26_A_Part_4"].unique())
print("Unique value in Q26_A_Part_5:",df1["Q26_A_Part_5"].unique())
print("Unique value in Q26_A_Part_6:",df1["Q26_A_Part_6"].unique())
print("Unique value in Q26_A_Part_7:",df1["Q26_A_Part_7"].unique())
print("Unique value in Q26_A_Part_8:",df1["Q26_A_Part_8"].unique())
print("Unique value in Q26_A_Part_9:",df1["Q26_A_Part_9"].unique())
print("Unique value in Q26_A_Part_10:",df1["Q26_A_Part_10"].unique())
print("Unique value in Q26_A_Part_11:",df1["Q26_A_Part_11"].unique())
print("Unique value in Q26_A_OTHER :",df1["Q26_A_OTHER"].unique())

# %%
aws=df1["Q26_A_Part_1"]
azure=df1["Q26_A_Part_2"]
gcp=df1["Q26_A_Part_3"]
ibm_cloud=df1["Q26_A_Part_4"]
oracle=df1["Q26_A_Part_5"]
sap=df1["Q26_A_Part_6"]
salesforce=df1["Q26_A_Part_7"]
vmware=df1["Q26_A_Part_8"]
alibaba=df1["Q26_A_Part_9"]
tencent=df1["Q26_A_Part_10"]
none=df1["Q26_A_Part_11"]
other=df1["Q26_A_OTHER"]

# %%
aws=aws.replace(' Amazon Web Services (AWS) ',1)
azure=azure.replace(' Microsoft Azure ',2)
gcp=gcp.replace(' Google Cloud Platform (GCP) ',3)
inm_cloud=ibm_cloud.replace(' IBM Cloud / Red Hat ',4)
oracle=oracle.replace(' Oracle Cloud ',5)
sap=sap.replace(' SAP Cloud ',6)
salesforce=salesforce.replace(' Salesforce Cloud ',7)
vnware=vmware.replace(' VMware Cloud ',8)
alibaba=alibaba.replace(' Alibaba Cloud ',9)
tencent=tencent.replace(' Tencent Cloud ',10)
none=none.replace('None',11)
other=other.replace('Other',12)

# %%
ccp=[aws,azure,gcp,ibm_cloud,oracle,sap,salesforce,vmware,alibaba,tencent,none,other]
ccp=pd.DataFrame(ccp,index=["aws","azure","gcp","ibm_cloud","oracle","sap","salesforce","vmware","alibaba","tencent","none","other"])
ccp=ccp.T
ccp=ccp.fillna(0)

# %%
ccp.head()

# %%
ccp.hist(sharey=True)

# %% [markdown]
# - The most used cloud computing platform is **Amazon Web Services (AWS)**.

# %%
plt.figure()
plt.xlabel(' Amazon Web Services (AWS) ')
ccp["aws"].hist(histtype="bar",ec="red")
plt.show()

# %%
plt.figure()
plt.xlabel(' Google Cloud Platform (GCP) ')
ccp["gcp"].hist(histtype="bar",ec="red")
plt.show()

# %%
plt.figure()
plt.xlabel(' Microsoft Azure ')
ccp["azure"].hist(histtype="bar",ec="red")
##plt.show()

# %% [markdown]
# ## Do you use any of the following cloud computing products on a regular basis?
# - Amazon EC2
# - AWS Lambda
# - Amazon Elastic Container Service
# - Azure Cloud Services
# - Microsoft Azure Container Instances
# - Azure Functions
# - Google Cloud Compute Engine
# - Google Cloud Functions
# - Google Cloud Run
# - Google Cloud App Engine
# - No / None
# - Other

# %%
print("Unique value in Q27_A_Part_1:",df1["Q27_A_Part_1"].unique())
print("Unique value in Q27_A_Part_2:",df1["Q27_A_Part_2"].unique())
print("Unique value in Q27_A_Part_3:",df1["Q27_A_Part_3"].unique())
print("Unique value in Q27_A_Part_4:",df1["Q27_A_Part_4"].unique())
print("Unique value in Q27_A_Part_5:",df1["Q27_A_Part_5"].unique())
print("Unique value in Q27_A_Part_6:",df1["Q27_A_Part_6"].unique())
print("Unique value in Q27_A_Part_7:",df1["Q27_A_Part_7"].unique())
print("Unique value in Q27_A_Part_8:",df1["Q27_A_Part_8"].unique())
print("Unique value in Q27_A_Part_9:",df1["Q27_A_Part_9"].unique())
print("Unique value in Q27_A_Part_10:",df1["Q27_A_Part_10"].unique())
print("Unique value in Q27_A_Part_11:",df1["Q27_A_Part_11"].unique())
print("Unique value in Q27_A_OTHER :",df1["Q27_A_OTHER"].unique())

# %%
amazone2c=df1["Q27_A_Part_1"].replace(' Amazon EC2 ',1)
awsl=df1["Q27_A_Part_2"].replace(' AWS Lambda ',2)
amazonecs=df1["Q27_A_Part_3"].replace(' Amazon Elastic Container Service ',3)
azure_service=df1["Q27_A_Part_4"].replace(' Azure Cloud Services ',4)
micro_azure=df1["Q27_A_Part_5"].replace(' Microsoft Azure Container Instances ',5)
azure_fun=df1["Q27_A_Part_6"].replace(' Azure Functions ',6)
gcce=df1["Q27_A_Part_7"].replace(' Google Cloud Compute Engine ',7)
gcf=df1["Q27_A_Part_8"].replace(' Google Cloud Functions ',8)
gcr=df1["Q27_A_Part_9"].replace(' Google Cloud Run ',9)
gcae=df1["Q27_A_Part_10"].replace(' Google Cloud App Engine ',10)
none=df1["Q27_A_Part_11"].replace('No / None',11)
other=df1["Q27_A_OTHER"].replace('Other',12)

# %%
cc_products=[amazone2c,awsl,amazonecs,azure_service,micro_azure,azure_fun,gcce,gcf,gcr,gcae,none,other]
cc_products=pd.DataFrame(cc_products,index=["amazone2c","awsl","amazonecs","azure_service","micro_azure","azure_fun","gcce","gcf","gcr","gcae","none","other"])
cc_products=cc_products.fillna(0)
cc_products=cc_products.T
cc_products.head()

# %%
cc_products.hist(sharey=True)

# %%
plt.figure()
plt.xlabel(' Amazon EC2 ')
cc_products["amazone2c"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' AWS Lambda ')
cc_products["awsl"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Amazon Elastic Container Service ')
cc_products["amazonecs"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Azure Cloud Services ')
cc_products["azure_service"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Microsoft Azure Container Instances ')
cc_products["micro_azure"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Azure Functions ')
cc_products["azure_fun"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Google Cloud Compute Engine ')
cc_products["gcce"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Google Cloud Functions ')
cc_products["gcf"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Google Cloud Run ')
cc_products["gcr"].hist()
plt.show()

# %%
plt.figure()
plt.xlabel(' Google Cloud App Engine ')
cc_products["gcae"].hist()
plt.show()

# %% [markdown]
# ## Do you use any of the following machine learning products on a regular basis?
#
# - Amazon SageMaker
# - Amazon Forecast
# - Amazon Rekognition
# - Azure Machine Learning Studio
# - Azure Cognitive Services
# - Google Cloud AI Platform / Google Cloud ML Engine
# - Google Cloud Video AI
# - Google Cloud Natural Language
# - Google Cloud Vision AI
# - No / None
# - Other

# %%
print("Unique value in Q28_A_Part_1:",df1["Q28_A_Part_1"].unique())
print("Unique value in Q28_A_Part_2:",df1["Q28_A_Part_2"].unique())
print("Unique value in Q28_A_Part_3:",df1["Q28_A_Part_3"].unique())
print("Unique value in Q28_A_Part_4:",df1["Q28_A_Part_4"].unique())
print("Unique value in Q28_A_Part_5:",df1["Q28_A_Part_5"].unique())
print("Unique value in Q28_A_Part_6:",df1["Q28_A_Part_6"].unique())
print("Unique value in Q28_A_Part_7:",df1["Q28_A_Part_7"].unique())
print("Unique value in Q28_A_Part_8:",df1["Q28_A_Part_8"].unique())
print("Unique value in Q28_A_OTHER :",df1["Q28_A_OTHER"].unique())

# %%
amazon_sm=df1["Q28_A_Part_1"].replace(' Amazon SageMaker ',1)
amazon_for=df1["Q28_A_Part_2"].replace(' Amazon Forecast ',2)
amazon_rek=df1["Q28_A_Part_3"].replace(' Amazon Rekognition ',3)
azuremls=df1["Q28_A_Part_4"].replace(' Azure Machine Learning Studio ',4)
azurecs=df1["Q28_A_Part_5"].replace(' Azure Cognitive Services ',5)
googleaiml=df1["Q28_A_Part_6"].replace(' Google Cloud AI Platform / Google Cloud ML Engine',6)
googleai=df1["Q28_A_Part_7"].replace(' Google Cloud Video AI ',7)
googlecnl=df1["Q28_A_Part_8"].replace(' Google Cloud Natural Language ',8)
other=df1["Q28_A_OTHER"].replace('Other',9)

# %%
ml_products=[amazon_sm,amazon_for,amazon_rek,azuremls,azurecs,googleaiml,googleai,googlecnl,other]
ml_products=pd.DataFrame(ml_products,index=["amazon_sm","amazon_for","amazon_rek","azuremls","azurecs","googleaiml","googleai","googlecnl","other"])
ml_products=ml_products.fillna(0)
ml_products=ml_products.T
ml_products.head()

# %%
a=ml_products["amazon_sm"]
b=ml_products["amazon_for"]
c=ml_products["amazon_rek"]
d=ml_products["azuremls"]
e=ml_products["azurecs"]
f=ml_products["googleaiml"]
g=ml_products["googleai"]
h=ml_products["googlecnl"]
o=ml_products["other"]

# %% [markdown]
# ### Machine learning products on a regular basis

# %%
plt.figure()
fig,axs  = plt.subplots(2,4)
plt.subplots_adjust(left=0,right=2,bottom=2,top=3,wspace=0.2,hspace=0.4)
#fig.suptitle("machine learning products")
axs[0,0].set_title(' Amazon SageMaker ')
axs[0,0].hist(a)

axs[0,1].set_title(' Amazon Forecast ')
axs[0,1].hist(b)
axs[1,0].set_title(' Amazon Rekognition ')
axs[1,0].hist(c)
axs[1,1].set_title(' Azure Machine Learning Studio ')
axs[1,1].hist(d)
axs[0,2].set_title(' Azure Cognitive Services ')
axs[0,2].hist(e)
axs[1,2].set_title(' Google Cloud AI Platform')
axs[1,2].hist(f)
axs[0,3].set_title(' Google Cloud Video AI ')
axs[0,3].hist(g)
axs[1,3].set_title('Other')
axs[1,3].hist(h)

# %% [markdown]
# ## Which of the following big data products (relational databases, data warehouses, data lakes, orsimilar) do you use on a regular basis?
# - MySQL
# - PostgreSQL
# - SQLite
# - Oracle Database
# - MongoDB
# - Snowflake
# - IBM Db2
# - Microsoft SQL Server
# - Microsoft Access
# - Microsoft Azure Data Lake Storage
# - Amazon Redshift
# - Amazon Athena
# - Amazon DynamoDB
# - Google Cloud BigQuery
# - Google Cloud SQL
# - Google Cloud Firestore
# - None
# - Other

# %%
print("Unique value in Q29_A_Part_1:",df1["Q29_A_Part_1"].unique())
print("Unique value in Q29_A_Part_2:",df1["Q29_A_Part_2"].unique())
print("Unique value in Q29_A_Part_3:",df1["Q29_A_Part_3"].unique())
print("Unique value in Q29_A_Part_4:",df1["Q29_A_Part_4"].unique())
print("Unique value in Q29_A_Part_5:",df1["Q29_A_Part_5"].unique())
print("Unique value in Q29_A_Part_6:",df1["Q29_A_Part_6"].unique())
print("Unique value in Q29_A_Part_7:",df1["Q29_A_Part_7"].unique())
print("Unique value in Q29_A_Part_8:",df1["Q29_A_Part_8"].unique())
print("Unique value in Q29_A_Part_9:",df1["Q29_A_Part_9"].unique())
print("Unique value in Q29_A_Part_10:",df1["Q29_A_Part_10"].unique())
print("Unique value in Q29_A_Part_11:",df1["Q29_A_Part_11"].unique())
print("Unique value in Q29_A_Part_12:",df1["Q29_A_Part_12"].unique())
print("Unique value in Q29_A_Part_13:",df1["Q29_A_Part_13"].unique())
print("Unique value in Q29_A_Part_14:",df1["Q29_A_Part_14"].unique())
print("Unique value in Q29_A_Part_15:",df1["Q29_A_Part_15"].unique())
print("Unique value in Q29_A_Part_16:",df1["Q29_A_Part_16"].unique())
print("Unique value in Q29_A_Part_17:",df1["Q29_A_Part_17"].unique())
print("Unique value in Q29_A_OTHER :",df1["Q29_A_OTHER"].unique())

# %%
mysql=df1["Q29_A_Part_1"].replace('MySQL ',1)
postgresssql=df1["Q29_A_Part_2"].replace('PostgresSQL ',2)
sqlite=df1["Q29_A_Part_3"].replace('SQLite ',3)
oracle=df1["Q29_A_Part_4"].replace('Oracle Database ',4)
mongodb=df1["Q29_A_Part_5"].replace('MongoDB ',5)
snowflake=df1["Q29_A_Part_6"].replace('Snowflake ',6)
ibm=df1["Q29_A_Part_7"].replace('IBM Db2 ',7)

msqlserver=df1["Q29_A_Part_8"].replace('Microsoft SQL Server ',8)

msacess=df1["Q29_A_Part_9"].replace('Microsoft Access ',9)

mazuredatalake=df1["Q29_A_Part_10"].replace('Microsoft Azure Data Lake Storage ',10)

aredshift=df1["Q29_A_Part_11"].replace('Amazon Redshift ',11)

aathena=df1["Q29_A_Part_12"].replace('Amazon Athena ',12)

adynamodb=df1["Q29_A_Part_13"].replace('Amazon DynamoDB ',13)

gcloudbigquery=df1["Q29_A_Part_14"].replace('Google Cloud BigQuery ',14)
gcloudsql=df1["Q29_A_Part_15"].replace('Google Cloud SQL ',15)
gcloudfirestore=df1["Q29_A_Part_16"].replace('Google Cloud Firestore ',16)
none=df1["Q29_A_Part_17"].replace('None',17)
other=df1["Q29_A_OTHER"].replace('Other',18)

# %%
bd_products=[mysql,postgresssql,sqlite,oracle,mongodb,snowflake,ibm,msqlserver,msacess,mazuredatalake,aredshift,aathena,adynamodb,gcloudbigquery,gcloudsql,gcloudfirestore,none,other]
bd_products=pd.DataFrame(bd_products,index=["mysql","postgresssql","sqlite","oracle","mongodb","snowflake","ibm","msqlserver","msacess","mazuredatalake","aredshift","aathena","adynamodb","gcloudbigquery","gcloudsql","gcloudfirestore","none","other"])
bd_products=bd_products.T
bd_products=bd_products.fillna(0)
bd_products.head()

# %%
bd_products.hist(sharey=True)

# %%
mysql=bd_products["mysql"]
postgresssql=bd_products["postgresssql"]
sqlite=bd_products["sqlite"]
oracle=bd_products["oracle"]
mongodb=bd_products["mongodb"]
snowflake=bd_products["snowflake"]
ibm=bd_products["ibm"]
msqlserver=bd_products["msqlserver"]
msacess=bd_products["msacess"]
mazuredatalake=bd_products["mazuredatalake"]
aredshift=bd_products["aredshift"]
aathena=bd_products["aathena"]
adynamodb=bd_products["adynamodb"]
gcloudbigquery=bd_products["gcloudbigquery"]
gcloudsql=bd_products["gcloudsql"]
gcloudfirestore=bd_products["gcloudfirestore"]
none=bd_products["none"]
other=bd_products["other"]

# %%
plt.figure()
fig,axs  = plt.subplots(2,2)
plt.subplots_adjust(left=0,right=2,bottom=2,top=3,wspace=0.2,hspace=0.3)
#fig.suptitle("machine learning products")
axs[0,0].set_title('MySQL ')
axs[0,0].hist(mysql)

axs[0,1].set_title('PostgresSQL ')
axs[0,1].hist(postgresssql)

axs[1,0].set_title('SQLite ')
axs[1,0].hist(sqlite)

axs[1,1].set_title('Oracle Database ')
axs[1,1].hist(oracle)

# %%
plt.figure()
fig,axs  = plt.subplots(2,2)
plt.subplots_adjust(left=0,right=2,bottom=2,top=3,wspace=0.2,hspace=0.3)
axs[0,0].set_title('MongoDB ')
axs[0,0].hist(mongodb)

axs[0,1].set_title('Snowflake ')
axs[0,1].hist(snowflake)

axs[1,0].set_title('IBM Db2 ')
axs[1,0].hist(ibm)

axs[1,1].set_title('Microsoft Access ')
axs[1,1].hist(msacess)

# %%
plt.figure()
fig,axs  = plt.subplots(2,2)
plt.subplots_adjust(left=0,right=2,bottom=1,top=2,wspace=0.2,hspace=0.4)

axs[0,0].set_title('Microsoft Azure Data Lake Storage ')
axs[0,0].hist(mazuredatalake)

axs[0,1].set_title('Amazon Redshift ')
axs[0,1].hist(aredshift)

axs[1,0].set_title('Amazon Athena ')
axs[1,0].hist(aathena)

axs[1,1].set_title('Amazon DynamoDB ')
axs[1,1].hist(adynamodb)

# %%
plt.figure()
fig,axs  = plt.subplots(2,2)
plt.subplots_adjust(left=0,right=2,bottom=1,top=2,wspace=0.2,hspace=0.4)

axs[0,0].set_title('Google Cloud BigQuery ')
axs[0,0].hist(gcloudbigquery)

axs[0,1].set_title('Google Cloud SQL ')
axs[0,1].hist(gcloudsql)

axs[1,0].set_title('Google Cloud Firestore ')
axs[1,0].hist(gcloudfirestore)

axs[1,1].set_title('Microsoft SQL Server ')
axs[1,1].hist(msqlserver)
