# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 1. Downloading the dataset:-

# %%
ds = pd.read_csv('/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv')
ds

# %% [markdown]
# # 2. Understanding Dataset:-

# %% [markdown]
# As from the dataset we can see that the column header is actually a list of question numbers as in the survey and the 1st row of the survey actually represents the questions. So, we can make the 1st row as the column header and represent the dataset as follows:

# %%
ds.iloc[0].unique()

# %% [markdown]
# ## 2.1 Questions:

# %% [markdown]
# ### 2.1.1 How many rows and columns are present in the dataset?

# %%
ds.shape

# %% [markdown]
# **dataFrame.shape** determines the number of rows and columns in the dataframe. Here, as we can see there are 355 columns that represent different questions asked in the survey and the (number of rows - 1) represent the number of survey participants which is in this case 20036.

# %% [markdown]
# ### 2.1.2 Disply the first n rows of the dataframe -

# %%
ds.head()

# %% [markdown]
# **dataFrame.head** determines the first **n** rows of the dataset. It is used to view first few elements of the dataset to determine the data and the type of data in the dataset.

# %% [markdown]
# ### 2.1.3 Display the last n rows of the dataframe -

# %%
ds.tail()

# %% [markdown]
# **dataframe.tail** determines the last **n** rows of the dataset.

# %% [markdown]
# ### 2.1.4 What are the columns in dataFrame?

# %%
ds.columns

# %% [markdown]
# **dataframe.columns** determines the Column names, type of the columns and number of columns. As we can see there are some columns that represent different parts for the same question, so we will have to group them together.

# %% [markdown]
# ## 2.2 Objectives:

# %% [markdown]
# - The first and foremost objective of this notebook is to analyse the answers of those who participated in the survey.
# - Secondly, we will refactor the amount of questions to that were actually asked in the survey.
# -

# %% [markdown]
# # 3. Data Mining:-
# ***(Gathering and scraping necessary data)***

# %% [markdown]
# As we can see in [2.1.4](#-2.1.4-What-are-the-columns-in-dataFrame?), the number of questions that were asked in the 2020 Kaggle ML & DS Survey, it shows 355 which is not the case and rather it stores multiple parts of same question from the survey in different columns making the count exceedingly more than the actual number of questions.
#
# So, lets first determine the number of questions actually there in the survey:

# %%
ds.iloc[:0]
column_headers = pd.DataFrame({'Questions':ds.columns})
column_headers

# %%
no_of_questions = column_headers['Questions'].unique()
len(no_of_questions)

# %% [markdown]
# Hence, there are 48 questions in all in the survey including all the parts of the questions.

# %%
for i in range(0, len(no_of_questions)):
    print(no_of_questions[i])

# %% [markdown]
# # 4. Data Exploration:-
# ***(Forming hypothesis by visually analysing data)***

# %% [markdown]
# ### 5.1 What is the age group of survey participants?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q1', data = ds)
plt.xlabel("Age Group")
plt.ylabel("No. of people")
plt.title('Age Group of survey participants');

# %% [markdown]
# Most of the people who participated in the survey are of the age group 25 - 29.

# %% [markdown]
# ### 5.2 What is the gender of survey participants?

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Q2', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Gender')
plt.title("Gender");

# %% [markdown]
# Most of the survey participants were Male.

# %% [markdown]
# ### 5.3 Which country do the survey participants currently live?

# %%
plt.figure(figsize = (10,12))
sns.countplot(y = 'Q3', data = ds)
plt.xlabel('No, of people')
plt.ylabel('Countries')
plt.title('Counrty of Origin');

# %% [markdown]
# ### 5.4 What is the highest level of formal education survey participants have attained or plan to attain within the next 2 years?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q4', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Education')
plt.title('Highest level of formal education');

# %% [markdown]
# Most of the survey participants have a master's degree.

# %% [markdown]
# ### 5.5 Title most similar to survey participant's current role -

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q5', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Profession')
plt.title('Current title');

# %% [markdown]
# ### 5.6 For how many years survey particiapnts have been writing code and/or programming?

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Q6', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Time (in years)')
plt.title('Time since coding and/or programming');

# %% [markdown]
# ### 5.7 What programming languages do the survey participants use on a regular basis?

# %%
Q7 = ds[['Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3', 'Q7_Part_4', 'Q7_Part_5', 'Q7_Part_6', 'Q7_Part_7', 'Q7_Part_8', 'Q7_Part_9', 'Q7_Part_10', 'Q7_Part_11', 'Q7_Part_12', 'Q7_OTHER']]
Q7

# %% [markdown]
# ### 5.8 What programming language do the survey participants recommend an aspiring data scientist to learn first?

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Q8', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Programming Languages')
plt.title('Most Recommended programming languages as per survey participants');

# %% [markdown]
# ### 5.9 Which Integrated Development Environments (IDE's) do survey participants use on a regular basis?

# %%
Q9 = ds[['Q9_Part_1', 'Q9_Part_2', 'Q9_Part_3', 'Q9_Part_4', 'Q9_Part_5', 'Q9_Part_6', 'Q9_Part_7', 'Q9_Part_8', 'Q9_Part_9', 'Q9_Part_10', 'Q9_Part_11', 'Q9_OTHER']]
Q9

# %% [markdown]
# ### 5.10 Which hosted notebook products have the survey participants used on a regular basis?

# %%
Q10 = ds[['Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5', 'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10', 'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13', 'Q10_OTHER']]
Q10

# %% [markdown]
# ### 5.11 What type of computing platform do the survey participants use most often for data science projects?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q11', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Computing Platforms')
plt.title('Survey participant\'s preferred computing platform');

# %% [markdown]
# ### 5.12 Which types of specialized hardware do the survey participants use on a regular basis?

# %%
Q12 = ds[['Q12_Part_1', 'Q12_Part_2', 'Q12_Part_3', 'Q12_OTHER']]
Q12

# %% [markdown]
# ### 5.13 Approximately how many times have the survey participants used a TPU (Tensor Processing Unit)?

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Q13', data = ds)
plt.xlabel('No. of people')
plt.ylabel('No. of times TPU used')
plt.title('How many times have the survey participants used TPU');

# %% [markdown]
# ### 5.14 What data visualization libraries or tools do the survey participants use on a regular basis?

# %%
Q14 = ds[['Q14_Part_1', 'Q14_Part_2', 'Q14_Part_3', 'Q14_Part_4', 'Q14_Part_5', 'Q14_Part_6', 'Q14_Part_7', 'Q14_Part_8', 'Q14_Part_9', 'Q14_Part_10', 'Q14_Part_11', 'Q14_OTHER']]
Q14

# %% [markdown]
# ### 5.15 For how many years have the survey participants used machine learning methods?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q15', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Time (in years)')
plt.title('Time since stated using ML');

# %% [markdown]
# ### 5.16 Which Machine Learning frameworks do the survey participants use on a regular basis?

# %%
Q16 = ds[['Q16_Part_1', 'Q16_Part_2', 'Q16_Part_3', 'Q16_Part_4', 'Q16_Part_5', 'Q16_Part_6', 'Q16_Part_7', 'Q16_Part_8', 'Q16_Part_9', 'Q16_Part_10', 'Q16_Part_11', 'Q16_Part_12', 'Q16_Part_13', 'Q16_Part_14', 'Q16_Part_15', 'Q16_OTHER']]
Q16

# %% [markdown]
# ### 5.17 Which ML algorithms do the survey participants use on a regular basis?

# %%
Q17 = ds[['Q17_Part_1', 'Q17_Part_2', 'Q17_Part_3', 'Q17_Part_4', 'Q17_Part_5', 'Q17_Part_6', 'Q17_Part_7', 'Q17_Part_8', 'Q17_Part_9', 'Q17_Part_10', 'Q17_Part_11', 'Q17_OTHER']]
Q17

# %% [markdown]
# ### 5.18 Which categories of computer vision methods do survey participants use on a regular basis?

# %%
Q18 = ds[['Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3', 'Q18_Part_4', 'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER']]
Q18

# %% [markdown]
# ### 5.19 Which Natural Language Processing (NLP) methods do survey participants use on a regular basis?

# %%
Q19 = ds[['Q19_Part_1', 'Q19_Part_2', 'Q19_Part_3', 'Q19_Part_4', 'Q19_Part_5', 'Q19_OTHER']]
Q19

# %% [markdown]
# ### 5.20 What is the size of the company where survey participants are employed in?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q20', data = ds)
plt.xlabel('No. of people')
plt.ylabel('No. of employees')
plt.title('Size of the company');

# %% [markdown]
# ### 5.21 How many individuals are responsible for data science workloads at survey participants place of business?

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Q21', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Individuals responsible')
plt.title('Individuals responsible for DS workloads');

# %% [markdown]
# ### 5.22 Does the survey participant's current employer incorporate machine learning methods in business?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q22', data = ds)
plt.xlabel('No. of people')
plt.ylabel('')
plt.title('ML Methodologies');

# %% [markdown]
# ### 5.23 Activities that make an important part of survey participant's role at work -

# %%
Q23 = ds[['Q23_Part_1', 'Q23_Part_2', 'Q23_Part_3', 'Q23_Part_4', 'Q23_Part_5', 'Q23_Part_6', 'Q23_Part_7', 'Q23_OTHER']]
Q23

# %% [markdown]
# ### 5.24 Current yearly compensation of survey participants -

# %%
plt.figure(figsize = (8,10))
sns.countplot(y = 'Q24', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Compensation (in USD)')
plt.title('Yearly compensation');

# %% [markdown]
# ### 5.25 Money spent on machine learning and/or cloud computing services at home (or at work) in the past 5 years by survey participants?

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Q25', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Salary')
plt.title('');

# %% [markdown]
# ### 5.26.1 Which Cloud Computing platforms do the survey participants use on a regular basis?

# %%
Q26A = ds[['Q26_A_Part_1', 'Q26_A_Part_2', 'Q26_A_Part_3', 'Q26_A_Part_4', 'Q26_A_Part_5', 'Q26_A_Part_6', 'Q26_A_Part_7', 'Q26_A_Part_8', 'Q26_A_Part_9', 'Q26_A_Part_10', 'Q26_A_Part_11', 'Q26_A_OTHER']]
Q26A

# %% [markdown]
# ### 5.26.2 Which Cloud Computing platforms do the survey participants hope to become more familiar with, in next 2 years?

# %%
Q26B = ds[['Q26_B_Part_1', 'Q26_B_Part_2', 'Q26_B_Part_3', 'Q26_B_Part_4', 'Q26_B_Part_5', 'Q26_B_Part_6', 'Q26_B_Part_7', 'Q26_B_Part_8', 'Q26_B_Part_9', 'Q26_B_Part_10', 'Q26_B_Part_11', 'Q26_B_OTHER']]
Q26B

# %% [markdown]
# ### 5.27.1  Which Cloud Computing products do the survey participants use on a regular basis?

# %%
Q27A = ds[['Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3', 'Q27_A_Part_4', 'Q27_A_Part_5', 'Q27_A_Part_6', 'Q27_A_Part_7', 'Q27_A_Part_8', 'Q27_A_Part_9', 'Q27_A_Part_10', 'Q27_A_Part_11', 'Q27_A_OTHER']]
Q27A

# %% [markdown]
# ### 5.27.2 Which Cloud Computing Products do the survey participants hope to become more familiar with, in next 2 years?

# %%
Q27B = ds[['Q27_B_Part_1', 'Q27_B_Part_2', 'Q27_B_Part_3', 'Q27_B_Part_4', 'Q27_B_Part_5', 'Q27_B_Part_6', 'Q27_B_Part_7', 'Q27_B_Part_8', 'Q27_B_Part_9', 'Q27_B_Part_10', 'Q27_B_Part_11', 'Q27_B_OTHER']]
Q27B

# %% [markdown]
# ### 5.28.1 Do the survey participants use any Machine Learning Products on a regular basis?

# %%
Q28A = ds[['Q28_A_Part_1', 'Q28_A_Part_2', 'Q28_A_Part_3', 'Q28_A_Part_4', 'Q28_A_Part_5', 'Q28_A_Part_6', 'Q28_A_Part_7', 'Q28_A_Part_8', 'Q28_A_Part_9', 'Q28_A_Part_10', 'Q28_A_OTHER']]
Q28A

# %% [markdown]
# ### 5.28.2 Which Machine Learning Products do the survey participants hope to become more familiar with, in next 2 years??

# %%
Q28B = ds[['Q28_B_Part_1', 'Q28_B_Part_2', 'Q28_B_Part_3', 'Q28_B_Part_4', 'Q28_B_Part_5', 'Q28_B_Part_6', 'Q28_B_Part_7', 'Q28_B_Part_8', 'Q28_B_Part_9', 'Q28_B_Part_10', 'Q28_B_OTHER']]
Q28B

# %% [markdown]
# ### 5.29.1 Which Big Data Products (relational databases, data warehouses, data lakes, or similar) do survey participants use on a regular basis?

# %%
Q29A = ds[['Q29_A_Part_1', 'Q29_A_Part_2', 'Q29_A_Part_3', 'Q29_A_Part_4', 'Q29_A_Part_5', 'Q29_A_Part_6', 'Q29_A_Part_7', 'Q29_A_Part_8', 'Q29_A_Part_9', 'Q29_A_Part_10', 'Q29_A_Part_11', 'Q29_A_Part_12', 'Q29_A_Part_13', 'Q29_A_Part_14', 'Q29_A_Part_15', 'Q29_A_Part_16', 'Q29_A_Part_17', 'Q29_A_OTHER']]
Q29A

# %% [markdown]
# ### 5.29.2 Which Big Data Products (relational databases, data warehouses, data lakes, or similar) do the survey participants hope to become more familiar with, in next 2 years?

# %%
Q29B = ds[['Q29_B_Part_1', 'Q29_B_Part_2', 'Q29_B_Part_3', 'Q29_B_Part_4', 'Q29_B_Part_5', 'Q29_B_Part_6', 'Q29_B_Part_7', 'Q29_B_Part_8', 'Q29_B_Part_9', 'Q29_B_Part_10', 'Q29_B_Part_11', 'Q29_B_Part_12', 'Q29_B_Part_13', 'Q29_B_Part_14', 'Q29_B_Part_15', 'Q29_B_Part_16', 'Q29_B_Part_17', 'Q29_B_OTHER']]
Q29B

# %% [markdown]
# ### 5.30 Which Big Data Products (relational database, data warehouse, data lake, or similar) do survey participants use most often?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q30', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Business Intelligence Products');

# %% [markdown]
# ### 5.31.1 Which Business Intelligence Tools do survey participants use on a regular basis?

# %%
Q31A =  ds[['Q31_A_Part_1', 'Q31_A_Part_2', 'Q31_A_Part_3', 'Q31_A_Part_4', 'Q31_A_Part_5', 'Q31_A_Part_6', 'Q31_A_Part_7', 'Q31_A_Part_8', 'Q31_A_Part_9', 'Q31_A_Part_10', 'Q31_A_Part_11', 'Q31_A_Part_12', 'Q31_A_Part_13', 'Q31_A_Part_14', 'Q31_A_OTHER']]
Q31A

# %% [markdown]
# ### 5.31.2 Which Business Intelligence Tools do the survey participants hope to become more familiar with, in next 2 years?

# %%
Q31B =  ds[['Q31_B_Part_1', 'Q31_B_Part_2', 'Q31_B_Part_3', 'Q31_B_Part_4', 'Q31_B_Part_5', 'Q31_B_Part_6', 'Q31_B_Part_7', 'Q31_B_Part_8', 'Q31_B_Part_9', 'Q31_B_Part_10', 'Q31_B_Part_11', 'Q31_B_Part_12', 'Q31_B_Part_13', 'Q31_B_Part_14', 'Q31_B_OTHER']]
Q31B

# %% [markdown]
# ### 5.32 Which Business Intelligence Tools do survey participants use most often?

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Q32', data = ds)
plt.xlabel('No. of people')
plt.ylabel('ML Tools')
plt.title('');

# %% [markdown]
# ### 5.33.1 Which Automated Machine Learning tools (or partial AutoML tools) do the survey participants use on a regular basis?

# %%
Q33A = ds[['Q33_A_Part_1', 'Q33_A_Part_2', 'Q33_A_Part_3', 'Q33_A_Part_4', 'Q33_A_Part_5', 'Q33_A_Part_6', 'Q33_A_Part_7', 'Q33_A_OTHER']]
Q33A

# %% [markdown]
# ### 5.33.2  Which categories of automated machine learning tools (or partial AutoML tools) do survey participants hope to become more familiar with, in next 2 years?

# %%
Q33B = ds[['Q33_B_Part_1', 'Q33_B_Part_2', 'Q33_B_Part_3', 'Q33_B_Part_4', 'Q33_B_Part_5', 'Q33_B_Part_6', 'Q33_B_Part_7', 'Q33_B_OTHER']]
Q33B

# %% [markdown]
# ### 5.34.1 Which Automated Machine Learning tools (or partial AutoML tools) do survey participants use on a regular basis?

# %%
Q34A = ds[['Q34_A_Part_1', 'Q34_A_Part_2', 'Q34_A_Part_3', 'Q34_A_Part_4', 'Q34_A_Part_5', 'Q34_A_Part_6', 'Q34_A_Part_7', 'Q34_A_Part_8', 'Q34_A_Part_9', 'Q34_A_Part_10', 'Q34_A_Part_11', 'Q34_A_OTHER']]
Q34A

# %% [markdown]
# ### 5.34.2 Which specific Automated Machine Learning tools (or partial AutoML tools) do survey participants hope to become more familiar with, in next 2 years?

# %%
Q34B = ds[['Q34_B_Part_1', 'Q34_B_Part_2', 'Q34_B_Part_3', 'Q34_B_Part_4', 'Q34_B_Part_5', 'Q34_B_Part_6', 'Q34_B_Part_7', 'Q34_B_Part_8', 'Q34_B_Part_9', 'Q34_B_Part_10', 'Q34_B_Part_11', 'Q34_B_OTHER']]
Q34B

# %% [markdown]
# ### 5.35.1 Do survey participants use any tools to help manage Machine Learning experiments?

# %%
Q35A = ds[['Q35_A_Part_1', 'Q35_A_Part_2', 'Q35_A_Part_3', 'Q35_A_Part_4', 'Q35_A_Part_5', 'Q35_A_Part_6', 'Q35_A_Part_7', 'Q35_A_Part_8', 'Q35_A_Part_9', 'Q35_A_Part_10', 'Q35_A_OTHER']]
Q35A

# %% [markdown]
# ### 5.35.2 Which tools for managing ML experiments do the survey participants hope to become more familiar with, in next 2 years?

# %%
Q35B = ds[['Q35_B_Part_1', 'Q35_B_Part_2', 'Q35_B_Part_3', 'Q35_B_Part_4', 'Q35_B_Part_5', 'Q35_B_Part_6', 'Q35_B_Part_7', 'Q35_B_Part_8', 'Q35_B_Part_9', 'Q35_B_Part_10', 'Q35_B_OTHER']]
Q35B

# %% [markdown]
# ### 5.36 Where do survey participants publicly share or deploy Data Analysis or Machine Learning applications?

# %%
Q36 = ds[['Q36_Part_1', 'Q36_Part_2', 'Q36_Part_3', 'Q36_Part_4', 'Q36_Part_5', 'Q36_Part_6', 'Q36_Part_7', 'Q36_Part_8', 'Q36_Part_9', 'Q36_OTHER']]
Q36

# %% [markdown]
# ### 5.37 On which platforms have survey participants begun or completed data science courses?

# %%
Q37 = ds[['Q37_Part_1', 'Q37_Part_2', 'Q37_Part_3', 'Q37_Part_4', 'Q37_Part_5', 'Q37_Part_6', 'Q37_Part_7', 'Q37_Part_8', 'Q37_Part_9', 'Q37_Part_10', 'Q37_Part_11', 'Q37_OTHER']]
Q37

# %% [markdown]
# ### 5.38 What is the primary tool that survey participants use at work or school to analyze data?

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = 'Q38', data = ds)
plt.xlabel('No. of people')
plt.ylabel('Tools')
plt.title('');

# %% [markdown]
# ### 5.39 Who/what are the favorite media sources of survey participants that report on Data Science topics?

# %%
Q39 = ds[['Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_4', 'Q39_Part_5', 'Q39_Part_6', 'Q39_Part_7', 'Q39_Part_8', 'Q39_Part_9', 'Q39_Part_10', 'Q39_Part_11', 'Q39_OTHER']]
Q39
