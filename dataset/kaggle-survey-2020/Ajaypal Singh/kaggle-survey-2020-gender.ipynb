# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")

# %%
df

# %%
df["Q3"].value_counts().reset_index()

# %%
df["Q3"].value_counts()

# %%
India= df[(df['Q3'] == 'India')]
India["Q2"].value_counts().reset_index()

# %%
India["Q2"].value_counts().plot.bar()

# %%
United_States_of_America= df[(df['Q3'] == 'United States of America')]
United_States_of_America["Q2"].value_counts().reset_index()

# %%
United_States_of_America["Q2"].value_counts().plot.bar()

# %%
Brazil= df[(df['Q3'] == 'Brazil')]
Brazil["Q2"].value_counts().reset_index()

# %%
Brazil["Q2"].value_counts().plot.line()

# %%
Japan= df[(df['Q3'] == 'Japan')]
Japan["Q2"].value_counts().reset_index()

# %%
Japan["Q2"].value_counts().plot.line()

# %%
UK= df[(df['Q3'] == 'United Kingdom of Great Britain and Northern Ireland')]
UK["Q2"].value_counts().reset_index()

# %%
UK["Q2"].value_counts().plot()

# %%
Russia= df[(df['Q3'] == 'Russia')]
Russia["Q2"].value_counts().reset_index()

# %%
Russia["Q2"].value_counts().plot()

# %%
Nigeria= df[(df['Q3'] == 'Nigeria')]
Nigeria["Q2"].value_counts().reset_index()

# %%
Nigeria["Q2"].value_counts().plot()

# %%
China= df[(df['Q3'] == 'China')]
China["Q2"].value_counts().reset_index()

# %%
China["Q2"].value_counts().plot.bar()

# %%
Germany= df[(df['Q3'] == 'Germany')]
Germany["Q2"].value_counts().reset_index()

# %%
Germany["Q2"].value_counts().plot.bar()

# %%
Turkey= df[(df['Q3'] == 'Turkey')]
Turkey["Q2"].value_counts().reset_index()

# %%
Turkey["Q2"].value_counts().plot.bar()

# %%
Spain= df[(df['Q3'] == 'Spain')]
Spain["Q2"].value_counts().reset_index()

# %%
Spain["Q2"].value_counts().plot.line()

# %%
France= df[(df['Q3'] == 'France')]
France["Q2"].value_counts().reset_index()

# %%
France["Q2"].value_counts().plot.pie()

# %%
Canada= df[(df['Q3'] == 'Canada')]
Canada["Q2"].value_counts().reset_index()

# %%
Canada["Q2"].value_counts().plot.line()

# %%
Indonesia= df[(df['Q3'] == 'Indonesia')]
Indonesia["Q2"].value_counts().reset_index()

# %%
Indonesia["Q2"].value_counts().plot.bar()

# %%
Pakistan= df[(df['Q3'] == 'Pakistan')]
Pakistan["Q2"].value_counts().reset_index()

# %%
Pakistan["Q2"].value_counts().plot.pie()

# %%
Taiwan= df[(df['Q3'] == 'Taiwan')]
Taiwan["Q2"].value_counts().reset_index()

# %%
Taiwan["Q2"].value_counts().plot.bar()

# %%
Australia= df[(df['Q3'] == 'Australia')]
Australia["Q2"].value_counts().reset_index()

# %%
Australia["Q2"].value_counts().plot.bar()

# %%
Mexico= df[(df['Q3'] == 'Mexico')]
Mexico["Q2"].value_counts().reset_index()

# %%
Mexico["Q2"].value_counts().plot.line()

# %%
Italy= df[(df['Q3'] == 'Italy')]
Italy["Q2"].value_counts().reset_index()

# %%
Italy["Q2"].value_counts().plot.pie()

# %%
South_Korea= df[(df['Q3'] == 'South Korea')]
South_Korea["Q2"].value_counts().reset_index()

# %%
South_Korea["Q2"].value_counts().plot.pie()

# %%
Egypt= df[(df['Q3'] == 'Egypt')]
Egypt["Q2"].value_counts().reset_index()

# %%
Egypt["Q2"].value_counts().plot.pie()

# %%
Colombia= df[(df['Q3'] == 'Colombia')]
Colombia["Q2"].value_counts().reset_index()

# %%
Colombia["Q2"].value_counts().plot.pie()

# %%
Ukraine= df[(df['Q3'] == 'Ukraine')]
Ukraine["Q2"].value_counts().reset_index()

# %%
Ukraine["Q2"].value_counts().plot.bar()

# %%
Iran= df[(df['Q3'] == 'Iran, Islamic Republic of...')]
Iran["Q2"].value_counts().reset_index()

# %%
Iran["Q2"].value_counts().plot.pie()

# %%
Kenya= df[(df['Q3'] == 'Kenya')]
Kenya["Q2"].value_counts().reset_index()

# %%
Kenya["Q2"].value_counts().plot.line()

# %%
Netherlands= df[(df['Q3'] == 'Netherlands')]
Netherlands["Q2"].value_counts().reset_index()

# %%
Netherlands["Q2"].value_counts().plot.pie()

# %%
df_developed = df[(df["Q3"]=="India") |(df["Q3"]=="China")|(df["Q3"]=='Pakistan')|(df["Q3"]=='United States of America')|(df["Q3"]=='United Kingdom of Great Britain and Northern Ireland')]

# %%
df_developed

# %%
import seaborn as sns
plt.figure(figsize = (16,8))
sns.countplot(x = df_developed['Q3'], hue = df_developed["Q2"])

# %%
plt.figure(figsize = (16,8))
sns.countplot(x = df_developed['Q6'], hue = df_developed["Q2"])

# %%
plt.figure(figsize = (30,8))
sns.countplot(x = df_developed['Q4'], hue = df_developed["Q2"])

# %%
plt.figure(figsize = (30,8))
sns.countplot(x = df_developed['Q5'], hue = df_developed["Q2"])
