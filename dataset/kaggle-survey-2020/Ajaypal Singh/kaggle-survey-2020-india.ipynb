# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")
descriptions = df.loc[0, :]
df = df.loc[1:, :]
df.head()

# %%
df

# %% [markdown]
# Indias Data

# %%
df2 = df[(df['Q3'] == 'India')]
df2.head()

# %% [markdown]
#  **gender**

# %%
df2["Q2"].value_counts().reset_index()

# %%
df2["Q2"].value_counts().plot.bar()

# %% [markdown]
#  What is the highest level of formal education that you have attained or plan to attain within the next 2 years?

# %%
df2["Q4"].value_counts().reset_index()

# %%
df2["Q4"].value_counts().plot.bar()

# %% [markdown]
# Select the title most similar to your current role (or most recent title if retired):

# %%
df2["Q5"].value_counts().reset_index()

# %%
df2["Q5"].value_counts().plot.bar()

# %% [markdown]
# For how many years have you been writing code and/or programming?

# %%
df2["Q6"].value_counts().reset_index()

# %%
df2["Q6"].value_counts().plot.pie()

# %% [markdown]
# What programming languages do you use on a regular basis?

# %%
Q7= {}
for i in range(1,13):
    Q7.update(dict(df2[f"Q7_Part_{i}"].value_counts()))
Q7 = pd.DataFrame(Q7.items(), columns = ['languague', 'counts'])

# %%
Q7

# %%
Q7.plot(x="languague", y="counts", kind='bar')

# %% [markdown]
# What programming language would you recommend an aspiring data scientist to learn first?

# %%
df2["Q8"].value_counts().reset_index()

# %%
df2["Q8"].value_counts().plot.bar()

# %% [markdown]
# Which of the following integrated development environments (IDE's) do you use on a regular basis?

# %%
Q9 = {}
for i in range(1,11):
    Q9.update(dict(df2[f"Q9_Part_{i}"].value_counts()))
Q9 = pd.DataFrame(Q9.items(), columns = ['ide', 'counts'])

# %%
Q9

# %%
Q9.plot(x="ide", y="counts", kind='bar')

# %% [markdown]
# Which of the following hosted notebook products do you use on a regular basis?

# %%
Q10 = {}
for i in range(1,14):
    Q10.update(dict(df2[f"Q10_Part_{i}"].value_counts()))
Q10 = pd.DataFrame(Q10.items(), columns = ['ide', 'counts'])

# %%
Q10

# %%
Q10.plot(x="ide", y="counts", kind='pie')

# %% [markdown]
# What type of computing platform do you use most often for your data science projects?

# %%
df2["Q11"].value_counts().reset_index()

# %%
df2["Q11"].value_counts().plot.bar()

# %% [markdown]
# Which types of specialized hardware do you use on a regular basis?

# %%
q12_columns = [column for column in df.columns if 'Q12' in column]
Q12 = {}

for column in q12_columns:
    Q12.update(dict(df2[column].value_counts()))

Q12 = pd.DataFrame(Q12.items(), columns = ['hardware', 'counts'])

# %%
Q12

# %%
Q12.plot(x="hardware", y="counts", kind='pie')

# %% [markdown]
# Approximately how many times have you used a TPU (tensor processing unit)?

# %%
df2["Q13"].value_counts().reset_index()

# %%
df2["Q13"].value_counts().plot.pie()

# %% [markdown]
# What data visualization libraries or tools do you use on a regular basis?

# %%
Q14= {}
for i in range(1,12):
    Q14.update(dict(df2[f"Q14_Part_{i}"].value_counts()))
Q14 = pd.DataFrame(Q14.items(), columns = ['visualization', 'counts'])

# %%
Q14

# %%
Q14.plot(x="visualization", y="counts", kind='bar')

# %% [markdown]
# For how many years have you used machine learning methods?

# %%
df2["Q15"].value_counts().reset_index()

# %%
df2["Q15"].value_counts().plot.bar()

# %% [markdown]
# Which of the following machine learning frameworks do you use on a regular basis?

# %%
Q16= {}
for i in range(1,16):
    Q16.update(dict(df2[f"Q16_Part_{i}"].value_counts()))
Q16 = pd.DataFrame(Q16.items(), columns = ['frameworks', 'counts'])

# %%
Q16

# %%
Q16.plot(x="frameworks", y="counts", kind='bar')

# %% [markdown]
# Which of the following ML algorithms do you use on a regular basis?

# %%
Q17= {}
for i in range(1,12):
    Q17.update(dict(df2[f"Q17_Part_{i}"].value_counts()))
Q17 = pd.DataFrame(Q17.items(), columns = ['algorithms', 'counts'])

# %%
Q17

# %%
Q17.plot(x="algorithms", y="counts", kind='bar')

# %% [markdown]
# Which categories of computer vision methods do you use on a regular basis?

# %%
Q18= {}
for i in range(1,7):
    Q18.update(dict(df2[f"Q18_Part_{i}"].value_counts()))
Q18 = pd.DataFrame(Q18.items(), columns = ['vision', 'counts'])

# %%
Q18

# %%
Q18.plot(x="vision", y="counts", kind='bar')

# %% [markdown]
# Which of the following natural language processing (NLP) methods do you use on a regular basis?

# %%
Q19= {}
for i in range(1,6):
    Q19.update(dict(df2[f"Q19_Part_{i}"].value_counts()))
Q19 = pd.DataFrame(Q19.items(), columns = ['NLP', 'counts'])

# %%
Q19

# %%
Q19.plot(x="NLP", y="counts", kind='bar')

# %% [markdown]
# What is the size of the company where you are employed?

# %%
df2["Q20"].value_counts().reset_index()

# %%
df2["Q20"].value_counts().plot.pie()

# %% [markdown]
# Approximately how many individuals are responsible for data science workloads at your place of
# business?

# %%
df2["Q21"].value_counts().reset_index()

# %%
df2["Q21"].value_counts().plot.pie()

# %% [markdown]
# Does your current employer incorporate machine learning methods into their business?

# %%
df2["Q22"].value_counts().reset_index()

# %%
df2["Q22"].value_counts().plot.pie()

# %% [markdown]
# Select any activities that make up an important part of your role at work:

# %%
Q23= {}
for i in range(1,8):
    Q23.update(dict(df2[f"Q23_Part_{i}"].value_counts()))
Q23 = pd.DataFrame(Q23.items(), columns = ['important', 'counts'])

# %%
Q23

# %%
Q23.plot(x="important", y="counts", kind='bar')

# %% [markdown]
# What is your current yearly compensation

# %%
df2["Q24"].value_counts().reset_index()

# %%
df2["Q24"].value_counts().plot.bar()

# %% [markdown]
# Approximately how much money have you (or your team) spent on machine learning and/or cloud
# computing services at home (or at work) in the past 5 years (approximate $USD)?

# %%
df2["Q25"].value_counts().reset_index()

# %%
df2["Q25"].value_counts().plot.pie()

# %% [markdown]
# Which of the following business intelligence tools do you use most often?

# %%
df2["Q32"].value_counts().reset_index()

# %%
df2["Q32"].value_counts().plot.bar()
