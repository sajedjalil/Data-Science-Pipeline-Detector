# %% [markdown]
# # **Today, the Underdogs... Tomorrow, the Challengers**
# **A story of underdeveloped countries and how they can become tomorrow's challengers with data science**
# ![](https://media1.tenor.com/images/63dc3e50bb6f234aae79161dddbd7efd/tenor.gif?itemid=17924212)

# %% [markdown]
# # Data Science: the key to success for underdeveloped countries

# %% [markdown]
# Data Science is all around us. Everytime we search the internet, order something on amazon, or use our fitness watches, we are using data science. Many articles talk about the plight of underdeveloped countries or the so-called underdogs. One day, I got to thinking, Could these people benefit from having acess to data science. If so, Why don't these people have acess to these resources yet? In this noteboook, I want to prove that "underdog" countries could benefit from data science, and become tomorrow's challengers, all by using the **power of data science**.
# ![](https://www.aircraft-commerce.com/wp-content/uploads/2019/08/The-Power-of-Data.jpg)

# %% [markdown]
# # The Underdogs of the World

# %% [markdown]
# In this section, we will identify the "underdogs of the world". My hypothesis is that countries such as Kenya, Morocco and Brazil will be underdogs.

# %% [markdown]
# # Population of Kagglers

# %%
# TODO: Create diagram of world with pop. of Data Scientists for 2018,2019 and 2020
import pandas as pd
import plotly.express as px

df_sur2020 = pd.read_csv("/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")
df_sur2019 = pd.read_csv("/kaggle/input/kaggle-2019-survey-copy/multiple_choice_responses.csv")
df_sur2018 = pd.read_csv("/kaggle/input/kaggle-survey-2018/multipleChoiceResponses.csv")

# %%
df_sur2020["year"] = 2020
df_sur2020 = df_sur2020.drop([0])

# %%
df_sur2019["year"] = 2019
df_sur2019 = df_sur2019.drop([0])

# %%
df_sur2018["year"] = 2018
df_sur2018 = df_sur2018.drop([0])

# %%
df_sur = df_sur2020.append(df_sur2019.append(df_sur2018))

# %%
df_sur["country"] = df_sur["Q3"]

# %%
df_sur.loc[df_sur["country"]=="India","iso_alpha"]="IND"
df_sur.loc[df_sur["country"]=="Algeria","iso_alpha"]="DZA"
df_sur.loc[df_sur["country"]=="United States","iso_alpha"]="USA"
df_sur.loc[df_sur["country"]=="United States of America","iso_alpha"]="USA"
df_sur.loc[df_sur["country"]=="Canada","iso_alpha"]="CAN"
df_sur.loc[df_sur["country"]=="Taiwan","iso_alpha"]="TWN"
df_sur.loc[df_sur["country"]=="Brazil","iso_alpha"]="BRA"
df_sur.loc[df_sur["country"]=="Australia","iso_alpha"]="AUS"
df_sur.loc[df_sur["country"]=="Russia","iso_alpha"]="RUS"
df_sur.loc[df_sur["country"]=="Netherlands","iso_alpha"]="NLD"
df_sur.loc[df_sur["country"]=="Italy","iso_alpha"]="ITA"
df_sur.loc[df_sur["country"]=="United Kingdom","iso_alpha"]="GBR"
df_sur.loc[df_sur["country"]=="Czech Republic","iso_alpha"]="CZE"
df_sur.loc[df_sur["country"]=="Colombia","iso_alpha"]="COL"
df_sur.loc[df_sur["country"]=="Germany","iso_alpha"]="DEU"
df_sur.loc[df_sur["country"]=="Denmark","iso_alpha"]="DNK"
df_sur.loc[df_sur["country"]=="Poland","iso_alpha"]="POL"
df_sur.loc[df_sur["country"]=="South Africa","iso_alpha"]="ZAF"
df_sur.loc[df_sur["country"]=="Sweden","iso_alpha"]="SWE"
df_sur.loc[df_sur["country"]=="Portugal","iso_alpha"]="PRT"
df_sur.loc[df_sur["country"]=="Mexico","iso_alpha"]="MEX"
df_sur.loc[df_sur["country"]=="New Zealand","iso_alpha"]="NZL"
df_sur.loc[df_sur["country"]=="People 's Republic of China","iso_alpha"]="CHN"
df_sur.loc[df_sur["country"]=="Japan","iso_alpha"]="JPN"
df_sur.loc[df_sur["country"]=="Iran","iso_alpha"]="IRN"
df_sur.loc[df_sur["country"]=="Singapore","iso_alpha"]="SGP"
df_sur.loc[df_sur["country"]=="France","iso_alpha"]="FRA"
df_sur.loc[df_sur["country"]=="Spain","iso_alpha"]="ESP"
df_sur.loc[df_sur["country"]=="Indonesia","iso_alpha"]="IDN"
df_sur.loc[df_sur["country"]=="Israel","iso_alpha"]="ISR"
df_sur.loc[df_sur["country"]=="Egypt","iso_alpha"]="EGY"
df_sur.loc[df_sur["country"]=="Hungary","iso_alpha"]="HUN"
df_sur.loc[df_sur["country"]=="Argentina","iso_alpha"]="ARG"
df_sur.loc[df_sur["country"]=="Turkey","iso_alpha"]="TUR"
df_sur.loc[df_sur["country"]=="Ukraine","iso_alpha"]="UKR"
df_sur.loc[df_sur["country"]=="Greece","iso_alpha"]="GRC"
df_sur.loc[df_sur["country"]=="Pakistan","iso_alpha"]="PAK"
df_sur.loc[df_sur["country"]=="Finland","iso_alpha"]="FIN"
df_sur.loc[df_sur["country"]=="Norway","iso_alpha"]="NOR"
df_sur.loc[df_sur["country"]=="Ireland","iso_alpha"]="IRL"
df_sur.loc[df_sur["country"]=="Chile","iso_alpha"]="CHL"
df_sur.loc[df_sur["country"]=="Belarus","iso_alpha"]="BLR"
df_sur.loc[df_sur["country"]=="Malaysia","iso_alpha"]="MYS"
df_sur.loc[df_sur["country"]=="South Korea","iso_alpha"]="KOR"
df_sur.loc[df_sur["country"]=="Nigeria","iso_alpha"]="NGA"
df_sur.loc[df_sur["country"]=="Belgium","iso_alpha"]="BEL"
df_sur.loc[df_sur["country"]=="Hong Kong","iso_alpha"]="HKG"
df_sur.loc[df_sur["country"]=="Republic of China","iso_alpha"]="CHN"
df_sur.loc[df_sur["country"]=="Philippines","iso_alpha"]="PHL"
df_sur.loc[df_sur["country"]=="Vietnam","iso_alpha"]="VNM"
df_sur.loc[df_sur["country"]=="Kenya","iso_alpha"]="KEN"
df_sur.loc[df_sur["country"]=="Switzerland","iso_alpha"]="CHE"
df_sur.loc[df_sur["country"]=="Romania","iso_alpha"]="ROU"
df_sur.loc[df_sur["country"]=="Iran, Islamic Republic of...","iso_alpha"]="IRN"
df_sur.loc[df_sur["country"]=='United Kingdom of Great Britain and Northern Ireland',"iso_alpha"]="GBR"
df_sur.loc[df_sur["country"]=="China","iso_alpha"]="CHN"
df_sur.loc[df_sur["country"]=="Austria","iso_alpha"]="AUT"
df_sur.loc[df_sur["country"]=="Hong Kong (S.A.R.)","iso_alpha"]="HKG"
df_sur.loc[df_sur["country"]=="Tunisia","iso_alpha"]="TUN"
df_sur.loc[df_sur["country"]=="Thailand","iso_alpha"]="THA"
df_sur.loc[df_sur["country"]=="Morocco","iso_alpha"]="MAR"
df_sur.loc[df_sur["country"]=="Bangladesh","iso_alpha"]="BGD"
df_sur.loc[df_sur["country"]=="Viet Nam","iso_alpha"]="VNM"
df_sur.loc[df_sur["country"]=="Peru","iso_alpha"]="PER"
df_sur.loc[df_sur["country"]=="Republic of Korea","iso_alpha"]="KOR"
df_sur.loc[df_sur["country"]=="Saudi Arabia","iso_alpha"]="SAU"
df_sur.loc[df_sur["country"]=="Nepal","iso_alpha"]="NPL"
df_sur.loc[df_sur["country"]=="United Arab Emirates","iso_alpha"]="ARE"
df_sur.loc[df_sur["country"]=="Ghana","iso_alpha"]="GHA"
df_sur.loc[df_sur["country"]=="Sri Lanka","iso_alpha"]="LKA"

# %%
df_sur = df_sur.groupby(['country', 'year','iso_alpha']).agg({'country': ["count"]}).sort_values('year') 
df_sur.columns = ['count']
df_sur = df_sur.reset_index()

# %%
df_sur

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode()

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json') as response:
    countries = json.load(response)

# %% [markdown]
# # Figure 1: Kaggler Population by Country

# %%
fig = px.choropleth(df_sur, geojson=countries, locations='iso_alpha', color='count',
                           color_continuous_scale="Viridis",
                           range_color=(0, 1000),
                           scope="world",
                           animation_frame = "year"
                          )
fig.show()

# %%
df_sur.loc[df_sur["country"]=="India","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Algeria","continent"]="Africa"
df_sur.loc[df_sur["country"]=="United States","continent"]="North America"
df_sur.loc[df_sur["country"]=="United States of America","continent"]="North America"
df_sur.loc[df_sur["country"]=="Canada","continent"]="North America"
df_sur.loc[df_sur["country"]=="Taiwan","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Brazil","continent"]="South America"
df_sur.loc[df_sur["country"]=="Australia","continent"]="Oceania"
df_sur.loc[df_sur["country"]=="Russia","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Netherlands","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Italy","continent"]="Europe"
df_sur.loc[df_sur["country"]=="United Kingdom","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Czech Republic","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Colombia","continent"]="South America"
df_sur.loc[df_sur["country"]=="Germany","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Denmark","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Poland","continent"]="Europe"
df_sur.loc[df_sur["country"]=="South Africa","continent"]="Africa"
df_sur.loc[df_sur["country"]=="Sweden","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Portugal","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Mexico","continent"]="North America"
df_sur.loc[df_sur["country"]=="New Zealand","continent"]="Oceania"
df_sur.loc[df_sur["country"]=="People 's Republic of China","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Japan","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Iran","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Singapore","continent"]="Asia"
df_sur.loc[df_sur["country"]=="France","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Spain","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Indonesia","continent"]="Oceania"
df_sur.loc[df_sur["country"]=="Israel","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Egypt","continent"]="Africa"
df_sur.loc[df_sur["country"]=="Hungary","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Argentina","continent"]="South America"
df_sur.loc[df_sur["country"]=="Turkey","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Ukraine","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Greece","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Pakistan","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Finland","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Norway","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Ireland","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Chile","continent"]="South America"
df_sur.loc[df_sur["country"]=="Belarus","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Malaysia","continent"]="Asia"
df_sur.loc[df_sur["country"]=="South Korea","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Nigeria","continent"]="Africa"
df_sur.loc[df_sur["country"]=="Belgium","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Hong Kong","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Republic of China","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Philippines","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Vietnam","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Kenya","continent"]="Africa"
df_sur.loc[df_sur["country"]=="Switzerland","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Romania","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Iran, Islamic Republic of...","continent"]="Asia"
df_sur.loc[df_sur["country"]=='United Kingdom of Great Britain and Northern Ireland',"continent"]="Europe"
df_sur.loc[df_sur["country"]=="China","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Austria","continent"]="Europe"
df_sur.loc[df_sur["country"]=="Hong Kong (S.A.R.)","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Tunisia","continent"]="Africa"
df_sur.loc[df_sur["country"]=="Thailand","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Morocco","continent"]="Africa"
df_sur.loc[df_sur["country"]=="Bangladesh","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Viet Nam","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Peru","continent"]="South America"
df_sur.loc[df_sur["country"]=="Republic of Korea","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Saudi Arabia","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Nepal","continent"]="Asia"
df_sur.loc[df_sur["country"]=="United Arab Emirates","continent"]="Asia"
df_sur.loc[df_sur["country"]=="Ghana","continent"]="Africa"
df_sur.loc[df_sur["country"]=="Sri Lanka","continent"]="Asia"

# %%
df_sur

# %% [markdown]
# # Figure 2: Kaggler Population by Continent

# %%
fig = px.bar(df_sur, x="count", y="continent", color='continent', orientation='h',
             hover_data=["count"],
             height=400,
             animation_frame = "year")
fig.show()

# %% [markdown]
# After seeing these graphs from recent years, we can denote that in kaggler population status, our underdog countries (see figure 1) are the dark purple countries such as Kenya, Morocco etc., and our underdog continents (see figure 2) are Africa.

# %% [markdown]
# # Economic Status

# %% [markdown]
# # Figure 3: Countries by GDP per Capita

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/0/0c/CountriesByGDPPerCapitaNominal2018.png/500px-CountriesByGDPPerCapitaNominal2018.png)
# Source: https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita

# %% [markdown]
# The "underdog" countries and continents that we identified above have a low GDP (red countries). See the below table to view a summary of our underdog countries.

# %%
 df_sur_underdog = df_sur[df_sur["continent"]=="Africa"]

# %%
df_sur_underdog = df_sur_underdog.drop("year",1)

# %%
df_sur_underdog = df_sur_underdog.drop_duplicates(subset=["country"])

# %% [markdown]
# # Figure 4: Table of Underdog Countries

# %%
df_sur_underdog

# %% [markdown]
# # Why don't these countries have access to updated technology and data science?

# %% [markdown]
# # Problem 1: Internet Access

# %% [markdown]
# Many youngsters in Africa cannot attend full-time on campus colleges, and thus can't learn data science and other technologies. They can't attend remotely, because as shown by the below graphs, only 12% of Africans have internet acess.

# %%
df_AfricaInternetUsers = pd.read_csv("/kaggle/input/internet-users-in-africa/AfricaInternetUsers.csv")

# %%
df_AfricaInternetUsers["continent"]="Africa"
df_AfricaInternetUsers = df_AfricaInternetUsers.drop([61])

# %%
for i in range(0,61):
    df_AfricaInternetUsers["Internet\nUsers\n30-SEPT-20"][i] = df_AfricaInternetUsers["Internet\nUsers\n30-SEPT-20"][i].replace(",","")
    df_AfricaInternetUsers["Population\n(2020 Est.)"][i] = df_AfricaInternetUsers["Population\n(2020 Est.)"][i].replace(",","")

# %%
df_tmp1 = pd.to_numeric(df_AfricaInternetUsers["Internet\nUsers\n30-SEPT-20"])
df_AfricaInternetUsers = df_AfricaInternetUsers.append(df_tmp1,1)

# %%
for i in range(0,61): 
    df_AfricaInternetUsers = df_AfricaInternetUsers.drop([i], axis=1)

# %%
df_AfricaInternetUsers_extracted = df_AfricaInternetUsers.drop([61,58,59,60])

# %%
df_AfricaInternetUsers_extracted

# %%
import numpy as np

# %% [markdown]
# # Figure 5: Internet Users by Country (Africa)

# %%
import plotly.express as px

fig = px.bar(df_AfricaInternetUsers_extracted, x='AFRICA', y='Internet\nUsers\n30-SEPT-20',
             hover_data=['Internet\nUsers\n30-SEPT-20','Population\n(2020 Est.)'],color = "AFRICA",
             height=400)
fig.show()

# %% [markdown]
# As compared to countries like India and United States (there are approximately 286,518,600 internet users in the US), Africa's countries have a very low internet usage.

# %%
df_AfricaInternetUsers

# %%
df_AfricaInternetUsers_transformed = pd.DataFrame()
df_AfricaInternetUsers_transformed["Title"] = df_AfricaInternetUsers["AFRICA"][[58,59]]
df_AfricaInternetUsers_transformed["Pop"] = df_AfricaInternetUsers["Population\n(2020 Est.)"][[58,59]]
df_AfricaInternetUsers_transformed["InternetUsers"] = df_AfricaInternetUsers["Internet\nUsers\n30-SEPT-20"][[58,59]]

# %%
df_AfricaInternetUsers_transformed

# %% [markdown]
# # Figure 6: Percentage of Internet Users in Africa

# %%
fig = px.pie(df_AfricaInternetUsers_transformed, values='InternetUsers', names='Title', color='Title',hole=.3)

fig.show()

# %% [markdown]
# # Problem 2: No Electricity

# %% [markdown]
# A lack of reliable, affordable electricity has caused one of the major setbacks in Africa. Without power, there is no internet. The entire digital ecosystem relies so heavily on reliable, affordable electricity, from home internet connections to the base stations that underpin cellular networks to the data centers that store the internet’s content. Demand for more Africa-based data centers is growing dramatically to serve the continent's burgeoning internet use with low-latency and high-bandwidth connectivity.

# %% [markdown]
# Africa's data center industry is expected to grow to 600 megawatts in 2020—and just that growth alone represents a projected capital investment of more than 1 billion in the region. Notably, it is local African businesses, including Vodacom/Safaricom, MTN, Rack Center Nigeria, Africa Data Centers and Teraco that are at the forefront of this growing industry, owning more than 95 percent of data center capacity in the region. But without cheap and reliable power, data centers won't get built in Africa—wasting a tremendous economic opportunity.

# %%
df_elecAfrica = pd.read_csv("/kaggle/input/weo2020electricityaccessdatabase/Africa-Table 1.csv")

# %%
df_elecAfrica = df_elecAfrica.drop(range(0,5))
df_elecAfrica

# %%
df_elec2000 = df_elecAfrica["Unnamed: 2"]
df_elec2000 = df_elec2000.reset_index().drop("index",1).drop([0,1])
df_elec2000["country"] = df_elecAfrica["Unnamed: 2"]
df_elec2000 = df_elec2000.drop("Unnamed: 2",1).drop([2,3,4,5,6]).reset_index().drop("index",1)
df_elec2000["year"] = 2000

# %%
df_elec2005 = df_elecAfrica["Unnamed: 2"]
df_elec2005 = df_elec2005.reset_index().drop("index",1).drop([0,1])
df_elec2005["country"] = df_elecAfrica["Unnamed: 2"]
df_elec2005 = df_elec2005.drop("Unnamed: 2",1).drop([2,3,4,5,6]).reset_index().drop("index",1)
df_elec2005["year"] = 2005

# %%
df_elec2010 = df_elecAfrica["Unnamed: 2"]
df_elec2010 = df_elec2010.reset_index().drop("index",1).drop([0,1])
df_elec2010["country"] = df_elecAfrica["Unnamed: 2"]
df_elec2010 = df_elec2010.drop("Unnamed: 2",1).drop([2,3,4,5,6]).reset_index().drop("index",1)
df_elec2010["year"] = 2010

# %%
df_elec2015 = df_elecAfrica["Unnamed: 2"]
df_elec2015 = df_elec2015.reset_index().drop("index",1).drop([0,1])
df_elec2015["country"] = df_elecAfrica["Unnamed: 2"]
df_elec2015 = df_elec2015.drop("Unnamed: 2",1).drop([2,3,4,5,6]).reset_index().drop("index",1)
df_elec2015["year"] = 2015

# %%
df_elec2019 = df_elecAfrica["Unnamed: 2"]
df_elec2019 = df_elec2019.reset_index().drop("index",1).drop([0,1])
df_elec2019["country"] = df_elecAfrica["Unnamed: 2"]
df_elec2019 = df_elec2019.drop("Unnamed: 2",1).drop([2,3,4,5,6]).reset_index().drop("index",1)
df_elec2019["year"] = 2019

# %%
df_elec2000.loc[df_elec2000["country"]=="North Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][7].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Algeria","usage"]=int(df_elecAfrica["Unnamed: 3"][8].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Egypt","usage"]=int(df_elecAfrica["Unnamed: 3"][9].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Libya","usage"]=100
df_elec2000.loc[df_elec2000["country"]=="Morocco","usage"]=int(df_elecAfrica["Unnamed: 3"][11].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Tunisia","usage"]=int(df_elecAfrica["Unnamed: 3"][12].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Sub-Saharan Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][13].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Central Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][14].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Cameroon","usage"]=int(df_elecAfrica["Unnamed: 3"][15].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Central African Republic","usage"]=int(df_elecAfrica["Unnamed: 3"][16].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Chad","usage"]=int(df_elecAfrica["Unnamed: 3"][17].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][18].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Democratic Republic of the Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][19].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Gabon","usage"]=int(df_elecAfrica["Unnamed: 3"][20].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="East Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][21].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Burundi","usage"]=int(df_elecAfrica["Unnamed: 3"][22].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Djibouti","usage"]=int(df_elecAfrica["Unnamed: 3"][23].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Eritrea","usage"]=int(df_elecAfrica["Unnamed: 3"][24].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Ethiopia","usage"]=int(df_elecAfrica["Unnamed: 3"][25].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Kenya","usage"]=int(df_elecAfrica["Unnamed: 3"][26].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Rwanda","usage"]=int(df_elecAfrica["Unnamed: 3"][27].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Somalia","usage"]=int(df_elecAfrica["Unnamed: 3"][28].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="South Sudan","usage"]=int(df_elecAfrica["Unnamed: 3"][29].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Sudan","usage"]=0
df_elec2000.loc[df_elec2000["country"]=="Uganda","usage"]=int(df_elecAfrica["Unnamed: 3"][31].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="West Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][32].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Nigeria","usage"]=int(df_elecAfrica["Unnamed: 3"][33].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Benin","usage"]=int(df_elecAfrica["Unnamed: 3"][34].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Cote d'Ivoire","usage"]=int(df_elecAfrica["Unnamed: 3"][35].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Ghana","usage"]=int(df_elecAfrica["Unnamed: 3"][36].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Senegal","usage"]=int(df_elecAfrica["Unnamed: 3"][37].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Togo","usage"]=int(df_elecAfrica["Unnamed: 3"][38].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Burkina Faso","usage"]=int(df_elecAfrica["Unnamed: 3"][39].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Cape Verde","usage"]=int(df_elecAfrica["Unnamed: 3"][40].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Gambia","usage"]=int(df_elecAfrica["Unnamed: 3"][41].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Guinea","usage"]=int(df_elecAfrica["Unnamed: 3"][42].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Guinea-Bissau","usage"]=int(df_elecAfrica["Unnamed: 3"][43].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Liberia","usage"]=int(df_elecAfrica["Unnamed: 3"][44].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Mali","usage"]=0
df_elec2000.loc[df_elec2000["country"]=="Mauritania","usage"]=int(df_elecAfrica["Unnamed: 3"][46].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Niger","usage"]=int(df_elecAfrica["Unnamed: 3"][47].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Sao Tome and Principe","usage"]=int(df_elecAfrica["Unnamed: 3"][48].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Sierra Leone","usage"]=int(df_elecAfrica["Unnamed: 3"][49].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="South Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][50].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Other Southern Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][51].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Angola","usage"]=int(df_elecAfrica["Unnamed: 3"][52].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Botswana","usage"]=int(df_elecAfrica["Unnamed: 3"][53].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Comoros","usage"]=int(df_elecAfrica["Unnamed: 3"][54].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Lesotho","usage"]=int(df_elecAfrica["Unnamed: 3"][55].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Madagascar","usage"]=int(df_elecAfrica["Unnamed: 3"][56].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Malawi","usage"]=int(df_elecAfrica["Unnamed: 3"][57].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Mauritius","usage"]=int(df_elecAfrica["Unnamed: 3"][58].rstrip("%"))
df_elec2000.loc[df_elec2000["country"]=="Mozambique","usage"]=100
df_elec2000.loc[df_elec2000["country"]=="Namibia","usage"]=int(df_elecAfrica["Unnamed: 3"][60].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="North Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][7].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Algeria","usage"]=int(df_elecAfrica["Unnamed: 3"][8].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Egypt","usage"]=int(df_elecAfrica["Unnamed: 3"][9].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Libya","usage"]=100
df_elec2005.loc[df_elec2005["country"]=="Morocco","usage"]=int(df_elecAfrica["Unnamed: 3"][11].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Tunisia","usage"]=int(df_elecAfrica["Unnamed: 3"][12].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Sub-Saharan Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][13].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Central Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][14].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Cameroon","usage"]=int(df_elecAfrica["Unnamed: 3"][15].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Central African Republic","usage"]=int(df_elecAfrica["Unnamed: 3"][16].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Chad","usage"]=int(df_elecAfrica["Unnamed: 3"][17].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][18].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Democratic Republic of the Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][19].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Gabon","usage"]=int(df_elecAfrica["Unnamed: 3"][20].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="East Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][21].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Burundi","usage"]=int(df_elecAfrica["Unnamed: 3"][22].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Djibouti","usage"]=int(df_elecAfrica["Unnamed: 3"][23].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Eritrea","usage"]=int(df_elecAfrica["Unnamed: 3"][24].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Ethiopia","usage"]=int(df_elecAfrica["Unnamed: 3"][25].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Kenya","usage"]=int(df_elecAfrica["Unnamed: 3"][26].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Rwanda","usage"]=int(df_elecAfrica["Unnamed: 3"][27].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Somalia","usage"]=int(df_elecAfrica["Unnamed: 3"][28].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="South Sudan","usage"]=int(df_elecAfrica["Unnamed: 3"][29].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Sudan","usage"]=0
df_elec2005.loc[df_elec2005["country"]=="Uganda","usage"]=int(df_elecAfrica["Unnamed: 3"][31].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="West Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][32].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Nigeria","usage"]=int(df_elecAfrica["Unnamed: 3"][33].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Benin","usage"]=int(df_elecAfrica["Unnamed: 3"][34].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Cote d'Ivoire","usage"]=int(df_elecAfrica["Unnamed: 3"][35].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Ghana","usage"]=int(df_elecAfrica["Unnamed: 3"][36].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Senegal","usage"]=int(df_elecAfrica["Unnamed: 3"][37].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Togo","usage"]=int(df_elecAfrica["Unnamed: 3"][38].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Burkina Faso","usage"]=int(df_elecAfrica["Unnamed: 3"][39].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Cape Verde","usage"]=int(df_elecAfrica["Unnamed: 3"][40].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Gambia","usage"]=int(df_elecAfrica["Unnamed: 3"][41].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Guinea","usage"]=int(df_elecAfrica["Unnamed: 3"][42].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Guinea-Bissau","usage"]=int(df_elecAfrica["Unnamed: 3"][43].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Liberia","usage"]=int(df_elecAfrica["Unnamed: 3"][44].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Mali","usage"]=0
df_elec2005.loc[df_elec2005["country"]=="Mauritania","usage"]=int(df_elecAfrica["Unnamed: 3"][46].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Niger","usage"]=int(df_elecAfrica["Unnamed: 3"][47].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Sao Tome and Principe","usage"]=int(df_elecAfrica["Unnamed: 3"][48].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Sierra Leone","usage"]=int(df_elecAfrica["Unnamed: 3"][49].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="South Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][50].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Other Southern Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][51].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Angola","usage"]=int(df_elecAfrica["Unnamed: 3"][52].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Botswana","usage"]=int(df_elecAfrica["Unnamed: 3"][53].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Comoros","usage"]=int(df_elecAfrica["Unnamed: 3"][54].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Lesotho","usage"]=int(df_elecAfrica["Unnamed: 3"][55].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Madagascar","usage"]=int(df_elecAfrica["Unnamed: 3"][56].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Malawi","usage"]=int(df_elecAfrica["Unnamed: 3"][57].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Mauritius","usage"]=int(df_elecAfrica["Unnamed: 3"][58].rstrip("%"))
df_elec2005.loc[df_elec2005["country"]=="Mozambique","usage"]=100
df_elec2005.loc[df_elec2005["country"]=="Namibia","usage"]=int(df_elecAfrica["Unnamed: 3"][60].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="North Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][7].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Algeria","usage"]=int(df_elecAfrica["Unnamed: 3"][8].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Egypt","usage"]=int(df_elecAfrica["Unnamed: 3"][9].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Libya","usage"]=100
df_elec2010.loc[df_elec2010["country"]=="Morocco","usage"]=int(df_elecAfrica["Unnamed: 3"][11].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Tunisia","usage"]=int(df_elecAfrica["Unnamed: 3"][12].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Sub-Saharan Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][13].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Central Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][14].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Cameroon","usage"]=int(df_elecAfrica["Unnamed: 3"][15].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Central African Republic","usage"]=int(df_elecAfrica["Unnamed: 3"][16].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Chad","usage"]=int(df_elecAfrica["Unnamed: 3"][17].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][18].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Democratic Republic of the Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][19].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Gabon","usage"]=int(df_elecAfrica["Unnamed: 3"][20].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="East Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][21].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Burundi","usage"]=int(df_elecAfrica["Unnamed: 3"][22].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Djibouti","usage"]=int(df_elecAfrica["Unnamed: 3"][23].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Eritrea","usage"]=int(df_elecAfrica["Unnamed: 3"][24].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Ethiopia","usage"]=int(df_elecAfrica["Unnamed: 3"][25].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Kenya","usage"]=int(df_elecAfrica["Unnamed: 3"][26].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Rwanda","usage"]=int(df_elecAfrica["Unnamed: 3"][27].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Somalia","usage"]=int(df_elecAfrica["Unnamed: 3"][28].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="South Sudan","usage"]=int(df_elecAfrica["Unnamed: 3"][29].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Sudan","usage"]=0
df_elec2010.loc[df_elec2010["country"]=="Uganda","usage"]=int(df_elecAfrica["Unnamed: 3"][31].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="West Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][32].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Nigeria","usage"]=int(df_elecAfrica["Unnamed: 3"][33].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Benin","usage"]=int(df_elecAfrica["Unnamed: 3"][34].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Cote d'Ivoire","usage"]=int(df_elecAfrica["Unnamed: 3"][35].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Ghana","usage"]=int(df_elecAfrica["Unnamed: 3"][36].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Senegal","usage"]=int(df_elecAfrica["Unnamed: 3"][37].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Togo","usage"]=int(df_elecAfrica["Unnamed: 3"][38].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Burkina Faso","usage"]=int(df_elecAfrica["Unnamed: 3"][39].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Cape Verde","usage"]=int(df_elecAfrica["Unnamed: 3"][40].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Gambia","usage"]=int(df_elecAfrica["Unnamed: 3"][41].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Guinea","usage"]=int(df_elecAfrica["Unnamed: 3"][42].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Guinea-Bissau","usage"]=int(df_elecAfrica["Unnamed: 3"][43].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Liberia","usage"]=int(df_elecAfrica["Unnamed: 3"][44].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Mali","usage"]=0
df_elec2010.loc[df_elec2010["country"]=="Mauritania","usage"]=int(df_elecAfrica["Unnamed: 3"][46].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Niger","usage"]=int(df_elecAfrica["Unnamed: 3"][47].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Sao Tome and Principe","usage"]=int(df_elecAfrica["Unnamed: 3"][48].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Sierra Leone","usage"]=int(df_elecAfrica["Unnamed: 3"][49].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="South Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][50].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Other Southern Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][51].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Angola","usage"]=int(df_elecAfrica["Unnamed: 3"][52].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Botswana","usage"]=int(df_elecAfrica["Unnamed: 3"][53].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Comoros","usage"]=int(df_elecAfrica["Unnamed: 3"][54].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Lesotho","usage"]=int(df_elecAfrica["Unnamed: 3"][55].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Madagascar","usage"]=int(df_elecAfrica["Unnamed: 3"][56].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Malawi","usage"]=int(df_elecAfrica["Unnamed: 3"][57].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Mauritius","usage"]=int(df_elecAfrica["Unnamed: 3"][58].rstrip("%"))
df_elec2010.loc[df_elec2010["country"]=="Mozambique","usage"]=100
df_elec2010.loc[df_elec2010["country"]=="Namibia","usage"]=int(df_elecAfrica["Unnamed: 3"][60].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="North Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][7].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Algeria","usage"]=int(df_elecAfrica["Unnamed: 3"][8].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Egypt","usage"]=int(df_elecAfrica["Unnamed: 3"][9].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Libya","usage"]=100
df_elec2015.loc[df_elec2015["country"]=="Morocco","usage"]=int(df_elecAfrica["Unnamed: 3"][11].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Tunisia","usage"]=int(df_elecAfrica["Unnamed: 3"][12].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Sub-Saharan Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][13].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Central Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][14].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Cameroon","usage"]=int(df_elecAfrica["Unnamed: 3"][15].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Central African Republic","usage"]=int(df_elecAfrica["Unnamed: 3"][16].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Chad","usage"]=int(df_elecAfrica["Unnamed: 3"][17].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][18].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Democratic Republic of the Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][19].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Gabon","usage"]=int(df_elecAfrica["Unnamed: 3"][20].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="East Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][21].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Burundi","usage"]=int(df_elecAfrica["Unnamed: 3"][22].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Djibouti","usage"]=int(df_elecAfrica["Unnamed: 3"][23].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Eritrea","usage"]=int(df_elecAfrica["Unnamed: 3"][24].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Ethiopia","usage"]=int(df_elecAfrica["Unnamed: 3"][25].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Kenya","usage"]=int(df_elecAfrica["Unnamed: 3"][26].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Rwanda","usage"]=int(df_elecAfrica["Unnamed: 3"][27].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Somalia","usage"]=int(df_elecAfrica["Unnamed: 3"][28].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="South Sudan","usage"]=int(df_elecAfrica["Unnamed: 3"][29].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Sudan","usage"]=0
df_elec2015.loc[df_elec2015["country"]=="Uganda","usage"]=int(df_elecAfrica["Unnamed: 3"][31].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="West Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][32].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Nigeria","usage"]=int(df_elecAfrica["Unnamed: 3"][33].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Benin","usage"]=int(df_elecAfrica["Unnamed: 3"][34].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Cote d'Ivoire","usage"]=int(df_elecAfrica["Unnamed: 3"][35].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Ghana","usage"]=int(df_elecAfrica["Unnamed: 3"][36].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Senegal","usage"]=int(df_elecAfrica["Unnamed: 3"][37].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Togo","usage"]=int(df_elecAfrica["Unnamed: 3"][38].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Burkina Faso","usage"]=int(df_elecAfrica["Unnamed: 3"][39].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Cape Verde","usage"]=int(df_elecAfrica["Unnamed: 3"][40].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Gambia","usage"]=int(df_elecAfrica["Unnamed: 3"][41].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Guinea","usage"]=int(df_elecAfrica["Unnamed: 3"][42].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Guinea-Bissau","usage"]=int(df_elecAfrica["Unnamed: 3"][43].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Liberia","usage"]=int(df_elecAfrica["Unnamed: 3"][44].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Mali","usage"]=0
df_elec2015.loc[df_elec2015["country"]=="Mauritania","usage"]=int(df_elecAfrica["Unnamed: 3"][46].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Niger","usage"]=int(df_elecAfrica["Unnamed: 3"][47].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Sao Tome and Principe","usage"]=int(df_elecAfrica["Unnamed: 3"][48].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Sierra Leone","usage"]=int(df_elecAfrica["Unnamed: 3"][49].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="South Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][50].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Other Southern Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][51].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Angola","usage"]=int(df_elecAfrica["Unnamed: 3"][52].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Botswana","usage"]=int(df_elecAfrica["Unnamed: 3"][53].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Comoros","usage"]=int(df_elecAfrica["Unnamed: 3"][54].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Lesotho","usage"]=int(df_elecAfrica["Unnamed: 3"][55].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Madagascar","usage"]=int(df_elecAfrica["Unnamed: 3"][56].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Malawi","usage"]=int(df_elecAfrica["Unnamed: 3"][57].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Mauritius","usage"]=int(df_elecAfrica["Unnamed: 3"][58].rstrip("%"))
df_elec2015.loc[df_elec2015["country"]=="Mozambique","usage"]=100
df_elec2015.loc[df_elec2015["country"]=="Namibia","usage"]=int(df_elecAfrica["Unnamed: 3"][60].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="North Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][7].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Algeria","usage"]=int(df_elecAfrica["Unnamed: 3"][8].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Egypt","usage"]=int(df_elecAfrica["Unnamed: 3"][9].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Libya","usage"]=100
df_elec2019.loc[df_elec2019["country"]=="Morocco","usage"]=int(df_elecAfrica["Unnamed: 3"][11].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Tunisia","usage"]=int(df_elecAfrica["Unnamed: 3"][12].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Sub-Saharan Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][13].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Central Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][14].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Cameroon","usage"]=int(df_elecAfrica["Unnamed: 3"][15].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Central African Republic","usage"]=int(df_elecAfrica["Unnamed: 3"][16].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Chad","usage"]=int(df_elecAfrica["Unnamed: 3"][17].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][18].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Democratic Republic of the Congo","usage"]=int(df_elecAfrica["Unnamed: 3"][19].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Gabon","usage"]=int(df_elecAfrica["Unnamed: 3"][20].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="East Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][21].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Burundi","usage"]=int(df_elecAfrica["Unnamed: 3"][22].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Djibouti","usage"]=int(df_elecAfrica["Unnamed: 3"][23].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Eritrea","usage"]=int(df_elecAfrica["Unnamed: 3"][24].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Ethiopia","usage"]=int(df_elecAfrica["Unnamed: 3"][25].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Kenya","usage"]=int(df_elecAfrica["Unnamed: 3"][26].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Rwanda","usage"]=int(df_elecAfrica["Unnamed: 3"][27].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Somalia","usage"]=int(df_elecAfrica["Unnamed: 3"][28].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="South Sudan","usage"]=int(df_elecAfrica["Unnamed: 3"][29].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Sudan","usage"]=0
df_elec2019.loc[df_elec2019["country"]=="Uganda","usage"]=int(df_elecAfrica["Unnamed: 3"][31].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="West Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][32].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Nigeria","usage"]=int(df_elecAfrica["Unnamed: 3"][33].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Benin","usage"]=int(df_elecAfrica["Unnamed: 3"][34].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Cote d'Ivoire","usage"]=int(df_elecAfrica["Unnamed: 3"][35].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Ghana","usage"]=int(df_elecAfrica["Unnamed: 3"][36].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Senegal","usage"]=int(df_elecAfrica["Unnamed: 3"][37].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Togo","usage"]=int(df_elecAfrica["Unnamed: 3"][38].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Burkina Faso","usage"]=int(df_elecAfrica["Unnamed: 3"][39].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Cape Verde","usage"]=int(df_elecAfrica["Unnamed: 3"][40].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Gambia","usage"]=int(df_elecAfrica["Unnamed: 3"][41].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Guinea","usage"]=int(df_elecAfrica["Unnamed: 3"][42].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Guinea-Bissau","usage"]=int(df_elecAfrica["Unnamed: 3"][43].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Liberia","usage"]=int(df_elecAfrica["Unnamed: 3"][44].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Mali","usage"]=0
df_elec2019.loc[df_elec2019["country"]=="Mauritania","usage"]=int(df_elecAfrica["Unnamed: 3"][46].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Niger","usage"]=int(df_elecAfrica["Unnamed: 3"][47].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Sao Tome and Principe","usage"]=int(df_elecAfrica["Unnamed: 3"][48].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Sierra Leone","usage"]=int(df_elecAfrica["Unnamed: 3"][49].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="South Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][50].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Other Southern Africa","usage"]=int(df_elecAfrica["Unnamed: 3"][51].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Angola","usage"]=int(df_elecAfrica["Unnamed: 3"][52].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Botswana","usage"]=int(df_elecAfrica["Unnamed: 3"][53].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Comoros","usage"]=int(df_elecAfrica["Unnamed: 3"][54].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Lesotho","usage"]=int(df_elecAfrica["Unnamed: 3"][55].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Madagascar","usage"]=int(df_elecAfrica["Unnamed: 3"][56].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Malawi","usage"]=int(df_elecAfrica["Unnamed: 3"][57].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Mauritius","usage"]=int(df_elecAfrica["Unnamed: 3"][58].rstrip("%"))
df_elec2019.loc[df_elec2019["country"]=="Mozambique","usage"]=100
df_elec2019.loc[df_elec2019["country"]=="Namibia","usage"]=int(df_elecAfrica["Unnamed: 3"][60].rstrip("%"))

# %%
df_elec = df_elec2000.append(df_elec2005.append(df_elec2010.append(df_elec2015.append(df_elec2019))))

# %%
df_elec.loc[df_elec["country"]=="India","iso_alpha"]="IND"
df_elec.loc[df_elec["country"]=="Algeria","iso_alpha"]="DZA"
df_elec.loc[df_elec["country"]=="United States","iso_alpha"]="USA"
df_elec.loc[df_elec["country"]=="United States of America","iso_alpha"]="USA"
df_elec.loc[df_elec["country"]=="Canada","iso_alpha"]="CAN"
df_elec.loc[df_elec["country"]=="Taiwan","iso_alpha"]="TWN"
df_elec.loc[df_elec["country"]=="Brazil","iso_alpha"]="BRA"
df_elec.loc[df_elec["country"]=="Australia","iso_alpha"]="AUS"
df_elec.loc[df_elec["country"]=="Russia","iso_alpha"]="RUS"
df_elec.loc[df_elec["country"]=="Netherlands","iso_alpha"]="NLD"
df_elec.loc[df_elec["country"]=="Italy","iso_alpha"]="ITA"
df_elec.loc[df_elec["country"]=="United Kingdom","iso_alpha"]="GBR"
df_elec.loc[df_elec["country"]=="Czech Republic","iso_alpha"]="CZE"
df_elec.loc[df_elec["country"]=="Colombia","iso_alpha"]="COL"
df_elec.loc[df_elec["country"]=="Germany","iso_alpha"]="DEU"
df_elec.loc[df_elec["country"]=="Denmark","iso_alpha"]="DNK"
df_elec.loc[df_elec["country"]=="Poland","iso_alpha"]="POL"
df_elec.loc[df_elec["country"]=="South Africa","iso_alpha"]="ZAF"
df_elec.loc[df_elec["country"]=="Sweden","iso_alpha"]="SWE"
df_elec.loc[df_elec["country"]=="Portugal","iso_alpha"]="PRT"
df_elec.loc[df_elec["country"]=="Mexico","iso_alpha"]="MEX"
df_elec.loc[df_elec["country"]=="New Zealand","iso_alpha"]="NZL"
df_elec.loc[df_elec["country"]=="People 's Republic of China","iso_alpha"]="CHN"
df_elec.loc[df_elec["country"]=="Japan","iso_alpha"]="JPN"
df_elec.loc[df_elec["country"]=="Iran","iso_alpha"]="IRN"
df_elec.loc[df_elec["country"]=="Singapore","iso_alpha"]="SGP"
df_elec.loc[df_elec["country"]=="France","iso_alpha"]="FRA"
df_elec.loc[df_elec["country"]=="Spain","iso_alpha"]="ESP"
df_elec.loc[df_elec["country"]=="Indonesia","iso_alpha"]="IDN"
df_elec.loc[df_elec["country"]=="Israel","iso_alpha"]="ISR"
df_elec.loc[df_elec["country"]=="Egypt","iso_alpha"]="EGY"
df_elec.loc[df_elec["country"]=="Hungary","iso_alpha"]="HUN"
df_elec.loc[df_elec["country"]=="Argentina","iso_alpha"]="ARG"
df_elec.loc[df_elec["country"]=="Turkey","iso_alpha"]="TUR"
df_elec.loc[df_elec["country"]=="Ukraine","iso_alpha"]="UKR"
df_elec.loc[df_elec["country"]=="Greece","iso_alpha"]="GRC"
df_elec.loc[df_elec["country"]=="Pakistan","iso_alpha"]="PAK"
df_elec.loc[df_elec["country"]=="Finland","iso_alpha"]="FIN"
df_elec.loc[df_elec["country"]=="Norway","iso_alpha"]="NOR"
df_elec.loc[df_elec["country"]=="Ireland","iso_alpha"]="IRL"
df_elec.loc[df_elec["country"]=="Chile","iso_alpha"]="CHL"
df_elec.loc[df_elec["country"]=="Belarus","iso_alpha"]="BLR"
df_elec.loc[df_elec["country"]=="Malaysia","iso_alpha"]="MYS"
df_elec.loc[df_elec["country"]=="South Korea","iso_alpha"]="KOR"
df_elec.loc[df_elec["country"]=="Nigeria","iso_alpha"]="NGA"
df_elec.loc[df_elec["country"]=="Belgium","iso_alpha"]="BEL"
df_elec.loc[df_elec["country"]=="Hong Kong","iso_alpha"]="HKG"
df_elec.loc[df_elec["country"]=="Republic of China","iso_alpha"]="CHN"
df_elec.loc[df_elec["country"]=="Philippines","iso_alpha"]="PHL"
df_elec.loc[df_elec["country"]=="Vietnam","iso_alpha"]="VNM"
df_elec.loc[df_elec["country"]=="Kenya","iso_alpha"]="KEN"
df_elec.loc[df_elec["country"]=="Switzerland","iso_alpha"]="CHE"
df_elec.loc[df_elec["country"]=="Romania","iso_alpha"]="ROU"
df_elec.loc[df_elec["country"]=="Iran, Islamic Republic of...","iso_alpha"]="IRN"
df_elec.loc[df_elec["country"]=='United Kingdom of Great Britain and Northern Ireland',"iso_alpha"]="GBR"
df_elec.loc[df_elec["country"]=="China","iso_alpha"]="CHN"
df_elec.loc[df_elec["country"]=="Austria","iso_alpha"]="AUT"
df_elec.loc[df_elec["country"]=="Hong Kong (S.A.R.)","iso_alpha"]="HKG"
df_elec.loc[df_elec["country"]=="Tunisia","iso_alpha"]="TUN"
df_elec.loc[df_elec["country"]=="Thailand","iso_alpha"]="THA"
df_elec.loc[df_elec["country"]=="Morocco","iso_alpha"]="MAR"
df_elec.loc[df_elec["country"]=="Bangladesh","iso_alpha"]="BGD"
df_elec.loc[df_elec["country"]=="Viet Nam","iso_alpha"]="VNM"
df_elec.loc[df_elec["country"]=="Peru","iso_alpha"]="PER"
df_elec.loc[df_elec["country"]=="Republic of Korea","iso_alpha"]="KOR"
df_elec.loc[df_elec["country"]=="Saudi Arabia","iso_alpha"]="SAU"
df_elec.loc[df_elec["country"]=="Nepal","iso_alpha"]="NPL"
df_elec.loc[df_elec["country"]=="United Arab Emirates","iso_alpha"]="ARE"
df_elec.loc[df_elec["country"]=="Ghana","iso_alpha"]="GHA"
df_elec.loc[df_elec["country"]=="Sri Lanka","iso_alpha"]="LKA"
df_elec.loc[df_elec["country"]=="Libya","iso_alpha"]="LBY"
df_elec.loc[df_elec["country"]=="Cameroon","iso_alpha"]="CMR"
df_elec.loc[df_elec["country"]=="Central African Republic","iso_alpha"]="CAF"
df_elec.loc[df_elec["country"]=="Chad","iso_alpha"]="TCD"
df_elec.loc[df_elec["country"]=="Congo","iso_alpha"]="COD"
df_elec.loc[df_elec["country"]=="Democratic Republic of Congo","iso_alpha"]="COD"
df_elec.loc[df_elec["country"]=="Equatorial Guinea","iso_alpha"]="GNQ"
df_elec.loc[df_elec["country"]=="Gabon","iso_alpha"]="GAB"
df_elec.loc[df_elec["country"]=="Burundi","iso_alpha"]="BDI"
df_elec.loc[df_elec["country"]=="Dijbouti","iso_alpha"]="DJI"
df_elec.loc[df_elec["country"]=="Eritrea","iso_alpha"]="ERI"
df_elec.loc[df_elec["country"]=="Ethiopia","iso_alpha"]="ETH"
df_elec.loc[df_elec["country"]=="Rwanda","iso_alpha"]="RWA"
df_elec.loc[df_elec["country"]=="Somalia","iso_alpha"]="SOM"
df_elec.loc[df_elec["country"]=="South Sudan","iso_alpha"]="SSD"
df_elec.loc[df_elec["country"]=="Sudan","iso_alpha"]="SDN"
df_elec.loc[df_elec["country"]=="Uganda","iso_alpha"]="UGA"
df_elec.loc[df_elec["country"]=="Benin","iso_alpha"]="BEN"
df_elec.loc[df_elec["country"]=="Cote d'Ivoire","iso_alpha"]="CIV"
df_elec.loc[df_elec["country"]=="Senegal","iso_alpha"]="SEN"
df_elec.loc[df_elec["country"]=="Togo","iso_alpha"]="TGO"
df_elec.loc[df_elec["country"]=="Burkina Faso","iso_alpha"]="BFA"
df_elec.loc[df_elec["country"]=="Cape Verde","iso_alpha"]="CPV"
df_elec.loc[df_elec["country"]=="Gambia","iso_alpha"]="GMB"
df_elec.loc[df_elec["country"]=="Guinea","iso_alpha"]="GIN"
df_elec.loc[df_elec["country"]=="Guinea-Bissau","iso_alpha"]="BEN"
df_elec.loc[df_elec["country"]=="Liberia","iso_alpha"]="LBR"
df_elec.loc[df_elec["country"]=="Mali","iso_alpha"]="MLI"
df_elec.loc[df_elec["country"]=="Niger","iso_alpha"]="NER"
df_elec.loc[df_elec["country"]=="Sao Tome and Principe","iso_alpha"]="STP"
df_elec.loc[df_elec["country"]=="Sierra Leone","iso_alpha"]="SLE"
df_elec.loc[df_elec["country"]=="Angola","iso_alpha"]="AGO"
df_elec.loc[df_elec["country"]=="Botswana","iso_alpha"]="BWA"
df_elec.loc[df_elec["country"]=="Comoros","iso_alpha"]="COM"
df_elec.loc[df_elec["country"]=="Lesotho","iso_alpha"]="LSO"
df_elec.loc[df_elec["country"]=="Madagascar","iso_alpha"]="MDG"
df_elec.loc[df_elec["country"]=="Malawi","iso_alpha"]="STP"
df_elec.loc[df_elec["country"]=="Mauritius","iso_alpha"]="MUS"
df_elec.loc[df_elec["country"]=="Mozambique","iso_alpha"]="MOZ"
df_elec.loc[df_elec["country"]=="Namibia","iso_alpha"]="NAM"

# %%
df_elec

# %%
fig = px.choropleth(df_elec, geojson=countries, locations='iso_alpha', color='usage',
                           color_continuous_scale="Viridis",
                           range_color=(0, 100),
                           scope="africa",
                           animation_frame = "year"
                          )

fig.show()

# %% [markdown]
# # Problem 3: Lack of data science courses and research programs

# %% [markdown]
# There is not enough resources from which to learn from in Africa. There should be more webinars and events hosted in Africa related to data science to generate interest. Companies like Google and Amazon should support local colleges so they can offer up-to-date courses on data science. Many efforts need to be made for Africa to reach its full potential in data science and become a challenger of tomorrow.

# %%
import plotly.graph_objects as go

# %%
df_sur_ed2018 = pd.read_csv("/kaggle/input/kaggle-survey-2018/multipleChoiceResponses.csv")
df_sur_ed2019 = pd.read_csv("/kaggle/input/kaggle-2019-survey-copy/multiple_choice_responses.csv")
df_sur_ed2020 = pd.read_csv("/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")

# %%
df_sur_ed2018["year"]=2018
df_sur_ed2019["year"]=2019
df_sur_ed2020["year"]=2020

# %%
df_sur_ed2018 = df_sur_ed2018.drop([0])
df_sur_ed2020 = df_sur_ed2020.drop([0])
df_sur_ed2019 = df_sur_ed2019.drop([0])

# %%
df_sur_ed = df_sur_ed2020.append(df_sur_ed2018.append(df_sur_ed2019,ignore_index=True))
df_sur_ed

# %%
df_sur_ed.loc[df_sur_ed["Q3"]=="India","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Algeria","continent"]="Africa"
df_sur_ed.loc[df_sur_ed["Q3"]=="United States","continent"]="North America"
df_sur_ed.loc[df_sur_ed["Q3"]=="United States of America","continent"]="North America"
df_sur_ed.loc[df_sur_ed["Q3"]=="Canada","continent"]="North America"
df_sur_ed.loc[df_sur_ed["Q3"]=="Taiwan","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Brazil","continent"]="South America"
df_sur_ed.loc[df_sur_ed["Q3"]=="Australia","continent"]="Oceania"
df_sur_ed.loc[df_sur_ed["Q3"]=="Russia","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Netherlands","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Italy","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="United Kingdom","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Czech Republic","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Colombia","continent"]="South America"
df_sur_ed.loc[df_sur_ed["Q3"]=="Germany","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Denmark","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Poland","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="South Africa","continent"]="Africa"
df_sur_ed.loc[df_sur_ed["Q3"]=="Sweden","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Portugal","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Mexico","continent"]="North America"
df_sur_ed.loc[df_sur_ed["Q3"]=="New Zealand","continent"]="Oceania"
df_sur_ed.loc[df_sur_ed["Q3"]=="People 's Republic of China","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Japan","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Iran","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Singapore","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="France","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Spain","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Indonesia","continent"]="Oceania"
df_sur_ed.loc[df_sur_ed["Q3"]=="Israel","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Egypt","continent"]="Africa"
df_sur_ed.loc[df_sur_ed["Q3"]=="Hungary","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Argentina","continent"]="South America"
df_sur_ed.loc[df_sur_ed["Q3"]=="Turkey","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Ukraine","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Greece","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Pakistan","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Finland","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Norway","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Ireland","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Chile","continent"]="South America"
df_sur_ed.loc[df_sur_ed["Q3"]=="Belarus","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Malaysia","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="South Korea","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Nigeria","continent"]="Africa"
df_sur_ed.loc[df_sur_ed["Q3"]=="Belgium","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Hong Kong","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Republic of China","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Philippines","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Vietnam","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Kenya","continent"]="Africa"
df_sur_ed.loc[df_sur_ed["Q3"]=="Switzerland","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Romania","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Iran, Islamic Republic of...","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=='United Kingdom of Great Britain and Northern Ireland',"continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="China","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Austria","continent"]="Europe"
df_sur_ed.loc[df_sur_ed["Q3"]=="Hong Kong (S.A.R.)","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Tunisia","continent"]="Africa"
df_sur_ed.loc[df_sur_ed["Q3"]=="Thailand","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Morocco","continent"]="Africa"
df_sur_ed.loc[df_sur_ed["Q3"]=="Bangladesh","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Viet Nam","continent"]="Asia"
df_sur_ed.loc[df_sur_ed["Q3"]=="Peru","continent"]="South America"

# %%
df_sur_ed_final = df_sur_ed
df_sur_ed = df_sur_ed.loc[df_sur_ed["continent"]=="Africa"]
df_sur_ed

# %%
res = []
[res.append(x) for x in df_sur_ed["Q4"] if x not in res]
print(res)

# %%
df_sur_ed["Q4"].value_counts()

# %% [markdown]
# # Figure 7: Education in Africa

# %%
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen']

fig = go.Figure(data=[go.Pie(labels=["Study without bachelor's degree","Bachelor's degree","Master's degree","Doctoral degree", "Professional degree","No formal education past high school"],
                             values=[27263,20054,8426,2896,1909,705],hole=.3)])
fig.update_traces(hoverinfo='label+percent', textfont_size=20,
                  marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.show()

# %% [markdown]
# This graph shows how much of each education area Africans are in. See the below graph to see how many college degrees are obtained by Africans compared to other countries.

# %%
df_sur_ed_final = df_sur_ed_final[["Q4","Q3","continent","year"]]

# %%
df_sur_ed_final = df_sur_ed_final.dropna()

# %%
df_sur_ed["Q4"].value_counts()

# %%
df_sur_ed_final.loc[df_sur_ed_final["Q4"]=="Bachelor’s degree","id"]=1
df_sur_ed_final.loc[df_sur_ed_final["Q4"]=="Master’s degree","id"]=1
df_sur_ed_final.loc[df_sur_ed_final["Q4"]=="Doctoral degree","id"]=1
df_sur_ed_final.loc[df_sur_ed_final["Q4"]=="Some college/university study without earning a bachelor’s degree","id"]=1
df_sur_ed_final.loc[df_sur_ed_final["Q4"]=="Professional degree","id"]=1
df_sur_ed_final.loc[df_sur_ed_final["Q4"]=="I prefer not to answer","id"]=0
df_sur_ed_final.loc[df_sur_ed_final["Q4"]=="No formal education past high school","id"]=0

# %%
df_sur_ed_final

# %% [markdown]
# # Figure 8: College degrees obtained country-to-country comparison

# %%
fig = px.sunburst(df_sur_ed_final, path=['year','continent', 'Q3'], values='id', color='id')
fig.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Africa is a goldmine waiting to be opened. It can rise as a challenger and key player of data science. Now, it is in the hands of projects and companies whether they realize the potential.
# ![](https://i.pinimg.com/originals/20/c0/27/20c0271883ddbbeda8aaa106b9c57066.gif)
# Hope you saw why the underdogs of the world will grab at the chance to improve their lives and status with the **power of data science**.

# %% [markdown]
# # Sources
#
# * [https://www.scientificamerican.com/article/why-hasnt-africa-gone-digital/](https://www.scientificamerican.com/article/why-hasnt-africa-gone-digital/)
# * [https://www.google.com/amp/s/qz.com/africa/1683977/why-data-science-is-crucial-to-africa-development/amp/](https://www.google.com/amp/s/qz.com/africa/1683977/why-data-science-is-crucial-to-africa-development/amp/)
# * [https://blogs.worldbank.org/opendata/preparing-africas-next-generation-leadership-digital-data-and-innovation](https://blogs.worldbank.org/opendata/preparing-africas-next-generation-leadership-digital-data-and-innovation)
# * [https://www.scidev.net/sub-saharan-africa/news/bringing-big-data-science-to-africa/](https://www.scidev.net/sub-saharan-africa/news/bringing-big-data-science-to-africa/)
# * [https://www.2030vision.com/projects/data-science-africa](https://www.2030vision.com/projects/data-science-africa)
