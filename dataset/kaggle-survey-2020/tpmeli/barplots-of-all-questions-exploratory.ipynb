# %% [markdown]
# ## Use this as a visual aid to guide your investigation ##
#
# I thought it would be useful to be able to see all of the barplots in one place so you can
# generate some interesting questions and create more interesting plots.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("seaborn-talk")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("../input/cleaned-csv-2020-kaggle-ml-ds-survey/cleaned_kaggle_questionere.csv")

# %%
def graph_barplots(df, colname, title, one_col = False, sort_vals = True, tall = False):
    
    if one_col:
        series = df[colname].value_counts()
    else:
        series = df.filter(like = colname).sum()
    
    if sort_vals:
        series = series.sort_values()
        
    # Get rid of colname in front
    # Capitalize
    
    ax = series.plot(kind = "barh")
    plt.title(title)
    if tall:
        plt.gcf().set_figheight(20)
        
    plt.show()

# %%
graph_barplots(df, "q1", "What is your age?", one_col = True)

# %%
graph_barplots(df, "q2", "What is your gender?", one_col = True)

# %%
graph_barplots(df, "q3", "In which country do you reside?", one_col = True, tall = True)

# %%
graph_barplots(df, "q4", "What is the highest level of formal education that you have attained or plan to attain within the next 2 years?", one_col = True)

# %%
graph_barplots(df, "q5", "Select the title most similar to your current role", one_col = True)

# %%
graph_barplots(df, "q6", "For how many years have you been writing code and/or programming?", one_col = True)

# %%
graph_barplots(df, "q7", "What programming languages do you use on a regular basis?")

# %%
graph_barplots(df, "q8", "What programming language would you recommend an aspiring data scientist to learn first?", one_col = True)

# %%
graph_barplots(df, "q9", "Which of the following integrated development environments (IDE's) do you use on a regular basis?")

# %%
graph_barplots(df, "q10", "Which of the following hosted notebook products do you use on a regular basis?")

# %%
graph_barplots(df, "q11", "What type of computing platform do you use most often for your data science projects?", one_col = True)

# %%
graph_barplots(df, "q12", "Which types of specialized hardware do you use on a regular basis?")

# %%
graph_barplots(df, "q13", "Approximately how many times have you used a TPU (tensor processing unit)?", one_col = True)

# %%
graph_barplots(df, "q14", "What data visualization libraries or tools do you use on a regular basis?")

# %%
graph_barplots(df, "q15", "For how many years have you used machine learning methods?", one_col = True)

# %%
graph_barplots(df, "q16", "Which of the following machine learning frameworks do you use on a regular basis?")

# %%
graph_barplots(df, "q17", "Which of the following machine learning frameworks do you use on a regular basis?")

# %%
graph_barplots(df, "q18", "Which categories of computer vision methods do you use on a regular basis?")

# %% [markdown]
# Is this a mistake?  Seems high?

# %%
graph_barplots(df, "q19", "Which of the following natural language processing (NLP) methods do you use on a regular basis?")

# %%
graph_barplots(df, "q20", "What is the size of the company where you are employed?", one_col = True)

# %%
graph_barplots(df, "q21", "Approximately how many individuals are responsible for data science workloads at your place of business?", one_col = True)

# %%
graph_barplots(df, "q22", "Does your current employer incorporate machine learning methods into their business?", one_col = True)

# %%
graph_barplots(df, "q23", "Select any activities that make up an important part of your role at work")

# %%
df['q24'] = pd.Categorical(df['q24'].str.replace("$", ""))
graph_barplots(df, "q24", "What is your current yearly compensation in USD", one_col = True)

# %%
graph_barplots(df, "q26", "Which of the following cloud computing platforms do you use on a regular basis?")

# %%
graph_barplots(df, "q27", "Do you use any of the following cloud computing products on a regular basis?")

# %%
graph_barplots(df, "q28", "Do you use any of the following machine learning products on a regular basis?")

# %%
graph_barplots(df, "q29", "Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis?")

# %%
graph_barplots(df, "q30", "Which of the following big data products (relational database, data warehouse, data lake, or similar do you use most often?", one_col = True)

# %%
graph_barplots(df, "q31", "Which of the following business intelligence tools do you use on a regular basis?")

# %%
graph_barplots(df, "q32", "Which of the following business intelligence tools do you use most often?", one_col = True)

# %%
graph_barplots(df, "q33", "Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis?")

# %%
graph_barplots(df, "q34", "Which of the following automated machine learning tools (or partial AutoML tools) do you use on a regular basis?")

# %%
graph_barplots(df, "q35", "Do you use any tools to help manage machine learning experiments?")
