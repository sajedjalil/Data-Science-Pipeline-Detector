# %% [markdown]
# #The Coronavirus Pandemic.
#
# Since the beginning of 2020, Coronavirus Pandemic affected almost everything. Uncertainty, school and business closings, economic vulnerability and job loss have been some results of the lockdowns. Why not  Kaggle Survey 2020 wouldn't present little changes?
#
# Schools/Universities were closed during each country lockdown. Students remained at home studying on-line. That was possible only for those that have access to internet. Many in low-income or in vulnerability situation simply couldn't proceed their courses. For them, 2020 is a year pratically lost.
#
# Women were also more affected? They had to stay home, taking care of their children. And many lose their jobs too.
#
# Have a peek at those charts and get some insights of what had changed between 2018-2020.
#
#
# #An Overview of the Pandemic's effects on Kagglers Education, Age, Gender and Salary.
#
# Let the charts speak for themselves. In other words, readers make your own Conclusions.

# %% [markdown]
# #I think even Kaggle Bot (Kerneler) got Covid-19. It should wear a Mask. What about Social Distancing?
#
# #He/She/It interact with all Datasets. Definitely, Wear a Mask Kaggle Bot! We all love You!
#
# #Take care of yourself, wear masks and practice Social Distancing.
#
# ![](https://pbs.twimg.com/profile_images/1173131614689185792/3NxG8ee5_400x400.png)twitter.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns #visualization
import matplotlib.pyplot as plt #visualization
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Codes by Paul Mooney https://www.kaggle.com/paultimothymooney/what-is-inside-of-the-mueller-report/notebook

# %%
#Codes by Paul Mooney https://www.kaggle.com/paultimothymooney/what-is-inside-of-the-mueller-report/notebook

# Import Python Packages
# PyTesseract and Tika-Python for OCR
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shutil
import PIL
import os
from os import walk
from shutil import copytree, ignore_patterns
from collections import Counter
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from wand.image import Image as Img
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)
import cv2

# %%
# Define helper function for plotting word clouds
def wordCloudFunction(df,column,numWords):
    # adapted from https://www.kaggle.com/benhamner/most-common-forum-topic-words
    topic_words = [ z.lower() for y in
                       [ x.split() for x in df[column] if isinstance(x, str)]
                       for z in y]
    word_count_dict = dict(Counter(topic_words))
    popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
    popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
    word_string=str(popular_words_nonstop)
    wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white',
                          max_words=numWords,
                          width=1000,height=1000,
                         ).generate(word_string)
    plt.clf()
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
# Define helper function for plotting word bar graphs
def wordBarGraphFunction(df,column,title):
    # adapted from https://www.kaggle.com/benhamner/most-common-forum-topic-words
    topic_words = [ z.lower() for y in
                       [ x.split() for x in df[column] if isinstance(x, str)]
                       for z in y]
    word_count_dict = dict(Counter(topic_words))
    popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
    popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
    plt.barh(range(50), [word_count_dict[w] for w in reversed(popular_words_nonstop[0:50])])
    plt.yticks([x + 0.5 for x in range(50)], reversed(popular_words_nonstop[0:50]))
    plt.title(title)
    plt.show()

# %%
# Preview the data folder
inputFolder = '../input/'
for root, directories, filenames in os.walk(inputFolder):
    for filename in filenames: 
        print(os.path.join(root,filename))
        
# Move data to folder with read/write access
outputFolder = '/kaggle/working/pdfs/'
shutil.copytree(inputFolder,outputFolder,ignore=ignore_patterns('*.db'))
for root, directories, filenames in os.walk(outputFolder, topdown=False):
    for file in filenames:
        try:
            shutil.move(os.path.join(root, file), outputFolder)
        except OSError:
            pass
print(os.listdir(outputFolder))

# %% [markdown]
# #The Methodology

# %%
# Look at page 2
pdf = os.path.join(outputFolder,'kaggle_survey_2020_methodology.pdf[2]')
with Img(filename=pdf, resolution=300) as img:
    img.compression_quality = 99
    img.convert("RGBA").save(filename='/kaggle/working/kaggle_survey_2020_methodology.jpg') # intro page to preview later

# %% [markdown]
# #.PDF to
#
# Convert Page 2 of PDF to CSV (Method 1 of 2: PyTesseract).

# %%
# Parse a PDF file and convert it to CSV using PyTesseract
import pytesseract
pdfimage = Image.open('/kaggle/working/kaggle_survey_2020_methodology.jpg')
text = pytesseract.image_to_string(pdfimage)  
df = pd.DataFrame([text.split('\n')])

# %%
# Plot WordCloud of page 2
plt.figure(figsize=(10,10))
wordCloudFunction(df.T,0,10000000)
plt.figure(figsize=(10,10))
wordBarGraphFunction(df.T,0,"Most Common Words on Page 2 of Kaggle Survey Methodology")

# %%
#Code by Rawwar https://www.kaggle.com/rawwar/eda-pandas-profile-based-conclusions
df1 = pd.read_csv("../input/kaggle-survey-2020/kaggle_survey_2020_responses.csv",skiprows=1)
df1.head(2)

# %%
#Code by Rawwar https://www.kaggle.com/rawwar/eda-pandas-profile-based-conclusions
df2 = pd.read_csv("../input/kaggle-survey-2018/multipleChoiceResponses.csv",skiprows=1)
df2.head(2)

# %%
#Code from Gabriel Preda
#plt.style.use('dark_background')
def plot_count(feature, title, df1, size=1):
    f, ax = plt.subplots(1,1, figsize=(4*size,4))
    total = float(len(df1))
    g = sns.countplot(df1[feature], order = df1[feature].value_counts().index[:20], palette='summer')
    g.set_title("Number and percentage of {}".format(title))
    if(size > 2):
        plt.xticks(rotation=90, size=8)
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(100*height/total),
                ha="center") 
    plt.show()

# %%
plot_count("What is the highest level of formal education that you have attained or plan to attain within the next 2 years?", "The highest level of formal education that you plan to attain within the next 2 years (2020)?", df1,4)

# %%
 #Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/parts-of-speech

plt.figure(figsize=(10,5))
sns.countplot(y="What is the highest level of formal education that you have attained or plan to attain within the next 2 years?",data=df1,
             facecolor=(0,0,0,0),linewidth=5,
             edgecolor=sns.color_palette("bone"))
plt.title("The highest level of formal education plan to attain within the next 2 years (2020)?",
         fontsize=15);

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.RdGy(np.linspace(0,1,20))
df1["What is the highest level of formal education that you have attained or plan to attain within the next 2 years?"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="What is your age (# years)?",colors=color,autopct="%0.1f%%")
plt.title("The highest level of formal education plan to attain within the next 2 years (2020)")
plt.axis("off")
plt.show()

# %%
plot_count("What is the highest level of formal education that you have attained or plan to attain within the next 2 years?", "The highest level of formal education that you plan to attain within the next 2 years (2018)?", df2,4)

# %%
 #Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/parts-of-speech

plt.figure(figsize=(10,5))
sns.countplot(y="What is the highest level of formal education that you have attained or plan to attain within the next 2 years?",data=df2,
             facecolor=(0,0,0,0),linewidth=5,
             edgecolor=sns.color_palette("rainbow"))
plt.title('The highest level of formal education that you have attained or plan to attain within the next 2 years? (2018)',
         fontsize=15);

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Pastel1(np.linspace(0,1,20))
df2["What is the highest level of formal education that you have attained or plan to attain within the next 2 years?"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="What is your age (# years)?",colors=color,autopct="%0.1f%%")
plt.title("The highest level of formal education plan to attain within the next 2 years (2018)")
plt.axis("off")
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,10)})

sns.countplot('What is your age (# years)?',data=df1,palette='twilight_shifted')
plt.xticks(rotation=80)
plt.title('What is your age Kaggler (2020)?')

# %%
sns.set(rc={'figure.figsize':(20,10)})

sns.countplot('What is your age (# years)?',data=df2,palette='ocean')
plt.xticks(rotation=80)
plt.title('What is your age Kaggler (2018)')

# %%
sns.set(rc={'figure.figsize':(20,10)})

sns.countplot('What is your gender? - Selected Choice',data=df1,palette='twilight_shifted')
plt.xticks(rotation=80)
plt.title('What is your gender? 2020 Survey')

# %%
sns.set(rc={'figure.figsize':(20,10)})

sns.countplot('What is your gender? - Selected Choice',data=df2,palette='gist_earth')
plt.xticks(rotation=80)
plt.title('What is your gender? 2018 Survey')

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Set2(np.linspace(0,1,20))
df1["What is your gender? - Selected Choice"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="In which country do you currently reside?",colors=color,autopct="%0.1f%%")
plt.title("What is your gender? 2020 Survey")
plt.axis("off")
plt.show()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.flag(np.linspace(0,1,20))
df2["What is your gender? - Selected Choice"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="In which country do you currently reside?",colors=color,autopct="%0.1f%%")
plt.title("What is your gender? 2018 Survey")
plt.axis("off")
plt.show()

# %%
# Count Plot by Nittin Datta
plt.style.use("classic")
plt.figure(figsize=(10, 8))
sns.countplot(df1['What is your current yearly compensation (approximate $USD)?'], palette='flag', **{'hatch':'/','linewidth':3})
plt.xlabel("What is your current yearly compensation (approximate $USD)? (2020)")
plt.ylabel("Count")
plt.title("What is your current yearly compensation (approximate $USD)? (2020)")
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %%
# Count Plot by Nittin Datta
plt.style.use("classic")
plt.figure(figsize=(10, 8))
sns.countplot(df2['What is your current yearly compensation (approximate $USD)?'], palette='rainbow', **{'hatch':'/','linewidth':3})
plt.xlabel("What is your current yearly compensation (approximate $USD)? (2018)")
plt.ylabel("Count")
plt.title("What is your current yearly compensation (approximate $USD)?(2018)")
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Thanks Paul, Olga, Rawwar, Taha07 and Nittin @mpwolke Was here' )
