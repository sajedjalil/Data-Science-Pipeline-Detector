# %% [markdown]
# # Data Science Kaggle Surveys 2020

# %% [markdown]
# This Notebook will present you the Insights of Data Science Landscape across the world through Kaggle Surveys.
#
# Please refer the below mentioned insights for your reference:-

# %% [markdown]
# # Table of Contents

# %% [markdown]
# [Insight Regarding Age Demographic of Kaggle Survey Participants:](#1)
#
# [Insight Regarding Gender Landscape among Kaggle survey participants:](#2)
#
# [Insight Regarding Countries which participated in Kaggle Surveys:](#3)
#
# [Insight Regarding Highest level of Formal Education of Participants who participated in Kaggle Surveys:](#4)
#
#
# [Insight Regarding Job Title of Participants who participated in Kaggle Surveys:](#5)
#
#
# [Insight Regarding No of Years of Experience in Coding of Participants who participated in Kaggle Surveys:](#6)
#
#
# [Insight Regarding Frequently used Programming languages by Participants who participated in Kaggle Surveys:](#7)
#
#
# [Insight Regarding Programming languages Recommended by Participants who participated in Kaggle Surveys:](#8)
#
#
# [Insight Regarding IDE(Integrated Development environment) Recommended by Participants who participated in Kaggle Surveys:](#9)
#
#
# [Insight Regarding Hosted Notebook Product Used by Participants who participated in Kaggle Surveys:](#10)
#
#
# [Insight Regarding Computing Platform Used by Participants who participated in Kaggle Surveys:](#11)
#
#
# [Insight Regarding Types of Specialized Hardware Platform used by Participants who participated in Kaggle Surveys:](#12)
#
#
# [Insight Regarding no of times Tensor Processing Unit (TPU) is used by Participants who participated in Kaggle Surveys:](#13)
#
#
# [Insight Regarding Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys:](#14)
#
# [Insight Regarding for how many Years Kaggle Survey Participants have used Machine Learning:](#15)
#
# [Insight Regarding machine learning frameworks used by Kaggle survey participants on a regular basis:](#16)
#
# [Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis:](#17)
#
# [Insight Regarding Computer Vision methods used by Kaggle survey participants on a regular basis:](#18)
#
# [Insight Regarding Natural language processing (NLP) methods used by Kaggle survey participants on a regular basis:](#19)
#
# [Insight Regarding size of the company where Kaggle survey participants are employed:](#20)
#
# [Insight Regarding how many individuals are responsible for data science workloads at your place of business:](#21)
#
# [Insight Regarding Does your current employer incorporate machine learning methods into their business:](#22)
#
# [Insight Regarding activity "Analyze and understand data to influence product or business decisions" that make up an important part of your role at work:](#23)
#
# [Insight regarding activities "Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data" that make up an important part of your role at work::](#24)
#
# [Insight regarding activity "Build prototypes to explore applying machine learning to new areas" that make up an important part of your role at work:](#25)
#
# [Insight regarding activity done by Kaggle Survey Participants to Build and/or run a machine learning service that operationally improves my product or workflows:](#26)
#
# [Insight regarding activity "Experimentation and iteration to improve existing ML models" performed by Kaggle Survey Participants:](#27)
#
#
# [Insight regarding activity to perform research that advances the state of the art of machine learning performed by Kaggle Survey Participants:](#28)
#
#
# [Insight regarding current yearly compensation(approximate USD) for Kaggle Survey Participants:](#29)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")

# %%
df.head()

# %%
df = df.drop(df.index[0])

# %%
###### Analyzing NaN values across Kaggle Survey 2020 Responses Dataset #######

# %%
df.isnull().sum()

# %%
###### Replacing Nan with 0 ######

# %%
# df = df.fillna(0)

# %%
 df = df.dropna(how='all', axis=0)

# %%
df.isnull().sum()

# %%
df.head()

# %%
print(df.columns.tolist())

# %%
##### Insight regarding Time Taken to Answer Surveys by Survey Participants #####

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['Time from Start to Finish (seconds)'],kde=False)

plt.show()

# %% [markdown]
# * Above Graph gives us insight that Survey participants have taken maximum time as around 19000 seconds to answer the Kaggle survey.

# %% [markdown]
# <a id="1"></a> <br>
# # 1.Insight Regarding Age Demographic of Survey Participants

# %%
sns.countplot(x='Q1',data=df)

# %% [markdown]
# ****Insight:****
# **Above graph gives us insight that highest number of survey participants are from age group 25-29 and lowest number of survey participants are from 70+ age group**

# %% [markdown]
# <a id="2"></a> <br>
# # 2.Insight Regarding Gender Landscape among survey participants

# %%
plt.figure(figsize=(12,4)) # this creates a figure 12 inch wide, 4 inch high
sns.countplot(x='Q2',data=df)
plt.show()

# %% [markdown]
# **Insight:**
# **Above Graph gives us Insight that "Man" have particpated the highest compared to other Gender Categories in Kaggle Surveys.**

# %% [markdown]
# <a id="3"></a> <br>
# # 3. Insight Regarding Countries which participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Countries participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q3', data=df)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:**
# **Above Barplot gives us the insight that highest participation is from "India" and second highest participation is from "USA" in Kaggle Surveys.**

# %% [markdown]
# <a id="4"></a> <br>
# # 4. Insight Regarding Highest level of Formal Education of Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Highest level of Formal Education of Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q4', data=df)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:
# Above Barplot gives us the insight that Maximum Kaggle Survey participants have Master's Degree and second highest Survey participants have Bachelor's Degree.**

# %% [markdown]
# <a id="5"></a> <br>
# # 5. Insight Regarding Job Title of  Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Job Title of Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q5', data=df)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that Maximum Job Titles of Kaggle Survey participants is "Student" and Second Highest Job Titles is "Data Scientist" and lowest number of Job Titles is DBA/Database Engineer .**

# %% [markdown]
# <a id="6"></a> <br>
#
# # 6. Insight Regarding No of Years of Experience in Coding of Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("No of Years of Experience in Coding of Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q6', data=df)

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that Maximum number of Kaggle Survey participants is having Coding Experience in the range of "3-5 years" and "1-2 years".**

# %% [markdown]
# <a id="7"></a> <br>
#
# # 7. Insight Regarding Frequently used Programming languages by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "Python" programming language is used highest by Student community, second highest by Data Scientist Community and lowest by DBA/Database Engineer.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "R" programming language is used highest by Data Scientist community, second highest by Student Community and lowest by DBA/Database Engineer.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "SQL" programming language is used highest by Data Scientist community, second highest by Student Community and lowest by Statistician.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "C" programming language is used highest by "Student" community, second highest by "Software Engineer" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_5',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "C++" programming language is used highest by "Student", second highest by "Data Engineer" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_6',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "Java" programming language is used highest by "Student", second highest by "Data Engineer" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_7',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "Javascript" programming language is used highest by "Data Engineer", second highest by "Student" and lowest by "Statistician".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_8',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "Julia" programming language is used highest by "Data Scientist", second highest by "Students" and lowest by "DBA/Database Engineer" among Kaggle Survey Participants.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_9',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "Swift" programming language is used highest by "Software Engineer", second highest by "Students" and lowest by "Statistician" among Kaggle Survey Participants.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_10',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "Bash" programming language is used highest by "Data Scientist", second highest by "Software Engineer" and lowest by "Statistician" among Kaggle Survey Participants.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Programming languages by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q7_Part_11',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "MATLAB" programming language is used highest by "Student", second highest by "Research Scientist" and lowest by "DBA/Database Engineer" among Kaggle Survey Participants.**

# %% [markdown]
# <a id="8"></a> <br>
#
# # 8. Insight Regarding Programming languages Recommended by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Programming languages Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q8',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

ax.legend(loc='upper right')

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "PYTHON" programming language is the most popular and is used highest by "Student", second highest by "Data Scientist" and then by "Data Analyst" and lowest by "DBA/Database Engineer".**

# %% [markdown]
# <a id="9"></a> <br>
#
# # 9. Insight Regarding IDE(Integrated Development environment) Recommended by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "Jupyter" IDE is used highest by "Student", second highest by "Data Scientist" and then by "Software Engineer" followed by "Currently not employed" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight:Above Barplot gives us the insight that "RStudio" IDE is used highest by "Student", second highest by "Data Scientist" and then by "Data Analyst" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Visual Studio" IDE is used highest by "Student", second highest by "Software Engineer" and lowest by "Statistician".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Visual Studio Code(VSCode)" IDE is used highest by "Student", second highest by "Software Engineer" followed by "Data Scientist" and lowest by "Statistician".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_5',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "PyCharm" IDE is used highest by "Student", second highest by "Data Scientist" followed by "Software Engineer" and lowest by "DBA/Database Engineer"**.

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_6',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Spyder" IDE is used highest by "Student", second highest by "Data Scientist" followed by "Data Analyst" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_7',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Notepad++" IDE is used highest by "Student", second highest by "Data Scientist" followed by "Software Engineer" and lowest by "Statistician".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_8',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Sublime Text" IDE is used highest by "Student", second highest by "Data Scientist" followed by "Software Engineer" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_9',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Vim/Emacs" IDE is used highest by "Data Scientist", second highest by "Software Engineer" followed by "Student" and lowest by "Statistician".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("IDE Recommended by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q9_Part_10',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "MATLAB" IDE is used highest by "Student", second highest by "Research Scientist" followed by "Data Scientist" and lowest by "DBA/Database Engineer".**

# %% [markdown]
# <a id="10"></a> <br>
#
# # 10. Insight Regarding Hosted Notebook Product Used by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Kaggle Notebooks" Product is used highest by "Student", second highest by "Data Scientist" followed by "Software Engineer" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Colab Notebooks" Product  is used highest by "Student", second highest by "Data Scientist" followed by "Software Engineer" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Azure Notebooks" Product is used highest by "Data Scientist", second highest by "Student" followed by "Software Engineer" and lowest by "DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Paperspace/Gradient" Product is used highest by "Student", second highest by "Data Scientist" followed by "Software Engineer" and lowest by "Product/Project Manager & DBA/Database Engineer".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_6',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Code Ocean" Product is used highest by "Student", second highest by "Software Engineer" followed by "Data Scientist" and lowest by "Business Analyst & DBA/Database Engineer & Data Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_7',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "IBM Watson Studio" Product is used highest by "Student", second highest by "Data Scientist" followed by "Statistician" and lowest by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing how many Kaggle Survey participants use this respective product #
ax = sns.countplot(x='Q10_Part_8',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Amazon Sagemaker Studio" Product is used highest by "Data Scientist", second highest by "Student" followed by "Machine Learning Engineer" and lowest by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_9',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Amazon EMR Notebooks" Product is used highest by "Data Scientist", second highest by "Student" followed by "Machine Learning Engineer" and lowest by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_10',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Google Cloud AI Notebooks" Product is used highest by "Student", second highest by "Data Scientist" followed by "Machine Learning Engineer" and lowest by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_11',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Google Cloud Datalab Notebooks" Product is used highest by "Student", second highest by "Data Scientist" followed by "Software Engineer" and lowest by "DBA/Database Engineer & Statistician"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Hosted Notebook Product Used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q10_Part_12',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Databricks Collaborative Notebooks" Product is used highest by "Data Scientist", second highest by "Data Engineer" followed by "Student" and lowest by "DBA/Database Engineer"**

# %% [markdown]
# <a id="11"></a> <br>
#
# # 11. Insight Regarding Computing Platform Used by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Computing Platform by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q11',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right", rotation='40')

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Personal computer/Laptop" is the Preffered Computing Platform for Students,Data Scientist's,Data Analyst's and Machine Learning Engineer's.**

# %% [markdown]
# <a id="12"></a> <br>
#
# # 12. Insight Regarding Types of Specialized Hardware Platform used by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Specialized Hardware Platform by Participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q12_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "GPU's" specialized hardware is used maximum by Students, followed by Data Scientist's.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Specialized Hardware Platform by Participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q12_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "TPU's" specialized hardware is used maximum by Students, followed by Data Scientist's and then by Machine Learning engineers**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Frequently used Specialized Hardware Platform by Participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q12_OTHER',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Other" specialized hardware is used maximum by Students, followed by Data Scientist's and then by Research Scientist & Software Engineers**

# %% [markdown]
# <a id="13"></a> <br>
#
# # 13. Insight Regarding no of times Tensor Processing Unit (TPU) is used by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("No of Times TPU was used by Participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q13',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="right", rotation='40')

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Tensor Processing Unit" "TPU" was used only "Once" by Data Scientists, Analysts and Students.**

# %% [markdown]
# <a id="14"></a> <br>
#
# # 14. Insight Regarding Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Matplotlib" Data Visualization library is used maximum by Students, followed by Data Scientist's and then by Software Engineers and minimum use is done by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Seaborn" Data Visualization library is used maximum by Students, followed by Data Scientist's and then by Statistician & Software Engineer and minimum use is done by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Plotly/Plotly Express" Data Visualization library is used maximum by Data Scientist's and minimum use of this Visualization library is done by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Ggplot / ggplot2"  Data Visualization library is used maximum by Data Scientist's followed by Students.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_5',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Shiny" Data Visualization library is used maximum by Data Scientist's and minimum use of this Visualization library is done by "DBA/Database Engineer"**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_6',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# Insight: Above Barplot gives us the insight that "D3.js" Data Visualization library is used maximum by "Software Engineers" and second highest use of this Visualization library is done by "Data Scientists."

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_7',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Above Barplot gives us the insight that "Altair" Data Visualization library is used maximum by "Data Scientist" and second highest use of this Visualization library is done by "Students" followed by "Machine Learning Engineer's".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_8',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Bokeh" Data Visualization library is used maximum by "Data Scientists" and second highest use of this Visualization library is done by "Students", Third Highest use of this Visualization library is done by "Software Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_9',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Geoplotlib" Data Visualization library is used maximum by "Students" and second highest use of this Visualization library is done by "Data Scientists", Third Highest use of this Visualization library is done by "Software Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_Part_10',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Folium" Data Visualization library is used maximum by "Data Scientists" and second highest use of this Visualization library is done by "Data Analysts".

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Data Visualization Libraries or Tools used by Participants who participated in Kaggle Surveys")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q14_OTHER',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Other" Data Visualization libraries are explored maximum by "Data Scientists" and second highest use of "Other" Visualization libraries is done by "Students" followed by "Data Analysts".**

# %% [markdown]
# <a id="15"></a> <br>
#
# # 15. Insight Regarding for how many Years Kaggle Survey Participants have used Machine Learning

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,8))

# Add title
plt.title("Insight Regarding for how many Years Kaggle Survey Participants have used Machine Learning")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q15',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left", rotation='40')

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Data Scientist, Research Scientist & Machine Learning Engineers have the highest Machine Learning experience in the bracket of "20 or more years" & "10-20 years" but they are very small in number whereas majority of participants have Machine Learning experience in the range of 3-4 years.**

# %% [markdown]
# <a id="16"></a> <br>
#
# # 16. Insight Regarding machine learning frameworks used by Kaggle survey participants on a regular basis

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Scikit-learn" Machine Learning library is used maximum by "Students" and second highest use of this Machine Learning library is done by "Data Scientists", Third Highest use of this ML library is done by "Software Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Tensorflow" Machine Learning library is used maximum by "Students" and second highest use of this Machine Learning library is done by "Data Scientists", Third Highest use of this ML library is done by "Software Engineers" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Keras" Machine Learning library is used maximum by "Students" and second highest use of this Machine Learning library is done by "Data Scientists", Third Highest use of this ML library is done by "Software Engineers" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "PyTorch" Machine Learning library is used maximum by "Students" and second highest use of this Machine Learning library is done by "Data Scientists", Third Highest use of this ML library is done by "Software Engineers" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_5',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "PyTorch" Machine Learning library is used maximum by "Students" and second highest use of this Machine Learning library is done by "Data Scientists", Third Highest use of this ML library is done by "Software Engineers" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_6',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "MXNet" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_7',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Xgboost" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Students".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_8',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "LightGBM" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Students" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_9',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "CatBoost" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Students" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_10',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Prophet" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Research Scientists" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_11',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "H20.3" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Students" followed by "Data Analysts".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_12',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Caret" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Data Analysts".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_13',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Tidymodels" Machine Learning library is used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Data Analysts" followed by "Students".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_Part_14',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "JAX" Machine Learning library is used maximum by "Data Engineers" and second highest use of this Machine Learning library is done by "Data Scientists".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Machine learning frameworks used by Kaggle survey participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q16_OTHER',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Other" Machine Learning library is explored and used maximum by "Data Scientists" and second highest use of this Machine Learning library is done by "Students".**

# %% [markdown]
# <a id="17"></a> <br>
#
# # 17. Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Linear or Logistic Regression" Machine Learning Algorithms is explored and used maximum by "Students" and second highest use of these Machine Learning Algorithms is done by "Data Scientists".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# Insight: Above Barplot gives us the insight that "Decision Trees or Random Forests" Machine Learning Algorithms is explored and used maximum by "Students" and second highest use of these Machine Learning Algorithms is done by "Data Scientists

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Gradient Boosting Machines" Machine Learning Algorithms is used maximum by "Data Scientists" and second highest use of these Machine Learning Algorithms is done by "Students".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Bayesian Approaches" Machine Learning Algorithms is used maximum by "Data Scientists" & "Students" and second highest use of these Machine Learning Algorithms is done by "Software Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_5',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Evolutionary Approaches" Machine Learning Algorithms is used maximum by "Data Scientists" & "Research Scientists".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_6',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Dense Neural Networks" Machine Learning Algorithms is used maximum by "Students" and second highest use of these Machine Learning Algorithms is done by "Data Scientists" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_7',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Convolutional Neural Networks" Machine Learning Algorithms is used maximum by "Students" and second highest use of these Machine Learning Algorithms is done by "Data Scientists" followed by "Software Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_8',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Generative Adversarial Networks" Machine Learning Algorithms is used maximum by "Students" and second highest use of these Machine Learning Algorithms is done by "Data Scientists" followed by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_9',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Recurrent Neural Networks" Machine Learning Algorithms is used maximum by "Data Scientists" & "Students" and second highest use of these Machine Learning Algorithms is done by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_Part_10',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Transformer Networks" Machine Learning Algorithms is used maximum by "Data Scientists" & "Students" and second highest use of these Machine Learning Algorithms is done by "Machine Learning Engineers".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding ML Algorithms used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q17_OTHER',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Other" Machine Learning Algorithms is used maximum by "Data Scientists" & "Students" and second highest use of these Machine Learning Algorithms is done by "Machine Learning Engineers".**

# %% [markdown]
# <a id="18"></a> <br>
#
# # 18. Insight Regarding Computer Vision methods used by Kaggle survey participants on a regular basis

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Computer Vision methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q18_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "General purpose image/video tools(PIL,cv2,skimage,etc)" is used maximum by "Students" and second highest use of these Computer vision methods is done by "Data Scientists".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Computer Vision methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q18_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Image segmentation methods(U-net,Mask,R-CNN,etc)" is used maximum by "Students" and second highest use of these Computer vision methods is done by "Data Scientists".

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Computer Vision methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q18_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Object Detection methods(YOLOv3,RetinaNet,etc)" is used maximum by "Students" and second highest use of these Computer vision - object detection methods is done by "Data Scientists".

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Computer Vision methods used by survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q18_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Image classification and general purpose networks(VGG,Inception,ResNet,ResNeXt,NASNet,EfficientNet,etc)" is used maximum by "Students" and second highest use of these Computer vision methods is done by "Data Scientists".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Computer Vision methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q18_Part_5',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Generative networks(GAN,VAE,etc)" is used maximum by "Students" and second highest use of these Computer vision methods is done by "Data Scientists".**

# %% [markdown]
# <a id="19"></a> <br>
#
# # 19. Insight Regarding Natural language processing (NLP) methods used by Kaggle survey participants on a regular basis

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Natural language processing (NLP) methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q19_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Word embeddings/vectors(GLoVe,fastText,word2vec)" is used maximum by "Data Scientists" and second highest use of these NLP methods is done by "Students".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Natural language processing (NLP) methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q19_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Encoder-decoder models(seq2seq,vanilla transformers)" is used maximum by "Data Scientists" and second highest use of these NLP methods is done by "Students".**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Natural language processing (NLP) methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q19_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Contextualized embeddings(ELMo,CoVe)" is used maximum by "Data Scientists" and second highest use of these NLP methods is done by "Students" & "Machine Learning.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Natural language processing (NLP) methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q19_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Transformer language models(GPT-3,BERT,XLnet)" is used maximum by "Data Scientists" and second highest use of these NLP methods is done by "Students" & "Machine Learning.**

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Natural language processing (NLP) methods used by Kaggle survey participants on a regular basis")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q19_OTHER',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Other NLP Methods" is used maximum by "Data Scientists" and second highest use of other NLP methods is done by  "Machine Learning Engineers".**

# %% [markdown]
# <a id="20"></a> <br>
#
# # 20. Insight Regarding size of the company where Kaggle survey participants are employed

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,8))

# Add title
plt.title("Insight Regarding size of the company where Kaggle survey participants are employed")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q20',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that maximum number of Kaggle Survey participants are from "0-49 employee" size company.**

# %% [markdown]
# <a id="21"></a> <br>
#
# # 21.Insight Regarding how many individuals are responsible for data science workloads at your place of business

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,8))

# Add title
plt.title("Insight Regarding how many individuals are responsible for data science workloads at your place of business")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q21',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that individuals responsible for Data Science workloads at your place of business is majorly in the category "0","1-2", "3-4","5-9","20+" people.**

# %% [markdown]
# <a id="22"></a> <br>
#
# # 22. Insight Regarding Does your current employer incorporate machine learning methods into their business

# %%
# Set the width and height of the figure
plt.figure(figsize=(59,12))

# Add title
plt.title("Insight Regarding incorporating machine learning methods into their business")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q22',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that current employers are incorporating Machine Learning methods into their business as biggest category is for "We have well established ML methods(models in production for more than 2 years)...it also shows that there is growing demand and adoption for Data Science Solutions.**

# %% [markdown]
# <a id="23"></a> <br>
#
# # 23. Insight Regarding activity "Analyze and understand data to influence product or business decisions" that make up an important part of your role at work:

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight Regarding Analyzing and understanding data to influence product or business decisions")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q23_Part_1',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# ****Insight: Above Barplot gives us the insight that "Analyze and understand data to influence product or business decisions" is an important part of "Data Scientist" & "Data Analyst" work.****

# %% [markdown]
# <a id="24"></a> <br>
#
# # 24. Insight regarding activities "Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data" that make up an important part of your role at work:

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,8))

# Add title
plt.title("Insight regarding Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q23_Part_2',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="left")

plt.tight_layout()

plt.show()

# %% [markdown]
# ****Insight: Above Barplot gives us the insight that "Building and running the data infrastructure that my business uses for storing,analyzing and operationalizing data" is an important part of "Data Scientist" ,"Data Analyst" and "Software Engineer" work.****

# %% [markdown]
# <a id="25"></a> <br>
#
# # 25. Insight regarding activity "Build prototypes to explore applying machine learning to new areas" that make up an important part of your role at work:

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,12))

# Add title
plt.title("Insight regarding Building prototypes to explore applying machine learning to new areas")
# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q23_Part_3',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="center")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Building prototypes to explore machine learning to new areas" work is major part of "Data Scientist"  work.**

# %% [markdown]
# <a id="26"></a> <br>
#
# # 26. Insight regarding activity done by Kaggle Survey Participants to Build and/or run a machine learning service that operationally improves my product or workflows

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,12))

# Add title
plt.title("Insight regarding run a machine learning service that operationally improves my product or workflows")
# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q23_Part_4',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="center")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Building or running machine learning service that operationally improves my product or workflows" is major part of "Data Scientist" and "Machine Learning Engineer" work.**

# %% [markdown]
# <a id="27"></a> <br>
#
# # 27. Insight regarding activity  "Experimentation and iteration to improve existing ML models" performed by Kaggle Survey Participants

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,12))

# Add title
plt.title("Insight regarding activity Experimentation and iteration to improve existing ML models")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q23_Part_5',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="center")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Experimentation and iteration to improve existing ML models" is major part of "Data Scientist" and "Machine Learning Engineer" work.**

# %% [markdown]
# <a id="28"></a> <br>
#
# # 28. Insight regarding activity to perform research that advances the state of the art of machine learning performed by Kaggle Survey Participants

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,12))

# Add title
plt.title("Insight regarding activity to perform research that advances the state of the art of machine learning")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q23_Part_6',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="center")

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Do research that advances the state of the art of machine learning" is major part of "Data Scientist" and "Research Scientist" work.**

# %% [markdown]
# <a id="29"></a> <br>
#
# # 29. Insight regarding current yearly compensation(approximate $USD) for Kaggle Survey Participants?

# %%
# Set the width and height of the figure
plt.figure(figsize=(12,12))

# Add title
plt.title("Insight regarding current yearly compensation(approximate $USD) for Kaggle Survey Participants")

# Bar chart showing participation from different countries #
ax = sns.countplot(x='Q24',data=df,hue='Q5')

ax.set_xticklabels(ax.get_xticklabels(), ha="center", rotation=40)

plt.tight_layout()

plt.show()

# %% [markdown]
# **Insight: Above Barplot gives us the insight that "Data Scientist" and "Research Scientist" salaries are the highest among Kaggle Survey Participants.**
