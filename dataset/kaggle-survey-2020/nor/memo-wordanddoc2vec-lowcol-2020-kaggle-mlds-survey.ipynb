# %%
# %matplotlib inline
from IPython.display import SVG, Image

import os.path
import sys
import re
import itertools
import csv
import datetime
import pickle
import random
from collections import defaultdict, Counter
import gc

import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import seaborn as sns
import pandas as pd
import numpy as np
import scipy
import gensim
from sklearn.metrics import f1_score, classification_report, confusion_matrix, log_loss
from sklearn.model_selection import train_test_split
import gensim
from keras.preprocessing.sequence import skipgrams
import tensorflow as tf

# %% [markdown]
# # 2020 Kaggle Machine Learning & Data Science Survey
# ---
# ## ks2020 encode data 001
# https://www.kaggle.com/wordroid/ks2020-encode-data-001

# %% [markdown]
# ## ks2020 lowcol fet12 001
# https://www.kaggle.com/wordroid/ks2020-lowcol-fet12-001

# %%
Image('../input/ks2020-lowcol-fet12-001/img_018.png')

# %% [markdown]
# ## ks2020 lowcol fet12 001 show
# https://www.kaggle.com/wordroid/ks2020-lowcol-fet12-001-show

# %%
Image('../input/ks2020-lowcol-fet12-001-show/img_001.png')

# %%
Image('../input/ks2020-lowcol-fet12-001-show/img_002.png')

# %%
Image('../input/ks2020-lowcol-fet12-001-show/img_003.png')

# %% [markdown]
# ## ks2020 lowcol fet12 001 somcls sksom_keras
# https://www.kaggle.com/wordroid/ks2020-lowcol-fet12-001-somcls-sksom-keras

# %%
Image('../input/ks2020-lowcol-fet12-001-somcls-sksom-keras/img_011.png')

# %% [markdown]
# ## ks2020 lowcol fet12 001 somcls show
# https://www.kaggle.com/wordroid/ks2020-lowcol-fet12-001-somcls-show

# %%
Image('../input/ks2020-lowcol-fet12-001-somcls-show/img_002.png')

# %% [markdown]
# ## ks2020 lowcol fet12 001 somcls sksom_keras hex
# https://www.kaggle.com/wordroid/ks2020-lowcol-fet12-001-somcls-sksom-keras-hex

# %% [markdown]
# ## ks2020 lowcol fet12 001 sommap
# https://www.kaggle.com/wordroid/ks2020-lowcol-fet12-001-sommap

# %%
Image('../input/ks2020-lowcol-fet12-001-sommap/img_014.png')

# %% [markdown]
# ## ks2020 lowcol fet12 001 sommap show
# https://www.kaggle.com/wordroid/ks2020-lowcol-fet12-001-sommap-show

# %%
Image('../input/ks2020-lowcol-fet12-001-sommap-show/img_007.png')

# %%
Image('../input/ks2020-lowcol-fet12-001-sommap-show/img_008.png')

# %%
Image('../input/ks2020-lowcol-fet12-001-sommap-show/img_009.png')

# %%
Image('../input/ks2020-lowcol-fet12-001-sommap-show/img_010.png')

# %%
Image('../input/ks2020-lowcol-fet12-001-sommap-show/img_011.png')
