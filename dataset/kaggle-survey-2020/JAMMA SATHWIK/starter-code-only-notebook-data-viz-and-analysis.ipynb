# %%
import numpy as np
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv("/kaggle/input/kaggle-survey-2020/kaggle_survey_2020_responses.csv")
df.head()

# %%
df.shape

# %%
df.isnull().sum()

# %%
sum(df.isnull().sum()>10000)

# %%
for col in df.columns:
    if(df[col].isnull().sum()>10000):
        df=df.drop(col,axis=1)
df.shape

# %%
df.head()

# %%
df.columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Q1'].value_counts()

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q1'][1:])

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Q2'][1:])

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q4'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q5'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q6'][1:])
#plt.xticks(rotation=90)

# %%
df['Q7_Part_1'][1:].value_counts()

# %%
df=df.drop(['Q7_Part_1'],axis=1)
df.columns

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q8'][1:])
plt.xticks(rotation=90)

# %%
df['Q9_Part_1'][1:].value_counts()

# %%
df=df.drop(['Q9_Part_1'],axis=1)
df.columns

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q11'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q13'][1:])
plt.xticks(rotation=90)

# %%
df['Q14_Part_1'][1:].value_counts()

# %%
df=df.drop(['Q14_Part_1'],axis=1)
df.columns

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q15'][1:])
plt.xticks(rotation=90)

# %%
df['Q16_Part_1'].value_counts()

# %%
df=df.drop(['Q16_Part_1'],axis=1)
df.columns

# %%
df['Q17_Part_1'].value_counts()

# %%
df=df.drop(['Q17_Part_1'],axis=1)
df.columns

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['Q20'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q21'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q22'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q24'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q25'][1:])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['Q38'][1:])
plt.xticks(rotation=90)
