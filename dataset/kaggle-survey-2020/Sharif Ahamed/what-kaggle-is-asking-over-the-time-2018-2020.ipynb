# %% [markdown]
# ![](https://www.incimages.com/uploaded_files/image/1920x1080/getty_487063216_162506.jpg)

# %% [markdown]
# Over the time(2017-2020) kaggle is asking different types of questions which ranged from personal interests to individuals working experience to individuals thinking about their future. Here, I have summarized all the questions from 2018_Kaggle_ML_&_DS_Survey to 2020_Kaggle_ML_&_DS_Survey.
# I have categorised them how frequently they were asked and If there have any common questions over the years.

# %% [markdown]
# # Most frequent and common questions from year 2018 to 2020:
#
# * Duration (in seconds)
# * What is your gender?
# * What is your age (# years)
# * In which country do you currently reside?
# * What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# * What is your current yearly compensation (approximate $USD)?
# * What programming languages do you use on a regular basis?
# * Select any activities that make up an important part of your role at work:
# * Select the title most similar to your current role (or most recent title if retired):
# * What programming language would you recommend an aspiring data scientist to learn first?
# * Does your current employer incorporate machine learning methods into their business?
# * For how many years have you used machine learning methods?
# * What is the primary tool that you use at work or school to analyze data?
# * Who/what are your favourite media sources that report on data science topics?

# %% [markdown]
# # Questions that is asked only this year(new in 2020):
#
# * For how many years have you been writing code and/or programming?
# * Do you use any tools to help manage machine learning experiments?
# * What type of computing platform do you use most often for your data science projects?
# * Approximately how much money have you (or your team) spent on machine learning and/or cloud computing services at home (or at work) in the past 5 years (approximate $USD)?
# * Which of the following business intelligence tools do you use on a regular basis?
# * Where do you publicly share or deploy your data analysis or machine learning applications?
# * Which of the following business intelligence tools do you hope to become more familiar with in the next 2 years?
# * Which of the following cloud computing platforms do you hope to become more familiar with in the next 2 years?
# * In the next 2 years, do you hope to become more familiar with any of these specific cloud computing products?
# * Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you hope to become more familiar with in the next 2 years?
# * Which categories of automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?
# * Which specific automated machine learning tools (or partial AutoML tools) do you hope to become more familiar with in the next 2 years?
# * In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments?

# %% [markdown]
# # Questions that were asked in 2020 but asked differently in 2019:
#
# **In 2020:** Which of the following automated machine learning tools (or partial AutoML tools) do you use on a regular basis?
# **In 2019:** Which automated machine learning tools (or partial AutoML tools) do you use on a regular basis?
#
# **In 2020:** Approximately how many times have you used a TPU (tensor processing unit)?
# **In 2019:** Have you ever used a TPU (tensor processing unit)?
#
#
#
# **In 2020:** Do you use any automated machine learning tools (or partial AutoML tools) on a regular basis?
# **In 2019:** Which categories of ML tools do you use on a regular basis?

# %% [markdown]
# # Some questions were merged in 2020 which is quite similar to 2018 or 2019 questions:
# **In 2020:** Which of the following big data products (relational databases, data warehouses, data lakes, or similar) do you use on a regular basis?
#
# **In 2019** Which specific big data / analytics products do you use on a regular basis?
# **In 2019:** Which of the following relational database products do you use on a regular basis?
#
# **In 2018:** Which of the following relational database products have you used at work or school in the last 5 years?
# **In 2018:** Which of the following big data and analytics products have you used at work or school in the last 5 years?

# %% [markdown]
# # Questions that were asked in year 2019, 2020 but asked differently in 2018:
#
# **In 19 & 20:** Which of the following hosted notebook products do you use on a regular basis?
# **In 18:** Which of the following hosted notebooks have you used at work or school in the last 5 years?
#
# **In 19 & 20:** Which of the following integrated development environments (IDE's) do you use on a regular basis?
#  Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years?
#
# **In 19 & 20:** Which of the following cloud computing platforms do you use on a regular basis?
# **In 18:** Which of the following cloud computing services have you used at work or school in the last 5 years?
#
# **In 19 & 20:** On which platforms have you begun or completed data science courses?
# **In 18:** On which online platforms have you begun or completed data science courses?
#
# **In 19 & 20:** Which of the following machine learning frameworks do you use on a regular basis?
# **In 18:** What machine learning frameworks have you used in the past 5 years?
#
# **In 19 & 20:** What data visualization libraries or tools do you use on a regular basis?
# **In 18:** Of the choices that you selected in the previous question, which specific data visualization library or tool have you used the most?
#
# **In 19 & 20:** Do you use any of the following cloud computing products on a regular basis?
# **In 18:** Which of the following cloud computing products have you used at work or school in the last 5 years?
#
# **In 19 & 20:** Do you use any of the following machine learning products on a regular basis?
# **In 18:** Which of the following machine learning products have you used at work or school in the last 5 years?

# %% [markdown]
# # Questions that were asked in year 2019 and 2020 but not in 2018:
# * Which of the following ML algorithms do you use on a regular basis?
# * Which types of specialized hardware do you use on a regular basis?
# * Which categories of computer vision methods do you use on a regular basis?
# * Which of the following natural language processing (NLP) methods do you use on a regular basis?
# * Approximately how many individuals are responsible for data science workloads at your place of business?
# * What is the size of the company where you are employed?

# %% [markdown]
# # Questions that were asked in 2019 and 2018 but not in 2020:
#
# * How long have you been writing code to analyze data (at work or at school)?

# %% [markdown]
# # Others questions asked in 2018:
#
# * Which best describes your undergraduate major?
# * What specific programming language do you use most often?
# * Approximately what percent of your time at work or school is spent actively coding?
# * Which types of data do you currently interact with most often at work or school?
# * What is the type of data that you currently interact with most often at work or school?
# * Where do you find public datasets?
# * How many years of experience do you have in your current role?
# * What data visualization libraries or tools have you used in the past 5 years?
# * Do you consider yourself to be a data scientist?
# * During a typical data science project at work or school, approximately what proportion of your time is devoted to the following?
# * What percentage of your current machine learning/data science training falls under each category?
# * On which online platform have you spent the most amount of time?
# * How do you perceive the quality of online learning platforms and in-person bootcamps as compared to the quality of the education provided by traditional brick and mortar institutions?
# * Which better demonstrates expertise in data science: academic achievements or independent projects?
# * How do you perceive the importance of the following topics?
# * What metrics do you or your organization use to determine whether or not your models were successful?
# * Approximately what percent of your data projects involved exploring unfair bias in the dataset and/or algorithm?
# * What do you find most difficult about ensuring that your algorithms are fair and unbiased?
# * In what circumstances would you explore model insights and interpret your model's predictions?
# * Approximately what percent of your data projects involve exploring model insights?
# * What methods do you prefer for explaining and/or interpreting decisions that are made by ML models?
# * Do you consider ML models to be "black boxes" with outputs that are difficult or impossible to explain?
# * What tools and methods do you use to make your work easy to reproduce?
# * What barriers prevent you from making your work even easier to reuse and reproduce?

# %% [markdown]
# Thanks for your time..
# If this work is helpful anyway for you please upvote this notebook and feel free to comment your thoughts or suggestions.
