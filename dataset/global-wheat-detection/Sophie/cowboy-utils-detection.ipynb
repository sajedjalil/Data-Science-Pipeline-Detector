# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))
# !pwd
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !ls /kaggle/working

# %%
# !git clone https://github.com/ultralytics/yolov5.git

#!cp ../input/yamlmunagedata/* /kaggle/working/yolov5
# !cp ../input/cowboyutilsyaml/* /kaggle/working/yolov5
#!ls ../input/yamlmunagedata
#!mkdir /kaggle/working/yolov5/wheatdata
##!cp -rf ../input/wheatdata /kaggle/working/yolov5

# !ls /kaggle/working/yolov5
#!rm -rf /kaggle/working/yolo5
# !cp /kaggle/input/requirements/requirements.txt /kaggle/working

# %%
# !ls /kaggle/working/yolov5
#../input/cowboyutilsyaml
# !wandb off
# !python /kaggle/working/yolov5/train.py --img 640 --batch 256 --epochs 50 --data cowboy_utils.yaml --cfg models/yolov5s.yaml --name cowboy_utils  --nosave --cache

# %%
#$ python train.py --img 640 --batch 16 --epochs 5 --data coco128.yaml --weights yolov5s.pt
#!gdown --id 1czESPsKbOWZF7_PkCcvRfTiUUJfpx12i -O models/yolov5x.yaml
#!ls /kaggle/working/yolov5
# !ls /kaggle/working/runs/train/exp/weights

#!cp /kaggle/input/requirements/requirements.txt /kaggle/working
#!cat /kaggle/working/requirements.txt
# !python /kaggle/working/yolov5/detect.py  --source ../input/cowboyutils/val/images --weights /kaggle/working/runs/train/exp/weights/best.pt

# %%
#!ls /kaggle/working/runs/detect/exp2
# !ls /kaggle/working
#__notebook__.ipynb  __output__.json

# %%
import zipfile
from pathlib import Path

img_root = Path('/kaggle/working/runs/detect/exp2')
with zipfile.ZipFile('result_imgs.zip', 'w') as z:
    for img_name in img_root.iterdir():
        z.write(img_name)

# %%
# !python test.py --weights best.pt --data cowboy_utils.yaml --img 640 --iou 0.65
