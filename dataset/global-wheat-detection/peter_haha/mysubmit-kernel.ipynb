# %%
# !cp -r /kaggle/input/mmdwhl/mmd_whl/cocoapi cocoapi;

# %%
cd /kaggle/working/cocoapi/PythonAPI

# %%
# !python setup.py build_ext install

# %%
cd /kaggle/working/

# %%
# !pip install /kaggle/input/mmdwhl/mmd_whl/addict-2.2.1-py3-none-any.whl
# !pip install /kaggle/input/mmdwhl/mmd_whl/mmcv-0.5.1-cp37-cp37m-linux_x86_64.whl
# !pip install /kaggle/input/mmdwhl/mmd_whl/terminal-0.4.0-py3-none-any.whl
# !pip install /kaggle/input/mmdwhl/mmd_whl/terminaltables-3.1.0-py3-none-any.whl
# !cp -r /kaggle/input/mmdwhl/mmd_code/* /kaggle/working
# !ln -s /kaggle/input/global-wheat-detection/test /kaggle/working/data
# !mkdir data/annotations
# !python data/get_test_json.py
# !pip install -v -e .
# !chmod +x tools/dist_test.sh

# %%
import run
config = '/kaggle/input/my-pth/faster_rcnn_r101_fpn_1x.py'
model = '/kaggle/input/my-pth/epoch_12.pth'
num_gpu = 1
run.test(config, num_gpu,model)
run.json2submit('results.bbox.json','data/annotations/test.json','submission.csv',0)

# %%
# !ls . |grep -v submission.csv | xargs rm -rf

# %%
# !cat /kaggle/input/mmdwhl/mmd_code/run.py
