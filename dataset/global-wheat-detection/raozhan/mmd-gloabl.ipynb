# %% [markdown]
# # 配置环境

# %%
# !conda create -n open-mmlab python=3.7 -y
# !source activate open-mmlab

# %%
# !conda install pytorch torchvision -c pytorch

# %%
# !pip install numpy==1.17.3

# %%
# !git clone https://github.com/open-mmlab/mmcv.git
# !cd mmcv
# !pip install . 
# !cd ..

# %%
# !pip install pycocotools

# %%
# !git clone https://github.com/open-mmlab/mmdetection.git

# %%
cd mmdetection/

# %%
# !pip install -r requirements.txt

# %%
# !pip install opencv-python

# %% [markdown]
# # 替换coco.py文件

# %%
rm -rf /kaggle/working/mmdetection/mmdet/datasets/coco.py

# %%
cp -r /kaggle/input/mmdetection/coco.py /kaggle/working/mmdetection/mmdet/datasets/coco.py

# %% [markdown]
# # 替换class_name文件

# %%
rm -rf /kaggle/working/mmdetection/mmdet/core/evaluation/class_names.py

# %%
cp -r /kaggle/input/mmdetection/class_names.py /kaggle/working/mmdetection/mmdet/core/evaluation/class_names.py

# %%
rm -rf /kaggle/working/mmdetection/global-wheat-detection/datasets/coco_detection.py

# %%
cp -r /kaggle/input/mmdetection/global-wheat-detection /kaggle/working/mmdetection/

# %%
# !python setup.py develop

# %%
# !python /kaggle/input/yuchuli1/kaggle_csv.py

# %%
# !rm -rf work_dirs
# !mkdir work_dirs

# %% [markdown]
# # 训练代码

# %%
# !python /kaggle/working/mmdetection/tools/train.py /kaggle/working/mmdetection/global-wheat-detection/cascade_rcnn_r50_fpn_1x_coco.py  --work-dir /kaggle/working/mmdetection/work_dirs
