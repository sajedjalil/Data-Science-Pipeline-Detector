# %%
# %cd /kaggle/input/wheatdetection/wheatdetection
! python ./tools/test_net.py MODEL.PRETRAINED '(False)' DATASETS.ROOT_DIR '("/kaggle/input/global-wheat-detection")'\
TEST.WEIGHT '("/kaggle/input/resnestwheat/giou-fold0.bin")' OUTPUT_DIR '("/kaggle/working/")'
