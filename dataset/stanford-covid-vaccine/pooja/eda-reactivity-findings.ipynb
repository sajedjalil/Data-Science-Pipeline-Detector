# %% [markdown]
# # *Summary:*
# 1.	High Reactivity observed towards the edges
# 2.	Specific Base is causing high reactivity at the edges
#     ![image.png](attachment:image.png)
# 3.	High reactivity observed for sequence A, followed by G
# 4.	Paired structures comparatively less reactive
# 5.	loop type S is less reactive compared to loop type- B,E,H
# 6.	G.E is highly reactive but U.E is less reactive
# 7.	G.E is highly reactive, but G(S or G)S is less reactive

# %% [markdown]
# **Approach:** Comparing high, medium, low reactivity
# Percentile distribution of reactivity is used to divide to high, low, and medium reactivity
#
#  ![image.png](attachment:image.png)
#
# * High reactivity (75th percentile): >0.4548
# * Medium reactivity (25-75th Percentile): >0.0238 to <=0.4548
# * Low reactivity (below 25th percentile): <=0.0238 reactivity

# %% [markdown]
# **Hypothesis 1:** Position of the base influences the reactivity (High reactivity at the edges):
#
# ![image.png](attachment:image.png)
#
# * High reactivity is observed towards the edge sequence position 0-4. This pattern was not prominent for medium or low reactivity.

# %% [markdown]
# **Hypothesis 2:** Specific Base is causing high reactivity at the edges
# When filtered for the edge position the following is observed.
#
# ![image.png](attachment:image.png)
#
# * Clearly G.E And A.E has very high reactivity.

# %% [markdown]
# **Hypothesis 3:** Common base Sequence, structure and loop combination that is causing high reactivity.
#
# ![image.png](attachment:image.png)
#
# * High reactivity observed for sequence A, ‘.’ structure and loop type- B,E,H

# %% [markdown]
# **Hypothesis 4:** Neighbors can influence high reactivity
#
# ![image.png](attachment:image.png)
#
# * G.E is highly reactive but U.E is less reactive
# * G.E is highly reactive, but G(S or G)S is less reactive
