# %% [markdown]
# Sit back, take a deep breath and make yourself comfortable ...
# What else could happen?

# %%
from IPython.display import Video

Video("/kaggle/input/memevideos/video.mp4", embed=True)
