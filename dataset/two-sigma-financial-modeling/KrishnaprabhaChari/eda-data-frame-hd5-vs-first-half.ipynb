# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import kagglegym
import numpy as np
import pandas as pd
import random
from sklearn import ensemble, linear_model, metrics


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
env = kagglegym.make()
o = env.reset()
train = o.train  #train dataset
print(train.shape) #print shape

# %%
train["nbnulls"]=train.isnull().sum(axis=1) #add variable to dataset for number of nulls
col=[x for x in train.columns if x not in ['id', 'timestamp', 'y']]  #col = predictors
len(list(train))
list(train)

# %%
d_mean= train.median(axis=0)  #imput median
d_mean

# %%
train.describe().transpose()

# %%
so=train.corr().unstack().order(kind="quicksort")
#print(so[-len(so):-len(so)+20])
print(so["y"].sort_values(ascending=False))

# %%
typ=(train.dtypes != "float32")
train.dtypes[typ.index[typ]]

# %%
train["timestamp"]

# %%
len(o.train)

# %%
with pd.HDFStore("../input/train.h5", "r") as train1:
    # Note that the "train" dataframe is the only dataframe in the file
    df = train1.get("train")

# %%
len(df)

# %%
df.head()

# %%
df.tail()

# %%
train.tail()

# %%
# How many timestamps are in the full training set?
len(df["timestamp"].unique())

# %%
# How many timestamps are in this train dataframe?
len(train["timestamp"].unique())

# %%
# Look at the first few rows of the features dataframe
o.features.head()

# %%
len(o.features)

# %%
len(o.features["timestamp"].unique())

# %%
o.features["timestamp"]

# %%
# Here's proof that it's the first half:
unique_times = list(o.train["timestamp"].unique())
(min(unique_times), max(unique_times))

# %%
predict_times=list(o.features["timestamp"].unique())
(min(predict_times),max(predict_times))
