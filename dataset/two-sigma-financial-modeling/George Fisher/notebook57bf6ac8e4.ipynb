# %% [markdown]
# # Reinforcement Learning: What Produces Good Rewards?
#
# I have managed to get onto the leaderboard with a brute-force regression, borrowing tricks like y-clip from other participants. But this approach bears no resemblance to reinforcement learning, so I've been wondering how I can modify my algorithm based on the rewards I receive.
#
# I've cut-and-pasted timestamp-by-timestamp data from a training run. This chart is as far as I have managed to get ... not very far.
#
# I've tried to regress each id but I always run out of time and I haven't found any brilliant way to cluster ids in enough time, either.
#
# So at the moment I'm thinking I have to do brute-force methods but maybe I can make modifications at each step based on the rewards I receive. But this graph doesn't give me any ideas about which levers to pull.
#
# ![Combined data][1]
#
#
#   [1]: https://georgefisher.com/images/reinforcementlearning.png

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data from training run

# %%
timestamps = [906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 933, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 959, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812]

rewards = [-0.18954802938021723, -0.031531294296047126, -0.086769559633674193, -0.12571688599064368, -0.047738813130002597, -0.12583377087037018, -0.34280531577210893, -0.060572830248815601, -0.13016524426282911, -0.046626619951715798, -0.054006488962454226, -0.16315754119923995, -0.02003684191978819, -0.061638873668380556, -0.17438959894699599, -0.14382983600057736, -0.10219832700552317, -0.27835925353835145, -0.068115607016526233, -0.075807277882543517, -0.16083619855856662, -0.03267074694322615, -0.20773253891608584, -0.08373078111727926, -0.15514478921011918, -0.017315749535163794, -0.36044306161360384, -0.14579743540621046, -0.12520003935119661, -0.15964236300538875, -0.033058925081710926, -0.063481801825087503, -0.3105637328332525, -0.26076588891975477, -0.049222077316616236, -0.013494310495717813, -0.049163734474724871, -0.19976599500888306, -0.081525159957704235, -0.046206674822292543, -0.019379719739917516, -0.20506957029110973, -0.36594922564480575, -0.11974345109534627, -0.10464613066972367, 0.036514830977086993, -0.055128790876495852, -0.13760529567925095, -0.089113279791714614, -0.095833469500844468, -0.068404570744953083, 0.043462183917969813, -0.092647536221866375, -0.10938358286543118, -0.15081279842500636, -0.03248530336167018, -0.044780079104958737, -0.14056669947836245, -0.14188577667235508, -0.13557500437873971, -0.43655147376281844, 0.049474241523140117, -0.14441072908264627, -0.065530583158295616, -0.094410822929325247, -0.088362188166353023, -0.067725275022944453, -0.22965456687711977, -0.041927500646135339, -0.14673151003706508, -0.078739231921270705, -0.29919043390521777, -0.20810955342625748, -0.13873109737858519, -0.1356818908761051, -0.11179134590445393, -0.082185903168094113, -0.3088609606080579, -0.16530527868549266, -0.13433939701764105, -0.08577912570150624, -0.15126679291850664, -0.17179130678836216, -0.067831862547659369, -0.089981832459365141, -0.095048203479778132, -0.24831768599923573, -0.19398992004297536, -0.42444032443849522, -0.088626545238760526, -0.30668674680460078, -0.055298942566019929, -0.16017150185359974, -0.32040589992396445, 0.046063833670505934, -0.1149957989188492, -0.16412119248374546, 0.052854873231515859, -0.28059865619555086, -0.042246210738230414, -0.15905936007165983, -0.1467157734231864, -0.14562791288983148, -0.061441611039602891, 0.062792659228156952, -0.11514960750439049, 0.068685299854566464, -0.02583249411443082, -0.1585942432294021, -0.081405900034254589, -0.044845449510775896, -0.11509276140050592, -0.024054726373169997, -0.35073192472416592, -0.17887453643162091, -0.054216397293340615, -0.13069919516012718, -0.14257125035794205, 0.025841610138540458, -0.11170154844542751, -0.056907426887344736, -0.076436572866960109, -0.031504204020993548, -0.22284378706337135, -0.095463944206293255, -0.20183319198372435, -0.15526313216785406, -0.078992993584593885, -0.24898693557445908, -0.21882863643340353, -0.077849986263231058, -0.10959844094185332, -0.1323945958823653, -0.25838931005534821, -0.10473048646405934, -0.1083575264399084, -0.068157221059574044, -0.081173238323993133, 0.019382310234000444, -0.1529673481534245, -0.059576576429929626, -0.10887625724665234, -0.12514506277036053, -0.085401083679378001, 0.049471107351766443, -0.026683244620606256, -0.1782101732315893, -0.19463524208717839, -0.11858118012950558, -0.085185175594608614, -0.20575798727549816, -0.14662259457771967, 0.096625444300101768, -0.29132316642705636, -0.064865211524754038, -0.16360581757363024, 0.0085634631809807151, 0.012401771540464641, -0.20078388617195247, 0.043393344322938045, -0.013514944419490129, -0.1460994391218185, -0.049770917555764974, -0.044391669613224348, 0.014960395598224967, -0.25232144041189214, -0.12445810099303789, -0.15915326736929913, -0.19632765876509953, -0.33690996912179888, -0.13611776744076581, -0.11091422420401408, -0.16614975924066117, -0.2112980178516293, -0.24256266053415745, 0.023351807982308348, -0.021809342647137582, -0.12438906431702812, -0.13952645635209535, -0.21882100337575514, -0.24641613141832258, -0.10616885060499397, -0.10227736039568715, -0.16842153335176735, -0.023212780334232998, -0.095978171130164769, -0.10860222194471848, -0.079006940451621196, -0.35560506536858527, -0.23365121228560509, 0.045787283910445051, -0.089323226332024955, -0.029590486709000875, -0.18026171597581989, -0.049815529496014345, -0.086741900807402406, -0.20519740453534741, -0.2231041686498885, -0.050885415159387867, -0.17452684362963095, -0.15611223578445096, -0.07020439615720471, -0.19034338851259491, -0.25558690675054929, -0.24681688570590951, -0.016589163704706977, -0.16387509366598091, -0.19378816438442648, -0.037734619954679631, -0.14678404847725007, -0.30919401230933957, -0.23203837622740248, -0.15383285285503745, -0.14409470175715286, -0.14526244784317688, -0.23985488847574798, -0.019482519053131135, -0.072941453401976095, -0.28678159203126785, -0.12595048627462771, -0.12341023582781313, -0.043293095244795958, -0.078514325128195686, -0.093896763511649009, 0.024145312298755418, -0.20780636854712331, -0.061037640752800847, -0.15233306223050552, 0.075016284236354661, -0.11025538279836757, -0.051120121180071192, -0.20171640488794157, -0.073177355941370203, -0.24874964616716022, 0.065937598246415596, -0.16167954530441411, -0.089932428389789196, -0.23514556539598075, -0.22050158472183903, -0.17369637084174031, -0.023734237825343715, -0.35205222833976019, -0.1952678865819113, 0.0423575050724736, -0.11839402319400687, -0.13238665100422731, -0.10376952514045704, -0.16741808809164621, -0.013287658482120303, -0.14286838299928403, -0.049496518153077304, -0.026788757254378473, -0.034098293719140672, -0.073774827764898132, -0.17711628194493997, -0.08515263367148096, -0.17402482090693247, -0.10417753505408806, -0.070968922645205407, -0.14319115578179739, -0.27094415567588348, -0.1512515098264485, 0.058913357938491159, -0.17628885526469118, 0.0092992810754448547, -0.13910366214701528, -0.056872436376058683, -0.098402043726181762, -0.033378191525397991, -0.12912382833010635, -0.1818316428981486, -0.052825368185303249, -0.18864401755315591, -0.23042618977508952, -0.27515266262182131, -0.16377742925296221, -0.048938422627819209, -0.17506283192935065, -0.058629723640978966, 0.024963781124450909, -0.095866011382760005, -0.078132914027513753, -0.057790244687716263, -0.16470037265830173, -0.02481127609306609, -0.2329155608077787, -0.11744724900409334, -0.13624733737321856, 0.055247802304579825, -0.10902725863303238, 0.076227612651809801, -0.17024318316326387, -0.0064465092435519924, -0.16920150515832463, -0.083777321448812267, -0.2257969540709098, -0.23599117936664007, -0.11822574677232532, -0.10387055801178831, -0.026120251525065023, -0.025836292542549849, -0.15875628651099086, -0.18436327074606773, -0.10237519300164034, 0.055011830497740839, -0.036445663612575431, -0.15099687154997904, -0.14869733741203056, -0.12304461337388781, -0.20521559927970942, -0.075391537872972925, -0.17674023220552337, -0.11058867595826052, -0.44077586767866672, -0.22005174595312441, 0.019042498177463046, -0.0083961388378096507, -0.13853127368850973, -0.045853622733226948, -0.11968597125864336, -0.059026121281762982, -0.19179356771252398, -0.16792329843907891, -0.069299567478154106, 0.042753749374596271, -0.33476402769206109, -0.091092557240428876, -0.2070420269781347, -0.069703767018802182, -0.26068160562338416, -0.26393072973470355, -0.21554611080917274, -0.069610299030472639, -0.15166593381754093, -0.11183437904684175, 0.029658765742742069, -0.063821192858028869, 0.066955508345650019, -0.11808996009758109, -0.072728046834091578, -0.027335812194937636, -0.080604016414123278, -0.13521842084586044, -0.15496843107690098, -0.1730314849600976, -0.027460021795221348, -0.19999139745601552, -0.16798864404594083, -0.35306588315145282, -0.12818974214909726, -0.2121667644094066, 0.0051040736886006771, -0.11262493394846534, -0.039355426170866396, -0.086702792997404743, -0.19928927599609531, -0.32688218955156451, -0.28124803453340019, -0.049788032050138806, -0.057266051072918843, -0.32465016768869542, -0.27314743675968683, -0.10878064091015996, -0.22532379558305982, -0.037392189302379988, -0.25037375022084907, -0.014887414713517183, -0.084133153653918713, -0.050123129899864574, -0.032261878019728948, -0.076523289189848936, -0.11872458466791935, -0.051490696726191686, -0.054053329440819191, -0.035709146929681024, -0.090594348113501255, -0.070903065883806793, -0.2202819807623167, -0.079468248765927299, -0.26173554943532185, -0.21767252469860549, -0.0016137737701572379, -0.11190169068599866, 0.028578511323541646, -0.093367151243889113, -0.10672803910518901, -0.12906464968087322, -0.087878982626052385, -0.16645045360952487, -0.32260973479324179, 0.015342273387975867, -0.043241492127018819, -0.079386084494881423, -0.0090019227099174797, -0.069908380197681835, -0.28111686738717168, -0.052905221953603358, -0.10655670959829246, -0.11216576156793567, -0.13890301863041873, -0.28559479876397498, -0.082554544985298434, -0.39381612390469967, -0.033680763005008066, -0.25200934290415206, 0.066848276026951092, -0.030843248792793619, -0.13938370812444117, 0.013461974234175106, -0.17809075928270535, -0.11917610553774323, 0.059322994754358663, -0.20790489425098138, -0.027474676906434355, -0.068853436301379425, -0.072487114867240438, -0.11198748630666892, -0.080252828745941363, -0.071223902595682953, -0.073715930488965187, -0.039000658099614657, -0.41173112255565503, -0.152375995420027, -0.14191330649222997, -0.24166923546638033, -0.13630565630740346, -0.081979030792994539, -0.040482691633935211, -0.087613313152081637, -0.15090081993606286, -0.10516494439126138, -0.1127264625439639, -0.055432428035144213, -0.14172611580102881, 0.034636836534618763, -0.27380918635047502, -0.085671182462537326, -0.088836019205875111, -0.14521345924426243, -0.055088311489288846, -0.14207122378926257, -0.11534000653675879, -0.10615143926811531, -0.05653591760135597, -0.18870522229382103, -0.22434487109872234, -0.12339220062452355, -0.080905716790747734, -0.14325535558374886, -0.059998017559413773, -0.13640467927956298, -0.057609974270735748, -0.11315067949985723, -0.15372562846748891, -0.11730093942922197, -0.19754243809393662, -0.1286434129130278, 0.045758186122251056, -0.21136326012968937, 0.038861860302907704, -0.083745638537592273, -0.38831480872237301, -0.31235787758010142, -0.26658236166883781, -0.26221480769618394, 0.043945546193903298, -0.12911665372910208, 0.043489016892825479, -0.028366604636879275, -0.044949519330671213, -0.097153816292869954, -0.18049787465335906, -0.12942240397897645, -0.064594181635315093, -0.21071187073460781, -0.1497739597731825, -0.10926069440115926, 0.051202026851644475, -0.042580758829080773, -0.039982865990872488, -0.069346884570730377, 0.023736889943179715, -0.19853381185740962, -0.12882781236011182, -0.25464703182281601, -0.047608020551913627, -0.4100307454347526, -0.11697579979043202, -0.11976781975304791, -0.37484187866505042, -0.12702942386585594, -0.011846436745838993, -0.1513167500581688, -0.12249449784337467, -0.16669830207926492, -0.082127438845125522, -0.29893742512961352, 0.067184702304595681, -0.3360840912807167, -0.12838917431609786, -0.1500631943443422, -0.14960595117366135, -0.35734081269726209, 0.084325838852169391, -0.28815011390883677, -0.094787422707346247, -0.08243477044883879, -0.08842767346295867, -0.066415222265209337, 0.030741330469589455, -0.086204172385697955, -0.06304526796454514, -0.047020739426351613, -0.13137982492262607, -0.15572894810709881, -0.1004965352798128, -0.080788066030054437, -0.15659338508383902, -0.079726848323907293, -0.10879424416921864, 0.055438445446723765, -0.086618653557316197, -0.16431365826685859, -0.096223809477439207, -0.14613410886998932, -0.082695256092926148, -0.10336149291579518, -0.14216025595746376, -0.14844576422223696, -0.11824207132827294, -0.2740057467730625, -0.1218964383923325, 0.028965183584377521, 0.029631014728940797, -0.11305983946156531, -0.12470349982213649, -0.089100848033531438, -0.26621849191700736, -0.036421047984064266, -0.047545922144013458, -0.33152264364333017, -0.13561440547193787, -0.10538639459919369, -0.064105562939431537, -0.049396249590760069, -0.12719196984322223, -0.12782014000550906, -0.21224048683585289, -0.03111987233312578, -0.10758553575201267, -0.13030078263649394, -0.049333476175768318, -0.055265770024026079, -0.061076856971055915, -0.10164414820820186, -0.029764096370310706, -0.17664227617058414, -0.030495338868922341, -0.29379061395327455, -0.090342524265409674, -0.17323522543022382, -0.015471448258628152, -0.10456291978497256, -0.10075793296762348, 0.046053341996150521, -0.10098822198529334, -0.11857103376842056, -0.053717884102164569, -0.07900473350866466, -0.08595395642296122, -0.061741720018093145, -0.24973700354014763, -0.1561000014482645, -0.1388937016802155, -0.34139896980798051, 0.090174115321666207, -0.16891553015228594, 0.049011504152379461, -0.35645831301418751, -0.11521178206536248, -0.10631481165175724, -0.15824474233161095, -0.38746612360140797, -0.23459467171023521, -0.13060529302168181, -0.10671766728439805, -0.40317495542323495, -0.14516235830794252, -0.059140109055001687, -0.057350965319133709, -0.1806471643912369, -0.16299987395640164, -0.18703541192086479, -0.16811886882608182, -0.15366012587379277, 0.042667598069695292, -0.022486836508311434, -0.13086918474380957, -0.11649050756841081, -0.13077341395519004, 0.018327447056125427, -0.048644692715653616, -0.11565777249046125, -0.26051125696480859, -0.23839593450683574, -0.13519964971210549, -0.12363196291558258, 0.062788494773969694, -0.045764046872854243, -0.083275441987990056, 0.044453530581512461, 0.091544557203844579, -0.22394439751381878, -0.084707639315042313, -0.13760516786669469, -0.059768645803651752, -0.055795633632312935, 0.055582732888118019, -0.18535115192600474, -0.11305148200833423, -0.31303195772131903, -0.090406567830549164, -0.093620710467898521, -0.14414714972327805, -0.051562231165397744, 0.057543412804707476, -0.32034646519574245, -0.17322801695527024, -0.179510461172595, -0.090642676310285095, 0.071493285805687715, 0.084409954997787751, -0.058321858703162199, -0.20103468179507031, -0.3329950699885979, -0.26084939977081856, -0.3527300641888253, -0.35767760312661451, -0.13144479468088169, -0.27710134798632952, -0.24737940161720856, -0.057007987805015779, -0.050140735525174965, 0.024705294180609311, -0.10149380020105447, -0.24851855077537316, -0.084315768168763169, -0.15119404700731121, -0.087630883387188163, -0.058258893711907074, -0.16695609053822436, -0.40430448103230815, -0.49277594847476813, -0.30558069572425445, -0.31916072053967226, -0.086450337455376849, -0.25061469834764671, 0.047201350218139863, -0.0321536912280799, -0.184416014427222, -0.33862423800535352, -0.17581228973952309, -0.18670074796418781, -0.12167577013821956, -0.28563022702673591, -0.42512199093263292, -0.39361524601735537, -0.10726753576158361, -0.13001639897302411, -0.24594501658441878, -0.24304924044123979, -0.045463423354661199, -0.25206896280343893, -0.12382788853824281, -0.13964576205913884, -0.07007366321855997, -0.28893508518507321, -0.2627645689614857, -0.38793238425385496, -0.36816795892945137, -0.10152326212972591, -0.50704184339600167, 0.07114294298865026, -0.2319900531000261, -0.11730676337919828, -0.27970876830073299, -0.34159068771321499, -0.21099539332523914, -0.37763735007246824, 0.06826161348907793, -0.26801649919766429, -0.42457663360206399, 0.087842470752530058, -0.21402379887476186, -0.1603669969295578, -0.12877260476981836, -0.17599509099855126, -0.29980879696403689, -0.13307372226359018, -0.23897950448928232, 0.053766210223742041, -0.2752592773457529, -0.1555460152519656, -0.051106598081592104, 0.054117404551444571, -0.11888267710622311, -0.10458264112172892, -0.21337671473591502, -0.1370331794613264, -0.022787229028467845, -0.22796838562400959, 0.023594608678980718, -0.17277575865761494, 0.047540173894436037, -0.060715884635002347, -0.062850101886709864, -0.31964807159872072, -0.21937763166925614, -0.067337362953638485, -0.035158087159183407, -0.18808228558874285, -0.052020647380809582, -0.31608376487524997, -0.23135138229707275, -0.15133473687780874, -0.16671571753026113, -0.024605325638947188, -0.16378618376631854, -0.058899118481096406, -0.17255153076544738, 0.069775363892516179, -0.058897500149367649, -0.34407278177096379, -0.13126480723471734, -0.25029977524646752, -0.080510095756025718, -0.10898789642232486, -0.42783108393810215, -0.11834303273504398, -0.042692410959670801, -0.072021238108830252, -0.45097961757309146, -0.27301231692040739, -0.1180244748293621, -0.24785263926554202, -0.10998584261722161, 0.071575570997758145, -0.090727282137251369, -0.2040526786634636, -0.33144023055514349, -0.34206319378033756, -0.22388765723553394, -0.25647620062209425, -0.20672181918893606, -0.15276477499373142, -0.26684613260246426, -0.12839587118329146, -0.05146472980934011, -0.19056942302316718, -0.081179120039630626, -0.25485683472153908, -0.18886409200450346, -0.3617070626456228, -0.48456508244580676, -0.28555457458540878, 0.083759623134390934, -0.24803130326187278, -0.16338403447166286, -0.060181659519676779, -0.10298921221831203, -0.23568472242406507, -0.1773907556598168, -0.26556874179948248, -0.071371679294976245, -0.25995698746585127, 0.075719099868203452, -0.093946328812812424, -0.2672205925141965, -0.083238340722785145, -0.094109440556192719, -0.10814436655753765, -0.039889184232523411, -0.079230594446774855, -0.061798274503078746, -0.21726864824865258, -0.096219149862225906, -0.19337617908827989, -0.18192646570683824, 
-0.22911183341774147, -0.028284471803541846, -0.2069346946571837, -0.13860410187459205, -0.061876502382899677, -0.30281170153683057, -0.039697185416929244, -0.23258294408029423, -0.052452632516590283, -0.17504641487946121, -0.15927418929652382, -0.07171932744690114, -0.15743499776284831, -0.20240412153450366, -0.25494462421839664, -0.14379345572385499, -0.059466809669146518, -0.11496207540280026, -0.11186701605135567, -0.098403040263104341, -0.1469015698320866, -0.20045769529707524, -0.087557429854267288, -0.041793194919913276, -0.26378536832602045, -0.064585087104550992, 0.094692324383315388, -0.023039214810926106, -0.079742798459128031, -0.042965971434820331, -0.16086784696456696, -0.058628839134774582, -0.083391751995894978, 0.025270239119312646, 0.050925920551879743, -0.063964994765015784, -0.18895558491257877, -0.24483151397034569, -0.08217753112888096, -0.22607123017230937, -0.059456006650374163, -0.10667528189412713, -0.11868581897069039, -0.14250395582705383, -0.27284514044872854, -0.12722859244141441, -0.073742464258890875, -0.043654929931153129, 0.048313872269858046, -0.37298882691223056, -0.051479901758697287, -0.09367752609973827, -0.17595669221176111, -0.11337853250784323, -0.11585992591133835, -0.19249458964536986, -0.052331242248630498, -0.21092267195774997, 0.054485958850438172, -0.15991635206477853, -0.096999594062241082, -0.074882371965552433, -0.11956500489252833, -0.09479991757026146, -0.06460946844530932, -0.21348081552062059, -0.049191663371152265, -0.17511919980470386, -0.040785160045274965, -0.32875608762447167, -0.086502899506909092, -0.28220993426963192, -0.40798798544766457, -0.25039622428156399, -0.11006455362601021, -0.16325668624393394, -0.08121397050691187, -0.20679131478709176, -0.060570929200740108, -0.22104959515672631, -0.14288065062749267, -0.15285296184011415, -0.28007512672749552, -0.099201733686598709, -0.29784860143921399, -0.13880178164265106, -0.044469097368567918, -0.072904274860676133, -0.03281550942338278, -0.33679870820132857, -0.3794222052022807, -0.14628297266487836, -0.17679274663693231, -0.18857138835423592, -0.20342838600667273, -0.1641814055106435, -0.30599892696311942, -0.20424099038626961, -0.057096128970117087, 0.050074260316975053, -0.26061114413599007, -0.036753540170221061, 0.074837875374051191, -0.11763078136699565, -0.070999289369941349, -0.016140171809825739, -0.064665375483496976, -0.1784266162455683, -0.086312751456412401, -0.059445360506761982, -0.096912571779439544, -0.14477476416400997, -0.12141586069171868, -0.025759918238187726, -0.067438921103063709, -0.16023444539021992, -0.32672798303157058, -0.24645201237635722, -0.03394834880128314]

y_pred_mean = [0.0001784745049375917, 0.0001749150445533971, 0.00017544006681169194, 0.00018177226259162864, 0.00018468209013828887, 0.0001809626260865892, 0.00017719366243029312, 0.00017205713082904086, 0.0001701366986972771, 0.000158612275965983, 0.00015587960813611603, 0.00016943818813438855, 0.0001777602933674377, 0.0001786839456404277, 0.00017503746999669514, 0.0001794825413886296, 0.00018025149119810997, 0.00018417533251971987, 0.00019281111067744267, 0.00018289106389612358, 0.00017835022863226234, 0.00017569626526202934, 0.00018791486997708803, 0.00017725492595099725, 0.00017800852619308374, 0.00017559044828535203, 0.00017395331124660498, 0.00014724116747176461, 0.00014389096968076503, 0.00015370884882048226, 0.00016594573549051175, 0.00016965166906282833, 0.0001695847807783395, 0.0001837285610884349, 0.00019748996400625123, 0.0001887626458546414, 0.00019052233140774043, 0.0001719476075160864, 0.00016017190325803398, 0.0001701423814877486, 0.0001731259173396537, 0.0001678725204953396, 0.00018831744597513667, 0.0001718238331761237, 0.00015143856720263482, 0.0001574843397923581, 0.0001598405315853105, 0.00015887048462333466, 0.00016992974137338847, 0.0001691742521719952, 0.00016993864513709114, 0.00017306510392454052, 0.00017502121145600223, 0.00018185691477814341, 0.0001892641447985853, 0.00018258320575321942, 0.000186647927512761, 0.0001878589847971032, 0.00019407952567530837, 0.00020056277035131024, 0.00019817596701341374, 0.00016756396306231305, 0.0001706546672391225, 0.0001764111588997402, 0.0001762658015233723, 0.00016973953846085676, 0.00017495421955884507, 0.00017668162053877985, 0.00018840403454744588, 0.00019058541270445007, 0.0001914564629215584, 0.00018795250700440687, 0.00019661560085059695, 0.00018864289233619377, 0.00018522752754244765, 0.0001849510908814828, 0.00018503728332885523, 0.00018505801437032772, 0.000194643151712728, 0.00018525957348839304, 0.00017969782204926396, 0.00017153550834496205, 0.00016102989000591958, 0.0001635126058280556, 0.00016437142266788495, 0.00016991049685757646, 0.00016671483950007245, 0.00016316588459664978, 0.00013824997490822062, 0.0001228577229808159, 0.00012863798932076005, 0.00012327581895635868, 0.00011892087144926984, 0.00013457957517064206, 0.00011231077075889064, 0.00011746285948631011, 0.00011833992592665194, 0.00011130298605351107, 0.00012138387547364032, 0.00013757656100002263, 0.0001339199011796015, 0.0001510413640630654, 0.0001630855053948691, 0.0001688112231960087, 0.00016808223845540045, 0.0001718221328270001, 0.00016846310527721093, 0.00017448854139212112, 0.0001753004167957806, 0.00017061541939136226, 0.0001708038203393676, 0.00016265326091715986, 0.0001578868792208089, 0.00015007584150566523, 0.00017529596628813025, 0.0001685720823079954, 0.00017221287241808445, 0.00018356963940425872, 0.0001751022642629938, 0.000177605658566751, 0.0001712728245303275, 0.00017572804267994548, 0.00017995789287690627, 0.00018524657892930472, 0.00017433839580928653, 0.00017083761053503577, 0.00016364697646304168, 0.00015423068052488906, 0.00014410157313777503, 0.00015844364798803413, 0.00016731129432921162, 0.00016006104597367636, 0.00015241462168238889, 0.00015318724953577014, 0.00017213301083942572, 0.00017169897125136543, 0.00016555839453659182, 0.0001599909730918286, 0.00013759825011480377, 0.00015538386245266865, 0.00015692867951950704, 0.00016348013804166222, 0.00016424425697211505, 0.00016983673651616832, 0.00017861550426662734, 0.00017529475078209773, 0.00016835284307504825, 0.00017260964631459906, 0.0001627144649592202, 0.00015578448644627078, 0.00016235821611234276, 0.00015287128806408518, 0.0001609694709943648, 0.00017311633369830617, 0.00019089377678610492, 0.00019065814979405478, 0.00018436219293602797, 
0.00018465864879507312, 0.0001946460531996026, 0.00020423738563897395, 0.00020470179489145794, 0.00020032196240137978, 0.00019164370102145683, 0.00019125905046528993, 0.00019202672020909297, 0.0001905846128130574, 0.00019754259017046625, 0.00018851212821314282, 0.00019530209342544127, 0.000190031224070597, 0.0001971672008559896, 0.00020032132903207006, 0.00020946189293145518, 0.00020713770528406057, 0.00020986520057124312, 0.0002051461704216289, 0.00019081311199064472, 0.00019471604578550342, 0.00020160707693966031, 0.00016269968563104408, 0.00017434285026460356, 0.00017995328457731294, 0.0001856166971094878, 0.0001945620756469361, 0.00019970563354279039, 0.00019386083803925674, 0.0001876917261769884, 0.0001988587725424255, 0.00020041656144048967, 0.00021018791898257507, 0.00021574213444208387, 0.00021688645201893062, 0.00020947478566602678, 0.00020642970484784095, 0.00021357970701733791, 0.00020803240132175806, 0.0001997914381340255, 0.00020413603029048033, 0.00019203846545086655, 0.00019331384710714685, 0.00020918768138842474, 0.00021295345430789062, 0.00020918989891074888, 0.00020056022530661832, 0.00019181154771980767, 0.0002061644954068661, 0.00020685060219364463, 0.00020945384077382238, 0.0002149605827769963, 0.0002125487618950961, 0.00020906790966804308, 0.00019490893678791394, 0.0001842149332310973, 0.00018132504258696626, 0.00019173177873397653, 0.00018387710580068198, 0.00019801810022766262, 0.00019593914196983688, 0.00019259974628836442, 0.0001742889556863728, 0.00017476767232954928, 0.00018078247715296522, 0.00018470693525946103, 0.00018624174727854877, 0.00018181363189180726, 0.0001882476616846961, 0.00019812741736404213, 0.00019654009454324773, 0.00020448508449059786, 0.00020836388157241192, 0.00021588842827301337, 0.00021128777877131615, 0.00019347836521883786, 0.00019789375021382063, 0.00018662184150758474, 0.00018910269810774858, 0.0001820635979285655, 0.0001789675300090638, 0.00017353015548776703, 0.00018333234287216612, 0.00019458722148750238, 0.00018880638573214354, 0.00020413045718143823, 0.00020948793969084885, 0.00020109281221231896, 0.00018887566866470623, 0.00018460333481404043, 0.0001863963913192128, 0.0001937720767442938, 0.0001925220462280292, 0.00017945476281591908, 0.00017940544948589677, 0.0001721124563634374, 0.00016269836913190445, 0.0001586809513662602, 0.0001538892471325337, 0.0001622321807504141, 0.0001719705089352774, 0.00016750610402416427, 0.000164007323064395, 0.00015704767568824416, 0.00017395025239379797, 0.0001805297713558469, 0.00017912258385506497, 0.00016806965445134397, 0.0001693030862941698, 0.00017298648217402618, 0.0001772713883742367, 0.00017515882230376774, 0.00017667092599273627, 0.00017794706992404805, 0.00019183751716016136, 0.00019413201257613457, 0.00020017954084813235, 0.00020506645749814945, 0.0002108611262387103, 0.00020459917897172389, 0.00020696489973727616, 0.00020452445035762092, 0.00020556667473165566, 0.00020780664005930758, 0.0002117500765150836, 0.0002044625308825583, 0.00020198440314069218, 0.00020562077961831882, 0.0002038285655367804, 0.00019439246211725635, 0.00018638112847610243, 0.00018086443268312791, 0.000180995924571414, 0.0001810636998921642, 0.00019210294042766506, 0.00018908487604045516, 0.00019108319050770769, 0.0001841336789833928, 0.00017423354564434393, 0.00016574824491797044, 0.00016666263726214473, 0.00016730541828952885, 0.00016519172047579133, 0.00016882579669344982, 0.00016529707663661674, 0.00016278556224499024, 0.00015881629264392913, 0.0001546300884244647, 0.00016063202851911742, 0.000167644594064367, 0.00017195850508714054, 0.00016423173127802214, 0.00016321404233730292, 0.00015347955838789821, 0.00015491830690655004, 0.0001490266999297572, 0.00015756992321767872, 0.0001361560209783879, 0.000149540616365884, 0.00016354772748036254, 0.0001741185566893677, 0.00016407623643410432, 0.00016897484390630523, 0.00017197814856069737, 0.00017222007808122825, 0.0001700211492761696, 0.00016920394315379417, 0.00017847390369099433, 0.00018383381482729732, 0.00020113134366581424, 0.0001997196539722506, 0.00020346345852946575, 0.0001997287165244714, 0.00019189364167459063, 0.00020133914934772172, 0.0001998682299033814, 0.000183553656425706, 0.00019361034150813336, 0.00019339875675228424, 0.00019371275882254133, 0.00019378504264135348, 0.00019504117878097732, 0.000189359137912243, 0.00018762652073941368, 0.00019142555725560687, 0.00019628563109915257, 0.00021122480368058073, 0.00021431932088511208, 0.0002062781882989723, 0.00020075163277854553, 0.00019684085906198127, 0.0002004887961412656, 0.0002087742224453175, 0.00021005265827450393, 0.0002030834894787763, 0.00020174885144531957, 0.00019862228974088802, 0.0001979947256430071, 0.00019800805424876982, 0.00020231295910212748, 0.0002092422039725941, 0.00021760293005297147, 0.00021631654639191856, 0.00021672090422506456, 0.00020310833051665058, 0.00019594889751514078, 0.000195637251924868, 0.000203537882204747, 0.00020198128665096943, 0.0001962920245451661, 0.0001748687098214465, 0.00017504697408388722, 0.00018035581093005324, 0.00018210525114778316, 0.00018735711478104605, 0.00018988908918640663, 0.0001965369873012844, 0.000193385758940362, 0.00019164501093802493, 0.00019036109100138815, 0.00019338916110959772, 0.00018200530563585384, 0.00018000154869823705, 0.00017017161850917372, 0.00018212640178876983, 0.00018645519356636422, 0.00018333657500665712, 0.00018015030151120285, 0.00018712686464231025, 0.00018013072960189862, 0.00017657505021501172, 0.00017561663149694384, 0.00018325598195124978, 0.00019425815963692246, 0.00019907511294079027, 0.00019712220659224251, 0.00019649535531245045, 0.00020009880176327996, 0.00019907564885266146, 0.00021104827960721266, 0.00019787225022885595, 0.00018238362738740168, 0.00018851417615073157, 0.00018307576026737856, 0.00020759216147392997, 0.00018728537555677964, 0.00021774018465484408, 0.00019641545174635318, 0.0001778305914229307, 0.00018801501453983305, 0.00018913974450798535, 0.0001950411082124907, 0.0001856808822098505, 0.00018782624787303575, 0.00018213408091623335, 0.00019117103158014317, 0.00020761812308094446, 0.00020829762765573303, 0.00021108807478870082, 0.00020460659583346452, 0.00019357644827441576, 0.00019813212600600606, 0.00019094762329513608, 0.0001937089100702288, 0.00019134546493353846, 0.00020515855589953527, 0.00020381706525268698, 0.0002147361281459047, 0.00020719634301952767, 0.00020911224115580362, 0.00021295326779270809, 0.00021047121915523592, 0.0002106392318486037, 0.00021415874438163583, 0.00021510838639968765, 0.00021421762955506287, 0.0002112039039155931, 0.00020345945257784626, 0.0001964822067923882, 0.00018760341173406676, 0.00018035644043501553, 0.00018363015493157544, 0.00018527558798530098, 0.00018808839086532957, 0.00018451097890335855, 0.0001839960421991189, 0.00018512720167886034, 0.00017737486075127052, 0.00016852931842404185, 0.00016510983384168077, 0.00016542793547986184, 0.00016247650694476212, 0.00016724921308471075, 0.00016746275095372596, 0.0001659780615455766, 0.0001525253573497773, 0.00014726284785619928, 0.00015255474574338136, 0.00015019673232537578, 0.00013288069684478057, 0.00012713068372613768, 0.00014313375196398968, 0.00015889442649612092, 0.00016187457472486078, 0.00015515842918549082, 0.00017258138503091968, 0.00019119495066162708, 0.00017057644615587033, 0.0001921270170055718, 0.00018903450609441887, 0.0001940081901174213, 0.00018448504285363798, 0.0001874116070325329, 0.00018297907013825412, 0.0001924641480249717, 0.00017963283271431592, 0.00017461696035791634, 0.00017729787000518663, 0.00018275571788331138, 0.00018588916065070417, 0.00018553484161111975, 0.0001864085756771528, 0.0001832748249485792, 0.00016744933120434513, 0.00017031983659246988, 0.000173410959679966, 0.00017783726532245677, 0.00019231750211280637, 0.0001833001775514988, 0.00017566377005012566, 0.00019518359770651637, 0.00020929716976580715, 0.00020508358959436733, 0.00022619735120698483, 0.00021770457139337032, 0.00021061451839215817, 0.00020105634879380766, 0.00017605143476317182, 0.00015898626499543858, 0.00015298847703511725, 4.452551282711054e-05, 7.502116809366538e-05, 4.360253285471375e-05, 3.94871482959463e-05, 6.615650487808135e-05, 3.3304774550679344e-05, 1.2247125304604883e-05, 4.6762722345975824e-05, 2.6378010723247974e-05, 5.50338961406198e-05, 6.0598236100200735e-05, 6.0374727870632556e-05, 9.264361708457232e-05, 0.00010284637495768321, 0.00011832141005807323, 0.00010643724705916597, 0.00010919371205088583, 0.00012378959179013235, 0.00012089679667426373, 0.00012034815200967513, 0.00012849415825167912, 0.00012958905218497557, 0.00012167689870801598, 0.00012600518018510343, 0.00013586149666482491, 0.00013358409466549995, 0.00014358467058477116, 0.0001474393626177799, 0.00016681595488284912, 0.00014110083132630802, 0.0001639410593106484, 0.00017695525458094033, 0.00016483007548334378, 0.00015091866679525046, 0.00013756037149731027, 0.000146614583976993, 0.00016057783067688767, 0.00016699618319234233, 0.00017365214220058434, 0.0001630785795211995, 0.00017284199696326752, 0.00014944664294791642, 0.00016250609238437953, 0.00015753060953674027, 0.0001617956723332489, 0.00015791375847747926, 0.00015195093310965585, 0.00014952568503411295, 0.00016262392701635566, 0.00017126654016525117, 0.00017239409303872508, 0.00018391338271567064, 0.00016893182190206907, 0.00015768193397553828, 0.00015487712822294812, 0.00015167991170691227, 0.00014128289633565382, 0.00013433972997081158, 0.00014945109967555206, 0.00014649149262356483, 0.00013341894892390996, 0.00013386016142611723, 0.00011972652740752827, 0.00012797759833961956, 0.00011516209059345004, 0.0001261085047072066, 0.00012795272006884228, 0.00012258527703672497, 0.00013212330288181977, 0.00013358298850066078, 0.00013656901897255385, 0.00013142206028796574, 0.00013630874130417833, 0.0001278390262643498, 0.00011931072170217577, 0.0001131017117686401, 0.00011445297250654221, 9.695933403868872e-05, 0.00010920737330858993, 0.00013101471381377067, 0.0001326950810634488,
0.00013589604894359542, 0.00011598500110582002, 0.00010643561089737738, 0.0001054445407202205, 0.00010419240421486337, 0.00012324304174771137, 0.0001563119614972334, 0.00014001173687037914, 0.00013600755255557817, 0.00015782361168765823, 0.0002142221642111525, 0.00020346524933908145, 0.00021414473936392034, 0.00019626457789463886, 0.0001927714113252008, 0.00017271033355105737, 0.0001452231991847957, 0.00010839789706974573, 0.00011857750662202451, 0.00012479250063671406, 8.197605410246791e-05, 6.140297351872158e-05, 0.00010968809506205978, 0.00010340216125802164, 0.00010847343415713371, 8.555506920354676e-05, 0.00012572117091138612, 6.37480393682519e-05, 8.361366913188408e-05, 9.436166132907904e-05, 0.00010349612291961984, 0.00011084808945318843, 8.872319277547143e-05, 9.586953673716666e-05, 0.0001071452938855845, 9.215561351779825e-05, 0.000139554870850791, 0.00016997972809730863, 0.00016728993046966233, 0.00017034717502365526, 0.00017733461139013773, 0.00017048540455830068, 0.0001579003738574826, 0.00013676827327531004, 0.00010549343181466225, 7.121616947370028e-05, 7.005338347256359e-05, 9.766520447640625e-05, 0.00010243759208586766, 0.00012839063467834404, 0.00011380671931879573, 5.4307241738610886e-05, -2.8155378539285272e-05, -3.456027504572954e-05, 4.8434432774108444e-05, 5.676014533964042e-05, 8.449584946355963e-05, 0.0001193926232753401, 0.00014383779913959636, 8.847649587551725e-05, 0.00014208288588390074, 0.00012051874139817305, 0.00014378369316575413, 0.00017371673492793183, 0.0001703553738620559, 0.00016558926671423309, 2.6981937587032448e-05, 0.00016484144876740113, 0.00013476387987828542, 0.00013427831021542278, 0.00017795358536528653, 0.000275096922350242, 0.00026048805484886147, 0.0002571686634685996, 0.00035920055208580644, 0.00022952701505732782, 0.00017538046999857583, 0.00011313642349262803, 0.00010138910952050833, 0.00015158895461375138, 0.0001537626301831541, 0.00014351861947058117, 0.00016966937909103973, 0.0002034657647242663, 0.00022205914394226036, 0.0002300439620310806, 0.0001992816387956344, 0.00020929675624345423, 0.00024269044889398928, 0.00028368480797238917, 0.0002828139013845961, 0.0003090106560278672, 0.00023188309169735013, 0.0001110584161361329, 0.00010719701751205346, 0.0001400957298589614, 0.0001123013825163826, 6.079068944991029e-05, 8.01061113888422e-05, 3.360815833337786e-05, 0.00010066694289006198, 4.058033217390148e-05, 0.00010050494518790961, 6.515380760021399e-05, -1.437533559827234e-05, 1.5473630244945163e-05, 3.75772007077389e-05, 6.358798547088594e-05, 5.203697003878375e-05, 0.00011541868601121891, 0.00010027658957345866, 7.313334884958569e-05, 7.349121910686876e-05, 1.4019588118981133e-05, -8.178609082412622e-05, -3.5825751636034205e-05, -6.502857369147665e-05, 4.955046224161667e-05, 4.70576509251999e-05, 6.181278773198966e-05, 2.7133731748027192e-05, 2.0631897976649117e-05, 5.712317755361253e-05, 6.004389705640634e-05, 9.122014968697855e-05, 7.123958245447194e-05, 7.185339597418975e-05, 7.06296835245793e-05, 8.87799145749957e-05, 9.012411903472803e-05, 0.00011870065608623684, 9.560499798756797e-05, 9.192205386313442e-05, 7.275800124128721e-05, 8.748186573984048e-05, 7.439046527869318e-05, 9.075689328731514e-05, 7.018434316498789e-05, 7.885632911950698e-05, 0.00011684181653625838, 0.0001345860609134265, 0.00013085371856592755, 9.930114010579204e-05, 0.0001160129004634571, 9.172097074525285e-05, 3.920759361021134e-05, 6.66324746669458e-05, 6.842243059563446e-05, 9.107641519039699e-05, 8.299127594422712e-05, 6.470087410994805e-05, 5.845251773024582e-05, 4.06144276114588e-05, 0.0001077360050193444, 0.00010716717200208122, 3.9738873337004404e-05, 2.872561201974202e-05, 7.289803157493328e-05, 7.995389689073877e-05, 6.627791181226327e-05, 1.282034714031839e-05, 7.950381960656814e-05, 6.86596915633483e-05, 5.142614781691642e-05, -5.654920989298291e-06, -3.9190733055978626e-05, 3.4770189543403014e-05, -8.478852046986056e-05, -0.00011327886324708922, -8.145218656181385e-05, -0.00018573640338608523, -6.889438359992345e-05, -0.00014714583544064215, -0.00019647780559084276, -0.00015058890238221369, -0.0002043251605059393, -0.00010522391448859251, -0.00010175033627055825, -0.00012894199329904475, -0.0001647286981609865, -0.00015685185989841808, -0.0001873395929530472, -0.0001661102945885891, -0.00010700496865359238, -0.00013083878418691176, -3.2402160486079835e-05, 6.426484086534165e-05, 4.214457715700016e-05, 6.114795133069948e-05, 2.365095410619263e-05, 9.229260263113064e-06, 1.4289102487553752e-05, 4.7514174812356735e-05, 4.6749588009951794e-05, 2.7043041631760768e-05, 5.8056386115459166e-05, 5.799169080167438e-05, 2.4641098293039066e-05, 5.771624289000655e-05, 5.2617777835521736e-05, 6.720304795738965e-05, 5.923516988342173e-05, 7.067025825571292e-05, 0.00010151676254250884, 0.00010384122044218656, 0.0001228168674946688, 0.00014039523054181586, 0.0001535428539645816, 0.00014312676865445035, 0.00016055433986450265, 0.0001813727925563431, 0.00016583431207605663, 0.0001606663943724123, 0.0001413690110981447, 0.00012601145001621655, 0.00012861346779396022, 0.00015668205135967782, 0.0001524334163736394, 0.00017028661119667895, 0.00017182085415646747, 0.00017581604789007285, 0.00017534723501387738, 0.00017024605211857368, 0.00017465053249535826, 0.00015539343385249105, 0.00012725653030144218, 0.00010490362349196918, 0.00010684752370714232, 0.00011984457049413879, 0.00010557602844968593, 8.768072138876411e-05, 7.562928260311906e-05, 4.850049407612766e-05, 2.5910841317475e-05, 3.3418654404856e-05, 1.139186716105537e-06, 1.13932612582166e-05, 3.860725792693449e-05, 4.909684207685559e-05, 7.238676340167253e-05, 9.301202671269608e-05, 8.509864374356525e-05, 0.00010965126023464507, 0.00010247068313366852, 0.00011568922352248635, 0.00012141761714680922, 0.0001170436671192135, 0.00010863492505263004, 0.00015024723593633397, 0.00015944458846657212, 0.00014166470293712144, 0.00015267352196815935, 0.00012284647914817274, 9.774553053773133e-05, 9.09483471464584e-05, 6.539972338568847e-05, 5.7188090577943e-05, 7.826448263297091e-05, 9.316973246181379e-05, 0.00011355376061197592, 0.0001473772152169712, 0.00014697680318857744, 0.0001425794949291194, 0.00013502874914334283, 0.0001413234449160827, 0.00015197838622905738, 0.00014614087535522955, 0.00015943002322809388, 0.00014098730642108447, 0.0001495953221294549, 0.00015729885880650722, 0.00015052154371979022, 0.0001557505415283306, 0.00015899833202865195, 0.0001648392276549003, 0.00016876271761609213, 0.00017515415472447302, 0.00017444937421805267, 0.0001832281410063005, 0.00018482456675814488, 0.00023101956034116093, 0.00022200619868002335, 0.00023110914235698542, 0.00019694958115630431, 0.0002056031544844028, 0.00019900525002766235, 0.00020446679854763648, 0.00021126614900370062, 0.0002192017571815949, 0.0002165307990441384, 0.00021242299173844666, 0.0002075153600762285, 0.00021346506498828922, 0.00021677320779258337, 0.0002187842049977255, 0.0002361071312639455, 0.0002385068067126908, 0.0002331324154988869, 0.0002282448912308896, 0.00022473267361430098, 0.0001970269976078824, 0.00017258843295662923, 0.0001629653462343094, 0.00015683706849724653, 0.00016897517572134297, 0.0001610530662190199, 0.00015546657583376976, 0.0001370850652404719, 0.00012616251057370165, 0.0001242770264920003, 0.00012032576480309383, 0.00011027530895079016, 0.0001440586020348268, 0.00015325754945891566, 0.00016252861734222806, 0.0001628057559955524, 0.00016198455282875806, 0.0001492937303179604, 0.00013169978738800114, 0.00012474813617717017, 0.00012399114201878036, 0.00013709209030997126, 0.00015732756994335216, 0.00015420480094271088, 0.00014846310365864736, 0.0001584453963793966, 0.00014583326584826438, 0.00011849567010491311, 0.0001267855076197308]

y_pred_stdev = [0.00018458167551722998, 0.00018890738788643143, 0.0002022780849114624, 0.0001987739290013501, 0.0001973634828239073, 0.00020086141158546044, 0.00021262295992729603, 0.00023003471720618672, 0.00022117882911492392, 0.0002324367083594736, 0.00024219066983613134, 0.00020830966397311984, 0.00019776456262869405, 0.0001988286143369254, 0.0002025458741145253, 0.00019754590624319348, 0.00018889225395870454, 0.00018577915879274315, 0.00017668052093233367, 0.00020068580263573517, 0.00021292789592747212, 0.0002212851502772555, 0.0001997191055552727, 0.0002106273891258983, 0.00021418424199731953, 0.00022597844351695997, 0.00022909396722760322, 0.00025361004533781985, 0.0002722019781570022, 0.0002604836399805839, 0.00023521099692458403, 0.00022703449265863024, 0.0002310392016331914, 0.00021898112002924312, 0.0001864313460290495, 0.00019628887089897438, 0.00019105556680711332, 0.0002155494050827061, 0.00023720874109724966, 0.0002198113230309069, 0.00021667456602049047, 0.0002230323296346166, 0.00020776859262964804, 0.00020808275248025828, 0.00023415007458811333, 0.00022979117228935566, 0.00022476961041816126, 0.00022666075126591894, 0.00020763023185219867, 0.0002066475931576705, 0.00021194539280136905, 0.00020547107550265763, 0.000197521473041693, 0.00019345743727192908, 0.0001766002746012688, 0.000181109935407576, 0.00017637815112459386, 0.00017520210527313584, 0.00016336658831699708, 0.0001617823211656071, 0.00015801944258117046, 0.00021430984926501425, 0.00019606892581800446, 0.00018457984033051344, 0.00018607213534815184, 0.00018913499524232427, 0.0001802692502576709, 0.0001726578151329038, 0.0001661632415677515, 0.0001563870752894961, 0.0001803724801001211, 0.000193079491955391, 0.00016150067504262444, 0.00019338618404365508, 0.00020888202720253989, 0.0002015964963586511, 0.00019094573983987896, 0.00019344340288248354, 0.00016418136827182263, 0.00017699553150491392, 0.00021276181970327648, 0.0002532404475475577, 0.000266622904053473,
0.00027529753292574447, 0.00026796495032674767, 0.0002588407167404722, 0.0002618166174872808, 0.0002581545840034508, 0.00029173217981398234, 0.0003043130567535811, 0.00029668332135647664, 0.0003136197022714271, 0.0003266668625849017, 0.0002940454410651585, 0.00030650823999009435, 0.0003082060895852552, 0.00030170028418148717, 0.0003168250224446395, 0.00029884435780877196, 0.00027577532482677764, 0.0002999134235266005, 0.00026097583182086744, 0.0002455897791025628, 0.00024010914792761204, 0.0002437495581435967, 0.00022722258277174285, 0.000222999284810043, 0.00020317115538721897, 0.00020150898822333073, 0.0002215538107114944, 0.00021803828728350454, 0.0002185656297595537, 0.00023252615049483292, 0.0002853832727687235, 0.00025323721699050045, 0.00024264339101794216, 0.0002443895325907015, 0.00022387018180192983, 0.00022960867382466676, 0.00020648349422690258, 0.00020750798790544216, 0.00021010276914440533, 0.00020979124178565915, 0.00019696994454740762, 0.00020211498678245938, 0.00021402103699817333, 0.00021523982199933017, 0.00022638121304620535, 0.0002311452025920284, 0.0002207312370043657, 0.00020595629339408467, 0.0002256550276060265, 0.00023612389075879165, 0.00022586323882403097, 0.00019947139674935445, 0.00020826411330707365, 0.00022286113523013236, 0.00023534597450849848, 0.00026725394458716555, 0.00023139771745201291, 0.0002393745696503032, 0.00024426927052923294, 0.00024446130047725827, 0.00024091830995968456, 0.00022947899183282396, 0.00023605972729402882, 0.0002463206028049477, 0.0002401109277386246, 0.0002568615024063029, 0.0002686943802887808, 0.00025405986979906665, 0.0002704796079468097, 0.00027393276281437564, 0.00022503815961893363, 0.0001895491703327147, 0.0001937311228851049, 0.00019913331737195607, 0.00019349726570405562, 0.000175141234554861, 0.00016081778995973494, 0.00015816609029877484, 0.00015808745811074856, 0.00017134957049958887, 0.00017496016406518097, 0.00017175024634632946, 0.0001711806644081396, 0.0001725448167915032, 0.00018261738804019299, 0.00017177857259776495, 0.0001665679092469605, 0.0001673666479173395, 0.0001706571829944023, 0.0001537043916080121, 0.00015296631337103364, 0.0001577420139900251, 0.0001624098337728244, 0.00018074470465762965, 0.00017510734131049297, 0.00016035618511960365, 0.0002345085674187664, 0.0002151212547482431, 0.0002110347350083993, 0.0002011355096579345, 0.00019454146413319914, 0.00018800942158297274, 0.00018500379490509703, 0.0002152004054191388, 0.000199214741533422, 0.0001720753872772996, 0.00018198317456710208, 0.00020004083999796579, 0.00018238737227373048, 0.00018116624121627725, 0.0001990186888096973, 0.00020209589511224275, 0.00019855840876935473, 0.00019680319783093748, 0.0001905579469405343, 0.00019603461947677775, 0.00019846865859880948, 0.00019164326979436078, 0.0001904867037674332, 0.00018953883351419007, 0.00018432331729999852, 0.00019488695075897761, 0.0001781134844637667, 0.0001770374330672447, 0.000185915250150947, 0.00018215318004611485, 0.0001751135737007438, 0.00016460537174363619, 0.00018489273264471145, 0.00020864891562321917, 0.0001931739795245069, 0.00017318832861053866, 0.00019026181857734962, 0.0001671928515996105, 0.0001688715900189319, 0.00019776355764559883, 0.00023361659743948658, 0.00022598350703034034, 0.0002117982985514387, 0.0001917459751782081, 0.00019167514915598583, 0.00021893692587445757, 0.00019102299442345707, 0.00018213968108783316, 0.0001923021808718342, 0.00017090230841273964, 0.00015082936330746783, 0.00014103545444710228, 0.000148291082723656, 0.00018421676974171312, 0.00017286305504690238, 0.000187872600911307, 0.00017677712552282342, 0.00018265522972333505, 0.0001849984435977709, 0.00018454329931431887, 0.0001773502499883082, 0.00016029266954453288, 0.00017715691531768483, 0.00015800068776525232, 0.00015469104113018345, 0.00016732865071649702, 0.000190332827817872, 0.00020305367832593884, 0.00019441912481516757, 0.00017773874236378114, 0.00017688862337960652, 0.00018786994494067184, 0.00019547028814795856, 0.00019548079321692776, 0.00021686083666744172, 0.00022856599896755401, 0.0002368977127377806, 0.00022930215060294783, 0.00020468305101574907, 0.00020959297434542062, 0.00021045242730136383, 0.000225893654488744, 0.00019420461916150826, 0.00018393316034047885, 0.00016895599431383392, 0.0001794443279463202, 0.00017437716935924579, 0.00017512463696526523, 0.00017236081807818127, 0.0001748599861617468, 0.00017250228325692768, 0.00018666919590551548, 0.00017723748855624736, 0.00016957652637970922, 0.00016127682832252666, 0.0001499275152250734, 0.00014912664883621956, 0.0001573512940637522, 0.00015693481857081648, 0.00016678545481517665, 0.00016448940374063674, 0.00015780361317511852, 0.00015085822863145076, 0.00015960745574810294, 0.00016855607603614495, 0.00015971867600649318, 0.00015866110477829644, 0.000173394053317611, 0.00018659477869403, 0.00020764153002345503, 0.0001964728433559514, 0.00019786061821512447, 0.00018090446705922836, 0.00017232078925550622, 0.00016748733978959465, 0.00017039413023009348, 0.00019197121555020673, 0.0002126428997988604, 0.0002093472776863201, 0.00020878942376156284, 0.00020922579419294812, 0.00020106290745313272, 0.00021930898373960498, 0.00021431069294217602, 0.00021444937540838604, 0.0002235910586788506, 0.00020940898294485814, 0.0001988183693490339, 0.0001908339546311419, 0.0001995988722122176, 0.00019894832086762924, 0.00021659987155270803, 0.0002091867026696559, 0.00022251428485670947, 0.00021146731234272914, 0.0002389912225175596, 0.00022166245877910446, 0.0002282034041341392, 0.00020497245367421307, 0.00021183997907235798, 0.00020607909360272807, 0.00019959737616849092, 0.0002056490671769834, 0.00019594283673895452, 0.00018942712929149034, 0.00018121668011875826, 0.00016965171375649154, 0.00015396027833347665, 0.00016787699063094418, 0.00016317318218120756, 0.00017012759848039516, 0.00017938466312335407, 0.0001669116620959032, 0.0001673664829433155, 0.00019242407057304322, 0.0002132304754167795, 0.00022621392856287913, 0.00021265505100987348, 0.00020927336528446172, 0.0001822394834322786, 0.00018186268186739892, 0.0001904717042394661, 0.00018301633637302913, 0.00018600262089776403, 0.00015366562130603642, 0.00014578743471620783, 0.00015927900834256182, 0.0001678559271350845, 0.0001847304147729818, 0.00019499837223626296, 0.00017069537707926823, 0.00017348779204936671, 0.0001737685850276621, 0.0001764710878450825, 0.00017553316507932742, 0.0001732594876658054, 0.00018581093401845395, 0.00017424597121036355, 0.00016049348724923502, 0.00015422349918408498, 0.00015495166153914512, 0.00015203970645331102, 0.00016962500987389008, 0.00017229423247554977, 0.00016413386315800957, 0.0001546984911624385, 0.00015294951811255206, 0.00015722102104372417, 0.00018475778188656428, 0.00018337840302424968, 0.0001745521652681775, 0.0001682481612704872, 0.0001643310844898044, 0.00015434245272278924, 0.00014700979144459592, 0.00015047052019779994, 0.0001615063751843641, 0.00016192440349064197, 0.00016022082979806095, 0.0001803106706464337, 0.00018766650800006767, 0.00020110193977790559, 0.0001824557188632822, 0.000174130647438242, 0.00017716843795249692, 0.00017733852406265083, 0.00016726397857416754, 0.0001861550460015886, 0.00018401229942363134, 0.0002015105258718056, 0.00018941823140733165, 0.00018006780283297413, 0.00018671510206565975, 0.00018959596331979893, 0.00018488447648347837, 0.00019865879304032752, 0.00020902862636005051, 0.00021183184524195558, 0.00023998200474038435, 0.00027910427562004666, 0.00027282218398661797, 0.0002842127969578807, 0.00025320890107765687, 0.0002875281275445378, 0.00029983881674144197, 0.0003191975223740632, 0.00025863818795905647, 0.00022516577756900814, 0.0002240792852364332, 0.00022070417481488051, 0.00023702889794053141, 0.00020454875001451038, 0.0002096906192882578, 0.00019127594574583516, 0.00017492108302739177, 0.00017088376088113857, 0.0001691953772241941, 0.0001775071727980869, 0.0001819528335935144, 0.00017825034575918544, 0.00018320323684621208, 0.0001829303491793465, 0.00018200411443224535, 0.0001909926922350774, 0.00020547565106431167, 0.00019401074169743038, 0.00018239978198694604, 0.00018439090382030206, 0.00017709038913071178, 0.00017158195390536122, 0.000186,
0.00017728585954040425, 0.0001880350649034081, 0.00019964340333989417, 0.00020242098413548584, 0.00020126181214351024, 0.00019190081623089014, 0.00019371192088526087, 0.00019052148287106188, 0.00018591892755618814, 0.00019787743302662037, 0.00018305108322430242, 0.00020876293622234686, 0.0002087361464714919, 0.00021403408388041544, 0.00023372514856716882, 0.00024155225747037122, 0.00024455236772629986, 0.0002666435851950836, 0.0002894003531359082, 0.00029634355214378026, 0.0002877123360292223, 0.0002825951964347532, 0.0003105279880311351, 0.0003183735786655305, 0.0003179271270061335, 0.0003544820490796773, 0.0003818433270494843, 0.00032890017479587577, 0.000295223647731608, 0.0002698534406882124, 0.00025382240821622456, 0.00025781356368030997, 0.0002531405787826821, 0.00024926813322696735, 0.00026212826146266443, 0.00023901508918473607, 0.00022637649573329738, 0.00022060151654958548, 0.0002352500645472109, 0.00022738631568825307, 0.00023318963965319512, 0.00021752680201027696, 0.00022833284384723475, 0.00022243488745973342, 0.00023219382921825204, 0.00024318046227606233, 0.0002402634865837447, 0.00023325512362480788, 0.00022687111752123587, 0.00023076593279817121, 0.0002682174628041785, 0.00027796402845532394, 0.00026454231930769963, 0.00025815240891457656, 0.00022675579978661392, 0.0002068986937956546, 0.0002275186506278244, 0.0002436940748377264, 0.0002356726042391035, 0.0002553402792199711, 0.0002496872307338542, 0.00022593511256471967, 0.00023448978358402815, 0.00030464952263860534, 0.0002924095276326015, 0.00032440630003383703, 0.0003165717577811269, 0.00048377420622573405, 0.00043106342972255195, 0.00046444621239353546, 0.0004844184040713784, 0.0004226244919726411, 0.0005030770459360202, 0.000527804603538842, 0.00044624642786489425, 0.00047220351473718243, 0.0004310514432726686, 0.00040156227957883247, 0.0003983883481058758, 0.0003396197609547534, 0.00032494658367238267, 0.0003039046524861947, 0.0003465512579916293, 0.0003457092376049822, 0.0003219285030079089, 0.00032043905806902723, 0.0003129771848763649, 0.000310654488639163, 0.0003174374389381348, 0.0003195840213019871, 0.0003142578366803018, 0.0002954482708140653, 0.0003038284004450098, 0.0002990533141721606, 0.00028615093549774924, 0.00026678825022250977, 0.0003004481872023495, 0.0002942441243236986, 0.00026277140194535403, 0.000294302955469081, 0.0003295102857651623, 0.0003268131718637393, 0.00030016142241740234, 0.0002762161841332397, 0.00026691600703915953, 0.0002574837130862533, 0.0002712896287377325, 0.000259255013699852, 0.00028158070014935426, 0.0002548590803706922, 0.00025052192749972874, 0.0002603785433559576, 0.00026717044768083815, 0.00029138029682611126, 0.0002932304554947575, 0.0002545339391001092, 0.0002603014047639742, 0.00027359913123948816, 0.00026592356827981995, 0.0002838554462274471, 0.00028841966494699123, 0.0002902423684041866, 0.00029872339715691264, 0.00032526499830123716, 0.0003211432001052754, 0.0002914585571432656, 0.0002932819229673124, 0.000303852388881159, 0.000297857143894467, 0.00030651120114926086, 0.00028932631740695474, 0.0003181391036994807, 0.00030151865130574845, 0.00029479522076748484, 0.00032347948835435825, 0.000295943139552496, 0.0002997056806947731, 0.0002902263772555465, 0.00030528267107857957, 0.00029338228042008127, 0.0003089693432072871, 0.0003423313613700148, 0.00034246354544307535, 0.0003261854504257007, 0.0003590137103525561, 0.0003628645915059937, 0.0003111771926579466, 0.00033038294645834377, 0.00034051250544005717, 0.0003497332660830552, 0.00037356836527232434, 0.00039993741212240364, 0.00038796269671970325, 0.0003853340254146136, 0.00031498823938114646, 0.0003513704685971686, 0.000368076190909623, 0.0003411413197039817, 0.0002920715629702793, 0.00027594242150354625, 0.0003061699039197664, 0.00033213097571717094, 0.00040623977740596195, 0.000427338734304278, 0.00037901327274251676, 0.00044503781959238795, 0.0004191396107457787, 0.0003643555623748136, 0.000532151879944723, 0.0006049620131378068, 0.0004778077869715252, 0.00046542740162688857, 0.00041095127435786407, 0.0004977129043675639, 0.00039812118146874973, 0.0005031324923521298, 0.0005340959258904378, 0.0005634913093378029, 0.0005172004001440916, 0.0004754847326437902, 0.0005256738966959773, 0.0004850695224542269, 0.0004020470713749214, 0.00042837251926665425, 0.00035953616996659037, 0.00027949897817877966, 0.0003001256011854342, 0.00029746835101234533, 0.0002688922987480696, 0.00026776488490571623, 0.00032264631230765825, 0.00034476043980878927, 0.00040216151189289407, 0.0004636985728780941, 0.0005280436587558374, 0.0005077215335671551, 0.0004330751471588091, 0.00040106472772803866, 0.00039630599177163813, 0.0005147277293145345, 0.000716003247095056, 0.0007114293266105423, 0.0005149788982913952, 0.000489254514299043, 0.00047206424856534025, 0.00042941938663470705, 0.0004235494107084277, 0.0005019841135385291, 0.000413775504360404, 0.000549772428245515, 0.0006369256603117576, 0.0006034297007073804, 0.0006080840309356635, 0.0006138797973790015, 0.0008254295457003775, 0.0004790565546847659, 0.0006645371631360246, 0.0006081786406072576, 0.0005314773694588491, 0.0005384348024789411, 0.0005546707231125767, 0.0005847968066879966, 0.0005476346381433239, 0.0005191731832239067, 0.0005517123974968246, 0.0005690377337180016, 0.0005758010407581669, 0.0005068449085472924, 0.00044970552332079637, 0.0004642812976611982, 0.0004612009477951329, 0.00046548734550132156, 0.00047673230032346955, 0.0005062860864071228, 0.0005327567605784414, 0.0005578352810767766, 0.0005629370262327603, 0.0006154159762062964, 0.0006662553861863378, 0.0006554068651071436, 0.0005578181293021746, 0.0005539281696999939, 0.0005550153735590454, 0.0005792147937604987, 0.000577189188277543, 0.0006270843738270525, 0.0005578442197750555, 0.0005872063136841711, 0.0005019450176342839, 0.0005648843118741244, 0.0004880383081668423, 0.0005615142501421953, 0.0006621769246197009, 0.0006054075058374717, 0.0006117727976232347, 0.0005657917001479345, 0.0005504118002556789, 0.0004339646795209038, 0.00044214528903650357, 0.0004501239377707743, 0.00044620467673996437, 0.0005385456600128702, 0.0006979956726602117, 0.0006449930804397751, 0.0006912672445250196, 0.0005365014227107693, 0.0005214294058434873, 0.0005061597321015732, 0.0005760644255785332, 0.0005907652492526725, 0.000578486004910081, 0.0005312029681665436, 0.0005319197474255706, 0.0005319077545779865, 0.0005233067363514489, 0.0004996161229663118, 0.0004937993919604189, 0.0005241709105693096, 0.0005107745928870454, 0.000546689965301005, 0.0005417387172906291, 0.0005133227213921447, 0.00048332008425917475, 0.000504431055730453, 0.00047412475695904024, 0.0005276632110999828, 0.0005247678523523826, 0.0004752005179569231, 0.0005075547491529279, 0.0005113132292891561, 0.0005187275087843796, 0.0005254865895746865, 0.0005406575531547007, 0.0006188639581611835, 0.0006715412165287906, 0.0007005271335652275, 0.0006816995296466011, 0.0006725500441482269, 0.0006190297718859833, 0.0006085852211343385, 0.0006012848200238276, 0.0005061333162482511, 0.0005017002540014282, 0.0006512117645301547, 0.0006298335884707983, 0.0005832821940099737, 0.0005658002730532861, 0.000578446789626612, 0.0006441193491196913, 0.0005286675262400638, 0.0005101080616468133, 0.0005753184253965165, 0.0006284747134453107, 0.0006607645583616055, 0.0005683329996620653, 0.0007310073961827546, 0.0008047251127057351, 0.0007791036238840656, 0.0009292721819196123, 0.0007321753874661645, 0.0008349314464352142, 0.0009157826482370391, 0.0008564277776172079, 0.0009289350987219944, 0.0007939054229815333, 0.0007808223492035784, 0.000812240634411408, 0.0008985123706664076, 0.0008957936254240242, 0.0009365661386747084, 0.0009206874909535335, 0.0008599400565965962, 0.0009072307842482794, 0.0007331361912062196, 0.0005719000864605406, 0.0006030338055086244, 0.0005326999389786616, 0.0005928148196725525, 0.0005947468732925106, 0.0005788435930863205, 0.0005087734501524485, 0.000487710074697005, 0.0005208894674270109, 0.00047791945833207123, 0.0004890620903728604, 0.0005387521430393803, 0.0004846128169875248, 0.0005061201051222717, 0.00046031245092601207, 0.0004930259853742623, 0.00048201185882878317, 0.0004162228809867,
0.00042996509270532647, 0.0003961261423679328, 0.0003536913791419527, 0.0003559795266644255, 0.0003734360848450912, 0.0003433652411496039, 0.00031945482894879485, 0.0003180265985978097, 0.00031524986102691755, 0.00034509905714489274, 0.00035369861312797683, 0.00036399342463234796, 0.0003305153951106405, 0.0003347905041208715, 0.0003051205257307178, 0.00028258495858183127, 0.00026856905848440273, 0.00026095200160261133, 0.0002617200572249916, 0.0002547155268176962, 0.0003058931274154455, 0.0003990604976549136, 0.00045009749648341915, 0.0004377780644369958, 0.0004278832560293402, 0.0004258520718958878, 0.0004621680089280266, 0.000496685915496594, 0.0005230527117605603, 0.0005654471930701586, 0.0005611513602730264, 0.0005908143384537831, 0.0006022548465474767, 0.0005482918301442495, 0.0005263147554758598, 0.0004835827216614423, 0.00045572892179515434, 0.00044929575988670505, 0.0003995515000982435, 0.00043518233153581973, 0.00041954112219368475, 0.0003996715050071206, 0.00041832858311854654, 0.00041481032299479963, 0.0002918160422406231, 0.00028572577200559765, 0.00031180037718626404, 0.00027546816991423417, 0.00032312106423608395, 0.00040001307146675987, 0.00039677612483229104, 0.0004407012220163968, 0.00045432820210564943, 0.0004269149508176737, 0.00038746180633085985, 0.0003361754707392019, 0.00030551168960055717, 0.0002992543495204972, 0.0003226018122055636, 0.000325762572021532, 0.00033437651952154666, 0.00033512244398024773, 0.0003605892821519105, 0.00031109114607964, 0.0003237933118771582, 0.00029975797819270766, 0.00031161290354606746, 0.0003544187780767348, 0.0003494932198738185, 0.00034314507640918757, 0.0003158696065333059, 0.0003087476895524896, 0.0002892252920871486, 0.0002997328553801172, 0.00030254064937548883, 0.00029176955318126056, 0.00023788183293701822, 0.0002376782766481464, 0.0002577358475333786, 0.0002795089405887742, 0.00027996162121191346, 0.00029933435591986704, 0.0002739181549300363, 0.00027751301769878293, 0.00026689383663361155, 0.000253591854468931, 0.00023838840729379303, 0.00022965163453086095, 0.00023935561665944268, 0.00022922828462396304, 0.00021933192646077102, 0.00019852487811291411, 0.000195420257220943, 0.00018757408900793547, 0.0001886158772250436, 0.00018366617084975313, 0.00021715244227251041, 0.00024079835207659931, 0.0002637289376286613, 0.0002660268149959834, 0.0002455507586225066, 0.0002465656111679702, 0.00025049832292230975, 0.0002923348142451626, 0.0003190433948505086, 0.0003257395223904865, 0.0003112685218527191, 0.0003243388809118262, 0.0002519247553776489, 0.0002314650698906504, 0.00021709642914119403, 0.00021086921189047387, 0.00022032173164319603, 0.0002460632722250797, 0.00028359607423786477, 0.0003124097448840771, 0.0003183851353753996, 0.0002997615501422078, 0.00026490689597189105, 0.0002690206010028699, 0.0002681185667522326, 0.0002514110779389419, 0.000285832878857664, 0.0003197868731242892, 0.00029551207826676904]

y_pred_median = [0.00024961672835138076, 0.00024791253435592716, 0.00024887716885616434, 0.0002509222919886691, 0.00025042766433384445, 0.0002534320154306841, 0.0002533328686281563, 0.0002519166512246075, 0.0002499199218180793, 0.00024678488827407257, 0.0002480974467532667, 0.00024754845585616477, 0.00024756346397393557, 0.0002495543847799779, 0.0002504181037255394, 0.00024961672835138076, 0.00025069525477593526, 0.0002501473711634817, 0.00024988516607640695, 0.00024810701315833707, 0.00025016067888995806, 0.0002510948337616911, 0.00025467507215294605, 0.00025421123391097773, 0.0002541870279418136, 0.0002505332050094212, 0.0002501664536036913, 0.0002488237391933092, 0.00025013214295032196, 0.00024990818634874613, 0.0002519053990831416, 0.00025214170036922713, 0.00025084205059797165, 0.0002524064111786279, 0.000252193883970579, 0.0002558538348168799, 0.0002547143776460731, 0.00025214170036922713, 0.0002542635069874878, 0.0002523246017010519, 0.0002524414135130692, 0.00025405202134705975, 0.00025356521480163457, 0.00024869891759191114, 0.00025038592434779914, 0.000252502336263952, 0.0002504920508649483, 0.00025103573204447835, 0.00025168456257776677, 0.0002504339437392344, 0.0002501739866164344, 0.0002503441843617539, 0.0002509729135215771, 0.00025042766433384445, 0.00024816352135133236, 0.0002519513855006104, 0.000251027957278277, 0.0002510138556716019, 0.000249888840382343, 0.00024850677783451523, 0.00024546864234229935, 0.0002482760356104764, 0.0002482760356104764, 0.0002487113823479804, 0.0002501473711634817, 0.00024619101973425773, 0.000247292194964524, 0.00024862587820448156, 0.0002478365022327484, 0.0002468132270145979, 0.0002464394928019435, 0.0002458743803969292, 0.0002442443037413866, 0.0002488624627988404, 0.0002479877635165684, 0.0002492293835966387, 0.000249700163413844, 0.00024905689061690097, 0.0002467593071466041, 0.0002476073343603703, 0.00024836639047566447, 0.0002495238095402859, 0.0002488911101425829, 0.0002497802166148786, 0.0002488624627988404, 0.0002477517395635432, 0.0002477517395635432, 0.00024712274229222086, 0.00024512097925744926, 0.00024399542784812384, 0.00024370069646170467, 0.00024888321122627934, 0.0002567886445983675, 0.0002587709353377208, 0.0002521279275714251, 0.0002529525555035862, 0.00025513678877750446, 0.00025513678877750446, 0.00025513678877750446, 0.00025589207758848465, 0.0002554807515402608, 0.00025207621443027806, 0.00025083863375561697, 0.0002484951998229435, 0.00025095777262573303, 0.0002482760356104764, 0.00025071146160539413, 0.00024747217758618045, 0.0002476073343603703, 0.0002476073343603703, 0.0002526106902695092, 0.00024850708083317275, 0.0002521780123532581, 0.00025222972549440514, 0.00024903874276703184, 0.0002478444694605487, 0.0002510789753176569, 0.0002511810770172032, 0.00025134772520667246, 0.00024728430538225026, 0.0002477118408148879, 0.00025093233930587944, 0.00025264055881276727, 0.00025379940530479176, 0.0002536779280685972, 0.000254408383458889, 0.0002510025333793665, 0.00025115541725594727, 0.00024994993751632777, 0.0002528289816761029, 0.00025048043467163286, 0.0002503790609369817, 0.0002524897515597276, 0.0002510025333793665, 0.0002504033709186863, 0.00024963030960120435, 0.00025084205059797165, 0.00024751959358750085, 0.0002511810770172032, 0.0002506142710168575, 0.0002511707816200962, 0.0002506157724002481, 0.0002569098931341072, 0.00025672245812233437, 0.0002571462122903968, 0.0002537727790847783, 0.00025594126655991144, 0.0002571131515849117, 0.00025690317430999586, 0.00025728292644690916, 0.00025499411572295415, 0.00025447220764530996, 0.0002532944207376632, 0.0002521279275714251, 0.000252024501289131, 0.000252024501289131, 0.0002519166512246075, 0.0002482760356104764, 0.00025511995450361395, 0.00025512127456655143, 0.00025443250676701693, 0.0002519705762568693, 0.0002499923665248999, 0.0002501739866164344, 0.0002455239338520601, 0.00024223315222571094, 0.0002474895773519593, 0.00024626179151877934, 0.00024614713115792897, 0.0002430271273548355, 0.00024350036478776657, 0.00024722734248498914, 0.00024970870491856836, 0.00025033461441893175, 0.0002529466857229105, 0.0002552829007836161, 0.0002546451621914152, 0.00025537390350500154, 0.00025335503206450006, 0.00024134501701238996, 0.00024198349914601952, 0.0002420826465209232, 0.00024092136329781702, 0.0002504033709186863, 0.0002510292980744349, 0.0002503441843617539, 0.0002446759323898437, 0.00024619215234194093, 0.00024055613209264905, 0.0002504181037255394, 0.0002568555135624738, 0.00025125764217526745, 0.000250967436342623, 0.0002504181037255394, 0.0002568704811917673, 0.0002549821509589932, 0.0002503790609369817, 0.0002535471887977723, 0.0002519166512246075, 0.0002507820419355834, 0.00025528221716148607, 0.000256031338833139, 0.00025579151733519064, 0.0002542992611422449, 0.0002554606268421112, 0.0002558105739665791, 0.00026049426726602664, 0.00025852988246605267, 0.0002584369996991371, 0.00026040229427221404, 0.0002569070989002171, 0.0002590739165475758, 0.0002617935290362284, 0.0002504059570179603, 0.00025424017299141913, 0.00025648185551458216, 0.0002504181037255394, 0.00025101461690465185, 0.0002481788200856018, 0.0002504691343818622, 0.00025073103247618474, 0.0002501454506767983, 0.0002503790609369817, 0.0002496104957134294, 0.0002510025333793665, 0.00025303841922581885, 0.00025054864812879685, 0.00025232490705961953, 0.0002541870279418136, 0.0002541870279418136, 0.0002556587584439031, 0.0002506019966502875, 0.0002515282207230402, 0.0002510025333793665, 0.0002504033709186863, 0.0002505297256464901, 0.00025084205059797165, 0.00025042766433384445, 0.0002505297256464901, 0.0002504085431172344, 0.0002504085431172344, 0.00025177039488545047, 0.0002517617397998721, 0.0002574863982861155, 0.00025573301031895154, 0.0002564968231438756, 0.00025754118073922244, 0.0002534149224739614, 0.0002519332294813314, 0.0002549857341270041, 0.0002533177732326662, 0.0002559610639104382, 0.0002523084216585578, 0.00025401775569830264, 0.00025194512381741764, 0.0002511796315344617, 0.0002508229716746797, 0.0002516907728558756, 0.00024963030960120435, 0.00024994993751632777, 0.0002496229609893322, 0.0002496229609893322, 0.0002484889708725226, 0.0002462696248147468, 0.00024312086944161494, 0.00024248459308350633, 0.00024343676708639243, 0.00024248459308350633, 0.0002462696248147468, 0.0002465110337967519, 0.0002436553746991622, 0.0002436553746991622, 0.00024406977832026953, 0.0002449826396371765, 0.00024889301707365003, 0.0002519182594093223, 0.0002510902044020839, 0.00025150090572257256, 0.0002537651388668169, 0.00025516959752557836, 0.00025579151733519064, 0.0002526713818123959, 0.0002473299565577165, 0.0002487113823479804, 0.00025135962065503994, 0.0002524108691903594, 0.000252199088777282, 0.00025080350594794025, 0.0002504085431172344, 0.00025135962065503994, 0.00024993560451943783, 0.00024979012355876603,
0.0002476270980966967, 0.0002477517395635432, 0.00024752926629821224, 0.0002472823312583308, 0.00025042286079415924, 0.00024808076423523024, 0.00024607184609689924, 0.00024680901063628906, 0.00024702757332707514, 0.0002460086562440813, 0.0002449976862632414, 0.0002477517395635432, 0.0002485807039664424, 0.0002474895773519593, 0.0002482446089525127, 0.00024866555109096867, 0.0002473182003719927, 0.00024873650778385473, 0.0002479659930748935, 0.0002501935790416627, 0.00025071146160539413, 0.0002524178531682481, 0.0002521279275714251, 0.00025446165230509204, 0.0002503737776402201, 0.00025420047172869734, 0.0002520161085196306, 0.00025217025161334433, 0.0002530934670487981, 0.000253455145761697, 0.00025336564414532754, 0.0002504033709186863, 0.0002499661288219219, 0.000250074425391196, 0.0002566949206462998, 0.00025651519519373674, 0.0002559610639104382, 0.00025692146865980597, 0.00025728408197122493, 0.0002572092138659571, 0.000258672035771584, 0.00025152545576564577, 0.00025485325308288314, 0.00025574355027115146, 0.00025573301031895154, 0.0002552161630751731, 0.00025460279704634, 0.0002542605835077184, 0.00025426643046725717, 0.00025727440026294306, 0.0002554019804409536, 0.0002562268565885875, 0.00025746459146089095, 0.00025573301031895154, 0.00025586120452930795, 0.0002574744176416489, 0.0002580435648741032, 0.0002550742218861581, 0.00025748957645017385, 0.0002552891856356355, 0.0002533730824963315, 0.0002519053990831416, 0.0002524108691903594, 0.0002533177732326662, 0.00025426643046725717, 0.0002519332294813314, 0.0002553219943837094, 0.00025551927324326884, 0.0002542992733512368, 0.0002525628481917818, 0.00025084205059797165, 0.0002495455744289607, 0.0002504085431172344, 0.0002524108691903594, 0.0002524472965290401, 0.0002479377665658086, 0.00024791812543466864, 0.00024966206588614983, 0.0002496909266264991, 0.00025080350594794025, 0.00024808160456072715, 0.0002524453374278098, 0.0002514261190234939, 0.0002502912648668344, 0.00024869924233175775, 0.0002493406668253074, 0.00025027652377670805, 0.0002518287934562695, 0.0002543556971460725, 0.00025587568099041263, 0.00025557276535605254, 0.00025524086267660854, 0.0002486822874467549, 0.00025042766433384445, 0.00024963030960120435, 0.00024751959358750085, 0.0002530244629058393, 0.0002552563768875616, 0.0002537478488988464, 0.0002545784708710854, 0.00025651161446403717, 0.00025205724231656533, 0.00025824849222030665, 0.00025761154745756066, 0.0002643169059290666, 0.00026386681828610475, 0.00026142592338274437, 0.0002616480580415514, 0.0002591844439475618, 0.00026261329699250115, 0.00026518759533859684, 0.00026837009439702956, 0.000267972632038297, 0.0002579483178044611, 0.00025607115362532207, 0.0002584244918142277, 0.000259747466495836, 0.00025421905690531333, 0.0002501664536036913, 0.0002529823970966785, 0.00025709455350510674, 0.00025837843382260666, 0.00025786884199691833, 0.0002572347898193911, 0.0002572094177454098, 0.0002520534661858335, 0.0002559610639104382, 0.0002559610639104382, 0.0002550172006674473, 0.0002558332504594064, 0.00025812036561741127, 0.00025824849222030665, 0.0002567934038588253, 0.00025667313050358983, 0.0002566604169731791, 0.00025820143787481996, 0.00025592558896143724, 0.0002573910249810497, 0.0002632981819665971, 0.00026230577636450323, 0.0002637464565029825, 0.00026201087292189, 0.00026131141706564034, 0.0002541302945879948, 0.0002540253530812911, 0.00025111785565664995, 0.00025163813593982373, 0.0002486741953425655, 0.00025053146532795566, 0.00025429174642251746, 0.0002550069751537943, 0.0002548641950213251, 0.00025621155353434196, 0.00025743272131134934, 0.0002584244918142277, 0.0002524937302350746, 0.00025482682778775576, 0.0002583801874586588, 0.00026141696258597544, 0.00025786884199691833, 0.0002557908545457822, 0.0002555976310974088, 0.000258014868876944, 0.00026115990335879094, 0.00026226870013777205, 0.00025638028438765455, 0.0002544146944469925, 0.00025421391551558103, 0.0002576243956910517, 0.0002534969763197665, 0.0002501888009250861, 0.0002551580550533318, 0.0002504033709186863, 0.00025489206688475457, 0.0002523002577113899, 0.00025489206688475457, 0.0002487113823479804, 0.00025071146160539413, 0.00025135962065503994, 0.0002497007242211918, 0.0002512738547670099, 0.00025042766433384445, 0.00024963030960120435, 0.0002515328945560598, 0.00025060030839374795, 0.0002521246120208091, 0.00025114770000263687, 0.0002536674711001797, 0.0002554206338134891, 0.0002554472888656532, 0.00025592295064766135, 0.00025789137657907034, 0.00025594200727904976, 0.0002466591533807055, 0.0002504377566083577, 0.0002505484589538989, 0.0002615719475428012, 0.00026215052498796196, 0.00026704185424437547, 0.000265159129866322, 0.00026461435886799065, 0.0002630981122382282, 0.0002589542326583256, 0.00025592295064766135, 0.0002580617125369851, 0.0002552563768875616, 0.0002575394969922015, 0.0002560394890035186, 0.00025374550996730525, 0.0002561999390955922, 0.00025134487975232386, 0.0002496229609893322, 0.0002486197198339569, 0.0002487113823479804, 0.00025033554488968277, 0.00025042766433384445, 0.0002505332050094212, 0.0002525109422928294, 0.00025042766433384445, 0.0002524108691903594, 0.000255849235440745, 0.00025564267517245813, 0.0002560127201995892, 0.0002544876002178146, 0.00025609826390905483, 0.0002564848588529965, 0.0002587085269089309, 0.0002555142861709834, 0.00025567980110998236, 0.00025582798048330645, 0.0002556297022709687, 0.0002597485578121456, 0.0002561504759044637, 0.000255236318511935, 0.00025551927324326884, 0.00025712038289775176, 0.00025645760756429074, 0.00025742115663061926, 0.0002573797852765619, 0.0002579700013055615, 0.0002581695557199483, 0.0002590126729896435, 0.00026041571489907983, 0.00026019390656399063, 0.00025689841946915427, 0.0002568229425406438, 0.00025300553133241957, 0.00025499411572295415, 0.0002536087544287413, 0.0002571462122903968, 0.00025384503473056754, 0.00025447220764530996, 0.0002545665015967085, 0.00025249733308027513, 0.0002539719851334527, 0.00025736692073064226, 0.0002622147484632899, 0.00026413142137376826, 0.0002622874338996912, 0.0002610320182374528, 0.00026347053867707205, 0.0002609613601358802, 0.00026215052498796196, 0.00026122334809286973, 0.00025824849222030665, 0.00025648162056998486, 0.0002557130617476831, 0.00025588319998252386, 0.00025734546137236563, 0.00025701406151036924, 0.0002559945641520534, 0.0002548324885847261, 0.0002577795305586251, 0.00025768138855900035, 0.0002591866771050665, 0.00026090518881742087, 0.00026040229427221404, 0.0002609885792952328, 0.00026147714799366786, 0.00025898166156793003, 0.00025812250137446154, 0.000257981327787863, 0.000257693020877784, 0.00025814905524491194, 0.0002586763228935952, 0.00025862960542494604, 0.00025760661201050305, 0.00025630329405598517, 0.0002554019804409536, 0.00025552639422298586, 0.00025718941282236766, 0.0002598553896421863, 0.0002605901066372906, 0.00025855475670754805, 0.00026063950576684, 0.00025552283373312735, 0.0002562128827711509, 0.0002678931203674953, 0.00026981911102880743, 0.0002673810361801289, 0.0002661052609516986, 0.00026646924228877625, 0.00026216322028096626, 0.0002609482545803651, 0.00026135596546441215, 0.0002622963084223943, 0.0002672681595573202, 0.0002671072745470022, 0.000273656530891951, 0.00027436790607384304, 0.0002705621233114869, 0.000269866493592278, 0.00027246649207585854, 0.00026175310718512003, 0.0002646484290100426, 0.00026402056801627454, 0.0002658027720388846, 0.00026626733592988514, 0.0002626034686289559, 0.0002643082525039869, 0.0002643082525039869, 0.0002636810403247064, 0.00026329572179006124, 0.0002626693710692069, 0.000261531182970066, 0.0002626199615877768, 0.00026015182949024247, 0.0002619499557265443, 0.00026142781617278745, 0.0002584244918142277, 0.00025582798048330645, 0.00025246109127851355, 0.00025773627571820456, 0.000258014868876944, 0.00025837623277349606, 0.000260731553439014, 0.0002586376663031507, 0.0002572325833563739, 0.00025835807399149564, 0.0002577795305586251, 0.0002569806442369072, 0.00025879400391074143, 0.00026073057725577907, 0.0002613660108653194, 0.0002658868938413862, 0.00026180935412282893, 0.0002654373894814906, 0.00026710624421652534, 0.0002687938237016128, 0.0002685607,
0.00026780338564123883, 0.0002682123490870212, 0.0002748977557682736, 0.0002764150908222719, 0.00027356671545228383, 0.0002744443773200909, 0.00028013743618684973, 0.00029184856397285625, 0.0002876353695835349, 0.00028830211796661737, 0.00029816036755670974, 0.0002811191133210449, 0.0002782000619398458, 0.00026510976763446416, 0.0002675552987073816, 0.00027407041531883787, 0.0002712251621198835, 0.0002747699237054418, 0.000276226335848137, 0.0002785432163738315, 0.0002809931424791927, 0.00028217444569052176, 0.0002832379931820718, 0.0002838672230693186, 0.00028642704060243614, 0.0002951061907582995, 0.00029813899962484014, 0.00029843415752718025, 0.00028648520921875035, 0.00028028814126532004, 0.0002777839599140345, 0.0002772147582770629, 0.0002751104615232594, 0.0002689379091795126, 0.00026903119221422314, 0.0002680588205287586, 0.00026970087753674227, 0.00026964443878418475, 0.0002720985240859894, 0.0002698021366653831, 0.0002658100920073043, 0.00026489417080686876, 0.00027045320484700625, 0.0002689291111769484, 0.0002681014850177148, 0.0002689291111769484, 0.0002690630386967742, 0.0002592458756301816, 0.00025903609870991994, 0.00025592057367729347, 0.00025135962065503994, 0.00026446687560934294, 0.0002636274974954521, 0.0002673458332949746, 0.0002673458332949746, 0.000262261698965296, 0.00026577366238169693, 0.000262708268015478, 0.00026577366238169693, 0.00026172464063333524, 0.00026762216472278795, 0.0002656266187088843, 0.0002673458332949746, 0.00026325186527088125, 0.00026787373876258124, 0.0002694091450480674, 0.0002716425037016985, 0.0002701847413578401, 0.00027086426747850435, 0.0002669589376199356, 0.00026877214387854457, 0.00026851087244232185, 0.0002667355058589527, 0.0002673737638735199, 0.00026854823937608657, 0.0002674941991405413, 0.00026828680005276705, 0.0002685885143997808, 0.0002699614432808918, 0.00027190057280919807, 0.0002729591766878862, 0.0002736900211686253, 0.00027843709466502655, 0.000278087149476582, 0.00027815968319541484, 0.0002772580790362752, 0.00027340037877633005, 0.00027517653319510566, 0.000275619492449216, 0.00027402414303390855, 0.00027269791226468797, 0.00027032231689826244, 0.00027034201342179755, 0.00027023203340448406, 0.0002775399402923838, 0.0002752767947215885, 0.00027537181036067847, 0.00027496232187107007, 0.000261486399677256, 0.00026513563564788627, 0.00026209752232913446, 0.00025920751403083907, 0.00026510908222247224, 0.00026324532912702886, 0.00026409614486724105, 0.0002632462299987738, 0.00026117136391689666, 0.00026260838281072854, 0.00026199689079902587, 0.00026243371326185936, 0.0002617839486217125, 0.0002579895167871185, 0.00026067646325493994, 0.0002615627174708125, 0.0002590227728210757, 0.0002583953981158988, 0.0002618763821474368, 0.00025793745449019523, 0.00026284754990396966, 0.000263145620838028, 0.0002607414603829015, 0.0002624473394818743, 0.00026438810018472825, 0.0002622885633644246, 0.0002624942103462447, 0.0002599116324307461, 0.0002577815807142031, 0.00025952900911890636, 0.0002612712669832463, 0.00025877013075195664, 0.00025785804905521857, 0.00026049001311029805, 0.0002610739812673379, 0.0002563636569608621, 0.000257269111527094, 0.0002575968242711472, 0.0002617935290362284, 0.00026215052498796196, 0.00026342048372666527, 0.0002652314004552382, 0.0002626034686289559, 0.0002633414929197622, 0.0002633414929197622, 0.0002637046053856835, 0.00026261329699250115, 0.00026770760901054187, 0.0002704377675871429, 0.00026943999511927025, 0.0002700368897127606, 0.0002691488602219977, 0.0002586529641592706, 0.00026279051453412846, 0.0002607999941932226, 0.000263746408378673, 0.00026176368501694435, 0.00026133408361318246, 0.00026329667909532175, 0.0002624632329132938, 0.000261550400192158, 0.00026319312943782786, 0.00026170000607602615, 0.00026639201041394505, 0.00026518713779825724, 0.0002660451092668582, 0.0002664738165701636, 0.0002668703729948391, 0.0002623845484966309, 0.0002626096055354056, 0.0002610033310900178, 0.0002598202670599651, 0.00025754340578265644, 0.0002576456172934966, 0.000258014868876944, 0.0002575766291524891, 0.00025784048811738864, 0.0002610648877197009, 0.000260406393684368, 0.000257981327787863, 0.00025940923519724227, 0.00025868251795737554, 0.00026175908483478186, 0.0002626199615877768, 0.00026013566958602144, 0.0002608935636561428, 0.00026064071763334714, 0.00026133122742234903, 0.00025906742993505796, 0.00025974249966086063, 0.0002612651093929765, 0.000258476148313843, 0.00025773627571820456, 0.0002575837192597165, 0.00025805948476840407, 0.0002578354535688477, 0.00025671305884199204, 0.0002589680463636196, 0.0002624632329132938, 0.00026171529154157163, 0.00026127747841400803, 0.00025963818011573225, 0.0002580939289698506, 0.0002585088898375865, 0.0002575919984032169, 0.00025986352190038564, 0.00025973504530324773, 0.00025821709027863747, 0.0002592144112424906, 0.000259311129218413, 0.00025861320554346814, 0.0002588152777759604, 0.000258395417655945, 0.00025961470096430914, 0.00026109378532941836, 0.00026142279443478914, 0.00026657787566725154, 0.0002661126479943724, 0.0002741951008391398, 0.0002741951008391398, 0.0002750918709808447, 0.00026459417796030404, 0.00026848691933937916, 0.00026582039249828723, 0.00026644872591700464, 0.00027011778396722615, 0.0002703567112084225, 0.00026834720155786615, 0.0002705590968791787, 0.0002683219848926828, 0.0002697971109627099, 0.00026921717250757483, 0.00026820019687356347, 0.0002719653831729391, 0.00027569902954002425, 0.00027312523995358254, 0.0002705458648685095, 0.00027107028420244504, 0.000267928066584085, 0.00026691779434343676, 0.00026660618079108085, 0.00026626733592988514, 0.00026541962999248773, 0.0002626248757695494, 0.00026421320263647776, 0.0002626248757695494, 0.0002610520900905124, 0.00026141829641050554, 0.0002617935290362284, 0.0002595671421811347, 0.00025862960542494604, 0.0002575710292603923, 0.000261480627356599, 0.00025630814243579234, 0.00025933839818598735, 0.0002586529641592706, 0.00025489664985154747, 0.0002571437402334671, 0.0002584267331246471, 0.00025812250137446154, 0.0002598861173867565, 0.00025746950455126993, 0.00025821709027863747, 0.00025646564041709234, 0.00025678991617887316, 0.00025614186191368884, 0.00025765220886050634]

# %%
stats = pd.DataFrame({'timestamp':timestamps,'reward':rewards,'y_pred_stdev':y_pred_stdev,'y_pred_mean':y_pred_mean,'y_pred_median':y_pred_median})
stats.head()

# %%
# how many positive rewards?
sum(np.asarray(rewards)>0)

# %%
# how many negative rewards?
sum(np.asarray(rewards)<0)

# %%
# find index of first reward > 0
[ n for n,i in enumerate(rewards) if i>0 ][0]

# %% [markdown]
# # Plot the combined the data

# %%
# Find rewards > 0
rwd = stats.reward.copy()
rwd[stats.reward<=0] = np.nan
rwd[stats.reward>0] = 0.0008

# %%
plt.figure()
plt.plot(stats.timestamp,rwd,'.', label="reward > 0")
plt.plot(stats.timestamp,stats.y_pred_stdev,'g')
plt.plot(stats.timestamp,stats.y_pred_median,'r')
plt.plot(stats.timestamp,stats.y_pred_mean, 'k')
plt.legend(loc='lower left',fontsize='small')
plt.xlabel("timestamp")
plt.title("So, ... where do I get rewarded?")
plt.show()
