# %% [markdown]
# **I would like to share some tips about the data of this competition with you.
# After analyzing the text files of the training and test data, there were significant points in them that no one mentioned.
# Here are some tips:**

# %% [markdown]
# **1. In text files, timestamps and features values are not sorted by time! You need to sort them out before working with them.**

# %% [markdown]
# **2. Wi-Fi signals are updated every 2 seconds but waypoints are given every 10 seconds.**

# %% [markdown]
# **3. The number of Wi-Fi signals in each update is different.**

# %% [markdown]
# **4. It seems that it is better to use signals that are closer to the waypoints based on time to training the model.**

# %% [markdown]
# **5. In my opinion, 3 features of Wi-Fi, magnetic field and beacon can be used for modeling.**

# %% [markdown]
# **6. To improve the model, the floor feature (which has been predicted with high accuracy) can be added to the feature set.**

# %% [markdown]
# **7. It is better to use BSSID of WiFi which is equivalent to device MAC address.**

# %% [markdown]
# **In the image below, you can see the time steps of the various features in the text files. Wi-Fi signals are updated every 2 seconds but waypoints are given every 10 seconds. Magnetic field and beacon features are almost present.**

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('../input/timesteps/time-steps.jpg')
plt.figure(figsize=(20,15))
imgplot = plt.imshow(img)
plt.show()
