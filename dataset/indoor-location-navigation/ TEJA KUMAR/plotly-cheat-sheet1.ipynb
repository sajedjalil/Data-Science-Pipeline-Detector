# %% [markdown]
# * * <font size="+3" color=purple ><b><center><u>Cheatsheet - 70+ Plotly Charts</u></center></b></font>

# %% [markdown]
# # Objective
#
# The aim of this kernel is provide all essential and most commonly used ggplot charts in a single page.This kernel will hold almost all charts with different attributes used for them.It could be a great time saver for you.Just utilize it anytime when you are working on data visualizations.
#
# **Note**:
# I made this kernel with different types of plots(70+ in count) which required multiple tabular datasets to be used from kaggle platform to showcase interesting insights from them.

# %% [markdown]
# <a id="top"></a>
#
# <div class="list-group" id="list-tab" role="tablist">
# <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Table of content</h3>
#
# * [Starters](#0)
#
# <font color="purple" size=+1><b>Scatter</b></font>
# * [1. Basic Scatter plot](#1)
# * [2. Scatter - Numerical](#2)
# * [3. Scatter - Categorical ](#3)
# * [4. Scatter - Color and size](#4)
# * [5. Line - Scatter](#5)
# * [6. Random sample scatter Plot](#6)
#
#
# <font color="magenta" size=+1><b>Bar</b></font>
# * [7. Basic Bar chart](#7)
# * [8. stacked Bar chart](#8)
# * [9. Bar Chart - Grouped](#9)
# * [10. Graph Objects - Bar Chart](#10)
# * [11. Graph Objects - Grouped Chart](#11)
# * [12. Graph Objects - Stacked Chart](#12)
# * [13. Graph Object Customization of Colors](#13)
# * [14. Graphh Objects - Relative Bar mode](#14)
# * [15. Category Ascending order or descending Order](#15)
# * [16. Horizontal Stacked bar chart](#16)
# * [17. Bar Chart - Horizontal](#17)
#
#
# <font color="green" size=+1><b>Pie</b></font>
#
# * [20. Basic Pie Plot](#20)
# * [21. Repeated labels Pie](#21)
# * [22. Customized Pie- Gradient & Text](#22)
# * [23. Donut Plot](#23)
# * [24. Ring Plot](#24)

# %%
pip install chart_studio

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import plotly.express as px 
import plotly.graph_objects as go 
import plotly.figure_factory as ff
import chart_studio.plotly as py
import plotly as ky

# %%
df = pd.read_csv("../input/100-sales-record/100-Sales-Records/100 Sales Records.csv",parse_dates=["Order Date"]) 
df1 = pd.read_csv("../input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv") 
df1

# %%
df["Order year"] =df["Order Date"].dt.year

# %% [markdown]
# <a id="1"></a>
# <font color="purple" size=+2.5><b>1. Basic Simple Scatter Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
fig.show()

# %% [markdown]
# <a id="2"></a>
# <font color="purple" size=+2.5><b>2. Scatter - Numerical plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.scatter(df,x="Units Sold",y="Unit Price")

# %% [markdown]
# <a id="3"></a>
# <font color="purple" size=+2.5><b>3.Scatter - Category plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.scatter(df,x="Units Sold",y="Unit Price",color="Country")

# %% [markdown]
# <a id="4"></a>
# <font color="purple" size=+2.5><b>4.Scatter Color and size plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.scatter(df,x="Units Sold",y="Unit Price",color="Region",size="Unit Cost",hover_data=["Sales Channel"])

# %% [markdown]
# <a id="5"></a>
# <font color="purple" size=+2.5><b>5.Scatter - Line plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
df1 = px.data.gapminder().query("continent == 'Oceania'")
fig = px.line(df1, x='year', y='lifeExp', color='country')
fig.show()

# %%
N = 1000
t = np.linspace(0, 10, 100)
y = np.sin(t)

fig = go.Figure(data=go.Scatter(x=t, y=y, mode='markers'))

fig.show()

# %%
N = 100
random_x = np.linspace(0, 1, N)
random_y0 = np.random.randn(N) + 5
random_y1 = np.random.randn(N)
random_y2 = np.random.randn(N) - 5

fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=random_x, y=random_y0,
                    mode='markers',
                    name='markers'))
fig.add_trace(go.Scatter(x=random_x, y=random_y1,
                    mode='lines+markers',
                    name='lines+markers'))
fig.add_trace(go.Scatter(x=random_x, y=random_y2,
                    mode='lines',
                    name='lines'))

fig.show()

# %%
fig = go.Figure(data=go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 11, 12, 13],
    mode='markers',
    marker=dict(size=[40, 60, 80, 100],
                color=[0, 1, 2, 3])
))

fig.show()

# %%
df.columns

# %%
fig = go.Figure(data = go.Scatter(x=df["Country"],
                                  y=df["Total Profit"],
                                  mode='markers',
                                  marker_color=df["Total Profit"])) 
fig.update_layout(title="Total Cost over an country wise")
fig.show()

# %% [markdown]
# <a id="6"></a>
# <font color="purple" size=+2.5><b>6.Random Sample Scatter plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
N = 100000
fig = go.Figure(data=go.Scattergl(
    x = np.random.randn(N),
    y = np.random.randn(N),
    mode='markers',
    marker=dict(
        color=np.random.randn(N),
        colorscale='plasma',
        line_width=1
    )
))

fig.show()

# %% [markdown]
# <a id="7"></a>
# <font color="purple" size=+2.5><b>7.Basic Bar Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.bar(df,x="Country",y="Total Cost")

# %%
df2 = pd.pivot_table(df,values=["Total Cost"],index=['Country','Sales Channel'],aggfunc={'Total Cost':np.sum})

# %% [markdown]
# <a id="8"></a>
# <font color="purple" size=+2.5><b>8.Stacked bar chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.bar(df,x='Country',y="Total Cost",color="Sales Channel")

# %%
fig = px.bar(df,x="Country",y="Total Cost",hover_data=["Region","Sales Channel"],height=500,color="Total Cost") 
fig.show()

# %%
px.bar(df,x="Sales Channel",y="Total Cost",color="Region")

# %% [markdown]
# <a id="9"></a>
# <font color="purple" size=+2.5><b>9.Grouped Bar Chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.bar(df,x="Sales Channel",y="Total Cost",color="Region",barmode="group",height=500)

# %%
df["Region"].unique()

# %%
px.bar(df,x="Sales Channel",y="Total Cost",color="Region",barmode="group",facet_row="Sales Channel",facet_col="Region",height=500,
       category_orders={"Region":['Australia and Oceania', 'Central America and the Caribbean',
       'Europe', 'Sub-Saharan Africa', 'Asia',
       'Middle East and North Africa', 'North America'],
                       "Sales Channel":["Offline","Online"]})

# %%
names = ["Richad","Teja","kumar"] 
Marks = [90,100,80]

# %% [markdown]
# <a id="10"></a>
# <font color="purple" size=+2.5><b>10.Graph Objects bar chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
go.Figure([go.Bar(x=names,y=Marks)])

# %% [markdown]
# <a id="11"></a>
# <font color="purple" size=+2.5><b>11. Graph Objects grouped bar chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
animals=['giraffes', 'orangutans', 'monkeys']

fig = go.Figure(data=[
    go.Bar(name='SF Zoo', x=animals, y=[20, 14, 23]),
    go.Bar(name='LA Zoo', x=animals, y=[12, 18, 29])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()

# %% [markdown]
# <a id="12"></a>
# <font color="purple" size=+2.5><b>12.Graph objects stacked bar chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
animals=['giraffes', 'orangutans', 'monkeys']

fig = go.Figure(data=[
    go.Bar(name='SF Zoo', x=animals, y=[20, 14, 23]),
    go.Bar(name='LA Zoo', x=animals, y=[12, 18, 29])
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()

# %%
x = ['Product A', 'Product B', 'Product C']
y = [20, 14, 23]

# Use textposition='auto' for direct text
fig = go.Figure(data=[go.Bar(
            x=x, y=y,
            text=y,
            textposition='auto',
        )]) 
fig.show()

# %%
fig = px.bar(df,x="Country",y="Total Profit",text=df["Total Profit"]) 
fig.update_traces(texttemplate='%{text:.2s}',textposition="outside") 
#fig.update_layout(uniformtext_minsize=180, uniformtext_mode='hide') 
fig.show()

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

fig = go.Figure()
fig.add_trace(go.Bar(
    x=months,
    y=[20, 14, 25, 16, 18, 22, 19, 15, 12, 16, 14, 17],
    name='Primary Product',
    marker_color='indianred'
))
fig.add_trace(go.Bar(
    x=months,
    y=[19, 14, 22, 14, 16, 19, 15, 14, 10, 12, 12, 16],
    name='Secondary Product',
    marker_color='lightsalmon'
))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.show()

# %% [markdown]
# <a id="13"></a>
# <font color="purple" size=+2.5><b>13.Graph Objects customization of colors</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
colors = ['mediumorchid',] * 5
colors[1] = 'crimson'

fig = go.Figure(data=[go.Bar(
    x=['Feature A', 'Feature B', 'Feature C',
       'Feature D', 'Feature E'],
    y=[20, 14, 23, 25, 22],
    marker_color=colors # marker color can be a single color value or an iterable
)])
fig.update_layout(title_text='Customize a each and every color')

# %%
fig = go.Figure(data=[go.Bar(
    x=[1, 2, 3, 5.5, 10],
    y=[10, 8, 6, 4, 2],
    width=[0.8, 0.8, 0.8, 3.5, 4],
    marker_color="mediumseagreen"# customize width here
)])

fig.show()

# %% [markdown]
# <a id="14"></a>
# <font color="purple" size=+2.5><b>14.Relative mode Bar Chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
x = [1, 2, 3, 4]

fig = go.Figure()
fig.add_trace(go.Bar(x=x, y=[1, 4, 9, 16]))
fig.add_trace(go.Bar(x=x, y=[6, -8, -4.5, 8]))
fig.add_trace(go.Bar(x=x, y=[-15, -3, 4.5, -8]))
fig.add_trace(go.Bar(x=x, y=[-1, 3, -3, -4]))

fig.update_layout(barmode='relative', title_text='Relative Barmode')
fig.show()

# %% [markdown]
# <a id="15"></a>
# <font color="purple" size=+2.5><b>15.Category Ascending order or descending order</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
x=['b', 'a', 'c', 'd']
fig = go.Figure(go.Bar(x=x, y=[2,5,1,9], name='Montreal',marker_color="goldenrod"))
fig.add_trace(go.Bar(x=x, y=[1, 4, 9, 16], name='Ottawa'))
fig.add_trace(go.Bar(x=x, y=[6, 8, 4.5, 8], name='Toronto'))

fig.update_layout(barmode='stack', xaxis={'categoryorder':'category ascending'})
fig.show()

# %%
x=['b', 'a', 'c', 'd']
fig = go.Figure(go.Bar(x=x, y=[2,5,1,9], name='Montreal',marker_color="goldenrod"))
fig.add_trace(go.Bar(x=x, y=[1, 4, 9, 16], name='Ottawa'))
fig.add_trace(go.Bar(x=x, y=[6, 8, 4.5, 8], name='Toronto'))

fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()

# %%
x = [
    ["BB+", "BB+", "BB+", "BB", "BB", "BB"],
    [16, 17, 18, 16, 17, 18,]
]
fig = go.Figure()
fig.add_bar(x=df["Country"],y=df["Sales Channel"])
fig.add_bar(x=df["Country"],y=df["Sales Channel"])
fig.update_layout(barmode="stack")
fig.show()

# %% [markdown]
# <a id="16"></a>
# <font color="purple" size=+2.5><b>16.Horizontal Stacked bar chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.bar(df,x="Total Profit",y="Region",orientation='h',color="Country")

# %% [markdown]
# <a id="17"></a>
# <font color="purple" size=+2.5><b>17.Horizontal bar chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
fig = go.Figure(go.Bar(
            x=[20, 14, 23],
            y=['giraffes', 'orangutans', 'monkeys'],
            orientation='h'))

fig.show()

# %% [markdown]
# <a id="18"></a>
# <font color="purple" size=+2.5><b>18.Basic Pie chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.pie(df,values="Total Profit",names=df["Country"])

# %% [markdown]
# <a id="19"></a>
# <font color="purple" size=+2.5><b>19.Pie chart - Setting in bulit colors</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.pie(df,names="Country",values="Total Profit",color_discrete_sequence=px.colors.sequential.Blugrn_r)

# %%
df["Region"].unique()

# %% [markdown]
# <a id="20"></a>
# <font color="purple" size=+2.5><b>20.Pie chart - Repeated Labels</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
fig = px.pie(df,names=df["Region"],values=df["Total Cost"],color_discrete_map={'Sub-Sarahan':'lightcyan',
                                 'Europe':'cyan',
                                 'Asia':'royalblue',
                                 'North America':'darkblue',
                                  'Middle East and North Africa':'green',
                                'Central America and the Caribbean':"yellow",
                                 'Australia and Oceania':'violet'}) 
fig.show()

# %% [markdown]
# <a id="21"></a>
# <font color="purple" size=+2.5><b>21.Customization of pie Chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
fig = px.pie(df,names=df["Region"],values=df["Total Cost"],color_discrete_map={'Sub-Sarahan':'lightcyan',
                                 'Europe':'cyan',
                                 'Asia':'royalblue',
                                 'North America':'darkblue',
                                  'Middle East and North Africa':'green',
                                'Central America and the Caribbean':"yellow",
                                 'Australia and Oceania':'violet'},labels={'Region':'Region'}) 
fig.update_traces(textposition="inside",textinfo='percent+label') 
fig.show()

# %%
labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500, 2500, 1053, 500]

fig = go.Figure(data=[go.Pie(labels=labels, values=values)])
fig.show()

# %% [markdown]
# <a id="22"></a>
# <font color="purple" size=+2.5><b>22. Donut Chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.pie(df,names="Country",values="Total Profit",color_discrete_sequence=px.colors.sequential.Blugrn_r,hole=0.3)

# %% [markdown]
# <a id="23"></a>
# <font color="purple" size=+2.5><b>23.Pulling Sectors from The Center</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500, 2500, 1053, 500]

fig = go.Figure(data=[go.Pie(labels=labels, values=values,pull=[0,0,0.3,0.1])])
fig.show()

# %% [markdown]
# # Tables

# %% [markdown]
# <a id="24"></a>
# <font color="purple" size=+2.5><b>24.Creation of table</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
fig = go.Figure(data=[go.Table(header=dict(values=['A Scores', 'B Scores']),
                 cells=dict(values=[[100, 90, 80, 90], [95, 85, 75, 95]]))
                     ])
fig.show()

# %%
df.columns[0:2]

# %% [markdown]
# <a id="25"></a>
# <font color="purple" size=+2.5><b>25.Setting colors for table </b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
fig = go.Figure(data=[go.Table(header=dict(values=df.columns[0:2],
                fill_color='lightskyblue',),
                 cells=dict(values=[df.Region,df.Country], 
                            fill_color='lavender',
                            align='left'))
                     ])
fig.show()

# %% [markdown]
# <a id="26"></a>
# <font color="purple" size=+2.5><b>26.Figure Factory table</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
table = ff.create_table(df.iloc[:,0:4],colorscale='sunsetdark')

# %%
table

# %% [markdown]
# <a id="27"></a>
# <font color="purple" size=+2.5><b>27.Tree map</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.treemap(df,path=["Region","Country","Sales Channel"])

# %% [markdown]
# <a id="28"></a>
# <font color="purple" size=+2.5><b>28.Suburst chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
df5 = px.data.tips()
fig = px.sunburst(df5, path=['sex','day','time'], values='total_bill',color="time",color_discrete_map={'(?)':'black', 'Lunch':'gold', 'Dinner':'darkblue'})
fig.show()

# %% [markdown]
# <a id="29"></a>
# <font color="purple" size=+2.5><b>29.Scatter webgl plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
N = 100000

df2 = pd.DataFrame(dict(x=np.random.randn(N),
                       y=np.random.randn(N)))

fig = px.scatter(df2, x="x", y="y", render_mode='webgl')

fig.update_traces(marker_line=dict(width=1, color='DarkSlateGray'))

fig.show()

# %%
df.head()

# %% [markdown]
# <a id="30"></a>
# <font color="purple" size=+2.5><b>30.Box Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.box(df,y="Total Cost")

# %% [markdown]
# <a id="31"></a>
# <font color="purple" size=+2.5><b>31.Box Plot - Specified Colors</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.box(df,x="Sales Channel",y="Total Cost",color_discrete_sequence=px.colors.sequential.Blues_r)

# %% [markdown]
# <a id="32"></a>
# <font color="purple" size=+2.5><b>32.Displaying data under box plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.box(df,x="Sales Channel",y="Total Cost",points="all",color_discrete_sequence=px.colors.sequential.Blackbody)

# %% [markdown]
# <a id="33"></a>
# <font color="purple" size=+2.5><b>33.Styled Box Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.box(df,x="Sales Channel",y="Total Cost",points="all",notched=True,color_discrete_sequence=px.colors.sequential.Agsunset)

# %% [markdown]
# <a id="34"></a>
# <font color="purple" size=+2.5><b>34.Strip Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.strip(df,x="Sales Channel",y="Total Cost",)

# %%
df3 = pd.read_csv("../input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv")

# %%
df3.head()

# %% [markdown]
# <a id="35"></a>
# <font color="purple" size=+2.5><b>35.Histogram</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.histogram(df3,x="avg_glucose_level")

# %% [markdown]
# <a id="36"></a>
# <font color="purple" size=+2.5><b>36.Histogram - Specified Bins</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.histogram(df3,x="avg_glucose_level",nbins=20)

# %% [markdown]
# <a id="37"></a>
# <font color="purple" size=+2.5><b>37.Several histograms  for the different values of one column</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.histogram(df3,x="avg_glucose_level",color="gender")

# %% [markdown]
# <a id="38"></a>
# <font color="purple" size=+2.5><b>38.Histogram - Rug Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.histogram(df3,x="avg_glucose_level",color="gender",marginal='rug')

# %% [markdown]
# <a id="39"></a>
# <font color="purple" size=+2.5><b>39.Histogram - Horizontal</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.histogram(df3,y="avg_glucose_level",color="gender")

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=df3["avg_glucose_level"]))
fig.add_trace(go.Histogram(x=df3["bmi"]))

# The two histograms are drawn on top of another
fig.update_layout(barmode='stack')
fig.show()

# %% [markdown]
# <a id="40"></a>
# <font color="purple" size=+2.5><b>40.Cummulative Histogram</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.histogram(df3,x=df3["avg_glucose_level"],cumulative=True)

# %%
df2 = sns.load_dataset("tips") 
df2.head()

# %% [markdown]
# <a id="41"></a>
# <font color="purple" size=+2.5><b>41.Violin Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.violin(df2,y="tip")

# %% [markdown]
# <a id="42"></a>
# <font color="purple" size=+2.5><b>42.Violin with box Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.violin(df2,y="tip",points="all",box=True)

# %% [markdown]
# <a id="43"></a>
# <font color="purple" size=+2.5><b>43.Displaying data under Violin Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.violin(df2, y = "tip", x="time",box=True,points="all",hover_data=df2.columns)

# %% [markdown]
# <a id="44"></a>
# <font color="purple" size=+2.5><b>44.Overlay Violin Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.violin(df2,y="tip",points="all",violinmode="overlay",color="sex")

# %% [markdown]
# <a id="45"></a>
# <font color="purple" size=+2.5><b>45.2d density heat map</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.density_heatmap(df,x="Total Cost",y="Total Profit")

# %%
y = df.groupby("Region")["Total Cost"].sum()[0:].values
y

# %% [markdown]
# <a id="46"></a>
# <font color="purple" size=+2.5><b>46.Funnel Chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.funnel(df,y=df["Region"].unique(),x=y)

# %%
df5  = pd.read_csv("../input/istanbul-stock-exchange/istanbul_stock_exchange.csv")

# %%
df5.head()

# %% [markdown]
# <a id="47"></a>
# <font color="purple" size=+2.5><b>47.Time Series data</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
px.line(df5,x="date",y="EM")

# %% [markdown]
# <a id="48"></a>
# <font color="purple" size=+2.5><b>48.Time Series - Range Slider</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
fig = px.line(df5,x="date",y="EM") 
fig.update_xaxes(rangeslider_visible=True)

# %% [markdown]
# * * * ![](http://)![](http://)![](http://)![](http://)![](http://)![](http://)![](http://)![](http://)![](http://)![](http://)

# %% [markdown]
# > > > >
