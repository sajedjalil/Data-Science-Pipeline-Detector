# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
import glob as glob
import seaborn as sns

# %%
path = '../input/indoor-location-navigation/train/*'
files = glob.glob(path)
cnt = np.zeros(11)

# %%
for i in files:
    cnt[0] += len(glob.glob(i+'/B1'))
    cnt[1] += len(glob.glob(i+'/B1'))
    for j in range (0,9):
        cnt[j+2] += len(glob.glob(i+'/F'+str(j)))

# %%
print(cnt)

# %%
prob = cnt / cnt.sum()

# %%
df_submission = pd.read_csv("../input/indoor-location-navigation/sample_submission.csv", index_col=0)
#Calculate the mean of the first 12113 files in the training Data
df_submission["x"] = 94.21851104 
df_submission["y"] = 98.96631499
df_submission["floor"] = np.random.choice(2,len(df_submission["floor"])) + 1
df_submission.head()

# %%
df_submission.to_csv("submission.csv")
