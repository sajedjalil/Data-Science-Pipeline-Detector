# %% [markdown]
# Here is the Milestone 1 final submission for Team 1: Lu Xinlong, Li Zhiang and Sun Zhaoying. Because this competition only needs us to submit the csv file which contains the final prediction. There's no way for us to provide a link that could be viewed by the public without logging into Lu Xinlong's private account. So we create a temporary notebook to indicate the final score for our Milestone 1.

# %%
import pandas as pd
results=pd.read_csv('../input/milestone-1/sub_modify_dn.csv')
results.to_csv('./sub_modify_dn.csv',index=False)
