# %% [markdown]
# Here is the Milestone 2 submission result for Team 1: Lu Xinlong, Li Zhiang and Sun Zhaoying. Because this competition only needs us to submit the csv file which contains the final prediction. There's no way for us to provide a link that could be viewed by the public without logging into Lu Xinlong's private account. Just like the milestone 1, we create a temporary notebook here.

# %%
import pandas as pd
results=pd.read_csv('../input/milestone-2/sub_fusion.csv')
results.to_csv('./sub_fusion.csv',index=False)
