# %%
import numpy as np
import pandas as pd 
from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))
import datetime
import time

# %% [markdown]
# Following an example of applying Latent Dirichlet Allocation.
# In LDA, the time complexity is proportional to (n_samples * iterations).
#
# References:
# “Latent Dirichlet Allocation” D. Blei, A. Ng, M. Jordan, 2003
