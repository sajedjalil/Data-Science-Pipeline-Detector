# %% [markdown]
# I have pasted my code to check the training data below. Your comments or suggestions are welcome.
# <font color=blue>
# It will be exiciting to hear from anyone who wants to team up.
# </font>

# %%
import pandas as pd

# %%
train = pd.read_csv("../input/train.csv")
train.head()

# %% [markdown]
# There are 3 columns besides users' ID, songs' ID and the target. Let's have a check one by one.
#
#
# ## source_system_tab

# %%
sysTab_df = pd.pivot_table(train, values='song_id', index=['source_system_tab'], columns=['target'], aggfunc=len)

# %%
sysTab_df['RecurringRatio'] = sysTab_df[1]/sysTab_df[0]

# %%
sysTab_df.sort_values(by='RecurringRatio', ascending=False)

# %% [markdown]
# source_system_tab is the name of the tab where the event was triggered. System tabs are used to categorize KKBOX mobile apps functions.
#
# It is reasonble that songs from **my library** have higher recurring ratio.
#
# We also find songs from **radio** are more likely to be skipped.
#
# Then let's do the same aggregation on screen name and source type.
#
# ## Screen Name

# %%
screenName = pd.pivot_table(train, values='song_id', index=['source_screen_name'], columns=['target'], aggfunc=len)
screenName['RecurringRatio'] = screenName[1]/screenName[0]
screenName.sort_values(by='RecurringRatio', ascending=False)

# %% [markdown]
# ## Source Type

# %%
srType = pd.pivot_table(train, values='song_id', index=['source_type'], columns=['target'], aggfunc=len)
srType['RecurringRatio'] = srType[1]/srType[0]
srType.sort_values(by='RecurringRatio', ascending=False)
