# %% [markdown]
# В коде содержатся считывания из вспомогательных backup-файлов, которые я использовал, поскольку запускать всё заново заняло бы слишком много времени. К сожалению, я не смог добавить их в input в kernel, поэтому загрузка из них, видимо, не сработает.
