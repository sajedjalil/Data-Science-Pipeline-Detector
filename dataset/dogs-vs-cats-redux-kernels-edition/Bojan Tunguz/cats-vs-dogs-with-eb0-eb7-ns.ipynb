# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import zipfile
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.linear_model import LogisticRegression

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
sample_submission = pd.read_csv('/kaggle/input/dogs-vs-cats-redux-kernels-edition/sample_submission.csv')
sample_submission.tail()

# %%
sample_submission.head()

# %%
TRAIN_FOLDER = '../input/cats-and-dogs-embedded-data/train/train/'
TEST_FOLDER =  '../input/cats-and-dogs-embedded-data/test/test/'
IMG_SIZE = 224

# %%
train_image_list = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_1/train_image_list.npy')
test_image_list = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_1/test_image_list.npy')

# %%
train_image_list

# %%
test_image_list

# %%
ids = [int(x.split('.')[0]) for x in test_image_list]
ids[:20]

# %%
target = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_1/target.npy')

# %%
target

# %%
train_EB0_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB0_ns.npy')
test_EB0_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB0_ns.npy')
train_EB1_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB1_ns.npy')
test_EB1_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB1_ns.npy')
train_EB2_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB2_ns.npy')
test_EB2_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB2_ns.npy')
train_EB3_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB3_ns.npy')
test_EB3_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB3_ns.npy')

train_EB4_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB4_ns.npy')
test_EB4_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB4_ns.npy')
train_EB5_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB5_ns.npy')
test_EB5_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB5_ns.npy')
train_EB6_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB6_ns.npy')
test_EB6_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB6_ns.npy')
train_EB7_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/train_EB7_ns.npy')
test_EB7_ns = np.load('../input/cats-and-dogs-embedded-data/cats_and_dogs_4/cats_and_dogs_4/test_EB7_ns.npy')

# %%
train_EB0_ns.shape

# %%
X_train, X_val, y_train, y_val = train_test_split(train_EB0_ns, target, test_size=0.1, random_state=42)

# %%
# %%time
lr = LogisticRegression(C=0.02, max_iter=10000)
lr.fit(X_train, y_train)

# %%
val_preds_EB0 = lr.predict_proba(X_val)[:,1]

# %%
val_preds_EB0

# %%
y_val

# %%
roc_auc_score(y_val, val_preds_EB0)

# %%
log_loss(y_val, val_preds_EB0)

# %%
test_preds_EB0 = lr.predict_proba(test_EB0_ns)[:,1]

# %%
test_preds_EB0

# %%
# %%time
X_train, X_val, y_train, y_val = train_test_split(train_EB1_ns, target, test_size=0.1, random_state=42)
lr = LogisticRegression(C=0.02, max_iter=10000)
lr.fit(X_train, y_train)
val_preds_EB1 = lr.predict_proba(X_val)[:,1]
test_preds_EB1 = lr.predict_proba(test_EB1_ns)[:,1]
print(roc_auc_score(y_val, val_preds_EB1))
print(log_loss(y_val, val_preds_EB1))

# %%
# %%time
X_train, X_val, y_train, y_val = train_test_split(train_EB2_ns, target, test_size=0.1, random_state=42)
lr = LogisticRegression(C=0.02, max_iter=10000)
lr.fit(X_train, y_train)
val_preds_EB2 = lr.predict_proba(X_val)[:,1]
test_preds_EB2 = lr.predict_proba(test_EB2_ns)[:,1]
print(roc_auc_score(y_val, val_preds_EB2))
print(log_loss(y_val, val_preds_EB2))

# %%
# %%time
X_train, X_val, y_train, y_val = train_test_split(train_EB3_ns, target, test_size=0.1, random_state=42)
lr = LogisticRegression(C=0.02, max_iter=10000)
lr.fit(X_train, y_train)
val_preds_EB3 = lr.predict_proba(X_val)[:,1]
test_preds_EB3 = lr.predict_proba(test_EB3_ns)[:,1]
print(roc_auc_score(y_val, val_preds_EB3))
print(log_loss(y_val, val_preds_EB3))

# %%
# %%time
X_train, X_val, y_train, y_val = train_test_split(train_EB4_ns, target, test_size=0.1, random_state=42)
lr = LogisticRegression(C=0.019, max_iter=10000)
lr.fit(X_train, y_train)
val_preds_EB4 = lr.predict_proba(X_val)[:,1]
test_preds_EB4 = lr.predict_proba(test_EB4_ns)[:,1]
print(roc_auc_score(y_val, val_preds_EB4))
print(log_loss(y_val, val_preds_EB4))

# %%
# %%time
X_train, X_val, y_train, y_val = train_test_split(train_EB5_ns, target, test_size=0.1, random_state=42)
lr = LogisticRegression(C=0.02, max_iter=10000)
lr.fit(X_train, y_train)
val_preds_EB5 = lr.predict_proba(X_val)[:,1]
test_preds_EB5 = lr.predict_proba(test_EB5_ns)[:,1]
print(roc_auc_score(y_val, val_preds_EB5))
print(log_loss(y_val, val_preds_EB5))

# %%
# %%time
X_train, X_val, y_train, y_val = train_test_split(train_EB6_ns, target, test_size=0.1, random_state=42)
lr = LogisticRegression(C=0.02, max_iter=10000)
lr.fit(X_train, y_train)
val_preds_EB6 = lr.predict_proba(X_val)[:,1]
test_preds_EB6 = lr.predict_proba(test_EB6_ns)[:,1]
print(roc_auc_score(y_val, val_preds_EB6))
print(log_loss(y_val, val_preds_EB6))

# %%
# %%time
X_train, X_val, y_train, y_val = train_test_split(train_EB7_ns, target, test_size=0.1, random_state=42)
lr = LogisticRegression(C=0.026, max_iter=10000)
lr.fit(X_train, y_train)
val_preds_EB7 = lr.predict_proba(X_val)[:,1]
test_preds_EB7 = lr.predict_proba(test_EB7_ns)[:,1]
print(roc_auc_score(y_val, val_preds_EB7))
print(log_loss(y_val, val_preds_EB7))

# %%
print(roc_auc_score(y_val, 0.6*val_preds_EB1+0.4*val_preds_EB0))
print(log_loss(y_val, 0.6*val_preds_EB1+0.4*val_preds_EB0))

# %%
sample_submission['id'] = ids
sample_submission['label'] = 0.8*test_preds_EB3+0.2*(0.6*test_preds_EB2+0.4*(0.6*test_preds_EB1+0.4*test_preds_EB0))
sample_submission.to_csv('submission_0.csv', index=False)
sample_submission.head()

# %%
sample_submission['id'] = ids
sample_submission['label'] = 0.5*test_preds_EB4+0.5*test_preds_EB5
sample_submission.to_csv('submission_1.csv', index=False)
sample_submission.head()

# %%
sample_submission['id'] = ids
sample_submission['label'] = 0.9*(0.5*test_preds_EB4+0.5*test_preds_EB5)+0.1*test_preds_EB6
sample_submission.to_csv('submission_2.csv', index=False)
sample_submission.head()

# %%
sample_submission['id'] = ids
sample_submission['label'] = 0.9*test_preds_EB7 + 0.1*(0.9*(0.5*test_preds_EB4+0.5*test_preds_EB5)+0.1*test_preds_EB6)
sample_submission.to_csv('submission_3.csv', index=False)
sample_submission.head()
