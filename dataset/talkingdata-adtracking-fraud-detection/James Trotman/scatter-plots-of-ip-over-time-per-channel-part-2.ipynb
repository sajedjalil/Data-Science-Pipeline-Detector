# %%
from IPython.core.display import HTML

# %% [markdown]
# # Scatter Plots of IP over Time per Channel: part 2
#
# These are some scatter plots of clicks over time.
#
# They show the interaction between [ip, channel, time, is_attributed].
#
#  - time (x axis)
#  - ip (y axis)
#  - channel (1 per plot)
#  - is_attributed (color)
#
# Color key:
#
#  - <font color=green>green</font> test set (test supplement, the original full test set)
#  - <font color=blue>blue</font> is_attributed==0
#  - <font color=red>red</font> is_attributed==1
#
# Days are quite clearly visible by the new block of IPs that were sampled by TalkingData for each day. The test set at the end has only low IP values as already [revealed][1]/[shared][2] by [others][3].
#
# Note that the test set (green, day 4) does contain new IP addresses, but all in the lowest range of IPs, up to 126413. This is not clear from these plots.
#
# For more details on the IP encoding see:
#
#  - [False Leak? (discussion by Andy Harless)][1]
#  - [Be careful about IPs as a Signal (kernel by Yulia)][2]
#  - [IP Download Rates (kernel by CPMP)][3]
#
# The plots are pregenerated by some old Java code I have, which is not shared here, only the output, partly as a test in autogenerating Jupyter Notebooks (using the nbformat module).
#
# (The embedded files are actually a little larger than shown in the Notebook, you can right click &rarr; View Image to see the full size.)
#
# I think the plots alone are worth sharing, they contain useful insights into the IP behaviour over time.
#
# I selected the most interesting plots to share then ran into the problem that notebooks are limited to 1Mb of source code, so I've split them into two kernels.
#
# This is part 2, [part 1][4] is here.
#
#  [1]: https://www.kaggle.com/c/talkingdata-adtracking-fraud-detection/discussion/52374
#  [2]: https://www.kaggle.com/yuliagm/be-careful-about-ips-as-a-signal
#  [3]: https://www.kaggle.com/cpmpml/ip-download-rates
#  [4]: https://www.kaggle.com/jtrotman/scatter-plots-of-ip-over-time-per-channel-part-1

# %%
chan320 = '''<h3>[channel 320] ip vs time</h3><img src="..."><br/>
32596 points<br/>
[576002.0..921541.0] (x time in seconds)<br/>
[20.0..364772.0] (y ip number)<br/>
[test x 3340, dud x 27660, is_attributed x 1596]<br/>'''

# %%
chan330 = '''<h3>[channel 330] ip vs time</h3><img src="..."><br/>
67881 points<br/>
[576036.0..921585.0] (x time in seconds)<br/>
[9.0..364775.0] (y ip number)<br/>
[test x 6184, dud x 59985, is_attributed x 1712]<br/>'''

# %%
chan332 = '''<h3>[channel 332] ip vs time</h3><img src="..."><br/>
10754 points<br/>
[576764.0..921549.0] (x time in seconds)<br/>
[20.0..364735.0] (y ip number)<br/>
[test x 1691, dud x 7769, is_attributed x 1294]<br/>'''

# %%
chan361 = '''<h3>[channel 361] ip vs time</h3><img src="..."><br/>
105945 points<br/>
[576429.0..921597.0] (x time in seconds)<br/>
[9.0..364778.0] (y ip number)<br/>
[test x 9113, dud x 96816, is_attributed x 16]<br/>'''

# %%
chan364 = '''<h3>[channel 364] ip vs time</h3><img src="..."><br/>
852316 points<br/>
[576000.0..921600.0] (x time in seconds)<br/>
[21.0..364494.0] (y ip number)<br/>
[test x 200175, dud x 652131, is_attributed x 10]<br/>'''

# %%
chan391 = '''<h3>[channel 391] ip vs time</h3><img src="..."><br/>
64441 points<br/>
[576008.0..921503.0] (x time in seconds)<br/>
[9.0..364776.0] (y ip number)<br/>
[test x 2441, dud x 61954, is_attributed x 46]<br/>'''

# %%
chan408 = '''<h3>[channel 408] ip vs time</h3><img src="..."><br/>
897 points<br/>
[609583.0..909303.0] (x time in seconds)<br/>
[691.0..364738.0] (y ip number)<br/>
[test x 203, dud x 33, is_attributed x 661]<br/>'''

# %%
chan419 = '''<h3>[channel 419] ip vs time</h3><img src="..."><br/>
14370 points<br/>
[576005.0..921550.0] (x time in seconds)<br/>
[69.0..364769.0] (y ip number)<br/>
[test x 3999, dud x 3696, is_attributed x 6675]<br/>'''

# %%
chan446 = '''<h3>[channel 446] ip vs time</h3><img src="..."><br/>
96254 points<br/>
[576042.0..921596.0] (x time in seconds)<br/>
[20.0..364549.0] (y ip number)<br/>
[test x 10873, dud x 85366, is_attributed x 15]<br/>'''

# %%
chan465 = '''<h3>[channel 465] ip vs time</h3><img src="..."><br/>
5272 points<br/>
[576059.0..921176.0] (x time in seconds)<br/>
[215.0..364725.0] (y ip number)<br/>
[test x 1577, dud x 1089, is_attributed x 2606]<br/>'''

# %%
chan484 = '''<h3>[channel 484] ip vs time</h3><img src="..."><br/>
108027 points<br/>
[576001.0..921594.0] (x time in seconds)<br/>
[20.0..364776.0] (y ip number)<br/>
[test x 18580, dud x 89441, is_attributed x 6]<br/>'''

# %%
chan498 = '''<h3>[channel 498] ip vs time</h3><img src="..."><br/>
1845 points<br/>
[576012.0..921525.0] (x time in seconds)<br/>
[235.0..363929.0] (y ip number)<br/>
[test x 705, dud x 1068, is_attributed x 72]<br/>'''

# %%
HTML(chan320)

# %%
HTML(chan330)

# %%
HTML(chan332)

# %%
HTML(chan361)

# %%
HTML(chan364)

# %%
HTML(chan391)

# %%
HTML(chan408)

# %%
HTML(chan419)

# %%
HTML(chan446)

# %%
HTML(chan465)

# %%
HTML(chan484)

# %%
HTML(chan498)
