# %%
from IPython.core.display import HTML

# %% [markdown]
# # Scatter Plots of IP over Time per Channel: part 1
#
# These are some scatter plots of clicks over time.
#
# They show the interaction between [ip, channel, time, is_attributed].
#
#  - time (x axis)
#  - ip (y axis)
#  - channel (1 per plot)
#  - is_attributed (color)
#
# Color key:
#
#  - <font color=green>green</font> test set (test supplement, the original full test set)
#  - <font color=blue>blue</font> is_attributed==0
#  - <font color=red>red</font> is_attributed==1
#
# Days are quite clearly visible by the new block of IPs that were sampled by TalkingData for each day. The test set at the end has only low IP values as already [revealed][1]/[shared][2] by [others][3].
#
# Note that the test set (green, day 4) does contain new IP addresses, but all in the lowest range of IPs, up to 126413. This is not clear from these plots.
#
# For more details on the IP encoding see:
#
#  - [False Leak? (discussion by Andy Harless)][1]
#  - [Be careful about IPs as a Signal (kernel by Yulia)][2]
#  - [IP Download Rates (kernel by CPMP)][3]
#
# The plots are pregenerated by some old Java code I have, which is not shared here, only the output, partly as a test in autogenerating Jupyter Notebooks (using the nbformat module).
#
# (The embedded files are actually a little larger than shown in the Notebook, you can right click &rarr; View Image to see the full size.)
#
# I think the plots alone are worth sharing, they contain useful insights into the IP behaviour over time.
#
# I selected the most interesting plots to share then ran into the problem that notebooks are limited to 1Mb of source code, so I've split them into two kernels.
#
# This is part 1, [part 2][4] is here.
#
#  [1]: https://www.kaggle.com/c/talkingdata-adtracking-fraud-detection/discussion/52374
#  [2]: https://www.kaggle.com/yuliagm/be-careful-about-ips-as-a-signal
#  [3]: https://www.kaggle.com/cpmpml/ip-download-rates
#  [4]: https://www.kaggle.com/jtrotman/scatter-plots-of-ip-over-time-per-channel-part-2

# %%
chan5 = '''<h3>[channel 5] ip vs time</h3><img src="..."><br/>
13073 points<br/>
[602865.0..921026.0] (x time in seconds)<br/>
[41.0..364739.0] (y ip number)<br/>
[test x 3416, dud x 3877, is_attributed x 5780]<br/>'''

# %%
chan13 = '''<h3>[channel 13] ip vs time</h3><img src="..."><br/>
134078 points<br/>
[576002.0..921592.0] (x time in seconds)<br/>
[1.0..364773.0] (y ip number)<br/>
[test x 18446, dud x 115618, is_attributed x 14]<br/>'''

# %%
chan18 = '''<h3>[channel 18] ip vs time</h3><img src="..."><br/>
107158 points<br/>
[576000.0..921600.0] (x time in seconds)<br/>
[19.0..364776.0] (y ip number)<br/>
[test x 51888, dud x 55241, is_attributed x 29]<br/>'''

# %%
chan21 = '''<h3>[channel 21] ip vs time</h3><img src="..."><br/>
377510 points<br/>
[574867.0..921599.0] (x time in seconds)<br/>
[6.0..364759.0] (y ip number)<br/>
[test x 74275, dud x 260766, is_attributed x 42469]<br/>'''

# %%
chan24 = '''<h3>[channel 24] ip vs time</h3><img src="..."><br/>
77606 points<br/>
[576001.0..921515.0] (x time in seconds)<br/>
[6.0..364701.0] (y ip number)<br/>
[test x 7151, dud x 70443, is_attributed x 12]<br/>'''

# %%
chan113 = '''<h3>[channel 113] ip vs time</h3><img src="..."><br/>
553573 points<br/>
[576001.0..921600.0] (x time in seconds)<br/>
[1.0..364776.0] (y ip number)<br/>
[test x 79285, dud x 418422, is_attributed x 55866]<br/>'''

# %%
chan114 = '''<h3>[channel 114] ip vs time</h3><img src="..."><br/>
853 points<br/>
[591520.0..906796.0] (x time in seconds)<br/>
[509.0..364628.0] (y ip number)<br/>
[test x 176, dud x 48, is_attributed x 629]<br/>'''

# %%
chan174 = '''<h3>[channel 174] ip vs time</h3><img src="..."><br/>
24680 points<br/>
[580477.0..921593.0] (x time in seconds)<br/>
[20.0..364026.0] (y ip number)<br/>
[test x 622, dud x 24053, is_attributed x 5]<br/>'''

# %%
chan182 = '''<h3>[channel 182] ip vs time</h3><img src="..."><br/>
150653 points<br/>
[576003.0..921590.0] (x time in seconds)<br/>
[1.0..364773.0] (y ip number)<br/>
[test x 20080, dud x 130473, is_attributed x 100]<br/>'''

# %%
chan222 = '''<h3>[channel 222] ip vs time</h3><img src="..."><br/>
779 points<br/>
[576007.0..920246.0] (x time in seconds)<br/>
[1049.0..362485.0] (y ip number)<br/>
[test x 51, dud x 614, is_attributed x 114]<br/>'''

# %%
chan225 = '''<h3>[channel 225] ip vs time</h3><img src="..."><br/>
12515 points<br/>
[576656.0..921598.0] (x time in seconds)<br/>
[10.0..359109.0] (y ip number)<br/>
[test x 12419, dud x 69, is_attributed x 27]<br/>'''

# %%
chan274 = '''<h3>[channel 274] ip vs time</h3><img src="..."><br/>
42404 points<br/>
[576003.0..921565.0] (x time in seconds)<br/>
[9.0..364748.0] (y ip number)<br/>
[test x 3932, dud x 12584, is_attributed x 25888]<br/>'''

# %%
HTML(chan5)

# %%
HTML(chan13)

# %%
HTML(chan18)

# %%
HTML(chan21)

# %%
HTML(chan24)

# %%
HTML(chan113)

# %%
HTML(chan114)

# %%
HTML(chan174)

# %%
HTML(chan182)

# %%
HTML(chan222)

# %%
HTML(chan225)

# %%
HTML(chan274)
