# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import seaborn as sns
# %matplotlib inline

from dateutil import parser

import os
file_list = os.listdir("../")

#size
# !ls "../input/" -al

# Any results you write to the current directory are saved as output.

# %%
file_list = os.listdir("../input/")
files= ['../input/' + s for s in file_list]
print(files)
num_lines = [sum(1 for line in open(f)) for  f in files]
print(num_lines)

# %%
trdf= pd.read_csv('../input/train.csv', nrows=10000000, )
test = pd.read_csv('../input/test.csv')
trdf.head(10)

# %%
cols = trdf.columns.values.tolist()
cols_best = cols[0:5]
for c in cols_best:
    trdf[c] = trdf[c].astype('category')
    test[c]= test[c].astype('category')
trdf['is_attributed']=trdf['is_attributed'].astype('category')

# %%
trdf.describe()

# %%
trdf[trdf.is_attributed == 1].head()

# %%
trdf.app.unique()

# %%
trdf.app.nunique()

# %%
trdf.app.value_counts().head()

# %%
trdf.device.nunique()

# %%
trdf.device.value_counts().head()

# %%
plt.figure(figsize=(12, 6))
plt.hist(trdf.device, log = True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(trdf.app, log = True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
cols = trdf.columns.values.tolist()
cols_best = cols[0:4]
counts = [trdf[col].nunique() for col in cols_best]

sns.set(font_scale=1.5)
ax = sns.barplot(cols_best, counts, palette=sns.color_palette(), log=True)
ax.set(xlabel='features', ylabel='log(counts)')

# %%
total = trdf.shape[0]
values= trdf.is_attributed.value_counts()
cat = trdf.is_attributed.unique()

# %%
sns.set(font_scale=1.5)
ax = sns.barplot(cat, values, palette=sns.color_palette(), log=False)
ax.set(xlabel='values', ylabel='counts')

# %%
pct_imbalance = (values[1]/values[0])*100
print(round(pct_imbalance,2))

# %%
trdf.dtypes
trdf["attributed_time"] = pd.to_datetime(trdf["attributed_time"])
trdf["click_time"] = pd.to_datetime(trdf["click_time"])

# %%
#add new col
trdf['diff_time'] = trdf.attributed_time - trdf.click_time

# %%
trdf.dtypes

trdf['diff_time_hr'] = np.round(trdf['diff_time'] / np.timedelta64(1, 'h'), 2)

# %%
trdf.head()

# %%
trdf['diff_time_hr'].describe()

# %%
trdf.diff_time_hr.value_counts()
