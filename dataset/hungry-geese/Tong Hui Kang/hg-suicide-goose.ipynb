# %%
# %%writefile suicide.py
# In case you want to start with fewer agents
# Not really the worst possible, but I want to keep it simple

def agent(obs, _):
    if obs["step"]%2 == 1:
        return "NORTH"
    return "SOUTH"

# %%
from kaggle_environments import make
env = make("hungry_geese", debug=True)

env.reset()
env.run(['suicide.py', 'suicide.py', 'suicide.py', 'suicide.py'])
env.render(mode="ipython", width=800, height=700)
