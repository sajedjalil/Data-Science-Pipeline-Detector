# %%
# !git clone https://github.com/DeNA/HandyRL.git
# %cd HandyRL
# !pip3 install -q -r requirements-dev.txt

# %%
# This is the public shared model.
# !mkdir models
# !cp /kaggle/input/geese-best/best.pth models/1500.pth

# %%
# %%writefile config.yaml
#
#
# env_args:
#     env: 'HungryGeese'
#
# train_args:
#     model_type: geese
#     turn_based_training: False
#     observation: False
#     gamma: 0.8
#     forward_steps: 32
#     compress_steps: 4
#     entropy_regularization: 2.0e-3
#     entropy_regularization_decay: 0.3
#     update_episodes: 500
#     batch_size: 400
#     minimum_episodes: 10000
#     maximum_episodes: 500000
#     epochs: 1
#     num_batchers: 7
#     eval_rate: 0.1
#     worker:
#         num_parallel: 4
#     lambda: 0.7
#     policy_target: 'TD' # 'UPGO' 'VTRACE' 'TD' 'MC'
#     value_target: 'TD' # 'VTRACE' 'TD' 'MC'
#     eval:
#         opponent: ['random']
#     seed: 0
#     restart_epoch: 0
#
# worker_args:
#     server_address: ''
#     num_parallel: 16

# %%
# training from scratch
# !python main.py --train

# %%
# %%writefile config.yaml
#
#
# env_args:
#     env: 'HungryGeese'
#
# train_args:
#     model_type: geese
#     turn_based_training: False
#     observation: False
#     gamma: 0.8
#     forward_steps: 32
#     compress_steps: 4
#     entropy_regularization: 2.0e-3
#     entropy_regularization_decay: 0.3
#     update_episodes: 500
#     batch_size: 400
#     minimum_episodes: 10000
#     maximum_episodes: 500000
#     epochs: 1501
#     num_batchers: 7
#     eval_rate: 0.1
#     worker:
#         num_parallel: 4
#     lambda: 0.7
#     policy_target: 'TD' # 'UPGO' 'VTRACE' 'TD' 'MC'
#     value_target: 'TD' # 'VTRACE' 'TD' 'MC'
#     eval:
#         opponent: ['random']
#     seed: 0
#     restart_epoch: 1500
#
# worker_args:
#     server_address: ''
#     num_parallel: 16

# %%
# training from checkpoint
# !python main.py --train
