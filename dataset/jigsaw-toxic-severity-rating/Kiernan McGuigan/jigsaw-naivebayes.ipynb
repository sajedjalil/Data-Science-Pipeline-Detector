# %% [markdown]
# # Imports

# %%
# base imports
import os
import numpy as np
import pandas as pd

# text cleaning imports
from bs4 import BeautifulSoup
import re
import nltk

# ml imports
import tensorflow as tf
from tensorflow.keras import callbacks, models, layers
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB, GaussianNB

# tokenization
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# bag of words
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import Binarizer

# visualizations
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
MAX_WORDS = 25_000

nltk.download('stopwords')
from nltk.corpus import stopwords

# %% [markdown]
# # Create train data
#
# The competition was multioutput
#
# We turn it into a binary toxic/ no-toxic classification

# %%
df = pd.read_csv("../input/jigsaw-toxic-comment-classification-challenge/train.csv")
df['y'] = (df[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']].sum(axis=1) > 0 ).astype(int)
df = df[['comment_text', 'y']].rename(columns={'comment_text': 'text'})
df.sample(5)

# %% [markdown]
# # Undersample
#
# The dataset is very unbalanced. Here we undersample the majority class. Other strategies might work better.

# %%
min_len = (df['y'] == 1).sum()
df_y0_undersample = df[df['y'] == 0].sample(n=min_len, random_state=201)
df = pd.concat([df[df['y'] == 1], df_y0_undersample])
df['y'].value_counts()

# %% [markdown]
# # transform the data

# %%
# stop_words = stopwords.words("english")
# vectorizer = CountVectorizer(analyzer = "word",
#                              tokenizer = None,
#                              preprocessor = None,
#                              stop_words = None,
#                              max_features = 5000)
# binarizer = Binarizer()

# def clean(comment):
#     clean_html = BeautifulSoup(comment).get_text()
#     clean_non_letters = re.sub("[^a-zA-Z]", " ", clean_html)
#     cleaned_lowercase = clean_non_letters.lower()
#     words = cleaned_lowercase.split()
#     cleaned_words = [w for w in words if w not in stop_words]
#     return " ".join(cleaned_words)
    
# df['cleaned'] = df['text'].apply(clean)
# X = vectorizer.fit_transform(df.cleaned)
# X = binarizer.fit_transform(X).toarray()
# y = df.y
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)
# print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)

# %%
vec = TfidfVectorizer()
X = vec.fit_transform(df.text)
y = df.y
print(X.shape, y.shape)

# %%
# vocab = vectorizer.get_feature_names()
# vocab[:20]

# %% [markdown]
# # Gradient boosting

# %%
# test_model = GaussianNB()
# test_model.fit(X_train, y_train)
# pred = test_model.predict(X_val)
# mean_absolute_error(y_val, pred)

# %%
model = MultinomialNB()
model.fit(X, y)
pred = model.predict(X)
mean_absolute_error(y, pred)

# %% [markdown]
# # Validate

# %%
# df_val = pd.read_csv("../input/jigsaw-toxic-severity-rating/validation_data.csv")
# X_less_toxic = binarizer.transform(vectorizer.transform(df_val['less_toxic'].apply(clean))).toarray()
# X_more_toxic = binarizer.transform(vectorizer.transform(df_val['more_toxic'].apply(clean))).toarray()

# %%
df_val = pd.read_csv("../input/jigsaw-toxic-severity-rating/validation_data.csv")
X_less_toxic = vec.transform(df_val['less_toxic'])
X_more_toxic = vec.transform(df_val['more_toxic'])

# %%
p1 = model.predict_proba(X_less_toxic)
p2 = model.predict_proba(X_more_toxic)

# %%
# Validation Accuracy
(p1[:, 1] < p2[:, 1]).mean()

# %% [markdown]
# # Submission

# %%
# df_sub = pd.read_csv("../input/jigsaw-toxic-severity-rating/comments_to_score.csv")
# X_test = binarizer.transform(vectorizer.transform(df_sub['text'].apply(clean))).toarray()
# p3 = model.predict_proba(X_test)

# %%
df_sub = pd.read_csv("../input/jigsaw-toxic-severity-rating/comments_to_score.csv")
X_test = vec.transform(df_sub['text'])
p3 = model.predict_proba(X_test)

# %%
df_sub['score'] = p3[:, 1]

# %%
df_sub['score'].count()

# %%
# 9 comments will fail if compared one with the other
df_sub['score'].nunique()

# %%
df_sub[['comment_id', 'score']].to_csv("submission.csv", index=False)
