# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/kaggle/input/jigsaw-toxic-severity-rating/sample_submission.csv")
df

# %%
df['score'] = df.reset_index()['index']
np.random.seed(42)
df["score"] = np.random.randint(100, 8000, size=(len(df), 2))
df.to_csv("submission.csv", index=False)

# %%
df
