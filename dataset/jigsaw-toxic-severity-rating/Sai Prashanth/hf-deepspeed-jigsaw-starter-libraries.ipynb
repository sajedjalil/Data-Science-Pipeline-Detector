# %%
# !git clone https://github.com/kootenpv/contractions.git
# !git clone https://github.com/kootenpv/textsearch.git
# !git clone https://github.com/WojciechMula/pyahocorasick.git
# !wget https://files.pythonhosted.org/packages/6d/7b/19437c9a5bd16e1bb3a5bf43f7655e341882befceae0122e43c8e2c21e1e/anyascii-0.3.0-py3-none-any.whl
from transformers import RobertaTokenizer,RobertaModel
tokenizer = RobertaTokenizer.from_pretrained('roberta-large')
model = RobertaModel.from_pretrained('roberta-large')

# %%
model.save_pretrained('./tokenizer/')
tokenizer.save_pretrained('./tokenizer/')
