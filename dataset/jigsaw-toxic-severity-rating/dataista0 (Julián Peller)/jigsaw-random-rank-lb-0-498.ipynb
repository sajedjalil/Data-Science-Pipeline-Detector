# %% [markdown]
# # ☣️ Jigsaw - Random rank

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/jigsaw-toxic-severity-rating/sample_submission.csv")
df

# %%
df['score'] = df.reset_index()['index'].sample(frac=1, random_state=2021)
df.to_csv("submission.csv", index=False)
