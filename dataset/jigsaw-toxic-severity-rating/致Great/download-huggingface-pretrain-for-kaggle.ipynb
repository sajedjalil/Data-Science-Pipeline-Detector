# %% [markdown]
# **When you see the model you want to use and train on the huggingface, you can download and save it to kaggledatasets through git**

# %% [markdown]
# ## 1：install `git-lfs`

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh |  bash
# !apt-get install -y --allow-unauthenticated git-lfs

# %% [markdown]
# ## 2:download pretrain models

# %%
# !git lfs install
# !git clone https://huggingface.co/xlnet-base-cased
# if you want to clone without large files – just their pointers
# prepend your git clone with the following env var:
# !GIT_LFS_SKIP_SMUDGE=1

# %% [markdown]
# **Now you can use output for no network kernel!**
