# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
test=pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')
train=pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
sample_sbmn=pd.read_csv('../input/house-prices-advanced-regression-techniques/sample_submission.csv')

# %%
train.head()

# %%
train.shape

# %%
train.info()

# %%
with open ('../input/house-prices-advanced-regression-techniques/data_description.txt','r') as f:
    print(f.read())

# %%
train.corr()['SalePrice'].sort_values()

# %%
sns.scatterplot(data=train,x='OverallQual',y='SalePrice')

# %%
sns.scatterplot(data=train,x='OverallQual',y='SalePrice')
plt.axhline(y=200000, color='r')

# %%
train[(train['OverallQual']>8)&(train['SalePrice']<200000)]

# %%
sns.scatterplot(data=train,x='GrLivArea',y='SalePrice')

# %%
sns.scatterplot(data=train,x='GrLivArea',y='SalePrice')
plt.axhline(y=200000,color='r')
plt.axvline(x=4000,color='r')

# %%
train[(train['GrLivArea']>4000)&(train['SalePrice']<200000)]

# %%
index_drop=train[(train['GrLivArea']>4000)&(train['SalePrice']<200000)].index

# %%
train=train.drop(index_drop,axis=0)

# %%
sns.scatterplot(data=train,x='OverallQual',y='SalePrice')
plt.axhline(y=200000, color='r')

# %%
sns.scatterplot(data=train,x='GrLivArea',y='SalePrice')
plt.axhline(y=200000,color='r')
plt.axvline(x=4000,color='r')

# %%
sns.boxplot(data=train,x='OverallQual',y='SalePrice')

# %% [markdown]
# * missing data

# %%
train=train.drop('Id',axis=1)

# %%
train.isnull()

# %%
train.isnull().sum()

# %%
(train.isnull().sum()/len(train))*100

# %%
def missing_percent (train):
    nan_percent=(train.isnull().sum()/len(train))*100
    nan_percent=nan_percent[nan_percent>0].sort_values()
    return nan_percent

# %%
nan_percent=missing_percent(train)
nan_percent

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)
plt.ylim(0,1)

# %%
nan_percent[nan_percent<1]

# %%
train[train['Electrical'].isnull()]

# %%
train[train['GarageArea'].isnull()]

# %%
train=train.dropna(subset=['Electrical', 'GarageArea'],axis=0)

# %%
nan_percent=missing_percent(train)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)
plt.ylim(0,1)

# %%
train[train['BsmtFinSF1'].isnull()]

# %%
train[train['BsmtHalfBath'].isnull()]

# %%
train[train['BsmtFullBath'].isnull()]

# %%
bsmt_str_cols= ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
train[bsmt_str_cols]= train[bsmt_str_cols].fillna('None')

# %%
nan_percent=missing_percent(train)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)
plt.ylim(0,1)

# %%
train['MasVnrType']= train['MasVnrType'].fillna("None")
train['MasVnrArea']= train['MasVnrArea'].fillna(0)

# %%
nan_percent=missing_percent(train)

plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)

# %%
nan_percent[nan_percent>80]

# %%
train=train.drop(['Fence', 'Alley', 'MiscFeature','PoolQC'], axis=1)

# %%
nan_percent=missing_percent(train)

plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)

# %%
nan_percent[nan_percent>0]

# %%
Gar_str_cols= ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
train[Gar_str_cols]=train[Gar_str_cols].fillna('None')

train['GarageYrBlt']=train['GarageYrBlt'].fillna(0)

# %%
nan_percent=missing_percent(train)

plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)

# %%
train['FireplaceQu']= train['FireplaceQu'].fillna('None')

# %%
nan_percent=missing_percent(train)

plt.figure(figsize=(12,6))
sns.barplot(x=nan_percent.index , y=nan_percent)
plt.xticks(rotation=90)

# %%
train.columns

# %%
train['LotFrontage']

# %%
train['Neighborhood']

# %%
plt.figure(figsize=(8,12))
sns.boxplot(data=train, x='LotFrontage', y='Neighborhood')

# %%
train.groupby('Neighborhood')['LotFrontage'].mean()

# %%
train.groupby('Neighborhood')['LotFrontage'].transform(lambda val: val.fillna(val.mean()))

# %%
train['LotFrontage']=train.groupby('Neighborhood')['LotFrontage'].transform(lambda val: val.fillna(val.mean()))

# %%
nan_percent=missing_percent(train)

# %%
train.head()

# %%
train.info()

# %%
train['MSSubClass']=train['MSSubClass'].apply(str)
train['LotArea']=train['LotArea'].apply(str)
train['OverallQual']=train['OverallQual'].apply(str)
train['OverallCond']=train['OverallCond'].apply(str)
train['YearBuilt']=train['YearBuilt'].apply(str)
train['YearRemodAdd']=train['YearRemodAdd'].apply(str)
train['BsmtFinSF1']=train['BsmtFinSF1'].apply(str)
train['BsmtFinSF2']=train['BsmtFinSF2'].apply(str)
train['BsmtUnfSF']=train['BsmtUnfSF'].apply(str)
train['TotalBsmtSF']=train['TotalBsmtSF'].apply(str)
train['1stFlrSF']=train['1stFlrSF'].apply(str)
train['2ndFlrSF']=train['2ndFlrSF'].apply(str)
train['LowQualFinSF']=train['LowQualFinSF'].apply(str)
train['GrLivArea']=train['GrLivArea'].apply(str)
train['BsmtFullBath']=train['BsmtFullBath'].apply(str)
train['BsmtHalfBath']=train['BsmtHalfBath'].apply(str)
train['FullBath']=train['FullBath'].apply(str)
train['HalfBath']=train['HalfBath'].apply(str)
train['BedroomAbvGr']=train['BedroomAbvGr'].apply(str)
train['KitchenAbvGr']=train['KitchenAbvGr'].apply(str)
train['TotRmsAbvGrd']=train['TotRmsAbvGrd'].apply(str)
train['Fireplaces']=train['Fireplaces'].apply(str)
train['GarageCars']=train['GarageCars'].apply(str)
train['GarageArea']=train['GarageArea'].apply(str)
train['WoodDeckSF']=train['WoodDeckSF'].apply(str)
train['OpenPorchSF']=train['OpenPorchSF'].apply(str)
train['EnclosedPorch']=train['EnclosedPorch'].apply(str)
train['3SsnPorch']=train['3SsnPorch'].apply(str)
train['ScreenPorch']=train['ScreenPorch'].apply(str)
train['PoolArea']=train['PoolArea'].apply(str)
train['YrSold']=train['YrSold'].apply(str)
train['YrSold']=train['YrSold'].apply(str)
train['SalePrice']=train['SalePrice'].apply(str)
train['MiscVal']=train['MiscVal'].apply(str)
train['MoSold']=train['MoSold'].apply(str)

# %%
train.info()

# %%
train_num=train.select_dtypes(exclude='object')
train_obj=train.select_dtypes(include='object')

# %% [raw]
# df_num=df.select_dtypes(exclude='object')
# df_obj=df.select_dtypes(include='object')

# %%
train_num.info()

# %%
train_obj.info()

# %%
train_obj=pd.get_dummies(train_obj, drop_first=True)

# %%
train_obj.shape

# %%
train_num.shape

# %%
final_train=pd.concat([train_num , train_obj], axis=1)

# %%
final_train.shape
