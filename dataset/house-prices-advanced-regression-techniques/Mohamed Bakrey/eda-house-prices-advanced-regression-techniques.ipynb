# %% [markdown]
# ![iamge](data:image/jpeg;base64,...)

# %% [markdown]
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRo6krgBihsYXYqSLNZvKXSW9SeXM95VbYiWw&usqp=CAU)

# %% [markdown]
# <h2 style="background-color:Tomato;"><center>Introduction</center></h2>
#
#
# **Everybody needs a roof over their heads. It can be a house, a villa, or a flat. Everybody, at some point in life, faces a choice whether to buy a house, and if so, which one. And why are they so expensive?**
#
# **The topic of real estate is not only the topic you just have to deal with. It can also be very interesting. There are plenty of TV Shows, for instance, Property Brothers, of which plot is based on examples of people buying and renovating houses. This particular one is the most famous in the world and has been running already for almost a decade. For many people houses are also an investment that generates profits.**

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# <h2 style="background-color:Tomato;"><center>Imoport some of library</center></h2>

# %%
train_df=pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
test_df=pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')

# %% [markdown]
# **work on train date**

# %%
train_df.head(10)

# %%
train_df.info()

# %%
print("Columns in original dataset: %d \n" % train_df.shape[1])
print("Columns with na's dropped: %d" % train_df.shape[1])

# %% [markdown]
# # clean data

# %%
columns_with_na_dropped = train_df.dropna(axis=1)
columns_with_na_dropped.head()

# %%
train_df.drop(['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','SaleCondition']
         , axis=1,inplace=True)

# %%
train_df.head(5)

# %%
columns_with_na_dropped = train_df.dropna(axis=1)
columns_with_na_dropped.head()

# %%
train_df.drop(['Neighborhood','Condition1','Condition2','BldgType','HouseStyle','SaleType']
         , axis=1,inplace=True)

# %%
train_df.columns

# %%
train_df.head(4)

# %%
columns_with_na_dropped = train_df.dropna(axis=1)
columns_with_na_dropped.head()

# %%
train_df.drop(['RoofStyle','RoofMatl','Exterior1st']
         , axis=1,inplace=True)

# %%
train_df.head(5)

# %%
columns_with_na_dropped = train_df.dropna(axis=1)
columns_with_na_dropped.head()

# %%
train_df.drop(['Exterior2nd','ExterQual','ExterCond']
         , axis=1,inplace=True)

# %%
train_df.head(5)

# %%
columns_with_na_dropped = train_df.dropna(axis=1)
columns_with_na_dropped.head()

# %%
train_df.drop(['Foundation']
         , axis=1,inplace=True)

# %%
train_df.head(5)

# %%
columns_with_na_dropped = train_df.dropna(axis=1)
columns_with_na_dropped.head()

# %%
# get the number of missing data points per column
missing_values_count = train_df.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:10]
#train_df.isnull()

# %%
# how many total missing values do we have?
total_cells = np.product(train_df.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)

# %%
train_df.isnull()

# %%
train_df.dropna( axis=1, inplace=False)

# %%
train_df.head(10).plot.line(title='train data')

# %%
train_df['LotArea'].plot.hist()

# %%
train_df.head(10)['LotArea'].value_counts().sort_index().plot.bar()

# %%
sns.scatterplot(x='OverallQual', y='OverallCond', data=train_df)

# %%
test_df

# %%
test_df.dropna( axis=1, inplace=False)

# %%
# As you can see there is no labels in data
plt.scatter(test_df['MSSubClass'],test_df['LotFrontage'])
plt.xlabel('pelvic_radius')
plt.ylabel('degree_spondylolisthesis')
plt.show()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(train_df, test_size = 0.3)# in this our main data is split into train and test
# the attribute test_size=0.3 splits the data into 70% and 30% ratio. train=70% and test=30%
print(train.shape)
print(test.shape)

# %%
train_df.columns

# %%
train_X = train[['Id','MSSubClass','OverallQual','LotArea']]# taking the training data features
train_y=train.SalePrice# output of our training data
test_X= test[['BsmtFinSF2','Electrical','GarageCars','OpenPorchSF']] # taking test data features
test_y =test.SalePrice   #output value of test data

# %%
train_X

# %%
test_X

# %%
train_df

# %%
plt.scatter(x = train_df['GrLivArea'], y = train_df['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('GrLivArea (Above grade "ground" living area square feet)')

# %%
plt.scatter(x = train_df['OverallQual'], y = train_df['MoSold'])
plt.ylabel('SalePrice')
plt.xlabel('GrLivArea (Above grade "ground" living area square feet)')

# %%
plt.scatter(x = train_df['GrLivArea'], y = train_df['MSSubClass'])
plt.ylabel('SalePrice')
plt.xlabel('GrLivArea (Above grade "ground" living area square feet)')

# %%
# remove GarageArea outliers
train = train[train['GarageArea'] < 1200]

# %%
train.dropna( axis=1, inplace=False)
