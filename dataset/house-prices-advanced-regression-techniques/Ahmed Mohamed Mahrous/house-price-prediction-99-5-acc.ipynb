# %% [markdown]
# <p style = "font-size : 42px; color : 	#D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>EDA & prediction House price</strong></p>

# %% [markdown]
# <img src="https://pangeamortgages.com/wp-content/uploads/2020/12/What-Makes-House-Prices-Go-Up-Or-Down1.png" alt="What Makes House Prices Go Up Or Down? - Pangea Mortgages" jsname="HiaYvf" jsaction="load:XAeZkd;" class="n3VNCb" data-noaft="1" style="margin-left: 5%; float: center;  border:5px solid ; width:90%; height : 100%;">

# %% [markdown]
# <a id = '0.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Table of Contents</strong></p>
#
# * [Info about data](#1.0)
# * [Importing libraries](#2.0)
# * [Importing dataset](#3.0)
# * [Preparing data for Analysis & Modelling](#4.0)
# * [Extract Numerical & Categorical Features](#5.0)
# * [Checking for null values](#6.0)
# * [delete data duplicated](#7.0)
# * [check co-relation in data](#8.0)
# * [Exploratory Data Analysis (EDA)](#9.0)
# * [Separate dependent & independent features](#10.0)
# * [convert categorical variable into dummy](#11.0)
# * [Feature Selection by KBest](#12.0)
#
# * [Defining function For ML models](#13.0)
#     * [Random Forest Algorithm](#11.0)
#     * [Gradient Boosting](#12.0)
#     * [Linear Regression Algorithm](#13.0)
#     * [Lasso Algorithm](#15.0)
#     * [Ridge Algorithm](#16.0)
#     * [K-Neighbors Algorithm](#17.0)
#     * [Decision Tree Algorithm](#18.0)

# %% [markdown]
# <a id = '1.0'></a>
# <p style = "font-size : 42px; color : 	#D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Info about data</strong></p>

# %% [markdown]
# ####    Link            https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# ###   description of each column
# * SalePrice - the property's sale price in dollars. This is the target variable that you're trying to * * predict.
# * MSSubClass: The building class
# * MSZoning: The general zoning classification
# * LotFrontage: Linear feet of street connected to property
# * LotArea: Lot size in square feet
# * Street: Type of road access
# * Alley: Type of alley access
# * LotShape: General shape of property
# * LandContour: Flatness of the property
# * Utilities: Type of utilities available
# * LotConfig: Lot configuration
# * LandSlope: Slope of property
# * Neighborhood: Physical locations within Ames city limits
# * Condition1: Proximity to main road or railroad
# * Condition2: Proximity to main road or railroad (if a second is present)
# * BldgType: Type of dwelling
# * HouseStyle: Style of dwelling
# * OverallQual: Overall material and finish quality
# * OverallCond: Overall condition rating
# * YearBuilt: Original construction date
# * YearRemodAdd: Remodel date
# * RoofStyle: Type of roof
# * RoofMatl: Roof material
# * Exterior1st: Exterior covering on house
# * Exterior2nd: Exterior covering on house (if more than one material)
# * MasVnrType: Masonry veneer type
# * MasVnrArea: Masonry veneer area in square feet
# * ExterQual: Exterior material quality
# * ExterCond: Present condition of the material on the exterior
# * Foundation: Type of foundation
# * BsmtQual: Height of the basement
# * BsmtCond: General condition of the basement
# * BsmtExposure: Walkout or garden level basement walls
# * BsmtFinType1: Quality of basement finished area
# * BsmtFinSF1: Type 1 finished square feet
# * BsmtFinType2: Quality of second finished area (if present)
# * BsmtFinSF2: Type 2 finished square feet
# * BsmtUnfSF: Unfinished square feet of basement area
# * TotalBsmtSF: Total square feet of basement area
# * Heating: Type of heating
# * HeatingQC: Heating quality and condition
# * CentralAir: Central air conditioning
# * Electrical: Electrical system
# * 1stFlrSF: First Floor square feet
# * 2ndFlrSF: Second floor square feet
# * LowQualFinSF: Low quality finished square feet (all floors)
# * GrLivArea: Above grade (ground) living area square feet
# * BsmtFullBath: Basement full bathrooms
# * BsmtHalfBath: Basement half bathrooms
# * FullBath: Full bathrooms above grade
# * HalfBath: Half baths above grade
# * Bedroom: Number of bedrooms above basement level
# * Kitchen: Number of kitchens
# * KitchenQual: Kitchen quality
# * TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# * Functional: Home functionality rating
# * Fireplaces: Number of fireplaces
# * FireplaceQu: Fireplace quality
# * GarageType: Garage location
# * GarageYrBlt: Year garage was built
# * GarageFinish: Interior finish of the garage
# * GarageCars: Size of garage in car capacity
# * GarageArea: Size of garage in square feet
# * GarageQual: Garage quality
# * GarageCond: Garage condition
# * PavedDrive: Paved driveway
# * WoodDeckSF: Wood deck area in square feet
# * OpenPorchSF: Open porch area in square feet
# * EnclosedPorch: Enclosed porch area in square feet
# * 3SsnPorch: Three season porch area in square feet
# * ScreenPorch: Screen porch area in square feet
# * PoolArea: Pool area in square feet
# * PoolQC: Pool quality
# * Fence: Fence quality
# * MiscFeature: Miscellaneous feature not covered in other categories
# * MiscVal: $Value of miscellaneous feature
# * MoSold: Month Sold
# * YrSold: Year Sold
# * SaleType: Type of sale
# * SaleCondition: Condition of sale

# %% [markdown]
# <a id = '2.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Importing libraries</strong></p>

# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2 , f_classif
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')

# %% [markdown]
# <a id = '3.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Importing dataset </strong></p>

# %%
train = pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
test = pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')

# %% [markdown]
# <a id = '4.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Preparing data for Analysis & Modelling</strong></p>

# %%
train.head()

# %%
test.head()

# %%
print(train.shape)
print('-'*50)
print(test.shape)

# %% [markdown]
# * The described method will help to see how data has been spread for numerical values.
# * We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %%
print('Train.describe')
train.describe().T

# %%
print('Test.describe')
test.describe().T

# %%
data = pd.concat([train, test],axis=0,sort=False)

# %% [markdown]
#  <a id = '5.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Extract Numerical & Categorical Features</strong></p>

# %%
num_features=[col for col in train.columns if train[col].dtype!='O']
num_features

# %%
cat_features=[col for col in train.columns if train[col].dtype=='O']
cat_features

# %% [markdown]
#  <a id = '6.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Checking for null values</strong></p>

# %%
null = pd.DataFrame({'Null Values' : data.isna().sum().sort_values(ascending=False), 'Percentage Null Values' : (data.isna().sum().sort_values(ascending=False)) / (data.shape[0]) * (100)})
null

# %%
null_counts = data.isna().sum().sort_values(ascending=False)/len(data)
plt.figure(figsize=(16,8))
plt.xticks(np.arange(len(null_counts))+0.5,null_counts.index,rotation='vertical')
plt.ylabel('fraction of rows with missing data')
plt.bar(np.arange(len(null_counts)),null_counts)

# %% [markdown]
# * I will drop [`PoolQC`, `MiscFeature`, `Alley`, `Fence`] column because it has above 90% of missing values¶

# %%
data.drop(["PoolQC","MiscFeature","Alley","Fence"],axis=1,inplace=True)

# %%
data = data.copy()

# %% [markdown]
# * I Clean missing values using Random Value Imputation Because This the best way to To maintain distrbuation For each feature.

# %%
### lets create a function so that I can easily do it for all features
def Random_value_imputation(feature):
    random_sample=data[feature].dropna().sample(data[feature].isnull().sum())               
    random_sample.index=data[data[feature].isnull()].index
    data.loc[data[feature].isnull(),feature]=random_sample

# %%
for col in data:
    Random_value_imputation(col)

# %%
null_counts = data.isna().sum().sort_values(ascending=False)/len(data)
plt.figure(figsize=(16,8))
plt.xticks(np.arange(len(null_counts))+0.5,null_counts.index,rotation='vertical')
plt.ylabel('fraction of rows with missing data')
plt.bar(np.arange(len(null_counts)),null_counts)

# %% [markdown]
# * Total unique categories in our categorical features to check if any dirtiness in data or not

# %%
for col in cat_features:
    print('{} has {} values '.format(col,train[col].unique()))
    print('\n')

# %%
data.columns

# %% [markdown]
# <a id = '7.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>delete data duplicated</strong></p>

# %%
duplicate = data.duplicated()
print(duplicate.sum())

# %% [markdown]
# * Threre is no data duplicated

# %% [markdown]
#  <a id = '8.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>check co-relation in data</strong></p>

# %%
co_relation=data.corr()
co_relation

# %%
co_relation=pd.DataFrame(data.corr()["SalePrice"]) 
co_relation

# %%
plt.rcParams['figure.figsize'] = (30, 15)
corr_df = data.corr()
sns.heatmap(corr_df,annot=True , cmap="YlGnBu")

# %% [markdown]
# <a id = '9.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Exploratory Data Analysis (EDA)</strong></p>

# %%
plt.rcParams['figure.figsize'] = (50, 10)
for i,col in enumerate(num_features):
    plt.subplot(2,20,i+1)
    sns.boxplot(data[col], color = '#CD853F')

# %% [markdown]
# * Analysing Distributions of data

# %%
plt.figure(figsize=(200,200))
for i,feature in enumerate(num_features):
    plt.subplot(5,9,i+1 , facecolor='#ADD8E6' )
    data[feature].hist()
    plt.title(feature)

# %%
#scatterplot
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(data[cols], size = 2.5 , palette = 'seaborn')
plt.show();

# %%
plt.rcParams['figure.figsize'] = (30, 15)
sns.catplot(x = data['SalePrice'] ,data = data.sort_values('SalePrice',ascending=False),kind='swarm' , color = 'g')

# %% [markdown]
# * Empirical Cumulative Distribution Functions for `SalePrice`

# %%
sd1 = np.sort(data['SalePrice'])
cdf = np.linspace(1/data['SalePrice'].size, 1, data['SalePrice'].size)

plt.plot(sd1, cdf, label="SalePrice CDF"  )
plt.hist(data['SalePrice'], histtype="step", density=True, alpha=0.3 )
plt.legend();

# %% [markdown]
# * I will build an important functions that we'll need , to know the relationship & the correlations between features & each other

# %%
# Defining violin and scatter plot & kde_plot functions¶

def violin(col):
    plt.rcParams['figure.figsize'] = (10, 8)
    fig = px.violin(data, y=col, box = True , color='#D2691E',)
    return fig.show()

def scatters(col1,col2):
    plt.rcParams['figure.figsize'] = (10, 8)
    fig = px.scatter(data, x=col1, y=col2 )
    return fig.show()

def make_kdeplot(feature) : 
    plt.rcParams['figure.figsize'] = (10, 8)
    sns.kdeplot(data[feature], shade=True)

# %%
px.violin(data,y='YearBuilt')

# %%
make_kdeplot('SalePrice')

# %%
make_kdeplot('YearBuilt')

# %%
make_kdeplot('TotalBsmtSF')

# %%
make_kdeplot('GrLivArea')

# %%
px.violin(data,y='SalePrice')

# %%
px.violin(data,y='FullBath')

# %%
px.violin(data,y='BedroomAbvGr')

# %%
px.violin(data,y='KitchenAbvGr')

# %%
px.violin(data,y='TotRmsAbvGrd')

# %%
scatters('TotalBsmtSF','SalePrice')

# %%
scatters('EnclosedPorch','SalePrice')

# %%
scatters('OpenPorchSF','SalePrice')

# %%
scatters('WoodDeckSF','SalePrice')

# %% [markdown]
# <a id = '11.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>convert categorical variable into dummy</strong></p>

# %%
data = pd.get_dummies(data)

# %%
data.head()

# %% [markdown]
# <a id = '10.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Separate dependent & independent features</strong></p>

# %%
y=data['SalePrice']
X=data.drop('SalePrice',axis=1)
cols=X.columns
cols

# %%
#Splitting data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

# %%
#Splitted Data
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)

# %%
print('Original X Shape is ' , X.shape)

# %% [markdown]
# <a id = '12.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Feature Selection by KBest</strong></p>

# %%
FeatureSelection = SelectKBest(score_func= chi2 ,k=40) # score_func can = f_classif 
X = FeatureSelection.fit_transform(X, y)

# %%
#showing X Dimension 
print('X Shape is ' , X.shape)
print('Selected Features are : ' , FeatureSelection.get_support())

# %% [markdown]
# <a id = '13.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Defining function For ML models</strong></p>

# %%
def predict(ml_model):          
    model=ml_model.fit(X_train,y_train)
    print('Training score : {}'.format(model.score(X_train,y_train)))
    y_prediction=model.predict(X_test)
    print('predictions are: \n {}'.format(y_prediction[:10]))
    print('\n')
    r2_score=metrics.r2_score(y_test,y_prediction)
    print('r2 score: {}'.format(r2_score))
    print('MAE:',metrics.mean_absolute_error(y_test,y_prediction))
    print('MSE:',metrics.mean_squared_error(y_test,y_prediction))
    print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_prediction)))
    sns.distplot(y_test-y_prediction)

# %% [markdown]
# <a id = '11.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Random Forest Algorithm</strong></p>

# %%
predict(RandomForestRegressor(ccp_alpha=0.1,n_estimators=50, max_depth = 70))

# %% [markdown]
# <a id = '12.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Gradient Boosting</strong></p>

# %%
predict(GradientBoostingRegressor(alpha=.9 , n_estimators=12,learning_rate=0.5, max_depth=12))

# %% [markdown]
# <a id = '13.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Linear Regression Algorithm</strong></p>

# %%
predict(LinearRegression())

# %% [markdown]
# <a id = '15.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Lasso Algorithm</strong></p>

# %%
predict(Lasso(max_iter=20,alpha=2))

# %% [markdown]
# <a id = '16.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Ridge Algorithm</strong></p>

# %%
predict(Ridge(solver='auto',alpha=0.5,  max_iter=12))

# %% [markdown]
# <a id = '17.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>K-Neighbors Algorithm</strong></p>

# %%
predict(KNeighborsRegressor(n_neighbors=3,
   
    weights='distance',
    algorithm='ball_tree',
    leaf_size=40,
    p=4,
    metric='minkowski',
    metric_params=None,
    n_jobs=None,))

# %% [markdown]
# <a id = '18.0'></a>
# <p style = "font-size : 35px; color : #D2691E ; font-family : 'Comic Sans MS'; text-align : center; background-color : #ffff99; border-radius: 5px 5px;"><strong>Decision Tree Algorithm</strong></p>

# %%
predict(DecisionTreeRegressor(max_depth=25,random_state=33))

# %% [markdown]
# ##  <p style="background-color:#BCDBF9;color:black;font-size:19px;text-align:center;border-radius:12px 10px;border:2px solid blue;">My Github👨‍💻</p>
#
# <a href = "https://github.com/AhmedMMahrous"><img src="https://raw.githubusercontent.com/Potential17/Potential17/master/github-logo-octocat-.gif" alt="alihrhera (Ali Tarek Hrhera) · GitHub" jsname="HiaYvf" jsaction="load:XAeZkd;" class="n3VNCb"  style="margin-left: 40%;  border:5px solid ; width:20%; height : 20%;"></a>
