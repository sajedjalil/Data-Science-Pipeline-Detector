# %% [markdown]
# **The folowing Dataset is about the price of a house in the Us and it Contains 1455 rows and 76 columns.**

# %%
# Import all necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Step2: Import the Dataset
df=pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')

# %%
df.head()

# %%
df.info()

# %%
df.shape

# %%
with open('../input/house-prices-advanced-regression-techniques/data_description.txt','r') as f:
    print(f.read())

# %% [markdown]
# **1- Dealing with Outliers**

# %%
df.corr()['SalePrice'].sort_values()

# %% [markdown]
# # finding outliers:

# %%
sns.scatterplot(data=df,x='OverallQual', y='SalePrice')
plt.axhline(y=200000,color='r')
plt.axhline(y=650000,color='r')

# %%
df[(df['OverallQual']>8) & (df['SalePrice']<200000)][['SalePrice', 'OverallQual']]

# %%
df[(df['OverallQual']>8) & (df['SalePrice']>650000)][['SalePrice', 'OverallQual']]

# %%
sns.scatterplot(data=df,x='GrLivArea', y='SalePrice')
plt.axhline(y=200000, color='r')
plt.axvline(x=4000, color='r')

# %%
df[(df['GrLivArea']>4000) & (df['SalePrice']>200000)][['SalePrice', 'GrLivArea']]

# %%
sns.scatterplot(data=df,x='GarageCars', y='SalePrice')
plt.axhline(y=650000, color='r')

# %%
df[df['SalePrice']>650000][['SalePrice', 'GarageCars']]

# %%
sns.lmplot(x='1stFlrSF',y='SalePrice',data=df)

# %%
#Remove the outliers:
index_drop=df[df['SalePrice']>650000 ].index
df=df.drop(index_drop, axis=0)
index_drop1=df[(df['OverallQual']>8) & (df['SalePrice']<200000)].index
df=df.drop(index_drop1, axis=0)

# %%
df.corr()['SalePrice'].sort_values()

# %% [markdown]
# we can see with removing outliers corrolations get improved.

# %% [markdown]
# **2-Dealing with Missing Data**

# %%
df=df.drop('Id',axis=1)

# %%
#number of missing Data in each columns:
df.isnull().sum().sort_values()

# %%
#The percent of missing data in any feature:
100*(df.isnull().sum()/len(df)).sort_values()

# %%
#Make a Function to calculate the percent of missing data in each columns (feature) and then sort it
def missing_percent(df):
    nan_percent= 100*(df.isnull().sum()/len(df))
    nan_percent= nan_percent[nan_percent>0].sort_values()
    return nan_percent

# %%
nan_percent= missing_percent(df)
nan_percent

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)
#Set 1% threshold:
plt.ylim(0,1)

# %%
#columns with missing Data under 1%:
nan_percent[nan_percent<1]

# %%
100/len(df)

# %% [markdown]
# It shows Electrical has got just 1 row missing Data.

# %%
#The index of a row with missing Data of Electrical:
df[df['Electrical'].isnull()]['Electrical']

# %%
#removing the row with missing Data of Electrical:
df=df.dropna(axis=0, subset=['Electrical'])

# %%
nan_percent= missing_percent(df)
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)
#Set 1% threshold:
plt.ylim(0,1)

# %%
#filling a missing Data with 0 for integer feature and None for object one:
df['MasVnrType']= df['MasVnrType'].fillna('None')
df['MasVnrArea']= df['MasVnrArea'].fillna(0)

# %%
nan_percent= missing_percent(df)
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)

# %%
bsm=['BsmtQual','BsmtCond','BsmtFinType1','BsmtExposure','BsmtFinType2']
for i in bsm:
    print(type(i))

# %%
df[bsm]=df[bsm].fillna('None')

# %%
nan_percent= missing_percent(df)
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)

# %%
garage=['GarageType','GarageFinish','GarageQual','GarageCond']
df[garage]=df[garage].fillna('None')

# %%
#replace the amount of missing Data with mean of the GarageYrBlt:
df['GarageYrBlt']=df['GarageYrBlt'].fillna(value=df['GarageYrBlt'].mean())

# %%
nan_percent= missing_percent(df)
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(8,12))
sns.boxplot(data=df, x='LotFrontage', y='Neighborhood')

# %%
df.groupby('Neighborhood')['LotFrontage'].mean()

# %%
df['LotFrontage']=df.groupby('Neighborhood')['LotFrontage'].transform(lambda val: val.fillna(val.mean()))

# %%
nan_percent= missing_percent(df)
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)

# %%
df['FireplaceQu']= df['FireplaceQu'].fillna('None')

# %%
nan_percent= missing_percent(df)
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(x=nan_percent.index,y=nan_percent)
plt.xticks(rotation=90)

# %%
df=df.drop(['Fence','Alley','MiscFeature','PoolQC'],axis=1)

# %%
nan_percent= missing_percent(df)
nan_percent

# %% [markdown]
# There is no more missing Data

# %% [markdown]
# **3-Dealing with Categorical Data**

# %%
# A- Changing Numerical Columns to Categorical
df['MSSubClass']

# %%
df.info()

# %%
df['MSSubClass'].unique()

# %%
#Convert to String:
df['MSSubClass']= df['MSSubClass'].apply(str)

# %%
df.info()
#or: df['MSSubClass'].dtype

# %%
# B- Creating Dummy Variables:
df.select_dtypes(include='object')

# %%
df_num= df.select_dtypes(exclude='object')
df_obj= df.select_dtypes(include='object')

# %%
df_num.info()

# %%
df_obj.info()

# %%
# Converting:
df_obj= pd.get_dummies(df_obj, drop_first=True)

# %%
df_obj.shape

# %%
Final_df= pd.concat([df_num, df_obj], axis=1)
Final_df.head()

# %% [markdown]
# # Starting a Linear Regression model

# %%
Final_df.info()

# %%
from scipy.stats import norm
plt.figure(figsize=(12,6))
sns.distplot(Final_df['SalePrice'] , fit=norm);
plt.figure(figsize=(12,6))
sns.distplot(Final_df['SalePrice'],color='purple',hist_kws=dict(edgecolor='pink',linewidth=5,),bins=50)
plt.axvline(x=(Final_df['SalePrice'].mean()), color='r')

# %% [markdown]
# As you see the sale price value is right skewed. We need to make this normal distributed.

# %%
Final_df['SalePrice'] = np.log1p(Final_df['SalePrice'])

# %%
from scipy.stats import norm
plt.figure(figsize=(12,6))
sns.distplot(Final_df['SalePrice'] , fit=norm);
plt.figure(figsize=(12,6))
sns.distplot(Final_df['SalePrice'],color='purple',hist_kws=dict(edgecolor='pink',linewidth=5,),bins=50)
plt.axvline(x=(Final_df['SalePrice'].mean()), color='r')

# %% [markdown]
# # Linear Regression
# Let's begin to train out regression model! We will need to first split up our data into an X array that contains the features to train on, and a y array with the target variable, in this case the Price column.

# %%
#Determine the Features & Target Variable
X=Final_df.drop('SalePrice',axis=1)
y=Final_df['SalePrice']

# %%
#Split the Dataset to Train & Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# This time we split Datas to train and test ,building a model on train datas and evaluating the model in test datas.

# %%
#Train the Model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, y_train)
pd.DataFrame(model.coef_ , X.columns ,columns=['coefcient'])

# %%
#predicting Test Data
y_pred= model.predict(X_test)
pd.DataFrame({'Y_Test': y_test,'Y_Pred':y_pred})[:5]

# %% [markdown]
# we predict a y quantity for each y_test data and then compare it with the real value of its label to understand how much the model is aqurated.

# %%
#Evaluating the Model
from sklearn import metrics
MAE_linear=metrics.mean_absolute_error(y_test , y_pred)
MSE_linear=metrics.mean_squared_error(y_test , y_pred)
RMSE_linear=np.sqrt(MSE_linear)
pd.DataFrame([MAE_linear,MSE_linear,RMSE_linear], index=['MAE_linear','MSE_linear','RMSE_linear'],columns=['Quantity'])

# %%
#Residuals:
test_residual=y_test-y_pred
sns.scatterplot(x=y_test,y=y_pred,color='green' ,s=200)
plt.ylabel('y_pred')
plt.xlabel('y_test')
plt.title('bias of y')

# %% [markdown]
# This shows relations are linear.

# %%
sns.scatterplot(x=y_test,y=test_residual,s=200)
plt.axhline(y=0,color='red',ls='--')

# %% [markdown]
# The plot shows intenses are choosed accidently from all parts and doesnt have specific pattern so the model works well.

# %% [markdown]
# # Starting Polynomial Model

# %% [markdown]
# It will be study in the next notebook
