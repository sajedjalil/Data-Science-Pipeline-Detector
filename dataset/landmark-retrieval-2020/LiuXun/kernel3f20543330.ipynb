# %%
from zipfile import ZipFile

with ZipFile('submission.zip','w') as zip:           
  zip.write('../input/landmark2020/gldv2_model_global/saved_model.pb', arcname='saved_model.pb') 
  zip.write('../input/landmark2020/gldv2_model_global/variables/variables.data-00000-of-00001', arcname='variables/variables.data-00000-of-00001') 
  zip.write('../input/landmark2020/gldv2_model_global/variables/variables.index', arcname='variables/variables.index')
