# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Load data...

# %%
train = pd.read_csv("/kaggle/input/tabular-playground-series-feb-2021/train.csv")
test = pd.read_csv("/kaggle/input/tabular-playground-series-feb-2021/test.csv")
sample_submission = pd.read_csv('../input/tabular-playground-series-feb-2021/sample_submission.csv')

# %%
sns.pairplot(train.sample(1000))

# %% [markdown]
# ### Look at data...

# %%
train.tail()

# %%
test.tail()

# %%
sample_submission.tail()

# %% [markdown]
# # Do your stuff...
#
# ### Deleverables
# - EDA
#     - What's going on?
#     - Show me the data...
#     - Bonus: Other / Etc...
# - Model
#     - [RandomForestRegressor()](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
#     - Bonus: [KNeighborsRegressor()](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)
#     - Bonus: Other / Etc...
# - Evaluation
#     - mean_squared_error()
#     - Bonus: Other / Etc...
# - RAPIDS Bonus
#     - Apply RAPIDS ([Starter Notebook](https://www.kaggle.com/tunguz/tps-feb-2021-rapids-starter))
#     - Replace pandas with cuDF & sklearn with cuML

# %% [markdown]
# **EDA and cleaning**

# %%
train.shape

# %%
train.isnull().sum()

# %%
test.isnull().sum()

# %%
train.describe()

# %%
train.describe(exclude='number')

# %%
sns.boxplot(x=train['target'])

# %%
train.loc[train.target<5]

# %%
len(train.loc[train.target<5])/len(train)

# %%
train = train.drop(train[train.target<5].index)

# %%
sns.boxplot(x=train['target'])

# %%
train.loc[train.target>10]

# %%
len(train.loc[train.target>10])/len(train)

# %%
train = train.drop(train[train.target>10].index)

# %%
sns.boxplot(x=train['target'])

# %%
train.loc[train.cont8>0.9]

# %%
len(train.loc[train.cont8>0.9])/len(train)

# %%
train = train.drop(train[train.cont8>0.9].index)

# %%
sns.boxplot(x=train['cont8'])

# %%
len(train.loc[train.cont8>0.8])/len(train)

# %%
train = train.drop(train[train.cont8>0.8].index)

# %%
sns.boxplot(x=train['cont8'])

# %%
train = train.drop(train[train.cont8>0.7].index)

# %%
sns.boxplot(x=train['cont8'])

# %%
len(train.loc[train.cont8<0.1])/len(train)

# %%
train = train.drop(train[train.cont8<0.1].index)

# %%
sns.boxplot(x=train['cont8'])

# %%
1-len(train)/300000

# %%
train.shape

# %%
list(train.columns)

# %%
train.drop(train[['id','cat0',
 'cat1',
 'cat2',
 'cat3',
 'cat4',
 'cat5',
 'cat6',
 'cat7',
 'cat8',
 'cat9']],axis=1,inplace=True)

# %%
test.drop(test[['id','cat0',
 'cat1',
 'cat2',
 'cat3',
 'cat4',
 'cat5',
 'cat6',
 'cat7',
 'cat8',
 'cat9']],axis=1,inplace=True)

# %% [markdown]
# **split**

# %%
from sklearn.model_selection import train_test_split
# select split parameter
x = train.drop(['target'], axis=1)
y = train.target

# %%
x_train, x_test ,y_train , y_test = train_test_split(x,y, test_size=0.7, random_state= 50)

# %% [markdown]
# **Models**

# %% [markdown]
# **Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0)

# %%
regr.fit(x_train, y_train)

# %%
preds = regr.predict(x_test)

# %%
preds[:-5]

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, preds)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test, preds)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, preds)

# %% [markdown]
# **KNeighbors Regressor**

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=3)

# %%
neigh.fit(x_train, y_train)

# %%
pred = neigh.predict(x_test)

# %%
pred[:-5]

# %%
mean_squared_error(y_test, pred)

# %%
mean_absolute_error(y_test, pred)

# %%
r2_score(y_test, pred)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(x_train, y_train)

# %%
pre = lr.predict(x_test)

# %%
pre[:5]

# %%
mean_squared_error(y_test, pre)

# %%
mean_absolute_error(y_test, pre)

# %%
r2_score(y_test, pre)

# %%
test_preds = regr.predict(test)
test_preds

# %%
sample_submission['target'] = test_preds
sample_submission.to_csv('submission.csv', index=False)
