# %%
# %matplotlib inline 

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("../input/tabular-playground-series-feb-2021/train.csv", index_col=1)
test = pd.read_csv("../input/tabular-playground-series-feb-2021/test.csv", index_col=1)
sample_submisson = pd.read_csv("../input/tabular-playground-series-feb-2021/sample_submission.csv", index_col=1)

# %%
train.head(3)

# %%
test.head(3)

# %%
sample_submisson.head(3)

# %%
tips = sns.load_dataset("tips")
tips

# %% [markdown]
# ### stripplot
# + conclusion:
#     + cat1, cat2 might be candiates to for removal?

# %%
sns.set_theme(style="whitegrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.stripplot(x='cat1', y='target',data=train,ax=ax1)
sns.stripplot(x='cat2', y='target',data=train,ax=ax2)
sns.stripplot(x='cat3', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, (ax4,ax5,ax6) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.stripplot(x='cat4', y='target',data=train,ax=ax4)
sns.stripplot(x='cat5', y='target',data=train,ax=ax5)
sns.stripplot(x='cat6', y='target',data=train,ax=ax6)

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, (ax7,ax8,ax9) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.stripplot(x='cat7', y='target',data=train,ax=ax7)
sns.stripplot(x='cat8', y='target',data=train,ax=ax8)
sns.stripplot(x='cat9', y='target',data=train,ax=ax9)

plt.show()

# %% [markdown]
# ### swarmplot

# %%
sns.set_theme(style="darkgrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.boxplot(x='cat1', y='target',data=train,ax=ax1)
sns.boxplot(x='cat2', y='target',data=train,ax=ax2)
sns.boxplot(x='cat3', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="darkgrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.boxplot(x='cat4', y='target',data=train,ax=ax1)
sns.boxplot(x='cat5', y='target',data=train,ax=ax2)
sns.boxplot(x='cat6', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="darkgrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.boxplot(x='cat7', y='target',data=train,ax=ax1)
sns.boxplot(x='cat8', y='target',data=train,ax=ax2)
sns.boxplot(x='cat9', y='target',data=train,ax=ax3)

plt.show()

# %% [markdown]
# ### barplot

# %%
sns.set_theme(style="whitegrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.barplot(x='cat1', y='target',data=train,ax=ax1)
sns.barplot(x='cat2', y='target',data=train,ax=ax2)
sns.barplot(x='cat3', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.barplot(x='cat4', y='target',data=train,ax=ax1)
sns.barplot(x='cat5', y='target',data=train,ax=ax2)
sns.barplot(x='cat6', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.barplot(x='cat7', y='target',data=train,ax=ax1)
sns.barplot(x='cat8', y='target',data=train,ax=ax2)
sns.barplot(x='cat9', y='target',data=train,ax=ax3)

plt.show()

# %% [markdown]
# ### violinplot

# %%
sns.set_theme(style="darkgrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.violinplot(x='cat1', y='target',data=train,ax=ax1)
sns.violinplot(x='cat2', y='target',data=train,ax=ax2)
sns.violinplot(x='cat3', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="darkgrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.violinplot(x='cat4', y='target',data=train,ax=ax1)
sns.violinplot(x='cat5', y='target',data=train,ax=ax2)
sns.violinplot(x='cat6', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="darkgrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.violinplot(x='cat7', y='target',data=train,ax=ax1)
sns.violinplot(x='cat8', y='target',data=train,ax=ax2)
sns.violinplot(x='cat9', y='target',data=train,ax=ax3)

plt.show()

# %% [markdown]
# ### countplot

# %%
sns.set_theme(style="whitegrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.boxenplot(x='cat1', y='target',data=train,ax=ax1)
sns.boxenplot(x='cat2', y='target',data=train,ax=ax2)
sns.boxenplot(x='cat3', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.boxenplot(x='cat4', y='target',data=train,ax=ax1)
sns.boxenplot(x='cat5', y='target',data=train,ax=ax2)
sns.boxenplot(x='cat6', y='target',data=train,ax=ax3)

plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, (ax1, ax2,ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18, 5))

sns.boxenplot(x='cat7', y='target',data=train,ax=ax1)
sns.boxenplot(x='cat8', y='target',data=train,ax=ax2)
sns.boxenplot(x='cat9', y='target',data=train,ax=ax3)

plt.show()
