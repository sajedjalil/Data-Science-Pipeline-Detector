# %% [markdown]
# # Tabular Playground Series February 2021

# %% [markdown]
# I'm attempting to break into the top 100 in the TPS Playground series.
#
# It looks like most people in this group are scoring slightly greater than RMSE = 0.84

# %% [markdown]
# **Version History**
#
# * [Version 1] Starting EDA. Got through the continuous features.

# %% [markdown]
# ## Imports and Reading in Files

# %%
from fastai.tabular.all import *
from sklearn.tree import ExtraTreeRegressor
from sklearn.model_selection import train_test_split
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import datatable as dt
pd.set_option('display.max_columns', 500)

# %%
INPUT_DIR = Path('../input/tabular-playground-series-feb-2021')

# %%
INPUT_DIR.ls()

# %%
train = dt.fread(INPUT_DIR / 'train.csv').to_pandas()
test =  dt.fread(INPUT_DIR / 'test.csv').to_pandas()
sample_submission = dt.fread(INPUT_DIR / 'sample_submission.csv').to_pandas()

# %%
train.head()

# %%
test.head()

# %%
sample_submission.head()

# %%
train.drop('id', axis=1, inplace=True)
test.drop('id', axis=1, inplace=True)

# %% [markdown]
# ## EDA

# %%
CONT_VARS = [f'cont{number}' for number in range(0,14)]
CAT_VARS = [f'cont{number}' for number in range(0,10)]

# %%
corr = train[CONT_VARS].corr()
np.fill_diagonal(corr.values, None)

# %%
fig, ax = plt.subplots(figsize=(13,13))
ax = sns.heatmap(corr, center=0, cmap=sns.diverging_palette(20, 220, n=200), square=True, annot=True,)

# %%
fig = sns.displot(train, x=CONT_VARS[0], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[1], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[2], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[3], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[4], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[5], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[6], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[7], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[8], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[9], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[10], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[11], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[12], kde=True, height=3, aspect=3)

# %%
fig = sns.displot(train, x=CONT_VARS[13], kde=True, height=3, aspect=3)
