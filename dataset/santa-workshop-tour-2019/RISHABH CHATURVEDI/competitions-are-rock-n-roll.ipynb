# %% [markdown]
# The sound track of Kaggle Competitions.

# %% [markdown]
# 1. Metallica - https://www.youtube.com/watch?v=hx27NL_iqEM
# 2. Black Sabbath - https://www.youtube.com/watch?v=0qanF-91aJo
# 3. We re Not Gonna Take it - https://www.youtube.com/watch?v=V9AbeALNVkk
# 4. Living On A Prayer - https://www.youtube.com/watch?v=lDK9QqIzhwk
# 5. Jingle Bell Rock  - https://www.youtube.com/watch?v=VfLf7A_-1Vw
# 6. Do they Know it s Christmas - https://www.youtube.com/watch?v=bjQzJAKxTrE&list=RDbjQzJAKxTrE&start_radio=1&t=42 **FEED THE WORLD**

# %% [markdown]
# That's my gift for the whole Kaggle community.

# %% [markdown]
# Codes (from other users) and Music. I'm just the groupie. Groupies are the audience. Without audience no Band survive.

# %% [markdown]
# **DON’T LET THE GRINCH STEAL CHRISTMAS.**

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNNO-Ce4Gso1jmxF-0HQOxTHvQTehAkBD4xy7ct1x1dlEdiY8a3g&s',width=400,height=400)

# %% [markdown]
# Image: slashfilm.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
fpath = '/kaggle/input/santa-workshop-tour-2019/family_data.csv'
xmas = pd.read_csv(fpath, index_col='family_id')

fpath = '/kaggle/input/santa-workshop-tour-2019/sample_submission.csv'
submission = pd.read_csv(fpath, index_col='family_id')

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS6LUh8H7ZugcClLX0uiZJCh1b0Q-jM-wIErodikAJFJTKIkRFk&s',width=400,height=400)

# %% [markdown]
# Image thetimes.co.uk

# %%
xmas.head()

# %%
xmas.info

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRk1PCSZCtdEe9owoa0AcjTa3UetR5R2FRRmDwAwpPgcb5M-COn&s',width=400,height=400)

# %% [markdown]
# Image theeverygirl.com

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
#  Lamar Jackson - Baltimore Ravens  - Image mercurynews.com

# %% [markdown]
# Indefensible,revolutionary,transcendent. Words to describe Texas Tom Notebook: https://www.kaggle.com/tombresee/next-gen-eda

# %%
f, ax = plt.subplots(figsize=(8,6))
x = xmas['choice_3']
ax = sns.distplot(x, bins=10, vertical = True)
plt.show()

# %% [markdown]
# <iframe width="713" height="535" src="https://www.youtube.com/embed/V9AbeALNVkk" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# We're Not Gonna Take it- Band:Twisted Sister  *Lyrics: We're not gonna take it/No, we ain't gonna take it/We're not gonna take it anymore/We've got the right to choose it/There ain't no way we'll lose it/This is our life, this is our song/We're right, yeah/We're free, yeah/We'll fight, yeah/You'll see, yea/ Oh, you're so condescending/Your gall is never ending/We don't want nothin', not a thing from you https://www.youtube.com/watch?v=V9AbeALNVkk  77,928,330 views

# %% [markdown]
# Pay attention at 3:41, great entry in a competition.

# %% [markdown]
# Fatih Bilgin awesome Notebook https://www.kaggle.com/fatihbilgin/quick-eda-and-data-visualization-for-beginners

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image socialistamorena.com.br

# %% [markdown]
# The line below (that begins with ng) can be an inspiration for ANDREW NG lovers :)  https://www.kaggle.com/general/118606#679565

# %%
ng = xmas[xmas.choice_2 <250]
plt.figure(figsize=(8,4))
sns.boxplot(y="choice_2",x ='choice_4' ,data = ng)
plt.title("choice_2 & choice_4 < 250")
plt.show()

# %%
xmas.isnull().sum()

# %% [markdown]
# David Tang excellent Notebook: https://www.kaggle.com/dcstang/see-like-a-radiologist-with-systematic-windowing

# %%
object_xmas=xmas.select_dtypes(include=['object'])
object_xmas.columns

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNg37dzyAS2trtuEDlwuA5EJkeS_oVR2ZMTBUZ3NFyXCJd3KxMWg&s',width=400,height=400)

# %% [markdown]
# Image: easons.com

# %%
for i in object_xmas.columns:
    print(xmas[i].value_counts())
    print('-'*40)

# %% [markdown]
# Paranoid - Band Black Sabbath *Lyrics: Finished with my woman 'cause she couldn't help me with my mind/People think I'm insane because I am frowning all the time/All day long I think of things but nothing seems to satisfy/Think I'll lose my mind if I don't find something to pacify/Can you help me, occupy my brain?    https://www.youtube.com/watch?v=0qanF-91aJo

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRF9RcQ9q0imxaoRBnADsP-oafJ5gzOl1619LiipXOoTfPwK_W&s',width=400,height=400)

# %% [markdown]
# Image: abc7ny.com

# %%
xmas.describe()

# %% [markdown]
# Caesar Lupum electrifying Notebook: https://www.kaggle.com/caesarlupum/ashrae-start-here-a-gentle-introduction

# %%
print('variance of each column')
xmas.var()

# %% [markdown]
# Livin' On A Prayer - Band: Bon Jovi *Lyrics: He's down on his luck, it's tough, so tough/ She says, we've got to hold on to what we've got/It doesn't make a difference if we make it or not/We'll give it a shot/Woah, we're half way there/Woah, livin' on a prayer/Baby, it's okay, someday/We've got to hold on to what we've got        https://www.youtube.com/watch?v=lDK9QqIzhwk

# %%
sns.scatterplot(x='choice_1',y='choice_4',data=xmas)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image zazzle.com - Just look at Walter Reade´s (aka Inversion) image account and you´ll understand Kaggler's drummer
# https://www.kaggle.com/inversion/inversion-s-been-nice-benchmark

# %% [markdown]
# https://www.youtube.com/watch?v=2Hgz-q76KtQ  This song is for you Inversion @inversion.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7KPreV_aXZKqoYIH7ypux5HGX2YEXcOsf2AIX4AfVHiIkAIqJ&s',width=400,height=400)

# %% [markdown]
# Image:mdjonline.com

# %%
sns.countplot(xmas["choice_5"])

# %% [markdown]
# <iframe width="951" height="535" src="https://www.youtube.com/embed/hx27NL_iqEM" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# METALLICA - MASTER of PUPPETS *Lyrics: You guys like that song, don't ya?/Sure, if you play it right/So you guys are tired, huh? /We're just getting warmed up and you guys are tired/You're ready to go home/You guys sound tired to me/
# Let's hear you say "F***** no James!" (f*** no James)/Taste me you will see/More is all you need/Dedicated to/How I'm killing you/Master (master), of (of), puppets!      https://www.youtube.com/watch?v=hx27NL_iqEM

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf = xmas.groupby('choice_0').size()/xmas['choice_8'].count()*100
labels = lowerdf.index
values = lowerdf.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS8MYnVE4IayOUg1aFl2EEGG2OJFhByKwA_jASmBb2570-fKXff&s',width=400,height=400)

# %% [markdown]
# Image: amazon.com

# %%
plt.figure(figsize=(8, 6))
pd.value_counts(xmas['choice_9']).plot.bar()
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpGci2F2e-nYcdKLyUaiizOYi97geSoba0AY__3jps1iXNCdYZUw&s',width=400,height=400)

# %% [markdown]
# Image: parade.com

# %%
labels1=xmas.choice_6.value_counts().index
sizes1=xmas.choice_6.value_counts().values
plt.figure(figsize=(11,11))
plt.pie(sizes1,labels=labels1,autopct="%1.1f%%")
plt.title("choice_6",size=15)
plt.show()

# %% [markdown]
# Jingle Bell Rock - Let's sing along - Lyrics:
# Jingle bell, jingle bell, jingle bell rock/
# Jingle bells swing and jingle bells ring/
# Snowing and blowing up bushels of fun/
# Now the jingle hop has begun/
# Jingle bell, jingle bell, jingle bell rock/
# Jingle bells chime in jingle bell time/
# Dancing and prancing in Jingle Bell Square/
# In the frosty air/
# What a bright time, it's the right time/
# To rock the night away/
# Jingle bell time is a swell time/
# To go gliding in a one-horse sleigh/
# Giddy-up jingle horse, pick up your feet/
# Jingle around the clock/
# Mix and a-mingle in the jingling feet/
# That's the jingle bell rock/
# Jingle bell, jingle bell, jingle bell rock/
# Jingle bells chime in jingle bell time/
# Dancing and prancing in Jingle Bell Square/
# In the frosty air/
# Jingle bell, jingle bell, jingle bell rock/
# Jingle bells chime in jingle bell time/
# Snowing and blowing up bushels of fun/
# Now the jingle hop has begun/
# Jingle bell, jingle bell, jingle bell rock/
# Jingle bells chime in jingle bell time/
# Dancing and prancing in Jingle Bell Square/
# In the frosty air/
# What a bright time, it's the right time/
# To rock the night away (rock the night away)/
# Jingle bell time is a swell time/
# To go gliding in a one-horse sleigh/
# Giddy-up jingle horse, pick up your feet/
# Jingle around the clock/
# Mix and a-mingle in the jingling feet/
# That's the jingle bell/
# That's the jingle bell/
# That's the jingle bell (rock)/    https://www.youtube.com/watch?v=VfLf7A_-1Vw  113,514,564 views

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRqIQ4WKeBqE8W3uEdXpegsLRWdzLk626NnhU050tVW71oBUdTJ9w&s',width=400,height=400)

# %% [markdown]
# Image:npr.org

# %% [markdown]
# Since the FAO estimates that as many as 25,000 people lose their lives every day as a result of hunger. That adds up to roughly 9.1 million people who die of starvation each year.https://www.creditdonkey.com/world-hunger-statistics.html My suggestion to optimize families finances is that they should think a little more before spending money in material things that sooner will be abandoned.That huge issue, even Santa can't fix. Spending money is good for the Economy. I don't want to be the Grinch. Just try to think twice: Do I need this? How long will I use it? It's just a reflection of my own.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTOCnRyI_WfqhZI-gr6BIOjxbEdcKg00kp65w_F42w6bZPRaQoP&s',width=400,height=400)

# %% [markdown]
# <iframe width="713" height="535" src="https://www.youtube.com/embed/bjQzJAKxTrE?list=RDbjQzJAKxTrE" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# **DO THEY KNOW IT'S CHRISTMAS** - Band Aid 1984 - Lyrics:
# It's Christmas time/
# There's no need to be afraid/
# At Christmas time/
# We let in light and we banish shade/
# And in our world of plenty/
# We can spread a smile of joy/
# Throw your arms around the world/
# At Christmas time/
# But say a prayer/
# Pray for the other ones/
# At Christmas time, it's hard/
# But when you're having fun/
# There's a world outside your window/
# And it's a world of dreaded fear/
# Where the only water flowing/
# Is a bitter sting of tears/
# And the Christmas bells that ring there/
# Are the clanging chimes of doom/
# We'll, tonight, thank God, it's them/
# Instead of you/
# And there won't be snow in Africa this Christmas time/
# The greatest gift they'll get this year is life/
# Where nothing ever grows, no rain or rivers flow/
# Do they…/
#   https://www.youtube.com/watch?v=bjQzJAKxTrE&list=RDbjQzJAKxTrE&start_radio=1&t=42 **FEED THE WORLD**

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrWQQJU18ZRlHDgvSzbw60Qt-n0bYO_ZPx-oSKwh9qiPlfctds&s',width=400,height=400)

# %% [markdown]
# Image oceanpop.com

# %% [markdown]
# Rock stars and high-level ML competitors are quite alike. I can't see any place for women in these careers/activities. Albeit, it's not an issue since we can work in other ways/situations. In those Youtube videos, there are no girls/women performing. Only in backing vocals, groupies or fans. Data Science: not everything is about competitions, titles (tier positions) and medals. There are so many amazing subjects that we can study and pursuit. In Kaggle Platform, we find plenty of fascinating activities that we can choose. So it's up to you. If everybody is a star we wouln't be able to see each others due the amount of brightness.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRNFPFLUkdRQwdfoybhy0Q9KJ6IKx0drPAj-AiIhW6tM-7TF4Ub&s',width=400,height=400)

# %% [markdown]
# Try to watch the YouTube videos. Most part of Kagglers were born after that time. Read the lyrics. Reflect about them. Maybe sing-along. Enjoy the track, enjoy the competition. Merry Xmas!

# %% [markdown]
# **FEED THE Machine Learning WORLD with KAGGLE NOTEBOOKS**

# %% [markdown]
# * K-Notebook Runner: Marília Prata @mpwolke
# * Executive Producer: Marília Prata @mpwolke
