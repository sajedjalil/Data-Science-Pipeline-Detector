# %%
# !wget https://dl.fbaipublicfiles.com/deit/M48_448.pth

# %%
 # !wget https://dl.fbaipublicfiles.com/deit/XXS24_224.pth

# %%
 # !wget https://dl.fbaipublicfiles.com/deit/XXS24_384.pth

# %%
# !wget https://dl.fbaipublicfiles.com/deit/XXS36_224.pth

# %%
# !wget https://dl.fbaipublicfiles.com/deit/XXS36_384.pth

# %%
# !wget https://dl.fbaipublicfiles.com/deit/XS24_384.pth

# %%
# !wget https://dl.fbaipublicfiles.com/deit/S24_224.pth

# %%
# !wget https://dl.fbaipublicfiles.com/deit/S24_384.pth

# %%
# !wget https://dl.fbaipublicfiles.com/deit/S36_384.pth

# %%
# !wget https://dl.fbaipublicfiles.com/deit/M36_384.pth
