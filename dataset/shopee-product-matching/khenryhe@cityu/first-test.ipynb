# %%
from numpy import *
import pandas as pd
import skimage.io
import skimage.transform
import matplotlib.pyplot as plt
from sklearn import *
import csv

# %%
test_pd = pd.read_csv('/kaggle/input/shopee-product-matching/test.csv')
textid_test = []
for index, row in test_pd.iterrows():
    textid_test.append(row[0])

# %%
result_dict = {}
for key in textid_test:
    result_dict[key] = []
    result_dict[key].append(key)
    result_dict[key].append(key)

# %%
print(result_dict)

# %%
def write_csv_kaggle_sub2(fname, result):
    # fname = file name
    # Y is a list/array with class entries
    
    # header
    df = pd.DataFrame.from_dict(result, columns = ['posting_id', 'matches'], orient='index')
    df.to_csv(path_or_buf = fname, index = False)

# %%
write_csv_kaggle_sub2("/kaggle/working/submission.csv", result_dict)
