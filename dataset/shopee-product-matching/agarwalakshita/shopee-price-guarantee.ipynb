# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
print(os.listdir('/kaggle/input/shopee-product-matching'))

# %%
test_data_file='/kaggle/input/shopee-product-matching/test.csv'
train_data_file='/kaggle/input/shopee-product-matching/train.csv'

train = pd.read_csv(train_data_file)
test = pd.read_csv(test_data_file)

# %%
train.head(5)

# %%
x_train = train.drop('label_group', axis=1)
y_train = train['label_group'].astype('int32')
print('x_train shape: ', x_train.shape)
print('y_train shape: ', y_train.shape)
print('test shape: ', test.shape)
print('\nsamples in test: ', test.shape[0])
print('samples in train: ', x_train.shape[0])

x_train.head(3)
