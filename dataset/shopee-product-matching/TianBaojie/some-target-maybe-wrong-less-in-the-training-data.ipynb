# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# **train_3805508898,train_3386243561,train_3423213080 are alomst same,but they are not in a same label_group.**

# %%
train=pd.read_csv('../input/shopee-product-matching/train.csv')
train.head(2)

# %%
tmp = train.groupby('label_group').posting_id.agg('unique').to_dict()
train['target'] = train.label_group.map(tmp)
train.head(2)

# %%
train[train.posting_id=='train_3805508898']

# %%
train[train.posting_id=='train_3423213080']

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg 
import numpy as np
# posting_id=='train_3805508898'
lena = mpimg.imread('../input/shopee-product-matching/train_images/bc8880b245804eecd8f07d16c22191fa.jpg') 
plt.imshow(lena) 
print(train[train.posting_id=='train_3805508898']['title'])

# %%
# posting_id=='train_3386243561'
lena = mpimg.imread('../input/shopee-product-matching/train_images/00039780dfc94d01db8676fe789ecd05.jpg') 
plt.imshow(lena) 
print(train[train.posting_id=='train_3386243561']['title'])

# %%
# posting_id=='train_3423213080'
lena = mpimg.imread('../input/shopee-product-matching/train_images/8cbe4bf9706bc177fd61071ef776be8c.jpg') 
plt.imshow(lena) 
print(train[train.posting_id=='train_3423213080']['title'])

# %% [markdown]
# **train_3805508898,train_3386243561,train_3423213080 are alomst same,but they are not in a same label_group.**
