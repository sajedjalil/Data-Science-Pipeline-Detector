# %%
import pandas as pd

test = pd.read_csv('../input/shopee-product-matching/test.csv')
submission = pd.DataFrame()
submission['posting_id'] = test['posting_id']
submission['matches'] = submission['posting_id']
submission.to_csv('./submission.csv', index=False)
