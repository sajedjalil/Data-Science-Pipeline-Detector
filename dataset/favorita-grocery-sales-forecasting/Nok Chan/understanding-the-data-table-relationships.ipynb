# %%
## I am creating this kernel for understanding the relationship between tables, will add more later when I started building model

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/5816/8641/ER.PNG?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1512379591&Signature=qQytRIDLSkpBoGVCtV6uONvgWQywDsZ0sLFR%2BS4i%2FuGykHforjPcC1Axt%2BvHtK2SnqA7FE24vqW%2FJh7l0Sk85sXcnCSXnOQm%2BKlo1jMJxLLO3iQxXkxEqB37zUiOgIS%2F5%2Fq8BRqCFGyXP8sSI8Xzbo1p2aZplzWuGV%2BOM8IEaLpJJw9vpqIZhwxmEdsC8Cc%2F7yU7r%2FdPrJOV9lqJOkq0Ck0zVpeHThbSLbJmQ4CkqawCLVHD8Owo7kw3rKnxFEmLPpez7AXNvyDJxtYJDkjgox9mZEKQ4WAd73QYL74U7swCP5pOq%2FTPXHQZ6oVSpZm2BocIRQTmM%2FL3oR7IC8YdDg%3D%3D)![image.png](attachment:image.png)
# Note that for transaction you need to use two columns as a key to join.

# %% [markdown]
# File Descriptions and Data Field Information
#
# URL: https://www.kaggle.com/c/favorita-grocery-sales-forecasting/data

# %% [markdown]
# Additional Notes
#
# Wages in the public sector are paid every two weeks on the 15 th and on the last day of the month. Supermarket sales could be affected by this.
# A magnitude 7.8 earthquake struck Ecuador on April 16, 2016. People rallied in relief efforts donating water and other first need products which greatly affected supermarket sales for several weeks after the earthquake.
