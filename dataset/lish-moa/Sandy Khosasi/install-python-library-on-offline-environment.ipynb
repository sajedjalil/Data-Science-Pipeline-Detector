# %% [markdown]
# A short demo to show installing Python library on offline environment
#
# Source : https://stackoverflow.com/a/51646354/11911037

# %% [markdown]
# # On online machine

# %% [markdown]
# ## 1. Write library you plan to use
#
# You don't need to write it's dependency

# %%
# !echo 'pytorch-tabnet\ntorch_optimizer' > requirements.txt

# %%
# library = \
# '''
# pytorch-tabnet
# torch_optimizer
# '''.lstrip('\n')
# with open('requirements.txt', 'w+') as f:
#     f.write(library)

# %%
# !cat requirements.txt

# %% [markdown]
# ## 2. Download library and save it to wheelhouse directory

# %%
# !mkdir wheelhouse && pip download -r requirements.txt -d wheelhouse

# %% [markdown]
# ## 3. Move requirements.txt to wheelhouse directory

# %%
# !mv requirements.txt wheelhouse/requirements.txt

# %% [markdown]
# ## 4. Upload to Kaggle Dataset

# %% [markdown]
# # On offline machine

# %% [markdown]
# ## 1. Install library
#
# ```sh
# pip install -r [path to requirement.txt] --no-index --find-links [path to wheelhouse directory]
# ```

# %%
# !pip install -r /kaggle/working/wheelhouse/requirements.txt --no-index --find-links /kaggle/working/wheelhouse

# %%
# !pip install -r /kaggle/input/wheelhouse-pytorch-tabnet-optimizer/wheelhouse/requirements.txt --no-index --find-links /kaggle/input/wheelhouse-pytorch-tabnet-optimizer/wheelhouse
