# %% [markdown]
#  # Some basic concepts in voice recognition
#
# ## Basic concepts:
#
# FFT: time domain-> frequency domain
# Get spectrogram: time domain->fft to different span->rotate 90 degrees->translate into grey scale->spectrogram
# ![Screen%20Shot%202017-11-28%20at%209.17.26%20PM.png](attachment:Screen%20Shot%202017-11-28%20at%209.17.26%20PM.png)
#
# Mel-frequency filter:
# point: human ears concentrate on low frequency components
# ![Screen%20Shot%202017-11-28%20at%209.17.34%20PM.png](attachment:Screen%20Shot%202017-11-28%20at%209.17.34%20PM.png)
#
# Cepstral Analysis
# Spectrum can be split  into spectral envelope (log H[k]) and spectral details (log E[k]) in log form by FFT
# Then perform IFFT: x[k]=h[k]+e[k]
# h[k] is what we want
# ![Screen%20Shot%202017-11-28%20at%209.17.40%20PM.png](attachment:Screen%20Shot%202017-11-28%20at%209.17.40%20PM.png)
#
# What does spectrum look like?
# ![Screen%20Shot%202017-11-28%20at%209.17.50%20PM.png](attachment:Screen%20Shot%202017-11-28%20at%209.17.50%20PM.png)
#
# ### MFCC??
# Spectrum->mel spectrum->cepstral analysis to get h[k] where H[k] is Mel-spectrum form of original sounds->MFCC
# In three paper we reviewed, all of them used mea-spectrum rather than MFCC. All paper I read observed that MFCC doesn’t outperform mel-spectrum (seems like MFCC is not used as input for the network)
#
# (I will keep on undating my progress, thanks my partner Hongye Yang for his patient teaching and encourage!)
