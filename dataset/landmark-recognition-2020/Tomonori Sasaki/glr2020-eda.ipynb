# %% [markdown]
# # OverView

# %% [markdown]
# Let's go over [the rules](https://www.kaggle.com/c/landmark-recognition-2020/overview/code-requirements) first.
# * TPUs will not be available for making submissions to this competition. You are still welcome to use them for training models.
# * No internet access enabled
# * Freely & publicly available external data is allowed, including pre-trained models

# %%
# linear algebra
import numpy as np
# data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
#Unix commands
import os

# import useful tools
from glob import glob
from PIL import Image
import cv2

# import data visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

from bokeh.plotting import figure
from bokeh.io import output_notebook, show, output_file
from bokeh.models import ColumnDataSource, HoverTool, Panel
from bokeh.models.widgets import Tabs
# import data augmentation
import albumentations as albu

# import math module
import math
#Libraries
import pandas_profiling
from xgboost import XGBClassifier
from sklearn import preprocessing

# %%
# linear algebra
import numpy as np
# data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
#Unix commands
import os

# import useful tools
from glob import glob
from PIL import Image
import cv2

# import data visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

from bokeh.plotting import figure
from bokeh.io import output_notebook, show, output_file
from bokeh.models import ColumnDataSource, HoverTool, Panel
from bokeh.models.widgets import Tabs
# import data augmentation
import albumentations as albu

# import math module
import math
#Libraries
import pandas_profiling
from xgboost import XGBClassifier
from sklearn import preprocessing

# %% [markdown]
# # Loading data

# %%
# Setup the paths to train and test images
DATASET = '../input/delg-saved-models/'
TEST_DIR = '../input/landmark-recognition-2020/test/'
TRAIN_DIR = '../input/landmark-recognition-2020/'

# %%
#Loading train Files for Submission
train = pd.read_csv(TRAIN_DIR + "train.csv")
#Loading Sample Files for Submission
sample = pd.read_csv(TRAIN_DIR + "sample_submission.csv")

# %% [markdown]
# * Let us check the format of the file for submission

# %%
# Display some of the training data
train.head(10).style.applymap(lambda x: 'background-color:lightsteelblue')

# %% [markdown]
# There seems to be unique IDs and some landmark IDs

# %% [markdown]
# Next, we will check for missing values

# %%
# Confirmation of the format of samples for submission
sample.head(10).style.applymap(lambda x: 'background-color:lightsteelblue')

# %%
#Check for missing values in the training data
train.isnull().sum()

# %% [markdown]
# * Fortunately, the missing value is content!
# * Let us check how many types of Landmark IDs there are

# %%
# Find the unique number of landmark IDs. 
n = train['landmark_id'].nunique()
print('The unique number of landmark IDs is ' + str(n))

# %% [markdown]
# * We have made it possible to notice that there are so many different types of Landmark IDs

# %% [markdown]
# * We will next show how the more than 80,000 landmark IDs are distributed in a scatterplot

# %%
# First, I'll use Sturgess's formula to find the appropriate number of classes in the histogram 
k = 1 + math.log2(n)

# %%
# Display a histogram of the FVC of the training data
sns.distplot(train['landmark_id'], kde=True, rug=False, bins=int(k), color='c') 
# Graph Title
plt.title('Distribuition of landmark_ids')
# label
plt.xlabel("landmark_ids")
plt.ylabel("Frequency")
# Show Histogram
plt.show()

# %% [markdown]
# * There doesn't seem to be much of a bias.

# %% [markdown]
# * We'll find the landmark IDs that appear most often

# %%
# coding: utf-8
from tqdm import tqdm
import time

# Set the total value 
bar = tqdm(total = 1000)
# Add description
bar.set_description('Progress rate')
for i in range(100):
    # Set the progress
    bar.update(25)
    time.sleep(1)

# %%
print(train['landmark_id'].value_counts())

# %% [markdown]
# * Check the number of landmark ID 138982

# %%
s_bool = train['landmark_id'] == 138982
m = s_bool.sum()
print('The number of landmark ID 138982' + str(m))

# %% [markdown]
# * Landmark ID 138982 looks like there are 6272 of them.
# * This ID seems to be the most common, so let us focus our attention on this ID.

# %%
the_most_cmn_pics = train[train["landmark_id"]==138982]

# %%
print(the_most_cmn_pics)

# %% [markdown]
# # Acknowledgements

# %% [markdown]
# * [Visualizing Landmarks (+more EDA)](https://www.kaggle.com/jeffreybraun/visualizing-landmarks-more-eda)

# %% [markdown]
# # Your upvote is the source of my motivation.

# %% [markdown]
# # To be continued, sir.
