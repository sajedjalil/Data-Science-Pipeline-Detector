# %% [markdown]
# ### It seems RAPIDS is available on kaggle notebook w/o this [dataset](https://www.kaggle.com/cdeotte/rapids) !!!

# %% [markdown]
# ![title](https://rapids.ai/assets/images/RAPIDS-logo-white.svg)

# %%
import cudf
import cuml

# %%
cudf.__version__

# %%
cuml.__version__
