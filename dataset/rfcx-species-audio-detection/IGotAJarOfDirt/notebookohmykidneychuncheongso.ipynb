# %%
import numpy as np 
import pandas as pd 
import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pd.options.display.max_columns = 1000000
pd.options.display.max_rows = 1000000000
pd.options.display.max_colwidth = 14

# %%
os.listdir('/kaggle/input/rfcx-species-audio-detection')

# %%
print("train false positive")
train_fp = pd.read_csv('/kaggle/input/rfcx-species-audio-detection/train_fp.csv')
print(train_fp.head(1))
print("---------------------------------------------------------------------------")
print("sample")
sample = pd.read_csv('/kaggle/input/rfcx-species-audio-detection/sample_submission.csv')
print(sample.head(1))
print("---------------------------------------------------------------------------")
print("train true positive")
train_tp = pd.read_csv('/kaggle/input/rfcx-species-audio-detection/train_tp.csv')
print(train_tp.head(1))
print("---------------------------------------------------------------------------")

# %%
sample.head(3)

# %%
sample.s0.unique()

# %%
train_tp.head(2)

# %%
train_fp.head(4)

# %%
train_fp.recording_id.value_counts()['003b04435']

# %%
os.listdir('/kaggle/input/rfcx-species-audio-detection/tfrecords/train')[:4]

# %%
import tensorflow as tf

# %%
for example in tf.python.python_io.tf_record_iterator("/kaggle/input/rfcx-species-audio-detection/tfrecords/train/16-148.tfrec"):
#     print(tf.train.Example.FromString(example))
    jsonMessage = MessageToJson(tf.train.Example.FromString(example))
    print(jsonMessage)

# %%
from google.protobuf.json_format import MessageToJson
