# %% [markdown]
# <div>
#     <h1 align="center"> Comparative Method - Part(B)</h1></h1>
#     <h2 align="center">Rainforest Connection Species Audio Detection</h2>
#     <h3 align="center">By: Somayyeh Gholami & Mehran Kazeminia</h3>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# </div>

# %% [markdown]
# # Description:

# %% [markdown]
# ### - In this notebook, we use the Comparative Method to improve the results of the previous notebook (Part A). The address of our previous notebook (Part A) is as follows:
#
# https://www.kaggle.com/mehrankazeminia/lb-0-980-rainforest-comparative-method-part-a
#
# ### - Of course, to use the Comparative Method, we need another suitable notebook. We have used the following notebook for this purpose. Thanks also to Mr. [@vzaguskin](https://www.kaggle.com/vzaguskin) for sharing this great notebook.
#
# https://www.kaggle.com/vzaguskin/rfcx-complete-tpu-training-and-inference-lb-0-95
#
# ### - In the end, we were able to easily improve the results once again with our own method. We saved the final results in the "f" file. The scores of the "f" file are as follows:
#
# ### "f" : [(Private Score: 0.98415) , (Public Score: 0.97684)]

# %% [markdown]
# <div class="alert alert-success">
# </div>

# %% [markdown]
# ## If you find this work useful, please don't forget upvoting :)

# %% [markdown]
# <div class="alert alert-success">
# </div>

# %% [markdown]
# # Import & Data Set

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %matplotlib inline

# _______________________________

sub974 = pd.read_csv("../input/lb-0-980-rainforest-comparative-method-part-a/submission.csv") 

sub943 = pd.read_csv("../input/rain943/RAIN943.csv")

# %% [markdown]
# <div class="alert alert-success">
# </div>

# %% [markdown]
# # Functions

# %%
def generate(main, support, coeff):
    g1 = main.copy()
    g2 = main.copy()
    g3 = main.copy()
    g4 = main.copy()
    
    for i in main.columns[1:]:
        lm, Is = [], []                
        lm = main[i].tolist()
        ls = support[i].tolist() 
        
        res1, res2, res3, res4 = [], [], [], []          
        for j in range(len(main)):
            res1.append(max(lm[j] , ls[j]))
            res2.append(min(lm[j] , ls[j]))
            res3.append((lm[j] + ls[j]) / 2)
            res4.append((lm[j] * coeff) + (ls[j] * (1.- coeff)))
            
        g1[i] = res1
        g2[i] = res2
        g3[i] = res3
        g4[i] = res4
        
    return g1,g2,g3,g4

# %%
def generate1(main, support, coeff):
    
    g = main.copy()    
    for i in main.columns[1:]:
        
        res = []
        lm, Is = [], []        
        lm = main[i].tolist()
        ls = support[i].tolist()  
        
        for j in range(len(main)):
            res.append((lm[j] * coeff[i]) + (ls[j] * (1.- coeff[i])))            
        g[i] = res
        
    return g

# %%
def drawing(main, support, generated, column_number):
    
    X  = main.iloc[:, column_number]
    Y1 = support.iloc[:, column_number]
    Y2 = generated.iloc[:, column_number]
    
    plt.style.use('seaborn-whitegrid') 
    plt.figure(figsize=(8, 8), facecolor='lightgray')
    plt.title(f'\nOn the X axis >>> main\n\nOn the Y axis >>> support\n')           
    plt.scatter(X, Y1, s=3)
    plt.show() 
    
    plt.style.use('seaborn-whitegrid') 
    plt.figure(figsize=(8, 8), facecolor='lightgray')
    plt.title(f'\nOn the X axis >>> main\n\nOn the Y axis >>> generated\n')           
    plt.scatter(X, Y2, s=3)
    plt.show()

# %%
def drawing1(main, support, generated, column_number):
    
    X  = main.iloc[:, column_number]
    Y1 = support.iloc[:, column_number]
    Y2 = generated.iloc[:, column_number]
    
    plt.style.use('seaborn-whitegrid') 
    plt.figure(figsize=(8, 8), facecolor='lightgray')
    plt.title(f'\nBlue | X axis >> main | Y axis >> support\n\nOrange | X axis >> main | Y axis >> generated\n') 
    
    plt.scatter(X, Y1, s=3)    
    plt.scatter(X, Y2, s=3)
    
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# </div>

# %% [markdown]
# # Comparative Method

# %%
# print(sub974.mean() , sub943.mean())

m1 = sub974.mean() + sub943.mean()

m1mean = m1.mean()

m2 = m1 / m1mean

m2

# %%
m3 = m2.copy()
for k in range(24):
    m3[k] = 0.80

# m3

# %%
m4 = m3.copy()

m4[2]   = 0.70

m4[3]   = 0.70

m4[17]  = 0.70

m4[18]  = 1.00

m4[20]  = 0.50

m4[23]  = 0.70

m4

# %%
f = generate1(sub974, sub943, m4)

# %%
sub974.describe()

# %%
sub943.describe()

# %%
drawing1(sub974, sub943, f, 1)

# %%
drawing1(sub974, sub943, f, 2)

# %%
drawing1(sub974, sub943, f, 3)

# %%
drawing1(sub974, sub943, f, 4)

# %%
drawing1(sub974, sub943, f, 5)

# %%
drawing1(sub974, sub943, f, 6)

# %%
drawing1(sub974, sub943, f, 7)

# %%
drawing1(sub974, sub943, f, 8)

# %%
drawing1(sub974, sub943, f, 9)

# %%
drawing1(sub974, sub943, f, 10)

# %%
drawing1(sub974, sub943, f, 11)

# %%
drawing1(sub974, sub943, f, 12)

# %%
drawing1(sub974, sub943, f, 13)

# %%
drawing1(sub974, sub943, f, 14)

# %%
drawing1(sub974, sub943, f, 15)

# %%
drawing1(sub974, sub943, f, 16)

# %%
drawing1(sub974, sub943, f, 17)

# %%
drawing1(sub974, sub943, f, 18)

# %%
drawing1(sub974, sub943, f, 19)

# %%
drawing1(sub974, sub943, f, 20)

# %%
drawing1(sub974, sub943, f, 21)

# %%
drawing1(sub974, sub943, f, 22)

# %%
drawing1(sub974, sub943, f, 23)

# %%
drawing1(sub974, sub943, f, 24)

# %% [markdown]
# ## Result
#
# ## [(Score: 0.974) , (Score: 0.943)] >>> f
#
# ## f : [(Private Score: 0.98415) , (Public Score: 0.97684)]

# %%
f.describe()

# %% [markdown]
# <div class="alert alert-success">
# </div>

# %% [markdown]
# # Submission

# %%
sub = f
sub.to_csv("submission.csv", index=False)

# %% [markdown]
# <div class="alert alert-success">
# </div>
