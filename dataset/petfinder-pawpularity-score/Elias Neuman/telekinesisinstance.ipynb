# %% [markdown]
# # Telekinesis instance setup guide:

# %% [markdown]
# Hi! This is a brief guide that explains how to setup a Telekinesis instance! It is based on Kaggle´s PetFinder.my Pawpularity Contest competition in order to show how to use it based on a real case
#
#
# Watchout: You will only be able to setup an instance if you are registered in Telekinesisis´ private beta

# %% [markdown]
# 1. First you will need to install telekinesis packages, it may take a few seconds to run it
#
#     Watchout: Make sure that you are connected to the internet in Kaggle notebook settings :)

# %%
# !pip install telekinesis
# !git clone https://github.com/telekinesis-inc/telekinesis_compute.git

# %% [markdown]
# 2. Run Telekinesis script to setup the notebook (you will need to keep this script running!)
#
# > !python telekinesis_compute/telekinesis_compute/script_base.py wss://telekinesis.cloud [InstanceName]
#
#    The name you define (InstanceName) while running the script is the one that will be used in you controller notebook to identify this instance

# %%
# !python telekinesis_compute/telekinesis_compute/script_base.py wss://telekinesis.cloud kaggle-instance

# %% [markdown]
# 3. Click on link or Scan the QR code that will appear when you run the script in step 2
#
# 4. Authenticate on telekinesis webpage
#
# 5. It´s done! Now you can go to you controller notebook and identify this instance by the name you defined (InstanceName)
