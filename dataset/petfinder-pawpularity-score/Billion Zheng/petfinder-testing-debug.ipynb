# %%
import os
import sys
import pandas as pd
import numpy as np
import torch

# %% [markdown]
# # training and testing

# %%
test_csv = pd.read_csv('../input/petfinder-pawpularity-score/test.csv')
final_test_predictions = np.zeros_like(test_csv["Id"])
test=torch.tensor(1.0)
# test.cuda()
test_csv["Pawpularity"] = final_test_predictions
test_csv = test_csv[["Id", "Pawpularity"]]
test_csv.to_csv("submission.csv", index=False)
print('successful')
