# %% [markdown]
# # Petfinder Pawpularity EDA
#
# Looks like this is going to be a *pawpular* competition :) We already have a bunch of great baseline kernels, so I'd like to focus instead on just looking at the data.

# %%
# !pip install ipyplot -qq

import pandas as pd
import ipyplot
from PIL import Image

train = pd.read_csv('../input/petfinder-pawpularity-score/train.csv')

# %% [markdown]
# ## Range of scores
#
# Looks like Pawpularity is a score between 0 and 100, with a peak around 30. Let's visualize both the least popular (<10) and most popular (>90) images.

# %%
train.Pawpularity.hist()

# %%
not_popular = train.Id[train.Pawpularity < 10].values.tolist()
popular = train.Id[train.Pawpularity > 90].values.tolist()
not_popular = [Image.open('../input/petfinder-pawpularity-score/train/' + x +'.jpg') for x in not_popular[:12]]
popular = [Image.open('../input/petfinder-pawpularity-score/train/' + x +'.jpg') for x in popular[:12]]

# %% [markdown]
# ## Not Very Popular
#
# They kind of look sad, don't they? 😢😢😢

# %%
ipyplot.plot_images(not_popular, max_images=12, img_width=300)

# %% [markdown]
# ## Popular
#
# These all look like cute little pups 😊😊😊

# %%
ipyplot.plot_images(popular, max_images=12, img_width=300)
