# %%
# !pip install -U ../input/autoxgb/ --no-deps -q

# %%
# !autoxgb train --help

# %%
# !autoxgb train \
--train_filename ../input/petfinder-pawpularity-score/train.csv \
--test_filename ../input/petfinder-pawpularity-score/test.csv \
--idx Id \
--task regression \
--targets Pawpularity \
--time_limit 3600 \
--output petf \
--use_gpu

# %%
# !cp /kaggle/working/petf/test_predictions.csv submission.csv
