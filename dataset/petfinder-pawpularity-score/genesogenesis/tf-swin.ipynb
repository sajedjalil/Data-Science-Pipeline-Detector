# %%
import tensorflow as tf

import sys
sys.path.append('../input/swintransformertf')
from swintransformer import SwinTransformer

# %%
class CFG:
    img_size = [384, 384]
    model_name = 'swin_large_384'

# %%
model = SwinTransformer(CFG.model_name,include_top=False, pretrained=True, use_tpu=True)

# %%
model.save('./PawSwin')
