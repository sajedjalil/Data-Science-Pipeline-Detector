# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:orange; padding:10px">Never forget Maths</span></h1><br>

# %%
import math
import random

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
from glob import glob
import cv2

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: black;"><b style="color:orange;">Strength. Utility. Beauty. Vitruvius Principles. Perfect Proportion</b></h1></center>
#
#
# "Vitruvius  was a Roman architect and engineer during the 1st century BCE, known for his multi-volume work entitled De architectura (around year 15 b.c.). He originated the idea that all buildings should have three attributes: firmitas, utilitas, and venustas ("strength", "utility", and "beauty"). These principles were later widely adopted in Roman architecture. His discussion of perfect proportion in architecture and the human body led to the famous Renaissance drawing of the Vitruvian Man by Leonardo da Vinci."
#
# "In 1486, the book was reprinted in Rome for the first time. It was the work of Fray Giovanni Sulpicio de Veroli and it was an instant hit. All the MASTERS begin its study."
#
# https://en.wikipedia.org/wiki/Vitruvius

# %%
def plotImages(vitruvian,directory):
    print(vitruvian)
    multipleImages = glob(directory)
    plt.rcParams['figure.figsize'] = (15, 15)
    plt.subplots_adjust(wspace=0, hspace=0)
    i_ = 0
    for l in multipleImages[:25]:
        im = cv2.imread(l)
        im = cv2.resize(im, (128, 128)) 
        plt.subplot(5, 5, i_+1) #.set_title(l)
        plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB)); plt.axis('off')
        i_ += 1
        
        
plotImages("Masks in Gray Scale","../input/hotel-id-to-combat-human-trafficking-2022-fgvc9/train_masks/**")

# %% [markdown]
# "Vitruvius, the architect, says in his work on architecture that the measurements of the human body are distributed by Nature as follows that is that 4 fingers make 1 palm, and 4 palms make 1 foot, 6 palms make 1 cubit; 4 cubits make a man's height."
#
# ![](https://slideplayer.com/slide/16834018/97/images/2/The+Drawing+The+Vitruvian+Man+is+a+famous+drawing+by+Leonardo+da+Vinci+from+1487+a.d..jpg)slideplayer.com

# %% [markdown]
# "The navel is in the centre of the human body, and, if in a man lying with his face upward, and his hands and feet extended, from his navel as the centre, a circle be described, it will touch his fingers and toes. It is not alone by a circle, that the human body is thus circumscribed, as may be seen by placing it within a square."
#
# "For measuring from the feet to the crown of the head, and then across the arms fully extended, we find the latter measure equal to the former; so that lines at right angles to each other, enclosing the figure, will form a square."
#
# "So, what the masters attempted to do was to draw a human figure that matched Vitruvius set of proportions, and that was inscribed in a circle and a square."
#
# "These MASTERS also draw Vitruvian Men:"
#
# "Fra Giovanni Giocondo, Cesare Cesariano, Francisco Giorgi, Taccola, Francisco di Giorgio, Giacomo Andrea Da Ferrara"
#
# "Some scholars think that Leonardo may have copied the idea from the last one".
#
# https://owlcation.com/humanities/Leonardo-Da-Vincis-Vitruvian-Man-Explained

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: black;"><b style="color:orange;">Talented were Unknown. Those with less talent but greater political position were famous. Sounds Algorithm Familiar?</b></h1></center>
#
# Vitruvius' De architectura was widely copied and survives in many dozens of manuscripts throughout the Middle Ages.
#
# "In Book III, Chapter 1, Paragraph 3, Vitruvius writes about the proportions of man"
#
# "Vitruvius makes the point that the work of some of the most talented are unknown, while many of those of lesser talent but greater political position are famous. This theme runs through Vitruvius's ten books repeatedly – echoing an implicit prediction that he and his works will also be forgotten."
#
# "Vitruvius illustrates this point by naming what he considers are the most talented individuals in history. Implicitly challenging the reader that they have never heard of some of these people, Vitruvius goes on and predicts that some of these individuals will be forgotten and their works lost, while other, less deserving political characters of history will be forever remembered with pageantry."
#
# Check Vitruvius lists:
#
# List of physicists: Thales, Democritus, Anaxagoras, Xenophanes
#
# List of philosophers: Socrates, Plato, Aristotle, Zeno, Epicurus
#
# List of kings: Croesus, Alexander the Great, Darius
#
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:orange; padding:10px">List Plagiarism and List Abusing Dead Authors</span></h1><br>
#
# On plagiarism: Aristophanes, Ptolemy I Soter, a person named Attalus
#
# On abusing dead authors: Zoilus Homeromastix, Ptolemy II Philadelphus
#
#
# ON PLAGIARISM and ON ABUSING DEAD AUTHORS List??!!!!  Really??!!
#
# https://en.wikipedia.org/wiki/Vitruvius

# %%
def plotImages(vitruvian,directory):
    print(vitruvian)
    multipleImages = glob(directory)
    plt.rcParams['figure.figsize'] = (15, 15)
    plt.subplots_adjust(wspace=0, hspace=0)
    i_ = 0
    for l in multipleImages[:25]:
        im = cv2.imread(l)
        im = cv2.resize(im, (128, 128)) 
        plt.subplot(5, 5, i_+1) #.set_title(l)
        plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB)); plt.axis('off')
        i_ += 1
        
        
plotImages("Masks in Gray Scale","../input/hotel-id-to-combat-human-trafficking-2022-fgvc9/test_images/abc.jpg")

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:orange; padding:10px">Squaring the Circle</span></h1><br>
#
#
# "Squaring the circle is a problem proposed by ancient geometers. It is the challenge of constructing a square with the same area as a given circle by using only a finite number of steps with compass and straightedge. The difficulty of the problem raised the question of whether specified axioms of Euclidean geometry concerning the existence of lines and circles implied the existence of such a square."
#
# "In 1882, the task was proven to be impossible, as a consequence of the Lindemann–Weierstrass theorem, which proves that pi (π) is a transcendental, rather than an algebraic irrational number; that is, it is not the root of any polynomial with rational coefficients. It had been known for decades that the construction would be impossible if π were transcendental, but π was not proven to be transcendental until 1882. Approximate squaring to any given non-perfect accuracy, in contrast, is possible in a finite number of steps, since there are rational numbers arbitrarily close to π."
#
# "The expression "squaring the circle" is sometimes used as a metaphor for trying to do the impossible."

# %% [markdown]
# #Squaring the Circle with HTML/CSS by Shiv Kumar Ganesh
#
# https://www.kaggle.com/code/shivkumarganesh/embed-html-css-in-notebook-create-shapes-cards/notebook

# %% [markdown]
# <div style="height: 150px;width: 150px;background-color: #DC143C;border-radius: 50%;"></div>

# %% [markdown]
# <div style="height: 150px;width: 150px;background-color: #DC143C;"></div>

# %% [markdown]
# <div style="width: 100px;height: 50px;transform: skew(50deg);background: #DC143C;"></div>

# %% [markdown]
# <div style="border-bottom: 150px solid #DC143C;border-left: 125px solid transparent;border-right: 125px solid transparent;height: 0;width: 125px;"></div>

# %% [markdown]
# ![](https://www.revistaquestaodeciencia.com.br/sites/default/files/inline-images/SQUARING_INTERNA_OK.jpg)revistaquestaodeciencia.com.br

# %%
#Code by Nagesh Singh Chauhan https://www.kaggle.com/nageshsingh/generate-realistic-human-face-using-gan

from tqdm import tqdm
from PIL import Image as Img
from keras import Input
from keras.layers import Dense, Reshape, LeakyReLU, Conv2D, Conv2DTranspose, Flatten, Dropout
from keras.models import Model
from tensorflow.keras.optimizers import RMSprop

# %%
#Code by Nagesh Singh Chauhan https://www.kaggle.com/nageshsingh/generate-realistic-human-face-using-gan

PIC_DIR = f'../input/hotel-id-to-combat-human-trafficking-2022-fgvc9/train_masks/'

IMAGES_COUNT = 1125

ORIG_WIDTH = 178
ORIG_HEIGHT = 208
diff = (ORIG_HEIGHT - ORIG_WIDTH) // 2

WIDTH = 128
HEIGHT = 128

crop_rect = (0, diff, ORIG_WIDTH, ORIG_HEIGHT - diff)

images = []
for pic_file in tqdm(os.listdir(PIC_DIR)[:IMAGES_COUNT]):
    pic = Image.open(PIC_DIR + pic_file).crop(crop_rect)
    pic.thumbnail((WIDTH, HEIGHT), Image.ANTIALIAS)
    images.append(np.uint8(pic))

# %%
#Code by Nagesh Singh Chauhan https://www.kaggle.com/nageshsingh/generate-realistic-human-face-using-gan

#Display first 5 images #Original 25 images
plt.figure(1, figsize=(10, 10))
for i in range(5): #Original 25
    plt.subplot(5, 1, i+1) #Original (5, 5, i+1)
    plt.imshow(images[i])
    plt.axis('off')
plt.show()

# %%
#Code by Volody  https://www.kaggle.com/code/volody/threshold-segmentation

img_list = ['00026.png', '00004.png', '00000.png', '00010.png']
fig = plt.figure(figsize=(16, 16))
for i in range(4):
    x = fig.add_subplot(2, 2, i+1)
    image = plt.imread('/kaggle/input/hotel-id-to-combat-human-trafficking-2022-fgvc9/train_masks/'+img_list[i])
    x.set_title("{image} ({shape[0]},{shape[1]})".format(image=img_list[i],shape=image.shape))
    plt.imshow(image)

# %% [markdown]
# "Da Vinci is not the only—or even the first—artist to attempt illustrating Virtruvius's proportions, though his work is the most famous."
#
# https://www.artandobject.com/news/history-and-influence-da-vincis-vitruvian-man
#
# "What was the original concept of Vitruvian man, according to Roman engineer and architect Vitruvius?"
#
# "For a man to be perfect, his hands and feet would touch the circumference of a circle when extended."
#
# https://quizlet.com/38130403/art-history-the-masters-i-leonardo-da-vinci-flash-cards/

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques

#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

def visualize_images(path, n_images, is_random=True, figsize=(16, 16)):
    plt.figure(figsize=figsize)
    w = int(n_images ** .5)
    h = math.ceil(n_images / w)
    
    all_names = os.listdir(path)
    image_names = all_names[:n_images]   
    if is_random:
        image_names = random.sample(all_names, n_images)
            
    for ind, image_name in enumerate(image_names):
        img = cv2.imread(os.path.join(path, image_name))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        plt.subplot(h, w, ind + 1)
        plt.imshow(img)
        plt.xticks([])
        plt.yticks([])

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

vitruvians_PNG_PATH = '../input/hotel-id-to-combat-human-trafficking-2022-fgvc9/train_masks'

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:orange; padding:10px">Iacomo Andrea</span></h1><br>
#
#
# Iacomo Andrea, also known as Giacomo Andrea de Ferrara, was an architect from Ferrara and the author on a commentary on Vitruvius.
#
# A Vitruvian Man prototype by Giacomo Andrea
#
# Luca Pacioli wrote that Andrea was almost like a brother to Leonardo da Vinci. Andrea drew a prototypical Vitruvian Man which may have served as the basis for Da Vinci's drawing or just been born alongside as a collaborative effort.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/6/69/Vitruvian_Man_by_Giacomo_Andrea.jpg)

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

visualize_images(vitruvians_PNG_PATH, 9)

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

def show_color_histogram(path):
    image_names = os.listdir(path)
    image_name = random.choice(image_names)
    img = cv2.imread(os.path.join(path, image_name))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    fig = make_subplots(1, 2)

    fig.add_trace(go.Image(z=img), 1, 1)
    for channel, color in enumerate(['red', 'green', 'blue']):
        fig.add_trace(
            go.Histogram(
                x=img[..., channel].ravel(), 
                opacity=0.5,
                marker_color=color, 
                name='%s channel' %color
            ), 1, 2)
    fig.update_layout(height=400)
    fig.show()

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:orange; padding:10px">The Vitruvian Man by Leonardo da Vinci</span></h1><br>
#
#
# "The Vitruvian Man was created by Leonardo da Vinci around the year 1487. It is accompanied by notes based on the work of the famed architect, Vitruvius Pollio. The drawing, which is in pen and ink on paper, depicts a male figure in two superimposed positions with his arms and legs apart and simultaneously inscribed in a circle and square. The drawing and text are sometimes called the Canon of Proportions or, less often, Proportions of Man."
#
# "The proportional relationship of the parts reflects the universal design.  These qualities are thus shared equally by God's creation of the human body and the human being's own production of a good building. In the late 1480s, this theme of the artistic microcosm emerged as one of the great unifying principles of his thought."
#
# This image provides a perfect example of Leonardo's keen interest in proportion. In addition, this picture represents a cornerstone of Leonardo's attempts to relate man to nature.  Vitruvian Man as a cosmografia del minor mondo (cosmography of the microcosm). He believed the workings of the human body to be an analogy for the workings of the universe."
#
# The square represents the material World and the circle
#
# "The Vitruvian Man, a late 15th-century drawing, intended to explore the idea of proportion, the piece is part work of art and part mathematical diagram, conveying the Old Master's belief that “everything connects to everything else.”
#
# https://www.leonardodavinci.net/the-vitruvian-man.jsp
#
# ![](https://miro.medium.com/max/600/1*MQn9bLm0xRalH0Q8uoPKpw.png)medium.com

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

def color_hist_visualization(image_path, figsize=(16, 4)):
    plt.figure(figsize=figsize)
    
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    plt.subplot(1, 4, 1)
    plt.imshow(img)
    plt.axis("off")
    
    colors = ["red", "green", "blue"]
    for i in range(len(colors)):
        plt.subplot(1, 4, i + 2)
        plt.hist(
            img[:, :, i].reshape(-1),
            bins=25,
            alpha=0.5,
            color=colors[i],
            density=True
        )
        plt.xlim(0, 255)
        plt.xticks([])
        plt.yticks([])
        
    plt.show()

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

img_path = '../input/hotel-id-to-combat-human-trafficking-2022-fgvc9/train_masks/00221.png'
color_hist_visualization(img_path)

img_path = '../input/hotel-id-to-combat-human-trafficking-2022-fgvc9/train_images/10947/000030890.jpg'
color_hist_visualization(img_path)

img_path = '../input/hotel-id-to-combat-human-trafficking-2022-fgvc9/test_images/abc.jpg'
color_hist_visualization(img_path)

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

import plotly.graph_objs as go
from plotly.subplots import make_subplots

show_color_histogram(vitruvians_PNG_PATH)

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

def batch_visualization(path, n_images, is_random=True, figsize=(16, 16)):
    plt.figure(figsize=figsize)
    
    w = int(n_images ** .5)
    h = math.ceil(n_images / w)
    
    all_names = os.listdir(path)
    
    image_names = all_names[:n_images]
    if is_random:
        image_names = random.sample(all_names, n_images)
    
    for ind, image_name in enumerate(image_names):
        img = cv2.imread(os.path.join(path, image_name))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        plt.subplot(h, w, ind + 1)
        plt.imshow(img)
        plt.axis("off")
    
    plt.show()

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

batch_visualization(vitruvians_PNG_PATH, 1, is_random=True, figsize=(5, 5))

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#https://www.kaggle.com/code/mpwolke/rijksmuseum-augmentation

batch_visualization(vitruvians_PNG_PATH, 4, is_random=True, figsize=(10, 10))

# %%
batch_visualization(vitruvians_PNG_PATH, 9, is_random=True)

# %% [markdown]
# ![](http://4.bp.blogspot.com/-0JSZeiVfd_c/T5q4putpEsI/AAAAAAAADQA/0CYCp5zz3vo/s1600/natural-history.gif)http://art109miami.blogspot.com/2012/04/vitruvian-humor.html

# %% [markdown]
# #Acknowledgements:
#
# Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques
#
# Volody  https://www.kaggle.com/code/volody/threshold-segmentation
#
# Nagesh Singh Chauhan https://www.kaggle.com/nageshsingh/generate-realistic-human-face-using-gan
#
# Shiv Kumar Ganesh https://www.kaggle.com/code/shivkumarganesh/embed-html-css-in-notebook-create-shapes-cards/notebook
#
# And obviously THE MASTERS: Vitruvius, Iacomo Andrea and Leonardo (Da Vinci).

# %% [markdown]
# #Copying someone's work, means learn, transform it, add value and share it with Kaggle community like a gift.
