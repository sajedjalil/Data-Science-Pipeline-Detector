# %% [markdown]
# # Overview
# A baseline model will always predict that there is no pneumonia.

# %%
import pandas as pd
sub = pd.read_csv('../input/stage_1_sample_submission.csv')

# %% [markdown]
# # Submission

# %%
sub['PredictionString'] = ''

# %%
sub.head()

# %%
sub.to_csv('naive_submission.csv',index=False)
