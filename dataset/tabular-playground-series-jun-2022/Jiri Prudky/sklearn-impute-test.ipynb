# %% [markdown]
# In this notebook I will test Imputers which are provided by scikit-learn.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from tqdm import tqdm

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('../input/tabular-playground-series-jun-2022/data.csv', index_col = 'row_id')
submission = pd.read_csv('../input/tabular-playground-series-jun-2022/sample_submission.csv', index_col = 'row-col')

display(data,submission)

# %% [markdown]
# ## Display missing values

# %%
import missingno as msno

msno.matrix(data);

# %% [markdown]
# # sklearn.impute

# %% [markdown]
# ## Simple Imputer

# %% [markdown]
# 1.75442Let's start with simple imputer (inspired by https://www.kaggle.com/code/inversion/get-started-with-mean-imputation)
#
# **Score** for different strategies:
# - Mean : **1.41613**
# - Median : **1.41708**
# - Most Frequent: **1.75442**

# %%
# %%time
from sklearn.impute import SimpleImputer

simple_imputer = SimpleImputer(strategy='most_frequent')
data[:] = simple_imputer.fit_transform(data) # note: fit_transform returns numpy.ndarray -> to keep pandas dataframe, we need to use [:]

# %% [markdown]
# ## Iterative Imputer

# %% [markdown]
# Still experimental feature, but let's try if/how it works.
#
# **Score**:
# - default params: **0.98250**
# - initial_strategy = median: **0.98251**

# %%
# %%time
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer

# iterative_imputer = IterativeImputer(initial_strategy='median')
# data[:] = iterative_imputer.fit_transform(data)

# %% [markdown]
# ## KNN Inputer

# %% [markdown]
# KNN Inputer did not finished in reasonable time - the run was cancelled by Kaggle after 12hours of processing.
#
# It is not usable for the purpose of this competition.

# %%
# %%time
# from sklearn.impute import KNNImputer

# knn_imputer = KNNImputer()
# data[:] = knn_imputer.fit_transform(data)

# %% [markdown]
# # Submission

# %%
for i in tqdm(submission.index):
    row = int(i.split('-')[0])
    col = i.split('-')[1]
    submission.loc[i,'value'] = data.loc[row,col]
    
    
submission.to_csv('submission.csv')
