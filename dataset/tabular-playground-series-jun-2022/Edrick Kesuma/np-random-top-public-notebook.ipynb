# %% [markdown]
# # Np.random until I beat the original notebook in public LB (Meme notebook)

# %% [markdown]
# <img src="https://i.postimg.cc/yYVzS8Nr/rng-meme.png">

# %%
import pandas as pd

sample_sub = pd.read_csv('../input/tabular-playground-series-jun-2022/sample_submission.csv')
top_public_sub = pd.read_csv('../input/tps-jun-2022-pytorch-lightning-with-na-counts/submission.csv')

# %%
top_public_sub.describe()

# %%
# source
# https://www.kaggle.com/code/hiro5299834/tps-jun-2022-pytorch-lightning-with-na-counts/notebook?scriptVersionId=98502241
top_public_sub

# %%
from numpy import random
#from scipy.stats import yeojohnson

#top_public_sub['value'] = top_public_sub['value'].apply(lambda x: x + random.normal(0.001,0.01))
#top_public_sub


random_values_list = random.rand(len(top_public_sub)) * 10e-4
sample_sub['value'] = top_public_sub['value'] + random_values_list
sample_sub['value'] = sample_sub['value'].apply(lambda x: round(x, 4))
#sample_sub['value'], lam = yeojohnson(sample_sub['value'])
sample_sub

# %%
sample_sub.to_csv('submission.csv', index=False)

# %%
# This is just for wasting subs :)
