# %% [markdown]
# ## A quick EDA with few lines of code.
#
# Though, I am not a big fun of auto_ml and to be frank any auto as here in my opinion we need to practice writing code line by line so we could improve our skills. However, for those who want have a qiuck overview in datasets statistics and jump right into preprocessing and bulding model I decided to create this notebook. So sa you can see, with few lines of code we could have a broad overview of our dataset. In this notebook I have used two technics to get similar results. I aslo had to limited the output of the report when I was using pandas_profiling as the data was to big to create a full report nut with some smaller ones you could have nice output with lots more information about any dataset. For further reading click links below:
#
#  - https://www.analyticsvidhya.com/blog/2021/04/top-python-libraries-to-automate-exploratory-data-analysis-in-2021/
#
#  - https://pandas-profiling.ydata.ai/docs/master/index.html
#
#  - https://pypi.org/project/sweetviz/

# %%
pip install sweetviz

# %%
import pandas as pd
import numpy as np
from ipywidgets import widgets
import sweetviz

# %%
data_df = pd.read_csv("/kaggle/input/tabular-playground-series-jun-2022/data.csv")

# %%
data_df.columns

# %%
data_df

# %%
my_report = sweetviz.analyze(data_df)
# my_report.show_html('FinalReport.html')
my_report.show_notebook()

# %% [markdown]
# ## If you like my notebook, don't forget to upvote. Thank You!!!
