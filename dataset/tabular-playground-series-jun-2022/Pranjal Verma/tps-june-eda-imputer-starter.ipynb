# %% [markdown]
# ![image.png](attachment:be2db19b-8bc2-4e0a-9774-92befa0e567a.png)

# %%
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#650076','#eb3446','Boogaloo','Smokum',40,10
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h4 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h4>"""%string))
    
    
dhtml('TPS June: EDA plus Iterative Imputer Baseline' )

# %%
from IPython.display import HTML
HTML("""
<style>
h1,h2,h3 {
	margin: 1em 0 0.5em 0;
	font-weight: 600;
	font-family: 'Titillium Web', sans-serif;
	position: relative;  
	font-size: 36px;
	line-height: 40px;
	padding: 15px 15px 15px 2.5%;
	color: #13003A;
	box-shadow: 
		inset 0 0 0 1px rgba(53,86,129, 1), 
		inset 0 0 5px rgba(53,86,129, 1),
		inset -285px 0 35px #F8FFBE;
	border-radius: 0 10px 0 15px;
	background: #fff
    
}
</style>
""")

# %% [markdown]
# <h1 style="background-color:#F0C3FF;font-size:30px;color:#00033E;font-weight : bold">Imports :</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import lightgbm
import xgboost
import catboost
import gc
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# <h1 style="background-color:#F0C3FF;font-size:30px;color:#00033E;font-weight : bold">EDA:</h1>

# %%
df = pd.read_csv("../input/tabular-playground-series-jun-2022/data.csv",index_col='row_id')

# %%
df.head()

# %%
df.describe().T.style.bar(subset=['mean'], color='#606ff2')\
                            .background_gradient(subset=['std'], cmap='PuBu')\
                            .background_gradient(subset=['50%'], cmap='PuBu')

# %%
def highlight_NAN(s):
    '''
    highlight blue is value is NAN else orange.
    '''
    is_max = s.isna()
    return ['background-color: #606ff2' if i else 'background-color: #FFD6C0' for i in is_max]

# %%
df.head(20).style.apply(highlight_NAN)

# %%
# !pip install dataprep
from dataprep.eda import *

# %%
print("\033[95mShape of dataset = " , df.shape)

# %%
gc.collect()

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_0</p>

# %%
plot(df,'F_1_0',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_1</p>

# %%
plot(df,'F_1_1',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_2</p>

# %%
plot(df,'F_1_2',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_3</p>

# %%
plot(df,'F_1_3',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_4</p>

# %%
plot(df,'F_1_4',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_5</p>

# %%
plot(df,'F_1_5',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_6</p>

# %%
plot(df,'F_1_6',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_7</p>

# %%
plot(df,'F_1_7',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_8</p>

# %%
plot(df,'F_1_8',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_9</p>

# %%
plot(df,'F_1_9',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_10</p>

# %%
plot(df,'F_1_10',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_11</p>

# %%
plot(df,'F_1_11',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_12</p>

# %%
plot(df,'F_1_12',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_13</p>

# %%
plot(df,'F_1_13',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_1_14</p>

# %%
plot(df,'F_1_14',config={'hist.color': '#37C68B','kde.hist_color': '#34AA79','box.color': '#34AA79'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_0</p>

# %%
plot(df,'F_2_0',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_1</p>

# %%
plot(df,'F_2_1',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_2</p>

# %%
plot(df,'F_2_2',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_3</p>

# %%
plot(df,'F_2_3',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_4</p>

# %%
plot(df,'F_2_4',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_5</p>

# %%
plot(df,'F_2_5',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_6</p>

# %%
plot(df,'F_2_6',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_7</p>

# %%
plot(df,'F_2_7',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_8</p>

# %%
plot(df,'F_2_8',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_9</p>

# %%
plot(df,'F_2_9',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_10</p>

# %%
plot(df,'F_2_10',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_11</p>

# %%
plot(df,'F_2_11',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_12</p>

# %%
plot(df,'F_2_12',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_13</p>

# %%
plot(df,'F_2_13',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_14</p>

# %%
plot(df,'F_2_14',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_15</p>

# %%
plot(df,'F_2_15',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_16</p>

# %%
plot(df,'F_2_16',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_17</p>

# %%
plot(df,'F_2_17',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_18</p>

# %%
plot(df,'F_2_18',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_19</p>

# %%
plot(df,'F_2_19',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_20</p>

# %%
plot(df,'F_2_20',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_21</p>

# %%
plot(df,'F_2_21',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_22</p>

# %%
plot(df,'F_2_22',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_23</p>

# %%
plot(df,'F_2_23',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_2_24</p>

# %%
plot(df,'F_2_24',config={'hist.color': '#A35BB9','kde.hist_color': '#875198','box.color': '#875198'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_0</p>

# %%
plot(df,'F_3_0',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_1</p>

# %%
plot(df,'F_3_1',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_2</p>

# %%
plot(df,'F_3_2',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_3</p>

# %%
plot(df,'F_3_3',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_4</p>

# %%
plot(df,'F_3_4',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_5</p>

# %%
plot(df,'F_3_5',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_6</p>

# %%
plot(df,'F_3_6',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_7</p>

# %%
plot(df,'F_3_7',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_8</p>

# %%
plot(df,'F_3_8',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_9</p>

# %%
plot(df,'F_3_9',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_10</p>

# %%
plot(df,'F_3_10',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_11</p>

# %%
plot(df,'F_3_11',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_12</p>

# %%
plot(df,'F_3_12',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_13</p>

# %%
plot(df,'F_3_13',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_14</p>

# %%
plot(df,'F_3_14',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_15</p>

# %%
plot(df,'F_3_15',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_16</p>

# %%
plot(df,'F_3_16',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_17</p>

# %%
plot(df,'F_3_17',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_18</p>

# %%
plot(df,'F_3_18',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_19</p>

# %%
plot(df,'F_3_19',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_20</p>

# %%
plot(df,'F_3_20',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_21</p>

# %%
plot(df,'F_3_21',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_22</p>

# %%
plot(df,'F_3_22',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_23</p>

# %%
plot(df,'F_3_23',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_3_24</p>

# %%
plot(df,'F_3_24',config={'hist.color': '#DCD231','kde.hist_color': '#B7B25C','box.color': '#B7B25C'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_0</p>

# %%
plot(df,'F_4_0',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_1</p>

# %%
plot(df,'F_4_1',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_2</p>

# %%
plot(df,'F_4_2',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_3</p>

# %%
plot(df,'F_4_3',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_4</p>

# %%
plot(df,'F_4_4',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_5</p>

# %%
plot(df,'F_4_5',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_6</p>

# %%
plot(df,'F_4_6',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_7</p>

# %%
plot(df,'F_4_7',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_8</p>

# %%
plot(df,'F_4_8',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_9</p>

# %%
plot(df,'F_4_9',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_10</p>

# %%
plot(df,'F_4_10',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_11</p>

# %%
plot(df,'F_4_11',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_12</p>

# %%
plot(df,'F_4_12',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_13</p>

# %%
plot(df,'F_4_13',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:20px;color:#1C37A6;font-weight : bold">For F_4_14</p>

# %%
plot(df,'F_4_14',config={'hist.color': '#E17135','kde.hist_color': '#F19D70','box.color': '#F19D70'})

# %% [markdown]
# - <p style="font-size:25px;color:#1C37A6;font-weight : bold">HexBin plot btw all variables</p>

# %%
import gc
gc.collect()

# %%
X=['F_1_1','F_2_15','F_3_3','F_4_8']

# %%
#showing just 5 graphs for demo 
count=0
for i in X:
    for j in X:
        if i!=j:
            count+=1
            if count > 5:
                break
            else:
                plot(df,i,j,display=['Hexbin Plot'],config={'height': 500,'width':500}).show()

# %% [markdown]
# <h1 style="background-color:#F0C3FF;font-size:30px;color:#00033E;font-weight : bold">Imputer Baseline :</h1>

# %%
data = df.copy()
sub=pd.read_csv('../input/tabular-playground-series-jun-2022/sample_submission.csv',index_col='row-col')

# %%
#Reference BIZEN
imp = IterativeImputer( estimator = lightgbm.LGBMRegressor(n_estimators=100,random_state=42,device='gpu',boosting_type='gbdt'),missing_values=np.nan,max_iter=10, initial_strategy='mean', 
                                    imputation_order='ascending',verbose=2,random_state=42 )

data[:] = imp.fit_transform(data)

# %% [markdown]
# <h1 style="background-color:#F0C3FF;font-size:30px;color:#00033E;font-weight : bold">Submission:</h1>

# %%
for i in tqdm(sub.index):
    row = int(i.split('-')[0])
    col = i.split('-')[1]
    sub.loc[i, 'value'] = data.loc[row, col]

sub.to_csv("submission.csv")
sub

# %%
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#650076','#eb3446','Boogaloo','Smokum',70,10
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h4 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h4>"""%string))
    
    
dhtml('Do UPVOTE if you like my work' )

# %% [markdown]
# ![image.png](attachment:62c648ae-c843-4dae-ad5f-520510620c0f.png)
