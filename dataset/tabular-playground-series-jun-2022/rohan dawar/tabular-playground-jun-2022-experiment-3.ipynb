# %% [markdown]
# *This notebook is the Third expermentation done as a part of **Tabular Playground June 2022**, here we have been given the task to impute the values in the dataset. My Rank imporved using this method*
#
#
# Here I have experimented IterativeImputer, the details for the imputer can be obtained here:
# Link: https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html
#
# Link for 1st Notebook: https://www.kaggle.com/code/rohandawar/tabular-playground-jun-2022-experiment-2
#
# _In the notebook I am trying to implement KNN imputer_

# %%
#Importing the Libs

#General
import pandas as pd
import numpy as np

# Time tracking
from tqdm import tqdm

# Path
from pathlib import Path

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns




# Sklearn
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer



from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer


# Settings
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 300)

# %%
#reading the dataset
df = pd.read_csv('../input/tabular-playground-series-jun-2022/data.csv', index_col='row_id') # setting row_id as index column
df.head()

# %%
#reading the submission file
submission = pd.read_csv('../input/tabular-playground-series-jun-2022/sample_submission.csv', index_col='row-col') #setting row-col as index
submission.head()

# %% [markdown]
# Now that we have loaded the data, lets check the missing values & data shape for the dataframe

# %%
print('# of rows in the dataframe is: ', df.shape[0])
print('# of columns in the dataframe is: ', df.shape[1])

# %%
#missing data 
df.isnull().sum()

# %% [markdown]
# So, we see that out of the 80 columns, we have missing values in the columns with the following prefix's
#
# - F_1_X
# - F_3_X
# - F_4_X

# %% [markdown]
# As the first strategy, let's try simple imputor from sklearn taking mean as the strategy as "mean", this is also the baseline solution provided with the dataset.

# %%
# Instiate the imputor
imputer =  IterativeImputer(max_iter=10, random_state=0)

#fiting the data
data = imputer.fit_transform(df)

# Display, just curious :)
data

# %% [markdown]
# Now that we have found the missing values, we have to fill them up in the submissions file.

# %%
#converting the Numpy array to pandas df
data = pd.DataFrame(data, columns=df.columns)
data.head()

# %%
for i in tqdm(submission.index):
    row  = int(i.split('-')[0])
    col = i.split('-')[1]
    submission.loc[i, 'value'] = data.loc[row,col]
    
#save the file
submission.to_csv('submission.csv')
