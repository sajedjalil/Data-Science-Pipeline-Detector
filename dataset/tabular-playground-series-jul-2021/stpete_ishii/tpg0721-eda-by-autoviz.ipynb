# %%
# !pip install autoviz

# %%
# !pip install xlrd

# %%
import numpy as np
import pandas as pd
import os
import xlrd
from autoviz.AutoViz_Class import AutoViz_Class

# %%
df1 = pd.read_csv('../input/tabular-playground-series-jul-2021/train.csv')
df1

# %%
print(df1.columns.to_list())

# %%
AV = AutoViz_Class()
target1 = 'target_carbon_monoxide'
dft = AV.AutoViz(filename='',sep=',',depVar=target1,dfte=df1,header=0,verbose=1)

# %%
target2 = 'target_benzene'
dft = AV.AutoViz(filename='',sep=',',depVar=target2,dfte=df1,header=0,verbose=1)

# %%
target3 = 'target_nitrogen_oxides'
dft = AV.AutoViz(filename='',sep=',',depVar=target3,dfte=df1,header=0,verbose=1)
