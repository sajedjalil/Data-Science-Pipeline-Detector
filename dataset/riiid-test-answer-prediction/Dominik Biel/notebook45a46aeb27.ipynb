# %%
import pandas as pd
import dask.dataframe as dd

#data = pd.read_csv("../input/riiid-test-answer-prediction/train.csv")

# %%
import pandas as pd
import dask.dataframe as dd

dtypes = {
    "row_id": "int64",
    "timestamp": "int64",
    "user_id": "int32",
    "content_id": "int16",
    "content_type_id": "boolean",
    "task_container_id": "int16",
    "user_answer": "int8",
    "answered_correctly": "int8",
    "prior_question_elapsed_time": "float32", 
    "prior_question_had_explanation": "boolean"
}

#train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", dtype=dtypes)

print("Train size:", train.shape)

# %%
train.head()

# %%
train.memory_usage(deep=True)

# %%
train.info()

# %%
unique_users_list = train.user_id.unique().tolist()
print("Number of Unique Users are :" , len(unique_users_list))
print("{:>20}: {:>8}".format('Percentage of Unique Users are',(len(unique_users_list)/(train.shape[0])) *100))

# %%
train.describe()

# %%
train['timestamp'].hist(bins = 100)

# %%
grouped_by_user = train.groupby('user_id')

# %%
grouped_by_user.agg({'timestamp': 'max'}).hist(bins = 100)

# %%
(train['answered_correctly']==-1).mean()

# %%
train_questions_only = train[train['answered_correctly']!=-1]
train_questions_only['answered_correctly'].mean()

# %%
questions = pd.read_csv('/kaggle/input/riiid-test-answer-prediction/questions.csv')

# %%
questions

# %%
print(f"Występuje {len(questions['part'].unique())} różnych części")

# %%
questions['tags'].values[-1]

# %%
unique_tags = set().union(*[y.split() for y in questions['tags'].astype(str).values])
print(f"Występuje {len(unique_tags)} różnych tagów")

# %%
train

# %%
import numpy as np
train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", dtype=dtypes)

# Define systematic sampling function
def systematic_sampling(train, step):
    
    indexes = np.arange(0,len(train),step=step)
    systematic_sample = train.iloc[indexes]
    return systematic_sample
    
# Obtain a systematic sample and save it in a new variable
systematic_sample = systematic_sampling(train, 2000)S

# Save the sample mean in a separate variable
systematic_mean = round(systematic_sample['row_id'].mean(),2000)

# View sampled data frame
systematic_sample

# %%
systematic_sample.to_csv(r'systematic_sample.csv')

# %%
systematic_sample.head

# %%
systematic_sample.info()
