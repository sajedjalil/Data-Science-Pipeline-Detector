# %%
import torch

device = torch.cuda.get_device_name(0)
print(device)

# %%
import csv
with open('submission.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['row_id', 'answered_correctly'])
    writer.writerow([1, device])
