# %% [markdown]
# # Running C++ in Notebooks
#
# Hat tip to this discussion: https://www.kaggle.com/c/abstraction-and-reasoning-challenge/discussion/131230
#
# Since the Kaggle image has a the `gcc` compiler and `g++`, it is actually possible to run C++ code in Kaggle Notebooks.
#
# Let's see what version of `gcc` we have:

# %%
# !g++ -v

# %% [markdown]
# I've written a short test script that writes to a file called `submission.csv`. Let's take a look:

# %%
! head -n 20 /kaggle/input/c-execution-example/test_c_code.cpp

# %% [markdown]
# This file can be uploaded in a dataset or written within the notebook!
#
# Ok, let's run the code

# %%
import os
import pandas as pd

os.system("g++ /kaggle/input/c-execution-example/test_c_code.cpp && ./a.out")

# %% [markdown]
# Here's the submission file:

# %%
submission = pd.read_csv("submission.csv")
submission
