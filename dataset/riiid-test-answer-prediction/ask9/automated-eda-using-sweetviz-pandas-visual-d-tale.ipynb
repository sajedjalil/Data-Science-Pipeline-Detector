# %% [markdown]
# <font size="+2" color=blue><b> <center><u>Automated EDA using Sweetviz, Pandas Visual Analysis and D-Tale on Riid Dataset</u></center></b></font>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Kernel Goal
#
# This kernel has following objective:
# - quick EDA on given dataset using SweatviZ
# - quick EDA on given dataset using Pandas Visual Analysis
# - quick EDA on given dataset using D-Tale

# %% [markdown]
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
# <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Table of content</h3>
#
# <font color="blue" size=+1><b>Library</b></font>
# * [1. Installation](#4)
# * [2. Import Libraries ](#5)
#
# <font color="blue" size=+1><b> Load and view your data </b></font>
# * [1. Load and Explore Data](#6)
# * [2. EDA using Sweetviz](#7)
# * [3. EDA Using Pandas Profiling](#8)
#
# <font color="blue" size=+1><b> Others </b></font>
# * [1. Sources](#9)

# %% [markdown]
# <a id="1"></a>
# <font color="blue" size=+2.5><b>Introduction</b></font>

# %% [markdown]
# <a id="1"></a>
# <font color="blue" size=+2.5><b> Installation of required Libraries </b></font>
#
# Following libraries we will be installing
# - Sweetviz
# - Pandas Visual Analysis
# - D-Tale

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # SweetViz

# %% [markdown]
# ## Installation

# %%
# !pip install sweetviz

# %% [markdown]
# ## Import SweetViz

# %%
import sweetviz as sv

# %%
train_data = pd.read_csv('../input/riiid-test-answer-prediction/train.csv',nrows=100000)

# %% [markdown]
# ## Generate Report

# %%
my_report = sv.analyze(train_data)
my_report.show_html()

# %% [markdown]
# # Download HTML report from /working/output Directory

# %% [markdown]
# # Pandas Visual Analysis

# %% [markdown]
# ## Install Pandas Visual Analysis

# %%
# !pip install pandas-visual-analysis

# %% [markdown]
# ## Import Pandas Visual Analysis and Report Generation

# %%
from pandas_visual_analysis import VisualAnalysis
VisualAnalysis(train_data)

# %% [markdown]
# # D-Tale

# %% [markdown]
# ## Installation

# %%
# !pip install dtale

# %%
import dtale

# %%
dtale.show(train_data)
