# %%
import os
import numpy as np
import pandas as pd
import torch
import time
from tqdm import tqdm
import warnings

warnings.filterwarnings("ignore")

# %%
101230332/6

# %%
"""for i in range(6):
    train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=i*16871722, nrows=16871722)
    train.to_csv("train"+str(i+1)+".csv", index=False)"""

# %%
train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=0, nrows=16871722+373)
train.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']
train.to_csv("train1.csv", index=False)
train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=16871722+373, nrows=16871722+3735)
train.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']
train.to_csv("train2.csv", index=False)
train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=2*16871722+4108, nrows=16871722+300)
train.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']
train.to_csv("train3.csv", index=False)
train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=3*16871722+4408, nrows=16871722)
train.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']
train.to_csv("train4.csv", index=False)
train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=4*16871722+4108, nrows=16871722+6847)
train.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']
train.to_csv("train5.csv", index=False)
train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=5*16871722+4108+6847)
train.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']
train.to_csv("train6.csv", index=False)

# %%
373+3735+300

# %%
"""train1 = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=4*16871722+4408, nrows=16871722+6847)
train1.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']
train2 = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", skiprows=5*16871722+4108, nrows=16871722)
train2.columns = ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time', 'prior_question_had_explanation']"""

# %%
#train1[-2:]

# %%
"""for i in range(16871722):
    if train2['user_id'][i] != 1796531206:
        print(i)
        break"""

# %%
#train2[:2]

# %%
"""train = pd.read_csv("../input/riiid-test-answer-prediction/train.csv", nrows=)
lectures = pd.read_csv("../input/riiid-test-answer-prediction/lectures.csv")
questions = pd.read_csv("../input/riiid-test-answer-prediction/questions.csv")
test = pd.read_csv("../input/riiid-test-answer-prediction/example_test.csv")"""

# %%
#questions

# %%
#lectures

# %%
#set(lectures["tag"].tolist())
