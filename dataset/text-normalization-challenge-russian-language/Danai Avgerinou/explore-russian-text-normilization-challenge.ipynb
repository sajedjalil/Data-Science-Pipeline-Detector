# %% [markdown]
# # Lets explore the Russian Language Text Normilization Challenge

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

# %% [markdown]
# Loading the data

# %%
train = pd.read_csv('../input/ru_train.csv')
test = pd.read_csv('../input/ru_test_2.csv')

# %% [markdown]
# ### How does the train and test set look like?

# %%
train.head()

# %%
test.head()

# %% [markdown]
# ### How many rows and columns each set has?

# %%
train.shape

# %%
test.shape

# %% [markdown]
# ### Which are the different classes of text?

# %%
train['class'].unique()

# %% [markdown]
# ### Examples of how each class should look like after the normilization.

# %% [markdown]
# #### 1. Plain class

# %%
train[train['class'] == 'PLAIN'].head(3)

# %% [markdown]
# #### 2. Date class

# %%
train[train['class'] == 'DATE'].head(3)

# %% [markdown]
# #### 3. Punct class

# %%
train[train['class'] == 'PUNCT'].head(3)

# %% [markdown]
# #### 4. Ordinal class

# %%
train[train['class'] == 'ORDINAL'].head(3)

# %% [markdown]
# #### 5. Verbatim class

# %%
train[train['class'] == 'VERBATIM'].head(3)

# %% [markdown]
# #### 6. Letters class

# %%
train[train['class'] == 'LETTERS'].head(3)

# %% [markdown]
# #### 7. Cardinal class

# %%
train[train['class'] == 'CARDINAL'].head(3)

# %% [markdown]
# #### 8. Measure class

# %%
train[train['class'] == 'MEASURE'].head(3)

# %% [markdown]
# #### 9. Telephone class

# %%
train[train['class'] == 'TELEPHONE'].head(3)

# %% [markdown]
# #### 10. Electronic class

# %%
train[train['class'] == 'ELECTRONIC'].head(3)

# %% [markdown]
# #### 11. Decimal class

# %%
train[train['class'] == 'DECIMAL'].head(3)

# %% [markdown]
# #### 12. Digit class

# %%
train[train['class'] == 'DIGIT'].head(3)

# %% [markdown]
# #### 13. Fraction class

# %%
train[train['class'] == 'FRACTION'].head(3)

# %% [markdown]
# #### 14. Money class

# %%
train[train['class'] == 'MONEY'].head(3)

# %% [markdown]
# #### 15. Time class

# %%
train[train['class'] == 'TIME'].head(3)

# %% [markdown]
# So know that we know how our result should look like after the normilization, lets create a histogram of the frequency of each class

# %%
dict1 = dict(Counter(train['class']))
dict1

# %%
class1 = list(train['class'].unique())

# %%
names = list(dict1.keys())
values = list(dict1.values())

# %%
fig, ax = plt.subplots(1,1, figsize=(10,12))
count_classes_fig = sns.countplot(y="class", data=train, ax=ax)
for item in count_classes_fig.get_xticklabels():
    item.set_rotation(45)
