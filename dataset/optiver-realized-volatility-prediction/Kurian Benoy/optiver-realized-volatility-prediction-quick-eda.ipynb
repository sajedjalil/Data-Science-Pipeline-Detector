# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
! ls ../input/optiver-realized-volatility-prediction

# %%
df_train = pd.read_csv('../input/optiver-realized-volatility-prediction/train.csv')
df_train.head()

# %%
train_profile = ProfileReport(df_train)

# %%
train_profile.to_widgets()

# %%
train_profile.to_notebook_iframe()

# %%
df_test = pd.read_csv('../input/optiver-realized-volatility-prediction/test.csv')
df_test.head()

# %%
test_profile = ProfileReport(df_test)

# %%
test_profile.to_widgets()

# %%
test_profile.to_notebook_iframe()
