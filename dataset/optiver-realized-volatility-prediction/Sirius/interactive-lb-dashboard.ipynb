# %% [markdown]
# # Interactive LB Dashboard Using Tableau
#
# I have created an interactive dashboard using Tableau based on all the current(6 updates) here:
#
# [Optiver Interactive Tableau Dashboard](https://public.tableau.com/app/profile/trushant/viz/OptiverInteractiveLB/PositionOverTime)
#
# **Update 1 - Added line chart over time. See different tabs on top to navigate between charts**
#
# **Update 2 - 12/23 - Charts updated for 6th score update.**
#
# You can use the filters on the right to search for specific teams or filter upto N teams.
#
# Data Credit: [Carl McBride](https://www.kaggle.com/carlmcbrideellis)

# %% [markdown]
# ### Please Upvote if you find this notebook useful :)
