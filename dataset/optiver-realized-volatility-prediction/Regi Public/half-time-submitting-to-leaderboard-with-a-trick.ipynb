# %%
# Hi girls and guys, hopefully this will help you by saving you some time..

# When submitting for competition, we have to wait to get our leaderboard results;
# 1) Saving notebook for 'save and run'  (1.5 hours to create all my features),
# 2) Submitting notebook and file as a competition entry (another 1.5 hours)
#
# We can speed up part 1) by only loading a small part of data, so it runs in 2mins instead of 1.5 hours..
# Using REAL WORLD TIME and a little trick..
#
# Manually set the 'checkTime' variable, so if code executed in next e.g. 3 mins (your choice) load short file.. 
# We wait a few mins for this to be complete, then few mins later manually submit for part 2)
# By the time we do that, code will lode the full data.. 


from datetime import datetime
# Set time to time now + 3 mins (or enough time to click & start running notebook) 
# Note: check the Kaggle notebook server time relative to your country. In UK we are 1 hour ahead
# of Kaggle local time..! Check with: print('time now = ', now)

now = datetime.now()   
checkTime = datetime(2021, 9, 19, 21, 43)  #  <--- Set time here: year, month, day, hour, min
print('time now = ', now)
if now <= checkTime:
    print('Calculate on only 2 stocks of data')
    # output is a list of a dict of our features..
    add_features_train = features_all_stocks(dir_book_train[:2])  
else:
    print('Calculate on full 112 stocks of data')
    # output is a list of a dict of our features..
    add_features_train = features_all_stocks(dir_book_train)  


print('Calc features for test file data..')
add_features_test = features_all_stocks(dir_book_test)

# Rich O'Regan woz here - in cloudy London..
