# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# @felipefonte99  added the LB intermediate results in a spreadsheet. I use the data to visuzlise the shakeup
# https://www.kaggle.com/c/optiver-realized-volatility-prediction/discussion/278743

# %%
shakeup=pd.read_csv("../input/optiver-shakeup/Optiver Kaggle 2021 Leaderboard - Sheet1.csv")
shakeup["Change in Rank"]= shakeup["Rank 27 Sep"] -shakeup["Rank 14 Oct"]
shakeup

# %%
shakeup = shakeup.dropna(how='any')           
shakeup.dropna(how='any', inplace=True)  
shakeup

# %%
import plotly.express as px
fig = px.scatter(shakeup, x="Rank 14 Oct", y="Rank 27 Sep", color="Change in Rank",
                 hover_data=['Team Name'])
fig.show()
