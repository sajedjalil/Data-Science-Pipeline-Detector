# %% [markdown]
# There has been another [post](https://www.kaggle.com/c/coleridgeinitiative-show-us-the-data/discussion/231374) about it, but just to be sure: I use data from the [RichContextCompetition](https://coleridgeinitiative.org/richcontext/richcontextcompetition).

# %%
# !wget https://public.boxcloud.com/d/1/b1!hgLdekGieZ-ivH-FG_QHv_8JRnWQ-0I1eAaaRD3ou0SUw5wDz54G442BfxuinSd5v2KjzI7e0bANb0jzUObKwYeOZat8Dq_mvcDcsPm9VNQc1tNoGd_NhzXZW5FrGfbkdmikPJqOe7u03k3yjX2IwKVPiWXaCi6o03w9PgUiUPq75Aph86nYniqXdlH_qxVvg4hiC0xob3kat6eXH18EZMH7N-DZ6bygoe4fAR-bKmD9V3GZP_LaxecTBZWLVyieBzEBIaC0QUz2GDiHi68sfWHN4T2G6XGri1VzyMsR-qpAJcJION6Q3xQ5fer-9_ta1fsCWSZW4Cvo0DuO22Bo_FaKxEr7GcDLaeUVYIXCfvcQoXd3fZTyn-hyiu68-hnNECV5umXG1K0f6jlFmDjb5E1AStr74qLsTzWduw0QbjDYHO1mUUtVX2hVby-osBDbPe0G_qZw6F9NcEguNSlstOa-cMQmsUzFfcUfjfFuEwmV4tOzcrgLQ2a_qGkNWnemtpPzcR1a8uaVta6fNwJZm2pKCMh5ckjjT33ArwHtAuCVoB6iwQm7Y8Zn4AXlGzeSYjTZ1jdXKpjit9zpWX4vjKz_qwOaEwarKKRcWuituqQIRzBO41ARMcMuMJ6lwdSMwHOKt-CIZnQzsV4YbHJcD6BTs0L9j8pg0WVZirztYTIGkgSo0KWdUnp3RfJXtfWC8eDtZJcNG_vUe5SyaH23PHvXRPFp6dz8k7dR2btYNKwHy8Hyf3jT5RLyiYAsypyNDbMKzSK439FAKBMOwCYbm42-iIfkjjrlSSWvB6lQUGUHHOgZ0HThNdq016z7eEqKSy0hZJwd3HXRQP5UqPwQgjCDK5QtK--rzBow53hurzjLfea6cKW3SotJ8ZZTplYSztDs2w8TrJsAWDYquWQbjTZuDyGOwDMKlGLxosvklBg3dp3D7NNlQf7wdSVCZZlsYmiPissbEZ1MO38M0Jptv79G4XCujLW1HRtcOtuGa8qKyJ9eh-sBNMsszNpGxfAtHN_JyrERMOa5bqxvF6AglP_ssIOayra-48B9qolkRt_g1AU-lhM5X4jpfHr0TY0bRwVNilDH_wVVtLsxJn-dxTpv6SRx_7tyLoW0DHhd95ZEQ5E-UUWSZPqszNlVU5xn6mL_lIOxWVd9-DpvU9mws4ZzOaf8Tpq9bTvFt1shCVOSJjjNniIxssKez80Q-s8tI_N89FHIDKrW0bquW9EtosNVplUtyhwZLd3BHyYzKtymvIL-_feEi-e6tyx26emAB7Y9NUxtihvVAFc6A8py5Q../download

# %%
# !ls -l --block-size=MB

# %%
# !tar -xvf ./download

# %%
# !ls -l --block-size=MB

# %%
# !rm ./download
