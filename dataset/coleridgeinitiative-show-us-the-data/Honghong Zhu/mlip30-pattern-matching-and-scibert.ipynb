# %% [markdown]
# # MLiP 30: Coleridge Initiave using Pattern Matching and SciBERT
#
# This notebook is created for the challeng "Coleridge Inititive - Show US the Data" and is part of the course NWI-IMC030 Machine Learning in Practice. We used the notebook [Coleridge: Matching + BERT NER](https://www.kaggle.com/tungmphung/coleridge-matching-bert-ner) by Tung M Phung as our baseline. Therefore, most of the notebook is similar to that notebook. The changes we made compared to the baseline notebook are:
# 1. Using SciBERT as the pretrained model instead of BERT.
# 2. Implementation of pattern matching (`characteristic_pattern_match()`) and use it to extract relevant sentences.

# %%
This notebook gives a simple combination of literal matching, pattern matching and Named Entity Recognition using SciBERT.

The training phase of the SciBERT model was done in another kernel.

# %%
MAX_SAMPLE = None # set a small number for experimentation, set None for production.

# %% [markdown]
# # Install packages

# %%
# !pip install datasets --no-index --find-links=file:///kaggle/input/coleridge-packages/packages/datasets
# !pip install ../input/coleridge-packages/seqeval-1.2.2-py3-none-any.whl
# !pip install ../input/coleridge-packages/tokenizers-0.10.1-cp37-cp37m-manylinux1_x86_64.whl
# !pip install ../input/coleridge-packages/transformers-4.5.0.dev0-py3-none-any.whl

# %% [markdown]
# # Import

# %%
import os
import re
import json
import time
import datetime
import random
import glob
import importlib

import numpy as np
import pandas as pd

from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

random.seed(123)
np.random.seed(456)

# %% [markdown]
# # Load data

# %%
train_path = '../input/coleridgeinitiative-show-us-the-data/train.csv'
train = pd.read_csv(train_path)
train = train[:MAX_SAMPLE]

paper_train_folder = '../input/coleridgeinitiative-show-us-the-data/train'
papers = {}
for paper_id in train['Id'].unique():
    with open(f'{paper_train_folder}/{paper_id}.json', 'r') as f:
        paper = json.load(f)
        papers[paper_id] = paper

# %%
sample_submission_path = '../input/coleridgeinitiative-show-us-the-data/sample_submission.csv'
sample_submission = pd.read_csv(sample_submission_path)

paper_test_folder = '../input/coleridgeinitiative-show-us-the-data/test'
for paper_id in sample_submission['Id']:
    with open(f'{paper_test_folder}/{paper_id}.json', 'r') as f:
        paper = json.load(f)
        papers[paper_id] = paper

# %% [markdown]
# # Literal matching

# %% [markdown]
# ### Create a knowledge bank

# %%
# Create a knowledge bank from all labels present in the data
all_labels = set()

for label_1, label_2, label_3 in train[['dataset_title', 'dataset_label', 'cleaned_label']].itertuples(index=False):
    all_labels.add(str(label_1).lower())
    all_labels.add(str(label_2).lower())
    all_labels.add(str(label_3).lower())
    
print(f'No. different labels: {len(all_labels)}')

# %% [markdown]
# ### Matching on test data

# %%
# Clean out characters other than text
def clean_text(txt):
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower()).strip()

def totally_clean_text(txt):
    txt = clean_text(txt)
    txt = re.sub(' +', ' ', txt)
    return txt

# %%
# Literal matching
literal_preds = []

for paper_id in sample_submission['Id']:
    paper = papers[paper_id]
    text_1 = '. '.join(section['text'] for section in paper).lower()
    text_2 = totally_clean_text(text_1)
    labels = set()
    for label in all_labels:
        if label in text_1 or label in text_2:
            labels.add(clean_text(label))
    
    literal_preds.append('|'.join(labels))

# %%
literal_preds[:5]

# %% [markdown]
# # Bert prediction

# %% [markdown]
# ### Paths and Hyperparameters

# %%
MAX_LENGTH = 64 # max no. words for each sentence.
OVERLAP = 20 # if a sentence exceeds MAX_LENGTH, we split it to multiple sentences with overlapping

PREDICT_BATCH = 64000 
# Use coleridge-scibert-models instead of coleridge-bert-models in the paths
PRETRAINED_PATH = '../input/coleridge-scibert-models/output/checkpoint-60000'
TEST_INPUT_SAVE_PATH = './input_data'
TEST_NER_DATA_FILE = 'test_ner_input.json'
TRAIN_PATH = '../input/coleridge-scibert-models/train_ner.json'
VAL_PATH = '../input/coleridge-scibert-models/train_ner.json'

PREDICTION_SAVE_PATH = './pred'
PREDICTION_FILE = 'test_predictions.txt'

# %% [markdown]
# ### Transform data to NER format

# %% [markdown]
# Group by publication, training labels should have the same form as expected output.

# %%
train = train.groupby('Id').agg({
    'pub_title': 'first',
    'dataset_title': '|'.join,
    'dataset_label': '|'.join,
    'cleaned_label': '|'.join
}).reset_index()

print(f'No. grouped training rows: {len(train)}')

# %%
# Clean function without lowercasing and a function for shortening sentences to a specified MAX_LENGTH
def clean_training_text(txt):
    """
    similar to the default clean_text function but without lowercasing.
    """
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt)).strip()

def shorten_sentences(sentences):
    short_sentences = []
    for sentence in sentences:
        words = sentence.split()
        if len(words) > MAX_LENGTH:
            for p in range(0, len(words), MAX_LENGTH - OVERLAP):
                short_sentences.append(' '.join(words[p:p+MAX_LENGTH]))
        else:
            short_sentences.append(sentence)
    return short_sentences

# %%
# Pattern matching without sentence cutting
# For sentence cutting uncomment the intersect function and switch the return to intersect(sw,scl,tc, sentence)

def characteristic_pattern_match(sentence):
    sentence = sentence.replace('-',' ')
    sw = re.findall(r"(dataset|database|data|study|model|survey)", sentence.lower()) #keywords 
    scl = re.findall(r"(([A-Z][a-z]+\s((in|and|of|by|in|the|a)\s)*)+[A-Z][a-z]+)", sentence) #sequence of words starting with a capital letter connected by connection words
    tc = re.findall(r"(\w*[A-Z]\w*[A-Z]\w*)", sentence) #at least two caps in one word
#     return intersect(sw,scl,tc, sentence)
    return sw or scl or tc

# def intersect(sw,scl,tc, sentence):
#     comb = ""
#     if sw:
#         for s in sw:
#             comb = comb + ' '+ s
#     if scl:
#         for sc in scl:
#             comb = comb + ' '+ sc[0]
#     if tc:
#         for t in tc:
#             comb = comb + ' '+ t
#     out = [word for word in sentence.split(' ') if word in comb]
#     output = ''
#     for o in out:
#         output += o+' '
#     return output

# %%
test_rows = [] # test data in NER format
paper_length = [] # store the number of sentences each paper has

for paper_id in sample_submission['Id']:
    # load paper
    paper = papers[paper_id]
    
    # extract sentences
    sentences = [clean_training_text(sentence) for section in paper 
                 for sentence in section['text'].split('.')
                ]
    sentences = shorten_sentences(sentences) # make sentences short
    # Without sentence cutting:
    sentences = [sentence for sentence in sentences if characteristic_pattern_match(sentence)]
    # With sentence cutting:
#     sentences = [characteristic_pattern_match(sentence) for sentence in sentences if characteristic_pattern_match(sentence) != '']
        
    # collect all sentences in json
    for sentence in sentences:
        sentence_words = sentence.split()
        dummy_tags = ['O']*len(sentence_words)
        test_rows.append({'tokens' : sentence_words, 'tags' : dummy_tags})
    
    # track which sentence belongs to which data point
    paper_length.append(len(sentences))
    
print(f'total number of sentences: {len(test_rows)}')

# %% [markdown]
# ### Do predict and collect results

# %%
os.environ["MODEL_PATH"] = f"{PRETRAINED_PATH}"
os.environ["TRAIN_FILE"] = f"{TRAIN_PATH}"
os.environ["VALIDATION_FILE"] = f"{VAL_PATH}"
os.environ["TEST_FILE"] = f"{TEST_INPUT_SAVE_PATH}/{TEST_NER_DATA_FILE}"
os.environ["OUTPUT_DIR"] = f"{PREDICTION_SAVE_PATH}"

# %%
# copy my_seqeval.py to the working directory because the input directory is non-writable
# !cp /kaggle/input/coleridge-packages/my_seqeval.py ./

# make necessart directories and files
os.makedirs(TEST_INPUT_SAVE_PATH, exist_ok=True)

# %%
def bert_predict():
    # !python ../input/kaggle-ner-utils/kaggle_run_ner.py \
    --model_name_or_path "$MODEL_PATH" \
    --train_file "$TRAIN_FILE" \
    --validation_file "$VALIDATION_FILE" \
    --test_file "$TEST_FILE" \
    --output_dir "$OUTPUT_DIR" \
    --report_to 'none' \
    --seed 123 \
    --do_predict

# %%
bert_outputs = []

for batch_begin in range(0, len(test_rows), PREDICT_BATCH):
    # write data rows to input file
    with open(f'{TEST_INPUT_SAVE_PATH}/{TEST_NER_DATA_FILE}', 'w') as f:
        for row in test_rows[batch_begin:batch_begin+PREDICT_BATCH]:
            json.dump(row, f)
            f.write('\n')
    
    # remove output dir
    # !rm -r "$OUTPUT_DIR"
    
    # do predict
    bert_predict()
    
    # read predictions
    with open(f'{PREDICTION_SAVE_PATH}/{PREDICTION_FILE}') as f:
        this_preds = f.read().split('\n')[:-1]
        bert_outputs += [pred.split() for pred in this_preds]

# %% [markdown]
# ### Restore Dataset labels from predictions

# %%
# get test sentences
test_sentences = [row['tokens'] for row in test_rows]

del test_rows

# %%
bert_dataset_labels = [] # store all dataset labels for each publication

for length in paper_length:
    labels = set()
    for sentence, pred in zip(test_sentences[:length], bert_outputs[:length]):
        curr_phrase = ''
        for word, tag in zip(sentence, pred):
            if tag == 'B': # start a new phrase
                if curr_phrase:
                    labels.add(curr_phrase)
                    curr_phrase = ''
                curr_phrase = word
            elif tag == 'I' and curr_phrase: # continue the phrase
                curr_phrase += ' ' + word
            else: # end last phrase (if any)
                if curr_phrase:
                    labels.add(curr_phrase)
                    curr_phrase = ''
        # check if the label is the suffix of the sentence
        if curr_phrase:
            labels.add(curr_phrase)
            curr_phrase = ''
    
    # record dataset labels for this publication
    bert_dataset_labels.append(labels)
    
    del test_sentences[:length], bert_outputs[:length]

# %%
bert_dataset_labels[:5]

# %% [markdown]
# ### Filter based on Jaccard score and clean

# %%
# Calculate the difference between true labels and SciBERT predicted labels
def jaccard_similarity(s1, s2):
    l1 = s1.split(" ")
    l2 = s2.split(" ")    
    intersection = len(list(set(l1).intersection(l2)))
    union = (len(l1) + len(l2)) - intersection
    return float(intersection) / union

filtered_bert_labels = []

for labels in bert_dataset_labels:
    filtered = []
    
    for label in sorted(labels, key=len):
        label = clean_text(label)
        if len(filtered) == 0 or all(jaccard_similarity(label, got_label) < 0.75 for got_label in filtered):
            filtered.append(label)
    
    filtered_bert_labels.append('|'.join(filtered))

# %%
filtered_bert_labels[:5]

# %% [markdown]
# # Aggregate final predictions and write submission file

# %%
final_predictions = []
for literal_match, bert_pred in zip(literal_preds, filtered_bert_labels):
    if literal_match:
        final_predictions.append(literal_match)
    else:
        final_predictions.append(bert_pred)

# %%
sample_submission['PredictionString'] = final_predictions
sample_submission.head()

# %%
sample_submission.to_csv(f'submission.csv', index=False)
