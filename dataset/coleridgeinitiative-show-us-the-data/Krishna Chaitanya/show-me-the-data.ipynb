# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
os.listdir('/kaggle/input/coleridgeinitiative-show-us-the-data')

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 1. Data Exploration

# %%
traindf=pd.read_csv('/kaggle/input/coleridgeinitiative-show-us-the-data/train.csv')
print(traindf.shape)
traindf.head()

# %% [markdown]
# Columns description
# 1. id (publication id) - note that there are multiple rows for some training documents, indicating multiple mentioned datasets
# 1. pub_title -  publication title (a small number of publications have the same title)
# 1. dataset_title - the title of the dataset that is mentioned within the publication
# 1. dataset_label - a portion of the text that indicates the dataset
# 1. cleaned_label - the dataset_label, as passed through the clean_text function from the Evaluation page

# %%
sample_sub_df=pd.read_csv('/kaggle/input/coleridgeinitiative-show-us-the-data/sample_submission.csv')
print(sample_sub_df.shape)
sample_sub_df.head()

# %%
len(traindf['dataset_title'].unique())

# %%
len(traindf['dataset_label'].unique())

# %%
len(traindf['cleaned_label'].unique())

# %% [markdown]
# cleaned_label and dataset_label values looks similar and number of unique values are same too, cross verifying it

# %%
traindf['cleaned_label'].equals(traindf['dataset_label'].str.lower())

# %% [markdown]
# cleaned_label and dataset_label values are not same

# %% [markdown]
# Picking up couple of json file and analyzing them

# %%
import json
with open('../input/coleridgeinitiative-show-us-the-data/train/0007f880-0a9b-492d-9a58-76eb0b0e0bd7.json') as f:
    sample = json.load(f)
    
    
jsondf= pd.json_normalize(sample)
jsondf

# %%
with open('../input/coleridgeinitiative-show-us-the-data/train/0008656f-0ba2-4632-8602-3017b44c2e90.json') as f:
    sample = json.load(f)
    
    
jsondf= pd.json_normalize(sample)
jsondf
