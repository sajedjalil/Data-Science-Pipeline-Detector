# %% [markdown]
# # Adding Data to the Notebook

# %% [markdown]
# Coming back to Kaggle after a long break of more than two years, I realized the data is not there in /kaggle/input/ folder as it used to be earlier. A lot of people who will be coming back to Kaggle might be facing the same issue. So, here is a small help.

# %% [markdown]
# Search this sign at the top right corner of the notebook
#
# ![image.png](attachment:1bdb348c-8b7a-44fa-8d40-d640fed8b97f.png)
#
#
# Click on it to expand the section
#
# Search for add data section just below the arrow sign
#
# ![image.png](attachment:8385c053-5163-484f-a80b-8badba9701e1.png)
#
# Click on add data
#
# Select Competition Data and Search the competition name
#
# ![image.png](attachment:47bd7b68-8b9f-4469-a828-c843a33cc625.png)
#
# Click on add icon and it will create a folder inside the notebook on the top right corner.
#
# ![image.png](attachment:f96cb183-027a-4278-ab4f-3b9a5f000485.png)

# %%
import os
os.listdir('../input/mens-march-mania-2022/MDataFiles_Stage1/')

# %% [markdown]
# Thanks!
