# %%
#IMPORT LIBRARIES

import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from collections import Counter

# %% [markdown]
# Thid notebook is highly insired from <a href="https://www.kaggle.com/dhananjay3/ncaam-2021-eda-all-you-need-to-know">DHANANJAY RAUT<a> notebook.please make upvote on his notebook.

# %% [markdown]
# ## Data Section 1: MTeams.csv

# %%
# load dataset 
teams = pd.read_csv('../input/mens-march-mania-2022/MDataFiles_Stage1/MTeams.csv')
teams.head(5)

# %% [markdown]
# This file identifies the different college teams present in the dataset. Each school is uniquely identified by a 4 digit id number. You will not see games present for all teams in all seasons, because the games listing is only for matchups where both teams are Division-I teams.There are 358 teams currently in Division-I.
#
# - **TeamID** : a 4 digit id number, from 1000-1999 and Uniquely Identified.A school's TeamID does not change from one year to the next, so for instance the Duke men's TeamID is 1181 for all seasons.To avoid possible confusion between the men's data and the women's data Men's team ID's range from 1000-1999 and women's team ID's range from 3000-3999.
#
# - **TeamName**: a compact spelling of the team's college name, 16 characters or fewer.here are no commas or double-quotes in the team names but some charecter are not in letter space.
#
# - **FirstD1Season** :the first season in our dataset that the school was a Division-I school.Many schools were Division-I far earlier than 1985, but since we don't have any data included prior to 1985, all such teams are listed with a FirstD1Season of 1985.
#
# - **LastD1Season**: It also from Division-I.For any teams that are currently Division-I, they will be listed with LastD1Season=2022, and you can confirm there are 358 such teams.

# %%
# teams rows and columns
print('Teams rows', teams.shape[0])
print('Teams Cols', teams.shape[1])

# %%
teams.FirstD1Season.value_counts()

# %%
fig = plt.figure(figsize=(5, 10))
sns.countplot(data=teams, y='FirstD1Season');
plt.show()

# %%
teams['years_in_d1'] = teams['LastD1Season'] - teams['FirstD1Season']

teams['years_in_d1'].hist(bins=20, figsize=(12,8))
plt.grid(False)
plt.title('Number of Years in Division 1', fontsize=16)
plt.show()

# %%
teams.FirstD1Season.hist(bins=20, alpha=0.7, label='First Season', figsize=(12,8))
teams.LastD1Season.hist(bins=20, alpha=0.7, label='Last Season', figsize=(12,8))
plt.grid(False)
plt.legend()
plt.title('Distribution of First and Last Season in D1', fontsize=16)
plt.show()

# %% [markdown]
# ## Data Section 2:  MSeasons.csv

# %%
seasons= pd.read_csv('../input/mens-march-mania-2022/MDataFiles_Stage1/MSeasons.csv')
seasons.head(5)

# %% [markdown]
# This dataset refers to:
# - **Season** : ndicates the year in which the tournament was played. Remember that the current season counts as 2022.
#
# - **DayZero** : tells you the date corresponding to DayNum=0 during that season. All game dates have been aligned upon a common scale so that (each year) the Monday championship game of the men's tournament is on DayNum=154. Working backward, the national semifinals are always on DayNum=152, the "play-in" games are on days 135, Selection Sunday is on day 132, the final day of the regular season is also day 132, and so on.
#
#
# - **RegionW, RegionX, Region Y, Region Z** : by our contests' convention, each of the four regions in the final tournament is assigned a letter of W, X, Y, or Z. Whichever region's name comes first alphabetically, that region will be Region W. And whichever Region plays against Region W in the national semifinals, that will be Region X.For the other two regions, whichever region's name comes first alphabetically, that region will be Region Y, and the other will be Region Z.

# %%
# seasons rows and columns
print('seasons rows', seasons.shape[0])
print('seasons Cols', seasons.shape[1])

# %%
seasons.RegionW.value_counts()

# %%
seasons.RegionZ.value_counts()

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data=seasons, x='RegionW');
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data=seasons, x='RegionX');
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data=seasons, x='RegionY');
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.countplot(data=seasons, x='RegionZ');
plt.show()

# %% [markdown]
# ## Data Section 3:  MNCAATourneySeeds.csv

# %%
MNCAATseeds=pd.read_csv('../input/mens-march-mania-2022/MDataFiles_Stage1/MNCAATourneySeeds.csv')
MNCAATseeds.head(5)

# %% [markdown]
# This dataset refers to:
# - **Season** :the year that the tournament was played in.
# - **Seed** : this is a 3/4-character identifier of the seed, where the first character is either W, X, Y, or Z (identifying the region the team was in) and the next two digits (either 01, 02, ..., 15, or 16) tell you the seed within the region. For play-in teams, there is a fourth character (a or b) to further distinguish the seeds, since teams that face each other in the play-in games will have seeds with the same first three characters.
#
# - **TeamID**: this identifies the id number of the team, as specified in the MTeams.csv file.

# %%
# seasons rows and columns
print('MNCAATseeds rows', MNCAATseeds.shape[0])
print('MNCAATseeds Cols', MNCAATseeds.shape[1])

# %%
fig = plt.figure(figsize=(5, 10))
sns.countplot(data=MNCAATseeds, y='Season');
plt.show()

# %%
fig = plt.figure(figsize=(5, 20))
sns.countplot(data=MNCAATseeds, y='Seed');
plt.show()

# %% [markdown]
# ### Data Section 4: MRegularSeasonCompactResult

# %%
MregularSC= pd.read_csv('../input/mens-march-mania-2022/MDataFiles_Stage1/MRegularSeasonCompactResults.csv')
MregularSC.head()

# %%
# seasons rows and columns
print('MregularSC rows', MregularSC.shape[0])
print('MregularSC Cols', MregularSC.shape[1])

# %%
MregularSC['point_diff'] = MregularSC.WScore - MregularSC.LScore
MregularSC.point_diff.hist(bins=30, figsize=(12,8))
plt.grid(False)
plt.title('Point difference distribution in the regular season', fontsize=16)
plt.show()

# %%
summaries = MregularSC[['Season', 'WLoc',
    'WScore', 
    'LScore', 
    'NumOT', 
    'point_diff']].groupby(['Season', 'WLoc']).agg(['min', 'max', 'mean', 'median', 'count'])

summaries.columns = ['_'.join(col).strip() for col in summaries.columns.values]
summaries

# %% [markdown]
# ### Data Section 5: WRegularSeasonCompactResults.csv

# %%
MregularScR= pd.read_csv('../input/mens-march-mania-2022/MDataFiles_Stage1/MRegularSeasonCompactResults.csv')
MregularScR.head()

# %%
# seasons rows and columns
print('MregularScR rows', MregularScR.shape[0])
print('MregularScR Cols', MregularScR.shape[1])

# %%
MregularScR.describe()

# %%
MregularScR['point_diff'] = MregularScR.WScore - MregularScR.LScore
MregularScR.point_diff.hist(bins=30, figsize=(12,8))
plt.grid(False)
plt.title('Point difference distribution in the regular season', fontsize=16)
plt.show()

# %% [markdown]
# Update comming, Dont forget to upvote please.
