# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
submission = pd.read_csv("../input/tabular-playground-series-nov-2021/sample_submission.csv")
submission.head()

# %%
sub1= pd.read_csv("../input/women-mania/submission (2).csv")
#
sub1.head()

# %%
sub2= pd.read_csv("../input/women-mania/submission (3).csv")
#
sub2.head()

# %%
sub3= pd.read_csv("../input/women-mania/submission (4).csv")
#
sub3.head()

# %%
#pre=sub1["target"].round(3)

# %%
inference = submission.copy(deep=True).drop("Pred", axis=1)

# %%
inference.loc[:, "sub1"] = sub1.Pred.values
inference.loc[:, "sub2"] = sub2.Pred.values
inference.loc[:, "sub3"] = sub3.Pred.values
#inference.loc[:, "sub4"] = sub4.target.values
inference.head()

# %%
submission.loc[:,"Pred"] = inference.drop("ID", axis=1).mean(axis=1)
submission.head()

# %%
submission.to_csv("submission.csv", index=False)

# %%
submission.loc[:, "Pred"] = (0.20*inference.sub1.values+0.30*inference.sub2.values+
                             0.50*inference.sub3.values)

# %%
submission.to_csv("submission_2.csv", index=False)
