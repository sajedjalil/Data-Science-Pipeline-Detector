# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import random
import sys
from tqdm.autonotebook import tqdm
import seaborn as sns
import glob

# %%
train_data = pd.read_csv('../input/hotel-id-2021-fgvc8/train.csv')
s1 = pd.read_csv('../input/hotel-id-2021-fgvc8/sample_submission.csv')

# %%
print('Train samples:', len(train_data))
print('Chains =', len(('../input/hotel-id-2021-fgvc8/train_images')))

# %%
train_data.head()

# %%
train_data.info()

# %%
print('Chain IDs = ', len(train_data['chain'].unique()))

# %%
print('Hotel IDs =', len(train_data['hotel_id'].unique()))

# %%
train_data.groupby(['chain', 'hotel_id']).count()

# %%
train_data['chain'].value_counts()

# %%
pred = s1.copy()
pred['hotel_id'] = 5398
pred.to_csv('submission.csv', index=False)
pred
