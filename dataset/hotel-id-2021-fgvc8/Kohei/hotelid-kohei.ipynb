# %%
# !ls -lha /kaggle/input/

# %%
# !pip -q install /kaggle/input/pekolib-deps/*.whl &&\
 pip -q install /kaggle/input/d/confirm/pekolib/*.whl &&\
 pip -q install /kaggle/input/d/confirm/geometricdeps/*.whl

# %%
# !cp -r /kaggle/input/pekolib-deps/inplace_abn-1.0.12/inplace_abn /tmp/inplace_abn && cd /tmp/inplace_abn && pip -q install .
# !python -m peko.subs.hotelid.v44
# !head submission.csv
