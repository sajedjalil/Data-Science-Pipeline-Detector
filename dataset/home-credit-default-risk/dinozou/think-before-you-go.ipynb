# %% [markdown]
# # <font color="red"> Let's be patient, Three Month!! NO hurry at all,  Focusing on the quality of work. This is not only about data. It requires a strong business understanding</font>
#
# # People tends to see themselves as a quick thinker and self-esteemed for that habit. But, did we forget one thing? Every Business Problem should have a high level overview and then dive into detail. It is much more like the power of ten, power of nine, power of eights, ....., to the power of one, to the power of minus one,......  <font color="red"> Programming is a tool to use.  It is not something you go out and show off </font>
#
# ## Then question Homecredit asks is can we give out the load to the person who has less credit record and other information. So, it is hard for their system to predict if a next new person comes to their office and ask for loan, how can they use machine learning algorithm to predict if that person could return the payments. So, the homecredit could have less risk of worrying about if people has the ability to return the money.

# %% [markdown]
# # As a beginner,  I ask myself: what should I do to solve this problem?
#     - Making a plan and understand the business problem.  - so, let's search a Youtube video to understand more about the business of HomeCredit
#      Here is the link <a href="https://www.youtube.com/watch?v=AqTs5aGC5B4" > More insights about what HOME CREDIT do</a>
#
#  # Value
#    - The value of this project is to helping HOME CREDIT better predict whom they should give the loan
#    - So which feature is the feature for prediction?
#
#       The feature:   TARGET should be our focus !!! We need to use algorithm to predict if we should given the people loan based on the data we have gathered from them
#
#
#   Some possible concerns aheads:
#   We should pay attention of the issue of overfitting
#
#
#
# # Algorithm to choose:
# Couple thngs come to my mind.
# 1st: this is a supervising learning machine learning probelm because it dose not require us to find the cluster in the dataset
#
# Possible Algorithm:
#  - Logistic Regression
# -  Decision Trees
# - Naive Bayes
# - Boosting Gradient Descent

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
PATH = "../input"

# Let's try to understand how to work with kaggle kernel
# Any results you write to the current directory are saved as output.

# %%
#Let's first explore then application train and import the data
# It takes time to importing the data because the adta set is large
application_train = pd.read_csv(PATH+"/application_train.csv")
application_test = pd.read_csv(PATH+"/application_test.csv")
bureau = pd.read_csv(PATH+"/bureau.csv")
bureau_balance = pd.read_csv(PATH+"/bureau_balance.csv")
credit_card_balance = pd.read_csv(PATH+"/credit_card_balance.csv")
installments_payments = pd.read_csv(PATH+"/installments_payments.csv")
previous_application = pd.read_csv(PATH+"/previous_application.csv")
POS_CASH_balance = pd.read_csv(PATH+"/POS_CASH_balance.csv")

# %% [markdown]
# ## Data model
#
# The structure of the data is explained in the following image (from the data description on the competition page)
#
# <img src="https://storage.googleapis.com/kaggle-media/competitions/home-credit/home_credit.png" width="800"></img>
#
# The dataframe *application_train* and *application_test* contains the loan and loan applicants. The dataframe *bureau* contains the application data from other loans that the client took from other credit institutions and were reported to the credit bureau. The dataframe *previous_applications* contains information about previous loans at **Home Credit** by the same client, previous loans information and client information at the time of the loan (there is a line in the dataframe per previous loan application).
#
# **SK_ID_CURR** is connecting the dataframes *application_train*|*test* with *bureau*, *previous_application* and also with dataframes *POS_CASH_balance*, *installments_payment* and *credit_card_balance*. **SK_ID_PREV** connects dataframe *previous_application* with *POS_CASH_balance*, *installments_payment* and *credit_card_balance*. **SK_ID_BUREAU** connects dataframe *bureau* with dataframe *bureau_balance*.

# %% [markdown]
# ## **Let's exploring the data**

# %%
# This task is very big. Let's use some giants shoulders to get things around and understand how to operate
# One thing to notice: you should write your code in a more readable way
print("application_train - rows:", application_train.shape[0],"columns:", application_train.shape[1])
print("application_test - rows:", application_test.shape[0],"columns:", application_test.shape[1])
print("bureau - rows:", bureau.shape[0],"columns:", bureau.shape[1])
print("bureau_balance - rows:", bureau_balance.shape[0],"columns:", bureau_balance.shape[1])
print("credit_card_balance - rows:", credit_card_balance.shape[0],"columns:", credit_card_balance.shape[1])
print("installments_payments - rows:", installments_payments.shape[0],"columns:", installments_payments.shape[1])
print("previous_application - rows:", previous_application.shape[0],"columns:", previous_application.shape[1])
print("POS_CASH_balance - rows:", POS_CASH_balance.shape[0],"columns:", POS_CASH_balance.shape[1])
# In here, we could see our dataset is not following the 80% - 20% rule
print(float(307511)/(307511+48744))

# %% [markdown]
# Application _train seems like having the most columns.  And other things like previous_application also have many things to consider.
# ## <font color="blue">Let's explore how many features we need to process in our entire dataset</font>
# ## Remeber, we have a HomeCredit_columns_description excel sheet. This excel sheet contains about 221 rows

# %% [markdown]
#  #  <font color="orange"> Processing the first dataset </font>

# %% [markdown]
# ## There are so many columns appears in here. And I have discovered many missing values.
# ## As I remebered in the class, the martrix with a lot of missing value
#         - And most of values has been adjusted for making computing less faster
#         - We have some categorical data we need to take care
#         - Let's review the homework I did for freshing my memotryw -- this is very similar to mushroom problem

# %%
application_train.head(10)

# %% [markdown]
# # Let's make some guesses about which features are the most important ?
# I think -- just based on my little understanding about how to solve it.
# AMT_INCOME_TOTAL
# AMT_CREDIT
# AMT_ANNUITY
# AMT_GOODS_PRICE
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# OCCUPATION_TYPE

# %%
# Spliting the dataset
y = application_train['TARGET'] # this is the label we could use for making the prediction
# Drop one column in application train
application_train.drop('TARGET', axis=1, inplace = True)

# %%
X = application_train

# %%
# I want to see the heatmap for those attributes. This couold take very long time to process
import seaborn as sns
matrix = X
corr = matrix.corr()
fig, ax = plt.subplots(figsize=(100,100))
sns.heatmap(corr, annot= True, square = True)

# %% [markdown]
# ## Here comes a very intuitive question:
# How can we process hundereds of features effectively???
# Let's do some researches and understand how can we solve the problem more effectively
# <a href="https://machinelearningmastery.com/feature-selection-machine-learning-python/"> Feature Selection For Machine Learning in Python </a>
# #1st Insight:
# The data features that you use to train your machine learning models have a huge influence on the performance you can achieve.
# Feature Selection
# Feature selection is a process where you automatically select those features in your data that contribute most to the prediction variable or output in which you are interested.
#
# #2nd Insight:
# Three benefits of performing feature selection before modeling your data are:
# Reduces Overfitting: Less redundant data means less opportunity to make decisions based on noise.
# Improves Accuracy: Less misleading data means modeling accuracy improves.
# Reduces Training Time: Less data means that algorithms train faster.
#
# #Another article:
# <a href="https://machinelearningmastery.com/an-introduction-to-feature-selection/"> An introduction to feature selection </a>
# #1st Insight: It is the automatic selection of attributes in your data (such as columns in tabular data) that are most relevant to the predictive modeling problem you are working on. (Focusing on here!! It is for prediction)
# #2nd Insight: Feature selection is itself useful, but it mostly acts as a filter, muting out features that aren’t useful in addition to your existing features.
#
#
# #Datacamp - RandomForest Algorithm
# <a href = " https://www.datacamp.com/community/tutorials/exploratory-data-analysis-python"> Selecting features </a>
# it randomly generates thousands of decision trees and takes turns leaving out each variable in fitting the model. This way, you can calculate how much better or worse a model does when you leave one variable out of the equation.

# %%
#Let's try it out - the random forest algorithm 
from sklearn.ensemble import RandomForestClassifier 
#Isolate Data, class labels and column values - it seems like not easy to do it.

# %%
# With the consideration of the domain of loan industry, which features are the most important?
