# %% [markdown]
# Don't think I'm in the wrong competition. These guys are from Liverpool. Since ion switching encode learning and memory, Why not the memory of The Beatles. Last year(2019) we comemorate their 50-Year Anniversary.

# %% [markdown]
# ![](https://media1.giphy.com/media/3ohzdOKguX7nXShLaw/giphy.webp?cid=790b761150134f5257a19ed9a290f31988b99a5f117ca17b&rid=giphy.webp)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# pinterest.com

# %%
train = pd.read_csv('/kaggle/input/liverpool-ion-switching/train.csv')
test = pd.read_csv('/kaggle/input/liverpool-ion-switching/test.csv')
submission = pd.read_csv('/kaggle/input/liverpool-ion-switching/sample_submission.csv')

# %% [markdown]
# # codes from Nike https://www.kaggle.com/kunaal0/simple-starter-code-with-logistic-regression

# %%
train_time = train['time'].values
train_time_0 = train_time[:50000]

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRoCi2-W71AWrWH7yn2taf8B9lpOfAC2pMfFx1DV52x5qAQmrSK&s',width=400,height=400)

# %%
for i in range(1,100):
    train_time_0 = np.hstack([train_time_0, train_time[i*50000:(i+1)*50000]])

# %%
train['time'] = train_time_0

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://miro.medium.com/max/1380/1*NxiBxeASQIej_qx5Eu_qYA.png',width=400,height=400)

# %% [markdown]
# Image towardsdatascience - https://towardsdatascience.com/john-or-paul-data-resolves-the-age-old-who-was-the-1-beatle-question-fca8d8232df5 Article by Dan Raviv.

# %%
train_time_0 = train_time[:50000] 

for i in range(1,40):
    train_time_0 = np.hstack([train_time_0, train_time[i*50000:(i+1)*50000]])
    
test['time'] = train_time_0

# %%
n_groups = 100
train["group"] = 0
for i in range(n_groups):
    ids = np.arange(i*50000, (i+1)*50000)
    train.loc[ids,"group"] = i

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRursYTNfVXcyao1fqpUzN935goZFrZtG1dSph6n5E35VywgYqv&s',width=400,height=400)

# %% [markdown]
# sportsgalleryweb.com

# %%
n_groups = 40
test["group"] = 0
for i in range(n_groups):
    ids = np.arange(i*50000, (i+1)*50000)
    test.loc[ids,"group"] = i

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://miro.medium.com/max/1448/1*IUv42UtorfHGmx9aND3whA.png',width=400,height=400)

# %% [markdown]
# towardsdatascience - https://towardsdatascience.com/john-or-paul-data-resolves-the-age-old-who-was-the-1-beatle-question-fca8d8232df5 Article by Dan Raviv.

# %%
train['signal_2'] = 0
test['signal_2'] = 0

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://miro.medium.com/max/1780/1*_0kQ6xWdHS4cI4d9xnaBNw.png',width=400,height=400)

# %% [markdown]
# Image towardsdatascience - https://towardsdatascience.com/john-or-paul-data-resolves-the-age-old-who-was-the-1-beatle-question-fca8d8232df5 Article by Dan Raviv.

# %%
#plot of the signal
plt.figure(figsize=(20, 8))
train.signal.plot()
plt.title("Train data")

# %%
X = train[['signal_2']].values
y = train['open_channels'].values

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSpKnb5_peEj54gqYmF04NWK8hT5m_Py4ErKEUV-XqgxIWB2jBxuA&s',width=400,height=400)

# %% [markdown]
# netflix.com

# %%
trnX = train[['signal']].values
trnY = train['open_channels'].values

# %% [markdown]
# #Codes from KKR https://www.kaggle.com/kalyankkr/simple-eda-ridge-lgb-for-beginner

# %%
model_lgb = lgb.LGBMRegressor(objective='regression',
                              num_leaves=4,
                              learning_rate=0.05, 
                              n_estimators=1080,
                              max_bin=75, 
                              bagging_fraction=0.80,
                              bagging_freq=5, 
                              feature_fraction=0.232,
                              feature_fraction_seed=9, 
                              bagging_seed=9,
                              min_data_in_leaf=6, 
                              min_sum_hessian_in_leaf=11)

# %% [markdown]
# ![](https://media0.giphy.com/media/1g1fqntyud56tLaCfY/giphy.webp?cid=790b76118827302d15c3a29b6c6199a4b7c098a05d91aa49&rid=giphy.webp)

# %%
model_lgb.fit(trnX, trnY)

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=0.5)
model.fit(trnX, trnY)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://miro.medium.com/max/1895/1*fV6LtafEA0ZC3SB7QErxeg.png',width=400,height=400)

# %% [markdown]
# Image towardsdatascience - https://towardsdatascience.com/john-or-paul-data-resolves-the-age-old-who-was-the-1-beatle-question-fca8d8232df5 Article by Dan Raviv.

# %%
submission = pd.read_csv('/kaggle/input/liverpool-ion-switching/sample_submission.csv')
testX = test[['signal']].values
ridge_prediction = model.predict(testX)
ridge_prediction = np.rint(ridge_prediction).astype(int)

# %%
lgb_train_pred_trn = model_lgb.predict(trnX)
lgb_train_pred = model_lgb.predict(testX)
lgb_pred = np.rint(lgb_train_pred).astype(int)

# %% [markdown]
# ![](https://media1.giphy.com/media/rh0W2vpayXMac/200.webp?cid=790b7611116ffd2ecbcfb5c66aa5e439f7c991b1abe4b6d4&rid=200.webp)

# %%
#ensemble
ensemble = ridge_prediction*0.35 + lgb_pred*0.65
submission['open_channels'] = ensemble
submission[submission['open_channels']<0]['open_channels'] = 0
submission.head()
submission.to_csv("submission.csv", index=False)

# %% [markdown]
# ![](https://media.giphy.com/media/Xpjg5nwpCdE7UuSkgj/giphy.gif)

# %% [markdown]
# #Codes from KKR https://www.kaggle.com/kalyankkr/simple-eda-ridge-lgb-for-beginner
#
# #Codes from Nike https://www.kaggle.com/kunaal0/simple-starter-code-with-logistic-regression

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata @mpwolke
