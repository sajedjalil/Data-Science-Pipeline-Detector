# %% [markdown]
# This is the ensemble of the following kernels:
#
# 942 gru_preds.csv https://www.kaggle.com/mobassir/understanding-ion-switching-with-modeling/output?scriptVersionId=32255557
#
# 944 submission_wavenet https://www.kaggle.com/nxrprime/wavenet-with-shifted-rfc-proba-and-cbr?scriptVersionId=32352115
#
# I made the dataset public.
#
# ### ☀️ Simply fork, run, and submit :)
#
# ### ☀️ Please 👍UPVOTE to keep this going … 🙌 ✔️

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df944 = pd.read_csv('/kaggle/input/uoflivoutputs/submission_wavenet.csv', dtype={'time': object})
df942 = pd.read_csv('/kaggle/input/uoflivoutputs/gru_preds.csv', dtype={'time': object})

# %%
df944.head(10)

# %%
df944.to_csv('df944.csv', index=False)
df942.to_csv('df942.csv', index=False)

# %%
ens1 = df944.copy()
for ii in ([0.1,0.3,0.5,0.7,0.9]):
    ens1['open_channels'] = ii * df944['open_channels'] + (1.0 - ii) * df942['open_channels']
    ens1['open_channels'] = ens1['open_channels'].apply(lambda x: round(x))
    ens1.to_csv('ens_'+str(ii)+'.csv', index=False)

# %%
display(df944.tail())
display(ens1.tail())

# %%
display(df944.describe())
display(ens1.describe())
