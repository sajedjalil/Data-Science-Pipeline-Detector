# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:skyblue;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Tabular Playground Series - Sep 2021
# </h1>
# </div>
#
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/25226/logos/header.png?t=2021-01-27-17-34-31)

# %% [markdown]
# ### Hello Kaggler !
# ### This time, I prepare the LightGBM tutorial.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:skyblue;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# Check the dataset!
# </h1>
# </div>

# %%
import pandas as pd
train =pd.read_csv("../input/tabular-playground-series-sep-2021/train.csv")
test = pd.read_csv("../input/tabular-playground-series-sep-2021/test.csv")
train = train.drop('id',axis=1)
test = test.drop('id',axis=1)

print("train data : ",len(train))
print("test data : ",len(test))

# %% [markdown]
# ### If you see the dataset, It has so many rows !
# ### When i saw this dataset. I surprised.. So I think that, I will prepare the fast ML model.
# ### That is LightGBM!

# %%
train.isna().sum()

# %%
test.isna().sum()

# %% [markdown]
# ### You should fill the NaN data first !

# %%
y_train = train['claim']
X_train = train.drop('claim',axis=1)

from sklearn.impute import SimpleImputer
import numpy as np
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
X_train = imp_mean.fit_transform(X_train)
test = imp_mean.transform(test)

# %% [markdown]
# ### I just use SimpleImputer

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:skyblue;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
# <h1 style="text-align: center;
#            padding: 10px;
#               color:white">
# LightGBM
# </h1>
# </div>

# %% [markdown]
# ![](https://lightgbm.readthedocs.io/en/latest/_images/LightGBM_logo_black_text.svg)

# %% [markdown]
# ### Welcome to LightGBM’s documentation!
# #### LightGBM is a gradient boosting framework that uses tree based learning algorithms. It is designed to be distributed and efficient with the following advantages:
#
# * Faster training speed and higher efficiency.
# * Lower memory usage.
# * Better accuracy.
# * Support of parallel, distributed, and GPU learning.
# * Capable of handling large-scale data.

# %% [markdown]
# ### When you visit the LightGBM document site, You can see that first.
# ### I think LightGBM is faster than other M/L models, and show high accuracy !
# ### Just use it !

# %%
from lightgbm import LGBMRegressor

model = LGBMRegressor(n_estimators=1000)
model.fit(X_train,y_train)
predict = model.predict(test)

# %%
sample = pd.read_csv("../input/tabular-playground-series-sep-2021/sample_solution.csv")
sample['claim'] = predict
sample.to_csv("test.csv",index=None)
sample

# %% [markdown]
# ### If you want more accuracy, try adjsut parameters !
