# %%
import numpy as np
import pandas as pd
from sklearn import model_selection
from sklearn.model_selection import StratifiedKFold

# %%
train = pd.read_csv("../input/tabular-playground-series-sep-2021/train.csv")
test = pd.read_csv("../input/tabular-playground-series-sep-2021/test.csv")
SS = pd.read_csv("../input/tabular-playground-series-sep-2021/sample_solution.csv")

# %%
X= train.drop(['claim','id'],axis=1)
y= train['claim']

# %%
kf = model_selection.StratifiedKFold(n_splits=15, shuffle=True, random_state=42)
for fold, (train_indicies, valid_indicies) in enumerate(kf.split(X,y)):
    train.loc[valid_indicies, "kfold"] = fold

# %%
train.head()

# %%
train.to_csv("train_15-Kfolds.csv", index=False)
