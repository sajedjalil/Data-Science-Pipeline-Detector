# %%
import numpy as np 
import pandas as pd 
from time import time

# %%
#Loading feather files
start = time()
train2 = pd.read_feather('/kaggle/input/september-feather/train')
test2 = pd.read_feather('/kaggle/input/september-feather/test')
ss2 = pd.read_feather('/kaggle/input/september-feather/sample_solution')
print(f'Took {time() - start :.2f} seconds.')

# %%
print(train2.shape)
print(test2.shape)
print(ss2.shape)

# %%
#Loading csv files
start = time()
train = pd.read_csv('/kaggle/input/tabular-playground-series-sep-2021/train.csv')
test = pd.read_csv('/kaggle/input/tabular-playground-series-sep-2021/test.csv')
ss = pd.read_csv('/kaggle/input/tabular-playground-series-sep-2021/sample_solution.csv')
print(f'Took {time() - start :.2f} seconds.')

# %%
print(train.shape)
print(test.shape)
print(ss.shape)
