# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

# %%
data_train = pd.read_csv("../input/tabular-playground-series-sep-2021/train.csv")
data_test = pd.read_csv("../input/tabular-playground-series-sep-2021/test.csv")
data_sample = pd.read_csv("../input/tabular-playground-series-sep-2021/sample_solution.csv")

# %%
data_train.head()

# %%
data_sample

# %%
data_train = data_train.fillna(data_train.mean())
data_test = data_test.fillna(data_test.mean())

# %%
data_train.claim.value_counts()

# %%
sns.catplot(x="claim", kind="count", data=data_train)

# %%
y = data_train.claim
X = data_train.drop('claim', axis=1)
X_train, X_val, Y_train, Y_val = train_test_split(X, y, test_size = 0.2, random_state = 0)
