# %%
import pandas as pd

# %% [markdown]
# ## Everything should be made as simple as possible, but not simpler

# %%
pred_lr_saga = pd.read_csv("../input/submission/meta_lasttt_lr_saga.csv")

# %%
sample_solution = pd.read_csv("../input/tabular-playground-series-sep-2021/sample_solution.csv")
sample_solution['claim'] = pred_lr_saga.claim
sample_solution.to_csv("submission.csv", index=False)

# %%
sample_solution
