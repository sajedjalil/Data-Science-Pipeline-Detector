# %% [markdown]
# <img src="https://miro.medium.com/max/630/1*pH_ycMHmyY_OxyMgOW0whQ.jpeg"
#      width="400"
#      height="500" />
# <img src="https://i.postimg.cc/SQ3d93G7/242269893-953243485224460-536187700114118432-n.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.postimg.cc/L5L1LCHN/241426370-4989674537714337-7340156749542474389-n.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.postimg.cc/3RDsjpzt/joker.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.postimg.cc/SNPBJgnw/cs.jpg"
#      width="400"
#      height="500" />

# %% [markdown]
# # **Wait, what! you came here to see the solution and to submit the output data.**
#
# ![Stop it get some help](https://hypixel.net/attachments/png-png.1995621/)
#
# # I am a beginner and this is my first ever TPS Competition, in which my brain was exhausted before my GPU allocation.below are some of the memes to fresh up your mind. happy kaggling

# %% [markdown]
# <img src="https://i.redd.it/nc5ua4x8lfg31.png"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/proxy/1*KBobA-DaVtQ8Px6P_-tNqQ.jpeg"
#      width="400"
#      height="500" />
# <img src="https://img-9gag-fun.9cache.com/photo/amP6xZd_460s.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.redd.it/077bsten3fx01.jpg"
#      width="400"
#      height="500" />
# <img src="https://preview.redd.it/e3t6zf00cl951.jpg?width=640&crop=smart&auto=webp&s=a7b39dd86abc0f4d014dbd9f2f7f61caf31d252b"
#      width="400"
#      height="500" />
#
# ![memes](https://miro.medium.com/max/630/1*E4_pTJctmAofSRpZCZbv-g.jpeg)
#
# <img src="https://miro.medium.com/max/450/1*qHbAsMNmdWQJkzm2SUA-8w.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/450/1*SPJDe05__KFLjHWd8za2xQ.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/212/1*3vE4n-8lGPiFcUgFDdoYZA.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/301/1*ymiqZipWTvcaPPt1ufLJ3g.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/630/1*TOCkiI_kCupxW-0jmi1p6g.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/427/1*A8bKVrmA9qMhReU0U_KYzw.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/630/1*vglBffD6z0K0hxL3vmYPzg.jpeg"
#      width="400"
#      height="500" />

# %%
import pandas as pd,numpy as np,os
meme = pd.read_csv('../input/tsp21sep-data-folder/upvote_before_u_copy.csv')
sub = pd.read_csv('../input/tabular-playground-series-sep-2021/sample_solution.csv')
sub.claim = (0.69**2)*0.1 + (meme.claim**2)*0.9
sub.to_csv('memes.csv',index=False)

# %% [markdown]
# <img src="https://miro.medium.com/max/196/1*WFh1po8b4B0Rpouzo-g8RQ.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/450/1*GOrVt6zYSh1bJz9Uz9r0AA.jpeg"
#      width="400"
#      height="500" />
# <img src="https://miro.medium.com/max/416/1*toOE09syOgAV7KlRmth-UA.jpeg"
#      width="400"
#      height="500" />
#
# <img src="https://miro.medium.com/max/450/1*SoA2-16rMISDOF3OGNjWiA.jpeg"
#      width="400"
#      height="500" />
# <img src="https://i.pinimg.com/564x/2a/39/23/2a3923e3193ffa5f709919e5aa5da010.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.pinimg.com/564x/be/71/37/be7137dfecb32b70c2afb28b5ea6ecbf.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.postimg.cc/xTmwNKL8/cat.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.postimg.cc/RZsLMYqH/model.jpg"
#      width="400"
#      height="500" />
# <img src="https://i.postimg.cc/pTXvDpR7/ml.jpg"
#      width="400"
#      height="500" />
