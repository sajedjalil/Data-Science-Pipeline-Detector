# %% [markdown]
# Beginner Approach to predict trip duration

# %%
#Import initial Required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import calendar
import datetime as dt
from math import sin, cos, sqrt, atan2, radians

# %% [markdown]
# Let's start our analysis with quick look of data set we have

# %%
#Import train and test data
data = pd.read_csv('../input/train.csv')
data_cv = pd.read_csv('../input/test.csv')
data.head()

# %% [markdown]
# So here we can see that we need to predict trip duration based on features we have. Let's try to explore trip duratio

# %%
print(np.min(data['trip_duration']))
print(np.max(data['trip_duration']))
print(np.median(data['trip_duration']))
print(np.mean(data['trip_duration']))
print(np.std(data['trip_duration']))

# %% [markdown]
# Here we can see that standard deviation of trip duration is very high, so we will remove some outlier here based on trips with very high value of trip duration and lat long values which ar
