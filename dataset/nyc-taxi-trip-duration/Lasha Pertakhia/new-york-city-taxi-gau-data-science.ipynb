# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install Packages

# %%
# !pip install -U pip
# !pip install -U setuptools wheel
# !pip install "mxnet<2.0.0"
# !pip install autogluon.tabular

# %% [markdown]
# ### Imports

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv('/kaggle/input/nyc-taxi-trip-duration/train.zip')
test_df = pd.read_csv('/kaggle/input/nyc-taxi-trip-duration/test.zip')

# %% [markdown]
# ## Quick Look

# %%
train_df.info()

# %%
test_df.info()

# %% [markdown]
# # EDA

# %%
train_df[['pickup_longitude', 'pickup_latitude']].quantile(q=[0.05, 0.95]).round(2)

# %%
train_df['vendor_id'].value_counts()

# %% [markdown]
# ## Visualizations

# %%
f, axes = plt.subplots(
    figsize=(16,8),
    ncols=2,
    sharex=True,
    sharey=True
)

axes[0].scatter(
    train_df.loc[train_df['vendor_id']==1, 'pickup_longitude'],
    train_df.loc[train_df['vendor_id']==1, 'pickup_latitude'],
    s=0.05,
    alpha=0.05,
    color='blue'
)
axes[1].scatter(
    train_df.loc[train_df['vendor_id']==2, 'pickup_longitude'],
    train_df.loc[train_df['vendor_id']==2, 'pickup_latitude'],
    s=0.05,
    alpha=0.05,
    color='red'
)
# sns.scatterplot(data=train_df, x='pickup_longitude', y='pickup_latitude', alpha=0.5, size=0.1, ax=ax)
plt.xlim((-74.025, -73.775))
plt.ylim((40.64, 40.84))
# plt.xlim((-74.05, -73.75))
# plt.ylim((40.5, 41.0))
plt.show()

# %% [markdown]
# ## Correlations

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# # Fine-Tuning

# %% [markdown]
# # Choosing the Best

# %% [markdown]
# # Test Submission with `median` Value

# %%
test_df['trip_duration'] = train_df['trip_duration'].median()
test_df[['id', 'trip_duration']].to_csv('submission.csv', index = False)
