# %% [markdown]
# # 1. Loading Data

# %%
import sys
import gc
import os
import warnings
import pickle
import pandas as pd

# %% [markdown]
# ## 1.2 Load files

# %%
print('Loading the data...')
DATA_GRID_INPUT_DIR = '../input/m5load'

data = pd.read_pickle(f'{DATA_GRID_INPUT_DIR}/m5_data_grid.pkl')

# %%
print('Data usage: {} GB'.format(data.memory_usage().sum() / 10**9))
data.head()
gc.collect()

# %%
data.info(memory_usage="deep")

# %%
print("Size of Variables")
_vars = globals().items()
for var, obj in _vars:
    print(var, sys.getsizeof(obj))

# %%
del data
gc.collect()
