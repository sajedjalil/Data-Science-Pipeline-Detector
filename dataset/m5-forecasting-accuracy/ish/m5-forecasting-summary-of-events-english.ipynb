# %% [markdown]
# # Summary of Events イベントについてのまとめ
#
# Thanks for a glance! This is my first kernel on kaggle. This kernel give a summary of the events in the 'calender.csv' especially for **NON-American** (but of course also welcome American!) to greduce domain knowledge disadvantage (see especially "2. Summary of Each Events"). If you have any correction or advice, please let me know!
#
# こんにちは！初めてのkaggle、初めてのkernelです！'calender.csv'に出てくるイベントについてまとめました。初心者でデータ可視化の技術が乏しいこともあり、そもそも各イベントがどのようなものかについて主に調べました。（特に「2. 各イベントの概略」にまとまっています）少しでもお役に立てれば幸いです。なお、個人的なまとめですので、100%の真偽の保証はできません。また、もし訂正や助言等ございましたら、知らせていただけるとありがたいです。

# %% [markdown]
# 2020.05.31 Version2 -> 3
# * added "1.2 Classification of Events", and changed the order of chapter because of that.
# * improve "2. Summary of Each Events".
#
#
# * 「1.2 イベントの分類」追加。それに伴って章構成一部変更。
# * 「2 各イベントの概略」追記。

# %%
# import modules
# インポート
import numpy as np 
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# Read in the data
# データの読み込み
INPUT_DIR = '../input/m5-forecasting-accuracy'
cal = pd.read_csv(f'{INPUT_DIR}/calendar.csv')

# %% [markdown]
# # 1. Overview of Data データの概要

# %% [markdown]
# ## 1.1 Examples of Events イベントの例

# %%
# Examples of events on 'calneder.csv'
# カレンダーに出てくるイベントの例
cal.drop_duplicates(['event_name_1', 'event_name_2'])[1:].head()

# %% [markdown]
# ## 1.2 Classification of Events イベントの分類

# %%
# Sporting list
cal_spo = cal[cal['event_type_1'] == 'Sporting']
cal_spo.drop_duplicates(['event_name_1'])[['event_name_1', 'event_type_1']].head()

# %%
# Cultural list
cal_cul = cal[cal['event_type_1'] == 'Cultural']
cal_cul.drop_duplicates(['event_name_1'])[['event_name_1', 'event_type_1']].head()

# %%
# National list
cal_nat = cal[cal['event_type_1'] == 'National']
cal_nat.drop_duplicates(['event_name_1'])[['event_name_1', 'event_type_1']].head()

# %%
# Religious list
cal_rel = cal[cal['event_type_1'] == 'Religious']
cal_rel.drop_duplicates(['event_name_1'])[['event_name_1', 'event_type_1']].head()

# %% [markdown]
# ## 1.3 Number of Event Days イベントの日数

# %% [markdown]
# ### All data 全てのデータ

# %%
# The number of days excpet NaN
# 各項目の欠損値でない日数
print("<All data> \n")
print(cal.count())
eve_rate = cal.count()["event_name_1"] / cal.count()["date"]
print("\n" + "event days rate: " + "{:.02f}".format(eve_rate * 100) + "%")

# %% [markdown]
#  * The number of event days is 162 (/1969, 8.23%)
#
#
#  * イベントがある日数は162日 (/1969日, 8.23%)

# %% [markdown]
# ### Test data テストデータ

# %%
# test data
# テストデータ
cal[-28:]

# %%
print("<Test data> \n")
# The number of days excpet NaN (only in test data)
# 各項目の欠損値でない日数 (only in test data)
print(cal[-28:].count())
eve_rate_28 = cal[-28:].count()["event_name_1"] / cal[-28:].count()["date"]
print("\n" + "event days rate: " + "{:.02f}".format(eve_rate_28 * 100) + "%")

# %% [markdown]
# * The number of event days (test data) is 4 (/28, 14.29%)
#
#
# * イベントがある日数(テストデータ)は4日 (/28, 14.29%)

# %% [markdown]
# ## 1.4 Total Number of Appearance 累計回数

# %% [markdown]
# ### Total number of each event 各イベントの累計回数

# %%
# All data, 全データ
print("<All data> \n")

# Each number of appearance (event_name_1)
# 各イベントの日数 (event_name_1)
print(cal['event_name_1'].value_counts())
print("\n")

# Each number of appearance (event_name_2)
# 各イベントの日数 (event_name_2)
print(cal['event_name_2'].value_counts())
print("\n")

# Test data, テストデータ
print("<Test data> \n")

# Each number of appearance (event_name_1, test data)
# 各イベントの日数 (event_name_1, テストデータ)
print(cal[-28:]['event_name_1'].value_counts())
print("\n")

# Each number of appearance (event_name_2, test data)
# 各イベントの日数 (event_name_2, test data)
print(cal[-28:]['event_name_2'].value_counts())

# %% [markdown]
# * All events are once a year, periodic
# * NBAFinalsStart, NBAFinalsEnd, Ramadan starts, MemorialDay, Father's day(event_name_2) are included in test data
#
#
# * イベントは年に一回の周期的なイベントのみ
# * テストデータに含まれるのはNBAFinalsStart, NBAFinalsEnd, Ramadan starts, MemorialDay, Father's day(event_name_2)の５つ

# %% [markdown]
# ### Total number of each event type 各イベントの種類の累計回数

# %%
# All data, 全データ
print("<All data> \n")

# Each number of appearance (event_type_1)
# 各イベントの種類の出現回数 (event_type_1)
print(cal['event_type_1'].value_counts())
print("\n")

# Each number of appearance (event_type_2)
# 各イベントの種類の出現回数 (event_type_2)
print(cal['event_type_2'].value_counts())
print("\n")


# Test data, テストデータ
print("<Test data> \n")

# Each number of appearance (event_type_1)
# 各イベントの種類の出現回数 (event_type_1)
print(cal[-28:]['event_type_1'].value_counts())
print("\n")

# Each number of appearance (event_type_2)
# 各イベントの種類の出現回数 (event_type_2)
print(cal[-28:]['event_type_2'].value_counts())

# %% [markdown]
# * There are 4 types of events; Religious, National, Cultural, Sporting
# * All types are also included in test data
#
#
# * イベントの種類はReligious, National, Cultural, Sportingの４種類
# * テストデータにも全種類含まれている

# %% [markdown]
# # 2. Summary of Each Event 各イベントの概略
#
#  Also cite [33], and use DeepL[34] for rough (but almost perfect) translation.
#  Please let me know any mistakes or additional infomation, thank you!

# %% [markdown]
# * **NewYear (新年)**[29]
#     National
#     Federal holiday. Events such as fireworks, parties, etc.
#     祝日。花火、パーティー、その他イベント。

# %%
cal[cal['event_name_1']=='NewYear'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **OrthodoxChristmas (正教会のクリスマス)**[16]
#     Religious
#     January 7.　Orthodox people abstain from eating until this day.
#     １月７日。正教徒はこの日まで節食。

# %%
cal[cal['event_name_1']=='OrthodoxChristmas'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **MartinLutherKingDay (キング牧師記念日)**[18]
#     National
#     Federal holiday.
#     祝日。

# %%
cal[cal['event_name_1']=='MartinLutherKingDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **SuperBowl (スーパーボウル)**[11]
#     Sporting
#     The championship game of the NFL (football). A de facto American holiday. Grocery consumption is the second highest for the year after Thanksgiving. TV coverage is the highest viewership for the year.
#     NFL(アメフト)の優勝決定戦。事実上アメリカの祝日。食料品の消費が感謝祭に次いで年間で２番目に多い。テレビ中継は年間最高視聴率。

# %%
cal[cal['event_name_1']=='SuperBowl'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **ValentinesDay (バレンタインデー)**[2][3][4]
#     Cultural
#     People send other people cards, flowers, chocolates, etc. with message to show their affection.
#     メッセージ付きのカードや花、チョコレートを送る。日本と違って男女関係ないらしい。

# %%
cal[cal['event_name_1']=='ValentinesDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %%
cal[cal['event_name_1']=='OrthodoxChristmas'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **PresidentsDay (ワシントン誕生日)**[12]
#     National
#     Federal holiday.
#     祝日。

# %%
cal[cal['event_name_1']=='PresidentsDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **LentStart (四旬節開始)**
#     Religious

# %%
cal[cal['event_name_1']=='LentStart'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **LentWeek2 (四旬節２週目)**
#     Religious

# %%
cal[cal['event_name_1']=='LentWeek2'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **StPatricksDay (聖パトリックの祝日)**[13]
#     Cultural
#     People celebrate by wearing a green object. In some places, there are parades. Drinking green-tinted lager beers and eating corned beef and cabbages as Irish food. There's a habit among children of being pinched if you don't wear green.
#     緑色の物を身に着けて祝う。場所によってはパレードがある。緑に染めたラガービールを飲んだり、コンビーフ・アンド・キャベッジをアイルランド料理として食べる。子供の間では緑色の服を着てないとつねられる習慣がある。

# %%
cal[cal['event_name_1']=='StPatricksDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Purim End (プーリーム)**[9][10]
#     Religious
#     Jewish holiday.
#     ユダヤ教の祭り。

# %%
cal[cal['event_name_1']=='Purim End'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Easter (復活祭、イースター)**[19][20][21]
#     Cultural
#     The most important Christian holiday. A lot of stores are closed or have limited trading hours in many parts of the US. Easter monday isn't a public holiday in the US. Easter Eggs.
#     キリスト教で最も重要な祭。多くのスーパーが閉まるか短縮営業になる。イースターマンデーはアメリカでは休みではない。イースターエッグ。

# %%
cal[cal['event_name_1']=='Easter'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %%
# 'event_name_2' exists.
cal[cal['event_name_2']=='Easter'][['event_name_2', 'event_type_1', 'date', 'weekday', 'event_name_1']]

# %% [markdown]
# * **OrthodoxEaster (正教会の復活祭)**
#     Religious

# %%
cal[cal['event_name_1']=='OrthodoxEaster'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %%
# 'event_name_2' exists.
cal[cal['event_name_2']=='OrthodoxEaster'][['event_name_2', 'event_type_1', 'date', 'weekday', 'event_name_1']]

# %% [markdown]
# * **Pesach End （過越）**[1]
#     Religious
#     Passover. Jewish religious holiday. From late March to early April, Jewish people don't eat bread with leaven ("End" means the last day here.)
#     Passoverとも。ユダヤ教の宗教的記念日。ユダヤ教徒は３月末から４月頭の一週間、酵母入りのパンを食べない。(Endなので最終日)

# %%
cal[cal['event_name_1']=='Pesach End'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Cinco De Mayo (シンコ・デ・マヨ)**[31]
#     Cultural
#     Mexican holiday. People enjoy Mexican Products - Drinks, food, and music.
#     メキシコの祝日。メキシコ製品。飲み物や食事、音楽。

# %%
cal[cal['event_name_1']=='Cinco De Mayo'][['event_name_1','event_type_1', 'date', 'weekday']]

# %%
# 'event_name_2' exists.
cal[cal['event_name_2']=='Cinco De Mayo'][['event_name_2', 'event_type_1', 'date', 'weekday', 'event_name_1']]

# %% [markdown]
# * **Mother's day (母の日)**[5]
#     Cultural
#     The sales of flowers, greeting cards, etc. are the biggest in the year. the highest church attendence after Christmas Eve and Easter.
#     花、グリーティングカードなどの売り上げが最大。教会に行く機会としてもクリスマスイブ、イースターに次ぐ。

# %%
cal[cal['event_name_1']=='Mother\'s day'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **MemorialDay (戦没将兵追悼記念日(せんぼつしょうへいついとうきねんび))**[8]
#     National
#     Federal holiday. The last Monday in May. Remembrance of the fallen from the Civil War. People visit cemeteries and memorials. Volunteers place the Star-Spangled Banner over the grave from dawn until noon. Occasions for picnics, family gatherings and sporting events.
#     祝日。５月の最終月曜日。南北戦争からの戦没者の追悼。墓地や記念碑を訪れる。ボランティアが墓の上に夜明けから正午まで星条旗を置く。ピクニック、家族の集い、スポーツイベントの機会。

# %%
cal[cal['event_name_1']=='MemorialDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **NBAFinalsStart (NBA-男子プロバスケットボールリーグ-のファイナルの初戦)**[6][7]
#     Sporting
#     The first day of NBA(National Basketball Association)Finals. At most 7 games (2-2-1-1-1 format from 2013/14 season. Before that 2-3-2 format.)
#     NBAファイナルの初戦。最大７試合。もともと2-3-2フォーマットだったが、2013/14シーズンからお互いのホームで2-2-1-1-1の形式で行われる。

# %%
cal[cal['event_name_1']=='NBAFinalsStart'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **NBAFinalsEnd (NBAファイナル最終日)**
#     Sporting
#     The last day of NBAFinals.
#     NBAファイナルの最終戦。

# %%
cal[cal['event_name_1']=='NBAFinalsEnd'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Father's day (父の日)**[32]
#     Cultural
#     Flowers (roses), greeting cards and gifts.
#     花(バラ)、グリーティングカード、ギフト。

# %%
cal[cal['event_name_1']=='Father\'s day'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %%
# 'event_name_2' exists.
cal[cal['event_name_2']=='Father\'s day'][['event_name_2', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **IndependenceDay (独立記念日)**[15]
#     National
#     Federal holiday. The week of Independence Day, along with Christmas and Thanksgiving, puts the nation in a holiday mood. It can be a sale period. Events such as fireworks, concerts and parades; at home, barbecues, picnics and baseball.
#     祝日。独立記念日の一週間はクリスマス、感謝祭と並び全米が祝日ムードとなる。セール期間になることも。花火、コンサート、パレードなどのイベント、家庭ではバーベキュー、ピクニック、野球など。

# %%
cal[cal['event_name_1']=='IndependenceDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Ramadan starts (ラマダーン開始)**[14]
#     Religious
#     Muslims fast from sunrise to sunset. They also avoids smoking.
#     ムスリムは日の出から日没まで断食。タバコなども避けるらしい。

# %%
cal[cal['event_name_1']=='Ramadan starts'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Eid al-Fitr (イド・アル＝フィトル)**[23]
#     Religious
#     Islamic holiday. A big festival to celebrate the end of Ramadan.
#     イスラム教の祝日。ラマダーンの終了を祝う大祭。

# %%
cal[cal['event_name_1']=='Eid al-Fitr'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **LaborDay (レイバー・デー、労働者の日)**[28]
#     National
#     Federal holiday. The last travel opportunity of the summer holidays. Events such as parades, picnics, barbecues, fireworks, water sports, arts events, etc. The NFL and college football opening games are around here.
#     祝日。夏休み最後の旅行の機会。イベントはパレード、ピクニック、バーベキュー、花火、水上スポーツ、芸術イベントなど。NFL、カレッジフットボールの開幕はこの辺り。

# %%
cal[cal['event_name_1']=='LaborDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **ColumbusDay (コロンブス・デー)**[17]
#     National
#     Federal holiday. Each region treat this holiday differently. California and Texas recognize it as a holiday, but the state government does not pay it. In some parts of Wisconsin, it is Indigenous People's Day.
#     祝日。地域により扱いが違う。カリフォルニア、テキサスでは休日とは認めているが州政府は有給ではない。ウィスコンシン州の一部では先住民の日となっている。

# %%
cal[cal['event_name_1']=='ColumbusDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Halloween (ハロウィーン)**[30]
#     Cultural
#     Trick-or-treat. Candies. Costumes. Pumpkins.
#     トリック・オア・トリート。お菓子。コスチューム。かぼちゃ。

# %%
cal[cal['event_name_1']=='Halloween'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **EidAlAdha (イード・アル＝アドハー)**[27]
#     Religious
#     Religious holiday in Islam. Those who can afford it financially sacrifice an animal (a sheep for one person, a camel or a cow for up to seven?) . Most of the meat from the sacrifice is served to the poor and the rest to the family.
#     イスラム教の宗教的祝日。経済的に余裕のある人は動物を生贄として捧げる（羊なら一人分、ラクダ、牛は最大七人分？）。生贄の肉は、大部分を貧しい人に、残りを家族に振る舞うらしい。

# %%
cal[cal['event_name_1']=='EidAlAdha'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **VeteransDay (復員軍人の日)**[25]
#     National
#     Most schools are not closed and businesses operate normally.
#     ほとんどの学校は休校とせず、企業は通常営業。

# %%
cal[cal['event_name_1']=='VeteransDay'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Thanksgiving (感謝祭)**[22]
#     National
#     Federal holiday. Events like a large dinner party for relatives and friends. The store may close early on the day. In some states, it's a consecutive holiday, and homecoming rush happens. Also, a prelude to the Christmas sale. The day after Thanksgiving is Black Friday (it's said that retailers will return to the black for the entire year after this Friday's big sales day). The first Monday of the week is Cyber Monday (many people buy gifts on EC sites).
#     祝日。親族や友人が集まる大規模な食事会など。当日は店が早く閉まることも。州によっては連休になり、帰省ラッシュ的なことが起こる。また、クリスマスセールの前哨戦。感謝祭翌日がブラック・フライデー（この金曜日の大売り出しを機に小売店の年間通算収支が黒字に転換すると言われている）。週明けの月曜日がサイバー・マンデー（ECサイトでプレゼント買う人が多い）。

# %%
cal[cal['event_name_1']=='Thanksgiving'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Christmas (クリスマス)**[24]
#     National
#     Federal holiday. People spend time with family at home. It's common to eat home cooked food. When people go out, they go to the church. Greeting cards, families exchanging gifts with each other, etc.
#     祝日。日本と違い、自宅で家族と過ごす。家庭料理を食べるのが一般的。外出は教会に行くくらい。グリーティングカード、家族同士でプレゼント交換など。

# %%
cal[cal['event_name_1']=='Christmas'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
# * **Chanukah End**[26]
#     Religious
#     Jewish holiday. Eight days from the 25th day of September in the Jewish calendar. Since it's the same time of year as Christmas, some people give gifts.
#     ユダヤ教の祭り。ユダヤ暦第９月の25日から８日間。クリスマスと同時期のため、プレゼントを渡すところも。

# %%
cal[cal['event_name_1']=='Chanukah End'][['event_name_1', 'event_type_1', 'date', 'weekday']]

# %% [markdown]
#
#
# #  References 参考文献
# [1] 過越 - Wikipedia. https://ja.wikipedia.org/wiki/%E9%81%8E%E8%B6%8A. Retrieved May 17, 2020.
# [2] バレンタインデー - Wikipedia. https://ja.wikipedia.org/wiki/%E3%83%90%E3%83%AC%E3%83%B3%E3%82%BF%E3%82%A4%E3%83%B3%E3%83%87%E3%83%BC#%E8%A5%BF%E6%AC%A7%E3%83%BB%E7%B1%B3%E5%9B%BD. Rtrieved May 17, 2020.
# [3] What is Valentine's Day and how did it start? https://www.bbc.co.uk/newsround/16945378. Retrieved May 17, 2020.
# [4] アメリカと日本のValentine’s Dayの違い. https://note.com/bicultural10/n/na5090489a8e5. Retrieved May 17, 2020.
# [5] Mother's Day - Wikipedia. https://en.wikipedia.org/wiki/Mother%27s_Day. Retrieved May 17, 2020.
# [6] NBAファイナル - Wikipedia. https://ja.wikipedia.org/wiki/NBA%E3%83%95%E3%82%A1%E3%82%A4%E3%83%8A%E3%83%AB. Retrieved May 17, 2020.
# [7] NBAプレーオフ - Wikipedia. https://ja.wikipedia.org/wiki/NBA%E3%83%97%E3%83%AC%E3%83%BC%E3%82%AA%E3%83%95. Retrieved May 17, 2020.
# [8] 戦没将兵追悼記念日 - Wikipedia. https://ja.wikipedia.org/wiki/%E6%88%A6%E6%B2%A1%E5%B0%86%E5%85%B5%E8%BF%BD%E6%82%BC%E8%A8%98%E5%BF%B5%E6%97%A5. Retrieved May 17, 2020.
# [9] プーリーム - Wikipedia. https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%BC%E3%83%AA%E3%83%BC%E3%83%A0. Retrieved May 17, 2020.
# [10] Purim - Wikipedia. https://en.wikipedia.org/wiki/Purim. Retrieved May 17, 2020.
# [11] スーパーボウル - Wikipedia. https://ja.wikipedia.org/wiki/%E3%82%B9%E3%83%BC%E3%83%91%E3%83%BC%E3%83%9C%E3%82%A6%E3%83%AB. Retrieved May 17, 2020.
# [12] ワシントン誕生日 - Wikipedia. https://ja.wikipedia.org/wiki/%E3%83%AF%E3%82%B7%E3%83%B3%E3%83%88%E3%83%B3%E8%AA%95%E7%94%9F%E6%97%A5. Retrieved May 17, 2020.
# [13] 聖パトリックの祝日 - Wikipedia. https://ja.wikipedia.org/wiki/%E8%81%96%E3%83%91%E3%83%88%E3%83%AA%E3%83%83%E3%82%AF%E3%81%AE%E7%A5%9D%E6%97%A5. Retrieved May 17, 2020.
# [14] ラマダーン - Wikipedia. https://ja.wikipedia.org/wiki/%E3%83%A9%E3%83%9E%E3%83%80%E3%83%BC%E3%83%B3. Retrieved May 17, 2020.
# [15] 独立記念日(アメリカ合衆国) - Wikipedia.  https://ja.wikipedia.org/wiki/%E7%8B%AC%E7%AB%8B%E8%A8%98%E5%BF%B5%E6%97%A5_(%E3%82%A2%E3%83%A1%E3%83%AA%E3%82%AB%E5%90%88%E8%A1%86%E5%9B%BD). Retrieved May 17, 2020.
# [16] Orthodox Christmas Day. https://www.timeanddate.com/holidays/common/orthodox-christmas-day. Retrieved May 17, 2020.
# [17] コロンブス・デー - Wikipedia. https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%AD%E3%83%B3%E3%83%96%E3%82%B9%E3%83%BB%E3%83%87%E3%83%BC. Retrieved May 17, 2020.
# [18] キング牧師記念日 - Wikipedia. https://ja.wikipedia.org/wiki/%E3%82%AD%E3%83%B3%E3%82%B0%E7%89%A7%E5%B8%AB%E8%A8%98%E5%BF%B5%E6%97%A5. Retrieved May 17, 2020.
# [19] 復活祭 - Wikipedia. https://ja.wikipedia.org/wiki/%E5%BE%A9%E6%B4%BB%E7%A5%AD. Retrieved May 17, 2020.
# [20] Easter Sunday in the United States. https://www.timeanddate.com/holidays/us/easter-sunday. Retrieved May 17, 2020.
# [21] Easter Monday in the United States. https://www.timeanddate.com/holidays/us/easter-monday. Retrieved May 17, 2020.
# [22] 感謝祭 - Wikipedia. https://ja.wikipedia.org/wiki/%E6%84%9F%E8%AC%9D%E7%A5%AD. Retrieved May 17, 2020.
# [23] イド・アル＝フィトル - Wikipedia. https://ja.wikipedia.org/wiki/%E3%82%A4%E3%83%89%E3%83%BB%E3%82%A2%E3%83%AB%EF%BC%9D%E3%83%95%E3%82%A3%E3%83%88%E3%83%AB. Retrieved May 17, 2020.
# [24] クリスマス - Wikipedia. https://ja.wikipedia.org/wiki/%E3%82%AF%E3%83%AA%E3%82%B9%E3%83%9E%E3%82%B9. Retrieved May 17, 2020.
# [25] 復員軍人の日 - Wikipedia. https://ja.wikipedia.org/wiki/%E5%BE%A9%E5%93%A1%E8%BB%8D%E4%BA%BA%E3%81%AE%E6%97%A5. Retrieved May 17, 2020.
# [26] ハヌカー - Wikipedia. https://ja.wikipedia.org/wiki/%E3%83%8F%E3%83%8C%E3%82%AB%E3%83%BC. Retrieved May 17, 2020.
# [27] イード・アル＝アドハー - Wikipedia. https://ja.wikipedia.org/wiki/%E3%82%A4%E3%83%BC%E3%83%89%E3%83%BB%E3%82%A2%E3%83%AB%EF%BC%9D%E3%82%A2%E3%83%89%E3%83%8F%E3%83%BC. Retrieved May 17, 2020.
# [28] レイバー・デー (アメリカ合衆国) - Wikipedia. https://ja.wikipedia.org/wiki/%E3%83%AC%E3%82%A4%E3%83%90%E3%83%BC%E3%83%BB%E3%83%87%E3%83%BC_(%E3%82%A2%E3%83%A1%E3%83%AA%E3%82%AB%E5%90%88%E8%A1%86%E5%9B%BD). Retrieved May 17, 2020.
# [29] New Year's Day in the United States. https://www.timeanddate.com/holidays/us/new-year-day. Retrieved May 17, 2020.
# [30] Halloween - Wikipedia. https://en.wikipedia.org/wiki/Halloween. Retrieved May 17, 2020.
# [31] シンコ・デ・マヨ - Wikipedia. https://ja.wikipedia.org/wiki/%E3%82%B7%E3%83%B3%E3%82%B3%E3%83%BB%E3%83%87%E3%83%BB%E3%83%9E%E3%83%A8. Retrieved May 17, 2020.
# [32] 父の日 - Wikipedia. https://ja.wikipedia.org/wiki/%E7%88%B6%E3%81%AE%E6%97%A5. Retrieved May 17, 2020.
# [33] 2020 Federal Holidays Calendar. https://www.redcort.com/us-federal-bank-holidays. Retrieved May 17, 2020.
# [34] DeepL. https://www.deepl.com/home. Retrieved May 17, 2020.
