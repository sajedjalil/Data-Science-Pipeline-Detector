# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder

# calendar = pd.read_csv('../input/m5-forecasting-accuracy/calendar.csv')
# train_eval = pd.read_csv('../input/m5-forecasting-accuracy/sales_train_evaluation.csv')
# train_val = pd.read_csv('../input/m5-forecasting-accuracy/sales_train_validation.csv')
sub = pd.read_csv('../input/m5-forecasting-accuracy/sample_submission.csv')
# prices = pd.read_csv('../input/m5-forecasting-accuracy/sell_prices.csv')

lgb_results = pd.read_csv('../input/vanila-lgb-results/results_of_lgbm_untuned.csv')

print ('SETUP COMPLETE')

# %%
columns_to_change = ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10','F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18',
                      'F19', 'F20', 'F21', 'F22', 'F23', 'F24', 'F25', 'F26', 'F27', 'F28']
lgb_results.columns = columns_to_change
lgb_results = pd.concat([lgb_results, lgb_results],axis=0).reset_index(drop=True)
preds = pd.concat([sub.id,lgb_results],axis=1).reset_index(drop=True)
preds.to_csv('submission.csv', index=False)
print('can submit')

# %%
# store_list = ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1',
#        'WI_2', 'WI_3']
# for store in store_list:
#     globals()["train_"+str(store)] = train_eval[train_eval['store_id']==store].reset_index(drop=True)

# %%
# import statsmodels.api as sm
# storage_data_frame = pd.DataFrame()
# train_evald = train_WI_3.drop(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'],axis=1)
# train_evaldt = train_evald.transpose()
# for iterator in range(3049):
#     try:
#         train = np.asarray(train_evaldt[iterator].astype(float))
#         mod = sm.tsa.statespace.SARIMAX(train, order=(0,1,1), seasonal_order=(0,1,1,7))
#         results=mod.fit()
#         storage_predict = pd.Series(results.predict(start=1941,end=1968))
#         storage_data_frame = pd.concat([storage_data_frame,storage_predict],axis=1)
#         print(str(iterator)+'-th iteration done of 3049')
#     except:
#         iterator += 1
# storage_data_frame = storage_data_frame.transpose()
# storage_data_frame.to_csv('predictions_wi3.csv')
# storage_data_frame.shape

# %%
# import statsmodels.api as sm
# storage_data_frame = pd.DataFrame()
# train_evald = train_WI_3.drop(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'],axis=1)
# train_evaldt = train_evald.transpose()
# for iterator in range(3049):
#     train = np.asarray(train_evaldt[iterator].astype(float))
#     mod = sm.tsa.statespace.SARIMAX(train, order=(0,1,1), seasonal_order=(0,1,1,7))
#     results=mod.fit()
#     storage_predict = pd.Series(results.predict(start=1941,end=1968))
#     storage_data_frame = pd.concat([storage_data_frame,storage_predict],axis=1)
#     print(str(iterator)+'-th iteration done of 3049')
# storage_data_frame = storage_data_frame.transpose()
# storage_data_frame.to_csv('predictions_wi3.csv')
# storage_data_frame.shape
