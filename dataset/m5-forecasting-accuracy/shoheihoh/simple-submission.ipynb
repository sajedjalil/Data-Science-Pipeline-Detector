# %% [markdown]
# # First　submission
#
# 28日前の売り上げをそのままsubmit。
# 参考にしたコード(https://www.kaggle.com/takahiro1127/starter-data-exploration-lstm)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from itertools import cycle
from tqdm import tqdm_notebook as tqdm
pd.set_option('max_columns', 50)
plt.style.use('bmh')
color_cycle = cycle(plt.rcParams['axes.prop_cycle'].by_key()['color'])

# %%
# Read in the data
INPUT_DIR = '../input/m5-forecasting-accuracy'
cal = pd.read_csv(f'{INPUT_DIR}/calendar.csv')
stv = pd.read_csv(f'{INPUT_DIR}/sales_train_validation.csv')
ss = pd.read_csv(f'{INPUT_DIR}/sample_submission.csv')
sellp = pd.read_csv(f'{INPUT_DIR}/sell_prices.csv')

# %%
stv

# %%
stv.loc[0:30489, 'd_1886':'d_1913']

# %%
ss.loc[0:30489, 'F1':'F28'] = stv.loc[0:30489, 'd_1886':'d_1913'].values

# %%
ss.loc[30490:60979, 'F1':'F28'] = stv.loc[0:30489, 'd_1886':'d_1913'].values

# %%
ss.tail(10)

# %%
ss.to_csv('submission.csv', index=False)
