# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Load data
train = pd.read_csv("/kaggle/input/tabular-playground-series-nov-2021/train.csv", index_col='id'
#                     , nrows=5000
                   )
test = pd.read_csv("/kaggle/input/tabular-playground-series-nov-2021/test.csv", index_col='id'
#                     , nrows=2500
                   )
print(train.shape)
print(test.shape)

# %%
# General info
train.info()

# %%
train.head()

# %%
train.describe()

# %% [markdown]
# Features data are distributed in a different ranges. So, we need scaling.

# %%
train.target.hist()

# %% [markdown]
# Target data is not skewed

# %%
features = list(train.select_dtypes('float').columns)

# %%
train.iloc[:, :20].hist(bins=100, figsize = (15,20))

# %%
train.iloc[:, 20:40].hist(bins=100, figsize = (15,20))

# %%
train.iloc[:, 40:80].hist(bins=100, figsize = (20,20))

# %%
train.iloc[:, 80:100].hist(bins=100, figsize = (15,20))

# %% [markdown]
# There are some features with bimodal distribution without left/right tails. \
# Most other features have one mode distribution near the Zero value. \
# There are some interesting exclusions: f21, f36 and maybe f39.

# %%
#train.f58.hist(bins=200) #, alpha=0.5)

# %%
#train.f58.describe()

# %%
#train[['f58']].boxplot(vert=0, figsize=(15, 10), notch=True, meanline=True, showmeans=True, patch_artist=True)

# %%
corr = train[['target'] + features].corr()
corr.style.background_gradient(cmap='coolwarm').format(precision = 3)
