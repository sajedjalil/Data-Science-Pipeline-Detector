# %% [markdown]
# # Goal
#
# In this notebook we will explore how to do Automatic Exploratory Data Analysis (EDA) on the Tabular Playground Series November 2021 dataset using [autoviz](https://github.com/AutoViML/AutoViz).
#
# We are going to cover the following steps:
# 1. Install autoviz
# 2. Import libraries
# 3. Load dataset
# 4. Print Report
# 5. References
#
# Let's get started.
#
# # Install autoviz

# %%
# !pip install git+git://github.com/AutoViML/AutoViz.git
# !pip install xlrd

# %% [markdown]
# # Import libraries

# %%
from pandas import read_csv

# %% [markdown]
# # Load dataset

# %%
# Load dataset
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
filename_training          = '/kaggle/input/tabular-playground-series-nov-2021/train.csv'
dataset_training           = read_csv(filename_training)

# %% [markdown]
# # Print Report

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()
dftc = AV.AutoViz(
    filename='', 
    sep='' , 
    depVar='target', 
    dfte=dataset_training, 
    header=0, 
    verbose=1, 
    lowess=False, 
    chart_format='png', 
    max_rows_analyzed=1000000, 
    max_cols_analyzed=105
)

# %% [markdown]
# # References
#
# Thank you to andreshg for sharing how to do Automatic EDA in this [notebook](https://www.kaggle.com/andreshg/automatic-eda-libraries-comparisson/notebook).
