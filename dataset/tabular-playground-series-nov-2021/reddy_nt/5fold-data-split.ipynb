# %%
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, train_test_split

# %%
input_path = Path('/kaggle/input/tabular-playground-series-nov-2021/')

# %%
train_df = pd.read_csv(input_path/'train.csv')
test_df = pd.read_csv(input_path/'test.csv')
submission_df = pd.read_csv(input_path/'sample_submission.csv')

train_df.shape, test_df.shape

# %%
target_var = train_df.target
# train_df.drop('target', axis=1, inplace=True)

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=13)
train_df['fold_no'] = None

for enum, (train_ix, test_ix) in enumerate(cv.split(train_df, target_var)):
    train_df.loc[test_ix, 'fold_no'] = enum

# %%
train_df.fold_no.value_counts()

# %%
train_df.head()

# %%
train_df.loc[:, ['id', 'fold_no']].to_csv('train_df_5fold.csv', index=False)
