# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Thank's to every public nb contributor

# %%
sub=pd.read_csv('../input/tabular-playground-series-nov-2021/sample_submission.csv')

# %%
df1=pd.read_csv("../input/new-public-submissions/submission (5).csv")
df2=pd.read_csv("../input/new-public-submissions/DNN_Submission (1).csv")
df3=pd.read_csv("../input/new-public-submissions/submission (6).csv")
df4=pd.read_csv("../input/new-public-submissions/nn_baseline (1).csv")
df5=pd.read_csv("../input/new-public-submissions/submission (7).csv")
df6=pd.read_csv("../input/new-public-submissions/submission (8).csv")
df7=pd.read_csv("../input/new-public-submissions/submission (9).csv")
df8=pd.read_csv("../input/new-public-submissions/submission (10).csv")
df9=pd.read_csv("../input/new-public-submissions/submission (11).csv")
df10=pd.read_csv("../input/new-public-submissions/1_sub.csv")

# %%
df1.head()

# %%
df2.head()

# %%
df3.head()

# %%
df4.head()

# %%
df5.head()

# %%
# df6.head()

# %%
# sub['target']=(10*df1['target'] + 4*df2['target']  + 3*df3['target'] + 2*df4['target'] +1*df5['target'] )/20

# %%
# sub['target']=(10*df1['target'] + 5*df2['target']  + 5*df3['target'] + 2*df4['target'] +2*df5['target'] )/24

# %%
df

# %%
sub['target']=(10*df1['target'].rank() + 4*df2['target'].rank()  + 3*df3['target'].rank() + 
               2*df4['target'].rank() +1*df5['target'].rank())/20# +5*df6['target'].rank()+
#                4*df7['target'].rank()+3*df8['target'].rank()+2*df9['target'].rank()+df10['target'].rank())/55

# %%
sub.head()

# %%
sub.to_csv("public_ensembleing7.csv",index=False)
