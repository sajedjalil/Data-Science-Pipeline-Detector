# %%
import pandas as pd

# %%
dataset_train = pd.read_csv('../input/tabular-playground-series-aug-2021/train.csv', index_col='id')
dataset_test = pd.read_csv('../input/tabular-playground-series-aug-2021/test.csv', index_col='id')
y = dataset_train.loss
y = pd.DataFrame(y)
dataset_train = dataset_train.drop(['loss'], axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
x_scaler = MinMaxScaler()
dataset_train_sc = x_scaler.fit_transform(dataset_train)
dataset_test_sc = x_scaler.transform(dataset_test)

# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.models import load_model
from matplotlib import pyplot as plt

model = load_model('../input/pseudo-tpu-aug-2021/model1.h5')

# %%
preds = model.predict(dataset_test_sc)
output = pd.DataFrame({'Id': dataset_test.index,'loss': preds[:,0]})
path = 'sample_submission.csv'
output.to_csv(path, index=False)
output
