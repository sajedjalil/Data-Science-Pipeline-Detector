# %% [markdown]
# # imports
#
# <p align="center">
#   <img width="600" height="350" src="https://user-images.githubusercontent.com/50532530/128719106-e8e21383-820e-4ebd-819b-f8f9bcfea318.jpg">
# </p>

# %%
# !pip install autoviz
# !pip install xlrd

from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
AV = AutoViz_Class()
from IPython.display import clear_output
clear_output()

# %% [markdown]
# # Auto viz

# %%
ff = AV.AutoViz('../input/tabular-playground-series-aug-2021/train.csv')

# %% [markdown]
# # observations and explorations

# %% [markdown]
# as we can see all there are a large number of columns and we have to understand the feature importance of the columns and based on that we have to work on the feature enginering in the next notebook I'll try to show how  to do the feature engineering 101.
#
# ### Thank you , and if you found this notebook helpfull please upvote
