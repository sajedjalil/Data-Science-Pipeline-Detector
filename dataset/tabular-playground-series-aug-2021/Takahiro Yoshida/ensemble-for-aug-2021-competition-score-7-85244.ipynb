# %% [markdown]
# This is an ensemble of public notebooks available for this competition as below, kindly upvote and appreciate the original authors for their work. The credit of this notebook goes entirely to them
#
# * Aug21 LightAutoML starter
# * LightAutoML Classifier-Regressor Mix
# * TPS Aug 21 - XGBoost & CatBoost
# * XGBRegressor with Optuna Tuning
# * Falling below 7.87 | Voting (CB/XGB/LGBM)
# * in python : tabular denoising + residual network
# * TPS Aug 2021 LGBM/XGB/CatBoost
# * [TPS Aug 2021] Simple weighted ensemble

# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv("../input/falling-below-7-87-voting-cb-xgb-lgbm/voting.csv")
data2 = pd.read_csv("../input/aug21-lightautoml-starter/In_LightAutoML_we_trust.csv")
data3 = pd.read_csv("../input/1-tps-aug-21-xgboost-catboost/submission_final.csv")
data4 = pd.read_csv("../input/lightautoml-classifier-regressor-mix/LightAutoML_utilized_submission.csv")
# data5 = pd.read_csv("../input/in-python-tabular-denoising-residual-network/submission43.csv")
data6 = pd.read_csv("../input/tps-aug-2021-lgbm-xgb-catboost/submission.csv")
data7 = pd.read_csv("../input/tps-aug-2021-simple-weighted-ensemble/submission_weighted_ensemble_8.csv")

# %%
data1.head()

# %%
data11 = data1

# %%
data11["loss"] = 0.65*data6["loss"] + 0.35*data7["loss"] + 0.0*data4["loss"]

# %%
data11.to_csv("submission.csv",index=False)
