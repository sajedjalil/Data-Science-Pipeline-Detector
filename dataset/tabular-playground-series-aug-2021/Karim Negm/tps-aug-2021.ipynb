# %%
import pandas as pd

# %%
file1 = pd.read_csv("../input/tps08-public-notebook/7.84996.csv",dtype={'loss': float,'id':int})
file2 = pd.read_csv("../input/tps08-temp/7.85000 b version 17.csv",dtype={'loss': float,'id':int})

# %%
file1.loss = file1.loss*0.7 + file2.loss*0.3 +0.01
file1

# %%
file1.to_csv('submission.csv',index=False)
