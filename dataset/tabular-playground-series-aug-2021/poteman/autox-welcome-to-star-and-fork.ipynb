# %% [markdown]
# [AutoX](https://github.com/4paradigm/autox) (A open source automl tool for competiton) to get a submission.
#
# https://github.com/4paradigm/autox: Welcome to STAR and FORK!

# %%
# !pip install ../input/autox/AutoX-master

# %%
from autox import AutoX
path = '../input/tabular-playground-series-aug-2021'
autox = AutoX(target = 'loss', train_name = 'train.csv', test_name = 'test.csv', 
               id = ['id'], path = path)
sub = autox.get_submit()
sub.to_csv("submission.csv", index = False)
