# %% [markdown]
# # <h><center> ⭐️⭐️Tabular Playground Series May 2022⭐️⭐️ </center></h>
#
# <center>
#     <img src="https://assets.website-files.com/5ac6b7f2924c656f2b13a88c/5ecb633d54bd2fe1e0378852_logo%20white.png" alt="centered image" />
# </center>
#
# ## **I attend virtual event --> Guest Morgan_McGuire(Introduce weight and bias) its great**
#
# ![crop.png](attachment:ffe1cf6c-4f8f-4d47-81bb-a6290ff3af3d.png)
#
# ## **Try it yourself guys! its free for personal usage and 100gb**
#
# ## ***I was trying to implement first time in tabular data***

# %% [markdown]
# # **Steps:**
#
# ## **Part 1: Explore the W and B:**
#
# ### **1. Install and access the W and B**
# ### **2. Import data**
# ### **3. Statistical analysis**
#
# ## **Part 2: Build Model**
#
# ## **1. Build simple sklearn ridge model**
# ## **2. Visualize w and b**
# ## **3. Predict output**
#
# ### **This is overall explore of W&B**

# %% [markdown]
# # **Import necessary library**

# %%
import gc
import os
import wandb
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
warnings.filterwarnings('ignore')

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
#secret_value_0 = user_secrets.get_secret("api_key")
os.environ["WANDB_SILENT"] = "true"

# %% [markdown]
# # **Login the w and B and generate key and paste --> access the w and b in kaggle**

# %%
wandb.login()

# %% [markdown]
# # **Part - 2: I am trying to build model and visualize W and B**
#
# ## ***I was consider this tps data is regression and predict the output! Just one try***
#
# <img src='https://gohighbrow.com/wp-content/uploads/2019/03/Learning-how-to-think-clearly_sharing.png'>
#
# ## **Build simple sklearn ridge model, predict, Generate Submission file**
#
# ### **Try yourself what model you choose [https://docs.wandb.ai/examples](http://) and also good documation,colab example**

# %% [markdown]
# # **Install and Import necessay library**

# %%
# !pip install -qq wandb
# !pip install -qq xgboost==1.3.3
# !pip install -Uqq scikit-learn==0.24.1

# %%
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn import datasets, cluster

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# # **Build the model - Sklearn**

# %%
import wandb
wandb.init(project="TPSMAY22")

# load and preprocess dataset
# Load csv data of this competition.

DATA = "../input/tabular-playground-series-may-2022"
train_df = pd.read_csv(DATA + "/train.csv")
test_df = pd.read_csv(DATA + "/test.csv")

# Feature selection

features = [feature for feature in train_df.columns if feature not in ['id', 'target','f_27']]
test_df = test_df[features]
X = train_df[features] 
y = train_df.target
X, y = X[::2], y[::2]  # subsample for faster demo
wandb.errors.term._show_warnings = False

#split and predict output
# ignore warnings about charts being built from subset of data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# Train model, get predictions
reg = Ridge()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
predict = reg.predict(test_df)

# %% [markdown]
# # **Initialize W&B run**

# %%
run = wandb.init(project='TPSMAY22', name="regression")

# %% [markdown]
# # **Visualization_ModelPerformance**

# %%
# Residual Plot
wandb.sklearn.plot_residuals(reg, X_train, y_train)

# %%
# Outlier candidates
wandb.sklearn.plot_outlier_candidates(reg, X_train, y_train)

# %% [markdown]
# # **All in one regression plot**

# %%
#This time i am trying plot of regressor, considered the regression data! This is just try
wandb.sklearn.plot_regressor(reg, X_train, X_test, y_train, y_test, model_name='Ridge')
wandb.finish()

# %% [markdown]
# ![Screenshot from 2022-05-13 14-16-15.png](attachment:27c4241b-e35a-4f65-a9c8-73c6203b18c0.png)
# ![Screenshot from 2022-05-13 14-19-37.png](attachment:7f957f77-d8e4-4f17-8b36-b7faf70446ae.png)

# %% [markdown]
# # **Submission file**

# %%
sample = pd.read_csv(DATA + "/sample_submission.csv")

# %%
sample.target = predict
sample.to_csv('submission.csv',index=False)
print('successfully done with W and B')
sample.head()

# %% [markdown]
# ## **⭐️⭐️Thank you for visiting guys⭐️⭐️**
#
# **Reference: Full_credit-This Notebook_Content**
#
# 1. https://www.kaggle.com/code/usharengaraju/tps-june-weights-and-biases
# 2. https://docs.wandb.ai/guides/integrations/scikit
