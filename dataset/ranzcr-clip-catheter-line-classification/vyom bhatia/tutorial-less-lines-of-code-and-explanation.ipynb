# %% [markdown]
# <center><div style="background:url(https://www.teahub.io/photos/full/19-197024_backgrounds-medical-hd-best-free-medicine-wallpapers-medicine.jpg); border-radius:8px;padding:20px; color:gray"><h1 style="font-size: 40px;">DATA EXPLANATION VIDEO</h1></div></center><br><br>
#             <div style="margin-left:50px;margin-right:50px;">
#     <p style="font-size:20px">Did I actually sit down to discuss this competetion with myself? You bet I did.<br><br><a hreaf="https://www.linkedin.com/posts/vyom-bhatia-40ba79181_computervision-activity-6747848578720419840-wMNc">Check it out here on LinkedIn.</a></p></div>

# %% [markdown]
# <center><div style="background:url(https://www.teahub.io/photos/full/19-197024_backgrounds-medical-hd-best-free-medicine-wallpapers-medicine.jpg); border-radius:8px;padding:20px; color:gray"><h1 style="font-size: 40px;">INTUBATION</h1></div></center><br><br>
#             <div style="margin-left:50px;margin-right:50px;">
#     <p style="font-size:20px">Nasogastric intubation is a medical process involving the insertion of a plastic tube through the nose, past the throat, and down into the stomach. <br>Orogastric intubation is a similar process involving the insertion of a plastic tube (orogastric tube) through the mouth.</p>
#
#
# <img src="https://cdn.sanity.io/images/0vv8moc6/contagion/932718a7efb2e107df436416a1d72fcda8250b89-3984x2656.jpg?auto=format" style="width:30%;border-radius:10px;float:right;"><br><br>
#     <center><div style="background:url(https://www.teahub.io/photos/full/19-197024_backgrounds-medical-hd-best-free-medicine-wallpapers-medicine.jpg); border-radius:8px;padding:20px; color:gray"><h1 style="font-size: 40px;">NCOVID-19 AND INTUBATION</h1></div></center><br>
# <p style="font-size:20px">The “early intubation” makes sense for two reasons:<br> <br>(1) patients with COVID-19 can deteriorate rapidly (e.g. from minimal oxygen requirements to life-threatening hypoxaemia and respiratory distress in hours) and <br><br>(2) it takes time to deal with the logistical complexity of preparing for, and performing, intubation of patients with COVID-19.<br><br> This logistical complexity arises from needing to transfer the patient to an appropriate location for intubation while maintaining infection control measures and the need for for the intubation team to assemble, don appropriate personal protective equipment (PPE), and prepare for this potentially life-or-death intervention.<br><br>Point being that patients with covid have a lot of complications. As the covid cases rise, we are seeing a rise in need of intubations.<br>Even though, Intubation has its own complications and require a technician or a physician to go through x-rays to ensure the tube is not erratically placed, which is prone to human errors.</p>
# <br><br>
#
# <img src="https://healthjade.net/wp-content/uploads/2019/05/nasogastric-tube.jpg" style="width:30%;border-radius:10px;float:left;"><br><br>
#     <center><div style="background:url(https://www.teahub.io/photos/full/19-197024_backgrounds-medical-hd-best-free-medicine-wallpapers-medicine.jpg); border-radius:8px;padding:60px; color:gray;"><h1 style="font-size: 40px;">COMPLICATIONS</h1></div></center><br><br>
#     <p style="font-size:20px;margin-left:50px;margin-right:50px;">If your NG tube isn’t inserted properly, it can potentially injure the tissue inside your nose, sinuses, throat, esophagus, or stomach.
# <br><br>
# This is why placement of the NG tube is checked and confirmed to be in the correct location before any other action is performed.</p></div><br><br>

# %% [markdown]
# <div style="margin-left:50px;margin-right:50px;">
# <img src="https://scontent.fdel27-2.fna.fbcdn.net/v/t31.0-8/704596_398230280272514_875501421_o.jpg?_nc_cat=100&ccb=2&_nc_sid=6e5ad9&_nc_ohc=elhSWP5xLp4AX8Ho6pF&_nc_oc=AQl_SLeozTq2hi4ktY5qBxr-a4u4jlFUKSr16K5AJcL_PAwFfffvt70edZmnrzs-VVA&_nc_ht=scontent.fdel27-2.fna&oh=ae907de942569e6dec4dce714c95eff7&oe=600C13B4" style="width:50%;border-radius:10px;float:left;"><br><br>
#     <center><div style="background:url(https://www.teahub.io/photos/full/19-197024_backgrounds-medical-hd-best-free-medicine-wallpapers-medicine.jpg); border-radius:8px;padding:60px; color:gray;"><h1 style="font-size: 40px;">NEED FOR AI</h1></div></center><br><br>
#     <p style="font-size:20px;margin-left:50px;margin-right:50px;">We need the physicians to do the jobs of spending time and looking through every single x-ray to see any abnormalitites.
# <br><br>
# Well if we can get AI to do the work, we free up human capital and save time. <br><br>That's why we fricking need AI.</p></div>

# %% [markdown]
# <div style="margin-left:50px;margin-right:50px;">
# <center><div style="background:url(https://www.teahub.io/photos/full/19-197024_backgrounds-medical-hd-best-free-medicine-wallpapers-medicine.jpg); border-radius:8px;padding:20px; color:white;"><h1 style="font-size: 40px;">TIME TO CODE</h1></div><br>
# <p style="font-size:20px;margin-left:50px;margin-right:50px;">The point is simple, we need a model to solve the problem, let's build one. <br><br>Also,<br><br> My mom said that I would be married off if I don't get 5 upvotes on this notebook. <br>That's how it works in India. Deal with it. </p></center></div>

# %% [markdown]
# # Importing Libraries + Data

# %%
# !pip install -q efficientnet_pytorch

# %%
from efficientnet_pytorch import EfficientNet

# %%
from fastai.vision.all import *
import torch

import pandas as pd

# %% [markdown]
# #### Reading the CSV with annotations.

# %%
data = pd.read_csv("../input/ranzcr-clip-catheter-line-classification/train_annotations.csv")
data.head()

# %% [markdown]
# # Forming the Dataloader

# %% [markdown]
# ### Defining the functions to grab those files.

# %%
path = "../input/ranzcr-clip-catheter-line-classification"

def get_x(r):
    return path + "/" + 'train' + "/" + r['StudyInstanceUID'] + ".jpg"

def get_y(r):
    return r['label']

# %% [markdown]
# ### Finally setting up the Dataloader for FastAI.
# #### Well below you can see we got a lot of hyperparmeter tuning. Hit me up on [LinkedIn](https://www.linkedin.com/in/vyom-bhatia-40ba79181/) on [Instagram](https://instagram.com/vyombhatia) if you got any questions.

# %%
def getblock(size=400,batch=32, data_df=data):
    block = DataBlock(blocks=(ImageBlock, CategoryBlock),
                      splitter=RandomSplitter(seed=42),
                      get_x=get_x, # Using the function above.
                      get_y=get_y, # Using the function above.
                      item_tfms = RandomResizedCrop(400), # Resizing images to 400 pixels.
                      
                      # Data Augmentation time:
                      batch_tfms = [*aug_transforms(mult=1.0, do_flip=False,
                                                   flip_vert=False, max_rotate=5,
                                                   min_zoom=1.0, max_zoom=1,
                                                   pad_mode="zeros",
                                                   xtra_tfms=[Contrast(max_lighting=0.15,p=1)],
                                                   max_lighting=0.1, max_warp=0.2,
                                                   p_affine=0.75, p_lighting=0.75),
                                    Normalize.from_stats(*imagenet_stats)])
    
    return block.dataloaders(data_df, bs=batch)

# %%
dataloader = getblock()

# %% [markdown]
# # Visualizing

# %% [markdown]
# ### Lets see how the data augmentations is doing:

# %%
dataloader.show_batch()

# %% [markdown]
# # Building the model

# %% [markdown]
# ### Easy Peasy grab a resnet50 and train the model using transfer learning:

# %%
model = EfficientNet.from_pretrained('efficientnet-b2')

# %%
learn = Learner(dataloader, model, metrics = accuracy)

# %% [markdown]
# # Learning Rate Finder

# %% [markdown]
# ### I absolutely love this function from the FastAI library.
# ### Why? It finds you the best Learning Rate.

# %%
learn.lr_find()

# %%
learn.fine_tune(2, 0.001737800776027143)
# The above LR was suggested by the lr_find.

# %% [markdown]
# ### Yes Josh, I know that the accuracy sucks with EfficientNet-B2 and my current hyperparameters for data augmentation. I will keep updating this notebook every few hours.
# ### A little background about me?
# ### I am an 18-year-old business major, Fresher at Delhi University and my mom will marry me off if you don't upvote this notebook. That's how it works here. Thank you. Love from India.
