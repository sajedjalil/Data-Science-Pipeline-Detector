# %% [markdown]
# You know, StratifiedKFold of scikit-learn cannot deal with multi-label data.
# So, here I would like to get stratified folds using the randomized algorithm.

# %%
# load libraries
import numpy as np
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import KFold, StratifiedKFold

# %%
# set parameters
NUM_FOLD = 5
SEED = 42

# %%
# fix random seed
np.random.seed(SEED)

# %%
# load data
df_train = pd.read_csv("../input/train_curated.csv")
df_test = pd.read_csv("../input/sample_submission.csv")

# preprocess labels
labels = df_test.columns[1:].tolist()
NUM_CLASS = len(labels)

for label in labels:
    df_train[label] = df_train['labels'].apply(lambda x: label in x)
print(df_train.shape)
df_train.head()
# Out:
# (4970, 82)
#           fname           labels        ...           Yell  Zipper_(clothing)
# 0  0006ae4e.wav             Bark        ...          False              False
# 1  0019ef41.wav         Raindrop        ...          False              False
# 2  001ec0ad.wav  Finger_snapping        ...          False              False
# 3  0026c7cb.wav              Run        ...          False              False
# 4  0026f116.wav  Finger_snapping        ...          False              False
#
# [5 rows x 82 columns]

# %%
# try KFold
folds = list(KFold(n_splits=NUM_FOLD, shuffle=True, random_state=SEED).split(np.arange(len(df_train))))
df_train['fold'] = 0
for i in range(NUM_FOLD):
    df_train['fold'][folds[i][1]] = i

# %%
# Check how well the folds are stratified.
print("fold                                         1    2    3    4    5   total")
print("==========================================================================")
for label in labels:
    label_padded = label + " "*(40-len(label))
    dist = ": "
    for i in range(NUM_FOLD):
        dist += "{:4d} ".format(df_train[label][folds[i][1]].sum())
    dist += "{:4d} ".format(df_train[label].sum())
    print(label_padded + dist)
label_padded = "total" + " "*(40-len("total"))
dist = ": "
for i in range(NUM_FOLD):
    dist += "{:4d} ".format(df_train.iloc[folds[i][1]].shape[0])
dist += "{:4d} ".format(df_train.shape[0])
print(label_padded + dist)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :   14   12   15   17   17   75
# Accordion                               :   16   11    7    8    5   47
# Acoustic_guitar                         :   17   14   11   12   21   75
# Applause                                :   16   15   16   14   14   75
# Bark                                    :   16   13   15   17   14   75
# Bass_drum                               :   18   13   16   14   14   75
# Bass_guitar                             :   13   16   17   17   12   75
# Bathtub_(filling_or_washing)            :   14   11   21   15   14   75
# Bicycle_bell                            :    8   14   18   11   16   67
# Burping_and_eructation                  :   21   19   11   11   13   75
# Bus                                     :   11   19   13   15   17   75
# Buzz                                    :   13    7   16   10   10   56
# Car_passing_by                          :   11   17   17   12   18   75
# Cheering                                :   13   15   16   16   15   75
# Chewing_and_mastication                 :   16    9   14   17   19   75
# Child_speech_and_kid_speaking           :   15   11   15   15   19   75
# Chink_and_clink                         :   21    9   17   20    8   75
# Chirp_and_tweet                         :   14   17   16   18   10   75
# Church_bell                             :   14    8   16   16   21   75
# Clapping                                :   11   20   20   16    8   75
# Computer_keyboard                       :   12   19   17   12   15   75
# Crackle                                 :   13   16   16   16   14   75
# Cricket                                 :   14   15   15   17   14   75
# Crowd                                   :   14   18   17   14   12   75
# Cupboard_open_or_close                  :   22   17   11   14   11   75
# Cutlery_and_silverware                  :   15   10   19   19   12   75
# Dishes_and_pots_and_pans                :   19   12   16   20    8   75
# Drawer_open_or_close                    :   11   13   19   17   15   75
# Drip                                    :   16   15   11   19   14   75
# Electric_guitar                         :   14   12   13   22   14   75
# Fart                                    :   18   17   16   16    8   75
# Female_singing                          :   12   17   13    8   25   75
# Female_speech_and_woman_speaking        :   14   11   14   18   18   75
# Fill_(with_liquid)                      :   12    9    8    9   12   50
# Finger_snapping                         :   17   21    8   18   11   75
# Frying_(food)                           :   11   14   12   17    9   63
# Gasp                                    :    7   11    8   12   10   48
# Glockenspiel                            :   14   11   15    8    8   56
# Gong                                    :   15   13   22   12   13   75
# Gurgling                                :   16   15   10   15   19   75
# Harmonica                               :   19   15   16   11   14   75
# Hi-hat                                  :   22   14   12   14   13   75
# Hiss                                    :   15   16   17   11   16   75
# Keys_jangling                           :   20   10   17   16   12   75
# Knock                                   :   14   19   10   15   17   75
# Male_singing                            :   14   14   15   12   20   75
# Male_speech_and_man_speaking            :   11   19   13   21   11   75
# Marimba_and_xylophone                   :   13   11   15   20   16   75
# Mechanical_fan                          :    8    7   16    9    9   49
# Meow                                    :   12   13   17   14   19   75
# Microwave_oven                          :   14   15   13   19   14   75
# Motorcycle                              :    5   19   25   15   11   75
# Printer                                 :   14   17   16   16   12   75
# Purr                                    :   13   15   13   13   11   65
# Race_car_and_auto_racing                :   13   10    7   12   14   56
# Raindrop                                :   13   18   12   18   14   75
# Run                                     :   15   11   14   17   18   75
# Scissors                                :   16   18   13   13   15   75
# Screaming                               :   17   16   13   14   15   75
# Shatter                                 :   25    7   16   12   15   75
# Sigh                                    :   14    8   12   19    4   57
# Sink_(filling_or_washing)               :   19   13   13   14   16   75
# Skateboard                              :   13   18   16   12   16   75
# Slam                                    :   17   17    9   15   17   75
# Sneeze                                  :   14   16    6    9   18   63
# Squeak                                  :   14   21    5   17   18   75
# Stream                                  :   10   17   19   11   18   75
# Strum                                   :   17   15   11   10   22   75
# Tap                                     :   10   19   21   17    8   75
# Tick-tock                               :   14    6   11   15   26   72
# Toilet_flush                            :   23   12   11   10   19   75
# Traffic_noise_and_roadway_noise         :   18   14   16   14   13   75
# Trickle_and_dribble                     :   11   12   12    7   11   53
# Walk_and_footsteps                      :   11   22   11   14   17   75
# Water_tap_and_faucet                    :   20   14   10   17   14   75
# Waves_and_surf                          :   15   19   12   19   10   75
# Whispering                              :    8   19   16   12   20   75
# Writing                                 :   12   13   16   12   22   75
# Yell                                    :   14   13   19   19   10   75
# Zipper_(clothing)                       :   17   17   13   15   13   75
# total                                   :  994  994  994  994  994 4970

# %% [markdown]
# You can see the folds are not stratified well.
# OK. Let's do the more sophisticated splitting.

# %%
# calculate number of positive label for each sample
df_train['num_labels'] = df_train[labels].values.sum(axis=1)
df_train.loc[:,['labels', 'num_labels']].head(10)
# Out:
#                   labels  num_labels
# 0                   Bark           1
# 1               Raindrop           1
# 2        Finger_snapping           1
# 3                    Run           1
# 4        Finger_snapping           1
# 5             Whispering           1
# 6  Acoustic_guitar,Strum           2
# 7                 Hi-hat           1
# 8              Bass_drum           1
# 9         Crowd,Cheering           2

# %%
# extract data sample with single label and do StratifiedKFold

df_train_single = df_train[df_train['num_labels']==1].reset_index(drop=True)
single_folds = list(StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=SEED).split(
    np.arange(len(df_train_single)), df_train_single[labels].values.argmax(axis=1)))
df_train_single['fold'] = 0
for i in range(NUM_FOLD):
    df_train_single['fold'][single_folds[i][1]] = i

# %%
# Check how well the folds are stratified.
print("fold                                         1    2    3    4    5   total")
print("==========================================================================")
for label in labels:
    label_padded = label + " "*(40-len(label))
    dist = ": "
    for i in range(NUM_FOLD):
        dist += "{:4d} ".format(df_train_single[label][df_train_single['fold']==i].sum())
    dist += "{:4d} ".format(df_train_single[label].sum())
    print(label_padded + dist)
label_padded = "total" + " "*(40-len("total"))
dist = ": "
for i in range(NUM_FOLD):
    dist += "{:4d} ".format(df_train_single[df_train_single['fold']==i].shape[0])
dist += "{:4d} ".format(df_train_single.shape[0])
print(label_padded + dist)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :    7    7    6    6    6   32
# Accordion                               :   10   10    9    9    9   47
# Acoustic_guitar                         :    1    0    1    1    0    3
# Applause                                :    0    0    0    0    0    0
# Bark                                    :   14   14   14   14   13   69
# Bass_drum                               :   14   14   14   13   13   68
# Bass_guitar                             :   13   13   13   13   12   64
# Bathtub_(filling_or_washing)            :   12   11   11   11   11   56
# Bicycle_bell                            :   14   14   13   13   13   67
# Burping_and_eructation                  :   15   15   15   15   14   74
# Bus                                     :   14   14   14   14   14   70
# Buzz                                    :   11   11   10   10   10   52
# Car_passing_by                          :   13   13   12   12   12   62
# Cheering                                :    0    0    0    0    0    0
# Chewing_and_mastication                 :   15   15   15   15   14   74
# Child_speech_and_kid_speaking           :   15   15   14   14   14   72
# Chink_and_clink                         :    8    8    8    7    7   38
# Chirp_and_tweet                         :   14   13   13   13   13   66
# Church_bell                             :   15   15   15   14   14   73
# Clapping                                :   11   11   10   10   10   52
# Computer_keyboard                       :   15   15   15   15   15   75
# Crackle                                 :   15   15   15   14   14   73
# Cricket                                 :   14   14   14   13   13   68
# Crowd                                   :    1    1    1    1    1    5
# Cupboard_open_or_close                  :   13   13   13   13   12   64
# Cutlery_and_silverware                  :    7    7    7    6    6   33
# Dishes_and_pots_and_pans                :    0    0    0    0    0    0
# Drawer_open_or_close                    :   14   13   13   13   13   66
# Drip                                    :    1    0    1    1    1    4
# Electric_guitar                         :   11   11   10   10   10   52
# Fart                                    :   15   15   15   15   14   74
# Female_singing                          :   14   13   13   13   13   66
# Female_speech_and_woman_speaking        :    9    9    9    9    8   44
# Fill_(with_liquid)                      :    8    8    8    8    8   40
# Finger_snapping                         :   15   15   15   15   15   75
# Frying_(food)                           :   12   12   12   12   12   60
# Gasp                                    :   10    9    9    9    9   46
# Glockenspiel                            :   12   11   11   11   11   56
# Gong                                    :   15   15   15   15   15   75
# Gurgling                                :   11   11   10   10   10   52
# Harmonica                               :   15   15   15   14   14   73
# Hi-hat                                  :   14   14   14   14   14   70
# Hiss                                    :   15   15   14   14   14   72
# Keys_jangling                           :   15   15   15   15   15   75
# Knock                                   :   14   14   14   14   14   70
# Male_singing                            :   13   13   13   13   13   65
# Male_speech_and_man_speaking            :   13   12   12   12   12   61
# Marimba_and_xylophone                   :   15   15   15   15   15   75
# Mechanical_fan                          :   10   10   10   10    9   49
# Meow                                    :   12   12   12   12   11   59
# Microwave_oven                          :   14   14   14   13   13   68
# Motorcycle                              :   12   12   12   12   11   59
# Printer                                 :   15   15   15   15   15   75
# Purr                                    :   11   11   10   10   10   52
# Race_car_and_auto_racing                :    6    6    5    5    5   27
# Raindrop                                :    4    4    4    4    3   19
# Run                                     :   14   13   13   13   13   66
# Scissors                                :   15   15   15   15   15   75
# Screaming                               :   10   10   10   10   10   50
# Shatter                                 :   15   15   14   14   14   72
# Sigh                                    :   12   12   11   11   11   57
# Sink_(filling_or_washing)               :    0    0    0    0    0    0
# Skateboard                              :   15   15   15   15   15   75
# Slam                                    :    8    8    8    8    7   39
# Sneeze                                  :   13   13   12   12   12   62
# Squeak                                  :    5    5    4    4    4   22
# Stream                                  :   15   14   14   14   14   71
# Strum                                   :    0    0    0    0    0    0
# Tap                                     :   13   13   13   13   13   65
# Tick-tock                               :   15   15   14   14   14   72
# Toilet_flush                            :   13   13   13   12   12   63
# Traffic_noise_and_roadway_noise         :   12   12   11   11   11   57
# Trickle_and_dribble                     :    7    7    7    7    7   35
# Walk_and_footsteps                      :    9    9    8    8    8   42
# Water_tap_and_faucet                    :    0    0    0    0    0    0
# Waves_and_surf                          :   15   14   14   14   14   71
# Whispering                              :   14   14   14   13   13   68
# Writing                                 :   15   15   14   14   14   72
# Yell                                    :    5    5    5    5    4   24
# Zipper_(clothing)                       :   15   15   15   15   15   75
# total                                   :  881  869  851  841  827 4269

# %%
# extract data sample with multi labels
df_train_multi = df_train[df_train['num_labels']!=1].reset_index(drop=True)

# count each label
label_counts = []
for i in range(NUM_CLASS):    
    label = labels[i] + " "*(40-len(labels[i]))
    label_counts.append(df_train_multi[labels[i]].sum())
    print("{:2d} {} {}".format(i, label, label_counts[i]))
# Out:
#  0 Accelerating_and_revving_and_vroom       43
#  1 Accordion                                0
#  2 Acoustic_guitar                          72
#  3 Applause                                 75
#  4 Bark                                     6
#  5 Bass_drum                                7
#  6 Bass_guitar                              11
#  7 Bathtub_(filling_or_washing)             19
#  8 Bicycle_bell                             0
#  9 Burping_and_eructation                   1
# 10 Bus                                      5
# 11 Buzz                                     4
# 12 Car_passing_by                           13
# 13 Cheering                                 75
# 14 Chewing_and_mastication                  1
# 15 Child_speech_and_kid_speaking            3
# 16 Chink_and_clink                          37
# 17 Chirp_and_tweet                          9
# 18 Church_bell                              2
# 19 Clapping                                 23
# 20 Computer_keyboard                        0
# 21 Crackle                                  2
# 22 Cricket                                  7
# 23 Crowd                                    70
# 24 Cupboard_open_or_close                   11
# 25 Cutlery_and_silverware                   42
# 26 Dishes_and_pots_and_pans                 75
# 27 Drawer_open_or_close                     9
# 28 Drip                                     71
# 29 Electric_guitar                          23
# 30 Fart                                     1
# 31 Female_singing                           9
# 32 Female_speech_and_woman_speaking         31
# 33 Fill_(with_liquid)                       10
# 34 Finger_snapping                          0
# 35 Frying_(food)                            3
# 36 Gasp                                     2
# 37 Glockenspiel                             0
# 38 Gong                                     0
# 39 Gurgling                                 23
# 40 Harmonica                                2
# 41 Hi-hat                                   5
# 42 Hiss                                     3
# 43 Keys_jangling                            0
# 44 Knock                                    5
# 45 Male_singing                             10
# 46 Male_speech_and_man_speaking             14
# 47 Marimba_and_xylophone                    0
# 48 Mechanical_fan                           0
# 49 Meow                                     16
# 50 Microwave_oven                           7
# 51 Motorcycle                               16
# 52 Printer                                  0
# 53 Purr                                     13
# 54 Race_car_and_auto_racing                 29
# 55 Raindrop                                 56
# 56 Run                                      9
# 57 Scissors                                 0
# 58 Screaming                                25
# 59 Shatter                                  3
# 60 Sigh                                     0
# 61 Sink_(filling_or_washing)                75
# 62 Skateboard                               0
# 63 Slam                                     36
# 64 Sneeze                                   1
# 65 Squeak                                   53
# 66 Stream                                   4
# 67 Strum                                    75
# 68 Tap                                      10
# 69 Tick-tock                                0
# 70 Toilet_flush                             12
# 71 Traffic_noise_and_roadway_noise          18
# 72 Trickle_and_dribble                      18
# 73 Walk_and_footsteps                       33
# 74 Water_tap_and_faucet                     75
# 75 Waves_and_surf                           4
# 76 Whispering                               7
# 77 Writing                                  3
# 78 Yell                                     51
# 79 Zipper_(clothing)                        0

# %% [markdown]
# All labels of multi-label data cannot be stratified.
# Label with more counts should be more stratified.
# Therefore, let's select a label with more counts and remove others.

# %%
reduced_label = np.zeros(len(df_train_multi), np.uint8)
for i in range(NUM_CLASS):
    target_idx = np.argsort(label_counts)[i]
    reduced_label[df_train_multi[labels[target_idx]]==1] = target_idx

# %%
# Do StratifiedKFold using reduced label
multi_folds = list(StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=SEED).split(
    np.arange(len(df_train_multi)), reduced_label))
for i in range(NUM_FOLD):
    df_train_multi['fold'][multi_folds[i][1]] = i

# %%
# Check how well the folds are stratified.
print("fold                                         1    2    3    4    5   total")
print("==========================================================================")
for label in labels:
    label_padded = label + " "*(40-len(label))
    dist = ": "
    for i in range(NUM_FOLD):
        dist += "{:4d} ".format(df_train_multi[label][df_train_multi['fold']==i].sum())
    dist += "{:4d} ".format(df_train_multi[label].sum())
    print(label_padded + dist)
label_padded = "total" + " "*(40-len("total"))
dist = ": "
for i in range(NUM_FOLD):
    dist += "{:4d} ".format(df_train_multi[df_train_multi['fold']==i].shape[0])
dist += "{:4d} ".format(df_train_multi.shape[0])
print(label_padded + dist)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :    8    9    9    8    9   43
# Accordion                               :    0    0    0    0    0    0
# Acoustic_guitar                         :   12   15   15   16   14   72
# Applause                                :   16   15   15   15   14   75
# Bark                                    :    2    0    2    1    1    6
# Bass_drum                               :    2    0    1    3    1    7
# Bass_guitar                             :    2    3    2    2    2   11
# Bathtub_(filling_or_washing)            :    4    3    4    5    3   19
# Bicycle_bell                            :    0    0    0    0    0    0
# Burping_and_eructation                  :    0    0    0    1    0    1
# Bus                                     :    1    1    1    1    1    5
# Buzz                                    :    3    1    0    0    0    4
# Car_passing_by                          :    1    3    2    4    3   13
# Cheering                                :   16   16   13   14   16   75
# Chewing_and_mastication                 :    0    0    0    1    0    1
# Child_speech_and_kid_speaking           :    2    0    0    1    0    3
# Chink_and_clink                         :    5    6    7   10    9   37
# Chirp_and_tweet                         :    3    2    1    2    1    9
# Church_bell                             :    1    0    0    1    0    2
# Clapping                                :    6    4    4    5    4   23
# Computer_keyboard                       :    0    0    0    0    0    0
# Crackle                                 :    1    0    0    1    0    2
# Cricket                                 :    2    2    1    1    1    7
# Crowd                                   :   15   14   15   15   11   70
# Cupboard_open_or_close                  :    2    2    2    3    2   11
# Cutlery_and_silverware                  :    7    9   11    8    7   42
# Dishes_and_pots_and_pans                :   15   15   15   15   15   75
# Drawer_open_or_close                    :    2    2    1    3    1    9
# Drip                                    :   14   15   13   16   13   71
# Electric_guitar                         :    8    4    4    3    4   23
# Fart                                    :    0    0    0    1    0    1
# Female_singing                          :    2    2    2    2    1    9
# Female_speech_and_woman_speaking        :    7    7    8    5    4   31
# Fill_(with_liquid)                      :    4    2    0    3    1   10
# Finger_snapping                         :    0    0    0    0    0    0
# Frying_(food)                           :    1    0    0    2    0    3
# Gasp                                    :    1    1    0    0    0    2
# Glockenspiel                            :    0    0    0    0    0    0
# Gong                                    :    0    0    0    0    0    0
# Gurgling                                :    5    3    5    4    6   23
# Harmonica                               :    0    0    1    1    0    2
# Hi-hat                                  :    1    0    1    2    1    5
# Hiss                                    :    1    1    0    1    0    3
# Keys_jangling                           :    0    0    0    0    0    0
# Knock                                   :    1    0    1    2    1    5
# Male_singing                            :    3    2    2    2    1   10
# Male_speech_and_man_speaking            :    2    2    3    4    3   14
# Marimba_and_xylophone                   :    0    0    0    0    0    0
# Mechanical_fan                          :    0    0    0    0    0    0
# Meow                                    :    3    3    5    3    2   16
# Microwave_oven                          :    1    2    0    2    2    7
# Motorcycle                              :    5    3    3    3    2   16
# Printer                                 :    0    0    0    0    0    0
# Purr                                    :    2    3    3    3    2   13
# Race_car_and_auto_racing                :    5    5    7    6    6   29
# Raindrop                                :   10   12   12   12   10   56
# Run                                     :    1    2    1    4    1    9
# Scissors                                :    0    0    0    0    0    0
# Screaming                               :    5    6    2    8    4   25
# Shatter                                 :    0    0    1    1    1    3
# Sigh                                    :    0    0    0    0    0    0
# Sink_(filling_or_washing)               :   14   16   15   13   17   75
# Skateboard                              :    0    0    0    0    0    0
# Slam                                    :   11    7    6    4    8   36
# Sneeze                                  :    0    0    0    1    0    1
# Squeak                                  :   12   10   11   10   10   53
# Stream                                  :    1    0    0    2    1    4
# Strum                                   :   15   15   15   15   15   75
# Tap                                     :    7    0    1    2    0   10
# Tick-tock                               :    0    0    0    0    0    0
# Toilet_flush                            :    3    2    2    4    1   12
# Traffic_noise_and_roadway_noise         :    4    4    4    3    3   18
# Trickle_and_dribble                     :    3    4    4    4    3   18
# Walk_and_footsteps                      :    5    6    8    9    5   33
# Water_tap_and_faucet                    :   15   15   15   15   15   75
# Waves_and_surf                          :    0    0    2    0    2    4
# Whispering                              :    1    2    1    3    0    7
# Writing                                 :    0    0    3    0    0    3
# Yell                                    :   11   10   10   10   10   51
# Zipper_(clothing)                       :    0    0    0    0    0    0
# total                                   :  148  138  139  149  127  701

# %%
# concatenate single-label data and multi-label data
df_train2 = pd.concat([df_train_single, df_train_multi]).reset_index(drop=True)

# %%
# Check how well the folds are stratified.
print("fold                                         1    2    3    4    5   total")
print("==========================================================================")
for label in labels:
    label_padded = label + " "*(40-len(label))
    dist = ": "
    for i in range(NUM_FOLD):
        dist += "{:4d} ".format(df_train2[label][df_train2['fold']==i].sum())
    dist += "{:4d} ".format(df_train2[label].sum())
    print(label_padded + dist)
label_padded = "total" + " "*(40-len("total"))
dist = ": "
for i in range(NUM_FOLD):
    dist += "{:4d} ".format(df_train2[df_train2['fold']==i].shape[0])
dist += "{:4d} ".format(df_train2.shape[0])
print(label_padded + dist)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :   15   16   15   14   15   75
# Accordion                               :   10   10    9    9    9   47
# Acoustic_guitar                         :   13   15   16   17   14   75
# Applause                                :   16   15   15   15   14   75
# Bark                                    :   16   14   16   15   14   75
# Bass_drum                               :   16   14   15   16   14   75
# Bass_guitar                             :   15   16   15   15   14   75
# Bathtub_(filling_or_washing)            :   16   14   15   16   14   75
# Bicycle_bell                            :   14   14   13   13   13   67
# Burping_and_eructation                  :   15   15   15   16   14   75
# Bus                                     :   15   15   15   15   15   75
# Buzz                                    :   14   12   10   10   10   56
# Car_passing_by                          :   14   16   14   16   15   75
# Cheering                                :   16   16   13   14   16   75
# Chewing_and_mastication                 :   15   15   15   16   14   75
# Child_speech_and_kid_speaking           :   17   15   14   15   14   75
# Chink_and_clink                         :   13   14   15   17   16   75
# Chirp_and_tweet                         :   17   15   14   15   14   75
# Church_bell                             :   16   15   15   15   14   75
# Clapping                                :   17   15   14   15   14   75
# Computer_keyboard                       :   15   15   15   15   15   75
# Crackle                                 :   16   15   15   15   14   75
# Cricket                                 :   16   16   15   14   14   75
# Crowd                                   :   16   15   16   16   12   75
# Cupboard_open_or_close                  :   15   15   15   16   14   75
# Cutlery_and_silverware                  :   14   16   18   14   13   75
# Dishes_and_pots_and_pans                :   15   15   15   15   15   75
# Drawer_open_or_close                    :   16   15   14   16   14   75
# Drip                                    :   15   15   14   17   14   75
# Electric_guitar                         :   19   15   14   13   14   75
# Fart                                    :   15   15   15   16   14   75
# Female_singing                          :   16   15   15   15   14   75
# Female_speech_and_woman_speaking        :   16   16   17   14   12   75
# Fill_(with_liquid)                      :   12   10    8   11    9   50
# Finger_snapping                         :   15   15   15   15   15   75
# Frying_(food)                           :   13   12   12   14   12   63
# Gasp                                    :   11   10    9    9    9   48
# Glockenspiel                            :   12   11   11   11   11   56
# Gong                                    :   15   15   15   15   15   75
# Gurgling                                :   16   14   15   14   16   75
# Harmonica                               :   15   15   16   15   14   75
# Hi-hat                                  :   15   14   15   16   15   75
# Hiss                                    :   16   16   14   15   14   75
# Keys_jangling                           :   15   15   15   15   15   75
# Knock                                   :   15   14   15   16   15   75
# Male_singing                            :   16   15   15   15   14   75
# Male_speech_and_man_speaking            :   15   14   15   16   15   75
# Marimba_and_xylophone                   :   15   15   15   15   15   75
# Mechanical_fan                          :   10   10   10   10    9   49
# Meow                                    :   15   15   17   15   13   75
# Microwave_oven                          :   15   16   14   15   15   75
# Motorcycle                              :   17   15   15   15   13   75
# Printer                                 :   15   15   15   15   15   75
# Purr                                    :   13   14   13   13   12   65
# Race_car_and_auto_racing                :   11   11   12   11   11   56
# Raindrop                                :   14   16   16   16   13   75
# Run                                     :   15   15   14   17   14   75
# Scissors                                :   15   15   15   15   15   75
# Screaming                               :   15   16   12   18   14   75
# Shatter                                 :   15   15   15   15   15   75
# Sigh                                    :   12   12   11   11   11   57
# Sink_(filling_or_washing)               :   14   16   15   13   17   75
# Skateboard                              :   15   15   15   15   15   75
# Slam                                    :   19   15   14   12   15   75
# Sneeze                                  :   13   13   12   13   12   63
# Squeak                                  :   17   15   15   14   14   75
# Stream                                  :   16   14   14   16   15   75
# Strum                                   :   15   15   15   15   15   75
# Tap                                     :   20   13   14   15   13   75
# Tick-tock                               :   15   15   14   14   14   72
# Toilet_flush                            :   16   15   15   16   13   75
# Traffic_noise_and_roadway_noise         :   16   16   15   14   14   75
# Trickle_and_dribble                     :   10   11   11   11   10   53
# Walk_and_footsteps                      :   14   15   16   17   13   75
# Water_tap_and_faucet                    :   15   15   15   15   15   75
# Waves_and_surf                          :   15   14   16   14   16   75
# Whispering                              :   15   16   15   16   13   75
# Writing                                 :   15   15   17   14   14   75
# Yell                                    :   16   15   15   15   14   75
# Zipper_(clothing)                       :   15   15   15   15   15   75
# total                                   : 1029 1007  990  990  954 4970

# %% [markdown]
# You can see the folds are more stratified well, but still, it's not perfect.
# Then, let's do the randomized algorithm.
#
# If each fold is well stratified, std of the number of labels will become small.
# So Let's define a score to optimize as the mean of each fold's std of labels' count.
# The std of all label's count also should be small.

# %%
def calc_score(df):
    score = np.zeros([5,NUM_CLASS+1])
    for i in range(5):
        score[i] = df.loc[df.fold==i, labels+['num_labels']].values.sum(axis=0)
    score = score.std(axis=0).mean()
    return score
score = calc_score(df_train)
print("KFold score: {:.6f}".format(calc_score(df_train)))
print("StratifiedKFold score: {:.6f}".format(calc_score(df_train2)))
# Out:
# KFold score: 3.292604
# StratifiedKFold score: 1.184777

# %%
def do_optimize(df, size, steps):
    """
    df: dataframe to optimize folds
    size: number of data to change fold
    steps: number of for loop
    """
    starttime = time.time()
    score = calc_score(df)
    for i in range(steps):
        # select index to change fold
        change_idx = np.random.choice(np.arange(df.shape[0]), size, replace=False)
        # change fold randomly
        change_fold = np.random.randint(0, NUM_FOLD, size)
        df_new = df.copy()
        df_new['fold'][change_idx] = change_fold

        score_new = calc_score(df_new)
        if score_new < score: # if score getting small, folds will be update
            score = score_new
            df = df_new
        if i%100==0:
            print("step: {:4d}, change size: {:2d}, score: {:.6f}, sec: {:.1f}".format(
                i, size, score, time.time()-starttime))
    return df

# %%
# Let's do optimization with randomized algorithm.
df_train3 = df_train2.copy()
df_train3 = do_optimize(df_train3, size=64, steps=1000)
df_train3 = do_optimize(df_train3, size=32, steps=1000)
df_train3 = do_optimize(df_train3, size=16, steps=1000)
df_train3 = do_optimize(df_train3, size=8, steps=1000)
df_train3 = do_optimize(df_train3, size=4, steps=1000)
df_train3 = do_optimize(df_train3, size=2, steps=1000)
df_train3 = do_optimize(df_train3, size=1, steps=10000)

print("StratifiedKFold with randomized algorithm score: {:.6f}".format(calc_score(df_train3)))
# Out:
# step:    0, change size: 64, score: 1.184777, sec: 0.1
# step:  100, change size: 64, score: 1.184777, sec: 12.3
# step:  200, change size: 64, score: 1.184777, sec: 24.4
# step:  300, change size: 64, score: 1.174183, sec: 36.0
# step:  400, change size: 64, score: 1.151375, sec: 48.2
# step:  500, change size: 64, score: 1.151375, sec: 60.4
# step:  600, change size: 64, score: 1.151375, sec: 72.1
# step:  700, change size: 64, score: 1.151375, sec: 83.6
# step:  800, change size: 64, score: 1.151375, sec: 95.0
# step:  900, change size: 64, score: 1.151375, sec: 106.4
# step:    0, change size: 32, score: 1.151375, sec: 0.1
# step:  100, change size: 32, score: 1.148799, sec: 12.0
# step:  200, change size: 32, score: 1.133602, sec: 23.0
# step:  300, change size: 32, score: 1.127135, sec: 34.2
# step:  400, change size: 32, score: 1.107961, sec: 45.9
# step:  500, change size: 32, score: 1.107961, sec: 57.2
# step:  600, change size: 32, score: 1.107961, sec: 68.4
# step:  700, change size: 32, score: 1.107961, sec: 80.3
# step:  800, change size: 32, score: 1.103231, sec: 92.1
# step:  900, change size: 32, score: 1.103231, sec: 102.8
# step:    0, change size: 16, score: 1.094746, sec: 0.1
# step:  100, change size: 16, score: 1.091904, sec: 11.8
# step:  200, change size: 16, score: 1.091904, sec: 23.4
# step:  300, change size: 16, score: 1.088211, sec: 35.4
# step:  400, change size: 16, score: 1.073717, sec: 46.7
# step:  500, change size: 16, score: 1.068924, sec: 57.8
# step:  600, change size: 16, score: 1.068924, sec: 69.7
# step:  700, change size: 16, score: 1.059491, sec: 81.2
# step:  800, change size: 16, score: 1.058729, sec: 92.8
# step:  900, change size: 16, score: 1.058729, sec: 104.3
# step:    0, change size:  8, score: 1.058729, sec: 0.1
# step:  100, change size:  8, score: 1.027562, sec: 12.2
# step:  200, change size:  8, score: 1.012497, sec: 23.9
# step:  300, change size:  8, score: 1.006367, sec: 35.5
# step:  400, change size:  8, score: 1.004308, sec: 47.2
# step:  500, change size:  8, score: 0.987868, sec: 58.8
# step:  600, change size:  8, score: 0.977751, sec: 70.2
# step:  700, change size:  8, score: 0.975843, sec: 81.6
# step:  800, change size:  8, score: 0.954549, sec: 93.3
# step:  900, change size:  8, score: 0.947426, sec: 105.2
# step:    0, change size:  4, score: 0.945645, sec: 0.1
# step:  100, change size:  4, score: 0.896281, sec: 12.2
# step:  200, change size:  4, score: 0.879494, sec: 23.6
# step:  300, change size:  4, score: 0.864710, sec: 35.3
# step:  400, change size:  4, score: 0.861204, sec: 47.2
# step:  500, change size:  4, score: 0.852438, sec: 58.4
# step:  600, change size:  4, score: 0.833432, sec: 69.6
# step:  700, change size:  4, score: 0.831977, sec: 81.7
# step:  800, change size:  4, score: 0.823769, sec: 92.5
# step:  900, change size:  4, score: 0.821288, sec: 104.0
# step:    0, change size:  2, score: 0.796711, sec: 0.1
# step:  100, change size:  2, score: 0.770188, sec: 11.0
# step:  200, change size:  2, score: 0.746997, sec: 22.4
# step:  300, change size:  2, score: 0.739393, sec: 33.5
# step:  400, change size:  2, score: 0.714233, sec: 45.4
# step:  500, change size:  2, score: 0.699956, sec: 57.4
# step:  600, change size:  2, score: 0.676989, sec: 69.5
# step:  700, change size:  2, score: 0.652485, sec: 80.8
# step:  800, change size:  2, score: 0.647359, sec: 92.6
# step:  900, change size:  2, score: 0.635678, sec: 104.3
# step:    0, change size:  1, score: 0.629375, sec: 0.1
# step:  100, change size:  1, score: 0.619723, sec: 12.1
# step:  200, change size:  1, score: 0.613415, sec: 23.6
# step:  300, change size:  1, score: 0.573912, sec: 34.8
# step:  400, change size:  1, score: 0.553352, sec: 46.4
# step:  500, change size:  1, score: 0.533998, sec: 58.0
# step:  600, change size:  1, score: 0.515900, sec: 69.4
# step:  700, change size:  1, score: 0.506796, sec: 80.6
# step:  800, change size:  1, score: 0.498599, sec: 92.6
# step:  900, change size:  1, score: 0.481716, sec: 103.9

# %%
# Check how well the folds are stratified.
print("fold                                         1    2    3    4    5   total")
print("==========================================================================")
for label in labels:
    label_padded = label + " "*(40-len(label))
    dist = ": "
    for i in range(NUM_FOLD):
        dist += "{:4d} ".format(df_train3[label][df_train3['fold']==i].sum())
    dist += "{:4d} ".format(df_train3[label].sum())
    print(label_padded + dist)
label_padded = "total" + " "*(40-len("total"))
dist = ": "
for i in range(5):
    dist += "{:4d} ".format(df_train3[df_train3['fold']==i].shape[0])
dist += "{:4d} ".format(df_train3.shape[0])
print(label_padded + dist)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :   14   16   16   14   15   75
# Accordion                               :    9   10   10    9    9   47
# Acoustic_guitar                         :   12   16   16   16   15   75
# Applause                                :   16   14   14   15   16   75
# Bark                                    :   16   14   15   15   15   75
# Bass_drum                               :   16   14   14   16   15   75
# Bass_guitar                             :   15   16   16   14   14   75
# Bathtub_(filling_or_washing)            :   16   14   15   16   14   75
# Bicycle_bell                            :   14   13   13   12   15   67
# Burping_and_eructation                  :   15   15   15   15   15   75
# Bus                                     :   15   15   15   15   15   75
# Buzz                                    :   14   12   10   10   10   56
# Car_passing_by                          :   14   16   14   16   15   75
# Cheering                                :   16   15   12   14   18   75
# Chewing_and_mastication                 :   15   15   16   15   14   75
# Child_speech_and_kid_speaking           :   16   15   15   15   14   75
# Chink_and_clink                         :   13   14   15   17   16   75
# Chirp_and_tweet                         :   17   15   14   15   14   75
# Church_bell                             :   16   15   14   15   15   75
# Clapping                                :   17   14   14   15   15   75
# Computer_keyboard                       :   15   15   15   15   15   75
# Crackle                                 :   16   15   15   15   14   75
# Cricket                                 :   16   16   14   14   15   75
# Crowd                                   :   16   14   15   16   14   75
# Cupboard_open_or_close                  :   15   15   14   17   14   75
# Cutlery_and_silverware                  :   14   16   17   14   14   75
# Dishes_and_pots_and_pans                :   15   15   14   15   16   75
# Drawer_open_or_close                    :   15   15   15   15   15   75
# Drip                                    :   15   15   14   17   14   75
# Electric_guitar                         :   18   15   15   13   14   75
# Fart                                    :   15   15   15   15   15   75
# Female_singing                          :   15   16   15   15   14   75
# Female_speech_and_woman_speaking        :   16   15   17   14   13   75
# Fill_(with_liquid)                      :   12   10    8   10   10   50
# Finger_snapping                         :   15   15   15   14   16   75
# Frying_(food)                           :   12   12   13   14   12   63
# Gasp                                    :   10   10    9    9   10   48
# Glockenspiel                            :   12   11   11   11   11   56
# Gong                                    :   15   15   15   15   15   75
# Gurgling                                :   16   13   15   15   16   75
# Harmonica                               :   15   16   16   14   14   75
# Hi-hat                                  :   15   14   15   16   15   75
# Hiss                                    :   15   15   15   15   15   75
# Keys_jangling                           :   15   15   15   15   15   75
# Knock                                   :   15   14   16   14   16   75
# Male_singing                            :   16   14   15   15   15   75
# Male_speech_and_man_speaking            :   15   14   15   16   15   75
# Marimba_and_xylophone                   :   15   16   14   15   15   75
# Mechanical_fan                          :   10   10   10   10    9   49
# Meow                                    :   15   16   16   15   13   75
# Microwave_oven                          :   14   15   15   15   16   75
# Motorcycle                              :   17   15   15   15   13   75
# Printer                                 :   15   15   15   15   15   75
# Purr                                    :   13   14   13   13   12   65
# Race_car_and_auto_racing                :    9   11   13   11   12   56
# Raindrop                                :   14   16   16   16   13   75
# Run                                     :   15   15   15   16   14   75
# Scissors                                :   15   15   15   15   15   75
# Screaming                               :   15   16   12   18   14   75
# Shatter                                 :   15   15   15   15   15   75
# Sigh                                    :   12   12   11   11   11   57
# Sink_(filling_or_washing)               :   14   16   15   13   17   75
# Skateboard                              :   15   15   15   15   15   75
# Slam                                    :   19   15   14   12   15   75
# Sneeze                                  :   13   13   12   13   12   63
# Squeak                                  :   17   15   15   14   14   75
# Stream                                  :   16   14   14   15   16   75
# Strum                                   :   14   15   15   15   16   75
# Tap                                     :   18   14   15   15   13   75
# Tick-tock                               :   15   15   14   14   14   72
# Toilet_flush                            :   16   15   15   16   13   75
# Traffic_noise_and_roadway_noise         :   16   16   15   14   14   75
# Trickle_and_dribble                     :   10   11   11   11   10   53
# Walk_and_footsteps                      :   14   15   16   17   13   75
# Water_tap_and_faucet                    :   15   15   15   15   15   75
# Waves_and_surf                          :   14   14   16   15   16   75
# Whispering                              :   14   16   15   16   14   75
# Writing                                 :   15   16   16   14   14   75
# Yell                                    :   16   14   15   15   15   75
# Zipper_(clothing)                       :   15   15   15   15   15   75
# total                                   : 1014 1005  993  979  979 4970

# %% [markdown]
# OK. Now we've got well-stratified folds.

# %%
# save
df_train3.to_csv("train_stratified.csv", index=None)

# %% [markdown]
# I'm not so familiar with the randomized algorithm.
# If you know a smarter way, please tell me.
