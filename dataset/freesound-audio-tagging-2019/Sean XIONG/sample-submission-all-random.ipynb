# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Output all random to see a baseline
data = pd.read_csv("../input/sample_submission.csv")
for i in range(len(data)):
    data.loc[i,1:] = np.random.uniform(0.0, 1.0)
data.to_csv("submission.csv", index=False)

# %%
data.head()
# Out:
#           fname        ...          Zipper_(clothing)
# 0  000ccb97.wav        ...                   0.136388
# 1  0012633b.wav        ...                   0.293454
# 2  001ed5f1.wav        ...                   0.941205
# 3  00294be0.wav        ...                   0.712853
# 4  003fde7a.wav        ...                   0.327887
#
# [5 rows x 81 columns]
