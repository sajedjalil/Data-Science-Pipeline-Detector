# %% [markdown]
# I just want to check if Public and Private test data have the same number or not.
# Of course, they have different number.

# %%
import numpy as np 
import pandas as pd
import os
import time

print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
print(os.listdir('../input'))

train_df = pd.read_csv('../input/aptos2019-blindness-detection/train.csv')
test_df = pd.read_csv('../input/aptos2019-blindness-detection/test.csv')
print(train_df.shape)
print(test_df.shape)

# %%
sub_df = pd.read_csv('../input/otheraptossubmission/submission.csv')

if test_df.shape[0] == sub_df.shape[0]:
    sub_df.to_csv('submission.csv',index=False)
else:
    exit(1)

# %% [markdown]
# I commit this kernel, and the submission.csv is created.
# After that I Commit to Competition to see the Public Score, I got the status 'Submission CSV NOT Found'.
# It means Public and Private test data have different number.

# %% [markdown]
# ![image.png](attachment:image.png)
