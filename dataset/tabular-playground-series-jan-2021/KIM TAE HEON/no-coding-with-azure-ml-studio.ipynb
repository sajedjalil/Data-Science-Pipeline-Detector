# %% [markdown]
# ## Use only the mouse :)

# %% [markdown]
# - I can't speak english well
# - so I used korean
# - Just look at the screen and follow it
# - thank you~

# %% [markdown]
# ### 1. Train(70%) & Val(30%) -> Evaluate

# %% [markdown]
# [![Video Label](http://img.youtube.com/vi/zk4mPW5Bwpo/0.jpg)](https://youtu.be/zk4mPW5Bwpo)

# %% [markdown]
# ### 2. kaggle submission

# %% [markdown]
# [![Video Label](http://img.youtube.com/vi/D9yh9PgmIGY/0.jpg)](https://youtu.be/D9yh9PgmIGY)

# %% [markdown]
# ### 3. z-score

# %% [markdown]
# [![Video Label](http://img.youtube.com/vi/vfXM0Og91zA/0.jpg)](https://youtu.be/vfXM0Og91zA)

# %% [markdown]
# thank you~ :)
