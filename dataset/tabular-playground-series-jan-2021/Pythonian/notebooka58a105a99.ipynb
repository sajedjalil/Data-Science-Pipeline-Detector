# %%
# !pip install deeptables

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt 

import tensorflow as tf
from deeptables.models.deeptable import DeepTable, ModelConfig
from deeptables.models.deepnets import (DeepFM,xDeepFM,DCN,PNN,WideDeep,AutoInt,AFM,FGCNN)
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

from tensorflow.compat.v1.metrics import root_mean_squared_error
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
def rmse(predictions, targets):
    """Competition metric: difference in prediction and target squared and then square rooted and averaged"""
    return np.sqrt(((predictions - targets) ** 2).mean())

train = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/train.csv')
test = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/test.csv')

print('train shape ', train.shape,'test shape ',test.shape)
print('train type ', type(train),'test type ',type(test))

# %%
target = train['target']
train = train[[col for col in train.columns.values if (col != 'target') & (col != 'id')]]
test = test[[col for col in train.columns.values if (col != 'target') & (col != 'id')]]
# train = train.values
# test = test.values

# %%
help(dt.fit_cross_validation)

# %%
# dt.fit_cross_validation(train,target)

# %%
dt.fit_cross_validation?

# %%
conf = ModelConfig(nets=DCN, metrics=['RootMeanSquaredError'],auto_discrete=False,apply_gbm_features=True)
dt = DeepTable(config=conf)
# with tf.device('./gpu'):
dt.fit_cross_validation(train, target, epochs=5,shuffle=True)

# %%
sub = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/sample_submission.csv')
sub['target'] = dt.predict(test)

# %%
plt.hist(sub['target'])

# %%
sub.to_csv('submission.csv',index=False)
