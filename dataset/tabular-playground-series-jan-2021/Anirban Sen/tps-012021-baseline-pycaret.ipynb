# %%
# !pip install pycaret

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df_train = pd.read_csv("/kaggle/input/tabular-playground-series-jan-2021/train.csv")
df_test = pd.read_csv("/kaggle/input/tabular-playground-series-jan-2021/test.csv")
sample_submission = pd.read_csv("/kaggle/input/tabular-playground-series-jan-2021/sample_submission.csv")

# %%
print(df_train.columns)
print(df_train.shape, df_test.shape)
df_train.head()

# %%
#import regression module 
from pycaret.regression import * 
#intialize the setup (in Notebook env)
exp_reg = setup(df_train, target = 'target', silent = True)

# %%
# # return best model based on RMSE
# best = compare_models(sort = 'RMSE', fold = 5) #default is 'R2'

# %%
cb_model = create_model('catboost', cross_validation = False)

# %%
df_test["target"] = cb_model.predict(df_test)
df_test[["id","target"]].to_csv("sample_submission.csv", index = False)
