# %% [markdown]
# # Hello Kagglers, Happy New Year!
# * In this notebook, we predict target by using [RandomForestRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html).
# * If you like, please feel free to upvote.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Import libraries and read csv files

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
train = pd.read_csv('../input/tabular-playground-series-jan-2021/train.csv')
test = pd.read_csv('../input/tabular-playground-series-jan-2021/test.csv')
sub = pd.read_csv('../input/tabular-playground-series-jan-2021/sample_submission.csv')

# %%
train.head()

# %%
print("The length is " + str(len(train)))

# %%
test.head()

# %%
print("The length is " + str(len(test)))

# %%
sub

# %% [markdown]
# # EDA (train.csv)

# %% [markdown]
# * There are 16 columns in train data.
# * We look at them closely by drawing histograms.

# %% [markdown]
# # cont1

# %%
fig = px.histogram(train, x="cont1")
fig.show()

# %% [markdown]
# # cont2

# %%
fig = px.histogram(train, x="cont2")
fig.show()

# %% [markdown]
# # cont3

# %%
fig = px.histogram(train, x="cont3")
fig.show()

# %% [markdown]
# # cont4

# %%
fig = px.histogram(train, x="cont4")
fig.show()

# %% [markdown]
# # cont5

# %%
fig = px.histogram(train, x="cont5")
fig.show()

# %% [markdown]
# # cont6

# %%
fig = px.histogram(train, x="cont6")
fig.show()

# %% [markdown]
# # cont7

# %%
fig = px.histogram(train, x="cont7")
fig.show()

# %% [markdown]
# # cont8

# %%
fig = px.histogram(train, x="cont8")
fig.show()

# %% [markdown]
# # cont9

# %%
fig = px.histogram(train, x="cont9")
fig.show()

# %% [markdown]
# # cont10

# %%
fig = px.histogram(train, x="cont10")
fig.show()

# %% [markdown]
# # cont11

# %%
fig = px.histogram(train, x="cont11")
fig.show()

# %% [markdown]
# # cont12

# %%
fig = px.histogram(train, x="cont12")
fig.show()

# %% [markdown]
# # cont13

# %%
fig = px.histogram(train, x="cont13")
fig.show()

# %% [markdown]
# # cont14

# %%
fig = px.histogram(train, x="cont14")
fig.show()

# %% [markdown]
# # target

# %%
fig = px.histogram(train, x="target")
fig.show()

# %% [markdown]
# # What we can learn from these graphs

# %% [markdown]
# * According to the above, we can learn that data is distributed differently by columns.

# %% [markdown]
# # Correlation between columns and Heatmap

# %% [markdown]
# * We can easily calculate correlation coefficient by using [corr()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html).

# %%
train_corr = train.corr()
train_corr

# %%
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(train_corr,annot=True,cmap='Blues')

# %% [markdown]
# # Modeling and Prediction

# %% [markdown]
# * We use a part of train data for saving time.

# %%
train = train.iloc[:100000,:]
y_train = train["target"]
X_train = train.drop(["target","id"],axis=1)
X_test = test.drop("id",axis = 1)

# %%
rf = RandomForestRegressor(random_state=2021)
rf.fit(X_train,y_train)

# %%
y_pred = rf.predict(X_test)

# %%
y_pred

# %% [markdown]
# # Submission

# %%
sub["target"] = y_pred

# %%
sub

# %%
sub.to_csv("submission.csv",index=False)
