# %%
# !ls -l ../input/*

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
dirname, filenames

# %%
from pathlib import Path
input_path = Path('/kaggle/input/tabular-playground-series-jan-2021/')
input_path

# %%
import pandas as pd
submission = pd.read_csv(input_path / 'sample_submission.csv', index_col='id')
display(submission.head())

# %%
submission.head()

# %%
submission.shape

# %%
submission.shape[0] / 1e5

# %%
input_path / 'sample_submission.csv'

# %%
pd.read_csv(input_path / 'sample_submission.csv')

# %%
test = pd.read_csv(input_path / 'test.csv', index_col='id')
display(test.head())

# %%
test.shape

# %%
test.shape[0] / 1e5

# %%
train = pd.read_csv(input_path / 'train.csv', index_col='id')
display(train.head())

# %%
train.shape

# %%
train.shape[0] / 1e5

# %%
type(test.index), type(train.index)

# %%
test.index

# %%
train.index

# %%
test.index.to_numpy(), train.index.to_numpy()

# %%
test_np = test.index.to_numpy()
train_np = train.index.to_numpy()

# %%
type(test_np), type(train_np)

# %%
import numpy as np
np2 = np.concatenate((test_np, train_np))
np2

# %%
uq = np.unique(np2)
uq

# %%
len(uq) / 1e5

# %%
train.head(0)

# %%
target = train.pop('target')
train.head(0)

# %%
type(target)

# %%
target.shape

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train, target, train_size=0.60)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
X_train

# %%
X_test

# %%
y_train

# %%
y_test

# %%
from sklearn.dummy import DummyRegressor
model_dummy = DummyRegressor(strategy='median')
model_dummy

# %%
model_dummy.fit(X_train, y_train)
y_dummy = model_dummy.predict(X_test)
y_dummy

# %%
np.median(y_train.to_numpy()), y_train.median()

# %%
from sklearn.metrics import mean_squared_error
score_dummy = mean_squared_error(y_test, y_dummy, squared=False)
print(f'{score_dummy:0.5f}') # 0.73599

# %%
from sklearn.linear_model import LinearRegression
model_simple_linear = LinearRegression(fit_intercept=False) # data is not centered, don't fit intercept
model_simple_linear

# %%
model_simple_linear.fit(X_train, y_train)
y_simple_linear = model_simple_linear.predict(X_test)
y_simple_linear

# %%
score_simple_linear = mean_squared_error(y_test, y_simple_linear, squared=False)
print(f'{score_simple_linear:0.5f}') # 1.33065

# %%
model_simple_linear = LinearRegression() # data is not centered, do fit intercept
model_simple_linear.fit(X_train, y_train)
y_simple_linear = model_simple_linear.predict(X_test)
score_simple_linear = mean_squared_error(y_test, y_simple_linear, squared=False)
print(f'{score_simple_linear:0.5f}') # 0.72821

# %%
model_simple_linear

# %%
name, model = "Dummy Median", DummyRegressor(strategy='median')
name, model

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred

# %%
figsize=(6,6)
figsize

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=figsize)

# %%
432 / 6

# %%
score = mean_squared_error(y_test, y_pred, squared=False)
score

# %%
num_to_plot=10000
num_to_plot

# %%
plt.scatter(y_test[:num_to_plot], y_pred[:num_to_plot])

# %%
lims=(0,12)
lims

# %%
plt.plot(lims, lims)

# %%
plt.ylim(lims)

# %%
plt.xlim(lims)

# %%
plt.title(f'{name}: {score:0.5f}', fontsize=18)

# %%
plt.show()

# %%
def plot_results(name, y, yhat, num_to_plot=10000, lims=(0,12), figsize=(6,6)):
    plt.figure(figsize=figsize)
    score = mean_squared_error(y, yhat, squared=False)
    plt.scatter(y[:num_to_plot], yhat[:num_to_plot])
    plt.plot(lims, lims)
    plt.ylim(lims)
    plt.xlim(lims)
    plt.title(f'{name}: {score:0.5f}', fontsize=18)
    plt.show()

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.linear_model import Ridge

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# %%time

model_names = ["Dummy Median", "Lasso", "Ridge", "Random Forest"]
# True    False
# 0.73599 
# 0.73527 2.38157
# 0.72821 1.33065 Linear = Ridge
# 0.71388 # slow

models = [
    DummyRegressor(strategy='median'),
    Lasso(),
    Ridge(),
    RandomForestRegressor(n_estimators=50, n_jobs=-1)]

for name, model in zip(model_names, models):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    plot_results(name, y_test, y_pred)

# %%
model = RandomForestRegressor(n_estimators=50, n_jobs=-1)
model

# %%
# %%time
model.fit(train, target)

# %%
submission

# %%
# %%time
submission['target'] = model.predict(test)
submission

# %%
# !ls -l

# %%
submission.to_csv('random_forest.csv')
# !ls -l

# %%
# !head random_forest.csv
