# %% [markdown]
#  **[Tabular Playground Series - Jan 2021](https://admin.kaggle.com/c/tabular-playground-series-jan-2021/overview)** competition.

# %%
import numpy as np
import pandas as pd
from pathlib import Path

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
        
input_path = Path('/kaggle/input/tabular-playground-series-jan-2021/')

# %% [markdown]
# # Read in the data files

# %%
train = pd.read_csv(input_path / 'train.csv', index_col='id')
display(train.head())

# %%
submission = pd.read_csv(input_path / 'sample_submission.csv', index_col='id')
display(submission.head())

# %%
from fastai.tabular.all import *
splits = RandomSplitter(valid_pct=0.2)(range_of(train))

# %%
to = TabularPandas(train, procs=[ FillMissing,Normalize],
                   cont_names = ['cont1',
                                 'cont2',
                                 'cont3',
                                 'cont4',
                                 'cont5',
                                 'cont6',
                                 'cont7',
                                 'cont8',
                                 'cont9',
                                 'cont10',
                                 'cont11',
                                 'cont12',
                                 'cont13',
                                 'cont14'],
                   y_names='target',
                   splits=splits)

# %%
to.xs.iloc[:2]

# %%
dls = to.dataloaders(bs=64)

# %%
learn = tabular_learner(dls, metrics=rmse)

# %%
learn.fit_one_cycle(4)

# %%
learn.show_results()

# %%
learn.lr_find()

# %%
lr = 1e-06
learn.fit_one_cycle(3, lr , wd = 0.3)

# %%
row, clas, probs = learn.predict(train.iloc[0])

# %%
print('i am done training')

# %%
test = pd.read_csv(input_path / 'test.csv', index_col='id')
display(test.head())

# %%
test_df = test.copy()
dl = learn.dls.test_dl(test_df)

# %%
preds = learn.get_preds(dl=dl)[0].numpy()

# %%
submission['target'] = preds
submission.to_csv('random_forest.csv')

# %%
submission['target'].describe()
