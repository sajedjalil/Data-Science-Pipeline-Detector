# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/train.csv')

# %%
train = train.set_index('id')

# %%
train.head()

# %%
import matplotlib.pyplot as plt

# %%
import math

# %%
new_train = pd.DataFrame(train.iloc[:,:-1]).apply(lambda x: 10**x)

# %%
plt.scatter(new_train.iloc[:, 5], new_train.iloc[:, 12])

# %%
plt.matshow(new_train.corr())
plt.colorbar()
plt.show();

# %%
new_train['target'] = train['target']

# %%
train = new_train

# %%
x = train.iloc[:,:-1]
y = train.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.1,random_state=42)

# %%
import statsmodels.regression.linear_model as smf

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
temp = x.copy()
temp_x = temp.values
selector = temp_x.copy()
regressor_ols = smf.OLS(endog = y, exog = temp_x).fit()

# %%
xp = [x for x in range(x_train.shape[1])]

# %%
xp

# %%
for i in range(len(x)-1):
    if float(regressor_ols.pvalues.max()) > 0.05:
        del xp[np.argmax(regressor_ols.pvalues)]
        temp_x = selector[:, xp]
        regressor_ols = smf.OLS(endog= y, exog=temp_x).fit()
    else:
        break

# %%
xp

# %%
regressor_ols.summary()

# %%
samples = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/sample_submission.csv')

# %%
samples

# %%
test = pd.read_csv('/kaggle/input/tabular-playground-series-jan-2021/test.csv')

# %%
test = test.set_index('id')

# %%
test = test.apply(lambda x: 10**x)

# %%
test

# %%
output = regressor_ols.predict(test.iloc[:, xp])

# %%
output = output.reset_index()

# %%
output

# %%
output.columns = ['id','target']

# %%
output.to_csv('submission.csv',index=False)

# %%
output
