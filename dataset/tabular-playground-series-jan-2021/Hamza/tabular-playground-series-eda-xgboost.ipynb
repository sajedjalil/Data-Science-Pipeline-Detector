# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import random
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('../input/tabular-playground-series-jan-2021/train.csv')
test  = pd.read_csv('../input/tabular-playground-series-jan-2021/test.csv')
sub = pd.read_csv('../input/tabular-playground-series-jan-2021/sample_submission.csv')

# %% [markdown]
# # EDA

# %%
print(train.shape,test.shape)

# %%
train.head(3)

# %%
#Check if there'is null values
train.isnull().sum()

# %%
#Remove redundant samples if exist
train=train.drop_duplicates(keep='first')
train.shape

# %% [markdown]
# * There's not duplicates in our data

# %%
train.describe()

# %%
columns = [col for col in train.columns.to_list() if col not in ['id','target']]

# %%
def plot_features(i):
    plt.subplot(1, 2, 1,title="test")
    sns.kdeplot(test[columns[i-1]],shade=True)

    plt.subplot(1, 2, 2,title="train")
    sns.kdeplot(train[columns[i-1]],shade=True)

    plt.subplots_adjust(right=3.0)
    plt.show()

# %%
plot_features(5)

# %%
plot_features(10)

# %%
#train vs test for cont2
ax = sns.kdeplot(test[columns[1]])
sns.kdeplot(train[columns[1]],ax=ax,legend=False)

# %%
train.target.describe()

# %%
import seaborn as sns
plt.figure(figsize=(10,4))
plt.xlim(train['target'].min(),train['target'].max())
sns.kdeplot(train['target'],shade=True)
plt.show()

# %% [markdown]
# **Let's plot the correlaton matrix**

# %%
corr = train[columns+['target']].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)

# %% [markdown]
# # Let's create an XGB model

# %%
X_train, X_test, y_train, y_test = train_test_split(train[columns],train['target'] , test_size=0.2, random_state=42)

# %%
import xgboost as xgb
model=xgb.XGBRegressor(n_estimators  = 400,max_depth=3)
model.fit(X_train, y_train)

# %%
y_predicted=model.predict(X_test)

# %%
mean_squared_error(y_test, y_predicted, squared=False)#0.7015802873306943

# %%
mean_squared_error(y_test, y_predicted, squared=False)

# %% [markdown]
# # Submission

# %%
sub['target']=model.predict(test[columns])

# %%
sub.to_csv('submission.csv', index=False)

# %%
sub

# %% [markdown]
# # Please If you find this kernel helpful, upvote it to help others see it 😊
