# %% [markdown]
# # Intro
# Welcome to the [Tabular Playground Series - Feb 2022](https://www.kaggle.com/c/tabular-playground-series-feb-2022) competition.
# ​
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/33102/logos/header.png)
#
# <font size="4"><span style="color: royalblue;">Please vote the notebook up if it helps you. Feel free to leave a comment above the notebook. Thank you. </span></font>

# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_error, make_scorer

# %% [markdown]
# # Path

# %%
path = '/kaggle/input/tabular-playground-series-feb-2022/'
os.listdir(path)

# %% [markdown]
# # Load Data

# %%
train_data = pd.read_csv(path+'train.csv')
test_data = pd.read_csv(path+'test.csv')
samp_subm = pd.read_csv(path+'sample_submission.csv')

# %% [markdown]
# # Overview

# %%
print('Number train samples:', len(train_data.index))
print('Number train features:', len(train_data.columns))
print('Number test samples:', len(test_data.index))

# %% [markdown]
# # EDA

# %%
train_data['target'].value_counts()

# %% [markdown]
# # Model

# %% [markdown]
# Define train, validation and test data:

# %%
X = train_data[train_data.columns[1:-1]]
y = train_data['target']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state=2022)

X_test = test_data[test_data.columns[1:]]

# %% [markdown]
# Define and train the model:

# %%
model = XGBClassifier()
model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True)

# %% [markdown]
# Predict test data:

# %%
y_test = model.predict(X_test)

# %% [markdown]
# # Export

# %%
samp_subm['target']=y_test

# %%
samp_subm['target'].value_counts()

# %%
samp_subm.to_csv('submission.csv', index=False)
