# %% [markdown]
# <center><img src="https://storage.googleapis.com/kaggle-competitions/kaggle/28012/logos/header.png?t=2021-06-30-01-16-12" width="1900" height="600"></center>
#
# <h1 style="color:rgb(0, 35, 156);"><center><font size="+4">Frequently Used Classification "वर्गीकरण" Models</font></center></h1>
#
# <h1 style="color:rgb(0, 103, 71);"><center><font size="+3">Fine-tune the Hyperparameters of your Choice to achieve High Classifiation Accuracy.</font></center></h1>
# <h3 style="text-align: right;"><i>By: Kush Trivedi</i></h3>
# <h1 style="color:rgb(233, 92, 32);"><center>Tabular Play Ground - Feb 2022</center></h1>
#
# <center><img src="https://cdn.pixabay.com/photo/2020/09/05/01/57/bacterias-5545353_960_720.png" width="800" height="200"></center>
#
# <h3 style="color:rgb(233, 92, 32);">Given Task</h3>
#
# <p>You must categorize <b>10 different bacteria species</b> using data from a genomic analysis technique that involves some data compression and data loss for the Tabular Playground Series competition in February 2022. In this method, 10-mer snippets of DNA are sampled and processed to <b>provide a base count histogram</b>. To put it another way, the <b>ATATGGCCTT DNA fragment becomes A2T4G2C2</b>.</p>
# <p><b>Is it possible to use this skewed data to reliably determine bacterium species?</b></p>
#
# <h3 style="color:rgb(233, 92, 32);">Score Evaluation</h3>
# <p><b>Classiffication Accuracy: </b> The accuracy of a classifier is given as the percentage of <b>total correct predictions divided by the total number of instances</b>.</p>
#
# <h3 style="color:rgb(233, 92, 32);">Aim</h3>
# <p><b>Classify the Bacteria Accurately</b></p>
#
# <h3 style="color:rgb(233, 92, 32);">Solution</h3>
# <p>As it says, it's a category data, therefore we will check out several <b>Classification models.</b></p>
# <li><b>Caution ⚠️ : DATA HAS HIGH CHANCE OF OVERFITTING</b></li>
# <li>One Solution I think will wrok for this Data is try training for <b>fewer epochs</b>, or using <b>regularisation</b> or <b>dropouts</b> to <b>mitigate over-fitting</b>, potentially sacrificing training loss and improving your test loss using DNN.</li>
# <li><b>P.S Note</b> Any Suggestion feel free to comment</li>
#
# <h3 style="color:rgb(233, 92, 32);">Conclusion</h3>
#
# [Click Here!](#38)
#
# <br></br>
#
# <center><h1 style="color:rgb(233, 92, 32);">Table of Contents</h1></center>
#
# <h2 style="color:rgb(233, 92, 32);">★ Does Data Spectated Bacterium Species Accurately?</h2>
#
# * [Import Libraries](#1)
# * [Helper Functions](#2)
#     * [Universal Summary Function for Data Frames](#2)
#     * [Universal Downcasting Memory Usage for Data Frames](#2)
#     * [Applying Feature Engineering on Data Frame](#2)
# * [Data Loading with Feature Engineering](#3)
# * [Downcasting](#4)
# * [Basic Summary of Train and Test Data](#5)
#
# <h2 style="color:rgb(233, 92, 32);">★ Data Wrangling </h2>
#
# * [Setting Global varaiable and Transforming  " Target " varaiable with data features](#6)
#
# <h2 style="color:rgb(233, 92, 32);">★ Classification Models (Base Models)</h2>
#
# 1. [K-Neighbor Classifiaction](#7)
#     * [K-Neighbor Classifiaction Report](#8)
#     * [K-Neighbor Confusion Matrix](#9)
#     * [K-Neighbor ROC Curve](#10)
# 2. [Decision Tree Classification](#11)
#     * [Decision Tree Classification Report](#12)
#     * [Decision Tree Confusion Matrix](#13)
#     * [Decision Tree ROC Curve](#14)
# 3. [Random Forest Classification](#15)
#     * [Random Forest Classification Report](#16)
#     * [Random Forest Confusion Matrix](#17)
#     * [Random Forest ROC Curve](#18)
# 4. [Extra Tree Classification](#19)
#     * [Extra Tree Classification Report](#20)
#     * [Extra Tree Confusion Matrix](#21)
#     * [Extra Tree ROC Curve](#22)
# 5. [Light GBM Classification](#23)
#     * [Light GBM Classification Report](#24)
#     * [Light GBM Confusion Matrix](#25)
#     * [Light GBM ROC Curve](#26)
# 6. [CatBoost Classification](#27)
#     * [CatBoost Classification Report](#28)
#     * [CatBoost Confusion Matrix](#29)
#     * [CatBoost ROC Curve](#30)
# 7. [XGBoost Classification](#31)
#     * [XGBoost Classification Report](#32)
#     * [XGBoost Confusion Matrix](#33)
#     * [XGBoost ROC Curve](#34)
#
# <h2 style="color:rgb(233, 92, 32);">★ Accuracy Score</h2>
#
# * [Mean Score Acurracy of all Models](#35)
# * [Mean Score Acurracy of all Models](#36)
#
# <h2 style="color:rgb(233, 92, 32);">★ Submission</h2>
#
# * [Inverse Transform and Submit to CSV](#37)
#
# <h2 style="color:rgb(233, 92, 32);">★ Conclusion</h2>
#
# * [Models Summary and Conclusion](#38)
#
# <h2 style="color:rgb(233, 92, 32);">★ Previous Version</h2>
#
# * [An Antibiotic for Bacteria](https://www.kaggle.com/kushtrivedi14728/an-antibiotic-of-extratree-part-1)

# %% [markdown]
# <h3><b id='1'><span style='color:rgb(233, 92, 32);'>Importing Library</span> </b></h3>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import scikitplot as skplt
import matplotlib.pyplot as plt
import plotly.graph_objects as go

from scipy.stats import mode
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from plotly.subplots import make_subplots
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score,confusion_matrix

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import time
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.dpi'] = 150
plt.rcParams["figure.figsize"] = (8,4)
sns.set(rc={'axes.facecolor':'#FFFFFF', 'figure.facecolor':'#FFFFFF'})
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <h3><b id='2'><span style='color:rgb(233, 92, 32);'>Helper Functions</span> </b></h3>
#
# 1. **Basic Summary Function**
# 2. **Downcast Memory Usage Function**
# 3. **Feature Engineering**

# %%
def basicSummary(dataFrameForSummary):
    print('\n\033[1;30;34mThis Datset consists of \033[0;0m\033[1m {}\033[0m \033[1;31;31mFeatures\033[0;0m & \033[1m{}\033[0m \033[1;31;32mSamples.\033[0;0m\n'.format(dataFrameForSummary.shape[1], dataFrameForSummary.shape[0]))
    summary = pd.DataFrame(dataFrameForSummary.dtypes, columns=['Data Type'])
    summary = summary.reset_index()
    summary = summary.rename(columns={'index': 'Feature'})
    summary['Num of Nulls'] = dataFrameForSummary.isnull().sum().values
    summary['Num of Unique'] = dataFrameForSummary.nunique().values
    summary['First Value'] = dataFrameForSummary.loc[0].values
    summary['Second Value'] = dataFrameForSummary.loc[1].values
    summary['Third Value'] = dataFrameForSummary.loc[2].values
    summary['Fourth Value'] = dataFrameForSummary.loc[3].values
    return summary


def downcastMemoryUsage(dataFrame):
    startMemoryOptimization = dataFrame.memory_usage().sum() / 1024 ** 2
    print('Memory usage of dataframe is: \033[1m{:.2f} MB\033[0m'.format(startMemoryOptimization))
    subTypeInt = ['uint8','uint16','uint32','uint64','int8','int16','int32','int64']
    subTypeFloat = ['float16','float32','float64']
    for column in dataFrame.columns:
        columnType = str(dataFrame[column].dtypes)
        maximumColumn = dataFrame[column].max()
        minimumColumn = dataFrame[column].min()
        if 'int' in columnType:
            for element in subTypeInt:
                if minimumColumn > np.iinfo(element).min and maximumColumn < np.iinfo(element).max:
                    dataFrame[column] = dataFrame[column].astype(element)
                    break
        elif 'float' in columnType:
            for element in subTypeFloat:
                if minimumColumn > np.finfo(element).min and maximumColumn < np.finfo(element).max:
                    dataFrame[column] = dataFrame[column].astype(element)
                    break
        elif 'object' in columnType:
            numberOfUnique = len(dataFrame[column].unique())
            numberOfTotal = len(dataFrame[column])
            if numberOfUnique / numberOfTotal < 0.5:
                dataFrame[column] = dataFrame[column].astype('category')
    endMemoryOptimization = dataFrame.memory_usage().sum() / 1024 ** 2
    print('Memory usage after optimization is: \033[1m{:.2f} MB\033[0m'.format(endMemoryOptimization))
    print('Compressed by: \033[1m{:.2f} %\033[0m'.format(100*(startMemoryOptimization - endMemoryOptimization) / startMemoryOptimization))
    return dataFrame


def feature_engineering(dataFrame):
    dataFrame['mean'] = dataFrame[FEATURES].mean(axis=1)
    dataFrame['median'] = dataFrame[FEATURES].median(axis=1)
    dataFrame["std"] = dataFrame[FEATURES].std(axis=1)
    dataFrame["min"] = dataFrame[FEATURES].min(axis=1)
    dataFrame["max"] = dataFrame[FEATURES].max(axis=1)
    dataFrame['q25'] = dataFrame[FEATURES].quantile(q=0.25, axis=1)
    dataFrame['q50'] = dataFrame[FEATURES].quantile(q=0.50, axis=1)
    dataFrame['q75'] = dataFrame[FEATURES].quantile(q=0.75, axis=1)
    dataFrame['q75-q25'] = dataFrame['q75'] - dataFrame['q25']
    dataFrame['skew'] = dataFrame[FEATURES].skew(axis=1)
    return dataFrame

# %% [markdown]
# <h3><b id='3'><span style='color:rgb(233, 92, 32);'>Data Loading with Feature Engineering</span> </b></h3>

# %%
train = pd.read_csv("../input/tabular-playground-series-feb-2022/train.csv")
test = pd.read_csv("../input/tabular-playground-series-feb-2022/test.csv")
submission = pd.read_csv("../input/tabular-playground-series-feb-2022/sample_submission.csv")

TARGET = 'target'
FEATURES = [col for col in train.columns if col not in ['row_id', TARGET]]

train = feature_engineering(train)
test = feature_engineering(test)

train.set_index('row_id', inplace=True)
train.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# <h3><b id='4'><span style='color:rgb(233, 92, 32);'>Downcasting Data Frames</span> </b></h3>

# %%
print("\033[1;30;34mTrain Dataset Downcasting \033[0;0m")
train = downcastMemoryUsage(train)
print("\n\033[1;30;34mTest Dataset Downcasting \033[0;0m")
test = downcastMemoryUsage(test)

# %% [markdown]
# <h3><b id='5'><span style='color:rgb(233, 92, 32);'>Summary of Train and Test Data</span> </b></h3>

# %%
fig = make_subplots(rows=1, cols=2)
fig.update_layout(
    title_text="<b>Train Dataset Summary</b>",
    title_x=0.5
)
fig['layout']['title']['font'] = dict(size=35, color='rgb(233, 92, 32)')
fig.add_trace(go.Indicator(mode = "number", value = train.shape[0], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Rows (Samples)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0, 0.5], 'y': [0.1, 1]}))
fig.add_trace(go.Indicator(mode = "number", value = train.shape[1], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Columns (Features)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0.5, 1], 'y': [0, 0.4]}))
fig.show()
display(basicSummary(train))

fig = make_subplots(rows=1, cols=2)
fig.update_layout(
    title_text="<b>Test Dataset Summary</b>",
    title_x=0.5
)
fig['layout']['title']['font'] = dict(size=35, color='rgb(233, 92, 32)')
fig.add_trace(go.Indicator(mode = "number", value = test.shape[0], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Rows (Samples)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0, 0.5], 'y': [0.1, 1]}))
fig.add_trace(go.Indicator(mode = "number", value = test.shape[1], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Columns (Features)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0.5, 1], 'y': [0, 0.4]}))
fig.show()
display(basicSummary(test))

# %% [markdown]
# <a id="6"></a> <br>
# # <div style="color:white;display:fill;border-radius:5px;background-color:white;letter-spacing:0.1px;overflow:hidden"><p style="padding:20px;color:rgb(233, 92, 32);overflow:hidden;margin:0;font-size:100%;text-align:center">Data Wrangling</p></div>
#
# <h3><b id='6'><span style='color:rgb(0, 103, 71);'>Setting Global varaiable and Transforming " Target " varaiable with data features</span> </b></h3>

# %%
RANDOM_STATE = 22
FOLDS = 5
REPEATS = 2
ESTIMATORS = 500

encoder = LabelEncoder()
train[TARGET] = encoder.fit_transform(train[TARGET])

# %% [markdown]
# <a id="7"></a> <br>
# # <div style="color:white;display:fill;border-radius:5px;background-color:white;letter-spacing:0.1px;overflow:hidden"><p style="padding:20px;color:rgb(233, 92, 32);overflow:hidden;margin:0;font-size:100%;text-align:center">Classification Models Training</p></div>
#
# <center><img src="https://www.jewishveg.org/pandemic/wp-content/uploads/2020/07/antibiotic_PNG.png" width="800" height="100"></center>
#
# 1. [K-Neighbor Classifiaction](#7)
#     * [K-Neighbor Classifiaction Report](#8)
#     * [K-Neighbor Confusion Matrix](#9)
#     * [K-Neighbor ROC Curve](#10)
# 2. [Decision Tree Classification](#11)
#     * [Decision Tree Classification Report](#12)
#     * [Decision Tree Confusion Matrix](#13)
#     * [Decision Tree ROC Curve](#14)
# 3. [Random Forest Classification](#15)
#     * [Random Forest Classification Report](#16)
#     * [Random Forest Confusion Matrix](#17)
#     * [Random Forest ROC Curve](#18)
# 4. [Extra Tree Classification](#19)
#     * [Extra Tree Classification Report](#20)
#     * [Extra Tree Confusion Matrix](#21)
#     * [Extra Tree ROC Curve](#22)
# 5. [Light GBM Classification](#23)
#     * [Light GBM Classification Report](#24)
#     * [Light GBM Confusion Matrix](#25)
#     * [Light GBM ROC Curve](#26)
# 6. [CatBoost Classification](#27)
#     * [CatBoost Classification Report](#28)
#     * [CatBoost Confusion Matrix](#29)
#     * [CatBoost ROC Curve](#30)
# 7. [XGBoost Classification](#31)
#     * [XGBoost Classification Report](#32)
#     * [XGBoost Confusion Matrix](#33)
#     * [XGBoost ROC Curve](#35)

# %% [markdown]
# <h3><center><b id='7'><span style='color:rgb(0, 103, 71);'><font size="+3">K- Neighbors Classification Model</font></span> </b></center></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>98.4 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.01 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.08 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>93-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>94-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>98.69 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.97452</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but <b>check recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other models</b> to get optimum solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Good</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>OK Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>

# %%
# print(56*'#')
# print(15*' ', "\033[1;30;34m  K-Nearest  Neighbors  \033[0;0m", 15*" ") 
# print(56*'#')
# print('')

# # KNeighbors_params = {
# #    Tune hyperparameters here, also you can use GridSearch Cross Validation 
# # }

# KNeighbors_predictions = []
# KNeighbors_scores = []
# KNeighbors_fimp = []
# KNeighbors_probability = []

# #Training the model
# rskf = RepeatedStratifiedKFold(n_splits=FOLDS, random_state=RANDOM_STATE, n_repeats=REPEATS)
# for fold, (train_idx, valid_idx) in enumerate(rskf.split(train[FEATURES], train[TARGET])):
    
#     print(11*"*=", f"\033[1;31;31m Fold = {fold+1} \033[0;0m", 11*"*=")
#     start_time = time.time()
    
#     X_train, X_valid = train.iloc[train_idx][FEATURES], train.iloc[valid_idx][FEATURES]
#     y_train , y_valid = train[TARGET].iloc[train_idx] , train[TARGET].iloc[valid_idx]
    
#     model = KNeighborsClassifier(n_neighbors=2,n_jobs=-1,p=1)
#     model.fit(X_train, y_train)
    
#     preds_valid = model.predict(X_valid)
#     proba_valid = model.predict_proba(X_valid)
#     acc = accuracy_score(y_valid,  preds_valid)
#     KNeighbors_scores.append(acc)
#     run_time = time.time() - start_time
    
#     print(f"\033[1;31;32mFold: \033[0;0m{fold+1}, \033[1;31;32m Accuracy: \033[0;0m\033[1m{acc:.5f}\033[0m, \033[1;31;33m Run Time: \033[0;0m{run_time:.2f}s")
#     print(28*'*=')
#     print("\n")
    
#     #Predict testing set
#     test_preds = model.predict(test[FEATURES])
#     test_proba = model.predict_proba(test[FEATURES])
#     KNeighbors_predictions.append(test_preds)
#     KNeighbors_probability.append(test_proba)
    
# #Check performance using accuracy
# print(f'\n\033[1;30;34m Training Accuracy   : \033[0;0m {(model.score(X_train, y_train)*100).round(2)}%')
# print(f'\033[1;30;34m Validation Accuracy : \033[0;0m {(model.score(X_valid, y_valid)*100).round(2)}%')
# print("\n\033[1;30;34m Mean Accuracy    : \033[0;0m", (np.mean(KNeighbors_scores)*100).round(2),"%")

# %% [markdown]
# <h3><b id='8'><span style='color:rgb(0, 35, 156);'>K- Neighbour Classification Report</span> </b></h3>

# %%
# classificationReportKNeighbors = classification_report(y_valid,  preds_valid)
# print(classificationReportKNeighbors)

# %% [markdown]
# <h3><b id='9'><span style='color:rgb(0, 35, 156);'>K- Neighbour Confusion Matrix</span> </b></h3>

# %%
# cf_matrix_KNN = confusion_matrix(y_valid, preds_valid)
# ax = sns.heatmap(cf_matrix_KNN, annot=True, fmt=".0f", cmap='Greens')
# ax.set_title('Confusion Matrix\n')
# ax.set_xlabel('\nPredicted Bacteria Category')
# ax.set_ylabel('Actual Bacteria Category\n')
# plt.show()

# %% [markdown]
#  <h3><b id='10'><span style='color:rgb(0, 35, 156);'>K- Neighbour ROC Curve</span> </b></h3>

# %%
# knn_roc_score = roc_auc_score(y_valid, proba_valid,multi_class='ovr').astype(float)
# skplt.metrics.plot_roc_curve(y_valid, proba_valid)
# plt.legend(loc=(1.04,0))
# plt.show()

# %% [markdown]
# <h3><center><b id='11'><span style='color:rgb(0, 103, 71);'><font size="+3">Decision Tree Classification Model</font></span> </b></center></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>100 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center>89.24 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>89.49 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>87-94 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>87-94 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>89 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>94.02 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.81537</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center><b>Not Good Data</b> Over-fits Clearly</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK but needs <b>improvement</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center>Good,but it'll <b>overfit</b> because validation accuracy differs significantly from training accuracy</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center><b>As Expected it won't Result Good Score</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>

# %%
print(56*'#')
print(15*' ', "\033[1;30;34m Decision Tree Classifier \033[0;0m", 15*" ")
print(56*'#')
print('')

# decisonTree_params = {
#    Tune hyperparameters here, also you can use GridSearch Cross Validation     
# }

decisionTree_predictions = []
decisionTree_scores = []
decisionTree_fimp = []
decisionTree_probability = []

rskf = RepeatedStratifiedKFold(n_splits=FOLDS, random_state=RANDOM_STATE, n_repeats=REPEATS)
for fold, (train_idx, valid_idx) in enumerate(rskf.split(train[FEATURES], train[TARGET])):
    
    print(11*"*=", f"\033[1;31;31m Fold = {fold+1} \033[0;0m", 11*"*=")
    start_time = time.time()
    
    X_train, X_valid = train.iloc[train_idx][FEATURES], train.iloc[valid_idx][FEATURES]
    y_train , y_valid = train[TARGET].iloc[train_idx] , train[TARGET].iloc[valid_idx]
    
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    
    preds_valid = model.predict(X_valid)
    proba_valid = model.predict_proba(X_valid)
    acc = accuracy_score(y_valid,  preds_valid)
    decisionTree_scores.append(acc)
    run_time = time.time() - start_time
    
    print(f"\033[1;31;32mFold: \033[0;0m{fold+1}, \033[1;31;32m Accuracy: \033[0;0m\033[1m{acc:.5f}\033[0m, \033[1;31;33m Run Time: \033[0;0m{run_time:.2f}s")
    print(28*'*=')
    print("\n")
    fim_decision_tree = pd.DataFrame(index=FEATURES,
                 data=model.feature_importances_,
                 columns=[f'{fold}_importance'])
    decisionTree_fimp.append(fim_decision_tree)
    test_preds = model.predict(test[FEATURES])
    decisionTree_predictions.append(test_preds)
    test_proba = model.predict_proba(test[FEATURES])
    decisionTree_probability.append(test_proba)
    
print(f'\n\033[1;30;34m Training Accuracy   : \033[0;0m {(model.score(X_train, y_train)*100).round(2)}%')
print(f'\033[1;30;34m Validation Accuracy : \033[0;0m {(model.score(X_valid, y_valid)*100).round(2)}%')
print("\n\033[1;30;34m Mean Accuracy    : \033[0;0m",(np.mean(decisionTree_scores)*100).round(2),"%")

# %% [markdown]
# <h3><b id='12'><span style='color:rgb(0, 35, 156);'>Decision Tree Classification Report</span> </b></h3>

# %%
classificationReportDecisionTree = classification_report(y_valid,  preds_valid)
print(classificationReportDecisionTree)

# %% [markdown]
# <h3><b id='13'><span style='color:rgb(0, 35, 156);'>Decision Tree Confusion Matrix</span> </b></h3>

# %%
cf_matrix_DecisionTree = confusion_matrix(y_valid, preds_valid)
ax = sns.heatmap(cf_matrix_DecisionTree, annot=True, fmt=".0f", cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Bacteria Category')
ax.set_ylabel('Actual Bacteria Category\n')
plt.show()

# %% [markdown]
# <h3><b id='14'><span style='color:rgb(0, 35, 156);'>Decision Tree ROC Curve</span> </b></h3>

# %%
decisionTree_roc_score = roc_auc_score(y_valid, proba_valid,multi_class='ovr').astype(float)
skplt.metrics.plot_roc_curve(y_valid, proba_valid)
plt.legend(loc=(1.04,0))
plt.show()

# %% [markdown]
# <h3><center><b id='15'><span style='color:rgb(0, 103, 71);'><font size="+3">Random Forest Classification Model</font></span> </b></center></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>100 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.48 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.42 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.92 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.97600</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but <b>check recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other models</b> to get optimum solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Very good</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Good Score to submit and it's approximately same as Validation Score</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>

# %%
print(56*'#')
print(15*' ', "\033[1;30;34m Random Forest Classifier \033[0;0m", 15*" ")
print(56*'#')
print('')

# randomForest_params = {
#    Tune hyperparameters here, also you can use GridSearch Cross Validation     
# }

randomForestClassifier_predictions = []
randomForestClassifier_scores = []
randomForestClassifier_fimp = []
randomForestClassifier_probability = []

rskf = RepeatedStratifiedKFold(n_splits=FOLDS, random_state=RANDOM_STATE, n_repeats=REPEATS)
for fold, (train_idx, valid_idx) in enumerate(rskf.split(train[FEATURES], train[TARGET])):
    
    print(11*"*=", f"\033[1;31;31m Fold = {fold+1} \033[0;0m", 11*"*=")
    start_time = time.time()
    
    X_train, X_valid = train.iloc[train_idx][FEATURES], train.iloc[valid_idx][FEATURES]
    y_train , y_valid = train[TARGET].iloc[train_idx] , train[TARGET].iloc[valid_idx]
    
    model = RandomForestClassifier(n_estimators=ESTIMATORS,n_jobs=-1, verbose=1)
    model.fit(X_train, y_train)
    
    preds_valid = model.predict(X_valid)
    proba_valid = model.predict_proba(X_valid)
    acc = accuracy_score(y_valid,  preds_valid)
    randomForestClassifier_scores.append(acc)
    run_time = time.time() - start_time
    
    print(f"\033[1;31;32mFold: \033[0;0m{fold+1}, \033[1;31;32m Accuracy: \033[0;0m\033[1m{acc:.5f}\033[0m, \033[1;31;33m Run Time: \033[0;0m{run_time:.2f}s")
    print(28*'*=')
    print("\n")
    fim_randomforest = pd.DataFrame(index=FEATURES,
                 data=model.feature_importances_,
                 columns=[f'{fold}_importance'])
    randomForestClassifier_fimp.append(fim_randomforest)
    test_preds = model.predict(test[FEATURES])
    test_proba = model.predict_proba(test[FEATURES])
    randomForestClassifier_predictions.append(test_preds)
    randomForestClassifier_probability.append(test_proba)
    
print(f'\n\033[1;30;34m Training Accuracy   : \033[0;0m {(model.score(X_train, y_train)*100).round(2)}%')
print(f'\033[1;30;34m Validation Accuracy : \033[0;0m {(model.score(X_valid, y_valid)*100).round(2)}%')
print("\n\033[1;30;34m Mean Accuracy    : \033[0;0m",(np.mean(randomForestClassifier_scores)*100).round(2),"%")

# %% [markdown]
# <h3><b id='16'><span style='color:rgb(0, 35, 156);'>Random Forest Classification Report</span> </b></h3>

# %%
classificationReportRandomForestClassifier = classification_report(y_valid,  preds_valid)
print(classificationReportRandomForestClassifier)

# %% [markdown]
# <h3><b id='17'><span style='color:rgb(0, 35, 156);'>Random Forest Confusion Matrix</span> </b></h3>

# %%
cf_matrix_RandomForest = confusion_matrix(y_valid, preds_valid)
ax = sns.heatmap(cf_matrix_RandomForest, annot=True, fmt=".0f", cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Bacteria Category')
ax.set_ylabel('Actual Bacteria Category\n')
plt.show()

# %% [markdown]
# <h3><b id='18'><span style='color:rgb(0, 35, 156);'>Random Forest ROC Curve</span> </b></h3>

# %%
randomForest_roc_score = roc_auc_score(y_valid, proba_valid,multi_class='ovr').astype(float)
skplt.metrics.plot_roc_curve(y_valid, proba_valid)
plt.legend(loc=(1.04,0))
plt.show()

# %% [markdown]
# <h3><center><b id='19'><span style='color:rgb(0, 103, 71);'><font size="+3">Extra Tree Classification Model</font></span> </b></center></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>100 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.58 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.59 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.93 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.97762</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but <b>check recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other models</b> to get optimum solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Very good</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Good Score to submit and it's approximately same as Validation Score and <b style='color: #00B1D2FF'>Better then Random Forest</b></b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>

# %%
print(56*'#')
print(15*' ', "\033[1;30;34m Extra  Tree Calssifier \033[0;0m", 15*" ")
print(56*'#')
print('')

# extraTree_params = {
#    Tune hyperparameters here, also you can use GridSearch Cross Validation     
# }


extraTree_predictions = []
extraTree_scores = []
extraTree_fimp = []
extraTree_probability = []

rskf = RepeatedStratifiedKFold(n_splits=FOLDS, random_state=RANDOM_STATE, n_repeats=REPEATS)
for fold, (train_idx, valid_idx) in enumerate(rskf.split(train[FEATURES], train[TARGET])):
    
    print(11*"*=", f"\033[1;31;31m Fold = {fold+1} \033[0;0m", 11*"*=")
    start_time = time.time()
    
    X_train, X_valid = train.iloc[train_idx][FEATURES], train.iloc[valid_idx][FEATURES]
    y_train , y_valid = train[TARGET].iloc[train_idx] , train[TARGET].iloc[valid_idx]
    
    model = ExtraTreesClassifier(n_estimators=ESTIMATORS,random_state=RANDOM_STATE,n_jobs=-1, verbose=1)
    model.fit(X_train, y_train)
    
    preds_valid = model.predict(X_valid)
    proba_valid = model.predict_proba(X_valid)
    acc = accuracy_score(y_valid,  preds_valid)
    extraTree_scores.append(acc)
    run_time = time.time() - start_time
    
    print(f"\033[1;31;32mFold: \033[0;0m{fold+1}, \033[1;31;32m Accuracy: \033[0;0m\033[1m{acc:.5f}\033[0m, \033[1;31;33m Run Time: \033[0;0m{run_time:.2f}s")
    print(28*'*=')
    print("\n")
    fim_extraTree = pd.DataFrame(index=FEATURES,
                 data=model.feature_importances_,
                 columns=[f'{fold}_importance'])
    extraTree_fimp.append(fim_extraTree)
    test_preds = model.predict(test[FEATURES])
    test_proba = model.predict_proba(test[FEATURES])
    extraTree_predictions.append(test_preds)
    extraTree_probability.append(test_proba)
    
print(f'\n\033[1;30;34m Training Accuracy   : \033[0;0m {(model.score(X_train, y_train)*100).round(2)}%')
print(f'\033[1;30;34m Validation Accuracy : \033[0;0m {(model.score(X_valid, y_valid)*100).round(2)}%')
print("\n\033[1;30;34m Mean Accuracy    : \033[0;0m",(np.mean(extraTree_scores)*100).round(2),"%")

# %% [markdown]
# <h3><b id='20'><span style='color:rgb(0, 35, 156);'>Extra Tree Classification Report</span> </b></h3>

# %%
classificationReportExtraTree = classification_report(y_valid,  preds_valid)
print(classificationReportExtraTree)

# %% [markdown]
# <h3><b id='21'><span style='color:rgb(0, 35, 156);'>Extra Tree Confusion Matrix</span> </b></h3>

# %%
cf_matrix_ExtraTree = confusion_matrix(y_valid, preds_valid)
ax = sns.heatmap(cf_matrix_ExtraTree, annot=True, fmt=".0f", cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Bacteria Category')
ax.set_ylabel('Actual Bacteria Category\n')
plt.show()

# %% [markdown]
# <h3><b id='22'><span style='color:rgb(0, 35, 156);'>Extra Tree ROC Curve</span> </b></h3>

# %%
extraTree_roc_score = roc_auc_score(y_valid, proba_valid,multi_class='ovr').astype(float)
skplt.metrics.plot_roc_curve(y_valid, proba_valid)
plt.legend(loc=(1.04,0))
plt.show()

# %% [markdown]
# <h3><center><b id='23'><span style='color:rgb(0, 103, 71);'><font size="+3">Light GBM Classification Model</font></span> </b></center></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.4 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.76 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.79 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.95 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.91170</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but check <b>recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other model</b> to get <b>optimum</b> solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Excellent</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Not that much Good Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>

# %%
print(56*'#')
print(15*' ', "\033[1;30;34m  Light GBM  Calssifier \033[0;0m", 15*" ")
print(56*'#')
print('')

# lgb_params = {
#    Tune hyperparameters here, also you can use GridSearch Cross Validation      
# }


lgb_predictions = []
lgb_scores = []
lgb_fimp = []
lgb_probability = []

rskf = RepeatedStratifiedKFold(n_splits=FOLDS, random_state=RANDOM_STATE, n_repeats=REPEATS)
for fold, (train_idx, valid_idx) in enumerate(rskf.split(train[FEATURES], train[TARGET])):
    
    print(11*"*=", f"\033[1;31;31m Fold = {fold+1} \033[0;0m", 11*"*=")
    start_time = time.time()
    
    X_train, X_valid = train.iloc[train_idx][FEATURES], train.iloc[valid_idx][FEATURES]
    y_train , y_valid = train[TARGET].iloc[train_idx] , train[TARGET].iloc[valid_idx]
    
    model = LGBMClassifier(device = 'gpu')
    model.fit(X_train, y_train,verbose=0)
    
    preds_valid = model.predict(X_valid)
    proba_valid = model.predict_proba(X_valid)
    acc = accuracy_score(y_valid,  preds_valid)
    lgb_scores.append(acc)
    run_time = time.time() - start_time
    
    print(f"\033[1;31;32mFold = \033[0;0m{fold+1}, \033[1;31;32m Accuracy: \033[0;0m\033[1m{acc:.5f}\033[0m, \033[1;31;33m Run Time: \033[0;0m{run_time:.2f}s")
    print(28*'*=')
    print("\n")
    fim_lgbm = pd.DataFrame(index=FEATURES,
                 data=model.feature_importances_,
                 columns=[f'{fold}_importance'])
    lgb_fimp.append(fim_lgbm)
    test_preds = model.predict(test[FEATURES])
    test_proba = model.predict_proba(test[FEATURES])
    lgb_predictions.append(test_preds)
    lgb_probability.append(test_proba)
    
print(f'\n\033[1;30;34m Training Accuracy   : \033[0;0m {(model.score(X_train, y_train)*100).round(2)}%')
print(f'\033[1;30;34m Validation Accuracy : \033[0;0m {(model.score(X_valid, y_valid)*100).round(2)}%')
print("\n\033[1;30;34m Mean Accuracy    : \033[0;0m",(np.mean(lgb_scores)*100).round(2),"%")

# %% [markdown]
# <h3><b id='24'><span style='color:rgb(0, 35, 156);'>Light GBM Classification Report</span> </b></h3>

# %%
classificationReportLGBM = classification_report(y_valid,  preds_valid)
print(classificationReportLGBM)

# %% [markdown]
# <h3><b id='25'><span style='color:rgb(0, 35, 156);'>Light GBM Confusion Matrix</span> </b></h3>

# %%
cf_matrix_LGBM = confusion_matrix(y_valid, preds_valid)
ax = sns.heatmap(cf_matrix_LGBM, annot=True, fmt=".0f", cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Bacteria Category')
ax.set_ylabel('Actual Bacteria Category\n')
plt.show()

# %% [markdown]
# <h3><b id='26'><span style='color:rgb(0, 35, 156);'>Light GBM ROC Curve</span> </b></h3>

# %%
lgbm_roc_score = roc_auc_score(y_valid, proba_valid,multi_class='ovr').astype(float)
skplt.metrics.plot_roc_curve(y_valid, proba_valid)
plt.legend(loc=(1.04,0))
plt.show()

# %% [markdown]
# <h3><center><b id='27'><span style='color:rgb(0, 103, 71);'><font size="+3">Cat Boost Classification Model</font></span> </b></center></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.68 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.49 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.53 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.94 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.92345</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but check <b>recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other model</b> to get <b>optimum</b> solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Excellent</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Not that much Good Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>

# %%
print(56*'#')
print(15*' ', "\033[1;30;34m  CAT Boost  Calssifier \033[0;0m", 15*" ")
print(56*'#')
print('')

catb_params = {
    "objective": "MultiClass",
    "task_type": "GPU",
}

catb_predictions = []
catb_scores = []
catb_fimp = []
catb_probability = []

rskf = RepeatedStratifiedKFold(n_splits=FOLDS, random_state=RANDOM_STATE, n_repeats=REPEATS)
for fold, (train_idx, valid_idx) in enumerate(rskf.split(train[FEATURES], train[TARGET])):
    
    print(11*"*=", f"\033[1;31;31m Fold = {fold+1} \033[0;0m", 11*"*=")
    start_time = time.time()
    
    X_train, X_valid = train.iloc[train_idx][FEATURES], train.iloc[valid_idx][FEATURES]
    y_train , y_valid = train[TARGET].iloc[train_idx] , train[TARGET].iloc[valid_idx]
    
    model = CatBoostClassifier(**catb_params)
    model.fit(X_train, y_train,verbose=0)
    
    preds_valid = model.predict(X_valid)
    proba_valid = model.predict_proba(X_valid)
    acc = accuracy_score(y_valid,  preds_valid)
    catb_scores.append(acc)
    run_time = time.time() - start_time
    
    print(f"\033[1;31;32mFold: \033[0;0m{fold+1}, \033[1;31;32m Accuracy: \033[0;0m\033[1m{acc:.5f}\033[0m, \033[1;31;33m Run Time: \033[0;0m{run_time:.2f}s")
    print(28*'*=')
    print("\n")
    fim_catBoost = pd.DataFrame(index=FEATURES,
                 data=model.feature_importances_,
                 columns=[f'{fold}_importance'])
    catb_fimp.append(fim_catBoost)
    test_preds = model.predict(test[FEATURES])
    test_proba = model.predict_proba(test[FEATURES])
    catb_predictions.append(test_preds)
    catb_probability.append(test_proba)
    
print(f'\n\033[1;30;34m Training Accuracy   : \033[0;0m {(model.score(X_train, y_train)*100).round(2)}%')
print(f'\033[1;30;34m Validation Accuracy : \033[0;0m {(model.score(X_valid, y_valid)*100).round(2)}%')
print("\n\033[1;30;34m Mean Accuracy    : \033[0;0m",(np.mean(catb_scores)*100).round(2),"%")

# %% [markdown]
# <h3><b id='28'><span style='color:rgb(0, 35, 156);'>Cat Boost Classification Report</span> </b></h3>

# %%
classificationReportCatBoost = classification_report(y_valid,  preds_valid)
print(classificationReportCatBoost)

# %% [markdown]
# <h3><b id='29'><span style='color:rgb(0, 35, 156);'>Cat Boost Confusion Matrix</span> </b></h3>

# %%
cf_matrix_CATBoost = confusion_matrix(y_valid, preds_valid)
ax = sns.heatmap(cf_matrix_CATBoost, annot=True, fmt=".0f", cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Bacteria Category')
ax.set_ylabel('Actual Bacteria Category\n')
plt.show()

# %% [markdown]
# <h3><b id='30'><span style='color:rgb(0, 35, 156);'>Cat Boost ROC Curve</span> </b></h3>

# %%
catBoost_roc_score = roc_auc_score(y_valid, proba_valid,multi_class='ovr').astype(float)
skplt.metrics.plot_roc_curve(y_valid, proba_valid)
plt.legend(loc=(1.04,0))
plt.show()

# %% [markdown]
# <h3><center><b id='31'><span style='color:rgb(0, 103, 71);'><font size="+3">XGBoost Classification Model</font></span> </b></center></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.61 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.8 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.91 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.95 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.91973</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but check <b>recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but shoul see <b>other model</b> to get <b>optimum</b> solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Excellent</b>, and it seems most of model give nearby <b style='color:rgb(208, 28,31);'>same result</b> but we should try <b style='color:rgb(208, 28,31);'>DNN Technique</b> now</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Not that much Good Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>

# %%
print(56*'#')
print(15*' ', "\033[1;30;34m  XG  Boost  Calssifier \033[0;0m", 15*" ")
print(56*'#')
print('')

# xgb_params = {
#    Tune hyperparameters here, also you can use GridSearch Cross Validation 
# }


xgb_predictions = []
xgb_scores = []
xgb_fimp = []
xgb_probability = []

rskf = RepeatedStratifiedKFold(n_splits=FOLDS, random_state=RANDOM_STATE, n_repeats=REPEATS)
for fold, (train_idx, valid_idx) in enumerate(rskf.split(train[FEATURES], train[TARGET])):
    
    print(11*"*=", f"\033[1;31;31m Fold = {fold+1} \033[0;0m", 11*"*=")
    start_time = time.time()
    
    X_train, X_valid = train.iloc[train_idx][FEATURES], train.iloc[valid_idx][FEATURES]
    y_train , y_valid = train[TARGET].iloc[train_idx] , train[TARGET].iloc[valid_idx]
    
    model = XGBClassifier(objective = 'multi:softprob',eval_metric = 'mlogloss',tree_method = 'gpu_hist',predictor = 'gpu_predictor')
    model.fit(X_train, y_train,verbose=0)
    
    preds_valid = model.predict(X_valid)
    proba_valid = model.predict_proba(X_valid)
    acc = accuracy_score(y_valid,  preds_valid)
    xgb_scores.append(acc)
    run_time = time.time() - start_time
    
    print(f"\033[1;31;32mFold: \033[0;0m{fold+1}, \033[1;31;32m Accuracy: \033[0;0m\033[1m{acc:.5f}\033[0m, \033[1;31;33m Run Time: \033[0;0m{run_time:.2f}s")
    print(28*'*=')
    print("\n")
    fim_xgb = pd.DataFrame(index=FEATURES,
                 data=model.feature_importances_,
                 columns=[f'{fold}_importance'])
    xgb_fimp.append(fim_xgb)
    test_preds = model.predict(test[FEATURES])
    test_proba = model.predict_proba(test[FEATURES])
    xgb_predictions.append(test_preds)
    xgb_probability.append(test_proba)
    
print(f'\n\033[1;30;34m Training Accuracy   : \033[0;0m {(model.score(X_train, y_train)*100).round(2)}%')
print(f'\033[1;30;34m Validation Accuracy : \033[0;0m {(model.score(X_valid, y_valid)*100).round(2)}%')
print("\n\033[1;30;34m Mean Accuracy    : \033[0;0m",(np.mean(xgb_scores)*100).round(2),"%")

# %% [markdown]
# <h3><b id='32'><span style='color:rgb(0, 35, 156);'>XGBoost Classification Report</span> </b></h3>

# %%
classificationReportXGB = classification_report(y_valid,  preds_valid)
print(classificationReportXGB)

# %% [markdown]
# <h3><b id='33'><span style='color:rgb(0, 35, 156);'>XGBoost Confusion Matrix</span> </b></h3>

# %%
cf_matrix_XGBoost = confusion_matrix(y_valid, preds_valid)
ax = sns.heatmap(cf_matrix_XGBoost, annot=True, fmt=".0f", cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Bacteria Category')
ax.set_ylabel('Actual Bacteria Category\n')
plt.show()

# %% [markdown]
# <h3><b id='34'><span style='color:rgb(0, 35, 156);'>XGBoost ROC Curve</span> </b></h3>

# %%
xgb_roc_score = roc_auc_score(y_valid, proba_valid,multi_class='ovr').astype(float)
skplt.metrics.plot_roc_curve(y_valid, proba_valid)
plt.legend(loc=(1.04,0))
plt.show()

# %% [markdown]
# <a id="35"></a> <br>
# # <div style="color:white;display:fill;border-radius:5px;background-color:white;letter-spacing:0.1px;overflow:hidden"><p style="padding:20px;color:rgb(233, 92, 32);overflow:hidden;margin:0;font-size:100%;text-align:center">Accuracy Scores</p></div>
#
# <h3><b id='35'><span style='color:rgb(0, 103, 71);'>Mean Score Accuracy</span> </b></h3>

# %%
# print("\033[1;31;31mKNeighbors Mean Accuracy    :\033[0;0m", '\033[1;31;32m', (np.mean(KNeighbors_scores)*100).round(2),"%\033[0;0m")
print("\n\033[1;31;31mDecision Tree Mean Accuracy :\033[0;0m", '\033[1;31;32m', (np.mean(decisionTree_scores)*100).round(2),"%\033[0;0m")
print("\n\033[1;31;31mRandom Forest Mean Accuracy :\033[0;0m", '\033[1;31;32m', (np.mean(randomForestClassifier_scores)*100).round(2),"%\033[0;0m")
print("\n\033[1;31;31mExtra Tree Mean Accuracy    :\033[0;0m", '\033[1;31;32m', (np.mean(extraTree_scores)*100).round(2),"%\033[0;0m")
print("\n\033[1;31;31mLight GBM Mean Accuracy     :\033[0;0m", '\033[1;31;32m', (np.mean(lgb_scores)*100).round(2),"%\033[0;0m")
print("\n\033[1;31;31mCatBoost Mean Accuracy      :\033[0;0m", '\033[1;31;32m', (np.mean(catb_scores)*100).round(2),"%\033[0;0m")
print("\n\033[1;31;31mXGBoost Mean Accuracy       :\033[0;0m", '\033[1;31;32m', (np.mean(xgb_scores)*100).round(2),"%\033[0;0m")

# %% [markdown]
# <h3><b id='36'><span style='color:rgb(0, 103, 71);'>ROC Curve Score</span> </b></h3>

# %%
# print('\033[1;30;34m KNN ROC Accuracy Score           :\033[0;0m','\033[1;31;32m',((knn_roc_score)*100).round(2),"%\033[0;0m")
print('\n\033[1;30;34m Decision Tree ROC Accuracy Score :\033[0;0m','\033[1;31;32m',((decisionTree_roc_score)*100).round(2),"%\033[0;0m")
print('\n\033[1;30;34m Random Forest ROC Accuracy Score :\033[0;0m','\033[1;31;32m',((randomForest_roc_score)*100).round(2),"%\033[0;0m")
print('\n\033[1;30;34m Extra Tree ROC Accuracy Score    :\033[0;0m','\033[1;31;32m',((extraTree_roc_score)*100).round(2),"%\033[0;0m")
print('\n\033[1;30;34m Light GBM ROC Accuracy Score     :\033[0;0m','\033[1;31;32m',((lgbm_roc_score)*100).round(2),"%\033[0;0m")
print('\n\033[1;30;34m CatBoost ROC Accuracy Score      :\033[0;0m','\033[1;31;32m',((catBoost_roc_score)*100).round(2),"%\033[0;0m")
print('\n\033[1;30;34m XGBoost ROC Accuracy Score       :\033[0;0m','\033[1;31;32m',((xgb_roc_score)*100).round(2),"%\033[0;0m")

# %% [markdown]
# <a id="37"></a> <br>
# # <div style="color:white;display:fill;border-radius:5px;background-color:white;letter-spacing:0.1px;overflow:hidden"><p style="padding:20px;color:rgb(233, 92, 32);overflow:hidden;margin:0;font-size:100%;text-align:center">Submission</p></div>
#
# <center><img src="https://www.pinclipart.com/picdir/big/84-849430_see-you-bacillus-bacteria-cartoon-png-clipart.png" width="800" height="100"></center>
#
# <h3><b id='37'><span style='color:rgb(0, 103, 71);'>Inverse Transform and Submit</span> </b></h3>

# %%
# KNeighbors_submission = submission.copy()
# KNeighbors_submission["target"] = encoder.inverse_transform(np.squeeze(mode(np.column_stack(KNeighbors_predictions),axis = 1)[0]).astype('int'))
# KNeighbors_submission.to_csv("KNeighborsSubmission_without_duplicates.csv",index=False)

decisionTree_submission = submission.copy()
decisionTree_submission["target"] = encoder.inverse_transform(np.squeeze(mode(np.column_stack(decisionTree_predictions),axis = 1)[0]).astype('int'))
decisionTree_submission.to_csv("decisionTreeSubmission_without_duplicates.csv",index=False)

randomForestClassifier_submission = submission.copy()
randomForestClassifier_submission["target"] = encoder.inverse_transform(np.squeeze(mode(np.column_stack(randomForestClassifier_predictions),axis = 1)[0]).astype('int'))
randomForestClassifier_submission.to_csv("randomForestClassifierSubmission_without_duplicates.csv",index=False)

extraTree_submission = submission.copy()
extraTree_submission["target"] = encoder.inverse_transform(np.squeeze(mode(np.column_stack(extraTree_predictions),axis = 1)[0]).astype('int'))
extraTree_submission.to_csv("extraTreeSubmission_without_duplicates.csv",index=False)

lgb_submission = submission.copy()
lgb_submission["target"] = encoder.inverse_transform(np.squeeze(mode(np.column_stack(lgb_predictions),axis = 1)[0]).astype('int'))
lgb_submission.to_csv("lgbmSubmission_without_duplicates.csv",index=False)

catb_submission = submission.copy()
catb_submission["target"] = encoder.inverse_transform(np.squeeze(mode(np.column_stack(catb_predictions),axis = 1)[0]).astype('int'))
catb_submission.to_csv("catBoostSubmission_without_duplicates.csv",index=False)

xgb_submission = submission.copy()
xgb_submission["target"] = encoder.inverse_transform(np.squeeze(mode(np.column_stack(xgb_predictions),axis = 1)[0]).astype('int'))
xgb_submission.to_csv("xgbSubmission_without_duplicates.csv",index=False)

# %% [markdown]
# <a id="38"></a> <br>
# # <div style="color:white;display:fill;border-radius:5px;background-color:white;letter-spacing:0.1px;overflow:hidden"><p style="padding:20px;color:rgb(233, 92, 32);overflow:hidden;margin:0;font-size:100%;text-align:center"><font size="+3">Summary</font></p></div>
#
# <h2><center><b style='color: #00B1D2FF'><b style='color:#EEB238FF'>Caution ⚠️ :</b> DATA HAS HIGH CHANCE OF OVERFITTING</b></center></h2>
# <h3 style='color: #422057FF'><center>One Solution I think will wrok for this Data is try training for <b>fewer epochs</b>, or using <b>regularisation</b> or <b>dropouts</b> to <b>mitigate over-fitting</b>, potentially sacrificing training loss and improving your test loss using DNN.</center></h3>
#
# <h3><li><b><span style='color:rgb(0, 103, 71);'><font size="+3">K- Neighbors Classification Model Summary</font></span> </b></li></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>98.4 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.01 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.08 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>93-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>94-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>98.69 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.95472</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but <b>check recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other models</b> to get optimum solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Good</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>OK Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>
#
#
# <h3><li><b><span style='color:rgb(0, 103, 71);'><font size="+3">Decision Tree Classification Model Summary</font></span> </b></li></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>100 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center>89.24 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>89.49 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>87-94 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>87-94 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>89 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>94.02 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.81537</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center><b>Not Good Data</b> Over-fits Clearly</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK but needs <b>improvement</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#EEB238FF'><center>OK</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center>Good,but it'll <b>overfit</b> because validation accuracy differs significantly from training accuracy</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(208, 28,31);'><center><b>As Expected it won't Result Good Score</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>
#
# <h3><li><b><span style='color:rgb(0, 103, 71);'><font size="+3">Random Forest Classification Model Summary</font></span> </b></li></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>100 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.48 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.42 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.92 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.97600</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but <b>check recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other models</b> to get optimum solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Very good</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Good Score to submit and it's approximately same as Validation Score</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>
#
# <h3><li><b><span style='color:rgb(0, 103, 71);'><font size="+3">Extra Tree Classification Model Summary</font></span> </b></li></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>100 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.58 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97.59 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.93 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.97762</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but <b>check recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other models</b> to get optimum solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Very good</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Good Score to submit and it's approximately same as Validation Score and <b style='color: #00B1D2FF'>Better then Random Forest</b></b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>
#
# <h3><li><b><span style='color:rgb(0, 103, 71);'><font size="+3">Light GBM Classification Model Summary</font></span> </b></li></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.4 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.76 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.79 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.95 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.91170</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but check <b>recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other model</b> to get <b>optimum</b> solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Excellent</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Not that much Good Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>
#
# <h3><li><b><span style='color:rgb(0, 103, 71);'><font size="+3">Cat Boost Classification Model Summary</font></span> </b></li></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.68 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.49 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.53 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-99 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.94 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.92345</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but check <b>recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but lets see <b>other model</b> to get <b>optimum</b> solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Excellent</b>, but we should <b style='color:rgb(208, 28,31);'>double-check</b> with <b style='color:rgb(208, 28,31);'>other models</b> and public LBs before making a conclusion.</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Not that much Good Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>
#
# <h3><li><b><span style='color:rgb(0, 103, 71);'><font size="+3">XG Boost Classification Model Summary</font></span> </b></li></h3>
#
# <font size="3">
#     <table style="border:2px solid black;margin-left:auto;margin-right:auto; border-left:auto">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Training Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Validation Accuracy</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   Mean Accuracy   </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      Precision    </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>       Recall      </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>      F1-Score     </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>  ROC AUC Accuracy </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Public Leaderboard</b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>Private Leaderboard</b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.61 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.8 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>96.91 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center>95-98 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>97 %</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>99.95 %</center></span></td>
#             <td style="border:2px solid black;"><span style='color: #00B1D2FF'><center><b>0.91973</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> Not yet Declared </center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Looks Good <b>Currently</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good Data but check <b>recall & precision</b> to make final Decision</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good but shoul see <b>other model</b> to get <b>optimum</b> solution</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center>Very Good</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #EEB238FF'><center><b>Excellent</b>, and it seems most of model give nearby <b style='color:rgb(208, 28,31);'>same result</b> but we should try <b style='color:rgb(208, 28,31);'>DNN Technique</b> now</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:rgb(0, 103, 71);'><center><b>Not that much Good Score to submit</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #422057FF'><center> - </center></span></td>
#         </tr>
#     </table>
# </font>
