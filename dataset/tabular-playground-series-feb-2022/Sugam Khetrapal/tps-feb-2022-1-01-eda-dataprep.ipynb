# %% [markdown]
# # Problem Statement
#
# In this notebook we will explore how to do Automatic Exploratory Data Analysis (EDA) on the Tabular Playground Series February 2022 dataset using [dataprep](https://pypi.org/project/dataprep/).
#
# We are going to cover the following steps:
# 1. Install dataprep
# 2. Import Libraries
# 3. Load Dataset
# 4. Print Report
# 5. References
#
# Let's get started.
#
# # Install dataprep

# %%
# !pip install dataprep

# %% [markdown]
# # Import Libraries

# %%
from dataprep.eda import plot, plot_correlation, create_report, plot_missing
from pandas import read_csv

# %% [markdown]
# # Load Dataset

# %%
# Load Dataset

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
filename_training          = '/kaggle/input/tabular-playground-series-feb-2022/train.csv'
dataset_training           = read_csv(filename_training)

# %% [markdown]
# # Print Report

# %%
plot(dataset_training)

# %% [markdown]
# # References
#
# 1. Thank you to andreshg for sharing how to do Automatic EDA in this [notebook](https://www.kaggle.com/andreshg/automatic-eda-libraries-comparisson/notebook).
