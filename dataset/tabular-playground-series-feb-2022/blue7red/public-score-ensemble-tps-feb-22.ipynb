# %%
# import module we'll need to import our custom module
from shutil import copyfile

# copy our file into the working directory (make sure it has .py suffix)
copyfile(src = "../input/public-label-encoding-ensemble/public_labelencoding_ensemble.py", dst = "../working/public_labelencoding_ensemble.py")

from public_labelencoding_ensemble import *

# %%
COMPETTITION_DIR = '/kaggle/input/tabular-playground-series-feb-2022'
SAMPLE_SUBMISSION_PATH = "/kaggle/input/tabular-playground-series-feb-2022/sample_submission.csv"
TARGET = "target"   

submitEnsemble(COMPETTITION_DIR,SAMPLE_SUBMISSION_PATH,TARGET)
