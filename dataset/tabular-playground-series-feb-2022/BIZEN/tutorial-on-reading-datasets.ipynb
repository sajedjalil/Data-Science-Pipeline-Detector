# %% [markdown]
# # Pandas
# ---

# %%
import pandas as pd

# %%
# %%time

data = pd.read_csv("../input/tabular-playground-series-feb-2022/train.csv")
data.info()

# %%
data.head()

# %% [markdown]
# # Dask
# ---

# %%
import dask.dataframe as dd

# %%
# %%time

data = dd.read_csv("../input/tabular-playground-series-feb-2022/train.csv").compute()
data.info()

# %%
data.head()

# %% [markdown]
# # datatable

# %%
import datatable as dt

# %%
# %%time

data = dt.fread("../input/tabular-playground-series-feb-2022/train.csv").to_pandas()
data.info()

# %%
data.head()

# %% [markdown]
# # RAPIDS/cuDF (GPU required)

# %%
import cudf

# %%
# %%time

data = cudf.read_csv("../input/tabular-playground-series-feb-2022/train.csv").to_pandas()
data.info()

# %%
data.head()
