# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>Notebook</strong> <strong style="font-size:60px;color:black">Motivation:</strong></h1>
#
# <h3>Many times, we wouldn't have small datasets to work with. The real world datasets are huge, and with humans generating data every second, possibilities to explore more and more data increases exponentially!</h3>
#
# <h3>Often loading such big data with Pandas can be a pain. Situation like these motivated me to look for alternate solutions on the internet and on Kaggle.</h3>
#
# <h3>Let us explore a few such tricks!😉</h3>

# %%
from IPython.core.display import display, HTML, Javascript

# ----- Notebook Theme -----
color_map = ['#16a085', '#e8f6f3', '#d0ece7', '#a2d9ce', '#73c6b6', '#45b39d', 
                        '#16a085', '#138d75', '#117a65', '#0e6655', '#0b5345']

prompt = color_map[-1]
main_color = color_map[0]
strong_main_color = color_map[1]
custom_colors = [strong_main_color, main_color]

css_file = ''' 

div #notebook {
background-color: white;
line-height: 20px;
}

#notebook-container {
# %s
margin-top: 2em;
padding-top: 2em;
border-top: 4px solid %s; /* light orange */
-webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5); /* pink */
    box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5); /* pink */
}

div .input {
margin-bottom: 1em;
}

.rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
color: %s; /* light orange */
font-weight: 600;
}

div.input_area {
border: none;
    background-color: %s; /* rgba(229, 143, 101, 0.1); light orange [exactly #E58F65] */
    border-top: 2px solid %s; /* light orange */
}

div.input_prompt {
color: %s; /* light blue */
}

div.output_prompt {
color: %s; /* strong orange */
}

div.cell.selected:before, div.cell.selected.jupyter-soft-selected:before {
background: %s; /* light orange */
}

div.cell.selected, div.cell.selected.jupyter-soft-selected {
    border-color: %s; /* light orange */
}

.edit_mode div.cell.selected:before {
background: %s; /* light orange */
}

.edit_mode div.cell.selected {
border-color: %s; /* light orange */

}
'''
def to_rgb(h): 
    return tuple(int(h[i:i+2], 16) for i in [0, 2, 4])

main_color_rgba = 'rgba(%s, %s, %s, 0.1)' % (to_rgb(main_color[1:]))
open('notebook.css', 'w').write(css_file % ('width: 95%;', main_color, main_color, main_color_rgba, main_color,  main_color, prompt, main_color, main_color, main_color, main_color))

def nb(): 
    return HTML("<style>" + open("notebook.css", "r").read() + "</style>")
nb()

# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>Pandas</strong> <strong style="font-size:60px;color:black">DataFrame:</strong></h1>

# %%
# %%time

import pandas as pd

pd_train = pd.read_csv('../input/tabular-playground-series-feb-2022/train.csv')
pd_test = pd.read_csv('../input/tabular-playground-series-feb-2022/test.csv')

# %% [markdown]
# <h3>By the time Pandas finished loading the DataFrame, I got triple PhD from Havard. 🤣</h3>
#
# <h3>We will use this as our Baseline.</h3>

# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>Polars</strong> <strong style="font-size:60px;color:black">DataFrame:</strong></h1>

# %%
# !pip3 install -U polars

# %%
# %%time

import polars as pl

polar_train = pl.read_csv('../input/tabular-playground-series-feb-2022/train.csv')
polar_test = pl.read_csv('../input/tabular-playground-series-feb-2022/test.csv')

# %% [markdown]
# <h3>Polars is Super Fast! Only a few seconds to load this data!😲</h3>
#
# <h3>More about Polars <a href="https://pola-rs.github.io/polars-book/user-guide/" style="text-decoration:none">here</a>.</h3>

# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>Dask</strong> <strong style="font-size:60px;color:black">DataFrame:</strong></h1>

# %%
# %%time

import dask.dataframe as dd

dd_train = dd.read_csv('../input/tabular-playground-series-feb-2022/train.csv')
dd_test = dd.read_csv('../input/tabular-playground-series-feb-2022/test.csv')

# %% [markdown]
# <h3>This is probably how long I last in bed... 😥</h3>
#
# <h3>More about Dask <a href="https://docs.dask.org/en/stable/dataframe.html" style="text-decoration:none">here</a>.</h3>

# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>Rapidsai/CUDF</strong> <strong style="font-size:60px;color:black">DataFrame:</strong></h1>

# %%
# %%time

import cudf

cudf_train = cudf.read_csv('../input/tabular-playground-series-feb-2022/train.csv')
cudf_test = cudf.read_csv('../input/tabular-playground-series-feb-2022/test.csv')

# %% [markdown]
# <h3>This took longer than I expected, but it is certainly faster than Pandas.🙃</h3>
#
# <h3>One thing to note here is that you should have your GPU enabled to leverage the power of CUDF.</h3>
#
# <h3>More about CUDF <a href="https://docs.rapids.ai/api/cudf/stable/" style="text-decoration:none">here</a>.</h3>

# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>DataTable</strong> <strong style="font-size:60px;color:black">Python:</strong></h1>

# %%
# %%time

import datatable as dt

dt_train = dt.fread('../input/tabular-playground-series-feb-2022/train.csv')
dt_test = dt.fread('../input/tabular-playground-series-feb-2022/test.csv')

# %% [markdown]
# <h3>Datatable definitely is fast, but it definitely takes some time to get used to.</h3>
#
# <h3><a href="https://www.kaggle.com/sudalairajkumar/getting-started-with-python-datatable" style="text-decoration:none">Here</a> is a wonderful notebook that talks about the same.</h3>

# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>Modin</strong> <strong style="font-size:60px;color:black">DataFrame:</strong></h1>

# %%
# !pip install modin

# %%
# !pip install modin[ray]

# %%
# %%time

import os
os.environ["MODIN_ENGINE"] = "ray"  # Modin will use Ray
import modin.pandas as pd

mod_train = pd.read_csv('../input/tabular-playground-series-feb-2022/train.csv')
mod_test = pd.read_csv('../input/tabular-playground-series-feb-2022/test.csv')

# %% [markdown]
# <h3>Meh... It's fine, but not worth the hype. There was not much difference between Modin and Pandas. Only a few seconds difference.😕</h3>

# %% [markdown]
# <h1 style="font-size:60px;color:#16a085"><strong>Final</strong> <strong style="font-size:60px;color:black">Verdict:</strong></h1>
#
# <h3>There are many such libraries out there that help us manage huge dataframes with minimal effort and ease.</h3>
#
# <h3>Dask was definitely the fastest one here.🔥🚒</h3>
#
# <h3>I will definitely try to use Dask and Polars in this competition and in my real life use cases.</h3>
#
# <h3>Finally, at the end of the day, it's all upto you. How you want to work with your data. You are the Captain of your ship and you should choose what works best for you.</h3>
#
# <h3>You guys can read more about them from <a href="https://www.kaggle.com/c/tabular-playground-series-feb-2022/discussion/304496" style="text-decoration:none">here</a></h3>.
#
# <h3 style="text-align:center;color:#16a085">If you like this minimalistic notebook, consider dropping an upvote.😁</h3>
