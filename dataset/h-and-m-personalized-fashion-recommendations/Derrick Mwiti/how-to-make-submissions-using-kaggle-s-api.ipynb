# %% [markdown]
# ### How to make submissions using Kaggle's API

# %%
# pip install kaggle

# %% [markdown]
# Start by obtaining the API on https://www.kaggle.com/yourusername/account

# %%
import os
os.environ["KAGGLE_USERNAME"]="yourusername"
os.environ["KAGGLE_KEY"]="yourapikey"

# %%
# !kaggle competitions list

# %% [markdown]
# ### List competitition files

# %%
# !kaggle competitions files h-and-m-personalized-fashion-recommendations

# %% [markdown]
# ### Make a submission

# %%
# !kaggle competitions submit -c h-and-m-personalized-fashion-recommendations  -f ../input/h-and-m-personalized-fashion-recommendations/sample_submission.csv -m "Submission via API"

# %% [markdown]
# ### Check the leaderboard

# %%
# !kaggle competitions submissions -c h-and-m-personalized-fashion-recommendations

# %%
# !kaggle competitions  leaderboard h-and-m-personalized-fashion-recommendations --show

# %% [markdown]
# Learn more on [GitHub](https://github.com/Kaggle/kaggle-api) and [Kaggle](https://www.kaggle.com/docs/api)
