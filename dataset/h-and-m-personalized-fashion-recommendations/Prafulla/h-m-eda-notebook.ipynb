# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

# %% [markdown]
# **Get first 30% data for the analysis**

# %%
Articles = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/articles.csv", usecols = [1])
Customers = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/customers.csv", usecols = [1])
transaction_train = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv", usecols = [1])

Articles = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/articles.csv", nrows = round(len(Articles)*.30))
Customers = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/customers.csv", nrows = round(len(Customers)*.30))
transaction_train = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv", nrows = round(len(transaction_train)*.30))

# %% [markdown]
# > **Articles table contains all the details about the products. It contains product with many articles and their description like colour, appeareance, department etc..**

# %%
Articles.head()

# %%
Articles['product_group_name'].unique()

# %% [markdown]
# > **Large variety of articles in Ladieswear.**

# %%
ax = plt.subplots(figsize = (10,7))
ax = sns.histplot(data = Articles, y = 'index_group_name', color = 'Red')

# %%
f, ax = plt.subplots(figsize = (15,7))
ax = sns.histplot(data = Articles, y = 'index_name', color = 'Red')

# %% [markdown]
# > **Products are grouped by index. Upper body garment has most number of articles in ladies and children wear. In shirt garment group menswear have most articles**

# %%
f, ax = plt.subplots(figsize=(15, 7))
ax = sns.histplot(data=Articles, y='product_group_name', color='red', hue='index_group_name', multiple="stack")
ax.set_xlabel('Count By Product Group')
ax.set_ylabel('Product Group')
plt.show()

# %%
f, ax = plt.subplots(figsize = (15,7))
ax = sns.histplot(data = Articles, y = 'garment_group_name', color = 'r', hue = 'index_group_name', multiple = 'stack')
