# %% [markdown]
# ## This is a demo to illustrate the results of a recommender system built using five different sets of user and item embeddings.
#
#
# ![image.png](attachment:760a6c8a-7226-49ca-82b4-d25e89dae178.png)
#
# # Demo Resources
#
# A video: https://www.youtube.com/watch?v=OGmCGVxmeY8&ab_channel=MohammadNour <br>
# The app hosted on Streamlit Share: https://share.streamlit.io/mnobeidat13/handm-recommender-system/main <br>
# The Github repo for the app: https://github.com/mnobeidat13/HandM-Recommender-System <br>
# All code can be found in the documentation section of the app or on my Kaggle page: https://www.kaggle.com/mohammedobeidat/code
