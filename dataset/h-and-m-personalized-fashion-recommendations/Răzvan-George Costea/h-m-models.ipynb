# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
path = "../input/h-m-eda/"

articles = pd.read_csv(path + "articles_data.csv")
customers = pd.read_csv(path + "customers_data.csv")

# %%
articles.head()

# %%
customers.head()

# %%
chunks = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv", chunksize=5298054) #this will result in 6 chunks

chunk_list = []

for chunk in chunks:
    #chunk_filter = chunk.drop(['sales_channel_id'], axis=1) 
    
    chunk_list.append(chunk)
transactions = pd.concat(chunk_list)

# %%
transactions

# %% [markdown]
# #### First strategy: We can use LSTM for each customer to predict the next buy based on the previous ones

# %%
for customer in customers.customer_id:
    customer_transactions = transactions[transactions.customer_id == customer].drop(['customer_id'], axis=1)
    X = customer_transactions.drop(['article_id'], axis=1)
    y = customer_transactions['article_id']
