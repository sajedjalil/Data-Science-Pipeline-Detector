# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
articles = pd.read_csv(
    "../input/h-and-m-personalized-fashion-recommendations/articles.csv"
)
customers = pd.read_csv(
    "../input/h-and-m-personalized-fashion-recommendations/customers.csv"
)
sample_submission = pd.read_csv(
    "../input/h-and-m-personalized-fashion-recommendations/sample_submission.csv"
)
train = pd.read_csv(
    "../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv",
    parse_dates=["t_dat"],
)

# %%
articles

# %%
articles.columns

# %%
print(articles.product_group_name.unique())
len(articles.product_group_name.unique())

# %%
print(articles.colour_group_name.unique())
len(articles.colour_group_name.unique())

# %%
print(articles.index_name.unique())
len(articles.index_name.unique())

# %%
print(articles.section_name.unique())
len(articles.section_name.unique())

# %%
min([(1,2),(2,3)])
