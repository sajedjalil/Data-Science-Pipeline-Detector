# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv")
df_offline=df[df["sales_channel_id"]==1]
df_online=df[df["sales_channel_id"]==2]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates

from datetime import datetime

# %%
dates_offline = matplotlib.dates.date2num(df_offline['t_dat'].unique())

# %%
plt.scatter(dates_offline,[1]*len(dates_offline))

# %%
dates_online = matplotlib.dates.date2num(df_online['t_dat'].unique())

# %%
plt.scatter(dates_online,[1]*len(dates_online))
