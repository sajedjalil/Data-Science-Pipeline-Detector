# %%
# !pip install turicreate

# %%
import turicreate as tc
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# %%
customers=pd.read_csv('../input/h-and-m-personalized-fashion-recommendations/customers.csv')
customers.describe()

# %%
transactionsdata=pd.read_csv('../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv',dtype={'article_id': str})

# %%
transactionsdata

# %%
transactionsdata=tc.SFrame.read_csv('../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv')

# %%
transactionsdata

# %%
data=transactionsdata.remove_column('t_dat')
data=data.remove_column('price')
data=data.remove_column('sales_channel_id')

# %%
res = data.rename({'customer_id': 'user_id', 'article_id':'item_id'})

# %%
sample=res[0:12]

# %%
sample

# %%
model=tc.item_similarity_recommender.create(sample)

# %%
ss=tc.SFrame.read_csv('../input/h-and-m-personalized-fashion-recommendations/sample_submission.csv')

# %%
ss

# %%
results = model.recommend(sample['user_id'])
print(results)

# %%
finalpredic=results.to_dataframe()
finalpredic[]

# %%
a=finalpredic.drop(['score','rank'],axis=1)

# %%
a

# %%
b1=a['item_id'].astype(str)

# %%
odata='0'+b1

# %%
odata

# %%
b['item_id']=odata

# %%
b

# %%
data=b.rename(columns={'user_id':'customer_id','item_id':'prediction'})
data=data['prediction'].astype(str)

# %%
top_12_items = data.head(12)

# %%
top_12_items

# %%
s=pd.read_csv('../input/h-and-m-personalized-fashion-recommendations/sample_submission.csv')
s

# %%
s['prediction'] =  ' '.join(top_12_items)
s.to_csv('submission.csv', index=False)
s.shape

# %%
(s['prediction'][0])
