# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset - articles into the dataframe
articles=pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/articles.csv")

# %%
# Display first 5 rows
articles.head()

# %%
# Check the types of data
articles.info()

# %%
# Summary of the numerical features
articles.describe()

# %%
# Total number of rows and columns
articles.shape

# %%
# Rows containing duplicate data
dupli_rows = articles[articles.duplicated()]
print("Number of duplicate rows: ", dupli_rows.shape)

# %%
# how many null-na  values in each column
articles.isna().sum()

# %% [markdown]
# Feature detail_desc is having null values

# %%
# Dealing null values with mode
articles.detail_desc.fillna(articles.detail_desc.mode()[0],inplace = True)

# %%
# Unique product types
articles.product_type_no.unique()

# %%
# Unique product types
product_count=articles["product_type_no"].value_counts()

# %%
# assigned index to each product
product_count.index

# %%
# Groupby Product
by_product=articles.groupby("product_type_no")
by_product.head()

# %%
by_product.count()

# %%
# By_Product type 
by_product.sum().to_csv("Product Types.csv")

# %%
plt.figure(figsize=(20, 15), dpi=80)
plt.hist(articles["product_type_no"])
