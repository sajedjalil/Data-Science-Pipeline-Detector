# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
article_df = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/articles.csv")
customer_df = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/customers.csv")

# %% [markdown]
# # 1. Articles

# %%
article_df['article_id'].count()

# %%
article_df.head()

# %% [markdown]
# ## 1.1. Count by Index

# %%
sns.displot(y = article_df['index_name'], height = 4)

# %% [markdown]
# ## 1.2. Count by Product Type

# %%
sns.displot(y = article_df['product_type_name'], height = 32)

# %% [markdown]
# ## 1.3. Count by Colour Group

# %%
sns.displot(y = article_df['colour_group_name'], height = 16)

# %% [markdown]
# ## 1.4. Count by Graphical Appearance

# %%
sns.displot(y = article_df['graphical_appearance_name'], height = 8)

# %% [markdown]
# # 2. Customers

# %%
customer_df['customer_id'].count()

# %%
customer_df.head()

# %% [markdown]
# ## 2.1. Count by Age

# %%
sns.displot(y = customer_df['age'], height = 16)

# %% [markdown]
# ## 2.2. Count by Club Member Status

# %%
sns.displot(y = customer_df['club_member_status'], height = 4)

# %% [markdown]
# ## 2.3. Count by Fashion News Frequency

# %%
sns.displot(y = customer_df['fashion_news_frequency'], height = 4)
