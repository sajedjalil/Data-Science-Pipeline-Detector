# %% [markdown]
# I found some departments that have similar name, but have different department_no.
# Are there any differeces ??

# %%
import pandas as pd

# %%
df = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/articles.csv")
_df = df[["department_no", "department_name"]].drop_duplicates().reset_index(drop=True)
_df.head()

# %%
_df[_df.department_name.str.contains("Promotion")]
