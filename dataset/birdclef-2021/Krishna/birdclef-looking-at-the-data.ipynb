# %%
import pandas as pd
from pathlib import Path
import IPython.display as ipd

# %%
train_meta = pd.read_csv(ROOT / 'train_metadata.csv'); train_meta.head().T

# %%
ROOT = Path("../input/birdclef-2021/")
sample_submission = pd.read_csv(ROOT / 'sample_submission.csv'); sample_submission

# %%
train_sound_labels =  pd.read_csv(ROOT / 'train_soundscape_labels.csv'); train_sound_labels.head().T

# %% [markdown]
# Total number of files

# %%
# !find ../input/birdclef-2021/train_short_audio -type f -name '*ogg' | wc -l

# %%
len(sample_submission), len(train_sound_labels), 3

# %%
test = pd.read_csv(ROOT / 'test.csv'); test

# %% [markdown]
# train_soundscapes

# %%
fname = Path(ROOT)/'train_soundscapes/10534_SSW_20170429.ogg'
ipd.Audio(fname)

# %% [markdown]
# train_short_audio

# %%
fname = Path(ROOT)/'train_short_audio/amewig/XC150015.ogg'
ipd.Audio(fname)
