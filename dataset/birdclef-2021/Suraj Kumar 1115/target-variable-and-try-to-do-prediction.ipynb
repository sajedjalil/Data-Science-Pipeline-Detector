# %%
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Embedding
from tensorflow .keras.models import Sequential
from tensorflow .keras .layers import LSTM,Dense,Bidirectional,Dropout
from tensorflow.keras.preprocessing.text import one_hot

# %%
train_data=pd.read_csv('../input/birdclef-2021/train_metadata.csv')

# %%
train_data.head()

# %%
train_data['license'][2100]

# %%
df_test=pd.read_csv('../input/birdclef-2021/test.csv')

# %%
df_test.head()

# %%
df_new=pd.read_csv('../input/birdclef-2021/train_soundscape_labels.csv')

# %%
df_new.tail(10)

# %%
df_new.isnull().sum()

# %%
df_new=df_new[['birds','seconds']]

# %%
df_new.head(10)

# %%
df_new['seconds'].unique()

# %%
df_new['birds'].unique()

# %%
possible_labels=df_new.birds.unique()
label_dict={}
for index,possible_label in enumerate(possible_labels):
    label_dict[possible_label]=index
label_dict

# %%
df_new['label']=df_new.birds.replace(label_dict)
df_new.head()

# %%
df_new.shape

# %%
df_new.describe()

# %%
df_new.info()

# %%
# histogram of label  column
df_new['label'].hist()

# %%
df_new['seconds'].hist()

# %%
#  barplot between label(each birds) sound recording at different time in seconds  
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(30,20))
sns.barplot(x='label',y='seconds',data=df_new)
