# %%
# !git clone https://github.com/chjinny/RSNA2019_Intracranial-Hemorrhage-Detection.git

# %%
# %cd RSNA2019_Intracranial-Hemorrhage-Detection

# %%
# !pip install -r requirements.txt

# %%
# %cd 2DNet

# %%
# !sudo apt install unzip
# !unzip data.zip

# %%
# %cd data
# !ls

# %%
# %cd ../src

# %%
# Prepapre Data for training
#!python prepare_data.py -dcm_path ../../../../input/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train -png_path train_png
#!python prepare_data.py -dcm_path ../../../../input/rsna-intracranial-hemorrhage-detection/rsna-intracranial-hemorrhage-detection/stage_2_train -png_path test_png

# %%
#!cd test_png && ls

# %%
'''
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("./test_png/ID_0161aacd7.png")
plt.imshow(img)
plt.show()
print(img.shape)

img = cv2.imread("./test_png/ID_4102a0aa2.png")
plt.imshow(img)
plt.show()
print(img.shape)
'''

# %%
# !cd ../../../../input/rsna-intracranial-hemorrhage-detection-weight-file && ls

# %%
#!python train.py -backbone se_resnext101_32x4d -img_size 256 -tbs 80 -vbs 40 -save_path ../../../../input/rsna-intracranial-hemorrhage-detection-weight-file/se_resnext101_256by256

# %%
# %cp -r ../../../../input/rsna-intracranial-hemorrhage-detection-weight-file/prediction ./

# %%
# !cd prediction && ls

# %%
# !python predict.py -backbone DenseNet121_change_avg -img_size 256 -tbs 4 -vbs 4 -spth ./prediction/DenseNet121_change_avg_512
