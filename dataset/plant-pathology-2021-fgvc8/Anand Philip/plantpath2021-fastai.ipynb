# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import sys

# %%
from fastai.vision import *
from fastai.vision.all import *
from fastai.vision.core import *
from fastai.vision.data import *

# %%
import torch
import fastai
print(torch.__version__)
print(torch.cuda.is_available())
print(fastai.__version__)

# %%
path = Path('../input/plant-pathology-2021-fgvc8')

# %%
train_df= pd.read_csv(path/'train.csv')
train_df.head()

# %%
def get_x(x): return path/'test_images'/x['image']
def get_y(y): return y['labels']

# %%
m = '../input/mylearner/learnerf1_0798.pkl'

# %%
sample = pd.read_csv(path/'sample_submission.csv')
sample

# %%
predictions = 0
learner = load_learner(m, cpu=False)
test_dl = learner.dls.test_dl(sample)
preds, _ = learner.tta(dl=test_dl)
predictions += preds
predictions

# %%
vocab = learner.dls.vocab
preds_dec = [vocab[i] for i in predictions.argmax(1)]
preds_dec

# %%
sample['labels'] = preds_dec
sample.to_csv('submission.csv',index=False)
sample
