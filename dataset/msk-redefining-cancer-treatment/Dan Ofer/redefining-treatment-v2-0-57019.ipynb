# %% [markdown]
# Donated to Cancer Treatment
# =============================

# %%
import pandas as pd
import numpy as np
import sqlite3, io

c = sqlite3.connect('../input/dataset01/database.sqlite')
df = pd.read_sql('Select * From stacks Where Id=3', c)
df.head()

# %%
df.ix[0]

# %%
submission = pd.read_csv(io.StringIO(df['file'][0]))
submission.to_csv('submission_xgb_fold_4.csv', index=False)
