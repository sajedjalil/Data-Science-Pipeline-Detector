# %% [markdown]
# I just want to download the 'test_v2_file_mapping.csv'...

# %%
# !ls ../input

# %%
# !cp ../input/test_v2_file_mapping.csv .

# %% [markdown]
# And there you have it. We've fixed it. Thanks for your patience, and good luck!
