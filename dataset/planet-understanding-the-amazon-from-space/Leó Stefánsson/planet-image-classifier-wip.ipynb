# %% [markdown]
# planet-understanding-the-amazon-from-space
# ==========================================
#
#
# ----------
#
#
# **Task / Problem Description:**
#
#
# For each image listed in the test set, predict a space-delimited list of tags which you believe are associated with the image. There are 17 possible tags:
#
#  - agriculture
#  - artisinal_mine
#  - bare_ground
#  - blooming
#  - blow_down
#  - clear
#  - cloudy
#  - conventional_mine
#  - cultivation
#  - habitation
#  - haze
#  - partly_cloudy
#  - primary, road
#  - selective_logging
#  - slash_burn
#  - water
#
# ----------

# %%
# IMPORTS

import numpy as np
import pandas as pd

# %%
# print list of data files
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %%
# lets look at the sample_submission.csv file...
sample_csv = pd.read_csv("../input/sample_submission.csv")
sample_csv.head()

# %% [markdown]
# okay, so looks like the format is a table with two columns:
#
# -   *image name* which is an image name :D
# - *tags* which is a separated list of tags

# %%
# lets look at the training data
train = pd.read_csv("../input/train.csv")
train.shape

# %%
# looks like 40478 rows (with the HEADER) and two columns. let's verify
train.head()
print(len(train))
# Jesse: We don't count the header

# %%
# lets look at the tags
tags = train['tags'].apply(lambda x: x.split(' '))
tags.head(n=20)

# %%
# lets count the instances of them
# TODO
tags.groupby(['tags'])
