# %%
import pandas as pd
import numpy as np
import random, math
import multiprocessing
from tqdm import tqdm
import numba
tqdm.pandas()

xtrain = pd.read_csv('../input/X_train.csv')
ytrain = pd.read_csv('../input/y_train.csv')
train = pd.merge(xtrain, ytrain, how='left', on='series_id')

xtest = pd.read_csv('../input/X_test.csv')
ytest = pd.read_csv('../input/sample_submission.csv')
test = pd.merge(xtest, ytest, how='left', on='series_id')
print(train.shape, test.shape)
# Out:
# (487680, 15) (488448, 14)

# %%
def features(df):
    for c in ['angular_velocity_', 'linear_acceleration_']:
        col = [c + c1 for c1 in ['X','Y','Z']]
        for agg in ['min(', 'max(', 'sum(', 'mean(', 'std(', 'skew(', 'kurtosis(', 'quantile(.25,', 'quantile(.5,', 'quantile(.75,']:
            df[c+agg] = eval('df[col].' + agg + 'axis=1)')
            df[c+'a'+agg] = eval('df[col].abs().' + agg + 'axis=1)')
    return df

train = features(train).fillna(0)
test = features(test).fillna(0)
print(train.shape, test.shape)
# Out:
# (487680, 55) (488448, 54)

# %%
col = [c for c in train.columns if c not in ['row_id', 'series_id', 'measurement_number', 'group_id', 'surface']] + ['surface']

# %%
#Inspiration from http://searene.me/2017/12/23/Write-Machine-Learning-Algorithms-From-Scratch-Random-Forest/
#@numba.jitclass()
class tree_node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        self.category = None
        self.split_point = (None, None)
        self.split_value = None

def get_most_common_category(data):
    gdata = data[data.columns[-1]].value_counts()
    return gdata.index[0]

def get_categories(data):
    return data[data.columns[-1]].unique()

def get_gini(left, right, categories): #Try different metrics here
    left = left[left.columns[-1]].value_counts()
    right = right[right.columns[-1]].value_counts()
    gini = 0
    for group in left, right:
        if len(group) == 0:
            continue
        score = 0
        for category in categories:
            if category in group.index:
                p = group[category] / sum(group)
            else:
                p = 0
            score += p * p
        gini += (1 - score) * (sum(group) / (sum(left) + sum(right)))
    return gini

def split(data, x, y):
    split_value = data.iloc[x][y]
    left = data[data[y]<=split_value]
    right = data[data[y]>split_value]
    return left, right

def get_split_point(data, split_search, split_min_gini): #Add histogram option
    features = list(data.columns[:-1])
    categories = get_categories(data)
    x, y, gini = None, None, None
    for i_ in range(split_search):
        feature = random.choice(features) 
        i = random.choice(range(len(data)))
        left, right = split(data, i, feature)
        current_gini = get_gini(left, right, categories)
        if gini is None or current_gini < gini:
            x, y, gini = i, feature, current_gini
        if gini <= split_min_gini:
            break
    return x, y

def build_tree(data, depth, max_depth, min_size, n_sample_rate, split_search, split_min_gini):
    if depth==1: data = data.sample(frac=n_sample_rate, random_state=None).copy()
    root = tree_node(data.copy())
    x, y = get_split_point(data, split_search, split_min_gini)
    left_branch, right_branch = split(data, x, y)
    root.split_point = (x, y)
    root.split_value = root.data.iloc[x][y]
    if len(left_branch) == 0 or len(right_branch) == 0 or depth >= max_depth:
        root.category = get_most_common_category(pd.concat((left_branch, right_branch)))
        #if depth < max_depth:print(depth, root.category)
    else:
        if len(left_branch) < min_size:
            root.left = tree_node(left_branch)
            root.left.category = get_most_common_category(left_branch)
        else:
            root.left = build_tree(left_branch, depth + 1, max_depth, min_size, n_sample_rate, split_search, split_min_gini)

        if len(right_branch) < min_size:
            root.right = tree_node(right_branch)
            root.right.category = get_most_common_category(right_branch)
        else:
            root.right = build_tree(right_branch, depth + 1, max_depth, min_size, n_sample_rate, split_search, split_min_gini)
    root.data = None #clean up
    if depth == 1: print('tree created...')
    return root

def RandomForest(df, n_trees, max_depth, min_size, n_sample_rate, split_search, split_min_gini):
    #TO DO: GPU enable and add numba if possible
    p = multiprocessing.Pool(multiprocessing.cpu_count())
    trees = [[df, 1, max_depth, min_size, n_sample_rate, split_search, split_min_gini] for i in range(n_trees)]
    trees=p.starmap(build_tree, trees)
    p.close(); p.join();
    return trees

model = RandomForest(df=train[col], n_trees=14, max_depth=10, min_size=2, n_sample_rate=0.4, split_search=10, split_min_gini=0.0001)
# Out:
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...
# tree created...

# %%
def print_tree(tree, l, feature='', comment=''):
    i, feature = tree.split_point
    if tree.category != None:
        print('\t'*l, l, comment, tree.category, feature, tree.split_value)
    l += 1
    try: print_tree(tree.left, l, comment='left')
    except: pass
    try: print_tree(tree.right, l, comment='right')
    except: pass

for tree in model:
    print_tree(tree,0,comment='root')
    break
# Out:
# 									 9 left concrete orientation_W -0.065042
# 									 9 right concrete orientation_Y 0.5355
# 									 9 left tiled orientation_Z 0.14631
# 									 9 right wood linear_acceleration_aquantile(.5, 2.6488
# 									 9 left concrete linear_acceleration_skew( -0.9686729227820298
# 									 9 right soft_pvc orientation_X -0.80377
# 									 9 left concrete orientation_Z 0.0023171999999999997
# 									 9 right fine_concrete linear_acceleration_astd( 7.303434557338987
# 									 9 left fine_concrete linear_acceleration_aquantile(.5, 0.2894
# 									 9 right concrete orientation_Y -0.86693
# 									 9 left concrete orientation_Y 0.42603
# 									 9 right soft_pvc orientation_Y -0.9158700000000001
# 									 9 left soft_pvc orientation_X -0.47522
# 									 9 right tiled linear_acceleration_aquantile(.25, 1.1485400000000001
# 									 9 left soft_pvc linear_acceleration_skew( -0.439550756608559
# 									 9 right soft_pvc linear_acceleration_min( -9.1761
# 									 9 left soft_pvc angular_velocity_Y -0.023612
# 									 9 right soft_pvc linear_acceleration_quantile(.75, -0.14156999999999997
# 									 9 left soft_pvc angular_velocity_astd( 0.009395609098580747
# 									 9 right fine_concrete orientation_X 0.6259
# 									 9 left soft_pvc linear_acceleration_amax( 10.036
# 									 9 right soft_pvc orientation_W 0.11154000000000001
# 									 9 left fine_concrete orientation_Y -0.75184
# 									 9 right soft_pvc linear_acceleration_X -0.40485
# 									 9 left soft_pvc linear_acceleration_amin( 0.37253000000000003
# 									 9 right soft_pvc orientation_Z 0.12251
# 									 9 left fine_concrete orientation_W 0.10492
# 									 9 right wood linear_acceleration_quantile(.25, -5.657355
# 									 9 left hard_tiles_large_space orientation_W 0.085039
# 									 9 right soft_pvc linear_acceleration_Z -11.507
# 									 9 left fine_concrete linear_acceleration_quantile(.5, 1.1772
# 									 9 right hard_tiles_large_space linear_acceleration_amean( 5.715733333333333
# 									 9 left hard_tiles_large_space angular_velocity_asum( 0.13893
# 									 9 right concrete orientation_Y -0.62721
# 									 9 left concrete angular_velocity_Z 0.02289
# 									 9 right tiled linear_acceleration_amax( 16.31
# 									 9 left concrete linear_acceleration_quantile(.5, -2.0835
# 									 9 right soft_pvc linear_acceleration_askew( 1.6928923521627663
# 									 9 left soft_pvc orientation_Y -0.5298
# 									 9 right tiled angular_velocity_Z -0.0047326
# 									 9 left fine_concrete angular_velocity_askew( 1.4199116468202877
# 									 9 right fine_concrete angular_velocity_Y -0.055072
# 									 9 left hard_tiles_large_space orientation_Z 0.094424
# 									 9 right concrete linear_acceleration_quantile(.75, 0.32404
# 									 9 left fine_concrete orientation_X 0.97893
# 									 9 right concrete linear_acceleration_quantile(.25, -7.0976
# 									 9 left hard_tiles_large_space linear_acceleration_sum( -9.9088
# 									 9 right fine_concrete None None
# 									 9 left soft_pvc linear_acceleration_Z -10.031
# 									 9 right soft_pvc angular_velocity_amin( 0.00066161
# 									 9 left soft_pvc orientation_Y 0.15272
# 									 9 right soft_pvc orientation_Y -0.27433
# 									 9 left soft_pvc linear_acceleration_quantile(.75, 0.12415500000000002
# 									 9 right fine_concrete orientation_W 0.14429
# 									 9 left soft_pvc orientation_W 0.13922
# 									 9 right soft_pvc linear_acceleration_amean( 3.63681
# 									 9 left hard_tiles angular_velocity_sum( -0.044372344
# 									 9 right hard_tiles linear_acceleration_sum( -9.28534
# 								 8 right concrete None None
# 									 9 left soft_pvc linear_acceleration_amax( 7.7379999999999995
# 									 9 right soft_pvc orientation_Y -0.41872
# 									 9 left soft_pvc angular_velocity_X -0.023159
# 									 9 right concrete orientation_Z 0.026504000000000003
# 									 9 left soft_tiles angular_velocity_amean( 0.004937766666666667
# 									 9 right soft_tiles orientation_Y 0.22059
# 									 9 left soft_pvc orientation_Y -0.9012
# 									 9 right soft_tiles orientation_X 0.5586
# 									 9 left wood orientation_W -0.040085
# 									 9 right wood angular_velocity_quantile(.75, -0.00172405
# 									 9 left wood orientation_W -0.043301
# 									 9 right soft_tiles linear_acceleration_sum( -6.866190000000001
# 									 9 left soft_pvc orientation_W -0.1244
# 									 9 right tiled linear_acceleration_aquantile(.5, 2.9902
# 									 9 left soft_tiles linear_acceleration_astd( 4.963112933603264
# 									 9 right soft_pvc orientation_X -0.24875
# 									 9 left soft_pvc angular_velocity_amax( 0.0442
# 									 9 right soft_tiles orientation_Z -0.057998
# 									 9 left soft_pvc orientation_Z 0.06501900000000001
# 									 9 right fine_concrete linear_acceleration_quantile(.75, 2.3602800000000004
# 									 9 left soft_tiles linear_acceleration_amax( 8.8342
# 									 9 right concrete linear_acceleration_quantile(.5, 1.1498
# 									 9 left concrete orientation_Y -0.76672
# 									 9 right concrete angular_velocity_asum( 0.0517469
# 									 9 left soft_pvc angular_velocity_aquantile(.75, 0.0437395
# 									 9 right soft_pvc linear_acceleration_X 1.7566
# 									 9 left soft_pvc orientation_X -0.69079
# 									 9 right wood linear_acceleration_amin( 1.61
# 									 9 left soft_pvc orientation_W 0.13971
# 									 9 right soft_pvc orientation_Z -0.077835
# 									 9 left soft_pvc orientation_W 0.13167
# 									 9 right soft_pvc linear_acceleration_max( 4.7323
# 									 9 left soft_pvc orientation_Z -0.092914
# 									 9 right soft_pvc linear_acceleration_aquantile(.75, 6.1270500000000006
# 									 9 left hard_tiles_large_space angular_velocity_amax( 0.063501
# 									 9 right soft_pvc linear_acceleration_amin( 2.6614
# 									 9 left concrete orientation_Z 0.039719
# 									 9 right fine_concrete linear_acceleration_quantile(.75, 2.44543
# 									 9 left soft_pvc orientation_X 0.82776
# 									 9 right soft_pvc angular_velocity_askew( 1.2954217784577895
# 									 9 left soft_pvc orientation_X -0.243
# 									 9 right soft_pvc linear_acceleration_asum( 14.03481
# 									 9 left concrete orientation_Z -0.14447000000000002
# 									 9 right soft_pvc linear_acceleration_aquantile(.75, 8.24785
# 									 9 left concrete orientation_W -0.1397
# 									 9 right fine_concrete linear_acceleration_Y 3.2663
# 									 9 left soft_pvc linear_acceleration_X 1.7297
# 									 9 right soft_pvc orientation_W 0.066995
# 									 9 left soft_pvc angular_velocity_amax( 0.05425700000000001
# 									 9 right soft_pvc angular_velocity_amax( 0.0677
# 									 9 left concrete orientation_W -0.11299000000000001
# 									 9 right concrete linear_acceleration_std( 7.685902752659141
# 									 9 left concrete orientation_Z 0.01616
# 									 9 right tiled orientation_W -0.033569999999999996
# 									 9 left concrete linear_acceleration_aquantile(.5, 4.9575
# 									 9 right tiled orientation_Y 0.21547
# 									 9 left concrete angular_velocity_asum( 0.105071
# 									 9 right hard_tiles_large_space None None
# 									 9 left concrete orientation_X 0.9748399999999999
# 									 9 right hard_tiles_large_space angular_velocity_aquantile(.5, 0.011052
# 									 9 left fine_concrete linear_acceleration_Y 6.2639
# 									 9 right soft_pvc linear_acceleration_Z -7.3794
# 									 9 left concrete linear_acceleration_max( 9.1223
# 									 9 right concrete angular_velocity_skew( 0.5188290741578901
# 									 9 left tiled orientation_X 0.9788399999999999
# 									 9 right concrete orientation_Y 0.5607800000000001
# 									 9 left fine_concrete orientation_Z 0.13797
# 									 9 right tiled orientation_X -0.15114
# 									 9 left concrete linear_acceleration_quantile(.75, 0.17314999999999992
# 									 9 right concrete linear_acceleration_astd( 3.9209144982431505
# 									 9 left tiled linear_acceleration_skew( -1.5217784852508807
# 									 9 right concrete linear_acceleration_amean( 5.5323
# 									 9 left concrete orientation_X -0.86775
# 									 9 right concrete linear_acceleration_Y 3.1911
# 									 9 left concrete orientation_Y 0.44883
# 									 9 right concrete angular_velocity_sum( -0.103498
# 									 9 left concrete orientation_Z -0.12087
# 									 9 right concrete angular_velocity_aquantile(.25, 0.0260489
# 									 9 left tiled orientation_X -0.98154
# 									 9 right concrete orientation_X -0.93866
# 									 9 left carpet orientation_Z 0.053111
# 									 9 right concrete orientation_X -0.89125
# 									 9 left concrete linear_acceleration_aquantile(.75, 5.6671499999999995
# 									 9 right concrete angular_velocity_skew( 1.1670700818742437
# 									 9 left concrete orientation_W -0.04415
# 									 9 right fine_concrete orientation_Y 0.8657100000000001
# 									 9 left concrete orientation_X -0.80385
# 									 9 right tiled orientation_W -0.0451
# 									 9 left soft_pvc angular_velocity_aquantile(.5, 0.04577
# 									 9 right soft_pvc orientation_Y 0.48938999999999994
# 									 9 left fine_concrete orientation_X -0.8595
# 									 9 right soft_pvc angular_velocity_amean( 0.04449366666666666
# 									 9 left concrete orientation_X -0.43095
# 									 9 right wood angular_velocity_astd( 0.01451679752332908
# 									 9 left tiled orientation_X -0.33145
# 									 9 right fine_concrete angular_velocity_amax( 0.08495499999999999
# 									 9 left fine_concrete orientation_Y 0.9464100000000001
# 									 9 right tiled angular_velocity_asum( 0.14618
# 									 9 left tiled angular_velocity_aquantile(.75, 0.0589335
# 									 9 right tiled linear_acceleration_quantile(.75, 3.9431499999999997
# 									 9 left tiled linear_acceleration_mean( -1.6476333333333333
# 									 9 right tiled orientation_X -0.046204
# 									 9 left tiled orientation_Z 0.15106
# 									 9 right wood angular_velocity_quantile(.5, -0.043075999999999996
# 									 9 left soft_pvc linear_acceleration_quantile(.5, -0.9298700000000001
# 									 9 right fine_concrete orientation_Y 0.91217
# 									 9 left hard_tiles_large_space orientation_Z -0.11388
# 									 9 right concrete orientation_Z -0.12650999999999998
# 									 9 left wood angular_velocity_amax( 0.06479
# 									 9 right concrete orientation_W 0.1229
# 									 9 left soft_pvc linear_acceleration_Y 2.3232
# 									 9 right soft_pvc angular_velocity_sum( 0.023320999999999998
# 									 9 left concrete linear_acceleration_quantile(.75, 0.5699000000000001
# 									 9 right soft_pvc linear_acceleration_skew( -0.5681571851657556
# 									 9 left soft_pvc angular_velocity_aquantile(.75, 0.056632
# 									 9 right concrete angular_velocity_Z -0.047766
# 									 9 left tiled orientation_X 0.0082193
# 									 9 right hard_tiles_large_space linear_acceleration_Y 5.2449
# 									 9 left soft_pvc linear_acceleration_Z -7.352
# 									 9 right concrete orientation_Z 0.065719
# 									 9 left carpet orientation_Y 0.86613
# 									 9 right fine_concrete orientation_W 0.069145
# 									 9 left tiled orientation_X -0.1285
# 									 9 right carpet linear_acceleration_std( 6.865028564397966
# 									 9 left concrete orientation_X 0.008914
# 									 9 right fine_concrete angular_velocity_amax( 0.04032
# 									 9 left tiled linear_acceleration_std( 4.243832376520072
# 									 9 right concrete linear_acceleration_amin( 2.055
# 									 9 left hard_tiles_large_space orientation_Y 0.6997399999999999
# 									 9 right fine_concrete orientation_W 0.092651
# 									 9 left tiled None None
# 									 9 right wood angular_velocity_aquantile(.25, 0.027089000000000002
# 								 8 left concrete None None
# 									 9 left hard_tiles_large_space angular_velocity_quantile(.25, -0.043815599999999996
# 									 9 right tiled linear_acceleration_skew( -1.5110492636461386
# 									 9 left tiled orientation_Y 0.14127
# 									 9 right concrete linear_acceleration_skew( -1.0959363642569049
# 									 9 left tiled orientation_W -0.14456
# 									 9 right concrete angular_velocity_mean( 0.03857
# 									 9 left soft_pvc orientation_Y -0.75064
# 									 9 right soft_pvc orientation_W 0.13832
# 									 9 left soft_pvc orientation_Y -0.57773
# 									 9 right tiled linear_acceleration_amean( 4.672083333333333
# 									 9 left fine_concrete linear_acceleration_aquantile(.75, 6.7608
# 									 9 right fine_concrete orientation_Y 0.11312
# 									 9 left fine_concrete linear_acceleration_astd( 5.421996803404934
# 									 9 right fine_concrete linear_acceleration_max( 0.13061
# 									 9 left tiled linear_acceleration_aquantile(.5, 1.7458
# 									 9 right fine_concrete orientation_X 0.25198000000000004
# 									 9 left tiled linear_acceleration_amin( 1.0187
# 									 9 right soft_tiles angular_velocity_amean( 0.03725333333333333
# 									 9 left soft_pvc orientation_X 0.62185
# 									 9 right concrete orientation_Z -0.0848
# 									 9 left soft_pvc linear_acceleration_askew( -0.40582930487209684
# 									 9 right soft_pvc angular_velocity_amax( 0.047907
# 									 9 left tiled linear_acceleration_mean( -2.5797000000000003
# 									 9 right tiled angular_velocity_std( 0.06513460186669859
# 									 9 left carpet linear_acceleration_quantile(.5, -0.7944
# 									 9 right tiled orientation_Z 0.01269
# 									 9 left soft_pvc linear_acceleration_astd( 5.585708410550983
# 									 9 right soft_pvc linear_acceleration_std( 7.985809311731237
# 									 9 left soft_tiles linear_acceleration_amean( 4.2996566666666665
# 									 9 right tiled orientation_X 0.94971
# 									 9 left concrete linear_acceleration_askew( 1.659454996125359
# 									 9 right concrete angular_velocity_Z -0.011854
# 									 9 left concrete orientation_W -0.13781
# 									 9 right concrete angular_velocity_quantile(.75, 0.0636905
# 									 9 left carpet angular_velocity_mean( 0.0119538
# 									 9 right concrete angular_velocity_sum( -0.02469600000000001
# 									 9 left soft_tiles angular_velocity_Z -0.05254299999999999
# 									 9 right concrete orientation_Z 0.060467999999999994
# 									 9 left concrete linear_acceleration_quantile(.75, -0.2633
# 									 9 right soft_tiles orientation_W -0.12445999999999999
# 									 9 left soft_pvc linear_acceleration_askew( 1.35033541627869
# 									 9 right soft_pvc angular_velocity_min( -0.060707000000000004
# 									 9 left concrete linear_acceleration_quantile(.75, -0.7272525000000001
# 									 9 right carpet linear_acceleration_astd( 4.749176178959884
# 									 9 left concrete orientation_W -0.1355
# 									 9 right soft_pvc linear_acceleration_amax( 10.378
# 									 9 left concrete linear_acceleration_aquantile(.25, 3.4734
# 									 9 right concrete orientation_Z 0.062878
# 									 9 left concrete orientation_Y 0.42768999999999996
# 									 9 right fine_concrete linear_acceleration_quantile(.75, 0.41627500000000006
# 									 9 left concrete linear_acceleration_Z -11.352
# 									 9 right concrete linear_acceleration_std( 8.754551721438016
# 									 9 left fine_concrete orientation_W -0.13426
# 									 9 right fine_concrete angular_velocity_aquantile(.75, 0.077252
# 									 9 left concrete angular_velocity_amax( 0.092694
# 									 9 right concrete orientation_Y 0.6138399999999999
# 									 9 left fine_concrete linear_acceleration_sum( -7.672799999999999
# 									 9 right soft_pvc orientation_W -0.12424
# 									 9 left tiled linear_acceleration_amean( 5.858486666666667
# 									 9 right tiled angular_velocity_amax( 0.058526999999999996
# 									 9 left concrete linear_acceleration_quantile(.5, -1.8477
# 									 9 right tiled orientation_W -0.025411000000000003
# 									 9 left tiled angular_velocity_askew( 1.7038078015917133
# 									 9 right tiled angular_velocity_asum( 0.156397
# 									 9 left tiled angular_velocity_quantile(.25, -0.0172545
# 									 9 right tiled linear_acceleration_askew( -0.07369479009593345
# 									 9 left tiled orientation_X -0.9883299999999999
# 									 9 right tiled linear_acceleration_amean( 5.2415
# 									 9 left tiled linear_acceleration_Z -6.1707
# 									 9 right tiled angular_velocity_amin( 0.048514999999999996
# 									 9 left tiled linear_acceleration_aquantile(.75, 6.4957
# 									 9 right tiled linear_acceleration_mean( -2.9185466666666664
# 								 8 right tiled angular_velocity_kurtosis( 0.0
# 									 9 left tiled linear_acceleration_skew( -1.7319257513309858
# 									 9 right tiled linear_acceleration_kurtosis( 0.0
# 									 9 left tiled None None
# 									 9 right tiled angular_velocity_min( 0.0035629
# 									 9 left tiled linear_acceleration_asum( 12.1772
# 									 9 right wood linear_acceleration_aquantile(.75, 6.785550000000001
# 									 9 left tiled linear_acceleration_quantile(.5, -1.0455
# 									 9 right tiled angular_velocity_amax( 0.16384
# 									 9 left tiled angular_velocity_astd( 0.07309207224681301
# 									 9 right wood orientation_X -0.9877799999999999
# 									 9 left tiled angular_velocity_mean( -0.027174000000000004
# 									 9 right tiled linear_acceleration_amax( 8.3068
# 									 9 left tiled angular_velocity_amax( 0.15112
# 									 9 right tiled angular_velocity_X -0.065707
# 									 9 left tiled angular_velocity_aquantile(.75, 0.16139
# 									 9 right tiled linear_acceleration_aquantile(.5, 3.0701
# 								 8 left tiled linear_acceleration_aquantile(.5, 8.5581
# 									 9 left tiled orientation_Z 0.016488
# 									 9 right tiled angular_velocity_max( 0.021759999999999998
# 									 9 left tiled angular_velocity_quantile(.25, -0.078112
# 									 9 right tiled angular_velocity_astd( 0.08977394437697389
# 									 9 left tiled angular_velocity_Z 0.14138
# 									 9 right concrete linear_acceleration_amax( 11.97
# 									 9 left tiled angular_velocity_quantile(.25, -0.053511350000000006
# 									 9 right carpet linear_acceleration_quantile(.5, -0.27460999999999997
# 									 9 left tiled orientation_Z 0.0043532
# 									 9 right tiled orientation_Y 0.10951
# 									 9 left concrete linear_acceleration_Y 4.4177
# 									 9 right concrete linear_acceleration_X 2.0777
# 									 9 left concrete linear_acceleration_mean( -4.091911666666666
# 									 9 right soft_tiles linear_acceleration_amin( 0.32714
# 									 9 left soft_tiles linear_acceleration_amin( 0.30887
# 									 9 right concrete angular_velocity_aquantile(.75, 0.081894
# 									 9 left concrete orientation_Y -0.65972
# 									 9 right concrete angular_velocity_std( 0.13724685314789553
# 									 9 left hard_tiles_large_space orientation_X -0.03731
# 									 9 right fine_concrete orientation_Z -0.14768
# 									 9 left hard_tiles_large_space linear_acceleration_astd( 1.5766638145886818
# 									 9 right hard_tiles_large_space linear_acceleration_amax( 8.1708
# 									 9 left hard_tiles_large_space angular_velocity_quantile(.5, -0.033338
# 									 9 right hard_tiles_large_space linear_acceleration_skew( -1.714924577288317
# 									 9 left hard_tiles_large_space linear_acceleration_amin( 2.2969
# 									 9 right hard_tiles_large_space angular_velocity_aquantile(.5, 0.04165
# 									 9 left tiled orientation_X -0.24605
# 									 9 right concrete orientation_Z 0.037547000000000004
# 									 9 left concrete orientation_Y 0.43938
# 									 9 right concrete angular_velocity_aquantile(.25, 0.027143
# 									 9 left wood orientation_Y -0.84134
# 									 9 right concrete angular_velocity_aquantile(.75, 0.135895
# 									 9 left wood orientation_W -0.07183400000000001
# 									 9 right concrete orientation_Y -0.9385700000000001
# 									 9 left concrete angular_velocity_aquantile(.25, 0.045828495
# 									 9 right concrete linear_acceleration_amean( 5.675833333333334
# 									 9 left concrete orientation_Z 0.12611
# 									 9 right wood linear_acceleration_X -2.1472
# 									 9 left fine_concrete orientation_Z 0.14317
# 									 9 right concrete orientation_Y 0.48823999999999995
# 									 9 left tiled orientation_X 0.14003
# 									 9 right hard_tiles_large_space linear_acceleration_mean( -5.8755
# 									 9 left concrete linear_acceleration_Z -1.1977
# 									 9 right soft_pvc orientation_X 0.5102899999999999
# 									 9 left soft_tiles linear_acceleration_quantile(.25, -4.0222549999999995
# 									 9 right tiled orientation_X 0.32295
# 									 9 left concrete angular_velocity_quantile(.75, -0.09711
# 									 9 right soft_pvc linear_acceleration_amin( 0.25911
# 									 9 left soft_pvc linear_acceleration_mean( -1.68476
# 									 9 right concrete linear_acceleration_quantile(.5, -0.14007999999999998
# 									 9 left concrete angular_velocity_Z -0.0022500999999999997
# 									 9 right fine_concrete linear_acceleration_quantile(.5, -1.5674
# 									 9 left fine_concrete linear_acceleration_max( 1.5463
# 									 9 right concrete linear_acceleration_quantile(.75, 2.66046
# 									 9 left concrete orientation_Z 0.07316399999999999
# 									 9 right tiled angular_velocity_amean( 0.08873266666666667
# 									 9 left tiled linear_acceleration_aquantile(.5, 3.7294
# 									 9 right tiled orientation_X -0.38637
# 									 9 left hard_tiles_large_space angular_velocity_mean( -0.03131366666666666
# 									 9 right hard_tiles_large_space angular_velocity_mean( -0.04048433333333334
# 									 9 left wood angular_velocity_aquantile(.75, 0.08226900000000001
# 									 9 right fine_concrete angular_velocity_quantile(.75, 0.02309465
# 									 9 left wood orientation_W 0.037703
# 									 9 right hard_tiles_large_space linear_acceleration_amax( 7.2491
# 									 9 left hard_tiles_large_space orientation_Z 0.10128
# 									 9 right hard_tiles_large_space angular_velocity_asum( 0.28697500000000004
# 									 9 left concrete linear_acceleration_asum( 14.77009
# 									 9 right concrete linear_acceleration_std( 5.058210580827968
# 									 9 left tiled orientation_X -0.12232
# 									 9 right carpet linear_acceleration_kurtosis( 0.0
# 									 9 left concrete angular_velocity_skew( -0.5169281693761874
# 									 9 right hard_tiles_large_space orientation_Z 0.096208
# 									 9 left tiled angular_velocity_X 0.22780999999999998
# 									 9 right tiled orientation_Z 0.14773
# 									 9 left concrete angular_velocity_sum( 0.147541
# 									 9 right concrete linear_acceleration_max( 5.9688
# 									 9 left concrete orientation_Z 0.13192
# 									 9 right tiled angular_velocity_Y -0.029580000000000002
# 									 9 left fine_concrete angular_velocity_amin( 0.006689100000000001
# 									 9 right tiled angular_velocity_asum( 0.267225
# 									 9 left hard_tiles_large_space orientation_W 0.11867
# 									 9 right hard_tiles_large_space linear_acceleration_mean( 0.3206666666666666
# 									 9 left fine_concrete linear_acceleration_Y 3.198
# 									 9 right concrete angular_velocity_quantile(.75, 0.11726650000000001
# 									 9 left concrete angular_velocity_asum( 0.40162000000000003
# 									 9 right wood None None
# 									 9 left hard_tiles_large_space linear_acceleration_aquantile(.5, 2.2785
# 									 9 right hard_tiles_large_space linear_acceleration_aquantile(.5, 4.725
# 									 9 left wood linear_acceleration_aquantile(.25, 2.0631500000000003
# 									 9 right hard_tiles_large_space angular_velocity_askew( 0.7882367045821767
# 									 9 left wood linear_acceleration_amean( 3.80302
# 									 9 right wood linear_acceleration_mean( -0.725123333333333
# 									 9 left wood orientation_X -0.54579
# 									 9 right wood orientation_X 0.54485
# 									 9 left tiled angular_velocity_mean( 0.058746999999999994
# 									 9 right tiled orientation_Y 0.86435
# 									 9 left tiled orientation_Y 0.8174600000000001
# 									 9 right tiled linear_acceleration_amax( 17.058
# 									 9 left carpet linear_acceleration_mean( -1.649
# 									 9 right concrete angular_velocity_min( -0.7612300000000001
# 									 9 left concrete angular_velocity_mean( -0.156266
# 									 9 right concrete linear_acceleration_amean( 2.64163
# 									 9 left concrete linear_acceleration_aquantile(.25, 1.08499
# 									 9 right concrete orientation_X -0.38372
# 									 9 left concrete angular_velocity_X -0.052899
# 									 9 right concrete linear_acceleration_quantile(.25, -6.42614
# 									 9 left tiled angular_velocity_amin( 0.037993
# 									 9 right tiled orientation_W -0.048962
# 									 9 left wood angular_velocity_amin( 0.050649
# 									 9 right soft_tiles angular_velocity_Z -0.38093
# 									 9 left wood orientation_Z -0.1053
# 									 9 right soft_pvc orientation_Y 0.75893
# 									 9 left wood orientation_W 0.096355
# 									 9 right wood angular_velocity_quantile(.25, -0.38683249999999997
# 									 9 left hard_tiles_large_space linear_acceleration_asum( 13.1746
# 									 9 right hard_tiles_large_space linear_acceleration_asum( 6.45613
# 									 9 left hard_tiles_large_space angular_velocity_aquantile(.5, 0.17677
# 									 9 right concrete angular_velocity_Z -0.66351
# 									 9 left concrete angular_velocity_mean( -0.12668000000000001
# 									 9 right concrete angular_velocity_Z 0.13124
# 									 9 left hard_tiles_large_space linear_acceleration_Z -4.9019
# 									 9 right hard_tiles_large_space orientation_Z 0.052073
# 									 9 left concrete angular_velocity_kurtosis( 0.0
# 									 9 right concrete linear_acceleration_kurtosis( 0.0
# 									 9 left concrete orientation_W 0.10371
# 									 9 right concrete angular_velocity_aquantile(.25, 0.1598135
# 									 9 left concrete angular_velocity_Z -0.2614
# 									 9 right soft_tiles orientation_X 0.9783299999999999
# 									 9 left concrete orientation_W 0.14022
# 									 9 right soft_pvc angular_velocity_amean( 0.29558
# 									 9 left wood linear_acceleration_quantile(.75, 0.7009099999999999
# 									 9 right wood orientation_W -0.014324000000000002
# 									 9 left wood orientation_Y 0.58523
# 									 9 right wood linear_acceleration_askew( 1.5275164625024418
# 									 9 left wood linear_acceleration_max( 1.2166
# 									 9 right wood angular_velocity_std( 0.4255442835726187
# 									 9 left wood orientation_Y -0.81745
# 									 9 right wood angular_velocity_quantile(.5, -0.037096
# 									 9 left soft_pvc orientation_X 0.9853799999999999
# 									 9 right tiled angular_velocity_amean( 0.207738
# 									 9 left wood angular_velocity_aquantile(.75, 0.26779
# 									 9 right wood linear_acceleration_aquantile(.5, 4.8323
# 									 9 left hard_tiles angular_velocity_amax( 0.42391
# 									 9 right wood angular_velocity_astd( 0.3241447432907095
# 									 9 left wood angular_velocity_astd( 0.20410455823425402
# 									 9 right wood angular_velocity_amax( 0.47523999999999994
# 									 9 left concrete orientation_Y 0.33055999999999996
# 									 9 right concrete angular_velocity_skew( 1.1103661402565288
# 									 9 left concrete angular_velocity_quantile(.5, -0.03781
# 									 9 right tiled angular_velocity_amean( 0.3060533333333333
# 									 9 left hard_tiles_large_space angular_velocity_amax( 0.29863
# 									 9 right tiled angular_velocity_Y -0.1344
# 									 9 left hard_tiles_large_space orientation_X 0.48493
# 									 9 right hard_tiles_large_space orientation_Y 0.6109
# 									 9 left wood orientation_X -0.9677899999999999
# 									 9 right wood linear_acceleration_max( 3.6049
# 									 9 left wood angular_velocity_sum( 0.508861
# 									 9 right wood angular_velocity_Z 0.17565
# 									 9 left hard_tiles_large_space linear_acceleration_min( -6.7566
# 									 9 right hard_tiles_large_space linear_acceleration_amax( 7.5048
# 									 9 left hard_tiles_large_space orientation_Y 0.5989800000000001
# 									 9 right wood orientation_Z 0.020086
# 									 9 left tiled orientation_X -0.9807799999999999
# 									 9 right tiled angular_velocity_std( 0.4056354074979813
# 									 9 left hard_tiles_large_space orientation_Z -0.12365
# 									 9 right concrete linear_acceleration_quantile(.75, 0.67435
# 									 9 left concrete angular_velocity_astd( 0.26134725564275585
# 									 9 right wood angular_velocity_aquantile(.75, 0.35789
# 									 9 left tiled linear_acceleration_mean( -3.58044
# 									 9 right tiled orientation_W -0.15029
# 									 9 left tiled angular_velocity_aquantile(.75, 0.23571000000000003
# 									 9 right concrete orientation_Y -0.8516
# 									 9 left concrete angular_velocity_quantile(.5, 0.06547599999999999
# 									 9 right concrete angular_velocity_Z 0.18367
# 									 9 left hard_tiles_large_space orientation_Z -0.10818
# 									 9 right concrete linear_acceleration_aquantile(.75, 7.2416
# 									 9 left concrete angular_velocity_std( 0.5076839411812564
# 									 9 right tiled linear_acceleration_asum( 16.1768
# 									 9 left tiled orientation_Z 0.02394
# 									 9 right wood angular_velocity_quantile(.75, 0.18979000000000001
# 									 9 left tiled linear_acceleration_Y -0.00076032
# 									 9 right concrete angular_velocity_mean( 0.07647999999999999
# 									 9 left hard_tiles_large_space angular_velocity_skew( 0.7314290735334182
# 									 9 right concrete orientation_X 0.93615
# 									 9 left hard_tiles_large_space linear_acceleration_mean( -3.05904
# 									 9 right hard_tiles_large_space orientation_X 0.95226
# 									 9 left concrete angular_velocity_astd( 0.16392391842461554
# 									 9 right concrete angular_velocity_Z -0.20594
# 									 9 left concrete angular_velocity_Y -0.21126
# 									 9 right concrete angular_velocity_amax( 0.49394
# 									 9 left hard_tiles_large_space angular_velocity_min( -0.23983000000000002
# 									 9 right hard_tiles_large_space linear_acceleration_std( 9.32453309572835
# 									 9 left concrete orientation_W -0.11508
# 									 9 right hard_tiles_large_space angular_velocity_Y 0.081338
# 									 9 left concrete orientation_W -0.06617
# 									 9 right wood linear_acceleration_min( -13.232000000000001
# 									 9 left tiled angular_velocity_Z -0.20065999999999998
# 									 9 right tiled orientation_Y 0.94878
# 									 9 left wood angular_velocity_max( 0.26766
# 									 9 right wood orientation_X -0.37116
# 									 9 left hard_tiles_large_space linear_acceleration_std( 11.0066645445854
# 									 9 right wood linear_acceleration_aquantile(.25, 4.4438
# 									 9 left wood linear_acceleration_amax( 8.3111
# 									 9 right wood angular_velocity_aquantile(.25, 0.14284550000000001
# 									 9 left fine_concrete angular_velocity_asum( 0.7191700000000001
# 									 9 right tiled linear_acceleration_aquantile(.75, 7.427650000000001
# 									 9 left concrete angular_velocity_Z -0.51293
# 									 9 right wood angular_velocity_mean( 0.07177699999999998
# 									 9 left hard_tiles_large_space linear_acceleration_amean( 7.722366666666666
# 									 9 right carpet linear_acceleration_quantile(.25, -15.484300000000001
# 									 9 left wood linear_acceleration_std( 9.06104976758396
# 									 9 right hard_tiles_large_space orientation_Y 0.94501
# 									 9 left carpet linear_acceleration_asum( 26.489800000000002
# 									 9 right carpet orientation_Y 0.9488700000000001
# 									 9 left wood angular_velocity_amean( 0.3700571666666667
# 									 9 right fine_concrete orientation_X 0.037727
# 									 9 left hard_tiles_large_space linear_acceleration_Z -9.4377
# 									 9 right carpet orientation_Z 0.1516
# 									 9 left wood angular_velocity_sum( 0.4330399999999999
# 									 9 right carpet angular_velocity_amean( 0.3832533333333333
# 									 9 left fine_concrete linear_acceleration_asum( 14.29164
# 									 9 right fine_concrete linear_acceleration_Z -11.609000000000002
# 									 9 left wood angular_velocity_aquantile(.5, 0.17069
# 									 9 right wood orientation_W 0.025525
# 									 9 left wood linear_acceleration_X 1.3867
# 									 9 right wood linear_acceleration_amax( 13.014000000000001

# %%
#@numba.jit()
def predict_tree(tree, r):
    if tree.category is not None:
        return tree.category
    i, feature = tree.split_point
    split_value = tree.split_value
    if r[feature] <= split_value:
        return predict_tree(tree.left, r)
    else:
        return predict_tree(tree.right, r)

#@numba.jit()
def predict(trees, r):
    prediction = []
    for tree in trees:
        prediction.append(predict_tree(tree, r))
    return max(set(prediction), key=prediction.count)

def mpredict_apply(df, model, col, target_name):
    df = pd.DataFrame(df)
    df[target_name] = df[col].progress_apply(lambda r: predict(model, r), axis=1).values
    return df

def mpredict(df, model, col, target_name, split):
    p = multiprocessing.Pool(multiprocessing.cpu_count())
    df = np.array_split(df, split)
    df = [[df_, model, col, target_name] for df_ in df]
    df = p.starmap(mpredict_apply, df)
    df = pd.concat(df, axis=0, ignore_index=True).reset_index(drop=True)
    p.close(); p.join()
    return df

val = train.tail(87680)
val = mpredict(val, model, col, 'surface2', split=4)
print('Accuracy Score: ', np.mean(val['surface'] ==val['surface2']))
# Out:
# 100%|██████████| 21920/21920 [00:41<00:00, 523.58it/s]
# 100%|██████████| 21920/21920 [00:42<00:00, 521.20it/s]
# 100%|██████████| 21920/21920 [00:42<00:00, 521.25it/s]
# 100%|██████████| 21920/21920 [00:42<00:00, 514.57it/s]
# Accuracy Score:  0.5954037408759124

# %%
test = mpredict(test, model, col, 'surface', split=4)
sub = test.groupby(by=['series_id', 'surface'], as_index=False)['row_id'].count()
sub = sub.sort_values(by=['series_id', 'surface', 'row_id'], ascending=[True, True, False]).reset_index(drop=True)
sub.drop_duplicates(subset=['series_id'], keep='first', inplace=True)
sub[['series_id', 'surface']].to_csv('submission.csv', index=False)
# Out:
#  30%|██▉       | 36511/122112 [01:13<02:41, 529.94it/s]
