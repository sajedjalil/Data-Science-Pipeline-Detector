# %%
import os
from time import time

import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline
import seaborn as sns
from seaborn import countplot,lineplot, barplot

import numpy as np 
import pandas as pd 

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
from sklearn.metrics import accuracy_score

from scipy import stats
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from numba import jit
import itertools

from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold

import warnings
warnings.filterwarnings('ignore')
import gc
gc.enable()

# !ls ../input/
# Out:
# X_test.csv  X_train.csv  sample_submission.csv	y_train.csv

# %%
train_raw = pd.read_csv('../input/X_train.csv')
test_raw = pd.read_csv('../input/X_test.csv')
target_raw = pd.read_csv('../input/y_train.csv')

# %%
def quaternion_to_euler(x, y, z, w):
    import math
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z

# %%
def fe_step0 (actual):
    
    # https://www.mathworks.com/help/aeroblks/quaternionnorm.html
    # https://www.mathworks.com/help/aeroblks/quaternionmodulus.html
    # https://www.mathworks.com/help/aeroblks/quaternionnormalize.html
        
    actual['norm_quat'] = (actual['orientation_X']**2 + actual['orientation_Y']**2 + actual['orientation_Z']**2 + actual['orientation_W']**2)
    actual['mod_quat'] = (actual['norm_quat'])**0.5
    actual['norm_X'] = actual['orientation_X'] / actual['mod_quat']
    actual['norm_Y'] = actual['orientation_Y'] / actual['mod_quat']
    actual['norm_Z'] = actual['orientation_Z'] / actual['mod_quat']
    actual['norm_W'] = actual['orientation_W'] / actual['mod_quat']
    
    return actual

# %%
train_raw = fe_step0(train_raw)
test_raw = fe_step0(test_raw)

# %%
def fe_step1 (actual):
    """Quaternions to Euler Angles"""
    
    x, y, z, w = actual['norm_X'].tolist(), actual['norm_Y'].tolist(), actual['norm_Z'].tolist(), actual['norm_W'].tolist()
    nx, ny, nz = [], [], []
    for i in range(len(x)):
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx.append(xx)
        ny.append(yy)
        nz.append(zz)
    
    actual['euler_x'] = nx
    actual['euler_y'] = ny
    actual['euler_z'] = nz
    return actual

# %%
train_raw = fe_step1(train_raw)
test_raw = fe_step1(test_raw)

# %%
def feat_eng(data):
    
    df = pd.DataFrame()
    data['totl_anglr_vel'] = (data['angular_velocity_X']**2 + data['angular_velocity_Y']**2 + data['angular_velocity_Z']**2)** 0.5
    data['totl_linr_acc'] = (data['linear_acceleration_X']**2 + data['linear_acceleration_Y']**2 + data['linear_acceleration_Z']**2)**0.5
    data['totl_xyz'] = (data['orientation_X']**2 + data['orientation_Y']**2 + data['orientation_Z']**2)**0.5
    data['acc_vs_vel'] = data['totl_linr_acc'] / data['totl_anglr_vel']
    
    def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    for col in data.columns:
        if col in ['row_id','series_id','measurement_number']:
            continue
        df[col + '_mean'] = data.groupby(['series_id'])[col].mean()
        df[col + '_median'] = data.groupby(['series_id'])[col].median()
        df[col + '_max'] = data.groupby(['series_id'])[col].max()
        df[col + '_min'] = data.groupby(['series_id'])[col].min()
        df[col + '_std'] = data.groupby(['series_id'])[col].std()
        df[col + '_range'] = df[col + '_max'] - df[col + '_min']
        df[col + '_maxtoMin'] = df[col + '_max'] / df[col + '_min']
        df[col + '_mean_abs_chg'] = data.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        df[col + '_mean_change_of_abs_change'] = data.groupby('series_id')[col].apply(mean_change_of_abs_change)
        df[col + '_abs_max'] = data.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        df[col + '_abs_min'] = data.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        df[col + '_abs_avg'] = (df[col + '_abs_min'] + df[col + '_abs_max'])/2
    return df

# %%
train_raw = feat_eng(train_raw)
test_raw = feat_eng(test_raw)

# %%
train_raw.fillna(0,inplace=True)
test_raw.fillna(0,inplace=True)
train_raw.replace(-np.inf,0,inplace=True)
train_raw.replace(np.inf,0,inplace=True)
test_raw.replace(-np.inf,0,inplace=True)
test_raw.replace(np.inf,0,inplace=True)

# %%
target_raw['surface'] = le.fit_transform(target_raw['surface'])

# %%
train_df = pd.merge(train_raw,target_raw,on='series_id')
train_df.drop('group_id', axis=1, inplace=True)
features = list(train_df.columns.values[1:])
features.remove('surface')

X = train_df[features].values
y = pd.DataFrame(train_df['surface']).values

test = test_raw[features].values

submission = pd.DataFrame()
submission['series_id'] = test_raw.index.values
submission['target'] = ""

# %%
def runXGB(train_X, train_y, validation_X, validation_y, test_X):
    param = {}
    param['num_class'] = 9
    param['objective'] = 'multi:softmax'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['gamma'] = 0
    param['eval_metric'] = "merror"
    param['min_child_weight'] = 3
    param['max_delta_step'] = 1
    param['subsample'] = 0.9
    param['colsample_bytree'] = 0.4
    param['colsample_bylevel'] = 0.6
    param['colsample_bynode'] = 0.5
    param['lambda'] = 0
    param['alpha'] = 0
    param['seed'] = 0
    num_rounds = 500

    plst = list(param.items())

    xgtrain = xgb.DMatrix(train_X, label = train_y)
    xgcv = xgb.DMatrix(validation_X, label = validation_y)
    xgtest = xgb.DMatrix(test_X)

    evallist = [(xgcv,'eval')]
    model = xgb.train(plst, xgtrain, num_rounds, evallist, early_stopping_rounds = 100)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
kfold = 7
skf = StratifiedKFold(n_splits=kfold, shuffle=True, random_state=42)

for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    submission = pd.DataFrame()
    submission['series_id'] = test_raw.index.values
    submission['surface' + str(i+1)] = ""
    
    print('[Fold %d/%d]' % (i + 1, kfold))
    X_train, X_valid = X[train_index], X[test_index]
    y_train, y_valid = y[train_index], y[test_index]
    
    preds, model = runXGB(X_train, y_train, X_valid, y_valid, test)
    
    submission['surface' + str(i+1)] = preds
    
    submission.to_csv('submission_' + str(i+1) + '.csv', index=False)
# Out:
# [Fold 1/7]
# [0]	eval-merror:0.310786
# Will train until eval-merror hasn't improved in 100 rounds.
# [1]	eval-merror:0.244973
# [2]	eval-merror:0.230347
# [3]	eval-merror:0.201097
# [4]	eval-merror:0.201097
# [5]	eval-merror:0.193784
# [6]	eval-merror:0.184644
# [7]	eval-merror:0.180987
# [8]	eval-merror:0.177331
# [9]	eval-merror:0.171846
# [10]	eval-merror:0.170018
# [11]	eval-merror:0.159049
# [12]	eval-merror:0.159049
# [13]	eval-merror:0.151737
# [14]	eval-merror:0.146252
# [15]	eval-merror:0.144424
# [16]	eval-merror:0.142596
# [17]	eval-merror:0.137112
# [18]	eval-merror:0.133455
# [19]	eval-merror:0.129799
# [20]	eval-merror:0.127971
# [21]	eval-merror:0.129799
# [22]	eval-merror:0.129799
# [23]	eval-merror:0.126143
# [24]	eval-merror:0.124314
# [25]	eval-merror:0.122486
# [26]	eval-merror:0.11883
# [27]	eval-merror:0.120658
# [28]	eval-merror:0.122486
# [29]	eval-merror:0.115174
# [30]	eval-merror:0.113346
# [31]	eval-merror:0.111517
# [32]	eval-merror:0.111517
# [33]	eval-merror:0.115174
# [34]	eval-merror:0.111517
# [35]	eval-merror:0.115174
# [36]	eval-merror:0.113346
# [37]	eval-merror:0.107861
# [38]	eval-merror:0.107861
# [39]	eval-merror:0.106033
# [40]	eval-merror:0.100548
# [41]	eval-merror:0.09872
# [42]	eval-merror:0.100548
# [43]	eval-merror:0.09872
# [44]	eval-merror:0.096892
# [45]	eval-merror:0.095064
# [46]	eval-merror:0.093236
# [47]	eval-merror:0.093236
# [48]	eval-merror:0.093236
# [49]	eval-merror:0.091408
# [50]	eval-merror:0.091408
# [51]	eval-merror:0.091408
# [52]	eval-merror:0.091408
# [53]	eval-merror:0.08958
# [54]	eval-merror:0.091408
# [55]	eval-merror:0.08958
# [56]	eval-merror:0.08958
# [57]	eval-merror:0.08958
# [58]	eval-merror:0.08958
# [59]	eval-merror:0.08958
# [60]	eval-merror:0.08958
# [61]	eval-merror:0.087751
# [62]	eval-merror:0.087751
# [63]	eval-merror:0.087751
# [64]	eval-merror:0.085923
# [65]	eval-merror:0.087751
# [66]	eval-merror:0.087751
# [67]	eval-merror:0.087751
# [68]	eval-merror:0.087751
# [69]	eval-merror:0.085923
# [70]	eval-merror:0.087751
# [71]	eval-merror:0.084095
# [72]	eval-merror:0.084095
# [73]	eval-merror:0.082267
# [74]	eval-merror:0.080439
# [75]	eval-merror:0.078611
# [76]	eval-merror:0.078611
# [77]	eval-merror:0.080439
# [78]	eval-merror:0.082267
# [79]	eval-merror:0.078611
# [80]	eval-merror:0.078611
# [81]	eval-merror:0.078611
# [82]	eval-merror:0.078611
# [83]	eval-merror:0.078611
# [84]	eval-merror:0.076782
# [85]	eval-merror:0.076782
# [86]	eval-merror:0.076782
# [87]	eval-merror:0.078611
# [88]	eval-merror:0.078611
# [89]	eval-merror:0.078611
# [90]	eval-merror:0.078611
# [91]	eval-merror:0.078611
# [92]	eval-merror:0.078611
# [93]	eval-merror:0.076782
# [94]	eval-merror:0.076782
# [95]	eval-merror:0.076782
# [96]	eval-merror:0.076782
# [97]	eval-merror:0.074954
# [98]	eval-merror:0.074954
# [99]	eval-merror:0.076782
# [100]	eval-merror:0.076782
# [101]	eval-merror:0.073126
# [102]	eval-merror:0.073126
# [103]	eval-merror:0.073126
# [104]	eval-merror:0.073126
# [105]	eval-merror:0.071298
# [106]	eval-merror:0.071298
# [107]	eval-merror:0.071298
# [108]	eval-merror:0.071298
# [109]	eval-merror:0.071298
# [110]	eval-merror:0.073126
# [111]	eval-merror:0.073126
# [112]	eval-merror:0.071298
# [113]	eval-merror:0.071298
# [114]	eval-merror:0.071298
# [115]	eval-merror:0.071298
# [116]	eval-merror:0.071298
# [117]	eval-merror:0.073126
# [118]	eval-merror:0.071298
# [119]	eval-merror:0.06947
# [120]	eval-merror:0.06947
# [121]	eval-merror:0.067642
# [122]	eval-merror:0.067642
# [123]	eval-merror:0.065814
# [124]	eval-merror:0.065814
# [125]	eval-merror:0.067642
# [126]	eval-merror:0.067642
# [127]	eval-merror:0.067642
# [128]	eval-merror:0.065814
# [129]	eval-merror:0.062157
# [130]	eval-merror:0.063985
# [131]	eval-merror:0.063985
# [132]	eval-merror:0.063985
# [133]	eval-merror:0.065814
# [134]	eval-merror:0.065814
# [135]	eval-merror:0.065814
# [136]	eval-merror:0.065814
# [137]	eval-merror:0.063985
# [138]	eval-merror:0.067642
# [139]	eval-merror:0.067642
# [140]	eval-merror:0.067642
# [141]	eval-merror:0.067642
# [142]	eval-merror:0.063985
# [143]	eval-merror:0.063985
# [144]	eval-merror:0.065814
# [145]	eval-merror:0.063985
# [146]	eval-merror:0.065814
# [147]	eval-merror:0.065814
# [148]	eval-merror:0.063985
# [149]	eval-merror:0.065814
# [150]	eval-merror:0.065814
# [151]	eval-merror:0.065814
# [152]	eval-merror:0.065814
# [153]	eval-merror:0.065814
# [154]	eval-merror:0.065814
# [155]	eval-merror:0.065814
# [156]	eval-merror:0.065814
# [157]	eval-merror:0.065814
# [158]	eval-merror:0.065814
# [159]	eval-merror:0.065814
# [160]	eval-merror:0.065814
# [161]	eval-merror:0.065814
# [162]	eval-merror:0.065814
# [163]	eval-merror:0.065814
# [164]	eval-merror:0.065814
# [165]	eval-merror:0.065814
# [166]	eval-merror:0.065814
# [167]	eval-merror:0.065814
# [168]	eval-merror:0.065814
# [169]	eval-merror:0.065814
# [170]	eval-merror:0.065814
# [171]	eval-merror:0.065814
# [172]	eval-merror:0.063985
# [173]	eval-merror:0.063985
# [174]	eval-merror:0.063985
# [175]	eval-merror:0.063985
# [176]	eval-merror:0.063985
# [177]	eval-merror:0.063985
# [178]	eval-merror:0.063985
# [179]	eval-merror:0.063985
# [180]	eval-merror:0.063985
# [181]	eval-merror:0.063985
# [182]	eval-merror:0.063985
# [183]	eval-merror:0.063985
# [184]	eval-merror:0.063985
# [185]	eval-merror:0.063985
# [186]	eval-merror:0.063985
# [187]	eval-merror:0.062157
# [188]	eval-merror:0.063985
# [189]	eval-merror:0.063985
# [190]	eval-merror:0.065814
# [191]	eval-merror:0.065814
# [192]	eval-merror:0.065814
# [193]	eval-merror:0.065814
# [194]	eval-merror:0.065814
# [195]	eval-merror:0.065814
# [196]	eval-merror:0.065814
# [197]	eval-merror:0.065814
# [198]	eval-merror:0.065814
# [199]	eval-merror:0.065814
# [200]	eval-merror:0.065814
# [201]	eval-merror:0.065814
# [202]	eval-merror:0.063985
# [203]	eval-merror:0.067642
# [204]	eval-merror:0.065814
# [205]	eval-merror:0.065814
# [206]	eval-merror:0.063985
# [207]	eval-merror:0.065814
# [208]	eval-merror:0.067642
# [209]	eval-merror:0.063985
# [210]	eval-merror:0.065814
# [211]	eval-merror:0.065814
# [212]	eval-merror:0.063985
# [213]	eval-merror:0.065814
# [214]	eval-merror:0.06947
# [215]	eval-merror:0.065814
# [216]	eval-merror:0.067642
# [217]	eval-merror:0.067642
# [218]	eval-merror:0.067642
# [219]	eval-merror:0.067642
# [220]	eval-merror:0.067642
# [221]	eval-merror:0.067642
# [222]	eval-merror:0.067642
# [223]	eval-merror:0.067642
# [224]	eval-merror:0.067642
# [225]	eval-merror:0.067642
# [226]	eval-merror:0.067642
# [227]	eval-merror:0.067642
# [228]	eval-merror:0.067642
# [229]	eval-merror:0.067642
# Stopping. Best iteration:
# [129]	eval-merror:0.062157
#
# [Fold 2/7]
# [0]	eval-merror:0.341865
# Will train until eval-merror hasn't improved in 100 rounds.
# [1]	eval-merror:0.250457
# [2]	eval-merror:0.246801
# [3]	eval-merror:0.221207
# [4]	eval-merror:0.212066
# [5]	eval-merror:0.191956
# [6]	eval-merror:0.197441
# [7]	eval-merror:0.182815
# [8]	eval-merror:0.177331
# [9]	eval-merror:0.175503
# [10]	eval-merror:0.171846
# [11]	eval-merror:0.151737
# [12]	eval-merror:0.149909
# [13]	eval-merror:0.142596
# [14]	eval-merror:0.140768
# [15]	eval-merror:0.140768
# [16]	eval-merror:0.137112
# [17]	eval-merror:0.131627
# [18]	eval-merror:0.133455
# [19]	eval-merror:0.127971
# [20]	eval-merror:0.126143
# [21]	eval-merror:0.122486
# [22]	eval-merror:0.11883
# [23]	eval-merror:0.117002
# [24]	eval-merror:0.111517
# [25]	eval-merror:0.109689
# [26]	eval-merror:0.113346
# [27]	eval-merror:0.109689
# [28]	eval-merror:0.100548
# [29]	eval-merror:0.104205
# [30]	eval-merror:0.104205
# [31]	eval-merror:0.104205
# [32]	eval-merror:0.102377
# [33]	eval-merror:0.096892
# [34]	eval-merror:0.09872
# [35]	eval-merror:0.096892
# [36]	eval-merror:0.095064
# [37]	eval-merror:0.095064
# [38]	eval-merror:0.095064
# [39]	eval-merror:0.095064
# [40]	eval-merror:0.093236
# [41]	eval-merror:0.093236
# [42]	eval-merror:0.093236
# [43]	eval-merror:0.095064
# [44]	eval-merror:0.095064
# [45]	eval-merror:0.095064
# [46]	eval-merror:0.093236
# [47]	eval-merror:0.091408
# [48]	eval-merror:0.091408
# [49]	eval-merror:0.091408
# [50]	eval-merror:0.091408
# [51]	eval-merror:0.087751
# [52]	eval-merror:0.087751
# [53]	eval-merror:0.08958
# [54]	eval-merror:0.08958
# [55]	eval-merror:0.08958
# [56]	eval-merror:0.087751
# [57]	eval-merror:0.084095
# [58]	eval-merror:0.084095
# [59]	eval-merror:0.082267
# [60]	eval-merror:0.084095
# [61]	eval-merror:0.082267
# [62]	eval-merror:0.082267
# [63]	eval-merror:0.082267
# [64]	eval-merror:0.080439
# [65]	eval-merror:0.076782
# [66]	eval-merror:0.076782
# [67]	eval-merror:0.076782
# [68]	eval-merror:0.076782
# [69]	eval-merror:0.076782
# [70]	eval-merror:0.076782
# [71]	eval-merror:0.076782
# [72]	eval-merror:0.078611
# [73]	eval-merror:0.076782
# [74]	eval-merror:0.076782
# [75]	eval-merror:0.076782
# [76]	eval-merror:0.076782
# [77]	eval-merror:0.078611
# [78]	eval-merror:0.076782
# [79]	eval-merror:0.080439
# [80]	eval-merror:0.080439
# [81]	eval-merror:0.080439
# [82]	eval-merror:0.080439
# [83]	eval-merror:0.078611
# [84]	eval-merror:0.078611
# [85]	eval-merror:0.078611
# [86]	eval-merror:0.078611
# [87]	eval-merror:0.078611
# [88]	eval-merror:0.078611
# [89]	eval-merror:0.078611
# [90]	eval-merror:0.078611
# [91]	eval-merror:0.078611
# [92]	eval-merror:0.080439
# [93]	eval-merror:0.078611
# [94]	eval-merror:0.078611
# [95]	eval-merror:0.078611
# [96]	eval-merror:0.078611
# [97]	eval-merror:0.080439
# [98]	eval-merror:0.080439
# [99]	eval-merror:0.080439
# [100]	eval-merror:0.080439
# [101]	eval-merror:0.078611
# [102]	eval-merror:0.078611
# [103]	eval-merror:0.078611
# [104]	eval-merror:0.078611
# [105]	eval-merror:0.078611
# [106]	eval-merror:0.078611
# [107]	eval-merror:0.078611
# [108]	eval-merror:0.078611
# [109]	eval-merror:0.078611
# [110]	eval-merror:0.078611
# [111]	eval-merror:0.078611
# [112]	eval-merror:0.078611
# [113]	eval-merror:0.078611
# [114]	eval-merror:0.078611
# [115]	eval-merror:0.078611
# [116]	eval-merror:0.078611
# [117]	eval-merror:0.078611
# [118]	eval-merror:0.078611
# [119]	eval-merror:0.078611
# [120]	eval-merror:0.078611
# [121]	eval-merror:0.078611
# [122]	eval-merror:0.078611
# [123]	eval-merror:0.076782
# [124]	eval-merror:0.078611
# [125]	eval-merror:0.074954
# [126]	eval-merror:0.074954
# [127]	eval-merror:0.074954
# [128]	eval-merror:0.074954
# [129]	eval-merror:0.073126
# [130]	eval-merror:0.074954
# [131]	eval-merror:0.076782
# [132]	eval-merror:0.073126
# [133]	eval-merror:0.073126
# [134]	eval-merror:0.074954
# [135]	eval-merror:0.074954
# [136]	eval-merror:0.074954
# [137]	eval-merror:0.073126
# [138]	eval-merror:0.074954
# [139]	eval-merror:0.074954
# [140]	eval-merror:0.074954
# [141]	eval-merror:0.071298
# [142]	eval-merror:0.073126
# [143]	eval-merror:0.071298
# [144]	eval-merror:0.071298
# [145]	eval-merror:0.071298
# [146]	eval-merror:0.071298
# [147]	eval-merror:0.071298
# [148]	eval-merror:0.071298
# [149]	eval-merror:0.073126
# [150]	eval-merror:0.073126
# [151]	eval-merror:0.071298
# [152]	eval-merror:0.071298
# [153]	eval-merror:0.071298
# [154]	eval-merror:0.071298
# [155]	eval-merror:0.071298
# [156]	eval-merror:0.071298
# [157]	eval-merror:0.071298
# [158]	eval-merror:0.071298
# [159]	eval-merror:0.071298
# [160]	eval-merror:0.071298
# [161]	eval-merror:0.071298
# [162]	eval-merror:0.071298
# [163]	eval-merror:0.071298
# [164]	eval-merror:0.071298
# [165]	eval-merror:0.071298
# [166]	eval-merror:0.071298
# [167]	eval-merror:0.071298
# [168]	eval-merror:0.071298
# [169]	eval-merror:0.071298
# [170]	eval-merror:0.073126
# [171]	eval-merror:0.073126
# [172]	eval-merror:0.073126
# [173]	eval-merror:0.073126
# [174]	eval-merror:0.073126
# [175]	eval-merror:0.073126
# [176]	eval-merror:0.073126
# [177]	eval-merror:0.073126
# [178]	eval-merror:0.073126
# [179]	eval-merror:0.073126
# [180]	eval-merror:0.071298
# [181]	eval-merror:0.071298
# [182]	eval-merror:0.071298
# [183]	eval-merror:0.071298
# [184]	eval-merror:0.073126
# [185]	eval-merror:0.071298
# [186]	eval-merror:0.073126
# [187]	eval-merror:0.071298
# [188]	eval-merror:0.071298
# [189]	eval-merror:0.073126
# [190]	eval-merror:0.073126
# [191]	eval-merror:0.073126
# [192]	eval-merror:0.073126
# [193]	eval-merror:0.073126
# [194]	eval-merror:0.073126
# [195]	eval-merror:0.073126
# [196]	eval-merror:0.073126
# [197]	eval-merror:0.073126
# [198]	eval-merror:0.071298
# [199]	eval-merror:0.071298
# [200]	eval-merror:0.073126
# [201]	eval-merror:0.073126
# [202]	eval-merror:0.073126
# [203]	eval-merror:0.073126
# [204]	eval-merror:0.073126
# [205]	eval-merror:0.073126
# [206]	eval-merror:0.073126
# [207]	eval-merror:0.073126
# [208]	eval-merror:0.073126
# [209]	eval-merror:0.073126
# [210]	eval-merror:0.073126
# [211]	eval-merror:0.073126
# [212]	eval-merror:0.073126
# [213]	eval-merror:0.073126
# [214]	eval-merror:0.074954
# [215]	eval-merror:0.073126
# [216]	eval-merror:0.073126
# [217]	eval-merror:0.073126
# [218]	eval-merror:0.073126
# [219]	eval-merror:0.073126
# [220]	eval-merror:0.073126
# [221]	eval-merror:0.073126
# [222]	eval-merror:0.073126
# [223]	eval-merror:0.073126
# [224]	eval-merror:0.073126
# [225]	eval-merror:0.073126
# [226]	eval-merror:0.073126
# [227]	eval-merror:0.073126
# [228]	eval-merror:0.073126
# [229]	eval-merror:0.073126
# [230]	eval-merror:0.073126
# [231]	eval-merror:0.074954
# [232]	eval-merror:0.074954
# [233]	eval-merror:0.074954
# [234]	eval-merror:0.074954
# [235]	eval-merror:0.073126
# [236]	eval-merror:0.073126
# [237]	eval-merror:0.074954
# [238]	eval-merror:0.073126
# [239]	eval-merror:0.073126
# [240]	eval-merror:0.073126
# [241]	eval-merror:0.073126
# Stopping. Best iteration:
# [141]	eval-merror:0.071298
#
# [Fold 3/7]
# [0]	eval-merror:0.326007
# Will train until eval-merror hasn't improved in 100 rounds.
# [1]	eval-merror:0.250916
# [2]	eval-merror:0.21978
# [3]	eval-merror:0.21978
# [4]	eval-merror:0.212454
# [5]	eval-merror:0.188645
# [6]	eval-merror:0.168498
# [7]	eval-merror:0.153846
# [8]	eval-merror:0.144689
# [9]	eval-merror:0.14652
# [10]	eval-merror:0.139194
# [11]	eval-merror:0.141026
# [12]	eval-merror:0.144689
# [13]	eval-merror:0.141026
# [14]	eval-merror:0.142857
# [15]	eval-merror:0.1337
# [16]	eval-merror:0.130037
# [17]	eval-merror:0.124542
# [18]	eval-merror:0.122711
# [19]	eval-merror:0.115385
# [20]	eval-merror:0.113553
# [21]	eval-merror:0.106227
# [22]	eval-merror:0.104396
# [23]	eval-merror:0.106227
# [24]	eval-merror:0.106227
# [25]	eval-merror:0.102564
# [26]	eval-merror:0.098901
# [27]	eval-merror:0.100733
# [28]	eval-merror:0.100733
# [29]	eval-merror:0.095238
# [30]	eval-merror:0.095238
# [31]	eval-merror:0.093407
# [32]	eval-merror:0.093407
# [33]	eval-merror:0.093407
# [34]	eval-merror:0.093407
# [35]	eval-merror:0.089744
# [36]	eval-merror:0.087912
# [37]	eval-merror:0.086081
# [38]	eval-merror:0.086081
# [39]	eval-merror:0.086081
# [40]	eval-merror:0.082418
# [41]	eval-merror:0.084249
# [42]	eval-merror:0.084249
# [43]	eval-merror:0.082418
# [44]	eval-merror:0.082418
# [45]	eval-merror:0.082418
# [46]	eval-merror:0.084249
# [47]	eval-merror:0.084249
# [48]	eval-merror:0.082418
# [49]	eval-merror:0.080586
# [50]	eval-merror:0.080586
# [51]	eval-merror:0.082418
# [52]	eval-merror:0.084249
# [53]	eval-merror:0.082418
# [54]	eval-merror:0.080586
# [55]	eval-merror:0.078755
# [56]	eval-merror:0.078755
# [57]	eval-merror:0.078755
# [58]	eval-merror:0.078755
# [59]	eval-merror:0.076923
# [60]	eval-merror:0.078755
# [61]	eval-merror:0.078755
# [62]	eval-merror:0.080586
# [63]	eval-merror:0.078755
# [64]	eval-merror:0.078755
# [65]	eval-merror:0.076923
# [66]	eval-merror:0.078755
# [67]	eval-merror:0.080586
# [68]	eval-merror:0.080586
# [69]	eval-merror:0.078755
# [70]	eval-merror:0.078755
# [71]	eval-merror:0.076923
# [72]	eval-merror:0.076923
# [73]	eval-merror:0.076923
# [74]	eval-merror:0.076923
# [75]	eval-merror:0.075092
# [76]	eval-merror:0.075092
# [77]	eval-merror:0.075092
# [78]	eval-merror:0.075092
# [79]	eval-merror:0.075092
# [80]	eval-merror:0.07326
# [81]	eval-merror:0.071429
# [82]	eval-merror:0.07326
# [83]	eval-merror:0.075092
# [84]	eval-merror:0.071429
# [85]	eval-merror:0.071429
# [86]	eval-merror:0.071429
# [87]	eval-merror:0.069597
# [88]	eval-merror:0.069597
# [89]	eval-merror:0.067766
# [90]	eval-merror:0.067766
# [91]	eval-merror:0.067766
# [92]	eval-merror:0.067766
# [93]	eval-merror:0.067766
# [94]	eval-merror:0.067766
# [95]	eval-merror:0.067766
# [96]	eval-merror:0.067766
# [97]	eval-merror:0.065934
# [98]	eval-merror:0.065934
# [99]	eval-merror:0.067766
# [100]	eval-merror:0.065934
# [101]	eval-merror:0.065934
# [102]	eval-merror:0.065934
# [103]	eval-merror:0.064103
# [104]	eval-merror:0.064103
# [105]	eval-merror:0.064103
# [106]	eval-merror:0.064103
# [107]	eval-merror:0.064103
# [108]	eval-merror:0.064103
# [109]	eval-merror:0.067766
# [110]	eval-merror:0.067766
# [111]	eval-merror:0.064103
# [112]	eval-merror:0.064103
# [113]	eval-merror:0.064103
# [114]	eval-merror:0.065934
# [115]	eval-merror:0.064103
# [116]	eval-merror:0.065934
# [117]	eval-merror:0.065934
# [118]	eval-merror:0.064103
# [119]	eval-merror:0.065934
# [120]	eval-merror:0.065934
# [121]	eval-merror:0.065934
# [122]	eval-merror:0.065934
# [123]	eval-merror:0.065934
# [124]	eval-merror:0.064103
# [125]	eval-merror:0.064103
# [126]	eval-merror:0.064103
# [127]	eval-merror:0.065934
# [128]	eval-merror:0.065934
# [129]	eval-merror:0.064103
# [130]	eval-merror:0.064103
# [131]	eval-merror:0.062271
# [132]	eval-merror:0.062271
# [133]	eval-merror:0.062271
# [134]	eval-merror:0.062271
# [135]	eval-merror:0.062271
# [136]	eval-merror:0.062271
# [137]	eval-merror:0.062271
# [138]	eval-merror:0.062271
# [139]	eval-merror:0.062271
# [140]	eval-merror:0.062271
# [141]	eval-merror:0.062271
# [142]	eval-merror:0.062271
# [143]	eval-merror:0.064103
# [144]	eval-merror:0.064103
# [145]	eval-merror:0.065934
# [146]	eval-merror:0.064103
# [147]	eval-merror:0.065934
# [148]	eval-merror:0.064103
# [149]	eval-merror:0.065934
# [150]	eval-merror:0.067766
# [151]	eval-merror:0.069597
# [152]	eval-merror:0.067766
# [153]	eval-merror:0.065934
# [154]	eval-merror:0.067766
# [155]	eval-merror:0.065934
# [156]	eval-merror:0.065934
# [157]	eval-merror:0.065934
# [158]	eval-merror:0.067766
# [159]	eval-merror:0.067766
# [160]	eval-merror:0.065934
# [161]	eval-merror:0.065934
# [162]	eval-merror:0.067766
# [163]	eval-merror:0.065934
# [164]	eval-merror:0.065934
# [165]	eval-merror:0.067766
# [166]	eval-merror:0.067766
# [167]	eval-merror:0.067766
# [168]	eval-merror:0.065934
# [169]	eval-merror:0.067766
# [170]	eval-merror:0.065934
# [171]	eval-merror:0.065934
# [172]	eval-merror:0.064103
# [173]	eval-merror:0.064103
# [174]	eval-merror:0.062271
# [175]	eval-merror:0.06044
# [176]	eval-merror:0.06044
# [177]	eval-merror:0.06044
# [178]	eval-merror:0.06044
# [179]	eval-merror:0.062271
# [180]	eval-merror:0.064103
# [181]	eval-merror:0.064103
# [182]	eval-merror:0.064103
# [183]	eval-merror:0.064103
# [184]	eval-merror:0.062271
# [185]	eval-merror:0.062271
# [186]	eval-merror:0.062271
# [187]	eval-merror:0.064103
# [188]	eval-merror:0.065934
# [189]	eval-merror:0.065934
# [190]	eval-merror:0.065934
# [191]	eval-merror:0.065934
# [192]	eval-merror:0.065934
# [193]	eval-merror:0.065934
# [194]	eval-merror:0.065934
# [195]	eval-merror:0.064103
# [196]	eval-merror:0.065934
# [197]	eval-merror:0.065934
# [198]	eval-merror:0.065934
# [199]	eval-merror:0.065934
# [200]	eval-merror:0.067766
# [201]	eval-merror:0.067766
# [202]	eval-merror:0.067766
# [203]	eval-merror:0.067766
# [204]	eval-merror:0.067766
# [205]	eval-merror:0.067766
# [206]	eval-merror:0.067766
# [207]	eval-merror:0.067766
# [208]	eval-merror:0.067766
# [209]	eval-merror:0.067766
# [210]	eval-merror:0.067766
# [211]	eval-merror:0.067766
# [212]	eval-merror:0.067766
# [213]	eval-merror:0.067766
# [214]	eval-merror:0.065934
# [215]	eval-merror:0.065934
# [216]	eval-merror:0.065934
# [217]	eval-merror:0.065934
# [218]	eval-merror:0.065934
# [219]	eval-merror:0.065934
# [220]	eval-merror:0.065934
# [221]	eval-merror:0.065934
# [222]	eval-merror:0.065934
# [223]	eval-merror:0.065934
# [224]	eval-merror:0.065934
# [225]	eval-merror:0.065934
# [226]	eval-merror:0.064103
# [227]	eval-merror:0.064103
# [228]	eval-merror:0.064103
# [229]	eval-merror:0.065934
# [230]	eval-merror:0.065934
# [231]	eval-merror:0.065934
# [232]	eval-merror:0.065934
# [233]	eval-merror:0.065934
# [234]	eval-merror:0.065934
# [235]	eval-merror:0.065934
# [236]	eval-merror:0.065934
# [237]	eval-merror:0.064103
# [238]	eval-merror:0.064103
# [239]	eval-merror:0.064103
# [240]	eval-merror:0.062271
# [241]	eval-merror:0.064103
# [242]	eval-merror:0.064103
# [243]	eval-merror:0.064103
# [244]	eval-merror:0.062271
# [245]	eval-merror:0.064103
# [246]	eval-merror:0.064103
# [247]	eval-merror:0.064103
# [248]	eval-merror:0.064103
# [249]	eval-merror:0.064103
# [250]	eval-merror:0.062271
# [251]	eval-merror:0.064103
# [252]	eval-merror:0.065934
# [253]	eval-merror:0.065934
# [254]	eval-merror:0.065934
# [255]	eval-merror:0.065934
# [256]	eval-merror:0.064103
# [257]	eval-merror:0.064103
# [258]	eval-merror:0.064103
# [259]	eval-merror:0.064103
# [260]	eval-merror:0.064103
# [261]	eval-merror:0.064103
# [262]	eval-merror:0.064103
# [263]	eval-merror:0.064103
# [264]	eval-merror:0.064103
# [265]	eval-merror:0.064103
# [266]	eval-merror:0.064103
# [267]	eval-merror:0.064103
# [268]	eval-merror:0.064103
# [269]	eval-merror:0.062271
# [270]	eval-merror:0.064103
# [271]	eval-merror:0.064103
# [272]	eval-merror:0.064103
# [273]	eval-merror:0.064103
# [274]	eval-merror:0.064103
# [275]	eval-merror:0.064103
# Stopping. Best iteration:
# [175]	eval-merror:0.06044
#
# [Fold 4/7]
# [0]	eval-merror:0.358456
# Will train until eval-merror hasn't improved in 100 rounds.
# [1]	eval-merror:0.297794
# [2]	eval-merror:0.255515
# [3]	eval-merror:0.235294
# [4]	eval-merror:0.240809
# [5]	eval-merror:0.220588
# [6]	eval-merror:0.226103
# [7]	eval-merror:0.215074
# [8]	eval-merror:0.207721
# [9]	eval-merror:0.198529
# [10]	eval-merror:0.193015
# [11]	eval-merror:0.185662
# [12]	eval-merror:0.1875
# [13]	eval-merror:0.180147
# [14]	eval-merror:0.170956
# [15]	eval-merror:0.169118
# [16]	eval-merror:0.170956
# [17]	eval-merror:0.159926
# [18]	eval-merror:0.158088
# [19]	eval-merror:0.150735
# [20]	eval-merror:0.150735
# [21]	eval-merror:0.148897
# [22]	eval-merror:0.147059
# [23]	eval-merror:0.145221
# [24]	eval-merror:0.145221
# [25]	eval-merror:0.143382
# [26]	eval-merror:0.145221
# [27]	eval-merror:0.139706
# [28]	eval-merror:0.134191
# [29]	eval-merror:0.130515
# [30]	eval-merror:0.128676
# [31]	eval-merror:0.128676
# [32]	eval-merror:0.123162
# [33]	eval-merror:0.119485
# [34]	eval-merror:0.123162
# [35]	eval-merror:0.121324
# [36]	eval-merror:0.119485
# [37]	eval-merror:0.119485
# [38]	eval-merror:0.119485
# [39]	eval-merror:0.117647
# [40]	eval-merror:0.115809
# [41]	eval-merror:0.113971
# [42]	eval-merror:0.113971
# [43]	eval-merror:0.115809
# [44]	eval-merror:0.117647
# [45]	eval-merror:0.115809
# [46]	eval-merror:0.106618
# [47]	eval-merror:0.108456
# [48]	eval-merror:0.108456
# [49]	eval-merror:0.108456
# [50]	eval-merror:0.108456
# [51]	eval-merror:0.108456
# [52]	eval-merror:0.110294
# [53]	eval-merror:0.112132
# [54]	eval-merror:0.110294
# [55]	eval-merror:0.110294
# [56]	eval-merror:0.106618
# [57]	eval-merror:0.104779
# [58]	eval-merror:0.101103
# [59]	eval-merror:0.102941
# [60]	eval-merror:0.099265
# [61]	eval-merror:0.101103
# [62]	eval-merror:0.102941
# [63]	eval-merror:0.102941
# [64]	eval-merror:0.102941
# [65]	eval-merror:0.099265
# [66]	eval-merror:0.102941
# [67]	eval-merror:0.101103
# [68]	eval-merror:0.095588
# [69]	eval-merror:0.101103
# [70]	eval-merror:0.095588
# [71]	eval-merror:0.09375
# [72]	eval-merror:0.09375
# [73]	eval-merror:0.09375
# [74]	eval-merror:0.095588
# [75]	eval-merror:0.095588
# [76]	eval-merror:0.095588
# [77]	eval-merror:0.097426
# [78]	eval-merror:0.097426
# [79]	eval-merror:0.09375
# [80]	eval-merror:0.09375
# [81]	eval-merror:0.09375
# [82]	eval-merror:0.09375
# [83]	eval-merror:0.09375
# [84]	eval-merror:0.091912
# [85]	eval-merror:0.090074
# [86]	eval-merror:0.088235
# [87]	eval-merror:0.086397
# [88]	eval-merror:0.086397
# [89]	eval-merror:0.088235
# [90]	eval-merror:0.086397
# [91]	eval-merror:0.086397
# [92]	eval-merror:0.088235
# [93]	eval-merror:0.086397
# [94]	eval-merror:0.088235
# [95]	eval-merror:0.086397
# [96]	eval-merror:0.084559
# [97]	eval-merror:0.084559
# [98]	eval-merror:0.084559
# [99]	eval-merror:0.086397
# [100]	eval-merror:0.084559
# [101]	eval-merror:0.086397
# [102]	eval-merror:0.086397
# [103]	eval-merror:0.086397
# [104]	eval-merror:0.086397
# [105]	eval-merror:0.084559
# [106]	eval-merror:0.084559
# [107]	eval-merror:0.084559
# [108]	eval-merror:0.084559
# [109]	eval-merror:0.084559
# [110]	eval-merror:0.086397
# [111]	eval-merror:0.084559
# [112]	eval-merror:0.084559
# [113]	eval-merror:0.084559
# [114]	eval-merror:0.084559
# [115]	eval-merror:0.082721
# [116]	eval-merror:0.082721
# [117]	eval-merror:0.082721
# [118]	eval-merror:0.082721
# [119]	eval-merror:0.080882
# [120]	eval-merror:0.080882
# [121]	eval-merror:0.080882
# [122]	eval-merror:0.080882
# [123]	eval-merror:0.082721
# [124]	eval-merror:0.082721
# [125]	eval-merror:0.082721
# [126]	eval-merror:0.082721
# [127]	eval-merror:0.082721
# [128]	eval-merror:0.082721
# [129]	eval-merror:0.080882
# [130]	eval-merror:0.080882
# [131]	eval-merror:0.080882
# [132]	eval-merror:0.079044
# [133]	eval-merror:0.082721
# [134]	eval-merror:0.079044
# [135]	eval-merror:0.079044
# [136]	eval-merror:0.077206
# [137]	eval-merror:0.077206
# [138]	eval-merror:0.077206
# [139]	eval-merror:0.077206
# [140]	eval-merror:0.075368
# [141]	eval-merror:0.075368
# [142]	eval-merror:0.077206
# [143]	eval-merror:0.077206
# [144]	eval-merror:0.077206
# [145]	eval-merror:0.077206
# [146]	eval-merror:0.077206
# [147]	eval-merror:0.077206
# [148]	eval-merror:0.077206
# [149]	eval-merror:0.077206
# [150]	eval-merror:0.077206
# [151]	eval-merror:0.077206
# [152]	eval-merror:0.075368
# [153]	eval-merror:0.075368
# [154]	eval-merror:0.075368
# [155]	eval-merror:0.075368
# [156]	eval-merror:0.073529
# [157]	eval-merror:0.075368
# [158]	eval-merror:0.075368
# [159]	eval-merror:0.073529
# [160]	eval-merror:0.073529
# [161]	eval-merror:0.073529
# [162]	eval-merror:0.073529
# [163]	eval-merror:0.073529
# [164]	eval-merror:0.073529
# [165]	eval-merror:0.073529
# [166]	eval-merror:0.075368
# [167]	eval-merror:0.073529
# [168]	eval-merror:0.073529
# [169]	eval-merror:0.073529
# [170]	eval-merror:0.071691
# [171]	eval-merror:0.071691
# [172]	eval-merror:0.071691
# [173]	eval-merror:0.071691
# [174]	eval-merror:0.071691
# [175]	eval-merror:0.071691
# [176]	eval-merror:0.071691
# [177]	eval-merror:0.071691
# [178]	eval-merror:0.071691
# [179]	eval-merror:0.071691
# [180]	eval-merror:0.071691
# [181]	eval-merror:0.071691
# [182]	eval-merror:0.071691
# [183]	eval-merror:0.071691
# [184]	eval-merror:0.071691
# [185]	eval-merror:0.071691
# [186]	eval-merror:0.071691
# [187]	eval-merror:0.071691
# [188]	eval-merror:0.071691
# [189]	eval-merror:0.073529
# [190]	eval-merror:0.073529
# [191]	eval-merror:0.073529
# [192]	eval-merror:0.073529
# [193]	eval-merror:0.073529
# [194]	eval-merror:0.073529
# [195]	eval-merror:0.073529
# [196]	eval-merror:0.073529
# [197]	eval-merror:0.071691
# [198]	eval-merror:0.071691
# [199]	eval-merror:0.071691
# [200]	eval-merror:0.071691
# [201]	eval-merror:0.071691
# [202]	eval-merror:0.071691
# [203]	eval-merror:0.069853
# [204]	eval-merror:0.071691
# [205]	eval-merror:0.071691
# [206]	eval-merror:0.071691
# [207]	eval-merror:0.069853
# [208]	eval-merror:0.073529
# [209]	eval-merror:0.071691
# [210]	eval-merror:0.071691
# [211]	eval-merror:0.069853
# [212]	eval-merror:0.069853
# [213]	eval-merror:0.069853
# [214]	eval-merror:0.068015
# [215]	eval-merror:0.068015
# [216]	eval-merror:0.068015
# [217]	eval-merror:0.068015
# [218]	eval-merror:0.068015
# [219]	eval-merror:0.068015
# [220]	eval-merror:0.068015
# [221]	eval-merror:0.068015
# [222]	eval-merror:0.068015
# [223]	eval-merror:0.069853
# [224]	eval-merror:0.069853
# [225]	eval-merror:0.069853
# [226]	eval-merror:0.069853
# [227]	eval-merror:0.069853
# [228]	eval-merror:0.069853
# [229]	eval-merror:0.069853
# [230]	eval-merror:0.069853
# [231]	eval-merror:0.069853
# [232]	eval-merror:0.069853
# [233]	eval-merror:0.069853
# [234]	eval-merror:0.068015
# [235]	eval-merror:0.068015
# [236]	eval-merror:0.068015
# [237]	eval-merror:0.069853
# [238]	eval-merror:0.069853
# [239]	eval-merror:0.069853
# [240]	eval-merror:0.069853
# [241]	eval-merror:0.069853
# [242]	eval-merror:0.068015
# [243]	eval-merror:0.069853
# [244]	eval-merror:0.068015
# [245]	eval-merror:0.068015
# [246]	eval-merror:0.068015
# [247]	eval-merror:0.068015
# [248]	eval-merror:0.068015
# [249]	eval-merror:0.068015
# [250]	eval-merror:0.068015
# [251]	eval-merror:0.068015
# [252]	eval-merror:0.066176
# [253]	eval-merror:0.066176
# [254]	eval-merror:0.068015
# [255]	eval-merror:0.066176
# [256]	eval-merror:0.066176
# [257]	eval-merror:0.066176
# [258]	eval-merror:0.066176
# [259]	eval-merror:0.066176
# [260]	eval-merror:0.066176
# [261]	eval-merror:0.068015
# [262]	eval-merror:0.066176
# [263]	eval-merror:0.066176
# [264]	eval-merror:0.066176
# [265]	eval-merror:0.066176
# [266]	eval-merror:0.068015
# [267]	eval-merror:0.066176
# [268]	eval-merror:0.066176
# [269]	eval-merror:0.066176
# [270]	eval-merror:0.068015
# [271]	eval-merror:0.066176
# [272]	eval-merror:0.064338
# [273]	eval-merror:0.066176
# [274]	eval-merror:0.066176
# [275]	eval-merror:0.066176
# [276]	eval-merror:0.066176
# [277]	eval-merror:0.066176
# [278]	eval-merror:0.066176
# [279]	eval-merror:0.066176
# [280]	eval-merror:0.066176
# [281]	eval-merror:0.066176
# [282]	eval-merror:0.066176
# [283]	eval-merror:0.066176
# [284]	eval-merror:0.066176
# [285]	eval-merror:0.066176
# [286]	eval-merror:0.066176
# [287]	eval-merror:0.066176
# [288]	eval-merror:0.068015
# [289]	eval-merror:0.068015
# [290]	eval-merror:0.068015
# [291]	eval-merror:0.066176
# [292]	eval-merror:0.066176
# [293]	eval-merror:0.066176
# [294]	eval-merror:0.068015
# [295]	eval-merror:0.068015
# [296]	eval-merror:0.068015
# [297]	eval-merror:0.069853
# [298]	eval-merror:0.068015
# [299]	eval-merror:0.066176
# [300]	eval-merror:0.068015
# [301]	eval-merror:0.068015
# [302]	eval-merror:0.068015
# [303]	eval-merror:0.068015
# [304]	eval-merror:0.068015
# [305]	eval-merror:0.068015
# [306]	eval-merror:0.068015
# [307]	eval-merror:0.068015
# [308]	eval-merror:0.068015
# [309]	eval-merror:0.068015
# [310]	eval-merror:0.068015
# [311]	eval-merror:0.068015
# [312]	eval-merror:0.068015
# [313]	eval-merror:0.068015
# [314]	eval-merror:0.068015
# [315]	eval-merror:0.068015
# [316]	eval-merror:0.068015
# [317]	eval-merror:0.068015
# [318]	eval-merror:0.068015
# [319]	eval-merror:0.068015
# [320]	eval-merror:0.068015
# [321]	eval-merror:0.068015
# [322]	eval-merror:0.068015
# [323]	eval-merror:0.068015
# [324]	eval-merror:0.068015
# [325]	eval-merror:0.068015
# [326]	eval-merror:0.068015
# [327]	eval-merror:0.068015
# [328]	eval-merror:0.068015
# [329]	eval-merror:0.068015
# [330]	eval-merror:0.068015
# [331]	eval-merror:0.068015
# [332]	eval-merror:0.068015
# [333]	eval-merror:0.068015
# [334]	eval-merror:0.068015
# [335]	eval-merror:0.068015
# [336]	eval-merror:0.068015
# [337]	eval-merror:0.068015
# [338]	eval-merror:0.068015
# [339]	eval-merror:0.068015
# [340]	eval-merror:0.068015
# [341]	eval-merror:0.068015
# [342]	eval-merror:0.068015
# [343]	eval-merror:0.068015
# [344]	eval-merror:0.068015
# [345]	eval-merror:0.068015
# [346]	eval-merror:0.068015
# [347]	eval-merror:0.068015
# [348]	eval-merror:0.068015
# [349]	eval-merror:0.068015
# [350]	eval-merror:0.068015
# [351]	eval-merror:0.068015
# [352]	eval-merror:0.068015
# [353]	eval-merror:0.068015
# [354]	eval-merror:0.068015
# [355]	eval-merror:0.068015
# [356]	eval-merror:0.068015
# [357]	eval-merror:0.068015
# [358]	eval-merror:0.068015
# [359]	eval-merror:0.068015
# [360]	eval-merror:0.068015
# [361]	eval-merror:0.068015
# [362]	eval-merror:0.068015
# [363]	eval-merror:0.068015
# [364]	eval-merror:0.068015
# [365]	eval-merror:0.068015
# [366]	eval-merror:0.068015
# [367]	eval-merror:0.068015
# [368]	eval-merror:0.068015
# [369]	eval-merror:0.068015
# [370]	eval-merror:0.068015
# [371]	eval-merror:0.068015
# [372]	eval-merror:0.068015
# Stopping. Best iteration:
# [272]	eval-merror:0.064338
#
# [Fold 5/7]
# [0]	eval-merror:0.307551
# Will train until eval-merror hasn't improved in 100 rounds.
# [1]	eval-merror:0.246777
# [2]	eval-merror:0.226519
# [3]	eval-merror:0.220994
# [4]	eval-merror:0.200737
# [5]	eval-merror:0.184162
# [6]	eval-merror:0.180479
# [7]	eval-merror:0.167587
# [8]	eval-merror:0.167587
# [9]	eval-merror:0.165746
# [10]	eval-merror:0.160221
# [11]	eval-merror:0.156538
# [12]	eval-merror:0.149171
# [13]	eval-merror:0.145488
# [14]	eval-merror:0.141805
# [15]	eval-merror:0.138122
# [16]	eval-merror:0.138122
# [17]	eval-merror:0.130755
# [18]	eval-merror:0.132597
# [19]	eval-merror:0.130755
# [20]	eval-merror:0.130755
# [21]	eval-merror:0.132597
# [22]	eval-merror:0.127072
# [23]	eval-merror:0.127072
# [24]	eval-merror:0.12523
# [25]	eval-merror:0.130755
# [26]	eval-merror:0.12523
# [27]	eval-merror:0.123389
# [28]	eval-merror:0.119705
# [29]	eval-merror:0.123389
# [30]	eval-merror:0.123389
# [31]	eval-merror:0.121547
# [32]	eval-merror:0.121547
# [33]	eval-merror:0.119705
# [34]	eval-merror:0.117864
# [35]	eval-merror:0.117864
# [36]	eval-merror:0.116022
# [37]	eval-merror:0.116022
# [38]	eval-merror:0.112339
# [39]	eval-merror:0.11418
# [40]	eval-merror:0.112339
# [41]	eval-merror:0.110497
# [42]	eval-merror:0.108656
# [43]	eval-merror:0.108656
# [44]	eval-merror:0.108656
# [45]	eval-merror:0.108656
# [46]	eval-merror:0.106814
# [47]	eval-merror:0.106814
# [48]	eval-merror:0.104972
# [49]	eval-merror:0.101289
# [50]	eval-merror:0.101289
# [51]	eval-merror:0.103131
# [52]	eval-merror:0.101289
# [53]	eval-merror:0.103131
# [54]	eval-merror:0.097606
# [55]	eval-merror:0.099448
# [56]	eval-merror:0.099448
# [57]	eval-merror:0.099448
# [58]	eval-merror:0.099448
# [59]	eval-merror:0.095764
# [60]	eval-merror:0.095764
# [61]	eval-merror:0.095764
# [62]	eval-merror:0.095764
# [63]	eval-merror:0.092081
# [64]	eval-merror:0.088398
# [65]	eval-merror:0.088398
# [66]	eval-merror:0.086556
# [67]	eval-merror:0.088398
# [68]	eval-merror:0.090239
# [69]	eval-merror:0.088398
# [70]	eval-merror:0.090239
# [71]	eval-merror:0.092081
# [72]	eval-merror:0.088398
# [73]	eval-merror:0.088398
# [74]	eval-merror:0.086556
# [75]	eval-merror:0.084715
# [76]	eval-merror:0.084715
# [77]	eval-merror:0.082873
# [78]	eval-merror:0.081031
# [79]	eval-merror:0.081031
# [80]	eval-merror:0.081031
# [81]	eval-merror:0.081031
# [82]	eval-merror:0.081031
# [83]	eval-merror:0.07919
# [84]	eval-merror:0.07919
# [85]	eval-merror:0.07919
# [86]	eval-merror:0.07919
# [87]	eval-merror:0.07919
# [88]	eval-merror:0.081031
# [89]	eval-merror:0.081031
# [90]	eval-merror:0.07919
# [91]	eval-merror:0.07919
# [92]	eval-merror:0.07919
# [93]	eval-merror:0.077348
# [94]	eval-merror:0.081031
# [95]	eval-merror:0.081031
# [96]	eval-merror:0.081031
# [97]	eval-merror:0.07919
# [98]	eval-merror:0.07919
# [99]	eval-merror:0.07919
# [100]	eval-merror:0.081031
# [101]	eval-merror:0.07919
# [102]	eval-merror:0.07919
# [103]	eval-merror:0.07919
# [104]	eval-merror:0.07919
# [105]	eval-merror:0.07919
# [106]	eval-merror:0.07919
# [107]	eval-merror:0.07919
# [108]	eval-merror:0.07919
# [109]	eval-merror:0.07919
# [110]	eval-merror:0.07919
# [111]	eval-merror:0.077348
# [112]	eval-merror:0.077348
# [113]	eval-merror:0.077348
# [114]	eval-merror:0.07919
# [115]	eval-merror:0.07919
# [116]	eval-merror:0.077348
# [117]	eval-merror:0.075506
# [118]	eval-merror:0.075506
# [119]	eval-merror:0.075506
# [120]	eval-merror:0.075506
# [121]	eval-merror:0.075506
# [122]	eval-merror:0.077348
# [123]	eval-merror:0.077348
# [124]	eval-merror:0.077348
# [125]	eval-merror:0.077348
# [126]	eval-merror:0.07919
# [127]	eval-merror:0.07919
# [128]	eval-merror:0.07919
# [129]	eval-merror:0.07919
# [130]	eval-merror:0.07919
# [131]	eval-merror:0.07919
# [132]	eval-merror:0.07919
# [133]	eval-merror:0.07919
# [134]	eval-merror:0.07919
# [135]	eval-merror:0.07919
# [136]	eval-merror:0.07919
# [137]	eval-merror:0.07919
# [138]	eval-merror:0.081031
# [139]	eval-merror:0.081031
# [140]	eval-merror:0.081031
# [141]	eval-merror:0.081031
# [142]	eval-merror:0.081031
# [143]	eval-merror:0.081031
# [144]	eval-merror:0.07919
# [145]	eval-merror:0.07919
# [146]	eval-merror:0.07919
# [147]	eval-merror:0.07919
# [148]	eval-merror:0.07919
# [149]	eval-merror:0.081031
# [150]	eval-merror:0.07919
# [151]	eval-merror:0.07919
# [152]	eval-merror:0.07919
# [153]	eval-merror:0.07919
# [154]	eval-merror:0.081031
# [155]	eval-merror:0.081031
# [156]	eval-merror:0.081031
# [157]	eval-merror:0.082873
# [158]	eval-merror:0.082873
# [159]	eval-merror:0.082873
# [160]	eval-merror:0.082873
# [161]	eval-merror:0.082873
# [162]	eval-merror:0.082873
# [163]	eval-merror:0.081031
# [164]	eval-merror:0.082873
# [165]	eval-merror:0.082873
# [166]	eval-merror:0.07919
# [167]	eval-merror:0.081031
# [168]	eval-merror:0.081031
# [169]	eval-merror:0.081031
# [170]	eval-merror:0.081031
# [171]	eval-merror:0.07919
# [172]	eval-merror:0.081031
# [173]	eval-merror:0.081031
# [174]	eval-merror:0.07919
# [175]	eval-merror:0.07919
# [176]	eval-merror:0.081031
# [177]	eval-merror:0.07919
# [178]	eval-merror:0.07919
# [179]	eval-merror:0.07919
# [180]	eval-merror:0.077348
# [181]	eval-merror:0.075506
# [182]	eval-merror:0.07919
# [183]	eval-merror:0.077348
# [184]	eval-merror:0.07919
# [185]	eval-merror:0.081031
# [186]	eval-merror:0.07919
# [187]	eval-merror:0.07919
# [188]	eval-merror:0.081031
# [189]	eval-merror:0.081031
# [190]	eval-merror:0.081031
# [191]	eval-merror:0.081031
# [192]	eval-merror:0.081031
# [193]	eval-merror:0.07919
# [194]	eval-merror:0.07919
# [195]	eval-merror:0.081031
# [196]	eval-merror:0.07919
# [197]	eval-merror:0.07919
# [198]	eval-merror:0.081031
# [199]	eval-merror:0.081031
# [200]	eval-merror:0.081031
# [201]	eval-merror:0.07919
# [202]	eval-merror:0.07919
# [203]	eval-merror:0.07919
# [204]	eval-merror:0.07919
# [205]	eval-merror:0.07919
# [206]	eval-merror:0.07919
# [207]	eval-merror:0.07919
# [208]	eval-merror:0.07919
# [209]	eval-merror:0.07919
# [210]	eval-merror:0.07919
# [211]	eval-merror:0.07919
# [212]	eval-merror:0.081031
# [213]	eval-merror:0.082873
# [214]	eval-merror:0.082873
# [215]	eval-merror:0.082873
# [216]	eval-merror:0.082873
# [217]	eval-merror:0.082873
# Stopping. Best iteration:
# [117]	eval-merror:0.075506
#
# [Fold 6/7]
# [0]	eval-merror:0.348708
# Will train until eval-merror hasn't improved in 100 rounds.
# [1]	eval-merror:0.289668
# [2]	eval-merror:0.284133
# [3]	eval-merror:0.260148
# [4]	eval-merror:0.236162
# [5]	eval-merror:0.208487
# [6]	eval-merror:0.191882
# [7]	eval-merror:0.191882
# [8]	eval-merror:0.191882
# [9]	eval-merror:0.191882
# [10]	eval-merror:0.188192
# [11]	eval-merror:0.182657
# [12]	eval-merror:0.175277
# [13]	eval-merror:0.178967
# [14]	eval-merror:0.177122
# [15]	eval-merror:0.178967
# [16]	eval-merror:0.166052
# [17]	eval-merror:0.156827
# [18]	eval-merror:0.153137
# [19]	eval-merror:0.151292
# [20]	eval-merror:0.147601
# [21]	eval-merror:0.143911
# [22]	eval-merror:0.142066
# [23]	eval-merror:0.140221
# [24]	eval-merror:0.136531
# [25]	eval-merror:0.134686
# [26]	eval-merror:0.136531
# [27]	eval-merror:0.136531
# [28]	eval-merror:0.130996
# [29]	eval-merror:0.130996
# [30]	eval-merror:0.127306
# [31]	eval-merror:0.127306
# [32]	eval-merror:0.125461
# [33]	eval-merror:0.125461
# [34]	eval-merror:0.123616
# [35]	eval-merror:0.123616
# [36]	eval-merror:0.125461
# [37]	eval-merror:0.123616
# [38]	eval-merror:0.123616
# [39]	eval-merror:0.119926
# [40]	eval-merror:0.119926
# [41]	eval-merror:0.116236
# [42]	eval-merror:0.116236
# [43]	eval-merror:0.112546
# [44]	eval-merror:0.114391
# [45]	eval-merror:0.112546
# [46]	eval-merror:0.110701
# [47]	eval-merror:0.107011
# [48]	eval-merror:0.103321
# [49]	eval-merror:0.101476
# [50]	eval-merror:0.103321
# [51]	eval-merror:0.101476
# [52]	eval-merror:0.099631
# [53]	eval-merror:0.097786
# [54]	eval-merror:0.097786
# [55]	eval-merror:0.097786
# [56]	eval-merror:0.103321
# [57]	eval-merror:0.101476
# [58]	eval-merror:0.101476
# [59]	eval-merror:0.097786
# [60]	eval-merror:0.099631
# [61]	eval-merror:0.095941
# [62]	eval-merror:0.094096
# [63]	eval-merror:0.092251
# [64]	eval-merror:0.092251
# [65]	eval-merror:0.092251
# [66]	eval-merror:0.094096
# [67]	eval-merror:0.088561
# [68]	eval-merror:0.088561
# [69]	eval-merror:0.090406
# [70]	eval-merror:0.090406
# [71]	eval-merror:0.090406
# [72]	eval-merror:0.092251
# [73]	eval-merror:0.090406
# [74]	eval-merror:0.090406
# [75]	eval-merror:0.094096
# [76]	eval-merror:0.088561
# [77]	eval-merror:0.088561
# [78]	eval-merror:0.088561
# [79]	eval-merror:0.088561
# [80]	eval-merror:0.088561
# [81]	eval-merror:0.088561
# [82]	eval-merror:0.090406
# [83]	eval-merror:0.088561
# [84]	eval-merror:0.088561
# [85]	eval-merror:0.086716
# [86]	eval-merror:0.086716
# [87]	eval-merror:0.084871
# [88]	eval-merror:0.084871
# [89]	eval-merror:0.086716
# [90]	eval-merror:0.084871
# [91]	eval-merror:0.084871
# [92]	eval-merror:0.086716
# [93]	eval-merror:0.084871
# [94]	eval-merror:0.084871
# [95]	eval-merror:0.084871
# [96]	eval-merror:0.084871
# [97]	eval-merror:0.084871
# [98]	eval-merror:0.084871
# [99]	eval-merror:0.084871
# [100]	eval-merror:0.084871
# [101]	eval-merror:0.084871
# [102]	eval-merror:0.084871
# [103]	eval-merror:0.084871
# [104]	eval-merror:0.084871
# [105]	eval-merror:0.084871
# [106]	eval-merror:0.084871
# [107]	eval-merror:0.084871
# [108]	eval-merror:0.083026
# [109]	eval-merror:0.083026
# [110]	eval-merror:0.083026
# [111]	eval-merror:0.083026
# [112]	eval-merror:0.083026
# [113]	eval-merror:0.083026
# [114]	eval-merror:0.084871
# [115]	eval-merror:0.084871
# [116]	eval-merror:0.083026
# [117]	eval-merror:0.084871
# [118]	eval-merror:0.084871
# [119]	eval-merror:0.084871
# [120]	eval-merror:0.084871
# [121]	eval-merror:0.084871
# [122]	eval-merror:0.084871
# [123]	eval-merror:0.084871
# [124]	eval-merror:0.083026
# [125]	eval-merror:0.083026
# [126]	eval-merror:0.083026
# [127]	eval-merror:0.083026
# [128]	eval-merror:0.083026
# [129]	eval-merror:0.083026
# [130]	eval-merror:0.083026
# [131]	eval-merror:0.083026
# [132]	eval-merror:0.083026
# [133]	eval-merror:0.083026
# [134]	eval-merror:0.083026
# [135]	eval-merror:0.083026
# [136]	eval-merror:0.083026
# [137]	eval-merror:0.083026
# [138]	eval-merror:0.083026
# [139]	eval-merror:0.083026
# [140]	eval-merror:0.083026
# [141]	eval-merror:0.083026
# [142]	eval-merror:0.081181
# [143]	eval-merror:0.081181
# [144]	eval-merror:0.081181
# [145]	eval-merror:0.081181
# [146]	eval-merror:0.081181
# [147]	eval-merror:0.081181
# [148]	eval-merror:0.081181
# [149]	eval-merror:0.083026
# [150]	eval-merror:0.083026
# [151]	eval-merror:0.083026
# [152]	eval-merror:0.081181
# [153]	eval-merror:0.081181
# [154]	eval-merror:0.081181
# [155]	eval-merror:0.081181
# [156]	eval-merror:0.081181
# [157]	eval-merror:0.081181
# [158]	eval-merror:0.081181
# [159]	eval-merror:0.081181
# [160]	eval-merror:0.079336
# [161]	eval-merror:0.079336
# [162]	eval-merror:0.079336
# [163]	eval-merror:0.081181
# [164]	eval-merror:0.081181
# [165]	eval-merror:0.081181
# [166]	eval-merror:0.079336
# [167]	eval-merror:0.081181
# [168]	eval-merror:0.081181
# [169]	eval-merror:0.081181
# [170]	eval-merror:0.081181
# [171]	eval-merror:0.081181
# [172]	eval-merror:0.079336
# [173]	eval-merror:0.079336
# [174]	eval-merror:0.079336
# [175]	eval-merror:0.079336
# [176]	eval-merror:0.079336
# [177]	eval-merror:0.079336
# [178]	eval-merror:0.083026
# [179]	eval-merror:0.081181
# [180]	eval-merror:0.079336
# [181]	eval-merror:0.079336
# [182]	eval-merror:0.079336
# [183]	eval-merror:0.081181
# [184]	eval-merror:0.079336
# [185]	eval-merror:0.077491
# [186]	eval-merror:0.077491
# [187]	eval-merror:0.077491
# [188]	eval-merror:0.077491
# [189]	eval-merror:0.077491
# [190]	eval-merror:0.077491
# [191]	eval-merror:0.077491
# [192]	eval-merror:0.077491
# [193]	eval-merror:0.077491
# [194]	eval-merror:0.079336
# [195]	eval-merror:0.079336
# [196]	eval-merror:0.079336
# [197]	eval-merror:0.079336
# [198]	eval-merror:0.077491
# [199]	eval-merror:0.079336
# [200]	eval-merror:0.079336
# [201]	eval-merror:0.077491
# [202]	eval-merror:0.079336
# [203]	eval-merror:0.077491
# [204]	eval-merror:0.077491
# [205]	eval-merror:0.077491
# [206]	eval-merror:0.077491
# [207]	eval-merror:0.077491
# [208]	eval-merror:0.077491
# [209]	eval-merror:0.077491
# [210]	eval-merror:0.077491
# [211]	eval-merror:0.077491
# [212]	eval-merror:0.077491
# [213]	eval-merror:0.077491
# [214]	eval-merror:0.077491
# [215]	eval-merror:0.077491
# [216]	eval-merror:0.077491
# [217]	eval-merror:0.077491
# [218]	eval-merror:0.077491
# [219]	eval-merror:0.077491
# [220]	eval-merror:0.077491
# [221]	eval-merror:0.077491
# [222]	eval-merror:0.077491
# [223]	eval-merror:0.077491
# [224]	eval-merror:0.077491
# [225]	eval-merror:0.077491
# [226]	eval-merror:0.079336
# [227]	eval-merror:0.079336
# [228]	eval-merror:0.079336
# [229]	eval-merror:0.079336
# [230]	eval-merror:0.079336
# [231]	eval-merror:0.079336
# [232]	eval-merror:0.079336
# [233]	eval-merror:0.075646
# [234]	eval-merror:0.079336
# [235]	eval-merror:0.075646
# [236]	eval-merror:0.077491
# [237]	eval-merror:0.075646
# [238]	eval-merror:0.077491
# [239]	eval-merror:0.075646
# [240]	eval-merror:0.077491
# [241]	eval-merror:0.075646
# [242]	eval-merror:0.075646
# [243]	eval-merror:0.075646
# [244]	eval-merror:0.075646
# [245]	eval-merror:0.075646
# [246]	eval-merror:0.077491
# [247]	eval-merror:0.077491
# [248]	eval-merror:0.077491
# [249]	eval-merror:0.077491
# [250]	eval-merror:0.077491
# [251]	eval-merror:0.079336
# [252]	eval-merror:0.079336
# [253]	eval-merror:0.077491
# [254]	eval-merror:0.075646
# [255]	eval-merror:0.075646
# [256]	eval-merror:0.075646
# [257]	eval-merror:0.075646
# [258]	eval-merror:0.075646
# [259]	eval-merror:0.075646
# [260]	eval-merror:0.073801
# [261]	eval-merror:0.073801
# [262]	eval-merror:0.075646
# [263]	eval-merror:0.073801
# [264]	eval-merror:0.073801
# [265]	eval-merror:0.075646
# [266]	eval-merror:0.073801
# [267]	eval-merror:0.073801
# [268]	eval-merror:0.075646
# [269]	eval-merror:0.075646
# [270]	eval-merror:0.073801
# [271]	eval-merror:0.073801
# [272]	eval-merror:0.075646
# [273]	eval-merror:0.077491
# [274]	eval-merror:0.075646
# [275]	eval-merror:0.075646
# [276]	eval-merror:0.075646
# [277]	eval-merror:0.075646
# [278]	eval-merror:0.075646
# [279]	eval-merror:0.077491
# [280]	eval-merror:0.077491
# [281]	eval-merror:0.077491
# [282]	eval-merror:0.077491
# [283]	eval-merror:0.077491
# [284]	eval-merror:0.077491
# [285]	eval-merror:0.077491
# [286]	eval-merror:0.077491
# [287]	eval-merror:0.077491
# [288]	eval-merror:0.077491
# [289]	eval-merror:0.077491
# [290]	eval-merror:0.077491
# [291]	eval-merror:0.075646
# [292]	eval-merror:0.075646
# [293]	eval-merror:0.077491
# [294]	eval-merror:0.077491
# [295]	eval-merror:0.077491
# [296]	eval-merror:0.077491
# [297]	eval-merror:0.077491
# [298]	eval-merror:0.075646
# [299]	eval-merror:0.075646
# [300]	eval-merror:0.075646
# [301]	eval-merror:0.075646
# [302]	eval-merror:0.075646
# [303]	eval-merror:0.075646
# [304]	eval-merror:0.075646
# [305]	eval-merror:0.075646
# [306]	eval-merror:0.075646
# [307]	eval-merror:0.075646
# [308]	eval-merror:0.075646
# [309]	eval-merror:0.075646
# [310]	eval-merror:0.075646
# [311]	eval-merror:0.075646
# [312]	eval-merror:0.077491
# [313]	eval-merror:0.077491
# [314]	eval-merror:0.075646
# [315]	eval-merror:0.075646
# [316]	eval-merror:0.075646
# [317]	eval-merror:0.073801
# [318]	eval-merror:0.075646
# [319]	eval-merror:0.075646
# [320]	eval-merror:0.073801
# [321]	eval-merror:0.073801
# [322]	eval-merror:0.073801
# [323]	eval-merror:0.073801
# [324]	eval-merror:0.073801
# [325]	eval-merror:0.075646
# [326]	eval-merror:0.075646
# [327]	eval-merror:0.073801
# [328]	eval-merror:0.073801
# [329]	eval-merror:0.073801
# [330]	eval-merror:0.073801
# [331]	eval-merror:0.073801
# [332]	eval-merror:0.075646
# [333]	eval-merror:0.073801
# [334]	eval-merror:0.075646
# [335]	eval-merror:0.075646
# [336]	eval-merror:0.073801
# [337]	eval-merror:0.075646
# [338]	eval-merror:0.073801
# [339]	eval-merror:0.073801
# [340]	eval-merror:0.073801
# [341]	eval-merror:0.073801
# [342]	eval-merror:0.073801
# [343]	eval-merror:0.073801
# [344]	eval-merror:0.073801
# [345]	eval-merror:0.073801
# [346]	eval-merror:0.073801
# [347]	eval-merror:0.073801
# [348]	eval-merror:0.071956
# [349]	eval-merror:0.071956
# [350]	eval-merror:0.071956
# [351]	eval-merror:0.071956
# [352]	eval-merror:0.071956
# [353]	eval-merror:0.071956
# [354]	eval-merror:0.071956
# [355]	eval-merror:0.071956
# [356]	eval-merror:0.071956
# [357]	eval-merror:0.071956
# [358]	eval-merror:0.071956
# [359]	eval-merror:0.071956
# [360]	eval-merror:0.071956
# [361]	eval-merror:0.071956
# [362]	eval-merror:0.071956
# [363]	eval-merror:0.071956
# [364]	eval-merror:0.071956
# [365]	eval-merror:0.071956
# [366]	eval-merror:0.071956
# [367]	eval-merror:0.071956
# [368]	eval-merror:0.071956
# [369]	eval-merror:0.073801
# [370]	eval-merror:0.075646
# [371]	eval-merror:0.075646
# [372]	eval-merror:0.075646
# [373]	eval-merror:0.073801
# [374]	eval-merror:0.071956
# [375]	eval-merror:0.071956
# [376]	eval-merror:0.071956
# [377]	eval-merror:0.075646
# [378]	eval-merror:0.071956
# [379]	eval-merror:0.071956
# [380]	eval-merror:0.071956
# [381]	eval-merror:0.071956
# [382]	eval-merror:0.071956
# [383]	eval-merror:0.073801
# [384]	eval-merror:0.073801
# [385]	eval-merror:0.073801
# [386]	eval-merror:0.073801
# [387]	eval-merror:0.073801
# [388]	eval-merror:0.073801
# [389]	eval-merror:0.073801
# [390]	eval-merror:0.073801
# [391]	eval-merror:0.075646
# [392]	eval-merror:0.075646
# [393]	eval-merror:0.075646
# [394]	eval-merror:0.073801
# [395]	eval-merror:0.073801
# [396]	eval-merror:0.073801
# [397]	eval-merror:0.073801
# [398]	eval-merror:0.073801
# [399]	eval-merror:0.075646
# [400]	eval-merror:0.073801
# [401]	eval-merror:0.073801
# [402]	eval-merror:0.073801
# [403]	eval-merror:0.073801
# [404]	eval-merror:0.073801
# [405]	eval-merror:0.073801
# [406]	eval-merror:0.073801
# [407]	eval-merror:0.073801
# [408]	eval-merror:0.073801
# [409]	eval-merror:0.073801
# [410]	eval-merror:0.071956
# [411]	eval-merror:0.071956
# [412]	eval-merror:0.073801
# [413]	eval-merror:0.073801
# [414]	eval-merror:0.075646
# [415]	eval-merror:0.075646
# [416]	eval-merror:0.075646
# [417]	eval-merror:0.075646
# [418]	eval-merror:0.075646
# [419]	eval-merror:0.075646
# [420]	eval-merror:0.075646
# [421]	eval-merror:0.075646
# [422]	eval-merror:0.075646
# [423]	eval-merror:0.075646
# [424]	eval-merror:0.075646
# [425]	eval-merror:0.075646
# [426]	eval-merror:0.075646
# [427]	eval-merror:0.075646
# [428]	eval-merror:0.075646
# [429]	eval-merror:0.075646
# [430]	eval-merror:0.075646
# [431]	eval-merror:0.073801
# [432]	eval-merror:0.073801
# [433]	eval-merror:0.073801
# [434]	eval-merror:0.073801
# [435]	eval-merror:0.073801
# [436]	eval-merror:0.073801
# [437]	eval-merror:0.073801
# [438]	eval-merror:0.073801
# [439]	eval-merror:0.071956
# [440]	eval-merror:0.071956
# [441]	eval-merror:0.073801
# [442]	eval-merror:0.073801
# [443]	eval-merror:0.075646
# [444]	eval-merror:0.073801
# [445]	eval-merror:0.075646
# [446]	eval-merror:0.075646
# [447]	eval-merror:0.073801
# [448]	eval-merror:0.073801
# Stopping. Best iteration:
# [348]	eval-merror:0.071956
#
# [Fold 7/7]
# [0]	eval-merror:0.371534
# Will train until eval-merror hasn't improved in 100 rounds.
# [1]	eval-merror:0.303142
# [2]	eval-merror:0.292052
# [3]	eval-merror:0.25878
# [4]	eval-merror:0.232902
# [5]	eval-merror:0.221811
# [6]	eval-merror:0.219963
# [7]	eval-merror:0.207024
# [8]	eval-merror:0.195933
# [9]	eval-merror:0.18854
# [10]	eval-merror:0.179298
# [11]	eval-merror:0.175601
# [12]	eval-merror:0.175601
# [13]	eval-merror:0.160813
# [14]	eval-merror:0.166359
# [15]	eval-merror:0.16451
# [16]	eval-merror:0.168207
# [17]	eval-merror:0.166359
# [18]	eval-merror:0.162662
# [19]	eval-merror:0.157116
# [20]	eval-merror:0.155268
# [21]	eval-merror:0.158965
# [22]	eval-merror:0.151571
# [23]	eval-merror:0.15342
# [24]	eval-merror:0.147874
# [25]	eval-merror:0.146026
# [26]	eval-merror:0.142329
# [27]	eval-merror:0.142329
# [28]	eval-merror:0.142329
# [29]	eval-merror:0.142329
# [30]	eval-merror:0.142329
# [31]	eval-merror:0.138632
# [32]	eval-merror:0.136784
# [33]	eval-merror:0.134935
# [34]	eval-merror:0.133087
# [35]	eval-merror:0.133087
# [36]	eval-merror:0.131238
# [37]	eval-merror:0.127542
# [38]	eval-merror:0.131238
# [39]	eval-merror:0.125693
# [40]	eval-merror:0.121996
# [41]	eval-merror:0.127542
# [42]	eval-merror:0.123845
# [43]	eval-merror:0.118299
# [44]	eval-merror:0.120148
# [45]	eval-merror:0.118299
# [46]	eval-merror:0.118299
# [47]	eval-merror:0.116451
# [48]	eval-merror:0.116451
# [49]	eval-merror:0.114603
# [50]	eval-merror:0.114603
# [51]	eval-merror:0.114603
# [52]	eval-merror:0.112754
# [53]	eval-merror:0.112754
# [54]	eval-merror:0.112754
# [55]	eval-merror:0.112754
# [56]	eval-merror:0.112754
# [57]	eval-merror:0.110906
# [58]	eval-merror:0.109057
# [59]	eval-merror:0.10536
# [60]	eval-merror:0.107209
# [61]	eval-merror:0.109057
# [62]	eval-merror:0.107209
# [63]	eval-merror:0.10536
# [64]	eval-merror:0.10536
# [65]	eval-merror:0.107209
# [66]	eval-merror:0.10536
# [67]	eval-merror:0.10536
# [68]	eval-merror:0.10536
# [69]	eval-merror:0.10536
# [70]	eval-merror:0.103512
# [71]	eval-merror:0.099815
# [72]	eval-merror:0.103512
# [73]	eval-merror:0.103512
# [74]	eval-merror:0.103512
# [75]	eval-merror:0.101664
# [76]	eval-merror:0.103512
# [77]	eval-merror:0.101664
# [78]	eval-merror:0.101664
# [79]	eval-merror:0.099815
# [80]	eval-merror:0.099815
# [81]	eval-merror:0.101664
# [82]	eval-merror:0.099815
# [83]	eval-merror:0.099815
# [84]	eval-merror:0.101664
# [85]	eval-merror:0.101664
# [86]	eval-merror:0.101664
# [87]	eval-merror:0.101664
# [88]	eval-merror:0.101664
# [89]	eval-merror:0.101664
# [90]	eval-merror:0.101664
# [91]	eval-merror:0.101664
# [92]	eval-merror:0.099815
# [93]	eval-merror:0.099815
# [94]	eval-merror:0.096118
# [95]	eval-merror:0.101664
# [96]	eval-merror:0.101664
# [97]	eval-merror:0.099815
# [98]	eval-merror:0.099815
# [99]	eval-merror:0.103512
# [100]	eval-merror:0.103512
# [101]	eval-merror:0.099815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-32fbfa69a679> in <module>()
#      11     y_train, y_valid = y[train_index], y[test_index]
#      12
# ---> 13     preds, model = runXGB(X_train, y_train, X_valid, y_valid, test)
#      14
#      15     submission['surface' + str(i+1)] = preds
#
# <ipython-input-13-826d6867baf8> in runXGB(train_X, train_y, validation_X, validation_y, test_X)
#      26
#      27     evallist = [(xgcv,'eval')]
# ---> 28     model = xgb.train(plst, xgtrain, num_rounds, evallist, early_stopping_rounds = 100)
#      29
#      30     pred_test_y = model.predict(xgtest)
#
# /opt/conda/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /opt/conda/lib/python3.6/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1108         if fobj is None:
#    1109             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1110                                                     dtrain.handle))
#    1111         else:
#    1112             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
submission1 = pd.read_csv('submission_1.csv')
submission2 = pd.read_csv('submission_2.csv')
submission3 = pd.read_csv('submission_3.csv')
submission4 = pd.read_csv('submission_4.csv')
submission5 = pd.read_csv('submission_5.csv')
submission6 = pd.read_csv('submission_6.csv')
submission7 = pd.read_csv('submission_7.csv')

# %%
from functools import reduce
submissions = [submission1,submission2,submission3,submission4,submission5,submission6,submission7]
submission_final = reduce(lambda left,right: pd.merge(left,right,on='series_id'), submissions)

# %%
submission_final = pd.DataFrame(submission_final.mode(axis='columns'))
submission_final = pd.DataFrame(submission_final[submission_final.columns[0]])
submission_final.columns = ['surface']
submission_final['surface'] = submission_final['surface'].astype('int')
submission_final['surface'] = le.inverse_transform(submission_final['surface'])
submission_final['series_id'] = test_raw.index.values
submission_final.to_csv('submission_final.csv', index=False)
