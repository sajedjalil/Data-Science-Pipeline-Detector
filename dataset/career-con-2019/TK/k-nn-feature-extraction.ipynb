# %% [markdown]
# ## Notebook Summary
#
# I have tried to extract features with K-NN based on this Japanese [article](https://blog.amedama.jp/entry/knn-feature-extraction).
# As a result, these features seemed to cause overfitting into train data set.
# - trained with features extracted with k-NN
#    - Local CV avarage accuracy : 0.9681818337327661
#    - LB accuracy : 0.67
# - trained with features extracted **without k-NN**
#    - Local CV avarage accuracy : 0.9226371135121014
#    - LB accuracy : 0.72
#
# I don't know whether my scripts is correct or not. Please feel free to comment and advice!

# %%
import numpy as np
import pandas as pd
import math
import multiprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
import functools
from concurrent.futures import ProcessPoolExecutor
from sklearn.model_selection import KFold

# %%
train = pd.read_csv('../input/X_train.csv')
test = pd.read_csv('../input/X_test.csv')
target = pd.read_csv('../input/y_train.csv')
submit = pd.read_csv('../input/sample_submission.csv')

# %%
# https://stackoverflow.com/questions/53033620/how-to-convert-euler-angles-to-quaternions-and-get-the-same-euler-angles-back-fr?rq=1
def quaternion_to_euler(x, y, z, w):

    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z
    
def feature_engineering(df):
    
    df_new = pd.DataFrame()
    
    # calculate euclidean distance
    df['total_angular_velocity'] = np.sqrt(df['angular_velocity_X'] ** 2 + df['angular_velocity_Y'] ** 2 + df['angular_velocity_Z'] ** 2)
    df['total_linear_acceleration'] = np.sqrt(df['linear_acceleration_X'] ** 2 + df['linear_acceleration_Y'] ** 2 + df['linear_acceleration_Z'] ** 2)
    df['total_orientation'] = np.sqrt(df['orientation_X'] ** 2 + df['orientation_Y'] ** 2 + df['orientation_Z'] ** 2 + df['orientation_W'] ** 2)

    # calculate absolute value 
    df['linear_acceleration_X_abs'] = df['linear_acceleration_X'].where(df['linear_acceleration_X']>=0, - df['linear_acceleration_X'])
    df['linear_acceleration_Y_abs'] = df['linear_acceleration_Y'].where(df['linear_acceleration_Y']>=0, - df['linear_acceleration_Y'])
    df['linear_acceleration_Z_abs'] = df['linear_acceleration_Z'].where(df['linear_acceleration_Z']>=0, - df['linear_acceleration_Z'])
    
    # how much Robot have acceleration compared to velocity                                           
    df['acc_vs_vel'] = df['total_linear_acceleration'] / df['total_angular_velocity']
    
    x, y, z, w = df['orientation_X'].tolist(), df['orientation_Y'].tolist(), df['orientation_Z'].tolist(), df['orientation_W'].tolist()
    nx, ny, nz = [], [], []
    
    for i in range(len(x)):
        
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx.append(xx)
        ny.append(yy)
        nz.append(zz)
    
    df['euler_x'] = nx
    df['euler_y'] = ny
    df['euler_z'] = nz
    
    df['total_angle'] = np.sqrt(df['euler_x'] ** 2 + df['euler_y'] ** 2 + df['euler_z'] ** 2)
    df['angle_vs_acc'] = df['total_angle'] / df['total_linear_acceleration']
    df['angle_vs_vel'] = df['total_angle'] / df['total_angular_velocity']
    
    # add interaction feature
    df['acc_times_vel'] = df['total_linear_acceleration'] * df['total_angular_velocity']
    df['angle_times_acc'] = df['total_angle'] * df['total_linear_acceleration']
    df['angle_times_vel'] = df['total_angle'] * df['total_angular_velocity']
    df['angle_times_vel_times_acc'] = df['total_angle'] * df['total_angular_velocity'] * df['total_linear_acceleration']

    def f1(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    def f2(x):
        return np.mean(np.abs(np.diff(x)))
    
    for col in df.columns:
        
        if col in ['row_id', 'series_id', 'measurement_number']:
            continue
        
        df_new[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        df_new[col + '_min'] = df.groupby(['series_id'])[col].min()
        df_new[col + '_max'] = df.groupby(['series_id'])[col].max()
        df_new[col + '_std'] = df.groupby(['series_id'])[col].std()
        df_new[col + '_max_to_min'] = df_new[col + '_max'] / df_new[col + '_min']

        df_new[col + '_mean_abs_change'] = df.groupby('series_id')[col].apply(f2)
        df_new[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(f1)
        
        df_new[col + '_abs_max'] = df.groupby('series_id')[col].apply(lambda x: np.max(np.abs(x)))
        df_new[col + '_abs_min'] = df.groupby('series_id')[col].apply(lambda x: np.min(np.abs(x)))


    return df_new

# %%
with multiprocessing.Pool() as pool: 
    train, test = pool.map(feature_engineering, [train, test])

# %%
train = train.reset_index()
test = test.reset_index()

# %%
le = LabelEncoder()
target['surface'] = le.fit_transform(target['surface'])

# %%
def _distance(a, b):
    distance = np.linalg.norm(a - b)
    
    return distance

def _knn_distance(xtr_c, target, k):
    distances = np.array([_distance(target, x) for x in xtr_c])
    sorted_distances = np.sort(distances)
    nearest_distances = sorted_distances[:k]
    sum_distances = np.sum(nearest_distances)

    return sum_distances

def _knn_distance_fold(xtr_c, k, folds, target):
    distances = np.empty([folds])

    kf = KFold(shuffle=True, n_splits=folds)
    for i, (train_index, _) in enumerate(kf.split(xtr_c)):
        xtr_c_sampled = xtr_c[train_index]
        distance = _knn_distance(xtr_c_sampled, target, k)
        distances[i] = distance

    average_distance = distances.mean()

    return average_distance


def knn_extract(xtr, ytr, xte, k=1, folds=5, nprocesses=-1):
    if nprocesses == -1:
        nprocesses = multiprocessing.cpu_count()

    classes = np.unique(ytr)
    features = np.zeros([len(xte), len(classes) * k])

    for i, class_ in enumerate(classes):
        xtr_c = xtr[ytr == class_]

        for j, k_n in enumerate(range(1, k + 1), 1):
            f = functools.partial(_knn_distance_fold, xtr_c, k_n, folds)
            with ProcessPoolExecutor(max_workers=nprocesses) as executor:
                feature = executor.map(f, xte)
                features[:, i * j] = list(feature)

    return features

# %%
train_array = train.values
test_array = test.values
knn_train = knn_extract(train_array, target['surface'].values, train_array)
knn_test = knn_extract(train_array, target['surface'].values, test_array)

# %%
knn_train = pd.DataFrame(knn_train)
knn_test = pd.DataFrame(knn_test)
knn_train = pd.concat([train, knn_train], axis=1)
knn_test = pd.concat([test, knn_test], axis=1)

# %%
# replace NAN to 0
train.fillna(0, inplace=True)
test.fillna(0, inplace=True)
knn_train.fillna(0, inplace=True)
knn_test.fillna(0, inplace=True)

# replace infinite value to zero
train.replace(-np.inf, 0, inplace=True)
train.replace(np.inf, 0, inplace=True)
test.replace(-np.inf, 0, inplace=True)
test.replace(np.inf, 0, inplace=True)
knn_train.replace(-np.inf, 0, inplace=True)
knn_train.replace(np.inf, 0, inplace=True)
knn_test.replace(-np.inf, 0, inplace=True)
knn_test.replace(np.inf, 0, inplace=True)

# %% [markdown]
# ### train with features with KNN

# %%
folds = StratifiedKFold(n_splits=100, shuffle=True, random_state=546789)
sub_preds_rf = np.zeros((knn_test.shape[0], 9))
score = 0
counter = 0

for train_index, test_index in folds.split(knn_train, target['surface']):
    
    clf_knn = RandomForestClassifier(n_estimators=200, n_jobs=-1)
    clf_knn.fit(knn_train.iloc[train_index], target['surface'][train_index])
    sub_preds_rf += clf_knn.predict_proba(knn_test) / folds.n_splits
    score += clf_knn.score(knn_train.iloc[test_index], target['surface'][test_index])
    counter += 1

print('avg accuracy : {}'.format(score / folds.n_splits))
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 21 members, which is too few. The minimum number of members in any class cannot be less than n_splits=100.
#   % (min_groups, self.n_splits)), Warning)
# avg accuracy : 0.9681818337327661

# %%
fti_knn = clf_knn.feature_importances_

for i, feat in enumerate(knn_train.columns):
    print('{0} : {1:>.6f}'.format(feat, fti_knn[i]))
# Out:
# series_id : 0.015044
# orientation_X_mean : 0.017196
# orientation_X_min : 0.010210
# orientation_X_max : 0.011695
# orientation_X_std : 0.001769
# orientation_X_max_to_min : 0.007179
# orientation_X_mean_abs_change : 0.001980
# orientation_X_mean_change_of_abs_change : 0.000590
# orientation_X_abs_max : 0.006935
# orientation_X_abs_min : 0.005689
# orientation_Y_mean : 0.006732
# orientation_Y_min : 0.006968
# orientation_Y_max : 0.007212
# orientation_Y_std : 0.001977
# orientation_Y_max_to_min : 0.003812
# orientation_Y_mean_abs_change : 0.002200
# orientation_Y_mean_change_of_abs_change : 0.000468
# orientation_Y_abs_max : 0.007936
# orientation_Y_abs_min : 0.006610
# orientation_Z_mean : 0.010866
# orientation_Z_min : 0.010907
# orientation_Z_max : 0.010054
# orientation_Z_std : 0.001148
# orientation_Z_max_to_min : 0.003253
# orientation_Z_mean_abs_change : 0.001952
# orientation_Z_mean_change_of_abs_change : 0.000603
# orientation_Z_abs_max : 0.008156
# orientation_Z_abs_min : 0.008358
# orientation_W_mean : 0.012079
# orientation_W_min : 0.011360
# orientation_W_max : 0.010838
# orientation_W_std : 0.001105
# orientation_W_max_to_min : 0.006109
# orientation_W_mean_abs_change : 0.001778
# orientation_W_mean_change_of_abs_change : 0.000632
# orientation_W_abs_max : 0.005746
# orientation_W_abs_min : 0.007707
# angular_velocity_X_mean : 0.001301
# angular_velocity_X_min : 0.001318
# angular_velocity_X_max : 0.001420
# angular_velocity_X_std : 0.003238
# angular_velocity_X_max_to_min : 0.000891
# angular_velocity_X_mean_abs_change : 0.004112
# angular_velocity_X_mean_change_of_abs_change : 0.000775
# angular_velocity_X_abs_max : 0.002001
# angular_velocity_X_abs_min : 0.000669
# angular_velocity_Y_mean : 0.003342
# angular_velocity_Y_min : 0.001910
# angular_velocity_Y_max : 0.002566
# angular_velocity_Y_std : 0.003127
# angular_velocity_Y_max_to_min : 0.003283
# angular_velocity_Y_mean_abs_change : 0.005189
# angular_velocity_Y_mean_change_of_abs_change : 0.000637
# angular_velocity_Y_abs_max : 0.001507
# angular_velocity_Y_abs_min : 0.000990
# angular_velocity_Z_mean : 0.003546
# angular_velocity_Z_min : 0.003947
# angular_velocity_Z_max : 0.002685
# angular_velocity_Z_std : 0.001447
# angular_velocity_Z_max_to_min : 0.002069
# angular_velocity_Z_mean_abs_change : 0.002928
# angular_velocity_Z_mean_change_of_abs_change : 0.000667
# angular_velocity_Z_abs_max : 0.001758
# angular_velocity_Z_abs_min : 0.001575
# linear_acceleration_X_mean : 0.001248
# linear_acceleration_X_min : 0.003015
# linear_acceleration_X_max : 0.003029
# linear_acceleration_X_std : 0.003312
# linear_acceleration_X_max_to_min : 0.000753
# linear_acceleration_X_mean_abs_change : 0.003658
# linear_acceleration_X_mean_change_of_abs_change : 0.000659
# linear_acceleration_X_abs_max : 0.005156
# linear_acceleration_X_abs_min : 0.001268
# linear_acceleration_Y_mean : 0.001190
# linear_acceleration_Y_min : 0.002120
# linear_acceleration_Y_max : 0.002435
# linear_acceleration_Y_std : 0.003246
# linear_acceleration_Y_max_to_min : 0.001287
# linear_acceleration_Y_mean_abs_change : 0.010657
# linear_acceleration_Y_mean_change_of_abs_change : 0.000650
# linear_acceleration_Y_abs_max : 0.002477
# linear_acceleration_Y_abs_min : 0.001564
# linear_acceleration_Z_mean : 0.001272
# linear_acceleration_Z_min : 0.002793
# linear_acceleration_Z_max : 0.001916
# linear_acceleration_Z_std : 0.005550
# linear_acceleration_Z_max_to_min : 0.001718
# linear_acceleration_Z_mean_abs_change : 0.009791
# linear_acceleration_Z_mean_change_of_abs_change : 0.000559
# linear_acceleration_Z_abs_max : 0.003490
# linear_acceleration_Z_abs_min : 0.001504
# total_angular_velocity_mean : 0.001858
# total_angular_velocity_min : 0.001232
# total_angular_velocity_max : 0.001603
# total_angular_velocity_std : 0.001824
# total_angular_velocity_max_to_min : 0.001270
# total_angular_velocity_mean_abs_change : 0.004134
# total_angular_velocity_mean_change_of_abs_change : 0.000695
# total_angular_velocity_abs_max : 0.002545
# total_angular_velocity_abs_min : 0.001021
# total_linear_acceleration_mean : 0.003373
# total_linear_acceleration_min : 0.001668
# total_linear_acceleration_max : 0.004098
# total_linear_acceleration_std : 0.005723
# total_linear_acceleration_max_to_min : 0.002623
# total_linear_acceleration_mean_abs_change : 0.008657
# total_linear_acceleration_mean_change_of_abs_change : 0.000553
# total_linear_acceleration_abs_max : 0.003323
# total_linear_acceleration_abs_min : 0.001243
# total_orientation_mean : 0.000162
# total_orientation_min : 0.000375
# total_orientation_max : 0.000313
# total_orientation_std : 0.000137
# total_orientation_max_to_min : 0.000725
# total_orientation_mean_abs_change : 0.000288
# total_orientation_mean_change_of_abs_change : 0.000000
# total_orientation_abs_max : 0.000394
# total_orientation_abs_min : 0.000429
# linear_acceleration_X_abs_mean : 0.003032
# linear_acceleration_X_abs_std : 0.006512
# linear_acceleration_X_abs_max_to_min : 0.001148
# linear_acceleration_X_abs_mean_abs_change : 0.006882
# linear_acceleration_X_abs_mean_change_of_abs_change : 0.000692
# linear_acceleration_X_abs_abs_max : 0.003666
# linear_acceleration_X_abs_abs_min : 0.001024
# linear_acceleration_Y_abs_mean : 0.002307
# linear_acceleration_Y_abs_std : 0.002794
# linear_acceleration_Y_abs_max_to_min : 0.002303
# linear_acceleration_Y_abs_mean_abs_change : 0.006936
# linear_acceleration_Y_abs_mean_change_of_abs_change : 0.000649
# linear_acceleration_Y_abs_abs_max : 0.002724
# linear_acceleration_Y_abs_abs_min : 0.001730
# linear_acceleration_Z_abs_mean : 0.001311
# linear_acceleration_Z_abs_std : 0.004392
# linear_acceleration_Z_abs_max_to_min : 0.004149
# linear_acceleration_Z_abs_mean_abs_change : 0.010798
# linear_acceleration_Z_abs_mean_change_of_abs_change : 0.000522
# linear_acceleration_Z_abs_abs_max : 0.003117
# linear_acceleration_Z_abs_abs_min : 0.002029
# acc_vs_vel_mean : 0.001426
# acc_vs_vel_min : 0.001691
# acc_vs_vel_max : 0.001226
# acc_vs_vel_std : 0.001224
# acc_vs_vel_max_to_min : 0.001056
# acc_vs_vel_mean_abs_change : 0.001605
# acc_vs_vel_mean_change_of_abs_change : 0.000646
# acc_vs_vel_abs_max : 0.001147
# acc_vs_vel_abs_min : 0.001388
# euler_x_mean : 0.003882
# euler_x_min : 0.003418
# euler_x_max : 0.004158
# euler_x_std : 0.002327
# euler_x_max_to_min : 0.002285
# euler_x_mean_abs_change : 0.002566
# euler_x_mean_change_of_abs_change : 0.000614
# euler_x_abs_max : 0.004441
# euler_x_abs_min : 0.003615
# euler_y_mean : 0.009658
# euler_y_min : 0.008710
# euler_y_max : 0.007504
# euler_y_std : 0.001879
# euler_y_max_to_min : 0.002298
# euler_y_mean_abs_change : 0.003713
# euler_y_mean_change_of_abs_change : 0.000483
# euler_y_abs_max : 0.007531
# euler_y_abs_min : 0.007238
# euler_z_mean : 0.008724
# euler_z_min : 0.007802
# euler_z_max : 0.008133
# euler_z_std : 0.001933
# euler_z_max_to_min : 0.004732
# euler_z_mean_abs_change : 0.001772
# euler_z_mean_change_of_abs_change : 0.000637
# euler_z_abs_max : 0.005776
# euler_z_abs_min : 0.007070
# total_angle_mean : 0.007162
# total_angle_min : 0.006034
# total_angle_max : 0.007484
# total_angle_std : 0.001730
# total_angle_max_to_min : 0.001461
# total_angle_mean_abs_change : 0.001545
# total_angle_mean_change_of_abs_change : 0.000823
# total_angle_abs_max : 0.006540
# total_angle_abs_min : 0.005325
# angle_vs_acc_mean : 0.004310
# angle_vs_acc_min : 0.001999
# angle_vs_acc_max : 0.001423
# angle_vs_acc_std : 0.003374
# angle_vs_acc_max_to_min : 0.001448
# angle_vs_acc_mean_abs_change : 0.004864
# angle_vs_acc_mean_change_of_abs_change : 0.000569
# angle_vs_acc_abs_max : 0.001206
# angle_vs_acc_abs_min : 0.001373
# angle_vs_vel_mean : 0.001624
# angle_vs_vel_min : 0.001626
# angle_vs_vel_max : 0.000779
# angle_vs_vel_std : 0.001401
# angle_vs_vel_max_to_min : 0.001151
# angle_vs_vel_mean_abs_change : 0.002134
# angle_vs_vel_mean_change_of_abs_change : 0.000602
# angle_vs_vel_abs_max : 0.001236
# angle_vs_vel_abs_min : 0.001338
# acc_times_vel_mean : 0.001809
# acc_times_vel_min : 0.001362
# acc_times_vel_max : 0.001878
# acc_times_vel_std : 0.002421
# acc_times_vel_max_to_min : 0.001143
# acc_times_vel_mean_abs_change : 0.008858
# acc_times_vel_mean_change_of_abs_change : 0.000569
# acc_times_vel_abs_max : 0.001523
# acc_times_vel_abs_min : 0.001215
# angle_times_acc_mean : 0.003076
# angle_times_acc_min : 0.001130
# angle_times_acc_max : 0.002457
# angle_times_acc_std : 0.004364
# angle_times_acc_max_to_min : 0.002475
# angle_times_acc_mean_abs_change : 0.003511
# angle_times_acc_mean_change_of_abs_change : 0.000594
# angle_times_acc_abs_max : 0.002242
# angle_times_acc_abs_min : 0.001332
# angle_times_vel_mean : 0.001680
# angle_times_vel_min : 0.000732
# angle_times_vel_max : 0.001565
# angle_times_vel_std : 0.001378
# angle_times_vel_max_to_min : 0.000950
# angle_times_vel_mean_abs_change : 0.002606
# angle_times_vel_mean_change_of_abs_change : 0.000629
# angle_times_vel_abs_max : 0.001505
# angle_times_vel_abs_min : 0.001205
# angle_times_vel_times_acc_mean : 0.002157
# angle_times_vel_times_acc_min : 0.001045
# angle_times_vel_times_acc_max : 0.001424
# angle_times_vel_times_acc_std : 0.002283
# angle_times_vel_times_acc_max_to_min : 0.001497
# angle_times_vel_times_acc_mean_abs_change : 0.007618
# angle_times_vel_times_acc_mean_change_of_abs_change : 0.000642
# angle_times_vel_times_acc_abs_max : 0.002108
# angle_times_vel_times_acc_abs_min : 0.001575
# 0 : 0.009730
# 1 : 0.041663
# 2 : 0.027507
# 3 : 0.003743
# 4 : 0.015821
# 5 : 0.043598
# 6 : 0.014743
# 7 : 0.031362
# 8 : 0.043365

# %%
submit['surface'] = le.inverse_transform(sub_preds_rf.argmax(axis=1))
submit.to_csv('submit_with_knn.csv', index=False)

# %% [markdown]
# ### train with features without KNN

# %%
folds = StratifiedKFold(n_splits=100, shuffle=True, random_state=546789)
sub_preds_rf = np.zeros((test.shape[0], 9))
score = 0
counter = 0

for train_index, test_index in folds.split(train, target['surface']):
    
    clf = RandomForestClassifier(n_estimators=200, n_jobs=-1)
    clf.fit(train.iloc[train_index], target['surface'][train_index])
    sub_preds_rf += clf.predict_proba(test) / folds.n_splits
    score += clf.score(train.iloc[test_index], target['surface'][test_index])
    counter += 1

print('avg accuracy : {}'.format(score / folds.n_splits))
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 21 members, which is too few. The minimum number of members in any class cannot be less than n_splits=100.
#   % (min_groups, self.n_splits)), Warning)
# avg accuracy : 0.9226371135121014

# %%
fti = clf.feature_importances_

for i, feat in enumerate(train.columns):
    print('\t{0} : {1:>.6f}'.format(feat, fti[i]))
# Out:
# 	series_id : 0.020132
# 	orientation_X_mean : 0.018480
# 	orientation_X_min : 0.018299
# 	orientation_X_max : 0.019384
# 	orientation_X_std : 0.003238
# 	orientation_X_max_to_min : 0.007586
# 	orientation_X_mean_abs_change : 0.003104
# 	orientation_X_mean_change_of_abs_change : 0.000768
# 	orientation_X_abs_max : 0.009617
# 	orientation_X_abs_min : 0.008853
# 	orientation_Y_mean : 0.009151
# 	orientation_Y_min : 0.009161
# 	orientation_Y_max : 0.009539
# 	orientation_Y_std : 0.002849
# 	orientation_Y_max_to_min : 0.005403
# 	orientation_Y_mean_abs_change : 0.002821
# 	orientation_Y_mean_change_of_abs_change : 0.000707
# 	orientation_Y_abs_max : 0.010163
# 	orientation_Y_abs_min : 0.009032
# 	orientation_Z_mean : 0.013154
# 	orientation_Z_min : 0.014192
# 	orientation_Z_max : 0.012104
# 	orientation_Z_std : 0.001501
# 	orientation_Z_max_to_min : 0.005376
# 	orientation_Z_mean_abs_change : 0.002993
# 	orientation_Z_mean_change_of_abs_change : 0.000768
# 	orientation_Z_abs_max : 0.013256
# 	orientation_Z_abs_min : 0.010554
# 	orientation_W_mean : 0.015344
# 	orientation_W_min : 0.014308
# 	orientation_W_max : 0.014066
# 	orientation_W_std : 0.001706
# 	orientation_W_max_to_min : 0.008384
# 	orientation_W_mean_abs_change : 0.002329
# 	orientation_W_mean_change_of_abs_change : 0.000920
# 	orientation_W_abs_max : 0.009254
# 	orientation_W_abs_min : 0.010752
# 	angular_velocity_X_mean : 0.001727
# 	angular_velocity_X_min : 0.002292
# 	angular_velocity_X_max : 0.002022
# 	angular_velocity_X_std : 0.004256
# 	angular_velocity_X_max_to_min : 0.001422
# 	angular_velocity_X_mean_abs_change : 0.003464
# 	angular_velocity_X_mean_change_of_abs_change : 0.000922
# 	angular_velocity_X_abs_max : 0.002031
# 	angular_velocity_X_abs_min : 0.000856
# 	angular_velocity_Y_mean : 0.004118
# 	angular_velocity_Y_min : 0.002570
# 	angular_velocity_Y_max : 0.003150
# 	angular_velocity_Y_std : 0.003066
# 	angular_velocity_Y_max_to_min : 0.003848
# 	angular_velocity_Y_mean_abs_change : 0.007646
# 	angular_velocity_Y_mean_change_of_abs_change : 0.000736
# 	angular_velocity_Y_abs_max : 0.002547
# 	angular_velocity_Y_abs_min : 0.001273
# 	angular_velocity_Z_mean : 0.004927
# 	angular_velocity_Z_min : 0.004321
# 	angular_velocity_Z_max : 0.003191
# 	angular_velocity_Z_std : 0.002290
# 	angular_velocity_Z_max_to_min : 0.002991
# 	angular_velocity_Z_mean_abs_change : 0.002278
# 	angular_velocity_Z_mean_change_of_abs_change : 0.001019
# 	angular_velocity_Z_abs_max : 0.002778
# 	angular_velocity_Z_abs_min : 0.001628
# 	linear_acceleration_X_mean : 0.001978
# 	linear_acceleration_X_min : 0.002765
# 	linear_acceleration_X_max : 0.004500
# 	linear_acceleration_X_std : 0.006231
# 	linear_acceleration_X_max_to_min : 0.001270
# 	linear_acceleration_X_mean_abs_change : 0.006184
# 	linear_acceleration_X_mean_change_of_abs_change : 0.000839
# 	linear_acceleration_X_abs_max : 0.005893
# 	linear_acceleration_X_abs_min : 0.001019
# 	linear_acceleration_Y_mean : 0.002037
# 	linear_acceleration_Y_min : 0.003885
# 	linear_acceleration_Y_max : 0.003599
# 	linear_acceleration_Y_std : 0.004904
# 	linear_acceleration_Y_max_to_min : 0.001696
# 	linear_acceleration_Y_mean_abs_change : 0.010724
# 	linear_acceleration_Y_mean_change_of_abs_change : 0.001012
# 	linear_acceleration_Y_abs_max : 0.003937
# 	linear_acceleration_Y_abs_min : 0.003067
# 	linear_acceleration_Z_mean : 0.001696
# 	linear_acceleration_Z_min : 0.003241
# 	linear_acceleration_Z_max : 0.002100
# 	linear_acceleration_Z_std : 0.008518
# 	linear_acceleration_Z_max_to_min : 0.003702
# 	linear_acceleration_Z_mean_abs_change : 0.011968
# 	linear_acceleration_Z_mean_change_of_abs_change : 0.000805
# 	linear_acceleration_Z_abs_max : 0.002921
# 	linear_acceleration_Z_abs_min : 0.003290
# 	total_angular_velocity_mean : 0.002246
# 	total_angular_velocity_min : 0.001073
# 	total_angular_velocity_max : 0.002416
# 	total_angular_velocity_std : 0.002134
# 	total_angular_velocity_max_to_min : 0.001239
# 	total_angular_velocity_mean_abs_change : 0.004260
# 	total_angular_velocity_mean_change_of_abs_change : 0.000855
# 	total_angular_velocity_abs_max : 0.001979
# 	total_angular_velocity_abs_min : 0.001671
# 	total_linear_acceleration_mean : 0.004875
# 	total_linear_acceleration_min : 0.001425
# 	total_linear_acceleration_max : 0.005207
# 	total_linear_acceleration_std : 0.004306
# 	total_linear_acceleration_max_to_min : 0.002214
# 	total_linear_acceleration_mean_abs_change : 0.007894
# 	total_linear_acceleration_mean_change_of_abs_change : 0.000797
# 	total_linear_acceleration_abs_max : 0.004230
# 	total_linear_acceleration_abs_min : 0.001291
# 	total_orientation_mean : 0.000219
# 	total_orientation_min : 0.000582
# 	total_orientation_max : 0.000506
# 	total_orientation_std : 0.000164
# 	total_orientation_max_to_min : 0.000759
# 	total_orientation_mean_abs_change : 0.000368
# 	total_orientation_mean_change_of_abs_change : 0.000003
# 	total_orientation_abs_max : 0.000448
# 	total_orientation_abs_min : 0.000483
# 	linear_acceleration_X_abs_mean : 0.006041
# 	linear_acceleration_X_abs_std : 0.004590
# 	linear_acceleration_X_abs_max_to_min : 0.000917
# 	linear_acceleration_X_abs_mean_abs_change : 0.007115
# 	linear_acceleration_X_abs_mean_change_of_abs_change : 0.000911
# 	linear_acceleration_X_abs_abs_max : 0.005192
# 	linear_acceleration_X_abs_abs_min : 0.001060
# 	linear_acceleration_Y_abs_mean : 0.003002
# 	linear_acceleration_Y_abs_std : 0.003627
# 	linear_acceleration_Y_abs_max_to_min : 0.003095
# 	linear_acceleration_Y_abs_mean_abs_change : 0.009027
# 	linear_acceleration_Y_abs_mean_change_of_abs_change : 0.000936
# 	linear_acceleration_Y_abs_abs_max : 0.003385
# 	linear_acceleration_Y_abs_abs_min : 0.002731
# 	linear_acceleration_Z_abs_mean : 0.001939
# 	linear_acceleration_Z_abs_std : 0.008229
# 	linear_acceleration_Z_abs_max_to_min : 0.003221
# 	linear_acceleration_Z_abs_mean_abs_change : 0.009014
# 	linear_acceleration_Z_abs_mean_change_of_abs_change : 0.000862
# 	linear_acceleration_Z_abs_abs_max : 0.003067
# 	linear_acceleration_Z_abs_abs_min : 0.002006
# 	acc_vs_vel_mean : 0.001719
# 	acc_vs_vel_min : 0.001702
# 	acc_vs_vel_max : 0.001598
# 	acc_vs_vel_std : 0.001570
# 	acc_vs_vel_max_to_min : 0.001197
# 	acc_vs_vel_mean_abs_change : 0.002646
# 	acc_vs_vel_mean_change_of_abs_change : 0.000770
# 	acc_vs_vel_abs_max : 0.001501
# 	acc_vs_vel_abs_min : 0.002275
# 	euler_x_mean : 0.005431
# 	euler_x_min : 0.005201
# 	euler_x_max : 0.005899
# 	euler_x_std : 0.003066
# 	euler_x_max_to_min : 0.003378
# 	euler_x_mean_abs_change : 0.002377
# 	euler_x_mean_change_of_abs_change : 0.001094
# 	euler_x_abs_max : 0.006280
# 	euler_x_abs_min : 0.005139
# 	euler_y_mean : 0.012760
# 	euler_y_min : 0.011346
# 	euler_y_max : 0.011240
# 	euler_y_std : 0.002284
# 	euler_y_max_to_min : 0.002972
# 	euler_y_mean_abs_change : 0.003955
# 	euler_y_mean_change_of_abs_change : 0.000774
# 	euler_y_abs_max : 0.011157
# 	euler_y_abs_min : 0.011218
# 	euler_z_mean : 0.011407
# 	euler_z_min : 0.011459
# 	euler_z_max : 0.011506
# 	euler_z_std : 0.002693
# 	euler_z_max_to_min : 0.006095
# 	euler_z_mean_abs_change : 0.002984
# 	euler_z_mean_change_of_abs_change : 0.000997
# 	euler_z_abs_max : 0.008442
# 	euler_z_abs_min : 0.008830
# 	total_angle_mean : 0.007504
# 	total_angle_min : 0.009362
# 	total_angle_max : 0.008217
# 	total_angle_std : 0.001615
# 	total_angle_max_to_min : 0.002447
# 	total_angle_mean_abs_change : 0.003010
# 	total_angle_mean_change_of_abs_change : 0.000929
# 	total_angle_abs_max : 0.008582
# 	total_angle_abs_min : 0.009129
# 	angle_vs_acc_mean : 0.005494
# 	angle_vs_acc_min : 0.002648
# 	angle_vs_acc_max : 0.001860
# 	angle_vs_acc_std : 0.002442
# 	angle_vs_acc_max_to_min : 0.001985
# 	angle_vs_acc_mean_abs_change : 0.005646
# 	angle_vs_acc_mean_change_of_abs_change : 0.001053
# 	angle_vs_acc_abs_max : 0.001709
# 	angle_vs_acc_abs_min : 0.002986
# 	angle_vs_vel_mean : 0.002352
# 	angle_vs_vel_min : 0.001750
# 	angle_vs_vel_max : 0.001581
# 	angle_vs_vel_std : 0.001548
# 	angle_vs_vel_max_to_min : 0.001349
# 	angle_vs_vel_mean_abs_change : 0.001921
# 	angle_vs_vel_mean_change_of_abs_change : 0.000857
# 	angle_vs_vel_abs_max : 0.001813
# 	angle_vs_vel_abs_min : 0.002100
# 	acc_times_vel_mean : 0.001941
# 	acc_times_vel_min : 0.001613
# 	acc_times_vel_max : 0.002570
# 	acc_times_vel_std : 0.003457
# 	acc_times_vel_max_to_min : 0.001180
# 	acc_times_vel_mean_abs_change : 0.010106
# 	acc_times_vel_mean_change_of_abs_change : 0.000844
# 	acc_times_vel_abs_max : 0.001963
# 	acc_times_vel_abs_min : 0.001375
# 	angle_times_acc_mean : 0.004674
# 	angle_times_acc_min : 0.001467
# 	angle_times_acc_max : 0.002926
# 	angle_times_acc_std : 0.006909
# 	angle_times_acc_max_to_min : 0.002153
# 	angle_times_acc_mean_abs_change : 0.006050
# 	angle_times_acc_mean_change_of_abs_change : 0.000839
# 	angle_times_acc_abs_max : 0.002499
# 	angle_times_acc_abs_min : 0.001659
# 	angle_times_vel_mean : 0.002131
# 	angle_times_vel_min : 0.001530
# 	angle_times_vel_max : 0.002541
# 	angle_times_vel_std : 0.002149
# 	angle_times_vel_max_to_min : 0.001347
# 	angle_times_vel_mean_abs_change : 0.002442
# 	angle_times_vel_mean_change_of_abs_change : 0.000965
# 	angle_times_vel_abs_max : 0.002277
# 	angle_times_vel_abs_min : 0.001342
# 	angle_times_vel_times_acc_mean : 0.002700
# 	angle_times_vel_times_acc_min : 0.001610
# 	angle_times_vel_times_acc_max : 0.002258
# 	angle_times_vel_times_acc_std : 0.002924
# 	angle_times_vel_times_acc_max_to_min : 0.001333
# 	angle_times_vel_times_acc_mean_abs_change : 0.006948
# 	angle_times_vel_times_acc_mean_change_of_abs_change : 0.000806
# 	angle_times_vel_times_acc_abs_max : 0.002141
# 	angle_times_vel_times_acc_abs_min : 0.001478

# %%
submit['surface'] = le.inverse_transform(sub_preds_rf.argmax(axis=1))
submit.to_csv('submit_without_knn.csv', index=False)
