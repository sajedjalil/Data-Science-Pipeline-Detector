# %% [markdown]
# # A Simple LSTM-Based Time-Series Classifier (PyTorch)
#
# The Recurrent Neural Network (RNN) architecutres show impressive results in tasks related to time-series processing and prediction. In this kernel, we're going to build a very simple LSTM-based classifier as an example of how one can apply RNN to classify a time-series data.

# %%
# %matplotlib inline

# %%
from multiprocessing import cpu_count
from pathlib import Path

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import _LRScheduler

# %%
seed = 1
np.random.seed(seed)
torch.cuda.set_device(0)  # if you have more than one CUDA device

# %% [markdown]
# ## Loading The Data
#
# First of all, we read the files and drop the irrelavant columns.

# %%
ROOT = Path.cwd().parent/'input'
SAMPLE = ROOT/'sample_submission.csv'
TRAIN = ROOT/'X_train.csv'
TARGET = ROOT/'y_train.csv'
TEST = ROOT/'X_test.csv'

ID_COLS = ['series_id', 'measurement_number']

x_cols = {
    'series_id': np.uint32,
    'measurement_number': np.uint32,
    'orientation_X': np.float32,
    'orientation_Y': np.float32,
    'orientation_Z': np.float32,
    'orientation_W': np.float32,
    'angular_velocity_X': np.float32,
    'angular_velocity_Y': np.float32,
    'angular_velocity_Z': np.float32,
    'linear_acceleration_X': np.float32,
    'linear_acceleration_Y': np.float32,
    'linear_acceleration_Z': np.float32
}

y_cols = {
    'series_id': np.uint32,
    'group_id': np.uint32,
    'surface': str
}

# %%
x_trn = pd.read_csv(TRAIN, usecols=x_cols.keys(), dtype=x_cols)
x_tst = pd.read_csv(TEST, usecols=x_cols.keys(), dtype=x_cols)
y_trn = pd.read_csv(TARGET, usecols=y_cols.keys(), dtype=y_cols)

# %% [markdown]
# ## PyTorch Wrappers
#
# Before we can start training a `torch` model, we need to convert `pandas` data frames into PyTorch-specific data types. The main classes here are `Dataset` and `DataLoader`. The functions below split the dataset into training and validation subsets, and wrap them with data loaders.

# %%
def create_datasets(X, y, test_size=0.2, dropcols=ID_COLS, time_dim_first=False):
    enc = LabelEncoder()
    y_enc = enc.fit_transform(y)
    X_grouped = create_grouped_array(X)
    if time_dim_first:
        X_grouped = X_grouped.transpose(0, 2, 1)
    X_train, X_valid, y_train, y_valid = train_test_split(X_grouped, y_enc, test_size=0.1)
    X_train, X_valid = [torch.tensor(arr, dtype=torch.float32) for arr in (X_train, X_valid)]
    y_train, y_valid = [torch.tensor(arr, dtype=torch.long) for arr in (y_train, y_valid)]
    train_ds = TensorDataset(X_train, y_train)
    valid_ds = TensorDataset(X_valid, y_valid)
    return train_ds, valid_ds, enc


def create_grouped_array(data, group_col='series_id', drop_cols=ID_COLS):
    X_grouped = np.row_stack([
        group.drop(columns=drop_cols).values[None]
        for _, group in data.groupby(group_col)])
    return X_grouped


def create_test_dataset(X, drop_cols=ID_COLS):
    X_grouped = np.row_stack([
        group.drop(columns=drop_cols).values[None]
        for _, group in X.groupby('series_id')])
    X_grouped = torch.tensor(X_grouped.transpose(0, 2, 1)).float()
    y_fake = torch.tensor([0] * len(X_grouped)).long()
    return TensorDataset(X_grouped, y_fake)


def create_loaders(train_ds, valid_ds, bs=512, jobs=0):
    train_dl = DataLoader(train_ds, bs, shuffle=True, num_workers=jobs)
    valid_dl = DataLoader(valid_ds, bs, shuffle=False, num_workers=jobs)
    return train_dl, valid_dl


def accuracy(output, target):
    return (output.argmax(dim=1) == target).float().mean().item()

# %% [markdown]
# ## Cyclic Learning Rate
#
# The recent papers by L. Smith show us that the cyclic learning rate schedulers have very positive influence on model's convergence speed. In the following cells, we implement a simple cosine scheduler for our model.

# %%
class CyclicLR(_LRScheduler):
    
    def __init__(self, optimizer, schedule, last_epoch=-1):
        assert callable(schedule)
        self.schedule = schedule
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        return [self.schedule(self.last_epoch, lr) for lr in self.base_lrs]

# %%
def cosine(t_max, eta_min=0):
    
    def scheduler(epoch, base_lr):
        t = epoch % t_max
        return eta_min + (base_lr - eta_min)*(1 + np.cos(np.pi*t/t_max))/2
    
    return scheduler

# %%
n = 100
sched = cosine(n)
lrs = [sched(t, 1) for t in range(n * 4)]
plt.plot(lrs)

# %% [markdown]
# ## The LSTM Model
#
# Our classifier contains of several LSTM cells (hidden under the hood of `nn.LSTM`),  and one `nn.Linear` layer. Note that we use `batch_first=True` to make sure that the first dimension of our tensors is interpreted as a batch size, and the next one - as a time dimension.

# %%
class LSTMClassifier(nn.Module):
    """Very simple implementation of LSTM-based time-series classifier."""
    
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.layer_dim = layer_dim
        self.rnn = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.batch_size = None
        self.hidden = None
    
    def forward(self, x):
        h0, c0 = self.init_hidden(x)
        out, (hn, cn) = self.rnn(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out
    
    def init_hidden(self, x):
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim)
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim)
        return [t.cuda() for t in (h0, c0)]

# %%
print('Preparing datasets')
trn_ds, val_ds, enc = create_datasets(x_trn, y_trn['surface'])
# Out:
# Preparing datasets

# %%
bs = 128
print(f'Creating data loaders with batch size: {bs}')
trn_dl, val_dl = create_loaders(trn_ds, val_ds, bs, jobs=cpu_count())
# Out:
# Creating data loaders with batch size: 128

# %% [markdown]
# ## Training Loop
#
# Finally, we are ready to bring everything together and train the model.

# %%
input_dim = 10    
hidden_dim = 256
layer_dim = 3
output_dim = 9
seq_dim = 128

lr = 0.0005
n_epochs = 1000
iterations_per_epoch = len(trn_dl)
best_acc = 0
patience, trials = 100, 0

model = LSTMClassifier(input_dim, hidden_dim, layer_dim, output_dim)
model = model.cuda()
criterion = nn.CrossEntropyLoss()
opt = torch.optim.RMSprop(model.parameters(), lr=lr)
sched = CyclicLR(opt, cosine(t_max=iterations_per_epoch * 2, eta_min=lr/100))

print('Start model training')

for epoch in range(1, n_epochs + 1):
    
    for i, (x_batch, y_batch) in enumerate(trn_dl):
        model.train()
        x_batch = x_batch.cuda()
        y_batch = y_batch.cuda()
        sched.step()
        opt.zero_grad()
        out = model(x_batch)
        loss = criterion(out, y_batch)
        loss.backward()
        opt.step()
    
    model.eval()
    correct, total = 0, 0
    for x_val, y_val in val_dl:
        x_val, y_val = [t.cuda() for t in (x_val, y_val)]
        out = model(x_val)
        preds = F.log_softmax(out, dim=1).argmax(dim=1)
        total += y_val.size(0)
        correct += (preds == y_val).sum().item()
    
    acc = correct / total

    if epoch % 5 == 0:
        print(f'Epoch: {epoch:3d}. Loss: {loss.item():.4f}. Acc.: {acc:2.2%}')

    if acc > best_acc:
        trials = 0
        best_acc = acc
        torch.save(model.state_dict(), 'best.pth')
        print(f'Epoch {epoch} best model saved with accuracy: {best_acc:2.2%}')
    else:
        trials += 1
        if trials >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
# Out:
# Start model training
# Epoch 1 best model saved with accuracy: 19.95%
# Epoch 2 best model saved with accuracy: 23.62%
# Epoch 3 best model saved with accuracy: 30.45%
# Epoch 4 best model saved with accuracy: 33.33%
# Epoch:   5. Loss: 1.7065. Acc.: 35.17%
# Epoch 5 best model saved with accuracy: 35.17%
# Epoch 6 best model saved with accuracy: 40.42%
# Epoch 8 best model saved with accuracy: 46.98%
# Epoch:  10. Loss: 1.3078. Acc.: 49.08%
# Epoch 10 best model saved with accuracy: 49.08%
# Epoch 13 best model saved with accuracy: 50.13%
# Epoch 14 best model saved with accuracy: 51.97%
# Epoch:  15. Loss: 1.4344. Acc.: 52.49%
# Epoch 15 best model saved with accuracy: 52.49%
# Epoch 16 best model saved with accuracy: 53.81%
# Epoch:  20. Loss: 1.1849. Acc.: 54.59%
# Epoch 20 best model saved with accuracy: 54.59%
# Epoch 22 best model saved with accuracy: 56.96%
# Epoch 24 best model saved with accuracy: 58.53%
# Epoch:  25. Loss: 1.0810. Acc.: 56.43%
# Epoch 28 best model saved with accuracy: 59.84%
# Epoch:  30. Loss: 0.9681. Acc.: 59.32%
# Epoch 32 best model saved with accuracy: 62.73%
# Epoch:  35. Loss: 1.0871. Acc.: 58.01%
# Epoch 38 best model saved with accuracy: 63.52%
# Epoch:  40. Loss: 0.9174. Acc.: 66.14%
# Epoch 40 best model saved with accuracy: 66.14%
# Epoch 42 best model saved with accuracy: 67.19%
# Epoch:  45. Loss: 1.1297. Acc.: 54.86%
# Epoch:  50. Loss: 0.8475. Acc.: 67.72%
# Epoch 50 best model saved with accuracy: 67.72%
# Epoch 52 best model saved with accuracy: 70.08%
# Epoch:  55. Loss: 0.7664. Acc.: 61.15%
# Epoch:  60. Loss: 0.7594. Acc.: 71.39%
# Epoch 60 best model saved with accuracy: 71.39%
# Epoch 62 best model saved with accuracy: 71.92%
# Epoch:  65. Loss: 1.1459. Acc.: 70.08%
# Epoch 66 best model saved with accuracy: 75.07%
# Epoch:  70. Loss: 0.6262. Acc.: 72.70%
# Epoch:  75. Loss: 0.8860. Acc.: 63.25%
# Epoch:  80. Loss: 0.6223. Acc.: 74.80%
# Epoch 82 best model saved with accuracy: 75.59%
# Epoch:  85. Loss: 0.5758. Acc.: 70.87%
# Epoch:  90. Loss: 0.5406. Acc.: 74.28%
# Epoch 92 best model saved with accuracy: 75.85%
# Epoch 94 best model saved with accuracy: 77.69%
# Epoch:  95. Loss: 0.5814. Acc.: 73.23%
# Epoch: 100. Loss: 0.4702. Acc.: 77.43%
# Epoch 102 best model saved with accuracy: 78.22%
# Epoch 104 best model saved with accuracy: 78.48%
# Epoch: 105. Loss: 0.4916. Acc.: 73.49%
# Epoch 108 best model saved with accuracy: 79.27%
# Epoch: 110. Loss: 0.4000. Acc.: 77.17%
# Epoch 112 best model saved with accuracy: 79.79%
# Epoch: 115. Loss: 0.5594. Acc.: 72.70%
# Epoch: 120. Loss: 0.3103. Acc.: 79.27%
# Epoch 124 best model saved with accuracy: 80.58%
# Epoch: 125. Loss: 0.6890. Acc.: 70.34%
# Epoch: 130. Loss: 0.3249. Acc.: 74.02%
# Epoch: 135. Loss: 0.3863. Acc.: 77.95%
# Epoch: 140. Loss: 0.3964. Acc.: 81.89%
# Epoch 140 best model saved with accuracy: 81.89%
# Epoch 144 best model saved with accuracy: 83.46%
# Epoch: 145. Loss: 0.3506. Acc.: 77.17%
# Epoch: 150. Loss: 0.5235. Acc.: 75.07%
# Epoch: 155. Loss: 0.2471. Acc.: 81.63%
# Epoch 156 best model saved with accuracy: 84.25%
# Epoch: 160. Loss: 0.1977. Acc.: 84.78%
# Epoch 160 best model saved with accuracy: 84.78%
# Epoch: 165. Loss: 0.2872. Acc.: 80.31%
# Epoch: 170. Loss: 0.2293. Acc.: 82.15%
# Epoch: 175. Loss: 0.2208. Acc.: 82.68%
# Epoch: 180. Loss: 0.1866. Acc.: 82.41%
# Epoch: 185. Loss: 0.2742. Acc.: 79.00%
# Epoch: 190. Loss: 0.2958. Acc.: 79.27%
# Epoch: 195. Loss: 0.2408. Acc.: 76.12%
# Epoch: 200. Loss: 0.1162. Acc.: 81.89%
# Epoch: 205. Loss: 0.1981. Acc.: 82.68%
# Epoch: 210. Loss: 0.0537. Acc.: 83.73%
# Epoch: 215. Loss: 0.1936. Acc.: 77.95%
# Epoch: 220. Loss: 0.1780. Acc.: 79.53%
# Epoch: 225. Loss: 0.0898. Acc.: 81.63%
# Epoch: 230. Loss: 0.0693. Acc.: 81.89%
# Epoch: 235. Loss: 0.1621. Acc.: 82.41%
# Epoch: 240. Loss: 0.0380. Acc.: 82.68%
# Epoch: 245. Loss: 0.1800. Acc.: 82.41%
# Epoch: 250. Loss: 0.0775. Acc.: 81.63%
# Epoch: 255. Loss: 0.0274. Acc.: 83.46%
# Epoch: 260. Loss: 0.0587. Acc.: 80.31%
# Early stopping on epoch 260

# %%
print('The training is finished! Restoring the best model weights')
# Out:
# The training is finished! Restoring the best model weights

# %% [markdown]
# ## Submission
#
# Next, we load the best weights and run model on the testing dataset.

# %%
model.load_state_dict(torch.load('best.pth'))

# %%
model.eval()
# Out:
# LSTMClassifier(
#   (rnn): LSTM(10, 256, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=256, out_features=9, bias=True)
# )

# %%
test_dl = DataLoader(create_test_dataset(x_tst), batch_size=64, shuffle=False)

# %%
test = []
print('Predicting on test dataset')
for batch, _ in test_dl:
    batch = batch.permute(0, 2, 1)
    out = model(batch.cuda())
    y_hat = F.log_softmax(out, dim=1).argmax(dim=1)
    test += y_hat.tolist()
# Out:
# Predicting on test dataset

# %%
submit = pd.read_csv(SAMPLE)
submit['surface'] = enc.inverse_transform(test)
submit.to_csv('submit.csv', index=None)
