# %%
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['X_train.csv', 'sample_submission.csv', 'X_test.csv', 'y_train.csv']

# %%
#Loading important libraries
import pandas as pd
import numpy as np
pd.options.display.max_rows=20
pd.options.display.max_columns=20
import time

# %%
#Reading CSV Files
start=time.time()
X_train  = pd.read_csv("../input/X_train.csv")
X_test  = pd.read_csv("../input/X_test.csv")
y_train  = pd.read_csv("../input/y_train.csv")
end=time.time()
print("All csv in repsository loaded within {:0.2f} secs".format(end-start))
# Out:
# All csv in repsository loaded within 3.60 secs

# %%
#Various way to get information from csv file
#a)X_train dataset
print ("Rows     : " ,X_train.shape[0])
print ("Columns  : " ,X_train.shape[1])
print ("\nFeatures : \n" ,X_train.columns.tolist())
print ("\nMissing values :  ", X_train.isnull().sum().values.sum())
print ("\nUnique values :  \n",X_train.nunique())
# Out:
# Rows     :  487680
# Columns  :  13
#
# Features :
#  ['row_id', 'series_id', 'measurement_number', 'orientation_X', 'orientation_Y', 'orientation_Z', 'orientation_W', 'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z', 'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z']
#
# Missing values :   0
#
# Unique values :
#  row_id                   487680
# series_id                  3810
# measurement_number          128
# orientation_X            163952
# orientation_Y            151162
# orientation_Z            134570
# orientation_W            140660
# angular_velocity_X       162043
# angular_velocity_Y       151146
# angular_velocity_Z       201611
# linear_acceleration_X    241824
# linear_acceleration_Y    119967
# linear_acceleration_Z     74443
# dtype: int64

# %%
#You can also store above information in dataframe.Let try this for test dataset
X_test_df = pd.DataFrame({
    "Rows": X_test.shape[0],
    "Columns": X_test.shape[1],
    "Features":X_test.columns.tolist(),
    "Missing Values":X_test.isnull().sum().values.sum(),
    "Unique values":X_test.nunique()
})
X_test_df
# Out:
#                          Rows  Columns               Features  Missing Values  \
# row_id                 488448       13                 row_id               0
# series_id              488448       13              series_id               0
# measurement_number     488448       13     measurement_number               0
# orientation_X          488448       13          orientation_X               0
# orientation_Y          488448       13          orientation_Y               0
# orientation_Z          488448       13          orientation_Z               0
# orientation_W          488448       13          orientation_W               0
# angular_velocity_X     488448       13     angular_velocity_X               0
# angular_velocity_Y     488448       13     angular_velocity_Y               0
# angular_velocity_Z     488448       13     angular_velocity_Z               0
# linear_acceleration_X  488448       13  linear_acceleration_X               0
# linear_acceleration_Y  488448       13  linear_acceleration_Y               0
# linear_acceleration_Z  488448       13  linear_acceleration_Z               0
#
#                        Unique values
# row_id                        488448
# series_id                       3816
# measurement_number               128
# orientation_X                 160946
# orientation_Y                 149728
# orientation_Z                 121701
# orientation_W                 138668
# angular_velocity_X            159433
# angular_velocity_Y            150410
# angular_velocity_Z            202351
# linear_acceleration_X         243392
# linear_acceleration_Y         112608
# linear_acceleration_Z          73231

# %%
#If difficulty in understanding the data or visually confusing try other way 
X_test_df.T
#First dataframe seems better for me .Compared to this but you can use any one.
# Out:
#                 row_id  series_id  measurement_number  orientation_X  \
# Rows            488448     488448              488448         488448
# Columns             13         13                  13             13
# Features        row_id  series_id  measurement_number  orientation_X
# Missing Values       0          0                   0              0
# Unique values   488448       3816                 128         160946
#
#                 orientation_Y  orientation_Z  orientation_W  \
# Rows                   488448         488448         488448
# Columns                    13             13             13
# Features        orientation_Y  orientation_Z  orientation_W
# Missing Values              0              0              0
# Unique values          149728         121701         138668
#
#                 angular_velocity_X  angular_velocity_Y  angular_velocity_Z  \
# Rows                        488448              488448              488448
# Columns                         13                  13                  13
# Features        angular_velocity_X  angular_velocity_Y  angular_velocity_Z
# Missing Values                   0                   0                   0
# Unique values               159433              150410              202351
#
#                 linear_acceleration_X  linear_acceleration_Y  \
# Rows                           488448                 488448
# Columns                            13                     13
# Features        linear_acceleration_X  linear_acceleration_Y
# Missing Values                      0                      0
# Unique values                  243392                 112608
#
#                 linear_acceleration_Z
# Rows                           488448
# Columns                            13
# Features        linear_acceleration_Z
# Missing Values                      0
# Unique values                   73231

# %%
#What our target column-Surface contains
y_train['surface'].value_counts()
# Out:
# concrete                  779
# soft_pvc                  732
# wood                      607
# tiled                     514
# fine_concrete             363
# hard_tiles_large_space    308
# soft_tiles                297
# carpet                    189
# hard_tiles                 21
# Name: surface, dtype: int64

# %%
y_train['surface'].value_counts().reset_index().rename(columns={'index': 'target'})
# Out:
#                    target  surface
# 0                concrete      779
# 1                soft_pvc      732
# 2                    wood      607
# 3                   tiled      514
# 4           fine_concrete      363
# 5  hard_tiles_large_space      308
# 6              soft_tiles      297
# 7                  carpet      189
# 8              hard_tiles       21

# %%
#Joining training set
combined_train=pd.merge(X_train,y_train,how='left',on='series_id')
combined_train.head()
print ("X_train :{} ,Y_train {} ,Combined_train {}".format(X_train.shape,y_train.shape,combined_train.shape))
combined_train.to_csv("combined_train.csv",index=False)
print("Csv file saved")
# Out:
# X_train :(487680, 13) ,Y_train (3810, 3) ,Combined_train (487680, 15)
# Csv file saved

# %%
#Drop unnecessary columns
combined_train.drop(columns=["row_id","measurement_number","group_id"], inplace=True)
combined_train.sample(2)
# Out:
#         series_id  orientation_X  orientation_Y  orientation_Z  orientation_W  \
# 384735       3005        0.98634       0.063577       0.020781        0.15052
# 135602       1059        0.94538      -0.286170      -0.034510        0.15225
#
#         angular_velocity_X  angular_velocity_Y  angular_velocity_Z  \
# 384735            0.001746            0.002676            0.001806
# 135602           -0.022413           -0.034128            0.070237
#
#         linear_acceleration_X  linear_acceleration_Y  linear_acceleration_Z  \
# 384735               0.084001                 3.1875                -9.3903
# 135602               0.913350                 5.6498                -1.4407
#
#               surface
# 384735  fine_concrete
# 135602          tiled

# %%
#excluding target variable and saving variable X
X=combined_train[combined_train.columns.difference(['surface'])]
y = combined_train.surface

# %%
#Feature selection
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embedded_rf_selector=SelectFromModel(RandomForestClassifier(n_estimators=20),threshold="1.25 *median")
embedded_rf_selector.fit(X,y)
embedded_rf_support=embedded_rf_selector.get_support()
embedded_rf_feature=X.loc[:,embedded_rf_support].columns.tolist()
print(str(len(embedded_rf_feature)),'selected features')
print("Feature include",embedded_rf_feature)
# Out:
# 5 selected features
# Feature include ['orientation_W', 'orientation_X', 'orientation_Y', 'orientation_Z', 'series_id']

# %%
#Considering the selected feature
#manually selected feature(aka Domain knowledge)
#embedded_rf_feature.append('series_id') #-Incase algorithm doesnot select series_id as feature add it manually
embedded_rf_feature
y = combined_train.surface
combined_train_features = embedded_rf_feature
X = combined_train[combined_train_features]
X.columns.tolist()
# Out:
# ['orientation_W',
#  'orientation_X',
#  'orientation_Y',
#  'orientation_Z',
#  'series_id']

# %%
y.value_counts().reset_index().rename(columns={'index':'Surface','surface' :'Total Count'})
# Out:
#                   Surface  Total Count
# 0                concrete        99712
# 1                soft_pvc        93696
# 2                    wood        77696
# 3                   tiled        65792
# 4           fine_concrete        46464
# 5  hard_tiles_large_space        39424
# 6              soft_tiles        38016
# 7                  carpet        24192
# 8              hard_tiles         2688

# %%
#Splitting our train and test data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1,stratify=y)

# %%
#Getting to know shape of train_test split
print("X_train {} ,\n X_train {}".format((X_train.shape),(X_train.columns.tolist())))
print("X_test {} ,\n X_train {}".format((X_test.shape),(X_test.columns.tolist())))
print("y_train {} ".format((y_train.shape)))
print("y_test {} ".format((y_test.shape)))
# Out:
# X_train (390144, 5) ,
#  X_train ['orientation_W', 'orientation_X', 'orientation_Y', 'orientation_Z', 'series_id']
# X_test (97536, 5) ,
#  X_train ['orientation_W', 'orientation_X', 'orientation_Y', 'orientation_Z', 'series_id']
# y_train (390144,)
# y_test (97536,)

# %%
#Randomly selecting ML algorithm for quick test
from sklearn.ensemble import RandomForestClassifier
randomForest=RandomForestClassifier(n_estimators=100)
randomForest.fit(X_train,y_train)
Y_prediction=randomForest.predict(X_test)
randomForest.score(X_train,y_train)
acc_randomForest=round(randomForest.score(X_train,y_train)*100,2)
print("Accuracy as per RandomForestClassifier algorithm:",round(acc_randomForest,2,),"%")

# %%
#Diff algo trial
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
Y_pred_knn=knn.predict(X_test)
acc_knn=round(knn.score(X_train,y_train)*100,2)
print("Accuracy as per KNeighborsClassifier algorithm:",round(acc_knn,2,),"%")

# %%
from lightgbm import LGBMClassifier
lgbmclassifier=LGBMClassifier(n_estimators=500)
lgbmclassifier.fit(X_train,y_train)
Y_pred_lgbm=lgbmclassifier.predict(X_test)
acc_lgbm=round(lgbmclassifier.score(X_train,y_train)*100,2)
print("Accuracy as per LGBMClassifier algorithm:",round(acc_lgbm,2,),"%")
# Out:
# Accuracy as per LGBMClassifier algorithm: 99.83 %

# %%
print("Making predictions for the following 5 top surfaces:")
print(X_test['series_id'].head())
print("The predictions are")
print(lgbmclassifier.predict(X_test.head()))
# Out:
# Making predictions for the following 5 top surfaces:
# 181276    1416
# 140022    1093
# 183153    1430
# 261081    2039
# 290520    2269
# Name: series_id, dtype: int64
# The predictions are
# ['tiled' 'tiled' 'soft_tiles' 'concrete' 'fine_concrete']

# %%
submission = pd.DataFrame({'series_id':X_test['series_id'],'surface':Y_pred_lgbm})
submission=submission.sort_values('series_id', ascending=True).drop_duplicates(['series_id'],keep='first').reset_index(drop=True)
submission.to_csv("submission.csv",index=False)
print("CSV saved")
# Out:
# CSV saved

# %%
#Check result
print("Shape of submitted file :",submission.shape)
submission.head()
# Out:
# Shape of submitted file : (3810, 2)
#    series_id        surface
# 0          0  fine_concrete
# 1          1       concrete
# 2          2       concrete
# 3          3       concrete
# 4          4     soft_tiles
