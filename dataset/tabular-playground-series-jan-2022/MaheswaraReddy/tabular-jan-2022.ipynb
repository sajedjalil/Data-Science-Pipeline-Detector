# %%
import pandas as pd
import numpy as np

# %%
train_jan_22 = pd.read_csv("../input/tabular-playground-series-jan-2022/train.csv")
test_jan_22 = pd.read_csv("../input/tabular-playground-series-jan-2022/test.csv")

# %%
train_jan_22.head()

# %%
test_jan_22.head()

# %%
type(train_jan_22['date'][0])

# %%
train_jan_22['date']= pd.to_datetime(train_jan_22['date'])
type(train_jan_22['date'][0])

# %%
test_jan_22['date']= pd.to_datetime(test_jan_22['date'])

# %%
pip install holidays

# %%
train_jan_22['month'] = train_jan_22['date'].dt.month
train_jan_22['day'] = train_jan_22['date'].dt.day
train_jan_22['year'] = train_jan_22['date'].dt.year
train_jan_22['quarter'] = train_jan_22['date'].dt.quarter
train_jan_22['semester'] = np.where(train_jan_22.quarter.isin([1,2]),1,2)
train_jan_22['dayofweek'] = train_jan_22['date'].dt.dayofweek
#train_jan_22['dayofweek_name'] = train_jan_22['date'].dt.weekday_name
train_jan_22['is_weekend'] = np.where(train_jan_22['dayofweek'].isin([5, 6]),1,0)
train_jan_22.head()

# %%
train_jan_22['month'].hist()

# %%
train_jan_22['day'].hist()

# %%
test_jan_22['month'] = test_jan_22['date'].dt.month
test_jan_22['day'] = test_jan_22['date'].dt.day
test_jan_22['year'] = test_jan_22['date'].dt.year
test_jan_22['quarter'] = test_jan_22['date'].dt.quarter
test_jan_22['semester'] = np.where(test_jan_22.quarter.isin([1,2]),1,2)
test_jan_22['dayofweek'] = test_jan_22['date'].dt.dayofweek
#train_jan_22['dayofweek_name'] = train_jan_22['date'].dt.weekday_name
test_jan_22['is_weekend'] = np.where(test_jan_22['dayofweek'].isin([5, 6]),1,0)
test_jan_22.head()

# %%
test_jan_22['month'].hist()

# %%
test_jan_22['day'].hist()

# %%
train_jan_22['year'].hist()

# %%
test_jan_22['year'].hist()

# %%
import holidays

california_holidays = holidays.UnitedStates()

#print(train_jan_22.date[100])

#print(california_holidays.get(train_jan_22.date[100]))

for i in range(len(train_jan_22)):
    train_jan_22.loc[i,'holiday'] = california_holidays.get(train_jan_22.loc[i,'date'])

# %%
for i in range(len(test_jan_22)):
    test_jan_22.loc[i,'holiday'] = california_holidays.get(test_jan_22.loc[i,'date'])

# %%
train_jan_22['holiday_usa'] = train_jan_22['date'].apply(lambda x: 1 if x != 'None' else 0)
train_jan_22.head()

# %%
test_jan_22['holiday_usa'] = test_jan_22['date'].apply(lambda x: 1 if x != 'None' else 0)
test_jan_22.head()

# %%
train_jan_22 = train_jan_22.drop(['date', 'holiday'], axis = 1)
train_jan_22.head()

# %%
test_jan_22 = test_jan_22.drop(['date', 'holiday'], axis = 1)
test_jan_22.head()

# %%
train_jan_22['store'].value_counts()

# %%
train_jan_22['store_label'] = train_jan_22['store'].apply(lambda x: 1 if x != 'KaggleMart' else 0)
train_jan_22.head()

# %%
test_jan_22['store_label'] = test_jan_22['store'].apply(lambda x: 1 if x != 'KaggleMart' else 0)
test_jan_22.head()

# %%
train_jan_22 = train_jan_22.drop(['store'], axis = 1)
train_jan_22.head()

# %%
test_jan_22 = test_jan_22.drop(['store'], axis = 1)
test_jan_22.head()

# %%
train_jan_22['country'].value_counts()

# %%
from sklearn.preprocessing import OneHotEncoder 
from sklearn.preprocessing import LabelEncoder
encoder = OneHotEncoder(categories = 'auto')
X = encoder.fit_transform(train_jan_22['country'].values.reshape(-1,1)).toarray()
dfonehot = pd.DataFrame(X)
train_jan_22 = pd.concat([train_jan_22, dfonehot], axis =1)
train_jan_22.head()

# %%
encoder = OneHotEncoder(categories = 'auto')
X = encoder.fit_transform(test_jan_22['country'].values.reshape(-1,1)).toarray()
dfonehot = pd.DataFrame(X)
test_jan_22 = pd.concat([test_jan_22, dfonehot], axis =1)
test_jan_22.head()

# %%
train_jan_22.tail()

# %%
train_jan_22['product'].value_counts()

# %%
encoder = OneHotEncoder(categories = 'auto')
X = encoder.fit_transform(train_jan_22['product'].values.reshape(-1,1)).toarray()
dfonehot1 = pd.DataFrame(X)
train_jan_22 = pd.concat([train_jan_22, dfonehot1], axis =1)
train_jan_22.head()

# %%
encoder = OneHotEncoder(categories = 'auto')
X = encoder.fit_transform(test_jan_22['product'].values.reshape(-1,1)).toarray()
dfonehot1 = pd.DataFrame(X)
test_jan_22 = pd.concat([test_jan_22, dfonehot1], axis =1)
test_jan_22.head()

# %%
train_jan_22 = train_jan_22.drop(['country', 'product'], axis = 1)
train_jan_22.head()

# %%
test_jan_22 = test_jan_22.drop(['country', 'product'], axis = 1)
test_jan_22.head()

# %%
train_jan_22.columns = ['row_id','num_sold','month','day','year','quarter', 'semester', 'dayofweek', 'is_weekend', 'holiday_usa','store_label',
                       'finland', 'norway', 'sweden', 'mug', 'hug','sticker']
train_jan_22.head()

# %%
test_jan_22.columns = ['row_id','month','day','year','quarter', 'semester', 'dayofweek', 'is_weekend', 'holiday_usa','store_label',
                       'finland', 'norway', 'sweden', 'mug', 'hug','sticker']
test_jan_22.head()

# %%
train_jan_22_1 = train_jan_22.copy()

# %%
test_jan_22_1 = test_jan_22.copy()

# %%
train_jan_22 = train_jan_22.drop(['row_id'], axis = 1)
train_jan_22.head()

# %%
test_jan_22 = test_jan_22.drop(['row_id'], axis = 1)
test_jan_22.head()

# %%
from sklearn.model_selection import train_test_split

y = train_jan_22["num_sold"]
X = train_jan_22.drop(['num_sold'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn import datasets, linear_model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
predictions

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,predictions))

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,predictions))

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,predictions)))

# %%
print("RMSE",np.log(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,predictions)
print(r2)

# %%
def SMAPE(y_true, y_pred):
    denominator = (y_true + np.abs(y_pred)) / 200.0
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    return np.mean(diff)

# %%
err = SMAPE(y_test,predictions)
err

# %%
test_pred = lm.predict(test_jan_22)
test_pred

# %%
df_pred = pd.DataFrame(columns = ['row_id', "num_sold"])
df_pred['row_id'] = test_jan_22_1['row_id']
df_pred['num_sold'] = test_pred
df_pred.to_csv("Mahi_Submission_LR_1.csv", index=False)

# %%
from sklearn.tree import DecisionTreeRegressor
dec_reg = DecisionTreeRegressor(random_state=0)
dec_reg.fit(X_train, y_train)
dec_pred = dec_reg.predict(X_test)

# %%
err = SMAPE(y_test,dec_pred)
err

# %%
test_dec_pred = dec_reg.predict(test_jan_22)
test_dec_pred

# %%
df_pred = pd.DataFrame(columns = ['row_id', "num_sold"])
df_pred['row_id'] = test_jan_22_1['row_id']
df_pred['num_sold'] = test_dec_pred
df_pred.to_csv("Mahi_Submission_DT_1.csv", index=False)

# %%
from sklearn.ensemble import RandomForestRegressor
ran_reg = RandomForestRegressor(n_estimators = 100, random_state = 0)
ran_reg.fit(X_train, y_train)
ran_pred = ran_reg.predict(X_test)
err = SMAPE(y_test,ran_pred)
err

# %%
test_ran_pred = ran_reg.predict(test_jan_22)
test_ran_pred

# %%
df_pred = pd.DataFrame(columns = ['row_id', "num_sold"])
df_pred['row_id'] = test_jan_22_1['row_id']
df_pred['num_sold'] = test_ran_pred
df_pred.to_csv("Mahi_Submission_RF_1.csv", index=False)

# %%
from sklearn.ensemble import GradientBoostingRegressor
grd_reg = GradientBoostingRegressor()
grd_reg.fit(X_train, y_train)
grd_pred = grd_reg.predict(X_test)
err = SMAPE(y_test,grd_pred)
err

# %%
test_grd_pred = grd_reg.predict(test_jan_22)
df_pred = pd.DataFrame(columns = ['row_id', "num_sold"])
df_pred['row_id'] = test_jan_22_1['row_id']
df_pred['num_sold'] = test_grd_pred
df_pred.to_csv("Mahi_Submission_GB_1.csv", index=False)

# %%
from xgboost import XGBRegressor
xgb_reg = XGBRegressor()
xgb_reg.fit(X_train, y_train)
xgb_pred = grd_reg.predict(X_test)
err = SMAPE(y_test,xgb_pred)
err

# %%
test_xgb_pred = xgb_reg.predict(test_jan_22)
df_pred = pd.DataFrame(columns = ['row_id', "num_sold"])
df_pred['row_id'] = test_jan_22_1['row_id']
df_pred['num_sold'] = test_xgb_pred
df_pred.to_csv("Mahi_Submission_XGB_1.csv", index=False)

# %%
from sklearn.ensemble import AdaBoostRegressor
adb_reg = AdaBoostRegressor()
adb_reg.fit(X_train, y_train)
adb_pred = grd_reg.predict(X_test)
err = SMAPE(y_test,adb_pred)
err

# %%
test_adb_pred = adb_reg.predict(test_jan_22)
df_pred = pd.DataFrame(columns = ['row_id', "num_sold"])
df_pred['row_id'] = test_jan_22_1['row_id']
df_pred['num_sold'] = test_adb_pred
df_pred.to_csv("Mahi_Submission_ADB_1.csv", index=False)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train1 = sc.fit_transform(X_train)
X_test1 = sc.transform(X_test)

# %%
X_train.info()

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
# Initialising the ANN
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(32, activation = 'relu', input_dim = 15))

# Adding the second hidden layer
model.add(Dense(units = 32, activation = 'relu'))

# Adding the third hidden layer
model.add(Dense(units = 16, activation = 'relu'))


model.add(Dense(units = 8, activation = 'linear'))

model.add(Dense(units = 4, activation = 'linear'))

model.add(Dense(units = 2, activation = 'linear'))

# Adding the output layer
model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adam',loss = 'mean_squared_error')
#model.compile(optimizer = 'adam',loss = SMAPE)

# %%
model.fit(X_train, y_train, batch_size = 10, epochs = 100)

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred.flatten()

# %%
y_pred.shape

# %%
y_test.shape

# %%
err = SMAPE(y_test,y_pred)
err

# %%
test_NN_pred = model.predict(test_jan_22)
df_pred = pd.DataFrame(columns = ['row_id', "num_sold"])
df_pred['row_id'] = test_jan_22_1['row_id']
df_pred['num_sold'] = test_NN_pred
df_pred.to_csv("Mahi_Submission_NN_1.csv", index=False)
