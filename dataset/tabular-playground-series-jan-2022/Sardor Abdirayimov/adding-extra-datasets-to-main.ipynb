# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        name = os.path.join(dirname, filename)
        print(name)
        if "train.csv" in name:                   
            df = pd.read_csv(name)                
        elif "test.csv" in name:
            test_df = pd.read_csv(name)              
        elif "submission.csv" in name:
            sample_df = pd.read_csv(name) 
        elif 'CPI' in name:
            cpi_df = pd.read_csv(name)
        elif 'GDP' in name:
            gdp_df = pd.read_csv(name)
        elif 'Holidays' in name:
            holidays_df = pd.read_csv(name)

# %%
holidays_df.head()

# %%
#each time automatically dataset has Unnamed: 0 
holidays_df = holidays_df.iloc[:,1:] # to remore that column

# %%
 final_df = df.merge(holidays_df, on=['date', 'country'])

# %%
final_df['date'] = pd.to_datetime(final_df['date'])

# %%
final_df['year'] = final_df['date'].dt.year

# %%
#each time automatically dataset has Unnamed: 0 
gdp_df = gdp_df.iloc[:,1:] #to remote that column

# %%
final_df = final_df.merge(gdp_df, on=['year', 'country'])

# %%
#each time automatically dataset has Unnamed: 0 
cpi_df = cpi_df.iloc[:,1:] # to remote that column

# %%
final_df = final_df.merge(cpi_df, on=['year', 'country'])

# %%
final_df.drop('year', axis=1, inplace=True)

# %%
final_df
