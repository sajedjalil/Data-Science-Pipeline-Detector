# %% [markdown]
# <center><img src="https://storage.googleapis.com/kaggle-competitions/kaggle/28012/logos/header.png?t=2021-06-30-01-16-12" width="1900" height="400"></center>

# %% [markdown]
# <h1 style="color:rgb(0, 35, 156);"><center><font size="+4"># जो दीखता है वही'ich' बिकता है</font></center></h1>
# <h3 style="text-align: right;"><i>By: Kush Trivedi</i></h3>
# <h1 style="color:rgb(233, 92, 32);"><center>Tabular Play Ground - Jan 2022</center></h1>
#
# <h3 style="color:rgb(233, 92, 32);">Given Task</h3>
#
# <p>There are <b>two</b> (fictitious) independent store chains that <b>sell Kaggle products</b> and strive to become the <b>official Kaggle store</b>. We've decided to enlist the help of the Kaggle community in determining <b>which of the store chains will have the best sales in the future</b>. So, we've gathered some data and are asking you to <b>create forecasting models to assist us in making a decision.</b></p>
#
# <p>Assist us in deciding whether <b>KaggleMart</b> or <b>KaggleRama</b> should be the <b>official Kaggle retailer!</b></p>
#
# <h3 style="color:rgb(233, 92, 32);">My Opinion with Statistical Proof</h3>
# <h2 style="color:rgb(0, 103, 71);"><center><font size="+3">Despite the fact that Kaggle Rama has sold more merchandise,it should not be considered an Official Kaggle Retailer.</font></center></h2>

# %% [markdown]
# <center><h1 style="color:rgb(233, 92, 32);">Table of Contents</h1></center>
#
# <h2 style="color:rgb(233, 92, 32);">★ Who Should be the Oficial Retailer [ Kaggle Rama | Kaggle Mart ]</h2>
#
# * [Import Libraries](#0)
# * [Universal Summary Function for Data Frames](#1)
# * [Helper Functions to Extract Data](#2)
# * [Data Loading](#3)
# * [Data Wrangling](#4)
# * [Glance of Train & Test Data](#5)
#
# <h2 style="color:rgb(233, 92, 32);">★ Exploratory Data Analysis (EDA)</h2>
#
# * [Product Sales Data Preparation for Both Stores [ Kagle Mart & Kaggle Rama ]](#6)
#
#     <h4 style="color:rgb(0, 103, 71);">☆ Finland: Kaggle Mart & Kaggle Rama (Little Tedious View)</h4>
#
#     * [Finland: Kaggle Mart & Rama Sales 2015 - 2018](#7)
#
#   <h4 style="color:rgb(0, 103, 71);">☆ Norway: Kaggle Mart & Kaggle Rama (Little Tedious View)</h4>
#
#     * [Norway: Kaggle Mart & Rama Sales 2015 - 2018](#8)
#
#   <h4 style="color:rgb(0, 103, 71);">☆ Swden: Kaggle Mart & Kaggle Rama (Little Tedious View)</h4>
#
#     * [Swden: Kaggle Mart & Rama Sales 2015 - 2018](#9)
#
#
# * [Data Preparation from a Tedious Point of View to Gain More Insights and Clarity](#10)
#
#      <h3 style="color:rgb(233, 92, 32);">1. Finland: Kaggle Stores Products Sales( Clear & Understanable View )</h3>
#
#    <i><h4 style="color:rgb(0, 103, 71);">☆ Finland: Kaggle Hats Sales</h4></i>
#
#      (A). [Kaggle Mart Hats Sales ( 2015 - 2018 )](#11)
#        (B). [Kaggle Rama Hats Sales ( 2015 - 2018 )](#12)
#
#   <i><h4 style="color:rgb(0, 103, 71);">☆ Finland: Kaggle Mugs Sales</h4></i>
#
#      (A). [Kaggle Mart Mugs Sales ( 2015 - 2018 )](#13)
#        (B). [Kaggle Rama Mugs Sales ( 2015 - 2018 )](#14)
#
#   <i><h4 style="color:rgb(0, 103, 71);">☆ Finland: Kaggle Stickers Sales</h4></i>
#
#      (A). [Kaggle Mart Stickers Sales ( 2015 - 2018 )](#15)
#        (B). [Kaggle Rama Stickers Sales ( 2015 - 2018 )](#16)
# <br>
#
#   <h3 style="color:rgb(233, 92, 32);">2. Norway: Kaggle Stores Products Sales( Clear & Understanable View )</h3>
#
#  <i><h4 style="color:rgb(0, 103, 71);">☆ Norway: Kaggle Hats Sales</h4></i>
#
#    (A). [Kaggle Mart Hats Sales ( 2015 - 2018 )](#17)
#      (B). [Kaggle Rama Hats Sales ( 2015 - 2018 )](#18)
#
#   <i><h4 style="color:rgb(0, 103, 71);">☆ Norway: Kaggle Mugs Sales</h4></i>
#
#    (A). [Kaggle Mart Mugs Sales ( 2015 - 2018 )](#19)
#      (B). [Kaggle Rama Mugs Sales ( 2015 - 2018 )](#20)
#
#   <i><h4 style="color:rgb(0, 103, 71);">☆ Norway: Kaggle Stickers Sales</h4></i>
#
#    (A). [Kaggle Mart Stickers Sales ( 2015 - 2018 )](#21)
#      (B). [Kaggle Rama Stickers Sales ( 2015 - 2018 )](#22)
# <br>
#
#   <h3 style="color:rgb(233, 92, 32);">3. Sweden: Kaggle Stores Products Sales( Clear & Understanable View )</h3>
#
#  <i><h4 style="color:rgb(0, 103, 71);">☆ Sweden: Kaggle Hats Sales</h4></i>
#
#    (A). [Kaggle Mart Hats Sales ( 2015 - 2018 )](#23)
#      (B). [Kaggle Rama Hats Sales ( 2015 - 2018 )](#24)
#
#   <i><h4 style="color:rgb(0, 103, 71);">☆ Sweden: Kaggle Mugs Sales</h4></i>
#
#    A. [Kaggle Mart Mugs Sales ( 2015 - 2018 )](#25)
#      B. [Kaggle Rama Mugs Sales ( 2015 - 2018 )](#26)
#
#   <i><h4 style="color:rgb(0, 103, 71);">☆ Sweden: Kaggle Stickers Sales</h4></i>
#
#    (A). [Kaggle Mart Stickers Sales ( 2015 - 2018 )](#27)
#      (B). [Kaggle Rama Stickers Sales ( 2015 - 2018 )](#28)
#
#
# <h2 style="color:rgb(233, 92, 32);">★ Statistical Testing</h2>
#
# * [Data Wrangling](#29)
#
#     <h4 style="color:rgb(0, 103, 71);">☆ Finland Statistical Testing</h4>
#
#      1. [Is Difference Significant for Product Sales in Finland for Both Stores](#30)
#      2. [Overall Distribution of All Products in Finland: Positively Skewed](#31)
#      3. [Comparing Means among Stores in Finland](#32)
#      4. [Finland T-Test Results](#69)
#
#   <h4 style="color:rgb(0, 103, 71);">☆ Norway Statistical Testing</h4>
#
#      1. [Is Difference Significant for Product Sales in Norway for Both Stores](#33)
#      2. [Overall Distribution of All Products in Norway: Positively Skewed](#34)
#      3. [Comparing Means among Stores in Norway](#35)
#      4. [Norway T-Test Results](#70)
#
#   <h4 style="color:rgb(0, 103, 71);">☆ Sweden Statistical Testing</h4>
#
#      1. [Is Difference Significant for Product Sales in Sweden for Both Stores](#36)
#      2. [Overall Distribution of All Products in Sweden: Positively Skewed](#37)
#      3. [Comparing Means among Stores in Sweden](#38)
#      4. [Sweden T-Test Results](#71)
#
#
# <h2 style="color:rgb(233, 92, 32);">★ Machine Learning Model To Forecast Sales: Fit Any Regression Model of your Choice and Tune it</h2>
#
# <h3 style="color:rgb(0, 103, 71);">☆ Data Exploration</h3>
#
#    * [Dataset Features](#39)
#    * [Basic Stats](#40)
#
# <h3 style="color:rgb(0, 103, 71);">☆ Exploratory Data Analysis (EDA)</h3>
#
#    * [Target Variable Distribution - Median Value](#41)
#    * [Categorical features in the dataset](#42)
#    * [Relationship between all the features](#43)
#
# <h3 style="color:rgb(0, 103, 71);">☆ Data Pre-processing</h3>
#
#    * [Remove Duplicates](#44)
#    * [Check Inconsistant Values](#45)
#
# <h3 style="color:rgb(0, 103, 71);">☆ Data Manipulation</h3>
#
#    * [Spliting Dataset](#46)
#    * [Standardization](#47)
#
# <h3 style="color:rgb(0, 103, 71);">☆ Feature Selection/Extraction</h3>
#
#    * [Correlation](#48)
#    * [OLS Regression](#49)
#        * [Fixing Multicollinearity](#50)
#            * [Manual Method - Variance Inflation Factor (VIF)](#50)
#            * [Automatic Method - RFE](#51)
#            * [Feature Elmination using PCA Decomposition](#52)
#
# <h3 style="color:rgb(0, 103, 71);">☆ Predictive Modelling</h3>
#
#    * [Regression Model Helper Function](#53)
#        * [Multiple Linear Regression(MLR)](#54)
#        * [Ridge Regression Model](#55)
#        * [Lasso Regression Model](#56)
#        * [Elastic-Net Regression](#57)
#        * [Gradient Boosting Regressor](#59)
#        * [Decision Tree Regressor](#60)
#        * [Random Forest Regressor](#61)
#        * [XGBoost Regressor](#62)
#        * [CATBoost Regressor](#63)
#        * [KNeighbour Regressor](#64)
#        * [LGBM Regressor](#65)
#        * [Evaluation Metics](#66)
#        * [Comapring Regression Models](#67)
#        * [Root Mean SquaredError Comparison](#68)
#        * [SMPE Values of Models](#72)
#
# <h3 style="color:rgb(0, 103, 71);">☆ Submission</h3>
#
# * [Submission to CSV](#73)
# * [Summary of Submission](#74)
# * [Glance of Submission](#75)
#
# <h3 style="color:rgb(0, 103, 71);">☆ Project Outcomes & Conclusion</h3>

# %% [markdown]
# **<p id='0'><li>Importing Library</li></p>**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import math
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py
from datetime import datetime, date, time
import holidays
import dateutil.easter as easter
from scipy.stats import ttest_ind
from plotly.offline import init_notebook_mode, iplot, plot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
from plotly.graph_objects import Layout
layout = Layout(plot_bgcolor='rgba(246,245,245,1)')
from statsmodels.formula import api
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost.sklearn import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

sns.set(rc={'axes.facecolor':'#f6f5f5', 'figure.facecolor':'#f6f5f5'})
sns.set_palette(sns.color_palette("Paired"))
plt.rcParams['figure.figsize'] = [16,6]
import warnings 
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 99999999

# %% [markdown]
# **<p id='1'><li>Universal Summary Function for Dataframes</li></p>**

# %%
def basicSummary(dataFrameForSummary):
    print('\nThe Datset consists of \033[1m {} \033[0m features & \033[1m {}\033[0m samples.\n'.format(dataFrameForSummary.shape[1], dataFrameForSummary.shape[0]))
    summary = pd.DataFrame(dataFrameForSummary.dtypes, columns=['Data Type'])
    summary = summary.reset_index()
    summary = summary.rename(columns={'index': 'Feature'})
    summary['Num of Nulls'] = dataFrameForSummary.isnull().sum().values
    summary['Num of Unique'] = dataFrameForSummary.nunique().values
    summary['First Value'] = dataFrameForSummary.loc[0].values
    summary['Second Value'] = dataFrameForSummary.loc[1].values
    summary['Third Value'] = dataFrameForSummary.loc[2].values
    summary['Fourth Value'] = dataFrameForSummary.loc[3].values
    return summary

# %% [markdown]
# **<p id='2'><li>Helper Function to Extract Data</li></p>**

# %%
# Define Model Evaluation functions
def smape(y_true, y_pred):
    return round(np.mean(np.abs(y_pred - y_true) / ((np.abs(y_pred) + np.abs(y_true))/2))*100, 2)

def evaluate_model(model, x, y):
    y_pred = model.predict(x)
    result = smape(y, y_pred)
    return result

def preprocess_dates(df):
    df = df.copy()
    df['date'] = pd.to_datetime(df['date'])
    df['weekday'] = df['date'].dt.weekday
    df['week']=df['date'].dt.isocalendar().week     
    df['week'][df['week']>52]=52                    
    df['week']=df['week'].astype('int')
    df['month']=df['date'].dt.month
    df['quarter'] = df['date'].dt.quarter
    df['year']=df['date'].dt.year
    df['day_of_year'] = df['date'].dt.day_of_year
    df['day_of_month']=df['date'].dt.day
    df['is_month_start'] = df['date'].dt.is_month_start
    df['is_month_end'] = df['date'].dt.is_month_end
    df['weekend']=(df['weekday']//5 == 1)       
    df['weekend']=df['weekend'].astype('int') 
    return df

def preprocess_holidays(df):
    holiday_finland = holidays.CountryHoliday(country='FI', years=[2015, 2016, 2017, 2018, 2019])
    holiday_norway = holidays.CountryHoliday(country='NO', years=[2015, 2016, 2017, 2018, 2019])
    holiday_sweden = holidays.CountryHoliday(country='SE', years=[2015, 2016, 2017, 2018, 2019])
    holidays_fin_nor_swe = holiday_finland.copy()
    holidays_fin_nor_swe.update(holiday_norway)
    holidays_fin_nor_swe.update(holiday_sweden)
    dates = list(holidays_fin_nor_swe.keys())
    dates = sorted(pd.to_datetime(dates))
    df = df.copy()
    df['is_holiday'] = df['date'].apply(lambda x : 1 if x in dates else 0)
    return df

def preprocess_timeseries(df):
    df = df.copy()
    # Sin of date values
    df['sin_day_of_year'] = np.sin(df['day_of_year'])
    df['sin_month'] = np.sin(df['month'])
    df['sin_weekday'] = np.sin(df['weekday'])
    df['sin_quarter'] = np.sin(df['quarter'])
    # Cos of date values
    df['cos_day_of_year'] = np.cos(df['day_of_year'])
    df['cos_month'] = np.cos(df['month'])
    df['cos_weekday'] = np.cos(df['weekday'])
    df['cos_quarter'] = np.cos(df['quarter'])
    return df

# %% [markdown]
# **<p id='3'><li>Data Loading</li></p>**

# %%
TrainData = pd.read_csv('/kaggle/input/c/tabular-playground-series-jan-2022/train.csv')
TestData = pd.read_csv('/kaggle/input/c/tabular-playground-series-jan-2022/test.csv')
trainData = TrainData.copy()
testData = TestData.copy()

# %% [markdown]
# **<p id='4'><li>Data Wrangling</li></p>**

# %%
trainData = preprocess_dates(trainData)
trainData = preprocess_holidays(trainData)
trainData = preprocess_timeseries(trainData)
trainData = trainData.drop(columns = ['row_id', 'date'])

testData = preprocess_dates(testData)
testData = preprocess_holidays(testData)
testData = preprocess_timeseries(testData)
testData = testData.drop(columns = ['row_id', 'date'])

# %% [markdown]
# **<p id='5'><li>Glance of Train & Test Data</li></p>**

# %%
display(basicSummary(trainData))
display(basicSummary(testData))

# %% [markdown]
# <a id="6"></a> <br>
# # Initial EDA
#
# **<p id='6'><li>Data Preparation</li></p>**

# %%
#FinlandDataKaggleMartData
###################################################################################################################################################

FinlandDataKaggleMartData2015 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleMart') & (trainData.year == 2015)]
FinlandDataKaggleMartData2015.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleMartDataFrame2015 = FinlandDataKaggleMartData2015.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleMartSeries2015 = FinlandDataKaggleMartDataFrame2015.groupby(['year','month','store','product','num_sold'], as_index=True).size()
FinlandDataKaggleMart2015 = pd.DataFrame(FinlandDataKaggleMartSeries2015)

FinlandDataKaggleMartData2016 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleMart') & (trainData.year == 2016)]
FinlandDataKaggleMartData2016.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleMartDataFrame2016 = FinlandDataKaggleMartData2016.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleMartSeries2016 = FinlandDataKaggleMartDataFrame2016.groupby(['year','month','store','product','num_sold'], as_index=True).size()
FinlandDataKaggleMart2016 = pd.DataFrame(FinlandDataKaggleMartSeries2016)

FinlandDataKaggleMartData2017 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleMart') & (trainData.year == 2017)]
FinlandDataKaggleMartData2017.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleMartDataFrame2017 = FinlandDataKaggleMartData2017.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleMartSeries2017 = FinlandDataKaggleMartDataFrame2017.groupby(['year','month','store','product','num_sold'], as_index=True).size()
FinlandDataKaggleMart2017 = pd.DataFrame(FinlandDataKaggleMartSeries2017)

FinlandDataKaggleMartData2018 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleMart') & (trainData.year == 2018)]
FinlandDataKaggleMartData2018.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleMartDataFrame2018 = FinlandDataKaggleMartData2018.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleMartSeries2018 = FinlandDataKaggleMartDataFrame2018.groupby(['year','month','store','product','num_sold'], as_index=True).size()
FinlandDataKaggleMart2018 = pd.DataFrame(FinlandDataKaggleMartSeries2018)

#FinlandDataKaggleRamaData
###################################################################################################################################################

FinlandDataKaggleRamaData2015 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleRama') & (trainData.year == 2015)]
FinlandDataKaggleRamaData2015.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleRamaDataFrame2015 = FinlandDataKaggleRamaData2015.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleRamaSeries2015 = FinlandDataKaggleRamaDataFrame2015.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
FinlandDataKaggleRama2015 = pd.DataFrame(FinlandDataKaggleRamaSeries2015)

FinlandDataKaggleRamaData2016 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleRama') & (trainData.year == 2016)]
FinlandDataKaggleRamaData2016.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleRamaDataFrame2016 = FinlandDataKaggleRamaData2016.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleRamaSeries2016 = FinlandDataKaggleRamaDataFrame2016.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
FinlandDataKaggleRama2016 = pd.DataFrame(FinlandDataKaggleRamaSeries2016)

FinlandDataKaggleRamaData2017 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleRama') & (trainData.year == 2017)]
FinlandDataKaggleRamaData2017.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleRamaDataFrame2017 = FinlandDataKaggleRamaData2017.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleRamaSeries2017 = FinlandDataKaggleRamaDataFrame2017.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
FinlandDataKaggleRama2017 = pd.DataFrame(FinlandDataKaggleRamaSeries2017)

FinlandDataKaggleRamaData2018 = trainData[(trainData.country == 'Finland') & (trainData.store == 'KaggleRama') & (trainData.year == 2018)]
FinlandDataKaggleRamaData2018.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
FinlandDataKaggleRamaDataFrame2018 = FinlandDataKaggleRamaData2018.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
FinlandDataKaggleRamaSeries2018 = FinlandDataKaggleRamaDataFrame2018.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
FinlandDataKaggleRama2018 = pd.DataFrame(FinlandDataKaggleRamaSeries2018)

#NorwayDataKaggleMartData
###################################################################################################################################################

NorwayDataKaggleMartData2015 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleMart') & (trainData.year == 2015)]
NorwayDataKaggleMartData2015.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleMartDataFrame2015 = NorwayDataKaggleMartData2015.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleMartSeries2015 = NorwayDataKaggleMartDataFrame2015.groupby(['year','month','store','product','num_sold'], as_index=True).size()
NorwayDataKaggleMart2015 = pd.DataFrame(NorwayDataKaggleMartSeries2015)

NorwayDataKaggleMartData2016 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleMart') & (trainData.year == 2016)]
NorwayDataKaggleMartData2016.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleMartDataFrame2016 = NorwayDataKaggleMartData2016.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleMartSeries2016 = NorwayDataKaggleMartDataFrame2016.groupby(['year','month','store','product','num_sold'], as_index=True).size()
NorwayDataKaggleMart2016 = pd.DataFrame(NorwayDataKaggleMartSeries2016)

NorwayDataKaggleMartData2017 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleMart') & (trainData.year == 2017)]
NorwayDataKaggleMartData2017.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleMartDataFrame2017 = NorwayDataKaggleMartData2017.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleMartSeries2017 = NorwayDataKaggleMartDataFrame2017.groupby(['year','month','store','product','num_sold'], as_index=True).size()
NorwayDataKaggleMart2017 = pd.DataFrame(NorwayDataKaggleMartSeries2017)

NorwayDataKaggleMartData2018 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleMart') & (trainData.year == 2018)]
NorwayDataKaggleMartData2018.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleMartDataFrame2018 = NorwayDataKaggleMartData2018.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleMartSeries2018 = NorwayDataKaggleMartDataFrame2018.groupby(['year','month','store','product','num_sold'], as_index=True).size()
NorwayDataKaggleMart2018 = pd.DataFrame(NorwayDataKaggleMartSeries2018)


#NorwayDataKaggleRamaData
###################################################################################################################################################

NorwayDataKaggleRamaData2015 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleRama') & (trainData.year == 2015)]
NorwayDataKaggleRamaData2015.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleRamaDataFrame2015 = NorwayDataKaggleRamaData2015.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleRamaSeries2015 = NorwayDataKaggleRamaDataFrame2015.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
NorwayDataKaggleRama2015 = pd.DataFrame(NorwayDataKaggleRamaSeries2015)

NorwayDataKaggleRamaData2016 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleRama') & (trainData.year == 2016)]
NorwayDataKaggleRamaData2016.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleRamaDataFrame2016 = NorwayDataKaggleRamaData2016.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleRamaSeries2016 = NorwayDataKaggleRamaDataFrame2016.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
NorwayDataKaggleRama2016 = pd.DataFrame(NorwayDataKaggleRamaSeries2016)

NorwayDataKaggleRamaData2017 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleRama') & (trainData.year == 2017)]
NorwayDataKaggleRamaData2017.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleRamaDataFrame2017 = NorwayDataKaggleRamaData2017.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleRamaSeries2017 = NorwayDataKaggleRamaDataFrame2017.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
NorwayDataKaggleRama2017 = pd.DataFrame(NorwayDataKaggleRamaSeries2017)

NorwayDataKaggleRamaData2018 = trainData[(trainData.country == 'Norway') & (trainData.store == 'KaggleRama') & (trainData.year == 2018)]
NorwayDataKaggleRamaData2018.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
NorwayDataKaggleRamaDataFrame2018 = NorwayDataKaggleRamaData2018.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
NorwayDataKaggleRamaSeries2018 = NorwayDataKaggleRamaDataFrame2018.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
NorwayDataKaggleRama2018 = pd.DataFrame(NorwayDataKaggleRamaSeries2018)

#SwedenDataKaggleMartData
###################################################################################################################################################

SwedenDataKaggleMartData2015 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleMart') & (trainData.year == 2015)]
SwedenDataKaggleMartData2015.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleMartDataFrame2015 = SwedenDataKaggleMartData2015.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleMartSeries2015 = SwedenDataKaggleMartDataFrame2015.groupby(['year','month','store','product','num_sold'], as_index=True).size()
SwedenDataKaggleMart2015 = pd.DataFrame(SwedenDataKaggleMartSeries2015)

SwedenDataKaggleMartData2016 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleMart') & (trainData.year == 2016)]
SwedenDataKaggleMartData2016.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleMartDataFrame2016 = SwedenDataKaggleMartData2016.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleMartSeries2016 = SwedenDataKaggleMartDataFrame2016.groupby(['year','month','store','product','num_sold'], as_index=True).size()
SwedenDataKaggleMart2016 = pd.DataFrame(SwedenDataKaggleMartSeries2016)

SwedenDataKaggleMartData2017 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleMart') & (trainData.year == 2017)]
SwedenDataKaggleMartData2017.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleMartDataFrame2017 = SwedenDataKaggleMartData2017.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleMartSeries2017 = SwedenDataKaggleMartDataFrame2017.groupby(['year','month','store','product','num_sold'], as_index=True).size()
SwedenDataKaggleMart2017 = pd.DataFrame(SwedenDataKaggleMartSeries2017)

SwedenDataKaggleMartData2018 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleMart') & (trainData.year == 2018)]
SwedenDataKaggleMartData2018.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleMartDataFrame2018 = SwedenDataKaggleMartData2018.groupby(['year','month','store','product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleMartSeries2018 = SwedenDataKaggleMartDataFrame2018.groupby(['year','month','store','product','num_sold'], as_index=True).size()
SwedenDataKaggleMart2018 = pd.DataFrame(SwedenDataKaggleMartSeries2018)

#NorwayDataKaggleRamaData
###################################################################################################################################################

SwedenDataKaggleRamaData2015 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleRama') & (trainData.year == 2015)]
SwedenDataKaggleRamaData2015.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleRamaDataFrame2015 = SwedenDataKaggleRamaData2015.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleRamaSeries2015 = SwedenDataKaggleRamaDataFrame2015.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
SwedenDataKaggleRama2015 = pd.DataFrame(SwedenDataKaggleRamaSeries2015)

SwedenDataKaggleRamaData2016 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleRama') & (trainData.year == 2016)]
SwedenDataKaggleRamaData2016.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleRamaDataFrame2016 = SwedenDataKaggleRamaData2016.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleRamaSeries2016 = SwedenDataKaggleRamaDataFrame2016.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
SwedenDataKaggleRama2016 = pd.DataFrame(SwedenDataKaggleRamaSeries2016)

SwedenDataKaggleRamaData2017 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleRama') & (trainData.year == 2017)]
SwedenDataKaggleRamaData2017.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleRamaDataFrame2017 = SwedenDataKaggleRamaData2017.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleRamaSeries2017 = SwedenDataKaggleRamaDataFrame2017.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
SwedenDataKaggleRama2017 = pd.DataFrame(SwedenDataKaggleRamaSeries2017)

SwedenDataKaggleRamaData2018 = trainData[(trainData.country == 'Sweden') & (trainData.store == 'KaggleRama') & (trainData.year == 2018)]
SwedenDataKaggleRamaData2018.drop(['weekday', 'week','quarter','day_of_year','day_of_month','is_month_start',
                                    'is_month_end','weekend','is_holiday','sin_day_of_year','sin_month',
                                    'sin_weekday','sin_quarter','cos_day_of_year','cos_month','cos_weekday',
                                    'cos_quarter'], axis=1, inplace=True)
SwedenDataKaggleRamaDataFrame2018 = SwedenDataKaggleRamaData2018.groupby(['year', 'month', 'store', 'product'])[['num_sold']].sum().reset_index()
SwedenDataKaggleRamaSeries2018 = SwedenDataKaggleRamaDataFrame2018.groupby(['year', 'month', 'store', 'product', 'num_sold'], as_index=True).size()
SwedenDataKaggleRama2018 = pd.DataFrame(SwedenDataKaggleRamaSeries2018)

# %% [markdown]
# **<p id='7'><li>Finland: Kaggle Mart & Kaggle Rama Products Sales (2015 - 2018) </li></p>**

# %%
print("\033[1;31;43m Finland: Kaggle Mart Products Sales 2015  \033[0;0m")
display(FinlandDataKaggleMart2015)
print("\n\033[1;31;43m Finland: Kaggle Mart Products Sales 2016  \033[0;0m")
display(FinlandDataKaggleMart2016)
print("\n\033[1;31;43m Finland: Kaggle Mart Products Sales 2017  \033[0;0m")
display(FinlandDataKaggleMart2017)
print("\n\033[1;31;43m Finland: Kaggle Mart Products Sales 2018  \033[0;0m")
display(FinlandDataKaggleMart2018)

print("\n\033[1;30;45m Finland: Kaggle Rama Products Sales 2015  \033[0;0m")
display(FinlandDataKaggleRama2015)
print("\n\033[1;30;45m Finland: Kaggle Rama Products Sales 2016  \033[0;0m")
display(FinlandDataKaggleRama2016)
print("\n\033[1;30;45m Finland: Kaggle Rama Products Sales 2017  \033[0;0m")
display(FinlandDataKaggleRama2017)
print("\n\033[1;30;45m Finland: Kaggle Rama Products Sales 2018  \033[0;0m")
display(FinlandDataKaggleRama2018)

# %% [markdown]
# **<p id='8'><li>Norway: Kaggle Mart & Kaggle Rama Products Sales (2015 - 2018) </li></p>**

# %%
print("\033[1;31;43m Norway: Kaggle Mart Products Sales 2015  \033[0;0m")
display(NorwayDataKaggleMart2018)
print("\n\033[1;31;43m Norway: Kaggle Mart Products Sales 2016  \033[0;0m")
display(NorwayDataKaggleMart2018)
print("\n\033[1;31;43m Norway: Kaggle Mart Products Sales 2017  \033[0;0m")
display(NorwayDataKaggleMart2018)
print("\n\033[1;31;43m Norway: Kaggle Mart Products Sales 2018  \033[0;0m")
display(NorwayDataKaggleMart2018)

print("\n\033[1;30;45m Sweden: Kaggle Rama Products Sales 2015  \033[0;0m")
display(NorwayDataKaggleRama2015)
print("\n\033[1;30;45m Norway: Kaggle Rama Products Sales 2016  \033[0;0m")
display(NorwayDataKaggleRama2016)
print("\n\033[1;30;45m Norway: Kaggle Rama Products Sales 2017  \033[0;0m")
display(NorwayDataKaggleRama2017)
print("\n\033[1;30;45m Norway: Kaggle Rama Products Sales 2018  \033[0;0m")
display(NorwayDataKaggleRama2018)

# %% [markdown]
# **<p id='9'><li>Sweden: Kaggle Mart & Kaggle Rama Products Sales (2015 - 2018) </li></p>**

# %%
print("\033[1;31;43m Sweden: Kaggle Mart Products Sales 2015  \033[0;0m")
display(SwedenDataKaggleMart2015)
print("\n\033[1;31;43m Sweden: Kaggle Mart Products Sales 2016  \033[0;0m")
display(SwedenDataKaggleMart2016)
print("\n\033[1;31;43m Sweden: Kaggle Mart Products Sales 2017  \033[0;0m")
display(SwedenDataKaggleMart2017)
print("\n\033[1;31;43m Sweden: Kaggle Mart Products Sales 2018  \033[0;0m")
display(SwedenDataKaggleMart2018)

print("\n\033[1;30;45m Sweden: Kaggle Rama Products Sales 2015  \033[0;0m")
display(SwedenDataKaggleRama2015)
print("\n\033[1;30;45m Sweden: Kaggle Rama Products Sales 2016  \033[0;0m")
display(SwedenDataKaggleRama2016)
print("\n\033[1;30;45m Sweden: Kaggle Rama Products Sales 2017  \033[0;0m")
display(SwedenDataKaggleRama2017)
print("\n\033[1;30;45m Sweden: Kaggle Rama Products Sales 2018  \033[0;0m")
display(SwedenDataKaggleRama2018)

# %% [markdown]
# **<p id='10'><li>Data Preparation from a Tedious Point of View to Gain More Insights and Clarity</li></p>**

# %%
###################################################################################################################################################

FinlandKaggleMartKaggleHatData = [
    [0,'Kaggle Mart','Kaggle Hat','January', 11396, 12063, 12412, 13787],
    [0,'Kaggle Mart','Kaggle Hat','February', 10162, 10696, 11180, 12460],
    [0,'Kaggle Mart','Kaggle Hat','March', 11897, 12526, 13111, 14581],
    [0,'Kaggle Mart','Kaggle Hat','April', 12234, 12447, 14007, 15125],
    [0,'Kaggle Mart','Kaggle Hat','May', 12164, 12492, 12821, 14866],
    [0,'Kaggle Mart','Kaggle Hat','June', 10427, 10639, 11846, 12875],
    [0,'Kaggle Mart','Kaggle Hat','July', 9182, 9714, 10732, 11336],
    [0,'Kaggle Mart','Kaggle Hat','August', 8369, 8546, 9479, 10113],
    [0,'Kaggle Mart','Kaggle Hat','September', 7340, 7645, 8538, 9208],
    [0,'Kaggle Mart','Kaggle Hat','October', 7530, 8083, 8706, 9382],
    [0,'Kaggle Mart','Kaggle Hat','November', 8186, 8622, 9590, 9951],
    [0,'Kaggle Mart','Kaggle Hat','December', 11179, 11982, 13635, 14321],
]

allFinlandKaggleMartKaggleHatData = pd.DataFrame(
    FinlandKaggleMartKaggleHatData, columns=['Store_Id','Store','Product','Finland Kaggle Mart: Hats','2015','2016','2017','2018']
)

FinlandKaggleMartKaggleMugData = [
    [0,'Kaggle Mart','Kaggle Mug','January', 6857, 7266, 7508, 8355],
    [0,'Kaggle Mart','Kaggle Mug','February', 5419, 5770, 6142, 6654],
    [0,'Kaggle Mart','Kaggle Mug','March', 5765, 6000, 6306, 6849],
    [0,'Kaggle Mart','Kaggle Mug','April', 5539, 5517, 6194, 6817],
    [0,'Kaggle Mart','Kaggle Mug','May', 5323, 5420, 5797, 6585],
    [0,'Kaggle Mart','Kaggle Mug','June', 4807, 4813, 5577, 6028],
    [0,'Kaggle Mart','Kaggle Mug','July', 4731, 4893, 5448, 5744],
    [0,'Kaggle Mart','Kaggle Mug','August', 4887, 5077, 5574, 6111],
    [0,'Kaggle Mart','Kaggle Mug','September', 5067, 5264, 5774, 6390],
    [0,'Kaggle Mart','Kaggle Mug','October', 5740, 5975, 6436, 6881],
    [0,'Kaggle Mart','Kaggle Mug','November', 5942, 6251, 7002, 7337],
    [0,'Kaggle Mart','Kaggle Mug','December', 7688, 8083, 9067, 9667],
]

allFinlandKaggleMartKaggleMugData = pd.DataFrame(
    FinlandKaggleMartKaggleMugData, columns=['Store_Id','Store','Product',"Finland Kaggle Mart: Mugs",'2015','2016','2017','2018']
)

FinlandKaggleMartKaggleStickerData = [
    [0,'Kaggle Mart','Kaggle Sticker','January', 3010, 3217, 3297, 3780],
    [0,'Kaggle Mart','Kaggle Sticker','February', 2490, 2656, 2818, 3060],
    [0,'Kaggle Mart','Kaggle Sticker','March', 2799, 2939, 3041, 3431],
    [0,'Kaggle Mart','Kaggle Sticker','April', 2870, 2915, 3265, 3555],
    [0,'Kaggle Mart','Kaggle Sticker','May', 2998, 3056, 3306, 3717],
    [0,'Kaggle Mart','Kaggle Sticker','June', 2828, 2841, 3220, 3541],
    [0,'Kaggle Mart','Kaggle Sticker','July', 2749, 2896, 3178, 3378],
    [0,'Kaggle Mart','Kaggle Sticker','August', 2798, 2845, 3174, 3446],
    [0,'Kaggle Mart','Kaggle Sticker','September', 2688, 2806, 3070, 3337],
    [0,'Kaggle Mart','Kaggle Sticker','October', 2755, 2981, 3132, 3414],
    [0,'Kaggle Mart','Kaggle Sticker','November', 2764, 2862, 3178, 3291],
    [0,'Kaggle Mart','Kaggle Sticker','December', 3385, 3552, 4041, 4178],
]

allFinlandKaggleMartKaggleStickerData = pd.DataFrame(
    FinlandKaggleMartKaggleStickerData, columns=['Store_Id','Store','Product',"Finland Kaggle Mart: Stickers",'2015','2016','2017','2018']
)

###################################################################################################################################################


FinlandKaggleRamaKaggleHatData = [
    [1,'Kaggle Rama','Kaggle Hat','January', 19343, 20807, 21480, 23820],
    [1,'Kaggle Rama','Kaggle Hat','February', 17720, 18501, 19559, 21375],
    [1,'Kaggle Rama','Kaggle Hat','March', 20569, 21637, 22534, 25170],
    [1,'Kaggle Rama','Kaggle Hat','April', 21142, 21760, 23986, 26437],
    [1,'Kaggle Rama','Kaggle Hat','May', 21430, 21796, 22708, 25766],
    [1,'Kaggle Rama','Kaggle Hat','June', 18542, 18603, 20679, 22128],
    [1,'Kaggle Rama','Kaggle Hat','July', 16140, 17158, 18293, 19688],
    [1,'Kaggle Rama','Kaggle Hat','August', 14339, 14859, 16212, 17912],
    [1,'Kaggle Rama','Kaggle Hat','September', 13002, 13437, 15000, 15943],
    [1,'Kaggle Rama','Kaggle Hat','October', 13394, 14209, 15153, 16308],
    [1,'Kaggle Rama','Kaggle Hat','November', 14339, 14655, 16272, 17096],
    [1,'Kaggle Rama','Kaggle Hat','December', 19280, 21055, 23472, 24154],
]

allFinlandKaggleRamaKaggleHatData = pd.DataFrame(
    FinlandKaggleRamaKaggleHatData, columns=['Store_Id','Store','Product','Finland Kaggle Rama: Hats','2015','2016','2017','2018']
)


FinlandKaggleRamaKaggleMugData = [
    [1,'Kaggle Rama','Kaggle Mug','January', 12056, 12657, 13362, 14665],
    [1,'Kaggle Rama','Kaggle Mug','February', 9570, 10246, 10606, 11751],
    [1,'Kaggle Rama','Kaggle Mug','March', 10056, 10465, 11093, 12186],
    [1,'Kaggle Rama','Kaggle Mug','April', 9534, 9665, 11016, 11809],
    [1,'Kaggle Rama','Kaggle Mug','May', 9269, 9430, 9910, 11354],
    [1,'Kaggle Rama','Kaggle Mug','June', 8273, 8453, 9340, 10400],
    [1,'Kaggle Rama','Kaggle Mug','July', 8157, 8696, 9412, 10135],
    [1,'Kaggle Rama','Kaggle Mug','August', 8561, 8752, 9727, 10605],
    [1,'Kaggle Rama','Kaggle Mug','September', 8887, 9142, 10014, 11134],
    [1,'Kaggle Rama','Kaggle Mug','October', 9837, 10290, 11242, 12085],
    [1,'Kaggle Rama','Kaggle Mug','November', 10396, 10912, 12400, 12737],
    [1,'Kaggle Rama','Kaggle Mug','December', 13251, 13960, 15948, 16832],
]

allFinlandKaggleRamaKaggleMugData = pd.DataFrame(
    FinlandKaggleRamaKaggleMugData, columns=['Store_Id','Store','Product','Finland Kaggle Rama: Mugs','2015','2016','2017','2018']
)


FinlandKaggleRamaKaggleStickerData = [
    [1,'Kaggle Rama','Kaggle Sticker','January', 5336, 5597, 5895, 6485],
    [1,'Kaggle Rama','Kaggle Sticker','February', 4317, 4617, 4987, 5215],
    [1,'Kaggle Rama','Kaggle Sticker','March', 4849, 5163, 5379, 5939],
    [1,'Kaggle Rama','Kaggle Sticker','April', 5024, 5063, 5719, 6191],
    [1,'Kaggle Rama','Kaggle Sticker','May', 5264, 5342, 5641, 6415],
    [1,'Kaggle Rama','Kaggle Sticker','June', 4992, 4974, 5669, 6250],
    [1,'Kaggle Rama','Kaggle Sticker','July', 4849, 5138, 5587, 5975],
    [1,'Kaggle Rama','Kaggle Sticker','August', 4820, 4931, 5478, 5964],
    [1,'Kaggle Rama','Kaggle Sticker','September', 4669, 4791, 5371, 5850],
    [1,'Kaggle Rama','Kaggle Sticker','October', 4948, 5103, 5460, 5977],
    [1,'Kaggle Rama','Kaggle Sticker','November', 4756, 5034, 5643, 5823],
    [1,'Kaggle Rama','Kaggle Sticker','December', 5968, 6420, 7038, 7403],
]

allFinlandKaggleRamaKaggleStickerData = pd.DataFrame(
    FinlandKaggleRamaKaggleStickerData, columns=['Store_Id','Store','Product','Finland Kaggle Rama: Stickers','2015','2016','2017','2018']
)

###################################################################################################################################################


NorwayKaggleMartKaggleHatData = [
    [0,'Kaggle Mart','Kaggle Hat','January', 19017, 18700, 19637, 22121],
    [0,'Kaggle Mart','Kaggle Hat','February', 17453, 17538, 18265, 20236],
    [0,'Kaggle Mart','Kaggle Hat','March', 20339, 20413, 20967, 23964],
    [0,'Kaggle Mart','Kaggle Hat','April', 22088, 19795, 23403, 25423],
    [0,'Kaggle Mart','Kaggle Hat','May', 22265, 20973, 21982, 25539],
    [0,'Kaggle Mart','Kaggle Hat','June', 17462, 16645, 19107, 20257],
    [0,'Kaggle Mart','Kaggle Hat','July', 16045, 15212, 17128, 18488],
    [0,'Kaggle Mart','Kaggle Hat','August', 14474, 13514, 15304, 16851],
    [0,'Kaggle Mart','Kaggle Hat','September', 12994, 12184, 13927, 15324],
    [0,'Kaggle Mart','Kaggle Hat','October', 13251, 13016, 14175, 15395],
    [0,'Kaggle Mart','Kaggle Hat','November', 13899, 13395, 14921, 15993],
    [0,'Kaggle Mart','Kaggle Hat','December', 18791, 18264, 20565, 22078],
]

allNorwayKaggleMartKaggleHatData = pd.DataFrame(
    NorwayKaggleMartKaggleHatData, columns=['Store_Id','Store','Product','Norway Kaggle Mart: Hats','2015','2016','2017','2018']
)


NorwayKaggleMartKaggleMugData = [
    [0,'Kaggle Mart','Kaggle Mug','January', 11862, 11373, 11759, 13248],
    [0,'Kaggle Mart','Kaggle Mug','February', 9488, 9533, 9973, 10981],
    [0,'Kaggle Mart','Kaggle Mug','March', 9999, 9991, 10108, 11739],
    [0,'Kaggle Mart','Kaggle Mug','April', 9870, 8738, 10467, 11588],
    [0,'Kaggle Mart','Kaggle Mug','May', 9675, 9082, 9551, 11312],
    [0,'Kaggle Mart','Kaggle Mug','June', 7861, 7462, 8553, 9326],
    [0,'Kaggle Mart','Kaggle Mug','July', 8038, 7827, 8859, 9329],
    [0,'Kaggle Mart','Kaggle Mug','August', 8596, 7989, 9019, 9891],
    [0,'Kaggle Mart','Kaggle Mug','September', 8846, 8420, 9580, 10508],
    [0,'Kaggle Mart','Kaggle Mug','October', 9817, 9525, 10336, 11534],
    [0,'Kaggle Mart','Kaggle Mug','November', 10143, 9842, 11134, 11653],
    [0,'Kaggle Mart','Kaggle Mug','December', 12621, 12525, 14010, 14934],
]

allNorwayKaggleMartKaggleMugData = pd.DataFrame(
    NorwayKaggleMartKaggleMugData, columns=['Store_Id','Store','Product','Norway Kaggle Mart: Mugs','2015','2016','2017','2018']
)


NorwayKaggleMartKaggleStickerData = [
    [0,'Kaggle Mart','Kaggle Sticker','January', 5193, 5125, 5351, 6062],
    [0,'Kaggle Mart','Kaggle Sticker','February', 4338, 4296, 4481, 5050],
    [0,'Kaggle Mart','Kaggle Sticker','March', 4870, 4853, 4962, 5569],
    [0,'Kaggle Mart','Kaggle Sticker','April', 5050, 4673, 5454, 5993],
    [0,'Kaggle Mart','Kaggle Sticker','May', 5546, 5157, 5433, 6444],
    [0,'Kaggle Mart','Kaggle Sticker','June', 4683, 4516, 5138, 5475],
    [0,'Kaggle Mart','Kaggle Sticker','July', 4785, 4658, 5221, 5581],
    [0,'Kaggle Mart','Kaggle Sticker','August', 4851, 4590, 5085, 5609],
    [0,'Kaggle Mart','Kaggle Sticker','September', 4668, 4546, 4975, 5561],
    [0,'Kaggle Mart','Kaggle Sticker','October', 4876, 4713, 5079, 5487],
    [0,'Kaggle Mart','Kaggle Sticker','November', 4678, 4483, 5039, 5427],
    [0,'Kaggle Mart','Kaggle Sticker','December', 5569, 5567, 6280, 6713],
]

allNorwayKaggleMartKaggleStickerData = pd.DataFrame(
    NorwayKaggleMartKaggleStickerData, columns=['Store_Id','Store','Product','Norway Kaggle Mart: Stickers','2015','2016','2017','2018']
)


###################################################################################################################################################


NorwayKaggleRamaKaggleHatData = [
    [1,'Kaggle Rama','Kaggle Hat','January', 33301, 32809, 33890, 38289],
    [1,'Kaggle Rama','Kaggle Hat','February', 30715, 30225, 31995, 35188],
    [1,'Kaggle Rama','Kaggle Hat','March', 36124, 35940, 36912, 41601],
    [1,'Kaggle Rama','Kaggle Hat','April', 37640, 34740, 40496, 44334],
    [1,'Kaggle Rama','Kaggle Hat','May', 38719, 36495, 38048, 45016],
    [1,'Kaggle Rama','Kaggle Hat','June', 30028, 28615, 32824, 35767],
    [1,'Kaggle Rama','Kaggle Hat','July', 27984, 26545, 30162, 32383],
    [1,'Kaggle Rama','Kaggle Hat','August', 24644, 23848, 26424, 29121],
    [1,'Kaggle Rama','Kaggle Hat','September', 22263, 21568, 23969, 26715],
    [1,'Kaggle Rama','Kaggle Hat','October', 23266, 22885, 24361, 26933],
    [1,'Kaggle Rama','Kaggle Hat','November', 24230, 23115, 26076, 27536],
    [1,'Kaggle Rama','Kaggle Hat','December', 32971, 31928, 36844, 38637],
]

allNorwayKaggleRamaKaggleHatData = pd.DataFrame(
    NorwayKaggleRamaKaggleHatData, columns=['Store_Id','Store','Product','Norway Kaggle Rama: Hats','2015','2016','2017','2018']
)


NorwayKaggleRamaKaggleMugData = [
    [1,'Kaggle Rama','Kaggle Mug','January', 20163, 20124, 20531, 23117],
    [1,'Kaggle Rama','Kaggle Mug','February', 16451, 16478, 17464, 19502],
    [1,'Kaggle Rama','Kaggle Mug','March', 17218, 17548, 18004, 20311],
    [1,'Kaggle Rama','Kaggle Mug','April', 17079, 15753, 18163, 19860],
    [1,'Kaggle Rama','Kaggle Mug','May', 16985, 16227, 16654, 19583],
    [1,'Kaggle Rama','Kaggle Mug','June', 13762, 13056, 15238, 16313],
    [1,'Kaggle Rama','Kaggle Mug','July', 14230, 13644, 15216, 16476],
    [1,'Kaggle Rama','Kaggle Mug','August', 14801, 14031, 15845, 17394],
    [1,'Kaggle Rama','Kaggle Mug','September', 15314, 14707, 16721, 17956],
    [1,'Kaggle Rama','Kaggle Mug','October', 17184, 16865, 18649, 20193],
    [1,'Kaggle Rama','Kaggle Mug','November', 17818, 16971, 19140, 20307],
    [1,'Kaggle Rama','Kaggle Mug','December', 21992, 21602, 24785, 26234],
]

allNorwayKaggleRamaKaggleMugData = pd.DataFrame(
    NorwayKaggleRamaKaggleMugData, columns=['Store_Id','Store','Product','Norway Kaggle Rama: Mugs','2015','2016','2017','2018']
)


NorwayKaggleRamaKaggleStickerData = [
    [1,'Kaggle Rama','Kaggle Sticker','January', 9003, 8743, 9317, 10444],
    [1,'Kaggle Rama','Kaggle Sticker','February', 7553, 7471, 7813, 8848],
    [1,'Kaggle Rama','Kaggle Sticker','March', 8438, 8491, 8722, 9898],
    [1,'Kaggle Rama','Kaggle Sticker','April', 8878, 8257, 9482, 10601],
    [1,'Kaggle Rama','Kaggle Sticker','May', 9410, 8999, 9590, 11181],
    [1,'Kaggle Rama','Kaggle Sticker','June', 8024, 7803, 9046, 9411],
    [1,'Kaggle Rama','Kaggle Sticker','July', 8575, 8186, 9038, 9772],
    [1,'Kaggle Rama','Kaggle Sticker','August', 8520, 8036, 8875, 9899],
    [1,'Kaggle Rama','Kaggle Sticker','September', 8203, 7855, 8753, 9496],
    [1,'Kaggle Rama','Kaggle Sticker','October', 8300, 8270, 8966, 9702],
    [1,'Kaggle Rama','Kaggle Sticker','November', 8074, 7893, 8809, 9367],
    [1,'Kaggle Rama','Kaggle Sticker','December', 9819, 9653, 10972, 11427],
]

allNorwayKaggleRamaKaggleStickerData = pd.DataFrame(
    NorwayKaggleRamaKaggleStickerData, columns=['Store_Id','Store','Product','Norway Kaggle Rama: Stickers','2015','2016','2017','2018']
)

###################################################################################################################################################


SwedenKaggleMartKaggleHatData = [
    [0,'Kaggle Mart','Kaggle Hat','January', 13525, 14496, 14692, 15253],
    [0,'Kaggle Mart','Kaggle Hat','February', 12351, 12802, 13094, 13479],
    [0,'Kaggle Mart','Kaggle Hat','March', 14123, 14768, 15078, 15986],
    [0,'Kaggle Mart','Kaggle Hat','April', 14745, 14694, 16186, 16518],
    [0,'Kaggle Mart','Kaggle Hat','May', 14689, 14784, 15033, 16085],
    [0,'Kaggle Mart','Kaggle Hat','June', 12985, 13128, 14452, 14522],
    [0,'Kaggle Mart','Kaggle Hat','July', 11021, 11636, 12452, 12235],
    [0,'Kaggle Mart','Kaggle Hat','August', 9977, 10063, 10826, 10886],
    [0,'Kaggle Mart','Kaggle Hat','September', 8914, 8998, 9840, 9961],
    [0,'Kaggle Mart','Kaggle Hat','October', 9359, 9620, 10105, 10123],
    [0,'Kaggle Mart','Kaggle Hat','November', 9847, 10126, 10866, 10815],
    [0,'Kaggle Mart','Kaggle Hat','December', 13129, 13965, 15322, 14918],
]

allSwedenKaggleMartKaggleHatData = pd.DataFrame(
    SwedenKaggleMartKaggleHatData, columns=['Store_Id','Store','Product','Sweden Kaggle Mart: Hats','2015','2016','2017','2018']
)


SwedenKaggleMartKaggleMugData = [
    [0,'Kaggle Mart','Kaggle Mug','January', 8355, 8627, 9047, 9266],
    [0,'Kaggle Mart','Kaggle Mug','February', 6696, 6963, 7034, 7280],
    [0,'Kaggle Mart','Kaggle Mug','March', 6947, 7158, 7307, 7600],
    [0,'Kaggle Mart','Kaggle Mug','April', 6499, 6517, 7291, 7409],
    [0,'Kaggle Mart','Kaggle Mug','May', 6400, 6332, 6644, 7105],
    [0,'Kaggle Mart','Kaggle Mug','June', 5915, 5842, 6440, 6611],
    [0,'Kaggle Mart','Kaggle Mug','July', 5594, 5816, 6233, 6259],
    [0,'Kaggle Mart','Kaggle Mug','August', 5966, 5977, 6485, 6629],
    [0,'Kaggle Mart','Kaggle Mug','September', 6074, 6174, 6769, 7012],
    [0,'Kaggle Mart','Kaggle Mug','October', 6782, 7122, 7603, 7583],
    [0,'Kaggle Mart','Kaggle Mug','November', 7178, 7358, 8106, 7830],
    [0,'Kaggle Mart','Kaggle Mug','December', 8936, 9368, 10375, 10114],
]

allSwedenKaggleMartKaggleMugData = pd.DataFrame(
    SwedenKaggleMartKaggleMugData, columns=['Store_Id','Store','Product','Sweden Kaggle Mart: Mugs','2015','2016','2017','2018']
)


SwedenKaggleMartKaggleStickerData = [
    [0,'Kaggle Mart','Kaggle Sticker','January', 3690, 3933, 4024, 4252],
    [0,'Kaggle Mart','Kaggle Sticker','February', 3047, 3122, 3168, 3355],
    [0,'Kaggle Mart','Kaggle Sticker','March', 3324, 3452, 3526, 3750],
    [0,'Kaggle Mart','Kaggle Sticker','April', 3432, 3471, 3764, 3887],
    [0,'Kaggle Mart','Kaggle Sticker','May', 3653, 3547, 3733, 4017],
    [0,'Kaggle Mart','Kaggle Sticker','June', 3536, 3511, 3824, 3924],
    [0,'Kaggle Mart','Kaggle Sticker','July', 3282, 3455, 3738, 3753],
    [0,'Kaggle Mart','Kaggle Sticker','August', 3353, 3416, 3678, 3769],
    [0,'Kaggle Mart','Kaggle Sticker','September', 3221, 3349, 3557, 3649],
    [0,'Kaggle Mart','Kaggle Sticker','October', 3356, 3468, 3657, 3665],
    [0,'Kaggle Mart','Kaggle Sticker','November', 3318, 3429, 3747, 3666],
    [0,'Kaggle Mart','Kaggle Sticker','December', 3983, 4160, 4572, 4572],
]

allSwedenKaggleMartKaggleStickerData = pd.DataFrame(
    SwedenKaggleMartKaggleStickerData, columns=['Store_Id','Store','Product','Sweden Kaggle Mart: Stickers','2015','2016','2017','2018']
)


###################################################################################################################################################


SwedenKaggleRamaKaggleHatData = [
    [1,'Kaggle Rama','Kaggle Hat','January', 23851, 25136, 25702, 26801],
    [1,'Kaggle Rama','Kaggle Hat','February', 20992, 22412, 23079, 23820],
    [1,'Kaggle Rama','Kaggle Hat','March', 24819, 25777, 26213, 27413],
    [1,'Kaggle Rama','Kaggle Hat','April', 25619, 25696, 27928, 28679],
    [1,'Kaggle Rama','Kaggle Hat','May', 25659, 25603, 26652, 28358],
    [1,'Kaggle Rama','Kaggle Hat','June', 22552, 22575, 25023, 25641],
    [1,'Kaggle Rama','Kaggle Hat','July', 19613, 20429, 21579, 21748],
    [1,'Kaggle Rama','Kaggle Hat','August', 17698, 17735, 18876, 19193],
    [1,'Kaggle Rama','Kaggle Hat','September', 15577, 16042, 17024, 17456],
    [1,'Kaggle Rama','Kaggle Hat','October', 16173, 16742, 17468, 17759],
    [1,'Kaggle Rama','Kaggle Hat','November', 16942, 17610, 19021, 18516],
    [1,'Kaggle Rama','Kaggle Hat','December', 23063, 23776, 26228, 26384],
]

allSwedenKaggleRamaKaggleHatData = pd.DataFrame(
    SwedenKaggleRamaKaggleHatData, columns=['Store_Id','Store','Product','Sweden Kaggle Rama: Hats','2015','2016','2017','2018']
)


SwedenKaggleRamaKaggleMugData = [
    [1,'Kaggle Rama','Kaggle Mug','January', 14573, 15494, 15576, 16365],
    [1,'Kaggle Rama','Kaggle Mug','February', 11442, 11975, 12208, 12640],
    [1,'Kaggle Rama','Kaggle Mug','March', 12311, 12449, 12669, 13261],
    [1,'Kaggle Rama','Kaggle Mug','April', 11376, 11265, 12464, 13064],
    [1,'Kaggle Rama','Kaggle Mug','May', 11140, 11305, 11641, 12183],
    [1,'Kaggle Rama','Kaggle Mug','June', 10160, 10327, 11397, 11421],
    [1,'Kaggle Rama','Kaggle Mug','July', 9734, 10177, 10713, 10960],
    [1,'Kaggle Rama','Kaggle Mug','August', 10320, 10479, 11177, 11574],
    [1,'Kaggle Rama','Kaggle Mug','September', 10677, 10770, 11768, 12087],
    [1,'Kaggle Rama','Kaggle Mug','October', 11959, 12337, 13055, 13134],
    [1,'Kaggle Rama','Kaggle Mug','November', 12564, 13168, 13823, 13942],
    [1,'Kaggle Rama','Kaggle Mug','December', 15611, 16323, 17917, 17895],
]

allSwedenKaggleRamaKaggleMugData = pd.DataFrame(
    SwedenKaggleRamaKaggleMugData, columns=['Store_Id','Store','Product','Sweden Kaggle Rama: Mugs','2015','2016','2017','2018']
)


SwedenKaggleRamaKaggleStickerData = [
    [1,'Kaggle Rama','Kaggle Sticker','January', 6326, 6897, 6971, 7252],
    [1,'Kaggle Rama','Kaggle Sticker','February', 5365, 5587, 5576, 5890],
    [1,'Kaggle Rama','Kaggle Sticker','March', 5869, 6079, 6227, 6506],
    [1,'Kaggle Rama','Kaggle Sticker','April', 5959, 6033, 6705, 6682],
    [1,'Kaggle Rama','Kaggle Sticker','May', 6367, 6253, 6416, 6856],
    [1,'Kaggle Rama','Kaggle Sticker','June', 6081, 6076, 6626, 6457],
    [1,'Kaggle Rama','Kaggle Sticker','July', 5918, 6022, 6520, 6337],
    [1,'Kaggle Rama','Kaggle Sticker','August', 5766, 5938, 6329, 6403],
    [1,'Kaggle Rama','Kaggle Sticker','September', 5578, 5762, 6175, 6534],
    [1,'Kaggle Rama','Kaggle Sticker','October', 5815, 6070, 6385, 6403],
    [1,'Kaggle Rama','Kaggle Sticker','November', 5864, 6054, 6392, 6300],
    [1,'Kaggle Rama','Kaggle Sticker','December', 6932, 7155, 8097, 7852],
]

allSwedenKaggleRamaKaggleStickerData = pd.DataFrame(
    SwedenKaggleRamaKaggleStickerData, columns=['Store_Id','Store','Product','Sweden Kaggle Rama: Stickers','2015','2016','2017','2018']
)




###################################################################################################################################################

totalKaggleMartKaggleHatData = allFinlandKaggleMartKaggleHatData["2015"] + allFinlandKaggleMartKaggleHatData["2016"] + allFinlandKaggleMartKaggleHatData["2017"] + allFinlandKaggleMartKaggleHatData["2018"] 
allFinlandKaggleMartKaggleHatData["Total"] = totalKaggleMartKaggleHatData

totalKaggleMartKaggleMugData = allFinlandKaggleMartKaggleMugData["2015"] + allFinlandKaggleMartKaggleMugData["2016"] + allFinlandKaggleMartKaggleMugData["2017"] + allFinlandKaggleMartKaggleMugData["2018"] 
allFinlandKaggleMartKaggleMugData["Total"] = totalKaggleMartKaggleMugData

totalKaggleMartKaggleStickerData = allFinlandKaggleMartKaggleStickerData["2015"] + allFinlandKaggleMartKaggleStickerData["2016"] + allFinlandKaggleMartKaggleStickerData["2017"] + allFinlandKaggleMartKaggleStickerData["2018"] 
allFinlandKaggleMartKaggleStickerData["Total"] = totalKaggleMartKaggleStickerData


###################################################################################################################################################


totalKaggleRamaKaggleHatData = allFinlandKaggleRamaKaggleHatData["2015"] + allFinlandKaggleRamaKaggleHatData["2016"] + allFinlandKaggleRamaKaggleHatData["2017"] + allFinlandKaggleRamaKaggleHatData["2018"] 
allFinlandKaggleRamaKaggleHatData["Total"] = totalKaggleRamaKaggleHatData

totalKaggleRamaKaggleMugData = allFinlandKaggleRamaKaggleMugData["2015"] + allFinlandKaggleRamaKaggleMugData["2016"] + allFinlandKaggleRamaKaggleMugData["2017"] + allFinlandKaggleRamaKaggleMugData["2018"] 
allFinlandKaggleRamaKaggleMugData["Total"] = totalKaggleRamaKaggleMugData

totalKaggleRamaKaggleStickerData = allFinlandKaggleRamaKaggleStickerData["2015"] + allFinlandKaggleRamaKaggleStickerData["2016"] + allFinlandKaggleRamaKaggleStickerData["2017"] + allFinlandKaggleRamaKaggleStickerData["2018"] 
allFinlandKaggleRamaKaggleStickerData["Total"] = totalKaggleRamaKaggleStickerData


###################################################################################################################################################


totalNorwayKaggleMartKaggleHatData = allNorwayKaggleMartKaggleHatData["2015"] + allNorwayKaggleMartKaggleHatData["2016"] + allNorwayKaggleMartKaggleHatData["2017"] + allNorwayKaggleMartKaggleHatData["2018"] 
allNorwayKaggleMartKaggleHatData["Total"] = totalNorwayKaggleMartKaggleHatData

totalNorwayKaggleMartKaggleMugData = allNorwayKaggleMartKaggleMugData["2015"] + allNorwayKaggleMartKaggleMugData["2016"] + allNorwayKaggleMartKaggleMugData["2017"] + allNorwayKaggleMartKaggleMugData["2018"] 
allNorwayKaggleMartKaggleMugData["Total"] = totalNorwayKaggleMartKaggleMugData

totalNorwayKaggleMartKaggleStickerData = allNorwayKaggleMartKaggleStickerData["2015"] + allNorwayKaggleMartKaggleStickerData["2016"] + allNorwayKaggleMartKaggleStickerData["2017"] + allNorwayKaggleMartKaggleStickerData["2018"] 
allNorwayKaggleMartKaggleStickerData["Total"] = totalNorwayKaggleMartKaggleStickerData



####################################################################################################################################################



totalNorwayKaggleRamaKaggleHatData = allNorwayKaggleRamaKaggleHatData["2015"] + allNorwayKaggleRamaKaggleHatData["2016"] + allNorwayKaggleRamaKaggleHatData["2017"] + allNorwayKaggleRamaKaggleHatData["2018"] 
allNorwayKaggleRamaKaggleHatData["Total"] = totalNorwayKaggleRamaKaggleHatData

totalNorwayKaggleRamaKaggleMugData = allNorwayKaggleRamaKaggleMugData["2015"] + allNorwayKaggleRamaKaggleMugData["2016"] + allNorwayKaggleRamaKaggleMugData["2017"] + allNorwayKaggleRamaKaggleMugData["2018"] 
allNorwayKaggleRamaKaggleMugData["Total"] = totalNorwayKaggleRamaKaggleMugData

totalNorwayKaggleRamaKaggleStickerData = allNorwayKaggleRamaKaggleStickerData["2015"] + allNorwayKaggleRamaKaggleStickerData["2016"] + allNorwayKaggleRamaKaggleStickerData["2017"] + allNorwayKaggleRamaKaggleStickerData["2018"] 
allNorwayKaggleRamaKaggleStickerData["Total"] = totalNorwayKaggleRamaKaggleStickerData


####################################################################################################################################################


totalSwedenKaggleMartKaggleHatData = allSwedenKaggleMartKaggleHatData["2015"] + allSwedenKaggleMartKaggleHatData["2016"] + allSwedenKaggleMartKaggleHatData["2017"] + allSwedenKaggleMartKaggleHatData["2018"] 
allSwedenKaggleMartKaggleHatData["Total"] = totalSwedenKaggleMartKaggleHatData

totalSwedenKaggleMartKaggleMugData = allSwedenKaggleMartKaggleMugData["2015"] + allSwedenKaggleMartKaggleMugData["2016"] + allSwedenKaggleMartKaggleMugData["2017"] + allSwedenKaggleMartKaggleMugData["2018"] 
allSwedenKaggleMartKaggleMugData["Total"] = totalSwedenKaggleMartKaggleMugData

totalSwedenKaggleMartKaggleStickerData = allSwedenKaggleMartKaggleStickerData["2015"] + allSwedenKaggleMartKaggleStickerData["2016"] + allSwedenKaggleMartKaggleStickerData["2017"] + allSwedenKaggleMartKaggleStickerData["2018"] 
allSwedenKaggleMartKaggleStickerData["Total"] = totalSwedenKaggleMartKaggleStickerData


####################################################################################################################################################


totalSwedenKaggleRamaKaggleHatData = allSwedenKaggleRamaKaggleHatData["2015"] + allSwedenKaggleRamaKaggleHatData["2016"] + allSwedenKaggleRamaKaggleHatData["2017"] + allSwedenKaggleRamaKaggleHatData["2018"] 
allSwedenKaggleRamaKaggleHatData["Total"] = totalSwedenKaggleRamaKaggleHatData

totalSwedenKaggleRamaKaggleMugData = allSwedenKaggleRamaKaggleMugData["2015"] + allSwedenKaggleRamaKaggleMugData["2016"] + allSwedenKaggleRamaKaggleMugData["2017"] + allSwedenKaggleRamaKaggleMugData["2018"] 
allSwedenKaggleRamaKaggleMugData["Total"] = totalSwedenKaggleRamaKaggleMugData

totalSwedenKaggleRamaKaggleStickerData = allSwedenKaggleRamaKaggleStickerData["2015"] + allSwedenKaggleRamaKaggleStickerData["2016"] + allSwedenKaggleRamaKaggleStickerData["2017"] + allSwedenKaggleRamaKaggleStickerData["2018"] 
allSwedenKaggleRamaKaggleStickerData["Total"] = totalSwedenKaggleRamaKaggleStickerData

# %% [markdown]
# <a id="11"></a> <br>
# # Finland: Kaggle Stores Products Sales
#
# **<p id='11'><li>Finland Kaggle Mart Hats</li></p>**

# %%
totals = allFinlandKaggleMartKaggleHatData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleHatData['2018'],
    x=allFinlandKaggleMartKaggleHatData['Finland Kaggle Mart: Hats'],
    name='2018',
    text = allFinlandKaggleMartKaggleHatData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(102, 157, 179)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleHatData['2017'],
    x=allFinlandKaggleMartKaggleHatData['Finland Kaggle Mart: Hats'],
    name='2017',
    text = allFinlandKaggleMartKaggleHatData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(240, 246, 247)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleHatData['2016'],
    x=allFinlandKaggleMartKaggleHatData['Finland Kaggle Mart: Hats'],
    name='2016',
    text = allFinlandKaggleMartKaggleHatData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(168, 156, 148)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleHatData['2015'],
    x=allFinlandKaggleMartKaggleHatData['Finland Kaggle Mart: Hats'],
    name='2015',
    text = allFinlandKaggleMartKaggleHatData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 79, 88)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allFinlandKaggleMartKaggleHatData['Finland Kaggle Mart: Hats'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Finland: Kaggle Mart (Hats)<br><sup>Kaggle Hats Sales in Finland (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='12'><li>Finland Kaggle Rama Hats</li></p>**

# %%
totals = allFinlandKaggleRamaKaggleHatData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleHatData['2018'],
    x=allFinlandKaggleRamaKaggleHatData['Finland Kaggle Rama: Hats'],
    name='2018',
    text = allFinlandKaggleRamaKaggleHatData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(171, 209, 201)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleHatData['2017'],
    x=allFinlandKaggleRamaKaggleHatData['Finland Kaggle Rama: Hats'],
    name='2017',
    text = allFinlandKaggleRamaKaggleHatData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(223, 220, 229)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleHatData['2016'],
    x=allFinlandKaggleRamaKaggleHatData['Finland Kaggle Rama: Hats'],
    name='2016',
    text = allFinlandKaggleRamaKaggleHatData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(219, 176, 74)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleHatData['2015'],
    x=allFinlandKaggleRamaKaggleHatData['Finland Kaggle Rama: Hats'],
    name='2015',
    text = allFinlandKaggleRamaKaggleHatData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(151, 179, 208)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allFinlandKaggleRamaKaggleHatData['Finland Kaggle Rama: Hats'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Finland: Kaggle Rama (Hats)<br><sup>Kaggle Hats Sales in Finland (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='13'><li>Finland Kaggle Mart Mug</li></p>**

# %%
totals = allFinlandKaggleMartKaggleMugData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleMugData['2018'],
    x=allFinlandKaggleMartKaggleMugData['Finland Kaggle Mart: Mugs'],
    name='2018',
    text = allFinlandKaggleMartKaggleMugData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(102, 157, 179)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleMugData['2017'],
    x=allFinlandKaggleMartKaggleMugData['Finland Kaggle Mart: Mugs'],
    name='2017',
    text = allFinlandKaggleMartKaggleMugData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(240, 246, 247)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleMugData['2016'],
    x=allFinlandKaggleMartKaggleMugData['Finland Kaggle Mart: Mugs'],
    name='2016',
    text = allFinlandKaggleMartKaggleMugData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(168, 156, 148)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleMugData['2015'],
    x=allFinlandKaggleMartKaggleMugData['Finland Kaggle Mart: Mugs'],
    name='2015',
    text = allFinlandKaggleMartKaggleMugData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 79, 88)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allFinlandKaggleMartKaggleMugData['Finland Kaggle Mart: Mugs'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Finland: Kaggle Mart (Mugs)<br><sup>Kaggle Mugs Sales in Finland (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='14'><li>Finland Kaggle Rama Mugs</li></p>**

# %%
totals = allFinlandKaggleRamaKaggleMugData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleMugData['2018'],
    x=allFinlandKaggleRamaKaggleMugData['Finland Kaggle Rama: Mugs'],
    name='2018',
    text = allFinlandKaggleRamaKaggleMugData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(171, 209, 201)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleMugData['2017'],
    x=allFinlandKaggleRamaKaggleMugData['Finland Kaggle Rama: Mugs'],
    name='2017',
    text = allFinlandKaggleRamaKaggleMugData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(223, 220, 229)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleMugData['2016'],
    x=allFinlandKaggleRamaKaggleMugData['Finland Kaggle Rama: Mugs'],
    name='2016',
    text = allFinlandKaggleRamaKaggleMugData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(219, 176, 74)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleMugData['2015'],
    x=allFinlandKaggleRamaKaggleMugData['Finland Kaggle Rama: Mugs'],
    name='2015',
    text = allFinlandKaggleRamaKaggleMugData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(151, 179, 208)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allFinlandKaggleRamaKaggleMugData['Finland Kaggle Rama: Mugs'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Finland: Kaggle Rama (Mugs)<br><sup>Kaggle Mugs Sales in Finland (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='15'><li>Finland Kaggle Mart Stickers</li></p>**

# %%
totals = allFinlandKaggleMartKaggleStickerData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleStickerData['2018'],
    x=allFinlandKaggleMartKaggleStickerData['Finland Kaggle Mart: Stickers'],
    name='2018',
    text = allFinlandKaggleMartKaggleStickerData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(102, 157, 179)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleStickerData['2017'],
    x=allFinlandKaggleMartKaggleStickerData['Finland Kaggle Mart: Stickers'],
    name='2017',
    text = allFinlandKaggleMartKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(240, 246, 247)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleStickerData['2016'],
    x=allFinlandKaggleMartKaggleStickerData['Finland Kaggle Mart: Stickers'],
    name='2016',
    text = allFinlandKaggleMartKaggleStickerData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(168, 156, 148)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleMartKaggleStickerData['2015'],
    x=allFinlandKaggleMartKaggleStickerData['Finland Kaggle Mart: Stickers'],
    name='2015',
    text = allFinlandKaggleMartKaggleStickerData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 79, 88)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allFinlandKaggleMartKaggleStickerData['Finland Kaggle Mart: Stickers'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Finland: Kaggle Mart (Stickers)<br><sup>Kaggle Stickers Sales in Finland (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='16'><li>Finland Kaggle Rama Stickers</li></p>**

# %%
totals = allFinlandKaggleRamaKaggleStickerData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleStickerData['2018'],
    x=allFinlandKaggleRamaKaggleStickerData['Finland Kaggle Rama: Stickers'],
    name='2018',
    text = allFinlandKaggleRamaKaggleStickerData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(171, 209, 201)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleStickerData['2017'],
    x=allFinlandKaggleRamaKaggleStickerData['Finland Kaggle Rama: Stickers'],
    name='2017',
    text = allFinlandKaggleRamaKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(223, 220, 229)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleStickerData['2016'],
    x=allFinlandKaggleRamaKaggleStickerData['Finland Kaggle Rama: Stickers'],
    name='2016',
    text = allFinlandKaggleRamaKaggleStickerData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(219, 176, 74)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allFinlandKaggleRamaKaggleStickerData['2015'],
    x=allFinlandKaggleRamaKaggleStickerData['Finland Kaggle Rama: Stickers'],
    name='2015',
    text = allFinlandKaggleRamaKaggleStickerData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(151, 179, 208)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allFinlandKaggleRamaKaggleStickerData['Finland Kaggle Rama: Stickers'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Finland: Kaggle Rama (Stickers)<br><sup>Kaggle Stickers Sales in Finland (2018- 2015)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# <a id="17"></a> <br>
# # Norway: Kaggle Stores Products Sales
#
# **<p id='17'><li>Norway Kaggle Mart Hats</li></p>**

# %%
totals = allNorwayKaggleMartKaggleHatData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleHatData['2018'],
    x=allNorwayKaggleMartKaggleHatData['Norway Kaggle Mart: Hats'],
    name='2018',
    text = allNorwayKaggleMartKaggleHatData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 111, 97)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleHatData['2017'],
    x=allNorwayKaggleMartKaggleHatData['Norway Kaggle Mart: Hats'],
    name='2017',
    text = allNorwayKaggleMartKaggleHatData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(247, 206, 215)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleHatData['2016'],
    x=allNorwayKaggleMartKaggleHatData['Norway Kaggle Mart: Hats'],
    name='2016',
    text = allNorwayKaggleMartKaggleHatData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(249, 159, 201)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleHatData['2015'],
    x=allNorwayKaggleMartKaggleHatData['Norway Kaggle Mart: Hats'],
    name='2015',
    text = allNorwayKaggleMartKaggleHatData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(239, 96, 121)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allNorwayKaggleMartKaggleHatData['Norway Kaggle Mart: Hats'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Norway: Kaggle Mart (Hats)<br><sup>Kaggle Hats Sales in Norway (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='18'><li>Norway Kaggle Rama Hats</li></p>**

# %%
totals = allNorwayKaggleRamaKaggleHatData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleHatData['2018'],
    x=allNorwayKaggleRamaKaggleHatData['Norway Kaggle Rama: Hats'],
    name='2018',
    text = allNorwayKaggleRamaKaggleHatData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 221, 226)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleHatData['2017'],
    x=allNorwayKaggleRamaKaggleHatData['Norway Kaggle Rama: Hats'],
    name='2017',
    text = allNorwayKaggleRamaKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(250, 160, 148)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleHatData['2016'],
    x=allNorwayKaggleRamaKaggleHatData['Norway Kaggle Rama: Hats'],
    name='2016',
    text = allNorwayKaggleRamaKaggleHatData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(158, 217, 204)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleHatData['2015'],
    x=allNorwayKaggleRamaKaggleHatData['Norway Kaggle Rama: Hats'],
    name='2015',
    text = allNorwayKaggleRamaKaggleHatData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(0, 140, 118)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allNorwayKaggleRamaKaggleHatData['Norway Kaggle Rama: Hats'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Norway: Kaggle Rama (Hats)<br><sup>Kaggle Hats Sales in Norway (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='19'><li>Norway Kaggle Mart Mugs</li></p>**

# %%
totals = allNorwayKaggleMartKaggleMugData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleMugData['2018'],
    x=allNorwayKaggleMartKaggleMugData['Norway Kaggle Mart: Mugs'],
    name='2018',
    text = allNorwayKaggleMartKaggleMugData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 111, 97)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleMugData['2017'],
    x=allNorwayKaggleMartKaggleMugData['Norway Kaggle Mart: Mugs'],
    name='2017',
    text = allNorwayKaggleMartKaggleMugData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(247, 206, 215)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleMugData['2016'],
    x=allNorwayKaggleMartKaggleMugData['Norway Kaggle Mart: Mugs'],
    name='2016',
    text = allNorwayKaggleMartKaggleMugData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(249, 159, 201)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleMugData['2015'],
    x=allNorwayKaggleMartKaggleMugData['Norway Kaggle Mart: Mugs'],
    name='2015',
    text = allNorwayKaggleMartKaggleMugData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(239, 96, 121)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allNorwayKaggleMartKaggleMugData['Norway Kaggle Mart: Mugs'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Norway: Kaggle Mart (Mugs)<br><sup>Kaggle Mugs Sales in Norway (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='20'><li>Norway Kaggle Rama Mugs</li></p>**

# %%
totals = allNorwayKaggleRamaKaggleMugData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleMugData['2018'],
    x=allNorwayKaggleRamaKaggleMugData['Norway Kaggle Rama: Mugs'],
    name='2018',
    text = allNorwayKaggleRamaKaggleMugData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 221, 226)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleMugData['2017'],
    x=allNorwayKaggleRamaKaggleMugData['Norway Kaggle Rama: Mugs'],
    name='2017',
    text = allNorwayKaggleRamaKaggleMugData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(250, 160, 148)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleMugData['2016'],
    x=allNorwayKaggleRamaKaggleMugData['Norway Kaggle Rama: Mugs'],
    name='2016',
    text = allNorwayKaggleRamaKaggleMugData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(158, 217, 204)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleMugData['2015'],
    x=allNorwayKaggleRamaKaggleMugData['Norway Kaggle Rama: Mugs'],
    name='2015',
    text = allNorwayKaggleRamaKaggleMugData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(0, 140, 118)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allNorwayKaggleRamaKaggleMugData['Norway Kaggle Rama: Mugs'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Norway: Kaggle Rama (Mugs)<br><sup>Kaggle Mugs Sales in Norway (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='21'><li>Norway Kaggle Mart Stickers</li></p>**

# %%
totals = allNorwayKaggleMartKaggleStickerData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleStickerData['2018'],
    x=allNorwayKaggleMartKaggleStickerData['Norway Kaggle Mart: Stickers'],
    name='2018',
    text = allNorwayKaggleMartKaggleStickerData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 111, 97)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleStickerData['2017'],
    x=allNorwayKaggleMartKaggleStickerData['Norway Kaggle Mart: Stickers'],
    name='2017',
    text = allNorwayKaggleMartKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(247, 206, 215)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleStickerData['2016'],
    x=allNorwayKaggleMartKaggleStickerData['Norway Kaggle Mart: Stickers'],
    name='2016',
    text = allNorwayKaggleMartKaggleStickerData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(249, 159, 201)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleMartKaggleStickerData['2015'],
    x=allNorwayKaggleMartKaggleStickerData['Norway Kaggle Mart: Stickers'],
    name='2015',
    text = allNorwayKaggleMartKaggleStickerData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(239, 96, 121)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allNorwayKaggleMartKaggleStickerData['Norway Kaggle Mart: Stickers'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Norway: Kaggle Mart (Stickers)<br><sup>Kaggle Stickers Sales in Norway (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='22'><li>Norway Kaggle Rama Stickers</li></p>**

# %%
totals = allNorwayKaggleRamaKaggleStickerData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleStickerData['2018'],
    x=allNorwayKaggleRamaKaggleStickerData['Norway Kaggle Rama: Stickers'],
    name='2018',
    text = allNorwayKaggleRamaKaggleStickerData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(255, 221, 226)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleStickerData['2017'],
    x=allNorwayKaggleRamaKaggleStickerData['Norway Kaggle Rama: Stickers'],
    name='2017',
    text = allNorwayKaggleRamaKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(250, 160, 148)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleStickerData['2016'],
    x=allNorwayKaggleRamaKaggleStickerData['Norway Kaggle Rama: Stickers'],
    name='2016',
    text = allNorwayKaggleRamaKaggleStickerData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(158, 217, 204)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allNorwayKaggleRamaKaggleStickerData['2015'],
    x=allNorwayKaggleRamaKaggleStickerData['Norway Kaggle Rama: Stickers'],
    name='2015',
    text = allNorwayKaggleRamaKaggleStickerData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(0, 140, 118)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allNorwayKaggleRamaKaggleStickerData['Norway Kaggle Rama: Stickers'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Norway: Kaggle Rama (Stickers) <br><sup>Kaggle Stickers Sales in Norway (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# <a id="23"></a> <br>
# # Sweden: Kaggle Stores Products Sales
#
# **<p id='23'><li>Sweden Kaggle Mart Hats</li></p>**

# %%
totals = allSwedenKaggleMartKaggleHatData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleHatData['2018'],
    x=allSwedenKaggleMartKaggleHatData['Sweden Kaggle Mart: Hats'],
    name='2018',
    text = allSwedenKaggleMartKaggleHatData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(240, 225, 185)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleHatData['2017'],
    x=allSwedenKaggleMartKaggleHatData['Sweden Kaggle Mart: Hats'],
    name='2017',
    text = allSwedenKaggleMartKaggleHatData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(252, 246, 245)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleHatData['2016'],
    x=allSwedenKaggleMartKaggleHatData['Sweden Kaggle Mart: Hats'],
    name='2016',
    text = allSwedenKaggleMartKaggleHatData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(243, 219, 116)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleHatData['2015'],
    x=allSwedenKaggleMartKaggleHatData['Sweden Kaggle Mart: Hats'],
    name='2015',
    text = allSwedenKaggleMartKaggleHatData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(161, 57, 65)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allSwedenKaggleMartKaggleHatData['Sweden Kaggle Mart: Hats'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Sweden: Kaggle Mart (Hats)<br><sup>Kaggle Hats Sales in Sweden (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='24'><li>Sweden Kaggle Rama Hats</li></p>**

# %%
totals = allSwedenKaggleRamaKaggleHatData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleHatData['2018'],
    x=allSwedenKaggleRamaKaggleHatData['Sweden Kaggle Rama: Hats'],
    name='2018',
    text = allSwedenKaggleRamaKaggleHatData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(46, 82, 102)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleHatData['2017'],
    x=allSwedenKaggleRamaKaggleHatData['Sweden Kaggle Rama: Hats'],
    name='2017',
    text = allSwedenKaggleRamaKaggleHatData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(110, 136, 152)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleHatData['2016'],
    x=allSwedenKaggleRamaKaggleHatData['Sweden Kaggle Rama: Hats'],
    name='2016',
    text = allSwedenKaggleRamaKaggleHatData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(159, 177, 188)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleHatData['2015'],
    x=allSwedenKaggleRamaKaggleHatData['Sweden Kaggle Rama: Hats'],
    name='2015',
    text = allSwedenKaggleRamaKaggleHatData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(211, 208, 203)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allSwedenKaggleRamaKaggleHatData['Sweden Kaggle Rama: Hats'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Sweden: Kaggle Rama (Hats)<br><sup>Kaggle Hats Sales in Sweden (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='25'><li>Sweden Kaggle Mart Mugs</li></p>**

# %%
totals = allSwedenKaggleMartKaggleMugData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleMugData['2018'],
    x=allSwedenKaggleMartKaggleMugData['Sweden Kaggle Mart: Mugs'],
    name='2018',
    text = allSwedenKaggleMartKaggleMugData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(240, 225, 185)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleMugData['2017'],
    x=allSwedenKaggleMartKaggleMugData['Sweden Kaggle Mart: Mugs'],
    name='2017',
    text = allSwedenKaggleMartKaggleMugData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(252, 246, 245)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleMugData['2016'],
    x=allSwedenKaggleMartKaggleMugData['Sweden Kaggle Mart: Mugs'],
    name='2016',
    text = allSwedenKaggleMartKaggleMugData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(243, 219, 116)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleMugData['2015'],
    x=allSwedenKaggleMartKaggleMugData['Sweden Kaggle Mart: Mugs'],
    name='2015',
    text = allSwedenKaggleMartKaggleMugData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(161, 57, 65)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allSwedenKaggleMartKaggleMugData['Sweden Kaggle Mart: Mugs'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Sweden: Kaggle Mart (Mugs)<br><sup>Kaggle Mugs Sales in Sweden (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='26'><li>Sweden Kaggle Rama Mugs</li></p>**

# %%
totals = allSwedenKaggleRamaKaggleMugData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleMugData['2018'],
    x=allSwedenKaggleRamaKaggleMugData['Sweden Kaggle Rama: Mugs'],
    name='2018',
    text = allSwedenKaggleRamaKaggleMugData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(46, 82, 102)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleMugData['2017'],
    x=allSwedenKaggleRamaKaggleMugData['Sweden Kaggle Rama: Mugs'],
    name='2017',
    text = allSwedenKaggleRamaKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(110, 136, 152)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleMugData['2016'],
    x=allSwedenKaggleRamaKaggleMugData['Sweden Kaggle Rama: Mugs'],
    name='2016',
    text = allSwedenKaggleRamaKaggleMugData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(159, 177, 188)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleMugData['2015'],
    x=allSwedenKaggleRamaKaggleMugData['Sweden Kaggle Rama: Mugs'],
    name='2015',
    text = allSwedenKaggleRamaKaggleMugData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(211, 208, 203)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allSwedenKaggleRamaKaggleMugData['Sweden Kaggle Rama: Mugs'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Sweden: Kaggle Rama (Mugs)<br><sup>Kaggle Mugs Sales in Sweden (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='27'><li>Sweden Kaggle Mart Stickers</li></p>**

# %%
totals = allSwedenKaggleMartKaggleStickerData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleStickerData['2018'],
    x=allSwedenKaggleMartKaggleStickerData['Sweden Kaggle Mart: Stickers'],
    name='2018',
    text = allSwedenKaggleMartKaggleStickerData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(240, 225, 185)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleStickerData['2017'],
    x=allSwedenKaggleMartKaggleStickerData['Sweden Kaggle Mart: Stickers'],
    name='2017',
    text = allSwedenKaggleMartKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(252, 246, 245)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleStickerData['2016'],
    x=allSwedenKaggleMartKaggleStickerData['Sweden Kaggle Mart: Stickers'],
    name='2016',
    text = allSwedenKaggleMartKaggleStickerData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(243, 219, 116)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleMartKaggleStickerData['2015'],
    x=allSwedenKaggleMartKaggleStickerData['Sweden Kaggle Mart: Stickers'],
    name='2015',
    text = allSwedenKaggleMartKaggleStickerData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(161, 57, 65)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allSwedenKaggleMartKaggleStickerData['Sweden Kaggle Mart: Stickers'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Sweden: Kaggle Mart (Stickers)<br><sup>Kaggle Stickers Sales in Sweden (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# **<p id='28'><li>Sweden Kaggle Rama Stickers</li></p>**

# %%
totals = allSwedenKaggleRamaKaggleStickerData['Total']
fig = go.Figure(layout=layout)

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleStickerData['2018'],
    x=allSwedenKaggleRamaKaggleStickerData['Sweden Kaggle Rama: Stickers'],
    name='2018',
    text = allSwedenKaggleRamaKaggleStickerData['2018'],
    textposition='auto',
    marker=dict(
        color='rgb(46, 82, 102)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleStickerData['2017'],
    x=allSwedenKaggleRamaKaggleStickerData['Sweden Kaggle Rama: Stickers'],
    name='2017',
    text = allSwedenKaggleRamaKaggleStickerData['2017'],
    textposition='auto',
    marker=dict(
        color='rgb(110, 136, 152)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleStickerData['2016'],
    x=allSwedenKaggleRamaKaggleStickerData['Sweden Kaggle Rama: Stickers'],
    name='2016',
    text = allSwedenKaggleRamaKaggleStickerData['2016'],
    textposition='auto',
    marker=dict(
        color='rgb(159, 177, 188)',
        line=dict(color='black')
    )
))

fig.add_trace(go.Bar(
    y=allSwedenKaggleRamaKaggleStickerData['2015'],
    x=allSwedenKaggleRamaKaggleStickerData['Sweden Kaggle Rama: Stickers'],
    name='2015',
    text = allSwedenKaggleRamaKaggleStickerData['2015'],
    textposition='auto',
    marker=dict(
        color='rgb(211, 208, 203)',
        line=dict(color='black')
    )
))


total_labels = [{"x": x, "y": total*1.05, "text": str(total), "showarrow": False} for x, total in zip(allSwedenKaggleRamaKaggleStickerData['Sweden Kaggle Rama: Stickers'], totals)]
template = dict(layout=go.Layout(title_font=dict(family="Rockwell", size=30)))

fig.update_layout(
    title = 'Sweden: Kaggle Rama  (Stickers)<br><sup>Kaggle Stickers Sales in Sweden (2015 - 2018)</sup>',
    template = template,
    annotations=total_labels,
    barmode='stack', 
    autosize=False,
    width=980,
    height=700,
    margin=dict(
    l=50,
    r=50,
    b=100,
    t=100,
    pad=4
    ),
    paper_bgcolor="rgba(246,245,245,1)",
    yaxis=dict(title="Sales",
               titlefont=dict(color="black"),
               tickfont=dict(color="black")
              )
)

fig.layout.xaxis.tickformat = ',.0%'
fig.show()

# %% [markdown]
# <a id="29"></a> <br>
# # Statistical Testing
#
# **<p id='29'><li>Data Wrangling</li></p>**

# %%
finlandKMHat = allFinlandKaggleMartKaggleHatData.drop(columns=['Finland Kaggle Mart: Hats'])
finlandKMMug = allFinlandKaggleMartKaggleMugData.drop(columns=['Finland Kaggle Mart: Mugs'])
finlandKMSticker = allFinlandKaggleMartKaggleStickerData.drop(columns=['Finland Kaggle Mart: Stickers'])

finlandKRHat = allFinlandKaggleRamaKaggleHatData.drop(columns=['Finland Kaggle Rama: Hats'])
finlandKRMug = allFinlandKaggleRamaKaggleMugData.drop(columns=['Finland Kaggle Rama: Mugs'])
finlandKRSticer = allFinlandKaggleRamaKaggleStickerData.drop(columns=['Finland Kaggle Rama: Stickers'])

###################################################################################################################################################


norwayKMHat = allNorwayKaggleMartKaggleHatData.drop(columns=['Norway Kaggle Mart: Hats'])
norwayKMMug = allNorwayKaggleMartKaggleMugData.drop(columns=['Norway Kaggle Mart: Mugs'])
norwayKMSticker = allNorwayKaggleMartKaggleStickerData.drop(columns=['Norway Kaggle Mart: Stickers'])

norwayKRHat = allNorwayKaggleRamaKaggleHatData.drop(columns=['Norway Kaggle Rama: Hats'])
norwayKRMug = allNorwayKaggleRamaKaggleMugData.drop(columns=['Norway Kaggle Rama: Mugs'])
norwayKRSticer = allNorwayKaggleRamaKaggleStickerData.drop(columns=['Norway Kaggle Rama: Stickers'])


###################################################################################################################################################


swedenKMHat = allSwedenKaggleMartKaggleHatData.drop(columns=['Sweden Kaggle Mart: Hats'])
swedenKMMug = allSwedenKaggleMartKaggleMugData.drop(columns=['Sweden Kaggle Mart: Mugs'])
swedenKMSticker = allSwedenKaggleMartKaggleStickerData.drop(columns=['Sweden Kaggle Mart: Stickers'])

swedenKRHat = allSwedenKaggleRamaKaggleHatData.drop(columns=['Sweden Kaggle Rama: Hats'])
swedenKRMug = allSwedenKaggleRamaKaggleMugData.drop(columns=['Sweden Kaggle Rama: Mugs'])
swedenKRSticer = allSwedenKaggleRamaKaggleStickerData.drop(columns=['Sweden Kaggle Rama: Stickers'])

###################################################################################################################################################


framesFinland = [
    finlandKMHat,
    finlandKMMug,
    finlandKMSticker,
    finlandKRHat,
    finlandKRMug,
    swedenKRSticer
]



framesNorway = [
    norwayKMHat,
    norwayKMMug,
    norwayKMSticker,
    norwayKRHat,
    norwayKRMug,
    norwayKRSticer
]


framesSweden = [
    swedenKMHat,
    swedenKMMug,
    swedenKMSticker,
    swedenKRHat,
    swedenKRMug,
    swedenKRSticer
]


###################################################################################################################################################


resultFinland = pd.concat(framesFinland,ignore_index=True)

resultNorway = pd.concat(framesNorway,ignore_index=True)

resultSweden = pd.concat(framesSweden,ignore_index=True)

store_list = ['Kaggle Mart','Kaggle Rama']

              
###################################################################################################################################################


KaggeleMartFinland = resultFinland [resultFinland ['Store'].isin(store_list)].query("Store_Id == 0")[['2015','2016','2017','2018']].mean().reset_index()
KggleRamaFinland  = resultFinland [resultFinland ['Store'].isin(store_list)].query("Store_Id == 1")[['2015','2016','2017','2018']].mean().reset_index()


KaggeleMartNorway = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 0")[['2015','2016','2017','2018']].mean().reset_index()
KggleRamaNorway = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 1")[['2015','2016','2017','2018']].mean().reset_index()


KaggeleMartSweden = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 0")[['2015','2016','2017','2018']].mean().reset_index()
KggleRamaSweden = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 1")[['2015','2016','2017','2018']].mean().reset_index()
              
              
###################################################################################################################################################


radarFinland = pd.merge(KggleRamaFinland, KaggeleMartFinland, on='index')
radarFinland.columns = ['Year','Finland: Kggle Rama', 'Finland: Kggle Mart']
radarFinland = radarFinland.set_index('Year').T.reset_index()
radarFinland = radarFinland[['index','2015','2016','2017','2018']]


radarNorway = pd.merge(KggleRamaNorway, KaggeleMartNorway, on='index')
radarNorway.columns = ['Year','Norway: Kggle Rama', 'Norway: Kggle Mart']
radarNorway = radarNorway.set_index('Year').T.reset_index()
radarNorway = radarNorway[['index','2015','2016','2017','2018']]


radarSweden = pd.merge(KggleRamaSweden, KaggeleMartSweden, on='index')
radarSweden.columns = ['Year','Sweden: Kggle Rama', 'Sweden: Kggle Mart']
radarSweden = radarSweden.set_index('Year').T.reset_index()
radarSweden = radarSweden[['index','2015','2016','2017','2018']] 



resultFinland['Total_Products_NaturalLog'] = np.log(resultFinland['Total'])
resultNorway['Total_Products_NaturalLog'] = np.log(resultNorway['Total'])
resultSweden['Total_Products_NaturalLog'] = np.log(resultSweden['Total'])



finland_KM_samples = resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].count()
finland_KR_samples = resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].count()

finland_KM_mean = resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].mean()
finland_KR_mean = resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].mean()

finland_KM_std = resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].std()
finland_KR_std = resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].std()


              
###################################################################################################################################################



norway_KM_samples = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].count()
norway_KR_samples = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].count()

norway_KM_mean = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].mean()
norway_KR_mean = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].mean()

norway_KM_std = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].std()
norway_KR_std = resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].std()




sweden_KM_samples = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].count()
sweden_KR_samples = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].count()

sweden_KM_mean = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].mean()
sweden_KR_mean = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].mean()

sweden_KM_std = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'].std()
sweden_KR_std = resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'].std()

# %% [markdown]
# <a id="30"></a> <br>
# # Finland Statistical Testing
#
# **<p id='30'><li>Is Difference Significant for Product Sales in Finland for Both Stores</li></p>**

# %%
plt.rcParams['figure.dpi'] = 150
background_color='#f6f5f5'
Comparison = radarFinland["index"].values.tolist()

years = ['2015','2016','2017','2018']
length = len(years)

colors = ["#FC766AFF", "#5B84B1FF"]

# The angles at which the values of the numeric variables are placed
ANGLES = [n / length * 2.3 * np.pi for n in range(length)]
ANGLES += ANGLES[:1]
 

# Plot
fig = plt.figure(figsize=(10, 5), facecolor=background_color)
ax = fig.add_subplot(1,1,1, polar=True)
ax.set_facecolor(background_color)
 
# rotate plot
ax.set_theta_offset(np.pi)
ax.set_theta_direction(-1)

# Radius of plot
ax.set_ylim(-0.1, radarFinland[['2015','2016','2017','2018']].max().max()+5)

# Radar
for idx, store in enumerate(Comparison):
    values = radarFinland.iloc[idx].drop("index").values.tolist()
    values += values[:1]
    ax.plot(ANGLES, values, c=colors[idx], linewidth=1.5, label=store)
    ax.scatter(ANGLES, values, s=150, c=colors[idx],ec='white',zorder=10)

# Tidy up & labels
ax.set_xticks(ANGLES[:-1])
ax.set_xticklabels(years, size=10, color='#323232')
ax.set_yticks([])
ax.yaxis.grid(False)
ax.xaxis.grid(False)
ax.spines["start"].set_color("none")
ax.spines["polar"].set_color("none")

# Title
fig.text(0,0.98, 'Average Kaggle Products Sales:\nIs this difference significant?', fontsize=15,fontweight='bold',color='#323232')
fig.text(0,0.93, '\nFinland: Kaggle Rama', fontsize=10,fontweight='bold',color='#FC766AFF')
fig.text(0,0.89, 'Finland: Kaggle Mart', fontsize=10,fontweight='bold',color='#5B84B1FF')

plt.show()

# %% [markdown]
# **What does this show ?**
#
# **Finland's Kaggle stores avaerage product sales (2015-2018).**
#
#    * It is obvious that Kaggle Rama has the better result, **but we must do statistical tests to be certain**.

# %% [markdown]
# **<p id='31'><li>Overall Distribution of All Products in Finland: Positively Skewed</li></p>**

# %%
fig = plt.figure(figsize=(18,10), facecolor=background_color)

colors = ['#0063B2FF', '#ADEFD1FF', '#949398FF', '#D85A7FFF','#EEA47FFF']

num = 0
variables = ['2015','2016','2017','2018', 'Total']

plots = [(0,0), (0,1), (0,2), (1,0), (1,1)]

data = resultFinland

for item in variables:
    
    if plots[num] == plots[-1]:
        colspan=3
    else: 
        colspan=1
        
    plt.subplot2grid((2,3), (plots[num]), colspan=colspan)
    
    ax = sns.kdeplot(data=data, x=item,color=colors[num],shade=True,  alpha=0.9, ec='black', cut=5)
    ax.set_facecolor(background_color)
    ax.tick_params(axis='y', left=False)
    ax.get_yaxis().set_visible(False)
    ax.set_axisbelow(True)
    ax.set_xlabel(item)
    ax.grid(which='major', axis='x', zorder=5, color='black', linestyle=':', dashes=(1,5))
    for s in ["top","right","left"]:
        ax.spines[s].set_visible(False)
    
    plt.xticks(list(np.arange(0,data[item].max()+10000,10000)))
        
    num +=1 
    
Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

fig.text(0.03,1.05, 'Overall Distribution of Kaggle Products Sold in Finland: Positively Skewed', fontsize=25,fontweight='bold',color='#323232')

    
plt.tight_layout()
plt.show()

# %% [markdown]
# **What does this show?**
#
# **We note that the years sales are not distributed normally.**
#
# * They are positively skewed.
# * To mitigate against this, we will take the natural log of the total sales (2015 - 2016).

# %%
print("\033[1mFinland: Mean Natural Log of Total Products in Kaghle Mart:\033[0m",finland_KM_mean)
print("\033[1mFinland: Mean Natural Log of Total Products in Kaghle Rama:\033[0m",finland_KR_mean,"\n")
finland_KM_std = finland_KM_std/np.sqrt(finland_KM_samples)
print("\033[1mStandard Error of Natural Log: Finland Total Products in Kaggle Mart:\033[0m",finland_KM_std)
finland_KR_std = finland_KR_std/np.sqrt(finland_KR_samples)
print("\033[1mStandard Error of Natural Log: Finland Total Products in Kaggle Rama:\033[0m",sweden_KR_std)
print('\n\033[1mIs this difference enough to declare that the two means are from different distributions?\033[0m')

topF = (finland_KR_mean-finland_KM_mean)
bott1F = finland_KM_std**2/finland_KM_samples
bott2F = finland_KR_std**2/finland_KR_samples
print("\n\033[1mFinland: Standard Errors between means\033[0m")
print(topF/(np.sqrt(bott1F + bott2F)))

print('\n\033[1mThis means that it is incredibly unlikely that the two means are from the same populations\033[0m')

# %% [markdown]
# **<p id='32'><li>Comparing Means among Stores in Finland</li></p>**

# %%
fig, ax = plt.subplots(1,1, figsize=(18,6), facecolor=background_color)
ax.set_facecolor(background_color)
sns.kdeplot(data=resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 1"), x='Total_Products_NaturalLog',shade=True,color='#FC766AFF',alpha=0.9, ax=ax)
sns.kdeplot(data=resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 0"), x='Total_Products_NaturalLog', shade=True, color='#5B84B1FF',alpha=0.7, ax=ax)

ax.axvline(color='black',x=finland_KM_mean+(4*sweden_KM_std))
ax.axvline(color='black',x=finland_KM_mean-(4*sweden_KM_std))
ax.axvspan(finland_KM_mean-(4*finland_KM_std), finland_KM_mean+(4*finland_KM_std), alpha=0.3, color='#5B84B1FF')

ax.axvline(color='black',x=finland_KR_mean+(4*finland_KR_std))
ax.axvline(color='black',x=finland_KR_mean-(4*finland_KR_std))
ax.axvspan(finland_KR_mean-(4*finland_KR_std), finland_KR_mean+(4*finland_KR_std), alpha=0.3, color='#FC766AFF')

for s in ['top','left', 'bottom', 'right']:
    ax.spines[s].set_visible(False)
    
ax.set_xlabel("Natural Log of Total Products",loc='left',color='black')
ax.get_yaxis().set_visible(False)
ax.tick_params(axis = 'both', which = 'major', labelsize = 10)

ax.tick_params(axis='both', which='both',left=False, bottom=False,labelbottom=True) 


Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.text(Xstart,Yend, 'Comparing Means of Products Sales', fontsize=18,fontweight='bold',color='#323232')
ax.text(Xstart,Yend-0.05, 'Finland Kaggle Stores', fontsize=18,fontweight='bold',color='#323232')
ax.text(Xstart,Yend-0.1, 'Kaggle Rama', fontsize=15,fontweight='bold',color='#FC766AFF')
ax.text(Xstart,Yend-0.14, 'Kaggle Mart', fontsize=15,fontweight='bold',color='#5B84B1FF')
plt.show()

# %% [markdown]
# **What does this show?**
#
# **Above I have plotted the distributions of the natural log of the mean total products sales of two stores at Finland**
#
# * The Blue & Pink boxes reprsent 4 standard errors above & below the mean values.
# * We note that these areas do not overlap. So we can not say that Kaggle Rama should be official Retailer at Finland.

# %% [markdown]
# **<p id='69'><li>Finland T-Test Results</li></p>**

# %%
print("\033[1;31;43m Finland T-Test \033[0m")
# compare samples
stat, p = ttest_ind(resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'], resultFinland[resultFinland['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'])
print('\033[1mStatistics =\033[0m %.3f, \033[1mp =\033[0m %.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('\033[1mSame distributions \033[0m(fail to reject H0)')
else:
    print('\033[1mDifferent distributions \033[0m(reject H0)')

# %% [markdown]
# Based on the tests above, it appears that **we can reject the null hypothesis:**
#
# * Kaggle Ramma performance can not be said it is better than Kaggle Mart at Finaland.

# %% [markdown]
# <a id="33"></a> <br>
# # Norway Statistical Testing
#
# **<p id='33'><li>Is Difference Significant for Product Sales in Norway for Both Stores</li></p>**

# %%
plt.rcParams['figure.dpi'] = 150
background_color='#f6f5f5'
Comparison = radarNorway["index"].values.tolist()

years = ['2015','2016','2017','2018']
length = len(years)

colors = ["#DAA03DFF", "#616247FF"]

# The angles at which the values of the numeric variables are placed
ANGLES = [n / length * 2.3 * np.pi for n in range(length)]
ANGLES += ANGLES[:1]
 

# Plot
fig = plt.figure(figsize=(10, 5), facecolor=background_color)
ax = fig.add_subplot(1,1,1, polar=True)
ax.set_facecolor(background_color)
 
# rotate plot
ax.set_theta_offset(np.pi)
ax.set_theta_direction(-1)

# Radius of plot
ax.set_ylim(-0.1, radarNorway[['2015','2016','2017','2018']].max().max()+5)

# Radar
for idx, store in enumerate(Comparison):
    values = radarNorway.iloc[idx].drop("index").values.tolist()
    values += values[:1]
    ax.plot(ANGLES, values, c=colors[idx], linewidth=1.5, label=store)
    ax.scatter(ANGLES, values, s=150, c=colors[idx],ec='white',zorder=10)

# Tidy up & labels
ax.set_xticks(ANGLES[:-1])
ax.set_xticklabels(years, size=10, color='#323232')
ax.set_yticks([])
ax.yaxis.grid(False)
ax.xaxis.grid(False)
ax.spines["start"].set_color("none")
ax.spines["polar"].set_color("none")

# Title
fig.text(0,0.98, 'Average Kaggle Products Sales:\nIs this difference significant?', fontsize=15,fontweight='bold',color='#323232')
fig.text(0,0.93, '\nNorway: Kaggle Rama', fontsize=10,fontweight='bold',color='#DAA03DFF')
fig.text(0,0.89, 'Norway: Kaggle Mart', fontsize=10,fontweight='bold',color='#616247FF')

plt.show()

# %% [markdown]
# **What does this show ?**
#
# **Norway's Kaggle stores avaerage product sales (2015-2018).**
#
#    * It is obvious that Kaggle Rama has the better result, **but we must do statistical tests to be certain**.

# %% [markdown]
# **<p id='34'><li>Overall Distribution of All Products in Norway: Positively Skewed</li></p>**

# %%
fig = plt.figure(figsize=(18,10), facecolor=background_color)

colors = ['#F4DF4EFF', '#5F4B8BFF', '#E69A8DFF', '#97BC62FF','#FAEBEFFF']

num = 0
variables = ['2015','2016','2017','2018', 'Total']

plots = [(0,0), (0,1), (0,2), (1,0), (1,1)]

data = resultNorway

for item in variables:
    
    if plots[num] == plots[-1]:
        colspan=3
    else: 
        colspan=1
        
    plt.subplot2grid((2,3), (plots[num]), colspan=colspan)
    
    ax = sns.kdeplot(data=data, x=item,color=colors[num],shade=True,  alpha=0.9, ec='black', cut=5)
    ax.set_facecolor(background_color)
    ax.tick_params(axis='y', left=False)
    ax.get_yaxis().set_visible(False)
    ax.set_axisbelow(True)
    ax.set_xlabel(item)
    ax.grid(which='major', axis='x', zorder=5, color='black', linestyle=':', dashes=(1,5))
    for s in ["top","right","left"]:
        ax.spines[s].set_visible(False)
    
    plt.xticks(list(np.arange(0,data[item].max()+20000,20000)))
        
    num +=1 
    
Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

fig.text(0.03,1.05, 'Overall Distribution of Kaggle Products Sold in Norway: Positively Skewed', fontsize=25,fontweight='bold',color='#323232')

    
plt.tight_layout()
plt.show()

# %% [markdown]
# **What does this show?**
#
# **We note that the years sales are not distributed normally.**
#
# * They are positively skewed.
# * To mitigate against this, we will take the natural log of the total sales (2015 - 2016).

# %%
print("\033[1mNorway: Mean Natural Log of Total Products in Kaghle Mart:\033[0m",norway_KM_mean)
print("\033[1mNorway: Mean Natural Log of Total Products in Kaghle Rama:\033[0m",norway_KR_mean,"\n")
norway_KM_std = norway_KM_std/np.sqrt(norway_KM_samples)
print("\033[1mStandard Error of Natural Log: Norway Total Products in Kaggle Mart:\033[0m",norway_KM_std)
norway_KR_std = norway_KR_std/np.sqrt(norway_KR_samples)
print("\033[1mStandard Error of Natural Log: Norway Total Products in Kaggle Rama:\033[0m",norway_KR_std)
print('\n\033[1mIs this difference enough to declare that the two means are from different distributions?\033[0m')

topN = (norway_KR_mean-norway_KM_mean)
bott1N = norway_KM_std**2/norway_KM_samples
bott2N = norway_KR_std**2/norway_KR_samples
print("\n\033[1mNorway: Standard Errors between means\033[0m")
print(topN/(np.sqrt(bott1N + bott2N)))

print('\n\033[1mThis means that it is incredibly unlikely that the two means are from the same populations\033[0m')

# %% [markdown]
# **<p id='35'><li>Comparing Means among Stores in Norway</li></p>**

# %%
fig, ax = plt.subplots(1,1, figsize=(18,6), facecolor=background_color)
ax.set_facecolor(background_color)
sns.kdeplot(data=resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 1"), x='Total_Products_NaturalLog',shade=True,color='#DAA03DFF',alpha=0.9, ax=ax)
sns.kdeplot(data=resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 0"), x='Total_Products_NaturalLog', shade=True, color='#616247FF',alpha=0.7, ax=ax)

ax.axvline(color='black',x=norway_KM_mean+(4*norway_KM_std))
ax.axvline(color='black',x=norway_KM_mean-(4*norway_KM_std))
ax.axvspan(norway_KM_mean-(4*norway_KM_std), norway_KM_mean+(4*norway_KM_std), alpha=0.3, color='#616247FF')

ax.axvline(color='black',x=norway_KR_mean+(4*norway_KR_std))
ax.axvline(color='black',x=norway_KR_mean-(4*norway_KR_std))
ax.axvspan(norway_KR_mean-(4*norway_KR_std), norway_KR_mean+(4*norway_KR_std), alpha=0.3, color='#DAA03DFF')

for s in ['top','left', 'bottom', 'right']:
    ax.spines[s].set_visible(False)
    
ax.set_xlabel("Natural Log of Total Products",loc='left',color='black')
ax.get_yaxis().set_visible(False)
ax.tick_params(axis = 'both', which = 'major', labelsize = 10)

ax.tick_params(axis='both', which='both',left=False, bottom=False,labelbottom=True) 


Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.text(Xstart,Yend, 'Comparing Means of Products Sales', fontsize=20,fontweight='bold',color='#323232')
ax.text(Xstart,Yend-0.05, 'Norway Kaggle Stores', fontsize=18,fontweight='bold',color='#323232')
ax.text(Xstart,Yend-0.1, 'Kaggle Rama', fontsize=15,fontweight='bold',color='#DAA03DFF')
ax.text(Xstart,Yend-0.14, 'Kaggle Mart', fontsize=15,fontweight='bold',color='#616247FF')
plt.show()

# %% [markdown]
# **What does this show?**
#
# **Above I have plotted the distributions of the natural log of the mean total products sales of two stores at Norway**
#
# * The Olive & Gold boxes reprsent 4 standard errors above & below the mean values.
# * We note that these areas do not overlap. So we can not say that Kaggle Rama should be official Retailer at Norway.

# %% [markdown]
# **<p id='70'><li>Norway T-Test</li></p>**

# %%
print("\033[1;31;43m Norway T-Test \033[0m")
# compare samples
stat, p = ttest_ind(resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'], resultNorway[resultNorway['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'])
print('\033[1mStatistics =\033[0m %.3f, \033[1mp =\033[0m %.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('\033[1mSame distributions \033[0m(fail to reject H0)')
else:
    print('\033[1mDifferent distributions \033[0m(reject H0)')

# %% [markdown]
# Based on the tests above, it appears that **we can reject the null hypothesis:**
#
# * Kaggle Ramma performance can not be said it is better than Kaggle Mart at Norway.

# %% [markdown]
# <a id="36"></a> <br>
# # Sweden Statistical Testing
#
# **<p id='36'><li>Is Difference Significant for Product Sales in Sweden for Both Stores</li></p>**

# %%
plt.rcParams['figure.dpi'] = 150
background_color='#f6f5f5'
Comparison = radarSweden["index"].values.tolist()

years = ['2015','2016','2017','2018']
length = len(years)

colors = ["#DF6589FF", "#3C1053FF"]

# The angles at which the values of the numeric variables are placed
ANGLES = [n / length * 2.3 * np.pi for n in range(length)]
ANGLES += ANGLES[:1]
 

# Plot
fig = plt.figure(figsize=(10, 5), facecolor=background_color)
ax = fig.add_subplot(1,1,1, polar=True)
ax.set_facecolor(background_color)
 
# rotate plot
ax.set_theta_offset(np.pi)
ax.set_theta_direction(-1)

# Radius of plot
ax.set_ylim(-0.1, radarSweden[['2015','2016','2017','2018']].max().max()+5)

# Radar
for idx, store in enumerate(Comparison):
    values = radarSweden.iloc[idx].drop("index").values.tolist()
    values += values[:1]
    ax.plot(ANGLES, values, c=colors[idx], linewidth=1.5, label=store)
    ax.scatter(ANGLES, values, s=150, c=colors[idx],ec='white',zorder=10)

# Tidy up & labels
ax.set_xticks(ANGLES[:-1])
ax.set_xticklabels(years, size=10, color='#323232')
ax.set_yticks([])
ax.yaxis.grid(False)
ax.xaxis.grid(False)
ax.spines["start"].set_color("none")
ax.spines["polar"].set_color("none")

# Title
fig.text(0,0.98, 'Average Kaggle Products Sales:\nIs this difference significant?', fontsize=15,fontweight='bold',color='#323232')
fig.text(0,0.93, '\nSweden: Kaggle Rama', fontsize=10,fontweight='bold',color='#DF6589FF')
fig.text(0,0.89, 'Sweden: Kaggle Mart', fontsize=10,fontweight='bold',color='#3C1053FF')

plt.show()

# %% [markdown]
# **What does this show ?**
#
# **Sweden's Kaggle stores avaerage product sales (2015-2018).**
#
#    * It is obvious that Kaggle Rama has the better result, **but we must do statistical tests to be certain**.

# %% [markdown]
# **<p id='37'><li>Overall Distribution of All Products in Sweden: Positively Skewed</li></p>**

# %%
fig = plt.figure(figsize=(18,10), facecolor=background_color)

colors = ['#FFBE7BFF', '#8BBEE8FF', '#E3C9CEFF', '#D7A9E3FF','#A8D5BAFF']

num = 0
variables = ['2015','2016','2017','2018', 'Total']

plots = [(0,0), (0,1), (0,2), (1,0), (1,1)]

data = resultSweden

for item in variables:
    
    if plots[num] == plots[-1]:
        colspan=3
    else: 
        colspan=1
        
    plt.subplot2grid((2,3), (plots[num]), colspan=colspan)
    
    ax = sns.kdeplot(data=data, x=item,color=colors[num],shade=True,  alpha=0.9, ec='black', cut=5)
    ax.set_facecolor(background_color)
    ax.tick_params(axis='y', left=False)
    ax.get_yaxis().set_visible(False)
    ax.set_axisbelow(True)
    ax.set_xlabel(item)
    ax.grid(which='major', axis='x', zorder=5, color='black', linestyle=':', dashes=(1,5))
    for s in ["top","right","left"]:
        ax.spines[s].set_visible(False)
    
    plt.xticks(list(np.arange(0,data[item].max()+10000,10000)))
        
    num +=1 
    
Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

fig.text(0.03,1.05, 'Overall Distribution of Kaggle Products Sold in Sweden: Positively Skewed', fontsize=25,fontweight='bold',color='#323232')

    
plt.tight_layout()
plt.show()

# %% [markdown]
# **What does this show?**
#
# **We note that the years sales are not distributed normally.**
#
# * They are positively skewed.
# * To mitigate against this, we will take the natural log of the total sales (2015 - 2016).

# %%
print("\033[1mSweden: Mean Natural Log of Total Products in Kaghle Mart:\033[0m",sweden_KM_mean)
print("\033[1mSweden: Mean Natural Log of Total Products in Kaghle Mart:\033[0m",sweden_KR_mean,"\n")
sweden_KM_std = sweden_KM_std/np.sqrt(sweden_KM_samples)
print("\033[1mStandard Error of Natural Log of Total Products for Kaggle Mart:\033[0m",sweden_KM_std)
sweden_KR_std = sweden_KR_std/np.sqrt(sweden_KR_samples)
print("\033[1mStandard Error of Natural Log of Total Products for Kaggle Rama:\033[0m",sweden_KR_std)
print('\n\033[1mIs this difference enough to declare that the two means are from different distributions?\033[0m')

topS = (sweden_KR_mean-sweden_KM_mean)
bott1S = sweden_KM_std**2/sweden_KM_samples
bott2S = sweden_KR_std**2/sweden_KR_samples
print("\n\033[1mSweden: Standard Errors between means\033[0m")
print(topS/(np.sqrt(bott1S + bott2S)))

print('\n\033[1mThis means that it is incredibly unlikely that the two means are from the same populations\033[0m')

# %% [markdown]
# **<p id='38'><li>Comparing Means among Stores in Sweden</li></p>**

# %%
fig, ax = plt.subplots(1,1, figsize=(18,6), facecolor=background_color)
ax.set_facecolor(background_color)
sns.kdeplot(data=resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 1"), x='Total_Products_NaturalLog',shade=True,color='#DF6589FF',alpha=0.9, ax=ax)
sns.kdeplot(data=resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 0"), x='Total_Products_NaturalLog', shade=True, color='#3C1053FF',alpha=0.7, ax=ax)

ax.axvline(color='black',x=sweden_KM_mean+(4*sweden_KM_std))
ax.axvline(color='black',x=sweden_KM_mean-(4*sweden_KM_std))
ax.axvspan(sweden_KM_mean-(4*sweden_KM_std), sweden_KM_mean+(4*sweden_KM_std), alpha=0.3, color='#3C1053FF')

#ax.axvline(x=Not_hosting_mean)

#ax.axvline(x=hosting_mean)
ax.axvline(color='black',x=sweden_KR_mean+(4*sweden_KR_std))
ax.axvline(color='black',x=sweden_KR_mean-(4*sweden_KR_std))
ax.axvspan(sweden_KR_mean-(4*sweden_KR_std), sweden_KR_mean+(4*sweden_KR_std), alpha=0.3, color='#DF6589FF')

for s in ['top','left', 'bottom', 'right']:
    ax.spines[s].set_visible(False)
    
ax.set_xlabel("Natural Log of Total Products",loc='left',color='black')
ax.get_yaxis().set_visible(False)
ax.tick_params(axis = 'both', which = 'major', labelsize = 10)

ax.tick_params(axis='both', which='both',left=False, bottom=False,labelbottom=True) 


Xstart, Xend = ax.get_xlim()
Ystart, Yend = ax.get_ylim()

ax.text(Xstart,Yend, 'Comparing Means of Products Sales', fontsize=20,fontweight='bold',color='#323232')
ax.text(Xstart,Yend-0.05, 'Sweden Kaggle Sotes', fontsize=18,fontweight='bold',color='#323232')
ax.text(Xstart,Yend-0.1, 'Kaggle Rama', fontsize=15,fontweight='bold',color='#DF6589FF')
ax.text(Xstart,Yend-0.14, 'Kaggle Mart', fontsize=15,fontweight='bold',color='#3C1053FF')
plt.show()

# %% [markdown]
# **What does this show?**
#
# **Above I have plotted the distributions of the natural log of the mean total products sales of two stores at Sweden**
#
# * The Purple & Pink boxes reprsent 4 standard errors above & below the mean values.
# * We note that these areas do not overlap. So we can not say that Kaggle Rama should be official Retailer at Sweden.

# %% [markdown]
# **<p id='71'><li>Sweden T-Test</li></p>**

# %%
print("\033[1;31;43m Sweden T-Test \033[0m")
# compare samples
stat, p = ttest_ind(resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 0")['Total_Products_NaturalLog'], resultSweden[resultSweden['Store'].isin(store_list)].query("Store_Id == 1")['Total_Products_NaturalLog'])
print('\033[1mStatistics =\033[0m %.3f, \033[1mp =\033[0m %.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('\033[1mSame distributions \033[0m(fail to reject H0)')
else:
    print('\033[1mDifferent distributions \033[0m(reject H0)')

# %% [markdown]
# Based on the tests above, it appears that **we can reject the null hypothesis:**
#
# * Kaggle Ramma performance can not be said it is better than Kaggle Mart at Sweden.

# %% [markdown]
# **<p id='39'><li>Dataset Features</li></p>**

# %%
target = 'num_sold'
features = [i for i in trainData.columns if i not in [target]]

trainDataFinalCopy = trainData.copy(deep=True)

#Checking number of unique rows in each feature

nu = trainData[features].nunique().sort_values()
nf = []; cf = []; nnf = 0; ncf = 0; #numerical & categorical features

for i in range(trainData[features].shape[1]):
    if nu.values[i]<=16:cf.append(nu.index[i])
    else: nf.append(nu.index[i])

print('\n\033[1mInference:\033[0m The Datset has \033[1m{}\033[0m numerical & \033[1m{}\033[0m categorical features.'.format(len(nf),len(cf)))

# %% [markdown]
# **<p id='40'><li>Basic Stats</li></p>**

# %%
display(trainData.describe())
print("\033[1mInference:\033[0m  The stats seem to be fine, let us do further analysis on the Dataset")

# %% [markdown]
# <a id="41"></a> <br>
# # Exploratory Data Analysis (EDA)
#
# **<p id='41'><li>Target Variable Distribution - Median Values</li></p>**

# %%
sns.distplot(trainData[target], color='#ADEFD1FF',kde_kws={"color": "k", "lw": 2, "label": "KDE"},hist_kws=dict(edgecolor="black", linewidth=2), bins=30)
plt.title('Target Variable Distribution - Median Value Sold')
plt.show()

# %% [markdown]
# **<p id='42'><li>Categorical features in the dataset</li></p>**

# %%
n=1
plt.figure(figsize=[16,6*math.ceil(len(cf)/n)])

for i in range(len(cf)):
    if trainData[cf[i]].nunique()<=17:
        plt.subplot(math.ceil(len(cf)/n),n,i+1)
        sns.countplot(trainData[cf[i]])
    else:
        plt.subplot(3,1,i-3)
        sns.countplot(trainData[cf[i]])
        
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="44"></a> <br>
# # Data Preprocessing
#
# **<p id='44'><li>Remove Duplicates</li></p>**

# %%
#Removal of any Duplicate rows (if any)

counter = 0
rs,cs = trainDataFinalCopy.shape

trainDataFinalCopy.drop_duplicates(inplace=True)

if trainDataFinalCopy.shape==(rs,cs):
    print('\n\033[1mInference:\033[0m The dataset doesn\'t have any duplicates')
else:
    print(f'\n\033[1mInference:\033[0m Number of duplicates dropped/fixed ---> {rs-df.shape[0]}')

# %% [markdown]
# **<p id='45'><li>Check Inconsistant Values</li></p>**

# %%
#Check for empty elements

nvc = pd.DataFrame(trainData.isnull().sum().sort_values(), columns=['Total Null Values'])
nvc['Percentage'] = round(nvc['Total Null Values']/trainData.shape[0],3)*100
print(nvc)

print("\n\033[1mInference:\033[0m The datset doesn't have any inconsistant values.")

# %%
#Dummies the 'country', 'store', 'product'
trainDataDummy = pd.get_dummies(trainData[['country', 'store', 'product']])
testDataDummy = pd.get_dummies(testData[['country', 'store', 'product']])

trainData = pd.concat([trainData, trainDataDummy],axis = 1)
testData = pd.concat([testData, testDataDummy],axis = 1)

trainData = trainData.drop(columns = ['country', 'store', 'product'])
testData = testData.drop(columns = ['country', 'store', 'product'])

# %% [markdown]
# <a id="46"></a> <br>
# # Data Manipulation
#
# **<p id='46'><li>Spliting Dataset</li></p>**

# %%
X = trainData.drop(target,axis=1)
X.rename(columns={'product_Kaggle Hat': 'product_Kaggle_Hat', 'product_Kaggle Mug': 'product_Kaggle_Mug', 'product_Kaggle Sticker': 'product_Kaggle_Sticker'}, inplace=True)
Y = trainData[target]
Y = np.log(Y)

std = StandardScaler()

#Splitting the data intro training & testing sets
Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y, train_size = 0.80,  test_size=0.20, random_state = 512)
Train_X.reset_index(drop=True,inplace=True)
print('Training set  ---> ',Train_X.shape,Train_Y.shape,'\nTesting set   ---> ', Test_X.shape,'', Test_Y.shape)

# %% [markdown]
# **<p id='47'><li>Standardization</li></p>**

# %%
print('\033[1mStandardardization on Training set'.center(120))
Train_X_std = std.fit_transform(Train_X)
Train_X_std = pd.DataFrame(Train_X_std,columns=X.columns)
display(Train_X_std.describe())

print('\n\n','\033[1mStandardardization on Testing set'.center(120))
Test_X_std = std.transform(Test_X)
Test_X_std = pd.DataFrame(Test_X_std,columns=X.columns)
display(Test_X_std.describe())

# %% [markdown]
# <a id="48"></a> <br>
# # Feature Selection/Extraction
#
# **<p id='48'><li>Correlation</li></p>**

# %%
print('\033[1mCorrelation Matrix')
sns.heatmap(trainData.corr(), annot=True, vmin=-1, vmax=1, center=0,cmap='twilight_shifted')
plt.show()

# %% [markdown]
# **<p id='49'><li>OLS Regression</li></p>**

# %%
#Testing a Linear Regression model with statsmodels

Train_xy = pd.concat([Train_X_std,Train_Y.reset_index(drop=True)],axis=1)
Train_xy.rename(columns={'product_Kaggle Hat': 'product_Kaggle_Hat', 'product_Kaggle Mug': 'product_Kaggle_Mug', 'product_Kaggle Sticker': 'product_Kaggle_Sticker'}, inplace=True)
a = Train_xy.columns.values

API = api.ols(formula='{} ~ {}'.format(target,' + '.join(i for i in Train_X.columns)), data=Train_xy).fit()
API.summary()

# %% [markdown]
# <a id="50"></a> <br>
# # Approach: We can fix these multicollinearity with two techniques
#
# **<p id='50'><li>Manual Method - Variance Inflation Factor (VIF)</li></p>**

# %%
Trr=[]; Tss=[]; n=3
order=['ord-'+str(i) for i in range(2,n)]

DROP=[];b=[]

for i in range(len(Train_X_std.columns)):
    vif = pd.DataFrame()
    X = Train_X_std.drop(DROP,axis=1)
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    vif.reset_index(drop=True, inplace=True)
    if vif.loc[0][1]>1:
        DROP.append(vif.loc[0][0])
        LR = LinearRegression()
        LR.fit(Train_X_std.drop(DROP,axis=1), Train_Y)

        pred1 = LR.predict(Train_X_std.drop(DROP,axis=1))
        pred2 = LR.predict(Test_X_std.drop(DROP,axis=1))
        
        Trr.append(np.sqrt(mean_squared_error(Train_Y, pred1)))
        Tss.append(np.sqrt(mean_squared_error(Test_Y, pred2)))

        
print('Dropped Features --> ',DROP)

plt.plot(Trr, label='Train RMSE')
plt.plot(Tss, label='Test RMSE')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **<p id='51'><li>Automatic Method - Recursive Feature Elimination (RFE)</li></p>**

# %%
Trr=[]; Tss=[]; n=3
order=['ord-'+str(i) for i in range(2,n)]
Trd = pd.DataFrame(np.zeros((10,n-2)), columns=order)
Tsd = pd.DataFrame(np.zeros((10,n-2)), columns=order)

m=trainData.shape[1]-2
for i in range(m):
    lm = LinearRegression()
    #lm.fit(Train_X_std, Train_Y)

    rfe = RFE(lm,n_features_to_select=Train_X_std.shape[1]-i)   # running RFE
    rfe = rfe.fit(Train_X_std, Train_Y)

    LR = LinearRegression()
    LR.fit(Train_X_std.loc[:,rfe.support_], Train_Y)

    pred1 = LR.predict(Train_X_std.loc[:,rfe.support_])
    pred2 = LR.predict(Test_X_std.loc[:,rfe.support_])

    Trr.append(np.sqrt(mean_squared_error(Train_Y, pred1)))
    Tss.append(np.sqrt(mean_squared_error(Test_Y, pred2)))



plt.plot(Trr, label='Train RMSE')
plt.plot(Tss, label='Test RMSE')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **<p id='52'><li>Feature Elmination using PCA Decomposition</li></p>**

# %%
pca = PCA().fit(Train_X_std)

fig, ax = plt.subplots(figsize=(16,6))
x_values = range(1, pca.n_components_+1)
ax.bar(x_values, pca.explained_variance_ratio_, lw=2, label='Explained Variance')
ax.plot(x_values, np.cumsum(pca.explained_variance_ratio_), lw=2, label='Cumulative Explained Variance', color='red')
plt.plot([0,pca.n_components_+1],[0.9,0.9],'g--')
ax.set_title('Explained variance of components')
ax.set_xlabel('Principal Component')
ax.set_ylabel('Explained Variance')
plt.legend()
plt.grid()
plt.show()

# %%
Trr=[]; Tss=[]; n=3
order=['ord-'+str(i) for i in range(2,n)]
Trd = pd.DataFrame(np.zeros((10,n-2)), columns=order)
Tsd = pd.DataFrame(np.zeros((10,n-2)), columns=order)
m=trainData.shape[1]-1

for i in range(m):
    pca = PCA(n_components=Train_X_std.shape[1]-i)
    Train_X_std_pca = pca.fit_transform(Train_X_std)
    Test_X_std_pca = pca.fit_transform(Test_X_std)
    
    LR = LinearRegression()
    LR.fit(Train_X_std_pca, Train_Y)

    pred1 = LR.predict(Train_X_std_pca)
    pred2 = LR.predict(Test_X_std_pca)

    Trr.append(round(np.sqrt(mean_squared_error(Train_Y, pred1)),2))
    Tss.append(round(np.sqrt(mean_squared_error(Test_Y, pred2)),2))

plt.plot(Trr, label='Train RMSE')
plt.plot(Tss, label='Test RMSE')
plt.legend()
plt.grid()
plt.show()


print('\n\033[1mInference:\033[0m It can be seen that the performance of the modelsis quiet comparable unpon dropping features using VIF, RFE & PCA\
\nTechniques. Comparing the RMSE plots, the optimal values were found for dropping most features using manual RFE Technique.')

# %% [markdown]
# <a id="53"></a> <br>
# # Predictive Modelling
#
# **<p id='53'><li>Regression Model Helper Function</li></p>**

# %%
#Let us first define a function to evaluate our models
import tensorflow as tf
Model_Evaluation_Comparison_Matrix = pd.DataFrame(np.zeros([11,8]), columns=['Train-R2','Test-R2','Train-RSS','Test-RSS',
                                                                            'Train-MSE','Test-MSE','Train-RMSE','Test-RMSE'])
rc=np.random.choice(Train_X_std.columns,2)

def Evaluate(n, pred1,pred2):
    #Plotting predicted predicteds alongside the actual datapoints 
    for e,i in enumerate(rc):
        plt.figure(figsize=[16,6])
        plt.subplot(2,3,e+1)
        plt.scatter(y=Train_Y, x=Train_X_std[i], label='Actual')
        plt.scatter(y=pred1, x=Train_X_std[i], label='Prediction')
        plt.legend()
    plt.show()

    #Evaluating the Multiple Linear Regression Model

    print('\n\n{}Training Set Metrics{}'.format('-'*20, '-'*20))
    print('\nR2-Score on Training set --->',round(r2_score(Train_Y, pred1),20))
    print('Residual Sum of Squares (RSS) on Training set  --->',round(np.sum(np.square(Train_Y-pred1)),20))
    print('Mean Squared Error (MSE) on Training set       --->',round(mean_squared_error(Train_Y, pred1),20))
    print('Root Mean Squared Error (RMSE) on Training set --->',round(np.sqrt(mean_squared_error(Train_Y, pred1)),20))

    print('\n{}Testing Set Metrics{}'.format('-'*20, '-'*20))
    print('\nR2-Score on Testing set --->',round(r2_score(Test_Y, pred2),20))
    print('Residual Sum of Squares (RSS) on Training set  --->',round(np.sum(np.square(Test_Y-pred2)),20))
    print('Mean Squared Error (MSE) on Training set       --->',round(mean_squared_error(Test_Y, pred2),20))
    print('Root Mean Squared Error (RMSE) on Training set --->',round(np.sqrt(mean_squared_error(Test_Y, pred2)),20))
    print('\n{}Residual Plots{}'.format('-'*20, '-'*20))
    
    Model_Evaluation_Comparison_Matrix.loc[n,'Train-R2']  = round(r2_score(Train_Y, pred1),20)
    Model_Evaluation_Comparison_Matrix.loc[n,'Test-R2']   = round(r2_score(Test_Y, pred2),20)
    Model_Evaluation_Comparison_Matrix.loc[n,'Train-RSS'] = round(np.sum(np.square(Train_Y-pred1)),20)
    Model_Evaluation_Comparison_Matrix.loc[n,'Test-RSS']  = round(np.sum(np.square(Test_Y-pred2)),20)
    Model_Evaluation_Comparison_Matrix.loc[n,'Train-MSE'] = round(mean_squared_error(Train_Y, pred1),20)
    Model_Evaluation_Comparison_Matrix.loc[n,'Test-MSE']  = round(mean_squared_error(Test_Y, pred2),20)
    Model_Evaluation_Comparison_Matrix.loc[n,'Train-RMSE']= round(np.sqrt(mean_squared_error(Train_Y, pred1)),20)
    Model_Evaluation_Comparison_Matrix.loc[n,'Test-RMSE'] = round(np.sqrt(mean_squared_error(Test_Y, pred2)),20)

    # Plotting y_test and y_pred to understand the spread.
    plt.figure(figsize=[16,6])

    plt.subplot(1,2,1)
    sns.distplot((Train_Y - pred1))
    plt.title('Error Terms')          
    plt.xlabel('Errors') 

    plt.subplot(1,2,2)
    plt.scatter(Train_Y,pred1)
    plt.plot([Train_Y.min(),Train_Y.max()],[Train_Y.min(),Train_Y.max()], 'r--')
    plt.title('Test vs Prediction')         
    plt.xlabel('y_test')                       
    plt.ylabel('y_pred')                       
    plt.show()
    

print('\n\033[1mObjective:\033[0m Let us now try building multiple regression models & compare their evaluation metrics to choose the best fit model\
both training and testing sets...')

# %% [markdown]
# **<p id='54'><li>Multi Linear Regression (MLR)</li></p>**

# %%
#Linear Regression

MLR = LinearRegression().fit(Train_X_std,Train_Y)
pred1 = MLR.predict(Train_X_std)
pred2 = MLR.predict(Test_X_std)

print('{}{}\033[1m Evaluating Multiple Linear Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))
print('The Coeffecient of the Regresion Model was found to be ',MLR.coef_)
print('The Intercept of the Regresion Model was found to be ',MLR.intercept_)

Evaluate(0, pred1, pred2)
scoreMLR = evaluate_model(MLR, Test_X, Test_Y)

# %% [markdown]
# **<p id='55'><li>Ridge Regression Model (RLR)</li></p>**

# %%
#Creating a Ridge Regression model

RLR = Ridge().fit(Train_X_std,Train_Y)
pred1 = RLR.predict(Train_X_std)
pred2 = RLR.predict(Test_X_std)

print('{}{}\033[1m Evaluating Ridge Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))
print('The Coeffecient of the Regresion Model was found to be ',RLR.coef_)
print('The Intercept of the Regresion Model was found to be ',RLR.intercept_)

Evaluate(1, pred1, pred2)
scoreRLR = evaluate_model(RLR, Test_X, Test_Y)

# %% [markdown]
# **<p id='56'><li>Lasso Regression Model (LLR)</li></p>**

# %%
#Creating a Ridge Regression model

LLR = Lasso().fit(Train_X_std,Train_Y)
pred1 = LLR.predict(Train_X_std)
pred2 = LLR.predict(Test_X_std)

print('{}{}\033[1m Evaluating Lasso Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))
print('The Coeffecient of the Regresion Model was found to be ',LLR.coef_)
print('The Intercept of the Regresion Model was found to be ',LLR.intercept_)

Evaluate(2, pred1, pred2)
scoreLLR = evaluate_model(LLR, Test_X, Test_Y)

# %% [markdown]
# **<p id='57'><li>Elastic-Net Regression (ENR)</li></p>**

# %%
#Creating a ElasticNet Regression model

ENR = ElasticNet().fit(Train_X_std,Train_Y)
pred1 = ENR.predict(Train_X_std)
pred2 = ENR.predict(Test_X_std)

print('{}{}\033[1m Evaluating Elastic-Net Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))
print('The Coeffecient of the Regresion Model was found to be ',ENR.coef_)
print('The Intercept of the Regresion Model was found to be ',ENR.intercept_)

Evaluate(3, pred1, pred2)
scoreENR = evaluate_model(ENR, Test_X, Test_Y)

# %% [markdown]
# **<p id='59'><li>Gradient Boosting Regressor (GBR)</li></p>**

# %%
#Creating a GradientBoostingRegressor Regression model
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
GBR = GradientBoostingRegressor().fit(Train_X_std,Train_Y)
# search_grid={'n_estimators':[500,1000,2000],'learning_rate':[.001,0.01,.1],'max_depth':[1,2,4],'subsample':[.5,.75,1],'random_state':[1]}
# search=GridSearchCV(estimator=GBR,param_grid=search_grid,scoring='neg_mean_squared_error',n_jobs=1,cv=2)
# search.fit(Train_X_std,Train_Y)
pred1 = GBR.predict(Train_X_std)
pred2 = GBR.predict(Test_X_std)

print('{}{}\033[1m Evaluating GBR Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))

Evaluate(4, pred1, pred2)
scoreGBR = evaluate_model(GBR, Test_X, Test_Y)

# %% [markdown]
# **<p id='60'><li>Decision Tree Regressor (DTR)</li></p>**

# %%
#Creating a DecisionTreeRegressor Regression model
# 'max_depth': 3,
#  'max_features': 'auto',
#  'max_leaf_nodes': 10,
#  'min_samples_leaf': 9,
#  'min_weight_fraction_leaf': 0.1,
#  'splitter': 'best'
    
DTR = DecisionTreeRegressor(max_depth=3,max_features='auto',max_leaf_nodes=10,min_samples_leaf=9,min_weight_fraction_leaf=0.1,splitter='best').fit(Train_X_std,Train_Y)

pred1 = DTR.predict(Train_X_std)
pred2 = DTR.predict(Test_X_std)

print('{}{}\033[1m Evaluating Decision Tree Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))

Evaluate(5, pred1, pred2)
scoreDTR = evaluate_model(DTR, Test_X, Test_Y)

# %% [markdown]
# **<p id='61'><li>Random Forest Regressor (RFR)</li></p>**

# %%
#Creating a RandomForestRegressor Regression model
RFR = RandomForestRegressor(max_depth=80, max_features=3, min_samples_leaf=3,
                      min_samples_split=8, n_estimators=2000,random_state=512).fit(Train_X_std,Train_Y)

pred1 = RFR.predict(Train_X_std)
pred2 = RFR.predict(Test_X_std)

print('{}{}\033[1m Evaluating Random Forest Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))

Evaluate(6, pred1, pred2)
scoreRFR = evaluate_model(RFR, Test_X, Test_Y)

# %% [markdown]
# **<p id='62'><li>XGBoost Regressor (XGBoost)</li></p>**

# %%
#Creating a XGBRegressor Regression model
params ={'lambda': 0.1, 
         'alpha': 3, 
         'eta': 0.01, 
         'colsample_bytree': 0.9, 
         'subsample': 0.6, 
         'learning_rate': 0.018, 
         'n_estimators': 2000, 
         'max_depth': 5, 
         'min_child_weight': 3
        }
XGB =  XGBRegressor(**params).fit(Train_X_std,Train_Y,eval_set=[(Train_X_std,Train_Y),(Test_X_std, Test_Y)],
        early_stopping_rounds=60,verbose=False)
pred1 = XGB.predict(Train_X_std)
pred2 = XGB.predict(Test_X_std)

print('{}{}\033[1m Evaluating XGBoost Regression Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))

Evaluate(7, pred1, pred2)
scoreXGB = evaluate_model(XGB, Test_X, Test_Y)
print(scoreXGB)

# %% [markdown]
# **<p id='63'><li>CATBoost Regressor (CAT)</li></p>**

# %%
#Creating a CatBoost Regression model


CAT = CatBoostRegressor(iterations = 100, depth = 13).fit(Train_X_std,Train_Y,silent=True)

pred1 = CAT.predict(Train_X_std)
pred2 = CAT.predict(Test_X_std)

print('{}{}\033[1m Evaluating CatBoostRegressor Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))
Evaluate(8, pred1, pred2)
scoreCAT = evaluate_model(CAT, Test_X, Test_Y)

# %% [markdown]
# **<p id='64'><li>KNeighbors Regressor (KNR)</li></p>**

# %%
#Creating a KNeighborsRegressor Regression model
KNR = KNeighborsRegressor().fit(Train_X_std,Train_Y)

pred1 = KNR.predict(Train_X_std)
pred2 = KNR.predict(Test_X_std)

print('{}{}\033[1m Evaluating KNeighborsRegressor Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))
Evaluate(9, pred1, pred2)
scoreKNR = evaluate_model(KNR, Test_X, Test_Y)

# %% [markdown]
# **<p id='65'><li>LGBM Regressor (LGBM)</li></p>**

# %%
#Creating a LGBMRegressor Regression model


LGBM = LGBMRegressor(learning_rate = 0.025,
                     objective = "regression", 
                     boosting_type = "gbdt",
                     verbosity = -1,n_jobs = -1, seed = 21,
                     reg_alpha =  0.003,reg_lambda = 0.65,
                     lambda_l1 = 1.11, lambda_l2= 2, 
                     num_leaves = 109, n_estimators = 2606, max_depth = 1, max_bin = 244, 
                     min_data_in_leaf = 366, random_state =512).fit(Train_X_std,Train_Y)

pred1 = LGBM.predict(Train_X_std)
pred2 = LGBM.predict(Test_X_std)

print('{}{}\033[1m Evaluating LGBMRegressor Model \033[0m{}{}\n'.format('<'*3,'-'*20,'-'*20,'>'*3))
Evaluate(10, pred1, pred2)
scoreLGBM = evaluate_model(LGBM, Test_X, Test_Y)

# %% [markdown]
# **<p id='66'><li>Evaluation of Metics</li></p>**

# %%
# Regression Models Results Evaluation

EMC = Model_Evaluation_Comparison_Matrix.copy()
EMC.index = [
    'Multiple Linear Regression (MLR)','Ridge Linear Regression (RLR)','Lasso Linear Regression (LLR)',
    'Elastic-Net Regression (ENR)','GradientBoostingRegressor (GBR)','DecisionTreeRegressor (DTR)',
    'RandomForestRegressor (RFR)','XGBRegressor (XGBoost)','CatBoostRegressor (CATBoost)',
    'KNeighborsRegressor (KNR)', 'LGBMRegressor (LGBM)'
    ]
EMC

# %% [markdown]
# **<p id='67'><li>Comapring Regression Models</li></p>**

# %%
# R2-Scores Comparison for different Regression Models

R2 = round(EMC['Train-R2'].sort_values(ascending=True),4)
plt.hlines(y=R2.index, xmin=0, xmax=R2.values,color='#195190FF')
plt.plot(R2.values, R2.index,'o')
plt.title('R2-Scores Comparison for various Regression Models')
plt.xlabel('R2-Score')
for i, v in enumerate(R2):
    plt.text(v+0.02, i-0.05, str(round(v*100,2)), color='black')
plt.xlim([0,1.1])
plt.show()

# %% [markdown]
#  **<p id='68'><li>Root Mean SquaredError Comparison</li></p>**

# %%
# Root Mean SquaredError Comparison for different Regression Models

cc = Model_Evaluation_Comparison_Matrix.columns.values
s=5
plt.bar(np.arange(11), Model_Evaluation_Comparison_Matrix[cc[6]].values, width=0.3, label='RMSE (Training)',ec='black')
plt.bar(np.arange(11)+0.3, Model_Evaluation_Comparison_Matrix[cc[7]].values, width=0.3, label='RMSE (Testing)',ec='black')
plt.xticks(np.arange(11),EMC.index, rotation = 90)
plt.legend()
plt.show()

print('\n\033[1mInference:\033[0m Lesser the RMSE, better the model! Also, provided the model should have close proximity with the \ntraining & testing scores. For this problem,it is can be said that RFR are the best choice to go with.')

# %% [markdown]
#  **<p id='72'><li>SMPE Value</li></p>**

# %%
print(f"SMAPE: MLR {scoreMLR} %")
print(f"\nSMAPE: RLR {scoreRLR} %")
print(f"\nSMAPE: LLR {scoreLLR} %")
print(f"\nSMAPE: ENR {scoreENR} %")
print(f"\nSMAPE: GBR {scoreGBR} %")
print(f"\nSMAPE: DTR {scoreDTR} %")
print(f"\nSMAPE: RFR {scoreRFR} %")
print(f"\nSMAPE: XGB {scoreXGB} %")
print(f"\nSMAPE: CAT {scoreCAT} %")
print(f"\nSMAPE: KNR {scoreKNR} %")
print(f"\nSMAPE: LGBM {scoreLGBM} %")

# %% [markdown]
# <a id="73"></a> <br>
# # Submission
#
#  **<p id='73'><li>Submission to CSV</li></p>**

# %%
testData = std.transform(testData)
submissionTarget = np.exp(DTR.predict(testData))
submissionTarget = np.ceil(submissionTarget)
submissionTarget = submissionTarget.astype(int)

submission = pd.read_csv('/kaggle/input/c/tabular-playground-series-jan-2022/sample_submission.csv')
submission['num_sold'] = submissionTarget
submission.to_csv('submission.csv', index=False)

# %% [markdown]
#  **<p id='74'><li>Summary of Submission</li></p>**

# %%
basicSummary(submission)

# %% [markdown]
#  **<p id='75'><li>Glance of Submission</li></p>**

# %%
submission.head()

# %%
merged = pd.merge(TestData, submission, left_on='row_id', right_on='row_id', how='left')

# %%
# merged['Year'] = merged['date'].apply(split_year)
# merged['Month'] = merged['date'].apply(split_month)
# merged['Day'] = merged['date'].apply(split_day)
# merged['Weekend'] = weekend(merged['date'])
# merged['Weekday'] = weekday(merged['date'])
# merged = merged.drop(columns = ['row_id', 'date'])

# %%
# FinlandDataKaggleMartData2019 = merged[(merged.country == 'Finland') & (merged.store == 'KaggleMart') & (merged.Year == '2019')]
# FinlandDataKaggleMartData2019.drop(['Day', 'Weekend','Weekday'], axis=1, inplace=True)
# FinlandDataKaggleMartDataFrame2019 = FinlandDataKaggleMartData2019.groupby(['Year','Month','store','product'])[['num_sold']].sum().reset_index()
# FinlandDataKaggleMartSeries2019 = FinlandDataKaggleMartDataFrame2019.groupby(['Year','Month','store','product','num_sold'], as_index=True).size()
# FinlandDataKaggleMart2019 = pd.DataFrame(FinlandDataKaggleMartSeries2019)


# FinlandDataKaggleRamaData2019 = merged[(merged.country == 'Finland') & (merged.store == 'KaggleRama') & (merged.Year == '2019')]
# FinlandDataKaggleRamaData2019.drop(['Day', 'Weekend', 'Weekday'], axis=1, inplace=True)
# FinlandDataKaggleRamaDataFrame2019 = FinlandDataKaggleRamaData2019.groupby(['Year', 'Month', 'store', 'product'])[['num_sold']].sum().reset_index()
# FinlandDataKaggleRamaSeries2019 = FinlandDataKaggleRamaDataFrame2019.groupby(['Year', 'Month', 'store', 'product', 'num_sold'], as_index=True).size()
# FinlandDataKaggleRama2019 = pd.DataFrame(FinlandDataKaggleRamaSeries2019)


# NorwayDataKaggleMartData2019 = merged[(merged.country == 'Norway') & (merged.store == 'KaggleMart') & (merged.Year == '2019')]
# NorwayDataKaggleMartData2019.drop(['Day', 'Weekend','Weekday'], axis=1, inplace=True)
# NorwayDataKaggleMartDataFrame2019 = NorwayDataKaggleMartData2019.groupby(['Year','Month','store','product'])[['num_sold']].sum().reset_index()
# NorwayDataKaggleMartSeries2019 = NorwayDataKaggleMartDataFrame2019.groupby(['Year','Month','store','product','num_sold'], as_index=True).size()
# NorwayDataKaggleMart2019 = pd.DataFrame(NorwayDataKaggleMartSeries2019)

# NorwayDataKaggleRamaData2019 = merged[(merged.country == 'Norway') & (merged.store == 'KaggleRama') & (merged.Year == '2019')]
# NorwayDataKaggleRamaData2019.drop(['Day', 'Weekend', 'Weekday'], axis=1, inplace=True)
# NorwayDataKaggleRamaDataFrame2019 = NorwayDataKaggleRamaData2019.groupby(['Year', 'Month', 'store', 'product'])[['num_sold']].sum().reset_index()
# NorwayDataKaggleRamaSeries2019 = NorwayDataKaggleRamaDataFrame2019.groupby(['Year', 'Month', 'store', 'product', 'num_sold'], as_index=True).size()
# NorwayDataKaggleRama2019 = pd.DataFrame(NorwayDataKaggleRamaSeries2019)


# SwedenDataKaggleMartData2019 = merged[(merged.country == 'Sweden') & (merged.store == 'KaggleMart') & (merged.Year == '2019')]
# SwedenDataKaggleMartData2019.drop(['Day', 'Weekend','Weekday'], axis=1, inplace=True)
# SwedenDataKaggleMartDataFrame2019 = SwedenDataKaggleMartData2019.groupby(['Year','Month','store','product'])[['num_sold']].sum().reset_index()
# SwedenDataKaggleMartSeries2019 = SwedenDataKaggleMartDataFrame2019.groupby(['Year','Month','store','product','num_sold'], as_index=True).size()
# SwedenDataKaggleMart2019 = pd.DataFrame(SwedenDataKaggleMartSeries2019)


# SwedenDataKaggleRamaData2019 = merged[(merged.country == 'Sweden') & (merged.store == 'KaggleRama') & (merged.Year == '2015')]
# SwedenDataKaggleRamaData2019.drop(['Day', 'Weekend', 'Weekday'], axis=1, inplace=True)
# SwedenDataKaggleRamaDataFrame2019 = SwedenDataKaggleRamaData2019.groupby(['Year', 'Month', 'store', 'product'])[['num_sold']].sum().reset_index()
# SwedenDataKaggleRamaSeries2019 = SwedenDataKaggleRamaDataFrame2019.groupby(['Year', 'Month', 'store', 'product', 'num_sold'], as_index=True).size()
# SwedenDataKaggleRama2019 = pd.DataFrame(SwedenDataKaggleRamaSeries2019)

# %%
# FinlandDataKaggleMart2019

# %% [markdown]
# **Work In Progress.....**
