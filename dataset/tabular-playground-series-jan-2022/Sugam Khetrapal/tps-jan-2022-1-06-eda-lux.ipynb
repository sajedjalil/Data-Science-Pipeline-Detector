# %% [markdown]
# # Problem Statement
#
# In this notebook we will explore how to do Automatic Exploratory Data Analysis (EDA) on the Tabular Playground Series January 2022 dataset using [LUX](https://github.com/lux-org/lux).
#
# We are going to cover the following steps:
# 1. Install LUX
# 2. Import Libraries
# 3. Load Dataset
# 4. Print Report
# 5. References
#
# Let's get started.
#
# # Install LUX

# %%
# !pip install lux-api

# %% [markdown]
# # Import Libraries

# %%
import lux
from lux.vis.Vis import Vis
import pandas as pd

# %% [markdown]
# # Load Dataset

# %%
# Load Dataset

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
filename_training          = '/kaggle/input/tabular-playground-series-jan-2022/train.csv'
dataset_training           = pd.read_csv(filename_training)

# %% [markdown]
# # Print Report

# %%
dataset_training
