# %% [markdown]
# # Problem Statement
#
# In this notebook we will explore how to do Automatic Exploratory Data Analysis (EDA) on the Tabular Playground Series January 2022 dataset using [D-Tale](https://dtale.readthedocs.io/en/latest/).
#
# We are going to cover the following steps:
# 1. Install D-Tale
# 2. Import Libraries
# 3. Load Dataset
# 4. Print Report
# 5. References
#
# Let's get started.
#
# # Install D-Tale

# %%
# !pip install dtale

# %% [markdown]
# # Import Libraries

# %%
import dtale
import dtale.app as dtale_app
dtale_app.USE_NGROK= True
import pandas as pd
from pandas import read_csv

# %% [markdown]
# # Load Dataset

# %%
# Load Dataset

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
filename_training          = '/kaggle/input/tabular-playground-series-jan-2022/train.csv'

# %% [markdown]
# # Print Report

# %%
d=dtale.show(pd.read_csv('/kaggle/input/tabular-playground-series-jan-2022/train.csv'))

# %%
d.main_url()

# %% [markdown]
# # References
#
# 1. Thank you to shreyasajal for demonstrating how to use D-tale in the [notebook](https://www.kaggle.com/shreyasajal/d-tale-sweetviz-netflix-explored-in-1-line).
