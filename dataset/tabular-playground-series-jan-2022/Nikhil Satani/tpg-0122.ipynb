# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('../input/tabular-playground-series-jan-2022/train.csv')
test = pd.read_csv('../input/tabular-playground-series-jan-2022/test.csv')

# %%
train.head()

# %%
test.head()

# %%
train['num_sold']

# %%
train['country']

# %%
train.drop('row_id', axis=1, inplace=True)
test.drop('row_id', axis=1, inplace=True)

# %%
train.head()

# %%
train.info()

# %%
train.describe()
train.head()

# %%
train['date'] = train['date'].str.replace("-","").astype(int)

# %%
test['date'] = test['date'].str.replace("-","").astype(int)

# %%
train.count()

# %%
train.items()

# %%
train.head(19)

# %%
print(train['country'].value_counts(), '\n')
print(train['product'].value_counts(), '\n')
print(train['store'].value_counts(), '\n')

# %%
test.head()

# %%
train['date'] = train['date'].astype(str)

# %%
train['date'] = train['date'].str[4:]

# %%
train.head()

# %%
test['date'] = test['date'].astype(str)
test['date'] = test['date'].str[4:]

# %%
test.head()

# %%
train['date'] = train['date'].astype(int)

# %%
test['date'] = test['date'].astype(int)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown='ignore')

# %%
train_cat = train[['country', 'store', 'product']]

# %%
train_cat_1hot = enc.fit_transform(train_cat)

# %%
train_cat_1hot.toarray()

# %%
enc.categories_

# %%
train.head()

# %%
test.head()

# %%
mapping1 = {'Finland': 1, 'Norway': 2, 'Sweden': 3}
mapping2 = {'KaggleMart': 1, 'KaggleRama': 2}
mapping3 = {'Kaggle Mug': 1, 'Kaggle Hat': 2, 'Kaggle Sticker': 3}

# %%
train = train.replace({'country': mapping1, 'store':mapping2, 'product': mapping3})
test = test.replace({'country': mapping1, 'store':mapping2, 'product': mapping3})

# %%
train.head()

# %%
test.head()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators = 1000, max_depth = 10, random_state = 42)

# %%
X, y = train.drop('num_sold', axis=1), train['num_sold']

# %%
model.fit(X, y)

# %%
prediction = model.predict(test)

# %%
submission = pd.read_csv('../input/tabular-playground-series-jan-2022/sample_submission.csv')

# %%
submission.head()

# %%
submission['num_sold'] = prediction

# %%
submission.head()

# %%
submission.to_csv('submission.csv', index=False)
