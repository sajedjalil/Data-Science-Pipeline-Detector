# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# Set up filepaths
import os
if not os.path.exists("../input/tabular-playground-series-jan-2022"):
    os.symlink("../input/tabular-playground-series-jan-2022/test.csv")  
    os.symlink("../input/tabular-playground-series-jan-2022/train.csv") 

# From competition: https://www.kaggle.com/c/tabular-playground-series-jan-2022/data?select=test.csv

# %%
#Libraries used
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

sales_train = pd.read_csv("../input/tabular-playground-series-jan-2022/test.csv")
sales_test = pd.read_csv("../input/tabular-playground-series-jan-2022/train.csv")

sales_train.head(5)
#looking at a set of data that appears to have no target output, so unsupervised.

# %%
sales_train.describe()

# %%
#Missing Values:
missing_val_count_by_column = (sales_train.isnull().sum())
print('missing', missing_val_count_by_column[missing_val_count_by_column > 0])
#looks like there are no missing values?

# %%
# run eventually:
#X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
#                                                      random_state=0)
