# %% [markdown]
# ### Tabular Playground Series - January 2022
#
# <h2> The Storytelling Behind Data - Using Flourish (Notebook 2) </h2>
#
# <h4> This Notebook is the the continuation of my previous notebook on Tabular Playground Series - January 2022. The previous notebook can be found at: </h4>
#
# [Click here to view Previous Notebook](https://www.kaggle.com/aestheteaman01/tabular-playground-2022-the-storytelling)

# %% [markdown]
# <h3> What would be in this notebook? </h3>
#
# This notebook won't be about the best approach to build the forecasting model to get a score as minimum as possible. I'll try to look through this dataset, do some EDA (Exploratory Data Analysis) and try to build a story using beautiful yet impactful open-source visualization tool - Flourish. Flourish makes it easy to visualize data using easy approaches without need of code. Interactive data dashboarding to analytics storytelling, that's what I wish to explore in the Playground Jan 22' Series.
#
# This data doesn't simulates a real-world environment, but data storytelling is a fun thing to do. Let's now navigate to the charts and explore the dataset in much more depth.
#
# From the previous notebook, this time I would love to explore the sales on country & timeseries level. Hope you have a happy reading :)

# %% [markdown]
# <h3> How the dataset looks like? </h3>
#
# Problem Statement - There are two (fictitious) independent store chains selling Kaggle merchandise that want to become the official outlet for all things Kaggle. We've decided to see if the Kaggle community could help us figure out which of the store chains would have the best sales going forward.
#
# We import the data using python libraries and check them

# %%
#Importing Pandas Library to open the dataset
import pandas as pd

#Loading the dataset and viewing first few rows
playground_data = pd.read_csv('../input/tabular-playground-series-jan-2022/train.csv')
playground_data.head()

# %% [markdown]
# <h3> Understanding the dataset </h3>
#
# * The dataset has 6 columns that store the details of sales of Kaggle Products by Stores in multiple countries.
# * 3 Countries - Finland, Norway and Sweden is present. There are 2 Stores, Kaggle Mart and Kaggle Rama
# * The stores sell 3 types of goodies - Kaggle Mug, Kaggle Hat and Kaggle Stickers
# * Sales data is recorded from January 01, 2015 to December 31, 2018 for all stores across 3 countries.
#
# Now that we know what the dataset is, let's study the following questions using interactive Flourish charts:

# %% [markdown]
# # Increasing Sales, but Ratio of Sales Growth between years decreasing?

# %% [markdown]
# # Analysis 1 - Amongst the mentioned years, which one had highest Sales?

# %% [markdown]
# <iframe src='https://flo.uri.sh/visualisation/8541100/embed' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe>

# %% [markdown]
# Year 2018 had the highest sales, but there are much more to know from the graph above -
#
# * Over span of 4 years, 16.63% increase in sales were seen (From 2015 to 2018)
# * Though 2018 reported the highest sales, but the % growth of sales between 2017-2018 was less than year 2016-2017
# * Year 2016-2017 had the highest growth increase in Kaggle Goodie Sales. Almost negligible growth was seen between 2015-2016
#
# Okay, so we now know the stores certainly needs to look to it's shops to understand why the growth of sales of goodies fell in the 2018 year.

# %% [markdown]
# # Analysis 2 - Was this Sales growth ratio decline in 2017-2018 present in all countries?
#
# From the [Tabular Playground 1 Notebook](https://www.kaggle.com/aestheteaman01/tabular-playground-2022-the-storytelling) we observed that Norway had the highest sales for Kaggle Goodies. Let's drill down to check the year wise sales growth at country level

# %% [markdown]
# <iframe src='https://flo.uri.sh/visualisation/8542094/embed' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe>

# %% [markdown]
# The increase of Sales growth is great for Stores, but the decline is not. Some key observations that we have from the above graph is:
#
# 1. For Finland growth of sales is positive between subsequent years.
# 2. Norway saw a sharp fell in sales growth between years 2015-16 (-3.53%)
# 3. A similar sales growth decline was seen in Sweden between years 2017-18
#
# For the Analysis 1, we now have some light on the fact that because of Sweden's sales decline between 2017-18, the overall sales growth decline was observed.

# %% [markdown]
# # At what points the Sales growth ratios are declining?
#
# # Analysis 3 - Drilling down the time when Sales growth are declining : Finland
#
# We build a dashboard to understand the Sales of Kaggle Products in Finland. Click on the arrow button to move between the charts

# %% [markdown]
# <iframe src='https://flo.uri.sh/story/1117445/embed' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe>

# %% [markdown]
# <h3> Key Observations from Analysis 3 </h3>
#
# * Overall no -ve sales growth was seen in Finland for both the stores (That is, there has been no year where sales was less as compared to previous year. The sales growth had always been positive)
#
# * For the Store Kaggle Mart, positive growth has been seen always. However the sales growth of Kaggle Mugs in 2018 was less than year 2017. This implies that increase in % of Kaggle mugs sold from 2017 to 2018 was less than that seen in 2016-2017.
#
# * A similar pattern is seen with Kaggle Rama store where % increase in sales of Mugs & Stickers were more in 2016 to 2017 than 2017 to 2018.
#
# So, for Finland for both the stores we observe that the sales growth % has increased over the span of 4 years. However the ratio of increase between years 2016-2017 was more than that of 2017-2018 for the following products:
#
# * Kaggle Mugs at Kaggle Mart Store
# * Kaggle Mugs and Stickers at Kaggle Rama Store

# %% [markdown]
# # Analysis 4 - Are there any months where sales decline in Finland?

# %% [markdown]
# <iframe src='https://flo.uri.sh/visualisation/8545943/embed' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe>

# %% [markdown]
# <H4> Key Observations - Finland Kaggle Product Sales </H4>
#
# * The average sales % growth for both the stores across all the products are approximately same.
# * Sales of Kaggle Products are highest in Nov-Dec months.
# * Sales decline sharply between Jan-Feb for all the products.
# * Decline in sales is seen between May - Sep for Kaggle products
#
# As a Kaggle Product seller in Finland special emphasis is required to me made between the months May - September as sales fell greatly during this tenure. December is the month of highest sales of Kaggle Goodies (can be related to Christmas or New Year) but the stores needs to attract the customers as a very high decline (-ve sales figures) are seen after the holiday period in February.

# %% [markdown]
# # Analysis 5 - Does Christmas & New Year increases Kaggle Goodies Sales? - Case Study Finland

# %% [markdown]
# <iframe src='https://flo.uri.sh/visualisation/8549537/embed' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe>

# %% [markdown]
# <h4> Observations </h4>
#
# New Year & Christmas increases Sales of Kaggle Products. Across both the stores in Finland for all of the three products, growth in sales % ratio between two consecutive days increases sharply as Christmas and New Year Approaches.
#
# <h2> A Great Takeaway </h2>
#
# After the peak of Sales, a very sharp decline of sales for all of the products in all stores of Finland is seen (Note: Shops are open, because we have sales data for the goodies). Unavailability of Goods or partial closure of few stores, might be a potential cause for this trend. This might be the area where stock of goodies needs to be ramped up.

# %% [markdown]
# <H3> The Thanks Note to Tabular Playground Series </H3>
#
# And Published. I'll possibly be doing comparable analysis for Norway & Sweden as well, when done. Would update the notebook ;)
#
# I always loved building stories out of data, and I loved very much writing these series of 2 notebooks to answer some basic questions with open source visualization tools. [Marília Prata](https://www.kaggle.com/mpwolke) made me aware about the event, and with concluding the last notebook on this series, I would specially like to Thank you, for the great source of inspiration & support you had been to me.
#
# Would love to hear your opinions on this notebook. Feel free to connect with me on [Linkedin](https://www.linkedin.com/in/amankumar01/). It was happy writing this notebook. Cheers!!
