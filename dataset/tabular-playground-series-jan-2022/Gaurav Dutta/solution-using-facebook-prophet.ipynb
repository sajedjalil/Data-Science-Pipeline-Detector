# %%
import pandas as pd
Sweden_KaggleRama_KaggleSticker=pd.read_csv('../input/sweden-kagglerama-kagglesticker/Sweden_KaggleRama_Kaggle Sticker.csv')
Sweden_KaggleRama_KaggleSticker.head()

# %%
Norway_KaggleRama_KaggleSticker=pd.read_csv('../input/norway-kagglerama-kagglesticker/Norway_KaggleRama_Kaggle Sticker.csv')
Norway_KaggleRama_KaggleSticker.head()

# %%
Finland_KaggleRama_KaggleSticker=pd.read_csv('../input/finland-kagglerama-kagglesticker/Finland_KaggleRama_Kaggle Sticker.csv')
Finland_KaggleRama_KaggleSticker.head()

# %%
Sweden_KaggleRama_KaggleMug=pd.read_csv('../input/sweden-kagglerama-kagglemug/Sweden_KaggleRama_Kaggle Mug.csv')
Sweden_KaggleRama_KaggleMug.head()

# %%
Finland_KaggleRama_KaggleMug=pd.read_csv('../input/finland-kagglerama-kagglemug/Finland_KaggleRama_Kaggle Mug.csv')
Finland_KaggleRama_KaggleMug.head()

# %%
Norway_KaggleRama_KaggleMug=pd.read_csv('../input/norway-kagglerama-kagglemug/Norway_KaggleRama_Kaggle Mug.csv')
Norway_KaggleRama_KaggleMug.head()

# %%
Sweden_KaggleRama_KaggleHat=pd.read_csv('../input/norway-kagglerama-kagglehat/Norway_KaggleRama_Kaggle Hat.csv')
Sweden_KaggleRama_KaggleHat.head()

# %%
Finland_KaggleRama_KaggleHat=pd.read_csv('../input/finland-kagglerama-kagglehat/Finland_KaggleRama_Kaggle Hat.csv')
Finland_KaggleRama_KaggleHat.head()

# %%
Norway_KaggleRama_KaggleHat=pd.read_csv('../input/norway-kagglerama-kagglehat/Norway_KaggleRama_Kaggle Hat.csv')
Norway_KaggleRama_KaggleHat.head()

# %%
Sweden_KaggleMart_KaggleSticker=pd.read_csv('../input/sweden-kagglemart-kagglesticker/Sweden_KaggleMart_Kaggle Sticker.csv')
Sweden_KaggleMart_KaggleSticker.head()

# %%
Norway_KaggleMart_KaggleSticker=pd.read_csv('../input/norway-kagglemart-kagglesticker/Norway_KaggleMart_Kaggle Sticker.csv')
Norway_KaggleMart_KaggleSticker.head()

# %%
Finland_KaggleMart_KaggleSticker=pd.read_csv('../input/finland-kagglemart-kagglesticker/Finland_KaggleMart_Kaggle Sticker.csv')
Finland_KaggleMart_KaggleSticker.head()

# %%
Sweden_KaggleMart_KaggleMug=pd.read_csv('../input/sweden-kagglemart-kagglemug/Sweden_KaggleMart_Kaggle Mug.csv')
Sweden_KaggleMart_KaggleMug.head()

# %%
Finland_KaggleMart_KaggleMug=pd.read_csv('../input/finland-kagglemart-kagglemug/Finland_KaggleMart_Kaggle Mug.csv')
Finland_KaggleMart_KaggleMug.head()

# %%
Norway_KaggleMart_KaggleMug=pd.read_csv('../input/norway-kagglemart-kagglemug/Norway_KaggleMart_Kaggle Mug.csv')
Norway_KaggleMart_KaggleMug.head()

# %%
Sweden_KaggleMart_KaggleHat=pd.read_csv('../input/sweden-kagglemart-kagglehat/Sweden_KaggleMart_Kaggle Hat.csv')
Sweden_KaggleMart_KaggleHat.head()

# %%
Norway_KaggleMart_KaggleHat=pd.read_csv('../input/norway-kagglemart-kagglehat/Norway_KaggleMart_Kaggle Hat.csv')
Norway_KaggleMart_KaggleHat.head()

# %%
Finland_KaggleMart_KaggleHat=pd.read_csv('../input/finland-kagglemart-kagglehat/Finland_KaggleMart_Kaggle Hat.csv')
Finland_KaggleMart_KaggleHat.head()

# %%
frames = [Sweden_KaggleRama_KaggleSticker, Norway_KaggleRama_KaggleSticker,Finland_KaggleRama_KaggleSticker,
         Sweden_KaggleRama_KaggleMug, Norway_KaggleRama_KaggleMug,Finland_KaggleRama_KaggleMug,
         Sweden_KaggleRama_KaggleHat, Norway_KaggleRama_KaggleHat,Finland_KaggleRama_KaggleHat,
         Sweden_KaggleMart_KaggleSticker, Norway_KaggleMart_KaggleSticker,Finland_KaggleMart_KaggleSticker,
         Sweden_KaggleMart_KaggleMug, Norway_KaggleMart_KaggleMug,Finland_KaggleMart_KaggleMug,
         Sweden_KaggleMart_KaggleHat, Norway_KaggleMart_KaggleHat,Finland_KaggleMart_KaggleHat,]
result = pd.concat(frames)
result.head()

# %%
result=result.sort_values(by ="row_id")
result= result.reset_index(drop=True)
result.head()

# %%
sol=pd.read_csv('../input/tabular-playground-series-jan-2022/sample_submission.csv')
sol.head()

# %%
sol.num_sold=result.num_sold
sol.head()

# %%
sol.to_csv('./submission.csv',index=False)
