# %%
import pandas as pd
train=pd.read_csv('../input/tabular-playground-series-jan-2022/train.csv')
train.head()

# %%
train.info()

# %%
train.nunique()

# %%
train.date=pd.to_datetime(train.date, infer_datetime_format=True)
train.info()

# %%
train.head()

# %%
# !pip install sweetviz

# %%
import sweetviz
feature_config =  sweetviz.FeatureConfig(force_num=["num_sold"])
my_report  = sweetviz.analyze(train, target_feat='num_sold',feat_cfg=feature_config)
my_report.show_notebook()
