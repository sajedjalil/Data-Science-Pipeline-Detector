# %% [markdown]
# ## Section1:

# %% [markdown]
# *Line 0:*
#
#     Number of rows: 400
#
#     Number of cols: 600
#
#     Number of drones: 30
#
#     Deadline: 112993
#
#     Max load of a drone: 200

# %% [markdown]
# ## Section 2 (product):

# %% [markdown]
# *Line 1,2:*
#
#     Number of product: 400
#
#     *Each product has:**
#
#     Weights: 73 40 84 107 52 36 13 74 36 94 93 46 123 24 ....

# %% [markdown]
# ## Section 3 (warehouse):

# %% [markdown]
# *Line 3 to 23:*
#
#     Number of warehouse: 10
#
#     **Each warehouse has:**
#
#         Coordinates of warehouse cell (warehouse 0): 113 179
#
#         Avilabe products at this warehouse (warehouse 0): 0 0 5 1 0 0 0 0 2 .... (400 item)
#
#         ...

# %% [markdown]
# ## Section 4 (orders):

# %% [markdown]
# *line 24 to 3774:*
#
#     Number of orders: 1250
#
#     **Each order has:**
#
#         Coordinates of delivery cell (order 0): 340 371
#
#         Ordered product items (order 0): 8
#
#         Product types (order 0): 226 183 6 220 299 280 12 42
#
#     ...
