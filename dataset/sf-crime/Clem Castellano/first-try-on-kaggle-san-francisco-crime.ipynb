# %% [markdown]
# # San Francisco Minority Report
#
# This will be my first try on Kaggle (except the Titanic competition). I am new to data science and I hope I can learn the most of it by getting my hand dirty!
#
# ## Introduction

# %%
#Import libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#Get data
df = pd.read_csv('../input/train.csv',header=0)
df_test = pd.read_csv('../input/test.csv',header=0)

# %% [markdown]
# ## Exploring Data
#
# I am intending to explore the data using solely the train file in order to stay neutral regarding the outcome of my prediction. I assume that using values from the test data could be a good help to improve my score (by having more data on the population), but this is not my actual goal here.
#
# ### Variables

# %%
df.info()

# %% [markdown]
# On first sight, we have 7 variables, from which 2 are float values. The dataset does not contain null values, which should make the cleaning easier.

# %%
### Output

# %%
print("Number of crime categories: {}".format(len(df.Category.drop_duplicates())+1))
print(df.Category.drop_duplicates())

# %% [markdown]
# The objective will be to predict among 40 potential crime categories, which will make the task complicated.
