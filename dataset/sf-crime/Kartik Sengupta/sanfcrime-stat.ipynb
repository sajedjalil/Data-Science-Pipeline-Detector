# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sf=pd.read_csv('../input/sf-crime/train.csv.zip')

# %%
sf.head(15)

# %%
sf.shape

# %%
sf.info

# %%
sf.describe

# %%
sf.isnull().sum()

# %%
sf['Resolution'].value_counts()

# %%
sf.dtypes

# %%
import seaborn as sns

# %%
sf['Address'].value_counts()

# %%
#Maximum number of crime in sanfrancisco takes place in 800 Block of BRYANT ST

# %%
sf['PdDistrict'].value_counts()

# %%
#Highest number of crimes takes place in the southern districts

# %%
data=sf.Category.value_counts()
sns.barplot(y=data.index,x=data,orient='h')

# %%
dat=sf.Resolution.value_counts()
sns.barplot(y=dat.index,x=dat,orient='h')

# %%
sft=pd.read_csv('../input/sf-crime/test.csv.zip')

# %%
sft.head(10)

# %%
sft.shape

# %%
sft.info

# %%
sf['DayOfWeek'].value_counts()[0:3]

# %%
#most number of crimes occur on Friday in SanFrancisco

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
sfle=sf

# %%
sfle['Category']=le.fit_transform(sfle['Category'])

# %%
sfle.head(10)

# %%
sffle=sfle

# %%
sffle['DayOfWeek']=le.fit_transform(sffle['DayOfWeek'])
sffle['PdDistrict']=le.fit_transform(sffle['PdDistrict'])
sffle['Resolution']=le.fit_transform(sffle['Resolution'])
sffle['Address']=le.fit_transform(sffle['Address'])
sffle['Descript']=le.fit_transform(sffle['Descript'])

# %%
sffle.head()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
sffle['Dates']=pd.to_datetime(sffle['Dates'])

# %%
sffle.head()

# %%
sffle.dtypes

# %%
dt=sffle['Dates']

# %%
dtt=dt.view('int64')

# %%
sffle.head()

# %%
df=sffle.drop('Dates',axis='columns')

# %%
df.head()

# %%
merged=pd.concat([dtt,df],axis='columns')

# %%
merged.head()

# %%
from sklearn import preprocessing

# %%
h = merged.values #returns a numpy array
scaler = preprocessing.StandardScaler()
h_scaled = scaler.fit_transform(h)
df = pd.DataFrame(h_scaled)

# %%
df

# %%
df.columns=merged.columns

# %%
dff=df.astype('int')

dff.columns=merged.columns
dff

# %%
scaler.fit(merged)

# %%
pdf=scaler.transform(merged)

# %%
pdf_d=pd.DataFrame(pdf)
pdf_d

# %%
sft.head()

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC 
from numpy import array
from sklearn.model_selection import train_test_split

# %%
sftle=sft

# %%
sftle['DayOfWeek']=le.fit_transform(sftle['DayOfWeek'])
sftle['PdDistrict']=le.fit_transform(sftle['PdDistrict'])

sftle['Address']=le.fit_transform(sftle['Address'])

# %%
sftle.head(10)

# %%
sftle['Dates']=pd.to_datetime(sftle['Dates'])

# %%
dte=sftle['Dates']

# %%
dtef=dte.view('int64')

# %%
sftlef=sftle.drop('Dates',axis='columns')

# %%
mert=pd.concat([dtef,sftlef],axis='columns')

# %%
mert.head()

# %%
plt.scatter(merged['X'],merged['Y'])

# %%
plt.scatter(mert['X'],mert['Y'])

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
f=dff.drop(['Descript','Resolution'],axis='columns')

# %%
X=f.drop('Category',axis='columns')
X

# %%
y=f.Category
y

# %%
model.fit(X,y)

# %%
model.predict([[1,1,2,2,1,1]])

# %%
svm=SVC()

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit(pdf)

# %%
pdf_t=pca.transform(pdf)

# %%
pdf_t.shape

# %%
pdf_t

# %%
rfc=RandomForestClassifier()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(LogisticRegression(),X,y)

# %%
cross_val_score(LinearRegression(),X,y)

# %%
dfs=dff.sample(10000,random_state=1)
dfs

# %%
ff=dfs.drop(['Descript','Resolution'],axis='columns')

# %%
Xt=ff.drop('Category',axis='columns')
Xt

# %%
yt=ff.Category
yt

# %%
rfc.fit(Xt,yt)

# %%
cross_val_score(RandomForestClassifier(),Xt,yt)

# %%
cross_val_score(LogisticRegression(),Xt,yt)

# %%
my_model=LogisticRegression()

# %%
my_model.fit(X_train,y_train)

# %%
my_model.score(X_test,y_test)

# %%
my_model.predict(X_test)

# %%
cross_val_score(LogisticRegression(),X,y)

# %%
cross_val_score(SVC(),Xt,yt)

# %%
ex=np.array(Xt)
ex

# %%
t = mert.values #returns a numpy array
scaler = preprocessing.StandardScaler()
t_scaled = scaler.fit_transform(t)
dft = pd.DataFrame(t_scaled)

# %%
dft

# %%
dft.columns=mert.columns

# %%
dft

# %%
test_id=dft.index.values

# %%
dft

# %%
dft_new=dft.drop('Id',axis=1)

# %%
dft_new

# %%
test_id

# %%
pred=my_model.predict(dft_new)
pred

# %%
my_submission = pd.DataFrame( {'Id':test_id,'Category': pred})
# you could use any filename. We choose submission here
my_submission.to_csv('submissionkartik.csv', index=False)
