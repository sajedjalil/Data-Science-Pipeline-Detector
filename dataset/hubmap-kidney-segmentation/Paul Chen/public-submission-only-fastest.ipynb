# %%
import numpy as np
import pandas as pd

my_submission_df = pd.read_csv('../input/hubmap-submission-files/submission.csv')
sample_submission_df = pd.read_csv('../input/hubmap-kidney-segmentation/sample_submission.csv')

sample_submission_df.drop(columns=['predicted'], inplace=True)
sample_submission_df = pd.merge(sample_submission_df, my_submission_df, how='left', left_on='id', right_on='id')
 
sample_submission_df.to_csv('submission.csv', index=False)
sample_submission_df
