# %%
# installation of Segmentation Models Pytorch (https://github.com/qubvel/segmentation_models.pytorch)
# Notebook idea: https://www.kaggle.com/matjes/segmentation-models-pytorch-install

# %%
# !rm -rf /kaggle/working/*
# !pip install virtualenv
# !virtualenv /kaggle/temp
# %cd /kaggle/temp
# !bin/pip install -t /kaggle/working segmentation_models_pytorch
