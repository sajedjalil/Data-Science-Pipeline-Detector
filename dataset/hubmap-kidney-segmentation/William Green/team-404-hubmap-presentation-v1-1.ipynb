# %%
from IPython.display import Image

# %%
Image("../input/posterv1/Slide1.PNG")

# %%
Image("../input/posterv1/Slide2.PNG")

# %%
Image("../input/posterv1/Slide1.1.PNG")

# %%
Image("../input/posterv1/Slide4.PNG")

# %%
Image("../input/posterv1/Slide5.PNG")

# %%
Image("../input/posterv1/Slide6.PNG")

# %%
Image("../input/posterv1/Slide7.PNG")

# %%
Image("../input/posterv1/Slide8.PNG")

# %%
Image("../input/posterv1/Slide9.PNG")

# %%
Image("../input/posterv1/Slide10.PNG")

# %%
Image("../input/posterv1/Slide11.PNG")

# %%
Image("../input/posterv1/Slide12.PNG")

# %%
Image("../input/posterv1/Slide13.PNG")

# %%
Image("../input/posterv1/Slide14.PNG")

# %%
Image("../input/posterv1/Slide15.PNG")
