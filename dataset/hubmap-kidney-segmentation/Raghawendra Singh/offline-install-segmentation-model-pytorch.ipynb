# %% [markdown]
# To download packages for offline installation, please go through following link
#
# https://www.kaggle.com/raghaw/download-segmentation-model-pytorch-packages?scriptVersionId=56700353

# %% [markdown]
# ### Internet of this notebook is disabled to confirm offline installation

# %%
# directory containing required packages
# !ls ../input/download-segmentation-model-pytorch-packages

# %%
# !pip install --no-index --find-links="../input/download-segmentation-model-pytorch-packages" segmentation-models-pytorch

# %%
import segmentation_models_pytorch as smp

# %%
model = smp.Unet( encoder_name="resnet34", encoder_weights=None, in_channels=3, classes=1)

# %%
model
