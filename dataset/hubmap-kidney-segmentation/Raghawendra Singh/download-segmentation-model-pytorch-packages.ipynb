# %% [markdown]
# ### Internet of this notebook should be enabled so that packages can be downloaded

# %%
# download segmentation models with dependencies.
# !pip download segmentation-models-pytorch -d .

# %%
# list all the downloaded packages.
# !ls -l

# %% [markdown]
# ### Remove pytorch and torchvision packages since we don't want to update it.

# %%
# !rm torch*

# %% [markdown]
# ### Segmantation_model_pytorch with required dependencies for offline installation

# %%
# !ls
