# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR08D7rRzrHuFwW4TVDDGMyuEag8bew4DEPiA-FuMTTD6ZLFk4c',width=400,height=400)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# ovh.com

# %% [markdown]
# #Solidarity and cooperation must define the battle against COVID-19  by Poonam Khetrapal Singh
# World Health Organization’s regional director
#
# The approach of the World Health Organization Southeast Asia region to health security is guided by a simple yet powerful logic: When we work together we are protected together. Never has this been more important. The outbreak of COVID-19 is a public health emergency of international concern (PHEIC) and provides significant challenges to countries in the region. We must stand together and work as one to face the outbreak down.
#
# Countries must continue to report and share information on suspected cases early and provide detailed reports on confirmed cases.
#
# Solidarity must define our onward battle. The benefits are many.
#
# First, by working together countries promote efficiency. Each country in the region has different strengths and faces different risks. By continuing to share knowledge and resources, countries will build surge capacity – a crucial asset that will help them prepare for all possibilities, including community transmission. The latest information suggests that the virus may be more transmissible than early data suggested. All countries must strengthen their readiness to respond.
#
# Second, by working together countries promote trust. Trust between countries allows national decision-makers to be confident that the public health measures they take are based on sound information, reflect ground realities and anticipate emerging trends. Measures that are unnecessary can spread panic and fear. Measures that are inadequate can spread virus and disease. As the outbreak unfolds, it is imperative that countries adopt and sequence their actions to protect the most vulnerable first. They must allocate resources accordingly.
#
# Third, by working together countries promote knowledge. Detailed case reporting will help us all learn more about COVID-19 and how it can be prevented and treated. Earlier this month, the WHO gathered 400 of the world’s leading experts for discussions on top research and innovation priorities. Based on those discussions, the WHO is developing a `research and innovation roadmap` that will help scientists and donors across the world strengthen our medical armory.
#
# We must all look out for one another. An important way to do this is by accessing and sharing high-quality information that empowers our friends, families, colleagues and communities to stay healthy. Regular hand-washing, coughing or sneezing into one’s elbow, avoiding close contact with people with flu-like symptoms, and thoroughly cooking meat and eggs are all highly recommended for day-to-day protection against a range of germs.
#
# If you are traveling, an alcohol-based hand rub will help keep your hands clean. Limiting contact between your hands and eyes, nose and mouth will reduce transmission pathways. Avoiding close contact with people suffering from a fever or cough is always a good idea, as is informing crew members if you become sick.
#
# ommunity concerns related to COVID-19 are understandable. There is much that we do not yet know but that we are working to find out. As we learn more, the WHO will continue to provide member states and the public with high-quality information through regular situation reports and through our social media accounts. I encourage you to access them regularly, in addition to the advice of your national health authority.
#
# We must be very clear: False rumors and misinformation can facilitate transmission and cost lives. They are our common enemy. The WHO is working with member states and partners region-wide to bust myths, promote knowledge and empower communities. As we continue to tackle the outbreak, I urge all people in the Southeast Asia region to adopt what has become a rallying point across the world: facts, not fear; rationality, not rumors; solidarity, not stigma.
#
# The WHO is committed to ensuring solidarity and cooperation continue to be among the region’s key weapons in the battle against COVID-19. For many years these values have been built into the region’s health security architecture, from the Southeast Asia Regional Health Emergency Fund to the Delhi Declaration on Emergency Preparedness and Response. Though COVID-19 may very well test that architecture, its foundations are solid and must now meet the task at hand.
#
# Together we must fight. Together we must win. https://www.thejakartapost.com/academia/2020/02/27/solidarity-and-cooperation-must-define-the-battle-against-covid-19.html

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np 
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown
import plotly.graph_objs as go
import plotly.offline as py
from plotly.subplots import make_subplots
import plotly.express as px
from plotly.offline import init_notebook_mode, plot, iplot, download_plotlyjs
import plotly as ply
import pycountry
import folium 
from folium import plugins
import json

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSF_5D1Efd4eaN-tkSkXr56qr_dyVT0B4YKGZvMmaFuomRLK25n',width=400,height=400)

# %% [markdown]
# youtube.com

# %%
train = pd.read_csv('/kaggle/input/covid19-local-us-ca-forecasting-week-1/ca_train.csv')
test = pd.read_csv('/kaggle/input/covid19-local-us-ca-forecasting-week-1/ca_test.csv')
submission = pd.read_csv('/kaggle/input/covid19-local-us-ca-forecasting-week-1/ca_submission.csv')

# %%
train.head()

# %%
train = train.rename(columns={'Province/State':'CA', 'Country/Region': 'US'})

# %% [markdown]
# #Codes from Saurav Mishra https://www.kaggle.com/sauravmishra1710/covid-19-sars-cov-2-a-geographical-analysis/notebook

# %%
# Utility Functions

'''Display markdown formatted output like bold, italic bold etc.'''
def formatted_text(string):
    display(Markdown(string))

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSTN8pYdGdR4yDpcrT1XfUHQYuRLVrwNb-imG1WOSrDAE_33Kcy',width=400,height=400)

# %% [markdown]
# portugali.news.eu - Let's find solutions faster than the virus spreads

# %%
strDate = train['Date'][-1:].astype('str')
year = int(strDate.values[0].split('-')[0])
month = int(strDate.values[0].split('-')[1])
day = int(strDate.values[0].split('-')[2].split()[0])

formatted_text('***Last reported case date-time***')
print(strDate)
print(year)
print(month)
print(strDate.values[0].split('-')[2].split())

# %%
CaWiseData = pd.DataFrame(train.groupby('US')['ConfirmedCases', 'Fatalities'].sum())
CaWiseData['US'] = CaWiseData.index
CaWiseData.index = np.arange(1, len(train.US.unique().tolist())+1)
CaWiseData = CaWiseData[['US','ConfirmedCases', 'Fatalities']]

formatted_text('***California wise numbers of ''ConfirmedCases'', ''Fatalities'' Cases***')

#CaWiseData = pd.merge(latest_covid_19_data[['Country', 'Lat','Long']], CountryWiseData, on='Country')

#CaWiseData = CaWiseData.drop_duplicates(subset = "Country", keep = 'first', inplace = True) 

CaWiseData

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTqhUPxecYgNdw61JnIz0q3Iv7Fw4AF0YzsP3fUMWwLwveEGTE_',width=400,height=400)

# %% [markdown]
# pmnewsnigeria.com

# %%
# Import the WORLD Latitute Longitude Data

#ca_Lat_Long_coordinates = pd.read_csv('/kaggle/input/china-geo-json/china_geojson.json')
#ca_Lat_Long_coordinates.head()

# %%
# Merge California co-coordinates above to the California wise data we created.

#CaWiseData = pd.merge(ca_Lat_Long_coordinates, CaWiseData, on='US')
#CaWiseData.head()

# %%
train["US"] = "US" # in order to have a single root node

fig1 = px.treemap(train.sort_values(by='ConfirmedCases', ascending=False).reset_index(drop=True), 
                 path=["US", "CA"], values="ConfirmedCases", title='Number of Confirmed Cases in California',
                 color_discrete_sequence = px.colors.qualitative.Prism, hover_data=["ConfirmedCases"])

fig1.data[0].textinfo = 'label+text+value+percent entry'
py.offline.iplot(fig1)

fig2 = px.treemap(train.sort_values(by='Fatalities', ascending=False).reset_index(drop=True), 
                 path=["US", "CA"], values="Fatalities", title='Number of Fatalities Reported in California',
                 color_discrete_sequence = px.colors.qualitative.Prism, hover_data=["Fatalities"])

fig2.data[0].textinfo = 'label+text+value+percent entry'
py.offline.iplot(fig2)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTN3SLSTG5mufNVP0BtyNY6RsbifXgmp_aSNlRCqH8vs-3tsUgg',width=400,height=400)

# %% [markdown]
# #Corona Crisis: How digital solutions must relieve doctors and nursing staff in further crises. By Mona Ciotta
#
# Overworked, understaffed & psychologically emaciated doctors and nurses are fighting on the front line against the spread of Covid-19.
#
# There is a lack of basic digital solutions in the everyday work of clinical staff. Hospital software, IT infrastructure, appointment scheduling, communication, organization and patient visits and education — all these areas in the hospital have not experienced any real innovation for years and lack modern tools.
#
# New digital solutions for voice, video and text communication between doctors within health institutions must be created as well as solutions for more effective doctor-patient communication. To achieve this, IT infrastructures must be created to enable this type of communication and organization. Hospital information systems have to be state-of-the-art and actually work intelligently and automatically with physicians instead of just being operated by them. Processes must be automated in such a way that they significantly increase support for clinical staff. Here are just some examples of how doctors and nurses could be relieved:
#
# Automatic voice recording for doctors to save them time
#
# Digital patient registration with comprehensive information on their health status
#
# Direct communication via secured messaging platforms for doctors to discuss issues and questions regarding the patient’s treatment process
#
# Intelligent hospital information systems that actively communicate with doctors and nurses
#
# Effective Patient-Doctor communication tools in hospitals
#
# Tele-health platforms to get help faster, save time and not get sicker by sitting at a doctors office with other ill patients
#
# Video education of patients to save time for doctors
#
# When we see how hospital staff are suffering from this crisis and still push themselves to the limit, we are even more ambitious in our efforts to make the lives of these very health heroes easier and faster with digital solutions.
# https://medium.com/medudoc/corona-crisis-how-digital-solutions-must-relieve-doctors-and-nursing-staff-in-further-crises-5cbd02d54c8c

# %%
#CaMap = folium.Map(location=[0,0], zoom_start=1.5,tiles='cartodbpositron')

#formatted_text('***Click on the pin to veiw details stats***')

#for Lat, Long, ConfirmedCases, Fatalities, US in zip(CaWiseData['Lat'],
 #                                                    CaWiseData['Long'],
 #                                                    CaWiseData['ConfirmedCases'],
  #                                                   CaWiseData['Fatalities'],
   #                                                  CaWiseData['US']):
#
 #   if (Fatalities == 0):
  #      folium.Marker(location=[lat, long]
   #                 , popup = ('<strong>nCov Numbers:</strong> ' + '<br>' + 
    #                           '<strong>US:</strong> ' + str(US) + '<br>'
     #                          '<strong>ConfirmedCases:</strong> ' + str(int(ConfirmedCases)) + '<br>'
      #                         '<strong>Fatalities:</strong> ' + str(int(Fatalities)) + '<br>')
       #                       
        #            , icon=folium.Icon(color='darkblue',icon='info-sign'), color='rgb(55, 83, 109)'
         #           , tooltip = str(country), fill_color='rgb(55, 83, 109)').add_to(CaMap)

    #else:
     #   folium.Marker(location=[Lat, Long]
      #              , popup = ('<strong>nCov Numbers:</strong> ' + '<br>' + 
       #                        '<strong>US:</strong> ' + str(US) + '<br>'
        #                       '<strong>ConfirmedCases:</strong> ' + str(int(ConfirmedCases)) + '<br>'
         #                      '<strong>Fatalities:</strong> ' + str(int(Fatalities)) + '<br>')
          #                     
           #         , icon=folium.Icon(color='red', icon='info-sign'), color='rgb(26, 118, 255)'
            #        , tooltip = str(US), fill_color='rgb(26, 118, 255)').add_to(CaMap)
        
#CaMap

# %% [markdown]
# I intended to make a Folium Map. I couldn't.

# %% [markdown]
# #Codes from Tawej https://www.kaggle.com/tawejssh/covid-19

# %%
# List of unique Date
dates = train['Date'].unique()
dates

# %%
#Let's visualise the evolution of results
evolution = train.groupby('Date').sum()[['ConfirmedCases','Fatalities']]
#evolution['Expiration Rate'] = (evolution['Expired'] / evolution['Cumulative']) * 100
#evolution['Discharging Rate'] = (evolution['Discharged'] / evolution['Cumulative']) * 100
evolution.head()

# %%
plt.figure(figsize=(20,7))
plt.plot(evolution['ConfirmedCases'], label='ConfirmedCases')
plt.plot(evolution['Fatalities'], label='Fatalities')
plt.legend()
#plt.grid()
plt.title('Evolution of COVID-19 California')
plt.xticks(evolution.index,rotation=45)
plt.xlabel('Date')
plt.ylabel('Number of Patients')
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://ogimg.infoglobo.com.br/mundo/24316970-8cd-08c/FT1086A/652/x87570270_Slovak-police-officers-unload-a-government-Airbus-319-shortly-after-it-arrived-from-Bei.jpg.pagespeed.ic.yoN1RppEmP.jpg',width=400,height=400)

# %% [markdown]
# Image: JOE KLAMAR / AFP - Slovak police officers unload testing Kits and medical masks given by China Government.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTF7n3IcIym70MhGCtuJEDZiVkhO8u7ijRjZlzyoxiqXUKss6se',width=400,height=400)

# %% [markdown]
# medium.com

# %% [markdown]
# #Codes from https://www.kaggle.com/thorgodofthunder/house-price-regression-eda-model

# %%
cat = []
num = []
for col in train.columns:
    if train[col].dtype=='O':
        cat.append(col)
    else:
        num.append(col)  
        
        
num

# %%
plt.style.use('dark_background')
for col in train[num].drop(['ConfirmedCases'],axis=1):
    plt.figure(figsize=(8,5))
    plt.plot(train[col].value_counts(),color='Blue')
    plt.xlabel(col)
    plt.ylabel('ConfirmedCases')
    plt.tight_layout()
    plt.show()

# %%
train.corr()
plt.figure(figsize=(10,4))
sns.heatmap(train.corr(),annot=True,cmap='RdGy_r')
plt.show()

# %%
train.plot.area(y=['ConfirmedCases','Fatalities'],alpha=0.4,figsize=(12, 6));

# %%
sns.barplot(x=train['ConfirmedCases'].value_counts().index,y=train['ConfirmedCases'].value_counts())

# %%
plt.figure(figsize=(18,9))
sns.factorplot(x=col,y='ConfirmedCases',data=train)
plt.tight_layout()
plt.show()

# %%
for col in train.columns:
    plt.figure(figsize=(18,9))
    sns.barplot(x=col,y='ConfirmedCases',data=train)
    sns.pointplot(x=col,y='ConfirmedCases',data=train,color='Black')
    plt.tight_layout()
    plt.show()

# %%
sns.pairplot(train)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRvxgN4olefDSxK-HAMZMAsR_KhwZNoDc4UvK3EAKQ7JmQ_aFTu',width=400,height=400)

# %% [markdown]
# twitter.com

# %% [markdown]
# #Codes from Paul Mooney https://www.kaggle.com/paultimothymooney/collections-of-paintings-from-50-artists/data

# %%
import numpy as np
import pandas as pd 
import cv2
from fastai.vision import *
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import seaborn as sns
import os
import shutil
from glob import glob
# %matplotlib inline
# !pip freeze > '../working/dockerimage_snapshot.txt'

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTEpQ_A9CAn4RtS753v3YEEHrs2S2sZbmiKB-9adNGtfYRXyZKm',width=400,height=400)

# %% [markdown]
# youtube.com

# %%
def makeWordCloud(df,column,numWords):
    topic_words = [ z.lower() for y in
                       [ x.split() for x in df[column] if isinstance(x, str)]
                       for z in y]
    word_count_dict = dict(Counter(topic_words))
    popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
    popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
    word_string=str(popular_words_nonstop)
    wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white',
                          max_words=numWords,
                          width=1000,height=1000,
                         ).generate(word_string)
    plt.clf()
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

def plotImages(artist,directory):
    print(artist)
    multipleImages = glob(directory)
    plt.rcParams['figure.figsize'] = (15, 15)
    plt.subplots_adjust(wspace=0, hspace=0)
    i_ = 0
    for l in multipleImages[:25]:
        im = cv2.imread(l)
        im = cv2.resize(im, (128, 128)) 
        plt.subplot(5, 5, i_+1) #.set_title(l)
        plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB)); plt.axis('off')
        i_ += 1

np.random.seed(7)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSVC7u027PqXxj2vbDhRXqSmgujM3QfkeLuR9D2_E9tPvQyrfRf',width=400,height=400)

# %% [markdown]
# popularresistance.org.

# %% [markdown]
# #Without global trust and solidarity, we will not be able to stop the coronavirus epidemic.
#
# #Xenophobia, isolationism and distrust now characterize most of the international system.
#
# #And we will likely see more of these epidemics in the future. But every crisis is also an opportunity.
#
# We hope that the current epidemic will help humanity to realize the grave danger posed by global disunity.
# Words from Yuval Noah Harari https://oglobo.globo.com/cultura/yuval-noah-harari-antidoto-para-epidemia-nao-a-segregacao-mas-cooperacao-24324017

# %%
print(os.listdir("../input/medical-masks-dataset/images/"))

# %%
img_dir='../input/medical-masks-dataset/images'
path=Path(img_dir)
data = ImageDataBunch.from_folder(path, train=".", 
                                  valid_pct=0.2,
                                  ds_tfms=get_transforms(do_flip=False,flip_vert=False, max_rotate=0,max_lighting=0.3),
                                  size=299,bs=64, 
                                  num_workers=0).normalize(imagenet_stats)
print(f'Classes: \n {data.classes}')
data.show_batch(rows=8, figsize=(40,40))

# %% [markdown]
# Angela Merkel, German Federal Chancellor. asks the population to reduce social contacts due to the coronavirus: "It is serious. Take it seriously, you too".
# #Viruses test SOLIDARITY IN GERMAN SOCIETY, She says.

# %% [markdown]
# According to Miguel Srougi, the great social consequence is that people will learn that
#
#  #SOLIDARITY and compassion are very important within any society.
#
# We can no longer be impassive when a hill falls and simple people die, who don't have the capacity to survive with dignity, who live in these places due to the absolute lack of option. I think the coronavirus will unite society and make people a little more supportive and compassionate. Right now the strong are threatened, the poor will die more, but the rich will also die.
# https://oglobo.globo.com/sociedade/coronavirus/coronavirus-pobres-morrerao-nas-portas-dos-hospitais-diz-professor-da-usp-24321941

# %% [markdown]
# Our scientists know the ruins of what already existed and have access to the remains of the beings that once inhabited the planet. But they consult these clues as if they know in advance what they will discover, a dead and buried past, which brings no hope for humanity.
#
# They research and consult only the events and beings that serve to explain our existence so far, what we are and need to be, within an immutable condition supported by religions and ideologies.They don't care what it could have been, with any utopia of the past.
#
# They are interested only in what is curious from the point of view of humanity, without any modesty towards ourselves. With deep disinterest for those who lived with us, the rest of the planet we can call Nature. https://oglobo.globo.com/opiniao/o-lixo-nas-urnas-24321401

# %% [markdown]
# #Together we must fight. Together we must win.  Plot.Solidarity

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQEk72PSLvWHFkYRV86Yv_yZOav9nwyU6mPtfpJVZQLiy_TzTR3',width=400,height=400)

# %% [markdown]
# twitter.com

# %% [markdown]
# Sometimes we make just what we can, not what we want.
#
# Kaggle Notebook Runner: Maríia Prata  @mpwolke
