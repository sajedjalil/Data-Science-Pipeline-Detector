# %% [markdown]
# # Import packages

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
import pickle
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *

import zipfile 
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Load dataframe test

# %%
test = pd.read_csv('../input/histopathologic-cancer-detection/sample_submission.csv')

print('Test Set Size:', test.shape)

# %%
test.head()

# %%
#The id in the csv file does not have .tif extension, therefore we need to add it here.
test['id'] = test['id'].apply(lambda x:f'{x}.tif')
test.head()

# %% [markdown]
# # Extract images

# %%
test_path = "../input/histopathologic-cancer-detection/test"
print('Test Images:', len(os.listdir(test_path)))

# %% [markdown]
# # Data generator

# %%
BATCH_SIZE = 64

test_datagen = ImageDataGenerator(rescale=1/255)

test_loader = test_datagen.flow_from_dataframe(
    dataframe = test,
    directory = test_path,
    x_col = 'id',
    batch_size = BATCH_SIZE,
    shuffle = False,
    class_mode = None,
    target_size = (96,96)
)

# %% [markdown]
# # Load label

# %%
cnn = keras.models.load_model('../input/cancer-detection-model-transfer-learning-1121/cancer_model_v00.h5')
cnn.summary()

# %% [markdown]
# # Test predictions

# %%
test_probs = cnn.predict(test_loader)
print(test_probs.shape)

# %%
test_pred = np.argmax(test_probs, axis=1)
print(test_pred[:10])

# %% [markdown]
# # Prepare submission

# %%
submission = pd.read_csv('../input/histopathologic-cancer-detection/sample_submission.csv')
submission.head()

# %%
submission.label = test_pred
submission.head()

# %%
submission.to_csv('submissionTL.csv', header=True, index=False)
