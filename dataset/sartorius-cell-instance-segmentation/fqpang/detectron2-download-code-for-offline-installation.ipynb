# %% [markdown]
# ![logo](https://raw.githubusercontent.com/facebookresearch/detectron2/main/.github/Detectron2-Logo-Horz.svg)

# %% [markdown]
# Fetch the repository and prepare for use in other notebooks (offline).

# %%
# !git clone https://github.com/facebookresearch/detectron2.git

# %%
# %cd detectron2

# %%
# !pip install -U .

# %%
# %cd /kaggle/working

# %%
# %%writefile requirements.txt
# pycocotools==2.0.2
# fvcore==0.1.5.post20211019
# omegaconf==2.1.1
# hydra-core==1.1.1
# black==21.4b2
# iopath==0.1.9
# antlr4-python3-runtime==4.8

# %%
# !pip wheel --wheel-dir=./wheels_cache -r requirements.txt

# %%
# !ls -al wheels_cache
