# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# Python program to read
# json file
 
 
#import json
 
# Opening JSON file
#f = open('/kaggle/input/sartorius-cell-instance-segmentation/LIVECell_dataset_2021/annotations/LIVECell_single_cells/skov3/livecell_skov3_test.json')
 
# returns JSON object as
# a dictionary
#data = json.load(f) 
# Closing file
#f.close()
#print(json.dumps(data, indent=4))

# %%
df=pd.read_csv("/kaggle/input/sartorius-cell-instance-segmentation/train.csv")
df.head()

# %%
from PIL import Image
import glob
image_list = []
url=/kaggle/input/sartorius-cell-instance-segmentation/LIVECell_dataset_2021/images/livecell_test_images/BT474/(?i)_4d04h00m*.tif
for filename in glob.glob('url'): #assuming gif
    im=Image.open(filename)
    image_list.append(im)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('/kaggle/input/sartorius-cell-instance-segmentation/train_semi_supervised/astro[hippo]_G2-3_Vessel-361_2020-09-14_13h00m00s_Ph_4.png')
# Output Images
plt.imshow(img)

# %%
df.info()

# %%
data=df.drop(["plate_time"],axis=1)
data.head()

# %%
df.cell_type.unique()

# %%
df.plate_time.unique()

# %%
pip install imutils

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('/kaggle/input/sartorius-cell-instance-segmentation/LIVECell_dataset_2021/images/livecell_test_images/BT474/BT474_Phase_D3_1_04d04h00m_2.tif')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(gray,0,255,cv.THRESH_BINARY_INV+cv.THRESH_OTSU)
plt.imshow(img)

# %%
df.sample_date.unique()

# %%
df.id.unique()

# %%
df.elapsed_timedelta.unique()

# %%
df.height.unique()
