# %% [markdown]
# <img src="https://ucfai.org/data-science/fa19/2019-10-24-nfl-deep-dive/nfl-deep-dive/banner.png">
#
# <div class="col-12">
#     <span class="btn btn-success btn-block">
#         Meeting in-person? Have you signed in?
#     </span>
# </div>
#
# <div class="col-12">
#     <h1> Big Data Bowl Deep Dive </h1>
#     <hr>
# </div>
#
# <div style="line-height: 2em;">
#     <p>by:
#         <strong> Alec Kerrigan</strong>
#         (<a href="https://github.com/ahkerrigan">@ahkerrigan</a>)
#      on 2019-10-24</p>
# </div>
