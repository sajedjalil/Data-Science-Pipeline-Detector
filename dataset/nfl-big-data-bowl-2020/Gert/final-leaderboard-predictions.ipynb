# %%
from io import StringIO
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
# input data:
# public lb and week1 based on https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/120884#latest-691853
# raw download of current (week2) lb data

doc_Felipe_Loque = ['Team Name,Score Public LB,Rank1,Score 2019-12-06,Rank2', 'Deep Snappers,0.01248,5,0.01122,1', 'Ppo,0.01263,9,0.01127,2', 'Deimon Devil Bats,0.01245,4,0.0113,3', 'vinmuk,0.01268,12,0.0113,4', 'Yu,0.01282,22,0.01134,5', 'hmdhmd,0.01277,17,0.01136,6', 'Deadline Fighter,0.01239,3,0.01137,7', 'Gert,0.01282,23,0.01139,8', 'The Last Run,0.01276,16,0.0114,9', "we don't know the rules,0.01256,7,0.01143,10", 'Go Browns! Go Pats!,0.01265,10,0.01144,11', 'Establish The Run,0.01268,14,0.01144,12', 'R1SEä½•æ´›æ´›,0.01279,19,0.01145,13', "Laplace's Demon,0.01267,11,0.01146,14", 'Zoltan,0.01272,15,0.01147,15', 'AlexanderGeiger,0.01291,25,0.01151,16', 'Beagle Kagglers,0.01279,20,0.01151,17', 'mrkmakr,0.01261,8,0.01151,18', "dot dash â€¢â\x81ƒ don't crash,0.01297,32,0.01153,19", 'ã‚µãƒ³ã‚°ãƒ¦ãƒ¼,0.01278,18,0.01153,20', 'Sleepers,0.0128,21,0.01156,21', 'mark4h,0.01313,43,0.01159,22', "You Sanu'ze You Lose,0.01295,30,0.01165,23", 'nyanp,0.01268,13,0.01166,24', 'agenlu,0.01292,27,0.01166,25', 'F.Y.R.J.,0.01297,31,0.01166,26', 'Arturo Garcia,0.01291,26,0.01167,27', 'charlie_s,0.01293,28,0.01168,28', 'nakano,0.01302,33,0.0117,29', 'Hongchen Luo,0.01305,34,0.01171,30', 'ln,0.01308,37,0.01172,31', 'adityasinha,0.01311,41,0.01173,32', 'go_bears,0.01322,58,0.01174,33', 'nrsgwr,0.01309,38,0.01175,34', 'Kaz-U,0.01319,48,0.01176,35', 'yoda and overfit padawans (PS: Michigan sucks),0.01232,2,0.01176,36', 'Stefan C,0.0132,52,0.01177,37', 'Chris R,0.01323,60,0.01178,38', 'vroom,0.01325,61,0.01179,39', 'çœ‹ä½ å¿ƒæƒ…...,0.01321,56,0.01181,40', 'RobertLutz,0.01313,44,0.01182,41', 'Anton Lytyakov,0.0131,39,0.01182,42', 'Griffin Series,0.01318,47,0.01183,43', 'Daizu,0.01321,57,0.01183,44', 'L&W,0.01356,205,0.01187,45', 'AkiraIshikawa,0.01329,68,0.01187,46', 'Shun_PI + colun,0.01289,24,0.01188,47', 'RunFastRunFree,0.01307,36,0.01189,48', 'If Eternity Should Fail,0.0132,51,0.01191,49', 'Michael Bian,0.01321,53,0.01193,50', 'Go Rams ðŸ\x90\x8f,0.0133,73,0.01195,51', 'MapleTriskit,0.01335,84,0.01195,52', 'Your Ad Could Be Here,0.01327,64,0.01195,53', 'Kohei TANAKA,0.01321,55,0.01196,54', 'fugusuki,0.01323,59,0.01196,55', 'JEP,0.01327,63,0.01197,56', 'minyus,0.01315,45,0.01198,57', 'Tverdov Konstantin,0.01332,75,0.01199,58', 'spam_filter,0.0133,72,0.012,59', '"@NFLmath, Blake & Serigne",0.01321,54,0.012,60', 'toronto_ds,0.01337,96,0.012,61', 'Lindada,0.01341,112,0.01204,62', 'Wong,0.01338,97,0.01204,63', 'Go Cowboys ðŸ¤,0.01346,137,0.01206,64', 'Jeffrey Chung,0.01336,92,0.01206,65', 'Mickey,0.01328,66,0.01206,66', 'Yupeng Li,0.01355,184,0.01206,67', 'Ian M,0.01344,127,0.01207,68', 'Adam Suwik,0.01338,101,0.01208,69', '[ods.ai] Mihail Parushkin,0.01328,65,0.01208,70', 'KrisztianSz,0.01332,74,0.01208,71', 'jyacky,0.01326,62,0.01208,72', 'DB sports,0.01341,114,0.01209,73', 'Ralf,0.01341,111,0.0121,74', 'SICS,0.01329,70,0.0121,75', 'Nico Higgs,0.01335,85,0.0121,76', 'PhysicsAndFootball,0.01336,88,0.0121,77', 'akira,0.0132,50,0.0121,78', 'Nilotpal Das,0.01329,69,0.01214,79', 'willyboy1,0.01333,78,0.01214,80', 'authman,0.01343,123,0.01215,81', 'Tomonori Masui,0.01333,77,0.01217,82', 'DeliveryClub,0.01339,102,0.01217,83', 'Aigu,0.01354,181,0.01217,84', 'Eyeshield 21,0.01334,80,0.01218,85', 'Piotr Nagrodkiewicz,0.01341,109,0.01219,86', 'Kyle Wang,0.01341,113,0.01219,87', 'hrunic,0.01336,91,0.01219,88', 'Keith SZE,0.01334,81,0.01219,89', 'two boys,0.01345,128,0.01219,90', 'pBuoro,0.01344,126,0.01219,91', 'Arateris,0.01368,958,0.01219,92', 'NFL = No Free Lunch,0.01333,76,0.0122,93', 'Vanishing Error Rate,0.01345,130,0.0122,94', 'small tiger,0.01344,124,0.01221,95', 'fwj7,0.01343,122,0.01221,96', 'Si Yu,0.01336,89,0.01221,97', 'fakeplastictrees,0.01343,119,0.01222,98', 'tdefoin,0.01346,138,0.01222,99', 'IEEE buddies,0.01354,182,0.01222,100', '@ChiefsAnalytics/@LeeSharpeNFL,0.01339,103,0.01223,101', 'KoitoU,0.01352,172,0.01223,102', 'Coffee Club,0.01342,116,0.01223,103', 'Eric Beckwith,0.01349,147,0.01224,104', 'Ryu Tomita,0.01358,223,0.01225,105', 'Smash,0.01346,134,0.01225,106', 'tamo123,0.01337,94,0.01225,107', 'Yujiro Kita,0.0134,105,0.01225,108', 'dog and chick,0.01336,93,0.01226,109', 'Ryuichi Ishikawa,0.01348,146,0.01226,110', 'Scott Taber,0.01345,131,0.01226,111', 'ä¹”ä¸–å\x90‰,0.01347,141,0.01226,112', 'JB,0.01346,136,0.01226,113', 'My Odds Are Stacked,0.01351,153,0.01228,114', 'Royz,0.01354,183,0.01228,115', '[ods.ai] Learn2Play,0.01355,186,0.01228,116', 'Arrested Development,0.01348,144,0.01228,117', 'é…’ã\x81¨å’Œã\x81¿ã\x81¨è‚‰ã\x81¨é‡Žè\x8fœ,0.01337,95,0.01228,118', 'takuoko,0.01356,206,0.01228,119', 'futbol klub,0.01344,125,0.01228,120', 'cjwh,0.01338,98,0.01229,121', 'lurker,0.01352,165,0.01229,122', 'Lisz,0.01352,164,0.01229,123', 'Rigel,0.0135,151,0.01229,124', 'Jean-Philippe MARY,0.01359,235,0.0123,125', 'RIStina_aguilera,0.01345,133,0.0123,126', 'denis,0.01351,162,0.0123,127', 'Predicting like Tony Romo,0.01329,67,0.0123,128', 'pao,0.01374,1061,0.0123,129', 'Ian Astalosh,0.0135,152,0.0123,130', 'Bluering Data Octopus,0.01358,224,0.0123,131', 'seba,0.01354,177,0.01231,132', 'Dowan_mao,0.0136,245,0.01231,133', 'Crossbell,0.01356,196,0.01231,134', 'Kaz,0.01351,156,0.01231,135', 'logreg x 199,0.01345,129,0.01231,136', 'Dan Emery,0.01343,118,0.01231,137', 'NFL,0.01357,219,0.01231,138', 'mohamed,0.01359,242,0.01232,139', 'K-hime,0.01359,238,0.01232,140', 'copypaste,0.01351,161,0.01232,141', 'steubk,0.01357,217,0.01232,142', "Bagel's Kaggle,0.01355,187,0.01232,143", 'Bernd Allmendinger,0.01347,139,0.01232,144', '369,0.01355,191,0.01233,145', 'SoulSk8rs4Life,0.01374,1075,0.01233,146', 'Ryota,0.01362,438,0.01233,147', 'shimaw28,0.01351,159,0.01233,148', 'Yuya.O,0.01355,194,0.01233,149', 'ZJU squad,0.01339,104,0.01233,150', 'Nikita,0.01361,260,0.01233,151', 'Alvaro,0.01358,228,0.01233,152', 'Daic,0.01361,290,0.01233,153', 'Sujeeth S,0.01391,1230,0.01233,154', 'thomas kern,0.01359,241,0.01233,155', 'wychwood,0.01349,148,0.01233,156', 'kehai,0.01357,208,0.01234,157', 'Alexander Kireev,0.01346,135,0.01234,158', 'Prashant Kikani,0.0136,257,0.01234,159', "Ryan O'Hara,0.01368,929,0.01234,160", 'USC ISE Analytics!,0.01352,166,0.01234,161', 'JesseFischer,0.01354,178,0.01234,162', 'Back-propagating the Backfield,0.0136,259,0.01234,163', 'Yuvraj,0.01357,211,0.01235,164', 'Shashi Prakash Tripathi,0.0136,252,0.01235,165', 'The ARMADA,0.01343,117,0.01235,166', 'Leonardo Ribeiro,0.01354,179,0.01235,167', 'Eric Freeman,0.01338,99,0.01235,168', 'YapaGenou,0.0135,150,0.01235,169', 'iwashi,0.01369,998,0.01236,170', 'InJu Kim,0.01361,279,0.01236,171', 'NFL Masters,0.01361,264,0.01236,172', 'CAI DeSI Drift,0.01357,218,0.01236,173', 'taichi,0.01361,262,0.01236,174', 'YQ_Wu,0.01357,216,0.01236,175', 'TJ Klein,0.01357,210,0.01236,176', 'SkyReaper,0.01359,237,0.01236,177', 'TSA,0.0136,255,0.01236,178', 'Subin An,0.01366,872,0.01236,179', 'b15d030,0.01361,283,0.01236,180', 'David Prakash,0.01362,424,0.01237,181', 'Iary Joseph,0.01368,931,0.01237,182', 'Dmitriy Guller,0.0137,1027,0.01237,183', '"Yu,Hai",0.01363,617,0.01237,184', 'suuuuuu,0.01358,226,0.01237,185', 'Yimin Nie,0.01358,225,0.01237,186', 'ClÃ©ment Fauchereau,0.01368,924,0.01237,187', 'whoami,0.01365,843,0.01237,188', 'Janos,0.01361,263,0.01237,189', 'golden_wind,0.01363,682,0.01237,190', 'Anoop,0.01361,261,0.01237,191', 'u++,0.01362,448,0.01237,192', 'juju,0.01352,170,0.01237,193', 'Soshi,0.01353,176,0.01237,194', 'wot,0.01361,286,0.01237,195', 'Arjun Subedi,0.01362,366,0.01237,196', 'Vadik,0.01362,296,0.01238,197', 'wangzhaoxu,0.01367,891,0.01238,198', 'Avinash Barnwal,0.01362,525,0.01238,199', 'New Paltz,0.0136,258,0.01238,200', 'Summers,0.0136,253,0.01238,201', 'GOSS,0.01362,378,0.01238,202', 'wxs123,0.01367,907,0.01238,203', 'ishio,0.01351,158,0.01238,204', 'Lain,0.01368,957,0.01238,205', 'Oregin,0.01366,868,0.01238,206', 'Dhruuv Agarwal,0.01369,993,0.01238,207', 'RyanCaldwell,0.01371,1037,0.01238,208', 'Kishore M,0.01363,703,0.01238,209', 'Yosuke Ishiguro,0.01367,906,0.01238,210', 'Pavel Pleskov,0.01362,455,0.01238,211', 'gaosq0604,0.01356,207,0.01238,212', 'duvallwh,0.01366,863,0.01238,213', 'Laffaye,0.01357,212,0.01238,214', 'Elahi,0.01362,499,0.01238,215', 'NoSaints,0.01363,653,0.01238,216', 'octaddust,0.01357,209,0.01238,217', 'Thomas Novitsky,0.01368,949,0.01238,218', 'FIrst blood,0.01361,270,0.01238,219', 'shyjin,0.01365,838,0.01239,220', 'Humanitis,0.01367,889,0.01239,221', 'Yusaku Muroya,0.01368,932,0.01239,222', 'Alex M,0.01362,394,0.01239,223', 'rockyalan,0.01368,942,0.01239,224', 'KolawoleTajudeen,0.01367,910,0.01239,225', 'TY.Yang,0.01362,370,0.01239,226', 'KeepLearning,0.0137,1010,0.01239,227', 'Ruichuan Wong,0.01369,977,0.01239,228', 'xffj,0.01363,722,0.01239,229', 'smartbean,0.01363,724,0.01239,230', 'pezlogd,0.01366,852,0.01239,231', 'tcash21,0.01369,988,0.01239,232', 'wittmaan,0.01363,727,0.01239,233', 'ironZinc,0.01358,220,0.01239,234', 'TracyZ,0.01356,204,0.01239,235', 'Sahil Malhotra,0.01357,213,0.01239,236', 'NFL Academy,0.01356,202,0.01239,237', 'Alexander,0.01366,879,0.01239,238', 'Akira Nakamura,0.01356,197,0.01239,239', 'Muhammad Farrel Mahendra,0.01374,1066,0.01239,240', 'Dacian,0.01363,552,0.01239,241', 'Rzeznik,0.01347,140,0.01239,242', 'Kamal Chhirang,0.01369,1004,0.0124,243', 'Timothee Henry,0.01371,1030,0.0124,244', 'Okubo Katsumi,0.01369,981,0.0124,245', 'Jinbao,0.0137,1005,0.0124,246', 'QuOx,0.01366,858,0.0124,247', 'Lights,0.01364,807,0.0124,248', 'Katya Gordeeva,0.01367,909,0.0124,249', '1999,0.01362,386,0.0124,250', 'Kien. Y. Knot,0.01364,816,0.0124,251', 'Wei-ting Chiu,0.01362,361,0.0124,252', 'pea98258,0.01362,510,0.0124,253', 'Ruslan Talipov,0.01363,568,0.0124,254', 'Andrew Shevelev,0.01367,886,0.0124,255', 'newhand,0.0137,1019,0.0124,256', 'kojimar,0.01367,884,0.0124,257', 'Orange,0.01364,797,0.0124,258', 'Rajath,0.01363,707,0.0124,259', 'Zeeshan,0.01362,449,0.0124,260', 'XiaoyuYang,0.01362,375,0.0124,261', 'Anthony Chan,0.01367,912,0.0124,262', 'brady == ðŸ\x90\x90,0.01368,943,0.0124,263', 'Vinay,0.01367,917,0.0124,264', 'lu xi,0.01364,784,0.0124,265', 'DHK123,0.01356,199,0.0124,266', 'yukimin,0.01363,677,0.0124,267', 'ADT,0.01362,369,0.0124,268', 'Bill Miao,0.01364,766,0.0124,269', 'Keisuke Shoji,0.01362,360,0.0124,270', 'nataliayap,0.01364,798,0.0124,271', 'MG,0.01367,905,0.0124,272', 'Harris Y,0.01362,436,0.0124,273', 'kt3472,0.01362,309,0.0124,274', 'laboratory,0.01363,626,0.0124,275', 'bu dong qiu,0.01367,895,0.0124,276', 'Raju Kumar Mishra,0.01367,904,0.0124,277', 'atom,0.01363,624,0.0124,278', 'whitehair,0.01363,623,0.0124,279', 'Young,0.01363,734,0.0124,280', 'Martin Meinke,0.0136,249,0.0124,281', 'yuki,0.0136,246,0.0124,282', 'botD,0.0136,250,0.0124,283', 'maelab,0.01368,961,0.0124,284', 'cjma,0.01367,890,0.0124,285', 'ljklight,0.0137,1020,0.0124,286', 'MMP CMC Kagglers,0.01363,608,0.0124,287', 'kohei y,0.01367,888,0.0124,288', 'SRK,0.01361,274,0.0124,289', 'Stack_it!,0.01363,544,0.0124,290', 'Maggie Zhou,0.01368,960,0.0124,291', 'Eve,0.0136,243,0.0124,292', 'yuto16,0.0136,247,0.0124,293', 'Kalyan Kumar P,0.01366,867,0.0124,294', 'JasonM,0.01362,516,0.0124,295', 'tamura,0.01353,174,0.0124,296', "Rory O'Reilly,0.01373,1048,0.0124,297", 'DaoSword,0.01365,833,0.0124,298', 'M.G.G,0.01363,715,0.0124,299', 'TaeHun Kim,0.01368,923,0.0124,300', '#rerun,0.01362,420,0.0124,301', 'PSThorbell,0.01359,240,0.0124,302', 'Atish,0.01367,897,0.0124,303', 'Carbon,0.01363,698,0.01241,304', 'Zee,0.01362,411,0.01241,305', 'ArcWaterCash,0.01368,938,0.01241,306', 'Aman.cyberia,0.01363,582,0.01241,307', 'GitanshKhirbat,0.01362,456,0.01241,308', 'dan musetoiu,0.01362,434,0.01241,309', 'rookie,0.01369,982,0.01241,310', 'Chi Gao,0.01363,586,0.01241,311', 'hktxt,0.01362,412,0.01241,312', 'Daisuke ODE,0.01363,704,0.01241,313', 'Elsa Xie,0.01363,583,0.01241,314', 'firstbloodY,0.01362,453,0.01241,315', 'Danny,0.01369,985,0.01241,316', 'singlefish,0.01363,573,0.01241,317', 'Varyans Idman Yurdu,0.01362,422,0.01241,318', 'Shailesh D,0.01369,980,0.01241,319', 'peterhwang2010,0.01363,569,0.01241,320', 'Zashio,0.01363,566,0.01241,321', 'hhxx,0.01366,875,0.01241,322', 'Moon_hyungjoon,0.01363,714,0.01241,323', 'IDKWTD,0.01368,937,0.01241,324', 'PaweÅ‚ LubiÅ„ski,0.01363,663,0.01241,325', 'Danya Chepenko,0.01369,978,0.01241,326', 'Harijs Cerins,0.01362,502,0.01241,327', 'Adriana Staudova,0.01368,953,0.01241,328', 'Andrei Dukhounik,0.01368,954,0.01241,329', 'Panagiotis Simakis,0.01362,513,0.01241,330', 'jun matsukuma,0.01368,970,0.01241,331', 'Narek Maloyan,0.01362,517,0.01241,332', 'kiyomomo,0.01362,518,0.01241,333', 'WARRIORS,0.01363,630,0.01241,334', 'Nayeun Irene Kim,0.01362,520,0.01241,335', 'Bo Peng,0.01362,521,0.01241,336', 'TMorioka,0.01363,629,0.01241,337', 'chexex,0.01363,627,0.01241,338', 'Hayato,0.01362,527,0.01241,339', 'Pepito Bleu,0.01368,967,0.01241,340', 'Euisung Kim,0.01368,962,0.01241,341', 'chadliu,0.01363,621,0.01241,342', 'Nikita Churkin,0.01368,955,0.01241,343', 'qudade,0.01363,619,0.01241,344', 'Lang Sys,0.01363,541,0.01241,345', 'Shiunwen,0.01368,956,0.01241,346', 'ryulapislazuli,0.01368,939,0.01241,347', 'Takahiro,0.01362,501,0.01241,348', 'nariman9119,0.01362,498,0.01241,349', 'MichaelP,0.01362,465,0.01241,350', 'Puck Wang,0.01363,560,0.01241,351', 'Casual Observer,0.01369,976,0.01241,352', 'Zaryel,0.01363,679,0.01241,353', 'YSasaki,0.01362,469,0.01241,354', 'LeonShangguan,0.01363,726,0.01241,355', 'buffalo wings,0.01368,975,0.01241,356', 'handonglee,0.01362,475,0.01241,357', 'Van de Rakt,0.01362,477,0.01241,358', 'Misuk Kim,0.01363,667,0.01241,359', 'Kazuyuki Mori,0.01368,946,0.01241,360', 'beepbloop11879,0.01363,615,0.01241,361', 'sarusiya,0.01368,947,0.01241,362', 'krovere,0.01362,487,0.01241,363', 'Aybek Bekbaev,0.01368,950,0.01241,364', 'y-mogi,0.01363,651,0.01241,365', 'Rishabh #2,0.01363,646,0.01241,366', 'hakusai,0.01362,495,0.01241,367', 'Kuno Nori,0.01368,971,0.01241,368', 'Alex Zhang,0.01363,555,0.01241,369', 'Dulya Ivan,0.01363,557,0.01241,370', 'charlse,0.01367,899,0.01241,371', 'Travis Sun,0.01363,576,0.01241,372', 'xjoyzaza,0.01364,788,0.01241,373', 'tom barkley,0.01361,289,0.01241,374', 'wancyope,0.01367,894,0.01241,375', 'isa k [dsmlkz],0.01362,345,0.01241,376', 'Oleksii Sainog,0.01367,892,0.01241,377', 'EduardVoinea,0.01362,347,0.01241,378', 'BartvonMeijenfeldt,0.01361,278,0.01241,379', 'Alexander Zinovev,0.01361,277,0.01241,380', 'Yasar,0.01365,848,0.01241,381', 'y-Carbon,0.01364,782,0.01241,382', 'Green Bay Packers,0.01364,781,0.01241,383', 'Bojan Tunguz,0.01362,352,0.01241,384', 'anatoly,0.01368,921,0.01241,385', 'Atul Rao,0.01362,356,0.01241,386', 'Veerala Hari Krishna,0.01362,357,0.01241,387', 'wyldream,0.01368,922,0.01241,388', 'care,0.01361,269,0.01241,389', 'Gilang Ardya,0.01362,341,0.01241,390', 'Arijit Gupta,0.01364,789,0.01241,391', 'zhbain,0.01361,292,0.01241,392', 'Jacob,0.01361,293,0.01241,393', 'Habib,0.01367,903,0.01241,394', 'Marcos Martins Marchetti,0.01362,315,0.01241,395', 'Boris Ilin,0.01367,900,0.01241,396', 'student,0.01362,316,0.01241,397', 'Ulf Pack,0.01363,577,0.01241,398', 'Dohee,0.01367,898,0.01241,399', '_erica_kaggler,0.01365,836,0.01241,400', 'Val An,0.01362,323,0.01241,401', 'marine6310ê¹€ì„±ì\x9d¼(ëŒ€í•™ì›\x90í•™ìƒ\x9d/ê²½ì œëŒ€í•™ì›\x90 ê¸°ì—…ê²½ì œì „ê³µ),0.01364,821,0.01241,402', 'â€\x8dFLOWKIM,0.01362,298,0.01241,403', 'Gang Min Lee,0.01364,805,0.01241,404', 'go!go!curry!,0.01362,328,0.01241,405', 'William Spiegel,0.01369,994,0.01241,406', 'Atanas Atanasov,0.01362,330,0.01241,407', 'andrekos,0.01362,335,0.01241,408', 'Iaroslav Elistratov,0.01367,896,0.01241,409', 'HarryQuake,0.01364,794,0.01241,410', 'Alvis Wong,0.01362,294,0.01241,411', 'shirapon,0.01362,325,0.01241,412', 'arthasli,0.01366,855,0.01241,413', 'Nikola,0.01366,853,0.01241,414', 'Thomas Wong,0.01364,820,0.01241,415', 'AntonNegreba,0.01353,175,0.01241,416', 'Pineapple of evolution,0.01359,230,0.01241,417', 'Lavanya Shukla,0.01366,865,0.01241,418', 'ZFTurbo,0.01363,749,0.01241,419', 'Udbhav Pangotra,0.01366,864,0.01241,420', 'Joowon Lee,0.01363,748,0.01241,421', 'Aleck Wu,0.01359,236,0.01241,422', 'earthy,0.01368,927,0.01241,423', 'Sergei Averkiev,0.01362,371,0.01241,424', 'Gleb Anferov,0.01371,1033,0.01241,425', 'paulorufino,0.01363,746,0.01241,426', 'forArya,0.01357,214,0.01241,427', 'Jerry,0.01363,741,0.01241,428', 'Honto no Jikan,0.01369,995,0.01241,429', 'monuvio,0.01357,215,0.01241,430', 'somnambWl,0.01356,198,0.01241,431', 'Behrang,0.01364,754,0.01241,432', 'zlannn,0.01364,755,0.01241,433', 'yjh3808,0.01362,404,0.01241,434', 'Tabish M,0.0137,1022,0.01241,435', 'Bruce Young,0.01364,763,0.01241,436', 'Wei Hao Khoong,0.01362,383,0.01241,437', 'LDPy,0.01363,733,0.01241,438', 'CFDAero,0.0136,251,0.01241,439', 'Aimyon,0.01356,200,0.01241,440', 'Executorg,0.01366,870,0.01241,441', 'Flavien Gelineau,0.0137,1024,0.01241,442', 'Huangzz1718,0.01367,881,0.01241,443', 'Jonathan Buchanan,0.01369,997,0.01241,444', 'D C Aichara,0.01364,756,0.01241,445', 'mengfanyu,0.01362,377,0.01241,446', 'Li-Der,0.01367,901,0.01242,447', 'Deep Chatterjee,0.01363,584,0.01242,448', 'Ah bon,0.01363,631,0.01242,449', 'Tweb,0.01367,880,0.01242,450', 'Abhishek Sheshadri,0.01363,628,0.01242,451', 'lucas1347,0.01365,827,0.01242,452', 'Ragnar,0.01363,606,0.01242,453', 'Zander,0.01363,590,0.01242,454', 'tianbadongbata,0.01363,607,0.01242,455', 'Tatsuryu,0.01367,887,0.01242,456', 'Eric Vos,0.01363,609,0.01242,457', 'Kazumi Sakamoto,0.01363,611,0.01242,458', 'Ivan Marevic,0.01363,612,0.01242,459', 'Changmin Choi,0.01363,613,0.01242,460', 'RyanGoodman,0.01363,605,0.01242,461', 'can.chu,0.01366,850,0.01242,462', 'Joey Wong,0.01363,602,0.01242,463', 'Stanislav Blinov,0.01363,600,0.01242,464', 'Tae heon Kim,0.01367,893,0.01242,465', 'simon,0.01363,625,0.01242,466', 'FelixGozali,0.01363,598,0.01242,467', 'Migs Rocha,0.01363,595,0.01242,468', 'KimBoKyu,0.01363,592,0.01242,469', 'AlEkhchidi,0.01363,589,0.01242,470', 'kitaura,0.01363,599,0.01242,471', 'Krishna Chaitanya,0.01363,728,0.01242,472', 'Project 23,0.01363,633,0.01242,473', 'Kasumi_Arimura_ha_Kawaii,0.01363,694,0.01242,474', 'dendenmushi,0.01364,764,0.01242,475', 'take_kana1114,0.01368,926,0.01242,476', 'pongba,0.01364,757,0.01242,477', 'justfitting,0.01368,936,0.01242,478', 'ddn_,0.01363,699,0.01242,479', 'skyneteyes,0.01363,702,0.01242,480', 'Hassan,0.01364,752,0.01242,481', 'imait,0.01364,751,0.01242,482', 'Mr Nik,0.01363,705,0.01242,483', 'bebe,0.01363,706,0.01242,484', 'Ankita Sinha,0.01363,708,0.01242,485', 'pcullen11,0.01363,709,0.01242,486', 'Yandi Zhu,0.01368,935,0.01242,487', 'Martin Bonardi,0.01363,711,0.01242,488', 'Justin Yee,0.01363,712,0.01242,489', 'Rachid Ahed,0.01363,713,0.01242,490', 'Yassu,0.01368,928,0.01242,491', 'YuhkiH,0.01363,742,0.01242,492', 'Samarth,0.01363,739,0.01242,493', 'Tadashi Kikuchi,0.01363,716,0.01242,494', 'Moritz Schwyzer,0.01363,717,0.01242,495', 'Luca Massaron,0.01363,737,0.01242,496', 'Ryu Hyun Sung,0.01368,934,0.01242,497', 'younglee,0.01363,735,0.01242,498', 'sakuragi123,0.01363,723,0.01242,499', 'JinaKK,0.01363,729,0.01242,500', 'manu++,0.01364,767,0.01242,501', 'Kyurie Park,0.01364,769,0.01242,502', 'Saravana kumar,0.01363,693,0.01242,503', 'Kaito510,0.01363,692,0.01242,504', 'QLQian,0.01363,634,0.01242,505', 'edvinmemet,0.01363,636,0.01242,506', 'bestpredict,0.01363,637,0.01242,507', 'Robe_82,0.01363,639,0.01242,508', 'Sammyy,0.01363,640,0.01242,509', 'suk1yak1,0.01364,815,0.01242,510', 'Sergey #2,0.01363,643,0.01242,511', 'yoshi_u,0.01364,810,0.01242,512', 'Karthik Kumar Billa,0.01368,951,0.01242,513', 'Jacek Rojek,0.01363,650,0.01242,514', 'Bassil Bassiouny,0.01363,659,0.01242,515', 'Ramstein,0.01364,792,0.01242,516', '8ct10nz,0.01364,790,0.01242,517', 'Solomon Xian,0.01364,819,0.01242,518', 'Bibin Paul,0.01363,662,0.01242,519', 'kaggle446,0.01363,669,0.01242,520', 'Backstreet Boys,0.01368,945,0.01242,521', 'shina47,0.01364,786,0.01242,522', 'Joonas Kalda,0.01363,673,0.01242,523', 'KrisztiÃ¡n Fekete,0.01363,674,0.01242,524', 'pushpendra,0.01363,675,0.01242,525', 'KrisztiÃ¡n PomÃ¡zi,0.01368,919,0.01242,526', 'just trying,0.01364,776,0.01242,527', 'Bo1Yuan,0.01364,774,0.01242,528', 'Jing Lu,0.01363,683,0.01242,529', 'Yejun Lee,0.01363,686,0.01242,530', 'SIDHARTH,0.01364,771,0.01242,531', 'MJ YU,0.01364,770,0.01242,532', 'Tarek Hamdi,0.01363,665,0.01242,533', 'parseltung,0.01364,801,0.01242,534', 'sirius*,0.01362,450,0.01242,535', 'Gig,0.01362,414,0.01242,536', 'GuangzhiWang,0.01369,991,0.01242,537', 'Aleksthegreat,0.01362,430,0.01242,538', 'Jisu Kim,0.01362,431,0.01242,539', 'nyancat62,0.01362,435,0.01242,540', 'ikousuke,0.01362,439,0.01242,541', 'Shaod Liu,0.01362,351,0.01242,542', 'Jon Compton,0.01362,441,0.01242,543', 'Mikhail Pchelintsev,0.01362,348,0.01242,544', 'å¤§ç¢—é¥\xadåŠ è›‹,0.01362,346,0.01242,545', 'Noah Weber,0.01362,454,0.01242,546', 'SpqceD,0.01369,979,0.01242,547', 'ashergaga,0.01362,343,0.01242,548', 'Alexandr Konovalov,0.01362,338,0.01242,549', 'gorogoroumaru,0.01362,462,0.01242,550', 'Rashid Haffadi,0.01362,333,0.01242,551', 'Justin Coleman,0.01362,329,0.01242,552', 'FengLei Dou,0.01362,471,0.01242,553', 'naoya kumagai,0.01362,491,0.01242,554', 'Dmitry Kozlov,0.01362,318,0.01242,555', 'T.K.,0.01362,320,0.01242,556', 'x5or6,0.01368,973,0.01242,557', 'vivekkumar,0.01362,488,0.01242,558', 'Nikita Hismatov,0.01362,486,0.01242,559', 'Jimin Yoon,0.01362,358,0.01242,560', 'Kyota,0.01368,974,0.01242,561', 'Igor Tokarev,0.01369,996,0.01242,562', 'Weather Superman,0.01362,480,0.01242,563', 'Data4Breakfast,0.01362,327,0.01242,564', 'deja vu,0.01362,479,0.01242,565', 'Sangwoo Jung,0.01362,476,0.01242,566', 'Edward0chen,0.01362,473,0.01242,567', 'OrKatz,0.01362,483,0.01242,568', 'Orkhan Baghirli,0.01362,492,0.01242,569', 'I want a job,0.01362,427,0.01242,570', 'Ken At,0.01362,359,0.01242,571', 'Adrian Zinovei,0.01362,385,0.01242,572', 'none,0.01362,387,0.01242,573', 'Lee_Chen,0.01362,381,0.01242,574', 'Tanishq Gautam,0.01362,388,0.01242,575', 'Olga Ivanova,0.01362,389,0.01242,576', 'Antonio Marin,0.01362,390,0.01242,577', 'DaNing,0.01362,391,0.01242,578', 'Lorenzo Ampil,0.01362,379,0.01242,579', '0DD1,0.01362,392,0.01242,580', 'Nikita Ageev,0.01362,393,0.01242,581', 'Georgios Sarantitis,0.01362,376,0.01242,582', 'rc95401,0.01362,397,0.01242,583', 'WRSPKU,0.01362,398,0.01242,584', 'NE Patriots,0.01362,399,0.01242,585', 'csoh,0.01362,400,0.01242,586', 'Huamin Zhang,0.01362,374,0.01242,587', 'Kirderf,0.01362,373,0.01242,588', 'coppell: liang & gupta,0.01362,362,0.01242,589', 'bm13800,0.01362,421,0.01242,590', 'ilialar,0.01362,419,0.01242,591', 'jewonkimmm,0.01362,416,0.01242,592', 'Semie,0.01362,363,0.01242,593', 'Nick Styles,0.01362,364,0.01242,594', 'tj_bh,0.01362,426,0.01242,595', 'Jie Wu,0.01362,365,0.01242,596', 'luca spelgatti,0.01362,413,0.01242,597', 'Siddharth Chandrakant,0.01362,410,0.01242,598', 'sunshineinautumn,0.01362,408,0.01242,599', 'Scottfree,0.01362,368,0.01242,600', 'Dmitriy Ershov,0.01362,405,0.01242,601', 'Piyush,0.01362,403,0.01242,602', 'ildarsafilo,0.01363,575,0.01242,603', 'BetterThanButter,0.01362,314,0.01242,604', '[ods] Vitali Burachonok,0.01362,324,0.01242,605', 'SethKitchen,0.01368,972,0.01242,606', 'siero,0.01362,528,0.01242,607', 'Beginner,0.01362,529,0.01242,608', 'mochidan,0.01362,300,0.01242,609', 'goku,0.01362,536,0.01242,610', 'Vladislav Bogorod,0.01362,313,0.01242,611', 'Mathurin AchÃ©,0.01362,537,0.01242,612', 'Aggelos G,0.01361,291,0.01242,613', 'FernandoTN,0.01361,288,0.01242,614', 'stdy,0.01361,285,0.01242,615', 'WNYSAC,0.01363,540,0.01242,616', 'henrykf22,0.01363,545,0.01242,617', 'shuheioka,0.01363,547,0.01242,618', 'predictor!,0.01363,548,0.01242,619', 'Kostas Maragkos,0.01363,551,0.01242,620', 'äººç”Ÿè‹¥å\x8fªå¦‚åˆ\x9dè§\x81,0.01368,968,0.01242,621', 'StephanMiller,0.0137,1011,0.01242,622', 'Shiggy,0.01361,280,0.01242,623', 'Takahiro Saito,0.01361,276,0.01242,624', 'DaniilChuykin,0.01363,556,0.01242,625', 'ajp,0.01363,558,0.01242,626', 'Parkinson Zabelin,0.01363,559,0.01242,627', 'TooHard,0.0137,1016,0.01242,628', 'gdps,0.01361,273,0.01242,629', 'Alexander Polyakov,0.01363,561,0.01242,630', 'Naruhiko Nakanishi,0.01361,267,0.01242,631', 'syllap,0.0137,1028,0.01242,632', 't.eno,0.01358,221,0.01242,633', 'Minimi,0.01363,565,0.01242,634', 'Taipon,0.01372,1046,0.01242,635', 'nvnn,0.01363,572,0.01242,636', 'Abrek Bavizhev,0.01363,553,0.01242,637', 'hysnar,0.01362,524,0.01242,638', 'Nguyen Quan Anh Minh,0.01362,384,0.01242,639', 'DOUYG,0.01362,519,0.01242,640', 'Arunkumar Venkataramanan,0.01362,311,0.01242,641', 'Santiago Mota,0.01362,507,0.01242,642', 'Sergey Zhitansky,0.01362,504,0.01242,643', 'Pavel Govoruha,0.01362,503,0.01242,644', 'RakeshNikam,0.01362,303,0.01242,645', 'mengnanyi,0.01362,515,0.01242,646', 'LaHora,0.01362,308,0.01242,647', 'RunningZ,0.01362,511,0.01242,648', 'Excuses,0.01362,319,0.01243,649', 'touchdown,0.01361,272,0.01243,650', 'jiheeyu,0.01362,310,0.01243,651', 'Ninja,0.01362,372,0.01243,652', 'Greg Hamel,0.01364,765,0.01243,653', 'Akhilesh Rai,0.01364,811,0.01243,654', 'Bilegzaya,0.01362,367,0.01243,655', 'Gabriel Preda,0.01362,307,0.01243,656', 'Frank V,0.01364,812,0.01243,657', 'Can Kural,0.01361,266,0.01243,658', 'erutsap,0.01364,796,0.01243,659', 'Anurag Trivedi,0.01361,265,0.01243,660', 'mnaoto,0.01386,1183,0.01243,661', 'ccc_k,0.01362,317,0.01243,662', 'Ruslan Khalitov,0.01364,817,0.01243,663', 'JunjiAkahane,0.01371,1042,0.01243,664', 'Kawabata Naoyuki,0.01371,1041,0.01243,665', 'Ahust,0.01367,882,0.01243,666', 'Guna Sekhar,0.01362,321,0.01243,667', 'hookbook,0.01355,188,0.01243,668', 'Sirish Somanchi,0.01371,1032,0.01243,669', 'Farb,0.01364,758,0.01243,670', 'masa-suke,0.01367,885,0.01243,671', 'Ayush GUPTA,0.01364,759,0.01243,672', 'uniko,0.01364,822,0.01243,673', 'Pavel Salikov,0.01364,761,0.01243,674', 'RahulAgarwal,0.01362,312,0.01243,675', 'Srinivas vaddi,0.01364,768,0.01243,676', 'Sowmiyan Morri,0.01365,829,0.01243,677', 'senkin13,0.01364,809,0.01243,678', 'moon_lighting,0.01364,795,0.01243,679', 'hmk,0.01362,337,0.01243,680', 'zakopuro,0.01369,1002,0.01243,681', 'Group 1,0.01362,339,0.01243,682', 'Sugawarya,0.01369,1000,0.01243,683', 'Niranjan Singh,0.01362,342,0.01243,684', 'Darko Androcec,0.01362,344,0.01243,685', 'rnrq,0.01364,800,0.01243,686', 'colligo,0.01362,302,0.01243,687', 'KrizsÃ³ Gergely,0.01362,301,0.01243,688', 'saneryee,0.01362,304,0.01243,689', 'seele1917,0.01362,349,0.01243,690', 'Kosarevsky Dmitry,0.01362,297,0.01243,691', 'jaejeong ahn,0.01362,350,0.01243,692', 'rua,0.01362,306,0.01243,693', 'Mikhail Karchevskiy,0.01364,802,0.01243,694', 'takashi,0.01368,920,0.01243,695', 'Stella Gim,0.01362,353,0.01243,696', 'trmk,0.01362,354,0.01243,697', 'Y. Y,0.01364,803,0.01243,698', 'Kirill Stroganov,0.01361,287,0.01243,699', 'Yixinchen,0.01364,804,0.01243,700', 'Hyewoon Joung,0.01362,305,0.01243,701', 'Ashutosh Sanzgiri,0.01361,284,0.01243,702', 'poteman,0.01361,282,0.01243,703', 'JumpeiT,0.01365,830,0.01243,704', 'Vlad Balanda,0.01365,845,0.01243,705', 'jun woo oh,0.01364,772,0.01243,706', 'Sida Chen,0.01364,806,0.01243,707', 'zmnako,0.01362,336,0.01243,708', 'xz,0.01364,780,0.01243,709', 'kes | Glib Kechyn,0.01362,295,0.01243,710', 'jangsangho,0.01363,578,0.01243,711', 'Pritesh Shrivastava,0.01364,750,0.01243,712', 'DENDEN ZZH5,0.01362,535,0.01243,713', 'Alexander Nichiporenko,0.01362,534,0.01243,714', 'TOMOTAKA,0.01363,622,0.01243,715', 'Vladimir Zhuravlev,0.01362,531,0.01243,716', 'dbrait,0.01362,523,0.01243,717', 'rivxhar5907,0.01362,522,0.01243,718', 'Kamal Jain,0.01362,509,0.01243,719', 'Morphy,0.01362,508,0.01243,720', 'Muhan Li,0.01362,506,0.01243,721', 'Maho #2,0.01362,505,0.01243,722', 'Feodeera Sondach,0.01363,618,0.01243,723', 'Han Jae Hyun,0.01363,638,0.01243,724', 'Murata Hoshi,0.01368,952,0.01243,725', 'ä¸€æˆ˜æˆ\x90å\x90\x8d,0.01362,500,0.01243,726', 'Keewon Shin,0.01363,644,0.01243,727', 'imthon,0.01362,497,0.01243,728', 'Tatanka007,0.01363,647,0.01243,729', 'Christophe Bourgoin,0.01363,648,0.01243,730', 'KFurudate,0.01363,649,0.01243,731', 'Grzegorz Sionkowski,0.01362,493,0.01243,732', "Football's Coming Home,0.01363,655,0.01243,733", 'Agnieszka Matyja,0.01364,753,0.01243,734', 'Niranjan Nakkala,0.01363,641,0.01243,735', 'erikw425,0.01363,616,0.01243,736', 'Pedro Reis,0.01362,538,0.01243,737', 'Akshay Varu,0.01363,614,0.01243,738', 'yassine zayani,0.01363,579,0.01243,739', 'Mitsuru Fujiwara,0.01363,581,0.01243,740', 'liuzhangzhen,0.01363,571,0.01243,741', 'Spurius,0.01363,570,0.01243,742', 'Ren,0.01363,567,0.01243,743', 'liuze,0.01363,585,0.01243,744', 'Yusuke_Sakai_1993,0.01363,587,0.01243,745', 'Matthew Smith,0.01363,588,0.01243,746', 'Taylor #2,0.01363,564,0.01243,747', 'AnjanaKumar,0.01363,563,0.01243,748', 'JRPC,0.01363,591,0.01243,749', 'wentixiaogege,0.01363,562,0.01243,750', 'Scirpus,0.01363,593,0.01243,751', 'jleecook,0.01363,594,0.01243,752', 'BlueDragon,0.01363,596,0.01243,753', 'Balaji Venkateswaran,0.01363,597,0.01243,754', 'LinhLPV,0.01363,601,0.01243,755', 'Tianjian Meng,0.01363,554,0.01243,756', 'GIDONG PARK,0.01363,604,0.01243,757', 'Minkyu Lee,0.01363,546,0.01243,758', 'Itsuki Hamano,0.01363,610,0.01243,759', 'Chaeyeon Yoo,0.01363,542,0.01243,760', 'Bonum,0.01362,539,0.01243,761', 'Tomi,0.01362,490,0.01243,762', 'Ado Dream,0.01363,658,0.01243,763', 'Ayman Khalafallah,0.01363,656,0.01243,764', 'Marco Vasquez E,0.01363,664,0.01243,765', 'à´®à´²à´¯à´¾à´³à´¿,0.01362,485,0.01243,766', 'DrWho,0.01369,989,0.01243,767', 'Mashlyn,0.01362,433,0.01243,768', 'Lawrence Chernin,0.01362,432,0.01243,769', 'Call me Dong,0.01362,428,0.01243,770', 'luyaxin,0.01362,425,0.01243,771', 'Bartig,0.01362,423,0.01243,772', 'MLS,0.01369,992,0.01243,773', 'Tang Hao,0.01363,719,0.01243,774', 'Lucy Kim,0.01363,720,0.01243,775', 'gavrand,0.01363,721,0.01243,776', 'Sho Takahashi,0.01362,415,0.01243,777', 'aryyyyy,0.01363,725,0.01243,778', 'Akshan Sameullah,0.01362,407,0.01243,779', 'kr0610_cho,0.01362,406,0.01243,780', 'Hiroto Sekita,0.01363,730,0.01243,781', 'Nooh,0.01362,402,0.01243,782', 'Jiyeon Lee,0.01362,401,0.01243,783', 'littlexiaogui,0.01363,738,0.01243,784', 'Khairul Islam,0.01363,740,0.01243,785', 'Tiemu,0.01362,396,0.01243,786', 'Sqy,0.01363,743,0.01243,787', 'Mike #2,0.01363,745,0.01243,788', 'Ladle Patel,0.01363,700,0.01243,789', 'Boxuan Li,0.01362,440,0.01243,790', 'rush_tom_sawyer,0.01363,701,0.01243,791', 'Serhii Shcherbyna,0.01362,452,0.01243,792', 'Igor Dudchenko,0.01362,482,0.01243,793', 'Alexander Varnavsky,0.01362,481,0.01243,794', 'Ivan Tellurian,0.01363,668,0.01243,795', 'The Elon Muskrats,0.01363,670,0.01243,796', 'JongWonC,0.01362,478,0.01243,797', 'Aleksandr Kosolapov,0.01362,474,0.01243,798', 'JaehongJeong,0.01362,470,0.01243,799', 'syasyasyasyathx,0.01362,446,0.01243,800', 'MA Junyi,0.01362,468,0.01243,801', 'Tsubasa,0.01363,681,0.01243,802', 'hukuda222,0.01363,678,0.01243,803', 'HONIHITAK,0.01362,460,0.01243,804', 'V B,0.01363,695,0.01243,805', 'Egor Savkin,0.01362,458,0.01243,806', 'Kishi,0.01362,459,0.01243,807', 'noidea,0.01362,464,0.01243,808', 'yorshka,0.01363,689,0.01243,809', 'GEYIJIE LI,0.01366,876,0.01243,810', 'Toshihiko Sato,0.01363,687,0.01243,811', 'Giba,0.01362,461,0.01243,812', 'Vladimir Larin,0.01363,685,0.01243,813', 'brandon lin,0.01363,688,0.01243,814', 'Federico Allocati,0.01371,1031,0.01244,815', 'yapkan,0.01371,1036,0.01244,816', 'Aozora,0.0137,1006,0.01244,817', 'monda,0.01373,1050,0.01244,818', 'Neild1990,0.01373,1052,0.01244,819', 'Massoud Hosseinali,0.01368,941,0.01244,820', 'Mark Guarnieri,0.01389,1222,0.01244,821', 'Ilya Plemian,0.01368,940,0.01244,822', 'rauta,0.01369,983,0.01244,823', 'AndNov,0.01363,550,0.01244,824', 'Radeeswar,0.01362,382,0.01244,825', 'P3n9W31,0.01362,417,0.01244,826', 'Key-Minamoto,0.01362,418,0.01244,827', 'python10pm,0.01364,762,0.01244,828', 'Turing,0.01364,760,0.01244,829', 'Jan Bre,0.01363,747,0.01244,830', 'Pavel Suprun,0.01362,444,0.01244,831', 'Mikhail Fadeev,0.01362,445,0.01244,832', 'Piotrek Rozenbajgier,0.01363,732,0.01244,833', 'Eduardo Munoz Sala,0.01363,731,0.01244,834', 'UTN SSK,0.01362,451,0.01244,835', 'Artem Gluschenko,0.01363,718,0.01244,836', 'D_dof,0.01363,697,0.01244,837', 'ashwinids,0.01363,691,0.01244,838', 'Ilu,0.01363,684,0.01244,839', 'MarcoWang,0.01363,676,0.01244,840', 'Gabriel CustÃ³dio,0.01363,672,0.01244,841', 'chhaatra,0.01362,533,0.01244,842', 'Jo,0.01363,549,0.01244,843', 'Roman,0.01362,496,0.01244,844', 'SUDHAKAR,0.01362,489,0.01244,845', 'zehengl,0.01363,574,0.01244,846', 'é‚ªæ\x81¶å°\x8fæ³•å¸ˆ,0.01363,580,0.01244,847', 'Mocha,0.01362,380,0.01244,848', 'Debut_Kele,0.01363,620,0.01244,849', 'steelrose,0.01362,484,0.01244,850', 'Thor,0.01363,642,0.01244,851', 'ChoEun000904 #2,0.01363,645,0.01244,852', 'lucaskg,0.01362,467,0.01244,853', 'Nanashi,0.01362,463,0.01244,854', 'tea,0.01362,457,0.01244,855', 'Mohammed Tayor,0.01363,632,0.01244,856', 'apoorvc,0.01362,355,0.01244,857', 'zhang jinlai,0.01364,775,0.01244,858', 'Harshit Sheoran,0.01362,532,0.01244,859', 'Eunjee Cho,0.01362,340,0.01244,860', 'Dimosthenis Karaflos,0.01365,835,0.01244,861', 'Vladislav Ryzhov,0.01365,834,0.01244,862', 'FernandoChafim,0.01361,271,0.01244,863', 'Leonard Strauss,0.01365,847,0.01244,864', 'Anton Morkovkin,0.01362,299,0.01244,865', 'Vitalii Peretiatko,0.01365,825,0.01244,866', 'heihei,0.01359,239,0.01244,867', 'æ— é™µ,0.01364,823,0.01244,868', 'Xiuchuanz,0.01366,859,0.01244,869', 'Datasciensyash,0.01365,841,0.01244,870', 'Adib Priatama,0.01366,860,0.01244,871', 'æ\x90\x8fä¸€æ\x90\x8f,0.01353,173,0.01244,872', 'tkm2261,0.01362,326,0.01244,873', 'fangds,0.01362,334,0.01244,874', 'Paritosh,0.01367,883,0.01245,875', 'Doe John,0.01366,866,0.01245,876', 'John Kyvetos,0.01355,192,0.01245,877', 'ilya37,0.01366,869,0.01245,878', 'DaisukeN,0.01362,472,0.01245,879', 'Sergey Yakushin,0.01366,871,0.01245,880', 'akki,0.01376,1086,0.01245,881', 'Zhenchen Hong,0.01368,964,0.01245,882', 'JPraguer,0.01363,661,0.01245,883', 'Zouzoulapin,0.0138,1106,0.01245,884', 'Appian,0.01363,603,0.01245,885', 'chechsterfildsilv,0.01373,1049,0.01245,886', 'Stephen,0.01367,914,0.01245,887', 'Igor V,0.01363,680,0.01245,888', 'Tang Tun Yu,0.01364,799,0.01245,889', 'Shao Yiqi,0.01362,395,0.01245,890', 'someone,0.01364,783,0.01245,891', 'John Henderson,0.01362,331,0.01245,892', 'Paulo Pinto,0.01362,322,0.01245,893', 'Roy Luo,0.01365,840,0.01245,894', 'Geeko,0.0137,1007,0.01245,895', 'æ\x81‹è¨€(regonn)ðŸ\x8dµ,0.0137,1018,0.01245,896', 'Shion Honda,0.01363,710,0.01245,897', 'Michael Kazachok,0.01363,696,0.01245,898', 'shivyshiv,0.01363,690,0.01245,899', 'Doudi,0.0137,1025,0.01245,900', 'sakana,0.01366,877,0.01246,901', 'Calanin,0.01355,185,0.01246,902', 'yutou,0.01369,984,0.01246,903', 'Pig Wings,0.01362,429,0.01246,904', 'Arthur Llau,0.01362,514,0.01246,905', 'Gator Liu,0.01373,1054,0.01246,906', 'asami,0.01358,229,0.01246,907', 'JBPARK,0.0137,1012,0.01246,908', 'Jiazhen Xi,0.01352,169,0.01246,909', 'tito,0.01363,736,0.01246,910', 'Mark Eckdahl,0.01364,778,0.01246,911', 'AnXiong,0.01367,913,0.01246,912', 'BillsMafia,0.01365,842,0.01246,913', 'hdkidz,0.01364,808,0.01246,914', 'James Requa,0.01364,818,0.01246,915', 'vishwajeetshukla,0.01365,826,0.01246,916', 'Zoopal2LondonRPZ,0.01251,6,0.01246,917', 'cerlymarco,0.01363,744,0.01246,918', 'zhuchengqi,0.01364,787,0.01247,919', 'noeasywayout,0.01367,911,0.01247,920', 'xct,0.01367,908,0.01247,921', 'Abner_Zhu,0.01365,824,0.01247,922', 'GX,0.01374,1062,0.01247,923', 'Seung Min Eo,0.01368,969,0.01247,924', 'YALICKJ,0.01365,832,0.01247,925', 'Zach Lindsey,0.0137,1021,0.01247,926', 'Corentin Berteloot,0.0137,1023,0.01247,927', 'Nitesh Chaudhry,0.01365,837,0.01247,928', 'SeongHun Jeong,0.01365,839,0.01247,929', 'imdksk,0.01365,844,0.01247,930', 'Dapeng LeeðŸ\x90¦,0.01366,861,0.01247,931', 'Pavel Troshenkov,0.01371,1039,0.01247,932', 'William Ma,0.01352,163,0.01247,933', 'younghyup jeong,0.0137,1017,0.01247,934', 'abdelatif,0.01364,785,0.01247,935', 'iamrouss,0.01374,1064,0.01247,936', 'Mycroft Holmes,0.01363,666,0.01247,937', 'heartkilla,0.01364,777,0.01247,938', 'Vladimir,0.01363,660,0.01247,939', 'DalAda Lab,0.01364,773,0.01247,940', 'BenLatimer,0.01368,966,0.01247,941', 'Tsukamoto Mitsuru,0.01369,987,0.01247,942', 'Shubham Kumar,0.01369,986,0.01247,943', 'katsu1110,0.01348,143,0.01248,944', 'Yusuef Ramadan,0.01383,1152,0.01248,945', 'Yuto Bando,0.01361,275,0.01248,946', 'KrishnaK,0.0137,1015,0.01248,947', 'luckylu,0.01371,1034,0.01248,948', 'Christoffer Karlsson,0.01366,857,0.01248,949', 'WitatRangthain,0.01364,813,0.01248,950', 'motacapla,0.01376,1089,0.01248,951', 'Ko,0.01362,526,0.01248,952', 'Alexander Stasiuk,0.01375,1080,0.01248,953', 'olaleye eniola,0.01369,1003,0.01248,954', 'worstfitting,0.01372,1044,0.01248,955', 'Holger,0.01375,1077,0.01248,956', 'Noboru Hayashi,0.01367,902,0.01248,957', 'grantfrefg,0.01362,443,0.01248,958', 'Unnamed,0.01368,948,0.01249,959', 'Muhammed Buyukkinaci,0.01371,1035,0.01249,960', 'DataHackers,0.01366,849,0.01249,961', 'Karim Steiner,0.01375,1079,0.01249,962', 'Mike Kim,0.01368,944,0.01249,963', 'yechiel amsalem,0.01369,1001,0.01249,964', 'MSU guys,0.01362,437,0.01249,965', 'Tanyapohn,0.01375,1076,0.01249,966', 'BayesianBro,0.01368,925,0.01249,967', 'Tetyana Yatsenko,0.01376,1085,0.0125,968', 'DavidGbodiOdaibo,0.0136,254,0.0125,969', 'Mike Zhu,0.01355,195,0.0125,970', 'TheNerdyCat,0.0136,256,0.0125,971', 'Yongqi Zhong,0.01363,635,0.0125,972', 'cc #2,0.01363,657,0.0125,973', 'loveisp,0.01368,918,0.0125,974', 'Scott M,0.01379,1100,0.01251,975', 'B H,0.01361,281,0.01251,976', 'feb3901ec4e54a42d447,0.0137,1026,0.01251,977', 'Siddharth Sriraman,0.01351,160,0.01251,978', 'Bootleg,0.0136,244,0.01251,979', 'Renato Aguiar,0.01365,831,0.01251,980', 'ThomasMo,0.01374,1058,0.01252,981', 'Ewan,0.01392,1237,0.01252,982', 'nyregals,0.01366,873,0.01252,983', 'Marek Nurzynski,0.01362,442,0.01252,984', 'Kohey,0.01363,671,0.01252,985', 'Patrick Ly,0.0137,1014,0.01252,986', 'Kent,0.01358,222,0.01252,987', 'mtodisco10,0.01352,171,0.01253,988', 'Mike C,0.01367,916,0.01253,989', 'Taumaru,0.01362,466,0.01253,990', 'chuckatx25,0.01378,1093,0.01253,991', 'Kelly Johnson,0.01373,1053,0.01253,992', 'MDFam,0.01371,1038,0.01254,993', 'Pozdnyakov Yuri,0.01372,1045,0.01254,994', 'Ivan Klenovskiy,0.01389,1221,0.01254,995', 'ramen,0.0137,1009,0.01255,996', 'Grand Rookie,0.01371,1029,0.01255,997', 'averagemn,0.01382,1128,0.01255,998', 'PeterWendel,0.01355,189,0.01255,999', 'Spencer Uresk,0.01382,1127,0.01255,1000', 'NYU VIDA,0.01381,1117,0.01255,1001', '[ODS.UKrAIna] Boyrin Vjacheslav Ukraincev,0.01379,1096,0.01255,1002', 'Powered by Thai Diner,0.01369,999,0.01256,1003', 'IDRK,0.01381,1114,0.01256,1004', 'Alexander Chernyshev,0.01373,1047,0.01256,1005', 'Sudeep Shouche,0.01373,1051,0.01256,1006', 'Lorenzo Lucido,0.01374,1063,0.01257,1007', 'Ivan Liu,0.01374,1067,0.01257,1008', 'studydl.com,0.01374,1069,0.01257,1009', 'Safvan CK,0.01374,1070,0.01257,1010', 'Andrey Demidov,0.01374,1072,0.01257,1011', 'Rizvan Dwikifirdaus,0.01374,1073,0.01257,1012', 'Aswin Hofsteenge,0.01374,1074,0.01257,1013', 'Bob Wang #2,0.01371,1040,0.01257,1014', 'å°\x8fæ•°,0.01374,1060,0.01257,1015', 'EQ Jordy,0.01382,1119,0.01258,1016', 'long beach blunderbusses,0.01382,1126,0.01258,1017', 'Merve,0.01384,1163,0.01258,1018', 'octapi,0.0137,1008,0.01258,1019', 'ceb263,0.01375,1078,0.01258,1020', 'Steffen neuralgamebot.com,0.01374,1059,0.01258,1021', 'Matheus Della Croce Oliveira,0.01375,1083,0.01258,1022', 'Ryan Gong,0.01377,1091,0.01259,1023', 'Kara Hills,0.01372,1043,0.01259,1024', 'Leo Artaza,0.0137,1013,0.01259,1025', 'Lawrence Teo,0.01385,1172,0.0126,1026', 'k.wata,0.01374,1065,0.0126,1027', 'developerX,0.01378,1092,0.0126,1028', 'Trust your sons,0.01351,155,0.01261,1029', 'Aruna Ojha,0.01393,1246,0.01261,1030', 'Vinita,0.01393,1245,0.01261,1031', 'IvÃ¡n MelÃ©ndez,0.01378,1094,0.01261,1032', 'Team-FM,0.01388,1215,0.01261,1033', 'Data1,0.01393,1249,0.01261,1034', 'Praveen Prakash,0.01393,1244,0.01261,1035', 'neilron,0.01386,1180,0.01262,1036', 'LemuelPR,0.01383,1155,0.01262,1037', 'EJ50,0.01391,1232,0.01262,1038', 'bradleetw2019,0.01387,1199,0.01262,1039', 'hirayuki,0.01386,1184,0.01262,1040', 'Olivier St-Amand,0.01365,846,0.01263,1041', 'Justin #5,0.01394,1258,0.01263,1042', 'sala1900,0.01394,1262,0.01263,1043', 'lionsheep24,0.01373,1056,0.01263,1044', 'Motohiro Sato,0.01394,1257,0.01263,1045', 'Imada Hanako,0.01376,1084,0.01263,1046', 'Youri Matiounine,0.01383,1153,0.01264,1047', 'Hartmut Ott,0.01368,933,0.01264,1048', 'TheDude,0.01379,1099,0.01264,1049', 'rugby-world-cup,0.01362,409,0.01265,1050', 'Adam Jalkemo,0.01382,1142,0.01265,1051', 'taninotsu,0.01385,1169,0.01266,1052', 'jeremypmobley,0.0138,1102,0.01266,1053', 'Randon,0.01387,1205,0.01266,1054', 'hatunina,0.01382,1137,0.01266,1055', 'stephen_mugisha,0.01383,1150,0.01267,1056', 'andre_beton,0.01381,1113,0.01267,1057', 'Alex Sinclair,0.01386,1188,0.01268,1058', 'Dmytro Korduban,0.01376,1088,0.01268,1059', 'Pablo Herrero Quintero,0.01387,1212,0.01268,1060', 'Jason Qiao,0.01383,1154,0.01268,1061', 'Cc_So_Niubility,0.0138,1103,0.01268,1062', 'Jose Espejo,0.01379,1098,0.01269,1063', 'Maximilian Kapsecker,0.01386,1185,0.01269,1064', 'Steffen,0.01389,1226,0.01269,1065', 'adam,0.01384,1164,0.0127,1066', 'Mitch Williams,0.01393,1247,0.0127,1067', 'Hot Yinzer Takes,0.01391,1234,0.0127,1068', 'Gultekin Gunduz,0.01341,110,0.0127,1069', 'Dan Kinn,0.01381,1109,0.0127,1070', 'Not.That.Hard,0.01392,1235,0.01271,1071', 'Offensive Lines of Code,0.01381,1111,0.01271,1072', 'Beards1120,0.01374,1057,0.01271,1073', 'dmh43,0.01391,1233,0.01271,1074', 'kenmatsu4,0.01392,1241,0.01271,1075', 'Minerva_US,0.01403,1343,0.01272,1076', 'Antonio Rivero,0.01396,1274,0.01272,1077', 'Nathan Hunt,0.01396,1272,0.01272,1078', 'Ben Gorman,0.01392,1236,0.01272,1079', 'noypeban,0.01403,1342,0.01273,1080', 'Aziz Temirkhanov,0.0139,1228,0.01273,1081', 'doodledood,0.01383,1156,0.01273,1082', 'Usman Islam,0.01387,1195,0.01273,1083', 'Sami N,0.01399,1315,0.01274,1084', 'Bill,0.01402,1339,0.01274,1085', 'marugari,0.01405,1360,0.01274,1086', 'water3345,0.01383,1148,0.01274,1087', 'Three people,0.01368,959,0.01275,1088', 'SB_VLC,0.01411,1401,0.01275,1089', 'Justin Dumouchelle,0.01395,1269,0.01276,1090', 'Noud,0.01388,1214,0.01276,1091', 'Tom Rodenhagen,0.01394,1252,0.01277,1092', 'Kellen Blumberg,0.01401,1326,0.01277,1093', 'JackSoslow,0.01392,1239,0.01277,1094', 'Marc JONOT,0.01394,1264,0.01277,1095', 'Data Bandidos ðŸŒ®,0.01398,1297,0.01277,1096', 'tsuka,0.01381,1108,0.01278,1097', 'Limitless,0.01398,1299,0.01278,1098', 'Imen Ferjani,0.01398,1296,0.01278,1099', '3sigma,0.01398,1295,0.01278,1100', 'A-team,0.01395,1271,0.01278,1101', 'polo,0.01398,1294,0.01278,1102', 'Rafay,0.01398,1293,0.01278,1103', 'SeongYunByeon,0.01398,1292,0.01278,1104', 'Peter CXL,0.01398,1281,0.01278,1105', 'Gopi Durgaprasad,0.01398,1282,0.01278,1106', 'these_guys,0.01398,1283,0.01278,1107', 'Arnold Kuo,0.01398,1285,0.01278,1108', 'Hao Tian,0.01398,1286,0.01278,1109', 'Alex Ovsyannikov,0.01398,1287,0.01278,1110', 'zhangxin,0.01398,1288,0.01278,1111', 'Benjamin Coudrin,0.01398,1289,0.01278,1112', 'Sergey Demchenko,0.01398,1301,0.01278,1113', 'TerrenceDonald,0.01398,1290,0.01278,1114', 'RAJESH_PARTHASARATHY_NAMAGIRI,0.01398,1302,0.01278,1115', 'Yuma Suzuki,0.01382,1132,0.01278,1116', 'Bonoron,0.01398,1308,0.01278,1117', 'Eliseev Dan,0.01398,1309,0.01278,1118', 'vybhavp,0.01398,1306,0.01278,1119', 'é¸½çŽ‹å¤§èµ›,0.01398,1305,0.01278,1120', 'tkuri,0.01398,1307,0.01278,1121', 'Darshan Patel,0.01398,1310,0.01278,1122', 'ZNing,0.01398,1304,0.01278,1123', 'Santhosh #2,0.01398,1303,0.01278,1124', 'Kostiantyn Isaienkov,0.01388,1219,0.01278,1125', 'dngeo17,0.01398,1311,0.01278,1126', 'forestchen,0.01399,1319,0.01278,1127', 'DW Zhang,0.01387,1197,0.01278,1128', 'Miyatti,0.01385,1168,0.01278,1129', 'Meyran,0.01394,1256,0.01279,1130', 'MQM Trinity Force,0.01398,1284,0.0128,1131', 'Bananalytics,0.01395,1267,0.0128,1132', 'VladB,0.01412,1405,0.0128,1133', 'Abhik Jha,0.01394,1250,0.0128,1134', 'YerneðŸ\x90‰,0.01394,1253,0.0128,1135', 'predictingnoise,0.01394,1254,0.0128,1136', 'ZheLI,0.01394,1255,0.0128,1137', 'Team-A*R*T,0.01394,1265,0.0128,1138', 'Kirill Zaitsev,0.01394,1251,0.0128,1139', 'Ray Lee,0.01394,1260,0.0128,1140', 'Reggie,0.01394,1261,0.0128,1141', 'Stefan PrÃ¼fer,0.01396,1275,0.01281,1142', 'MarcelFlygare,0.01398,1300,0.01281,1143', 'Devin Anzelmo,0.01399,1313,0.01281,1144', 'Yaroslav Samoilov,0.01407,1374,0.01282,1145', 'miguel perez,0.0139,1227,0.01282,1146', 'billyClanton,0.01387,1198,0.01283,1147', 'PAT,0.01396,1273,0.01284,1148', 'cs18mds11016,0.0141,1394,0.01284,1149', 'govindha,0.0141,1395,0.01284,1150', 'statnik,0.01393,1248,0.01284,1151', 'Johann Haas,0.01419,1471,0.01284,1152', '229,0.01403,1347,0.01285,1153', 'Megatron,0.01391,1231,0.01285,1154', 'Jo Jimbo,0.01392,1238,0.01286,1155', 'GGPLOT2,0.01404,1356,0.01286,1156', 'Fernando Pereira,0.01399,1317,0.01286,1157', 'AIvar,0.01399,1314,0.01286,1158', 'Electric Light Bulb,0.01406,1369,0.01286,1159', 'mick77rus,0.01401,1329,0.01286,1160', 'Robert Simpson,0.014,1322,0.01286,1161', 'ryches,0.01397,1278,0.01286,1162', 'Tam D,0.01417,1446,0.01286,1163', 'threecourse,0.01415,1425,0.01287,1164', 'UPenn Team,0.01412,1410,0.01287,1165', 'deep_panda,0.01406,1368,0.01287,1166', 'ponythewhite,0.01392,1242,0.01287,1167', 'Marius BjÃ¸rkli,0.01398,1298,0.01287,1168', 'ML_Expert_Silicon_Valley,0.01401,1327,0.01287,1169', 'kgglstartup,0.01387,1202,0.01287,1170', 'CS18MDS11001,0.01404,1350,0.01288,1171', 'Lu Tang,0.01431,1554,0.01288,1172', 'Marcelo Li Koga,0.0141,1397,0.01288,1173', 'ahmed zaky,0.01393,1243,0.01288,1174', 'WangMH,0.01382,1136,0.01288,1175', 'asilon,0.014,1323,0.01289,1176', 'The Secret,0.01403,1341,0.01289,1177', 'ä¸\x8dä¹\x90æ— è¯\xad,0.01403,1345,0.01289,1178', 'Deep Shah,0.01416,1433,0.0129,1179', 'Tom Wood,0.01411,1402,0.0129,1180', 'ktpazder,0.01423,1502,0.0129,1181', 'alizaky,0.01402,1333,0.0129,1182', 'Balaji Selvaraj,0.01397,1279,0.0129,1183', 'LÃ©onard Deroose,0.01408,1382,0.01291,1184', 'Pablo,0.01408,1387,0.01291,1185', 'Yongke,0.01407,1376,0.01291,1186', 'Bowen Peng,0.01405,1365,0.01291,1187', 'William Laprade,0.01403,1346,0.01291,1188', 'Jonathan Bown,0.01395,1266,0.01291,1189', 'DataRockstar,0.01382,1139,0.01292,1190', 'Nikhil Gupta,0.01409,1390,0.01292,1191', 'Team Room 42,0.01399,1321,0.01292,1192', 'Santhosh,0.01405,1367,0.01292,1193', 'default,0.01404,1352,0.01292,1194', 'Tiago M. Leite,0.01399,1318,0.01292,1195', 'Keep Pounding,0.01395,1270,0.01292,1196', 'Dmitry Dryomov,0.01411,1399,0.01293,1197', 'Vincent Yong,0.0138,1105,0.01293,1198', 'Tetsuto,0.01386,1179,0.01293,1199', 'dankouji,0.01403,1348,0.01293,1200', 'ShedrickBridgeforth,0.0141,1396,0.01293,1201', 'tetz0024,0.01387,1206,0.01293,1202', 'ItalicLoveGun,0.01407,1379,0.01294,1203', 'Matt McMullan,0.01408,1385,0.01294,1204', 'ako,0.01401,1330,0.01294,1205', 'la_xx,0.01406,1370,0.01294,1206', 'prasoon kottarathil,0.01405,1361,0.01294,1207', 'thisisnew,0.01407,1380,0.01294,1208', 'don m meyer,0.01411,1400,0.01294,1209', 'Mike Hall,0.01405,1357,0.01294,1210', 'random_seed=42,0.01403,1340,0.01294,1211', 'why4,0.01402,1335,0.01294,1212', 'Devon Shurick,0.01413,1411,0.01294,1213', 'DJ Christy,0.01399,1312,0.01294,1214', 'PengJu Zhang,0.01407,1381,0.01294,1215', 'Mohsen SADOK,0.01405,1359,0.01295,1216', 'Eiji Konaka,0.01417,1450,0.01295,1217', 'Darkhan Nurakhmetov,0.01408,1384,0.01295,1218', 'Daniel Sobrado,0.01407,1377,0.01295,1219', 'Dollars4Donuts,0.01415,1423,0.01295,1220', 'cubictoaster,0.01421,1479,0.01295,1221', 'Edward Wheatcroft,0.01421,1482,0.01295,1222', 'Guilherme Campos,0.01404,1351,0.01295,1223', 'NAldershof,0.01418,1458,0.01295,1224', 'NPC648,0.01404,1355,0.01295,1225', 'is jab,0.01398,1291,0.01295,1226', 'Team Prakrut-Nick,0.01432,1557,0.01295,1227', 'Dennis Leszkowicz,0.01405,1366,0.01295,1228', 'jgeiman,0.01402,1334,0.01295,1229', 'OCEAN,0.01419,1472,0.01295,1230', 'huiqin,0.01402,1336,0.01295,1231', 'Speed Snail,0.01409,1391,0.01296,1232', 'Uriel Corona,0.01409,1389,0.01296,1233', 'Sreelakshmi Nair,0.01405,1358,0.01296,1234', 'joacoib,0.01405,1364,0.01296,1235', 'MIT Team,0.01416,1442,0.01297,1236', 'å¤§åŠ›å‡ºå¥‡è¿¹,0.01402,1338,0.01297,1237', 'Harry Hu,0.01421,1486,0.01297,1238', 'orishko,0.01403,1344,0.01297,1239', 'Rees,0.01446,1657,0.01297,1240', 'forward,0.01417,1447,0.01298,1241', 'Sunny Mulchandani,0.01424,1508,0.01298,1242', 'AASaaS,0.01414,1417,0.01298,1243', 'SimonW & SonamP,0.01418,1467,0.01298,1244', 'LiangXi,0.01408,1383,0.01298,1245', 'Dzmitry Shakhrai,0.01436,1599,0.01298,1246', 'Tim H,0.01424,1505,0.01299,1247', 'Martin Matta,0.01406,1372,0.01299,1248', 'CaseyPeters,0.01415,1421,0.01299,1249', 'dmcdiarmid,0.01413,1415,0.01299,1250', 'haterol,0.01424,1504,0.01299,1251', 'Salman,0.01426,1530,0.013,1252', 'claverru,0.01424,1509,0.013,1253', 'mehrler,0.01415,1427,0.013,1254', 'abhinavm24,0.01433,1567,0.013,1255', 'Kota Iizuka,0.01412,1406,0.013,1256', 'Sir Andrew,0.01421,1478,0.013,1257', 'Dalek,0.0141,1393,0.013,1258', 'denkimagic,0.01423,1496,0.013,1259', 'Bunnyhanhan,0.01416,1438,0.013,1260', 'chuck_thunder,0.01412,1408,0.013,1261', 'kalikichandu,0.01423,1494,0.013,1262', 'Max Halford,0.0143,1549,0.01301,1263', 'Ingmar43,0.01416,1429,0.01301,1264', 'Robin Lingwood,0.01417,1452,0.01301,1265', 'siliconlips,0.01407,1375,0.01301,1266', 'yfee,0.01417,1448,0.01301,1267', 'naknak,0.01418,1454,0.01301,1268', 'kolpshnikova,0.01418,1456,0.01301,1269', 'lambdabest,0.01413,1412,0.01301,1270', 'ThomasAnthony,0.01424,1506,0.01301,1271', 'Prachi,0.0142,1474,0.01301,1272', 'Yosuke KOBAYASHI,0.01428,1544,0.01301,1273', 'takmanman,0.0142,1475,0.01301,1274', 'Joe Young,0.0142,1477,0.01301,1275', 'bitmapand,0.01418,1459,0.01302,1276', 'Kenko Nakamura,0.01418,1465,0.01302,1277', 'Matthew P. McAteer,0.01416,1443,0.01302,1278', 'mohi12345,0.01417,1451,0.01302,1279', 'remisharoon,0.01425,1517,0.01302,1280', 'ScottSchriner,0.01418,1457,0.01302,1281', 'EndInTears,0.01418,1462,0.01302,1282', 'Andrew,0.01415,1428,0.01302,1283', 'Mohammed Qadir Khan,0.01407,1378,0.01302,1284', 'SR,0.01415,1420,0.01302,1285', 'Booty Poppers,0.01415,1422,0.01302,1286', 'Will Rose,0.01428,1540,0.01302,1287', 'statexchange,0.01415,1426,0.01302,1288', 'FELIZ,0.01409,1392,0.01302,1289', 'Nigel A. R. Henry,0.01413,1413,0.01302,1290', 'Manraj Singh,0.01416,1431,0.01302,1291', 'Nick W,0.01413,1414,0.01302,1292', 'Prashant Banerjee,0.01416,1436,0.01302,1293', 'Maxim555,0.01425,1515,0.01303,1294', 'semprecalando,0.01423,1498,0.01303,1295', 'kstats,0.01416,1435,0.01303,1296', 'grinningSEAL,0.01418,1455,0.01303,1297', 'Sumiyama Fumitaka,0.01417,1445,0.01303,1298', 'currypurin,0.01431,1552,0.01303,1299', 'JohnGeorge3,0.01416,1439,0.01303,1300', 'Phil Butcher,0.01424,1514,0.01303,1301', 'Berkeley W207,0.01424,1513,0.01303,1302', 'fingeeker,0.01439,1645,0.01303,1303', 'wangjiade1015,0.01424,1512,0.01303,1304', 'Alex Galantsev,0.01416,1432,0.01303,1305', 'Droughns,0.01427,1533,0.01304,1306', 'Nicolas Wesner,0.01421,1480,0.01304,1307', 'jumdar,0.01413,1416,0.01304,1308', 'SA0987,0.01422,1490,0.01304,1309', 'Rutvik Lathiya,0.01416,1444,0.01304,1310', 'zvone,0.01418,1464,0.01304,1311', 'Mr Goose,0.01414,1419,0.01304,1312', 'ValeriyBabushkin,0.01431,1553,0.01305,1313', 'rahul yadav,0.01425,1519,0.01305,1314', 'seaguII,0.01423,1499,0.01305,1315', 'SÃ©bastien MATHIEU,0.01417,1449,0.01305,1316', 'Sergey Enikeev,0.01416,1441,0.01305,1317', 'yunhu ye,0.01427,1537,0.01305,1318', 'FZambolin,0.01425,1522,0.01305,1319', 'johnxuu,0.01428,1547,0.01305,1320', 'Junye Luo,0.0142,1473,0.01305,1321', 'tsomers,0.01404,1349,0.01305,1322', 'MichaÅ‚ MarciÅ„czuk,0.01419,1469,0.01305,1323', 'Siddharth Yadav,0.01419,1468,0.01305,1324', 'Aicanghai_Smile,0.01418,1466,0.01305,1325', 'ymtmytk,0.01427,1532,0.01305,1326', 'Igeta Kazu,0.01426,1528,0.01306,1327', 'Julien RoullÃ©,0.01424,1503,0.01306,1328', 'antwerp,0.01423,1501,0.01306,1329', 'Zuoqiao Shen,0.01424,1511,0.01306,1330', 'Team PBD,0.01425,1523,0.01306,1331', 'user_san,0.01419,1470,0.01306,1332', 'Maxenso,0.01421,1484,0.01306,1333', 'yhchen2018,0.01479,1693,0.01306,1334', 'Shi Zhenyu,0.01438,1641,0.01306,1335', 'Jerry Gonzalez,0.01428,1545,0.01306,1336', 'alants,0.01418,1460,0.01306,1337', 'Woo Sung Jang,0.01422,1488,0.01306,1338', 'DarrenTitor,0.01426,1531,0.01307,1339', 'Jose,0.01422,1487,0.01307,1340', 'GammaBros,0.01407,1373,0.01307,1341', '_TÃ¯_,0.01439,1646,0.01307,1342', 'McSnappy,0.01421,1485,0.01307,1343', 'Gannon Traynor,0.01426,1527,0.01307,1344', 'NickNapier,0.01426,1526,0.01307,1345', 'jung sun woo,0.01427,1536,0.01308,1346', 'Luke Metz,0.01422,1491,0.01308,1347', 'Tatsuya Izuka,0.01425,1520,0.01308,1348', 'ume08,0.01427,1539,0.01308,1349', 'Unstetig,0.01401,1331,0.01308,1350', 'Luke Plewa,0.01432,1563,0.01308,1351', 'davidsteinandfriends,0.01433,1570,0.01308,1352', 'AndyOlivers,0.01427,1534,0.01308,1353', 'Hidayat Lee,0.0143,1550,0.01308,1354', 'jousle,0.01423,1500,0.01308,1355', 'Alex Paxton,0.01426,1529,0.01308,1356', 'Mr.Qiang,0.01427,1535,0.01308,1357', 'GianPaolob,0.01416,1440,0.01308,1358', 'Alexys Pereira,0.01433,1568,0.01309,1359', 'Toto,0.01428,1541,0.01309,1360', 'AshutoshSharma,0.01425,1525,0.01309,1361', 'RSY,0.01421,1481,0.01309,1362', 'shilpa.rpns,0.01425,1521,0.01309,1363', 'PratheekMBharadwaj,0.01425,1516,0.01309,1364', 'Pirafu,0.01387,1208,0.01309,1365', 'tanegoman,0.01425,1524,0.01309,1366', 'Reese Haywood,0.01418,1463,0.01309,1367', 'ukkuruza,0.01416,1430,0.0131,1368', 'Keisuke Daimon,0.01427,1538,0.0131,1369', 'boulderslayer,0.01434,1575,0.0131,1370', 'Diogo Gomes,0.01386,1190,0.0131,1371', 'Jordan,0.01428,1546,0.01311,1372', 'SVJ24,0.01428,1542,0.01311,1373', 'rokiso,0.01423,1497,0.01311,1374', 'Amal V Nair,0.01424,1510,0.01311,1375', 'Zoe3,0.01429,1548,0.01311,1376', 'matsu32,0.01428,1543,0.01312,1377', 'Yasuaki Koshiji,0.01433,1566,0.01312,1378', 'Aleks Dominik,0.01445,1656,0.01312,1379', 'Omar Ismail,0.01432,1565,0.01312,1380', 'Jayaram,0.01456,1675,0.01312,1381', 'Andriy G,0.01488,1695,0.01312,1382', 'Daeshy,0.01418,1461,0.01313,1383', 'Fei. Zhang,0.01386,1178,0.01313,1384', 'Jack tao,0.01437,1634,0.01315,1385', 'Vishky,0.01536,1702,0.01315,1386', 'onishi,0.01388,1217,0.01316,1387', 'Do Phuc,0.01434,1571,0.01316,1388', 'Ivan Afanasev,0.01434,1572,0.01316,1389', 'SiChao Liu,0.01434,1573,0.01316,1390', 'Alan #3,0.01437,1633,0.01316,1391', 'Kirill Vladimirov,0.01434,1591,0.01316,1392', 'ddq1988,0.01434,1576,0.01316,1393', 'Shobha Sriram,0.01434,1589,0.01316,1394', 'TI,0.01434,1577,0.01316,1395', 'Jeffrey Scholz,0.01434,1578,0.01316,1396', 'tsanok,0.01434,1588,0.01316,1397', 'DownUnderData,0.01434,1581,0.01316,1398', 'Jefferson,0.01434,1586,0.01316,1399', 'Sahil Mishra,0.01434,1584,0.01316,1400', 'mithos,0.01434,1583,0.01316,1401', 'vov_or,0.01434,1574,0.01316,1402', 'rakuraku 21,0.01422,1489,0.01316,1403', 'AksanBA,0.01437,1635,0.01317,1404', 'Priyanshu Kumar,0.0149,1696,0.01317,1405', 'Hartorn,0.01436,1611,0.01317,1406', 'Amico and Jones,0.01432,1559,0.01317,1407', 'GarrettStreet,0.01434,1590,0.01317,1408', 'Konstantin Shamruk,0.01431,1555,0.01317,1409', 'narsil,0.01421,1483,0.01318,1410', 'Spencer Cushman,0.01434,1587,0.01318,1411', 'hrappuccino,0.01422,1492,0.01318,1412', 'C4rl05/V,0.0153,1700,0.01319,1413', 'dylan,0.01417,1453,0.01319,1414', 'Rushikesh Joshi,0.0144,1649,0.01319,1415', 'solohayuna,0.01436,1612,0.0132,1416', 'Kasper P. Lauritzen,0.01436,1610,0.0132,1417', 'William Fleshman,0.01436,1609,0.0132,1418', 'Telaro,0.01436,1607,0.0132,1419', 'horohoro,0.01388,1213,0.0132,1420', 'bringbroiler,0.01436,1615,0.0132,1421', 'Thorn,0.01436,1606,0.0132,1422', 'JoÃ£o GonÃ§alves,0.01436,1617,0.0132,1423', 'Durham Bull Rushers,0.01436,1618,0.0132,1424', 'Uri Z,0.01436,1619,0.0132,1425', 'mzmzmz,0.01436,1620,0.0132,1426', 'Chuanyu Yao,0.01436,1622,0.0132,1427', 'Ahyoung Song,0.01436,1623,0.0132,1428', 'hehpollon,0.01436,1624,0.0132,1429', '(2/3)Trinca+B,0.01436,1625,0.0132,1430', 'Captain Awesome,0.01437,1632,0.0132,1431', 'steelRstats,0.01437,1627,0.0132,1432', 'matsuboccri,0.01437,1628,0.0132,1433', 'pies,0.01436,1614,0.0132,1434', 'grobot,0.01436,1604,0.0132,1435', 'Adrian Celaya,0.01439,1643,0.0132,1436', 'RenÃ© Blaim,0.01437,1630,0.0132,1437', 'BlueJay,0.01436,1602,0.0132,1438', 'kengow,0.01436,1598,0.0132,1439', 'hoxosh,0.01436,1595,0.0132,1440', 'Sophie Antoniak,0.01435,1592,0.0132,1441', 'Smaba,0.01334,79,0.0132,1442', 'Grisha,0.01448,1660,0.0132,1443', 'Andres the cockroach,0.01438,1637,0.0132,1444', 'Nikita Kotelevskii,0.01437,1631,0.0132,1445', 'digimagi,0.01438,1640,0.01321,1446', 'Kabir Singh,0.01438,1638,0.01321,1447', 'PMF,0.01436,1597,0.01321,1448', 'Bruno Gorresen Mello,0.01411,1403,0.01321,1449', 'Sam Oâ€™Connell,0.01441,1651,0.01321,1450', 'avati,0.0143,1551,0.01321,1451', 'Cheese,0.01432,1558,0.01321,1452', 'Robin Jackson,0.01436,1605,0.01322,1453', 'Hailiang Du,0.01436,1621,0.01322,1454', 'saewonYang,0.01436,1603,0.01322,1455', 'Takao,0.01431,1556,0.01322,1456', 'Kostas H.,0.01432,1560,0.01323,1457', 'mANDy,0.01436,1601,0.01323,1458', 'The Mathletes,0.01437,1636,0.01323,1459', 'A goofy team,0.01453,1672,0.01324,1460', 'zuo wang,0.01423,1495,0.01324,1461', 'Kusunoki Chihiro,0.01432,1564,0.01324,1462', 'gorilladoi,0.01432,1562,0.01324,1463', 'Robert McKee,0.01362,494,0.01324,1464', 'Hear Fur Da MoolÃ£h,0.01437,1629,0.01325,1465', 'Nico Magu,0.01469,1687,0.01325,1466', 'Drastamat,0.01436,1600,0.01325,1467', 'Model builder,0.01434,1580,0.01325,1468', 'Shiki,0.01444,1654,0.01326,1469', 'poxiao,0.0144,1650,0.01327,1470', 'Tim Moore,0.01455,1673,0.01327,1471', 'faucet,0.01442,1652,0.01327,1472', 'Divya Shah,0.01458,1680,0.01328,1473', 'Matthias B,0.0144,1648,0.01328,1474', 'Nicolas Drewniak,0.01442,1653,0.01329,1475', 'Eduardo Rojas,0.01438,1639,0.01329,1476', 'Afonso Cunha,0.01384,1165,0.01329,1477', 'Roy Perry,0.0145,1664,0.01329,1478', 'HOZHEN,0.01439,1642,0.0133,1479', 'Brandon,0.01451,1667,0.01331,1480', 'MichaelSmith,0.01434,1582,0.01332,1481', 'Cebo,0.01451,1665,0.01333,1482', 'AYOUB ZAROU,0.01451,1666,0.01334,1483', 'PyVyz,0.01448,1659,0.01335,1484', 'Carlos Giraldo,0.01466,1686,0.01335,1485', 'druggist,0.01457,1678,0.01336,1486', 'arif romadhan,0.01457,1677,0.01337,1487', 'Naren,0.01457,1676,0.01337,1488', 'Markus Plack,0.01447,1658,0.01338,1489', 'resory,0.01465,1684,0.01339,1490', 'znstrider,0.01453,1671,0.01339,1491', 'Michal Sroka,0.01472,1689,0.01339,1492', 'IvoL,0.01451,1668,0.01344,1493', 'Sasase,0.01473,1690,0.01347,1494', 'Haakon E. Nustad,0.0147,1688,0.01347,1495', 'Shozen Dan,0.01475,1691,0.01349,1496', 'Bengalstro,0.01463,1683,0.01353,1497', 'Davide Anastasia,0.01459,1682,0.01353,1498', 'devrishi,0.01466,1685,0.01356,1499', 'NeverWatchNFL,0.01456,1674,0.01359,1500', 'Will Yin,0.0145,1663,0.01362,1501', 'warrarougundji,0.01453,1669,0.01363,1502', 'Guillermo GutiÃ©rrez,0.01476,1692,0.01365,1503', 'Vilen Jumutc,0.01501,1698,0.01372,1504', 'Aviv Levi,0.01408,1386,0.01374,1505', 'pixel,0.0148,1694,0.01374,1506', 'Ehsan,0.01495,1697,0.01376,1507', 'novanova,0.01546,1705,0.01377,1508', 'ploenzke,0.01513,1699,0.01378,1509', 'AbdurRafae,0.01439,1644,0.01386,1510', 'Seika_Miya,0.02212,2009,0.01389,1511', 'The Data Miners,0.01583,1748,0.0139,1512', 'tora can,0.01542,1704,0.01405,1513', 'JohnM,0.01336,90,0.01407,1514', 'Madden2KFifa,0.01533,1701,0.01414,1515', 'Dan Namba,0.01563,1716,0.01417,1516', 'amanemisa,0.0156,1714,0.01421,1517', 'reilp38,0.01554,1710,0.01421,1518', 'Shahules786,0.01459,1681,0.01423,1519', 'Iatco Sergiu,0.01632,1832,0.0143,1520', 'UE Football,0.0154,1703,0.01434,1521', 'meth,0.01557,1712,0.01437,1522', 'YaselGarcÃ©sSuÃ¡rez,0.01551,1706,0.01438,1523', 'Mehdi Kashef,0.01612,1820,0.01439,1524', 'SIMPLE,0.01562,1715,0.01444,1525', 'CS18MDS11005,0.01553,1709,0.01446,1526', 'Shohei Goda,0.01556,1711,0.01448,1527', 'Pim88,0.01579,1739,0.0145,1528', 'darthvader,0.01575,1726,0.01452,1529', 'CS18MDS11023,0.0158,1742,0.01454,1530', 'RenatoDeggau,0.01576,1730,0.0146,1531', 'GoodNine,0.01575,1723,0.01461,1532', 'gameofthodes,0.01575,1724,0.01461,1533', 'Pebble,0.01575,1725,0.01461,1534', 'Kuntal Chakraborty,0.01575,1728,0.01461,1535', 'Nelson Hong Ming Tseng,0.01575,1722,0.01461,1536', 'TTang,0.01574,1719,0.01461,1537', 'Fernando Contreras,0.01575,1727,0.01461,1538', 'john24142,0.01386,1182,0.01461,1539', 'Åžems Kurtoglu,0.01385,1170,0.01462,1540', 'Blazej,0.01587,1756,0.01462,1541', 'KEISUKE,0.01387,1203,0.01463,1542', 'gg,0.01574,1721,0.01463,1543', 'Michael Maguire,0.01579,1740,0.01464,1544', 'theheena,0.01552,1708,0.01464,1545', 'Pablo Lobato,0.01582,1746,0.01466,1546', 'Parul Pandey,0.01577,1733,0.01468,1547', 'StephenSmith,0.01576,1729,0.01468,1548', 'CS18MDS11006,0.01574,1720,0.01469,1549', 'Shasa,0.0158,1741,0.01469,1550', 'CS18MDS11030,0.01576,1731,0.01469,1551', 'sasakama,0.01582,1747,0.0147,1552', 'ByungSunBae,0.01578,1738,0.0147,1553', 'MichaelBeers,0.01578,1735,0.01471,1554', 'ren lei,0.01572,1718,0.01471,1555', 'Kagawa Keisuke,0.0159,1762,0.01471,1556', 'Danila Otnyukov,0.01585,1751,0.01471,1557', 'Becon,0.01585,1753,0.01471,1558', 'A Humphrey,0.01587,1757,0.01471,1559', 'SPhillips,0.01589,1760,0.01472,1560', 'Hamitcan MalkoÃ§,0.01578,1736,0.01472,1561', 'Kaushal Shah,0.01578,1737,0.01472,1562', 'CS18MDS11002,0.01585,1754,0.01472,1563', 'Damilola Gbenle,0.01453,1670,0.01473,1564', 'Centrycs,0.01577,1734,0.01474,1565', 'yuton,0.0158,1743,0.01474,1566', 'The cosmopolitain pretender,0.01581,1745,0.01475,1567', 'Anirudh Raghavan,0.01607,1817,0.01475,1568', 'Archit Gupta,0.01585,1752,0.01475,1569', 'Bob Wang,0.01614,1822,0.01475,1570', 'servase,0.01585,1749,0.01475,1571', 'Eguy,0.01585,1750,0.01476,1572', 'Allison Rountree,0.01588,1758,0.01477,1573', 'MoisÃ©s Riestra,0.016,1772,0.01477,1574', 'NRC,0.01599,1767,0.01478,1575', 'Srinivas,0.01588,1759,0.01478,1576', 'Akira Sasaki,0.01602,1811,0.01478,1577', 'konsome,0.01599,1766,0.01478,1578', 'TekoTeko-chan,0.01599,1765,0.01478,1579', 'é\x9d’æœ¨ç™½ç¾Š,0.016,1786,0.01479,1580', 'Gustavo Bakker,0.016,1782,0.01479,1581', 'Ali Esm,0.016,1783,0.01479,1582', 'Ken Ho,0.016,1784,0.01479,1583', 'WSTeam,0.016,1785,0.01479,1584', 'talesofyousan,0.016,1807,0.01479,1585', '00yq,0.016,1787,0.01479,1586', 'Love agarwal,0.016,1788,0.01479,1587', 'WJSNSeola,0.016,1789,0.01479,1588', 'Beta,0.016,1790,0.01479,1589', 'Kranti Kumar,0.016,1791,0.01479,1590', 'ajiajiajiaji,0.016,1792,0.01479,1591', 'Ilikeev Bilal,0.016,1793,0.01479,1592', 'ykmaku,0.016,1794,0.01479,1593', 'azis,0.016,1795,0.01479,1594', 'shintaro,0.016,1796,0.01479,1595', 'ynarita,0.016,1797,0.01479,1596', 'Seradja,0.016,1798,0.01479,1597', 'Akki,0.016,1799,0.01479,1598', 'Qi Pan,0.016,1800,0.01479,1599', 'Saber,0.016,1801,0.01479,1600', 'GrzesiekM,0.016,1802,0.01479,1601', 'Daikon,0.016,1803,0.01479,1602', 'ChibiYuki,0.016,1804,0.01479,1603', 'Ryo Tomizawa,0.016,1781,0.01479,1604', 'wakarimi,0.016,1780,0.01479,1605', 'adamyd,0.016,1777,0.01479,1606', 'Travelor,0.016,1778,0.01479,1607', 'LogicJake,0.01586,1755,0.01479,1608', 'PC Jimmmy,0.01603,1813,0.01479,1609', 'R.Mutt,0.01449,1661,0.01479,1610', 'Jacob Rose,0.01603,1812,0.01479,1611', 'Falcons,0.016,1779,0.01479,1612', 'sept,0.016,1768,0.01479,1613', 'Niyamat Ullah,0.016,1769,0.01479,1614', 'Mohamad Falah,0.01387,1204,0.01479,1615', '10462709,0.016,1771,0.01479,1616', 'Matteo Cati,0.016,1770,0.01479,1617', 'Morty Zhang,0.016,1776,0.01479,1618', 'masamichi_14,0.016,1775,0.01479,1619', 'Tyler,0.016,1773,0.01479,1620', 'Shohei Yamaguchi,0.016,1805,0.01479,1621', 'TheAINerds,0.016,1808,0.01479,1622', 'Toyonosuke Toyohama,0.016,1806,0.01479,1623', 'CS18MDS11028,0.01718,1855,0.01481,1624', 'Ralph Neumann,0.01601,1810,0.01482,1625', 'Saulius Tautvaisas,0.01649,1836,0.01482,1626', 'Hyoseok Seo,0.01649,1835,0.01482,1627', 'Chibadai,0.01603,1815,0.01483,1628', 'RickArko,0.01387,1207,0.01483,1629', 'asqtzal,0.01589,1761,0.01483,1630', 'SN,0.01603,1814,0.01485,1631', 'nissy,0.01594,1764,0.01486,1632', 'Haruka Nakashima,0.01615,1824,0.0149,1633', 'ConorM,0.0157,1717,0.01491,1634', 'IvoFilipe,0.01614,1823,0.01492,1635', 'narain p,0.01552,1707,0.01493,1636', 'Errol Pereira,0.01612,1819,0.01494,1637', 'Rshad Zhran,0.01624,1828,0.01495,1638', 'ä»Šæ™šæ‰“è€\x81è™Ž,0.01762,1863,0.01503,1639', 'ricardoCSAG,0.01606,1816,0.01504,1640', 'SusheendharVijay,0.01619,1826,0.01516,1641', 'Liyang,0.01627,1830,0.01517,1642', '[AI@UCF] Big Thonk,0.01594,1763,0.01518,1643', 'Andrey Pavlov,0.01622,1827,0.01518,1644', 'Djamel Khebab,0.01647,1834,0.01523,1645', 'jamalc,0.01668,1842,0.01526,1646', 'Ioannis M,0.01625,1829,0.01526,1647', 'Goto Yugo,0.0167,1843,0.01527,1648', 'godymevol,0.01708,1853,0.01536,1649', '@doanquanvietnamca,0.01631,1831,0.01537,1650', 'yoyoyo,0.01661,1841,0.01539,1651', 'ANTON Baxdela,0.01661,1840,0.01539,1652', 'Luis Garavaso,0.01677,1846,0.01541,1653', 'RyanCMcV,0.01674,1844,0.01546,1654', 'MakotoTanji,0.01658,1837,0.01556,1655', 'Marschall Furman,0.01718,1854,0.01563,1656', 'CS18MDS11010,0.01676,1845,0.01565,1657', 'heh mda,0.01772,1865,0.01568,1658', 'abromberg,0.01686,1849,0.0157,1659', 'sunilcube,0.01704,1852,0.01579,1660', 'user,0.01612,1818,0.01585,1661', 'Ramadan,0.01757,1862,0.01588,1662', 'Maxime Berenger,0.01684,1848,0.0159,1663', 'Abhi,0.01742,1861,0.01613,1664', 'govindam,0.0156,1713,0.01619,1665', 'Josh K,0.01809,1871,0.01622,1666', 'yuto.s,0.01733,1859,0.01625,1667', 'Kiely Pak,0.01727,1857,0.01625,1668', 'Ace_huang,0.01381,1112,0.01629,1669', 'Syracuse Sport Analytics,0.01774,1866,0.0164,1670', 'Andy_Maricopa,0.01731,1858,0.01642,1671', 'TeamSX,0.01827,1877,0.01667,1672', 'MadCoder,0.0178,1867,0.0167,1673', 'EconGuy,0.01823,1875,0.01675,1674', 'Kyle Marshall,0.01449,1662,0.01676,1675', 'Ellis K,0.01795,1869,0.01678,1676', 'DKim,0.01807,1870,0.01681,1677', 'Heisenberg,0.01821,1873,0.01688,1678', 'kagren,0.01433,1569,0.01689,1679', 'Ricardo Stamato,0.01821,1874,0.01697,1680', 'DocSavage,0.01834,1879,0.01705,1681', 'Our Gordon Savior,0.01834,1878,0.01705,1682', 'Carryon Calvin,0.01826,1876,0.01707,1683', 'Austin Brown,0.01844,1881,0.01707,1684', 'FatimaZahraeGasmi,0.01581,1744,0.01707,1685', 'CS18MDS11025,0.01841,1880,0.01709,1686', 'yasu,0.01735,1860,0.01717,1687', 'JasonZivkovic,0.0185,1882,0.01724,1688', 'Nyangao,0.01861,1884,0.01726,1689', 'Phil Walsh,0.01858,1883,0.01726,1690', 'JimmyP,0.01865,1939,0.01729,1691', 'Pranjal Gangwar,0.01865,1938,0.01729,1692', 'mahesh,0.01865,1937,0.01729,1693', 'Fredrick Neo,0.01865,1936,0.01729,1694', 'Kampachi,0.01865,1941,0.01729,1695', 'chengc,0.01865,1942,0.01729,1696', 'JonasKrueger,0.01865,1943,0.01729,1697', 'cs18mds11012,0.01865,1935,0.01729,1698', 'ArnikaKumar,0.01865,1940,0.01729,1699', 'robert1003,0.01865,1934,0.01729,1700', 'cdonohue,0.01865,1931,0.01729,1701', 'y.ume,0.01865,1944,0.01729,1702', 'Jonny Bouthilet,0.01865,1924,0.01729,1703', 'Joseph Szabo,0.01865,1925,0.01729,1704', 'yoshino,0.01865,1926,0.01729,1705', 'Diego Campo,0.01865,1927,0.01729,1706', 'Tony Sysoev,0.01865,1928,0.01729,1707', 'Yugendran,0.01865,1932,0.01729,1708', 'Niklas,0.01865,1929,0.01729,1709', 'lokeshaggarwal11,0.01865,1930,0.01729,1710', 'Scott Hanna-Riggs,0.01865,1933,0.01729,1711', 'JoÃ£o Felix,0.01865,1945,0.01729,1712', 'wire,0.01865,1923,0.01729,1713', 'urmil12345,0.01865,1947,0.01729,1714', 'Z Dog,0.01865,1964,0.01729,1715', 'NFL?!,0.01865,1965,0.01729,1716', 'Laurent R.,0.01865,1966,0.01729,1717', 'Cory Wilson,0.01865,1967,0.01729,1718', 'matheus,0.01865,1968,0.01729,1719', 'FEILI,0.01865,1969,0.01729,1720', 'Samdish Arora,0.01865,1970,0.01729,1721', 'Seonghyeon Lee,0.01865,1963,0.01729,1722', 'Florian Schwarz,0.01865,1961,0.01729,1723', 'Rock W,0.01865,1946,0.01729,1724', 'TTU - Data Science League,0.01865,1959,0.01729,1725', 'Lamine Gaye,0.01865,1956,0.01729,1726', 'shinsuke27,0.01865,1955,0.01729,1727', 'SkyBlazer,0.01865,1954,0.01729,1728', 'niik,0.01865,1953,0.01729,1729', 'Nakamoto Jiro,0.01865,1952,0.01729,1730', 'wickiwack,0.01865,1951,0.01729,1731', 'amrshoof,0.01865,1950,0.01729,1732', 'Michael Mariboe,0.01865,1949,0.01729,1733', 'Jack Sandom,0.01865,1948,0.01729,1734', 'gusarov.vladislav,0.01865,1958,0.01729,1735', 'JA,0.01865,1922,0.01729,1736', 'JaredNielsen,0.01436,1626,0.01729,1737', 'Devin Davis,0.01865,1920,0.01729,1738', 'Pedro FrazÃ£o,0.01865,1899,0.01729,1739', 'Kiri,0.01865,1898,0.01729,1740', 'Maximilian Nitsche,0.01865,1896,0.01729,1741', 'whale9490,0.01865,1895,0.01729,1742', 'Hirotaka Kawashima,0.01865,1894,0.01729,1743', 'nab391,0.01865,1893,0.01729,1744', 'So Jae Woo,0.01865,1892,0.01729,1745', 'Tak Yg,0.01865,1891,0.01729,1746', 'Navy,0.01865,1890,0.01729,1747', 'tkasasagi,0.01865,1889,0.01729,1748', 'Gabriel Wu,0.01865,1888,0.01729,1749', 'Shun Fukuda,0.01865,1887,0.01729,1750', 'GyÃ¶rgy Katona,0.01436,1613,0.01729,1751', 'nobu23tego,0.01865,1921,0.01729,1752', 'dipplestix,0.01381,1115,0.01729,1753', 'Sag3x,0.01865,1900,0.01729,1754', 'qtumshift02,0.01865,1901,0.01729,1755', 'Sergey Petrukhin,0.01865,1897,0.01729,1756', 'Tomasz Nowak,0.01865,1903,0.01729,1757', 'smileeok,0.01865,1919,0.01729,1758', 'mutoyu,0.01865,1918,0.01729,1759', 'LABAT,0.01865,1917,0.01729,1760', 'Leonid Sinev,0.01865,1916,0.01729,1761', 'Alexandre Gandini,0.01865,1902,0.01729,1762', 'akk,0.01865,1914,0.01729,1763', 'TouchDown!!!!!,0.01865,1913,0.01729,1764', 'SimonW,0.01865,1912,0.01729,1765', 'kohei tsuchiya,0.01865,1915,0.01729,1766', 'å¤©å¤–é£žä»™,0.01865,1910,0.01729,1767', 'MarkDonovan,0.01865,1909,0.01729,1768', 'Kevin Hamon,0.01865,1908,0.01729,1769', 'Taejun Jang,0.01865,1907,0.01729,1770', 'Thomas Bourgeois,0.01865,1906,0.01729,1771', 'Jack Wallner,0.01865,1904,0.01729,1772', 'Vasiliy Adyoshkin,0.01865,1911,0.01729,1773', 'Pulkit Mehta,0.01865,1905,0.01729,1774', 'Eric #2,0.01885,1975,0.01732,1775', 'Soriba,0.01864,1886,0.0174,1776', 'IfIcanUcan,0.01866,1971,0.01744,1777', 'Chia-Ta Tsai,0.01897,1978,0.01745,1778', 'cs18mds11029,0.0187,1972,0.01746,1779', 'Shaswata Jash,0.01885,1974,0.01759,1780', 'KonanComing,0.01818,1872,0.01761,1781', 'Shingo.S,0.01875,1973,0.01762,1782', 'Artem,0.01935,1989,0.01775,1783', 'Zachary Eagle,0.01895,1976,0.01777,1784', 'CS18MDS11011,0.01899,1980,0.01782,1785', 'Steel Curtains,0.01955,1991,0.01787,1786', 'CS18MDS11026,0.01912,1981,0.01792,1787', 'CS18MDS11018,0.02001,1996,0.01797,1788', 'DBN,0.01919,1986,0.01799,1789', 'cs18mds11031,0.01865,1960,0.01799,1790', 'Ruben B,0.01919,1987,0.01799,1791', 'ç‹‚æš´é‡Žè\x8fŠèŠ±,0.01919,1985,0.01799,1792', 'Jonathan E,0.01919,1984,0.01799,1793', 'anhol,0.01919,1983,0.01799,1794', 'William AttiÃ©,0.01864,1885,0.01799,1795', 'CS18MDS11008,0.01931,1988,0.01805,1796', 'severus.banerjee,0.01986,1994,0.01825,1797', 'Alexander Booth,0.01943,1990,0.01835,1798', 'rx kenp,0.02005,1997,0.01858,1799', 'Runhan Xu,0.01899,1979,0.01865,1800', 'CS18MDS11027,0.01998,1995,0.01871,1801', 'Tobie Olivier,0.01917,1982,0.01872,1802', 'CS18MDS11007,0.01978,1993,0.01878,1803', 'KentW,0.02016,1998,0.01879,1804', 'tkfmy,0.02021,1999,0.01893,1805', 'Tim S,0.02145,2007,0.01898,1806', 'TGIF,0.02029,2000,0.01932,1807', 'cs18mds11032,0.02096,2004,0.01962,1808', 'Josh M,0.0208,2002,0.01966,1809', 'AmrA,0.01961,1992,0.0197,1810', 'Jishnu Nair,0.02071,2001,0.01987,1811', 'Ezekizel,0.02125,2005,0.01995,1812', 'Keisuke Yanagisawa,0.02135,2006,0.02002,1813', 'Donatello,0.02354,2011,0.02029,1814', 'sonseungbum,0.02161,2008,0.02075,1815', 'Echo,0.01445,1655,0.02189,1816', 'Jason Durr,0.02321,2010,0.02215,1817', 'drakk,0.02418,2012,0.02283,1818', 'Pyry Kontio,0.02442,2013,0.02296,1819', 'Xiaotian,0.02649,2016,0.02557,1820', 'kitayama,0.02901,2017,0.02819,1821', 'cs18mds11014@iith.ac.in,0.01767,1864,0.03067,1822', 'Unexpected Threat,0.01402,1332,0.03145,1823', 'kukang,0.04517,2020,0.04461,1824', 'wisteria30,0.03619,2018,0.05101,1825', 'Harani,0.0571,2021,0.05686,1826', 'Mohit Rane,0.06715,2022,0.0677,1827', 'zenginlique,0.03758,2019,0.07033,1828', 'MikeAltonji,0.07626,2024,0.0715,1829', 'Paco M,0.08011,2025,0.07401,1830', 'Joel E,0.08216,2026,0.08173,1831', 'Ð©ÐµÑ‚ÐºÐ¸Ð½ Ð\x90Ð»ÐµÐºÑ\x81Ð°Ð½Ð´Ñ€,0.08408,2027,0.08176,1832', 'Jay,0.08948,2028,0.08382,1833', 'Yuki Nakashima,0.09372,2029,0.08496,1834', 'Mason Hansen,0.06838,2023,0.1092,1835', 'The Mean Squirrels,0.15292,2030,0.16309,1836', 'PassTheROC,0.01384,1159,0.24136,1837', 'Just Learning,0.27053,2032,0.25379,1838', 'Ananth Reddy,0.26157,2031,0.27481,1839', 'I need an internship,0.0134,108,0.438,1840', 'petesim1,0.48027,2034,0.43863,1841', 'dh6512,0.48027,2035,0.4817,1842', 'Allent Dan,0.01334,83,0.4817,1843', 'mjjy,0.48027,2033,0.4817,1844', 'CS18MDS11024,0.49703,2037,0.49116,1845', 'cs18mds11017,0.49611,2036,0.49541,1846', 'KOLI MAHESH,0.49962,2038,0.49818,1847']
raw_week2_download = ['TeamId,TeamName,SubmissionDate,Score', '3763673,Sag3x,"2019-12-11 16:57:40",0.01741', '3774657,"Christophe Bourgoin","2019-12-11 16:57:41",0.01253', '3961304,Zashio,"2019-12-11 16:57:41",0.01251', '3827358,tkfmy,"2019-12-11 16:57:41",0.01904', '3975966,"V B","2019-12-11 16:57:41",0.01258', '3777199,YQ_Wu,"2019-12-11 16:57:41",0.01249', '3983044,"kes | Glib Kechyn","2019-12-11 16:57:41",0.01253', '3871748,"Keisuke Shoji","2019-12-11 16:57:41",0.01253', '3788573,golden_wind,"2019-12-11 16:57:41",0.01252', '4018420,Mocha,"2019-12-11 16:57:41",0.01252', '3781260,Yugendran,"2019-12-11 16:57:41",0.31061', '3796208,stdy,"2019-12-11 16:57:41",0.01252', '3946736,"Uri Z","2019-12-11 16:57:41",0.01323', '4022273,"Jan Bre","2019-12-11 16:57:41",0.01252', '3816903,bm13800,"2019-12-11 16:57:41",0.01252', '3766481,Lee_Chen,"2019-12-11 16:57:41",0.01253', '3808989,Calanin,"2019-12-11 16:57:41",0.01246', '3775248,"Andrey Pavlov","2019-12-11 16:57:41",0.01497', '3771822,poteman,"2019-12-11 16:57:41",0.01252', '3811976,shirapon,"2019-12-11 16:57:41",0.01252', '3992451,"[ods.ai] Learn2Play","2019-12-11 16:57:41",0.01244', '4017297,"Alvis Wong","2019-12-11 16:57:41",0.01253', '3868687,littlexiaogui,"2019-12-11 16:57:41",0.01252', '3937371,Bonum,"2019-12-11 16:57:41",0.01252', '3771693,WNYSAC,"2019-12-11 16:57:41",0.01252', '3810293,"Bluering Data Octopus","2019-12-11 16:57:41",0.01254', '3771829,none,"2019-12-11 16:57:41",0.01253', '3793196,dmh43,"2019-12-11 16:57:41",0.01274', '3973622,colligo,"2019-12-11 16:57:41",0.01253', '3764434,"John Kyvetos","2019-12-11 16:57:41",0.01243', '3766934,xct,"2019-12-11 16:57:41",0.01258', '3904464,"Ahyoung Song","2019-12-11 16:57:41",0.01317', '3801449,"Darko Androcec","2019-12-11 16:57:41",0.01254', '3966848,"Ivan Tellurian","2019-12-11 16:57:41",0.01252', '3812551,newhand,"2019-12-11 16:57:41",0.01258', '3766934,xct,"2019-12-11 16:57:41",0.01255', '3774589,kr0610_cho,"2019-12-11 16:57:41",0.01252', '4018977,"Kranti Kumar","2019-12-11 16:57:41",0.01476', '3781052,MLS,"2019-12-11 16:57:41",0.01253', '3777594,Takahiro,"2019-12-11 16:57:41",0.01252', '3827794,tito,"2019-12-11 16:57:41",0.01255', '3781400,Kohey,"2019-12-11 16:57:41",0.01262', '3768639,sakuragi123,"2019-12-11 16:57:41",0.01253', '4017386,Oregin,"2019-12-11 16:57:41",0.01251', '3833758,DavidGbodiOdaibo,"2019-12-11 16:57:41",0.01257', '3765649,Piyush,"2019-12-11 16:57:41",0.01252', '3778831,"Bassil Bassiouny","2019-12-11 16:57:41",0.01253', '3827247,pushpendra,"2019-12-11 16:57:40",0.01253', '3765380,"Shohei Goda","2019-12-11 16:57:40",0.01445', '4018266,M.G.G,"2019-12-11 16:57:40",0.01252', '3903538,mehrler,"2019-12-11 16:57:40",0.01316', '3766799,"Prashant Kikani","2019-12-11 16:57:40",0.01249', '3777999,"Kien. Y. Knot","2019-12-11 16:57:40",0.01251', '3766799,"Prashant Kikani","2019-12-11 16:57:40",0.01248', '3774811,siero,"2019-12-11 16:57:40",0.01252', '3768584,"Yimin Nie","2019-12-11 16:57:40",0.01246', '4015356,"Akshan Sameullah","2019-12-11 16:57:40",0.01252', '3791266,"Anurag Trivedi","2019-12-11 16:57:40",0.01254', '3763187,"Fall of the Jedi","2019-12-11 16:57:40",0.01196', '3997740,shyjin,"2019-12-11 16:57:40",0.01251', '3772589,"Bilegzaya ","2019-12-11 16:57:40",0.01252', '3772569,"Shohei Yamaguchi","2019-12-11 16:57:40",0.01476', '3932734,seele1917,"2019-12-11 16:57:40",0.01252', '3774811,siero,"2019-12-11 16:57:40",0.01252', '3773159,"Kishore M","2019-12-11 16:57:40",0.01252', '3875775,"Guna Sekhar","2019-12-11 16:57:40",0.01252', '3816407,Turing,"2019-12-11 16:57:40",0.01254', '3827247,pushpendra,"2019-12-11 16:57:40",0.01252', '4013097,"Iván Meléndez","2019-12-11 16:57:40",0.01270', '3842150,Behrang,"2019-12-11 16:57:40",0.01443', '3827358,tkfmy,"2019-12-11 16:57:41",0.01883', '4009922,"Jason Durr","2019-12-11 16:57:41",0.02179', '3816940,jangsangho,"2019-12-11 16:57:41",0.01253', '3981351,"Justin #5","2019-12-11 16:57:41",0.01286', '3767756,"[ODS.UKrAIna] Boyrin Vjacheslav Ukraincev","2019-12-11 16:57:41",0.01278', '3789892,"Ian M","2019-12-11 16:57:41",0.01212', '3763201,pezlogd,"2019-12-11 16:57:41",0.01252', '3769052,YapaGenou,"2019-12-11 16:57:41",0.01257', '3981205,siliconlips,"2019-12-11 16:57:41",0.01462', '3809539,BayesianBro,"2019-12-11 16:57:41",0.01257', '3995985,NeverWatchNFL,"2019-12-11 16:57:41",0.01347', '3765214,"Michael Kazachok","2019-12-11 16:57:41",0.01255', '3787731,"Val An","2019-12-11 16:57:41",0.01252', '3809539,BayesianBro,"2019-12-11 16:57:41",0.01256', '3770232,"Yaroslav Samoilov","2019-12-11 16:57:40",0.01300', '4019710,Key-Minamoto,"2019-12-11 16:57:40",0.01253', '3778036,FernandoChafim,"2019-12-11 16:57:40",0.01253', '3828702,AlEkhchidi,"2019-12-11 16:57:40",0.01253', '4017297,"Alvis Wong","2019-12-11 16:57:40",0.01252', '3852919,"Pineapple of evolution","2019-12-11 16:57:40",0.01251', '3966187,"Elsa Xie","2019-12-11 16:57:40",0.01252', '4000392,JPraguer,"2019-12-11 16:57:41",0.01253', '3766891,simon,"2019-12-11 16:57:41",0.01254', '3785186,Chibadai,"2019-12-11 16:57:54",0.01642', '3779563,"Sami N","2019-12-11 16:57:55",0.01283', '3916307,"Mikhail Pchelintsev","2019-12-11 16:57:55",0.01252', '3926295,"Scott Taber","2019-12-11 16:57:55",0.01227', '4000520,邪恶小法师,"2019-12-11 16:57:55",0.01252', '3766278,"Boxuan Li","2019-12-11 16:57:55",0.01252', '4016787,"Toshihiko Sato","2019-12-11 16:57:55",0.01314', '4018261,"Andrew Shevelev","2019-12-11 16:57:55",0.01641', '3767756,"[ODS.UKrAIna] Boyrin Vjacheslav Ukraincev","2019-12-11 16:57:55",0.01271', '3860614,BetterThanButter,"2019-12-11 16:57:55",0.01252', '4019193,"Grzegorz Sionkowski","2019-12-11 16:57:55",0.01253', '3810154,Crossbell,"2019-12-11 16:57:55",0.01242', '3957131,xffj,"2019-12-11 16:57:55",0.01251', '3783775,"UTN SSK","2019-12-11 16:57:55",0.01253', '3783521,"Misuk Kim","2019-12-11 16:57:55",0.01255', '3781450,T.K.,"2019-12-11 16:57:55",0.01254', '3921593,Ezekizel,"2019-12-11 16:57:55",0.02024', '3783636,"Tadashi Kikuchi","2019-12-11 16:57:55",0.01253', '3767366,student,"2019-12-11 16:57:55",0.01253', '3775850,Unstetig,"2019-12-11 16:57:55",0.01309', '3769839,"Georgios Sarantitis","2019-12-11 16:57:55",0.01252', '3921895,"Ulf Pack","2019-12-11 16:57:55",0.01372', '3771614,yuki,"2019-12-11 16:57:55",0.01250', '3766413,"Katya Gordeeva","2019-12-11 16:57:55",0.01252', '3819225,Team-A*R*T,"2019-12-11 16:57:55",0.01276', '3777688,サングユー,"2019-12-11 16:57:55",0.01159', '4016413,"Akshay Varu","2019-12-11 16:57:55",0.01253', '3801449,"Darko Androcec","2019-12-11 16:57:55",0.01251', '3764030,zakopuro,"2019-12-11 16:57:55",0.01253', '3861880,Kirderf,"2019-12-11 16:57:55",0.01254', '4023288,"Sergei Averkiev","2019-12-11 16:57:55",0.01252', '3773906,"Vanishing Error Rate","2019-12-11 16:57:55",0.01232', '3779639,"Martin Meinke","2019-12-11 16:57:55",0.01252', '3783758,"Kazumi Sakamoto","2019-12-11 16:57:55",0.01255', '4016787,"Toshihiko Sato","2019-12-11 16:57:55",0.01253', '3767504,"isa k [dsmlkz]","2019-12-11 16:57:55",0.01251', '3835962,"Luca Basanisi","2019-12-11 16:57:55",0.01258', '3871396,chengc,"2019-12-11 16:57:55",0.01792', '4017386,Oregin,"2019-12-11 16:57:55",0.01250', '3787460,RahulAgarwal,"2019-12-11 16:57:55",0.01253', '3791217,"Joey Wong","2019-12-11 16:57:55",0.01252', '3802168,"Saravana kumar","2019-12-11 16:57:55",0.01253', '3816912,gdps,"2019-12-11 16:57:55",0.01252', '3766506,"Varyans Idman Yurdu","2019-12-11 16:57:55",0.01253', '3783758,"Kazumi Sakamoto","2019-12-11 16:57:54",0.01253', '4018261,"Andrew Shevelev","2019-12-11 16:57:54",0.01251', '3816918,\u200dFLOWKIM,"2019-12-11 16:57:54",0.01252', '3812692,syasyasyasyathx,"2019-12-11 16:57:54",0.01253', '3765357,"Antonio Marin","2019-12-11 16:57:54",0.01252', '3811469,Sammyy,"2019-12-11 16:57:54",0.01247', '3764237,ccc_k,"2019-12-11 16:57:54",0.01253', '3764237,ccc_k,"2019-12-11 16:57:54",0.01252', '4016564,Daikon,"2019-12-11 16:57:54",0.01476', '3763748,chhaatra,"2019-12-11 16:57:54",0.01256', '3816964,krovere,"2019-12-11 16:57:54",0.01252', '3816952,yjh3808,"2019-12-11 16:57:54",0.01253', '3881433,"narain p","2019-12-11 16:57:54",0.01636', '3771352,NoSaints,"2019-12-11 16:57:54",0.01251', '4001862,"Sergey Zhitansky","2019-12-11 16:57:54",0.01252', '3765182,"Rory O\'Reilly","2019-12-11 16:57:54",0.01250', '3772034,tkm2261,"2019-12-11 16:57:54",0.01265', '3915686,go!go!curry!,"2019-12-11 16:57:54",0.01252', '3768543,"Udbhav Pangotra","2019-12-11 16:57:54",0.01256', '3777841,LinhLPV,"2019-12-11 16:57:54",0.01253', '3768543,"Udbhav Pangotra","2019-12-11 16:57:54",0.01254', '3766114,"Allent Dan","2019-12-11 16:57:54",0.48104', '3995985,NeverWatchNFL,"2019-12-11 16:57:54",0.01337', '3775554,zmnako,"2019-12-11 16:57:54",0.01253', '3768981,jleecook,"2019-12-11 16:57:54",0.01252', '3766477,"Şems Kurtoglu","2019-12-11 16:57:54",0.01462', '3903839,"Van de Rakt","2019-12-11 16:57:54",0.01252', '3783521,"Misuk Kim","2019-12-11 16:57:54",0.01254', '3768841,KentW,"2019-12-11 16:57:54",0.51895', '3771454,Ehsan,"2019-12-11 16:57:54",0.01375', '3764336,Sqy,"2019-12-11 16:57:54",0.01258', '3774577,mick77rus,"2019-12-11 16:57:54",0.01292', '4014102,"Luke Plewa","2019-12-11 16:57:54",0.01309', '3996122,"Frank V","2019-12-11 16:57:54",0.01253', '3766372,grantfrefg,"2019-12-11 16:57:55",0.01257', '3771941,rc95401,"2019-12-11 16:57:54",0.01252', '3965644,vishwajeetshukla,"2019-12-11 16:57:54",0.01256', '3786082,pea98258,"2019-12-11 16:57:54",0.01252', '3994933,Ren,"2019-12-11 16:57:54",0.01253', '3907121,LemuelPR,"2019-12-11 16:57:54",0.01268', '3766119,Steffen,"2019-12-11 16:57:54",0.01269', '3763942,"Yupeng Li","2019-12-11 16:57:54",0.01222', '3776184,"Gabriel Preda","2019-12-11 16:57:54",0.01252', '3765883,"Niranjan Singh","2019-12-11 16:57:54",0.01254', '3779733,MarcoWang,"2019-12-11 16:57:54",0.01254', '3910376,"Ryu Hyun Sung","2019-12-11 16:57:55",0.01250', '3773032,Nikita,"2019-12-11 16:58:07",0.01247', '3803802,Team-FM,"2019-12-11 16:58:08",0.01291', '3819392,kitayama,"2019-12-11 16:58:08",0.03183', '3765238,predictor!,"2019-12-11 16:58:08",0.01253', '3764633,"Offensive Lines of Code","2019-12-11 16:58:08",0.01270', '3763721,Lindada,"2019-12-11 16:58:08",0.01223', '3816901,"Minkyu Lee","2019-12-11 16:58:08",0.01253', '3927201,"Alex Sinclair","2019-12-11 16:58:08",0.01306', '3764087,"SeongHun Jeong","2019-12-11 16:58:08",0.01258', '3865563,tea,"2019-12-11 16:58:08",0.01254', '3765399,ashwinids,"2019-12-11 16:58:07",0.01253', '4029796,Executorg,"2019-12-11 16:58:07",0.01252', '3776300,#rerun,"2019-12-11 16:58:07",0.01254', '3818366,SkyReaper,"2019-12-11 16:58:07",0.01246', '3790070,F.Y.R.J.,"2019-12-11 16:58:07",0.01176', '3901554,LaHora,"2019-12-11 16:58:07",0.01252', '3971178,Paritosh,"2019-12-11 16:58:07",0.01256', '3965193,"Stefan C","2019-12-11 16:58:07",0.01190', '3769351,"Eric Beckwith","2019-12-11 16:58:07",0.01237', '3765508,"Same continent","2019-12-11 16:58:07",0.01245', '3817668,nakano,"2019-12-11 16:58:07",0.01178', '3982896,kehai,"2019-12-11 16:58:08",0.01247', '3785952,Yasar,"2019-12-11 16:58:07",0.01253', '3943004,AASaaS,"2019-12-11 16:58:08",0.01305', '3767799,"Doe John","2019-12-11 16:58:08",0.01255', '3764327,"Ayman Khalafallah","2019-12-11 16:58:08",0.01253', '3971178,Paritosh,"2019-12-11 16:58:08",0.01255', '3768841,KentW,"2019-12-11 16:58:08",0.01854', '3774029,"@NFLmath, Blake & Serigne","2019-12-11 16:58:08",0.01206', '3787260,"Panagiotis Simakis","2019-12-11 16:58:08",0.01253', '3765496,"Ryuichi Ishikawa","2019-12-11 16:58:08",0.01231', '3831110,y-mogi,"2019-12-11 16:58:08",0.01252', '3780479,AksanBA,"2019-12-11 16:58:08",0.01323', '3770631,Ralf,"2019-12-11 16:58:08",0.01220', '4026821,"Karthik Kumar Billa","2019-12-11 16:58:08",0.01256', '3766553,fakeplastictrees,"2019-12-11 16:58:08",0.01236', '3828549,xz,"2019-12-11 16:58:08",0.01255', '3763933,Rzeznik,"2019-12-11 16:58:08",0.01247', '3816912,gdps,"2019-12-11 16:58:08",0.01252', '3881757,RobertLutz,"2019-12-11 16:58:08",0.01185', '3772614,"Yejun Lee","2019-12-11 16:58:08",0.01252', '4029300,"Hiroto Sekita","2019-12-11 16:58:08",0.01252', '3768287,hatunina,"2019-12-11 16:58:07",0.01268', '3764761,"Eyeshield 21","2019-12-11 16:58:07",0.01224', '3764259,FelixGozali,"2019-12-11 16:58:07",0.01253', '3868541,Lain,"2019-12-11 16:58:07",0.01252', '3766021,"Kamal Jain","2019-12-11 16:58:07",0.01253', '3803587,"Keewon Shin","2019-12-11 16:58:07",0.01253', '4027053,ikousuke,"2019-12-11 16:58:07",0.01253', '3776003,"Egor Savkin","2019-12-11 16:58:07",0.01252', '3877391,"A goofy team","2019-12-11 16:58:07",0.01335', '3773059,"naoya kumagai","2019-12-11 16:58:07",0.01253', '4026539,"Rock W","2019-12-11 16:58:07",0.01741', '3791490,JRPC,"2019-12-11 16:58:07",0.01253', '3786813,Heisenberg,"2019-12-11 16:58:07",0.01699', '4026821,"Karthik Kumar Billa","2019-12-11 16:58:07",0.01250', '4006868,"Piotrek Rozenbajgier","2019-12-11 16:58:07",0.01276', '3782668,taichi,"2019-12-11 16:58:07",0.01243', '3779742,Droughns,"2019-12-11 16:58:07",0.01312', '3999311,"Takahiro Saito","2019-12-11 16:58:07",0.01252', '3764288,"Bojan Tunguz","2019-12-11 16:58:07",0.01252', '3764288,"Bojan Tunguz","2019-12-11 16:58:07",0.01252', '3764412,WRSPKU,"2019-12-11 16:58:07",0.01252', '3880707,zhbain,"2019-12-11 16:58:07",0.01263', '3871748,"Keisuke Shoji","2019-12-11 16:58:07",0.01251', '3790081,"Sho Takahashi","2019-12-11 16:58:07",0.01253', '4026927,can.chu,"2019-12-11 16:58:07",0.01250', '3790864,gaosq0604,"2019-12-11 16:58:07",0.01252', '3900424,Wong,"2019-12-11 16:58:07",0.01211', '4027943,Tsubasa,"2019-12-11 16:58:07",0.01254', '3766857,agenlu,"2019-12-11 16:58:07",0.01172', '3772586,"Lucy Kim","2019-12-11 16:58:07",0.01251', '3789169,meth,"2019-12-11 16:58:07",0.01438', '3775303,Aimyon,"2019-12-11 16:58:07",0.01242', '3965193,"Stefan C","2019-12-11 16:58:07",0.01189', '3770808,"Trust your sons","2019-12-11 16:58:07",0.01259', '3988267,imthon,"2019-12-11 16:58:07",0.01253', '3786460,"Eduardo Munoz Sala","2019-12-11 16:58:08",0.01252', '3774061,python10pm,"2019-12-11 16:58:07",0.01252', '3769489,"Léonard Deroose","2019-12-11 16:58:07",0.01294', '3855676,Dowan_mao,"2019-12-11 16:58:07",0.01248', '3764608,lurker,"2019-12-11 16:58:07",0.01242', '3765444,"Veerala Hari Krishna","2019-12-11 16:58:07",0.01252', '3768707,"Stanislav Blinov","2019-12-11 16:58:07",0.01253', '3769351,"Eric Beckwith","2019-12-11 16:58:07",0.01229', '3961998,lambdabest,"2019-12-11 16:58:07",0.01306', '3767416,"Project 23","2019-12-11 16:58:07",0.01252', '3910376,"Ryu Hyun Sung","2019-12-11 16:58:07",0.01250', '3916994,"Ruben B","2019-12-11 16:58:20",0.01798', '3812175,jumdar,"2019-12-11 16:58:21",0.01305', '3992437,"deja vu","2019-12-11 16:58:21",0.01252', '3793196,dmh43,"2019-12-11 16:58:21",0.01268', '3998086,"The Mathletes","2019-12-11 16:58:21",0.01323', '3918240,"The Secret","2019-12-11 16:58:21",0.01438', '3781079,"Chi Gao","2019-12-11 16:58:21",0.01253', '3793321,vivekkumar,"2019-12-11 16:58:21",0.01253', '3777199,YQ_Wu,"2019-12-11 16:58:21",0.01248', '3764807,RunningZ,"2019-12-11 16:58:21",0.01255', '3773059,"naoya kumagai","2019-12-11 16:58:21",0.01252', '3767815,LDPy,"2019-12-11 16:58:21",0.01253', '3964868,小数,"2019-12-11 16:58:21",0.01260', '3816915,"GIDONG PARK","2019-12-11 16:58:21",0.01253', '3763686,minyus,"2019-12-11 16:58:21",0.01199', '3832601,denkimagic,"2019-12-11 16:58:21",0.01308', '3949355,"Alan #3","2019-12-11 16:58:21",0.01353', '3781079,"Chi Gao","2019-12-11 16:58:21",0.01252', '3782509,Prachi,"2019-12-11 16:58:21",0.07245', '3772835,"heh mda","2019-12-11 16:58:21",0.01706', '4026025,"Kiely Pak","2019-12-11 16:58:21",0.01640', '3772835,"heh mda","2019-12-11 16:58:21",0.01665', '3972986,一战成名,"2019-12-11 16:58:21",0.01252', '3845115,"Ashutosh Sanzgiri","2019-12-11 16:58:21",0.01252', '3774851,handonglee,"2019-12-11 16:58:21",0.01254', '3928899,"ChoEun000904 #2","2019-12-11 16:58:21",0.01251', '3785952,Yasar,"2019-12-11 16:58:21",0.01252', '3831164,GitanshKhirbat,"2019-12-11 16:58:21",0.01253', '3778682,mengfanyu,"2019-12-11 16:58:21",0.01251', '3764587,lionsheep24,"2019-12-11 16:58:21",0.01270', '3772034,tkm2261,"2019-12-11 16:58:21",0.01253', '3765679,"Harijs Cerins","2019-12-11 16:58:21",0.01253', '3801766,മലയാളി,"2019-12-11 16:58:21",0.01253', '3790281,"Danya Chepenko","2019-12-11 16:58:21",0.01251', '3770305,"DalAda Lab","2019-12-11 16:58:21",0.01256', '3978813,SUDHAKAR,"2019-12-11 16:58:21",0.01253', '3816916,csoh,"2019-12-11 16:58:21",0.01252', '3816905,"Sangwoo Jung","2019-12-11 16:58:21",0.01252', '3860331,Ryota,"2019-12-11 16:58:21",0.01246', '3997608,"Steel Curtains","2019-12-11 16:58:21",0.01838', '3873502,forArya,"2019-12-11 16:58:21",0.01253', '4015400,emand2pac,"2019-12-11 16:58:21",0.01258', '3845458,Yuya.O,"2019-12-11 16:58:21",0.01237', '3793321,vivekkumar,"2019-12-11 16:58:20",0.01253', '3764184,Unnamed,"2019-12-11 16:58:20",0.01256', '3766058,Anoop,"2019-12-11 16:58:20",0.01248', '3781287,"NFL Masters","2019-12-11 16:58:20",0.01253', '3793307,"Harshit Sheoran","2019-12-11 16:58:20",0.01253', '3776300,#rerun,"2019-12-11 16:58:20",0.01254', '4006994,Yusuke_Sakai_1993,"2019-12-11 16:58:20",0.01253', '3770962,Kent,"2019-12-11 16:58:20",0.01264', '3996546,"Guillermo Gutiérrez","2019-12-11 16:58:20",0.01381', '3879331,"Ivan Marevic","2019-12-11 16:58:20",0.01251', '3772990,"Laplace\'s Demon","2019-12-11 16:58:20",0.01147', '3845974,"Aggelos G","2019-12-11 16:58:20",0.01252', '3779742,Droughns,"2019-12-11 16:58:20",0.01307', '3812742,Ilu,"2019-12-11 16:58:20",0.01253', '3777917,t.eno,"2019-12-11 16:58:20",0.01250', '4024263,"Moritz Schwyzer","2019-12-11 16:58:20",0.01254', '3996546,"Guillermo Gutiérrez","2019-12-11 16:58:20",0.01373', '3786446,ADT,"2019-12-11 16:58:20",0.01250', '3779584,"Noah Weber","2019-12-11 16:58:20",0.01253', '3911101,"Muhan Li","2019-12-11 16:58:20",0.01253', '3857816,"Alex M","2019-12-11 16:58:20",0.01250', '3795282,"Bagel\'s Kaggle","2019-12-11 16:58:21",0.01249', '3816953,"jaejeong ahn","2019-12-11 16:58:21",0.01252', '3967304,apoorvc,"2019-12-11 16:58:21",0.01254', '3764757,firstbloodY,"2019-12-11 16:58:21",0.01252', '3846360,"Robin Jackson","2019-12-11 16:58:21",0.01326', '3918240,"The Secret","2019-12-11 16:58:20",0.01296', '3780416,developerX,"2019-12-11 16:58:20",0.01261', '3943197,adityasinha,"2019-12-11 16:58:20",0.01191', '3779733,MarcoWang,"2019-12-11 16:58:20",0.01252', '3768311,jgeiman,"2019-12-11 16:58:20",0.01294', '3773803,masa-suke,"2019-12-11 16:58:20",0.01258', '3769860,BlueDragon,"2019-12-11 16:58:20",0.01252', '3763959,"NFL Academy","2019-12-11 16:58:20",0.01247', '4002799,"Dmytro Korduban","2019-12-11 16:58:20",0.01270', '3768875,"New Paltz","2019-12-11 16:58:20",0.01248', '3787924,"Nayeun Irene Kim","2019-12-11 16:58:20",0.01254', '3779305,ilialar,"2019-12-11 16:58:20",0.01254', '3764757,firstbloodY,"2019-12-11 16:58:20",0.01251', '3776615,"Dmitry Kozlov","2019-12-11 16:58:20",0.01253', '3763748,chhaatra,"2019-12-11 16:58:21",0.01253', '3813354,charlse,"2019-12-11 16:58:32",0.01249', '3877955,Mashlyn,"2019-12-11 16:58:33",0.01252', '3763318,"Mitsuru Fujiwara","2019-12-11 16:58:33",0.01253', '3827329,Nooh,"2019-12-11 16:58:33",0.01252', '3777848,"Vladimir Zhuravlev","2019-12-11 16:58:33",0.01253', '3879839,"Alexander Stasiuk","2019-12-11 16:58:33",0.01461', '4001451,Edward0chen,"2019-12-11 16:58:33",0.01252', '4001264,"Lamine Gaye","2019-12-11 16:58:33",0.01741', '3999208,不乐无语,"2019-12-11 16:58:33",0.01306', '3972823,DaNing,"2019-12-11 16:58:33",0.01252', '3770633,pBuoro,"2019-12-11 16:58:33",0.01240', '3840208,Aleksthegreat,"2019-12-11 16:58:33",0.01253', '3783393,Ninja,"2019-12-11 16:58:33",0.01253', '3803578,fangds,"2019-12-11 16:58:33",0.01252', '3887954,YSasaki,"2019-12-11 16:58:33",0.01253', '3767929,Arateris,"2019-12-11 16:58:33",0.01252', '3913970,sakana,"2019-12-11 16:58:33",0.01254', '3766664,Jo,"2019-12-11 16:58:33",0.01252', '3791227,sirius*,"2019-12-11 16:58:33",0.01252', '3917288,"Ladle Patel","2019-12-11 16:58:33",0.01461', '3993506,Excuses,"2019-12-11 16:58:33",0.01253', '3777312,Jerry,"2019-12-11 16:58:33",0.01253', '3969587,"Dapeng Lee🐦","2019-12-11 16:58:33",0.01258', '3996122,"Frank V","2019-12-11 16:58:33",0.01252', '3956707,"Ken At","2019-12-11 16:58:33",0.01253', '3769832,FernandoTN,"2019-12-11 16:58:33",0.01253', '3795043,"Team Prakrut-Nick","2019-12-11 16:58:33",0.01306', '3999208,不乐无语,"2019-12-11 16:58:33",0.01298', '3996248,"Jerry Gonzalez","2019-12-11 16:58:33",0.01313', '3850069,Ramstein,"2019-12-11 16:58:33",0.01259', '3768859,"Alexander Varnavsky","2019-12-11 16:58:33",0.01253', '3889707,forestchen,"2019-12-11 16:58:33",0.01284', '3785537,lucas1347,"2019-12-11 16:58:33",0.01253', '3764570,TY.Yang,"2019-12-11 16:58:33",0.01252', '3763791,"Vladislav Bogorod","2019-12-11 16:58:33",0.01252', '3768594,Beginner,"2019-12-11 16:58:33",0.01324', '3973560,gusarov.vladislav,"2019-12-11 16:58:33",0.01741', '3999638,OrKatz,"2019-12-11 16:58:33",0.01253', '3996798,trmk,"2019-12-11 16:58:33",0.01252', '3779451,WitatRangthain,"2019-12-11 16:58:33",0.01256', '3983611,"Jiyeon Lee","2019-12-11 16:58:33",0.01253', '3769747,"Mohammed Tayor","2019-12-11 16:58:33",0.01251', '3766205,"[ods] Vitali Burachonok","2019-12-11 16:58:33",0.01253', '3778174,"Igor V","2019-12-11 16:58:33",0.01254', '3763295,"Hear Fur Da Moolãh","2019-12-11 16:58:33",0.01318', '3974386,CS18MDS11005,"2019-12-11 16:58:33",0.01440', '3990596,"coppell: liang & gupta","2019-12-11 16:58:32",0.01254', '3771394,"Justin Coleman","2019-12-11 16:58:32",0.01253', '3931721,"DENDEN ZZH5","2019-12-11 16:58:32",0.01253', '3765949,"Pavel Pleskov","2019-12-11 16:58:32",0.01253', '3772604,"Haruka Nakashima","2019-12-11 16:58:32",0.01490', '3866302,nyancat62,"2019-12-11 16:58:32",0.01253', '3766157,"Nikita Hismatov","2019-12-11 16:58:32",0.01253', '3764941,rush_tom_sawyer,"2019-12-11 16:58:32",0.01252', '3771767,mochidan,"2019-12-11 16:58:32",0.01252', '3799643,Daic,"2019-12-11 16:58:32",0.01252', '3993506,Excuses,"2019-12-11 16:58:32",0.01252', '3763540,dbrait,"2019-12-11 16:58:32",0.01253', '3763836,Morphy,"2019-12-11 16:58:32",0.01252', '3928340,"Gang Min Lee","2019-12-11 16:58:32",0.01251', '3997977,WSTeam,"2019-12-11 16:58:32",0.01476', '3767057,JumpeiT,"2019-12-11 16:58:32",0.01253', '3921673,tianbadongbata,"2019-12-11 16:58:32",0.01252', '3777188,"Damilola Gbenle","2019-12-11 16:58:32",0.01438', '3795883,Tomi,"2019-12-11 16:58:32",0.01252', '3763282,"Lawrence Chernin","2019-12-11 16:58:32",0.01253', '3778705,"yassine zayani","2019-12-11 16:58:32",0.01252', '3768372,"Wei Hao Khoong","2019-12-11 16:58:33",0.01253', '3879551,"Marcos Martins Marchetti","2019-12-11 16:58:33",0.01253', '3940546,"Harris Y","2019-12-11 16:58:33",0.01263', '3765378,SRK,"2019-12-11 16:58:32",0.01253', '3918160,"Wei-ting Chiu","2019-12-11 16:58:32",0.01253', '3999109,"Tianjian Meng","2019-12-11 16:58:32",0.01252', '3803802,Team-FM,"2019-12-11 16:58:32",0.01273', '3779211,willyboy1,"2019-12-11 16:58:32",0.01222', '3981205,siliconlips,"2019-12-11 16:58:33",0.01300', '3784909,搏一搏,"2019-12-11 16:58:32",0.01249', '3844503,"Hyewoon Joung","2019-12-11 16:58:32",0.01252', '3844503,"Hyewoon Joung","2019-12-11 16:58:32",0.01252', '3832073,"Jisu Kim","2019-12-11 16:58:32",0.01252', '3990596,"coppell: liang & gupta","2019-12-11 16:58:32",0.01253', '3763301,rugby-world-cup,"2019-12-11 16:58:32",0.01273', '3817013,KimBoKyu,"2019-12-11 16:58:32",0.01253', '3997831,0DD1,"2019-12-11 16:58:32",0.01253', '3763337,"Jie Wu","2019-12-11 16:58:32",0.01253', '3901810,"Lorenzo Ampil","2019-12-11 16:58:32",0.01253', '3799643,Daic,"2019-12-11 16:58:33",0.01250', '3766797,"Gilang Ardya","2019-12-11 16:58:46",0.01249', '3948359,"Andrei Dukhounik","2019-12-11 16:58:46",0.01253', '3787260,"Panagiotis Simakis","2019-12-11 16:58:46",0.01253', '3810705,ajp,"2019-12-11 16:58:46",0.01252', '3770738,Dollars4Donuts,"2019-12-11 16:58:46",0.01303', '3815825,Atish,"2019-12-11 16:58:46",0.01253', '3770023,MichaelP,"2019-12-11 16:58:46",0.01253', '3994464,"Krizsó Gergely","2019-12-11 16:58:46",0.01252', '3986693,severus.banerjee,"2019-12-11 16:58:46",0.01865', '3776212,"Mikhail Fadeev","2019-12-11 16:58:46",0.01253', '3928358,"Han Jae Hyun","2019-12-11 16:58:46",0.01250', '3770945,RyanCMcV,"2019-12-11 16:58:46",0.01643', '3779895,Ragnar,"2019-12-11 16:58:46",0.01252', '3779929,"Olga Ivanova ","2019-12-11 16:58:46",0.01251', '3921895,"Ulf Pack","2019-12-11 16:58:46",0.01252', '3772841,rivxhar5907,"2019-12-11 16:58:46",0.01254', '3766337,"Arunkumar Venkataramanan","2019-12-11 16:58:46",0.01252', '3766411,Smaba,"2019-12-11 16:58:46",0.01323', '3824882,henrykf22,"2019-12-11 16:58:46",0.01252', '3763805,jeremypmobley,"2019-12-11 16:58:46",0.01266', '3774107,Eve,"2019-12-11 16:58:46",0.01252', '3892500,"Sergey #2","2019-12-11 16:58:47",0.01253', '3955237,Thor,"2019-12-11 16:58:47",0.01253', '3765862,"Mathurin Aché","2019-12-11 16:58:47",0.01253', '3846948,Jacob,"2019-12-11 16:58:47",0.01251', '3840879,TheNerdyCat,"2019-12-11 16:58:47",0.01251', '3994934,"Tang Hao","2019-12-11 16:58:47",0.01476', '3961443,"MA Junyi","2019-12-11 16:58:47",0.01253', '3793560,Huangzz1718,"2019-12-11 16:58:47",0.01251', '3771908,Scottfree,"2019-12-11 16:58:47",0.01253', '3913850,asilon,"2019-12-11 16:58:47",0.01292', '3948359,"Andrei Dukhounik","2019-12-11 16:58:47",0.01251', '3767880,"Niranjan Nakkala","2019-12-11 16:58:47",0.01252', '3988340,"Kirill Stroganov","2019-12-11 16:58:47",0.01253', '3778464,"Travis Sun","2019-12-11 16:58:47",0.01251', '3828469,"Alexander Zinovev","2019-12-11 16:58:47",0.01253', '3832590,"Electric Light Bulb","2019-12-11 16:58:47",0.01295', '3993252,"Anton Morkovkin","2019-12-11 16:58:47",0.01254', '3786944,monuvio,"2019-12-11 16:58:47",0.01245', '3763415,"Dimosthenis Karaflos","2019-12-11 16:58:46",0.01263', '3994934,"Tang Hao","2019-12-11 16:58:46",0.01253', '3768021,"Greg Hamel","2019-12-11 16:58:46",0.01252', '3765302,theheena,"2019-12-11 16:58:46",0.01595', '3764751,"Y. Y","2019-12-11 16:58:46",0.01251', '3891738,"Can Kural","2019-12-11 16:58:46",0.01254', '3875429,GOSS,"2019-12-11 16:58:46",0.01251', '3787022,"dan musetoiu","2019-12-11 16:58:46",0.01255', '3767211,rnrq,"2019-12-11 16:58:46",0.01252', '3995368,"IEEE buddies","2019-12-11 16:58:46",0.01240', '3769735,"Mason Hansen","2019-12-11 16:58:46",0.12700', '3764060,takuoko,"2019-12-11 16:58:46",0.01238', '3791111,kt3472,"2019-12-11 16:58:46",0.01250', '3928973,"Dan Kinn","2019-12-11 16:58:46",0.01273', '3901810,"Lorenzo Ampil","2019-12-11 16:58:46",0.01253', '3941358,johnxuu,"2019-12-11 16:58:46",0.01312', '3992437,"deja vu","2019-12-11 16:58:46",0.01252', '3812738,zlannn,"2019-12-11 16:58:46",0.01256', '3763408,JB,"2019-12-11 16:58:46",0.01232', '3765088,YALICKJ,"2019-12-11 16:58:46",0.01256', '3889707,forestchen,"2019-12-11 16:58:46",0.01280', '3777312,Jerry,"2019-12-11 16:58:46",0.01252', '3770954,Zoe3,"2019-12-11 16:58:46",0.01306', '3779279,"Eric Vos","2019-12-11 16:58:46",0.01253', '3994782,TooHard,"2019-12-11 16:58:46",0.01251', '3769381,DataHackers,"2019-12-11 16:58:46",0.01258', '3946307,paulorufino,"2019-12-11 16:58:46",0.01251', '3984312,shivyshiv,"2019-12-11 16:58:46",0.01256', '3989877,"Florian Schwarz","2019-12-11 16:58:46",0.01741', '3769783,"Siddharth Chandrakant","2019-12-11 16:58:46",0.01255', '3779879,"Srinivas vaddi","2019-12-11 16:58:46",0.01252', '3869573,yapkan,"2019-12-11 16:58:46",0.01271', '3995368,"IEEE buddies","2019-12-11 16:58:47",0.01237', '3989752,"Taylor #2","2019-12-11 16:58:46",0.01252', '3802196,tsomers,"2019-12-11 16:58:46",0.01305', '3946094,Moon_hyungjoon,"2019-12-11 16:58:46",0.01252', '3784563,"Hot Yinzer Takes","2019-12-11 16:58:46",0.01278', '3781569,"Shaod Liu","2019-12-11 16:58:46",0.01252', '3851886,"Yosuke Ishiguro","2019-12-11 16:58:46",0.01255', '3833758,DavidGbodiOdaibo,"2019-12-11 16:58:46",0.01254', '3986693,severus.banerjee,"2019-12-11 16:58:46",0.01823', '3768521,"Tim Moore","2019-12-11 16:58:46",0.01330', '3764674,KFurudate,"2019-12-11 16:58:47",0.01252', '3847309,XiaoyuYang,"2019-12-11 16:58:58",0.01254', '3816903,bm13800,"2019-12-11 16:58:59",0.01251', '3774321,Drastamat,"2019-12-11 16:58:59",0.01330', '3810154,Crossbell,"2019-12-11 16:58:59",0.01240', '3963127,laboratory,"2019-12-11 16:58:59",0.01253', '3770526,"Kelly Johnson","2019-12-11 16:58:59",0.01262', '3879504,PAT,"2019-12-11 16:58:59",0.01295', '3770945,RyanCMcV,"2019-12-11 16:58:59",0.01533', '3861880,Kirderf,"2019-12-11 16:58:59",0.01254', '3765182,"Rory O\'Reilly","2019-12-11 16:58:59",0.01249', '3769420,Ace_huang,"2019-12-11 16:58:59",0.01635', '3915601,yuto.s,"2019-12-11 16:58:59",0.01631', '3886089,"Football\'s Coming Home","2019-12-11 16:58:59",0.01251', '3778831,"Bassil Bassiouny","2019-12-11 16:58:59",0.01251', '3783393,Ninja,"2019-12-11 16:58:59",0.01251', '3953822,"Rashid Haffadi","2019-12-11 16:58:59",0.01252', '3804164,RunFastRunFree,"2019-12-11 16:58:58",0.01202', '3994933,Ren,"2019-12-11 16:58:58",0.01253', '3781932,liuze,"2019-12-11 16:58:58",0.01253', '3763331,"Ruslan Khalitov","2019-12-11 16:58:58",0.01258', '3958650,"Tobie Olivier","2019-12-11 16:58:59",0.01866', '3766317,"Nick Styles","2019-12-11 16:58:59",0.01252', '3839501,KonanComing,"2019-12-11 16:58:59",0.01757', '3793252,"Khairul Islam","2019-12-11 16:58:59",0.01253', '3772272,"Tanishq Gautam","2019-12-11 16:58:59",0.01253', '3764537,liuzhangzhen,"2019-12-11 16:58:59",0.01252', '3772585,"Tae heon Kim","2019-12-11 16:58:59",0.01250', '3771394,"Justin Coleman","2019-12-11 16:58:59",0.01252', '4010841,yasu,"2019-12-11 16:58:59",0.01713', '3891684,"InJu Kim","2019-12-11 16:58:59",0.01252', '3945438,"Pozdnyakov Yuri","2019-12-11 16:58:59",0.01262', '3962935,"Paweł Lubiński","2019-12-11 16:58:59",0.01252', '3768945,"FIrst blood","2019-12-11 16:58:59",0.01250', '3888771,YuhkiH,"2019-12-11 16:58:59",0.01254', '3764336,Sqy,"2019-12-11 16:58:59",0.01253', '3997710,Xiuchuanz,"2019-12-11 16:58:59",0.01254', '3849886,Summers,"2019-12-11 16:58:59",0.01254', '3765949,"Pavel Pleskov","2019-12-11 16:58:59",0.01252', '3908836,"Jimin Yoon","2019-12-11 16:58:59",0.01252', '3788713,"Austin Brown","2019-12-11 16:58:59",0.01723', '3986833,zhuchengqi,"2019-12-11 16:58:59",0.01253', '3975545,DaniilChuykin,"2019-12-11 16:58:58",0.01252', '3768127,Tiemu,"2019-12-11 16:58:58",0.01252', '3963127,laboratory,"2019-12-11 16:58:58",0.01250', '3938559,Abner_Zhu,"2019-12-11 16:58:58",0.01255', '3923390,"Woo Sung Jang","2019-12-11 16:58:58",0.01310', '4000561,"I want a job","2019-12-11 16:58:58",0.01254', '3999311,"Takahiro Saito","2019-12-11 16:58:58",0.01252', '3771190,"Tomonori Masui","2019-12-11 16:58:58",0.01221', '3765153,"Vlad Balanda","2019-12-11 16:58:58",0.01253', '3968062,"safaf asdasd","2019-12-11 16:58:58",0.02363', '3778919,fwj7,"2019-12-11 16:58:58",0.01226', '3979603,_erica_kaggler,"2019-12-11 16:58:58",0.01254', '3764593,wangzhaoxu,"2019-12-11 16:58:58",0.01256', '4009359,"Aybek Bekbaev","2019-12-11 16:58:58",0.01252', '3977298,229,"2019-12-11 16:58:58",0.01296', '3831634,KrishnaK,"2019-12-11 16:58:58",0.01254', '3784773,hmk,"2019-12-11 16:58:58",0.01252', '3770951,"Alexys Pereira","2019-12-11 16:58:58",0.01313', '3982203,"Kota Iizuka","2019-12-11 16:58:58",0.01302', '4008828,"Z Dog","2019-12-11 16:58:58",0.01741', '3764916,SVJ24,"2019-12-11 16:58:58",0.01318', '3893877,amanemisa,"2019-12-11 16:58:58",0.01428', '3764107,kenmatsu4,"2019-12-11 16:58:58",0.01276', '3765153,"Vlad Balanda","2019-12-11 16:58:58",0.01252', '4000561,"I want a job","2019-12-11 16:58:58",0.01252', '3846969,"Tim H","2019-12-11 16:58:58",0.01314', '3773169,"My Odds Are Stacked","2019-12-11 16:58:58",0.01233', '3923435,"Marius Bjørkli","2019-12-11 16:58:58",0.01285', '3763367,ZFTurbo,"2019-12-11 16:58:58",0.01252', '3877421,ceb263,"2019-12-11 16:58:58",0.01313', '3814315,"Alexander Nichiporenko","2019-12-11 16:58:58",0.01252', '3833982,"Nitesh Chaudhry","2019-12-11 16:58:58",0.01256', '4007698,"Laurent R.","2019-12-11 16:58:59",0.01741', '4008179,"Gabriel Custódio","2019-12-11 16:58:58",0.01253', '3791131,"Ryan Gong","2019-12-11 16:58:58",0.01264', '3819864,takmanman,"2019-12-11 16:58:58",0.01310', '3932976,"Ayush GUPTA","2019-12-11 16:58:58",0.01251', '4008134,"Jing Lu","2019-12-11 16:58:58",0.01253', '3765834,"Pavel Govoruha","2019-12-11 16:58:58",0.01252', '3784779,"Jon Compton","2019-12-11 16:58:58",0.01253', '3767112,Zee,"2019-12-11 16:58:58",0.01252', '3782510,MDFam,"2019-12-11 16:58:59",0.01260', '3776424,"DB sports","2019-12-11 16:59:13",0.01218', '3783486,kaggle446,"2019-12-11 16:59:13",0.01253', '3885614,ilya37,"2019-12-11 16:59:13",0.01256', '3770962,Kent,"2019-12-11 16:59:13",0.01251', '3979603,_erica_kaggler,"2019-12-11 16:59:13",0.01252', '3973622,colligo,"2019-12-11 16:59:13",0.01253', '4006809,ThomasAnthony,"2019-12-11 16:59:13",0.01311', '3763538,"Tarek Hamdi","2019-12-11 16:59:13",0.01254', '3764272,wentixiaogege,"2019-12-11 16:59:13",0.01252', '3789801,"Christoffer Karlsson","2019-12-11 16:59:13",0.01260', '4001237,"Michal Sroka","2019-12-11 16:59:13",0.01344', '3994263,yoyoyo,"2019-12-11 16:59:13",0.01555', '3956147,wxs123,"2019-12-11 16:59:13",0.01251', '4006868,"Piotrek Rozenbajgier","2019-12-11 16:59:13",0.01252', '3783624,ItalicLoveGun,"2019-12-11 16:59:13",0.01296', '3846969,"Tim H","2019-12-11 16:59:13",0.01311', '3868346,"Migs Rocha","2019-12-11 16:59:13",0.01253', '3763495,"Aleksandr Kosolapov","2019-12-11 16:59:13",0.01253', '3765372,heartkilla,"2019-12-11 16:59:13",0.01254', '3794497,Humanitis,"2019-12-11 16:59:13",0.01247', '3772093,ddn_,"2019-12-11 16:59:13",0.01253', '3767181,Aman.cyberia,"2019-12-11 16:59:13",0.01253', '3997831,0DD1,"2019-12-11 16:59:13",0.01252', '3993355,bebe,"2019-12-11 16:59:13",0.01253', '3999638,OrKatz,"2019-12-11 16:59:13",0.01252', '3769793,"Lang Sys","2019-12-11 16:59:13",0.01253', '3859355,asami,"2019-12-11 16:59:13",0.01256', '3962935,"Paweł Lubiński","2019-12-11 16:59:13",0.01252', '3981593,skyneteyes,"2019-12-11 16:59:13",0.01253', '3919466,gorogoroumaru,"2019-12-11 16:59:13",0.01252', '3890296,FEILI,"2019-12-11 16:59:13",0.01741', '3933488,DOUYG,"2019-12-11 16:59:13",0.01253', '3765378,SRK,"2019-12-11 16:59:13",0.01253', '3766021,"Kamal Jain","2019-12-11 16:59:13",0.01252', '3884862,"Kuntal Chakraborty","2019-12-11 16:59:13",0.01461', '3875091,"Shao Yiqi","2019-12-11 16:59:13",0.01253', '3837325,"Rachid Ahed","2019-12-11 16:59:13",0.01253', '3763586,suk1yak1,"2019-12-11 16:59:13",0.01252', '3775327,"Fernando Contreras","2019-12-11 16:59:13",0.01461', '3778278,hktxt,"2019-12-11 16:59:13",0.01254', '3781169,ashergaga,"2019-12-11 16:59:13",0.01252', '4002974,"Renato Aguiar","2019-12-11 16:59:13",0.01254', '3864830,smartbean,"2019-12-11 16:59:13",0.01255', '3777035,"luca spelgatti","2019-12-11 16:59:13",0.01252', '3763957,"Adrian Zinovei","2019-12-11 16:59:13",0.01252', '3811959,yorshka,"2019-12-11 16:59:13",0.01252', '3840879,TheNerdyCat,"2019-12-11 16:59:13",0.01250', '3965644,vishwajeetshukla,"2019-12-11 16:59:13",0.01255', '3765557,大碗饭加蛋,"2019-12-11 16:59:13",0.01253', '3765861,luyaxin,"2019-12-11 16:59:13",0.01251', '3764549,"Pedro Reis","2019-12-11 16:59:13",0.01252', '3763227,"Ian Astalosh","2019-12-11 16:59:13",0.01248', '3981293,"The Elon Muskrats","2019-12-11 16:59:13",0.01253', '3982203,"Kota Iizuka","2019-12-11 16:59:13",0.01299', '3787997,"Deep Chatterjee","2019-12-11 16:59:13",0.01253', '3983044,"kes | Glib Kechyn","2019-12-11 16:59:13",0.01253', '3886961,gavrand,"2019-12-11 16:59:13",0.01253', '3996608,iamrouss,"2019-12-11 16:59:13",0.01261', '3775395,"Justin Dumouchelle","2019-12-11 16:59:13",0.01284', '4002849,"Cory Wilson","2019-12-11 16:59:13",0.01741', '3981293,"The Elon Muskrats","2019-12-11 16:59:13",0.01251', '3764159,"Dmitriy Guller","2019-12-11 16:59:13",0.01247', '3917288,"Ladle Patel","2019-12-11 16:59:13",0.01253', '3923342,Data4Breakfast,"2019-12-11 16:59:13",0.01253', '3804164,RunFastRunFree,"2019-12-11 16:59:13",0.01196', '3996592,"Agnieszka Matyja","2019-12-11 16:59:13",0.01252', '3924750,Kaz,"2019-12-11 16:59:13",0.01254', '3983625,"Narek Maloyan","2019-12-11 16:59:13",0.01252', '3766205,"[ods] Vitali Burachonok","2019-12-11 16:59:13",0.01252', '3765657,"Vladimir Larin","2019-12-11 16:59:13",0.01252', '3834943,"Mark Eckdahl","2019-12-11 16:59:13",0.01255', '3784779,"Jon Compton","2019-12-11 16:59:13",0.01253', '3986443,"Ankita Sinha","2019-12-11 16:59:23",0.01252', '3773357,mANDy,"2019-12-11 16:59:24",0.01323', '4043124,"Chaeyeon Yoo","2019-12-11 16:59:24",0.01252', '3846360,"Robin Jackson","2019-12-11 16:59:24",0.01323', '3985230,toronto_ds,"2019-12-11 16:59:24",0.01210', '3937066,"Michael Bian","2019-12-11 16:59:24",0.01210', '3817768,"Jeffrey Chung","2019-12-11 16:59:24",0.01221', '3843244,"Akira Nakamura","2019-12-11 16:59:24",0.01251', '3900068,"Team Room 42","2019-12-11 16:59:24",0.01286', '3961542,"Team PBD","2019-12-11 16:59:24",0.01314', '3770583,Zoltan,"2019-12-11 16:59:24",0.01155', '3764670,"Syracuse Sport Analytics","2019-12-11 16:59:24",0.01736', '3849254,"Sirish Somanchi","2019-12-11 16:59:24",0.02376', '3770790,"Coffee Club","2019-12-11 16:59:24",0.01230', '3775269,tdefoin,"2019-12-11 16:59:24",0.01239', '3833062,"ZJU squad","2019-12-11 16:59:24",0.01235', '3816662,andre_beton,"2019-12-11 16:59:24",0.01276', '3768858,mtodisco10,"2019-12-11 16:59:24",0.01252', '3766922,"Establish The Run","2019-12-11 16:59:24",0.01148', '3775053,"Carryon Calvin","2019-12-11 16:59:24",0.01705', '3772146,hookbook,"2019-12-11 16:59:24",0.01256', '3777241,vinmuk,"2019-12-11 16:59:24",0.01135', '3764928,乔世吉,"2019-12-11 16:59:24",0.01239', '3780237,PeterWendel,"2019-12-11 16:59:24",0.01259', '3768495,"Paulo Pinto","2019-12-11 16:59:24",0.01257', '3809571,nyanp,"2019-12-11 16:59:24",0.01176', '3767438,goku,"2019-12-11 16:59:24",0.01250', '3854715,charlie_s,"2019-12-11 16:59:24",0.01168', '3764614,"Three people","2019-12-11 16:59:24",0.01298', '3906783,zehengl,"2019-12-11 16:59:24",0.01253', '3816951,singlefish,"2019-12-11 16:59:24",0.01253', '3862710,Gig,"2019-12-11 16:59:24",0.01252', '3890550,"Solomon Xian","2019-12-11 16:59:24",0.01251', '3904607,P3n9W31,"2019-12-11 16:59:24",0.01253', '3872640,"Maho #2","2019-12-11 16:59:24",0.01253', '3843244,"Akira Nakamura","2019-12-11 16:59:24",0.01250', '3813308,Radeeswar,"2019-12-11 16:59:24",0.01315', '3764223,"CAI DeSI Drift","2019-12-11 16:59:24",0.01245', '3986352,无陵,"2019-12-11 16:59:24",0.01252', '3810911,RIStina_aguilera,"2019-12-11 16:59:24",0.01237', '3981468,DocSavage,"2019-12-11 16:59:24",0.01722', '3800210,mohamed,"2019-12-11 16:59:24",0.01244', '3989767,"Your Ad Could Be Here","2019-12-11 16:59:24",0.01206', '3766922,"Establish The Run","2019-12-11 16:59:24",0.01145', '3764668,Cc_So_Niubility,"2019-12-11 16:59:24",0.01279', '3768071,"Fundamental Geometricalism","2019-12-11 16:59:24",0.01173', '3775376,KrisztianSz,"2019-12-11 16:59:24",0.01210', '3971544,mohi12345,"2019-12-11 16:59:24",0.01311', '3770790,"Coffee Club","2019-12-11 16:59:24",0.01228', '3767268,ln,"2019-12-11 16:59:24",0.01182', '3813308,Radeeswar,"2019-12-11 16:59:23",0.01252', '4033591,kitaura,"2019-12-11 16:59:23",0.01253', '3765032,Jordan,"2019-12-11 16:59:23",0.02086', '3767681,octaddust,"2019-12-11 16:59:23",0.01251', '3878456,"Imada Hanako","2019-12-11 16:59:23",0.01272', '3811451,"Robert McKee","2019-12-11 16:59:23",0.01293', '3766667,"Gultekin Gunduz","2019-12-11 16:59:23",0.01279', '3766225,IDRK,"2019-12-11 16:59:23",0.01265', '3851895,Shiunwen,"2019-12-11 16:59:23",0.01251', '3768441,"Deadline Fighter","2019-12-11 16:59:23",0.01127', '3764614,"Three people","2019-12-11 16:59:23",0.01288', '3768938,Ko,"2019-12-11 16:59:23",0.01256', '3886771,"Muhammed Buyukkinaci","2019-12-11 16:59:23",0.01255', '3779278,PSThorbell,"2019-12-11 16:59:24",0.01252', '3973491,"Feodeera Sondach","2019-12-11 16:59:24",0.01253', '3782694,"Keith SZE","2019-12-11 16:59:24",0.01227', '4000963,EduardVoinea,"2019-12-11 16:59:24",0.01253', '3764616,看你心情...,"2019-12-11 16:59:24",0.01192', '3763614,hukuda222,"2019-12-11 16:59:24",0.01256', '3834763,AlexanderGeiger,"2019-12-11 16:59:24",0.01165', '3763961,Alexander,"2019-12-11 16:59:24",0.01259', '3767267,"dot dash •⁃ don\'t crash","2019-12-11 16:59:24",0.01168', '3933233,shuheioka,"2019-12-11 16:59:24",0.01253', '3775315,"Nilotpal Das","2019-12-11 16:59:24",0.01207', '3777688,サングユー,"2019-12-11 16:59:24",0.01158', '4006350,Vladimir,"2019-12-11 16:59:24",0.01253', '3836053,Ppo,"2019-12-11 16:59:24",0.01129', '3877962,"Murata Hoshi","2019-12-11 16:59:24",0.01252', '3768380,"Back-propagating the Backfield","2019-12-11 16:59:24",0.01245', '3802301,mengnanyi,"2019-12-11 16:59:24",0.01250', '3865840,"Junye Luo","2019-12-11 16:59:24",0.01308', '3982896,kehai,"2019-12-11 16:59:24",0.01245', '3768910,Smash,"2019-12-11 16:59:24",0.01235', '4000963,EduardVoinea,"2019-12-11 16:59:24",0.01253', '3878026,"Tsukamoto Mitsuru","2019-12-11 16:59:24",0.01251', '3793491,TeamSX,"2019-12-11 16:59:24",0.01689', '3786760,hakusai,"2019-12-11 16:59:24",0.01253', '3763933,Rzeznik,"2019-12-11 16:59:24",0.01244', '3818057,JaehongJeong,"2019-12-11 16:59:38",0.01254', '3818057,JaehongJeong,"2019-12-11 16:59:38",0.01253', '3878287,"Okubo Katsumi","2019-12-11 16:59:38",0.01250', '3777182,cjwh,"2019-12-11 16:59:38",0.01228', '3986032,DHK123,"2019-12-11 16:59:38",0.01246', '3763373,"Yujiro Kita","2019-12-11 16:59:38",0.01232', '3912051,Tatanka007,"2019-12-11 16:59:38",0.01253', '3766332,seba,"2019-12-11 16:59:38",0.01242', '3870494,Zeeshan,"2019-12-11 16:59:38",0.01253', '3765787,"Kyle Wang","2019-12-11 16:59:38",0.01222', '3819392,kitayama,"2019-12-11 16:59:38",0.03104', '3764199,"Jiazhen Xi","2019-12-11 16:59:38",0.01245', '3998834,Elahi,"2019-12-11 16:59:38",0.01249', '3991309,Ramadan,"2019-12-11 16:59:38",0.01577', '3780862,abromberg,"2019-12-11 16:59:38",0.01575', '3770532,"thomas kern","2019-12-11 16:59:38",0.01247', '3827959,ishio,"2019-12-11 16:59:38",0.01243', '3768620,"Alexander Polyakov","2019-12-11 16:59:38",0.01257', '3816958,jiheeyu,"2019-12-11 16:59:38",0.01253', '3878138,"Kuno Nori","2019-12-11 16:59:38",0.01255', '3995319,hdkidz,"2019-12-11 16:59:38",0.01256', '3769679,"Deep Snappers","2019-12-11 16:59:38",0.01122', '3785294,steubk,"2019-12-11 16:59:38",0.01247', '3765869,"Davide Anastasia","2019-12-11 16:59:38",0.01366', '3766072,wychwood,"2019-12-11 16:59:38",0.01242', '3948842,Daizu,"2019-12-11 16:59:38",0.01196', '3766116,"Atanas Atanasov","2019-12-11 16:59:38",0.01253', '3932515,"Phil Walsh","2019-12-11 16:59:38",0.01741', '3767144,octapi,"2019-12-11 16:59:38",0.01262', '3766116,"Atanas Atanasov","2019-12-11 16:59:38",0.01251', '3913197,Kaz-U,"2019-12-11 16:59:38",0.01188', '4040549,Zander,"2019-12-11 16:59:38",0.01253', '3785294,steubk,"2019-12-11 16:59:38",0.01241', '3772146,hookbook,"2019-12-11 16:59:38",0.01246', '3764521,"Mike Zhu","2019-12-11 16:59:38",0.01253', '3764889,"I want a job in Chengdu China","2019-12-11 16:59:38",0.01191', '3764954,shimaw28,"2019-12-11 16:59:38",0.01243', '3770516,"Arthur  Llau","2019-12-11 16:59:38",0.01257', '3790864,gaosq0604,"2019-12-11 16:59:38",0.01247', '3763683,akira,"2019-12-11 16:59:38",0.01213', '3765613,go_bears,"2019-12-11 16:59:38",0.01190', '3855056,"Balaji Venkateswaran","2019-12-11 16:59:38",0.01314', '4040686,DaisukeN,"2019-12-11 16:59:38",0.01255', '4040686,DaisukeN,"2019-12-11 16:59:38",0.01252', '3765005,Debut_Kele,"2019-12-11 16:59:38",0.01254', '3764491,Yu,"2019-12-11 16:59:38",0.01151', '3882382,tamura,"2019-12-11 16:59:38",0.01247', '3875117,zhongtian,"2019-12-11 16:59:38",0.01249', '3765032,Jordan,"2019-12-11 16:59:38",0.01316', '3768565,酒と和みと肉と野菜,"2019-12-11 16:59:38",0.01216', '3772534,tamo123,"2019-12-11 16:59:38",0.01241', '3927201,"Alex Sinclair","2019-12-11 16:59:38",0.01273', '3766072,wychwood,"2019-12-11 16:59:38",0.01241', '3939921,"Igor Dudchenko","2019-12-11 16:59:38",0.01252', '3772478,someone,"2019-12-11 16:59:38",0.01255', '4010230,HONIHITAK,"2019-12-11 16:59:38",0.01251', '3794755,AntonNegreba,"2019-12-11 16:59:38",0.01251', '3998834,Elahi,"2019-12-11 16:59:38",0.01249', '3987000,Shiggy,"2019-12-11 16:59:38",0.01254', '3770633,pBuoro,"2019-12-11 16:59:38",0.01232', '3773866,"I need  an internship","2019-12-11 16:59:38",0.43867', '3772534,tamo123,"2019-12-11 16:59:38",0.01235', '3764554,KoitoU,"2019-12-11 16:59:38",0.01241', '3855056,"Balaji Venkateswaran","2019-12-11 16:59:38",0.01252', '3767929,Arateris,"2019-12-11 16:59:38",0.01230', '3781168,"Honto no Jikan","2019-12-11 16:59:38",0.01253', '3987000,Shiggy,"2019-12-11 16:59:38",0.01252', '3785966,"NFL = No Free Lunch","2019-12-11 16:59:38",0.01230', '3802322,"Kohei TANAKA","2019-12-11 16:59:38",0.01203', '3768580,"Kostiantyn Isaienkov","2019-12-11 16:59:38",0.01279', '3766464,"The Zoo","2019-12-11 16:59:38",0.01067', '3919006,"Gator Liu","2019-12-11 16:59:38",0.01252', '3941249,Kishi,"2019-12-11 16:59:38",0.01252', '3770801,"Beagle Kagglers","2019-12-11 16:59:38",0.01175', '4039978,"Vladislav Ryzhov","2019-12-11 16:59:38",0.01254', '3913130,"small tiger","2019-12-11 16:59:38",0.01234', '3950893,"Serhii Shcherbyna","2019-12-11 16:59:38",0.01255', '3944829,heihei,"2019-12-11 16:59:38",0.01249', '3987992,Bartig,"2019-12-11 16:59:38",0.01252', '4036640,Datasciensyash,"2019-12-11 16:59:38",0.01256', '3767144,octapi,"2019-12-11 16:59:38",0.01260', '3809571,nyanp,"2019-12-11 16:59:38",0.01173', '3771865,nrsgwr,"2019-12-11 16:59:38",0.01181', '3831360,hmdhmd,"2019-12-11 16:59:38",0.01153', '3885862,"Jean-Philippe MARY","2019-12-11 16:59:49",0.01242', '3904415,"Our Gordon Savior","2019-12-11 16:59:49",0.01726', '3842220,Lights,"2019-12-11 16:59:49",0.01253', '3820414,MichaelBeers,"2019-12-11 16:59:49",0.01465', '3764161,loveisp,"2019-12-11 16:59:49",0.01258', '3810517,denis,"2019-12-11 16:59:49",0.01236', '3836010,"The Data Miners","2019-12-11 16:59:49",0.01409', '3856906,"Casual Observer","2019-12-11 16:59:49",0.01262', '3947806,PhysicsAndFootball,"2019-12-11 16:59:49",0.01219', '3810904,"Sophie Antoniak","2019-12-11 16:59:49",0.01412', '3798154,"we don\'t know the rules","2019-12-11 16:59:49",0.01140', '3796775,jyacky,"2019-12-11 16:59:49",0.01206', '3864661,petesim1,"2019-12-11 16:59:49",0.47737', '3993947,"Hailiang Du","2019-12-11 16:59:49",0.01323', '3918160,"Wei-ting Chiu","2019-12-11 16:59:49",0.01253', '3764366,"Mike C","2019-12-11 16:59:49",0.01258', '3764161,loveisp,"2019-12-11 16:59:49",0.01256', '3766584,Gert,"2019-12-11 16:59:49",0.01154', '3983843,JEP,"2019-12-11 16:59:49",0.01206', '3866064,taninotsu,"2019-12-11 16:59:49",0.01274', '3962022,"Mike Kim","2019-12-11 16:59:49",0.01260', '3787930,"Predicting like Tony Romo","2019-12-11 16:59:49",0.01227', '3781814,suuuuuu,"2019-12-11 16:59:49",0.01249', '3966684,"ANTON Baxdela","2019-12-11 16:59:49",0.01555', '3770870,Giba,"2019-12-11 16:59:49",0.01253', '3769739,"Arturo Garcia","2019-12-11 16:59:49",0.01166', '3763680,Zoopal2LondonRPZ,"2019-12-11 16:59:49",0.01260', '3771877,statnik,"2019-12-11 16:59:49",0.01283', '3933774,"Uriel Corona","2019-12-11 16:59:49",0.01300', '3981468,DocSavage,"2019-12-11 16:59:49",0.01719', '3780978,Liyang,"2019-12-11 16:59:49",0.01547', '3765352,"Bo Peng","2019-12-11 16:59:49",0.01255', '3786284,SB_VLC,"2019-12-11 16:59:49",0.01276', '3788078,SICS,"2019-12-11 16:59:49",0.01220', '3766615,"Vitalii Peretiatko","2019-12-11 16:59:49",0.01261', '3896226,"Sergey Yakushin","2019-12-11 16:59:49",0.01254', '3792701,"You Sanu\'ze You Lose","2019-12-11 16:59:49",0.01167', '3811681,L&W,"2019-12-11 16:59:49",0.01299', '3767681,octaddust,"2019-12-11 16:59:49",0.01251', '3795204,doodledood,"2019-12-11 16:59:49",0.01288', '3880970,Appian,"2019-12-11 16:59:49",0.01302', '3864830,smartbean,"2019-12-11 16:59:49",0.01249', '3763889,zzz,"2019-12-11 16:59:49",0.01221', '3792701,"You Sanu\'ze You Lose","2019-12-11 16:59:49",0.01153', '3764668,Cc_So_Niubility,"2019-12-11 16:59:49",0.01276', '3763257,"Massoud Hosseinali","2019-12-11 16:59:49",0.01258', '3798894,"Griffin Series","2019-12-11 16:59:49",0.01211', '3769809,McSnappy,"2019-12-11 16:59:49",0.01361', '3910202,K-hime,"2019-12-11 16:59:49",0.01250', '3777227,"Tam D","2019-12-11 16:59:49",0.01299', '3937066,"Michael Bian","2019-12-11 16:59:49",0.01207', '3784563,"Hot Yinzer Takes","2019-12-11 16:59:49",0.01273', '3850354,"Ryu Tomita","2019-12-11 16:59:49",0.01232', '3775850,Unstetig,"2019-12-11 16:59:49",0.01270', '3856906,"Casual Observer","2019-12-11 16:59:49",0.01250', '3776184,"Gabriel Preda","2019-12-11 16:59:49",0.01252', '3767267,"dot dash •⁃ don\'t crash","2019-12-11 16:59:49",0.01167', '3765424,"Aviv Levi","2019-12-11 16:59:49",0.01282', '3763187,"Fall of the Jedi","2019-12-11 16:59:49",0.01175', '3768135,Taumaru,"2019-12-11 16:59:49",0.01259', '3895500,NFL,"2019-12-11 16:59:49",0.01243', '3769809,McSnappy,"2019-12-11 16:59:49",0.01313', '3849932,"Group 1","2019-12-11 16:59:49",0.01252', '3766496,Nanashi,"2019-12-11 16:59:49",0.01253', '3850303,Spurius,"2019-12-11 16:59:49",0.01252', '3782389,touchdown,"2019-12-11 16:59:49",0.01252', '3868708,"Powered by Thai Diner","2019-12-11 16:59:49",0.01262', '3777189,Sleepers,"2019-12-11 16:59:49",0.01162', '3763281,"Mycroft Holmes","2019-12-11 16:59:49",0.01319', '3776641,JesseFischer,"2019-12-11 16:59:49",0.01234', '3763961,Alexander,"2019-12-11 16:59:49",0.01255', '3766496,Nanashi,"2019-12-11 16:59:49",0.01252', '3763227,"Ian Astalosh","2019-12-11 16:59:49",0.01243', '3763177,"Eric Freeman","2019-12-11 16:59:49",0.01241', '3767743,Soshi,"2019-12-11 16:59:49",0.01245', '3775053,"Carryon Calvin","2019-12-11 16:59:49",0.01700', '3793491,TeamSX,"2019-12-11 16:59:49",0.01683', '3835849,DeliveryClub,"2019-12-11 16:59:58",0.01232', '3764519,"The Last Run","2019-12-11 16:59:58",0.01142', '3766607,"Go Browns! Go Pats!","2019-12-11 16:59:58",0.01150', '3986792,"MSU guys","2019-12-11 16:59:58",0.01280', '3841366,spam_filter,"2019-12-11 16:59:58",0.01207', '3770055,"Patrick Ly","2019-12-11 16:59:58",0.01267', '3943197,adityasinha,"2019-12-11 16:59:58",0.01181', '3765352,"Bo Peng","2019-12-11 16:59:58",0.01252', '3767224,"Deimon Devil Bats","2019-12-11 16:59:58",0.01127', '3763585,"Dmitriy Ershov","2019-12-11 16:59:58",0.01253', '3782510,MDFam,"2019-12-11 16:59:58",0.01258', '3770055,"Patrick Ly","2019-12-11 16:59:58",0.01255', '3784522,何洛洛艺考加油,"2019-12-11 16:59:58",0.01323', '3806556,"Tverdov Konstantin","2019-12-11 16:59:58",0.01211', '3766909,Royz,"2019-12-11 16:59:58",0.01242', '3924750,Kaz,"2019-12-11 16:59:58",0.01238', '4043960,Robe_82,"2019-12-11 16:59:58",0.01253', '3782694,"Keith SZE","2019-12-11 16:59:58",0.01227', '3776784,erikw425,"2019-12-11 16:59:58",0.01254', '3775112,fugusuki,"2019-12-11 16:59:58",0.01197', '3974629,"MMP CMC Kagglers","2019-12-11 16:59:58",0.01251', '3814101,"logreg x 199","2019-12-11 16:59:58",0.01238', '3769588,"Allison Rountree","2019-12-11 16:59:58",0.01526', '3998268,"SimonW & SonamP","2019-12-11 16:59:58",0.01298', '3933774,"Uriel Corona","2019-12-11 16:59:58",0.01299', '3763936,Alvaro,"2019-12-11 16:59:58",0.01241', '3769052,YapaGenou,"2019-12-11 16:59:58",0.01240', '3849886,Summers,"2019-12-11 16:59:58",0.01249', '3763936,Alvaro,"2019-12-11 16:59:58",0.01241', '3784522,何洛洛艺考加油,"2019-12-11 16:59:58",0.01153', '3763583,SoulSk8rs4Life,"2019-12-11 16:59:58",0.01239', '3834763,AlexanderGeiger,"2019-12-11 16:59:58",0.01163', '3766475,"Shun_PI + colun","2019-12-11 16:59:58",0.01184', '3986792,"MSU guys","2019-12-11 16:59:58",0.01261', '3769824,"Huamin Zhang","2019-12-11 16:59:58",0.01252', '3768361,Merve,"2019-12-11 16:59:58",0.01269', '3880472,"Julien Roullé","2019-12-11 16:59:58",0.01305', '3804745,BenLatimer,"2019-12-11 16:59:58",0.01255', '3764244,katsu1110,"2019-12-11 16:59:58",0.01254', '3877421,ceb263,"2019-12-11 16:59:58",0.01263', '3766475,"Shun_PI + colun","2019-12-11 16:59:58",0.01180', '3775112,fugusuki,"2019-12-11 16:59:58",0.01194', '3781672,"If Eternity Should Fail","2019-12-11 16:59:58",0.01203', '4043478,lucaskg,"2019-12-11 16:59:58",0.01476', '4043478,lucaskg,"2019-12-11 16:59:58",0.01252', '3880707,zhbain,"2019-12-11 16:59:58",0.01247', '3765559,vroom,"2019-12-11 16:59:58",0.01189', '3775415,"Leonardo Ribeiro","2019-12-11 16:59:58",0.01249', '3780152,AndNov,"2019-12-11 16:59:58",0.01254', '3841049,EconGuy,"2019-12-11 16:59:58",0.01694', '3971544,mohi12345,"2019-12-11 16:59:58",0.01308', '3775350,andrekos,"2019-12-11 16:59:58",0.01252', '3782587,TSA,"2019-12-11 16:59:58",0.01313', '3765370,"dog and chick","2019-12-11 16:59:58",0.01232', '3784066,yuto16,"2019-12-11 16:59:58",0.01250', '3765797,Sugawarya,"2019-12-11 16:59:58",0.01257', '3944771,"Kara Hills","2019-12-11 16:59:58",0.01260', '3775129,sryo,"2019-12-11 16:59:58",0.01176', '3775129,sryo,"2019-12-11 16:59:58",0.01173', '3768062,"B H","2019-12-11 16:59:58",0.01259', '3768610,rauta,"2019-12-11 16:59:58",0.01253', '3946350,"Luca Massaron","2019-12-11 16:59:58",0.01257', '3793498,"MIT Team","2019-12-11 16:59:58",0.01304', '3994464,"Krizsó Gergely","2019-12-11 16:59:58",0.01251', '3831360,hmdhmd,"2019-12-11 16:59:58",0.01144', '3769648,"Chris R","2019-12-11 16:59:58",0.01192', '3979692,kagren,"2019-12-11 16:59:58",0.01689', '3913130,"small tiger","2019-12-11 16:59:58",0.01232', '3806556,"Tverdov Konstantin","2019-12-11 16:59:58",0.01210', '3794726,"[ods.ai] Mihail Parushkin","2019-12-11 16:59:58",0.01207', '3881183,"two boys","2019-12-11 16:59:58",0.01231', '3767007,AbdurRafae,"2019-12-11 16:59:58",0.01504', '3763721,Lindada,"2019-12-11 16:59:58",0.01219', '3775471,"Matthew Smith","2019-12-11 17:00:06",0.01276', '3980624,"Shaswata Jash","2019-12-11 17:00:06",0.01747', '3783775,"UTN SSK","2019-12-11 17:00:06",0.01252', '3819902,"Alexander Chernyshev","2019-12-11 17:00:06",0.01259', '3783636,"Tadashi Kikuchi","2019-12-11 17:00:06",0.01252', '3804985,"Arjun Subedi","2019-12-11 17:00:06",0.01249', '3996608,iamrouss,"2019-12-11 17:00:06",0.01254', '3784391,"UPenn Team","2019-12-11 17:00:06",0.01296', '3767386,"NE Patriots","2019-12-11 17:00:06",0.01252', '3816948,"Hyoseok Seo","2019-12-11 17:00:06",0.01482', '3793498,"MIT Team","2019-12-11 17:00:06",0.01300', '3956495,warrarougundji,"2019-12-11 17:00:06",0.01355', '3970875,"Pavel Suprun","2019-12-11 17:00:06",0.01254', '3764453,BlueJay,"2019-12-11 17:00:06",0.01424', '3764163,"The ARMADA","2019-12-11 17:00:06",0.01238', '3765928,"Marek Nurzynski","2019-12-11 17:00:06",0.01261', '3764029,Vadik,"2019-12-11 17:00:06",0.01251', '3857816,"Alex M","2019-12-11 17:00:06",0.01250', '4036489,"Joowon Lee","2019-12-11 17:00:06",0.01252', '3770801,"Beagle Kagglers","2019-12-11 17:00:06",0.01160', '3779023,authman,"2019-12-11 17:00:06",0.01223', '3788830,"Siddharth Sriraman","2019-12-11 17:00:06",0.01255', '3888701,"Leo Artaza","2019-12-11 17:00:06",0.01258', '3890550,"Solomon Xian","2019-12-11 17:00:06",0.01248', '3775350,andrekos,"2019-12-11 17:00:07",0.01252', '3816962,younglee,"2019-12-11 17:00:07",0.01253', '3764369,ironZinc,"2019-12-11 17:00:06",0.01242', '3794889,YaselGarcésSuárez,"2019-12-11 17:00:06",0.01437', '3950893,"Serhii Shcherbyna","2019-12-11 17:00:06",0.01253', '3771038,moon_lighting,"2019-12-11 17:00:06",0.01253', '3765797,Sugawarya,"2019-12-11 17:00:06",0.01257', '3766756,hrunic,"2019-12-11 17:00:06",0.01232', '3766756,hrunic,"2019-12-11 17:00:06",0.01228', '3765014,TI,"2019-12-11 17:00:06",0.01382', '3892973,"Kabir Singh","2019-12-11 17:00:06",0.01324', '3767095,"Jacek Rojek","2019-12-11 17:00:06",0.01253', '3878138,"Kuno Nori","2019-12-11 17:00:06",0.01250', '3768471,Stephen,"2019-12-11 17:00:06",0.01258', '3930514,GGPLOT2,"2019-12-11 17:00:06",0.01295', '3970875,"Pavel Suprun","2019-12-11 17:00:06",0.01253', '3769783,"Siddharth Chandrakant","2019-12-11 17:00:06",0.01251', '3891684,"InJu Kim","2019-12-11 17:00:06",0.01249', '3763683,akira,"2019-12-11 17:00:06",0.01209', '3768857,mark4h,"2019-12-11 17:00:06",0.01180', '3766691,"Kostas Maragkos","2019-12-11 17:00:06",0.01252', '3771873,resory,"2019-12-11 17:00:06",0.01411', '3974629,"MMP CMC Kagglers","2019-12-11 17:00:06",0.01248', '3777060,bradleetw2019,"2019-12-11 17:00:06",0.01272', '3766332,seba,"2019-12-11 17:00:06",0.01242', '3766553,fakeplastictrees,"2019-12-11 17:00:06",0.01231', '3764954,shimaw28,"2019-12-11 17:00:06",0.01243', '3788009,"Si Yu","2019-12-11 17:00:06",0.01228', '3775471,"Matthew Smith","2019-12-11 17:00:06",0.01252', '3763890,"Edison Siow","2019-12-11 17:00:06",0.01246', '3775415,"Leonardo Ribeiro","2019-12-11 17:00:06",0.01244', '3766584,Gert,"2019-12-11 17:00:06",0.01146', '3904450,"jun woo oh","2019-12-11 17:00:06",0.01252', '3768372,"Wei Hao Khoong","2019-12-11 17:00:06",0.01252', '3770364,"UE Football","2019-12-11 17:00:06",0.01428', '3809687,Nikola,"2019-12-11 17:00:06",0.51895', '3767953,"Dan Emery","2019-12-11 17:00:06",0.01241', '3882382,tamura,"2019-12-11 17:00:06",0.01247', '3910004,"Timothee Henry","2019-12-11 17:00:06",0.01254', '3785295,"Nico Higgs","2019-12-11 17:00:06",0.01220', '3772478,someone,"2019-12-11 17:00:06",0.01251', '3967823,TMorioka,"2019-12-11 17:00:07",0.01253', '3767076,"Steffen neuralgamebot.com","2019-12-11 17:00:06",0.01261', '3767007,AbdurRafae,"2019-12-11 17:00:06",0.01345', '3763473,Tweb,"2019-12-11 17:00:06",0.01253', '3768857,mark4h,"2019-12-11 17:00:06",0.01174', '3786760,hakusai,"2019-12-11 17:00:06",0.01252', '3785700,kiyomomo,"2019-12-11 17:00:07",0.01252', '3938365,"FengLei Dou","2019-12-11 17:00:15",0.01253', '3764328,"TaeHun Kim","2019-12-11 17:00:15",0.01251', '3776424,"DB sports","2019-12-11 17:00:15",0.01216', '3868609,"Ivan Klenovskiy","2019-12-11 17:00:15",0.01300', '3774717,"Ashish Singh","2019-12-11 17:00:15",0.01202', '3764741,"Kosarevsky Dmitry","2019-12-11 17:00:15",0.01253', '3816906,JBPARK,"2019-12-11 17:00:15",0.01259', '3767667,steelrose,"2019-12-11 17:00:15",0.01272', '3766909,Royz,"2019-12-11 17:00:15",0.01241', '3763195,"Go Rams 🐏","2019-12-11 17:00:15",0.01199', '3764289,"Aleck Wu","2019-12-11 17:00:15",0.01251', '4027053,ikousuke,"2019-12-11 17:00:15",0.01252', '3868609,"Ivan Klenovskiy","2019-12-11 17:00:15",0.01265', '3818366,SkyReaper,"2019-12-11 17:00:15",0.01245', '3771873,resory,"2019-12-11 17:00:15",0.01369', '3852962,earthy,"2019-12-11 17:00:15",0.01252', '3852962,earthy,"2019-12-11 17:00:15",0.01251', '3768924,@ChiefsAnalytics/@LeeSharpeNFL,"2019-12-11 17:00:15",0.01236', '3940918,mjjy,"2019-12-11 17:00:15",0.48104', '3763408,JB,"2019-12-11 17:00:15",0.01231', '3816662,andre_beton,"2019-12-11 17:00:15",0.01267', '3800402,"Mr Nik","2019-12-11 17:00:15",0.01252', '3880970,Appian,"2019-12-11 17:00:15",0.01251', '3766414,AnjanaKumar,"2019-12-11 17:00:15",0.01253', '3995319,hdkidz,"2019-12-11 17:00:15",0.01256', '3778153,"Shion Honda","2019-12-11 17:00:15",0.01256', '3770748,"Zach Lindsey","2019-12-11 17:00:15",0.01263', '4018005,"Eunjee Cho","2019-12-11 17:00:15",0.01252', '3887029,"USC ISE Analytics!","2019-12-11 17:00:15",0.01240', '3852919,"Pineapple of evolution","2019-12-11 17:00:15",0.01250', '3765496,"Ryuichi Ishikawa","2019-12-11 17:00:15",0.01230', '3784863,sunshineinautumn,"2019-12-11 17:00:15",0.01252', '3763623,u++,"2019-12-11 17:00:15",0.01252', '4007130,Habib,"2019-12-11 17:00:15",0.01252', '3789111,"Scott M","2019-12-11 17:00:15",0.01258', '4018059,"Seung Min Eo","2019-12-11 17:00:15",0.01257', '3983625,"Narek Maloyan","2019-12-11 17:00:15",0.01251', '3773032,Nikita,"2019-12-11 17:00:15",0.01246', '4030907,Zaryel,"2019-12-11 17:00:15",0.01253', '3763593,"Naruhiko Nakanishi","2019-12-11 17:00:15",0.01253', '3888701,"Leo Artaza","2019-12-11 17:00:15",0.01253', '3773644,AnXiong,"2019-12-11 17:00:15",0.01254', '3927839,nyregals,"2019-12-11 17:00:15",0.01257', '3961304,Zashio,"2019-12-11 17:00:15",0.01251', '3777946,"Call me Dong","2019-12-11 17:00:15",0.01253', '3764661,saneryee,"2019-12-11 17:00:15",0.01252', '3764761,"Eyeshield 21","2019-12-11 17:00:15",0.01223', '3763583,SoulSk8rs4Life,"2019-12-11 17:00:15",0.01236', '4027463,MadCoder,"2019-12-11 17:00:15",0.01680', '3784667,"brandon lin","2019-12-11 17:00:15",0.01253', '3793063,"Yuto Bando","2019-12-11 17:00:15",0.01251', '3780081,ploenzke,"2019-12-11 17:00:15",0.01394', '3816927,hysnar,"2019-12-11 17:00:15",0.01252', '3831842,b15d030,"2019-12-11 17:00:15",0.01254', '3763959,"NFL Academy","2019-12-11 17:00:15",0.01245', '3763907,Laffaye,"2019-12-11 17:00:15",0.01247', '3772990,"Laplace\'s Demon","2019-12-11 17:00:15",0.01145', '3856556,1999,"2019-12-11 17:00:15",0.01253', '3763665,aryyyyy,"2019-12-11 17:00:15",0.01252', '3771121,"Santiago Mota","2019-12-11 17:00:15",0.01252', '3767667,steelrose,"2019-12-11 17:00:15",0.01254', '3795282,"Bagel\'s Kaggle","2019-12-11 17:00:15",0.01246', '3929672,"Jonathan Bown","2019-12-11 17:00:15",0.01289', '3827546,ZheLI,"2019-12-11 17:00:15",0.01276', '3768580,"Kostiantyn Isaienkov","2019-12-11 17:00:15",0.01274', '3997608,"Steel Curtains","2019-12-11 17:00:15",0.01805', '3778000,"Marc JONOT","2019-12-11 17:00:15",0.01285', '3865563,tea,"2019-12-11 17:00:15",0.01253', '4024935,Roman,"2019-12-11 17:00:15",0.01252', '3775656,"Justin Yee","2019-12-11 17:00:15",0.01252', '3764554,KoitoU,"2019-12-11 17:00:15",0.01240', '3763201,pezlogd,"2019-12-11 17:00:15",0.01251', '3765842,RakeshNikam,"2019-12-11 17:00:15",0.01253', '3766615,"Vitalii Peretiatko","2019-12-11 17:00:15",0.01257', '4010780,"Sowmiyan Morri","2019-12-11 17:00:15",0.01254', '3764616,看你心情...,"2019-12-11 17:00:25",0.01189', '3881183,"two boys","2019-12-11 17:00:25",0.01229', '3764199,"Jiazhen Xi","2019-12-11 17:00:25",0.01245', '3972692,cubictoaster,"2019-12-11 17:00:25",0.01295', '3768022,"Alexandr Konovalov","2019-12-11 17:00:25",0.01252', '3798894,"Griffin Series","2019-12-11 17:00:25",0.01189', '3966187,"Elsa Xie","2019-12-11 17:00:25",0.01251', '3767743,Soshi,"2019-12-11 17:00:25",0.01240', '3816962,younglee,"2019-12-11 17:00:25",0.01251', '3814315,"Alexander Nichiporenko","2019-12-11 17:00:25",0.01252', '3985230,toronto_ds,"2019-12-11 17:00:25",0.01210', '3866164,juju,"2019-12-11 17:00:25",0.01244', '3804985,"Arjun Subedi","2019-12-11 17:00:25",0.01249', '3859355,asami,"2019-12-11 17:00:25",0.01249', '3778313,care,"2019-12-11 17:00:25",0.01252', '3940546,"Harris Y","2019-12-11 17:00:25",0.01249', '4036236,"Jack Wallner","2019-12-11 17:00:25",0.01741', '3916557,Ewan,"2019-12-11 17:00:25",0.01269', '3842220,Lights,"2019-12-11 17:00:25",0.01250', '4015034,"Toyonosuke Toyohama","2019-12-11 17:00:25",0.01635', '3817958,"Eduardo Rojas","2019-12-11 17:00:25",0.01333', '4015034,"Toyonosuke Toyohama","2019-12-11 17:00:25",0.01476', '3763282,"Lawrence Chernin","2019-12-11 17:00:25",0.01253', '3764521,"Mike Zhu","2019-12-11 17:00:25",0.01248', '3779368,guangkunli,"2019-12-11 17:00:25",0.01320', '3768380,"Back-propagating the Backfield","2019-12-11 17:00:25",0.01244', '3914435,Yuvraj,"2019-12-11 17:00:25",0.01244', '3913121,HOZHEN,"2019-12-11 17:00:25",0.01324', '3787930,"Predicting like Tony Romo","2019-12-11 17:00:25",0.01211', '3839870,rua,"2019-12-11 17:00:25",0.01255', '3816940,jangsangho,"2019-12-11 17:00:25",0.01252', '3811681,L&W,"2019-12-11 17:00:25",0.01223', '3764984,mrkmakr,"2019-12-11 17:00:25",0.01144', '3958185,"Atul Rao","2019-12-11 17:00:25",0.01252', '3782053,"Arrested Development","2019-12-11 17:00:25",0.01244', '3946350,"Luca Massaron","2019-12-11 17:00:25",0.01255', '3782587,TSA,"2019-12-11 17:00:25",0.01241', '3854715,charlie_s,"2019-12-11 17:00:25",0.01168', '3766286,Hayato,"2019-12-11 17:00:25",0.01250', '3790747,"Weather Superman","2019-12-11 17:00:25",0.01253', '3816677,dh6512,"2019-12-11 17:00:25",0.48104', '3771014,"Runhan Xu","2019-12-11 17:00:25",0.01837', '3763623,u++,"2019-12-11 17:00:25",0.01245', '4038500,恋言(regonn)🍵,"2019-12-11 17:00:25",0.01253', '3849254,"Sirish Somanchi","2019-12-11 17:00:25",0.01241', '3777189,Sleepers,"2019-12-11 17:00:25",0.01154', '3766465,"Piotr Nagrodkiewicz","2019-12-11 17:00:25",0.01232', '3768620,"Alexander Polyakov","2019-12-11 17:00:25",0.01252', '3805469,"Ellis K","2019-12-11 17:00:25",0.01683', '3771014,"Runhan Xu","2019-12-11 17:00:25",0.01767', '3805469,"Ellis K","2019-12-11 17:00:25",0.01680', '4008158,"Jason Qiao","2019-12-11 17:00:25",0.01273', '3903539,jousle,"2019-12-11 17:00:25",0.01323', '3986274,TracyZ,"2019-12-11 17:00:25",0.01263', '3769695,Randon,"2019-12-11 17:00:25",0.01273', '3910244,Minimi,"2019-12-11 17:00:25",0.01252', '3766607,"Go Browns! Go Pats!","2019-12-11 17:00:25",0.01148', '3986274,TracyZ,"2019-12-11 17:00:25",0.01247', '3843902,"Ananth Reddy","2019-12-11 17:00:25",0.11118', '3790980,"Stella Gim","2019-12-11 17:00:25",0.01253', '4037552,JinaKK,"2019-12-11 17:00:25",0.01253', '3933233,shuheioka,"2019-12-11 17:00:31",0.01252', '3868346,"Migs Rocha","2019-12-11 17:00:31",0.01252', '3764170,senkin13,"2019-12-11 17:00:31",0.01253', '3903539,jousle,"2019-12-11 17:00:31",0.01312', '3778982,JasonM,"2019-12-11 17:00:31",0.01298', '4037552,JinaKK,"2019-12-11 17:00:31",0.01253', '3910004,"Timothee Henry","2019-12-11 17:00:31",0.01252', '3766691,"Kostas Maragkos","2019-12-11 17:00:31",0.01252', '3769312,"futbol klub","2019-12-11 17:00:31",0.01233', '3992451,"[ods.ai] Learn2Play","2019-12-11 17:00:31",0.01240', '3855220,"Joonas Kalda","2019-12-11 17:00:31",0.01251', '3940748,Semie,"2019-12-11 17:00:31",0.01253', '3940748,Semie,"2019-12-11 17:00:31",0.01252', '3788009,"Si Yu","2019-12-11 17:00:31",0.01226', '3782389,touchdown,"2019-12-11 17:00:31",0.01252', '3764032,"Chia-Ta Tsai","2019-12-11 17:00:31",0.01760', '3827413,imdksk,"2019-12-11 17:00:31",0.01256', '3787022,"dan musetoiu","2019-12-11 17:00:31",0.01255', '3769418,"Grand Rookie","2019-12-11 17:00:32",0.01267', '3767027,znstrider,"2019-12-11 17:00:32",0.01338', '3847654,"Rutvik Lathiya","2019-12-11 17:00:32",0.01305', '3792910,GammaBros,"2019-12-11 17:00:32",0.01282', '3769045,Centrycs,"2019-12-11 17:00:32",0.01461', '3769418,"Grand Rookie","2019-12-11 17:00:32",0.01263', '3829368,"Vilen Jumutc","2019-12-11 17:00:32",0.01385', '3768713,AkiraIshikawa,"2019-12-11 17:00:32",0.01200', '3774082,"Mohammed Qadir Khan","2019-12-11 17:00:32",0.01298', '3839870,rua,"2019-12-11 17:00:32",0.01252', '3765842,RakeshNikam,"2019-12-11 17:00:32",0.01251', '4029996,JongWonC,"2019-12-11 17:00:32",0.01254', '3974646,jewonkimmm,"2019-12-11 17:00:32",0.01254', '3974646,jewonkimmm,"2019-12-11 17:00:32",0.01253', '3763331,"Ruslan Khalitov","2019-12-11 17:00:32",0.01252', '3847309,XiaoyuYang,"2019-12-11 17:00:31",0.01251', '3986032,DHK123,"2019-12-11 17:00:31",0.01246', '3911101,"Muhan Li","2019-12-11 17:00:31",0.01251', '3774529,"Ah bon","2019-12-11 17:00:31",0.01252', '4036640,Datasciensyash,"2019-12-11 17:00:31",0.01254', '3766802,"Clément Fauchereau","2019-12-11 17:00:31",0.01250', '3763864,pcullen11,"2019-12-11 17:00:31",0.01252', '3763907,Laffaye,"2019-12-11 17:00:31",0.01247', '3764453,BlueJay,"2019-12-11 17:00:31",0.01323', '3810911,RIStina_aguilera,"2019-12-11 17:00:31",0.01235', '3810293,"Bluering Data Octopus","2019-12-11 17:00:31",0.01240', '3763281,"Mycroft Holmes","2019-12-11 17:00:31",0.01257', '3770172,"Nikita Ageev","2019-12-11 17:00:31",0.01253', '4030725,"Artem Gluschenko","2019-12-11 17:00:31",0.01253', '3843784,"Marcelo Li Koga","2019-12-11 17:00:31",0.01296', '3763614,hukuda222,"2019-12-11 17:00:31",0.01253', '3817958,"Eduardo Rojas","2019-12-11 17:00:31",0.01332', '3764369,ironZinc,"2019-12-11 17:00:31",0.01241', '3814101,"logreg x 199","2019-12-11 17:00:31",0.01238', '3766465,"Piotr Nagrodkiewicz","2019-12-11 17:00:31",0.01222', '3786389,"Pavel Salikov","2019-12-11 17:00:31",0.01257', '3766809,ConorM,"2019-12-11 17:00:31",0.01461', '3766809,ConorM,"2019-12-11 17:00:31",0.01460', '3769941,"Captain Awesome","2019-12-11 17:00:32",0.01323', '4036489,"Joowon Lee","2019-12-11 17:00:31",0.01252', '3812013,smileeok,"2019-12-11 17:00:31",0.01741', '3774205,"Orkhan Baghirli","2019-12-11 17:00:31",0.01253', '3903538,mehrler,"2019-12-11 17:00:31",0.01309', '4034422,"MJ YU","2019-12-11 17:00:31",0.01252', '3863769,"Ilya Plemian","2019-12-11 17:00:31",0.01257', '3764418,tj_bh,"2019-12-11 17:00:31",0.01252', '3764418,tj_bh,"2019-12-11 17:00:31",0.01252', '3763680,Zoopal2LondonRPZ,"2019-12-11 17:00:31",0.01257', '3769763,mzmzmz,"2019-12-11 17:00:32",0.01324', '3816685,"Zachary Eagle","2019-12-11 17:00:38",0.01784', '3839576,QuOx,"2019-12-11 17:00:38",0.01252', '3776598,"Yusaku Muroya","2019-12-11 17:00:38",0.01254', '3862283,Hassan,"2019-12-11 17:00:38",0.01316', '3876680,"Aleks Dominik","2019-12-11 17:00:38",0.01325', '3832410,"kohei y","2019-12-11 17:00:38",0.01252', '3765891,人生若只如初见,"2019-12-11 17:00:38",0.01254', '3763608,"Fernando Pereira","2019-12-11 17:00:38",0.01299', '3833575,DownUnderData,"2019-12-11 17:00:38",0.01319', '3764266,"bu dong qiu","2019-12-11 17:00:38",0.01252', '3765825,WARRIORS,"2019-12-11 17:00:38",0.01253', '3806235,darthvader,"2019-12-11 17:00:38",0.01461', '3785140,ktpazder,"2019-12-11 17:00:38",0.01300', '3866972,chexex,"2019-12-11 17:00:38",0.01253', '3783887,"Pablo Herrero Quintero","2019-12-11 17:00:38",0.01278', '3875956,"Morty Zhang","2019-12-11 17:00:38",0.01476', '3779951,maelab,"2019-12-11 17:00:38",0.01255', '3764573,ArcWaterCash,"2019-12-11 17:00:38",0.01249', '3768031,Vinay,"2019-12-11 17:00:38",0.01251', '3785674,"Motohiro Sato","2019-12-11 17:00:38",0.01273', '3818137,"Euisung Kim","2019-12-11 17:00:38",0.01252', '3771653,RyanCaldwell,"2019-12-11 17:00:38",0.01251', '3768793,"Ali Esm","2019-12-11 17:00:38",0.01476', '3882825,wangjiade1015,"2019-12-11 17:00:38",0.01476', '3785841,"Maxime Berenger","2019-12-11 17:00:38",0.01599', '3866071,"jun matsukuma","2019-12-11 17:00:38",0.01276', '3782763,kukang,"2019-12-11 17:00:38",0.04405', '3800841,今晚打老虎,"2019-12-11 17:00:38",0.01488', '3801278,"Gustavo Bakker","2019-12-11 17:00:38",0.01476', '3843374,"Ryo Tomizawa","2019-12-11 17:00:38",0.01476', '3764056,"Olivier St-Amand","2019-12-11 17:00:38",0.01270', '3765384,"yechiel amsalem","2019-12-11 17:00:38",0.01256', '3869441,"Kirill Zaitsev","2019-12-11 17:00:38",0.01276', '3810927,Holger,"2019-12-11 17:00:38",0.01260', '3766242,"Saulius Tautvaisas","2019-12-11 17:00:38",0.01482', '3831581,bringbroiler,"2019-12-11 17:00:38",0.01323', '3791069,take_kana1114,"2019-12-11 17:00:38",0.01262', '3780221,"Maximilian Kapsecker","2019-12-11 17:00:38",0.01272', '3774231,Tanyapohn,"2019-12-11 17:00:38",0.01262', '3771653,RyanCaldwell,"2019-12-11 17:00:38",0.01251', '3876776,"Pavel Troshenkov","2019-12-11 17:00:38",0.01257', '3780980,"Noboru Hayashi","2019-12-11 17:00:38",0.01454', '3770657,predictingnoise,"2019-12-11 17:00:38",0.01276', '3791069,take_kana1114,"2019-12-11 17:00:38",0.01252', '3816685,"Zachary Eagle","2019-12-11 17:00:38",0.01762', '3766682,"Arijit Gupta","2019-12-11 17:00:38",0.01252', '3786821,"Karim Steiner","2019-12-11 17:00:38",0.01260', '3880906,"Joseph Szabo","2019-12-11 17:00:38",0.01741', '3779941,bitmapand,"2019-12-11 17:00:38",0.01305', '3774617,saewonYang,"2019-12-11 17:00:38",0.01323', '3791709,"Will Yin","2019-12-11 17:00:38",0.01741', '3766115,robert1003,"2019-12-11 17:00:38",0.01741', '3791712,MakotoTanji,"2019-12-11 17:00:38",0.01553', '3767650,Soriba,"2019-12-11 17:00:38",0.01765', '3820562,mahesh,"2019-12-11 17:00:38",0.01741', '3767650,Soriba,"2019-12-11 17:00:38",0.01752', '3793768,Shiki,"2019-12-11 17:00:38",0.01339', '3771842,"tora can","2019-12-11 17:00:38",0.01403', '3782637,"Djamel Khebab","2019-12-11 17:00:38",0.01538', '3805079,Cheese,"2019-12-11 17:00:38",0.01320', '3765912,"Nelson Hong Ming Tseng","2019-12-11 17:00:38",0.01463', '3771842,"tora can","2019-12-11 17:00:38",0.01373', '3834127,"Dmitry Dryomov","2019-12-11 17:00:38",0.01296', '3821044,"Daniel #3","2019-12-11 17:00:38",0.01297', '3811067,"Sahil Malhotra","2019-12-11 17:00:38",0.01247', '3836440,yoshino,"2019-12-11 17:00:38",0.01741', '3803385,Reggie,"2019-12-11 17:00:38",0.01741', '3769763,mzmzmz,"2019-12-11 17:00:38",0.01323', '3780977,GarrettStreet,"2019-12-11 17:00:38",0.01321', '3803385,Reggie,"2019-12-11 17:00:38",0.01276', '3769285,"Phil Butcher","2019-12-11 17:00:38",0.01301', '3766778,noypeban,"2019-12-11 17:00:38",0.01278', '3774224,"lu xi","2019-12-11 17:00:38",0.01254', '3865923,Taipon,"2019-12-11 17:00:38",0.01254', '3881065,anhol,"2019-12-11 17:00:38",0.01798', '3768345,"Yandi Zhu","2019-12-11 17:00:38",0.01253', '3771253,"Tetyana Yatsenko","2019-12-11 17:00:38",0.01260', '3879839,"Alexander Stasiuk","2019-12-11 17:00:38",0.01261', '3775505,Hartorn,"2019-12-11 17:00:38",0.01320', '3866750,urmil12345,"2019-12-11 17:00:38",0.01741', '3825341,dylan,"2019-12-11 17:00:38",0.01319', '3786310,Bootleg,"2019-12-11 17:00:38",0.01263', '3787270,"João Felix","2019-12-11 17:00:38",0.01741', '3877467,JonasKrueger,"2019-12-11 17:00:38",0.01741', '3786310,Bootleg,"2019-12-11 17:00:38",0.01258', '3769206,"DJ Christy","2019-12-11 17:00:38",0.01298', '3855733,"EQ Jordy","2019-12-11 17:00:38",0.01271', '3770730,"Mohamad Falah","2019-12-11 17:00:38",0.01476', '3819496,"Andres the cockroach","2019-12-11 17:00:38",0.01325', '3873414,"Alex Paxton","2019-12-11 17:00:38",0.01313', '3776632,motacapla,"2019-12-11 17:00:38",0.01262', '3777814,ByungSunBae,"2019-12-11 17:00:52",0.01469', '3776169,"Thomas Bourgeois","2019-12-11 17:00:52",0.01741', '3775206,"René Blaim","2019-12-11 17:00:52",0.01324', '3764834,"Sahil Mishra","2019-12-11 17:00:52",0.01319', '3767873,default,"2019-12-11 17:00:52",0.01339', '3781256,"Dzmitry Shakhrai","2019-12-11 17:00:52",0.01303', '3781044,matsuboccri,"2019-12-11 17:00:52",0.01324', '3763654,digimagi,"2019-12-11 17:00:51",0.01476', '3774611,"Kusunoki Chihiro","2019-12-11 17:00:51",0.01345', '3821710,"Lu Tang","2019-12-11 17:00:51",0.01298', '3890463,"György Katona","2019-12-11 17:00:51",0.01741', '3764670,"Syracuse Sport Analytics","2019-12-11 17:00:51",0.01710', '3763968,antwerp,"2019-12-11 17:00:51",0.01312', '3779128,"Boris Ilin","2019-12-11 17:00:51",0.01255', '3808942,"Harry Hu","2019-12-11 17:00:51",0.01337', '3796590,"Luke Metz","2019-12-11 17:00:51",0.01304', '3782564,hhxx,"2019-12-11 17:00:51",0.01251', '3802696,SethKitchen,"2019-12-11 17:00:51",0.01253', '3770539,edvinmemet,"2019-12-11 17:00:51",0.01265', '3769982,Jefferson,"2019-12-11 17:00:52",0.01319', '3834371,"Sujeeth S","2019-12-11 17:00:51",0.01256', '3775930,IvoL,"2019-12-11 17:00:52",0.01338', '3780098,Bengalstro,"2019-12-11 17:00:52",0.01345', '3763730,"Kostas H.","2019-12-11 17:00:52",0.01321', '3766067,"Dan Namba","2019-12-11 17:00:52",0.01407', '3769941,"Captain Awesome","2019-12-11 17:00:52",0.01323', '3764016,TouchDown!!!!!,"2019-12-11 17:00:52",0.01741', '3768453,Shasa,"2019-12-11 17:00:52",0.01465', '3788075,"Seonghyeon Lee","2019-12-11 17:00:52",0.01741', '3773565,"Tomasz Nowak","2019-12-11 17:00:52",0.01741', '3777231,masamichi_14,"2019-12-11 17:00:52",0.01741', '3779853,"William Fleshman","2019-12-11 17:00:52",0.01323', '3763612,"Marschall Furman","2019-12-11 17:00:52",0.01573', '3763425,"Devin Anzelmo","2019-12-11 17:00:52",0.01291', '3776966,ScottSchriner,"2019-12-11 17:00:52",0.01305', '3773113,"Prashant Banerjee","2019-12-11 17:00:52",0.01345', '3772457,qtumshift02,"2019-12-11 17:00:52",0.01741', '3765219,"Hirotaka Kawashima","2019-12-11 17:00:52",0.01741', '3767820,solohayuna,"2019-12-11 17:00:52",0.01323', '3773095,SPhillips,"2019-12-11 17:00:52",0.01477', '3777086,"Afonso Cunha","2019-12-11 17:00:52",0.01322', '3776368,"Nikita Kotelevskii","2019-12-11 17:00:52",0.01324', '3769033,pies,"2019-12-11 17:00:51",0.01809', '3769206,"DJ Christy","2019-12-11 17:00:51",0.01296', '3837734,"Scott Hanna-Riggs","2019-12-11 17:00:51",0.01741', '3827713,DBN,"2019-12-11 17:00:51",0.01917', '3789397,"Carlos Giraldo","2019-12-11 17:00:51",0.01345', '3763284,Optimo,"2019-12-11 17:00:51",0.01298', '3874712,user_san,"2019-12-11 17:00:51",0.01307', '3768499,MikeAltonji,"2019-12-11 17:00:51",0.07210', '3764907,ryches,"2019-12-11 17:00:51",0.01290', '3856910,"Omar Ismail","2019-12-11 17:00:51",0.01656', '3841108,anatoly,"2019-12-11 17:00:51",0.01252', '3764056,"Olivier St-Amand","2019-12-11 17:00:51",0.01270', '3790982,"Alex Galantsev","2019-12-11 17:00:51",0.01303', '3827178,狂暴野菊花,"2019-12-11 17:00:51",0.01798', '3787873,monda,"2019-12-11 17:00:51",0.01476', '3870713,GuangzhiWang,"2019-12-11 17:00:51",0.01252', '3868815,"Oleksii Sainog","2019-12-11 17:00:51",0.01255', '3877721,justfitting,"2019-12-11 17:00:51",0.01254', '3866686,sala1900,"2019-12-11 17:00:51",0.01273', '3767795,"rx kenp","2019-12-11 17:00:51",0.01842', '3775962,"Spencer Uresk","2019-12-11 17:00:51",0.01260', '3843499,dendenmushi,"2019-12-11 17:00:51",0.01253', '3774956,narsil,"2019-12-11 17:00:51",0.01330', '3869236,"William Spiegel","2019-12-11 17:00:51",0.01253', '3821661,marugari,"2019-12-11 17:00:51",0.01283', '3767296,Geeko,"2019-12-11 17:00:51",0.01255', '3856910,"Omar Ismail","2019-12-11 17:00:51",0.01316', '3872123,"Kawabata Naoyuki","2019-12-11 17:00:51",0.01269', '3763804,NAldershof,"2019-12-11 17:00:52",0.01303', '3808942,"Harry Hu","2019-12-11 17:00:51",0.01304', '3782754,"Youri Matiounine","2019-12-11 17:00:51",0.01267', '3775346,neilron,"2019-12-11 17:00:51",0.01277', '3828023,TGIF,"2019-12-11 17:00:51",0.01904', '3834127,"Dmitry Dryomov","2019-12-11 17:00:51",0.01296', '3763304,"zuo wang","2019-12-11 17:00:51",0.01324', '3795204,doodledood,"2019-12-11 17:00:51",0.01275', '3764907,ryches,"2019-12-11 17:00:51",0.01289', '3763284,Optimo,"2019-12-11 17:00:51",0.01281', '3775599,"Martin Bonardi","2019-12-11 17:00:51",0.01257', '3767152,nobu23tego,"2019-12-11 17:01:05",0.01741', '3836695,"TTU - Data Science League","2019-12-11 17:01:05",0.01741', '3764009,"Do Phuc","2019-12-11 17:01:05",0.01319', '3785835,"Ivan Afanasev","2019-12-11 17:01:05",0.01319', '3796113,matheus,"2019-12-11 17:01:05",0.01741', '3813639,"Benjamin Coudrin","2019-12-11 17:01:05",0.40295', '3772147,"Kenko Nakamura","2019-12-11 17:01:05",0.01305', '3764455,NFL?!,"2019-12-11 17:01:05",0.01792', '3764455,NFL?!,"2019-12-11 17:01:05",0.01741', '3764273,"Reese Haywood","2019-12-11 17:01:05",0.01432', '3790925,devrishi,"2019-12-11 17:01:05",0.01350', '3763423,steelRstats,"2019-12-11 17:01:05",0.01324', '3774563,Kiri,"2019-12-11 17:01:05",0.01741', '3774058,kengow,"2019-12-11 17:01:05",0.01323', '3774751,Saber,"2019-12-11 17:01:05",0.01741', '3774575,"Sergey Petrukhin ","2019-12-11 17:01:05",0.01741', '3768154,"Michał Marcińczuk","2019-12-11 17:01:05",0.01310', '3768581,LogicJake,"2019-12-11 17:01:05",0.01473', '3773095,SPhillips,"2019-12-11 17:01:05",0.01471', '3765244,"Shun Fukuda","2019-12-11 17:01:05",0.01741', '3805066,boulderslayer,"2019-12-11 17:01:05",0.01319', '3819496,"Andres the cockroach","2019-12-11 17:01:05",0.01323', '3791105,EndInTears,"2019-12-11 17:01:05",0.01323', '3792679,"SiChao Liu","2019-12-11 17:01:05",0.01319', '3764203,"rakuraku 21","2019-12-11 17:01:05",0.01319', '3791105,EndInTears,"2019-12-11 17:01:05",0.01305', '3789058,"Samdish Arora","2019-12-11 17:01:05",0.01741', '3771538,onishi,"2019-12-11 17:01:05",0.01319', '3791082,"Sunny Mulchandani","2019-12-11 17:01:05",0.01296', '3791733,"Shobha Sriram","2019-12-11 17:01:05",0.01319', '3769688,"Kirill Vladimirov","2019-12-11 17:01:05",0.01319', '3767269,SR,"2019-12-11 17:01:05",0.01306', '3805148,"Spencer Cushman","2019-12-11 17:01:05",0.01331', '3781260,Yugendran,"2019-12-11 17:01:05",0.01741', '3793768,Shiki,"2019-12-11 17:01:05",0.01334', '3821494,Bunnyhanhan,"2019-12-11 17:01:05",0.01302', '3821703,"Hidayat Lee","2019-12-11 17:01:05",0.01303', '3805148,"Spencer Cushman","2019-12-11 17:01:05",0.01321', '3779424,grobot,"2019-12-11 17:01:05",0.01323', '3768209,horohoro,"2019-12-11 17:01:05",0.01324', '3779072,Kampachi,"2019-12-11 17:01:05",0.01741', '3777026,mithos,"2019-12-11 17:01:05",0.01319', '3765530,"Eiji Konaka","2019-12-11 17:01:05",0.01306', '3769766,"Jishnu Nair","2019-12-11 17:01:05",0.01958', '3765426,sasakama,"2019-12-11 17:01:05",0.01746', '3764109,whale9490,"2019-12-11 17:01:05",0.01741', '3764449,"Gabriel Wu","2019-12-11 17:01:05",0.01741', '3764397,tkasasagi,"2019-12-11 17:01:05",0.01741', '3764216,Navy,"2019-12-11 17:01:05",0.01741', '3763690,"Maximilian Nitsche","2019-12-11 17:01:05",0.01741', '3764102,"Alexandre Gandini","2019-12-11 17:01:05",0.01741', '3764347,"Kevin Hamon","2019-12-11 17:01:05",0.01741', '3769422,"Pedro Frazão","2019-12-11 17:01:05",0.01741', '3764509,"Archit Gupta","2019-12-11 17:01:05",0.01471', '3769628,JA,"2019-12-11 17:01:05",0.01741', '3764070,"So Jae Woo","2019-12-11 17:01:05",0.01741', '3765860,Madden2KFifa,"2019-12-11 17:01:05",0.01412', '3765860,Madden2KFifa,"2019-12-11 17:01:05",0.01404', '3764723,hehpollon,"2019-12-11 17:01:05",0.01323', '3768741,"Krisztián Pomázi","2019-12-11 17:01:05",0.01324', '3772608,mutoyu,"2019-12-11 17:01:05",0.01741', '3764263,"Devin Davis","2019-12-11 17:01:05",0.01741', '3764127,nab391,"2019-12-11 17:01:05",0.01741', '3765035,akk,"2019-12-11 17:01:05",0.01741', '3765318,"Pulkit Mehta","2019-12-11 17:01:05",0.01741', '3767073,SimonW,"2019-12-11 17:01:05",0.01741', '3765530,"Eiji Konaka","2019-12-11 17:01:05",0.01304', '3766907,novanova,"2019-12-11 17:01:05",0.01741', '3771322,chuck_thunder,"2019-12-11 17:01:05",0.01303', '3766976,"Tak Yg","2019-12-11 17:01:05",0.01741', '3766730,"João Gonçalves","2019-12-11 17:01:05",0.01323', '3771396,davidsteinandfriends,"2019-12-11 17:01:05",0.01323', '3774636,MarkDonovan,"2019-12-11 17:01:05",0.01741', '3765578,"kohei tsuchiya","2019-12-11 17:01:05",0.01741', '3770457,"Danila Otnyukov","2019-12-11 17:01:05",0.01466', '3765538,"Leonid Sinev","2019-12-11 17:01:05",0.01741', '3767741,天外飞仙,"2019-12-11 17:01:05",0.01741', '3765780,"Chuanyu Yao","2019-12-11 17:01:05",0.01323', '3765503,"SusheendharVijay ","2019-12-11 17:01:05",0.01741', '3763719,"Taejun Jang","2019-12-11 17:01:05",0.01741', '3764301,Cebo,"2019-12-11 17:01:05",0.01337', '3765260,ZNing,"2019-12-11 17:01:05",0.01741', '3765568,LABAT,"2019-12-11 17:01:05",0.01741', '3768118,"Vasiliy Adyoshkin","2019-12-11 17:01:05",0.01741', '3772283,"Devon Shurick","2019-12-11 17:01:05",0.01741', '3769238,yfee,"2019-12-11 17:01:21",0.01304', '3786515,kalikichandu,"2019-12-11 17:01:21",0.01309', '3777946,"Call me Dong","2019-12-11 17:01:21",0.01252', '3765841,botD,"2019-12-11 17:01:21",0.01253', '3771117,Mukesh,"2019-12-11 17:01:21",0.01255', '3894886,"Unexpected Threat","2019-12-11 17:01:21",0.03208', '3764468,Rajath,"2019-12-11 17:01:21",0.01253', '3839311,wot,"2019-12-11 17:01:21",0.01245', '3770543,"Mark Guarnieri","2019-12-11 17:01:21",0.01285', '3812738,zlannn,"2019-12-11 17:01:21",0.01250', '3777051,hirayuki,"2019-12-11 17:01:21",0.01461', '3948855,"Igor Tokarev","2019-12-11 17:01:21",0.01252', '3787475,copypaste,"2019-12-11 17:01:21",0.01239', '3834898,"Keisuke Daimon","2019-12-11 17:01:21",0.01311', '3894334,yukimin,"2019-12-11 17:01:21",0.01253', '3880440,"Berkeley W207","2019-12-11 17:01:21",0.01308', '3905174,semprecalando,"2019-12-11 17:01:21",0.01313', '3804559,"NYU VIDA","2019-12-11 17:01:21",0.01268', '3796274,"Aziz Temirkhanov","2019-12-11 17:01:21",0.01276', '3958517,"Ray Lee","2019-12-11 17:01:21",0.01276', '3804195,"Alexander Kireev","2019-12-11 17:01:21",0.01240', '3908779,Carbon,"2019-12-11 17:01:21",0.01252', '3800863,"Usman Islam","2019-12-11 17:01:21",0.01266', '3783445,"William Attié","2019-12-11 17:01:21",0.01798', '3764270,"Adam Suwik","2019-12-11 17:01:21",0.01214', '3919602,"Ado Dream","2019-12-11 17:01:21",0.01252', '3769583,Blazej,"2019-12-11 17:01:21",0.01496', '3766682,"Arijit Gupta","2019-12-11 17:01:21",0.01251', '3794755,AntonNegreba,"2019-12-11 17:01:21",0.01245', '3862283,Hassan,"2019-12-11 17:01:21",0.01252', '3765649,Piyush,"2019-12-11 17:01:21",0.01251', '3771986,"Bill Miao","2019-12-11 17:01:21",0.01251', '3770930,"GEYIJIE LI","2019-12-11 17:01:21",0.01259', '3769716,"Dhruuv Agarwal","2019-12-11 17:01:21",0.01252', '3881097,Dacian,"2019-12-11 17:01:21",0.01251', '3966324,"Konstantin Shamruk","2019-12-11 17:01:21",0.01324', '3774791,"buffalo wings","2019-12-11 17:01:21",0.01250', '3767520,somnambWl,"2019-12-11 17:01:21",0.01251', '3928000,"Jeffrey Scholz","2019-12-11 17:01:21",0.01319', '3952377,"Kaushal Shah","2019-12-11 17:01:21",0.01467', '3842150,Behrang,"2019-12-11 17:01:21",0.01252', '3944884,"Shi Zhenyu","2019-12-11 17:01:21",0.01317', '3825344,AmrA,"2019-12-11 17:01:21",0.01968', '3890817,"Diego Campo","2019-12-11 17:01:21",0.01741', '3782312,"Nathan Hunt","2019-12-11 17:01:21",0.01281', '3770531,IvoFilipe,"2019-12-11 17:01:21",0.01486', '3769788,"John Henderson","2019-12-11 17:01:21",0.01255', '3959224,Kaito510,"2019-12-11 17:01:21",0.01255', '3765014,TI,"2019-12-11 17:01:21",0.01319', '3814488,"Jack tao","2019-12-11 17:01:21",0.01320', '3890356,Neild1990,"2019-12-11 17:01:21",0.01256', '3764532,JohnM,"2019-12-11 17:01:21",0.01907', '3767269,SR,"2019-12-11 17:01:21",0.01306', '3765611,OCEAN,"2019-12-11 17:01:21",0.01296', '3763229,dipplestix,"2019-12-11 17:01:21",0.01741', '3770078,"Robin Lingwood","2019-12-11 17:01:21",0.02075', '3790764,ddq1988,"2019-12-11 17:01:21",0.01319', '3763649,Takao,"2019-12-11 17:01:21",0.01319', '3770414,"Jonathan E","2019-12-11 17:01:21",0.01798', '3781264,"arif romadhan","2019-12-11 17:01:21",0.01339', '3793903,threecourse,"2019-12-11 17:01:21",0.01319', '3765061,"ahmed zaky","2019-12-11 17:01:21",0.01284', '3790606,Samarth,"2019-12-11 17:01:21",0.01741', '3834898,"Keisuke Daimon","2019-12-11 17:01:21",0.01311', '3912146,Ahust,"2019-12-11 17:01:21",0.01347', '3774472,ramen,"2019-12-11 17:01:21",0.01262', '3800210,mohamed,"2019-12-11 17:01:21",0.01244', '3765916,VladB,"2019-12-11 17:01:21",0.01284', '3819654,"Andriy G","2019-12-11 17:01:21",0.01336', '3768741,"Krisztián Pomázi","2019-12-11 17:01:21",0.01253', '3794488,Bananalytics,"2019-12-11 17:01:21",0.01281', '3959224,Kaito510,"2019-12-11 17:01:21",0.01252', '3842548,DrWho,"2019-12-11 17:01:21",0.01251', '3792037,"Bibin Paul","2019-12-11 17:01:21",0.01253', '3960982,y-Carbon,"2019-12-11 17:01:21",0.01252', '3797603,xjoyzaza,"2019-12-11 17:01:21",0.01252', '3843655,Aigu,"2019-12-11 17:01:21",0.01225', '3778982,JasonM,"2019-12-11 17:01:21",0.01249', '3894334,yukimin,"2019-12-11 17:01:21",0.01252', '3825344,AmrA,"2019-12-11 17:01:21",0.01941', '3796083,Data1,"2019-12-11 17:01:21",0.01273', '3774763,"Robert Simpson","2019-12-11 17:01:21",0.01288', '3765069,"Martin Matta","2019-12-11 17:01:21",0.01301', '3774763,"Robert Simpson","2019-12-11 17:01:35",0.01288', '3891292,"Corentin Berteloot","2019-12-11 17:01:35",0.01257', '3768490,Meyran,"2019-12-11 17:01:35",0.01286', '3784246,Jose,"2019-12-11 17:01:35",0.01323', '3922431,ildarsafilo,"2019-12-11 17:01:35",0.01252', '3771908,Scottfree,"2019-12-11 17:01:35",0.01252', '3768103,BartvonMeijenfeldt,"2019-12-11 17:01:35",0.01246', '3922431,ildarsafilo,"2019-12-11 17:01:35",0.01250', '3769301,pao,"2019-12-11 17:01:35",0.01263', '3889941,"Nguyen Quan Anh Minh","2019-12-11 17:01:35",0.01252', '3797603,xjoyzaza,"2019-12-11 17:01:35",0.01252', '3943041,"Kazuyuki Mori","2019-12-11 17:01:35",0.01252', '3769380,Andy_Maricopa,"2019-12-11 17:01:35",0.01578', '3902035,"Parkinson Zabelin","2019-12-11 17:01:35",0.01252', '3943491,Maxim555,"2019-12-11 17:01:35",0.01306', '3877713,"Abrek Bavizhev","2019-12-11 17:01:35",0.01253', '3847728,"Bob Wang #2","2019-12-11 17:01:35",0.01260', '3938988,wire,"2019-12-11 17:01:35",0.01741', '3903866,"Jonny Bouthilet","2019-12-11 17:01:35",0.01741', '3843499,dendenmushi,"2019-12-11 17:01:35",0.01253', '3944366,"Mitch Williams","2019-12-11 17:01:35",0.01311', '3838475,Akki,"2019-12-11 17:01:35",0.01476', '3903553,"Mike #2","2019-12-11 17:01:35",0.01252', '3766481,Lee_Chen,"2019-12-11 17:01:35",0.01252', '3778897,"miguel perez","2019-12-11 17:01:35",0.01283', '3931570,"Shashi Prakash Tripathi","2019-12-11 17:01:35",0.01250', '3809924,"Nikita Churkin","2019-12-11 17:01:35",0.01250', '3830833,Rigel,"2019-12-11 17:01:35",0.01252', '3955449,"Zuoqiao Shen","2019-12-11 17:01:35",0.01542', '3862471,LeonShangguan,"2019-12-11 17:01:35",0.01252', '3776879,chechsterfildsilv,"2019-12-11 17:01:35",0.01255', '3793742,Dalek,"2019-12-11 17:01:35",0.01296', '3836726,TheDude,"2019-12-11 17:01:35",0.01270', '3765206,Lisz,"2019-12-11 17:01:35",0.01240', '3781569,"Shaod Liu","2019-12-11 17:01:35",0.01252', '3839812,Dohee,"2019-12-11 17:01:35",0.01251', '3812112,Pablo,"2019-12-11 17:01:35",0.01292', '3772588,"Keisuke Yanagisawa","2019-12-11 17:01:35",0.01977', '3769793,"Lang Sys","2019-12-11 17:01:35",0.01253', '3808091,"Thomas Novitsky","2019-12-11 17:01:35",0.01253', '3765736,ValeriyBabushkin,"2019-12-11 17:01:35",0.01303', '3774224,"lu xi","2019-12-11 17:01:35",0.01254', '3844072,"Speed Snail","2019-12-11 17:01:35",0.01303', '3781934,Abhi,"2019-12-11 17:01:35",0.01656', '3812551,newhand,"2019-12-11 17:01:35",0.01251', '3771767,mochidan,"2019-12-11 17:01:35",0.01251', '3819654,"Andriy G","2019-12-11 17:01:35",0.01335', '3767880,"Niranjan Nakkala","2019-12-11 17:01:35",0.01252', '3955181,"Kyurie Park","2019-12-11 17:01:35",0.01252', '3769716,"Dhruuv Agarwal","2019-12-11 17:01:35",0.01250', '3767922,kojimar,"2019-12-11 17:01:35",0.01252', '3768996,pongba,"2019-12-11 17:01:35",0.01253', '3764852,"Marco Vasquez E","2019-12-11 17:01:35",0.01252', '3781934,Abhi,"2019-12-11 17:01:35",0.01629', '3765557,大碗饭加蛋,"2019-12-11 17:01:35",0.01253', '3871934,SA0987,"2019-12-11 17:01:35",0.01318', '3866302,nyancat62,"2019-12-11 17:01:35",0.01252', '3764150,"Itsuki Hamano","2019-12-11 17:01:35",0.01252', '3779877,"Roy Perry","2019-12-11 17:01:35",0.01345', '3767233,"Edward Wheatcroft","2019-12-11 17:01:35",0.01308', '3788946,wittmaan,"2019-12-11 17:01:35",0.01252', '3866972,chexex,"2019-12-11 17:01:35",0.01252', '3839812,Dohee,"2019-12-11 17:01:35",0.01250', '3845038,Yongke,"2019-12-11 17:01:35",0.01297', '3915900,imait,"2019-12-11 17:01:35",0.01251', '3790606,Samarth,"2019-12-11 17:01:35",0.01251', '3779584,"Noah Weber","2019-12-11 17:01:35",0.01252', '3764916,SVJ24,"2019-12-11 17:01:35",0.01311', '3766317,"Nick Styles","2019-12-11 17:01:35",0.01252', '3774472,ramen,"2019-12-11 17:01:35",0.01261', '3768326,"Anton Lytyakov","2019-12-11 17:01:35",0.01196', '3781659,"brady == 🐐","2019-12-11 17:01:35",0.01251', '3766423,DaoSword,"2019-12-11 17:01:35",0.01253', '3850069,Ramstein,"2019-12-11 17:01:35",0.01253', '3944366,"Mitch Williams","2019-12-11 17:01:35",0.01279', '3926936,TTang,"2019-12-11 17:01:47",0.01461', '3979316,CS18MDS11023,"2019-12-11 17:01:47",0.01453', '3942110,Artem,"2019-12-11 17:01:47",0.01765', '3867001,"Lawrence Teo","2019-12-11 17:01:47",0.01269', '3977940,CS18MDS11018,"2019-12-11 17:01:47",0.01844', '3770198,ukkuruza,"2019-12-11 17:01:47",0.01308', '3967390,Janos,"2019-12-11 17:01:47",0.01250', '3867001,"Lawrence Teo","2019-12-11 17:01:47",0.01268', '3882687,"Pritesh Shrivastava","2019-12-11 17:01:47",0.01252', '3975861,CS18MDS11028,"2019-12-11 17:01:47",0.04444', '3979874,govindha,"2019-12-11 17:01:47",0.01294', '3828023,TGIF,"2019-12-11 17:01:47",0.01903', '3974248,CS18MDS11026,"2019-12-11 17:01:47",0.01809', '3974781,CS18MDS11025,"2019-12-11 17:01:47",0.01722', '3768326,"Anton Lytyakov","2019-12-11 17:01:47",0.01191', '3800021,Sasase,"2019-12-11 17:01:47",0.01346', '3982932,remisharoon,"2019-12-11 17:01:47",0.01314', '3982932,remisharoon,"2019-12-11 17:01:47",0.01309', '3777051,hirayuki,"2019-12-11 17:01:47",0.01270', '3977940,CS18MDS11018,"2019-12-11 17:01:47",0.01838', '3766891,simon,"2019-12-11 17:01:47",0.01251', '3763743,"Green Bay Packers","2019-12-11 17:01:47",0.01251', '3780980,"Noboru Hayashi","2019-12-11 17:01:47",0.01256', '3974539,CS18MDS11008,"2019-12-11 17:01:47",0.01813', '3765356,forward,"2019-12-11 17:01:47",0.01300', '3851886,"Yosuke Ishiguro","2019-12-11 17:01:47",0.01251', '3775349,Yixinchen,"2019-12-11 17:01:47",0.01252', '3983611,"Jiyeon Lee","2019-12-11 17:01:47",0.01252', '3768781,parseltung,"2019-12-11 17:01:47",0.01252', '3817013,KimBoKyu,"2019-12-11 17:01:47",0.01252', '3764756,DKim,"2019-12-11 17:01:47",0.01693', '3892650,"TJ Klein","2019-12-11 17:01:47",0.01248', '3843655,Aigu,"2019-12-11 17:01:47",0.01217', '3773159,"Kishore M","2019-12-11 17:01:47",0.01249', '3908836,"Jimin Yoon","2019-12-11 17:01:47",0.01250', '3981351,"Justin #5","2019-12-11 17:01:47",0.01276', '3783509,"The Mean Squirrels","2019-12-11 17:01:47",0.14809', '3774516,Yerne🐉,"2019-12-11 17:01:47",0.01276', '3974427,CS18MDS11011,"2019-12-11 17:01:47",0.01764', '3768945,"FIrst blood","2019-12-11 17:01:47",0.01249', '3978984,cs18mds11017,"2019-12-11 17:01:47",0.49589', '3974669,CS18MDS11030,"2019-12-11 17:01:47",0.01466', '3805329,jamalc,"2019-12-11 17:01:47",0.01573', '3784246,Jose,"2019-12-11 17:01:47",0.01311', '3766405,"Bernd Allmendinger","2019-12-11 17:01:47",0.01238', '3955449,"Zuoqiao Shen","2019-12-11 17:01:47",0.01312', '3936748,"Qi Pan","2019-12-11 17:01:47",0.01476', '3792661,tasv,"2019-12-11 17:01:47",0.01256', '3872532,Becon,"2019-12-11 17:01:47",0.01483', '3872532,Becon,"2019-12-11 17:01:47",0.01470', '3951727,"Mikhail Karchevskiy","2019-12-11 17:01:47",0.01251', '3787873,monda,"2019-12-11 17:01:47",0.01254', '3764817,Mickey,"2019-12-11 17:01:47",0.01211', '3932081,"Krishna Chaitanya","2019-12-11 17:01:47",0.01252', '3769583,Blazej,"2019-12-11 17:01:47",0.01463', '3845038,Yongke,"2019-12-11 17:01:47",0.01296', '3947791,@doanquanvietnamca,"2019-12-11 17:01:47",0.01522', '3931570,"Shashi Prakash Tripathi","2019-12-11 17:01:47",0.01249', '3978605,CS18MDS11027,"2019-12-11 17:01:47",0.01896', '3974248,CS18MDS11026,"2019-12-11 17:01:47",0.01792', '3827413,imdksk,"2019-12-11 17:01:47",0.01256', '3819902,"Alexander Chernyshev","2019-12-11 17:01:47",0.01259', '3971313,servase,"2019-12-11 17:01:47",0.01472', '3974067,"Krisztián Fekete","2019-12-11 17:01:47",0.01251', '3983463,CS18MDS11024,"2019-12-11 17:01:47",0.49367', '3923530,CaseyPeters,"2019-12-11 17:01:47",0.01305', '3979307,"cs18mds11032 ","2019-12-11 17:01:47",0.01988', '3975861,CS18MDS11028,"2019-12-11 17:01:47",0.01479', '3977423,cs18mds11031,"2019-12-11 17:01:47",0.01798', '3975112,cs18mds11012,"2019-12-11 17:01:47",0.01738', '3976068,CS18MDS11010,"2019-12-11 17:01:47",0.01597', '3770543,"Mark Guarnieri","2019-12-11 17:01:47",0.01259', '3978605,CS18MDS11027,"2019-12-11 17:01:47",0.01855', '3768707,"Stanislav Blinov","2019-12-11 17:01:47",0.01252', '3974361,CS18MDS11006,"2019-12-11 17:01:47",0.01473', '3929098,"Jo Jimbo","2019-12-11 17:01:57",0.01296', '3892650,"TJ Klein","2019-12-11 17:01:57",0.01248', '3836726,TheDude,"2019-12-11 17:01:57",0.01268', '3880617,Pim88,"2019-12-11 17:01:57",0.01468', '3904276,SN,"2019-12-11 17:01:56",0.01481', '3764006,BillsMafia,"2019-12-11 17:01:56",0.01257', '3764191,"Yongqi Zhong","2019-12-11 17:01:56",0.01262', '3803731,"Fredrick Neo","2019-12-11 17:01:56",0.01741', '3774192,"zhang jinlai","2019-12-11 17:01:56",0.01253', '3886649,"Pablo Lobato","2019-12-11 17:01:56",0.01470', '3764807,RunningZ,"2019-12-11 17:01:56",0.01252', '3951766,nataliayap,"2019-12-11 17:01:56",0.01252', '3951766,nataliayap,"2019-12-11 17:01:56",0.01250', '3816843,"Bruce Young","2019-12-11 17:01:56",0.01252', '3943094,"Daisuke ODE","2019-12-11 17:01:57",0.01251', '3866049,kstats,"2019-12-11 17:01:56",0.01323', '3771693,WNYSAC,"2019-12-11 17:01:57",0.01251', '3765841,botD,"2019-12-11 17:01:57",0.01252', '3968154,avati,"2019-12-11 17:01:57",0.01316', '3975966,"V B","2019-12-11 17:01:57",0.01253', '3784664,D_dof,"2019-12-11 17:01:57",0.01333', '3773513,Kasumi_Arimura_ha_Kawaii,"2019-12-11 17:01:57",0.01252', '3784664,D_dof,"2019-12-11 17:01:57",0.01251', '3976643,CS18MDS11001,"2019-12-11 17:01:57",0.01301', '3980605,Harani,"2019-12-11 17:01:57",0.05614', '3929098,"Jo Jimbo","2019-12-11 17:01:57",0.01282', '3975374,cs18mds11029,"2019-12-11 17:01:57",0.01748', '3981947,"Iaroslav Elistratov","2019-12-11 17:01:57",0.01254', '3974655,CS18MDS11002,"2019-12-11 17:01:57",0.01470', '3974781,CS18MDS11025,"2019-12-11 17:01:57",0.01721', '3881433,"narain p","2019-12-11 17:01:57",0.01462', '3982015,ChibiYuki,"2019-12-11 17:01:57",0.01476', '3981593,skyneteyes,"2019-12-11 17:01:57",0.01252', '3764006,BillsMafia,"2019-12-11 17:01:57",0.01255', '3866049,kstats,"2019-12-11 17:01:57",0.01305', '3778278,hktxt,"2019-12-11 17:01:56",0.01253', '3948993,beepbloop11879,"2019-12-11 17:01:56",0.01253', '3966324,"Konstantin Shamruk","2019-12-11 17:01:56",0.01323', '3831842,b15d030,"2019-12-11 17:01:56",0.01253', '3987580,"Kamal Chhirang","2019-12-11 17:01:56",0.01252', '3959734,"cc #2","2019-12-11 17:01:56",0.01258', '3817075,faucet,"2019-12-11 17:01:56",0.01346', '3782509,Prachi,"2019-12-11 17:01:56",0.01297', '3974336,cs18mds11014@iith.ac.in,"2019-12-11 17:01:56",0.04362', '3764099,Young,"2019-12-11 17:01:56",0.01252', '3769381,DataHackers,"2019-12-11 17:01:56",0.01256', '3981947,"Iaroslav Elistratov","2019-12-11 17:01:56",0.01251', '3817075,faucet,"2019-12-11 17:01:56",0.01336', '3764060,takuoko,"2019-12-11 17:01:56",0.01232', '3798138,wancyope,"2019-12-11 17:01:56",0.01255', '3985546,takashi,"2019-12-11 17:01:56",0.01250', '3975211,cs18mds11016,"2019-12-11 17:01:56",0.01294', '3842018,"James Requa","2019-12-11 17:01:56",0.01253', '3974539,CS18MDS11008,"2019-12-11 17:01:56",0.01799', '3880617,Pim88,"2019-12-11 17:01:56",0.01453', '3770198,ukkuruza,"2019-12-11 17:01:56",0.01304', '3976643,CS18MDS11001,"2019-12-11 17:01:56",0.01299', '3975126,abdelatif,"2019-12-11 17:01:56",0.01255', '3763415,"Dimosthenis Karaflos","2019-12-11 17:01:56",0.01254', '3766414,AnjanaKumar,"2019-12-11 17:01:56",0.01251', '3973166,HarryQuake,"2019-12-11 17:01:56",0.01252', '3972792,gorilladoi,"2019-12-11 17:01:56",0.01476', '3773121,chadliu,"2019-12-11 17:01:56",0.01252', '3972792,gorilladoi,"2019-12-11 17:01:56",0.01320', '3816843,"Bruce Young","2019-12-11 17:01:56",0.01251', '3816915,"GIDONG PARK","2019-12-11 17:01:56",0.01252', '3863001,Not.That.Hard,"2019-12-11 17:01:57",0.01285', '3816922,"marine6310김성일(대학원학생/경제대학원 기업경제전공)","2019-12-11 17:01:56",0.01252', '3903553,"Mike #2","2019-12-11 17:01:56",0.01251', '3764817,Mickey,"2019-12-11 17:01:56",0.01210', '3773725,Scirpus,"2019-12-11 17:01:56",0.01252', '3961443,"MA Junyi","2019-12-11 17:01:56",0.01253', '3768753,"just trying","2019-12-11 17:01:56",0.01252', '3765302,theheena,"2019-12-11 17:01:56",0.01446', '3805329,jamalc,"2019-12-11 17:01:56",0.01553', '3978129,"Igeta Kazu","2019-12-11 17:02:05",0.01310', '3797842,"Sam O’Connell","2019-12-11 17:02:05",0.01327', '3810904,"Sophie Antoniak","2019-12-11 17:02:05",0.01323', '3770530,"Nigel A. R. Henry","2019-12-11 17:02:05",0.01306', '3912146,Ahust,"2019-12-11 17:02:05",0.01252', '3815303,"Eric #2","2019-12-11 17:02:05",0.01753', '3767936,"Muhammad Farrel Mahendra","2019-12-11 17:02:05",0.01257', '3785537,lucas1347,"2019-12-11 17:02:05",0.01253', '3902570,"Maggie Zhou","2019-12-11 17:02:05",0.01252', '3810875,"Pepito Bleu","2019-12-11 17:02:05",0.01249', '3859154,(2/3)Trinca+B,"2019-12-11 17:02:05",0.01323', '3856556,1999,"2019-12-11 17:02:05",0.01251', '3769845,"Hartmut Ott","2019-12-11 17:02:05",0.01265', '3782484,nariman9119,"2019-12-11 17:02:05",0.01253', '3787107,_Tï_,"2019-12-11 17:02:05",0.01315', '3782484,nariman9119,"2019-12-11 17:02:05",0.01251', '3765718,"Adib Priatama","2019-12-11 17:02:05",0.01250', '3908164,"tom barkley","2019-12-11 17:02:05",0.01246', '3898994,"Josh M","2019-12-11 17:02:05",0.01949', '3798138,wancyope,"2019-12-11 17:02:05",0.01252', '3915278,niik,"2019-12-11 17:02:05",0.01741', '3915375,wyldream,"2019-12-11 17:02:05",0.01250', '3808715,"Haakon E. Nustad","2019-12-11 17:02:05",0.01374', '3807034,TheAINerds,"2019-12-11 17:02:05",0.01476', '3877713,"Abrek Bavizhev","2019-12-11 17:02:05",0.01251', '3764485,369,"2019-12-11 17:02:05",0.01246', '3889256,"Mohit Rane","2019-12-11 17:02:05",0.06869', '3811918,LiangXi,"2019-12-11 17:02:05",0.01300', '3897060,"Ruichuan Wong","2019-12-11 17:02:05",0.01250', '3913900,Kyota,"2019-12-11 17:02:05",0.01251', '3766562,"Flavien Gelineau","2019-12-11 17:02:05",0.01252', '3771388,"D C Aichara","2019-12-11 17:02:05",0.01249', '3919175,sarusiya,"2019-12-11 17:02:05",0.01252', '3764236,"Avinash Barnwal","2019-12-11 17:02:05",0.01253', '3919466,gorogoroumaru,"2019-12-11 17:02:05",0.01249', '3828549,xz,"2019-12-11 17:02:05",0.01252', '3776827,JaredNielsen,"2019-12-11 17:02:05",0.01741', '3908276,"Lorenzo Lucido","2019-12-11 17:02:05",0.01314', '3906905,"Josh K","2019-12-11 17:02:05",0.01652', '3808091,"Thomas Novitsky","2019-12-11 17:02:05",0.01249', '3764478,"Ricardo Stamato","2019-12-11 17:02:05",0.01699', '3764461,duvallwh,"2019-12-11 17:02:05",0.01252', '3911786,"Tim S","2019-12-11 17:02:05",0.01906', '3910072,"Artem Vazhentsev","2019-12-11 17:02:05",0.01274', '3778456,CFDAero,"2019-12-11 17:02:05",0.01248', '3781932,liuze,"2019-12-11 17:02:05",0.01252', '3767095,"Jacek Rojek","2019-12-11 17:02:05",0.01252', '3974361,CS18MDS11006,"2019-12-11 17:02:05",0.01466', '3784009,noidea,"2019-12-11 17:02:05",0.01250', '3977912,CS18MDS11007,"2019-12-11 17:02:05",0.01864', '3975374,cs18mds11029,"2019-12-11 17:02:05",0.01743', '3774410,stephen_mugisha,"2019-12-11 17:02:05",0.01269', '3831460,luckylu,"2019-12-11 17:02:05",0.01264', '3766016,KolawoleTajudeen,"2019-12-11 17:02:05",0.01253', '3865438,drakk,"2019-12-11 17:02:05",0.02243', '3908276,"Lorenzo Lucido","2019-12-11 17:02:05",0.01260', '3830984,GX,"2019-12-11 17:02:05",0.01256', '3797177,k.wata,"2019-12-11 17:02:05",0.01261', '3774552,"Sudeep Shouche","2019-12-11 17:02:05",0.01259', '3801658,asqtzal,"2019-12-11 17:02:05",0.01479', '3775243,"Andrey Demidov","2019-12-11 17:02:05",0.01260', '3773313,SkyBlazer,"2019-12-11 17:02:05",0.01741', '3763367,ZFTurbo,"2019-12-11 17:02:05",0.01250', '3765718,"Adib Priatama","2019-12-11 17:02:05",0.01249', '3846694,rookie,"2019-12-11 17:02:05",0.01250', '3791424,claverru,"2019-12-11 17:02:05",0.01310', '3765444,"Veerala Hari Krishna","2019-12-11 17:02:05",0.01250', '3764053,"Subin An","2019-12-11 17:02:05",0.01253', '3764266,"bu dong qiu","2019-12-11 17:02:05",0.01250', '3868687,littlexiaogui,"2019-12-11 17:02:05",0.01251', '3784691,"Kagawa Keisuke","2019-12-11 17:02:05",0.01470', '3768345,"Yandi Zhu","2019-12-11 17:02:05",0.01250', '3764570,TY.Yang,"2019-12-11 17:02:05",0.01249', '3866071,"jun matsukuma","2019-12-11 17:02:05",0.01251', '3909975,SpqceD,"2019-12-11 17:02:05",0.01253', '3909975,SpqceD,"2019-12-11 17:02:15",0.01252', '3776313,naknak,"2019-12-11 17:02:15",0.01310', '3765546,"Yu,Hai ","2019-12-11 17:02:15",0.01253', '3903204,statexchange,"2019-12-11 17:02:15",0.01306', '3847416,"Abhik Jha","2019-12-11 17:02:15",0.01276', '3882666,studydl.com,"2019-12-11 17:02:15",0.01260', '3772946,"Anthony Chan","2019-12-11 17:02:15",0.01251', '3776598,"Yusaku Muroya","2019-12-11 17:02:15",0.01253', '3777493,"William Ma","2019-12-11 17:02:15",0.01256', '3771983,Shingo.S,"2019-12-11 17:02:15",0.01798', '3827476,ljklight,"2019-12-11 17:02:15",0.01253', '3882825,wangjiade1015,"2019-12-11 17:02:15",0.01307', '3764099,Young,"2019-12-11 17:02:15",0.01250', '3831302,Yassu,"2019-12-11 17:02:15",0.01252', '3831302,Yassu,"2019-12-11 17:02:15",0.01251', '3776297,"David Prakash","2019-12-11 17:02:15",0.01242', '3908524,"Ivan Liu","2019-12-11 17:02:15",0.01260', '3796924,"Zhenchen Hong","2019-12-11 17:02:15",0.01258', '3768519,tcash21,"2019-12-11 17:02:15",0.01251', '3789907,bestpredict,"2019-12-11 17:02:15",0.01252', '3865510,"don m meyer","2019-12-11 17:02:15",0.01301', '3834337,"Mr Goose","2019-12-11 17:02:15",0.01313', '3773907,JimmyP,"2019-12-11 17:02:15",0.01741', '3834337,"Mr Goose","2019-12-11 17:02:15",0.01307', '3805872,"Pyry Kontio","2019-12-11 17:02:15",0.02342', '3863051,"Tang Tun Yu","2019-12-11 17:02:15",0.01259', '3817550,ume08,"2019-12-11 17:02:15",0.01309', '3768215,"Shubham Kumar","2019-12-11 17:02:15",0.01259', '3764239,ryulapislazuli,"2019-12-11 17:02:15",0.01249', '3868689,"Booty Poppers","2019-12-11 17:02:15",0.01306', '3909059,"Lavanya Shukla","2019-12-11 17:02:15",0.01252', '3771983,Shingo.S,"2019-12-11 17:02:15",0.01763', '3774529,"Ah bon","2019-12-11 17:02:15",0.01252', '3871771,talesofyousan,"2019-12-11 17:02:15",0.01476', '3779221,sunilcube,"2019-12-11 17:02:15",0.01594', '3885922,RickArko,"2019-12-11 17:02:15",0.01477', '3809725,Ingmar43,"2019-12-11 17:02:15",0.01314', '3896007,"Leonard Strauss","2019-12-11 17:02:15",0.01258', '3809725,Ingmar43,"2019-12-11 17:02:15",0.01304', '3776374,MarcelFlygare,"2019-12-11 17:02:15",0.01321', '3896007,"Leonard Strauss","2019-12-11 17:02:15",0.01255', '3896573,yutou,"2019-12-11 17:02:15",0.01259', '3776374,MarcelFlygare,"2019-12-11 17:02:15",0.01304', '3909327,AshutoshSharma,"2019-12-11 17:02:15",0.01312', '3779221,sunilcube,"2019-12-11 17:02:15",0.01594', '3900864,"Thomas Wong","2019-12-11 17:02:15",0.01248', '3909368,"Rizvan Dwikifirdaus","2019-12-11 17:02:15",0.01260', '3774389,"Iary Joseph","2019-12-11 17:02:15",0.01249', '3766920,"Shailesh D","2019-12-11 17:02:15",0.01250', '3914548,"Aswin Hofsteenge","2019-12-11 17:02:15",0.01260', '3916147,Jinbao,"2019-12-11 17:02:15",0.01252', '3774666,StephanMiller,"2019-12-11 17:02:15",0.01251', '3916099,"Praveen Prakash","2019-12-11 17:02:15",0.01273', '3915900,imait,"2019-12-11 17:02:15",0.01251', '3844321,WJSNSeola,"2019-12-11 17:02:15",0.01476', '3785841,"Maxime Berenger","2019-12-11 17:02:15",0.01594', '3808715,"Haakon E. Nustad","2019-12-11 17:02:15",0.01354', '3769518,"Stefan Prüfer","2019-12-11 17:02:15",0.01290', '3778221,Thorn,"2019-12-11 17:02:15",0.01323', '3774133,"Pig Wings","2019-12-11 17:02:15",0.01256', '3764893,billyClanton,"2019-12-11 17:02:15",0.01297', '3858291,chuckatx25,"2019-12-11 17:02:15",0.01468', '3865244,"olaleye eniola","2019-12-11 17:02:15",0.01258', '3764405,TOMOTAKA,"2019-12-11 17:02:15",0.01259', '3763330,"Go Cowboys 🤠","2019-12-11 17:02:15",0.01227', '3877721,justfitting,"2019-12-11 17:02:15",0.01253', '3791679,uniko,"2019-12-11 17:02:15",0.01257', '3893355,"Matt McMullan","2019-12-11 17:02:15",0.01319', '3770078,"Robin Lingwood","2019-12-11 17:02:15",0.01304', '3898390,"Ryan O\'Hara","2019-12-11 17:02:15",0.01251', '3776313,naknak,"2019-12-11 17:02:15",0.01306', '3772283,"Devon Shurick","2019-12-11 17:02:15",0.01296', '3871396,chengc,"2019-12-11 17:02:15",0.01741', '3765004,"Michael Maguire","2019-12-11 17:02:15",0.01443', '3763652,adam,"2019-12-11 17:02:26",0.01282', '3830833,Rigel,"2019-12-11 17:02:26",0.01243', '3941297,yoshi_u,"2019-12-11 17:02:26",0.01252', '3781744,"long beach blunderbusses","2019-12-11 17:02:26",0.01295', '3941274,QLQian,"2019-12-11 17:02:26",0.01252', '3930780,shintaro,"2019-12-11 17:02:26",0.01476', '3764236,"Avinash Barnwal","2019-12-11 17:02:26",0.01252', '3815006,whoami,"2019-12-11 17:02:26",0.01253', '3846078,"Adriana Staudova","2019-12-11 17:02:26",0.01253', '3778456,CFDAero,"2019-12-11 17:02:26",0.01248', '3889941,"Nguyen Quan Anh Minh","2019-12-11 17:02:26",0.01252', '3813801,atom,"2019-12-11 17:02:26",0.01252', '3781293,pixel,"2019-12-11 17:02:26",0.01422', '3763632,JasonZivkovic,"2019-12-11 17:02:26",0.01738', '3920757,"younghyup jeong","2019-12-11 17:02:26",0.01258', '3781293,pixel,"2019-12-11 17:02:26",0.01342', '3834943,"Mark Eckdahl","2019-12-11 17:02:26",0.01255', '3763873,user,"2019-12-11 17:02:26",0.01570', '3795370,peterhwang2010,"2019-12-11 17:02:26",0.01252', '3920202,"ren lei","2019-12-11 17:02:26",0.01470', '3937092,"Akhilesh Rai","2019-12-11 17:02:26",0.01252', '3824882,henrykf22,"2019-12-11 17:02:26",0.01252', '3809687,Nikola,"2019-12-11 17:02:26",0.01250', '3863051,"Tang Tun Yu","2019-12-11 17:02:26",0.01251', '3802879,noeasywayout,"2019-12-11 17:02:26",0.01255', '3763330,"Go Cowboys 🤠","2019-12-11 17:02:26",0.01223', '3856984,"Durham Bull Rushers","2019-12-11 17:02:26",0.01323', '3769985,"Gannon Traynor","2019-12-11 17:02:26",0.01314', '3802879,noeasywayout,"2019-12-11 17:02:26",0.01255', '3938365,"FengLei Dou","2019-12-11 17:02:26",0.01252', '3922774,"Markus Plack","2019-12-11 17:02:26",0.01342', '3773261,SIDHARTH,"2019-12-11 17:02:26",0.01252', '3789078,"Jose Espejo","2019-12-11 17:02:26",0.01264', '3786547,FatimaZahraeGasmi,"2019-12-11 17:02:26",0.01728', '3863001,Not.That.Hard,"2019-12-11 17:02:26",0.01283', '3772272,"Tanishq Gautam","2019-12-11 17:02:26",0.01252', '3892500,"Sergey #2","2019-12-11 17:02:26",0.01251', '3907667,IfIcanUcan,"2019-12-11 17:02:26",0.01743', '3766423,DaoSword,"2019-12-11 17:02:26",0.01252', '3892177,"Nick W","2019-12-11 17:02:26",0.01296', '3779279,"Eric Vos","2019-12-11 17:02:26",0.01251', '3766157,"Nikita Hismatov","2019-12-11 17:02:26",0.01252', '3811297,cjma,"2019-12-11 17:02:26",0.01254', '3811297,cjma,"2019-12-11 17:02:26",0.01251', '3764357,"Sida Chen","2019-12-11 17:02:26",0.01252', '3781287,"NFL Masters","2019-12-11 17:02:26",0.01253', '3881870,"MQM Trinity Force","2019-12-11 17:02:26",0.01283', '3764063,MichaelSmith,"2019-12-11 17:02:26",0.01327', '3806732,Megatron,"2019-12-11 17:02:26",0.01282', '3788783,PMF,"2019-12-11 17:02:26",0.01323', '3935295,"Changmin Choi","2019-12-11 17:02:26",0.01251', '3902861,rockyalan,"2019-12-11 17:02:26",0.01252', '3811586,"Abhishek Sheshadri","2019-12-11 17:02:26",0.01254', '3763558,"Raju Kumar Mishra","2019-12-11 17:02:26",0.01269', '3934904,"Roy Luo","2019-12-11 17:02:26",0.01252', '3763632,JasonZivkovic,"2019-12-11 17:02:26",0.01735', '3889256,"Mohit Rane","2019-12-11 17:02:26",0.06754', '3788544,"Backstreet Boys","2019-12-11 17:02:26",0.01250', '3804549,"Kalyan Kumar P","2019-12-11 17:02:26",0.01253', '3763652,adam,"2019-12-11 17:02:26",0.01278', '3763593,"Naruhiko Nakanishi","2019-12-11 17:02:26",0.01251', '3791679,uniko,"2019-12-11 17:02:26",0.01253', '3781744,"long beach blunderbusses","2019-12-11 17:02:26",0.01278', '3934158,"Jonathan Buchanan","2019-12-11 17:02:26",0.01251', '3769588,"Allison Rountree","2019-12-11 17:02:26",0.01479', '3769301,pao,"2019-12-11 17:02:26",0.01253', '3872670,"Tony Sysoev","2019-12-11 17:02:26",0.01741', '3933488,DOUYG,"2019-12-11 17:02:26",0.01252', '3764405,TOMOTAKA,"2019-12-11 17:02:26",0.01253', '3770539,edvinmemet,"2019-12-11 17:02:26",0.01252', '3807962,nvnn,"2019-12-11 17:02:26",0.01252', '3931721,"DENDEN ZZH5","2019-12-11 17:02:26",0.01252', '3763507,Farb,"2019-12-11 17:02:26",0.01252', '3786791,Niklas,"2019-12-11 17:02:26",0.01741', '3833965,"Will Rose","2019-12-11 17:02:26",0.01314', '3765825,WARRIORS,"2019-12-11 17:02:26",0.01253', '3803566,Beards1120,"2019-12-11 17:02:26",0.01269', '3932372,qudade,"2019-12-11 17:02:36",0.01252', '3767961,"Puck Wang","2019-12-11 17:02:36",0.01252', '3931035,lokeshaggarwal11,"2019-12-11 17:02:36",0.01741', '3930990,"Pranjal Gangwar","2019-12-11 17:02:36",0.01741', '3777493,"William Ma","2019-12-11 17:02:36",0.01254', '3888771,YuhkiH,"2019-12-11 17:02:36",0.01252', '3886961,gavrand,"2019-12-11 17:02:36",0.01252', '3926264,erutsap,"2019-12-11 17:02:36",0.01252', '3879088,syllap,"2019-12-11 17:02:36",0.01249', '3779368,guangkunli,"2019-12-11 17:02:36",0.01297', '3792061,shina47,"2019-12-11 17:02:36",0.01252', '3774240,Alvah,"2019-12-11 17:02:36",0.01262', '3917734,arthasli,"2019-12-11 17:02:36",0.01252', '3781874,"Tom Wood","2019-12-11 17:02:36",0.01311', '3765410,RyanGoodman,"2019-12-11 17:02:36",0.01252', '3925870,"Dulya Ivan","2019-12-11 17:02:36",0.01252', '3764553,"Alex Zhang","2019-12-11 17:02:36",0.01252', '3860643,whitehair,"2019-12-11 17:02:36",0.01252', '3767961,"Puck Wang","2019-12-11 17:02:36",0.01250', '3787924,"Nayeun Irene Kim","2019-12-11 17:02:37",0.01252', '3765224,manu++,"2019-12-11 17:02:37",0.01252', '3768891,iwashi,"2019-12-11 17:02:37",0.01250', '3768594,Beginner,"2019-12-11 17:02:37",0.01252', '3767181,Aman.cyberia,"2019-12-11 17:02:37",0.01251', '3869573,yapkan,"2019-12-11 17:02:37",0.01250', '3832073,"Jisu Kim","2019-12-11 17:02:37",0.01252', '3765914,"Ruslan  Talipov","2019-12-11 17:02:37",0.01253', '3866217,Vinita,"2019-12-11 17:02:37",0.01273', '3806207,Orange,"2019-12-11 17:02:37",0.01251', '3765914,"Ruslan  Talipov","2019-12-11 17:02:37",0.01252', '3764982,KeepLearning,"2019-12-11 17:02:37",0.01251', '3927143,"Kasper P. Lauritzen","2019-12-11 17:02:36",0.01323', '3766482,akki,"2019-12-11 17:02:36",0.01250', '3781346,"rahul yadav","2019-12-11 17:02:36",0.01315', '3779877,"Roy Perry","2019-12-11 17:02:36",0.01334', '3765614,Stack_it!,"2019-12-11 17:02:36",0.01252', '3766482,akki,"2019-12-11 17:02:36",0.01244', '3786501,8ct10nz,"2019-12-11 17:02:36",0.01252', '3893261,"Antonio Rivero","2019-12-11 17:02:36",0.01283', '3887954,YSasaki,"2019-12-11 17:02:36",0.01252', '3763356,Danny,"2019-12-11 17:02:36",0.01250', '3799269,Bo1Yuan,"2019-12-11 17:02:36",0.01741', '3871934,SA0987,"2019-12-11 17:02:36",0.01312', '3803566,Beards1120,"2019-12-11 17:02:36",0.01268', '3770930,"GEYIJIE LI","2019-12-11 17:02:36",0.01251', '3764593,wangzhaoxu,"2019-12-11 17:02:36",0.01251', '3763743,"Green Bay Packers","2019-12-11 17:02:36",0.01251', '3774851,handonglee,"2019-12-11 17:02:36",0.01252', '3865510,"don m meyer","2019-12-11 17:02:36",0.01300', '3781874,"Tom Wood","2019-12-11 17:02:36",0.01299', '3917734,arthasli,"2019-12-11 17:02:36",0.01251', '3858291,chuckatx25,"2019-12-11 17:02:36",0.01263', '3841831,"Kyle Marshall","2019-12-11 17:02:36",0.01902', '3921882,FZambolin,"2019-12-11 17:02:36",0.01309', '3883362,PratheekMBharadwaj,"2019-12-11 17:02:36",0.01308', '3925330,"Rishabh #2","2019-12-11 17:02:36",0.01252', '3787466,godymevol,"2019-12-11 17:02:36",0.01552', '3910244,Minimi,"2019-12-11 17:02:36",0.01252', '3923050,"Matheus Della Croce Oliveira","2019-12-11 17:02:36",0.01260', '3771513,PassTheROC,"2019-12-11 17:02:36",0.23708', '3794143,"Adam Jalkemo","2019-12-11 17:02:36",0.01276', '3769606,IDKWTD,"2019-12-11 17:02:36",0.01250', '3770530,"Nigel A. R. Henry","2019-12-11 17:02:36",0.01305', '3897729,"Nakamoto Jiro","2019-12-11 17:02:36",0.01741', '3893538,"Safvan CK","2019-12-11 17:02:36",0.01260', '3879088,syllap,"2019-12-11 17:02:36",0.01249', '3774389,"Iary Joseph","2019-12-11 17:02:36",0.01248', '3907033,MG,"2019-12-11 17:02:36",0.01251', '3811586,"Abhishek Sheshadri","2019-12-11 17:02:37",0.01251', '3774240,Alvah,"2019-12-11 17:02:36",0.01262', '3920693,Beta,"2019-12-11 17:02:36",0.01476', '3806207,Orange,"2019-12-11 17:02:36",0.01250', '3764053,"Subin An","2019-12-11 17:02:36",0.01249', '3775554,zmnako,"2019-12-11 17:02:36",0.01252', '3902570,"Maggie Zhou","2019-12-11 17:02:36",0.01250', '3870494,Zeeshan,"2019-12-11 17:02:37",0.01252', '3893355,"Matt McMullan","2019-12-11 17:02:46",0.01299', '3777288,Grisha,"2019-12-11 17:02:47",0.01319', '3827625,"Santhosh #2","2019-12-11 17:02:47",0.01278', '3827640,RAJESH_PARTHASARATHY_NAMAGIRI,"2019-12-11 17:02:47",0.01278', '3785477,Limitless,"2019-12-11 17:02:47",0.01278', '3764071,dngeo17,"2019-12-11 17:02:47",0.01278', '3768790,"Bowen Peng","2019-12-11 17:02:47",0.01295', '3827246,vybhavp,"2019-12-11 17:02:47",0.01278', '3782077,"Arnold Kuo","2019-12-11 17:02:47",0.01278', '3774857,tetz0024,"2019-12-11 17:02:47",0.01298', '3764321,alants,"2019-12-11 17:02:47",0.01306', '3770804,"Data Bandidos 🌮","2019-12-11 17:02:47",0.01278', '3815923,"Tiago M. Leite","2019-12-11 17:02:47",0.01298', '3813179,Tetsuto,"2019-12-11 17:02:47",0.01300', '3801161,Bonoron,"2019-12-11 17:02:47",0.01278', '3830451,"Hao Tian","2019-12-11 17:02:47",0.01278', '3820707,gameofthodes,"2019-12-11 17:02:47",0.01463', '3769997,Daeshy,"2019-12-11 17:02:47",0.01308', '3811455,Seradja,"2019-12-11 17:02:47",0.01476', '3771863,"Peter CXL","2019-12-11 17:02:47",0.01278', '3769678,Rafay,"2019-12-11 17:02:47",0.01278', '3778237,Pebble,"2019-12-11 17:02:47",0.01463', '3775266,thisisnew,"2019-12-11 17:02:47",0.01296', '3808149,"Ilikeev Bilal","2019-12-11 17:02:47",0.01476', '3771315,"Amico and Jones","2019-12-11 17:02:47",0.01316', '3808149,"Ilikeev Bilal","2019-12-11 17:02:47",0.01476', '3766994,rokiso,"2019-12-11 17:02:47",0.01316', '3794061,3sigma,"2019-12-11 17:02:47",0.01278', '3775159,ykmaku,"2019-12-11 17:02:47",0.01476', '3767356,azis,"2019-12-11 17:02:47",0.01476', '3770804,"Data Bandidos 🌮","2019-12-11 17:02:47",0.01278', '3785812,"Darshan Patel","2019-12-11 17:02:47",0.01278', '3831481,ynarita,"2019-12-11 17:02:47",0.01476', '3781239,"DW Zhang","2019-12-11 17:02:47",0.01278', '3827233,"Yasuaki Koshiji","2019-12-11 17:02:47",0.01317', '3811929,water3345,"2019-12-11 17:02:47",0.01275', '3768682,"Deep Shah","2019-12-11 17:02:47",0.01300', '3767830,la_xx,"2019-12-11 17:02:47",0.01297', '3776446,"Sergey Demchenko","2019-12-11 17:02:47",0.01278', '3775491,reilp38,"2019-12-11 17:02:47",0.06004', '3779829,"Mike Hall","2019-12-11 17:02:47",0.01296', '3829265,SeongYunByeon,"2019-12-11 17:02:47",0.01278', '3788210,dmcdiarmid,"2019-12-11 17:02:47",0.01303', '3775808,"Ben Gorman","2019-12-11 17:02:46",0.01281', '3767027,znstrider,"2019-12-11 17:02:46",0.01338', '3773181,"Tom Rodenhagen","2019-12-11 17:02:46",0.01283', '3778932,"Imen Ferjani","2019-12-11 17:02:46",0.01288', '3768972,cdonohue,"2019-12-11 17:02:46",0.01741', '3833293,Maxenso,"2019-12-11 17:02:46",0.01319', '3794439,vov_or,"2019-12-11 17:02:46",0.01319', '3845695,amrshoof,"2019-12-11 17:02:46",0.01741', '3866427,"Aruna Ojha","2019-12-11 17:02:46",0.01273', '3928099,"Michael Mariboe","2019-12-11 17:02:46",0.01741', '3828702,AlEkhchidi,"2019-12-11 17:02:46",0.01252', '3799269,Bo1Yuan,"2019-12-11 17:02:46",0.01252', '3925870,"Dulya Ivan","2019-12-11 17:02:46",0.01251', '3805066,boulderslayer,"2019-12-11 17:02:47",0.01314', '3775808,"Ben Gorman","2019-12-11 17:02:47",0.01281', '3783962,Bill,"2019-12-11 17:02:47",0.01292', '3817680,TerrenceDonald,"2019-12-11 17:02:47",0.01278', '3765002,"Kellen Blumberg","2019-12-11 17:02:47",0.01281', '3767785,"Johann Haas","2019-12-11 17:02:47",0.01302', '3767341,huiqin,"2019-12-11 17:02:47",0.01302', '3840999,NickNapier,"2019-12-11 17:02:47",0.01312', '3840999,NickNapier,"2019-12-11 17:02:47",0.01311', '3833293,Maxenso,"2019-12-11 17:02:47",0.01309', '3830631,ML_Expert_Silicon_Valley,"2019-12-11 17:02:47",0.01302', '3833428,Xiaotian,"2019-12-11 17:02:47",0.02552', '3830631,ML_Expert_Silicon_Valley,"2019-12-11 17:02:47",0.01293', '3783621,Andrew,"2019-12-11 17:02:47",0.01306', '3786044,"Nicolas Drewniak","2019-12-11 17:02:47",0.01328', '3836014,kgglstartup,"2019-12-11 17:02:47",0.01293', '3764532,JohnM,"2019-12-11 17:02:47",0.01463', '3775346,neilron,"2019-12-11 17:02:47",0.01275', '3837670,hrappuccino,"2019-12-11 17:02:47",0.01316', '3783962,Bill,"2019-12-11 17:02:47",0.01279', '3816153,wickiwack,"2019-12-11 17:02:47",0.01741', '3837510,tanegoman,"2019-12-11 17:02:47",0.01312', '3764872,"Paco M","2019-12-11 17:02:58",0.07525', '3767752,Jayaram,"2019-12-11 17:02:58",0.01318', '3780107,ponythewhite,"2019-12-11 17:02:58",0.01290', '3769818,gg,"2019-12-11 17:02:58",0.01551', '3779785,"Mehdi Kashef","2019-12-11 17:02:58",0.01481', '3772565,polo,"2019-12-11 17:02:58",0.01278', '3763189,x5or6,"2019-12-11 17:02:58",0.01253', '3872123,"Kawabata Naoyuki","2019-12-11 17:02:58",0.01254', '3771829,none,"2019-12-11 17:02:58",0.01252', '3765782,Tatsuryu,"2019-12-11 17:02:58",0.01253', '3849905,"Gleb Anferov","2019-12-11 17:02:58",0.01249', '3837506,"Akira Sasaki","2019-12-11 17:02:58",0.01477', '3766950,JunjiAkahane,"2019-12-11 17:02:58",0.01255', '3802437,Nyangao,"2019-12-11 17:02:58",0.01741', '3769547,mnaoto,"2019-12-11 17:02:58",0.01255', '3865984,y.ume,"2019-12-11 17:02:58",0.01741', '3769547,mnaoto,"2019-12-11 17:02:58",0.01252', '3764763,WangMH,"2019-12-11 17:02:58",0.01286', '3764037,sonseungbum,"2019-12-11 17:02:58",0.02225', '3769818,gg,"2019-12-11 17:02:58",0.01461', '3769999,Salman,"2019-12-11 17:02:58",0.01308', '3765867,Falcons,"2019-12-11 17:02:58",0.01476', '3778771,adamyd,"2019-12-11 17:02:58",0.01476', '3773727,"A Humphrey","2019-12-11 17:02:58",0.01470', '3766766,"Moisés Riestra","2019-12-11 17:02:58",0.01476', '3777814,ByungSunBae,"2019-12-11 17:02:58",0.01466', '3782709,sept,"2019-12-11 17:02:58",0.01476', '3777105,fingeeker,"2019-12-11 17:02:58",0.01301', '3769282,"Iatco Sergiu","2019-12-11 17:02:58",0.01456', '3777015,abhinavm24,"2019-12-11 17:02:58",0.01310', '3767752,Jayaram,"2019-12-11 17:02:58",0.01317', '3772593,"Divya Shah","2019-12-11 17:02:58",0.01328', '3772593,"Divya Shah","2019-12-11 17:02:58",0.01317', '3771582,poxiao,"2019-12-11 17:02:58",0.01478', '3774751,Saber,"2019-12-11 17:02:58",0.01476', '3774214,Noud,"2019-12-11 17:02:58",0.01281', '3783124,"Sergey Enikeev","2019-12-11 17:02:58",0.01305', '3773113,"Prashant Banerjee","2019-12-11 17:02:58",0.01305', '3782868,JohnGeorge3,"2019-12-11 17:02:58",0.01305', '3778336,druggist,"2019-12-11 17:02:58",0.01338', '3763554,Li-Der,"2019-12-11 17:02:58",0.01252', '3868830,"Yusuef Ramadan","2019-12-11 17:02:58",0.01268', '3791709,"Will Yin","2019-12-11 17:02:58",0.01355', '3765429,averagemn,"2019-12-11 17:02:58",0.01273', '3777676,feb3901ec4e54a42d447,"2019-12-11 17:02:58",0.01261', '3816130,GrzesiekM,"2019-12-11 17:02:58",0.01476', '3779323,"Yuma Suzuki","2019-12-11 17:02:58",0.01278', '3774959,these_guys,"2019-12-11 17:02:58",0.01278', '3833403,"Sreelakshmi Nair","2019-12-11 17:02:58",0.01298', '3775491,reilp38,"2019-12-11 17:02:58",0.01424', '3765503,"SusheendharVijay ","2019-12-11 17:02:58",0.01520', '3764273,"Reese Haywood","2019-12-11 17:02:58",0.01314', '3766985,Miyatti,"2019-12-11 17:02:58",0.01278', '3813639,"Benjamin Coudrin","2019-12-11 17:02:58",0.01278', '3774721,john24142,"2019-12-11 17:02:58",0.01463', '3786215,tkuri,"2019-12-11 17:02:58",0.01278', '3768970,鸽王大赛,"2019-12-11 17:02:58",0.01278', '3770435,"AYOUB ZAROU","2019-12-11 17:02:58",0.01333', '3779052,"Joel E","2019-12-11 17:02:58",0.08175', '3802880,ArnikaKumar,"2019-12-11 17:02:58",0.01741', '3763558,"Raju Kumar Mishra","2019-12-11 17:02:58",0.01254', '3766413,"Katya Gordeeva","2019-12-11 17:02:58",0.01251', '3775599,"Martin Bonardi","2019-12-11 17:02:58",0.01254', '3827249,Naren,"2019-12-11 17:02:58",0.01339', '3827713,DBN,"2019-12-11 17:02:58",0.01798', '3781974,Doudi,"2019-12-11 17:02:58",0.01256', '3779287,AIvar,"2019-12-11 17:02:58",0.01288', '3840873,shinsuke27,"2019-12-11 17:02:58",0.01741', '3782328,Zouzoulapin,"2019-12-11 17:02:58",0.01261', '3774722,Aozora,"2019-12-11 17:02:58",0.01255', '3776140,"Federico Allocati","2019-12-11 17:02:58",0.01256', '3769033,pies,"2019-12-11 17:02:58",0.01323', '3779591,"Tabish M","2019-12-11 17:02:58",0.01257', '3846814,worstfitting,"2019-12-11 17:02:58",0.01257', '3817762,青木白羊,"2019-12-11 17:02:58",0.01476', '3763533,"Joe Young","2019-12-11 17:02:58",0.01306', '3767380,NPC648,"2019-12-11 17:03:09",0.01298', '3768136,"Love agarwal","2019-12-11 17:03:10",0.01476', '3763940,"Rshad Zhran","2019-12-11 17:03:10",0.01494', '3773618,10462709,"2019-12-11 17:03:10",0.01476', '3767722,"Gopi Durgaprasad","2019-12-11 17:03:10",0.01475', '3765426,sasakama,"2019-12-11 17:03:10",0.01469', '3772545,Eguy,"2019-12-11 17:03:10",0.01472', '3771107,ajiajiajiaji,"2019-12-11 17:03:10",0.01476', '3775301,"Ken Ho","2019-12-11 17:03:10",0.01476', '3771836,SIMPLE,"2019-12-11 17:03:10",0.01564', '3777462,"Nico Magu","2019-12-11 17:03:10",0.01383', '3771107,ajiajiajiaji,"2019-12-11 17:03:09",0.01474', '3771426,Vishky,"2019-12-11 17:03:09",0.01356', '3771426,Vishky,"2019-12-11 17:03:09",0.01315', '3763199,"Bruno Gorresen Mello","2019-12-11 17:03:09",0.01383', '3764037,sonseungbum,"2019-12-11 17:03:10",0.02022', '3771781,EJ50,"2019-12-11 17:03:10",0.01268', '3769850,ShedrickBridgeforth,"2019-12-11 17:03:10",0.01298', '3770442,orishko,"2019-12-11 17:03:10",0.01328', '3771396,davidsteinandfriends,"2019-12-11 17:03:10",0.01317', '3769207,"Matthias B","2019-12-11 17:03:10",0.01416', '3784789,random_seed=42,"2019-12-11 17:03:10",0.01299', '3763346,JackSoslow,"2019-12-11 17:03:10",0.01283', '3767159,大力出奇迹,"2019-12-11 17:03:10",0.01302', '3767873,default,"2019-12-11 17:03:10",0.01296', '3792856,"Vincent Yong","2019-12-11 17:03:10",0.01297', '3767190,matsu32,"2019-12-11 17:03:10",0.01310', '3800427,"Balaji Selvaraj ","2019-12-11 17:03:10",0.01297', '3768399,GianPaolob,"2019-12-11 17:03:10",0.01311', '3767559,"Errol Pereira","2019-12-11 17:03:10",0.01494', '3767006,Toto,"2019-12-11 17:03:10",0.01309', '3765292,currypurin,"2019-12-11 17:03:10",0.01310', '3777676,feb3901ec4e54a42d447,"2019-12-11 17:03:10",0.01257', '3776825,haoliangzhang,"2019-12-11 17:03:10",0.01287', '3767852,"Model builder","2019-12-11 17:03:10",0.01598', '3763199,"Bruno Gorresen Mello","2019-12-11 17:03:09",0.01314', '3771763,StephenSmith,"2019-12-11 17:03:09",0.01464', '3763519,RSY,"2019-12-11 17:03:09",0.01306', '3765968,Aicanghai_Smile,"2019-12-11 17:03:09",0.01301', '3770310,"Max Halford","2019-12-11 17:03:09",0.01334', '3765480,nissy,"2019-12-11 17:03:09",0.01484', '3780107,ponythewhite,"2019-12-11 17:03:09",0.01283', '3763425,"Devin Anzelmo","2019-12-11 17:03:09",0.01287', '3786580,"Niyamat Ullah","2019-12-11 17:03:09",0.01476', '3773727,"A Humphrey","2019-12-11 17:03:09",0.01470', '3766907,novanova,"2019-12-11 17:03:09",0.01349', '3765412,Travelor,"2019-12-11 17:03:09",0.01476', '3768873,wakarimi,"2019-12-11 17:03:09",0.01476', '3787323,"Darkhan Nurakhmetov","2019-12-11 17:03:09",0.01296', '3777231,masamichi_14,"2019-12-11 17:03:09",0.01476', '3780167,"Sébastien MATHIEU","2019-12-11 17:03:09",0.01304', '3774611,"Kusunoki Chihiro","2019-12-11 17:03:09",0.01320', '3777682,"Daniel Sobrado","2019-12-11 17:03:09",0.01303', '3785355,"Matthew P. McAteer","2019-12-11 17:03:09",0.01305', '3780993,"Goto Yugo","2019-12-11 17:03:09",0.01661', '3771836,SIMPLE,"2019-12-11 17:03:09",0.01440', '3775369,"Matteo Cati","2019-12-11 17:03:09",0.01476', '3766033,"Dennis Leszkowicz","2019-12-11 17:03:09",0.01477', '3768101,NRC,"2019-12-11 17:03:09",0.01475', '3765287,00yq,"2019-12-11 17:03:09",0.01476', '3771225,"Ralph Neumann","2019-12-11 17:03:09",0.01479', '3767734,"Parul Pandey","2019-12-11 17:03:09",0.01464', '3763940,"Rshad Zhran","2019-12-11 17:03:09",0.01493', '3772959,"Nikhil Gupta","2019-12-11 17:03:10",0.01295', '3769726,joacoib,"2019-12-11 17:03:09",0.01476', '3770694,"PC Jimmmy","2019-12-11 17:03:09",0.01476', '3769751,seaguII,"2019-12-11 17:03:09",0.01309', '3770446,"Jacob Rose","2019-12-11 17:03:09",0.01476', '3768801,"Anirudh Raghavan","2019-12-11 17:03:09",0.01476', '3768966,konsome,"2019-12-11 17:03:09",0.01475', '3765719,TekoTeko-chan,"2019-12-11 17:03:09",0.01475', '3773646,yhchen2018,"2019-12-11 17:03:09",0.01382', '3767559,"Errol Pereira","2019-12-11 17:03:10",0.01488', '3808701,"Nicolas Wesner","2019-12-11 17:03:19",0.01303', '3789168,"Guilherme Campos","2019-12-11 17:03:20",0.01298', '3767852,"Model builder","2019-12-11 17:03:20",0.01326', '3780697,plastio,"2019-12-11 17:03:20",0.02855', '3792909,"is jab","2019-12-11 17:03:20",0.01295', '3770310,"Max Halford","2019-12-11 17:03:20",0.01300', '3774692,dankouji,"2019-12-11 17:03:20",0.01299', '3767844,"Щеткин Александр","2019-12-11 17:03:20",0.09036', '3792909,"is jab","2019-12-11 17:03:20",0.01292', '3775478,zvone,"2019-12-11 17:03:20",0.01304', '3791606,"PengJu Zhang","2019-12-11 17:03:20",0.01299', '3786208,"Priyanshu Kumar","2019-12-11 17:03:20",0.01309', '3788862,wisteria30,"2019-12-11 17:03:20",0.02742', '3767380,NPC648,"2019-12-11 17:03:20",0.01297', '3779287,AIvar,"2019-12-11 17:03:20",0.01285', '3777524,"Sumiyama Fumitaka","2019-12-11 17:03:20",0.01304', '3774420,Santhosh,"2019-12-11 17:03:20",0.01298', '3779782,DarrenTitor,"2019-12-11 17:03:20",0.01471', '3767713,"Manraj Singh","2019-12-11 17:03:20",0.01305', '3766033,"Dennis Leszkowicz","2019-12-11 17:03:20",0.01299', '3766775,A-team,"2019-12-11 17:03:20",0.01292', '3767713,"Manraj Singh","2019-12-11 17:03:20",0.01304', '3794811,kolpshnikova,"2019-12-11 17:03:20",0.01305', '3769726,joacoib,"2019-12-11 17:03:20",0.01299', '3775055,"yunhu ye","2019-12-11 17:03:20",0.01309', '3785186,Chibadai,"2019-12-11 17:03:20",0.01477', '3782722,"Bob Wang","2019-12-11 17:03:20",0.01472', '3793903,threecourse,"2019-12-11 17:03:20",0.01295', '3800427,"Balaji Selvaraj ","2019-12-11 17:03:20",0.01297', '3766117,"Siddharth Yadav","2019-12-11 17:03:20",0.01304', '3775981,"Mohsen SADOK","2019-12-11 17:03:20",0.01297', '3790780,"Yuki Nakashima","2019-12-11 17:03:20",0.09087', '3774692,dankouji,"2019-12-11 17:03:20",0.01298', '3790298,Tyler,"2019-12-11 17:03:20",0.01476', '3765112,why4,"2019-12-11 17:03:20",0.01290', '3777682,"Daniel Sobrado","2019-12-11 17:03:20",0.01297', '3784299,ako,"2019-12-11 17:03:20",0.01304', '3814014,tsuka,"2019-12-11 17:03:20",0.01278', '3774841,FELIZ,"2019-12-11 17:03:20",0.01300', '3765942,Jay,"2019-12-11 17:03:20",0.09445', '3766775,A-team,"2019-12-11 17:03:20",0.01289', '3778932,"Imen Ferjani","2019-12-11 17:03:20",0.01278', '3769207,"Matthias B","2019-12-11 17:03:20",0.01335', '3769850,ShedrickBridgeforth,"2019-12-11 17:03:20",0.01295', '3764653,Donatello,"2019-12-11 17:03:20",0.02015', '3763799,Telaro,"2019-12-11 17:03:20",0.01323', '3785930,PyVyz,"2019-12-11 17:03:20",0.01349', '3769148,R.Mutt,"2019-12-11 17:03:20",0.01476', '3772613,Mr.Qiang,"2019-12-11 17:03:20",0.01306', '3787454,"Tatsuya Izuka","2019-12-11 17:03:19",0.01308', '3775055,"yunhu ye","2019-12-11 17:03:19",0.01305', '3772078,GoodNine,"2019-12-11 17:03:20",0.01463', '3768867,zhangxin,"2019-12-11 17:03:20",0.01278', '3819352,"Alex Ovsyannikov","2019-12-11 17:03:20",0.01278', '3767722,"Gopi Durgaprasad","2019-12-11 17:03:20",0.01278', '3773052,deep_panda,"2019-12-11 17:03:20",0.01286', '3788562,"William Laprade","2019-12-11 17:03:20",0.01297', '3770866,"Diogo Gomes ","2019-12-11 17:03:20",0.01306', '3767791,"Yosuke KOBAYASHI","2019-12-11 17:03:20",0.01297', '3780993,"Goto Yugo","2019-12-11 17:03:20",0.01523', '3815735,"Just Learning","2019-12-11 17:03:20",0.26787', '3788562,"William Laprade","2019-12-11 17:03:20",0.01295', '3815735,"Just Learning","2019-12-11 17:03:20",0.26787', '3790306,Rees,"2019-12-11 17:03:20",0.01310', '3784299,ako,"2019-12-11 17:03:20",0.01299', '3814550,"Eliseev Dan","2019-12-11 17:03:20",0.01463', '3814550,"Eliseev Dan","2019-12-11 17:03:20",0.01278', '3808701,"Nicolas Wesner","2019-12-11 17:03:20",0.01303', '3765260,ZNing,"2019-12-11 17:03:20",0.01278', '3815923,"Tiago M. Leite","2019-12-11 17:03:20",0.01298', '3766488,"Amal V Nair","2019-12-11 17:03:20",0.01311', '3776706,Brandon,"2019-12-11 17:03:29",0.01347', '3763884,govindam,"2019-12-11 17:03:29",0.01627', '3779782,DarrenTitor,"2019-12-11 17:03:29",0.01309', '3773564,"Rushikesh Joshi","2019-12-11 17:03:29",0.01318', '3773794,shilpa.rpns,"2019-12-11 17:03:29",0.01309', '3771582,poxiao,"2019-12-11 17:03:29",0.01331', '3768532,"Fei. Zhang","2019-12-11 17:03:29",0.01309', '3847066,"jjs2434 ","2019-12-11 17:03:29",0.01255', '3779794,"Jinsoo Park","2019-12-11 17:03:29",0.01256', '3769845,"Hartmut Ott","2019-12-11 17:03:29",0.01258', '3799966,ymtmytk,"2019-12-11 17:03:29",0.01305', '3776706,Brandon,"2019-12-11 17:03:29",0.01334', '3784560,haterol,"2019-12-11 17:03:29",0.01304', '3804850,alizaky,"2019-12-11 17:03:29",0.01323', '3804850,alizaky,"2019-12-11 17:03:29",0.01285', '3801891,Pirafu,"2019-12-11 17:03:29",0.01311', '3767339,"prasoon kottarathil","2019-12-11 17:03:29",0.01297', '3790306,Rees,"2019-12-11 17:03:29",0.01281', '3794811,kolpshnikova,"2019-12-11 17:03:29",0.01301', '3796711,DataRockstar,"2019-12-11 17:03:29",0.01298', '3794689,grinningSEAL,"2019-12-11 17:03:29",0.01476', '3794689,grinningSEAL,"2019-12-11 17:03:29",0.01305', '3788884,zenginlique,"2019-12-11 17:03:29",0.09139', '3770442,orishko,"2019-12-11 17:03:29",0.01297']

# %%
df1 = pd.read_csv(StringIO('\n'.join(doc_Felipe_Loque))).set_index('Team Name')

# no idea why some teams have multiple entries, take the best score (min)
df2 = pd.read_csv(StringIO('\n'.join(raw_week2_download))).set_index(
    'TeamName').groupby(level=0)['Score'].min().to_frame()

# %%
# some names have become corrupt, fix as much as possible with a simple approach

missing_in_1 = [t for t in df2.index if t not in df1.index]
missing_in_2 = [t for t in df1.index if t not in df2.index]

def clean_txt(txt):
    return ''.join([c for c in txt if c.lower() in ' abcdefghijklmnopqrstuvwxyz'])

mapping = {i:i for i in df1.index}
for t in missing_in_1:
    candidates = []
    for t2 in missing_in_2:
        if clean_txt(t2) == clean_txt(t):
            candidates.append(t2)
    if len(candidates) == 1:
        mapping[candidates[0]] = t

df1.index = df1.index.map(mapping)

# %%
# join scores
# focus on scores below 0.03
# filter teams that did better on the public lb (indicating overfit)
# plot to check

df = df1.join(df2).rename({
    'Score Public LB': 'public',
    'Score 2019-12-06': 'week1',
    'Score': 'week2'}, axis=1).dropna(subset=['public', 'week1', 'week2'])

df = df[df.week1<0.03]
df = df[~(df.week1 - df.public > 0)]

pd.plotting.scatter_matrix(df[['public', 'week1', 'week2']])
plt.show()

# %%
# predict the final leaderboard score, using public and week1 as features
# proxy-target is the week2_plays_score
# assume that week2 = (week1_plays_score + week2_plays_score) / 2
# calculate target = 2 * week2 - week1

# fit the model, and replace week1 by week2 for predicting (because week2 is a better estimate)

df['target'] = 2 * df['week2'] - df['week1']

model = LinearRegression(fit_intercept=False)
model.fit(df[['public', 'week1']], df['week2'])
print('[public, private] weights', model.coef_)

df['public_factor'] = df['public']/df['week2']
public_factor = df['public_factor'].mean()
week1_factor = (df['week1']/df['week2']).mean()
target_factor = (df['target']/df['week2']).mean()
print('public_factor', public_factor)

unmatched_teams = [team_name for team_name in df2.index if team_name not in df.index]
dfx = df2.loc[unmatched_teams].rename({'Score': 'week2'}, axis=1)
dfx['public'] = public_factor * dfx.week2

df = df.append(dfx, sort=True)

df['week2_c'] = df['week2'] * week1_factor

df['final_score'] = model.predict(df[['public', 'week2_c']]) / target_factor
df.sort_values(by='final_score', inplace=True)
df['final_rank'] = np.arange(1, len(df)+1)

df.loc[unmatched_teams, 'public'] = np.nan

pd.set_option('display.max_rows', 200)
df[['final_rank', 'final_score', 'week1', 'week2', 'public', 'public_factor']].head(200)
