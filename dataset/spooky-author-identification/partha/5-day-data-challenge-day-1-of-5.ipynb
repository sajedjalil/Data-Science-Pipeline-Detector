# %% [markdown]
# **This imports the Pandas**

# %%
import pandas as pd

# %% [markdown]
# Reading the cvs file and creating a data object called ''data"

# %%
data = pd.read_csv("../input/test.csv")

# %% [markdown]
# Describe function gives the statictics about the input file

# %%
data.describe()
