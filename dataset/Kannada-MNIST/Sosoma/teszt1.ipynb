# %%
import numpy as np 
import pandas as pd
import io

import seaborn as sns
import time as time
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.model_selection import GridSearchCV,RandomizedSearchCV,train_test_split, cross_val_score, KFold,RepeatedKFold

from xgboost import XGBClassifier
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import StackingClassifier,GradientBoostingClassifier, HistGradientBoostingClassifier

from sklearn.pipeline import make_pipeline

from sklearn.metrics import make_scorer, mean_squared_error,roc_curve, roc_auc_score,mean_squared_log_error
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,explained_variance_score

# %%
train_data = pd.read_csv('/kaggle/input/Kannada-MNIST/train.csv')

# %%
X, y = (train_data.drop(['label'], axis=1), train_data.label)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#cl03=XGBClassifier(tree_method='gpu_hist',learning_rate=0.5,max_depth=5)
cl03=XGBClassifier(learning_rate=0.5,max_depth=5)
cl03.fit(X_train,y_train)

# %%
test_data = pd.read_csv('/kaggle/input/Kannada-MNIST/test.csv')

# %%
ids, test_set = test_data.id, test_data.drop(['id'], axis=1)

# %%
final_preds = cl03.predict(test_set)

# %%
pd.Series(final_preds, index=ids, name='label').to_csv('/kaggle/working/submission.csv')

# %%
#final_pred_df.to_csv('/kaggle/working/submission.csv')
