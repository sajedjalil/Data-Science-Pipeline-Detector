# %%
from IPython.display import Image
path = "../input/pbs-images"

# %%
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %% [markdown]
# # PBS KIDS Measure Up!
# * For whom : Children ages 3 to 5
# * why :Learn easy math concepts
# * which concepts ?
#     * length
#     * width
#     * capacity and
#     * weight
#
# * How do they learn ?
#     * By going on an adventure through following maps
#         * Treetop City
#         * Magma Peak and
#         * Crystal Caves
#     * Joined by their favorite PBS KIDS characters from
#         * Dinosaur Train
#         * Peg + Cat and
#         * Sid the Science Kid
#     * Can also collect rewards and unlock digital toys as they play
#
#
# * What can parents/caregivers do here: They can monitor and expand upon what their child is learning using a free companion app: **PBS KIDS Super Vision™**

# %% [markdown]
# # Homepage

# %%
Image(f"{path}/homepage.jpg")

# %% [markdown]
# # Map
# We can see map of 3 places here
# * Treetop city for height and length
# * Magma peak for capacity
# * Cristal caves for weigth

# %%
Image(f"{path}/map.jpg", width=700)

# %% [markdown]
# # Advancing
# To advance to next activity/level you run along the map and stand on an orange platform to check current one.

# %%
Image(f"{path}/to advance.jpg")

# %% [markdown]
# # Height
# Let's checkout this sorting game

# %%
Image(f"{path}/sorting.jpg")

# %% [raw]
# Here we are shown several animals and we need to select who should go to which house based on their height. The tallest dinosaur gets the tallest house and so on. After selecting appropriate houses for all three of them this step is done. And player is returned to the previous map where they can keep going forward.

# %%
Image(f"{path}/dinosaur sort.jpg")

# %% [markdown]
# # Length
# How many toothbrushes long is this rock ?

# %%
Image(f"{path}/rock.jpg")

# %% [markdown]
# # Weight
# Lets check another activity. This time it is in **Crystal caves** .You need to balance food for the bady dinosaur with the rock on the right side. You pick food from the bottom of the screen and will be informed if it underweights or overweights. You can also the check the arrow signs in the middle to know if they are close to be balanced.

# %%
Image(f"{path}/weight equal.jpg")

# %% [markdown]
# # Some different ones
# There were some quite different challenges too. For example in this event is called **Roll or Slidet**. The player needs learn which objects will roll or which objects will slide down .

# %%
Image(f"{path}/roll or slide.jpg")

# %% [markdown]
# The following one is called **Surface challange**. In this challenge you need to pick the surface and the right speed to hit the golf ball so that it reaches the hole beside the red flag. Based on surface, friction would be different in each case.

# %%
Image(f"{path}/surface challenge.jpg")

# %% [markdown]
# # Prize
# You also win prize after clearing stages. This is to encourage kids to keep going on with learning.

# %%
Image(f"{path}/prize.jpg")
