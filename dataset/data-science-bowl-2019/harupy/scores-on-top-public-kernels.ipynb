# %% [markdown]
# ## Markdonw in this notebook is generated by:
# ## https://github.com/harupy/kernel-profiling

# %%
markdown = """
### Created at 2020/01/12 09:36:14 (UTC)

<br>

# [Convert to Regression](https://www.kaggle.com/challenge1a3/convert-to-regression)

<a href="/challenge1a3"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" alt="challenge_1a3" width="72" height="72"></a>

- Author: [challenge_1a3](/challenge1a3)
- Best score: 0.55
- Vote count: 14
- Comment count: 2
- Last updated: 13d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Convert to Regression|Version 16|0.529|13 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25958443)|
|Convert to Regression|Version 15|0.526|13 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25954320)|
|Convert to Regression|Version 14|0.512|13 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25935609)|
|Convert to Regression|Version 13|-|13 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25933093)|
|Convert to Regression|Version 12|-|14 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25916642)|
|Convert to Regression|Version 11|-|14 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25915138)|
|Convert to Regression|Version 10|-|14 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25915102)|
|Convert to Regression|Version 9|-|14 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25914509)|
|Convert to Regression|Version 7|-|14 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25913139)|
|Convert to Regression|Version 6|-|14 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25912233)|
|Convert to Regression|Version 4|-|14 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25911944)|
|Convert to Regression|Version 3|0.544|15 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25856010)|
|Convert to Regression|Version 2|0.55|15 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25844451)|
|Convert to Regression|Version 1|-|15 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression?scriptVersionId=25842135)|
|Convert to Regression|Forked from|0.538|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression)|

<br>

# [Convert to Regression](https://www.kaggle.com/braquino/convert-to-regression)

<a href="/braquino"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1966794-kg.jpg" alt="Bruno Aquino" width="72" height="72"></a>

- Author: [Bruno Aquino](/braquino)
- Best score: 0.547
- Vote count: 288
- Comment count: 83
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Convert to Regression|Version 24|0.538|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=25175782)|
|Convert to Regression|Version 23|0.539|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=25168771)|
|Convert to Regression|Version 22|-|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=25166029)|
|Convert to Regression|Version 21|0.546|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=25158231)|
|Convert to Regression|Version 20|0.535|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=25155756)|
|Convert to Regression|Version 19|-|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24856349)|
|Convert to Regression|Version 18|0.5|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24555299)|
|Convert to Regression|Version 17|-|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24553444)|
|Convert to Regression|Version 16|-|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24553409)|
|Convert to Regression|Version 15|0.539|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24405088)|
|Convert to Regression|Version 14|0.542|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24399904)|
|Convert to Regression|Version 13|0.544|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24252969)|
|Convert to Regression|Version 12|0.54|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24116748)|
|Convert to Regression|Version 11|-|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24116591)|
|Convert to Regression|Version 10|0.542|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24115127)|
|Convert to Regression|Version 9|0.536|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24113334)|
|Convert to Regression|Version 8|0.537|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24108794)|
|Convert to Regression|Version 7|0.524|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=24022136)|
|Convert to Regression|Version 6|0.542|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=23939162)|
|Convert to Regression|Version 5|0.536|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=23937591)|
|Convert to Regression|Version 4|0.54|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=23935990)|
|Convert to Regression|Version 3|0.533|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=23930003)|
|Convert to Regression|Version 2|0.547|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=23925632)|
|Convert to Regression|Version 1|0.543|2 months ago|[Open](https://www.kaggle.com/braquino/convert-to-regression?scriptVersionId=23916258)|

<br>

# [Data Science Bowl Data Minification](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification)

<a href="/roydatascience"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1918280-kg.jpg" alt="Ashish Gupta" width="72" height="72"></a>

- Author: [Ashish Gupta](/roydatascience)
- Best score: 0.545
- Vote count: 20
- Comment count: 6
- Last updated: 2d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Data Science Bowl Data Minification|Version 28|-|2 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26644481)|
|Data Science Bowl Data Minification|Version 27|-|2 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26617944)|
|Data Science Bowl Data Minification|Version 26|-|2 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26609264)|
|Data Science Bowl Data Minification|Version 25|-|2 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26597166)|
|Data Science Bowl Data Minification|Version 24|-|2 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26595657)|
|Data Science Bowl Data Minification|Version 23|-|3 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26592780)|
|Data Science Bowl Data Minification|Version 22|-|3 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26590628)|
|Data Science Bowl Data Minification|Version 21|-|3 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26585109)|
|Data Science Bowl Data Minification|Version 20|-|3 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26528508)|
|Data Science Bowl Data Minification|Version 19|0.538|4 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26516599)|
|Data Science Bowl Data Minification|Version 18|0.544|5 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26407466)|
|Data Science Bowl Data Minification|Version 17|-|6 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26398397)|
|Data Science Bowl Data Minification|Version 16|-|6 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26398240)|
|Data Science Bowl Data Minification|Version 15|0.544|6 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26361145)|
|Data Science Bowl Data Minification|Version 14|0.542|8 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26244888)|
|Data Science Bowl Data Minification|Version 13|-|8 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26244640)|
|Data Science Bowl Data Minification|Version 12|-|8 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26243667)|
|Data Science Bowl Data Minification|Version 11|0.537|8 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26228087)|
|Data Science Bowl Data Minification|Version 10|0.544|9 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26224591)|
|Data Science Bowl Data Minification|Version 9|0.535|9 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26220994)|
|Data Science Bowl Data Minification|Version 8|-|9 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26220754)|
|Data Science Bowl Data Minification|Version 7|-|9 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26215280)|
|Data Science Bowl Data Minification|Version 6|0.545|12 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26050911)|
|Data Science Bowl Data Minification|Version 5|-|12 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26045841)|
|Data Science Bowl Data Minification|Version 4|-|12 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26044645)|
|Data Science Bowl Data Minification|Version 3|0.545|12 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26037851)|
|Data Science Bowl Data Minification|Version 2|0.54|12 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26009940)|
|Data Science Bowl Data Minification|Version 1|0.54|12 days ago|[Open](https://www.kaggle.com/roydatascience/data-science-bowl-data-minification?scriptVersionId=26003761)|

<br>

# [Bayesian Opt Seed Blending with tuning 69](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69)

<a href="/khoongweihao"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1738095-kg.png" alt="Wei Hao Khoong" width="72" height="72"></a>

- Author: [Wei Hao Khoong](/khoongweihao)
- Best score: 0.543
- Vote count: 24
- Comment count: 3
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Bayesian Opt Seed Blending with tuning 69|Version 15|0.535|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24998615)|
|Bayesian Opt Seed Blending with tuning 69|Version 14|0.543|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24998602)|
|Bayesian Opt Seed Blending with tuning 69|Version 13|0.536|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24998593)|
|Bayesian Opt Seed Blending with tuning 69|Version 12|0.534|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24998580)|
|Bayesian Opt Seed Blending with tuning 69|Version 11|0.533|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24998430)|
|Bayesian Opt Seed Blending with tuning 69|Version 10|0.52|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24932187)|
|Bayesian Opt Seed Blending with tuning 69|Version 9|0.533|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24932155)|
|Bayesian Opt Seed Blending with tuning 69|Version 8|0.54|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24932126)|
|Bayesian Opt Seed Blending with tuning 69|Version 7|0.532|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24932092)|
|Bayesian Opt Seed Blending with tuning 69|Version 6|0.538|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24932060)|
|Bayesian Opt Seed Blending with tuning 69|Version 5|0.525|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24861020)|
|Bayesian Opt Seed Blending with tuning 69|Version 4|0.534|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24861001)|
|Bayesian Opt Seed Blending with tuning 69|Version 3|0.536|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24860982)|
|Bayesian Opt Seed Blending with tuning 69|Version 2|0.529|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24860963)|
|Bayesian Opt Seed Blending with tuning 69|Version 1|0.527|a month ago|[Open](https://www.kaggle.com/khoongweihao/bayesian-opt-seed-blending-with-tuning-69?scriptVersionId=24860940)|

<br>

# [ To Regression](https://www.kaggle.com/lilhxr/to-regression)

<a href="/lilhxr"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/3372526-kg.jpg" alt="Lil.H" width="72" height="72"></a>

- Author: [Lil.H](/lilhxr)
- Best score: 0.542
- Vote count: 8
- Comment count: 1
- Last updated: This Notebook has collaborators.

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
| To Regression|Version 3|0.537|11 days ago|[Open](https://www.kaggle.com/lilhxr/to-regression?scriptVersionId=26073842)|
| To Regression|Version 2|0.54|12 days ago|[Open](https://www.kaggle.com/lilhxr/to-regression?scriptVersionId=26034740)|
| To Regression|Version 1|0.536|13 days ago|[Open](https://www.kaggle.com/lilhxr/to-regression?scriptVersionId=25939374)|
| To Regression|Forked from|0.538|a month ago|[Open](https://www.kaggle.com/braquino/convert-to-regression)|

<br>

# [Truncated Val](https://www.kaggle.com/ragnar123/truncated-val)

<a href="/ragnar123"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" alt="ragnar" width="72" height="72"></a>

- Author: [ragnar](/ragnar123)
- Best score: 0.542
- Vote count: 41
- Comment count: 8
- Last updated: 11d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Truncated Val|Version 15|0.539|11 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=26090905)|
|Truncated Val|Version 14|0.539|14 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25906642)|
|Truncated Val|Version 13|0.528|15 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25855551)|
|Truncated Val|Version 12|0.542|16 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25814754)|
|Truncated Val|Version 11|-|16 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25814314)|
|Truncated Val|Version 10|-|16 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25813344)|
|Truncated Val|Version 9|0.537|16 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25807026)|
|Truncated Val|Version 8|-|16 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25806351)|
|Truncated Val|Version 7|0.532|17 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25758285)|
|Truncated Val|Version 6|0.523|17 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25721371)|
|Truncated Val|Version 5|-|17 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25720345)|
|Truncated Val|Version 4|-|17 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25719542)|
|Truncated Val|Version 3|-|17 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25718727)|
|Truncated Val|Version 2|-|17 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25718515)|
|Truncated Val|Version 1|-|17 days ago|[Open](https://www.kaggle.com/ragnar123/truncated-val?scriptVersionId=25718495)|

<br>

# [Bayesian Opt Seed Blending with tuning](https://www.kaggle.com/irochka/bayesian-opt-seed-blending-with-tuning)

<a href="/irochka"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/2948082-kg.JPG" alt="Iryna" width="72" height="72"></a>

- Author: [Iryna](/irochka)
- Best score: 0.542
- Vote count: 45
- Comment count: 4
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Bayesian Opt Seed Blending with tuning|Version 3|0.519|a month ago|[Open](https://www.kaggle.com/irochka/bayesian-opt-seed-blending-with-tuning?scriptVersionId=24678528)|
|Bayesian Opt Seed Blending with tuning|Version 2|-|a month ago|[Open](https://www.kaggle.com/irochka/bayesian-opt-seed-blending-with-tuning?scriptVersionId=24678479)|
|Bayesian Opt Seed Blending with tuning|Version 1|0.542|a month ago|[Open](https://www.kaggle.com/irochka/bayesian-opt-seed-blending-with-tuning?scriptVersionId=24662058)|
|Bayesian Opt Seed Blending with tuning|Forked from|0.511|2 months ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-seed-blending)|

<br>

# [Convert to Regression with tuning](https://www.kaggle.com/vbmokin/convert-to-regression-with-tuning)

<a href="/vbmokin"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1798416-gp.jpg" alt="Vitalii Mokin" width="72" height="72"></a>

- Author: [Vitalii Mokin](/vbmokin)
- Best score: 0.541
- Vote count: 13
- Comment count: 2
- Last updated: 21h ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Convert to Regression with tuning|Version 4|0.537|21 hours ago|[Open](https://www.kaggle.com/vbmokin/convert-to-regression-with-tuning?scriptVersionId=26691316)|
|Convert to Regression with tuning|Version 3|0.537|a day ago|[Open](https://www.kaggle.com/vbmokin/convert-to-regression-with-tuning?scriptVersionId=26686312)|
|Convert to Regression with tuning|Version 2|-|a day ago|[Open](https://www.kaggle.com/vbmokin/convert-to-regression-with-tuning?scriptVersionId=26665470)|
|Convert to Regression with tuning|Version 1|0.541|a day ago|[Open](https://www.kaggle.com/vbmokin/convert-to-regression-with-tuning?scriptVersionId=26663674)|
|Convert to Regression with tuning|Forked from|0.529|13 days ago|[Open](https://www.kaggle.com/challenge1a3/convert-to-regression)|

<br>

# [Adversarial Validation and Model](https://www.kaggle.com/ragnar123/adversarial-validation-and-model)

<a href="/ragnar123"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" alt="ragnar" width="72" height="72"></a>

- Author: [ragnar](/ragnar123)
- Best score: 0.54
- Vote count: 45
- Comment count: 8
- Last updated: 22d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Adversarial Validation and Model|Version 29|0.524|22 days ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25475898)|
|Adversarial Validation and Model|Version 28|-|22 days ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25471609)|
|Adversarial Validation and Model|Version 27|-|22 days ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25465325)|
|Adversarial Validation and Model|Version 26|-|22 days ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25465212)|
|Adversarial Validation and Model|Version 25|0.527|24 days ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25405838)|
|Adversarial Validation and Model|Version 24|0.532|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25279702)|
|Adversarial Validation and Model|Version 23|0.52|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25264638)|
|Adversarial Validation and Model|Version 22|0.52|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25244892)|
|Adversarial Validation and Model|Version 21|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25244657)|
|Adversarial Validation and Model|Version 20|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25244489)|
|Adversarial Validation and Model|Version 19|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25243466)|
|Adversarial Validation and Model|Version 18|0.506|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25235241)|
|Adversarial Validation and Model|Version 17|0.492|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25232628)|
|Adversarial Validation and Model|Version 16|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25231949)|
|Adversarial Validation and Model|Version 15|0.509|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=25213655)|
|Adversarial Validation and Model|Version 14|0.5|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24600164)|
|Adversarial Validation and Model|Version 13|0.509|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24598623)|
|Adversarial Validation and Model|Version 12|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24598605)|
|Adversarial Validation and Model|Version 11|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24598593)|
|Adversarial Validation and Model|Version 10|0.51|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24580964)|
|Adversarial Validation and Model|Version 9|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24562978)|
|Adversarial Validation and Model|Version 8|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24552745)|
|Adversarial Validation and Model|Version 7|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24552316)|
|Adversarial Validation and Model|Version 6|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24551706)|
|Adversarial Validation and Model|Version 5|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24551703)|
|Adversarial Validation and Model|Version 4|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24549592)|
|Adversarial Validation and Model|Version 3|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24549013)|
|Adversarial Validation and Model|Version 2|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24549003)|
|Adversarial Validation and Model|Version 1|-|a month ago|[Open](https://www.kaggle.com/ragnar123/adversarial-validation-and-model?scriptVersionId=24548631)|

<br>

# [Regression with event_data](https://www.kaggle.com/sourabhchauhan/regression-with-event-data)

<a href="/sourabhchauhan"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/2453765-kg.jpg" alt="sourabhsc" width="72" height="72"></a>

- Author: [sourabhsc](/sourabhchauhan)
- Best score: 0.539
- Vote count: 2
- Comment count: 0
- Last updated: 5d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Regression with event_data|Version 2|0.539|5 days ago|[Open](https://www.kaggle.com/sourabhchauhan/regression-with-event-data?scriptVersionId=26460665)|
|Regression with event_data|Version 1|-|5 days ago|[Open](https://www.kaggle.com/sourabhchauhan/regression-with-event-data?scriptVersionId=26426399)|

<br>

# [Bayesian Optimization Seed Blending](https://www.kaggle.com/hengzheng/bayesian-optimization-seed-blending)

<a href="/hengzheng"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1197382-kg.jpg" alt="Heng Zheng" width="72" height="72"></a>

- Author: [Heng Zheng](/hengzheng)
- Best score: 0.538
- Vote count: 108
- Comment count: 6
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Bayesian Optimization Seed Blending|Version 5|0.511|a month ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-seed-blending?scriptVersionId=24833393)|
|Bayesian Optimization Seed Blending|Version 4|-|a month ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-seed-blending?scriptVersionId=24828688)|
|Bayesian Optimization Seed Blending|Version 3|0.538|2 months ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-seed-blending?scriptVersionId=24071047)|
|Bayesian Optimization Seed Blending|Version 2|0.523|2 months ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-seed-blending?scriptVersionId=24066200)|
|Bayesian Optimization Seed Blending|Version 1|0.532|2 months ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-seed-blending?scriptVersionId=24061838)|
|Bayesian Optimization Seed Blending|Forked from|0.526|2 months ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-optimizedrounder)|

<br>

# [Fork of Fork of Fork of Trunc train dcf361](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-trunc-train-dcf361)

<a href="/lolaya"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/3545108-kg.jpg" alt="lolaya" width="72" height="72"></a>

- Author: [lolaya](/lolaya)
- Best score: 0.537
- Vote count: 0
- Comment count: 0
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Fork of Fork of Fork of Trunc train dcf361|Version 1|0.537|a month ago|[Open](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-trunc-train-dcf361?scriptVersionId=25058590)|
|Fork of Fork of Fork of Trunc train dcf361|Forked from|0.532|a month ago|[Open](https://www.kaggle.com/lolaya/fork-of-fork-of-trunc-train-dcf361)|

<br>

# [Fork of Fork of Fork of Fork of Fork of Trunc trai](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-fork-of-fork-of-trunc-trai)

<a href="/lolaya"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/3545108-kg.jpg" alt="lolaya" width="72" height="72"></a>

- Author: [lolaya](/lolaya)
- Best score: 0.536
- Vote count: 0
- Comment count: 0
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Fork of Fork of Fork of Fork of Fork of Trunc trai|Version 1|0.536|a month ago|[Open](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-fork-of-fork-of-trunc-trai?scriptVersionId=25120461)|
|Fork of Fork of Fork of Fork of Fork of Trunc trai|Forked from|0.533|a month ago|[Open](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-fork-of-trunc-train-3a8d32)|

<br>

# [Using Neural Network](https://www.kaggle.com/rodrigolima82/using-neural-network)

<a href="/rodrigolima82"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/2982285-kg.jpg" alt="Rodrigo Lima" width="72" height="72"></a>

- Author: [Rodrigo Lima](/rodrigolima82)
- Best score: 0.536
- Vote count: 24
- Comment count: 3
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Using Neural Network|Version 30|0.423|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24991881)|
|Using Neural Network|Version 29|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24991736)|
|Using Neural Network|Version 28|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24987214)|
|Using Neural Network|Version 27|0.413|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24960253)|
|Using Neural Network|Version 26|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24960228)|
|Using Neural Network|Version 25|0.431|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24937282)|
|Using Neural Network|Version 24|0.436|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24901029)|
|Using Neural Network|Version 23|0.433|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24889617)|
|Using Neural Network|Version 22|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24889601)|
|Using Neural Network|Version 21|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24889535)|
|Using Neural Network|Version 20|0.409|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24861414)|
|Using Neural Network|Version 19|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24827244)|
|Using Neural Network|Version 18|0.414|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24811367)|
|Using Neural Network|Version 17|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24811352)|
|Using Neural Network|Version 16|0.375|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24805090)|
|Using Neural Network|Version 15|0.171|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24791835)|
|Using Neural Network|Version 14|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24791169)|
|Using Neural Network|Version 13|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24769459)|
|Using Neural Network|Version 12|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24762847)|
|Using Neural Network|Version 11|0.532|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24661415)|
|Using Neural Network|Version 10|0.522|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24656553)|
|Using Neural Network|Version 9|0.528|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24644438)|
|Using Neural Network|Version 8|0.536|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24619793)|
|Using Neural Network|Version 7|0.507|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24602151)|
|Using Neural Network|Version 6|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24602140)|
|Using Neural Network|Version 5|0.525|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24591399)|
|Using Neural Network|Version 4|0.498|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24584737)|
|Using Neural Network|Version 3|-|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24559319)|
|Using Neural Network|Version 2|0.523|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24556285)|
|Using Neural Network|Version 1|0.534|a month ago|[Open](https://www.kaggle.com/rodrigolima82/using-neural-network?scriptVersionId=24546107)|
|Using Neural Network|Forked from|0.526|2 months ago|[Open](https://www.kaggle.com/hengzheng/bayesian-optimization-optimizedrounder)|

<br>

# [Quick and dirty regression](https://www.kaggle.com/artgor/quick-and-dirty-regression)

<a href="/artgor"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/727004-gr.jpg" alt="Andrew Lukyanenko" width="72" height="72"></a>

- Author: [Andrew Lukyanenko](/artgor)
- Best score: 0.536
- Vote count: 557
- Comment count: 100
- Last updated: 2mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Quick and dirty regression|Version 3|0.536|2 months ago|[Open](https://www.kaggle.com/artgor/quick-and-dirty-regression?scriptVersionId=23822562)|
|Quick and dirty regression|Version 2|-|2 months ago|[Open](https://www.kaggle.com/artgor/quick-and-dirty-regression?scriptVersionId=23821426)|
|Quick and dirty regression|Version 1|0.535|2 months ago|[Open](https://www.kaggle.com/artgor/quick-and-dirty-regression?scriptVersionId=23792373)|

<br>

# [DSB_Classfication](https://www.kaggle.com/zakopur0/dsb-classfication)

<a href="/zakopur0"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1985486-kg.png" alt="zakopuro" width="72" height="72"></a>

- Author: [zakopuro](/zakopur0)
- Best score: 0.535
- Vote count: 21
- Comment count: 3
- Last updated: 11d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|DSB_Classfication|Version 2|0.535|11 days ago|[Open](https://www.kaggle.com/zakopur0/dsb-classfication?scriptVersionId=26068520)|
|DSB_Classfication|Version 1|0.53|16 days ago|[Open](https://www.kaggle.com/zakopur0/dsb-classfication?scriptVersionId=25787666)|

<br>

# [kernel608b588315](https://www.kaggle.com/revoltmoon/kernel608b588315)

<a href="/revoltmoon"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" alt="Revolt Moon" width="72" height="72"></a>

- Author: [Revolt Moon](/revoltmoon)
- Best score: 0.534
- Vote count: 1
- Comment count: 0
- Last updated: 4d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|kernel608b588315|Version 2|0.529|4 days ago|[Open](https://www.kaggle.com/revoltmoon/kernel608b588315?scriptVersionId=26484550)|
|kernel608b588315|Version 1|0.534|5 days ago|[Open](https://www.kaggle.com/revoltmoon/kernel608b588315?scriptVersionId=26426564)|

<br>

# [XGB Simple and Efficient](https://www.kaggle.com/servietsky/xgb-simple-and-efficient)

<a href="/servietsky"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1904745-kg.jpg" alt="Evil Morty" width="72" height="72"></a>

- Author: [Evil Morty](/servietsky)
- Best score: 0.534
- Vote count: 19
- Comment count: 3
- Last updated: 25d ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|XGB Simple and Efficient|Version 2|0.534|25 days ago|[Open](https://www.kaggle.com/servietsky/xgb-simple-and-efficient?scriptVersionId=25313614)|
|XGB Simple and Efficient|Version 1|0.524|a month ago|[Open](https://www.kaggle.com/servietsky/xgb-simple-and-efficient?scriptVersionId=25294792)|

<br>

# [ML final_v2](https://www.kaggle.com/jiachengyou/ml-final-v2)

<a href="/jiachengyou"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" alt="Chris" width="72" height="72"></a>

- Author: [Chris](/jiachengyou)
- Best score: 0.534
- Vote count: 1
- Comment count: 0
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|ML final_v2|Version 10|0.534|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25292367)|
|ML final_v2|Version 9|0.527|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25279962)|
|ML final_v2|Version 8|0.484|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25254573)|
|ML final_v2|Version 7|-|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25223135)|
|ML final_v2|Version 6|0.501|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25215864)|
|ML final_v2|Version 5|-|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25192086)|
|ML final_v2|Version 4|0.512|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25168787)|
|ML final_v2|Version 3|0.503|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25167122)|
|ML final_v2|Version 2|-|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25166591)|
|ML final_v2|Version 1|-|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final-v2?scriptVersionId=25165175)|
|ML final_v2|Forked from|-|a month ago|[Open](https://www.kaggle.com/jiachengyou/ml-final)|

<br>

# [Fork of Fork of Fork of Fork of Trunc train 3a8d32](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-fork-of-trunc-train-3a8d32)

<a href="/lolaya"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/3545108-kg.jpg" alt="lolaya" width="72" height="72"></a>

- Author: [lolaya](/lolaya)
- Best score: 0.533
- Vote count: 0
- Comment count: 1
- Last updated: 1mo ago

|Title|Version|Score|Committed at|Link|
|-|-|-|-|-|
|Fork of Fork of Fork of Fork of Trunc train 3a8d32|Version 1|0.533|a month ago|[Open](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-fork-of-trunc-train-3a8d32?scriptVersionId=25120273)|
|Fork of Fork of Fork of Fork of Trunc train 3a8d32|Forked from|0.537|a month ago|[Open](https://www.kaggle.com/lolaya/fork-of-fork-of-fork-of-trunc-train-dcf361)|
"""

# %%
from IPython.display import display, Markdown

display(Markdown(markdown))
