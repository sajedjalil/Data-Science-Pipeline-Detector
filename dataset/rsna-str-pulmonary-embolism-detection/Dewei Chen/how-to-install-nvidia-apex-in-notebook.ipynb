# %% [markdown]
# The main problem is we need to confirm CUDA version and Pytorch CUDA version

# %% [markdown]
# > ## Setup apex

# %% [markdown]
# ## Check CUDA version

# %%
# !nvcc -V

# %%
#!pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# %% [markdown]
# ## Check Pytorch CUDA version

# %%
#! pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ../input/nvidiaapex/repository/NVIDIA-apex-39e153a
#! pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ../input/nvidiaapex/repository/NVIDIA-apex-39e153a
#! git clone https://github.com/NVIDIA/apex
#!pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex
#!cd ../input/apex-master/apex-master/apex-master/ && pip install --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" .
import torch

print(torch.version.cuda)
print(torch.__version__)

# %% [markdown]
# ## Check APEX Lib

# %%
import os
print(os.listdir("../input/nvidiaapex/repository/NVIDIA-apex-39e153a"))

# %% [markdown]
# ## Install Apex

# %%
# !git clone https://github.com/NVIDIA/apex
# !cd apex
# !pip install -v --no-cache-dir   ../input/nvidiaapex/repository/NVIDIA-apex-39e153a

# %%
import torch
import sys
import warnings

from apex import amp 




device = torch.device('cuda')

# %% [markdown]
# ## Done

# %%
dir(amp)

# %% [markdown]
# If you have any question, please leave a comment here.
