# %%
import os
from tqdm import tqdm
from zipfile import ZipFile

# %%
for first_folder in tqdm(sorted(os.listdir("../input/rsna-str-pulmonary-embolism-detection/train"))[2100:2350]):
    path_name = "../input/rsna-str-pulmonary-embolism-detection/train/{}".format(first_folder)
    target_name = "{}.tar.gz".format(first_folder)
    # !tar -zcf $target_name $path_name
