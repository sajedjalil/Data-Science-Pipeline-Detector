# %% [markdown]
# # GI-Seg Downloads
#
# Download requirements and weights for offline training and inference.
#
# ## Train & Infer Notebook Link
# [GI-Seg PyTorch ⚡ Train & Infer](https://www.kaggle.com/clemchris/gi-seg-pytorch-train-infer)

# %% [markdown]
# ## Segmentation Models PyTorch Requirements

# %%
# !pip download segmentation_models_pytorch efficientnet-pytorch==0.6.3 timm==0.4.12 pretrainedmodels==0.7.4 --no-deps

# %% [markdown]
# ## MONAI Requirements

# %%
# !pip download monai --no-deps

# %% [markdown]
# ## TorchMetrics Requirements

# %%
# !pip download torchmetrics --no-deps

# %% [markdown]
# ## Weights

# %%
# !wget https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b1-f1951068.pth
# !wget https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/tf_efficientnet_b1_ns-99dd0c41.pth
