# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

df_train = pd.read_csv('../input/uw-madison-gi-tract-image-segmentation/train.csv')
#print('Shape of training data: ' + str(df_train.shape) + '\n')
print(df_train.head())

# %%
#quit NaN
#data = df_train[df_train['segmentation'].notna()]

# %%
import matplotlib.pyplot as plt
import glob, os

images = [img for img in glob.glob("../input/uw-madison-gi-tract-image-segmentation/train/case101/case101_day20/scans/*.png") if 'mask' not in img]
    
for file in images[0:5]:
    im = plt.imread(file)
    plt.figure(figsize=(5,5))
    plt.imshow(im, cmap="Greys_r")
    plt.show()
