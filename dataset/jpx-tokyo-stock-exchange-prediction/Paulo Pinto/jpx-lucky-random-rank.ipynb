# %%
# CARL MCBRIDE ELLIS kernel inspired
# https://www.kaggle.com/code/carlmcbrideellis/jpx-baseline-monkey-throwing-dart-model

import random as r
import jpx_tokyo_market_prediction

e = jpx_tokyo_market_prediction.make_env()
i = e.iter_test()
r.seed(636)

for (_, _, _, _, _, s) in i:
    s['Rank'] = r.sample(range(2000), 2000)
    e.predict(s)
