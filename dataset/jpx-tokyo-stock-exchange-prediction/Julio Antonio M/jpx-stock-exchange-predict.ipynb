# %%
#Import library
import warnings
warnings.filterwarnings("ignore")
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
df = pd.read_csv('../input/jpx-tokyo-stock-exchange-prediction/train_files/stock_prices.csv')

# %%
print(df.head())

# %%
print(df.info())

# %%
print(df.isnull().sum())

# %%
print((df.isnull().sum()/len(df))*100)

# %%
df_spec = pd.read_csv('../input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_price_spec.csv')

# %%
print(df_spec)

# %% [markdown]
# Dealing with missing value
#
# The ExpectedDividend column contain almost all missing values. I will leave it out first

# %%
#Visualization of Open Price
sns.lineplot(x = "Date", y = "Open", 
             color = 'r', data = df)

# %%
#Visualization of High Price
sns.lineplot(x = "Date", y = "High", 
             color = 'g', data = df)

# %%
#Visualization of Low Price
sns.lineplot(x = "Date", y = "Low", 
             color = 'b', data = df)

# %%
#Visualization of Close Price
sns.lineplot(x = "Date", y = "Close", 
             color = 'y', data = df)

# %% [markdown]
# Looks like the OHLC follows the same trend
