# %%
import jpx_tokyo_market_prediction

env = jpx_tokyo_market_prediction.make_env()   # initialize the environment
iter_test = env.iter_test()    # an iterator which loops over the test files

# %% [markdown]
# ### Iterator provide Date column as named "index".

# %%
(prices, options, financials, trades, secondary_prices, sample_prediction) = next(iter_test)
env.predict(sample_prediction)
trades.head()

# %% [markdown]
# ### Train file provide Date column as named 'Date'.

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/jpx-tokyo-stock-exchange-prediction/train_files/trades.csv')
df.head(1)

# %% [markdown]
# ### Supplemental file also same.

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/jpx-tokyo-stock-exchange-prediction/supplemental_files/trades.csv')
df.head(1)
