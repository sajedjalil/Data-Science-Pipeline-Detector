# %% [markdown]
# 2022

# %% [markdown]
# BSD 3-Clause License
#
# Copyright (c) 2008-2011, AQR Capital Management, LCC, Lambda Foundry, Inc. and PyData Development Team
#
#     All rights reserved.
#
# Copyright (c) 2011-2021, Open source contributors.

# %% [markdown]
# THIS SOFTWARE, EVEN IF

# %%
import pandas as pd

# %%
df = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/stock_list.csv")

# %%
df.head(3)

# %%
df = pd.DataFrame(
    {
        "Secured":["1301","1305","1306"],
        "Capital":["3.365911e+10","7.621831e+12","1.641739e+13"],
        "Issued":["1.092828e+07","3.634636e+09","7.917718e+09"]
    }
)

# %%
df

# %%
pd.options.display.float_format="{:.1f}".format
df = 33659.11 / 10.92828
pd.DataFrame({"S":[df],"C":[df],"I":[df]})

# %%
pd.options.display.float_format="{:.1f}".format
df = 7621831 / 3634.636
pd.DataFrame({"S":[df],"C":[df],"I":[df]})

# %%
pd.options.display.float_format="{:.1f}".format
df = 16417390 / 7917.718
pd.DataFrame({"S":[df],"C":[df],"I":[df]})
