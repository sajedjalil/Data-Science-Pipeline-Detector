# %% [markdown]
# # The Scale Vector Network Machine

# %% [markdown]
# ![the network scale label.png](attachment:e76eb25d-0f44-4c7c-ab0e-6b24ba6bca89.png)

# %% [markdown]
# Over lattice under lattice hybrid lattice X X X X no default the default.
#
# Easy to buy some riffles than a handgun. You cannot stop it. They are your hallucinators.
#
# Hybrid buckets some highlighter all over the war documents and maps you become a billionair.
#
# The billion is nothing because all your tax gonna end up to a spill bucket potato eaters red.
#
# They all gonna keep lobsters, whales, and dolphin eggs safe because hell yah what they are.
#
# You and I need to be a group sufficient. Retail investors? OMG. We shall highlight some whales.
#
# Buy more foreign currencies because they are really undervalued.

# %% [markdown]
# # Left K Right K The Guru Mask
#
# A week later, we are here in YVR. Left. Right. Left eye. Right eye.
#
# Originally, all masks were invented to separate left and right inputs.
#
# This is a Guru Hand. Left blink, right blink, and a mask look reasonable.
#
# What is a guru's hand?
#
# Put two fingers right in front of your nose.
#
# Watch four monitors in the YVR domestic observation area with a guru's hand.
#
# Shake your guru's hand IYF since blinking irritate your eyes. Use AVERYSAD.

# %%
# Takasakick Agenda
# Clothings
# Personal Items
# Utensils
# Food
# Restaurants
# Household
# Services
# Other

# %% [markdown]
# ![figure four screens x.png](attachment:f1dd4abb-a6f3-4f7f-ae02-00227ed0dac3.png)

# %% [markdown]
# ![gold_5.jpg](attachment:f14c3164-1f24-4587-9081-68b53387b571.jpg)

# %% [markdown]
# ![green_01.jpg](attachment:e8a5d670-1c9b-4b32-9c58-0039217254a7.jpg)

# %% [markdown]
# ![purple.jpg](attachment:37203fcd-7b77-4275-95b3-8488ed771b65.jpg)

# %%
# Do not buy guns. Buy saline.
# %matplotlib inline
import networkx as nx

# %%
# https://networkx.org/documentation/stable/tutorial.html
MG = nx.MultiGraph()
MG.add_weighted_edges_from([(1, 2, 0.5), (1, 2, 0.75), (2, 3, 0.5)])
dict(MG.degree(weight='weight'))
{1: 1.25, 2: 1.75, 3: 0.5}
GG = nx.Graph()
for n, nbrs in MG.adjacency():
   for nbr, edict in nbrs.items():
       minvalue = min([d['weight'] for d in edict.values()])
       GG.add_edge(n, nbr, weight = minvalue)
nx.shortest_path(GG, 1, 3)

# %%
import matplotlib.pyplot as plt
G = nx.petersen_graph()
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
plt.show()

# %%
options = {
    'node_color': 'black',
    'node_size': 100,
    'width': 3,
}
subax1 = plt.subplot(221)
nx.draw_random(G, **options)
subax2 = plt.subplot(222)
nx.draw_circular(G, **options)
subax3 = plt.subplot(223)
nx.draw_spectral(G, **options)
subax4 = plt.subplot(224)
nx.draw_shell(G, nlist=[range(5,10), range(5)], **options)

# %%
G = nx.dodecahedral_graph()
shells = [[2, 3, 4, 5, 6], [8, 1, 0, 19, 18, 17, 16, 15, 14, 7], [9, 10, 11, 12, 13]]
nx.draw_shell(G, nlist=shells, **options)

# %%
nx.draw(G)
plt.savefig("path.png")
