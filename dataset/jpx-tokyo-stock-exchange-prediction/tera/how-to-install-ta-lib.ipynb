# %% [markdown]
# # Summary
# Internet access is not allowed in LB, so it must be installed based on the dataset.

# %% [markdown]
# # Method1. Install from whl
#
# Download whl from https://www.wheelodex.org/projects/talib-binary/ and add it to your dataset, then do the following.

# %%
# !pip install ../input/talib-source/talib_binary-0.4.19-cp37-cp37m-manylinux1_x86_64.whl
import talib as ta

# %% [markdown]
# # Method2. Build from Source
# I have not tried it, but it should work if you replace the part that wget with the dataset.
# Get the source from
# http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
#
# The code does not work as is, just for reference.

# %%
# %cd /kaggle/working
# %rm -rf temp
# !mkdir temp
# %cd ./temp
# !cp -r ../../input/talib-source/ta-lib-0.4.0-src/ta-lib ./
# %cd ./ta-lib
# !./configure --prefix=/usr
# !make > null
# !make install > null
# !pip install Ta-Lib > null
# %cd /kaggle/working
# !rm -rf temp
import talib as ta
