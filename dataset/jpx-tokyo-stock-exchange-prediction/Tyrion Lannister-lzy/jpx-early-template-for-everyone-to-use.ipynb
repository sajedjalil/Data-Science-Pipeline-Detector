# %% [markdown]
# <h1>Importing the Libraries</h1>

# %% [markdown]
# > If this notebook is useful to you, please DO **UPVOTE**⭐️⭐️⭐️

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

from plotly.offline import init_notebook_mode
init_notebook_mode(connected = True)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1>Check all the description first</h1>
#
# > you can remove the .head() to see the whole infomation

# %%
# check the data_specification first
data_specification_price=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_price_spec.csv")
data_specification_fin=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_fin_spec.csv")
data_specification_list=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_list_spec.csv")
data_specification_options=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/options_spec.csv")
data_specification_trades=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/trades_spec.csv")

# %%
data_specification_price

# %%
data_specification_fin.head()

# %%
data_specification_list.head()

# %%
data_specification_options.head()

# %%
data_specification_trades.head()

# %% [markdown]
# <h1>Loading the training data<h1>

# %%
train_fin=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/financials.csv",index_col=['DisclosureNumber'])
train_options=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/options.csv",index_col='DateCode')
train_sec=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/secondary_stock_prices.csv",index_col='RowId')
train_prices=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/stock_prices.csv",index_col='RowId')
train_trades=pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/trades.csv")

# %%
train_fin.loc[: ,"Date"] = pd.to_datetime(train_fin.loc[: ,"Date"], format="%Y-%m-%d")
train_fin_feat=train_fin.columns
train_fin.head()

# %%
train_options.loc[: ,"Date"] = pd.to_datetime(train_options.loc[: ,"Date"], format="%Y-%m-%d")
train_options_feat=train_options.columns
train_options.head()

# %%
train_sec.loc[: ,"Date"] = pd.to_datetime(train_sec.loc[: ,"Date"], format="%Y-%m-%d")
train_sec_feat=train_sec.columns
train_sec.head()

# %%
train_prices.loc[: ,"Date"] = pd.to_datetime(train_prices.loc[: ,"Date"], format="%Y-%m-%d")
train_prices_feat=train_prices.columns
train_prices.head()

# %%
train_trades.loc[: ,"Date"] = pd.to_datetime(train_trades.loc[: ,"Date"], format="%Y-%m-%d")
train_trades_feat=train_trades.columns
train_trades

# %%
missing_values_count_train_trades = train_trades.isnull().sum().sort_values(ascending=False)
missing_values_count_train_trades.head(10)

# %% [markdown]
# <h3>Since the missing values' attributes ,we can just drop them by row

# %%
train_trades.dropna()

# %% [markdown]
# <h1>Futher EDA is coming soon...<h1>
