# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Initialize the environment

# %%
import jpx_tokyo_market_prediction
env = jpx_tokyo_market_prediction.make_env()
iter_test = env.iter_test()

# %% [markdown]
# Loading data

# %%
import gc
import warnings

import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# Configuration
warnings.simplefilter('ignore')
pd.set_option('max_column', None)
sns.set_style("darkgrid")
colors = sns.color_palette('Set2')

# %%
TRAIN_DIR = "../input/jpx-tokyo-stock-exchange-prediction/train_files"

# %%
# %%time

df_prices = pd.read_csv(os.path.join(TRAIN_DIR, 'stock_prices.csv'))
df_prices_sec = pd.read_csv(os.path.join(TRAIN_DIR, 'secondary_stock_prices.csv'))
df_fins = pd.read_csv(os.path.join(TRAIN_DIR, 'financials.csv'))
df_opts = pd.read_csv(os.path.join(TRAIN_DIR, 'options.csv'))
df_trades = pd.read_csv(os.path.join(TRAIN_DIR, 'trades.csv'))
stock_list = pd.read_csv(os.path.join("../input/jpx-tokyo-stock-exchange-prediction/stock_list.csv"))

# %% [markdown]
# Take a look at first 5 rows.

# %%
df_prices.head(10)

# %% [markdown]
# Check oldest date and most recent date for stock price

# %% [markdown]
# Check oldest and newest stock price.

# %%
print('Oldest date:',df_prices['Date'].min())
print('Most recent date:',df_prices['Date'].max())

# %% [markdown]
# Check null value of stock price

# %% [markdown]
# Check null value counts.

# %%
df_prices.isnull().sum()

# %% [markdown]
# There are many missing value in Target, let's examine them.

# %%
df_prices[df_prices['Target'].isnull()]

# %% [markdown]
# check percentage of missing value.

# %%
df_prices.isnull().sum() / df_prices.shape[0] * 100

# %% [markdown]
# check df price shape.

# %%
df_prices.shape

# %% [markdown]
# check each column data type

# %%
df_prices.info()

# %% [markdown]
# check summary description of Df price.

# %%
df_prices.describe()

# %% [markdown]
# check value count of a column

# %%
df_prices.SecuritiesCode.value_counts()

# %% [markdown]
# Check the correlation between variables in the data

# %%
corrMatrix = df_prices.corr()

# %% [markdown]
# Next, we visualise the matrix with Seaborn library

# %%
sns.heatmap(corrMatrix, annot = True, cmap= 'coolwarm')

# %% [markdown]
# Stock List EDA

# %%
stock_list.describe()

# %%
stock_list.head(10)
