# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.offline as po
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
import random
import plotly.figure_factory as ff
import warnings
import missingno as msno
warnings.simplefilter('ignore')

# %%
#Loading the training data
financial_df=pd.read_csv("/kaggle/input/jpx-tokyo-stock-exchange-prediction/train_files/financials.csv")
options_df=pd.read_csv("/kaggle/input/jpx-tokyo-stock-exchange-prediction/train_files/options.csv")
secondary_stock_df=pd.read_csv("/kaggle/input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_price_spec.csv")
stock_prices_df=pd.read_csv("/kaggle/input/jpx-tokyo-stock-exchange-prediction/train_files/stock_prices.csv")
trades_df=pd.read_csv("/kaggle/input/jpx-tokyo-stock-exchange-prediction/train_files/trades.csv")

# %%
financial_df.head(10).style.set_caption("Financial Dataframe").set_properties(**{'background-color': 'yellow',
                           'color': 'magenta','border': '1.3px solid green'})

# %%
options_df.head(10).style.set_caption("Options Dataframe").set_properties(**{'background-color': 'yellow',
                           'color': 'magenta','border': '1.3px solid green'})

# %%
secondary_stock_df.head(10).style.set_caption("Secondary Dataframe").set_properties(**{'background-color': 'yellow',
                           'color': 'magenta','border': '1.3px solid green'})

# %%
stock_prices_df.head(10).style.set_caption("Stock Prices Dataframe").set_properties(**{'background-color': 'yellow',
                           'color': 'magenta','border': '1.3px solid green'})

# %%
trades_df.head(10).style.set_caption("Trades Dataframe").set_properties(**{'background-color': 'yellow',
                           'color': 'magenta','border': '1.3px solid green'})

# %%
# Shape of the data files ( number of rows and number of columns) 
print('\033[1m'"Shape of the Financial File "'\033[0m',financial_df.shape )
print('\033[1m'"Shape of the Options file"'\033[0m', options_df.shape)
print('\033[1m'"Shape of the Secondary Stock File"'\033[0m',secondary_stock_df.shape)
print('\033[1m'"Shape of the Stock Prices File"'\033[0m',stock_prices_df.shape)
print('\033[1m'"Shape of the trades File"'\033[0m',trades_df.shape)

# %%
# Data Types of each column
print('\033[1m'"Data types of each column in Financial data file\n"'\033[0m',financial_df.dtypes)
print('\033[1m'"Data types of each column in Options data file\n"'\033[0m',options_df.dtypes)
print('\033[1m'"Data types of each column in Secondary data file\n"'\033[0m',secondary_stock_df.dtypes)
print('\033[1m'"Data types of each column in Stock prices data file\n"'\033[0m',stock_prices_df.dtypes)
print('\033[1m'"Data types of each column in trades data file\n"'\033[0m',trades_df.dtypes)

# %%
#Missing value count  
print('\033[1m'"Missing value count in each column of financial data file\n"'\033[0m',financial_df.isna().sum())
print('\033[1m'"Missing value count in each column of options data file\n"'\033[0m',options_df.isna().sum())
print('\033[1m'"Missing value count in each column of secondary stock data file\n"'\033[0m',secondary_stock_df.isna().sum())
print('\033[1m'"Missing value count in each column of stock prices data file\n"'\033[0m',stock_prices_df.isna().sum())
print('\033[1m'"Missing value count in each column of trades data file\n"'\033[0m',trades_df.isna().sum())

# %%
# Dsipalying the column names of the tables 
print("Financial Dataframe Columns:")
print('-'*50)
print(financial_df.columns)
print("\n")
print("Options Dataframe Columns:")
print('-'*50)
print(options_df.columns)
print("\n")
print("Secondary Dataframe Columns:")
print('-'*50)
print(secondary_stock_df.columns)
print("\n")
print("Stock Prices Dataframe Columns:")
print('-'*50)
print(stock_prices_df.columns)
print("\n")
print("Trades Dataframe Columns:")
print('-'*50)
print(trades_df.columns)

# %%
msno.bar(financial_df, color="dodgerblue", sort="ascending",figsize=(20,10), fontsize=12)
plt.show()

# %%
msno.bar(options_df, color="dodgerblue", sort="ascending",figsize=(10,5), fontsize=12)
plt.show()

# %%
msno.bar(secondary_stock_df, color="dodgerblue", sort="ascending",figsize=(10,5), fontsize=12)
plt.show()

# %%
msno.bar(stock_prices_df, color="dodgerblue", sort="ascending",figsize=(10,5), fontsize=12)
plt.show()

# %%
msno.heatmap(trades_df, sort="ascending",figsize=(20,10), fontsize=12)
plt.show()

# %%
# No of duplicated values 
print('⁕'*50)
print("Number of Duplicate value in Financial Dataframe:",financial_df.duplicated().sum())
print("Number of Duplicate value in Options Dataframe:",options_df.duplicated().sum())
print("Number of Duplicate value in Secondary Stock Dataframe:",secondary_stock_df.duplicated().sum())
print("Number of Duplicate value in Stock Dataframe:",stock_prices_df.duplicated().sum())
print("Number of Duplicate value in Trades Dataframe:",trades_df.duplicated().sum())
print('⁕'*50)

# %% [markdown]
# # Analysis of the Financial Dataframe

# %% [markdown]
# ## Univariate Analysis

# %%
financial_df.dtypes

# %%
financial_df.head(2)

# %%
# No of unique values 

print("Number of Unique values in DateCode column of Financial Dataframe:",financial_df["DateCode"].nunique())

# %%
financial_df.TypeOfDocument.value_counts()

# %%
#count of pp_total_raw in the district dataframe

plt.figure(figsize=(10,8))
sns.countplot(y ='TypeOfDocument',data = financial_df,order=financial_df['TypeOfDocument'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x ='TypeOfCurrentPeriod',data = financial_df,order=financial_df['TypeOfCurrentPeriod'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x ='ApplyingOfSpecificAccountingOfTheQuarterlyFinancialStatements',data = financial_df,order=financial_df['ApplyingOfSpecificAccountingOfTheQuarterlyFinancialStatements'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x ='MaterialChangesInSubsidiaries',data = financial_df,order=financial_df['MaterialChangesInSubsidiaries'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x ='ChangesBasedOnRevisionsOfAccountingStandard',data = financial_df,order=financial_df['ChangesBasedOnRevisionsOfAccountingStandard'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x ='ChangesOtherThanOnesBasedOnRevisionsOfAccountingStandard',data = financial_df,order=financial_df['ChangesOtherThanOnesBasedOnRevisionsOfAccountingStandard'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x ='ChangesInAccountingEstimates',data = financial_df,order=financial_df['ChangesInAccountingEstimates'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x ='RetrospectiveRestatement',data = financial_df,order=financial_df['RetrospectiveRestatement'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
# SecurityCode distribution wrt to Type of Document

sns.displot(data=financial_df, x='SecuritiesCode', hue='TypeOfDocument',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)

# %%
#SecurityCode distribution wrt TypeOfCurrentPeriod

sns.displot(data=financial_df, x='SecuritiesCode', hue='TypeOfCurrentPeriod',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)

# %%
sns.displot(data=financial_df, x='SecuritiesCode', hue='ApplyingOfSpecificAccountingOfTheQuarterlyFinancialStatements',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)

# %%
sns.displot(data=financial_df, x='SecuritiesCode', hue='MaterialChangesInSubsidiaries',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)

# %%
sns.displot(data=financial_df, x='SecuritiesCode', hue='ChangesBasedOnRevisionsOfAccountingStandard',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)

# %%
sns.displot(data=financial_df, x='SecuritiesCode', hue='ChangesOtherThanOnesBasedOnRevisionsOfAccountingStandard',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)

# %%
sns.displot(data=financial_df, x='SecuritiesCode', hue='ChangesInAccountingEstimates',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)

# %%
sns.displot(data=financial_df, x='SecuritiesCode', hue='RetrospectiveRestatement',kind='kde',multiple="stack",height=8.27, aspect=11.7/8.27)
