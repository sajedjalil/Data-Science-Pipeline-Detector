# %% [markdown]
# # ConnectX - Numba Testcases
#
# I was having some issues getting numba to work (its fiddly!), both in general and specifically inside a Kaggle AI Submit environment.
#
# The fallback method for debugging such issues is write unit tests, starting with the simplest possible usecase and expanding until we figure out which features or syntax patterns break it.

# %%
# %%writefile submission.py
from numba import njit

# WORKS | Testcase 1 - native python - return static value
def python_constant():
    return 3


# WORKS | Testcase 2 - @njit - return static value
@njit
def njit_constant():
    return 3

# BROKEN | Testcase 3 - @njit - passing in Structs arguments
# BROKEN | cannot determine Numba type of <class 'kaggle_environments.utils.Struct'>
@njit
def njit_struct_arguments(observation, configuration):
    return configuration.columns - configuration.rows



# The last function defined in the file run by Kaggle in submission.py
def agent(observation, configuration) -> int:
    for code in [
        'python_constant()',
        'njit_constant()',
        'njit_struct_arguments(observation, configuration)'
    ]:
        try:
            value = eval(code)
            print('WORKS', code, '=', value, type(value))
        except Exception as e:
            print('\n','EXCEPTION: ', code, '\n', e)
        
    action = njit_constant()
    return int(action)

# %%
# %run submission.py

# %%
from kaggle_environments import make
env = make("connectx", debug=True)
env.render()
env.reset()

observation   = env.state[0].observation
configuration = env.configuration
action = agent(observation, configuration)
print('RUN: action', '=', action, type(action))
