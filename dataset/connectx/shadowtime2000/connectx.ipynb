# %% [markdown]
# Let's create the first logic for our agent:

# %%
def agent_blocker(obs, config):
    my_mark = obs.mark
    for area in range(obs.board):
        if (obs.board[area] == 0):
            if (not (obs.board[area + 1] == 0 or obs.board[area + 1] == my_mark) or not (obs.board[area - 1] == 0 or obs.board[area - 1] == 1) or not (obs.board[area + 8] == 0 or obs.board[area + 8] == 1 or obs.board[area - 9])):
                return area

# %% [markdown]
# That agent just has the logic to try to block the opponent. What if their is no way it can block the opponent? Then it should put a token in a spot where it can help progress to winning.

# %%
def agent_blocker(obs, config):
    my_mark = obs.mark
    for area in range(obs.board):
        if (obs.board[area] == 0):
            if (not (obs.board[area + 1] == 0 or obs.board[area + 1] == my_mark) or not (obs.board[area - 1] == 0 or obs.board[area - 1] == 1) or not (obs.board[area + 8] == 0 or obs.board[area + 8] == 1 or obs.board[area - 9])):
                return area
    for area in range(obs.board):
        if (obs.board[area] == 0):
            if (obs.board[area + 1] == my_mark or obs.board[area - 1] == my_mark or obs.board[config.columns + 1 + area] == my_mark):
                return area

# %% [markdown]
# But, of course if we can't do that, we should have it drop a token in the leftmost area.

# %%
def agent_blocker(obs, config):
    my_mark = obs.mark
    for area in range(obs.board):
        if (obs.board[area] == 0):
            if (not (obs.board[area + 1] == 0 or obs.board[area + 1] == my_mark) or not (obs.board[area - 1] == 0 or obs.board[area - 1] == 1) or not (obs.board[area + 8] == 0 or obs.board[area + 8] == 1 or obs.board[area - 9])):
                return area
    for area in range(obs.board):
        if (obs.board[area] == 0):
            if (obs.board[area + 1] == my_mark or obs.board[area - 1] == my_mark or obs.board[config.columns + 1 + area] == my_mark):
                return area
    for area in range(obs.board):
        if (obs.board[area] == 0):
            return area

# %% [markdown]
# So that is our simple agent for ConnectX. Here is the full code.

# %%
# %%writefile "submission.py"
#
# def agent_blocker(obs, config):
#     my_mark = obs.mark
#     for area in range(obs.board):
#         if (obs.board[area] == 0):
#             if (not (obs.board[area + 1] == 0 or obs.board[area + 1] == my_mark) or not (obs.board[area - 1] == 0 or obs.board[area - 1] == 1) or not (obs.board[area + 8] == 0 or obs.board[area + 8] == 1 or obs.board[area - 9])):
#                 return area
#     for area in range(obs.board):
#         if (obs.board[area] == 0):
#             if (obs.board[area + 1] == my_mark or obs.board[area - 1] == my_mark or obs.board[config.columns + 1 + area] == my_mark):
#                 return area
#     for area in range(obs.board):
#         if (obs.board[area] == 0):
#             return area
