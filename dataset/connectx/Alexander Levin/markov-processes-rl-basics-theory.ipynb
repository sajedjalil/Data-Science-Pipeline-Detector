# %% [markdown]
# # Markov Reward and Decision Processes
# ### Notebook Series about Reinforcement Learning
# ##### Created with the help of [RL Course by David Silverman](http://www0.cs.ucl.ac.uk/staff/d.silver/web/Teaching.html)

# %% [markdown]
# ## Definitions

# %% [markdown]
# History is the sequence of **observations, actions, rewards**:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **State** is a function of the history:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Observation** is the data about environment at the exact state.
#
# For example, if the environment is the Chess game, then an observation is the board (8х8 array) at the exact state, and the state is the game at the exact point of the time.

# %% [markdown]
# **Action** is the change in the environment (transition from the one state to other), that was provoked by an agent.

# %% [markdown]
# **Reward** is:
# ![image.png](attachment:image.png)

# %% [markdown]
# Model:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Value Function:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Policy:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Markov Process (Markov Chain)

# %% [markdown]
# When the state is Markov:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# State Transition Matrix:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Markov Process:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Markov Reward Process

# %% [markdown]
# A Markov reward process is a Markov chain with values (at each state):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Return:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Markov Decision Process

# %% [markdown]
# A Markov decision process (MDP) is a Markov reward process with
# decisions. It is an environment in which all states are Markov:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# State-Value Function:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Action-Value Function:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Bellman Equation:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Optimal Value Function:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Main Point
# #### "To train the reinforcement learnig agent" in the context of MDP means to achieve the maximum (optimal) value function with the optimal policy. And in order to do that we need to solve this:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# where q_star(s,a) is:
#
# ![image.png](attachment:image.png)
#
# If we know q_star(s,a), we immediately have the optimal policy.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this notebook we defined basic and the most important RL-definitions: action, state, reward, observation, state-transition matrix, value function, policy, model. We also considered Markov reward processes (MRPs) and Markov decision processes (MDPs), Bellman Equation and Optimal Value Function.

# %% [markdown]
# ## Practice (to be finished..)
# Let's model out environment.

# %%
# !pip install 'kaggle-environments>=0.1.6'

# %%
# import numpy as np
# import pandas as pd
# from kaggle_environments import evaluate, make, utils
# from copy import deepcopy

# env = make("connectx", debug=True)
# env.render()

# %%
# trainer = env.train([None, "random"])
# observation = trainer.reset()

# while not env.done:
#     my_action = agent
#     observation, reward, done, info = trainer.step(my_action)
#     if reward==0:
#     env.render(mode="ipython", width=100, height=90, header=False, controls=False)
# env.render()

# %% [markdown]
# In Practice block we implemented a simple Connect4 environment with rewards and actions and have tested it with "manual input" and random agent.
