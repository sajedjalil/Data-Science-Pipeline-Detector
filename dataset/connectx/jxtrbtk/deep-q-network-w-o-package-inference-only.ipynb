# %% [markdown]
# # Install kaggle-environments

# %%
# 1. Enable Internet in the Kernel (Settings side pane)

# 2. Curl cache may need purged if v0.1.4 cannot be found (uncomment if needed). 
# !curl -X PURGE https://pypi.org/simple/kaggle-environments

# ConnectX environment was defined in v0.1.4
# !pip install 'kaggle-environments>=0.1.4'

# %% [markdown]
# # Create ConnectX Environment

# %%
from kaggle_environments import evaluate, make

env = make("connectx", debug=True)
env.render()

# %% [markdown]
# # Create an Agent
#
# To create the submission, an agent function should be fully encapsulated (no external dependencies).
#
# When your agent is being evaluated against others, it will not have access to the Kaggle docker image.  Only the following can be imported: Python Standard Library Modules, gym, numpy, scipy (more may be added later).

# %% [markdown]
# > I've copy and paste all the weights and bias from my DQN so I can compute a forward pass in numpy.

# %%
def my_agent(observation, configuration):
    import numpy as np
    b1 = np.array([ 0.39107022,  0.27184662,  0.80062366,  0.36411327, -0.03787428,
            0.4961624 ,  0.5667995 ,  0.15747194,  0.3425753 , -0.33075845,
            0.475386  ,  0.42489567,  0.4289762 ,  0.17465332, -0.00765293,
           -0.18805483, -0.20053709,  0.0637599 ,  0.32381004,  0.5840297 ,
            0.33262524,  0.34748912,  0.0598983 , -0.25116265, -0.14862378,
            0.6888255 ,  0.19916199,  0.02622735,  0.34718773,  0.04602281,
            0.27913368,  0.03676706,  0.40374726,  0.5493425 ,  0.40862375,
            0.5466992 ,  0.29174048,  0.10160056,  0.43475536, -0.01828752,
           -0.1650022 ,  0.46653083,  0.4334895 , -0.08003529,  0.6210371 ,
            0.29796436, -0.21583314,  0.21850221,  0.19239588, -0.12594125,
            0.49363983,  0.35180327,  0.48679602,  0.19941545,  0.32375053,
           -0.5343979 ,  0.19665527,  0.20604187, -0.02936064,  0.02905595,
            0.7188601 ,  0.2829313 ,  0.40301415, -0.26804033])
    b2 = np.array([ 0.3000102 ,  0.39370584,  0.26930538,  0.21107528,  0.42241582,
            0.3372803 ,  0.13139315,  0.4699662 ,  0.37946337,  0.44936034,
            0.12010058, -0.11157609,  0.26417217, -0.03273825,  0.24150424,
            0.46845   ,  0.47745755, -0.07723615,  0.16868372,  0.47249776,
           -0.08843984,  0.7293285 ,  0.12830809,  0.16906166,  0.2131781 ,
            0.06286443,  0.0398999 ,  0.0757384 , -0.04084555,  0.17131642,
            0.12469839,  0.3333829 ,  0.16961312,  0.2329742 ,  0.15992527,
            0.23196723,  0.06463318,  0.03777971,  0.06548359,  0.21637048,
            0.00987172,  0.09708743,  0.13394016,  0.30789828,  0.5830163 ,
            0.00831597,  0.5075819 ,  0.5032453 , -0.1283854 ,  0.12985444,
            0.5330339 ,  0.44353622,  0.5081669 ,  0.17687146,  0.17184292,
            0.1981685 , -0.12975271, -0.02563613,  0.15349977,  0.03644698,
            0.4565636 , -0.16377354,  0.2172874 ,  0.43911967])
    b3 =np.array([0.55594903, 0.26781517, 0.056481  , 0.06579881, 0.48296842,
           0.2996088 , 0.725221  ])    
    w1 = np.array([[-3.23087513e-01,  2.44436398e-01, -8.53015929e-02,
         4.20761630e-02, -4.29029942e-01, -8.16381693e-01,
         1.82251692e-01,  1.14811607e-01,  2.39248812e-01,
        -3.16569746e-01, -5.34243099e-02,  6.16381429e-02,
        -3.18263322e-02, -5.81023574e-01, -7.53208436e-03,
        -1.43814713e-01,  5.23015149e-02,  3.11345458e-01,
         1.29029483e-01, -5.29837655e-03,  1.00121520e-01,
         8.02803636e-01, -2.42633685e-01,  4.91211973e-02,
        -6.18229993e-02, -1.58237576e-01, -3.14234823e-01,
        -1.32465139e-01,  1.38451662e-02,  1.10857084e-01,
        -2.12411210e-01,  2.44526163e-01, -7.62929171e-02,
        -2.55778998e-01, -2.32406154e-01, -1.43656850e-01,
        -1.87360898e-01,  2.05634028e-01, -1.03169098e-01,
         2.08409980e-01,  3.98760587e-02,  2.81327963e-02],
       [-5.15240848e-01,  4.29337472e-02, -2.26876467e-01,
         1.25338942e-01, -2.47898668e-01, -5.81112839e-02,
         1.64015055e-01,  7.77720809e-02, -4.21582721e-02,
        -2.01848984e-01,  3.14144462e-01, -1.76261321e-01,
         1.10661939e-01, -2.26640478e-01,  5.78098714e-01,
         2.85627872e-01,  8.44197571e-02, -7.24573314e-01,
         1.81378260e-01,  2.59494215e-01, -3.25541139e-01,
         1.18454659e+00,  2.54525114e-02,  2.13604122e-01,
        -3.93788278e-01,  2.28146315e-01,  2.01413967e-02,
        -6.36757731e-01,  4.14426714e-01,  3.48472446e-02,
         2.90848494e-01, -3.71186882e-01,  2.07018301e-01,
         2.46722460e-01,  3.92759517e-02, -2.22103655e-01,
         1.37845472e-01,  1.11235999e-01, -3.18640292e-01,
         1.80016190e-01,  2.24775180e-01, -4.38016087e-01],
       [ 2.11992696e-01,  2.20331058e-01,  3.01156402e-01,
         4.69898015e-01,  1.21220909e-01,  8.53477940e-02,
        -1.26043722e-01, -8.59155133e-02,  1.26654401e-01,
        -4.02568638e-01,  2.97798932e-01, -1.10563882e-01,
        -8.55739787e-02,  4.80861403e-02,  8.32851529e-02,
         3.90972406e-01,  2.20217127e-02,  4.95883971e-01,
        -2.07202107e-01,  2.13238522e-01,  7.21680149e-02,
        -1.51322675e+00, -3.91043752e-01, -3.35160524e-01,
        -2.17081219e-01, -1.42629668e-01, -3.22531909e-01,
        -2.31644465e-03, -4.61534768e-01, -3.77578944e-01,
        -2.88347751e-01,  1.42749902e-02, -2.30738610e-01,
         5.79633415e-02,  2.83863574e-01,  1.42114982e-01,
         3.19482237e-02,  4.02666070e-03,  1.61202952e-01,
         9.32554379e-02,  3.05406779e-01,  2.89965719e-02],
       [ 9.32897270e-01, -2.24118382e-01, -7.42666364e-01,
        -4.11033005e-01,  4.72308666e-01,  6.50214672e-01,
        -7.37007856e-01,  2.28812650e-01,  1.55988663e-01,
        -3.33238453e-01,  2.13795990e-01,  9.38148648e-02,
        -2.54625827e-01,  1.57262515e-02,  7.66293034e-02,
         2.50171691e-01, -1.42014310e-01,  3.99379492e-01,
         1.05089098e-01, -2.31389269e-01,  1.60538971e-01,
         9.95850936e-02,  3.53795409e-01, -2.55989045e-01,
        -2.35534787e-01, -1.74290955e-01, -2.32977629e-01,
         5.40910587e-02, -7.76591897e-01, -2.72134274e-01,
         7.80808702e-02, -3.38413939e-02, -4.62391108e-01,
         9.85086486e-02,  4.44898419e-02, -9.37939659e-02,
        -2.10461572e-01,  2.90766835e-01,  7.41695389e-02,
         2.91651905e-01, -4.21129525e-01, -1.63814649e-01],
       [-2.75448233e-01, -3.59664917e-01,  4.51483935e-01,
        -8.40680718e-01, -1.93060979e-01,  3.80023047e-02,
        -5.99357672e-02, -2.39118561e-01, -3.69869769e-01,
         3.67007852e-01, -2.79579401e-01,  2.07557585e-02,
         2.04438820e-01,  2.81014919e-01, -1.36997372e-01,
        -2.30621055e-01,  8.26798603e-02, -9.02632475e-01,
         2.48917252e-01,  1.22274034e-01,  1.58007324e-01,
         2.79983640e-01,  4.19413120e-01,  5.09947836e-02,
        -4.63827252e-01,  1.32510558e-01, -1.30286366e-02,
        -3.06223452e-01,  4.48904067e-01,  3.33316810e-02,
        -9.33476612e-02, -2.66445398e-01, -6.79159537e-02,
        -8.81503522e-02,  5.95619045e-02,  1.31802754e-02,
         4.83739257e-01, -1.44495638e-02, -1.63264528e-01,
         4.38955247e-01,  2.06406385e-01, -2.86666512e-01],
       [-6.32366002e-01,  2.13374086e-02,  7.29807988e-02,
        -1.06305182e-01, -1.99519843e-01, -1.78371623e-01,
        -3.93034786e-01, -3.12285990e-01, -1.96907997e-01,
        -4.16911542e-02, -3.79305072e-02, -2.75516748e-01,
        -6.08504117e-01,  1.20094866e-01, -6.06956065e-01,
         4.26087439e-01, -2.44225308e-01, -4.52110112e-01,
        -8.62970203e-02, -1.99977830e-01, -2.96115786e-01,
         3.97936162e-03, -4.34164017e-01, -9.33898985e-02,
        -1.22196533e-01, -1.99923292e-01, -1.26815006e-01,
        -1.92296118e-01,  1.33151308e-01, -5.46375334e-01,
         1.74307033e-01, -1.50421590e-01, -5.88998675e-01,
        -3.69624078e-01,  4.32408541e-01,  7.98613504e-02,
        -3.02891731e-01, -1.80457439e-02, -5.38476348e-01,
        -1.02679648e-01, -1.39399612e+00,  1.12965042e-02],
       [ 8.55584979e-01,  1.22261196e-01, -2.48599514e-01,
         1.86211765e-01,  1.28312811e-01,  4.94630575e-01,
         6.39567971e-02, -1.72613505e-02, -4.22618806e-01,
        -1.40486121e-01,  2.59033978e-01,  2.40006775e-01,
         4.78732325e-02,  7.50977620e-02, -4.25142527e-01,
        -1.58703066e-02, -1.99196845e-01,  9.22891498e-02,
        -7.60421515e-01, -3.85831267e-01, -2.70382836e-02,
        -6.73078895e-01, -1.00108147e-01,  5.18519580e-01,
         1.32994562e-01, -7.38898277e-01, -2.55005479e-01,
         2.27487624e-01, -2.71808449e-02, -3.91460925e-01,
        -3.62685889e-01,  1.70958281e-01, -6.06714673e-02,
         1.45851387e-04, -1.99679434e-02,  4.28523049e-02,
        -2.21710265e-01, -8.42762645e-03, -4.06040579e-01,
         8.31152126e-02,  9.16423276e-02, -1.45300269e-01],
       [-2.77213514e-01,  4.00797457e-01,  2.99435735e-01,
        -6.78540468e-01,  4.60626423e-01, -1.07946053e-01,
        -4.80825782e-01, -1.46753088e-01,  8.18207443e-01,
         1.77495405e-02, -4.03368860e-01, -2.70201951e-01,
        -3.81257832e-01,  1.69954047e-01,  8.96459445e-02,
         2.28146985e-01,  4.50063916e-03, -2.77706444e-01,
        -7.16663718e-01,  1.27499327e-01, -1.97635621e-01,
         1.33140087e-01, -3.56313288e-01, -1.67251192e-02,
        -7.05209970e-02, -8.44555140e-01, -5.35870016e-01,
         3.46895039e-01,  2.99310654e-01,  2.06722885e-01,
        -1.99901983e-02, -6.03910424e-02,  1.94807306e-01,
        -1.05721086e-01,  2.55970865e-01, -8.82705003e-02,
        -1.67417631e-01, -1.00619607e-01, -3.37462276e-01,
         3.39666009e-01,  7.28969574e-02, -9.88976583e-02],
       [ 2.23564625e-01,  2.36101821e-01,  4.64479439e-02,
         8.59959424e-02,  5.34286201e-01, -3.30283530e-02,
        -1.42748848e-01,  6.73387289e-01,  3.33979458e-01,
         4.54988003e-01,  5.81955612e-02,  1.06114864e-01,
        -6.80637583e-02, -3.90561298e-02,  2.77029127e-01,
         2.14278072e-01,  3.63018841e-01, -6.35679141e-02,
         4.78174359e-01,  5.62500000e-01,  1.16308726e-01,
         3.28652948e-01, -9.05876160e-02,  3.22809845e-01,
        -5.25729597e-01,  3.65501940e-01, -2.05254052e-02,
         3.18153024e-01, -2.72283107e-01,  4.93912578e-01,
         1.32878914e-01,  1.04753219e-01, -1.69085190e-01,
        -3.58669788e-01, -1.51646733e-01,  1.76380336e-01,
         6.21538013e-02,  1.21804617e-01, -9.00504068e-02,
        -8.76668692e-02,  1.11864597e-01,  1.32059649e-01],
       [ 4.41416621e-01,  6.38651550e-01,  6.31104827e-01,
        -1.50214404e-01,  2.75708616e-01, -1.16101606e-02,
         4.04371142e-01,  5.18771529e-01,  7.25331008e-01,
         2.63480186e-01,  9.69614983e-02,  2.63346016e-01,
         1.62313923e-01,  2.52380401e-01,  3.54742467e-01,
         2.54441142e-01,  3.10098678e-01, -4.91567403e-01,
         1.04021229e-01, -7.51338527e-02,  9.40553937e-03,
         3.99766982e-01,  5.40930510e-01,  4.25898194e-01,
         3.67761493e-01,  5.31354360e-02, -2.23669992e-03,
        -2.20276907e-01,  1.64474890e-01,  1.27393976e-01,
         2.63064891e-01,  1.54414624e-01,  1.12646714e-01,
         1.14221036e-01, -6.17824979e-02,  1.28953472e-01,
        -3.50852031e-03, -1.84472382e-01, -3.38763953e-03,
        -8.12527016e-02,  6.89775646e-02,  4.42664027e-01],
       [-1.69733956e-01, -4.14196461e-01,  1.41451523e-01,
         3.63612890e-01, -8.78919736e-02,  2.87821572e-02,
        -5.28471589e-01, -2.05947399e-01, -6.74051270e-02,
         8.84636194e-02,  1.60520330e-01, -9.77071524e-01,
        -1.33342743e-01,  3.13703716e-01,  8.14916044e-02,
        -3.25836688e-01, -3.82341981e-01, -4.56464104e-03,
        -6.72788739e-01, -9.21085596e-01, -6.95014894e-01,
        -3.43157381e-01,  6.98676631e-02,  2.21932709e-01,
        -8.23350132e-01,  1.57631308e-01, -8.13445687e-01,
        -4.92716163e-01, -2.50025481e-01,  5.42626604e-02,
         7.82778114e-03, -2.06303492e-01, -2.45351605e-02,
        -2.91783482e-01,  1.87007278e-01,  1.51308347e-02,
        -2.02827409e-01,  5.22340983e-02, -7.72842228e-01,
         7.04824738e-03,  4.45139021e-01,  2.00213194e-01],
       [ 2.98669845e-01, -6.37855470e-01, -7.01511204e-01,
        -4.15585428e-01, -1.36302173e-01,  5.26729934e-02,
         7.23233372e-02,  3.07565629e-01, -1.82161048e-01,
         1.52786642e-01, -3.48676741e-02, -1.31748393e-01,
         2.14390107e-03, -8.86664689e-02, -5.54025054e-01,
        -2.16751471e-01, -5.03904343e-01,  3.45673084e-01,
        -8.52949560e-01, -2.12343171e-01, -5.87975085e-02,
         1.86150074e-01, -2.53950618e-02,  4.57405895e-01,
         7.33779013e-01, -1.52743086e-01, -4.88545746e-01,
         3.62458140e-01,  2.47325152e-01, -2.41025567e-01,
         2.00199023e-01,  1.91244587e-01,  3.09051901e-01,
        -1.44390240e-01, -4.99136373e-02,  1.56411335e-01,
        -4.79136914e-01, -1.89248592e-01, -3.57341737e-01,
        -5.48977405e-02, -3.23419087e-02,  9.58560854e-02],
       [-3.89792532e-01, -2.33964905e-01,  1.45155683e-01,
        -5.54327965e-01,  4.42832038e-02, -2.44622484e-01,
         8.16054791e-02, -3.58485192e-01, -1.08245656e-01,
        -2.18228132e-01, -1.11991465e+00, -6.68954253e-02,
         7.69374073e-02,  1.58455938e-01,  4.26747687e-02,
         1.32984757e-01, -2.17443645e-01,  5.26722908e-01,
         9.38659087e-02, -1.43866166e-01, -4.06744063e-01,
        -2.77622491e-01,  2.31279135e-01,  2.25581512e-01,
         5.33883095e-01,  6.14227317e-02,  7.10135221e-01,
        -1.24519050e-01,  4.09555703e-01,  1.60045981e-01,
        -1.83734030e-01, -6.03972256e-01, -3.80465873e-02,
         9.88755077e-02, -2.23691478e-01,  1.25080636e-02,
         1.44406095e-01,  2.21848279e-01, -1.87861100e-01,
        -6.86921775e-02, -1.41739681e-01,  4.66457829e-02],
       [-3.78640115e-01,  1.08050987e-01, -5.40958047e-01,
         7.75209785e-01, -1.07448310e-01,  1.34204909e-01,
         5.11256993e-01,  2.25476727e-01,  5.72123885e-01,
        -2.64251769e-01,  6.86279595e-01, -2.88680624e-02,
         9.17395800e-02,  4.20255005e-01, -2.67111897e-01,
        -2.75805295e-01, -5.55323243e-01,  6.61699295e-01,
         8.96497518e-02, -9.21189412e-03,  6.67288387e-03,
        -6.58793271e-01, -2.12039053e-01,  9.07488823e-01,
         1.84992805e-01, -3.83379191e-01, -2.29671314e-01,
         1.14588305e-01,  1.22551203e-01, -1.42311566e-02,
        -2.52425764e-02,  4.06526774e-02, -4.15677696e-01,
         5.34212589e-01, -1.29569858e-01, -4.14223939e-01,
        -2.79498309e-01, -1.12368375e-01, -4.99056667e-01,
        -7.19705105e-01, -2.75926273e-02, -9.93086547e-02],
       [-2.44952515e-01,  7.28922188e-02,  2.27461562e-01,
         3.96574810e-02, -2.76858091e-01,  3.77833068e-01,
        -9.93472636e-02,  1.26231954e-01, -5.86996973e-01,
         2.10676745e-01,  3.14292796e-02,  3.76184247e-02,
        -1.48410633e-01, -2.09824920e-01, -1.34228900e-01,
         1.58913344e-01, -1.49613908e-02, -8.81292760e-01,
        -2.00484246e-02,  6.16384745e-01, -1.22206032e-01,
         2.29338273e-01,  4.14353669e-01, -3.94529253e-02,
         6.72061384e-01,  5.13994813e-01,  8.49928930e-02,
         2.31036872e-01, -1.28682088e-02, -1.08703375e-01,
        -7.89382532e-02, -2.67048538e-01,  3.00188303e-01,
         2.16360852e-01, -3.25496078e-01, -2.45637342e-01,
         3.07093821e-02,  1.34272411e-01,  7.07997799e-01,
        -3.64874341e-02, -8.26129377e-01,  1.25918090e-01],
       [-3.33393037e-01, -3.10936775e-02,  3.51040848e-02,
         3.61658841e-01, -8.28346796e-03, -5.18041886e-02,
        -1.65411443e-01, -4.01402771e-01,  8.79553705e-03,
        -1.54278591e-01, -7.41660669e-02,  1.64746165e-01,
         2.51467258e-01, -4.01612759e-01, -1.25137031e+00,
        -1.43311799e-01, -2.68530995e-01,  5.34594357e-01,
        -2.10958019e-01, -2.77067292e-02, -6.39054775e-02,
         4.09394979e-01, -1.28970910e-02, -3.89841765e-01,
         3.68597388e-01, -5.32677770e-02,  7.03851804e-02,
         6.64108753e-01,  3.66310388e-01,  1.15810689e-02,
        -4.28976193e-02, -2.89912939e-01,  1.85500085e-01,
         8.79573449e-02, -4.62540565e-03,  1.12099037e-01,
        -6.72584698e-02,  1.69514939e-01, -8.09972286e-02,
         2.47542232e-01, -5.52418292e-01,  1.59940138e-01],
       [-4.60827984e-02, -6.59124672e-01, -4.90285978e-02,
         1.48376644e-01, -2.59062611e-02, -1.73882872e-01,
        -1.89020172e-01,  7.61183649e-02,  1.99286848e-01,
        -2.69491881e-01, -1.96569741e-01, -8.02767351e-02,
        -3.25145386e-02, -4.65072691e-02,  1.24188505e-01,
        -1.51553679e+00, -3.12218279e-01,  3.76275808e-01,
         1.78544313e-01,  2.07724139e-01,  2.01797456e-01,
        -9.01734605e-02,  6.52791977e-01,  2.17213094e-01,
         3.12856495e-01, -1.64838005e-02, -4.04326431e-03,
         1.47825137e-01, -1.66052461e-01,  7.66406894e-01,
        -4.59973902e-01, -1.97448730e-01, -2.00053081e-01,
         4.22926247e-02, -2.01338783e-01, -3.16747501e-02,
         7.33764827e-01, -3.46042603e-01,  5.34235872e-02,
        -6.29862770e-02, -2.39246577e-01, -1.28994718e-01],
       [-7.62719987e-03, -3.49366695e-01, -4.97057527e-01,
        -1.99453384e-01, -2.64273942e-01,  3.78139794e-01,
         2.31677562e-01, -1.35659456e-01,  3.88595611e-01,
        -1.91318586e-01, -1.66626900e-01, -3.74592870e-01,
         1.83158144e-01,  4.02591050e-01,  9.26209614e-02,
        -1.31594718e-01,  4.00069505e-02,  8.52760494e-01,
        -9.11931843e-02, -4.87383962e-01, -3.96434188e-01,
         3.71541232e-01,  1.60169706e-01, -2.73625612e-01,
         9.06918347e-02, -2.14402765e-01, -1.40964404e-01,
         1.17036127e-01,  1.90339521e-01,  6.07579909e-02,
        -6.02886677e-01,  1.30314790e-02, -3.67620081e-01,
        -1.50839984e-03,  5.27209677e-02,  3.03639382e-01,
        -1.94683477e-01, -1.15578473e+00,  2.72140652e-01,
         2.34655991e-01,  8.07599574e-02, -6.30035177e-02],
       [-4.63763356e-01, -3.68089110e-01, -2.03049690e-01,
        -3.33926201e-01,  1.10531434e-01, -1.47245884e-01,
        -3.47489869e-04, -3.81766967e-02, -3.35889548e-01,
        -5.89653730e-01, -8.46410021e-02,  5.72501644e-02,
        -1.05364006e-02, -2.34640315e-01, -4.46156025e-01,
        -7.30277002e-02, -1.05303027e-01,  2.73093171e-02,
        -2.78312564e-01,  4.02840525e-01, -4.44236249e-01,
        -9.75540467e-03,  4.00324166e-01, -2.62452867e-02,
        -7.11403966e-01,  2.85900440e-02, -3.12487960e-01,
        -1.27427608e-01, -2.05782831e-01, -2.59975433e-01,
         5.94057329e-02, -9.10575390e-01, -3.70569110e-01,
         3.70662473e-02,  1.81416705e-01, -3.12780708e-01,
         9.06298384e-02,  1.85734823e-01, -6.58669248e-02,
        -3.25843900e-01, -3.14322114e-01,  1.04136467e-01],
       [-2.56016374e-01,  2.67071307e-01,  5.37945747e-01,
        -5.17816432e-02, -1.19369164e-01, -1.54769700e-02,
         1.66844249e-01, -1.20924450e-01,  8.41371492e-02,
         2.85850376e-01, -1.90616429e-01, -4.93015379e-01,
        -9.06948149e-02, -1.92853794e-01, -5.53265095e-01,
         4.79110777e-01, -8.47936422e-03,  3.67605127e-02,
         1.87355001e-02,  5.60952544e-01, -3.82816344e-01,
        -3.92852962e-01,  3.06151330e-01,  3.24647635e-01,
         1.49296448e-01, -2.36653835e-01, -2.14828640e-01,
        -2.59948343e-01,  4.57815938e-02, -4.69332859e-02,
        -5.03749512e-02,  1.26178865e-03,  1.39631912e-01,
        -5.29690742e-01, -4.37282883e-02,  2.11250067e-01,
        -7.04381540e-02, -1.18165538e-01, -7.96869025e-02,
         2.23025575e-01, -2.78105557e-01,  8.02648440e-02],
       [-2.95846134e-01,  5.97980171e-02, -2.44665027e-01,
        -2.56737620e-01, -2.07360283e-01, -4.08403367e-01,
        -1.73906997e-01, -5.30601759e-03, -9.17816311e-02,
        -3.58031839e-02, -1.00854114e-01, -3.28216076e-01,
        -3.97373624e-02,  4.00962919e-01,  3.38845663e-02,
        -4.56473865e-02, -4.27430272e-02, -3.91801119e-01,
         6.68664634e-01, -4.21427459e-01,  1.38775527e-01,
         1.08020641e-01,  3.21328074e-01, -2.16286406e-01,
        -1.22569942e+00, -1.03707492e+00, -4.40686733e-01,
         1.29103348e-01,  1.21896699e-01,  5.22516072e-02,
         1.10234819e-01,  2.66779065e-01, -1.54112801e-01,
         4.10966910e-02,  4.19390798e-01,  1.20399212e-02,
        -1.94244638e-01,  3.20064388e-02, -3.56406987e-01,
        -3.04562181e-01, -5.22601344e-02, -1.12269409e-01],
       [-2.02555388e-01,  4.77063954e-02, -1.53505564e-01,
         6.58629894e-01,  2.54440457e-01, -6.71396106e-02,
        -1.34296775e-01,  9.58399549e-02, -6.02274299e-01,
        -2.71617085e-01,  7.72659957e-01,  1.44225612e-01,
         1.71114519e-01,  2.08457425e-01, -3.74963105e-01,
        -6.37566805e-01,  4.57509756e-02,  4.57180500e-01,
        -2.24585444e-01,  4.60643798e-01,  1.94835171e-01,
         9.14152801e-01, -4.55400258e-01,  1.85933068e-01,
         2.43942276e-01, -7.38701046e-01,  3.90979767e-01,
        -2.72161156e-01, -6.67039910e-03, -5.01194656e-01,
        -2.69305483e-02, -3.59659314e-01, -2.71631330e-01,
        -1.40451804e-01, -2.15108052e-01, -2.34105870e-01,
         1.57777488e-01,  2.40262941e-01,  1.88342303e-01,
         6.91660494e-02, -2.51894206e-01,  2.57643878e-01],
       [ 1.04898317e-02, -1.75204486e-01,  1.12149343e-01,
        -2.46433884e-01, -4.07259047e-01,  1.13158301e-01,
         1.47465557e-01, -1.51410416e-01, -3.41737211e-01,
         5.54649949e-01, -3.44738424e-01, -4.36220258e-01,
        -2.29709148e-02,  3.34913701e-01,  8.36324543e-02,
        -1.40874013e-01,  1.18448913e-01,  2.90799607e-02,
        -9.38535016e-03,  9.62977782e-02,  2.06406504e-01,
        -6.96600020e-01,  1.26998469e-01, -2.65590578e-01,
        -4.46360596e-02,  3.27717245e-01, -3.94189924e-01,
        -6.87958896e-02, -7.41156340e-01, -1.16862081e-01,
        -4.67579335e-01,  1.95239827e-01, -3.06087900e-02,
        -2.07549836e-02,  2.79124320e-01, -4.23559189e-01,
        -1.23334920e-03, -4.08219397e-01,  7.58230984e-01,
        -2.69796878e-01, -1.00400066e+00, -5.12854680e-02],
       [-1.92334428e-01,  3.81326601e-02,  2.90094644e-01,
        -3.21277261e-01,  3.23549271e-01,  1.82420373e-01,
         2.90072262e-01, -8.99267420e-02, -8.87792706e-02,
        -1.71489958e-02, -1.24349140e-01,  1.81113817e-02,
        -4.95424211e-01,  1.99135542e-01,  5.22650871e-03,
         9.88543592e-03, -1.18963592e-01, -2.34393522e-01,
         9.44767371e-02, -8.87252837e-02, -1.27396882e-01,
        -1.72736719e-02, -4.27992344e-02,  9.37723089e-03,
        -1.70917034e-01,  7.21943736e-01, -2.13980389e+00,
        -1.40183205e-02,  8.80666375e-02,  2.17471644e-02,
         8.63776207e-02, -3.72131735e-01, -6.69863373e-02,
        -6.81379214e-02, -1.57865986e-01, -4.31150943e-02,
         1.16220474e-01,  1.34999752e-01, -5.90201244e-02,
         2.81558454e-01,  1.11539893e-01, -2.91390270e-01],
       [-5.15986800e-01,  3.51210505e-01,  2.90430576e-01,
         5.27633965e-01, -2.82472849e-01, -4.96510603e-02,
         1.26826510e-01, -7.63913572e-01,  8.50129128e-02,
        -4.38737646e-02, -3.78357381e-01,  1.47460960e-02,
        -2.36924216e-01, -6.97277337e-02,  2.09375665e-01,
        -1.23455217e-02,  6.88436776e-02,  9.10117701e-02,
         6.87468350e-01, -1.04778640e-01,  1.00373710e-02,
        -2.86710143e-01, -2.59368923e-02, -6.75414503e-01,
        -1.49901628e-01,  4.83791798e-01, -6.27188921e-01,
         1.21435799e-01, -1.06278956e-01, -5.36637843e-01,
        -3.79244775e-01,  2.58833077e-02,  8.16106275e-02,
         2.90151328e-01,  3.51915509e-01, -3.55918974e-01,
        -5.33578813e-01, -6.12565577e-01,  4.18691128e-01,
        -1.35851145e-01, -1.51356131e-01,  1.96332596e-02],
       [-3.55860263e-01, -3.89953256e-01,  3.96773875e-01,
         1.79967865e-01, -2.44763270e-01, -6.30982459e-01,
        -6.95299447e-01,  6.86152652e-02, -2.06012487e-01,
         1.65438458e-01, -1.27369329e-01, -3.30744088e-01,
         5.41837692e-01, -9.26088765e-02,  3.13107461e-01,
        -2.13208184e-01, -4.73654687e-01, -4.14729029e-01,
        -5.23829997e-01,  4.55213398e-01, -4.57516201e-02,
        -3.99863362e-01, -2.79005945e-01, -4.76833761e-01,
        -3.58363450e-01, -4.29701895e-01, -7.71729946e-01,
         7.28332549e-02,  2.16152534e-01,  9.54525620e-02,
         2.09511984e-02, -3.52879018e-01, -2.84947604e-01,
        -6.84835076e-01,  1.07669286e-01, -8.67438391e-02,
        -3.62440467e-01, -3.35335165e-01,  3.78990978e-01,
        -9.60452184e-02, -7.83868909e-01,  2.90161431e-01],
       [-6.94963932e-02,  3.14798146e-01,  4.13343348e-02,
         4.17076377e-03,  7.23078996e-02,  1.82050690e-01,
         3.01138490e-01, -3.03991526e-01,  7.82172084e-02,
         7.91382103e-04,  1.26303304e-02, -1.45094529e-01,
        -5.84080182e-02, -9.41634849e-02, -9.11382735e-02,
         1.70408022e-02,  1.04422063e-01, -7.58183599e-02,
         1.85358599e-01, -1.70471191e-01, -7.94162601e-02,
         4.13438201e-01, -2.78607279e-01, -4.45674628e-01,
        -8.79154056e-02, -1.42762680e-02, -1.98085040e-01,
        -2.61192322e-01, -2.12828238e-02,  1.08458340e-01,
        -2.54905134e-01, -1.82527807e-02, -7.88164288e-02,
         2.69122839e-01, -2.89086580e-01, -8.28331113e-01,
        -6.92421377e-01, -6.71614170e-01, -6.73479259e-01,
        -6.35787964e-01,  3.05616587e-01, -2.86610156e-01],
       [-1.07518554e+00, -7.16049492e-01, -2.31581986e-01,
         4.22302820e-02, -7.29458854e-02, -3.98700178e-01,
        -3.24917257e-01, -6.55696273e-01, -2.44639479e-02,
        -3.13871056e-01, -1.19245708e-01, -3.65079641e-01,
        -3.05212677e-01, -1.27797455e-01,  1.14169903e-01,
        -3.32098544e-01, -7.12701321e-01,  2.05374118e-02,
        -1.20160006e-01, -6.24310672e-01, -4.21571136e-01,
         1.08782709e-01, -9.81461909e-03, -7.63835430e-01,
        -4.08814222e-01, -2.58035213e-01,  2.51338005e-01,
        -5.10426462e-01, -3.62505734e-01, -9.73981738e-01,
        -1.48478031e-01, -8.14281642e-01, -2.56245911e-01,
        -3.32647003e-02, -1.23697527e-01,  3.04584891e-01,
         1.37012973e-02,  4.11261529e-01, -7.44831979e-01,
         1.14630468e-01,  5.83607435e-01,  1.20784335e-01],
       [ 7.12076724e-01,  4.12923783e-01, -5.57056144e-02,
        -5.77105522e-01, -1.06365811e-02, -2.63621900e-02,
        -4.69362617e-01, -1.26072630e-01,  3.86733919e-01,
         6.76232502e-02, -3.84882152e-01, -8.54796246e-02,
        -3.92591953e-01, -6.43148869e-02, -3.05251703e-02,
         1.74226433e-01, -1.04743451e-01,  1.11765213e-01,
        -1.43000968e-02, -1.83696955e-01, -7.26998299e-02,
         6.73769191e-02, -3.83997738e-01, -6.34421483e-02,
        -3.01799923e-01,  6.73741162e-01,  6.96680486e-01,
        -1.62698731e-01, -2.46635869e-01, -2.02161521e-01,
        -4.89764474e-02, -1.08612813e-01,  6.39417171e-02,
         3.50011960e-02, -1.49033099e-01, -4.42940965e-02,
         3.83848213e-02, -2.74025202e-01, -3.56565267e-01,
         3.88346523e-01,  2.28070736e-01, -2.53541935e-02],
       [ 5.30170873e-02, -1.91972643e-01,  8.71787667e-02,
        -2.01115429e-01, -5.76138556e-01, -6.30581602e-02,
        -4.14708909e-03, -3.57767105e-01,  1.39683848e-02,
         6.37467504e-02, -2.16250375e-01,  1.04305036e-01,
        -1.54891700e-01,  2.77985990e-01,  6.12079680e-01,
        -3.71484041e-01, -2.71267176e-01, -9.14737284e-01,
         1.63083538e-01, -6.81331679e-02,  3.52899015e-01,
        -7.85284936e-01, -9.52058360e-02,  2.49297991e-01,
        -1.19693184e+00, -8.59553292e-02, -6.81088686e-01,
         1.05739295e-01, -9.12643131e-03,  7.78271332e-02,
         1.31650493e-01,  5.15004341e-03,  1.66034415e-01,
         1.93513371e-02, -2.81887711e-03, -3.34028788e-02,
         1.94606818e-02,  3.09884250e-01,  1.72822818e-01,
         8.90751854e-02, -3.07716608e-01,  1.47937596e-01],
       [-8.17998171e-01, -2.33851388e-01,  1.93958253e-01,
         3.65891546e-01, -1.25184402e-01, -8.89666200e-01,
         1.77046403e-01, -2.69392401e-01, -1.93395570e-01,
        -2.33694538e-02,  1.85566232e-01, -2.59896982e-02,
        -2.11183965e-01,  3.64683270e-01, -5.28038144e-02,
         4.82746437e-02, -2.30783075e-01,  3.80016059e-01,
         2.55575716e-01, -3.58129382e-01,  1.69572175e-01,
        -5.76563954e-01, -3.85371819e-02, -6.01099730e-02,
        -3.50388348e-01, -1.43811870e+00, -2.71684498e-01,
         4.05103862e-01, -3.90046164e-02, -1.08744182e-01,
        -1.05580829e-01,  3.33942443e-01, -2.70673454e-01,
         1.00736283e-01, -7.21211880e-02, -1.08419091e-01,
         1.71975985e-01,  2.02107579e-01, -7.00950921e-02,
        -7.49908209e-01,  2.50585616e-01,  4.68864925e-02],
       [ 2.05596685e-01,  4.25687820e-01, -4.47273135e-01,
        -8.07588577e-01, -3.96371394e-01, -1.33300528e-01,
        -6.68206513e-01, -5.45144439e-01,  1.78786725e-01,
        -5.42529440e-03, -6.12013102e-01, -1.08717665e-01,
        -1.35594517e-01, -2.88419336e-01, -5.55077851e-01,
         2.16504335e-01, -3.37656327e-02,  1.74795195e-01,
        -2.63417840e-01, -9.58085060e-02,  3.66575010e-02,
        -7.66543090e-01, -2.86524832e-01, -1.07880667e-01,
        -2.75215991e-02, -8.68072569e-01, -8.69273067e-01,
        -5.42068601e-01,  2.89647728e-01,  4.64969337e-01,
        -6.54146433e-01,  3.47459912e-02, -2.82556564e-02,
        -2.53258020e-01,  1.30491599e-01,  8.61925185e-02,
         1.56359859e-02,  3.87689359e-02, -1.22479230e-01,
        -1.89913347e-01, -1.91651732e-01,  3.41374695e-01],
       [ 5.33076108e-01, -1.96883976e-01, -1.18717514e-01,
         3.40913475e-01, -1.37501553e-01,  2.07093507e-02,
        -4.74934399e-01, -1.19647488e-01,  4.00604874e-01,
        -5.63321233e-01,  2.21509740e-01, -3.95892203e-01,
         2.24892907e-02,  1.15880035e-01,  1.30522594e-01,
         4.30718571e-01,  8.57247934e-02,  1.88642561e-01,
        -3.52869511e-01, -4.11961764e-01,  6.14235215e-02,
        -6.51543140e-01, -1.20740920e-01, -7.54341409e-02,
        -2.96248645e-01,  5.80407798e-01, -6.48098171e-01,
         9.18570384e-02, -9.67436433e-02, -6.25687093e-02,
        -5.23897111e-01, -4.24917251e-01,  2.99889177e-01,
        -3.76336314e-02,  1.55257910e-01, -1.68536425e-01,
         2.07380146e-01,  9.52010900e-02, -7.51003265e-01,
         2.68065065e-01,  2.89850533e-01,  3.54867354e-02],
       [-8.86077642e-01, -8.25667441e-01, -3.78240913e-01,
        -9.44732353e-02,  5.87240875e-01,  8.02791789e-02,
         4.41332430e-01, -2.10515574e-01,  1.51234537e-01,
        -5.20686209e-01, -2.58681476e-01,  5.68859816e-01,
        -1.99534640e-01, -5.54031312e-01,  1.46251321e-01,
        -2.84677237e-01,  1.48340583e-01, -3.83852459e-02,
        -5.00198483e-01, -8.11354164e-03, -1.16619039e-02,
        -2.26061851e-01, -1.66279554e-01, -6.23271108e-01,
         2.52544761e-01, -3.68423074e-01, -4.13959801e-01,
         3.10188621e-01,  1.14956342e-01,  2.33434096e-01,
        -8.28761011e-02, -4.55356479e-01, -7.06894398e-01,
        -4.86056596e-01,  7.06378147e-02, -8.34690183e-02,
        -2.48032406e-01, -3.54636967e-01, -4.85870540e-01,
         4.74546045e-01,  1.26347184e-01,  5.70460856e-02],
       [ 3.96723092e-01, -2.15695992e-01, -1.79882571e-01,
        -2.50397354e-01,  1.26525462e-01,  1.24188073e-01,
         2.66162068e-01,  2.45498717e-01, -1.48441762e-01,
        -9.77870598e-02, -5.90823710e-01, -7.54084647e-01,
         8.93662125e-02,  1.01196505e-01,  3.48226249e-01,
        -3.28309417e-01, -7.81910270e-02,  5.41010499e-01,
        -1.83788455e+00, -1.21883892e-01,  3.06415677e-01,
         1.86928943e-01,  2.21692741e-01, -9.48903039e-02,
         5.86466976e-02, -9.79488790e-01, -8.08740333e-02,
         4.72949505e-01, -1.94638789e-01,  1.02595180e-01,
        -6.55180737e-02, -1.68513909e-01,  7.55565390e-02,
        -2.97018569e-02,  1.62848383e-01, -3.57564427e-02,
         1.86382324e-01, -3.95508111e-01, -3.13400239e-01,
         1.16651826e-01, -7.75555447e-02, -2.02697486e-01],
       [-7.51871049e-01, -4.47886258e-01, -2.09202886e-01,
         4.52423692e-01, -4.03747529e-01, -3.53006095e-01,
         2.05593348e-01, -3.85081679e-01, -5.77436924e-01,
        -3.07835937e-01,  5.57131648e-01, -2.76239336e-01,
        -4.46656317e-01,  2.13946193e-01, -3.19418728e-01,
        -3.03757697e-01, -3.43749702e-01,  4.75848794e-01,
        -2.29940578e-01, -6.22891903e-01,  2.65883774e-01,
        -1.17029436e-01, -1.62472725e-01, -1.82093477e+00,
         3.57559621e-01, -9.76553485e-02,  1.18494794e-01,
        -1.84728697e-01,  2.02762470e-01, -4.94026616e-02,
         3.71975079e-02, -1.67448953e-01, -5.20274490e-02,
         4.16961491e-01, -2.81386256e-01,  1.16742723e-01,
         1.14969350e-01,  1.27158523e-01,  1.75644591e-01,
         1.04434118e-01,  1.50825635e-01,  1.05857700e-01],
       [-4.77750361e-01, -1.68848008e-01, -2.32687786e-01,
        -1.13225542e-01,  6.34928467e-04, -1.36233464e-01,
         3.33444059e-01,  6.08957298e-02,  2.18563035e-01,
         2.95439929e-01, -2.33534649e-01, -1.56418607e-02,
         2.58973967e-02,  1.64903373e-01, -4.34836090e-01,
         1.05471276e-01, -4.60105650e-02, -2.49136955e-01,
         6.13584183e-02,  1.95898652e-01,  8.50555658e-01,
        -2.92290717e-01,  8.23367834e-02, -2.90105879e-01,
         1.37940168e-01, -1.53313100e-01,  2.89988488e-01,
         3.93282592e-01,  1.55075029e-01, -1.79416820e-01,
         6.67284662e-03, -2.40176931e-01, -1.50594056e-01,
         1.28542349e-01, -1.41277909e-01, -1.12459190e-01,
         5.48313893e-02, -1.99116811e-01, -1.34073449e-02,
        -2.95569208e-02,  4.07096595e-01, -1.92529827e-01],
       [ 1.34782881e-01, -6.88519329e-02,  9.83693525e-02,
         4.76451337e-01, -5.20552039e-01, -3.45618665e-01,
        -4.07845117e-02, -4.53468263e-02, -2.01606572e-01,
        -4.20515001e-01,  2.26587534e-01, -3.71172011e-01,
        -5.25887728e-01, -2.57348239e-01,  1.59523815e-01,
         7.20399693e-02, -3.07977170e-01, -1.81008071e-01,
        -2.53440708e-01,  3.09120774e-01, -5.38047543e-03,
         5.36895573e-01,  8.71948004e-02, -3.62187535e-01,
         2.44504437e-01, -5.79969883e-01, -4.49114770e-01,
        -4.03071910e-01,  2.34192044e-01, -7.09544122e-02,
        -3.41975898e-01,  3.77413034e-02, -8.38506892e-02,
        -1.44513026e-01,  9.92099494e-02,  1.68562606e-01,
        -8.70848894e-02, -5.14968157e-01, -1.72030404e-01,
         2.38090068e-01,  1.18050665e-01, -3.41236979e-01],
       [ 1.69254199e-01, -2.14725677e-02,  1.32730871e-01,
        -2.34704003e-01, -4.07390028e-01,  1.11911364e-01,
        -2.25176960e-01,  1.68254703e-01, -1.26909420e-01,
        -3.95602763e-01, -8.15887898e-02, -3.08930188e-01,
        -3.05313796e-01,  3.22863042e-01, -1.57121569e-01,
        -2.15742588e-01, -3.97740036e-01, -3.13502014e-01,
        -4.49174434e-01, -3.03235799e-01,  1.53301721e-02,
        -2.57613420e-01,  3.87504935e-01, -3.57124686e-01,
        -9.20665711e-02, -1.21340744e-01, -2.78263539e-01,
         5.11512995e-01,  2.47838691e-01, -3.29588689e-02,
        -3.98631573e-01,  2.88323671e-01,  7.02806422e-03,
        -3.42339188e-01, -5.95677011e-02, -9.94447544e-02,
        -5.56355774e-01, -7.40264803e-02, -2.86294222e-01,
        -5.72879612e-01, -1.71729922e-01,  2.83627868e-01],
       [-5.77842444e-02, -1.89588573e-02, -1.01111007e+00,
        -4.23359454e-01, -1.56389311e-01,  4.37651783e-01,
         6.67930953e-03, -2.77305961e-01, -2.11476013e-01,
        -1.67681947e-01, -3.13631892e-01, -4.23200816e-01,
         4.22327727e-01,  1.99774861e-01,  1.92904964e-01,
        -2.55860150e-01,  6.88354433e-01,  4.98695299e-02,
         4.90766913e-02,  7.86880031e-02,  4.77064736e-02,
         3.90163332e-01, -9.98612195e-02, -7.18601346e-01,
         4.24977064e-01, -2.18937576e-01, -7.34842643e-02,
         5.07772923e-01,  1.39981300e-01, -1.24748528e-01,
        -3.13656747e-01,  8.60299449e-03, -5.58379710e-01,
        -2.45144427e-01,  1.07325241e-01,  1.15346558e-01,
        -3.03285122e-02, -5.14880419e-01,  7.84152985e-01,
         2.16619730e-01, -1.03703871e-01, -1.10481761e-01],
       [-4.08704400e-01, -4.11341250e-01, -4.36653793e-01,
         1.27896994e-01, -2.88421631e-01, -3.53586495e-01,
        -5.19531667e-02, -2.21073672e-01, -9.10317481e-01,
        -1.01560199e+00,  3.17721635e-01,  1.66635215e-01,
         1.37082696e-01, -6.58799931e-02,  5.89146674e-01,
        -9.71215069e-02,  1.46071598e-01,  1.08211350e+00,
         1.51768088e-01, -3.36932158e-03,  2.10872203e-01,
        -7.83539712e-01, -8.27364698e-02, -3.51756126e-01,
        -1.67309597e-01, -1.26667094e+00,  2.75279731e-01,
         2.12339193e-01, -2.81169564e-02,  1.46690775e-02,
        -2.68037796e-01,  2.22399756e-01, -1.40650764e-01,
        -2.86983490e-01,  9.06253606e-03,  1.62858516e-01,
        -9.02069509e-02, -1.33074261e-02,  5.29193938e-01,
         9.18788388e-02, -3.80524509e-02,  3.30888443e-02],
       [-5.52265286e-01, -2.99903043e-02, -8.57834071e-02,
         8.80607739e-02, -2.97616512e-01, -3.16623151e-02,
        -5.13374150e-01, -1.98500365e-01, -1.31872475e-01,
         2.11409628e-01,  1.84528992e-01,  7.43538380e-01,
         2.87682474e-01, -6.05491281e-01, -9.52464808e-03,
        -4.74701554e-01,  3.69872987e-01,  5.11021733e-01,
         3.73560786e-01,  2.54757226e-01,  1.07817478e-01,
        -3.64124514e-02,  4.62563485e-02, -3.46020848e-01,
         2.74260044e-01, -7.04536065e-02, -1.48479268e-01,
        -8.80132377e-01,  2.07181692e-01,  1.69438198e-01,
        -1.92963034e-01,  6.04589283e-02,  5.91199473e-02,
         1.00583084e-01, -3.52644682e-01, -7.01784119e-02,
         2.10532650e-01, -7.85529539e-02,  8.91395062e-02,
         1.27174795e-01, -3.58706802e-01, -2.79393166e-01],
       [ 1.04489648e+00, -5.52920461e-01,  1.55864894e-01,
        -4.07562554e-01, -3.44520926e-01, -1.11379609e-01,
        -3.33019122e-02, -5.63595295e-01, -3.10054690e-01,
        -2.75838017e-01, -4.79824394e-01,  1.91392172e-02,
        -2.23787725e-01, -2.17235148e-01, -2.24831879e-01,
         4.75136846e-01,  6.90743998e-02,  3.98282915e-01,
         4.87258546e-02, -4.44646813e-02, -4.48982418e-02,
        -1.21723962e+00,  1.14880614e-01, -1.68928981e-01,
         4.05385524e-01,  1.81965947e-01, -2.58267164e-01,
         4.07443643e-01,  2.01731790e-02, -5.68308355e-03,
         1.30857691e-01,  2.97104329e-01,  6.88567534e-02,
        -6.82570264e-02,  9.68402326e-02, -6.83984682e-02,
         2.67241418e-01, -2.76867688e-01,  1.72894403e-01,
         1.34870084e-02,  1.39633477e-01,  1.92214549e-02],
       [-1.47122722e-02,  1.45581663e-01, -6.69982076e-01,
         5.74443378e-02, -1.19677854e+00, -5.86895049e-01,
         3.03145237e-02, -7.38548577e-01, -2.44992495e-01,
        -7.89239287e-01,  3.55775684e-01, -6.84882581e-01,
        -1.01859963e+00,  1.08715005e-01, -1.39803326e+00,
         2.37475127e-01, -1.85756147e+00, -1.54470410e-02,
        -6.21446729e-01, -7.36446440e-01, -7.21316159e-01,
         5.33077478e-01, -2.47954857e-02, -6.20069504e-02,
        -1.53050655e-02, -2.93090850e-01, -1.04741737e-01,
        -1.01620473e-01,  4.94759530e-02, -8.13104212e-02,
         2.27602065e-01, -6.52129352e-02,  1.95875376e-01,
         1.25307918e-01,  3.18488717e-01, -2.29849666e-02,
         2.56209344e-01,  3.32197338e-01, -4.50424477e-02,
        -1.51609883e-01,  1.98458180e-01,  2.20879227e-01],
       [ 1.61982179e-01, -2.52417505e-01,  2.21428871e-01,
        -2.69504100e-01,  1.18744969e-01, -5.94226122e-01,
         1.79593727e-01,  2.57620275e-01, -4.93875295e-01,
         2.51032948e-01, -2.69896179e-01, -5.39081655e-02,
         2.90253311e-02, -4.54120100e-01,  4.21117812e-01,
        -1.28063634e-01, -8.88452455e-02,  4.14920390e-01,
         2.43984303e-03,  3.65228385e-01,  3.99558902e-01,
         3.40759724e-01,  2.02343002e-01, -4.85661060e-01,
         3.23829859e-01,  2.37300172e-01, -6.48531675e-01,
        -1.18436441e-01, -5.15560135e-02, -4.76699471e-01,
        -1.76064074e-01,  2.09827289e-01,  1.31351784e-01,
        -9.17365789e-01,  2.28578269e-01,  7.77982026e-02,
         1.98346563e-02,  4.68404107e-02, -1.61530837e-01,
         9.09347013e-02, -2.93184698e-01, -9.92299095e-02],
       [-2.01210603e-01,  5.66942655e-02, -1.21061303e-01,
        -1.69290707e-01,  3.75052512e-01, -9.24927474e-04,
         3.58019203e-01, -2.57804126e-01,  5.10486126e-01,
        -2.49312073e-01, -3.27153534e-01,  2.81048328e-01,
        -2.87908494e-01,  1.16204500e-01, -1.64038792e-01,
         3.32156241e-01, -1.49325095e-02, -6.19990945e-01,
        -1.74932390e-01, -1.20024252e+00, -9.14769694e-02,
         9.89355221e-02,  3.62141907e-01, -6.94260955e-01,
         1.06850111e+00,  5.45808822e-02, -1.49941832e-01,
        -4.23871167e-02, -6.34383559e-02,  3.14264536e-01,
        -4.22099411e-01, -9.16400254e-02, -1.46143630e-01,
         5.18304817e-02, -2.19071999e-01, -4.75716777e-02,
         6.53678104e-02, -1.04983218e-01,  1.16361059e-01,
         3.29328328e-01, -5.48558636e-03, -7.17690647e-01],
       [-1.87453464e-01, -2.35027164e-01, -1.00374028e-01,
        -5.91292262e-01, -1.21285453e-01, -3.83317500e-01,
        -2.37633556e-01, -1.01602964e-01, -2.47561961e-01,
        -1.76000148e-01, -1.44875437e-01, -5.58088124e-01,
        -5.11817753e-01,  8.28817114e-02,  8.20353627e-03,
        -7.62068480e-02, -2.91511472e-02, -8.85052264e-01,
        -1.12018146e-01,  4.19597104e-02,  2.09370106e-01,
        -2.70331383e-01, -2.95560271e-01,  8.34467188e-02,
         8.41493011e-01, -3.69541019e-01,  2.30494440e-01,
         2.29468629e-01,  2.92822301e-01, -2.48442650e-01,
         4.32193354e-02,  4.02791709e-01, -4.96488661e-01,
        -3.91429037e-01, -1.38019994e-01, -7.96695277e-02,
         1.21146038e-01,  5.78607898e-03, -2.36049771e-01,
        -5.12734354e-01,  3.95370536e-02,  1.45799518e-01],
       [-1.30575532e-02, -1.89064860e-01, -4.38265264e-01,
        -1.39428973e-01, -1.56190053e-01, -2.47761086e-02,
        -3.17408517e-02, -9.43183228e-02,  5.14111593e-02,
        -2.07628356e-04, -1.64262250e-01, -1.60753042e-01,
        -7.36884400e-02, -2.29988679e-01, -5.09486437e-01,
        -6.05121404e-02, -7.30386376e-02, -2.25901008e-01,
         2.04500154e-01, -4.06624615e-01,  5.55287525e-02,
         2.06626192e-01,  1.17742412e-01, -6.25892580e-01,
        -1.69781816e+00,  1.66892171e-01,  3.41878265e-01,
         1.92219168e-01,  2.65916467e-01, -1.65680885e-01,
        -3.29122186e-01, -9.74720716e-02, -6.05508797e-02,
         2.71981210e-01, -2.49892354e-01,  6.64630949e-01,
         2.66527534e-01,  7.35552311e-02,  4.28614020e-02,
         3.42794299e-01,  3.19430888e-01, -2.90158927e-01],
       [ 1.28791466e-01,  3.80827934e-01,  1.06402442e-01,
        -5.05631447e-01, -3.25333886e-02,  1.74961731e-01,
        -6.20741129e-01,  2.35546604e-01,  1.09072536e-01,
         2.71838844e-01, -2.27240413e-01, -5.23052327e-02,
         5.93976602e-02, -1.20646007e-01, -2.01695532e-01,
         4.38797444e-01, -6.31014168e-01, -1.63134873e-01,
        -2.79804111e-01, -3.97844166e-01, -7.98982501e-01,
        -6.38964996e-02,  1.36725321e-01, -2.20589384e-01,
        -6.19977772e-01, -9.69237089e-02, -3.73775303e-01,
        -1.24724798e-01,  3.83338571e-01, -8.24564323e-02,
        -5.68653271e-02, -5.07751584e-01,  1.97568849e-01,
         1.84396118e-01,  3.12475771e-01,  1.38299510e-01,
        -2.14108061e-02, -2.44578093e-01, -1.53319821e-01,
        -6.16410971e-01,  2.75977105e-01,  5.22264004e-01],
       [-9.26441550e-01, -2.02089980e-01, -6.26125216e-01,
         1.55668899e-01, -5.93861580e-01, -6.51664972e-01,
         1.28918692e-01, -1.54503345e-01, -7.60435939e-01,
        -8.25068876e-02,  1.69842184e-01, -3.25497359e-01,
        -6.27755761e-01,  3.25974196e-01, -3.22786897e-01,
        -3.39382887e-01,  3.52276117e-01,  7.90687442e-01,
         9.01072398e-02, -4.05772895e-01,  3.54386047e-02,
         2.71858033e-02,  1.61140841e-02, -3.26701730e-01,
         2.54264772e-01,  2.67413706e-01, -5.36396541e-02,
        -4.52267043e-02, -1.52481303e-01, -2.81883121e-01,
        -6.50553644e-01,  2.46976450e-01, -1.18018044e-02,
         8.52109492e-02,  2.92070836e-01,  1.66589692e-01,
        -4.08729017e-02,  1.25396550e-01,  3.36177200e-01,
         1.40940785e-01,  3.14238034e-02,  5.74807264e-02],
       [-3.64301771e-01, -7.37225488e-02, -3.21370900e-01,
        -2.40283161e-02, -2.97233343e-01,  2.62128174e-01,
        -3.45036745e-01, -2.93710381e-01, -5.67078471e-01,
        -2.71146119e-01,  2.03941286e-01, -9.43721011e-02,
        -1.91417351e-01,  1.21423518e-02,  2.83060342e-01,
         3.13313156e-01, -3.66453752e-02,  7.85407901e-01,
        -2.50239763e-02, -9.18577090e-02,  2.66371876e-01,
         2.63994873e-01, -2.33709008e-01,  3.23208235e-02,
        -1.99164450e-01,  3.22406143e-02, -4.17301893e-01,
         3.45822275e-01,  2.96884537e-01, -3.35493982e-01,
         3.39365005e-02, -1.39969334e-01, -3.42634499e-01,
         2.31069162e-01, -9.41366479e-02,  1.43157318e-01,
        -3.99890803e-02,  9.47507843e-03, -1.25785060e-02,
        -8.78872052e-02,  1.39887944e-01,  1.15188295e-02],
       [-1.47782683e-01,  2.44723827e-01,  2.28188306e-01,
        -5.58816373e-01, -2.51331985e-01, -3.85588050e-01,
         4.87470590e-02,  5.69646619e-02,  1.80077791e-01,
         9.02948678e-02, -3.76342423e-02, -4.34103459e-01,
        -8.89299214e-02, -3.82590979e-01,  1.88622978e-02,
         1.69716209e-01, -5.36642611e-01,  2.23633960e-01,
        -2.07106695e-01, -1.21097609e-01, -5.01185894e-01,
         3.10475171e-01, -2.16079168e-02, -2.65139967e-01,
         4.79559213e-01, -5.73161803e-02, -1.02858871e-01,
        -1.63936153e-01, -2.87859172e-01, -5.78471422e-01,
        -8.28051660e-03, -4.76947159e-01,  1.17930375e-01,
         1.92000642e-01,  2.82551855e-01, -2.86028802e-01,
         9.02848691e-02,  4.77497905e-01, -4.89955582e-02,
         1.44721702e-01,  4.25312698e-01, -3.20114583e-01],
       [ 3.76370214e-02,  2.29734257e-02, -4.12176818e-01,
         3.22840512e-01,  1.68920383e-01,  2.66560733e-01,
         2.04734311e-01, -2.62620300e-01, -4.99394506e-01,
        -3.90524477e-01,  2.77421921e-01,  1.89324655e-02,
         2.35949069e-01, -6.70795441e-02,  2.06253678e-01,
        -9.49342251e-01, -1.61723106e-03,  3.75620812e-01,
         9.59456190e-02,  1.71673849e-01, -4.47778285e-01,
        -1.08814292e-01,  3.21496904e-01,  1.15934968e-01,
        -2.20536515e-02, -9.03653502e-01,  1.18153580e-01,
        -3.43858123e-01,  6.36183918e-02,  4.20796782e-01,
        -2.07457319e-01, -2.30156720e-01, -1.53694525e-01,
        -2.02639513e-02,  1.90101221e-01, -2.11402684e-01,
         4.66785133e-01, -6.23881146e-02,  1.58176929e-01,
         4.52811301e-01,  1.96217060e-01, -2.48436779e-01],
       [-2.86360204e-01, -5.19324243e-01, -6.67342395e-02,
        -1.93914264e-01, -7.43040740e-02,  1.61041636e-02,
         1.63337216e-01,  3.44198495e-01, -5.89727640e-01,
         5.80698550e-02, -2.98529327e-01, -5.28760180e-02,
        -3.69829684e-01,  2.02943921e-01,  1.33728147e-01,
        -8.66743267e-01,  2.17447132e-02, -5.38916409e-01,
         1.96423586e-02, -3.33132059e-03,  4.35338140e-01,
         4.51429486e-01,  3.79800797e-02, -4.19834554e-01,
         4.52728331e-01,  3.30134869e-01,  7.06253052e-02,
         5.43731511e-01, -2.00950950e-01, -2.04963505e-01,
        -1.65658481e-02, -5.23146689e-02,  1.01740159e-01,
         6.77172765e-02, -1.57596603e-01, -3.46345842e-01,
         3.26081216e-01,  9.98115316e-02,  3.63316685e-02,
        -4.09580395e-02,  1.69243708e-01,  2.11894900e-01],
       [-2.30755121e-01, -2.52841562e-01,  1.89079642e-01,
        -8.72893184e-02, -2.34107986e-01,  4.39643174e-01,
         2.32446715e-01, -1.59902826e-01, -3.93913329e-01,
        -4.04440284e-01,  1.99619249e-01, -8.55286643e-02,
         4.43353802e-01,  1.04697965e-01, -1.28204161e-02,
         6.09495997e-01, -6.06430531e-01,  8.20230186e-01,
        -6.15496840e-03, -2.59205192e-01, -9.56478640e-02,
         3.78015071e-01, -1.73303615e-02, -3.08767676e-01,
        -2.42951632e-01, -8.19576085e-02, -8.05191994e-01,
        -3.57471481e-02,  2.14138687e-01,  2.44367510e-01,
         1.01333834e-01,  3.73755336e-01, -4.24293652e-02,
         1.19053662e-01,  2.48009786e-01,  1.33751154e-01,
        -4.01464701e-01, -7.38572538e-01, -1.00440599e-01,
        -8.15000772e-01,  9.44284648e-02,  8.61251280e-02],
       [-8.15320667e-03,  1.87525108e-01,  6.42372891e-02,
         3.04585427e-01,  1.02561608e-01,  2.37177566e-01,
         4.34514344e-01,  5.65126479e-01,  1.27698304e-02,
         3.09807777e-01, -2.12304294e-02,  2.38049254e-01,
         1.91339776e-01,  2.32286766e-01,  5.01493037e-01,
         4.38070327e-01,  4.09001797e-01, -1.04072027e-01,
         8.77516791e-02,  2.33413383e-01,  5.26718497e-01,
        -5.87844141e-02, -1.18701467e-02,  1.11001454e-01,
         2.59850770e-01,  2.26573184e-01,  2.06999004e-01,
         6.05785362e-02,  3.18768114e-01, -6.85890913e-02,
        -1.32773951e-01,  4.48227644e-01,  1.71872601e-01,
         5.15400946e-01,  5.72095299e-03, -3.40104178e-02,
        -2.60636266e-02, -1.67453974e-01,  6.30336881e-01,
        -4.77875583e-02,  3.13294053e-01, -1.38483569e-02],
       [-1.44192502e-01, -3.07332426e-01, -6.21804297e-02,
        -3.85076195e-01,  3.92940104e-01, -1.01897679e-01,
         2.83809770e-02, -3.82817507e-01, -2.96333611e-01,
        -8.92418146e-01, -7.51619786e-02, -5.98219752e-01,
         3.19474757e-01,  2.68385887e-01, -4.39131856e-01,
        -1.98081642e-01, -1.01538479e+00, -1.46444634e-01,
        -9.49640393e-01,  2.51369923e-01, -1.42605394e-01,
        -3.85006458e-01, -2.68271357e-01,  9.26530212e-02,
        -4.37378913e-01, -5.79290045e-03, -2.18857989e-01,
        -2.51787961e-01, -1.06473863e-01,  4.24718589e-01,
        -3.15294415e-01, -4.10483658e-01, -1.79832935e-01,
        -2.76597202e-01,  5.18890798e-01, -7.03187287e-01,
        -3.53202112e-02,  3.01690459e-01, -3.45287561e-01,
        -2.10636165e-02, -1.87833309e-01,  8.22288170e-02],
       [-6.38244033e-01,  2.25625724e-01, -1.83616444e-01,
         4.99022871e-01, -2.48422936e-01, -2.35222325e-01,
        -1.67185426e-01, -6.00118935e-01,  5.95685206e-02,
         2.25389376e-02,  4.86654103e-01, -7.48402774e-02,
         2.70959903e-02, -6.62594378e-01, -5.00311136e-01,
         3.95034403e-01, -3.80096287e-01,  7.56282210e-01,
         9.97427031e-02,  2.55627215e-01,  2.55359933e-02,
        -1.13861077e-03,  2.68284470e-01, -1.80986654e-02,
        -8.35643947e-01, -3.63570273e-01,  4.72192951e-02,
        -5.38841933e-02, -5.28341472e-01,  3.14421773e-01,
        -1.70340404e-01,  3.68815400e-02, -7.11762965e-01,
        -6.38804734e-01, -3.54377955e-01,  2.68992007e-01,
         3.01097125e-01, -2.99404804e-02,  2.72481535e-02,
         5.55175915e-02,  3.65962476e-01,  2.94009715e-01],
       [-1.05709389e-01,  2.02792406e-01,  1.86051056e-01,
        -4.31786925e-01, -3.31143469e-01, -2.12195158e-01,
        -8.04159511e-03, -2.38885671e-01,  2.70948172e-01,
         3.86469156e-01, -3.22059870e-01, -1.65487863e-02,
        -3.20159405e-01,  4.44346741e-02,  3.06454897e-01,
        -4.51397419e-01, -1.01779282e-01, -2.72124708e-01,
        -1.52139634e-01,  5.79768717e-02,  4.12639827e-01,
        -6.30526721e-01, -9.84781459e-02, -2.70811524e-02,
        -1.51102543e+00, -4.34575118e-02,  1.16201565e-01,
         3.08676064e-01,  3.57526928e-01, -2.72693872e-01,
         2.00460643e-01, -2.23756552e-01,  2.02150151e-01,
         4.82299954e-01,  8.52806270e-02, -2.42419675e-01,
        -3.72432351e-01,  6.85751587e-02, -3.58120739e-01,
        -2.81083018e-01,  2.04997078e-01, -2.35343035e-02],
       [-1.20952502e-01,  5.95676079e-02, -2.16215551e-02,
        -3.85737121e-01,  3.15614161e-03, -2.68892258e-01,
        -7.85347167e-03, -5.26136607e-02,  4.19681966e-01,
        -3.23932499e-01, -6.09526157e-01,  2.54679501e-01,
        -6.01374544e-02,  8.25020224e-02,  4.91235331e-02,
         2.34415218e-01, -6.62359059e-01, -5.30553162e-01,
         4.44950134e-01,  2.76811182e-01,  4.42565084e-01,
         3.24911654e-01,  2.04300404e-01,  3.98026139e-01,
        -9.32989359e-01,  1.08616807e-01,  3.18838298e-01,
         2.30516776e-01,  1.08730271e-01,  6.66385400e-04,
        -1.85005978e-01, -4.58814204e-01,  1.28341280e-02,
        -4.52297144e-02,  1.88595474e-01,  2.55076051e-01,
        -1.94643721e-01, -2.94385433e-01,  1.55198544e-01,
        -5.06994464e-02,  1.22822128e-01, -1.89419165e-01],
       [ 2.65074015e-01, -4.84630466e-01, -2.26656973e-01,
         9.35386941e-02, -5.23740232e-01, -2.81961322e-01,
        -4.27281344e-03,  1.46579593e-01,  3.72186750e-02,
        -8.04277718e-01,  5.27080238e-01, -2.08400905e-01,
        -3.28620136e-01,  1.68390363e-01,  3.16752225e-01,
        -2.75039583e-01, -5.10336366e-03,  6.87863171e-01,
         7.41949558e-01, -5.14890432e-01,  1.11357689e-01,
        -5.66408694e-01, -2.41995364e-01, -1.14934340e-01,
         7.96310827e-02, -1.02120948e+00, -3.28480184e-01,
        -2.66852253e-03, -1.00369349e-01, -8.97289291e-02,
        -2.03858733e-01, -1.04094483e-01, -1.43365189e-01,
         1.19202219e-01,  8.66074488e-02,  6.06910605e-03,
        -3.00183088e-01, -1.56349912e-01,  7.63799474e-02,
        -6.70390427e-02, -2.63387896e-02, -4.69026342e-02],
       [ 1.76870629e-01, -4.29205179e-01,  1.11104421e-01,
        -3.90793711e-01, -3.42383534e-02, -9.46676135e-02,
         8.92244056e-02,  7.09499791e-02, -2.25914583e-01,
        -4.68308628e-01, -5.45375012e-02, -2.36057281e-01,
        -4.48841959e-01, -6.75596446e-02,  1.66801646e-01,
         1.49668768e-01, -5.64566534e-03,  1.74249306e-01,
        -8.38565767e-01, -2.43329883e-01, -1.76003546e-01,
         1.30473062e-01, -5.10722958e-02,  8.78248215e-02,
         2.91931480e-01, -2.70685226e-01, -7.12564766e-01,
         3.76967132e-01, -8.45624879e-02, -9.28788185e-02,
        -6.50973618e-02,  1.13036290e-01,  7.58291855e-02,
         4.13892537e-01,  3.86403263e-01,  1.46241888e-01,
        -3.40830863e-01,  1.19577110e-01,  2.87878990e-01,
        -5.10103822e-01,  1.56277075e-01, -2.55234063e-01],
       [-4.13019687e-01,  5.40787399e-01,  4.15754199e-01,
        -6.93299949e-01, -4.65881974e-02,  1.94187853e-02,
         2.83830203e-02, -1.68961406e-01,  5.11893809e-01,
        -3.32249850e-02,  4.99590099e-01, -2.87590116e-01,
        -3.47914249e-01,  1.71196550e-01,  1.79841340e-01,
         2.70459890e-01, -3.89445007e-01,  5.64040542e-01,
        -3.35720420e-01,  8.83450210e-02, -3.12318534e-01,
         9.04885009e-02,  5.16886897e-02, -4.30245548e-01,
        -6.89482927e-01,  1.25470921e-01, -1.72442906e-02,
        -3.10231239e-01,  8.04446936e-02, -7.27327093e-02,
        -6.35332882e-01,  1.84150726e-01, -4.95386332e-01,
        -8.45068842e-02,  8.38899314e-02,  3.08765471e-01,
        -3.23436409e-01, -2.52828121e-01, -1.11367337e-01,
        -4.10774909e-02,  3.44256788e-01, -8.91325921e-02],
       [ 1.38909519e-01, -6.43721297e-02,  2.53264695e-01,
        -1.76076904e-01, -1.75164714e-02, -2.35218331e-01,
        -8.16676468e-02,  3.19582075e-01, -1.14039011e-01,
         5.47084063e-02,  6.38452470e-02,  2.09014654e-01,
         3.79377663e-01,  2.26254612e-01,  1.41801015e-01,
         2.88280338e-01, -4.29424681e-02, -3.06836933e-01,
        -1.10533528e-01,  7.90754259e-02, -2.15930697e-02,
        -2.24926755e-01,  9.86438915e-02,  2.28230178e-01,
         3.77547860e-01,  3.19051117e-01,  7.90587902e-01,
         3.78791392e-02,  1.10259011e-01,  1.62494704e-01,
         5.95403850e-01,  1.02186287e-02,  1.94131762e-01,
         2.63247371e-01, -1.71901941e-01, -3.11889499e-01,
         2.06020191e-01,  3.73738468e-01, -1.01638891e-01,
         6.25267327e-02,  1.62417382e-01, -2.99534678e-01]])
    w2 = np.array([[ 5.05561769e-01, -4.19589460e-01, -1.97754651e-01,
        -3.68161619e-01, -5.42085350e-01,  1.50392726e-01,
         3.23362499e-01, -1.46464884e-01,  2.22756386e-01,
        -3.23920041e-01,  2.09208280e-01, -2.89499015e-01,
         4.11604673e-01, -1.24444880e-01, -9.31821764e-02,
         8.99106637e-02, -2.47024551e-01,  1.57284588e-02,
         1.06455144e-02,  5.99282049e-02,  1.14940271e-01,
        -3.85406092e-02, -1.45382538e-01,  6.83160067e-01,
         2.59189814e-01, -9.60766971e-02, -4.41341847e-01,
        -4.54354197e-01, -4.09847736e-01,  3.67033929e-01,
        -2.90331172e-05, -3.88723373e-01, -1.68887645e-01,
         2.07512736e-01,  3.75717252e-01,  3.09353352e-01,
        -1.30896777e-01,  2.15135917e-01,  1.42153189e-01,
        -1.19610444e-01, -8.57114196e-02, -1.15580209e-01,
         1.33945853e-01, -4.71624792e-01, -7.01631531e-02,
         1.08116850e-01,  3.18708643e-02,  1.64930463e-01,
        -5.66246092e-01,  1.74558327e-01,  9.12966058e-02,
         4.49605614e-01,  1.83061138e-01,  2.35013336e-01,
         2.58705746e-02,  9.67088435e-03, -5.28686643e-02,
         3.20870280e-01,  3.12830657e-01, -3.06112971e-02,
         4.48458135e-01, -4.16562021e-01, -2.11345226e-01,
        -3.68927605e-04],
       [ 2.43667245e-01, -3.63646001e-01, -4.33999926e-01,
        -1.83941081e-01,  4.51531895e-02, -8.55982602e-01,
        -2.20706686e-01,  3.12329292e-01,  5.88260591e-02,
         1.58928022e-01, -1.00912035e+00, -9.85095799e-02,
        -1.73914641e-01, -4.93565708e-01, -3.40424627e-01,
         3.96376431e-01,  3.55747223e-01,  1.89931802e-02,
        -3.82817234e-03,  2.02580884e-01, -1.90802261e-01,
         1.73859671e-01, -7.77953088e-01,  3.92744929e-01,
         7.87968040e-01, -1.00396085e+00,  3.06773514e-01,
         1.12659633e-01, -3.63346130e-01, -2.23455161e-01,
         4.75180566e-01, -6.48421764e-01,  3.15097004e-01,
        -7.80114114e-01,  2.43761882e-01,  6.31042123e-02,
        -1.33065462e-01, -3.86677414e-01,  3.90609115e-01,
         4.46356893e-01,  2.29577616e-01, -6.69354737e-01,
         3.79159808e-01, -9.74440277e-02,  2.25345016e-01,
         2.61783779e-01,  3.50459725e-01, -2.87058979e-01,
         2.40166530e-01, -1.35945737e-01,  4.48219955e-01,
        -1.30813703e-01, -3.81125659e-01,  1.59503445e-01,
        -1.42224163e-01, -1.32666707e-01, -8.02193522e-01,
         6.02660060e-01,  3.11869010e-02, -4.05376144e-02,
        -8.91887695e-02,  2.21173003e-01, -6.37803257e-01,
        -1.21779852e-01],
       [-2.02675566e-01, -1.73068885e-02,  4.73402947e-01,
         2.27594361e-01, -2.43738607e-01,  2.09253550e-01,
         1.99891448e-01, -6.97923228e-02, -7.21426234e-02,
        -4.63746309e-01,  3.68049532e-01,  1.02817267e-01,
        -1.08578429e-01, -1.66712195e-01,  1.76253930e-01,
         1.29415408e-01, -2.45636955e-01, -2.09606901e-01,
         1.19219542e-01,  2.32717857e-01,  9.93390009e-02,
        -2.24260271e-01, -1.26756012e-01,  8.60797465e-01,
         2.36960307e-01, -1.97549164e-01,  1.91020668e-01,
        -4.50791717e-01, -3.58650029e-01,  6.51783273e-02,
         2.68834252e-02, -3.05454582e-01,  2.15759665e-01,
         7.90599883e-02,  6.74872240e-03, -3.79101411e-02,
        -1.61880612e-01, -1.93713829e-01,  1.99933406e-02,
        -1.75783470e-01,  3.22465837e-01,  3.80083978e-01,
         3.44570637e-01, -1.69467270e-01, -1.73791066e-01,
         1.11612022e-01, -9.44637835e-01,  3.35749537e-01,
         2.07164451e-01,  3.25229555e-01,  1.58250272e-01,
        -4.65058209e-03,  7.17589319e-01, -3.38962346e-01,
         3.48396391e-01, -2.22471356e-01, -1.78656071e-01,
         5.13678908e-01,  9.31956396e-02, -9.92374588e-03,
         3.38697851e-01,  1.32353589e-01,  1.14932150e-01,
        -5.06788313e-01],
       [ 1.33722454e-01,  1.39606223e-02,  3.56746048e-01,
         3.74567062e-01, -5.51777899e-01,  3.35035473e-01,
         3.89365494e-01, -5.49760699e-01,  3.51065457e-01,
        -4.73439336e-01,  2.11399645e-01,  7.23641291e-02,
         2.67243773e-01, -7.38692880e-01,  4.06103045e-01,
        -5.21421909e-01,  1.36607260e-01, -1.90977886e-01,
         2.64859200e-01,  7.00938255e-02,  1.28615990e-01,
         5.82517445e-01,  3.18129271e-01, -1.10651898e+00,
         1.63990462e+00, -2.87379213e-02, -1.69030890e-01,
         8.57245326e-02, -6.30060792e-01, -2.90872782e-01,
         5.82176708e-02, -3.32451425e-02, -4.78306800e-01,
        -2.46474385e-01, -2.09222473e-02,  6.28214955e-01,
        -1.76283047e-01,  3.71144265e-01,  1.93491310e-01,
         3.88551593e-01, -4.20518994e-01,  4.40844148e-01,
        -3.79020683e-02, -5.36076009e-01,  3.16086292e-01,
        -3.64063352e-01, -7.68408656e-01, -9.95640755e-01,
        -1.98999956e-01,  1.36823729e-02,  2.31185213e-01,
        -9.39811915e-02,  3.27110708e-01, -1.82383075e-01,
        -1.49007514e-01,  6.11067414e-02, -3.85416329e-01,
         3.66887867e-01, -1.69127602e-02, -6.37245834e-01,
         6.40982449e-01,  2.38447301e-02,  3.45739834e-02,
        -2.90853173e-01],
       [-2.32204627e-02, -8.56540978e-01,  6.14270866e-01,
        -3.31946820e-01, -5.31503797e-01,  8.62775445e-02,
         2.23000541e-01,  3.62665981e-01,  1.35161862e-01,
        -2.84681827e-01,  1.83831602e-01,  3.34376007e-01,
         5.11387110e-01, -4.98924218e-02, -6.97877347e-01,
        -1.32939771e-01,  3.73002648e-01, -3.75336021e-01,
         6.45853758e-01,  1.62436113e-01, -4.97802757e-02,
        -4.51365024e-01, -3.19478244e-01,  1.29638106e-01,
         5.28156817e-01, -1.96787238e-01,  1.88440710e-01,
        -5.45847178e-01,  2.33430453e-02, -2.74500757e-01,
         2.87159920e-01, -1.79286644e-01,  2.05758855e-01,
        -2.68941164e-01,  1.86322957e-01,  2.81528205e-01,
         2.69168556e-01,  5.75911880e-01,  5.12086213e-01,
        -1.57078370e-01,  4.71345156e-01,  3.10353369e-01,
         3.54449689e-01, -1.75326675e-01, -3.67124714e-02,
        -5.11268258e-01, -4.26392645e-01, -2.97587931e-01,
         2.98577547e-01,  4.37478393e-01,  2.34543592e-01,
         7.96150193e-02,  6.56465590e-01, -9.95677635e-02,
         4.76057708e-01, -4.83414941e-02, -3.26672941e-01,
         2.26118818e-01,  6.49921373e-02, -1.35651261e-01,
         4.76079673e-01,  2.42470488e-01, -4.17710811e-01,
        -2.76235640e-01],
       [ 4.03874576e-01, -2.57787984e-02,  2.89697498e-01,
         7.72484168e-02, -5.53017110e-02, -9.89853963e-03,
         3.22524041e-01, -3.16526294e-01,  1.30987585e-01,
        -2.63446588e-02,  3.10923517e-01,  1.92883700e-01,
         4.04428035e-01, -2.79009700e-01, -4.31079984e-01,
         1.43548891e-01,  1.21312045e-01,  3.42646062e-01,
        -2.81545911e-02,  4.66071963e-01, -4.69127178e-01,
         3.68168652e-01,  1.72266856e-01, -8.59273911e-01,
         3.13731015e-01,  5.82077146e-01, -9.71608460e-02,
         1.10867754e-01, -3.14628690e-01, -5.12008965e-01,
        -1.06525391e-01, -4.60391343e-02, -3.23105156e-02,
         4.98923957e-01, -4.66372877e-01,  6.52379513e-01,
        -1.01859398e-01,  2.67566890e-01, -1.51369423e-01,
         7.96613097e-02,  1.93494976e-01,  3.93682927e-01,
         3.20189238e-01, -2.20297590e-01,  8.97371545e-02,
        -3.70835334e-01,  3.90214100e-02, -6.90960228e-01,
         8.20518613e-01, -3.25713009e-01,  3.65130961e-01,
        -2.10592180e-01, -3.39044452e-01, -4.09455746e-01,
        -4.03323770e-01, -1.03523508e-01, -6.59330606e-01,
         3.11164856e-01, -1.77100599e-01, -4.64465052e-01,
         2.24283442e-01, -4.51429307e-01,  2.22673088e-01,
        -1.14366941e-01],
       [ 6.78384066e-01, -1.23309739e-01,  3.67068201e-01,
        -6.58240199e-01, -6.86844945e-01, -4.11780417e-01,
         2.51919210e-01,  2.42641747e-01,  1.69721097e-01,
        -3.52867782e-01,  4.01759148e-01, -4.85687777e-02,
         3.05112064e-01,  9.12221849e-01, -5.63711762e-01,
        -3.82385179e-02,  4.46079761e-01,  2.44325623e-01,
         1.60919517e-01,  1.45110004e-02,  2.25945130e-01,
         3.81559193e-01,  2.49638066e-01,  3.28831404e-01,
         2.56101459e-01,  1.72409967e-01,  7.60997057e-01,
         8.03155065e-01,  6.90155244e-03, -4.23314646e-02,
         3.36364359e-01,  2.74839818e-01, -6.43115401e-01,
         3.79665848e-03,  2.79237181e-01,  4.45921570e-01,
        -1.93242893e-01,  8.85923624e-01,  8.88751633e-03,
        -4.63300556e-01,  1.74840167e-01,  2.01260373e-02,
        -1.74759347e-02,  3.07874888e-01,  4.02751654e-01,
        -1.34483119e-02, -3.04957181e-01, -8.36970985e-01,
        -4.19578135e-01,  2.26891443e-01,  1.06907278e-01,
        -5.94134152e-01,  2.98295915e-01, -2.88300961e-01,
         5.77606261e-01, -3.58362287e-01, -4.17447060e-01,
        -2.61825975e-02, -1.85668692e-01, -4.69975203e-01,
         5.40775001e-01,  8.99118036e-02,  2.09930465e-02,
        -5.84989250e-01],
       [ 4.27263379e-02,  1.10289723e-01,  2.72281975e-01,
        -1.76984400e-01, -2.75732595e-02,  3.32602829e-01,
        -1.73670843e-01, -4.42555815e-01,  2.89871097e-01,
        -2.10554093e-01, -1.17928728e-01, -1.26794785e-01,
         2.05629587e-01, -8.55325535e-02, -5.61727136e-02,
         1.48935705e-01,  1.13161348e-01, -2.69756854e-01,
         5.04492581e-01,  2.27185056e-01, -1.22219278e-02,
        -8.97520408e-02,  2.32075915e-01,  7.04650640e-01,
        -8.31278972e-03, -6.01396933e-02,  5.36830127e-01,
        -4.88171905e-01,  2.46621102e-01,  4.23305124e-01,
         1.82179391e-01, -3.42236489e-01, -1.53105810e-01,
        -1.60323121e-02,  4.31675911e-01, -1.48964211e-01,
        -2.77486518e-02,  1.78301409e-01,  6.30960986e-02,
        -2.52398282e-01,  1.81854323e-01,  1.77647546e-01,
         1.12845279e-01, -6.06587827e-01,  1.47809550e-01,
        -9.73656535e-01, -8.09085071e-01,  7.18765259e-01,
        -1.03606857e-01, -9.97757837e-02,  2.92512327e-01,
        -1.96465731e-01,  3.69200371e-02, -1.15154937e-01,
         7.33225405e-01, -7.69225135e-02, -4.77395833e-01,
        -3.45516428e-02,  2.93474495e-01, -1.55115752e-02,
         5.29726088e-01, -5.61658517e-02,  2.60606796e-01,
        -3.90488319e-02],
       [ 4.87803787e-01, -7.77697489e-02,  3.23775262e-01,
         1.31343171e-01, -1.31118998e-01, -2.36410350e-01,
        -1.96269248e-02,  2.21338630e-01, -1.00487210e-01,
        -1.33464903e-01, -3.31989169e-01, -7.09104612e-02,
         3.84356141e-01, -4.12060060e-02, -5.51728368e-01,
        -2.29250081e-02,  3.54629844e-01,  1.96548909e-01,
         2.68445343e-01,  5.16408801e-01, -4.41893488e-01,
        -5.41002415e-02, -5.95875621e-01,  2.34428093e-01,
         2.79684901e-01, -3.89218628e-01,  7.32018828e-01,
        -4.75097716e-01,  6.10825539e-01, -2.84861803e-01,
         6.23217165e-01, -4.22139227e-01, -2.60595202e-01,
        -2.04273269e-01,  1.23745635e-01,  2.45720193e-01,
         1.59062997e-01,  2.21993372e-01,  3.66881579e-01,
        -2.65201241e-01,  3.48166853e-01,  8.27267945e-01,
         2.10787088e-01, -3.18030328e-01,  4.45520788e-01,
        -7.03812987e-02, -3.46511602e-01, -1.14424795e-01,
         2.15531006e-01, -1.92263443e-02,  4.00398336e-02,
        -3.67444083e-02, -3.57660130e-02,  2.32465968e-01,
         5.30399859e-01, -7.73103908e-02, -6.77307695e-02,
         6.71134982e-03, -4.15238887e-02,  1.33920521e-01,
         5.31748950e-01,  5.20443201e-01, -4.76253778e-01,
        -2.55051076e-01],
       [ 2.49506965e-01, -6.29967332e-01,  4.47750717e-01,
         5.58588445e-01, -4.88109559e-01, -1.48175776e-01,
         3.92309159e-01, -2.07509678e-02,  1.04539864e-01,
        -3.84206086e-01,  3.92162174e-01,  2.52559692e-01,
         3.53353947e-01,  9.53912318e-01, -5.73724687e-01,
        -6.52275443e-01,  2.38260310e-02,  1.65035218e-01,
         7.80557334e-01,  7.61590376e-02, -5.69367051e-01,
        -2.90257647e-03, -5.25323153e-01,  5.08781187e-02,
         1.11131918e+00,  1.70105100e-01,  3.60430390e-01,
         4.72664595e-01,  9.12841707e-02, -5.73632658e-01,
         1.68987408e-01, -2.21201982e-02,  2.47938961e-01,
        -3.71507466e-01, -8.31618309e-02,  3.77918392e-01,
        -1.61067918e-02,  6.99562550e-01,  2.99913645e-01,
        -2.01376960e-01,  3.24921012e-01,  2.48487368e-01,
         1.54727533e-01,  1.74106792e-01,  4.37950432e-01,
        -5.26348174e-01, -7.60247648e-01, -6.34992063e-01,
         4.96277601e-01,  5.17545819e-01,  1.30969256e-01,
         4.16963845e-01, -1.17765432e-02,  1.56540841e-01,
         2.43231561e-03,  3.56620215e-02,  4.34830710e-02,
         1.27417654e-01, -1.55965924e-01, -2.12844893e-01,
         4.34547275e-01,  2.22013772e-01, -1.77929580e-01,
        -4.73796695e-01],
       [-6.35197312e-02,  2.67302454e-01,  4.04352635e-01,
        -1.39125869e-01, -1.46482921e+00, -2.23530188e-01,
         3.50502133e-01,  8.39289427e-02,  8.17202106e-02,
        -2.21418262e-01,  3.00917327e-01,  2.77992915e-02,
        -2.11930811e-01,  6.72351718e-02, -1.24025118e+00,
        -7.72612318e-02,  6.96989447e-02,  4.03979808e-01,
         2.75784612e-01,  9.22522247e-02, -1.26346457e+00,
         4.24006045e-01, -4.34234619e-01,  1.13905823e+00,
         4.73745555e-01, -9.64096487e-02,  1.00038096e-01,
         7.82990932e-01, -3.81073385e-01, -8.41071486e-01,
         3.37650478e-01,  2.75387257e-01,  2.16795783e-02,
         6.77572638e-02,  5.58617488e-02,  5.87627709e-01,
        -3.64323169e-01,  7.28373647e-01,  1.27493441e-01,
         5.41584313e-01,  3.55518252e-01,  3.39102387e-01,
         9.93510783e-02, -6.18675888e-01,  8.02305698e-01,
        -3.51379186e-01, -9.76704419e-01, -7.50676095e-01,
        -3.81566048e-01,  7.04892397e-01, -4.52321544e-02,
         7.50007033e-01,  3.60980213e-01,  8.66356418e-02,
         2.87063867e-01,  4.05470654e-02, -6.01454318e-01,
         2.03113407e-01, -6.79757595e-01, -4.17224467e-01,
         4.83233035e-01,  7.57125765e-02, -4.32700723e-01,
        -1.08550656e+00],
       [-1.94619581e-01, -4.00054693e-01,  8.87635499e-02,
        -6.29500508e-01, -2.25780770e-01,  4.96139526e-02,
         1.54710025e-01, -7.83514157e-02, -1.23644733e+00,
        -2.54548490e-01,  3.05747151e-01, -4.51796114e-01,
        -5.26197776e-02, -3.03866882e-02, -1.48370767e+00,
         2.08342507e-01,  4.65804577e-01,  5.33259392e-01,
         3.63298982e-01,  4.31287825e-01, -8.71450484e-01,
         5.21302223e-01,  1.89101890e-01,  1.75712794e-01,
         1.59689665e-01,  3.14738661e-01, -2.73871452e-01,
         3.57994586e-01, -6.77813828e-01, -6.20917439e-01,
         1.47297338e-01,  2.22424567e-01,  5.96033558e-02,
         7.83321932e-02, -8.01081285e-02,  1.74152002e-01,
         2.48385832e-01,  9.77260470e-01,  3.02244455e-01,
         2.00556498e-02,  2.89017767e-01, -1.28766835e-01,
         6.00722693e-02,  2.63079166e-01,  2.67228365e-01,
        -6.22211158e-01, -3.07708919e-01, -5.95563173e-01,
        -1.09931827e-01,  5.50552845e-01,  3.48579586e-01,
        -4.40678149e-01,  3.34900379e-01, -1.08037636e-01,
        -4.37639840e-02,  3.52347404e-01,  9.51940238e-01,
        -2.27732025e-02, -1.14225817e+00, -9.13000464e-01,
         3.14038873e-01, -8.46338421e-02, -3.87763590e-01,
        -6.99217394e-02],
       [ 8.08613747e-02, -2.32424423e-01,  2.40086004e-01,
         1.85956270e-01, -3.39842647e-01, -1.84918508e-01,
        -1.13728963e-01,  4.92164046e-01, -3.00210953e-01,
        -2.47137323e-01,  1.09655678e-01,  9.21470597e-02,
         8.27100426e-02,  1.99590206e-01, -8.35801601e-01,
        -3.13763767e-01,  2.17748340e-02,  9.06735808e-02,
        -1.86934486e-01,  1.60403416e-01, -1.84295475e-01,
         2.37360865e-01, -2.45715350e-01,  3.48032564e-01,
         2.75337826e-02, -5.73825419e-01,  6.77620232e-01,
        -2.84473985e-01,  3.58345926e-01, -6.43043160e-01,
         3.98971289e-01, -1.99926227e-01,  8.72304812e-02,
        -3.96684110e-01,  8.31807256e-02,  2.12445796e-01,
         5.73872067e-02,  7.32790232e-02,  1.02950409e-01,
        -6.01853251e-01,  6.52650654e-01,  1.62355542e-01,
         1.44608617e-01, -1.51092261e-01,  3.12645495e-01,
        -5.53332567e-01,  1.45819426e-01, -3.47068191e-01,
         1.31239057e-01,  1.20104440e-01,  2.35026646e-02,
         3.51128370e-01,  2.71513134e-01,  1.03834301e-01,
         2.19281137e-01, -7.73278475e-02, -5.91555178e-01,
         2.73210377e-01, -3.93631339e-01,  2.92519569e-01,
         4.11600739e-01,  4.59307283e-01, -3.98005962e-01,
        -6.44849777e-01],
       [-5.85604966e-01, -1.30057299e+00, -1.69971108e-01,
        -2.09224932e-02, -2.17224345e-01, -5.28009474e-01,
        -5.42084634e-01,  1.60756707e-01,  1.74486518e-01,
        -1.46606907e-01,  1.59416303e-01, -7.67199337e-01,
         2.11541027e-01,  4.47160035e-01,  2.86703289e-01,
         2.38906562e-01, -5.44271111e-01,  5.29059470e-01,
        -3.69924575e-01,  4.86698687e-01, -7.10291803e-01,
         8.59662116e-01,  2.81777650e-01, -3.17234039e-01,
         6.33817136e-01,  4.22185630e-01,  8.47220063e-01,
         1.05251409e-01,  2.01367050e-01, -3.28827947e-01,
        -2.71427542e-01,  4.11895066e-01,  1.23455018e-01,
         3.42143863e-01,  6.44870102e-01, -2.59569168e-01,
        -3.04596543e-01, -4.82470728e-02,  4.55834448e-01,
        -4.30961102e-01,  1.61794610e-02,  1.33621380e-01,
         3.22592407e-01, -6.47526145e-01, -9.17961061e-01,
         6.18998945e-01, -3.40981521e-02,  3.63808393e-01,
         3.52089137e-01, -4.24553193e-02, -3.72741334e-02,
        -1.69193983e-01, -9.06276643e-01, -3.35465759e-01,
         1.34041384e-01, -2.78992772e-01, -8.35656285e-01,
         5.38643658e-01, -9.44496453e-01, -6.38783304e-03,
        -2.18725652e-01,  1.36634871e-01,  1.14070557e-01,
         2.84376562e-01],
       [-3.09172869e-01,  9.51170325e-02, -7.94990480e-01,
        -9.21750963e-01, -2.94967085e-01, -1.90828726e-01,
        -1.96174160e-01, -7.60218322e-01,  3.43299091e-01,
        -3.87391329e-01, -1.16519287e-01, -2.61318296e-01,
        -3.38344090e-02, -7.12795019e-01, -1.40284657e+00,
        -1.82215169e-01,  6.09292090e-01,  1.51423682e-02,
        -4.08045977e-01, -8.90684307e-01,  3.45037609e-01,
        -6.80859536e-02, -1.30866006e-01, -8.29050466e-02,
        -1.16334572e-01,  1.01200140e+00, -6.57403171e-01,
        -4.58800703e-01, -4.87508267e-01,  5.92816055e-01,
         9.93694425e-01,  9.48666036e-01,  1.91915214e-01,
        -6.75333619e-01, -1.01664686e+00, -9.84686136e-01,
        -1.36906779e+00, -3.21149409e-01, -4.87157494e-01,
        -1.49280345e+00,  5.86909316e-02,  9.77100134e-02,
        -2.01150522e-01,  6.01644039e-01, -8.00679266e-01,
        -1.06237042e+00, -1.06691234e-01,  2.41890848e-01,
         8.76500249e-01, -8.93665571e-03, -1.63847193e-01,
         9.82657447e-02, -2.68089861e-01,  3.48018378e-01,
         3.39859933e-01, -2.34568059e-01,  1.51372284e-01,
         5.85479438e-01, -3.42650652e-01, -5.99094527e-03,
        -1.55975418e-02,  2.22795159e-01, -1.06543854e-01,
        -6.57784998e-01],
       [ 1.66956246e-01, -6.06121123e-01,  5.93605995e-01,
         7.82896578e-02, -5.04498184e-01, -8.37023780e-02,
        -5.19278273e-03,  2.76939332e-01, -1.14187613e-01,
        -2.00196914e-02,  2.88787514e-01,  1.40962318e-01,
         1.30537614e-01, -2.38671899e-01, -8.86036754e-01,
        -6.90311641e-02, -3.26358341e-02, -5.70095107e-02,
         3.37045550e-01,  6.35891974e-01, -4.09822404e-01,
         3.66956770e-01, -1.21782042e-01, -4.50573295e-01,
         4.59000319e-01, -3.29206102e-02,  3.16527069e-01,
         5.37817329e-02,  7.98475817e-02, -5.57357669e-01,
         3.02325785e-01, -1.73682064e-01, -1.68316469e-01,
        -7.00496078e-01,  2.86901712e-01,  4.27811682e-01,
         2.99690545e-01, -9.05878283e-03,  2.53710002e-01,
         2.41685182e-01,  2.44179189e-01,  3.86174947e-01,
        -7.96796288e-03,  1.43799603e-01, -2.95595437e-01,
        -6.58345640e-01,  3.16516496e-02, -3.67487222e-01,
         3.28832775e-01,  3.17467928e-01,  3.25744689e-01,
        -1.66363157e-02,  3.41902137e-01, -8.20826367e-02,
         1.97477669e-01,  8.38485919e-03, -5.48716605e-01,
         2.58460864e-02, -2.14414090e-01, -3.16383064e-01,
         4.62713420e-01,  7.05857754e-01, -5.61779857e-01,
        -7.00306952e-01],
       [ 1.18622780e-01, -6.25295639e-01,  4.56291676e-01,
         3.71443182e-01, -7.00311899e-01,  5.91621459e-01,
         2.04548851e-01, -7.33116195e-02,  1.93265781e-01,
        -3.79655540e-01,  5.96215352e-02, -2.29289159e-02,
         3.63528639e-01,  4.94547695e-01, -3.26905698e-01,
        -5.27118027e-01,  2.35704511e-01, -1.05429187e-01,
         2.93740064e-01,  2.62511104e-01, -2.42005333e-01,
         5.44705212e-01, -1.54364958e-01,  4.05881822e-01,
        -3.54599692e-02,  5.52866459e-01,  8.13762546e-01,
        -1.08511612e-01, -5.19480295e-02, -9.35980603e-02,
         2.09921494e-01,  6.69234172e-02,  3.45991671e-01,
         1.07905202e-01, -2.15336069e-01,  7.68259242e-02,
        -2.75832832e-01,  7.86192775e-01,  6.17664695e-01,
         5.23391187e-01,  1.75720021e-01,  2.77892798e-01,
        -1.00662142e-01,  8.32957104e-02,  2.70164341e-01,
         2.81926095e-01,  1.61908254e-01, -5.60394645e-01,
         2.81866133e-01,  3.28144655e-02,  3.11493576e-01,
         1.03621818e-01,  2.17606932e-01, -1.16315316e-02,
        -3.20464700e-01, -2.35342726e-01,  4.81084734e-01,
         6.44832850e-01,  1.17844708e-01, -3.75330538e-01,
         6.77461147e-01,  1.43664017e-01, -1.07247807e-01,
        -8.39433432e-01],
       [-7.19794452e-01, -2.38407522e-01, -5.49214780e-01,
        -7.07903564e-01, -5.62801957e-02,  9.70861688e-02,
        -2.94552654e-01, -4.12889302e-01, -7.18639791e-01,
        -2.18289852e-01, -1.88826665e-01, -2.01891840e-01,
         1.11474529e-01,  4.20256674e-01,  5.58552563e-01,
        -3.06651592e-01,  3.44443098e-02, -4.80433613e-01,
        -1.29944658e+00,  9.23327029e-01, -6.60464585e-01,
        -2.95812547e-01, -1.17771721e+00, -7.48419166e-01,
        -2.52914637e-01, -1.25165021e+00, -2.04560816e-01,
         4.69303668e-01,  4.89479512e-01,  2.79614896e-01,
        -5.47717392e-01, -5.20891964e-01,  1.76474422e-01,
        -3.19853425e-02, -6.15470231e-01, -4.22171615e-02,
         7.54572973e-02, -1.00089478e+00, -3.57199848e-01,
        -8.09887469e-01, -1.22726083e-01,  6.39307618e-01,
         1.90713450e-01,  5.45278907e-01,  2.32120588e-01,
        -1.03306107e-01,  1.31170839e-01, -2.04272896e-01,
        -2.31156498e-01,  1.32702515e-01, -4.48445618e-01,
         2.15439871e-01,  3.96622755e-02,  1.29816383e-01,
         2.87781488e-02,  4.22419123e-02,  4.66707408e-01,
        -2.77670383e-01, -2.43589640e-01,  1.84506103e-01,
         2.49641672e-01, -1.85741186e-01, -1.64016321e-01,
        -1.04951328e-02],
       [ 1.47201046e-01, -4.30399328e-01,  5.44970095e-01,
        -3.86476785e-01,  4.53680724e-01,  8.62677470e-02,
         3.35886121e-01, -2.43069008e-01, -4.82453465e-01,
        -1.15655415e-01,  1.83131341e-02,  2.66132921e-01,
         3.29932481e-01,  4.10197973e-01, -7.63715684e-01,
         1.89044215e-02,  2.71274503e-02,  2.39731684e-01,
        -8.93574208e-03, -4.14531291e-01, -8.50302398e-01,
         3.24470371e-01,  2.66351312e-01,  2.54904360e-01,
         7.25587010e-01, -3.61873001e-01,  3.15443099e-01,
         2.28628695e-01,  1.40112653e-01, -4.36347216e-01,
         7.66335577e-02,  2.00866267e-01, -9.01971638e-01,
        -1.81693390e-01,  3.68742436e-01, -8.00809190e-02,
        -5.60979941e-04,  2.29677379e-01,  1.59860387e-01,
         4.39283289e-02,  5.59183061e-01,  7.83524960e-02,
         7.28449970e-02, -1.14475000e+00,  3.62314641e-01,
        -9.78527129e-01, -6.88776433e-01, -1.34207761e+00,
        -6.17550135e-01,  6.26141727e-01,  5.18824935e-01,
        -7.26912320e-01,  1.37150392e-01,  2.59633958e-01,
         2.22680811e-02,  2.86874343e-02,  2.94129625e-02,
         1.79868698e-01, -1.23355031e+00, -4.31313694e-01,
         3.60574931e-01, -2.74531990e-01, -1.68722868e-01,
        -1.43530214e+00],
       [ 2.21352708e-02,  5.07507995e-02,  4.66581166e-01,
        -1.51823387e-01, -8.28002095e-01, -1.62914500e-01,
         5.17118752e-01, -4.16786343e-01,  3.74608189e-01,
        -1.19743004e-01,  1.92304343e-01,  1.52338162e-01,
         5.22483252e-02,  3.04102618e-02, -7.31215656e-01,
         1.77264959e-01,  3.54617983e-01, -2.84810811e-01,
         7.98191130e-02,  1.86479315e-01, -2.17622653e-01,
         1.91507980e-01, -2.46228456e-01,  3.32568616e-01,
         4.50470835e-01,  1.87989250e-01,  7.85249099e-02,
        -5.70731521e-01, -2.47652642e-02, -6.74043000e-01,
         1.61781739e-02,  1.18688695e-01, -9.44551677e-02,
        -2.96519339e-01,  2.65160322e-01,  1.99553207e-01,
         4.22486097e-01,  4.50250387e-01,  9.34098437e-02,
        -3.63552511e-01,  7.46687889e-01,  7.18258858e-01,
         1.52234957e-01, -7.09814131e-02,  3.21032144e-02,
        -2.92768896e-01, -5.93715012e-01, -2.31250331e-01,
         2.45009139e-01,  2.21739978e-01,  5.30134499e-01,
        -1.55178517e-01,  5.30901849e-01,  9.13842171e-02,
         1.51388600e-01, -5.08442447e-02, -2.15029027e-02,
         5.60786948e-02, -3.23506862e-01, -1.83238015e-02,
         5.70144475e-01,  1.34693980e-02, -3.69894892e-01,
        -3.92926961e-01],
       [-7.48611242e-02,  1.92334622e-01,  7.66356051e-01,
         6.46469414e-01,  3.77309412e-01,  3.98430467e-01,
        -2.28585228e-01,  3.30447137e-01, -7.36199319e-03,
        -3.88316125e-01, -1.47429153e-01, -9.92663875e-02,
        -5.34150600e-01,  1.30358589e+00, -2.74573743e-01,
        -4.47665043e-02, -7.66640455e-02, -3.32887650e-01,
         5.96229620e-02,  3.48585039e-01,  1.84562072e-01,
         2.58442074e-01,  2.66563267e-01,  2.40820408e-01,
        -1.57858336e+00, -2.35887244e-01, -4.74886820e-02,
         9.37270448e-02,  4.02700096e-01,  2.88294911e-01,
         1.84566602e-01, -3.55431922e-02, -4.74958986e-01,
         3.00799698e-01, -3.77274267e-02, -6.45275354e-01,
        -3.05432856e-01, -2.21513942e-01, -8.76854062e-01,
        -1.40756726e-01,  7.66366482e-01,  1.09413214e-01,
         1.27782568e-01, -7.96886146e-01, -4.12708014e-01,
        -1.97381243e-01,  7.55561471e-01, -2.99920499e-01,
        -2.24988520e-01, -4.38414700e-02, -2.41175741e-01,
         9.76673886e-03,  1.16479412e-01,  3.81540000e-01,
         4.60877642e-02, -6.50876164e-02, -3.74307513e-01,
         6.97490051e-02,  3.53961289e-01, -6.68767333e-01,
         4.16439354e-01, -1.17207475e-01, -5.11238992e-01,
         1.49077505e-01],
       [ 6.40670955e-01,  1.89721704e-01,  4.16290499e-02,
         2.85338730e-01,  5.31857386e-02, -5.77455282e-01,
        -1.69937741e-02, -4.84948725e-01,  1.73506573e-01,
        -3.11995316e-02, -2.70111978e-01, -8.11269565e-04,
         3.49810272e-01, -4.74812277e-02, -2.35893160e-01,
         1.60292357e-01,  1.05387308e-01,  4.48198356e-02,
         3.45088780e-01,  1.13020107e-01, -2.88911939e-01,
        -6.74804151e-02, -6.56357408e-01,  1.91318715e-04,
         2.57019103e-01, -1.27607003e-01,  2.29384884e-01,
        -5.83141863e-01,  1.74631312e-01,  1.09289519e-01,
        -8.76893848e-02, -4.60134238e-01, -2.84035116e-01,
        -1.23461559e-01,  3.20699275e-01, -1.35406956e-01,
         6.79306015e-02,  4.65339124e-01,  4.16337132e-01,
         6.39848351e-01, -1.06103480e-01,  1.83541074e-01,
         1.76068231e-01, -1.94553092e-01, -3.61912437e-02,
        -4.09035623e-01, -2.83350676e-01, -2.35160336e-01,
         2.25647256e-01,  2.35375047e-01, -3.08218915e-02,
         2.99233139e-01,  9.01237354e-02,  3.08313593e-02,
         4.39023495e-01, -2.34524935e-01, -1.46151826e-01,
        -9.38087702e-02, -4.01260331e-02,  6.08314127e-02,
         4.95756567e-02,  1.55225590e-01, -3.03717971e-01,
        -9.27150175e-02],
       [ 2.26213023e-01,  2.54149765e-01, -4.62940603e-01,
        -6.47436559e-01,  3.59787233e-02, -4.24712300e-01,
        -4.34217900e-01,  2.87387103e-01, -1.16914272e-01,
        -5.85311353e-02,  3.12331945e-01, -5.96841201e-02,
         2.38663241e-01,  1.63087338e-01, -1.73222870e-01,
         3.55841845e-01, -2.59610236e-01,  3.53503197e-01,
         6.22036219e-01, -2.16969684e-01,  8.48803446e-02,
         2.47782886e-01, -8.58017728e-02,  2.03869998e-01,
         2.10664719e-01, -1.15875053e+00, -1.54975787e-01,
        -2.15230420e-01,  7.00094551e-02, -2.32487813e-01,
        -3.22349906e-01,  4.27646488e-01, -2.18982235e-01,
         9.35790464e-02, -3.35085422e-01, -8.99845883e-02,
        -2.85246968e-01,  2.51244396e-01,  3.53271663e-01,
        -7.74470985e-01,  2.76049376e-02, -6.95380926e-01,
         4.26596701e-02,  3.31645191e-01, -2.55256861e-01,
         2.70157009e-01, -5.90650082e-01,  4.24413979e-01,
         7.03202784e-01, -8.97077397e-02, -8.16261247e-02,
         5.77746006e-03,  8.24576765e-02, -1.09090619e-01,
         3.69710512e-02, -5.42916238e-01, -3.17140907e-01,
        -3.21316242e-01,  1.43304303e-01, -2.07370117e-01,
        -3.70751828e-01,  1.24433771e-01, -5.76294065e-01,
        -2.72508532e-01],
       [ 6.07588530e-01,  2.35483497e-01,  3.73951077e-01,
        -2.72991657e-01, -6.53038144e-01, -2.21568719e-01,
         1.88309073e-01, -2.05049977e-01, -3.17080431e-02,
        -1.32945165e-01,  3.88683915e-01,  2.18027890e-01,
         7.01248050e-01,  4.01759088e-01, -8.83967936e-01,
        -4.74835336e-01,  2.07936913e-01,  9.40328613e-02,
         4.42744523e-01,  3.91451836e-01, -1.17822289e+00,
         1.52937651e-01,  4.03361395e-03,  1.18527365e+00,
         1.12054618e-02,  1.96150169e-01,  7.66885400e-01,
         3.59724671e-01,  2.89282709e-01, -1.07835245e+00,
         5.95428050e-01,  4.26961511e-01, -8.12029019e-02,
        -1.60578713e-02,  1.27919510e-01,  7.19633758e-01,
        -5.45909941e-01,  1.47308201e-01, -1.43091157e-01,
         2.40539357e-01,  5.90874374e-01,  2.20766619e-01,
        -3.71635407e-01, -1.54882208e-01,  5.32746851e-01,
        -5.49037576e-01, -5.47164202e-01, -5.30609429e-01,
        -2.53331810e-01,  1.24054587e+00,  4.90037119e-03,
         1.03051327e-01,  4.84227031e-01, -6.28266811e-01,
         7.29695082e-01, -1.76617056e-01, -3.93830955e-01,
         5.78767538e-01, -1.20088756e+00, -3.63751501e-01,
         3.90610874e-01,  1.78073198e-01,  5.49878366e-02,
        -1.19037712e+00],
       [-7.66203180e-02, -5.32929301e-01, -8.92763853e-01,
        -1.40525711e+00, -6.99806869e-01, -2.87640125e-01,
         5.43599389e-02, -9.47297037e-01, -4.80696708e-01,
         2.70253897e-01, -2.85821527e-01,  4.15079087e-01,
        -9.16875720e-01, -1.61862707e+00,  7.13753104e-01,
         2.30382785e-01, -2.37906929e-02, -4.00151312e-01,
        -4.09888253e-02,  3.44349369e-02, -6.25315309e-01,
        -9.49704647e-01, -8.93458128e-01, -8.39343786e-01,
        -1.47216678e+00, -2.68006269e-02, -6.33049846e-01,
        -6.96959198e-02, -1.16203249e+00, -4.76556748e-01,
         1.83908910e-01,  3.76592129e-01, -1.12140346e+00,
         7.59201497e-02, -2.12771133e-01,  2.21120253e-01,
         4.27175254e-01, -3.05941641e-01, -1.18707396e-01,
         3.78516555e-01, -3.65888923e-01, -6.44816995e-01,
         6.29275143e-01, -6.91486061e-01, -1.01682997e+00,
         8.16028595e-01,  6.75168157e-01, -1.05847597e+00,
        -5.93713403e-01, -3.05571586e-01, -1.77394375e-01,
        -8.99127781e-01, -1.07428348e+00,  4.81820107e-01,
        -1.43945563e+00,  2.83994913e-01, -4.19160128e-01,
        -6.73687816e-01, -7.23132730e-01, -1.04407763e+00,
        -1.80151492e-01,  1.73673078e-01, -1.24200344e+00,
        -7.48016596e-01],
       [-3.87453198e-01,  3.20962608e-01, -6.07106864e-01,
        -5.53925941e-03,  3.17983836e-01,  4.13731098e-01,
        -5.78126498e-02,  4.12556350e-01, -2.76252598e-01,
        -1.05244093e-01, -5.44628203e-01, -6.93713278e-02,
         4.96836722e-01, -5.78306615e-01,  4.45489764e-01,
         3.45602542e-01, -3.46476346e-01,  3.15978238e-03,
         9.56170857e-02,  1.14066914e-01, -3.22869509e-01,
        -1.07165679e-01, -8.70855510e-01, -6.58565283e-01,
         6.28264904e-01,  1.81787312e-01,  3.07126671e-01,
        -6.44876242e-01, -5.45924485e-01,  1.90960839e-01,
        -1.26545027e-01, -1.33939266e+00, -3.08695287e-01,
        -1.84568197e-01, -1.12491682e-01, -1.82487041e-01,
        -1.79664761e-01, -7.46182024e-01, -6.14062786e-01,
         3.18832368e-01, -2.25723580e-01,  3.19384336e-02,
         2.18137890e-01,  4.62641716e-01, -1.27874947e+00,
        -8.46541643e-01,  2.11719006e-01, -4.13072035e-02,
         7.10659474e-02,  7.40996227e-02, -2.91948766e-01,
         4.51687366e-01, -8.54875565e-01, -3.27694684e-01,
        -5.49487829e-01, -6.52331173e-01,  5.87277591e-01,
         1.83641329e-01, -1.51801467e-01, -9.99886841e-02,
        -1.22498369e+00,  4.53674167e-01, -2.08666563e-01,
         3.36594805e-02],
       [-3.42300862e-01,  1.12580555e-03, -1.58222079e+00,
        -9.31071758e-01,  3.01110655e-01, -5.90955615e-01,
        -9.06644285e-01, -1.38918865e+00,  5.83746992e-02,
         4.15896177e-02, -1.09521389e+00, -3.10446024e-01,
        -2.38689452e-01, -3.85133564e-01, -1.80593565e-01,
        -2.44189560e-01,  1.28807461e+00, -6.74893185e-02,
        -4.34779912e-01, -1.98561385e-01, -3.57765883e-01,
        -5.60298145e-01, -1.31017312e-01, -6.69740736e-02,
        -8.63002658e-01, -2.49471620e-01, -8.27848136e-01,
        -5.76246679e-01, -2.41767317e-01, -1.75093278e-01,
        -1.90803528e-01, -4.56112325e-01, -4.96675596e-02,
        -8.91767204e-01,  1.56433135e-03, -8.26931000e-02,
        -2.77839631e-01, -9.50858235e-01, -5.39992929e-01,
        -2.96864808e-01, -3.15244168e-01, -4.77497041e-01,
         2.51321793e-01, -9.35466468e-01, -3.06920856e-01,
        -6.56954348e-02,  3.28838438e-01, -7.78664351e-02,
        -3.26208979e-01, -6.06834032e-02, -7.84094036e-01,
        -9.12827611e-01,  7.42645040e-02,  3.33933443e-01,
        -4.02852595e-01, -3.70000392e-01, -5.31137884e-01,
        -2.76367873e-01, -4.60138232e-01, -3.67791355e-01,
        -1.46681166e+00,  4.89290282e-02, -6.41672194e-01,
         1.31565228e-03],
       [-1.22940429e-02, -1.23496905e-01, -2.92668432e-01,
        -5.60545862e-01, -1.57768279e-01, -4.42943841e-01,
         7.14625567e-02, -1.17726317e-02, -2.49264136e-01,
        -2.65653849e-01, -8.13943565e-01,  2.92183429e-01,
         4.36223418e-01,  8.75283927e-02, -4.39249694e-01,
         1.07161738e-02,  1.40169516e-01,  4.51101184e-01,
        -8.76709580e-01,  1.38081223e-01,  1.81166660e-02,
         5.69118083e-01, -1.06994247e+00, -1.47182390e-01,
         4.42761332e-01, -2.71901667e-01, -6.94080532e-01,
        -5.44381738e-01,  2.80728757e-01, -2.72178978e-01,
         3.29928547e-01, -1.86099783e-01,  2.22719684e-01,
        -9.50785160e-01,  2.95970231e-01, -2.30329648e-01,
        -5.11924364e-02,  2.39324272e-01, -3.89303088e-01,
         3.86027277e-01,  2.44737774e-01,  9.43626016e-02,
         3.24435323e-01,  2.99510986e-01, -4.45528366e-02,
        -4.45203096e-01, -7.03956246e-01, -2.49557674e-01,
         2.03406572e-01,  2.18409762e-01, -4.45051827e-02,
        -3.92150968e-01,  6.94868043e-02,  6.10393919e-02,
         9.47706580e-01,  6.72496036e-02, -2.34777018e-01,
        -3.63471955e-01,  7.65414536e-02, -1.45165950e-01,
         3.12225968e-01,  2.09874988e-01, -3.19872797e-01,
         5.18311918e-01],
       [-1.28305644e-01,  1.48976117e-01, -6.96524739e-01,
        -1.62517071e+00,  1.85763836e-01, -4.92910504e-01,
         1.49805725e-01,  2.38598913e-01,  2.31388882e-01,
        -1.15888916e-01, -1.40621945e-01,  1.10870488e-01,
        -8.32075894e-01, -4.80711870e-02,  1.87897190e-01,
        -3.48898053e-01, -6.62834346e-02,  5.30574858e-01,
        -9.83104825e-01,  2.54957452e-02,  5.81090264e-02,
        -1.79372638e-01, -2.51516700e-01, -2.03458399e-01,
        -7.58094341e-02, -4.92203563e-01, -5.65939069e-01,
        -2.62960583e-01, -3.22969854e-02, -3.71328384e-01,
         4.65428561e-01, -8.81905556e-01,  1.36702862e-02,
         2.80392259e-01, -5.18610001e-01, -3.07317853e-01,
        -1.51182294e-01,  4.51141782e-02,  2.54967719e-01,
         2.75153458e-01, -7.42696166e-01, -5.26314735e-01,
        -3.46408755e-01,  3.09501320e-01, -6.07286751e-01,
         2.05702752e-01,  3.70437652e-01, -1.38389328e-02,
         6.76896930e-01, -1.41885400e-01,  2.54360437e-01,
        -1.33459225e-01, -2.67446160e-01, -1.71320841e-01,
         2.73104757e-01, -3.98269564e-01,  3.28427553e-01,
        -2.54834712e-01,  5.49795330e-02, -1.55147865e-01,
        -9.79265153e-01,  8.21368024e-02,  2.81013459e-01,
         5.12266159e-02],
       [ 6.66083097e-02,  3.72781783e-01,  4.53087509e-01,
         5.69515944e-01,  2.02314079e-01, -1.32949024e-01,
         2.66108900e-01,  2.35802501e-01, -1.62796378e-01,
        -3.80503714e-01,  8.95698726e-01,  7.94508457e-02,
        -2.46302083e-01,  4.06436622e-01,  4.01285738e-01,
         1.00562185e-01,  4.69074577e-01, -3.31163734e-01,
         3.26815099e-01,  3.56807172e-01, -4.59624976e-01,
        -1.91274583e-01, -1.16343684e-01,  4.65871692e-01,
        -1.06635280e-02, -1.34479225e-01,  1.70103647e-02,
         2.23640114e-01,  1.28490642e-01, -7.59815425e-02,
         1.79659992e-01, -4.98350382e-01,  3.62369895e-01,
        -5.18210642e-02,  2.65117913e-01, -3.50521132e-02,
        -2.91324735e-01, -7.88938701e-01,  3.33871126e-01,
        -4.16642666e-01,  3.60919744e-01,  5.72746336e-01,
         1.81468710e-01,  2.67581820e-01,  1.76166184e-02,
         7.41933882e-02,  5.83960712e-01, -2.60635674e-01,
        -1.27420858e-01, -5.90565443e-01, -3.56409311e-01,
         3.46869379e-01, -1.91258848e-01, -4.89939488e-02,
         2.39887998e-01, -8.88667405e-01,  7.29937851e-02,
        -4.20445502e-01, -7.13221878e-02, -3.63038391e-01,
         1.42557025e-01,  6.21985435e-01,  1.00174755e-01,
        -1.10181653e+00],
       [ 2.13936597e-01, -5.47141545e-02, -5.92972815e-01,
         2.75055438e-01, -3.63942116e-01, -8.21948946e-01,
        -1.73336446e-01,  4.97553311e-02,  1.80168435e-01,
        -3.33792657e-01, -4.43507344e-01, -7.19502270e-02,
        -8.67534354e-02, -1.42639101e-01,  3.13954651e-02,
         5.74095249e-01, -9.19677168e-02, -1.86558336e-01,
        -4.97323334e-01, -6.46762908e-01,  5.72651029e-02,
         3.43173534e-01, -5.11883087e-02,  1.14001729e-01,
        -1.08104706e+00,  1.77880511e-01, -8.01245570e-01,
        -7.21195579e-01,  9.41801667e-02,  9.70011950e-02,
         2.21046969e-01, -3.69060963e-01, -1.37912363e-01,
         1.30955614e-02, -2.36648880e-02, -5.89279592e-01,
         1.85925692e-01,  3.34643662e-01,  8.94085288e-01,
         4.61749621e-02, -5.35310686e-01,  1.14044569e-01,
        -1.20529041e-01,  3.93837631e-01, -2.02092186e-01,
        -6.91909567e-02, -1.97333680e-03,  2.20797330e-01,
         3.23825508e-01,  3.04698914e-01,  3.26905340e-01,
        -5.93264699e-01,  2.03869082e-02,  2.67169148e-01,
        -2.01882973e-01, -3.86704206e-02, -3.92309129e-01,
         2.41107792e-01, -9.91772674e-03,  4.21093181e-02,
         6.04878590e-02,  1.05760396e-01,  3.66234243e-01,
         1.96979880e-01],
       [ 2.45353132e-01,  1.86756462e-01,  3.53859335e-01,
         1.38394475e-01,  3.67856794e-03,  5.02045304e-02,
         3.47281992e-01,  1.49650902e-01, -1.04431354e-01,
         2.75302641e-02, -1.74896106e-01, -1.32106155e-01,
         6.02499008e-01, -3.40251118e-01, -4.37468648e-01,
        -1.68851376e-01,  4.24156994e-01,  9.82916206e-02,
         7.00009763e-02,  6.30851209e-01, -3.53293866e-01,
         2.13505119e-01, -5.39079070e-01,  6.07636049e-02,
         4.77781266e-01, -2.79085606e-01,  1.61761269e-01,
        -5.08413315e-01,  4.00892735e-01, -5.60093939e-01,
         4.07331705e-01, -8.99933577e-02, -2.52601713e-01,
        -2.36290276e-01,  3.93247098e-01, -3.81464437e-02,
         3.38940233e-01,  1.85625643e-01,  4.58837509e-01,
         9.94152725e-02,  5.88810742e-01,  9.36435997e-01,
         3.78089219e-01, -3.30561131e-01,  4.37514752e-01,
        -3.11938345e-01, -3.35947186e-01, -2.18472302e-01,
         3.21500629e-01, -5.02378829e-02,  2.87645400e-01,
        -1.77825272e-01,  3.43256354e-01,  3.70404124e-01,
         7.03183413e-01,  2.23735914e-01, -3.11065912e-01,
         1.28626555e-01, -6.88738003e-02, -1.04953028e-01,
         4.42686915e-01,  4.42751527e-01, -3.32922518e-01,
        -1.41163602e-01],
       [ 3.13287564e-02, -1.71312869e-01,  1.15167163e-01,
        -5.98034382e-01, -1.80573180e-01, -3.78761590e-01,
        -1.43840238e-01,  4.74375367e-01,  3.21447551e-01,
        -7.00218260e-01, -6.99178800e-02,  3.25967699e-01,
        -6.06566444e-02, -6.34315193e-01, -6.19769514e-01,
        -5.90837121e-01, -4.22154993e-01,  2.87881523e-01,
         4.90498155e-01, -3.17791015e-01,  7.42251147e-03,
         2.46844012e-02,  1.93889931e-01,  6.28116667e-01,
        -1.64943516e-01,  8.08818936e-01,  7.74738658e-03,
         2.33135596e-01,  2.57172853e-01, -2.38142386e-01,
        -2.26027355e-01, -1.22285755e-02, -5.37549496e-01,
        -3.46573368e-02,  2.82498691e-02,  2.42338493e-01,
         2.06034869e-01,  4.28221345e-01,  3.60423207e-01,
        -1.27083346e-01, -5.31107187e-01, -1.50214005e+00,
        -1.85749844e-01,  5.12549043e-01,  5.81518048e-03,
        -5.84894538e-01,  7.39349484e-01, -1.45306945e+00,
        -1.10949710e-01, -5.19678831e-01,  2.69661486e-01,
         1.66720048e-01,  2.97281891e-01, -2.01052114e-01,
         5.50717711e-01, -4.80715215e-01,  7.67243467e-03,
        -6.54530406e-01,  3.10639322e-01,  2.12189049e-01,
        -5.62021434e-02, -4.32101279e-01,  1.62477687e-01,
         3.16395044e-01],
       [ 2.04115301e-01, -2.82591879e-01, -1.19518094e-01,
         3.09263021e-01,  9.11282077e-02, -6.70400977e-01,
         1.30808532e-01,  3.68318222e-02, -2.36463472e-01,
        -1.66035980e-01,  6.93395197e-01,  9.15326849e-02,
         5.08667707e-01, -1.15077384e-01, -6.69259667e-01,
         2.15012431e-02, -4.62716997e-01, -7.29670703e-01,
        -6.74746512e-03, -3.51721913e-01,  2.20733911e-01,
        -1.74051121e-01, -1.99382320e-01, -6.20598078e-01,
        -1.35406971e-01, -3.22879940e-01, -2.74329871e-01,
        -4.08022791e-01, -8.41088355e-01,  3.83161724e-01,
        -5.36786318e-01,  3.59275900e-02,  4.07131404e-01,
         4.31161851e-01, -3.41544002e-01,  3.15028995e-01,
         5.74110210e-01,  1.50103614e-01,  8.35808814e-02,
        -4.22392964e-01, -3.00824970e-01,  1.03488080e-01,
         2.21316382e-01,  4.00332600e-01, -7.00305998e-01,
         3.79064441e-01, -1.51831910e-01,  5.86170554e-02,
         2.98810244e-01, -4.79698151e-01,  2.34245911e-01,
        -5.78263879e-01,  1.63970679e-01, -3.12160879e-01,
         1.58870518e-01, -1.12938344e+00, -2.58184105e-01,
        -1.31446809e-01,  2.60585457e-01, -1.62471041e-01,
        -1.54781193e-02,  3.60668987e-01, -4.19506967e-01,
        -4.34780955e-01],
       [ 1.66059166e-01, -1.99815378e-01, -6.55594707e-01,
         8.14064592e-02, -2.98847765e-01, -1.08183610e+00,
        -1.16633213e+00,  3.89431059e-01, -1.26137272e-01,
        -7.59119913e-02, -5.78958273e-01,  3.41714501e-01,
        -8.30149293e-01, -9.43515003e-01, -2.62794048e-01,
         3.19162607e-02, -2.24036366e-01,  3.08276564e-01,
         1.91961691e-01, -6.28087461e-01,  4.35636789e-01,
        -9.12533760e-01,  1.69342101e-01, -3.99198294e-01,
        -1.90518305e-01, -4.31712449e-01,  1.86487228e-01,
         2.80825440e-02, -5.57313919e-01,  2.47309640e-01,
         5.92194676e-01, -6.35778427e-01, -6.84269443e-02,
         7.05855191e-01,  1.47870734e-01, -4.85520512e-01,
         2.90269613e-01, -8.37610304e-01, -3.51877540e-01,
         1.67570218e-01, -3.76634777e-01, -2.32454419e-01,
         1.48238644e-01,  4.72317725e-01, -1.57883748e-01,
        -4.42843705e-01,  4.50780213e-01,  1.26255639e-02,
         3.80850792e-01, -2.81510532e-01,  2.02634841e-01,
        -3.21081191e-01, -9.28417444e-01,  6.02423191e-01,
        -8.16289306e-01, -2.53843311e-02, -1.44842297e-01,
        -7.64057040e-01, -2.06203058e-01,  2.17150792e-01,
        -1.66924410e-02, -1.62358642e-01, -3.78360540e-01,
        -1.12627320e-01],
       [-8.62264037e-02, -2.29874417e-01,  3.76982689e-01,
         2.39426747e-01, -1.37510225e-01,  8.09804082e-01,
         3.11785609e-01,  2.87740320e-01,  1.53258264e-01,
        -6.45711362e-01,  2.30363414e-01,  2.19160944e-01,
         2.57155985e-01, -6.41650200e-01, -2.04780087e-01,
        -2.47933298e-01,  1.15982778e-01,  8.64182413e-02,
        -6.27996624e-02,  3.47315744e-02, -1.71496291e-02,
        -7.90390432e-01,  2.91580111e-01,  7.13112652e-02,
         7.79271275e-02,  2.32554927e-01,  8.88614118e-01,
        -5.92619121e-01, -6.65458500e-01, -5.37555456e-01,
         1.70491874e-01,  2.79197425e-01, -9.01873857e-02,
         5.85953832e-01,  4.44557965e-01,  1.35158658e-01,
         2.64577568e-01, -1.70965061e-01, -2.72881687e-01,
         1.59129754e-01, -3.35774422e-01,  3.11976254e-01,
        -4.00038779e-01, -2.13305667e-01, -3.67433131e-01,
        -1.01581097e+00,  5.22804379e-01, -4.21577059e-02,
        -4.50437844e-01, -6.47738755e-01,  2.44243920e-01,
        -2.82817274e-01,  8.54972005e-02, -2.90409446e-01,
         1.20786473e-01,  1.48522276e-02, -1.24390554e+00,
        -5.55658460e-01,  3.79786581e-01,  2.00701341e-01,
         2.16402829e-01, -5.37171125e-01, -1.46639859e-03,
        -7.05359802e-02],
       [ 4.15467322e-02,  4.60766166e-01, -1.59361348e-01,
        -1.22069538e+00,  2.13728055e-01,  7.80794561e-01,
        -8.18606988e-02,  3.16214323e-01, -7.06439614e-01,
        -3.20003688e-01,  8.40927184e-01,  1.02933712e-01,
         6.36923313e-01,  5.50934732e-01, -3.29897046e-01,
         5.07531643e-01,  2.35764891e-01, -1.41104519e-01,
         2.11259440e-01, -7.76382014e-02,  2.30039150e-01,
        -1.52444676e-01,  4.09970693e-02,  2.65130937e-01,
         9.69030023e-01, -6.00887835e-01,  1.08901680e+00,
         4.59394902e-01,  8.36423412e-02, -5.45230865e-01,
         7.10951865e-01,  4.80115771e-01, -3.10206056e-01,
        -4.38283145e-01, -3.35377097e-01,  3.02316636e-01,
         4.68037963e-01,  2.43494317e-01, -1.63792717e+00,
        -2.64294505e-01,  3.60700190e-01, -3.34985942e-01,
         2.68410921e-01, -3.64164174e-01, -2.24413931e-01,
        -3.49366814e-01,  3.84711951e-01, -2.77758807e-01,
         6.52940691e-01, -2.89921969e-01, -2.19714618e-03,
         8.58560577e-02,  2.42071062e-01, -2.06637949e-01,
        -6.90244675e-01, -4.99040246e-01, -1.12111187e+00,
        -3.48761618e-01,  1.11918382e-01, -6.31857097e-01,
         1.27782181e-01,  3.92092504e-02, -4.87775981e-01,
         4.45039690e-01],
       [ 8.13637227e-02,  3.54022533e-02, -5.95891476e-01,
         5.40434361e-01,  5.90401709e-01,  1.78484097e-01,
        -6.13827825e-01, -1.36982873e-01, -1.03805907e-01,
         1.52876660e-01, -2.52509028e-01, -2.05945820e-01,
         1.42673314e-01, -9.52254087e-02,  5.10453999e-01,
        -2.21689925e-01,  6.96004629e-02,  3.07773203e-02,
        -4.63646919e-01,  1.97225437e-01,  3.29839766e-01,
         3.47409964e-01, -3.43983263e-01,  4.17615712e-01,
        -3.32870195e-03, -1.96010008e-01,  7.27233589e-02,
         3.88055235e-01, -6.38881698e-02, -4.22123402e-01,
         1.87678784e-01,  2.47177839e-01,  1.19552232e-01,
        -3.13842028e-01,  3.63249183e-01, -3.17958653e-01,
         3.27082813e-01, -3.80995512e-01, -4.34316516e-01,
         2.40721539e-01, -3.01968724e-01,  2.14861587e-01,
         3.22890013e-01, -5.61517440e-02, -1.02027416e-01,
         2.15419814e-01,  6.01537883e-01,  1.31675512e-01,
         3.79751116e-01, -5.50999045e-01, -5.20355940e-01,
        -4.03838813e-01, -2.86659032e-01,  3.02348197e-01,
        -7.56978095e-01, -2.45435193e-01,  1.00377180e-01,
        -1.53904319e-01, -2.03744784e-01, -3.15324426e-01,
        -2.42507979e-01,  2.17054754e-01,  1.15614367e+00,
        -3.54672283e-01],
       [ 3.74987066e-01, -4.16507810e-01,  3.03020120e-01,
         8.62389430e-02, -6.39401615e-01,  2.03350753e-01,
        -6.11309670e-02,  2.66920447e-01, -3.28587964e-02,
        -2.11042777e-01, -1.65980272e-02,  1.96037009e-01,
         1.99024841e-01,  5.52839875e-01, -1.97893071e+00,
         4.50945705e-01, -3.14281821e-01,  7.64469862e-01,
         4.32002038e-01,  1.26802176e-02,  2.67107099e-01,
        -1.37394041e-01,  2.86531657e-01,  4.23512727e-01,
         1.33667335e-01, -1.95486993e-02,  6.42920375e-01,
        -1.52550328e+00,  2.25857586e-01, -8.29769075e-01,
        -2.30818763e-01, -1.04243731e+00, -6.94703996e-01,
         6.39204860e-01,  7.26828724e-02,  1.15419045e-01,
        -7.72289261e-02,  1.61899105e-01, -3.34119052e-01,
         5.59568882e-01, -2.65332878e-01,  6.57819092e-01,
         1.47026777e-01,  6.14595711e-02,  2.82542259e-01,
         8.14869046e-01, -5.82721353e-01, -5.38478971e-01,
        -1.06360745e+00,  3.88853878e-01, -2.70571232e-01,
         3.58752787e-01,  1.89504847e-01, -3.50701869e-01,
        -9.31441262e-02, -1.33611131e+00,  4.58742112e-01,
        -4.23310727e-01, -1.45209149e-01, -2.55432546e-01,
        -6.50679097e-02, -1.31458752e-02, -5.88978902e-02,
        -1.02002013e+00],
       [-4.11462128e-01, -6.32293582e-01, -6.71196938e-01,
         6.07070401e-02, -2.28804514e-01,  5.17148435e-01,
         1.59433797e-01, -2.90475368e-01, -4.10421908e-01,
         9.59085301e-02, -8.32485333e-02,  6.68037832e-01,
        -8.16355169e-01, -8.63759220e-01,  1.84861153e-01,
        -3.71591330e-01, -3.25816780e-01,  3.15407097e-01,
         1.31628618e-01, -1.50326267e-01, -7.17034459e-01,
        -5.62324762e-01, -3.22153419e-01,  6.64919198e-01,
        -7.04857945e-01, -8.40151086e-02, -1.60944834e-01,
        -2.79557079e-01,  2.82820035e-02, -2.70934135e-01,
        -5.89159250e-01, -1.50158539e-01, -3.39892745e-01,
         6.51011541e-02, -8.33382010e-02,  1.42587386e-02,
         4.27398622e-01,  1.43612921e-01, -1.71221003e-01,
         4.03361619e-01, -4.79906023e-01,  3.39665622e-01,
        -9.43221501e-04,  1.88126087e-01, -6.70334876e-01,
         6.34765923e-01,  1.10091865e+00, -1.06466103e+00,
        -7.83011019e-01,  3.23855132e-01, -4.03133988e-01,
        -2.31322809e-03, -4.64605212e-01,  1.39167206e-02,
        -3.35139126e-01,  9.03330967e-02, -2.70653158e-01,
        -6.09795868e-01,  1.25094399e-01, -3.99862349e-01,
        -4.96892601e-01,  2.01636204e-03, -3.29485834e-01,
         4.15592253e-01],
       [-4.16587770e-01, -5.48159540e-01,  5.04115105e-01,
        -1.24680221e+00,  3.57315801e-02,  3.80443692e-01,
        -2.63162076e-01,  1.89813465e-01, -1.16959132e-01,
         6.30515441e-02, -1.40747145e-01,  4.53550853e-02,
         1.53846871e-02, -2.17263058e-01,  7.14168549e-01,
        -6.03595376e-01,  3.74817908e-01,  6.63713664e-02,
        -3.02198082e-01, -2.69496024e-01, -1.52159601e-01,
         3.94926846e-01, -5.25390953e-02, -1.21027224e-01,
        -6.20865107e-01,  1.53476298e-01,  2.14891776e-01,
         2.47646615e-01,  1.50887549e-01, -1.62074849e-01,
         1.09881379e-01, -4.92799819e-01, -6.72214925e-01,
         2.22066432e-01, -7.89583474e-02, -1.43635392e-01,
        -4.20999795e-01,  2.25867201e-02,  2.28827804e-01,
        -2.03493740e-02, -3.38449895e-01,  1.97676681e-02,
         8.41475874e-02,  4.36848640e-01, -6.55290723e-01,
         2.97122121e-01,  8.18265319e-01, -3.16170871e-01,
        -2.99350470e-01, -2.67932825e-02, -4.08567525e-02,
        -1.71642974e-01,  3.25775072e-02,  2.81227529e-01,
         2.51992226e-01, -5.75784743e-01,  2.97361165e-01,
        -5.69532216e-01,  9.03723668e-03, -2.26491943e-01,
        -1.88181967e-01, -5.85608125e-01, -5.85269779e-02,
        -1.24874599e-01],
       [-6.81892693e-01,  3.18108320e-01,  2.28654861e-01,
         1.06160939e-01, -5.81514537e-01, -1.99519858e-01,
         1.73545241e-01, -2.41890118e-01, -1.32674143e-01,
        -3.74923974e-01,  5.10303855e-01,  3.12316716e-01,
         2.73425549e-01, -1.24559247e+00, -2.52199590e-01,
        -3.58504295e-01,  8.87511577e-03, -4.12580729e-01,
         3.13125610e-01,  4.66976054e-02,  8.14698357e-03,
         6.00770302e-02, -6.07951045e-01, -8.24252784e-01,
        -5.20536721e-01, -2.36387357e-01, -2.90743995e+00,
         2.26907283e-01, -4.98737365e-01,  1.34714991e-01,
        -3.33613396e-01, -8.91832292e-01,  1.68336496e-01,
         2.12455261e-02,  2.69221961e-01,  2.86622941e-01,
         3.03081393e-01,  3.68830234e-01,  4.92541552e-01,
         2.07803905e-01, -1.56533822e-01,  8.25303197e-01,
         9.24423188e-02,  3.54532063e-01,  4.31759477e-01,
         3.60938162e-01,  1.71470232e-02, -1.02623664e-01,
         4.00079906e-01, -5.99619225e-02, -3.99538040e-01,
        -2.16999829e-01,  7.41043836e-02,  1.70465317e-02,
        -3.21240574e-01, -3.99721652e-01, -6.97937191e-01,
        -7.20061779e-01, -2.60552347e-01,  3.23018551e-01,
         2.32435778e-01, -5.76953590e-01, -2.12552324e-01,
         5.59266247e-02],
       [-7.20757902e-01, -1.93270057e-01,  2.39868537e-01,
        -5.87279141e-01, -1.32461548e-01, -3.02420437e-01,
         4.71398383e-01, -1.43787935e-01, -3.68945092e-01,
        -8.44570398e-02,  1.49896562e-01,  1.26186535e-02,
        -1.31684110e-01,  4.49894130e-01, -1.45922875e+00,
        -3.94094467e-01,  5.41714966e-01,  2.24874094e-01,
         6.95280552e-01,  4.53311801e-01, -8.72156262e-01,
        -7.86775202e-02, -7.13064671e-01, -6.39723778e-01,
         6.93906426e-01,  4.95691001e-01,  4.34882551e-01,
        -1.34577274e-01, -1.03465891e+00, -1.15540349e+00,
         3.99065197e-01,  4.69189167e-01, -7.46721923e-01,
         4.43203926e-01, -4.35957193e-01, -3.10399532e-01,
        -1.96338415e-01, -1.21548072e-01,  1.31942824e-01,
         2.51117125e-02, -1.38783425e-01,  2.50361599e-02,
         3.26533943e-01, -9.20293510e-01, -2.34734327e-01,
        -8.18065405e-01,  4.27557454e-02, -9.78558540e-01,
         6.67919338e-01,  5.60146093e-01,  2.15337574e-01,
        -2.65522510e-01,  3.49610180e-01, -4.91104349e-02,
        -1.07382878e-03,  2.23382309e-01, -3.20668191e-01,
        -3.54216456e-01, -1.24401426e+00, -1.90500677e-01,
         3.50072950e-01,  1.95801452e-01,  1.16975993e-01,
        -8.17973018e-01],
       [-6.54159114e-02, -3.56481969e-01,  4.12236378e-02,
        -3.77227962e-01,  5.11320196e-02,  9.73068550e-02,
         1.27987698e-01, -2.49954343e-01, -1.00569256e-01,
        -3.32224756e-01,  4.11589444e-01, -1.25176623e-01,
         2.40106940e-01,  5.63129663e-01,  4.51724380e-01,
         1.52490899e-01,  2.08994940e-01, -2.12830111e-01,
        -3.23735714e-01, -1.95951179e-01,  5.16837180e-01,
        -1.99572593e-01,  4.09876972e-01, -1.24473102e-01,
        -3.52184236e-01, -2.45563388e-01, -3.20867360e-01,
         2.22262144e-02, -8.88880253e-01,  5.23302197e-01,
         5.83234504e-02, -5.11731625e-01, -1.41591430e-01,
         5.83853662e-01, -2.69443721e-01,  4.32493491e-03,
        -7.84742311e-02,  2.04891190e-01,  2.75866449e-01,
         5.95226645e-01,  4.58676741e-03, -5.08659124e-01,
         3.26648921e-01,  3.66672240e-02, -4.37063664e-01,
         5.25954485e-01,  8.26621771e-01,  3.17305386e-01,
        -9.02021527e-02, -1.68766126e-01, -1.86246596e-02,
        -4.19352651e-02,  2.98105240e-01, -2.15047821e-01,
         4.49814588e-01, -6.21693879e-02, -8.10136348e-02,
        -4.40834820e-01,  5.57841897e-01, -2.58142650e-01,
         1.94503099e-01,  2.96675172e-02,  6.59371436e-01,
        -6.32002875e-02],
       [ 2.95873046e-01,  3.91694635e-01, -9.03291104e-04,
        -2.93164141e-02, -7.73377717e-02, -7.52291381e-02,
        -3.98877054e-01, -1.25987887e-01,  7.55693913e-02,
        -1.68899417e-01, -2.16362834e-01, -1.46055773e-01,
         2.63405174e-01, -1.16010539e-01,  3.43076974e-01,
         1.52470797e-01,  1.81416824e-01, -3.34556043e-01,
         7.32222140e-01,  2.36822203e-01, -8.10466558e-02,
        -1.55605957e-01, -9.43737999e-02,  4.49535191e-01,
        -2.83421308e-01, -1.98527783e-01,  2.09384605e-01,
        -6.80623949e-01,  4.50487018e-01,  2.33795032e-01,
        -1.46222889e-01, -4.55604851e-01, -2.47732550e-01,
        -2.11063921e-01,  3.23283941e-01, -1.36763275e-01,
        -6.82988092e-02,  2.44719815e-02, -5.04722893e-02,
        -1.53448638e-02, -3.21424678e-02,  3.12118113e-01,
         4.20318870e-03, -6.18124664e-01,  1.17866650e-01,
        -3.97869438e-01, -1.07024014e-01,  2.81820267e-01,
        -2.23004833e-01, -2.25821733e-01, -1.94014952e-01,
         1.39818182e-02, -2.82878488e-01,  3.95407408e-01,
         4.10280645e-01, -1.43780589e-01,  4.60897572e-02,
        -4.76435930e-01,  1.86673537e-01,  5.19871488e-02,
         2.52007037e-01,  1.56061187e-01, -3.36452216e-01,
         1.28020212e-01],
       [ 1.03733696e-01, -4.23729986e-01, -5.92508674e-01,
        -5.07780790e-01, -9.97122586e-01, -4.63873506e-01,
        -5.17939031e-01,  1.12008192e-01,  4.28749621e-02,
        -1.16356879e-01, -5.08589745e-01, -5.43724835e-01,
         9.15199071e-02, -8.04966018e-02, -1.04664207e-01,
         5.56572795e-01, -1.85645998e-01, -1.40028149e-01,
         2.42341205e-01, -3.45331997e-01, -5.68029404e-01,
         7.20057249e-01,  1.54136151e-01,  8.44260156e-02,
         5.18520057e-01,  3.96638483e-01, -1.12202299e+00,
        -9.08064663e-01, -8.27874422e-01, -1.19741715e-01,
        -5.34547627e-01, -3.23803425e-01, -6.30944788e-01,
        -1.23560607e-01, -1.36457328e-02,  6.26791775e-01,
         4.84595671e-02,  2.81792462e-01, -4.24436539e-01,
        -7.42091984e-02,  4.58882809e-01, -1.19926974e-01,
        -3.31558049e-01,  1.12461574e-01,  9.56706405e-02,
        -4.00098592e-01, -8.53360295e-01, -1.98902890e-01,
        -2.46209979e-01,  2.76490360e-01,  4.66437608e-01,
         4.16793108e-01,  3.40976775e-01,  2.88885266e-01,
        -2.22623035e-01,  1.07976481e-01, -8.04726928e-02,
         1.80852205e-01,  3.28527331e-01, -1.67366818e-01,
         2.05944046e-01,  1.84951529e-01, -6.53735518e-01,
        -2.81102568e-01],
       [ 4.42674637e-01,  4.05736864e-01,  3.65126133e-01,
         5.09162128e-01, -2.49121830e-01, -1.44275561e-01,
         4.02917191e-02, -1.69796407e-01, -1.14415482e-01,
         6.40668422e-02,  2.12154109e-02,  2.57688224e-01,
         4.88741904e-01,  2.88523674e-01, -1.91452205e-01,
        -1.02532119e-01,  3.87866825e-01,  1.96451068e-01,
        -3.46515089e-01,  2.06268057e-02, -4.41125959e-01,
        -7.41797537e-02, -9.12728488e-01,  4.22265828e-02,
         2.18597241e-02, -4.32421237e-01, -2.88568065e-02,
        -8.22353005e-01,  1.48220137e-01, -2.50962764e-01,
         5.31858325e-01, -1.88262776e-01, -3.48253250e-01,
        -1.84091553e-01,  3.79941612e-01,  5.46122752e-02,
         3.96789350e-02,  3.62416536e-01,  3.19546074e-01,
         4.56957489e-01,  6.01881981e-01,  5.31061053e-01,
         4.96129811e-01, -3.93338978e-01,  2.98832715e-01,
        -3.36642236e-01, -4.61389482e-01, -5.96515000e-01,
         4.79100943e-01, -8.97741783e-03,  4.23400551e-01,
         1.12128116e-01,  2.12471709e-01,  3.41038048e-01,
         3.01532388e-01,  6.51621222e-02, -3.04006934e-01,
         2.47363150e-01, -1.13443993e-01, -2.47496143e-01,
         4.51448351e-01,  2.60429159e-02, -2.73516655e-01,
        -1.64285660e-01],
       [ 2.88040191e-01, -8.77401512e-03,  4.49091971e-01,
         5.79452276e-01, -2.94664383e-01, -5.72199076e-02,
         8.17991197e-02, -9.94380787e-02,  8.98588821e-02,
         2.63989288e-02, -4.96269688e-02,  2.01990619e-01,
        -3.29914987e-01,  1.91879019e-01, -3.12800437e-01,
        -2.71019787e-01,  1.23291247e-01, -3.15197855e-01,
         6.10840358e-02,  3.25341254e-01, -5.87430239e-01,
         4.53749066e-03, -4.14897442e-01,  3.55374902e-01,
         3.02282721e-01, -6.76510409e-02,  4.66841936e-01,
        -6.77214444e-01,  3.62665839e-02, -5.59660137e-01,
         3.08564246e-01, -4.52522412e-02, -2.54640467e-02,
         3.72548588e-02, -1.60090979e-02,  3.41363028e-02,
         1.59840018e-01,  4.35630709e-01,  3.37369651e-01,
        -4.75301355e-01,  4.97432351e-01,  1.64261937e-01,
         4.32947695e-01, -4.18729812e-01,  2.30819851e-01,
        -3.07358652e-01,  1.18258379e-01, -2.47170538e-01,
         2.45869115e-01,  1.65435687e-01,  2.07104653e-01,
         4.37989414e-01,  2.31764808e-01,  2.25862674e-02,
         2.11863086e-01, -1.90254718e-01, -6.37566090e-01,
         2.02374026e-01, -1.37600869e-01, -4.14203495e-01,
         4.80091631e-01, -2.84229834e-02, -1.59469560e-01,
        -4.02612448e-01],
       [-3.06132495e-01, -2.79662877e-01, -2.03463227e-01,
         1.94166809e-01, -6.32178426e-01,  2.47033183e-02,
         1.75358325e-01,  1.82032377e-01,  1.33327678e-01,
        -5.03445268e-01, -3.32938433e-01,  6.03731692e-01,
        -9.77545604e-02, -4.59049642e-02,  1.08988628e-01,
        -7.54901692e-02,  3.98556322e-01,  2.80129224e-01,
         1.87899932e-01,  1.25853851e-01, -6.37646392e-02,
        -1.68612108e-01, -6.47373676e-01,  3.83161306e-01,
        -6.34166300e-02,  2.10020021e-01,  3.04103434e-01,
         5.30436188e-02,  1.22100085e-01, -6.04002595e-01,
         6.91290423e-02, -7.47697234e-01, -6.19545221e-01,
         2.12963343e-01, -1.62509546e-01,  1.67675659e-01,
         1.76178947e-01,  1.00591190e-01, -2.74926096e-01,
         4.60879207e-01, -3.88922915e-02, -2.71103501e-01,
        -3.94016355e-01, -2.68619597e-01, -2.51521319e-01,
        -4.79715407e-01,  1.47067606e-01, -9.74901557e-01,
         1.42703891e-01,  3.80251966e-02, -1.30911261e-01,
         1.04633175e-01, -7.02297211e-01, -5.31938374e-01,
        -5.19735694e-01, -7.21569180e-01, -6.79163337e-01,
        -1.99343055e-01,  2.28872836e-01, -1.40542686e-01,
        -8.49160627e-02, -6.34177804e-01, -1.21238176e-02,
         4.35769975e-01],
       [-1.63755968e-01, -9.38573629e-02, -8.31421733e-01,
        -9.39787626e-01, -2.49674261e-01,  2.77565777e-01,
         4.72430140e-01,  4.45854843e-01, -4.45880711e-01,
        -3.69179517e-01, -6.70813560e-01,  1.01443268e-02,
         2.57869244e-01, -5.00543058e-01, -4.56809737e-02,
         3.80250514e-01, -2.09299445e-01,  2.59078503e-01,
        -4.69117790e-01,  2.88085550e-01,  6.50016069e-01,
        -2.72139519e-01, -1.71875656e-01,  6.81894839e-01,
         3.35486457e-02,  1.09259516e-01, -6.34425938e-01,
        -6.65130973e-01,  8.82342681e-02,  1.02902301e-01,
         5.57369441e-02, -3.72015595e-01,  4.83117789e-01,
         1.61650315e-01, -2.34868541e-01, -5.85777938e-01,
         3.34493257e-02,  6.01895332e-01,  2.18377203e-01,
         1.18211480e-02,  9.29716527e-02, -2.21538562e-02,
        -1.11363724e-01, -1.20008528e-01,  1.82668924e-01,
         6.49993360e-01,  7.40267560e-02,  1.32562965e-01,
         3.98392230e-01,  1.75104544e-01,  2.42272586e-01,
         1.32423583e-02,  1.67813718e-01, -8.08993950e-02,
         3.51455390e-01, -4.23093051e-01, -3.44838262e-01,
        -6.06033921e-01,  3.85899156e-01, -2.26162255e-01,
        -5.16400822e-02,  3.57539803e-01, -1.29610509e-01,
         5.73036253e-01],
       [-2.90929258e-01, -1.04087019e+00,  2.92825431e-01,
        -4.49757904e-01,  6.85785785e-02, -2.34429911e-01,
         1.95418984e-01,  3.54050189e-01,  9.67729837e-02,
        -2.55797833e-01, -2.54004329e-01,  1.51861608e-01,
         3.93016338e-01, -1.10276021e-01, -7.14974999e-01,
         4.91959341e-02,  2.97971576e-01,  2.90740877e-01,
         5.87631643e-01,  2.20120341e-01,  2.71719933e-01,
        -8.37422386e-02, -5.00909686e-01, -1.94538966e-01,
         4.78444278e-01, -1.44347608e-01,  5.06282151e-01,
        -3.11204731e-01, -2.73851663e-01,  3.10478270e-01,
         2.26707175e-01, -5.13521850e-01, -5.68454899e-02,
        -2.79355615e-01, -1.96042396e-02, -5.03797941e-02,
         4.29281861e-01,  8.54613036e-02,  3.45718831e-01,
         4.54112947e-01,  3.19283932e-01,  5.87583244e-01,
         3.64861786e-01, -1.51308119e-01, -9.73782167e-02,
        -3.71631950e-01, -7.27628469e-01, -2.24667490e-01,
        -3.48520093e-02,  1.14725620e-01,  1.70842499e-01,
        -9.69886184e-02,  2.42585331e-01, -6.68317825e-02,
         5.56940973e-01,  1.15566000e-01, -3.46419692e-01,
         1.57173231e-01,  7.00521618e-02, -7.35506369e-03,
         1.41745493e-01,  4.37524796e-01, -5.17272413e-01,
        -1.25921085e-01],
       [ 1.88822120e-01, -4.85117048e-01,  1.16809227e-01,
         6.95939213e-02, -5.56141317e-01, -8.29995215e-01,
         1.11563966e-01, -2.64601171e-01,  2.64681578e-01,
        -2.01079637e-01,  1.82234541e-01, -6.46213815e-02,
         3.18427831e-01, -5.32597601e-01, -4.87745404e-01,
         2.40399569e-01,  3.13869745e-01,  8.62984136e-02,
        -2.57391911e-02,  3.44483227e-01,  1.20164558e-01,
        -5.88273294e-02, -6.11134529e-01, -3.80558986e-03,
         5.16758263e-01, -3.51381063e-01, -1.70404896e-01,
        -3.02695245e-01, -3.51849914e-01,  1.77991539e-01,
         9.68030933e-03,  1.04497902e-01, -1.81535438e-01,
        -3.19591731e-01,  6.22760832e-01, -1.78884462e-01,
         2.55494028e-01, -3.78536358e-02,  5.89170039e-01,
         4.96749133e-01, -1.16187483e-01,  4.77487236e-01,
         1.56730801e-01,  2.47229069e-01,  4.01741982e-01,
        -7.67932981e-02,  2.07989246e-01, -2.43000761e-01,
         1.92761540e-01, -7.71220848e-02, -3.02584190e-02,
        -1.87966794e-01,  2.69019961e-01,  3.54351908e-01,
         9.10919547e-01,  2.11299062e-02,  2.28053436e-01,
        -9.88894254e-02, -1.58027783e-01, -3.09241861e-01,
         5.84346615e-02,  1.19686916e-01, -7.89314687e-01,
        -1.98073730e-01],
       [ 2.92898476e-01, -2.33255893e-01,  4.52118903e-01,
        -1.84378132e-01, -5.02524972e-01, -7.79415620e-03,
         2.45211989e-01,  3.48660648e-01, -1.58294603e-01,
        -2.06585810e-01,  3.00500870e-01,  4.22072053e-01,
         4.06595349e-01,  3.31870049e-01, -6.31750166e-01,
        -2.17805400e-01,  2.50467509e-01, -1.11668766e-01,
         3.29515904e-01,  2.46182159e-01, -4.34422761e-01,
         3.04585129e-01, -5.53768456e-01,  2.58560002e-01,
         3.92871261e-01, -1.18737407e-02,  4.13689822e-01,
        -2.85209775e-01, -6.32464290e-02, -3.17005515e-01,
         4.90657240e-01, -4.06186223e-01,  1.79528236e-01,
        -4.48479980e-01,  1.51861563e-01,  5.90863943e-01,
        -9.95590240e-02,  7.24273562e-01, -9.22771245e-02,
        -2.34947234e-01,  5.94355345e-01,  1.65263206e-01,
         5.44508815e-01, -2.38885865e-01,  2.35547557e-01,
        -4.45548773e-01, -2.46302202e-01, -5.98986983e-01,
         7.54462183e-01,  1.02608822e-01, -2.05626767e-02,
         5.54359239e-03,  2.64167279e-01,  1.56851962e-01,
        -2.63272405e-01, -1.23253554e-01, -3.85809004e-01,
         2.99730211e-01, -3.04317564e-01, -3.61609936e-01,
         6.79522276e-01,  4.48174655e-01, -1.05267584e-01,
        -1.13496810e-01],
       [-3.15758497e-01, -1.47986889e-01, -9.79592681e-01,
        -4.57662195e-01,  2.89248765e-01, -1.01172006e+00,
        -1.09191149e-01,  6.91603541e-01, -2.62802005e-01,
        -1.92784235e-01,  1.80902958e-01, -1.70730352e-01,
         6.71835840e-02, -5.99953651e-01, -1.28982830e+00,
         1.07450567e-01, -1.26483142e-01,  4.04820949e-01,
        -1.24571645e+00,  2.87045985e-01,  7.57459104e-01,
        -1.99519455e-01, -7.05950081e-01, -9.43900526e-01,
         5.53703457e-02, -1.37311965e-01, -8.17325413e-02,
        -1.35631442e+00,  3.58220518e-01, -5.31295955e-01,
        -9.49034452e-01, -9.00512397e-01,  2.15341195e-01,
         3.25812995e-01,  9.60008577e-02, -9.14198697e-01,
        -1.16251481e+00,  7.54544511e-02, -1.37863442e-01,
        -4.87143755e-01, -1.13156414e+00, -4.57593799e-01,
        -1.64677724e-01,  7.11085498e-01, -5.10711633e-02,
        -1.11842775e+00, -3.33994714e-04, -1.90566957e-01,
         5.49278021e-01, -4.83435541e-01,  1.18559292e-02,
         5.79539597e-01, -1.01065433e+00, -6.46390319e-01,
        -9.10782456e-01, -1.05105639e+00, -8.56253207e-01,
        -4.81733918e-01, -8.55850041e-01,  2.60142177e-01,
        -8.72632742e-01, -7.08530128e-01,  7.46842325e-01,
        -1.02718789e-02],
       [-5.46213746e-01, -2.55683839e-01,  2.08058983e-01,
         3.61955613e-01,  1.11377165e-01, -1.27822387e+00,
        -3.98534358e-01,  8.26814845e-02, -1.67144716e+00,
        -2.33495280e-01,  4.49058376e-02,  6.12104058e-01,
        -5.96026421e-01, -1.99835420e-01, -7.84328997e-01,
         1.88423693e-01, -1.32160318e+00, -4.02202249e-01,
        -9.57648098e-01, -1.38127849e-01, -3.67095232e-01,
         3.70962590e-01, -2.28697285e-01,  4.95338470e-01,
        -6.36125803e-01, -5.79738796e-01, -4.21439111e-01,
        -8.34543347e-01,  2.21993223e-01, -8.69575515e-02,
        -6.51265383e-01, -5.63444257e-01,  4.84294504e-01,
        -8.84866193e-02, -1.59451663e-01,  1.90869924e-02,
        -4.54143703e-01, -1.93882048e-01, -1.19002676e+00,
         7.19803333e-01, -3.17402899e-01, -3.19841176e-01,
         3.97786707e-01,  2.52725780e-01,  2.39107609e-01,
         6.38967574e-01,  9.94426683e-02,  3.82982418e-02,
        -5.06312191e-01,  3.39953989e-01, -7.06620932e-01,
        -1.17266381e+00, -4.39604819e-02,  1.90503478e-01,
        -3.49396348e-01, -3.30076627e-02, -7.59933054e-01,
        -2.57881820e-01, -1.07393765e+00, -9.32773352e-02,
         2.24433079e-01, -7.09126413e-01, -7.76149482e-02,
        -3.73671025e-01],
       [ 1.51658235e-02, -1.11627817e+00, -5.73099069e-02,
         1.38921365e-01, -8.72792482e-01, -3.08682293e-01,
         2.44192034e-01,  1.30924761e-01, -5.49956225e-02,
        -2.45653614e-01,  3.60721827e-01,  4.93939519e-01,
         1.00207977e-01,  3.02379042e-01, -3.95525455e-01,
         8.13122001e-03,  6.85064346e-02, -1.29644409e-01,
         1.15000248e-01, -2.60196477e-02,  6.99805468e-02,
         2.39646479e-01, -1.40419617e-01,  2.31296733e-01,
         4.75093722e-01, -3.97222728e-01,  1.00216758e+00,
         2.41848513e-01,  2.14785159e-01, -3.65126073e-01,
         7.03899860e-01, -3.87012303e-01,  9.73102003e-02,
        -8.12265798e-02,  2.10249797e-01,  8.13127086e-02,
         4.29901123e-01,  1.69310361e-01,  9.99618173e-02,
        -2.63527662e-01,  5.94043136e-01,  3.89477223e-01,
         2.03961939e-01, -6.71855211e-02, -5.15602678e-02,
        -8.83772433e-01,  1.99526697e-02, -5.57565272e-01,
        -2.44312193e-02,  1.61060944e-01,  3.01004916e-01,
        -2.28168610e-02,  2.03837186e-01, -4.78789359e-02,
         3.96507144e-01, -9.86938104e-02, -2.74474084e-01,
         3.35184187e-01, -3.80568132e-02,  1.18466139e-01,
         4.27408636e-01,  3.41054380e-01, -3.78421128e-01,
        -3.75986487e-01],
       [-1.18942177e+00, -8.16118717e-01, -2.85243601e-01,
         5.91588497e-01, -3.09851319e-01, -6.09753467e-02,
         9.61531624e-02, -3.57932448e-01,  1.20840706e-02,
        -1.08408131e-01, -1.28378540e-01, -6.91650331e-01,
        -1.29319385e-01, -1.48149228e+00,  1.91817302e-02,
        -4.33784336e-01, -1.05694704e-01,  1.94343165e-01,
         1.20503746e-01,  5.28473333e-02, -4.31365758e-01,
         2.99079061e-01, -8.91544148e-02, -1.37579417e+00,
         3.77811074e-01,  4.26675141e-01, -1.12489724e+00,
         3.87721568e-01, -3.42637450e-01, -7.43641928e-02,
        -1.43396318e+00, -7.83308387e-01, -2.82618403e-01,
         1.23294465e-01,  5.01983643e-01, -1.42053053e-01,
        -2.27511808e-01, -3.96465451e-01,  3.53508085e-01,
        -2.43977472e-01, -1.43581843e+00, -6.22375607e-01,
        -6.22239411e-01,  4.72205549e-01, -2.25962162e-01,
        -1.20411921e+00,  1.80836841e-01, -1.23025715e+00,
         4.70667668e-02, -2.03885034e-01,  1.48880243e-01,
        -8.45884979e-02,  1.94631308e-01,  1.14865787e-02,
         1.84359908e-01, -3.40392202e-01, -2.45596394e-01,
        -8.51711988e-01, -1.88709777e-02,  1.84271228e-03,
         1.59482017e-01, -1.66921560e-02,  1.86394900e-02,
        -8.05129409e-01],
       [ 1.86572239e-01, -1.33427188e-01, -3.71797472e-01,
        -8.11277553e-02, -4.74908531e-01,  1.79645419e-01,
         4.76328224e-01, -9.48348418e-02,  1.85278952e-01,
        -4.32716310e-01,  7.68371597e-02,  2.45570987e-01,
         1.90314099e-01,  8.69514868e-02,  4.81445968e-01,
         5.78795485e-02, -2.43202955e-01, -9.51549113e-01,
         4.33082730e-01,  6.87676743e-02, -4.55736816e-02,
        -3.47662121e-01, -1.15738988e-01,  1.31316960e+00,
        -1.48462161e-01,  2.14015052e-01,  5.01161933e-01,
        -7.66775608e-02, -3.21008742e-01,  2.62629151e-01,
         3.85355651e-01, -3.56855631e-01,  1.42056003e-01,
        -2.81002909e-01, -4.73448306e-01,  5.76118886e-01,
         1.07995190e-01, -7.53756315e-02, -6.61336243e-01,
         6.97709024e-02, -5.72682738e-01,  5.90233505e-01,
         1.44297667e-02, -1.48950726e-01,  1.94666460e-01,
         4.73756909e-01, -3.82202089e-01, -3.86003405e-01,
        -2.15532213e-01, -1.23245344e-01,  1.96775958e-01,
        -5.62265337e-01,  2.66632438e-01,  6.10629767e-02,
        -1.39654815e-01, -7.51098573e-01,  1.92676023e-01,
        -7.71774948e-02,  7.38425255e-01, -3.35569113e-01,
         2.77147233e-01, -3.45573604e-01, -9.20214206e-02,
         2.19309002e-01],
       [-2.79134363e-01, -1.77292421e-01,  1.12611771e-01,
        -7.58663595e-01,  2.23173454e-01,  3.00596327e-01,
        -5.37506163e-01,  1.17441528e-01,  1.79238260e-01,
        -6.05171062e-02, -5.37503242e-01,  1.96980938e-01,
        -1.77117929e-01,  2.42023282e-02, -2.30401993e-01,
        -1.12375692e-01, -2.58209854e-01,  1.75008215e-02,
        -5.07555425e-01, -6.02279343e-02, -9.05121863e-01,
        -1.93605036e-01,  1.55972661e-02, -3.92818332e-01,
        -1.12473100e-01, -4.84750807e-01,  3.67497981e-01,
         1.87006995e-01, -1.38543174e-01, -6.66204929e-01,
        -2.85905927e-01, -4.23940301e-01, -4.39293534e-01,
         6.48172259e-01,  1.63788125e-01,  5.22790030e-02,
         1.02924787e-01,  8.34707677e-01,  3.33519727e-01,
        -2.37201944e-01,  2.58934438e-01,  4.69176561e-01,
         6.33113742e-01,  6.13532007e-01, -4.75088865e-01,
        -5.35511784e-02, -2.68246800e-01, -1.78631201e-01,
        -5.36680877e-01,  1.31118372e-01,  5.08775532e-01,
        -3.27678956e-02,  7.11102366e-01, -1.60905123e-01,
         2.15718016e-01,  1.01697959e-01, -5.76493263e-01,
         3.83826941e-01, -1.28936398e+00, -1.51142970e-01,
        -4.37024742e-01,  5.19702613e-01, -1.05658285e-01,
        -3.30614209e-01],
       [-2.00598225e-01,  1.53639400e-02, -4.81290013e-01,
         2.70840079e-01, -2.45091408e-01, -2.39702389e-01,
         5.25918543e-01,  7.16717720e-01,  2.98727453e-01,
        -1.41514257e-01, -1.01881661e-01,  9.58485842e-01,
         7.43520260e-01, -5.01207650e-01, -1.67182517e+00,
         3.26352984e-01, -8.38340104e-01,  5.98204374e-01,
        -7.03262389e-02, -1.25439735e-02,  4.10943300e-01,
        -1.14517832e+00, -4.47569698e-01, -2.13071823e-01,
        -2.36526527e-03, -2.30511785e-01,  1.01149634e-01,
        -8.16788375e-01, -6.78700447e-01, -2.23498344e-01,
        -1.20786643e+00, -2.17994347e-01,  2.42447481e-01,
         6.60873234e-01,  1.20006032e-01, -1.07344604e+00,
        -5.23132563e-01,  1.08139642e-01, -3.79526675e-01,
        -6.25246942e-01, -7.57936597e-01, -3.92165869e-01,
         1.38661906e-01,  4.86350179e-01, -1.06540787e+00,
        -1.03814638e+00, -9.95592773e-01, -3.35325718e-01,
         4.02902335e-01, -7.66445100e-01,  1.98473707e-01,
         9.87818122e-01, -1.02193952e+00, -9.66898166e-03,
        -3.31061274e-01, -1.13326633e+00, -6.27777278e-01,
        -7.34809935e-01, -3.19835603e-01,  1.58321574e-01,
        -7.88641989e-01, -5.99137425e-01,  8.55621338e-01,
        -1.35160172e+00],
       [ 2.18895212e-01, -3.12781990e-01,  1.28508702e-01,
        -3.62173207e-02, -1.44548416e-01,  1.03450313e-01,
         2.87011236e-01, -3.71477932e-01, -1.77460819e-01,
        -5.39053559e-01,  6.77361414e-02, -4.89621796e-02,
        -1.14152864e-01,  2.00775743e-01,  6.22273266e-01,
         1.16295770e-01, -2.66877055e-01,  2.52378434e-01,
         5.39889276e-01,  1.28382936e-01,  4.74504195e-02,
         1.05219819e-01, -2.97467172e-01,  3.45425606e-01,
         7.52955452e-02, -1.82625279e-02,  2.12528840e-01,
        -6.31252050e-01, -7.16535076e-02,  3.68588448e-01,
         7.42712095e-02, -6.26411915e-01, -2.70316273e-01,
         4.15013105e-01, -7.07886592e-02,  4.90190201e-02,
        -1.91919699e-01,  7.18415916e-01, -2.77989358e-01,
         5.36189377e-01,  1.91935860e-02,  3.49797577e-01,
        -5.88646047e-02,  2.03797609e-01, -2.41937488e-01,
         3.19499582e-01,  2.72754669e-01,  3.33279520e-01,
         2.72648692e-01,  2.72954732e-01, -4.32894677e-02,
        -1.60902083e-01,  2.68600374e-01, -9.04711261e-02,
         5.04063845e-01, -1.99426085e-01, -5.39457500e-02,
         6.27593696e-03, -8.99896175e-02,  2.87221491e-01,
         9.96317416e-02,  3.81662279e-01,  3.78883958e-01,
        -1.05215147e-01],
       [ 1.75567880e-01, -2.66432524e-01, -5.82142532e-01,
         3.37032795e-01, -2.14341998e-01, -6.39261901e-01,
        -1.66611001e-01,  3.87348533e-01, -4.57009256e-01,
        -4.30035889e-01, -2.23671660e-01,  4.34015185e-01,
        -4.28725600e-01, -6.09647036e-01,  5.18850565e-01,
        -1.56103566e-01,  1.12163931e-01,  5.32920361e-02,
         3.66127729e-01,  4.38426465e-01, -2.28403777e-01,
         7.59682178e-01,  3.63327339e-02, -3.87856811e-01,
        -3.61093789e-01, -1.15041263e-01,  6.45171642e-01,
        -8.19449484e-01, -2.23444045e-01,  3.84288043e-01,
         3.32990289e-01, -3.32163602e-01,  2.94682980e-01,
        -2.33558699e-01,  1.31269749e-02, -1.85603932e-01,
        -5.17257750e-01, -4.29489732e-01, -8.14553946e-02,
         2.33294949e-01, -2.00194828e-02, -1.59049839e-01,
        -5.63702047e-01,  3.96449268e-01,  8.10248435e-01,
        -1.20840833e-01,  3.97847027e-01, -4.00067031e-01,
        -4.85290319e-01, -1.68201596e-01, -1.95746809e-01,
        -1.70644388e-01, -4.79763299e-01,  7.49365687e-02,
        -7.18160346e-02, -1.95200190e-01, -4.82725292e-01,
        -6.43339574e-01, -7.17503801e-02, -1.67188495e-01,
        -5.26830673e-01, -2.39054054e-01, -4.57806647e-01,
         5.37105463e-02],
       [-5.87549090e-01,  3.72009724e-02,  2.60837320e-02,
        -3.70031148e-01, -3.51481378e-01, -9.76812184e-01,
         2.66051054e-01, -2.82057934e-02,  4.90474403e-02,
         5.50108030e-02, -1.30497015e+00,  2.03744650e-01,
         3.29253405e-01,  5.29479027e-01, -5.91302752e-01,
        -9.59326029e-02, -7.49578476e-02,  2.61066973e-01,
        -3.02546471e-01, -1.30282938e+00, -6.09180443e-02,
        -1.65368423e-01, -6.37097299e-01,  5.31441271e-01,
         1.81058124e-01, -1.50878787e-01,  6.59364760e-01,
        -1.19474471e+00, -6.99134827e-01,  1.52383506e-01,
         9.18730721e-02,  3.00732881e-01, -3.18661600e-01,
        -8.61882567e-01,  3.47283542e-01, -3.37113231e-01,
        -3.48040368e-03, -2.26922985e-02,  1.21194072e-01,
        -4.01386321e-02, -7.88729608e-01,  2.93115109e-01,
        -1.70268297e-01,  4.25456226e-01, -2.13570967e-01,
        -9.31188941e-01,  5.14513552e-01, -2.28103071e-01,
         2.24662602e-01,  4.36442941e-01,  3.96353483e-01,
        -7.02937067e-01, -4.44721788e-01, -3.38551819e-01,
         4.13930565e-02, -5.44900119e-01, -3.11126590e-01,
        -5.33568203e-01,  6.49488032e-01,  6.85603440e-01,
        -3.76961082e-01,  3.75675336e-02, -7.42018595e-02,
         2.05375016e-01],
       [ 3.47192258e-01, -1.99056212e-02,  5.74956536e-01,
         4.18839425e-01, -3.67275387e-01,  6.03309311e-02,
         4.89202082e-01,  2.27512829e-02,  2.22880557e-01,
        -2.25155935e-01,  2.27509171e-01,  2.90723145e-01,
         4.26878363e-01, -3.55486274e-02, -4.52904284e-01,
        -3.10619563e-01,  2.15635195e-01,  8.32685009e-02,
         8.24791193e-01,  3.60673368e-01, -1.34971583e+00,
         1.87355354e-01, -3.13647151e-01,  3.86292487e-01,
         6.38086557e-01, -2.17690825e-01,  2.02711284e-01,
         1.13454007e-01, -1.73621520e-01, -8.34998965e-01,
        -3.25947672e-01,  7.50925615e-02, -1.41870737e-01,
         1.96195260e-01, -2.62650937e-01,  2.08591402e-01,
        -7.21878886e-01,  9.65871990e-01,  3.21236759e-01,
         3.53134751e-01,  3.20459992e-01,  4.78254586e-01,
         3.45893741e-01,  2.78464526e-01,  3.00836176e-01,
        -9.65622783e-01, -5.58438122e-01, -2.11467594e-01,
         1.60940096e-01,  5.22500753e-01, -2.49109771e-02,
         5.22755444e-01,  1.79177299e-01, -2.93194484e-02,
         5.31322658e-02,  1.13344476e-01, -2.00216576e-01,
        -1.85448006e-01, -1.02418292e+00, -7.46836722e-01,
         3.90033573e-01,  2.32009783e-01, -8.42792839e-02,
        -8.05121064e-01]])
    w3 = np.array([[-1.90384030e-01,  4.98476386e-01,  3.03679872e-02,
         3.04719098e-02,  2.15054348e-01,  7.22265363e-01,
         1.00482523e+00,  4.96305466e-01,  3.19815964e-01,
         2.99924850e-01,  2.42350563e-01,  7.23195255e-01,
         2.67375946e-01, -7.18309999e-01, -3.66581023e-01,
         3.27586859e-01,  5.61585069e-01,  4.30479079e-01,
         9.09745038e-01,  2.88673341e-01,  2.64480799e-01,
         2.64722168e-01,  1.50488624e-02,  5.68042219e-01,
         9.29752737e-02,  8.89248908e-01,  2.99093127e-02,
         5.95523894e-01, -1.04945672e+00,  5.15271187e-01,
         7.31138468e-01,  3.65221240e-02,  9.00604129e-01,
         5.82490742e-01,  5.78128219e-01,  8.37800920e-01,
         6.39949381e-01,  6.75862014e-01,  1.20467141e-01,
         4.36893582e-01,  1.05651654e-01,  1.07008648e+00,
         5.65054417e-01, -3.29835176e-01,  2.30141655e-01,
         8.35763097e-01, -1.52718024e-02,  5.97748421e-02,
         3.48033011e-01,  5.45280218e-01,  4.50052619e-01,
         3.18728507e-01,  2.91161239e-01, -8.75920475e-01,
         3.04549456e-01,  3.88069719e-01,  5.60573414e-02,
         4.07913268e-01,  9.28153872e-01, -5.19566596e-01,
         6.95363879e-01, -1.19043720e+00,  5.07078946e-01,
         1.48460135e-01],
       [ 4.68369544e-01,  4.70560610e-01,  2.79965788e-01,
         5.61827421e-01,  1.32617190e-01,  7.32666671e-01,
         4.20605510e-01,  2.24327952e-01,  3.89323205e-01,
         4.03839618e-01,  4.06617910e-01,  8.09523523e-01,
         2.73529351e-01, -9.93519485e-01, -1.03923798e+00,
         5.26415825e-01,  1.81736762e-03,  1.00036299e+00,
         1.27479529e+00,  1.84178799e-01,  8.48905623e-01,
         2.84257382e-01,  1.00046945e+00,  6.99812353e-01,
         1.75995559e-01,  3.67561281e-01, -1.82738471e+00,
         5.02258182e-01,  2.04738647e-01,  3.48361135e-01,
         4.02531713e-01,  1.87462106e-01,  1.03469178e-01,
         6.82517827e-01,  6.09287024e-01,  7.51008466e-02,
         9.74410295e-01,  6.56029642e-01,  9.73360464e-02,
         8.13961849e-02, -1.11810517e+00,  5.06104231e-01,
         6.36106193e-01,  2.47418731e-01,  3.83656681e-01,
         3.56556326e-01,  2.91979790e-01,  2.17118740e-01,
         6.34008944e-01,  2.45916396e-01,  2.88847655e-01,
         1.95971444e-01,  3.14929336e-01, -3.31496477e-01,
        -6.97139859e-01,  5.49063683e-01,  2.11650681e+00,
         6.00629151e-01, -1.27547592e-01, -1.66773021e-01,
         3.34010273e-01,  1.11122496e-01,  4.65636402e-01,
         4.39973861e-01],
       [ 1.75474137e-01,  4.95243251e-01,  3.19405645e-01,
         1.22073002e-01,  2.52844065e-01,  5.81634939e-01,
         7.36908197e-01,  3.13676834e-01,  3.57863277e-01,
         8.18052739e-02,  5.31720638e-01,  3.47010165e-01,
         3.36881578e-01,  6.65909290e-01, -1.04833174e+00,
         2.91615188e-01,  6.28937304e-01,  6.82752430e-01,
         1.16261292e+00,  2.20833853e-01,  9.97639775e-01,
        -3.60523500e-02,  1.17125368e+00,  8.34239960e-01,
        -2.43125230e-01, -1.87633723e-01, -2.24422500e-01,
         4.38399285e-01,  9.81557965e-01,  3.22511911e-01,
         5.56807935e-01,  3.80956262e-01,  1.68217823e-01,
         6.38540924e-01,  6.82211399e-01,  4.15783226e-01,
         1.19736457e+00,  5.12995183e-01,  5.52588105e-02,
         5.53936303e-01,  4.04794365e-01,  3.62978995e-01,
         4.89216447e-01,  3.45741585e-02,  3.48009706e-01,
         7.64113665e-01,  8.26081783e-02,  1.99597612e-01,
         4.73005101e-02,  5.72596073e-01,  5.43809056e-01,
         3.23938191e-01,  3.06158960e-01, -5.50374448e-01,
         4.73555177e-01,  3.20706815e-01,  1.02601063e+00,
         8.80103171e-01, -8.64465088e-02,  4.11654264e-01,
        -8.07937309e-02, -2.27893218e-01, -6.27625227e-01,
         1.74710214e-01],
       [-2.18621641e-01,  6.87176466e-01, -4.07419056e-01,
         1.63998738e-01,  5.12513399e-01,  6.95870519e-02,
        -7.81435147e-02, -7.22880363e-01,  4.66684967e-01,
         6.05094254e-01,  8.94164562e-01,  1.24934387e+00,
         4.68651891e-01,  5.65518260e-01, -8.23161960e-01,
         5.32648385e-01,  1.46867320e-01,  7.20729351e-01,
         5.88862538e-01,  4.45671618e-01,  7.47937739e-01,
         2.86703348e-01,  4.61162865e-01,  5.87281048e-01,
        -2.49005413e+00, -1.16595626e+00, -2.12882772e-01,
         7.32780993e-01,  6.33778512e-01,  7.73602128e-01,
         6.01855695e-01,  5.86057186e-01,  3.96445453e-01,
         1.90724358e-01, -3.60599220e-01, -6.86317027e-01,
         1.06501961e+00,  3.62599730e-01,  1.29776239e+00,
        -1.11052799e+00,  5.43364584e-01, -3.14565897e-01,
         8.59831274e-01, -4.29139733e-01,  9.81377140e-02,
         9.14419055e-01,  6.07723475e-01,  2.15366483e-01,
         3.77902269e-01,  9.06423509e-01,  3.85558486e-01,
         6.17596626e-01,  6.25139832e-01, -3.81102264e-01,
         3.28279316e-01,  5.81438601e-01, -6.69842839e-01,
         2.32738137e-01,  1.19937801e+00,  4.26764488e-01,
        -2.32136711e-01,  7.68385947e-01,  6.86708272e-01,
         5.31902969e-01],
       [ 4.12105829e-01,  3.93263638e-01,  4.02976304e-01,
         7.60758042e-01,  3.92558157e-01,  6.83277786e-01,
         1.83286555e-02,  1.84039026e-01,  1.10420264e-01,
         4.36949402e-01,  3.94924343e-01,  6.38054088e-02,
        -9.71605107e-02, -9.73712206e-01, -1.19065928e+00,
         5.18636359e-03,  5.86151004e-01,  1.03474724e+00,
         1.06111562e+00,  4.42905068e-01,  4.34690230e-02,
         3.76244217e-01,  6.47420108e-01,  2.83446312e-01,
        -1.93977915e-02, -7.71145344e-01, -2.60587245e-01,
         2.92416096e-01,  1.10156223e-01,  6.14968121e-01,
         7.49945700e-01,  1.93357974e-01, -4.08074588e-01,
         9.73421514e-01,  4.85393286e-01, -4.97867167e-02,
         7.76760995e-01,  6.57512069e-01,  5.74706852e-01,
        -7.77334198e-02,  1.09073082e-02, -8.25591147e-01,
         5.89959621e-01,  7.72534832e-02,  2.21570119e-01,
         4.14456218e-01,  1.61301821e-01,  1.52483493e-01,
         7.60809243e-01,  3.99170786e-01,  3.28408033e-01,
         3.98087412e-01,  2.19986051e-01, -2.00318217e-01,
        -1.15865660e+00, -1.34930909e-01,  7.89589047e-01,
         7.47605801e-01,  4.85697269e-01,  5.35663784e-01,
         1.95474669e-01, -6.43845856e-01,  6.73989415e-01,
         5.59169710e-01],
       [ 1.85520649e-01,  7.38546252e-01,  1.93005845e-01,
         4.25584823e-01,  3.92508686e-01,  5.12155890e-01,
         6.91323280e-01,  2.33073696e-01,  2.23896191e-01,
         1.89703107e-01,  4.92852300e-01,  6.75289631e-01,
         2.53610522e-01,  1.31855868e-02, -5.18449843e-01,
         1.02693282e-01,  7.21496582e-01,  9.02603924e-01,
         1.21640456e+00,  2.74541855e-01,  5.92546940e-01,
         4.89055067e-01,  8.69899750e-01,  6.51755571e-01,
        -2.26830021e-01,  5.98461628e-01, -1.45595983e-01,
         1.92536041e-01, -4.19956326e-01, -3.47723037e-01,
         5.55969357e-01,  1.03218026e-01,  9.88333941e-01,
         6.14745677e-01,  6.38068974e-01,  6.54101372e-01,
         6.40852690e-01,  4.95151490e-01,  1.71713531e-01,
         4.13525194e-01,  2.18200777e-02,  1.30088818e+00,
         4.05605316e-01,  5.69980860e-01,  2.63604373e-01,
         4.13439393e-01,  3.61981422e-01,  3.26565355e-01,
         3.56941760e-01,  5.59754074e-01,  3.07885438e-01,
         4.22596514e-01,  2.89136618e-01,  4.64327067e-01,
         2.49925375e-01,  2.20597386e-01, -1.94874120e+00,
         3.41597497e-01,  4.71794069e-01, -2.14956790e-01,
         8.94117504e-02, -6.29582584e-01,  4.25510973e-01,
         2.83764809e-01],
       [ 3.52331311e-01, -8.15364718e-02,  4.60288465e-01,
         6.01741850e-01,  3.60056907e-01,  6.13714099e-01,
         4.88600552e-01,  3.87157023e-01,  9.43235382e-02,
         4.61915821e-01,  4.56575334e-01, -2.63330221e-01,
         2.84637988e-01, -1.12472439e+00,  7.72038877e-01,
         3.04856747e-01,  2.95519054e-01,  9.35436130e-01,
         2.47137845e-01,  5.59077203e-01,  9.47995603e-01,
         1.37488991e-01,  9.79072869e-01,  3.78797531e-01,
        -4.37500030e-01, -4.50309873e-01,  8.03698376e-02,
         9.02242064e-01,  6.00016057e-01, -3.14127766e-02,
        -8.43019690e-03,  2.49880552e-01,  9.34984922e-01,
         1.50355148e+00, -3.77790123e-01,  1.09994543e+00,
         1.42263758e+00,  8.66174221e-01, -1.21559060e+00,
         6.55344725e-01,  5.58150351e-01,  8.02390873e-01,
         1.35536897e+00,  2.08604857e-01,  7.89016336e-02,
         1.03810430e+00,  3.39801431e-01,  4.28765982e-01,
         7.67739534e-01,  1.26886535e+00,  1.45437166e-01,
        -1.85630456e-01,  4.32874799e-01,  1.19036126e+00,
        -6.52123511e-01,  1.52064726e-01, -1.38912594e+00,
         3.06995749e-01,  4.39217299e-01, -2.13062692e+00,
         2.38609090e-01,  5.59082627e-01,  7.39850223e-01,
         5.36204934e-01]])

    def linear(input_array, weight, bias=None, debug=False):
        if debug : print(input_array)
        output = np.matmul(input_array, np.transpose(weight))
        if debug : print(output.shape)
        if bias is not None:
            output += bias
        if debug : print(output)
        ret = output
        return ret

    state = np.array(observation.board)
    # forward pass in the network for the given state of the board
    x = linear(state, w1, b1)
    x = linear(x, w2, b2)
    x = linear(x, w3, b3)
    # avoid invalid step and take the best value
    mask = [(observation.board[c] == 0) for c in range(configuration.columns)]
    action = int(np.argwhere(x == max(x[mask])))
    
    return action

# %% [markdown]
# # Test your Agent

# %%
env.reset()
# Play as the first agent against default "random" agent.
env.run([my_agent, "random"])
env.render(mode="ipython", width=500, height=450)

# %% [markdown]
# # Debug/Train your Agent

# %%
# # Play as first position against random agent.
trainer = env.train([None, my_agent])

observation = trainer.reset()

while not env.done:
    my_action = my_agent(observation, env.configuration)
    print("My Action", my_action)
    observation, reward, done, info = trainer.step(my_action)
    # env.render(mode="ipython", width=100, height=90, header=False, controls=False)
env.render()

# %% [markdown]
# # Evaluate your Agent

# %%
evaluate("connectx", [my_agent, "negamax"], num_episodes=10)

# %%
def mean_reward(rewards):
    return sum(r[0] for r in rewards) / sum(r[0] + r[1] for r in rewards)

# # Run multiple episodes to estimate it's performance.
print("My Agent vs Random Agent:", mean_reward(evaluate("connectx", [my_agent, "random"], num_episodes=10)))
print("My Agent vs Negamax Agent:", mean_reward(evaluate("connectx", [my_agent, "negamax"], num_episodes=10)))

# %% [markdown]
# # Write Submission File

# %%
import inspect
import os

def write_agent_to_file(function, file):
    with open(file, "a" if os.path.exists(file) else "w") as f:
        f.write(inspect.getsource(function))
        print(function, "written to", file)

write_agent_to_file(my_agent, "submission.py")

# %% [markdown]
# # Submit to Competition
#
# 1. Commit this kernel.
# 2. View the commited version.
# 3. Go to "Data" section and find submission.py file.
# 4. Click "Submit to Competition"
# 5. Go to [My Submissions](https://kaggle.com/c/connectx/submissions) to view your score and episodes being played.
