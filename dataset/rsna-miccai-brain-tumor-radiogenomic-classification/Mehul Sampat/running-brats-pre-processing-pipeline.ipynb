# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import subprocess
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
os.system('apt install bc')
! cp /kaggle/input/captk-181-installerbin/CaPTk_1.8.1_Installer.bin /kaggle/working/
! chmod +x /kaggle/working/CaPTk_1.8.1_Installer.bin
! echo -e Y | /kaggle/working/CaPTk_1.8.1_Installer.bin

# %%
subprocess.call(["/kaggle/working/CaPTk/1.8.1/captk", "--appimage-extract"])

# %%
os.environ['PATH'] = "/kaggle/working/squashfs-root/usr/lib:" + os.environ['PATH'] 
os.environ['LD_LIBRARY_PATH'] = "/kaggle/working/squashfs-root/usr/lib:" + os.environ['LD_LIBRARY_PATH'] 
print(os.environ['PATH'])
print(os.environ['LD_LIBRARY_PATH'])

# !/kaggle/working/squashfs-root/usr/bin/BraTSPipeline -h

# %%
cmd = '/kaggle/working/squashfs-root/usr/bin/BraTSPipeline'

subj = '/kaggle/input/rsna-miccai-brain-tumor-radiogenomic-classification/test/00001'

t1c = os.path.join(subj,'T1wCE','Image-1.dcm')
t1w = os.path.join(subj,'T1w','Image-1.dcm')
t2w = os.path.join(subj,'T2w','Image-257.dcm')
fl  = os.path.join(subj,'FLAIR','Image-1.dcm')
op  = os.path.join('/kaggle/working/','00001')

if os.path.exists(op)==False:
    os.mkdir(op)

print(os.path.exists(t1c))
print(os.path.exists(t1w))
print(os.path.exists(t2w))
print(os.path.exists(fl))

# %%
# %%time
subprocess.call([cmd,'-t1c',t1c,'-t1',t1w,'-t2',t2w,'-fl',fl,'-s','0','-b','0','-o',op])
