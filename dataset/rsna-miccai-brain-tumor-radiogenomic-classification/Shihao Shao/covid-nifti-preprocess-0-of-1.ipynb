# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import glob
from tqdm import tqdm
folder_list=glob.glob('../input/dicom-nifti-0-of-1/*')

for n,i in tqdm(enumerate(folder_list)):
    
    folder_split = i.split('/0')
    if len(folder_split)==1:
        continue
    file_list = glob.glob(folder_list[n]+'/*')
    if len(file_list)!=4:
        continue
    series_id = folder_split[-1]
    print(i)
    t1_file = glob.glob(folder_list[n]+'/*t1w.*')[0]
    
    t1ce_file = glob.glob(folder_list[n]+'/*t1wce.*')[0]
    t2_file = glob.glob(folder_list[n]+'/*t2w.*')[0]
    flair_file = glob.glob(folder_list[n]+'/*flair.*')[0]
    #os.rename(t1_file,f'brain_{series_id}_0000.nii.gz')
    #os.rename(t1ce_file,f'brain_{series_id}_0001.nii.gz')
    #os.rename(t2_file,f'brain_{series_id}_0002.nii.gz')
    #os.rename(flair_file,f'brain_{series_id}_0003.nii.gz')
    
    # !cp '{t1_file}' 'brain_{series_id}_0000.nii.gz'
    # !cp '{t1ce_file}' 'brain_{series_id}_0001.nii.gz'
    # !cp '{t2_file}' 'brain_{series_id}_0002.nii.gz'
    # !cp '{flair_file}' 'brain_{series_id}_0003.nii.gz'

# %%
glob.glob('../input/dicom-nifti-0-of-1/00120/*')
