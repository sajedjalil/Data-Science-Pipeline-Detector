# %% [markdown]
# # You must run this code on google colab.
# # You can use this code for download any dataset on kaggle.
#
# # **feel free to upvote this kernel:)**

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

# %%
# !pip install -p kaggle

# %% [markdown]
# # You must get kaggle.json from your account/API and upload here.

# %%
from google.colab import files
files.upload()

# %%
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list

# %% [markdown]
# **I used this data set rsna-png-256x256x36-images from below link.**
#
# https://www.kaggle.com/smoschou55/pngtest

# %%
! kaggle datasets download -d smoschou55/pngtest

# %% [markdown]
# create new folder in google drive

# %%
! mkdir /content/drive/MyDrive/rsna

# %%
! unzip pngtest.zip -d /content/drive/MyDrive/rsna

# %%
# Import the os module
import os

# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))

# Change the current working directory
os.chdir('/content/drive/MyDrive/rsna')

# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))

# %% [markdown]
# show number of content in folder

# %%
os.chdir('/content/drive/MyDrive/rsna/png_voxel_converted_ds/train')
# !find . -type f -printf . | wc -c

# %%
# !ls '/content/drive/MyDrive/rsna/png_voxel_converted_ds/test'
