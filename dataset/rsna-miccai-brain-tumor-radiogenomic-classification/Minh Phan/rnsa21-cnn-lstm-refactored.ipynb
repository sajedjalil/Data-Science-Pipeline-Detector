# %%
# !pip install efficientnet-pytorch
# !pip install pydicom

# %%
# !git clone https://github.com/minhnhatphan/rnsa21-cnn-lstm.git

# %%
# !python ./rnsa21-cnn-lstm/src/train.py --setting-path ./rnsa21-cnn-lstm/settings/SETTINGS_kaggle.json

# %%
# !python ./rnsa21-cnn-lstm/src/predict.py --setting-path ./rnsa21-cnn-lstm/settings/SETTINGS_kaggle.json
