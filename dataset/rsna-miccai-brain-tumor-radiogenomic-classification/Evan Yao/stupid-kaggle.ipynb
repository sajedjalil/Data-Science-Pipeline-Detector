# %%
import pandas as pd

y_pred_final = [[0.6165322 ],
 [0.58640236],
 [0.4971151 ],
 [0.5019761 ],
 [0.5997576 ],
 [0.57956463],
 [0.5738496 ],
 [0.63216007],
 [0.5724483 ],
 [0.53937215],
 [0.56800044],
 [0.50228083],
 [0.6079527 ],
 [0.5081887 ],
 [0.50012374],
 [0.49977726],
 [0.501428  ],
 [0.50888914],
 [0.48869643],
 [0.49378428],
 [0.48974982],
 [0.4845357 ],
 [0.5114134 ],
 [0.4911342 ],
 [0.48813763],
 [0.50334907],
 [0.49524227],
 [0.48749876],
 [0.49653763],
 [0.5001523 ],
 [0.4988492 ],
 [0.4910848 ],
 [0.501881  ],
 [0.48845026],
 [0.5084366 ],
 [0.48300707],
 [0.50229406],
 [0.49242106],
 [0.5514736 ],
 [0.48747385],
 [0.5158133 ],
 [0.4921757 ],
 [0.52889735],
 [0.49002138],
 [0.4959559 ],
 [0.49447787],
 [0.5082381 ],
 [0.49450946],
 [0.5024773 ],
 [0.5084077 ],
 [0.60233307],
 [0.55959904],
 [0.5977588 ],
 [0.59408635],
 [0.55726826],
 [0.6295617 ],
 [0.6263069 ],
 [0.5520878 ],
 [0.6250029 ],
 [0.56432456],
 [0.50516295],
 [0.49877504],
 [0.4982482 ],
 [0.5362271 ],
 [0.606656  ],
 [0.60515136],
 [0.5828635 ],
 [0.588209  ],
 [0.55231154],
 [0.5999524 ],
 [0.5818498 ],
 [0.60136753],
 [0.589177  ],
 [0.573055  ],
 [0.5799902 ],
 [0.5716944 ],
 [0.5593755 ],
 [0.5797691 ],
 [0.54541236],
 [0.49781844],
 [0.48018306],
 [0.50378865],
 [0.5205465 ],
 [0.51803637],
 [0.49974832],
 [0.49953797],
 [0.51519495],]

# %%
submission = pd.read_csv("../input/rsna-miccai-brain-tumor-radiogenomic-classification/sample_submission.csv", dtype=str, index_col="BraTS21ID")
submission["MGMT_value"] = [1.0 for _ in range(len(submission))]

for i in range(len(submission)):
    try:
        submission["MGMT_value"].iloc[i] = y_pred_final[i][0]
    except Exception as e:
        print(e)

submission["MGMT_value"].to_csv("submission.csv")

# %%
submission
