# %%
import pandas as pd

# %%
submission = pd.read_csv('../input/rsna-fast-submission/submission.csv')

# %%
submission.head()

# %%
pd.read_csv(
    '../input/rsna-miccai-brain-tumor-radiogenomic-classification/sample_submission.csv',
    usecols=[0],
    index_col=0
).join(submission.set_index('BraTS21ID')).fillna(0).to_csv('submission.csv')
