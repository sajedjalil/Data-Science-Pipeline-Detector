# %%
# !echo "dcmstack" > requirements.txt
# !pip download --requirement requirements.txt

# then after using "Add data" to selection the output of this notebook, pip install dcmstack in a new kernel with the following line:
# !pip install --quiet --no-index --find-links ../input/pip-download-dcmstack/ --requirement ../input/pip-download-dcmstack/requirements.txt
