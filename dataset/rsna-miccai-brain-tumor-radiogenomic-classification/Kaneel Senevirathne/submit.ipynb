# %%
import pandas as pd

# samp = pd.read_csv('../input/rsna-miccai-brain-tumor-radiogenomic-classification/sample_submission.csv')

# samp.info()
sample_sub = pd.read_csv('../input/data-analysis/submission.csv')

# %%
# sample_sub['MGMT_value'] = [0.1 if x < 0.1 else x for x in sample_sub['MGMT_value']]
# sample_sub['MGMT_value'] = [0.98 if x > 0.98 else x for x in sample_sub['MGMT_value']]

sample_sub['MGMT_value'] = 0.5

# %%
sample_sub.to_csv('submission.csv', index = False)
