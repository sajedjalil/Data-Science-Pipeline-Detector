# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupKFold

# %%
df = pd.read_csv('../input/rsna-miccai-brain-tumor-radiogenomic-classification/train_labels.csv')
gkf  = GroupKFold(n_splits = folds)
df['fold'] = -1
for fold, (train_idx, val_idx) in enumerate(gkf.split(df, groups = df.BraTS21ID.tolist())):
    df.loc[val_idx, 'fold'] = fold

# %%
for index, item in enumerate(df.BraTS21ID):
    n = item
    df.loc[index, "folder_name"] = (5 - len([i for i in str(n)])) * "0" + str(n)

# %%
df
