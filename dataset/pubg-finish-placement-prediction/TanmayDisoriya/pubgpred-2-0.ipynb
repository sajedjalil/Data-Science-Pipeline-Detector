# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
# read data in pandas dataframe
train =  pd.read_csv('../input/train_V2.csv')

# list first few rows (datapoints)
train.head(10)

# %%
#k= train[train["matchId"]<20]

# %%
#kg= k.drop_duplicates(subset=['groupId'], keep='first')

# %%
#kg.head(20)

# %%
#kg['rank'] = kg.groupby('matchId')['winPlacePerc'].rank(ascending=False)

# %%
#kg['normRank']=(1-(kg['rank']-1)/(kg['maxPlace']-1))

# %%
#kg['normRank1']=(1-(kg['rank']-1)/(kg['numGroups']-1))

# %%
#kg["K"]=1/(kg["maxPlace"]-1)
#kg["L"]=kg["normRank1"]/kg["K"]
#kg["L"]=round(kg["L"],0)
#kg["Max2"] = kg["K"]*kg["L"]

# %%
#a= kg.sort_values(['matchId', 'winPlacePerc'], ascending=[1, 0])

# %%
#a[a['matchId']==4]

# %%
test =  pd.read_csv('../input/test_V2.csv')

# %% [markdown]
# yufor i in ['assists', 'boosts', 'damageDealt', 'DBNOs','headshotKills', 'heals', 'killPlace', 'killPoints', 'kills','killStreaks', 'longestKill', 'maxPlace', 'numGroups', 'revives','rideDistance', 'roadKills', 'swimDistance', 'teamKills','vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints'] :
#     a='std1'+i
#     print(a)
#     test[a] = test.groupby(['matchId'])[i].transform('std')
#     train[a] = train.groupby(['matchId'])[i].transform('std')
#     test[a] = test[a].fillna(0)
#     train[a] = train[a].fillna(0)
#
# for i in ['assists', 'boosts', 'damageDealt', 'DBNOs','headshotKills', 'heals', 'killPlace', 'killPoints', 'kills','killStreaks', 'longestKill', 'maxPlace', 'numGroups', 'revives','rideDistance', 'roadKills', 'swimDistance', 'teamKills','vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints'] :
#     a='Mean1'+i
#     print(a)
#     test[a] = test.groupby(['matchId'])[i].transform('mean')
#     train[a] = train.groupby(['matchId'])[i].transform('mean')
#     test[a] = test[a].fillna(0)
#     train[a] = train[a].fillna(0)

# %%
train.columns

# %%
train.shape

# %%
train_matchtype = pd.get_dummies(train['matchType'])

# %%
test_matchtype = pd.get_dummies(test['matchType'])

# %%
for i in ['assists', 'boosts', 'damageDealt', 'DBNOs',
       'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
       'killStreaks', 'longestKill', 'matchDuration', 'maxPlace',
       'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
       'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
       'weaponsAcquired', 'winPoints']:
    a='std'+i
    print(a)
    test[a] = test.groupby(['groupId'])[i].transform('std')
    train[a] = train.groupby(['groupId'])[i].transform('std')
    test[a] = test[a].fillna(0)
    train[a] = train[a].fillna(0)

# %%
train.head()

# %%
for i in ['assists', 'boosts', 'damageDealt', 'DBNOs',
       'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
       'killStreaks', 'longestKill', 'matchDuration', 'maxPlace',
       'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
       'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
       'weaponsAcquired', 'winPoints']:
    a='Mean'+i
    print(a)
    test[a] = test.groupby(['groupId'])[i].transform('mean')
    train[a] = train.groupby(['groupId'])[i].transform('mean')
    test[a] = test[a].fillna(0)
    train[a] = train[a].fillna(0)

# %%
train=train.fillna(0)

# %%
#train['assists']=train['boosts']

# %%
for i in ['assists', 'boosts', 'damageDealt', 'DBNOs','matchType',
       'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
       'killStreaks', 'longestKill', 'matchDuration', 'maxPlace',
       'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
       'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
       'weaponsAcquired', 'winPoints']:
    print(i)
    train=train.drop(columns=i)
    test=test.drop(columns=i)

# %%
#test = test.fillna(method='ffill')
#train = train.fillna(method='ffill')

# %%
train['NumberOfPlayers'] = train.groupby('matchId')['matchId'].transform('count')
train['NumberOfPlayersInTeam'] = train.groupby(['matchId','groupId'])['groupId'].transform('count')

# %% [markdown]
# train['DifNumberOfPlayers'] = train.groupby(['matchId'])['NumberOfPlayersInTeam'].transform('max')
# train['DifKills'] = train.groupby(['matchId'])['kills'].transform('max')
# train['Difassists'] = train.groupby(['matchId'])['assists'].transform('max')
# train['DifdamageDealt'] = train.groupby(['matchId'])['damageDealt'].transform('max')
# train['DifwinPoints'] = train.groupby(['matchId'])['winPoints'].transform('max')
# train['DifDBNOs'] = train.groupby(['matchId'])['DBNOs'].transform('max')
# train['DifNumberOfPlayers'] = train['DifNumberOfPlayers'] - train['NumberOfPlayersInTeam']
# train['DifKills'] = train['DifKills']- train['kills']
# train['Difassists'] = train['Difassists'] - train['assists']
# train['DifdamageDealt'] =train['DifdamageDealt'] - train['damageDealt']
# train['DifwinPoints'] = train['DifwinPoints']-train['winPoints']
# train['DifDBNOs'] =train['DifDBNOs'] - train['DBNOs']

# %%
test['NumberOfPlayers'] = test.groupby('matchId')['matchId'].transform('count')
test['NumberOfPlayersInTeam'] = test.groupby(['matchId','groupId'])['groupId'].transform('count')

# %% [markdown]
# test['DifNumberOfPlayers'] = test.groupby(['matchId'])['NumberOfPlayersInTeam'].transform('max')
# test['DifKills'] = test.groupby(['matchId'])['kills'].transform('max')
# test['Difassists'] = test.groupby(['matchId'])['assists'].transform('max')
# test['DifdamageDealt'] = test.groupby(['matchId'])['damageDealt'].transform('max')
# test['DifwinPoints'] = test.groupby(['matchId'])['winPoints'].transform('max')
# test['DifDBNOs'] = test.groupby(['matchId'])['DBNOs'].transform('max')
# test['DifNumberOfPlayers'] = test['DifNumberOfPlayers'] - test['NumberOfPlayersInTeam']
# test['DifKills'] = test['DifKills']- test['kills']
# test['Difassists'] = test['Difassists'] - test['assists']
# test['DifdamageDealt'] =test['DifdamageDealt'] - test['damageDealt']
# test['DifwinPoints'] = test['DifwinPoints']-test['winPoints']
# test['DifDBNOs'] =test['DifDBNOs'] - test['DBNOs']

# %%
train = pd.concat([train,train_matchtype],axis=1)

# %%
test = pd.concat([test,test_matchtype],axis=1)

# %%
train.columns

# %% [markdown]
# for i in ['assists', 'boosts', 'damageDealt', 'DBNOs','headshotKills', 'heals', 'killPlace', 'killPoints', 'kills','killStreaks', 'longestKill','revives','rideDistance', 'roadKills', 'swimDistance', 'teamKills','vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints','NumberOfPlayers', 'NumberOfPlayersInTeam'] :
#     a='Max'+i
#     b='Min'+i
#     print(a,b)
#     test[a] = test.groupby(['matchId'])[i].transform('max')
#     test[b] = test.groupby(['matchId'])[i].transform('min')
#     train[a] = train.groupby(['matchId'])[i].transform('max')
#     train[b] = train.groupby(['matchId'])[i].transform('min')

# %%
test.head()

# %%
train.shape

# %%
#test[test['groupId']==1659508]

# %%
traing= train.drop_duplicates(subset=['groupId'], keep='first')
del train

# %%
testg= test.drop_duplicates(subset=['groupId'], keep='first')

# %%
traing['NumberOfGroups'] = traing.groupby('matchId')['groupId'].transform('count')

# %%
testg['NumberOfGroups'] = testg.groupby('matchId')['groupId'].transform('count')

# %%
Y=traing["winPlacePerc"]
traing=traing.drop(columns="winPlacePerc")

train_objs_num = len(traing)

# %%
test.columns

# %%
for i in ['stdassists', 'stdboosts', 'stddamageDealt',
       'stdDBNOs', 'stdheadshotKills', 'stdheals', 'stdkillPlace',
       'stdkillPoints', 'stdkills', 'stdkillStreaks', 'stdlongestKill',
       'stdmatchDuration', 'stdmaxPlace', 'stdnumGroups', 'stdrankPoints',
       'stdrevives', 'stdrideDistance', 'stdroadKills', 'stdswimDistance',
       'stdteamKills', 'stdvehicleDestroys', 'stdwalkDistance',
       'stdweaponsAcquired', 'stdwinPoints', 'Meanassists', 'Meanboosts',
       'MeandamageDealt', 'MeanDBNOs', 'MeanheadshotKills', 'Meanheals',
       'MeankillPlace', 'MeankillPoints', 'Meankills', 'MeankillStreaks',
       'MeanlongestKill', 'MeanmatchDuration', 'MeanmaxPlace', 'MeannumGroups',
       'MeanrankPoints', 'Meanrevives', 'MeanrideDistance', 'MeanroadKills',
       'MeanswimDistance', 'MeanteamKills', 'MeanvehicleDestroys',
       'MeanwalkDistance', 'MeanweaponsAcquired', 'MeanwinPoints',
         ]:
    a='std2'+i
    print(a)
    testg[a] = testg.groupby(['matchId'])[i].transform('std')
    traing[a] = traing.groupby(['matchId'])[i].transform('std')
    testg[a] = testg[a].fillna(0)
    traing[a] = traing[a].fillna(0)
    
for i in ['stdassists', 'stdboosts', 'stddamageDealt',
       'stdDBNOs', 'stdheadshotKills', 'stdheals', 'stdkillPlace',
       'stdkillPoints', 'stdkills', 'stdkillStreaks', 'stdlongestKill',
       'stdmatchDuration', 'stdmaxPlace', 'stdnumGroups', 'stdrankPoints',
       'stdrevives', 'stdrideDistance', 'stdroadKills', 'stdswimDistance',
       'stdteamKills', 'stdvehicleDestroys', 'stdwalkDistance',
       'stdweaponsAcquired', 'stdwinPoints', 'Meanassists', 'Meanboosts',
       'MeandamageDealt', 'MeanDBNOs', 'MeanheadshotKills', 'Meanheals',
       'MeankillPlace', 'MeankillPoints', 'Meankills', 'MeankillStreaks',
       'MeanlongestKill', 'MeanmatchDuration', 'MeanmaxPlace', 'MeannumGroups',
       'MeanrankPoints', 'Meanrevives', 'MeanrideDistance', 'MeanroadKills',
       'MeanswimDistance', 'MeanteamKills', 'MeanvehicleDestroys',
       'MeanwalkDistance', 'MeanweaponsAcquired', 'MeanwinPoints',
         ]:
    a='Mean2'+i
    print(a)
    testg[a] = testg.groupby(['matchId'])[i].transform('mean')
    traing[a] = traing.groupby(['matchId'])[i].transform('mean')
    testg[a] = testg[a].fillna(0)
    traing[a] = traing[a].fillna(0)

# %%
temp1=testg['groupId']

# %%
temp2=pd.DataFrame()
temp2['groupId']=testg['groupId']
temp2['NumberOfGroups']=testg['NumberOfGroups']
temp2['maxPlace']=testg['MeanmaxPlace']

# %%
testg=testg.drop(columns=["Id"])
testg=testg.drop(columns=["groupId"])
testg=testg.drop(columns=["matchId"])

# %%
traing=traing.drop(columns=["Id"])
traing=traing.drop(columns=["groupId"])
traing=traing.drop(columns=["matchId"])

# %%
#data = pd.concat(objs=[traing, testg], axis=0)

# %%
traing.isna().sum().sum()

# %%
#del X

# %% [markdown]
# data=data.drop(columns=["Id"])
# data=data.drop(columns=["groupId"])
# data=data.drop(columns=["matchId"])
# #data=data.drop(columns=["heals"])
# #data=data.drop(columns=["numGroups"])

# %%
#train_preprocessed = data[:train_objs_num]
#test_preprocessed = data[train_objs_num:]

# %%
traing.shape

# %%
#del data

# %%
#del test

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(traing)

# %%
X_test = sc.transform(testg)

# %%
del traing

del testg

# %% [markdown]
# from pyearth import Earth
# model1 = Earth()
# model1.fit(X_train[:1000000],Y[:1000000])

# %% [markdown]
# model1.mse_

# %%
#model1.summary()

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.cross_validation import cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
X_train.shape[1]

# %%
model = Sequential()
model.add(Dense(163, input_dim=X_train.shape[1], kernel_initializer='normal', activation='linear'))
model.add(Dense(326, activation='relu'))
model.add(Dense(163, activation='relu'))

#model.add(Dropout(0.1))
#model.add(Dense(60, activation='relu'))
#model.add(Dense(30, activation='relu'))

model.add(Dense(1, activation='sigmoid'))
model.summary()

# %%
model.compile(loss='mae', optimizer='adam', metrics=['mae'])
model.fit(X_train,Y, epochs=1, batch_size=50)

# %%
model.compile(loss='mae', optimizer='adam', metrics=['mae'])
model.fit(X_train,Y, epochs=2, batch_size=100)

# %%
model.fit(X_train,Y, epochs=10, batch_size=1000)

# %%
model.fit(X_train,Y, epochs=20, batch_size=10000)

# %% [markdown]
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.datasets import make_regression
# regr = RandomForestRegressor(n_estimators=10)
# regr.fit(X_train,Y)

# %%
model.fit(X_train,Y, epochs=20, batch_size=100000)

# %%
model.fit(X_train,Y, epochs=5, batch_size=300000)

# %%
y_pred = model.predict(X_test)

# %%
y_pred= np.reshape(y_pred, np.shape(test_preprocessed.DBNOs)[0])

# %%
y_pred[y_pred > 1] = 1

# %%
y_pred

# %%
New= pd.DataFrame()
New['groupId']=temp1

# %%
New['pred']=y_pred

# %%
New.head()

# %%
test =  pd.read_csv('../input/test.csv')

# %%
New1= pd.DataFrame()
New1['Id']=test['Id']
New1['groupId']=test['groupId']
New1.head()

# %%
results= New1.merge( New,on='groupId')

# %%
results= results.merge( temp2,on='groupId')
results["N"]=1/results["NumberOfGroups"]
results["M"]=results["pred"]/results["N"]
results["M"]=round(results["M"],0)
results["M1"]=np.floor(results["M"])
results["M2"]=np.ceil(results["M"])
results["N1"] = results["N"]*results["M"]
results["N2"] = results["N"]*results["M1"]
results["N3"] = results["N"]*results["M2"]

results["K"]=1/results["maxPlace"]
results["L"]=results["pred"]/results["K"]
results["L"]=round(results["L"],0)
results["Max1"] = results["K"]*results["L"]

results["K"]=1/(results["maxPlace"]-1)
results["L"]=results["pred"]/results["K"]
results["L"]=round(results["L"],0)
results["Max2"] = results["K"]*results["L"]

results["K"]=1/(results["NumberOfGroups"]-1)
results["L"]=results["pred"]/results["K"]
results["L"]=round(results["L"],0)
results["Max3"] = results["K"]*results["L"]

# %%
results.loc[results.maxPlace==0 , 'Max2'] = 0

# %%
results=results.fillna(0)

# %%
#results.head()

# %%
results[results['maxPlace']==0]

# %%
results.head()

# %%
my_submission = pd.DataFrame({'Id': results.Id, 'winPlacePerc': results.N1})
#my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('submission.csv', index=False)

# %%
my_submission = pd.DataFrame({'Id': results.Id, 'winPlacePerc': results.N2})
#my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('submission1.csv', index=False)

# %%
my_submission = pd.DataFrame({'Id': results.Id, 'winPlacePerc': results.N3})
#my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('submission2.csv', index=False)

# %%
my_submission = pd.DataFrame({'Id': results.Id, 'winPlacePerc': results.pred})
#my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('submission3.csv', index=False)

# %%
my_submission = pd.DataFrame({'Id': results.Id, 'winPlacePerc': results.Max1})
#my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('submission4.csv', index=False)

# %%
my_submission = pd.DataFrame({'Id': results.Id, 'winPlacePerc': results.Max2})
#my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('submission5.csv', index=False)

# %%
my_submission = pd.DataFrame({'Id': results.Id, 'winPlacePerc': results.Max3})
#my_submission = pd.DataFrame({'Id': test.Id, 'SalePrice': predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('submission5.csv', index=False)

# %%
my_submission
