# %%
import pandas as pd
import numpy as np
df_sub=pd.read_csv('../input/pubg-finish-placement-prediction/sample_submission_V2.csv')
#df_sub3= pd.read_csv('../input/xgboost-sub/submission888.csv')
df_sub2=pd.read_csv('../input/lgbm-new-features-eng/submission (6).csv')
df_sub4=pd.read_csv('../input/last-submission/submission1124587.csv')
#df.to_csv('submission.csv', index=False)

# %%
import pandas as pd
df_sub=pd.read_csv('../input/pubg-finish-placement-prediction/sample_submission_V2.csv')
df_sub3= pd.read_csv('../input/lgbm-new-features-eng/submission (6).csv')
df_sub2=pd.read_csv('../input/111111lightlgbmpubg/submission_lgbm22.csv')
df_sub4=pd.read_csv('../input/xgb-new-parameters/submission999.csv')
#df.to_csv('submission.csv', index=False)
# STACK
df_sub["winPlacePerc"] = ( df_sub4["winPlacePerc"]*0.2+df_sub2["winPlacePerc"]*0.3+df_sub3["winPlacePerc"]*0.5)

#df_sub["winPlacePerc"] = ( df_sub4["winPlacePerc"]+df_sub2["winPlacePerc"])/2

df_sub[["Id", "winPlacePerc"]].to_csv("submission.csv", index=False)
