# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
df=pd.read_csv('/kaggle/input/pubg-finish-placement-prediction/train_V2.csv')

# %%
df

# %%
df.columns

# %%
df.isnull().sum()

# %% [markdown]
# Data Wrangling:
# 1. One nan value in winPlacePerc
# 2. Invalid datas in walkDistance
#
# Structuring:
# 1. all the distance into total distance
# 2. new column 'headshot_rate'

# %%
df.dtypes

# %%
df_copy=df.copy()

# %%
df_copy['matchType'].unique()

# %%
f, ax = plt.subplots(figsize=(15, 15))
ax = sns.heatmap(df_copy.corr(), annot=True)

# %% [markdown]
# High Correlation between:
# 1. walkDistance and winPlacePerc
# 2. boosts and winPlacePerc
# 3. weaponsAquired and winPlacePerc
# 4. weaponsAcquired with kills

# %%
print('A player kills on average is {} kills'.format(df_copy['kills'].mean()))

# %%
plt.figure(figsize=(10,8))
sns.countplot(df_copy['kills'])
plt.show()

# %% [markdown]
# MOST of the players manage 0 kills throughout the game

# %%
print("PLayers with 0 kills inflicted {} damage".format(df_copy[df_copy['kills']==0]['damageDealt'].mean()))
print("PLayers with more than 0 kills inflicted {} damage".format(df_copy['damageDealt'].mean()))

# %%
print(df_copy['damageDealt'].skew())
print(df_copy['damageDealt'].kurt())

# %% [markdown]
# damageDealt doesnot follow Normal Distribution

# %%
print("{}({} %) players with 0 kills have won the game".format(len(df_copy[(df_copy['kills']==0) & (df_copy['winPlacePerc']==1)]),(len(df_copy[(df_copy['kills']==0) & (df_copy['winPlacePerc']==1)])/len(df_copy))*100))
print("{}({} %) players with 0 damageDealt have won the game".format(len(df_copy[(df_copy['damageDealt']==0.0) & (df_copy['winPlacePerc']==1)]),(len(df_copy[(df_copy['damageDealt']==0) & (df_copy['winPlacePerc']==1)])/len(df_copy))*100))

# %%
plt.scatter(x=df_copy['winPlacePerc'],y=df_copy['kills'])
plt.xlabel('Winning Chances')
plt.ylabel('Kills')
plt.show()

# %% [markdown]
# The players with more kills, survives more and wins the game

# %%
print(df_copy['walkDistance'].skew())
print(df_copy['walkDistance'].kurt())
plt.scatter(x=df_copy['winPlacePerc'],y=df_copy['walkDistance'])

# %% [markdown]
# The player who moves for long distance ,chances of winning is high

# %%
plt.scatter(x=df_copy['winPlacePerc'],y=df_copy['rideDistance'])

# %% [markdown]
# The player who moves for long ridedistance ,chances of winning is high

# %%
plt.scatter(x=df_copy['winPlacePerc'],y=df_copy['boosts'])

# %%
plt.scatter(x=df_copy['winPlacePerc'],y=df_copy['heals'])

# %% [markdown]
# The number of heals helps the player survive for more match duration which might contribute to winning

# %%
sns.catplot(x='matchType',y='winPlacePerc',kind='box',data=df_copy)
plt.show()

# %% [markdown]
# There isn't any relation between matchType with winning

# %%
sns.jointplot(x="winPlacePerc",y="DBNOs", data=df_copy)

# %% [markdown]
# The number of DBNOs doesnot contribute to winning

# %%
sns.jointplot(x="winPlacePerc",y="assists", data=df_copy)

# %% [markdown]
# The number of assist doesnot contribute to winning

# %%
sns.jointplot(x="winPlacePerc",y="revives", data=df_copy)

# %% [markdown]
# The number of revives doesnot contribute to winning

# %%
df_copy['total_dist']=df_copy['rideDistance']+df_copy['walkDistance']+df_copy['swimDistance']

# %%
df_copy['headshot_rate']=df_copy['headshotKills']/df_copy['kills']

# %%
df_copy.isnull().any()

# %%
df_copy['headshot_rate']=df_copy['headshot_rate'].fillna(0)

# %% [markdown]
# Invalid Data:

# %%
df_copy.drop(df_copy[(df_copy['walkDistance']==0.0) & (df_copy['rideDistance']>0)].index,inplace=True)

# %%
df_copy.drop(df_copy[(df_copy['total_dist']==0.0) & (df_copy['kills']>0)].index,inplace=True)

# %%
f, ax = plt.subplots(figsize=(15, 15))
ax = sns.heatmap(df_copy.corr(), annot=True)

# %%
CONCLUSION: boosts,damageDealt,heals,kills,longestKill,total_distance contributes to winning chances
