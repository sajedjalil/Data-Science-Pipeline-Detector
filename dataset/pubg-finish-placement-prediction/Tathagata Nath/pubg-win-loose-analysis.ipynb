# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
train=pd.read_csv('/kaggle/input/pubg-finish-placement-prediction/train_V2.csv')

# %%
train.shape

# %%
train_copy=train.copy()

# %%
train_copy.shape

# %% [markdown]
# # ISSUES
#
# ### CONTENT RELATED
#
# - 1 missing value in winPlacePerc
# - In case of solo games assists, revives and team-kills can not be done, hence those should be zero but in some solo games those are not zero
# - In case of duo games team-kills can not be more than 1, but it is more than 1 in some cases
#
#
#
#
# ### STRUCTURE RELATED
#
# - Wrong datatype for matchType

# %%
train_copy=train_copy[train_copy['winPlacePerc'].isnull()==False]

# %%
train_copy.shape

# %%
train_copy=train_copy.astype({'matchType':'category'})

# %%
train_copy.info()

# %%
index=train_copy[train_copy['matchType'].isin(['solo-fpp','solo','normal-solo-fpp','normal-solo'])].index.tolist()

for i in index :
    train_copy.at[i,'assists']=0
    train_copy.at[i,'revives']=0
    train_copy.at[i,'teamKills']=0

# %%
index=train_copy[train_copy['matchType'].isin(['duo-fpp','duo'])].index.tolist()

for i in index :
    if train_copy.at[i,'teamKills'] > 1 :
        train_copy.at[i,'teamKills']=1

# %%
train_copy.describe()

# %% [markdown]
# ## NUMERICAL COLUMNS
#
# - assists
# - boosts
# - damageDealt
# - DBNOs
# - headshotKills
# - heals
# - killPlace
# - killPoints
# - kills
# - killStreaks
# - longestKill
# - matchDuration
# - maxPlace
# - numGroups
# - rankPoints
# - revives
# - rideDistance
# - roadKills
# - swimDistance
# - teamKills
# - vehicleDestroys
# - walkDistance
# - weaponsAcquired
# - winPoints
# - winPlacePerc
#
# ## CATEGORICAL COLUMNS
#
# - matchType
#
# ## IDENTITY COLUMNS
#
# - Id
# - groupId
# - matchId

# %% [markdown]
# ### assists

# %%
print(train_copy['assists'].value_counts())
print(train_copy['assists'].skew())
sns.boxplot(train_copy['assists'])

# %% [markdown]
# #### conclusion
#
# - highly positively skewed data
# - a lot of values are zero
# - more analysis is required to find out which non zero values should be considered as outliers

# %% [markdown]
# ### boosts

# %%
print(train_copy['boosts'].value_counts())
print(train_copy['boosts'].skew())
sns.boxplot(train_copy['boosts'])

# %% [markdown]
# #### conclusion
#
# - positively skewed data
# - values more than 25 are outliers
# - more analysis is required to find whether values within (Q3+1.5*IQR) and 25 are to be considered as outliers or not

# %%
train_copy=train_copy[train_copy['boosts']<25]

# %% [markdown]
# ### damageDealt

# %%
print(train_copy['damageDealt'].value_counts())
print(train_copy['damageDealt'].skew())
sns.boxplot(train_copy['damageDealt'])

# %% [markdown]
# #### conclusion
#
# - highly positively skewed data
# - values greater than 6000 are outliers
# - more analysis is required to find out whether the values within (Q3+1.5*IQR) and 6000 are to be considered as outliers or not

# %%
train_copy=train_copy[train_copy['damageDealt']<6000]

# %% [markdown]
# ### DBNOs

# %%
print(train_copy['DBNOs'].value_counts())
print(train_copy['DBNOs'].skew())
sns.boxplot(train_copy['DBNOs'])

# %% [markdown]
# #### conclusion
#
# - Highly positively skewed data
# - Data beyond 50 are outliers
# - More analysis is required to find out whether to consider data within (Q3+1.5*IQR) and 40 as outliers or not

# %%
train_copy=train_copy[train_copy['DBNOs']<50]

# %% [markdown]
# ### headshotKills

# %%
print(train_copy['headshotKills'].value_counts())
print(train_copy['headshotKills'].skew())
sns.boxplot(train_copy['headshotKills'])

# %% [markdown]
# #### conclusion
#
# - Extremely positively skewed data
# - Data beyond 60 are outliers
# - More analysis is required to find out whether to consider data within (Q3+1.5*IQR) and 50 as outliers or not

# %%
train_copy=train_copy[train_copy['headshotKills']<60]

# %% [markdown]
# ### heals

# %%
print(train_copy['heals'].value_counts())
print(train_copy['heals'].skew())
sns.boxplot(train_copy['heals'])

# %% [markdown]
# #### conclusions
#
# - Highly positively skewed data
# - Data beyond 70 are outliers
# - More analysis is required to find out whether to consider data within (Q3+1.5*IQR) and 65 as outliers or not

# %%
train_copy=train_copy[train_copy['heals']<70]

# %% [markdown]
# ### killPlace

# %%
print(train_copy['killPlace'].value_counts())
print(train_copy['killPlace'].skew())
sns.boxplot(train_copy['killPlace'])

# %% [markdown]
# #### concusion
#
# - Normally distributed data
# - No outliers

# %%
m=train['killPlace'].mean()
sd=train['killPlace'].std()

train[(train['killPlace']<(m-3*sd)) | (train['killPlace']>(m+3*sd))]

# %% [markdown]
# ### killPoints

# %%
print(train_copy['killPoints'].value_counts())
print(train_copy['killPoints'].skew())
sns.boxplot(train_copy['killPoints'])

# %% [markdown]
# #### conclusions
#
# - Almost normally distributed data
# - No outliers

# %%
m=train['killPoints'].mean()
sd=train['killPoints'].std()

train[(train['killPoints']<(m-3*sd)) | (train['killPoints']>(m+3*sd))]

# %% [markdown]
# ### kills

# %%
print(train_copy['kills'].value_counts())
print(train_copy['kills'].skew())
sns.boxplot(train_copy['kills'])

# %% [markdown]
# #### conclusions
#
# - Highly positively skewed data
# - Data beyond 50 are outliers
# - More analysis is reruired to find out whether to consider data within (Q3+1.5*IQR) and 50 as outliers or not

# %%
train_copy=train_copy[train_copy['kills']<50]

# %% [markdown]
# ### killStreaks

# %%
print(train_copy['killStreaks'].value_counts())
print(train_copy['killStreaks'].skew())
sns.boxplot(train_copy['killStreaks'])

# %% [markdown]
# #### conclusions
#
# - Positively skewed data
# - More analysis is required to find out outliers

# %% [markdown]
# ### longestKill

# %%
print(train_copy['longestKill'].value_counts())
print(train_copy['longestKill'].skew())
sns.boxplot(train_copy['longestKill'])

# %% [markdown]
# #### conclusions
#
# - Highly positively skewed data
# - More analysis is required to find out outliers

# %% [markdown]
# ### matchDuration

# %%
print(train_copy['matchDuration'].value_counts())
print(train_copy['matchDuration'].skew())
sns.boxplot(train_copy['matchDuration'])

# %% [markdown]
# #### conclusion
#
# - Normally distributed data
# - More analysis is required to find out whether to consider data less than (Q1-1.5*IQR) as outliers or not

# %% [markdown]
# ### maxPlace

# %%
print(train_copy['maxPlace'].value_counts())
print(train_copy['maxPlace'].skew())
sns.boxplot(train_copy['maxPlace'])

# %% [markdown]
# #### conclusions
#
# - Positively skewed data
# - More analysis is required to find out whether to consider the data beyond 80 as outliers or not

# %% [markdown]
# ### numGroups

# %%
print(train_copy['numGroups'].value_counts())
print(train_copy['numGroups'].skew())
sns.boxplot(train_copy['numGroups'])

# %% [markdown]
# #### conclusions
#
# - Positively skewed data
# - More analysis is required to find out whether to consider the data beyond 80 as outliers or not

# %% [markdown]
# ### rankPoints

# %%
print(train_copy['rankPoints'].value_counts())
print(train_copy['rankPoints'].skew())
sns.boxplot(train_copy['rankPoints'])

# %% [markdown]
# #### conclusions
#
# - Normally Distributed Data
# - More analysis is required to find out whether to consider the data beyond (Q3+1.5*IQR) and as outliers or not

# %% [markdown]
# ### revives

# %%
print(train_copy['revives'].value_counts())
print(train_copy['revives'].skew())
sns.boxplot(train_copy['revives'])

# %% [markdown]
# #### conclusions
#
# - Extremely positively skewed data
# - Data beyond 20 may be considered as outliers
# - More analysis is required to find out whether to consider the data within (Q3+1.5*IQR) and 20 as outliers or not

# %%
train_copy=train_copy[train_copy['revives']<20]

# %% [markdown]
# ### rideDistance

# %%
print(train_copy['rideDistance'].value_counts())
print(train_copy['rideDistance'].skew())
sns.boxplot(train_copy['rideDistance'])

# %% [markdown]
# #### conclusion
#
# - Highly positively skewed data
# - Data beyond 40000 are outliers
# - More analysis is required to find out whether to consider the data within 40000 as outliers or not

# %%
train_copy=train_copy[train_copy['rideDistance']<40000]

# %% [markdown]
# ### roadKills

# %%
print(train_copy['roadKills'].value_counts())
print(train_copy['roadKills'].skew())
sns.boxplot(train_copy['roadKills'])

# %% [markdown]
# #### conclusion
#
# - Dangerously positively skewed data
# - Data beyond 12.5 are outliers
# - More analysis is required to find out whether to consider data within 12.5 as outliers or not

# %%
train_copy=train_copy[train_copy['roadKills']<12.5]

# %% [markdown]
# ### swimDistance

# %%
print(train_copy['swimDistance'].value_counts())
print(train_copy['swimDistance'].skew())
sns.boxplot(train_copy['swimDistance'])

# %% [markdown]
# #### conclusion
#
# - Dangerously positively skewed data
# - Data beyond 3000 are outliers
# - More analysis is required to find out whether to consider data within 3000 as outliers or not

# %%
train_copy=train_copy[train_copy['swimDistance']<3000]

# %% [markdown]
# ### teamKills

# %%
print(train_copy['teamKills'].value_counts())
print(train_copy['teamKills'].skew())
sns.boxplot(train_copy['teamKills'])

# %% [markdown]
# #### conclusions
#
# - Extremely positively skewed data
# - More analysis is required to find out outliers

# %% [markdown]
# ### vehicleDestroys

# %%
print(train_copy['vehicleDestroys'].value_counts())
print(train_copy['vehicleDestroys'].skew())
sns.boxplot(train_copy['vehicleDestroys'])

# %% [markdown]
# #### conclusion
#
# - Highly positively skewed data
# - More analysis is required to find out outliers

# %% [markdown]
# ### walkDistance

# %%
print(train_copy['walkDistance'].value_counts())
print(train_copy['walkDistance'].skew())
sns.boxplot(train_copy['walkDistance'])

# %% [markdown]
# #### conclusions
#
# - Positively Skewed Data
# - Data beyond 25000 are outliers
# - More analysis is required to find out whether to consider the data within (Q3+1.5*IQR) and 15000 as outliers or not

# %%
train_copy=train_copy[train_copy['walkDistance']<25000]

# %% [markdown]
# ### weaponsAcquired

# %%
print(train_copy['weaponsAcquired'].value_counts())
print(train_copy['weaponsAcquired'].skew())
sns.boxplot(train_copy['weaponsAcquired'])

# %% [markdown]
# #### conclusion
#
# - Positively skewed Data
# - Data beyond 200 are outliers
# - Data within 100 to 200 may be considered as outliers
# - More analysis is required to find out whether the data between (Q3+1.5*IQR) and 100 can be considered as outliers or not

# %%
train_copy=train_copy[train_copy['weaponsAcquired']<200]

# %% [markdown]
# ### winPoints

# %%
print(train_copy['winPoints'].value_counts())
print(train_copy['winPoints'].skew())
sns.boxplot(train_copy['winPoints'])

# %% [markdown]
# #### conclusions
#
# - Normally distributed data
# - No outliers
# - A wide IQR
# - Median not detected seperately

# %%
m=train['winPoints'].mean()
sd=train['winPoints'].std()

train[(train['winPoints']<(m-3*sd)) | (train['winPoints']>(m+3*sd))]

# %% [markdown]
# ### winPlacePerc

# %%
print(train_copy['winPlacePerc'].value_counts())
print(train_copy['winPlacePerc'].skew())
sns.boxplot(train_copy['winPlacePerc'])

# %% [markdown]
# #### conclusions
#
# - Normally distributed data
# - No outliers

# %%
m=train['winPlacePerc'].mean()
sd=train['winPlacePerc'].std()

train[(train['winPlacePerc']<(m-3*sd)) | (train['winPlacePerc']>(m+3*sd))]

# %%
x=train_copy.pivot_table(index=['matchType'], aggfunc='sum')

# %%
x.drop(columns=['maxPlace','numGroups','killPlace','killPoints','longestKill','matchDuration','rankPoints','winPoints','winPlacePerc'], inplace=True)

# %%
x

# %%
x=x.reset_index()

# %%
x

# %% [markdown]
# ### matchType vs assists

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('assists')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='assists',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Assists', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusions
#
# - In solo matches there is no question of any assistance
# - In duo there are only 2 players, hence they assis each other quite a lot
# - There is high assistance in squard matches
#
# ##### If a player lacks ample resources and needs assistance to survive in the game, then he should go for duo or squard matches instead of solo matches

# %% [markdown]
# ### matchType vs DBNOs

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('DBNOs')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='DBNOs',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('DBNOs', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### The graphs of DBNOs and assists are almost similar, proving that there is a really high corealtion between these two aspects, with the increase in assistance more enemy players are knocked down and hence there is more chances of win, hence more the number of teammates a player has, more likely he is to win and vice-versa

# %% [markdown]
# ### matchType vs boosts

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('boosts')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='boosts',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Boosts', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### A lot of boost items are used are used in solo and duo games and squard-fpp games indicating the high amount of injuries occouring in these modes and thereby reduing the chance of survival of the player as compared to other modes

# %% [markdown]
# ### matchType vs damageDealt

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('damageDealt')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='damageDealt',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Damage Dealt', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.5, i.get_height(), int(i.get_height()), rotation=45, fontsize=20, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### crashtpp is the safest having most chance of survival where as squard-fpp is the most dangerous one having least chance of survival, solo and duo modes are also dangerous

# %% [markdown]
# ### matchType vs headshotKills

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('headshotKills')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='headshotKills',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Headshot Kills', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### Number of headshots are higher in the solo, duo and squard games indicating that in these games the game is played in a more diciplined way and the aiming is more accurate, thereby knocking out the enemy more efficiently and incresing the chance of win

# %% [markdown]
# ### matchType vs heals

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('heals')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='heals',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Heals', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### In the solo, duo and squard games, the players need to take more healing items, indicating that in these modes, the players are more vulnerable
#
# ##### There is a huge amount of similarity between the graphs of headshotKills and heals, indicating that in the solo, duo and squared modes it is wise to stay in a safe territory and aim at the enemy from a distance and perform headshots rather than coming out in the open as there is lack of teammates to defend each other in these modes but in the other modes, due to assistance the players are not so vulnerable, not in need to take a lot of healing items and come face to face with the enemy and hence there are not much headshots as the firing is random and not diciplined

# %% [markdown]
# ### matchType vs revives

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('revives')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='revives',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Revives', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### In the solo modes, there is no one to revive a player, hence making the player most vulnerable, in the duo mode either player revive each other a lot, in other modes the number of times a player revives a teammate decreases as the number of players increases, sharing the responsibility among themselves. With the increase in the number of players the assurance of getting revived gets stronger as the amount of resources increases with the increase in the number of players, thus making the player lesser and lesser vulnerable and making the team as a whole stronger, increasing the chance of winning

# %% [markdown]
# ### matchType vs roadKills

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('roadKills')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='roadKills',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Road Kills', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20,rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### The modes having high number of road kills show that in these modes a player should keep driving vehicles for as long as possible to be able to kill more and more enemies and increase the chance to win

# %% [markdown]
# ### matchType vs teamKills

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('teamKills')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='teamKills',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Team Kills', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### In solo games there is no question of killing teammates but in the duo and squard modes there is a high chance of killing teammates, stating that in the duo and squard modes, the players need to be extra cautions about not killing teammates to avoid loosing them and increase the chance to win

# %% [markdown]
# ### matcType vs weaponsAcquired

# %%
plt.figure(figsize=(25,6))

t=x.sort_values('weaponsAcquired')
order=t['matchType'].values.tolist()

chart = sns.barplot(
    data=t,
    x='matchType',
    y='weaponsAcquired',
    order=order,
)

chart.set_xticklabels(t['matchType'], rotation=90, fontsize=20)
chart.set_yscale('symlog')
chart.set_xlabel('Match Type', fontsize=28)
chart.set_ylabel('Weapons Acquired', fontsize=28)

for i in chart.patches :
    chart.text(i.get_x()+.4, i.get_height(), int(i.get_height()), fontsize=20, rotation=45, color='black', ha='center')

# %% [markdown]
# #### conclusion
#
# ##### In the solo, duo and squard games, the players are able to acquire a lot of weapons to strengthen themselves and increase their chance to win
#
# ##### The less the number of players in a team, the more is the chance to acquire weapons

# %% [markdown]
# ## OVERALL HEATMAP

# %%
plt.figure(figsize=(25,10))
sns.heatmap(x.corr(), cmap='autumn', annot=True, fmt='.4g')

# %% [markdown]
# ### CONCLUSIONS
#
# - A player should assist more in order to kill more enemies to increase chance of win
# - A player should be cautious about not killing his/her teammates
# - A player should try to acquire more and more weapons to secure win
# - A player should have a good supply of boosts, heals and revives for himself/herself and for his/her teammates
# - A player should ensure that less and less self-damage is done while eliminating enemies or riding vehicles or swimming
# - A player should try to kill enemies through headshots as it kills the enemy in just one go saving bullets and also strengthening his/ her team's position
