# %% [markdown]
# Set up the relevant libraries below

# %% [markdown]
# 1. Write a program to draw a line with a suitable label in the x-axis & y-axis, make it red & add a title/ axis labels. Data for the graph provided below

# %%
x = range(1, 50)
y = [value * 3 for value in x]

# write your code below

# %% [markdown]
# 2. Draw a bar chart of favourite colours at applied strategic (make up the data!), label your graph appropriately

# %%
# write your code below
