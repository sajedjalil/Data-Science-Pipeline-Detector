# %% [markdown]
# # Explainable AI Methods Application
#
# ## EDA
#
# * EDA: Exploratory Analysis of Flowers Dataset: https://www.kaggle.com/code/christianhritter/flowerclass-eda1
#
# ## Modeling
#
# * Modeling: EfficientNetV2 application. Saving model for later XAI analysis:
# https://www.kaggle.com/code/christianhritter/flowerclass-efficientnetv2-2
# * Model Error Analysis Part 1: https://www.kaggle.com/code/christianhritter/flowerclass-efficientnetv2-2-analysis
# * Model Error Analysis Part 2: https://www.kaggle.com/code/christianhritter/flowerclass-efficientnetv2-2-analysis2-imgvis
#
# ## XAI Methods Analysis:
#
# * XAI LIME method applied to Model: https://www.kaggle.com/code/christianhritter/flowerclass-efficientnetv2-2-analysis3-lime
# * XAI Anchor method applied to Model: https://www.kaggle.com/code/christianhritter/flowerclass-efficientnetv2-2-analysis3-anchors
# * XAI Kernel SHAP method applied to model: https://www.kaggle.com/code/christianhritter/flowerclass-efficientnetv2-2-analysis3-kernelshap
