# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/train.csv')
test = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/test.csv')
label = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/train_labels.csv')
submit = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/sample_submission.csv')

# %%
train.shape

# %%
test.shape

# %%
submit.shape

# %%
label.shape

# %%
label.head()

# %%
train.head()

# %%
train.info()

# %%
train.describe()

# %%
train.isnull().sum()

# %%
train = train.groupby('sequence').sum()

# %%
train.shape

# %%
train = train.reset_index()

# %%
train.head()

# %%
test.info()

# %%
test.isnull().sum()

# %%
test.head()

# %%
test = test.groupby('sequence').sum()

# %%
test = test.reset_index()

# %%
test.head()

# %%
test.shape

# %%
submit.shape

# %% [markdown]
# **Now we have to join train and label on column sequence so we know our state**

# %%
train = train.merge(label, on = 'sequence', how = 'left')

# %%
train.head()

# %%
train[train['state'] == 0]

# %% [markdown]
# **Dataset is Balance**

# %%
train.shape

# %%
train.isnull().sum()

# %%
train.drop(['sequence', 'subject'], axis = 1, inplace = True)

# %%
test.drop(['sequence', 'subject'], axis = 1, inplace = True)

# %%
train.shape

# %%
test.shape

# %%
train.head()

# %%
test.head()

# %%
train.drop('step', axis = 1, inplace = True)

# %%
test.drop('step', axis = 1, inplace = True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = train.drop('state', axis = 1)

# %%
y = train['state']

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
sns.pairplot(train)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
randomforest = RandomForestClassifier()

# %%
from sklearn.metrics import classification_report

# %%
randomforest.fit(X_train, y_train)

# %%
#knn.fit(X_train, y_train)

# %%
pred1 = randomforest.predict(X_test)

# %%
print(classification_report(y_test, pred1))

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators' : [100,120,150],
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [4,6,7,8,12]
    
}

# %%
grid = GridSearchCV(randomforest, param_grid, cv = 10, scoring = 'accuracy')

# %%
#grid.fit(X_train, y_train)

# %%
a = 5
a

# %% [raw]
# #ANN

# %%
#from tensorflow.keras import Sequential
#from tensorflow.keras.layers import Dense

# %%
#ann = Sequential()

# %%
#ann.add(Dense(35, activation = 'relu'))
#ann.add(Dense(12, activation = 'relu'))

# %%
#ann.add(Dense(1, activation = 'sigmoid'))

# %%
#ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#ann.fit(X_train, y_train, batch_size = 32, epochs = 40)

# %%
#len(train)/60

# %% [markdown]
# **Applying through Lstm**

# %%
#train = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/train.csv')
#test = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/test.csv')
#label = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/train_labels.csv')
#submit = pd.read_csv('/kaggle/input/tabular-playground-series-apr-2022/sample_submission.csv')

# %%
#seq = train["sequence"]
#df_train = train.drop(["sequence", "subject", "step"], inplace=False, axis=1).values
#df_test = test.drop(["sequence", "subject", "step"], inplace=False, axis=1).values
#df_labels = label["state"]

# %%
#df_labels = train['state'].values

# %%
#df_train.shape

# %%
#from sklearn.preprocessing import StandardScaler

# %%
#sc = StandardScaler()
#sc.fit(df_train)
#df_train = sc.transform(df_train)
#df_test = sc.transform(df_test)

# %%
#df_train = df_train.reshape(int(len(df_train)/60), 60, 13)
#df_test = df_test.reshape(int(len(df_test)/60), 60, 13)

# %%
#df_train.shape

# %%
#from tensorflow.keras.layers import LSTM, Conv1D, MaxPooling1D, GlobalMaxPooling1D

# %%
#import tensorflow as tf

# %%
#    model = Sequential()
 #   model.add(LSTM(1024, return_sequences = True))
  #  model.add(LSTM(512, return_sequences = True))
   # model.add(LSTM(256, return_sequences = True))
    #model.add(LSTM(128, return_sequences = True))
    #model.add(Conv1D(128, 3))
    #model.add(MaxPooling1D())
    #model.add(Conv1D(64, 3))
    #model.add(MaxPooling1D())
    #model.add(Conv1D(128, 3))
    #model.add(GlobalMaxPooling1D())
    #model.add(Dense(128, activation ='relu'))
    #model.add(Dense(1, activation ='sigmoid'))
    #model.compile(optimizer ="adam", loss ="binary_crossentropy", metrics =["accuracy"])

# %%
#model.fit(df_train, df_labels, batch_size = 256, epochs = 7)

# %%
#model.fit(df_train, df_labels, batch_size = 256, epochs = 3)

# %%
#predict = model.evaluate(df_test)

# %%
from xgboost  import XGBClassifier

# %%
params = {'n_estimators': 4096,
          'max_depth': 7,
          'learning_rate': 0.15,
          'subsample': 0.95,
          'colsample_bytree': 0.60,
          'reg_lambda': 1.50,
          'reg_alpha': 6.10,
          'gamma': 1.40,
          'random_state': 69,
          'objective': 'binary:logistic',
          
         }

# %%
xgb = XGBClassifier(**params)

# %%
xgb.fit(X_train, y_train)

# %%
prediction = xgb.predict(X_test)

# %%
print(classification_report(y_test, prediction))

# %%
pred1

# %%
submit.head()

# %%
pred2 = randomforest.predict(test)

# %%
len(pred2)

# %%
submit.shape

# %%
submit['state'] = pred2

# %%
submit.head()

# %%
submit.to_csv('final.csv', index = False)
