# %% [markdown]
# # Hi guys !

# %% [markdown]
# credit :
# > https://www.kaggle.com/code/dmitryuarov/tps-sensors-2xlstm-xgb-auc-0-976/notebook
# > https://www.kaggle.com/code/tyrionlannisterlzy/xgboost-dnn-ensemble-lb-0-974

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ## Load Data

# %%
data_1 = pd.read_csv("../input/tps-sensors-2xlstm-xgb-auc-0-976/blend_sub12.csv")
data_2 = pd.read_csv("../input/xgboost-dnn-ensemble-lb-0-974/my_submission_ty.csv")

data_1.shape, data_2.shape

# %%
data_1.describe()

# %%
data_2.describe()

# %% [markdown]
# # Submission

# %%
sub = data_1.copy()

sub['state'] = (data_1['state'] * 0.65) + (data_2['state'] * 0.35)

sub.to_csv("submission.csv", index=False)
sub.describe()
