# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/kaggle/input/walmart-recruiting-store-sales-forecasting/features.csv.zip')

# %%
df1=pd.read_csv('/kaggle/input/walmart-recruiting-store-sales-forecasting/stores.csv')
df1

# %%
df3=pd.read_csv('/kaggle/input/walmart-recruiting-store-sales-forecasting/test.csv.zip')

# %%
df4=pd.read_csv('/kaggle/input/walmart-recruiting-store-sales-forecasting/train.csv.zip')
df4

# %%
df5=pd.merge(df,df4,on=['Store','Date'])
df5

# %%
df6=pd.merge(df5,df1,on='Store')
df6.shape

# %%
df6.corr()

# %%
sns.heatmap(df6.corr())

# %%
sns.jointplot(x='MarkDown3',y='Weekly_Sales',data=df6)

# %%
sns.jointplot(x='MarkDown4',y='MarkDown1',data=df6)

# %%
# sns.pairplot(df6,hue='Type')

# %%
df6.columns

# %%
sns.distplot(df6['Weekly_Sales'],kde=False)

# %%
df6['Weekly_Sales'].head(20)

# %%
df6.columns

# %%
df6=pd.get_dummies(df6,columns=['Type'],drop_first=True)

# %%
df6

# %%
import datetime
df6['Month']=pd.DatetimeIndex(df6['Date']).month

# %%
df6

# %%
df6.drop(['Date'],axis=1,inplace=True)
df6

# %%
df6.corr()

# %%
sns.heatmap(df6.corr())

# %%
df6=df6[['Size','Dept','Month','Type_B','Type_C','IsHoliday_x']]

# %%
df6.isna().sum()

# %%
df6.isna().sum()

# %%
y=df5.Weekly_Sales

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(df6)

# %%
X

# %%
y

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df6,y,test_size=0.25)

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
import numpy as np 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score

random_search = {'criterion': ['entropy', 'gini'],
               'max_depth': list(np.linspace(10, 1200, 10, dtype = int)) + [None],
               'max_features': ['auto', 'sqrt','log2', None],
               'min_samples_leaf': [4, 6, 8, 12],
               'min_samples_split': [5, 7, 10, 14],
               'n_estimators': list(np.linspace(151, 1200, 10, dtype = int))}

clf = RandomForestRegressor()
model = RandomizedSearchCV(estimator = clf, param_distributions = random_search, n_iter = 80, 
                               cv = 4, verbose= 5, random_state= 101, n_jobs = -1)
model.fit(X_train,y_train)
