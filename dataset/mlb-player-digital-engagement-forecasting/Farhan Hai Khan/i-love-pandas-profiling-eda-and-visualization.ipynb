# %% [markdown]
# ### We will Try to perform some EDA using Pandas Profiling.
#
# ### Why?
# Because it's actually informative and is absolutely easy peasy!

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import pandas_profiling as pp
import seaborn as sns
import warnings
import os

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
DATA_DIR = "../input/mlb-player-digital-engagement-forecasting"

# %% [markdown]
# ### Choose All CSVs except the Example Ones

# %%
all_csvs = ['players.csv',
 'teams.csv',
 'seasons.csv',
 'train.csv',
 'awards.csv']

all_root_csvs = [os.path.join(DATA_DIR,each) for each in all_csvs]

# %% [markdown]
# # Players

# %%
df_pl = pd.read_csv(all_root_csvs[0])

# %%
df_pl.info()

# %%
df_pl.describe()

# %%
pp.ProfileReport(df_pl)

# %% [markdown]
# # Teams

# %%
df_t = pd.read_csv(all_root_csvs[1])

# %%
df_t.info()

# %%
df_t.describe()

# %%
pp.ProfileReport(df_t)

# %% [markdown]
# # Seasons

# %%
df_s = pd.read_csv(all_root_csvs[2])

# %%
df_s.info()

# %%
df_s.describe()

# %%
pp.ProfileReport(df_s)

# %% [markdown]
# # Awards

# %%
df_a = pd.read_csv(all_root_csvs[-1])

# %%
df_a.info()

# %%
df_a.describe()

# %%
pp.ProfileReport(df_a)

# %% [markdown]
# # Train
#
# I have to admit that the training dataset is quite bulky: around `3GB`. This  is probably optimized using big data tools such as an Apache Spark RDD/ Hadoop. But that's another lesson.
#
# I'm not exactly sure that Pandas Profiling can deal with such big datasets, but who knows?

# %%
df_train = pd.read_csv(all_root_csvs[-2])

# %%
df_train.info()

# %%
df_train.describe()

# %%
# pp.ProfileReport(df_train)
