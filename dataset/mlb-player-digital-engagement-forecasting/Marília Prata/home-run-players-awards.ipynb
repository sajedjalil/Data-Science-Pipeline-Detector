# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #<font color="red">Baseball Fan's Engagement</font>

# %% [markdown]
# ![](https://pbs.twimg.com/media/EuXQpOtWYAEWBZc.jpg:large)twitter.com

# %% [markdown]
# #<font color="red">Glossary of Baseball Jargon</font>
#
# <font color="red">What is October called in baseball?</font>
#
# "Fall Classic. The World Series -- the championship series of Major League Baseball, in which the champion of the American League faces off against the champion of the National League. Typically, this series takes place in October, so playing in October is the goal of any major league team."
#
# <font color="red">What does S mean in baseball batting?</font>  SAVE
#
# "In baseball statistics, save (abbreviated SV, or sometimes, S) is the successful maintenance of a lead by a relief pitcher, usually the closer, until the end of the game. ... He comes into the game with the potential tying run being either on base, at bat, or on deck."
#
# <font color="red">What does F mean in baseball?</font> Foul Tip
#
# "A batted ball that is hit sharply and directly from the bat to the catcher's mitt and legally caught by the catcher. It is not a foul tip, as most announcers and journalists mistakenly use the term, if the ball is not caught by the catcher. In this case, it is simply a foul ball."
#
# <font color="red">What does R mean in baseball?</font> RUN
#
# Run (R) Runs Batted In (RBI)
#
# <font color="red">Why do they use the letter K for a strikeout?</font>
#
# "A strikeout is a Statistic recorded for both pitchers and batters, and is denoted by K."
#
# K is the prominent letter of the word "strike," which was used more frequently than strikeout. Some scorers use a forward K for a swinging strikeout, a backward K for a batter caught looking."
#
# https://en.wikipedia.org/wiki/

# %%
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')

# %%
df = pd.read_csv('../input/mlb-player-digital-engagement-forecasting/awards.csv', encoding='ISO-8859-2')
df.tail().style.set_properties(**{'background-color':'#0000FF',
                                     'color': 'white'})

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:red;">Awards</b></i></h1></center>
#
# <font color="red">MVP Awards ( Most Valuable Player Award):</font> American League;; National League
#
# <font color="red">Cy Young Awards (Best pitchers in Major League Baseball):</font> American League;; National League
# In honor of Hall of Fame pitcher Cy Young, who died in 1955.
#
# <font color="red">Rookie of the Year Awards:</font> American League;; National League
#
# <font color="red">Manager of the Year Awards:</font> American League;; National League
#
# <font color="red">MLB Awards</font>
#
# <font color="red">Clemente Award</font> Recognizes those who best represent the game through positive contributions on and off the field, including sportsmanship and community involvement.
#
# <font color="red">Aaron Awards</font> American League;; National League
#
# <font color="red">Defensive Awards</font> Defensive Player of the Year
#
# <font color="red">Relievers of the Year</font> Americam League;; National League
#
# <font color="red">Silver Slugger Awards</font>
#
# <font color="red"></font>
#
# <font color="red">Gold Glove Awards</font>
#
# <font color="red">Postseason Awards</font> WS MVP;; ALCS MVP;; NLCS MVP
#
# <font color="red">Players Choice Awards</font> Player of the Year; Man of the Year; Always Game Award.
#
# <font color="red">Comeback Player Awards</font> American League;; National League
#
# <font color="red">Outstanding DH Award</font> Outstanding Designated Hitter Award.
#
# https://www.mlb.com/awards/2017

# %% [markdown]
# #<font color="red">American League Most Valuable Player Award</font>
#
#
# ![](https://www.theplayoffs.com.br/wp-content/uploads/2019/11/Trout-MVP-Twitter.jpg)theplayoffs.com.br

# %%
AlMvp= df[(df['awardName']=='AL MVP')].reset_index(drop=True)
AlMvp.head()

# %% [markdown]
# #<font color="#DC143C">October. Finally. We've never done it like this before.</font>

# %% [markdown]
# <iframe width="642" height="361" src="https://www.youtube.com/embed/MpczNpVk0k4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# https://www.youtube.com/watch?v=MpczNpVk0k4

# %% [markdown]
# #<font color="red">We've never done it like this before:  October: The Remix (Postseason 2020)</font>
#
# <font color="#0000FF">October. Finally. We've never done it like this before.</font>
#
# #<font color="#0000FF">This  is October. Remix. This year we invited a few extra friends.</font>
#
# #<font color="#0000FF">That means anything can happen. That's right. Anything.</font>
#
# #<font color="#0000FF">These Kagglers are different. Watch the Comp. They are young, loud and hungry .</font>
#
# #<font color="#0000FF">Same Comp. Whole new attitude.</font>
#
# #<font color="#0000FF">And if you don't know. Now you know.</font>
#
# #<font color="#0000FF">But one thing remains the same. This LB ain't gone lift itself.</font>
#
# <font color="#0000FF">Ohhhhh Shiiiiii its ma boys</font>
#
# <font color="#0000FF">Mic Drop.</font>
#
# #<font color="#0000FF">Music: "Mic Drop" - BTS + Steve Aoki.</font>
#
# https://www.youtube.com/watch?v=MpczNpVk0k4

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in AlMvp.playerName)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='RdBu', background_color="Blue").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# #Red Sox Rookie of the Year

# %%
RedSox_rookie= df[(df['awardName']=='Red Sox Rookie of the Year')].reset_index(drop=True)
RedSox_rookie.head()

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ5-rrA84s5IdVlxHPYG0TL3rhAzjb8NGhDnw&usqp=CAU)americanas.com.br

# %%
df1 = pd.read_csv('../input/mlb-player-digital-engagement-forecasting/players.csv', encoding='ISO-8859-2')
df1.tail().style.set_properties(**{'background-color':'red',
                                     'color': 'white'})

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:white;">Baseball Positions</b></i></h1></center>
#
# <font color="red">BASEBALL POSITIONS: BODY TYPE, SKILLS, NUMBERS AND MORE EXPLAINED</font>
#
# By Dan Blewett / Baseball
#
# "What do the baseball position numbers mean? They are used in scoring the game, and so each position is designated with a 1-9 number. They go in order, starting with the pitcher as #1, however the shortstop is out of order–he should be #5 if following the pattern, but instead is #6."
#
# "This was because originally, the shortstop was the fourth outfielder. Later, the shortstop was moved permanently to the infield but his number stuck at #6. It’s important to understand the positional numbers so that a proper scorebook can be kept and players understand the lineup and dugout card."
#
# <font color="red">Pitchers (Position #1 on the field chart)</font>
#
# "Pitchers have a LOT of influence on the outcome of a game. Pitchers have the #1 designation in the baseball scorebook, and they’re in control of the ball and the speed of the game. The following are some of the skills a pitcher needs: Strong arm, Mentally tough, Able to handle high-pressure situations, High dexterity and “feel” for throwing a baseball, Good body control for repeatability of mechanics, Strong focus and baseball intelligence.
# Very competitive."
#
# <font color="red">Catcher (Position #2 on the field chart)</font>
#
# "Catchers have an extremely demanding role on the team – both physically and mentally. Because the catcher must control and corral the pitcher, he has to be physically and mentally quick. Foul tips and long days squatting and blocking in the heat make for very long, draining days."
#
# <font color="red">First Baseman (Position #3 on the field chart)</font>
#
# "First baseman are the biggest power hitters on a team, and they are typically very big and relatively slow because of this. First baseman can often “hide” at first because they don’t often have to make long throws or move around too much. But, that doesn’t mean first base is not a difficult position – it’s easy to play an average first base, but it’s NOT easy to be great at it.Good reflexes and instincts are important, as line drives scream to first base."
#
# <font color="red">Second Baseman (Position #4 on the field chart)</font>
#
# "Second baseman are typically great defensive players with the worst bat on the team. Though there are some great-hitting second baseman, it’s typically a less offensive player who excels at 2nd. Dustin Pedroia was an amazing player and a great example."
#
# "Very agile and quick. Great IQ for the game. Excellent glove and defensive skills
# Needs an adequate arm, but it doesn’t need to be a cannon. Should be fast and a skilled contact hitter. Typically a “spark plug” type player who gets on base and makes things happen on the basepaths."
#
# <font color="red">Shortstop (Position #6 on the field chart)</font>
#
# "Andrelton Simmons is one of the best defensive shortstops ever, and shows off the athleticism and skill needed to play the position at the highest level."Shortstops are usually the best athletes on the field at all levels of baseball."
#
# "Must have excellent glove skills. Excellent range and agility. Excellent arm strength
# Excellent field vision and understanding of where to go and other players’ movement.
# Hitting skills are secondary to defensive ability, however at the MLB level there is a growing importance on being threat at the plate – it’s not enough any more to hit .250 as an MLB shortstop. Must be mentally tough and have strong leadership skills."
#
# <font color="red">Third Baseman (Position #5 on the field chart)</font>
#
# "Third baseman have a similar skillset to shortstops, but they’re typically bigger, stronger and more capable of hitting for power. Nolan Arenado is a great example of a third baseman who is a threat at the plate and yet also an excellent defender."
#
# "VERY strong arm to make long throws across the diamond. Excellent reflexes and is NOT afraid of the ball (they call it the hot corner for a reason). Great defender, but lacks the range of a shortstop typically because of bigger physical size. One of the top power-hitters on the team, typically. Many high school shortstops who don’t have quite the defensive skills to play SS in college move to third base and pack on some extra muscle."
#
# <font color="red">Left Fielder (Position #7 on the field chart)</font>
# "
# "Left fielders typically have an OK arm with a decent glove and a solid bat. Because more throws from left field aren’t THAT long, they don’t need to have a cannon for an arm."
#
# "Left fielders need to play excellent outfield defense and thus must be fast and have a great glove."
#
# <font color="red">Center Fielder (Position #8 on the field chart)</font>
#
# "Mike Trout is perhaps a stronger hitter than most center fielders (he’s a stronger hitter than everyone, but that’s another story…), but he’s still a great example of what a center fielder should be."
#
# "Must be an excellent fielder – the best defensive outfielder on the team. Must be exceptionally fast. Must get great reads and jumps on fly balls. Arm must be strong
# Must be a solid hitter at the plate and a great base runner to utilize speed."
#
# <font color="red">Right Fielder (Position #9 on the field chart)</font>
#
# "Right fielders are most commonly known for having rocket launcher arms."
#
# "At youth levels, the right fielder is one of the lesser players on the team because fewer fly balls are hit that way. At college and pro levels, the right fielder has one of the strongest arms on the team because of the long throw to third base Must hit for power
# Must be an excellent fielder but does not have to be as fast or as amazing in the outfield as the center fielder."
#
# <font color="red">Other Positions: DH + Roles of Pinch Runner, Pinch Hitter</font>
#
# "What is the DH in baseball? The Designated Hitter is a player who only hits, and this position exists only in the American League. The DH hits in place of the pitcher, who does not bat in the American League."
#
# "Pinch Runners enter the game to run the bases in place of another player, but this is not really a position – more just a role. Same goes for pinch hitters, who replace a hitter already in the game to bat for them."
#
# https://danblewett.com/baseball-positions-fielders-body-type/

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQipeeT74I4tBauKdH6v5a63HGEtpmLwePnQw&usqp=CAU)slideshare.net

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

position_cnt = np.round(df1['primaryPositionName'].value_counts(normalize=True) * 100)
hv.Bars(position_cnt).opts(title="Primary Position Name Count", color="red", xlabel="primaryPositionName", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=True)).opts(xrotation=45)

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:white;">Home Run (HR)</b></i></h1></center>
#
# "A home run occurs when a batter hits a fair ball and scores on the play without being put out or without the benefit of an error."
#
# "In almost every instance of a home run, a batter hits the ball in the air over the outfield fence in fair territory. In that situation, the batter is awarded all four bases, and any runners on base score as well. The batter can circle the bases at his leisure, as there is no threat of him being thrown out. (This also occurs when the ball hits the foul pole in left or right field, or when the ball hits an opposing defender on the fly and bounces directly over the wall in fair ground.)"
#
# "There are also instances of "inside-the-park home runs." These occur when the batter hits the ball in play (not over the wall) and touches all four bases without being thrown out. These are extremely rare and typically only occur with a very fast runner at the plate and some sort of misplay by an outfielder that doesn't qualify as an error."
#
# "The term "home run" comes from the basic act of a batter circling all the bases successfully. In the early days of the home run, running was typically a necessity as players weren't very powerful and outfields were much bigger, leading to a greater number of inside-the-park home runs. Now, however, most home runs feature players trotting around the bases after hitting the ball over the fence."
#
# https://www.mlb.com/glossary/standard-stats/home-run

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

future_cnt = np.round(df1['playerForTestSetAndFuturePreds'].value_counts(normalize=True) * 100)
hv.Bars(future_cnt).opts(title="Player For Test Set And Future Preds", color="red", xlabel="playerForTestSetAndFuturePreds", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=True))

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df1.primaryPositionName)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='RdBu', background_color="Blue").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
df2 = pd.read_csv('../input/mlb-player-digital-engagement-forecasting/teams.csv', encoding='ISO-8859-2')
df2.tail().style.set_properties(**{'background-color':'#00008B',
                                     'color': 'white'})

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:red;">Baseball Divisions</b></i></h1></center>
#
#
# <font color="red">American League East, Central and West</font>
#
# American League East: Tampa Bay, Boston, N.Y.Yankees, Toronto, Baltimore
#
# American League Central: Chi White Sox, Cleveland, Kansas City, Detroit, Minnesota
#
# American League West: Oakland, Houston, Seattle, LA Angels, Texas.
#
# <font color="red">National League East, Central and West</font>
#
# National League East: NY Mets, Atlanta, Philadelphia, Washington, Miami
#
# National League Central: Chi Cubs, Milwaukee, St.Louis, Cincinatti, Pittisburgh
#
# national League West: San Francisco, LA Dodgers, San Diego, Colorado, Arizona
#
# https://www.mlb.com/standings

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

division_cnt = np.round(df2['divisionName'].value_counts(normalize=True) * 100)
hv.Bars(division_cnt).opts(title="Division Name", color="blue", xlabel="divisionName", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=True)).opts(xrotation=45)

# %% [markdown]
# ![](https://pbs.twimg.com/media/EbYHtmSU8AATCTa.jpg)itwperformancepolymers.com

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

league_cnt = np.round(df2['leagueName'].value_counts(normalize=True) * 100)
hv.Bars(league_cnt).opts(title="League Name", color="blue", xlabel="leagueName", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=True))

# %%
df3 = pd.read_csv('../input/mlb-player-digital-engagement-forecasting/seasons.csv', encoding='ISO-8859-2')
df3.tail().style.set_properties(**{'background-color':'#DC143C',
                                     'color': 'white'})

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:red;">MLB playoffs: 2021 posteason picture, format and schedule</b></i></h1></center>
#
# Author: Matt Johnson
#
# "The 2021 season is underway and we’re starting to get a picture of how the MLB playoffs will look in October, with several teams emerging as World Series contenders."
#
# "Throughout the season, we’ll have updates on where things stand in the postseason race for both American League and National League teams. We’ll also provide overviews for postseason matchups, which will continue to change as the 2021 season unfolds. Let’s dive into the latest playoff picture in June."With Major League Baseball shifting back to a 10-team format, the postseason will kick off on Tuesday, Oct. 5. It comes just two days after the 2021 MLB regular season wraps up.
#
# <font color="red">When are the MLB playoffs?</font>
#
# With Major League Baseball shifting back to a 10-team format, the postseason will kick off on Tuesday, Oct. 5. It comes just two days after the 2021 MLB regular season wraps up.
#
# National League and American League wild-card games: Oct. 5-6
#
# American League and National League Division Series: Oct. 7-14
#
# NL and AL Championship Series: Oct. 15-24
#
# 2021 World Series: Oct. 26- Nov. 3
#
# https://sportsnaut.com/mlb-playoffs-schedule-bracket-dates/

# %%
fig = px.line(df3, x="seasonStartDate", y="seasonId", color_discrete_sequence=['#2B3A67'], 
              title="Seasons Start Dates")
fig.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df2.name)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='RdBu', background_color="Blue").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# ![](https://media0.giphy.com/media/l0MYEZkOB8xCYM7O8/200w.webp?cid=ecf05e478hjsigl71rgr4k8gd35k3rrz7h6ab3lpych7l4mp&rid=200w.webp&ct=g)

# %% [markdown]
# #I couldn't even grab the foul ball.
