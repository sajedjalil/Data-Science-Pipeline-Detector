# %%
import numpy as np 
import pandas as pd 
import os
os.listdir('../input/')

# %%
sub1 = pd.read_csv('../input/tpu-incepresnetv2-enb7/submission.csv')
sub1.head()

# %%
sub2 = pd.read_csv('../input/average-efficientnet/submission.csv')
sub2.head()

# %%
sub3 = pd.read_csv('../input/classification-densenet201-efficientnetb7/submission.csv')
sub3.head()

# %%
sub4 = pd.read_csv('../input/plant-pathology-pytorch-gpu-model/v6_efficientnet_b4_5_fold_submission1_fold_0_39ep_best_fold_1_30ep_best_fold_2_33ep_best_fold_3_25ep_best_fold_4_44ep_best.csv')
sub4.head()

# %%
sub5 = pd.read_csv('../input/tf-zoo-models-on-tpu/submission.csv')
sub5.head()

# %%
sub6 = pd.read_csv('../input/fork-of-plant-2020-tpu-915e9c/submission.csv')
sub6.head()

# %%
sub = pd.read_csv('../input/plant-pathology-2020-fgvc7/sample_submission.csv')
sub.head()

# %%
sub.healthy = (sub1.healthy + sub2.healthy + sub3.healthy + sub4.healthy + sub5.healthy + sub6.healthy)/6

# %%
sub.multiple_diseases = (sub1.multiple_diseases + sub2.multiple_diseases + sub3.multiple_diseases + sub4.multiple_diseases + sub5.multiple_diseases + sub6.multiple_diseases)/6

# %%
sub.rust = (sub1.rust + sub2.rust + sub3.rust + sub4.rust + sub5.rust + sub6.rust)/6

# %%
sub.scab = (sub1.scab + sub2.scab + sub3.scab + sub4.scab + sub5.scab + sub6.scab)/6

# %%
sub.head()

# %%
sub.to_csv('submission.csv', index=False)
