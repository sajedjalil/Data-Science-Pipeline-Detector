# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('../input/tabular-playground-series-mar-2021/train.csv')

# %%
col=data.columns
col

# %%
cols=col[1:20]
cols

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
for i in cols:
    data[i]= label_encoder.fit_transform(data[i])

# %%
data

# %%
X=data[col[1:-1]]
Y=data['target']

# %%
data.dtypes

# %%
X

# %%
Y

# %%
import keras 
from sklearn.model_selection import train_test_split 
from keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, LSTM,Dropout

# %%
def create_model():
        model = Sequential()
        model.add(Dense(30,input_dim=30,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(128,activation='relu'))
        model.add(Dense(128,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(256,activation='relu'))
        model.add(Dropout(0.4))
        model.add(Dense(62,activation='relu'))
        model.add(Dense(128,activation='relu'))
        model.add(Dense(128,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(256,activation='relu'))
        model.add(Dropout(0.4))
        model.add(Dense(30,activation='relu'))
        model.add(Dense(62,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(128,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(60,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(120,activation='relu'))
        model.add(Dense(128,activation='relu'))
        model.add(Dense(256,activation='relu'))
        model.add(Dropout(0.4))
        model.add(Dense(12,activation='relu'))
        model.add(Dense(1, activation='sigmoid'))
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',keras.metrics.AUC()])
        return model

# %%
train_x,test_x,train_y,test_y=train_test_split(X,Y,test_size=0.15)

# %%
model=create_model()
model.summary()

# %%
hist=model.fit(np.asarray(train_x).astype('float32'),train_y,epochs=55,batch_size=128)

# %%
model.evaluate(test_x,test_y)

# %%
test=pd.read_csv('../input/tabular-playground-series-mar-2021/test.csv')
test2=pd.read_csv('../input/tabular-playground-series-mar-2021/test.csv')

# %%
for i in cols:
    test[i]= label_encoder.fit_transform(test[i])

# %%
test

# %%
X_t=test[col[1:-1]]

# %%
X_t

# %%
y_pred=model.predict(np.asarray(X_t).astype('float32'))

# %%
def app(y_pred):
    pred=[]
    for i in y_pred:
        if i>0.500000001:
            pred.append(1)
        else:
            pred.append(0)
    return pred

# %%
pred=app(y_pred)

# %%
submission = pd.DataFrame({'id':test2.id,'target':pred})
submission.to_csv('submission.csv',index=False)

# %%
df=data[data['target']==0]

# %%
df_true=data[data['target']==1]

# %%
df=df.head(79461)

# %%
frames = [df, df_true]

result = pd.concat(frames)

# %%
result

# %%
X=result[col[1:-1]]
Y=result['target']

# %%
train_x,test_x,train_y,test_y=train_test_split(X,Y,test_size=0.10)

# %%
hist=model.fit(np.asarray(train_x).astype('float32'),train_y,epochs=85,batch_size=128)

# %%
def app2(y_pred):
    pred=[]
    for i in y_pred:
        pred.append(i[0])
    return pred

# %%
y_pred=model.predict(np.asarray(X_t).astype('float32'))

# %%
y_pred=app2(y_pred)

# %%
submission = pd.DataFrame({'id':test2.id,'target':y_pred})
submission.to_csv('submission.csv',index=False)
