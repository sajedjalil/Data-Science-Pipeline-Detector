# %% [markdown]
# <div>
#     <h2 align="center">Tabular Playground Series - Mar 2021</h2></h2>
# </div>

# %%
import numpy as np

import pandas as pd

# %%
dfk = pd.DataFrame({ 
    
    'Kernel ID'   : ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],  
    
    'Public Score': [ 0.89212, 0.89224, 0.89225, 0.89230, 0.89253, 0.89257, 0.89268, 0.89295, 0.89335, 0.89399],   
    
    'File Path'   : ['../input/tps-mar-2021-single-lgbm/submission.csv', '../input/catboost-vs-xgb-vs-lgbm-tps-mar-21/submissionLGBM.csv', '../input/tps-mar-2021-eda-5folds-lgbm/submission.csv', '../input/tps-complete-eda-single-lgb-tuning-strategy/submission.csv', '../input/mljar-automl-tps-mar2021/1_submission.csv', '../input/tps-mar-2021-lgbm/submission.csv', '../input/tps-mar-2021-stacked-starter/submission.csv', '../input/mar89295/MAR89295.csv', '../input/mar89335/MAR89335.csv', '../input/tps-mar-2021-rank-averaging-and-stacking/submission_stacking_cv0.899063.csv']  
    
})    

dfk

# %%
a89212 = pd.read_csv(dfk.iloc[0, 2])

b89224 = pd.read_csv(dfk.iloc[1, 2]) 

c89225 = pd.read_csv(dfk.iloc[2, 2]) 

d89230 = pd.read_csv(dfk.iloc[3, 2]) 

e89253 = pd.read_csv(dfk.iloc[4, 2])

f89257 = pd.read_csv(dfk.iloc[5, 2])

g89268 = pd.read_csv(dfk.iloc[6, 2])

h89295 = pd.read_csv(dfk.iloc[7, 2])

i89335 = pd.read_csv(dfk.iloc[8, 2])

j89399 = pd.read_csv(dfk.iloc[9, 2])

# %%
a89212.to_csv("a89212.csv", index=False)

b89224.to_csv("b89224.csv", index=False)

c89225.to_csv("c89225.csv", index=False) 

d89230.to_csv("d89230.csv", index=False)

e89253.to_csv("e89253.csv", index=False)

f89257.to_csv("f89257.csv", index=False)

g89268.to_csv("g89268.csv", index=False)

h89295.to_csv("h89295.csv", index=False)

i89335.to_csv("i89335.csv", index=False)

j89399.to_csv("j89399.csv", index=False)

# !ls
