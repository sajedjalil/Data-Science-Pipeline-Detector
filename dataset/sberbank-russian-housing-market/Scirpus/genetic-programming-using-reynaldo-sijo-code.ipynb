# %% [markdown]
# Just using Reynaldos/Sijos data munging with GP gets about .324
#
# Hopefully you may get some insight into extra features

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def GP(data):
    v = pd.DataFrame()
    v['gp0'] = np.ones(data.shape[0])*15.652000
    v["gp1"] = 0.050000*np.tanh((((((data["cafe_count_3000_price_2500"] * 2.0) + ((np.maximum( (data["life_sq"]),  (data["num_room"])) * 2.0) - np.maximum( ((data["cafe_count_2000_price_1000"] * 2.0)),  (np.maximum( (data["nuclear_reactor_km"]),  (data["num_room"])))))) * 2.0) * 2.0) * 2.0))
    v["gp2"] = 0.050000*np.tanh((((data["trc_count_5000"] + data["sport_objects_raion"]) + (data["sport_count_5000"] + data["build_count_monolith"])) + ((((((data["cafe_count_2000_price_1000"] * 2.0) - data["big_church_km"]) - data["big_church_km"]) + data["product_type"]) + data["max_floor"]) * 2.0)))
    v["gp3"] = 0.050000*np.tanh((((((data["state"] + (data["kitch_sq"] + data["full_sq"]))/2.0) - data["zd_vokzaly_avto_km"]) + ((data["full_sq"] + (-((data["public_healthcare_km"] - ((data["full_sq"] + data["full_sq"]) * 2.0))))) * 2.0)) * 2.0))
    v["gp4"] = 0.050000*np.tanh((((((data["full_sq"] + ((data["full_sq"] * 2.0) * 2.0)) - data["metro_km_avto"]) + data["num_room"]) + (((np.tanh(data["cafe_avg_price_1000"]) + data["cafe_count_5000_price_500"])/2.0) + (data["museum_km"] * data["cafe_count_500_na_price"]))) * 2.0))
    v["gp5"] = 0.050000*np.tanh(((data["full_sq"] + (data["floor"] + ((data["full_sq"] + data["num_room"]) - (data["church_count_2000"] - ((data["trc_count_5000"] + (data["full_sq"] * 2.0)) + np.tanh(data["school_education_centers_raion"])))))) - data["zd_vokzaly_avto_km"]))
    v["gp6"] = 0.050000*np.tanh(((data["office_sqm_5000"] - (data["church_count_2000"] - ((data["full_sq"] - np.maximum( (data["metro_min_avto"]),  (data["power_transmission_line_km"]))) * 2.0))) - (data["prom_part_1000"] - (data["full_sq"] - np.maximum( (data["metro_km_avto"]),  (data["catering_km"]))))))
    v["gp7"] = 0.050000*np.tanh(((data["full_sq"] + ((((data["ekder_female"] * data["railroad_station_walk_km"]) + data["cafe_sum_5000_max_price_avg"]) + (data["full_sq"] * 2.0)) - np.minimum( (data["public_healthcare_km"]),  (data["ttk_km"])))) - ((data["radiation_raion"] >= 0.0).astype(float))))
    v["gp8"] = 0.050000*np.tanh(((data["trc_count_5000"] - data["church_count_500"]) - ((((data["indust_part"] + data["metro_km_avto"])/2.0) * 2.0) - np.maximum( ((data["num_room"] * 2.0)),  (np.tanh((data["trc_count_2000"] + (((data["shopping_centers_raion"] >= 0.0).astype(float)) * 2.0))))))))
    v["gp9"] = 0.024050*np.tanh(((data["cafe_avg_price_2000"] + (np.minimum( ((data["school_education_centers_raion"] + ((data["cemetery_km"] >= 0.0).astype(float)))),  (np.tanh(data["cemetery_km"]))) + (data["life_sq"] * data["life_sq"]))) + ((data["church_count_2000"] + (data["num_room"] + data["green_part_500"]))/2.0)))
    v["gp10"] = 0.050000*np.tanh((np.minimum( (data["cafe_sum_3000_max_price_avg"]),  ((((-(data["theater_km"])) * (-(data["trc_sqm_500"]))) + data["num_room"]))) + (data["floor"] + ((((data["life_sq"] * 2.0) * (data["life_sq"] * 2.0)) * ((data["life_sq"] * 2.0) * (data["life_sq"] * 2.0))) + (-(data["theater_km"]))))))
    v["gp11"] = 0.050000*np.tanh(((data["full_sq"] * 2.0) * (((((data["full_sq"] - data["kremlin_km"]) * 2.0) * ((data["full_sq"] - data["kremlin_km"]) * 2.0)) - ((data["sport_objects_raion"] < data["full_sq"]).astype(float))) - ((data["max_floor"] < (data["max_floor"] * 2.0)).astype(float)))))
    v["gp12"] = 0.050000*np.tanh(((((((data["culture_objects_top_25_raion"] + ((data["kitch_sq"] > (0.318310 * 0.318310)).astype(float))) * 2.0) - (data["culture_objects_top_25_raion"] * data["trc_count_1500"])) + data["cafe_sum_3000_min_price_avg"]) + (data["life_sq"] * data["life_sq"])) + (data["life_sq"] * data["life_sq"])))
    v["gp13"] = 0.050000*np.tanh(((data["cafe_count_500_price_1500"] - (data["prom_part_5000"] * (((np.maximum( (data["build_count_panel"]),  (data["cafe_count_500_price_1500"])) >= 0.0).astype(float)) * 2.0))) + (((data["product_type"] + (data["ttk_km"] * data["build_count_panel"]))/2.0) + np.maximum( (data["sport_count_2000"]),  (data["cafe_count_500_price_1500"])))))
    v["gp14"] = 0.017770*np.tanh(((data["full_sq"] * (((((data["full_sq"] * 2.0) * (data["full_sq"] * 2.0)) * 2.0) * (((data["full_sq"] * 2.0) - data["nuclear_reactor_km"]) * ((data["full_sq"] * 2.0) - data["nuclear_reactor_km"]))) * ((((data["full_sq"] * 2.0) * (data["full_sq"] * 2.0)) * 2.0) * (((data["full_sq"] * 2.0) - data["nuclear_reactor_km"]) * ((data["full_sq"] * 2.0) - data["nuclear_reactor_km"]))))) - (((data["full_sq"] * 2.0) * 2.0) - data["nuclear_reactor_km"])))
    v["gp15"] = 0.050000*np.tanh((((data["full_sq"] * 2.0) * 2.0) * (data["cafe_count_5000_price_1500"] + np.maximum( (data["public_healthcare_km"]),  (np.maximum( (data["public_healthcare_km"]),  ((data["cafe_count_5000_price_1500"] + (data["cafe_sum_5000_min_price_avg"] + np.maximum( (((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"]))),  (data["full_sq"])))))))))))
    v["gp16"] = 0.050000*np.tanh((((data["full_sq"] + (data["cafe_count_1000_price_4000"] * data["big_road1_1line"])) * ((((data["full_sq"] + data["office_sqm_3000"]) * (data["full_sq"] + data["office_sqm_3000"])) * ((data["full_sq"] + data["office_sqm_3000"]) * (data["full_sq"] + data["office_sqm_3000"]))) * (((data["full_sq"] + data["office_sqm_3000"]) * (data["full_sq"] + data["office_sqm_3000"])) * ((data["full_sq"] + data["office_sqm_3000"]) * (data["full_sq"] + data["office_sqm_3000"]))))) * (((data["full_sq"] + data["full_sq"]) + data["big_road1_1line"]) * ((data["full_sq"] + data["full_sq"]) + data["big_road1_1line"]))))
    v["gp17"] = 0.050000*np.tanh((((np.maximum( (data["public_transport_station_km"]),  (((data["full_sq"] + (np.maximum( (data["big_road2_km"]),  ((data["full_sq"] * data["full_sq"]))) * np.maximum( (data["big_road2_km"]),  ((data["full_sq"] * data["full_sq"]))))) * (data["full_sq"] + (np.maximum( (data["big_road2_km"]),  ((data["full_sq"] * data["full_sq"]))) * np.maximum( (data["big_road2_km"]),  ((data["full_sq"] * data["full_sq"])))))))) - (data["big_road2_km"] * data["big_road2_km"])) - (data["public_transport_station_km"] * data["public_transport_station_km"])) / 2.0))
    v["gp18"] = 0.050000*np.tanh(((((((data["nuclear_reactor_km"] < ((data["big_church_count_1000"] >= 0.0).astype(float))).astype(float)) * ((np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))) * (np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))))) * data["full_sq"]) * ((((data["nuclear_reactor_km"] < ((data["big_church_count_1000"] >= 0.0).astype(float))).astype(float)) * ((np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))) * (np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))))) * data["full_sq"])) * (((((data["nuclear_reactor_km"] < ((data["big_church_count_1000"] >= 0.0).astype(float))).astype(float)) * ((np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))) * (np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))))) * data["full_sq"]) * ((((data["nuclear_reactor_km"] < ((data["big_church_count_1000"] >= 0.0).astype(float))).astype(float)) * ((np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))) * (np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0))) * np.maximum( (data["state"]),  ((((data["nuclear_reactor_km"] * data["nuclear_reactor_km"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0)))))) * data["full_sq"]))))
    v["gp19"] = 0.050000*np.tanh(((data["cafe_count_5000_price_500"] + (((data["full_sq"] / 2.0) - (data["cafe_count_1500_price_1500"] * data["trc_sqm_500"])) / 2.0)) * (data["cafe_count_1500_price_high"] + ((data["full_sq"] + np.maximum( (data["full_sq"]),  (data["build_count_panel"]))) * (data["full_sq"] + np.maximum( (data["full_sq"]),  (data["build_count_panel"])))))))
    v["gp20"] = 0.050000*np.tanh(((data["kitch_sq"] + data["cafe_count_5000_price_high"]) * (((data["kitch_sq"] + (data["num_room"] + data["sport_count_1000"])) + (data["leisure_count_1000"] + data["life_sq"])) + ((data["num_room"] + ((data["big_church_km"] * data["big_church_km"]) * (data["big_church_km"] * data["big_church_km"])))/2.0))))
    v["gp21"] = 0.050000*np.tanh(((data["full_sq"] - ((data["park_km"] < (data["full_sq"] * 2.0)).astype(float))) * np.maximum( ((np.maximum( (((data["metro_km_walk"] < (data["full_sq"] * 2.0)).astype(float))),  ((data["full_sq"] * (data["full_sq"] * 2.0)))) * np.maximum( (((data["metro_km_walk"] < (data["full_sq"] * 2.0)).astype(float))),  ((data["full_sq"] * (data["full_sq"] * 2.0)))))),  (data["railroad_1line"]))))
    v["gp22"] = 0.050000*np.tanh((data["office_count_3000"] * np.minimum( (((data["office_count_3000"] * np.minimum( (data["ID_railroad_station_walk"]),  (data["cafe_count_1000_na_price"]))) * 2.0)),  ((((data["cafe_count_500_price_2500"] * 2.0) - np.minimum( (data["build_count_block"]),  (data["cafe_count_1000_na_price"]))) - ((data["cafe_count_1500"] > data["cafe_count_3000_price_4000"]).astype(float)))))))
    v["gp23"] = 0.050000*np.tanh((np.maximum( (data["cafe_count_3000_na_price"]),  (data["full_sq"])) * ((data["industrial_km"] + (data["full_sq"] * (data["full_sq"] * (np.maximum( (data["sport_count_3000"]),  (data["industrial_km"])) - (-((data["trc_count_500"] * (-(data["industrial_km"])))))))))/2.0)))
    v["gp24"] = 0.050000*np.tanh(((((-(np.maximum( (data["green_zone_km"]),  (((data["church_count_500"] > data["cafe_count_1000_price_high"]).astype(float)))))) >= 0.0).astype(float)) * np.maximum( (data["cafe_sum_5000_max_price_avg"]),  (np.maximum( (np.maximum( (data["cafe_count_1000_price_high"]),  (((data["cafe_sum_5000_max_price_avg"] > data["fitness_km"]).astype(float))))),  (data["cafe_count_3000_price_2500"]))))))
    v["gp25"] = 0.050000*np.tanh(((np.minimum( ((data["ID_railroad_terminal"] * (data["sub_area"] + (-((data["product_type"] * data["railroad_1line"])))))),  (data["product_type"])) + ((data["full_sq"] * data["full_sq"]) + (-(((data["build_count_wood"] + data["build_count_1921-1945"])/2.0)))))/2.0))
    v["gp26"] = 0.050000*np.tanh((data["metro_km_avto"] * (-((((((data["detention_facility_raion"] + data["prom_part_500"]) + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"]))) / 2.0) + data["water_1line"]) + ((data["metro_km_avto"] * (data["full_sq"] * data["full_sq"])) * (data["metro_km_avto"] * (data["full_sq"] * data["full_sq"]))))))))
    v["gp27"] = 0.050000*np.tanh((((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])) * np.minimum( (((data["leisure_count_500"] * data["full_sq"]) * (data["leisure_count_500"] * data["full_sq"]))),  (np.minimum( (data["sport_count_5000"]),  ((data["full_sq"] * (data["full_sq"] * (data["full_sq"] * 2.0)))))))))
    v["gp28"] = 0.050000*np.tanh(((data["num_room"] * ((np.minimum( (np.minimum( (data["leisure_count_500"]),  (data["cafe_count_500_price_4000"]))),  ((data["leisure_count_500"] * (((data["thermal_power_plant_raion"] * data["thermal_power_plant_raion"]) * 2.0) * 2.0)))) + ((((data["state"] * data["state"]) + data["metro_min_walk"])/2.0) * (((data["state"] * data["state"]) + data["metro_min_walk"])/2.0)))/2.0)) * 2.0))
    v["gp29"] = 0.050000*np.tanh(((np.minimum( (data["shopping_centers_raion"]),  (((data["railroad_station_avto_min"] + (((((data["ID_big_road1"] * data["product_type"]) < data["cafe_count_1000"]).astype(float)) * (data["school_education_centers_raion"] / 2.0)) - np.minimum( (data["cafe_count_1000"]),  ((data["railroad_terminal_raion"] * data["product_type"])))))/2.0))) >= 0.0).astype(float)))
    v["gp30"] = 0.050000*np.tanh((((data["church_count_1000"] * data["water_treatment_km"]) + (data["male_f"] * np.maximum( ((data["railroad_1line"] + (data["railroad_1line"] + data["kitch_sq"]))),  (np.maximum( (data["metro_min_avto"]),  (((((data["water_treatment_km"] + data["office_sqm_2000"])/2.0) + data["water_treatment_km"])/2.0)))))))/2.0))
    v["gp31"] = 0.050000*np.tanh((data["floor"] * np.minimum( (data["cafe_count_3000_price_2500"]),  ((((data["prom_part_2000"] * np.minimum( (np.minimum( (data["ID_big_road2"]),  (data["ID_big_road2"]))),  (np.minimum( (data["ID_big_road2"]),  (data["cafe_count_1000_price_1500"]))))) < ((data["big_church_count_3000"] < data["floor"]).astype(float))).astype(float))))))
    v["gp32"] = 0.050000*np.tanh((data["big_church_count_3000"] * np.minimum( ((-(np.maximum( (data["prom_part_2000"]),  ((data["prom_part_2000"] + ((np.maximum( (data["prom_part_1000"]),  ((((data["product_type"] * data["cafe_count_1000_price_1500"]) >= 0.0).astype(float)))) < data["ID_big_road2"]).astype(float)))))))),  ((((-(data["railroad_km"])) >= 0.0).astype(float))))))
    v["gp33"] = 0.050000*np.tanh(((data["cemetery_km"] * data["kitch_sq"]) + ((data["water_km"] * data["kitch_sq"]) + (((data["build_count_brick"] * data["mosque_count_5000"]) * data["kitch_sq"]) + ((data["big_church_count_500"] > ((data["build_count_brick"] < data["trc_count_3000"]).astype(float))).astype(float))))))
    v["gp34"] = 0.050000*np.tanh((((np.tanh(data["product_type"]) + (((data["full_sq"] + ((data["full_sq"] * data["full_sq"]) * (data["full_sq"] * data["full_sq"])))/2.0) * ((data["product_type"] + ((data["state"] + (data["full_sq"] * data["full_sq"]))/2.0))/2.0)))/2.0) * ((data["kremlin_km"] < data["sport_count_3000"]).astype(float))))
    v["gp35"] = 0.050000*np.tanh((((data["full_sq"] * ((((np.maximum( (((data["full_sq"] + data["full_sq"])/2.0)),  (data["state"])) * ((data["full_sq"] + data["state"])/2.0)) * (np.maximum( (((data["full_sq"] + data["full_sq"])/2.0)),  (data["state"])) * ((data["full_sq"] + data["state"])/2.0))) - data["life_sq"]) - data["life_sq"])) - data["life_sq"]) / 2.0))
    v["gp36"] = 0.050000*np.tanh(((((((data["church_count_2000"] - data["0_13_all"]) > ((data["church_count_2000"] < data["zd_vokzaly_avto_km"]).astype(float))).astype(float)) * np.minimum( ((((data["church_count_1000"] - data["detention_facility_raion"]) / 2.0) - data["0_13_all"])),  (data["thermal_power_plant_km"]))) * ((((data["church_count_2000"] - data["0_13_all"]) > ((data["church_count_2000"] < data["zd_vokzaly_avto_km"]).astype(float))).astype(float)) * np.minimum( ((((data["church_count_1000"] - data["detention_facility_raion"]) / 2.0) - data["0_13_all"])),  (data["thermal_power_plant_km"])))) * (((((data["church_count_2000"] - data["0_13_all"]) > ((data["church_count_2000"] < data["zd_vokzaly_avto_km"]).astype(float))).astype(float)) * np.minimum( ((((data["church_count_1000"] - data["detention_facility_raion"]) / 2.0) - data["0_13_all"])),  (data["thermal_power_plant_km"]))) * ((((data["church_count_2000"] - data["0_13_all"]) > ((data["church_count_2000"] < data["zd_vokzaly_avto_km"]).astype(float))).astype(float)) * np.minimum( ((((data["church_count_1000"] - data["detention_facility_raion"]) / 2.0) - data["0_13_all"])),  (data["thermal_power_plant_km"]))))))
    v["gp37"] = 0.050000*np.tanh((((np.minimum( (data["cafe_count_500_na_price"]),  (((data["mosque_count_500"] + ((data["trc_count_2000"] < ((data["ekder_male"] + ((data["cafe_count_500"] < ((data["university_top_20_raion"] + (data["cafe_count_500_na_price"] / 2.0))/2.0)).astype(float)))/2.0)).astype(float)))/2.0))) >= 0.0).astype(float)) * 2.0))
    v["gp38"] = 0.050000*np.tanh((data["mosque_count_1000"] * np.maximum( (((data["big_church_count_1000"] + data["railroad_1line"])/2.0)),  (((np.maximum( (data["water_1line"]),  ((data["green_part_1000"] - ((data["water_1line"] > data["sport_count_3000"]).astype(float))))) / 2.0) * 2.0)))))
    v["gp39"] = 0.050000*np.tanh((data["build_count_wood"] * ((((np.maximum( (np.maximum( (data["cafe_count_5000_price_4000"]),  ((data["build_count_after_1995"] * data["green_part_1000"])))),  (data["male_f"])) + np.minimum( (data["cafe_sum_3000_max_price_avg"]),  (np.minimum( (data["prom_part_500"]),  ((-(data["leisure_count_500"])))))))/2.0) + data["prom_part_500"])/2.0)))
    v["gp40"] = 0.047120*np.tanh(((-(data["cafe_count_1500_price_high"])) * (data["prom_part_500"] * np.maximum( (data["mosque_count_500"]),  ((((((data["office_sqm_5000"] > np.tanh(np.maximum( (np.tanh(data["prom_part_500"])),  ((((data["cafe_count_1000_price_500"] >= 0.0).astype(float)) * 2.0))))).astype(float)) * 2.0) * 2.0) * 2.0))))))
    v["gp41"] = 0.048910*np.tanh((data["nuclear_reactor_raion"] * np.maximum( ((((data["max_floor"] + ((((data["max_floor"] + ((data["max_floor"] + (data["office_sqm_1500"] * data["office_sqm_1500"]))/2.0))/2.0) - data["railroad_station_walk_km"]) * (((data["max_floor"] + ((data["max_floor"] + (data["office_sqm_1500"] * data["office_sqm_1500"]))/2.0))/2.0) - data["railroad_station_walk_km"])))/2.0) - data["detention_facility_km"])),  ((data["cafe_count_1000_price_4000"] * data["nuclear_reactor_raion"])))))
    v["gp42"] = 0.049990*np.tanh((((np.minimum( ((data["exhibition_km"] * data["exhibition_km"])),  (np.minimum( (data["ts_km"]),  (data["big_road2_km"])))) * np.maximum( (data["state"]),  ((((data["market_shop_km"] * data["market_shop_km"]) > (data["exhibition_km"] * data["exhibition_km"])).astype(float))))) * ((data["radiation_raion"] > data["big_road2_km"]).astype(float))) * ((np.minimum( ((data["exhibition_km"] * data["exhibition_km"])),  (np.minimum( (data["ts_km"]),  (data["big_road2_km"])))) * np.maximum( (data["state"]),  ((((data["market_shop_km"] * data["market_shop_km"]) > (data["exhibition_km"] * data["exhibition_km"])).astype(float))))) * ((data["radiation_raion"] > data["big_road2_km"]).astype(float)))))
    v["gp43"] = 0.050000*np.tanh((data["cafe_count_1000_price_1500"] * (data["full_sq"] + (((((-(data["cafe_count_500_na_price"])) * 2.0) + ((data["cafe_sum_1500_max_price_avg"] * 2.0) + data["full_sq"]))/2.0) * data["full_sq"]))))
    v["gp44"] = 0.050000*np.tanh((data["kitch_sq"] * (data["build_count_after_1995"] - ((((data["big_road2_km"] * data["green_part_3000"]) + data["mosque_count_500"]) + ((data["big_road2_km"] + data["ID_railroad_terminal"])/2.0)) + (data["green_part_1500"] * (((data["big_road2_km"] >= 0.0).astype(float)) * ((data["big_road2_km"] >= 0.0).astype(float))))))))
    v["gp45"] = 0.050000*np.tanh((data["big_church_count_1000"] * (data["state"] * np.minimum( (data["build_count_1971-1995"]),  ((((data["big_church_count_1000"] * 2.0) * np.minimum( (data["cafe_sum_1500_max_price_avg"]),  (np.minimum( ((data["church_count_3000"] - data["office_sqm_2000"])),  (data["build_count_1971-1995"]))))) * 2.0))))))
    v["gp46"] = 0.050000*np.tanh(np.tanh((data["prom_part_500"] * ((((((data["build_count_foam"] - data["ID_railroad_terminal"]) + data["young_male"])/2.0) - ((data["cafe_count_500"] > (data["ID_railroad_terminal"] * (((data["cafe_sum_3000_min_price_avg"] >= 0.0).astype(float)) / 2.0))).astype(float))) + np.tanh(data["church_count_500"]))/2.0))))
    v["gp47"] = 0.050000*np.tanh((data["incineration_raion"] * ((((data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))))) * (data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))))))))) * ((data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))))) * (data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))))))) * (((data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))))) * (data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))))))))) * ((data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))))) * (data["incineration_raion"] * ((-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))) * (-(((-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"]))))) * (-((np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])) * np.minimum( ((data["floor"] - (data["mosque_count_500"] * data["floor"]))),  (data["big_road1_1line"])))))))))))))))
    v["gp48"] = 0.050000*np.tanh((data["floor"] * ((((data["product_type"] + data["build_count_block"])/2.0) + (data["build_count_1946-1970"] * ((data["cafe_count_5000_price_2500"] + (-(((((data["floor"] + data["build_count_1946-1970"])/2.0) + data["build_count_1946-1970"])/2.0))))/2.0)))/2.0)))
    v["gp49"] = 0.050000*np.tanh((data["male_f"] * ((data["cafe_count_3000_price_4000"] > (np.tanh(np.tanh(np.minimum( ((((((data["school_education_centers_top_20_raion"] * data["male_f"]) >= 0.0).astype(float)) - data["water_treatment_km"]) / 2.0)),  ((data["num_room"] * data["power_transmission_line_km"]))))) / 2.0)).astype(float))))
    v["gp50"] = 0.050000*np.tanh(((((((np.maximum( (data["sport_objects_raion"]),  (((((data["leisure_count_1000"] >= 0.0).astype(float)) >= 0.0).astype(float)))) < data["trc_count_500"]).astype(float)) < ((data["trc_count_500"] >= 0.0).astype(float))).astype(float)) < np.minimum( (np.minimum( (data["cafe_count_5000_price_high"]),  (data["leisure_count_1000"]))),  ((data["trc_count_500"] * data["trc_count_500"])))).astype(float)))
    v["gp51"] = 0.050000*np.tanh((data["kitch_sq"] * ((data["cafe_sum_1000_min_price_avg"] - ((data["cafe_count_500_price_1000"] > (data["cafe_count_2000_price_2500"] * (data["shopping_centers_raion"] + data["cafe_count_2000_price_2500"]))).astype(float))) - ((data["cafe_count_500_price_1000"] > (data["cafe_count_2000_price_2500"] * (data["shopping_centers_raion"] * data["cafe_sum_1000_min_price_avg"]))).astype(float)))))
    v["gp52"] = 0.050000*np.tanh(((2.0 < (data["full_sq"] - np.minimum( (np.tanh(data["life_sq"])),  (np.minimum( ((data["cafe_avg_price_3000"] / 2.0)),  (((data["full_sq"] / 2.0) - (((data["cafe_avg_price_3000"] / 2.0) - data["full_sq"]) - data["full_sq"])))))))).astype(float)))
    v["gp53"] = 0.050000*np.tanh((-(((((((((((((((data["cafe_count_500_price_2500"] + np.maximum( (data["leisure_count_500"]),  (data["trc_sqm_1000"])))/2.0) + data["cafe_count_500_price_1500"])/2.0) >= 0.0).astype(float)) / 2.0) + np.maximum( (data["16_29_male"]),  (data["cafe_count_500_price_4000"])))/2.0) + data["leisure_count_500"])/2.0) >= 0.0).astype(float)) / 2.0))))
    v["gp54"] = 0.050000*np.tanh((((data["kitch_sq"] * np.maximum( (data["state"]),  ((data["market_count_1000"] * data["railroad_station_walk_km"])))) * (np.maximum( ((data["market_count_1000"] * data["railroad_station_walk_km"])),  (np.maximum( (np.maximum( (data["market_count_5000"]),  (data["state"]))),  (data["mosque_count_5000"])))) * np.maximum( ((data["market_count_1000"] * data["railroad_station_walk_km"])),  (np.maximum( (np.maximum( (data["market_count_5000"]),  (data["state"]))),  (data["mosque_count_5000"])))))) * ((data["kitch_sq"] * np.maximum( (data["state"]),  ((data["market_count_1000"] * data["railroad_station_walk_km"])))) * (np.maximum( ((data["market_count_1000"] * data["railroad_station_walk_km"])),  (np.maximum( (np.maximum( (data["market_count_5000"]),  (data["state"]))),  (data["mosque_count_5000"])))) * np.maximum( ((data["market_count_1000"] * data["railroad_station_walk_km"])),  (np.maximum( (np.maximum( (data["market_count_5000"]),  (data["state"]))),  (data["mosque_count_5000"]))))))))
    v["gp55"] = 0.050000*np.tanh((data["full_sq"] * ((data["product_type"] + (((data["full_sq"] < data["sadovoe_km"]).astype(float)) * ((data["full_sq"] < data["sadovoe_km"]).astype(float)))) * (((np.minimum( (data["full_sq"]),  ((-(data["kitch_sq"])))) > data["num_room"]).astype(float)) * 2.0))))
    v["gp56"] = 0.050000*np.tanh((np.minimum( (data["power_transmission_line_km"]),  (data["cafe_avg_price_500"])) * ((np.minimum( (((np.minimum( (data["ekder_male"]),  (np.tanh((data["cafe_count_500_na_price"] - data["power_transmission_line_km"])))) + data["school_km"])/2.0)),  (np.tanh((data["trc_sqm_1500"] - data["cafe_count_500_na_price"])))) >= 0.0).astype(float))))
    v["gp57"] = 0.006900*np.tanh((np.minimum( (data["cafe_count_1500_na_price"]),  ((data["sport_count_5000"] * data["max_floor"]))) * ((((data["trc_sqm_500"] > (((0.0 > (data["church_count_3000"] * data["trc_sqm_1500"])).astype(float)) * data["trc_sqm_1500"])).astype(float)) > (data["church_count_3000"] * data["trc_sqm_1500"])).astype(float))))
    v["gp58"] = 0.050000*np.tanh((((data["office_sqm_500"] >= 0.0).astype(float)) * ((((data["office_sqm_500"] >= 0.0).astype(float)) * (((data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float)))) * (data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float))))) * ((data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float)))) * (data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float))))))) * (((data["office_sqm_500"] >= 0.0).astype(float)) * (((data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float)))) * (data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float))))) * ((data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float)))) * (data["railroad_station_walk_min"] * (data["prom_part_1000"] * (((data["office_sqm_500"] / 2.0) > np.tanh(data["sport_count_500"])).astype(float))))))))))
    v["gp59"] = 0.050000*np.tanh((data["full_sq"] * (data["full_sq"] * (data["kremlin_km"] * (-((((data["full_sq"] / 2.0) + (((data["prom_part_2000"] * 2.0) * ((data["full_sq"] >= 0.0).astype(float))) * np.minimum( (data["office_sqm_500"]),  (data["ID_big_road2"]))))/2.0)))))))
    v["gp60"] = 0.045260*np.tanh(((np.minimum( (np.minimum( (data["hospice_morgue_km"]),  (data["hospice_morgue_km"]))),  (np.minimum( (np.minimum( (data["hospice_morgue_km"]),  ((-((data["ts_km"] - data["build_count_1971-1995"])))))),  ((-((data["sport_count_2000"] - (-((data["sport_count_2000"] - data["build_count_1971-1995"])))))))))) >= 0.0).astype(float)))
    v["gp61"] = 0.050000*np.tanh((-(((data["leisure_count_2000"] < np.minimum( (data["park_km"]),  (np.minimum( (((np.minimum( (data["cafe_count_2000_na_price"]),  (data["church_count_1500"])) + (-(data["cafe_sum_3000_max_price_avg"])))/2.0)),  (np.minimum( ((-((data["cafe_count_2000_na_price"] * 2.0)))),  (np.minimum( (data["cafe_count_2000_na_price"]),  (data["church_count_1500"]))))))))).astype(float)))))
    v["gp62"] = 0.050000*np.tanh((data["green_part_1000"] * (data["trc_sqm_1000"] * ((data["railroad_1line"] + (((((((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0))) * ((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)))) * (((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0))) * ((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0))))) + (data["ID_railroad_terminal"] * data["ID_railroad_terminal"]))/2.0) * ((((((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0))) * ((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)))) * (((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0))) * ((((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0)) * (((data["max_floor"] + data["big_road1_1line"])/2.0) * ((data["max_floor"] + data["big_road1_1line"])/2.0))))) + (data["ID_railroad_terminal"] * data["ID_railroad_terminal"]))/2.0)))/2.0))))
    v["gp63"] = 0.050000*np.tanh((np.minimum( (np.minimum( (data["cafe_avg_price_2000"]),  (data["cafe_count_3000_price_1000"]))),  (data["material"])) * ((data["full_sq"] > ((data["cafe_avg_price_2000"] < np.minimum( ((-(data["indust_part"]))),  ((data["indust_part"] * data["indust_part"])))).astype(float))).astype(float))))
    v["gp64"] = 0.045940*np.tanh(((((0.636620 * data["life_sq"]) > (((data["office_count_1500"] > (-((data["life_sq"] / 2.0)))).astype(float)) * ((data["office_count_1500"] > (-((data["life_sq"] / 2.0)))).astype(float)))).astype(float)) * (((-((data["mosque_count_1000"] / 2.0))) + (data["ID_big_road2"] * data["ID_big_road2"]))/2.0)))
    v["gp65"] = 0.045590*np.tanh((-(((((data["material"] * (data["material"] * (data["sport_objects_raion"] - (data["water_treatment_km"] / 2.0)))) / 2.0) * ((data["zd_vokzaly_avto_km"] < (data["water_treatment_km"] / 2.0)).astype(float))) * (((data["material"] * (data["material"] * (data["sport_objects_raion"] - (data["water_treatment_km"] / 2.0)))) / 2.0) * ((data["zd_vokzaly_avto_km"] < (data["water_treatment_km"] / 2.0)).astype(float)))))))
    v["gp66"] = 0.050000*np.tanh((data["ID_metro"] * ((((data["leisure_count_1500"] > ((np.tanh((-(np.tanh(data["cafe_count_1000_price_4000"])))) < data["trc_count_500"]).astype(float))).astype(float)) > ((np.minimum( (data["big_church_count_500"]),  (data["big_church_count_500"])) < data["cafe_count_500_price_2500"]).astype(float))).astype(float))))
    v["gp67"] = 0.050000*np.tanh((data["mosque_count_500"] * (((data["mosque_count_1500"] * data["market_count_2000"]) + ((((data["office_sqm_1500"] * data["office_sqm_1500"]) * data["num_room"]) + data["num_room"])/2.0)) * ((data["market_count_2000"] - ((data["leisure_count_2000"] >= 0.0).astype(float))) + data["mosque_count_5000"]))))
    v["gp68"] = 0.050000*np.tanh((data["additional_education_km"] * (data["max_floor"] * (((((((((data["bulvar_ring_km"] * data["bulvar_ring_km"]) * (data["bulvar_ring_km"] * data["bulvar_ring_km"])) > data["church_count_500"]).astype(float)) > (data["additional_education_km"] * data["additional_education_km"])).astype(float)) * ((((((data["bulvar_ring_km"] * data["bulvar_ring_km"]) * (data["bulvar_ring_km"] * data["bulvar_ring_km"])) > data["church_count_500"]).astype(float)) > (data["additional_education_km"] * data["additional_education_km"])).astype(float))) * ((data["additional_education_km"] > data["max_floor"]).astype(float))) * ((((((((data["bulvar_ring_km"] * data["bulvar_ring_km"]) * (data["bulvar_ring_km"] * data["bulvar_ring_km"])) > data["church_count_500"]).astype(float)) > (data["additional_education_km"] * data["additional_education_km"])).astype(float)) * ((((((data["bulvar_ring_km"] * data["bulvar_ring_km"]) * (data["bulvar_ring_km"] * data["bulvar_ring_km"])) > data["church_count_500"]).astype(float)) > (data["additional_education_km"] * data["additional_education_km"])).astype(float))) * ((data["additional_education_km"] > data["max_floor"]).astype(float)))))))
    v["gp69"] = 0.050000*np.tanh((data["prom_part_1500"] * (((((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0)) * ((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0))) * (((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0)) * ((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0)))) * ((((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0)) * ((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0))) * (((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0)) * ((((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0) * (((-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))))))) * (-((((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))) * ((-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0)))) * (-((((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0) * ((data["trc_count_1500"] + (data["thermal_power_plant_raion"] * data["office_sqm_5000"]))/2.0))))))))) * 2.0)))))))
    v["gp70"] = 0.050000*np.tanh(((data["leisure_count_1000"] + ((data["cafe_count_500_price_1500"] * np.minimum( (((data["work_female"] + data["max_floor"]) - data["cafe_sum_1500_min_price_avg"])),  ((data["max_floor"] - ((data["cafe_sum_1500_min_price_avg"] > data["work_female"]).astype(float)))))) / 2.0))/2.0))
    v["gp71"] = 0.042520*np.tanh((((data["build_count_slag"] * 2.0) * 2.0) * ((data["cafe_count_2000_na_price"] > ((data["build_year"] < ((data["sport_count_500"] > (((data["big_road1_km"] + np.maximum( (np.maximum( (data["market_count_5000"]),  (data["water_1line"]))),  (data["build_year"])))/2.0) / 2.0)).astype(float))).astype(float))).astype(float))))
    v["gp72"] = 0.050000*np.tanh((((((data["full_sq"] > ((((4.0) > np.maximum( ((data["metro_km_walk"] * (-(data["cafe_sum_1000_min_price_avg"])))),  (np.maximum( (data["metro_km_walk"]),  (data["school_education_centers_top_20_raion"]))))).astype(float)) * 2.0)).astype(float)) * (((4.0) > data["full_sq"]).astype(float))) * 2.0) * 2.0))
    v["gp73"] = 0.040390*np.tanh((((((data["catering_km"] > ((data["market_count_1500"] + (np.tanh(np.minimum( ((data["7_14_female"] * data["office_count_3000"])),  ((data["church_synagogue_km"] / 2.0)))) * 2.0))/2.0)).astype(float)) * 2.0) * 2.0) * (data["mosque_count_1500"] * (data["church_synagogue_km"] * data["church_synagogue_km"]))))
    v["gp74"] = 0.050000*np.tanh((data["stadium_km"] * (data["cafe_sum_2000_max_price_avg"] * (-(np.tanh(((data["green_part_5000"] < (np.tanh(data["public_healthcare_km"]) - (np.tanh(((data["public_healthcare_km"] < data["cafe_sum_2000_max_price_avg"]).astype(float))) * np.tanh(((data["public_healthcare_km"] < data["cafe_sum_2000_max_price_avg"]).astype(float)))))).astype(float))))))))
    v["gp75"] = 0.050000*np.tanh((data["cafe_count_500_price_high"] * np.minimum( ((data["cafe_count_500_price_high"] + ((data["cafe_count_5000_price_1000"] > np.minimum( ((data["cafe_count_500_price_high"] - data["office_count_3000"])),  ((data["big_road1_1line"] - ((data["build_count_slag"] > data["office_count_3000"]).astype(float)))))).astype(float)))),  ((data["build_count_slag"] - data["7_14_all"])))))
    v["gp76"] = 0.013240*np.tanh((data["mosque_count_500"] * ((data["railroad_1line"] + ((data["mosque_count_500"] * data["sport_count_1500"]) + ((data["cafe_count_2000_price_high"] + (((data["big_road1_1line"] * data["cafe_count_2000_price_high"]) + data["ID_big_road2"]) + data["market_count_5000"])) + data["prom_part_3000"])))/2.0)))
    v["gp77"] = 0.050000*np.tanh(np.minimum( (((data["green_part_500"] * 2.0) * ((data["mosque_count_1500"] > ((data["product_type"] * (((data["male_f"] - np.maximum( (((data["cafe_sum_5000_min_price_avg"] >= 0.0).astype(float))),  ((data["male_f"] * data["male_f"])))) >= 0.0).astype(float))) / 2.0)).astype(float)))),  ((data["product_type"] * data["product_type"]))))
    v["gp78"] = 0.049990*np.tanh(((data["cafe_count_1000_price_1000"] > np.maximum( (data["sport_count_3000"]),  ((np.maximum( (data["workplaces_km"]),  (np.maximum( (np.tanh((data["workplaces_km"] * data["workplaces_km"]))),  (np.maximum( (data["prom_part_1000"]),  (data["trc_sqm_1500"])))))) * np.maximum( (data["workplaces_km"]),  (np.maximum( (np.tanh((data["workplaces_km"] * data["workplaces_km"]))),  (np.maximum( (data["prom_part_1000"]),  (data["trc_sqm_1500"])))))))))).astype(float)))
    v["gp79"] = 0.050000*np.tanh(((np.minimum( (data["cafe_sum_500_max_price_avg"]),  (data["trc_count_1000"])) + (((data["full_sq"] < (((data["leisure_count_5000"] < data["cafe_sum_500_max_price_avg"]).astype(float)) / 2.0)).astype(float)) / 2.0)) * data["railroad_1line"]))
    v["gp80"] = 0.050000*np.tanh((data["build_count_foam"] * (data["church_count_500"] * ((data["prom_part_1500"] < (np.minimum( (np.minimum( (np.minimum( (data["trc_sqm_2000"]),  ((data["church_count_500"] + data["church_count_500"])))),  (data["build_count_foam"]))),  (data["cafe_sum_5000_min_price_avg"])) * ((data["prom_part_1500"] < data["railroad_1line"]).astype(float)))).astype(float)))))
    v["gp81"] = 0.050000*np.tanh(np.minimum( (((data["trc_count_5000"] > data["ID_bus_terminal"]).astype(float))),  ((-((data["market_count_3000"] * ((data["green_part_500"] > ((((data["cafe_count_500_price_1000"] < (((data["leisure_count_1000"] * 2.0) > data["sub_area"]).astype(float))).astype(float)) > (data["cafe_count_500_price_1000"] / 2.0)).astype(float))).astype(float))))))))
    v["gp82"] = 0.050000*np.tanh((((data["work_all"] > np.tanh(data["mosque_count_5000"])).astype(float)) * ((data["office_sqm_5000"] > (((-(np.minimum( (data["office_sqm_5000"]),  (np.minimum( (data["full_all"]),  ((((-(data["swim_pool_km"])) > data["work_all"]).astype(float)))))))) >= 0.0).astype(float))).astype(float))))
    v["gp83"] = 0.046670*np.tanh((((data["product_type"] < data["big_church_count_2000"]).astype(float)) * (-(((data["big_church_count_2000"] < (data["additional_education_km"] + np.minimum( (data["cafe_count_5000_na_price"]),  (((data["radiation_raion"] >= 0.0).astype(float)))))).astype(float))))))
    v["gp84"] = 0.050000*np.tanh((data["full_sq"] * (((data["full_sq"] * (data["full_sq"] * data["cafe_count_1000_price_4000"])) + ((np.minimum( (data["full_sq"]),  ((data["culture_objects_top_25_raion"] - data["green_zone_km"]))) + data["green_zone_part"])/2.0))/2.0)))
    v["gp85"] = 0.050000*np.tanh(((((((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0) * ((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0)) * (((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0) * ((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0))) / 2.0) * (((((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0) * ((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0)) * (((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0) * ((data["state"] + ((data["cafe_count_1500_price_500"] < np.minimum( ((-(data["trc_count_2000"]))),  ((data["trc_count_2000"] + (data["ID_railroad_station_walk"] * data["ID_railroad_station_walk"]))))).astype(float)))/2.0))) / 2.0)))
    v["gp86"] = 0.050000*np.tanh(((((data["cafe_count_2000_na_price"] >= 0.0).astype(float)) * ((((data["cafe_count_2000_na_price"] >= 0.0).astype(float)) > (data["cafe_count_2000_na_price"] * (((data["cafe_count_2000_na_price"] * 2.0) * 2.0) * 2.0))).astype(float))) * ((((data["green_part_2000"] > data["trc_sqm_3000"]).astype(float)) * 2.0) * 2.0)))
    v["gp87"] = 0.050000*np.tanh((data["water_1line"] * ((((data["leisure_count_1000"] + (data["material"] * (data["prom_part_1000"] * (((data["material"] + data["office_sqm_5000"])/2.0) / 2.0))))/2.0) >= 0.0).astype(float))))
    v["gp88"] = 0.050000*np.tanh(((np.minimum( ((data["thermal_power_plant_raion"] + (data["thermal_power_plant_raion"] + data["sport_count_2000"]))),  (np.minimum( ((data["prom_part_1500"] * data["sport_count_2000"])),  (((data["prom_part_1500"] / 2.0) + (data["cafe_count_1000_price_2500"] + data["thermal_power_plant_raion"])))))) >= 0.0).astype(float)))
    v["gp89"] = 0.050000*np.tanh((((((data["big_church_count_1500"] >= 0.0).astype(float)) > ((((data["market_count_5000"] > np.tanh(((np.tanh(data["cafe_count_5000_price_2500"]) >= 0.0).astype(float)))).astype(float)) * 2.0) * 2.0)).astype(float)) * ((((data["big_church_count_1500"] >= 0.0).astype(float)) > ((((data["market_count_5000"] > np.tanh(((np.tanh(data["cafe_count_5000_price_2500"]) >= 0.0).astype(float)))).astype(float)) * 2.0) * 2.0)).astype(float))))
    v["gp90"] = 0.050000*np.tanh(((data["church_count_3000"] > (np.maximum( (np.maximum( (np.tanh(data["sport_count_5000"])),  ((np.maximum( (((data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))) * (data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))))),  (data["power_transmission_line_km"])) * np.maximum( (((data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))) * (data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))))),  (data["power_transmission_line_km"])))))),  (data["big_church_count_500"])) * np.maximum( (np.maximum( (np.tanh(data["sport_count_5000"])),  ((np.maximum( (((data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))) * (data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))))),  (data["power_transmission_line_km"])) * np.maximum( (((data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))) * (data["sport_count_1500"] * ((data["sport_count_5000"] >= 0.0).astype(float))))),  (data["power_transmission_line_km"])))))),  (data["big_church_count_500"])))).astype(float)))
    v["gp91"] = 0.037860*np.tanh(np.minimum( ((data["detention_facility_raion"] * np.tanh((data["cafe_count_2000_price_1500"] - data["kitch_sq"])))),  ((-((((data["green_part_1500"] * data["green_part_1500"]) * (data["green_part_1500"] * data["green_part_1500"])) * (((((data["detention_facility_raion"] / 2.0) > data["detention_facility_km"]).astype(float)) / 2.0) * ((((data["detention_facility_raion"] / 2.0) > data["detention_facility_km"]).astype(float)) / 2.0))))))))
    v["gp92"] = 0.049990*np.tanh((-((data["cafe_count_2000_price_4000"] * (np.minimum( (data["ID_bus_terminal"]),  (np.maximum( (data["market_count_1500"]),  (np.minimum( (data["ID_big_road2"]),  (data["office_km"])))))) * np.minimum( (data["ID_metro"]),  (((data["office_km"] + data["full_sq"])/2.0))))))))
    v["gp93"] = 0.050000*np.tanh((data["prom_part_1000"] * (((data["office_sqm_500"] > ((data["16_29_all"] < ((((((((data["office_sqm_500"] < (data["railroad_km"] - data["ID_bus_terminal"])).astype(float)) + data["ID_bus_terminal"])/2.0) + data["metro_km_avto"])/2.0) + data["metro_km_avto"])/2.0)).astype(float))).astype(float)) / 2.0)))
    v["gp94"] = 0.050000*np.tanh((data["life_sq"] * ((data["office_count_3000"] < np.minimum( (np.minimum( (np.minimum( (data["cafe_avg_price_1500"]),  (np.maximum( ((-(np.maximum( (data["leisure_count_3000"]),  (data["cafe_count_2000_price_high"]))))),  ((data["cafe_count_2000_price_high"] * data["cafe_count_2000_price_high"])))))),  ((data["office_sqm_2000"] * 2.0)))),  (data["cafe_avg_price_1500"]))).astype(float))))
    v["gp95"] = 0.050000*np.tanh((((np.minimum( (data["public_healthcare_km"]),  (np.minimum( ((data["public_healthcare_km"] - (data["church_count_1500"] / 2.0))),  ((data["cafe_count_5000_price_1500"] + ((((data["leisure_count_2000"] - (data["trc_count_1500"] / 2.0)) / 2.0) + data["market_count_1000"])/2.0)))))) >= 0.0).astype(float)) * 2.0))
    v["gp96"] = 0.050000*np.tanh((data["office_km"] * ((np.tanh(np.minimum( (data["prom_part_500"]),  (((data["office_sqm_1000"] + np.tanh(((((data["prom_part_1000"] * ((np.minimum( (((data["prom_part_500"] >= 0.0).astype(float))),  (data["sport_count_500"])) >= 0.0).astype(float))) >= 0.0).astype(float)) - data["prom_part_500"])))/2.0)))) >= 0.0).astype(float))))
    v["gp97"] = 0.012870*np.tanh((data["big_church_count_500"] * ((data["office_count_500"] * 2.0) * (data["office_count_500"] * ((data["office_count_500"] > (data["cafe_count_1000_price_500"] + (((((data["additional_education_km"] >= 0.0).astype(float)) < np.maximum( (data["additional_education_km"]),  (((data["cafe_count_500"] >= 0.0).astype(float))))).astype(float)) * 2.0))).astype(float))))))
    v["gp98"] = 0.050000*np.tanh((data["swim_pool_km"] * (data["0_17_male"] * (-((data["big_road1_1line"] * ((data["swim_pool_km"] < (np.minimum( (data["ID_railroad_terminal"]),  (data["metro_min_walk"])) + ((((-(data["cafe_count_500_price_1500"])) * data["swim_pool_km"]) > data["cafe_count_1000"]).astype(float)))).astype(float))))))))
    v["gp99"] = 0.050000*np.tanh(((((1.570796 < np.maximum( (np.maximum( ((1.570796 * np.minimum( (data["16_29_female"]),  (data["ID_railroad_station_walk"])))),  (np.maximum( ((data["floor"] / 2.0)),  (data["state"]))))),  ((data["cafe_count_1000_price_high"] / 2.0)))).astype(float)) * ((1.570796 < np.maximum( (np.maximum( ((1.570796 * np.minimum( (data["16_29_female"]),  (data["ID_railroad_station_walk"])))),  (np.maximum( ((data["floor"] / 2.0)),  (data["state"]))))),  ((data["cafe_count_1000_price_high"] / 2.0)))).astype(float))) * 2.0))
    v["gp100"] = 0.050000*np.tanh(((data["ID_railroad_station_avto"] + (np.maximum( (data["trc_count_1500"]),  (data["metro_min_avto"])) + data["ID_metro"])) * ((((data["big_road1_1line"] < np.maximum( (data["children_preschool"]),  (data["ID_metro"]))).astype(float)) > (1.570796 + np.maximum( (data["trc_count_1500"]),  (data["metro_min_avto"])))).astype(float))))
    return np.expm1(v.sum(axis=1))

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')
macro = pd.read_csv('../input/macro.csv')
id_train = train.id
id_test = test.id
train.sample(3)

# %%
y_train = train["price_doc"]
x_train = train.drop(["id", "timestamp", "price_doc"], axis=1)
x_test = test.drop(["id", "timestamp"], axis=1)

#can't merge train with test because the kernel run for very long time

for c in x_train.columns:
    if x_train[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(x_train[c].values)) 
        x_train[c] = lbl.transform(list(x_train[c].values))
        
for c in x_test.columns:
    if x_test[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(x_test[c].values)) 
        x_test[c] = lbl.transform(list(x_test[c].values))

# %%
ss = preprocessing.StandardScaler()
alldata = pd.concat([x_train,x_test])
alldata.fillna(-1,inplace=True,axis=1)
ss.fit(alldata[alldata.columns])
gptrain = x_train.copy()
gptrain.fillna(-1,inplace=True,axis=1)
gptrain[gptrain.columns] = ss.transform(gptrain[gptrain.columns])
gptrain['price_doc'] = np.log1p(y_train)
gptest = x_test.copy()
gptest.fillna(-1,inplace=True,axis=1)
gptest[gptest.columns] = ss.transform(gptest[gptest.columns])

# %%
y_predict = GP(gptrain)
print(y_train[:5])
print(y_predict[:5])

# %%
print(np.sqrt(((np.log1p(y_predict)-np.log1p(y_train))**2).mean()))

# %%
y_predict = GP(gptest)
output = pd.DataFrame({'id': id_test, 'price_doc': y_predict})
output.to_csv('gpsubmission.csv', index=False)
