# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go

import plotly
plotly.offline.init_notebook_mode(connected=True)

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #4682B4;"><b style="color:white;">Health Rankings - Factors that Influence how well we live</b></h1></center>
#
# According to phase-ii-widsdatathon2022/critical_health/critical_health/Health-Related Datasets for WiDS Phase 2 Datathon.docx:
#
# E. County Health Rankings
#
# Description prepared by Mingying Yang, Computer Science student at MIT
#
# "The County Health Rankings are county-level data and are based on a model of community health that emphasizes the many factors that influence how long and how well we live. The Rankings use more than 30 measures that help communities understand how healthy their residents are today (health outcomes) and what will impact their health in the future (health factors)."
#
# "The County Health Rankings are compiled from many different types of data. To calculate the ranks, each of the measures was first standardized using a z-score. The ranks are then calculated based on weighted sums of the standardized measures within each state. The county with the lowest z-score (best health) gets a rank of number1 for that state and the county with the highest score (worst health) is assigned a rank corresponding to the number of places we rank in that state."

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQE41F7PAPHi_g7HGIBZ7K2B1DRGlZnjNyl6Q&usqp=CAU)wndu.com

# %%
df = pd.read_csv("/kaggle/input/cusersmarildownloadsrankmdcsv/rankmd.csv", delimiter=';', encoding='ISO-8859-2')
pd.set_option('display.max_columns', None)
df.head()

# %% [markdown]
# #Ci Low and Ci High
#
# "In frequentist statistics, a confidence interval (CI) is a range of estimates for an unknown parameter, defined as an interval with a lower bound and an upper bound (notwithstanding one-sided confidence intervals, which are bounded only on one side). The interval is computed at a designated confidence level. The 95% confidence level is most common, but other levels (such as 90% or 99%) are sometimes used. The confidence level represents the long-run frequency of confidence intervals that contain the true value of the parameter. In other words, 95% of confidence intervals computed at the 95% confidence level contain the parameter, and likewise for other confidence levels."
#
# https://en.wikipedia.org/wiki/Confidence_interval

# %%
df.isnull().sum()

# %% [markdown]
# #Premature Deaths
#
# "Death that occurs before the average age of death in a certain population. In the United States, the average age of death is about 75 years. Smoking cigarettes and being exposed to secondhand tobacco smoke are leading causes of premature death in the United State."
#
# "They can increase the risk of cancer, heart disease, stroke, lung disease, and many other health problems. Other causes of premature death are injuries and suicide."
#
# https://www.cancer.gov/publications/dictionaries/cancer-terms/def/premature-death

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['premature_deathDeaths'])
plt.axvline(df['premature_deathDeaths'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Premature Deaths distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['poor-or_fair_health_% Fair or Poor Health'])
plt.axvline(df['poor-or_fair_health_% Fair or Poor Health'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Poor or Fair Health % Distribution');

# %% [markdown]
# #Low Birth Weight
#
# "Regarding gestational age, newborns younger than 22 weeks with extreme low birth weight (500–999 g) had a 92.5% death rate, which decreased to 63.2% with an increase in gestational age from 22 to 27 weeks."
#
# "Among newborns in this same weight stratum, when presenting a gestation age of 28–31 weeks, there was a greater drop in the percentage of death, indicating a 35.6% mortality."
#
# "Very low birth weight infants (1000–1499 g) presented a variation in gestational age between 22 weeks and, as a maximum, 36 weeks, and those born at 22–27 weeks had a risk of 1.9 (95% CI, 1.2–2.8) times greater of death in the first year of life, when compared with the reference category (32–36 weeks)."
#
# https://pophealthmetrics.biomedcentral.com/articles/10.1186/s12963-019-0195-7#:~:text=Regarding%20gestational%20age%2C%20newborns%20younger,from%2022%20to%2027%20weeks.

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Low Birth Weight Quartile Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['low_birthweight_Quartile'], hist=True, rug=False,norm_hist=True);

# %% [markdown]
# #Smoking
#
# Cigarette smoking causes premature death:
#
# "Life expectancy for smokers is at least 10 years shorter than for nonsmokers. Quitting smoking before the age of 40 reduces the risk of dying from smoking-related disease by about 90%."
#
# https://www.cdc.gov/tobacco/data_statistics/fact_sheets/health_effects/tobacco_related_mortality/index.htm#:~:text=Cigarette%20smoking%20causes%20premature%20death,years%20shorter%20than%20for%20nonsmokers.&text=Quitting%20smoking%20before%20the%20age,related%20disease%20by%20about%2090%25.

# %% [markdown]
# ![](https://www.dlsph.utoronto.ca/wp-content/uploads/2017/08/premature-mortality.jpg)dlsph.utoronto.ca

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Adult Smoking % Smokers Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['adult_smoking_% Smokers'], hist=True, rug=False,norm_hist=True, color='r');

# %% [markdown]
# #Obesity

# %% [markdown]
# ![](https://slideplayer.com/slide/14095999/86/images/2/Prevention+of+obesity%3D+prevention+of+premature+death+%3Dreduced+mortality.jpg)slideplayer.com

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Adult Obesity % Adults with Obesity Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['adult_obesity_% Adults with Obesity'], hist=True, rug=False,norm_hist=True, color='purple');

# %% [markdown]
# #I don't know why that snippets haven't removed Nan once. I had to run them 3 times.

# %%
# Lets first handle numerical features with nan value
numerical_nan = [feature for feature in df.columns if df[feature].isna().sum()>1 and df[feature].dtypes!='O']
numerical_nan

# %%
df[numerical_nan].isna().sum()

# %%
## Replacing the numerical Missing Values

for feature in numerical_nan:
    ## We will replace by using median since there are outliers
    median_value=df[feature].median()
    
    df[feature].fillna(median_value,inplace=True)
    
df[numerical_nan].isnull().sum()

# %% [markdown]
# #Food Environment Index
#
# "There is strong evidence that food deserts are correlated with high prevalence of overweight, obesity, and premature death as supermarkets traditionally provide healthier options than convenience stores or smaller grocery stores."
#
# "Additionally, those with low income may face barriers to accessing a consistent source of healthy food. Lacking consistent access to food is related to negative health outcomes such as weight gain, premature mortality, asthma, and activity limitations, as well as increased health care costs."
#
# https://www.countyhealthrankings.org/explore-health-rankings/measures-data-sources/county-health-rankings-model/health-factors/health-behaviors/diet-exercise/food-environment-index

# %% [markdown]
# #To avoid ValueError: invalid literal for int() with base 10: '5,5'
#
# Run the next snippet removing commas

# %%
#Remove commas to avoid errors ValueError: invalid literal for int() with base 10

#Code by Sohom Majumder https://www.kaggle.com/sohommajumder21/statistical-tests-for-understanding-life-value/comments

df['food_environment_index_Food Environment Index']=df['food_environment_index_Food Environment Index'].str.replace(',', '')
df['food_environment_index_Food Environment Index'] = pd.to_numeric(df['food_environment_index_Food Environment Index'], errors = 'coerce')

# %% [markdown]
# #ValueError: cannot convert float NaN to integer
#
# Run AGAIN the removing Nan snippets above.  Though I had run the snippet I appeared: food_environment_index_Food Environment Index        19 Nan
#
# Now, run the below snippet.

# %%
df["food_environment_index_Food Environment Index"]=df["food_environment_index_Food Environment Index"].apply(int)

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['food_environment_index_Food Environment Index'], color='green')
plt.axvline(df['food_environment_index_Food Environment Index'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('food_environment_index_Food Environment Index Distribution');

# %% [markdown]
# #Physical Inactivity
#
# "Inactivity is responsible for 9% of premature mortality (5.1% to 12.5%), or >5.3 of the 57 million deaths that occurred worldwide in 2008. If inactivity were not eliminated, but decreased instead by 10% or 25%, >533,000 and >1.3 million deaths, respectively, may be averted each year."
#
# "By eliminating physical inactivity, life expectancy of the world’s population is estimated to increase by 0.68 (0.41 to 0.95) years."
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3645500/#:~:text=Inactivity%20is%20responsible%20for%209,may%20be%20averted%20each%20year.

# %% [markdown]
# ![](http://slideplayer.com/slide/17824124/106/images/2/Physical+inactivity+Less+than+150+minutes+of+moderate+physical+activity+per+week..jpg)slideplayer.com

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Physical Inactivity % Physically Inactive Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['physical_inactivity_% Physically Inactive'], hist=True, rug=False,norm_hist=True, color='yellow');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['access_to_exercise_opportunities_% With Access to Exercise Opportunities'], color='green')
plt.axvline(df['access_to_exercise_opportunities_% With Access to Exercise Opportunities'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Access to Exercise Opportunities %  Distribution');

# %% [markdown]
# #Excessive Drinking

# %% [markdown]
# "According to a 2014 World Health Organization (WHO) report, among people ages 15 to 49, alcohol misuse was the first-leading risk factor for premature death and disability."
#
# "In 2016, approximately 14 percent of total deaths among people ages 20 to 39 are alcohol attributable."
#
# https://www.niaaa.nih.gov/publications/brochures-and-fact-sheets/alcohol-facts-and-statistics#:~:text=According%20to%20a%202014%20World,for%20premature%20death%20and%20disability.&text=In%202016%2C%20approximately%2014%20percent,to%2039%20are%20alcohol%20attributable.

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8tsM9_Aw0U-hwgaoOwl8nDaXRACIgrmrJdPqSTLYbH6z08sv048rAl2h2piTOyG2HXa0&usqp=CAU)alcoholjustice.com

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Excessive Drinking % Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['excessive_drinking_% Excessive Drinking'], hist=True, rug=False,norm_hist=True, color='orange');

# %% [markdown]
# #Drunk Driving - Alcohol Impaired Driving Deaths
#
# "Every day, about 28 people in the United States die in drunk-driving crashes — that's one person every 52 minutes. In 2019, these deaths reached the lowest percentage since 1982 when NHTSA started reporting alcohol data — but still 10,142 people lost their lives. These deaths were all preventable."
#
# https://www.nhtsa.gov/risky-driving/drunk-driving#:~:text=Every%20day%2C%20about%2028%20people,10%2C142%20people%20lost%20their%20lives.

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['alcohol_impaired_driving_deaths_95% CI - Low'], color='green')
plt.axvline(df['alcohol_impaired_driving_deaths_95% CI - Low'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Alcohol Impaired Driving Deaths 95% CI  Low Distribution');

# %% [markdown]
# #Since I got ValueError: could not convert string to float: '583,4'

# %% [markdown]
# #Sexually Transmitted Infections

# %% [markdown]
# "More than 340 million new cases of sexually transmitted bacterial and protozoal infections occur worldwide every year."
#
# "Untreated gonococcal and chlamydial infections in women result in pelvic inflammatory disease in up to 40% of cases. One in four of these results in infertility. Worldwide, untreated maternal infections account for eye infections leading to blindness in up to 4000 newborn babies every year."
#
# "New vaccines against human papillomavirus infection could stop the untimely deaths of about 240 000 women from cervical cancer every year in resource-poor settings."
#
# https://www.euro.who.int/en/health-topics/communicable-diseases/sexually-transmitted-infections/data-and-statistics

# %% [markdown]
# ![](https://www.kff.org/wp-content/uploads/2020/02/FEATURE2-Knowledge-of-how-common-STIs-are_1-002.png)https://www.kff.org/womens-health-policy/issue-brief/public-knowledge-and-attitudes-about-sexually-transmitted-infections/

# %%
#Remove commas to avoid errors ValueError: invalid literal for int() with base 10

#Code by Sohom Majumder https://www.kaggle.com/sohommajumder21/statistical-tests-for-understanding-life-value/comments

df['sexually_transmitted_infections_Chlamydia Rate']=df['sexually_transmitted_infections_Chlamydia Rate'].str.replace(',', '')
df['sexually_transmitted_infections_Chlamydia Rate'] = pd.to_numeric(df['sexually_transmitted_infections_Chlamydia Rate'], errors = 'coerce')

# %% [markdown]
# CHLAMYDIA
#
# "Chlamydia is a common STD caused by infection with Chlamydia trachomatis. It can cause cervicitis, urethritis, and proctitis."
#
# In women, these infections can lead to:
#
# pelvic inflammatory disease (PID), tubal factor infertility, ectopic pregnancy, and chronic pelvic pain.
#
# https://www.cdc.gov/std/chlamydia/stdfact-chlamydia-detailed.htm

# %% [markdown]
# #Run for the 3rd time the removing Nan snippet above
#
# Because there are still: sexually_transmitted_infections_Chlamydia Rate      154 Nan
#
# #I think my Removing Nan is Jinxed!!

# %%
df["sexually_transmitted_infections_Chlamydia Rate"]=df["sexually_transmitted_infections_Chlamydia Rate"].apply(int)

# %% [markdown]
# #No more Chlamydia Nan!
#
# #Fine better would be: NO CHLAMYDIA at ALL!  No I'm ready for my Distplot without Chlamydia NaNs.

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['sexually_transmitted_infections_Chlamydia Rate'], color='brown')
plt.axvline(df['sexually_transmitted_infections_Chlamydia Rate'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Sexually Transmitted Infections Chlamydia Rate  Distribution');

# %% [markdown]
# #Teen Births
#
# "Approximately 12 million girls aged 15–19 years and at least 777,000 girls under 15 years give birth each year in developing regions."
#
# "At least 10 million unintended pregnancies occur each year among adolescent girls aged 15–19 years in the developing world."
#
# "Complications during pregnancy and childbirth are the leading cause of death for 15–19-year-old girls globally."
#
# "Of the estimated 5.6 million abortions that occur each year among adolescent girls aged 15–19 years, 3.9 million are unsafe, contributing to maternal mortality, morbidity and lasting health problems.
#
# https://www.who.int/news-room/fact-sheets/detail/adolescent-pregnancy

# %% [markdown]
# ![](https://aho.org/wp-content/uploads/2019/09/teen-pregnancy-1000x750.jpg)aho.org

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['teen_births_Teen Birth Rate (Asian)'], color='green')
plt.axvline(df['teen_births_Teen Birth Rate (Asian)'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Teen Birth Rate (Asian) Distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['teen_births_Teen Birth Rate (Black)'], color='red')
plt.axvline(df['teen_births_Teen Birth Rate (Black)'].values.mean(), color='blue', linestyle='dashed', linewidth=1)
plt.title('Teen Birth Rate (Black) Distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['teen_births_Teen Birth Rate (Hispanic)'], color='blue')
plt.axvline(df['teen_births_Teen Birth Rate (Hispanic)'].values.mean(), color='purple', linestyle='dashed', linewidth=1)
plt.title('Teen Birth Rate (Hispanic) Distribution');

# %% [markdown]
# #Uninsured
#
# "Uninsurance is associated with mortality. The strength of that association appears similar to that from a study that evaluated data from the mid-1980s, despite changes in medical therapeutics and the demography of the uninsured since that time."
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2775760/
#
# "The number of uninsured Americans reached 47 million in 2006, and it continues to rise. For many of the uninsured, the lack of health insurance has dire consequences. The uninsured face medical debt, often go without necessary care, and even die prematurely."
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2323087/#:~:text=PMID%3A%2018420687-,More%20than%2026%20000%20Americans%20die%20each,of%20lack%20of%20health%20insurance

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Uninsured % Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['uninsured_% Uninsured'], hist=True, rug=False,norm_hist=True, color='cyan');

# %% [markdown]
# "The percentage of uninsured people in each state ranges from 10% in Minnesota to 28% in Texas. However, Ron Pollack, executive director of Families USA, advised against making comparisons across states because of differences in population size and death rate."
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2323087/#:~:text=PMID%3A%2018420687-,More%20than%2026%20000%20Americans%20die%20each,of%20lack%20of%20health%20insurance

# %% [markdown]
# #Zapata County - Texas State

# %%
unin = df[(df['County']=='Zapata')].reset_index(drop=True)
unin.tail()

# %% [markdown]
# #Anoka County - Minnesota State

# %%
unin1 = df[(df['County']=='Anoka')].reset_index(drop=True)
unin1.tail()

# %% [markdown]
# #Primary Care Physicians
#
# Association of number of primary care physicians with preventable hospitalizations and premature deaths
#
# Authors: Satya Preetham Gunta,Ain Ul-Ejaz,Abigail May Murphy,Kaylea May Gunn,Ambika Bhatnagar,Vanika Angraal,Angel Lopez-Candales, & Suveen Angraal
#
# https://doi.org/10.1080/00325481.2021.2021038
#
# "Primary care physicians (PCPs) may be the first providers for patients in a healthcare interaction, putting them in a unique position that may determine the health trajectory of a patient. Assessing whether PCPs improve the overall health of a community through reducing preventable hospital stays and premature deaths may provide necessary information towards improving the health outcomes at grassroots."
#
# https://www.tandfonline.com/doi/abs/10.1080/00325481.2021.2021038

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Primary Care Physicians Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['primary_care_physicians_# Primary Care Physicians'], hist=True, rug=False,norm_hist=True, color='cyan');

# %% [markdown]
# #Dentists
#
# Oral health in relation to all-cause mortality: the IPC cohort study
#
# Citation: Adolph M, Darnaud C, Thomas F, et al. Oral health in relation to all-cause mortality: the IPC cohort study. Sci Rep. 2017;7:44604. Published 2017 Mar 15. doi:10.1038/srep44604
#
# "While oral health as a whole is represented by an aggregation of an array of characteristics, a limited number of oral health variables have been used in previous reports of oral disease as a risk factor for health."
#
# That study, based on clinical measurements, aims to evaluate the association between a combination of various oral health variables and future mortality using a propensity score model. Having previously found that poor oral health was associated with an elevated likelihood of hypertension, the authors anticipated a similar relation with mortality.
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5353629/

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['dentists_Dentist Rate'], color='blue')
plt.axvline(df['dentists_Dentist Rate'].values.mean(), color='purple', linestyle='dashed', linewidth=1)
plt.title('Dentists Rate Distribution');

# %% [markdown]
# #Mental Health Providers
#
# Premature death among people with severe mental disorders
#
# "People with severe mental disorders on average tend to die earlier than the general
# population. This is referred to as premature mortality. There is a 10-25 year life expectancy reduction in patients with severe mental disorders."
#
# "The vast majority of these deaths are due to chronic physical medical conditions such as
# cardiovascular, respiratory and infectious diseases, diabetes and hypertension. Suicide is
# another important cause of death."
#
# "Mortality rates among people with schizophrenia is 2 to 2.5 times higher than the general
# population."
#
# "People with bipolar mood disorders have high mortality rates ranging from 35% higher to
# twice as high as the general population."
#
# "There is a 1.8 times higher risk of dying associated with depression. People with severe
# mental illness do not receive the same quality of physical health care as the general
# population."
#
# "The majority of deaths of patients with severe mental illness that are due to physical medical conditions are preventable with more attentive checks for physical illness, side effects of medicines and suicidal tendencies."
#
# https://www.who.int/mental_health/management/info_sheet.pdf

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Mental Health Providers Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['mental_health_providers_# Mental Health Providers'], hist=True, rug=False,norm_hist=True, color='magenta');

# %% [markdown]
# #Preventable Hospitalizations
#
# "Preventable hospitalizations are an important measure of whether people with preventable health conditions are receiving effective care and avoiding hospital stays. This is a measure of how well the overall public health and health care systems are proactively addressing preventable conditions. The data reported here applies to Medicare recipients."
#
# https://marc2.org/healthdata/status_hosp.htm
#
# #American Indian and Alaska Native (AIAN)

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis
# American Indian and Alaska Native (AIAN)

sns.distplot(df['preventable_hospital_stays_Preventable Hosp. Rate (AIAN)'], color='green')
plt.axvline(df['preventable_hospital_stays_Preventable Hosp. Rate (AIAN)'].values.mean(), color='purple', linestyle='dashed', linewidth=1)
plt.title('Preventable Hospitals Rate (AIAN) Distribution');

# %% [markdown]
# "The data presented indicates that between 2010 and 2014, preventable hospitalizations declined in every county, as well as both states and the nation. However, with the exceptions of Johnson and Platte counties, the preventable hospitalization rates are higher than the rate nationally."
#
# https://marc2.org/healthdata/status_hosp.htm

# %% [markdown]
# #Platte County - Wyoming State
#
# Preventable Hospitalization Rate: 4310.0

# %%
prev = df[(df['County']=='Platte')].reset_index(drop=True)
prev.head()

# %% [markdown]
# #Mammography Screening
#
# "Breast cancer remains the most common nonskin cancer, the second leading cause of cancer deaths, and the leading cause of premature death in US women. Mammography screening has been proven effective in reducing breast cancer deaths in women age 40 years and older.
#
#
# "A mortality reduction of 40% is possible with regular screening. Treatment advances cannot overcome the disadvantage of being diagnosed with an advanced-stage tumor."
#
# https://www.sciencedirect.com/science/article/pii/S1546144021003835

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Mammography Screening % (White) Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['mammography_screening_% Screened (White)'], hist=True, rug=False,norm_hist=True, color='magenta');

# %% [markdown]
# #Flu Vaccination
#
# "It should be noted that influenza vaccination appears to be beneficial in primary prevention, as a study carried out on 80,363 people aged 65 and over showed that vaccination reduced the incidence of myocardial infarction by 25% over a period of 13 years."
#
# "Whether you are healthy or have cardiovascular disease, there are only advantages to getting the influenza vaccine."
#
# https://observatoireprevention.org/en/2021/11/04/influenza-vaccination-reduces-the-risk-of-premature-death-in-coronary-patients/

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['flu_vaccinations_% Vaccinated'], color='green')
plt.axvline(df['flu_vaccinations_% Vaccinated'].values.mean(), color='chartreuse', linestyle='dashed', linewidth=1)
plt.title('Flu Vaccinations % Vaccinated Distribution');

# %% [markdown]
# #High School Completion
#
# "How education levels affected mortality over time, the researchers concluded that, using the educational disparities observed among people born in 1945, the deaths in 2010 of hundreds of thousands of American adults could have been prevented if those people had gotten high-school or bachelor’s degrees.
#
# "Specifically, the deaths of roughly 145,000 individuals were associated with those individuals’ failure to get a high-school degree, while the deaths of another 110,000 or so people were attributed to those adults failing to complete their four-year degree programs."
#
# In public health and public-health policy, there is a lot of emphasis on addressing health behaviors: smoking, obesity, nutrition, drinking, et cetera,” “There should be more attention paid to education, which is a more fundamental driver of these behaviors.”
#
# https://www.theatlantic.com/education/archive/2015/07/dropping-out-could-be-deadly/398024/

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('High School Completion Population Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['high_school_completion_Population'], hist=True, rug=False,norm_hist=True, color='crimson');

# %% [markdown]
# #Unemployment
#
# "Previous observational follow-up studies of individuals have shown that mortality rates among the unemployed are higher than among the employed. Two mechanisms may explain this excess mortality:"
#
# "Causal effects of unemployment: Becoming jobless and prolonged redundancy have negative
# effects on health and increase the risk of premature death. The causal effects of unemployment are mainly assumed to be mediated through increased psychosocial stress, tobacco and alcohol consumption, as well as loss of income and material deprivation."
#
# "Selection: Persons likely to become unemployed, or to have difficulty in re-employment,
# pre-existing ill-health and/or "lifestyle" (e.g. tobacco and alcohol consumption, diet), socioeconomic (e.g. social class, housing tenure) or personal characteristics (e.g. age, sex, physical weakness, psychological characteristics, and early life experiences) that increase the risk of future ill-health and mortality."
#
# https://www.tilastokeskus.fi/isi99/proceedings/arkisto/varasto/mart0473.pdf

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['unemployed_Labor Force'], color='DarkViolet')
plt.axvline(df['unemployed_Labor Force'].values.mean(), color='green', linestyle='dashed', linewidth=1)
plt.title('Unemployed Labor Force Distribution');

# %% [markdown]
# #Poverty and early deaths await millions of world's most disadvantaged children
#
# "Some 69 million children under five years of age will die from mostly preventable causes, 167 million children will live in poverty, and 750 million women will have been married as children by 2030, unless the world focuses more on the plight of its most disadvantaged children, according to a United Nations report published on 28 June 2016."
#
# https://news.un.org/en/story/2016/06/533242-poverty-and-early-deaths-await-millions-worlds-most-disadvantaged-children#:~:text=Some%2069%20million%20children%20under,to%20a%20United%20Nations%20report

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Children in Poverty 95% CI - High Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['children_in_poverty_95% CI - High'], hist=True, rug=False,norm_hist=True, color='crimson');

# %% [markdown]
# #Income inequality
#
# Premature mortality attributable to socioeconomic inequality in England between 2003 and 2018: an observational study
#
# Authors: Dan Lewer, Wikum Jayatunga, Robert W Aldridge,Chantal Edge, Prof Michael Marmot,
# Alistair Story, Prof Andrew Hayward. DOI:https://doi.org/10.1016/S2468-2667(19)30219-1
#
# "Low socioeconomic position is consistently associated with increased risk of premature death. The aim of this study is to measure the aggregate scale of inequality in premature mortality for the whole population."
#
# "35·6% (95% CI 35·3–35·9) of premature deaths were attributable to socioeconomic inequality, equating to 877 082 deaths, or one every 10 min. The biggest contributors were ischaemic heart disease (152 171 excess deaths), respiratory cancers (111 083) and chronic obstructive pulmonary disease (83 593).
#
#
# "The most unequal causes of death were tuberculosis, opioid use, HIV, psychoactive drugs use, viral hepatitis, and obesity, each with more than two-thirds attributable to inequality.
#
# "Inequality was greater among men and peaked in early childhood and at age 40–49 years. The proportion of deaths attributable to inequality increased during the study period, particularly for women, because mortality rates among the most deprived women (excluding cardiovascular diseases) plateaued, and for some diseases increased. A mean of 14·4 months of life before age 75 years are lost due to socioeconomic inequality."
#
# https://www.thelancet.com/journals/lanpub/article/PIIS2468-2667(19)30219-1/fulltext

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['income_inequality_20th Percentile Income'], color='DodgerBlue')
plt.axvline(df['income_inequality_20th Percentile Income'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Income Inequality 20th Percentile Distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['income_inequality_80th Percentile Income'], color='green')
plt.axvline(df['income_inequality_80th Percentile Income'].values.mean(), color='magenta', linestyle='dashed', linewidth=1)
plt.title('Income Inequality 80th Percentile Distribution');

# %% [markdown]
# #Single Parent Households
#
# Single-parent households and mortality among children and youth
#
# Authors: Paul R. Amato and Sarah E. Patterson - DOI:10.1016/j.ssresearch.2016.09.017
#
# "Regression models with state and year fixed effects revealed that increases in single parenthood were associated with small increments in accidental deaths and homicides."
#
# https://www.researchgate.net/publication/308999941_Single-parent_households_and_mortality_among_children_and_youth

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Children in Single Parent Households 95% CI - Low Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['children_in_single_parent_households_95% CI - Low'], hist=True, rug=False,norm_hist=True, color='crimson');

# %% [markdown]
# #Social Relationships
#
# "The quality and quantity of individuals' social relationships has been linked not only to mental health but also to both morbidity and mortality."
#
# "The influence of social relationships on risk for mortality is comparable with well-established risk factors for mortality."
#
# https://journals.plos.org/plosmedicine/article?id=10.1371/journal.pmed.1000316

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Social Associations Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['social_associations_# Associations'], hist=True, rug=False,norm_hist=True, color='Indigo');

# %% [markdown]
# #Violent Crimes
#
# "Crime and violence experienced by individuals living in a community is an important public health issue. People can be exposed to violence in many ways. They may be victimized directly, witness violence or property crimes in their community, or hear about crime and violence from other residents."
#
# "Violence can lead to premature death or cause non-fatal injuries. People who survive violent crime endure physical pain and suffering and may also experience mental distress and reduced quality of life. Repeated exposure to crime and violence may be linked to an increase in negative health outcomes."
#
# https://health.gov/healthypeople/objectives-and-data/social-determinants-health/literature-summaries/crime-and-violence

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Violent Crimes Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['violent_crime_Annual Average Violent Crimes'], hist=True, rug=False,norm_hist=True, color='LawnGreen');

# %% [markdown]
# #Injury deaths
#
# "Injuries and violence have been neglected from the global health agenda for
# many years, despite being predictable and largely preventable. Evidence from
# many countries shows that dramatic successes in preventing injuries and
# violence can be achieved through concerted efforts that involve, but are not
# limited to, the health sector."
#
# "The international community needs to work with governments and civil society around the world to implement these proven measures and reduce the unnecessary loss of life that occurs each day as a result of injuries and violence."
#
# https://apps.who.int/iris/bitstream/handle/10665/149798/9789241508018_eng.pdf

# %% [markdown]
# ![](https://pbs.twimg.com/media/CsoBZbFWYAAFeL2.jpg)twitter.com

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Injury Deaths Injury Death Rate (Black) Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['injury_deaths_Injury Death Rate (Black)'], hist=True, rug=False,norm_hist=True, color='Navy');

# %% [markdown]
# #To avoid ValueError: invalid literal for int() with base 10: '9,2'

# %% [markdown]
# #Particulate Matter
#
# Particulate Matter (PM) Basics
#
# What is PM, and how does it get into the air?
#
# "PM stands for particulate matter (also called particle pollution): the term for a mixture of solid particles and liquid droplets found in the air. Some particles, such as dust, dirt, soot, or smoke, are large or dark enough to be seen with the naked eye. Others are so small they can only be detected using an electron microscope."
#
# Particle pollution includes:
#
# "PM10 : inhalable particles, with diameters that are generally 10 micrometers and smaller; and PM2.5 : fine inhalable particles, with diameters that are generally 2.5 micrometers and smaller."
#
# "How small is 2.5 micrometers? Think about a single hair from your head. The average human hair is about 70 micrometers in diameter – making it 30 times larger than the largest fine particle."
#
# https://www.epa.gov/pm-pollution/particulate-matter-pm-basics

# %%
#Remove commas to avoid errors ValueError: invalid literal for int() with base 10

#Code by Sohom Majumder https://www.kaggle.com/sohommajumder21/statistical-tests-for-understanding-life-value/comments

df['air_pollution_particulate_matter_Average Daily PM2.5']=df['air_pollution_particulate_matter_Average Daily PM2.5'].str.replace(',', '')
df['air_pollution_particulate_matter_Average Daily PM2.5'] = pd.to_numeric(df['air_pollution_particulate_matter_Average Daily PM2.5'], errors = 'coerce')

# %% [markdown]
# #To avoid ValueError: could not convert string to float: '9,2'

# %% [markdown]
# #Seems that we still have air_pollution_particulate_matter_Average Daily PM2.5      26 NaNs
#
# After running the removing snippets for the 4th time, the line below shows No error.

# %%
df["air_pollution_particulate_matter_Average Daily PM2.5"]=df["air_pollution_particulate_matter_Average Daily PM2.5"].apply(int)

# %% [markdown]
# #Run removing Nan for the 4th time: ValueError: cannot convert float NaN to integer

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['air_pollution_particulate_matter_Average Daily PM2.5'], color='magenta')
plt.axvline(df['air_pollution_particulate_matter_Average Daily PM2.5'].values.mean(), color='green', linestyle='dashed', linewidth=1)
plt.title('Air pollution Particulate Matter Average Daily PM2.5 Distribution');

# %% [markdown]
# #Presence of Water Violation
#
# "In 2020, 74% of the global population (5.8 billion people) used a safely managed drinking-water service – that is, one located on premises, available when needed, and free from contamination."
#
# "Globally, at least 2 billion people use a drinking water source contaminated with faeces. Microbial contamination of drinking-water as a result of contamination with faeces poses the greatest risk to drinking-water safety."
#
# "Microbiologically contaminated drinking water can transmit diseases such as diarrhoea, cholera, dysentery, typhoid and polio and is estimated to cause 485 000 diarrhoeal deaths each year."
#
# "While the most important chemical risks in drinking water arise from arsenic, fluoride or nitrate, emerging contaminants such as pharmaceuticals, pesticides, per- and polyfluoroalkyl substances (PFASs) and microplastics generate public concern."
#
# "Safe and sufficient water facilitates the practice of hygiene, which is a key measure to prevent not only diarrhoeal diseases, but acute respiratory infections and numerous neglected tropical diseases."
#
# "Over 2 billion people live in water-stressed countries, which is expected to be exacerbated in some regions as result of climate change and population growth."
#
# https://www.who.int/news-room/fact-sheets/detail/drinking-water

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["drinking_water_violations_Presence of Water Violation"].value_counts().plot.barh(color=['blue', '#f5005a'], title='Presence of Water Violation',);

# %% [markdown]
# #Severe Housing Problems
#
# "Inadequate housing accounts for over 100 000 deaths per year in the WHO European Region and causes or contributes to many preventable diseases and injuries, including respiratory, nervous system and cardiovascular diseases and cancer."
#
# “Home should be a safe place. Yet for many it is not, especially for vulnerable people who spend most of their time at home such as young children, older people and people with disabilities,” “Inadequate housing conditions represent a serious environmental health threat that is preventable.”
#
# "However, the reality is that much of the housing stock in the European Union (EU) still had many health hazards in 2009, such as excessive noise exposure (22%), dampness (16%), overcrowding (18%), problems keeping the dwelling warm in winter (9%) and a lack of hygiene equipment such as an indoor flush toilet (3%) or a bath or shower (3%).  Comparable statistical data for the countries in the European Region outside the EU are not easily available, but evidence indicates that the housing situation is worse, especially among people with low income."
#
#
# "People die of cold at home: low indoor temperatures cause 12.8 deaths per 100 000 population per year; and exposure to radon causes 2–3 deaths per 100 000 population for selected countries."
#
# "In most societies in the European Region, people spend about 90% of their time in built and artificial environments. Ensuring that the housing stock is as safe and healthy as possible will therefore provide great benefits to public health and society generally and contribute to primary prevention efforts to reduce noncommunicable diseases."
#
# https://www.euro.who.int/en/media-centre/sections/press-releases/2011/06/new-evidence-from-who-inadequate-housing-causes-more-than-100-000-annual-deaths-in-europe

# %% [markdown]
# ![](https://assets.americashealthrankings.org/app/uploads/ahr_fullreport_4col_severe_housing_problems.png)americashealthrankings.org

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['severe_housing_problems_Overcrowding'], color='olive')
plt.axvline(df['severe_housing_problems_Overcrowding'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Severe Housing Problems Overcrowding Distribution');

# %% [markdown]
# #Drive Alone to Work
#
# U.S. Value: 75.9%
#
# Healthiest State: New York: 52.8%
#
# Least-healthy State: Alabama: 85.2%
#
# Definition: Percentage of workers ages 16 and older who drove alone to work
#
# https://www.americashealthrankings.org/explore/annual/measure/drive_alone/state/NY

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['drive_alone_to_work_% Drive Alone to Work'], color='olive')
plt.axvline(df['drive_alone_to_work_% Drive Alone to Work'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Drive Alone to Work % Drive Alone to Work Distribution');

# %% [markdown]
# #New York State % Drive Alone to work
#
# Broome County 81%

# %%
driv = df[(df['State']=='New York')].reset_index(drop=True)
driv.head()

# %% [markdown]
# #Long Commute Driving Alone
#
# "Workers who drive alone to work contribute to traffic congestion and air pollution. The sedentary habit of driving to work has been associated with decreased levels of physical activity and cardiorespiratory health, and increased BMI and hypertension. Stress-inducing traffic congestion may further exacerbate these negative health effects. Alternatives to driving alone–carpooling, taking public transportation, and biking–can help to reduce the number of commuters who drive alone to work each day."
#
# https://www.nevadatomorrow.org/indicators/index/view?indicatorId=2367&localeId=1813

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['long_commute_driving_alone_# Workers who Drive Alone'], color='salmon')
plt.axvline(df['long_commute_driving_alone_# Workers who Drive Alone'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Workers who Drive Alone Distribution');

# %% [markdown]
# #Acknowledgements:
#
# Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook
#
# Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis
#
# Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil
#
# Sohom Majumder https://www.kaggle.com/sohommajumder21/statistical-tests-for-understanding-life-value/comments

# %% [markdown]
# #Since this Dataset has many columns I opened just some of the features that contribute to a better/worse way of life.
#
# #An insight of those factors can give hints how to change behaviors, so that those health rankings could be improved. I hope so.
