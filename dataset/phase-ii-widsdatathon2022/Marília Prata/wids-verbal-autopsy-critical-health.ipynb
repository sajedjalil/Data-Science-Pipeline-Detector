# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go

import plotly
plotly.offline.init_notebook_mode(connected=True)

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: white;"><b style="color:purple;">Verbal Autopsy and Covid-19 Deaths</b></h1></center>
#
# Use of Verbal Autopsy in the identification of COVID-19 deaths
#
# "VA can fill a critical gap in measuring the mortality from COVID-19 for deaths which occur outside of a healthcare setting. A set of questions to identify COVID-19 deaths has been included in version 1.5.3 of the electronic (ODK) 2016 WHO VA instrument."
#
# "The questions have been added to the WHO VA questionnaire upon request by countries and to standardize and align questions proposed by different initiatives with the WHO definition of death due to COVID-19, the underlying case definition for surveillance of COVID-19, including questions for rapid mortality surveillance purposes."
#
# "A brief technical note has been added to the WHO VA Standards Manual that offers guidance for the use of VA to identify COVID-19 deaths. Specific information on each of the new questions can be found in the updated sections of the question by question instructions (Appendices A-C) of the VA Field Interviewer Manual for the 2016 WHO VA Instrument."
#
# https://www.who.int/standards/classifications/other-classifications/verbal-autopsy-standards-ascertaining-and-attributing-causes-of-death-tool#:~:text=The%20WHO%20verbal%20autopsy%20instrument&text=The%20instrument%20is%20designed%20for,SmartVA%2C%20InterVA%2C%20InSilicoVA).

# %% [markdown]
# ![](https://crvsgateway.info/image/O1LpLLeslM0Myc0tKAKTEAkA/VA-Guidelines-Step-1)crvsgateway.info

# %%
#Code by Kaggle Bot https://www.kaggle.com/kerneler/starter-do-not-count-calories-count-2598f6d5-5

nRowsRead = 1000 # specify 'None' if want to read whole file
df2 = pd.read_csv('../input/cusersmarildownloadsverbautcsv/verbaut.csv', delimiter=';', nrows = nRowsRead, encoding='ISO-8859-2')
df2.dataframeName = 'verbaut.csv'
nRow, nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')
df2.head()

# %%
#Code by Kaggle Bot https://www.kaggle.com/kerneler/starter-do-not-count-calories-count-2598f6d5-5

nRowsRead = 1000 # specify 'None' if want to read whole file
df3 = pd.read_csv('../input/cusersmarildownloadschoicecsv/choice.csv', delimiter=';', nrows = nRowsRead, encoding='ISO-8859-2')
df3.dataframeName = 'choice.csv'
nRow, nCol = df3.shape
print(f'There are {nRow} rows and {nCol} columns')
df3.head()

# %%
select501 = df3[(df3['list_name']=='select_501')].reset_index(drop=True)
select501.head()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil
#With [:10] the letters were so tiny that we couldn't read

df3["label_english"].value_counts()[:5].plot.barh(title='Verbal Autopsy Symptoms', figsize=(20,10), color='orange');

# %% [markdown]
# #Vaccines

# %%
vaccines = df3[(df3['list_name']=='select_vaccines')].reset_index(drop=True)
vaccines.head(10)

# %%
select501 = df3[(df3['list_name']=='select_501')].reset_index(drop=True)
select501.head()

# %%
select25 = df3[(df3['list_name']=='select_25')].reset_index(drop=True)
select25.head(10)

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil
#With [:10] the letters were so tiny that we couldn't read

df3["label_english"].value_counts()[:10].plot.barh(title='Verbal Autopsy Diseases', figsize=(20,10), color='g');

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'purple',
                      height =2000,
                      width = 2000
                     ).generate(str(vaccines["name"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Verbal Autopsy Vaccines")
plt.show()

# %% [markdown]
# <h1><span class="label label-default" style="background-color:purple;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:white; padding:10px">Verbal Autopsy - Docx WiDS file</span></h1><br>
#
# According to the Docx file in WiDS:
#
# Verbal Autopsy Dataset
#
# Description prepared by Adrien Carrel, MSc student in Engineering Sciences at CentraleSupelec, Paris, France & Marie Charpignon, PhD candidate in Statistics at MIT IDSS
#
# "The PHMRC Gold Standard Verbal Autopsy Dataset was collected as part of the Population Health Metrics Research Consortium (PHMRC) project. The dataset contains verbal autopsies (VAs) that were collected in 2009 in six sites and across four countries (India, Mexico, Tanzania, and the Philippines) using a standardized VA questionnaire developed by the PHMRC. Each individual VA is matched with a "gold standard" diagnosis of the underlying cause of death, which was established from medical records using stringent diagnostic criteria, including laboratory, pathology and medical imaging findings."
#
# Useful link
# Murray, C.J., Lopez, A.D., Black, R. et al. Population Health Metrics Research Consortium gold standard verbal autopsy validation study: design, implementation, and development of analysis datasets. Popul Health Metrics 9, 27 (2011). DOI: https://doi.org/10.1186/1478-7954-9-27.

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'green',
                      height =2000,
                      width = 2000
                     ).generate(str(df3["label_english"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Verbal Autopsy in English")
plt.show()

# %%
select510 = df3[(df3['list_name']=='select_510')].reset_index(drop=True)
select510.head(12)

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil
#With [:10] the letters were so tiny that we couldn't read

select510["name"].value_counts()[:10].plot.barh(title='Verbal Autopsy Diseases', figsize=(20,10), color='yellow');

# %%
df2["label_english"].value_counts()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil
#With [:10] the letters were so tiny that we couldn't read

df2["label_english"].value_counts()[:5].plot.barh(title='Verbal Autopsy in english', figsize=(20,10), color='g');

# %% [markdown]
# Population Health Metrics Research Consortium gold standard verbal autopsy validation study: design, implementation, and development of analysis datasets
#
# https://pophealthmetrics.biomedcentral.com/articles/10.1186/1478-7954-9-27
#
# https://www.who.int/standards/classifications/other-classifications/verbal-autopsy-standards-ascertaining-and-attributing-causes-of-death-tool#:~:text=The%20WHO%20verbal%20autopsy%20instrument&text=The%20instrument%20is%20designed%20for,SmartVA%2C%20InterVA%2C%20InSilicoVA).

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'green',
                      height =2000,
                      width = 2000
                     ).generate(str(df2["label_english"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Verbal Autopsy in English")
plt.show()

# %% [markdown]
# #Some abbreviations on Critical Health file:
#
# RBIRTH2018 Birth rate in period 7/1/2017 to 6/30/2018
#
# RDEATH2018 Death rate in period 7/1/2017 to 6/30/2018
#
# RNATURALINC2018 Natural increase rate in period 7/1/2017 to 6/30/2018
#
# RINTERNATIONALMIG2018 Net international migration rate in period 7/1/2017 to 6/30/2018
#
# RDOMESTICMIG2018 Net domestic migration rate in period 7/1/2017 to 6/30/2018
#
# RNETMIG2018 Net migration rate in period 7/1/2017 to 6/30/2018
#
# https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2019/co-est2019-alldata.pdf
#
#  Association of American Medical Colleges (AAMC)
#
#  https://arxiv.org/ftp/arxiv/papers/2010/2010.15754.pdf
#
#  PCTPOVALL 2018 Estimated percent of people of all ages in poverty
# 2018
#
# MEDHHINC_2018:
# ed HH Income Percent of State Total 2018 County Household Median Income as a percent of the
# State Total Median Household Income, 2018
#
# https://www.medrxiv.org/content/10.1101/2020.04.24.20078204v1.full.pdf

# %%
df = pd.read_csv("/kaggle/input/phase-ii-widsdatathon2022/critical_health/critical_health/dataset.csv", delimiter=',', encoding='utf8')
pd.set_option('display.max_columns', None)
df.head()

# %%
df.isnull().sum()

# %% [markdown]
# #Really?? There is no missing values? Check with Missingo

# %%
# visualizing the missing values using missingo
import missingno as msno
msno.matrix(df)
plt.show()

# %% [markdown]
# #How do you want us to handle this huge file? Same way you'd eat an elephant... one bite at a time.
#
# Warrick Brown:
# How do you want us to handle this?
#
# Gil Grissom:
# Same way you'd eat an elephant... one bite at a time.
#
# https://www.quotes.net/mquote/696432

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis
#RDEATH2018 Death rate in period 7/1/2017 to 6/30/2018

sns.distplot(df['R_death_2018'])
plt.axvline(df['R_death_2018'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Death rate 2018 distribution');

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil
#With [:10] the letters were so tiny that we couldn't read

select25["label_english"].value_counts()[:10].plot.barh(title='Verbal Autopsy Employement', figsize=(20,10), color='red');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis
#RDEATH2018 Death rate in period 7/1/2017 to 6/30/2018

sns.distplot(df['Employed_2018'])
plt.axvline(df['Employed_2018'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Employed 2018 Distribution');

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Birth rate 2018 Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['R_birth_2018'], hist=True, rug=False,norm_hist=True, color='red');

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Estimated percent of people of all ages in poverty 2018 Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(df['PCTPOVALL_2018'], hist=True, rug=False,norm_hist=True, color='brown');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['Active Physicians per 100000 Population 2018 (AAMC)'], color = 'g')
plt.axvline(df['Active Physicians per 100000 Population 2018 (AAMC)'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Active Physicians per 100000 Population 2018 (AAMC) Distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['Total Hospitals (2019)'], color = 'purple')
plt.axvline(df['Total Hospitals (2019)'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Total Hospitals (2019) Distribution');

# %% [markdown]
# #Where are the Latinos, the Hispanic Population?
#
# HBA FEMALE Hispanic, Black or African American alone female population: Rel. Importance on Contextual determinants of covid-19: 1.000
#
# https://www.medrxiv.org/content/10.1101/2020.04.24.20078204v1.full.pdf

# %%
features = ['Black-alone pop', 'Native American/American Indian-alone pop', 'Asian-alone pop', 'White-alone pop']

# %%
#Code by Ashwin Shetgaonkar https://www.kaggle.com/code/ashwinshetgaonkar/mech-prop-data-transformations-lightgbm

# determining the skewness values
skewness_values=df[features].skew().to_list()
skewness_values[:3]

# %%
#Code by Ashwin Shetgaonkar  https://www.kaggle.com/code/ashwinshetgaonkar/mech-prop-data-transformations-lightgbm

# distribution of numerical feature columns
for col,sk in zip(features,skewness_values):
    plt.figure(figsize=(14,6))
    sns.histplot(data=df,x=col,kde=True)
    plt.title(f"Distribution of {col}\nskewness:{sk:.2f}",fontsize=20)

# %% [markdown]
# #The 2014 Who Verbal Autopsy instrument
#
# https://www.who.int/standards/classifications/other-classifications/verbal-autopsy-standards-ascertaining-and-attributing-causes-of-death-tool#:~:text=The%20WHO%20verbal%20autopsy%20instrument&text=The%20instrument%20is%20designed%20for,SmartVA%2C%20InterVA%2C%20InSilicoVA).

# %%
#Code by Kaggle Bot https://www.kaggle.com/kerneler/starter-do-not-count-calories-count-2598f6d5-5

nRowsRead = 1000 # specify 'None' if want to read whole file
df1 = pd.read_csv('../input/cusersmarildownloadsautopsycsv/autopsy.csv', delimiter=';', nrows = nRowsRead, encoding='ISO-8859-2')
df1.dataframeName = 'autopsy.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
df1.tail()

# %% [markdown]
# #Verbal Autopsy Questions, in english.

# %%
df1["english"].value_counts()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df1["english"].value_counts()[:10].plot.barh(title='Verbal Autopsy in english', figsize=(8,6), color='g');

# %% [markdown]
# #Verbal Autopsy Questions, in Bahasa.

# %%
df1["label::Bahasa"].value_counts()

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'green',
                      height =2000,
                      width = 2000
                     ).generate(str(df1["label::Bahasa"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Verbal Autopsy in Bahasa")
plt.show()

# %%
df1["relevant"].value_counts()

# %%
df1["hint_english"].value_counts()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df1["hint_english"].value_counts()[:10].plot.barh(title='Verbal Autopsy English hints', figsize=(8,6), color='r');

# %%
df1["hint::Bahasa"].value_counts()

# %%
df1["constraint_message::Bahasa"].value_counts()

# %% [markdown]
# <h1><span class="label label-default" style="background-color:purple;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:white; padding:10px">Verbal Autopsy Instrument for COVID-19 (VAIC)</span></h1><br>
#
# Development of the Verbal Autopsy Instrument for COVID-19 (VAIC)
#
# Authors: Tony Rosen , Monika M Safford , Madeline R Sterling , Parag Goyal , Melissa Patterson , Christina Al Malouf , Mary Ballin , Tessa Del Carmen , Veronica M LoFaso , Barrie L Raik , Ingrid Custodio , Alyssa Elman , Sunday Clark , Mark S Lachs  - PMC8231744 DOI: 10.1007/s11606-021-06842-1
#
# "Background: Improving accuracy of identification of COVID-19-related deaths is essential to public health surveillance and research. The verbal autopsy, an established strategy involving an interview with a decedent's caregiver or witness using a semi-structured questionnaire, may improve accurate counting of COVID-19-related deaths."
#
# "Objective: To develop and pilot-test the Verbal Autopsy Instrument for COVID-19 (VAIC) and a death adjudication protocol using it."
#
# "The authors reviewed the VAIC and clinical information for the 15 deaths and developed a death adjudication process/algorithm to determine whether the underlying cause of death was definitely (40% of these pilot cases), probably (33%), possibly (13%), or unlikely/definitely not (13%) COVID-19-related. They noted differences between the adjudicated cause of death and a death certificate."
#
# "Conclusions: The VAIC and a death adjudication protocol using it may improve accuracy in identifying COVID-19-related deaths."
#
# https://pubmed.ncbi.nlm.nih.gov/34173194/

# %% [markdown]
# #World Health Organization (WHO):  VA in the identification of COVID-19 deaths
#
# Since this file has so many information to be approached, to start the analysis I joined some Verbal Autopsy (World Health Organization :  VA in the identification of COVID-19 deaths) to compare with some charts of the Critical Health file(MIT Critical Data: CDC county level COVID data).
