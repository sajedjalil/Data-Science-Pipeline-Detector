# %%
# https://docs.python.org/3.6/library/filecmp.html
# https://docs.python.org/3/library/pathlib.html

import filecmp

xyz_folders = map(str, range(1, 2400))
xyz_files = [folder+"/geometry.xyz" for folder in xyz_folders]

match, mismatch, errors = filecmp.cmpfiles("../input/train", "../input/train", 
                                           xyz_files, shallow=False)
print("match", match)
print("mismatch", mismatch)
print("errors", errors)

# %% [markdown]
# the output above makes sense since it's comparing all geometry.xyz files found in train folder - there should be at least 1 match for each xyz file

# %%
from pathlib import Path
all_xyz = list(Path('../input').glob('**/*.xyz'))
#all_xyz = sorted(Path('../input').glob('**/*.xyz'))
cnt_xyz = len(all_xyz)
print("total # geometry files:", cnt_xyz)

print(all_xyz[:12])
print('*'*21)
print("tail:\n", all_xyz[-12:])

# %% [markdown]
# ## file by file comparison

# %%
# str(all_xyz[0])
similar_files = []
for file1 in all_xyz:
    for file2 in all_xyz:
        cmp_flag = filecmp.cmp(str(file1), str(file2), shallow=False)
        if cmp_flag and str(file1) != str(file2):
            ## add file string of lesser subfolder integer
            ## to the front of our result string
            int_sub1 = int(str(file1).split('/')[3])
            int_sub2 = int(str(file2).split('/')[3])
            if int_sub1 <= int_sub2:
                # equal sign not needed
                similar_files.append(f"{file1}, {file2}")
            else:
                #int_sub1 > int_sub2:
                similar_files.append(f"{file2}, {file1}")
                
## get rid of duplicates
similar_files = set(similar_files)

# %%
print(similar_files)

# %% [markdown]
# there you have it, these are the *.xyz files with similar content (obviously not considering files in the same subfolder - ../../1/geometry.xyz should return True when compared to itself):
# + ../input/__train/1215__/geometry.xyz  >>>  ../input/__train/1886__/geometry.xyz
# + ../input/__train/531__/geometry.xyz  >>>  ../input/__train/1379__/geometry.xyz
# + ../input/__train/353__/geometry.xyz  >>>  ../input/__train/2075__/geometry.xyz
# + ../input/__test/212__/geometry.xyz  >>>  ../input/__train/1553__/geometry.xyz
# + ../input/__train/2319__/geometry.xyz  >>>  ../input/__train/2337__/geometry.xyz
# + ../input/__train/126__/geometry.xyz  >>>  ../input/__train/395__/geometry.xyz
# + ../input/__train/308__/geometry.xyz  >>>  ../input/__train/2154__/geometry.xyz
# + ../input/__train/2333__/geometry.xyz  >>>  ../input/__train/2370__/geometry.xyz

# %% [markdown]
# ### disclaimer
# it is my first example with the filecmp module so I cannot verify what it does or how. I'll have to learn more about that after competing
