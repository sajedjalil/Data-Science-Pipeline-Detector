# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read input file and rename columns

# %%
train = pd.read_csv('../input/train.csv')
train.rename(columns={
    'number_of_total_atoms': 'natoms',
    'percent_atom_al': 'al',
    'percent_atom_ga': 'ga',
    'percent_atom_in': 'in',
    'lattice_vector_1_ang': 'a',
    'lattice_vector_2_ang': 'b',
    'lattice_vector_3_ang': 'c',
    'lattice_angle_alpha_degree': 'alpha',
    'lattice_angle_beta_degree': 'beta',
    'lattice_angle_gamma_degree': 'gamma',
    'formation_energy_ev_natom': 'E0',
    'bandgap_energy_ev': 'bandgap'
}, inplace=True)

# %% [markdown]
# Add a few possibly useful features

# %%
train['spacegroup_gamma'] = train.apply(
    lambda row: '{:03.0f}-{:03d}'.format(row['spacegroup'], int((row['gamma']+5)/10)*10),
    axis=1)
train['a_over_b'] = train.apply(lambda row: row['a'] / row['b'], axis=1)
train['c_over_b'] = train.apply(lambda row: row['c'] / row['b'], axis=1)

# %% [markdown]
# Scatter plots by spacegroup_gamma

# %%
for i, sgg in enumerate(sorted(train['spacegroup_gamma'].unique())):
    train[train['spacegroup_gamma'] == sgg].plot(
        figsize=(16,8), kind='scatter', x='a_over_b', y='c_over_b', title=sgg,
        ax=plt.subplot2grid((2, 4), (i//4, i%4))
    )
plt.tight_layout()
plt.show()

# %% [markdown]
# * looks like there are 10-11 configurations
# * if I remember correctly back from the physics of semiconductors class, the bandgap might be related to the deformation potential, i.e. how much these lattice configurations "depart" from the "standard" ones, i.e. the amount of "stress" put on the lattice.
# * ot sure if the same is true for the activation energy, but it might be worth investigating
