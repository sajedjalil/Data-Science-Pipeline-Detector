# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error

# %%
def GPFE(data):
    return (0.167936 +
            0.025000*np.tanh(np.where(data["percent_atom_ga"]>0, np.where(data["SG_227"]>0, 31.006277, ((((data["lattice_vector_3_ang"]) - (((31.006277) / 2.0)))) - (np.cos((((data["lattice_vector_3_ang"]) * 2.0))))) ), data["lattice_vector_3_ang"] )) +
            0.025000*np.tanh((((((((((((((((np.sin((((((data["percent_atom_in"]) * 2.0)) * 2.0)))) + (np.tanh((data["SG_227"]))))/2.0)) - (data["percent_atom_ga"]))) * 2.0)) * 2.0)) * 2.0)) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((((((np.where(data["SG_194"]>0, (11.29595851898193359), np.where((((data["SG_12"]) < (((data["percent_atom_in"]) * 2.0)))*1.)>0, data["SG_227"], -3.0 ) )) + (data["SG_12"]))) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((np.where((((data["percent_atom_in"]) < (((np.sin((((((data["percent_atom_in"]) * 2.0)) * (((data["percent_atom_in"]) * 2.0)))))) * 2.0)))*1.)>0, (((data["percent_atom_ga"]) < (0.318310))*1.), np.sin((data["lattice_vector_1_ang"])) )) * 2.0)) +
            0.025000*np.tanh(((((np.tanh((0.616162))) - (np.maximum(((data["SG_167"])), ((np.where(((data["a1"]) - (np.tanh((data["SG_33"]))))>0, data["SG_206"], data["SG_33"] ))))))) - (data["SG_12"]))) +
            0.025000*np.tanh(np.cos((((((((-1.0*((data["lattice_vector_1_ang"])))) + (np.tanh((((((((((data["SG_12"]) * ((-1.0*(((11.83683109283447266))))))) + (0.676056))/2.0)) + (data["lattice_angle_gamma_degree"]))/2.0)))))/2.0)) * (((((-1.0*((data["lattice_vector_1_ang"])))) + (np.tanh((((((((((data["SG_12"]) * ((-1.0*(((11.83683109283447266))))))) + (0.676056))/2.0)) + (data["lattice_angle_gamma_degree"]))/2.0)))))/2.0)))))) +
            0.024228*np.tanh(((0.400000) + (np.where(data["SG_206"]>0, np.where(data["percent_atom_ga"]>0, (-1.0*(((((data["percent_atom_ga"]) < (0.318310))*1.)))), (-1.0*((31.006277))) ), (-1.0*((data["percent_atom_ga"]))) )))) +
            0.025000*np.tanh((-1.0*((((np.cos((np.where(data["percent_atom_in"]>0, 1.589740, np.where(((data["SG_194"]) + (data["SG_12"]))>0, data["SG_194"], ((-3.0) / 2.0) ) )))) * 2.0))))) +
            0.025000*np.tanh(np.minimum(((np.where(data["percent_atom_al"]>0, (((data["a0"]) < (0.676056))*1.), np.sin((data["number_of_total_atoms"])) ))), (((((((np.sin((data["percent_atom_al"]))) < (0.676056))*1.)) - (data["percent_atom_al"])))))) +
            0.024302*np.tanh((((((np.tanh((data["SG_206"]))) / 2.0)) + (np.sin(((-1.0*(((((((((np.cos((data["lattice_angle_alpha_degree"]))) > (data["SG_227"]))*1.)) + (data["SG_33"]))) + (data["SG_33"])))))))))/2.0)) +
            0.025000*np.tanh(np.minimum(((np.minimum(((np.cos((((data["percent_atom_al"]) * 2.0))))), ((data["SG_167"]))))), ((np.where(data["percent_atom_al"]>0, data["percent_atom_al"], (-1.0*((((((((data["SG_194"]) * 2.0)) * 2.0)) * (((((data["SG_194"]) * 2.0)) * 2.0)))))) ))))) +
            0.025000*np.tanh(((((((np.sin((data["lattice_vector_2_ang"]))) * (np.sin((data["lattice_vector_2_ang"]))))) * (((np.sin((data["lattice_vector_2_ang"]))) * (np.sin((data["lattice_vector_2_ang"]))))))) * (np.where(data["percent_atom_ga"]>0, data["percent_atom_ga"], (-1.0*((((((((((data["lattice_vector_2_ang"]) / 2.0)) / 2.0)) * (((((data["lattice_vector_2_ang"]) / 2.0)) / 2.0)))) * (((((((data["lattice_vector_2_ang"]) / 2.0)) / 2.0)) * (((((data["lattice_vector_2_ang"]) / 2.0)) / 2.0)))))))) )))) +
            0.025000*np.tanh(((((np.maximum((((((data["percent_atom_in"]) > (np.cos((np.sin((data["a1"]))))))*1.))), (((((data["number_of_total_atoms"]) < (np.where(data["percent_atom_in"]>0, 3.0, data["a1"] )))*1.))))) * 2.0)) * 2.0)) +
            0.024995*np.tanh(((np.where(data["a1"]>0, data["percent_atom_al"], ((np.cos((data["lattice_angle_alpha_degree"]))) * (((1.589740) * 2.0))) )) * (((data["lattice_angle_alpha_degree"]) * (data["SG_227"]))))) +
            0.025000*np.tanh(((np.where(data["percent_atom_al"]>0, (((data["lattice_angle_gamma_degree"]) < (data["percent_atom_al"]))*1.), np.where(data["SG_167"]>0, 1.076920, ((((data["SG_206"]) * 2.0)) - (data["lattice_angle_gamma_degree"])) ) )) / 2.0)) +
            0.025000*np.tanh((((((((((((((((3.141593) + (data["percent_atom_ga"]))) > (data["lattice_vector_1_ang"]))*1.)) * 2.0)) * 2.0)) * 2.0)) * 2.0)) * ((((((((((((((3.141593) + (data["percent_atom_ga"]))) > (data["lattice_vector_1_ang"]))*1.)) * 2.0)) * 2.0)) * 2.0)) * 2.0)))) +
            0.025000*np.tanh(((((((((((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))) * (((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))))) * (((((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))) * (((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))))))) * (((((((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))) * (((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))))) * (((((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))) * (((((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)) * (((((((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * (((np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((data["a1"]) * 2.0)) * (((data["a1"]) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))))) * 2.0)))))))))) * 2.0)) +
            0.025000*np.tanh((-1.0*((((((np.minimum(((((data["percent_atom_ga"]) - (data["SG_167"])))), (((((np.sin((data["lattice_vector_2_ang"]))) > (data["SG_33"]))*1.))))) * (np.cos((np.sin((data["lattice_vector_1_ang"]))))))) * (((np.minimum(((((data["percent_atom_ga"]) - (data["SG_167"])))), (((((np.sin((data["lattice_vector_2_ang"]))) > (data["SG_33"]))*1.))))) * (np.cos((np.sin((data["lattice_vector_1_ang"])))))))))))) +
            0.025000*np.tanh(np.where(data["percent_atom_ga"]>0, ((1.184620) - (((((((data["SG_227"]) + (1.184620))/2.0)) + (data["lattice_angle_alpha_degree"]))/2.0))), ((((((data["SG_227"]) * 2.0)) * 2.0)) * (((((data["SG_227"]) * 2.0)) * 2.0))) )) +
            0.025000*np.tanh(((data["percent_atom_al"]) * (((data["percent_atom_al"]) * (((data["percent_atom_al"]) * ((((data["SG_194"]) + (((data["percent_atom_al"]) * (np.sin((((((data["percent_atom_al"]) * 2.0)) * 2.0)))))))/2.0)))))))) +
            0.025000*np.tanh((-1.0*((((np.maximum(((((np.sin((((((data["lattice_vector_3_ang"]) / 2.0)) * (((data["lattice_vector_3_ang"]) / 2.0)))))) / 2.0))), (((-1.0*((((((data["a1"]) * (data["a1"]))) * (((data["a1"]) * (data["a1"]))))))))))) * (np.maximum(((((np.sin((((((data["lattice_vector_3_ang"]) / 2.0)) * (((data["lattice_vector_3_ang"]) / 2.0)))))) / 2.0))), (((-1.0*((((((data["a1"]) * (data["a1"]))) * (((data["a1"]) * (data["a1"])))))))))))))))) +
            0.025000*np.tanh((((((((((((-2.0) + (((data["lattice_angle_alpha_degree"]) + (data["lattice_angle_gamma_degree"]))))/2.0)) < (data["a0"]))*1.)) + (((-2.0) + (data["lattice_angle_gamma_degree"]))))/2.0)) * ((((((((((-2.0) + (((data["lattice_angle_alpha_degree"]) + (data["lattice_angle_gamma_degree"]))))/2.0)) < (data["a0"]))*1.)) + (((-2.0) + (data["lattice_angle_gamma_degree"]))))/2.0)))) +
            0.015828*np.tanh(((((data["a2"]) * (((1.589740) * (((data["a2"]) * (np.cos((np.maximum(((1.589740)), ((((data["a0"]) * 2.0))))))))))))) * (((data["a2"]) * 2.0)))) +
            0.025000*np.tanh(((np.where(data["percent_atom_al"]>0, ((np.sin((((np.where(data["percent_atom_in"]>0, 9.869604, ((data["percent_atom_al"]) + (1.157890)) )) * (np.where(data["percent_atom_in"]>0, 9.869604, ((data["percent_atom_al"]) + (1.157890)) )))))) * 2.0), data["percent_atom_in"] )) * (data["SG_227"]))) +
            0.020312*np.tanh((((-1.0*((data["percent_atom_in"])))) * ((((((data["percent_atom_ga"]) > (0.161290))*1.)) + ((((((0.500000) < (data["percent_atom_in"]))*1.)) - ((((0.907216) > (data["percent_atom_in"]))*1.)))))))) +
            0.024370*np.tanh(np.minimum(((((data["percent_atom_in"]) - (((((((((data["lattice_angle_beta_degree"]) / 2.0)) / 2.0)) / 2.0)) / 2.0))))), ((np.minimum((((((0.676056) > (data["percent_atom_in"]))*1.))), ((((data["SG_206"]) / 2.0)))))))) +
            0.021347*np.tanh(np.minimum(((((((((((((((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))) * (((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))))) * 2.0)) * (((((((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))) * (((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))))) * 2.0)))) * 2.0)) * (((((((((((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))) * (((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))))) * 2.0)) * (((((((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))) * (((((np.cos((data["lattice_vector_3_ang"]))) * 2.0)) * (np.cos((((data["lattice_vector_3_ang"]) * 2.0)))))))) * 2.0)))) * 2.0))))), ((data["SG_167"])))) +
            0.025000*np.tanh(((((((((((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))) * (((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))))) * (((((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))) * (((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))))))) * (((((((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))) * (((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))))) * (((((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))) * (((data["number_of_total_atoms"]) * (data["percent_atom_ga"]))))))))) * ((((data["number_of_total_atoms"]) < ((((3.0)) * (np.cos((((data["lattice_vector_2_ang"]) * 2.0)))))))*1.)))) +
            0.020087*np.tanh(((((0.400000) - (data["percent_atom_ga"]))) * (((np.where(0.400000>0, np.where(data["percent_atom_ga"]>0, 1.245280, data["SG_227"] ), 1.076920 )) - (1.184620))))) +
            0.025000*np.tanh(((((((np.where(data["SG_12"]>0, np.tanh((data["SG_12"])), ((np.cos((data["SG_33"]))) + (0.318310)) )) < (data["percent_atom_in"]))*1.)) > (data["percent_atom_in"]))*1.)) +
            0.025000*np.tanh(np.minimum(((((data["a1"]) + (0.285714)))), ((np.where(data["percent_atom_al"]>0, 0.0, ((np.sin((data["number_of_total_atoms"]))) + ((((np.sin((data["lattice_vector_1_ang"]))) < (0.285714))*1.))) ))))) +
            0.021884*np.tanh(np.minimum(((((0.636620) - (data["percent_atom_ga"])))), ((np.tanh(((((((((data["percent_atom_ga"]) * (0.616162))) > (np.minimum(((data["percent_atom_in"])), ((0.285714)))))*1.)) - (data["percent_atom_ga"])))))))) +
            0.025000*np.tanh(np.minimum(((((data["percent_atom_in"]) - (((0.285714) * (0.285714)))))), ((((((((np.minimum(((data["percent_atom_al"])), ((data["percent_atom_in"])))) * (31.006277))) - (0.285714))) * (data["SG_194"])))))) +
            0.025000*np.tanh(((np.minimum(((np.where(np.minimum(((data["percent_atom_ga"])), ((data["SG_206"])))>0, ((data["percent_atom_ga"]) - (data["percent_atom_al"])), 0.161290 ))), (((((data["SG_206"]) + ((-1.0*((data["percent_atom_ga"])))))/2.0))))) * (np.minimum(((np.where(np.minimum(((data["percent_atom_ga"])), ((data["SG_206"])))>0, ((data["percent_atom_ga"]) - (data["percent_atom_al"])), 0.161290 ))), (((((data["SG_206"]) + ((-1.0*((data["percent_atom_ga"])))))/2.0))))))) +
            0.020439*np.tanh(((-3.0) * (((((((data["lattice_angle_gamma_degree"]) * (((((np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )) * (np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )))) * (((np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )) * (np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )))))))) * (((data["lattice_angle_gamma_degree"]) * (((((np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )) * (np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )))) * (((np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )) * (np.where(data["percent_atom_ga"]>0, ((data["a2"]) * (data["percent_atom_ga"])), data["a1"] )))))))))) * 2.0)))) +
            0.025000*np.tanh(np.where(data["a2"]>0, ((((data["percent_atom_in"]) * ((((data["SG_167"]) < ((((data["a2"]) < (((((data["percent_atom_in"]) / 2.0)) * (((data["percent_atom_in"]) / 2.0)))))*1.)))*1.)))) * (((data["percent_atom_in"]) * ((((data["SG_167"]) < ((((data["a2"]) < (((((data["percent_atom_in"]) / 2.0)) * (((data["percent_atom_in"]) / 2.0)))))*1.)))*1.))))), ((0.400000) / 2.0) )) +
            0.019144*np.tanh(((((np.sin((((((0.946667) + (data["lattice_vector_2_ang"]))) * (((0.946667) + (data["lattice_vector_2_ang"]))))))) * ((((data["percent_atom_in"]) > (np.maximum(((0.946667)), ((data["SG_33"])))))*1.)))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))) +
            0.018304*np.tanh((((((((data["percent_atom_al"]) < (0.616162))*1.)) - ((((np.tanh((np.where((((data["percent_atom_al"]) < (0.905263))*1.)>0, 0.905263, (13.83974742889404297) )))) > (data["percent_atom_al"]))*1.)))) / 2.0)) +
            0.025000*np.tanh((((((data["SG_206"]) < ((((data["percent_atom_ga"]) < (((np.tanh((np.tanh((data["percent_atom_in"]))))) * (np.tanh((np.tanh((data["percent_atom_in"]))))))))*1.)))*1.)) * (np.minimum((((((data["percent_atom_in"]) < (0.536842))*1.))), ((data["percent_atom_in"])))))) +
            0.025000*np.tanh(((((((((((data["SG_206"]) + (0.285714))/2.0)) + (data["SG_227"]))/2.0)) * (np.tanh((np.tanh((np.sin((((((1.245280) * (data["lattice_vector_1_ang"]))) * (((1.245280) * (data["lattice_vector_1_ang"]))))))))))))) / 2.0)) +
            0.025000*np.tanh(((np.minimum((((((data["percent_atom_ga"]) > (np.sin((np.cos((data["SG_167"]))))))*1.))), ((((np.cos((data["SG_206"]))) - (np.sin((np.cos((data["percent_atom_ga"])))))))))) * (np.minimum((((((data["percent_atom_ga"]) > (np.sin((np.cos((data["SG_167"]))))))*1.))), ((((np.cos((data["SG_206"]))) - (np.sin((np.cos((data["percent_atom_ga"])))))))))))) +
            0.025000*np.tanh((-1.0*(((((((data["percent_atom_ga"]) + ((-1.0*(((((data["SG_167"]) + ((((data["percent_atom_al"]) < ((((data["a2"]) + ((((data["SG_167"]) + (0.285714))/2.0)))/2.0)))*1.)))/2.0))))))/2.0)) * ((((data["percent_atom_ga"]) + ((-1.0*(((((data["SG_167"]) + ((((data["percent_atom_al"]) < ((((data["a2"]) + ((((data["SG_167"]) + (0.285714))/2.0)))/2.0)))*1.)))/2.0))))))/2.0))))))) +
            0.025000*np.tanh(((((((((data["percent_atom_ga"]) > (np.sin((data["a2"]))))*1.)) > (data["lattice_angle_gamma_degree"]))*1.)) * (((data["a2"]) - ((((((data["percent_atom_ga"]) > (data["lattice_angle_gamma_degree"]))*1.)) - (data["a2"]))))))) +
            0.023178*np.tanh((((np.minimum(((0.161290)), ((data["percent_atom_in"])))) > (((((data["lattice_angle_gamma_degree"]) - (((np.tanh((data["percent_atom_al"]))) * (np.tanh((data["percent_atom_al"]))))))) - (((np.tanh((((data["percent_atom_in"]) * (data["percent_atom_in"]))))) * (np.tanh((((data["percent_atom_in"]) * (data["percent_atom_in"]))))))))))*1.)) +
            0.025000*np.tanh(((((((((((data["a0"]) * (np.minimum(((np.cos((data["lattice_angle_alpha_degree"])))), ((((np.cos((data["lattice_angle_alpha_degree"]))) * 2.0))))))) - (np.cos((data["lattice_angle_alpha_degree"]))))) * 2.0)) * 2.0)) * 2.0)) +
            0.025000*np.tanh(np.minimum(((0.161290)), ((np.minimum(((data["SG_227"])), ((((((((data["a0"]) * 2.0)) * 2.0)) * (((((data["a2"]) * (data["a0"]))) - (((0.161290) / 2.0)))))))))))) +
            0.022602*np.tanh(((np.tanh((((((((((data["SG_12"]) * (data["lattice_vector_2_ang"]))) * (np.cos((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))))) + (data["lattice_vector_2_ang"]))) * (((((((data["SG_12"]) * (data["lattice_vector_2_ang"]))) * (np.cos((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))))) + (data["lattice_vector_2_ang"]))))))) - (np.tanh((2.255810))))) +
            0.017147*np.tanh(((((data["a2"]) * 2.0)) * (((((data["a2"]) * 2.0)) * (np.minimum(((np.cos((data["lattice_angle_beta_degree"])))), (((-1.0*((np.cos((data["lattice_angle_beta_degree"]))))))))))))) +
            0.025000*np.tanh(np.minimum((((((np.cos((((((((data["lattice_vector_1_ang"]) / 2.0)) * (((data["lattice_vector_1_ang"]) / 2.0)))) / 2.0)))) < (np.cos((np.sin((data["lattice_vector_1_ang"]))))))*1.))), (((-1.0*((np.cos((data["lattice_angle_beta_degree"]))))))))) +
            0.025000*np.tanh((((((np.cos((((data["percent_atom_al"]) * (data["percent_atom_al"]))))) < (data["a2"]))*1.)) * (((data["lattice_angle_alpha_degree"]) * (((np.cos(((((data["lattice_angle_beta_degree"]) < (data["lattice_angle_alpha_degree"]))*1.)))) - (data["percent_atom_al"]))))))) +
            0.025000*np.tanh(((np.cos((np.where(np.cos((np.where(np.cos((data["lattice_angle_beta_degree"]))>0, data["lattice_angle_alpha_degree"], ((data["lattice_angle_beta_degree"]) + (3.0)) )))>0, 1.589740, data["lattice_angle_alpha_degree"] )))) * (3.141593))) +
            0.023247*np.tanh((((((((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))) * ((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))))) * ((((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))) * ((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))))))) * ((((((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))) * ((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))))) * ((((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))) * ((((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)) * ((((((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))) * ((((10.0)) * ((((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))) * ((((10.0)) * (((np.cos((data["lattice_angle_alpha_degree"]))) * (np.cos((data["lattice_angle_alpha_degree"]))))))))))))) * 2.0)))))))))) +
            0.020917*np.tanh(np.where(np.sin((((data["lattice_vector_1_ang"]) - (np.cos((((1.589740) - (np.cos((((1.589740) - (np.cos((data["lattice_vector_1_ang"]))))))))))))))>0, data["lattice_angle_gamma_degree"], 0.0 )) +
            0.025000*np.tanh((((-3.0) < (-3.0))*1.)) +
            0.025000*np.tanh((((((data["lattice_angle_alpha_degree"]) + (data["percent_atom_ga"]))/2.0)) * (np.minimum(((data["SG_194"])), (((((data["percent_atom_ga"]) > ((((1.570796) + ((((1.570796) < (data["lattice_angle_alpha_degree"]))*1.)))/2.0)))*1.))))))) +
            0.025000*np.tanh(((np.cos((data["lattice_angle_alpha_degree"]))) * (((((((((((((((data["a0"]) * (data["a0"]))) < (((((data["percent_atom_in"]) * 2.0)) * 2.0)))*1.)) < (data["percent_atom_in"]))*1.)) * 2.0)) * 2.0)) * (((((((((((((data["a0"]) * (data["a0"]))) < (((((data["percent_atom_in"]) * 2.0)) * 2.0)))*1.)) < (data["percent_atom_in"]))*1.)) * 2.0)) * 2.0)))))) +
            0.023740*np.tanh(((((np.tanh(((((data["lattice_angle_gamma_degree"]) < (np.tanh((np.minimum(((np.sin((0.676056)))), ((data["a2"])))))))*1.)))) * (data["lattice_angle_gamma_degree"]))) * (data["lattice_angle_gamma_degree"]))) +
            0.025000*np.tanh(np.where(np.cos((data["lattice_angle_alpha_degree"]))>0, ((data["SG_194"]) * (((0.400000) - (0.716667)))), (((3.0) < (3.0))*1.) )) +
            0.025000*np.tanh(((data["a2"]) * (((data["a2"]) * (np.cos((np.where(np.cos((data["lattice_angle_alpha_degree"]))>0, np.where(np.cos((data["lattice_angle_beta_degree"]))>0, data["lattice_vector_3_ang"], data["lattice_angle_beta_degree"] ), data["lattice_angle_alpha_degree"] )))))))) +
            0.023081*np.tanh(((0.285714) * (((data["percent_atom_al"]) * (np.minimum(((np.cos((((data["lattice_vector_1_ang"]) * (data["lattice_vector_1_ang"])))))), (((((np.cos((data["lattice_vector_3_ang"]))) < (0.318310))*1.))))))))) +
            0.024956*np.tanh(np.minimum(((((((data["a1"]) + (np.minimum(((((data["percent_atom_ga"]) + ((-1.0*((((0.716667) - (data["lattice_angle_gamma_degree"]))))))))), ((0.0)))))) + (0.0)))), ((0.0)))) +
            0.025000*np.tanh(((((((np.maximum((((((((np.cos((data["lattice_angle_beta_degree"]))) * (3.0))) > (0.400000))*1.))), ((np.cos((data["lattice_angle_beta_degree"])))))) * 2.0)) * (((np.maximum((((((((np.cos((data["lattice_angle_beta_degree"]))) * (3.0))) > (0.400000))*1.))), ((np.cos((data["lattice_angle_beta_degree"])))))) * 2.0)))) * (((((np.maximum((((((((np.cos((data["lattice_angle_beta_degree"]))) * (3.0))) > (0.400000))*1.))), ((np.cos((data["lattice_angle_beta_degree"])))))) * 2.0)) * (((np.maximum((((((((np.cos((data["lattice_angle_beta_degree"]))) * (3.0))) > (0.400000))*1.))), ((np.cos((data["lattice_angle_beta_degree"])))))) * 2.0)))))) +
            0.025000*np.tanh(((data["lattice_vector_1_ang"]) * (((data["SG_12"]) * (((data["lattice_vector_1_ang"]) * (np.minimum(((data["percent_atom_al"])), (((((data["percent_atom_al"]) < (np.cos((1.473680))))*1.))))))))))) +
            0.018431*np.tanh((((((1.589740) > (((((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))) + (((data["lattice_angle_gamma_degree"]) + (((0.400000) + (0.400000))))))))*1.)) * (1.473680))) +
            0.025000*np.tanh(((((((np.tanh((np.tanh((np.tanh((((data["SG_33"]) / 2.0)))))))) + (((data["percent_atom_al"]) * 2.0)))) * (((np.tanh((np.tanh((np.tanh((((data["SG_33"]) / 2.0)))))))) + (((data["percent_atom_al"]) * 2.0)))))) * ((((((data["percent_atom_al"]) / 2.0)) < ((0.05319358035922050)))*1.)))) +
            0.025000*np.tanh(((((data["lattice_angle_gamma_degree"]) * (np.cos((1.589740))))) * (((np.cos((((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))) * (1.245280))))) * 2.0)))) +
            0.024990*np.tanh(np.sin((((np.cos((1.589740))) / 2.0)))) +
            0.017479*np.tanh(((np.cos((data["lattice_angle_alpha_degree"]))) * (np.minimum(((data["lattice_angle_alpha_degree"])), ((((((((np.cos((((9.869604) * (data["percent_atom_al"]))))) * 2.0)) * 2.0)) * 2.0))))))) +
            0.025000*np.tanh((((((((data["percent_atom_ga"]) + (0.716667))) < ((((data["a0"]) < (((data["percent_atom_ga"]) * 2.0)))*1.)))*1.)) * (((data["percent_atom_ga"]) - (((data["percent_atom_ga"]) * 2.0)))))) +
            0.025000*np.tanh(((np.where(data["percent_atom_ga"]>0, np.where(data["percent_atom_in"]>0, np.minimum(((data["percent_atom_al"])), ((data["percent_atom_in"]))), (((((data["percent_atom_ga"]) < (((0.536842) / 2.0)))*1.)) / 2.0) ), data["percent_atom_ga"] )) * (np.where(data["percent_atom_ga"]>0, np.where(data["percent_atom_in"]>0, np.minimum(((data["percent_atom_al"])), ((data["percent_atom_in"]))), (((((data["percent_atom_ga"]) < (((0.536842) / 2.0)))*1.)) / 2.0) ), data["percent_atom_ga"] )))) +
            0.025000*np.tanh((((((1.570796) < (((data["percent_atom_in"]) * 2.0)))*1.)) * (((((np.minimum(((((((((((data["percent_atom_al"]) * 2.0)) * 2.0)) * (((((data["percent_atom_al"]) * 2.0)) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))) * (np.minimum(((((((((((data["percent_atom_al"]) * 2.0)) * 2.0)) * (((((data["percent_atom_al"]) * 2.0)) * 2.0)))) * 2.0))), ((data["percent_atom_in"])))))) * 2.0)))) +
            0.020150*np.tanh(((((((1.245280) - (((data["SG_167"]) - (data["SG_206"]))))) - (((data["SG_167"]) - (data["SG_206"]))))) * (((1.245280) - (1.267610))))) +
            0.023081*np.tanh(((((np.minimum(((((np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.))))) * (np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.)))))))), ((data["a1"])))) * (np.minimum(((((np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.))))) * (np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.)))))))), ((data["a1"])))))) * (((np.minimum(((((np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.))))) * (np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.)))))))), ((data["a1"])))) * (np.minimum(((((np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.))))) * (np.minimum(((((data["percent_atom_al"]) * 2.0))), (((((data["a2"]) > ((((((2.255810) + (data["percent_atom_al"]))/2.0)) / 2.0)))*1.)))))))), ((data["a1"])))))))) +
            0.025000*np.tanh((((((data["a1"]) > (np.sin((data["percent_atom_al"]))))*1.)) * (((((-1.0*((np.sin((((((np.tanh((data["percent_atom_al"]))) * 2.0)) + (data["a1"])))))))) + (data["a1"]))/2.0)))) +
            0.022446*np.tanh(((((((np.tanh((1.157890))) - ((((np.sin(((((data["percent_atom_in"]) > (0.318310))*1.)))) > (data["percent_atom_in"]))*1.)))) * (((data["SG_194"]) * 2.0)))) * (data["percent_atom_in"]))) +
            0.025000*np.tanh(((0.0) * (-3.0))) +
            0.024907*np.tanh(np.minimum(((np.minimum((((((0.161290) > (((((data["percent_atom_in"]) * (np.cos((data["percent_atom_in"]))))) * (((data["percent_atom_al"]) * 2.0)))))*1.))), ((((data["percent_atom_in"]) * 2.0)))))), ((data["percent_atom_al"])))) +
            0.021542*np.tanh(((np.where(data["percent_atom_al"]>0, np.where(data["percent_atom_in"]>0, np.where(data["SG_194"]>0, data["SG_206"], data["percent_atom_ga"] ), data["SG_194"] ), data["SG_194"] )) * ((-1.0*((((data["percent_atom_ga"]) / 2.0))))))) +
            0.017469*np.tanh(np.minimum(((((((((((data["percent_atom_ga"]) > (0.285714))*1.)) + (np.cos((1.589740))))/2.0)) + (np.cos(((10.94861888885498047))))))), (((((data["percent_atom_ga"]) > (np.tanh((2.0))))*1.))))) +
            0.022338*np.tanh(((((((((((((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))) * (((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))))) * (((((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))) * (((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))))))) * 2.0)) * (((((((((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))) * (((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))))) * (((((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))) * (((2.255810) * (np.minimum(((data["percent_atom_ga"])), ((((((((data["percent_atom_in"]) > (0.616162))*1.)) > (0.616162))*1.))))))))))) * 2.0)))) * 2.0)) +
            0.023545*np.tanh(((np.sin((((((2.255810) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))) * (((2.255810) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))))) * (((((np.sin((data["lattice_vector_2_ang"]))) / 2.0)) * (((np.sin((data["lattice_vector_2_ang"]))) / 2.0)))))) +
            0.025000*np.tanh(((((np.minimum(((0.161290)), ((data["SG_167"])))) * (np.minimum(((0.161290)), ((data["SG_167"])))))) + ((((data["lattice_angle_alpha_degree"]) > ((((3.0) + (data["lattice_angle_gamma_degree"]))/2.0)))*1.)))) +
            0.025000*np.tanh(((2.0) * (0.0))) +
            0.025000*np.tanh(((((data["percent_atom_al"]) + (data["percent_atom_al"]))) * (((np.cos((data["lattice_vector_3_ang"]))) * ((((((((data["percent_atom_al"]) - (data["SG_167"]))) * (((data["percent_atom_al"]) - (data["SG_167"]))))) > (data["percent_atom_al"]))*1.)))))) +
            0.000000*np.tanh((((0.0) > (np.minimum(((((0.0) + (((((((data["lattice_vector_1_ang"]) / 2.0)) * (((data["lattice_vector_1_ang"]) / 2.0)))) - (3.0)))))), ((0.0)))))*1.)) +
            0.025000*np.tanh(((((np.minimum(((((((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"]))))) * (((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"])))))))), ((((((np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))) * (np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))))) * 2.0))))) * (np.minimum(((((((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"]))))) * (((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"])))))))), ((((((np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))) * (np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))))) * 2.0))))))) * (((np.minimum(((((((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"]))))) * (((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"])))))))), ((((((np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))) * (np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))))) * 2.0))))) * (np.minimum(((((((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"]))))) * (((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"])))))))), ((((((np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))) * (np.sin((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))))) * 2.0))))))))) +
            0.016912*np.tanh(((((((((data["SG_227"]) * (np.sin((((1.589740) * 2.0)))))) * (1.589740))) * 2.0)) * (((data["SG_227"]) * (np.sin((1.184620))))))) +
            0.025000*np.tanh(((np.minimum((((((((data["percent_atom_in"]) > (0.318310))*1.)) - (((data["percent_atom_in"]) - (data["percent_atom_ga"])))))), ((np.minimum((((((data["percent_atom_in"]) > (data["a1"]))*1.))), ((data["a1"]))))))) * (np.minimum((((((((data["percent_atom_in"]) > (0.318310))*1.)) - (((data["percent_atom_in"]) - (data["percent_atom_ga"])))))), ((np.minimum((((((data["percent_atom_in"]) > (data["a1"]))*1.))), ((data["a1"]))))))))) +
            0.025000*np.tanh((((((((data["lattice_angle_alpha_degree"]) > (((1.589740) + (((data["a2"]) / 2.0)))))*1.)) * ((((0.161290) + (np.sin((((data["lattice_vector_1_ang"]) * 2.0)))))/2.0)))) * (data["lattice_vector_3_ang"]))) +
            0.020209*np.tanh(((np.cos((np.maximum(((np.minimum(((data["lattice_angle_alpha_degree"])), ((1.589740))))), ((((data["a2"]) * (data["lattice_angle_beta_degree"])))))))) * (((data["lattice_angle_beta_degree"]) * (((data["lattice_angle_beta_degree"]) + (data["a2"]))))))) +
            0.025000*np.tanh((((((-1.0*((1.589740)))) + (1.589740))) + (((np.cos((data["lattice_angle_alpha_degree"]))) * (((data["percent_atom_in"]) + (((data["percent_atom_in"]) + ((-1.0*((1.589740)))))))))))) +
            0.025000*np.tanh(((np.cos((1.589740))) * ((((((4.83601665496826172)) * ((((1.589740) < (data["lattice_angle_alpha_degree"]))*1.)))) + (data["SG_167"]))))) +
            0.025000*np.tanh((((((((np.sin((0.716667))) > (np.cos((np.cos((data["lattice_vector_1_ang"]))))))*1.)) * (1.589740))) * (np.cos((1.589740))))) +
            0.016815*np.tanh((((((0.676056) < (((data["a0"]) * (data["a0"]))))*1.)) * (((((((data["lattice_angle_gamma_degree"]) - (np.cos((data["lattice_vector_3_ang"]))))) - (0.676056))) * (((0.676056) * (0.676056))))))) +
            0.025000*np.tanh(np.minimum(((0.0)), ((0.0)))) +
            0.025000*np.tanh((((0.0)) * (0.0))) +
            0.025000*np.tanh(np.minimum(((data["percent_atom_al"])), ((((((np.minimum((((((0.161290) > (data["percent_atom_al"]))*1.))), ((((data["percent_atom_al"]) - ((0.00272870133630931))))))) * (data["number_of_total_atoms"]))) * (data["number_of_total_atoms"])))))) +
            0.022128*np.tanh((-1.0*((((((((((((data["percent_atom_in"]) * (((0.285714) * (0.285714))))) > (((data["percent_atom_in"]) * (data["percent_atom_in"]))))*1.)) + (((((((data["percent_atom_in"]) * (data["percent_atom_in"]))) * (((data["percent_atom_in"]) * (data["percent_atom_in"]))))) * (((((data["percent_atom_in"]) * (data["percent_atom_in"]))) * (((data["percent_atom_in"]) * (data["percent_atom_in"]))))))))/2.0)) * (((((((((data["percent_atom_in"]) * (((0.285714) * (0.285714))))) > (((data["percent_atom_in"]) * (data["percent_atom_in"]))))*1.)) + (((((((data["percent_atom_in"]) * (data["percent_atom_in"]))) * (((data["percent_atom_in"]) * (data["percent_atom_in"]))))) * (((((data["percent_atom_in"]) * (data["percent_atom_in"]))) * (((data["percent_atom_in"]) * (data["percent_atom_in"]))))))))/2.0))))))) +
            0.025000*np.tanh(((((data["percent_atom_in"]) * (np.sin((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))))) * (np.minimum(((data["percent_atom_al"])), ((((((np.sin((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))) * (np.sin((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))))) * (((np.sin((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))) * (np.sin((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"])))))))))))))) +
            0.025000*np.tanh(((((((((((((data["percent_atom_al"]) * (data["percent_atom_al"]))) * (((data["percent_atom_al"]) * (data["percent_atom_al"]))))) * 2.0)) * (((((((data["percent_atom_al"]) * (data["percent_atom_al"]))) * (((data["percent_atom_al"]) * (data["percent_atom_al"]))))) * 2.0)))) * (((((((((data["percent_atom_al"]) * (data["percent_atom_al"]))) * (((data["percent_atom_al"]) * (data["percent_atom_al"]))))) * 2.0)) * (((((((data["percent_atom_al"]) * (data["percent_atom_al"]))) * (((data["percent_atom_al"]) * (data["percent_atom_al"]))))) * 2.0)))))) * ((((((data["percent_atom_al"]) * (data["percent_atom_al"]))) < (0.636620))*1.)))))


def GPBE(data):
    return (1.068357 +
            0.025000*np.tanh(np.where(((data["percent_atom_in"]) - (((((((0.500000) - (data["percent_atom_in"]))) * 2.0)) - (data["SG_227"]))))>0, (-1.0*(((12.79285621643066406)))), (12.79285621643066406) )) +
            0.025000*np.tanh(((((((((data["percent_atom_al"]) - (np.tanh((data["percent_atom_in"]))))) * (31.006277))) - (((data["percent_atom_in"]) * (data["lattice_vector_3_ang"]))))) - (((data["SG_227"]) * (data["lattice_vector_3_ang"]))))) +
            0.025000*np.tanh(((9.869604) * (((data["SG_167"]) - (((data["SG_194"]) - (((np.tanh((((((((data["percent_atom_al"]) - (data["percent_atom_in"]))) * 2.0)) - (data["SG_227"]))))) * 2.0)))))))) +
            0.025000*np.tanh(((((((data["lattice_vector_3_ang"]) * ((((((((7.0)) * (((0.285714) - (data["percent_atom_in"]))))) - (data["SG_227"]))) - (data["SG_194"]))))) - (data["lattice_angle_gamma_degree"]))) * 2.0)) +
            0.025000*np.tanh(((data["lattice_vector_2_ang"]) - (((((((((data["percent_atom_in"]) * (((np.cos((data["lattice_vector_2_ang"]))) * (((3.141593) + (np.cos((data["lattice_vector_2_ang"]))))))))) * 2.0)) * (((((data["percent_atom_in"]) * (((np.cos((data["lattice_vector_2_ang"]))) * (((3.141593) + (np.cos((data["lattice_vector_2_ang"]))))))))) * 2.0)))) * (((((((data["percent_atom_in"]) * (((np.cos((data["lattice_vector_2_ang"]))) * (((3.141593) + (np.cos((data["lattice_vector_2_ang"]))))))))) * 2.0)) * (((((data["percent_atom_in"]) * (((np.cos((data["lattice_vector_2_ang"]))) * (((3.141593) + (np.cos((data["lattice_vector_2_ang"]))))))))) * 2.0)))))))) +
            0.025000*np.tanh((((11.48045444488525391)) * (((((((((((np.maximum(((data["percent_atom_al"])), ((data["SG_167"])))) * 2.0)) * (((np.maximum(((data["percent_atom_al"])), ((data["SG_167"])))) * 2.0)))) + (data["percent_atom_in"]))) * (data["percent_atom_al"]))) - (((data["percent_atom_in"]) * 2.0)))))) +
            0.025000*np.tanh(((31.006277) * (((((data["percent_atom_al"]) - (((data["SG_194"]) - ((((((data["percent_atom_al"]) + (((data["SG_194"]) / 2.0)))/2.0)) - (data["percent_atom_in"]))))))) - (data["SG_227"]))))) +
            0.025000*np.tanh(((((data["lattice_vector_3_ang"]) * (((data["percent_atom_al"]) - (np.tanh((np.tanh((np.maximum(((np.where(data["percent_atom_in"]>0, 0.400000, 0.161290 ))), ((data["SG_227"])))))))))))) * 2.0)) +
            0.025000*np.tanh((((11.16402530670166016)) * (((((((data["percent_atom_al"]) - (((data["percent_atom_in"]) - (np.where(data["percent_atom_in"]>0, (0.27556306123733521), 0.676056 )))))) - (data["SG_227"]))) - (data["SG_194"]))))) +
            0.025000*np.tanh(((((((((((((((((data["percent_atom_al"]) + (data["SG_167"]))) * (((data["percent_atom_al"]) + (data["SG_167"]))))) - (((np.tanh((data["percent_atom_in"]))) * 2.0)))) * 2.0)) - (data["SG_227"]))) * 2.0)) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((((data["percent_atom_al"]) + (((((((((((data["percent_atom_al"]) - (data["percent_atom_in"]))) + (data["SG_206"]))) - (((0.536842) - (data["SG_167"]))))) * 2.0)) * 2.0)))) * 2.0)) +
            0.025000*np.tanh(((((((data["percent_atom_al"]) - (data["percent_atom_in"]))) * (data["lattice_vector_3_ang"]))) - (((((np.sin((((((np.sin((data["lattice_vector_3_ang"]))) - (0.536842))) * 2.0)))) * 2.0)) * 2.0)))) +
            0.025000*np.tanh(((((((((((((((data["percent_atom_al"]) - (0.400000))) - (((((data["percent_atom_in"]) - (data["SG_167"]))) * 2.0)))) * 2.0)) - (data["SG_227"]))) * 2.0)) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((((((((np.where(data["percent_atom_al"]>0, ((data["SG_33"]) + (data["percent_atom_al"])), 0.905263 )) - (data["percent_atom_in"]))) - ((((data["percent_atom_in"]) > (0.676056))*1.)))) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((((((data["SG_194"]) + (((((((((((((data["percent_atom_al"]) - (data["SG_194"]))) - (data["SG_227"]))) * 2.0)) * 2.0)) - (data["a1"]))) * 2.0)))) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((((((((((data["SG_167"]) * 2.0)) - (((data["percent_atom_in"]) * (data["lattice_vector_3_ang"]))))) + (data["a2"]))) - (np.sin((((data["percent_atom_al"]) * ((5.0)))))))) * 2.0)) +
            0.025000*np.tanh(((((((((((((((((((data["percent_atom_al"]) > (0.400000))*1.)) + (data["percent_atom_in"]))) > (data["SG_227"]))*1.)) - (data["percent_atom_in"]))) * 2.0)) - (0.400000))) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((((((((data["SG_167"]) + (((((data["percent_atom_al"]) * 2.0)) - (np.where(data["percent_atom_in"]>0, data["lattice_angle_gamma_degree"], ((data["lattice_angle_gamma_degree"]) - (0.400000)) )))))) * 2.0)) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((np.where(data["SG_227"]>0, (-1.0*((np.where((((data["lattice_vector_2_ang"]) < ((6.0)))*1.)>0, data["a1"], data["lattice_vector_2_ang"] )))), np.where(data["percent_atom_in"]>0, data["percent_atom_ga"], data["lattice_vector_2_ang"] ) )) * 2.0)) +
            0.025000*np.tanh((((11.16508769989013672)) * ((((data["percent_atom_al"]) > (np.minimum(((0.905263)), (((((11.16508769989013672)) * (((np.cos((data["lattice_vector_2_ang"]))) * (np.cos((data["lattice_vector_2_ang"])))))))))))*1.)))) +
            0.025000*np.tanh((((((((((((np.tanh((data["percent_atom_al"]))) > (((np.cos((data["SG_227"]))) - (0.318310))))*1.)) - (np.tanh((data["SG_227"]))))) * 2.0)) * 2.0)) - (data["percent_atom_al"]))) +
            0.025000*np.tanh(((np.sin((((np.tanh((np.tanh((np.cos((data["lattice_vector_3_ang"]))))))) - (np.where(np.cos((((data["lattice_vector_3_ang"]) * 2.0)))>0, data["lattice_vector_2_ang"], ((data["lattice_vector_3_ang"]) * 2.0) )))))) * 2.0)) +
            0.025000*np.tanh(((np.sin(((((((((((0.636620) < (data["percent_atom_al"]))*1.)) - (data["SG_227"]))) - ((((((data["percent_atom_in"]) < (data["percent_atom_al"]))*1.)) - (data["percent_atom_al"]))))) * 2.0)))) * 2.0)) +
            0.025000*np.tanh(((((data["percent_atom_ga"]) - (((np.sin((((data["number_of_total_atoms"]) * (data["number_of_total_atoms"]))))) * ((((data["lattice_angle_gamma_degree"]) + (((((31.006277) * (data["a1"]))) * (data["SG_227"]))))/2.0)))))) * 2.0)) +
            0.025000*np.tanh(((((((data["percent_atom_al"]) * (data["percent_atom_al"]))) - (np.where(np.where(data["percent_atom_in"]>0, data["percent_atom_al"], data["a0"] )>0, (((0.616162) > (data["a0"]))*1.), data["percent_atom_in"] )))) + (data["SG_33"]))) +
            0.025000*np.tanh((((((((((((0.400000) < (data["percent_atom_in"]))*1.)) * 2.0)) * (np.where(data["SG_206"]>0, data["percent_atom_in"], (-1.0*(((((0.616162) < (data["percent_atom_in"]))*1.)))) )))) * 2.0)) * 2.0)) +
            0.025000*np.tanh((((((np.tanh((np.sin((data["percent_atom_al"]))))) > (((((np.minimum((((((data["lattice_angle_gamma_degree"]) > (data["a2"]))*1.))), ((data["a2"])))) * 2.0)) * 2.0)))*1.)) * ((14.29195022583007812)))) +
            0.025000*np.tanh((-1.0*(((((((0.161290) < (np.minimum(((data["a2"])), (((((np.minimum(((data["a0"])), ((data["a2"])))) < (np.tanh((data["SG_227"]))))*1.))))))*1.)) * (9.869604)))))) +
            0.025000*np.tanh(np.where(np.minimum((((((1.589740) < (data["lattice_angle_alpha_degree"]))*1.))), ((data["percent_atom_al"])))>0, (7.18376922607421875), ((((0.676056) - ((((data["a2"]) > (data["percent_atom_al"]))*1.)))) - (data["percent_atom_al"])) )) +
            0.025000*np.tanh(np.sin((np.where(data["SG_227"]>0, ((((5.0)) + (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))/2.0), np.where(data["a1"]>0, ((0.536842) * (0.536842)), (-1.0*((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))) ) )))) +
            0.024526*np.tanh(((np.where(data["SG_12"]>0, (-1.0*((np.cos((((((((data["lattice_vector_3_ang"]) * 2.0)) * 2.0)) * 2.0)))))), np.cos((((((data["lattice_vector_3_ang"]) * 2.0)) * 2.0))) )) * (-1.0))) +
            0.025000*np.tanh(((np.minimum(((data["percent_atom_al"])), ((np.sin((((((np.sin((data["percent_atom_in"]))) + (((data["percent_atom_in"]) + (np.sin((((data["lattice_vector_2_ang"]) + (data["percent_atom_in"]))))))))) * 2.0))))))) * 2.0)) +
            0.025000*np.tanh((-1.0*((((((((data["percent_atom_in"]) + ((((np.minimum((((((data["a0"]) + (data["percent_atom_in"]))/2.0))), ((np.minimum(((data["SG_227"])), ((data["percent_atom_in"]))))))) > (0.285714))*1.)))) * (((data["percent_atom_in"]) + ((((np.minimum((((((data["a0"]) + (data["percent_atom_in"]))/2.0))), ((np.minimum(((data["SG_227"])), ((data["percent_atom_in"]))))))) > (0.285714))*1.)))))) * (((((data["percent_atom_in"]) + ((((np.minimum((((((data["a0"]) + (data["percent_atom_in"]))/2.0))), ((np.minimum(((data["SG_227"])), ((data["percent_atom_in"]))))))) > (0.285714))*1.)))) * (((data["percent_atom_in"]) + ((((np.minimum((((((data["a0"]) + (data["percent_atom_in"]))/2.0))), ((np.minimum(((data["SG_227"])), ((data["percent_atom_in"]))))))) > (0.285714))*1.))))))))))) +
            0.025000*np.tanh(((data["percent_atom_al"]) * (((((data["lattice_vector_3_ang"]) * ((((0.907216) < (np.maximum(((data["percent_atom_al"])), (((((1.589740) < (data["lattice_angle_alpha_degree"]))*1.))))))*1.)))) - (np.sin((data["percent_atom_al"]))))))) +
            0.025000*np.tanh(np.where(data["percent_atom_al"]>0, (((np.cos((((((data["lattice_angle_gamma_degree"]) / 2.0)) * (((data["lattice_angle_gamma_degree"]) / 2.0)))))) < (((data["percent_atom_al"]) - (data["SG_194"]))))*1.), ((((data["lattice_vector_2_ang"]) * (data["SG_194"]))) / 2.0) )) +
            0.025000*np.tanh(((((((((((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)) * (((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)))) * 2.0)) * (((((((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)) * (((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)))) * 2.0)))) * (((((((((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)) * (((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)))) * 2.0)) * (((((((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)) * (((((np.minimum(((np.where(data["percent_atom_al"]>0, (((data["percent_atom_ga"]) > (0.676056))*1.), data["percent_atom_ga"] ))), ((data["SG_194"])))) * 2.0)) * 2.0)))) * 2.0)))))) +
            0.025000*np.tanh(((((((((((((0.636620) < (((data["lattice_angle_alpha_degree"]) - ((((0.318310) + (data["lattice_angle_beta_degree"]))/2.0)))))*1.)) > ((((0.318310) + (data["lattice_angle_beta_degree"]))/2.0)))*1.)) * 2.0)) * 2.0)) * 2.0)) +
            0.025000*np.tanh((((((-1.0*((np.cos((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"])))))))) * (data["SG_167"]))) - (((np.cos((((((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))) * (((data["lattice_vector_2_ang"]) * (data["lattice_vector_2_ang"]))))))) * (data["SG_227"]))))) +
            0.025000*np.tanh((((-1.0*(((((data["lattice_vector_3_ang"]) < ((6.0)))*1.))))) - (((((((0.285714) > (((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))))*1.)) > ((((0.285714) > (data["a0"]))*1.)))*1.)))) +
            0.025000*np.tanh((((((((((1.589740) < (((data["lattice_angle_alpha_degree"]) - (((data["lattice_angle_beta_degree"]) - (1.570796))))))*1.)) * 2.0)) + (((data["lattice_angle_beta_degree"]) - (1.589740))))) * 2.0)) +
            0.025000*np.tanh(((((((((((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))) * (((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))))) * (((((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))) * (((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))))))) * (((((((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))) * (((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))))) * (((((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))) * (((data["lattice_angle_gamma_degree"]) * (data["lattice_angle_gamma_degree"]))))))))) * (((((((((data["SG_227"]) / 2.0)) < (data["percent_atom_in"]))*1.)) < ((((data["percent_atom_ga"]) < (0.285714))*1.)))*1.)))) +
            0.025000*np.tanh((-1.0*(((((((data["percent_atom_al"]) > (0.636620))*1.)) * (((((((((data["SG_33"]) + (data["lattice_angle_beta_degree"]))/2.0)) > (data["percent_atom_al"]))*1.)) + ((((data["SG_12"]) > (data["percent_atom_al"]))*1.))))))))) +
            0.025000*np.tanh(((((((data["percent_atom_al"]) - (data["SG_227"]))) * (2.0))) * (np.where(data["percent_atom_in"]>0, (((((np.tanh((0.161290))) / 2.0)) > (data["percent_atom_al"]))*1.), 0.318310 )))) +
            0.024643*np.tanh(((((1.589740) * 2.0)) * ((((((((((np.maximum(((data["lattice_angle_beta_degree"])), (((((data["lattice_angle_alpha_degree"]) + (1.570796))/2.0))))) + (data["lattice_angle_beta_degree"]))/2.0)) + (1.589740))/2.0)) < (data["lattice_angle_alpha_degree"]))*1.)))) +
            0.025000*np.tanh(((31.006277) * ((((-1.0*((np.where(np.cos((data["lattice_angle_beta_degree"]))>0, (-1.0*((np.cos((data["lattice_angle_beta_degree"]))))), data["SG_227"] ))))) * ((((0.400000) > (data["a0"]))*1.)))))) +
            0.022001*np.tanh(np.minimum((((((np.tanh(((-1.0*((((np.sin((((data["lattice_vector_1_ang"]) * (data["lattice_vector_1_ang"]))))) * 2.0))))))) + (data["SG_33"]))/2.0))), ((((((np.sin((((data["lattice_angle_beta_degree"]) * (data["lattice_angle_beta_degree"]))))) * (np.sin((((data["lattice_angle_beta_degree"]) * (data["lattice_angle_beta_degree"]))))))) * (((np.sin((((data["lattice_angle_beta_degree"]) * (data["lattice_angle_beta_degree"]))))) * (np.sin((((data["lattice_angle_beta_degree"]) * (data["lattice_angle_beta_degree"])))))))))))) +
            0.025000*np.tanh(np.minimum(((data["SG_167"])), (((((((data["a0"]) > (0.500000))*1.)) - ((((((((((data["a0"]) > (0.318310))*1.)) > (data["SG_12"]))*1.)) > (data["a0"]))*1.))))))) +
            0.025000*np.tanh(np.where(((np.cos((data["lattice_vector_2_ang"]))) * ((((data["lattice_vector_2_ang"]) > (data["lattice_vector_1_ang"]))*1.)))>0, 31.006277, ((((((data["lattice_vector_1_ang"]) > (data["lattice_vector_2_ang"]))*1.)) < (data["SG_194"]))*1.) )) +
            0.024985*np.tanh((((((data["percent_atom_in"]) < ((((np.minimum(((data["SG_167"])), ((0.285714)))) > (((0.946667) - (data["percent_atom_in"]))))*1.)))*1.)) * ((11.15888977050781250)))) +
            0.023383*np.tanh(((data["lattice_angle_beta_degree"]) * ((-1.0*((((((((data["lattice_angle_beta_degree"]) > (data["lattice_angle_alpha_degree"]))*1.)) < (((((((data["lattice_angle_alpha_degree"]) > (data["lattice_angle_gamma_degree"]))*1.)) < ((((data["percent_atom_al"]) < (data["percent_atom_in"]))*1.)))*1.)))*1.))))))) +
            0.025000*np.tanh((((((data["percent_atom_in"]) > (((((np.cos((data["SG_194"]))) - (data["percent_atom_in"]))) - (data["percent_atom_in"]))))*1.)) * (((np.cos((data["a0"]))) - (data["percent_atom_in"]))))) +
            0.021777*np.tanh(np.tanh((np.tanh((np.cos((np.where(np.cos((data["lattice_angle_beta_degree"]))>0, np.where(data["SG_167"]>0, -2.0, 1.473680 ), np.where(data["a2"]>0, data["lattice_angle_beta_degree"], 3.0 ) )))))))) +
            0.025000*np.tanh(((((((((np.where(data["percent_atom_ga"]>0, data["percent_atom_ga"], 0.905263 )) > (np.where(data["a0"]>0, data["lattice_angle_gamma_degree"], 0.905263 )))*1.)) > (data["percent_atom_ga"]))*1.)) * (data["lattice_vector_3_ang"]))) +
            0.025000*np.tanh(np.where(data["percent_atom_al"]>0, ((((((np.minimum(((np.maximum(((data["percent_atom_in"])), ((((data["percent_atom_al"]) * (data["percent_atom_al"]))))))), ((data["SG_194"])))) * (np.minimum(((np.maximum(((data["percent_atom_in"])), ((((data["percent_atom_al"]) * (data["percent_atom_al"]))))))), ((data["SG_194"])))))) * (((np.minimum(((np.maximum(((data["percent_atom_in"])), ((((data["percent_atom_al"]) * (data["percent_atom_al"]))))))), ((data["SG_194"])))) * (np.minimum(((np.maximum(((data["percent_atom_in"])), ((((data["percent_atom_al"]) * (data["percent_atom_al"]))))))), ((data["SG_194"])))))))) * (-3.0)), data["SG_194"] )) +
            0.025000*np.tanh((-1.0*(((((((((((data["SG_227"]) * (np.minimum(((data["a2"])), (((((data["percent_atom_ga"]) > (data["a2"]))*1.))))))) > (0.161290))*1.)) * ((8.33435821533203125)))) * (data["percent_atom_ga"])))))) +
            0.020067*np.tanh((-1.0*(((((((data["percent_atom_al"]) < (np.sin(((((((data["lattice_angle_gamma_degree"]) < (np.sin((data["percent_atom_al"]))))*1.)) * 2.0)))))*1.)) * 2.0))))) +
            0.025000*np.tanh(((np.minimum(((data["SG_206"])), (((((np.sin((data["lattice_vector_2_ang"]))) < (np.cos((data["lattice_vector_2_ang"]))))*1.))))) * (data["lattice_vector_2_ang"]))) +
            0.025000*np.tanh(((data["SG_206"]) * (((np.where(data["percent_atom_al"]>0, np.where(data["percent_atom_in"]>0, (((data["percent_atom_al"]) > (0.616162))*1.), data["percent_atom_al"] ), 0.616162 )) - (data["percent_atom_ga"]))))) +
            0.025000*np.tanh(((((np.minimum(((((data["percent_atom_in"]) * (data["percent_atom_in"])))), (((-1.0*((((np.minimum(((((((data["percent_atom_in"]) * (data["percent_atom_in"]))) * (((data["percent_atom_in"]) * (data["percent_atom_in"])))))), ((np.cos((data["lattice_angle_alpha_degree"])))))) * 2.0)))))))) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((data["lattice_vector_2_ang"]) * (np.sin((((data["number_of_total_atoms"]) * (((data["number_of_total_atoms"]) * ((((((data["SG_206"]) < ((((0.905263) < (data["percent_atom_al"]))*1.)))*1.)) * (data["a2"]))))))))))) +
            0.025000*np.tanh((((((((0.400000) / 2.0)) > (data["a2"]))*1.)) * (((31.006277) * (((data["SG_227"]) * (((31.006277) * (((data["percent_atom_al"]) - (0.161290))))))))))) +
            0.025000*np.tanh(np.minimum(((np.where((((data["percent_atom_al"]) > (data["percent_atom_in"]))*1.)>0, (((0.536842) > (data["percent_atom_al"]))*1.), ((((data["percent_atom_al"]) * (data["SG_12"]))) - (data["percent_atom_al"])) ))), ((data["percent_atom_in"])))) +
            0.025000*np.tanh((((((((np.sin((np.minimum(((np.sin((data["lattice_vector_2_ang"])))), (((((data["lattice_vector_2_ang"]) > (3.141593))*1.))))))) > (np.sin((data["lattice_vector_1_ang"]))))*1.)) * (0.946667))) * (data["SG_194"]))) +
            0.025000*np.tanh((-1.0*((((data["percent_atom_in"]) * (((0.616162) * (((31.006277) * ((((np.where(data["SG_194"]>0, data["percent_atom_in"], ((data["percent_atom_al"]) * (data["percent_atom_al"])) )) > (0.716667))*1.))))))))))) +
            0.025000*np.tanh((((((1.076920) > (((0.716667) * (data["lattice_angle_beta_degree"]))))*1.)) * (((((np.sin((data["lattice_vector_3_ang"]))) * (31.006277))) * (data["lattice_vector_3_ang"]))))) +
            0.025000*np.tanh((-1.0*((np.minimum(((((((((np.where(data["percent_atom_ga"]>0, (((0.676056) < (data["percent_atom_ga"]))*1.), np.cos((data["lattice_vector_1_ang"])) )) + (0.161290))/2.0)) + (0.161290))/2.0))), ((data["SG_206"]))))))) +
            0.025000*np.tanh((((-1.0*((np.minimum((((((((data["percent_atom_al"]) / 2.0)) > (np.where(data["percent_atom_in"]>0, data["a0"], ((data["a0"]) * (data["a0"])) )))*1.))), (((((data["a0"]) > (data["SG_33"]))*1.)))))))) * 2.0)) +
            0.018705*np.tanh(np.minimum(((((((data["a2"]) * (data["a2"]))) * (((data["a2"]) * (data["a2"])))))), ((np.minimum((((((((((((data["percent_atom_in"]) * 2.0)) * 2.0)) + ((-1.0*((data["a2"])))))/2.0)) * ((((((((data["percent_atom_in"]) * 2.0)) * 2.0)) + ((-1.0*((data["a2"])))))/2.0))))), ((data["a0"]))))))) +
            0.025000*np.tanh(((np.sin(((((np.cos((data["lattice_vector_1_ang"]))) + (((((data["lattice_vector_1_ang"]) * 2.0)) * (((data["lattice_vector_1_ang"]) * 2.0)))))/2.0)))) * (((np.sin((data["lattice_vector_1_ang"]))) * (((((data["a0"]) * (data["a0"]))) * 2.0)))))) +
            0.025000*np.tanh(((data["a2"]) * (np.minimum(((data["percent_atom_al"])), ((np.sin((((data["lattice_vector_1_ang"]) * (((data["lattice_vector_1_ang"]) + (np.sin((np.minimum(((data["percent_atom_al"])), ((data["a2"]))))))))))))))))) +
            0.023525*np.tanh(((((((((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))) * (((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))))) * (((((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))) * (((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))))))) * (((((((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))) * (((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))))) * (((((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))) * (((((((data["a0"]) * 2.0)) * 2.0)) * ((((np.minimum(((((1.473680) * (data["a0"])))), ((0.907216)))) < (data["percent_atom_in"]))*1.)))))))))) +
            0.025000*np.tanh((-1.0*((((((np.cos((((((((data["percent_atom_in"]) - (data["number_of_total_atoms"]))) * 2.0)) * (((((data["percent_atom_in"]) - (data["number_of_total_atoms"]))) * 2.0)))))) * (2.255810))) * (np.minimum(((data["SG_227"])), ((((data["percent_atom_in"]) * 2.0)))))))))) +
            0.000000*np.tanh((((np.cos((data["a0"]))) < ((((data["lattice_angle_gamma_degree"]) > (((1.267610) + (((np.cos((data["a0"]))) / 2.0)))))*1.)))*1.)) +
            0.025000*np.tanh((((((((((data["percent_atom_ga"]) < (np.tanh(((((data["lattice_angle_gamma_degree"]) < (np.tanh((data["percent_atom_ga"]))))*1.)))))*1.)) * 2.0)) * 2.0)) * 2.0)) +
            0.019672*np.tanh(np.minimum(((((data["SG_227"]) * (((data["SG_227"]) * (np.cos((((((data["percent_atom_in"]) * 2.0)) + (np.tanh((data["SG_227"])))))))))))), ((((((data["percent_atom_in"]) * 2.0)) * 2.0))))) +
            0.025000*np.tanh((((((((((((0.400000) > (data["percent_atom_al"]))*1.)) > (data["SG_227"]))*1.)) > (data["SG_33"]))*1.)) * (((((((((data["percent_atom_al"]) * 2.0)) * (((data["percent_atom_al"]) * 2.0)))) * (((((data["percent_atom_al"]) * 2.0)) * (((data["percent_atom_al"]) * 2.0)))))) * 2.0)))) +
            0.025000*np.tanh(((np.cos((np.where(data["percent_atom_ga"]>0, 1.589740, data["lattice_angle_beta_degree"] )))) * (np.where(data["SG_167"]>0, data["percent_atom_ga"], np.where(np.sin((data["lattice_vector_2_ang"]))>0, 1.589740, data["lattice_vector_2_ang"] ) )))) +
            0.025000*np.tanh((((np.where(data["percent_atom_in"]>0, data["percent_atom_in"], data["a0"] )) < (((((np.tanh((np.tanh((np.sin((np.sin((data["a0"]))))))))) / 2.0)) / 2.0)))*1.)) +
            0.025000*np.tanh((-1.0*(((((((data["percent_atom_ga"]) > (0.400000))*1.)) * (np.where(data["percent_atom_al"]>0, ((((((data["percent_atom_al"]) > (0.400000))*1.)) + (data["SG_227"]))/2.0), (-1.0*((data["percent_atom_in"]))) ))))))) +
            0.025000*np.tanh(np.minimum(((data["a2"])), ((((((((((((((data["SG_33"]) - (data["percent_atom_in"]))) * 2.0)) * 2.0)) * 2.0)) * 2.0)) * ((((data["percent_atom_in"]) < (((0.285714) * (0.285714))))*1.))))))) +
            0.025000*np.tanh(((((((data["lattice_vector_3_ang"]) - (np.sin((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))))) * (np.cos((data["lattice_angle_alpha_degree"]))))) * (np.cos((((data["lattice_vector_1_ang"]) * (data["lattice_vector_1_ang"]))))))) +
            0.025000*np.tanh((((((((((0.616162) > (data["a1"]))*1.)) > (data["percent_atom_in"]))*1.)) < (((((((0.616162) > (((data["percent_atom_in"]) * (data["percent_atom_in"]))))*1.)) > ((((0.616162) > (data["percent_atom_in"]))*1.)))*1.)))*1.)) +
            0.025000*np.tanh(np.sin((((((np.sin((((np.sin((((((data["lattice_vector_2_ang"]) * (3.141593))) * (data["lattice_vector_3_ang"]))))) * (3.141593))))) * (3.141593))) * (data["SG_227"]))))) +
            0.024497*np.tanh(np.tanh(((((((data["SG_12"]) < (np.cos((data["lattice_vector_3_ang"]))))*1.)) * (np.minimum(((((((np.cos((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))) * (np.cos((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))))) * (((np.cos((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"]))))) * (np.cos((((data["lattice_vector_3_ang"]) * (data["lattice_vector_3_ang"])))))))))), ((np.cos((data["lattice_vector_3_ang"])))))))))) +
            0.025000*np.tanh(((0.161290) * (((((0.676056) - ((((np.sin((3.0))) > (data["percent_atom_al"]))*1.)))) - ((((np.maximum(((data["percent_atom_al"])), ((0.676056)))) > (data["a0"]))*1.)))))) +
            0.025000*np.tanh((((((((np.minimum(((data["percent_atom_al"])), ((((data["percent_atom_ga"]) / 2.0))))) > (0.161290))*1.)) - (((data["percent_atom_ga"]) * (((data["percent_atom_ga"]) * (data["percent_atom_ga"]))))))) * (data["SG_227"]))) +
            0.025000*np.tanh(((np.minimum(((np.sin((np.sin((((0.905263) - (np.sin((data["lattice_vector_3_ang"])))))))))), (((-1.0*((((data["lattice_vector_1_ang"]) * ((((3.141593) > (data["lattice_vector_1_ang"]))*1.)))))))))) * 2.0)) +
            0.020141*np.tanh(((np.maximum(((0.907216)), (((((data["percent_atom_al"]) < ((((data["SG_12"]) < (np.cos((data["lattice_angle_alpha_degree"]))))*1.)))*1.))))) - (np.maximum(((data["SG_194"])), (((((data["percent_atom_al"]) < (0.946667))*1.))))))) +
            0.012786*np.tanh(((np.where(data["percent_atom_ga"]>0, np.minimum(((data["percent_atom_ga"])), ((((np.where(data["SG_12"]>0, 0.500000, data["percent_atom_al"] )) * (np.where(data["SG_12"]>0, 0.500000, data["percent_atom_al"] )))))), 0.500000 )) * (np.where(data["percent_atom_ga"]>0, np.minimum(((data["percent_atom_ga"])), ((((np.where(data["SG_12"]>0, 0.500000, data["percent_atom_al"] )) * (np.where(data["SG_12"]>0, 0.500000, data["percent_atom_al"] )))))), 0.500000 )))) +
            0.024995*np.tanh((((0.318310) < (np.minimum(((data["a0"])), ((np.sin((data["lattice_vector_2_ang"])))))))*1.)) +
            0.025000*np.tanh((-1.0*(((((((data["lattice_vector_1_ang"]) < (3.141593))*1.)) * (data["lattice_vector_3_ang"])))))) +
            0.025000*np.tanh(((((((((((0.285714) < (data["percent_atom_in"]))*1.)) < (np.cos((data["lattice_angle_beta_degree"]))))*1.)) * (((data["a2"]) + (data["a2"]))))) * ((((0.161290) < (data["percent_atom_al"]))*1.)))) +
            0.015018*np.tanh(np.cos((np.where(data["percent_atom_al"]>0, (7.89490509033203125), np.where(data["SG_194"]>0, (((data["lattice_vector_1_ang"]) + ((((data["lattice_vector_1_ang"]) + (data["percent_atom_in"]))/2.0)))/2.0), 1.184620 ) )))) +
            0.025000*np.tanh(((data["lattice_vector_3_ang"]) * (((data["SG_227"]) * (((data["a2"]) * (np.sin(((((10.14920616149902344)) * (np.sin((((data["lattice_vector_3_ang"]) * (np.cos((data["lattice_vector_3_ang"]))))))))))))))))) +
            0.025000*np.tanh((((((((((data["a2"]) + (data["a2"]))) > (((data["a1"]) + (1.589740))))*1.)) * (np.cos((9.869604))))) * ((((1.589740) > (data["lattice_angle_beta_degree"]))*1.)))) +
            0.010520*np.tanh((((((((2.91873049736022949)) * (9.869604))) * (9.869604))) * (((data["lattice_vector_3_ang"]) * ((((2.91871976852416992)) - ((2.91873049736022949)))))))) +
            0.025000*np.tanh(((((((np.minimum((((((np.minimum(((np.cos((data["lattice_angle_alpha_degree"])))), ((data["percent_atom_in"])))) > ((((((1.076920) / 2.0)) > (data["lattice_angle_gamma_degree"]))*1.)))*1.))), ((data["SG_227"])))) * 2.0)) * 2.0)) * 2.0)) +
            0.025000*np.tanh(((np.cos((data["lattice_angle_alpha_degree"]))) * (((((((((data["lattice_vector_1_ang"]) * (data["lattice_vector_3_ang"]))) * (data["a1"]))) + (3.141593))) - ((((12.78803157806396484)) * (data["a0"]))))))) +
            0.020346*np.tanh(((((((((((0.905263) + (((np.cos((((((((data["lattice_vector_3_ang"]) / 2.0)) + (0.536842))) * (((((data["lattice_vector_3_ang"]) / 2.0)) + (0.536842))))))) * 2.0)))) * 2.0)) * 2.0)) * 2.0)) * (data["SG_227"]))) +
            0.022915*np.tanh((-1.0*((np.minimum(((((data["lattice_angle_gamma_degree"]) * (np.tanh((data["SG_227"])))))), ((data["a2"]))))))))

# %%
def get_xyz_data(filename):
    pos_data = []
    lat_data = []
    with open(filename) as f:
        for line in f.readlines():
            x = line.split()
            if x[0] == 'atom':
                pos_data.append([np.array(x[1:4], dtype=np.float),x[4]])
            elif x[0] == 'lattice_vector':
                lat_data.append(np.array(x[1:4], dtype=np.float))
    
    A = np.transpose(lat_data)
    B = np.linalg.inv(A)
    R = pos_data[0][0]
    return np.matmul(B, R)


def GrabData():
    train = pd.read_csv('../input/train.csv')
    test = pd.read_csv('../input/test.csv')
    test['bandgap_energy_ev'] = np.nan
    test['formation_energy_ev_natom'] =np.nan
    for c in train.columns:
        if(c.find('angle')!=-1):
            train[c] = np.radians(train[c])
            test[c] = np.radians(test[c])
    traindata = np.zeros((train.shape[0],3))
    for i,idx in enumerate(train.id.values):
        fn = "../input/train/{}/geometry.xyz".format(idx)
        data = get_xyz_data(fn)
        traindata[i,:] = data
    testdata = np.zeros((test.shape[0],3))
    for i,idx in enumerate(test.id.values):
        fn = "../input/test/{}/geometry.xyz".format(idx)
        data = get_xyz_data(fn)
        testdata[i,:] = data
    train['a0'] = 0
    train['a1'] = 0
    train['a2'] = 0
    train[['a0','a1','a2']]= traindata
    test['a0'] = 0
    test['a1'] = 0
    test['a2'] = 0
    test[['a0','a1','a2']] = testdata

    alldata = pd.concat([train,test])


    alldata = pd.concat([alldata.drop(['spacegroup'], axis=1), 
                       pd.get_dummies(alldata['spacegroup'], prefix='SG')], axis=1)

    alldata.formation_energy_ev_natom = np.log1p(alldata.formation_energy_ev_natom)
    alldata.bandgap_energy_ev = np.log1p(alldata.bandgap_energy_ev)
    alldata.number_of_total_atoms = np.log(alldata.number_of_total_atoms)
    features = ['id', 
                'a0', 'a1', 'a2', 
                'lattice_angle_alpha_degree', 'lattice_angle_beta_degree',
                'lattice_angle_gamma_degree', 'lattice_vector_1_ang',
                'lattice_vector_2_ang', 'lattice_vector_3_ang', 'number_of_total_atoms',
                'percent_atom_al', 'percent_atom_ga', 'percent_atom_in', 'SG_12',
                'SG_33', 'SG_167', 'SG_194', 'SG_206', 'SG_227',
                'bandgap_energy_ev', 'formation_energy_ev_natom']

    alldata = alldata[features]
    alldata[features[1:]] = alldata[features[1:]] .astype(float).round(6)
    test = alldata[train.shape[0]:].copy()
    train = alldata[:train.shape[0]].copy()
    return train, test

# %%
train, test = GrabData()

# %%
print(np.sqrt(mean_squared_error(train.formation_energy_ev_natom, GPFE(train))))
print(np.sqrt(mean_squared_error(train.bandgap_energy_ev, GPBE(train))))

# %%
sub = pd.DataFrame({'id':test.id.values,
                    'formation_energy_ev_natom':np.expm1(GPFE(test)),
                    'bandgap_energy_ev':np.expm1(GPBE(test))})
sub[['id','formation_energy_ev_natom','bandgap_energy_ev']].to_csv('submission.csv',index=False)
