# %% [markdown]
# # **libjpeg** & **gdcm** without internet access

# %% [markdown]
# Taken originally from pydicom_conda_helper notebook here[https://www.kaggle.com/awsaf49/pydicom-conda-helper] and add extra packages personalized.

# %%
# !wget 'https://anaconda.org/conda-forge/libjpeg-turbo/2.1.0/download/linux-64/libjpeg-turbo-2.1.0-h7f98852_0.tar.bz2' -q
# !wget 'https://anaconda.org/conda-forge/libgcc-ng/9.3.0/download/linux-64/libgcc-ng-9.3.0-h2828fa1_19.tar.bz2' -q
# !wget 'https://anaconda.org/conda-forge/gdcm/2.8.9/download/linux-64/gdcm-2.8.9-py37h500ead1_1.tar.bz2' -q
# !wget 'https://anaconda.org/conda-forge/conda/4.10.1/download/linux-64/conda-4.10.1-py37h89c1867_0.tar.bz2' -q
# !wget 'https://anaconda.org/conda-forge/certifi/2020.12.5/download/linux-64/certifi-2020.12.5-py37h89c1867_1.tar.bz2' -q
# !wget 'https://anaconda.org/conda-forge/openssl/1.1.1k/download/linux-64/openssl-1.1.1k-h7f98852_0.tar.bz2' -q

# %%
# !pip download pyspark
# !pip download fastai
# !pip download wwf
# !pip download efficientnet_pytorch
# !pip download icevision[all]
# !pip download yolov5-icevision
# !pip download icedata

# %% [markdown]
# # How to use it
#
# Install the ones you need.
# ```
# !conda install 'libjpeg-turbo-2.1.0-h7f98852_0.tar.bz2' -c conda-forge -y
# !conda install 'libgcc-ng-9.3.0-h2828fa1_19.tar.bz2' -c conda-forge -y
# !conda install 'gdcm-2.8.9-py37h500ead1_1.tar.bz2' -c conda-forge -y
# !conda install 'conda-4.10.1-py37h89c1867_0.tar.bz2' -c conda-forge -y
# !conda install 'certifi-2020.12.5-py37h89c1867_1.tar.bz2' -c conda-forge -y
# !conda install 'openssl-1.1.1k-h7f98852_0.tar.bz2' -c conda-forge -y
# !pip install --no-index --find-links "/kaggle/input/modified-siim-helper/" pyspark
# !pip install --no-index --find-links "/kaggle/input/modified-siim-helper/" fastai
# !pip install --no-index --find-links "/kaggle/input/modified-siim-helper/" wwf
# !pip install --no-index --find-links "/kaggle/input/modified-siim-helper/" efficientnet_pytorch
# !pip install --no-index --find-links "/kaggle/input/modified-siim-helper/" icevision[all] yolov5-icevision icedata
# ```

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1N34aCuCoVAx0lc1kNPf84vrmI7wCgSIV
# !unzip "/kaggle/working/Assemble-ResNet152.zip"
# !rm "./Assemble-ResNet152.zip"

# %%
# !pip install -U efficientnet efficientnet_pytorch

# %%
# !wget https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b7-dcc49843.pth

# %% [markdown]
# Below are from https://github.com/zoogzog/chexnet and https://github.com/arnoweng/CheXNet respectively.

# %%
# !wget https://github.com/zoogzog/chexnet/raw/master/models/m-25012018-123527.pth.tar -O chexnet_zoogzog.pth.tar
# !wget https://github.com/arnoweng/CheXNet/raw/master/model.pth.tar -O arnoweng.pth.tar

# %% [markdown]
# ### Icevision Requirement

# %%
# !wget https://raw.githubusercontent.com/airctic/storage/master/SpaceGrotesk-Medium.ttf
# !wget https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth

# %% [markdown]
# !mkdir --parents /root/.icevision/fonts/
# !cd /root/.icevision/fonts/
# !mv ./SpaceGrotesk-Medium.ttf /root/.icevision/fonts/
