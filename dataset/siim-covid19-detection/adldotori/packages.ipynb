# %%
# !wget 'https://anaconda.org/conda-forge/webcolors/1.11.1/download/noarch/webcolors-1.11.1-pyhd8ed1ab_0.tar.bz2' -q

# %%
# !conda install webcolors-1.11.1-pyhd8ed1ab_0.tar.bz2 -c conda-forge -y
