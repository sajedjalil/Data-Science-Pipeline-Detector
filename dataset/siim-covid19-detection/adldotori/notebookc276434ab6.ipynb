# %%
import pandas as pd
sub = pd.read_csv('../input/siim-test/covid-19 submission.csv')
sub.head()

# %%
sample = pd.read_csv('../input/siim-covid19-detection/sample_submission.csv')
sample.head()

# %%
sample['PredictionString'] = sub.PredictionString.values

# %%
sample.loc[sample.id.str.contains('study'), 'PredictionString'] = 'typical 1.0 0 0 1 1'

# %%
sample

# %%
# sub.to_csv('submission.csv', index=None)

# %%
sample.to_csv('submission.csv', index=None)
