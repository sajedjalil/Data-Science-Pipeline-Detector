# %%
import pandas as pd

# %%
yuan_df = pd.read_csv('../input/siim-covid19-detection/sample_submission.csv')
study_df = pd.read_csv('../input/inference-studyclass-baseline/submission.csv')
image_df = pd.read_csv('../input/tempsubcsv/sub_image.csv')

# %%
image_df.to_csv('./submission.csv',index=False)

# %%
yuan_df

# %%
yuan_df.loc[0:1213]
#study_df.loc[0:1214]

# %%
image_df.loc[1213:]

# %%
he_df = [study_df.loc[0:1213], image_df.loc[1214:]]
he = pd.concat(he_df)

# %%
he

# %%
#study_df.to_csv('./submission.csv',index=False)
