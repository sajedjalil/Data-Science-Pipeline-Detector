# %%
# !wget https://download.pytorch.org/whl/torch_stable.html
# !wget https://download.pytorch.org/whl/torchtext-0.5.0-py3-none-any.whl 
# !wget https://download.pytorch.org/whl/cu100/torch-1.2.0-cp37-cp37m-manylinux1_x86_64.whl 
# !wget https://download.pytorch.org/whl/cu100/torchvision-0.4.0-cp37-cp37m-manylinux1_x86_64.whl

# %%
import os
import urllib.request

url = "https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth"
target_path = 'vgg16_reducedfc.pth' 
if not os.path.exists(target_path):
    urllib.request.urlretrieve(url, target_path)

# %%
# !ls
