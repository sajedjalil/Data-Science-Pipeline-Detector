# %%
# !pip download albumentations==1.0.0
# !pip download effdet==0.2.4
# !pip download git+https://github.com/rwightman/pytorch-image-models/
# !pip download pylibjpeg
# !pip download numpy==1.20.0
# !pip download segmentation_models_pytorch==0.2.0
# !pip download ensemble_boxes==1.0.6
