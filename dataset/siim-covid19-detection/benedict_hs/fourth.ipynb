# %%
import pandas as pd

df = pd.read_csv("../input/siim-covid19-detection/train_image_level.csv")
df

# %%
df['none'] = 0
df

# %%
for i in range(len(df)):
    if df.loc[i,'label'].split()[0] == 'none':
        df.loc[i,'none'] = 1
df

# %%
df.to_csv("train.csv", index=False)
