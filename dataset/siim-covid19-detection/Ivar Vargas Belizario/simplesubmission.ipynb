# %%
import numpy as np
import pandas as pd
  
main_path = "/kaggle/input/siim-covid19-detection/"
test_path = main_path+"test/"
train_path = main_path+"train/"

def simple_submission():
    df = pd.read_csv(main_path + "sample_submission.csv")
    df.to_csv('./submission.csv',index=False)
    print(df)
    
def random_submission():
    pass


random_submission()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(plt.imread('/kaggle/input/superpixels-samples/0c81b34981b3_50.png'))

# %%
plt.imshow(plt.imread('/kaggle/input/superpixels-samples/0c81b34981b3_100.png'))

# %%
plt.imshow(plt.imread('/kaggle/input/superpixels-samples/0c81b34981b3_200.png'))
