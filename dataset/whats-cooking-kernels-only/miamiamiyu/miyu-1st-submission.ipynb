# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#For ignoring warning
import warnings
warnings.filterwarnings('ignore', category = DeprecationWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})
sns.set_palette("bright")
import torch.nn
import random

# %%
# inputのところにあるzipファイルを解凍する
# !unzip ../input/whats-cooking-kernels-only/sample_submission.csv.zip

# %%
#データを取り込む
# さっき解凍した分はoutputのところから持ってくる
df = pd.read_csv("./sample_submission.csv")
df_test = pd.read_json("../input/whats-cooking-kernels-only/test.json")
df_train = pd.read_json("../input/whats-cooking-kernels-only/train.json")
print(len(df))
print(len(df_test))
df.head()

# %%
# JSONファイルをDataframeにする
df = pd.read_json('../input/whats-cooking-kernels-only/test.json').transpose()
df = pd.read_json('../input/whats-cooking-kernels-only/train.json').transpose()

# %%
import pandas as pd
from pandas import DataFrame

 
data_s = pd.DataFrame()
data_s

# %%
#green bell pepper 全レシピlistの材料をひとつづつ取り出す
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'green bell pepper' : 
            df_train.loc[index, 'green bell pepper'] = 1
        else :
            df_train.loc[index, 'green bell pepper'] = 0

# %%
df_train[df_train["green bell pepper"] > 0]

# %%
#検証用データにも、green bell pepperのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'green bell pepper' : 
            df_test.loc[index, 'green bell pepper'] = 1
        else :
            df_test.loc[index, 'green bell pepper'] = 0

# %%
df_test[df_test["green bell pepper"] > 0]

# %%
# garam masalaのカラムを作る　１
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'garam masala' : 
            df_train.loc[index, 'garam masala'] = 1
        else :
            df_train.loc[index, 'garam masala'] = 0

# %%
# ２　green onions　
df_train[df_train["garam masala"] > 0]

# %%
#3 検証用データにも、green onionsのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'garam masala' : 
            df_test.loc[index, 'garam masala'] = 1
        else :
            df_test.loc[index, 'garam masala'] = 0

# %%
# ４
df_test[df_test["garam masala"] > 0]

# %%
# coconut milk　のカラムを作る　１
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'coconut milk' : 
            df_train.loc[index, 'coconut milk'] = 1
        else :
            df_train.loc[index, 'coconut milk'] = 0

# %%
# ２
df_train[df_train["coconut milk"] > 0]

# %%
#3 検証用データにも、coconut milkのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'coconut milk' : 
            df_test.loc[index, 'coconut milk'] = 1
        else :
            df_test.loc[index, 'coconut milk'] = 0

# %%
# ４
df_test[df_test["coconut milk"] > 0]

# %%
# 1 feta cheese
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'feta cheese' : 
            df_train.loc[index, 'feta cheese'] = 1
        else :
            df_train.loc[index, 'feta cheese'] = 0

# %%
# ２　feta cheese
df_train[df_train["feta cheese"] > 0]

# %%
# 3feta cheese 検証用データにも、feta cheeseのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'feta cheese' : 
            df_test.loc[index, 'feta cheese'] = 1
        else :
            df_test.loc[index, 'feta cheese'] = 0

# %%
# ４ feta cheese
df_test[df_test["feta cheese"] > 0]

# %%
# 1 shallots
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'shallots' : 
            df_train.loc[index, 'shallots'] = 1
        else :
            df_train.loc[index, 'shallots'] = 0

# %%
# ２
df_train[df_train["shallots"] > 0]

# %%
# 3 shallots 検証用データにも、shallotsのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'shallots' : 
            df_test.loc[index, 'shallots'] = 1
        else :
            df_test.loc[index, 'shallots'] = 0

# %%
# ４ sesame oil
df_test[df_test["shallots"] > 0]

# %% [markdown]
# ここからは１か国の頻出食材

# %%
#green bell pepper 全レシピlistの材料をひとつづつ取り出す
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'green bell pepper' : 
            df_train.loc[index, 'green bell pepper'] = 1
        else :
            df_train.loc[index, 'green bell pepper'] = 0

# %%
df_train[df_train["green bell pepper"] > 0]

# %%
#検証用データにも、green bell pepperのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'green bell pepper' : 
            df_test.loc[index, 'green bell pepper'] = 1
        else :
            df_test.loc[index, 'green bell pepper'] = 0

# %%
df_test[df_test["green bell pepper"] > 0]

# %%
# garam masalaのカラムを作る　１
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'garam masala' : 
            df_train.loc[index, 'garam masala'] = 1
        else :
            df_train.loc[index, 'garam masala'] = 0

# %%
# ２　green onions　
df_train[df_train["garam masala"] > 0]

# %%
#3 検証用データにも、green onionsのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'garam masala' : 
            df_test.loc[index, 'garam masala'] = 1
        else :
            df_test.loc[index, 'garam masala'] = 0

# %%
# ４
df_test[df_test["garam masala"] > 0]

# %%
# coconut milk　のカラムを作る　１
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'coconut milk' : 
            df_train.loc[index, 'coconut milk'] = 1
        else :
            df_train.loc[index, 'coconut milk'] = 0

# %%
# ２
df_train[df_train["coconut milk"] > 0]

# %%
#3 検証用データにも、coconut milkのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'coconut milk' : 
            df_test.loc[index, 'coconut milk'] = 1
        else :
            df_test.loc[index, 'coconut milk'] = 0

# %%
# ４
df_test[df_test["coconut milk"] > 0]

# %%
# 1 feta cheese
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'feta cheese' : 
            df_train.loc[index, 'feta cheese'] = 1
        else :
            df_train.loc[index, 'feta cheese'] = 0

# %%
# ２　feta cheese
df_train[df_train["feta cheese"] > 0]

# %%
# 3feta cheese 検証用データにも、feta cheeseのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'feta cheese' : 
            df_test.loc[index, 'feta cheese'] = 1
        else :
            df_test.loc[index, 'feta cheese'] = 0

# %%
# ４ feta cheese
df_test[df_test["feta cheese"] > 0]

# %%
# 1 shallots
word = list()
for index, row in df_train.iterrows():
    list_ingredients = df_train.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'shallots' : 
            df_train.loc[index, 'shallots'] = 1
        else :
            df_train.loc[index, 'shallots'] = 0

# %%
# ２
df_train[df_train["shallots"] > 0]

# %%
# 3 shallots 検証用データにも、shallotsのカラムを作る
word = list()
for index, row in df_test.iterrows():
    list_ingredients = df_test.loc[index, 'ingredients']
    for ingredient in list_ingredients:
        if ingredient == 'shallots' : 
            df_test.loc[index, 'shallots'] = 1
        else :
            df_test.loc[index, 'shallots'] = 0

# %%
# ４ shallots
df_test[df_test["shallots"] > 0]

# %% [markdown]
# くくるの終わり

# %%
# 材料のカラムを取り除く（材料のカラムはリスト（文字）だから学習には使えない）

print(df_train.drop('ingredients', axis=1))

# %%
#学習用データのcuisine以外をx_train とする
x_train = df_train.drop('cuisine',axis=1)

# %%
#学習用データのcuisineとingredients以外をx_train とする
x_train = df_train.drop(['cuisine', 'ingredients'], axis=1)

# %%
x_train

# %%
#検証用データのcuisineがy_train
y_train = df_train.cuisine

# %%
#y_trainを横並びのデータにする
y_train = df_train.cuisine.values

# %%
print(df_test.drop('ingredients', axis=1))

# %%
df_test = df_test.drop('ingredients', axis=1)

# %%
# ロジスティック回帰
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# 学習してもらう
model.fit(x_train, y_train)

# %%
x_test = df_test

# %%
y_prediction = model.predict(x_test)

# %%
y_prediction

# %%
df_submit = pd.read_csv ("sample_submission.csv")

# %%
df_submit['cuisine'] = pd.DataFrame(y_prediction.T)

# %%
df_submit.to_csv('submission.csv', index=False)
