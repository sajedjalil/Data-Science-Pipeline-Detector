# %%
# !pip install fsspec -q
# !pip install gcsfs -q

# %%
#  %cd /content/drive/MyDrive/Kaggle/ventilator

# %%
from kaggle_datasets import KaggleDatasets
print(KaggleDatasets().get_gcs_path('ventilator-pressure-prediction'))

# %%
ventilator_csv_path="gs://kds-c544cf17997c19a6bf7fc6c97f8d935dd3cf8ae29ac9ff3a286b67a6"

# %%
import os
Train_CSV_PATH    = os.path.join(ventilator_csv_path,"train.csv")
Test_CSV_PATH    = os.path.join(ventilator_csv_path,"test.csv")
Submission_CSV_PATH = os.path.join(ventilator_csv_path,"sample_submission.csv")

# %%
Train_CSV_PATH

# %%
import pandas as pd
train_ori = pd.read_csv(Train_CSV_PATH)
test_ori = pd.read_csv(Test_CSV_PATH)
submission = pd.read_csv(Submission_CSV_PATH)

# %%
train_ori

# %%
test_ori

# %%
submission
