# %%
import numpy as np
import pandas as pd

# %%
sub = pd.read_csv("../input/ventilator-pressure-prediction/sample_submission.csv")

sub_0 = pd.read_csv('../input/gb-vpp-pulp-fiction/median_submission.csv')
sub_1 = pd.read_csv('../input/new-ensemble-of-public-notebooks/submission.csv')
sub_2 = pd.read_csv('../input/vpp-a-basic-ensembling-technique/submission_pp.csv')
sub_3 = pd.read_csv('../input/ensemble-without-overfitting-risk/submission_median.csv')

# %%
sub['pressure'] = (sub_0['pressure'].values*0.656) + (sub_1['pressure'].values*0.344)+(sub_2['pressure'].values*0)+(sub_3['pressure'].values*0)
sub.to_csv('submission.csv', index=False)
sub.head(5)
