# %%
import numpy as np
import pandas as pd

# %%
sub = pd.read_csv("../input/ventilator-pressure-prediction/sample_submission.csv")

sub_0 = pd.read_csv('../input/gb-vpp-pulp-fiction-abb651/median_submission.csv')
sub_1 = pd.read_csv('../input/new-ensemble-of-public-notebooks/submission.csv')
sub_2 = pd.read_csv('../input/median-ensemble-of-published-notebooks/submission.csv')
sub_3 = pd.read_csv('../input/vent-011-median-wins/submission.csv')
sub_4 = pd.read_csv('../input/dnn-lstm-tpu/median_submission.csv')

# %%
sub['pressure'] = (sub_0['pressure'].values*0.1) + (sub_1['pressure'].values*0.14)+(sub_2['pressure'].values*0.5)+(sub_3['pressure'].values*0.16)+(sub_4['pressure'].values*0.1)
sub.to_csv('submission3.csv', index=False)
sub.head(5)
