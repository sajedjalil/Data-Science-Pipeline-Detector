# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ****Objective : To simulate a ventilator connected to a sedated patient's lung.****

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/train.csv')

# %% [markdown]
# ****train_data**** :: the training set

# %%
train_data

# %% [markdown]
# ****id**** - globally-unique time step identifier across an entire file.
#
#
# ****breath_id**** - globally-unique time step for breaths.
#
#
# ****R**** - lung attribute indicating how restricted the airway is (in cmH2O/L/S). Physically, this is the change in pressure per change in flow (air volume per time). Intuitively, one can imagine blowing up a balloon through a straw. We can change R by changing the diameter of the straw, with higher R being harder to blow.
#
#
# ****C**** - lung attribute indicating how compliant the lung is (in mL/cmH2O). Physically, this is the change in volume per change in pressure. Intuitively, one can imagine the same balloon example. We can change C by changing the thickness of the balloon’s latex, with higher C having thinner latex and easier to blow.
#
#
# ****time_step**** - the actual time stamp.
#
#
# ***u_in*** - the control input for the inspiratory solenoid valve. Ranges from 0 to 100.
#
#
# ***u_out*** - the control input for the exploratory solenoid valve. Either 0 or 1.
#
#
# ***pressure*** - the airway pressure measured in the respiratory circuit, measured in cmH2O.

# %%
sample_data = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/sample_submission.csv')

# %% [markdown]
# ***sample_data***:  a sample submission file in the correct format

# %%
sample_data

# %%
test_data = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/test.csv')

# %% [markdown]
# ***test_data*** :: the test set

# %%
test_data

# %%
train_data.describe()   #Details of the train_data set

# %% [markdown]
# ***Medians*** of all the features ::

# %%
print(np.median(train_data['id']))

# %%
print(np.median(train_data['breath_id']))

# %%
print(np.median(train_data['R']))

# %%
print(np.median(train_data['C']))

# %%
print(np.median(train_data['time_step']))

# %%
print(np.median(train_data['u_in']))

# %%
print(np.median(train_data['u_out']))

# %%
print(np.median(train_data['pressure']))

# %% [markdown]
# ***Unique*** from each features ::

# %%
print(train_data['id'].unique())

# %%
print(train_data['breath_id'].unique())

# %%
print(train_data['R'].unique())

# %%
print(train_data['C'].unique())

# %%
print(train_data['time_step'].unique())

# %%
print(train_data['u_in'].unique())

# %%
print(train_data['u_out'].unique())

# %%
print(train_data['pressure'].unique())

# %% [markdown]
# Getting ***Datapoints*** in every class ::

# %%
train_data['id'].value_counts()

# %%
train_data['breath_id'].value_counts()

# %%
train_data['R'].value_counts()

# %%
train_data['C'].value_counts()

# %%
train_data['u_in'].value_counts()

# %%
train_data['u_out'].value_counts()

# %%
train_data['pressure'].value_counts()

# %% [markdown]
# ***Plotting*** ::

# %%
train_data['R'].value_counts().plot(kind='bar')
plt.xlabel('R')

plt.show()

# %%
train_data['C'].value_counts().plot(kind='bar')
plt.xlabel('C')
plt.show()

# %%
test_data.plot(kind='scatter', x='R', y='breath_id')  #plotting a scatter plot
plt.legend()
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='R', y ='C')
plt.xlabel('R')
plt.ylabel('C')
plt.show()

# %%
test_data.plot(kind='scatter', x='breath_id', y='u_in')
plt.xlabel('u_in')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='id', y='u_in')
plt.xlabel('id')
plt.ylabel('u_in')
plt.show()

# %%
test_data.plot(kind='scatter', x='R', y='u_in')
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='C', y='u_in')
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='u_in', y='u_out')
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='R', y='u_out')
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='C', y='u_in')
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='R', y='time_step')
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()

# %%
test_data.plot(kind='scatter', x='R', y='time_step')
plt.xlabel('R')
plt.ylabel('breath id')
plt.show()
