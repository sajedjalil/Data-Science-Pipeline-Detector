# %% [markdown]
#  # <h1 style=' border:0;'><center>🔥 Google Colab + Kaggle API 🔗</center></h1>

# %% [markdown]
# <h1 style=' border:0; color:#FFA500 '><left>Download the Kaggle API 📩</left></h1>
#
# To download the Kaggle API, sign up for a Kaggle account at https://www.kaggle.com. Then go to the 'Account' tab of your user profile (`https://www.kaggle.com/<username>/account`) and select 'Create API Token'. This will trigger the download of `kaggle.json`, a file containing your API credentials.

# %% [markdown]
# ### 1.On rightside of your kaggle website you will find your profile pic click it and under you will find **"Your Profile"**
# ![tempsnip.png](attachment:e8eb2836-bf14-48da-a3a2-05bdf8d0c977.png)
#
#
# ### 2.Your home page opens and scroll little down you will find API section
# ### 3.Click "Create New API Token"
#
#
# ![tempsnip1.png](attachment:2753e73a-8134-4445-be7c-55d1ec08eb0d.png)
# ### 4.kaggle.json file will be generated and save in your PC
# #### ⚠️ NOTE : Dont't share your kaggle.json file to anyone because it contains your credentials

# %% [markdown]
# <h1 style=' border:0; color:#FFA500 '><left>Open Colab Notebook 📭</left> </h1>

# %% [markdown]
# #### Open the colab website https://colab.research.google.com and open new notebook      `File -> New notebook`

# %% [markdown]
# <h1 style=' border:0; color:#FFA500 '><left>Follow the code below 🔽</left></h1>

# %%
from google.colab import files #import the files fron colab

# %%
files.upload() #upload your kaggle.json file form your PC

# %%
! mkdir ~/.kaggle #creating folder

# %%
! cp kaggle.json ~/.kaggle/ #copying kaggle.json

# %%
 ! chmod 600 ~/.kaggle/kaggle.json #reading the file with full access

# %% [markdown]
# <h1 style=' border:0; color:#FFA500 '><left>Download the Dataset 📂</left> </h1>

# %%
! kaggle competitions download -c 'ventilator-pressure-prediction' #downloading the compatition dataset

# %% [markdown]
# # <h1 style=' border:0; color:#FFA500 '><left>Loading Data 🚚</left></h1>

# %%
import required modules
import zipfile
import pandas as pd 

train = pd.read_csv("/content/train.csv.zip" ,compression='zip') #reading the train.csv zip file and store in train variable
test = pd.read_csv("/content/test.csv.zip" ,compression='zip') #reading the test.csv zip flie and store in test variable

# %% [markdown]
# # <h1 style=' border:0; color:#FFA500 '><left>Your modeling 📚</left></h1>

# %%
#your modeling and create the submission file

# %% [markdown]
# <h1 style=' border:0; color:#FFA500 '><left>✔️Submit your submission.csv</left> </h1>

# %% [markdown]
# #### Submit your submission file through notebook. It will be directily submit the submission.csv in your kaggle account

# %%
! kaggle competitions submit ventilator-pressure-prediction -f submission.csv -m "My submission message" #submit your submission.csv

# %% [markdown]
# ### Important : Colab TPU is very much slower the Kaggle TPU 😔. It is better to use if your quota is over!

# %% [markdown]
# ### To know more about kaggle api visit [Github](https://github.com/Kaggle/kaggle-api) or [Documentation](https://www.kaggle.com/docs/api)

# %% [markdown]
# # <h1 style=' border:0; color:#FFA500 '><center> If you find this notebook usefull support me with giving ⬆️!</left></h1>
