# %% [markdown]
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 30px;"> Automated Exploratory Data Analysis using Four different AutoML Libraries</p>

# %% [markdown]
# * [1. Standard Libraries Import](#1)
#
# * [2. Installation of new libraries](#2)
#
# * [3. Reading the input data](#3)
#
# * [4. EDA using Sweetviz](#4)
#
# * [5. EDA using Pandas profiling](#5)
#
# * [6. EDA Using Autoviz](#6)
#
# * [7. EDA Using Dataprep](#7)

# %% [markdown]
# <a id="1"></a>
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 60px;"> Standard Libraries Import</p>

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

# %% [markdown]
# <a id="2"></a>
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 60px;"> Installation of new libraries</p>

# %%
# !pip install sweetviz
import sweetviz as sv
# !pip install autoviz
# !pip install xlrd
# !pip install dataprep

# %% [markdown]
# <a id="3"></a>
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 60px;"> Reading the input Data</p>

# %%
df=pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
#Replace this with any dataset of your choice

# %% [markdown]
# <a id="4"></a>
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 60px;"> EDA Using Sweetviz</p>

# %%
#analyzing the dataset
data_report = sv.analyze(df)
#display the report in output folder
data_report.show_html('Report_Sweetviz')
#Display the output in notebook
data_report.show_notebook()

# %% [markdown]
# <a id="5"></a>
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 60px;"> EDA Using Pandas Profiling</p>

# %%
import pandas_profiling as pp

# %%
pp.ProfileReport(df)

# %% [markdown]
# <a id="6"></a>
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 60px;"> EDA Using Autoviz</p>

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
dft = AV.AutoViz(filename="",sep=",", dfte=df,verbose=1)

# %% [markdown]
# <a id="7"></a>
# # <p style="background-color:#A291A7;font-family:newtimeroman;color:#444160;font-size:150%;text-align:center;border-radius:20px 60px;"> EDA using Dataprep</p>

# %%
from dataprep.eda import create_report

# %%
report = create_report(df.sample(frac=.5)) # notebook error
report.show()
report.save('EDA Report')
