# %%
from IPython.display import Image
Image('../input/datariskimagesmodeling/1_.png')

# %%
Image('../input/datariskimagesmodeling/2_.png')

# %%
Image('../input/datariskimagesmodeling/3_.png')

# %%
Image('../input/datariskimagesmodeling/4_.png')

# %%
Image('../input/datariskimagesmodeling/5_.png')

# %%
Image('../input/datariskimagesmodeling/6_.png')

# %%
Image('../input/datariskimagesmodeling/8_.png')

# %%
Image('../input/datariskimagesmodeling/9_.png')
