# %% [markdown]
# Why is this relevant? Because contact to the head ruins lives....
#
# There's also a Will Smith movie that adds some color to the NFLs history in all this: https://www.youtube.com/watch?v=Io6hPdC41RM

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from pathlib import Path
from PIL import Image

# %%
input_path = Path('../input/nfl-impact-detection')
os.listdir(input_path)

# %%
image_labels = pd.read_csv(input_path/'image_labels.csv')
train_labels = pd.read_csv(input_path/'train_labels.csv')
train_player = pd.read_csv(input_path/'train_player_tracking.csv')
sub_df = pd.read_csv(input_path/'sample_submission.csv')

# %%
image_labels.head(1)

# %%
image_labels.shape

# %%
image_labels.label.unique()

# %%
train_labels.head(1)

# %%
train_labels.shape

# %%
#Over half have definitive and obvious contact!
train_labels.confidence.value_counts()

# %%
#almost 2/3 are visible
train_labels.visibility.value_counts()

# %%
# 0.25% of the frames have impact -- so can we discard most of the frames provided?
(train_labels.impact.sum() / train_labels.shape[0])*100

# %%
image_path = input_path/'images'
len(os.listdir(image_path)), os.listdir(image_path)[:5]

# %%
one_img_path = os.listdir(image_path)[0]
img = Image.open(image_path/one_img_path)
img

# %%
img_arr = np.array(img)
img_arr.shape

# %% [markdown]
# So we have 120 mp4 clips

# %%
train_path = input_path/'train'
len(os.listdir(train_path)), os.listdir(train_path)[:5]

# %%
from IPython.display import Video
display(Video(str(train_path/os.listdir(train_path)[12]), embed=True, width=500, height=300))
