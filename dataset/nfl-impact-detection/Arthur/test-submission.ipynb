# %%
import pandas as pd

#datadf = pd.read_csv('../input/sample/submission (7).csv')

rawdata = {'gameKey': [57995], 'playID': [109], 'view': ['Endzone'], 'video': ['57995_000109_Endzone.mp4'], 'frame': [41], 
        'left': [913], 'width': [24], 'top': [285], 'height': [21]}
datadf = pd.DataFrame(data=rawdata)
#datadf.to_csv('submission.csv')
print(datadf)

# %%
import os, sys
sys.path.append('../input/nfl-impact-detection/nflimpact')

# %%
import nflimpact
env = nflimpact.make_env()

# %%
env.predict(datadf)
