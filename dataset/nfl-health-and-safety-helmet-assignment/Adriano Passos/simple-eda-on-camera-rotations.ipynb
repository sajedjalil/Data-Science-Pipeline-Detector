# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rotations = pd.read_csv('../input/nlf-helmet-safety-camera-rotations/NFL-rotations-plays.csv').set_index('play')
rotations.head()

# %%
rotations['Sideline'].value_counts().plot.pie();

# %%
rotations['Endzone'].value_counts().plot.pie();
