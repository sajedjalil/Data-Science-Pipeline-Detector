# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %pip install -qr yolov5/requirements.txt  # install
# %pip install --upgrade -q wandb

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
from PIL import Image

import os
import torch
import wandb
from IPython.core.display import Video, display

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
wandb_api = user_secrets.get_secret("wandb_api")

# %%
wandb.login(key=wandb_api)

# %%
# %%writefile config.yaml
# # train and val data as 1) directory: path/images/, 2) file: path/images.txt, or 3) list: [path1/images/, path2/images/]
# train: ../input/nfl-2021-helmet-dataset/train_yolo
# val: ../input/nfl-2021-helmet-dataset/val_yolo
#
# # number of classes
# nc: 1
#
# # class names
# names: ['helmet']

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 5 --data config.yaml --weights yolov5m.pt --device 0 --project train_helmet --cache
