# %%
import os
 
n_test_videos = len(os.listdir('../input/nfl-health-and-safety-helmet-assignment/test/'))
PRIVATE = n_test_videos > 6

if PRIVATE:
    assert 1 == 0
else:
    # !cp ../input/nfl-health-and-safety-helmet-assignment/sample_submission.csv submission.csv
