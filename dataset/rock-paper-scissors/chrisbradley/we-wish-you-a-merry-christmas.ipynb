# %% [markdown]
# **agent we wish you a merry christmas**

# %%
# %%writefile 'agent_wwyamc.py'
#
# # agent wwyamc
# def agent_wwyamc(obs, config):
#
#     wwyamc = 'we wish you a merry christmas' # and a happy new year!
#     return (ord(wwyamc.replace(' ','')[obs['step']%len(wwyamc.replace(' ',''))])-ord('a')) % 3
