# %% [markdown]
# # **NFL 2018 Season - Passing Plays - Defense**
# Terry Carpenter
#
# **Competion Overview**
# >"The goal of this submission is to identify unique and impactful approaches to measure defensive performance on passing plays during the 2018 NFL season."

# %% [markdown]
# **My Approach**
#
# To consider the audience of this notebook to be a defensive coach that is looking for ways to help his team get better at pass protection. The plan is to allow said coach to get statistics on pass plays only for the 2018 NFL season in the following order:
# 1. League Statistics
# 2. Team Statistics for the Season
# 3. Team Statistics for a Specific Game
# 4. Team Statistics for a Particular Play

# %% [markdown]
# **1. League Statistics**
#
# Statistical data to consider for pass protection for the entire league is...
# 1. Compare the number of passing touch downs allowed per team
# 2. Compare the total passing yards allowed per team
# 3. Compare the total number of completions allowed per team
# 4. Compare the total number of pass attempts allowed per team
# 5. Compare the pass completion ratio allowed per team
# 6. Compare the number of passes allowed over       50    yards per team
# 7. Compare the number of passes allowed between 40 to 49 yards per team
# 8. Compare the number of passes allowed between 30 to 39 yards per team
# 9. Compare the number of passes allowed between 20 to 29 yards per team
# 10. Compare the number of passes allowed between 10 to 19 yards per team
# 11. Compare the number of passes allowed between  0 to  9 yards per team
# 12. Compare the number of passes with            negative yards per team
# 13. Compare the average yards per completion per team
# 14. Compare the average tightness of coverage per team

# %% [markdown]
# **2. Team Statistics for the Season**

# %%
from IPython.display import Image
Image(filename = "../input/images/NFL_32_TeamsLogos.PNG", width = 2000)

# %%
import ipywidgets as widgets

print("Select a team...")
widgets.Select(
    options=[' 1. Buffalo Bills    ', ' 2. Miami Dolphins    ', ' 3. New England Patriots', ' 4. New York Jets       ',
             ' 5. Baltimore Ravens ', ' 6. Cincinnati Bengals', ' 7. Cleveland Browns    ', ' 8. Pittsburg Steelers  ',
             ' 9. Houston Texans   ', '10. Baltimore Colts   ', '11. Jacksonville Jaguars', '12. Tennessee Titans    ',
             '13. Denver Broncos   ', '14. Kansas City Chiefs', '15. Oakland Raders      ', '16. Los Angeles Chargers',
             '17. Dallas Cowboys   ', '18. New York Giants   ', '19. Philadelphia Eagles ', '20. Washington Redskins ',
             '21. Chicago Bears    ', '22. Detroit Lions     ', '23. Green Bay Packers   ', '24. Minnesota Vikings   ',
             '25. Atlanta Falcons  ', '26. Carolina Panthers ', '27. New Orleans Saints  ', '28. Tampa Bay Buccaneers',
             '29. Arizona Cardinals', '30. Los Angeles Rams  ', '31. San Francisco 49ers ', '32. Seattle Seahawks    '],
    value=' 1. Buffalo Bills    ',
    rows=1,
    description='NFL Teams:',
    disabled=False
)

# %%
# Supplied CODE HERE --------------------------------------------------------------------------------------------------------------------------------
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory


#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

from PIL import Image
import matplotlib.pyplot as plt

# !ls '../input/images'

img_array2 = np.array(Image.open('../input/images/32TeamLockup_Field_2015-1024x472.png'))
plt.imshow(img_array2)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Supplied CODE HERE --------------------------------------------------------------------------------------------------------------------------------

#Looking for sample submission file, these kaggle rats are hiding it from me!!!
for dirname, _, filenames in os.walk('/kaggle'):
    for filename in filenames:
        full_filename = os.path.join(dirname, filename)
        print(full_filename)
        st = os.stat(full_filename)
        print("file_size = ")
        print(st.st_size)

print(" \r\nI'm learning how to use Python!\r\n")
#print("--------ipynb-----------------")
#f = open("/kaggle/working/__notebook_source__.ipynb", "r")
#for x in range(24):
#    print(f.readline())    
#f.close()

print("--------Plays-----------------")
f = open("/kaggle/input/nfl-big-data-bowl-2021/plays.csv", "r")
print(f.readline())
print(f.readline())
print(f.readline())
f.close()
print("--------Games-----------------")
f = open("/kaggle/input/nfl-big-data-bowl-2021/games.csv", "r")
print(f.readline())
print(f.readline())
print(f.readline())
f.close()
print("--------Players-----------------")
f = open("/kaggle/input/nfl-big-data-bowl-2021/players.csv", "r")
print(f.readline())
print(f.readline())
print(f.readline())
f.close()

print("--------Week1---------------------------------------------------------------")
print("--------Data read from one file and written to another file-----------------")
#read from this file
nfl_file = open("/kaggle/input/nfl-big-data-bowl-2021/week1.csv", "r")

#write to this file
my_file = open("//kaggle/working/my_week1.csv", "a")
in_line = nfl_file.readline()
my_file.write(in_line)

#Read and write traking data for twenty two players on the field at one time, maybe?
for x in range(24):
    in_line = nfl_file.readline()
    my_file.write(in_line)

print("-------------------------")
nfl_file.close()
my_file.close()

print(" I'm making my first summit of a notebook... Here goes nothing...")

print(" Submit failed with status code 500.")
print(" I guess this means something to someone?")
print(" NOT ME!!!")

print("Python Notebook cursor location")
