# %%
import pandas as pd
batch_0=pd.read_csv('../input/batch-0-job-report-for-new-prod-records/batchreport.csv')
batch_0.head()

# %%
batch_1=pd.read_csv('../input/batch-1-job-report-for-new-prod-records/batchreport.csv')
batch_1.head()

# %%
batch_2=pd.read_csv('../input/batch-2-job-report-for-new-prod-records/batchreport.csv')
batch_2.head()

# %%
batch_3=pd.read_csv('../input/batch-3-job-report-for-new-prod-record/batchreport.csv')
batch_3.head()

# %%
batch_4=pd.read_csv('../input/batch-4-job-report-for-new-prod-records/batchreport.csv')
batch_4.head()

# %%
batch_5=pd.read_csv('../input/batch-5-job-report-for-new-prod-records/batchreport.csv')
batch_5.head()

# %%
batch_6=pd.read_csv('../input/batch-6-job-report-for-new-prod-records/batchreport.csv')
batch_6.head()

# %%
batch_7=pd.read_csv('../input/batch-7-job-report-for-new-prod-records/batchreport.csv')
batch_7.head()

# %%
batch_8=pd.read_csv('../input/batch-8-job-report-for-new-prod-records/batchreport.csv')
batch_8.head()

# %%
batch_9=pd.read_csv('../input/batch-9-job-report-for-new-prod-records/batchreport.csv')
batch_9.head()

# %%
batch_10=pd.read_csv('../input/batch-10-job-report-for-new-prod-records/batchreport.csv')
batch_10.head()

# %%
batch_11=pd.read_csv('../input/batch-11-job-report-for-new-prod-records/batchreport.csv')
batch_11.head()

# %%
batch_12=pd.read_csv('../input/batch-12-job-report-for-new-prod-records/batchreport.csv')
batch_12.head()

# %%
batch_13=pd.read_csv('../input/batch-13-job-report-for-new-prod-records/batchreport.csv')
batch_13.head()

# %%
batch_14=pd.read_csv('../input/batch-14-job-report-for-new-prod-records/batchreport.csv')
batch_14.head()

# %%
batch_15=pd.read_csv('../input/batch-15-job-report-for-new-prod-records/batchreport.csv')
batch_15.head()

# %%
batch_16=pd.read_csv('../input/batch-16-job-report-for-new-prod-records/batchreport.csv')
batch_16.head()

# %%
batch_17=pd.read_csv('../input/batch-17-job-report-for-new-prod-records/batchreport.csv')
batch_17.head()

# %%
batch_18=pd.read_csv('../input/batch-18-job-report-for-new-prod-records/batchreport.csv')
batch_18.head()

# %%
batch_19=pd.read_csv('../input/batch-19-job-report-for-new-prod-records/batchreport.csv')
batch_19.head()

# %%
batch_20=pd.read_csv('../input/batch-20-job-report-for-new-prod-records/batchreport.csv')
batch_20.head()

# %%
batch_21=pd.read_csv('../input/batch-21-job-report-for-new-prod-records/batchreport.csv')
batch_21.head()

# %%
batch_22=pd.read_csv('../input/batch-22-job-report-for-new-prod-records/batchreport.csv')
batch_22.head()

# %%
batch_23=pd.read_csv('../input/batch-23-job-report-for-new-prod-records/batchreport.csv')
batch_23.head()

# %%
batch_24=pd.read_csv('../input/batch-24-job-report-for-new-prod-records/batchreport.csv')
batch_24.head()

# %%
batch_25=pd.read_csv('../input/batch-25-job-report-for-new-prod-records/batchreport.csv')
batch_25.head()

# %%
batch_26=pd.read_csv('../input/batch-26-job-report-for-new-prod-records/batchreport.csv')
batch_26.head()

# %%
batch_27=pd.read_csv('../input/batch-27-job-report-for-new-prod-records/batchreport.csv')
batch_27.head()

# %%
batch_28=pd.read_csv('../input/batch-28-job-report-for-new-prod-records/batchreport.csv')
batch_28.head()

# %%
batch_29=pd.read_csv('../input/batch-29-job-report-for-new-prod-records/batchreport.csv')
batch_29.head()

# %%
batch_30=pd.read_csv('../input/batch-30-job-report-for-new-prod-records/batchreport.csv')
batch_30.head()

# %%
batch_31=pd.read_csv('../input/batch-31-job-report-for-new-prod-records/batchreport.csv')
batch_31.head()

# %%
batch_32=pd.read_csv('../input/batch-32-job-report-for-new-prod-records/batchreport.csv')
batch_32.head()

# %%
batch_33=pd.read_csv('../input/batch-33-job-report-for-new-prod-records/batchreport.csv')
batch_33.head()

# %%
batch_34=pd.read_csv('../input/batch-34-job-report-for-new-prod-records/batchreport.csv')
batch_34.head()

# %%
batch_35=pd.read_csv('../input/batch-35-job-report-for-new-prod-records/batchreport.csv')
batch_35.head()

# %%
batch_36=pd.read_csv('../input/batch-36-job-report-for-new-prod-records/batchreport.csv')
batch_36.head()

# %%
batch_37=pd.read_csv('../input/batch-37-job-report-for-new-prod-records/batchreport.csv')
batch_37.head()

# %%
batch_38=pd.read_csv('../input/batch-38-job-report-for-new-prod-records/batchreport.csv')
batch_38.head()

# %%
batch_39=pd.read_csv('../input/batch-39-job-report-for-new-prod-records/batchreport.csv')
batch_39.head()

# %%
batch_40=pd.read_csv('../input/batch-40-job-report-for-new-prod-records/batchreport.csv')
batch_40.head()

# %%
batch_41=pd.read_csv('../input/batch-41-job-report-for-new-prod-records/batchreport.csv')
batch_41.head()

# %%
batch_42=pd.read_csv('../input/batch-42-job-report-for-new-prod-records/batchreport.csv')
batch_42.head()

# %%
batch_43=pd.read_csv('../input/batch-43-job-report-for-new-prod-records/batchreport.csv')
batch_43.head()

# %%
batch_44=pd.read_csv('../input/batch-44-job-report-for-new-prod-records/batchreport.csv')
batch_44.head()

# %%
batch_45=pd.read_csv('../input/batch-45-job-report-for-new-prod-records/batchreport.csv')
batch_45.head()

# %%
frames = [batch_0,batch_1,batch_2,batch_3,batch_4,
         batch_5,batch_6,batch_7,batch_8,batch_9,
         batch_10,batch_11,batch_12,batch_13,batch_14,
         batch_15,batch_16,batch_17,batch_18,batch_19,
         batch_20,batch_21,batch_22,batch_23,batch_24,
         batch_25,batch_26,batch_27,batch_28,batch_29,
         batch_30,batch_31,batch_32,batch_33,batch_34,
         batch_35,batch_36,batch_37,batch_38,batch_39,
         batch_40,batch_41,batch_42,batch_43,batch_44,
         batch_45]
#pd.options.display.float_format = '{:.0f}'.format 
result = pd.concat(frames)
result.head()

# %%
result['click'].value_counts()

# %%
round(result['click'].value_counts()*100/len(result),2)

# %%
result.head()

# %%
result.id=result.id.astype('uint64')
result.head()

# %%
result.to_csv("./FinalReport.csv",index=False)
