# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Exploratory Data Analysis

# %%
permutations = pd.read_csv('/kaggle/input/santa-2021/permutations.csv')
distance_matrix = pd.read_csv('/kaggle/input/santa-2021/distance_matrix.csv')
wildcards = pd.read_csv('/kaggle/input/santa-2021/wildcards.csv')
sample_submission = pd.read_csv('/kaggle/input/santa-2021/sample_submission.csv')

# %%
permutations

# %%
distance_matrix

# %%
distance_matrix.shape

# %%
wildcards

# %%
sample_submission

# %%
print('The number of elements in the schedule: {}.'.format(len(sample_submission.iloc[0 , 0])))
print('The number of elements in the schedule: {}.'.format(len(sample_submission.iloc[1 , 0])))
print('The number of elements in the schedule: {}.'.format(len(sample_submission.iloc[2 , 0])))

# %% [markdown]
# # Permutation

# %%
import itertools

print("Elements' permutations: {}\nNumber of permutations: {}\n"
      .format(list(itertools.permutations([1, 2, 3])), len(list(itertools.permutations([1, 2, 3])))))
print("Elements' permutations: {}\nNumber of permutations: {}\n"
      .format(list(itertools.permutations([1, 2, 3], 2)), len(list(itertools.permutations([1, 2, 3], 2)))))
print("Elements' permutations: {}\nNumber of permutations: {}"
      .format(list(itertools.permutations([1, 2, 3], 1)), len(list(itertools.permutations([1, 2, 3], 1)))))

# %%
comm =permutations[permutations.Permutation.str[:2] =='🎅🤶']
comm

# %%
other =permutations[permutations.Permutation.str[:2] !='🎅🤶'].reset_index(drop=True)
other

# %%
a=comm.copy()
b=comm.copy()
c=comm.copy()
for i in range(len(other)):
    if i%3 ==0:
        a = a.append(other.iloc[i],ignore_index=True)
    if i%3 ==1:
        b = b.append(other.iloc[i],ignore_index=True)
    if i%3 ==2:
        c = c.append(other.iloc[i],ignore_index=True)
        
aa =str()
bb =str()
cc =str()
for i in a.Permutation.values:
    aa +=i

for i in b.Permutation.values:
    bb +=i
for i in c.Permutation.values:
    cc +=i
    
    
sample_submission.loc[0,'schedule'] = aa
sample_submission.loc[1,'schedule'] = bb
sample_submission.loc[2,'schedule'] = cc

# %%
print(len(sample_submission.loc[0,'schedule']))
print(len(sample_submission.loc[1,'schedule']))
print(len(sample_submission.loc[2,'schedule']))

# %%
comm_check =str()
for i in comm.Permutation.values:
    comm_check +=i
comm_check

# %%
other_check =str()
for i in other.Permutation.values:
    other_check +=i
len(other_check)

# %%
len(comm_check)

# %%
for r in range(int(len(other_check)/7)):
    x = r*7
    #for i in range(len(comm_check)-7):
    if comm_check.find(other_check[x:x+7])== True:
            print('find',x)
    else:
            comm_check +=other_check[x:x+7]
    #if x%100 ==0:
    #    print(x)

# %%
len(comm_check)

# %%
data = permutations.Permutation.to_list()
print(data[:10])
print(len(data))

# %%
all_check =str(data.pop(int(np.random.rand()*len(data))))
print(all_check)
print(len(data))

# %%
pattern_list = list(itertools.permutations(range(7),7))
pattern_list[0:3]

# %%
pattern = pd.DataFrame()
pattern['permutation'] = pattern_list.copy()
pattern['permutation'] = pattern['permutation'].apply(lambda x: str(x[0])+str(x[1])+str(x[2])+str(x[3])+str(x[4])+str(x[5])+str(x[6]))
pattern

# %%
len(pattern.permutation.unique())

# %%
pattern =pattern[pattern['permutation'].str[:2] !='01'].reset_index(drop=True)
pattern

# %%
a = str()
for i in range(len(pattern)):
    a+=str(pattern.permutation.values[i])
len(a)

# %%
comm = pd.DataFrame()
comm['permutation'] = pattern_list.copy()
comm['permutation'] = comm['permutation'].apply(lambda x: str(x[0])+str(x[1])+str(x[2])+str(x[3])+str(x[4])+str(x[5])+str(x[6]))
comm = comm[comm['permutation'].str[:2] =='01'].reset_index(drop=True)
comm

# %%
pattern

# %%
a = str()
for i in range(len(pattern)):
    a+=str(pattern.permutation.values[i])
len(a)

# %%
comm = pd.DataFrame()
comm['permutation'] = pattern_list.copy()
comm['permutation'] = comm['permutation'].apply(lambda x: str(x[0])+str(x[1])+str(x[2])+str(x[3])+str(x[4])+str(x[5])+str(x[6]))
comm = comm[comm['permutation'].str[:2] =='01'].reset_index(drop=True)
comm
