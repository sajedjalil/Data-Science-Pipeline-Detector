# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import math
from textwrap import wrap
warnings.filterwarnings('ignore')
sns.set_palette('Set2')
sns.set_style('darkgrid')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #DC143C;"><b style="color:darkgreen;">Santa is coming to Kaggle!</b></h1></center>

# %% [markdown]
# <iframe width="956" height="538" src="https://www.youtube.com/embed/zYneDzAnlVc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# #Mean Girsl Dance https://www.youtube.com/watch?v=zYneDzAnlVc

# %% [markdown]
# #The majority of Kagglers are men. Hence, let's they do the "Mean girls dance" too. Men do that in the ancient Greece.

# %%
#Matrix will be df

df = pd.read_csv('../input/santa-2021/distance_matrix.csv', encoding='utf8')
df.head()

# %%
df.columns.tolist()

# %%
sum=df['Permutation'].str.len()
print(sum)

# %%
# let's check the length of name, the average length is 20 characters.
df['Permutation length'] = df['Permutation'].apply(len)
df['Permutation length'].describe()

# %%
sns.boxplot(x='🎅🤶🦌🧝🎄🎀🎁', y=df['Permutation length'], data=df);

# %%
s = (df.isna().sum()/df.shape[0]*100)<50
df_modified = df[s.index[s].tolist()]
print (df_modified.shape)
df_modified.head()

# %%
plt.rcParams['font.size'] = 14
fig, ax = plt.subplots(3, 2, figsize=(20,20))
for col, ax in zip(['Permutation','🎅🤶🦌🧝🎄🎁🎀'], ax.flat):
    dict_ = df_modified[col].value_counts().head(10).to_dict()
    if ('Not Available' in dict_.keys()):
        dict_.pop('Not Available')
    labels = []
    for i in dict_.keys():
        i = i.split(' ')
        if (len(i) > 6):
            i[math.ceil(len(i)/2)-1] += '\n'
            labels.append(' '.join(i))
        else:
            labels.append(' '.join(i))
    ax.pie(x=list(dict_.values()), labels=labels, shadow=True, startangle=0)
    
    col = (' '.join(col.split('_'))).upper()
    ax.set_title(col, weight='bold', fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# #It seems that I've been a mean girl (woman or whatever I want to be) and Santa won't deliver my gift.

# %%
#Code by Savita Nair https://www.kaggle.com/savitanair/hr-analytics

print(f'Dataset has {len(df.Permutation.unique())} unique Permutations')
print('*'*20)
print(f'And the top 10 Permutations are :')
print(df.Permutation.value_counts().head(10))
print('*'*20)

c = df.Permutation.value_counts().head(10)
fig, ax = plt.subplots(1,1,figsize=(12,6))
ax.bar(c.index, c.values, width=0.8, color='y')
plt.xticks(rotation=45)

# %%
# !pip install emot

# %% [markdown]
# #Emot doesn't work any more

# %%
df["🎅🤶🦌🧝🎄🎁🎀"].value_counts()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["🎅🤶🦌🧝🎄🎁🎀"].value_counts().plot.bar(color= 'red', title='Santas 2021');

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["🎀🎁🎄🧝🦌🤶🎅"].value_counts().plot.bar(color= 'green', title='Santas 2021');

# %% [markdown]
# #Isn't it almost the same in green?

# %%
cards = pd.read_csv('../input/santa-2021/wildcards.csv', encoding='utf8')
cards.head()

# %%
permutations = pd.read_csv('../input/santa-2021/wildcards.csv', encoding='utf8')
permutations.head()

# %%
sub = pd.read_csv('../input/santa-2021/sample_submission.csv', encoding='utf8')
sub.head()

# %%
#scatterplot
sns.set(palette = 'deep')
cols = ['Permutation', '🎅🤶🦌🧝🎄🎁🎀', '🎅🤶🦌🧝🎁🎀🎄', '🎅🤶🦌🎄🧝🎁🎀', '🎀🎁🎄🦌🧝🤶🎅', '🎀🎁🎄🧝🤶🎅🦌', '🎀🎁🎄🧝🤶🦌🎅', '🎀🎁🎄🧝🦌🤶🎅']
sns.pairplot(df[cols], height = 2.5)
plt.show();

# %% [markdown]
# #That pairplot was not very useful (from my point of view)

# %%
# !pip install klib

# %%
import sys

sys.path.append('../input/klib-library-python')

# %%
import klib

# %%
klib.missingval_plot(df)

# %% [markdown]
# #Cleaning will take some time.

# %%
df_cleaned = klib.data_cleaning(df)

# %%
df_cleaned.columns.tolist()

# %% [markdown]
# #Now permutation column changed to lower case. (after cleaning)

# %%
klib.dist_plot(df_cleaned['🎅🤶🦌🧝🎄🎁🎀']);

# %% [markdown]
# #Different columns though the chart is the same below?

# %%
klib.dist_plot(df_cleaned['🎀🎁🎄🧝🤶🎅🦌']);

# %% [markdown]
# #Top 10 Best On-Screen Santas, Ranked
#
# "Though Gremlins is certainly wrapped up in some Christmas imagery, we can’t forget that the entire movie is essentially about monsters—not your typical Christmas theme—rather than about Christmas itself."
#
# https://www.regmovies.com/static/en/us/blog/gremlins-christmas-movie-or-not
#
# ![](https://www.freefilmfestivals.org/wp-content/uploads/2017/11/Gremlins-Christmas-Poster-09.jpg)freefilmfestivals.org

# %% [markdown]
# #Watch out because Gremlins seem (as those Santas emojis) to be cute, though they can bring us some unexpected surprise.

# %% [markdown]
# <iframe width="1046" height="438" src="https://www.youtube.com/embed/NzEX3QMuVPM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# #For KING & COUNTRY - Little Drummer Boy (Official Music Video) https://www.youtube.com/watch?v=NzEX3QMuVPM
#
# To honor the drummer in Kaggle Team (just like in my last Santas Notebook)
