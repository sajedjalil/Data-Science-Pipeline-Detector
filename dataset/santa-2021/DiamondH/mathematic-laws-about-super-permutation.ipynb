# %% [markdown]
# Sorry for the last nootbook,so many mistakes,It's 5.am where i live,really tiered,brain at low level.

# %% [markdown]
# So these are parts of my conclusions.
# For the news to better understand this Competition,
# and also for these on the leaderbord to get a bettle solution.

# %% [markdown]
# I'm just a junior,really practicing coding Seldomly,hoping someone to help me get me further in this competition,good Teammates are needed.

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('../input/super-permutation-solution-based-on-math/IMG_1480.JPG')
plt.figure(figsize=(10,8),dpi=200)
plt.imshow(img)
plt.axis('off')

# %% [markdown]
# If you find it Interesting ,please do upvote it.Good luck!
