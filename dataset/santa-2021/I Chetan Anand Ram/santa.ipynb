# %% [markdown]
# # imports

# %%
import numpy as np
import pandas as pd
import os
import random

# %% [markdown]
# # reading, changing

# %%
pem = pd.read_csv('../input/santa-data/submission.csv')
spem = pem.replace("🎅🎀🤶", "🤶")
print(spem)

# %% [markdown]
# # submiting to kaggle

# %%
spem.to_csv('submission.csv', index=False)
