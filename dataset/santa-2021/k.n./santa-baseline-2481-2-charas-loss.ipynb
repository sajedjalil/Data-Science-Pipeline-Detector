# %%
# This notebook is copy of https://www.kaggle.com/ks2019/santa-baseline-2481
# I fround 2 characters loss

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../input/santa-baseline-2481/submission.csv')
for i in range(3):
    print(df.loc[i][0][2200:2206])

# %%
for i in range(3):
    df.loc[i][0] = df.loc[i][0].replace('🎅🤶🎅🤶', '🎅🤶')

# %% [markdown]
# ## Submission

# %%
df.to_csv('submission.csv',index=False)
df.head()
