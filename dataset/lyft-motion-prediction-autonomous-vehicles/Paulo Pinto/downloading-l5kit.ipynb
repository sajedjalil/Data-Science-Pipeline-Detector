# %%
# Downloading and installing PIP upgrade
# !pip install --upgrade pip==20.2.2
# !pip download -d /kaggle/working pip==20.2.2

# %%
# Downloading all requirements to l5kit
# !pip wheel -w /kaggle/working -f /kaggle/working pymap3d==2.1.0
# !pip wheel -w /kaggle/working transforms3d==0.3.1
# !pip wheel --prefer-binary -w /kaggle/working -f /kaggle/working l5kit
