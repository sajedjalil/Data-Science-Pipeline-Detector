# %%
import pandas as pd

# %%
sub = pd.read_csv("../input/lyft-complete-train-and-prediction-pipeline/submission.csv")
# sub["track_id"] = 0 #### Original score is  23.622 !!!
sub = sub.sample(frac=1.0).reset_index(drop=True) #### Original score is  23.622 !!!
sub.to_csv("submission.csv", index=False, float_format='%.6g')
