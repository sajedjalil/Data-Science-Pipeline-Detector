# %% [markdown]
# # The Wide Mouth
#
# Hue Hue Owl
#
# Why Why Owl
#
# Wow Wow Owl
#
# Wah~ Air In

# %% [markdown]
# # The Reverse Dunning Krugar

# %% [markdown]
# Use illustrator to highlight (softlight), label (scramble), and jamboard (no white) your work.
#
# The reverse dunning krugar is showing how 40% is the top 5%. Let's balance the property tax.
#
# You should stand up, give up birds, and eat a dozen of boiled eggs. Do not drink water.
#
# Pour a bottle of water to your eyeballs. Do not use AVERYSAD salins. --Kitkat

# %% [markdown]
# import pandas

# %%
import pandas as pd

# %% [markdown]
# read sample submission csv

# %%
pd.read_csv('../input/AI4Code/sample_submission.csv')

# %% [markdown]
# read test 0009d135ece78d json

# %%
testjson = pd.read_json('../input/AI4Code/test/0009d135ece78d.json')
testjson

# %% [markdown]
# # Schimitt Schumatt Schumann

# %% [markdown]
# zero vector: the vector
#
# zero index: any non zero raised to the power 0
#
# option 1: goats + the bird + goats
#
# 1 + 1 + 1
#
# 2 + 2 + 2
#
# 4 + 4
#
# 16
#
# 1
