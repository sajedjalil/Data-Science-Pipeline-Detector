# %% [markdown]
# # Test The Logic Explosion Crank [+] [%] [-] [x]

# %%
# cell | type | command | test | json.0009d135ece78d
import pandas
test1 = pandas.read_json('../input/AI4Code/test/0009d135ece78d.json')
test1.head(3)

# %%
# cell | type | command | test | json.0010483c12ba9b
import pandas
test1 = pandas.read_json('../input/AI4Code/test/0010483c12ba9b.json')
test1.head(3)

# %%
# cell | type | command | test | json.0010a919d60e4f
import pandas
test1 = pandas.read_json('../input/AI4Code/test/0010a919d60e4f.json')
test1.head(3)

# %%
# cell | type | command | test | json.0028856e09c5b7
import pandas
test1 = pandas.read_json('../input/AI4Code/test/0028856e09c5b7.json')
test1.head(3)

# %% [markdown]
# # Train The Field Direction Track [ψ] [υ] [/] [ή]

# %% [markdown]
# Element. Union. Curve Subset. Brightness. https://www.soulpurse.com/

# %%
import pandas
test1 = pandas.read_json('../input/AI4Code/train/00001756c60be8.json')
test1.head(3)

# %%
import pandas
test1 = pandas.read_json('../input/AI4Code/train/00015c83e2717b.json')
test1.head(3)
