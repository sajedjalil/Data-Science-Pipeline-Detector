# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_colwidth', None)

order = pd.read_csv("../input/AI4Code/train_orders.csv")
order.iloc[[0]]

# %% [markdown]
# all is just to store the data in a fancy way

# %%
str = order.id[0]
mir = str[-7:] + " " + str[:7]
from itertools import permutations
[" ".join(combo) for combo in\
    permutations (mir.split(), 2)]

# %% [markdown]
# all you need to do is be there and hold a whiteout, supress some population with a sharpie

# %%
str = order.id[1]
mir = str[-7:] + " " + str[:7]
from itertools import permutations
[" ".join(combo) for combo in\
    permutations (mir.split(), 2)]

# %% [markdown]
# are you looking for a highlighter?

# %%
order = pd.read_csv("../input/AI4Code/train_orders.csv")
order.iloc[[1]]

# %% [markdown]
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# DAL-505 Sweeter
#
# 1. Data: Marathon. Bikerace. Heart. Workers.
# 2. Infograph: Nike. Carshare. Downtown. Mango.
# 3. Know: Hearts. 1min. Apartment. Break.
# 4. Wisdom: The worker. 8hrs. Lactose. Chocolate.
# 5. AI: The steak. Nuts. Father. Hifive. The hotel.
#
# Face the red carpet. Introduce smoke, beer, and handgun tax. You must have those markets. For workers: Kitkat? Sneakers.

# %% [markdown]
# Visit: Reliance, Mumbai

# %% [markdown]
# $3.50 Kitkat
#
# $4 hot water noodle
#
# a habit political airline
#
# tend to be on one side
#
# the US attitude to
#
# the US calculation to
#
# driven by the people
#
# most of them armed
#
# is the defence
#
# self+
#
# state+
#
# the ability to
#
# suppress own freedom
#
# the horizontal ownership
#
# the vertical trigonometry
#
# the depth crystal
#
# the diamond
#
# what human is
#
# really good at
#
# it is what you
#
# really good at
#
# less than 1 degree error
#
# what are you waiting for?
#
# vector you vector
