# %% [markdown]
# # Regression Crank
#
# Previously, DogCatHam.
#
# What does your UV pigments say about this flower?

# %%
import matplotlib.pyplot as pyplot
import numpy as np
regression = np.array([3, 6, 9, 12, 15])
pyplot.plot([5, 5, 10, 10, 10])
pyplot.plot([7, 7, 13, 13, 13])
pyplot.plot(regression)

# %%
# train | id | 00001756c60be8
import pandas
train1 = pandas.read_json('../input/AI4Code/train/00001756c60be8.json')
train1.to_csv('train1.csv')
print(train1)
