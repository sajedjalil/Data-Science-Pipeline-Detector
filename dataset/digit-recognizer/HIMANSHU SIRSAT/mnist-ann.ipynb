# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("../input/digit-recognizer/train.csv")
df

# %%
X_=df.drop(["label"],axis=1)
y_=df["label"]

# %%
X1=X_.to_numpy()
y1=y_.to_numpy()

# %%
#X=X1.reshape(28,28)
#y=y1

# %% [markdown]
# # Data Exploration

# %%
X*=X1[56].reshape(28,28)
plt.imshow(X)

# %% [markdown]
# # splitting data

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test=train_test_split(X1,y1,train_size=0.8)

# %% [markdown]
# # First using ANN model

# %%
import tensorflow as tf
import keras
from tensorflow.keras import layers, models

# %%
ann=keras.Sequential([
                     keras.layers.Flatten(input_shape=(784,)),
                     layers.Dense(3000,activation="relu"),
                     layers.Dense(1800,activation="relu"),
                     layers.Dense(10,activation="sigmoid")


]
)

# %%
ann.compile(
            optimizer = "adam",
            loss ="sparse_categorical_crossentropy",
            metrics =["accuracy"]

)

ann.fit(X1,y1,epochs=3)

# %%
w=ann.predict(X_test)
pred=np.argmax(w,axis=1)
pred

# %%
tst=pd.read_csv("../input/digit-recognizer/test.csv")
tst

# %%
res=ann.predict(tst)
argmx=np.argmax(res,axis=1)
rest=pd.DataFrame(argmx,columns=["Label"])
rest

# %%
sample=pd.read_csv("../input/digit-recognizer/sample_submission.csv")
submission=sample.drop(["Label"],axis=1)
submission

# %%
submission=pd.concat([submission,rest],axis=1)
submission

# %%
submission.to_csv("submission.csv",index=False)

# %%
# !kaggle competitions submit -c digit-recognizer -f submission.csv -m "Message"
