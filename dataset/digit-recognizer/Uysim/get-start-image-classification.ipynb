# %% [markdown]
# # Import libraries

# %%
# Disable warning
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
print(os.listdir("../input"))
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
FAST_RUN=False
batch_size=32
epochs=100
if FAST_RUN:
    epochs=1

# %% [markdown]
# # Import data
# Data input train and test data

# %%
train_data = pd.read_csv("../input/train.csv")
test_data = pd.read_csv("../input/test.csv")

# %% [markdown]
# # Data exploration

# %% [markdown]
# **Columns**

# %%
print(train_data.columns)
# Out:
# Index(['label', 'pixel0', 'pixel1', 'pixel2', 'pixel3', 'pixel4', 'pixel5',
#        'pixel6', 'pixel7', 'pixel8',
#        ...
#        'pixel774', 'pixel775', 'pixel776', 'pixel777', 'pixel778', 'pixel779',
#        'pixel780', 'pixel781', 'pixel782', 'pixel783'],
#       dtype='object', length=785)

# %% [markdown]
# We can see that data have label and other pixels columns. Which label present the digit and pixel present pixel of image

# %% [markdown]
# **Show Image**
# This is how 784 pixels of each row form to be images

# %%
def show_image(train_image, label, index):
    image_shaped = train_image.values.reshape(28,28)
    plt.subplot(3, 6, index+1)
    plt.imshow(image_shaped, cmap=plt.cm.gray)
    plt.title(label)


plt.figure(figsize=(18, 8))
sample_image = train_data.sample(18).reset_index(drop=True)
for index, row in sample_image.iterrows():
    label = row['label']
    image_pixels = row.drop('label')
    show_image(image_pixels, label, index)
plt.tight_layout()

# %% [markdown]
# # Data Preparation
# We split data for test and train

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

x = train_data.drop(columns=['label']).values.reshape(train_data.shape[0],28,28,1)
y = to_categorical(train_data['label'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=10,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)
train_datagen.fit(x_train)
train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size=batch_size
)

validation_datagen = ImageDataGenerator(rescale=1./255)
train_datagen.fit(x_test)
validation_generator = validation_datagen.flow(
    x_test,
    y_test
    
)

# %% [markdown]
# # Build CNN Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

model = Sequential()
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # Compile Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Callbacks

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %% [markdown]
# # Fit model

# %%
model.fit_generator(
    train_generator, 
    steps_per_epoch=len(x_train) // batch_size, 
    validation_data=validation_generator,
    validation_steps=len(x_test) // batch_size,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 1181/1181 [==============================] - 14s 12ms/step - loss: 0.4141 - acc: 0.8730 - val_loss: 0.0973 - val_acc: 0.9704
#
# Epoch 00001: val_loss improved from inf to 0.09727, saving model to model.h5
# Epoch 2/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.1849 - acc: 0.9448 - val_loss: 0.0659 - val_acc: 0.9786
#
# Epoch 00002: val_loss improved from 0.09727 to 0.06588, saving model to model.h5
# Epoch 3/100
# 1181/1181 [==============================] - 12s 11ms/step - loss: 0.1432 - acc: 0.9570 - val_loss: 0.0537 - val_acc: 0.9822
#
# Epoch 00003: val_loss improved from 0.06588 to 0.05374, saving model to model.h5
# Epoch 4/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.1260 - acc: 0.9634 - val_loss: 0.0533 - val_acc: 0.9842
#
# Epoch 00004: val_loss improved from 0.05374 to 0.05333, saving model to model.h5
# Epoch 5/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.1139 - acc: 0.9672 - val_loss: 0.0746 - val_acc: 0.9794
#
# Epoch 00005: val_loss did not improve from 0.05333
# Epoch 6/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.1067 - acc: 0.9686 - val_loss: 0.0574 - val_acc: 0.9827
#
# Epoch 00006: val_loss did not improve from 0.05333
# Epoch 7/100
# 1181/1181 [==============================] - 14s 11ms/step - loss: 0.1040 - acc: 0.9698 - val_loss: 0.0435 - val_acc: 0.9863
#
# Epoch 00007: val_loss improved from 0.05333 to 0.04346, saving model to model.h5
# Epoch 8/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.0961 - acc: 0.9721 - val_loss: 0.0471 - val_acc: 0.9870
#
# Epoch 00008: val_loss did not improve from 0.04346
# Epoch 9/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0949 - acc: 0.9727 - val_loss: 0.0493 - val_acc: 0.9873
#
# Epoch 00009: val_loss did not improve from 0.04346
# Epoch 10/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0926 - acc: 0.9731 - val_loss: 0.0441 - val_acc: 0.9894
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00010: val_loss did not improve from 0.04346
# Epoch 11/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0746 - acc: 0.9777 - val_loss: 0.0401 - val_acc: 0.9899
#
# Epoch 00011: val_loss improved from 0.04346 to 0.04012, saving model to model.h5
# Epoch 12/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0764 - acc: 0.9765 - val_loss: 0.0431 - val_acc: 0.9878
#
# Epoch 00012: val_loss did not improve from 0.04012
# Epoch 13/100
# 1181/1181 [==============================] - 12s 11ms/step - loss: 0.0713 - acc: 0.9785 - val_loss: 0.0396 - val_acc: 0.9887
#
# Epoch 00013: val_loss improved from 0.04012 to 0.03965, saving model to model.h5
# Epoch 14/100
# 1181/1181 [==============================] - 14s 12ms/step - loss: 0.0755 - acc: 0.9775 - val_loss: 0.0499 - val_acc: 0.9878
#
# Epoch 00014: val_loss did not improve from 0.03965
# Epoch 15/100
# 1181/1181 [==============================] - 12s 11ms/step - loss: 0.0733 - acc: 0.9781 - val_loss: 0.0383 - val_acc: 0.9899
#
# Epoch 00015: val_loss improved from 0.03965 to 0.03832, saving model to model.h5
# Epoch 16/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0721 - acc: 0.9790 - val_loss: 0.0371 - val_acc: 0.9885
#
# Epoch 00016: val_loss improved from 0.03832 to 0.03711, saving model to model.h5
# Epoch 17/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.0700 - acc: 0.9791 - val_loss: 0.0460 - val_acc: 0.9875
#
# Epoch 00017: val_loss did not improve from 0.03711
# Epoch 18/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0736 - acc: 0.9785 - val_loss: 0.0436 - val_acc: 0.9885
#
# Epoch 00018: val_loss did not improve from 0.03711
# Epoch 19/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0725 - acc: 0.9790 - val_loss: 0.0401 - val_acc: 0.9894
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00019: val_loss did not improve from 0.03711
# Epoch 20/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.0705 - acc: 0.9797 - val_loss: 0.0387 - val_acc: 0.9887
#
# Epoch 00020: val_loss did not improve from 0.03711
# Epoch 21/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0687 - acc: 0.9806 - val_loss: 0.0410 - val_acc: 0.9880
#
# Epoch 00021: val_loss did not improve from 0.03711
# Epoch 22/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0675 - acc: 0.9800 - val_loss: 0.0400 - val_acc: 0.9914
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00022: val_loss did not improve from 0.03711
# Epoch 23/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0688 - acc: 0.9797 - val_loss: 0.0375 - val_acc: 0.9885
#
# Epoch 00023: val_loss did not improve from 0.03711
# Epoch 24/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0706 - acc: 0.9791 - val_loss: 0.0444 - val_acc: 0.9880
#
# Epoch 00024: val_loss did not improve from 0.03711
# Epoch 25/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0700 - acc: 0.9792 - val_loss: 0.0378 - val_acc: 0.9906
#
# Epoch 00025: val_loss did not improve from 0.03711
# Epoch 26/100
# 1181/1181 [==============================] - 12s 11ms/step - loss: 0.0673 - acc: 0.9804 - val_loss: 0.0417 - val_acc: 0.9882
#
# Epoch 00026: val_loss did not improve from 0.03711
# Epoch 00026: early stopping

# %% [markdown]
# # Evaluate Model

# %%
x_test_recaled = (x_test.astype("float32") / 255)
scores = model.evaluate(x_test_recaled, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("%s: %.2f%%" % (model.metrics_names[0], scores[0]*100))
# Out:
# acc: 98.93%
# loss: 4.06%

# %% [markdown]
# # Prediction

# %%
test_digit_data = test_data.values.reshape(test_data.shape[0],28,28,1).astype("float32") / 255
predictions = model.predict(test_digit_data)
results = np.argmax(predictions, axis = 1)

# %% [markdown]
# ### Set how is our prediction

# %%
plt.figure(figsize=(18, 8))
sample_test = test_data.head(18)
for index, image_pixels in sample_test.iterrows():
    label = results[index]
    show_image(image_pixels, label, index)
plt.tight_layout()

# %% [markdown]
# ### Create submission file

# %%
submissions = pd.read_csv("../input/sample_submission.csv")
submissions['Label'] = results
submissions.to_csv('submission.csv', index = False)

# %% [markdown]
# Next step check [Dog And Cat Image Classification](https://www.kaggle.com/uysimty/keras-cnn-dog-or-cat-classification)
