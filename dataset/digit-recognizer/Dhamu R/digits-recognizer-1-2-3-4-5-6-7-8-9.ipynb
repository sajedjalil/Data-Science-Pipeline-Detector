# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:red;
#             font-size:210%;
#             font-family:cursive;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:white;
#             border-style: solid;
#             border-color: black;
#             text-align:center;">
# <b>
# Hand written Digit-recognizer</b>
# </div>

# %% [markdown]
# <h1><b>1 <span style='color:red;'>|</span> Importing the necessary Libraries</b></h1>
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>1.1 | Names and uses</b></p>
# </div>
# <ul>
#     <li style="font-size:15px"><mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Pandas</b></mark> for handling the data </li>
#     <li style="font-size:15px"><mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Math</b></mark> for doing mathematics </li>
#     <li style="font-size:15px"><mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Matplotlib</b></mark> for visualizing the data</li>
#     <li style="font-size:15px"><mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Numpy</b></mark> for creating and handling the array</li>
#     <li style="font-size:15px">Kfolds giving you an accuracy score for each fold <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b> cross_val_score</b></mark></li>
#     <li style="font-size:15px"> Spliting the data <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>train_test_split</b></mark></li>
#     <li style="font-size:15px">For predictions <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b> RandomForestClasssifier</b></mark></li>
#
# </ul>

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# <h1><b>2 <span style='color:red;'>|</span> Reading the data from csv file</b></h1>
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>2.1 | About the data</b></p>
# </div>
# <ul>
#     <li style="font-size:15px;">It is <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b> 28x28</b></mark> pixel image data </li>
#     <li style="font-size:15px;">Therefore every row contains <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>784</b></mark> columns of numbers </li>
#     <li style="font-size:15px;">28 x 28 = <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b> 784</b></mark> </li>
#     <li style="font-size:15px;">Convert 1d data to <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>2d array</b></mark>  to Visualize the data </li>
#     </ul>

# %%
df = pd.read_csv('../input/digit-recognizer/train.csv')
df.head()

# %%
x = df.drop(['label'],axis=1)
x.head()

# %%
y = df['label']
y

# %% [markdown]
# <h1><b>3 <span style='color:red;'>|</span> Visualize the data as readable formate</b></h1>
# <hr>
# <ul>
# <li style="font-size:15px;"> <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Matplotlib</b></mark> is used to visualize the data</li>
# <li style="font-size:15px;">To visualize multiple data <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>subplot</b></mark> in matplotlib is used</li>
# <li style="font-size:15px;">To visualize unique data count <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>bar chart</b></mark> in matplotlib is used</li>
# <li style="font-size:15px;">To built a  <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>fancy charts</b></mark> using matplotlib <a href="https://www.kaggle.com/dhamur/matplotlib-different-charts">refer</a></li>
#     </ul>
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>3.1 | Extracting single row from the data</b></p>
# </div>

# %%
a = x.iloc[0:1,]
print("Length of columns :",len(a.columns))
print("Square root for length of a.columns",math.sqrt(len(a.columns)))

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>3.2 | Creating the single row data into the 2d array</b></p>
# </div>

# %%
b = np.array(a)
ab = np.reshape(b,(28,28))

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>3.4 |  Data Visualization</b></p>
# </div>

# %%
plt.matshow(ab)
plt.show()

# %%
data = []
for i in range(2,10):
    aa = x.iloc[i-1:i,]
    bb =np.array(aa)
    aabb = np.reshape(bb,(28,28))
    data.append(aabb)
    
fig, ax= plt.subplots(2,4,figsize=(10,5))
for i in range(0,2):
    for j in range(0,4):
        if i==0:
            ax[i,j].matshow(data[j])
        elif i==1:
            ax[i,j].matshow(data[j+4])

# %%
count = pd.DataFrame(df['label'].value_counts()).reset_index()
counts = count.rename(columns={'index':'label','label':'count'})
counts

# %%
plt.figure(figsize=(14,8))
ax = plt.axes()
ax.set_axisbelow(True)

ax.spines['bottom'].set_color('#000000')
ax.spines['top'].set_color('#000000') 
ax.spines['right'].set_color('#000000')
ax.spines['left'].set_color('#000000')

ax.spines['right'].set_linewidth(3)
ax.spines['left'].set_lw(3)
ax.spines['bottom'].set_lw(3)
ax.spines['top'].set_lw(3)

plt.bar(counts['label'],counts['count'], color='#ff5100', label='Salary_1', edgecolor='black')
# hatch='x',linestyle='--'

plt.xlabel('Labels',labelpad=20,loc='center',color='#000000',weight='bold', fontsize=18, fontdict={'family':'cursive'})
plt.ylabel('Count',labelpad=20,loc='center',color='#000000',weight='bold', fontsize=18, fontdict={'family':'cursive'})
plt.title('Bar chart',loc='center',color='#000000',weight='bold', fontsize=30, fontdict={'family':'cursive'},pad=20,fontstyle='italic')
plt.grid(visible=True,axis='both',which='both',color='#a1a1a1',linestyle='-',linewidth=1,mec='#00cefc')
plt.xticks(ticks=counts['label'],fontsize=15,weight='bold')
plt.yticks(fontsize=15,weight='bold')

plt.show()

# %% [markdown]
# <h1><b>4 <span style='color:red;'>|</span> Best Prediction model</b></h1>
# <hr>
# <p style="font-size:16px;"> Find out the best model using <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>K-Fold</b></mark> cross validation method. We can also use <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Decision Tree Classifier</b></mark> and <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Naive bayes</b></mark>. Due to less accuracy score in Decision tree and naive bayes, I used <mark style="background-color:#ff4800;color:white;border-radius:4px;"><br><b>Random Forest Classifier</b></mark> it gives <b>96%</b> accuracy. We can also use <mark style="background-color:#ff4800;color:white;border-radius:4px;"><b>Bagging classifier</b></mark> to make predictions more accurate.</p>
#
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>4.1 | Random Forest Classifier</b></p>
# </div>

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
cross_val_score(RandomForestClassifier(),x,y,cv=5)

# %%
best_model = RandomForestClassifier(n_estimators=100,criterion='entropy')
best_model.fit(x_train,y_train)

# %%
print("Test Score :",best_model.score(x_test,y_test))
print("Sample Score :",best_model.score(x_train,y_train))

# %% [markdown]
# <h1><b>5 <span style='color:red;'>|</span> Test data</b></h1>
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>5.1 | Reading the data</b></p>
# </div>

# %%
test = pd.read_csv('../input/digit-recognizer/test.csv')
test.head()

# %%
test.shape

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#323232;font-size:150%;
#             font-family:Nexa;letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>5.2 | Predictions and output file</b></p>
# </div>

# %%
pre = best_model.predict(test)

# %%
sample = pd.read_csv('../input/digit-recognizer/sample_submission.csv')
sample['Label']=pre
sample.to_csv('out.csv',index=False, header=True)

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:red;
#             font-size:210%;
#             font-family:cursive;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:white;
#             border-style: solid;
#             border-color: black;
#             text-align:center;">
# <b>
# The End</b>
# </div>
