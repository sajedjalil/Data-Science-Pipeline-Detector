# %% [markdown]
# # Dependencies
#
# * [NLTK](https://www.nltk.org/)
# * [Spacy](https://spacy.io/)
# * [CoreNLP](https://stanfordnlp.github.io/CoreNLP/)
# * [Others (toolbox)](https://github.com/amitness/toolbox#NLP)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Data Cleaning
#
#
# Add suggestions for data cleaning here:
# * Check for missing data
# * Check for incorrect symbols
# * Check for typos / syntax errors

# %%
PATH = "/kaggle/input/tweet-sentiment-extraction/"
df_train = pd.read_csv(PATH + "train.csv")
df_test = pd.read_csv(PATH + "test.csv")

display(df_train.head())
display(df_train.describe())

# %% [markdown]
# # Data Pre-processing
#
# Add suggestions for data pre-processing here:
# * Tokenization

# %% [markdown]
# # Feature Engineering
#
# Add suggestions for feature engineering here:
#
# *

# %% [markdown]
# # Modelling
#
# Add suggestions for modelling here:
#
# *

# %% [markdown]
# # Performance Evaluation
#
# Add suggestions for performance evaluation here:
#
# *
