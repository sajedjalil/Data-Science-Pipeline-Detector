# %% [markdown]
# # In these Kernal:
# - We will explore Dataset
# - Perform EDA
# - Generate Report of The EDA
# - Final Prediction

# %% [markdown]
# # Loading Modules

# %%
# Loading necessary modules

import pandas as pd


import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# # Loading Data

# %%
# Loading data

train =  pd.read_csv("../input/demand-forecasting-kernels-only/train.csv")
test =  pd.read_csv("../input/demand-forecasting-kernels-only/test.csv")
sub =  pd.read_csv("../input/demand-forecasting-kernels-only/sample_submission.csv")

# %% [markdown]
# - Checking dimension

# %%
train.shape

# %%
test.shape

# %% [markdown]
# - Displaying columns names

# %%
train.columns

# %%
test.columns

# %% [markdown]
# - Displaying content of Train and Test

# %%
train.head()

# %%
test.head()

# %% [markdown]
# - Checking for null values

# %%
train.isnull().sum()

# %%
test.isnull().sum()

# %% [markdown]
# # EDA

# %%
train.columns

# %%
train.dtypes

# %%
# Converting Date from string to datetime format

pd.to_datetime(train['date'])

# %%
# Checking if date was converted from string to datetime

train.dtypes

# %%
# Displaying the start and end date for the training set

sd = train.date.iloc[0]
ed = train.date.iloc[-1]

print("Start Date:", sd)
print("End Date  :", ed)

# %%
# Displaying the start and end date for the testing set

sd = test.date.iloc[0]
ed = test.date.iloc[-1]

print("Start Date:", sd)
print("End Date  :", ed)

# %%
train.store.value_counts()

# %%
train.item.value_counts()

# %%
s = train.sales.value_counts()
s

# %%
# Plotting correlation 

plt.figure(figsize=(10,10))
sns.heatmap(train.corr(), cmap='Spectral')
plt.ylabel('file index numbers')
plt.xlabel('file index numbers')
plt.title('Plotting Correlation')
plt.show()

# %% [markdown]
# - Converting date to datatime and taking year 2013 as consideration

# %%
train['date'] = pd.to_datetime(train['date'], format='%Y-%m-%d')

y_2013 = train.loc[(train['date'] >= '2012-12-31')
                     & (train['date'] <= '2013-12-31')]

# %%
monthvise= y_2013.groupby(y_2013['date'].dt.strftime('%B'))[['store','item','sales']]

# %% [markdown]
# # Plotting line chart for the year 2013 for the different Stores and Items

# %%
y_2013[:365]

# %%
fig = px.line(y_2013[:365], x="date", y="sales", title='Sales record for Store 1 Item 1 in Year 2013')
fig.show()

# %%
y_2013[365:730]

# %%
fig = px.line(y_2013[365:730], x="date", y="sales", title='Sales record for Store 2 Item 1 in Year 2013')
fig.show()

# %%
y_2013[730:1095]

# %%
fig = px.line(y_2013[730:1095], x="date", y="sales", title='Sales record for Store 3 Item 1 in Year 2013')
fig.show()

# %% [markdown]
# - And so ...

# %%
monthvise= y_2013.groupby(y_2013[:365]['date'].dt.strftime('%B'))[['sales']].mean()
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 
             'September', 'October', 'November', 'December']
monthvise = monthvise.reindex(new_order, axis=0)
monthvise

# %%
fig = go.Figure()

fig.add_trace(go.Bar(
    x=monthvise.index,
    y=monthvise['sales'],
    name='Stock Open Price',
    marker_color='crimson'
))
fig.update_layout(title='Average Sales for Store 1 Item 1 in year 2013')

# %%
monthvise= y_2013.groupby(y_2013[365:730]['date'].dt.strftime('%B'))[['sales']].mean()
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 
             'September', 'October', 'November', 'December']
monthvise = monthvise.reindex(new_order, axis=0)
monthvise

# %%
fig = go.Figure()

fig.add_trace(go.Bar(
    x=monthvise.index,
    y=monthvise['sales'],
    name='Stock Open Price',
    marker_color='crimson'
))
fig.update_layout(title='Average Sales for Store 2 Item 1 in year 2013')

# %%
# Prediction :


sub.to_csv("Submission.csv",index=False)

# %% [markdown]
# check if submission file is created

# %%
import os
os.listdir('/kaggle/working')

# %% [markdown]
# # Will be adding more content soom !

# %% [markdown]
# # Let me know your feedback as well as suggestion
