# %% [markdown]
# It is easy to get lost in data munging with the provided challenging data set.
# Despite the time zone diffference (2 am kickoff) we watched the Steelers - Patriots game last Sunday.
#
# This was our favorite punt play by far :)

# %%
from IPython.display import HTML
HTML('<blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">(Special) Teamwork.<a href="https://twitter.com/hashtag/NEvsPIT?src=hash&amp;ref_src=twsrc%5Etfw">#NEvsPIT</a> | <a href="https://twitter.com/hashtag/GoPats?src=hash&amp;ref_src=twsrc%5Etfw">#GoPats</a> <a href="https://t.co/fjEkxMKg0C">pic.twitter.com/fjEkxMKg0C</a></p>&mdash; New England Patriots (@Patriots) <a href="https://twitter.com/Patriots/status/1074429313506656256?ref_src=twsrc%5Etfw">2018. december 16.</a></blockquote>'
'<script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>')

# %% [markdown]
# # Divisional Round - Muffed Punt Recover In Bounds

# %%
HTML('<blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">The <a href="https://twitter.com/Patriots?ref_src=twsrc%5Etfw">@Patriots</a> jump on the muffed punt and recover in bounds! <a href="https://twitter.com/hashtag/EverythingWeGot?src=hash&amp;ref_src=twsrc%5Etfw">#EverythingWeGot</a> <a href="https://twitter.com/hashtag/NFLPlayoffs?src=hash&amp;ref_src=twsrc%5Etfw">#NFLPlayoffs</a><br><br>📺: <a href="https://twitter.com/hashtag/LACvsNE?src=hash&amp;ref_src=twsrc%5Etfw">#LACvsNE</a> on CBS <a href="https://t.co/Wy866tYf1Z">pic.twitter.com/Wy866tYf1Z</a></p>&mdash; NFL (@NFL) <a href="https://twitter.com/NFL/status/1084532158981595137?ref_src=twsrc%5Etfw">2019. január 13.</a></blockquote>'
'<script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>')

# %% [markdown]
# # Playoff Blocked Punt TD!

# %%
HTML('<blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">THE <a href="https://twitter.com/Colts?ref_src=twsrc%5Etfw">@COLTS</a> BLOCK THE PUNT!<br><br>And it&#39;s recovered in the end zone for SIX. <a href="https://twitter.com/hashtag/Colts?src=hash&amp;ref_src=twsrc%5Etfw">#Colts</a> <a href="https://twitter.com/hashtag/NFLPlayoffs?src=hash&amp;ref_src=twsrc%5Etfw">#NFLPlayoffs</a><br><br>📺: <a href="https://twitter.com/hashtag/INDvsKC?src=hash&amp;ref_src=twsrc%5Etfw">#INDvsKC</a> on NBC <a href="https://t.co/G9cT22FeBa">pic.twitter.com/G9cT22FeBa</a></p>&mdash; NFL (@NFL) <a href="https://twitter.com/NFL/status/1084218769017233409?ref_src=twsrc%5Etfw">2019. január 12.</a></blockquote>'
'<script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>')

# %% [markdown]
# # Wildcard Punt Block
#
# LAC - BAL no TD yet :)

# %%
HTML('<blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">HUGE PLAY BUCK! <a href="https://t.co/WYEXTcQFzZ">pic.twitter.com/WYEXTcQFzZ</a></p>&mdash; Baltimore Ravens (@Ravens) <a href="https://twitter.com/Ravens/status/1082005707317104640?ref_src=twsrc%5Etfw">2019. január 6.</a></blockquote>'
'<script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>')

# %% [markdown]
# # Xmas Miracle

# %%
HTML('<iframe width="640" height="360" src="https://www.youtube.com/embed/qG7ZRXgLvOc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# # Unexpected Tackle from the Punter

# %%
HTML('<iframe width="640" height="360" src="https://www.youtube.com/embed/t7Mh4QiApwk" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# Here are a few  best of selections.
#
# # Punt Return Touchdowns

# %%
HTML('<iframe width="640" height="360" src="https://www.youtube.com/embed/-B930Iciz0U" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %%
HTML('<iframe width="640" height="360" src="https://www.youtube.com/embed/pJjs_lmif_Y" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# # Fake Punts

# %%
HTML('<iframe width="640" height="360" src="https://www.youtube.com/embed/Sq1z1P9AK78" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
