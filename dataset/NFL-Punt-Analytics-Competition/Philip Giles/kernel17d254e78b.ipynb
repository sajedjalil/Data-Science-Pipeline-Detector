# %%
My proposed change is for NFL punt plays to continue to be played under existing 
rules, except to eliminate the option for the receiving team to return punts.

My analysis was conducted using Microsoft Excel. I do not know R or Python.
Should that invalidate my entry if I have a plausible proposal?

I have never used Kaggle or kernels before. What appears below is a written summary of 
the analysis supporting my proposed change to reduce the frequency of concussions
in NFL games.



Data analyzed were:
    
NFL Punt Analytics Competition data provided on Kaggle site
2016 and 2017 pre-season, regular season, and post-season games
Game, play, player, and concussion data
Video footage of punt plays when a concussion occurred

From NFL website
For 2016 and 2017, punting statistics

From Play Smart, Play Safe website
Incidence of concussion statistics, 2012-2017

From Pro Football Reference website
Data for all plays using Team Game Finder database



In 2016 and 2017, there were 6680 punts.

2977 punts were returned; 203 were muffed.

3703 punts were fair caught, went into end zone or out-of-bounds, downed by 
kicking team, called dead, blocked, or faked.

Penalties were called on 626 plays where punt was returned (21.0%).

Anecdotal observation suggests that most penalties during punt returns 
arecalled on receiving team, negating the return, but further analysis is 
required.

Only 2211 non-muffed punts were returned with no penalties called
(33.1% of 6680 punts) [includes returns with fumbles]

Average yards gained on those returns:  8.1 yards


 

In 2016 and 2017, there were 37 concussions on punt plays.

Based on interpretation of punt plays in videos:
    
A  Concussion occurred during punt return (22)
B  Concussion occurred but punt was not returned (5)
C  Concussion did occur on punt play – but video inconclusive about when it occurred (8)
D  Punt was returned on play but concussion was not related to return (2)

At least 22/37 (59.5%) of concussions on punt plays occurred during returns –
could be higher if contexts of type C concussions were determined.




There were 452 in-game concussions in all games 2016 and 2017.

At least 22 concussions occurred during punt returns, representing 4.9% 
of all in-game concussions.


There were 83194 plays in 2016 and 2017 (regular/post-season only).

4968 of those plays were punt plays; assuming same 33.1% ratio 
from above = 1644 punt returns, so all other plays = 81550.

Of 361 concussions in these games, at least 13 occurred during punt 
returns in those games; remaining ones (348) occurred on all other plays.

Frequency of concussion on punt plays with returns = 13/1644 = 0.79%

Frequency of concussion on all other plays = 348/81550 = 0.43%




The analysis showed that most concussions on punt plays occurred during 
punt returns (at least 59.5% in 2016 and 2017),

and that the frequency of concussion was at least 1.8 times higher 
during punt returns (0.79%) than on all other plays (0.44%).

Therefore, the proposed change is:
To eliminate the option for the receiving team to return punts.

Other existing rules and strategies regarding punt plays would remain.
