# %%
import pandas as pd
import cudf

# %%
import os
fileSize = os.path.getsize("../input/tabular-playground-series-oct-2021/train.csv")/(1024*1024*1024)
print('Size of file is : ', fileSize ,  'GB')

# %%
# %%time
pandas_df = pd.read_csv("../input/tabular-playground-series-oct-2021/train.csv")
pandas_df.shape

# %%
# %%time
cud_df = cudf.read_csv('../input/tabular-playground-series-oct-2021/train.csv', index_col = 'id').to_pandas()
cud_df.shape
