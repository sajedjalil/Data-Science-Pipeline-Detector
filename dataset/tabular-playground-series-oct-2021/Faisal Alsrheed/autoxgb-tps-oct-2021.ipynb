# %% [markdown]
# https://github.com/abhishekkrthakur/autoxgb

# %%
# !pip install -U ../input/autoxgb/ --no-deps -q

# %%
# !autoxgb train --help

# %%
# !autoxgb train \
--train_filename ../input/tabular-playground-series-oct-2021/train.csv \
--test_filename ../input/tabular-playground-series-oct-2021/test.csv \
--id_column id \
--target target \
--problem_type classification \
--time_limit 25200 \
--output_dir TPS_oct_2021 \
--use_gpu

# %%
# !cp /kaggle/working/TPS_oct_2021/test_predictions.csv submission.csv
