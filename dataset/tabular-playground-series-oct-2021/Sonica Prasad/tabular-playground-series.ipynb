# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading datasets

# %%
train_data = pd.read_csv("../input/tabular-playground-series-oct-2021/train.csv")
test_data = pd.read_csv("../input/tabular-playground-series-oct-2021/test.csv")

# %%
train_data.head()

# %%
train_data.shape

# %%
test_data.shape

# %% [markdown]
# Missing values

# %%
train_data.isna().sum()

# %%
test_data.isna().sum()

# %%
train_data.info()

# %%
sns.countplot(data=train_data, x='target')

# %%
train_data = pd.read_csv("../input/tabular-playground-series-oct-2021/train.csv", nrows=10000)

# %%
import gc
#del unwanted_dataframe
garbage_coll = gc.collect()

# %%
del(garbage_coll)

# %% [markdown]
# Machine Learning

# %%
X = train_data.drop('target', axis=1)
y = train_data['target']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))

# %% [markdown]
# Random Forest CLassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators = 700)
rfc.fit(X,y)
rfc_pred = rfc.predict(test_data)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)
rfc.fit(X_train, y_train)
rfc_pred2 = rfc.predict(X_test)

# %%
score = round(model.score(X_train, y_train)*100, 2)
print("the score of the model is", score)

# %%
print(confusion_matrix(y_test, rfc_pred2))
print(classification_report(y_test, rfc_pred2))

# %%
output_values = pd.DataFrame({"id": test_data['id'], "target":rfc_pred})

# %%
output_values.to_csv("submission.csv", index=False)
