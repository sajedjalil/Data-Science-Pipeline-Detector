# %%
import numpy as np
import pandas as pd

# %%
sub = pd.read_csv("../input/tabular-playground-series-oct-2021/sample_submission.csv")
sub_1 = pd.read_csv('../input/tps-oct-2021-pca-and-kmeans-feature-eng-t/submission.csv')
sub_2 = pd.read_csv('../input/tps-oct-2021-kmeans12-nn/submission.csv')
sub_3 = pd.read_csv('../input/single-xgboost-model-featureengineering/xgb.csv')
sub_4 = pd.read_csv('../input/tps-oct-21-eda-modeling/submission.csv')
sub_5 = pd.read_csv('../input/noob-stacking-0-85654/LGBM.csv')
sub['target'] = (sub_1['target'].values*0.075)+\
                (sub_2['target'].values*0.300)+\
                (sub_3['target'].values*0.1625)+\
                (sub_4['target'].values*0.1625)+\
                (sub_5['target'].values*0.300)
sub.to_csv('submission.csv', index=False)
