# %%
import numpy as np
import pandas as pd

# %%
sub = pd.read_csv("../input/tabular-playground-series-oct-2021/sample_submission.csv")
sub_1 = pd.read_csv('../input/exploring-submissions-and-power-averaging/submission.csv')
sub_2 = pd.read_csv('../input/blending-weighted-rank-average/submission.csv')
sub_3 = pd.read_csv('../input/stacking-3-folds-bagging-seeds/overfit_for_sure_lol.csv')
sub_4 = pd.read_csv('../input/ensemble-of-pn-better-weights/submission.csv')

# %%
sub['target'] = ((sub_1['target']**4)*0.5 +(sub_2['target']**4)*0.5 + (sub_3['target']**4)*0 + (sub_4['target']**4)*0)/4
sub.to_csv('submission.csv', index=False)

# %%
sub.head(5)

# %% [markdown]
# Thanks to all the Public NB Creators!
