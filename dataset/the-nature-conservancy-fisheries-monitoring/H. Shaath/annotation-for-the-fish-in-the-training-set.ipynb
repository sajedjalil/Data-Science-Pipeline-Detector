# %%
#This is annotations for all the fish in the training set.  That's a rectangle that  
# contains the fish.

#This is a hard competition, but an important one. 
#So I release this data in hope that others would use it to come up with better models.
# The approach I am trying to follow (which could be incorrect)is to first detect the 
#fish via cascade classifiers), and then classify.  
#I still have ways to go will continue to try, 
#but maybe this would help others who are ahead in solving this beautiful problem.

#This is released completely free and can be used by anyone with or without siting the source.

# there are no gurantees to the data, the fish was manually labeld by my self using sloth.
# It may have some mistakes.


# Good luck everyone!

# %%
[
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.0,
                "width": 250.0,
                "x": 322.0,
                "y": 227.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07914.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.0,
                "width": 251.0,
                "x": 376.0,
                "y": 115.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07912.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.0,
                "width": 266.0,
                "x": 758.0,
                "y": 5.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07885.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.0,
                "width": 136.0,
                "x": 541.0,
                "y": 411.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07862.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.0,
                "width": 335.0,
                "x": 253.0,
                "y": 184.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07826.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.0,
                "width": 162.0,
                "x": 304.0,
                "y": 162.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07822.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.0,
                "width": 382.0,
                "x": 645.0,
                "y": 174.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07810.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.0,
                "width": 431.0,
                "x": 568.0,
                "y": 307.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07801.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.0,
                "width": 191.0,
                "x": 751.0,
                "y": 23.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07785.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.0,
                "width": 105.0,
                "x": 572.0,
                "y": 244.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07768.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.0,
                "width": 137.0,
                "x": 623.0,
                "y": 337.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07763.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.0,
                "width": 381.0,
                "x": 566.0,
                "y": 82.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07749.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 275.0,
                "width": 147.0,
                "x": 321.0,
                "y": 308.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07735.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.0,
                "width": 164.0,
                "x": 216.0,
                "y": 61.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07732.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.0,
                "width": 412.0,
                "x": 638.0,
                "y": 347.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07726.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.0,
                "width": 355.0,
                "x": 609.0,
                "y": 190.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07720.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 52.0,
                "width": 193.0,
                "x": 751.0,
                "y": 361.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07710.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.0,
                "width": 57.0,
                "x": 875.0,
                "y": 287.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07705.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 49.0,
                "width": 81.0,
                "x": 918.0,
                "y": 188.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07704.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.0,
                "width": 82.0,
                "x": 819.0,
                "y": 300.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07701.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 258.0,
                "width": 174.0,
                "x": 482.0,
                "y": 142.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07694.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.0,
                "width": 317.0,
                "x": 816.0,
                "y": 312.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07686.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.0,
                "width": 159.0,
                "x": 211.0,
                "y": 48.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07684.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.0,
                "width": 265.0,
                "x": 655.0,
                "y": 323.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07645.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.0,
                "width": 331.0,
                "x": 350.0,
                "y": 136.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07639.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.0,
                "width": 126.0,
                "x": 388.0,
                "y": 126.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07638.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.0,
                "width": 137.0,
                "x": 604.0,
                "y": 352.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07619.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.0,
                "width": 65.0,
                "x": 307.0,
                "y": 115.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07608.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.0,
                "width": 158.0,
                "x": 159.0,
                "y": 356.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07566.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.0,
                "width": 124.0,
                "x": 220.0,
                "y": 369.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07559.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.0,
                "width": 443.0,
                "x": 630.0,
                "y": 565.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07549.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.0,
                "width": 237.0,
                "x": 454.0,
                "y": 62.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07537.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.0,
                "width": 415.0,
                "x": 586.0,
                "y": 333.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07520.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 366.0,
                "width": 233.0,
                "x": 915.0,
                "y": 238.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07491.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.0,
                "width": 362.0,
                "x": 241.0,
                "y": 56.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07488.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.0,
                "width": 454.0,
                "x": 535.0,
                "y": 237.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07486.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.0,
                "width": 333.0,
                "x": 265.0,
                "y": 55.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07477.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.0,
                "width": 259.0,
                "x": 758.0,
                "y": 8.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07459.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.0,
                "width": 176.0,
                "x": 193.0,
                "y": 51.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07443.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.0,
                "width": 73.0,
                "x": 824.0,
                "y": 288.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07439.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.0,
                "width": 315.0,
                "x": 772.0,
                "y": 177.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07404.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 59.0,
                "width": 191.0,
                "x": 168.0,
                "y": 387.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.0,
                "width": 330.0,
                "x": 272.0,
                "y": 58.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07380.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.0,
                "width": 197.0,
                "x": 275.0,
                "y": 166.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07377.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.0,
                "width": 187.0,
                "x": 741.0,
                "y": 337.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07349.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.0,
                "width": 387.0,
                "x": 514.0,
                "y": 66.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07335.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.0,
                "width": 206.0,
                "x": 613.0,
                "y": 358.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07328.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 271.0,
                "width": 299.0,
                "x": 346.0,
                "y": 141.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07298.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.0,
                "width": 354.0,
                "x": 778.0,
                "y": 192.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07296.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.0,
                "width": 415.0,
                "x": 559.0,
                "y": 182.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07291.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.0,
                "width": 108.0,
                "x": 161.0,
                "y": 157.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07272.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.0,
                "width": 231.0,
                "x": 478.0,
                "y": 228.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07271.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.0,
                "width": 288.0,
                "x": 430.0,
                "y": 298.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07252.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.0,
                "width": 232.0,
                "x": 647.0,
                "y": 364.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07241.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.0,
                "width": 344.0,
                "x": 806.0,
                "y": 321.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07225.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.0,
                "width": 171.0,
                "x": 301.0,
                "y": 133.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07207.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.0,
                "width": 216.0,
                "x": 524.0,
                "y": 416.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07200.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.0,
                "width": 422.0,
                "x": 448.0,
                "y": 249.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07197.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.0,
                "width": 275.0,
                "x": 352.0,
                "y": 10.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07178.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.0,
                "width": 215.0,
                "x": 1034.0,
                "y": 239.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07174.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.0,
                "width": 163.0,
                "x": 647.0,
                "y": 338.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07172.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 41.26544413225946,
                "width": 35.370380684793815,
                "x": 368.86254142713545,
                "y": 403.3907701908627
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07159.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.27164963410652,
                "width": 114.53266126504661,
                "x": 634.140396563089,
                "y": 208.01152450343025
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07155.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.42949771304,
                "width": 131.37569968637695,
                "x": 675.4058406953485,
                "y": 153.2716496341065
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07150.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.2689901333149,
                "width": 237.48684174075845,
                "x": 450.55127777058783,
                "y": 301.4903877418139
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07136.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.01063800316638,
                "width": 304.85899542607996,
                "x": 331.8078569002086,
                "y": 181.06266302930163
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07134.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.74076136958763,
                "width": 323.3863376895434,
                "x": 347.80874340047245,
                "y": 266.1200070570201
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07117.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.85278992423292,
                "width": 331.80785690020866,
                "x": 786.5698942761289,
                "y": 362.9674779796698
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07105.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.0617765290378,
                "width": 325.0706415316764,
                "x": 370.5468452692685,
                "y": 269.48861474128614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07083.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.63848431784484,
                "width": 341.9136799530068,
                "x": 261.067095530621,
                "y": 57.26633063252331
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07078.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.11025555411754,
                "width": 161.69316884477178,
                "x": 767.200400091599,
                "y": 302.33253966288044
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07040.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.58557279144571,
                "width": 162.5353207658382,
                "x": 378.96836447993365,
                "y": 418.5495047700601
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07035.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.64291681916418,
                "width": 314.1226665578116,
                "x": 770.5690077758651,
                "y": 178.53620726610208
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07016.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.11202855464529,
                "width": 337.7029203476742,
                "x": 259.38279168848794,
                "y": 58.95063447465635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07014.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.74342087037923,
                "width": 98.53177476478277,
                "x": 580.2426736148318,
                "y": 403.3907701908627
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07008.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.27430913489812,
                "width": 394.12709905913096,
                "x": 522.134191061242,
                "y": 102.74253437011535
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07001.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.27430913489803,
                "width": 196.22139760849905,
                "x": 714.1448290644083,
                "y": 470.7629238761843
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07000.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.85013042344133,
                "width": 170.1146880554369,
                "x": 643.4040676948207,
                "y": 355.38811069007113
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06989.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.4841822399668,
                "width": 453.91988545485384,
                "x": 453.07773353378735,
                "y": 367.1782375850024
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06987.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.32367466024175,
                "width": 96.00531900158319,
                "x": 442.1297585599226,
                "y": 330.1235530580756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06970.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.21696510717966,
                "width": 274.54152626768524,
                "x": 347.80874340047245,
                "y": 9.263671131731712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06963.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.1658265813083,
                "width": 368.8625414271355,
                "x": 729.3035636436057,
                "y": 343.59798379513984
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06948.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.43304371409548,
                "width": 414.33874516472747,
                "x": 510.34406416631066,
                "y": 130.5335477653105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06932.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.90481495036815,
                "width": 397.495706743397,
                "x": 546.556596772171,
                "y": 35.37038068479381
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06887.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.06089002877388,
                "width": 160.00886500263857,
                "x": 752.8838174334683,
                "y": 328.43924921594254
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06865.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.53088826451886,
                "width": 127.16494008104439,
                "x": 640.8776119316211,
                "y": 347.80874340047245
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06864.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.63937081810872,
                "width": 183.58911879250115,
                "x": 621.5081177470912,
                "y": 352.86165492687155
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06853.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.38013218769635,
                "width": 99.37392668584937,
                "x": 579.4005216937652,
                "y": 242.53975326715755
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06844.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.4312707135677,
                "width": 138.1129150549092,
                "x": 693.0910310377453,
                "y": 220.64380331942806
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06843.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.8501304234413,
                "width": 74.95152097492024,
                "x": 447.1826700863217,
                "y": 46.31835565865856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06804.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 221.48595524049455,
                "width": 120.42772471251229,
                "x": 154.113801555173,
                "y": 253.4877282410223
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06797.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.37215368532156,
                "width": 189.48418223996686,
                "x": 236.6446898196919,
                "y": 371.388997190335
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06796.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.85456292476064,
                "width": 328.4392492159425,
                "x": 352.86165492687155,
                "y": 144.8501304234413
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06767.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.69316884477172,
                "width": 403.3907701908628,
                "x": 516.2391276137763,
                "y": 148.2187381077074
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06707.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.58645929170962,
                "width": 327.59709729487605,
                "x": 264.43570321488704,
                "y": 326.75494537380945
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06695.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.26810363305106,
                "width": 50.529115263991116,
                "x": 827.8353384083885,
                "y": 253.4877282410223
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06694.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.27608213542584,
                "width": 261.06709553062103,
                "x": 826.1510345662554,
                "y": 2.5264557631995577
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06693.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.11291505490914,
                "width": 330.1235530580755,
                "x": 264.43570321488704,
                "y": 51.371267185057675
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06680.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.06000352851004,
                "width": 519.6077352980425,
                "x": 665.3000176425502,
                "y": 624.8767254313573
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06670.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.37658618664085,
                "width": 393.2849471380646,
                "x": 834.5725537769206,
                "y": 428.6553278228583
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06656.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.42772471251223,
                "width": 439.6033027967231,
                "x": 387.3898836905989,
                "y": 254.3298801620888
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06653.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.95506697597568,
                "width": 396.65355482233065,
                "x": 566.7682428777674,
                "y": 94.32101515945016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06648.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.16671308157214,
                "width": 81.68873634345232,
                "x": 300.6482358207474,
                "y": 295.59532429434825
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06594.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.85013042344133,
                "width": 241.697601346091,
                "x": 320.85988192634386,
                "y": 242.53975326715755
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06591.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.2725361343704,
                "width": 356.2302626111376,
                "x": 689.7224233534793,
                "y": 570.1368505620335
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06588.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 246.75051287249016,
                "width": 167.5882322922373,
                "x": 772.2533116179982,
                "y": 524.6606468244415
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06587.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.2151921066519,
                "width": 197.90570145063202,
                "x": 244.22405710929058,
                "y": 330.1235530580756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06583.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.90304194984049,
                "width": 324.2284896106099,
                "x": 556.6624198249692,
                "y": 389.9163394537984
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06563.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.2716496341065,
                "width": 377.2840606378006,
                "x": 510.34406416631066,
                "y": 69.8986094485211
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06561.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.69139584424397,
                "width": 165.90392845010433,
                "x": 628.2453331156233,
                "y": 361.2831741375368
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06560.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.00709200211094,
                "width": 280.4365897151509,
                "x": 261.90924745168746,
                "y": 199.59000529276506
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06554.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.69405534503557,
                "width": 400.0221625065966,
                "x": 533.9243179561732,
                "y": 138.95506697597568
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06546.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00620550184715,
                "width": 51.37126718505772,
                "x": 576.0319140094991,
                "y": 560.8731794303018
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06545.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.05734402771844,
                "width": 39.58114029012643,
                "x": 992.0549630163597,
                "y": 289.7002608468826
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06539.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.79899189756992,
                "width": 171.79899189756992,
                "x": 211.38013218769635,
                "y": 46.31835565865856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06512.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.00797850237478,
                "width": 330.96570497914195,
                "x": 821.0981230398563,
                "y": 287.1738050836831
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06471.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.27608213542584,
                "width": 176.00975150290253,
                "x": 715.8291329065414,
                "y": 490.1324180607142
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06461.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 51.371267185057675,
                "width": 79.16228058025285,
                "x": 634.9825484841555,
                "y": 98.53177476478275
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06460.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.42772471251223,
                "width": 144.00797850237473,
                "x": 582.7691293780314,
                "y": 202.95861297703115
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06458.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.11114205438145,
                "width": 120.42772471251226,
                "x": 742.77799438067,
                "y": 271.1729185834192
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06435.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.79810539730602,
                "width": 495.1853295871133,
                "x": 736.0407790121378,
                "y": 611.402294694293
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06422.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.32367466024175,
                "width": 383.17912408526627,
                "x": 718.3555886697409,
                "y": 78.3201286591863
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06405.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.69139584424397,
                "width": 361.2831741375367,
                "x": 403.3907701908627,
                "y": 127.1649400810444
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06393.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.63848431784484,
                "width": 361.2831741375368,
                "x": 783.2012865918629,
                "y": 191.16848608209986
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06388.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.1155745557008,
                "width": 129.69139584424397,
                "x": 725.0928040382731,
                "y": 425.2867201385922
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06386.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.95595347623953,
                "width": 169.27253613437034,
                "x": 214.7487398719624,
                "y": 62.31924215892243
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06372.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.80076489809764,
                "width": 214.74873987196236,
                "x": 291.3845646890157,
                "y": 187.7998783978338
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06347.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.21430560638805,
                "width": 162.53532076583824,
                "x": 245.0662090303571,
                "y": 357.07241453220416
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06301.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.79987839783382,
                "width": 345.28228763727304,
                "x": 832.8882499347875,
                "y": 266.1200070570201
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06286.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.11380155517298,
                "width": 104.42683821224841,
                "x": 618.9816619838916,
                "y": 339.3872241898073
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06254.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.11646105596463,
                "width": 138.95506697597568,
                "x": 711.6183733012087,
                "y": 396.6535548223306
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06231.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 249.2769686356897,
                "width": 306.54329926821305,
                "x": 351.1773510847385,
                "y": 93.47886323838364
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06215.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.2725361343704,
                "width": 398.3378586644636,
                "x": 523.8184949033749,
                "y": 125.48063623891137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06213.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.48329573970295,
                "width": 242.5397532671575,
                "x": 759.6210328020004,
                "y": 6.737215368532154
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06187.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.11468805543691,
                "width": 112.84835742291352,
                "x": 673.7215368532154,
                "y": 130.5335477653105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06176.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.27519563516196,
                "width": 120.42772471251226,
                "x": 205.4850687402307,
                "y": 74.95152097492021
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06175.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.53798026662983,
                "width": 117.90126894931268,
                "x": 203.80076489809767,
                "y": 74.95152097492021
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06157.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.58734579197346,
                "width": 199.590005292765,
                "x": 661.0892580372176,
                "y": 402.5486182697962
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06123.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 50.52911526399117,
                "width": 169.27253613437034,
                "x": 486.76381037644813,
                "y": 511.1862160873772
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06114.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.48063623891136,
                "width": 370.5468452692685,
                "x": 515.3969756927098,
                "y": 66.53000176425502
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06089.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.268103633051,
                "width": 53.05557102719081,
                "x": 988.6863553320936,
                "y": 302.33253966288044
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06086.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.42861121277616,
                "width": 318.3334261631443,
                "x": 171.79899189756992,
                "y": 317.49127424207774
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06064.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 425.28672013859216,
                "width": 142.32367466024175,
                "x": 268.64646282021965,
                "y": 172.64114381863644
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06025.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.74430737064307,
                "width": 54.739874869323785,
                "x": 453.07773353378735,
                "y": 358.7567183743372
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05902.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.58734579197346,
                "width": 100.21607860691574,
                "x": 650.9834349844194,
                "y": 355.38811069007113
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05890.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.21962460797127,
                "width": 363.80962990073635,
                "x": 384.02127600633276,
                "y": 173.48329573970298
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05889.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.58645929170962,
                "width": 374.75760487460104,
                "x": 504.449000718845,
                "y": 76.63582481705325
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05885.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.16671308157214,
                "width": 309.9119069524791,
                "x": 344.4401357162064,
                "y": 49.686963342924635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05884.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.0600035285101,
                "width": 208.01152450343022,
                "x": 602.9807754836278,
                "y": 354.5459587690046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05862.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.58379979091802,
                "width": 231.5917782932928,
                "x": 606.3493831678938,
                "y": 335.1764645844747
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05849.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.7443073706431,
                "width": 362.12532605860326,
                "x": 776.4640712233307,
                "y": 195.37924568743247
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05845.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 307.38545118927954,
                "width": 154.11380155517298,
                "x": 291.3845646890157,
                "y": 181.06266302930163
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05823.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.90304194984043,
                "width": 132.21785160744344,
                "x": 601.2964716414948,
                "y": 350.33519916367203
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05821.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.16494008104439,
                "width": 112.84835742291364,
                "x": 469.92077195511774,
                "y": 293.9110204522152
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05818.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.8501304234413,
                "width": 368.0203895060689,
                "x": 712.4605252222754,
                "y": 82.5308882645189
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05815.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.01241100369407,
                "width": 117.05911702824619,
                "x": 519.6077352980424,
                "y": 450.55127777058783
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05811.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.6420303189003,
                "width": 245.90836095142356,
                "x": 450.55127777058783,
                "y": 261.067095530621
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05808.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 236.6446898196919,
                "width": 391.6006432959314,
                "x": 680.4587522217475,
                "y": 168.43038421330385
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05763.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.53620726610208,
                "width": 160.8510169237052,
                "x": 206.32722066129722,
                "y": 40.42329221119292
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05758.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.2707631338426,
                "width": 179.37835918716866,
                "x": 391.60064329593143,
                "y": 423.6024162964592
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05734.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.06177652903776,
                "width": 179.37835918716863,
                "x": 208.01152450343025,
                "y": 54.73987486932375
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05727.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.26987663357875,
                "width": 90.11025555411754,
                "x": 826.1510345662554,
                "y": 324.2284896106099
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05710.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.68873634345238,
                "width": 69.05645752745454,
                "x": 819.4138191977232,
                "y": 267.8043108991531
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05690.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00620550184703,
                "width": 96.00531900158319,
                "x": 813.5187557502576,
                "y": 298.1217800575478
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05675.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.95683997650343,
                "width": 115.37481318611316,
                "x": 281.27874163621743,
                "y": 277.0679820308848
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05674.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.43038421330385,
                "width": 156.64025731837256,
                "x": 216.43304371409545,
                "y": 49.686963342924635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05648.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.58468629118181,
                "width": 149.90304194984043,
                "x": 442.97191048098915,
                "y": 570.9790024831001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05641.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.167599581836,
                "width": 233.27608213542584,
                "x": 474.13153156045036,
                "y": 53.89772294825723
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05637.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.95772647676728,
                "width": 86.74164786985148,
                "x": 409.28583363832837,
                "y": 284.6473493204835
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05621.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.69405534503557,
                "width": 220.643803319428,
                "x": 379.8105164010002,
                "y": 192.85278992423292
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05610.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.58734579197346,
                "width": 413.496593243661,
                "x": 559.1888755881688,
                "y": 94.32101515945016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05597.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.7972188970422,
                "width": 405.9172259540623,
                "x": 493.50102574498027,
                "y": 53.89772294825723
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05575.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.59000529276506,
                "width": 191.1684860820999,
                "x": 541.5036852457719,
                "y": 419.39165669112657
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05570.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.48329573970298,
                "width": 67.37215368532156,
                "x": 275.3836781887518,
                "y": 234.11823405649235
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05566.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.1631670805167,
                "width": 74.95152097492019,
                "x": 825.3088826451889,
                "y": 267.8043108991531
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05556.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.90481495036812,
                "width": 294.75317237328176,
                "x": 332.6500088212751,
                "y": 78.3201286591863
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05550.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.4824092394391,
                "width": 426.97102398072525,
                "x": 385.70557984846585,
                "y": 229.06532253009323
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05533.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.58645929170962,
                "width": 272.8572224255522,
                "x": 321.70203384741035,
                "y": 225.69671484582716
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05523.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.32633416103334,
                "width": 102.74253437011544,
                "x": 572.6633063252331,
                "y": 240.85544942502452
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05518.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.42772471251226,
                "width": 82.53088826451881,
                "x": 737.7250828542709,
                "y": 293.9110204522152
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05515.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.42949771304,
                "width": 396.65355482233065,
                "x": 529.7135583508406,
                "y": 134.74430737064307
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05512.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.90215544957655,
                "width": 362.12532605860326,
                "x": 234.96038597755887,
                "y": 47.16050757972508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05491.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.11646105596463,
                "width": 106.95329397544799,
                "x": 571.8211544041666,
                "y": 236.6446898196919
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05419.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.74608037117082,
                "width": 396.65355482233053,
                "x": 630.7717888788229,
                "y": 341.9136799530068
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05408.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.74696687143467,
                "width": 117.05911702824619,
                "x": 662.7735618793506,
                "y": 140.63937081810872
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.74430737064307,
                "width": 443.8140624020557,
                "x": 448.86697392845474,
                "y": 62.31924215892243
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05384.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.06177652903781,
                "width": 108.63759781758097,
                "x": 791.6228058025281,
                "y": 191.16848608209986
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05383.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.74253437011538,
                "width": 113.69050934398007,
                "x": 309.9119069524791,
                "y": 461.4992527444526
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05382.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.84924392317745,
                "width": 346.96659147940596,
                "x": 258.5406397674214,
                "y": 47.16050757972508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05348.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.21962460797124,
                "width": 388.2320356116654,
                "x": 389.9163394537984,
                "y": 165.0617765290378
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05343.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.95861297703112,
                "width": 210.5379802666298,
                "x": 51.371267185057675,
                "y": 272.85722242555227
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05318.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.74253437011532,
                "width": 234.96038597755887,
                "x": 231.5917782932928,
                "y": 324.2284896106099
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05315.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.4815227391752,
                "width": 423.6024162964592,
                "x": 561.7153313513684,
                "y": 174.3254476607695
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05313.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.37569968637698,
                "width": 385.70557984846585,
                "x": 376.44190871673413,
                "y": 128.84924392317745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05309.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.321901659714,
                "width": 106.95329397544788,
                "x": 796.6757173289272,
                "y": 290.54241276794914
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05303.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.37747268690472,
                "width": 250.96127247782283,
                "x": 758.7788808809338,
                "y": 6.737215368532154
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05279.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.89860944852109,
                "width": 138.1129150549092,
                "x": 717.5134367486744,
                "y": 272.85722242555227
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05247.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 245.0662090303572,
                "width": 90.1102555541176,
                "x": 474.13153156045036,
                "y": 458.13064506018645
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05235.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.0070920021109,
                "width": 75.79367289598673,
                "x": 299.80608389968086,
                "y": 63.161394079988945
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05227.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.58468629118181,
                "width": 124.63848431784481,
                "x": 512.0283680084437,
                "y": 580.2426736148318
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05225.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.85456292476061,
                "width": 110.321901659714,
                "x": 194.53709376636596,
                "y": 63.161394079988945
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05214.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.42949771303995,
                "width": 419.39165669112657,
                "x": 375.5997567956676,
                "y": 118.74342087037921
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05193.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.53443426557436,
                "width": 437.91899895459005,
                "x": 562.5574832724349,
                "y": 90.95240747518407
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05161.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.1146880554369,
                "width": 189.48418223996686,
                "x": 197.90570145063202,
                "y": 48.002659500791594
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05159.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.95683997650343,
                "width": 384.02127600633276,
                "x": 504.449000718845,
                "y": 52.21341910612419
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05158.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.79899189756998,
                "width": 191.1684860820999,
                "x": 453.9198854548539,
                "y": 457.28849313911996
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05148.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.58734579197346,
                "width": 139.79721889704217,
                "x": 698.1439425641445,
                "y": 318.3334261631443
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05109.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.4321572138316,
                "width": 120.42772471251226,
                "x": 205.4850687402307,
                "y": 94.32101515945016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05101.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.11114205438145,
                "width": 77.47797673811976,
                "x": 835.4147056979871,
                "y": 290.54241276794914
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05100.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.59000529276508,
                "width": 398.33785866446357,
                "x": 381.49482024313323,
                "y": 163.37747268690472
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05094.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 272.8572224255522,
                "width": 336.8607684266077,
                "x": 336.8607684266077,
                "y": 81.68873634345236
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05093.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.48418223996683,
                "width": 181.90481495036815,
                "x": 197.0635495295655,
                "y": 37.896836447993365
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05077.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 236.64468981969196,
                "width": 237.48684174075845,
                "x": 303.1746915839469,
                "y": 293.9110204522152
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05020.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 83.37304018558541,
                "width": 153.27164963410655,
                "x": 702.354702169477,
                "y": 275.3836781887518
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04997.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.5362072661021,
                "width": 95.16316708051659,
                "x": 669.5107772478829,
                "y": 162.5353207658382
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04983.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.5335477653105,
                "width": 349.4930472426055,
                "x": 268.64646282021965,
                "y": 57.26633063252331
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04980.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.27342263463424,
                "width": 269.48861474128614,
                "x": 348.650895321539,
                "y": 3.368607684266077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04973.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.4815227391752,
                "width": 355.38811069007113,
                "x": 186.11557455570076,
                "y": 259.38279168848794
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04969.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.43304371409545,
                "width": 224.01241100369407,
                "x": 525.502798745508,
                "y": 270.3307666623527
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04963.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.0608900287739,
                "width": 407.60152979619534,
                "x": 513.7126718505767,
                "y": 138.11291505490917
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04955.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.26987663357875,
                "width": 82.53088826451892,
                "x": 760.4631847230669,
                "y": 266.9621589780866
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04939.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.05911702824616,
                "width": 399.1800105855301,
                "x": 510.34406416631066,
                "y": 228.2231706090267
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04917.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.21785160744352,
                "width": 195.3792456874325,
                "x": 288.01595700474957,
                "y": 230.7496263722263
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04904.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.42949771304,
                "width": 132.21785160744355,
                "x": 607.1915350889603,
                "y": 344.4401357162064
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04899.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.58557279144571,
                "width": 126.32278815997779,
                "x": 808.4658442238585,
                "y": 274.5415262676853
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04890.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.38013218769632,
                "width": 405.07507403299576,
                "x": 517.0812795348428,
                "y": 128.84924392317745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04883.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 2.5264557631995785,
                "width": 1.6843038421330903,
                "x": 917.945593962506,
                "y": 760.4631847230669
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04876.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.32367466024175,
                "width": 332.65000882127515,
                "x": 411.8122894015279,
                "y": 112.84835742291358
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04875.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.38013218769635,
                "width": 95.1631670805167,
                "x": 648.4569792212199,
                "y": 405.9172259540623
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04861.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.79544589651445,
                "width": 138.11291505490914,
                "x": 310.7540588735456,
                "y": 55.58202679039027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04848.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.32278815997788,
                "width": 256.0141840042218,
                "x": 359.59887029540374,
                "y": 223.1702590826276
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04841.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.69139584424397,
                "width": 122.11202855464524,
                "x": 805.939388460659,
                "y": 266.9621589780866
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04822.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.5353207658382,
                "width": 249.27696863568974,
                "x": 757.0945770388008,
                "y": 7.5793672895986735
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04806.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.2760821354258,
                "width": 106.95329397544793,
                "x": 202.11646105596463,
                "y": 47.16050757972508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04792.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.06000352851004,
                "width": 371.38899719033503,
                "x": 341.9136799530068,
                "y": 64.00354600105547
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04778.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.69671484582716,
                "width": 181.06266302930158,
                "x": 515.3969756927098,
                "y": 451.3934296916543
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04774.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.74696687143467,
                "width": 133.90215544957653,
                "x": 128.00709200211094,
                "y": 479.18444308684946
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04771.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.37924568743244,
                "width": 342.75583187407335,
                "x": 756.2524251177343,
                "y": 177.69405534503557
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04762.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.1146880554369,
                "width": 401.7064663487297,
                "x": 522.9763429823084,
                "y": 177.69405534503557
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04728.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.95595347623953,
                "width": 201.2743091348981,
                "x": 613.9287504574926,
                "y": 342.75583187407335
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04721.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.2716496341065,
                "width": 249.27696863568963,
                "x": 976.0540765160958,
                "y": 211.38013218769635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04714.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.21519210665195,
                "width": 125.48063623891142,
                "x": 733.5143232489382,
                "y": 280.4365897151509
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04706.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.95595347623953,
                "width": 116.21696510717959,
                "x": 604.6650793257609,
                "y": 356.2302626111377
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04683.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.74608037117076,
                "width": 361.28317413753666,
                "x": 784.0434385129295,
                "y": 375.5997567956676
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04578.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.58645929170962,
                "width": 325.0706415316764,
                "x": 402.5486182697962,
                "y": 279.5944377940844
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04574.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.5882322922373,
                "width": 288.0159570047497,
                "x": 922.1563535678386,
                "y": 211.38013218769635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04561.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.22051110823514,
                "width": 264.4357032148871,
                "x": 755.4102731966677,
                "y": 3.368607684266077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04552.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.74785337169857,
                "width": 133.06000352851007,
                "x": 135.5864592917096,
                "y": 144.00797850237478
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04545.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.2169651071797,
                "width": 66.53000176425508,
                "x": 871.6272383038474,
                "y": 288.01595700474957
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04543.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00620550184703,
                "width": 213.90658795089593,
                "x": 210.5379802666298,
                "y": 330.1235530580756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04542.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.16671308157214,
                "width": 86.74164786985148,
                "x": 202.11646105596463,
                "y": 320.85988192634386
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04528.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.32101515945016,
                "width": 203.80076489809767,
                "x": 292.2267166100822,
                "y": 376.44190871673413
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04513.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.64114381863646,
                "width": 208.85367642449674,
                "x": 193.69494184529944,
                "y": 48.002659500791594
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04471.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.85190342396908,
                "width": 126.3227881599779,
                "x": 658.562802274018,
                "y": 151.58734579197346
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04412.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.11734755622842,
                "width": 212.2222841087629,
                "x": 533.0821660351066,
                "y": 398.3378586644636
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04368.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.42949771304,
                "width": 147.3765861866408,
                "x": 638.3511561684217,
                "y": 327.597097294876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04362.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.9568399765034,
                "width": 384.02127600633276,
                "x": 564.241787114568,
                "y": 63.161394079988945
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04361.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.3254476607695,
                "width": 241.697601346091,
                "x": 392.442795216998,
                "y": 0.8421519210665193
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04346.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.4824092394391,
                "width": 598.7700158782951,
                "x": 632.456092720956,
                "y": 607.1915350889603
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04340.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.58823229223734,
                "width": 394.96925098019756,
                "x": 514.5548237716432,
                "y": 54.73987486932375
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04336.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.48329573970295,
                "width": 404.2329221119292,
                "x": 490.1324180607142,
                "y": 46.31835565865856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04326.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.69228234450784,
                "width": 403.3907701908628,
                "x": 488.44811421858117,
                "y": 49.686963342924635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04320.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.58823229223734,
                "width": 241.69760134609112,
                "x": 736.8829309332043,
                "y": 164.21962460797127
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04308.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.22317060902674,
                "width": 253.4877282410223,
                "x": 526.3449506665745,
                "y": 256.85633592528836
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04307.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.11646105596463,
                "width": 173.48329573970295,
                "x": 769.7268558547986,
                "y": 345.2822876372729
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04296.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.01329750395792,
                "width": 563.3996351935012,
                "x": 613.9287504574926,
                "y": 537.2929256404393
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04248.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.0106380031665,
                "width": 480.02659500791606,
                "x": 612.2444466153595,
                "y": 588.6641928254969
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04229.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.0088650026387,
                "width": 110.32190165971406,
                "x": 630.7717888788229,
                "y": 201.2743091348981
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04220.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 221.4859552404946,
                "width": 195.3792456874325,
                "x": 492.6588738239138,
                "y": 476.6579873236499
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04196.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 62.31924215892241,
                "width": 144.00797850237478,
                "x": 256.0141840042219,
                "y": 372.2311491114015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04187.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.3227881599779,
                "width": 91.79455939625063,
                "x": 746.146602064936,
                "y": 284.6473493204835
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04164.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 242.53975326715752,
                "width": 327.5970972948761,
                "x": 751.1995135913352,
                "y": 138.11291505490917
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04154.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.16671308157214,
                "width": 229.06532253009323,
                "x": 659.4049541950845,
                "y": 328.43924921594254
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04147.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.9568399765034,
                "width": 196.22139760849896,
                "x": 202.95861297703115,
                "y": 47.16050757972508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04098.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.3721536853215,
                "width": 158.3245611605056,
                "x": 704.0390060116101,
                "y": 294.75317237328176
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04086.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.483295739703,
                "width": 378.9683644799337,
                "x": 402.5486182697962,
                "y": 108.63759781758098
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04062.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.59000529276506,
                "width": 407.60152979619534,
                "x": 528.0292545087076,
                "y": 159.16671308157214
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04031.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.4815227391752,
                "width": 343.59798379513984,
                "x": 746.146602064936,
                "y": 296.4374762154148
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04025.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.00975150290253,
                "width": 174.3254476607695,
                "x": 214.7487398719624,
                "y": 48.84481142185812
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04018.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.00886500263863,
                "width": 435.3925431913905,
                "x": 565.0839390356344,
                "y": 335.1764645844747
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04008.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.0088650026387,
                "width": 196.22139760849896,
                "x": 215.59089179302893,
                "y": 52.21341910612419
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03932.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26899013331493,
                "width": 328.43924921594254,
                "x": 344.4401357162064,
                "y": 252.64557631995578
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03904.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 277.0679820308848,
                "width": 271.17291858341923,
                "x": 688.8802714324128,
                "y": 266.9621589780866
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03877.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.22051110823514,
                "width": 188.6420303189003,
                "x": 642.5619157737542,
                "y": 331.8078569002086
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03862.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.95772647676728,
                "width": 64.0035460010555,
                "x": 488.44811421858117,
                "y": 474.97368348151684
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03860.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.22228410876286,
                "width": 354.5459587690045,
                "x": 741.093690538537,
                "y": 175.16759958183601
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03859.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.64114381863646,
                "width": 87.58379979091808,
                "x": 439.603302796723,
                "y": 39.581140290126406
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03858.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.48329573970298,
                "width": 182.7469668714347,
                "x": 197.0635495295655,
                "y": 48.002659500791594
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03851.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.1146880554369,
                "width": 170.9568399765034,
                "x": 212.22228410876286,
                "y": 55.58202679039027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03845.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.16937258236374,
                "width": 384.86342792739924,
                "x": 536.4507737193728,
                "y": 33.68607684266077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03808.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00620550184703,
                "width": 67.37215368532156,
                "x": 606.3493831678938,
                "y": 569.294698640967
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03785.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.74430737064313,
                "width": 562.557483272435,
                "x": 616.455206220692,
                "y": 606.3493831678938
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03780.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.1658265813083,
                "width": 349.4930472426055,
                "x": 757.0945770388008,
                "y": 299.80608389968086
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03746.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.79633239677833,
                "width": 80.84658442238583,
                "x": 796.6757173289272,
                "y": 277.91013395195137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03736.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.53620726610208,
                "width": 127.16494008104439,
                "x": 633.2982446420225,
                "y": 195.37924568743247
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03730.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.16405358078052,
                "width": 82.53088826451881,
                "x": 982.791291884628,
                "y": 249.2769686356897
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03709.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.06177652903776,
                "width": 330.1235530580755,
                "x": 350.33519916367203,
                "y": 5.895063447465635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03698.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.59177829329278,
                "width": 314.9648184788782,
                "x": 423.6024162964592,
                "y": 195.37924568743247
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03693.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.27164963410652,
                "width": 452.2355816127208,
                "x": 625.7188773524238,
                "y": 204.64291681916418
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03687.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.22317060902668,
                "width": 268.64646282021954,
                "x": 527.1871025876411,
                "y": 400.02216250659666
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03673.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.64114381863646,
                "width": 373.91545295353455,
                "x": 726.7771078804061,
                "y": 69.05645752745458
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03666.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.43215721383157,
                "width": 336.0186165055412,
                "x": 750.3573616702687,
                "y": 181.90481495036815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03656.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.11291505490917,
                "width": 373.91545295353455,
                "x": 481.71089885004903,
                "y": 102.74253437011535
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03636.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.90481495036815,
                "width": 136.4286112127761,
                "x": 708.2497656169427,
                "y": 221.48595524049458
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03634.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.64025731837256,
                "width": 352.86165492687144,
                "x": 719.1977405908075,
                "y": 59.79278639572287
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03625.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.32367466024175,
                "width": 144.00797850237478,
                "x": 415.180897085794,
                "y": 80.00443250131933
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03623.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.3316531626165,
                "width": 517.9234314559093,
                "x": 609.7179908521599,
                "y": 487.6059622975147
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03620.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.16848608209986,
                "width": 448.86697392845474,
                "x": 496.8696334292464,
                "y": 160.00886500263866
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03616.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.59000529276506,
                "width": 394.96925098019756,
                "x": 376.44190871673413,
                "y": 142.32367466024175
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03606.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.11557455570076,
                "width": 411.8122894015279,
                "x": 528.8714064297741,
                "y": 163.37747268690472
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03603.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.27519563516205,
                "width": 141.48152273917526,
                "x": 709.0919175380092,
                "y": 439.603302796723
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03586.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.95861297703112,
                "width": 277.91013395195137,
                "x": 422.7602643753927,
                "y": 107.79544589651447
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03579.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.32722066129725,
                "width": 542.3458371668384,
                "x": 534.7664698772397,
                "y": 533.0821660351066
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03576.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.06443602982935,
                "width": 95.1631670805167,
                "x": 581.0848255358983,
                "y": 232.43393021435932
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03570.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.48418223996686,
                "width": 414.33874516472747,
                "x": 503.6068487977785,
                "y": 133.06000352851004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03552.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.48329573970295,
                "width": 250.9612724778226,
                "x": 1049.321293648883,
                "y": 714.1448290644083
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03544.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.79633239677834,
                "width": 369.704693348202,
                "x": 340.2293761108738,
                "y": 61.477090237855904
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03524.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.53000176425502,
                "width": 143.16582658130824,
                "x": 706.5654617748097,
                "y": 272.0150705044857
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03516.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 293.06886853114867,
                "width": 348.650895321539,
                "x": 586.9798889833639,
                "y": 33.68607684266077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03515.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 315.8069703999447,
                "width": 376.44190871673413,
                "x": 624.0345735102908,
                "y": 247.59266479355665
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03512.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.4841822399668,
                "width": 170.9568399765035,
                "x": 674.5636887742819,
                "y": 420.2338086121931
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03501.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.32544766076947,
                "width": 254.3298801620889,
                "x": 764.6739443283994,
                "y": 5.895063447465635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03411.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.85544942502452,
                "width": 233.27608213542584,
                "x": 409.28583363832837,
                "y": 203.80076489809767
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03384.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.42861121277613,
                "width": 193.6949418452994,
                "x": 319.1755780842108,
                "y": 237.48684174075842
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03381.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.11202855464529,
                "width": 103.58468629118192,
                "x": 816.0452115134572,
                "y": 279.5944377940844
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03376.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.8554494250245,
                "width": 128.84924392317743,
                "x": 197.90570145063202,
                "y": 43.791899895459004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03369.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.59000529276508,
                "width": 148.2187381077074,
                "x": 682.9852079849471,
                "y": 213.9065879508959
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03360.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.11557455570073,
                "width": 324.2284896106099,
                "x": 639.1933080894881,
                "y": 334.3343126634081
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03357.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.6931688447717,
                "width": 412.6544413225944,
                "x": 490.97456998178075,
                "y": 133.90215544957655
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03348.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.9039284501043,
                "width": 374.75760487460104,
                "x": 506.9754564820446,
                "y": 57.26633063252331
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03320.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.69228234450784,
                "width": 415.18089708579396,
                "x": 200.43215721383157,
                "y": 141.48152273917523
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03293.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.9568399765034,
                "width": 426.97102398072536,
                "x": 520.4498872191089,
                "y": 122.95418047571181
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03264.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.22317060902674,
                "width": 193.69494184529947,
                "x": 509.50191224524417,
                "y": 451.3934296916543
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03237.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.22317060902674,
                "width": 149.9030419498404,
                "x": 175.16759958183601,
                "y": 48.002659500791594
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03215.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.85101692370517,
                "width": 272.0150705044857,
                "x": 946.5787592787676,
                "y": 210.5379802666298
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03212.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.00975150290253,
                "width": 239.17114558289143,
                "x": 386.54773176953233,
                "y": 2.5264557631995577
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03153.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.22051110823514,
                "width": 414.3387451647274,
                "x": 507.81760840311114,
                "y": 122.11202855464529
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03151.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.16937258236368,
                "width": 355.388110690071,
                "x": 771.4111596969317,
                "y": 350.33519916367203
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03150.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.11734755622848,
                "width": 107.79544589651448,
                "x": 574.3476101673662,
                "y": 233.27608213542584
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03141.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.80076489809767,
                "width": 346.9665914794059,
                "x": 759.6210328020004,
                "y": 174.3254476607695
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03107.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.7469668714347,
                "width": 220.64380331942803,
                "x": 189.48418223996683,
                "y": 47.16050757972508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03106.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.85544942502452,
                "width": 133.06000352851004,
                "x": 534.7664698772397,
                "y": 442.1297585599226
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03067.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.95506697597568,
                "width": 399.1800105855301,
                "x": 405.07507403299576,
                "y": 696.4596387220114
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03041.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.64203031890037,
                "width": 194.537093766366,
                "x": 456.4463412180534,
                "y": 508.6597603241776
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03038.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.48152273917526,
                "width": 378.9683644799337,
                "x": 497.7117853503129,
                "y": 42.10759605332596
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03021.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.11291505490914,
                "width": 375.5997567956676,
                "x": 236.6446898196919,
                "y": 43.791899895459004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03017.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.7460803711708,
                "width": 282.9630454783505,
                "x": 944.8944554366346,
                "y": 221.48595524049458
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03003.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.00797850237478,
                "width": 179.3783591871686,
                "x": 263.59355129382055,
                "y": 183.5891187925012
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02996.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.8527899242329,
                "width": 336.0186165055411,
                "x": 736.0407790121378,
                "y": 181.90481495036815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02994.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 332.6500088212751,
                "width": 128.00709200211094,
                "x": 342.75583187407335,
                "y": 261.90924745168746
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02940.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.79544589651445,
                "width": 357.9145664532707,
                "x": 339.3872241898073,
                "y": 241.69760134609103
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02886.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.06000352851004,
                "width": 91.79455939625063,
                "x": 546.556596772171,
                "y": 533.9243179561732
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02883.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.3748131861131,
                "width": 72.42506521172072,
                "x": 575.1897620884326,
                "y": 259.38279168848794
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02875.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.95861297703112,
                "width": 480.86874692898243,
                "x": 432.0239355071244,
                "y": 96.84747092264972
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02868.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.32544766076944,
                "width": 233.27608213542578,
                "x": 413.496593243661,
                "y": 442.1297585599226
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02862.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.85367642449677,
                "width": 179.3783591871686,
                "x": 592.0328005097631,
                "y": 320.0177300052773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02823.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.47797673811976,
                "width": 195.37924568743256,
                "x": 901.9447074622421,
                "y": 426.12887205965876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02820.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.42861121277613,
                "width": 387.3898836905989,
                "x": 255.17203208315533,
                "y": 58.95063447465635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02794.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.58557279144573,
                "width": 360.4410222164703,
                "x": 241.69760134609103,
                "y": 52.21341910612419
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02762.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.85367642449677,
                "width": 264.43570321488704,
                "x": 13.474430737064308,
                "y": 341.0715280319403
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02689.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.06089002877388,
                "width": 74.10936905385364,
                "x": 440.4454547177896,
                "y": 370.5468452692685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02664.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.79810539730605,
                "width": 214.7487398719624,
                "x": 337.70292034767425,
                "y": 198.74785337169854
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02662.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.01152450343028,
                "width": 137.2707631338426,
                "x": 624.0345735102908,
                "y": 419.39165669112657
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02635.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.37658618664085,
                "width": 374.75760487460104,
                "x": 237.48684174075842,
                "y": 51.371267185057675
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02630.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.53443426557436,
                "width": 284.6473493204835,
                "x": 320.85988192634386,
                "y": 213.06443602982938
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02605.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.8501304234413,
                "width": 399.1800105855301,
                "x": 441.2876066388561,
                "y": 91.7945593962506
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02593.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.4286112127761,
                "width": 351.1773510847385,
                "x": 280.4365897151509,
                "y": 55.58202679039027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02586.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.5379802666298,
                "width": 118.74342087037917,
                "x": 621.5081177470912,
                "y": 414.33874516472747
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02583.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.4850687402307,
                "width": 450.5512777705878,
                "x": 434.5503912703239,
                "y": 244.22405710929058
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02572.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.69228234450782,
                "width": 196.22139760849902,
                "x": 163.37747268690472,
                "y": 272.85722242555227
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02492.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.43038421330385,
                "width": 201.27430913489812,
                "x": 215.59089179302893,
                "y": 47.16050757972508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02488.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.7460803711708,
                "width": 384.86342792739936,
                "x": 519.6077352980424,
                "y": 128.84924392317745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02480.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.74519387090695,
                "width": 329.28140113700897,
                "x": 339.3872241898073,
                "y": 215.59089179302893
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02477.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.7478533716985,
                "width": 436.23469511245696,
                "x": 495.1853295871133,
                "y": 146.53443426557436
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02456.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.63937081810872,
                "width": 112.00620550184709,
                "x": 412.65444132259444,
                "y": 36.212532605860325
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02453.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.5900052927651,
                "width": 549.9252044564371,
                "x": 681.300904142814,
                "y": 581.0848255358983
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02452.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.95329397544793,
                "width": 124.63848431784481,
                "x": 745.3044501438695,
                "y": 285.48950124155004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02437.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.96038597755893,
                "width": 215.59089179302896,
                "x": 436.23469511245696,
                "y": 502.764696876712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02436.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.85190342396905,
                "width": 262.751399372754,
                "x": 762.1474885652,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02425.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.0617765290378,
                "width": 162.53532076583818,
                "x": 212.22228410876286,
                "y": 58.10848255358983
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02408.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.00975150290253,
                "width": 165.0617765290378,
                "x": 218.11734755622848,
                "y": 44.63405181652552
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.79810539730607,
                "width": 379.8105164010002,
                "x": 709.0919175380092,
                "y": 95.16316708051667
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02392.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.95329397544793,
                "width": 146.5344342655743,
                "x": 741.9358424596035,
                "y": 284.6473493204835
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02376.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.3254476607695,
                "width": 379.8105164010002,
                "x": 506.9754564820446,
                "y": 47.16050757972508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02373.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 63.16139407998895,
                "width": 186.11557455570076,
                "x": 230.7496263722263,
                "y": 341.9136799530068
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02362.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 230.74962637222626,
                "width": 103.5846862911819,
                "x": 208.01152450343025,
                "y": 61.477090237855904
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02361.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.95595347623953,
                "width": 580.2426736148317,
                "x": 650.9834349844194,
                "y": 635.8247004052221
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02342.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.1631670805167,
                "width": 141.48152273917526,
                "x": 818.5716672766567,
                "y": 264.43570321488704
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02328.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.32101515945016,
                "width": 339.3872241898073,
                "x": 333.49216074234164,
                "y": 257.6984878463549
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02326.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.42949771304,
                "width": 266.12000705701996,
                "x": 960.053190015832,
                "y": 203.80076489809767
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02273.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.79633239677831,
                "width": 187.79987839783382,
                "x": 392.442795216998,
                "y": 77.47797673811978
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02250.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.85190342396905,
                "width": 200.43215721383157,
                "x": 193.69494184529944,
                "y": 43.791899895459004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02229.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.63848431784487,
                "width": 218.95949947729503,
                "x": 673.7215368532154,
                "y": 336.8607684266077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02185.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.483295739703,
                "width": 111.16405358078055,
                "x": 734.3564751700048,
                "y": 416.0230490068605
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02182.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.3765861866409,
                "width": 109.47974973864751,
                "x": 210.5379802666298,
                "y": 278.75228587301785
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02178.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.32633416103334,
                "width": 127.16494008104439,
                "x": 650.9834349844194,
                "y": 160.85101692370517
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02174.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.58823229223734,
                "width": 123.79633239677833,
                "x": 670.3529291689493,
                "y": 133.90215544957655
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02151.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.58734579197346,
                "width": 416.86520092792705,
                "x": 628.2453331156233,
                "y": 67.37215368532154
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02148.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.74342087037921,
                "width": 220.64380331942812,
                "x": 689.7224233534793,
                "y": 89.26810363305104
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02120.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.06532253009323,
                "width": 115.37481318611316,
                "x": 199.59000529276506,
                "y": 46.31835565865856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02112.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.21430560638805,
                "width": 224.01241100369413,
                "x": 224.01241100369413,
                "y": 325.0706415316764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02109.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.06000352851004,
                "width": 265.27785513595364,
                "x": 428.6553278228583,
                "y": 305.7011473471465
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02108.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.74430737064307,
                "width": 218.11734755622842,
                "x": 604.6650793257609,
                "y": 339.3872241898073
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02106.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.48418223996683,
                "width": 341.91367995300675,
                "x": 742.77799438067,
                "y": 122.95418047571181
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02086.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.2725361343704,
                "width": 90.95240747518409,
                "x": 320.0177300052773,
                "y": 286.33165316261653
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02069.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.21696510717965,
                "width": 283.805197399417,
                "x": 237.48684174075842,
                "y": 327.597097294876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02063.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.32367466024175,
                "width": 318.3334261631443,
                "x": 522.9763429823084,
                "y": 171.79899189756992
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02047.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.22139760849896,
                "width": 111.16405358078055,
                "x": 568.4525467199005,
                "y": 243.38190518822407
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02034.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.58911879250115,
                "width": 112.84835742291364,
                "x": 547.3987486932375,
                "y": 420.2338086121931
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02032.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.2160786069158,
                "width": 157.4824092394391,
                "x": 869.9429344617143,
                "y": 253.4877282410223
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02012.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 253.4877282410223,
                "width": 239.17114558289154,
                "x": 374.75760487460104,
                "y": 114.53266126504661
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01992.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.85101692370517,
                "width": 197.90570145063202,
                "x": 274.5415262676853,
                "y": 123.79633239677833
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01990.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.9577264767673,
                "width": 115.3748131861131,
                "x": 629.9296369577564,
                "y": 181.90481495036815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01985.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.1631670805167,
                "width": 93.47886323838361,
                "x": 791.6228058025281,
                "y": 286.33165316261653
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01980.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.5362072661021,
                "width": 546.5565967721709,
                "x": 605.5072312468274,
                "y": 566.7682428777674
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01975.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.5370937663659,
                "width": 368.8625414271355,
                "x": 765.516096249466,
                "y": 362.9674779796698
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01948.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.85278992423287,
                "width": 120.42772471251226,
                "x": 747.8309059070691,
                "y": 389.0741875327319
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01936.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.42772471251232,
                "width": 477.5001392447164,
                "x": 357.07241453220416,
                "y": 437.91899895459
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01934.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.89860944852114,
                "width": 149.90304194984037,
                "x": 657.7206503529516,
                "y": 269.48861474128614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01931.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.1667130815722,
                "width": 174.32544766076956,
                "x": 646.7726753790868,
                "y": 405.07507403299576
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01919.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.79544589651448,
                "width": 202.95861297703115,
                "x": 187.7998783978338,
                "y": 369.70469334820194
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01911.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.90304194984043,
                "width": 90.11025555411754,
                "x": 648.4569792212199,
                "y": 348.650895321539
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01902.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.3801321876963,
                "width": 121.26987663357875,
                "x": 638.3511561684217,
                "y": 404.23292211192927
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01896.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.16671308157214,
                "width": 153.27164963410644,
                "x": 632.456092720956,
                "y": 332.6500088212751
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01884.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.21696510717959,
                "width": 146.5344342655743,
                "x": 488.44811421858117,
                "y": 567.610394798834
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01869.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.3254476607695,
                "width": 178.53620726610208,
                "x": 197.0635495295655,
                "y": 48.84481142185812
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01858.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.21696510717965,
                "width": 312.43836271567864,
                "x": 349.4930472426055,
                "y": 229.90747445115977
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01810.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.11557455570076,
                "width": 435.3925431913905,
                "x": 528.8714064297741,
                "y": 46.31835565865856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01790.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.1684860820999,
                "width": 181.06266302930163,
                "x": 144.00797850237478,
                "y": 325.0706415316764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01763.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.0617765290378,
                "width": 197.0635495295655,
                "x": 198.74785337169854,
                "y": 48.84481142185812
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01756.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.11912055675623,
                "width": 322.54418576847695,
                "x": 597.9278639572286,
                "y": 32.001773000527734
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01738.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.85190342396902,
                "width": 170.95683997650337,
                "x": 642.5619157737542,
                "y": 398.3378586644636
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01729.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.38013218769635,
                "width": 193.69494184529947,
                "x": 695.6174868009449,
                "y": 421.91811245432615
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01728.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.00709200211094,
                "width": 223.17025908262758,
                "x": 599.6121677993617,
                "y": 362.9674779796698
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01699.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.5370937663659,
                "width": 168.4303842133039,
                "x": 667.8264734057498,
                "y": 455.60418929698693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01686.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.537093766366,
                "width": 188.6420303189003,
                "x": 441.2876066388561,
                "y": 484.23735461324856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01683.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.79899189756992,
                "width": 416.86520092792705,
                "x": 558.3467236671023,
                "y": 73.26721713278718
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01663.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.79987839783377,
                "width": 189.4841822399668,
                "x": 598.7700158782952,
                "y": 346.96659147940596
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01655.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.63671131731712,
                "width": 327.59709729487605,
                "x": 338.54507226874074,
                "y": 255.17203208315533
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01652.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.74430737064307,
                "width": 369.704693348202,
                "x": 473.2893796393838,
                "y": 119.58557279144574
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01554.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.16671308157208,
                "width": 388.2320356116653,
                "x": 745.3044501438695,
                "y": 583.6112812990979
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01540.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.89949594878493,
                "width": 98.53177476478288,
                "x": 955.8424304104993,
                "y": 337.70292034767425
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01529.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.95506697597568,
                "width": 376.44190871673413,
                "x": 395.81140290126405,
                "y": 125.48063623891137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01480.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.01063800316638,
                "width": 333.49216074234164,
                "x": 760.4631847230669,
                "y": 183.5891187925012
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01478.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.0000000000001,
                "width": 146.0000000000001,
                "x": 521.0000000000002,
                "y": 515.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01466.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.00000000000006,
                "width": 188.0000000000001,
                "x": 475.0000000000002,
                "y": 446.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01460.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.00000000000006,
                "width": 177.0000000000001,
                "x": 633.0000000000002,
                "y": 356.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01448.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.00000000000006,
                "width": 92.0,
                "x": 769.0000000000003,
                "y": 265.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01434.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.0000000000001,
                "width": 108.00000000000011,
                "x": 564.0000000000002,
                "y": 239.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01433.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.00000000000009,
                "width": 372.0000000000001,
                "x": 510.0000000000002,
                "y": 58.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01390.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.00000000000006,
                "width": 366.0000000000001,
                "x": 69.00000000000003,
                "y": 354.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01374.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 303.0000000000001,
                "width": 668.0000000000002,
                "x": 127.00000000000006,
                "y": 576.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01363.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.00000000000006,
                "width": 375.0000000000001,
                "x": 239.0000000000001,
                "y": 59.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01357.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.00000000000009,
                "width": 265.0000000000001,
                "x": 754.0000000000003,
                "y": 6.000000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01333.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.00000000000006,
                "width": 156.0000000000001,
                "x": 518.0000000000002,
                "y": 295.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01287.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.00000000000006,
                "width": 77.0,
                "x": 976.0000000000005,
                "y": 317.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01273.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.0000000000001,
                "width": 477.00000000000017,
                "x": 405.00000000000017,
                "y": 273.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01268.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.0000000000001,
                "width": 501.0000000000002,
                "x": 613.0000000000002,
                "y": 589.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01238.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.00000000000006,
                "width": 350.0000000000001,
                "x": 256.0000000000001,
                "y": 52.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01207.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.00000000000006,
                "width": 358.0000000000001,
                "x": 242.0000000000001,
                "y": 62.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01206.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.00000000000006,
                "width": 136.00000000000009,
                "x": 197.00000000000009,
                "y": 277.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01197.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.00000000000006,
                "width": 351.0000000000001,
                "x": 882.0000000000003,
                "y": 263.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01196.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.00000000000009,
                "width": 373.0000000000001,
                "x": 718.0000000000003,
                "y": 219.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01186.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.00000000000006,
                "width": 114.0,
                "x": 715.0000000000003,
                "y": 330.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01141.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.00000000000009,
                "width": 274.0000000000001,
                "x": 749.0000000000003,
                "y": 2.000000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01139.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.0000000000001,
                "width": 367.00000000000017,
                "x": 141.00000000000006,
                "y": 311.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01129.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.00000000000009,
                "width": 228.0000000000001,
                "x": 276.0000000000001,
                "y": 209.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01127.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.00000000000006,
                "width": 161.0,
                "x": 678.0000000000003,
                "y": 266.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01125.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.0000000000001,
                "width": 85.0,
                "x": 724.0000000000003,
                "y": 306.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01117.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.00000000000006,
                "width": 198.00000000000009,
                "x": 193.00000000000009,
                "y": 46.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01110.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.00000000000006,
                "width": 389.0000000000002,
                "x": 525.0000000000002,
                "y": 135.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01109.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.00000000000006,
                "width": 367.0000000000001,
                "x": 214.00000000000009,
                "y": 120.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01079.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.00000000000009,
                "width": 333.0000000000001,
                "x": 748.0000000000003,
                "y": 183.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01077.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.0,
                "width": 50.000000000000114,
                "x": 627.0000000000002,
                "y": 532.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01070.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.0000000000001,
                "width": 77.00000000000006,
                "x": 407.00000000000017,
                "y": 297.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01056.jpg"
    },
    {
        "annotations": [],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01047.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.00000000000003,
                "width": 206.0000000000001,
                "x": 283.0000000000001,
                "y": 167.00000000000009
            },
            {
                "class": "rect",
                "height": 201.00000000000009,
                "width": 358.0000000000001,
                "x": 728.0000000000003,
                "y": 175.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01032.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.00000000000006,
                "width": 360.0000000000001,
                "x": 791.0000000000003,
                "y": 256.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01025.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.00000000000009,
                "width": 253.0000000000001,
                "x": 755.0000000000003,
                "y": 8.000000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01023.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.00000000000009,
                "width": 237.0000000000001,
                "x": 283.0000000000001,
                "y": 206.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01021.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 75.00000000000006,
                "width": 139.0,
                "x": 714.0000000000003,
                "y": 281.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01014.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.00000000000006,
                "width": 134.0000000000001,
                "x": 550.0000000000002,
                "y": 234.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01009.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.00000000000006,
                "width": 119.0,
                "x": 753.0000000000003,
                "y": 277.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01001.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.00000000000006,
                "width": 237.0000000000001,
                "x": 513.0000000000002,
                "y": 408.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00984.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.00000000000006,
                "width": 180.0000000000001,
                "x": 545.0000000000002,
                "y": 415.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00975.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.00000000000006,
                "width": 167.0,
                "x": 699.0000000000003,
                "y": 298.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00928.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.00000000000006,
                "width": 195.0,
                "x": 677.0000000000003,
                "y": 359.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00911.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.0000000000001,
                "width": 142.00000000000006,
                "x": 149.00000000000006,
                "y": 135.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00901.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.00000000000006,
                "width": 313.0000000000001,
                "x": 485.0000000000002,
                "y": 48.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00885.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.00000000000006,
                "width": 215.0000000000001,
                "x": 700.0000000000003,
                "y": 282.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00881.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.00000000000006,
                "width": 217.0000000000001,
                "x": 596.0000000000002,
                "y": 342.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00866.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.00000000000006,
                "width": 266.00000000000017,
                "x": 436.00000000000017,
                "y": 254.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00863.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.00000000000006,
                "width": 163.0000000000001,
                "x": 300.0000000000001,
                "y": 286.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00834.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 327.00000000000017,
                "width": 353.0000000000001,
                "x": 541.0000000000002,
                "y": 134.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00829.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.00000000000006,
                "width": 140.0000000000001,
                "x": 624.0000000000002,
                "y": 410.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00824.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.00000000000006,
                "width": 102.0,
                "x": 773.0000000000003,
                "y": 252.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00820.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.00000000000009,
                "width": 359.0000000000001,
                "x": 276.0000000000001,
                "y": 47.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00793.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.00000000000009,
                "width": 122.00000000000011,
                "x": 613.0000000000002,
                "y": 208.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00782.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.0000000000001,
                "width": 541.0000000000002,
                "x": 599.0000000000002,
                "y": 596.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00762.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.00000000000006,
                "width": 194.0000000000001,
                "x": 588.0000000000002,
                "y": 343.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00744.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.00000000000009,
                "width": 140.0000000000001,
                "x": 578.0000000000002,
                "y": 80.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00742.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.00000000000009,
                "width": 111.00000000000011,
                "x": 630.0000000000002,
                "y": 190.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00741.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.0,
                "width": 280.0000000000001,
                "x": 165.00000000000009,
                "y": 364.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00722.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.0000000000001,
                "width": 218.0000000000001,
                "x": 503.0000000000002,
                "y": 509.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00719.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.0000000000001,
                "width": 500.0000000000002,
                "x": 614.0000000000002,
                "y": 306.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00706.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.0000000000001,
                "width": 378.0000000000001,
                "x": 495.0000000000002,
                "y": 30.000000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00687.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.00000000000006,
                "width": 193.00000000000009,
                "x": 187.00000000000009,
                "y": 376.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00684.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.00000000000006,
                "width": 265.0000000000001,
                "x": 301.0000000000001,
                "y": 35.000000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00665.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.00000000000006,
                "width": 134.0,
                "x": 646.0000000000003,
                "y": 375.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00660.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.00000000000006,
                "width": 272.00000000000006,
                "x": 349.00000000000017,
                "y": 3.0000000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00653.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.00000000000006,
                "width": 115.0,
                "x": 738.0000000000003,
                "y": 232.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00636.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.00000000000006,
                "width": 174.00000000000009,
                "x": 203.00000000000009,
                "y": 40.000000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00632.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.0000000000001,
                "width": 452.0000000000001,
                "x": 641.0000000000003,
                "y": 539.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00594.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.00000000000003,
                "width": 202.0000000000001,
                "x": 472.0000000000002,
                "y": 164.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00568.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.00000000000006,
                "width": 121.0,
                "x": 688.0000000000003,
                "y": 364.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00508.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.00000000000006,
                "width": 464.0000000000002,
                "x": 482.0000000000002,
                "y": 387.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00496.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.00000000000006,
                "width": 406.0000000000001,
                "x": 699.0000000000003,
                "y": 358.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00461.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.00000000000006,
                "width": 105.0,
                "x": 452.0000000000002,
                "y": 126.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00425.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.00000000000006,
                "width": 151.0,
                "x": 709.0000000000003,
                "y": 271.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00403.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.00000000000006,
                "width": 350.0000000000001,
                "x": 257.0000000000001,
                "y": 60.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 242.00000000000009,
                "width": 108.00000000000006,
                "x": 306.0000000000001,
                "y": 174.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00361.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.00000000000003,
                "width": 362.0000000000002,
                "x": 564.0000000000002,
                "y": 164.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00337.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.00000000000009,
                "width": 340.0000000000001,
                "x": 744.0000000000003,
                "y": 8.000000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00327.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 80.00000000000006,
                "width": 180.0,
                "x": 685.0000000000003,
                "y": 273.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00319.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.00000000000009,
                "width": 328.00000000000017,
                "x": 368.00000000000017,
                "y": 217.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00301.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.00000000000006,
                "width": 131.0000000000001,
                "x": 558.0000000000002,
                "y": 233.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00294.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.00000000000009,
                "width": 440.0000000000002,
                "x": 509.0000000000002,
                "y": 172.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00290.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.0000000000001,
                "width": 200.0000000000001,
                "x": 504.0000000000002,
                "y": 459.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00278.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.00000000000006,
                "width": 394.0000000000001,
                "x": 655.0000000000003,
                "y": 237.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00277.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 336.0000000000002,
                "width": 773.0000000000005,
                "x": 129.00000000000006,
                "y": 561.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00248.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 59.0,
                "width": 160.0,
                "x": 659.0000000000003,
                "y": 322.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00237.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.00000000000006,
                "width": 178.0,
                "x": 695.0000000000003,
                "y": 281.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00236.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.00000000000006,
                "width": 133.0000000000001,
                "x": 616.0000000000002,
                "y": 419.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00233.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.0000000000001,
                "width": 150.0,
                "x": 450.0000000000002,
                "y": 490.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00219.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.00000000000009,
                "width": 87.0,
                "x": 510.0000000000002,
                "y": 187.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00215.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.00000000000006,
                "width": 120.00000000000011,
                "x": 625.0000000000002,
                "y": 352.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00209.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.00000000000006,
                "width": 186.00000000000009,
                "x": 198.00000000000009,
                "y": 54.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00206.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.00000000000006,
                "width": 188.0000000000001,
                "x": 637.0000000000002,
                "y": 329.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00197.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.00000000000006,
                "width": 355.0000000000001,
                "x": 796.0000000000003,
                "y": 321.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00090.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.00000000000006,
                "width": 208.00000000000006,
                "x": 403.00000000000017,
                "y": 121.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00074.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.0000000000001,
                "width": 120.00000000000006,
                "x": 438.00000000000017,
                "y": 498.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00057.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.00000000000006,
                "width": 200.00000000000009,
                "x": 182.00000000000009,
                "y": 367.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00055.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.00000000000009,
                "width": 330.0000000000001,
                "x": 755.0000000000003,
                "y": 186.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00041.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.00000000000006,
                "width": 101.0,
                "x": 752.0000000000003,
                "y": 243.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00038.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.00000000000006,
                "width": 247.0000000000001,
                "x": 230.0000000000001,
                "y": 330.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00015.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.0000000000001,
                "width": 337.0000000000001,
                "x": 806.0000000000003,
                "y": 315.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00003.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.00000000000006,
                "width": 353.0000000000001,
                "x": 827.0000000000003,
                "y": 258.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03458.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.00000000000009,
                "width": 468.0000000000002,
                "x": 520.0000000000002,
                "y": 168.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07917.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.00000000000006,
                "width": 130.0000000000001,
                "x": 618.0000000000002,
                "y": 347.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07903.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.00000000000006,
                "width": 357.0000000000001,
                "x": 252.0000000000001,
                "y": 56.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07892.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.00000000000006,
                "width": 119.00000000000011,
                "x": 626.0000000000002,
                "y": 407.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07890.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 269.0000000000001,
                "width": 154.0,
                "x": 993.0000000000005,
                "y": 537.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07878.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 236.00000000000006,
                "width": 122.00000000000011,
                "x": 639.0000000000002,
                "y": 400.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07876.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00000000000006,
                "width": 121.0,
                "x": 473.0000000000002,
                "y": 279.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07869.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 293.0000000000001,
                "width": 380.0000000000001,
                "x": 771.0000000000003,
                "y": 145.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07868.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.00000000000006,
                "width": 383.0000000000001,
                "x": 830.0000000000003,
                "y": 411.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07863.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 75.00000000000003,
                "width": 103.00000000000011,
                "x": 569.0000000000002,
                "y": 53.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07851.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.0000000000001,
                "width": 401.0000000000002,
                "x": 506.0000000000002,
                "y": 119.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07850.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.0,
                "width": 193.00000000000009,
                "x": 212.00000000000009,
                "y": 487.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07836.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.0000000000001,
                "width": 353.0000000000001,
                "x": 164.00000000000009,
                "y": 284.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07814.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.00000000000009,
                "width": 212.0000000000001,
                "x": 303.0000000000001,
                "y": 189.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07789.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00000000000006,
                "width": 223.0000000000001,
                "x": 152.00000000000006,
                "y": 346.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07773.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.00000000000004,
                "width": 397.0000000000001,
                "x": 494.0000000000002,
                "y": 99.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07767.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.00000000000009,
                "width": 435.0000000000002,
                "x": 531.0000000000002,
                "y": 64.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07766.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.00000000000006,
                "width": 161.0,
                "x": 452.0000000000002,
                "y": 301.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07755.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.00000000000006,
                "width": 127.00000000000011,
                "x": 797.0000000000003,
                "y": 264.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07740.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.00000000000006,
                "width": 109.00000000000011,
                "x": 637.0000000000002,
                "y": 406.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07739.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.00000000000006,
                "width": 255.00000000000009,
                "x": 172.00000000000009,
                "y": 374.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07730.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.00000000000006,
                "width": 113.0,
                "x": 714.0000000000003,
                "y": 327.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07727.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.00000000000009,
                "width": 340.00000000000017,
                "x": 348.00000000000017,
                "y": 212.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07709.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.00000000000006,
                "width": 46.000000000000114,
                "x": 862.0000000000003,
                "y": 284.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07681.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.00000000000006,
                "width": 82.0,
                "x": 763.0000000000003,
                "y": 296.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07672.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.00000000000006,
                "width": 373.0000000000002,
                "x": 541.0000000000002,
                "y": 146.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07671.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.00000000000006,
                "width": 113.0,
                "x": 454.0000000000002,
                "y": 321.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07670.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.0000000000001,
                "width": 111.0,
                "x": 524.0000000000002,
                "y": 525.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07669.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.00000000000006,
                "width": 159.00000000000009,
                "x": 210.00000000000009,
                "y": 48.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07668.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 258.0000000000001,
                "width": 292.0000000000001,
                "x": 573.0000000000002,
                "y": 463.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07657.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.00000000000009,
                "width": 384.00000000000017,
                "x": 377.00000000000017,
                "y": 204.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07647.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.0,
                "width": 187.00000000000009,
                "x": 164.00000000000009,
                "y": 343.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07640.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.00000000000006,
                "width": 376.0000000000001,
                "x": 228.0000000000001,
                "y": 50.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07617.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.00000000000003,
                "width": 385.0000000000002,
                "x": 640.0000000000002,
                "y": 190.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07614.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.00000000000006,
                "width": 144.0,
                "x": 703.0000000000003,
                "y": 281.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07604.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.00000000000006,
                "width": 202.0000000000001,
                "x": 617.0000000000002,
                "y": 353.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07603.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.00000000000006,
                "width": 162.0000000000001,
                "x": 762.0000000000003,
                "y": 342.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07587.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.00000000000006,
                "width": 420.0000000000002,
                "x": 531.0000000000002,
                "y": 140.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07576.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.00000000000006,
                "width": 314.00000000000017,
                "x": 397.00000000000017,
                "y": 271.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07567.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.00000000000006,
                "width": 376.0000000000002,
                "x": 615.0000000000002,
                "y": 322.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07560.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.00000000000009,
                "width": 436.0000000000002,
                "x": 543.0000000000002,
                "y": 181.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07558.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 59.0,
                "width": 148.0000000000001,
                "x": 548.0000000000002,
                "y": 321.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07554.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.00000000000006,
                "width": 133.0000000000001,
                "x": 606.0000000000002,
                "y": 337.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07542.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.00000000000006,
                "width": 362.0000000000001,
                "x": 249.0000000000001,
                "y": 53.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07540.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.00000000000009,
                "width": 374.00000000000017,
                "x": 383.00000000000017,
                "y": 209.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07527.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.00000000000006,
                "width": 67.0,
                "x": 797.0000000000003,
                "y": 292.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07522.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 308.00000000000017,
                "width": 327.0000000000001,
                "x": 669.0000000000003,
                "y": 143.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07511.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.00000000000006,
                "width": 87.00000000000011,
                "x": 835.0000000000003,
                "y": 293.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07492.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.00000000000009,
                "width": 205.0000000000001,
                "x": 301.0000000000001,
                "y": 213.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07489.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 263.0000000000001,
                "width": 402.0000000000002,
                "x": 589.0000000000002,
                "y": 97.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07476.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.00000000000006,
                "width": 95.0,
                "x": 778.0000000000003,
                "y": 253.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07470.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.0000000000001,
                "width": 346.0000000000001,
                "x": 758.0000000000003,
                "y": 577.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07465.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.00000000000006,
                "width": 480.0000000000002,
                "x": 454.0000000000002,
                "y": 363.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07463.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.00000000000006,
                "width": 91.00000000000006,
                "x": 304.0000000000001,
                "y": 381.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07461.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.00000000000006,
                "width": 140.00000000000006,
                "x": 393.00000000000017,
                "y": 417.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07454.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.00000000000006,
                "width": 212.0000000000001,
                "x": 765.0000000000003,
                "y": 8.000000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07452.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.00000000000009,
                "width": 217.0000000000001,
                "x": 738.0000000000003,
                "y": 191.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07450.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.00000000000007,
                "width": 71.00000000000011,
                "x": 573.0000000000002,
                "y": 111.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07449.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.00000000000006,
                "width": 344.0000000000001,
                "x": 881.0000000000003,
                "y": 274.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07444.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.0000000000001,
                "width": 328.0000000000001,
                "x": 799.0000000000003,
                "y": 121.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07442.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.00000000000006,
                "width": 89.0,
                "x": 768.0000000000003,
                "y": 279.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07772.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.00000000000006,
                "width": 91.0,
                "x": 643.0000000000003,
                "y": 341.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07432.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 302.0000000000001,
                "width": 374.00000000000017,
                "x": 434.00000000000017,
                "y": 227.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07424.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.0,
                "width": 39.000000000000114,
                "x": 632.0000000000002,
                "y": 472.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07423.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.00000000000006,
                "width": 98.00000000000011,
                "x": 603.0000000000002,
                "y": 339.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07412.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.00000000000006,
                "width": 359.0000000000001,
                "x": 518.0000000000002,
                "y": 61.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07398.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.00000000000006,
                "width": 342.0000000000001,
                "x": 257.0000000000001,
                "y": 41.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07397.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.00000000000006,
                "width": 162.00000000000009,
                "x": 208.00000000000009,
                "y": 49.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07394.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.0000000000001,
                "width": 117.00000000000011,
                "x": 788.0000000000003,
                "y": 594.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07390.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.00000000000006,
                "width": 383.00000000000017,
                "x": 363.00000000000017,
                "y": 82.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07384.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.00000000000009,
                "width": 402.0000000000002,
                "x": 521.0000000000002,
                "y": 164.00000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07381.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.00000000000006,
                "width": 277.0000000000001,
                "x": 25.00000000000001,
                "y": 344.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07366.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 440.00000000000017,
                "width": 167.00000000000006,
                "x": 255.0000000000001,
                "y": 147.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07306.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.00000000000006,
                "width": 101.00000000000006,
                "x": 230.0000000000001,
                "y": 257.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07300.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.00000000000006,
                "width": 81.00000000000011,
                "x": 823.0000000000003,
                "y": 346.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07299.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.00000000000006,
                "width": 151.00000000000006,
                "x": 435.00000000000017,
                "y": 14.000000000000007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07285.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.4899997229764,
                "width": 92.61986827889581,
                "x": 446.47526247262584,
                "y": 470.2239466467017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07257.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.8041445053816,
                "width": 343.16848631539597,
                "x": 828.8290776752469,
                "y": 407.2899335854007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07255.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.86907878334131,
                "width": 184.05230234908777,
                "x": 965.384011676183,
                "y": 486.84802556855476
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07232.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.92874975760435,
                "width": 170.99052605334603,
                "x": 207.80098652316363,
                "y": 54.62197360037444
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07228.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.5559866616754,
                "width": 192.3643418100143,
                "x": 276.6721706279836,
                "y": 193.55177601871813
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07222.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.99052605334606,
                "width": 340.7936178979883,
                "x": 147.24184187927023,
                "y": 281.42190746279874
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07218.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.9255917753864,
                "width": 517.7213149948534,
                "x": 556.9066438820785,
                "y": 172.17796026204985
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07214.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 316.9887387387387,
                "width": 680.0450450450451,
                "x": 154.65540540540542,
                "y": 558.2950450450451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07195.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.7650310988252,
                "width": 120.30407740152043,
                "x": 640.4422944022115,
                "y": 335.2591568762958
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07193.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.53489979267454,
                "width": 86.68970283344856,
                "x": 797.0145127850726,
                "y": 281.2992398064962
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07180.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.07118175535592,
                "width": 369.75812024879065,
                "x": 400.7187284035937,
                "y": 206.9937802349689
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07171.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.6876295784382,
                "width": 233.53144436765723,
                "x": 421.0642709053214,
                "y": 140.6496199032481
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07170.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113336,
                "width": 280.41465100207324,
                "x": 692.6330338631652,
                "y": 129.14996544574984
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07168.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.61230131306152,
                "width": 149.49550794747756,
                "x": 310.4906703524534,
                "y": 192.84035936420182
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07153.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.42017968210092,
                "width": 76.0746371803732,
                "x": 801.4374568071873,
                "y": 286.60677263303387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07126.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 48.602626123013124,
                "width": 78.25846579129234,
                "x": 588.1741534208708,
                "y": 66.7256392536282
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07113.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.18728403593641,
                "width": 251.2232204561161,
                "x": 752.7850725639254,
                "y": 3.5383552176917763
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07108.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 397.1803731859019,
                "x": 503.33102971665517,
                "y": 57.49827228749137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07098.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.4346924671735,
                "width": 205.61713890808574,
                "x": 699.7277125086387,
                "y": 183.58673116793366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07096.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.8811333794057,
                "width": 161.87975120939876,
                "x": 296.3372494816863,
                "y": 200.8016586040083
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07092.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.1071181755356,
                "width": 168.87353144436764,
                "x": 215.00483759502418,
                "y": 55.19281271596406
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07081.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.6973047684865,
                "width": 88.14374568071872,
                "x": 418.47684865238426,
                "y": 275.1402902557015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07076.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.72702142363511,
                "width": 264.4920525224603,
                "x": 399.8341395991707,
                "y": 238.8389771941949
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07075.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 88.96751900483758,
                "width": 32.127159640635796,
                "x": 874.8472702142363,
                "y": 222.418797512094
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07071.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286108,
                "width": 337.02833448514167,
                "x": 163.64892881824466,
                "y": 306.9523151347616
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07057.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.37871458189352,
                "width": 441.409813407049,
                "x": 626.2888735314444,
                "y": 558.1755355908778
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07046.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.92052522460261,
                "width": 313.1444367657222,
                "x": 352.9509329647547,
                "y": 260.9536973047685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07041.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.60953697304768,
                "width": 309.60608154803043,
                "x": 371.5272978576365,
                "y": 148.61091914305462
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07039.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.8804422944022,
                "width": 214.07049067035246,
                "x": 1023.4692467173463,
                "y": 216.7242570836213
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07037.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.0945945945946,
                "width": 216.43243243243245,
                "x": 380.83783783783787,
                "y": 66.5945945945946
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07031.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.29163787145819,
                "width": 122.57360055286802,
                "x": 534.3856254319281,
                "y": 294.52937111264686
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07030.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.64754664823772,
                "width": 247.68486523842438,
                "x": 455.5632342778162,
                "y": 253.87698686938495
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07020.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.95577055977884,
                "width": 327.2978576364893,
                "x": 767.8230822391155,
                "y": 181.34070490670354
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07009.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 235.30062197650312,
                "width": 302.52937111264686,
                "x": 351.1817553559088,
                "y": 91.99723565998619
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06999.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.109191430546,
                "width": 384.79612992398063,
                "x": 675.8258465791292,
                "y": 107.03524533517623
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06995.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.7194194885971,
                "width": 91.70974429854869,
                "x": 579.3586731167934,
                "y": 235.44713199723566
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06991.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901868,
                "width": 208.76295784381477,
                "x": 442.29440221147206,
                "y": 215.83966827919835
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06961.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.65031098825153,
                "width": 200.80165860400825,
                "x": 656.3648928818245,
                "y": 410.44920525224603
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06960.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.49619903248097,
                "width": 233.53144436765723,
                "x": 459.101589495508,
                "y": 209.64754664823775
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06950.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.53556485355648,
                "width": 197.26638772663875,
                "x": 627.5034867503487,
                "y": 359.721059972106
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06944.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.1029716655149,
                "width": 215.0587422252937,
                "x": 694.4823773324119,
                "y": 161.55632342778162
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06942.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 54.369039391845206,
                "width": 140.8652384243262,
                "x": 521.4485141672426,
                "y": 502.5017277125086
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06935.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.41948859709748,
                "width": 91.1126468555633,
                "x": 748.3621285418106,
                "y": 285.7221838286109
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06931.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.3800967519005,
                "width": 130.9191430545958,
                "x": 606.8279198341396,
                "y": 347.64340013821703
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06907.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.88113337940567,
                "width": 416.64132688320666,
                "x": 455.5632342778162,
                "y": 65.45957152729787
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06906.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.30180180180184,
                "width": 163.43018018018017,
                "x": 819.3445945945946,
                "y": 608.75
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06900.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.76364892881827,
                "width": 455.56323427781615,
                "x": 619.2121630960609,
                "y": 563.4830684174153
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06884.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.68832066344163,
                "width": 155.68762957843808,
                "x": 774.0152038700761,
                "y": 323.7595024187975
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06882.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.14789219073953,
                "width": 483.87007601935045,
                "x": 598.8666205943331,
                "y": 566.1368348306842
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06873.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786458,
                "width": 115.8811333794057,
                "x": 714.7477539737388,
                "y": 326.41326883206636
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06866.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.40221147201106,
                "width": 171.34485141672425,
                "x": 212.53351762266757,
                "y": 48.60262612301313
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06833.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.5321354526607,
                "width": 392.75742916378715,
                "x": 683.7871458189358,
                "y": 80.49758120248791
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06823.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.76710435383552,
                "width": 185.76364892881827,
                "x": 146.84174153420872,
                "y": 374.1810642709053
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06781.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.38078783690395,
                "width": 136.22667588113336,
                "x": 810.2833448514168,
                "y": 271.56876295784383
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06774.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.209398756047,
                "width": 158.1644782308224,
                "x": 363.2840359364202,
                "y": 71.6682791983414
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06760.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.34346924671735,
                "width": 331.7208016586041,
                "x": 337.9129232895646,
                "y": 259.18451969592263
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06758.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.76364892881827,
                "width": 222.03178991015898,
                "x": 290.14512785072566,
                "y": 198.14789219073947
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06749.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.42778161713892,
                "width": 259.1195577055978,
                "x": 715.4637180373187,
                "y": 208.7643400138217
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06727.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.49412577747069,
                "width": 329.95162404975815,
                "x": 840.3593642017969,
                "y": 302.52937111264686
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06726.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.91706979958536,
                "width": 337.0283344851417,
                "x": 840.3593642017969,
                "y": 300.76019350380096
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06720.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 244.14651002073253,
                "width": 422.83344851416723,
                "x": 666.9799585348999,
                "y": 93.76641326883207
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06716.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.44594594594597,
                "width": 221.6351351351351,
                "x": 504.6621621621622,
                "y": 55.14864864864865
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06711.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.91666666666663,
                "width": 189.75450450450444,
                "x": 576.9414414414415,
                "y": 516.6148648648649
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06702.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.87836903939188,
                "width": 188.4174153420871,
                "x": 544.0221147201106,
                "y": 412.2183828610919
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06652.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.8030407740152,
                "width": 405.1416724257083,
                "x": 556.4063579820319,
                "y": 87.57429163787147
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06647.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 219.94747753973738,
                "width": 121.09467864547341,
                "x": 196.8818244644091,
                "y": 84.02487906012439
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06633.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.6088458880442,
                "width": 272.45335176226683,
                "x": 566.1368348306842,
                "y": 418.41050449205255
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06629.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.03248099516242,
                "width": 340.5666897028335,
                "x": 837.705597788528,
                "y": 264.49205252246026
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06627.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.5708362128542,
                "width": 260.95369730476847,
                "x": 113.22736696613684,
                "y": 161.87975120939876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06607.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.06427090532134,
                "width": 156.96475466482372,
                "x": 380.94816862474084,
                "y": 423.2757429163787
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06589.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.22391154111955,
                "width": 148.61091914305462,
                "x": 526.3303386316517,
                "y": 444.94816862474084
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06568.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.34001382170007,
                "width": 412.21838286109187,
                "x": 647.519004837595,
                "y": 191.95577055977887
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06566.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.63994471319972,
                "width": 176.28749136143745,
                "x": 205.1195577055978,
                "y": 40.36489288182447
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06562.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.1644782308224,
                "width": 105.44298548721497,
                "x": 430.00967519004837,
                "y": 478.6123013130615
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06527.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.15065653075331,
                "width": 152.1492743607464,
                "x": 317.5673807878369,
                "y": 173.37940566689704
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06518.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.64892881824466,
                "width": 359.1430545957153,
                "x": 550.2142363510712,
                "y": 54.844505874222534
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06514.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 401.6033172080166,
                "x": 395.411195577056,
                "y": 123.84243261921218
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06497.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 58.48790601243954,
                "width": 118.62335867311685,
                "x": 897.9129232895646,
                "y": 188.64409122322044
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06492.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.76572218382861,
                "width": 76.0746371803732,
                "x": 824.4367657221838,
                "y": 246.8002764340014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06462.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 254.76157567380787,
                "width": 217.60884588804424,
                "x": 439.6406357982032,
                "y": 139.76503109882518
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06443.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901868,
                "width": 186.64823773324122,
                "x": 282.18382861091914,
                "y": 195.49412577747063
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06439.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.37940566689701,
                "width": 327.2978576364893,
                "x": 756.3234277816172,
                "y": 576.7519004837595
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06421.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.72494816862473,
                "width": 341.45127850725635,
                "x": 795.2453351762267,
                "y": 305.1831375259157
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06420.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.6496199032481,
                "width": 335.2591568762957,
                "x": 735.0932964754666,
                "y": 78.72840359364203
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06390.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633033,
                "width": 176.91776088458874,
                "x": 498.02349689011754,
                "y": 429.9101589495508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06381.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.91845196959224,
                "width": 98.18935729094676,
                "x": 651.0573600552868,
                "y": 351.1817553559088
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06377.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.84035936420184,
                "width": 350.2971665514858,
                "x": 789.937802349689,
                "y": 365.3351762266759
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06367.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.91706979958536,
                "width": 352.0663441603318,
                "x": 826.2059433310297,
                "y": 270.6841741534209
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06360.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.7643400138217,
                "width": 394.526606772633,
                "x": 350.2971665514859,
                "y": 102.61230131306151
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06350.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.93503800967517,
                "width": 158.98825155494126,
                "x": 215.82861091914305,
                "y": 42.012439530062196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06344.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.67657221838283,
                "width": 116.97581202487902,
                "x": 558.5183137525916,
                "y": 574.17000691085
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06340.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.2364864864865,
                "width": 207.3040540540541,
                "x": 229.24099099099098,
                "y": 206.2072072072072
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06338.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.3427781617139,
                "width": 350.2971665514858,
                "x": 402.48790601243957,
                "y": 112.3427781617139
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06313.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 83.15134761575678,
                "width": 174.26399447132002,
                "x": 250.33863165169316,
                "y": 357.3738769868694
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06307.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.41879751209402,
                "width": 388.3344851416724,
                "x": 573.2135452660677,
                "y": 118.53489979267451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06282.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364199,
                "width": 252.99239806496198,
                "x": 227.33932273669663,
                "y": 330.8362128541811
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06279.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.48306841741532,
                "width": 134.0373185901866,
                "x": 505.2854181064271,
                "y": 545.8493434692467
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06229.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633033,
                "width": 267.14581893572915,
                "x": 242.37733241188667,
                "y": 327.2978576364893
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06200.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863167,
                "width": 334.3745680718729,
                "x": 158.341395991707,
                "y": 313.1444367657222
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06185.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.8804422944022,
                "width": 429.9101589495508,
                "x": 559.9447131997237,
                "y": 343.2204561161023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06184.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.03317208016585,
                "width": 285.7221838286108,
                "x": 839.474775397374,
                "y": 67.22874913614375
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06160.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.8693849343469,
                "width": 88.96751900483758,
                "x": 435.77608845888045,
                "y": 57.66413268832066
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06158.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728403,
                "width": 401.6033172080166,
                "x": 440.52522460262617,
                "y": 127.38078783690395
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06153.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.24324324324326,
                "width": 347.5405405405405,
                "x": 279.9054054054054,
                "y": 45.78378378378378
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06143.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.03248099516236,
                "width": 129.14996544574979,
                "x": 799.6682791983415,
                "y": 332.605390463027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06142.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.8023496890118,
                "width": 438.7560469937802,
                "x": 270.6841741534209,
                "y": 299.875604699378
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06126.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0718728403594,
                "width": 266.2612301313061,
                "x": 742.1700069108501,
                "y": 4.42294402211472
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06125.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 387.4498963372496,
                "x": 719.1706979958535,
                "y": 163.64892881824466
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06115.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.5701451278507,
                "width": 184.87906012439527,
                "x": 496.25431928127165,
                "y": 257.41534208707674
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06112.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.26537664132687,
                "width": 256.5307532826538,
                "x": 331.72080165860405,
                "y": 229.99308914996547
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06104.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.99585348997928,
                "width": 360.02764340013823,
                "x": 245.0310988251555,
                "y": 51.306150656530754
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06096.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728408,
                "width": 399.8341395991706,
                "x": 662.5570145127851,
                "y": 360.02764340013823
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06090.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.46371803731859,
                "width": 120.27090532135455,
                "x": 146.63165169315826,
                "y": 158.1644782308224
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06075.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.80096751900481,
                "width": 177.80234968901175,
                "x": 513.0615065653076,
                "y": 459.101589495508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06069.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.4561161022806,
                "width": 217.60884588804424,
                "x": 287.4913614374568,
                "y": 202.5708362128542
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06062.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.65031098825153,
                "width": 68.11333794056668,
                "x": 866.8970283344852,
                "y": 280.4146510020733
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06058.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.13683483068422,
                "width": 116.40082930200413,
                "x": 738.0870767104354,
                "y": 292.7657221838286
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06057.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 71.42778161713892,
                "width": 139.3282653766413,
                "x": 704.5777470628888,
                "y": 274.24740843123703
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06043.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 360.02764340013823,
                "x": 732.4395300621977,
                "y": 76.07463718037319
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06039.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.07049067035248,
                "width": 366.21976503109875,
                "x": 762.5155494125778,
                "y": 170.7256392536282
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06029.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.78299930891498,
                "width": 117.28265376641332,
                "x": 646.3773324118866,
                "y": 167.54664823773325
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06018.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036632,
                "width": 112.34277816171391,
                "x": 810.2833448514168,
                "y": 281.2992398064962
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06014.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.29232895646163,
                "width": 129.62819626814098,
                "x": 521.1582584657913,
                "y": 321.86592950932965
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05985.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.65514858327575,
                "width": 154.31928127159642,
                "x": 602.2861091914306,
                "y": 146.3828610919143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05980.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574294,
                "width": 422.8334485141673,
                "x": 348.52798894264,
                "y": 18.576364892881827
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05973.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 269.79958534899794,
                "width": 663.4416033172081,
                "x": 508.63856254319285,
                "y": 483.8700760193504
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05970.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 226.45473393227365,
                "width": 167.1872840359365,
                "x": 682.0179682100899,
                "y": 423.71803731859023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05938.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53282653766416,
                "width": 205.224602626123,
                "x": 584.713199723566,
                "y": 330.8362128541811
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05924.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.53489979267454,
                "width": 121.18866620594338,
                "x": 818.2446440912232,
                "y": 300.76019350380096
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05893.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.95853489979271,
                "width": 165.41810642709052,
                "x": 227.33932273669663,
                "y": 372.41188666205943
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05886.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 50.26399447132002,
                "width": 155.2011057360055,
                "x": 693.1140290255702,
                "y": 297.1748445058742
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05883.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805112,
                "width": 315.798203178991,
                "x": 321.99032480995163,
                "y": 128.2653766413269
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05868.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.83206634416035,
                "width": 215.0587422252937,
                "x": 785.7512093987561,
                "y": 217.1568762957844
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05859.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.68693693693695,
                "width": 295.0518018018018,
                "x": 132.71846846846847,
                "y": 227.0472972972973
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05851.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.6095369730477,
                "width": 467.9474775397374,
                "x": 442.29440221147206,
                "y": 101.72771250863858
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05842.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.38217000691088,
                "width": 183.10988251554937,
                "x": 280.4146510020733,
                "y": 373.2964754664824
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05832.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.18797512093988,
                "width": 223.80096751900487,
                "x": 1030.54595715273,
                "y": 216.7242570836213
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05812.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.9177608845888,
                "width": 145.95715272978578,
                "x": 599.751209398756,
                "y": 367.98894263994475
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05810.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.16447823082243,
                "width": 149.0283344851416,
                "x": 560.8403593642018,
                "y": 221.3379405666897
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05806.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.65100207325497,
                "width": 512.1769177608846,
                "x": 734.2087076710436,
                "y": 653.7111264685557
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05804.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.93243243243245,
                "width": 238.28378378378375,
                "x": 378.7567567567568,
                "y": 72.83783783783784
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05803.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.18797512093988,
                "width": 490.9467864547339,
                "x": 711.209398756047,
                "y": 600.635798203179
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05801.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.3427781617139,
                "width": 324.64409122322036,
                "x": 729.7857636489289,
                "y": 78.72840359364203
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05778.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 431.6793365583967,
                "x": 720.9398756046994,
                "y": 344.9896337249482
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05777.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.76503109882515,
                "width": 137.99585348997925,
                "x": 720.9398756046994,
                "y": 398.06496199032483
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05759.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.07256392536283,
                "width": 322.8749136143746,
                "x": 826.2059433310297,
                "y": 279.53006219765035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05745.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.0725639253628,
                "width": 402.48790601243957,
                "x": 513.0615065653076,
                "y": 137.99585348997928
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05725.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 344.98963372494825,
                "x": 151.26468555632343,
                "y": 298.99101589495507
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05713.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767796,
                "width": 391.8728403593642,
                "x": 229.99308914996547,
                "y": 111.45818935729095
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05709.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.5708362128542,
                "width": 277.7608845888044,
                "x": 434.33310297166554,
                "y": 255.64616447823084
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05694.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.30960608154805,
                "width": 171.95577055977884,
                "x": 403.875604699378,
                "y": 445.3213545266068
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05684.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.97581202487906,
                "width": 115.32826537664135,
                "x": 403.64892881824466,
                "y": 77.43469246717346
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05681.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.95646164478234,
                "width": 403.3724948168625,
                "x": 501.5618521078093,
                "y": 42.460262612301314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05618.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.4174153420871,
                "width": 506.86938493434695,
                "x": 587.3669661368349,
                "y": 562.5984796129924
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05605.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.0732550103663,
                "width": 291.91430545957155,
                "x": 367.1043538355218,
                "y": 229.10850034554252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05604.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.22736696613683,
                "width": 343.22045611610224,
                "x": 260.0691085003456,
                "y": 57.49827228749137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05600.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.72494816862476,
                "width": 214.9550794747754,
                "x": 291.91430545957155,
                "y": 189.30200414651003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05583.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.5321354526607,
                "width": 234.41603317208018,
                "x": 272.4533517622668,
                "y": 186.6482377332412
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05562.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.61230131306155,
                "width": 122.95784381478927,
                "x": 757.2080165860401,
                "y": 249.45404284727022
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05554.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.62837837837833,
                "width": 148.07432432432415,
                "x": 1088.0720720720722,
                "y": 663.5923423423424
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05553.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.0186592950933,
                "width": 115.51900483759505,
                "x": 741.6143745680719,
                "y": 294.52937111264686
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05511.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.26675881133377,
                "width": 151.26468555632346,
                "x": 145.95715272978578,
                "y": 404.25708362128546
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05507.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.0711817553559,
                "width": 314.0290255701451,
                "x": 771.3614374568073,
                "y": 181.34070490670354
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05501.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.45945945945945,
                "width": 297.2454954954955,
                "x": 143.68693693693695,
                "y": 240.20945945945945
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05500.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.11057360055287,
                "width": 373.29647546648243,
                "x": 722.7090532135453,
                "y": 322.8749136143746
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05494.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.3800967519005,
                "width": 405.14167242570835,
                "x": 482.98548721492745,
                "y": 68.1133379405667
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05481.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.00557880055788,
                "width": 241.00418410041843,
                "x": 217.79637377963738,
                "y": 324.01673640167365
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05480.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.57360055286796,
                "width": 97.30476848652381,
                "x": 796.1299239806497,
                "y": 279.53006219765035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05472.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.99654457498272,
                "width": 352.95093296475466,
                "x": 253.87698686938495,
                "y": 57.49827228749137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05453.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.07256392536283,
                "width": 411.33379405666915,
                "x": 634.2501727712508,
                "y": 178.6869384934347
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05443.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.14581893572904,
                "width": 440.52522460262605,
                "x": 833.2826537664133,
                "y": 475.9087767795439
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05442.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.49412577747057,
                "width": 339.68210089841045,
                "x": 786.3994471319972,
                "y": 366.21976503109886
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05397.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 80.24602626123016,
                "width": 152.55563234277815,
                "x": 715.1596406357982,
                "y": 269.8382861091914
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05390.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.14996544574984,
                "width": 451.1402902557015,
                "x": 458.21700069108505,
                "y": 219.37802349689014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05376.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.72702142363511,
                "width": 368.87353144436764,
                "x": 374.1810642709053,
                "y": 53.95991706979959
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05375.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.29729729729729,
                "width": 281.98648648648657,
                "x": 330.8918918918919,
                "y": 1.0405405405405406
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05373.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.8790601243953,
                "width": 144.18797512093988,
                "x": 686.4409122322046,
                "y": 227.33932273669663
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05353.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.5701451278507,
                "width": 177.93503800967522,
                "x": 357.5176226675881,
                "y": 134.27505183137527
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05350.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.4561161022806,
                "width": 406.02626123013124,
                "x": 518.3690393918453,
                "y": 166.3026952315135
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05342.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.98825155494126,
                "width": 166.4022114720111,
                "x": 211.7097442985487,
                "y": 57.66413268832066
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05332.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 342.3358673116794,
                "width": 378.6040082930201,
                "x": 431.6793365583967,
                "y": 208.7629578438148
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05297.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921216,
                "width": 91.1126468555633,
                "x": 750.1313061506565,
                "y": 285.7221838286109
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05296.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.03317208016585,
                "width": 242.37733241188664,
                "x": 761.6309606081549,
                "y": 1.7691776088458881
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05286.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.30200414651006,
                "width": 260.0691085003456,
                "x": 429.9101589495508,
                "y": 253.87698686938495
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05283.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.99723565998619,
                "width": 245.0310988251556,
                "x": 711.209398756047,
                "y": 339.6821008984105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05275.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113342,
                "width": 131.80373185901874,
                "x": 712.0939875604699,
                "y": 318.45196959225984
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05270.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.7249481686248,
                "width": 283.9530062197651,
                "x": 102.61230131306151,
                "y": 159.22598479612992
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05258.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.41672425708362,
                "width": 325.52868002764336,
                "x": 351.1817553559088,
                "y": 147.72633033863167
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05237.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 346.75881133379403,
                "x": 881.0504492052523,
                "y": 279.53006219765035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05228.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728403,
                "width": 449.3711126468555,
                "x": 188.41741534208708,
                "y": 123.84243261921218
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05226.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.38078783690398,
                "width": 355.6046993780235,
                "x": 150.38009675190048,
                "y": 188.41741534208708
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05215.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.15065653075328,
                "width": 310.4906703524533,
                "x": 360.02764340013823,
                "y": 253.87698686938495
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05213.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.92812715964067,
                "width": 137.56461644782303,
                "x": 534.3856254319281,
                "y": 598.758811333794
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05204.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728403,
                "width": 335.25915687629583,
                "x": 170.7256392536282,
                "y": 293.68348306841744
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05179.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.91845196959224,
                "width": 106.15065653075328,
                "x": 645.7498272287492,
                "y": 351.1817553559088
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05154.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.80304077401524,
                "width": 196.37871458189363,
                "x": 637.7885279889426,
                "y": 338.79751209398756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05153.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 58.48790601243951,
                "width": 148.27919834139595,
                "x": 521.4485141672426,
                "y": 499.2066344160332
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05149.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.72494816862473,
                "width": 345.8742225293712,
                "x": 842.1285418106428,
                "y": 268.914996544575
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05145.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.85694540428472,
                "width": 121.09467864547338,
                "x": 420.94816862474084,
                "y": 107.91430545957152
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05136.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.52702702702703,
                "width": 273.6621621621622,
                "x": 341.2972972972973,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05135.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.38078783690395,
                "width": 94.65100207325509,
                "x": 818.2446440912232,
                "y": 288.37595024187976
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05132.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.6883206634416,
                "width": 280.41465100207324,
                "x": 329.0670352453352,
                "y": 227.33932273669663
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05131.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.1492743607464,
                "width": 383.02695231513485,
                "x": 726.2474084312371,
                "y": 343.2204561161023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05121.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 51.897719419488595,
                "width": 87.31997235659992,
                "x": 913.564616447823,
                "y": 190.2916378714582
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05107.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.8161713890809,
                "width": 111.209398756047,
                "x": 159.81202487906012,
                "y": 156.51693158258465
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05104.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.99585348997928,
                "width": 122.95784381478921,
                "x": 285.7221838286109,
                "y": 241.49274360746372
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05090.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.75881133379403,
                "width": 107.91430545957155,
                "x": 158.98825155494126,
                "y": 149.92674498963373
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05086.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.0746371803732,
                "width": 169.84105044920534,
                "x": 744.8237733241189,
                "y": 356.48928818244644
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05083.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.5210780926054,
                "width": 161.45957152729787,
                "x": 211.7097442985487,
                "y": 48.60262612301313
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05075.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.30338631651694,
                "width": 234.41603317208023,
                "x": 1012.854181064271,
                "y": 214.07049067035246
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05067.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.1499654457498,
                "width": 233.5314443676573,
                "x": 357.3738769868694,
                "y": 230.87767795438842
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05057.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901868,
                "width": 160.99516240497587,
                "x": 673.1720801658604,
                "y": 361.7968210089841
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05053.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.65100207325509,
                "width": 441.4098134070492,
                "x": 748.3621285418109,
                "y": 664.3261921216312
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05049.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863167,
                "width": 158.34139599170692,
                "x": 704.1326883206635,
                "y": 433.4485141672426
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05040.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.72563925362823,
                "width": 240.60815480304075,
                "x": 286.60677263303387,
                "y": 213.1859018659295
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05039.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.53351762266766,
                "width": 225.57014512785076,
                "x": 652.8265376641327,
                "y": 360.02764340013823
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05029.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.63994471319972,
                "width": 177.9350380096752,
                "x": 210.88597097442985,
                "y": 51.07394609536973
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05027.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 122.95784381478927,
                "x": 614.7892190739461,
                "y": 339.6821008984105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04994.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767107,
                "width": 260.0691085003455,
                "x": 313.1444367657222,
                "y": 191.95577055977887
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04987.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.84174153420872,
                "width": 341.4512785072564,
                "x": 415.7567380787837,
                "y": 590.9053213545267
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04982.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.34139599170697,
                "width": 182.22529371112648,
                "x": 634.2501727712508,
                "y": 333.48997926744994
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04981.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 251.2232204561161,
                "width": 167.1872840359364,
                "x": 520.1382170006912,
                "y": 436.9868693849344
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04979.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.30131306150662,
                "width": 220.26261230131308,
                "x": 540.4837595024188,
                "y": 263.6074637180373
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04976.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.92674498963373,
                "width": 168.87353144436767,
                "x": 211.7097442985487,
                "y": 61.782999308914995
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04968.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.4554250172771,
                "width": 389.21907394609536,
                "x": 620.0967519004838,
                "y": 295.45266067726334
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04965.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.03455425017276,
                "width": 357.3738769868694,
                "x": 259.18451969592263,
                "y": 55.729094678645474
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04954.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767798,
                "width": 199.0324809951624,
                "x": 156.5722183828611,
                "y": 344.10504492052524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04951.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.91845196959224,
                "width": 375.9502418797513,
                "x": 543.1375259156877,
                "y": 68.99792674498964
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04915.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728403,
                "width": 353.8355217691776,
                "x": 538.7145818935729,
                "y": 66.3441603317208
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04893.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036627,
                "width": 267.14581893572915,
                "x": 319.3365583966828,
                "y": 218.4934346924672
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04882.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 281.2992398064962,
                "x": 229.99308914996547,
                "y": 315.79820317899106
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04878.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.31928127159637,
                "width": 264.54733932273666,
                "x": 439.1485832757429,
                "y": 415.3393227366966
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04877.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.38009675190048,
                "width": 285.7221838286109,
                "x": 318.45196959225984,
                "y": 212.3013130615066
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04874.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.4574982722875,
                "width": 193.72494816862473,
                "x": 268.914996544575,
                "y": 204.34001382170007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04852.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.57152729785764,
                "width": 414.87214927436077,
                "x": 387.4498963372495,
                "y": 145.07256392536283
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04821.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.38009675190045,
                "width": 100.8431237042156,
                "x": 827.9751209398756,
                "y": 276.8762957843815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04808.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.84312370421571,
                "width": 222.91637871458192,
                "x": 872.2045611610229,
                "y": 567.0214236351071
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04798.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.43883897719411,
                "width": 90.61506565307525,
                "x": 518.977194194886,
                "y": 584.0552868002765
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05032.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.7643400138217,
                "width": 312.25984796129933,
                "x": 926.1644782308224,
                "y": 214.07049067035246
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04796.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.00967519004837,
                "width": 161.3738769868694,
                "x": 391.5300621976503,
                "y": 432.09398756046994
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04786.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.10919143054593,
                "width": 479.4471319972357,
                "x": 622.7505183137527,
                "y": 551.0988251554942
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04783.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.16516931582578,
                "width": 139.3282653766413,
                "x": 500.87629578438145,
                "y": 343.0297166551486
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04755.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.27090532135453,
                "width": 102.97166551485833,
                "x": 317.15272978576365,
                "y": 98.02902557014512
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04742.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.57152729785764,
                "width": 440.52522460262617,
                "x": 248.5694540428473,
                "y": 302.52937111264686
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04692.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.26468555632346,
                "width": 275.10711817553556,
                "x": 938.5487214927437,
                "y": 199.91706979958536
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04659.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.04146510020732,
                "width": 130.1561852107809,
                "x": 410.2391154111956,
                "y": 94.73393227366967
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04630.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.22874913614373,
                "width": 114.63718037318586,
                "x": 566.1313061506565,
                "y": 239.85625431928128
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04609.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.2653766413269,
                "width": 292.79889426399455,
                "x": 374.1810642709053,
                "y": 289.2605390463027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04579.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.91706979958533,
                "width": 448.4865238424327,
                "x": 586.4823773324119,
                "y": 173.37940566689704
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04572.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.11057360055287,
                "width": 255.64616447823084,
                "x": 758.0926053904631,
                "y": 9.730476848652385
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04547.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.03248099516242,
                "width": 143.30338631651694,
                "x": 541.3683483068418,
                "y": 13.268832066344162
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04537.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.8023496890118,
                "width": 444.06357982031795,
                "x": 328.18244644091226,
                "y": 382.14236351071185
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04517.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.04279279279277,
                "width": 178.78603603603602,
                "x": 276.4054054054054,
                "y": 188.65765765765767
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04500.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.4948168624741,
                "width": 406.02626123013135,
                "x": 428.1409813407049,
                "y": 45.11402902557015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04477.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.8099516240498,
                "width": 118.16447823082245,
                "x": 477.06703524533515,
                "y": 292.7657221838286
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04474.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.30338631651694,
                "width": 145.07256392536283,
                "x": 700.5943331029717,
                "y": 315.79820317899106
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04466.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286114,
                "width": 329.0670352453352,
                "x": 896.0884588804423,
                "y": 263.6074637180373
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04460.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.11264685556324,
                "width": 338.79751209398756,
                "x": 345.87422252937114,
                "y": 263.6074637180373
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04446.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 317.5673807878369,
                "width": 387.4498963372496,
                "x": 657.2494816862475,
                "y": 360.9122322045612
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04441.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 304.2985487214927,
                "width": 384.79612992398063,
                "x": 559.0601243953007,
                "y": 257.41534208707674
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04436.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.33863165169322,
                "width": 205.2246026261231,
                "x": 638.6731167933656,
                "y": 410.44920525224603
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04431.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.29163787145819,
                "width": 97.88251554941257,
                "x": 749.550794747754,
                "y": 274.24740843123703
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04400.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.23704215618523,
                "width": 115.51900483759505,
                "x": 723.0960608154803,
                "y": 278.65653075328265
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04378.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.57360055286799,
                "width": 291.9143054595716,
                "x": 303.4139599170698,
                "y": 244.14651002073256
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04377.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.22598479612992,
                "width": 129.33241188666204,
                "x": 430.83344851416723,
                "y": 320.4478230822391
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04349.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.87975120939882,
                "width": 186.64823773324122,
                "x": 617.442985487215,
                "y": 336.1437456807187
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04347.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.13959917069799,
                "width": 52.72149274360743,
                "x": 603.8258465791292,
                "y": 39.5411195577056
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04345.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.53213545266073,
                "width": 111.45818935729096,
                "x": 635.1347615756738,
                "y": 417.5259156876296
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04330.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.11057360055287,
                "width": 477.6779543883898,
                "x": 543.1375259156877,
                "y": 176.9177608845888
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04309.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.26399447132,
                "width": 384.79612992398063,
                "x": 506.86938493434695,
                "y": 52.1907394609537
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04301.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.49481686247412,
                "width": 100.8431237042156,
                "x": 651.9419488597098,
                "y": 319.3365583966828
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04290.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.80096751900487,
                "width": 608.5970974429856,
                "x": 571.4443676572218,
                "y": 526.3303386316517
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04259.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.72702142363511,
                "width": 108.80442294402212,
                "x": 800.5528680027644,
                "y": 216.7242570836213
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04231.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.60055286800275,
                "width": 168.42847270214236,
                "x": 380.0663441603317,
                "y": 423.2757429163787
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04206.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.41879751209402,
                "width": 212.30131306150656,
                "x": 433.4485141672426,
                "y": 169.84105044920526
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04205.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.87975120939876,
                "width": 383.9115411195578,
                "x": 175.14858327574294,
                "y": 312.2598479612993
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04174.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.46371803731859,
                "width": 173.81617138908086,
                "x": 205.94333102971666,
                "y": 46.13130615065653
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04153.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.41534208707674,
                "width": 387.44989633724947,
                "x": 593.5590877677955,
                "y": 92.88182446440912
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04140.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.72494816862473,
                "width": 425.48721492743607,
                "x": 542.2529371112647,
                "y": 166.3026952315135
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04124.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.34208707671047,
                "width": 75.19004837595025,
                "x": 799.6682791983415,
                "y": 267.1458189357291
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04112.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.95715272978578,
                "width": 151.2646855563234,
                "x": 421.94885970974434,
                "y": 0.8845888044229441
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04100.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.52702702702703,
                "width": 1.040540540540519,
                "x": 355.8648648648649,
                "y": -89.48648648648648
            },
            {
                "class": "rect",
                "height": 89.4864864864865,
                "width": 306.9594594594594,
                "x": 347.5405405405406,
                "y": 65.55405405405405
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04090.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.76364892881827,
                "width": 481.2163096060816,
                "x": 628.0580511402903,
                "y": 563.4830684174153
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04078.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.7256392536282,
                "width": 269.799585348998,
                "x": 752.7850725639254,
                "y": 3.5383552176917763
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04075.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.20270270270268,
                "width": 318.0855855855856,
                "x": 167.81756756756758,
                "y": 214.981981981982
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04070.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.4968901174845,
                "width": 114.1119557705598,
                "x": 286.60677263303387,
                "y": 337.02833448514167
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04059.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.26468555632346,
                "width": 306.95231513476153,
                "x": 697.05597788528,
                "y": 68.1133379405667
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04032.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.91706979958536,
                "width": 178.6869384934347,
                "x": 530.7532826537664,
                "y": 422.8334485141673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04026.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 71.65169315825852,
                "width": 99.95853489979271,
                "x": 301.6447823082239,
                "y": 407.7954388389772
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04023.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 303.4139599170698,
                "width": 266.2612301313061,
                "x": 796.1299239806497,
                "y": 159.22598479612992
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04014.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.44298548721497,
                "width": 74.96337249481678,
                "x": 583.2315134761576,
                "y": 527.2149274360746
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04006.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.10919143054593,
                "width": 306.0677263303387,
                "x": 728.9011748445059,
                "y": 550.2142363510712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04005.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.496199032481,
                "width": 272.4533517622667,
                "x": 326.41326883206636,
                "y": 232.64685556323428
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03991.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.02073255010366,
                "width": 87.3199723565998,
                "x": 602.1782999308915,
                "y": 37.89357290946786
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03990.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.33783783783785,
                "width": 225.7972972972973,
                "x": 396.44594594594594,
                "y": 95.72972972972973
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03985.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.27027027027032,
                "width": 400.3490990990991,
                "x": 282.9864864864865,
                "y": 726.1126126126126
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03984.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.7643400138217,
                "width": 226.4547339322737,
                "x": 643.0960608154803,
                "y": 411.333794056669
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03969.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.91666666666663,
                "width": 136.009009009009,
                "x": 652.6238738738739,
                "y": 487.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03965.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.18797512093985,
                "width": 252.992398064962,
                "x": 968.6247408431237,
                "y": 210.5321354526607
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03944.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574294,
                "width": 224.68555632342782,
                "x": 291.91430545957155,
                "y": 204.34001382170007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03913.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.62750518313754,
                "width": 186.1727712508639,
                "x": 313.0338631651693,
                "y": 73.31582584657913
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03902.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.57014512785076,
                "width": 183.99447131997238,
                "x": 548.4450587422253,
                "y": 396.29578438147894
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03884.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.84174153420872,
                "width": 155.6876295784382,
                "x": 300.76019350380096,
                "y": 274.22252937111267
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03880.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53282653766414,
                "width": 214.0704906703525,
                "x": 302.52937111264686,
                "y": 191.07118175535592
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03879.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921216,
                "width": 225.57014512785065,
                "x": 669.6337249481687,
                "y": 348.52798894264
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03861.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.496199032481,
                "width": 107.03524533517623,
                "x": 742.1700069108501,
                "y": 280.4146510020733
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03836.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.34277816171388,
                "width": 351.1817553559088,
                "x": 338.79751209398756,
                "y": 245.0310988251555
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03827.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.68555632342776,
                "width": 192.84035936420184,
                "x": 528.9841050449205,
                "y": 378.60400829302006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03821.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.04975812024878,
                "width": 119.44713199723566,
                "x": 404.4727021423635,
                "y": 76.6109191430546
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03820.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863167,
                "width": 363.56599861783,
                "x": 728.016586040083,
                "y": 123.84243261921218
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03800.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.68624740843126,
                "width": 219.37802349689014,
                "x": 287.4913614374568,
                "y": 201.68624740843126
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03798.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.3026952315135,
                "width": 212.30131306150656,
                "x": 289.2605390463027,
                "y": 199.91706979958536
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03797.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.5300621976503,
                "width": 420.1796821008985,
                "x": 467.06288873531446,
                "y": 229.10850034554252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03794.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.6869384934347,
                "width": 463.5245335176227,
                "x": 443.178991015895,
                "y": 365.3351762266759
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03793.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.72771250863855,
                "width": 211.41672425708362,
                "x": 180.4561161022806,
                "y": 367.98894263994475
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03775.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.0725639253628,
                "width": 486.5238424326193,
                "x": 612.1354526606773,
                "y": 211.41672425708364
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03748.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.33932273669666,
                "width": 373.2964754664823,
                "x": 677.5950241879751,
                "y": 390.98825155494126
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03738.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.1085003455425,
                "width": 427.2563925362821,
                "x": 694.4022114720111,
                "y": 275.99170697995856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03729.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.30269523151344,
                "width": 491.83137525915697,
                "x": 598.8666205943331,
                "y": 298.1064270905322
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03686.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.57360055286802,
                "width": 215.83966827919835,
                "x": 180.4561161022806,
                "y": 366.21976503109886
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03680.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 59.31167933655837,
                "width": 156.51693158258456,
                "x": 518.977194194886,
                "y": 326.2142363510712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03664.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.11126468555636,
                "width": 267.14581893572904,
                "x": 948.2791983413961,
                "y": 232.64685556323428
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03662.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.64754664823778,
                "width": 175.1485832757429,
                "x": 553.752591568763,
                "y": 412.2183828610919
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03645.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.16447823082234,
                "width": 138.44644091223222,
                "x": 340.3842432619212,
                "y": 396.82100898410505
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03642.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.07394609536973,
                "width": 107.03524533517623,
                "x": 797.0145127850726,
                "y": 222.9163787145819
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03635.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.2833448514167,
                "width": 164.7546648237733,
                "x": 212.53351762266757,
                "y": 53.54526606772633
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03600.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.922598479613,
                "width": 130.15618521078096,
                "x": 353.39875604699375,
                "y": 127.68486523842432
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03593.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.53144436765723,
                "width": 259.1845196959226,
                "x": 344.10504492052524,
                "y": 160.99516240497582
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03589.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.72563925362823,
                "width": 234.4160331720802,
                "x": 80.49758120248791,
                "y": 344.10504492052524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03569.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 447.60193503800986,
                "x": 600.635798203179,
                "y": 238.8389771941949
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03556.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.26330338631652,
                "width": 229.9930891499655,
                "x": 648.403593642018,
                "y": 413.9875604699378
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03538.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.8797512093988,
                "width": 377.71941948859717,
                "x": 539.5991706979959,
                "y": 136.2266758811334
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03532.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.49774774774778,
                "width": 195.23873873873873,
                "x": 277.5022522522523,
                "y": 189.7545045045045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03509.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.1644782308224,
                "width": 137.56461644782308,
                "x": 480.5943331029717,
                "y": 269.8382861091914
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03499.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.83966827919838,
                "width": 314.91361437456806,
                "x": 770.4768486523843,
                "y": 169.84105044920526
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03491.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.18728403593644,
                "width": 398.06496199032483,
                "x": 555.5217691776089,
                "y": 71.65169315825847
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03487.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 343.22045611610224,
                "x": 882.8196268140982,
                "y": 270.6841741534209
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03486.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 88.18244644091226,
                "width": 98.76434001382177,
                "x": 744.2598479612992,
                "y": 273.3655839668279
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03482.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.55405405405403,
                "width": 264.29729729729723,
                "x": 386.0405405405406,
                "y": 2.081081081081081
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03466.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.29163787145819,
                "width": 314.81133379405674,
                "x": 610.2225293711126,
                "y": 544.0856945404284
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03463.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.34277816171391,
                "width": 128.26537664132695,
                "x": 640.4422944022115,
                "y": 348.52798894264
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03451.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.53213545266067,
                "width": 145.95715272978566,
                "x": 633.365583966828,
                "y": 437.8714581893573
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03448.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805118,
                "width": 231.76226675881128,
                "x": 590.0207325501037,
                "y": 321.99032480995163
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03424.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.85694540428473,
                "width": 196.88182446440908,
                "x": 458.01796821008986,
                "y": 37.89357290946786
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03414.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.76295784381477,
                "width": 361.7968210089841,
                "x": 355.6046993780235,
                "y": 110.57360055286802
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03401.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 403.37249481686246,
                "x": 496.25431928127165,
                "y": 71.65169315825847
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03397.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.2833448514167,
                "width": 114.50449205252244,
                "x": 426.7145818935729,
                "y": 78.25846579129232
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03391.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.65031098825153,
                "width": 324.64409122322047,
                "x": 845.6668970283346,
                "y": 421.0642709053214
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03374.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.5680718728404,
                "width": 209.64754664823772,
                "x": 435.2176917760885,
                "y": 197.26330338631652
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03352.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.11057360055287,
                "width": 443.1789910158949,
                "x": 559.0601243953007,
                "y": 75.19004837595024
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03350.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.0945945945946,
                "width": 284.0675675675676,
                "x": 549.4054054054054,
                "y": 59.310810810810814
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03344.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.68901174844507,
                "width": 140.86523842432626,
                "x": 409.4153420870767,
                "y": 105.44298548721493
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03335.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.04975812024878,
                "width": 184.52522460262614,
                "x": 196.05805114029025,
                "y": 46.955079474775395
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03323.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.8030407740152,
                "width": 124.72702142363505,
                "x": 937.6641326883207,
                "y": 493.6005528680028
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03314.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.3800967519005,
                "width": 133.57290946786463,
                "x": 605.9433310297167,
                "y": 345.87422252937114
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03311.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.70145127850728,
                "width": 99.64616447823084,
                "x": 568.7767795438839,
                "y": 233.68348306841742
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03307.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.2653766413269,
                "width": 341.45127850725646,
                "x": 822.667588113338,
                "y": 409.5646164478231
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03282.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.87353144436767,
                "width": 96.38147892190739,
                "x": 561.813407049067,
                "y": 84.02487906012439
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03277.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.43469246717348,
                "width": 135.92259847961293,
                "x": 904.5031098825156,
                "y": 300.6772633033863
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03263.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.70270270270271,
                "width": 257.01351351351354,
                "x": 434.94594594594594,
                "y": 47.86486486486486
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03251.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.64685556323428,
                "width": 114.63718037318586,
                "x": 495.58534899792676,
                "y": 401.23013130615067
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03250.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.76503109882515,
                "width": 218.4934346924672,
                "x": 701.4789219073947,
                "y": 360.02764340013823
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03233.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.91637871458192,
                "width": 108.80442294402212,
                "x": 538.7145818935729,
                "y": 467.06288873531446
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03226.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.8030407740152,
                "width": 360.9122322045612,
                "x": 735.0932964754666,
                "y": 375.06565307532827
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03224.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.38009675190048,
                "width": 495.36973047684864,
                "x": 439.6406357982032,
                "y": 54.844505874222534
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03216.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 64.25431928127159,
                "width": 99.67657221838283,
                "x": 460.48928818244644,
                "y": 608.7684865238424
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03202.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.26399447131996,
                "width": 156.57221838286114,
                "x": 692.6330338631652,
                "y": 291.0297166551486
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03188.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.64892881824466,
                "width": 271.5687629578438,
                "x": 740.4008293020042,
                "y": 7.076710435383553
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03182.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.03248099516242,
                "width": 353.8355217691775,
                "x": 843.0131306150657,
                "y": 179.57152729785764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03179.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.92052522460261,
                "width": 127.38078783690395,
                "x": 300.76019350380096,
                "y": 334.3745680718729
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03176.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 1.7691776088458937,
                "width": 2.6537664132688406,
                "x": 484.75466482377334,
                "y": 153.91845196959227
            },
            {
                "class": "rect",
                "height": 112.34277816171391,
                "width": 319.3365583966828,
                "x": 289.2605390463027,
                "y": 53.95991706979959
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03171.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.41810642709055,
                "width": 416.6413268832067,
                "x": 692.6330338631652,
                "y": 286.60677263303387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03154.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.7263303386316,
                "width": 85.80511402902562,
                "x": 942.0870767104354,
                "y": 491.8313752591569
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03147.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.91983413959912,
                "width": 153.9184519695923,
                "x": 512.1769177608846,
                "y": 419.2950932964755
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03146.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.42087076710436,
                "width": 182.22529371112648,
                "x": 252.992398064962,
                "y": 332.605390463027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03145.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.98825155494126,
                "width": 161.45957152729784,
                "x": 215.00483759502418,
                "y": 54.3690393918452
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03143.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.0345542501728,
                "width": 177.80234968901175,
                "x": 291.0297166551486,
                "y": 214.9550794747754
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03125.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.9841050449205,
                "width": 71.6682791983414,
                "x": 441.5425017277125,
                "y": 42.012439530062196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03123.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728403,
                "width": 188.4174153420871,
                "x": 614.7892190739461,
                "y": 333.48997926744994
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03119.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.3400138217001,
                "width": 248.56945404284727,
                "x": 518.3690393918453,
                "y": 411.333794056669
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03115.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.36489288182443,
                "width": 107.58258465791289,
                "x": 632.2681409813407,
                "y": 183.41948859709746
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03099.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.22529371112648,
                "width": 457.3324118866621,
                "x": 382.14236351071185,
                "y": 276.8762957843815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03092.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.76226675881134,
                "width": 154.80304077401524,
                "x": 654.5957152729786,
                "y": 339.6821008984105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03089.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633033,
                "width": 111.45818935729095,
                "x": 84.92052522460263,
                "y": 467.9474775397374
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03047.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.53351762266757,
                "width": 325.5286800276434,
                "x": 76.07463718037319,
                "y": 229.99308914996547
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03040.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.68693693693695,
                "width": 286.277027027027,
                "x": 248.98423423423424,
                "y": 170.01126126126127
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03037.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113342,
                "width": 336.14374568071867,
                "x": 729.7857636489289,
                "y": 76.07463718037319
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03031.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.22529371112648,
                "width": 149.49550794747756,
                "x": 785.5148583275743,
                "y": 360.9122322045612
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03016.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.76503109882515,
                "width": 137.1112646855563,
                "x": 806.744989633725,
                "y": 268.03040774015204
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03011.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.30200414651003,
                "width": 275.10711817553556,
                "x": 405.1416724257084,
                "y": 245.0310988251555
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03005.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805115,
                "width": 248.56945404284733,
                "x": 383.91154111955774,
                "y": 138.88044229440223
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02995.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 374.1810642709054,
                "x": 712.0939875604699,
                "y": 76.07463718037319
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02992.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.6641326883207,
                "width": 140.2100898410505,
                "x": 715.1596406357982,
                "y": 292.7657221838286
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02950.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.64685556323428,
                "width": 96.1188666205943,
                "x": 567.8949550794748,
                "y": 236.3289564616448
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02948.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.22529371112648,
                "width": 447.60193503800963,
                "x": 519.2536281962682,
                "y": 163.64892881824466
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02946.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.33932273669666,
                "width": 341.45127850725635,
                "x": 804.9758120248791,
                "y": 319.3365583966828
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02945.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.80234968901175,
                "width": 90.22805805114035,
                "x": 651.9419488597098,
                "y": 400.7187284035937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02933.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286114,
                "width": 478.5625431928129,
                "x": 569.675190048376,
                "y": 231.76226675881134
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02925.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.5708362128542,
                "width": 189.30200414650994,
                "x": 523.676572218383,
                "y": 414.87214927436077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02915.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.58108108108108,
                "width": 355.8648648648649,
                "x": 533.7972972972973,
                "y": 109.25675675675676
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02901.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.69730476848653,
                "width": 185.348997926745,
                "x": 196.8818244644091,
                "y": 47.77885279889426
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02888.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.6869384934347,
                "width": 312.2598479612992,
                "x": 916.4340013821701,
                "y": 213.1859018659295
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02885.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.72702142363516,
                "width": 86.68970283344856,
                "x": 577.6364892881825,
                "y": 395.411195577056
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02859.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.98825155494126,
                "width": 114.50449205252244,
                "x": 412.7104353835522,
                "y": 104.61921216309607
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02856.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286108,
                "width": 137.99585348997937,
                "x": 637.7885279889426,
                "y": 344.9896337249482
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02828.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.1485832757429,
                "width": 270.68417415342094,
                "x": 743.9391845196959,
                "y": 1.7691776088458881
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02816.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.32411886662058,
                "width": 103.79543883897725,
                "x": 848.4865238424326,
                "y": 204.2957843814789
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02807.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.14789219073947,
                "width": 139.76503109882515,
                "x": 695.2868002764341,
                "y": 423.71803731859023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02793.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.02487906012439,
                "width": 74.9633724948169,
                "x": 596.4118866620594,
                "y": 36.24602626123013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02779.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.3614374568072,
                "width": 152.3980649619903,
                "x": 177.11126468555634,
                "y": 65.07809260539047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02777.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 57.664132688320706,
                "width": 140.0414651002073,
                "x": 503.3255010366275,
                "y": 514.0345542501727
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02774.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.68901174844507,
                "width": 75.19004837595025,
                "x": 839.474775397374,
                "y": 266.26123013130615
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02768.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.15065653075328,
                "width": 200.8016586040083,
                "x": 214.07049067035246,
                "y": 340.56668970283346
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02737.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.63718037318591,
                "width": 182.53766413268835,
                "x": 507.9308914996545,
                "y": 263.6655148583276
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02729.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.2646855563235,
                "width": 118.53489979267442,
                "x": 956.2404975812026,
                "y": 482.1008984105045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02725.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.6283783783784,
                "width": 270.9211711711712,
                "x": 728.3063063063063,
                "y": 471.64414414414415
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02724.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.80234968901175,
                "width": 190.186592950933,
                "x": 649.2881824464409,
                "y": 314.02902557014517
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02698.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.60884588804424,
                "width": 543.1375259156877,
                "x": 528.0995162404976,
                "y": 542.2529371112647
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02671.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.93089149965445,
                "width": 181.23013130615067,
                "x": 208.41465100207324,
                "y": 51.897719419488595
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02623.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.88251554941257,
                "width": 66.34416033172081,
                "x": 248.5694540428473,
                "y": 298.1064270905322
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02604.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.72494816862476,
                "width": 245.03109882515548,
                "x": 776.668970283345,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02591.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.41672425708364,
                "width": 363.56599861783013,
                "x": 753.6696613683483,
                "y": 176.03317208016588
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02584.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.88597097442988,
                "width": 132.62750518313754,
                "x": 199.35314443676572,
                "y": 81.5535590877678
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02578.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.5307532826538,
                "width": 295.45266067726334,
                "x": 284.837595024188,
                "y": 200.8016586040083
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02576.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.06979958534902,
                "width": 205.22460262612304,
                "x": 498.02349689011754,
                "y": 451.1402902557015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02555.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.22598479612992,
                "width": 368.8735314443677,
                "x": 814.7062888735315,
                "y": 276.8762957843815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02551.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.1492743607464,
                "width": 107.03524533517623,
                "x": 810.2833448514168,
                "y": 286.60677263303387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02547.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 276.87629578438145,
                "width": 149.49550794747756,
                "x": 749.2467173462336,
                "y": 293.68348306841744
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02545.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.68762957843816,
                "width": 417.52591568762955,
                "x": 521.0228058051141,
                "y": 137.11126468555634
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02542.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.99447131997235,
                "width": 295.45266067726334,
                "x": 725.3628196268141,
                "y": -5.307532826537664
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02537.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 394.52660677263304,
                "width": 336.1437456807188,
                "x": 565.2522460262612,
                "y": 152.14927436074638
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02519.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.61091914305456,
                "width": 360.9122322045612,
                "x": 812.0525224602627,
                "y": 388.3344851416725
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02513.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 137.99585348997925,
                "x": 770.4768486523843,
                "y": 236.18521078092607
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02501.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.9184519695923,
                "width": 233.53144436765717,
                "x": 592.6744989633726,
                "y": 339.6821008984105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02495.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921219,
                "width": 356.48928818244644,
                "x": 783.7456807187284,
                "y": 206.10919143054596
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02494.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 230.87767795438845,
                "x": 1031.4305459571528,
                "y": 218.4934346924672
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02489.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 83.15134761575672,
                "width": 213.18590186592954,
                "x": 117.65031098825156,
                "y": 367.98894263994475
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02484.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 319.3365583966828,
                "x": 355.6046993780235,
                "y": 213.1859018659295
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02481.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.51071181755356,
                "width": 166.6648237733241,
                "x": 544.0856945404284,
                "y": 457.66689702833446
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02471.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.22529371112645,
                "width": 428.1409813407049,
                "x": 524.5611610228059,
                "y": 118.53489979267451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02470.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.09882515549413,
                "width": 65.07809260539045,
                "x": 807.2978576364893,
                "y": 253.72218382861092
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02468.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.76710435383555,
                "width": 138.39391845196963,
                "x": 176.28749136143745,
                "y": 68.37318590186592
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02447.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 239.85625431928133,
                "width": 210.75604699378027,
                "x": 509.6945404284727,
                "y": 462.0760193503801
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02433.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.34346924671735,
                "width": 221.14720110573603,
                "x": 129.14996544574984,
                "y": 364.45058742225297
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02420.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.33724948168629,
                "width": 145.5010366275052,
                "x": 818.3331029716655,
                "y": 542.3220456116102
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02418.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.49689011748444,
                "width": 236.18521078092604,
                "x": 229.99308914996547,
                "y": 325.5286800276434
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02414.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.45542501727715,
                "width": 338.7975120939875,
                "x": 806.744989633725,
                "y": 311.3752591568763
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02410.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901868,
                "width": 184.87906012439538,
                "x": 482.1008984105045,
                "y": 419.2950932964755
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02405.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.8424326192121,
                "width": 92.88182446440908,
                "x": 910.2418797512095,
                "y": 518.3690393918453
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02399.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805115,
                "width": 337.9129232895646,
                "x": 378.60400829302006,
                "y": 138.88044229440223
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02393.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.81617138908086,
                "width": 167.22598479612992,
                "x": 205.94333102971666,
                "y": 49.426399447132
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02386.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767107,
                "width": 421.94885970974434,
                "x": 382.14236351071185,
                "y": 115.88113337940567
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02382.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.26330338631655,
                "width": 293.68348306841744,
                "x": 931.4720110573601,
                "y": 191.07118175535592
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02359.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.4174153420871,
                "width": 219.37802349689014,
                "x": 285.7221838286109,
                "y": 198.14789219073947
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02340.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.34485141672425,
                "width": 171.34485141672423,
                "x": 213.35729094678646,
                "y": 40.36489288182447
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02338.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.3026952315135,
                "width": 277.7608845888045,
                "x": 749.2467173462336,
                "y": 7.961299239806497
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02324.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.4174153420871,
                "width": 441.4098134070491,
                "x": 504.2156185210781,
                "y": 164.5335176226676
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02289.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.5196959225985,
                "width": 119.04630269523159,
                "x": 569.658604008293,
                "y": 236.3289564616448
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02286.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.0663441603317,
                "width": 88.14374568071872,
                "x": 208.41465100207324,
                "y": 70.84450587422253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02263.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.36420179682102,
                "width": 155.20110573600556,
                "x": 485.8852798894264,
                "y": 267.19281271596407
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02253.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.49205252246026,
                "width": 69.19695922598487,
                "x": 593.9405666897028,
                "y": 33.77470628887353
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02227.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.1499654457499,
                "width": 168.07187284035945,
                "x": 937.6641326883207,
                "y": 499.7926744989634
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02205.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.03178991015895,
                "width": 351.1817553559089,
                "x": 759.861782999309,
                "y": 169.84105044920526
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02201.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.99516240497584,
                "width": 411.333794056669,
                "x": 389.2190739460954,
                "y": 118.53489979267451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02197.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.94609536973047,
                "width": 156.96475466482377,
                "x": 529.0946786454734,
                "y": 302.46579129232896
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02192.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.55563234277827,
                "width": 147.26468555632346,
                "x": 541.4402211472011,
                "y": 581.1223220456116
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02190.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728406,
                "width": 402.48790601243957,
                "x": 515.7152729785764,
                "y": 131.80373185901865
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02184.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.87975120939876,
                "width": 398.9495507947478,
                "x": 533.4070490670352,
                "y": 126.496199032481
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02171.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.64961990324812,
                "width": 310.49067035245344,
                "x": 859.8203178991016,
                "y": 149.49550794747753
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02170.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036632,
                "width": 192.84035936420184,
                "x": 475.9087767795439,
                "y": 438.7560469937803
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.9177608845888,
                "width": 183.99447131997238,
                "x": 677.5950241879751,
                "y": 361.7968210089841
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02140.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 153.03386316516935,
                "x": 657.2494816862475,
                "y": 342.33586731167935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02107.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.41879751209393,
                "width": 113.22736696613686,
                "x": 892.5501036627505,
                "y": 425.4872149274361
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02068.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 220.77125086385627,
                "width": 129.33241188666207,
                "x": 186.99654457498272,
                "y": 65.07809260539047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02058.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036632,
                "width": 78.72840359364204,
                "x": 869.550794747754,
                "y": 283.95300621976503
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02039.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.18659295093295,
                "width": 268.030407740152,
                "x": 859.8203178991016,
                "y": 485.6392536281963
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02030.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 251.2232204561161,
                "width": 317.56738078783695,
                "x": 341.4512785072564,
                "y": 90.2280580511403
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02019.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.04054054054055,
                "width": 231.0,
                "x": 455.7567567567568,
                "y": 53.06756756756757
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02018.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.38009675190045,
                "width": 64.57498272287489,
                "x": 935.8949550794748,
                "y": 496.25431928127165
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02005.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 56.61368348306843,
                "width": 97.30476848652381,
                "x": 807.629578438148,
                "y": 252.992398064962
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01958.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.68901174844507,
                "width": 80.49758120248794,
                "x": 866.0124395300622,
                "y": 286.60677263303387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01954.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.9184519695923,
                "width": 194.60953697304774,
                "x": 641.3268832066344,
                "y": 341.4512785072564
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01949.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.0810810810811,
                "width": 293.4324324324325,
                "x": 555.6486486486486,
                "y": 98.85135135135135
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01941.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 54.36903939184515,
                "width": 144.16033172080165,
                "x": 507.44436765722185,
                "y": 509.91568762957843
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01929.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.84035936420173,
                "width": 346.75881133379403,
                "x": 726.2474084312371,
                "y": 559.0601243953007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01926.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.76641326883208,
                "width": 177.80234968901186,
                "x": 781.0919143054596,
                "y": 292.7988942639945
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01921.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.95646164478228,
                "width": 87.57429163787151,
                "x": 651.0573600552868,
                "y": 406.9108500345543
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01917.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.341395991707,
                "width": 387.44989633724947,
                "x": 504.2156185210781,
                "y": 60.152038700760194
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01909.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.49343469246725,
                "width": 102.6123013130615,
                "x": 772.2460262612302,
                "y": 373.2964754664824
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01897.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.95577055977884,
                "width": 150.79198341396,
                "x": 653.4319281271596,
                "y": 130.51002073255012
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01890.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.76641326883208,
                "width": 323.7595024187976,
                "x": 341.4512785072564,
                "y": 259.18451969592263
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01865.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.84174153420872,
                "width": 218.4934346924672,
                "x": 86.68970283344852,
                "y": 348.52798894264
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01846.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.1492743607464,
                "width": 521.907394609537,
                "x": 721.8244644091224,
                "y": 600.635798203179
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01838.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.30476848652387,
                "width": 216.7242570836213,
                "x": 661.6724257083622,
                "y": 358.25846579129234
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01833.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.28265376641326,
                "width": 142.85556323427784,
                "x": 680.7684865238424,
                "y": 329.80234968901175
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01826.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.828610919143,
                "width": 165.782999308915,
                "x": 511.45818935729096,
                "y": 527.3310297166552
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01823.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.9184519695923,
                "width": 90.22805805114024,
                "x": 654.5957152729786,
                "y": 360.02764340013823
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01822.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.6883206634416,
                "width": 347.64340013821703,
                "x": 264.49205252246026,
                "y": 56.61368348306842
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01819.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.3939184519696,
                "width": 106.26675881133383,
                "x": 555.2232204561161,
                "y": 111.209398756047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01816.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.9557705597789,
                "width": 375.0656530753283,
                "x": 741.2854181064272,
                "y": 332.605390463027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01805.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.80234968901175,
                "width": 368.8735314443677,
                "x": 802.3220456116103,
                "y": 268.03040774015204
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01800.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.14789219073947,
                "width": 390.1036627505183,
                "x": 612.1354526606773,
                "y": 160.11057360055287
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01797.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.03317208016588,
                "width": 398.94955079474784,
                "x": 487.4084312370422,
                "y": 44.2294402211472
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01796.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.75675675675674,
                "width": 134.2297297297298,
                "x": 445.35135135135135,
                "y": 108.21621621621622
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01788.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.76434001382171,
                "width": 130.51002073255017,
                "x": 489.41257774706287,
                "y": 254.84727021423635
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01786.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0718728403594,
                "width": 443.1789910158949,
                "x": 633.365583966828,
                "y": 199.91706979958536
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01778.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.45542501727715,
                "width": 348.5279889426399,
                "x": 786.3994471319972,
                "y": 200.8016586040083
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01768.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 235.44713199723566,
                "width": 187.828610919143,
                "x": 527.3310297166552,
                "y": 448.8486523842433
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01744.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.38217000691083,
                "width": 245.91568762957849,
                "x": 215.83966827919835,
                "y": 309.60608154803043
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01741.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.0732550103663,
                "width": 342.33586731167935,
                "x": 340.56668970283346,
                "y": 241.49274360746372
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01734.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036632,
                "width": 106.15065653075328,
                "x": 774.0152038700761,
                "y": 281.2992398064962
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01713.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.50000000000001,
                "width": 229.95945945945942,
                "x": 364.1891891891892,
                "y": 32.25675675675676
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01690.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.6496199032481,
                "width": 277.76088458880446,
                "x": 314.9136143745681,
                "y": 221.14720110573603
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01682.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.7546648237733,
                "width": 177.9350380096752,
                "x": 201.00069108500347,
                "y": 46.955079474775395
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01680.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.31582584657917,
                "width": 130.97995853489977,
                "x": 458.8417415342087,
                "y": 609.5922598479613
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01660.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.99516240497582,
                "width": 338.7975120939876,
                "x": 251.2232204561161,
                "y": 166.3026952315135
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01645.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.84105044920523,
                "width": 457.33241188666216,
                "x": 580.2902557014513,
                "y": 330.8362128541811
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01641.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.06979958534902,
                "width": 274.2225293711126,
                "x": 7.961299239806497,
                "y": 202.5708362128542
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01638.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.61230131306152,
                "width": 407.79543883897725,
                "x": 214.9550794747754,
                "y": 145.07256392536283
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01636.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.26399447131996,
                "width": 479.4471319972357,
                "x": 689.9792674498964,
                "y": 76.07463718037319
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01607.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0718728403594,
                "width": 285.72218382861104,
                "x": 746.5929509329648,
                "y": 6.192121630960608
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01603.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.341395991707,
                "width": 266.2612301313062,
                "x": 744.8237733241189,
                "y": 7.961299239806497
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01601.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.99654457498272,
                "width": 138.39391845196957,
                "x": 387.9972356599862,
                "y": 91.4388389771942
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01590.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.14996544574979,
                "width": 106.15065653075328,
                "x": 850.0898410504493,
                "y": 279.53006219765035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01580.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.4105044920525,
                "width": 163.10711817553562,
                "x": 120.27090532135452,
                "y": 134.27505183137527
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01574.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.80234968901175,
                "width": 406.91085003455424,
                "x": 385.68071872840363,
                "y": 256.5307532826538
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01556.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.76364892881827,
                "width": 251.2232204561161,
                "x": 620.9813407049068,
                "y": 361.7968210089841
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01542.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.22736696613686,
                "width": 221.147201105736,
                "x": 229.10850034554252,
                "y": 317.5673807878369
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01520.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.84450587422248,
                "width": 121.9184519695923,
                "x": 532.1575673807878,
                "y": 490.9689011748445
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01514.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.04729729729732,
                "width": 163.4301801801802,
                "x": 139.29954954954954,
                "y": 241.3063063063063
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01509.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805118,
                "width": 150.38009675190048,
                "x": 209.64754664823775,
                "y": 414.87214927436077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01489.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.84035936420184,
                "width": 423.7180373185903,
                "x": 746.5929509329648,
                "y": 567.9060124395301
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01458.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.4561161022806,
                "width": 403.3724948168625,
                "x": 191.07118175535592,
                "y": 318.45196959225984
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01454.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.99585348997928,
                "width": 359.1430545957153,
                "x": 247.68486523842435,
                "y": 42.460262612301314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01446.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.11126468555634,
                "width": 341.45127850725635,
                "x": 621.8659295093297,
                "y": 65.45957152729787
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01445.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.41948859709746,
                "width": 383.02695231513474,
                "x": 229.10850034554252,
                "y": 53.07532826537665
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01422.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286108,
                "width": 367.1043538355219,
                "x": 755.4388389771942,
                "y": 78.72840359364203
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01417.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.64892881824466,
                "width": 347.643400138217,
                "x": 863.3586731167934,
                "y": 176.9177608845888
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01416.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.2646855563234,
                "width": 107.91983413959917,
                "x": 754.5542501727713,
                "y": 260.9536973047685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01409.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.7263303386317,
                "width": 297.2218382861092,
                "x": 375.06565307532827,
                "y": 222.9163787145819
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01398.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.06427090532137,
                "width": 233.68348306841744,
                "x": 889.7608845888044,
                "y": 156.08293020041464
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01367.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 271.56876295784383,
                "width": 193.7249481686248,
                "x": 539.5991706979959,
                "y": 371.5272978576365
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01362.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.72494816862476,
                "width": 258.2999308914997,
                "x": 125.61161022805805,
                "y": 168.9564616447823
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01361.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.7643400138217,
                "width": 364.45058742225297,
                "x": 506.86938493434695,
                "y": 52.1907394609537
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01355.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 251.22322045611617,
                "width": 148.61091914305462,
                "x": 515.7152729785764,
                "y": 451.1402902557015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01336.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.41672425708362,
                "width": 346.75881133379414,
                "x": 761.6309606081549,
                "y": 165.41810642709055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01319.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901865,
                "width": 364.4505874222531,
                "x": 682.9025570145128,
                "y": 73.42087076710436
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01316.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.87975120939876,
                "width": 472.37042156185214,
                "x": 436.10228058051143,
                "y": 38.92190739460954
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01314.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.87353144436764,
                "width": 145.80787836903937,
                "x": 363.2840359364202,
                "y": 18.123013130615064
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01313.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.9827228749136,
                "width": 152.5556323427781,
                "x": 389.7664132688321,
                "y": 245.147201105736
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01306.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 258.8558558558558,
                "width": 224.8536036036037,
                "x": 678.9481981981982,
                "y": 467.2567567567568
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01291.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633033,
                "width": 268.0304077401521,
                "x": 222.03178991015895,
                "y": 305.1831375259157
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01282.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.99516240497587,
                "width": 327.2978576364893,
                "x": 166.3026952315135,
                "y": 298.99101589495507
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01278.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036632,
                "width": 160.99516240497576,
                "x": 774.899792674499,
                "y": 281.2992398064962
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01276.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.5328265376641,
                "width": 79.61299239806493,
                "x": 312.2598479612993,
                "y": 257.41534208707674
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01271.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.99516240497582,
                "width": 459.101589495508,
                "x": 488.2930200414651,
                "y": 141.53420870767104
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01265.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.7622667588113,
                "width": 277.76088458880446,
                "x": 490.062197650311,
                "y": 248.5694540428473
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01262.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.49481686247412,
                "width": 452.0248790601245,
                "x": 634.2501727712508,
                "y": 214.07049067035246
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01261.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.03317208016585,
                "width": 383.02695231513485,
                "x": 564.3676572218383,
                "y": 57.49827228749137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01255.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.22736696613686,
                "width": 296.33724948168634,
                "x": 335.2591568762958,
                "y": 238.8389771941949
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01247.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.26330338631652,
                "width": 433.44851416724265,
                "x": 374.1810642709053,
                "y": 85.80511402902557
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01243.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 241.49274360746372,
                "width": 273.33794056668967,
                "x": 509.5231513476158,
                "y": 245.0310988251555
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01240.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 319.3365583966828,
                "width": 313.1444367657223,
                "x": 805.8604008293021,
                "y": 208.7629578438148
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01225.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.80234968901175,
                "width": 448.4865238424327,
                "x": 570.5597788527989,
                "y": 307.83690393918454
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01205.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.8804422944022,
                "width": 191.9557705597789,
                "x": 636.9039391845197,
                "y": 273.3379405666897
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01191.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 235.3006219765031,
                "width": 341.45127850725646,
                "x": 759.861782999309,
                "y": 155.68762957843816
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01183.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.84105044920528,
                "width": 251.2232204561161,
                "x": 750.1313061506565,
                "y": 6.192121630960608
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.9177608845888,
                "width": 358.25846579129234,
                "x": 797.0145127850726,
                "y": 252.10780926053906
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01162.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.1859018659295,
                "width": 160.99516240497576,
                "x": 596.2128541810644,
                "y": 402.48790601243957
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01160.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.7622667588114,
                "width": 196.37871458189363,
                "x": 541.3683483068418,
                "y": 399.8341395991707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01144.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.34485141672428,
                "width": 167.22598479612992,
                "x": 215.00483759502418,
                "y": 53.54526606772633
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01130.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.22460262612304,
                "width": 373.2964754664823,
                "x": 763.4001382170007,
                "y": 111.45818935729095
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01095.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.28749136143745,
                "width": 181.23013130615064,
                "x": 209.23842432619213,
                "y": 46.13130615065653
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01085.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.95646164478234,
                "width": 403.3724948168625,
                "x": 516.5998617829994,
                "y": 123.84243261921218
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01083.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.18728403593644,
                "width": 122.07325501036632,
                "x": 641.3268832066344,
                "y": 344.10504492052524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01082.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.41948859709743,
                "width": 222.03178991015892,
                "x": 308.7214927436075,
                "y": 166.3026952315135
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01074.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.9557705597789,
                "width": 183.10988251554943,
                "x": 638.6731167933656,
                "y": 320.22114720110574
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01063.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.76434001382165,
                "width": 424.6026261230131,
                "x": 669.6337249481687,
                "y": 366.21976503109886
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01029.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.73738769868694,
                "width": 200.17415342087077,
                "x": 468.24879060124397,
                "y": 216.92881824464408
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01028.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.30200414651,
                "width": 202.57083621285426,
                "x": 637.7885279889426,
                "y": 388.3344851416725
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01011.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633033,
                "width": 241.49274360746375,
                "x": 163.64892881824466,
                "y": 359.1430545957153
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01006.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 264.4920525224603,
                "width": 263.60746371803737,
                "x": 505.984796129924,
                "y": 245.91568762957846
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00998.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 247.68486523842432,
                "width": 298.1064270905321,
                "x": 497.1389080856946,
                "y": 113.22736696613684
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00996.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.95853489979265,
                "width": 168.95646164478234,
                "x": 445.8327574291638,
                "y": 431.6793365583967
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00994.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.80096751900481,
                "width": 243.2619212163096,
                "x": 515.7152729785764,
                "y": 260.0691085003456
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00993.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.38078783690395,
                "width": 325.5286800276434,
                "x": 134.4574982722875,
                "y": 220.26261230131308
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00987.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.1105736005529,
                "width": 284.837595024188,
                "x": 790.822391154112,
                "y": -1.7691776088458881
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00970.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.76641326883208,
                "width": 221.147201105736,
                "x": 243.26192121630962,
                "y": 322.8749136143746
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00961.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.82031789910158,
                "width": 182.05390463026956,
                "x": 204.2957843814789,
                "y": 38.71734623358673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00957.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.91637871458192,
                "width": 128.26537664132695,
                "x": 629.8272287491363,
                "y": 398.9495507947479
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00899.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.1112646855563,
                "width": 147.72633033863167,
                "x": 701.4789219073948,
                "y": 436.9868693849345
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00898.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.07187284035942,
                "width": 108.80442294402212,
                "x": 554.6371803731861,
                "y": 79.61299239806499
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00897.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.80442294402215,
                "width": 145.95715272978583,
                "x": 483.8700760193505,
                "y": 243.26192121630967
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00895.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.9571527297858,
                "width": 286.606772633034,
                "x": 912.8956461644785,
                "y": 191.95577055977893
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00893.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.95715272978578,
                "width": 263.6074637180375,
                "x": 1014.6233586731171,
                "y": 219.3780234968902
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00880.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.60815480304086,
                "width": 236.18521078092613,
                "x": 472.37042156185225,
                "y": 240.60815480304086
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00878.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.30131306150662,
                "width": 187.53282653766416,
                "x": 594.4436765722186,
                "y": 329.06703524533526
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00869.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.57360055286804,
                "width": 158.34139599170703,
                "x": 508.63856254319296,
                "y": 206.99378023496897
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00840.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.88182446440919,
                "width": 155.6876295784382,
                "x": 270.68417415342094,
                "y": 388.33448514167253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00823.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.03248099516247,
                "width": 120.3040774015204,
                "x": 227.3393227366967,
                "y": 255.6461644782309
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00810.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.64961990324812,
                "width": 363.56599861783,
                "x": 249.4540428472703,
                "y": 42.46026261230133
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00790.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.2646855563235,
                "width": 173.37940566689701,
                "x": 758.9771941948862,
                "y": 306.95231513476165
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00756.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.76503109882518,
                "width": 344.9896337249483,
                "x": 343.2204561161024,
                "y": 228.22391154111963
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00754.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.80304077401524,
                "width": 212.30131306150662,
                "x": 376.8348306841743,
                "y": 0.8845888044229443
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00747.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.18935729094679,
                "width": 221.14720110573614,
                "x": 905.818935729095,
                "y": 190.18659295093303
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00728.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.72425708362135,
                "width": 340.56668970283357,
                "x": 492.71596406358,
                "y": 59.26744989633727
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00715.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.071181755356,
                "width": 137.99585348997925,
                "x": 602.4049758120251,
                "y": 339.6821008984106
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00710.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.303386316517,
                "width": 410.4492052522461,
                "x": 560.8293020041467,
                "y": 91.9972356599862
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00705.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.38009675190054,
                "width": 389.2190739460955,
                "x": 642.2114720110576,
                "y": 183.10988251554946
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00701.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.60953697304774,
                "width": 480.3317208016588,
                "x": 615.6738078783692,
                "y": 555.521769177609
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00690.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286114,
                "width": 435.2176917760886,
                "x": 516.5998617829995,
                "y": 137.11126468555636
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00679.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 121.18866620594326,
                "x": 959.7788527988946,
                "y": 465.2937111264687
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00668.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.61091914305462,
                "width": 140.6496199032482,
                "x": 625.4042847270216,
                "y": 323.75950241879764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00643.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.87836903939188,
                "width": 137.1112646855563,
                "x": 634.2501727712511,
                "y": 413.102971665515
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00634.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.57152729785767,
                "width": 415.75673807878377,
                "x": 512.1769177608847,
                "y": 169.8410504492053
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00624.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113342,
                "width": 355.6046993780236,
                "x": 735.0932964754667,
                "y": 303.4139599170699
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00617.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 230.87767795438847,
                "width": 226.4547339322737,
                "x": 82.26675881133382,
                "y": 242.37733241188673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00607.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.53351762266766,
                "width": 184.87906012439532,
                "x": 639.5577055977888,
                "y": 330.83621285418116
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00596.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.2246026261231,
                "width": 123.84243261921222,
                "x": 480.3317208016588,
                "y": 427.2563925362821
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00595.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.6876295784382,
                "width": 157.45680718728408,
                "x": 521.0228058051142,
                "y": 277.7608845888045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00592.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.95922598479615,
                "width": 112.34277816171391,
                "x": 519.2536281962683,
                "y": 503.3310297166553
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00579.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.45818935729096,
                "width": 105.26606772633033,
                "x": 762.515549412578,
                "y": 321.1057360055288
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00576.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 284.83759502418803,
                "width": 204.34001382170015,
                "x": 770.4768486523844,
                "y": 199.03248099516247
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00570.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.9958534899793,
                "width": 82.26675881133383,
                "x": 812.9371112646858,
                "y": 294.56807187284045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00555.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.61230131306155,
                "width": 121.18866620594332,
                "x": 499.79267449896355,
                "y": 266.2612301313062
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00546.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.11126468555636,
                "width": 113.22736696613686,
                "x": 721.8244644091226,
                "y": 320.22114720110585
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00544.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.6876295784382,
                "width": 183.99447131997238,
                "x": 704.1326883206636,
                "y": 351.1817553559089
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00526.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.95646164478237,
                "width": 229.9930891499655,
                "x": 279.5300621976504,
                "y": 204.34001382170013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00525.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.22598479612998,
                "width": 207.87836903939194,
                "x": 652.8265376641328,
                "y": 392.75742916378726
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00509.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.45749827228752,
                "width": 495.3697304768488,
                "x": 447.6019350380098,
                "y": 375.0656530753284
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00507.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.7650310988252,
                "width": 343.22045611610235,
                "x": 165.41810642709058,
                "y": 181.3407049067036
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00502.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.64823773324122,
                "width": 145.07256392536289,
                "x": 133.57290946786458,
                "y": 141.5342087076711
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00466.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.9557705597789,
                "width": 264.4920525224603,
                "x": 386.56530753282664,
                "y": 172.49481686247412
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00457.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.41879751209402,
                "width": 79.61299239806499,
                "x": 254.76157567380795,
                "y": 242.37733241188673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00451.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.61161022805808,
                "width": 337.0283344851418,
                "x": 154.80304077401524,
                "y": 187.5328265376642
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00447.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.0331720801659,
                "width": 321.99032480995174,
                "x": 386.56530753282664,
                "y": 46.88320663441605
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00421.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.91983413959923,
                "width": 84.92052522460267,
                "x": 860.7049067035248,
                "y": 291.02971665514866
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00401.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.68832066344157,
                "width": 188.4174153420871,
                "x": 713.8631651693161,
                "y": 402.4879060124397
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00384.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.45611610228065,
                "width": 125.61161022805811,
                "x": 744.8237733241191,
                "y": 379.4885970974431
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00381.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 252.10780926053917,
                "width": 75.19004837595027,
                "x": 0.8845888044229443,
                "y": 474.13959917069815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00366.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863173,
                "width": 341.45127850725646,
                "x": 170.72563925362826,
                "y": 311.3752591568764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00356.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.34070490670354,
                "width": 77.8438147892191,
                "x": 305.1831375259158,
                "y": 263.6074637180374
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00353.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.9184519695923,
                "width": 434.33310297166554,
                "x": 636.9039391845199,
                "y": 217.6088458880443
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00342.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.15065653075331,
                "width": 199.91706979958536,
                "x": 421.0642709053215,
                "y": 148.61091914305464
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00341.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.03386316516935,
                "width": 169.8410504492053,
                "x": 204.34001382170013,
                "y": 54.84450587422255
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00317.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.37940566689707,
                "width": 83.15134761575678,
                "x": 565.2522460262614,
                "y": 261.83828610919153
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00300.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.49550794747756,
                "width": 339.68210089841057,
                "x": 730.6703524533519,
                "y": 338.7975120939877
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00299.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0718728403594,
                "width": 143.30338631651696,
                "x": 206.10919143054602,
                "y": 262.7228749136145
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00295.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.53351762266766,
                "width": 118.53489979267454,
                "x": 666.9799585349,
                "y": 136.22667588113342
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00291.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.6876295784382,
                "width": 339.68210089841057,
                "x": 811.1679336558399,
                "y": 281.2992398064963
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00281.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.68832066344166,
                "width": 364.4505874222531,
                "x": 650.172771250864,
                "y": 187.5328265376642
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00264.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.95646164478237,
                "width": 387.4498963372496,
                "x": 529.8686938493437,
                "y": 132.68832066344166
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00227.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.65031098825159,
                "width": 357.3738769868695,
                "x": 137.11126468555636,
                "y": 195.49412577747069
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00208.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 50.4215618521078,
                "width": 153.9184519695923,
                "x": 595.3282653766415,
                "y": 320.22114720110585
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00201.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767798,
                "width": 189.3020041465101,
                "x": 169.8410504492053,
                "y": 329.9516240497582
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00193.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 71.6516931582585,
                "width": 91.99723565998613,
                "x": 918.2031789910162,
                "y": 191.95577055977893
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00188.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036632,
                "width": 209.64754664823778,
                "x": 198.14789219073953,
                "y": 371.5272978576366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00187.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786458,
                "width": 88.45888044229446,
                "x": 822.6675881133382,
                "y": 291.9143054595716
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00177.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.99585348997934,
                "width": 297.2218382861093,
                "x": 364.450587422253,
                "y": 225.5701451278508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00156.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.10850034554255,
                "width": 734.2087076710437,
                "x": 115.8811333794057,
                "y": 550.2142363510713
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00136.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.8410504492053,
                "width": 257.41534208707674,
                "x": 749.2467173462338,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00130.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574296,
                "width": 82.26675881133389,
                "x": 447.6019350380098,
                "y": 100.84312370421566
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00110.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.3026952315135,
                "width": 389.2190739460955,
                "x": 525.445749827229,
                "y": 121.18866620594336
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00085.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.57360055286807,
                "width": 123.84243261921222,
                "x": 735.0932964754667,
                "y": 419.2950932964756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00045.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.0732550103663,
                "width": 304.29854872149286,
                "x": 365.33517622667597,
                "y": 110.57360055286804
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00039.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.64823773324127,
                "width": 99.07394609536976,
                "x": 292.79889426399455,
                "y": 268.0304077401521
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00037.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 57.49827228749143,
                "width": 127.380787836904,
                "x": 509.5231513476159,
                "y": 509.5231513476159
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00032.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.64754664823778,
                "width": 191.9557705597789,
                "x": 597.9820317899104,
                "y": 332.60539046302705
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00029.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 6.192121630960571,
                "width": 21.23013130615061,
                "x": 717.4015203870078,
                "y": 500.6772633033865
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00020.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.6095369730478,
                "width": 176.91776088458886,
                "x": 460.870767104354,
                "y": 494.48514167242587
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00012.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.60953697304768,
                "width": 107.03524533517623,
                "x": 647.5190048375953,
                "y": 418.41050449205267
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00010.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.2280580511403,
                "width": 104.38147892190739,
                "x": 758.0926053904633,
                "y": 281.2992398064963
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04589.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.6067726330339,
                "width": 300.760193503801,
                "x": 323.75950241879764,
                "y": 124.72702142363515
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01507.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.07187284035942,
                "width": 244.14651002073265,
                "x": 759.8617829993092,
                "y": 5.307532826537666
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04588.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.84381478921915,
                "width": 177.8023496890118,
                "x": 454.6786454733934,
                "y": 445.8327574291639
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07915.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.99447131997238,
                "width": 84.03593642017971,
                "x": 113.22736696613687,
                "y": 481.2163096060817
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07904.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786463,
                "width": 70.76710435383552,
                "x": 560.8293020041467,
                "y": 364.450587422253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07883.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 60.152038700760215,
                "width": 142.41879751209405,
                "x": 407.7954388389773,
                "y": 390.98825155494137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07879.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 59.26744989633721,
                "width": 176.0331720801659,
                "x": 414.8721492743609,
                "y": 383.91154111955785
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07874.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.53489979267454,
                "width": 199.91706979958536,
                "x": 375.95024187975133,
                "y": 339.6821008984106
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07807.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.3020041465101,
                "width": 330.8362128541811,
                "x": 841.2439530062201,
                "y": 162.76434001382174
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07794.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.2280580511403,
                "width": 236.18521078092618,
                "x": 367.10435383552186,
                "y": 393.6420179682102
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07771.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.0704906703525,
                "width": 183.9944713199725,
                "x": 655.4803040774017,
                "y": 444.063579820318
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07662.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.34277816171397,
                "width": 153.91845196959224,
                "x": 379.4885970974431,
                "y": 412.21838286109204
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07652.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.37871458189363,
                "width": 223.80096751900487,
                "x": 599.7512093987563,
                "y": 432.56392536281976
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07636.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.38217000691088,
                "width": 178.6869384934347,
                "x": 360.9122322045613,
                "y": 442.2944022114722
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07479.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.10919143054605,
                "width": 102.61230131306154,
                "x": 95.53559087767799,
                "y": 468.83206634416047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07445.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.30545957152731,
                "width": 193.7249481686248,
                "x": 316.68279198341406,
                "y": 419.2950932964756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07406.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.7242570836213,
                "width": 184.87906012439532,
                "x": 648.4035936420182,
                "y": 441.4098134070492
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07280.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.91914305459574,
                "width": 404.2570836212855,
                "x": 381.257774706289,
                "y": 124.72702142363515
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07262.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 60.152038700760215,
                "width": 157.45680718728408,
                "x": 266.2612301313062,
                "y": 419.2950932964756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07242.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.53628196268147,
                "width": 169.84105044920528,
                "x": 462.6399447131999,
                "y": 446.71734623358685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07204.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.30131306150662,
                "width": 324.6440912232206,
                "x": 857.166551485833,
                "y": 115.8811333794057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07167.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.03593642017972,
                "width": 152.1492743607464,
                "x": 425.4872149274362,
                "y": 388.33448514167253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.99792674498968,
                "width": 164.5335176226676,
                "x": 239.72356599861791,
                "y": 410.44920525224614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07162.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.8438147892191,
                "width": 178.68693849343475,
                "x": 322.8749136143747,
                "y": 403.3724948168626
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07118.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.18935729094682,
                "width": 191.0711817553559,
                "x": 381.257774706289,
                "y": 390.1036627505184
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07021.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.1499654457499,
                "width": 178.6869384934348,
                "x": 614.7892190739462,
                "y": 326.4132688320664
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06929.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.34277816171391,
                "width": 158.34139599170703,
                "x": 471.4858327574293,
                "y": 382.14236351071196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06918.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.57152729785764,
                "width": 89.3434692467174,
                "x": 545.7912923289566,
                "y": 353.8355217691777
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06879.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.8396682791984,
                "width": 350.29716655148593,
                "x": 607.7125086385628,
                "y": 45.11402902557016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06868.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.76710435383552,
                "width": 162.76434001382177,
                "x": 237.06979958534907,
                "y": 398.9495507947479
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06721.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364204,
                "width": 163.6489288182447,
                "x": 231.7622667588114,
                "y": 406.91085003455436
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06714.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.0338631651694,
                "width": 136.22667588113342,
                "x": 498.02349689011766,
                "y": 368.87353144436776
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06709.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.03524533517623,
                "width": 188.4174153420871,
                "x": 388.33448514167253,
                "y": 400.7187284035938
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06668.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 75.19004837595025,
                "width": 191.07118175535595,
                "x": 256.53075328265385,
                "y": 413.102971665515
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06664.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.45818935729102,
                "width": 199.03248099516247,
                "x": 310.49067035245344,
                "y": 410.44920525224614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06645.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.95715272978583,
                "width": 338.7975120939877,
                "x": 462.6399447131999,
                "y": 102.61230131306154
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06570.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.1499654457499,
                "width": 338.7975120939877,
                "x": 451.1402902557016,
                "y": 101.72771250863859
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06479.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.38009675190057,
                "width": 134.45749827228752,
                "x": 374.18106427090544,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06450.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.49619903248106,
                "width": 177.8023496890118,
                "x": 383.0269523151349,
                "y": 388.33448514167253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06445.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.34416033172084,
                "width": 130.0345542501728,
                "x": 334.37456807187294,
                "y": 452.02487906012453
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06319.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.07463718037326,
                "width": 175.14858327574302,
                "x": 465.2937111264687,
                "y": 451.1402902557016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06298.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.80442294402218,
                "width": 99.07394609536982,
                "x": 812.0525224602628,
                "y": 286.6067726330339
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06293.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.3393227366967,
                "width": 355.6046993780235,
                "x": 610.3662750518316,
                "y": 51.30615065653077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06263.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.18866620594338,
                "width": 198.14789219073953,
                "x": 308.72149274360754,
                "y": 402.4879060124397
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06260.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.1859018659296,
                "width": 337.0283344851417,
                "x": 322.8749136143747,
                "y": 168.95646164478237
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06252.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364204,
                "width": 177.8023496890118,
                "x": 260.9536973047686,
                "y": 403.3724948168626
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06190.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.07463718037314,
                "width": 193.72494816862485,
                "x": 443.17899101589506,
                "y": 461.75535590877695
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05962.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.26399447132002,
                "width": 78.72840359364204,
                "x": 390.1036627505184,
                "y": 371.5272978576366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05878.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113342,
                "width": 345.87422252937125,
                "x": 292.79889426399455,
                "y": 237.95438838977202
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05836.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.92052522460261,
                "width": 186.64823773324122,
                "x": 220.26261230131314,
                "y": 403.3724948168626
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05588.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767798,
                "width": 164.5335176226676,
                "x": 374.18106427090544,
                "y": 351.1817553559089
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05576.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.18866620594332,
                "width": 147.72633033863173,
                "x": 421.94885970974445,
                "y": 343.2204561161024
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05559.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 59.26744989633727,
                "width": 179.5715272978577,
                "x": 413.98756046993793,
                "y": 375.95024187975133
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05312.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.03524533517623,
                "width": 130.03455425017273,
                "x": 643.9806496199035,
                "y": 342.33586731167946
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05266.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.99792674498968,
                "width": 167.1872840359365,
                "x": 313.1444367657223,
                "y": 407.7954388389773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05206.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.99792674498968,
                "width": 161.87975120939882,
                "x": 350.29716655148593,
                "y": 454.6786454733934
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05106.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.49619903248106,
                "width": 149.49550794747756,
                "x": 630.7118175535593,
                "y": 329.9516240497582
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05089.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 83.15134761575683,
                "width": 176.91776088458886,
                "x": 459.98617829993105,
                "y": 446.71734623358685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05000.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.95784381478927,
                "width": 322.8749136143747,
                "x": 278.64547339322746,
                "y": 237.06979958534907
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04950.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.34001382170015,
                "width": 107.91983413959929,
                "x": 613.0200414651003,
                "y": 431.6793365583968
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04920.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152037,
                "width": 166.30269523151355,
                "x": 430.79474775397387,
                "y": 363.56599861783013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04907.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.15065653075334,
                "width": 80.49758120248794,
                "x": 820.0138217000693,
                "y": 274.2225293711127
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04836.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.92052522460267,
                "width": 183.99447131997243,
                "x": 378.6040082930202,
                "y": 435.2176917760886
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04823.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 230.87767795438845,
                "width": 170.7256392536283,
                "x": 655.4803040774017,
                "y": 435.2176917760886
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04708.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 57.498272287491375,
                "width": 162.76434001382177,
                "x": 234.41603317208023,
                "y": 412.21838286109204
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04666.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.64754664823778,
                "width": 172.49481686247418,
                "x": 654.5957152729787,
                "y": 446.71734623358685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04635.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152043,
                "width": 90.22805805114035,
                "x": 815.5908776779546,
                "y": 282.18382861091925
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04612.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.68970283344851,
                "width": 170.72563925362823,
                "x": 317.567380787837,
                "y": 403.3724948168626
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04598.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 75.19004837595025,
                "width": 156.57221838286114,
                "x": 467.9474775397375,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04583.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 66.34416033172079,
                "x": 474.13959917069815,
                "y": 360.9122322045613
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04570.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 61.92121630960605,
                "width": 213.18590186592957,
                "x": 251.22322045611617,
                "y": 422.8334485141674
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04527.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.41672425708367,
                "width": 150.3800967519005,
                "x": 666.095369730477,
                "y": 448.48652384243275
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04504.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.303386316517,
                "width": 464.40912232204573,
                "x": 400.7187284035938,
                "y": 122.07325501036631
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04489.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.6088458880443,
                "width": 332.6053904630271,
                "x": 350.29716655148593,
                "y": 173.37940566689707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04480.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.53628196268147,
                "width": 162.76434001382177,
                "x": 353.8355217691777,
                "y": 449.3711126468557
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04354.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.26675881133383,
                "width": 226.4547339322737,
                "x": 361.79682100898424,
                "y": 406.0262612301314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04342.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.8410504492053,
                "width": 326.4132688320665,
                "x": 873.973738769869,
                "y": 163.64892881824468
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04202.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.95922598479615,
                "width": 158.34139599170703,
                "x": 155.6876295784382,
                "y": 383.91154111955785
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04121.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.72771250863855,
                "width": 178.68693849343475,
                "x": 364.450587422253,
                "y": 403.3724948168626
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04102.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.9592259847962,
                "width": 206.109191430546,
                "x": 413.102971665515,
                "y": 451.1402902557016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04065.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364204,
                "width": 196.3787145818937,
                "x": 413.102971665515,
                "y": 390.1036627505184
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04056.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.99723565998625,
                "width": 144.18797512093994,
                "x": 421.94885970974445,
                "y": 387.4498963372496
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03910.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.33932273669672,
                "width": 324.6440912232206,
                "x": 358.25846579129245,
                "y": 155.6876295784382
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03842.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 83.15134761575683,
                "width": 145.95715272978583,
                "x": 379.4885970974431,
                "y": 445.8327574291639
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03737.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.18797512093988,
                "width": 169.84105044920534,
                "x": 344.98963372494825,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03706.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.1872840359365,
                "width": 84.03593642017972,
                "x": 749.2467173462338,
                "y": 235.30062197650318
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03694.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.7249481686248,
                "width": 397.180373185902,
                "x": 603.289564616448,
                "y": 61.036627505183155
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03682.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.99378023496894,
                "width": 252.992398064962,
                "x": 916.4340013821703,
                "y": 160.11057360055293
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03661.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921222,
                "width": 214.0704906703525,
                "x": 298.10642709053224,
                "y": 399.83413959917084
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03644.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 55.72909467864548,
                "width": 185.7636489288183,
                "x": 247.6848652384244,
                "y": 428.140981340705
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03575.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.1126468555633,
                "width": 167.1872840359365,
                "x": 465.2937111264687,
                "y": 438.7560469937804
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03559.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.03248099516247,
                "width": 140.6496199032481,
                "x": 596.2128541810645,
                "y": 428.140981340705
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03483.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863173,
                "width": 151.26468555632346,
                "x": 628.0580511402904,
                "y": 314.0290255701452
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03479.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.2280580511403,
                "width": 181.3407049067036,
                "x": 413.98756046993793,
                "y": 382.14236351071196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03470.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 65.45957152729784,
                "width": 199.91706979958548,
                "x": 330.83621285418116,
                "y": 417.5259156876297
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03432.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.6475466482378,
                "width": 384.7961299239808,
                "x": 303.4139599170699,
                "y": 169.8410504492053
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03356.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 60.15203870076016,
                "width": 179.57152729785767,
                "x": 206.99378023496897,
                "y": 422.8334485141674
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03262.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152043,
                "width": 155.6876295784382,
                "x": 620.9813407049069,
                "y": 329.06703524533526
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03209.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.14789219073953,
                "width": 251.2232204561161,
                "x": 606.8279198341398,
                "y": 434.33310297166565
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03208.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 57.498272287491375,
                "width": 206.10919143054605,
                "x": 212.30131306150662,
                "y": 411.3337940566691
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03161.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 58.38286109191432,
                "width": 185.76364892881833,
                "x": 271.5687629578439,
                "y": 425.4872149274362
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03090.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.84312370421566,
                "width": 193.72494816862476,
                "x": 191.95577055977893,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03061.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.0739460953697,
                "width": 195.49412577747074,
                "x": 451.1402902557016,
                "y": 438.7560469937804
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02978.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 62.805805114029056,
                "width": 169.8410504492053,
                "x": 210.53213545266075,
                "y": 415.7567380787838
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02928.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.8023496890118,
                "width": 80.49758120248794,
                "x": 550.2142363510713,
                "y": 340.56668970283357
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02825.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.61091914305462,
                "width": 68.99792674498963,
                "x": 477.67795438838994,
                "y": 363.56599861783013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02821.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.72425708362132,
                "width": 338.7975120939876,
                "x": 839.4747753973742,
                "y": 130.03455425017282
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02719.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.95507947477546,
                "width": 183.99447131997238,
                "x": 597.0974429854874,
                "y": 414.8721492743609
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02710.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863173,
                "width": 162.76434001382182,
                "x": 365.33517622667597,
                "y": 379.4885970974431
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02658.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.0345542501728,
                "width": 167.1872840359365,
                "x": 435.2176917760886,
                "y": 360.02764340013834
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02643.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.03593642017972,
                "width": 194.60953697304774,
                "x": 302.52937111264697,
                "y": 388.33448514167253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02610.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.80304077401524,
                "width": 85.80511402902562,
                "x": 538.714581893573,
                "y": 363.56599861783013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02530.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.64961990324815,
                "width": 357.3738769868695,
                "x": 272.45335176226683,
                "y": 231.7622667588114
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02514.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.42087076710436,
                "width": 176.9177608845889,
                "x": 163.64892881824468,
                "y": 401.60331720801673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02491.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.80511402902556,
                "width": 184.87906012439538,
                "x": 451.1402902557016,
                "y": 447.6019350380098
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02388.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.64961990324812,
                "width": 77.8438147892191,
                "x": 755.4388389771945,
                "y": 244.14651002073262
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02208.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.4561161022806,
                "width": 93.7664132688321,
                "x": 91.11264685556326,
                "y": 477.67795438838994
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02134.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.26399447132007,
                "width": 72.53628196268141,
                "x": 468.83206634416047,
                "y": 354.72011057360066
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02118.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.95507947477546,
                "width": 158.34139599170703,
                "x": 661.6724257083623,
                "y": 443.17899101589506
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02072.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.34416033172079,
                "width": 176.91776088458886,
                "x": 317.567380787837,
                "y": 400.7187284035938
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02052.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.15065653075334,
                "width": 189.30200414651011,
                "x": 337.91292328956473,
                "y": 387.4498963372496
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02046.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.03524533517623,
                "width": 181.3407049067036,
                "x": 239.72356599861791,
                "y": 400.7187284035938
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02036.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.65100207325503,
                "width": 200.80165860400837,
                "x": 299.87560469937813,
                "y": 391.8728403593643
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02025.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 337.9129232895647,
                "width": 168.07187284035933,
                "x": 919.0877677954392,
                "y": 166.30269523151352
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01950.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.42017968210092,
                "width": 211.41672425708373,
                "x": 312.25984796129933,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01914.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.37871458189363,
                "width": 341.4512785072566,
                "x": 847.4360746371806,
                "y": 153.9184519695923
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01910.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786463,
                "width": 183.99447131997243,
                "x": 344.10504492052536,
                "y": 391.8728403593643
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01883.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.30476848652387,
                "width": 200.80165860400837,
                "x": 219.3780234968902,
                "y": 421.0642709053215
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01878.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.7256392536283,
                "width": 102.61230131306161,
                "x": 540.4837595024189,
                "y": 352.95093296475477
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01830.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.68762957843825,
                "width": 87.57429163787151,
                "x": 353.8355217691777,
                "y": 371.5272978576366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01809.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.11195577055986,
                "width": 173.37940566689707,
                "x": 482.98548721492756,
                "y": 384.79612992398074
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01772.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.303386316517,
                "width": 137.99585348997925,
                "x": 433.4485141672427,
                "y": 336.14374568071884
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01733.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.68832066344163,
                "width": 149.49550794747756,
                "x": 466.1782999308916,
                "y": 369.7581202487907
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01722.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 50.4215618521078,
                "width": 221.14720110573603,
                "x": 284.8375950241881,
                "y": 439.64063579820333
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01693.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364204,
                "width": 261.83828610919153,
                "x": 252.99239806496206,
                "y": 386.56530753282664
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01654.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.76226675881145,
                "width": 94.65100207325504,
                "x": 101.72771250863859,
                "y": 415.7567380787838
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01612.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805112,
                "width": 97.30476848652393,
                "x": 538.714581893573,
                "y": 360.9122322045613
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01604.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.42017968210098,
                "width": 114.99654457498275,
                "x": 805.8604008293023,
                "y": 287.4913614374569
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01599.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.68832066344163,
                "width": 381.257774706289,
                "x": 407.7954388389773,
                "y": 124.72702142363515
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01584.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.53213545266073,
                "width": 374.18106427090544,
                "x": 303.4139599170699,
                "y": 161.87975120939882
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01558.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.91845196959235,
                "width": 93.76641326883208,
                "x": 362.6814098134072,
                "y": 367.10435383552186
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01485.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.60953697304774,
                "width": 85.80511402902559,
                "x": 96.42017968210092,
                "y": 474.13959917069815
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01464.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.2280580511403,
                "width": 231.7622667588114,
                "x": 219.3780234968902,
                "y": 413.98756046993793
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01455.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.68762957843825,
                "width": 173.37940566689713,
                "x": 358.25846579129245,
                "y": 373.2964754664825
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01364.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863173,
                "width": 93.7664132688321,
                "x": 101.72771250863859,
                "y": 485.6392536281964
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01354.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.72563925362826,
                "width": 380.373185901866,
                "x": 283.95300621976514,
                "y": 229.10850034554258
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01338.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.07394609536976,
                "width": 209.64754664823784,
                "x": 268.91499654457505,
                "y": 392.75742916378726
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01304.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 242.37733241188673,
                "width": 346.75881133379414,
                "x": 360.9122322045613,
                "y": 146.84174153420875
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01246.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.95784381478927,
                "width": 140.6496199032481,
                "x": 472.37042156185225,
                "y": 370.64270905321365
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01239.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.99792674498968,
                "width": 222.91637871458198,
                "x": 234.41603317208023,
                "y": 409.5646164478232
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01152.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.8438147892191,
                "width": 160.99516240497584,
                "x": 207.8783690393919,
                "y": 385.6807187284037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01128.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036635,
                "width": 102.6123013130615,
                "x": 797.0145127850728,
                "y": 241.49274360746378
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01112.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.26675881133377,
                "width": 204.34001382170015,
                "x": 275.9917069799586,
                "y": 403.3724948168626
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01093.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.303386316517,
                "width": 178.68693849343475,
                "x": 337.0283344851418,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01072.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.6102280580512,
                "width": 340.5666897028336,
                "x": 620.0967519004839,
                "y": 38.03731859018661
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01046.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.95853489979271,
                "width": 131.80373185901874,
                "x": 428.140981340705,
                "y": 375.0656530753284
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01033.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.26468555632346,
                "width": 127.38078783690395,
                "x": 498.9080856945406,
                "y": 355.6046993780236
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00967.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.18935729094682,
                "width": 205.22460262612304,
                "x": 416.6413268832068,
                "y": 361.79682100898424
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00940.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.88044229440231,
                "width": 168.0718728403594,
                "x": 344.10504492052536,
                "y": 390.1036627505184
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00831.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.88251554941263,
                "width": 140.64961990324812,
                "x": 205.22460262612307,
                "y": 407.7954388389773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00713.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.53351762266766,
                "width": 293.68348306841744,
                "x": 861.5894955079477,
                "y": 175.14858327574296
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00672.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.4554250172772,
                "width": 139.7650310988252,
                "x": 64.57498272287494,
                "y": 432.56392536281976
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00633.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786458,
                "width": 396.29578438147905,
                "x": 397.180373185902,
                "y": 102.61230131306154
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00562.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113342,
                "width": 358.25846579129245,
                "x": 273.3379405666898,
                "y": 231.7622667588114
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00561.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 80.49758120248794,
                "width": 183.99447131997243,
                "x": 325.5286800276435,
                "y": 379.4885970974431
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00369.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364204,
                "width": 191.071181755356,
                "x": 266.2612301313062,
                "y": 404.2570836212855
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00351.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.61091914305462,
                "width": 164.53351762266766,
                "x": 469.7166551485834,
                "y": 354.72011057360066
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00338.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.99723565998619,
                "width": 236.18521078092607,
                "x": 344.10504492052536,
                "y": 383.0269523151349
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00288.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 63.690393918451946,
                "width": 187.53282653766422,
                "x": 412.21838286109204,
                "y": 402.4879060124397
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00275.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.68970283344856,
                "width": 192.8403593642019,
                "x": 413.98756046993793,
                "y": 394.52660677263316
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00211.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.1098825155495,
                "width": 301.64478230822397,
                "x": 881.0504492052526,
                "y": 175.14858327574296
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00186.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 71.65169315825847,
                "width": 166.30269523151355,
                "x": 426.37180373185913,
                "y": 377.7194194885972
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.65100207325509,
                "width": 177.8023496890118,
                "x": 277.7608845888045,
                "y": 387.4498963372496
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00154.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.11057360055293,
                "width": 108.80442294402218,
                "x": 447.6019350380098,
                "y": 345.8742225293712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00121.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805123,
                "width": 129.1499654457499,
                "x": 435.2176917760886,
                "y": 352.0663441603318
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00097.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.41672425708367,
                "width": 332.6053904630271,
                "x": 613.9046302695233,
                "y": 41.57567380787838
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07877.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.95507947477546,
                "width": 186.64823773324122,
                "x": 610.3662750518316,
                "y": 411.3337940566691
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07871.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152043,
                "width": 168.07187284035945,
                "x": 387.4498963372496,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07858.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901874,
                "width": 188.41741534208717,
                "x": 413.98756046993793,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07811.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.18590186592957,
                "width": 175.1485832757429,
                "x": 597.9820317899104,
                "y": 413.98756046993793
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07802.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.7284035936421,
                "width": 198.14789219073953,
                "x": 442.2944022114722,
                "y": 449.3711126468557
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07797.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574302,
                "width": 73.42087076710436,
                "x": 559.9447131997238,
                "y": 345.8742225293712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07745.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.65031098825159,
                "width": 127.380787836904,
                "x": 640.4422944022117,
                "y": 325.5286800276435
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07741.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.72771250863855,
                "width": 178.6869384934347,
                "x": 323.75950241879764,
                "y": 401.60331720801673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07698.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 88.45888044229446,
                "width": 214.07049067035257,
                "x": 741.2854181064273,
                "y": 269.799585348998
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07664.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.64754664823778,
                "width": 361.79682100898424,
                "x": 317.567380787837,
                "y": 178.68693849343475
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07651.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.88251554941263,
                "width": 155.6876295784382,
                "x": 213.18590186592957,
                "y": 406.0262612301314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07471.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767798,
                "width": 180.45611610228062,
                "x": 145.07256392536286,
                "y": 378.6040082930202
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07447.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.30545957152731,
                "width": 206.993780234969,
                "x": 251.22322045611617,
                "y": 419.2950932964756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07441.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364204,
                "width": 168.95646164478237,
                "x": 183.9944713199724,
                "y": 409.5646164478232
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07437.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.26675881133377,
                "width": 185.76364892881833,
                "x": 198.14789219073953,
                "y": 401.60331720801673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07435.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.18590186592957,
                "width": 206.10919143054593,
                "x": 607.7125086385628,
                "y": 419.2950932964756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07418.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.1098825155495,
                "width": 115.88113337940575,
                "x": 444.063579820318,
                "y": 327.29785763648937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07374.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.95715272978583,
                "width": 86.68970283344856,
                "x": 366.2197650310989,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07358.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.7263303386317,
                "width": 86.68970283344856,
                "x": 758.9771941948862,
                "y": 241.49274360746378
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07316.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.14789219073953,
                "width": 99.95853489979271,
                "x": 360.02764340013834,
                "y": 358.25846579129245
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07307.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.26675881133383,
                "width": 104.38147892190739,
                "x": 753.6696613683486,
                "y": 276.87629578438157
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07240.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.07394609536976,
                "width": 156.57221838286108,
                "x": 421.94885970974445,
                "y": 382.14236351071196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07239.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.37871458189363,
                "width": 408.6800276434002,
                "x": 600.6357982031792,
                "y": 47.767795438838995
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07223.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.34346924671735,
                "width": 217.60884588804436,
                "x": 310.49067035245344,
                "y": 396.29578438147905
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07210.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.76364892881833,
                "width": 123.84243261921222,
                "x": 513.9460953697306,
                "y": 344.10504492052536
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07145.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.9930891499655,
                "width": 199.9170697995853,
                "x": 649.2881824464412,
                "y": 436.10228058051155
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07133.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.41672425708367,
                "width": 242.37733241188675,
                "x": 597.9820317899104,
                "y": 417.5259156876297
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07127.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.30200414651,
                "width": 92.88182446440914,
                "x": 413.102971665515,
                "y": 343.2204561161024
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07114.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.53628196268147,
                "width": 200.80165860400842,
                "x": 408.68002764340025,
                "y": 367.9889426399448
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07090.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 64.57498272287495,
                "width": 224.68555632342787,
                "x": 330.83621285418116,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07048.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.38078783690395,
                "width": 138.8804422944022,
                "x": 437.87145818935744,
                "y": 363.56599861783013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07033.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.1126468555633,
                "width": 223.80096751900493,
                "x": 288.3759502418798,
                "y": 404.2570836212855
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_07018.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 352.0663441603318,
                "width": 169.84105044920534,
                "x": 957.1250863856258,
                "y": 166.30269523151352
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06979.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.64478230822397,
                "width": 285.72218382861104,
                "x": 910.2418797512097,
                "y": 142.41879751209405
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06976.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.99792674498963,
                "width": 60.15203870076016,
                "x": 839.4747753973742,
                "y": 284.8375950241881
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06923.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.72702142363516,
                "width": 206.109191430546,
                "x": 305.1831375259158,
                "y": 397.180373185902
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06915.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.99654457498275,
                "width": 168.07187284035945,
                "x": 477.67795438838994,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06852.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767803,
                "width": 187.53282653766422,
                "x": 443.17899101589506,
                "y": 367.10435383552186
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06850.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.03524533517623,
                "width": 203.45542501727715,
                "x": 383.0269523151349,
                "y": 383.0269523151349
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06834.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.03524533517628,
                "width": 207.87836903939188,
                "x": 370.64270905321365,
                "y": 385.6807187284037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06826.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.496199032481,
                "width": 166.30269523151355,
                "x": 330.83621285418116,
                "y": 380.37318590186607
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06735.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.34346924671735,
                "width": 201.68624740843129,
                "x": 129.14996544574987,
                "y": 395.4111955770561
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06722.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901868,
                "width": 144.18797512093994,
                "x": 487.4084312370423,
                "y": 382.14236351071196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06622.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.57360055286802,
                "width": 95.53559087767792,
                "x": 799.6682791983417,
                "y": 282.18382861091925
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06619.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.84105044920534,
                "width": 96.42017968210098,
                "x": 542.2529371112648,
                "y": 352.95093296475477
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06574.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.76295784381483,
                "width": 207.87836903939183,
                "x": 607.7125086385628,
                "y": 421.94885970974445
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06503.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 220.26261230131314,
                "width": 391.8728403593644,
                "x": 293.6834830684175,
                "y": 156.57221838286114
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06437.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633039,
                "width": 217.60884588804436,
                "x": 311.3752591568764,
                "y": 370.64270905321365
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.2246026261231,
                "width": 337.9129232895648,
                "x": 868.6662059433313,
                "y": 156.57221838286114
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06383.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.7256392536283,
                "width": 89.3434692467174,
                "x": 463.5245335176228,
                "y": 360.9122322045613
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06380.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574302,
                "width": 120.30407740152043,
                "x": 505.1002073255012,
                "y": 355.6046993780236
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06376.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.41603317208023,
                "width": 180.4561161022807,
                "x": 650.172771250864,
                "y": 423.7180373185903
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06553.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.18797512093994,
                "width": 239.72356599861786,
                "x": 420.17968210089856,
                "y": 355.6046993780236
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06247.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.68970283344856,
                "width": 179.5715272978577,
                "x": 238.83897719419497,
                "y": 409.5646164478232
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06194.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.53351762266766,
                "width": 92.88182446440919,
                "x": 552.8680027643402,
                "y": 347.6434001382171
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06135.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921222,
                "width": 215.8396682791984,
                "x": 415.7567380787838,
                "y": 356.48928818244656
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06134.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.2646855563234,
                "width": 176.9177608845888,
                "x": 355.6046993780236,
                "y": 382.14236351071196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06080.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863167,
                "width": 171.61022805805112,
                "x": 609.4816862474087,
                "y": 321.1057360055288
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06078.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.91776088458886,
                "width": 307.8369039391845,
                "x": 843.8977194194889,
                "y": 159.22598479612998
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06061.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 75.19004837595025,
                "width": 254.76157567380795,
                "x": 341.4512785072565,
                "y": 331.7208016586041
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06060.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.18797512093994,
                "width": 176.0331720801659,
                "x": 420.17968210089856,
                "y": 347.6434001382171
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_06022.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.9184519695923,
                "width": 136.22667588113336,
                "x": 640.4422944022117,
                "y": 311.3752591568764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05990.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.9550794747755,
                "width": 386.56530753282664,
                "x": 314.0290255701452,
                "y": 165.41810642709058
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05852.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.1098825155495,
                "width": 319.3365583966829,
                "x": 852.7436074637183,
                "y": 172.49481686247412
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05846.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.84105044920534,
                "width": 171.61022805805123,
                "x": 356.48928818244656,
                "y": 356.48928818244656
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05827.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.80442294402218,
                "width": 194.60953697304774,
                "x": 324.6440912232206,
                "y": 367.10435383552186
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05757.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.30476848652387,
                "width": 251.22322045611622,
                "x": 276.87629578438157,
                "y": 406.91085003455436
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05707.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.41810642709055,
                "width": 154.80304077401524,
                "x": 473.2550103662752,
                "y": 374.18106427090544
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05703.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.18935729094687,
                "width": 181.3407049067036,
                "x": 454.6786454733934,
                "y": 429.9101589495509
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05677.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 80.49758120248794,
                "width": 173.37940566689707,
                "x": 196.37871458189363,
                "y": 378.6040082930202
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05663.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 248.56945404284733,
                "width": 499.79267449896355,
                "x": 286.6067726330339,
                "y": 157.45680718728408
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05560.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.34277816171391,
                "width": 199.91706979958536,
                "x": 381.257774706289,
                "y": 340.56668970283357
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05510.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 88.4588804422944,
                "width": 249.45404284727033,
                "x": 390.1036627505184,
                "y": 377.7194194885972
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05482.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.64754664823778,
                "width": 413.9875604699379,
                "x": 594.4436765722186,
                "y": 41.57567380787838
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05465.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.11333794056674,
                "width": 186.64823773324122,
                "x": 161.87975120939882,
                "y": 406.0262612301314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05363.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.49550794747762,
                "width": 155.68762957843825,
                "x": 489.1776088458882,
                "y": 373.2964754664825
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05358.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 230.8776779543885,
                "width": 221.14720110573614,
                "x": 574.0981340704908,
                "y": 407.7954388389773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05281.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.3413959917071,
                "width": 155.6876295784382,
                "x": 481.2163096060817,
                "y": 367.9889426399448
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05272.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.26399447132002,
                "width": 144.18797512093988,
                "x": 429.025570145128,
                "y": 341.4512785072565
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05243.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.07118175535598,
                "width": 352.95093296475477,
                "x": 606.8279198341398,
                "y": 56.613683483068435
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05201.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.14927436074646,
                "width": 84.92052522460267,
                "x": 364.450587422253,
                "y": 366.2197650310989
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05200.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.72425708362135,
                "width": 180.4561161022807,
                "x": 652.8265376641328,
                "y": 444.94816862474096
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.6496199032482,
                "width": 161.87975120939876,
                "x": 375.0656530753284,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05103.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 335.2591568762959,
                "width": 133.57290946786463,
                "x": 921.741534208708,
                "y": 176.91776088458886
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05043.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.95922598479615,
                "width": 230.8776779543885,
                "x": 297.2218382861093,
                "y": 428.140981340705
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05031.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.99723565998625,
                "width": 201.6862474084313,
                "x": 344.98963372494825,
                "y": 390.1036627505184
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05022.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786463,
                "width": 150.3800967519005,
                "x": 625.4042847270216,
                "y": 327.29785763648937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_05017.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 219.37802349689014,
                "width": 167.1872840359365,
                "x": 665.2107809260541,
                "y": 439.64063579820333
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04827.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.88182446440914,
                "width": 181.3407049067036,
                "x": 337.0283344851418,
                "y": 400.7187284035938
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04780.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.91706979958542,
                "width": 301.64478230822397,
                "x": 866.0124395300625,
                "y": 158.34139599170703
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04737.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.72840359364204,
                "width": 168.9564616447824,
                "x": 360.02764340013834,
                "y": 413.98756046993793
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04736.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.88182446440919,
                "width": 189.30200414651011,
                "x": 331.7208016586041,
                "y": 423.7180373185903
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04729.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.53628196268141,
                "width": 186.64823773324122,
                "x": 161.87975120939882,
                "y": 398.9495507947479
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04713.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.76641326883208,
                "width": 188.4174153420871,
                "x": 436.10228058051155,
                "y": 446.71734623358685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04660.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.18590186592957,
                "width": 475.0241879751211,
                "x": 204.34001382170013,
                "y": 160.11057360055293
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04633.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.11126468555642,
                "width": 177.8023496890118,
                "x": 332.60539046302705,
                "y": 391.8728403593643
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04567.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.49619903248112,
                "width": 233.5314443676573,
                "x": 310.49067035245344,
                "y": 405.14167242570846
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04524.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.99723565998613,
                "width": 185.76364892881833,
                "x": 452.9094678645475,
                "y": 442.2944022114722
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04519.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.38078783690395,
                "width": 229.99308914996556,
                "x": 373.2964754664825,
                "y": 413.102971665515
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04490.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.68762957843825,
                "width": 118.5348997926746,
                "x": 446.71734623358685,
                "y": 364.450587422253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04433.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.10850034554255,
                "width": 172.49481686247407,
                "x": 642.2114720110576,
                "y": 434.33310297166565
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04379.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.88182446440914,
                "width": 249.45404284727027,
                "x": 299.87560469937813,
                "y": 399.83413959917084
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04350.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.80511402902556,
                "width": 191.95577055977895,
                "x": 455.5632342778163,
                "y": 462.6399447131999
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04312.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.76710435383552,
                "width": 217.6088458880443,
                "x": 281.2992398064963,
                "y": 416.6413268832068
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04303.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.88251554941257,
                "width": 189.30200414651011,
                "x": 404.2570836212855,
                "y": 379.4885970974431
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04277.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.1492743607464,
                "width": 196.37871458189363,
                "x": 396.29578438147905,
                "y": 356.48928818244656
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04243.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.22736696613691,
                "width": 218.4934346924673,
                "x": 309.6060815480305,
                "y": 388.33448514167253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.76710435383558,
                "width": 194.60953697304777,
                "x": 243.26192121630967,
                "y": 385.6807187284037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04093.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 341.4512785072565,
                "width": 127.38078783690389,
                "x": 944.7408431237045,
                "y": 173.37940566689707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04092.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 245.0310988251556,
                "width": 337.02833448514184,
                "x": 860.7049067035248,
                "y": 175.14858327574296
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04055.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.34070490670354,
                "width": 105.26606772633045,
                "x": 541.3683483068419,
                "y": 352.95093296475477
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04054.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.68693849343475,
                "width": 99.07394609536976,
                "x": 390.1036627505184,
                "y": 341.4512785072565
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04043.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.5348997926746,
                "width": 208.7629578438149,
                "x": 312.25984796129933,
                "y": 408.68002764340025
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04040.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.34208707671047,
                "width": 130.9191430545958,
                "x": 747.4775397373879,
                "y": 296.33724948168634
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04016.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.84174153420872,
                "width": 161.87975120939882,
                "x": 622.7505183137528,
                "y": 319.3365583966829
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_04011.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.3434692467174,
                "width": 226.4547339322737,
                "x": 480.3317208016588,
                "y": 390.98825155494137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03927.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.91983413959923,
                "width": 122.95784381478927,
                "x": 430.79474775397387,
                "y": 371.5272978576366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03905.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 65.4595715272979,
                "width": 182.22529371112648,
                "x": 743.9391845196961,
                "y": 276.87629578438157
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03855.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.8438147892191,
                "width": 191.9557705597789,
                "x": 436.9868693849345,
                "y": 379.4885970974431
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03758.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.53489979267454,
                "width": 158.34139599170703,
                "x": 394.52660677263316,
                "y": 393.6420179682102
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03747.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.68901174844513,
                "width": 145.07256392536294,
                "x": 622.7505183137528,
                "y": 330.83621285418116
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03714.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.84312370421571,
                "width": 174.26399447132002,
                "x": 334.37456807187294,
                "y": 429.025570145128
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03713.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.9958534899793,
                "width": 385.6807187284037,
                "x": 274.2225293711127,
                "y": 238.83897719419497
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03700.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.14927436074646,
                "width": 95.53559087767798,
                "x": 340.56668970283357,
                "y": 373.2964754664825
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03699.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.42017968210092,
                "width": 215.8396682791984,
                "x": 271.5687629578439,
                "y": 396.29578438147905
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03612.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.26675881133383,
                "width": 207.87836903939188,
                "x": 265.3766413268833,
                "y": 405.14167242570846
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03599.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.68762957843822,
                "width": 410.4492052522462,
                "x": 390.1036627505184,
                "y": 106.15065653075331
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03578.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 77.8438147892191,
                "width": 189.30200414651011,
                "x": 367.9889426399448,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03553.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.65100207325509,
                "width": 173.37940566689707,
                "x": 417.5259156876297,
                "y": 367.9889426399448
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03549.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.53213545266073,
                "width": 402.4879060124397,
                "x": 314.0290255701452,
                "y": 176.91776088458886
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03535.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.18935729094682,
                "width": 191.9557705597789,
                "x": 293.6834830684175,
                "y": 391.8728403593643
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03431.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.2280580511403,
                "width": 182.22529371112654,
                "x": 279.5300621976504,
                "y": 400.7187284035938
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03429.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.42017968210092,
                "width": 189.30200414651011,
                "x": 404.2570836212855,
                "y": 367.10435383552186
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03427.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.45611610228065,
                "width": 393.64201796821015,
                "x": 375.0656530753284,
                "y": 96.42017968210092
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03406.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.38217000691088,
                "width": 179.57152729785773,
                "x": 144.1879751209399,
                "y": 387.4498963372496
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03387.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.41948859709743,
                "width": 164.53351762266766,
                "x": 428.140981340705,
                "y": 414.8721492743609
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03382.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.30476848652387,
                "width": 204.34001382170015,
                "x": 386.56530753282664,
                "y": 415.7567380787838
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03373.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.80511402902562,
                "width": 191.95577055977895,
                "x": 325.5286800276435,
                "y": 364.450587422253
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03363.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.18866620594332,
                "width": 182.22529371112654,
                "x": 318.45196959225996,
                "y": 362.6814098134072
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03345.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.95784381478927,
                "width": 134.45749827228752,
                "x": 419.2950932964756,
                "y": 333.48997926745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03341.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.45818935729096,
                "width": 163.6489288182447,
                "x": 397.180373185902,
                "y": 354.72011057360066
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03304.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.380787836904,
                "width": 107.91983413959917,
                "x": 751.9004837595027,
                "y": 256.53075328265385
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03300.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.95853489979271,
                "width": 200.80165860400834,
                "x": 225.5701451278508,
                "y": 407.7954388389773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03286.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.53628196268141,
                "width": 193.7249481686248,
                "x": 360.9122322045613,
                "y": 392.75742916378726
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03281.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.2653766413269,
                "width": 91.1126468555633,
                "x": 750.1313061506568,
                "y": 256.53075328265385
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03213.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.2280580511403,
                "width": 201.68624740843126,
                "x": 340.56668970283357,
                "y": 383.0269523151349
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03164.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.95715272978578,
                "width": 171.61022805805123,
                "x": 617.4429854872151,
                "y": 323.75950241879764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03159.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.64892881824468,
                "width": 376.8348306841743,
                "x": 260.9536973047686,
                "y": 229.10850034554258
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03112.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.1499654457499,
                "width": 158.3413959917071,
                "x": 404.2570836212855,
                "y": 352.0663441603318
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03108.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921216,
                "width": 145.07256392536289,
                "x": 198.14789219073953,
                "y": 359.1430545957154
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03050.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 262.7228749136145,
                "width": 186.64823773324122,
                "x": 593.5590877677956,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_03039.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 361.79682100898424,
                "width": 168.95646164478228,
                "x": 915.5494125777474,
                "y": 153.9184519695923
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02938.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.07187284035945,
                "width": 99.07394609536976,
                "x": 446.71734623358685,
                "y": 355.6046993780236
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02931.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.60953697304768,
                "width": 65.45957152729787,
                "x": 119.41948859709748,
                "y": 459.98617829993105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02913.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.57360055286807,
                "width": 136.22667588113342,
                "x": 418.41050449205267,
                "y": 352.0663441603318
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02880.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.18935729094687,
                "width": 198.14789219073953,
                "x": 324.6440912232206,
                "y": 429.025570145128
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02801.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113342,
                "width": 96.42017968210092,
                "x": 336.14374568071884,
                "y": 375.95024187975133
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02784.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.53144436765734,
                "width": 237.95438838977202,
                "x": 583.8286109191432,
                "y": 406.91085003455436
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02776.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.993780234969,
                "width": 370.6427090532136,
                "x": 605.0587422252939,
                "y": 58.38286109191432
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02765.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.14996544574984,
                "width": 221.14720110573603,
                "x": 602.4049758120251,
                "y": 315.7982031789911
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02704.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.87975120939882,
                "width": 111.45818935729102,
                "x": 448.48652384243275,
                "y": 350.29716655148593
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02695.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.92052522460267,
                "width": 206.10919143054602,
                "x": 246.80027643400146,
                "y": 415.7567380787838
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02686.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.3800967519005,
                "width": 188.4174153420871,
                "x": 356.48928818244656,
                "y": 387.4498963372496
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02645.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.57429163787145,
                "width": 158.34139599170703,
                "x": 352.0663441603318,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02629.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.45818935729096,
                "width": 211.41672425708367,
                "x": 364.450587422253,
                "y": 395.4111955770561
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02609.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.61230131306155,
                "width": 229.1085003455426,
                "x": 368.87353144436776,
                "y": 337.91292328956473
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02549.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.26537664132695,
                "width": 99.07394609536982,
                "x": 811.1679336558399,
                "y": 271.5687629578439
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02499.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805118,
                "width": 76.0746371803732,
                "x": 388.33448514167253,
                "y": 368.87353144436776
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02448.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.53489979267454,
                "width": 148.61091914305467,
                "x": 482.98548721492756,
                "y": 382.14236351071196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02446.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.49481686247418,
                "width": 96.42017968210098,
                "x": 535.1762266758813,
                "y": 359.1430545957154
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02421.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.61230131306155,
                "width": 176.91776088458892,
                "x": 391.8728403593643,
                "y": 360.02764340013834
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02404.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.0338631651694,
                "width": 80.49758120248788,
                "x": 462.6399447131999,
                "y": 348.52798894264004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02352.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.38078783690406,
                "width": 258.2999308914997,
                "x": 280.41465100207336,
                "y": 404.2570836212855
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02346.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.8030407740153,
                "width": 98.18935729094682,
                "x": 341.4512785072565,
                "y": 369.7581202487907
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02296.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.65100207325506,
                "width": 76.0746371803732,
                "x": 827.0905321354529,
                "y": 244.14651002073262
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02292.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633039,
                "width": 127.380787836904,
                "x": 482.10089841050467,
                "y": 384.79612992398074
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02283.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.45818935729096,
                "width": 171.61022805805123,
                "x": 327.29785763648937,
                "y": 381.257774706289
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02276.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 72.53628196268147,
                "width": 176.0331720801659,
                "x": 306.95231513476165,
                "y": 408.68002764340025
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02254.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.91914305459574,
                "width": 193.7249481686248,
                "x": 618.327574291638,
                "y": 323.75950241879764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02203.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 309.6060815480305,
                "width": 114.99654457498264,
                "x": 954.4713199723569,
                "y": 190.18659295093303
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02189.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 80.49758120248794,
                "width": 191.071181755356,
                "x": 291.02971665514866,
                "y": 409.5646164478232
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02133.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 226.45473393227377,
                "width": 245.0310988251556,
                "x": 586.482377332412,
                "y": 410.44920525224614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02090.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863167,
                "width": 174.26399447132002,
                "x": 421.94885970974445,
                "y": 344.10504492052536
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02035.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.68901174844507,
                "width": 237.95438838977196,
                "x": 264.49205252246037,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02008.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.61091914305462,
                "width": 187.53282653766416,
                "x": 608.5970974429857,
                "y": 315.7982031789911
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_02002.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.57429163787151,
                "width": 200.80165860400837,
                "x": 391.8728403593643,
                "y": 389.2190739460955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01928.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 263.6074637180374,
                "width": 193.7249481686248,
                "x": 581.1748445058744,
                "y": 368.87353144436776
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01901.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.84174153420878,
                "width": 504.2156185210783,
                "x": 372.41188666205954,
                "y": 115.8811333794057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01875.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.68901174844513,
                "width": 209.64754664823778,
                "x": 375.95024187975133,
                "y": 410.44920525224614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01855.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574296,
                "width": 236.18521078092613,
                "x": 960.6634416033176,
                "y": 139.7650310988252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01841.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.11126468555636,
                "width": 462.63994471319984,
                "x": 389.2190739460955,
                "y": 122.95784381478926
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01806.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 350.29716655148593,
                "width": 129.14996544575,
                "x": 928.8182446440915,
                "y": 168.95646164478237
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01804.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.34416033172084,
                "width": 185.76364892881827,
                "x": 741.2854181064273,
                "y": 289.26053904630277
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01753.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53282653766416,
                "width": 279.5300621976504,
                "x": 888.127159640636,
                "y": 160.99516240497587
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01735.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.7284035936421,
                "width": 183.99447131997243,
                "x": 455.5632342778163,
                "y": 444.94816862474096
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01620.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 64.57498272287489,
                "width": 205.22460262612307,
                "x": 187.5328265376642,
                "y": 418.41050449205267
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01578.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.07118175535595,
                "width": 286.606772633034,
                "x": 909.3572909467867,
                "y": 181.3407049067036
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01570.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.18659295093303,
                "width": 361.79682100898424,
                "x": 633.3655839668281,
                "y": 19.460953697304774
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01547.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.49550794747756,
                "width": 377.7194194885973,
                "x": 820.0138217000693,
                "y": 283.95300621976514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01506.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.88182446440914,
                "width": 222.03178991015903,
                "x": 381.257774706289,
                "y": 449.3711126468557
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01482.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.34139599170703,
                "width": 131.80373185901874,
                "x": 437.87145818935744,
                "y": 342.33586731167946
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01402.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.26606772633039,
                "width": 191.071181755356,
                "x": 340.56668970283357,
                "y": 348.52798894264004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01401.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.61091914305467,
                "width": 158.34139599170703,
                "x": 611.2508638562545,
                "y": 313.1444367657223
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.92052522460261,
                "width": 222.03178991015903,
                "x": 330.83621285418116,
                "y": 419.2950932964756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01353.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.88251554941257,
                "width": 192.84035936420184,
                "x": 237.06979958534907,
                "y": 415.7567380787838
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01334.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80373185901868,
                "width": 199.03248099516242,
                "x": 375.0656530753284,
                "y": 362.6814098134072
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01330.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.22805805114035,
                "width": 225.57014512785076,
                "x": 238.83897719419497,
                "y": 405.14167242570846
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01300.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.57014512785076,
                "width": 273.3379405666898,
                "x": 561.7138908085697,
                "y": 397.180373185902
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01121.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53282653766422,
                "width": 283.95300621976503,
                "x": 942.9716655148586,
                "y": 172.49481686247412
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01111.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.88044229440226,
                "width": 88.45888044229446,
                "x": 820.8984105044923,
                "y": 256.53075328265385
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01105.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.53489979267454,
                "width": 219.3780234968902,
                "x": 380.37318590186607,
                "y": 349.412577747063
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01086.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.80304077401524,
                "width": 158.34139599170703,
                "x": 433.4485141672427,
                "y": 340.56668970283357
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01066.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.65100207325497,
                "width": 185.76364892881833,
                "x": 446.71734623358685,
                "y": 442.2944022114722
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01045.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.0345542501728,
                "width": 94.65100207325497,
                "x": 766.0539046302698,
                "y": 264.49205252246037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01038.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.7650310988252,
                "width": 93.76641326883214,
                "x": 729.785763648929,
                "y": 236.18521078092613
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_01000.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.8811333794057,
                "width": 148.61091914305456,
                "x": 422.8334485141674,
                "y": 368.87353144436776
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00956.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 354.72011057360066,
                "width": 144.18797512093977,
                "x": 922.626123013131,
                "y": 161.87975120939882
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00939.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.80511402902567,
                "width": 215.83966827919835,
                "x": 439.64063579820333,
                "y": 443.17899101589506
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00870.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.49689011748444,
                "width": 216.72425708362135,
                "x": 283.0684174153422,
                "y": 381.257774706289
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00843.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 252.10780926053914,
                "width": 258.2999308914997,
                "x": 889.011748445059,
                "y": 162.76434001382174
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00817.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 83.15134761575678,
                "width": 176.0331720801659,
                "x": 220.26261230131314,
                "y": 406.0262612301314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00811.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.61161022805805,
                "width": 93.76641326883203,
                "x": 804.0912232204564,
                "y": 282.18382861091925
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00809.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.18866620594338,
                "width": 172.49481686247412,
                "x": 452.02487906012453,
                "y": 428.140981340705
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00788.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.57014512785076,
                "width": 185.76364892881827,
                "x": 640.4422944022117,
                "y": 432.56392536281976
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00745.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.22874913614379,
                "width": 184.87906012439532,
                "x": 141.5342087076711,
                "y": 385.6807187284037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00727.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.6876295784382,
                "width": 327.2978576364893,
                "x": 842.128541810643,
                "y": 179.5715272978577
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00714.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.9564616447824,
                "width": 101.72771250863866,
                "x": 534.2916378714583,
                "y": 345.8742225293712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00712.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 58.38286109191432,
                "width": 167.18728403593647,
                "x": 246.80027643400146,
                "y": 421.94885970974445
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00638.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.03524533517628,
                "width": 93.76641326883203,
                "x": 753.6696613683486,
                "y": 275.1071181755357
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00626.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.4934346924672,
                "width": 166.30269523151355,
                "x": 658.1340704906705,
                "y": 433.4485141672427
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00605.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574296,
                "width": 111.45818935729102,
                "x": 453.7940566689704,
                "y": 328.1824464409123
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00558.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.61299239806499,
                "width": 229.1085003455426,
                "x": 301.644782308224,
                "y": 438.7560469937804
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00545.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.4181064270906,
                "width": 97.30476848652393,
                "x": 587.366966136835,
                "y": 362.6814098134072
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00523.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.53489979267454,
                "width": 82.26675881133383,
                "x": 818.2446440912234,
                "y": 285.722183828611
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00490.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152043,
                "width": 125.61161022805805,
                "x": 490.06219765031113,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00482.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.30545957152736,
                "width": 189.30200414651006,
                "x": 305.1831375259158,
                "y": 405.14167242570846
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00415.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.30269523151355,
                "width": 84.92052522460267,
                "x": 547.5604699378025,
                "y": 353.8355217691777
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00385.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.99792674498968,
                "width": 150.3800967519005,
                "x": 196.37871458189363,
                "y": 407.7954388389773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00344.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 61.92121630960611,
                "width": 168.07187284035942,
                "x": 229.10850034554258,
                "y": 418.41050449205267
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00296.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921222,
                "width": 93.76641326883203,
                "x": 806.7449896337253,
                "y": 267.14581893572915
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00274.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.34277816171391,
                "width": 199.91706979958548,
                "x": 370.64270905321365,
                "y": 383.91154111955785
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00270.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.80511402902562,
                "width": 145.07256392536289,
                "x": 137.9958534899793,
                "y": 376.8348306841743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00269.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.7636489288183,
                "width": 307.8369039391846,
                "x": 873.973738769869,
                "y": 168.95646164478237
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00239.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.72702142363516,
                "width": 99.0739460953697,
                "x": 796.1299239806499,
                "y": 268.0304077401521
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00228.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.95784381478921,
                "width": 129.14996544574984,
                "x": 500.6772633033865,
                "y": 380.37318590186607
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00191.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.72771250863855,
                "width": 240.60815480304086,
                "x": 355.6046993780236,
                "y": 324.6440912232206
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00134.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.9958534899793,
                "width": 105.26606772633033,
                "x": 517.4844505874224,
                "y": 372.41188666205954
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00043.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.2280580511403,
                "width": 168.95646164478234,
                "x": 137.11126468555636,
                "y": 379.4885970974431
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/ALB/img_00019.jpg"
    }
]

# %%
[
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.0,
                "width": 400.0,
                "x": 503.0,
                "y": 147.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07825.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 221.0,
                "width": 404.0,
                "x": 242.0,
                "y": 136.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07804.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.0,
                "width": 308.0,
                "x": 790.0,
                "y": 103.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07795.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.0,
                "width": 482.0,
                "x": 545.0,
                "y": 82.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07734.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 246.0,
                "width": 486.0,
                "x": 517.0,
                "y": 70.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07721.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 486.0,
                "width": 237.0,
                "x": 296.0,
                "y": 301.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07620.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.0,
                "width": 472.0,
                "x": 412.0,
                "y": 158.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07581.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.0,
                "width": 387.0,
                "x": 643.0,
                "y": 37.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07579.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 375.0,
                "width": 567.0,
                "x": 276.0,
                "y": 382.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07545.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.0,
                "width": 209.0,
                "x": 114.0,
                "y": 171.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07519.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.0,
                "width": 561.0,
                "x": 457.0,
                "y": 135.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07518.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 351.0,
                "x": 934.0,
                "y": 110.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07440.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.0,
                "width": 109.0,
                "x": 517.0,
                "y": 325.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07410.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 489.0,
                "width": 227.0,
                "x": 212.0,
                "y": 283.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07378.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.0,
                "width": 313.0,
                "x": 367.0,
                "y": 402.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07321.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.0,
                "width": 457.0,
                "x": 586.0,
                "y": 81.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07311.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 360.0,
                "width": 286.0,
                "x": 813.0,
                "y": 214.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07164.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.0,
                "width": 166.0,
                "x": 175.0,
                "y": 258.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07059.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 504.0,
                "width": 254.0,
                "x": 200.0,
                "y": 145.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07015.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.0,
                "width": 428.0,
                "x": 472.0,
                "y": 121.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_07007.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.0,
                "width": 116.0,
                "x": 515.0,
                "y": 342.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06997.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.0,
                "width": 234.0,
                "x": 563.0,
                "y": 440.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06983.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 88.0,
                "width": 250.0,
                "x": 379.0,
                "y": 434.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06867.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0,
                "width": 462.0,
                "x": 640.0,
                "y": 385.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06862.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.0,
                "width": 429.0,
                "x": 491.0,
                "y": 148.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06827.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 339.0,
                "width": 271.0,
                "x": 763.0,
                "y": 103.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06825.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 248.0,
                "width": 595.0,
                "x": 479.0,
                "y": 15.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06777.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 271.0,
                "width": 360.0,
                "x": 427.0,
                "y": 423.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06776.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 325.0,
                "width": 355.0,
                "x": 765.0,
                "y": 231.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06772.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.0,
                "width": 361.0,
                "x": 794.0,
                "y": 265.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06636.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.0,
                "width": 223.0,
                "x": 324.0,
                "y": 380.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06623.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.0,
                "width": 316.0,
                "x": 740.0,
                "y": 75.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06613.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.0,
                "width": 435.0,
                "x": 402.0,
                "y": 231.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06575.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.0,
                "width": 407.0,
                "x": 629.0,
                "y": 152.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06542.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.0,
                "width": 228.0,
                "x": 311.0,
                "y": 407.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06532.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 247.0,
                "width": 216.0,
                "x": 92.0,
                "y": 175.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06453.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 329.0,
                "width": 228.0,
                "x": 808.0,
                "y": 272.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06384.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.0,
                "width": 94.0,
                "x": 607.0,
                "y": 355.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06287.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.0,
                "width": 435.0,
                "x": 536.0,
                "y": 158.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06277.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.0,
                "width": 147.0,
                "x": 382.0,
                "y": 381.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_06035.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 492.0,
                "width": 221.0,
                "x": 229.0,
                "y": 226.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05986.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.0,
                "width": 364.0,
                "x": 269.0,
                "y": 124.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05974.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.0,
                "width": 337.0,
                "x": 803.0,
                "y": 145.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05874.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 266.0,
                "width": 360.0,
                "x": 438.0,
                "y": 433.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05858.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 391.0,
                "width": 262.0,
                "x": 807.0,
                "y": 209.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05848.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 381.0,
                "width": 262.0,
                "x": 812.0,
                "y": 194.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05841.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.0,
                "width": 122.0,
                "x": 515.0,
                "y": 322.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05797.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.0,
                "width": 156.0,
                "x": 277.0,
                "y": 72.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05796.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.0,
                "width": 177.0,
                "x": 252.0,
                "y": 86.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05784.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 337.0,
                "width": 263.0,
                "x": 807.0,
                "y": 229.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05748.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.0,
                "width": 371.0,
                "x": 710.0,
                "y": 103.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05736.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.0,
                "width": 412.0,
                "x": 487.0,
                "y": 247.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05728.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 287.0,
                "width": 371.0,
                "x": 605.0,
                "y": 489.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05658.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.0,
                "width": 370.0,
                "x": 466.0,
                "y": 442.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05616.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.0,
                "width": 451.0,
                "x": 473.0,
                "y": 144.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05561.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.0,
                "width": 105.0,
                "x": 874.0,
                "y": 320.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05450.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.0,
                "width": 336.0,
                "x": 267.0,
                "y": 150.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05431.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.0,
                "width": 429.0,
                "x": 561.0,
                "y": 66.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05402.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.0,
                "width": 223.0,
                "x": -1.0,
                "y": 272.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05369.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.0,
                "width": 607.0,
                "x": 383.0,
                "y": 180.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05351.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.0,
                "width": 273.0,
                "x": 507.0,
                "y": 384.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05346.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.0,
                "width": 295.0,
                "x": 287.0,
                "y": 404.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05344.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 359.0,
                "width": 282.0,
                "x": 795.0,
                "y": 209.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05314.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 263.0,
                "width": 642.0,
                "x": 443.0,
                "y": 8.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05262.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.0,
                "width": 215.0,
                "x": 326.0,
                "y": 373.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05255.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 497.0,
                "width": 206.0,
                "x": 213.0,
                "y": 198.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05252.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 337.0,
                "width": 326.0,
                "x": 790.0,
                "y": 222.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05240.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 291.0,
                "width": 457.0,
                "x": 396.0,
                "y": 578.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05194.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 269.0,
                "width": 421.0,
                "x": 599.0,
                "y": 104.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05164.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.0,
                "width": 372.0,
                "x": 267.0,
                "y": 156.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05110.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.0,
                "width": 406.0,
                "x": 579.0,
                "y": 100.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05069.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.0,
                "width": 479.0,
                "x": 581.0,
                "y": 94.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_05065.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.0,
                "width": 109.0,
                "x": 307.0,
                "y": 47.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04989.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.0,
                "width": 119.0,
                "x": 506.0,
                "y": 326.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04972.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.0,
                "width": 420.0,
                "x": 583.0,
                "y": 87.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04938.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 258.0,
                "width": 225.0,
                "x": 102.0,
                "y": 168.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04931.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0,
                "width": 316.0,
                "x": 754.0,
                "y": 68.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04914.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.0,
                "width": 211.0,
                "x": 413.0,
                "y": 422.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04891.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.0,
                "width": 245.0,
                "x": 308.0,
                "y": 390.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04853.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.0,
                "width": 388.0,
                "x": 721.0,
                "y": 85.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04815.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.0,
                "width": 346.0,
                "x": 773.0,
                "y": 148.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04744.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 114.0,
                "x": 523.0,
                "y": 343.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04732.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 528.0,
                "width": 281.0,
                "x": 255.0,
                "y": 290.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04718.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.0,
                "width": 342.0,
                "x": 341.0,
                "y": 365.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04672.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.0,
                "width": 325.0,
                "x": 543.0,
                "y": 450.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04670.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 243.0,
                "width": 420.0,
                "x": 164.0,
                "y": 182.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04619.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.0,
                "width": 326.0,
                "x": 499.0,
                "y": 236.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04568.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.0,
                "width": 440.0,
                "x": 355.0,
                "y": 281.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04557.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.0,
                "width": 187.0,
                "x": 368.0,
                "y": 381.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04464.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.0,
                "width": 246.0,
                "x": 569.0,
                "y": 451.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04463.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 353.0,
                "width": 274.0,
                "x": 806.0,
                "y": 219.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04327.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.0,
                "width": 379.0,
                "x": 254.0,
                "y": 135.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04304.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 510.0,
                "width": 282.0,
                "x": 237.0,
                "y": 259.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04289.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 273.0,
                "width": 482.0,
                "x": 569.0,
                "y": 610.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04227.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 347.0,
                "width": 438.0,
                "x": 590.0,
                "y": 482.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04185.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 221.0,
                "width": 401.0,
                "x": 585.0,
                "y": 50.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04179.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.0,
                "width": 429.0,
                "x": 193.0,
                "y": 203.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04158.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 238.0,
                "width": 426.0,
                "x": 244.0,
                "y": 131.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04048.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.0,
                "width": 269.0,
                "x": 358.0,
                "y": 393.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04042.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 268.0,
                "width": 403.0,
                "x": 681.0,
                "y": 68.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04039.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.0,
                "width": 393.0,
                "x": 476.0,
                "y": 226.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04033.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 285.0,
                "width": 369.0,
                "x": 306.0,
                "y": 374.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04028.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 252.0,
                "width": 411.0,
                "x": 699.0,
                "y": 78.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_04022.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.0,
                "width": 521.0,
                "x": 409.0,
                "y": 146.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03918.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 230.0,
                "width": 184.0,
                "x": 490.0,
                "y": 381.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03881.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.0,
                "width": 418.0,
                "x": 427.0,
                "y": 159.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03846.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 314.0,
                "width": 363.0,
                "x": 594.0,
                "y": 491.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03833.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 268.0,
                "width": 387.0,
                "x": 355.0,
                "y": 410.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03817.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.0,
                "width": 264.0,
                "x": 829.0,
                "y": 110.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03813.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 353.0,
                "width": 289.0,
                "x": 793.0,
                "y": 217.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03759.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.0,
                "width": 135.0,
                "x": 502.0,
                "y": 309.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03723.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.0,
                "width": 415.0,
                "x": 631.0,
                "y": 84.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03708.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.0,
                "width": 224.0,
                "x": 353.0,
                "y": 362.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03647.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.0,
                "width": 236.0,
                "x": 459.0,
                "y": 377.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03565.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.0,
                "width": 156.0,
                "x": 492.0,
                "y": 312.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03453.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.0,
                "width": 139.0,
                "x": 510.0,
                "y": 316.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03371.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.0,
                "width": 449.0,
                "x": 612.0,
                "y": 137.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03366.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.0,
                "width": 506.0,
                "x": 373.0,
                "y": 228.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03347.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 343.0,
                "width": 593.0,
                "x": 466.0,
                "y": 408.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03315.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.0,
                "width": 355.0,
                "x": 505.0,
                "y": 443.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03287.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.0,
                "width": 527.0,
                "x": 253.0,
                "y": 205.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03184.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.0,
                "width": 373.0,
                "x": 487.0,
                "y": 225.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_03051.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.0,
                "width": 456.0,
                "x": 558.0,
                "y": 314.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02981.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.0,
                "width": 402.0,
                "x": 661.0,
                "y": 13.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02969.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.0,
                "width": 416.0,
                "x": 583.0,
                "y": 85.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02967.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 235.0,
                "width": 386.0,
                "x": 245.0,
                "y": 130.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02840.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 376.0,
                "width": 294.0,
                "x": 806.0,
                "y": 213.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02818.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 511.0,
                "width": 232.0,
                "x": 226.0,
                "y": 223.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02757.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.0,
                "width": 374.0,
                "x": 805.0,
                "y": 256.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02742.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 251.0,
                "width": 545.0,
                "x": 457.0,
                "y": 139.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02736.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 230.0,
                "width": 555.0,
                "x": 426.0,
                "y": 155.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02696.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.0,
                "width": 239.0,
                "x": 290.0,
                "y": 405.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02647.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.0,
                "width": 156.0,
                "x": 168.0,
                "y": 240.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02554.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 402.0,
                "x": 486.0,
                "y": 235.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02553.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.0,
                "width": 390.0,
                "x": 486.0,
                "y": 132.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02498.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.0,
                "width": 439.0,
                "x": 465.0,
                "y": 126.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02358.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.0,
                "width": 507.0,
                "x": 207.0,
                "y": 200.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02343.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.0,
                "width": 352.0,
                "x": 254.0,
                "y": 141.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02206.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 282.0,
                "width": 606.0,
                "x": 423.0,
                "y": 7.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02196.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 369.0,
                "width": 238.0,
                "x": 270.0,
                "y": 385.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02195.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.0,
                "width": 159.0,
                "x": 508.0,
                "y": 364.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02168.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.0,
                "width": 407.0,
                "x": 489.0,
                "y": 116.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02139.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.0,
                "width": 258.0,
                "x": 551.0,
                "y": 393.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02138.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.0,
                "width": 254.0,
                "x": 232.0,
                "y": 397.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02128.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 373.0,
                "width": 279.0,
                "x": 756.0,
                "y": 74.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02115.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 226.0,
                "width": 499.0,
                "x": 221.0,
                "y": 194.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02103.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 284.0,
                "width": 410.0,
                "x": 346.0,
                "y": 283.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02097.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.0,
                "width": 125.0,
                "x": 512.0,
                "y": 331.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02016.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.0,
                "width": 395.0,
                "x": 608.0,
                "y": 85.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_02007.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 232.0,
                "width": 159.0,
                "x": 520.0,
                "y": 376.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01943.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 340.0,
                "width": 268.0,
                "x": 785.0,
                "y": 232.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01933.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 219.0,
                "width": 497.0,
                "x": 489.0,
                "y": 231.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01915.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.0,
                "width": 419.0,
                "x": 481.0,
                "y": 139.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01912.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.0,
                "width": 446.0,
                "x": 66.0,
                "y": 320.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01905.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 342.0,
                "width": 246.0,
                "x": 790.0,
                "y": 234.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01725.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 313.0,
                "width": 415.0,
                "x": 597.0,
                "y": 502.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01707.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.0,
                "width": 386.0,
                "x": 745.0,
                "y": 164.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01696.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 253.0,
                "width": 136.0,
                "x": 166.0,
                "y": 253.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01668.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.0,
                "width": 301.0,
                "x": 484.0,
                "y": 430.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01481.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.0,
                "width": 238.0,
                "x": 335.0,
                "y": 354.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01477.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 318.0,
                "width": 346.0,
                "x": 613.0,
                "y": 478.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01450.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 490.0,
                "width": 268.0,
                "x": 249.0,
                "y": 331.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01440.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.0,
                "width": 368.0,
                "x": 703.0,
                "y": 55.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01351.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 335.0,
                "width": 287.0,
                "x": 805.0,
                "y": 218.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01350.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 479.0,
                "width": 253.0,
                "x": 201.0,
                "y": 170.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01343.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.0,
                "width": 438.0,
                "x": 191.0,
                "y": 324.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01299.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.0,
                "width": 212.0,
                "x": 333.0,
                "y": 383.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01264.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.0,
                "width": 421.0,
                "x": 571.0,
                "y": 79.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01234.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.0,
                "width": 384.0,
                "x": 251.0,
                "y": 156.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01218.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 126.0,
                "width": 308.0,
                "x": 780.0,
                "y": 87.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01215.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.0,
                "width": 387.0,
                "x": 495.0,
                "y": 155.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01194.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 443.0,
                "width": 349.0,
                "x": 213.0,
                "y": 391.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01166.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 287.0,
                "width": 226.0,
                "x": 545.0,
                "y": 3.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01118.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 475.0,
                "width": 315.0,
                "x": 130.0,
                "y": 226.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01003.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.0,
                "width": 427.0,
                "x": 640.0,
                "y": 65.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_01002.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 437.0,
                "width": 256.0,
                "x": 164.0,
                "y": 240.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00923.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.0,
                "width": 169.0,
                "x": 173.0,
                "y": 237.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00888.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.0,
                "width": 258.0,
                "x": 208.0,
                "y": 385.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00883.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 459.0,
                "width": 268.0,
                "x": 275.0,
                "y": 363.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00774.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.0,
                "width": 200.0,
                "x": 225.0,
                "y": 107.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00771.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 379.0,
                "width": 196.0,
                "x": 281.0,
                "y": 370.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00732.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 220.0,
                "width": 215.0,
                "x": 85.0,
                "y": 180.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00630.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 306.0,
                "width": 445.0,
                "x": 332.0,
                "y": 559.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00601.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 497.0,
                "width": 255.0,
                "x": 178.0,
                "y": 224.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00583.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.0,
                "width": 361.0,
                "x": 172.0,
                "y": 196.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00542.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 260.0,
                "width": 442.0,
                "x": 690.0,
                "y": 82.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00537.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 315.0,
                "width": 375.0,
                "x": 599.0,
                "y": 491.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00531.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 266.0,
                "width": 491.0,
                "x": 660.0,
                "y": 84.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00491.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 302.0,
                "width": 452.0,
                "x": 316.0,
                "y": 281.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00443.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 276.0,
                "width": 394.0,
                "x": 543.0,
                "y": 477.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00441.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.0,
                "width": 330.0,
                "x": 820.0,
                "y": 271.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00435.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.0,
                "width": 67.0,
                "x": 890.0,
                "y": 318.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00379.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 243.0,
                "width": 347.0,
                "x": 273.0,
                "y": 129.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00363.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.0,
                "width": 143.0,
                "x": 286.0,
                "y": 66.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00329.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 196.0,
                "width": 216.0,
                "x": -1.0,
                "y": 282.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00321.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 238.0,
                "width": 584.0,
                "x": 369.0,
                "y": 155.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00259.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 458.0,
                "width": 317.0,
                "x": 255.0,
                "y": 385.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00231.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 468.0,
                "x": 558.0,
                "y": 78.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00225.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.0,
                "width": 218.0,
                "x": 107.0,
                "y": 159.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00158.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 321.0,
                "width": 290.0,
                "x": 806.0,
                "y": 232.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/BET/img_00107.jpg"
    }
]

# %%
[
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.0,
                "width": 145.0,
                "x": 685.0,
                "y": 270.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00165.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.0,
                "width": 248.0,
                "x": 400.0,
                "y": 402.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00325.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.0,
                "width": 349.0,
                "x": 160.0,
                "y": 330.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00348.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.0,
                "width": 161.0,
                "x": 283.0,
                "y": 279.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00352.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.0,
                "width": 228.0,
                "x": 324.0,
                "y": 371.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00565.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.0,
                "width": 195.0,
                "x": 450.0,
                "y": 569.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00644.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.0,
                "width": 240.0,
                "x": 288.0,
                "y": 414.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00678.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.0,
                "width": 266.0,
                "x": 222.0,
                "y": 279.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00689.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.0,
                "width": 247.0,
                "x": 346.0,
                "y": 414.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00733.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 56.0,
                "width": 214.0,
                "x": 415.0,
                "y": 433.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00734.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 54.0,
                "width": 146.0,
                "x": 246.0,
                "y": 443.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00770.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.0,
                "width": 348.0,
                "x": 214.0,
                "y": 305.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00918.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.0,
                "width": 129.0,
                "x": 411.0,
                "y": 421.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00951.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.0,
                "width": 272.0,
                "x": 160.0,
                "y": 318.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_00983.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.0,
                "width": 234.0,
                "x": 302.0,
                "y": 401.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01042.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 220.0,
                "width": 264.0,
                "x": 435.0,
                "y": 382.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01055.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.0,
                "width": 146.0,
                "x": 329.0,
                "y": 304.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01153.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.0,
                "width": 252.0,
                "x": 325.0,
                "y": 411.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01185.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.0,
                "width": 252.0,
                "x": 371.0,
                "y": 419.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01232.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.0,
                "width": 108.0,
                "x": 696.0,
                "y": 287.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01311.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.0,
                "width": 217.0,
                "x": 463.0,
                "y": 429.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01360.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.0,
                "width": 495.0,
                "x": 489.0,
                "y": 539.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01397.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 261.0,
                "width": 140.0,
                "x": 818.0,
                "y": 601.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01470.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.0,
                "width": 196.0,
                "x": 591.0,
                "y": 490.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01471.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.0,
                "width": 236.0,
                "x": 434.0,
                "y": 563.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01474.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.0,
                "width": 376.0,
                "x": 240.0,
                "y": 279.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01531.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.0,
                "width": 237.0,
                "x": 460.0,
                "y": 434.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01596.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.0,
                "width": 240.0,
                "x": 387.0,
                "y": 420.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01608.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.0,
                "width": 186.0,
                "x": 256.0,
                "y": 278.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01615.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.0,
                "width": 213.0,
                "x": 430.0,
                "y": 541.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01628.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.0,
                "width": 114.0,
                "x": 699.0,
                "y": 277.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01757.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.0,
                "width": 308.0,
                "x": 204.0,
                "y": 343.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01776.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.0,
                "width": 86.0,
                "x": 717.0,
                "y": 271.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01812.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.0,
                "width": 329.0,
                "x": 245.0,
                "y": 275.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01844.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.0,
                "width": 416.0,
                "x": 153.0,
                "y": 317.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_01850.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.0,
                "width": 140.0,
                "x": 704.0,
                "y": 274.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02100.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.0,
                "width": 251.0,
                "x": 353.0,
                "y": 418.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02210.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.0,
                "width": 219.0,
                "x": 397.0,
                "y": 413.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02267.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.0,
                "width": 272.0,
                "x": 528.0,
                "y": 437.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02333.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.0,
                "width": 224.0,
                "x": 235.0,
                "y": 304.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02341.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.0,
                "width": 382.0,
                "x": 182.0,
                "y": 298.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02378.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.0,
                "width": 252.0,
                "x": 457.0,
                "y": 435.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02432.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.0,
                "width": 129.0,
                "x": 209.0,
                "y": 369.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02440.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.0,
                "width": 326.0,
                "x": 141.0,
                "y": 312.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02474.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.0,
                "width": 296.0,
                "x": 376.0,
                "y": 459.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02475.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 246.0,
                "width": 169.0,
                "x": 365.0,
                "y": 299.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02529.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.0,
                "width": 313.0,
                "x": 413.0,
                "y": 411.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02599.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.0,
                "width": 156.0,
                "x": 785.0,
                "y": 756.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02654.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.0,
                "width": 282.0,
                "x": 307.0,
                "y": 413.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02752.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.0,
                "width": 359.0,
                "x": 142.0,
                "y": 312.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02772.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.0,
                "width": 179.0,
                "x": 473.0,
                "y": 575.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02798.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.0,
                "width": 316.0,
                "x": 208.0,
                "y": 297.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02910.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 69.0,
                "width": 233.0,
                "x": 399.0,
                "y": 425.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02926.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.0,
                "width": 267.0,
                "x": 158.0,
                "y": 331.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02936.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.0,
                "width": 156.0,
                "x": 370.0,
                "y": 290.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02937.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.0,
                "width": 296.0,
                "x": 146.0,
                "y": 345.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_02953.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.0,
                "width": 294.0,
                "x": 201.0,
                "y": 336.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03259.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.0,
                "width": 227.0,
                "x": 361.0,
                "y": 418.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03296.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 220.0,
                "width": 163.0,
                "x": 359.0,
                "y": 308.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03409.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.0,
                "width": 258.0,
                "x": 295.0,
                "y": 401.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03546.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.0,
                "width": 169.0,
                "x": 388.0,
                "y": 310.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03689.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.0,
                "width": 253.0,
                "x": 371.0,
                "y": 417.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03727.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 235.0,
                "width": 205.0,
                "x": 439.0,
                "y": 388.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03843.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.0,
                "width": 230.0,
                "x": 395.0,
                "y": 423.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03922.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.0,
                "width": 240.0,
                "x": 248.0,
                "y": 440.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_03997.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.0,
                "width": 452.0,
                "x": 193.0,
                "y": 357.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04283.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.0,
                "width": 139.0,
                "x": 402.0,
                "y": 407.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04314.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.0,
                "width": 181.0,
                "x": 335.0,
                "y": 411.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04363.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.0,
                "width": 492.0,
                "x": 205.0,
                "y": 343.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04385.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.0,
                "width": 263.0,
                "x": 379.0,
                "y": 399.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04614.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.0,
                "width": 253.0,
                "x": 551.0,
                "y": 468.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04676.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.0,
                "width": 237.0,
                "x": 463.0,
                "y": 436.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04743.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.0,
                "width": 253.0,
                "x": 246.0,
                "y": 442.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04760.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 232.0,
                "width": 93.0,
                "x": 716.0,
                "y": 241.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04824.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.0,
                "width": 181.0,
                "x": 279.0,
                "y": 264.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_04927.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.0,
                "width": 239.0,
                "x": 400.0,
                "y": 405.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05054.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.0,
                "width": 242.0,
                "x": 187.0,
                "y": 336.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05165.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.0,
                "width": 228.0,
                "x": 332.0,
                "y": 397.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05294.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.0,
                "width": 136.0,
                "x": 703.0,
                "y": 268.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05367.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.0,
                "width": 194.0,
                "x": 579.0,
                "y": 480.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05420.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.0,
                "width": 82.0,
                "x": 773.0,
                "y": 238.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05444.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 251.0,
                "width": 498.0,
                "x": 458.0,
                "y": 576.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05446.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.0,
                "width": 308.0,
                "x": 279.0,
                "y": 404.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05462.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.0,
                "width": 253.0,
                "x": 394.0,
                "y": 421.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05485.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.0,
                "width": 436.0,
                "x": 222.0,
                "y": 295.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05521.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.0,
                "width": 150.0,
                "x": 701.0,
                "y": 273.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05557.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.0,
                "width": 311.0,
                "x": 410.0,
                "y": 381.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05571.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.0,
                "width": 252.0,
                "x": 366.0,
                "y": 401.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05635.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.0,
                "width": 254.0,
                "x": 368.0,
                "y": 406.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05782.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.0,
                "width": 388.0,
                "x": 222.0,
                "y": 285.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05894.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.0,
                "width": 242.0,
                "x": 311.0,
                "y": 408.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05923.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 251.0,
                "width": 137.0,
                "x": 692.0,
                "y": 226.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05934.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.0,
                "width": 239.0,
                "x": 382.0,
                "y": 401.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_05971.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.0,
                "width": 355.0,
                "x": 186.0,
                "y": 343.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06012.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.0,
                "width": 136.0,
                "x": 706.0,
                "y": 257.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06117.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.0,
                "width": 101.0,
                "x": 706.0,
                "y": 231.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06204.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.0,
                "width": 208.0,
                "x": 336.0,
                "y": 408.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06209.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.0,
                "width": 261.0,
                "x": 287.0,
                "y": 406.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06244.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.0,
                "width": 392.0,
                "x": 198.0,
                "y": 339.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06284.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.0,
                "width": 267.0,
                "x": 370.0,
                "y": 406.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06297.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 220.0,
                "x": 436.0,
                "y": 533.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06299.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.0,
                "width": 182.0,
                "x": 415.0,
                "y": 378.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06334.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.0,
                "width": 254.0,
                "x": 292.0,
                "y": 419.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06442.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.0,
                "width": 300.0,
                "x": 364.0,
                "y": 400.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06579.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.0,
                "width": 273.0,
                "x": 346.0,
                "y": 413.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06644.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.0,
                "width": 266.0,
                "x": 373.0,
                "y": 409.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06671.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.0,
                "width": 264.0,
                "x": 372.0,
                "y": 408.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06768.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.0,
                "width": 296.0,
                "x": 547.0,
                "y": 456.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06773.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.0,
                "width": 254.0,
                "x": 330.0,
                "y": 404.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_06952.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.0,
                "width": 370.0,
                "x": 396.0,
                "y": 186.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07212.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.0,
                "width": 681.0,
                "x": 509.0,
                "y": 664.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07265.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.0,
                "width": 228.0,
                "x": 213.0,
                "y": 264.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07302.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 80.0,
                "width": 256.0,
                "x": 244.0,
                "y": 434.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07557.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.0,
                "width": 107.0,
                "x": 698.0,
                "y": 282.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07643.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.0,
                "width": 232.0,
                "x": 409.0,
                "y": 417.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07693.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.0,
                "width": 331.0,
                "x": 412.0,
                "y": 402.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07728.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.0,
                "width": 267.0,
                "x": 370.0,
                "y": 412.0
            }
        ],
        "class": "image",
        "filename": "../../../train/train/DOL/img_07898.jpg"
    }
]

# %%
[
    {
        "annotations": [
            {
                "class": "rect",
                "height": 376.41664415910196,
                "width": 492.7851966120736,
                "x": 569.96842017782,
                "y": 129.4303287487133
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07919.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.8030918446422,
                "width": 244.6114469929811,
                "x": 643.5893411174551,
                "y": 328.9192758109503
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07830.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.993684035564,
                "width": 144.86697346186247,
                "x": 911.949472284512,
                "y": 309.92032847168963
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07817.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 398.97789412447395,
                "width": 463.0993413944788,
                "x": 499.9098018642963,
                "y": 119.93085507908296
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07774.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.98947339260667,
                "width": 219.67532861020152,
                "x": 656.6511174131967,
                "y": 315.8574995152086
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07334.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 378.7915125765096,
                "width": 423.9140125072536,
                "x": 579.4678938474503,
                "y": 147.24184187927017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07269.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 393.04072308095505,
                "width": 436.97578880299534,
                "x": 568.7809859691163,
                "y": 143.6795392531588
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07176.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 370.479473115583,
                "width": 417.9768414637347,
                "x": 564.0312491343011,
                "y": 142.492105044455
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07142.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 366.91717048947163,
                "width": 369.29203890687927,
                "x": 650.7139463696778,
                "y": 128.2428945400095
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07087.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 395.4155914983626,
                "width": 463.09934139447887,
                "x": 514.1590123687417,
                "y": 123.49315770519433
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_07010.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.5538813401967,
                "width": 179.3025655142726,
                "x": 670.9003279176422,
                "y": 339.6061836892844
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_06876.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 325.3569731848389,
                "width": 357.41769681984124,
                "x": 659.0259858306044,
                "y": 167.42822342723463
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_06713.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 389.4784204548437,
                "width": 452.4124335161447,
                "x": 510.5967097426304,
                "y": 118.74342087037917
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_06536.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.70031688546857,
                "width": 128.76615864393148,
                "x": 827.926160655903,
                "y": 335.4962024043058
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_06257.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 384.79612992398063,
                "width": 418.4105044920525,
                "x": 582.9440221147202,
                "y": 142.418797512094
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_06224.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 372.4118866620595,
                "width": 420.1796821008985,
                "x": 572.3289564616448,
                "y": 149.49550794747753
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_06223.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.45749827228752,
                "width": 195.49412577747057,
                "x": 693.5176226675882,
                "y": 298.99101589495507
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_06129.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 408.6800276434002,
                "width": 475.90877677954387,
                "x": 492.71596406357986,
                "y": 107.91983413959917
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05966.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 318.45196959225984,
                "x": 523.676572218383,
                "y": 316.682791983414
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05945.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.9557705597789,
                "width": 188.417415342087,
                "x": 810.2833448514168,
                "y": 269.79958534899794
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05939.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.61022805805112,
                "width": 217.60884588804424,
                "x": 659.9032480995163,
                "y": 327.2978576364893
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05449.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 411.333794056669,
                "width": 382.1423635107118,
                "x": 705.0172771250865,
                "y": 51.306150656530754
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05386.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.22598479612992,
                "width": 196.37871458189363,
                "x": 826.2059433310297,
                "y": 293.68348306841744
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05123.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 382.1423635107119,
                "width": 419.29509329647544,
                "x": 582.0594333102972,
                "y": 133.57290946786455
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05081.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 344.98963372494825,
                "width": 439.6406357982031,
                "x": 624.5196959225985,
                "y": 150.38009675190048
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_05005.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.4561161022806,
                "width": 170.72563925362817,
                "x": 681.1333794056669,
                "y": 319.3365583966828
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04958.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 412.2183828610919,
                "width": 406.02626123013135,
                "x": 682.0179682100899,
                "y": 50.421561852107814
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04953.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 384.7961299239807,
                "width": 462.6399447131997,
                "x": 503.33102971665517,
                "y": 127.38078783690395
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04741.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 411.33379405666903,
                "width": 415.75673807878377,
                "x": 689.0946786454734,
                "y": 45.998617829993094
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04734.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.14996544574979,
                "width": 156.57221838286102,
                "x": 733.3241188666207,
                "y": 298.1064270905322
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04711.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 392.75742916378715,
                "width": 477.6779543883898,
                "x": 500.6772633033863,
                "y": 118.53489979267451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04678.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286114,
                "width": 220.26261230131308,
                "x": 683.7871458189358,
                "y": 281.2992398064962
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04481.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152037,
                "width": 185.76364892881816,
                "x": 738.6316516931583,
                "y": 275.1071181755356
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04435.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 418.4105044920526,
                "width": 456.44782308223915,
                "x": 496.25431928127165,
                "y": 98.18935729094679
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04414.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.95646164478234,
                "width": 219.37802349689014,
                "x": 655.4803040774016,
                "y": 325.5286800276434
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04352.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 411.33379405666903,
                "width": 455.56323427781615,
                "x": 513.9460953697305,
                "y": 105.26606772633035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04297.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 404.2570836212854,
                "width": 380.3731859018659,
                "x": 596.2128541810644,
                "y": 126.496199032481
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04279.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.49550794747756,
                "width": 263.60746371803737,
                "x": 509.5231513476158,
                "y": 319.3365583966828
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_04199.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.91706979958536,
                "width": 309.6060815480304,
                "x": 615.6738078783691,
                "y": 310.4906703524534
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_03940.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.95646164478234,
                "width": 191.9557705597789,
                "x": 713.8631651693158,
                "y": 282.18382861091914
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_03774.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 355.6046993780235,
                "width": 445.83275742916396,
                "x": 602.4049758120249,
                "y": 150.38009675190048
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_03771.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 431.67933655839676,
                "width": 474.13959917069803,
                "x": 520.1382170006912,
                "y": 91.11264685556324
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_03611.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.22598479612992,
                "width": 160.99516240497587,
                "x": 817.3600552868003,
                "y": 297.22183828610923
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_03232.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 382.1423635107119,
                "width": 443.178991015895,
                "x": 574.9827228749136,
                "y": 138.88044229440223
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_03052.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 414.8721492743608,
                "width": 489.177608845888,
                "x": 514.8306841741535,
                "y": 108.80442294402212
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02758.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.76503109882515,
                "width": 176.9177608845888,
                "x": 705.0172771250865,
                "y": 294.5680718728404
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02728.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 398.9495507947478,
                "width": 449.37111264685564,
                "x": 503.33102971665517,
                "y": 34.49896337249482
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02694.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 368.8735314443677,
                "width": 394.52660677263316,
                "x": 635.1347615756738,
                "y": 132.6883206634416
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02608.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.2653766413269,
                "width": 209.64754664823772,
                "x": 430.79474775397375,
                "y": 375.9502418797512
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02533.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.99516240497582,
                "width": 189.30200414651006,
                "x": 673.1720801658604,
                "y": 337.9129232895646
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02415.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.49550794747756,
                "width": 158.34139599170692,
                "x": 729.7857636489289,
                "y": 291.91430545957155
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02349.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.68762957843813,
                "width": 218.4934346924672,
                "x": 674.9412577747063,
                "y": 279.53006219765035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02236.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.10988251554937,
                "width": 184.87906012439532,
                "x": 806.744989633725,
                "y": 279.53006219765035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02186.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.4968901174845,
                "width": 209.64754664823778,
                "x": 422.8334485141673,
                "y": 390.1036627505183
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02089.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 424.6026261230131,
                "width": 406.9108500345543,
                "x": 680.248790601244,
                "y": 41.575673807878374
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_02042.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.18728403593644,
                "width": 199.03248099516236,
                "x": 661.6724257083622,
                "y": 337.02833448514167
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01952.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 416.6413268832067,
                "width": 475.90877677954387,
                "x": 497.1389080856946,
                "y": 102.61230131306151
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01766.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.10988251554943,
                "width": 210.53213545266067,
                "x": 660.7878369039393,
                "y": 317.5673807878369
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01644.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.11057360055287,
                "width": 229.10850034554244,
                "x": 666.9799585348999,
                "y": 273.3379405666897
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01527.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 394.52660677263304,
                "width": 470.60124395300636,
                "x": 561.7138908085694,
                "y": 135.34208707671044
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01512.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 408.68002764340014,
                "width": 427.25639253628196,
                "x": 668.7491361437458,
                "y": 57.49827228749137
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01457.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 398.9495507947478,
                "width": 465.29371112646857,
                "x": 518.3690393918453,
                "y": 118.53489979267451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01221.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 214.95507947477552,
                "x": 671.4029025570145,
                "y": 286.60677263303387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_01037.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 398.9495507947477,
                "width": 422.83344851416734,
                "x": 567.9060124395301,
                "y": 128.2653766413269
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_00784.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.1485832757429,
                "width": 210.53213545266078,
                "x": 818.2446440912232,
                "y": 278.6454733932274
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_00657.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113336,
                "width": 224.68555632342782,
                "x": 670.5183137525916,
                "y": 296.3372494816863
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_00176.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 421.06427090532134,
                "width": 475.0241879751209,
                "x": 498.02349689011754,
                "y": 109.68901174844507
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/LAG/img_00091.jpg"
    }
]

# %%
[
    {
        "annotations": [
            {
                "class": "rect",
                "height": 282.0,
                "width": 117.0,
                "x": 747.0,
                "y": 253.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07923.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.0,
                "width": 257.0,
                "x": 352.0,
                "y": 419.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07922.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.0,
                "width": 523.0,
                "x": 512.0,
                "y": 182.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07916.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 544.0,
                "x": 488.0,
                "y": 185.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07840.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.0,
                "width": 96.0,
                "x": 791.0,
                "y": 602.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07839.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 278.0,
                "width": 545.0,
                "x": 718.0,
                "y": 315.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07806.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.0,
                "width": 404.0,
                "x": 310.0,
                "y": 54.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07779.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.0,
                "width": 97.0,
                "x": 436.0,
                "y": 344.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07770.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.0,
                "width": 124.0,
                "x": 551.0,
                "y": 379.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07751.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.0,
                "width": 131.0,
                "x": 809.0,
                "y": 264.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07743.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 298.0,
                "width": 157.0,
                "x": 750.0,
                "y": 241.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07729.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 75.0,
                "width": 302.0,
                "x": 433.0,
                "y": 494.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07627.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.0,
                "width": 269.0,
                "x": 720.0,
                "y": 320.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07536.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.0,
                "width": 136.0,
                "x": 801.0,
                "y": 275.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07503.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 309.0,
                "width": 134.0,
                "x": 752.0,
                "y": 252.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07483.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 262.0,
                "width": 529.0,
                "x": 722.0,
                "y": 321.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07457.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.0,
                "width": 170.0,
                "x": 771.0,
                "y": 261.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07415.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.0,
                "width": 120.0,
                "x": 738.0,
                "y": 323.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07405.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 285.0,
                "width": 540.0,
                "x": 695.0,
                "y": 304.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07399.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.0,
                "width": 102.0,
                "x": 746.0,
                "y": 320.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07305.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.0,
                "width": 96.0,
                "x": 747.0,
                "y": 320.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07279.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 506.0,
                "x": 505.0,
                "y": 170.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07254.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0,
                "width": 430.0,
                "x": 696.0,
                "y": 172.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07220.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.0,
                "width": 71.0,
                "x": 421.0,
                "y": 364.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07139.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 239.0,
                "width": 392.0,
                "x": 613.0,
                "y": 4.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06878.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 289.0,
                "width": 137.0,
                "x": 739.0,
                "y": 253.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06877.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 277.0,
                "width": 108.0,
                "x": 747.0,
                "y": 253.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06863.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 287.0,
                "width": 113.0,
                "x": 748.0,
                "y": 250.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06785.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.0,
                "width": 116.0,
                "x": 750.0,
                "y": 239.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06766.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.0,
                "width": 447.0,
                "x": 698.0,
                "y": 178.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06740.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.0,
                "width": 300.0,
                "x": 700.0,
                "y": 239.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06708.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.0,
                "width": 364.0,
                "x": 305.0,
                "y": 46.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06706.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.0,
                "width": 289.0,
                "x": 671.0,
                "y": 131.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06700.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 269.0,
                "width": 516.0,
                "x": 736.0,
                "y": 306.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06584.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.0,
                "width": 116.0,
                "x": 557.0,
                "y": 391.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06463.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.0,
                "width": 94.0,
                "x": 752.0,
                "y": 324.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06239.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.0,
                "width": 229.0,
                "x": 91.0,
                "y": 154.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06199.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 235.0,
                "width": 158.0,
                "x": 527.0,
                "y": 390.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06149.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.0,
                "width": 476.0,
                "x": 676.0,
                "y": 177.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06136.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 282.0,
                "width": 119.0,
                "x": 742.0,
                "y": 257.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06133.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.0,
                "width": 131.0,
                "x": 554.0,
                "y": 395.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06111.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.0,
                "width": 132.0,
                "x": 446.0,
                "y": 344.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06105.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.0,
                "width": 259.0,
                "x": 332.0,
                "y": 416.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06087.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 119.0,
                "width": 150.0,
                "x": 717.0,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06070.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 280.0,
                "width": 188.0,
                "x": 749.0,
                "y": 254.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06063.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.0,
                "width": 119.0,
                "x": 732.0,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06044.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.0,
                "width": 429.0,
                "x": 701.0,
                "y": 175.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06005.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 312.0,
                "width": 221.0,
                "x": 726.0,
                "y": 231.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05954.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 76.0,
                "width": 251.0,
                "x": 334.0,
                "y": 420.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05943.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 284.0,
                "width": 137.0,
                "x": 745.0,
                "y": 247.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05912.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.0,
                "width": 136.0,
                "x": 747.0,
                "y": 253.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05895.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.0,
                "width": 291.0,
                "x": 331.0,
                "y": 413.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05834.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 289.0,
                "width": 140.0,
                "x": 743.0,
                "y": 240.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05756.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.0,
                "width": 502.0,
                "x": 508.0,
                "y": 173.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05751.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.0,
                "width": 429.0,
                "x": 701.0,
                "y": 178.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05715.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.0,
                "width": 362.0,
                "x": 662.0,
                "y": 21.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05689.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.0,
                "width": 299.0,
                "x": 588.0,
                "y": 431.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05645.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.0,
                "width": 295.0,
                "x": 742.0,
                "y": 336.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05607.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 280.0,
                "width": 600.0,
                "x": 685.0,
                "y": 313.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05598.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.0,
                "width": 114.0,
                "x": 434.0,
                "y": 352.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05546.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.0,
                "width": 129.0,
                "x": 808.0,
                "y": 252.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05540.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.0,
                "width": 139.0,
                "x": 551.0,
                "y": 564.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05502.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.99157871408534,
                "width": 227.98736807112806,
                "x": 124.68059191389817,
                "y": 416.78940725503105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05425.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.68059191389818,
                "width": 93.8073024875996,
                "x": 745.7086830659814,
                "y": 318.2323679326163
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05413.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.5528286794574,
                "width": 518.9087492035571,
                "x": 501.09723607300026,
                "y": 195.9266444361257
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05345.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.42822342723468,
                "width": 434.600920385588,
                "x": 704.1484857613488,
                "y": 176.92769709686502
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05274.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.98947339260675,
                "width": 174.55282867945743,
                "x": 789.6437487880218,
                "y": 243.42401278427738
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05239.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.48368375854045,
                "width": 149.61671029667787,
                "x": 757.5830251530193,
                "y": 244.61144699298117
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05216.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 305.1705916368745,
                "width": 128.24289454000962,
                "x": 755.2081567356117,
                "y": 249.36118382779634
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05114.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.74026288816123,
                "width": 246.98631541038878,
                "x": 720.7725646832018,
                "y": 314.6700653065049
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05082.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.48368375854045,
                "width": 135.36749979223237,
                "x": 561.6563807168936,
                "y": 175.74026288816123
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05009.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.55598666167543,
                "width": 263.61039433224187,
                "x": 572.3432885952278,
                "y": 461.91190718577514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04996.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.61881561815645,
                "width": 474.9736834815168,
                "x": 694.6490120917184,
                "y": 222.05019702760913
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04992.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.23973655779156,
                "width": 92.61986827889575,
                "x": 404.91506516799313,
                "y": 340.7936178979883
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04988.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 289.7339469237253,
                "width": 123.49315770519445,
                "x": 752.8332883182042,
                "y": 248.17374961909255
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04967.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 271.92243379316835,
                "width": 541.4699991689292,
                "x": 712.4605252222752,
                "y": 320.60723635002387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04966.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.98842073186745,
                "width": 275.4847364192797,
                "x": 96.18217090500717,
                "y": 175.74026288816123
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04948.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.2407892185309,
                "width": 174.55282867945743,
                "x": 775.3945382835763,
                "y": 256.4857890800191
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04928.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.4868417407584,
                "width": 160.30361817501193,
                "x": 132.99263137482473,
                "y": 123.49315770519438
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04880.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.24289454000956,
                "width": 113.993684035564,
                "x": 737.3966436050549,
                "y": 314.6700653065049
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04873.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.30467083575124,
                "width": 476.16111769022075,
                "x": 710.0856568048677,
                "y": 208.98842073186742
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04851.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.9915787140854,
                "width": 408.47736779410445,
                "x": 647.1516437435668,
                "y": 110.43138140945267
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04826.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.80309184464232,
                "width": 87.87013144408058,
                "x": 415.60197304632726,
                "y": 355.0428284024338
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04820.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.429276087974,
                "width": 529.5956570818913,
                "x": 548.594604421152,
                "y": 207.80098652316363
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04779.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 298.04598638465177,
                "width": 167.42822342723468,
                "x": 740.9589462311662,
                "y": 246.98631541038876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04717.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.80203918390296,
                "width": 131.80519716612093,
                "x": 807.4552619185787,
                "y": 252.9234864539077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04702.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.37065777445025,
                "width": 239.86171015816598,
                "x": 350.29309156761866,
                "y": 417.97684146373484
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04693.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 307.5454600542822,
                "width": 174.55282867945755,
                "x": 740.9589462311662,
                "y": 231.54967069723946
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04685.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 269.54756537576077,
                "width": 541.4699991689292,
                "x": 706.5233541787563,
                "y": 315.8574995152087
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04652.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.23763123631292,
                "width": 346.7307889415073,
                "x": 618.6532227346758,
                "y": 22.56124996537205
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04636.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.7392102274219,
                "width": 457.16217035095985,
                "x": 675.6500647524578,
                "y": 154.36644713149298
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04617.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 290.9213811324291,
                "width": 169.80309184464227,
                "x": 740.9589462311662,
                "y": 257.6732232887229
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04592.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.2397365577916,
                "width": 140.11723662704753,
                "x": 806.2678277098748,
                "y": 243.42401278427738
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04565.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.93296040056163,
                "width": 262.4229601235381,
                "x": 336.04388106317316,
                "y": 413.2271046289197
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04556.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 330.1067100196542,
                "width": 150.8041445053816,
                "x": 742.1463804398701,
                "y": 229.17480227983188
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04548.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.61355231445987,
                "width": 104.49421036593367,
                "x": 396.6030257070666,
                "y": 327.7318416022466
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04530.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.6082890107632,
                "width": 229.17480227983197,
                "x": 726.7097357267207,
                "y": 239.861710158166
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04494.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.05230234908782,
                "width": 106.86907878334125,
                "x": 397.7904599157704,
                "y": 345.5433547328035
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04484.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 337.23131527187695,
                "width": 137.74236820963984,
                "x": 746.8961172746853,
                "y": 218.48789440149775
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04448.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 300.42085480205935,
                "width": 150.8041445053816,
                "x": 726.7097357267207,
                "y": 232.73710490594326
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04391.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.4899997229764,
                "width": 459.53703876836744,
                "x": 692.2741436743108,
                "y": 168.61565763593848
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04380.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.80098652316363,
                "width": 295.6711179672442,
                "x": 628.1526964043061,
                "y": 237.48684174075842
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04366.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.3643418100143,
                "width": 433.413486176884,
                "x": 816.954735588209,
                "y": 186.42717076649535
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04253.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.1140786448295,
                "width": 308.73289426298595,
                "x": 602.0291438128226,
                "y": 9.499473669630337
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04150.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.1726969583532,
                "width": 548.594604421152,
                "x": 700.5861831352373,
                "y": 315.8574995152087
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04123.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 260.0480917061305,
                "width": 542.657433377633,
                "x": 721.9599988919056,
                "y": 328.9192758109504
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04064.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.48894706223712,
                "width": 141.30467083575127,
                "x": 584.2176306822657,
                "y": 426.2888809246614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04057.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.49105238371573,
                "width": 434.600920385588,
                "x": 695.8364463004222,
                "y": 179.3025655142726
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03979.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.86802612260195,
                "width": 508.22184132522307,
                "x": 617.4657885259719,
                "y": 218.48789440149775
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03975.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.36644713149295,
                "width": 476.16111769022064,
                "x": 687.5244068394957,
                "y": 194.73921022742192
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03951.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.24078921853086,
                "width": 541.4699991689291,
                "x": 521.2836176209647,
                "y": 210.1758549405712
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03873.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 292.10881534113287,
                "width": 136.5549340009361,
                "x": 745.7086830659814,
                "y": 244.61144699298117
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03841.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 295.6711179672442,
                "width": 194.73921022742184,
                "x": 713.6479594309791,
                "y": 242.2365785755736
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03834.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.1161839663081,
                "width": 520.0961834122609,
                "x": 533.1579597080026,
                "y": 204.23868389705225
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03807.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.49315770519439,
                "width": 110.43138140945268,
                "x": 736.2092093963511,
                "y": 317.0449337239125
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03772.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 244.61144699298117,
                "width": 347.91822315021113,
                "x": 631.7149990304174,
                "y": 3.5623026261113764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03742.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.17796026204985,
                "width": 438.1632230116994,
                "x": 700.5861831352373,
                "y": 170.99052605334606
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03716.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.99052605334606,
                "width": 181.67743393168018,
                "x": 776.5819724922801,
                "y": 260.0480917061305
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03572.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.68164457463752,
                "width": 90.24499986148828,
                "x": 750.4584199007966,
                "y": 326.5444073935428
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03530.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.67848659241952,
                "width": 154.36644713149292,
                "x": 790.8311829967256,
                "y": 267.17269695835324
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03526.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.74131554890056,
                "width": 137.74236820963984,
                "x": 805.0803935011711,
                "y": 264.79782854094566
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03389.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.11302598409014,
                "width": 235.11197332335084,
                "x": 91.43243407019199,
                "y": 163.8659208011233
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03383.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 322.98210476743145,
                "width": 115.18111824426785,
                "x": 752.8332883182042,
                "y": 226.7999338624243
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03365.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.11828928778681,
                "width": 105.68164457463752,
                "x": 751.6458541095004,
                "y": 317.0449337239125
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03308.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.61565763593848,
                "width": 435.7883545942916,
                "x": 697.023880509126,
                "y": 173.36539447075364
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03298.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.99157871408536,
                "width": 511.7841439513345,
                "x": 580.6553280561543,
                "y": 201.86381547964467
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03267.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.42717076649535,
                "width": 281.4219074627987,
                "x": 621.0280911520833,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03265.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 296.85855217594803,
                "width": 116.3685524529717,
                "x": 748.083551483389,
                "y": 244.61144699298117
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03246.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 300.42085480205935,
                "width": 108.0565129920451,
                "x": 749.2709856920928,
                "y": 246.98631541038876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03191.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.11407864482948,
                "width": 470.2239466467016,
                "x": 769.4573672400574,
                "y": 180.4899997229764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.23868389705225,
                "width": 153.17901292278918,
                "x": 790.8311829967256,
                "y": 254.1109206626115
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03132.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.18217090500713,
                "width": 249.36118382779637,
                "x": 339.60618368928453,
                "y": 398.9778941244742
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03076.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.61671029667778,
                "width": 425.10144671595754,
                "x": 763.5201961965383,
                "y": 211.363289149275
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03070.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.36644713149298,
                "width": 102.11934194852608,
                "x": 746.8961172746853,
                "y": 306.35802584557837
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03066.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.864868140384,
                "width": 197.11407864482942,
                "x": 771.8322356574649,
                "y": 251.73605224520392
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03049.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.36960511371092,
                "width": 295.6711179672443,
                "x": 322.98210476743145,
                "y": 408.4773677941045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03022.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.42611810575602,
                "width": 523.6584860383723,
                "x": 496.3474992381851,
                "y": 149.6167102966778
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02955.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.2407892185309,
                "width": 167.42822342723468,
                "x": 784.8940119532066,
                "y": 263.61039433224187
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02942.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.61355231445987,
                "width": 62.93401306130096,
                "x": 419.16427567243863,
                "y": 334.85644685446937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02802.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.18111824426785,
                "width": 303.9831574281708,
                "x": 476.16111769022064,
                "y": 461.91190718577514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02773.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 289.7339469237253,
                "width": 131.80519716612093,
                "x": 748.083551483389,
                "y": 252.9234864539077
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02760.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.42717076649535,
                "width": 162.67848659241952,
                "x": 790.8311829967256,
                "y": 263.61039433224187
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02745.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.99052605334606,
                "width": 460.7244729770714,
                "x": 697.023880509126,
                "y": 182.86486814038398
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02691.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.7444735311185,
                "width": 330.10671001965426,
                "x": 439.3506572204031,
                "y": 473.78624927281305
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02680.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 268.360131167057,
                "width": 560.4689465081899,
                "x": 698.2113147178297,
                "y": 312.2951968890973
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02595.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.1151313055688,
                "width": 174.55282867945743,
                "x": 780.1442751183914,
                "y": 260.0480917061305
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02543.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.74236820963986,
                "width": 296.85855217594803,
                "x": 691.086709465607,
                "y": 233.92453911464705
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02541.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.5549340009361,
                "width": 303.9831574281708,
                "x": 675.6500647524578,
                "y": 121.1182892877868
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02511.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 280.2344732540949,
                "width": 489.2228939859624,
                "x": 758.7704593617232,
                "y": 300.4208548020594
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02419.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 83.12039460926547,
                "width": 309.9203284716897,
                "x": 419.16427567243863,
                "y": 493.9726308207775
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02395.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.98947339260673,
                "width": 271.92243379316847,
                "x": 714.8353936396828,
                "y": 307.54546005428216
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02377.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.92874975760435,
                "width": 461.91190718577514,
                "x": 687.5244068394957,
                "y": 184.05230234908777
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02353.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.2407892185309,
                "width": 480.9108545250358,
                "x": 692.2741436743108,
                "y": 178.1151313055688
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02331.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.61881561815648,
                "width": 328.91927581095047,
                "x": 697.023880509126,
                "y": 148.42927608797402
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02202.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.7392102274219,
                "width": 534.3453939167064,
                "x": 486.84802556855476,
                "y": 174.55282867945743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02177.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.86802612260198,
                "width": 112.80624982686027,
                "x": 740.9589462311662,
                "y": 308.73289426298595
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02160.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.48789440149778,
                "width": 159.11618396630809,
                "x": 517.7213149948534,
                "y": 393.0407230809552
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02099.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.1800655835285,
                "width": 319.41980214132,
                "x": 697.023880509126,
                "y": 239.861710158166
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02084.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 341.9810521066921,
                "width": 124.68059191389818,
                "x": 757.5830251530193,
                "y": 239.861710158166
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02051.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.42927608797402,
                "width": 102.1193419485262,
                "x": 743.3338146485738,
                "y": 295.67111796724424
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02031.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.99052605334612,
                "width": 78.37065777445025,
                "x": 413.2271046289197,
                "y": 351.48052577632245
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01993.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.92980241834368,
                "width": 112.80624982686027,
                "x": 745.7086830659814,
                "y": 318.2323679326163
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01982.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.80624982686027,
                "width": 91.43243407019202,
                "x": 750.4584199007966,
                "y": 332.4815784370618
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01957.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 313.4826310978011,
                "width": 112.80624982686027,
                "x": 750.4584199007966,
                "y": 249.36118382779634
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01879.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.61355231445987,
                "width": 104.49421036593367,
                "x": 402.54019675058555,
                "y": 315.8574995152087
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01807.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.23973655779156,
                "width": 448.85013089003337,
                "x": 683.9621042133842,
                "y": 169.80309184464227
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01697.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.0470390453911,
                "width": 537.9076965428178,
                "x": 711.2730910135715,
                "y": 308.73289426298595
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01692.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.49210504445506,
                "width": 321.7946705587276,
                "x": 661.4008542480123,
                "y": 122.30572349649059
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01678.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.99052605334606,
                "width": 473.78624927281317,
                "x": 679.2123673785691,
                "y": 174.55282867945743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01664.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.99473669630333,
                "width": 298.04598638465177,
                "x": 306.35802584557837,
                "y": 407.2899335854007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01656.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.0533550098271,
                "width": 299.2334205933556,
                "x": 625.7778279868985,
                "y": 433.41348617688413
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01639.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 368.10460469817554,
                "width": 122.3057234964906,
                "x": 736.2092093963511,
                "y": 217.30046019279396
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01534.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.8659208011233,
                "width": 444.1003940552183,
                "x": 694.6490120917184,
                "y": 172.17796026204985
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01522.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.99052605334606,
                "width": 452.4124335161447,
                "x": 685.1495384220881,
                "y": 170.99052605334606
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01483.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.80730248759954,
                "width": 90.24499986148817,
                "x": 909.5746038671048,
                "y": 263.61039433224187
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01452.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.92769709686502,
                "width": 440.53809142910677,
                "x": 692.2741436743108,
                "y": 172.17796026204985
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01451.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.6177629574171,
                "width": 489.2228939859623,
                "x": 647.1516437435668,
                "y": 214.92559177538638
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01425.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.30151285353327,
                "width": 518.9087492035571,
                "x": 490.41032819466614,
                "y": 155.55388134019677
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01423.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.49631568741233,
                "width": 256.48578908001906,
                "x": 345.5433547328035,
                "y": 436.9757888029955
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01418.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 283.79677588020627,
                "width": 73.62092093963508,
                "x": 774.2071040748725,
                "y": 246.98631541038876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01400.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 281.4219074627987,
                "width": 188.80203918390305,
                "x": 755.2081567356117,
                "y": 251.73605224520392
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01327.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.30256551427257,
                "width": 378.7915125765096,
                "x": 866.8269723537683,
                "y": 198.3015128535333
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01044.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.2407892185309,
                "width": 422.72657829854995,
                "x": 691.086709465607,
                "y": 172.17796026204985
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01019.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.86486814038398,
                "width": 467.84907822929415,
                "x": 667.3380252915312,
                "y": 161.49105238371573
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00908.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.74026288816123,
                "width": 495.1600650294814,
                "x": 676.8374989611615,
                "y": 169.80309184464227
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00862.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.36960511371092,
                "width": 264.79782854094566,
                "x": 439.3506572204031,
                "y": 488.03545977725855
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00848.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 289.7339469237253,
                "width": 156.74131554890062,
                "x": 731.4594725615359,
                "y": 256.4857890800191
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00821.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 275.4847364192797,
                "width": 533.1579597080027,
                "x": 713.6479594309791,
                "y": 314.6700653065049
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00814.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.7423682096399,
                "width": 111.61881561815642,
                "x": 732.6469067702398,
                "y": 314.6700653065049
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00781.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.73921022742192,
                "width": 153.17901292278918,
                "x": 797.9557882489484,
                "y": 255.2983548713153
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00721.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.2418418792702,
                "width": 308.73289426298595,
                "x": 683.9621042133842,
                "y": 220.86276281890534
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00691.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.0533550098271,
                "width": 423.9140125072538,
                "x": 698.2113147178297,
                "y": 180.4899997229764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00639.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.67638127094088,
                "width": 550.9694728385596,
                "x": 505.8469729078154,
                "y": 193.55177601871813
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00631.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.80414450538163,
                "width": 312.29519688909727,
                "x": 704.1484857613488,
                "y": 237.48684174075842
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00574.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 248.17374961909252,
                "width": 165.0533550098271,
                "x": 548.594604421152,
                "y": 383.5412494113249
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00485.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.61355231445984,
                "width": 307.5454600542821,
                "x": 628.1526964043061,
                "y": 4.7497368348151685
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00453.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.55703932241471,
                "width": 238.67427594946224,
                "x": 345.5433547328035,
                "y": 412.0396704202159
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00434.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.62092093963508,
                "width": 276.6721706279836,
                "x": 321.79467055872766,
                "y": 420.3517098811424
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00433.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.80730248759954,
                "width": 252.92348645390774,
                "x": 338.41874948058074,
                "y": 404.91506516799313
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00412.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.99157871408536,
                "width": 321.7946705587277,
                "x": 691.086709465607,
                "y": 224.4250654450167
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00397.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.55282867945746,
                "width": 151.99157871408534,
                "x": 797.9557882489484,
                "y": 251.73605224520392
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00368.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.42717076649535,
                "width": 106.86907878334125,
                "x": 407.2899335854007,
                "y": 344.3559205240997
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00359.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.3674997922323,
                "width": 121.11828928778687,
                "x": 740.9589462311662,
                "y": 315.8574995152087
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00332.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.87013144408058,
                "width": 251.7360522452039,
                "x": 343.1684863153959,
                "y": 409.6648020028083
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00305.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.49210504445503,
                "width": 340.79361789798827,
                "x": 678.0249331698653,
                "y": 229.17480227983188
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00267.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.42822342723468,
                "width": 172.17796026204985,
                "x": 549.7820386298557,
                "y": 552.1569070472633
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00263.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.48789440149778,
                "width": 464.28677560318283,
                "x": 773.0196698661687,
                "y": 174.55282867945743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00262.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.55493400093607,
                "width": 317.04493372391255,
                "x": 686.3369726307918,
                "y": 238.6742759494622
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00226.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.42717076649535,
                "width": 157.92874975760435,
                "x": 553.3443412559672,
                "y": 554.5317754646709
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00183.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 305.17059163687463,
                "width": 150.8041445053816,
                "x": 733.8343409789435,
                "y": 243.42401278427738
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00127.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.98526274964945,
                "width": 420.35170988114237,
                "x": 617.4657885259719,
                "y": -1.1874342087037921
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00126.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.98947339260678,
                "width": 477.3485518989244,
                "x": 305.1705916368746,
                "y": 327.7318416022466
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07864.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.30677615722988,
                "width": 160.30361817501193,
                "x": 412.0396704202159,
                "y": 395.4155914983628
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07570.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.30782881796921,
                "width": 137.7423682096399,
                "x": 408.4773677941045,
                "y": 403.72763095928934
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07547.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 59.37171043518964,
                "width": 198.30151285353327,
                "x": 402.54019675058555,
                "y": 474.97368348151684
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07546.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.68374989611618,
                "width": 193.5517760187181,
                "x": 409.6648020028083,
                "y": 471.41138085540547
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07451.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.05756565278438,
                "width": 155.55388134019682,
                "x": 467.8490782292941,
                "y": 407.2899335854007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07365.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 64.12144727000481,
                "width": 198.30151285353327,
                "x": 400.16532833317797,
                "y": 460.72447297707134
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07359.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.68374989611613,
                "width": 182.86486814038392,
                "x": 407.2899335854007,
                "y": 458.34960455966376
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07266.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.3025655142726,
                "width": 451.22499930744095,
                "x": 294.48368375854045,
                "y": 330.1067100196542
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07227.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.87013144408058,
                "width": 153.17901292278918,
                "x": 471.41138085540547,
                "y": 402.54019675058555
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07077.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.9915787140854,
                "width": 236.29940753205466,
                "x": 427.4763151333652,
                "y": 389.47842045484384
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07073.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 51.0596709742631,
                "width": 185.23973655779162,
                "x": 423.9140125072538,
                "y": 478.5359861076282
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07042.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.68269723537679,
                "width": 153.17901292278918,
                "x": 368.10460469817554,
                "y": 391.8532888722514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_07019.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.8638154796447,
                "width": 116.3685524529717,
                "x": 495.1600650294813,
                "y": 332.4815784370618
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06984.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.43243407019196,
                "width": 143.67953925315885,
                "x": 343.1684863153959,
                "y": 391.8532888722514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06818.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.0565129920451,
                "width": 218.48789440149778,
                "x": 407.2899335854007,
                "y": 423.9140125072538
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06719.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.24394720074889,
                "width": 220.8627628189053,
                "x": 422.72657829855,
                "y": 415.60197304632726
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06699.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.36960511371097,
                "width": 203.05124968834843,
                "x": 421.5391440898462,
                "y": 429.85118355077276
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06651.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.67743393168018,
                "width": 436.97578880299557,
                "x": 325.35697318483903,
                "y": 334.85644685446937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06578.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.24394720074883,
                "width": 166.2407892185309,
                "x": 378.79151257650966,
                "y": 396.6030257070666
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06419.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.6135523144598,
                "width": 474.97368348151684,
                "x": 274.297302210576,
                "y": 321.79467055872766
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06382.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.8638154796447,
                "width": 110.43138140945268,
                "x": 371.6669073242869,
                "y": 344.3559205240997
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06363.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.495263026673,
                "width": 157.92874975760435,
                "x": 407.2899335854007,
                "y": 404.91506516799313
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06155.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 232.73710490594328,
                "width": 125.86802612260198,
                "x": 371.6669073242869,
                "y": 320.60723635002387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06093.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.23868389705223,
                "width": 125.86802612260198,
                "x": 362.1674336546566,
                "y": 336.04388106317316
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_06028.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.17585494057124,
                "width": 86.68269723537674,
                "x": 512.9715781600382,
                "y": 324.16953897613524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05997.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.99473669630333,
                "width": 162.67848659241957,
                "x": 458.34960455966376,
                "y": 396.6030257070666
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05860.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.7392102274219,
                "width": 104.49421036593378,
                "x": 509.4092755339268,
                "y": 340.7936178979883
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05753.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.17690760131057,
                "width": 109.24394720074889,
                "x": 498.7223676555927,
                "y": 347.9182231502111
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05711.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.48894706223706,
                "width": 478.5359861076283,
                "x": 298.0459863846518,
                "y": 324.16953897613524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05704.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.11407864482948,
                "width": 100.93190773982235,
                "x": 520.096183412261,
                "y": 336.04388106317316
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05490.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.74131554890056,
                "width": 255.29835487131527,
                "x": 421.5391440898462,
                "y": 321.79467055872766
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05310.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.7444735311185,
                "width": 161.49105238371573,
                "x": 352.66795998502624,
                "y": 383.5412494113249
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05287.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.92664443612574,
                "width": 486.8480255685547,
                "x": 265.98526274964945,
                "y": 319.4198021413201
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05223.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.6146049751992,
                "width": 112.80624982686027,
                "x": 378.79151257650966,
                "y": 341.9810521066921
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05155.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 66.49631568741233,
                "width": 286.1716442976139,
                "x": 319.4198021413201,
                "y": 402.54019675058555
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05141.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.8073024875996,
                "width": 144.86697346186264,
                "x": 346.7307889415073,
                "y": 379.97894678521345
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05133.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 62.04000000000002,
                "width": 212.91000000000008,
                "x": 400.44000000000017,
                "y": 466.7100000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05112.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.01000000000005,
                "width": 197.40000000000015,
                "x": 369.42000000000013,
                "y": 400.44000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05111.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.9400000000001,
                "width": 492.0900000000002,
                "x": 279.1800000000001,
                "y": 334.17000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05092.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.01000000000005,
                "width": 157.92000000000007,
                "x": 353.91000000000014,
                "y": 387.75000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_05070.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.99000000000007,
                "width": 499.14000000000027,
                "x": 265.0800000000001,
                "y": 328.53000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04769.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.04000000000013,
                "width": 146.6400000000001,
                "x": 356.73000000000013,
                "y": 328.53000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04751.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.93000000000006,
                "width": 173.43,
                "x": 421.5900000000002,
                "y": 396.21000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04680.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.50000000000006,
                "width": 509.01000000000016,
                "x": 293.28000000000014,
                "y": 334.17000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04495.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 60.63000000000005,
                "width": 293.2800000000001,
                "x": 276.3600000000001,
                "y": 406.08000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04434.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.44000000000005,
                "width": 160.74,
                "x": 400.44000000000017,
                "y": 383.52000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.47000000000003,
                "width": 177.66000000000008,
                "x": 321.48000000000013,
                "y": 383.52000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04371.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.80000000000001,
                "width": 184.7100000000001,
                "x": 418.77000000000015,
                "y": 387.75000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04238.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.22000000000008,
                "width": 150.87000000000006,
                "x": 359.5500000000001,
                "y": 339.8100000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04072.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.60000000000002,
                "width": 331.35000000000014,
                "x": 297.5100000000001,
                "y": 394.8000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04060.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.27000000000015,
                "width": 477.9900000000002,
                "x": 290.4600000000001,
                "y": 324.3000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_04012.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.42000000000013,
                "width": 562.5900000000003,
                "x": 252.3900000000001,
                "y": 320.0700000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03917.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53000000000014,
                "width": 489.2700000000002,
                "x": 287.6400000000001,
                "y": 329.9400000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03646.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 73.32,
                "width": 284.82000000000016,
                "x": 327.1200000000001,
                "y": 404.6700000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03395.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.17000000000002,
                "width": 496.32000000000016,
                "x": 272.1300000000001,
                "y": 332.76000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03243.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 70.50000000000006,
                "width": 298.9200000000001,
                "x": 311.6100000000001,
                "y": 399.03000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_03133.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.22000000000008,
                "width": 133.95000000000005,
                "x": 355.32000000000016,
                "y": 329.9400000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02959.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 80.37,
                "width": 187.53000000000003,
                "x": 413.13000000000017,
                "y": 455.4300000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02874.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.01000000000005,
                "width": 159.3300000000001,
                "x": 368.01000000000016,
                "y": 397.6200000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02831.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.76000000000016,
                "width": 108.57000000000005,
                "x": 504.7800000000002,
                "y": 339.8100000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02792.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.73000000000002,
                "width": 201.63000000000005,
                "x": 408.90000000000015,
                "y": 459.6600000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02715.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 71.91000000000003,
                "width": 305.97000000000014,
                "x": 315.84000000000015,
                "y": 407.4900000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02528.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 64.86000000000001,
                "width": 197.40000000000003,
                "x": 413.13000000000017,
                "y": 473.7600000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02413.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.29000000000002,
                "width": 176.25000000000006,
                "x": 421.5900000000002,
                "y": 391.9800000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02407.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.69999999999999,
                "width": 246.7500000000001,
                "x": 400.44000000000017,
                "y": 431.4600000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02360.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.06000000000006,
                "width": 184.7100000000001,
                "x": 427.2300000000002,
                "y": 399.03000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02198.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.35000000000014,
                "width": 86.00999999999999,
                "x": 521.7000000000003,
                "y": 341.22000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_02011.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.99000000000012,
                "width": 118.44000000000005,
                "x": 365.19000000000017,
                "y": 331.35000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01871.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.9400000000001,
                "width": 507.60000000000025,
                "x": 277.7700000000001,
                "y": 334.17000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01866.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.96000000000004,
                "width": 303.15000000000015,
                "x": 318.66000000000014,
                "y": 396.21000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01814.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.17000000000007,
                "width": 83.18999999999994,
                "x": 521.7000000000003,
                "y": 336.9900000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01648.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.60000000000002,
                "width": 153.69000000000005,
                "x": 325.71000000000015,
                "y": 394.8000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01559.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.49000000000007,
                "width": 174.8400000000001,
                "x": 446.9700000000002,
                "y": 334.17000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01526.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.24000000000007,
                "width": 167.79000000000002,
                "x": 358.14000000000016,
                "y": 393.39000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01428.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 104.34000000000009,
                "width": 177.66000000000008,
                "x": 444.1500000000002,
                "y": 399.03000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01356.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.21000000000004,
                "width": 267.90000000000003,
                "x": 352.50000000000017,
                "y": 415.95000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01349.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 221.37000000000012,
                "width": 475.1700000000002,
                "x": 297.5100000000001,
                "y": 321.48000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01175.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.39000000000004,
                "width": 187.53000000000003,
                "x": 413.13000000000017,
                "y": 390.57000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_01080.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.88,
                "width": 239.70000000000016,
                "x": 406.08000000000015,
                "y": 455.4300000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00886.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.73000000000002,
                "width": 311.6100000000002,
                "x": 290.4600000000001,
                "y": 393.39000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00851.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.11000000000001,
                "width": 221.37000000000012,
                "x": 355.32000000000016,
                "y": 390.57000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00802.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.72000000000003,
                "width": 232.65000000000003,
                "x": 421.5900000000002,
                "y": 328.53000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00698.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.7600000000001,
                "width": 105.75000000000011,
                "x": 510.4200000000002,
                "y": 336.9900000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00670.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.09000000000015,
                "width": 132.54000000000008,
                "x": 360.96000000000015,
                "y": 336.9900000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00589.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.9400000000001,
                "width": 101.51999999999998,
                "x": 499.1400000000002,
                "y": 342.63000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00472.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.26000000000005,
                "width": 200.22000000000008,
                "x": 428.64000000000016,
                "y": 417.3600000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00261.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.70000000000005,
                "width": 163.56000000000006,
                "x": 365.19000000000017,
                "y": 390.57000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/OTHER/img_00063.jpg"
    }
]

# %%
[
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.0,
                "width": 103.0,
                "x": 518.0,
                "y": 335.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07860.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.0,
                "width": 84.0,
                "x": 541.0,
                "y": 322.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07857.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.0,
                "width": 104.0,
                "x": 521.0,
                "y": 354.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07841.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 325.0,
                "width": 508.0,
                "x": 2.0,
                "y": 484.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07661.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.1601411376414,
                "width": 37.45691117468084,
                "x": 581.8306869133763,
                "y": 354.59209245364565
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07556.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.77468276671743,
                "width": 97.74470154154824,
                "x": 520.8294315717532,
                "y": 361.370009713826
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07533.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 168.0718728403594,
                "width": 651.9419488597098,
                "x": 375.9502418797512,
                "y": 216.7242570836213
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07498.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767803,
                "width": 189.30200414651,
                "x": 453.7940566689703,
                "y": 429.02557014512786
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07484.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 320.2792792792793,
                "width": 528.6801801801803,
                "x": 1.0968468468468469,
                "y": 489.1936936936937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07473.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.4174153420871,
                "width": 628.0580511402902,
                "x": 384.7961299239807,
                "y": 199.03248099516242
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07414.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 158.8764449793553,
                "width": 61.45220985050537,
                "x": 567.3088153272263,
                "y": 343.23307453087136
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07392.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.11297071129707,
                "width": 157.9916317991632,
                "x": 473.08228730822873,
                "y": 425.77405857740587
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07282.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.36794914537631,
                "width": 64.51656186375271,
                "x": 559.7367918938,
                "y": 344.8298996166097
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07221.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.61645746164578,
                "width": 173.1659693165969,
                "x": 458.8005578800558,
                "y": 427.55927475592745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07080.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 321.3761261261261,
                "width": 511.13063063063066,
                "x": -1.0968468468468469,
                "y": 483.7094594594595
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07056.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 261.0495495495495,
                "width": 585.7162162162163,
                "x": 358.6689189189189,
                "y": 555.0045045045046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07022.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.9527027027027,
                "width": 664.6891891891892,
                "x": 336.73198198198196,
                "y": 558.2950450450451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_07003.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.3434692467174,
                "width": 163.6489288182446,
                "x": 474.13959917069803,
                "y": 430.79474775397375
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06956.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.61161022805805,
                "width": 76.95922598479609,
                "x": 497.1389080856946,
                "y": 359.1430545957153
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06913.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.30338631651688,
                "width": 61.03662750518315,
                "x": 121.18866620594333,
                "y": 461.75535590877683
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06903.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.6621621621622,
                "width": 514.4211711711712,
                "x": 316.98873873873873,
                "y": 561.5855855855856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06881.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 254.46846846846847,
                "width": 383.8963963963964,
                "x": 141.49324324324326,
                "y": 557.1981981981982
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06847.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.95715272978578,
                "width": 88.45888044229446,
                "x": 532.5224602626123,
                "y": 358.25846579129234
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06821.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.72297297297303,
                "width": 648.2364864864865,
                "x": 358.6689189189189,
                "y": 557.1981981981982
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06786.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.8030407740152,
                "width": 91.99723565998613,
                "x": 551.9834139599171,
                "y": 346.7588113337941
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06686.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.49550794747756,
                "width": 116.76572218382864,
                "x": 503.33102971665517,
                "y": 358.25846579129234
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06677.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786452,
                "width": 71.65169315825847,
                "x": 116.76572218382861,
                "y": 464.4091223220456
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06595.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.1098825155494,
                "width": 583.8286109191431,
                "x": 377.7194194885971,
                "y": 207.87836903939186
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06590.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 164.5335176226676,
                "width": 76.95922598479615,
                "x": 545.7912923289565,
                "y": 343.2204561161023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06537.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.6496199032481,
                "width": 68.99792674498963,
                "x": 118.53489979267451,
                "y": 462.6399447131997
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06523.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.8804422944022,
                "width": 62.80580511402901,
                "x": 122.95784381478923,
                "y": 470.60124395300625
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06493.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.88182446440908,
                "width": 160.11057360055293,
                "x": 467.9474775397374,
                "y": 432.56392536281965
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06474.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.11057360055287,
                "width": 86.68970283344856,
                "x": 541.3683483068418,
                "y": 352.06634416033177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06467.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.49550794747756,
                "width": 85.80511402902562,
                "x": 539.5991706979959,
                "y": 343.2204561161023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06448.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53282653766416,
                "width": 584.713199723566,
                "x": 398.9495507947478,
                "y": 213.1859018659295
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06444.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.72522522522524,
                "width": 673.4639639639638,
                "x": 357.5720720720721,
                "y": 559.3918918918919
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06410.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.84105044920523,
                "width": 590.9053213545267,
                "x": 388.3344851416725,
                "y": 202.5708362128542
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06385.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 248.98423423423424,
                "width": 574.7477477477478,
                "x": 354.2815315315315,
                "y": 568.1666666666666
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06303.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.2770270270271,
                "width": 553.9076576576576,
                "x": 55.93918918918919,
                "y": 540.7454954954954
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06220.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.60884588804421,
                "width": 453.79405666897037,
                "x": 240.60815480304078,
                "y": 158.341395991707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06163.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.26468555632346,
                "width": 88.45888044229446,
                "x": 539.5991706979959,
                "y": 341.4512785072564
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06124.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.11126468555636,
                "width": 71.65169315825847,
                "x": 545.7912923289565,
                "y": 338.79751209398756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06118.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.4968901174845,
                "width": 225.57014512785088,
                "x": 488.2930200414653,
                "y": 276.8762957843816
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06082.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 95.53559087767803,
                "width": 192.8403593642018,
                "x": 449.3711126468556,
                "y": 426.371803731859
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06013.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.5900900900901,
                "width": 204.01351351351354,
                "x": 688.8198198198198,
                "y": 126.13738738738739
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06006.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.22805805114035,
                "width": 164.53351762266766,
                "x": 467.9474775397374,
                "y": 431.6793365583967
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_06000.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.45818935729096,
                "width": 94.65100207325509,
                "x": 528.9841050449205,
                "y": 367.1043538355218
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05942.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.76641326883203,
                "width": 257.41534208707674,
                "x": 362.6814098134071,
                "y": 440.52522460262617
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05900.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.87906012439532,
                "width": 559.0601243953007,
                "x": 206.10919143054596,
                "y": 199.91706979958536
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05887.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152043,
                "width": 62.80580511402911,
                "x": 563.4830684174153,
                "y": 338.79751209398756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05873.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.49343469246722,
                "width": 567.9060124395302,
                "x": 240.60815480304078,
                "y": 168.9564616447823
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05872.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 276.4054054054054,
                "width": 518.8085585585586,
                "x": 364.15315315315314,
                "y": 542.9391891891892
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05762.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 120.30407740152037,
                "width": 86.68970283344856,
                "x": 532.5224602626123,
                "y": 361.7968210089841
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05685.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.91706979958533,
                "width": 528.9841050449206,
                "x": 202.5708362128542,
                "y": 191.95577055977887
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05579.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 272.018018018018,
                "width": 513.3243243243244,
                "x": 358.6689189189189,
                "y": 558.2950450450451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05532.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.26399447131996,
                "width": 91.1126468555633,
                "x": 538.7145818935729,
                "y": 315.79820317899106
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05519.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.14858327574296,
                "width": 95.53559087767792,
                "x": 550.2142363510712,
                "y": 322.8749136143746
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05504.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 273.1148648648649,
                "width": 607.6531531531532,
                "x": 353.18468468468467,
                "y": 550.6171171171171
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05464.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.6489288182447,
                "width": 132.68832066344157,
                "x": 509.5231513476158,
                "y": 354.72011057360055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05399.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.99723565998625,
                "width": 215.8396682791983,
                "x": 418.41050449205255,
                "y": 432.56392536281965
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05391.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.34277816171397,
                "width": 166.30269523151355,
                "x": 462.6399447131997,
                "y": 410.44920525224603
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05366.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.57221838286108,
                "width": 104.38147892190739,
                "x": 535.1762266758811,
                "y": 342.33586731167935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05327.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.759009009009,
                "width": 562.6824324324325,
                "x": 338.9256756756757,
                "y": 561.5855855855856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05300.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.7277125086386,
                "width": 193.72494816862468,
                "x": 441.4098134070491,
                "y": 418.41050449205255
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05257.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.5292792792793,
                "width": 673.463963963964,
                "x": 336.73198198198196,
                "y": 550.6171171171171
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05249.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.30405405405406,
                "width": 686.6261261261261,
                "x": 327.9572072072072,
                "y": 557.1981981981982
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05231.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.72771250863849,
                "width": 167.1872840359365,
                "x": 465.29371112646857,
                "y": 425.4872149274361
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05126.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.34001382170007,
                "width": 543.1375259156877,
                "x": 191.07118175535592,
                "y": 191.07118175535592
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_05019.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 248.98423423423424,
                "width": 607.6531531531532,
                "x": 355.3783783783784,
                "y": 561.5855855855856
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04910.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.45680718728408,
                "width": 96.42017968210098,
                "x": 528.9841050449205,
                "y": 338.79751209398756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04857.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 349.89414414414415,
                "width": 530.8738738738739,
                "x": 8.774774774774775,
                "y": 479.3220720720721
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04855.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.03524533517628,
                "width": 158.34139599170703,
                "x": 466.1782999308915,
                "y": 411.333794056669
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04854.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 216.07882882882893,
                "width": 696.4977477477478,
                "x": 343.31306306306305,
                "y": 551.7139639639639
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04837.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 93.76641326883214,
                "width": 160.1105736005528,
                "x": 474.13959917069803,
                "y": 430.79474775397375
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04819.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.07394609536976,
                "width": 168.95646164478234,
                "x": 459.101589495508,
                "y": 422.8334485141673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04791.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.45749827228747,
                "width": 114.1119557705598,
                "x": 518.3690393918453,
                "y": 349.4125777470629
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04710.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 292.7988942639945,
                "width": 568.790601243953,
                "x": 340.56668970283346,
                "y": 129.14996544574984
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04682.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 333.4414414414414,
                "width": 653.7207207207208,
                "x": -4.387387387387387,
                "y": 478.22522522522524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04650.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.49689011748444,
                "width": 169.84105044920534,
                "x": 463.5245335176227,
                "y": 428.1409813407049
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04618.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.41879751209393,
                "width": 75.19004837595025,
                "x": 107.03524533517623,
                "y": 459.101589495508
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04535.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.1126468555633,
                "width": 147.72633033863167,
                "x": 478.56254319281277,
                "y": 429.02557014512786
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04359.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.3434692467174,
                "width": 154.80304077401524,
                "x": 470.60124395300625,
                "y": 433.4485141672426
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04343.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.9958534899793,
                "width": 82.26675881133379,
                "x": 104.3814789219074,
                "y": 457.3324118866621
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04245.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.61299239806499,
                "width": 166.3026952315135,
                "x": 461.75535590877683,
                "y": 436.10228058051143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04235.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.91637871458192,
                "width": 494.4851416724257,
                "x": 284.837595024188,
                "y": 146.84174153420872
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04177.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 263.24324324324334,
                "width": 648.2364864864865,
                "x": 352.08783783783787,
                "y": 551.7139639639639
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04170.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.18935729094676,
                "width": 184.87906012439527,
                "x": 456.44782308223915,
                "y": 430.79474775397375
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04161.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.07325501036632,
                "width": 75.19004837595025,
                "x": 539.5991706979959,
                "y": 354.72011057360055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04131.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.7643400138217,
                "width": 104.38147892190739,
                "x": 522.79198341396,
                "y": 352.9509329647547
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04110.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.57290946786458,
                "width": 72.53628196268141,
                "x": 549.3296475466483,
                "y": 353.8355217691776
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_04050.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.26468555632346,
                "width": 103.49689011748444,
                "x": 519.2536281962682,
                "y": 344.9896337249482
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03983.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.91983413959912,
                "width": 162.76434001382177,
                "x": 463.5245335176227,
                "y": 421.94885970974434
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03976.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.87975120939876,
                "width": 103.49689011748444,
                "x": 509.5231513476158,
                "y": 346.7588113337941
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03971.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.18728403593641,
                "width": 476.7933655839668,
                "x": 237.06979958534902,
                "y": 192.84035936420182
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03962.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.68901174844501,
                "width": 179.5715272978577,
                "x": 453.7940566689703,
                "y": 418.41050449205255
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03791.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 266.53378378378386,
                "width": 545.1328828828829,
                "x": 365.25,
                "y": 542.9391891891892
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03770.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.34346924671729,
                "width": 168.95646164478228,
                "x": 467.9474775397374,
                "y": 436.10228058051143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03712.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.41603317208018,
                "width": 549.3296475466482,
                "x": 305.1831375259157,
                "y": 160.99516240497582
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03525.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.80165860400828,
                "width": 548.4450587422253,
                "x": 229.10850034554252,
                "y": 172.4948168624741
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03521.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 241.49274360746372,
                "width": 650.172771250864,
                "x": 395.411195577056,
                "y": 155.68762957843816
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03507.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.64754664823775,
                "width": 526.3303386316518,
                "x": 208.7629578438148,
                "y": 168.9564616447823
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03385.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.84174153420872,
                "width": 80.49758120248794,
                "x": 543.1375259156877,
                "y": 344.10504492052524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03353.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 273.1148648648649,
                "width": 427.7702702702702,
                "x": 112.97522522522523,
                "y": 540.7454954954954
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03351.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 334.53828828828824,
                "width": 506.7432432432432,
                "x": 1.0968468468468469,
                "y": 479.3220720720721
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03305.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.42017968210092,
                "width": 156.57221838286114,
                "x": 468.83206634416035,
                "y": 424.6026261230132
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03241.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.7072508168593,
                "width": 65.4064454756666,
                "x": 557.9570246699724,
                "y": 336.3760053034283
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03170.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.89121338912128,
                "width": 64.26778242677824,
                "x": 124.07252440725244,
                "y": 468.6192468619247
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03168.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.1485832757429,
                "width": 504.2156185210781,
                "x": 222.03178991015895,
                "y": 203.45542501727715
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03148.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.12322362315967,
                "width": 88.76097237431532,
                "x": 529.9241386395134,
                "y": 356.6289068610883
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03131.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.98465829846583,
                "width": 586.4435146443515,
                "x": 390.0697350069735,
                "y": 210.65550906555092
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03117.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 353.18468468468467,
                "width": 536.3581081081081,
                "x": -4.387387387387387,
                "y": 469.45045045045043
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_03057.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 325.76351351351354,
                "width": 510.0337837837838,
                "x": 0.0,
                "y": 487.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02987.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 95.53559087767798,
                "x": 159.22598479612992,
                "y": 430.79474775397375
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02944.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.30476848652381,
                "width": 160.99516240497576,
                "x": 475.024187975121,
                "y": 429.02557014512786
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02867.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 88.45888044229446,
                "width": 164.53351762266755,
                "x": 470.60124395300625,
                "y": 433.4485141672426
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02790.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.03593642017972,
                "width": 158.34139599170692,
                "x": 476.7933655839669,
                "y": 436.10228058051143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02744.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 101.72771250863866,
                "x": 530.7532826537664,
                "y": 352.06634416033177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02732.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.3434692467174,
                "width": 160.11057360055293,
                "x": 473.2550103662751,
                "y": 435.2176917760885
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02718.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.84174153420872,
                "width": 66.34416033172081,
                "x": 118.53489979267451,
                "y": 462.6399447131997
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02624.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.759009009009,
                "width": 488.0968468468468,
                "x": 365.25,
                "y": 555.0045045045046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02558.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53282653766416,
                "width": 498.02349689011754,
                "x": 231.76226675881134,
                "y": 201.68624740843126
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02557.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.53420870767104,
                "width": 100.8431237042156,
                "x": 541.3683483068418,
                "y": 344.9896337249482
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02478.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.418797512094,
                "width": 95.53559087767803,
                "x": 529.8686938493435,
                "y": 344.10504492052524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02469.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.80511402902562,
                "width": 171.61022805805118,
                "x": 460.8707671043539,
                "y": 432.56392536281965
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02348.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.2646855563234,
                "width": 94.65100207325509,
                "x": 537.82999308915,
                "y": 350.2971665514859
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02288.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.68832066344163,
                "width": 78.72840359364204,
                "x": 548.4450587422253,
                "y": 354.72011057360055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02271.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.6869384934347,
                "width": 421.06427090532134,
                "x": 216.7242570836213,
                "y": 217.60884588804424
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02260.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.7882882882883,
                "width": 640.5585585585586,
                "x": 363.0563063063063,
                "y": 557.1981981981982
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02259.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.3800967519005,
                "width": 70.76710435383552,
                "x": 566.1368348306842,
                "y": 339.6821008984105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02224.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.20945945945937,
                "width": 568.1666666666667,
                "x": 357.5720720720721,
                "y": 571.4572072072073
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02176.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.99308914996547,
                "width": 530.7532826537664,
                "x": 398.9495507947478,
                "y": 169.84105044920526
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02169.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 295.05180180180184,
                "width": 495.77477477477476,
                "x": 54.84234234234234,
                "y": 526.4864864864865
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02114.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.65990990990997,
                "width": 708.563063063063,
                "x": 322.47297297297297,
                "y": 556.1013513513514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02095.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 242.4031531531532,
                "width": 677.8513513513514,
                "x": 299.43918918918916,
                "y": 562.6824324324324
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02094.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.38585415982527,
                "width": 70.74574714714959,
                "x": 560.6266755057138,
                "y": 343.49507419873896
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02088.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.139470013947,
                "width": 67.83821478382148,
                "x": 117.82426778242677,
                "y": 457.01534170153417
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02087.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.84243261921216,
                "width": 89.34346924671735,
                "x": 167.18728403593644,
                "y": 444.94816862474084
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_02080.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.8797512093988,
                "width": 505.98479612992406,
                "x": 233.53144436765723,
                "y": 204.34001382170007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01986.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.61161022805805,
                "width": 81.38217000691085,
                "x": 168.9564616447823,
                "y": 446.71734623358674
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01942.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.07049067035246,
                "width": 507.75397373876984,
                "x": 235.30062197650312,
                "y": 176.9177608845888
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01916.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.91776088458883,
                "width": 511.29232895646163,
                "x": 231.76226675881134,
                "y": 204.34001382170007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01881.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.95853489979265,
                "width": 199.91706979958536,
                "x": 412.2183828610919,
                "y": 436.10228058051143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01820.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.3420870767104,
                "width": 48.65238424326196,
                "x": 579.4056668970284,
                "y": 348.52798894264
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01795.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.72633033863167,
                "width": 55.72909467864554,
                "x": 570.5597788527989,
                "y": 357.3738769868694
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01780.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.22667588113336,
                "width": 76.95922598479613,
                "x": 112.3427781617139,
                "y": 469.7166551485833
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01759.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 325.76351351351354,
                "width": 506.7432432432433,
                "x": -1.0968468468468469,
                "y": 484.8063063063063
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01572.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.3434692467174,
                "width": 155.6876295784382,
                "x": 472.37042156185214,
                "y": 432.56392536281965
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01546.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 244.5968468468468,
                "width": 650.4301801801803,
                "x": 355.3783783783784,
                "y": 567.0698198198198
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01524.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.07256392536283,
                "width": 102.6123013130615,
                "x": 521.907394609537,
                "y": 361.7968210089841
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01432.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.03455425017273,
                "width": 121.18866620594338,
                "x": 508.63856254319285,
                "y": 350.2971665514859
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01406.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 251.17792792792784,
                "width": 526.4864864864865,
                "x": 342.2162162162162,
                "y": 555.0045045045046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01342.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 104.38147892190733,
                "width": 168.0718728403594,
                "x": 458.21700069108505,
                "y": 421.0642709053214
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01324.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.9527027027027,
                "width": 492.4842342342343,
                "x": 331.2477477477477,
                "y": 559.3918918918919
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01307.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 332.3445945945946,
                "width": 497.9684684684685,
                "x": 2.1936936936936937,
                "y": 489.1936936936937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01298.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.2646855563234,
                "width": 100.84312370421571,
                "x": 526.3303386316517,
                "y": 352.06634416033177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01182.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.61091914305462,
                "width": 84.92052522460267,
                "x": 540.4837595024188,
                "y": 353.8355217691776
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01161.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 253.37162162162167,
                "width": 683.3355855855857,
                "x": 343.31306306306305,
                "y": 559.3918918918919
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_01061.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.2646855563234,
                "width": 75.19004837595024,
                "x": 114.99654457498274,
                "y": 459.98617829993094
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00903.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.95853489979265,
                "width": 168.0718728403594,
                "x": 461.75535590877683,
                "y": 426.371803731859
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00736.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.64892881824466,
                "width": 84.92052522460267,
                "x": 540.4837595024188,
                "y": 347.64340013821703
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00703.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 254.46846846846847,
                "width": 648.2364864864865,
                "x": 361.9594594594595,
                "y": 556.1013513513514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00685.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.2653766413269,
                "width": 120.30407740152032,
                "x": 519.2536281962682,
                "y": 360.9122322045612
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00600.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.4581893572909,
                "width": 173.37940566689707,
                "x": 458.21700069108505,
                "y": 421.0642709053214
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00560.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.20945945945948,
                "width": 522.099099099099,
                "x": 355.3783783783784,
                "y": 567.0698198198198
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00510.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.30338631651694,
                "width": 96.42017968210087,
                "x": 475.9087767795439,
                "y": 365.3351762266759
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00478.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 284.837595024188,
                "width": 549.3296475466483,
                "x": 362.6814098134071,
                "y": 131.80373185901865
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00427.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.18866620594338,
                "width": 76.95922598479615,
                "x": 539.5991706979959,
                "y": 335.2591568762958
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00409.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.40090090090087,
                "width": 647.1396396396397,
                "x": 366.34684684684686,
                "y": 558.2950450450451
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00391.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 330.1509009009009,
                "width": 511.13063063063066,
                "x": -2.1936936936936937,
                "y": 471.64414414414415
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00365.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 219.36936936936934,
                "width": 714.0472972972973,
                "x": 330.1509009009009,
                "y": 547.3265765765766
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00265.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 199.03248099516242,
                "width": 545.7912923289565,
                "x": 216.7242570836213,
                "y": 184.87906012439532
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00247.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.98198198198202,
                "width": 684.4324324324324,
                "x": 350.990990990991,
                "y": 551.7139639639639
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00245.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.76434001382177,
                "width": 129.14996544574979,
                "x": 468.83206634416035,
                "y": 357.3738769868694
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00235.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.95853489979271,
                "width": 165.41810642709055,
                "x": 461.75535590877683,
                "y": 421.94885970974434
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00096.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.49689011748444,
                "width": 191.0711817553559,
                "x": 450.2557014512785,
                "y": 427.25639253628196
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00072.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.72771250863849,
                "width": 169.84105044920528,
                "x": 456.44782308223915,
                "y": 423.71803731859023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/SHARK/img_00033.jpg"
    }
]

# %%
[
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.0,
                "width": 795.0,
                "x": 363.0,
                "y": 492.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07891.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 323.0,
                "width": 371.0,
                "x": 711.0,
                "y": 479.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07782.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 321.0,
                "width": 312.0,
                "x": 360.0,
                "y": 316.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07761.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 306.0,
                "width": 499.0,
                "x": 499.0,
                "y": 464.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07714.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 304.0,
                "width": 396.0,
                "x": 497.0,
                "y": 436.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07648.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 354.0,
                "width": 351.0,
                "x": 441.0,
                "y": 391.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07633.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 278.0,
                "width": 861.0,
                "x": 331.0,
                "y": 478.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07610.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 282.0,
                "width": 300.0,
                "x": 473.0,
                "y": 295.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07602.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 266.0,
                "width": 162.0,
                "x": 321.0,
                "y": 406.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07595.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.0,
                "width": 266.0,
                "x": 418.0,
                "y": 385.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07562.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 314.0,
                "width": 240.0,
                "x": 406.0,
                "y": 361.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07431.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 345.0,
                "width": 258.0,
                "x": 447.0,
                "y": 290.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07429.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 221.0,
                "width": 353.0,
                "x": 342.0,
                "y": 379.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07388.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 351.0,
                "width": 422.0,
                "x": 410.0,
                "y": 382.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07344.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.0,
                "width": 279.0,
                "x": 428.0,
                "y": 373.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07341.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 336.0,
                "width": 477.0,
                "x": 426.0,
                "y": 463.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07338.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.0,
                "width": 415.0,
                "x": 571.0,
                "y": 451.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07261.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 319.0,
                "width": 464.0,
                "x": 471.0,
                "y": 478.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07250.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 245.0,
                "width": 371.0,
                "x": 620.0,
                "y": 451.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07233.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.0,
                "width": 93.0,
                "x": 491.0,
                "y": 180.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07166.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 328.0,
                "width": 402.0,
                "x": 558.0,
                "y": 449.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07116.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 328.0,
                "width": 255.0,
                "x": 395.0,
                "y": 353.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07061.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 274.0,
                "width": 347.0,
                "x": 596.0,
                "y": 410.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07038.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 253.0,
                "width": 275.0,
                "x": 270.0,
                "y": 347.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06835.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 329.0,
                "width": 451.0,
                "x": 449.0,
                "y": 476.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06805.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 278.0,
                "width": 180.0,
                "x": 395.0,
                "y": 299.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06782.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 327.0,
                "width": 469.0,
                "x": 433.0,
                "y": 474.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06765.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.0,
                "width": 84.0,
                "x": 480.0,
                "y": 203.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06754.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 324.0,
                "width": 465.0,
                "x": 439.0,
                "y": 472.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06724.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 339.0,
                "width": 325.0,
                "x": 380.0,
                "y": 355.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06672.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.0,
                "width": 88.0,
                "x": 490.0,
                "y": 165.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06660.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 349.0,
                "width": 369.0,
                "x": 566.0,
                "y": 454.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06650.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 300.0,
                "width": 377.0,
                "x": 385.0,
                "y": 377.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06635.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 314.0,
                "width": 423.0,
                "x": 520.0,
                "y": 474.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06599.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 342.0,
                "width": 399.0,
                "x": 547.0,
                "y": 453.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06434.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 318.0,
                "width": 346.0,
                "x": 377.0,
                "y": 387.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06404.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 269.0,
                "width": 310.0,
                "x": 669.0,
                "y": 514.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06085.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 333.0,
                "width": 380.0,
                "x": 559.0,
                "y": 460.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06079.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 285.0,
                "width": 312.0,
                "x": 508.0,
                "y": 323.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05787.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 367.0,
                "width": 356.0,
                "x": 421.0,
                "y": 390.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05729.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 317.0,
                "width": 367.0,
                "x": 331.0,
                "y": 372.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05695.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 287.0,
                "width": 249.0,
                "x": 404.0,
                "y": 366.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05624.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 338.0,
                "width": 210.0,
                "x": 408.0,
                "y": 294.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05592.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 314.0,
                "width": 253.0,
                "x": 286.0,
                "y": 282.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05478.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.0,
                "width": 341.0,
                "x": 487.0,
                "y": 417.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05451.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 266.0,
                "width": 354.0,
                "x": 452.0,
                "y": 358.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05407.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.0,
                "width": 382.0,
                "x": 426.0,
                "y": 433.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05370.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 352.0,
                "width": 228.0,
                "x": 476.0,
                "y": 372.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05307.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 323.0,
                "width": 508.0,
                "x": 436.0,
                "y": 473.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05184.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 318.0,
                "width": 196.0,
                "x": 367.0,
                "y": 295.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05174.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.0,
                "width": 406.0,
                "x": 433.0,
                "y": 454.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05170.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 356.0,
                "width": 287.0,
                "x": 444.0,
                "y": 387.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05048.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 285.0,
                "width": 411.0,
                "x": 473.0,
                "y": 394.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05014.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 335.0,
                "width": 533.0,
                "x": 403.0,
                "y": 462.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04908.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.0,
                "width": 192.0,
                "x": 450.0,
                "y": 139.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04765.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 331.0,
                "width": 294.0,
                "x": 728.0,
                "y": 482.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04694.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.0,
                "width": 289.0,
                "x": 471.0,
                "y": 388.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04681.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.0,
                "width": 168.0,
                "x": 375.0,
                "y": 282.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04632.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 283.0,
                "width": 249.0,
                "x": 505.0,
                "y": 367.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04394.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 297.0,
                "width": 171.0,
                "x": 316.0,
                "y": 365.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04319.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 319.0,
                "width": 256.0,
                "x": 508.0,
                "y": 362.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04316.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.0,
                "width": 250.0,
                "x": 462.0,
                "y": 380.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04258.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 325.0,
                "width": 470.0,
                "x": 426.0,
                "y": 478.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04255.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 303.0,
                "width": 423.0,
                "x": 497.0,
                "y": 470.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04208.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 264.0,
                "width": 199.0,
                "x": 446.0,
                "y": 310.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04096.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 282.0,
                "width": 391.0,
                "x": 482.0,
                "y": 416.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04077.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 305.0,
                "width": 256.0,
                "x": 411.0,
                "y": 361.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03968.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 342.0,
                "width": 346.0,
                "x": 582.0,
                "y": 447.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03898.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 249.0,
                "width": 843.0,
                "x": 346.0,
                "y": 494.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03824.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 332.0,
                "width": 388.0,
                "x": 545.0,
                "y": 452.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03596.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 324.0,
                "width": 231.0,
                "x": 499.0,
                "y": 363.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03464.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.0,
                "width": 331.0,
                "x": 649.0,
                "y": 433.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03340.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 358.0,
                "width": 221.0,
                "x": 507.0,
                "y": 365.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03301.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 380.0,
                "width": 264.0,
                "x": 685.0,
                "y": 413.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03198.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 329.0,
                "width": 365.0,
                "x": 566.0,
                "y": 454.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03185.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 307.0,
                "width": 228.0,
                "x": 737.0,
                "y": 488.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02990.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 368.0,
                "width": 221.0,
                "x": 475.0,
                "y": 353.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02976.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 339.0,
                "width": 308.0,
                "x": 465.0,
                "y": 360.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02968.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.0,
                "width": 400.0,
                "x": 482.0,
                "y": 475.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02966.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 317.0,
                "width": 478.0,
                "x": 540.0,
                "y": 475.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02884.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 239.0,
                "width": 244.0,
                "x": 454.0,
                "y": 330.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02845.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 305.0,
                "width": 222.0,
                "x": 498.0,
                "y": 350.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02809.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.0,
                "width": 139.0,
                "x": 607.0,
                "y": 202.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02785.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 233.0,
                "width": 374.0,
                "x": 640.0,
                "y": 476.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02550.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.0,
                "width": 275.0,
                "x": 469.0,
                "y": 301.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02516.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 327.0,
                "width": 238.0,
                "x": 489.0,
                "y": 359.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02505.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 318.0,
                "width": 270.0,
                "x": 399.0,
                "y": 351.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02427.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.0,
                "width": 309.0,
                "x": 656.0,
                "y": 421.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02411.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 277.0,
                "width": 863.0,
                "x": 374.0,
                "y": 478.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02355.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 252.0,
                "width": 307.0,
                "x": 630.0,
                "y": 425.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02311.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 240.0,
                "width": 378.0,
                "x": 356.0,
                "y": 374.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02275.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 246.0,
                "width": 332.0,
                "x": 662.0,
                "y": 430.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02262.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 349.0,
                "width": 244.0,
                "x": 469.0,
                "y": 362.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02258.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 268.0,
                "width": 874.0,
                "x": 339.0,
                "y": 478.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02255.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 291.0,
                "width": 331.0,
                "x": 289.0,
                "y": 356.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02225.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 372.0,
                "width": 345.0,
                "x": 429.0,
                "y": 373.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02218.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.0,
                "width": 116.0,
                "x": 496.0,
                "y": 137.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02121.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 299.0,
                "width": 150.0,
                "x": 333.0,
                "y": 371.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02113.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 304.0,
                "width": 321.0,
                "x": 606.0,
                "y": 499.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02055.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.0,
                "width": 243.0,
                "x": 574.0,
                "y": 461.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02038.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.0,
                "width": 335.0,
                "x": 495.0,
                "y": 369.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01974.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 202.0,
                "width": 349.0,
                "x": 572.0,
                "y": 177.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01959.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 319.0,
                "width": 476.0,
                "x": 445.0,
                "y": 483.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01938.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 258.0210141139973,
                "width": 189.33486452346563,
                "x": 304.01087079635334,
                "y": 305.8026833943672
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01854.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 295.0,
                "width": 291.0000000000001,
                "x": 658.0000000000001,
                "y": 431.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01848.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 298.0,
                "width": 374.0000000000001,
                "x": 433.0000000000001,
                "y": 405.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01840.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 309.00000000000006,
                "width": 359.0,
                "x": 391.0000000000001,
                "y": 377.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01835.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 317.00000000000006,
                "width": 267.0,
                "x": 389.0000000000001,
                "y": 349.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01808.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 306.0,
                "width": 285.0,
                "x": 480.0000000000001,
                "y": 400.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01783.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 334.0000000000001,
                "width": 455.0000000000001,
                "x": 440.0000000000001,
                "y": 458.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01721.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 273.0,
                "width": 482.0000000000001,
                "x": 541.0000000000001,
                "y": 473.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01718.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.00000000000006,
                "width": 405.00000000000006,
                "x": 299.00000000000006,
                "y": 367.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01712.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 370.0000000000001,
                "width": 345.0000000000001,
                "x": 635.0000000000001,
                "y": 413.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01658.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 327.0000000000001,
                "width": 350.0000000000001,
                "x": 596.0000000000001,
                "y": 503.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01535.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 296.0,
                "width": 490.0000000000001,
                "x": 408.0000000000001,
                "y": 405.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01429.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.00000000000006,
                "width": 185.00000000000006,
                "x": 317.00000000000006,
                "y": 281.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01346.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 327.0000000000001,
                "width": 495.0000000000001,
                "x": 459.0000000000001,
                "y": 475.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01301.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.0,
                "width": 356.0000000000001,
                "x": 651.0000000000001,
                "y": 458.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01270.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 258.0,
                "width": 348.0000000000001,
                "x": 649.0000000000001,
                "y": 449.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01235.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 318.0,
                "width": 430.0000000000001,
                "x": 446.0000000000001,
                "y": 398.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01174.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 275.0000000000001,
                "width": 332.0000000000001,
                "x": 664.0000000000001,
                "y": 495.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01156.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.00000000000006,
                "width": 289.0000000000001,
                "x": 543.0000000000001,
                "y": 315.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01087.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 296.00000000000006,
                "width": 245.0,
                "x": 500.0000000000001,
                "y": 363.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01076.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.0000000000001,
                "width": 553.0000000000001,
                "x": 502.0000000000001,
                "y": 471.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01064.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 264.0,
                "width": 870.0000000000002,
                "x": 349.00000000000006,
                "y": 491.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00968.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 311.0,
                "width": 362.0000000000001,
                "x": 724.0000000000001,
                "y": 453.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00803.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 317.0000000000001,
                "width": 485.0000000000001,
                "x": 428.0000000000001,
                "y": 474.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00783.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 307.0,
                "width": 409.0000000000001,
                "x": 441.0000000000001,
                "y": 425.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00680.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 311.0,
                "width": 355.0000000000001,
                "x": 625.0000000000001,
                "y": 403.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00647.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 362.0000000000001,
                "width": 510.0000000000001,
                "x": 633.0000000000001,
                "y": 468.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00506.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 249.0,
                "width": 402.0000000000001,
                "x": 473.0000000000001,
                "y": 393.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00404.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 358.00000000000006,
                "width": 210.0,
                "x": 495.0000000000001,
                "y": 369.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00395.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 365.0,
                "width": 342.0,
                "x": 412.0000000000001,
                "y": 386.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00362.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 312.0000000000001,
                "width": 428.0000000000001,
                "x": 514.0000000000001,
                "y": 457.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00298.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 316.00000000000006,
                "width": 266.00000000000006,
                "x": 383.00000000000006,
                "y": 354.00000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00253.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 355.86990000000014,
                "width": 218.6910000000001,
                "x": 485.0964000000002,
                "y": 369.78660000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00238.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.04800000000006,
                "width": 190.85760000000005,
                "x": 439.3701000000002,
                "y": 137.17890000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00047.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.86950000000007,
                "width": 248.51250000000016,
                "x": 334.00080000000014,
                "y": 290.26260000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00014.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.0000000000001,
                "width": 510.00000000000017,
                "x": 112.00000000000006,
                "y": 30.000000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07911.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.00000000000006,
                "width": 349.00000000000017,
                "x": 100.00000000000004,
                "y": 351.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07901.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.00000000000006,
                "width": 495.0000000000002,
                "x": 479.0000000000002,
                "y": 431.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07828.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.00000000000003,
                "width": 201.0,
                "x": 981.0000000000005,
                "y": 56.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07759.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 395.00000000000017,
                "width": 559.0000000000002,
                "x": 529.0000000000002,
                "y": 93.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07752.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00000000000004,
                "width": 238.00000000000006,
                "x": 373.00000000000017,
                "y": 36.000000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07747.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.75000000000006,
                "width": 263.67000000000013,
                "x": 373.65000000000015,
                "y": 111.39000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07742.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.1900000000001,
                "width": 452.6100000000002,
                "x": -2.820000000000001,
                "y": 274.9500000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07731.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.30000000000007,
                "width": 468.12000000000035,
                "x": 669.7500000000002,
                "y": 98.70000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07706.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 305.97000000000014,
                "width": 449.7900000000002,
                "x": 12.690000000000005,
                "y": 272.1300000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07644.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 249.57000000000016,
                "width": 451.20000000000016,
                "x": 9.870000000000005,
                "y": 282.0000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07624.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 273.5400000000002,
                "width": 583.7400000000002,
                "x": 90.24000000000004,
                "y": 253.8000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07609.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 305.97000000000014,
                "width": 523.1100000000004,
                "x": 693.7200000000003,
                "y": 115.62000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07588.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.99000000000007,
                "width": 369.42000000000013,
                "x": 338.40000000000015,
                "y": 294.6900000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07571.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.6949418452994,
                "width": 297.2796281364813,
                "x": 736.0407790121378,
                "y": 310.7540588735456
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07555.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 307.00000000000017,
                "width": 436.0000000000002,
                "x": 481.0000000000002,
                "y": 439.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07535.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 230.4964539007093,
                "width": 198.58156028368796,
                "x": 743.971631205674,
                "y": 278.7234042553192
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07513.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.16848608209983,
                "width": 402.5486182697962,
                "x": 606.3493831678938,
                "y": 455.60418929698693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07510.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.22051110823514,
                "width": 223.17025908262758,
                "x": 697.301790643078,
                "y": 304.85899542607996
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07462.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 276.2258301098183,
                "width": 464.0257085076521,
                "x": 548.240900614304,
                "y": 74.95152097492021
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07400.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 282.9630454783504,
                "width": 333.49216074234164,
                "x": 315.8069703999447,
                "y": 101.05823052798232
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07395.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 329.281401137009,
                "width": 492.6588738239138,
                "x": 87.58379979091801,
                "y": 325.91279345274296
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07383.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 419.39165669112657,
                "width": 574.3476101673662,
                "x": 269.48861474128614,
                "y": 100.21607860691579
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07369.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.27342263463424,
                "width": 292.22671661008224,
                "x": 95.16316708051667,
                "y": 323.3863376895434
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07340.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 321.70203384741035,
                "width": 784.0434385129295,
                "x": 309.06975503141257,
                "y": 210.5379802666298
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07309.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.1400000000001,
                "width": 542.8500000000001,
                "x": 293.28000000000014,
                "y": 544.2600000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07290.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 252.3900000000001,
                "width": 389.1600000000001,
                "x": 682.4400000000003,
                "y": 490.6800000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07287.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 291.8700000000002,
                "width": 174.84000000000015,
                "x": 792.4200000000003,
                "y": 373.65000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07275.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.07000000000005,
                "width": 225.60000000000002,
                "x": 745.8900000000003,
                "y": 325.71000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07273.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 293.28000000000014,
                "width": 699.3600000000004,
                "x": 610.5300000000002,
                "y": 212.91000000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07217.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.91000000000008,
                "width": 242.5200000000001,
                "x": 187.5300000000001,
                "y": 286.23000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07208.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 241.11000000000013,
                "width": 332.7600000000001,
                "x": 589.3800000000002,
                "y": 406.08000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07130.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 163.56000000000006,
                "width": 360.96000000000015,
                "x": 84.60000000000004,
                "y": 297.5100000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07119.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.48000000000008,
                "width": 352.5000000000001,
                "x": 90.24000000000004,
                "y": 332.76000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07109.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.83000000000007,
                "width": 540.0300000000002,
                "x": 320.0700000000001,
                "y": 47.94000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07107.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.0800000000001,
                "width": 180.48000000000002,
                "x": 795.2400000000004,
                "y": 382.1100000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07067.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 243.93000000000012,
                "width": 554.1300000000001,
                "x": 135.36000000000007,
                "y": 235.47000000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07055.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.37481318611314,
                "width": 111.16405358078055,
                "x": 806.7815403817254,
                "y": 24.42240571092906
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07025.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 245.06620903035713,
                "width": 154.11380155517304,
                "x": 792.4649577235946,
                "y": 396.6535548223306
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07024.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.382791688488,
                "width": 480.02659500791594,
                "x": 122.95418047571181,
                "y": 277.0679820308848
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07017.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 107.79544589651442,
                "width": 133.90215544957653,
                "x": 564.241787114568,
                "y": 434.5503912703239
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06971.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.27342263463424,
                "width": 181.06266302930166,
                "x": 31.159621079461214,
                "y": 258.5406397674214
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06920.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.4868417407585,
                "width": 394.127099059131,
                "x": 25.26455763199558,
                "y": 280.4365897151509
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06919.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.33165316261653,
                "width": 477.50013924471637,
                "x": 715.8291329065414,
                "y": 126.32278815997789
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06858.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.6958283455633,
                "width": 440.44545471778963,
                "x": 232.43393021435932,
                "y": 311.59621079461215
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06841.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.84924392317748,
                "width": 369.704693348202,
                "x": 157.4824092394391,
                "y": 343.59798379513984
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06824.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.1146880554369,
                "width": 301.49038774181395,
                "x": 104.42683821224838,
                "y": 341.0715280319403
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06822.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 274.54152626768524,
                "width": 194.53709376636596,
                "x": 795.8335654078606,
                "y": 372.2311491114015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06819.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 219.8016513983615,
                "width": 277.91013395195137,
                "x": 28.633165316261653,
                "y": 287.1738050836831
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06771.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.33165316261653,
                "width": 725.092804038273,
                "x": 526.3449506665745,
                "y": 493.50102574498027
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06769.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 213.06443602982938,
                "width": 553.2938121407032,
                "x": 109.4797497386475,
                "y": 250.11912055675623
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06763.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.6411438186364,
                "width": 357.07241453220416,
                "x": 122.11202855464529,
                "y": 311.59621079461215
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06729.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00620550184708,
                "width": 248.43481671462314,
                "x": 349.4930472426055,
                "y": 42.94974797439248
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06666.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 261.067095530621,
                "width": 292.22671661008224,
                "x": 603.8229274046943,
                "y": 378.12621255886717
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06592.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.53620726610205,
                "width": 321.70203384741046,
                "x": 726.7771078804061,
                "y": 324.2284896106099
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06586.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.90481495036818,
                "width": 396.65355482233053,
                "x": 150.74519387090695,
                "y": 314.12266655781167
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06576.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 396.65355482233053,
                "width": 585.295585141231,
                "x": 440.4454547177896,
                "y": 74.95152097492021
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06567.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 309.91190695247906,
                "width": 437.91899895459005,
                "x": 491.81672190284723,
                "y": 430.3396316649913
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06550.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 281.27874163621743,
                "width": 454.7620373759204,
                "x": 554.1359640617696,
                "y": 50.52911526399116
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06535.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 400.02216250659666,
                "width": 592.8749524308296,
                "x": 452.23558161272086,
                "y": 71.58291329065413
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06502.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 336.8607684266077,
                "width": 258.54063976742145,
                "x": 164.21962460797127,
                "y": 89.26810363305104
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06500.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.3281071615611,
                "width": 506.9754564820446,
                "x": 98.53177476478275,
                "y": 346.1244395583394
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06487.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 178.53620726610205,
                "width": 244.22405710929058,
                "x": 31.159621079461214,
                "y": 325.91279345274296
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06481.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.11912055675623,
                "width": 435.39254319139036,
                "x": 759.6210328020004,
                "y": 90.11025555411756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06452.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.22051110823514,
                "width": 298.1217800575479,
                "x": 739.4093866964039,
                "y": 312.43836271567864
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06428.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.167599581836,
                "width": 283.805197399417,
                "x": 203.80076489809767,
                "y": 309.9119069524791
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06418.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 344.4401357162064,
                "width": 346.1244395583394,
                "x": 48.002659500791594,
                "y": 263.59355129382055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06417.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.58468629118187,
                "width": 256.85633592528836,
                "x": 430.3396316649913,
                "y": 57.26633063252331
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06415.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 227.38101868796025,
                "width": 319.17557808421077,
                "x": 608.0336870100269,
                "y": 405.07507403299576
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06395.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.69848784635485,
                "width": 498.5539372713794,
                "x": 122.11202855464529,
                "y": 349.4930472426055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06374.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.90481495036818,
                "width": 485.0795065343151,
                "x": 141.48152273917523,
                "y": 264.43570321488704
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06339.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.0617765290378,
                "width": 82.53088826451892,
                "x": 814.3609076713241,
                "y": 118.74342087037921
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06323.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 281.27874163621743,
                "width": 480.86874692898243,
                "x": 528.0292545087076,
                "y": 53.89772294825723
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06304.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.11912055675623,
                "width": 167.5882322922373,
                "x": 800.0443250131933,
                "y": 389.0741875327319
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06289.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 181.90481495036818,
                "width": 333.4921607423416,
                "x": 236.6446898196919,
                "y": 12.63227881599779
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06271.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 269.48861474128614,
                "width": 301.49038774181383,
                "x": 302.33253966288044,
                "y": 312.43836271567864
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06234.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.74608037117082,
                "width": 309.91190695247906,
                "x": 312.43836271567864,
                "y": 330.1235530580756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06226.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 238.67427594946219,
                "width": 733.8343409789435,
                "x": 558.0940780907823,
                "y": 514.159012368742
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06198.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 339.60618368928453,
                "width": 605.591446438934,
                "x": 74.8083551483389,
                "y": 320.60723635002387
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06196.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 296.8585521759481,
                "width": 377.60407836780587,
                "x": 584.2176306822657,
                "y": 374.0417757416945
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06171.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.54861803650016,
                "width": 569.9684201778202,
                "x": 298.0459863846518,
                "y": 33.24815784370618
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06156.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 340.7936178979884,
                "width": 401.3527625418817,
                "x": 613.9034858998606,
                "y": 421.5391440898462
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06154.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.36328914927503,
                "width": 296.8585521759479,
                "x": 977.258353763221,
                "y": 662.588288456716
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06152.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.36328914927498,
                "width": 543.8448675863367,
                "x": 43.93506572204031,
                "y": 276.6721706279836
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06145.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 260.04809170613044,
                "width": 489.2228939859623,
                "x": 539.0951307515217,
                "y": 84.30782881796924
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06138.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.1726969583532,
                "width": 483.2857229424434,
                "x": 752.8332883182042,
                "y": 67.68374989611615
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06132.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.18006558352852,
                "width": 356.2302626111376,
                "x": 142.49210504445506,
                "y": 331.294144228358
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06094.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 277.8596048366874,
                "width": 195.92664443612568,
                "x": 793.2060514141332,
                "y": 371.6669073242869
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06092.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.92664443612568,
                "width": 440.5380914291069,
                "x": 461.91190718577514,
                "y": 431.03861775947655
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06072.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 288.54651271502144,
                "width": 346.7307889415073,
                "x": 586.5924990996733,
                "y": 416.78940725503105
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06054.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.55072335797877,
                "width": 454.7873019335524,
                "x": -2.3748684174075843,
                "y": 290.9213811324291
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06053.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.05124968834843,
                "width": 412.0396704202159,
                "x": 230.36223648853567,
                "y": 277.85960483668737
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06027.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 302.795723219467,
                "width": 503.4721044904079,
                "x": 75.9957893570427,
                "y": 174.55282867945743
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05975.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 398.9778941244741,
                "width": 767.0824988226498,
                "x": 292.10881534113287,
                "y": 198.3015128535333
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05965.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 229.17480227983185,
                "width": 511.78414395133444,
                "x": 123.49315770519438,
                "y": 353.85539419373004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05913.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.4857890800191,
                "width": 140.11723662704753,
                "x": 820.5170382143203,
                "y": 383.5412494113249
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05892.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.17269695835324,
                "width": 306.35802584557837,
                "x": 588.9673675170809,
                "y": 384.7286836200287
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05837.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 327.7318416022466,
                "width": 566.4061175517088,
                "x": 211.363289149275,
                "y": 87.87013144408061
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05781.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.48789440149775,
                "width": 578.2804596387468,
                "x": 286.1716442976139,
                "y": 49.87223676555927
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05774.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 219.67532861020152,
                "width": 314.67006530650497,
                "x": 368.10460469817554,
                "y": 296.85855217594803
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05737.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 385.91611782873247,
                "width": 629.3401306130099,
                "x": 429.85118355077276,
                "y": 85.49526302667303
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05676.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 302.795723219467,
                "width": 496.34749923818504,
                "x": 528.4082228731875,
                "y": 53.43453939167065
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05656.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 244.61144699298114,
                "width": 555.7192096733747,
                "x": 132.99263137482473,
                "y": 276.6721706279836
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05633.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.98526274964945,
                "width": 191.17690760131052,
                "x": 776.5819724922801,
                "y": 383.5412494113249
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05632.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.73758865248232,
                "width": 298.5815602836881,
                "x": 64.5390070921986,
                "y": 339.7163120567377
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05628.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 261.06709553062103,
                "width": 138.95506697597568,
                "x": 813.5187557502576,
                "y": 374.75760487460104
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05617.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 359.59887029540374,
                "width": 662.7735618793506,
                "x": 427.8131759017918,
                "y": 103.58468629118187
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05574.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.63937081810872,
                "width": 296.4374762154148,
                "x": 342.75583187407335,
                "y": 98.53177476478275
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05506.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 263.5935512938205,
                "width": 246.75051287249016,
                "x": 4.210759605332596,
                "y": 259.38279168848794
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05460.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.00620550184705,
                "width": 250.96127247782272,
                "x": 367.1782375850024,
                "y": 32.001773000527734
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05417.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 222.3281071615611,
                "width": 559.1888755881689,
                "x": 271.1729185834192,
                "y": 526.3449506665745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05414.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.79461325337091,
                "width": 127.50250401942674,
                "x": 836.6028087653416,
                "y": 0.8471927177370547
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05400.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.00000000000017,
                "width": 230.0000000000001,
                "x": 515.0000000000003,
                "y": 3.0000000000000018
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05395.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 328.0000000000002,
                "width": 536.0000000000005,
                "x": 79.00000000000006,
                "y": 310.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05380.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 287.0000000000002,
                "width": 505.00000000000034,
                "x": 520.0000000000003,
                "y": 48.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05333.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 268.0000000000002,
                "width": 165.0000000000001,
                "x": 811.0000000000006,
                "y": 372.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05323.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.0000000000001,
                "width": 123.00000000000006,
                "x": 449.0000000000003,
                "y": 542.0000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05302.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.0000000000001,
                "width": 362.0000000000002,
                "x": 72.00000000000004,
                "y": 312.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05280.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.00000000000014,
                "width": 445.0000000000003,
                "x": 432.0000000000003,
                "y": 31.00000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05245.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.12549670539721,
                "width": 180.07142497862287,
                "x": 791.2076857300948,
                "y": 286.70590010562876
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05183.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.2983548713155,
                "width": 388.2909862461403,
                "x": 739.7715120224631,
                "y": 104.49421036593378
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05171.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 232.73710490594345,
                "width": 211.36328914927526,
                "x": 938.0730248759965,
                "y": 117.5559866616755
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05122.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.17269695835347,
                "width": 492.7851966120741,
                "x": 161.49105238371584,
                "y": 249.36118382779654
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05116.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 467.8490782292945,
                "width": 402.5401967505859,
                "x": 184.0523023490879,
                "y": 128.24289454000964
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05108.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.67848659241963,
                "width": 309.92032847168997,
                "x": 155.55388134019688,
                "y": 317.0449337239127
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05102.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.6732232887231,
                "width": 205.42611810575613,
                "x": 759.9578935704276,
                "y": 374.0417757416948
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05097.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.1790129227893,
                "width": 313.48263109780135,
                "x": 74.80835514833896,
                "y": 318.2323679326165
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05088.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 238.67427594946238,
                "width": 263.610394332242,
                "x": 486.84802556855516,
                "y": 30.87328942629862
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05066.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 292.10881534113304,
                "width": 388.29098624614033,
                "x": 10.686907878334138,
                "y": 283.79677588020655
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05060.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 223.23763123631312,
                "width": 527.2207886644841,
                "x": 338.418749480581,
                "y": 55.80940780907827
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05036.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.48789440149795,
                "width": 529.5956570818917,
                "x": 102.1193419485262,
                "y": 317.0449337239127
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05024.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.1716442976141,
                "width": 302.7957232194672,
                "x": 5.9371710435189655,
                "y": 284.98421008891034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04977.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80519716612102,
                "width": 262.4229601235383,
                "x": 402.54019675058584,
                "y": 21.373815756668275
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04947.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 276.67217062798375,
                "width": 176.92769709686513,
                "x": 784.8940119532072,
                "y": 378.79151257650994
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04942.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 302.79572321946716,
                "width": 460.7244729770716,
                "x": 540.2825649602258,
                "y": 450.03756509873756
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04933.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 284.98421008891034,
                "width": 393.04072308095544,
                "x": 630.5275648217141,
                "y": 452.41243351614514
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04918.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 400.16532833317825,
                "width": 596.091972769304,
                "x": 472.5988150641096,
                "y": 90.24499986148827
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04912.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 432.2260519681806,
                "width": 232.73710490594343,
                "x": 239.86171015816618,
                "y": 26.123552591483445
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04868.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 206.61355231445998,
                "width": 471.4113808554058,
                "x": 184.0523023490879,
                "y": 265.9852627496496
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04859.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.67638127094102,
                "width": 435.78835459429206,
                "x": 137.74236820963998,
                "y": 26.123552591483445
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04817.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 292.19858156028397,
                "width": 265.24822695035493,
                "x": 494.3262411347523,
                "y": 2.1276595744680877
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04801.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.28527928404353,
                "width": 472.14759006480233,
                "x": 359.9706803685549,
                "y": 55.2513137309875
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04768.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.37080216902274,
                "width": 535.7703149671514,
                "x": 98.78265182206856,
                "y": 318.1136245117462
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04759.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 244.44520620376295,
                "width": 592.6959109324114,
                "x": 10.04569340563409,
                "y": 585.9987819953219
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04756.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 277.93085088920986,
                "width": 205.93671481549893,
                "x": 778.541238936642,
                "y": 363.31924483709963
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04738.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 231.05094832958412,
                "width": 537.4445972014239,
                "x": 61.94844266807689,
                "y": 294.6736732319333
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04730.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 303.04508440329505,
                "width": 460.42761442489575,
                "x": 768.4955455310079,
                "y": 120.54832086760909
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04698.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 281.2794153577546,
                "width": 174.12535236432427,
                "x": 800.3069079821826,
                "y": 370.016373774189
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04646.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.98827214742198,
                "width": 319.7879067460186,
                "x": 177.47391683286892,
                "y": 328.1593179173803
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04627.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 319.78790674601856,
                "width": 554.1874195441474,
                "x": 58.5998781995322,
                "y": 318.1136245117462
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04626.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.3081259868606,
                "width": 443.6847920821724,
                "x": 215.98240822113294,
                "y": 257.83946407794167
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04591.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.4510701300519,
                "width": 251.1423351408523,
                "x": 729.9870541427439,
                "y": 323.13647121456324
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04573.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.2695035460995,
                "width": 516.3120567375894,
                "x": 426.9503546099296,
                "y": 568.7943262411355
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04558.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 328.5300000000004,
                "width": 556.9500000000007,
                "x": 528.7500000000007,
                "y": 174.84000000000023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04533.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.71000000000026,
                "width": 332.76000000000045,
                "x": 105.75000000000014,
                "y": 301.7400000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04488.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.32000000000028,
                "width": 217.14000000000033,
                "x": 721.920000000001,
                "y": 279.1800000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04473.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.94000000000028,
                "width": 372.2400000000005,
                "x": 135.36000000000018,
                "y": 290.4600000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04444.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 272.1300000000004,
                "width": 181.8900000000002,
                "x": 798.0600000000011,
                "y": 376.47000000000054
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04392.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 263.6700000000003,
                "width": 167.7900000000002,
                "x": 800.8800000000011,
                "y": 375.0600000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04381.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 277.7700000000004,
                "width": 266.49000000000035,
                "x": 509.0100000000007,
                "y": 397.6200000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04373.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.66000000000025,
                "width": 397.6200000000006,
                "x": 224.1900000000003,
                "y": 0.0
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04367.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.14000000000027,
                "width": 428.6400000000006,
                "x": 16.920000000000023,
                "y": 284.8200000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04364.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 425.82000000000056,
                "width": 697.950000000001,
                "x": 372.2400000000005,
                "y": 121.26000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04331.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 277.7700000000004,
                "width": 143.82000000000016,
                "x": 812.1600000000011,
                "y": 377.8800000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04302.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.45000000000027,
                "width": 241.11000000000035,
                "x": 679.6200000000009,
                "y": 290.4600000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04292.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.50000000000028,
                "width": 329.9400000000004,
                "x": 150.8700000000002,
                "y": 283.41000000000037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04280.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.43000000000023,
                "width": 249.5700000000004,
                "x": 300.3300000000004,
                "y": 329.94000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04273.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 322.89000000000044,
                "width": 490.68000000000063,
                "x": 672.570000000001,
                "y": 105.75000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04267.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.0600000000003,
                "width": 180.48000000000025,
                "x": 805.1100000000012,
                "y": 393.39000000000055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04241.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 408.90000000000055,
                "width": 618.9900000000009,
                "x": 496.3200000000007,
                "y": 69.09000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04236.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.48000000000025,
                "width": 296.1000000000004,
                "x": 93.06000000000013,
                "y": 332.76000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04217.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 301.74000000000046,
                "width": 417.3600000000006,
                "x": 754.350000000001,
                "y": 119.85000000000016
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04120.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 262.26000000000033,
                "width": 179.07000000000016,
                "x": 805.1100000000012,
                "y": 380.7000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04113.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.92000000000021,
                "width": 150.87000000000023,
                "x": 785.370000000001,
                "y": 38.07000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04097.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.73000000000036,
                "width": 411.7200000000006,
                "x": 604.8900000000008,
                "y": 442.7400000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04083.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.58000000000027,
                "width": 382.1100000000005,
                "x": 78.96000000000011,
                "y": 322.89000000000044
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04082.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 272.1300000000004,
                "width": 163.5600000000003,
                "x": 803.7000000000011,
                "y": 386.34000000000054
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04049.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 391.9800000000005,
                "width": 755.7600000000009,
                "x": 358.1400000000005,
                "y": 150.8700000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04041.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 243.93000000000035,
                "width": 534.3900000000008,
                "x": 345.45000000000044,
                "y": 42.300000000000054
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04021.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 260.8500000000003,
                "width": 184.71000000000026,
                "x": 786.7800000000011,
                "y": 377.8800000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03999.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.69000000000023,
                "width": 282.00000000000034,
                "x": 399.03000000000054,
                "y": 69.09000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03950.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.2200000000003,
                "width": 434.28000000000065,
                "x": 262.26000000000033,
                "y": 78.96000000000011
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03948.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 293.2800000000004,
                "width": 456.84000000000066,
                "x": 69.09000000000009,
                "y": 298.9200000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03947.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.4000000000002,
                "width": 407.4900000000006,
                "x": 102.93000000000013,
                "y": 317.25000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03938.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 345.4500000000005,
                "width": 454.02000000000055,
                "x": 720.510000000001,
                "y": 57.81000000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03921.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 314.4300000000005,
                "width": 669.7500000000009,
                "x": 248.16000000000034,
                "y": 600.6600000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03911.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 273.5400000000004,
                "width": 169.20000000000016,
                "x": 800.8800000000011,
                "y": 375.0600000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03856.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.62000000000035,
                "width": 162.1500000000002,
                "x": 803.7000000000011,
                "y": 390.5700000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03819.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 329.94000000000045,
                "width": 518.8800000000007,
                "x": 242.52000000000032,
                "y": 152.2800000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03787.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.61000000000018,
                "width": 338.4000000000005,
                "x": 71.9100000000001,
                "y": 324.30000000000047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03782.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.63000000000028,
                "width": 351.0900000000005,
                "x": 90.24000000000012,
                "y": 291.8700000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03756.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 284.8200000000004,
                "width": 167.7900000000002,
                "x": 791.0100000000011,
                "y": 360.9600000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03721.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 283.4100000000004,
                "width": 469.53000000000065,
                "x": 558.3600000000008,
                "y": 74.7300000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03710.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 246.75000000000034,
                "width": 748.7100000000011,
                "x": 52.17000000000007,
                "y": 607.7100000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03675.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.38000000000022,
                "width": 353.9100000000005,
                "x": 114.21000000000015,
                "y": 284.8200000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03668.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 267.9000000000003,
                "width": 155.10000000000014,
                "x": 806.5200000000011,
                "y": 375.0600000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03657.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 241.11000000000035,
                "width": 548.4900000000008,
                "x": 91.65000000000012,
                "y": 304.5600000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03622.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.95000000000022,
                "width": 270.7200000000004,
                "x": 359.55000000000047,
                "y": 102.93000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03607.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 212.9100000000003,
                "width": 492.09000000000066,
                "x": 353.9100000000005,
                "y": 47.94000000000007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03604.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.21000000000038,
                "width": 480.8100000000006,
                "x": 33.840000000000046,
                "y": 289.0500000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03585.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 258.0300000000003,
                "width": 583.7400000000008,
                "x": 23.970000000000034,
                "y": 602.0700000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03567.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 360.9600000000005,
                "width": 547.0800000000007,
                "x": 542.8500000000007,
                "y": 167.79000000000022
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03560.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 200.22000000000025,
                "width": 258.03000000000037,
                "x": 335.58000000000044,
                "y": 351.0900000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03541.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.21000000000035,
                "width": 459.66000000000054,
                "x": 554.1300000000008,
                "y": 67.68000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03540.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.71000000000026,
                "width": 283.41000000000037,
                "x": 16.920000000000023,
                "y": 235.4700000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03514.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.7300000000003,
                "width": 393.39000000000055,
                "x": 9.870000000000013,
                "y": 263.67000000000036
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03505.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 245.34000000000037,
                "width": 421.5900000000006,
                "x": 23.970000000000034,
                "y": 290.4600000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03485.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.82000000000016,
                "width": 129.72000000000025,
                "x": 690.9000000000009,
                "y": 282.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03477.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 300.3300000000004,
                "width": 362.37000000000046,
                "x": 280.5900000000004,
                "y": 70.5000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03460.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.1800000000004,
                "width": 468.1200000000007,
                "x": 541.4400000000007,
                "y": 71.9100000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03396.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.79000000000025,
                "width": 284.8200000000004,
                "x": 111.39000000000016,
                "y": 338.40000000000043
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03388.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 477.9900000000007,
                "width": 317.2500000000004,
                "x": 184.71000000000026,
                "y": 109.98000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03372.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.0200000000002,
                "width": 235.47000000000037,
                "x": 783.9600000000011,
                "y": 327.12000000000046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03325.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.4100000000002,
                "width": 352.5000000000005,
                "x": 78.96000000000011,
                "y": 303.15000000000043
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03313.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 221.3700000000003,
                "width": 222.7800000000003,
                "x": 733.200000000001,
                "y": 279.1800000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03278.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 290.4600000000003,
                "width": 322.89000000000044,
                "x": 606.3000000000009,
                "y": 414.5400000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03276.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 224.19000000000028,
                "width": 572.4600000000008,
                "x": 304.5600000000004,
                "y": 49.350000000000065
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03266.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 320.07000000000045,
                "width": 386.3400000000005,
                "x": 602.0700000000008,
                "y": 454.0200000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03242.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 210.09000000000026,
                "width": 262.26000000000033,
                "x": 693.7200000000009,
                "y": 274.9500000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03217.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 286.2300000000004,
                "width": 188.94000000000028,
                "x": 778.3200000000011,
                "y": 348.2700000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03211.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 322.8900000000005,
                "width": 492.0900000000006,
                "x": 507.6000000000007,
                "y": 439.9200000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03196.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 311.61000000000047,
                "width": 365.1900000000005,
                "x": 602.0700000000008,
                "y": 390.5700000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03189.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 308.7900000000004,
                "width": 571.0500000000008,
                "x": 47.94000000000007,
                "y": 231.24000000000032
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03160.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 287.6400000000004,
                "width": 218.5500000000003,
                "x": 757.170000000001,
                "y": 373.6500000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03157.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.08000000000018,
                "width": 262.2600000000004,
                "x": 363.7800000000005,
                "y": 23.970000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03136.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.51000000000022,
                "width": 291.8700000000004,
                "x": 156.51000000000022,
                "y": 325.71000000000043
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03127.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 184.7100000000002,
                "width": 401.8500000000006,
                "x": 493.5000000000007,
                "y": 438.5100000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03121.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.62000000000035,
                "width": 446.9700000000006,
                "x": 554.1300000000008,
                "y": 74.7300000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03101.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 194.58000000000027,
                "width": 212.9100000000003,
                "x": 737.430000000001,
                "y": 311.6100000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03100.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.6900000000004,
                "width": 310.2000000000004,
                "x": 342.63000000000045,
                "y": 56.40000000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03094.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 219.96000000000026,
                "width": 509.01000000000073,
                "x": 78.96000000000011,
                "y": 258.03000000000037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03086.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 352.5000000000005,
                "width": 541.4400000000007,
                "x": 532.9800000000007,
                "y": 173.43000000000023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03081.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.06000000000034,
                "width": 582.3300000000008,
                "x": 95.88000000000014,
                "y": 329.94000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03063.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.43000000000023,
                "width": 320.07000000000045,
                "x": 121.26000000000016,
                "y": 324.30000000000047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03062.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 232.65000000000032,
                "width": 265.0800000000004,
                "x": 1050.4500000000014,
                "y": 676.8000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03046.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.0800000000004,
                "width": 451.2000000000006,
                "x": 566.8200000000007,
                "y": 66.2700000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03035.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 291.87000000000046,
                "width": 322.89000000000044,
                "x": 423.00000000000057,
                "y": 423.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03015.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 152.2800000000002,
                "width": 342.63000000000045,
                "x": 101.52000000000014,
                "y": 341.2200000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03004.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 370.83000000000055,
                "width": 485.04000000000065,
                "x": 186.12000000000026,
                "y": 145.2300000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02986.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 327.12000000000046,
                "width": 747.300000000001,
                "x": 351.0900000000005,
                "y": 203.04000000000028
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02962.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 217.1400000000003,
                "width": 523.1100000000008,
                "x": 69.09000000000009,
                "y": 248.16000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02958.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.62000000000015,
                "width": 322.8900000000004,
                "x": 324.30000000000047,
                "y": 36.66000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02934.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 238.29000000000036,
                "width": 461.07000000000073,
                "x": 566.8200000000007,
                "y": 93.06000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02919.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 262.26000000000033,
                "width": 463.89000000000067,
                "x": 556.9500000000007,
                "y": 70.5000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02918.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.53000000000026,
                "width": 276.36000000000035,
                "x": 8.460000000000012,
                "y": 279.1800000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02917.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.87000000000023,
                "width": 290.4600000000004,
                "x": 74.7300000000001,
                "y": 283.41000000000037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02897.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 170.61000000000024,
                "width": 329.9400000000005,
                "x": 721.920000000001,
                "y": 327.12000000000046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02863.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 177.66000000000025,
                "width": 435.6900000000006,
                "x": 16.920000000000023,
                "y": 308.7900000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02853.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 272.13000000000034,
                "width": 452.6100000000007,
                "x": 575.2800000000008,
                "y": 70.5000000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02846.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.35000000000025,
                "width": 174.84000000000026,
                "x": 379.29000000000053,
                "y": 40.89000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02806.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 188.94000000000025,
                "width": 156.51000000000028,
                "x": 449.7900000000006,
                "y": -2.820000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02756.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.8700000000003,
                "width": 313.02000000000044,
                "x": 549.9000000000008,
                "y": 435.69000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02748.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.80000000000015,
                "width": 187.53000000000026,
                "x": 448.3800000000006,
                "y": 29.610000000000042
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02730.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.7300000000003,
                "width": 565.4100000000008,
                "x": 325.71000000000043,
                "y": 47.94000000000007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02727.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 145.2300000000002,
                "width": 183.30000000000027,
                "x": 8.460000000000012,
                "y": 280.5900000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02713.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 215.7300000000003,
                "width": 390.57000000000056,
                "x": -1.410000000000002,
                "y": 289.0500000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02712.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.6200000000003,
                "width": 184.71000000000015,
                "x": 520.2900000000008,
                "y": 400.44000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02707.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.21000000000038,
                "width": 507.60000000000076,
                "x": 117.03000000000016,
                "y": 365.1900000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02673.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 180.48000000000025,
                "width": 258.0300000000003,
                "x": 827.6700000000011,
                "y": 421.5900000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02652.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 225.60000000000025,
                "width": 313.02000000000044,
                "x": 961.6200000000013,
                "y": 662.700000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02642.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 191.76000000000028,
                "width": 415.9500000000006,
                "x": 43.71000000000006,
                "y": 324.30000000000047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02626.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 342.63000000000045,
                "width": 737.430000000001,
                "x": 406.08000000000055,
                "y": 94.47000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02597.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.4200000000003,
                "width": 525.9300000000007,
                "x": 52.17000000000007,
                "y": 235.4700000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02592.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.3300000000002,
                "width": 289.0500000000004,
                "x": 404.6700000000005,
                "y": 94.47000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02585.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.92000000000024,
                "width": 338.4000000000005,
                "x": 107.16000000000014,
                "y": 311.6100000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02579.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 236.88000000000028,
                "width": 468.1200000000006,
                "x": 540.0300000000008,
                "y": 414.5400000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02559.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 348.2700000000005,
                "width": 277.7700000000004,
                "x": 166.38000000000022,
                "y": 100.11000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02525.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 253.8000000000003,
                "width": 717.690000000001,
                "x": 46.530000000000065,
                "y": 592.2000000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02515.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 183.30000000000024,
                "width": 334.17000000000047,
                "x": 124.08000000000017,
                "y": 297.5100000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02500.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 294.69000000000034,
                "width": 180.48000000000025,
                "x": 782.5500000000011,
                "y": 362.3700000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02485.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 300.33000000000044,
                "width": 218.5500000000003,
                "x": 755.760000000001,
                "y": 363.7800000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02463.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 259.4400000000003,
                "width": 366.6000000000005,
                "x": 42.300000000000054,
                "y": 265.0800000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02450.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 362.37000000000046,
                "width": 391.98000000000053,
                "x": 2.820000000000004,
                "y": 270.72000000000037
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02387.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.07000000000022,
                "width": 291.87000000000035,
                "x": 105.75000000000014,
                "y": 372.2400000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02371.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 272.1300000000004,
                "width": 492.0900000000006,
                "x": 516.0600000000007,
                "y": 406.08000000000055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02368.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 238.2900000000003,
                "width": 435.6900000000005,
                "x": 578.1000000000008,
                "y": 104.34000000000015
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02365.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 139.5900000000002,
                "width": 94.47000000000025,
                "x": 1133.6400000000015,
                "y": 132.5400000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02364.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.0800000000003,
                "width": 274.9500000000004,
                "x": -1.410000000000002,
                "y": 320.07000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02308.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.99000000000024,
                "width": 360.9600000000005,
                "x": 105.75000000000014,
                "y": 305.9700000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02295.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 243.93000000000035,
                "width": 477.9900000000007,
                "x": 528.7500000000007,
                "y": 80.3700000000001
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02278.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.4000000000003,
                "width": 431.4600000000006,
                "x": 238.29000000000033,
                "y": 248.16000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02247.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.21000000000035,
                "width": 504.7800000000007,
                "x": 73.3200000000001,
                "y": 243.93000000000032
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02220.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 274.95000000000033,
                "width": 282.00000000000045,
                "x": 713.460000000001,
                "y": 468.12000000000063
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02219.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 101.52000000000015,
                "width": 252.39000000000038,
                "x": 339.81000000000046,
                "y": 62.040000000000084
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02199.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 162.1500000000002,
                "width": 383.52000000000055,
                "x": 129.72000000000017,
                "y": 318.6600000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02173.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.95000000000022,
                "width": 325.7100000000005,
                "x": 214.32000000000028,
                "y": 342.63000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02165.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 234.06000000000034,
                "width": 243.9300000000003,
                "x": 721.920000000001,
                "y": 269.31000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02150.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.27000000000032,
                "width": 358.1400000000005,
                "x": 83.19000000000011,
                "y": 336.99000000000046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02149.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.0800000000004,
                "width": 186.12000000000023,
                "x": 779.730000000001,
                "y": 383.52000000000055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02111.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 353.9100000000005,
                "width": 561.1800000000007,
                "x": 489.27000000000066,
                "y": 138.18000000000018
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02075.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.8400000000002,
                "width": 270.72000000000037,
                "x": 126.90000000000018,
                "y": 331.3500000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02067.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 253.80000000000032,
                "width": 493.5000000000007,
                "x": 730.380000000001,
                "y": 98.70000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02014.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 311.6100000000004,
                "width": 482.2200000000006,
                "x": 695.1300000000009,
                "y": 107.16000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01973.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 256.62000000000035,
                "width": 516.0600000000007,
                "x": 108.57000000000015,
                "y": 248.16000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01898.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 246.7500000000004,
                "width": 420.1800000000006,
                "x": 23.970000000000034,
                "y": 339.81000000000046
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01876.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.1000000000002,
                "width": 284.8200000000004,
                "x": 234.06000000000031,
                "y": 334.17000000000047
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01861.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 266.4900000000004,
                "width": 500.55000000000064,
                "x": 528.7500000000007,
                "y": 64.86000000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01842.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 166.38000000000022,
                "width": 236.88000000000034,
                "x": 843.1800000000012,
                "y": 431.4600000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01829.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 270.72000000000037,
                "width": 864.3300000000012,
                "x": 540.0300000000008,
                "y": 514.6500000000007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01784.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 290.4600000000004,
                "width": 332.76000000000045,
                "x": 617.5800000000008,
                "y": 418.77000000000055
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01769.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 190.35000000000025,
                "width": 344.0400000000004,
                "x": 737.430000000001,
                "y": 313.02000000000044
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01767.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 373.6500000000005,
                "width": 690.900000000001,
                "x": 420.1800000000006,
                "y": 94.47000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01749.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 260.85000000000036,
                "width": 236.88000000000034,
                "x": 706.410000000001,
                "y": 260.85000000000036
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01742.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 110.00000000000017,
                "width": 274.0000000000004,
                "x": 99.00000000000013,
                "y": 456.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01727.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 326.00000000000045,
                "width": 299.0000000000004,
                "x": 6.000000000000008,
                "y": 256.00000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01700.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.00000000000028,
                "width": 578.0000000000007,
                "x": 295.0000000000004,
                "y": 39.00000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01634.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.00000000000023,
                "width": 116.00000000000023,
                "x": 784.000000000001,
                "y": 82.00000000000011
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01625.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.00000000000028,
                "width": 443.00000000000057,
                "x": 243.0000000000003,
                "y": 86.00000000000011
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01623.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 133.00000000000017,
                "width": 232.00000000000028,
                "x": 375.0000000000005,
                "y": 21.00000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01610.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.00000000000028,
                "width": 480.0000000000006,
                "x": 301.0000000000004,
                "y": 308.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01606.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 197.00000000000028,
                "width": 326.0000000000004,
                "x": 73.0000000000001,
                "y": 301.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01539.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.00000000000016,
                "width": 247.00000000000034,
                "x": 359.00000000000045,
                "y": 29.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01532.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 315.0000000000004,
                "width": 306.00000000000045,
                "x": 708.0000000000009,
                "y": 490.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01521.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 179.00000000000023,
                "width": 352.00000000000045,
                "x": 104.00000000000014,
                "y": 322.00000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01498.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 207.00000000000028,
                "width": 577.0000000000008,
                "x": 327.00000000000045,
                "y": 52.00000000000007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01492.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 262.00000000000034,
                "width": 760.0000000000011,
                "x": 533.0000000000007,
                "y": 499.0000000000007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01472.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 300.0000000000004,
                "width": 419.00000000000057,
                "x": 581.0000000000008,
                "y": 53.00000000000007
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01469.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 262.0000000000004,
                "width": 171.00000000000023,
                "x": 797.000000000001,
                "y": 384.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01456.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.00000000000014,
                "width": 239.00000000000034,
                "x": 436.00000000000057,
                "y": 88.00000000000011
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01410.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 241.0000000000003,
                "width": 395.00000000000057,
                "x": 176.00000000000023,
                "y": 202.00000000000026
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01380.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 304.00000000000034,
                "width": 484.00000000000057,
                "x": 145.0000000000002,
                "y": 249.00000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01375.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 247.00000000000034,
                "width": 384.0000000000005,
                "x": 452.0000000000006,
                "y": 424.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01370.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 329.00000000000045,
                "width": 520.0000000000008,
                "x": 606.0000000000008,
                "y": 177.00000000000023
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01358.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.00000000000034,
                "width": 393.0000000000005,
                "x": 8.00000000000001,
                "y": 229.0000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01340.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 374.0000000000005,
                "width": 351.00000000000045,
                "x": 701.0000000000009,
                "y": 480.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01335.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.00000000000011,
                "width": 184.00000000000023,
                "x": 811.0000000000011,
                "y": 305.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01329.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 239.00000000000034,
                "width": 495.0000000000007,
                "x": 112.00000000000014,
                "y": 337.00000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01323.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 342.0000000000005,
                "width": 499.0000000000007,
                "x": 82.00000000000011,
                "y": 310.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01308.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 264.0000000000004,
                "width": 177.00000000000023,
                "x": 782.000000000001,
                "y": 387.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01292.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.00000000000017,
                "width": 141.00000000000023,
                "x": 619.0000000000008,
                "y": 347.00000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01254.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.00000000000023,
                "width": 295.0000000000004,
                "x": 170.00000000000023,
                "y": 286.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01241.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 257.0000000000004,
                "width": 203.00000000000034,
                "x": 800.000000000001,
                "y": 385.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01217.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 209.00000000000023,
                "width": 251.00000000000034,
                "x": 1.0000000000000013,
                "y": 332.00000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01199.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 274.00000000000034,
                "width": 641.0000000000009,
                "x": 28.000000000000036,
                "y": 574.0000000000008
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01190.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 171.00000000000023,
                "width": 349.00000000000045,
                "x": 87.00000000000011,
                "y": 328.00000000000045
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01189.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 160.00000000000023,
                "width": 155.00000000000023,
                "x": 443.00000000000057,
                "y": 23.000000000000032
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01007.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.00000000000034,
                "width": 292.0000000000004,
                "x": 1.0000000000000013,
                "y": 264.00000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00997.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 218.00000000000028,
                "width": 466.0000000000007,
                "x": 659.0000000000009,
                "y": 94.00000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00969.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 324.00000000000045,
                "width": 373.00000000000057,
                "x": 438.00000000000057,
                "y": 437.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00945.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 248.0000000000003,
                "width": 500.00000000000057,
                "x": 558.0000000000008,
                "y": 111.00000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00900.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 292.00000000000045,
                "width": 313.00000000000034,
                "x": 663.0000000000009,
                "y": 434.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00896.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 388.00000000000045,
                "width": 488.0000000000007,
                "x": 187.00000000000026,
                "y": 145.0000000000002
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00891.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.00000000000013,
                "width": 222.00000000000023,
                "x": 414.00000000000057,
                "y": 33.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00890.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 246.00000000000034,
                "width": 464.00000000000057,
                "x": 569.0000000000008,
                "y": 99.00000000000013
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00827.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 485.0000000000007,
                "width": 282.00000000000034,
                "x": 190.00000000000026,
                "y": 110.00000000000014
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00807.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 303.0000000000004,
                "width": 471.0000000000007,
                "x": 714.0000000000009,
                "y": 128.00000000000017
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00801.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.00000000000026,
                "width": 518.0000000000007,
                "x": 147.0000000000002,
                "y": 237.0000000000003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00796.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.00000000000034,
                "width": 353.00000000000045,
                "x": 625.0000000000008,
                "y": 422.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00769.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 228.00000000000028,
                "width": 165.00000000000017,
                "x": 388.0000000000005,
                "y": 34.00000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00752.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 253.00000000000028,
                "width": 480.0000000000007,
                "x": 102.00000000000014,
                "y": 293.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00743.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 172.00000000000023,
                "width": 181.00000000000023,
                "x": 432.00000000000057,
                "y": 7.000000000000009
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00739.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 232.0000000000003,
                "width": 479.0000000000007,
                "x": 168.00000000000023,
                "y": 191.00000000000026
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00696.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 193.00000000000028,
                "width": 350.0000000000005,
                "x": 465.0000000000006,
                "y": 450.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00694.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.00000000000023,
                "width": 286.00000000000034,
                "x": 106.00000000000014,
                "y": 319.0000000000004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00677.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 326.00000000000045,
                "width": 342.00000000000045,
                "x": 7.000000000000009,
                "y": 266.00000000000034
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00641.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 371.0000000000005,
                "width": 333.00000000000045,
                "x": 696.0000000000009,
                "y": 480.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00573.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 255.29835487131555,
                "width": 263.61039433224215,
                "x": 486.8480255685552,
                "y": 3.5623026261113795
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00572.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 235.1119733233511,
                "width": 537.9076965428184,
                "x": 334.8564468544697,
                "y": 52.247105182966905
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00566.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 241.04914436687005,
                "width": 289.7339469237256,
                "x": 319.41980214132036,
                "y": 328.91927581095075
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00539.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 237.48684174075868,
                "width": 435.7883545942921,
                "x": 167.42822342723485,
                "y": 184.05230234908794
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00536.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 104.49421036593378,
                "width": 108.05651299204521,
                "x": 632.9024332391218,
                "y": 374.0417757416949
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00522.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 331.29414422835833,
                "width": 546.219736003745,
                "x": 575.9055912213397,
                "y": 173.3653944707538
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00501.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 187.61460497519937,
                "width": 260.0480917061307,
                "x": 331.29414422835833,
                "y": 347.9182231502114
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00470.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.05124968834863,
                "width": 477.3485518989249,
                "x": 167.42822342723485,
                "y": 230.3622364885359
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00439.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.7402628881614,
                "width": 245.79888120168516,
                "x": 698.2113147178304,
                "y": 303.98315742817107
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00437.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 185.23973655779173,
                "width": 516.53388078615,
                "x": 170.99052605334623,
                "y": 332.4815784370621
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00378.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 352.66795998502664,
                "width": 541.4699991689298,
                "x": 607.9663148563421,
                "y": 175.7402628881614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00370.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 203.05124968834866,
                "width": 187.6146049751993,
                "x": 983.1955248067408,
                "y": 79.55809198315414
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00313.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.3015128535335,
                "width": 719.5851304744986,
                "x": 577.0930254300436,
                "y": 553.3443412559676
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00312.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 344.35592052410004,
                "width": 597.279406978008,
                "x": 573.5307228039321,
                "y": 160.30361817501208
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00284.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.7402628881614,
                "width": 546.2197360037449,
                "x": 161.49105238371587,
                "y": 306.35802584557865
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00279.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 211.3632891492752,
                "width": 442.91295984651487,
                "x": 176.9276970968652,
                "y": 212.550723357979
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00276.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 182.86486814038415,
                "width": 235.11197332335098,
                "x": 697.0238805091267,
                "y": 305.17059163687486
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00250.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 288.5465127150218,
                "width": 451.2249993074415,
                "x": 726.7097357267214,
                "y": 113.99368403556414
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00221.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 282.60934167150276,
                "width": 432.22605196818074,
                "x": 45.12249993074414,
                "y": 193.5517760187183
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00217.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.7402628881614,
                "width": 376.4166441591024,
                "x": 176.9276970968652,
                "y": 58.18427622648587
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00214.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 250.54861803650033,
                "width": 181.6774339316804,
                "x": 797.955788248949,
                "y": 395.41559149836314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00194.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.1800655835286,
                "width": 307.5454600542825,
                "x": 18.998947339260692,
                "y": 233.92453911464727
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00184.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 175.7402628881614,
                "width": 307.54546005428256,
                "x": 744.5212488572784,
                "y": 336.0438810631735
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00139.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 169.80309184464244,
                "width": 315.85749951520893,
                "x": 803.892959292468,
                "y": 421.5391440898466
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00137.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 186.42717076649558,
                "width": 312.2951968890976,
                "x": 34.43559205241,
                "y": 226.7999338624245
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00118.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 288.5465127150217,
                "width": 351.48052577632285,
                "x": 440.5380914291073,
                "y": 440.5380914291073
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00116.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 288.5465127150218,
                "width": 414.4145388376239,
                "x": 758.7704593617239,
                "y": 92.61986827889588
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00114.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.3015128535335,
                "width": 207.80098652316383,
                "x": 749.2709856920935,
                "y": 302.7957232194673
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00093.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 391.85328887225177,
                "width": 366.917170489472,
                "x": 693.4615778830153,
                "y": 486.8480255685552
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00069.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 265.9852627496497,
                "width": 450.0375650987377,
                "x": 561.6563807168942,
                "y": 67.68374989611621
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00061.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 279.04703904539144,
                "width": 178.11513130556898,
                "x": 788.4563145793187,
                "y": 376.4166441591025
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00021.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 306.3580258455787,
                "width": 436.9757888029959,
                "x": 520.0961834122614,
                "y": 448.8501308900338
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00004.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.55388134019688,
                "width": 251.73605224520423,
                "x": 274.2973022105762,
                "y": 388.2909862461404
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07854.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.3685524529717,
                "width": 169.8030918446425,
                "x": 356.23026261113796,
                "y": 397.7904599157707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07853.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 113.99368403556417,
                "width": 206.61355231446,
                "x": 231.5496706972397,
                "y": 395.41559149836314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07852.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 201.8638154796448,
                "width": 125.86802612260209,
                "x": 389.4784204548442,
                "y": 337.2313152718773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07849.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.0544076705666,
                "width": 205.4261181057562,
                "x": 345.54335473280383,
                "y": 364.5423020720645
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07775.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.49210504445517,
                "width": 222.05019702760936,
                "x": 235.11197332335107,
                "y": 369.2920389068797
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07765.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.80414450538177,
                "width": 290.9213811324293,
                "x": 355.04282840243417,
                "y": 382.35381520262143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07750.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.55388134019688,
                "width": 305.1705916368749,
                "x": 352.6679599850266,
                "y": 388.2909862461404
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07712.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.05440767056655,
                "width": 289.73394692372557,
                "x": 372.8543415329911,
                "y": 395.41559149836314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07665.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 104.49421036593384,
                "width": 206.61355231445998,
                "x": 327.73184160224696,
                "y": 403.7276309592897
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07655.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.92664443612586,
                "width": 122.30572349649071,
                "x": 381.16638099391764,
                "y": 345.54335473280383
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07653.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.1161839663083,
                "width": 269.5475653757611,
                "x": 235.11197332335107,
                "y": 374.0417757416949
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07577.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.55388134019694,
                "width": 267.1726969583535,
                "x": 360.9799994459531,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07569.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.6177629574173,
                "width": 220.8627628189055,
                "x": 232.73710490594348,
                "y": 390.665854663548
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07530.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.1193419485262,
                "width": 194.7392102274221,
                "x": 235.11197332335107,
                "y": 379.97894678521385
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07517.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.11828928778687,
                "width": 197.11407864482968,
                "x": 243.4240127842776,
                "y": 375.2292099503987
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07499.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 141.30467083575138,
                "width": 286.1716442976142,
                "x": 349.1056573589152,
                "y": 397.7904599157707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07472.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 134.18006558352863,
                "width": 225.6124996537207,
                "x": 414.41453883762387,
                "y": 412.0396704202162
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07427.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.43032874871352,
                "width": 211.3632891492752,
                "x": 345.54335473280383,
                "y": 396.60302570706693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07403.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.36749979223248,
                "width": 245.79888120168516,
                "x": 353.8553941937304,
                "y": 393.04072308095556
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07315.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.30677615723005,
                "width": 220.86276281890548,
                "x": 339.6061836892849,
                "y": 402.5401967505859
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07286.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 161.49105238371584,
                "width": 227.98736807112834,
                "x": 349.1056573589152,
                "y": 357.41769681984175
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07276.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.05651299204516,
                "width": 268.36013116705726,
                "x": 204.23868389705243,
                "y": 384.728683620029
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07226.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.05756565278455,
                "width": 219.67532861020175,
                "x": 349.1056573589152,
                "y": 444.10039405521866
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07095.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.74236820964006,
                "width": 265.9852627496496,
                "x": 384.728683620029,
                "y": 397.7904599157707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07069.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.92769709686524,
                "width": 143.67953925315896,
                "x": 383.5412494113252,
                "y": 349.1056573589152
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06925.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.68164457463757,
                "width": 206.61355231445998,
                "x": 427.4763151333656,
                "y": 426.2888809246618
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06898.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.6805919138983,
                "width": 241.04914436687002,
                "x": 231.5496706972397,
                "y": 390.665854663548
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06875.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 205.4261181057562,
                "width": 123.4931577051945,
                "x": 391.85328887225177,
                "y": 331.29414422835833
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06846.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.18111824426796,
                "width": 179.30256551427277,
                "x": 340.79361789798867,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06687.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.55703932241482,
                "width": 189.98947339260695,
                "x": 431.03861775947695,
                "y": 435.7883545942921
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06569.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 100.9319077398224,
                "width": 299.23342059335585,
                "x": 149.61671029667795,
                "y": 374.0417757416949
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06509.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.5549340009362,
                "width": 276.67217062798386,
                "x": 360.9799994459531,
                "y": 395.41559149836314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06486.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 92.61986827889586,
                "width": 163.86592080112342,
                "x": 326.54440739354317,
                "y": 400.1653283331783
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06464.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.3685524529717,
                "width": 270.73499958446484,
                "x": 235.11197332335107,
                "y": 377.60407836780627
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06406.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.05756565278455,
                "width": 174.55282867945755,
                "x": 385.9161178287328,
                "y": 410.85223621151243
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06326.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.30677615723005,
                "width": 229.17480227983208,
                "x": 319.41980214132036,
                "y": 400.1653283331783
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06316.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.11828928778687,
                "width": 254.11092066261176,
                "x": 334.8564468544697,
                "y": 371.6669073242873
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06262.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.93296040056174,
                "width": 192.36434181001448,
                "x": 363.3548678633607,
                "y": 412.0396704202162
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06228.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 97.36960511371109,
                "width": 199.4889470622373,
                "x": 357.41769681984175,
                "y": 406.10249937669727
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06146.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.67953925315896,
                "width": 217.30046019279416,
                "x": 341.98105210669246,
                "y": 400.1653283331783
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06048.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.74447353111862,
                "width": 172.17796026205008,
                "x": 436.9757888029959,
                "y": 432.22605196818074
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05926.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.67953925315896,
                "width": 230.36223648853587,
                "x": 396.60302570706693,
                "y": 383.5412494113252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05903.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.36749979223248,
                "width": 201.8638154796448,
                "x": 346.7307889415076,
                "y": 368.1046046981759
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05783.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 176.92769709686513,
                "width": 189.98947339260695,
                "x": 382.35381520262143,
                "y": 337.2313152718773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05769.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 94.99473669630345,
                "width": 248.1737496190928,
                "x": 178.11513130556898,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05765.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.243947200749,
                "width": 229.17480227983208,
                "x": 213.7381575666828,
                "y": 396.60302570706693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05744.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 132.9926313748249,
                "width": 267.17269695835347,
                "x": 359.79256523724933,
                "y": 395.41559149836314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05708.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.6177629574173,
                "width": 260.0480917061307,
                "x": 379.97894678521385,
                "y": 393.04072308095556
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05706.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.80624982686038,
                "width": 205.42611810575622,
                "x": 236.29940753205486,
                "y": 396.60302570706693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05680.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.74236820964,
                "width": 305.1705916368748,
                "x": 326.54440739354317,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05669.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 81.93296040056174,
                "width": 182.86486814038417,
                "x": 238.67427594946244,
                "y": 404.9150651679935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05667.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.05756565278449,
                "width": 258.8606574974269,
                "x": 199.48894706223726,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05655.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.17901292278935,
                "width": 207.80098652316383,
                "x": 337.2313152718773,
                "y": 359.79256523724933
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05644.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.8051971661211,
                "width": 271.9224337931687,
                "x": 229.1748022798321,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05495.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 96.1821709050073,
                "width": 206.61355231446,
                "x": 245.7988812016852,
                "y": 407.28993358540106
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05477.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.55493400093627,
                "width": 282.60934167150276,
                "x": 346.7307889415076,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05347.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80519716612105,
                "width": 292.1088153411331,
                "x": 206.61355231446004,
                "y": 390.665854663548
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05329.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 167.42822342723485,
                "width": 283.79677588020655,
                "x": 366.9171704894721,
                "y": 382.35381520262143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05172.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.5549340009362,
                "width": 232.73710490594345,
                "x": 218.48789440149795,
                "y": 385.9161178287328
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05143.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.68164457463757,
                "width": 210.17585494057144,
                "x": 248.17374961909277,
                "y": 381.16638099391764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05128.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.55703932241482,
                "width": 192.36434181001454,
                "x": 345.54335473280383,
                "y": 397.7904599157707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04936.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.55809198315416,
                "width": 210.17585494057136,
                "x": 287.359078506318,
                "y": 398.9778941244745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04911.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 121.11828928778692,
                "width": 269.54756537576105,
                "x": 366.9171704894721,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04825.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.05651299204516,
                "width": 181.67743393168035,
                "x": 265.9852627496497,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04802.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.49210504445523,
                "width": 283.7967758802066,
                "x": 216.11302598409037,
                "y": 388.2909862461404
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04688.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.4931577051945,
                "width": 236.29940753205483,
                "x": 211.3632891492752,
                "y": 385.9161178287328
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04684.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.74342087037934,
                "width": 178.115131305569,
                "x": 249.36118382779657,
                "y": 383.5412494113252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04668.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.05651299204521,
                "width": 268.36013116705726,
                "x": 298.0459863846521,
                "y": 396.60302570706693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04628.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.9298024183438,
                "width": 269.54756537576105,
                "x": 370.4794731155835,
                "y": 388.2909862461404
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04551.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 98.55703932241488,
                "width": 203.05124968834866,
                "x": 432.22605196818074,
                "y": 434.6009203855883
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04472.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.74342087037934,
                "width": 252.9234864539079,
                "x": 327.73184160224696,
                "y": 383.5412494113252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04469.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.6826972353769,
                "width": 194.73921022742206,
                "x": 356.23026261113796,
                "y": 412.0396704202162
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04467.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 192.36434181001448,
                "width": 110.4313814094528,
                "x": 395.41559149836314,
                "y": 334.8564468544697
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04429.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.74236820964006,
                "width": 275.48473641928,
                "x": 365.7297362807683,
                "y": 395.41559149836314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04413.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.55493400093627,
                "width": 244.61144699298137,
                "x": 382.35381520262143,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04360.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 198.3015128535335,
                "width": 143.67953925315902,
                "x": 368.1046046981759,
                "y": 334.8564468544697
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04317.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.24499986148828,
                "width": 170.99052605334623,
                "x": 256.48578908001934,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04281.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.36855245297176,
                "width": 230.36223648853587,
                "x": 336.0438810631735,
                "y": 388.2909862461404
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04249.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 104.49421036593384,
                "width": 238.67427594946247,
                "x": 338.4187494805811,
                "y": 400.1653283331783
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04230.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 189.9894733926069,
                "width": 211.36328914927515,
                "x": 346.7307889415076,
                "y": 344.35592052410004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04159.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.36855245297176,
                "width": 225.6124996537207,
                "x": 225.6124996537207,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04148.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.36855245297176,
                "width": 268.36013116705726,
                "x": 233.92453911464727,
                "y": 398.9778941244745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04087.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.2386838970524,
                "width": 117.55598666167555,
                "x": 393.04072308095556,
                "y": 332.4815784370621
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03963.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.05440767056655,
                "width": 263.6103943322421,
                "x": 376.4166441591025,
                "y": 393.04072308095556
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03939.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.68059191389835,
                "width": 226.7999338624245,
                "x": 413.2271046289201,
                "y": 410.85223621151243
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03755.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 104.49421036593378,
                "width": 211.3632891492752,
                "x": 338.4187494805811,
                "y": 432.22605196818074
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03753.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 128.24289454000962,
                "width": 224.4250654450169,
                "x": 220.86276281890554,
                "y": 390.665854663548
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03654.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.74447353111862,
                "width": 208.9884207318676,
                "x": 230.3622364885359,
                "y": 396.60302570706693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03651.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.80519716612105,
                "width": 307.54546005428244,
                "x": 175.7402628881614,
                "y": 381.16638099391764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03590.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 125.86802612260209,
                "width": 220.8627628189056,
                "x": 344.35592052410004,
                "y": 384.728683620029
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03568.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.30572349649066,
                "width": 219.67532861020175,
                "x": 404.9150651679935,
                "y": 419.16427567243903
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03558.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.1193419485262,
                "width": 172.17796026205005,
                "x": 244.6114469929814,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03480.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 214.92559177538664,
                "width": 141.30467083575144,
                "x": 382.35381520262143,
                "y": 322.98210476743174
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03400.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.92980241834385,
                "width": 229.17480227983214,
                "x": 315.857499515209,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03367.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 124.6805919138983,
                "width": 214.92559177538658,
                "x": 224.4250654450169,
                "y": 385.9161178287328
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03327.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.3685524529717,
                "width": 191.1769076013107,
                "x": 347.9182231502114,
                "y": 402.5401967505859
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03253.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.87013144408076,
                "width": 218.48789440149795,
                "x": 336.0438810631735,
                "y": 447.66269668133003
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03244.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 87.8701314440807,
                "width": 198.30151285353344,
                "x": 210.1758549405714,
                "y": 416.78940725503145
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03183.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.80624982686038,
                "width": 230.36223648853587,
                "x": 340.79361789798867,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03096.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.36855245297176,
                "width": 219.67532861020175,
                "x": 337.2313152718773,
                "y": 410.85223621151243
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03065.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.74236820963995,
                "width": 230.36223648853587,
                "x": 210.1758549405714,
                "y": 381.16638099391764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03007.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.67953925315902,
                "width": 175.7402628881614,
                "x": 358.60513102854554,
                "y": 324.1695389761355
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02905.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.1172366270476,
                "width": 268.36013116705726,
                "x": 363.3548678633607,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02858.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 138.92980241834385,
                "width": 235.1119733233511,
                "x": 402.5401967505859,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02787.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.74342087037934,
                "width": 189.98947339260695,
                "x": 336.0438810631735,
                "y": 403.7276309592897
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02721.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 174.5528286794576,
                "width": 186.42717076649558,
                "x": 363.3548678633607,
                "y": 345.54335473280383
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02690.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.4292760879742,
                "width": 203.05124968834863,
                "x": 231.5496706972397,
                "y": 375.2292099503987
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02633.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.1172366270476,
                "width": 274.2973022105763,
                "x": 356.23026261113796,
                "y": 398.9778941244745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02562.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.11618396630826,
                "width": 248.1737496190928,
                "x": 256.48578908001934,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02457.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 129.43032874871352,
                "width": 233.92453911464725,
                "x": 219.67532861020175,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02438.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.43243407019207,
                "width": 198.30151285353347,
                "x": 205.42611810575622,
                "y": 417.97684146373524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02351.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.3685524529717,
                "width": 236.29940753205483,
                "x": 422.7265782985504,
                "y": 432.22605196818074
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02274.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.36855245297176,
                "width": 217.30046019279413,
                "x": 229.1748022798321,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02221.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.55388134019688,
                "width": 260.0480917061307,
                "x": 375.2292099503987,
                "y": 388.2909862461404
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02179.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.36749979223242,
                "width": 268.3601311670572,
                "x": 370.4794731155835,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02104.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.1172366270476,
                "width": 216.11302598409037,
                "x": 328.91927581095075,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02053.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 123.49315770519456,
                "width": 212.550723357979,
                "x": 407.28993358540106,
                "y": 409.66480200280864
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01953.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.3685524529717,
                "width": 283.7967758802066,
                "x": 131.80519716612105,
                "y": 378.79151257651006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01886.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.11723662704765,
                "width": 237.48684174075862,
                "x": 210.1758549405714,
                "y": 381.16638099391764
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01779.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.80414450538171,
                "width": 271.9224337931686,
                "x": 371.6669073242873,
                "y": 383.5412494113252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01747.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.5549340009362,
                "width": 226.7999338624245,
                "x": 412.0396704202162,
                "y": 415.60197304632766
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01709.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.43243407019207,
                "width": 178.11513130556898,
                "x": 251.73605224520418,
                "y": 390.665854663548
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01704.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.8669734618628,
                "width": 274.2973022105762,
                "x": 180.48999972297656,
                "y": 366.9171704894721
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01675.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.49210504445523,
                "width": 290.9213811324293,
                "x": 336.0438810631735,
                "y": 383.5412494113252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01662.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 153.17901292278935,
                "width": 305.17059163687486,
                "x": 231.5496706972397,
                "y": 379.97894678521385
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01573.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.1172366270476,
                "width": 273.1098680018724,
                "x": 360.9799994459531,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01518.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 147.24184187927034,
                "width": 314.6700653065052,
                "x": 346.7307889415076,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01516.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.36749979223242,
                "width": 267.17269695835347,
                "x": 179.30256551427277,
                "y": 358.60513102854554
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01415.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.92664443612586,
                "width": 180.48999972297656,
                "x": 339.6061836892849,
                "y": 340.79361789798867
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01403.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 127.05546033130582,
                "width": 224.42506544501688,
                "x": 230.3622364885359,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01385.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.05756565278455,
                "width": 217.3004601927942,
                "x": 200.67638127094105,
                "y": 412.0396704202162
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01368.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.68164457463763,
                "width": 195.92664443612586,
                "x": 414.41453883762387,
                "y": 404.9150651679935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01233.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 208.98842073186762,
                "width": 143.67953925315896,
                "x": 371.6669073242873,
                "y": 320.60723635002415
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01201.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.36855245297176,
                "width": 262.42296012353836,
                "x": 353.8553941937304,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01143.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 144.86697346186276,
                "width": 270.7349995844649,
                "x": 359.79256523724933,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01113.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.05651299204521,
                "width": 217.3004601927941,
                "x": 416.78940725503145,
                "y": 422.7265782985504
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01008.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 111.61881561815659,
                "width": 211.36328914927515,
                "x": 422.7265782985504,
                "y": 428.66374934206937
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00958.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.8051971661211,
                "width": 232.73710490594345,
                "x": 223.23763123631312,
                "y": 396.60302570706693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00955.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 204.23868389705245,
                "width": 121.11828928778692,
                "x": 401.3527625418821,
                "y": 331.29414422835833
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00925.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 143.67953925315902,
                "width": 282.6093416715028,
                "x": 359.79256523724933,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00872.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 130.6177629574172,
                "width": 244.61144699298137,
                "x": 328.91927581095075,
                "y": 383.5412494113252
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00871.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.805197166121,
                "width": 224.42506544501697,
                "x": 359.79256523724933,
                "y": 382.35381520262143
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00815.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 79.55809198315416,
                "width": 206.61355231446004,
                "x": 267.17269695835347,
                "y": 395.41559149836314
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00806.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 195.9266444361259,
                "width": 116.3685524529717,
                "x": 381.16638099391764,
                "y": 337.2313152718773
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00738.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 140.1172366270476,
                "width": 254.1109206626117,
                "x": 382.35381520262143,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00704.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 135.36749979223242,
                "width": 248.17374961909275,
                "x": 381.16638099391764,
                "y": 394.22815728965935
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00540.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 137.74236820964,
                "width": 239.86171015816626,
                "x": 330.10671001965454,
                "y": 374.0417757416949
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00535.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 89.05756565278449,
                "width": 194.73921022742206,
                "x": 427.4763151333656,
                "y": 438.1632230116997
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00477.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.30572349649071,
                "width": 207.8009865231638,
                "x": 232.73710490594348,
                "y": 385.9161178287328
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00440.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.24499986148828,
                "width": 195.92664443612588,
                "x": 248.17374961909277,
                "y": 397.7904599157707
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00436.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 131.8051971661211,
                "width": 268.3601311670572,
                "x": 372.8543415329911,
                "y": 396.60302570706693
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00420.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 105.68164457463757,
                "width": 199.48894706223723,
                "x": 286.1716442976142,
                "y": 387.1035520374366
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00372.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.24394720074895,
                "width": 223.23763123631312,
                "x": 419.16427567243903,
                "y": 429.85118355077316
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00333.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 116.36855245297176,
                "width": 281.421907462799,
                "x": 195.92664443612588,
                "y": 391.85328887225177
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00287.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 122.30572349649066,
                "width": 264.79782854094583,
                "x": 229.1748022798321,
                "y": 375.2292099503987
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00286.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.86907878334137,
                "width": 254.1109206626118,
                "x": 160.30361817501208,
                "y": 389.4784204548442
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00222.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 112.80624982686038,
                "width": 227.9873680711283,
                "x": 401.3527625418821,
                "y": 417.97684146373524
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00092.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 154.36644713149315,
                "width": 265.9852627496497,
                "x": 223.23763123631312,
                "y": 360.9799994459531
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00023.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 64.12144727000481,
                "width": 220.86276281890548,
                "x": 371.6669073242873,
                "y": 344.35592052410004
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07649.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 173.3653944707538,
                "width": 309.92032847168997,
                "x": 333.6690126457659,
                "y": 363.3548678633607
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07613.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 151.99157871408556,
                "width": 277.85960483668765,
                "x": 343.16848631539625,
                "y": 369.2920389068797
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07541.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 156.74131554890073,
                "width": 289.73394692372557,
                "x": 338.4187494805811,
                "y": 360.9799994459531
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07466.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.55598666167555,
                "width": 235.1119733233511,
                "x": 180.48999972297656,
                "y": 360.9799994459531
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07368.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 118.74342087037934,
                "width": 251.73605224520418,
                "x": 173.3653944707538,
                "y": 364.5423020720645
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07074.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.05440767056655,
                "width": 283.7967758802066,
                "x": 346.7307889415076,
                "y": 376.4166441591025
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_07072.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 155.55388134019694,
                "width": 273.1098680018724,
                "x": 349.1056573589152,
                "y": 359.79256523724933
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06988.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 159.11618396630837,
                "width": 274.2973022105762,
                "x": 355.04282840243417,
                "y": 366.9171704894721
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06980.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 148.4292760879742,
                "width": 268.3601311670573,
                "x": 352.6679599850266,
                "y": 375.2292099503987
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06897.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.243947200749,
                "width": 231.54967069723966,
                "x": 179.30256551427277,
                "y": 366.9171704894721
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06854.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 84.30782881796932,
                "width": 255.2983548713155,
                "x": 351.4805257763228,
                "y": 346.7307889415076
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06625.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 85.49526302667311,
                "width": 244.61144699298137,
                "x": 359.79256523724933,
                "y": 377.60407836780627
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06600.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.80835514833899,
                "width": 241.04914436687005,
                "x": 377.60407836780627,
                "y": 398.9778941244745
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06593.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.11934194852626,
                "width": 250.5486180365004,
                "x": 173.3653944707538,
                "y": 364.5423020720645
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06407.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.61053266938302,
                "width": 194.65821638750595,
                "x": 218.29887832604027,
                "y": 360.14284995724614
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06364.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.00000000000023,
                "width": 253.00000000000034,
                "x": 359.00000000000057,
                "y": 378.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_06336.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.00000000000017,
                "width": 215.00000000000034,
                "x": 182.00000000000028,
                "y": 363.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05816.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 67.00000000000011,
                "width": 161.00000000000028,
                "x": 409.0000000000006,
                "y": 329.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05786.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.00000000000017,
                "width": 211.0000000000003,
                "x": 194.0000000000003,
                "y": 360.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05662.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 165.00000000000023,
                "width": 197.00000000000034,
                "x": 434.0000000000007,
                "y": 378.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05321.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.00000000000023,
                "width": 281.0000000000004,
                "x": 338.0000000000005,
                "y": 371.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05282.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 117.00000000000017,
                "width": 190.00000000000028,
                "x": 214.00000000000034,
                "y": 358.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05166.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.00000000000017,
                "width": 213.00000000000034,
                "x": 178.00000000000028,
                "y": 363.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05152.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 108.00000000000017,
                "width": 238.00000000000034,
                "x": 178.00000000000028,
                "y": 367.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_05041.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.00000000000023,
                "width": 286.0000000000005,
                "x": 346.0000000000005,
                "y": 376.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04952.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 114.00000000000017,
                "width": 238.00000000000034,
                "x": 181.00000000000028,
                "y": 350.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04594.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 136.00000000000023,
                "width": 300.0000000000004,
                "x": 319.0000000000005,
                "y": 367.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04526.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 86.00000000000017,
                "width": 260.00000000000034,
                "x": 352.00000000000057,
                "y": 342.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04516.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 99.00000000000011,
                "width": 244.0000000000004,
                "x": 333.0000000000005,
                "y": 388.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04420.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 109.00000000000017,
                "width": 243.00000000000037,
                "x": 162.00000000000026,
                "y": 358.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04355.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 146.00000000000023,
                "width": 273.00000000000045,
                "x": 354.00000000000057,
                "y": 373.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04224.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 102.00000000000017,
                "width": 257.0000000000004,
                "x": 337.0000000000005,
                "y": 399.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_04046.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 91.00000000000017,
                "width": 260.0000000000004,
                "x": 386.0000000000006,
                "y": 343.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03779.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 82.00000000000011,
                "width": 240.00000000000034,
                "x": 352.00000000000057,
                "y": 351.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03649.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 142.00000000000017,
                "width": 270.00000000000045,
                "x": 355.00000000000057,
                "y": 386.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03543.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 68.00000000000011,
                "width": 292.0000000000005,
                "x": 338.0000000000005,
                "y": 353.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03437.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 74.00000000000011,
                "width": 232.00000000000034,
                "x": 297.00000000000045,
                "y": 391.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03430.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 106.00000000000017,
                "width": 224.00000000000034,
                "x": 176.00000000000028,
                "y": 367.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_03407.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.00000000000011,
                "width": 196.00000000000028,
                "x": 418.0000000000006,
                "y": 330.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02493.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.00000000000017,
                "width": 212.0000000000003,
                "x": 196.0000000000003,
                "y": 353.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_02449.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 150.00000000000023,
                "width": 275.00000000000045,
                "x": 354.00000000000057,
                "y": 366.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01972.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 90.00000000000011,
                "width": 234.0000000000004,
                "x": 328.0000000000005,
                "y": 403.0000000000006
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01817.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.00000000000023,
                "width": 277.0000000000004,
                "x": 342.0000000000005,
                "y": 364.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01691.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 115.00000000000017,
                "width": 261.0000000000004,
                "x": 403.0000000000006,
                "y": 324.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_01372.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 157.00000000000023,
                "width": 279.0000000000004,
                "x": 339.0000000000005,
                "y": 367.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00916.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 149.00000000000023,
                "width": 201.00000000000034,
                "x": 428.0000000000007,
                "y": 371.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00778.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 103.00000000000017,
                "width": 210.00000000000034,
                "x": 380.00000000000057,
                "y": 372.00000000000057
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00218.jpg"
    },
    {
        "annotations": [
            {
                "class": "rect",
                "height": 78.00000000000011,
                "width": 200.00000000000028,
                "x": 389.0000000000006,
                "y": 323.0000000000005
            }
        ],
        "class": "image",
        "filename": "Downloads/train/train/YFT/img_00052.jpg"
    }
]
