# %%
! ls ../input/denoising-dirty-documents

# %%
# !unzip ../input/denoising-dirty-documents/test.zip -d data

# %%
# !unzip ../input/denoising-dirty-documents/train.zip -d data

# %%
# !unzip ../input/denoising-dirty-documents/train_cleaned.zip -d data
