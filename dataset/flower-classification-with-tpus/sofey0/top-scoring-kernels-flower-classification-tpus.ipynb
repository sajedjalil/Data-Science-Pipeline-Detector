# %% [markdown]
# ## My GitHub repository: [harupy/kernel-profiler](https://github.com/harupy/kernel-profiler) automatically updates this notebook by using [GitHub Actions](https://github.com/features/actions) and [Kaggle API](https://github.com/Kaggle/kaggle-api). Any feedback would be appreciated.
# ## Last Updated: 2020/04/25 00:05:56 (UTC)
#
# <br>
#
# # [FlowerTPUwin](https://www.kaggle.com/hatemamine/flowertpuwin)
#
# <a href="https://www.kaggle.com/hatemamine" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/2768833-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[hatem amine](https://www.kaggle.com/hatemamine)|
# |Language|Py|
# |Best Score|0.96739|
# |Votes|19|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/bronzes@1x.png" align="left">|
# |Comments|0|
# |Last Updated|20d ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 7|0.96344|20 days ago|2.0 h|+2|-2|[Open](https://www.kaggle.com/hatemamine/flowertpuwin?scriptVersionId=31424052)|
# |Version 5|0.94388|21 days ago|2.2 h|+5|-4|[Open](https://www.kaggle.com/hatemamine/flowertpuwin?scriptVersionId=31398416)|
# |Version 4|0.95039|21 days ago|2.3 h|+60|-7|[Open](https://www.kaggle.com/hatemamine/flowertpuwin?scriptVersionId=31384733)|
# |Version 3|0.96739|21 days ago|2.0 h|0|0|[Open](https://www.kaggle.com/hatemamine/flowertpuwin?scriptVersionId=31379229)|
# |Forked from|0.9662|a month ago|1.9 h|0|0|[Open](https://www.kaggle.com/luonganhtuan93/ensemble-enet-b7-and-densenet201)|
#
# <br>
#
# # [Ensemble ENet B7 and DenseNet201 ](https://www.kaggle.com/luonganhtuan93/ensemble-enet-b7-and-densenet201)
#
# <a href="https://www.kaggle.com/luonganhtuan93" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/308842-fb.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Tuấn Lương](https://www.kaggle.com/luonganhtuan93)|
# |Language|Py|
# |Best Score|0.9662|
# |Votes|11|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/bronzes@1x.png" align="left">|
# |Comments|1|
# |Last Updated|1mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 1|0.9662|a month ago|1.9 h|+411|0|[Open](https://www.kaggle.com/luonganhtuan93/ensemble-enet-b7-and-densenet201?scriptVersionId=30598535)|
#
# <br>
#
# # [Flower Classification Ensemble](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble)
#
# <a href="https://www.kaggle.com/sebastiankoenig" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/4286547-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Sebastian Koenig](https://www.kaggle.com/sebastiankoenig)|
# |Language|Py|
# |Best Score|0.96552|
# |Votes|19|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/bronzes@1x.png" align="left">|
# |Comments|5|
# |Last Updated|1mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 19|0.95434|a month ago|2.2 h|+1|-1|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=30196459)|
# |Version 16|0.95175|a month ago|1.6 h|+1|-1|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=30128087)|
# |Version 10|0.9648|a month ago|1.7 h|+11|-55|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=30039548)|
# |Version 7|0.96552|2 months ago|2.0 h|+32|-27|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=29771674)|
# |Version 5|0.95873|2 months ago|1.7 h|+1|-1|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=29768378)|
# |Version 4|0.94785|2 months ago|54.5 m|+9|-7|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=29766261)|
# |Version 2|0.95142|2 months ago|1.0 h|+5|-5|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=29663905)|
# |Version 1|0.91972|2 months ago|38.2 m|+379|0|[Open](https://www.kaggle.com/sebastiankoenig/flower-classification-ensemble?scriptVersionId=29662458)|
#
# <br>
#
# # [Flower Classification - ENet B7 + DenseNet](https://www.kaggle.com/jagannathrk/flower-classification-enet-b7-densenet)
#
# <a href="https://www.kaggle.com/jagannathrk" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/718515-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Kranti Kumar](https://www.kaggle.com/jagannathrk)|
# |Language|Py|
# |Best Score|0.96551|
# |Votes|4|
# |Medal|-|
# |Comments|0|
# |Last Updated|1mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 1|0.96551|a month ago|1.5 h|0|0|[Open](https://www.kaggle.com/jagannathrk/flower-classification-enet-b7-densenet?scriptVersionId=29951454)|
# |Forked from|0.96509|2 months ago|1.5 h|0|0|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet)|
#
# <br>
#
# # [Flower Classification with DenseNet201 + ENetB7](https://www.kaggle.com/ar2017/flower-classification-with-densenet201-enetb7)
#
# <a href="https://www.kaggle.com/ar2017" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1218451-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[AndikaRachman](https://www.kaggle.com/ar2017)|
# |Language|Py|
# |Best Score|0.96531|
# |Votes|5|
# |Medal|-|
# |Comments|0|
# |Last Updated|12d ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 10|0.96531|12 days ago|2.0 h|+2|-3|[Open](https://www.kaggle.com/ar2017/flower-classification-with-densenet201-enetb7?scriptVersionId=31917838)|
# |Version 9|0.96322|12 days ago|2.0 h|0|0|[Open](https://www.kaggle.com/ar2017/flower-classification-with-densenet201-enetb7?scriptVersionId=31910677)|
#
# <br>
#
# # [104 Flowers: Direct Submission](https://www.kaggle.com/msheriey/104-flowers-direct-submission)
#
# <a href="https://www.kaggle.com/msheriey" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/2510328-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-expert@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Mourad](https://www.kaggle.com/msheriey)|
# |Language|Py|
# |Best Score|0.96523|
# |Votes|6|
# |Medal|-|
# |Comments|0|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 4|0.96523|2 months ago|9.6 s|+1|-1|[Open](https://www.kaggle.com/msheriey/104-flowers-direct-submission?scriptVersionId=28647305)|
#
# <br>
#
# # [TPU: ENet B7 + DenseNet](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet)
#
# <a href="https://www.kaggle.com/wrrosa" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/3974868-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-expert@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Wojtek Rosa](https://www.kaggle.com/wrrosa)|
# |Language|Py|
# |Best Score|0.96523|
# |Votes|89|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/golds@1x.png" align="left">|
# |Comments|8|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 28|0.96509|2 months ago|1.5 h|0|0|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29569034)|
# |Version 27|0.96152|2 months ago|1.5 h|+24|-20|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29564824)|
# |Version 26|0.96343|2 months ago|1.5 h|0|0|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29445941)|
# |Version 25|0.96412|2 months ago|1.5 h|+7|-5|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29443514)|
# |Version 24|0.9594|2 months ago|1.4 h|+5|-3|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29440464)|
# |Version 23|0.96137|2 months ago|1.5 h|+78|-8|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29206000)|
# |Version 22|0.96008|2 months ago|1.4 h|+16|-6|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29184881)|
# |Version 21|0.96049|2 months ago|1.4 h|+9|-4|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29157718)|
# |Version 20|0.95948|2 months ago|1.4 h|+4|-1|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29113946)|
# |Version 19|0.96242|2 months ago|1.4 h|+15|-4|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=29044695)|
# |Version 18|0.95658|2 months ago|1.3 h|+44|-3|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28946943)|
# |Version 17|0.95931|2 months ago|1.3 h|+84|-2|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28899010)|
# |Version 16|0.96129|2 months ago|1.4 h|+4|-2|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28836632)|
# |Version 15|0.96309|2 months ago|1.4 h|+6|-2|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28811150)|
# |Version 13|0.96044|2 months ago|1.4 h|+9|-7|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28793775)|
# |Version 12|0.96056|2 months ago|1.4 h|+3|-1|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28777356)|
# |Version 11|0.96256|2 months ago|1.4 h|+5|-3|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28759373)|
# |Version 10|0.96114|2 months ago|1.4 h|+5|-3|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28754939)|
# |Version 9|0.95955|2 months ago|1.4 h|+5|-3|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28738771)|
# |Version 8|0.96059|2 months ago|1.4 h|+3|-1|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28734881)|
# |Version 7|0.96523|2 months ago|1.4 h|+2|-2|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28547367)|
# |Version 5|0.95784|2 months ago|1.3 h|+26|-6|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28544041)|
# |Version 4|0.96049|2 months ago|1.4 h|+69|-29|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28540122)|
# |Version 3|0.95083|2 months ago|1.3 h|+2|0|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28525338)|
# |Version 2|0.95388|2 months ago|1.3 h|+44|-2|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28518792)|
# |Version 1|0.95556|2 months ago|1.5 h|+43|-8|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet?scriptVersionId=28511135)|
#
# <br>
#
# # [kernel4fcb503f8e](https://www.kaggle.com/jd81197/kernel4fcb503f8e)
#
# <a href="https://www.kaggle.com/jd81197" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[JayDeep](https://www.kaggle.com/jd81197)|
# |Language|Py|
# |Best Score|0.96487|
# |Votes|2|
# |Medal|-|
# |Comments|1|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 2|0.96487|2 months ago|1.5 h|+134|0|[Open](https://www.kaggle.com/jd81197/kernel4fcb503f8e?scriptVersionId=29460023)|
#
# <br>
#
# # [Kernel mashup](https://www.kaggle.com/volody/kernel-mashup)
#
# <a href="https://www.kaggle.com/volody" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/835535-gr.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[volody](https://www.kaggle.com/volody)|
# |Language|Py|
# |Best Score|0.96487|
# |Votes|6|
# |Medal|-|
# |Comments|2|
# |Last Updated|4d ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 94|0.95352|4 days ago|2.1 h|+4|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=32382910)|
# |Version 90|0.94332|7 days ago|1.5 h|+1|-1|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=32211663)|
# |Version 87|0.94596|10 days ago|1.6 h|+4|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31991023)|
# |Version 84|0.94291|11 days ago|1.6 h|+42|-42|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31962866)|
# |Version 83|0.96026|11 days ago|2.9 h|+31|-5|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31956037)|
# |Version 82|0.96088|13 days ago|2.9 h|+1|-3|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31846719)|
# |Version 80|0.96487|13 days ago|2.9 h|+2|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31828490)|
# |Version 79|0.96428|14 days ago|2.8 h|0|0|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31787371)|
# |Version 73|0.96308|18 days ago|2.7 h|+10|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31549710)|
# |Version 72|0.95937|18 days ago|2.8 h|+10|-9|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31540242)|
# |Version 71|0.96089|19 days ago|2.8 h|+1|-1|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31495850)|
# |Version 70|0.95476|19 days ago|2.0 h|+27|-31|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31491409)|
# |Version 69|0.95748|20 days ago|2.8 h|+11|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31435524)|
# |Version 67|0.95972|20 days ago|2.6 h|+3|-3|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31410993)|
# |Version 66|0.96336|21 days ago|2.5 h|+7|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31394107)|
# |Version 65|0.95815|21 days ago|1.8 h|+2|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31361648)|
# |Version 64|0.95952|22 days ago|1.8 h|+60|-28|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31334843)|
# |Version 63|0.95807|22 days ago|1.9 h|+2|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31317754)|
# |Version 62|0.95939|22 days ago|1.8 h|+4|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31312072)|
# |Version 61|0.9575|23 days ago|1.8 h|+30|-18|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31287279)|
# |Version 59|0.92032|24 days ago|46.7 m|+30|-26|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31225930)|
# |Version 52|0.94789|25 days ago|2.9 h|0|0|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31138669)|
# |Version 49|0.94319|a month ago|2.2 h|+11|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31093592)|
# |Version 46|0.94866|a month ago|53.9 m|+277|-185|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=31075751)|
# |Version 45|0.95484|a month ago|1.4 h|+5|-5|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30908706)|
# |Version 44|0.9537|a month ago|2.4 h|+3|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30844290)|
# |Version 42|0.95353|a month ago|1.4 h|+2|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30825468)|
# |Version 41|0.95367|a month ago|2.1 h|+12|-12|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30785231)|
# |Version 40|0.94159|a month ago|54.3 m|+60|-23|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30779484)|
# |Version 39|0.95186|a month ago|1.4 h|+14|-9|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30746111)|
# |Version 38|0.95444|a month ago|1.4 h|+1|-1|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30721361)|
# |Version 37|0.91321|a month ago|40.4 m|+2|-6|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30718472)|
# |Version 36|0.91186|a month ago|39.9 m|+11|-7|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30716106)|
# |Version 35|0.95664|a month ago|1.1 h|+5|-5|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30713281)|
# |Version 34|0.95319|a month ago|1.8 h|0|-1|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30707176)|
# |Version 31|0.95548|a month ago|1.3 h|+4|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30659824)|
# |Version 30|0.95043|a month ago|59.3 m|+34|-15|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30657542)|
# |Version 29|0.93738|a month ago|55.1 m|+8|-7|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30654863)|
# |Version 28|0.93576|a month ago|40.5 m|+10|-9|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30651663)|
# |Version 27|0.9266|a month ago|37.8 m|+118|-77|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30645941)|
# |Version 26|0.86696|a month ago|27.5 m|+26|-6|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30641149)|
# |Version 25|0.90704|a month ago|29.4 m|+1|-14|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30601074)|
# |Version 24|0.92196|a month ago|27.1 m|+94|-28|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=30600140)|
# |Version 23|0.91786|2 months ago|25.7 m|+28|-17|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=29773256)|
# |Version 20|0.91346|2 months ago|16.4 m|+5|-3|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=29136217)|
# |Version 18|0.91586|2 months ago|26.8 m|+7|-10|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=29119858)|
# |Version 17|0.90639|2 months ago|50.8 m|+2|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=29113192)|
# |Version 16|0.91501|2 months ago|47.2 m|+1|-1|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=29110629)|
# |Version 15|0.92295|2 months ago|27.1 m|+58|-48|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=29108350)|
# |Version 13|0.86|2 months ago|11.8 m|+3|-3|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=29038295)|
# |Version 11|0.78953|2 months ago|5.1 m|+1|0|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28975669)|
# |Version 10|0.7689|2 months ago|4.9 m|+5|-4|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28934408)|
# |Version 9|0.4256|2 months ago|9.4 m|+10|-6|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28923765)|
# |Version 8|0.51702|2 months ago|8.5 m|+74|-35|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28923331)|
# |Version 7|0.5246|2 months ago|5.2 m|+2|-2|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28916249)|
# |Version 6|0.17368|2 months ago|3.5 m|+1|-1|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28886371)|
# |Version 5|0.34761|2 months ago|3.3 m|+44|-21|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28886111)|
# |Version 4|0.37914|2 months ago|2.3 m|+12|-8|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28885731)|
# |Version 3|0.20153|2 months ago|5.4 m|+11|-6|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28826701)|
# |Version 2|0.29048|2 months ago|10.0 m|+17|-11|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28812867)|
# |Version 1|0.24821|2 months ago|5.4 m|+252|0|[Open](https://www.kaggle.com/volody/kernel-mashup?scriptVersionId=28811560)|
#
# <br>
#
# # [Getting started with 100+ flowers on TPU](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu)
#
# <a href="https://www.kaggle.com/fanjiawei" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-novice@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[fanjiawei](https://www.kaggle.com/fanjiawei)|
# |Language|Py|
# |Best Score|0.96362|
# |Votes|1|
# |Medal|-|
# |Comments|1|
# |Last Updated|This Notebook has collaborators.|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 28|0.95813|a month ago|1.8 h|+3|-3|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29983271)|
# |Version 27|0.95948|a month ago|1.2 h|+7|-7|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29980282)|
# |Version 26|0.95955|2 months ago|1.8 h|+35|-15|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29865057)|
# |Version 24|0.95523|2 months ago|1.6 h|+5|-3|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29828839)|
# |Version 23|0.95639|2 months ago|1.3 h|+1|-1|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29823442)|
# |Version 20|0.95972|2 months ago|1.3 h|+4|-2|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29670028)|
# |Version 18|0.95926|2 months ago|1.8 h|+210|-131|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29623416)|
# |Version 17|0.95668|2 months ago|2.8 h|+10|-10|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29144467)|
# |Version 14|0.95792|2 months ago|1.7 h|+35|-34|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29098586)|
# |Version 13|0.96189|2 months ago|2.6 h|+33|-33|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29091756)|
# |Version 12|0.95734|2 months ago|1.8 h|0|0|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29086342)|
# |Version 8|0.96043|2 months ago|1.5 h|+32|-31|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29055320)|
# |Version 6|0.96067|2 months ago|2.4 h|+2|-2|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=29048201)|
# |Version 3|0.96362|2 months ago|2.0 h|+79|-72|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=28998361)|
# |Version 1|0.95287|2 months ago|1.3 h|+118|-31|[Open](https://www.kaggle.com/fanjiawei/getting-started-with-100-flowers-on-tpu?scriptVersionId=28961712)|
#
# <br>
#
# # [Flowers on TPU: Ensemble + LR schedule](https://www.kaggle.com/msheriey/flowers-on-tpu-ensemble-lr-schedule)
#
# <a href="https://www.kaggle.com/msheriey" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/2510328-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-expert@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Mourad](https://www.kaggle.com/msheriey)|
# |Language|Py|
# |Best Score|0.96338|
# |Votes|41|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/silvers@1x.png" align="left">|
# |Comments|10|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 10|0.96295|2 months ago|1.4 h|+2|-2|[Open](https://www.kaggle.com/msheriey/flowers-on-tpu-ensemble-lr-schedule?scriptVersionId=28983405)|
# |Version 7|0.96338|2 months ago|1.4 h|+2|0|[Open](https://www.kaggle.com/msheriey/flowers-on-tpu-ensemble-lr-schedule?scriptVersionId=28529286)|
# |Version 5|0.93699|2 months ago|33.8 m|+2|-1|[Open](https://www.kaggle.com/msheriey/flowers-on-tpu-ensemble-lr-schedule?scriptVersionId=28524827)|
# |Version 3|0.95819|2 months ago|1.3 h|+3|-3|[Open](https://www.kaggle.com/msheriey/flowers-on-tpu-ensemble-lr-schedule?scriptVersionId=28521573)|
# |Forked from|0.96509|2 months ago|1.3 h|0|0|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet)|
#
# <br>
#
# # [Flowers on TPU II](https://www.kaggle.com/mmmarchetti/flowers-on-tpu-ii)
#
# <a href="https://www.kaggle.com/mmmarchetti" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/3393450-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-expert@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Marcos Martins Marchetti](https://www.kaggle.com/mmmarchetti)|
# |Language|Py|
# |Best Score|0.96322|
# |Votes|33|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/silvers@1x.png" align="left">|
# |Comments|6|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 10|0.96322|2 months ago|2.0 h|+205|-48|[Open](https://www.kaggle.com/mmmarchetti/flowers-on-tpu-ii?scriptVersionId=28549056)|
# |Version 8|0.94347|2 months ago|1.7 h|0|0|[Open](https://www.kaggle.com/mmmarchetti/flowers-on-tpu-ii?scriptVersionId=28502886)|
# |Version 6|0.60886|2 months ago|23.5 m|+354|-278|[Open](https://www.kaggle.com/mmmarchetti/flowers-on-tpu-ii?scriptVersionId=28472703)|
# |Version 3|0.35713|5 months ago|9.6 m|0|-16|[Open](https://www.kaggle.com/mmmarchetti/flowers-on-tpu-ii?scriptVersionId=24250431)|
# |Version 2|0.3217|5 months ago|12.6 m|0|0|[Open](https://www.kaggle.com/mmmarchetti/flowers-on-tpu-ii?scriptVersionId=24228313)|
# |Version 1|0.3217|5 months ago|12.1 m|0|0|[Open](https://www.kaggle.com/mmmarchetti/flowers-on-tpu-ii?scriptVersionId=24222391)|
# |Forked from|0.3217|5 months ago|9.8 m|0|0|[Open](https://www.kaggle.com/abazdyrev/use-features-oof)|
#
# <br>
#
# # [ENet B7 + DenseNet with TTA](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta)
#
# <a href="https://www.kaggle.com/gskdhiman" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1807868-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Gursewak Dhiman](https://www.kaggle.com/gskdhiman)|
# |Language|Py|
# |Best Score|0.96315|
# |Votes|11|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/bronzes@1x.png" align="left">|
# |Comments|3|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 15|0.95937|2 months ago|1.6 h|+6|-5|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=29407194)|
# |Version 10|0.95743|2 months ago|1.6 h|+7|-5|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=28921549)|
# |Version 9|0.96161|2 months ago|1.6 h|+3|-1|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=28865177)|
# |Version 7|0.95798|2 months ago|1.6 h|+8|-4|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=28809626)|
# |Version 6|0.96168|2 months ago|1.6 h|+2|-2|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=28805079)|
# |Version 5|0.9593|2 months ago|1.6 h|+8|-1|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=28804095)|
# |Version 4|0.96315|2 months ago|1.6 h|+2|0|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=28750320)|
# |Version 3|0.96207|2 months ago|1.6 h|0|0|[Open](https://www.kaggle.com/gskdhiman/enet-b7-densenet-with-tta?scriptVersionId=28704360)|
#
# <br>
#
# # [TPU: ENet B7 + Xception+Densnet201](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201)
#
# <a href="https://www.kaggle.com/anyexiezouqu" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/3146630-kg.jpeg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-expert@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[lixiangyang](https://www.kaggle.com/anyexiezouqu)|
# |Language|Py|
# |Best Score|0.9619|
# |Votes|14|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/bronzes@1x.png" align="left">|
# |Comments|4|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 17|0.95376|2 months ago|2.1 h|+48|-13|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=29177607)|
# |Version 16|0.96053|2 months ago|2.0 h|+15|-18|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=29097054)|
# |Version 15|0.9613|2 months ago|1.6 h|+1|-1|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=29039094)|
# |Version 13|0.95751|2 months ago|1.5 h|+9|-20|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=29034367)|
# |Version 11|0.95908|2 months ago|1.6 h|+2|-2|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28819857)|
# |Version 10|0.9599|2 months ago|1.0 h|+7|-6|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28803634)|
# |Version 9|0.9619|2 months ago|1.5 h|+4|-4|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28793136)|
# |Version 8|0.94233|2 months ago|2.7 h|+4|-4|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28780059)|
# |Version 6|0.96042|2 months ago|2.2 h|+9|-5|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28763827)|
# |Version 5|0.9551|2 months ago|1.8 h|+10|-4|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28746669)|
# |Version 3|0.95982|2 months ago|1.5 h|+42|-5|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28734127)|
# |Version 1|0.96143|2 months ago|1.4 h|0|0|[Open](https://www.kaggle.com/anyexiezouqu/tpu-enet-b7-xception-densnet201?scriptVersionId=28720894)|
# |Forked from|0.96509|2 months ago|1.4 h|0|0|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet)|
#
# <br>
#
# # [TPU: ENet B7 + DenseNet](https://www.kaggle.com/shank885/tpu-enet-b7-densenet)
#
# <a href="https://www.kaggle.com/shank885" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1793891-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Shashank Shekhar](https://www.kaggle.com/shank885)|
# |Language|Py|
# |Best Score|0.96182|
# |Votes|0|
# |Medal|-|
# |Comments|0|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 9|0.95695|2 months ago|2.3 h|+422|-267|[Open](https://www.kaggle.com/shank885/tpu-enet-b7-densenet?scriptVersionId=29444329)|
# |Version 8|0.96084|2 months ago|2.4 h|+196|-169|[Open](https://www.kaggle.com/shank885/tpu-enet-b7-densenet?scriptVersionId=29347585)|
# |Version 4|0.94786|2 months ago|1.2 h|+52|-51|[Open](https://www.kaggle.com/shank885/tpu-enet-b7-densenet?scriptVersionId=29184539)|
# |Version 3|0.95064|2 months ago|1.6 h|+9|-4|[Open](https://www.kaggle.com/shank885/tpu-enet-b7-densenet?scriptVersionId=28865878)|
# |Version 2|0.96182|2 months ago|1.5 h|+7|-7|[Open](https://www.kaggle.com/shank885/tpu-enet-b7-densenet?scriptVersionId=28840786)|
# |Version 1|0.96051|2 months ago|1.7 h|+3|-1|[Open](https://www.kaggle.com/shank885/tpu-enet-b7-densenet?scriptVersionId=28835708)|
# |Forked from|0.96509|2 months ago|1.4 h|0|0|[Open](https://www.kaggle.com/wrrosa/tpu-enet-b7-densenet)|
#
# <br>
#
# # [TPU: ENet B7 + DenseNet](https://www.kaggle.com/darwinwin/tpu-enet-b7-densenet)
#
# <a href="https://www.kaggle.com/darwinwin" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/4538297-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[darwinwin](https://www.kaggle.com/darwinwin)|
# |Language|Py|
# |Best Score|0.96112|
# |Votes|2|
# |Medal|-|
# |Comments|0|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 1|0.96112|2 months ago|2.4 h|0|0|[Open](https://www.kaggle.com/darwinwin/tpu-enet-b7-densenet?scriptVersionId=29410356)|
# |Forked from|0.95695|2 months ago|2.4 h|0|0|[Open](https://www.kaggle.com/shank885/tpu-enet-b7-densenet)|
#
# <br>
#
# # [ 4 KFold DenseNet201](https://www.kaggle.com/ragnar123/4-kfold-densenet201)
#
# <a href="https://www.kaggle.com/ragnar123" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/default-thumb.png" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-master@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[ragnar](https://www.kaggle.com/ragnar123)|
# |Language|Py|
# |Best Score|0.96043|
# |Votes|13|
# |Medal|<img alt="medal" src="https://www.kaggle.com/static/images/medals/discussion/bronzes@1x.png" align="left">|
# |Comments|2|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 11|0.95614|2 months ago|2.8 h|+4|-4|[Open](https://www.kaggle.com/ragnar123/4-kfold-densenet201?scriptVersionId=29076396)|
# |Version 2|0.96043|2 months ago|2.9 h|+1|-1|[Open](https://www.kaggle.com/ragnar123/4-kfold-densenet201?scriptVersionId=28666444)|
# |Version 1|0.95786|2 months ago|2.2 h|+243|0|[Open](https://www.kaggle.com/ragnar123/4-kfold-densenet201?scriptVersionId=28618774)|
#
# <br>
#
# # [Flower Classification with TPU](https://www.kaggle.com/shank885/flower-classification-with-tpu)
#
# <a href="https://www.kaggle.com/shank885" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1793891-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Shashank Shekhar](https://www.kaggle.com/shank885)|
# |Language|Py|
# |Best Score|0.96029|
# |Votes|0|
# |Medal|-|
# |Comments|0|
# |Last Updated|1mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 9|0.95883|a month ago|1.5 h|+3|-3|[Open](https://www.kaggle.com/shank885/flower-classification-with-tpu?scriptVersionId=30017442)|
# |Version 7|0.95951|2 months ago|1.5 h|+11|-7|[Open](https://www.kaggle.com/shank885/flower-classification-with-tpu?scriptVersionId=28782221)|
# |Version 6|0.96029|2 months ago|1.8 h|0|0|[Open](https://www.kaggle.com/shank885/flower-classification-with-tpu?scriptVersionId=28590934)|
# |Version 2|0.95121|2 months ago|52.0 m|+5|-22|[Open](https://www.kaggle.com/shank885/flower-classification-with-tpu?scriptVersionId=28544113)|
# |Version 1|0.95541|2 months ago|58.8 m|+64|-25|[Open](https://www.kaggle.com/shank885/flower-classification-with-tpu?scriptVersionId=28537357)|
# |Forked from|0.9444|2 months ago|51.2 m|0|0|[Open](https://www.kaggle.com/shank885/flowers-custom-data)|
#
# <br>
#
# # [Flower Classification with TPU](https://www.kaggle.com/darwinwin/flower-classification-with-tpu)
#
# <a href="https://www.kaggle.com/darwinwin" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/4538297-kg.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-contributor@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[darwinwin](https://www.kaggle.com/darwinwin)|
# |Language|Py|
# |Best Score|0.96018|
# |Votes|3|
# |Medal|-|
# |Comments|0|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 1|0.96018|2 months ago|1.5 h|0|0|[Open](https://www.kaggle.com/darwinwin/flower-classification-with-tpu?scriptVersionId=29422981)|
# |Forked from|0.95883|2 months ago|1.5 h|0|0|[Open](https://www.kaggle.com/shank885/flower-classification-with-tpu)|
#
# <br>
#
# # [Flower Classification: DNet201+ENetB7](https://www.kaggle.com/sanikamal/flower-classification-dnet201-enetb7)
#
# <a href="https://www.kaggle.com/sanikamal" style="display: inline-block"><img src="https://storage.googleapis.com/kaggle-avatars/thumbnails/1272482-gp.jpg" width="72"><img src="https://www.kaggle.com/static/images/avatier/avatier-expert@2x.png" width="72"></a>
#
# ### Kernel Information
# |Key|Value|
# |-|-|
# |Author|[Sani Kamal](https://www.kaggle.com/sanikamal)|
# |Language|Py|
# |Best Score|0.95959|
# |Votes|5|
# |Medal|-|
# |Comments|3|
# |Last Updated|2mo ago|
#
# ### Commit History
# |Version|Score|Committed at|Run Time|Added|Deleted|Link|
# |-|-|-|-|-|-|-|
# |Version 9|0.95959|2 months ago|1.4 h|+56|-32|[Open](https://www.kaggle.com/sanikamal/flower-classification-dnet201-enetb7?scriptVersionId=29094636)|
# |Version 8|0.9564|2 months ago|1.3 h|+35|-32|[Open](https://www.kaggle.com/sanikamal/flower-classification-dnet201-enetb7?scriptVersionId=28778097)|
# |Version 3|0.95828|2 months ago|1.0 h|+25|-25|[Open](https://www.kaggle.com/sanikamal/flower-classification-dnet201-enetb7?scriptVersionId=28683581)|
