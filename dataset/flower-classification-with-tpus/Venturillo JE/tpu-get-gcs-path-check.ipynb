# %%
from kaggle_datasets import KaggleDatasets
print('Flower Classification with TPUs check:')
prefix = KaggleDatasets().get_gcs_path("flower-classification-with-tpus")
print(prefix)
print('Digit Recognizer check:')
prefix = KaggleDatasets().get_gcs_path("digit-recognizer")
print(prefix)
print('BMS Molecular Translation check:')
prefix = KaggleDatasets().get_gcs_path("bms-molecular-translation")
print(prefix)
