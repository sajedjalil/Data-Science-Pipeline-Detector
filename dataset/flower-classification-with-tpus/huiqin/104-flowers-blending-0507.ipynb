# %% [markdown]
# # About
#
# This kernel was built for you in case you're running your work elsewhere and want to try out your submissions directly.

# %% [markdown]
# <font size=4 color='red'> If you find this kernel useful, please don't forget to upvote. Thank you. </font>

# %% [markdown]
# # Reminder
#
# Please note that in order to be eligible for this competition prizes, your submission can't be generated from this kernel but from machine learning code fully run on TPUs for both training and inference. That code must be made public following the end of the competition. Prizes are subject to fulfillment of Winners Obligations as specified in the competition's rules.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
os.listdir('../input/')
# Any results you write to the current directory are saved as output.

# %%
preds1=np.load('../input/tpu-enet-b7-densenet-random-cut/probs.npz')
preds1['a'].shape

# %%
preds2=np.load('../input/kernel4-aug/probs.npz')
preds2['a'].shape

# %%
preds4=np.load('../input/fork-of-tpu-enet-b7-incepentionresnetv2-densene/probs.npz')
preds4['a'].shape

# %%
preds3=np.load('../input/fork-of-fork-of-tpu-enet-b7-incepentionresnetv2/probs.npz')
preds3['a'].shape

# %% [markdown]
# ## 5fold b7

# %%
preds51=np.load('../input/5-kfold-efficentne-e7-p1/probs.npz')
preds51['a'].shape

# %%
preds52=np.load('../input/5-kfold-efficentne-e7-p2/probs.npz')
preds52['a'].shape

# %%
preds53=np.load('../input/5-kfold-efficentne-e7-p3/probs.npz')
preds53['a'].shape

# %%
preds54=np.load('../input/5-kfold-efficentne-e7-p4/probs.npz')
preds54['a'].shape

# %%
preds55=np.load('../input/5-kfold-efficentne-e7-p5/probs.npz')
preds55['a'].shape

# %%
preds55=(preds51['a']+preds52['a']+preds53['a']+preds54['a']+preds55['a'])/5

# %%
preds55=0.65*preds4['a']+0.35*preds55

# %%
preds=0.3*preds1['a']+0.3*preds2['a']+0.3*preds3['a']+0.1*preds55
preds.shape

# %%
del preds1,preds2,preds3,preds4,preds55
import gc
gc.collect()

# %%
#lb 0.96387
preds6=np.load('../input/flowertpuwin-densenet201/probs.npz')
preds6['a'].shape

# %%
#lb 0.96557
preds7=np.load('../input/flowertpuwin-densenet201/probs.npz')
preds7['a'].shape

# %%
#lb 0.96335
preds8=np.load('../input/tpu-enet-b7-incepention-b6-new/probs.npz')
preds8['a'].shape

# %%
preds=0.7*preds+0.3*(0.3*preds6['a']+0.4*preds7['a']+0.3*preds8['a'])
preds.shape

# %%
# help(np.argmax)
preds=np.argmax(preds, axis=1)
preds.shape

# %%
submission = pd.read_csv('/kaggle/input/flower-blending-v1/submission.csv')

submission.head()

# %%
submission1=submission.copy()
submission1['label']=preds
submission1.head()

# %%
submission1.to_csv('submission.csv', index=False)

# %%
submission1['y']=submission['label']
submission1.corr()
