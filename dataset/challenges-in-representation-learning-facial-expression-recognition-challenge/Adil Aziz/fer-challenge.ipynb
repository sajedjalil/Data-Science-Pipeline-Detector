# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train=pd.read_csv('/kaggle/input/challenges-in-representation-learning-facial-expression-recognition-challenge/train.csv')
train.head()
test=pd.read_csv('/kaggle/input/challenges-in-representation-learning-facial-expression-recognition-challenge/test.csv')
test.head()

# %%
train.head()

# %%
train.info()

# %%
train['pixels']=train['pixels'].apply(lambda x: np.fromstring(x,dtype=int,sep=' ').reshape(48,48))

# %%
train.info()

# %%
test['pixels']

# %%
train.head()

# %%
train.describe()

# %%
x=train.drop(['emotion'],axis=1)
y=train['emotion']

# %%
x.shape,y.shape

# %%
i=np.random.randint(1,len(train))
plt.imshow(train['pixels'][i],cmap='gray')
plt.show()

# %%
img=train['pixels']
img=img/255
x=np.empty((len(img),48,48,1))
x.shape

# %%
for i in range(len(img)):
    x[i,]=np.expand_dims(img[i],axis=2)

# %%
x=np.array(x).astype(np.float32)

# %%
from keras.utils import to_categorical
num_classes=7
y=np.array(y).astype(np.float32)
y=y.reshape(-1,1)
y.shape
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(sparse=False)
y=ohe.fit_transform(y)

# %%
x.shape,y.shape

# %%
y.shape

# %%
from keras.models import *
from keras.layers import *
from keras import models
from keras import layers
model=Sequential()

# %%
model=models.Sequential()
model.add(layers.Conv2D(32,(3,3),activation='elu',padding='same',input_shape=(48,48,1)))
model.add(layers.MaxPooling2D((2,2),padding='same'))

model.add(layers.Conv2D(64,(3,3),activation='elu',padding='same'))
model.add(layers.MaxPooling2D((2,2),padding='same'))

model.add(layers.Conv2D(128,(3,3),activation='elu',padding='same'))
model.add(layers.MaxPooling2D((2,2),padding='same'))

model.add(layers.Conv2D(128,(3,3),activation='elu',padding='same'))
model.add(layers.MaxPooling2D((2,2),padding='same'))

model.add(layers.GlobalAveragePooling2D())


model.add(layers.Flatten())
model.add(layers.Dense(64,activation='elu'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(7,activation='sigmoid'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

# %%
history=model.fit(x,y,epochs=50,batch_size=32)

# %%
model.save('fer_challenge.h5')

# %%
test['pixels']=test['pixels'].apply(lambda x: np.fromstring(x,dtype=int,sep=' ').reshape(48,48))

# %%
image=test['pixels']
image=image/255
w=np.empty((len(img),48,48,1))
w.shape

# %%
for i in range(len(image)):
    w[i,]=np.expand_dims(image[i],axis=2)

# %%
w=np.array(w).astype(np.float32)

# %%
y_pred=model.predict(w)

# %%
np.argmax(y_pred[0])

# %%
q=[]
for i in y_pred:
    s=np.argmax(i)
    q.append(s)

# %%
len(q)

# %%
df=pd.DataFrame(q,columns=['prediction'])

# %%
df.head()

# %%
y_pr=df['prediction']

# %%
output=pd.DataFrame()
output['pred']=y_pr
submission=output.to_csv('submission.csv',index=False)
