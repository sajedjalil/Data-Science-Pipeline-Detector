# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#To find the who details of the dataset
#import pandas_profiling
#df_train.profile_report()

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
pip install numpy

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import missingno as msno

# %%
df_train = pd.read_csv('/kaggle/input/bike-sharing-demand/train.csv')
df_test = pd.read_csv('/kaggle/input/bike-sharing-demand/test.csv')

# %%
df_train.head()

# %%
df_test.head()

# %%
test_datetime = df_test['datetime']

# %%
train_cols = df_train.columns
train_cols

# %%
test_cols = df_test.columns
test_cols

# %%
test_cols_match = list (test_cols)
train_cols_match = list(train_cols)
cols_match=[]
cols_nomatch=[]
#print("Outside" , test_cols_match)
for test_match in test_cols_match:
    #print("inside",test_match)
    for train_match in train_cols_match:
            #print("inside2",train_match)
            if train_match == test_match:
                #print(train_cols_match)
                #print(test_match)
                cols_match.append(test_match)
            else :
                cols_nomatch.append(test_match)
print("Matching column :" , cols_match)

# %%
print(test_cols_match)
print(train_cols_match)

# %%
df_train.select_dtypes(include = np.number).columns

# %%
#To find the categorical value
df_train.select_dtypes(exclude = np.number).columns

# %%
#To check the value is null or not
xt = df_train.isnull().sum()
xt

# %%
#To identify the total null value using histograph
plt.hist(x= xt)

# %%
df_train.info()

# %%
df_test.info()

# %%
#To find the missing value
plt.figure(figsize =(20,10))
#fig,ax = plt.subplots(figsize=(20, 10))
ax = msno.bar(df_train)

# %%
#To find the missing value in test data
msno.matrix(df_test)
#Incase its missing happen then we can replace it 
#df_test = df_test.replace("nan", np.nan)

# %%
#To find the value counts
df_train['season'].value_counts()

# %%
#Pandas to_datetime() method helps to convert string Date time into Python Date time object.
#Parameters: arg: An integer, string, float, list or dict object to convert in to Date time object.
df_train['datetime']= pd.to_datetime(df_train['datetime'])
df_train['year'] = df_train['datetime'].dt.year
df_train['month'] = df_train['datetime'].dt.month
df_train['date'] = df_train['datetime'].dt.date
df_train['hour'] = df_train['datetime'].dt.hour
df_train['minute'] = df_train['datetime'].dt.minute

# %%
df_train.head()

# %%
df_train.shape

# %%
df_test['datetime']= pd.to_datetime(df_test['datetime'])
df_test['year'] = df_test['datetime'].dt.year
df_test['month'] = df_test['datetime'].dt.month
df_test['date'] = df_test['datetime'].dt.date
df_test['hour'] = df_test['datetime'].dt.hour
df_test['minute'] = df_test['datetime'].dt.minute

# %%
df_test.head()

# %%
df_test.shape

# %%
df_train.columns

# %%
df_test.columns

# %%
df_test.drop(['datetime','atemp'],axis = 1,inplace = True)

# %%
df_train.drop(['atemp'],axis = 1,inplace = True)

# %%
df_train.drop(['datetime','casual','registered'],axis =1,inplace = True)

# %%
df_train.shape

# %%
df_test.shape

# %%
#To identify the skewness
target_skew = df_train['count']
plt.grid()
sns.distplot(target_skew,rug=True)
plt.show()
print("Skew value in count : " ,df_train['count'].skew())

# %%
#Apply log transform to reduce the skew
target_log = np.log(df_train['count'])
plt.grid()
sns.distplot(target_log,rug=True)
plt.show()
print("Skew value in count : " ,target_log.skew())

# %%
#target_sqrt = np.sqrt(df_train['count'])
#sns.distplot(target_sqrt,rug=True)
#print("Skew Value of square root :" , target_sqrt.skew())

# %%
from scipy import stats
target_box = stats.boxcox(df_train['count'])[0]
sns.distplot(target_box,rug=True)
print("Skew Value of Boxcox root :" ,pd.Series(target_box).skew())

# %%
sns.boxplot(df_train['count'])

# %%
df_train['count'] = target_box

# %%
sns.boxplot(df_train['count'])

# %%
train_cols_match

# %%
train_boxplot = df_train.columns
train_boxplot

# %%
i = 0
for a in train_boxplot:
    plt.figure(i)
    plt.grid()
    sns.boxplot(x = df_train[a],y = df_train['count'],data = df_train)
    plt.title(a)
    plt.show()
    i = 1+1

# %%
# select all rows that are not outliers
#mask = yhat != -1

# %%
from scipy import stats
i = 0
for at in train_boxplot:
    plt.figure(i)
    plt.grid()
    sns.boxplot(x = np.abs(stats.zscore(df_train[at])),data = df_train)
    plt.title(at)
    plt.show()
    i = 1+1

# %%
train_boxplot

# %%
sns.boxplot(x = np.abs(stats.zscore(df_train['workingday'])),data = df_train)

# %%
sns.countplot(x = df_train['season'] , data = df_train)
plt.show()

# %%
sns.lineplot(x = 'date' , y = 'count' ,data = df_train)
plt.show()

# %%
sns.lineplot(x = df_train['hour'],y = df_train['count'],data = df_train)
plt.show()

# %%
sns.lineplot(x = df_train['month'],y = df_train['count'],hue = 'weather',data = df_train)
plt.show()

# %%
#To find the comparison of month respective to holiday
sns.lineplot(x = df_train['month'],y = df_train['count'],hue = 'holiday',style = 'holiday',data = df_train)
plt.show()

# %%
sns.countplot(x=df_train['holiday'],hue = df_train['season'],data = df_train)
plt.show()

# %%
fig = plt.figure(figsize=[20,20])
sns.heatmap(df_train.corr(),annot=True,square=True)

# %%
df_train.shape

# %%
df_test.shape

# %%
df_train.columns

# %%
df_train['date'] = (df_train.date -df_train.date[0]).astype('timedelta64[D]')

# %%
df_test['date'] = (df_test.date -df_test.date[0]).astype('timedelta64[D]')

# %%
x = df_train.drop(['count'],axis = 1)
y = df_train['count'].astype(int)
y

# %%
#split the data to train the model 
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size = 0.3,random_state= 0)

# %%
X_train.shape,Y_train.shape

# %%
X_test.shape,Y_test.shape

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train,Y_train)
y_pred = rfr.predict(X_test)
y_pred

# %%
y_pred.shape,Y_test.shape

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(Y_test, y_pred))
print(rmse)

# %%
df_test['count'] = rfr.predict(df_test)
df_test['count']

# %%
df_train.shape,df_test.shape

# %%
df_train.columns

# %%
df_test.columns

# %%
submission = pd.DataFrame({'datetime':test_datetime,'count': df_test['count']})
submission.to_csv('submission.csv', index=False)

# %%
from IPython.display import FileLink
FileLink(r'submission.csv')

# %%
""""
#Hypertunning
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
#n_estimators = [int (x) for x in np.linespace(start = 200 , stop = 2000 , num = 10)]
n_estimators = [200,1000,1500]
# Number of features to consider at every split
max_features = ['auto','sqrt','log2']
# Maximum number of levels in tree
#max_depth = [int(x) for x in np.linspace(10, 1000,10)]
max_depth = [10, 1000,10]
# Minimum number of samples required to split a node
min_samples_split = [2,5,10,15]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['gini']}
print(random_grid)
rfrs = RandomForestRegressor()
rf_randomcv=RandomizedSearchCV(estimator=rfrs,param_distributions=random_grid,n_iter=100,cv=2,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf_randomcv.fit(X_train,Y_train)
rf_randomcv.best_params_
rf_randomcv
best_random_grid=rf_randomcv.best_estimator_
y_preds=best_random_grid.predict(X_test)
y_preds
""""""
