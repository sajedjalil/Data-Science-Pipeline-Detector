# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import seaborn as sns
import matplotlib.pyplot as plt 

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train=pd.read_csv('/kaggle/input/bike-sharing-demand/train.csv')
test=pd.read_csv('/kaggle/input/bike-sharing-demand/test.csv')

# %% [markdown]
# ## Checking the range of data and distribution of data

# %%
train['datetime']=pd.to_datetime(train['datetime'])
print(train['datetime'].dt.year.unique())
print(train['datetime'].dt.month.unique())
print(train['datetime'].dt.hour.unique())
print(train['datetime'].dt.minute.unique())

# %% [markdown]
# ## Cheking duplicates and null values

# %%
print (train.drop_duplicates().count())
print (train.count())
print (train.isnull().sum())
## There are no duplicates and null values

# %%
train.info()

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))

sns.distplot(train.season, kde=False, ax=axs[0])
sns.boxplot(train.season, ax=axs[1], orient = 'v')

# %%
train.holiday.unique()

# %%
train.workingday.unique()

# %%
train.weather.unique()

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))
sns.distplot(train.temp, kde=False, ax=axs[0])
sns.boxplot(train.temp, ax=axs[1], orient = 'v')

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))
sns.distplot(train.atemp, kde=False, ax=axs[0])
sns.boxplot(train.atemp, ax=axs[1], orient = 'v')

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))
sns.distplot(train.humidity, kde=False, ax=axs[0])
sns.boxplot(train.humidity, ax=axs[1], orient = 'v')

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))
sns.distplot(train.windspeed, kde=False, ax=axs[0])
sns.boxplot(train.windspeed, ax=axs[1], orient = 'v')

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))
sns.distplot(train.casual, kde=False, ax=axs[0])
sns.boxplot(train.casual, ax=axs[1], orient = 'v')

#train.info()

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))
sns.distplot(train.registered, kde=False, ax=axs[0])
sns.boxplot(train.registered, ax=axs[1], orient = 'v')

# %%
plots, axs = plt.subplots(ncols = 2, figsize=(13, 4))
sns.distplot(train['count'], kde=False, ax=axs[0])
sns.boxplot(train['count'], ax=axs[1], orient = 'v')

# %%
train['count'].median()
