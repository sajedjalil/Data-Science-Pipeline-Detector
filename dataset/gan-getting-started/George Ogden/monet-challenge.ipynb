# %% [markdown]
# Checkout V2 for implementation

# %%
# !mkdir images && cp ../input/cutmonet-submission/* images -r

# %%
import shutil
shutil.make_archive("/kaggle/working/images","zip","images")

# %%
# !rm -rf images
