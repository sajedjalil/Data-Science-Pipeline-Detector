# %%
from kaggle_datasets import KaggleDatasets

GCS_PATH = KaggleDatasets().get_gcs_path("gan-getting-started")
CHOSEN_MONET_DS_GCS_PATH = KaggleDatasets().get_gcs_path("chosen-monet-ds")
print(GCS_PATH)
print(CHOSEN_MONET_DS_GCS_PATH)
