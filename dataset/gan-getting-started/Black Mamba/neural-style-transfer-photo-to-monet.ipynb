# %% [markdown]
# ## Import Necessary Libraries

# %%
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Load pre-trained model

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %% [markdown]
# ### function to load image and display

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels = 3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis , :]
    return img

# %%
def plot(content_image, style_image):
    plt.figure(figsize = (10,10))
    plt.subplot(1,2,1)
    plt.title("content_image",size = 16)
    plt.imshow(np.squeeze(content_image))
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.title("style_image",size = 16)
    plt.imshow(np.squeeze(style_image))
    plt.axis('off')
    plt.show()
 
def plot_pair(content_image, style_image, stylized_image):
    plt.figure(figsize = (17,10))
    plt.subplot(1,3,1)
    plt.title("content_image",size = 16)
    plt.imshow(np.squeeze(content_image))
    plt.axis('off')
    plt.subplot(1,3,2)
    plt.title("style_image",size = 16)
    plt.imshow(np.squeeze(style_image))
    plt.axis('off')

    plt.subplot(1,3,3)
    plt.title("stylized_image",size = 16)
    plt.imshow(np.squeeze(stylized_image))
    plt.axis('off')
    plt.show()

# %% [markdown]
# #### Plotting  images

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/00e1798585.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/184d6c66cd.jpg')
plot(content_image,style_image)
print("===="*38)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/00dcf0f1e3.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/118da0690c.jpg')
plot(content_image,style_image)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/003aab6fdd.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/17557a29cb.jpg')
plot(content_image,style_image)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/023eed0385.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/3417ace946.jpg')
plot(content_image,style_image)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/02001e59af.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/4260d1c556.jpg')
plot(content_image,style_image)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/03fe5d2263.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/599098859e.jpg')
plot(content_image,style_image)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/05557b0148.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/676a5a4c2e.jpg')
plot(content_image,style_image)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %%
content_image = load_image('../input/gan-getting-started/photo_jpg/05e37a8900.jpg')
style_image = load_image('../input/gan-getting-started/monet_jpg/608ee0d370.jpg')
plot(content_image,style_image)
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plot_pair(content_image,style_image,stylized_image)

# %% [markdown]
# ## Thank You !!
