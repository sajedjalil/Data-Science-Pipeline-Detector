# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# # seti

# %%
img = np.load('../input/seti-breakthrough-listen/train/0/00034abb3629.npy')

# %%
img.dtype

# %%
print(img.shape)
print(6 * 273 * 256)
npshape = 6 * 273 * 256

# %%
img = tf.io.read_file('../input/seti-breakthrough-listen/train/0/00034abb3629.npy')

# %%
img = tf.io.decode_raw(img, tf.float16)

# %%
tensorshape = img.shape[0]

# %%
tensorshape - npshape

# %%
print(img[64:]) # npy value

# %% [markdown]
# # g2net

# %%
img = np.load('../input/g2net-gravitational-wave-detection/train/0/0/0/00000e74ad.npy')

# %%
img.dtype

# %%
print(img.shape)
print(3 * 4096)
npshape = 3 * 4096

# %%
img = tf.io.read_file('../input/g2net-gravitational-wave-detection/train/0/0/0/00000e74ad.npy')

# %%
img = tf.io.decode_raw(img, tf.float64)

# %%
tensorshape = img.shape[0]

# %%
tensorshape - npshape

# %%
print(img[16:]) # npy value

# %% [markdown]
# # conclusion

# %%
dtype=32
remove_len = 1024//dtype
img = img[remove_len:]
