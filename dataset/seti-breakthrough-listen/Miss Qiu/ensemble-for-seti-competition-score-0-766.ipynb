# %% [markdown]
# This is an ensemble of public notebooks available for this competition as below, kindly upvote and appreciate the original authors for their work. The credit of this notebook goes entirely to them
#
# * rerun-seti-e-t-volo-d1-baseline-inference
# * fixed-gradual-warmup-custom-head
# * seti-learned-image-resizing
# * lb-0-980-efficientnet-b0-more-epoch
# * inference-5x-ensemble-vanilla-resnet34d-seti
# * one-stop-understanding-eda-efficientnet
# * ensemble-for-seti-competition

# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv("../input/rerun-seti-e-t-volo-d1-baseline-inference/submission.csv")
data2 = pd.read_csv("../input/lb-0-980-efficientnet-b0-more-epoch/submission.csv")
data3 = pd.read_csv("../input/inference-5x-ensemble-vanilla-resnet34d-seti/submission.csv")
data4 = pd.read_csv("../input/seti-learned-image-resizing/submission.csv")
data5 = pd.read_csv("../input/rerun-seti-e-t-resnet18d-baseline/submission.csv")
data6 = pd.read_csv("../input/ensemble-for-seti-competition/submission.csv")
data7 = pd.read_csv("../input/fixed-gradual-warmup-custom-head/submission.csv")

# %%
data11 = data1

# %%
data11["target"] = 0.10*data1["target"]+0.10*data2["target"] + 0.10*data3["target"] + 0.10*data4["target"]+ 0.15*data5["target"]+ 1*data6["target"]

# %%
data11.to_csv("submission.csv",index=False)
