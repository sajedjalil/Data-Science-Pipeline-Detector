# %%
import requests

# %%
with open('../input/demo-class-2/demo_2.txt','r') as file:
    data = file.readlines()

# %%
# !mkdir demo

# %%
data = data[0:-1]
for i, url in enumerate(data):
    r = requests.get(url)
    with open('./demo/'+ str(i)+'.jpg','wb') as f:
        f.write(r.content)

# %%
# !zip demo_2.zip demo
