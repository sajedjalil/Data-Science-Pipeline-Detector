# %% [markdown]
# This is an ensemble of public notebooks available for this competition as below, kindly upvote and appreciate the original authors for their work. The credit of this notebook goes entirely to them
#
# * rerun-seti-e-t-volo-d1-baseline-inference
# * seti-bl-spatial-info-tf-tpu
# * seti-bl-tf-starter-tpu
# * seti-learned-image-resizing
# * lb-0-980-efficientnet-b0-more-epoch
# * inference-5x-ensemble-vanilla-resnet34d-seti
# * one-stop-understanding-eda-efficientnet
# * old-data-vs-new-data
# * setietyuta
# * rerun-seti-e-t-resnet18d-baseline
# * fixed-gradual-warmup-custom-head

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
data1 = pd.read_csv("../input/rerun-seti-e-t-volo-d1-baseline-inference/submission.csv") #0.727 --
data2 = pd.read_csv("../input/seti-bl-spatial-info-tf-tpu/submission.csv") #0.673
data3 = pd.read_csv("../input/seti-bl-tf-starter-tpu/submission.csv") #0.641
data4 = pd.read_csv("../input/setietyuta/submissio.csv") #0.749 --x
data5 = pd.read_csv("../input/lb-0-980-efficientnet-b0-more-epoch/submission.csv") #0.750 --
data6 = pd.read_csv("../input/inference-5x-ensemble-vanilla-resnet34d-seti/submission.csv") #0.725 --
data7 = pd.read_csv("../input/one-stop-understanding-eda-efficientnet/submission.csv") #0.705
data8 = pd.read_csv("../input/old-data-vs-new-data/new_submission.csv") #0.715
#data9 = pd.read_csv("../input/seti-learned-image-resizing-22e87b/submission.csv") #0.757 --
data10 = pd.read_csv("../input/fixed-gradual-warmup-custom-head/submission.csv") #0.731 --x
data11 = pd.read_csv("../input/ensemble-for-seti-competition-score-0-760/submission.csv") #0.760 ---
data12 = pd.read_csv("../input/rerun-seti-e-t-resnet18d-baseline/submission.csv") #0.726 --
data13 = pd.read_csv("../input/seti-learned-image-resizing-e2194f/submission.csv") #0.765
data14 = pd.read_csv("../input/seti-b7-best/best_score_tta_submission.csv")#0.769
#data15 = pd.read_csv("../input/ensemble-for-seti-competition-594df9/submission.csv")#0.767
data17 = pd.read_csv("../input/seti-b6/best_score_tta_submission (1).csv")#0.759
data18 = pd.read_csv("../input/seti-bset-0775/hy-tmpSETI_ETSSsubmBSL4_BackBonesV14best_score_tta_submission.csv.csv")#0.775
data19 = pd.read_csv("../input/seti-b7-bset-078/best_score_tta_submission.csv")#0.7815
data20 = pd.read_csv("../input/seti-b7-bset-078/best_score_submission.csv")#0.7778

# %%
data16 = data1
data16["target"] = 0.025*data1["target"]+0.025*data5["target"] + 0.025*data6["target"] + 0.025*data12["target"] + 0.025*data11["target"] +0.025*data4["target"] + 0.025*data10["target"] + 0.025*data13["target"] + 0.325*data14["target"] + 0.025*data17["target"]+ 0.125*data18["target"]+ 0.8025*data19["target"] + 0.025*data20["target"]

# %%
data16.to_csv("submission.csv",index=False)

# %%
data16.head()
