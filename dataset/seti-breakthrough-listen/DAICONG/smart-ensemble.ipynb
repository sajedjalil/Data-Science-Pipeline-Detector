# %% [markdown]
# ## Please Upvote, Before Fork.

# %% [markdown]
# This is an ensemble of public notebooks available for this competition as below, kindly upvote and appreciate the original authors for their work. The credit of this notebook goes entirely to them
#
# * rerun-seti-e-t-volo-d1-baseline-inference
# * seti-bl-spatial-info-tf-tpu
# * seti-bl-tf-starter-tpu
# * seti-learned-image-resizing
# * lb-0-980-efficientnet-b0-more-epoch
# * inference-5x-ensemble-vanilla-resnet34d-seti

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
data1 = pd.read_csv("../input/rerun-seti-e-t-volo-d1-baseline-inference/submission.csv")
data2 = pd.read_csv("../input/seti-bl-spatial-info-tf-tpu/submission.csv")
data3 = pd.read_csv("../input/seti-bl-tf-starter-tpu/submission.csv")
data4 = pd.read_csv("../input/seti-learned-image-resizing/submission.csv")
data5 = pd.read_csv("../input/lb-0-980-efficientnet-b0-more-epoch/submission.csv")
data6 = pd.read_csv("../input/inference-5x-ensemble-vanilla-resnet34d-seti/submission.csv")
data6 = pd.read_csv("../input/seti-b401/submission.csv")

# %%
data1.head()

# %%
data2.head()

# %%
data6 = data1
data6["target"] = 0.65*data5["target"]+0.125*data4["target"] + 0.125*data6["target"] + 0.00*data2["target"] + 0.0*data3["target"] + 0.1*data6["target"]

# %%
data6.to_csv("submission.csv",index=False)
