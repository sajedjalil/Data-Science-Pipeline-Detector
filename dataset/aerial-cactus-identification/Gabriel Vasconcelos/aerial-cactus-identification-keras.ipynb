# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, BatchNormalization, Dropout, LeakyReLU, DepthwiseConv2D, Flatten
from keras.layers.pooling import GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

from sklearn.metrics import confusion_matrix, roc_auc_score, classification_report
from sklearn.model_selection import train_test_split

from tqdm import tqdm, tqdm_notebook

import numpy as np
import pandas as pd
import cv2 as cv
import seaborn as sns
import matplotlib.pyplot as plt

import os
# Out:
# Using TensorFlow backend.

# %%
os.listdir('../input')
# Out:
# ['train', 'test', 'train.csv', 'sample_submission.csv']

# %%
train_data = pd.read_csv('../input/train.csv')

# %%
train_data.head()
# Out:
#                                      id  has_cactus
# 0  0004be2cfeaba1c0361d39e2b000257b.jpg           1
# 1  000c8a36845c0208e833c79c1bffedd1.jpg           1
# 2  000d1e9a533f62e55c289303b072733d.jpg           1
# 3  0011485b40695e9138e92d0b3fb55128.jpg           1
# 4  0014d7a11e90b62848904c1418fc8cf2.jpg           1

# %%
def create_model():
    model = Sequential()
        
    model.add(Conv2D(3, kernel_size = 3, activation = 'relu', input_shape = (32, 32, 3)))
    
    model.add(Conv2D(filters = 16, kernel_size = 3, activation = 'relu'))
    model.add(Conv2D(filters = 16, kernel_size = 3, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    model.add(DepthwiseConv2D(kernel_size = 3, strides = 1, padding = 'Same', use_bias = True))
    model.add(Conv2D(filters = 32, kernel_size = 1, activation = 'relu'))
    model.add(Conv2D(filters = 64, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    model.add(DepthwiseConv2D(kernel_size = 3, strides = 2, padding = 'Same', use_bias = True))
    model.add(Conv2D(filters = 128, kernel_size = 1, activation = 'relu'))
    model.add(Conv2D(filters = 256, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    model.add(DepthwiseConv2D(kernel_size = 3, strides = 1, padding = 'Same', use_bias = True))
    model.add(Conv2D(filters = 256, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(filters = 512, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    model.add(DepthwiseConv2D(kernel_size = 3, strides = 2, padding = 'Same', use_bias = True))
    model.add(Conv2D(filters = 512, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(filters = 1024, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    model.add(DepthwiseConv2D(kernel_size = 3, strides = 1, padding = 'Same', use_bias = True))
    model.add(Conv2D(filters = 1024, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(filters = 2048, kernel_size = 1, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    #model.add(GlobalAveragePooling2D())
    model.add(Flatten())
    
    model.add(Dense(470, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(256, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(128, activation = 'tanh'))

    model.add(Dense(1, activation = 'sigmoid'))

    model.compile(optimizer = 'rmsprop', loss = 'mean_squared_error', metrics = ['accuracy'])
    
    return model

# %%
def plot_training_curves(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(1, len(acc) + 1)
    
    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'g', label='Validation loss')
    plt.title('Losses')
    plt.legend()
    plt.figure()
    
    plt.plot(epochs, acc, 'r', label='Training acc')
    plt.plot(epochs, val_acc, 'g', label='Validation acc')
    plt.title('Accuracies')
    plt.legend()
    plt.figure()
    
    plt.show()

# %%
file_path = 'weights-aerial-cactus.h5'

callbacks = [
        ModelCheckpoint(file_path, monitor = 'val_acc', verbose = 1, save_best_only = True, mode = 'max'),
        ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 3, verbose = 1, mode = 'min', min_lr = 0.00001),
        EarlyStopping(monitor = 'val_loss', min_delta = 1e-10, patience = 15, verbose = 1, restore_best_weights = True)
        ]

training_path = '../input/train/train/'
test_path = '../input/test/test/'

# %%
images_train = []
labels_train = []

images = train_data['id'].values
for image_id in tqdm_notebook(images):
    
    image = np.array(cv.imread(training_path + image_id))
    label = train_data[train_data['id'] == image_id]['has_cactus'].values[0]
    
    images_train.append(image)
    labels_train.append(label)
    
    images_train.append(np.flip(image))
    labels_train.append(label)
    
    images_train.append(np.flipud(image))
    labels_train.append(label)
    
    images_train.append(np.fliplr(image))
    labels_train.append(label)
    
    
images_train = np.asarray(images_train)
images_train = images_train.astype('float32')
images_train /= 255.

labels_train = np.asarray(labels_train)
# Out:
# HBox(children=(IntProgress(value=0, max=17500), HTML(value='')))

# %%
x_tr = images_train
y_tr = labels_train

images_train = x_tr
labels_train = y_tr

# %%
test_images_names = []

for filename in os.listdir(test_path):
    test_images_names.append(filename)
    
test_images_names.sort()

images_test = []

for image_id in tqdm_notebook(test_images_names):
    images_test.append(np.array(cv.imread(test_path + image_id)))
    
images_test = np.asarray(images_test)
images_test = images_test.astype('float32')
images_test /= 255
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
x_train, x_test, y_train, y_test = train_test_split(images_train, labels_train, test_size = 0.2, stratify = labels_train)

# %%
model = create_model()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
history = model.fit(x_train, 
            y_train, 
            batch_size = 128, 
            epochs = 80, 
            validation_data = (x_test, y_test),
            verbose = 1,
            callbacks = callbacks)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 56000 samples, validate on 14000 samples
# Epoch 1/80
# 56000/56000 [==============================] - 49s 870us/step - loss: 0.0501 - acc: 0.9361 - val_loss: 0.0269 - val_acc: 0.9688
#
# Epoch 00001: val_acc improved from -inf to 0.96879, saving model to weights-aerial-cactus.h5
# Epoch 2/80
# 56000/56000 [==============================] - 42s 749us/step - loss: 0.0137 - acc: 0.9825 - val_loss: 0.0190 - val_acc: 0.9788
#
# Epoch 00002: val_acc improved from 0.96879 to 0.97879, saving model to weights-aerial-cactus.h5
# Epoch 3/80
# 56000/56000 [==============================] - 42s 747us/step - loss: 0.0077 - acc: 0.9903 - val_loss: 0.0294 - val_acc: 0.9677
#
# Epoch 00003: val_acc did not improve from 0.97879
# Epoch 4/80
# 56000/56000 [==============================] - 42s 744us/step - loss: 0.0043 - acc: 0.9945 - val_loss: 0.0073 - val_acc: 0.9919
#
# Epoch 00004: val_acc improved from 0.97879 to 0.99193, saving model to weights-aerial-cactus.h5
# Epoch 5/80
# 56000/56000 [==============================] - 42s 746us/step - loss: 0.0035 - acc: 0.9957 - val_loss: 0.0034 - val_acc: 0.9963
#
# Epoch 00005: val_acc improved from 0.99193 to 0.99629, saving model to weights-aerial-cactus.h5
# Epoch 6/80
# 56000/56000 [==============================] - 42s 747us/step - loss: 0.0026 - acc: 0.9969 - val_loss: 0.0181 - val_acc: 0.9799
#
# Epoch 00006: val_acc did not improve from 0.99629
# Epoch 7/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 0.0020 - acc: 0.9976 - val_loss: 0.0071 - val_acc: 0.9920
#
# Epoch 00007: val_acc did not improve from 0.99629
# Epoch 8/80
# 56000/56000 [==============================] - 42s 745us/step - loss: 0.0019 - acc: 0.9977 - val_loss: 0.0033 - val_acc: 0.9964
#
# Epoch 00008: val_acc improved from 0.99629 to 0.99636, saving model to weights-aerial-cactus.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 9/80
# 56000/56000 [==============================] - 42s 748us/step - loss: 8.3899e-04 - acc: 0.9990 - val_loss: 1.9468e-04 - val_acc: 0.9997
#
# Epoch 00009: val_acc improved from 0.99636 to 0.99971, saving model to weights-aerial-cactus.h5
# Epoch 10/80
# 56000/56000 [==============================] - 42s 746us/step - loss: 5.3462e-04 - acc: 0.9993 - val_loss: 3.3295e-04 - val_acc: 0.9996
#
# Epoch 00010: val_acc did not improve from 0.99971
# Epoch 11/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 3.2229e-04 - acc: 0.9996 - val_loss: 3.4762e-04 - val_acc: 0.9996
#
# Epoch 00011: val_acc did not improve from 0.99971
# Epoch 12/80
# 56000/56000 [==============================] - 42s 745us/step - loss: 2.8185e-04 - acc: 0.9997 - val_loss: 4.5737e-04 - val_acc: 0.9995
#
# Epoch 00012: val_acc did not improve from 0.99971
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 13/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 3.4445e-04 - acc: 0.9996 - val_loss: 3.1002e-04 - val_acc: 0.9996
#
# Epoch 00013: val_acc did not improve from 0.99971
# Epoch 14/80
# 56000/56000 [==============================] - 42s 745us/step - loss: 2.3017e-04 - acc: 0.9997 - val_loss: 1.7833e-04 - val_acc: 0.9998
#
# Epoch 00014: val_acc improved from 0.99971 to 0.99979, saving model to weights-aerial-cactus.h5
# Epoch 15/80
# 56000/56000 [==============================] - 42s 746us/step - loss: 2.0213e-04 - acc: 0.9997 - val_loss: 2.2195e-04 - val_acc: 0.9998
#
# Epoch 00015: val_acc did not improve from 0.99979
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 16/80
# 56000/56000 [==============================] - 42s 748us/step - loss: 1.7140e-04 - acc: 0.9998 - val_loss: 2.2845e-04 - val_acc: 0.9998
#
# Epoch 00016: val_acc did not improve from 0.99979
# Epoch 17/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 1.3301e-04 - acc: 0.9999 - val_loss: 2.6794e-04 - val_acc: 0.9997
#
# Epoch 00017: val_acc did not improve from 0.99979
# Epoch 18/80
# 56000/56000 [==============================] - 42s 745us/step - loss: 1.8571e-04 - acc: 0.9998 - val_loss: 2.6418e-04 - val_acc: 0.9997
#
# Epoch 00018: val_acc did not improve from 0.99979
# Epoch 19/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 1.9024e-04 - acc: 0.9998 - val_loss: 2.7806e-04 - val_acc: 0.9996
#
# Epoch 00019: val_acc did not improve from 0.99979
# Epoch 20/80
# 56000/56000 [==============================] - 42s 744us/step - loss: 2.3020e-04 - acc: 0.9997 - val_loss: 2.4477e-04 - val_acc: 0.9997
#
# Epoch 00020: val_acc did not improve from 0.99979
# Epoch 21/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 1.9712e-04 - acc: 0.9998 - val_loss: 2.3970e-04 - val_acc: 0.9998
#
# Epoch 00021: val_acc did not improve from 0.99979
# Epoch 22/80
# 56000/56000 [==============================] - 42s 744us/step - loss: 2.5062e-04 - acc: 0.9997 - val_loss: 2.2090e-04 - val_acc: 0.9998
#
# Epoch 00022: val_acc did not improve from 0.99979
# Epoch 23/80
# 56000/56000 [==============================] - 42s 744us/step - loss: 1.2605e-04 - acc: 0.9999 - val_loss: 2.2766e-04 - val_acc: 0.9998
#
# Epoch 00023: val_acc did not improve from 0.99979
# Epoch 24/80
# 56000/56000 [==============================] - 42s 746us/step - loss: 2.0962e-04 - acc: 0.9997 - val_loss: 2.1940e-04 - val_acc: 0.9998
#
# Epoch 00024: val_acc did not improve from 0.99979
# Epoch 25/80
# 56000/56000 [==============================] - 42s 744us/step - loss: 2.1371e-04 - acc: 0.9997 - val_loss: 2.1230e-04 - val_acc: 0.9998
#
# Epoch 00025: val_acc did not improve from 0.99979
# Epoch 26/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 2.5107e-04 - acc: 0.9997 - val_loss: 2.4328e-04 - val_acc: 0.9997
#
# Epoch 00026: val_acc did not improve from 0.99979
# Epoch 27/80
# 56000/56000 [==============================] - 42s 744us/step - loss: 2.2562e-04 - acc: 0.9997 - val_loss: 2.0872e-04 - val_acc: 0.9998
#
# Epoch 00027: val_acc did not improve from 0.99979
# Epoch 28/80
# 56000/56000 [==============================] - 42s 743us/step - loss: 3.2997e-04 - acc: 0.9996 - val_loss: 1.9251e-04 - val_acc: 0.9998
#
# Epoch 00028: val_acc did not improve from 0.99979
# Epoch 29/80
# 56000/56000 [==============================] - 42s 744us/step - loss: 2.3102e-04 - acc: 0.9997 - val_loss: 2.1575e-04 - val_acc: 0.9998
#
# Epoch 00029: val_acc did not improve from 0.99979
# Restoring model weights from the end of the best epoch
# Epoch 00029: early stopping

# %%
model.load_weights(file_path)

# %%
predictions = model.predict(images_test, verbose = 1)
# Out:
# 4000/4000 [==============================] - 1s 306us/step

# %%
predictions
# Out:
# array([[9.9931699e-01],
#        [9.9931568e-01],
#        [8.9073181e-04],
#        ...,
#        [9.9928594e-01],
#        [9.9931777e-01],
#        [9.9931794e-01]], dtype=float32)

# %%
plot_training_curves(history)

# %%
y_pred_probability = model.predict_proba(x_tr)

y_pred = model.predict_classes(x_tr)
conf_matrix = confusion_matrix(y_tr, y_pred)
fig, ax = plt.subplots(figsize = (10, 10))

sns.heatmap(conf_matrix, annot = True, fmt = 'd', xticklabels = ['0', '1'], yticklabels = ['0', '1'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

print(classification_report(y_tr, y_pred, target_names = ['0','1']))
print("\n\n AUC: {:<0.4f}".format(roc_auc_score(y_tr, y_pred_probability)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     17456
#            1       1.00      1.00      1.00     52544
#
#    micro avg       1.00      1.00      1.00     70000
#    macro avg       1.00      1.00      1.00     70000
# weighted avg       1.00      1.00      1.00     70000
#
#
#
#  AUC: 1.0000

# %%
test_df = pd.read_csv('../input/sample_submission.csv')
X_test = []
images_test = test_df['id'].values

for img_id in tqdm_notebook(images_test):
    X_test.append(cv.imread(test_path + img_id))
    
X_test = np.asarray(X_test)
X_test = X_test.astype('float32')
X_test /= 255

y_test_pred = model.predict_proba(X_test)

test_df['has_cactus'] = y_test_pred
test_df.to_csv('aerial-cactus-submission.csv', index = False)
