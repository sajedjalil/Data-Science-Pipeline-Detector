# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))
import ast

# Any results you write to the current directory are saved as output.

import json
import ast
from collections import Counter
import time
import datetime
import os
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %% [markdown]
# #### We'll use the data prep part from the kernel [https://www.kaggle.com/artgor/eda-feature-engineering-and-model-interpretation](https://www.kaggle.com/artgor/eda-feature-engineering-and-model-interpretation). The main difference is that, when calculating top categories (such as genres, production companies, etc) we are using only the training dataset

# %% [markdown]
# # Import data

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')

# %%
# from this kernel: https://www.kaggle.com/gravix/gradient-in-a-box
dict_columns = ['belongs_to_collection', 'genres', 'production_companies',
                'production_countries', 'spoken_languages', 'Keywords', 'cast', 'crew']

# %%
def text_to_dict(df, columns_to_parse):
    for column in columns_to_parse:
        df[column] = df[column].apply(lambda x: {} if pd.isna(x) else ast.literal_eval(x) )
    return df

# %%
df_train_clean = text_to_dict(df_train,dict_columns)
df_test_clean = text_to_dict(df_test, dict_columns)

# %% [markdown]
# # Create new features

# %% [markdown]
# * ## Feature: `belongs_to_collection`
#  Create a binary variable for belonging to a collection

# %%
df_train_clean['has_collection'] = df_train_clean['belongs_to_collection'].apply(lambda x: len(x) if x != {} else 0)
df_test_clean['has_collection'] = df_test_clean['belongs_to_collection'].apply(lambda x: len(x) if x != {} else 0)

# %% [markdown]
# * ## Number of values: `genres, production_companies, production_countries, spoken_languages, Keywords, cast, crew`
# Create new features counting number of values of the features above

# %%
columns_to_select = ['genres', 'production_companies',
                'production_countries', 'spoken_languages', 'Keywords', 'cast', 'crew']

# %%
def number_of_values(df, columns):
    for column in columns:
        new_column_name = 'num_' + column
        df[new_column_name] = df[column].apply(lambda x: len(x) if x != {} else 0)
    return df

# %%
df_train_clean = number_of_values(df_train_clean, columns_to_select)
df_test_clean = number_of_values(df_test_clean, columns_to_select)

# %% [markdown]
# * ## List of values: `belongs_to_collection, genres, production_companies, production_countries, spoken_languages, Keywords, cast, crew`
# Create new features creating a list with names of the features above

# %%
def list_of_values(df, columns, key):
    for column in columns:
        new_column_name = 'all_' + column + '_' + key
        df[new_column_name] = df[column].apply(lambda x: ' '.join(sorted([i[key] for i in x])) if x != {} else '')
    return df

# %%
columns_to_select = ['belongs_to_collection', 'genres', 'production_companies',
                'production_countries', 'spoken_languages', 'Keywords', 'cast', 'crew']

# %%
df_train_clean = list_of_values(df_train_clean, columns_to_select, 'name')
df_test_clean = list_of_values(df_test_clean, columns_to_select, 'name')

# %% [markdown]
# * ## Top values: `belongs_to_collection, genres, production_companies, production_countries, languages_spoken, Keywords, cast, crew`
# Create new features for the top of names of the features above

# %%
columns_top_to_select = {'belongs_to_collection':32, 'genres': 10, 'production_companies': 20,
                'production_countries': 15, 'spoken_languages': 15, 'Keywords':30, 'cast':30, 'crew':20}

# %%
def top_values(df_calculate_top, df_apply_top, columns_to_select, key):
    for column, top_value in columns_to_select.items():
        list_of_values = df_calculate_top[column].apply(lambda x: [i[key] for i in x] if x != {} else []).values
        top_values = [m[0] for m in Counter([i for j in list_of_values for i in j]).most_common(top_value)]
        for value in top_values:
            df_apply_top[column+'_'+key+'_'+value] = df_apply_top['all_'+column+'_'+key].apply(lambda x: 1 if value in x else 0)
    return df_apply_top

# %%
df_train_clean = top_values(df_train_clean, df_train_clean, columns_top_to_select, 'name')
df_test_clean = top_values(df_train_clean, df_test_clean, columns_top_to_select, 'name')

# %% [markdown]
# * ## Feature: `cast`

# %% [markdown]
# Create features for **main characters** in cast

# %%
df_train_clean = list_of_values(df_train_clean, ['cast'], 'character')
df_test_clean = list_of_values(df_test_clean, ['cast'], 'character')

columns_top_to_select = {'cast': 10}
df_train_clean = top_values(df_train_clean, df_train_clean, columns_top_to_select, 'character')
df_test_clean = top_values(df_train_clean, df_test_clean, columns_top_to_select, 'character')

# %% [markdown]
# Create features for cast **genders**

# %%
#count gender
dict_gender = {0:'genunk', 1:'female', 2:'male'}

# %%
def count_gender(df, dict_gender, column, key):
    for k, v in dict_gender.items():
        df['num' + '_' + column + '_' + key + '_' + v] = df[column].apply(lambda x: sum([1 for i in x if i[key] == k]))
    return df

# %%
#cast gender
df_train_clean = count_gender(df_train_clean, dict_gender, 'cast', 'gender')
df_test_clean = count_gender(df_test_clean, dict_gender, 'cast', 'gender')

# %% [markdown]
# * ## Feature: `crew`

# %% [markdown]
# Create features for crew **genders**

# %%
#crew gender
df_train_clean = count_gender(df_train_clean, dict_gender, 'crew', 'gender')
df_test_clean = count_gender(df_test_clean, dict_gender, 'crew', 'gender')

# %% [markdown]
# Create features for crew main **directors / producers**

# %%
def top_jobs(df, all_values, column, new_column_name, top):
    top = [m[0] for m in Counter([i for j in all_values for i in j]).most_common(top)]
    for value in top:
        df[new_column_name+'_'+value] = df[column].apply(lambda x: 1 if value in str(x) else 0)
    return df

# %% [markdown]
# Main **directors**

# %%
list_directors = list(df_train_clean['crew'].apply(lambda x: [i['name'] for i in x if i['job'] == 'Director'] if x != {} else []).values)
df_train_clean = top_jobs(df_train_clean, list_directors, 'crew', 'director', 30)
df_test_clean = top_jobs(df_test_clean, list_directors, 'crew', 'director', 30)

# %% [markdown]
# Main **producers**

# %%
list_producers = list(df_train_clean['crew'].apply(lambda x: [i['name'] for i in x if i['job'] == 'Executive Producer'] if x != {} else []).values)
df_train_clean = top_jobs(df_train_clean, list_producers, 'crew', 'producer', 15)
df_test_clean = top_jobs(df_test_clean, list_producers, 'crew', 'producer', 15)

# %% [markdown]
# * ## Feature `release_date`
# Convert dates into date time formats

# %%
def fix_date(x):
    """
    Fixes dates which are in 20xx
    """
    year = x.split('/')[2]
    if int(year) <= 19:
        return x[:-2] + '20' + year
    else:
        return x[:-2] + '19' + year

# %%
df_test_clean.loc[df_test_clean['release_date'].isnull() == True, 'release_date'] = '01/01/98'

# %%
df_train_clean['release_date'] = df_train_clean['release_date'].apply(lambda x: fix_date(x))
df_test_clean['release_date'] = df_test_clean['release_date'].apply(lambda x: fix_date(x))
df_train_clean['release_date'] = pd.to_datetime(df_train_clean['release_date'])
df_test_clean['release_date'] = pd.to_datetime(df_test_clean['release_date'])

# %%
df_train_clean['year']=pd.DatetimeIndex(df_train_clean['release_date']).year
df_test_clean['year']=pd.DatetimeIndex(df_test_clean['release_date']).year
df_train_clean['month']=pd.DatetimeIndex(df_train_clean['release_date']).month
df_test_clean['month']=pd.DatetimeIndex(df_test_clean['release_date']).month
df_train_clean['yr_mth']=df_train_clean['year']*100+df_train_clean['month']
df_test_clean['yr_mth']=df_test_clean['year']*100+df_test_clean['month']

# %% [markdown]
# # Remove unecessary features

# %% [markdown]
# Remove all features which start by `all_`

# %%
def find_features_start_by(df, start):
    features = list(df)
    start_by = []
    for feature in features:
        if feature.startswith(start):
            start_by.append(feature)
    return start_by

# %%
#drop from train set
features_to_drop = find_features_start_by(df_train_clean, 'all_')
df_train_clean = df_train_clean.drop(features_to_drop, axis=1)

#drop from test set
df_test_clean = df_test_clean.drop(features_to_drop, axis=1)

# %% [markdown]
# Remove original features: `belongs_to_collection, genres, production_companies, production_countries, spoken_languages, Keywords, cast, crew`

# %%
original_features = ['belongs_to_collection', 'genres', 'production_companies', 'production_countries',
                     'spoken_languages', 'Keywords', 'cast', 'crew', 'release_date']

# %%
df_train_clean = df_train_clean.drop(original_features, axis=1)
df_test_clean = df_test_clean.drop(original_features, axis=1)

# %% [markdown]
# # Final data after preparation

# %% [markdown]
# Number of features

# %%
print('training set: ' + str(len(list(df_train_clean))) + ' features')
print('testing set: ' + str(len(list(df_test_clean))) + ' features')
# Out:
# training set: 258 features
# testing set: 257 features

# %%
i = 1
for column in list(df_train_clean.columns):
    print(str(i) + ' ' + column)
    i = i + 1
# Out:
# 1 id
# 2 budget
# 3 homepage
# 4 imdb_id
# 5 original_language
# 6 original_title
# 7 overview
# 8 popularity
# 9 poster_path
# 10 runtime
# 11 status
# 12 tagline
# 13 title
# 14 revenue
# 15 has_collection
# 16 num_genres
# 17 num_production_companies
# 18 num_production_countries
# 19 num_spoken_languages
# 20 num_Keywords
# 21 num_cast
# 22 num_crew
# 23 belongs_to_collection_name_James Bond Collection
# 24 belongs_to_collection_name_Friday the 13th Collection
# 25 belongs_to_collection_name_The Pink Panther (Original) Collection
# 26 belongs_to_collection_name_Police Academy Collection
# 27 belongs_to_collection_name_Pokémon Collection
# 28 belongs_to_collection_name_Rocky Collection
# 29 belongs_to_collection_name_Ice Age Collection
# 30 belongs_to_collection_name_The Fast and the Furious Collection
# 31 belongs_to_collection_name_Rambo Collection
# 32 belongs_to_collection_name_Alien Collection
# 33 belongs_to_collection_name_Resident Evil Collection
# 34 belongs_to_collection_name_Child's Play Collection
# 35 belongs_to_collection_name_Transformers Collection
# 36 belongs_to_collection_name_Paranormal Activity Collection
# 37 belongs_to_collection_name_Rush Hour Collection
# 38 belongs_to_collection_name_Qatsi Collection
# 39 belongs_to_collection_name_The Jaws Collection
# 40 belongs_to_collection_name_Diary of a Wimpy Kid Collection
# 41 belongs_to_collection_name_Missing in Action Collection
# 42 belongs_to_collection_name_Cars Collection
# 43 belongs_to_collection_name_Alex Cross Collection
# 44 belongs_to_collection_name_Mexico Trilogy
# 45 belongs_to_collection_name_Three Heroes Collection
# 46 belongs_to_collection_name_Indiana Jones Collection
# 47 belongs_to_collection_name_[REC] Collection
# 48 belongs_to_collection_name_The Vengeance Collection
# 49 belongs_to_collection_name_The Dark Knight Collection
# 50 belongs_to_collection_name_Halloween Collection
# 51 belongs_to_collection_name_Planet of the Apes Original Collection
# 52 belongs_to_collection_name_The Wolverine Collection
# 53 belongs_to_collection_name_Star Trek: The Original Series Collection
# 54 belongs_to_collection_name_Scary Movie Collection
# 55 genres_name_Drama
# 56 genres_name_Comedy
# 57 genres_name_Thriller
# 58 genres_name_Action
# 59 genres_name_Romance
# 60 genres_name_Crime
# 61 genres_name_Adventure
# 62 genres_name_Horror
# 63 genres_name_Science Fiction
# 64 genres_name_Family
# 65 production_companies_name_Warner Bros.
# 66 production_companies_name_Universal Pictures
# 67 production_companies_name_Paramount Pictures
# 68 production_companies_name_Twentieth Century Fox Film Corporation
# 69 production_companies_name_Columbia Pictures
# 70 production_companies_name_Metro-Goldwyn-Mayer (MGM)
# 71 production_companies_name_New Line Cinema
# 72 production_companies_name_Touchstone Pictures
# 73 production_companies_name_Walt Disney Pictures
# 74 production_companies_name_Columbia Pictures Corporation
# 75 production_companies_name_TriStar Pictures
# 76 production_companies_name_Relativity Media
# 77 production_companies_name_Canal+
# 78 production_companies_name_United Artists
# 79 production_companies_name_Miramax Films
# 80 production_companies_name_Village Roadshow Pictures
# 81 production_companies_name_Regency Enterprises
# 82 production_companies_name_BBC Films
# 83 production_companies_name_Dune Entertainment
# 84 production_companies_name_Working Title Films
# 85 production_countries_name_United States of America
# 86 production_countries_name_United Kingdom
# 87 production_countries_name_France
# 88 production_countries_name_Germany
# 89 production_countries_name_Canada
# 90 production_countries_name_India
# 91 production_countries_name_Italy
# 92 production_countries_name_Japan
# 93 production_countries_name_Australia
# 94 production_countries_name_Russia
# 95 production_countries_name_Spain
# 96 production_countries_name_China
# 97 production_countries_name_Hong Kong
# 98 production_countries_name_Ireland
# 99 production_countries_name_Belgium
# 100 spoken_languages_name_English
# 101 spoken_languages_name_Français
# 102 spoken_languages_name_Español
# 103 spoken_languages_name_Deutsch
# 104 spoken_languages_name_Pусский
# 105 spoken_languages_name_Italiano
# 106 spoken_languages_name_日本語
# 107 spoken_languages_name_普通话
# 108 spoken_languages_name_हिन्दी
# 109 spoken_languages_name_
# 110 spoken_languages_name_Português
# 111 spoken_languages_name_العربية
# 112 spoken_languages_name_한국어/조선말
# 113 spoken_languages_name_广州话 / 廣州話
# 114 spoken_languages_name_தமிழ்
# 115 Keywords_name_woman director
# 116 Keywords_name_independent film
# 117 Keywords_name_duringcreditsstinger
# 118 Keywords_name_murder
# 119 Keywords_name_based on novel
# 120 Keywords_name_violence
# 121 Keywords_name_sport
# 122 Keywords_name_biography
# 123 Keywords_name_aftercreditsstinger
# 124 Keywords_name_dystopia
# 125 Keywords_name_revenge
# 126 Keywords_name_friendship
# 127 Keywords_name_sex
# 128 Keywords_name_suspense
# 129 Keywords_name_sequel
# 130 Keywords_name_love
# 131 Keywords_name_police
# 132 Keywords_name_teenager
# 133 Keywords_name_nudity
# 134 Keywords_name_female nudity
# 135 Keywords_name_drug
# 136 Keywords_name_prison
# 137 Keywords_name_musical
# 138 Keywords_name_high school
# 139 Keywords_name_los angeles
# 140 Keywords_name_new york
# 141 Keywords_name_family
# 142 Keywords_name_father son relationship
# 143 Keywords_name_kidnapping
# 144 Keywords_name_investigation
# 145 cast_name_Samuel L. Jackson
# 146 cast_name_Robert De Niro
# 147 cast_name_Morgan Freeman
# 148 cast_name_J.K. Simmons
# 149 cast_name_Bruce Willis
# 150 cast_name_Liam Neeson
# 151 cast_name_Susan Sarandon
# 152 cast_name_Bruce McGill
# 153 cast_name_John Turturro
# 154 cast_name_Forest Whitaker
# 155 cast_name_Willem Dafoe
# 156 cast_name_Bill Murray
# 157 cast_name_Owen Wilson
# 158 cast_name_Nicolas Cage
# 159 cast_name_Sylvester Stallone
# 160 cast_name_Jason Statham
# 161 cast_name_Keith David
# 162 cast_name_John Goodman
# 163 cast_name_Mel Gibson
# 164 cast_name_Sigourney Weaver
# 165 cast_name_Frank Welker
# 166 cast_name_Michael Caine
# 167 cast_name_George Clooney
# 168 cast_name_Denzel Washington
# 169 cast_name_Robert Duvall
# 170 cast_name_Ed Harris
# 171 cast_name_Dennis Quaid
# 172 cast_name_Richard Jenkins
# 173 cast_name_Matt Damon
# 174 cast_name_Christopher Plummer
# 175 crew_name_Avy Kaufman
# 176 crew_name_Robert Rodriguez
# 177 crew_name_Deborah Aquila
# 178 crew_name_James Newton Howard
# 179 crew_name_Mary Vernieu
# 180 crew_name_Steven Spielberg
# 181 crew_name_Luc Besson
# 182 crew_name_Jerry Goldsmith
# 183 crew_name_Francine Maisler
# 184 crew_name_Tricia Wood
# 185 crew_name_James Horner
# 186 crew_name_Kerry Barden
# 187 crew_name_Bob Weinstein
# 188 crew_name_Harvey Weinstein
# 189 crew_name_Janet Hirshenson
# 190 crew_name_Jane Jenkins
# 191 crew_name_John Debney
# 192 crew_name_Hans Zimmer
# 193 crew_name_John Papsidera
# 194 crew_name_Francis Ford Coppola
# 195 cast_character_
# 196 cast_character_Himself
# 197 cast_character_Herself
# 198 cast_character_Dancer
# 199 cast_character_Additional Voices (voice)
# 200 cast_character_Doctor
# 201 cast_character_Reporter
# 202 cast_character_Waitress
# 203 cast_character_Nurse
# 204 cast_character_Bartender
# 205 num_cast_gender_genunk
# 206 num_cast_gender_female
# 207 num_cast_gender_male
# 208 num_crew_gender_genunk
# 209 num_crew_gender_female
# 210 num_crew_gender_male
# 211 director_Ron Howard
# 212 director_Clint Eastwood
# 213 director_Steven Spielberg
# 214 director_Blake Edwards
# 215 director_Woody Allen
# 216 director_Wes Craven
# 217 director_Martin Scorsese
# 218 director_Paul W.S. Anderson
# 219 director_Alfred Hitchcock
# 220 director_Michael Bay
# 221 director_Francis Ford Coppola
# 222 director_Brian De Palma
# 223 director_Steven Soderbergh
# 224 director_Joel Schumacher
# 225 director_Peter Hyams
# 226 director_Peter Jackson
# 227 director_Michael Mann
# 228 director_Robert Rodriguez
# 229 director_Tim Burton
# 230 director_Billy Wilder
# 231 director_Roger Donaldson
# 232 director_Ridley Scott
# 233 director_Garry Marshall
# 234 director_Wolfgang Petersen
# 235 director_Todd Phillips
# 236 director_Walter Hill
# 237 director_Ivan Reitman
# 238 director_Renny Harlin
# 239 director_Sidney Lumet
# 240 director_Oliver Stone
# 241 producer_Bob Weinstein
# 242 producer_Harvey Weinstein
# 243 producer_Bruce Berman
# 244 producer_Toby Emmerich
# 245 producer_Steven Spielberg
# 246 producer_Stan Lee
# 247 producer_Ryan Kavanaugh
# 248 producer_Frank Marshall
# 249 producer_Thomas Tull
# 250 producer_Liza Chasin
# 251 producer_Tessa Ross
# 252 producer_Ben Waisbren
# 253 producer_Gary Barber
# 254 producer_Richard Brener
# 255 producer_John Lasseter
# 256 year
# 257 month
# 258 yr_mth

# %%
df_train_clean.to_csv('../working/train_prep.csv', index=False)
df_test_clean.to_csv('../working/test_prep.csv', index=False)
