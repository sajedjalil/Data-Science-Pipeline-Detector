# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train = pd.read_csv('../input/tmdb-box-office-prediction/train.csv')
test = pd.read_csv('../input/tmdb-box-office-prediction/test.csv')

# %%
#The shapes of Train and test datas
print(train.shape)
print(test.shape)

# %%
#Filling in train data with real value
train.loc[train['id'] == 16,'revenue'] = 192864          # Skinning
train.loc[train['id'] == 90,'budget'] = 30000000         # Sommersby          
train.loc[train['id'] == 118,'budget'] = 60000000        # Wild Hogs
train.loc[train['id'] == 149,'budget'] = 18000000        # Beethoven
train.loc[train['id'] == 313,'revenue'] = 12000000       # The Cookout 
train.loc[train['id'] == 451,'revenue'] = 12000000       # Chasing Liberty
train.loc[train['id'] == 464,'budget'] = 20000000        # Parenthood
train.loc[train['id'] == 470,'budget'] = 13000000        # The Karate Kid, Part II
train.loc[train['id'] == 513,'budget'] = 930000          # From Prada to Nada
train.loc[train['id'] == 797,'budget'] = 8000000         # Welcome to Dongmakgol
train.loc[train['id'] == 819,'budget'] = 90000000        # Alvin and the Chipmunks: The Road Chip
train.loc[train['id'] == 850,'budget'] = 90000000        # Modern Times
train.loc[train['id'] == 1112,'budget'] = 7500000        # An Officer and a Gentleman
train.loc[train['id'] == 1131,'budget'] = 4300000        # Smokey and the Bandit   
train.loc[train['id'] == 1359,'budget'] = 10000000       # Stir Crazy 
train.loc[train['id'] == 1542,'budget'] = 1              # All at Once
train.loc[train['id'] == 1542,'budget'] = 15800000       # Crocodile Dundee II
train.loc[train['id'] == 1571,'budget'] = 4000000        # Lady and the Tramp
train.loc[train['id'] == 1714,'budget'] = 46000000       # The Recruit
train.loc[train['id'] == 1721,'budget'] = 17500000       # Cocoon
train.loc[train['id'] == 1865,'revenue'] = 25000000      # Scooby-Doo 2: Monsters Unleashed
train.loc[train['id'] == 2268,'budget'] = 17500000       # Madea Goes to Jail budget
train.loc[train['id'] == 2491,'revenue'] = 6800000       # Never Talk to Strangers
train.loc[train['id'] == 2602,'budget'] = 31000000       # Mr. Holland's Opus
train.loc[train['id'] == 2612,'budget'] = 15000000       # Field of Dreams
train.loc[train['id'] == 2696,'budget'] = 10000000       # Nurse 3-D
train.loc[train['id'] == 2801,'budget'] = 10000000       # Fracture


train.runtime[train.id == 391] = 86 #Il peor natagle de la meva vida
train.runtime[train.id == 592] = 90 #А поутру они проснулись
train.runtime[train.id == 925] = 95 #¿Quién mató a Bambi?
train.runtime[train.id == 978] = 93 #La peggior settimana della mia vita
train.runtime[train.id == 1256] = 92 #Cipolla Colt
train.runtime[train.id == 1542] = 93 #Все и сразу
train.runtime[train.id == 1875] = 86 #Vermist
train.runtime[train.id == 2151] = 108 #Mechenosets
train.runtime[train.id == 2499] = 108 #Na Igre 2. Novyy Uroven
train.runtime[train.id == 2646] = 98 #同桌的妳
train.runtime[train.id == 2786] = 111 #Revelation
train.runtime[train.id == 2866] = 96 #Tutto tutto niente niente

# TEST
test.runtime[test.id == 4074] = 103 #Shikshanachya Aaicha Gho
test.runtime[test.id == 4222] = 93 #Street Knight
test.runtime[test.id == 4431] = 100 #Плюс один
test.runtime[test.id == 5520] = 86 #Glukhar v kino
test.runtime[test.id == 5845] = 83 #Frau Müller muss weg!
test.runtime[test.id == 5849] = 140 #Shabd
test.runtime[test.id == 6210] = 104 #Le dernier souffle
test.runtime[test.id == 6804] = 145 #Chaahat Ek Nasha..
test.runtime[test.id == 7321] = 87 #El truco del manco

# %%
test.loc[test['id'] == 3889,'budget'] = 15000000       # Colossal
test.loc[test['id'] == 6733,'budget'] = 5000000        # The Big Sick
test.loc[test['id'] == 3197,'budget'] = 8000000        # High-Rise
test.loc[test['id'] == 6683,'budget'] = 50000000       # The Pink Panther 2
test.loc[test['id'] == 5704,'budget'] = 4300000        # French Connection II
test.loc[test['id'] == 6109,'budget'] = 281756         # Dogtooth
test.loc[test['id'] == 7242,'budget'] = 10000000       # Addams Family Values
test.loc[test['id'] == 7021,'budget'] = 17540562       #  Two Is a Family
test.loc[test['id'] == 5591,'budget'] = 4000000        # The Orphanage
test.loc[test['id'] == 4282,'budget'] = 20000000       # Big Top Pee-wee
test.loc[test['release_date'].isnull() == True, 'release_date'] = '10/19/2001'

# %%
budget_median=train[train['budget']>0]['budget'].median()
print(budget_median)
revenue_median=train[train['revenue']>0]['revenue'].median()
runtime_median_train = train[train['runtime']>0]['runtime'].median()
runtime_median_test = test[test['runtime']>0]['runtime'].median()
print(revenue_median)

# %%
cols_with_missing = [col for col in train.columns
                     if train[col].isnull().any()]

# %%
invalid_revenue = train.id[train.budget > 1000][train.revenue < 100]
for anId in invalid_revenue :
    train.loc[train['id'] == anId,'revenue'] =  revenue_median
    
train['runtime'] = train['runtime'].fillna(runtime_median_train)
    
test['runtime'] = test['runtime'].fillna(runtime_median_test)

# %%
train['budget_was_imputed'] = train['budget'].isnull()
test['budget_was_imputed'] = test['budget'].isnull()

invalid_budget_train = train.id[train.budget == 0]
for anId in invalid_budget_train:
    train.loc[train['id'] == anId,'budget'] =  budget_median
    train.loc[train['id'] == anId,'budget_was_imputed'] =  True
    
invalid_budget_test = test.id[test.budget == 0]
for anId in invalid_budget_test:
    test.loc[test['id'] == anId,'budget'] =  budget_median
    test.loc[test['id'] == anId,'budget_was_imputed'] =  True

# %%
train.head()

# %%
new_train=train.drop(['imdb_id','id', 'overview','poster_path','original_title', 'spoken_languages', 'status','tagline','title'], axis=1)
new_test=test.drop(['imdb_id','id', 'overview','poster_path','original_title', 'spoken_languages', 'status','tagline','title'], axis=1)
new_train['homepage'] = train['homepage'].notna()
new_test['homepage'] = test['homepage'].notna()

# %%
import seaborn as sns
sns.jointplot(x="budget", y="revenue", data=new_train, hue = "popularity")

# %% [markdown]
# There seems to be a strong correlation between budget and total revenue grossed by the movie. Popularity seems to be quite irrelevant in determining neither the budget nor the revenue.

# %%
sns.jointplot(x="budget", y="revenue", data=new_train, kind = "reg")

# %% [markdown]
# Budget and revenue show strong linear correlation. Due to the fact we imputed median values for those that were NaN in budget, the graph for budget distribution has a considerable spike in the quantity of median values.
# Revenue quantities are evidently heavily skewed to the right e.g. a lot of movies make under 20 million dollars.

# %%
sns.jointplot(x="popularity", y="revenue", data=new_train, kind="reg")

# %% [markdown]
# As we saw from the first graph, there seems to be no correlation between popularity and revenue. Popularity graph is a lot less skewed to the right than the revenue graph. Popularity is a lot more evenly distributed, with a few movies being outliers wiht incredible popularity.

# %%
sns.jointplot(x="runtime", y="revenue", data=new_train, kind="reg")

# %% [markdown]
# Runtime seems to have little effect on the budget. Runtime is normally distributed around 70-200 minutes.

# %%
sns.distplot(train.revenue)

# %%
train['logRevenue'] = np.log1p(train['revenue'])
sns.distplot(train['logRevenue'])

# %%
#JSON Parsing, some stuff borrowed :-)
def get_dictionary(s):
    try:
        d = eval(s)
    except:
        d = {}
    return d

# %%
from sklearn.preprocessing import LabelEncoder
total_data=pd.concat([new_train, new_test])
encoder=LabelEncoder()
encoder.fit(total_data['original_language'])
new_train['original_language']=encoder.transform(new_train['original_language'])
new_test['original_language']=encoder.transform(new_test['original_language'])

new_train['collection'] = new_train['belongs_to_collection'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
new_test['collection'] = new_test['belongs_to_collection'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
encoder2 = LabelEncoder()
total_data=pd.concat([new_train, new_test])
encoder2.fit(total_data['collection'])
new_train['collection'] = encoder2.transform(new_train['collection'])
new_test['collection'] = encoder2.transform(new_test['collection']) 

new_train['genre_encoded'] = new_train['genres'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
new_test['genre_encoded'] = new_test['genres'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
encoder3 = LabelEncoder()
total_data=pd.concat([new_train, new_test])
encoder3.fit(total_data['genre_encoded'])
new_train['genre_encoded'] = encoder3.transform(new_train['genre_encoded'])
new_test['genre_encoded'] = encoder3.transform(new_test['genre_encoded'])

# %%
from datetime import timedelta, date
new_train['release_date'] = pd.to_datetime(new_train['release_date'])
new_train['year_encoded']=new_train['release_date'].dt.year
new_train['day_of_year']=new_train['release_date'].dt.dayofyear
new_train['day_of_week']=new_train['release_date'].dt.dayofweek
new_train['quarter']=new_train['release_date'].dt.quarter
new_train['month']=new_train['release_date'].dt.month
new_train.drop(['release_date', 'belongs_to_collection', 'genres', 'crew', 'cast'], axis=1, inplace=True)

new_target = new_train.pop('revenue')

# %%
new_test['release_date'] = pd.to_datetime(new_test['release_date'])
new_test['year_encoded']=new_test['release_date'].dt.year
new_test['day_of_year']=new_test['release_date'].dt.dayofyear
new_test['day_of_week']=new_test['release_date'].dt.dayofweek
new_test['quarter']=new_test['release_date'].dt.quarter
new_test['month']=new_test['release_date'].dt.month
new_test.drop(['release_date', 'belongs_to_collection', 'genres', 'crew', 'cast'], axis=1, inplace=True)

# %%
total_data=pd.concat([new_train, new_test])
encoder=LabelEncoder()
encoder.fit(total_data['year_encoded'])
new_train['year_encoded']=encoder.transform(new_train['year_encoded'])
new_test['year_encoded']=encoder.transform(new_test['year_encoded'])

# %%
new_test.head()

# %%
new_test.head()

# %%
for column in ['production_countries','production_companies', 'Keywords']:
    new_train[f"{column}_encoded"] = new_train[column].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
    new_test[f"{column}_encoded"] = new_test[column].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
    encoder3 = LabelEncoder()
    total_data=pd.concat([new_train, new_test])
    encoder3.fit(total_data[f"{column}_encoded"])
    new_train[f"{column}_encoded"] = encoder3.transform(new_train[f"{column}_encoded"])
    new_test[f"{column}_encoded"] = encoder3.transform(new_test[f"{column}_encoded"]) 
    new_test.drop([column], axis=1, inplace=True)
    new_train.drop([column], axis=1, inplace=True)

# %%
 new_test.head()

# %%
new_train.head()

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

# %%
#From Kaggle Course

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Function for comparing different approaches
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=10, random_state=0)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_absolute_error(y_valid, preds)

# %%
print(score_dataset(X_train, X_valid, y_train, y_valid))

# %%
#
discrete_features = new_test.dtypes != float
discrete_features= ['homepage', 'original_language', 'budget_was_imputed', 'collection', 'genre_encoded', 'day_of_year', 'year_encoded'
                   'day_of_week', 'Keywords_encoded',  'production_companies_encoded', 'production_countries_encoded', 'month', 'quarter']

# %%
from sklearn.feature_selection import mutual_info_regression

# Utility mi_score and plot mi scores functions from Kaggle Feature Engineering course
def make_mi_scores(X, y):
    X = X.copy()
    for colname in X.select_dtypes(["object", "category"]):
        X[colname], _ = X[colname].factorize()
    # All discrete features should now have integer dtypes
    discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features, random_state=0)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(new_train, new_target)
mi_scores[:]

# %%
#from Kaggle course on Feature Engineering
def plot_mi_scores(scores):
    import seaborn as sns
    from sklearn.feature_selection import mutual_info_regression
    import matplotlib.pyplot as plt
    plt.style.use("seaborn-whitegrid")
    plt.rc("figure", autolayout=True)
    plt.rc(
        "axes",
        labelweight="bold",
        labelsize="large",
        titleweight="bold",
        titlesize=14,
        titlepad=10,
    )
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")
    
plot_mi_scores(mi_scores)

# %%
#quarter and month seem to be irrelevant, so lets drop them
new_test.drop(['quarter', 'month'], axis=1, inplace=True)
new_train.drop(['quarter', 'month'], axis=1, inplace=True)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)
print(score_dataset(X_train, X_valid, y_train, y_valid))

# %% [markdown]
# Our previous score was 41388287.35, so dropping them resulted in an improvement

# %%
print(new_train.shape,
new_test.shape,
new_target.shape)

# %% [markdown]
# BASELINE METHOD - using median revenue value

# %%
test_rows = new_test.shape[0]
movie_id = [3001 + x for x in range(0,test_rows )] #to account for time steps
baseline1_predictions = [revenue_median] * test_rows

output = pd.DataFrame({'id': movie_id,
                       'revenue': baseline1_predictions})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 11.50.17 AM.png](attachment:b64c8642-1610-49ac-a644-e2415eef510c.png)
# As we can see, the baseline method leaves us at a very high testing loss

# %%
for nonlog in ['budget','popularity','runtime']:
    new_train[nonlog] = np.log(new_train[nonlog])
    
for nonlog in ['budget','popularity','runtime']:
    new_test[nonlog] = np.log(new_test[nonlog])
    
new_target = np.log(new_target)

# %%
new_train.head()

# %%
new_target.head()

# %% [markdown]
# Shallow model:
# # **XGBoost**

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_log_error as rmsle

#default settings 
XGB_factory = XGBRegressor(random_state = 0)

XGB_factory.fit(X_train, y_train)

validp_XGBFactory = XGB_factory.predict(X_valid)

# Calculate RMSLE
rmsle_XGB_factory = rmsle(y_valid, validp_XGBFactory) # Your code here

print("RMSLE:" , rmsle_XGB_factory)

predictions_XGB_factory = XGB_factory.predict(new_test)

# %%
#CSV
output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_XGB_factory)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 12.25.28 PM.png](attachment:30bb3be9-d79d-4f06-a4e8-d4212df3d6e5.png)
# (before logarithms)The rmsle went up. Upon closer inspection, I noticed that the model had generated negative predictions, which shouldn't be possible, so the most probable cause of this is not logifying the data. After this, I also decided to encode the year

# %% [markdown]
# ![Screen Shot 2022-05-03 at 8.02.14 PM.png](attachment:9fdaf786-fbe7-49fe-b918-16cc3214ec17.png)

# %% [markdown]
# After using logs we now have a major increase and a high position on the leaderboard!

# %% [markdown]
# # Grid Search Optimized **XGBoost**

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold

X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

#default settings 

parameters = {'learning_rate': [0.01, 0.1],
              'max_depth': [5, 6],
              'min_child_weight': [4, 3],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [100, 300]}

XGB_grid = GridSearchCV(XGB_factory,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

XGB_grid.fit(X_train, y_train)

print(XGB_grid.best_score_)
print(XGB_grid.best_params_)

# %%
best_params = XGB_grid.best_params_
best_params['random_state'] = 0
print(best_params)
XGB_best = XGBRegressor(colsample_bytree=0.7, 
                        learning_rate= 0.1, max_depth= 5, min_child_weight=3, n_estimators =100, subsample= 0.7)

XGB_best.fit(X_train, y_train)

validp_XGBbest = XGB_best.predict(X_valid)

# Calculate RMSLE
rmsle_XGB_best = rmsle(y_valid, validp_XGBbest) # Your code here

print("RMSLE:" , rmsle_XGB_best)

predictions_XGB_best = XGB_best.predict(new_test)

# %%
output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_XGB_best)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 11.08.07 PM.png](attachment:5f53d9c7-e670-45bc-8a2c-9cfcca73e58b.png)

# %% [markdown]
# # **3-Layer Neural Network**

# %%
from tensorflow import keras
from keras import layers

X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

X_train = np.asarray(X_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
X_valid = np.asarray(X_valid).astype(np.float32)
y_valid = np.asarray(y_valid).astype(np.float32)
new_test_asarr = np.asarray(new_test).astype(np.float32)

onelayer = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(512, input_shape=[X_train.shape[1]], activation = 'relu'),
        layers.Dense(1)
    ])


onelayer.compile(
    optimizer = 'adam',
    loss = 'mae',
    metrics = ['mean_squared_logarithmic_error']
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = onelayer.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping],
    verbose = False
)

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="mae")
history_df.loc[:, ['mean_squared_logarithmic_error', 'val_mean_squared_logarithmic_error']].plot(title="RMSLE")

# %%
predictions_onelayer = onelayer.predict(new_test_asarr)
predictions_onelayer = predictions_onelayer.tolist()
predictions_onelayer = [predictions_onelayer[i][0] for i in range(len(predictions_onelayer))]

output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_onelayer)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# rmsle: 2.6

# %% [markdown]
# First result of the **1 layer NN** gave us a loss that is higher than the one of the XGBoost, but still a great result. lets try more configurations

# %%
onelayer2 = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(2048, input_shape=[X_train.shape[1]], activation = 'relu'),
        layers.Dense(1)
    ])


onelayer2.compile(
    optimizer = 'adam',
    loss = 'mae',
    metrics = ['mean_squared_logarithmic_error']
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=30,
    min_delta=0.001,
    restore_best_weights=True,
)

history = onelayer2.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping],
    verbose = False
)

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[3:, ['loss', 'val_loss']].plot(title="mae")
history_df.loc[3:, ['mean_squared_logarithmic_error', 'val_mean_squared_logarithmic_error']].plot(title="RMSLE")

# %%
predictions_onelayer = onelayer2.predict(new_test_asarr)
predictions_onelayer = predictions_onelayer.tolist()
predictions_onelayer = [predictions_onelayer[i][0] for i in range(len(predictions_onelayer))]

output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_onelayer)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![image.png](attachment:f393ead2-9c2d-4dab-b05b-f9c2d9159132.png)

# %% [markdown]
# ![image.png](attachment:7b798406-f8fa-4cc2-b7a5-a95b7ad991fc.png)

# %% [markdown]
# # **Deep Neural Network**

# %% [markdown]
# Blind Approach

# %%
deepnn1 = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(512, input_shape=[X_train.shape[1]], activation = 'relu'),
        layers.BatchNormalization(),
        layers.Dropout(rate=0.2),
        layers.Dense(256, input_shape=[X_train.shape[1]], activation = 'relu'),
        layers.BatchNormalization(),
        layers.Dense(1)
    ])


deepnn1.compile(
    optimizer = 'adam',
    loss = 'mae',
    metrics = ['mean_squared_logarithmic_error']
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=30,
    min_delta=0.001,
    restore_best_weights=True,
)

history = deepnn1.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping],
    verbose = False
)

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="mae")
history_df.loc[:, ['mean_squared_logarithmic_error', 'val_mean_squared_logarithmic_error']].plot(title="RMSLE")

# %%
predictions_dnn1 = deepnn1.predict(new_test_asarr)
predictions_dnn1 = predictions_dnn1.tolist()
predictions_dnn1 = [predictions_dnn1[i][0] for i in range(len(predictions_dnn1))]

output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_dnn1)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 9.34.44 PM.png](attachment:498136ee-6232-474c-98c0-133f3939088d.png)

# %% [markdown]
# Approach where we use only 2 hidden layers with neurons between size of input and size of output

# %%
deepnn2 = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(14, input_shape=[X_train.shape[1]], activation = 'relu'),
        layers.BatchNormalization(),
        layers.Dense(14, activation = 'relu'),
        layers.BatchNormalization(),
        layers.Dense(1)
    ])


deepnn2.compile(
    optimizer = 'adam',
    loss = 'mae',
    metrics = ['mean_squared_logarithmic_error']
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=30,
    min_delta=0.001,
    restore_best_weights=True,
)

history = deepnn2.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=500,
    callbacks=[early_stopping],
    verbose = False
)

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[14:, ['loss', 'val_loss']].plot(title="mae")
history_df.loc[14:, ['mean_squared_logarithmic_error', 'val_mean_squared_logarithmic_error']].plot(title="RMSLE")

# %%
predictions_dnn2 = deepnn2.predict(new_test_asarr)
predictions_dnn2 = predictions_dnn2.tolist()
predictions_dnn2 = [predictions_dnn2[i][0] for i in range(len(predictions_dnn2))]

output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_dnn2)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 9.37.00 PM.png](attachment:1b671d02-2199-4d77-a756-5a07a2b06f90.png)

# %% [markdown]
# The more scientific approach gave the best results to date

# %% [markdown]
# # Adding more data. Creating new features.

# %%
train = pd.read_csv('../input/tmdb-box-office-prediction/train.csv')
test = pd.read_csv('../input/tmdb-box-office-prediction/test.csv')

# %%
#Filling in train data with real value
train.loc[train['id'] == 16,'revenue'] = 192864          # Skinning
train.loc[train['id'] == 90,'budget'] = 30000000         # Sommersby          
train.loc[train['id'] == 118,'budget'] = 60000000        # Wild Hogs
train.loc[train['id'] == 149,'budget'] = 18000000        # Beethoven
train.loc[train['id'] == 313,'revenue'] = 12000000       # The Cookout 
train.loc[train['id'] == 451,'revenue'] = 12000000       # Chasing Liberty
train.loc[train['id'] == 464,'budget'] = 20000000        # Parenthood
train.loc[train['id'] == 470,'budget'] = 13000000        # The Karate Kid, Part II
train.loc[train['id'] == 513,'budget'] = 930000          # From Prada to Nada
train.loc[train['id'] == 797,'budget'] = 8000000         # Welcome to Dongmakgol
train.loc[train['id'] == 819,'budget'] = 90000000        # Alvin and the Chipmunks: The Road Chip
train.loc[train['id'] == 850,'budget'] = 90000000        # Modern Times
train.loc[train['id'] == 1112,'budget'] = 7500000        # An Officer and a Gentleman
train.loc[train['id'] == 1131,'budget'] = 4300000        # Smokey and the Bandit   
train.loc[train['id'] == 1359,'budget'] = 10000000       # Stir Crazy 
train.loc[train['id'] == 1542,'budget'] = 1              # All at Once
train.loc[train['id'] == 1542,'budget'] = 15800000       # Crocodile Dundee II
train.loc[train['id'] == 1571,'budget'] = 4000000        # Lady and the Tramp
train.loc[train['id'] == 1714,'budget'] = 46000000       # The Recruit
train.loc[train['id'] == 1721,'budget'] = 17500000       # Cocoon
train.loc[train['id'] == 1865,'revenue'] = 25000000      # Scooby-Doo 2: Monsters Unleashed
train.loc[train['id'] == 2268,'budget'] = 17500000       # Madea Goes to Jail budget
train.loc[train['id'] == 2491,'revenue'] = 6800000       # Never Talk to Strangers
train.loc[train['id'] == 2602,'budget'] = 31000000       # Mr. Holland's Opus
train.loc[train['id'] == 2612,'budget'] = 15000000       # Field of Dreams
train.loc[train['id'] == 2696,'budget'] = 10000000       # Nurse 3-D
train.loc[train['id'] == 2801,'budget'] = 10000000       # Fracture


train.runtime[train.id == 391] = 86 #Il peor natagle de la meva vida
train.runtime[train.id == 592] = 90 #А поутру они проснулись
train.runtime[train.id == 925] = 95 #¿Quién mató a Bambi?
train.runtime[train.id == 978] = 93 #La peggior settimana della mia vita
train.runtime[train.id == 1256] = 92 #Cipolla Colt
train.runtime[train.id == 1542] = 93 #Все и сразу
train.runtime[train.id == 1875] = 86 #Vermist
train.runtime[train.id == 2151] = 108 #Mechenosets
train.runtime[train.id == 2499] = 108 #Na Igre 2. Novyy Uroven
train.runtime[train.id == 2646] = 98 #同桌的妳
train.runtime[train.id == 2786] = 111 #Revelation
train.runtime[train.id == 2866] = 96 #Tutto tutto niente niente

# TEST
test.runtime[test.id == 4074] = 103 #Shikshanachya Aaicha Gho
test.runtime[test.id == 4222] = 93 #Street Knight
test.runtime[test.id == 4431] = 100 #Плюс один
test.runtime[test.id == 5520] = 86 #Glukhar v kino
test.runtime[test.id == 5845] = 83 #Frau Müller muss weg!
test.runtime[test.id == 5849] = 140 #Shabd
test.runtime[test.id == 6210] = 104 #Le dernier souffle
test.runtime[test.id == 6804] = 145 #Chaahat Ek Nasha..
test.runtime[test.id == 7321] = 87 #El truco del manco

# %%
test.loc[test['id'] == 3889,'budget'] = 15000000       # Colossal
test.loc[test['id'] == 6733,'budget'] = 5000000        # The Big Sick
test.loc[test['id'] == 3197,'budget'] = 8000000        # High-Rise
test.loc[test['id'] == 6683,'budget'] = 50000000       # The Pink Panther 2
test.loc[test['id'] == 5704,'budget'] = 4300000        # French Connection II
test.loc[test['id'] == 6109,'budget'] = 281756         # Dogtooth
test.loc[test['id'] == 7242,'budget'] = 10000000       # Addams Family Values
test.loc[test['id'] == 7021,'budget'] = 17540562       #  Two Is a Family
test.loc[test['id'] == 5591,'budget'] = 4000000        # The Orphanage
test.loc[test['id'] == 4282,'budget'] = 20000000       # Big Top Pee-wee
test.loc[test['release_date'].isnull() == True, 'release_date'] = '10/19/2001'

# %%
budget_median=train[train['budget']>0]['budget'].median()
print(budget_median)
revenue_median=train[train['revenue']>0]['revenue'].median()
runtime_median_train = train[train['runtime']>0]['runtime'].median()
runtime_median_test = test[test['runtime']>0]['runtime'].median()
print(revenue_median)

# %%
add_train = pd.read_csv('../input/tmdb-additional-features/TrainAdditionalFeatures.csv')
add_test = pd.read_csv('../input/tmdb-additional-features/TestAdditionalFeatures.csv')

# %%
new_train = pd.merge(train,add_train,how='left',on = ['imdb_id'])
new_test = pd.merge(test,add_test,how='left',on=['imdb_id'])

# %%
cols_with_missing = [col for col in new_train.columns
                     if new_train[col].isnull().any()]
print(cols_with_missing)

# %% [markdown]
# Most columns have missing values, but not the key columns we will be looking at e.g. Revenue and Budget.

# %%
invalid_revenue = new_train.id[new_train.budget > 1000][new_train.revenue < 100]
for anId in invalid_revenue :
    new_train.loc[new_train['id'] == anId,'revenue'] =  revenue_median
    
new_train['runtime'] = new_train['runtime'].fillna(runtime_median_train)
    
new_test['runtime'] = new_test['runtime'].fillna(runtime_median_test)

# %%
new_train['budget_was_imputed'] = new_train['budget'].isnull()
new_test['budget_was_imputed'] = new_test['budget'].isnull()

invalid_budget_train = new_train.id[new_train.budget == 0]
for anId in invalid_budget_train:
    new_train.loc[new_train['id'] == anId,'budget'] =  budget_median
    new_train.loc[new_train['id'] == anId,'budget_was_imputed'] =  True
    
invalid_budget_test = new_test.id[new_test.budget == 0]
for anId in invalid_budget_test:
    new_test.loc[new_test['id'] == anId,'budget'] =  budget_median
    new_test.loc[new_test['id'] == anId,'budget_was_imputed'] =  True

# %%
cols_with_missing = [col for col in add_train.columns
                     if add_train[col].isnull().any()]
print(cols_with_missing)

# %% [markdown]
# #### Each of the columns has some missing values that we will need to fix.

# %%
print(new_train.imdb_id[new_train.popularity2.isnull()])
print(add_test.imdb_id[add_test.popularity2.isnull()])

# %% [markdown]
# #### We now identified missing popularity2 values in add_train (1st) and add_test (2nd). Now, onto fixing them by plugging in median values.

# %%
invalid_popularity2_train = new_train.imdb_id[new_train.popularity2.isnull()]
for anId in invalid_popularity2_train:
    new_train.loc[new_train['imdb_id'] == anId,'popularity2'] =  5.0
    
invalid_popularity2_test = new_test.imdb_id[new_test.popularity2.isnull()]
for anId in invalid_popularity2_test:
    new_test.loc[new_test['imdb_id'] == anId,'popularity2'] =  5.0

# %% [markdown]
# #### Check that popularity2 has been updated. Update the rest of the values

# %%
invalid_rating_train = new_train.imdb_id[new_train.rating.isnull()]
for anId in invalid_rating_train:
    new_train.loc[new_train['imdb_id'] == anId,'rating'] =  5.0
    
invalid_rating_test = new_test.imdb_id[new_test.rating.isnull()]
for anId in invalid_rating_test:
    new_test.loc[new_test['imdb_id'] == anId,'rating'] =  5.0

# %%
totalVotes_median = new_train[new_train['totalVotes']>0]['totalVotes'].median()
print(totalVotes_median)
totalVotes_median_te = new_test[new_test['totalVotes']>0]['totalVotes'].median()
print(totalVotes_median_te)

# %%
invalid_totalVotes_train = new_train.imdb_id[new_train.totalVotes.isnull()]
for anId in invalid_totalVotes_train:
    new_train.loc[new_train['imdb_id'] == anId,'totalVotes'] =  totalVotes_median
    
invalid_totalVotes_test = new_test.imdb_id[new_test.totalVotes.isnull()]
for anId in invalid_totalVotes_test:
    new_test.loc[new_test['imdb_id'] == anId,'totalVotes'] =  totalVotes_median

# %% [markdown]
# #### This should've fixed all missing values. Now to check if there are still any columns left with missing values.

# %%
cols_with_missing = [col for col in new_train.columns
                     if new_train[col].isnull().any()]
print(cols_with_missing)

# %%
new_train=new_train.drop(['imdb_id','id', 'overview','poster_path','original_title', 'spoken_languages', 'status','tagline','title'], axis=1)
new_test=new_test.drop(['imdb_id','id', 'overview','poster_path','original_title', 'spoken_languages', 'status','tagline','title'], axis=1)
new_train['homepage'] = train['homepage'].notna()
new_test['homepage'] = test['homepage'].notna()

# %%
from sklearn.preprocessing import LabelEncoder
total_data=pd.concat([new_train, new_test])
encoder=LabelEncoder()
encoder.fit(total_data['original_language'])
new_train['original_language']=encoder.transform(new_train['original_language'])
new_test['original_language']=encoder.transform(new_test['original_language'])

new_train['collection'] = new_train['belongs_to_collection'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
new_test['collection'] = new_test['belongs_to_collection'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
encoder2 = LabelEncoder()
total_data=pd.concat([new_train, new_test])
encoder2.fit(total_data['collection'])
new_train['collection'] = encoder2.transform(new_train['collection'])
new_test['collection'] = encoder2.transform(new_test['collection']) 

new_train['genre_encoded'] = new_train['genres'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
new_test['genre_encoded'] = new_test['genres'].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
encoder3 = LabelEncoder()
total_data=pd.concat([new_train, new_test])
encoder3.fit(total_data['genre_encoded'])
new_train['genre_encoded'] = encoder3.transform(new_train['genre_encoded'])
new_test['genre_encoded'] = encoder3.transform(new_test['genre_encoded'])

# %%
from datetime import timedelta, date
new_train['release_date'] = pd.to_datetime(new_train['release_date'])
new_train['year_encoded']=new_train['release_date'].dt.year
new_train['day_of_year']=new_train['release_date'].dt.dayofyear
new_train['day_of_week']=new_train['release_date'].dt.dayofweek
new_train['quarter']=new_train['release_date'].dt.quarter
new_train['month']=new_train['release_date'].dt.month
new_train.drop(['release_date', 'belongs_to_collection', 'genres', 'crew', 'cast'], axis=1, inplace=True)

new_target = new_train.pop('revenue')

# %%
new_test['release_date'] = pd.to_datetime(new_test['release_date'])
new_test['year_encoded']=new_test['release_date'].dt.year
new_test['day_of_year']=new_test['release_date'].dt.dayofyear
new_test['day_of_week']=new_test['release_date'].dt.dayofweek
new_test['quarter']=new_test['release_date'].dt.quarter
new_test['month']=new_test['release_date'].dt.month
new_test.drop(['release_date', 'belongs_to_collection', 'genres', 'crew', 'cast'], axis=1, inplace=True)

# %%
total_data=pd.concat([new_train, new_test])
encoder=LabelEncoder()
encoder.fit(total_data['year_encoded'])
new_train['year_encoded']=encoder.transform(new_train['year_encoded'])
new_test['year_encoded']=encoder.transform(new_test['year_encoded'])

# %%
for column in ['production_countries','production_companies', 'Keywords']:
    new_train[f"{column}_encoded"] = new_train[column].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
    new_test[f"{column}_encoded"] = new_test[column].apply(lambda x: get_dictionary(x)).apply(lambda row: row[0]['name'] if row != {} else '0')
    encoder3 = LabelEncoder()
    total_data=pd.concat([new_train, new_test])
    encoder3.fit(total_data[f"{column}_encoded"])
    new_train[f"{column}_encoded"] = encoder3.transform(new_train[f"{column}_encoded"])
    new_test[f"{column}_encoded"] = encoder3.transform(new_test[f"{column}_encoded"]) 
    new_test.drop([column], axis=1, inplace=True)
    new_train.drop([column], axis=1, inplace=True)

# %%
cols_with_missing = [col for col in new_train.columns
                     if new_train[col].isnull().any()]
print(cols_with_missing)

# %% [markdown]
# #### Here we confirmed there are no more missing values in any of the training data columns after encoding.

# %% [markdown]
# ### Logarithmesizing the data.
# #### The performance of neural networks on data that exhibits heavy skewness is improved if the data is logarithmesized to make it more "normal". In the following section, we take a look at a number of features that currently exist within our data, identify those that are heavily skewed, and in case if they are, we turn them into logs of these values.
# #### This will greatly improve the power of prediction of our ML algorithm.

# %%
print(new_train.columns)

# %%
sns.distplot(new_train.budget)

# %% [markdown]
# #### Budget is a candidate for Log

# %%
sns.distplot(new_train.popularity)

# %% [markdown]
# #### Popularity is a candidate for Log

# %%
sns.distplot(new_train.popularity2)

# %%
sns.distplot(new_train.rating)

# %%
sns.distplot(new_train.totalVotes)

# %% [markdown]
# #### Total Votes is a candidate for Log

# %%
sns.distplot(new_train.runtime)

# %%
sns.distplot(new_target)

# %% [markdown]
# #### Revenue is a candidate for Log

# %%
# Transforming highlighted values into logs
for nonlog in ['budget','popularity','totalVotes']:
    new_train[nonlog] = np.log(new_train[nonlog])
    new_test[nonlog] = np.log(new_test[nonlog])
    new_train[nonlog].replace(to_replace = 0, value = .0001, inplace=True)
    new_test[nonlog].replace(to_replace = 0, value = .0001, inplace=True)
    # need to replace zeros with small values to allow for future composite feature creation

# %%
new_target = np.log(new_target)
new_target.replace(to_replace = 0, value = .0001, inplace = True)
# same idea

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

# %%
mi_scores = make_mi_scores(new_train, new_target)
mi_scores[:]

# %%
plot_mi_scores(mi_scores)

# %% [markdown]
# #### Our new values are quite good at predicting variation in (log of) total revenue. But we want to improve the prediction capacity of our model by creating some more composite features.

# %%
new_train['votes_by_pop2'] = new_train['totalVotes']/new_train['popularity2']
new_train['budget_by_pop2'] = new_train['budget']/new_train['popularity2']
new_train['budget_by_totVotes'] = new_train['budget']/new_train['totalVotes']
new_train['pop_by_pop2'] = new_train['popularity']/new_train['popularity2']

# %%
new_test['votes_by_pop2'] = new_test['totalVotes']/new_test['popularity2']
new_test['budget_by_pop2'] = new_test['budget']/new_test['popularity2']
new_test['budget_by_totVotes'] = new_test['budget']/new_test['totalVotes']
new_test['pop_by_pop2'] = new_test['popularity']/new_test['popularity2']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

# %%
mi_scores = make_mi_scores(new_train, new_target)
mi_scores[:]

# %%
plot_mi_scores(mi_scores)

# %% [markdown]
# ### New Feature Iteration 1
# #### votes_by_pop2 and budget_by_totVotes performed well. However, some of the new composite values are worse than the originals, we will drop them and try to make new ones. We will also drop the poorly performing days_of and quarter values, as well as runtime.

# %%
new_test.drop(['quarter', 'month', 'day_of_year', 'day_of_week', 'runtime', 'budget_by_pop2', 'pop_by_pop2'], axis=1, inplace=True)
new_train.drop(['quarter', 'month', 'day_of_year', 'day_of_week', 'runtime', 'budget_by_pop2', 'pop_by_pop2'], axis=1, inplace=True)

# %%
new_train['totVotes_by_budget'] = new_train['totalVotes']/new_train['budget']
new_train['pop2_by_budget'] = new_train['popularity2']/new_train['budget']

new_test['totVotes_by_budget'] = new_test['totalVotes']/new_test['budget']
new_test['pop2_by_budget'] = new_test['popularity2']/new_test['budget']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

# %%
mi_scores = make_mi_scores(new_train, new_target)
mi_scores[:]

# %%
plot_mi_scores(mi_scores)

# %% [markdown]
# ### New Feature Iteration 2
# #### Further edits to features proved to be even more unsuccessful. As a result, we decided to bring back the previously dropped additional features (budget_by_pop2 and pop_by_pop2), and drop the two new features introduced in the last iteration (pop2_by_budget and totVotes_by_budget).
#
# #### This will be the basis for our future training.

# %%
new_train.drop(['pop2_by_budget', 'totVotes_by_budget'], axis=1, inplace=True)
new_train['budget_by_pop2'] = new_train['budget']/new_train['popularity2']
new_train['pop_by_pop2'] = new_train['popularity']/new_train['popularity2']

new_test.drop(['pop2_by_budget', 'totVotes_by_budget'], axis=1, inplace=True)
new_test['budget_by_pop2'] = new_test['budget']/new_test['popularity2']
new_test['pop_by_pop2'] = new_test['popularity']/new_test['popularity2']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

# %%
mi_scores = make_mi_scores(new_train, new_target)
mi_scores[:]

# %%
plot_mi_scores(mi_scores)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)
print(np.expm1(score_dataset(X_train, X_valid, y_train, y_valid)))

# %%
print(new_train.head())

# %% [markdown]
# # **XGBoost reviewed**

# %%
X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)

from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_log_error as rmsle

#default settings 
XGB_factory = XGBRegressor(random_state = 0)

XGB_factory.fit(X_train, y_train)

validp_XGBFactory = XGB_factory.predict(X_valid)

# Calculate RMSLE
rmsle_XGB_factory = rmsle(y_valid, validp_XGBFactory) # Your code here

print("RMSLE:" , rmsle_XGB_factory)

predictions_XGB_factory = XGB_factory.predict(new_test)

# %%
#CSV
output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_XGB_factory)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 11.22.50 PM.png](attachment:a6490b36-22eb-45ca-8d11-920509f50b5a.png)

# %% [markdown]
# # **XGBoost Gridsearch Optimized reviewed**

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold

X_train, X_valid, y_train, y_valid = train_test_split(new_train, new_target, train_size=0.8, test_size=0.2, random_state=0)


# parameters = {'learning_rate': [0.01, 0.1, 0.3],
#               'max_depth': [5, 6, 7],
#               'min_child_weight': [4, 5],
#               'subsample': [0.7],
#               'colsample_bytree': [0.7],
#               'n_estimators': [100, 300]}

# XGB_grid = GridSearchCV(XGB_factory,
#                         parameters,
#                         cv = 2,
#                         n_jobs = 5,
#                         verbose=True)

# XGB_grid.fit(X_train, y_train)

print(XGB_grid.best_score_)
print(XGB_grid.best_params_)

# %%
best_params = XGB_grid.best_params_
best_params['random_state'] = 0
print(best_params)
XGB_best = XGBRegressor(colsample_bytree=0.7, 
                        learning_rate= 0.1, max_depth= 5, min_child_weight=4, n_estimators =100, subsample= 0.7)

XGB_best.fit(X_train, y_train)

validp_XGBbest = XGB_best.predict(X_valid)

# Calculate RMSLE
rmsle_XGB_best = rmsle(y_valid, validp_XGBbest) # Your code here

print("RMSLE:" , rmsle_XGB_best)

predictions_XGB_best = XGB_best.predict(new_test)

output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_XGB_best)})
output.to_csv('submission.csv', index=False)

# %%
onelayer2 = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(2048, input_shape=[X_train.shape[1]], activation = 'relu'),
        layers.Dense(1)
    ])


onelayer2.compile(
    optimizer = 'adam',
    loss = 'mae',
    metrics = ['mean_squared_logarithmic_error']
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=30,
    min_delta=0.001,
    restore_best_weights=True,
)

history = onelayer2.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=500,
    callbacks=[early_stopping],
    verbose = False
)

# %%
predictions_onelayer = onelayer2.predict(new_test_asarr)
predictions_onelayer = predictions_onelayer.tolist()
predictions_onelayer = [predictions_onelayer[i][0] for i in range(len(predictions_onelayer))]

output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_onelayer)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 11.43.43 PM.png](attachment:f8d2b4aa-249f-4029-bd33-8bf6092856c5.png)

# %% [markdown]
# # **DNN Revisited**

# %%
deepnn2 = keras.Sequential([
        layers.BatchNormalization(),
        layers.Dense(X_train.shape[1], input_shape=[X_train.shape[1]], activation = 'relu'),
        layers.BatchNormalization(),
        layers.Dense(X_train.shape[1], activation = 'relu'),
        layers.BatchNormalization(),
        layers.Dense(1)
    ])


deepnn2.compile(
    optimizer = 'adam',
    loss = 'mae',
    metrics = ['mean_squared_logarithmic_error']
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=30,
    min_delta=0.001,
    restore_best_weights=True,
)

history = deepnn2.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=500,
    callbacks=[early_stopping],
    verbose = False
)

# %%
predictions_dnn2 = deepnn2.predict(new_test_asarr)
predictions_dnn2 = predictions_dnn2.tolist()
predictions_dnn2 = [predictions_dnn2[i][0] for i in range(len(predictions_dnn2))]

output = pd.DataFrame({'id': movie_id,
                       'revenue': np.expm1(predictions_dnn2)})
output.to_csv('submission.csv', index=False)

# %% [markdown]
# ![Screen Shot 2022-05-03 at 11.49.14 PM.png](attachment:383922d8-f8e3-4650-8d1b-0eeccdb9a487.png)
