# %%
# Importing libraries 
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split

import pandas as pd

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %%
data=pd.read_csv('../input/train.csv')
data.head()
# Out:
#    id  target      0      1      2  ...      295    296    297    298    299
# 0   0     1.0 -0.098  2.165  0.681  ...   -2.097  1.051 -0.414  1.038 -1.065
# 1   1     0.0  1.081 -0.973 -0.383  ...   -1.624 -0.458 -1.099 -0.936  0.973
# 2   2     1.0 -0.523 -0.089 -0.348  ...   -1.165 -1.544  0.004  0.800 -1.211
# 3   3     1.0  0.067 -0.021  0.392  ...    0.467 -0.562 -0.254 -0.533  0.238
# 4   4     1.0  2.347 -0.831  0.511  ...    1.378  1.246  1.478  0.428  0.253
#
# [5 rows x 302 columns]

# %%
# Splitting data into training and test set
X_train, X_test, y_train, y_test = train_test_split(data.drop(['id','target'],axis=1),data['target'],train_size=0.75, test_size=0.25)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((187, 300), (63, 300), (187,), (63,))

# %%
tpot = TPOTClassifier(generations=8, population_size=50, verbosity=2)
tpot.fit(X_train, y_train)
print("Accuracy is {}%".format(tpot.score(X_test, y_test)*100))
# Out:
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=450, style=ProgressStyle(descript…
# Generation 1 - Current best internal CV score: 0.7112375533428164
# Generation 2 - Current best internal CV score: 0.7112375533428164
# Generation 3 - Current best internal CV score: 0.7112375533428164
# Generation 4 - Current best internal CV score: 0.7166429587482218
# Generation 5 - Current best internal CV score: 0.7166429587482218
# Generation 6 - Current best internal CV score: 0.7166429587482218
# Generation 7 - Current best internal CV score: 0.7169274537695591
# Generation 8 - Current best internal CV score: 0.7169274537695591
#
# Best pipeline: LinearSVC(PCA(input_matrix, iterated_power=10, svd_solver=randomized), C=0.5, dual=True, loss=squared_hinge, penalty=l2, tol=0.0001)
# Accuracy is 66.66666666666666%

# %%
data_test=pd.read_csv('../input/test.csv')
data_test.head()
# Out:
#     id      0      1      2      3  ...      295    296    297    298    299
# 0  250  0.500 -1.033 -1.595  0.309  ...    2.132  0.609 -0.104  0.312  0.979
# 1  251  0.776  0.914 -0.494  1.347  ...   -1.133 -3.138  0.281 -0.625 -0.761
# 2  252  1.750  0.509 -0.057  0.835  ...    0.701  0.976  0.135 -1.327  2.463
# 3  253 -0.556 -1.855 -0.682  0.578  ...    0.916  2.411  1.053 -1.601 -1.529
# 4  254  0.754 -0.245  1.173 -1.623  ...    0.322 -0.068 -0.156 -1.153  0.825
#
# [5 rows x 301 columns]

# %%
tpot.export('tpot_exported_pipeline.py')

# %%
# import module we'll need to import our custom module
#from shutil import copyfile

# copy our file into the working directory (make sure it has .py suffix)
#copyfile(src = "../input/tpot_exported_pipeline.py", dst = "../working/tpot_exported_pipeline.py")

# import all our functions
#from tpot_exported_pipeline import *

# %%
tpot.predict(data_test.drop(['id'],axis=1))
# Out:
# array([1., 0., 1., ..., 1., 1., 0.])

# %%
submission=pd.DataFrame({'id': data_test['id'], 'target':tpot.predict(data_test.drop(['id'],axis=1)) })
submission.to_csv('submission.csv',index=False)
