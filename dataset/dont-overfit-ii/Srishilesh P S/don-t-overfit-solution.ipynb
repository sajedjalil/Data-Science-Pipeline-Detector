# %% [markdown]
# **SIMPLE CODE TO UNDERSTAND THE WORKFLOW**

# %% [markdown]
# Importing all the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn import model_selection

# %% [markdown]
# Importing the training and test dataset

# %%
train = pd.read_csv("../input/train.csv")
print(train.shape)

test = pd.read_csv("../input/test.csv")
print(test.shape)
# Out:
# (250, 302)
# (19750, 301)

# %%
print(train.columns)
train.describe()

print(test.columns)
test.describe()
# Out:
# Index(['id', 'target', '0', '1', '2', '3', '4', '5', '6', '7',
#        ...
#        '290', '291', '292', '293', '294', '295', '296', '297', '298', '299'],
#       dtype='object', length=302)
# Index(['id', '0', '1', '2', '3', '4', '5', '6', '7', '8',
#        ...
#        '290', '291', '292', '293', '294', '295', '296', '297', '298', '299'],
#       dtype='object', length=301)
#                  id             0      ...                298           299
# count  19750.000000  19750.000000      ...       19750.000000  19750.000000
# mean   10124.500000     -0.014043      ...           0.013076      0.000070
# std     5701.478244      1.003779      ...           0.996285      1.000596
# min      250.000000     -4.070000      ...          -3.581000     -4.135000
# 25%     5187.250000     -0.688750      ...          -0.663000     -0.675000
# 50%    10124.500000     -0.006000      ...           0.016000      0.007000
# 75%    15061.750000      0.664000      ...           0.686000      0.676000
# max    19999.000000      3.767000      ...           3.764000      4.070000
#
# [8 rows x 301 columns]

# %% [markdown]
# Extracting the target variable and the features

# %% [markdown]
# To split the Features and Target values of both Training and Test dataset

# %%
train_x = train.iloc[:,2:]
train_y_ = train.iloc[:,1]
train_y = []
for i in train_y_:
    train_y.append(i)
    
test_x = test.iloc[:,1:]


#print(test_x)

# %% [markdown]
# Scaling of the data

# %%
scaler = StandardScaler()
train_x = scaler.fit_transform(train_x)
#test_x = scaler.fit_transform(test_x)

# %% [markdown]
# Cross Validation to reduce overfitting of the data

# %% [markdown]
# Applying Regression layer

# %%
regression = LogisticRegression(class_weight='balanced', solver='liblinear', penalty ='l1', C= 0.1, max_iter=10000)
regression.fit(train_x,train_y)

scores = model_selection.cross_val_score(regression,train_x,train_y,scoring="accuracy",cv=50)   # To Cross validate and remodel it with less features
# cv - number of runs to find cross validated model

test_y_ = regression.predict_proba(test_x)
print("Training Accuracy score: ",regression.score(train_x,train_y))
test_y = []
#for i in test_y_[:,1]:
#    test_y.append(i)
    
#print(len(train_y))
print((test_y_[:,1]))

#score = accuracy_score(train_y,test_y)
#print(score)
# Out:
# Training Accuracy score:  0.876
# [0.66692307 0.46983056 0.51550206 ... 0.28299603 0.77668405 0.22995998]

# %% [markdown]
# Submission of code

# %%
submission = pd.DataFrame({"id":test["id"],"target":test_y_[:,1]})

#Visualize the first 5 rows
submission.head()

filename = 'submission.csv'

submission.to_csv(filename,index=False)

print('Saved file: ' + filename)
# Out:
# Saved file: submission.csv
