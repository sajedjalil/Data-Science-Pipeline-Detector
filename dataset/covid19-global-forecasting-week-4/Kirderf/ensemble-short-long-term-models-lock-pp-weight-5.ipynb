# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
#AIG_covid = pd.read_csv("../input/sub2-submission-covid19-w4/submission.csv")
#Moradnejad = pd.read_csv("../input/covid-w4-sub-ensemble/submission.csv")
Lockdown = pd.read_csv("../input/subsw4/Lockdown.csv")
Northquay = pd.read_csv("../input/subsw4/Northquay.csv")
Nanashi = pd.read_csv("../input/subsw4/Nanashi.csv")
kirderf = pd.read_csv("../input/all-in-super-average-over-900-models/submission.csv")
PauloPinto = pd.read_csv("../input/covid19-w4-blend6/submission.csv")
PDD = pd.read_csv("../input/cv19w4-full-pdd-oscii-david-vopa-sub1/submission.csv")

sub_df_final = Lockdown.copy()

# %%
#AIG_covidC = AIG_covid["ConfirmedCases"]
#AIG_covidF = AIG_covid["Fatalities"]
#MoradnejaC = Moradnejad["ConfirmedCases"]
#MoradnejadF = Moradnejad["Fatalities"]
LockdownC = Lockdown["ConfirmedCases"]
LockdownF = Lockdown["Fatalities"]
NorthquayC = Northquay["ConfirmedCases"]
NorthquayF = Northquay["Fatalities"]
NanashiC = Nanashi["ConfirmedCases"]
NanashiF = Nanashi["Fatalities"]
kirderfC = kirderf["ConfirmedCases"]
kirderfF = kirderf["Fatalities"]
PauloPintoC = PauloPinto["ConfirmedCases"]
PauloPintoF = PauloPinto["Fatalities"]
PDDC = PDD["ConfirmedCases"]
PDDF = PDD["Fatalities"]


#sub_df_final["ConfirmedCases"] =  0.5 *LockdownC.values +  0.5 * NanashiC.values
#sub_df_final["Fatalities"] = 0.5 * LockdownF.values +  0.5 * NanashiF.values

# %%
print(Lockdown.loc[[27,28,29,30,31]])

# %%
print(PauloPinto.loc[[27,28,29,30,31]])

# %%
print(Lockdown.loc[[27+43,28+43,29+43,30+43,31+43]])

# %%
print(PauloPinto.loc[[27+43,28+43,29+43,30+43,31+43]])

# %%
print(sub_df_final.loc[[27,28,29,30,31]])

# %%
for i in range(15,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(16,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(17,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(18,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(19,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(20,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(21,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(22,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(23,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(24,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(25,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(26,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(27,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(28,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(29,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(30,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(31,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(32,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(33,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(34,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(35,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(36,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(37,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(38,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(39,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(40,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(41,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(42,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
for i in range(43,13460, 43):
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['ConfirmedCases']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['ConfirmedCases']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['ConfirmedCases']])
    sub_df_final.loc[sub_df_final['ForecastId'] == i, ['Fatalities']] = .5*(Lockdown.loc[Lockdown['ForecastId'] == i, ['Fatalities']])+.5*(PauloPinto.loc[PauloPinto['ForecastId'] == i, ['Fatalities']])

# %%
print(sub_df_final.loc[[27,28,29,30,31]])

# %%
print(sub_df_final.loc[[27+43,28+43,29+43,30+43,31+43]])

# %%
sub_df_final.to_csv('submission.csv',index=False)
