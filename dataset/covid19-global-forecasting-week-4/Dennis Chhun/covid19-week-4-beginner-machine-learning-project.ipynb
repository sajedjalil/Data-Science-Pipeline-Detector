# %% [markdown]
# ### This project is intended for Beginner Machine Learning/Data Analysis
# - EE257 Machine Learning for Electrical Engineers - San Jose State University

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
dfSubmission = pd.read_csv(dirname + '/submission.csv')
dfTest = pd.read_csv(dirname + '/test.csv')  
dfTrain = pd.read_csv(dirname + '/train.csv')
dfSubmission.head()

# %%
dfTest.head()

# %%
dfTest.corr()

# %%
dfTest.info()

# %%
dfTest.describe()

# %%
dfTest.shape

# %%
dfTrain.head()

# %%
dfTrain.corr()

# %%
dfTrain.info()

# %%
dfTrain.describe()

# %%
dfTrain.shape

# %%
ConfirmedCases = dfTrain["ConfirmedCases"]

# %%
Fatalities = dfTrain["Fatalities"]

# %%
dfTrain["Date"] = dfTrain["Date"].apply(pd.to_datetime, "%m/%d/%Y")
dfTest["Date"] = dfTest["Date"].apply(pd.to_datetime, "%m/%d/%Y")

# %% [markdown]
# ## Dataset Cleaning - Dataset Concatenate

# %%
confirmedTotal = dfTrain.groupby(['Date']).agg({'ConfirmedCases':['sum']})
fatalTotal = dfTrain.groupby(['Date']).agg({'Fatalities':['sum']})
totalDate = confirmedTotal.join(fatalTotal)

# %%
print(totalDate)

# %%
confirmedCases = totalDate.iloc[0:100,0]
print(confirmedCases)
fatalities = totalDate.iloc[0:100,1]
print(fatalities)

# %%
cases = totalDate.iloc[0:100,1:2]
print(cases)

# %%
#totalDate.to_csv(path+'/ConfirmFatal.csv',mode='a')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style
dfTrain.hist(bins = 20, figsize = (10,10)) 
plt.show()

# %% [markdown]
# ### Comapring Italy, China, and United States Total Confirmed Cases vs Fatalities

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style
# Italy
totalItaly = dfTrain[dfTrain['Country_Region']=='Italy'].groupby(['Date']).agg({'ConfirmedCases':['sum']})
fatalItaly = dfTrain[dfTrain['Country_Region']=='Italy'].groupby(['Date']).agg({'Fatalities':['sum']})
dateItaly = totalItaly.join(fatalItaly)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(17,7))
dateItaly.plot(ax=ax1)
ax1.set_title("Italy confirmed cases", size=13)
ax1.set_ylabel("Number of cases", size=13)
ax1.set_xlabel("Date", size=13)
fatalItaly.plot(ax=ax2, color='orange')
ax2.set_title("Italy deceased cases", size=13)
ax2.set_ylabel("Number of cases", size=13)
ax2.set_xlabel("Date", size=13)

# %%
# China
totalChina = dfTrain[dfTrain['Country_Region']=='China'].groupby(['Date']).agg({'ConfirmedCases':['sum']})
fatalChina = dfTrain[dfTrain['Country_Region']=='China'].groupby(['Date']).agg({'Fatalities':['sum']})
dateChina = totalChina.join(fatalChina)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(17,7))
dateChina.plot(ax=ax1)
ax1.set_title("China confirmed cases", size=13)
ax1.set_ylabel("Number of cases", size=13)
ax1.set_xlabel("Date", size=13)
fatalChina.plot(ax=ax2, color='orange')
ax2.set_title("China deceased cases", size=13)
ax2.set_ylabel("Number of cases", size=13)
ax2.set_xlabel("Date", size=13)

# %%
# United States
totalUS = dfTrain[dfTrain['Country_Region']=='US'].groupby(['Date']).agg({'ConfirmedCases':['sum']})
fatalUS = dfTrain[dfTrain['Country_Region']=='US'].groupby(['Date']).agg({'Fatalities':['sum']})
dateUS = totalUS.join(fatalUS)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(17,7))
dateUS.plot(ax=ax1)
ax1.set_title("US Cases", size=13)
ax1.set_ylabel("Number of cases", size=13)
ax1.set_xlabel("Date", size=13)
fatalUS.plot(ax=ax2, color='orange')
ax2.set_title("US deceased cases", size=13)
ax2.set_ylabel("Number of cases", size=13)
ax2.set_xlabel("Date", size=13)

# %%
# United States - California
totalCA = dfTrain[dfTrain['Province_State']=='California'].groupby(['Date']).agg({'ConfirmedCases':['sum']})
fatalCA = dfTrain[dfTrain['Province_State']=='California'].groupby(['Date']).agg({'Fatalities':['sum']})
dateCA = totalCA.join(fatalCA)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(17,7))
dateCA.plot(ax=ax1)
ax1.set_title("California Cases", size=13)
ax1.set_ylabel("Number of cases", size=13)
ax1.set_xlabel("Date", size=13)
fatalCA.plot(ax=ax2, color='orange')
ax2.set_title("California deceased cases", size=13)
ax2.set_ylabel("Number of cases", size=13)
ax2.set_xlabel("Date", size=13)

# %%
# United States - New York
totalNY = dfTrain[dfTrain['Province_State']=='New York'].groupby(['Date']).agg({'ConfirmedCases':['sum']})
fatalNY = dfTrain[dfTrain['Province_State']=='New York'].groupby(['Date']).agg({'Fatalities':['sum']})
dateNY = totalNY.join(fatalNY)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(17,7))
dateNY.plot(ax=ax1)
ax1.set_title("US Cases", size=13)
ax1.set_ylabel("Number of cases", size=13)
ax1.set_xlabel("Date", size=13)
fatalNY.plot(ax=ax2, color='orange')
ax2.set_title("US deceased cases", size=13)
ax2.set_ylabel("Number of cases", size=13)
ax2.set_xlabel("Date", size=13)

# %%
dateNY

# %%
dateNY2 = dateNY.iloc[0:100,0]
dateNY2

# %%
dateNY2.shape

# %%
plt.figure(figsize=(17,10))
plt.subplot(2, 2, 1)
dateNY.plot(ax=plt.gca(), title='New York')
plt.ylabel("Confirmed infection cases", size=13)
plt.grid()
plt.subplot(2, 2, 2)
dateCA.plot(ax=plt.gca(), title='California')
plt.grid()

# %%
CA = [i for i in dateCA.ConfirmedCases['sum'].values]
CA_30 = CA[0:70] 
NY = [i for i in dateNY.ConfirmedCases['sum'].values]
NY_30 = NY[0:70] 


# Plots
plt.figure(figsize=(12,6))
plt.plot(CA_30)
plt.plot(NY_30)
plt.legend(["California", "New York"], loc='upper left')
plt.title("COVID-19 infections from the first confirmed case", size=15)
plt.xlabel("Days", size=13)
plt.ylabel("Infected cases", size=13)
plt.ylim(0, 130000)
plt.grid()
plt.show()

# %% [markdown]
# ## 1. Prediction of US Cases - Logistic Regression

# %%
trainData = dfTrain.groupby(["Date","Country_Region"], as_index=False).agg({"ConfirmedCases":["sum"],"Fatalities":["sum"]})
trainData.columns = list(map("".join, trainData.columns.values))
trainData.columns = ["Date","Country_Region","ConfirmedCases","Fatalities"]
#trainData = pd.merge(trainData, on="Country_Region")
trainData

# %%
dfTest

# %% [markdown]
# The following Logistic Regression Analysis is Referenced from Ramon Diaz's Algorithm
# https://www.kaggle.com/ramondiaz/covid19-logistic-curve-fitting/notebook

# %%
# Train x,y
x_train = dfTrain["Date"].apply(pd.to_datetime, "%m/%d/%Y")
x_train = trainData["Date"].values
y_train = trainData["ConfirmedCases"].values
x_test = dfTest["Date"].apply(pd.to_datetime, "%m/%d/%Y")
x_test = dfTest["Date"].values

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()
trainData['Date'] = (encoder.fit_transform(trainData.Date))
dfTest['Date'] = (encoder.fit_transform(dfTest.Date))

# %%
print(x_train.shape,y_train.shape,x_test.shape,sep = '\n')

# %%
x_test_new = dfTest[['Date']]
x_test = list(x_test_new['Date'])

# %%
# Logistic Curve Equation
def log_curve(x, k, x_0, L):
    return L / (1 + np.exp(-k*(x-x_0)))

# %%
from scipy.optimize import curve_fit
import datetime
# Fit the model
fitParam, fitCov = curve_fit(log_curve, x_train, y_train, bounds=([0,0,0],np.inf), maxfev=100000)
estimatedK, estimatedX0, L = fitParam
# Create the predictions
logPredict = log_curve(x_test, estimatedK, estimatedX0, L)

# %%
logPredict.shape

# %% [markdown]
# Fatalities Prediction

# %%
y_train_fatal = list(trainData["Fatalities"])

# %%
# Fit the model
fitParamFatal, fitCovFatal = curve_fit(log_curve, x_train, y_train_fatal, bounds=([0,0,0],np.inf), maxfev=100000)
estimatedKFatal, estimatedX0Fatal, LFatal = fitParamFatal
# Create the predictions
logPredictFatal = log_curve(x_test, estimatedKFatal, estimatedX0Fatal, LFatal)

# %%
logPredictFatal.shape

# %%
'''from sklearn.preprocessing import scale
import sklearn.linear_model as skl_lm
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
trainData = dfTrain.groupby(["Date"], as_index=False).agg({"ConfirmedCases":["sum"],"Fatalities":["sum"]})
trainData.columns = list(map("".join, trainData.columns.values))
trainData.columns = ["Date","ConfirmedCases","Fatalities"]
encoder = preprocessing.LabelEncoder()
#trainData['Day_No'] = (encoder.fit_transform(trainData.Date))'''

# %%
'''X = trainData["Date"].values.reshape(-1,1)
y = trainData["ConfirmedCases"].values
xtest = dfTest["Date"].values.reshape(-1,1)
#y = y.astype(np.uint8)'''

# %%
#Fatalities = Fatalities.astype(np.uint8)
#(x_train, x_test, y_train, y_test) = train_test_split(X, y,test_size=1,random_state=42)
#log = skl_lm.LogisticRegression(solver='newton-cg',n_jobs=-1)

# %%
'''print('classes: ',log.classes_)
print('coefficients: ',log.coef_)
print('intercept :', log.intercept_)'''

# %%
'''# Perform Logistic Regression on Test Data
x_train = x_train.values.reshape(-1,1)
logPredict = log.predict(x_train.values,y)
# Check accuracy of predictions from test data
#from sklearn.metrics import accuracy_score
#accuracy_score(y_test,logPredict)'''

# %%
#X = list(np.array(trainData["Date"]).reshape(-1,1))
#y1 = list(trainData["Fatalities"])
#y = y.astype(np.uint8)

# %%
#(x_train1, x_test1, y_train1, y_test1) = train_test_split(X, y1,test_size=0.95,random_state=42)
#log1 = skl_lm.LogisticRegression(solver='newton-cg')

# %%
#log1.fit(x_train1,y_train1)

# %%
'''# Perform Logistic Regression on Test Data
logPredictFatal = log1.predict(x_test1)
print(len(logPredictFatal))

# Check accuracy of predictions from test data
#from sklearn.metrics import accuracy_score
#accuracy_score(y_test,logPredict)'''

# %%
submission = pd.DataFrame(dfTest["ForecastId"])

# %%
submission['ConfirmedCases'] = logPredict
submission['Fatalities'] = logPredictFatal
submission

# %%
submission.to_csv('submission.csv', index = False)
