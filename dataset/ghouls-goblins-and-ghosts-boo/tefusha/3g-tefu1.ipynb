# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# zipfileをcsvにする
import zipfile
zf1 = zipfile.ZipFile('/kaggle/input/ghouls-goblins-and-ghosts-boo/train.csv.zip')
print(zf1.namelist())

zf2 = zipfile.ZipFile('/kaggle/input/ghouls-goblins-and-ghosts-boo/test.csv.zip')
print(zf2.namelist()) 

zf3 = zipfile.ZipFile('/kaggle/input/ghouls-goblins-and-ghosts-boo/sample_submission.csv.zip')
print(zf3.namelist())

# %%
zf1.extractall()
zf2.extractall()
zf3.extractall()

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.describe

# %%
# csv内のヘッダーを確認
import csv
csv_file = open("train.csv", "r", encoding="ms932", errors="", newline="" )
f = csv.reader(csv_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)
header = next(f)
print(header)

# %%
# ダミー
pd.get_dummies(train['type'])
pd.get_dummies(train['color'])
pd.get_dummies(test['color'])

training = pd.get_dummies(train, columns=['color','type'])
training
testing = pd.get_dummies(test, columns=['color'])
testing

# %%
# ダミー導入後の相関
training.corr()

# %%
# ニューラルネットワーク
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
import joblib

# %%
## Ghost
# paramate
hidden_layer_sizes=(100,)
activation = 'relu'
solver = 'adam'
batch_size = 'auto'
alpha = 0.0001
random_state = 0
max_iter = 10000
# early_stopping = True

# 説明変数
x = ['bone_length', 'rotting_flesh', 'hair_length', 'has_soul','color_black','color_blood','color_blue','color_clear','color_green','color_white']
# x = ['bone_length', 'rotting_flesh', 'hair_length', 'has_soul']

train_X = training[x]

# 目的変数
y1 = ['type_Ghost']
train_y1 = training[y1]

# 学習
clf = MLPClassifier(
    hidden_layer_sizes=hidden_layer_sizes,
    activation=activation,
    solver=solver,
    batch_size=batch_size,
    alpha=alpha,
    random_state=random_state,
    max_iter=max_iter,
#     early_stopping = early_stopping
    )

clf.fit(train_X, train_y1)

SAVE_TRAINED_DATA_PATH = 'train1.learn'
# 学習結果を出力
joblib.dump(clf, SAVE_TRAINED_DATA_PATH)

# 学習済ファイルのロード
clf1 = joblib.load(SAVE_TRAINED_DATA_PATH)



# 検証用の説明変数（学習データ）：x1, x2
# test_X = test['bone_length', 'rotting_flesh', 'hair_length', 'has_soul', 'color_black','color_blood','color_blue','color_clear','color_green','color_white']
test_X1 = testing[x]

# 検証用の目的変数（正解データ）：x3
# test_y = test[y1]

# 学習結果の検証（テスト用データx1, x2を入力）
predict_y1 = clf1.predict_proba(test_X1)
predict_Y1 = clf1.predict(test_X1)

# 学習データの精度
print("学習データの精度: {:.3f}".format(clf.score(train_X, train_y1)))

# テスト結果の精度
print("テスト結果の精度: {:.3f}".format(clf.score(test_X1, predict_Y1)))

# %%
## Ghoul
# paramate
hidden_layer_sizes=(100,)
activation = 'relu'
solver = 'adam'
batch_size = 'auto'
alpha = 0.0001
random_state = 0
max_iter = 10000
# early_stopping = True

# 説明変数
# x = ['bone_length', 'rotting_flesh', 'hair_length', 'has_soul','color_black','color_blood','color_blue','color_clear','color_green','color_white']
train_X = training[x]

# 目的変数
y2 = ['type_Ghoul']
train_y2 = training[y2]

# 学習
clf = MLPClassifier(
    hidden_layer_sizes=hidden_layer_sizes,
    activation=activation,
    solver=solver,
    batch_size=batch_size,
    alpha=alpha,
    random_state=random_state,
    max_iter=max_iter,
#     early_stopping = early_stopping
    )

clf.fit(train_X, train_y2)

SAVE_TRAINED_DATA_PATH = 'train2.learn'
# 学習結果を出力
joblib.dump(clf, SAVE_TRAINED_DATA_PATH)

# 学習済ファイルのロード
clf2 = joblib.load(SAVE_TRAINED_DATA_PATH)



# 検証用の説明変数（学習データ）：x1, x2
# test_X = test['bone_length', 'rotting_flesh', 'hair_length', 'has_soul', 'color_black','color_blood','color_blue','color_clear','color_green','color_white']
test_X2 = testing[x]

# 検証用の目的変数（正解データ）：x3
# test_y = test[y1]

# 学習結果の検証（テスト用データx1, x2を入力）
predict_y2 = clf2.predict_proba(test_X2)
predict_Y2 = clf2.predict(test_X2)

# 学習データの精度
print("訓練セットの精度: {:.3f}".format(clf.score(train_X, train_y2)))

# テスト結果の精度
print("テスト結果の精度: {:.3f}".format(clf.score(test_X2, predict_Y2)))

# %%
## Goblin
# paramate
hidden_layer_sizes=(100,)
activation = 'relu'
solver = 'adam'
batch_size = 'auto'
alpha = 0.0001
random_state = 0
max_iter = 10000
# early_stopping = True

# 説明変数
# x = ['bone_length', 'rotting_flesh', 'hair_length', 'has_soul','color_black','color_blood','color_blue','color_clear','color_green','color_white']
train_X = training[x]

# 目的変数
y3 = ['type_Goblin']
train_y3 = training[y3]

# 学習
clf = MLPClassifier(
    hidden_layer_sizes=hidden_layer_sizes,
    activation=activation,
    solver=solver,
    batch_size=batch_size,
    alpha=alpha,
    random_state=random_state,
    max_iter=max_iter,
#     early_stopping = early_stopping
    )


clf.fit(train_X, train_y3)

SAVE_TRAINED_DATA_PATH = 'train3.learn'
# 学習結果を出力
joblib.dump(clf, SAVE_TRAINED_DATA_PATH)

# 学習済ファイルのロード
clf3 = joblib.load(SAVE_TRAINED_DATA_PATH)



# 検証用の説明変数（学習データ）：x1, x2
# test_X = test['bone_length', 'rotting_flesh', 'hair_length', 'has_soul', 'color_black','color_blood','color_blue','color_clear','color_green','color_white']
test_X3 = testing[x]

# 検証用の目的変数（正解データ）：x3
# test_y = test[y1]

# 学習結果の検証（テスト用データx1, x2を入力）
predict_y3 = clf3.predict_proba(test_X3)
predict_Y3 = clf3.predict(test_X3)

# 学習データの精度
print("訓練セットの精度: {:.3f}".format(clf.score(train_X, train_y3)))

# テスト結果の精度
print("テスト結果の精度: {:.3f}".format(clf.score(test_X3, predict_Y3)))

# %%
# テストデータ
print(len(predict_y1))

type = []
for m in range(len(predict_y1)):
    l = [predict_y1[m][1],predict_y2[m][1],predict_y3[m][1]]
    max2 = l.index(max(l))
    if max2 == 0:
        type.append('Ghost')
    elif max2 == 1:
        type.append('Ghoul')
    else:
        type.append('Goblin')

print(type)

# %%
# 提出用データ
sub = pd.read_csv('sample_submission.csv')
sub['type'] = list(map(str, type))
sub.to_csv('sample_submission.csv', index=False)
