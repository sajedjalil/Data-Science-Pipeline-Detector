# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Name of the Dataset is IEEE-fraud-detection

# %%
test=pd.read_csv('../input/ieee-fraud-detection/test_transaction.csv')

# %%
test

# %%
test.info()

# %% [markdown]
# 1. Number of Instances= 5,06,691
# 2. Number of Attributes=393

# %%
test.describe()

# %% [markdown]
# Here we have calculated the mean,median,mode,Q1(25%),Q2(75%)
