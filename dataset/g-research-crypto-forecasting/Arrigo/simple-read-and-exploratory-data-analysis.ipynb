# %% [markdown]
# # Simple EDA
#
# In this Kaggle notebook is presented a simple EDA of the [G-Research Crypto Forecast Competition](https://www.kaggle.com/c/g-research-crypto-forecasting/overview).
#
# Any comments and votes are very welcome! ;)

# %% [markdown]
#  <a id="1"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">How to copy this notebook?</p>
#
# To copy this notebook to start making your own modifications you just neet to click the button "Copy & Edit" that is in the upper right corner of the page. After doing that, you could make any change to it.
#
# Each block of code is named "cell". And to run a cel you need to put the cursor on it and hit "ctrl+Intro" in the keyboard.
#
#
# The next cell has some python modules that we will use (module = a bunch of useful functions).  If you need to use those modules, you need to erase the "#".
#
# Let first run th

# %%
import pandas as pd 
import numpy as np

# import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
#  <a id="1"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Reading Data </p>
#
# We will only work with the "train.csv" data. So the next cell reads the data and save it under the name "train". One could read in the same way the other files; to do that one just needs to eliminate the character "#" of the beggining of the line and run again the cel.
#
# This could take like 30 seconds to run.

# %%
train = pd.read_csv('../input/g-research-crypto-forecasting/train.csv') 
# test = pd.read_csv('../input/g-research-crypto-forecasting/example_test.csv') 
# sub = pd.read_csv('../input/g-research-crypto-forecasting/example_sample_submission.csv') 
# asset_details = pd.read_csv('../input/g-research-crypto-forecasting/asset_details.csv')

# %% [markdown]
# <a id="1"></a>
# # <p style="background-color:#627D78;font-family:newtimeroman;color:#D5CABD;font-size:150%;text-align:center;border-radius:20px 60px;">Data Exploration</p>
#
# The simples data exploration that we could perform is to print the first 10 lines of the "train" data.

# %%
train.head(10)

# %% [markdown]
# In the next cells we explore other characteristics of the data

# %%
# The type of each colum
train.info()

# %%
# The dimension of the data (number of rows and colums)
train.shape

# %%
# Number fo NA values (NA = Not Answer mining that is a missing value )
train.isna().sum()

# %%
# Basic statistics 
train.describe()

# %% [markdown]
# This notebook is still in progres, so any comment is more than welcome.
#
# The same goes for up-votes (to up-vote a notebook you need to click the button with the triangle that appears in the upper left of the original notebook next to the "Copy & Edit" button).
#
# Best regards,
# A
