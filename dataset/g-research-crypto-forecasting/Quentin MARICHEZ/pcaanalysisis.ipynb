# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

crypto = pd.read_csv("../input/g-research-crypto-forecasting/supplemental_train.csv")

# %%
bitcoin=crypto[crypto['Asset_ID']==1].dropna()
btc_train=bitcoin[bitcoin['timestamp']<1630181440] 
btc_test=bitcoin[bitcoin['timestamp']>1630181440] 
training_data = btc_train.drop(['timestamp','Asset_ID'], axis = 1)

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

eth_pca_dataset1 = bitcoin.dropna().drop(labels=['Target','timestamp','Asset_ID'], axis=1)
#print(eth_pca_dataset1.size)

pca = PCA(n_components=2)
pca.fit(eth_pca_dataset1)

X_r = pca.fit(eth_pca_dataset1).transform(eth_pca_dataset1)
min_max_scaler =preprocessing.MinMaxScaler()

y = bitcoin.dropna()
#print(y.tail(17))
y = y['Target']

print(max(y))
print(min(y))
print(np.std(y))
y = y.values.reshape(-1,1)

y =min_max_scaler.fit_transform(y)



#print(y.size)


#print(pca.explained_variance_ratio_)

pca.get_covariance()

print(max(y))

cmap = sns.cubehelix_palette(as_cmap = True)
f,ax = plt.subplots()
points = ax.scatter(X_r[:,0],X_r[:,1],c=y[:,0],cmap=cmap)
f.colorbar(points)
plt.xlim(0, 30000)
plt.ylim(0, 10000)
plt.show()
