# %% [markdown]
# ## Crypto Leaderboard on 2020/02/18
#
# Is it just random?

# %%
import pandas as pd

df = pd.read_csv('../input/leaderboardcrypto20220218/g-research-crypto-forecasting-publicleaderboard.csv')

# %%
df.head()

# %% [markdown]
# ### Invalid scores
#
# There are others (like me) who directly got an error and we dissapeared from the competition.

# %%
df.query('Score == -1')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.histplot(data=df.query('Score != -1'), x='Score', kde=True)
plt.title('Scores distribution')

# %% [markdown]
# Looks like a matter of luck. If you are lucky enough to not get an error? I'd love to know your opinion.
