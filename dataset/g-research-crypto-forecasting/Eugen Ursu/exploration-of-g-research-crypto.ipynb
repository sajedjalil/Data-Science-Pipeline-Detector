# %%
from pathlib import Path
import pandas as pd

INPUT_DIR = Path("/kaggle/input/g-research-crypto-forecasting")
OUTPUT_DIR = INPUT_DIR.parent / "output"

# %% [markdown]
# ## Asset details
# It looks like there are 14 cryptocurrencies with weights associated to them. The weights vary significantly, with most max weight being identified for BTC.

# %%
assets = pd.read_csv(INPUT_DIR / "asset_details.csv").sort_values(by=["Weight"], ascending=False)
assets

# %%
assets['Weight'].plot.hist()

# %% [markdown]
# ## The example sample submission and example test set

# %%
sample_submission_example = pd.read_csv(INPUT_DIR / "example_sample_submission.csv")
print(f"Shape of sample submission: {sample_submission_example.shape}")
sample_submission_example.head(3)

# %%
example_test = pd.read_csv(INPUT_DIR / "example_test.csv")
example_test.head(3)

# %% [markdown]
# ## Training set

# %%
train = pd.read_csv(INPUT_DIR / "train.csv")
print(f"Shape of train: {train.shape}")
train.head(3)

# %% [markdown]
# ## Training set supplement

# %%
train_supp = pd.read_csv(INPUT_DIR / "supplemental_train.csv")
print(f"Shape of train: {train_supp.shape}")
train_supp.head(3)
