# %% [markdown]
# # Data Processing

# %%
# Choice from [ full, test, local]
mode = 'full'

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import gc
from datetime import datetime, timedelta
from sklearn.metrics import log_loss
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.


#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_profiling

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#Set missing value
pd.options.mode.use_inf_as_na = True

#date time
import datetime

# %%
if mode == 'full':
    from kaggle.competitions import twosigmanews
    env = twosigmanews.make_env()
    (market_df, news_df) = env.get_training_data()
    Select_Portion = 1.0
elif mode == 'test':
    from kaggle.competitions import twosigmanews
    env = twosigmanews.make_env()
    (market_df, news_df) = env.get_training_data()
    Select_Portion = .8
elif mode == 'local':
    market_df = pd.read_csv("./Two Sigma Data/all/marketdata_sample.csv")
    news_df = pd.read_csv("./Two Sigma Data/all/news_sample.csv")
    Select_Portion = 1.0

# %%
market_profile = pandas_profiling.ProfileReport(market_df)
market_rejected_variables = market_profile.get_rejected_variables(threshold=0.9)
print("market_rejected_variables", market_rejected_variables)
market_profile.to_file(outputfile="market_train_df_profile.html")
market_profile
