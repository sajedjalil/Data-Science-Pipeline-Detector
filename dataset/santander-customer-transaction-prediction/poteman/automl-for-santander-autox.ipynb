# %%
# !git clone https://github.com/4paradigm/autox.git
# !pip install ./autox

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
train = pd.read_csv('../input/santander-customer-transaction-prediction/train.csv')
test = pd.read_csv('../input/santander-customer-transaction-prediction/test.csv')

# train = pd.read_csv('../input/santander-small/santander_train_small.csv')
# test = pd.read_csv('../input/santander-small/santander_test_small.csv')

# %%
train.head()

# %%
test.head()

# %%
train.shape, test.shape

# %%
from autox import AutoX

path = f'../input/santander-customer-transaction-prediction' # path = f'../input/santander-small'
autox = AutoX(target = 'target', train_name = 'train.csv', test_name = 'test.csv',  id = ['ID_code'], path = path)
sub = autox.get_submit()

# %%
sub.shape, test.shape

# %%
sub.head()

# %%
sub.to_csv("./autox_Santander.csv", index = False)

# %% [markdown]
# Please upvote if you like this, thx.
#
# More details: [github-AutoX](https://github.com/4paradigm/autox?spm=5176.21852664.0.0.5594640eeR1PoH)
