# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %%
train_df = pd.read_csv( '../input/train.csv' )
test_df = pd.read_csv( '../input/test.csv' )

# %%
# To verify the data types and data format
train_df.info()
train_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB
# (200000, 202)

# %%
test_df.info()
test_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 201 entries, ID_code to var_199
# dtypes: float64(200), object(1)
# memory usage: 306.7+ MB
# (200000, 201)

# %%
train_df.head( 10 )
# Out:
#    ID_code  target    var_0   var_1   ...     var_196  var_197  var_198  var_199
# 0  train_0       0   8.9255 -6.7863   ...      7.8784   8.5635  12.7803  -1.0914
# 1  train_1       0  11.5006 -4.1473   ...      8.1267   8.7889  18.3560   1.9518
# 2  train_2       0   8.6093 -2.7457   ...     -6.5213   8.2675  14.7222   0.3965
# 3  train_3       0  11.0604 -2.1518   ...     -2.9275  10.2922  17.9697  -8.9996
# 4  train_4       0   9.8369 -1.4834   ...      3.9267   9.5031  17.9974  -8.8104
# 5  train_5       0  11.4763 -2.3182   ...     -3.6241   9.7670  12.5809  -4.7602
# 6  train_6       0  11.8091 -0.0832   ...      9.1104   9.1143  10.8869  -3.2097
# 7  train_7       0  13.5580 -7.9881   ...      4.2178   9.4237   8.6624   3.4806
# 8  train_8       0  16.1071  2.4426   ...     -1.0733   8.1975  19.5114   4.8453
# 9  train_9       0  12.5088  1.9743   ...     14.1287   7.9133  16.2375  14.2514
#
# [10 rows x 202 columns]

# %%
test_df.head(10)
# Out:
#   ID_code    var_0    var_1   ...     var_197  var_198  var_199
# 0  test_0  11.0656   7.7798   ...     10.7200  15.4722  -8.7197
# 1  test_1   8.5304   1.2543   ...      9.8714  19.1293 -20.9760
# 2  test_2   5.4827 -10.3581   ...      7.0618  19.8956 -23.1794
# 3  test_3   8.5374  -1.3222   ...      9.2295  13.0168  -4.2108
# 4  test_4  11.7058  -0.1327   ...      7.2882  13.9260  -9.1846
# 5  test_5   5.9862  -2.2913   ...      9.8117  17.1127  10.8240
# 6  test_6   8.4624  -6.1065   ...      9.1509  18.4736   5.1499
# 7  test_7  17.3035  -2.4212   ...     10.4855  23.4631   0.7283
# 8  test_8   6.9856   0.8402   ...      9.9207  16.9865  -3.3304
# 9  test_9  10.3811  -6.9348   ...      9.5788  15.8146   9.3457
#
# [10 rows x 201 columns]

# %%
TrainMissingCount = train_df.isnull().sum()
print( TrainMissingCount )
# Out:
# ID_code    0
# target     0
# var_0      0
# var_1      0
# var_2      0
# var_3      0
# var_4      0
# var_5      0
# var_6      0
# var_7      0
# var_8      0
# var_9      0
# var_10     0
# var_11     0
# var_12     0
# var_13     0
# var_14     0
# var_15     0
# var_16     0
# var_17     0
# var_18     0
# var_19     0
# var_20     0
# var_21     0
# var_22     0
# var_23     0
# var_24     0
# var_25     0
# var_26     0
# var_27     0
#           ..
# var_170    0
# var_171    0
# var_172    0
# var_173    0
# var_174    0
# var_175    0
# var_176    0
# var_177    0
# var_178    0
# var_179    0
# var_180    0
# var_181    0
# var_182    0
# var_183    0
# var_184    0
# var_185    0
# var_186    0
# var_187    0
# var_188    0
# var_189    0
# var_190    0
# var_191    0
# var_192    0
# var_193    0
# var_194    0
# var_195    0
# var_196    0
# var_197    0
# var_198    0
# var_199    0
# Length: 202, dtype: int64

# %%
TestMissingCount = test_df.isnull().sum()
print( TestMissingCount )
# Out:
# ID_code    0
# var_0      0
# var_1      0
# var_2      0
# var_3      0
# var_4      0
# var_5      0
# var_6      0
# var_7      0
# var_8      0
# var_9      0
# var_10     0
# var_11     0
# var_12     0
# var_13     0
# var_14     0
# var_15     0
# var_16     0
# var_17     0
# var_18     0
# var_19     0
# var_20     0
# var_21     0
# var_22     0
# var_23     0
# var_24     0
# var_25     0
# var_26     0
# var_27     0
# var_28     0
#           ..
# var_170    0
# var_171    0
# var_172    0
# var_173    0
# var_174    0
# var_175    0
# var_176    0
# var_177    0
# var_178    0
# var_179    0
# var_180    0
# var_181    0
# var_182    0
# var_183    0
# var_184    0
# var_185    0
# var_186    0
# var_187    0
# var_188    0
# var_189    0
# var_190    0
# var_191    0
# var_192    0
# var_193    0
# var_194    0
# var_195    0
# var_196    0
# var_197    0
# var_198    0
# var_199    0
# Length: 201, dtype: int64

# %%
train_df.describe()
# Out:
#               target          var_0      ...              var_198        var_199
# count  200000.000000  200000.000000      ...        200000.000000  200000.000000
# mean        0.100490      10.679914      ...            15.870720      -3.326537
# std         0.300653       3.040051      ...             3.010945      10.438015
# min         0.000000       0.408400      ...             6.299300     -38.852800
# 25%         0.000000       8.453850      ...            13.829700     -11.208475
# 50%         0.000000      10.524750      ...            15.934050      -2.819550
# 75%         0.000000      12.758200      ...            18.064725       4.836800
# max         1.000000      20.315000      ...            26.079100      28.500700
#
# [8 rows x 201 columns]

# %%
test_df.describe()
# Out:
#                var_0          var_1      ...              var_198        var_199
# count  200000.000000  200000.000000      ...        200000.000000  200000.000000
# mean       10.658737      -1.624244      ...            15.869184      -3.246342
# std         3.036716       4.040509      ...             3.008717      10.398589
# min         0.188700     -15.043400      ...             6.584000     -39.457800
# 25%         8.442975      -4.700125      ...            13.847275     -11.124000
# 50%        10.513800      -1.590500      ...            15.943400      -2.725950
# 75%        12.739600       1.343400      ...            18.045200       4.935400
# max        22.323400       9.385100      ...            26.538400      27.907400
#
# [8 rows x 200 columns]

# %% [markdown]
# Looks like, the target variable is train_df['target'] and the feature variables are from var_0 to var_199( 200 variables ). 200000 entries are there in both train and test data set. Variables data types are same - float64. There is no categorical variable in the dataset. So no encoding is required. And no missing data in the training and test data set. The variable count is same in both train and test data set.
#
# As per the describe() function, the data looks good. no scaling is required. There is a difference between mean and standard deviation. But we can see the same variation between train and test data set.

# %%
X_train = train_df[list(train_df.columns[2:])]

# %%
X_train.head(10)
# Out:
#      var_0   var_1    var_2   var_3   ...     var_196  var_197  var_198  var_199
# 0   8.9255 -6.7863  11.9081  5.0930   ...      7.8784   8.5635  12.7803  -1.0914
# 1  11.5006 -4.1473  13.8588  5.3890   ...      8.1267   8.7889  18.3560   1.9518
# 2   8.6093 -2.7457  12.0805  7.8928   ...     -6.5213   8.2675  14.7222   0.3965
# 3  11.0604 -2.1518   8.9522  7.1957   ...     -2.9275  10.2922  17.9697  -8.9996
# 4   9.8369 -1.4834  12.8746  6.6375   ...      3.9267   9.5031  17.9974  -8.8104
# 5  11.4763 -2.3182  12.6080  8.6264   ...     -3.6241   9.7670  12.5809  -4.7602
# 6  11.8091 -0.0832   9.3494  4.2916   ...      9.1104   9.1143  10.8869  -3.2097
# 7  13.5580 -7.9881  13.8776  7.5985   ...      4.2178   9.4237   8.6624   3.4806
# 8  16.1071  2.4426  13.9307  5.6327   ...     -1.0733   8.1975  19.5114   4.8453
# 9  12.5088  1.9743   8.8960  5.4508   ...     14.1287   7.9133  16.2375  14.2514
#
# [10 rows x 200 columns]

# %%
# Visualizing the train - target variable
sns.countplot( train_df['target'] )

# %% [markdown]
# As per input data set, the True transactions are less

# %%
y_train = train_df['target']

# %%
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
X_test = test_df[list(test_df.columns[1:])]
X_test.head()
# Out:
#      var_0    var_1    var_2   ...     var_197  var_198  var_199
# 0  11.0656   7.7798  12.9536   ...     10.7200  15.4722  -8.7197
# 1   8.5304   1.2543  11.3047   ...      9.8714  19.1293 -20.9760
# 2   5.4827 -10.3581  10.1407   ...      7.0618  19.8956 -23.1794
# 3   8.5374  -1.3222  12.0220   ...      9.2295  13.0168  -4.2108
# 4  11.7058  -0.1327  14.1295   ...      7.2882  13.9260  -9.1846
#
# [5 rows x 200 columns]

# %%
train = train_df
test = test_df
train_correlations = train.drop(["target"], axis=1).corr()
train_correlations = train_correlations.values.flatten()
train_correlations = train_correlations[train_correlations != 1]

test_correlations = test.corr()
test_correlations = test_correlations.values.flatten()
test_correlations = test_correlations[test_correlations != 1]

plt.figure(figsize=(20,5))
sns.distplot(train_correlations, color="Red", label="train")
sns.distplot(test_correlations, color="Green", label="test")
plt.xlabel("Correlation values found in train")
plt.ylabel("Density")
plt.title("Correlations between features"); 
plt.legend();

# %% [markdown]
# **Model**

# %%
learningRate = 0.1
xgbModel = xgb.XGBClassifier(   max_depth = 5,
                                objective = 'binary:logistic',
                                booster= 'gbtree',
                                learning_rate = learningRate,
                                base_score= 0.2,
                                alpha= 0.4,
                                n_estimators= 100,
                                seed= 1301,
                                silent= 1,
                                eta= 0.3,
                                gamma= 0,
                                min_child_weight= 1,
                                max_delta_step= 0,
                                subsample= .8,
                                colsample_bytree= .8,
                                reg_alpha=0,
                                reg_lambda= 1,
                                missing= None,
                                verbosity= 1,
                                nthread = 2 )

# %%
idx         = 1
kf          = StratifiedKFold( n_splits = 10, random_state = 44000, shuffle = False )

for train_index, val_index in kf.split( y_train, y_train ):
    print('\n{} of kfold {}'.format( idx, kf.n_splits ))
    trn_dat, trn_tgt = X_train.loc[ train_index ], y_train.loc[ train_index ]
    val_dat, val_tgt = X_train.loc[ val_index ], y_train.loc[ val_index ]
    xgbModel.fit( trn_dat, trn_tgt,
                  early_stopping_rounds = 20,
                  eval_set = [(trn_dat, trn_tgt), (val_dat, val_tgt)],
                  eval_metric = "auc", verbose = True )
    pred = xgbModel.predict( val_dat )
    print('accuracy_score', accuracy_score( val_tgt, pred ))
    idx += 1
# Out:
# 1 of kfold 10
# [0]	validation_0-auc:0.636675	validation_1-auc:0.625323
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.664236	validation_1-auc:0.654259
# [2]	validation_0-auc:0.687647	validation_1-auc:0.676336
# [3]	validation_0-auc:0.689978	validation_1-auc:0.674596
# [4]	validation_0-auc:0.705076	validation_1-auc:0.688033
# [5]	validation_0-auc:0.711341	validation_1-auc:0.695028
# [6]	validation_0-auc:0.716708	validation_1-auc:0.700507
# [7]	validation_0-auc:0.724117	validation_1-auc:0.708003
# [8]	validation_0-auc:0.740161	validation_1-auc:0.721706
# [9]	validation_0-auc:0.745903	validation_1-auc:0.72486
# [10]	validation_0-auc:0.75261	validation_1-auc:0.732316
# [11]	validation_0-auc:0.758447	validation_1-auc:0.736728
# [12]	validation_0-auc:0.76491	validation_1-auc:0.740102
# [13]	validation_0-auc:0.77066	validation_1-auc:0.745774
# [14]	validation_0-auc:0.776043	validation_1-auc:0.751905
# [15]	validation_0-auc:0.781085	validation_1-auc:0.756938
# [16]	validation_0-auc:0.784652	validation_1-auc:0.758282
# [17]	validation_0-auc:0.790503	validation_1-auc:0.762984
# [18]	validation_0-auc:0.794217	validation_1-auc:0.764484
# [19]	validation_0-auc:0.797356	validation_1-auc:0.766346
# [20]	validation_0-auc:0.802824	validation_1-auc:0.770691
# [21]	validation_0-auc:0.806599	validation_1-auc:0.773681
# [22]	validation_0-auc:0.810289	validation_1-auc:0.777618
# [23]	validation_0-auc:0.813858	validation_1-auc:0.78024
# [24]	validation_0-auc:0.81674	validation_1-auc:0.782327
# [25]	validation_0-auc:0.820698	validation_1-auc:0.785812
# [26]	validation_0-auc:0.82375	validation_1-auc:0.787732
# [27]	validation_0-auc:0.826175	validation_1-auc:0.789256
# [28]	validation_0-auc:0.828241	validation_1-auc:0.791464
# [29]	validation_0-auc:0.83094	validation_1-auc:0.793337
# [30]	validation_0-auc:0.83232	validation_1-auc:0.794027
# [31]	validation_0-auc:0.835054	validation_1-auc:0.796026
# [32]	validation_0-auc:0.837348	validation_1-auc:0.796832
# [33]	validation_0-auc:0.839389	validation_1-auc:0.798807
# [34]	validation_0-auc:0.842021	validation_1-auc:0.800631
# [35]	validation_0-auc:0.844298	validation_1-auc:0.801584
# [36]	validation_0-auc:0.846564	validation_1-auc:0.80259
# [37]	validation_0-auc:0.847848	validation_1-auc:0.804007
# [38]	validation_0-auc:0.849137	validation_1-auc:0.805345
# [39]	validation_0-auc:0.850897	validation_1-auc:0.806769
# [40]	validation_0-auc:0.852694	validation_1-auc:0.807764
# [41]	validation_0-auc:0.854774	validation_1-auc:0.809013
# [42]	validation_0-auc:0.857241	validation_1-auc:0.810844
# [43]	validation_0-auc:0.858544	validation_1-auc:0.812383
# [44]	validation_0-auc:0.860168	validation_1-auc:0.813517
# [45]	validation_0-auc:0.861981	validation_1-auc:0.814776
# [46]	validation_0-auc:0.863191	validation_1-auc:0.815426
# [47]	validation_0-auc:0.864607	validation_1-auc:0.816372
# [48]	validation_0-auc:0.866366	validation_1-auc:0.817742
# [49]	validation_0-auc:0.867836	validation_1-auc:0.819287
# [50]	validation_0-auc:0.869354	validation_1-auc:0.820704
# [51]	validation_0-auc:0.870954	validation_1-auc:0.821215
# [52]	validation_0-auc:0.872615	validation_1-auc:0.821762
# [53]	validation_0-auc:0.873397	validation_1-auc:0.822015
# [54]	validation_0-auc:0.874586	validation_1-auc:0.823295
# [55]	validation_0-auc:0.875622	validation_1-auc:0.82431
# [56]	validation_0-auc:0.876802	validation_1-auc:0.824963
# [57]	validation_0-auc:0.87821	validation_1-auc:0.82596
# [58]	validation_0-auc:0.878947	validation_1-auc:0.826556
# [59]	validation_0-auc:0.879895	validation_1-auc:0.827522
# [60]	validation_0-auc:0.880718	validation_1-auc:0.827998
# [61]	validation_0-auc:0.881329	validation_1-auc:0.828762
# [62]	validation_0-auc:0.882518	validation_1-auc:0.829586
# [63]	validation_0-auc:0.883385	validation_1-auc:0.830135
# [64]	validation_0-auc:0.88453	validation_1-auc:0.83081
# [65]	validation_0-auc:0.885162	validation_1-auc:0.831363
# [66]	validation_0-auc:0.886138	validation_1-auc:0.831932
# [67]	validation_0-auc:0.886902	validation_1-auc:0.832207
# [68]	validation_0-auc:0.887708	validation_1-auc:0.832896
# [69]	validation_0-auc:0.888467	validation_1-auc:0.833528
# [70]	validation_0-auc:0.889823	validation_1-auc:0.834253
# [71]	validation_0-auc:0.890654	validation_1-auc:0.83454
# [72]	validation_0-auc:0.891227	validation_1-auc:0.834974
# [73]	validation_0-auc:0.891791	validation_1-auc:0.83553
# [74]	validation_0-auc:0.892363	validation_1-auc:0.835392
# [75]	validation_0-auc:0.893244	validation_1-auc:0.836029
# [76]	validation_0-auc:0.893935	validation_1-auc:0.836645
# [77]	validation_0-auc:0.894842	validation_1-auc:0.837341
# [78]	validation_0-auc:0.895851	validation_1-auc:0.838244
# [79]	validation_0-auc:0.896372	validation_1-auc:0.83858
# [80]	validation_0-auc:0.89721	validation_1-auc:0.83905
# [81]	validation_0-auc:0.898335	validation_1-auc:0.839239
# [82]	validation_0-auc:0.899064	validation_1-auc:0.839586
# [83]	validation_0-auc:0.89973	validation_1-auc:0.839723
# [84]	validation_0-auc:0.9007	validation_1-auc:0.840426
# [85]	validation_0-auc:0.901353	validation_1-auc:0.840758
# [86]	validation_0-auc:0.901963	validation_1-auc:0.841324
# [87]	validation_0-auc:0.902485	validation_1-auc:0.841178
# [88]	validation_0-auc:0.903009	validation_1-auc:0.841696
# [89]	validation_0-auc:0.903594	validation_1-auc:0.8421
# [90]	validation_0-auc:0.90433	validation_1-auc:0.842933
# [91]	validation_0-auc:0.904989	validation_1-auc:0.84365
# [92]	validation_0-auc:0.90552	validation_1-auc:0.844082
# [93]	validation_0-auc:0.906022	validation_1-auc:0.844482
# [94]	validation_0-auc:0.906762	validation_1-auc:0.845219
# [95]	validation_0-auc:0.907272	validation_1-auc:0.845321
# [96]	validation_0-auc:0.907766	validation_1-auc:0.845336
# [97]	validation_0-auc:0.90833	validation_1-auc:0.846063
# [98]	validation_0-auc:0.908856	validation_1-auc:0.846528
# [99]	validation_0-auc:0.909545	validation_1-auc:0.846766
# accuracy_score 0.9063046847657618
#
# 2 of kfold 10
# [0]	validation_0-auc:0.624972	validation_1-auc:0.620466
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.666431	validation_1-auc:0.65749
# [2]	validation_0-auc:0.68601	validation_1-auc:0.672302
# [3]	validation_0-auc:0.692332	validation_1-auc:0.676642
# [4]	validation_0-auc:0.701492	validation_1-auc:0.68169
# [5]	validation_0-auc:0.709699	validation_1-auc:0.691017
# [6]	validation_0-auc:0.724511	validation_1-auc:0.701295
# [7]	validation_0-auc:0.731832	validation_1-auc:0.70718
# [8]	validation_0-auc:0.743114	validation_1-auc:0.717051
# [9]	validation_0-auc:0.749647	validation_1-auc:0.724126
# [10]	validation_0-auc:0.758691	validation_1-auc:0.729686
# [11]	validation_0-auc:0.762411	validation_1-auc:0.732247
# [12]	validation_0-auc:0.768375	validation_1-auc:0.739226
# [13]	validation_0-auc:0.775091	validation_1-auc:0.744758
# [14]	validation_0-auc:0.780561	validation_1-auc:0.750668
# [15]	validation_0-auc:0.785029	validation_1-auc:0.754778
# [16]	validation_0-auc:0.787661	validation_1-auc:0.75523
# [17]	validation_0-auc:0.792191	validation_1-auc:0.759146
# [18]	validation_0-auc:0.797286	validation_1-auc:0.762947
# [19]	validation_0-auc:0.799658	validation_1-auc:0.765286
# [20]	validation_0-auc:0.803946	validation_1-auc:0.767685
# [21]	validation_0-auc:0.808645	validation_1-auc:0.771183
# [22]	validation_0-auc:0.812298	validation_1-auc:0.774677
# [23]	validation_0-auc:0.81465	validation_1-auc:0.776985
# [24]	validation_0-auc:0.817676	validation_1-auc:0.779146
# [25]	validation_0-auc:0.820924	validation_1-auc:0.781913
# [26]	validation_0-auc:0.824275	validation_1-auc:0.786023
# [27]	validation_0-auc:0.827106	validation_1-auc:0.788064
# [28]	validation_0-auc:0.830099	validation_1-auc:0.790977
# [29]	validation_0-auc:0.832345	validation_1-auc:0.792501
# [30]	validation_0-auc:0.835422	validation_1-auc:0.795727
# [31]	validation_0-auc:0.837309	validation_1-auc:0.796907
# [32]	validation_0-auc:0.838798	validation_1-auc:0.79913
# [33]	validation_0-auc:0.839803	validation_1-auc:0.800748
# [34]	validation_0-auc:0.841484	validation_1-auc:0.800952
# [35]	validation_0-auc:0.844145	validation_1-auc:0.80205
# [36]	validation_0-auc:0.845868	validation_1-auc:0.803428
# [37]	validation_0-auc:0.848606	validation_1-auc:0.805112
# [38]	validation_0-auc:0.850515	validation_1-auc:0.80735
# [39]	validation_0-auc:0.852234	validation_1-auc:0.808847
# [40]	validation_0-auc:0.853915	validation_1-auc:0.809506
# [41]	validation_0-auc:0.856107	validation_1-auc:0.811444
# [42]	validation_0-auc:0.857602	validation_1-auc:0.81307
# [43]	validation_0-auc:0.859183	validation_1-auc:0.814941
# [44]	validation_0-auc:0.860803	validation_1-auc:0.816484
# [45]	validation_0-auc:0.862683	validation_1-auc:0.818102
# [46]	validation_0-auc:0.864152	validation_1-auc:0.818961
# [47]	validation_0-auc:0.865939	validation_1-auc:0.820829
# [48]	validation_0-auc:0.86717	validation_1-auc:0.821373
# [49]	validation_0-auc:0.868237	validation_1-auc:0.82188
# [50]	validation_0-auc:0.869383	validation_1-auc:0.822812
# [51]	validation_0-auc:0.870836	validation_1-auc:0.824212
# [52]	validation_0-auc:0.872587	validation_1-auc:0.826076
# [53]	validation_0-auc:0.873733	validation_1-auc:0.82706
# [54]	validation_0-auc:0.875077	validation_1-auc:0.828054
# [55]	validation_0-auc:0.875591	validation_1-auc:0.82781
# [56]	validation_0-auc:0.876786	validation_1-auc:0.828897
# [57]	validation_0-auc:0.877716	validation_1-auc:0.829301
# [58]	validation_0-auc:0.878325	validation_1-auc:0.829302
# [59]	validation_0-auc:0.87959	validation_1-auc:0.82976
# [60]	validation_0-auc:0.881024	validation_1-auc:0.830951
# [61]	validation_0-auc:0.88204	validation_1-auc:0.831487
# [62]	validation_0-auc:0.882951	validation_1-auc:0.832113
# [63]	validation_0-auc:0.883739	validation_1-auc:0.83287
# [64]	validation_0-auc:0.884909	validation_1-auc:0.833759
# [65]	validation_0-auc:0.885809	validation_1-auc:0.834269
# [66]	validation_0-auc:0.886585	validation_1-auc:0.834784
# [67]	validation_0-auc:0.887328	validation_1-auc:0.835707
# [68]	validation_0-auc:0.888129	validation_1-auc:0.836589
# [69]	validation_0-auc:0.889101	validation_1-auc:0.837338
# [70]	validation_0-auc:0.889727	validation_1-auc:0.837616
# [71]	validation_0-auc:0.890233	validation_1-auc:0.83796
# [72]	validation_0-auc:0.890851	validation_1-auc:0.838692
# [73]	validation_0-auc:0.891585	validation_1-auc:0.838943
# [74]	validation_0-auc:0.892301	validation_1-auc:0.839651
# [75]	validation_0-auc:0.893165	validation_1-auc:0.840765
# [76]	validation_0-auc:0.893682	validation_1-auc:0.841158
# [77]	validation_0-auc:0.894411	validation_1-auc:0.841798
# [78]	validation_0-auc:0.895187	validation_1-auc:0.842414
# [79]	validation_0-auc:0.895831	validation_1-auc:0.842555
# [80]	validation_0-auc:0.896725	validation_1-auc:0.843135
# [81]	validation_0-auc:0.897659	validation_1-auc:0.84364
# [82]	validation_0-auc:0.898468	validation_1-auc:0.844587
# [83]	validation_0-auc:0.898832	validation_1-auc:0.845133
# [84]	validation_0-auc:0.899682	validation_1-auc:0.845509
# [85]	validation_0-auc:0.900342	validation_1-auc:0.846281
# [86]	validation_0-auc:0.901042	validation_1-auc:0.846452
# [87]	validation_0-auc:0.901408	validation_1-auc:0.846763
# [88]	validation_0-auc:0.901838	validation_1-auc:0.846809
# [89]	validation_0-auc:0.902541	validation_1-auc:0.846965
# [90]	validation_0-auc:0.903094	validation_1-auc:0.847407
# [91]	validation_0-auc:0.903895	validation_1-auc:0.848109
# [92]	validation_0-auc:0.904368	validation_1-auc:0.848135
# [93]	validation_0-auc:0.904971	validation_1-auc:0.848599
# [94]	validation_0-auc:0.905521	validation_1-auc:0.848899
# [95]	validation_0-auc:0.906156	validation_1-auc:0.849268
# [96]	validation_0-auc:0.906675	validation_1-auc:0.849587
# [97]	validation_0-auc:0.90723	validation_1-auc:0.850095
# [98]	validation_0-auc:0.907946	validation_1-auc:0.850639
# [99]	validation_0-auc:0.908625	validation_1-auc:0.85081
# accuracy_score 0.9057547122643868
#
# 3 of kfold 10
# [0]	validation_0-auc:0.630207	validation_1-auc:0.631084
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.665281	validation_1-auc:0.651328
# [2]	validation_0-auc:0.691769	validation_1-auc:0.670832
# [3]	validation_0-auc:0.698022	validation_1-auc:0.671524
# [4]	validation_0-auc:0.703101	validation_1-auc:0.675418
# [5]	validation_0-auc:0.714538	validation_1-auc:0.686118
# [6]	validation_0-auc:0.722045	validation_1-auc:0.694852
# [7]	validation_0-auc:0.730964	validation_1-auc:0.701996
# [8]	validation_0-auc:0.735136	validation_1-auc:0.705573
# [9]	validation_0-auc:0.747433	validation_1-auc:0.714845
# [10]	validation_0-auc:0.756283	validation_1-auc:0.723432
# [11]	validation_0-auc:0.763631	validation_1-auc:0.727187
# [12]	validation_0-auc:0.767918	validation_1-auc:0.731609
# [13]	validation_0-auc:0.772382	validation_1-auc:0.7345
# [14]	validation_0-auc:0.777733	validation_1-auc:0.740133
# [15]	validation_0-auc:0.781813	validation_1-auc:0.742201
# [16]	validation_0-auc:0.787104	validation_1-auc:0.745718
# [17]	validation_0-auc:0.793692	validation_1-auc:0.752527
# [18]	validation_0-auc:0.800222	validation_1-auc:0.757572
# [19]	validation_0-auc:0.804564	validation_1-auc:0.761437
# [20]	validation_0-auc:0.806665	validation_1-auc:0.763812
# [21]	validation_0-auc:0.811128	validation_1-auc:0.767482
# [22]	validation_0-auc:0.814294	validation_1-auc:0.770739
# [23]	validation_0-auc:0.816251	validation_1-auc:0.771987
# [24]	validation_0-auc:0.819273	validation_1-auc:0.775591
# [25]	validation_0-auc:0.822619	validation_1-auc:0.777572
# [26]	validation_0-auc:0.824116	validation_1-auc:0.778302
# [27]	validation_0-auc:0.826717	validation_1-auc:0.780518
# [28]	validation_0-auc:0.829326	validation_1-auc:0.783286
# [29]	validation_0-auc:0.831913	validation_1-auc:0.785745
# [30]	validation_0-auc:0.834253	validation_1-auc:0.787097
# [31]	validation_0-auc:0.836637	validation_1-auc:0.78907
# [32]	validation_0-auc:0.838562	validation_1-auc:0.790631
# [33]	validation_0-auc:0.840768	validation_1-auc:0.791705
# [34]	validation_0-auc:0.842143	validation_1-auc:0.792836
# [35]	validation_0-auc:0.844521	validation_1-auc:0.794396
# [36]	validation_0-auc:0.84665	validation_1-auc:0.79602
# [37]	validation_0-auc:0.84946	validation_1-auc:0.798017
# [38]	validation_0-auc:0.851642	validation_1-auc:0.800787
# [39]	validation_0-auc:0.852989	validation_1-auc:0.802059
# [40]	validation_0-auc:0.854595	validation_1-auc:0.802655
# [41]	validation_0-auc:0.855673	validation_1-auc:0.803772
# [42]	validation_0-auc:0.85708	validation_1-auc:0.8046
# [43]	validation_0-auc:0.859046	validation_1-auc:0.806465
# [44]	validation_0-auc:0.860877	validation_1-auc:0.807888
# [45]	validation_0-auc:0.862976	validation_1-auc:0.809227
# [46]	validation_0-auc:0.864429	validation_1-auc:0.810931
# [47]	validation_0-auc:0.865945	validation_1-auc:0.813026
# [48]	validation_0-auc:0.867465	validation_1-auc:0.814549
# [49]	validation_0-auc:0.869254	validation_1-auc:0.815506
# [50]	validation_0-auc:0.870056	validation_1-auc:0.816372
# [51]	validation_0-auc:0.871175	validation_1-auc:0.817525
# [52]	validation_0-auc:0.872303	validation_1-auc:0.818613
# [53]	validation_0-auc:0.873258	validation_1-auc:0.819214
# [54]	validation_0-auc:0.874461	validation_1-auc:0.820149
# [55]	validation_0-auc:0.875212	validation_1-auc:0.820364
# [56]	validation_0-auc:0.876574	validation_1-auc:0.820714
# [57]	validation_0-auc:0.877601	validation_1-auc:0.821702
# [58]	validation_0-auc:0.878641	validation_1-auc:0.822587
# [59]	validation_0-auc:0.880024	validation_1-auc:0.824147
# [60]	validation_0-auc:0.881015	validation_1-auc:0.824864
# [61]	validation_0-auc:0.882328	validation_1-auc:0.825957
# [62]	validation_0-auc:0.883428	validation_1-auc:0.826889
# [63]	validation_0-auc:0.884463	validation_1-auc:0.827546
# [64]	validation_0-auc:0.88573	validation_1-auc:0.828639
# [65]	validation_0-auc:0.886909	validation_1-auc:0.830077
# [66]	validation_0-auc:0.887746	validation_1-auc:0.830634
# [67]	validation_0-auc:0.888677	validation_1-auc:0.831456
# [68]	validation_0-auc:0.88949	validation_1-auc:0.831933
# [69]	validation_0-auc:0.890505	validation_1-auc:0.832931
# [70]	validation_0-auc:0.891308	validation_1-auc:0.833147
# [71]	validation_0-auc:0.891826	validation_1-auc:0.833199
# [72]	validation_0-auc:0.892542	validation_1-auc:0.833421
# [73]	validation_0-auc:0.893432	validation_1-auc:0.834107
# [74]	validation_0-auc:0.894198	validation_1-auc:0.834678
# [75]	validation_0-auc:0.894832	validation_1-auc:0.83501
# [76]	validation_0-auc:0.89526	validation_1-auc:0.835419
# [77]	validation_0-auc:0.896028	validation_1-auc:0.835844
# [78]	validation_0-auc:0.896912	validation_1-auc:0.83639
# [79]	validation_0-auc:0.897803	validation_1-auc:0.837187
# [80]	validation_0-auc:0.898847	validation_1-auc:0.838071
# [81]	validation_0-auc:0.89965	validation_1-auc:0.838923
# [82]	validation_0-auc:0.900539	validation_1-auc:0.839487
# [83]	validation_0-auc:0.901203	validation_1-auc:0.839575
# [84]	validation_0-auc:0.901774	validation_1-auc:0.839893
# [85]	validation_0-auc:0.902478	validation_1-auc:0.840202
# [86]	validation_0-auc:0.903253	validation_1-auc:0.840924
# [87]	validation_0-auc:0.903811	validation_1-auc:0.841079
# [88]	validation_0-auc:0.9045	validation_1-auc:0.841532
# [89]	validation_0-auc:0.905344	validation_1-auc:0.84223
# [90]	validation_0-auc:0.90577	validation_1-auc:0.842473
# [91]	validation_0-auc:0.906197	validation_1-auc:0.842962
# [92]	validation_0-auc:0.90695	validation_1-auc:0.843492
# [93]	validation_0-auc:0.907619	validation_1-auc:0.844166
# [94]	validation_0-auc:0.908242	validation_1-auc:0.844413
# [95]	validation_0-auc:0.909138	validation_1-auc:0.845283
# [96]	validation_0-auc:0.909766	validation_1-auc:0.84576
# [97]	validation_0-auc:0.910478	validation_1-auc:0.846279
# [98]	validation_0-auc:0.91105	validation_1-auc:0.846414
# [99]	validation_0-auc:0.911531	validation_1-auc:0.846962
# accuracy_score 0.906
#
# 4 of kfold 10
# [0]	validation_0-auc:0.628429	validation_1-auc:0.620682
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.663328	validation_1-auc:0.649496
# [2]	validation_0-auc:0.684874	validation_1-auc:0.674599
# [3]	validation_0-auc:0.694077	validation_1-auc:0.684228
# [4]	validation_0-auc:0.700283	validation_1-auc:0.688686
# [5]	validation_0-auc:0.709443	validation_1-auc:0.696775
# [6]	validation_0-auc:0.715259	validation_1-auc:0.701338
# [7]	validation_0-auc:0.726279	validation_1-auc:0.708031
# [8]	validation_0-auc:0.732646	validation_1-auc:0.713993
# [9]	validation_0-auc:0.744315	validation_1-auc:0.722227
# [10]	validation_0-auc:0.756667	validation_1-auc:0.731431
# [11]	validation_0-auc:0.761756	validation_1-auc:0.737905
# [12]	validation_0-auc:0.76408	validation_1-auc:0.740028
# [13]	validation_0-auc:0.77074	validation_1-auc:0.74501
# [14]	validation_0-auc:0.777582	validation_1-auc:0.752558
# [15]	validation_0-auc:0.784636	validation_1-auc:0.759242
# [16]	validation_0-auc:0.78974	validation_1-auc:0.761974
# [17]	validation_0-auc:0.792605	validation_1-auc:0.764204
# [18]	validation_0-auc:0.797869	validation_1-auc:0.768418
# [19]	validation_0-auc:0.802058	validation_1-auc:0.771621
# [20]	validation_0-auc:0.805694	validation_1-auc:0.77596
# [21]	validation_0-auc:0.8087	validation_1-auc:0.778889
# [22]	validation_0-auc:0.813088	validation_1-auc:0.782843
# [23]	validation_0-auc:0.816304	validation_1-auc:0.784861
# [24]	validation_0-auc:0.818169	validation_1-auc:0.785469
# [25]	validation_0-auc:0.821725	validation_1-auc:0.788663
# [26]	validation_0-auc:0.82425	validation_1-auc:0.790167
# [27]	validation_0-auc:0.827144	validation_1-auc:0.792898
# [28]	validation_0-auc:0.829582	validation_1-auc:0.793826
# [29]	validation_0-auc:0.832652	validation_1-auc:0.796293
# [30]	validation_0-auc:0.833991	validation_1-auc:0.797486
# [31]	validation_0-auc:0.83534	validation_1-auc:0.799022
# [32]	validation_0-auc:0.837851	validation_1-auc:0.801054
# [33]	validation_0-auc:0.840733	validation_1-auc:0.803499
# [34]	validation_0-auc:0.842367	validation_1-auc:0.804989
# [35]	validation_0-auc:0.84465	validation_1-auc:0.807022
# [36]	validation_0-auc:0.846218	validation_1-auc:0.808104
# [37]	validation_0-auc:0.849181	validation_1-auc:0.809894
# [38]	validation_0-auc:0.851901	validation_1-auc:0.811237
# [39]	validation_0-auc:0.853611	validation_1-auc:0.81233
# [40]	validation_0-auc:0.855508	validation_1-auc:0.813957
# [41]	validation_0-auc:0.856743	validation_1-auc:0.814884
# [42]	validation_0-auc:0.858113	validation_1-auc:0.816165
# [43]	validation_0-auc:0.859557	validation_1-auc:0.817354
# [44]	validation_0-auc:0.860919	validation_1-auc:0.818186
# [45]	validation_0-auc:0.862508	validation_1-auc:0.819633
# [46]	validation_0-auc:0.863905	validation_1-auc:0.820778
# [47]	validation_0-auc:0.86547	validation_1-auc:0.821881
# [48]	validation_0-auc:0.867527	validation_1-auc:0.823312
# [49]	validation_0-auc:0.868861	validation_1-auc:0.824162
# [50]	validation_0-auc:0.869839	validation_1-auc:0.824634
# [51]	validation_0-auc:0.870528	validation_1-auc:0.825359
# [52]	validation_0-auc:0.872063	validation_1-auc:0.826548
# [53]	validation_0-auc:0.873263	validation_1-auc:0.826918
# [54]	validation_0-auc:0.874875	validation_1-auc:0.828257
# [55]	validation_0-auc:0.876299	validation_1-auc:0.829397
# [56]	validation_0-auc:0.877563	validation_1-auc:0.830515
# [57]	validation_0-auc:0.878118	validation_1-auc:0.830681
# [58]	validation_0-auc:0.879278	validation_1-auc:0.831131
# [59]	validation_0-auc:0.880279	validation_1-auc:0.832429
# [60]	validation_0-auc:0.88154	validation_1-auc:0.833237
# [61]	validation_0-auc:0.88279	validation_1-auc:0.834023
# [62]	validation_0-auc:0.883724	validation_1-auc:0.834729
# [63]	validation_0-auc:0.884683	validation_1-auc:0.835103
# [64]	validation_0-auc:0.885794	validation_1-auc:0.835616
# [65]	validation_0-auc:0.886433	validation_1-auc:0.835789
# [66]	validation_0-auc:0.887274	validation_1-auc:0.836387
# [67]	validation_0-auc:0.887971	validation_1-auc:0.836526
# [68]	validation_0-auc:0.888878	validation_1-auc:0.836786
# [69]	validation_0-auc:0.890094	validation_1-auc:0.837395
# [70]	validation_0-auc:0.891106	validation_1-auc:0.838136
# [71]	validation_0-auc:0.891899	validation_1-auc:0.838724
# [72]	validation_0-auc:0.892705	validation_1-auc:0.838887
# [73]	validation_0-auc:0.893643	validation_1-auc:0.840116
# [74]	validation_0-auc:0.894237	validation_1-auc:0.84039
# [75]	validation_0-auc:0.895081	validation_1-auc:0.84062
# [76]	validation_0-auc:0.895804	validation_1-auc:0.841597
# [77]	validation_0-auc:0.896535	validation_1-auc:0.84188
# [78]	validation_0-auc:0.897406	validation_1-auc:0.842579
# [79]	validation_0-auc:0.898092	validation_1-auc:0.842885
# [80]	validation_0-auc:0.898917	validation_1-auc:0.842971
# [81]	validation_0-auc:0.899881	validation_1-auc:0.843401
# [82]	validation_0-auc:0.900408	validation_1-auc:0.843656
# [83]	validation_0-auc:0.901048	validation_1-auc:0.843987
# [84]	validation_0-auc:0.901528	validation_1-auc:0.844545
# [85]	validation_0-auc:0.902374	validation_1-auc:0.845175
# [86]	validation_0-auc:0.902921	validation_1-auc:0.845803
# [87]	validation_0-auc:0.903799	validation_1-auc:0.846524
# [88]	validation_0-auc:0.904677	validation_1-auc:0.847029
# [89]	validation_0-auc:0.905267	validation_1-auc:0.847367
# [90]	validation_0-auc:0.905804	validation_1-auc:0.847371
# [91]	validation_0-auc:0.906448	validation_1-auc:0.847649
# [92]	validation_0-auc:0.90679	validation_1-auc:0.847962
# [93]	validation_0-auc:0.907488	validation_1-auc:0.848431
# [94]	validation_0-auc:0.908039	validation_1-auc:0.848923
# [95]	validation_0-auc:0.908602	validation_1-auc:0.84938
# [96]	validation_0-auc:0.909069	validation_1-auc:0.849871
# [97]	validation_0-auc:0.909762	validation_1-auc:0.85038
# [98]	validation_0-auc:0.910091	validation_1-auc:0.850554
# [99]	validation_0-auc:0.910552	validation_1-auc:0.850648
# accuracy_score 0.90575
#
# 5 of kfold 10
# [0]	validation_0-auc:0.628876	validation_1-auc:0.620502
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.665405	validation_1-auc:0.653388
# [2]	validation_0-auc:0.688413	validation_1-auc:0.675648
# [3]	validation_0-auc:0.690045	validation_1-auc:0.676421
# [4]	validation_0-auc:0.701947	validation_1-auc:0.686663
# [5]	validation_0-auc:0.715439	validation_1-auc:0.695663
# [6]	validation_0-auc:0.722045	validation_1-auc:0.700197
# [7]	validation_0-auc:0.730297	validation_1-auc:0.706881
# [8]	validation_0-auc:0.73526	validation_1-auc:0.71302
# [9]	validation_0-auc:0.744809	validation_1-auc:0.72125
# [10]	validation_0-auc:0.753768	validation_1-auc:0.728382
# [11]	validation_0-auc:0.760367	validation_1-auc:0.733966
# [12]	validation_0-auc:0.767191	validation_1-auc:0.738924
# [13]	validation_0-auc:0.77364	validation_1-auc:0.746383
# [14]	validation_0-auc:0.779094	validation_1-auc:0.749945
# [15]	validation_0-auc:0.784843	validation_1-auc:0.753806
# [16]	validation_0-auc:0.789072	validation_1-auc:0.756941
# [17]	validation_0-auc:0.792873	validation_1-auc:0.760999
# [18]	validation_0-auc:0.795877	validation_1-auc:0.762528
# [19]	validation_0-auc:0.799596	validation_1-auc:0.766263
# [20]	validation_0-auc:0.803	validation_1-auc:0.768481
# [21]	validation_0-auc:0.807588	validation_1-auc:0.771648
# [22]	validation_0-auc:0.811537	validation_1-auc:0.775013
# [23]	validation_0-auc:0.815664	validation_1-auc:0.77886
# [24]	validation_0-auc:0.818902	validation_1-auc:0.78194
# [25]	validation_0-auc:0.821195	validation_1-auc:0.783984
# [26]	validation_0-auc:0.82222	validation_1-auc:0.785552
# [27]	validation_0-auc:0.824826	validation_1-auc:0.7879
# [28]	validation_0-auc:0.826668	validation_1-auc:0.789158
# [29]	validation_0-auc:0.829175	validation_1-auc:0.79187
# [30]	validation_0-auc:0.831978	validation_1-auc:0.79417
# [31]	validation_0-auc:0.834895	validation_1-auc:0.796532
# [32]	validation_0-auc:0.837246	validation_1-auc:0.79846
# [33]	validation_0-auc:0.839847	validation_1-auc:0.799877
# [34]	validation_0-auc:0.842234	validation_1-auc:0.800885
# [35]	validation_0-auc:0.844444	validation_1-auc:0.803168
# [36]	validation_0-auc:0.846529	validation_1-auc:0.804668
# [37]	validation_0-auc:0.848638	validation_1-auc:0.80612
# [38]	validation_0-auc:0.850807	validation_1-auc:0.80782
# [39]	validation_0-auc:0.852154	validation_1-auc:0.809013
# [40]	validation_0-auc:0.854248	validation_1-auc:0.810432
# [41]	validation_0-auc:0.856008	validation_1-auc:0.811884
# [42]	validation_0-auc:0.857673	validation_1-auc:0.813349
# [43]	validation_0-auc:0.859482	validation_1-auc:0.814282
# [44]	validation_0-auc:0.860989	validation_1-auc:0.815473
# [45]	validation_0-auc:0.862642	validation_1-auc:0.817147
# [46]	validation_0-auc:0.863894	validation_1-auc:0.818243
# [47]	validation_0-auc:0.865212	validation_1-auc:0.819351
# [48]	validation_0-auc:0.86666	validation_1-auc:0.82035
# [49]	validation_0-auc:0.867468	validation_1-auc:0.820555
# [50]	validation_0-auc:0.869257	validation_1-auc:0.821166
# [51]	validation_0-auc:0.870348	validation_1-auc:0.822917
# [52]	validation_0-auc:0.872025	validation_1-auc:0.824538
# [53]	validation_0-auc:0.873232	validation_1-auc:0.826067
# [54]	validation_0-auc:0.874322	validation_1-auc:0.826623
# [55]	validation_0-auc:0.875579	validation_1-auc:0.827516
# [56]	validation_0-auc:0.876848	validation_1-auc:0.828802
# [57]	validation_0-auc:0.878177	validation_1-auc:0.829855
# [58]	validation_0-auc:0.879237	validation_1-auc:0.831028
# [59]	validation_0-auc:0.880682	validation_1-auc:0.832343
# [60]	validation_0-auc:0.88122	validation_1-auc:0.832875
# [61]	validation_0-auc:0.882166	validation_1-auc:0.833794
# [62]	validation_0-auc:0.883089	validation_1-auc:0.834784
# [63]	validation_0-auc:0.884077	validation_1-auc:0.835269
# [64]	validation_0-auc:0.885231	validation_1-auc:0.836094
# [65]	validation_0-auc:0.886405	validation_1-auc:0.836447
# [66]	validation_0-auc:0.886906	validation_1-auc:0.83654
# [67]	validation_0-auc:0.8881	validation_1-auc:0.837499
# [68]	validation_0-auc:0.888982	validation_1-auc:0.837966
# [69]	validation_0-auc:0.889679	validation_1-auc:0.838298
# [70]	validation_0-auc:0.890606	validation_1-auc:0.838842
# [71]	validation_0-auc:0.891506	validation_1-auc:0.839661
# [72]	validation_0-auc:0.892132	validation_1-auc:0.839972
# [73]	validation_0-auc:0.893284	validation_1-auc:0.840828
# [74]	validation_0-auc:0.893805	validation_1-auc:0.841387
# [75]	validation_0-auc:0.894636	validation_1-auc:0.842231
# [76]	validation_0-auc:0.895765	validation_1-auc:0.842802
# [77]	validation_0-auc:0.896152	validation_1-auc:0.843338
# [78]	validation_0-auc:0.896835	validation_1-auc:0.843786
# [79]	validation_0-auc:0.897569	validation_1-auc:0.844234
# [80]	validation_0-auc:0.898312	validation_1-auc:0.844624
# [81]	validation_0-auc:0.898848	validation_1-auc:0.845099
# [82]	validation_0-auc:0.899664	validation_1-auc:0.845954
# [83]	validation_0-auc:0.900445	validation_1-auc:0.846231
# [84]	validation_0-auc:0.9008	validation_1-auc:0.846518
# [85]	validation_0-auc:0.90161	validation_1-auc:0.846996
# [86]	validation_0-auc:0.902327	validation_1-auc:0.847601
# [87]	validation_0-auc:0.903022	validation_1-auc:0.847999
# [88]	validation_0-auc:0.903695	validation_1-auc:0.848709
# [89]	validation_0-auc:0.904424	validation_1-auc:0.849128
# [90]	validation_0-auc:0.90453	validation_1-auc:0.849447
# [91]	validation_0-auc:0.905207	validation_1-auc:0.849979
# [92]	validation_0-auc:0.905987	validation_1-auc:0.850949
# [93]	validation_0-auc:0.906841	validation_1-auc:0.851934
# [94]	validation_0-auc:0.907336	validation_1-auc:0.852398
# [95]	validation_0-auc:0.907726	validation_1-auc:0.852968
# [96]	validation_0-auc:0.908494	validation_1-auc:0.853586
# [97]	validation_0-auc:0.908922	validation_1-auc:0.853616
# [98]	validation_0-auc:0.909492	validation_1-auc:0.854086
# [99]	validation_0-auc:0.909936	validation_1-auc:0.854279
# accuracy_score 0.90555
#
# 6 of kfold 10
# [0]	validation_0-auc:0.629833	validation_1-auc:0.627815
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.666188	validation_1-auc:0.656175
# [2]	validation_0-auc:0.677173	validation_1-auc:0.664298
# [3]	validation_0-auc:0.688465	validation_1-auc:0.674273
# [4]	validation_0-auc:0.696471	validation_1-auc:0.678674
# [5]	validation_0-auc:0.704405	validation_1-auc:0.687662
# [6]	validation_0-auc:0.713765	validation_1-auc:0.696467
# [7]	validation_0-auc:0.723649	validation_1-auc:0.703346
# [8]	validation_0-auc:0.730863	validation_1-auc:0.709494
# [9]	validation_0-auc:0.74304	validation_1-auc:0.716994
# [10]	validation_0-auc:0.752772	validation_1-auc:0.724841
# [11]	validation_0-auc:0.758956	validation_1-auc:0.733948
# [12]	validation_0-auc:0.766328	validation_1-auc:0.738827
# [13]	validation_0-auc:0.77212	validation_1-auc:0.745436
# [14]	validation_0-auc:0.778508	validation_1-auc:0.74934
# [15]	validation_0-auc:0.783156	validation_1-auc:0.751035
# [16]	validation_0-auc:0.787799	validation_1-auc:0.755372
# [17]	validation_0-auc:0.792026	validation_1-auc:0.758331
# [18]	validation_0-auc:0.796323	validation_1-auc:0.762151
# [19]	validation_0-auc:0.799434	validation_1-auc:0.765901
# [20]	validation_0-auc:0.802497	validation_1-auc:0.768054
# [21]	validation_0-auc:0.807247	validation_1-auc:0.772718
# [22]	validation_0-auc:0.812206	validation_1-auc:0.777709
# [23]	validation_0-auc:0.816791	validation_1-auc:0.781409
# [24]	validation_0-auc:0.819483	validation_1-auc:0.78319
# [25]	validation_0-auc:0.820522	validation_1-auc:0.783985
# [26]	validation_0-auc:0.823278	validation_1-auc:0.78647
# [27]	validation_0-auc:0.826354	validation_1-auc:0.789571
# [28]	validation_0-auc:0.828686	validation_1-auc:0.791721
# [29]	validation_0-auc:0.830392	validation_1-auc:0.792257
# [30]	validation_0-auc:0.832447	validation_1-auc:0.793798
# [31]	validation_0-auc:0.834508	validation_1-auc:0.795605
# [32]	validation_0-auc:0.835819	validation_1-auc:0.796359
# [33]	validation_0-auc:0.837398	validation_1-auc:0.797916
# [34]	validation_0-auc:0.840275	validation_1-auc:0.800579
# [35]	validation_0-auc:0.843027	validation_1-auc:0.803966
# [36]	validation_0-auc:0.845232	validation_1-auc:0.805977
# [37]	validation_0-auc:0.847013	validation_1-auc:0.807617
# [38]	validation_0-auc:0.849603	validation_1-auc:0.809629
# [39]	validation_0-auc:0.850971	validation_1-auc:0.810485
# [40]	validation_0-auc:0.853738	validation_1-auc:0.812492
# [41]	validation_0-auc:0.855864	validation_1-auc:0.814404
# [42]	validation_0-auc:0.857238	validation_1-auc:0.815178
# [43]	validation_0-auc:0.858263	validation_1-auc:0.816139
# [44]	validation_0-auc:0.859736	validation_1-auc:0.817209
# [45]	validation_0-auc:0.861479	validation_1-auc:0.819619
# [46]	validation_0-auc:0.862705	validation_1-auc:0.820925
# [47]	validation_0-auc:0.86439	validation_1-auc:0.822229
# [48]	validation_0-auc:0.865881	validation_1-auc:0.823316
# [49]	validation_0-auc:0.866823	validation_1-auc:0.824177
# [50]	validation_0-auc:0.868295	validation_1-auc:0.825262
# [51]	validation_0-auc:0.869859	validation_1-auc:0.82638
# [52]	validation_0-auc:0.871747	validation_1-auc:0.827005
# [53]	validation_0-auc:0.872957	validation_1-auc:0.827509
# [54]	validation_0-auc:0.873632	validation_1-auc:0.828348
# [55]	validation_0-auc:0.874394	validation_1-auc:0.828489
# [56]	validation_0-auc:0.875121	validation_1-auc:0.82859
# [57]	validation_0-auc:0.87639	validation_1-auc:0.829664
# [58]	validation_0-auc:0.877454	validation_1-auc:0.830555
# [59]	validation_0-auc:0.878772	validation_1-auc:0.830922
# [60]	validation_0-auc:0.879552	validation_1-auc:0.831304
# [61]	validation_0-auc:0.880485	validation_1-auc:0.831941
# [62]	validation_0-auc:0.881757	validation_1-auc:0.83317
# [63]	validation_0-auc:0.88299	validation_1-auc:0.834162
# [64]	validation_0-auc:0.884237	validation_1-auc:0.835439
# [65]	validation_0-auc:0.885302	validation_1-auc:0.835745
# [66]	validation_0-auc:0.886466	validation_1-auc:0.836095
# [67]	validation_0-auc:0.887566	validation_1-auc:0.836599
# [68]	validation_0-auc:0.888764	validation_1-auc:0.837843
# [69]	validation_0-auc:0.889657	validation_1-auc:0.838925
# [70]	validation_0-auc:0.890866	validation_1-auc:0.839566
# [71]	validation_0-auc:0.891715	validation_1-auc:0.840264
# [72]	validation_0-auc:0.891863	validation_1-auc:0.840422
# [73]	validation_0-auc:0.892473	validation_1-auc:0.840745
# [74]	validation_0-auc:0.893401	validation_1-auc:0.842102
# [75]	validation_0-auc:0.894275	validation_1-auc:0.842939
# [76]	validation_0-auc:0.895496	validation_1-auc:0.843699
# [77]	validation_0-auc:0.896477	validation_1-auc:0.844429
# [78]	validation_0-auc:0.896948	validation_1-auc:0.84454
# [79]	validation_0-auc:0.897478	validation_1-auc:0.844993
# [80]	validation_0-auc:0.897941	validation_1-auc:0.845209
# [81]	validation_0-auc:0.898772	validation_1-auc:0.845893
# [82]	validation_0-auc:0.899492	validation_1-auc:0.846428
# [83]	validation_0-auc:0.899973	validation_1-auc:0.846649
# [84]	validation_0-auc:0.9005	validation_1-auc:0.846633
# [85]	validation_0-auc:0.901136	validation_1-auc:0.846909
# [86]	validation_0-auc:0.901681	validation_1-auc:0.847233
# [87]	validation_0-auc:0.902197	validation_1-auc:0.847616
# [88]	validation_0-auc:0.902689	validation_1-auc:0.847831
# [89]	validation_0-auc:0.903288	validation_1-auc:0.848735
# [90]	validation_0-auc:0.903654	validation_1-auc:0.849192
# [91]	validation_0-auc:0.904457	validation_1-auc:0.849657
# [92]	validation_0-auc:0.905091	validation_1-auc:0.850175
# [93]	validation_0-auc:0.905726	validation_1-auc:0.850403
# [94]	validation_0-auc:0.906407	validation_1-auc:0.850926
# [95]	validation_0-auc:0.907134	validation_1-auc:0.851714
# [96]	validation_0-auc:0.908035	validation_1-auc:0.851952
# [97]	validation_0-auc:0.908531	validation_1-auc:0.852169
# [98]	validation_0-auc:0.909004	validation_1-auc:0.852681
# [99]	validation_0-auc:0.909502	validation_1-auc:0.852951
# accuracy_score 0.90565
#
# 7 of kfold 10
# [0]	validation_0-auc:0.629625	validation_1-auc:0.612681
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.663952	validation_1-auc:0.646422
# [2]	validation_0-auc:0.67936	validation_1-auc:0.659617
# [3]	validation_0-auc:0.685897	validation_1-auc:0.666766
# [4]	validation_0-auc:0.698502	validation_1-auc:0.682323
# [5]	validation_0-auc:0.709524	validation_1-auc:0.696266
# [6]	validation_0-auc:0.715564	validation_1-auc:0.701279
# [7]	validation_0-auc:0.724774	validation_1-auc:0.708855
# [8]	validation_0-auc:0.730884	validation_1-auc:0.714464
# [9]	validation_0-auc:0.744848	validation_1-auc:0.725942
# [10]	validation_0-auc:0.756463	validation_1-auc:0.736001
# [11]	validation_0-auc:0.762687	validation_1-auc:0.740957
# [12]	validation_0-auc:0.766885	validation_1-auc:0.744795
# [13]	validation_0-auc:0.773516	validation_1-auc:0.750928
# [14]	validation_0-auc:0.779433	validation_1-auc:0.755346
# [15]	validation_0-auc:0.784009	validation_1-auc:0.759293
# [16]	validation_0-auc:0.787968	validation_1-auc:0.762339
# [17]	validation_0-auc:0.793493	validation_1-auc:0.765709
# [18]	validation_0-auc:0.796733	validation_1-auc:0.768372
# [19]	validation_0-auc:0.800012	validation_1-auc:0.769333
# [20]	validation_0-auc:0.804369	validation_1-auc:0.772477
# [21]	validation_0-auc:0.809026	validation_1-auc:0.775425
# [22]	validation_0-auc:0.813492	validation_1-auc:0.779542
# [23]	validation_0-auc:0.816478	validation_1-auc:0.783919
# [24]	validation_0-auc:0.820208	validation_1-auc:0.786783
# [25]	validation_0-auc:0.82196	validation_1-auc:0.787558
# [26]	validation_0-auc:0.823315	validation_1-auc:0.788993
# [27]	validation_0-auc:0.826508	validation_1-auc:0.790722
# [28]	validation_0-auc:0.828544	validation_1-auc:0.792722
# [29]	validation_0-auc:0.831005	validation_1-auc:0.793819
# [30]	validation_0-auc:0.833872	validation_1-auc:0.796099
# [31]	validation_0-auc:0.835783	validation_1-auc:0.797944
# [32]	validation_0-auc:0.838152	validation_1-auc:0.799473
# [33]	validation_0-auc:0.839828	validation_1-auc:0.800887
# [34]	validation_0-auc:0.842029	validation_1-auc:0.802475
# [35]	validation_0-auc:0.844074	validation_1-auc:0.803376
# [36]	validation_0-auc:0.84634	validation_1-auc:0.804533
# [37]	validation_0-auc:0.848415	validation_1-auc:0.806116
# [38]	validation_0-auc:0.851032	validation_1-auc:0.807921
# [39]	validation_0-auc:0.853002	validation_1-auc:0.809115
# [40]	validation_0-auc:0.85532	validation_1-auc:0.811501
# [41]	validation_0-auc:0.856844	validation_1-auc:0.812762
# [42]	validation_0-auc:0.858005	validation_1-auc:0.813386
# [43]	validation_0-auc:0.859565	validation_1-auc:0.814824
# [44]	validation_0-auc:0.860309	validation_1-auc:0.815548
# [45]	validation_0-auc:0.862466	validation_1-auc:0.816962
# [46]	validation_0-auc:0.864105	validation_1-auc:0.817888
# [47]	validation_0-auc:0.865153	validation_1-auc:0.819072
# [48]	validation_0-auc:0.866366	validation_1-auc:0.819395
# [49]	validation_0-auc:0.867774	validation_1-auc:0.820232
# [50]	validation_0-auc:0.868936	validation_1-auc:0.821176
# [51]	validation_0-auc:0.870171	validation_1-auc:0.821899
# [52]	validation_0-auc:0.871473	validation_1-auc:0.822885
# [53]	validation_0-auc:0.872437	validation_1-auc:0.823145
# [54]	validation_0-auc:0.873614	validation_1-auc:0.823805
# [55]	validation_0-auc:0.874361	validation_1-auc:0.824579
# [56]	validation_0-auc:0.876071	validation_1-auc:0.825895
# [57]	validation_0-auc:0.877569	validation_1-auc:0.827093
# [58]	validation_0-auc:0.878765	validation_1-auc:0.827379
# [59]	validation_0-auc:0.880034	validation_1-auc:0.828866
# [60]	validation_0-auc:0.881119	validation_1-auc:0.829471
# [61]	validation_0-auc:0.882203	validation_1-auc:0.83072
# [62]	validation_0-auc:0.882985	validation_1-auc:0.831157
# [63]	validation_0-auc:0.883663	validation_1-auc:0.830982
# [64]	validation_0-auc:0.884601	validation_1-auc:0.831816
# [65]	validation_0-auc:0.885118	validation_1-auc:0.832008
# [66]	validation_0-auc:0.886029	validation_1-auc:0.832233
# [67]	validation_0-auc:0.887079	validation_1-auc:0.832884
# [68]	validation_0-auc:0.888259	validation_1-auc:0.833505
# [69]	validation_0-auc:0.889308	validation_1-auc:0.834745
# [70]	validation_0-auc:0.89018	validation_1-auc:0.835856
# [71]	validation_0-auc:0.890788	validation_1-auc:0.836272
# [72]	validation_0-auc:0.891603	validation_1-auc:0.836856
# [73]	validation_0-auc:0.892331	validation_1-auc:0.837141
# [74]	validation_0-auc:0.893095	validation_1-auc:0.837516
# [75]	validation_0-auc:0.893956	validation_1-auc:0.83814
# [76]	validation_0-auc:0.894841	validation_1-auc:0.838873
# [77]	validation_0-auc:0.895463	validation_1-auc:0.8396
# [78]	validation_0-auc:0.89624	validation_1-auc:0.840343
# [79]	validation_0-auc:0.896853	validation_1-auc:0.840895
# [80]	validation_0-auc:0.897823	validation_1-auc:0.841638
# [81]	validation_0-auc:0.89881	validation_1-auc:0.842486
# [82]	validation_0-auc:0.899444	validation_1-auc:0.842856
# [83]	validation_0-auc:0.899827	validation_1-auc:0.843179
# [84]	validation_0-auc:0.900632	validation_1-auc:0.843801
# [85]	validation_0-auc:0.901341	validation_1-auc:0.844645
# [86]	validation_0-auc:0.901858	validation_1-auc:0.844957
# [87]	validation_0-auc:0.902656	validation_1-auc:0.845818
# [88]	validation_0-auc:0.903425	validation_1-auc:0.846498
# [89]	validation_0-auc:0.904192	validation_1-auc:0.846972
# [90]	validation_0-auc:0.904431	validation_1-auc:0.847386
# [91]	validation_0-auc:0.905087	validation_1-auc:0.847576
# [92]	validation_0-auc:0.905671	validation_1-auc:0.848052
# [93]	validation_0-auc:0.906358	validation_1-auc:0.848556
# [94]	validation_0-auc:0.906974	validation_1-auc:0.849066
# [95]	validation_0-auc:0.90781	validation_1-auc:0.849601
# [96]	validation_0-auc:0.908658	validation_1-auc:0.849914
# [97]	validation_0-auc:0.909348	validation_1-auc:0.850558
# [98]	validation_0-auc:0.909656	validation_1-auc:0.850594
# [99]	validation_0-auc:0.910165	validation_1-auc:0.850821
# accuracy_score 0.90495
#
# 8 of kfold 10
# [0]	validation_0-auc:0.63841	validation_1-auc:0.624825
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.65821	validation_1-auc:0.649931
# [2]	validation_0-auc:0.681653	validation_1-auc:0.673972
# [3]	validation_0-auc:0.69205	validation_1-auc:0.681199
# [4]	validation_0-auc:0.699622	validation_1-auc:0.689117
# [5]	validation_0-auc:0.712394	validation_1-auc:0.701165
# [6]	validation_0-auc:0.71955	validation_1-auc:0.708202
# [7]	validation_0-auc:0.731359	validation_1-auc:0.719855
# [8]	validation_0-auc:0.737582	validation_1-auc:0.723857
# [9]	validation_0-auc:0.74588	validation_1-auc:0.730866
# [10]	validation_0-auc:0.756382	validation_1-auc:0.73803
# [11]	validation_0-auc:0.763079	validation_1-auc:0.742426
# [12]	validation_0-auc:0.770596	validation_1-auc:0.747717
# [13]	validation_0-auc:0.776849	validation_1-auc:0.752214
# [14]	validation_0-auc:0.780532	validation_1-auc:0.754369
# [15]	validation_0-auc:0.785019	validation_1-auc:0.759236
# [16]	validation_0-auc:0.790322	validation_1-auc:0.761841
# [17]	validation_0-auc:0.791448	validation_1-auc:0.762972
# [18]	validation_0-auc:0.79669	validation_1-auc:0.765298
# [19]	validation_0-auc:0.800103	validation_1-auc:0.767117
# [20]	validation_0-auc:0.804003	validation_1-auc:0.769231
# [21]	validation_0-auc:0.808665	validation_1-auc:0.773501
# [22]	validation_0-auc:0.812108	validation_1-auc:0.776492
# [23]	validation_0-auc:0.814066	validation_1-auc:0.777737
# [24]	validation_0-auc:0.816758	validation_1-auc:0.779751
# [25]	validation_0-auc:0.819327	validation_1-auc:0.781197
# [26]	validation_0-auc:0.822814	validation_1-auc:0.784687
# [27]	validation_0-auc:0.826018	validation_1-auc:0.788271
# [28]	validation_0-auc:0.827964	validation_1-auc:0.790936
# [29]	validation_0-auc:0.831477	validation_1-auc:0.793331
# [30]	validation_0-auc:0.833454	validation_1-auc:0.794412
# [31]	validation_0-auc:0.836645	validation_1-auc:0.797349
# [32]	validation_0-auc:0.837894	validation_1-auc:0.799184
# [33]	validation_0-auc:0.839356	validation_1-auc:0.799717
# [34]	validation_0-auc:0.842395	validation_1-auc:0.802333
# [35]	validation_0-auc:0.844278	validation_1-auc:0.804054
# [36]	validation_0-auc:0.846355	validation_1-auc:0.805245
# [37]	validation_0-auc:0.849116	validation_1-auc:0.807449
# [38]	validation_0-auc:0.851775	validation_1-auc:0.809837
# [39]	validation_0-auc:0.8537	validation_1-auc:0.811782
# [40]	validation_0-auc:0.854939	validation_1-auc:0.812655
# [41]	validation_0-auc:0.856751	validation_1-auc:0.813439
# [42]	validation_0-auc:0.85771	validation_1-auc:0.814258
# [43]	validation_0-auc:0.858908	validation_1-auc:0.814693
# [44]	validation_0-auc:0.860502	validation_1-auc:0.816124
# [45]	validation_0-auc:0.862427	validation_1-auc:0.817264
# [46]	validation_0-auc:0.863603	validation_1-auc:0.817672
# [47]	validation_0-auc:0.864734	validation_1-auc:0.818829
# [48]	validation_0-auc:0.866223	validation_1-auc:0.819401
# [49]	validation_0-auc:0.867588	validation_1-auc:0.82054
# [50]	validation_0-auc:0.868617	validation_1-auc:0.820599
# [51]	validation_0-auc:0.869743	validation_1-auc:0.820503
# [52]	validation_0-auc:0.870588	validation_1-auc:0.821315
# [53]	validation_0-auc:0.871814	validation_1-auc:0.822567
# [54]	validation_0-auc:0.87364	validation_1-auc:0.823984
# [55]	validation_0-auc:0.874631	validation_1-auc:0.824738
# [56]	validation_0-auc:0.875788	validation_1-auc:0.825686
# [57]	validation_0-auc:0.877077	validation_1-auc:0.827164
# [58]	validation_0-auc:0.878355	validation_1-auc:0.828186
# [59]	validation_0-auc:0.879108	validation_1-auc:0.82921
# [60]	validation_0-auc:0.880282	validation_1-auc:0.829565
# [61]	validation_0-auc:0.881161	validation_1-auc:0.830498
# [62]	validation_0-auc:0.882181	validation_1-auc:0.831194
# [63]	validation_0-auc:0.88345	validation_1-auc:0.831543
# [64]	validation_0-auc:0.88435	validation_1-auc:0.831985
# [65]	validation_0-auc:0.885611	validation_1-auc:0.832558
# [66]	validation_0-auc:0.88669	validation_1-auc:0.833622
# [67]	validation_0-auc:0.887286	validation_1-auc:0.834123
# [68]	validation_0-auc:0.888227	validation_1-auc:0.834827
# [69]	validation_0-auc:0.889182	validation_1-auc:0.835846
# [70]	validation_0-auc:0.890273	validation_1-auc:0.836762
# [71]	validation_0-auc:0.890692	validation_1-auc:0.837379
# [72]	validation_0-auc:0.891379	validation_1-auc:0.837922
# [73]	validation_0-auc:0.891681	validation_1-auc:0.837887
# [74]	validation_0-auc:0.892589	validation_1-auc:0.838433
# [75]	validation_0-auc:0.893474	validation_1-auc:0.839149
# [76]	validation_0-auc:0.894253	validation_1-auc:0.839899
# [77]	validation_0-auc:0.89518	validation_1-auc:0.840332
# [78]	validation_0-auc:0.895898	validation_1-auc:0.840495
# [79]	validation_0-auc:0.896652	validation_1-auc:0.841241
# [80]	validation_0-auc:0.897251	validation_1-auc:0.841608
# [81]	validation_0-auc:0.898089	validation_1-auc:0.842672
# [82]	validation_0-auc:0.898938	validation_1-auc:0.843392
# [83]	validation_0-auc:0.899559	validation_1-auc:0.843475
# [84]	validation_0-auc:0.900126	validation_1-auc:0.843984
# [85]	validation_0-auc:0.900911	validation_1-auc:0.844708
# [86]	validation_0-auc:0.90164	validation_1-auc:0.845425
# [87]	validation_0-auc:0.902504	validation_1-auc:0.845616
# [88]	validation_0-auc:0.903493	validation_1-auc:0.846372
# [89]	validation_0-auc:0.904178	validation_1-auc:0.846798
# [90]	validation_0-auc:0.904694	validation_1-auc:0.847025
# [91]	validation_0-auc:0.905271	validation_1-auc:0.847494
# [92]	validation_0-auc:0.905867	validation_1-auc:0.848097
# [93]	validation_0-auc:0.906559	validation_1-auc:0.848609
# [94]	validation_0-auc:0.907231	validation_1-auc:0.849316
# [95]	validation_0-auc:0.908011	validation_1-auc:0.849788
# [96]	validation_0-auc:0.908711	validation_1-auc:0.849996
# [97]	validation_0-auc:0.909313	validation_1-auc:0.850203
# [98]	validation_0-auc:0.909839	validation_1-auc:0.850547
# [99]	validation_0-auc:0.910279	validation_1-auc:0.851095
# accuracy_score 0.90535
#
# 9 of kfold 10
# [0]	validation_0-auc:0.62731	validation_1-auc:0.632872
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.669001	validation_1-auc:0.674251
# [2]	validation_0-auc:0.683087	validation_1-auc:0.686751
# [3]	validation_0-auc:0.694816	validation_1-auc:0.697141
# [4]	validation_0-auc:0.70561	validation_1-auc:0.705534
# [5]	validation_0-auc:0.714038	validation_1-auc:0.712187
# [6]	validation_0-auc:0.726062	validation_1-auc:0.720797
# [7]	validation_0-auc:0.735854	validation_1-auc:0.7287
# [8]	validation_0-auc:0.739504	validation_1-auc:0.729299
# [9]	validation_0-auc:0.746943	validation_1-auc:0.733489
# [10]	validation_0-auc:0.751773	validation_1-auc:0.740235
# [11]	validation_0-auc:0.757984	validation_1-auc:0.745569
# [12]	validation_0-auc:0.764442	validation_1-auc:0.749686
# [13]	validation_0-auc:0.76893	validation_1-auc:0.7551
# [14]	validation_0-auc:0.776406	validation_1-auc:0.760731
# [15]	validation_0-auc:0.783423	validation_1-auc:0.766414
# [16]	validation_0-auc:0.78926	validation_1-auc:0.7715
# [17]	validation_0-auc:0.794028	validation_1-auc:0.775725
# [18]	validation_0-auc:0.799543	validation_1-auc:0.779109
# [19]	validation_0-auc:0.801674	validation_1-auc:0.780086
# [20]	validation_0-auc:0.80435	validation_1-auc:0.782241
# [21]	validation_0-auc:0.808386	validation_1-auc:0.785987
# [22]	validation_0-auc:0.811998	validation_1-auc:0.788095
# [23]	validation_0-auc:0.815753	validation_1-auc:0.791601
# [24]	validation_0-auc:0.819084	validation_1-auc:0.793527
# [25]	validation_0-auc:0.821269	validation_1-auc:0.79591
# [26]	validation_0-auc:0.823205	validation_1-auc:0.797643
# [27]	validation_0-auc:0.82629	validation_1-auc:0.800202
# [28]	validation_0-auc:0.828995	validation_1-auc:0.802328
# [29]	validation_0-auc:0.831939	validation_1-auc:0.804507
# [30]	validation_0-auc:0.833323	validation_1-auc:0.805805
# [31]	validation_0-auc:0.836169	validation_1-auc:0.807613
# [32]	validation_0-auc:0.838269	validation_1-auc:0.808494
# [33]	validation_0-auc:0.839515	validation_1-auc:0.809264
# [34]	validation_0-auc:0.842017	validation_1-auc:0.810791
# [35]	validation_0-auc:0.844799	validation_1-auc:0.812238
# [36]	validation_0-auc:0.847363	validation_1-auc:0.813275
# [37]	validation_0-auc:0.849531	validation_1-auc:0.814888
# [38]	validation_0-auc:0.851682	validation_1-auc:0.816243
# [39]	validation_0-auc:0.853462	validation_1-auc:0.818136
# [40]	validation_0-auc:0.85532	validation_1-auc:0.819877
# [41]	validation_0-auc:0.856936	validation_1-auc:0.82129
# [42]	validation_0-auc:0.857902	validation_1-auc:0.822204
# [43]	validation_0-auc:0.85929	validation_1-auc:0.823215
# [44]	validation_0-auc:0.861309	validation_1-auc:0.825045
# [45]	validation_0-auc:0.862486	validation_1-auc:0.826253
# [46]	validation_0-auc:0.863378	validation_1-auc:0.826868
# [47]	validation_0-auc:0.864975	validation_1-auc:0.828276
# [48]	validation_0-auc:0.866004	validation_1-auc:0.828964
# [49]	validation_0-auc:0.867344	validation_1-auc:0.830174
# [50]	validation_0-auc:0.868523	validation_1-auc:0.831674
# [51]	validation_0-auc:0.86988	validation_1-auc:0.832116
# [52]	validation_0-auc:0.871414	validation_1-auc:0.83323
# [53]	validation_0-auc:0.872835	validation_1-auc:0.834222
# [54]	validation_0-auc:0.874165	validation_1-auc:0.83578
# [55]	validation_0-auc:0.87568	validation_1-auc:0.836854
# [56]	validation_0-auc:0.876441	validation_1-auc:0.83724
# [57]	validation_0-auc:0.877345	validation_1-auc:0.837837
# [58]	validation_0-auc:0.87837	validation_1-auc:0.838329
# [59]	validation_0-auc:0.879351	validation_1-auc:0.838712
# [60]	validation_0-auc:0.880699	validation_1-auc:0.839964
# [61]	validation_0-auc:0.881654	validation_1-auc:0.840441
# [62]	validation_0-auc:0.882855	validation_1-auc:0.841496
# [63]	validation_0-auc:0.883623	validation_1-auc:0.841873
# [64]	validation_0-auc:0.884354	validation_1-auc:0.842502
# [65]	validation_0-auc:0.885372	validation_1-auc:0.84354
# [66]	validation_0-auc:0.886805	validation_1-auc:0.844504
# [67]	validation_0-auc:0.887098	validation_1-auc:0.844649
# [68]	validation_0-auc:0.887974	validation_1-auc:0.845195
# [69]	validation_0-auc:0.888664	validation_1-auc:0.845703
# [70]	validation_0-auc:0.889531	validation_1-auc:0.846185
# [71]	validation_0-auc:0.890461	validation_1-auc:0.846483
# [72]	validation_0-auc:0.891524	validation_1-auc:0.846943
# [73]	validation_0-auc:0.892285	validation_1-auc:0.847455
# [74]	validation_0-auc:0.893093	validation_1-auc:0.848095
# [75]	validation_0-auc:0.893984	validation_1-auc:0.848739
# [76]	validation_0-auc:0.894675	validation_1-auc:0.849435
# [77]	validation_0-auc:0.895453	validation_1-auc:0.849912
# [78]	validation_0-auc:0.896138	validation_1-auc:0.850313
# [79]	validation_0-auc:0.896759	validation_1-auc:0.851015
# [80]	validation_0-auc:0.897319	validation_1-auc:0.851278
# [81]	validation_0-auc:0.8981	validation_1-auc:0.851516
# [82]	validation_0-auc:0.898742	validation_1-auc:0.851872
# [83]	validation_0-auc:0.899529	validation_1-auc:0.852534
# [84]	validation_0-auc:0.90027	validation_1-auc:0.853309
# [85]	validation_0-auc:0.900906	validation_1-auc:0.854174
# [86]	validation_0-auc:0.901433	validation_1-auc:0.854536
# [87]	validation_0-auc:0.902356	validation_1-auc:0.855159
# [88]	validation_0-auc:0.903017	validation_1-auc:0.855332
# [89]	validation_0-auc:0.903755	validation_1-auc:0.855899
# [90]	validation_0-auc:0.903989	validation_1-auc:0.856235
# [91]	validation_0-auc:0.904775	validation_1-auc:0.856286
# [92]	validation_0-auc:0.905275	validation_1-auc:0.857192
# [93]	validation_0-auc:0.905577	validation_1-auc:0.857558
# [94]	validation_0-auc:0.906186	validation_1-auc:0.857984
# [95]	validation_0-auc:0.906799	validation_1-auc:0.858282
# [96]	validation_0-auc:0.907477	validation_1-auc:0.858751
# [97]	validation_0-auc:0.908042	validation_1-auc:0.859177
# [98]	validation_0-auc:0.90864	validation_1-auc:0.859251
# [99]	validation_0-auc:0.908956	validation_1-auc:0.859442
# accuracy_score 0.9066453322666134
#
# 10 of kfold 10
# [0]	validation_0-auc:0.628048	validation_1-auc:0.617702
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.671549	validation_1-auc:0.66856
# [2]	validation_0-auc:0.692302	validation_1-auc:0.689703
# [3]	validation_0-auc:0.700773	validation_1-auc:0.696021
# [4]	validation_0-auc:0.713216	validation_1-auc:0.706914
# [5]	validation_0-auc:0.713448	validation_1-auc:0.70561
# [6]	validation_0-auc:0.722548	validation_1-auc:0.713162
# [7]	validation_0-auc:0.734718	validation_1-auc:0.721681
# [8]	validation_0-auc:0.743548	validation_1-auc:0.728897
# [9]	validation_0-auc:0.749333	validation_1-auc:0.732709
# [10]	validation_0-auc:0.752556	validation_1-auc:0.735285
# [11]	validation_0-auc:0.758506	validation_1-auc:0.739311
# [12]	validation_0-auc:0.767579	validation_1-auc:0.74768
# [13]	validation_0-auc:0.770751	validation_1-auc:0.750575
# [14]	validation_0-auc:0.778294	validation_1-auc:0.757724
# [15]	validation_0-auc:0.783634	validation_1-auc:0.762456
# [16]	validation_0-auc:0.789825	validation_1-auc:0.767043
# [17]	validation_0-auc:0.793667	validation_1-auc:0.770098
# [18]	validation_0-auc:0.798579	validation_1-auc:0.773412
# [19]	validation_0-auc:0.802774	validation_1-auc:0.776502
# [20]	validation_0-auc:0.80694	validation_1-auc:0.779653
# [21]	validation_0-auc:0.810442	validation_1-auc:0.781664
# [22]	validation_0-auc:0.814913	validation_1-auc:0.785091
# [23]	validation_0-auc:0.817286	validation_1-auc:0.787239
# [24]	validation_0-auc:0.818622	validation_1-auc:0.789313
# [25]	validation_0-auc:0.822013	validation_1-auc:0.791166
# [26]	validation_0-auc:0.823779	validation_1-auc:0.792887
# [27]	validation_0-auc:0.826313	validation_1-auc:0.794172
# [28]	validation_0-auc:0.828465	validation_1-auc:0.796405
# [29]	validation_0-auc:0.830967	validation_1-auc:0.799364
# [30]	validation_0-auc:0.83274	validation_1-auc:0.801708
# [31]	validation_0-auc:0.835142	validation_1-auc:0.80258
# [32]	validation_0-auc:0.837255	validation_1-auc:0.804596
# [33]	validation_0-auc:0.838854	validation_1-auc:0.805776
# [34]	validation_0-auc:0.841423	validation_1-auc:0.807471
# [35]	validation_0-auc:0.843532	validation_1-auc:0.809453
# [36]	validation_0-auc:0.84588	validation_1-auc:0.8118
# [37]	validation_0-auc:0.848152	validation_1-auc:0.81395
# [38]	validation_0-auc:0.850587	validation_1-auc:0.815212
# [39]	validation_0-auc:0.852162	validation_1-auc:0.81696
# [40]	validation_0-auc:0.854201	validation_1-auc:0.819138
# [41]	validation_0-auc:0.85611	validation_1-auc:0.821089
# [42]	validation_0-auc:0.857636	validation_1-auc:0.822082
# [43]	validation_0-auc:0.859448	validation_1-auc:0.823067
# [44]	validation_0-auc:0.861068	validation_1-auc:0.823691
# [45]	validation_0-auc:0.862795	validation_1-auc:0.82505
# [46]	validation_0-auc:0.864099	validation_1-auc:0.82591
# [47]	validation_0-auc:0.865801	validation_1-auc:0.827113
# [48]	validation_0-auc:0.867186	validation_1-auc:0.828049
# [49]	validation_0-auc:0.868592	validation_1-auc:0.828988
# [50]	validation_0-auc:0.869061	validation_1-auc:0.829441
# [51]	validation_0-auc:0.87048	validation_1-auc:0.830141
# [52]	validation_0-auc:0.871714	validation_1-auc:0.830947
# [53]	validation_0-auc:0.872906	validation_1-auc:0.831791
# [54]	validation_0-auc:0.873757	validation_1-auc:0.831984
# [55]	validation_0-auc:0.874457	validation_1-auc:0.832538
# [56]	validation_0-auc:0.875667	validation_1-auc:0.833013
# [57]	validation_0-auc:0.876941	validation_1-auc:0.833259
# [58]	validation_0-auc:0.878601	validation_1-auc:0.83415
# [59]	validation_0-auc:0.879682	validation_1-auc:0.835093
# [60]	validation_0-auc:0.880906	validation_1-auc:0.83619
# [61]	validation_0-auc:0.882142	validation_1-auc:0.837189
# [62]	validation_0-auc:0.88292	validation_1-auc:0.837505
# [63]	validation_0-auc:0.883546	validation_1-auc:0.83832
# [64]	validation_0-auc:0.884712	validation_1-auc:0.839282
# [65]	validation_0-auc:0.885785	validation_1-auc:0.840046
# [66]	validation_0-auc:0.887163	validation_1-auc:0.840993
# [67]	validation_0-auc:0.887802	validation_1-auc:0.841958
# [68]	validation_0-auc:0.88847	validation_1-auc:0.842428
# [69]	validation_0-auc:0.889535	validation_1-auc:0.843076
# [70]	validation_0-auc:0.890217	validation_1-auc:0.844264
# [71]	validation_0-auc:0.890728	validation_1-auc:0.844845
# [72]	validation_0-auc:0.891887	validation_1-auc:0.845264
# [73]	validation_0-auc:0.892401	validation_1-auc:0.845146
# [74]	validation_0-auc:0.893247	validation_1-auc:0.845553
# [75]	validation_0-auc:0.894053	validation_1-auc:0.845875
# [76]	validation_0-auc:0.8951	validation_1-auc:0.846563
# [77]	validation_0-auc:0.896074	validation_1-auc:0.847233
# [78]	validation_0-auc:0.896716	validation_1-auc:0.848088
# [79]	validation_0-auc:0.897432	validation_1-auc:0.848734
# [80]	validation_0-auc:0.898051	validation_1-auc:0.849442
# [81]	validation_0-auc:0.898508	validation_1-auc:0.849429
# [82]	validation_0-auc:0.899183	validation_1-auc:0.850056
# [83]	validation_0-auc:0.900044	validation_1-auc:0.850383
# [84]	validation_0-auc:0.900573	validation_1-auc:0.850933
# [85]	validation_0-auc:0.901314	validation_1-auc:0.851256
# [86]	validation_0-auc:0.902043	validation_1-auc:0.852072
# [87]	validation_0-auc:0.902818	validation_1-auc:0.852531
# [88]	validation_0-auc:0.90343	validation_1-auc:0.852984
# [89]	validation_0-auc:0.904128	validation_1-auc:0.853574
# [90]	validation_0-auc:0.904721	validation_1-auc:0.854174
# [91]	validation_0-auc:0.905045	validation_1-auc:0.854412
# [92]	validation_0-auc:0.90569	validation_1-auc:0.855392
# [93]	validation_0-auc:0.906131	validation_1-auc:0.855847
# [94]	validation_0-auc:0.906541	validation_1-auc:0.855692
# [95]	validation_0-auc:0.90702	validation_1-auc:0.856063
# [96]	validation_0-auc:0.907538	validation_1-auc:0.85627
# [97]	validation_0-auc:0.908264	validation_1-auc:0.85673
# [98]	validation_0-auc:0.908738	validation_1-auc:0.857198
# [99]	validation_0-auc:0.90911	validation_1-auc:0.857503
# accuracy_score 0.9062953147657383

# %% [markdown]
# Feature Importance Graph

# %%
plt.figure( figsize=( 18, 14 ))
plt.bar(range(len(xgbModel.feature_importances_)), xgbModel.feature_importances_)
plt.show()

# %% [markdown]
# **Submission**

# %%
pred_prob_val = pd.DataFrame()
pred_prob_val['target'] = xgbModel.predict_proba( data=X_test )[:,1]
sub_df = pd.DataFrame({"ID_code":test_df["ID_code"].values})
sub_df["target"] = xgbModel.predict( X_test )
sub_df.loc[pred_prob_val['target'] > 0.36, 'target'] = 1
sub_df.to_csv("submission.csv", index=False)

# %% [markdown]
# **References**
# * https://www.kaggle.com/gpreda/santander-eda-and-prediction
# * https://www.kaggle.com/ogrellier/xgb-classifier-upsampling-lb-0-283
