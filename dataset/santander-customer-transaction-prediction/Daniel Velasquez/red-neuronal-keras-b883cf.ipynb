# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['train.csv', 'test.csv', 'sample_submission.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrenamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrenamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.3364 - binary_accuracy: 0.8995 - val_loss: 0.3191 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.3115 - binary_accuracy: 0.8995 - val_loss: 0.3029 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2951 - binary_accuracy: 0.8995 - val_loss: 0.2856 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2779 - binary_accuracy: 0.8996 - val_loss: 0.2679 - val_binary_accuracy: 0.8998
# Epoch 5/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2622 - binary_accuracy: 0.9012 - val_loss: 0.2532 - val_binary_accuracy: 0.9034
# Epoch 6/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2508 - binary_accuracy: 0.9057 - val_loss: 0.2438 - val_binary_accuracy: 0.9087
# Epoch 7/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2443 - binary_accuracy: 0.9093 - val_loss: 0.2388 - val_binary_accuracy: 0.9110
# Epoch 8/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2411 - binary_accuracy: 0.9109 - val_loss: 0.2364 - val_binary_accuracy: 0.9124
# Epoch 9/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2395 - binary_accuracy: 0.9114 - val_loss: 0.2352 - val_binary_accuracy: 0.9127
# Epoch 10/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2385 - binary_accuracy: 0.9117 - val_loss: 0.2346 - val_binary_accuracy: 0.9138
# Epoch 11/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2378 - binary_accuracy: 0.9120 - val_loss: 0.2342 - val_binary_accuracy: 0.9138
# Epoch 12/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2373 - binary_accuracy: 0.9122 - val_loss: 0.2340 - val_binary_accuracy: 0.9137
# Epoch 13/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2367 - binary_accuracy: 0.9123 - val_loss: 0.2338 - val_binary_accuracy: 0.9138
# Epoch 14/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2362 - binary_accuracy: 0.9124 - val_loss: 0.2337 - val_binary_accuracy: 0.9141
# Epoch 15/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2358 - binary_accuracy: 0.9128 - val_loss: 0.2336 - val_binary_accuracy: 0.9140

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8559399420279604
# Vali AUC:  0.8570798868359704

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [10,1000,2000]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2010
# _________________________________________________________________
# dense_9 (Dense)              (None, 1000)              11000
# _________________________________________________________________
# dense_10 (Dense)             (None, 2000)              2002000
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 2001
# =================================================================
# Total params: 2,017,011
# Trainable params: 2,017,011
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8531979242348495
# Vali AUC:  0.8564030735704469

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [10, 1500, 2000]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.4177 - binary_accuracy: 0.8995 - val_loss: 0.3280 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3198 - binary_accuracy: 0.8995 - val_loss: 0.3138 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3089 - binary_accuracy: 0.8995 - val_loss: 0.3033 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2983 - binary_accuracy: 0.8995 - val_loss: 0.2920 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2872 - binary_accuracy: 0.8995 - val_loss: 0.2807 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2766 - binary_accuracy: 0.8995 - val_loss: 0.2704 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2677 - binary_accuracy: 0.8995 - val_loss: 0.2622 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2608 - binary_accuracy: 0.8995 - val_loss: 0.2562 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2559 - binary_accuracy: 0.8995 - val_loss: 0.2521 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2526 - binary_accuracy: 0.8995 - val_loss: 0.2494 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2503 - binary_accuracy: 0.8995 - val_loss: 0.2477 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2486 - binary_accuracy: 0.8995 - val_loss: 0.2464 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2473 - binary_accuracy: 0.8995 - val_loss: 0.2455 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2463 - binary_accuracy: 0.8995 - val_loss: 0.2447 - val_binary_accuracy: 0.8995
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2453 - binary_accuracy: 0.8995 - val_loss: 0.2441 - val_binary_accuracy: 0.8995
# Train AUC:  0.8543285464948838
# Vali AUC:  0.8548909289019051

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [10,1500,2000]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                2010
# _________________________________________________________________
# dense_17 (Dense)             (None, 1500)              16500
# _________________________________________________________________
# dense_18 (Dense)             (None, 2000)              3002000
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 2001
# =================================================================
# Total params: 3,022,511
# Trainable params: 3,022,511
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.4238 - binary_accuracy: 0.8962 - val_loss: 0.3279 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3193 - binary_accuracy: 0.8995 - val_loss: 0.3134 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3085 - binary_accuracy: 0.8995 - val_loss: 0.3030 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2979 - binary_accuracy: 0.8995 - val_loss: 0.2918 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2869 - binary_accuracy: 0.8995 - val_loss: 0.2804 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2763 - binary_accuracy: 0.8995 - val_loss: 0.2703 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2674 - binary_accuracy: 0.8995 - val_loss: 0.2621 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2606 - binary_accuracy: 0.8995 - val_loss: 0.2561 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2557 - binary_accuracy: 0.8995 - val_loss: 0.2519 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2524 - binary_accuracy: 0.8995 - val_loss: 0.2492 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2501 - binary_accuracy: 0.8995 - val_loss: 0.2473 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2485 - binary_accuracy: 0.8995 - val_loss: 0.2460 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2472 - binary_accuracy: 0.8995 - val_loss: 0.2451 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2462 - binary_accuracy: 0.8995 - val_loss: 0.2443 - val_binary_accuracy: 0.8995
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2453 - binary_accuracy: 0.8995 - val_loss: 0.2437 - val_binary_accuracy: 0.8995
# Train AUC:  0.8542825263682258
# Vali AUC:  0.8554660411118392

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.2)(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.5)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0.7)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0.7)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 1029
# =================================================================
# Total params: 2,323,281
# Trainable params: 2,323,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8531533776468503
# Vali AUC:  0.8610965738290206

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 1029
# =================================================================
# Total params: 2,323,281
# Trainable params: 2,323,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 1.9542 - binary_accuracy: 0.8952 - val_loss: 1.8872 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 1.7284 - binary_accuracy: 0.8995 - val_loss: 1.6916 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 1.5394 - binary_accuracy: 0.8995 - val_loss: 1.5161 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 1.3759 - binary_accuracy: 0.8995 - val_loss: 1.3621 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 1.2336 - binary_accuracy: 0.8995 - val_loss: 1.2262 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 1.1099 - binary_accuracy: 0.8995 - val_loss: 1.1056 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 1.0012 - binary_accuracy: 0.8995 - val_loss: 0.9979 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.9070 - binary_accuracy: 0.8995 - val_loss: 0.9017 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.8230 - binary_accuracy: 0.8995 - val_loss: 0.8144 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.7497 - binary_accuracy: 0.8995 - val_loss: 0.7398 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.6862 - binary_accuracy: 0.8995 - val_loss: 0.6730 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.6290 - binary_accuracy: 0.8995 - val_loss: 0.6127 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.5808 - binary_accuracy: 0.8995 - val_loss: 0.5617 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.5370 - binary_accuracy: 0.8995 - val_loss: 0.5173 - val_binary_accuracy: 0.8999
# Epoch 15/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.5003 - binary_accuracy: 0.8995 - val_loss: 0.4801 - val_binary_accuracy: 0.9012
# Train AUC:  0.8529041954476602
# Vali AUC:  0.8609874750759818

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
