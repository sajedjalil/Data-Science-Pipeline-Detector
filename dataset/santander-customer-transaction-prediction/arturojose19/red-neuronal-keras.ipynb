# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_101 (Dense)            (None, 1028)              206628
# _________________________________________________________________
# dense_102 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dense_103 (Dense)            (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 0.3348 - binary_accuracy: 0.8981 - val_loss: 0.3161 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.3074 - binary_accuracy: 0.8995 - val_loss: 0.2987 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.2896 - binary_accuracy: 0.8995 - val_loss: 0.2807 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.2718 - binary_accuracy: 0.8999 - val_loss: 0.2639 - val_binary_accuracy: 0.9007
# Epoch 5/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.2568 - binary_accuracy: 0.9028 - val_loss: 0.2516 - val_binary_accuracy: 0.9046
# Epoch 6/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2470 - binary_accuracy: 0.9076 - val_loss: 0.2448 - val_binary_accuracy: 0.9090
# Epoch 7/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2420 - binary_accuracy: 0.9106 - val_loss: 0.2416 - val_binary_accuracy: 0.9106
# Epoch 8/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.2395 - binary_accuracy: 0.9119 - val_loss: 0.2402 - val_binary_accuracy: 0.9115
# Epoch 9/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2382 - binary_accuracy: 0.9124 - val_loss: 0.2396 - val_binary_accuracy: 0.9118
# Epoch 10/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.2374 - binary_accuracy: 0.9127 - val_loss: 0.2393 - val_binary_accuracy: 0.9121
# Epoch 11/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2368 - binary_accuracy: 0.9130 - val_loss: 0.2391 - val_binary_accuracy: 0.9122
# Epoch 12/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2363 - binary_accuracy: 0.9130 - val_loss: 0.2390 - val_binary_accuracy: 0.9122
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2358 - binary_accuracy: 0.9133 - val_loss: 0.2389 - val_binary_accuracy: 0.9122
# Epoch 14/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2353 - binary_accuracy: 0.9134 - val_loss: 0.2388 - val_binary_accuracy: 0.9122
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2348 - binary_accuracy: 0.9135 - val_loss: 0.2387 - val_binary_accuracy: 0.9122

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8568905468964757
# Vali AUC:  0.8512296079358627

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [1045,2408,3120,4548]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 1045)              210045
# _________________________________________________________________
# dense_105 (Dense)            (None, 2408)              2518768
# _________________________________________________________________
# dense_106 (Dense)            (None, 3120)              7516080
# _________________________________________________________________
# dense_107 (Dense)            (None, 4548)              14194308
# _________________________________________________________________
# dense_108 (Dense)            (None, 1)                 4549
# =================================================================
# Total params: 24,443,750
# Trainable params: 24,443,750
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8830084272042962
# Vali AUC:  0.8467766088954892

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [2255, 3155, 4005, 4028]
model2 = func_model(arquitectura2)
print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_109 (Dense)            (None, 2255)              453255
# _________________________________________________________________
# dense_110 (Dense)            (None, 3155)              7117680
# _________________________________________________________________
# dense_111 (Dense)            (None, 4005)              12639780
# _________________________________________________________________
# dense_112 (Dense)            (None, 4028)              16136168
# _________________________________________________________________
# dense_113 (Dense)            (None, 1)                 4029
# =================================================================
# Total params: 36,350,912
# Trainable params: 36,350,912
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2884 - binary_accuracy: 0.8998 - val_loss: 0.2548 - val_binary_accuracy: 0.9053
# Epoch 2/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2467 - binary_accuracy: 0.9097 - val_loss: 0.2451 - val_binary_accuracy: 0.9103
# Epoch 3/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2403 - binary_accuracy: 0.9116 - val_loss: 0.2442 - val_binary_accuracy: 0.9102
# Epoch 4/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2362 - binary_accuracy: 0.9130 - val_loss: 0.2437 - val_binary_accuracy: 0.9108
# Epoch 5/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2330 - binary_accuracy: 0.9139 - val_loss: 0.2449 - val_binary_accuracy: 0.9109
# Epoch 6/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2298 - binary_accuracy: 0.9151 - val_loss: 0.2431 - val_binary_accuracy: 0.9107
# Epoch 7/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2266 - binary_accuracy: 0.9157 - val_loss: 0.2429 - val_binary_accuracy: 0.9114
# Epoch 8/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2233 - binary_accuracy: 0.9167 - val_loss: 0.2429 - val_binary_accuracy: 0.9112
# Epoch 9/15
# 180000/180000 [==============================] - 8s 47us/step - loss: 0.2202 - binary_accuracy: 0.9183 - val_loss: 0.2435 - val_binary_accuracy: 0.9105
# Epoch 10/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2171 - binary_accuracy: 0.9194 - val_loss: 0.2464 - val_binary_accuracy: 0.9075
# Epoch 11/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2139 - binary_accuracy: 0.9204 - val_loss: 0.2440 - val_binary_accuracy: 0.9096
# Epoch 12/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2105 - binary_accuracy: 0.9216 - val_loss: 0.2447 - val_binary_accuracy: 0.9109
# Epoch 13/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2070 - binary_accuracy: 0.9228 - val_loss: 0.2446 - val_binary_accuracy: 0.9108
# Epoch 14/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.2035 - binary_accuracy: 0.9244 - val_loss: 0.2449 - val_binary_accuracy: 0.9091
# Epoch 15/15
# 180000/180000 [==============================] - 8s 46us/step - loss: 0.1992 - binary_accuracy: 0.9255 - val_loss: 0.2465 - val_binary_accuracy: 0.9095
# Train AUC:  0.9126874007574872
# Vali AUC:  0.8453717792361152

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = arquitectura1
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_114 (Dense)            (None, 1045)              210045
# _________________________________________________________________
# dense_115 (Dense)            (None, 2408)              2518768
# _________________________________________________________________
# dense_116 (Dense)            (None, 3120)              7516080
# _________________________________________________________________
# dense_117 (Dense)            (None, 4548)              14194308
# _________________________________________________________________
# dense_118 (Dense)            (None, 1)                 4549
# =================================================================
# Total params: 24,443,750
# Trainable params: 24,443,750
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 9s 49us/step - loss: 0.3062 - binary_accuracy: 0.8993 - val_loss: 0.2753 - val_binary_accuracy: 0.9000
# Epoch 2/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2573 - binary_accuracy: 0.9054 - val_loss: 0.2472 - val_binary_accuracy: 0.9081
# Epoch 3/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2430 - binary_accuracy: 0.9109 - val_loss: 0.2444 - val_binary_accuracy: 0.9103
# Epoch 4/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2391 - binary_accuracy: 0.9121 - val_loss: 0.2419 - val_binary_accuracy: 0.9109
# Epoch 5/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2367 - binary_accuracy: 0.9126 - val_loss: 0.2417 - val_binary_accuracy: 0.9108
# Epoch 6/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2347 - binary_accuracy: 0.9132 - val_loss: 0.2411 - val_binary_accuracy: 0.9107
# Epoch 7/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2327 - binary_accuracy: 0.9140 - val_loss: 0.2417 - val_binary_accuracy: 0.9111
# Epoch 8/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2308 - binary_accuracy: 0.9144 - val_loss: 0.2405 - val_binary_accuracy: 0.9122
# Epoch 9/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2290 - binary_accuracy: 0.9151 - val_loss: 0.2404 - val_binary_accuracy: 0.9112
# Epoch 10/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2271 - binary_accuracy: 0.9155 - val_loss: 0.2401 - val_binary_accuracy: 0.9116
# Epoch 11/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2253 - binary_accuracy: 0.9162 - val_loss: 0.2398 - val_binary_accuracy: 0.9120
# Epoch 12/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2235 - binary_accuracy: 0.9169 - val_loss: 0.2408 - val_binary_accuracy: 0.9106
# Epoch 13/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2216 - binary_accuracy: 0.9176 - val_loss: 0.2404 - val_binary_accuracy: 0.9116
# Epoch 14/15
# 180000/180000 [==============================] - 6s 35us/step - loss: 0.2196 - binary_accuracy: 0.9179 - val_loss: 0.2400 - val_binary_accuracy: 0.9113
# Epoch 15/15
# 180000/180000 [==============================] - 6s 36us/step - loss: 0.2176 - binary_accuracy: 0.9188 - val_loss: 0.2399 - val_binary_accuracy: 0.9121
# Train AUC:  0.8839686183543192
# Vali AUC:  0.85038573115523

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0)(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model3 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 1045)              210045
# _________________________________________________________________
# dense_105 (Dense)            (None, 2408)              2518768
# _________________________________________________________________
# dense_106 (Dense)            (None, 3120)              7516080
# _________________________________________________________________
# dense_107 (Dense)            (None, 4548)              14194308
# _________________________________________________________________
# dense_108 (Dense)            (None, 1)                 4549
# =================================================================
# Total params: 24,443,750
# Trainable params: 24,443,750
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
