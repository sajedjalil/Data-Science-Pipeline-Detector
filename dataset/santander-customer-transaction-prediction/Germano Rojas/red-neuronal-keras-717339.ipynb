# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 0.3369 - binary_accuracy: 0.8983 - val_loss: 0.3190 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3096 - binary_accuracy: 0.8995 - val_loss: 0.3026 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2916 - binary_accuracy: 0.8995 - val_loss: 0.2851 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2730 - binary_accuracy: 0.8997 - val_loss: 0.2684 - val_binary_accuracy: 0.9004
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2570 - binary_accuracy: 0.9025 - val_loss: 0.2564 - val_binary_accuracy: 0.9049
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2466 - binary_accuracy: 0.9073 - val_loss: 0.2501 - val_binary_accuracy: 0.9091
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2412 - binary_accuracy: 0.9106 - val_loss: 0.2474 - val_binary_accuracy: 0.9096
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2386 - binary_accuracy: 0.9119 - val_loss: 0.2465 - val_binary_accuracy: 0.9100
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2373 - binary_accuracy: 0.9123 - val_loss: 0.2461 - val_binary_accuracy: 0.9107
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2365 - binary_accuracy: 0.9125 - val_loss: 0.2460 - val_binary_accuracy: 0.9107
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2359 - binary_accuracy: 0.9128 - val_loss: 0.2459 - val_binary_accuracy: 0.9107
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2353 - binary_accuracy: 0.9129 - val_loss: 0.2460 - val_binary_accuracy: 0.9106
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2348 - binary_accuracy: 0.9133 - val_loss: 0.2459 - val_binary_accuracy: 0.9107
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2344 - binary_accuracy: 0.9133 - val_loss: 0.2457 - val_binary_accuracy: 0.9113
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2339 - binary_accuracy: 0.9132 - val_loss: 0.2457 - val_binary_accuracy: 0.9110

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8587562020287791
# Vali AUC:  0.837236012820832

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [4000,4000,4000]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.9041504590617027
# Vali AUC:  0.83149303510242

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [5000,5000]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [4000,4000,4000]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4000)              804000
# _________________________________________________________________
# dense_9 (Dense)              (None, 4000)              16004000
# _________________________________________________________________
# dense_10 (Dense)             (None, 4000)              16004000
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 4001
# =================================================================
# Total params: 32,816,001
# Trainable params: 32,816,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 8s 47us/step - loss: 0.2807 - binary_accuracy: 0.9016 - val_loss: 0.2584 - val_binary_accuracy: 0.9063
# Epoch 2/15
# 180000/180000 [==============================] - 7s 42us/step - loss: 0.2448 - binary_accuracy: 0.9102 - val_loss: 0.2508 - val_binary_accuracy: 0.9076
# Epoch 3/15
# 180000/180000 [==============================] - 7s 41us/step - loss: 0.2396 - binary_accuracy: 0.9118 - val_loss: 0.2516 - val_binary_accuracy: 0.9061
# Epoch 4/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2363 - binary_accuracy: 0.9128 - val_loss: 0.2513 - val_binary_accuracy: 0.9086
# Epoch 5/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2331 - binary_accuracy: 0.9136 - val_loss: 0.2496 - val_binary_accuracy: 0.9081
# Epoch 6/15
# 180000/180000 [==============================] - 7s 42us/step - loss: 0.2304 - binary_accuracy: 0.9148 - val_loss: 0.2496 - val_binary_accuracy: 0.9084
# Epoch 7/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2277 - binary_accuracy: 0.9153 - val_loss: 0.2493 - val_binary_accuracy: 0.9076
# Epoch 8/15
# 180000/180000 [==============================] - 7s 42us/step - loss: 0.2250 - binary_accuracy: 0.9162 - val_loss: 0.2542 - val_binary_accuracy: 0.9051
# Epoch 9/15
# 180000/180000 [==============================] - 7s 42us/step - loss: 0.2224 - binary_accuracy: 0.9172 - val_loss: 0.2515 - val_binary_accuracy: 0.9080
# Epoch 10/15
# 180000/180000 [==============================] - 7s 41us/step - loss: 0.2195 - binary_accuracy: 0.9181 - val_loss: 0.2508 - val_binary_accuracy: 0.9063
# Epoch 11/15
# 180000/180000 [==============================] - 7s 41us/step - loss: 0.2170 - binary_accuracy: 0.9193 - val_loss: 0.2494 - val_binary_accuracy: 0.9074
# Epoch 12/15
# 180000/180000 [==============================] - 7s 42us/step - loss: 0.2141 - binary_accuracy: 0.9202 - val_loss: 0.2495 - val_binary_accuracy: 0.9072
# Epoch 13/15
# 180000/180000 [==============================] - 7s 41us/step - loss: 0.2114 - binary_accuracy: 0.9209 - val_loss: 0.2499 - val_binary_accuracy: 0.9077
# Epoch 14/15
# 180000/180000 [==============================] - 7s 41us/step - loss: 0.2086 - binary_accuracy: 0.9217 - val_loss: 0.2507 - val_binary_accuracy: 0.9060
# Epoch 15/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2053 - binary_accuracy: 0.9229 - val_loss: 0.2507 - val_binary_accuracy: 0.9082
# Train AUC:  0.9029818723952767
# Vali AUC:  0.8331871631282166

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.1)(inp)
    x=Dense(4000, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(4000, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(4000, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.8697814820464009
# Vali AUC:  0.850967452896717

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 4000)              804000
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 4000)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 4000)              16004000
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 4000)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 4000)              16004000
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 4000)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 4001
# =================================================================
# Total params: 32,816,001
# Trainable params: 32,816,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 10s 57us/step - loss: 130.8741 - binary_accuracy: 0.9016 - val_loss: 121.8411 - val_binary_accuracy: 0.9071
# Epoch 2/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 113.6929 - binary_accuracy: 0.9074 - val_loss: 105.8619 - val_binary_accuracy: 0.9083
# Epoch 3/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 98.7888 - binary_accuracy: 0.9093 - val_loss: 91.9888 - val_binary_accuracy: 0.9089
# Epoch 4/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 85.8444 - binary_accuracy: 0.9094 - val_loss: 79.9390 - val_binary_accuracy: 0.9090
# Epoch 5/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 74.6013 - binary_accuracy: 0.9098 - val_loss: 69.4721 - val_binary_accuracy: 0.9095
# Epoch 6/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 64.8349 - binary_accuracy: 0.9104 - val_loss: 60.3817 - val_binary_accuracy: 0.9097
# Epoch 7/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 56.3513 - binary_accuracy: 0.9113 - val_loss: 52.4831 - val_binary_accuracy: 0.9101
# Epoch 8/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 48.9814 - binary_accuracy: 0.9110 - val_loss: 45.6228 - val_binary_accuracy: 0.9096
# Epoch 9/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 42.5806 - binary_accuracy: 0.9112 - val_loss: 39.6638 - val_binary_accuracy: 0.9102
# Epoch 10/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 37.0206 - binary_accuracy: 0.9116 - val_loss: 34.4877 - val_binary_accuracy: 0.9112
# Epoch 11/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 32.1914 - binary_accuracy: 0.9115 - val_loss: 29.9913 - val_binary_accuracy: 0.9110
# Epoch 12/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 27.9950 - binary_accuracy: 0.9119 - val_loss: 26.0853 - val_binary_accuracy: 0.9114
# Epoch 13/15
# 180000/180000 [==============================] - 8s 45us/step - loss: 24.3505 - binary_accuracy: 0.9123 - val_loss: 22.6920 - val_binary_accuracy: 0.9113
# Epoch 14/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 21.1841 - binary_accuracy: 0.9126 - val_loss: 19.7447 - val_binary_accuracy: 0.9109
# Epoch 15/15
# 180000/180000 [==============================] - 8s 44us/step - loss: 18.4350 - binary_accuracy: 0.9123 - val_loss: 17.1843 - val_binary_accuracy: 0.9118
# Train AUC:  0.870276501233742
# Vali AUC:  0.8430149143111569
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-21-0915a45dda66> in <module>()
#       4 graf_model(train_history_regF)
#       5 precision(modelRF, True)
# ----> 6 assert(len(precisiones_globales)==3)
#
# AssertionError:

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
