# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.3342 - binary_accuracy: 0.8968 - val_loss: 0.3138 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.3055 - binary_accuracy: 0.8995 - val_loss: 0.2964 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2874 - binary_accuracy: 0.8995 - val_loss: 0.2784 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2694 - binary_accuracy: 0.9001 - val_loss: 0.2620 - val_binary_accuracy: 0.9014
# Epoch 5/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2547 - binary_accuracy: 0.9037 - val_loss: 0.2509 - val_binary_accuracy: 0.9068
# Epoch 6/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2456 - binary_accuracy: 0.9082 - val_loss: 0.2452 - val_binary_accuracy: 0.9108
# Epoch 7/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2410 - binary_accuracy: 0.9110 - val_loss: 0.2428 - val_binary_accuracy: 0.9125
# Epoch 8/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2388 - binary_accuracy: 0.9118 - val_loss: 0.2419 - val_binary_accuracy: 0.9128
# Epoch 9/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2376 - binary_accuracy: 0.9121 - val_loss: 0.2416 - val_binary_accuracy: 0.9128
# Epoch 10/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2368 - binary_accuracy: 0.9124 - val_loss: 0.2414 - val_binary_accuracy: 0.9125
# Epoch 11/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2362 - binary_accuracy: 0.9125 - val_loss: 0.2413 - val_binary_accuracy: 0.9122
# Epoch 12/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2357 - binary_accuracy: 0.9129 - val_loss: 0.2412 - val_binary_accuracy: 0.9124
# Epoch 13/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2352 - binary_accuracy: 0.9130 - val_loss: 0.2411 - val_binary_accuracy: 0.9123
# Epoch 14/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2347 - binary_accuracy: 0.9132 - val_loss: 0.2411 - val_binary_accuracy: 0.9122
# Epoch 15/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2342 - binary_accuracy: 0.9134 - val_loss: 0.2410 - val_binary_accuracy: 0.9126

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8582400892661421
# Vali AUC:  0.8435023880043917

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [2048, 2048, 2048, 1024, 1024, 1024]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.8774108914108316
# Vali AUC:  0.843112854294398

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [4096, 4096, 4096, 2048, 2048, 2048]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 14s 77us/step - loss: 0.2896 - binary_accuracy: 0.8998 - val_loss: 0.2531 - val_binary_accuracy: 0.9096
# Epoch 2/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2481 - binary_accuracy: 0.9090 - val_loss: 0.2474 - val_binary_accuracy: 0.9109
# Epoch 3/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2390 - binary_accuracy: 0.9119 - val_loss: 0.2494 - val_binary_accuracy: 0.9115
# Epoch 4/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2334 - binary_accuracy: 0.9133 - val_loss: 0.2539 - val_binary_accuracy: 0.9103
# Epoch 5/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2282 - binary_accuracy: 0.9154 - val_loss: 0.2456 - val_binary_accuracy: 0.9110
# Epoch 6/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2240 - binary_accuracy: 0.9167 - val_loss: 0.2497 - val_binary_accuracy: 0.9115
# Epoch 7/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2192 - binary_accuracy: 0.9185 - val_loss: 0.2467 - val_binary_accuracy: 0.9106
# Epoch 8/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2140 - binary_accuracy: 0.9204 - val_loss: 0.2524 - val_binary_accuracy: 0.9065
# Epoch 9/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2092 - binary_accuracy: 0.9220 - val_loss: 0.2483 - val_binary_accuracy: 0.9106
# Epoch 10/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2064 - binary_accuracy: 0.9230 - val_loss: 0.2492 - val_binary_accuracy: 0.9113
# Epoch 11/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2001 - binary_accuracy: 0.9251 - val_loss: 0.2504 - val_binary_accuracy: 0.9107
# Epoch 12/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.1946 - binary_accuracy: 0.9281 - val_loss: 0.2618 - val_binary_accuracy: 0.9000
# Epoch 13/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.1917 - binary_accuracy: 0.9286 - val_loss: 0.2609 - val_binary_accuracy: 0.9005
# Epoch 14/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.1885 - binary_accuracy: 0.9304 - val_loss: 0.2583 - val_binary_accuracy: 0.9033
# Epoch 15/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.1788 - binary_accuracy: 0.9341 - val_loss: 0.2775 - val_binary_accuracy: 0.8900
# Train AUC:  0.9543928544467475
# Vali AUC:  0.8328273999651546

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [2048, 2048, 2048, 1024, 1024, 1024]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 2048)              411648
# _________________________________________________________________
# dense_23 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_24 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_25 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dense_26 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_27 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 13,002,753
# Trainable params: 13,002,753
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 0.3379 - binary_accuracy: 0.8983 - val_loss: 0.3223 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.3128 - binary_accuracy: 0.8995 - val_loss: 0.3016 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2823 - binary_accuracy: 0.8995 - val_loss: 0.2640 - val_binary_accuracy: 0.9007
# Epoch 4/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2502 - binary_accuracy: 0.9059 - val_loss: 0.2480 - val_binary_accuracy: 0.9102
# Epoch 5/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2415 - binary_accuracy: 0.9111 - val_loss: 0.2464 - val_binary_accuracy: 0.9112
# Epoch 6/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2389 - binary_accuracy: 0.9117 - val_loss: 0.2448 - val_binary_accuracy: 0.9122
# Epoch 7/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2369 - binary_accuracy: 0.9122 - val_loss: 0.2443 - val_binary_accuracy: 0.9121
# Epoch 8/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2352 - binary_accuracy: 0.9128 - val_loss: 0.2438 - val_binary_accuracy: 0.9122
# Epoch 9/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2336 - binary_accuracy: 0.9134 - val_loss: 0.2455 - val_binary_accuracy: 0.9108
# Epoch 10/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2320 - binary_accuracy: 0.9137 - val_loss: 0.2433 - val_binary_accuracy: 0.9124
# Epoch 11/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2304 - binary_accuracy: 0.9141 - val_loss: 0.2439 - val_binary_accuracy: 0.9117
# Epoch 12/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2286 - binary_accuracy: 0.9147 - val_loss: 0.2432 - val_binary_accuracy: 0.9126
# Epoch 13/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2269 - binary_accuracy: 0.9153 - val_loss: 0.2439 - val_binary_accuracy: 0.9115
# Epoch 14/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2250 - binary_accuracy: 0.9160 - val_loss: 0.2434 - val_binary_accuracy: 0.9122
# Epoch 15/15
# 180000/180000 [==============================] - 4s 21us/step - loss: 0.2232 - binary_accuracy: 0.9168 - val_loss: 0.2443 - val_binary_accuracy: 0.9124
# Train AUC:  0.8772024719927471
# Vali AUC:  0.8415730685095921

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.1)(inp)
    x=Dense(2048, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.3)(x)
    x=Dense(1024, activation="relu",kernel_regularizer=None)(x)
    x=Dropout(0.4)(x)
    x=Dense(1024, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.4)(x)
    x=Dense(512, activation="relu")(x)
    x=Dropout(0.4)(x)
    x=Dense(256, activation="relu")(x)
    x=Dropout(0.4)(x)  
    x=Dense(256, activation="relu")(x)
    x=Dropout(0)(x) 
    x=Dense(1, activation="sigmoid")(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['binary_accuracy'])
    return model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-8b5b38263580> in <module>()
# ----> 1 kernel_regularizer("=regularizers.l2(0.01)")
#
# NameError: name 'kernel_regularizer' is not defined

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_49 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_294 (Dropout)        (None, 200)               0
# _________________________________________________________________
# dense_329 (Dense)            (None, 2048)              411648
# _________________________________________________________________
# dropout_295 (Dropout)        (None, 2048)              0
# _________________________________________________________________
# dense_330 (Dense)            (None, 1024)              2098176
# _________________________________________________________________
# dropout_296 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_331 (Dense)            (None, 1024)              1049600
# _________________________________________________________________
# dropout_297 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_332 (Dense)            (None, 512)               524800
# _________________________________________________________________
# dropout_298 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_333 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dropout_299 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_334 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_300 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_335 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 4,281,601
# Trainable params: 4,281,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.867601686090985
# Vali AUC:  0.8498629006164287

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_50 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_301 (Dropout)        (None, 200)               0
# _________________________________________________________________
# dense_336 (Dense)            (None, 2048)              411648
# _________________________________________________________________
# dropout_302 (Dropout)        (None, 2048)              0
# _________________________________________________________________
# dense_337 (Dense)            (None, 1024)              2098176
# _________________________________________________________________
# dropout_303 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_338 (Dense)            (None, 1024)              1049600
# _________________________________________________________________
# dropout_304 (Dropout)        (None, 1024)              0
# _________________________________________________________________
# dense_339 (Dense)            (None, 512)               524800
# _________________________________________________________________
# dropout_305 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_340 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dropout_306 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_341 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_307 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_342 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 4,281,601
# Trainable params: 4,281,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 13s 72us/step - loss: 0.4854 - binary_accuracy: 0.9011 - val_loss: 0.3081 - val_binary_accuracy: 0.9095
# Epoch 2/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2935 - binary_accuracy: 0.9066 - val_loss: 0.2787 - val_binary_accuracy: 0.9133
# Epoch 3/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2799 - binary_accuracy: 0.9078 - val_loss: 0.2675 - val_binary_accuracy: 0.9142
# Epoch 4/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2737 - binary_accuracy: 0.9076 - val_loss: 0.2615 - val_binary_accuracy: 0.9118
# Epoch 5/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2710 - binary_accuracy: 0.9078 - val_loss: 0.2603 - val_binary_accuracy: 0.9136
# Epoch 6/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2679 - binary_accuracy: 0.9084 - val_loss: 0.2674 - val_binary_accuracy: 0.9128
# Epoch 7/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2664 - binary_accuracy: 0.9087 - val_loss: 0.2633 - val_binary_accuracy: 0.9121
# Epoch 8/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2650 - binary_accuracy: 0.9086 - val_loss: 0.2619 - val_binary_accuracy: 0.9133
# Epoch 9/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2641 - binary_accuracy: 0.9091 - val_loss: 0.2573 - val_binary_accuracy: 0.9119
# Epoch 10/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2647 - binary_accuracy: 0.9090 - val_loss: 0.2564 - val_binary_accuracy: 0.9127
# Epoch 11/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2630 - binary_accuracy: 0.9095 - val_loss: 0.2569 - val_binary_accuracy: 0.9109
# Epoch 12/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2626 - binary_accuracy: 0.9090 - val_loss: 0.2578 - val_binary_accuracy: 0.9102
# Epoch 13/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2635 - binary_accuracy: 0.9090 - val_loss: 0.2552 - val_binary_accuracy: 0.9129
# Epoch 14/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2621 - binary_accuracy: 0.9095 - val_loss: 0.2570 - val_binary_accuracy: 0.9130
# Epoch 15/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2623 - binary_accuracy: 0.9093 - val_loss: 0.2555 - val_binary_accuracy: 0.9109
# Train AUC:  0.8676165394494438
# Vali AUC:  0.8517059228593

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
