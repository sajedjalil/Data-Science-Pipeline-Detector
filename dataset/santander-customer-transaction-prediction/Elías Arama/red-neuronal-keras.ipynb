# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capas ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3385 - binary_accuracy: 0.8977 - val_loss: 0.3188 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3112 - binary_accuracy: 0.8995 - val_loss: 0.3027 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2944 - binary_accuracy: 0.8995 - val_loss: 0.2857 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2770 - binary_accuracy: 0.8996 - val_loss: 0.2690 - val_binary_accuracy: 0.9000
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2611 - binary_accuracy: 0.9011 - val_loss: 0.2555 - val_binary_accuracy: 0.9028
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2498 - binary_accuracy: 0.9059 - val_loss: 0.2473 - val_binary_accuracy: 0.9079
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2434 - binary_accuracy: 0.9097 - val_loss: 0.2434 - val_binary_accuracy: 0.9095
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2402 - binary_accuracy: 0.9114 - val_loss: 0.2417 - val_binary_accuracy: 0.9101
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2385 - binary_accuracy: 0.9119 - val_loss: 0.2410 - val_binary_accuracy: 0.9102
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2376 - binary_accuracy: 0.9123 - val_loss: 0.2406 - val_binary_accuracy: 0.9107
# Epoch 11/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.2370 - binary_accuracy: 0.9126 - val_loss: 0.2404 - val_binary_accuracy: 0.9103
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2364 - binary_accuracy: 0.9128 - val_loss: 0.2403 - val_binary_accuracy: 0.9107
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2359 - binary_accuracy: 0.9131 - val_loss: 0.2401 - val_binary_accuracy: 0.9105
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2354 - binary_accuracy: 0.9132 - val_loss: 0.2401 - val_binary_accuracy: 0.9109
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2349 - binary_accuracy: 0.9134 - val_loss: 0.2400 - val_binary_accuracy: 0.9110

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8568240001765501
# Vali AUC:  0.849855129577239

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capas ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capas ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capas ocultas, con 5, 10 y 20 capas respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [200,2100,2100,2100,2100,2100]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.8658328689623616
# Vali AUC:  0.8523436320343807

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [200,2110,2110,2110,2110,2110]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 6s 33us/step - loss: 0.3405 - binary_accuracy: 0.8995 - val_loss: 0.3227 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.3150 - binary_accuracy: 0.8995 - val_loss: 0.3070 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2958 - binary_accuracy: 0.8995 - val_loss: 0.2844 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2696 - binary_accuracy: 0.8996 - val_loss: 0.2595 - val_binary_accuracy: 0.8998
# Epoch 5/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2500 - binary_accuracy: 0.9042 - val_loss: 0.2493 - val_binary_accuracy: 0.9071
# Epoch 6/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2430 - binary_accuracy: 0.9097 - val_loss: 0.2460 - val_binary_accuracy: 0.9091
# Epoch 7/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2400 - binary_accuracy: 0.9112 - val_loss: 0.2446 - val_binary_accuracy: 0.9097
# Epoch 8/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2379 - binary_accuracy: 0.9122 - val_loss: 0.2436 - val_binary_accuracy: 0.9097
# Epoch 9/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2362 - binary_accuracy: 0.9127 - val_loss: 0.2429 - val_binary_accuracy: 0.9099
# Epoch 10/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2347 - binary_accuracy: 0.9133 - val_loss: 0.2423 - val_binary_accuracy: 0.9101
# Epoch 11/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2334 - binary_accuracy: 0.9135 - val_loss: 0.2418 - val_binary_accuracy: 0.9103
# Epoch 12/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2321 - binary_accuracy: 0.9139 - val_loss: 0.2413 - val_binary_accuracy: 0.9106
# Epoch 13/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2309 - binary_accuracy: 0.9142 - val_loss: 0.2410 - val_binary_accuracy: 0.9106
# Epoch 14/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2297 - binary_accuracy: 0.9148 - val_loss: 0.2406 - val_binary_accuracy: 0.9109
# Epoch 15/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2286 - binary_accuracy: 0.9150 - val_loss: 0.2403 - val_binary_accuracy: 0.9103
# Train AUC:  0.8679410168961341
# Vali AUC:  0.8491864192102301

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [200,2100,2100,2100,2100,2100]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dense_19 (Dense)             (None, 2100)              422100
# _________________________________________________________________
# dense_20 (Dense)             (None, 2100)              4412100
# _________________________________________________________________
# dense_21 (Dense)             (None, 2100)              4412100
# _________________________________________________________________
# dense_22 (Dense)             (None, 2100)              4412100
# _________________________________________________________________
# dense_23 (Dense)             (None, 2100)              4412100
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 2101
# =================================================================
# Total params: 18,112,801
# Trainable params: 18,112,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 6s 33us/step - loss: 0.3397 - binary_accuracy: 0.8994 - val_loss: 0.3220 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.3144 - binary_accuracy: 0.8995 - val_loss: 0.3069 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2961 - binary_accuracy: 0.8995 - val_loss: 0.2853 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2714 - binary_accuracy: 0.8995 - val_loss: 0.2608 - val_binary_accuracy: 0.8997
# Epoch 5/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2515 - binary_accuracy: 0.9030 - val_loss: 0.2486 - val_binary_accuracy: 0.9078
# Epoch 6/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2438 - binary_accuracy: 0.9093 - val_loss: 0.2450 - val_binary_accuracy: 0.9095
# Epoch 7/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2406 - binary_accuracy: 0.9110 - val_loss: 0.2433 - val_binary_accuracy: 0.9102
# Epoch 8/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2385 - binary_accuracy: 0.9118 - val_loss: 0.2422 - val_binary_accuracy: 0.9104
# Epoch 9/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2368 - binary_accuracy: 0.9122 - val_loss: 0.2414 - val_binary_accuracy: 0.9108
# Epoch 10/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2353 - binary_accuracy: 0.9127 - val_loss: 0.2408 - val_binary_accuracy: 0.9109
# Epoch 11/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2340 - binary_accuracy: 0.9130 - val_loss: 0.2404 - val_binary_accuracy: 0.9111
# Epoch 12/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2327 - binary_accuracy: 0.9135 - val_loss: 0.2399 - val_binary_accuracy: 0.9118
# Epoch 13/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2315 - binary_accuracy: 0.9139 - val_loss: 0.2393 - val_binary_accuracy: 0.9114
# Epoch 14/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2304 - binary_accuracy: 0.9141 - val_loss: 0.2389 - val_binary_accuracy: 0.9121
# Epoch 15/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.2292 - binary_accuracy: 0.9145 - val_loss: 0.2390 - val_binary_accuracy: 0.9117
# Train AUC:  0.8666969768896582
# Vali AUC:  0.8512150890904012

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.1)(inp)
    x=Dense(200, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.15)(x)
    x=Dense(2100, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.25)(x)
    x=Dense(2100, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.4)(x)  
    x=Dense(2100, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.5)(x)  
    x=Dense(2100, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.6)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train AUC:  0.8579693334093124
# Vali AUC:  0.8546515891913419

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 2100)              422100
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2100)              0
# _________________________________________________________________
# dense_33 (Dense)             (None, 2100)              4412100
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2100)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 2100)              4412100
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 2100)              0
# _________________________________________________________________
# dense_35 (Dense)             (None, 2100)              4412100
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2100)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 2101
# =================================================================
# Total params: 13,700,701
# Trainable params: 13,700,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 7s 41us/step - loss: 106.8293 - binary_accuracy: 0.8965 - val_loss: 99.4919 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 92.8275 - binary_accuracy: 0.8995 - val_loss: 86.4596 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 80.6727 - binary_accuracy: 0.8995 - val_loss: 75.1358 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 70.1144 - binary_accuracy: 0.8995 - val_loss: 65.3019 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 60.9429 - binary_accuracy: 0.8995 - val_loss: 56.7586 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 52.9751 - binary_accuracy: 0.8995 - val_loss: 49.3378 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 46.0535 - binary_accuracy: 0.8995 - val_loss: 42.8924 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 40.0414 - binary_accuracy: 0.8995 - val_loss: 37.2944 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 34.8191 - binary_accuracy: 0.8995 - val_loss: 32.4321 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 30.2837 - binary_accuracy: 0.8995 - val_loss: 28.2091 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 26.3439 - binary_accuracy: 0.8995 - val_loss: 24.5410 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 22.9225 - binary_accuracy: 0.8995 - val_loss: 21.3551 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 19.9499 - binary_accuracy: 0.8995 - val_loss: 18.5881 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 17.3686 - binary_accuracy: 0.8995 - val_loss: 16.1842 - val_binary_accuracy: 0.8995
# Epoch 15/15
# 180000/180000 [==============================] - 5s 27us/step - loss: 15.1252 - binary_accuracy: 0.8995 - val_loss: 14.0958 - val_binary_accuracy: 0.8995
# Train AUC:  0.8579934660833993
# Vali AUC:  0.8549052403352885

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
