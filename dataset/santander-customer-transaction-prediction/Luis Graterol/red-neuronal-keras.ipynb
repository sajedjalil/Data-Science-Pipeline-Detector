# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrenamiento: ",train_dfX.shape)
print("Validacion: ",val_dfX.shape)
# Out:
# Entrenamiento:  (180000, 200)
# Validacion:  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dense_45 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.3397 - binary_accuracy: 0.8961 - val_loss: 0.3204 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3117 - binary_accuracy: 0.8995 - val_loss: 0.3041 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2948 - binary_accuracy: 0.8995 - val_loss: 0.2869 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2771 - binary_accuracy: 0.8996 - val_loss: 0.2697 - val_binary_accuracy: 0.8999
# Epoch 5/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2609 - binary_accuracy: 0.9013 - val_loss: 0.2561 - val_binary_accuracy: 0.9044
# Epoch 6/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2494 - binary_accuracy: 0.9063 - val_loss: 0.2480 - val_binary_accuracy: 0.9081
# Epoch 7/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2430 - binary_accuracy: 0.9098 - val_loss: 0.2441 - val_binary_accuracy: 0.9097
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2399 - binary_accuracy: 0.9113 - val_loss: 0.2425 - val_binary_accuracy: 0.9110
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2382 - binary_accuracy: 0.9120 - val_loss: 0.2419 - val_binary_accuracy: 0.9116
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2373 - binary_accuracy: 0.9121 - val_loss: 0.2416 - val_binary_accuracy: 0.9118
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2366 - binary_accuracy: 0.9124 - val_loss: 0.2415 - val_binary_accuracy: 0.9118
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2360 - binary_accuracy: 0.9126 - val_loss: 0.2414 - val_binary_accuracy: 0.9117
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2355 - binary_accuracy: 0.9127 - val_loss: 0.2413 - val_binary_accuracy: 0.9122
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2350 - binary_accuracy: 0.9130 - val_loss: 0.2413 - val_binary_accuracy: 0.9120
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2346 - binary_accuracy: 0.9130 - val_loss: 0.2413 - val_binary_accuracy: 0.9124

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8579220785900834
# Vali AUC:  0.8442078379641538

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [4096,2048,1024,1024]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 4096)              823296
# _________________________________________________________________
# dense_48 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dense_49 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dense_50 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 12,362,753
# Trainable params: 12,362,753
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8737931626191842
# Vali AUC:  0.8422991352299095

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [1024,1024,256,256]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=20, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/20
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.4148 - binary_accuracy: 0.8895 - val_loss: 0.3271 - val_binary_accuracy: 0.8995
# Epoch 2/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3236 - binary_accuracy: 0.8995 - val_loss: 0.3209 - val_binary_accuracy: 0.8995
# Epoch 3/20
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.3172 - binary_accuracy: 0.8995 - val_loss: 0.3142 - val_binary_accuracy: 0.8995
# Epoch 4/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3097 - binary_accuracy: 0.8995 - val_loss: 0.3059 - val_binary_accuracy: 0.8995
# Epoch 5/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3001 - binary_accuracy: 0.8995 - val_loss: 0.2948 - val_binary_accuracy: 0.8995
# Epoch 6/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2871 - binary_accuracy: 0.8995 - val_loss: 0.2803 - val_binary_accuracy: 0.8995
# Epoch 7/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2716 - binary_accuracy: 0.8995 - val_loss: 0.2655 - val_binary_accuracy: 0.8995
# Epoch 8/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2583 - binary_accuracy: 0.8995 - val_loss: 0.2553 - val_binary_accuracy: 0.8995
# Epoch 9/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2503 - binary_accuracy: 0.8995 - val_loss: 0.2504 - val_binary_accuracy: 0.8995
# Epoch 10/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2463 - binary_accuracy: 0.8995 - val_loss: 0.2482 - val_binary_accuracy: 0.8995
# Epoch 11/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2442 - binary_accuracy: 0.8995 - val_loss: 0.2471 - val_binary_accuracy: 0.8995
# Epoch 12/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2429 - binary_accuracy: 0.8995 - val_loss: 0.2464 - val_binary_accuracy: 0.8995
# Epoch 13/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2418 - binary_accuracy: 0.8995 - val_loss: 0.2459 - val_binary_accuracy: 0.8995
# Epoch 14/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2409 - binary_accuracy: 0.8996 - val_loss: 0.2455 - val_binary_accuracy: 0.8999
# Epoch 15/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2401 - binary_accuracy: 0.9024 - val_loss: 0.2452 - val_binary_accuracy: 0.9057
# Epoch 16/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2393 - binary_accuracy: 0.9081 - val_loss: 0.2449 - val_binary_accuracy: 0.9087
# Epoch 17/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2385 - binary_accuracy: 0.9108 - val_loss: 0.2445 - val_binary_accuracy: 0.9106
# Epoch 18/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2378 - binary_accuracy: 0.9117 - val_loss: 0.2441 - val_binary_accuracy: 0.9110
# Epoch 19/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2370 - binary_accuracy: 0.9123 - val_loss: 0.2438 - val_binary_accuracy: 0.9116
# Epoch 20/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2363 - binary_accuracy: 0.9126 - val_loss: 0.2437 - val_binary_accuracy: 0.9115
# Train AUC:  0.8602062087993743
# Vali AUC:  0.8450240459735785

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [1024,1024,256,256]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=20, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 1024)              205824
# _________________________________________________________________
# dense_58 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dense_59 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_60 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_61 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 1,583,873
# Trainable params: 1,583,873
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/20
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.4358 - binary_accuracy: 0.8893 - val_loss: 0.3280 - val_binary_accuracy: 0.8995
# Epoch 2/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3250 - binary_accuracy: 0.8995 - val_loss: 0.3223 - val_binary_accuracy: 0.8995
# Epoch 3/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3192 - binary_accuracy: 0.8995 - val_loss: 0.3161 - val_binary_accuracy: 0.8995
# Epoch 4/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3123 - binary_accuracy: 0.8995 - val_loss: 0.3085 - val_binary_accuracy: 0.8995
# Epoch 5/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.3033 - binary_accuracy: 0.8995 - val_loss: 0.2981 - val_binary_accuracy: 0.8995
# Epoch 6/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2907 - binary_accuracy: 0.8995 - val_loss: 0.2837 - val_binary_accuracy: 0.8995
# Epoch 7/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2747 - binary_accuracy: 0.8995 - val_loss: 0.2677 - val_binary_accuracy: 0.8995
# Epoch 8/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2600 - binary_accuracy: 0.8995 - val_loss: 0.2561 - val_binary_accuracy: 0.8995
# Epoch 9/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2510 - binary_accuracy: 0.8995 - val_loss: 0.2506 - val_binary_accuracy: 0.8995
# Epoch 10/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2466 - binary_accuracy: 0.8995 - val_loss: 0.2481 - val_binary_accuracy: 0.8995
# Epoch 11/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2442 - binary_accuracy: 0.8995 - val_loss: 0.2469 - val_binary_accuracy: 0.8995
# Epoch 12/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2427 - binary_accuracy: 0.8995 - val_loss: 0.2460 - val_binary_accuracy: 0.8995
# Epoch 13/20
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2414 - binary_accuracy: 0.8995 - val_loss: 0.2454 - val_binary_accuracy: 0.8996
# Epoch 14/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2403 - binary_accuracy: 0.9005 - val_loss: 0.2449 - val_binary_accuracy: 0.9031
# Epoch 15/20
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2393 - binary_accuracy: 0.9070 - val_loss: 0.2443 - val_binary_accuracy: 0.9096
# Epoch 16/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2384 - binary_accuracy: 0.9112 - val_loss: 0.2439 - val_binary_accuracy: 0.9118
# Epoch 17/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2375 - binary_accuracy: 0.9124 - val_loss: 0.2433 - val_binary_accuracy: 0.9124
# Epoch 18/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2366 - binary_accuracy: 0.9130 - val_loss: 0.2429 - val_binary_accuracy: 0.9126
# Epoch 19/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2358 - binary_accuracy: 0.9132 - val_loss: 0.2426 - val_binary_accuracy: 0.9127
# Epoch 20/20
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2349 - binary_accuracy: 0.9133 - val_loss: 0.2421 - val_binary_accuracy: 0.9129
# Train AUC:  0.8612658157494172
# Vali AUC:  0.8461995746669653

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0)(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)
    x=Dense(256, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)
    x=Dense(256, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_76 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_77 (Dense)             (None, 256)               263424
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 1,593,913
# Trainable params: 1,593,913
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8616493602262887
# Vali AUC:  0.8489260340874836

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_80 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_81 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_82 (Dense)             (None, 256)               263424
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_83 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 1,593,913
# Trainable params: 1,593,913
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 2.0202 - binary_accuracy: 0.8930 - val_loss: 1.8176 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 1.7151 - binary_accuracy: 0.8995 - val_loss: 1.6162 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 1.5266 - binary_accuracy: 0.8995 - val_loss: 1.4400 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 1.3613 - binary_accuracy: 0.8995 - val_loss: 1.2851 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 1.2153 - binary_accuracy: 0.8995 - val_loss: 1.1476 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 1.0847 - binary_accuracy: 0.8995 - val_loss: 1.0240 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.9671 - binary_accuracy: 0.8995 - val_loss: 0.9132 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.8631 - binary_accuracy: 0.8995 - val_loss: 0.8178 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.7753 - binary_accuracy: 0.8995 - val_loss: 0.7387 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.7022 - binary_accuracy: 0.8995 - val_loss: 0.6724 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.6402 - binary_accuracy: 0.8995 - val_loss: 0.6158 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.5870 - binary_accuracy: 0.8995 - val_loss: 0.5669 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.5408 - binary_accuracy: 0.8995 - val_loss: 0.5244 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.5006 - binary_accuracy: 0.8995 - val_loss: 0.4875 - val_binary_accuracy: 0.8995
# Epoch 15/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.4655 - binary_accuracy: 0.8995 - val_loss: 0.4554 - val_binary_accuracy: 0.8995
# Train AUC:  0.8620070074020804
# Vali AUC:  0.848136941750392

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = model.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
