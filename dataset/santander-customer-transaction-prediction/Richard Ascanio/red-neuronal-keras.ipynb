# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrenamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrenamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 17us/step - loss: 0.3357 - binary_accuracy: 0.8960 - val_loss: 0.3153 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3070 - binary_accuracy: 0.8995 - val_loss: 0.2978 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2892 - binary_accuracy: 0.8995 - val_loss: 0.2796 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2714 - binary_accuracy: 0.8999 - val_loss: 0.2627 - val_binary_accuracy: 0.9007
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2564 - binary_accuracy: 0.9029 - val_loss: 0.2506 - val_binary_accuracy: 0.9074
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2467 - binary_accuracy: 0.9072 - val_loss: 0.2440 - val_binary_accuracy: 0.9099
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2417 - binary_accuracy: 0.9101 - val_loss: 0.2410 - val_binary_accuracy: 0.9113
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2393 - binary_accuracy: 0.9115 - val_loss: 0.2398 - val_binary_accuracy: 0.9115
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2380 - binary_accuracy: 0.9122 - val_loss: 0.2393 - val_binary_accuracy: 0.9118
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2372 - binary_accuracy: 0.9124 - val_loss: 0.2391 - val_binary_accuracy: 0.9117
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2366 - binary_accuracy: 0.9127 - val_loss: 0.2390 - val_binary_accuracy: 0.9119
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2361 - binary_accuracy: 0.9129 - val_loss: 0.2389 - val_binary_accuracy: 0.9123
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2356 - binary_accuracy: 0.9129 - val_loss: 0.2388 - val_binary_accuracy: 0.9122
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2351 - binary_accuracy: 0.9131 - val_loss: 0.2387 - val_binary_accuracy: 0.9123
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2346 - binary_accuracy: 0.9132 - val_loss: 0.2387 - val_binary_accuracy: 0.9121

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8575104907825938
# Vali AUC:  0.8483461237448111

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [2048,1028,256]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 2048)              411648
# _________________________________________________________________
# dense_37 (Dense)             (None, 1028)              2106372
# _________________________________________________________________
# dense_38 (Dense)             (None, 256)               263424
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 2,781,701
# Trainable params: 2,781,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8590768927662291
# Vali AUC:  0.8487694103136347

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [1028,2048,1028,2048,1028,2048]
model2 = func_model(arquitectura2)
print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_31 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_142 (Dense)            (None, 1028)              206628
# _________________________________________________________________
# dense_143 (Dense)            (None, 2048)              2107392
# _________________________________________________________________
# dense_144 (Dense)            (None, 1028)              2106372
# _________________________________________________________________
# dense_145 (Dense)            (None, 2048)              2107392
# _________________________________________________________________
# dense_146 (Dense)            (None, 1028)              2106372
# _________________________________________________________________
# dense_147 (Dense)            (None, 2048)              2107392
# _________________________________________________________________
# dense_148 (Dense)            (None, 1)                 2049
# =================================================================
# Total params: 10,743,597
# Trainable params: 10,743,597
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 6s 34us/step - loss: 0.3390 - binary_accuracy: 0.8975 - val_loss: 0.3219 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.3148 - binary_accuracy: 0.8995 - val_loss: 0.3059 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2935 - binary_accuracy: 0.8995 - val_loss: 0.2782 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2628 - binary_accuracy: 0.9008 - val_loss: 0.2510 - val_binary_accuracy: 0.9066
# Epoch 5/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2455 - binary_accuracy: 0.9089 - val_loss: 0.2442 - val_binary_accuracy: 0.9110
# Epoch 6/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2409 - binary_accuracy: 0.9111 - val_loss: 0.2428 - val_binary_accuracy: 0.9125
# Epoch 7/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2386 - binary_accuracy: 0.9116 - val_loss: 0.2418 - val_binary_accuracy: 0.9126
# Epoch 8/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2369 - binary_accuracy: 0.9120 - val_loss: 0.2412 - val_binary_accuracy: 0.9126
# Epoch 9/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2352 - binary_accuracy: 0.9126 - val_loss: 0.2409 - val_binary_accuracy: 0.9129
# Epoch 10/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2337 - binary_accuracy: 0.9132 - val_loss: 0.2403 - val_binary_accuracy: 0.9131
# Epoch 11/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2323 - binary_accuracy: 0.9134 - val_loss: 0.2400 - val_binary_accuracy: 0.9129
# Epoch 12/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2308 - binary_accuracy: 0.9142 - val_loss: 0.2402 - val_binary_accuracy: 0.9133
# Epoch 13/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2293 - binary_accuracy: 0.9142 - val_loss: 0.2399 - val_binary_accuracy: 0.9132
# Epoch 14/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2278 - binary_accuracy: 0.9150 - val_loss: 0.2393 - val_binary_accuracy: 0.9135
# Epoch 15/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2263 - binary_accuracy: 0.9153 - val_loss: 0.2390 - val_binary_accuracy: 0.9135
# Train AUC:  0.8728926747962468
# Vali AUC:  0.8485363206203558

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [1028,2048,1028,2048,1028,2048]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_34 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_163 (Dense)            (None, 1028)              206628
# _________________________________________________________________
# dense_164 (Dense)            (None, 2048)              2107392
# _________________________________________________________________
# dense_165 (Dense)            (None, 1028)              2106372
# _________________________________________________________________
# dense_166 (Dense)            (None, 2048)              2107392
# _________________________________________________________________
# dense_167 (Dense)            (None, 1028)              2106372
# _________________________________________________________________
# dense_168 (Dense)            (None, 2048)              2107392
# _________________________________________________________________
# dense_169 (Dense)            (None, 1)                 2049
# =================================================================
# Total params: 10,743,597
# Trainable params: 10,743,597
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 6s 36us/step - loss: 0.3374 - binary_accuracy: 0.8993 - val_loss: 0.3217 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.3130 - binary_accuracy: 0.8995 - val_loss: 0.3033 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2881 - binary_accuracy: 0.8995 - val_loss: 0.2720 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2573 - binary_accuracy: 0.9025 - val_loss: 0.2493 - val_binary_accuracy: 0.9083
# Epoch 5/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2439 - binary_accuracy: 0.9100 - val_loss: 0.2443 - val_binary_accuracy: 0.9109
# Epoch 6/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2402 - binary_accuracy: 0.9114 - val_loss: 0.2429 - val_binary_accuracy: 0.9120
# Epoch 7/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2380 - binary_accuracy: 0.9122 - val_loss: 0.2421 - val_binary_accuracy: 0.9122
# Epoch 8/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2362 - binary_accuracy: 0.9126 - val_loss: 0.2416 - val_binary_accuracy: 0.9122
# Epoch 9/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2346 - binary_accuracy: 0.9134 - val_loss: 0.2412 - val_binary_accuracy: 0.9125
# Epoch 10/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2330 - binary_accuracy: 0.9139 - val_loss: 0.2408 - val_binary_accuracy: 0.9125
# Epoch 11/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2315 - binary_accuracy: 0.9143 - val_loss: 0.2405 - val_binary_accuracy: 0.9126
# Epoch 12/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2300 - binary_accuracy: 0.9145 - val_loss: 0.2404 - val_binary_accuracy: 0.9132
# Epoch 13/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2284 - binary_accuracy: 0.9152 - val_loss: 0.2399 - val_binary_accuracy: 0.9131
# Epoch 14/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2267 - binary_accuracy: 0.9156 - val_loss: 0.2396 - val_binary_accuracy: 0.9132
# Epoch 15/15
# 180000/180000 [==============================] - 4s 22us/step - loss: 0.2251 - binary_accuracy: 0.9161 - val_loss: 0.2398 - val_binary_accuracy: 0.9134
# Train AUC:  0.8739186327884763
# Vali AUC:  0.847128946706158
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-47-33d3b7c9108c> in <module>()
#       5 graf_model(train_history_tamF)
#       6 precision(modelF, True)
# ----> 7 assert(len(precisiones_globales)==3)
#
# AssertionError:

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0)(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adamax', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model3 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model3.summary())
train_history_tam1 = model3.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_37 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_178 (Dense)            (None, 1028)              206628
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_179 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_180 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_181 (Dense)            (None, 1)                 1029
# =================================================================
# Total params: 2,323,281
# Trainable params: 2,323,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8725382357382792
# Vali AUC:  0.8521807858981911

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_38 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_182 (Dense)            (None, 1028)              206628
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_183 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_184 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_185 (Dense)            (None, 1)                 1029
# =================================================================
# Total params: 2,323,281
# Trainable params: 2,323,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 5s 28us/step - loss: 0.3292 - binary_accuracy: 0.9040 - val_loss: 0.2512 - val_binary_accuracy: 0.9122
# Epoch 2/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2478 - binary_accuracy: 0.9124 - val_loss: 0.2452 - val_binary_accuracy: 0.9140
# Epoch 3/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2433 - binary_accuracy: 0.9126 - val_loss: 0.2465 - val_binary_accuracy: 0.9128
# Epoch 4/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2417 - binary_accuracy: 0.9131 - val_loss: 0.2417 - val_binary_accuracy: 0.9130
# Epoch 5/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2402 - binary_accuracy: 0.9131 - val_loss: 0.2412 - val_binary_accuracy: 0.9142
# Epoch 6/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2394 - binary_accuracy: 0.9136 - val_loss: 0.2415 - val_binary_accuracy: 0.9152
# Epoch 7/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2380 - binary_accuracy: 0.9137 - val_loss: 0.2415 - val_binary_accuracy: 0.9130
# Epoch 8/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2373 - binary_accuracy: 0.9137 - val_loss: 0.2408 - val_binary_accuracy: 0.9140
# Epoch 9/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2358 - binary_accuracy: 0.9146 - val_loss: 0.2408 - val_binary_accuracy: 0.9156
# Epoch 10/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2351 - binary_accuracy: 0.9145 - val_loss: 0.2407 - val_binary_accuracy: 0.9146
# Epoch 11/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2348 - binary_accuracy: 0.9146 - val_loss: 0.2424 - val_binary_accuracy: 0.9142
# Epoch 12/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2345 - binary_accuracy: 0.9145 - val_loss: 0.2411 - val_binary_accuracy: 0.9140
# Epoch 13/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2341 - binary_accuracy: 0.9146 - val_loss: 0.2408 - val_binary_accuracy: 0.9155
# Epoch 14/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2336 - binary_accuracy: 0.9146 - val_loss: 0.2414 - val_binary_accuracy: 0.9149
# Epoch 15/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2332 - binary_accuracy: 0.9152 - val_loss: 0.2427 - val_binary_accuracy: 0.9139
# Train AUC:  0.8771181376415174
# Vali AUC:  0.8502880815488982
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-54-0915a45dda66> in <module>()
#       4 graf_model(train_history_regF)
#       5 precision(modelRF, True)
# ----> 6 assert(len(precisiones_globales)==3)
#
# AssertionError:

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
