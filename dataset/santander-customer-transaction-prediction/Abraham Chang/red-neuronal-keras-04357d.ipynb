# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_54 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_223 (Dense)            (None, 1028)              206628
# _________________________________________________________________
# dense_224 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dense_225 (Dense)            (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 5s 30us/step - loss: 0.3374 - binary_accuracy: 0.8978 - val_loss: 0.3177 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3094 - binary_accuracy: 0.8995 - val_loss: 0.3007 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2918 - binary_accuracy: 0.8995 - val_loss: 0.2825 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2736 - binary_accuracy: 0.8997 - val_loss: 0.2651 - val_binary_accuracy: 0.9003
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2580 - binary_accuracy: 0.9025 - val_loss: 0.2521 - val_binary_accuracy: 0.9048
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2477 - binary_accuracy: 0.9074 - val_loss: 0.2445 - val_binary_accuracy: 0.9092
# Epoch 7/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2423 - binary_accuracy: 0.9106 - val_loss: 0.2410 - val_binary_accuracy: 0.9097
# Epoch 8/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2396 - binary_accuracy: 0.9119 - val_loss: 0.2394 - val_binary_accuracy: 0.9100
# Epoch 9/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2383 - binary_accuracy: 0.9125 - val_loss: 0.2386 - val_binary_accuracy: 0.9105
# Epoch 10/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2374 - binary_accuracy: 0.9128 - val_loss: 0.2382 - val_binary_accuracy: 0.9110
# Epoch 11/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2368 - binary_accuracy: 0.9130 - val_loss: 0.2380 - val_binary_accuracy: 0.9111
# Epoch 12/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2362 - binary_accuracy: 0.9132 - val_loss: 0.2378 - val_binary_accuracy: 0.9107
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2357 - binary_accuracy: 0.9134 - val_loss: 0.2376 - val_binary_accuracy: 0.9110
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2352 - binary_accuracy: 0.9136 - val_loss: 0.2375 - val_binary_accuracy: 0.9110
# Epoch 15/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 0.2348 - binary_accuracy: 0.9137 - val_loss: 0.2374 - val_binary_accuracy: 0.9111

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8568422632805881
# Vali AUC:  0.8532401638278866

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [200,400,600,800]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.8536735258669406
# Vali AUC:  0.8502195249433764

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [3000,5000,9000]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 18s 101us/step - loss: 0.2799 - binary_accuracy: 0.9026 - val_loss: 0.2510 - val_binary_accuracy: 0.9071
# Epoch 2/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2478 - binary_accuracy: 0.9086 - val_loss: 0.2474 - val_binary_accuracy: 0.9087
# Epoch 3/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2411 - binary_accuracy: 0.9110 - val_loss: 0.2484 - val_binary_accuracy: 0.9072
# Epoch 4/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2352 - binary_accuracy: 0.9129 - val_loss: 0.2460 - val_binary_accuracy: 0.9083
# Epoch 5/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2306 - binary_accuracy: 0.9147 - val_loss: 0.2550 - val_binary_accuracy: 0.9079
# Epoch 6/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2255 - binary_accuracy: 0.9159 - val_loss: 0.2598 - val_binary_accuracy: 0.9018
# Epoch 7/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2212 - binary_accuracy: 0.9176 - val_loss: 0.2506 - val_binary_accuracy: 0.9081
# Epoch 8/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2167 - binary_accuracy: 0.9187 - val_loss: 0.2465 - val_binary_accuracy: 0.9092
# Epoch 9/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2127 - binary_accuracy: 0.9205 - val_loss: 0.2477 - val_binary_accuracy: 0.9083
# Epoch 10/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2083 - binary_accuracy: 0.9219 - val_loss: 0.2460 - val_binary_accuracy: 0.9080
# Epoch 11/15
# 180000/180000 [==============================] - 13s 71us/step - loss: 0.2037 - binary_accuracy: 0.9234 - val_loss: 0.2460 - val_binary_accuracy: 0.9081
# Epoch 12/15
# 180000/180000 [==============================] - 13s 71us/step - loss: 0.2000 - binary_accuracy: 0.9248 - val_loss: 0.2628 - val_binary_accuracy: 0.9001
# Epoch 13/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.1961 - binary_accuracy: 0.9261 - val_loss: 0.2471 - val_binary_accuracy: 0.9083
# Epoch 14/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.1914 - binary_accuracy: 0.9281 - val_loss: 0.2477 - val_binary_accuracy: 0.9077
# Epoch 15/15
# 180000/180000 [==============================] - 13s 71us/step - loss: 0.1872 - binary_accuracy: 0.9296 - val_loss: 0.2483 - val_binary_accuracy: 0.9089
# Train AUC:  0.9288040347838357
# Vali AUC:  0.840588220653265

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [3000,5000,9000]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_58 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dense_242 (Dense)            (None, 3000)              603000
# _________________________________________________________________
# dense_243 (Dense)            (None, 5000)              15005000
# _________________________________________________________________
# dense_244 (Dense)            (None, 9000)              45009000
# _________________________________________________________________
# dense_245 (Dense)            (None, 1)                 9001
# =================================================================
# Total params: 60,626,001
# Trainable params: 60,626,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 19s 103us/step - loss: 0.2790 - binary_accuracy: 0.9026 - val_loss: 0.2515 - val_binary_accuracy: 0.9062
# Epoch 2/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2462 - binary_accuracy: 0.9098 - val_loss: 0.2493 - val_binary_accuracy: 0.9064
# Epoch 3/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2400 - binary_accuracy: 0.9116 - val_loss: 0.2482 - val_binary_accuracy: 0.9066
# Epoch 4/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2344 - binary_accuracy: 0.9136 - val_loss: 0.2545 - val_binary_accuracy: 0.9083
# Epoch 5/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2288 - binary_accuracy: 0.9151 - val_loss: 0.2474 - val_binary_accuracy: 0.9075
# Epoch 6/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2245 - binary_accuracy: 0.9167 - val_loss: 0.2465 - val_binary_accuracy: 0.9074
# Epoch 7/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2200 - binary_accuracy: 0.9181 - val_loss: 0.2472 - val_binary_accuracy: 0.9075
# Epoch 8/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2157 - binary_accuracy: 0.9197 - val_loss: 0.2540 - val_binary_accuracy: 0.9045
# Epoch 9/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2113 - binary_accuracy: 0.9212 - val_loss: 0.2482 - val_binary_accuracy: 0.9084
# Epoch 10/15
# 180000/180000 [==============================] - 13s 71us/step - loss: 0.2072 - binary_accuracy: 0.9226 - val_loss: 0.2498 - val_binary_accuracy: 0.9077
# Epoch 11/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2033 - binary_accuracy: 0.9239 - val_loss: 0.2482 - val_binary_accuracy: 0.9080
# Epoch 12/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.1985 - binary_accuracy: 0.9261 - val_loss: 0.2525 - val_binary_accuracy: 0.9080
# Epoch 13/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.1945 - binary_accuracy: 0.9272 - val_loss: 0.2475 - val_binary_accuracy: 0.9079
# Epoch 14/15
# 180000/180000 [==============================] - 13s 71us/step - loss: 0.1902 - binary_accuracy: 0.9289 - val_loss: 0.2489 - val_binary_accuracy: 0.9080
# Epoch 15/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.1857 - binary_accuracy: 0.9306 - val_loss: 0.2521 - val_binary_accuracy: 0.9076
# Train AUC:  0.9289237560865701
# Vali AUC:  0.8395596641583634

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.2)(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train AUC:  0.8561410606774585
# Vali AUC:  0.8551038996236161

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_62 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_258 (Dense)            (None, 1028)              206628
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_259 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_260 (Dense)            (None, 1028)              1057812
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_261 (Dense)            (None, 1)                 1029
# =================================================================
# Total params: 2,323,281
# Trainable params: 2,323,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 7s 38us/step - loss: 18.3735 - binary_accuracy: 0.8982 - val_loss: 17.1159 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 15.9864 - binary_accuracy: 0.8995 - val_loss: 14.9044 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 13.9228 - binary_accuracy: 0.8995 - val_loss: 12.9817 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 12.1296 - binary_accuracy: 0.8995 - val_loss: 11.3113 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 10.5709 - binary_accuracy: 0.8995 - val_loss: 9.8589 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 9.2167 - binary_accuracy: 0.8995 - val_loss: 8.5965 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 8.0402 - binary_accuracy: 0.8995 - val_loss: 7.5001 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 7.0192 - binary_accuracy: 0.8996 - val_loss: 6.5489 - val_binary_accuracy: 0.8999
# Epoch 9/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 6.1329 - binary_accuracy: 0.9001 - val_loss: 5.7230 - val_binary_accuracy: 0.9008
# Epoch 10/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 5.3642 - binary_accuracy: 0.9013 - val_loss: 5.0068 - val_binary_accuracy: 0.9020
# Epoch 11/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 4.6965 - binary_accuracy: 0.9023 - val_loss: 4.3845 - val_binary_accuracy: 0.9034
# Epoch 12/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 4.1164 - binary_accuracy: 0.9035 - val_loss: 3.8443 - val_binary_accuracy: 0.9045
# Epoch 13/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 3.6123 - binary_accuracy: 0.9044 - val_loss: 3.3749 - val_binary_accuracy: 0.9052
# Epoch 14/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 3.1750 - binary_accuracy: 0.9048 - val_loss: 2.9674 - val_binary_accuracy: 0.9059
# Epoch 15/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 2.7947 - binary_accuracy: 0.9055 - val_loss: 2.6134 - val_binary_accuracy: 0.9063
# Train AUC:  0.8565613973539752
# Vali AUC:  0.855000719028537

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
