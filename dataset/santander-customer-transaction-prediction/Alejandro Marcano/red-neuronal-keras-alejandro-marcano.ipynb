# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['train.csv', 'test.csv', 'sample_submission.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_df.head()
#test_df.head()
# Out:
#    ID_code  target    var_0   var_1   ...     var_196  var_197  var_198  var_199
# 0  train_0       0   8.9255 -6.7863   ...      7.8784   8.5635  12.7803  -1.0914
# 1  train_1       0  11.5006 -4.1473   ...      8.1267   8.7889  18.3560   1.9518
# 2  train_2       0   8.6093 -2.7457   ...     -6.5213   8.2675  14.7222   0.3965
# 3  train_3       0  11.0604 -2.1518   ...     -2.9275  10.2922  17.9697  -8.9996
# 4  train_4       0   9.8369 -1.4834   ...      3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='glorot_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='glorot_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='glorot_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 17us/step - loss: 0.2601 - binary_accuracy: 0.9068 - val_loss: 0.2434 - val_binary_accuracy: 0.9114
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2311 - binary_accuracy: 0.9146 - val_loss: 0.2430 - val_binary_accuracy: 0.9114
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2206 - binary_accuracy: 0.9186 - val_loss: 0.2428 - val_binary_accuracy: 0.9120
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2047 - binary_accuracy: 0.9247 - val_loss: 0.2587 - val_binary_accuracy: 0.9058
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.1812 - binary_accuracy: 0.9335 - val_loss: 0.2756 - val_binary_accuracy: 0.9049
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.1499 - binary_accuracy: 0.9451 - val_loss: 0.3174 - val_binary_accuracy: 0.9078
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.1114 - binary_accuracy: 0.9594 - val_loss: 0.3463 - val_binary_accuracy: 0.8986
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0707 - binary_accuracy: 0.9750 - val_loss: 0.4130 - val_binary_accuracy: 0.8945
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0404 - binary_accuracy: 0.9864 - val_loss: 0.4759 - val_binary_accuracy: 0.8838
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0230 - binary_accuracy: 0.9931 - val_loss: 0.5483 - val_binary_accuracy: 0.8811
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0135 - binary_accuracy: 0.9965 - val_loss: 0.6219 - val_binary_accuracy: 0.8970
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0101 - binary_accuracy: 0.9974 - val_loss: 0.6676 - val_binary_accuracy: 0.8858
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0145 - binary_accuracy: 0.9952 - val_loss: 0.6846 - val_binary_accuracy: 0.8913
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0214 - binary_accuracy: 0.9922 - val_loss: 0.6910 - val_binary_accuracy: 0.8953
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.0196 - binary_accuracy: 0.9932 - val_loss: 0.6904 - val_binary_accuracy: 0.8859

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.9998194912582017
# Vali AUC:  0.7734696998608956

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='glorot_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='glorot_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='glorot_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [1028,1028,1028]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.9997139684078555
# Vali AUC:  0.7642194945229384

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [2056,2056]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.2639 - binary_accuracy: 0.9068 - val_loss: 0.2409 - val_binary_accuracy: 0.9120
# Epoch 2/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.2327 - binary_accuracy: 0.9134 - val_loss: 0.2413 - val_binary_accuracy: 0.9127
# Epoch 3/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.2247 - binary_accuracy: 0.9167 - val_loss: 0.2442 - val_binary_accuracy: 0.9115
# Epoch 4/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.2129 - binary_accuracy: 0.9215 - val_loss: 0.2509 - val_binary_accuracy: 0.9088
# Epoch 5/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1946 - binary_accuracy: 0.9293 - val_loss: 0.2642 - val_binary_accuracy: 0.9028
# Epoch 6/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1716 - binary_accuracy: 0.9378 - val_loss: 0.2844 - val_binary_accuracy: 0.9054
# Epoch 7/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1431 - binary_accuracy: 0.9480 - val_loss: 0.3315 - val_binary_accuracy: 0.9046
# Epoch 8/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1108 - binary_accuracy: 0.9590 - val_loss: 0.3702 - val_binary_accuracy: 0.8978
# Epoch 9/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.0746 - binary_accuracy: 0.9721 - val_loss: 0.4650 - val_binary_accuracy: 0.8897
# Epoch 10/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.0477 - binary_accuracy: 0.9829 - val_loss: 0.5507 - val_binary_accuracy: 0.8914
# Epoch 11/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.0304 - binary_accuracy: 0.9897 - val_loss: 0.6267 - val_binary_accuracy: 0.8904
# Epoch 12/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.0218 - binary_accuracy: 0.9930 - val_loss: 0.6996 - val_binary_accuracy: 0.8969
# Epoch 13/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.0200 - binary_accuracy: 0.9933 - val_loss: 0.7179 - val_binary_accuracy: 0.8936
# Epoch 14/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.0165 - binary_accuracy: 0.9946 - val_loss: 0.7931 - val_binary_accuracy: 0.8937
# Epoch 15/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.0186 - binary_accuracy: 0.9937 - val_loss: 0.7816 - val_binary_accuracy: 0.8923
# Train AUC:  0.9996951512969876
# Vali AUC:  0.7818986363347242

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [2056,2056]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2056)              413256
# _________________________________________________________________
# dense_12 (Dense)             (None, 2056)              4229192
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 2057
# =================================================================
# Total params: 4,644,505
# Trainable params: 4,644,505
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 18us/step - loss: 0.2606 - binary_accuracy: 0.9081 - val_loss: 0.2411 - val_binary_accuracy: 0.9124
# Epoch 2/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.2322 - binary_accuracy: 0.9141 - val_loss: 0.2419 - val_binary_accuracy: 0.9112
# Epoch 3/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.2245 - binary_accuracy: 0.9170 - val_loss: 0.2431 - val_binary_accuracy: 0.9118
# Epoch 4/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.2121 - binary_accuracy: 0.9228 - val_loss: 0.2507 - val_binary_accuracy: 0.9089
# Epoch 5/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1930 - binary_accuracy: 0.9302 - val_loss: 0.2615 - val_binary_accuracy: 0.9097
# Epoch 6/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1687 - binary_accuracy: 0.9393 - val_loss: 0.2833 - val_binary_accuracy: 0.9045
# Epoch 7/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1379 - binary_accuracy: 0.9494 - val_loss: 0.3335 - val_binary_accuracy: 0.9033
# Epoch 8/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.1088 - binary_accuracy: 0.9594 - val_loss: 0.4033 - val_binary_accuracy: 0.9019
# Epoch 9/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.0780 - binary_accuracy: 0.9708 - val_loss: 0.4639 - val_binary_accuracy: 0.8923
# Epoch 10/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.0497 - binary_accuracy: 0.9821 - val_loss: 0.5749 - val_binary_accuracy: 0.8912
# Epoch 11/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.0339 - binary_accuracy: 0.9882 - val_loss: 0.6554 - val_binary_accuracy: 0.8879
# Epoch 12/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.0247 - binary_accuracy: 0.9914 - val_loss: 0.6828 - val_binary_accuracy: 0.8849
# Epoch 13/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.0194 - binary_accuracy: 0.9935 - val_loss: 0.7410 - val_binary_accuracy: 0.8877
# Epoch 14/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.0175 - binary_accuracy: 0.9942 - val_loss: 0.7872 - val_binary_accuracy: 0.8923
# Epoch 15/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.0177 - binary_accuracy: 0.9939 - val_loss: 0.7952 - val_binary_accuracy: 0.8917
# Train AUC:  0.9994403486174142
# Vali AUC:  0.778460352489913

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.1)(inp)
    x=Dense(1028, activation="relu", kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.8)(x)
    x=Dense(1028, activation="relu", kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.00))(x)
    x=Dropout(0.8)(x)
    x=Dense(1, activation="sigmoid", kernel_initializer='glorot_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train AUC:  0.8522688894387217
# Vali AUC:  0.846607222365106

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 3.5434 - binary_accuracy: 0.8749 - val_loss: 3.2654 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 3.0581 - binary_accuracy: 0.8964 - val_loss: 2.8984 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 2.6819 - binary_accuracy: 0.8993 - val_loss: 2.5750 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 10us/step - loss: 2.3645 - binary_accuracy: 0.8995 - val_loss: 2.2900 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 2.0928 - binary_accuracy: 0.8995 - val_loss: 2.0364 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 1.8571 - binary_accuracy: 0.8995 - val_loss: 1.8128 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 1.6525 - binary_accuracy: 0.8995 - val_loss: 1.6210 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 1.4742 - binary_accuracy: 0.8995 - val_loss: 1.4546 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 1.3194 - binary_accuracy: 0.8995 - val_loss: 1.3039 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 1.1839 - binary_accuracy: 0.8995 - val_loss: 1.1710 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 1.0654 - binary_accuracy: 0.8995 - val_loss: 1.0565 - val_binary_accuracy: 0.8996
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.9615 - binary_accuracy: 0.8995 - val_loss: 0.9544 - val_binary_accuracy: 0.8996
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.8708 - binary_accuracy: 0.8995 - val_loss: 0.8658 - val_binary_accuracy: 0.8998
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.7920 - binary_accuracy: 0.8996 - val_loss: 0.7868 - val_binary_accuracy: 0.9007
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.7215 - binary_accuracy: 0.8997 - val_loss: 0.7179 - val_binary_accuracy: 0.9026
# Train AUC:  0.8507213434915497
# Vali AUC:  0.8451303930597154

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
