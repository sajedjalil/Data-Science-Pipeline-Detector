# %%
import numpy as np, pandas as pd
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from imblearn.ensemble import *
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import os
SEED = 13
np.random.seed(SEED)
# Out:
# Using TensorFlow backend.

# %%
# Load data
data = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

y_data = data['target']
x_data = data.drop(columns=['ID_code', 'target'])

y_data = y_data.astype('int8')
x_data = x_data.astype('float16')

print("data loaded")

# %%
# %%time

clf = BalancedRandomForestClassifier(n_estimators=500, 
                                     criterion='entropy', 
                                     n_jobs=-1)

print('fiting...')
clf.fit(x_data, y_data)

y_pred = clf.predict(x_data)
print('Score:', clf.score(x_data, y_data))
print('B Score:', metrics.balanced_accuracy_score(y_data, y_pred))
print('AUC Score:', metrics.roc_auc_score(y_data, y_pred))
# Out:
# fiting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# /opt/conda/lib/python3.6/site-packages/imbalanced_learn-0.5.0.dev0-py3.6.egg/imblearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     435                         s, t, self, X, y, sample_weight, i, len(trees),
#     436                         verbose=self.verbose, class_weight=self.class_weight)
# --> 437                     for i, (s, t) in enumerate(zip(samplers, trees)))
#     438             samplers, trees = zip(*samplers_trees)
#     439
#
# /opt/conda/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# /opt/conda/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
# Condusion Matrix
cnf_matrix = metrics.confusion_matrix(y_data, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-7eb98b380013> in <module>()
#       1 # Condusion Matrix
# ----> 2 cnf_matrix = metrics.confusion_matrix(y_data, y_pred)
#       3 p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
#       4 plt.title('Confusion matrix', y=1.1)
#       5 plt.ylabel('Actual label')
#
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [200000, 39999]

# %%
# Save outputc file
id_code = test.pop('ID_code')
test = test.astype('float16')
targets = clf.predict(test)
output = pd.DataFrame({'ID_code': id_code.values, 'target': targets})
output.to_csv('output.csv', index=False)
