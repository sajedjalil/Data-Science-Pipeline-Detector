# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3353 - binary_accuracy: 0.8974 - val_loss: 0.3156 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.3071 - binary_accuracy: 0.8995 - val_loss: 0.2979 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2890 - binary_accuracy: 0.8995 - val_loss: 0.2793 - val_binary_accuracy: 0.8996
# Epoch 4/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2710 - binary_accuracy: 0.8999 - val_loss: 0.2621 - val_binary_accuracy: 0.9010
# Epoch 5/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2562 - binary_accuracy: 0.9031 - val_loss: 0.2496 - val_binary_accuracy: 0.9067
# Epoch 6/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2469 - binary_accuracy: 0.9076 - val_loss: 0.2427 - val_binary_accuracy: 0.9102
# Epoch 7/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2421 - binary_accuracy: 0.9103 - val_loss: 0.2394 - val_binary_accuracy: 0.9121
# Epoch 8/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2397 - binary_accuracy: 0.9114 - val_loss: 0.2379 - val_binary_accuracy: 0.9129
# Epoch 9/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2384 - binary_accuracy: 0.9121 - val_loss: 0.2371 - val_binary_accuracy: 0.9130
# Epoch 10/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2376 - binary_accuracy: 0.9125 - val_loss: 0.2367 - val_binary_accuracy: 0.9138
# Epoch 11/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2370 - binary_accuracy: 0.9127 - val_loss: 0.2364 - val_binary_accuracy: 0.9137
# Epoch 12/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2365 - binary_accuracy: 0.9130 - val_loss: 0.2362 - val_binary_accuracy: 0.9141
# Epoch 13/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2360 - binary_accuracy: 0.9130 - val_loss: 0.2361 - val_binary_accuracy: 0.9143
# Epoch 14/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2355 - binary_accuracy: 0.9132 - val_loss: 0.2359 - val_binary_accuracy: 0.9144
# Epoch 15/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2351 - binary_accuracy: 0.9134 - val_loss: 0.2359 - val_binary_accuracy: 0.9143

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8566252703293826
# Vali AUC:  0.8540475499102598

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [1024,1024,2018,2048]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              205824
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_6 (Dense)              (None, 2018)              2068450
# _________________________________________________________________
# dense_7 (Dense)              (None, 2048)              4134912
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 7,460,835
# Trainable params: 7,460,835
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8635839981720321
# Vali AUC:  0.8550267008481771

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [4096,4096,2048,2048,2048]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 9s 51us/step - loss: 0.2958 - binary_accuracy: 0.8998 - val_loss: 0.2573 - val_binary_accuracy: 0.9069
# Epoch 2/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2486 - binary_accuracy: 0.9084 - val_loss: 0.2437 - val_binary_accuracy: 0.9103
# Epoch 3/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2409 - binary_accuracy: 0.9109 - val_loss: 0.2465 - val_binary_accuracy: 0.9104
# Epoch 4/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2370 - binary_accuracy: 0.9123 - val_loss: 0.2429 - val_binary_accuracy: 0.9095
# Epoch 5/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2335 - binary_accuracy: 0.9134 - val_loss: 0.2409 - val_binary_accuracy: 0.9106
# Epoch 6/15
# 180000/180000 [==============================] - 8s 43us/step - loss: 0.2299 - binary_accuracy: 0.9144 - val_loss: 0.2406 - val_binary_accuracy: 0.9103
# Epoch 7/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2267 - binary_accuracy: 0.9154 - val_loss: 0.2405 - val_binary_accuracy: 0.9106
# Epoch 8/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2233 - binary_accuracy: 0.9166 - val_loss: 0.2404 - val_binary_accuracy: 0.9107
# Epoch 9/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2200 - binary_accuracy: 0.9176 - val_loss: 0.2408 - val_binary_accuracy: 0.9109
# Epoch 10/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2166 - binary_accuracy: 0.9188 - val_loss: 0.2486 - val_binary_accuracy: 0.9059
# Epoch 11/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2127 - binary_accuracy: 0.9199 - val_loss: 0.2423 - val_binary_accuracy: 0.9101
# Epoch 12/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2086 - binary_accuracy: 0.9217 - val_loss: 0.2477 - val_binary_accuracy: 0.9065
# Epoch 13/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2037 - binary_accuracy: 0.9234 - val_loss: 0.2472 - val_binary_accuracy: 0.9064
# Epoch 14/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.1983 - binary_accuracy: 0.9253 - val_loss: 0.2457 - val_binary_accuracy: 0.9103
# Epoch 15/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.1932 - binary_accuracy: 0.9276 - val_loss: 0.2478 - val_binary_accuracy: 0.9105
# Train AUC:  0.923310204630025
# Vali AUC:  0.8428222146632042

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [4096,4096,2048,2048,2048]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 4096)              823296
# _________________________________________________________________
# dense_16 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dense_17 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dense_18 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_19 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 34,390,017
# Trainable params: 34,390,017
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 9s 50us/step - loss: 0.2936 - binary_accuracy: 0.9001 - val_loss: 0.2562 - val_binary_accuracy: 0.9080
# Epoch 2/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2481 - binary_accuracy: 0.9089 - val_loss: 0.2487 - val_binary_accuracy: 0.9105
# Epoch 3/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2414 - binary_accuracy: 0.9116 - val_loss: 0.2427 - val_binary_accuracy: 0.9120
# Epoch 4/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2373 - binary_accuracy: 0.9123 - val_loss: 0.2415 - val_binary_accuracy: 0.9106
# Epoch 5/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2335 - binary_accuracy: 0.9136 - val_loss: 0.2405 - val_binary_accuracy: 0.9123
# Epoch 6/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2301 - binary_accuracy: 0.9145 - val_loss: 0.2419 - val_binary_accuracy: 0.9103
# Epoch 7/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2269 - binary_accuracy: 0.9156 - val_loss: 0.2422 - val_binary_accuracy: 0.9121
# Epoch 8/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2236 - binary_accuracy: 0.9168 - val_loss: 0.2393 - val_binary_accuracy: 0.9118
# Epoch 9/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2201 - binary_accuracy: 0.9176 - val_loss: 0.2521 - val_binary_accuracy: 0.9047
# Epoch 10/15
# 180000/180000 [==============================] - 8s 43us/step - loss: 0.2168 - binary_accuracy: 0.9187 - val_loss: 0.2444 - val_binary_accuracy: 0.9125
# Epoch 11/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2126 - binary_accuracy: 0.9207 - val_loss: 0.2426 - val_binary_accuracy: 0.9098
# Epoch 12/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2085 - binary_accuracy: 0.9219 - val_loss: 0.2472 - val_binary_accuracy: 0.9126
# Epoch 13/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.2048 - binary_accuracy: 0.9232 - val_loss: 0.2425 - val_binary_accuracy: 0.9114
# Epoch 14/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.1998 - binary_accuracy: 0.9250 - val_loss: 0.2485 - val_binary_accuracy: 0.9122
# Epoch 15/15
# 180000/180000 [==============================] - 8s 42us/step - loss: 0.1941 - binary_accuracy: 0.9276 - val_loss: 0.2692 - val_binary_accuracy: 0.9102
# Train AUC:  0.921526311515853
# Vali AUC:  0.8405252088639625

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0)(inp)
    x=Dense(4096, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(4096, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(2048, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(2048, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)
    x=Dense(2048, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0)(x)  
    x=Dense(1, activation="sigmoid", bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
modelRF = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(modelRF.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(modelRF)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 4096)              823296
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 34,390,017
# Trainable params: 34,390,017
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.49786843149152016
# Vali AUC:  0.4861130976579028

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 4096)              823296
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 34,390,017
# Trainable params: 34,390,017
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 17s 96us/step - loss: 3.5132 - binary_accuracy: 0.9018 - val_loss: 0.2937 - val_binary_accuracy: 0.9136
# Epoch 2/15
# 180000/180000 [==============================] - 11s 62us/step - loss: 0.2868 - binary_accuracy: 0.9117 - val_loss: 0.2768 - val_binary_accuracy: 0.9154
# Epoch 3/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2758 - binary_accuracy: 0.9124 - val_loss: 0.2652 - val_binary_accuracy: 0.9152
# Epoch 4/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2717 - binary_accuracy: 0.9124 - val_loss: 0.2818 - val_binary_accuracy: 0.9076
# Epoch 5/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2693 - binary_accuracy: 0.9128 - val_loss: 0.2613 - val_binary_accuracy: 0.9139
# Epoch 6/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2665 - binary_accuracy: 0.9122 - val_loss: 0.2593 - val_binary_accuracy: 0.9147
# Epoch 7/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2662 - binary_accuracy: 0.9126 - val_loss: 0.2609 - val_binary_accuracy: 0.9156
# Epoch 8/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2645 - binary_accuracy: 0.9128 - val_loss: 0.2585 - val_binary_accuracy: 0.9146
# Epoch 9/15
# 180000/180000 [==============================] - 11s 62us/step - loss: 0.2636 - binary_accuracy: 0.9131 - val_loss: 0.2589 - val_binary_accuracy: 0.9153
# Epoch 10/15
# 180000/180000 [==============================] - 11s 62us/step - loss: 0.2628 - binary_accuracy: 0.9130 - val_loss: 0.2585 - val_binary_accuracy: 0.9138
# Epoch 11/15
# 180000/180000 [==============================] - 11s 62us/step - loss: 0.2622 - binary_accuracy: 0.9128 - val_loss: 0.2543 - val_binary_accuracy: 0.9163
# Epoch 12/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2612 - binary_accuracy: 0.9126 - val_loss: 0.2572 - val_binary_accuracy: 0.9163
# Epoch 13/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2601 - binary_accuracy: 0.9130 - val_loss: 0.2557 - val_binary_accuracy: 0.9153
# Epoch 14/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2592 - binary_accuracy: 0.9128 - val_loss: 0.2541 - val_binary_accuracy: 0.9155
# Epoch 15/15
# 180000/180000 [==============================] - 11s 61us/step - loss: 0.2598 - binary_accuracy: 0.9128 - val_loss: 0.2542 - val_binary_accuracy: 0.9155
# Train AUC:  0.8583956301408147
# Vali AUC:  0.8639120130310095

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
