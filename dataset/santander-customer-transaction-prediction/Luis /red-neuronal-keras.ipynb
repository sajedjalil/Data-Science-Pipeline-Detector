# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 14us/step - loss: 0.3358 - binary_accuracy: 0.8985 - val_loss: 0.3166 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.3079 - binary_accuracy: 0.8995 - val_loss: 0.2993 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2899 - binary_accuracy: 0.8995 - val_loss: 0.2813 - val_binary_accuracy: 0.8996
# Epoch 4/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2718 - binary_accuracy: 0.8999 - val_loss: 0.2645 - val_binary_accuracy: 0.9007
# Epoch 5/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2566 - binary_accuracy: 0.9032 - val_loss: 0.2526 - val_binary_accuracy: 0.9055
# Epoch 6/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2468 - binary_accuracy: 0.9078 - val_loss: 0.2461 - val_binary_accuracy: 0.9090
# Epoch 7/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2418 - binary_accuracy: 0.9105 - val_loss: 0.2433 - val_binary_accuracy: 0.9109
# Epoch 8/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2393 - binary_accuracy: 0.9115 - val_loss: 0.2421 - val_binary_accuracy: 0.9107
# Epoch 9/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2380 - binary_accuracy: 0.9121 - val_loss: 0.2416 - val_binary_accuracy: 0.9113
# Epoch 10/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2372 - binary_accuracy: 0.9124 - val_loss: 0.2415 - val_binary_accuracy: 0.9115
# Epoch 11/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2365 - binary_accuracy: 0.9124 - val_loss: 0.2413 - val_binary_accuracy: 0.9113
# Epoch 12/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2360 - binary_accuracy: 0.9128 - val_loss: 0.2412 - val_binary_accuracy: 0.9115
# Epoch 13/15
# 180000/180000 [==============================] - 1s 8us/step - loss: 0.2355 - binary_accuracy: 0.9128 - val_loss: 0.2411 - val_binary_accuracy: 0.9117
# Epoch 14/15
# 180000/180000 [==============================] - 2s 8us/step - loss: 0.2350 - binary_accuracy: 0.9131 - val_loss: 0.2411 - val_binary_accuracy: 0.9115
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2346 - binary_accuracy: 0.9132 - val_loss: 0.2410 - val_binary_accuracy: 0.9118

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8571551480703427
# Vali AUC:  0.8461697764650897

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [7,1000,1000]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.8532557835472145
# Vali AUC:  0.8441259101933358

# %%
arquitectura2 = [7,2000,2000]
model2 = func_model(arquitectura2)
#print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 2s 13us/step - loss: 0.4241 - binary_accuracy: 0.8954 - val_loss: 0.3301 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.3225 - binary_accuracy: 0.8995 - val_loss: 0.3169 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.3126 - binary_accuracy: 0.8995 - val_loss: 0.3076 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.3024 - binary_accuracy: 0.8995 - val_loss: 0.2969 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2910 - binary_accuracy: 0.8995 - val_loss: 0.2856 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2798 - binary_accuracy: 0.8995 - val_loss: 0.2754 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2700 - binary_accuracy: 0.8995 - val_loss: 0.2671 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2624 - binary_accuracy: 0.8995 - val_loss: 0.2611 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2569 - binary_accuracy: 0.8995 - val_loss: 0.2571 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2531 - binary_accuracy: 0.8995 - val_loss: 0.2545 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2504 - binary_accuracy: 0.8995 - val_loss: 0.2528 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2485 - binary_accuracy: 0.8995 - val_loss: 0.2516 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2470 - binary_accuracy: 0.8995 - val_loss: 0.2507 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2458 - binary_accuracy: 0.8995 - val_loss: 0.2499 - val_binary_accuracy: 0.8995
# Epoch 15/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2447 - binary_accuracy: 0.8995 - val_loss: 0.2493 - val_binary_accuracy: 0.8995
# Train AUC:  0.8552137824841879
# Vali AUC:  0.8450786506599852

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [7,2000,2000]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 7)                 1407
# _________________________________________________________________
# dense_13 (Dense)             (None, 2000)              16000
# _________________________________________________________________
# dense_14 (Dense)             (None, 2000)              4002000
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 2001
# =================================================================
# Total params: 4,021,408
# Trainable params: 4,021,408
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.4173 - binary_accuracy: 0.8986 - val_loss: 0.3242 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.3146 - binary_accuracy: 0.8995 - val_loss: 0.3085 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.3015 - binary_accuracy: 0.8995 - val_loss: 0.2963 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2892 - binary_accuracy: 0.8995 - val_loss: 0.2844 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2777 - binary_accuracy: 0.8995 - val_loss: 0.2740 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2680 - binary_accuracy: 0.8995 - val_loss: 0.2660 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2607 - binary_accuracy: 0.8995 - val_loss: 0.2603 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2555 - binary_accuracy: 0.8995 - val_loss: 0.2565 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2520 - binary_accuracy: 0.8995 - val_loss: 0.2541 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2495 - binary_accuracy: 0.8995 - val_loss: 0.2526 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2477 - binary_accuracy: 0.8995 - val_loss: 0.2515 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2463 - binary_accuracy: 0.8995 - val_loss: 0.2507 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2452 - binary_accuracy: 0.8995 - val_loss: 0.2500 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2441 - binary_accuracy: 0.8995 - val_loss: 0.2495 - val_binary_accuracy: 0.8995
# Epoch 15/15
# 180000/180000 [==============================] - 2s 11us/step - loss: 0.2432 - binary_accuracy: 0.8995 - val_loss: 0.2489 - val_binary_accuracy: 0.8995
# Train AUC:  0.8568842569982866
# Vali AUC:  0.8453836846893934

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.01)(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.5)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0.6)(x)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=None)(x)
    x=Dropout(0)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model3 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model3.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model3)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 1029
# =================================================================
# Total params: 2,323,281
# Trainable params: 2,323,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.5101234888701425
# Vali AUC:  0.5044159967256546

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1028)              206628
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1028)              1057812
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1028)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 1029
# =================================================================
# Total params: 2,323,281
# Trainable params: 2,323,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3908 - binary_accuracy: 0.9034 - val_loss: 0.2873 - val_binary_accuracy: 0.9117
# Epoch 2/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2855 - binary_accuracy: 0.9095 - val_loss: 0.2751 - val_binary_accuracy: 0.9123
# Epoch 3/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2753 - binary_accuracy: 0.9106 - val_loss: 0.2727 - val_binary_accuracy: 0.9120
# Epoch 4/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2712 - binary_accuracy: 0.9104 - val_loss: 0.2654 - val_binary_accuracy: 0.9111
# Epoch 5/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2694 - binary_accuracy: 0.9106 - val_loss: 0.2647 - val_binary_accuracy: 0.9120
# Epoch 6/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2672 - binary_accuracy: 0.9106 - val_loss: 0.2625 - val_binary_accuracy: 0.9133
# Epoch 7/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2664 - binary_accuracy: 0.9102 - val_loss: 0.2599 - val_binary_accuracy: 0.9137
# Epoch 8/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2652 - binary_accuracy: 0.9106 - val_loss: 0.2591 - val_binary_accuracy: 0.9120
# Epoch 9/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2647 - binary_accuracy: 0.9111 - val_loss: 0.2594 - val_binary_accuracy: 0.9115
# Epoch 10/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2641 - binary_accuracy: 0.9114 - val_loss: 0.2600 - val_binary_accuracy: 0.9127
# Epoch 11/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2634 - binary_accuracy: 0.9110 - val_loss: 0.2608 - val_binary_accuracy: 0.9129
# Epoch 12/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2631 - binary_accuracy: 0.9107 - val_loss: 0.2584 - val_binary_accuracy: 0.9138
# Epoch 13/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2622 - binary_accuracy: 0.9115 - val_loss: 0.2579 - val_binary_accuracy: 0.9133
# Epoch 14/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2618 - binary_accuracy: 0.9113 - val_loss: 0.2578 - val_binary_accuracy: 0.9121
# Epoch 15/15
# 180000/180000 [==============================] - 2s 12us/step - loss: 0.2615 - binary_accuracy: 0.9111 - val_loss: 0.2584 - val_binary_accuracy: 0.9133
# Train AUC:  0.8640503109278226
# Vali AUC:  0.8525742189552515

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
