# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
import gc

# %%
train_df = pd.read_csv('../input/train.csv') 
test_df = pd.read_csv('../input/test.csv') 
features = [c for c in train_df.columns if c not in ['ID_code', 'target']]
target = train_df.pop('target')
train_df.drop('ID_code',axis=1,inplace=True)
test_df.drop('ID_code',axis=1,inplace=True)

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.335,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.041,
    'learning_rate': 0.0083,
    'max_depth': -1,
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary',
    'verbosity': 1}

# %%
test_df['target'] = -1
train_df['i_am_train'] = 1
test_df['i_am_train'] = 0

full_df = pd.concat([train_df, test_df], axis=0)

# %%
full_df['var_20_counts'] = full_df['var_20'].map(full_df['var_20'].value_counts().to_dict())
full_df['var_155_counts'] = full_df['var_155'].map(full_df['var_155'].value_counts().to_dict())

full_df['var_198_counts'] = full_df['var_198'].map(full_df['var_198'].value_counts().to_dict())
full_df['var_191_counts'] = full_df['var_191'].map(full_df['var_191'].value_counts().to_dict())

full_df['var_177_counts'] = full_df['var_177'].map(full_df['var_177'].value_counts().to_dict())
full_df['var_88_counts'] = full_df['var_88'].map(full_df['var_88'].value_counts().to_dict())

full_df['var_116_counts'] = full_df['var_116'].map(full_df['var_116'].value_counts().to_dict())
full_df['var_4_counts'] = full_df['var_4'].map(full_df['var_4'].value_counts().to_dict())

# %%
full_df['var20_155_countdiff'] = full_df['var_20_counts'] - full_df['var_155_counts']
full_df['var198_191_countdiff'] = full_df['var_198_counts'] - full_df['var_191_counts']
full_df['var177_88_countdiff'] = full_df['var_177_counts'] - full_df['var_88_counts']
full_df['var116_4_countdiff'] = full_df['var_116_counts'] - full_df['var_4_counts']

# %%
train_df = full_df.loc[full_df['i_am_train']==1]
test_df = full_df.loc[full_df['i_am_train']==0]

del train_df['i_am_train'], test_df['i_am_train'], test_df['target'], full_df

# %%
# random_state= 44000
num_folds = 5
folds = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
oof = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))

# %%
train_df.head()
# Out:
#    target    var_0         ...          var177_88_countdiff  var116_4_countdiff
# 0     NaN   8.9255         ...                           -2                   3
# 1     NaN  11.5006         ...                            2                   2
# 2     NaN   8.6093         ...                           -6                   2
# 3     NaN  11.0604         ...                            2                  -7
# 4     NaN   9.8369         ...                           -5                  -5
#
# [5 rows x 213 columns]

# %%
features = [c for c in train_df.columns if c not in ['ID_code', 'target']]

# %%
print('Training the Model:')
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df.values, target.values)):
    print("Fold idx:{}".format(fold_ + 1))
    to_appends = []
    for i in range(9):
        np.random.seed(i)
        to_append_train = train_df.iloc[trn_idx].loc[target==1].copy().apply(np.random.permutation) # Shuffle each column
        to_appends.append(to_append_train)
    full_append = pd.concat(to_appends,axis=0)
    full_append['target'] = 1
    
    trn_data = lgb.Dataset(pd.concat([train_df.iloc[trn_idx][features],full_append[features]], axis=0), label=pd.concat([target.iloc[trn_idx],full_append['target']],axis=0))
    val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])
    clf = lgb.train(param, trn_data, 1000000, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 4000)
    oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
    predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits
print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
# Out:
#
# [4900]	training's auc: 0.914318	valid_1's auc: 0.897354
# [5000]	training's auc: 0.914637	valid_1's auc: 0.897505
# [5100]	training's auc: 0.914871	valid_1's auc: 0.897623
# [5200]	training's auc: 0.915057	valid_1's auc: 0.897731
# [5300]	training's auc: 0.91524	valid_1's auc: 0.897869
# [5400]	training's auc: 0.915553	valid_1's auc: 0.897969
# [5500]	training's auc: 0.91572	valid_1's auc: 0.898063
# [5600]	training's auc: 0.916083	valid_1's auc: 0.898181
# [5700]	training's auc: 0.916307	valid_1's auc: 0.898311
# [5800]	training's auc: 0.916549	valid_1's auc: 0.898427
# [5900]	training's auc: 0.916771	valid_1's auc: 0.898562
# [6000]	training's auc: 0.917239	valid_1's auc: 0.898621
# [6100]	training's auc: 0.917473	valid_1's auc: 0.898695
# [6200]	training's auc: 0.91786	valid_1's auc: 0.898772
# [6300]	training's auc: 0.918101	valid_1's auc: 0.898819
# [6400]	training's auc: 0.918719	valid_1's auc: 0.898914
# [6500]	training's auc: 0.918961	valid_1's auc: 0.89899
# [6600]	training's auc: 0.919146	valid_1's auc: 0.899111
# [6700]	training's auc: 0.919345	valid_1's auc: 0.899176
# [6800]	training's auc: 0.919496	valid_1's auc: 0.89923
# [6900]	training's auc: 0.919989	valid_1's auc: 0.899301
# [7000]	training's auc: 0.920193	valid_1's auc: 0.899383
# [7100]	training's auc: 0.920326	valid_1's auc: 0.899449
# [7200]	training's auc: 0.920461	valid_1's auc: 0.899534
# [7300]	training's auc: 0.920673	valid_1's auc: 0.899593
# [7400]	training's auc: 0.920972	valid_1's auc: 0.899663
# [7500]	training's auc: 0.921132	valid_1's auc: 0.899731
# [7600]	training's auc: 0.921303	valid_1's auc: 0.899801
# [7700]	training's auc: 0.921479	valid_1's auc: 0.899855
# [7800]	training's auc: 0.921634	valid_1's auc: 0.899925
# [7900]	training's auc: 0.921805	valid_1's auc: 0.899976
# [8000]	training's auc: 0.922178	valid_1's auc: 0.900013
# [8100]	training's auc: 0.922313	valid_1's auc: 0.900064
# [8200]	training's auc: 0.922459	valid_1's auc: 0.900109
# [8300]	training's auc: 0.922595	valid_1's auc: 0.900122
# [8400]	training's auc: 0.922739	valid_1's auc: 0.900158
# [8500]	training's auc: 0.922866	valid_1's auc: 0.900207
# [8600]	training's auc: 0.92308	valid_1's auc: 0.900221
# [8700]	training's auc: 0.923289	valid_1's auc: 0.900239

# %%
train_df = pd.read_csv('../input/train.csv', usecols=['ID_code','target']) 
test_df = pd.read_csv('../input/test.csv', usecols=['ID_code','var_0'])

# %%
sub = pd.DataFrame({"ID_code": test_df.ID_code.values})
sub["target"] = predictions
sub.to_csv('submission_upsampled.csv', index=False)

# %%
oofs = pd.DataFrame({"ID_code": train_df.ID_code.values})
oofs["target"] = oof
oofs.to_csv('oof_upsampled.csv', index=False)
