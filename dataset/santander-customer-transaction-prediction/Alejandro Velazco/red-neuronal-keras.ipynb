# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 17us/step - loss: 0.3390 - binary_accuracy: 0.8966 - val_loss: 0.3195 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.3110 - binary_accuracy: 0.8995 - val_loss: 0.3034 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2946 - binary_accuracy: 0.8995 - val_loss: 0.2865 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2775 - binary_accuracy: 0.8996 - val_loss: 0.2694 - val_binary_accuracy: 0.8999
# Epoch 5/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2617 - binary_accuracy: 0.9011 - val_loss: 0.2554 - val_binary_accuracy: 0.9034
# Epoch 6/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2502 - binary_accuracy: 0.9059 - val_loss: 0.2465 - val_binary_accuracy: 0.9080
# Epoch 7/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2436 - binary_accuracy: 0.9094 - val_loss: 0.2421 - val_binary_accuracy: 0.9104
# Epoch 8/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2404 - binary_accuracy: 0.9111 - val_loss: 0.2401 - val_binary_accuracy: 0.9115
# Epoch 9/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2388 - binary_accuracy: 0.9118 - val_loss: 0.2393 - val_binary_accuracy: 0.9118
# Epoch 10/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2378 - binary_accuracy: 0.9122 - val_loss: 0.2389 - val_binary_accuracy: 0.9117
# Epoch 11/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2371 - binary_accuracy: 0.9125 - val_loss: 0.2387 - val_binary_accuracy: 0.9120
# Epoch 12/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2366 - binary_accuracy: 0.9128 - val_loss: 0.2385 - val_binary_accuracy: 0.9119
# Epoch 13/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2361 - binary_accuracy: 0.9129 - val_loss: 0.2383 - val_binary_accuracy: 0.9119
# Epoch 14/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2356 - binary_accuracy: 0.9131 - val_loss: 0.2382 - val_binary_accuracy: 0.9120
# Epoch 15/15
# 180000/180000 [==============================] - 2s 9us/step - loss: 0.2351 - binary_accuracy: 0.9133 - val_loss: 0.2381 - val_binary_accuracy: 0.9117

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8566239639317672
# Vali AUC:  0.851091706558923

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [200,1200,1200 , 1200, 1200, 1200] 
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_5 (Dense)              (None, 1200)              241200
# _________________________________________________________________
# dense_6 (Dense)              (None, 1200)              1441200
# _________________________________________________________________
# dense_7 (Dense)              (None, 1200)              1441200
# _________________________________________________________________
# dense_8 (Dense)              (None, 1200)              1441200
# _________________________________________________________________
# dense_9 (Dense)              (None, 1200)              1441200
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1201
# =================================================================
# Total params: 6,047,401
# Trainable params: 6,047,401
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8564122271310297
# Vali AUC:  0.8495355767023692

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [200,1280, 1280, 1280, 1280, 1280]
model2 = func_model(arquitectura2)
print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dense_12 (Dense)             (None, 1280)              257280
# _________________________________________________________________
# dense_13 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_14 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_15 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_16 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 1281
# =================================================================
# Total params: 6,857,481
# Trainable params: 6,857,481
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 18us/step - loss: 0.3846 - binary_accuracy: 0.8946 - val_loss: 0.3251 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3218 - binary_accuracy: 0.8995 - val_loss: 0.3179 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3140 - binary_accuracy: 0.8995 - val_loss: 0.3095 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3044 - binary_accuracy: 0.8995 - val_loss: 0.2984 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2913 - binary_accuracy: 0.8995 - val_loss: 0.2834 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2750 - binary_accuracy: 0.8995 - val_loss: 0.2665 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2599 - binary_accuracy: 0.8995 - val_loss: 0.2544 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2510 - binary_accuracy: 0.8995 - val_loss: 0.2489 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2469 - binary_accuracy: 0.8995 - val_loss: 0.2464 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2446 - binary_accuracy: 0.8995 - val_loss: 0.2450 - val_binary_accuracy: 0.8996
# Epoch 11/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2430 - binary_accuracy: 0.9012 - val_loss: 0.2441 - val_binary_accuracy: 0.9042
# Epoch 12/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2417 - binary_accuracy: 0.9062 - val_loss: 0.2434 - val_binary_accuracy: 0.9090
# Epoch 13/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2405 - binary_accuracy: 0.9092 - val_loss: 0.2426 - val_binary_accuracy: 0.9102
# Epoch 14/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2394 - binary_accuracy: 0.9105 - val_loss: 0.2420 - val_binary_accuracy: 0.9106
# Epoch 15/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2384 - binary_accuracy: 0.9113 - val_loss: 0.2414 - val_binary_accuracy: 0.9116
# Train AUC:  0.8575837945078536
# Vali AUC:  0.8502791075196557

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = arquitectura2
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dense_19 (Dense)             (None, 1280)              257280
# _________________________________________________________________
# dense_20 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_21 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_22 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_23 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 1281
# =================================================================
# Total params: 6,857,481
# Trainable params: 6,857,481
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 19us/step - loss: 0.3835 - binary_accuracy: 0.8965 - val_loss: 0.3256 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3226 - binary_accuracy: 0.8995 - val_loss: 0.3186 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3152 - binary_accuracy: 0.8995 - val_loss: 0.3107 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.3063 - binary_accuracy: 0.8995 - val_loss: 0.3006 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2944 - binary_accuracy: 0.8995 - val_loss: 0.2869 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2792 - binary_accuracy: 0.8995 - val_loss: 0.2704 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2635 - binary_accuracy: 0.8995 - val_loss: 0.2567 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2531 - binary_accuracy: 0.8995 - val_loss: 0.2498 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2480 - binary_accuracy: 0.8995 - val_loss: 0.2469 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 0.2454 - binary_accuracy: 0.8995 - val_loss: 0.2454 - val_binary_accuracy: 0.8999
# Epoch 11/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 0.2436 - binary_accuracy: 0.9024 - val_loss: 0.2443 - val_binary_accuracy: 0.9045
# Epoch 12/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 0.2421 - binary_accuracy: 0.9065 - val_loss: 0.2435 - val_binary_accuracy: 0.9080
# Epoch 13/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2408 - binary_accuracy: 0.9090 - val_loss: 0.2428 - val_binary_accuracy: 0.9100
# Epoch 14/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2397 - binary_accuracy: 0.9101 - val_loss: 0.2421 - val_binary_accuracy: 0.9113
# Epoch 15/15
# 180000/180000 [==============================] - 3s 15us/step - loss: 0.2386 - binary_accuracy: 0.9110 - val_loss: 0.2416 - val_binary_accuracy: 0.9123
# Train AUC:  0.8571703459544664
# Vali AUC:  0.8493688450465847

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.1)(inp)
    x=Dense(200, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.15)(x)
    x=Dense(1280, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.25)(x)
    x=Dense(1280, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.4)(x)
    x=Dense(1280, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.5)(x)  
    x=Dense(1280, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros', kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.6)(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1280)              257280
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 1281
# =================================================================
# Total params: 5,217,801
# Trainable params: 5,217,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.857414792889117
# Vali AUC:  0.8555043570363857

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 200)               40200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1280)              257280
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_33 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1280)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1280)              0
# _________________________________________________________________
# dense_35 (Dense)             (None, 1280)              1639680
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1280)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 1281
# =================================================================
# Total params: 5,217,801
# Trainable params: 5,217,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 4s 23us/step - loss: 40.8835 - binary_accuracy: 0.8960 - val_loss: 38.0629 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 35.5289 - binary_accuracy: 0.8995 - val_loss: 33.1021 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 30.9024 - binary_accuracy: 0.8995 - val_loss: 28.7929 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 26.8836 - binary_accuracy: 0.8995 - val_loss: 25.0496 - val_binary_accuracy: 0.8995
# Epoch 5/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 23.3924 - binary_accuracy: 0.8995 - val_loss: 21.7982 - val_binary_accuracy: 0.8995
# Epoch 6/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 20.3594 - binary_accuracy: 0.8995 - val_loss: 18.9735 - val_binary_accuracy: 0.8995
# Epoch 7/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 17.7251 - binary_accuracy: 0.8995 - val_loss: 16.5194 - val_binary_accuracy: 0.8995
# Epoch 8/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 15.4352 - binary_accuracy: 0.8995 - val_loss: 14.3866 - val_binary_accuracy: 0.8995
# Epoch 9/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 13.4455 - binary_accuracy: 0.8995 - val_loss: 12.5338 - val_binary_accuracy: 0.8995
# Epoch 10/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 11.7170 - binary_accuracy: 0.8995 - val_loss: 10.9238 - val_binary_accuracy: 0.8995
# Epoch 11/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 10.2161 - binary_accuracy: 0.8995 - val_loss: 9.5261 - val_binary_accuracy: 0.8995
# Epoch 12/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 8.9123 - binary_accuracy: 0.8995 - val_loss: 8.3115 - val_binary_accuracy: 0.8995
# Epoch 13/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 7.7798 - binary_accuracy: 0.8995 - val_loss: 7.2573 - val_binary_accuracy: 0.8995
# Epoch 14/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 6.7969 - binary_accuracy: 0.8995 - val_loss: 6.3419 - val_binary_accuracy: 0.8995
# Epoch 15/15
# 180000/180000 [==============================] - 3s 16us/step - loss: 5.9426 - binary_accuracy: 0.8995 - val_loss: 5.5466 - val_binary_accuracy: 0.8995
# Train AUC:  0.8579677483863825
# Vali AUC:  0.8559823036015033

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
