# %% [markdown]
# # **Deep Neural Network con Keras**
#
# En este ejercicio se procede a realizar una Deep Neural Network con el Framework Keras, utilizando Tensorflow como Backend.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Input, Dense, BatchNormalization, Add, GaussianNoise, Dropout
from keras.models import Model
from sklearn.metrics import roc_auc_score
from keras.layers import Wrapper
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from keras import regularizers
import matplotlib.pyplot as plt
# Feature Scaling
from sklearn.preprocessing import StandardScaler
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %% [markdown]
# # 0. Funciones auxiliares.

# %%
precisiones_globales=[]
epochs = 15
def graf_model(train_history):
    f = plt.figure(figsize=(15,10))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)
    # summarize history for accuracy
    ax.plot(train_history.history['binary_accuracy'])
    ax.plot(train_history.history['val_binary_accuracy'])
    ax.set_title('model accuracy')
    ax.set_ylabel('accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    # summarize history for loss
    ax2.plot(train_history.history['loss'])
    ax2.plot(train_history.history['val_loss'])
    ax2.set_title('model loss')
    ax2.set_ylabel('loss')
    ax2.set_xlabel('epoch')
    ax2.legend(['train', 'test'], loc='upper left')
    plt.show()
def precision(model, registrar=False):
    y_pred = model.predict(train_dfX)
    train_auc = roc_auc_score(train_dfY, y_pred)
    y_pred = model.predict(val_dfX)
    val_auc = roc_auc_score(val_dfY, y_pred)
    print('Train AUC: ', train_auc)
    print('Vali AUC: ', val_auc)
    if registrar:
        precisiones_globales.append([train_auc,val_auc])

# %% [markdown]
# # 1. Importando los datos:
# Se procede a leer tanto el train.csv que es el conjunto de entrenamiento como el test.csv que es el conjunto de validacion. Mas adelante se construira en base a train.csv el conjunto de dev

# %%
train_df = pd.read_csv("../input/train.csv")
test_df = pd.read_csv("../input/test.csv")
print("Train shape : ",train_df.shape)
print("Test shape : ",test_df.shape)
# Out:
# Train shape :  (200000, 202)
# Test shape :  (200000, 201)

# %% [markdown]
# Se crea las variables X y Y con las que se van a entrenar al modelo.
# Tambien se elimina el ID_Code ya que no aporta valor al entrenamiento del modelo.

# %%
train_dfX = train_df.drop(['ID_code', 'target'], axis=1)
train_dfY = train_df['target']
submission = test_df[['ID_code']].copy()
test_df = test_df.drop(['ID_code'], axis=1)

# %% [markdown]
# # 2. Normalizando los valores de X
# Se transforma X de manera que quede normalizado todos su valores.

# %%
sc = StandardScaler()
train_dfX = sc.fit_transform(train_dfX)
test_df = sc.transform(test_df)

# %% [markdown]
# # 3. Separando Entrenamiento de Validacion
# Se divide X para tener un conjunto de entrenamiento y otro de validacion y pruebas. El 90% de las observaciones quedan en el conjunto de entrenamiento.

# %%
train_dfX,val_dfX,train_dfY, val_dfY = train_test_split(train_dfX,train_dfY , test_size=0.1, stratify=train_dfY)
print("Entrnamiento: ",train_dfX.shape)
print("Validacion : ",val_dfX.shape)
# Out:
# Entrnamiento:  (180000, 200)
# Validacion :  (20000, 200)

# %% [markdown]
# Aqui podemos ver como nuestra variable de entramiento train_dfX tiene 16200 observaciones y 200 caracteristicas. Es decir, la forma en la que ingresaremos datos a nuestro modelo sera (200, )

# %% [markdown]
# # 4. Creacion del modelo.

# %% [markdown]
# Vamos a definir una funcion que cree un modelo de red neuronal. Esta red va a tener 2 capaz ocultas con 1028 neuronas cada una. Se va a utilizar el optimizador SGD y la funcion de costo BinaryCrossEntropy. Los valores W del modelo se iniciaran de manera aleatoria y uniforme, los valores de b se iniciaran en cero.
#
# A tener en cuenta:
#
# Cual es el learning Rate de este modelo?

# %%
def func_model():   
    inp = Input(shape=(200,))
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)
    x=Dense(1028, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x) 
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model
model = func_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1028)              206628
# _________________________________________________________________
# dense_2 (Dense)              (None, 1028)              1057812
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1029
# =================================================================
# Total params: 1,265,469
# Trainable params: 1,265,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 5. Entrenamiento del modelo.
#
# Se entrenara el modelo con un batch_size de 512. Utilizando nuestras variables de validacion para seguir de cerca el accuracy tanto en entrenamiento como en validacion. Esto lo haremos por 20 epochs.

# %%
train_history = model.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 3s 14us/step - loss: 0.3381 - binary_accuracy: 0.8959 - val_loss: 0.3164 - val_binary_accuracy: 0.8995
# Epoch 2/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.3083 - binary_accuracy: 0.8995 - val_loss: 0.2999 - val_binary_accuracy: 0.8995
# Epoch 3/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2908 - binary_accuracy: 0.8995 - val_loss: 0.2829 - val_binary_accuracy: 0.8995
# Epoch 4/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2731 - binary_accuracy: 0.8998 - val_loss: 0.2669 - val_binary_accuracy: 0.9002
# Epoch 5/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2578 - binary_accuracy: 0.9025 - val_loss: 0.2552 - val_binary_accuracy: 0.9040
# Epoch 6/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2476 - binary_accuracy: 0.9073 - val_loss: 0.2489 - val_binary_accuracy: 0.9069
# Epoch 7/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2421 - binary_accuracy: 0.9103 - val_loss: 0.2461 - val_binary_accuracy: 0.9083
# Epoch 8/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2394 - binary_accuracy: 0.9116 - val_loss: 0.2451 - val_binary_accuracy: 0.9091
# Epoch 9/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2380 - binary_accuracy: 0.9122 - val_loss: 0.2448 - val_binary_accuracy: 0.9091
# Epoch 10/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2371 - binary_accuracy: 0.9127 - val_loss: 0.2447 - val_binary_accuracy: 0.9097
# Epoch 11/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2364 - binary_accuracy: 0.9129 - val_loss: 0.2446 - val_binary_accuracy: 0.9097
# Epoch 12/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2359 - binary_accuracy: 0.9129 - val_loss: 0.2446 - val_binary_accuracy: 0.9101
# Epoch 13/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2354 - binary_accuracy: 0.9131 - val_loss: 0.2446 - val_binary_accuracy: 0.9099
# Epoch 14/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2349 - binary_accuracy: 0.9131 - val_loss: 0.2445 - val_binary_accuracy: 0.9103
# Epoch 15/15
# 180000/180000 [==============================] - 1s 7us/step - loss: 0.2345 - binary_accuracy: 0.9133 - val_loss: 0.2444 - val_binary_accuracy: 0.9101

# %% [markdown]
# Vamos a ver una grafica de como se comporta nuestro modelo tanto en la perdida como en la precision (binary_accuracy).

# %%
graf_model(train_history)

# %% [markdown]
# # 6. Precision del modelo.
#
# En esta competencia la metrica utilizada para medir la precision de nuestro modelo es el AUC (referencia rapida: https://es.wikipedia.org/wiki/Curva_ROC). Por lo que vamos a estar bastante enfocados en mejorarla.
#
# La funcion precision() nos va a permitir, dado como parametro uno de nuestros modelos, imprimir el valor de AUC tanto del conjunto de entrenamiento como del de validacion.

# %%
precision(model, True)
# Out:
# Train AUC:  0.8574784712365472
# Vali AUC:  0.8431744418540982

# %% [markdown]
# # 7. Tamaño de la Red. (Evaluado)
#
# En este apartado vamos a estar revisando como el tamaño de la red afecta el desempeño de la misma. Vamos a experimentar utilizando distinta cantidad de capaz ocultas y de neuronas por capa.
#
# La variable arquitectura es una lista de Python que sirve como parametro de la funcion model(arquitectura) para definir una red neuronal con una cantidad len(arquitectura) de capaz ocultas, donde cada capa oculta l tiene una cantidad de neuronas arquitectura[l-1].
#
# Por ejemplo, de configurar la variable arquitectura  de forma [5,10,20] tendremos una red neuronal con 3 capaz ocultas, con 5, 10 y 20 capaz respectivamente.

# %%
def func_model(arquitectura): 
    first =True
    inp = Input(shape=(200,))
    for capa in arquitectura:        
        if first:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(inp)            
            first = False
        else:
            x=Dense(capa, activation="relu", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    x=Dense(1, activation="sigmoid", kernel_initializer='random_uniform', bias_initializer='zeros')(x)  
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento 1
#
# Juega con distintos tamaños de red para ver como esto afecta el desempeño del modelo (Vas a poder ver el impacto en las graficas de perdida, binary_accuracy y valor de AUC)
#
# Vas a poder comparar valores utilizando el Experimento 1 y 2 al mismo tiempo.

# %%
arquitectura1 = [2048, 2048, 512, 512, 1024, 1024]
model1 = func_model(arquitectura1)
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2048)              411648
# _________________________________________________________________
# dense_5 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 7,495,681
# Trainable params: 7,495,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train AUC:  0.8641515755228995
# Vali AUC:  0.8404203827997313

# %% [markdown]
# # Experimento 2

# %%
arquitectura2 = [4096, 4096, 4096, 2048, 2048, 2048]
model2 = func_model(arquitectura2)
print(model2.summary())
train_history_tam2 = model2.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tam2)
precision(model2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 4096)              823296
# _________________________________________________________________
# dense_12 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dense_13 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dense_14 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dense_15 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_16 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 51,171,329
# Trainable params: 51,171,329
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 13s 70us/step - loss: 0.2853 - binary_accuracy: 0.9021 - val_loss: 0.2581 - val_binary_accuracy: 0.9060
# Epoch 2/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2469 - binary_accuracy: 0.9095 - val_loss: 0.2542 - val_binary_accuracy: 0.9074
# Epoch 3/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2380 - binary_accuracy: 0.9120 - val_loss: 0.2514 - val_binary_accuracy: 0.9073
# Epoch 4/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2318 - binary_accuracy: 0.9142 - val_loss: 0.2508 - val_binary_accuracy: 0.9080
# Epoch 5/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2273 - binary_accuracy: 0.9154 - val_loss: 0.2591 - val_binary_accuracy: 0.9075
# Epoch 6/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2219 - binary_accuracy: 0.9174 - val_loss: 0.2527 - val_binary_accuracy: 0.9056
# Epoch 7/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2178 - binary_accuracy: 0.9190 - val_loss: 0.2519 - val_binary_accuracy: 0.9062
# Epoch 8/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2127 - binary_accuracy: 0.9205 - val_loss: 0.2558 - val_binary_accuracy: 0.9033
# Epoch 9/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2075 - binary_accuracy: 0.9223 - val_loss: 0.2532 - val_binary_accuracy: 0.9051
# Epoch 10/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2033 - binary_accuracy: 0.9241 - val_loss: 0.2538 - val_binary_accuracy: 0.9056
# Epoch 11/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.1980 - binary_accuracy: 0.9261 - val_loss: 0.2576 - val_binary_accuracy: 0.9081
# Epoch 12/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.1933 - binary_accuracy: 0.9278 - val_loss: 0.2593 - val_binary_accuracy: 0.9016
# Epoch 13/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.1871 - binary_accuracy: 0.9309 - val_loss: 0.2665 - val_binary_accuracy: 0.8968
# Epoch 14/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.1826 - binary_accuracy: 0.9328 - val_loss: 0.2909 - val_binary_accuracy: 0.9068
# Epoch 15/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.1804 - binary_accuracy: 0.9335 - val_loss: 0.2831 - val_binary_accuracy: 0.9079
# Train AUC:  0.9549874126984939
# Vali AUC:  0.8262068479171679

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
arquitecturaFinal = [4096, 4096, 4096, 2048, 2048, 2048]
modelF = func_model(arquitecturaFinal)
print(modelF.summary())
train_history_tamF = modelF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_tamF)
precision(modelF, True)
assert(len(precisiones_globales)==2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 200)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 4096)              823296
# _________________________________________________________________
# dense_19 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dense_20 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dense_21 (Dense)             (None, 2048)              8390656
# _________________________________________________________________
# dense_22 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_23 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 51,171,329
# Trainable params: 51,171,329
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 12s 68us/step - loss: 0.2925 - binary_accuracy: 0.9001 - val_loss: 0.2660 - val_binary_accuracy: 0.9042
# Epoch 2/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2485 - binary_accuracy: 0.9092 - val_loss: 0.2536 - val_binary_accuracy: 0.9062
# Epoch 3/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2395 - binary_accuracy: 0.9120 - val_loss: 0.2541 - val_binary_accuracy: 0.9071
# Epoch 4/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2337 - binary_accuracy: 0.9136 - val_loss: 0.2611 - val_binary_accuracy: 0.9064
# Epoch 5/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2283 - binary_accuracy: 0.9150 - val_loss: 0.2520 - val_binary_accuracy: 0.9064
# Epoch 6/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2242 - binary_accuracy: 0.9164 - val_loss: 0.2577 - val_binary_accuracy: 0.9073
# Epoch 7/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2195 - binary_accuracy: 0.9183 - val_loss: 0.2540 - val_binary_accuracy: 0.9052
# Epoch 8/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2151 - binary_accuracy: 0.9197 - val_loss: 0.2540 - val_binary_accuracy: 0.9069
# Epoch 9/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2097 - binary_accuracy: 0.9218 - val_loss: 0.2556 - val_binary_accuracy: 0.9046
# Epoch 10/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.2055 - binary_accuracy: 0.9238 - val_loss: 0.2725 - val_binary_accuracy: 0.9061
# Epoch 11/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.2001 - binary_accuracy: 0.9251 - val_loss: 0.2774 - val_binary_accuracy: 0.9063
# Epoch 12/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.1979 - binary_accuracy: 0.9268 - val_loss: 0.2576 - val_binary_accuracy: 0.9048
# Epoch 13/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.1921 - binary_accuracy: 0.9285 - val_loss: 0.2715 - val_binary_accuracy: 0.8935
# Epoch 14/15
# 180000/180000 [==============================] - 11s 59us/step - loss: 0.1873 - binary_accuracy: 0.9310 - val_loss: 0.2618 - val_binary_accuracy: 0.9049
# Epoch 15/15
# 180000/180000 [==============================] - 11s 60us/step - loss: 0.1827 - binary_accuracy: 0.9326 - val_loss: 0.2745 - val_binary_accuracy: 0.9065
# Train AUC:  0.9496477473654119
# Vali AUC:  0.8259387885475347

# %% [markdown]
# # 7. Regularizacion de la Red. (Evaluado)
#
# En el siguiente ejercicio vamos a experimentar con la regularizacion de nuestra red. La idea es que basado en la arquitectura "optima" que consiguieron en el apartado anterior empecemos a mejorar nuestro modelo.
#
# Vamos a experimentar con distintos valores para el P del DropOut y aplicando o no regularizacion L2 en las distintas capas. Para agregar regularizacion L2 a una capa se debe colocar regularizers.l2(0.01) como parametro en kernel_regularizer.

# %%
def func_model_reg():   
    inp = Input(shape=(200,))
    x=Dropout(0.1)(inp)
    x=Dense(2500, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x=Dropout(0.3)(x)
    x=Dense(2000, activation="relu", kernel_regularizer=None)(x)
    x=Dropout(0.3)(x)
    x=Dense(2000, activation="relu", kernel_regularizer=None)(x)
    x=Dropout(0.3)(x)
    x=Dense(1000, activation="relu", kernel_regularizer=None)(x)
    x=Dropout(0.3)(x)
    x=Dense(1000, activation="relu", kernel_regularizer=None)(x)
    x=Dropout(0.3)(x)
    x=Dense(1000, activation="relu", kernel_regularizer=None)(x)
    x=Dropout(0)(x)
    x=Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['binary_accuracy'])
    return model

# %% [markdown]
# # Experimento
#
# Prueba modificando la funcion de arriba para ver que resultados da sobre la precision.

# %%
model1 = func_model_reg()
#Para revisar la estructura del modelo, quitar el comentario de la instruccion siguiente:
#print(model1.summary())
train_history_tam1 = model1.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY), verbose=0)
graf_model(train_history_tam1)
precision(model1)
# Out:
# Train AUC:  0.8660826417038088
# Vali AUC:  0.846968534205017

# %% [markdown]
# # Resultado Final
#
# Elije una arquitectura de red que te permita tener el valor de AUC mas alto que puedas lograr
#
#  **Ejecuta esta celda 1 sola vez con la arquitectura final elegida en los experimentos anteriores**

# %%
modelRF = func_model_reg()
print(modelRF.summary())
train_history_regF = modelRF.fit(train_dfX, train_dfY, batch_size=512, epochs=epochs, validation_data=(val_dfX, val_dfY))
graf_model(train_history_regF)
precision(modelRF, True)
assert(len(precisiones_globales)==3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 200)               0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 2500)              502500
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 2500)              0
# _________________________________________________________________
# dense_61 (Dense)             (None, 2000)              5002000
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 2000)              0
# _________________________________________________________________
# dense_62 (Dense)             (None, 2000)              4002000
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 2000)              0
# _________________________________________________________________
# dense_63 (Dense)             (None, 1000)              2001000
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_64 (Dense)             (None, 1000)              1001000
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_65 (Dense)             (None, 1000)              1001000
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_66 (Dense)             (None, 1)                 1001
# =================================================================
# Total params: 13,510,501
# Trainable params: 13,510,501
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 180000 samples, validate on 20000 samples
# Epoch 1/15
# 180000/180000 [==============================] - 7s 41us/step - loss: 0.4659 - binary_accuracy: 0.9013 - val_loss: 0.2868 - val_binary_accuracy: 0.9060
# Epoch 2/15
# 180000/180000 [==============================] - 5s 30us/step - loss: 0.2867 - binary_accuracy: 0.9075 - val_loss: 0.2726 - val_binary_accuracy: 0.9093
# Epoch 3/15
# 180000/180000 [==============================] - 5s 30us/step - loss: 0.2764 - binary_accuracy: 0.9076 - val_loss: 0.2685 - val_binary_accuracy: 0.9098
# Epoch 4/15
# 180000/180000 [==============================] - 5s 30us/step - loss: 0.2708 - binary_accuracy: 0.9086 - val_loss: 0.2632 - val_binary_accuracy: 0.9097
# Epoch 5/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2680 - binary_accuracy: 0.9088 - val_loss: 0.2631 - val_binary_accuracy: 0.9108
# Epoch 6/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2659 - binary_accuracy: 0.9092 - val_loss: 0.2604 - val_binary_accuracy: 0.9097
# Epoch 7/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2650 - binary_accuracy: 0.9088 - val_loss: 0.2598 - val_binary_accuracy: 0.9113
# Epoch 8/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2642 - binary_accuracy: 0.9093 - val_loss: 0.2599 - val_binary_accuracy: 0.9087
# Epoch 9/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2624 - binary_accuracy: 0.9092 - val_loss: 0.2566 - val_binary_accuracy: 0.9104
# Epoch 10/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2629 - binary_accuracy: 0.9094 - val_loss: 0.2588 - val_binary_accuracy: 0.9092
# Epoch 11/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2621 - binary_accuracy: 0.9089 - val_loss: 0.2569 - val_binary_accuracy: 0.9122
# Epoch 12/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2605 - binary_accuracy: 0.9097 - val_loss: 0.2568 - val_binary_accuracy: 0.9093
# Epoch 13/15
# 180000/180000 [==============================] - 5s 30us/step - loss: 0.2606 - binary_accuracy: 0.9099 - val_loss: 0.2548 - val_binary_accuracy: 0.9106
# Epoch 14/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2599 - binary_accuracy: 0.9096 - val_loss: 0.2569 - val_binary_accuracy: 0.9091
# Epoch 15/15
# 180000/180000 [==============================] - 5s 29us/step - loss: 0.2597 - binary_accuracy: 0.9094 - val_loss: 0.2570 - val_binary_accuracy: 0.9107
# Train AUC:  0.8672201317705432
# Vali AUC:  0.8498209204118375
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-0915a45dda66> in <module>()
#       4 graf_model(train_history_regF)
#       5 precision(modelRF, True)
# ----> 6 assert(len(precisiones_globales)==3)
#
# AssertionError:

# %% [markdown]
# # Modelo Final.
#
# Juega con el modelo y genera el mejor valor de AUC que puedas lograr.

# %% [markdown]
# # Salida de datos.
#
# Con esta celda se exportaran los datos.

# %%
y_test = modelRF.predict(test_df)
submission['target'] = y_test
submission.to_csv('submission.csv', index=False)
