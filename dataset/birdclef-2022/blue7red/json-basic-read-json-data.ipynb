# %%
import pandas as pd
import json
from pandas import json_normalize

# %%
SCORED_BIRDS_JSON = "../input/birdclef-2022/scored_birds.json"

# %% [markdown]
# # 1.read original json data

# %%
with open(SCORED_BIRDS_JSON) as json_file:
    scored_json = json.load(json_file)
    
scored_json

# %% [markdown]
# # 2.read json data as pandas DataFrame

# %%
scored_birds_df = pd.read_json(SCORED_BIRDS_JSON)

scored_df = pd.DataFrame()
scored_df["bird_type"] = scored_birds_df[0]
scored_df
