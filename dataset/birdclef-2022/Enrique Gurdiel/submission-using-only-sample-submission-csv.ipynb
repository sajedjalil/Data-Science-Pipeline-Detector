# %% [markdown]
# ### Imports and environment variables

# %%
import pandas as pd

datapath="../input/birdclef-2022"

# %% [markdown]
# ### Prepare testing data

# %%
submission=pd.read_csv(datapath+'/'+'sample_submission.csv')

# %% [markdown]
# ### Load model

# %%
def naive(row_id):
    return True

# %% [markdown]
# ### Update target using pd.apply()

# %%
submission['target']=submission.apply(
    lambda row: naive(row.row_id) , axis=1)

# %% [markdown]
# ### Write csv

# %%
submission.to_csv('submission.csv',header=True, index=False)

# %% [markdown]
# ### Conclusion
# You get .48 returning all values to False (same as just saving sample_submission.csv as it is)
#
# Interestingly you get .51 by returning all values to True
#
# It seems to me this is the intended way to proceed, I share because it was unclear to me
