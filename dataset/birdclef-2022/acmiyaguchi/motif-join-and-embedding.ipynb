# %%
! pip install \
    --no-index \
    --find-links=/kaggle/input/model-sync/pip-packages/ \
    birdclef

# %%
! python -m birdclef.workflows.classify_nn predict \
    --birdclef-root ../input/birdclef-2022 \
    --classifier-source ../input/model-sync/classify-nn/0.13.0-202205222347 \
    --method top-not-noise \
    submission.csv
