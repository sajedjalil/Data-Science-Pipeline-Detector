# %% [markdown]
# # Introduction
# I found the noisereduce package in Jira Borovec's notebook: https://www.kaggle.com/jirkaborovec/birdclef-convert-spectrograms-noise-reduce
# This is a very useful package but the normal pip install command doesn't work without Internet connection. So I created a dataset wich contains this package so you can also add it to your kernel.
#
# You can add the package to your kernel if you click on Add data and look for noisereduce noisereduce 2.0.0.
# ![](https://goew.eu/kaggle/bird_clef_2022/noisereduce.png)

# %% [markdown]
# # Example

# %%
# !pip install '../input/noisereduce-2-0-0/noisereduce-2.0.0-py3-none-any.whl'

# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio

# %% [markdown]
# ## Original data

# %%
test_soundscape = '../input/birdclef-2022/test_soundscapes/soundscape_453028782.ogg'
Audio(test_soundscape)

# %%
y, sr = librosa.load(test_soundscape, sr=32000, offset=None)

# %%
X = librosa.stft(y.astype('float'))
Xdb = librosa.amplitude_to_db(X)
plt.figure(figsize=(12, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.show()

# %% [markdown]
# ## Noise reduction

# %%
import noisereduce as nr

# %%
reduced_noise = nr.reduce_noise(y=y, sr=32000)
Audio(reduced_noise, rate=32000)

# %%
X = librosa.stft(reduced_noise.astype('float'))
Xdb = librosa.amplitude_to_db(X)
plt.figure(figsize=(12, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.show()
