# %% [markdown]
# # Summary of Code/Discussion that I, as a beginner, have found helpful
# （初心者である私が参考にさせていただいたCode/Discussionのまとめ）

# %% [markdown]
# Thank you for opening this Code.
#
# This is not a Code, but 'Summary of Code/Discussion referred to by **beginner**'.
#
# I'm a Japanese Kaggle begineer, so  I would not have been able to participate in this competition without Code/Discussion.
#
# If you are also a person similar to me, this Summary would help you.
#
# このCodeを開いていただきありがとうございます。
#
# これはCodeではなく、「**初心者**である私が参考にさせていただいたCode/Discussionのまとめ」です。
#
# 私は日本人のKaggle初心者であるため、Code/Discussionなしでは、このコンペに参加することはできませんでした。
#
# もし同じような方であれば、このSummaryはお役に立てるのではないかと思っています。

# %% [markdown]
# ## Outline of this competiton（コンペの概要を掴む）

# %% [markdown]
# * https://www.kaggle.com/pixyz0130/ump-baseline-lgbm-english/notebook
#
#   Outline translated from Japanese
#
#   概要の日本語訳

# %% [markdown]
# ### Objectives of this competiton（コンペの目的を把握）

# %% [markdown]
# * https://www.kaggle.com/c/ubiquant-market-prediction/discussion/303397

# %% [markdown]
# ## File expansion（ファイルの展開）

# %% [markdown]
# * https://www.kaggle.com/robikscube/fast-data-loading-and-low-mem-with-parquet-files
#
#   Quickly and with less memory to extract files.
#
#   早くかつ少ないメモリでファイルを展開できる

# %% [markdown]
# ## EDA

# %% [markdown]
# * https://www.kaggle.com/lucamassaron/eda-target-analysis

# %% [markdown]
# ## Baseline

# %% [markdown]
# * https://www.kaggle.com/ilialar/ubiquant-eda-and-baseline
#
#   Baseline by Lightgbm
#
#   Lightgbmによるベースライン

# %% [markdown]
# →I read that visualization of f0~299 would come in handy later on, so I did it.
#
# →f0~299の可視化が後々活きてくると書いてあったのでやってみた
#
# https://www.kaggle.com/mk1001/eda-f-0-299-histogram

# %% [markdown]
# ## Valuation index（評価指標）

# %% [markdown]
# * https://www.kaggle.com/c/ubiquant-market-prediction/discussion/302181
#
#   Reference material on this evaluation index "correlation coefficient"
#
#   今回の評価指標「相関係数」に関する参考資料

# %% [markdown]
# * https://www.kaggle.com/c/ubiquant-market-prediction/discussion/301987
#
#   Code

# %% [markdown]
# ## Submission（提出）

# %% [markdown]
# * https://www.kaggle.com/jiprud/simple-light-gbm#3.-Submission

# %% [markdown]
# Thank you for reading to the end.
#
# We hope this Summary is helpful.
#
# 最後までお読みいただきありがとうございました。
#
# このSummaryがお役に立てれば幸いです。
#
# ---
#
# I will add to this page as needed.
#
# 随時加筆していく予定です。
