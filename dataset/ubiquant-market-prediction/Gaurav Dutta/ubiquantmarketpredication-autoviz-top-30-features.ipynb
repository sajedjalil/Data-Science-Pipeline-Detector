# %%
import pandas as pd
train=pd.read_pickle('../input/ump195gb/train.pkl')
train.head()

# %%
train=train.drop(['row_id','time_id','investment_id'],axis=1)
train.head()

# %%
train.info()

# %%
# !pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline
AV = AutoViz_Class()
df = AV.AutoViz(filename='',dfte=train,depVar='target',verbose=0,max_rows_analyzed=50000)
