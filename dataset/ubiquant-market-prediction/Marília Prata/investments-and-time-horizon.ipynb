# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.graph_objs as go
import plotly.offline as py

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ![](https://corepathways.georgetown.edu/wp-content/uploads/2020/05/xobkagxotot01-Henry-Silver.jpg)corepathways.georgetown.edu

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: white;"><b style="color:#00008B;">Ubiquant Investment - Time Horizon and Investiments</b></h1></center>
#
# "Ubiquant Investment is a hedge fund manager that was founded in 2012. The firm is headquartered in Beijing and it has offices in Shenzhen and Shanghai. The firm's investment strategy is mainly quantitative trading using high-frequency trading strategies with a focus on domestic and overseas markets."
#
# https://www.preqin.com/data/profile/fund-manager/ubiquant-investment/371760

# %% [markdown]
# ![](https://zenprospect-production.s3.amazonaws.com/uploads/pictures/61b193d0a5c89c0001837741/picture)apollo.io

# %% [markdown]
# #Thanks to Ernnnn4u for the Dataset  https://www.kaggle.com/ernnnn4u/ubiquant?select=train.feather

# %%
train=pd.read_feather('../input/ubiquant/train.feather')
train.head()

# %%
nRow, nCol = train.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# #Oh My Memory is so Screwed

# %%
train.isnull().sum()

# %% [markdown]
# #Time is the most critical aspect of investing.
#
# "Time is the most critical aspect of investing. Understanding one’s personal time horizons and the ability to stay invested for the longest time possible allows the magic of compounding to make you rich,” Satyen Kothari's words.
#
# https://outlookmoney.com/investment/importance-of-time-horizon-in-investment-3237

# %%
# Could be any column: No, only numeric data.
train['time_id'].plot()
plt.title('time_id', fontsize=20);

# %% [markdown]
# #"Time horizon of an investment is nothing but length of time investor aims to hold investment before selling it."
#
# "Time is an indication of how much risk an investor is exposed to. In a long time horizon an investor can take more risk since the market has a chance to bounce back even if it falls. “
#
# "Assume that you are investing to build a corpus for down payment of your house in another 2 years. In this case your TIME HORIZON would be 2 years, and in such a case it is best to invest in bank FDs or debt funds. The rate of return is lower, but they are assured."
#
# https://outlookmoney.com/investment/importance-of-time-horizon-in-investment-3237

# %%
# Could be any column: No, only numeric data.
train['investment_id'].plot(color='r')
plt.title('investment_id', fontsize=20);

# %% [markdown]
# #Investments and Time Horizon
#
# "Investing in long-term goals like retirement, the time horizon is much larger and investing in equities directly or mutual funds can yield higher returns because market volatilities even out over a period of time."
#
# "The time horizon of an investment is nothing but the length of time an investor aims to hold an investment before selling it. The time horizon of the investment is important for several reasons. When the term horizon is short, an investor is exposed to more risk. However, when the time horizon is long an investor can take more risk since the market has a chance to bounce back even if it falls."
#
# https://outlookmoney.com/investment/importance-of-time-horizon-in-investment-3237

# %%
# Could be any column: No, only numeric data.
train['f_0'].plot(color='g')
plt.title('f_0', fontsize=20);

# %%
# Could be any column: No, only numeric data.
train['f_1'].plot(color='purple')
plt.title('f_1', fontsize=20);

# %% [markdown]
# #Long time Goals.
#
# "With a goal that is 10 or more years away, investing in aggressive equity funds can reap benefits for the investor. The aggressive investor may also consider small and mid-cap funds."
#
# https://outlookmoney.com/investment/importance-of-time-horizon-in-investment-3237

# %%
# Could be any column: No, only numeric data.
train['f_299'].plot(color='orange')
plt.title('f_299', fontsize=20);

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(train['target'])
plt.axvline(train['target'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Target Distribution');

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('Time Id Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(train['time_id'], hist=True, rug=False,norm_hist=True, color='brown');

# %% [markdown]
# #Inspired by the Petit Prince: It could be a Snake, Hat, Pinball or even Time of the Investment(above).
#
# ![](https://res.cloudinary.com/teepublic/image/private/s--5LmLDEJZ--/c_crop,x_10,y_10/c_fit,w_1109/c_crop,g_north_west,h_945,w_1260,x_-76,y_-67/co_rgb:ffffff,e_colorize,u_Misc:One%20Pixel%20Gray/c_scale,g_north_west,h_945,w_1260/fl_layer_apply,g_north_west,x_-76,y_-67/bo_180px_solid_white/e_overlay,fl_layer_apply,h_945,l_Misc:Art%20Print%20Bumpmap,w_1260/e_shadow,x_6,y_6/c_limit,h_1134,w_1134/c_lpad,g_center,h_1260,w_1260/b_rgb:eeeeee/c_limit,f_jpg,h_630,q_90,w_630/v1549833531/production/designs/4177714_0.jpg)teepublic.com

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(train['investment_id'], color = 'g')
plt.axvline(train['investment_id'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Investment Id Distribution');

# %%
#Code by Firat Gonen https://www.kaggle.com/frtgnn/elo-eda-lgbm/notebook 

plt.figure(figsize=(10, 6))
plt.title('F 299 Distribution')
sns.despine()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

sns.distplot(train['f_299'], hist=True, rug=False,norm_hist=True, color='yellow');

# %%
train.groupby('investment_id').count()['time_id'].plot()
plt.title('Investment Id', fontsize=20);
plt.tight_layout()

# %%
train.groupby('time_id').count()['investment_id'].plot(color='r')
plt.title('Time id', fontsize=20);
plt.tight_layout()

# %% [markdown]
# #Time and Money
#
# "All the projects you want to perform in your life will require the utilization of time and money. Both resources are often limited and usually shared by all your projects, so it’s necessary to manage them with good judgement to make the most of them."
#
# "Though money is much more tangible and, therefore, easier to handle.
#
# https://facilethings.com/blog/en/time-as-asset

# %% [markdown]
# ![](https://i.pinimg.com/originals/33/25/24/3325245cc3c57c08cf98515e8caa59a8.jpg)pinterest.com
#
#
# #Now my time is up with No Investments.
