# %% [markdown]
# # Step 1. **Mount your google cloud drive in colab.**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Step 2. **Access to your predefined directories.**

# %%
input_folder = '/content/drive/MyDrive/ubiquant-market-prediction-half-precision-pickle/input/'
output_folder = '/content/drive/MyDrive/ubiquant-market-prediction-half-precision-pickle/output/'

# %%
import pandas as pd

train = pd.read_pickle(train_file)

# %% [markdown]
# # Step 3. **Train your models similar to how you did with Kaggle Notebook.**

# %% [markdown]
# # Step 4. **Save models to your google cloud drive.**

# %%
import keras

checkpoint = keras.callbacks.ModelCheckpoint(
    output_folder+f"model_{index}",
    save_best_only=True,
    monitor='val_loss',
    mode='min')

# %% [markdown]
# # Step 5. **Download the models from cloud drive.**

# %% [markdown]
#  * ## Direct upload the models from colab to Kaggle using Kaggle API (Tips from @valley).

# %%
# !mkdir -p /root/.kaggle

import json, os
token = {"username":"xxxxxx","key":"xxxxxxxxxxxxxxxxxxxxxxxxxxx"}
with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# !pip install --upgrade --force-reinstall --no-deps kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle -v

# %%
import json

title = 'xxxxxx'
slug = '{username}/{title}'

meta_file = './data/dataset-metadata.json'

with open(meta_file, "r") as f:
    data = json.load(f)
    data['title'] = title
    data['id'] = slug

with open(meta_file, "w") as f:
    json.dump(data, f)

# !kaggle datasets create -p data               # create a new dataset
# !kaggle datasets version -p data -m "xxxxxx"  # update the dataset
