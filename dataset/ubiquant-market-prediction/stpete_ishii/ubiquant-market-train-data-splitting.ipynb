# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ```
# data0=pd.read_csv('../input/ubiquant-market-prediction/train.csv', nrows=1000000) # SUCCESS,MAX
# data0=pd.read_csv('../input/ubiquant-market-prediction/train.csv', nrows=1200000) # MLE
# data0=pd.read_csv('../input/ubiquant-market-prediction/train.csv', chunksize=100) # SUCCESS
# ```

# %%
data0=pd.read_csv('../input/ubiquant-market-prediction/train.csv', chunksize=100) 
print(type(data0))

# %%
data0a=data0.get_chunk(900000)
data0a.to_csv('train0a.csv',index=False)
print(data0a.index)
del data0a

# %%
data0b=data0.get_chunk(900000)
data0b.to_csv('train0b.csv',index=False)
print(data0b.index)
del data0b

# %%
data0c=data0.get_chunk(900000)
data0c.to_csv('train0c.csv',index=False)
print(data0c.index)
del data0c

# %%
data0d=data0.get_chunk(900000)
data0d.to_csv('train0d.csv',index=False)
print(data0d.index)
del data0d
