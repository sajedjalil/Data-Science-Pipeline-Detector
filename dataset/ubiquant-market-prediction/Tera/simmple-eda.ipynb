# %% [markdown]
# ## Let's get started simmple EDA

# %% [markdown]
# 2022/01/22.
# Hello everyone. Nice to meet you. I am going to challenge this competition.
# I am still a beginner, but  will try my best to achieve good results.
# I will be challenging myself over the next three months, and upload the my code.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import time

import dask.dataframe as dd
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# I use this datasets https://www.kaggle.com/columbia2131/ump-train-picklefile
# I appreciate this owner.

# %%
# %%time
train = pd.read_pickle('../input/ump-train-picklefile/train.pkl')

# %%
train.head()

# %%
train.tail()

# %%
train.columns.values

# %%
train.shape

# %%
train.info()

# %%
train_null = train.isnull().sum()
train_null.values

# %% [markdown]
# ### My notice
# ### No missing values

# %%
train.describe()

# %%
train["time_id"].value_counts().sort_index()

# %% [markdown]
# ### My notice
# ### time_id is **not continuous**.

# %%
train["investment_id"].value_counts().sort_index()

# %% [markdown]
# ### My notice
# ### investment_id is **not continuous too**.

# %%
train["target"].nunique()

# %%
train["target"]

# %%
fig = plt.figure(figsize=(16, 10))
sns.displot(train['target'])
plt.show()

# %% [markdown]
# The target appears to be normally distributed.

# %%
train["target"].describe().apply(lambda x: format(x, 'f'))

# %% [markdown]
# data columns [f_0:f_299](https://www.kaggle.com/c/ubiquant-market-prediction/data) are anonymized features generated from market data.
# so first, I think except for these data.

# %%
simmple_train = train[['row_id','time_id', 'investment_id', 'target']]
simmple_train

# %%
simmple_train['row_id'].str.contains('1219_')

# %%
simmple_train[simmple_train['row_id'].str.contains('1219_')]

# %%
simmple_train[simmple_train['row_id'].str.contains('1209_')]

# %%
simmple_train[simmple_train['row_id'].str.contains('1109_')]

# %%
feature_col = [col for col in train.columns if 'f_' in col]
train[feature_col]

# %% [markdown]
# What I think so far is that
# - Need to find row_id time_id investment_id
# - Need to examine special features of f_.
# - Since this is a [code compensation](https://www.kaggle.com/c/ubiquant-market-prediction/overview/code-requirements), need an algorithm to make the process as fast as possible.

# %% [markdown]
# As per the theory, check test.csv and submission.csv at the end.

# %%
test = pd.read_csv('../input/ubiquant-market-prediction/example_test.csv')
test

# %%
submission = pd.read_csv('../input/ubiquant-market-prediction/example_sample_submission.csv')
submission

# %% [markdown]
# ##### I will now perform data preprocessing and exploration.
# ##### I look forward to working with you all for a long time.
# ##### Have a good day. Thank you dear all.
