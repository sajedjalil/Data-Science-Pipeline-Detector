# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql import functions as F
import pandas as pd
spark = SparkSession.builder.enableHiveSupport().appName('ubiquant').getOrCreate()
sc = spark.sparkContext

# %%
df = spark.read.csv("../input/ubiquant-market-prediction/train.csv", inferSchema=True, header=True)

# %%
df.show(1)

# %%
df.dtypes[: 30]

# %%
df.printSchema()

# %%
df.describe()

# %%
df.count()

# %%
df.groupBy("investment_id").count().orderBy(["count"], ascending=[0]).show()

# %%
df2 = df.filter(df.target > 0.1).select('investment_id', 'target')
df2.groupBy("investment_id").count().orderBy(["count"], ascending=[0]).show()
