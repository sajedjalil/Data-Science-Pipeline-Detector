# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# final result test

import ubiquant
env = ubiquant.make_env()   # initialize the environment
iter_test = env.iter_test()    # an iterator which loops over the test set and sample submission
for (test_df, sample_prediction_df) in iter_test:
    sample_prediction_df['target'] = 0  # make your predictions here
    env.predict(sample_prediction_df)   # register your predictions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import gc

# %%
sample_in=pd.read_csv('../input/ubiquant-market-prediction/example_test.csv')
sample_in

# %%
sample_in.info()

# %%
sample_out=pd.read_csv('../input/ubiquant-market-prediction/example_sample_submission.csv')
sample_out

# %%
sample_out.info()

# %%
data_check=pd.read_csv('../input/ubiquant-market-prediction/train.csv',chunksize=1000).get_chunk(10)
data_check.info()

# %%
#check the datatype of int columns
def int_fit(d):
    dmax=max(d)
    dmin=min(d)
    if dmax >np.iinfo(np.int32).max or dmin <np.iinfo(np.int32).min:
        dtype='int64'
    elif dmax >np.iinfo(np.int16).max or dmin <np.iinfo(np.int16).min:
        dtype='int32'
    elif dmax >np.iinfo(np.int8).max or dmin <np.iinfo(np.int8).min:
        dtype='int16'
    else:
        dtype='int8'
    return dtype
    
    
with pd.read_csv('../input/ubiquant-market-prediction/train.csv',chunksize=10000) as reader:
    int_type1='int8'
    int_type2='int8'
    for chunk in reader:
        
        dtype1=int_fit(chunk['time_id'])
        dtype2=int_fit(chunk['investment_id'])
        
        if int(int_type1[3:])<int(dtype1[3:]):
            int_type1=dtype1 
        if int(int_type2[3:])<int(dtype2[3:]):
            int_type2=dtype２

print(int_type1,int_type2)
del reader
gc.collect()

# %%
#read csv and save as pickle
columns=data_check.columns
del data_check
gc.collect()

type_dict={'row_id':object,'time_id':np.int16,'investment_id':np.int16}
for i in range(3,304):
    type_dict[columns[i]]=np.float16
df=pd.read_csv('../input/ubiquant-market-prediction/train.csv',dtype=type_dict)

# %%
len(set(df['investment_id']))

# %%
df.to_pickle('train.pickle')
