# %%
import pandas as pd
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import os
import gc
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup
from nltk.stem import WordNetLemmatizer
import warnings
warnings.filterwarnings('ignore')
train =True

# %%
#%%capture
#'''
data_types_dict = {
    'time_id': 'int32',
    'investment_id': 'int16',
    "target": 'float16',
}

features = [f'f_{i}' for i in range(300)]

for f in features:
    data_types_dict[f] = 'float16'
    
target = 'target'


train = pd.read_csv('/kaggle/input/ubiquant-market-prediction/train.csv', 
                       usecols = data_types_dict.keys(),
                       dtype=data_types_dict, 
                       index_col = 0)

train = train.reset_index()
train
#'''

# %%
# %%capture
'''
test = pd.read_csv('../input/ubiquant-market-prediction/example_test.csv')
sub = pd.read_csv('../input/ubiquant-market-prediction/example_sample_submission.csv')
'''

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import accuracy_score
#!pip install optuna
import optuna 
import optuna.integration.lightgbm as lgbo

# %% [markdown]
# # Train

# %%
# %%capture
'''
models={}
for i in tqdm(x_train.investment_id.unique()):	
    train_x =x_train[x_train.investment_id == i]
    model = lgb.LGBMRegressor(n_estimators=150)
    train_x = train_x.reset_index()
    y=  train_x['target']
    X=  train_x.drop(['target'],axis=1)
    model.fit(X,y)
    models[i] =model
    '''

# %% [markdown]
# # ALL

# %%
models={}
for i in tqdm(train.investment_id.unique()):	
    train_x =train[train.investment_id == i]
    model = lgb.LGBMRegressor(n_estimators=150)
    y=  train_x['target']
    X=  train_x.drop(['target','time_id'],axis=1)
    
    model.fit(X,y)
    models[i] =model

# %%
# %%capture
'''
models={}
for i in tqdm(train.investment_id.unique()):	
    train_x =train[train.investment_id == i]
    model = lgb.LGBMRegressor(n_estimators=150)
    train_x = train_x.reset_index()
    y=  train_x['target']
    X=  train_x.drop(['target','time_id'],axis=1)
    model.fit(X,y)
    models[i] =model
    '''

# %%
import pickle
with open('models', 'wb') as web:
    pickle.dump(models, web)

# %% [markdown]
# # Validation

# %%
'''
pred = []
for i in tqdm(y_train.investment_id.unique()):
    
    test_x =y_train[y_train.investment_id == i]
    test_x = test_x.reset_index(drop=True)
    y=  test_x['target']
    X=  test_x.drop(['target'],axis=1)
    
    pred.append(models[i].predict(X))
    '''

# %%
'''
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_train.target.values, pred)
'''
