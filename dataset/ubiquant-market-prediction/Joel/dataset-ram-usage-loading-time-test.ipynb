# %% [markdown]
# # Different version of dataset ram usage and loading time
# - **Half precision pkl**: https://www.kaggle.com/lonnieqin/ubiquant-market-prediction-half-precision-pickle
#
#  CPU times: user 552 ms,   sys: 2.17 s,   **total: 2.73 s,   Wall time: 17.2 s**
#
#  Ram usage: **2.3Gi**
#
# - **32 bit feather**: https://www.kaggle.com/slawekbiel/ubiquant-trainfeather-32-bit
#
#  CPU times: user 6.38 s,   sys: 13.8 s,   **total: 20.2 s,   Wall time: 35.5 s**
#
#  Ram usage: **4.1Gi**
#
#
#  - **Normal pkl**: https://www.kaggle.com/columbia2131/ump-train-picklefile
#
#  CPU times: user 1.63 s,   sys: 7.17 s,   **total: 8.8 s,   Wall time: 43.7 s**
#
#  Ram usage: **4.3Gi**
#
#  - **Low memory parquet**: https://www.kaggle.com/currypurin/ubiquant-parquet-low-mem
#
#  CPU times: user 9.88 s,   sys: 19 s,   **total: 28.9 s,   Wall time: 41.5 s**
#
#  Ram usage: **4.4Gi**

# %%
# %%time
import pandas as pd
train = pd.read_feather('../input/ubiquant-trainfeather-32-bit/train32.feather')

# %%
# !free -h

# %%
# %%time
import pandas as pd
train = pd.read_pickle('../input/ump-train-picklefile/train.pkl')

# %%
# !free -h

# %%
# %%time
import pandas as pd
train = pd.read_parquet('../input/ubiquant-parquet-low-mem/train_low_mem.parquet')

# %%
# !free -h

# %%
# %%time
import pandas as pd
train = pd.read_pickle('../input/ubiquant-market-prediction-half-precision-pickle/train.pkl')

# %%
# !free -h
