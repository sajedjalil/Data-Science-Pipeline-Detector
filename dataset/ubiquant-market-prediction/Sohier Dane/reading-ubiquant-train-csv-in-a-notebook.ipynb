# %%
import pandas as pd

# %%
df = pd.DataFrame()
with pd.read_csv('../input/ubiquant-market-prediction/train.csv', chunksize=10**5) as reader:
    for counter, chunk in enumerate(reader):
        print(counter, flush=True)
        df = pd.concat([df, chunk])

# %%
df.head()

# %% [raw]
# For more details, see https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#iterating-through-files-chunk-by-chunk
