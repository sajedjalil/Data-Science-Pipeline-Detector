# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# Lets read the Training data.

# %%
Train=pd.read_csv('/kaggle/input/airbnb-recruiting-new-user-bookings/train_users_2.csv.zip')

# %% [markdown]
# Now,lets check the columns and rows that we have in our data.

# %%
Train

# %% [markdown]
# We can see that there are 213451 rows and 16 columns.

# %% [markdown]
# Lets check how much the different signup methods have been used.

# %%
Train['signup_method'].value_counts()

# %% [markdown]
# Now,we will check the the amount of Airbnb customers on the basis of their Gender.
# We can see here that Females are more likely to use Airbnb.

# %%
Train['gender'].value_counts()

# %% [markdown]
# As we can see that we have numerous amount of not assigned data.
# Many users have not defined their booking dates,account creation dates,Destination and it can become a roadblock in our analysis.So,we will drop these data to make more fruitful analysis.

# %%
Train['date_first_booking'].dropna(inplace=True)

# %%
Train.dropna(inplace=True)

# %%
Train

# %% [markdown]
# Reset the index.

# %%
Train.reset_index(drop=True,inplace=True)

# %%
Train

# %% [markdown]
# Import Matplotlib for the visualisations.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Lets check the Matplotlib version we are using.

# %%
import matplotlib as mpl
print ('Matplotlib version: ', mpl.__version__)

# %%
mpl.style.use(['ggplot'])

# %% [markdown]
# Lets see how many people are visiting the different countries.

# %%
Train['country_destination'].value_counts()

# %% [markdown]
# I am going to visualize a bar graph for the Customers who are using Airbnb according to their genders.
# We can clearly see that Airbnb is being used by Females mostly.

# %%
Train.gender.value_counts().plot(kind='bar')

# %% [markdown]
# Lets get some stastical info about the age column.

# %%
Train['age'].describe()

# %% [markdown]
# Here we will see how many users have entered their age above 135.
# More than 75% people have registered their age as 2014,which must be because of some misunderstanding.

# %%
Train[Train.age>135]['age'].describe()

# %% [markdown]
# Lets check how many people have registered their age below 18yrs.
# We can see the average age for this set of people is around 9yrs,which is very low and the minimum age is 2 years which is quite impossible.
# More than 75% users in this set are above 15yrs which can be accepted.

# %%
Train[Train.age<18]['age'].describe()

# %% [markdown]
# So,I will just nullify the users who have registered below 15 years.

# %%
Train.loc[Train.age<15,'age']=np.nan

# %% [markdown]
# As we can check over google that 122 is the longest living person.
# So,I will just nullify the users who have registered themselves above 122years.

# %%
Train.loc[Train.age>122,'age']=np.nan

# %%
Train.dropna(inplace=True)

# %%
Train.shape

# %%
men=sum(Train.gender=='MALE')
women=sum(Train.gender=='FEMALE')

# %% [markdown]
# Lets see the percentage of Females and Males visiting Different Countries.

# %%
Fav_F_Dest=Train.loc[Train.gender=='FEMALE','country_destination'].value_counts()/women *100
Fav_M_Dest=Train.loc[Train.gender=='MALE','country_destination'].value_counts()/men*100
width=0.4
Fav_F_Dest.plot(kind='bar',label='Female',color='b',position=0,width=width)
Fav_M_Dest.plot(kind='bar',label='Male',color='g',position=1,width=width)
plt.legend()

# %% [markdown]
# The percentages are nearly same so Gender can't decide the customer's preferences.

# %%
Train['country_destination'].value_counts()

# %% [markdown]
# We will go through a distribution plot to see how differently aged persons are using Airbnb.
# We can see that people aged between 30-40 are mostly using Airbnb.

# %%
import seaborn as sns
sns.distplot(Train['age'])

# %% [markdown]
# I will check now what is preference in terms of Countries for Younger and older people.

# %%
young=sum(Train.age<40)
old=sum(Train.age>40)
Young_dest=Train.loc[Train.age<40,'country_destination'].value_counts()/young *100
Old_dest=Train.loc[Train.age>40,'country_destination'].value_counts()/old * 100
Young_dest.plot(kind='bar',color='b',position=0,width=width,label='Younger')
Old_dest.plot(kind='bar',color='g',position=1,width=width,label='Older')
plt.legend()

# %% [raw]
# For US, People below 40 are more likely to visit but the Older public are also showing their keen interest.
# For France, People who are aged above 40 are more likely to visit.
# For rest of the countries the percentages are somewhat equal.

# %% [markdown]
# I am going to change the Data Type of First Booking Date columns to a Date-Time datatype.

# %%
Train['date_first_booking'] = pd.to_datetime(Train['date_first_booking'])

# %%
Train['date_first_booking'].dtype

# %% [markdown]
# Slicing the data for the users who have booked in the year of 2014 and 2015.

# %%
dest_2014_=Train.loc[Train.date_first_booking > pd.to_datetime(20140101,format='%Y%m%d')]

# %%
dest_2014_['date_first_booking'].value_counts().plot(kind='line')

# %% [markdown]
# We can see higher number of people where booking in the first six months of the Year 2014 because we dont have the data of people creating their accounts from the second half of the year.
# You will see that below.

# %%
dest_2014_=dest_2014_.loc[dest_2014_.date_first_booking<pd.to_datetime(20150101,format='%Y%m%d')]

# %% [raw]
# For the year 2014 only.

# %%
dest_2014_['date_first_booking'].value_counts().plot(kind='line')

# %% [markdown]
# Now,we will check the Account Created dates for the year 2014.

# %%
Train['date_account_created'] = pd.to_datetime(Train['date_account_created'])

# %%
Train['date_account_created'].dtype

# %%
acc_2014=Train.loc[Train.date_account_created>pd.to_datetime(20140101,format='%Y%m%d')]

# %%
acc_2014=acc_2014.loc[acc_2014.date_account_created<pd.to_datetime(20150101,format='%Y%m%d')]

# %%
acc_2014['date_account_created'].value_counts().plot(kind='line')

# %% [raw]
# Here,we can see that we have the data of users creating their account only till the first half of 2014 in the Training Data.

# %%
acc_2014

# %% [markdown]
# We will plot a line graph for the people creating their accounts and booking them for the year of 2014.
# We can see that at the start the account creation was very good but the bookings were low but gradually it increased after couple of months and was quite high in the month of June and July.

# %%
acc_2014['date_account_created'].value_counts().plot(kind='line',label='account created')
dest_2014_['date_first_booking'].value_counts().plot(kind='line',label='bookings')
plt.legend()

# %% [markdown]
# As we dont have complete data for 2014,we will also check the trends in 2013.

# %%
dest_2013_=Train.loc[Train.date_first_booking>pd.to_datetime(20130101,format='%Y%m%d')]

# %%
dest_2013_=dest_2013_.loc[dest_2013_.date_first_booking<pd.to_datetime(20140101,format='%Y%m%d')]

# %%
acc_2013=Train.loc[Train.date_account_created>pd.to_datetime(20130101,format='%Y%m%d')]

# %%
acc_2013=acc_2013.loc[acc_2013.date_account_created<pd.to_datetime(20140101,format='%Y%m%d')]

# %%
dest_2013_['date_first_booking'].value_counts().plot(kind='line',color='b',label='bookings',figsize=(20,10))
acc_2013['date_account_created'].value_counts().plot(kind='line',color='r',label='accounts created',figsize=(20,10))
plt.legend()

# %% [markdown]
# The booking and account creation graph for the years 2010 to 2015.

# %%
Train['date_first_booking'].value_counts().plot(kind='line',color='b',label='bookings',figsize=(20,10))
Train['date_account_created'].value_counts().plot(kind='line',color='r',label='accounts created',figsize=(20,10))
plt.legend()

# %%
dest_2013_US=dest_2013_.loc[dest_2013_.country_destination=='US']
dest_2013_US

# %% [markdown]
# **Trends of the Year 2013 for the users visiting US**

# %%
dest_2013_US['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# People are more likely to book in US from the month of June till the year end.

# %%
dest_2013_FR=dest_2013_.loc[dest_2013_.country_destination=='FR']

# %% [markdown]
# **Trends of the Year 2013 for the users visiting France**

# %%
dest_2013_FR['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Italy**

# %%
dest_2013_IT=dest_2013_.loc[dest_2013_.country_destination=='IT']

# %%
dest_2013_IT['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# Here if we will see the graph minutely,we can see that the Users are more likely to book for Italy in the month of April to July.

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Great Britain**

# %%
dest_2013_GB=dest_2013_.loc[dest_2013_.country_destination=='GB']
dest_2013_GB['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# The frequency of users visiting Great Britain in the month of June is quite good.

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Spain**

# %%
dest_2013_ES=dest_2013_.loc[dest_2013_.country_destination=='ES']
dest_2013_ES['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# The frequency of users visiting spain is quite better from the month of March to August.
# The best is between June to August.

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Canada**

# %%
dest_2013_CA=dest_2013_.loc[dest_2013_.country_destination=='CA']
dest_2013_CA['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# The users are mainly visiting after March to late November.As from December the winter season starts for Canada and it lasts till March.

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Germany**

# %%
dest_2013_DE=dest_2013_.loc[dest_2013_.country_destination=='DE']
dest_2013_DE['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Netherlands**

# %%
dest_2013_NL=dest_2013_.loc[dest_2013_.country_destination=='NL']
dest_2013_NL['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Australia**

# %%
dest_2013_AU=dest_2013_.loc[dest_2013_.country_destination=='AU']
dest_2013_AU['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# **Trends of the Year 2013 for the users visiting Portugal**

# %%
dest_2013_PT=dest_2013_.loc[dest_2013_.country_destination=='PT']
dest_2013_PT['date_first_booking'].value_counts().plot(kind='line',figsize=(20,10))

# %% [markdown]
# **Comparison of visitors for different Countries for the year 2013**

# %%
x=(30,25)
dest_2013_US['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='US')
dest_2013_PT['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Portugal')
dest_2013_AU['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Australia')
dest_2013_NL['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Netherlands')
dest_2013_DE['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Germany')
dest_2013_CA['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Canada')
dest_2013_ES['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Spain')
dest_2013_GB['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Great Britain')
dest_2013_IT['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='Italy')
dest_2013_FR['date_first_booking'].value_counts().plot(kind='line',figsize=x,label='France')
plt.legend()

# %% [markdown]
# With all of these visualisations,we can see that the Users are more inclined towards US and bookings are done mostly after the month of May in the case of US.
# People who are younger than 40 are more inclined towards US but the older people are also very keen comparitively.
# Rest,I have also made some insights for the different countries above.
# These insights can help in marketing for the different countries for the different months.
# Feedback is appreciated!!
