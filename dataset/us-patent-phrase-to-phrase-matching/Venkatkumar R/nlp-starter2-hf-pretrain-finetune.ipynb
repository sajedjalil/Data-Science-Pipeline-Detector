# %% [markdown]
# # <h1><center><b> Part-2: U.S. Patent Phrase to Phrase Matching - Transformer</b></center></h1>
#
# ## <center>My learning process of transformer followed by this dicussion (below link)</center>
#
# ### <center>https://www.kaggle.com/competitions/us-patent-phrase-to-phrase-matching/discussion/320962</center>
#
# ## **Now I learn in hugging face (Text data), This notebook fully followed by NLP with transformer book and hugging face course**
#
#
#
# <img src='https://i.ytimg.com/vi/C6eehLgLADs/maxresdefault.jpg'>
#
#
#
#
#
#
#
# ### **Hello Guys! This is my first competition Based on NLP --> Two members(Me and my friend Edoziem Enyinnaya)**
#
# ## ***I try to apply the concept in Competition data later! Now learn Transformers***
#
# ### ***I am trying in Coming weeks (below the content) of part 2 and finally apply the concepts in Competition data | If anyone interested in the process suggest your idea and topics guys***
#
# ## **Part 1: https://www.kaggle.com/code/venkatkumar001/nlp-starter-almost-all-basic-concept**
#
# ### **1. Data Cleaning and Preprocessing:**
#
# - Data-Punctuations,stopwords,number,caseconversion (Remove noise)
# - word normalization(stemming,tokenization,lemmatization,POS,NER)
# - word standartization(tables,regularexp)--> Clean text data
#
# ### **2. Text Representation and word_Embedding:**
#
# - BOW
# - TF-IDF
# - Word-Embedding (word2vec,doc2vec,Glove)
# - TSNE visualization
#
# ## **Part 2: https://www.kaggle.com/venkatkumar001/nlp-starter-transformer-pipeline**
#
# ### **Transformer**
#
# - NLP with transforer book & Hugging face course

# %% [markdown]
# # <center>Hugging Face</center>
#
# <img src = 'https://analyticsindiamag.com/wp-content/uploads/2021/06/Hugging-Face-1024x694.jpg'>
#
# # **1. Hello transformer**
#
# <img src = 'https://github.com/nlp-with-transformers/notebooks/raw/c2db380169af910eed0ca5c61b7882f3caa18cf3//images/chapter01_timeline.png'>
#
# To understand what is novel about transformers,we first need to explain:
#
# • The encoder-decoder framework:
#
# The job of the encoder is to encode the information from the input sequence into a numerical representation that is often called the last hidden state. This state is then passed to the decoder, which generates the output sequence.
#
# <img src = 'https://github.com/nlp-with-transformers/notebooks/raw/c2db380169af910eed0ca5c61b7882f3caa18cf3//images/chapter01_enc-dec.png'>
#
# • Attention mechanisms:
#
#
# The idea behind the attention mechanism was to permit the decoder to utilize the most relevant parts of the input sequence in a flexible manner, by a weighted combination of all of the encoded input vectors, with the most relevant vectors being attributed the highest weights
#
# <img src = 'https://github.com/nlp-with-transformers/notebooks/raw/c2db380169af910eed0ca5c61b7882f3caa18cf3//images/chapter01_enc-dec-attn.png'>
#
# • Transfer learning
#
# Transfer learning is first build model large amount of data and train then the model weights used for our usecase
#
# <img src = 'https://github.com/nlp-with-transformers/notebooks/raw/c2db380169af910eed0ca5c61b7882f3caa18cf3//images/chapter01_transfer-learning.png'>
#
# This image credit: NLP with transformer book

# %% [markdown]
# # ***Now little experiment in Hugging face using Pipeline API***
#
# Hugging face: Already build the model and finetune throught the transformer. This pipeline command single line command predict the result. Let see!
#
# ## ***Pipeline API: The pipelines are a great and easy way to use models for inference. These pipelines are objects that abstract most of the complex code from the library***
#
# <img src='https://github.com/nlp-with-transformers/notebooks/raw/c2db380169af910eed0ca5c61b7882f3caa18cf3//images/chapter01_hf-ecosystem.png'>
#
# 1. Text classification
# 2. Name Entity Recognition
# 3. Question and Answering
# 4. Summarization
# 5. Translation
#
# I will try one application guys! Its awesome

# %% [markdown]
# # **Install the Hugging face transformer**

# %%
# install Hugging face transformer
# !pip install transformers

# %% [markdown]
# ## **1.1: Pipline - Text classification**
#
# All are know text classification! this package used to just two line to predict output

# %%
import pandas as pd
import numpy as np
from transformers import pipeline

# Input data

## This input is negative command so output is negative

text = """Dear Amazon, last week I ordered an Optimus Prime action figure \
from your online store in Germany. Unfortunately, when I opened the package, \
I discovered to my horror that I had been sent an action figure of Megatron \
instead! As a lifelong enemy of the Decepticons, I hope you can understand my \
dilemma. To resolve the issue, I demand an exchange of Megatron for the \
Optimus Prime figure I ordered. Enclosed are copies of my records concerning \
this purchase. I expect to hear from you soon. Sincerely, Bumblebee."""

#pipeline in text classification package interface

classifier = pipeline("text-classification")

# output

text_class = classifier(text)
pd.DataFrame(text_class)

# %%
# this input positive! try it yourself
text1 = "Now i learn Hugging face and develop the transformer skills in NLP"
out = classifier(text1)
pd.DataFrame(out)

# %% [markdown]
# # <center>2. Text Classification</center>
#
# ### **Following steps: Step by Step process**
#
# <img src='https://github.com/nlp-with-transformers/notebooks/raw/c2db380169af910eed0ca5c61b7882f3caa18cf3//images/chapter02_hf-libraries.png'>
#
# ### **Twitter emotion dataset: Data taken Hugging face Hub dataset**
#
# #### ***📢 All are know the process of above steps but this notebook is "How to use Hugging face dataset, Model, Transformer ?"***

# %%
#import datasets
from datasets import list_datasets

all_datasets = list_datasets()

print(f"There are {len(all_datasets)} datasets currently available on the Hub")
print('')
print(f"The first 10 are: {all_datasets[:10]}")

# %% [markdown]
# ## **2.1. Emotion dataset**

# %%
# import load emotion dataset
from datasets import load_dataset
#load data
emotions = load_dataset("emotion")
emotions

# %%
#split the data
train_ds = emotions["train"]
train_ds

# %%
#length of the data
print('Length Of Data: ',len(train_ds))
print('')
# Single example
print("Single example by its index in all taken emotion data: ", train_ds[0])
print('')

#column names
print('Column_Names: ', train_ds.column_names)
print('')
#features
print("Features of our data: ",train_ds.features)
print('')

# data visualize in head (text and label)
print('First 5 rows of data and label: ',train_ds[:5])
print('')

# text feature first 5
print('First 5 rows of data (Text):',train_ds['text'][:5])

# %% [markdown]
# ## **2.2. From Datasets to DataFrames(set format: Pandas)**

# %%
# setformat in pandas
emotions.set_format(type="pandas")

# convert all data in the format
df = emotions["train"][:]

# Tail the process(display)
display(df.tail())

# Tail the label(integer) -> label names (string) of one column (label_int2str)
def label_int2str(row):
    return emotions["train"].features["label"].int2str(row)

#create one features
df["label_name"] = df["label"].apply(label_int2str)
#display(head)
display(df.head())

# %%
# Class distribution of label_name
import matplotlib.pyplot as plt

df["label_name"].value_counts(ascending=True).plot.barh()
plt.title("Frequency distribution of class")
plt.show()

# %%
#How long are our tweets
# Identify the imbalance of data

df["Words Per Tweet"] = df["text"].str.split().apply(len)
df.boxplot("Words Per Tweet", by="label_name", grid=False,
showfliers=False, color="black")
plt.suptitle("")
plt.xlabel("")
plt.show()

# %%
## Before distribution all classes are range is 15 counts
#reset the format
emotions.reset_format()

# %% [markdown]
# ## **2.3. From Text to Tokens**
#
# Transformer models like distilbert cannot receive raw string as input instead, they assume the text has been token and encode as numerical vector

# %% [markdown]
# ## ***2.3.1. Character Tokenization***

# %%
# Character Tokenization
text = "Its all about hugging face! Learning NLP"
print('Character Tokenized: ')
tokenized_text = list(text)
print(tokenized_text)
print('')

# character to numerical token
print('token to Numerical values: ')
token2idx = {ch: idx for idx, ch in enumerate(sorted(set(tokenized_text)))}
print(token2idx)
print('')

#Mapping the each character
print('Mapping the all character to numerical: ')
input_ids = [token2idx[token] for token in tokenized_text]
print(input_ids)
print('')

# pandas dataframe to name and give label
print("Create dataframe of own category: ")
categorical_df = pd.DataFrame(
{"Name": ["VK", "VK_ANT", "Beast"], "Label ID": [0,1,2]})
display(categorical_df)
print('')

#get dummies
print('Get dummies-one hot method: ')
display(pd.get_dummies(categorical_df['Name']))
print('')
#One hot encoding approach(Pytorch-Tensor)
print('OneHotEncoding - Pytorch: ')

import torch
import torch.nn.functional as F

input_ids = torch.tensor(input_ids)
OHE = F.one_hot(input_ids,num_classes=len(token2idx))
print('Shape:',OHE.shape)
print('')

#By examining the first vector, we can verify that a 1 appears in the location indicated by input_ids[0] :
print(f"Token: {tokenized_text[0]}")
print(f"Tensor index: {input_ids[0]}")
print(f"One-hot: {OHE[0]}")

# %% [markdown]
# ## ***2.3.2. Word tokenization***

# %%
tokenized_text = text.split()
print(tokenized_text)

# %% [markdown]
# # <center>3. Transformer Approach - What a different traditional methods</center>
#
# ## **Always Bert base model Popular one:**
#
# <img src='https://miro.medium.com/max/2000/0*EmHoJfuewF-gEsMv.png'>
#
# BERT stands for Bidirectional Encoder Representations from Transformers and is a language representation model by Google. It uses two steps, pre-training and fine-tuning, to create state-of-the-art models for a wide range of tasks.
#
# - L = Number of layers (i.e., #Transformer encoder blocks in the stack).
# - H = Hidden size (i.e. the size of q, k and v vectors).
# - A = Number of attention heads.
#
# 1. BERT Base: L=12, H=768, A=12. (Total Parameters=110M!)
# 2. BERT Large: L=24, H=1024, A=16 (Total Parameters=340M!)
#
# ### And two main purpose:
#
# 1. pretrained (Mask language Model & Next sentence Prediction)
# 2. Finetune
#
# <img src='https://miro.medium.com/max/1400/1*UKcrS0VO_ZBEysVh-AvL7w.png'>
#
#
#
# ## **Then this task used distilbert - sentence and word embedding:**
#
# ## **Distilbert:**
#
# The DistilBERT model was proposed in the blog post Smaller, faster, cheaper, lighter: Introducing DistilBERT, a distilled version of BERT, and the paper DistilBERT, a distilled version of BERT: smaller, faster, cheaper and lighter. DistilBERT is a small, fast, cheap and light Transformer model trained by distilling BERT base. It has 40% less parameters than bert-base-uncased, runs 60% faster while preserving over 95% of BERT’s performances as measured on the GLUE language understanding benchmark.
#
# <img src='https://www.freesion.com/images/36/08f26e2db11ec7a2bdfaaeff46878c64.png'>

# %%
#common large auto tokenizer
from transformers import AutoTokenizer

model_ckpt = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

# %%
#specifically tokenize the data (particularly distilberttoken)

from transformers import DistilBertTokenizer

distilbert_token = DistilBertTokenizer.from_pretrained(model_ckpt)

#check tokenizer model
#id and attention
encoded_text = tokenizer(text)
print(encoded_text)
print('')

#id to token word
tokens = tokenizer.convert_ids_to_tokens(encoded_text.input_ids)
print(tokens)
print('')
print(tokenizer.convert_tokens_to_string(tokens))
print('')
#tokenzier size
print('tokenizer vocab size: ',tokenizer.vocab_size)
print('')

#Model maximum context size
print('Model max length: ',tokenizer.model_max_length)
print('')

#features name
print('Features name: ',tokenizer.model_input_names)
print('')

# %% [markdown]
# ## **3.1. Emotion dataset - Ok lets apply the knowledge in real data**
#
# Output - How to work attention masks
#
# <img src='https://github.com/nlp-with-transformers/notebooks/raw/c2db380169af910eed0ca5c61b7882f3caa18cf3//images/chapter02_attention-mask.png'>

# %%
# Tokenize the emotion input data
def tokenize(batch):
    return tokenizer(batch["text"], padding=True, truncation=True)

# special token id pad=0,unknown = 100, cls=101, sep=102, mask=103

print('Tokenize the emotion data: ',tokenize(emotions['train'][:2]))
print('')

#special token ids
tokens2ids = list(zip(tokenizer.all_special_tokens, tokenizer.all_special_ids))
data = sorted(tokens2ids, key=lambda x : x[-1])
df = pd.DataFrame(data, columns=["Special Token", "Special Token ID"])
print('Special token ids:')
display(df.T)
print('')

# Map the all input data's
# map = all corpus of data, batch =True is means single time train, batchsize not defined
emotions_encoded = emotions.map(tokenize, batched=True, batch_size=None)

print('Features Name of emotion data: ',emotions_encoded["train"].column_names)

# %% [markdown]
# ## **3.2. Training a Text Classifier - DistilBERT**
#
# ### **Step by step process of training data:**
#
# ### ***Token Encoding > Token Embedding > Encoder Stack > Hidden states > Classification head > Predictions***

# %% [markdown]
# ### **Two options to train such a model on our Twitter-Emotion dataset:**
#
# **1. Feature extraction**
# We use the hidden states as features and just train a classifier on them, without modifying the pretrained model.
#
# **2. Fine-tuning**
# We train the whole model end-to-end, which also updates the parameters of the pretrained model.

# %% [markdown]
# ## **3.2.1 Using Pretrained Model - DistilBERT**

# %%
from transformers import AutoModel

#Checkpoints
model_ckpt = "distilbert-base-uncased"

#Device selected
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#Initiate the model
model = AutoModel.from_pretrained(model_ckpt).to(device)

# %%
# Extracting last hidden states

text = "I am Vk - Best Engineer"
inputs = tokenizer(text,return_tensors='pt')
print(f"Input tensor shape: {inputs['input_ids'].size()}")
print('')

#Best model outputs
print('Best model outputs: ')
print('')
inputs = {k:v.to(device) for k,v in inputs.items()}
with torch.no_grad():
    outputs = model(**inputs)
print(outputs)
print('')
#print last hidden size
print('Last hidden size: ')
print(outputs.last_hidden_state.size())

# %%
#Extract the hidden layers
def extract_hidden_states(batch):
    # Place model inputs on the GPU
    inputs = {k:v.to(device) for k,v in batch.items() 
              if k in tokenizer.model_input_names}
    # Extract last hidden states
    with torch.no_grad():
        last_hidden_state = model(**inputs).last_hidden_state
    # Return vector for [CLS] token
    return {"hidden_state": last_hidden_state[:,0].cpu().numpy()}

# Since our model expects tensors as inputs, the next thing to do is convert the input_ids and attention_mask columns to the "torch" format, as follows:
emotions_encoded.set_format("torch",
                            columns=["input_ids", "attention_mask", "label"])

# extract the hidden states across all splits in one go
emotions_hidden = emotions_encoded.map(extract_hidden_states,batched=True)

emotions_hidden['train'].column_names

# %% [markdown]
# ## **3.2.1.1. Creating a feature matrix**

# %%
import numpy as np

X_train = np.array(emotions_hidden["train"]["hidden_state"])
X_valid = np.array(emotions_hidden['validation']["hidden_state"])
y_train = np.array(emotions_hidden["train"]["label"])
y_valid = np.array(emotions_hidden["validation"]["label"])
print(f'Xtrain_shape : {X_train.shape}, X_valid_shape: {X_valid.shape}')

# %% [markdown]
# ## **3.2.1.2. Visualize the training set - UMAP-learn**
#
# ***UMAP Visualization:***
#
# Uniform Manifold Approximation and Projection (UMAP) is a dimension reduction technique that can be used for visualisation similarly to t-SNE, but also for general non-linear dimension reduction. The algorithm is founded on three assumptions about the data:
#
# - The data is uniformly distributed on a Riemannian manifold
# - The Riemannian metric is locally constant (or can be approximated as such);
# - The manifold is locally connected.
#
#
# * From these assumptions it is possible to model the manifold with a fuzzy topological structure. The embedding is found by searching for a low dimensional projection of the data that has the closest possible equivalent fuzzy topological structure.

# %%
# !pip install umap-learn

# %%
# in this data hidden state 768 dimensions and featured scale [0,1] interval like MinMaxScale
from umap import UMAP
from sklearn.preprocessing import MinMaxScaler

# Scale features to [0,1] range
X_scaled = MinMaxScaler().fit_transform(X_train)

# initialize and fit UMAP
mapper = UMAP(n_components = 2, metric="cosine").fit(X_scaled)

# Create a Dataframe of 2D embeddings

df_emb = pd.DataFrame(mapper.embedding_,columns=["X","Y"])
df_emb["label"] = y_train
display(df_emb.head())

# %% [markdown]
# ## ***Ploting the data - UMAP***

# %%
fig,axes = plt.subplots(2, 3, figsize=(7,5))

#1D axises
axes = axes.flatten()

#Color used
cmaps = ['Greys', "Blues", "Oranges", "Reds", "Purples", "Greens"]

#Labels name of emotions
labels = emotions["train"].features["label"].names

#separate
for i,(label, cmap) in enumerate(zip(labels, cmaps)):
    df_emb_sub = df_emb.query(f"label == {i}")
    axes[i].hexbin(df_emb_sub["X"], df_emb_sub["Y"], cmap=cmap,
                  gridsize= 20, linewidths=(0,))
    axes[i].set_title(label)
    axes[i].set_xticks([]),axes[i].set_yticks([])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **3.2.1.3. Training a simple Classifier**
#
# **As a UMAP plot shows one result - What its means separate equally but fear and anger both are much similar compare with others**
#
# ## ***Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression
# Max iteration (3000)
lr_clf = LogisticRegression(max_iter = 1000)
lr_clf.fit(X_train, y_train)
print('Logistic Regression_Score',lr_clf.score(X_valid, y_valid))

# %% [markdown]
# ## **Dummy Classifier**
#
# DummyClassifier makes predictions that ignore the input features, This classifier serves as a simple baseline to compare against other more complex classifiers.

# %%
#Dummy Classifier why choose means? Multiclass?

from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(X_train,y_train)
print('Dummy_Classifier_Score:',dummy_clf.score(X_valid,y_valid))

# %% [markdown]
# ## **3.2.1.4. Performance Analysis in Simple Model || Confusion Matrix**

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

def plot_confusion_matrix(y_preds, y_true, labels):
    cm = confusion_matrix(y_true, y_preds, normalize="true")
    fig, ax = plt.subplots(figsize=(6, 6))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap="Blues", values_format=".2f", ax=ax, colorbar=False)
    plt.title("Normalized confusion matrix")
    plt.show()

y_preds = lr_clf.predict(X_valid)
plot_confusion_matrix(y_preds, y_valid, labels)

# %% [markdown]
# ### **Just try simple model and you see the confusion matrix and after i will try fine tuning transformer --> what's different (Its great experience) of see the result.**

# %% [markdown]
# # **3.2.2. Fine-Tuning Transformers**
#
# <img src='https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/67/f199f04ecf4fe59ee6f88c8c8e2621/BERT_diagrams.png?auto=format%2Ccompress&dpr=1&w=552&h=414&fit=crop'>

# %%
#Loading Pretrained Model

from transformers import AutoModelForSequenceClassification

num_labels = 6

model = (AutoModelForSequenceClassification.from_pretrained(model_ckpt,num_labels = num_labels).to(device))


# Defining the performance Metrics 

from sklearn.metrics import accuracy_score, f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average="weighted")
    acc = accuracy_score(labels, preds)
    return {"accuracy": acc, "f1": f1}

# %% [markdown]
# ## **3.2.2.1. Model_Hub**

# %% [markdown]
# ## **Configuration**

# %%
from transformers import Trainer, TrainingArguments

batch_size = 12
logging_steps = len(emotions_encoded["train"]) // batch_size
model_name = f"{model_ckpt}-finetuned-emotion"
training_args = TrainingArguments(output_dir=model_name,
                                  num_train_epochs=2,
                                  learning_rate=2e-5,
                                  per_device_train_batch_size=batch_size,
                                  per_device_eval_batch_size=batch_size,
                                  weight_decay=0.01,
                                  evaluation_strategy="epoch",
                                  disable_tqdm=False,
                                  logging_steps=logging_steps,
                                  push_to_hub=False, 
                                  log_level="error")

# %% [markdown]
# ## **Train the Model**

# %%
from transformers import Trainer

trainer = Trainer(model=model, args=training_args,
                    compute_metrics=compute_metrics,
                    train_dataset=emotions_encoded["train"],
                    eval_dataset=emotions_encoded["validation"],
                    tokenizer=tokenizer)
trainer.train();

# %% [markdown]
# ## **Output predicition**

# %%
preds_output = trainer.predict(emotions_encoded["validation"])

# %%
preds_output.metrics

# %%
y_preds = np.argmax(preds_output.predictions, axis=1)

# %% [markdown]
# ## **Confusion Matrix - Compare normal model vs finetune model**

# %%
plot_confusion_matrix(y_preds, y_valid, labels)

# %% [markdown]
# ## **3.2.2.2. Error Analysis**

# %%
from torch.nn.functional import cross_entropy

def forward_pass_with_label(batch):
    # Place all input tensors on the same device as the model
    inputs = {k:v.to(device) for k,v in batch.items() 
              if k in tokenizer.model_input_names}

    with torch.no_grad():
        output = model(**inputs)
        pred_label = torch.argmax(output.logits, axis=-1)
        loss = cross_entropy(output.logits, batch["label"].to(device), 
                             reduction="none")

    # Place outputs on CPU for compatibility with other dataset columns   
    return {"loss": loss.cpu().numpy(), 
            "predicted_label": pred_label.cpu().numpy()}

# %%
#hide_output
# Convert our dataset back to PyTorch tensors
emotions_encoded.set_format("torch", 
                            columns=["input_ids", "attention_mask", "label"])
# Compute loss values
emotions_encoded["validation"] = emotions_encoded["validation"].map(
    forward_pass_with_label, batched=True, batch_size=16)

# %% [markdown]
# ## **3.2.2.3. Generate output in Dataframe format**

# %%
emotions_encoded.set_format("pandas")
cols = ["text", "label", "predicted_label", "loss"]
df_test = emotions_encoded["validation"][:][cols]
df_test["label"] = df_test["label"].apply(label_int2str)
df_test["predicted_label"] = (df_test["predicted_label"]
                              .apply(label_int2str))

# %%
#hide_output
df_test.sort_values("loss", ascending=False).head(10)

# %%
#hide_output
df_test.sort_values("loss", ascending=True).head(10)

# %% [markdown]
# # **Applying the Knowledge! Competition Data**
#
# ![US.png](attachment:04c4b61a-7044-4a66-9527-4779dd7c6e6b.png)
#
# # ***Full Credit: This notebook is great one for Hugging_Face, https://www.kaggle.com/code/danofer/uspppm-huggingface-patent-bert***

# %% [markdown]
# # **Import Library**

# %%
import os 
import datasets, transformers

from transformers import TrainingArguments, Trainer
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from transformers import AutoModelForMaskedLM

import numpy as np
os.environ["WANDB_DISABLED"] = "true"

# %% [markdown]
# # **Configuration**

# %%
class CFG:
    
    input_path = '../input/us-patent-phrase-to-phrase-matching/'
#     model_path = '../input/roberta-base'
#     model_path = "../input/bert-for-patents/bert-for-patents" #ORIG
    model_path = "../input/bert-for-patent/bert-for-patents"
#     model = 'roberta-base'
    model = "bert-for-patents"
    
    learning_rate = 0.00115
    weight_decay = 0.01
    
    epochs = 50
    batch_size = 32

# %% [markdown]
# # **Preprocess_Context**

# %%
table = """
A: Human Necessities
B: Operations and Transport
C: Chemistry and Metallurgy
D: Textiles
E: Fixed Constructions
F: Mechanical Engineering
G: Physics
H: Electricity
Y: Emerging Cross-Sectional Technologies
"""
splits = [i for i in table.split('\n') if i != '']
table = {e.split(': ')[0]: e.split(': ')[1] for e in splits}
table

# %% [markdown]
# # **Load Model & Tokenizer**

# %%
model = AutoModelForSequenceClassification.from_pretrained(CFG.model_path, num_labels=1)

tokenizer = AutoTokenizer.from_pretrained(CFG.model_path)

# %% [markdown]
# # **Load Dataset**

# %%
train = datasets.Dataset.from_csv(CFG.input_path + 'train.csv')
train

# %% [markdown]
# # **Tokenize**

# %%
def process(unit, eval = False):
    
    sig = unit['context'][0]
    prefix = table[sig]
    text = unit['anchor']
    
    return {
        **tokenizer( prefix + text, unit['target']),
        'label':unit['score']
    }

encoded_ds = train.map(process, remove_columns= ['id', 'anchor', 'target', 'context', 'score'])

# %% [markdown]
# # **Split into train & Valid**

# %%
encoded_ds = encoded_ds.train_test_split(test_size=0.1)
encoded_ds

# %% [markdown]
# # **Training Set_Up**

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    
    predictions = predictions.reshape(len(predictions))
    return {
        'pearson': np.corrcoef(predictions, labels)[0][1]
    }


args = TrainingArguments(
    f"uspppm",
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=CFG.learning_rate,
    per_device_train_batch_size=CFG.batch_size,
    per_device_eval_batch_size=CFG.batch_size,
    num_train_epochs=CFG.epochs,
    weight_decay=CFG.weight_decay,
    load_best_model_at_end=True,
    metric_for_best_model="pearson",
)

trainer = Trainer(
    model,
    args,
    train_dataset=encoded_ds["train"],
    eval_dataset=encoded_ds["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %% [markdown]
# # **If everything's OK!**

# %%
trainer.evaluate()

# %% [markdown]
# # **Building Model - Train it**

# %%
trainer.train()

# %% [markdown]
# # **Make Predictions**

# %%
def test_process(unit, eval = False):
    
    sig = unit['context'][0]
    prefix = table[sig]
    text = unit['anchor']
    
    return {
        **tokenizer( prefix + text, unit['target']),
        'label':-1
    }



test = datasets.Dataset.from_csv(CFG.input_path + 'test.csv')

encoded_test = test.map(test_process, remove_columns= ['id', 'anchor', 'target', 'context'])

outputs = trainer.predict(encoded_test)
predictions = outputs.predictions.reshape(-1)

# %% [markdown]
# # **CompetitionData, Prediction_Submission**

# %%
submission = datasets.Dataset.from_dict({
    'id': test['id'],
    'score': predictions,
})

submission.to_csv('submission.csv', index=False)

# %%
submission.head()

# %% [markdown]
# ## **⭐️Thankyou for visiting Guys!⭐️**
#
# Reference: Full credit of this notebook
#
# 1. NLP with transformer book
# 2. https://huggingface.co/course/
# 3. https://www.kaggle.com/code/danofer/uspppm-huggingface-patent-bert
#
# ## **"if you see any errors and your opinion! feel free to share with me"**
# ## **⭐️Enjoy!🤗HuggingFace🤗⭐️**
