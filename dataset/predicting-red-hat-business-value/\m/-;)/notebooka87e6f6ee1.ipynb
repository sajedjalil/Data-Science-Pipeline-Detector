# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
# IMPORT PACKAGES
import pandas as pd
import seaborn
import numpy as np

# %%
# READ DATA
people =  pd.read_csv("../input/people.csv")
act_train =  pd.read_csv("../input/act_train.csv")

# %%
# DATA EXPLORATION

a=len(act_train['people_id'])
b= len(act_train['people_id'].unique())
print("ACTIVITY : number of rows  = {} and unique people count = {}".format(a,b))

a=len(people['people_id'])
b= len(people['people_id'].unique())
print("PEOPLE : number of rows  = {} and unique people count = {}".format(a,b))

a=len(act_train['activity_category'])
b= len(act_train['activity_category'].unique())
print("ACTIVITY : number of rows IN  = {} and unique activity count = {}".format(a,b))

peop_in_act = act_train['people_id']
peop_in_peop = people['people_id']

all_peop = pd.concat([peop_in_act,peop_in_peop],ignore_index=True)
all_peop.head()
print("\n detail of the distinct people included in both the dataset")
all_peop.describe()

# %%
# merged dataset 
act_peop=pd.merge(people, act_train, on='people_id')

# %%
p.head()

# %%
# distribution of outcome across various activities
def dist_explr(list_clm,data_name):
    p = data_name[list_clm]
    p_sum = p.groupby(list_clm).size()
    data_explore = pd.DataFrame(p_sum)

    print("Sample output")
    #print(data_explore)
    return data_explore

#dist_explr('activity_category','outcome')

samp_data = dist_explr(['people_id','group_1'],people)

# %%
act_peop.head()

# %%
#based on time
samp_data = dist_explr(['people_id','activity_category','date_x','outcome'],act_peop)
samp_data.head()

'''
sample data for people_id : ppl_100
'''
peop_samp1 = act_peop.loc[act_peop['people_id'] == 'ppl_100003'][['people_id','activity_id','activity_category','date_x','outcome']]

# %%
test_data = pd.read_csv('../input/act_test.csv')

test_act = test_data['activity_id'].drop_duplicates()
test_actdf = pd.DataFrame(test_act)
test_actdf['outcome']=np.random.randint(0,2, size=len(test_actdf['activity_id']))
test_actdf

test_actdf.to_csv("red_hat_out1.csv", index=False)

# %%
import os 
os.getcwd()
