# %% [markdown]
# # README
#
# ## 文件梳理
#
# ###文件整理
#
# people.csv（用户特征数据集）
# act_train.csv（activity训练数据集 ）
# act_test.csv（activity原始数据，用来作为预测集）
# sample_submission.csv（将来提交的结果示例，该结果是act_test.csv跑模型的结果）
# ### 数据集分析
#
# 在activity相关的文件中，将用户所做的操作进行了一个分类，type1——type7，其中type1有9个相关特征，type2-type7只有1个相关特征。（即当该条活动的activity_category为type1时，char_1—char_9都是有值的，而char_10是空的；相反，当activity_category为type2-type7时，只有char_10有值。）
#
# ## 思路整理
#
# **最简单的思路**
#
# 直接将people文件和activity文件整合为一个整体，利用某一个算法（决策树，SVM等）进行运算建模。 但这样简单的方法red hat一定考虑过，所以不太可行（不过还是需要出一版）。
#
# **稍复杂的思路**
#
# 使用无监督分类将用户分类（例如分为A、B两类）。
# 将act_train的数据根据A，B分组，分别使用不同的模型。
# 这里使用何种模型还待商酌。

# %% [markdown]
# ## 数据清理
# 整个过程开始之前，最重要的一步是清理数据集。
#
#  1. 数据是否有缺失值？如何处理？
#  2. 对于标称型特征值如何处理？
#  3. 使用那些特征值？
#  4. 特征值的选取是否过多/少？是否会造成过/欠拟合？
#  5. ...

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.
