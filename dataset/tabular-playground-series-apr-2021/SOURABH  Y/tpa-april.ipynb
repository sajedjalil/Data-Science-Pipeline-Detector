# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('../input/tabular-playground-series-apr-2021/train.csv')

# %%
data.dtypes

# %%
cols=['Name','Sex','Ticket','Cabin','Embarked']

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
for i in cols:
    data[i]= label_encoder.fit_transform(data[i])

# %%
data

# %%
data.isnull().sum()

# %%
data.describe()

# %%
data.Sex.unique()

# %%
no_of_women=len(data[data.Sex==0])
no_of_men=len(data[data.Sex==1])

# %%
data=data.fillna(0)

# %%
mean_age_men=0
mean_age_women=0
for index, row in data.iterrows():
    if(row['Sex']==1):
        mean_age_men=mean_age_men+row['Age']
    else :
        mean_age_women=mean_age_women+row['Age']
mean_age_men=mean_age_men/no_of_men
mean_age_women=mean_age_women/no_of_women

# %%
mean_age_men

# %%
mean_age_women

# %%
for index, row in data.iterrows():
    if(row['Sex']==1 and row['Age']==0):
        row['Age']=mean_age_men
    elif(row['Sex']==0 and row['Age']==0):
        row['Age']=mean_age_women

# %%
data.describe()

# %%
mean_fare_men=0
mean_fare_women=0
for index, row in data.iterrows():
    if(row['Sex']==1):
        mean_fare_men=mean_fare_men+row['Fare']
    else :
        mean_fare_women=mean_fare_women+row['Fare']
mean_fare_men=mean_fare_men/no_of_men
mean_fare_women=mean_fare_women/no_of_women

# %%
for index, row in data.iterrows():
    if(row['Sex']==1 and row['Fare']==0):
        row['Fare']=mean_fare_men
    elif(row['Sex']==0 and row['Fare']==0):
        row['Fare']=mean_fare_women

# %%
mean_fare_women

# %%
mean_fare_men

# %%
data.describe()

# %%
no_of_men

# %%
no_of_women

# %%
from sklearn.model_selection import train_test_split

# %%
data.columns

# %%
col=['Pclass', 'Sex', 'Age', 'SibSp','Parch', 'Cabin', 'Embarked']

# %%
X=data[col]
Y=data['Survived']

# %%
X

# %%
Y

# %%
train_x,test_x,train_y,test_y=train_test_split(X,Y,test_size=0.15)

# %%
import keras 
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, LSTM,Dropout

# %%
def create_model():
        model = Sequential()
        model.add(Dense(7,input_dim=7,activation='relu'))
        model.add(Dense(14,activation='relu'))
        model.add(Dense(14,activation='relu'))

        model.add(Dense(7,activation='relu'))
        model.add(Dense(5,activation='relu'))
        model.add(Dense(3,activation='relu'))
        model.add(Dense(1, activation='sigmoid'))
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

# %%
model=create_model()
model.summary()

# %%
hist=model.fit(np.asarray(train_x).astype('float32'),train_y,epochs=150,batch_size=128)

# %%
model.evaluate(test_x,test_y)

# %%
test=pd.read_csv('../input/tabular-playground-series-apr-2021/test.csv')
test2=pd.read_csv('../input/tabular-playground-series-apr-2021/test.csv')

# %%
for i in cols:
    test[i]= label_encoder.fit_transform(test[i])

# %%
test

# %%
test.isnull().sum()

# %%
test=test.fillna(0)

# %%
for index, row in test.iterrows():
    if(row['Sex']==1 and row['Fare']==0):
        row['Fare']=mean_fare_men
    elif(row['Sex']==0 and row['Fare']==0):
        row['Fare']=mean_fare_women

# %%
for index, row in test.iterrows():
    if(row['Sex']==1 and row['Age']==0):
        row['Age']=mean_age_men
    elif(row['Sex']==0 and row['Age']==0):
        row['Age']=mean_age_women

# %%
X_t=test[col]

# %%
X_t

# %%
y_pred=model.predict(np.asarray(X_t).astype('float32'))

# %%
def app(y_pred):
    pred=[]
    for i in y_pred:
        
        if i[0]>0.500000001:
            pred.append(1)
        else:
            pred.append(0)
    return pred

# %%
pred=app(y_pred)

# %%
y_pred

# %%
pred

# %%
submission = pd.DataFrame({'PassengerId':test2.PassengerId,'Survived':pred})
submission.to_csv('submission.csv',index=False)
