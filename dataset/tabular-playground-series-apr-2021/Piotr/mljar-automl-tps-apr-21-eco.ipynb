# %% [markdown]
# # MLJAR AutoML ECO
#
# The version of MLJAR AutoML with reduced carbon footprint. Not running on all columns. Thus, computation should be faster and final model should generalize better.
#
# MLJAR GitHub: https://github.com/mljar/mljar-supervised

# %%
# !pip install -q -U git+https://github.com/mljar/mljar-supervised.git@master

# %%
import numpy as np
import pandas as pd
from supervised.automl import AutoML # mljar-supervised

# %%
train = pd.read_csv("../input/tabular-playground-series-apr-2021/train.csv")
test = pd.read_csv("../input/tabular-playground-series-apr-2021/test.csv")

# %%
x_cols = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]
y_col = train.columns[1]

# %%
automl = AutoML(
    mode="Compete", 
    eval_metric="accuracy",
    total_time_limit=2*3600
)
automl.fit(train[x_cols], train[y_col])

# %%
preds = automl.predict(test[x_cols])

# %%
submission = pd.DataFrame({'PassengerId':test.iloc[:,0], 'Survived': preds})
submission.to_csv('1_submission.csv', index=False)

# %%
automl.report()
