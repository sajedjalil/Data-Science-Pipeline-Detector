# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from pandas import option_context

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression #importer le modele de regression log

# %%
train = pd.read_csv('/kaggle/input/quora-question-pairs/train.csv.zip', index_col = 'id') #pandas arrive à dézipper lui-même donc pas besoin des lignes au-dessus

# %%
def print_questions(index):
    q1 = train.iloc[index].question1
    q2 = train.iloc[index].question2
    print(q1)
    print(q2)

# %%
train

# %%
train.shape

# %%
print_questions(3)

# %%
lambda x : len(x) if not pd.isnull(x) else -1

# %%
with option_context('display.max_colwidth', 400, 'display.max_rows', 150):
    display(train[train.is_duplicate==1].head(150))

# %%
pd.read_csv('train.csv', index_col='id')

# %%
len(sentence.split(‘ ‘)) #calcul du nombre de mots

# %%
#supprimer les lignes qui ont un n/a, un null

# %%
q1

# %%
q1.split(' ')[0] #spliter la phrase en mots pour en récupérer le 1er

# %%
'sdf'.ist

# %%
train.head(10) #pour tester sur les 10 premières lignes du dataset

# %%
train.isnull().sum()

# %%
train[pd.isnull(train.question1)] #trouver les valeurs nulles dans une colonne

# %%
lambda x : len(x) if not pd.isnull(x) else -1 #trouver les vides et les remplacer par -1

# %%
train=train.dropna() #on enleve les lignes qui contiennent une valeur nulle

# %%
train

# %%
df=pd.DataFrame(master_X)
df["nbmotsq1"] = df["question1"].str.split().str.len() #ajouter une variable

# %%
X=df[["qid1","qid2","nbmotsq1","nbmotsq2"]]
Y=df[[]]
Xtrain, Xtest, ytrain, ytest =train_test_split(train,test_size=0.2)  #diviser notre dataset en 2 pour avoir un dataset de test

# %%
lr=LogisticRegression() #l'objet lr va stocker tous les teta0 et teta1
lr.fit(Xtrain,ytrain)

# %%
lr.coef #afficher les résultats de l'entrainement si l'instance a été entrainée 1 fois ;-

# %%
df.qid1 == 8461

# %%
for col, coef in zip(X.columns, lr.coef_[0]):
    print(col, coef) # la mm chose mais avec affichage plus sympa

# %%
train[train.qid1 == 8461]

# %%
Ypred=lr.predict(Xtest)

# %%
print(Ypred)
