# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

import stylecloud
from IPython.display import Image

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #001f3f;"><b style="color:orange;">Argument Writing</b></h1></center>

# %% [markdown]
# ![](https://ecdn.teacherspayteachers.com/thumbitem/Argument-Writing-Common-Core-Grades-6-12-078110900-1375381041-1518521322/original-803863-1.jpg)teachers.payteachers.com

# %% [markdown]
# "In argumentative writing, you are typically asked to take a position on an issue or topic and explain and support your position with research from reliable and credible sources."
#
# "What are the characteristics of an argumentative paper?"
#
#
# The argument you are making should be clearly stated within your thesis statement.
# You should have several reasons or points of discussion that help you to support your argument. You will explain and support these reasons and points of discussion within the body paragraphs of your paper. As with all academic writing, you’ll need to cite any information that you used from a source within your paper.
#
# https://writingcenter.uagc.edu/argumentative-writing

# %%
train = pd.read_csv('../input/feedback-prize-2021/train.csv',delimiter=',', encoding='utf-8')
train.head()

# %% [markdown]
# #Predict human annotations. (Really???). Ok predict students in grades 6-12. Those kids are so predictable. Do you need ML to predict those kids? I simply loved this comp.
#
# Segment each essay into discrete rhetorical and argumentative elements (i.e., discourse elements) and then classify each element as one of the following:
#
# Lead - an introduction that begins with a statistic, a quotation, a description, or some other device to grab the reader’s attention and point toward the thesis
#
# Position - an opinion or conclusion on the main question
#
# Claim - a claim that supports the position
#
# Counterclaim - a claim that refutes another claim or gives an opposing reason to the position
#
# Rebuttal - a claim that refutes a counterclaim
#
# Evidence - ideas or examples that support claims, counterclaims, or rebuttals.
#
# Concluding Statement - a concluding statement that restates the claims
#
# #I think this Competition is very appropriate to Lawyers and CSIs. I believe in Evidences like Gil' Arthur Grissom.
#
# https://www.kaggle.com/c/feedback-prize-2021/data

# %%
# !pip install stylecloud

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

concat_discourse_text = ' '.join([i for i in train.discourse_text.astype(str)])
print(concat_discourse_text[:1000])

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text=concat_discourse_text,
                          icon_name='fas fa-biking',
                          palette='colorbrewer.diverging.Spectral_11',
                          background_color='black',
                          gradient='horizontal',
                          size=1024)

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text=''.join([i for i in train[train.discourse_type.str.contains('Evidence')].discourse_text]),
                          icon_name='fas fa-dharmachakra', #Evidence above came from train.discourse_text.value_counts in 11
                          palette='colorbrewer.sequential.BuGn_9',
                          background_color='black',
                          gradient='horizontal',
                          size=1024)

# %% [markdown]
# ![](https://assets.ltkcontent.com/images/95084/argumentative-statements_0066f46bde.jpg)grammar.yourdictionary.com

# %% [markdown]
# #Everything is about a Phone? Those people don't have real life problem.

# %%
train.dropna(inplace=True)

# %%
Image(filename="./stylecloud.png", width=1024, height=1024)

# %%
train.discourse_type.value_counts()[:40]

# %% [markdown]
# ![](https://s2.studylib.net/store/data/005415648_1-6b969c83474ec2fe0fe62910eb0374d0.png)studylib.net

# %%
file_path = train

# %%
#Code by Paul Mooney

student_file = '../input/feedback-prize-2021/train/000E6DE9E817.txt'
with open(student_file) as f: # The with keyword automatically closes the file when you are done
    print (f.read(4000))

# %% [markdown]
# #Probably that student learned with my friend Carl how to write properly and not only those 140 characters.

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text='Dear Principal. I am arguing against the policy change because even though there are some children out there that really needs help with their academic work, that does not mean that only because they have an average that would not let them enjoy their sports or other activities unless they have a B average. Sometimes teachers or even principal needs to consider that we should give the help that any student should have. Also this may consider student self as steam. Meaning student would start to feel sad nervous, and not wanting to go to school because of the reason they have a low averages and they can not participate in other activities or sports.'.join([i for i in train[train.discourse_type.str.contains('Claim')].discourse_type]),
                          icon_name='fas fa-dharmachakra', #Claim above came from train.discourse_type.value_counts in 11
                          palette='colorbrewer.sequential.BuGn_9',
                          background_color='black',
                          gradient='horizontal',
                          size=1024)

# %%
Image(filename="./stylecloud.png", width=1024, height=1024)

# %%
#Code by Paul Mooney

student_file1 = '../input/feedback-prize-2021/train/0016926B079C.txt'
with open(student_file1) as f: # The with keyword automatically closes the file when you are done
    print (f.read(4000))

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text='I think that students would benefit from learning at home,because they wont have to change and get up early in the morning to shower and do there hair. taking only classes helps them because at there house they will be pay more attention. they will be comfortable at home.'.join([i for i in train[train.discourse_type.str.contains('Claim')].discourse_type]),
                          icon_name='fas fa-dharmachakra', #Claim above came from train.discourse_type.value_counts in 11
                          palette='cmocean.sequential.Matter_10',
                          background_color='black',
                          gradient='horizontal',
                          size=1024)

# %% [markdown]
# ![](https://misslewisreading.weebly.com/uploads/1/6/5/5/16553398/parts-of-an-argument_orig.jpg)https://misslewisreading.weebly.com/8th-grade/march-23-writing-a-multi-paragraph-argument

# %%
Image(filename="./stylecloud.png", width=1024, height=1024)

# %%
#Code by Paul Mooney

student_file2 = '../input/feedback-prize-2021/train/00203C45FC55.txt'
with open(student_file2) as f: # The with keyword automatically closes the file when you are done
    print (f.read(4000))

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text='It is every students dream to be able to lounge around at home, and complete school from the comforts of their own beds. Though, for some students, this long desired fantasy is becoming a reality. With the introduction of new and innovative technologies into the classroom, distance learning is now a common practice, whether it be online or through video conferencing. However, to pretend that this is a solution to the ever-growing problems within the education system, is willfully ignorant. Distance education is actually detrimental to the students who choose to take these courses, due to the lack of typical classroom structure.'.join([str(i) for i in train[train.discourse_type.str.contains('')].discourse_type]),
                          icon_name='fas fa-yin-yang',
                          palette='tableau.Gray_5',
                          background_color='lightblue',
                          gradient='center',
                          size=1024)


Image(filename="./stylecloud.png", width=1024, height=1024)

# %%
#Code by Paul Mooney

student_file3 = '../input/feedback-prize-2021/train/0029F4D19C3F.txt'
with open(student_file3) as f: # The with keyword automatically closes the file when you are done
    print (f.read(4000))

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text='Thank you for your time i hope you rethink about changing the schools policy so that students MAY participate in sports and other activities even if we have a "C" average. I am sure i am not the only student that would like to propose this statement. Sincerely, not happy.'.join([str(i) for i in train[train.discourse_type.str.contains('')].discourse_type]),
                          icon_name='fas fa-yin-yang',
                          palette='tableau.Gray_5',
                          background_color='white',
                          gradient='center',
                          size=1024)


Image(filename="./stylecloud.png", width=1024, height=1024)

# %%
#Code by Paul Mooney

student_file4 = '../input/feedback-prize-2021/train/003FDC7E6F20.txt'
with open(student_file4) as f: # The with keyword automatically closes the file when you are done
    print (f.read(4000))

# %%
#Code by Paul Mooney

student_file5 = '../input/feedback-prize-2021/train/0045BE2791A2.txt'
with open(student_file5) as f: # The with keyword automatically closes the file when you are done
    print (f.read(4000))

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text='Dear Teacher, I agree 100% with you. I think in order to be on a team sport you will have to have you grade up to a B. I think that because its not fair to the teachers if all you think about is sports and your grades are going down in school but you are doing sports. That telling the teachers you just do not care. Also i think its unfair to the other students that you are on the soccer team but have grades that are failing and you miss practice all the time because you have detention. Its fair do have the honor students play for are school even if there not the best in the school. Also its unfair to you. You will have bad grades but do well in sports. You should do a activity i agree with that but only if your grades are high. Why would you want bad grades? you should pass. Also it just does not seem right. Or you could get a scholarship into a college for sports but it would not boost your grade up all the way to get in a great college. So that is why i think its important school before sports. and have an A or B for grades so you can do sports '.join([str(i) for i in train[train.discourse_type.str.contains('Evidence')].discourse_type]),
                          icon_name='fas fa-fingerprint',#Austen above came from data.author.value_counts
                          palette='cartocolors.qualitative.Bold_6',
                          background_color='black',
                          gradient='center',
                          size=1024)

Image(filename="./stylecloud.png", width=1024, height=1024)

# %% [markdown]
# ![](http://image.slidesharecdn.com/argumentwritingpresentation-140910101302-phpapp02/95/argument-writing-presentation-2-638.jpg?cb=1410345369)blendspace.com

# %% [markdown]
# #Imagine number 4 with students in grades 6-12. That will Not end nicely.

# %%
#Code by Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook

stylecloud.gen_stylecloud(text='This is why I disagree on having to make kids participate in a sport or activity. Its way to much work, stress, and money. So when coming down to a decision I agree with a no because having every kid in a sport or activity is absurd.'.join([str(i) for i in train[train.discourse_type.str.contains('')].discourse_type]),
                          icon_name='fas fa-tree',
                          colors=['#525252', '#414141', '#D8E3E7','#EEEEEE','#DDDDDD'],
                          background_color='black',
                          gradient='horizontal',
                          size=1024)


Image(filename="./stylecloud.png", width=1024, height=1024)

# %% [markdown]
# ![](https://i.ytimg.com/vi/P3LtZv_B-6M/maxresdefault.jpg)youtube.com

# %% [markdown]
# #Never forget to write a conclusion in your works Kagglers. A couple of lines with your findings will do Kagglers.

# %% [markdown]
# #Acknowledgment
#
# Kapa Kudaibergenov https://www.kaggle.com/kapakudaibergenov/stylecloud/notebook
#
#
# #Paul Timothy Mooney  for every txt file I made. There is always Paul.
#
# #This Kaggle Notebook is dedicated to Paul T. Mooney for being so long in many of my works.
