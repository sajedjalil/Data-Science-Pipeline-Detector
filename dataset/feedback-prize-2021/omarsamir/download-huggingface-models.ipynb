# %%
#!git lfs install
#!git lfs clone https://huggingface.co/google/bigbird-roberta-large

# %%
#from transformers import AutoTokenizer, AutoModel
#tokenizer = AutoTokenizer.from_pretrained("google/bigbird-roberta-large")
#model = AutoModel.from_pretrained("google/bigbird-roberta-large")

# %%
# !sudo apt-get install git-lfs

# %%
# !git lfs install
# !git clone https://huggingface.co/google/bigbird-roberta-large

# %%
#!ls ~/.cache/huggingface/transformers/

# %%
#!ls /kaggle/lib/kaggle
