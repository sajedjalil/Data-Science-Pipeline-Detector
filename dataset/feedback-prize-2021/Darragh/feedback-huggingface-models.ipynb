# %%
# !git clone https://huggingface.co/allenai/longformer-large-4096 allenai/longformer-large-4096

# %%
# !git clone https://huggingface.co/allenai/led-large-16384 allenai/led-large-16384

# %%
# !git clone https://huggingface.co/microsoft/deberta-v3-large microsoft/deberta-v3-large

# %%
# !git clone https://huggingface.co/microsoft/deberta-v2-xlarge microsoft/deberta-v2-xlarge

# %%
# !git clone https://huggingface.co/facebook/bart-large facebook/bart-large

# %%
# !git clone https://huggingface.co/google/bigbird-roberta-large google/bigbird-roberta-large

# %%
# !git clone https://huggingface.co/microsoft/deberta-v2-xxlarge microsoft/deberta-v2-xxlarge

# %%
# !git clone https://huggingface.co/microsoft/deberta-large microsoft/deberta-large

# %%
# !git clone https://github.com/alcinos/transformers/ -b debertav2-fast-tokenizer

# %%
cd transformers/

# %%
pip install .

# %%
from transformers import DebertaV2Tokenizer, AutoTokenizer

# %%
tok = AutoTokenizer.from_pretrained('microsoft/deberta-v3-large')
tok.save_pretrained('test')

# %%
tok = AutoTokenizer.from_pretrained('microsoft/deberta-v3-large')
tok.save_pretrained('deberta-v3-large')

# %%
tok = AutoTokenizer.from_pretrained('microsoft/deberta-v2-xlarge')
tok.save_pretrained('deberta-v2-xlarge')

# %%
tok = AutoTokenizer.from_pretrained('microsoft/deberta-v2-xxlarge')
tok.save_pretrained('deberta-v2-xxlarge')

# %%
tok = AutoTokenizer.from_pretrained('microsoft/deberta-large')
tok.save_pretrained('deberta-large')
