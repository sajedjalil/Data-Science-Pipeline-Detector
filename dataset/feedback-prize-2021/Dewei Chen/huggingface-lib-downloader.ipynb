# %% [markdown]
# ## We need Check the git version first. git should be upper than 1.8

# %%
# !git --version

# %% [markdown]
# ## Then we can install the big file download tools

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash

# %%
# !sudo apt-get install git-lfs
# !git lfs install

# %% [markdown]
# ## Final We clone it

# %%
# !git clone https://huggingface.co/microsoft/deberta-base
