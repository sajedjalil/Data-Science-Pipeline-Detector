# %% [markdown]
# NOTE: Part of examples for the `feedback-prize-2021-lib` [library](https://www.kaggle.com/sentinel1/feedback-prize-2021-lib)

# %%
from pathlib import Path

if Path.cwd() == Path('/kaggle/working'):
    # Kaggle
    import sys
    LIB_PATH = (Path.cwd()/".."/"input"/"feedback-prize-2021-lib").resolve()
    assert LIB_PATH.is_dir(), ("Use the '+ Add data' feature to add the 'Notebook Output Files' from the 'sentinel1/feedback-prize-2021-lib' "
                               "in order to make some utilities importable from that library (one time restart is required after adding).")
    sys.path.insert(0, str(LIB_PATH))
else:
    # Local machine
    assert (Path.cwd()/"lib"/"feedback_util.py").is_file(), ("Run the 'sentinel1/feedback-prize-2021-lib' notebook locally "
                                                             "in order to generate the importable library on your machine")

# %%
from lib.feedback_util import color_print_essay, read_train_csv

# %%
# ?color_print_essay

# %%
# ?read_train_csv

# %%
train_df = read_train_csv()
train_df.head(2)

# %%
color_print_essay('423A1CA112E2', train_df)

# %%
color_print_essay('A8445CABFECE', train_df)

# %%
color_print_essay('6B4F7A0165B9', train_df)

# %% [markdown]
# Sometimes discourses of the same type are adjacent, this is where `start_end_indicators=True` flag might be useful, see the example below (with and without showing indicators):

# %%
color_print_essay('62FC97D29846', train_df, start_end_indicators=True)

# %%
color_print_essay('62FC97D29846', train_df)  # Same essay without start_end_indicators=True
