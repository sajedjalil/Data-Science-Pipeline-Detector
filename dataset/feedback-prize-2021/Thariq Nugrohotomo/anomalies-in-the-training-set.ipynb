# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
train = pd.read_csv('../input/feedback-prize-2021/train.csv')

# %% [markdown]
# ### `predictionstring` contains 18 indices but `discourse_text` only contains 17 words

# %%
row = train.loc[46]
print('discourse_text:'.upper())
print(row.discourse_text)
print('predictionstring:'.upper(), len(row.predictionstring.split()))
with open('../input/feedback-prize-2021/train/' + row.id + '.txt') as file:
    txt = file.read().split()
print(*map(lambda ii: txt[int(ii)], row.predictionstring.split()))

# %% [markdown]
# ### missing space separating two words 'DrivingHundreds' in the txt file

# %%
print('A97DE0D49AEA.txt:'.upper())
with open('../input/feedback-prize-2021/train/A97DE0D49AEA.txt') as file:
    print(' '.join(file.read().split()[11:41]))
print()
print('discourse_text[71]:'.upper())
print(train.loc[71].discourse_text)
print()
print('discourse_text[72]:'.upper())
print(train.loc[72].discourse_text)

# %% [markdown]
# ### word index is off by 1 ??

# %%
print('discourse_text:'.upper())
print(train.loc[252].discourse_text)
print()
print('predictionstring'.upper())
with open('../input/feedback-prize-2021/train/' + train.loc[252].id + '.txt') as file:
    txt = file.read().split()
print(*map(lambda ii: txt[int(ii)], train.loc[252].predictionstring.split()))

# %% [markdown]
# ### `predictionstring` contains 10 indices but `discourse_text` only contains 9 words

# %%
row = train.loc[316]
print('discourse_text:'.upper())
print(row.discourse_text)
print('predictionstring:'.upper(), len(row.predictionstring.split()))
with open('../input/feedback-prize-2021/train/' + row.id + '.txt') as file:
    txt = file.read().split()
print(*map(lambda ii: txt[int(ii)], row.predictionstring.split()))

# %% [markdown]
# ### word index is off by 1 ??

# %%
row = train.loc[486]
print('discourse_text:'.upper())
print(row.discourse_text)
print('predictionstring:'.upper(), len(row.predictionstring.split()))
with open('../input/feedback-prize-2021/train/' + row.id + '.txt') as file:
    txt = file.read().split()
print(*map(lambda ii: txt[int(ii)], row.predictionstring.split()))

# %% [markdown]
# ### do indexing start from 0 or 1 ??

# %%
row = train.loc[712]
print('discourse_text:'.upper())
print(row.discourse_text)
print()
print('predictionstring:'.upper(), row.predictionstring)
print()
print('FULL TEXT FILE:'.upper())
with open('../input/feedback-prize-2021/train/' + row.id + '.txt') as file:
    print(file.read())
