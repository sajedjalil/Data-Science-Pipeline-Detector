# %%
import pandas as pd
train_csv = pd.read_csv('../input/feedback-prize-2021/train.csv')
text = open("../input/feedback-prize-2021/train/F91D7BB4277C.txt", 'r').read()
print(text)
print("----")
print('\n'.join(train_csv.loc[train_csv["id"] == "F91D7BB4277C"]['discourse_text']))
train_csv.loc[train_csv["id"] == "F91D7BB4277C"]
