# %%
import numpy as np 
import pandas as pd 

data = dict()

print('ok')
open("text.txt", "w").write("da")

sub_df = pd.read_csv('../input/landmark-retrieval-2021/sample_submission.csv')
print(sub_df)
sub_df.to_csv('submission.csv', index=False)

# %%
a = 2
b = 3
print (a + b)
