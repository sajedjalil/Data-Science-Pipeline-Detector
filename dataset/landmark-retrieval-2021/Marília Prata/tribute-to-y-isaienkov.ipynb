# %%
import os
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# #This work is a Tribute to Yaroslav Isaienkov to show all the admiration, respect and gratitude for the work he shared with Kaggle community.

# %%
os.listdir('../input/landmark-retrieval-2021/')

# %% [markdown]
# #Forever Yaroslav Isaienkov
#
# https://www.kaggle.com/ihelon/google-landmark-retrieval-2020-eda

# %%
df = pd.read_csv('../input/landmark-retrieval-2021/train.csv', index_col=0)
df.head()

# %%
#Code By Yaroslav Isaienkov https://www.kaggle.com/ihelon/google-landmark-retrieval-2020-eda

def create_full_path(name):
    return os.path.join(
        '../input/landmark-retrieval-2021/train/',
        name[0],
        name[1],
        name[2],
        f'{name}.jpg'
    )

# %%
#Code By Yaroslav Isaienkov https://www.kaggle.com/ihelon/google-landmark-retrieval-2020-eda

def vis(_id):
    arr = df[df['landmark_id'] == _id].index.tolist()

    plt.figure(figsize=(16, 16))
    for i, name in enumerate(arr):
        img = cv2.imread(create_full_path(name))
        plt.subplot(4, 3, i + 1)
        plt.imshow(img)
        plt.xticks([])
        plt.yticks([])
        if i >= 11:
            break
    plt.suptitle(_id)
    plt.show()

# %%
#Code By Yaroslav Isaienkov https://www.kaggle.com/ihelon/google-landmark-retrieval-2020-eda

vis(random.choice(df['landmark_id'].unique()))

# %%
import torch
import fastai
from fastai.tabular.all import *
from fastai.text.all import *
from fastai.vision.all import *
from fastai.medical.imaging import *
from fastai import *

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %%
from PIL import Image

img = Image.open("../input/landmark-retrieval-2021/train/0/0/0/00001b2ba2c69ac5.jpg")
img

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques

def visualize_images(path, n_images, is_random=True, figsize=(16, 16)):
    plt.figure(figsize=figsize)
    w = int(n_images ** .5)
    h = math.ceil(n_images / w)
    
    all_names = os.listdir(path)
    image_names = all_names[:n_images]   
    if is_random:
        image_names = random.sample(all_names, n_images)
            
    for ind, image_name in enumerate(image_names):
        img = cv2.imread(os.path.join(path, image_name))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        plt.subplot(h, w, ind + 1)
        plt.imshow(img)
        plt.xticks([])
        plt.yticks([])
    
    plt.show()

# %%
landmarks_JPG_PATH = '../input/landmark-retrieval-2021/train/0/0/0'

# %%
visualize_images(landmarks_JPG_PATH, 9)

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques

def show_color_histogram(path):
    image_names = os.listdir(path)
    image_name = random.choice(image_names)
    img = cv2.imread(os.path.join(path, image_name))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    fig = make_subplots(1, 2)

    fig.add_trace(go.Image(z=img), 1, 1)
    for channel, color in enumerate(['red', 'green', 'blue']):
        fig.add_trace(
            go.Histogram(
                x=img[..., channel].ravel(), 
                opacity=0.5,
                marker_color=color, 
                name='%s channel' %color
            ), 1, 2)
    fig.update_layout(height=400)
    fig.show()

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques

def color_hist_visualization(image_path, figsize=(16, 4)):
    plt.figure(figsize=figsize)
    
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    plt.subplot(1, 4, 1)
    plt.imshow(img)
    plt.axis("off")
    
    colors = ["red", "green", "blue"]
    for i in range(len(colors)):
        plt.subplot(1, 4, i + 2)
        plt.hist(
            img[:, :, i].reshape(-1),
            bins=25,
            alpha=0.5,
            color=colors[i],
            density=True
        )
        plt.xlim(0, 255)
        plt.xticks([])
        plt.yticks([])

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques

img_path = '../input/landmark-retrieval-2021/train/0/0/0/0000fb2148d6c0e4.jpg'
color_hist_visualization(img_path)

img_path = '../input/landmark-retrieval-2021/train/2/0/2/20200a7671167ac4.jpg'
color_hist_visualization(img_path)

img_path = '../input/landmark-retrieval-2021/train/6/0/0/6000a31590ca910f.jpg'
color_hist_visualization(img_path)

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques

import plotly.graph_objs as go
from plotly.subplots import make_subplots

show_color_histogram(landmarks_JPG_PATH)

# %%
#Code by Yaroslav Isaienkov https://www.kaggle.com/ihelon/monet-eda-and-visualization-techniques

def batch_visualization(path, n_images, is_random=True, figsize=(16, 16)):
    plt.figure(figsize=figsize)
    
    w = int(n_images ** .5)
    h = math.ceil(n_images / w)
    
    all_names = os.listdir(path)
    
    image_names = all_names[:n_images]
    if is_random:
        image_names = random.sample(all_names, n_images)
    
    for ind, image_name in enumerate(image_names):
        img = cv2.imread(os.path.join(path, image_name))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        plt.subplot(h, w, ind + 1)
        plt.imshow(img)
        plt.axis("off")
    
    plt.show()

# %%
batch_visualization(landmarks_JPG_PATH, 1, is_random=True, figsize=(5, 5))

# %%
batch_visualization(landmarks_JPG_PATH, 4, is_random=True, figsize=(10, 10))

# %% [markdown]
# #Thank you Yaroslav Isaienkov for all the wonderful work you shared with us.
