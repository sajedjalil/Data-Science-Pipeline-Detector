# %%
import os
import pandas as pd

# %%
print(os.listdir('/kaggle/input/landmark-retrieval-2021'))

# %%
df= pd.read_csv('/kaggle/input/landmark-retrieval-2021/sample_submission.csv')
df.to_csv('submission.csv', index=False)
