# %%
from PIL import Image
import os, sys

path = "../input/cassava-leaf-disease-classification/train_images/"
dirs = os.listdir( path )
os.mkdir('/kaggle/working/train_images')

# %%
def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((224,224), Image.ANTIALIAS)
            imResize.save('/kaggle/working/train_images/'+ item, 'JPEG', quality=90)

# %%
resize()

# %%
import shutil
shutil.make_archive('train_images','zip','/kaggle/working/train_images')

# %%
path = "../input/cassava-leaf-disease-classification/test_images/"
dirs = os.listdir( path )
os.mkdir('/kaggle/working/test_images')

# %%
def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((224,224), Image.ANTIALIAS)
            imResize.save('/kaggle/working/test_images/'+ item, 'JPEG', quality=90)

# %%
resize()

# %%
import shutil
shutil.make_archive('test_images','zip','/kaggle/working/test_images')
