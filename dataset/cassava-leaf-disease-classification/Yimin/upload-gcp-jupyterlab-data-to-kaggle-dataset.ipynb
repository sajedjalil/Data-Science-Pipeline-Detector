# %% [markdown]
# # This Notebook shows how to upload your data from GCP JupyterLab to Kaggle Dataset

# %% [markdown]
# ## First, upload *kaggle.json* to root dir

# %% [markdown]
# ### To download *kaggle.json,*
# ### go to Your Profile -> Account -> Create New API Token

# %% [markdown]
# ## Then, in your GCP jupyter Notebook

# %%
## run this code
## to create a dir ~/.kaggle 
## and copy kaggle.json to this dir
## and change the mod

# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
## The version 1.5.10 works well

# !kaggle --version

# %% [markdown]
# ## *FILENAME* is the folder you want to upload to your Kaggle Dataset

# %%
# !kaggle datasets init -p FILENAME/

# %%
'''
{
  "title": "INSERT_TITLE_HERE",
  "id": "YOURUSERNAME/INSERT_TITLE_HERE",
  "licenses": [
    {
      "name": "CC0-1.0"
    }
  ]
}
'''

## Running this code will show the info above.
## go to the folder, open the json file with editor
## change INSERT_TITLE_HERE with the name you like
## Cannot leave it default
## Then CTRL+S
## After, rerun this code to make sure changes are saved

# !cat FILENAME/dataset-metadata.json

# %%
## I don't know this principle ><

# !echo 'hello'>FILENAME/test.txt

# %%
## start upload and make your Kaggle Dataset

# !kaggle datasets create -p FILENAME/

# %% [markdown]
# # Done!

# %% [markdown]
# Reference
#
# https://www.kaggle.com/c/riiid-test-answer-prediction/discussion/206871
#
# https://www.kaggle.com/c/riiid-test-answer-prediction/discussion/208110
