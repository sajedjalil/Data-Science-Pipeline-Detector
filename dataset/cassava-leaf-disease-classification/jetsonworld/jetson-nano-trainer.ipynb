# %% [markdown]
# ## Jetson Nano (2GB, 4GB) Trainer
# <img src = "https://elinux.org/images/6/6d/Jetson_Nano_Family.png" height="50" width="250">

# %%
# Install tqdm
# !pip install tqdm
# !apt install unzip

# %%
# Download Jetson Trainer
# !git clone https://github.com/dusty-nv/pytorch-classification.git

# %%
# Download Cassava Datasets For Jetson Nano Trainer
# modifying

# %%
# Unzip cassava.zip
# tar -zxvf photos_cassava.tar.gz
# !ls
# !pwd
# !unzip /kaggle/working/photos_cassava.zip -d /kaggle/working/pytorch-classification/data
# !ls /kaggle/working/pytorch-classification/data

# %%
# !unzip photos_cassava.zip

# %%
# Make a directory
# !mkdir /kaggle/working/pytorch-classification/models/cassava

# %%
# Set the GPU to train.
# !python3 /kaggle/working/pytorch-classification/train.py --model-dir=/kaggle/working/pytorch-classification/models/cassava --batch-size=256 --worker=1 --epochs=160 /kaggle/working/pytorch-classification/data/cassava

# %%
# See the model 'model_best.pth.tar'.
# !ls /kaggle/working/pytorch-classification/models/cassava
# !cp /kaggle/working/pytorch-classification/models/cassava/model_best.pth.tar /kaggle/working/
# !pwd

# %%
# END
# You can download the traind model from /kaggle/working
