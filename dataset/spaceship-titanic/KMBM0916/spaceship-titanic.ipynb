# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# 컬럼별 설명
#
#
# Passenger ID
# * 각 승객의 고유 ID입니다.
#
# HomePlanet
# * 승객이 출발한 행성, 일반적으로 영구 거주 행성입니다.
#
# 크라이오슬립
# * 승객이 항해 기간 동안 애니메이션을 일시 중단하도록 선택했는지 여부를 나타냅니다.
#
# 선실
# * 승객이 머물고 있는 객실 번호입니다.
#
# 목적지
# * 승객이 출발할 행성입니다.
#
# 나이
# * 승객의 나이.
#
# 요인
# * 승객이 항해 중 특별 VIP 서비스 비용을 지불했는지 여부.
#
# 룸 서비스
# * 승객이 룸서비스에 대해 청구한 금액입니다.
#
# 푸드 코트
# * 승객이 푸드 코트에서 청구한 금액입니다.
#
# 쇼핑몰
# * 승객이 쇼핑몰에서 청구한 금액입니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
train = pd.read_csv('../input/spaceship-titanic/train.csv')  # 다운받은 csv를 pandas의 DataFrame 형식으로 불러옵니다.

# %%
train.head() # 데이터 상위 5개를 확인합니다.

# %%
train.shape # 데이터를 모양을 확인합니다.

# %%
train_df = train
print(train_df.isnull().sum())
train_df = train_df.dropna()

# %%
print(train_df.isnull().sum())

# %%
print(train_df.info())

# %%
print(train_df.columns)

# %%
print(train_df['Cabin'].value_counts())

# %%
print(train_df['Transported'].value_counts())

# %%
print(train_df['VIP'].value_counts())

# %%
print(train_df['Destination'].value_counts())

# %%
print(train_df['CryoSleep'].value_counts())

# %%
train_df.groupby(["CryoSleep", "Transported"])["Transported"].count()

# %%
train_df.groupby(["VIP", "Transported"])["Transported"].count()

# %%
train_df.groupby(["Destination", "Transported"])["Transported"].count()

# %%
CS_plot = sns.barplot(x="CryoSleep", y="Transported", data=train_df)
CS_plot.set_title("CryoSleep")

# %%
HP_plot = sns.barplot(x="HomePlanet", y="Transported", data=train_df)
HP_plot.set_title("HomePlanet")

# %%
CS_plot_VIP = sns.barplot(x="CryoSleep", y="Transported", hue="VIP", data=train_df)
CS_plot_VIP.set_title("CryoSleep_VIP")

# %%
CS_plot_Des = sns.barplot(x="CryoSleep", y="Transported", hue="Destination", data=train_df)
CS_plot_Des.set_title("CryoSleep_Des")

# %%
CS_plot_Des = sns.barplot(x="CryoSleep", y="Transported", hue="Destination", data=train_df)
CS_plot_Des.set_title("CryoSleep_Des")

# %%
CS_plot_Des = sns.barplot(x="Destination", y="Transported", hue="HomePlanet", data=train_df)
CS_plot_Des.set_title("HomePlanet_Des")

# %%
type(train_df)

# %%
test = pd.read_csv('../input/spaceship-titanic/test.csv')

# %%
test_df = test
type(test_df)

# %%
test_df.head()

# %%
train_df.head()

# %%
test.shape

# %%
train_df.isnull().sum()

# %%
test_df.isnull().sum()

# %%
test_df = test_df.dropna()

# %%
test_df.isnull().sum()

# %%
from sklearn.linear_model import LogisticRegression
ml = LogisticRegression(solver='lbfgs')

# %%
train_df.columns

# %%
import seaborn as sns

homeplanet_mapping = {"TRAPPIST-le": 0, "PSO J318.5-22": 1, "55 Cancri e": 2}
train_df["HomePlanet"] = train_df.loc["HomePlanet"].map(homeplanet_mapping)
test_df["HomePlanet"] = test_df.loc["HomePlanet"].map(homeplanet_mapping)

# %%
x = train_df.drop(['PassengerId', 'Cabin', 'Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Name', 'Transported'], axis=1)
y = train_df['Transported']
ml.fit(x, y)

# %%
import matplotlib.pyplot as plt

# %%
train

# %%
fig, ax = plt.subplots() #Basic
ax.hist(train['Transported'].value_counts())
ax.set_title('Current Titanic crew transported situation')
ax.set_xlabel('Confirmation')
ax.set_ylabel('Frequency')
