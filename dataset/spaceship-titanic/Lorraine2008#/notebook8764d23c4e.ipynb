# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
working_directory =os.getcwd()
print(working_directory)

# %%
path =working_directory +'input/spaceship-titanic/sample_submission.csv'

# %%
#READ DATA

# %% [markdown]
# ****

# %%
import pandas as pd
import numpy as np

# %%
df_train =pd.read_csv('/kaggle/input/spaceship-titanic/train.csv')

# %%
df_test=pd.read_csv('/kaggle/input/spaceship-titanic/test.csv')

# %%
df_test.head()

# %%
df_test.info()

# %%
df_train.head()

# %%
df_train.info()

# %%
df_train.describe()

# %%
df_train.isnull()

# %%
#Data exploration anaysis

# %%
#Categorical attribute

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.set(stlye='white grid',palette=deep',font-scale=1.1,rc=figure.figsize,:[8,5]

# %%
sns.countplot(df_train['VIP'])

# %%
sns.countplot(df_train['Destination'])

# %%
sns.countplot(df_train['Name'])

# %%
sns.countplot(df_train['cabin'])

# %%
#Analysis of all Categorical variables

# %%
fig, ax = plt.subplots(2, 4, figsize=(20, 10))
for variable, subplot in zip(categorical, ax.flatten()):
    sns.countplot(df_train[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %%
# Numerical attributes.

# %%
sns.displot(df_train['Age'])

# %%
sns.displot(df_train['ShoppingMall'])

# %%
sns.displot(df_train['Spa'])

# %%
sns.displot(df_train['Spa'])

# %%
sns.displot(df_train['Vrdec'])

# %%
numerical _variable='Age','Spa','Vrdec','shopping mall','transported'
df_train(numerical _variables['Age','Spa','Vrdec','shopping mall','transported']).hist(bins=15, figsize=(15, 6), layout=(2, 4));

# %% [markdown]
# # Attribute Relationships

# %% [markdown]
# # Correlations

# %%
sns.scatterplot=sns.scatterplot(x=df_train['Age'], y=['Transported'])

# %% [markdown]
# # Feature Selection

# %% [markdown]
# #Combining dataframes

# %%
pd.merge(df_train,df_test,on='Age',how='right')
df=final_df()
final_df.head(2)

# %%
final_df.info()

# %%
df_train.head()

# %%
df_train.tail()

# %% [markdown]
# #

# %%
df_test.head()

# %%
# COMBINING THE DATAFRAMES

# %%
df_train=df.drop(columns['passengersId','cabin','name'],axis=1)
df_train.head()

# %%
df.info()

# %% [markdown]
# # Fill missing values using mean of that column

# %%
df_test.head()

# %%
df_test.isnull()

# %%
# Imputing missing values with mode value

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Train and test columns

# %%
Train_columns =df_train. columns
Test_columns = df_test.columns

# %% [markdown]
# Imputing the values

# %%
impute = simple imputer(strategy= 'most_frequent')

# %%
df_train =impute.fit_transform(df-train)
df_test = impute.fit_transform(df_test)

# %%
print(df_train)

# %% [markdown]
# #Returning the columns

# %%
df_train =pd.dataframe(df_train,columns =train_columns)
df_test  =pd.dataframe(df_test,columns =test_column)

# %%
df_train.head(5)

# %%
# Separating all features that are correlated

# %%
id_columns =['Passenger group', 'passeners number']
Cabin_columns =[Deck',' Deck number','side']

# %% [markdown]
# # Split train dataset

# %%
#Providing column names

# %%
Sepr_cabin_test =df_test[Cabin].str.split('/',n=-1,expand =true)
Sepr_id_test = df_test['Passenger id'].str.split('_',n=-1,expand =true)

# %% [markdown]
# #Providing column names for test dataset

# %% [markdown]
# #Combine cabin and Id column into the main data frame

# %%
df_train =pd.concat([df_tran,Sepr_cabin,sepr_id],axis=1)
df_test =pd.concat([df_test,sepr_cabin, sepr_id],axis=1)

# %%
#Drop Columns

# %%
df.drop(columns=['passengers id','cabin'],axis=1,inplace=True)

# %%
df_train.head()

# %%
df_train.info()

# %% [markdown]
# #VISUALISATION

# %% [markdown]
# #Numerical Attributes

# %%
import seaborn as sns

# %% [markdown]
# ****
