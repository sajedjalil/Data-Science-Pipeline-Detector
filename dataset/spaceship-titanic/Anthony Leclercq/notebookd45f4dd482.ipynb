# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

# %% [markdown]
# # Chargement des différents fichiers de data

# %%
train = pd.read_csv("../input/spaceship-titanic/train.csv")
test = pd.read_csv("../input/spaceship-titanic/test.csv")
submission = pd.read_csv("../input/spaceship-titanic/sample_submission.csv")

# %% [markdown]
# # Affiche les 5 premières lignes

# %%
train.head()

# %% [markdown]
# # Affiche les valeurs manquantes par colonne

# %%
print(train.isna().sum().sort_values(ascending = False))

# %% [markdown]
# # Remplissage des valeurs avec la median

# %%
imputer_cols = ["Age", "FoodCourt", "ShoppingMall", "Spa", "VRDeck" ,"RoomService"]
imputer = SimpleImputer(strategy="median" )
imputer.fit(train[imputer_cols])
train[imputer_cols] = imputer.transform(train[imputer_cols])
train["HomePlanet"].fillna('Kelper', inplace=True)

# %%
print(train.isna().sum().sort_values(ascending = False))

# %% [markdown]
# # Affiche les stats de chaque variables

# %%
train.describe()

# %% [markdown]
# # Utilisation StandardScaler

# %%
scaler = StandardScaler()
imputer_cols = ["Age", "FoodCourt", "ShoppingMall", "Spa", "VRDeck" ,"RoomService"]
scaled_df = scaler.fit_transform(train[imputer_cols])
scaled_df = pd.DataFrame(scaled_df, columns=imputer_cols)

# %% [markdown]
# # Utilisation du labelEncoder sur les variables catégorielles

# %%
label_cols = ["HomePlanet", "CryoSleep","Cabin", "Destination" ,"VIP"]
def label_encoder(train,columns):
    for col in columns:
        train[col] = train[col].astype(str)
        train[col] = LabelEncoder().fit_transform(train[col])
    return train

train = label_encoder(train, label_cols)
