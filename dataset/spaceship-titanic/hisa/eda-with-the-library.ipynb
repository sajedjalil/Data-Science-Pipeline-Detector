# %%
#import library

from pathlib import Path
# !pip install pandas-profiling
# !pip install sweetviz

# %%
#EDA tools import 

from pandas_profiling import ProfileReport
import sweetviz as sv

# %%
#Loading data

import pandas as pd

data_dir = Path('../input/spaceship-titanic')

train = pd.read_csv(data_dir / 'train.csv')
test = pd.read_csv(data_dir / 'test.csv')

# %%
train.head()

# %%
test.head()

# %%
#Pandas_profiling

profile = ProfileReport(train, title='Spaceship Titanic EDA', explorative=True)

profile.to_widgets()

# %%
#Sweetviz

sweetviz_EDA = sv.analyze(train)
sweetviz_EDA.show_html("sweetviz_EDA.html")
