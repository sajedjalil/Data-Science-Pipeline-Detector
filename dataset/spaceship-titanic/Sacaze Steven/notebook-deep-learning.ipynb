# %% [markdown]
# # From : Yahse Koffi et Steven Sacaze #

# %% [markdown]
# # Projet 1 : #
#
# Dans se projet, il est demandé de créer une architechture avec KERAS et un entrainement de modèle, sur le projet spaceship-titanic.
#
# https://www.kaggle.com/competitions/spaceship-titanic
#
# Le rendu comportera :
#
#     - Un seul neurone
#     - 1 couche de 512 neurones
#     - 3 couches de respectivement 512, 256, 128 neurones
#     - Ajoutez un Dropout
#     - Ajoutez un BatchNormalization
#
# Choisir le nombre d'Epoch pour les architectures
#
# Travaillez la donnée Catégorielle, si il y a afin de la rendre utilisable par le modèle.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#ALL import
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

import tensorflow as tf

# %%
# Setup plotting
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex1 import *

# %%
# lecture du fichier train.csv
train_data = pd.read_csv('../input/spaceship-titanic/train.csv')
train_data.head()

# ajout des paramètre du dropout
X = train_data.copy().dropna()
y = X.pop('Destination')
don = X['PassengerId']

train_data.shape
input_shape = [14]
#print(train_data.shape)
print(y)

# %% [markdown]
# # Un seul neurone : #
# Définir un modèle linéair et regarder les poids

# %%
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[14])
])
w, b = model.weights

print("Weights\n{}\n\nBias\n{}".format(w, b))

# %% [markdown]
# Tracer la sortie d'un modèle linéaire non formé

# %%
model = keras.Sequential([
    layers.Dense(1, input_shape=[1]),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w, b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %% [markdown]
# # Réseau neuronal #

# %% [markdown]
# Définir un modèle avec des calques masqués et les Couches d'activation
#
# # Ajoutez un Dropout au réseau neuronal#

# %%
# YOUR CODE HERE
model = keras.Sequential([
    layers.Dropout(rate=0.3),
    layers.Dense(512, activation='relu', input_shape=input_shape),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w,b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %%
# YOUR CODE HERE
model = keras.Sequential([
    layers.Dropout(rate=0.3),
    layers.Dense(256, activation='relu', input_shape=input_shape),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w,b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %%
# YOUR CODE HERE
model = keras.Sequential([
    layers.Dropout(rate=0.3),

    layers.Dense(128, activation='relu', input_shape=input_shape),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w,b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %%
model = keras.Sequential([
    layers.Dropout(rate=0.3),
    layers.Dense(1,activation='relu', input_shape=[1]),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w, b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %% [markdown]
# # Ajouter un batch de normalisation #

# %%
model = keras.Sequential([
    layers.BatchNormalization(input_shape=[1]),
    layers.Dense(128,activation='relu'),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %%
model = keras.Sequential([
    layers.BatchNormalization(input_shape=[1]),
    layers.Dense(256,activation='relu'),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()

# %%
model = keras.Sequential([
    layers.BatchNormalization(input_shape=[1]),
    layers.Dense(512,activation='relu'),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()
