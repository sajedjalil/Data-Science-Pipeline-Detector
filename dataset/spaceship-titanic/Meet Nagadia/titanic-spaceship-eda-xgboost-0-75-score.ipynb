# %% [markdown]
# # **🚀 Spaceship Titanic: EDA (Just Started)**
# Work in Progress, This notebook is not completed yet
# but is updated daily

# %% [markdown]
# ![](https://c.tenor.com/4wAtE3WwF1wAAAAd/space-gif-space.gif)
#
# - The Goal of this Competitions is to
# To help rescue crews and retrieve the lost passengers, you are challenged to predict which passengers were transported by the anomaly using records recovered from the spaceship’s damaged computer system.
#
# Help save them and change history!

# %% [markdown]
# # Loading the Necessary Library 🚀

# %%
# these library are for data manipulation 
import pandas as pd
import numpy as np

#these library are for visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # File and Data Field Descriptions 📁
# - train.csv - Personal records for about two-thirds (8700) of the passengers, to be used as training data.
# > - PassengerId - A unique Id for each passenger. Each Id takes the form gggg_pp where gggg indicates a group the passenger is travelling with and pp is their number within the group. People in a group are often family members, but not always. <br>
# > - HomePlanet - The planet the passenger departed from, typically their planet of permanent residence. <br>
# > - CryoSleep - Indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Passengers in cryosleep are confined to their cabins.<br>
# > - Cabin - The cabin number where the passenger is staying. Takes the form deck/num/side, where side can be either P for Port or S for Starboard. <br>
# > - Destination - The planet the passenger will be debarking to. <br>
# > - Age - The age of the passenger. <br>
# > - VIP - Whether the passenger has paid for special VIP service during the voyage. <br>
# > - RoomService, FoodCourt, ShoppingMall, Spa, VRDeck - Amount the passenger has billed at each of the  Spaceship Titanic's many luxury amenities. <br>
# > - Name - The first and last names of the passenger. <br>
# > - Transported - Whether the passenger was transported to another dimension. This is the target, the
# column you are trying to predict. <br>
#
# - test.csv - Personal records for the remaining one-third (~4300) of the passengers, to be used as test data. Your task is to predict the value of Transported for the passengers in this set.
#
#
# - sample_submission.csv:  A submission file in the correct format.
# > PassengerId - Id for each passenger in the test set. <br>
# > Transported - The target. For each passenger, predict either True or False.

# %% [markdown]
# # Loading the dataset

# %%
# Loading train data and test data and submission file

train_data= pd.read_csv('../input/spaceship-titanic/train.csv')
test_data= pd.read_csv('../input/spaceship-titanic/test.csv')
sub = pd.read_csv("../input/spaceship-titanic/sample_submission.csv")

# %% [markdown]
# # 🪐 Exploring Data 🌐

# %%
# lets first see the dimension of the training dataset

print(train_data.shape)

# %%
# lets first see the dimension of the testing dataset

print(test_data.shape)

# %%
##lets first see the dimension of the submission

print(sub.shape)

# %%
# Displaying first rows of the training data

train_data.head()

# %%
# Displaying first rows of the testing data

test_data.head()

# %%
# Displaying first rows of the submission file

sub.head()

# %% [markdown]
# - Now lets check the datatype of the dataset

# %%
# this will print the datatype present in the columns of the training dataset

print(train_data.dtypes)

# %%
# this will print the datatype present in the columns of the training dataset

print(test_data.dtypes)

# %% [markdown]
# # Checking for Null Values

# %%
# isnull() we give us the bool value, if null value is present it gives True or else False
# isnull().sum() will give us the number of the null value present in the dataset

train_data.isnull().sum()

# %%
test_data.isnull().sum()

# %% [markdown]
# - **Note:** We do have null values in the dataset

# %% [markdown]
# ![](https://i.kym-cdn.com/photos/images/newsfeed/000/865/302/3d5.gif)

# %% [markdown]
# - We can deal null values in many ways, it depends upon the data as well as how we apply the technique

# %% [markdown]
# # Preprocessing Data
# > Here since we have missing values in both training and testing dataset we need to deal with first before moving to EDA and model building.<br>
# > We can do a whole lot of stuff to remove null values, to start with we can remove all the null values present in the training as well as testing.<br>
# > Is that right thing to do ??<br>
# > We can do that but we might loose some columns. If the dataset is huge and missing values are low we can just drop them it wil not affect that much to performance of the model.<br>
# > Here that's not the case, What to do in these suitation??<br>
# > We can replace the missing data with the mean of the column or by taking the median of the column and replacing it with null values.<br>
# > Here we will replace it with median of the column.

# %%
# These all column contains the null values which are being replaced by median of the column.

train_data["Age"].fillna(train_data["Age"].median(skipna=True), inplace=True)
test_data["Age"].fillna(test_data["Age"].median(skipna=True), inplace=True)

train_data["FoodCourt"].fillna(train_data["FoodCourt"].median(skipna=True), inplace=True)
test_data["FoodCourt"].fillna(test_data["FoodCourt"].median(skipna=True), inplace=True)

train_data["ShoppingMall"].fillna(train_data["ShoppingMall"].median(skipna=True), inplace=True)
test_data["ShoppingMall"].fillna(test_data["ShoppingMall"].median(skipna=True), inplace=True)

train_data["Spa"].fillna(train_data["Spa"].median(skipna=True), inplace=True)
test_data["Spa"].fillna(test_data["Spa"].median(skipna=True), inplace=True)

train_data["VRDeck"].fillna(train_data["VRDeck"].median(skipna=True), inplace=True)
test_data["VRDeck"].fillna(test_data["VRDeck"].median(skipna=True), inplace=True)

train_data["RoomService"].fillna(train_data["RoomService"].median(skipna=True), inplace=True)
test_data["RoomService"].fillna(test_data["RoomService"].median(skipna=True), inplace=True)

# %%
# Here HomePlanet is having values such as Earth Europa and Mars we can't take median of 
# such values since they are string

train_data["HomePlanet"].value_counts()

# %%
# Instead of removing them we can fill them using fillna() and insert with dummy values

train_data["HomePlanet"].fillna('Flat_Earth', inplace=True)
test_data["HomePlanet"].fillna('Flat_Earth', inplace=True)

# %%
# Checking the null values that has been replaced by mean

train_data.isnull().sum()

# %%
# Checking the null values that has been replaced by mean

test_data.isnull().sum()

# %% [markdown]
# **Note:** We will have missing values, Lets have a look at what kind of values this column contains

# %%
"""CryoSleep:Indicates whether the passenger elected to be put into suspended animation for 
 the duration of the voyage. Passengers in cryosleep are confined to their cabins"""

train_data.CryoSleep.value_counts()

# %%
"""Cabin:he cabin number where the passenger is staying. Takes the form deck/num/side, where 
side can be either P for Port or S for Starboard."""

train_data.Cabin.value_counts()

# %%
"""Destination:The planet the passenger will be debarking to."""

train_data.Destination.value_counts()

# %%
"""VIP:Whether the passenger has paid for special VIP service during the voyage."""

train_data.VIP.value_counts()

# %%
"""RoomService: Amount the passenger has billed at each of the Spaceship Titanic's many luxury amenities."""

train_data.RoomService.value_counts()

# %%
"""Name: The first and last names of the passenger."""

train_data.Name.value_counts()

# %% [markdown]
# - We can't just blindly put the median of these values(it affect the performance of the model), we can just drop them using dropna()

# %%
# using dropna() to remove rest of missing values in training and testing data

train_data = train_data.dropna()
test_data = test_data.dropna()

# %%
# Final checking for null values

train_data.isnull().sum()

# %%
# Final checking for null values

test_data.isnull().sum()

# %% [markdown]
# ![](https://thumbs.gfycat.com/ImprobableFarflungHapuka-max-1mb.gif)

# %% [markdown]
# # EDA 📊

# %%
# First lets see the columns of the training dataset

train_data.columns

# %%
# lets see the columns of the testing dataset

test_data.columns

# %% [markdown]
# - Let's create the a new Dataframe for EDA so we dont alter with any of the dataset present.
# - We will explore only Training dataset.

# %%
eda_data = train_data

# %%
eda_data.shape

# %%
eda_data.head()

# %%
eda_data.columns

# %% [markdown]
# - Since we cannot perform EDA on some columns we can simply drop them as of now.
#
# **Note: we are using eda_data and not our training data or testing data**

# %%
eda_data.drop(['PassengerId','Name','Cabin','RoomService','FoodCourt','ShoppingMall','Spa','VRDeck'],axis=1,inplace=True)

# %%
eda_data.columns

# %% [markdown]
# - Now we can start our EDA

# %%
hp = eda_data.HomePlanet.value_counts()
hp

# %%
# Plotting Histogram

eda_data.HomePlanet.hist(bins=10,color='pink')
plt.title('Home Planet of the Passenagers')
plt.show()

# %%
# Plotting Pie Chart 

fig = px.pie(eda_data, values=hp.values, names=hp.index, title='Home Planet of the Passengers')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
# Plotting Barchart using Plottty

fig = go.Figure([go.Bar(x=hp.index, y=hp.values,text=hp.values,
            textposition='auto')])
fig.update_layout(title_text='Home Planet of the Passengers')
fig.show()

# %% [markdown]
# - Conclusion on Home Planet:
# > - Through plotting we can say that the data of home planet is not distributed properly since Earth has more passengers than other planets.<br>
# > - Europa Stands second on the most passengers list with 1891 passengers.<br>
# > - Mars stands third with 1567 passengers.<br>
# > - Then we have Flath_Earth with 180 passengers since, we have given this dummy value we will consider it as of now

# %% [markdown]
# - CryoSleep: Indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Passengers in cryosleep are confined to their cabins.

# %%
cs = eda_data.CryoSleep.value_counts()
cs

# %%
# Plotting Pie Chart 

fig = px.pie(eda_data, values=cs.values, names=cs.index, title='CryoSleep of Passengers')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
# Plotting Barchart using Plottty

fig = go.Figure([go.Bar(x=cs.index, y=cs.values,text=cs.values,
            textposition='auto')])
fig.update_layout(title_text='CryoSleep of the Passengers')
fig.show()

# %% [markdown]
# - Conclusion on CryoSleep:
# > As we can see via Plotting most of the Passengers were not CryoSleep about 64%.<br>
# > Only about 35% were on CryoSleep as per the training data.

# %% [markdown]
# - Destination: The planet the passenger will be debarking to.

# %%
des = eda_data.Destination.value_counts()
des

# %%
# Plotting Histogram

eda_data.Destination.hist(bins=10,color='pink')
plt.title('Destination of the Passenagers')
plt.show()

# %%
# Plotting Pie Chart 

fig = px.pie(eda_data, values=des.values, names=des.index, title='Destination of Passengers')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
# Plotting Barchart using Plottty

fig = go.Figure([go.Bar(x=des.index, y=des.values,text=des.values,
            textposition='auto')])
fig.update_layout(title_text='Destination of the Passengers')
fig.show()

# %% [markdown]
# - Conclusion on Destination of the Passengers:
# > As we can see again the data is not properly distribured.<br>
# > TRAPPIST-1e has the most passenger will be debarking to(5392 passengers).<br>
# > 55 Canri e has the medium passenger will be debarking to(1624 passengers).<br>
# > While PSO J318.5-22 has the least passenger will be debarking to(723 passengers).<br>

# %% [markdown]
# Image of TRAPPIST-1e
# ![](https://ourplnt.com/wp-content/uploads/2018/05/TRAPPIST-1e-artist-conception.jpg)

# %% [markdown]
# Image of 55 Canri e
# ![](https://i.pinimg.com/originals/72/3a/ff/723affe8f588f9ba78fa6832f6fa9a41.jpg)

# %% [markdown]
# Image of PSO_J318.5
# ![](https://upload.wikimedia.org/wikipedia/commons/e/e2/PSO_J318.5-22_image_from_the_Pan-STARRS1_telescope.png)

# %%
age = eda_data.Age.value_counts()
age

# %%
# Plotting Histogram

eda_data.Age.hist(bins=10,color='yellow')
plt.title('Distribution of Age of the Passenagers')
plt.show()

# %%
# Plotting Pie Chart 

fig = px.pie(eda_data, values=age.values, names=age.index, title='Age of Passengers')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %%
# The below written code is of by @Ruchi_Bhatia
def hist(col,title):
    
    plt.figure(figsize = (10,8))
    
    ax = sns.histplot(col,kde=False);
    
    values = np.array([patch.get_height() for patch in ax.patches])
    
    #normalizing the values to get a range of colours
    norm = plt.Normalize(values.min(), values.max())
    
    #range of colours from colourmap-rainbow
    colors = plt.cm.rainbow(norm(values))
    
    #set colour for each patch
    for patch, color in zip(ax.patches, colors):
        patch.set_color(color)

    plt.title(title, size = 20)
    
hist(train_data['Age'],'Distribution of Age')

# %%
# Plotting Barchart using Plottty

fig = go.Figure([go.Bar(x=age.index, y=age.values,text=age.values,textposition='auto')])
fig.update_layout(title_text='Distribution of Age of the Passengers')
fig.show()

# %% [markdown]
# - Conclusion of Age of the Passengers:
# > As excepted No Normal Distribution of the data.<br>
# > Most Passengers(395) have their Age as 27.<br>
# > The Highest Age of the passengers avialable is 79.<br>

# %% [markdown]
# - VIP: Whether the passenger has paid for special VIP service during the voyage.

# %%
vip = eda_data.VIP.value_counts()
vip

# %%
# Plotting Barchart using Plottty

fig = go.Figure([go.Bar(x=vip.index, y=vip.values,text=vip.values,
            textposition='auto')])
fig.update_layout(title_text='Count of VIP Passengers')
fig.show()

# %%
# Plotting Pie Chart 

fig = px.pie(eda_data, values=vip.values, names=vip.index, title='Count of VIP Passengers')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# - Conclusion on VIP Passengers:
# > From plotting we can say that most of the Passengers were not VIP passengers.<br>
# > The total Count of VIP passengers are 185.<br>
# > The total Count of Non-VIP passengers are 7554.

# %% [markdown]
# - Transported: Whether the passenger was transported to another dimension. This is the target, the column you are trying to predict.

# %%
tp = eda_data.Transported.value_counts()
tp

# %%
# Plotting Barchart using Plottty

fig = go.Figure([go.Bar(x=tp.index, y=tp.values,text=tp.values,
            textposition='auto')])
fig.update_layout(title_text='Count of Transported Passengers')
fig.show()

# %%
# Plotting Pie Chart 

fig = px.pie(eda_data, values=tp.values, names=tp.index, title='Count of Transported Passengers')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Prediction

# %%
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
train_df =pd.read_csv("../input/spaceship-titanic/train.csv") 
test_df = pd.read_csv("../input/spaceship-titanic/test.csv")

# %%
imputer_cols = ["Age", "FoodCourt", "ShoppingMall", "Spa", "VRDeck" ,"RoomService"]
imputer = SimpleImputer(strategy="median" )
imputer.fit(train_df[imputer_cols])
train_df[imputer_cols] = imputer.transform(train_df[imputer_cols])
test_df[imputer_cols] = imputer.transform(test_df[imputer_cols])
train_df["HomePlanet"].fillna('Z', inplace=True)
test_df["HomePlanet"].fillna('Z', inplace=True)

# %%
label_cols = ["HomePlanet", "CryoSleep","Cabin", "Destination" ,"VIP"]
def label_encoder(train,test,columns):
    for col in columns:
        train[col] = train[col].astype(str)
        test[col] = test[col].astype(str)
        train[col] = LabelEncoder().fit_transform(train[col])
        test[col] =  LabelEncoder().fit_transform(test[col])
    return train, test

train_df ,test_df = label_encoder(train_df,test_df ,label_cols)

# %%
X_train = train_df.drop(["Transported","Name"], axis =1 )
y_train = train_df["Transported"]
X_test = test_df.drop("Name",axis=1)

# %%
X_train.dtypes

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
X_train["PassengerId"] = le.fit_transform(X_train["PassengerId"])
X_test["PassengerId"]= le.fit_transform(X_test["PassengerId"])

# %%
X_train.dtypes

# %%
import xgboost as xgb
my_model = xgb.XGBClassifier()
my_model.fit(X_train, y_train)
   
# Predicting the Test set results
y_pred = my_model.predict(X_test)

# %%
y_pred

# %% [markdown]
# # Submission:
#
# > As of now we will just submit the original submission.<br>
# > In upcoming days I wil create a Model for prediction then we will generate our own submission.csv

# %%
X_test["PassengerId"]= le.inverse_transform(X_test["PassengerId"])

# %%
X_test.dtypes

# %%
submission = pd.DataFrame(
    {'PassengerId':X_test["PassengerId"] ,
     'Transported': y_pred},columns=['PassengerId', 'Transported'])

# %%
submission.to_csv("submission.csv",index=False)

# %%
submission.shape

# %% [markdown]
# # Work in Progress

# %% [markdown]
# # [Prediction with Random forest score 0.79471](https://www.kaggle.com/meetnagadia/titanic-random-forest-score-0-79471?scriptVersionId=89388637)

# %% [markdown]
# If you found this notebook useful then dont forget to
#
# ![](https://c.tenor.com/YW9-svTAIsgAAAAM/leonardo-dicaprio-upvote.gif)

# %% [markdown]
# Any Feedback is appericated
