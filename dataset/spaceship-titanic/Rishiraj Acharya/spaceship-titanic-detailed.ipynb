# %% [markdown]
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/34377/logos/header.png?t=2022-02-11-21-53-06)

# %% [markdown]
# # <center>🛠️ 𝙄𝙣𝙨𝙩𝙖𝙡𝙡 𝙇𝙞𝙗𝙧𝙖𝙧𝙞𝙚𝙨</center>

# %%
# !pip install pandas-profiling[notebook]

# %% [markdown]
# # <center>📚 𝙄𝙢𝙥𝙤𝙧𝙩 𝙇𝙞𝙗𝙧𝙖𝙧𝙞𝙚𝙨</center>

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %% [markdown]
# # <center>📊 𝙀𝙭𝙥𝙡𝙤𝙧𝙖𝙩𝙤𝙧𝙮 𝘿𝙖𝙩𝙖 𝘼𝙣𝙖𝙡𝙮𝙨𝙞𝙨</center>

# %%
profile = ProfileReport(pd.read_csv("../input/spaceship-titanic/train.csv"), title="Spaceship Titanic EDA", explorative=True)
profile.to_widgets()

# %%
profile.to_notebook_iframe()

# %% [markdown]
# ## <center>𝙁𝙤𝙪𝙣𝙙 𝙩𝙝𝙞𝙨 𝙣𝙤𝙩𝙚𝙗𝙤𝙤𝙠 𝙪𝙨𝙚𝙛𝙪𝙡? 𝙔𝙤𝙪 𝙢𝙖𝙮 𝙨𝙪𝙥𝙥𝙤𝙧𝙩 𝙬𝙞𝙩𝙝 𝙖𝙣 𝙐𝙥𝙫𝙤𝙩𝙚! 👍</center>
