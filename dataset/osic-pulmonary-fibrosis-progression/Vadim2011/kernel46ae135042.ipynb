# %%
Patient_Week,FVC,Confidence
ID00419637202311204720264_-12,3093.458810682,206.81509177590686
ID00421637202311550012437_-12,2834.562831747354,226.1789338392573
ID00422637202311677017371_-12,2015.7041708775535,218.5947663647305
ID00423637202312137826377_-12,3390.6688852989246,211.91406814530504
ID00426637202313170790466_-12,2984.663948324545,235.04097867773044
ID00419637202311204720264_-11,3089.6803493011766,206.87368080507528
ID00421637202311550012437_-11,2830.7843703665308,226.23752286842574
ID00422637202311677017371_-11,2011.9257094967297,218.6533553938989
ID00423637202312137826377_-11,3386.890423918101,211.97265717447345
ID00426637202313170790466_-11,2980.885486943722,235.09956770689885
ID00419637202311204720264_-10,3085.9018879203536,206.93226983424367
ID00421637202311550012437_-10,2827.0059089857073,226.29611189759413
ID00422637202311677017371_-10,2008.1472481159065,218.7119444230673
ID00423637202312137826377_-10,3383.1119625372776,212.03124620364187
ID00426637202313170790466_-10,2977.1070255628983,235.15815673606727
ID00419637202311204720264_-9,3082.1234265395296,206.9908588634121
ID00421637202311550012437_-9,2823.2274476048833,226.35470092676258
ID00422637202311677017371_-9,2004.3687867350832,218.77053345223572
ID00423637202312137826377_-9,3379.333501156454,212.0898352328103
ID00426637202313170790466_-9,2973.3285641820744,235.2167457652357
ID00419637202311204720264_-8,3078.3449651587066,207.04944789258053
ID00421637202311550012437_-8,2819.4489862240603,226.41328995593096
ID00422637202311677017371_-8,2000.5903253542597,218.82912248140417
ID00423637202312137826377_-8,3375.5550397756306,212.1484242619787
ID00426637202313170790466_-8,2969.550102801251,235.2753347944041
ID00419637202311204720264_-7,3074.566503777883,207.10803692174892
ID00421637202311550012437_-7,2815.670524843237,226.4718789850994
ID00422637202311677017371_-7,1996.8118639734362,218.8877115105726
ID00423637202312137826377_-7,3371.776578394807,212.20701329114712
ID00426637202313170790466_-7,2965.7716414204274,235.33392382357252
ID00419637202311204720264_-6,3070.7880423970596,207.16662595091734
ID00421637202311550012437_-6,2811.8920634624137,226.5304680142678
ID00422637202311677017371_-6,1993.0334025926127,218.946300539741
ID00423637202312137826377_-6,3367.998117013984,212.26560232031554
ID00426637202313170790466_-6,2961.9931800396043,235.39251285274094
ID00419637202311204720264_-5,3067.009581016236,207.22521498008575
ID00421637202311550012437_-5,2808.1136020815898,226.58905704343618
ID00422637202311677017371_-5,1989.2549412117892,219.0048895689094
ID00423637202312137826377_-5,3364.21965563316,212.32419134948393
ID00426637202313170790466_-5,2958.214718658781,235.45110188190935
ID00419637202311204720264_-4,3063.231119635413,207.2838040092542
ID00421637202311550012437_-4,2804.3351407007667,226.64764607260463
ID00422637202311677017371_-4,1985.4764798309657,219.06347859807784
ID00423637202312137826377_-4,3360.4411942523366,212.38278037865234
ID00426637202313170790466_-4,2954.4362572779573,235.50969091107774
ID00419637202311204720264_-3,3059.452658254589,207.34239303842259
ID00421637202311550012437_-3,2800.5566793199428,226.70623510177305
ID00422637202311677017371_-3,1981.6980184501422,219.12206762724625
ID00423637202312137826377_-3,3356.662732871513,212.4413694078208
ID00426637202313170790466_-3,2950.657795897134,235.56827994024619
ID00419637202311204720264_-2,3055.6741968737656,207.40098206759097
ID00421637202311550012437_-2,2796.7782179391197,226.76482413094146
ID00422637202311677017371_-2,1977.919557069319,219.18065665641464
ID00423637202312137826377_-2,3352.88427149069,212.49995843698923
ID00426637202313170790466_-2,2946.87933451631,235.6268689694146
ID00419637202311204720264_-1,3051.895735492942,207.45957109675942
ID00421637202311550012437_-1,2792.999756558296,226.82341316010985
ID00422637202311677017371_-1,1974.1410956884954,219.23924568558306
ID00423637202312137826377_-1,3349.105810109866,212.55854746615762
ID00426637202313170790466_-1,2943.100873135487,235.685457998583
ID00419637202311204720264_0,3048.1172741121186,207.51816012592786
ID00421637202311550012437_0,2789.2212951774727,226.8820021892783
ID00422637202311677017371_0,1970.362634307672,219.29783471475147
ID00423637202312137826377_0,3345.327348729043,212.617136495326
ID00426637202313170790466_0,2939.3224117546633,235.74404702775144
ID00419637202311204720264_1,3044.3388127312955,207.57674915509628
ID00421637202311550012437_1,2785.442833796649,226.9405912184467
ID00422637202311677017371_1,1966.5841729268486,219.3564237439199
ID00423637202312137826377_1,3341.5488873482195,212.67572552449445
ID00426637202313170790466_1,2935.5439503738403,235.80263605691982
ID00419637202311204720264_2,3040.560351350472,207.6353381842647
ID00421637202311550012437_2,2781.6643724158257,226.99918024761513
ID00422637202311677017371_2,1962.8057115460251,219.41501277308834
ID00423637202312137826377_2,3337.7704259673965,212.73431455366287
ID00426637202313170790466_2,2931.7654889930163,235.86122508608827
ID00419637202311204720264_3,3036.7818899696485,207.69392721343308
ID00421637202311550012437_3,2777.885911035002,227.05776927678352
ID00422637202311677017371_3,1959.0272501652016,219.47360180225672
ID00423637202312137826377_3,3333.9919645865725,212.7929035828313
ID00426637202313170790466_3,2927.987027612193,235.91981411525666
ID00419637202311204720264_4,3033.003428588825,207.7525162426015
ID00421637202311550012437_4,2774.1074496541787,227.11635830595193
ID00422637202311677017371_4,1955.2487887843781,219.53219083142514
ID00423637202312137826377_4,3330.2135032057495,212.85149261199967
ID00426637202313170790466_4,2924.2085662313693,235.97840314442507
ID00419637202311204720264_5,3029.2249672080015,207.81110527176992
ID00421637202311550012437_5,2770.3289882733557,227.17494733512035
ID00422637202311677017371_5,1951.4703274035548,219.59077986059356
ID00423637202312137826377_5,3326.4350418249255,212.91008164116812
ID00426637202313170790466_5,2920.4301048505463,236.0369921735935
ID00419637202311204720264_6,3025.446505827178,207.8696943009383
ID00421637202311550012437_6,2766.5505268925317,227.2335363642888
ID00422637202311677017371_6,1947.6918660227311,219.64936888976194
ID00423637202312137826377_6,3322.656580444102,212.96867067033654
ID00426637202313170790466_6,2916.651643469723,236.09558120276193
ID00419637202311204720264_7,3021.6680444463545,207.92828333010675
ID00421637202311550012437_7,2762.7720655117087,227.29212539345718
ID00422637202311677017371_7,1943.9134046419078,219.7079579189304
ID00423637202312137826377_7,3318.878119063279,213.02725969950495
ID00426637202313170790466_7,2912.8731820888993,236.1541702319303
ID00419637202311204720264_8,3017.889583065531,207.98687235927517
ID00421637202311550012437_8,2758.9936041308847,227.3507144226256
ID00422637202311677017371_8,1940.1349432610843,219.76654694809878
ID00423637202312137826377_8,3315.0996576824555,213.08584872867334
ID00426637202313170790466_8,2909.0947207080762,236.21275926109877
ID00419637202311204720264_9,3014.1111216847075,208.04546138844358
ID00421637202311550012437_9,2755.2151427500617,227.40930345179402
ID00422637202311677017371_9,1936.3564818802608,219.82513597726722
ID00423637202312137826377_9,3311.321196301632,213.14443775784176
ID00426637202313170790466_9,2905.316259327252,236.27134829026716
ID00419637202311204720264_10,3010.332660303884,208.104050417612
ID00421637202311550012437_10,2751.436681369238,227.46789248096246
ID00422637202311677017371_10,1932.5780204994373,219.8837250064356
ID00423637202312137826377_10,3307.5427349208085,213.20302678701017
ID00426637202313170790466_10,2901.5377979464292,236.32993731943557
ID00419637202311204720264_11,3006.5541989230605,208.1626394467804
ID00421637202311550012437_11,2747.6582199884147,227.52648151013088
ID00422637202311677017371_11,1928.799559118614,219.94231403560406
ID00423637202312137826377_11,3303.764273539985,213.2616158161786
ID00426637202313170790466_11,2897.7593365656053,236.388526348604
ID00419637202311204720264_12,3002.7757375422375,208.2212284759488
ID00421637202311550012437_12,2743.8797586075916,227.58507053929924
ID00422637202311677017371_12,1925.0210977377906,220.00090306477244
ID00423637202312137826377_12,3299.9858121591615,213.320204845347
ID00426637202313170790466_12,2893.980875184782,236.4471153777724
ID00419637202311204720264_13,2998.997276161414,208.27981750511725
ID00421637202311550012437_13,2740.101297226768,227.64365956846768
ID00422637202311677017371_13,1921.242636356967,220.0594920939409
ID00423637202312137826377_13,3296.207350778338,213.37879387451542
ID00426637202313170790466_13,2890.2024138039587,236.50570440694082
ID00419637202311204720264_14,2995.21881478059,208.3384065342857
ID00421637202311550012437_14,2736.3228358459446,227.70224859763607
ID00422637202311677017371_14,1917.4641749761436,220.1180811231093
ID00423637202312137826377_14,3292.4288893975145,213.43738290368384
ID00426637202313170790466_14,2886.4239524231352,236.56429343610924
ID00419637202311204720264_15,2991.440353399767,208.39699556345408
ID00421637202311550012437_15,2732.5443744651207,227.76083762680452
ID00422637202311677017371_15,1913.68571359532,220.17667015227772
ID00423637202312137826377_15,3288.6504280166914,213.49597193285226
ID00426637202313170790466_15,2882.6454910423117,236.62288246527766
ID00419637202311204720264_16,2987.661892018943,208.45558459262247
ID00421637202311550012437_16,2728.765913084297,227.8194266559729
ID00422637202311677017371_16,1909.9072522144966,220.23525918144614
ID00423637202312137826377_16,3284.8719666358675,213.55456096202067
ID00426637202313170790466_16,2878.8670296614882,236.68147149444607
ID00419637202311204720264_17,2983.8834306381204,208.5141736217909
ID00421637202311550012437_17,2724.987451703474,227.87801568514135
ID00422637202311677017371_17,1906.128790833673,220.29384821061456
ID00423637202312137826377_17,3281.093505255044,213.61314999118906
ID00426637202313170790466_17,2875.0885682806647,236.74006052361446
ID00419637202311204720264_18,2980.1049692572965,208.5727626509593
ID00421637202311550012437_18,2721.2089903226506,227.93660471430977
ID00422637202311677017371_18,1902.35032945285,220.35243723978297
ID00423637202312137826377_18,3277.315043874221,213.6717390203575
ID00426637202313170790466_18,2871.3101068998412,236.7986495527829
ID00419637202311204720264_19,2976.326507876473,208.6313516801277
ID00421637202311550012437_19,2717.430528941827,227.99519374347818
ID00422637202311677017371_19,1898.5718680720263,220.41102626895133
ID00423637202312137826377_19,3273.5365824933974,213.73032804952595
ID00426637202313170790466_19,2867.5316455190177,236.8572385819513
ID00419637202311204720264_20,2972.5480464956495,208.68994070929614
ID00421637202311550012437_20,2713.6520675610036,228.0537827726466
ID00422637202311677017371_20,1894.7934066912028,220.46961529811978
ID00423637202312137826377_20,3269.7581211125735,213.78891707869434
ID00426637202313170790466_20,2863.7531841381947,236.9158276111197
ID00419637202311204720264_21,2968.7695851148264,208.74852973846458
ID00421637202311550012437_21,2709.87360618018,228.11237180181502
ID00422637202311677017371_21,1891.0149453103795,220.5282043272882
ID00423637202312137826377_21,3265.9796597317504,213.84750610786273
ID00426637202313170790466_21,2859.9747227573707,236.97441664028813
ID00419637202311204720264_22,2964.991123734003,208.80711876763297
ID00421637202311550012437_22,2706.0951447993566,228.17096083098343
ID00422637202311677017371_22,1887.236483929556,220.5867933564566
ID00423637202312137826377_22,3262.2011983509265,213.90609513703117
ID00426637202313170790466_22,2856.196261376547,237.03300566945654
ID00419637202311204720264_23,2961.2126623531794,208.86570779680142
ID00421637202311550012437_23,2702.316683418533,228.22954986015185
ID00422637202311677017371_23,1883.4580225487325,220.64538238562503
ID00423637202312137826377_23,3258.4227369701034,213.96468416619956
ID00426637202313170790466_23,2852.4177999957237,237.09159469862496
ID00419637202311204720264_24,2957.434200972356,208.9242968259698
ID00421637202311550012437_24,2698.53822203771,228.28813888932027
ID00422637202311677017371_24,1879.679561167909,220.70397141479344
ID00423637202312137826377_24,3254.64427558928,214.02327319536795
ID00426637202313170790466_24,2848.6393386149007,237.1501837277934
ID00419637202311204720264_25,2953.655739591532,208.98288585513822
ID00421637202311550012437_25,2694.759760656886,228.34672791848865
ID00422637202311677017371_25,1875.9010997870855,220.76256044396186
ID00423637202312137826377_25,3250.8658142084564,214.0818622245364
ID00426637202313170790466_25,2844.8608772340767,237.2087727569618
ID00419637202311204720264_26,2949.877278210709,209.04147488430664
ID00421637202311550012437_26,2690.981299276063,228.40531694765707
ID00422637202311677017371_26,1872.1226384062622,220.82114947313028
ID00423637202312137826377_26,3247.087352827633,214.14045125370484
ID00426637202313170790466_26,2841.0824158532537,237.2673617861302
ID00419637202311204720264_27,2946.0988168298854,209.10006391347503
ID00421637202311550012437_27,2687.202837895239,228.4639059768255
ID00422637202311677017371_27,1868.3441770254387,220.87973850229872
ID00423637202312137826377_27,3243.30889144681,214.19904028287326
ID00426637202313170790466_27,2837.3039544724297,237.32595081529865
ID00419637202311204720264_28,2942.320355449062,209.15865294264347
ID00421637202311550012437_28,2683.424376514416,228.5224950059939
ID00422637202311677017371_28,1864.565715644615,220.9383275314671
ID00423637202312137826377_28,3239.5304300659864,214.25762931204167
ID00426637202313170790466_28,2833.525493091607,237.38453984446704
ID00419637202311204720264_29,2938.5418940682384,209.2172419718119
ID00421637202311550012437_29,2679.6459151335926,228.58108403516232
ID00422637202311677017371_29,1860.7872542637917,220.9969165606355
ID00423637202312137826377_29,3235.751968685163,214.31621834121006
ID00426637202313170790466_29,2829.747031710783,237.4431288736355
ID00419637202311204720264_30,2934.763432687416,209.2758310009803
ID00421637202311550012437_30,2675.867453752769,228.63967306433074
ID00422637202311677017371_30,1857.0087928829682,221.05550558980394
ID00423637202312137826377_30,3231.973507304339,214.3748073703785
ID00426637202313170790466_30,2825.96857032996,237.50171790280388
ID00419637202311204720264_31,2930.9849713065914,209.3344200301487
ID00421637202311550012437_31,2672.0889923719456,228.69826209349918
ID00422637202311677017371_31,1853.230331502145,221.11409461897233
ID00423637202312137826377_31,3228.195045923516,214.4333963995469
ID00426637202313170790466_31,2822.190108949136,237.5603069319723
ID00419637202311204720264_32,2927.2065099257684,209.3930090593171
ID00421637202311550012437_32,2668.3105309911225,228.75685112266757
ID00422637202311677017371_32,1849.4518701213215,221.17268364814075
ID00423637202312137826377_32,3224.4165845426924,214.4919854287153
ID00426637202313170790466_32,2818.4116475683127,237.6188959611407
ID00419637202311204720264_33,2923.428048544945,209.45159808848553
ID00421637202311550012437_33,2664.532069610299,228.81544015183596
ID00422637202311677017371_33,1845.673408740498,221.23127267730916
ID00423637202312137826377_33,3220.638123161869,214.55057445788373
ID00426637202313170790466_33,2814.6331861874896,237.6774849903091
ID00419637202311204720264_34,2919.6495871641214,209.51018711765397
ID00421637202311550012437_34,2660.753608229475,228.8740291810044
ID00422637202311677017371_34,1841.8949473596745,221.2898617064776
ID00423637202312137826377_34,3216.8596617810454,214.60916348705214
ID00426637202313170790466_34,2810.854724806666,237.73607401947754
ID00419637202311204720264_35,2915.8711257832974,209.56877614682236
ID00421637202311550012437_35,2656.975146848652,228.93261821017285
ID00422637202311677017371_35,1838.116485978851,221.348450735646
ID00423637202312137826377_35,3213.081200400222,214.66775251622056
ID00426637202313170790466_35,2807.0762634258426,237.79466304864596
ID00419637202311204720264_36,2912.092664402475,209.62736517599078
ID00421637202311550012437_36,2653.196685467828,228.99120723934124
ID00422637202311677017371_36,1834.3380245980275,221.40703976481444
ID00423637202312137826377_36,3209.3027390193984,214.72634154538898
ID00426637202313170790466_36,2803.297802045019,237.85325207781437
ID00419637202311204720264_37,2908.314203021651,209.6859542051592
ID00421637202311550012437_37,2649.418224087005,229.04979626850962
ID00422637202311677017371_37,1830.559563217204,221.46562879398283
ID00423637202312137826377_37,3205.524277638575,214.7849305745574
ID00426637202313170790466_37,2799.5193406641956,237.9118411069828
ID00419637202311204720264_38,2904.5357416408274,209.7445432343276
ID00421637202311550012437_38,2645.6397627061815,229.10838529767807
ID00422637202311677017371_38,1826.7811018363805,221.52421782315128
ID00423637202312137826377_38,3201.745816257752,214.8435196037258
ID00426637202313170790466_38,2795.740879283372,237.97043013615118
ID00419637202311204720264_39,2900.757280260004,209.80313226349602
ID00421637202311550012437_39,2641.861301325358,229.16697432684649
ID00422637202311677017371_39,1823.0026404555572,221.5828068523197
ID00423637202312137826377_39,3197.967354876928,214.90210863289423
ID00426637202313170790466_39,2791.962417902549,238.02901916531962
ID00419637202311204720264_40,2896.978818879181,209.8617212926644
ID00421637202311550012437_40,2638.0828399445345,229.2255633560149
ID00422637202311677017371_40,1819.2241790747337,221.6413958814881
ID00423637202312137826377_40,3194.188893496105,214.9606976620626
ID00426637202313170790466_40,2788.183956521725,238.087608194488
ID00419637202311204720264_41,2893.2003574983573,209.92031032183286
ID00421637202311550012437_41,2634.304378563711,229.2841523851833
ID00422637202311677017371_41,1815.4457176939104,221.6999849106565
ID00423637202312137826377_41,3190.4104321152818,215.01928669123106
ID00426637202313170790466_41,2784.405495140902,238.14619722365646
ID00419637202311204720264_42,2889.421896117534,209.9788993510013
ID00421637202311550012437_42,2630.5259171828875,229.34274141435174
ID00422637202311677017371_42,1811.667256313087,221.7585739398249
ID00423637202312137826377_42,3186.6319707344583,215.07787572039945
ID00426637202313170790466_42,2780.627033760078,238.20478625282485
ID00419637202311204720264_43,2885.6434347367103,210.03748838016972
ID00421637202311550012437_43,2626.7474558020645,229.40133044352015
ID00422637202311677017371_43,1807.8887949322634,221.81716296899333
ID00423637202312137826377_43,3182.8535093536343,215.1364647495679
ID00426637202313170790466_43,2776.8485723792546,238.26337528199326
ID00419637202311204720264_44,2881.864973355887,210.09607740933814
ID00421637202311550012437_44,2622.9689944212405,229.45991947268857
ID00422637202311677017371_44,1804.11033355144,221.87575199816175
ID00423637202312137826377_44,3179.075047972811,215.19505377873628
ID00426637202313170790466_44,2773.0701109984316,238.3219643111617
ID00419637202311204720264_45,2878.0865119750633,210.15466643850652
ID00421637202311550012437_45,2619.1905330404174,229.51850850185699
ID00422637202311677017371_45,1800.3318721706164,221.93434102733016
ID00423637202312137826377_45,3175.2965865919873,215.25364280790473
ID00426637202313170790466_45,2769.291649617608,238.38055334033012
ID00419637202311204720264_46,2874.30805059424,210.21325546767497
ID00421637202311550012437_46,2615.4120716595935,229.5770975310254
ID00422637202311677017371_46,1796.5534107897931,221.99293005649858
ID00423637202312137826377_46,3171.5181252111643,215.3122318370731
ID00426637202313170790466_46,2765.5131882367846,238.4391423694985
ID00419637202311204720264_47,2870.529589213417,210.27184449684336
ID00421637202311550012437_47,2611.6336102787704,229.6356865601938
ID00422637202311677017371_47,1792.7749494089696,222.051519085667
ID00423637202312137826377_47,3167.7396638303408,215.37082086624156
ID00426637202313170790466_47,2761.734726855961,238.49773139866693
ID00419637202311204720264_48,2866.751127832593,210.33043352601175
ID00421637202311550012437_48,2607.855148897947,229.6942755893622
ID00422637202311677017371_48,1788.996488028146,222.1101081148354
ID00423637202312137826377_48,3163.9612024495173,215.42940989540998
ID00426637202313170790466_48,2757.956265475138,238.55632042783537
ID00419637202311204720264_49,2862.9726664517693,210.3890225551802
ID00421637202311550012437_49,2604.0766875171234,229.75286461853062
ID00422637202311677017371_49,1785.2180266473226,222.1686971440038
ID00423637202312137826377_49,3160.1827410686938,215.48799892457833
ID00426637202313170790466_49,2754.177804094314,238.61490945700376
ID00419637202311204720264_50,2859.194205070946,210.4476115843486
ID00421637202311550012437_50,2600.2982261363,229.81145364769904
ID00422637202311677017371_50,1781.4395652664994,222.22728617317222
ID00423637202312137826377_50,3156.40427968787,215.54658795374678
ID00426637202313170790466_50,2750.3993427134906,238.67349848617215
ID00419637202311204720264_51,2855.415743690123,210.50620061351702
ID00421637202311550012437_51,2596.5197647554764,229.87004267686746
ID00422637202311677017371_51,1777.6611038856759,222.28587520234066
ID00423637202312137826377_51,3152.6258183070468,215.60517698291522
ID00426637202313170790466_51,2746.620881332667,238.7320875153406
ID00419637202311204720264_52,2851.637282309299,210.56478964268544
ID00421637202311550012437_52,2592.7413033746534,229.9286317060359
ID00422637202311677017371_52,1773.8826425048524,222.34446423150905
ID00423637202312137826377_52,3148.8473569262233,215.66376601208364
ID00426637202313170790466_52,2742.842419951844,238.79067654450898
ID00419637202311204720264_53,2847.858820928476,210.62337867185386
ID00421637202311550012437_53,2588.9628419938294,229.9872207352043
ID00422637202311677017371_53,1770.1041811240289,222.40305326067747
ID00423637202312137826377_53,3145.0688955453998,215.72235504125203
ID00426637202313170790466_53,2739.0639585710205,238.84926557367746
ID00419637202311204720264_54,2844.080359547652,210.68196770102227
ID00421637202311550012437_54,2585.1843806130064,230.04580976437273
ID00422637202311677017371_54,1766.3257197432054,222.46164228984588
ID00423637202312137826377_54,3141.2904341645763,215.78094407042045
ID00426637202313170790466_54,2735.285497190197,238.90785460284582
ID00419637202311204720264_55,2840.3018981668292,210.7405567301907
ID00421637202311550012437_55,2581.4059192321824,230.10439879354112
ID00422637202311677017371_55,1762.5472583623819,222.52023131901433
ID00423637202312137826377_55,3137.5119727837528,215.83953309958886
ID00426637202313170790466_55,2731.5070358093735,238.96644363201426
ID00419637202311204720264_56,2836.5234367860053,210.79914575935908
ID00421637202311550012437_56,2577.6274578513594,230.16298782270957
ID00422637202311677017371_56,1758.7687969815584,222.57882034818275
ID00423637202312137826377_56,3133.7335114029293,215.89812212875728
ID00426637202313170790466_56,2727.72857442855,239.02503266118268
ID00419637202311204720264_57,2832.7449754051822,210.85773478852752
ID00421637202311550012437_57,2573.848996470536,230.22157685187793
ID00422637202311677017371_57,1754.9903356007349,222.63740937735116
ID00423637202312137826377_57,3129.955050022106,215.9567111579257
ID00426637202313170790466_57,2723.9501130477265,239.0836216903511
ID00419637202311204720264_58,2828.9665140243583,210.9163238176959
ID00421637202311550012437_58,2570.0705350897124,230.28016588104634
ID00422637202311677017371_58,1751.2118742199116,222.69599840651955
ID00423637202312137826377_58,3126.1765886412827,216.0153001870941
ID00426637202313170790466_58,2720.171651666903,239.1422107195195
ID00419637202311204720264_59,2825.188052643535,210.97491284686436
ID00421637202311550012437_59,2566.292073708889,230.3387549102148
ID00422637202311677017371_59,1747.433412839088,222.754587435688
ID00423637202312137826377_59,3122.398127260459,216.07388921626253
ID00426637202313170790466_59,2716.3931902860795,239.20079974868793
ID00419637202311204720264_60,2821.4095912627117,211.03350187603274
ID00421637202311550012437_60,2562.5136123280654,230.39734393938323
ID00422637202311677017371_60,1743.6549514582648,222.8131764648564
ID00423637202312137826377_60,3118.6196658796352,216.13247824543095
ID00426637202313170790466_60,2712.614728905256,239.25938877785634
ID00419637202311204720264_61,2817.6311298818882,211.09209090520116
ID00421637202311550012437_61,2558.735150947242,230.45593296855162
ID00422637202311677017371_61,1739.8764900774413,222.87176549402477
ID00423637202312137826377_61,3114.8412044988117,216.1910672745994
ID00426637202313170790466_61,2708.8362675244325,239.31797780702476
ID00419637202311204720264_62,2813.8526685010643,211.15067993436958
ID00421637202311550012437_62,2554.9566895664184,230.51452199772
ID00422637202311677017371_62,1736.0980286966178,222.93035452319322
ID00423637202312137826377_62,3111.0627431179887,216.24965630376778
ID00426637202313170790466_62,2705.057806143609,239.37656683619315
ID00419637202311204720264_63,2810.074207120241,211.20926896353802
ID00421637202311550012437_63,2551.178228185595,230.57311102688845
ID00422637202311677017371_63,1732.3195673157945,222.98894355236163
ID00423637202312137826377_63,3107.284281737165,216.30824533293617
ID00426637202313170790466_63,2701.2793447627855,239.43515586536157
ID00419637202311204720264_64,2806.2957457394177,211.2678579927064
ID00421637202311550012437_64,2547.399766804772,230.63170005605687
ID00422637202311677017371_64,1728.5411059349708,223.04753258153005
ID00423637202312137826377_64,3103.5058203563417,216.36683436210458
ID00426637202313170790466_64,2697.5008833819625,239.49374489452998
ID00419637202311204720264_65,2802.517284358594,211.3264470218748
ID00421637202311550012437_65,2543.621305423948,230.6902890852253
ID00422637202311677017371_65,1724.7626445541473,223.10612161069847
ID00423637202312137826377_65,3099.727358975518,216.425423391273
ID00426637202313170790466_65,2693.7224220011385,239.55233392369843
ID00419637202311204720264_66,2798.7388229777707,211.38503605104324
ID00421637202311550012437_66,2539.842844043125,230.7488781143937
ID00422637202311677017371_66,1720.984183173324,223.16471063986688
ID00423637202312137826377_66,3095.948897594695,216.48401242044142
ID00426637202313170790466_66,2689.9439606203155,239.61092295286682
ID00419637202311204720264_67,2794.960361596947,211.4436250802117
ID00421637202311550012437_67,2536.064382662301,230.80746714356212
ID00422637202311677017371_67,1717.2057217925003,223.2232996690353
ID00423637202312137826377_67,3092.1704362138717,216.54260144960983
ID00426637202313170790466_67,2686.1654992394915,239.66951198203526
ID00419637202311204720264_68,2791.1819002161237,211.5022141093801
ID00421637202311550012437_68,2532.285921281478,230.86605617273054
ID00422637202311677017371_68,1713.427260411677,223.28188869820372
ID00423637202312137826377_68,3088.391974833048,216.60119047877828
ID00426637202313170790466_68,2682.3870378586685,239.72810101120365
ID00419637202311204720264_69,2787.4034388353,211.56080313854847
ID00421637202311550012437_69,2528.507459900654,230.92464520189893
ID00422637202311677017371_69,1709.6487990308535,223.34047772737213
ID00423637202312137826377_69,3084.6135134522247,216.65977950794667
ID00426637202313170790466_69,2678.608576477845,239.7866900403721
ID00419637202311204720264_70,2783.6249774544767,211.6193921677169
ID00421637202311550012437_70,2524.728998519831,230.98323423106734
ID00422637202311677017371_70,1705.8703376500303,223.39906675654055
ID00423637202312137826377_70,3080.8350520714007,216.7183685371151
ID00426637202313170790466_70,2674.8301150970215,239.84527906954048
ID00419637202311204720264_71,2779.8465160736537,211.67798119688533
ID00421637202311550012437_71,2520.950537139007,231.04182326023576
ID00422637202311677017371_71,1702.0918762692068,223.45765578570894
ID00423637202312137826377_71,3077.0565906905777,216.7769575662835
ID00426637202313170790466_71,2671.051653716198,239.90386809870893
ID00419637202311204720264_72,2776.06805469283,211.73657022605374
ID00421637202311550012437_72,2517.1720757581843,231.10041228940418
ID00422637202311677017371_72,1698.3134148883832,223.51624481487738
ID00423637202312137826377_72,3073.2781293097546,216.83554659545194
ID00426637202313170790466_72,2667.273192335375,239.96245712787731
ID00419637202311204720264_73,2772.2895933120067,211.79515925522216
ID00421637202311550012437_73,2513.3936143773603,231.1590013185726
ID00422637202311677017371_73,1694.5349535075597,223.57483384404577
ID00423637202312137826377_73,3069.4996679289306,216.89413562462036
ID00426637202313170790466_73,2663.4947309545514,240.02104615704576
ID00419637202311204720264_74,2768.511131931183,211.85374828439058
ID00421637202311550012437_74,2509.6151529965373,231.217590347741
ID00422637202311677017371_74,1690.7564921267362,223.6334228732142
ID00423637202312137826377_74,3065.721206548107,216.95272465378875
ID00426637202313170790466_74,2659.716269573728,240.07963518621418
ID00419637202311204720264_75,2764.732670550359,211.912337313559
ID00421637202311550012437_75,2505.8366916157133,231.27617937690943
ID00422637202311677017371_75,1686.9780307459127,223.6920119023826
ID00423637202312137826377_75,3061.9427451672836,217.01131368295717
ID00426637202313170790466_75,2655.9378081929044,240.13822421538254
ID00419637202311204720264_76,2760.954209169536,211.97092634272738
ID00421637202311550012437_76,2502.0582302348903,231.33476840607784
ID00422637202311677017371_76,1683.1995693650892,223.75060093155105
ID00423637202312137826377_76,3058.16428378646,217.06990271212558
ID00426637202313170790466_76,2652.159346812081,240.19681324455098
ID00419637202311204720264_77,2757.1757477887127,212.0295153718958
ID00421637202311550012437_77,2498.279768854067,231.3933574352463
ID00422637202311677017371_77,1679.4211079842657,223.80918996071944
ID00423637202312137826377_77,3054.3858224056366,217.128491741294
ID00426637202313170790466_77,2648.3808854312574,240.2554022737194
ID00419637202311204720264_78,2753.397286407889,212.08810440106421
ID00421637202311550012437_78,2494.5013074732433,231.45194646441468
ID00422637202311677017371_78,1675.6426466034425,223.86777898988782
ID00423637202312137826377_78,3050.6073610248136,217.1870807704624
ID00426637202313170790466_78,2644.602424050434,240.3139913028878
ID00419637202311204720264_79,2749.618825027066,212.14669343023263
ID00421637202311550012437_79,2490.72284609242,231.51053549358306
ID00422637202311677017371_79,1671.864185222619,223.92636801905627
ID00423637202312137826377_79,3046.8288996439896,217.24566979963083
ID00426637202313170790466_79,2640.8239626696104,240.37258033205623
ID00419637202311204720264_80,2745.8403636462426,212.20528245940105
ID00421637202311550012437_80,2486.9443847115963,231.5691245227515
ID00422637202311677017371_80,1668.0857238417957,223.98495704822471
ID00423637202312137826377_80,3043.0504382631666,217.30425882879925
ID00426637202313170790466_80,2637.045501288787,240.43116936122465
ID00419637202311204720264_81,2742.061902265419,212.26387148856946
ID00421637202311550012437_81,2483.165923330773,231.62771355191995
ID00422637202311677017371_81,1664.3072624609722,224.04354607739313
ID00423637202312137826377_81,3039.2719768823426,217.36284785796767
ID00426637202313170790466_81,2633.2670399079634,240.48975839039306
ID00419637202311204720264_82,2738.2834408845956,212.32246051773788
ID00421637202311550012437_82,2479.3874619499493,231.68630258108834
ID00422637202311677017371_82,1660.5288010801487,224.10213510656155
ID00423637202312137826377_82,3035.49351550152,217.42143688713605
ID00426637202313170790466_82,2629.48857852714,240.54834741956148
ID00419637202311204720264_83,2734.5049795037717,212.3810495469063
ID00421637202311550012437_83,2475.6090005691262,231.74489161025673
ID00422637202311677017371_83,1656.7503396993254,224.16072413572994
ID00423637202312137826377_83,3031.715054120696,217.48002591630447
ID00426637202313170790466_83,2625.710117146317,240.60693644872987
ID00419637202311204720264_84,2730.7265181229486,212.43963857607474
ID00421637202311550012437_84,2471.8305391883023,231.80348063942517
ID00422637202311677017371_84,1652.9718783185017,224.21931316489835
ID00423637202312137826377_84,3027.9365927398726,217.5386149454729
ID00426637202313170790466_84,2621.931655765493,240.66552547789829
ID00419637202311204720264_85,2726.948056742125,212.49822760524313
ID00421637202311550012437_85,2468.0520778074792,231.8620696685936
ID00422637202311677017371_85,1649.1934169376782,224.27790219406677
ID00423637202312137826377_85,3024.158131359049,217.59720397464133
ID00426637202313170790466_85,2618.15319438467,240.7241145070667
ID00419637202311204720264_86,2723.1695953613016,212.55681663441158
ID00421637202311550012437_86,2464.2736164266553,231.920658697762
ID00422637202311677017371_86,1645.414955556855,224.33649122323519
ID00423637202312137826377_86,3020.379669978226,217.65579300380972
ID00426637202313170790466_86,2614.3747330038464,240.78270353623515
ID00419637202311204720264_87,2719.391133980478,212.61540566357996
ID00421637202311550012437_87,2460.4951550458322,231.9792477269304
ID00422637202311677017371_87,1641.6364941760312,224.3950802524036
ID00423637202312137826377_87,3016.6012085974025,217.71438203297814
ID00426637202313170790466_87,2610.596271623023,240.84129256540353
ID00419637202311204720264_88,2715.6126725996546,212.6739946927484
ID00421637202311550012437_88,2456.7166936650087,232.03783675609884
ID00422637202311677017371_88,1637.858032795208,224.45366928157202
ID00423637202312137826377_88,3012.822747216579,217.77297106214655
ID00426637202313170790466_88,2606.8178102421994,240.89988159457198
ID00419637202311204720264_89,2711.834211218831,212.7325837219168
ID00421637202311550012437_89,2452.9382322841852,232.09642578526726
ID00422637202311677017371_89,1634.0795714143844,224.51225831074044
ID00423637202312137826377_89,3009.0442858357555,217.831560091315
ID00426637202313170790466_89,2603.039348861376,240.95847062374037
ID00419637202311204720264_90,2708.0557498380076,212.79117275108518
ID00421637202311550012437_90,2449.1597709033617,232.15501481443565
ID00422637202311677017371_90,1630.3011100335611,224.57084733990885
ID00423637202312137826377_90,3005.265824454932,217.89014912048341
ID00426637202313170790466_90,2599.2608874805524,241.01705965290878
ID00419637202311204720264_91,2704.277288457184,212.84976178025363
ID00421637202311550012437_91,2445.3813095225387,232.21360384360406
ID00422637202311677017371_91,1626.5226486527376,224.62943636907727
ID00423637202312137826377_91,3001.4873630741085,217.94873814965183
ID00426637202313170790466_91,2595.482426099729,241.0756486820772
ID00419637202311204720264_92,2700.4988270763606,212.90835080942205
ID00421637202311550012437_92,2441.6028481417147,232.27219287277248
ID00422637202311677017371_92,1622.7441872719141,224.68802539824568
ID00423637202312137826377_92,2997.708901693285,218.00732717882022
ID00426637202313170790466_92,2591.703964718906,241.1342377112456
ID00419637202311204720264_93,2696.720365695537,212.96693983859046
ID00421637202311550012437_93,2437.8243867608917,232.3307819019409
ID00422637202311677017371_93,1618.9657258910906,224.7466144274141
ID00423637202312137826377_93,2993.9304403124615,218.06591620798866
ID00426637202313170790466_93,2587.9255033380823,241.19282674041403
ID00419637202311204720264_94,2692.9419043147136,213.02552886775885
ID00421637202311550012437_94,2434.0459253800677,232.38937093110934
ID00422637202311677017371_94,1615.1872645102671,224.8052034565825
ID00423637202312137826377_94,2990.151978931638,218.12450523715708
ID00426637202313170790466_94,2584.147041957259,241.25141576958248
ID00419637202311204720264_95,2689.1634429338906,213.0841178969273
ID00421637202311550012437_95,2430.2674639992442,232.44795996027773
ID00422637202311677017371_95,1611.4088031294436,224.8637924857509
ID00423637202312137826377_95,2986.3735175508145,218.18309426632547
ID00426637202313170790466_95,2580.3685805764353,241.31000479875084
ID00419637202311204720264_96,2685.384981553067,213.1427069260957
ID00421637202311550012437_96,2426.489002618421,232.50654898944615
ID00422637202311677017371_96,1607.6303417486201,224.92238151491932
ID00423637202312137826377_96,2982.595056169991,218.24168329549389
ID00426637202313170790466_96,2576.590119195612,241.3685938279193
ID00419637202311204720264_97,2681.6065201722436,213.20129595526413
ID00421637202311550012437_97,2422.7105412375977,232.56513801861456
ID00422637202311677017371_97,1603.8518803677966,224.98097054408777
ID00423637202312137826377_97,2978.816594789168,218.3002723246623
ID00426637202313170790466_97,2572.8116578147883,241.4271828570877
ID00419637202311204720264_98,2677.82805879142,213.25988498443252
ID00421637202311550012437_98,2418.932079856774,232.62372704778295
ID00422637202311677017371_98,1600.0734189869734,225.03955957325616
ID00423637202312137826377_98,2975.038133408344,218.35886135383072
ID00426637202313170790466_98,2569.033196433965,241.48577188625612
ID00419637202311204720264_99,2674.049597410597,213.31847401360093
ID00421637202311550012437_99,2415.1536184759507,232.6823160769514
ID00422637202311677017371_99,1596.2949576061496,225.0981486024246
ID00423637202312137826377_99,2971.259672027521,218.41745038299914
ID00426637202313170790466_99,2565.2547350531413,241.54436091542453
ID00419637202311204720264_100,2670.2711360297735,213.37706304276935
ID00421637202311550012437_100,2411.375157095127,232.74090510611978
ID00422637202311677017371_100,1592.5164962253266,225.156737631593
ID00423637202312137826377_100,2967.481210646698,218.47603941216755
ID00426637202313170790466_100,2561.4762736723183,241.60294994459295
ID00419637202311204720264_101,2666.49267464895,213.4356520719378
ID00421637202311550012437_101,2407.5966957143037,232.79949413528823
ID00422637202311677017371_101,1588.7380348445029,225.21532666076143
ID00423637202312137826377_101,2963.7027492658735,218.53462844133597
ID00426637202313170790466_101,2557.6978122914943,241.66153897376137
ID00419637202311204720264_102,2662.714213268126,213.49424110110618
ID00421637202311550012437_102,2403.81823433348,232.85808316445662
ID00422637202311677017371_102,1584.9595734636796,225.27391568992982
ID00423637202312137826377_102,2959.9242878850505,218.59321747050438
ID00426637202313170790466_102,2553.919350910671,241.72012800292978
ID00419637202311204720264_103,2658.935751887303,213.5528301302746
ID00421637202311550012437_103,2400.0397729526567,232.91667219362506
ID00422637202311677017371_103,1581.181112082856,225.33250471909827
ID00423637202312137826377_103,2956.145826504227,218.6518064996728
ID00426637202313170790466_103,2550.1408895298478,241.7787170320982
ID00419637202311204720264_104,2655.1572905064795,213.61141915944302
ID00421637202311550012437_104,2396.2613115718336,232.97526122279345
ID00422637202311677017371_104,1577.4026507020326,225.39109374826666
ID00423637202312137826377_104,2952.367365123403,218.71039552884122
ID00426637202313170790466_104,2546.3624281490243,241.8373060612666
ID00419637202311204720264_105,2651.378829125656,213.6700081886114
ID00421637202311550012437_105,2392.4828501910097,233.0338502519619
ID00422637202311677017371_105,1573.6241893212093,225.4496827774351
ID00423637202312137826377_105,2948.5889037425804,218.7689845580096
ID00426637202313170790466_105,2542.5839667682003,241.89589509043503
ID00419637202311204720264_106,2647.6003677448325,213.72859721777985
ID00421637202311550012437_106,2388.704388810186,233.0924392811303
ID00422637202311677017371_106,1569.8457279403856,225.5082718066035
ID00423637202312137826377_106,2944.810442361757,218.82757358717805
ID00426637202313170790466_106,2538.8055053873773,241.95448411960342
ID00419637202311204720264_107,2643.821906364009,213.78718624694824
ID00421637202311550012437_107,2384.925927429363,233.15102831029873
ID00422637202311677017371_107,1566.0672665595623,225.56686083577188
ID00423637202312137826377_107,2941.0319809809334,218.88616261634644
ID00426637202313170790466_107,2535.0270440065533,242.01307314877184
ID00419637202311204720264_108,2640.0434449831855,213.84577527611668
ID00421637202311550012437_108,2381.1474660485396,233.20961733946714
ID00422637202311677017371_108,1562.2888051787388,225.62544986494032
ID00423637202312137826377_108,2937.2535196001095,218.94475164551486
ID00426637202313170790466_108,2531.2485826257303,242.07166217794025
ID00419637202311204720264_109,2636.264983602362,213.90436430528513
ID00421637202311550012437_109,2377.369004667716,233.26820636863556
ID00422637202311677017371_109,1558.5103437979155,225.68403889410874
ID00423637202312137826377_109,2933.4750582192864,219.00334067468327
ID00426637202313170790466_109,2527.4701212449067,242.13025120710867
ID00419637202311204720264_110,2632.486522221539,213.96295333445352
ID00421637202311550012437_110,2373.5905432868926,233.32679539780398
ID00422637202311677017371_110,1554.731882417092,225.74262792327715
ID00423637202312137826377_110,2929.696596838463,219.06192970385172
ID00426637202313170790466_110,2523.6916598640832,242.1888402362771
ID00419637202311204720264_111,2628.708060840715,214.02154236362196
ID00421637202311550012437_111,2369.8120819060687,233.38538442697234
ID00422637202311677017371_111,1550.9534210362683,225.80121695244557
ID00423637202312137826377_111,2925.9181354576394,219.1205187330201
ID00426637202313170790466_111,2519.91319848326,242.24742926544553
ID00419637202311204720264_112,2624.929599459892,214.08013139279035
ID00421637202311550012437_112,2366.0336205252456,233.44397345614078
ID00422637202311677017371_112,1547.174959655445,225.859805981614
ID00423637202312137826377_112,2922.139674076816,219.1791077621885
ID00426637202313170790466_112,2516.1347371024367,242.30601829461392
ID00419637202311204720264_113,2621.151138079068,214.13872042195877
ID00421637202311550012437_113,2362.255159144422,233.5025624853092
ID00422637202311677017371_113,1543.3964982746215,225.9183950107824
ID00423637202312137826377_113,2918.3612126959924,219.23769679135694
ID00426637202313170790466_113,2512.356275721613,242.3646073237823
ID00419637202311204720264_114,2617.3726766982454,214.19730945112718
ID00421637202311550012437_114,2358.4766977635986,233.56115151447761
ID00422637202311677017371_114,1539.618036893798,225.97698403995082
ID00423637202312137826377_114,2914.582751315169,219.29628582052538
ID00426637202313170790466_114,2508.5778143407897,242.42319635295075
ID00419637202311204720264_115,2613.5942153174215,214.2558984802956
ID00421637202311550012437_115,2354.6982363827756,233.61974054364603
ID00422637202311677017371_115,1535.8395755129745,226.0355730691192
ID00423637202312137826377_115,2910.8042899343454,219.3548748496938
ID00426637202313170790466_115,2504.799352959966,242.4817853821192
ID00419637202311204720264_116,2609.815753936598,214.31448750946402
ID00421637202311550012437_116,2350.919775001952,233.67832957281445
ID00422637202311677017371_116,1532.061114132151,226.09416209828763
ID00423637202312137826377_116,2907.0258285535224,219.41346387886222
ID00426637202313170790466_116,2501.0208915791427,242.5403744112876
ID00419637202311204720264_117,2606.0372925557745,214.37307653863243
ID00421637202311550012437_117,2347.1413136211286,233.73691860198286
ID00422637202311677017371_117,1528.2826527513278,226.15275112745604
ID00423637202312137826377_117,2903.2473671726984,219.47205290803063
ID00426637202313170790466_117,2497.242430198319,242.59896344045603
ID00419637202311204720264_118,2602.258831174951,214.43166556780085
ID00421637202311550012437_118,2343.362852240305,233.79550763115128
ID00422637202311677017371_118,1524.5041913705043,226.21134015662446
ID00423637202312137826377_118,2899.4689057918754,219.53064193719902
ID00426637202313170790466_118,2493.4639688174957,242.65755246962442
ID00419637202311204720264_119,2598.4803697941275,214.49025459696924
ID00421637202311550012437_119,2339.5843908594816,233.85409666031973
ID00422637202311677017371_119,1520.7257299896805,226.26992918579288
ID00423637202312137826377_119,2895.6904444110514,219.58923096636744
ID00426637202313170790466_119,2489.685507436672,242.71614149879287
ID00419637202311204720264_120,2594.7019084133044,214.54884362613765
ID00421637202311550012437_120,2335.805929478658,233.91268568948811
ID00422637202311677017371_120,1516.9472686088575,226.3285182149613
ID00423637202312137826377_120,2891.911983030229,219.64781999553585
ID00426637202313170790466_120,2485.9070460558487,242.77473052796125
ID00419637202311204720264_121,2590.9234470324805,214.60743265530607
ID00421637202311550012437_121,2332.0274680978346,233.9712747186565
ID00422637202311677017371_121,1513.168807228034,226.3871072441297
ID00423637202312137826377_121,2888.133521649405,219.70640902470427
ID00426637202313170790466_121,2482.128584675025,242.83331955712967
ID00419637202311204720264_122,2587.1449856516574,214.66602168447452
ID00421637202311550012437_122,2328.249006717011,234.02986374782495
ID00422637202311677017371_122,1509.3903458472105,226.44569627329815
ID00423637202312137826377_122,2884.3550602685814,219.7649980538727
ID00426637202313170790466_122,2478.3501232942017,242.8919085862981
ID00419637202311204720264_123,2583.366524270834,214.7246107136429
ID00421637202311550012437_123,2324.470545336188,234.0884527769934
ID00422637202311677017371_123,1505.611884466387,226.50428530246657
ID00423637202312137826377_123,2880.576598887758,219.8235870830411
ID00426637202313170790466_123,2474.5716619133786,242.9504976154665
ID00419637202311204720264_124,2579.5880628900104,214.78319974281132
ID00421637202311550012437_124,2320.692083955364,234.14704180616178
ID00422637202311677017371_124,1501.8334230855635,226.562874331635
ID00423637202312137826377_124,2876.7981375069344,219.88217611220952
ID00426637202313170790466_124,2470.7932005325547,243.00908664463492
ID00419637202311204720264_125,2575.809601509187,214.84178877197974
ID00421637202311550012437_125,2316.9136225745406,234.20563083533017
ID00422637202311677017371_125,1498.0549617047402,226.62146336080338
ID00423637202312137826377_125,2873.0196761261113,219.9407651413779
ID00426637202313170790466_125,2467.0147391517316,243.0676756738033
ID00419637202311204720264_126,2572.0311401283634,214.90037780114818
ID00421637202311550012437_126,2313.1351611937175,234.2642198644986
ID00422637202311677017371_126,1494.2765003239165,226.68005238997182
ID00423637202312137826377_126,2869.241214745288,219.99935417054633
ID00426637202313170790466_126,2463.236277770908,243.12626470297175
ID00419637202311204720264_127,2568.25267874754,214.95896683031657
ID00421637202311550012437_127,2309.356699812894,234.322808893667
ID00422637202311677017371_127,1490.4980389430932,226.7386414191402
ID00423637202312137826377_127,2865.4627533644643,220.05794319971477
ID00426637202313170790466_127,2459.4578163900846,243.18485373214014
ID00419637202311204720264_128,2564.4742173667164,215.01755585948496
ID00421637202311550012437_128,2305.57823843207,234.38139792283545
ID00422637202311677017371_128,1486.7195775622697,226.79723044830862
ID00423637202312137826377_128,2861.6842919836404,220.11653222888322
ID00426637202313170790466_128,2455.679355009261,243.2434427613086
ID00419637202311204720264_129,2560.695755985893,215.0761448886534
ID00421637202311550012437_129,2301.799777051247,234.43998695200384
ID00422637202311677017371_129,1482.9411161814464,226.85581947747704
ID00423637202312137826377_129,2857.9058306028173,220.17512125805158
ID00426637202313170790466_129,2451.9008936284376,243.30203179047697
ID00419637202311204720264_130,2556.9172946050694,215.13473391782185
ID00421637202311550012437_130,2298.021315670423,234.49857598117228
ID00422637202311677017371_130,1479.162654800623,226.91440850664546
ID00423637202312137826377_130,2854.127369221994,220.23371028722
ID00426637202313170790466_130,2448.122432247614,243.36062081964542
ID00419637202311204720264_131,2553.1388332242464,215.19332294699024
ID00421637202311550012437_131,2294.2428542896,234.5571650103407
ID00422637202311677017371_131,1475.3841934197994,226.97299753581387
ID00423637202312137826377_131,2850.348907841171,220.29229931638844
ID00426637202313170790466_131,2444.343970866791,243.4192098488138
ID00419637202311204720264_132,2549.3603718434224,215.25191197615862
ID00421637202311550012437_132,2290.4643929087765,234.6157540395091
ID00422637202311677017371_132,1471.605732038976,227.0315865649823
ID00423637202312137826377_132,2846.570446460347,220.35088834555683
ID00426637202313170790466_132,2440.5655094859676,243.47779887798225
ID00419637202311204720264_133,2545.581910462599,215.31050100532707
ID00421637202311550012437_133,2286.685931527953,234.6743430686775
ID00422637202311677017371_133,1467.8272706581524,227.0901755941507
ID00423637202312137826377_133,2842.7919850795233,220.40947737472527
ID00426637202313170790466_133,2436.787048105144,243.53638790715064
