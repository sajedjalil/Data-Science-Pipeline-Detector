# %% [markdown]
# ### Reference
# - [kaggle-mercedes-benz-greener-manufacturing-leaderboard-probing (PDF Link)](https://crowdstats.eu/topics/kaggle-mercedes-benz-greener-manufacturing-leaderboard-probing)

# %%
import pandas as pd
from pathlib import Path

input_root_path = Path("../input")

# %%
# !ls ../input

# %% [markdown]
# # Baseline Probe (PB) - all Zero
# Public Score is -59.28220
# ![kaggle_lb_provinb_1.PNG](attachment:kaggle_lb_provinb_1.PNG)

# %%
# read sample_submission.csv
sub = pd.read_csv(input_root_path.joinpath("sample_submission.csv"))
# replace all zero from y_value
all_zeros = sub.copy()
all_zeros["y"] = 0
# save submit
all_zeros.to_csv("baseline_probe_0.0.csv", index=False)
P_bp = -59.28220

# %% [markdown]
# # Other Probe
# ID = 1 replace y_value 100
#
# Public Score is -59.25187
# ![kaggle_lb_provinb_2.PNG](attachment:kaggle_lb_provinb_2.PNG)

# %%
idx_1_replace_100 = all_zeros.copy()
idx_1_replace_100["y"][0] = 100
# save submit
idx_1_replace_100.to_csv("probe_0001_100.csv", index=False)
P_1_100 = -59.25187

# %% [markdown]
# ## Numerical value of Stot
# ID = 1 replace y_value 200
#
# Public Score is -59.36366
# ![kaggle_lb_provinb_3.PNG](attachment:kaggle_lb_provinb_3.PNG)

# %%
idx_1_replace_100["y"][0] = 200
# save submit
idx_1_replace_100.to_csv("probe_0001_200.csv", index=False)
P_1_200 = -59.36366

# %% [markdown]
# ![kaggle_lb_provinb_7.PNG](attachment:kaggle_lb_provinb_7.PNG)
#
# ![kaggle_lb_provinb_6.PNG](attachment:kaggle_lb_provinb_6.PNG)
#
# ![kaggle_lb_provinb_5.PNG](attachment:kaggle_lb_provinb_5.PNG)

# %%
# (2.11)
S_tot = 20000.0 / (2 * P_1_100 - P_bp - P_1_200)
print("Stot is : {:.5f}".format(S_tot))

# %%
def calc_y_value_any_idx(P_any_idx, p_bp=P_bp, s_tot=S_tot):
    return (s_tot * (P_any_idx - p_bp) + 10000.0) / 200.0

# %%
print("y_1 is : {:.5f}".format(calc_y_value_any_idx(P_1_100)))

# %% [markdown]
# ID = 2 replace y_value 100
#
# Public Score is -59.28220
#
# **This Public Score is equal BaselineProving(BP).**
# ![kaggle_lb_provinb_4.PNG](attachment:kaggle_lb_provinb_4.PNG)

# %%
idx_2_replace_100 = all_zeros.copy()
idx_2_replace_100["y"][1] = 100
# save submit
idx_2_replace_100.to_csv("probe_0002_100.csv", index=False)
P_2_100 = -59.28220

# %%
print("Test_data'rows is {}".format(sub.shape[0]))

# %% [markdown]
# There are **4029 lines** of test data.
# Therefore, it is necessary to repeat this procedure 4029 times.
#
# The duration of this competition is 31/5/2017 - 31/7/2017.
#
# ![kaggle_lb_provinb_submit_limit.PNG](attachment:kaggle_lb_provinb_submit_limit.PNG)
#
# 5 (submit/day) × 30 × 2 = 300 (all_submit)
#
# > We have in total 4209 data points in the test set defined by the test.csv file and we are
# allowed to make only 5 submissions per day, so it impossible for a single team4
# to probe all
# of them before the competition deadline.
