# %% [markdown]
# ![title](https://raw.githubusercontent.com/emdemor/Covid-Brasil/main/source/title_under_construction.png)
# <a id="toc"></a>

# %% [markdown]
# <div  style="margin-top: 9px; background-color: #efefef; padding-top:10px; padding-bottom:10px;margin-bottom: 9px;box-shadow: 5px 5px 5px 0px rgba(87, 87, 87, 0.2);">
#         <center>
#             <h2 style = "color: #0d354f">Table of Contents</h2>
#         </center>
#
#
# <ol>
#     <li><a href="#first" style="color: #2d934f;">Introduction</a></li>
#     <li><a href="#second" style="color: #2d934f;">Initializing Script</a></li>
#     <li><a href="#third" style="color: #2d934f;">Exploratory Analysis</a></li>
#     <li><a href="#fourth" style="color: #2d934f;">Pre-Processing</a></li>
#     <li><a href="#fifth" style="color: #2d934f;">Machine Learning: Classification Algorithms</a></li>
#
# <!--     <li><a href="#seventh"></a></li> -->
# <!--     <li><a href="#eighth">Teste t pareado para duas médias</a></li> -->
# <!--     <li><a href="#ninth">Teste F para duas variâncias</a></li> -->
# <!--     <li><a href="#tenth">Teste t para duas médias</a></li> -->
# </ol>
#
#
# </div>

# %% [markdown]
# <!-- <a id="first"></a> -->
#
# <a id="first" style="
#   background-color: #005da9;
#   border: none;
#   color: white;
#   padding: 2px 10px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 10px;" href="#toc">TOC ↻</a>
#
#
# <div  style="margin-top: 9px; background-color: #efefef; padding-top:10px; padding-bottom:10px;margin-bottom: 9px;box-shadow: 5px 5px 5px 0px rgba(87, 87, 87, 0.2);">
#         <center>
#             <h1 style = "color: #0d354f">1. Introduction</h1>
#         </center>
#
#
# <ol>
# <!--     <li><a href="#ea-init">Initializing</a></li> -->
#
# </ol>
#
#
# </div>

# %% [markdown]
# <h1 style = "color: #2d934f;">Welcome</h1>
#
# The Acea Group is one of the leading Italian multiutility operators. Listed on the Italian Stock Exchange since 1999, the company manages and develops water and electricity networks and environmental services. Acea is the foremost Italian operator in the water services sector supplying 9 million inhabitants in Lazio, Tuscany, Umbria, Molise, Campania.
#
# In this competition we will focus only on the water sector to help Acea Group preserve precious waterbodies. As it is easy to imagine, a water supply company struggles with the need to forecast the water level in a waterbody (water spring, lake, river, or aquifer) to handle daily consumption. During fall and winter waterbodies are refilled, but during spring and summer they start to drain. To help preserve the health of these waterbodies it is important to predict the most efficient water availability, in terms of level and water flow for each day of the year.
#
# <h1 style = "color: #2d934f;">Data</h1>
#
# The reality is that each waterbody has such unique characteristics that their attributes are not linked to each other. This analytics competition uses datasets that are completely independent from each other. However, it is critical to understand total availability in order to preserve water across the country.
#
# Each dataset represents a different kind of waterbody. As each waterbody is different from the other, the related features are also different. So, if for instance we consider a water spring we notice that its features are different from those of a lake. These variances are expected based upon the unique behavior and characteristics of each waterbody. The Acea Group deals with four different type of waterbodies: water springs, lakes, rivers and aquifers.
#
# <h1 style = "color: #2d934f;">Challenge</h1>
#
# Can you build a story to predict the amount of water in each unique waterbody? The challenge is to determine how features influence the water availability of each presented waterbody. To be more straightforward, gaining a better understanding of volumes, they will be able to ensure water availability for each time interval of the year.
#
# The time interval is defined as day/month depending on the available measures for each waterbody. Models should capture volumes for each waterbody(for instance, for a model working on a monthly interval a forecast over the month is expected).
#
# The desired outcome is a notebook that can generate four mathematical models, one for each category of waterbody (acquifers, water springs, river, lake) that might be applicable to each single waterbody.
#
#
# ![title](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F6195295%2Fcca952eecc1e49c54317daf97ca2cca7%2FAcea-Input.png?generation=1606932492951317&alt=media)
# <a id="toc"></a>

# %% [markdown]
# <a id="second" style="
#   background-color: #005da9;
#   border: none;
#   color: white;
#   padding: 2px 10px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 10px;" href="#toc">TOC ↻</a>
#
#
# <div  style="margin-top: 9px; background-color: #efefef; padding-top:10px; padding-bottom:10px;margin-bottom: 9px;box-shadow: 5px 5px 5px 0px rgba(87, 87, 87, 0.2);">
#         <center>
#             <h1 style = "color: #0d354f">2. Initializing Script</h1>
#         </center>
#
#
#
# <ol>
#     <li><a href="#is-dep" style="color: #2d934f;">Packages and Modules</a></li>
#     <li><a href="#is-set" style="color: #2d934f;">Settings</a></li>
#     <li><a href="#is-func" style="color: #2d934f;">Useful Functions</a></li>
# </ol>
#
#
# </div>

# %% [markdown]
# <a id="is-dep"></a>
#
# <h2 style = "color: #005da9">2.1 Packages and Modules <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#second">↻</a></h2>

# %%
# Pandas and numpy for data manipulation
import warnings
import pandas as pd
import numpy as np
import datetime as dt

# Matplotlib and seaborn for visualization
import matplotlib.pyplot as plt
import seaborn as sns
import string

# Scipy for statistics
from scipy import stats

# os to manipulate files
import os

# %% [markdown]
# <a id="is-set"></a>
#
# <h2 style = "color: #005da9">2.2 Settings <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#second">↻</a></h2>

# %%
warnings.filterwarnings("ignore")

# Setting seaborn style
# sns.set_style("darkgrid")
color_map = ["#005da9", "#f9b036","#e8e100","#2d934f","#00a8b0","#afcb37","#0d354f","#d4f593"]
sns.set_palette(sns.color_palette(
    color_map
))

# Setting Pandas float format
pd.options.display.float_format = '{:,.3f}'.format

SEED = 42   #The Answer to the Ultimate Question of Life, The Universe, and Everything
np.random.seed(SEED)

# Categories of Waterbodies
waterbodies_categories = ('aquifer', 'lake', 'river', 'water_spring')
waterbodies_target = {'aquifer':'depth', 'lake':'level', 'river':'hydrometry', 'water_spring':'depth'}

# First Date
FIRST_DATE = pd.Timestamp('2006/01/01')

# %% [markdown]
# <a id="is-func"></a>
#
# <h2 style = "color: #005da9">2.3 Useful Functions <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#second">↻</a></h2>

# %%
def get_name_from_file(file,category):
    """
    Description
    --------------
        This function with return the waterbody name from the file name.
    """
    
    # Romoving the extenstion
    file_without_extension = waterbody.replace('.csv','')
    
    # Removing the waterbody category
    file_without_cat = file_without_extension.lower().replace(cat.lower()+'_','').replace('_',' ')
    
    # Return the name capitalized
    return string.capwords(file_without_cat)

# %% [markdown]
# <a id="third" style="
#   background-color: #005da9;
#   border: none;
#   color: white;
#   padding: 2px 10px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 10px;" href="#toc">TOC ↻</a>
#
# <div  style="margin-top: 9px; background-color: #efefef; padding-top:10px; padding-bottom:10px;margin-bottom: 9px;box-shadow: 5px 5px 5px 0px rgba(87, 87, 87, 0.2);">
#         <center>
#             <h1 style = "color: #0d354f">3. Exploratory Analysis</h1>
#         </center>
#
#
# <ol>
#     <li><a href="#ea-data" style="color: #2d934f;">The Dataset</a></li>
#     <li><a href="#ea-aquifer" style="color: #2d934f;">Aquifers</a></li>
#     <li><a href="#ea-river" style="color: #2d934f;">Rivers</a></li>
#     <li><a href="#ea-lake" style="color: #2d934f;">Lakes</a></li>
#     <li><a href="#ea-ws" style="color: #2d934f;">Water Springs</a></li>
#
# </ol>
#
#
# </div>

# %% [markdown]
# <a id="ea-data"></a>
# <h2  style = "color: #005da9">3.1 The Datasets <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#third">↻</a></h2>

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
dirname

# %%
files = {} 
datasets = {}
names = {}

# Loop trough the categories
for cat in waterbodies_categories:
    
    # Get the file name
    files[cat] =  list(filter(lambda element: cat in element.lower(),os.listdir(dirname)))
    
    
    dataset_temp = {}
    names[cat] = []
    
    # Loop trough the files of this category
    for waterbody in files[cat.lower()]:
        name = get_name_from_file(waterbody,cat)
        df_temp = pd.read_csv(dirname+'/'+waterbody,parse_dates = ['Date']).sort_values('Date').reset_index(drop = True)
        
        dataset_temp[name.lower().replace(' ','_')] = df_temp
        names[cat].append(name.lower().replace(' ','_')) 
        
    datasets[cat] = dataset_temp
    
    print(cat,': ',list(datasets[cat].keys()),'\n')

# %% [markdown]
# <a id="ea-functions"></a>
# <h3  style = "color: #005da9">3.1.a Defining Functions <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-data">↻</a></h3>

# %%
def plot_waterbody_quantity(
        category,
        name,
        target_list = None,
        window = 100,
        min_periods=0,
        center = True,
    ):
    """
    Description
    --------------
        ...
    """

    waterbody_cat = category
    n_wb = len(names[waterbody_cat])
    wb_choice = name
    
    df = datasets[waterbody_cat][wb_choice].copy()
    
    std_target = list(filter(lambda element: waterbodies_target[waterbody_cat] in element.lower(),df.columns))
    if target_list:
        if type(target_list) == list:
            target_cols = target_list
        else:
            print('[Erro]: Not valid target list.')
            target_cols = std_target
    else:
        target_cols = std_target

    n_targets = len(target_cols)

    for col in target_cols:
        df[col + '_rolling'] = df[col].rolling(window,min_periods=min_periods,center = center).mean()

        df[col] = df[col] / df[col].mean()
        df[col + '_rolling'] = df[col + '_rolling'] / df[col + '_rolling'].mean()

    # Setting up figure and axes
    fig = plt.figure(figsize=(10,int(round(2.2*(1+n_targets))))) # create figure
    gs = fig.add_gridspec(n_targets, 1)

    # Change background color
    background_color = "#fbfbfb"
    fig.patch.set_facecolor(background_color)

    ax_list = []
    gs.update(wspace=0.0, hspace=0.5)
    for i in range(n_targets):

        df_temp = df[df[target_cols[i] + '_rolling'].notna()]

        x_min = df_temp['Date'].min()
        x_max = df_temp['Date'].max()
        x_ampl = x_max-x_min

        y_min = df_temp[target_cols[i] + '_rolling'].min()
        y_max = df_temp[target_cols[i] + '_rolling'].max()
        y_ampl = y_max - y_min

        ax = fig.add_subplot(gs[i, 0], ylim=(y_min - 0.3*y_ampl, y_max+0.3*y_ampl))
        ax.set_facecolor(background_color)
        ax.plot(df['Date'],df[target_cols[i]],color = color_map[7])
        ax.plot(df['Date'],df[target_cols[i] + '_rolling'],color = color_map[0])
        ax.grid(color='black', linestyle=':', axis='y', zorder=0,  dashes=(1,5))

        ax.text(df_temp['Date'].min() - 0.1*x_ampl, y_max+0.45*y_ampl, 
             target_cols[i].capitalize(), 
             fontsize=12, 
             fontweight='bold', 
             fontfamily='serif',
             horizontalalignment='left',
             color = color_map[3],
            )

        ax_list.append(ax)



    df_temp = df[df[target_cols[0] + '_rolling'].notna()]

    x_min = df_temp['Date'].min()
    x_max = df_temp['Date'].max()
    x_ampl = x_max-x_min

    y_min = df_temp[target_cols[0] + '_rolling'].min()
    y_max = df_temp[target_cols[0] + '_rolling'].max()
    y_ampl = y_max - y_min


    ax_list[0].text(df_temp['Date'].min() - 0.05*x_ampl, y_max + (0.7 + n_targets*0.05)*y_ampl, 
             waterbody_cat.capitalize()+' '+wb_choice.capitalize(), 
             fontsize=20, 
             fontweight='bold', 
             fontfamily='serif',
             color = color_map[6],
            )
    
    return fig

# %% [markdown]
# <a id="ea-aquifer"></a>
# <h2  style = "color: #005da9">3.2 Aquifers<a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#third">↻</a></h2>
#
#
# <ol>
#     <li><a href="#ea-aq-petr" style="color: #2d934f;">Petrignano</a></li>
#     <li><a href="#ea-aq-luco" style="color: #2d934f;">Luco</a></li>
#     <li><a href="#ea-aq-auser" style="color: #2d934f;">Auser</a></li>
#     <li><a href="#ea-aq-doga" style="color: #2d934f;">Doganella</a></li>
#
# </ol>

# %% [markdown]
# <a id="ea-aq-petr"></a>
# <h3  style = "color: #005da9">3.2.a Aquifer Petrignano <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-aquifer">↻</a></h3>

# %%
#'petrignano', 'luco', 'auser', 'doganella'
fig = plot_waterbody_quantity('aquifer','petrignano')

# %% [markdown]
# <a id="ea-aq-luco"></a>
# <h3  style = "color: #005da9">3.2.b Aquifer Luco <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-aquifer">↻</a></h3>

# %%
#'petrignano', 'luco', 'auser', 'doganella'
fig = plot_waterbody_quantity('aquifer','luco')

# %% [markdown]
# <a id="ea-aq-auser"></a>
# <h3  style = "color: #005da9">3.2.c Aquifer Auser <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-aquifer">↻</a></h3>

# %%
#'petrignano', 'luco', 'auser', 'doganella'
fig = plot_waterbody_quantity('aquifer','auser')

# %% [markdown]
# <a id="ea-aq-doga"></a>
# <h3  style = "color: #005da9">3.2.d Aquifer Doganella <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-aquifer">↻</a></h3>

# %%
#'petrignano', 'luco', 'auser', 'doganella'
fig = plot_waterbody_quantity('aquifer','doganella')

# %% [markdown]
# <a id="ea-river"></a>
# <h2  style = "color: #005da9">3.3 Rivers <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#third">↻</a></h2>
#
#
# <ol>
#     <li><a href="#ea-ri-arno" style="color: #2d934f;">Arno</a></li>
#
# </ol>

# %% [markdown]
# <a id="ea-ri-arno"></a>
# <h3  style = "color: #005da9">3.3.a River Arno<a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-river">↻</a></h3>

# %%
fig = plot_waterbody_quantity(
    'river','arno',
    window = 100,center = True,
    target_list = [
        'Rainfall_Le_Croci', 'Rainfall_Cavallina', 'Rainfall_S_Agata',
       'Rainfall_Mangona', 'Rainfall_S_Piero', 'Rainfall_Vernio',
       'Rainfall_Stia', 'Rainfall_Consuma', 'Rainfall_Incisa',
       'Rainfall_Montevarchi', 'Rainfall_S_Savino', 'Rainfall_Laterina',
       'Rainfall_Bibbiena', 'Rainfall_Camaldoli', 'Temperature_Firenze',
       'Hydrometry_Nave_di_Rosano' 
    ]
)

# %% [markdown]
# <a id="ea-lake"></a>
# <h2  style = "color: #005da9">3.4 Lakes <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#third">↻</a></h2>
#
#
# <ol>
#     <li><a href="#ea-lk-bila" style="color: #2d934f;">Lake Bilancino</a></li>
# </ol>

# %% [markdown]
# <a id="ea-lk-bila"></a>
# <h3  style = "color: #005da9">3.4.a Lake Bilancino<a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-lake">↻</a></h3>

# %%
datasets['lake']['bilancino'].columns

# %%
fig = plot_waterbody_quantity(
    'lake','bilancino',
    window = 100,center = True,
    target_list = [
        'Rainfall_S_Piero', 'Rainfall_Mangona', 'Rainfall_S_Agata',
       'Rainfall_Cavallina', 'Rainfall_Le_Croci', 'Temperature_Le_Croci',
       'Lake_Level', 'Flow_Rate'
    ]
)

# %% [markdown]
# <a id="ea-ws"></a>
# <h2  style = "color: #005da9">3.5 Water Springs <a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#third">↻</a></h2>
#
#
# <ol>
#     <li><a href="#ea-ws-mado" style="color: #2d934f;">Madonna di Canneto</a></li>
#     <li><a href="#ea-ws-amia" style="color: #2d934f;">Amiata</a></li>
#     <li><a href="#ea-ws-lupa" style="color: #2d934f;">Lupa</a></li>
# </ol>

# %%
datasets['water_spring'].keys()

# %% [markdown]
# <a id="ea-ws-mado"></a>
# <h3  style = "color: #005da9">3.5.a Water Spring Madonna di Canneto<a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-ws">↻</a></h3>

# %%
datasets['water_spring']['madonna_di_canneto'].columns

# %%
fig = plot_waterbody_quantity(
    'water_spring','madonna_di_canneto',
    window = 100,center = True,
    target_list = [
        'Rainfall_Settefrati', 'Temperature_Settefrati',
       'Flow_Rate_Madonna_di_Canneto'
    ]
)

# %% [markdown]
# <a id="ea-ws-amia"></a>
# <h3  style = "color: #005da9">3.5.b Water Spring Amiata<a style="
#   border-radius: 10px;
#   background-color: #f1f1f1;
#   border: none;
#   color: #2d934f;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   padding: 4px 4px;
#   font-size: 14px;" href="#ea-ws">↻</a></h3>

# %%
datasets['water_spring']['amiata'].columns

# %%
fig = plot_waterbody_quantity(
    'water_spring','amiata',
    window = 100,center = True,
    target_list = [
        'Rainfall_Castel_del_Piano', 'Rainfall_Abbadia_S_Salvatore',
       'Rainfall_S_Fiora', 'Rainfall_Laghetto_Verde', 'Rainfall_Vetta_Amiata',
       'Depth_to_Groundwater_S_Fiora_8', 'Depth_to_Groundwater_S_Fiora_11bis',
       'Depth_to_Groundwater_David_Lazzaretti',
       'Temperature_Abbadia_S_Salvatore', 'Temperature_S_Fiora',
       'Temperature_Laghetto_Verde', 'Flow_Rate_Bugnano', 'Flow_Rate_Arbure',
       'Flow_Rate_Ermicciolo', 'Flow_Rate_Galleria_Alta'
    ]
)
