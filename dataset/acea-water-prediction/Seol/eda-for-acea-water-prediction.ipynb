# %%
# !pip install dataprep

# %%
import pandas as pd
import time
from dataprep.eda import plot, plot_correlation, create_report, plot_missing

# %%
Aquifer_Auser = pd.read_csv("../input/acea-water-prediction/Aquifer_Auser.csv")
Aquifer_Doganella = pd.read_csv("../input/acea-water-prediction/Aquifer_Doganella.csv")
Aquifer_Luco = pd.read_csv("../input/acea-water-prediction/Aquifer_Luco.csv")
Aquifer_Petrignano = pd.read_csv("../input/acea-water-prediction/Aquifer_Petrignano.csv")
Lake_Bilancino = pd.read_csv("../input/acea-water-prediction/Lake_Bilancino.csv")
River_Arno = pd.read_csv("../input/acea-water-prediction/River_Arno.csv")
Water_Spring_Amiata = pd.read_csv("../input/acea-water-prediction/Water_Spring_Amiata.csv")
Water_Spring_Lupa = pd.read_csv("../input/acea-water-prediction/Water_Spring_Lupa.csv")
Water_Spring_Madonna_di_Canneto = pd.read_csv("../input/acea-water-prediction/Water_Spring_Madonna_di_Canneto.csv")

# %%
create_report(Aquifer_Auser).save("Aquifer_Auser")
create_report(Aquifer_Auser)

# %%
create_report(Aquifer_Doganella).save("Aquifer_Doganella")
create_report(Aquifer_Doganella)

# %%
create_report(Aquifer_Luco).save("Aquifer_Luco")
create_report(Aquifer_Luco)

# %%
create_report(Aquifer_Petrignano).save("Aquifer_Petrignano")
create_report(Aquifer_Petrignano)

# %%
create_report(Lake_Bilancino).save("Lake_Bilancino")
create_report(Lake_Bilancino)

# %%
create_report(River_Arno).save("River_Arno")
create_report(River_Arno)

# %%
create_report(Water_Spring_Amiata).save("Water_Spring_Amiata")
create_report(Water_Spring_Amiata)

# %%
create_report(Water_Spring_Lupa).save("Water_Spring_Lupa")
create_report(Water_Spring_Lupa)

# %%
create_report(Water_Spring_Madonna_di_Canneto).save("Water_Spring_Madonna_di_Canneto")
create_report(Water_Spring_Madonna_di_Canneto)
