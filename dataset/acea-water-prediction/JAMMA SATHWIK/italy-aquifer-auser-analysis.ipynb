# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Aquifer_Auser=pd.read_csv("../input/acea-water-prediction/Aquifer_Auser.csv")
Aquifer_Auser.head()

# %%
Aquifer_Auser.shape

# %%
plt.plot(Aquifer_Auser["Rainfall_Gallicano"])

# %%
plt.plot(Aquifer_Auser.isnull().sum())
plt.xticks(rotation=90)

# %% [markdown]
# # Rainfalls

# %%
rainfalls = Aquifer_Auser[Aquifer_Auser.columns[1:11]]
rainfalls.head()

# %%
rainfalls.shape

# %%
for i in range(10):
    sns.boxplot(rainfalls[rainfalls.columns[i]])
    plt.show()

# %% [markdown]
# # Depth to GroundWaters

# %%
depths = Aquifer_Auser[Aquifer_Auser.columns[11:16]]
depths.head()

# %%
for i in range(5):
    sns.violinplot(depths[depths.columns[i]])
    plt.show()

# %% [markdown]
# # Temperatures

# %%
temperatures = Aquifer_Auser[Aquifer_Auser.columns[16:20]]
temperatures.head()

# %%
for i in range(4):
    plt.plot(temperatures[temperatures.columns[i]])
    plt.show()

# %% [markdown]
# # Volumes

# %%
volumes = Aquifer_Auser[Aquifer_Auser.columns[20:25]]
volumes.head()

# %%
plt.figure(figsize=(10,5))
plt.plot(volumes[volumes.columns[0]],'r')
plt.plot(volumes[volumes.columns[1]],'b')
plt.plot(volumes[volumes.columns[2]],'o')

# %%
plt.figure(figsize=(10,5))
plt.plot(volumes[volumes.columns[3]],'y')
plt.plot(volumes[volumes.columns[4]],'g')
