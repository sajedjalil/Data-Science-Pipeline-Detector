# %%
import numpy as np
import pandas as pd
import os 

PROJECT_DIR = "../input/happy-whale-and-dolphin/"
TRAIN_PATH = "../input/happy-whale-and-dolphin/train.csv"
TRAIN_IMAGE_DIR = "../input/happy-whale-and-dolphin/train_images/"
TEST_IMAGE_DIR = "../input/happy-whale-and-dolphin/test_images/"

SAMPLE_SUBMISSION_PATH = "../input/happy-whale-and-dolphin/sample_submission.csv"
SUBMISSION_PATH = "submission.csv"

ID = "image"
TARGET1 = "species"
TARGET2 = "individual_id"
IMAGE_PATH_COL = "image_path"

# %%
train = pd.read_csv(TRAIN_PATH)
train[IMAGE_PATH_COL] = train[ID].apply(lambda image_path : os.path.join(PROJECT_DIR,image_path))
train.head()
