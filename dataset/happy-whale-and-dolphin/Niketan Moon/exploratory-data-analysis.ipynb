# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
train_dataset = pd.read_csv("../input/happy-whale-and-dolphin/train.csv")
