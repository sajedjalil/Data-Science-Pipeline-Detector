# %% [markdown]
# # This notebook is for someone who want to use function to plot multiple images
# # maybe for trying to create your own test set for classification

# %%
import cv2
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from glob import glob
import numpy as np
from matplotlib import pyplot as plt
import gc
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
outside_path ='../input/happy-whale-and-dolphin/'
path = '../input/happy-whale-and-dolphin/train_images/*.jpg' 
files = glob(path)
print(os.listdir(outside_path))
print(files[:10])

# %%
train_data = pd.read_csv(outside_path+'train.csv')
samp_subm = pd.read_csv(outside_path+'sample_submission.csv')

# %%
print('Number train samples:', len(train_data))
print('Number train images:', len(os.listdir(outside_path+'train_images/')))
print('Number test images:', len(os.listdir(outside_path+'test_images/')))

# %%
# plot multiple whales
def plot_examples(category = 'bottlenose_dolphin'):
    """ Plot 5 images of a given category """
    
    fig, axs = plt.subplots(1, 5, figsize=(25, 20))
    fig.subplots_adjust(hspace = .1, wspace=.1)
    axs = axs.ravel()
    temp = train_data[train_data['species']==category].copy()
    temp.index = range(len(temp.index))
    for i in range(5):
        file = temp.loc[i, 'image']
        species = temp.loc[i, 'species']
        img = cv2.imread(outside_path+'train_images/'+file)
        axs[i].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        axs[i].set_title(species)
        axs[i].set_xticklabels([])
        axs[i].set_yticklabels([])
    plt.show()

# %%
plot_examples(category = 'beluga')

# %%
plot_examples(category = 'blue_whale')

# %%
plot_examples(category = 'bottlenose_dolphin')

# %%
plot_examples(category = 'bottlenose_dolpin')

# %%
plot_examples(category = 'brydes_whale')

# %%
plot_examples(category = 'commersons_dolphin')

# %%
plot_examples(category = 'common_dolphin')

# %%
plot_examples(category = 'cuviers_beaked_whale')

# %%
plot_examples(category = 'dusky_dolphin')

# %%
plot_examples(category = 'false_killer_whale')

# %%
plot_examples(category = 'fin_whale')

# %%
plot_examples(category = 'frasiers_dolphin')

# %%
plot_examples(category = 'globis')

# %%
plot_examples(category = 'gray_whale')

# %%
plot_examples(category = 'humpback_whale')

# %%
plot_examples(category = 'kiler_whale')

# %%
plot_examples(category = 'killer_whale')

# %%
plot_examples(category = 'long_finned_pilot_whale')

# %%
plot_examples(category = 'melon_headed_whale')

# %%
plot_examples(category = 'minke_whale')

# %%
plot_examples(category = 'humpback_whale')

# %%
plot_examples(category = 'kiler_whale')

# %%
plot_examples(category = 'killer_whale')

# %%
plot_examples(category = 'long_finned_pilot_whale')

# %%
plot_examples(category = 'melon_headed_whale')

# %%
plot_examples(category = 'minke_whale')

# %%
plot_examples(category = 'pantropic_spotted_dolphin')

# %%
plot_examples(category = 'pilot_whale')

# %%
plot_examples(category = 'pygmy_killer_whale')

# %%
plot_examples(category = 'rough_toothed_dolphin')

# %%
plot_examples(category = 'sei_whale')

# %%
plot_examples(category = 'short_finned_pilot_whale')

# %%
plot_examples(category = 'southern_right_whale')

# %%
plot_examples(category = 'spinner_dolphin')

# %%
plot_examples(category = 'spotted_dolphin')

# %%
plot_examples(category = 'white_sided_dolphin')

# %% [markdown]
# If you like this please help to thumb up , thank you
