# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %% [markdown]
# yolov5でクジラ/イルカの画像を切り取りしてからkerasで学習させたい。
#
#
# 事前準備としてyolov5の使い方を整理する。

# %% [markdown]
# PATHの整理です。

# %%
def addpath(x):
    BASE_PATH = "/kaggle/input/happy-whale-and-dolphin/train"
    y = BASE_PATH + '/' + x
    return y
df = pd.read_csv('/kaggle/input/happy-whale-and-dolphin/train.csv')
df['image'] = df['image'].apply(addpath)

# %% [markdown]
# yolov5のセットアップ

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks

# %%
BASE_PATH = "/kaggle/input/happy-whale-and-dolphin/train"
SAVE_PATH = "/kaggle/working/exp"

# %% [markdown]
# プロジェクトフォルダに対してdetect.pyを実施
# /kaggle/workingフォルダへ結果保存
# save-crop検出したものを切り取って保存exp/cropに保存されている。

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.01 --source /kaggle/input/happy-whale-and-dolphin/test_images/000110707af0ba.jpg --project /kaggle/working --save-crop
#フォルダに適用する場合はこれを以下を使う
#!python detect.py --weights yolov5s.pt --img 640 --conf 0.2 --source /kaggle/input/happy-whale-and-dolphin/test_images --project /kaggle/working --save-crop
#display.Image(filename='/kaggle/input/happy-whale-and-dolphin/test_images/186a069306d4de.jpg', width=600)
#display.Image(filename='/kaggle/working/yolov5/runs/detect/exp2/ffdcc55cbc1559.jpg', width=600)

# %% [markdown]
# イルカやクジラと認識されない(/ω＼)
#
# クジラ/イルカのデータセットを用意し学習する。train.py
#
# 学習後にdetecする。

# %%
display.Image(filename='/kaggle/working/exp/000110707af0ba.jpg', width=600)
