# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import cv2
import matplotlib.pyplot as plt

# %%
train = glob.glob("../input/happy-whale-and-dolphin/test_images/*")
I=cv2.imread(train[0])
I.shape

# %%
data =pd.DataFrame()
data['path'] = train
data['x']=data['path'].apply(lambda a: cv2.imread(a).shape[0])
data['y']=data['path'].apply(lambda a: cv2.imread(a).shape[1])
data

# %%
data.describe()

# %%
test = glob.glob("../input/happy-whale-and-dolphin/train_images/*")
I=cv2.imread(test[0])
I.shape

# %%
data2 =pd.DataFrame()
data2['path'] = test
data2['x'] =data2['path'].apply(lambda a: cv2.imread(a).shape[0])
data2['y'] =data2['path'].apply(lambda a: cv2.imread(a).shape[1])
data2

# %%
data2.describe()

# %%
data.to_csv('train.csv',index=False)
data2.to_csv('test.csv',index=False)
