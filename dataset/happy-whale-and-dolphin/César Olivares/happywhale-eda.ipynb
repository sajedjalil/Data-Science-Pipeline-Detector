# %% [markdown]
# ## Brief EDA of the Happywhale competition data. 🐋🐬

# %% [markdown]
# <img src="https://static.simpsonswiki.com/images/thumb/e/ec/Betsy.png/250px-Betsy.png" alt="alt text" title="image Title" height="750"/>

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Look at the train csv

# %%
df = pd.read_csv('../input/happy-whale-and-dolphin/train.csv')

# %%
df.head()

# %% [markdown]
# ## The dataframe has 3 rows:
# * Image id
# * The species
# * An individual id
#
# ## How many images do we have?

# %%
df.image.shape

# %% [markdown]
# ## Number of species?

# %%
len(df.species.unique())

# %% [markdown]
# ## How many unique individual id?

# %%
len(df.individual_id.unique())

# %% [markdown]
# # Let's find the number of images per specie

# %%
df.groupby('species').count().plot.barh(figsize=(10,8))

# %% [markdown]
# # The number of image per species seems to be inbalanced. 🧐

# %% [markdown]
# # Explore some images

# %%
df_show = df.sample(9)
img_ids = df_show['image'].values
species_ids = df_show['species'].values

path = '../input/happy-whale-and-dolphin/train_images/'

fig = plt.figure(figsize=(15, 15))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = cv2.imread(path+ img_ids[i-1])
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
    plt.title(species_ids[i-1])
plt.show()

# %% [markdown]
# # Now by unique id which is the label we will predict.

# %%
random_id = df.individual_id.sample(1).values
unique_id = df[df['individual_id'] == random_id[0]]

img_ids = unique_id.sample(3)['image'].values

path = '../input/happy-whale-and-dolphin/train_images/'

fig = plt.figure(figsize=(15, 15))
columns = 3
rows = 1
for i in range(1, columns*rows +1):
    img = cv2.imread(path+ img_ids[i-1])
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
    plt.title(unique_id.species.unique()[0] + '\n' + random_id[0])
plt.show()

# %% [markdown]
# ## Working...
