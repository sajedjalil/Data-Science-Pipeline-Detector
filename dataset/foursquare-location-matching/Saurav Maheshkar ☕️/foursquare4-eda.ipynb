# %% [markdown]
# # Packages 📦 and Basic Setup
#
# ---

# %%
# %%capture
# !pip install -U skimpy

import numpy as np
import pandas as pd
from skimpy import skim

# %% [markdown]
# # 💿 The Data
# ---

# %%
df_train = pd.read_csv('../input/foursquare-location-matching/train.csv')
df_test = pd.read_csv('../input/foursquare-location-matching/test.csv')
df_pairs = pd.read_csv('../input/foursquare-location-matching/pairs.csv')

# %% [markdown]
# # 🧐 Exploratory Data Analysis
# ---

# %%
skim(df_train)

# %%
skim(df_pairs)

# %% [markdown]
# <div align = 'center'>
#   <h1>🚧🚧🚧 WORK IN PROGRESS 🚧🚧</h1>
# </div>
