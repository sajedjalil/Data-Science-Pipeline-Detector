# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
train=pd.read_csv('../input/foursquare-location-matching/train.csv')

# %%
sns.displot(train['latitude'], kind='kde')

# %%
train.info()

# %%
train.describe()

# %%
counts_country=train['country'].value_counts()[:10:]
countries=train['country'].tolist()[:10:]
sns.barplot(countries, counts_country)

# %%
cities=train['city'].unique()[:10:]
city_counts=train['city'].value_counts()[:10:]
sns.barplot(cities, city_counts)

# %%
train.columns

# %%
cats=train['categories'].unique()[:3:]
cats_value=train['categories'].value_counts()[:3:]
sns.barplot(cats, cats_value)

# %%
len(train['categories'].unique())

# %%
train['point_of_interest'].value_counts()

# %%
train.hist()

# %%
perc=[]
for i in train.columns:
    perc.append(train[i].isna().sum())

# %%
sns.barplot(perc, train.columns)

# %%
poi = train['point_of_interest'].unique()[:10:]
poi_counts=train['point_of_interest'].value_counts()[:10:]

# %%
sns.barplot(poi, poi_counts)
