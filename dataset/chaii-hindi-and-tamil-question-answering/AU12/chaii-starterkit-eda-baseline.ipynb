# %% [markdown]
# # ChAII Starter Code: EDA + Baseline
# My first proper competition with text and QnA. The plan you ask? ... well its simple
# <img src="https://media.giphy.com/media/l3V0x0469o9iWA2He/giphy.gif">
# - Learn along the way
# - Getting better at EDA
# - Explore different tricks in the Text/NLP domain
# - Train some fancy models (well, why not :D)
# - Try to get a decent leaderboard finish (nothing fancy, haven't participated actively in any competition so far)

# %% [markdown]
# ## It's Raining Imports here!!!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading The Data

# %%
df_train = pd.read_csv('../input/chaii-hindi-and-tamil-question-answering/train.csv')
df_test = pd.read_csv('../input/chaii-hindi-and-tamil-question-answering/test.csv')
df_sub = pd.read_csv('../input/chaii-hindi-and-tamil-question-answering/sample_submission.csv')

# %% [markdown]
# ## Let us get to the Exploration, Shall we?
# <img src="https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy.gif" width="500" class="center">

# %%
df_train.head(15)

# %%
print(f"Total samples in train set: {len(df_train)}")
print(f"Total samples in test set: {len(df_test)}")
print(f"Total samples for submission: {len(df_sub)}")

# %%
df_train.info()

# %% [markdown]
# ## Language metrics

# %%
# Train Language splits
print("LANGUAGE SPLIT FOR TRAIN SET")
print(df_train['language'].value_counts())
print("\n")
# Test Language Split
print("LANGUAGE SPLIT FOR TEST SET")
print(df_test['language'].value_counts())

# %%
# For Train Set
df_train['language'].value_counts().plot.bar()
plt.title('Train Language Split')

# %% [markdown]
# ## Language-wise Word and Character plots

# %%
# spliting the dataframe into language specific dataframes
df_train_hindi = df_train[df_train['language']=='hindi']
df_train_tamil = df_train[df_train['language']=='tamil']

# %% [markdown]
# ### Question Word Length

# %%
# For Hindi
df_train_hindi['question'].apply(lambda x: len(x.split())).plot(kind='hist')
plt.title('Question Word Count for Hindi')

# %%
# For Tamil
df_train_tamil['question'].apply(lambda x: len(x.split())).plot(kind='hist')
plt.title('Question Word Count for Tamil')

# %% [markdown]
# ### Question Char Length

# %%
# For Hindi
df_train_hindi['question'].apply(lambda x: len(x)).plot(kind='hist')
plt.title('Question Char Count for Hindi')

# %%
# For Tamil
df_train_tamil['question'].apply(lambda x: len(x)).plot(kind='hist')
plt.title('Question Char Count for Tamil')

# %% [markdown]
# ### Context Word Length

# %%
# For Hindi
df_train_hindi['context'].apply(lambda x: len(x.split())).plot(kind='hist')
plt.title('Context Word Count for Hindi')

# %%
# For Tamil
df_train_tamil['context'].apply(lambda x: len(x.split())).plot(kind='hist')
plt.title('Context Word Count for Tamil')

# %% [markdown]
# ### Context Char Length

# %%
# For Hindi
df_train_hindi['context'].apply(lambda x: len(x)).plot(kind='hist')
plt.xscale('log')
plt.title('Context Char count for Hindi')

# %%
# For Tamil
df_train_tamil['context'].apply(lambda x: len(x)).plot(kind='hist')
plt.xscale('log')
plt.title('Context Char count for Tamil')

# %% [markdown]
# ## Full Train Set Level Stats for Words and Characters

# %% [markdown]
# ### Word and Char stats for Questions

# %%
# For Full Train Set Question : Word Level
df_train['question'].apply(lambda x: len(x.split())).plot(kind='hist')
plt.title('Question word count in words for Full Train Set')

# %%
# For Full Train Set Question : Char level
df_train['question'].apply(lambda x: len(x)).plot(kind='hist')
plt.title('Question Char count for Full Train Set')

# %% [markdown]
# ### Words and Char Stats for Context

# %%
# For Full Set Train Context : Word Level
df_train['context'].apply(lambda x: len(x.split())).plot(kind='hist')
plt.title('Context word count for Full Train Set')

# %%
# For Full Set Train Context : Char level
df_train['context'].apply(lambda x: len(x)).plot(kind='hist')
plt.xscale('log')
plt.title('Context char count for Full Train Set')

# %% [markdown]
# **More EDA in upcoming versions, this seems to be okay for now**

# %% [markdown]
# # Baseline Model

# %% [markdown]
# Since this is the very first version, we will keep it simple and evolve it as the competition proceeds.
#
# For now Sticking to the pipeline from the transformers library and later will enhance the solution. This mean unfortunately no finetuning or training in this one lads.
#
# <img src="https://media.giphy.com/media/7CiWMPL8IZFwq0DLxy/giphy-downsized.gif">

# %%
from transformers import pipeline

# %%
model_name = "../input/xlm-roberta-squad2/deepset/xlm-roberta-large-squad2"
batch_size = 16

# %%
pip1 = pipeline('question-answering', model=model_name, tokenizer=model_name, device=0)

# %%
predictions = []
for que,cont in df_test[['question','context']].to_numpy():
    ans = pip1(context=cont, question=que)
    print(ans)
    predictions.append(ans['answer'])

# %%
submission_df = pd.DataFrame(data={"id": df_test["id"], "PredictionString": predictions})

submission_df.to_csv("submission.csv", index=False)

submission_df

# %% [markdown]
# So For the baseline using transformers pipeline, In the future iterations of the kernel we have the following targets:
# - Advanced EDA
# - Beating the above baseline
#
# <img src="https://media.giphy.com/media/u5BzptR1OTZ04/giphy.gif" width='500'>

# %% [markdown]
# Watch this space for more updates, lets see how it goes.
#
# **If you like it so far, consider upvoting 😄**
#
# <img src="https://media.giphy.com/media/eunrMjB8lBUKeL1fqD/giphy-downsized.gif">
