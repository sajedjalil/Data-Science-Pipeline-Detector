# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
train = pd.read_csv("../input/chaii-hindi-and-tamil-question-answering/train.csv")
train

# %%
test = pd.read_csv("../input/chaii-hindi-and-tamil-question-answering/test.csv")
test

# %%
print(train.shape)
print(test.shape)

# %%
train.columns

# %%
test.columns

# %%
train.describe()

# %%
test.describe()

# %%
train.info()

# %%
test.info()

# %%
from pandas_profiling import ProfileReport

# %%
profile_train = ProfileReport(train, title="Pandas Profiling Report", explorative=True)
profile_train

# %%
profile_test = ProfileReport(test, title="Pandas Profiling Report", explorative=True)
profile_test

# %%
# count plot of language
fig = plt.subplots(figsize = (5,5))
sns.countplot(x='language',data=train)

# %%
tamil_in_t= test[test['language']=="tamil"].shape[0]*100/test.shape[0]
hindi_in_t= test[test['language']=="hindi"].shape[0]*100/test.shape[0]

# %%
test["context"]

# %%
tamil_in= train[train['language']=="tamil"].shape[0]*100/train.shape[0]
hindi_in= train[train['language']=="hindi"].shape[0]*100/train.shape[0]

# %%
train["context"]

# %%
submission = pd.read_csv("../input/chaii-hindi-and-tamil-question-answering/sample_submission.csv")
submission

# %%
### work in progress 
### will update soon
