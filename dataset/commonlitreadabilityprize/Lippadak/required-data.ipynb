# %%
# !pip install transformers --quiet
# !pip install tensorflow --quiet

# %%
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py

# %%
# !ls

# %%
from transformers import (AutoModel, AutoTokenizer)
from transformers import AutoModelWithLMHead

# %%
model = AutoModel.from_pretrained('idjotherwise/autonlp-reading_prediction-172506',output_hidden_states=True)  
# model = AutoModelWithLMHead.from_pretrained("huggingtweets/texttheater")

# %%
# model

# %%
tokenizer = AutoTokenizer.from_pretrained('idjotherwise/autonlp-reading_prediction-172506')
# tokenizer = AutoTokenizer.from_pretrained("huggingtweets/texttheater")

# %%
import os
os.makedirs('./renjith')

# %%
model.save_pretrained("./renjith")
tokenizer.save_pretrained("./renjith")
