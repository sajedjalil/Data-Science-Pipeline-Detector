# %%
import pandas as pd
ids = ["c0f722661", "f0953f0a5", "0df072751", "04caf4e0c", "0e63f8bea", "12537fe78", "965e592c0"]
target = [1, 1, 1, 1, 1, 1, 1]
result = pd.DataFrame({"id": ids, "target": target})
result

# %%
result.to_csv("submission.csv", index=False)
