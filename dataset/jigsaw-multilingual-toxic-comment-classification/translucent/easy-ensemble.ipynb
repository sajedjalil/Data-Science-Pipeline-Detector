# %% [markdown]
# # phase 1 [Ensemble]

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import os

# %% [markdown]
# submission_train2mix comes from my kernel https://www.kaggle.com/xukaibing/single-model-9471-9455-private-lb

# %% [markdown]
# other submissions come from other public kernels or my history kernels

# %%
submission1 = pd.read_csv('/kaggle/input/sub0427/submission9404.csv')
submission9412 = pd.read_csv('/kaggle/input/sub0427/submission9412.csv')
submission9463 = pd.read_csv('/kaggle/input/haveatry/submission9463.csv')
submission4 = pd.read_csv('/kaggle/input/sub0427/submissionen9115.csv')
submission5 = pd.read_csv('/kaggle/input/sub0427/submission9408.csv')
submission6 = pd.read_csv('/kaggle/input/haveatry/submission9435.csv')
submission9477 = pd.read_csv('/kaggle/input/haveatry/submission9477.csv')
submission9438 = pd.read_csv('/kaggle/input/haveatry/submission9438.csv')
submission_val9710 = pd.read_csv('/kaggle/input/haveatry/submission_val9710.csv')
submission9480 = pd.read_csv('/kaggle/input/haveatry/submission9480.csv')
submission9471 = pd.read_csv('/kaggle/input/haveatry/submission9471.csv')
submission9472 = pd.read_csv('/kaggle/input/haveatry/submission9472.csv')
submission9460 = pd.read_csv('/kaggle/input/haveatry/submission_train2_9460.csv')
submission9454 = pd.read_csv('/kaggle/input/haveatry/submission9454.csv')
submission9457 = pd.read_csv('/kaggle/input/haveatry/submission9457.csv')
submission9458 = pd.read_csv('/kaggle/input/haveatry/submission9458.csv')
submission9481 = pd.read_csv('/kaggle/input/haveatry/submission9481.csv')
submission9482 = pd.read_csv('/kaggle/input/haveatry/submission9482.csv')
submission9483 = pd.read_csv('/kaggle/input/haveatry/submission9483.csv')
submission9484 = pd.read_csv('/kaggle/input/haveatry/submission9484.csv')
submission9486 = pd.read_csv('/kaggle/input/haveatry/submission9486.csv')
submission9487 = pd.read_csv('/kaggle/input/haveatry/submission9487.csv')
submission9488 = pd.read_csv('/kaggle/input/haveatry/submission9488.csv')
submission9442 = pd.read_csv('/kaggle/input/haveatry/submission9442(2).csv')
submission9443 = pd.read_csv('/kaggle/input/haveatry/submission9443.csv')
submission9450 = pd.read_csv('/kaggle/input/haveatry/submission9450.csv')
submission9459 = pd.read_csv('/kaggle/input/haveatry/submission9459(2).csv')
submission9435 = pd.read_csv('/kaggle/input/haveatry/submission9435(2).csv')
submission9436 = pd.read_csv('/kaggle/input/haveatry/submission9436(2).csv')
submission9446 = pd.read_csv('/kaggle/input/haveatry/submission_mix_9446.csv')
submission_tr_9437=pd.read_csv('/kaggle/input/haveatry/submission_tr_9437.csv')
submission_it=pd.read_csv('/kaggle/input/haveatry/submission_it_0.csv')
submission_pt=pd.read_csv('/kaggle/input/haveatry/submission_pt_0.csv')
submission_es=pd.read_csv('/kaggle/input/haveatry/submission_es_0.csv')
submission_fr=pd.read_csv('/kaggle/input/haveatry/submission_fr_0.csv')
submission_ru=pd.read_csv('/kaggle/input/haveatry/submission_ru_0.csv')
submission_es_precise=pd.read_csv('/kaggle/input/haveatry/submission_es_precise.csv')
sub = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/sample_submission.csv')
test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')

# %%
submission_mix1 = pd.read_csv('/kaggle/input/haveatry/submission_mix1.csv')
submission_mix2 = pd.read_csv('/kaggle/input/haveatry/submission_mix2.csv')
submission_mix3 = pd.read_csv('/kaggle/input/haveatry/submission_mix3.csv')

# %%
submission_train2mix1 = pd.read_csv('/kaggle/input/haveatry/submission9450.csv')
submission_train2mix2 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_2.csv')
submission_train2mix3 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_3.csv')
submission_train2mix4 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_4.csv')
submission_train2mix5 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_5.csv')
submission_train2mix6 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_6.csv')
submission_train2mix7 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_7.csv')
submission_train2mix8 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_8.csv')
submission_train2mix9 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_9.csv')
submission_train2mix10 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_10.csv')
submission_train2mix11 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_11.csv')
submission_train2mix12 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_12.csv')
submission_train2mix13 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_13.csv')
submission_train2mix14 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_14.csv')
submission_train2mix15 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_15.csv')
submission_train2mix16 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_16.csv')
submission_train2mix17 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_17.csv')
submission_train2mix18 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_18.csv')
submission_train2mix19 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_19.csv')
submission_train2mix20 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_20.csv')
submission_train2mix21 = pd.read_csv('/kaggle/input/haveatry/submission_train2mix_21.csv')

# %%
submission9464 = pd.read_csv('/kaggle/input/haveatry/submission9464.csv')

# %%
submission9470 = pd.read_csv('/kaggle/input/haveatry/submission_train2_9470.csv')

# %%
submission_mix9450 = pd.read_csv('/kaggle/input/haveatry/submission_mix123_9450.csv')

# %%
sns.set()
plt.hist(submission1['toxic'],bins=100)
plt.show()

# %%
for i in range(len(submission1['toxic'])):
    sub['toxic'][i]=submission9460['toxic'][i]*0.15+submission9487['toxic'][i]*0.85

# %%
#submission1['toxic'] = submission1['toxic'].round()

# %%
#sub['toxic']=result
sub.to_csv('submission.csv', index=False)

# %%
print(sub)
