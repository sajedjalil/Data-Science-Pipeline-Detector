# %% [markdown]
# # This project will build a model to automatically classify 100 plant species using features extracted from their leaf images.
# ### The data were downloaded from the UCI machine-learning repository. The data contains three files of pre-extracted feature vectors used in the published paper. The data also contains black and white leaf images which allows feature extraction for model building.
# ### I will first prepare the pre-extracted features and use them as a benchmark in model building.
# ### I will mainly focus on extracting features from the images and test whether and how they can be used for model building.
# ### Although this project didn't use the data on kaggle, it is highly related to the classification task assigned here. I upload my notebook here in case that you are interested.
# ### Comments are welcomed.
# ###https://github.com/vradore/python_data/blob/master/UCI_plant_leaves/species_classification_MGu_final.ipynb
