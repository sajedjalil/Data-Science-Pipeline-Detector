# %%
import os
import re
import gc
import sys
import yaml
import copy
import random
import shutil
import typing as tp
from pathlib import Path

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

import cv2
import albumentations
from albumentations.core.transforms_interface import ImageOnlyTransform, DualTransform
from albumentations.pytorch import ToTensorV2

import torch
from torch import nn
from torch.utils import data


sys.path.append("../input/iterative-stratification/iterative-stratification-master")
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# %%
import numpy as np
import pandas as pd
import torch

train = pd.read_pickle('../input/molecular-preprocessed/train2.pkl')

def get_train_file_path(image_id):
    return "../input/bms-molecular-translation/train/{}/{}/{}/{}.png".format(
        image_id[0], image_id[1], image_id[2], image_id 
    )

#train['path'] = train['image_id'].apply(get_train_file_path)

print(f'train.shape: {train.shape}')

# %%
from sklearn.model_selection import train_test_split

# %%
#train_ids,test_ids = train_test_split(train,test_size=0.2)

# %%
#train['kfold'] = -1
#train.loc[train_ids.index,'kfold'] = -1
#train.loc[test_ids.index,'kfold'] = 0

# %%
train_save = pd.read_csv('../input/moleculartraintestsplit/data.csv')
train_save.to_csv('data.csv',index=False)

# %%
path_dict = {}
import os
for dirname, _, filenames in os.walk('../input/bms-molecular-translation/test'):
    for filename in filenames:
        path_dict[filename.replace('.png','')] = os.path.join(dirname, filename)

# %%
train_save.head()

# %%
sample = pd.read_csv('../input/bms-molecular-translation/sample_submission.csv')

# %%
sample['path'] = sample.image_id.apply(lambda x:path_dict[x])

# %%
sample.to_csv('sample_submission.csv',index=False)
