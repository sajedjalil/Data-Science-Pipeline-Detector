# %%
import os
import sys

os.system('pip install --no-index --find-links="../input/pytorchpretrainedbert/" pytorch_pretrained_bert')
# !cp -r ../input/jigsaw-pytorch-pretrained-bert/repository/huggingface-pytorch-pretrained-BERT-3fc63f1/ ./
# !pip install ./huggingface-pytorch-pretrained-BERT-3fc63f1/.

# %%
# !wget https://storage.googleapis.com/bert_models/2019_05_30/wwm_uncased_L-24_H-1024_A-16.zip
# !unzip wwm_uncased_L-24_H-1024_A-16.zip
# !rm wwm_uncased_L-24_H-1024_A-16.zip

# %%
# !mkdir bert_large_uncased_whole_word_masking
# !cp ./wwm_uncased_L-24_H-1024_A-16/bert_config.json ./bert_large_uncased_whole_word_masking/

# !pytorch_pretrained_bert convert_tf_checkpoint_to_pytorch \
    wwm_uncased_L-24_H-1024_A-16/bert_model.ckpt \
    wwm_uncased_L-24_H-1024_A-16/bert_config.json \
    bert_large_uncased_whole_word_masking/pytorch_model.bin

# !rm -rf wwm_uncased_L-24_H-1024_A-16
# !tar czf bert_large_uncased_whole_word_masking.tar.gz bert_large_uncased_whole_word_masking
# !rm -rf bert_large_uncased_whole_word_masking

# %%
# !wget https://storage.googleapis.com/bert_models/2019_05_30/wwm_cased_L-24_H-1024_A-16.zip
# !unzip wwm_cased_L-24_H-1024_A-16.zip
# !rm wwm_cased_L-24_H-1024_A-16.zip

# %%
# !mkdir bert_large_cased_whole_word_masking
# !cp ./wwm_cased_L-24_H-1024_A-16/bert_config.json ./bert_large_cased_whole_word_masking/

# !pytorch_pretrained_bert convert_tf_checkpoint_to_pytorch \
    wwm_cased_L-24_H-1024_A-16/bert_model.ckpt \
    wwm_cased_L-24_H-1024_A-16/bert_config.json \
    bert_large_cased_whole_word_masking/pytorch_model.bin

# !rm -rf wwm_cased_L-24_H-1024_A-16
# !tar czf bert_large_cased_whole_word_masking.tar.gz bert_large_cased_whole_word_masking
# !rm -rf bert_large_cased_whole_word_masking

# %%
# !rm -rf ./huggingface-pytorch-pretrained-BERT-3fc63f1
