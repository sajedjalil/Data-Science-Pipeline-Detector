# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import tensorflow as tf

# %%
data=pd.read_csv("../input/jigsaw-unintended-bias-in-toxicity-classification/all_data.csv")

# %%
data.head()

# %%
data.info()

# %%
print("id",data["id"].isnull().sum())
print("comment_text",data["comment_text"].isnull().sum())
print("split",data["split"].isnull().sum())
print("created_date",data["created_date"].isnull().sum())
print("publication_id",data["publication_id"].isnull().sum())
print("parent_id",data["parent_id"].isnull().sum())
print("article_id",data["article_id"].isnull().sum())
print("rating",data["rating"].isnull().sum())
print("funny",data["funny"].isnull().sum())
print("wow",data["wow"].isnull().sum())
print("sad",data["sad"].isnull().sum())
print("likes",data["likes"].isnull().sum())
print("disagree",data["disagree"].isnull().sum())
print("toxicity",data["toxicity"].isnull().sum())
print("severe_toxicity",data["severe_toxicity"].isnull().sum())
print("obscene",data["obscene"].isnull().sum())
print("sexual_explicit",data["sexual_explicit"].isnull().sum())
print("identity_attack",data["identity_attack"].isnull().sum())
print("insult",data["insult"].isnull().sum())
print("threat",data["threat"].isnull().sum())
print("male",data["male"].isnull().sum())
print("female",data["female"].isnull().sum())
print("transgender",data["transgender"].isnull().sum())
print("other_gender",data["other_gender"].isnull().sum())
print("heterosexual",data["heterosexual"].isnull().sum())
print("homosexual_gay_or_lesbian",data["homosexual_gay_or_lesbian"].isnull().sum())
print("bisexual",data["bisexual"].isnull().sum())
print("other_sexual_orientation",data["other_sexual_orientation"].isnull().sum())
print("christian",data["christian"].isnull().sum())
print("jewish",data["jewish"].isnull().sum())
print("muslim",data["muslim"].isnull().sum())
print("hindu",data["hindu"].isnull().sum())
print("buddhist",data["buddhist"].isnull().sum())
print("atheist",data["atheist"].isnull().sum())
print("other_religion",data["other_religion"].isnull().sum())
print("black",data["black"].isnull().sum())
print("white",data["white"].isnull().sum())
print("asian",data["asian"].isnull().sum())
print("latino",data["latino"].isnull().sum())
print("other_race_or_ethnicity",data["other_race_or_ethnicity"].isnull().sum())
print("physical_disability",data["physical_disability"].isnull().sum())
print("intellectual_or_learning_disability",data["intellectual_or_learning_disability"].isnull().sum())
print("psychiatric_or_mental_illness",data["psychiatric_or_mental_illness"].isnull().sum())
print("other_disability",data["other_disability"].isnull().sum())
print("identity_annotator_count",data["identity_annotator_count"].isnull().sum())
print("toxicity_annotator_count",data["toxicity_annotator_count"].isnull().sum())

# %%
data.drop(['parent_id','male',
'female',
'transgender',
'other_gender',
'heterosexual',
'homosexual_gay_or_lesbian',
'bisexual',
'other_sexual_orientation',
'christian',
'jewish',
'muslim',
'hindu',
'buddhist',
'atheist',
'other_religion',
'black',
'white',
'asian',
'latino',
'other_race_or_ethnicity',
'physical_disability',
'intellectual_or_learning_disability',
'psychiatric_or_mental_illness',
'other_disability'],axis=1,inplace=True)

# %%
data.info()

# %%
data

# %%
print("id",data['id'].value_counts())
print("comment_text",data['comment_text'].value_counts())
print("split",data['split'].value_counts())
print("created_date",data['created_date'].value_counts())
print("publication_id",data['publication_id'].value_counts())
print("article_id",data['article_id'].value_counts())
print("rating",data['rating'].value_counts())
print("funny",data['funny'].value_counts())
print("wow",data['wow'].value_counts())
print("sad",data['sad'].value_counts())
print("likes",data['likes'].value_counts())
print("disagree",data['disagree'].value_counts())
print("toxicity",data['toxicity'].value_counts())
print("severe_toxicity",data['severe_toxicity'].value_counts())
print("obscene",data['obscene'].value_counts())
print("sexual_explicit",data['sexual_explicit'].value_counts())
print("identity_attack",data['identity_attack'].value_counts())
print("insult",data['insult'].value_counts())
print("threat",data['threat'].value_counts())
print("identity_annotator_count",data['identity_annotator_count'].value_counts())
print("toxicity_annotator_count",data['toxicity_annotator_count'].value_counts())

# %%
data

# %%
data.to_csv('csv_to_submit.csv', index = False)
