# %% [markdown]
# You can use this notebook as an empty starter template, if you want more detail on how to use actors' functions check this cool notebook: [https://www.kaggle.com/thalesgaluchi/lux-ai-first-approach](https://www.kaggle.com/thalesgaluchi/lux-ai-first-approach)

# %%
# !pip install kaggle-environments -U

# %%
from kaggle_environments import make
import json

# %%
# Run this if you are using kaggle notebooks
# !cp -r ../input/lux-ai-2021/* .

# %% [markdown]
# Get your code and strategy for your agent inside agent function.

# %%
def agent(observation, configuration):
    global game_state
    actions = []
    # your code here
    return actions

# %% [markdown]
# # Watch your agent play
#
# Use the next code block to visualize your agent playing against a simple agent.

# %%
# run another match but with our empty agent
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2}, debug=False)
steps = env.run(["./agent.py", "simple_agent"])
# Show the game
env.render(mode="ipython", width=800, height=600)

# %% [markdown]
# Or you can replay it on your browser [here](https://2021vis.lux-ai.org/)

# %%
# save the replay as a file. if working locally this should appear in your current directory, otherwise you can download
# from this kaggle notebook by opening the output section of the data panel on the right
replay = env.toJSON()
with open("replay.json", "w") as f:
    json.dump(replay, f)
# this replay can then be watched here https://2021vis.lux-ai.org/

# %% [markdown]
# # Create submission file

# %%
# !tar -czf submission.tar.gz *
