# %% [markdown]
# **Code from https://www.kaggle.com/c/lux-ai-2021/discussion/276938**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

# %% [markdown]
# **Using 32x32 and without err**

# %%
import matplotlib.pyplot as plt
import json
replay = "../input/testerrjsonok/27826113-0.json"
with open(replay, "r") as read_file:
    data = json.load(read_file)

plt.plot([data[c][0]['duration'] for c in range(len(data))])

# %% [markdown]
# **Using 32x32 and with err**

# %%
import matplotlib.pyplot as plt
import json
replay = "../input/testerrjson/27825952-1.json"
with open(replay, "r") as read_file:
    data = json.load(read_file)

plt.plot([data[c][0]['duration'] for c in range(len(data))])

# %% [markdown]
# **Using 32x32 a try with quant transform**
# https://pytorch.org/docs/stable/quantization.html

# %%
import matplotlib.pyplot as plt
import json
replay = "../input/testerrjsonquant/27827058-1.json"
with open(replay, "r") as read_file:
    data = json.load(read_file)

plt.plot([data[c][0]['duration'] for c in range(len(data))])
