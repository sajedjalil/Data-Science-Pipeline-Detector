# %%
# !git clone https://github.com/AI-Leap/lux-ai-rule-based-agent
# !mv lux-ai-rule-based-agent/* .
# !rm -rf lux-ai-rule-based-agent
# !tar -czf submission.tar.gz *

# %%
from kaggle_environments import make

env = make("lux_ai_2021", configuration={"width": 12, "height": 12, "loglevel": 2, "annotations": True}, debug=False)
steeps = env.run(['agent.py', 'simple_agent'])
env.render(mode="ipython", width=900, height= 800)

# %% [markdown]
# Let us use the sentdex example agent : https://www.youtube.com/watch?v=6_GXTbTL9Uc&t=313s

# %%
# !wget "https://gist.githubusercontent.com/Sentdex/971fa96b6b706627d69ba0a09ae437cc/raw/652fed15660200f65e935b6d0c118ceced5af32d/agent.py" -o "agent1.py"

# %%
steeps = env.run(['agent1.py', 'simple_agent'])
env.render(mode="ipython", width=900, height= 800)

# %% [markdown]
# Woah sentdex actually won
