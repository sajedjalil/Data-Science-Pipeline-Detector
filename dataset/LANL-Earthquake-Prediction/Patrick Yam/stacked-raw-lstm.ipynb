# %%
import numpy as np
import pandas as pd
import os
import psutil
import math

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.metrics import mean_absolute_error
pd.options.display.precision = 15

import time
import datetime

import gc
import seaborn as sns
import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")

# %%
# %%time
train = pd.read_csv('../input/train.csv', dtype={'acoustic_data': np.int16, 'time_to_failure': np.float32})
# Out:
# CPU times: user 2min 4s, sys: 11.5 s, total: 2min 15s
# Wall time: 2min 16s

# %%
X_mean = train['acoustic_data'].mean()
X_std = train['acoustic_data'].std()
y_mean = train['time_to_failure'].mean()
y_std = train['time_to_failure'].std()

# %%
cut_time = []
for i in range(0,len(train)-10000,10000):
    if train['time_to_failure'][i] < train['time_to_failure'][i + 10000]:
        cut_time.append(i)
accurate_cut_time = [0]
for t in cut_time:
    for i in range(t,t+10000):
        if train['time_to_failure'][i] < train['time_to_failure'][i + 1]:
            accurate_cut_time.append(i + 1)
            break
accurate_cut_time.append(len(train))

# %%
df_all = []
for i in range(len(accurate_cut_time)-1):
    df_all.append(train.iloc[accurate_cut_time[i]:accurate_cut_time[i] + 150000 * ((accurate_cut_time[i+1] - accurate_cut_time[i]) // 150000)])

# %%
del train
del cut_time
del accurate_cut_time
gc.collect()
# Out:
# 18

# %%
val_df = []
val_target = []
for df in df_all[:3]:
    segments = int(np.floor(df.shape[0] / 150000))
    for segment in tqdm_notebook(range(segments)):
        seg = df.iloc[segment*150000:segment*150000+150000]
        x_raw = seg['acoustic_data']
        val_df.append((x_raw.values - X_mean) / X_std)
        val_target.append(seg['time_to_failure'].values[-1])
val_df = np.array(val_df).reshape((-1, 150000,1))
val_target = np.array(val_target).reshape((-1, 1))
# Out:
# HBox(children=(IntProgress(value=0, max=37), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=296), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=363), HTML(value='')))

# %%
import keras
from keras.models import Model
from keras.layers import *
from keras.optimizers import Adam,SGD
from keras.backend import clear_session
import tensorflow.keras.backend as K
import tensorflow as tf

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim
# Out:
# Using TensorFlow backend.

# %%
clear_session()
inp = Input(shape=(150000,1))

# First_LSTM_Cell = Bidirectional(CuDNNLSTM(32, return_sequences=True))
# First_Attention = Attention(400)
# x = []
# for i in range(375):
#     temp = First_LSTM_Cell(Lambda(lambda x: keras.backend.slice(x, (0,i*400,0), (-1,400,-1)))(inp))
#     x.append(First_Attention(temp))
# x = Concatenate()(x)
# x = Reshape((375,128))(x)

x = inp
dilation_rates = [2**i for i in range(10)] 
for dilation_rate in dilation_rates:
    tanh_out = Conv1D(filters=4,
            kernel_size=15, 
            padding='same',
            activation = 'tanh',
            dilation_rate=dilation_rate)(x)
    sigm_out = Conv1D(filters=4,
            kernel_size=15, 
            padding='same',
            activation = 'sigmoid',
            dilation_rate=dilation_rate)(x)
    x = Multiply()([tanh_out,sigm_out])
    x = Conv1D(filters = 4,
                   kernel_size = 1,
                   padding='same',
                   activation = 'relu',)(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.2)(x)

x = Conv1D(filters=16,
        kernel_size=60, 
        strides = 20,
#         activation='relu',
        padding='same')(x)

dilation_rates = [2**i for i in range(5)] 
for dilation_rate in dilation_rates:
    tanh_out = Conv1D(filters=32,
            kernel_size=15, 
            padding='same',
            activation = 'tanh',
            dilation_rate=dilation_rate)(x)
    sigm_out = Conv1D(filters=32,
            kernel_size=15, 
            padding='same',
            activation = 'sigmoid',
            dilation_rate=dilation_rate)(x)
    x = Multiply()([tanh_out,sigm_out])
    x = Conv1D(filters = 32,
                   kernel_size = 1,
                   padding='same',
                   activation = 'relu',)(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.2)(x)
    
x = Conv1D(filters=32,
        kernel_size=60, 
        strides = 20,
#         activation='relu',
        padding='same')(x)

x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
x = Attention(375)(x)
x = Dropout(0.2)(x)
x = Dense(64, activation="relu")(x)
x = Dense(1)(x)

model = Model(inputs = inp, outputs=x)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 150000, 1)    0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150000, 4)    64          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 150000, 4)    64          input_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 150000, 4)    0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150000, 4)    20          multiply_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 150000, 4)    16          conv1d_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 150000, 4)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 150000, 4)    244         spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150000, 4)    244         spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 150000, 4)    0           conv1d_4[0][0]
#                                                                  conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 150000, 4)    20          multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150000, 4)    16          conv1d_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 150000, 4)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150000, 4)    244         spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 150000, 4)    244         spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 150000, 4)    0           conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150000, 4)    20          multiply_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150000, 4)    16          conv1d_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 150000, 4)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 150000, 4)    0           conv1d_10[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150000, 4)    20          multiply_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 150000, 4)    16          conv1d_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 150000, 4)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 150000, 4)    0           conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150000, 4)    20          multiply_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 150000, 4)    16          conv1d_15[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 150000, 4)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 150000, 4)    0           conv1d_16[0][0]
#                                                                  conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150000, 4)    20          multiply_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150000, 4)    16          conv1d_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 150000, 4)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 150000, 4)    0           conv1d_19[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150000, 4)    20          multiply_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150000, 4)    16          conv1d_21[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 150000, 4)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 150000, 4)    0           conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150000, 4)    20          multiply_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 150000, 4)    16          conv1d_24[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_8 (SpatialDro (None, 150000, 4)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 150000, 4)    0           conv1d_25[0][0]
#                                                                  conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150000, 4)    20          multiply_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 150000, 4)    16          conv1d_27[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_9 (SpatialDro (None, 150000, 4)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150000, 4)    244         spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 150000, 4)    0           conv1d_28[0][0]
#                                                                  conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150000, 4)    20          multiply_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150000, 4)    16          conv1d_30[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_10 (SpatialDr (None, 150000, 4)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 7500, 16)     3856        spatial_dropout1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 7500, 32)     7712        conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 7500, 32)     7712        conv1d_31[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 7500, 32)     0           conv1d_32[0][0]
#                                                                  conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 7500, 32)     1056        multiply_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7500, 32)     128         conv1d_34[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_11 (SpatialDr (None, 7500, 32)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_11[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 7500, 32)     0           conv1d_35[0][0]
#                                                                  conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 7500, 32)     1056        multiply_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7500, 32)     128         conv1d_37[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_12 (SpatialDr (None, 7500, 32)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_12[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 7500, 32)     0           conv1d_38[0][0]
#                                                                  conv1d_39[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 7500, 32)     1056        multiply_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7500, 32)     128         conv1d_40[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_13 (SpatialDr (None, 7500, 32)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 7500, 32)     0           conv1d_41[0][0]
#                                                                  conv1d_42[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 7500, 32)     1056        multiply_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7500, 32)     128         conv1d_43[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_14 (SpatialDr (None, 7500, 32)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 7500, 32)     15392       spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 7500, 32)     0           conv1d_44[0][0]
#                                                                  conv1d_45[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 7500, 32)     1056        multiply_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7500, 32)     128         conv1d_46[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_15 (SpatialDr (None, 7500, 32)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 375, 32)      61472       spatial_dropout1d_15[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 375, 128)     50176       conv1d_47[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 128)          503         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            65          dense_1[0][0]
# ==================================================================================================
# Total params: 273,688
# Trainable params: 273,288
# Non-trainable params: 400
# __________________________________________________________________________________________________

# %%
def generator():
    batch_size = 16
    while True:
        X = []
        Y = []
        for i in range(batch_size):
            while True:
                land = 3 + np.random.randint(len(df_all)-3)
                point = np.random.randint(int((len(df_all[land])-150000)/100))
                seg = df_all[land].iloc[point*100:point*100+150000]
                if seg['time_to_failure'].values[-1] < seg['time_to_failure'].values[0]:
                    break
            x_raw = seg['acoustic_data']
            x = (x_raw.values - X_mean) / X_std
            y = seg['time_to_failure'].values[-1]
#             y = (y - y_mean) / y_std
            X.append(x)
            Y.append(y)
        yield np.array(X).reshape((-1, 150000,1)),np.array(Y).reshape((-1, 1))

# %%
from keras.callbacks import LearningRateScheduler,ModelCheckpoint,EarlyStopping
def step_decay(epoch):
    x = 0.0001
    if epoch >= 200: x = 0.00001
    if epoch >= 500: x = 0.000001
    return x
lr_decay = LearningRateScheduler(step_decay)

# %%
model.compile(Adam(lr=0.0001), loss='mae')
history = model.fit_generator(generator(),
                             steps_per_epoch=400,
                             epochs=1000,
                             verbose=1,
                             callbacks = [ModelCheckpoint("model.hdf5", save_best_only=True,save_weights_only = True, period=1), lr_decay, EarlyStopping(patience = 50)],
                             validation_data = (val_df,val_target)
                             )
# Out:
# Epoch 1/1000
# 400/400 [==============================] - 184s 459ms/step - loss: 3.2711 - val_loss: 3.4181
# Epoch 2/1000
# 400/400 [==============================] - 171s 426ms/step - loss: 2.9466 - val_loss: 3.4547
# Epoch 3/1000
# 400/400 [==============================] - 170s 426ms/step - loss: 2.9195 - val_loss: 3.4175
# Epoch 4/1000
# 400/400 [==============================] - 170s 426ms/step - loss: 2.9315 - val_loss: 3.4492
# Epoch 5/1000
# 400/400 [==============================] - 170s 426ms/step - loss: 2.9479 - val_loss: 3.4277
# Epoch 6/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9387 - val_loss: 3.4338
# Epoch 7/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9385 - val_loss: 3.4213
# Epoch 8/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.8971 - val_loss: 3.4351
# Epoch 9/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9214 - val_loss: 3.4220
# Epoch 10/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9593 - val_loss: 3.4850
# Epoch 11/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9361 - val_loss: 3.4500
# Epoch 12/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9414 - val_loss: 3.4589
# Epoch 13/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9439 - val_loss: 3.3830
# Epoch 14/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9417 - val_loss: 3.3877
# Epoch 15/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.9816 - val_loss: 3.3489
# Epoch 16/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.8772 - val_loss: 3.2808
# Epoch 17/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.7128 - val_loss: 3.0384
# Epoch 18/1000
# 400/400 [==============================] - 170s 424ms/step - loss: 2.5304 - val_loss: 2.6827
# Epoch 19/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.3767 - val_loss: 2.4771
# Epoch 20/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.2534 - val_loss: 2.3343
# Epoch 21/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.1513 - val_loss: 2.2862
# Epoch 22/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.1117 - val_loss: 2.3074
# Epoch 23/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.1153 - val_loss: 2.2970
# Epoch 24/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.1072 - val_loss: 2.3529
# Epoch 25/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.0673 - val_loss: 2.2672
# Epoch 26/1000
# 400/400 [==============================] - 170s 424ms/step - loss: 2.0277 - val_loss: 2.1399
# Epoch 27/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.0015 - val_loss: 2.2044
# Epoch 28/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.0491 - val_loss: 2.2602
# Epoch 29/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.0112 - val_loss: 2.3037
# Epoch 30/1000
# 400/400 [==============================] - 170s 424ms/step - loss: 1.9783 - val_loss: 2.2842
# Epoch 31/1000
# 400/400 [==============================] - 170s 426ms/step - loss: 2.0452 - val_loss: 2.2536
# Epoch 32/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.0298 - val_loss: 2.2823
# Epoch 33/1000
# 400/400 [==============================] - 170s 425ms/step - loss: 2.0500 - val_loss: 2.2565
# Epoch 34/1000
# 400/400 [==============================] - 170s 424ms/step - loss: 1.9998 - val_loss: 2.2413
# Epoch 35/1000
# 400/400 [==============================] - 170s 424ms/step - loss: 1.9807 - val_loss: 2.2239
# Epoch 36/1000
# 400/400 [==============================] - 170s 424ms/step - loss: 1.9957 - val_loss: 2.1306
# Epoch 37/1000
# 400/400 [==============================] - 170s 424ms/step - loss: 1.9824 - val_loss: 2.1904
# Epoch 38/1000
# 400/400 [==============================] - 170s 426ms/step - loss: 1.9475 - val_loss: 2.2252
# Epoch 39/1000
# 293/400 [====================>.........] - ETA: 43s - loss: 1.9682

# %%
model.load_weights("model.hdf5")

# %%
submission = pd.read_csv('../input/sample_submission.csv', index_col='seg_id')
pred_test = []
for i, seg_id in enumerate(tqdm_notebook(submission.index)):
    seg = pd.read_csv('../input/test/' + seg_id + '.csv')
    x_raw = seg['acoustic_data']
    pred_test.append(model.predict(((x_raw.values - X_mean) / X_std).reshape((-1, 150000,1))).reshape((1)))
submission['time_to_failure'] = np.array(pred_test)
print(submission.head())
submission.to_csv('submission.csv')
