# %%
import numpy as np
import pandas as pd

import glob
from scipy.io import loadmat

# %%
files = glob.glob('../input/*/*.mat');

# %%
data = loadmat(files[0])['dataStruct']['data'].item(0).astype(np.float32)

# %%
data

# %%
for file in files:
    if loadmat(file)['dataStruct']['iEEGsamplingRate'][0][0][0][0] != 400:
        print(file)

# %%
len(files)
