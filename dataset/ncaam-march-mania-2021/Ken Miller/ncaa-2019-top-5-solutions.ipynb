# %% [markdown]
# This notebooks links to top solutions for the past NCAA competions

# %% [markdown]
# 2019 Top 5
#
# https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/89150
#
# https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/88805
#
# https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/90254
#
# https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/89645
#
# https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/89942
