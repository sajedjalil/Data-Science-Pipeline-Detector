# %%
#ライブラリのインポート欄
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest
from sklearn import model_selection
from sklearn.model_selection import GridSearchCV
import warnings

from sklearn.preprocessing import StandardScaler

warnings.filterwarnings('ignore')

# %%
# CSVを読み込む

train = pd.read_csv('../input/tabular-playground-series-jun-2021/train.csv')
test = pd.read_csv('../input/tabular-playground-series-jun-2021/test.csv')

# 提出用に（分ける）
#PassengerId = test["PassengerId"]
# データの統合（分けて適用するのが面倒なため）

dataset = pd.concat([train, test], ignore_index = True)

# %%
#print (train.describe)
#print (train.corr())

#pd.set_option('display.max_rows', 80)
#train.isnull().sum()#欠損値がないことを確認

#ここからデータの処理をしていく
train2 = pd.get_dummies(train['target'])
training = pd.get_dummies(train, columns=["target"], drop_first=True)
#train2 = pd.get_dummies(train, columns=["target"])
#train3 = train.assign(train2[:][0])
#train3 = pd.concat([train, train2], ignore_index = True)
#print(train.corr())
#print(train2['Class_1'])
#sns.heatmap(train2.corr(), vmax=1, vmin=-1, center=0)
#plt.savefig('seaborn_heatmap_corr_example3.png')#相関係数のヒートマップ

# %%
# from sklearn.linear_model import LogisticRegression
#cols = ["Age","Fare","Alone","Pclass_2","Pclass_2","Embarked_Q","Embarked_S","Sex_male"] 
X = training
y = train2['Class_1']
# Build a logreg and compute the feature importances
model = LogisticRegression()
# create the RFE model and select 8 attributes
model.fit(X,y)



from sklearn.metrics import accuracy_score
train_predicted = model.predict(X)
print(accuracy_score(train_predicted, y))

# %%
conda install -c conda-forge lightgbm
