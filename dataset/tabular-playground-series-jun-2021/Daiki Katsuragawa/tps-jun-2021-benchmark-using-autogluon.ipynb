# %%
# !pip install autogluon.tabular[all]

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

train = TabularDataset('../input/tabular-playground-series-jun-2021/train.csv')
test = TabularDataset('../input/tabular-playground-series-jun-2021/test.csv')

label = 'target'
time_limit = 60
predictor = TabularPredictor(label=label,learner_kwargs={'ignored_columns': ['id']}).fit(train_data=train,time_limit=time_limit)

# %%
submission = pd.read_csv('../input/tabular-playground-series-jun-2021/sample_submission.csv')
predictions = predictor.predict_proba(test)
columns = ['Class_1', 'Class_2', 'Class_3', 'Class_4', 'Class_5', 'Class_6', 'Class_7', 'Class_8', 'Class_9']
for column in columns:
    submission[column] = predictions[column]
submission.to_csv('submission.csv', index=False)
submission.head()
