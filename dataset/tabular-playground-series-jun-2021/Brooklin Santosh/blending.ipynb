# %% [markdown]
# Hello Everyone,
# I am going to blend the previous top scored model from my notebooks. Link to those notebooks are below,
#
# * https://www.kaggle.com/brookie210/tps-june2021-catboost-baselinemodel
# * https://www.kaggle.com/brookie210/tps-june2021-lightbgm-optuna
# * https://www.kaggle.com/brookie210/tps-june2021-cat-lgbm-blended
#
# This is very simple notebook, I am just going to add and take average of my previous predictions.

# %% [markdown]
# ## Importing the required libraries

# %%
import numpy as np 
import pandas as pd 

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ## Reading the data and predictions from previous notebooks

# %%
blended = pd.read_csv("../input/tps-june2021-cat-lgbm-blended/sub.csv")
cat = pd.read_csv("../input/tps-june2021-catboost-baselinemodel/cat_pred.csv")
lgbm = pd.read_csv("../input/lgbm-optuna/tuned_lgbm_sub (1).csv")
ss = pd.read_csv("../input/tabular-playground-series-jun-2021/sample_submission.csv")

# %% [markdown]
# ##

# %% [markdown]
# ## Blending

# %%
ss["Class_1"] = (blended["Class_1"] + cat["Class_1"] + lgbm ["Class_1"]) / 3
ss["Class_2"] = (blended["Class_2"] + cat["Class_2"] + lgbm ["Class_2"]) / 3
ss["Class_3"] = (blended["Class_3"] + cat["Class_3"] + lgbm ["Class_3"]) / 3
ss["Class_4"] = (blended["Class_4"] + cat["Class_4"] + lgbm ["Class_4"]) / 3
ss["Class_5"] = (blended["Class_5"] + cat["Class_5"] + lgbm ["Class_5"]) / 3
ss["Class_6"] = (blended["Class_6"] + cat["Class_6"] + lgbm ["Class_6"]) / 3
ss["Class_7"] = (blended["Class_7"] + cat["Class_7"] + lgbm ["Class_7"]) / 3
ss["Class_8"] = (blended["Class_8"] + cat["Class_8"] + lgbm ["Class_8"]) / 3
ss["Class_9"] = (blended["Class_9"] + cat["Class_9"] + lgbm ["Class_9"]) / 3
ss.to_csv("/kaggle/working/sub.csv", index=False)

# %% [markdown]
# If you like this notebook, kindly upvote it. Also check my mentioned other notebooks.

# %% [markdown]
# ### Thank you!
