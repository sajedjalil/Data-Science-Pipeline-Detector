# %%
# Below is a way to install VSAC and MGSAC++ on Kaggle environment.
# This approach can also be used to install other C++/Python wrapper and its dependencies.

# %%
# VSAC - https://github.com/ivashmak/vsac
# Below conda installation takes a while/minutes, the offline version goes in seconds, maybe we can speed up the the online installation in some way, haven’t look at it yet.

# !conda install opencv lapack Glog gflags eigen -y
# !git clone --recurse-submodules --recursive https://github.com/ivashmak/vsac.git
# !pip install ./vsac

import pvsac

# %%
#MAGSAC - https://github.com/danini/magsac

# !apt-get install libgoogle-glog-dev -y
# !git clone --recurse-submodules --recursive https://github.com/danini/magsac.git
# !pip install ./magsac

import pymagsac

# %%
# Example of VSAC offline installation below, just download and e.g tar the packages+dependencies and save the cloned git rep. locally and do the same procedure.
# I don't share them here public, as there are many packages, I haven’t checked if there is a package that can't be shared so better leave it for now.
# But it's pretty the same as online so it's no magic.

# %%
import tarfile
my_tar = tarfile.open('../input/geopacks/geopacks.tar')
my_tar.extractall('/opt/conda/pkgs')
my_tar.close()
# !conda install /opt/conda/pkgs/geopacks/* -y

my_tar = tarfile.open('../input/vsac-tar/vsac.tar')
my_tar.extractall('./')
my_tar.close()

# !pip install ./vsac

import pvsac
