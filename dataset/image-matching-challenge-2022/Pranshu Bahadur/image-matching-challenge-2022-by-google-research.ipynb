# %% [markdown]
# # [Problem Formulation](https://www.kaggle.com/competitions/image-matching-challenge-2022/overview/problem-definition)
# ---

# %% [markdown]
# Let $G_{R, T}(M_{i}) = RM_{i} + T$
#
# Note: $G$ is an Affine Mapping of the form:
#
# $y = Ax + b$
#
# $P_{K, G}(M_{i}) = K \times G(M_{i}; R, T)$
#
#
# Note: $P$ is a linear map of the form:
#
# $y = Ax$
#
# $P = KG(M_{i})$
#
# $P = K(RM_{i} + T)$
#
# Let $\psi$ denote a vector of ones.
#
# $G(M) = RM^{T} + \psi T^{T}$ Ok..so now we get $3\times n$ I think?
#
# $P(M) = KG$
#
# Oh ok, then reshape n

# %% [markdown]
# $P'FP = 0$
#
# 3xn nx3 3xn
#
#
# Aight lets code I guess
