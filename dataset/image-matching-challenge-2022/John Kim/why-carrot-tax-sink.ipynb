# %% [markdown]
# # A big boat

# %% [markdown]
# Rockman, A. "Shipwrecks," Grover, A. Tipping Points, pp. 9-12, 2021.

# %% [markdown]
# Pint 1
#
#   mL 500 (market rate*)
#
# Gallon 1
#
#   L 4.5

# %% [markdown]
# A long long time ago, a famous Egyptian Queen, next to a famous Egyptian with no hair, I mean some hair, used to drink carbon something for her well-being. Limestone and oysters are the sources. She used pearls. Her drink is somewhat related to the first chemical component humanity ever found. Many industries are using it as well. Portland cement is manufactured with carbon something. Runway. Highway. Construction. Potash. You name it. When you say carbon, you look smart and powerful. When you say chlorine, you look stupid. Ooops, the ozone. This dots are rare and unstable. Unlike `abundant` carbon which you can find anywhere, the ozone is 1 in million particles. Yet, it was good enough to protect all living beings from harmful lights. However, one free chlorine particle can do so much damage to the ozone. The melting North and the rising sea level might contribute to dry wet dry wet vibrations of abnormal rise in chlorine into the atmosphere. It is just strange. The whole thing is just strange. If chlorine did actual `permanent` damage, why do we pay tax for the carbon? It gives an unbreathable burden to our key labors. Truckers. Aviation. Carbon temporary. Chlorine is permanent. Do chlorine tax. No carbon. I am sure some smart people can do carbon sink anytime and make a profit, influence, and power. Do you care about us? I see no tears and there is a hole. Thank you very much. You are very helpful.

# %% [markdown]
# Options
#   1. Hyperplane
#   2. 3D Perspective
#   3. 4-way drill & the explosion

# %% [markdown]
# # The curtain match

# %%
import pandas
pandas.read_csv('../input/image-matching-challenge-2022/sample_submission.csv')

# %%
pandas.read_csv('../input/image-matching-challenge-2022/test.csv')

# %% [markdown]
# # The match accelerator
#
# 4-way two points a collider up down left right simulation

# %% [markdown]
# # The image slayer
#
# layer-6
# layer-5
# layer-4
# layer-3
# layer-2
# layer-1
