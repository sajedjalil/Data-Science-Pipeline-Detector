# %% [markdown]
# In this kernel lets explore the data given . There are 7 files given in this competition giving information order history,product details and departments which are relational in nature(can be combined with common fields).

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
orders = pd.read_csv("../input/orders.csv")
products = pd.read_csv("../input/products.csv")
aisles = pd.read_csv("../input/aisles.csv")
departments= pd.read_csv("../input/departments.csv")
train = pd.read_csv("../input/order_products__train.csv")
prior = pd.read_csv("../input/order_products__prior.csv")

# %%
orders.head(5)

# %%
train.head(5)

# %%
prior.head(5)

# %% [markdown]
# We can see the orders  df has information about users(user_id),orders(order_id,order_number) and days since last purchase,hour and on which day of week orders is placed. Train and Prior has full order details which includes product_id and whether is product is reordered or not(1/0 Flag) . In order to understand how train and prior is different lets investigate a single case user_id = 1

# %%
orders[orders.user_id==1]

# %% [markdown]
# User 1 has a total of 11 orders in which we can see 10 were assigned to prior and one to train dfs

# %%
train[train.order_id.isin(orders.order_id[orders.user_id==1])]

# %%
len(prior.order_id[prior.order_id.isin(orders.order_id[orders.user_id==1])].drop_duplicates())

# %% [markdown]
# From the above analysis we can see that prior data frame has all but last order of the user and last order is present in train df.

# %% [markdown]
# **More to Come**
