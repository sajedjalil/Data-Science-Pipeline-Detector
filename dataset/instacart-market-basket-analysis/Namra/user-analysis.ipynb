# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
orders = pd.read_csv("../input/orders.csv")

# %%
orders_train = orders[orders["eval_set"] != 'test']
#orders_test = orders[orders["eval_set"] == 'test']

# %%
grouped_user = orders_train.groupby('user_id')

# %%
#num_order = grouped_user.order_number.max()
#num_order = num_order.value_counts().sort_index()
#num_order.cumsum() / num_order.sum()

# %% [markdown]
# Next stop : try to analyze the users with more than 10 orders on the frequency of their purchases

# %%
num_order = (grouped_user.order_number.max()).reset_index()
num_order = num_order[num_order['order_number'] >= 20]

# %%
freq_user = orders_train[orders_train['user_id'].isin(num_order['user_id'])]

# %%
freq_user.head(10)

# %%
reorder_freq = freq_user['days_since_prior_order'][freq_user['days_since_prior_order'].notnull()]

# %%
reorder_freq.hist(bins=30)
