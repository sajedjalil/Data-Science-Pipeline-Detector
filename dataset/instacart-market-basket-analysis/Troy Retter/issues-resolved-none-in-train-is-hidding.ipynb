# %% [markdown]
# # There is "None"  in Train, but it's hidding

# %% [markdown]
# I thought that the Train dataset did not have 'None', since every entry has purchased items paired with it.
#
# I believe the 'None' are rows where the ONLY items listed are those that had never been purchased before by the user.
