# %%
import itertools
from itertools import combinations, groupby
import collections
import numpy as np
import pandas as pd

# Embeddings
from gensim.models import Word2Vec
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['products.csv', 'departments.csv', 'sample_submission.csv', 'order_products__prior.csv', 'order_products__train.csv', 'aisles.csv', 'orders.csv']

# %%
products = pd.read_csv("../input/products.csv")
departments = pd.read_csv("../input/departments.csv")
aisles = pd.read_csv("../input/aisles.csv")

# %%
prod_names = list(products['product_name'])
product_table = pd.DataFrame(prod_names, columns=['Products'])

# %%
# Make everything lowercase.
product_table['Products_mod'] = product_table['Products'].str.lower()

# Clean special characters.
product_table['Products_mod'] = product_table['Products_mod'].str.replace('\W', ' ')

# Split products into terms: Tokenize.
product_table['Products_mod'] = product_table['Products_mod'].str.split()
product_table.head()
# Out:
#                                             Products                                       Products_mod
# 0                         Chocolate Sandwich Cookies                     [chocolate, sandwich, cookies]
# 1                                   All-Seasons Salt                               [all, seasons, salt]
# 2               Robust Golden Unsweetened Oolong Tea         [robust, golden, unsweetened, oolong, tea]
# 3  Smart Ones Classic Favorites Mini Rigatoni Wit...  [smart, ones, classic, favorites, mini, rigato...
# 4                          Green Chile Anytime Sauce                     [green, chile, anytime, sauce]

# %%
# Add product and aisle information
enriched_prods = pd.merge(products, departments, on="department_id")
enriched_prods = pd.merge(enriched_prods, aisles, on="aisle_id")

# %%
enriched_prods[['product_id', 'product_name', 'department', 'aisle']]
# Out:
#        product_id              ...                                      aisle
# 0               1              ...                              cookies cakes
# 1              78              ...                              cookies cakes
# 2             102              ...                              cookies cakes
# 3             172              ...                              cookies cakes
# 4             285              ...                              cookies cakes
# 5             331              ...                              cookies cakes
# 6             449              ...                              cookies cakes
# 7             559              ...                              cookies cakes
# 8             569              ...                              cookies cakes
# 9             574              ...                              cookies cakes
# 10            576              ...                              cookies cakes
# 11            622              ...                              cookies cakes
# 12            627              ...                              cookies cakes
# 13            635              ...                              cookies cakes
# 14            658              ...                              cookies cakes
# 15            733              ...                              cookies cakes
# 16            796              ...                              cookies cakes
# 17           1058              ...                              cookies cakes
# 18           1129              ...                              cookies cakes
# 19           1209              ...                              cookies cakes
# 20           1256              ...                              cookies cakes
# 21           1419              ...                              cookies cakes
# 22           1473              ...                              cookies cakes
# 23           1547              ...                              cookies cakes
# 24           1608              ...                              cookies cakes
# 25           1610              ...                              cookies cakes
# 26           1624              ...                              cookies cakes
# 27           1648              ...                              cookies cakes
# 28           1694              ...                              cookies cakes
# 29           1861              ...                              cookies cakes
# ...           ...              ...                                        ...
# 49658       19066              ...               bulk grains rice dried goods
# 49659       22260              ...               bulk grains rice dried goods
# 49660       23038              ...               bulk grains rice dried goods
# 49661       25859              ...               bulk grains rice dried goods
# 49662       27414              ...               bulk grains rice dried goods
# 49663       28067              ...               bulk grains rice dried goods
# 49664       32232              ...               bulk grains rice dried goods
# 49665       38613              ...               bulk grains rice dried goods
# 49666       39653              ...               bulk grains rice dried goods
# 49667       40397              ...               bulk grains rice dried goods
# 49668       42091              ...               bulk grains rice dried goods
# 49669       42134              ...               bulk grains rice dried goods
# 49670       43210              ...               bulk grains rice dried goods
# 49671       43578              ...               bulk grains rice dried goods
# 49672       43769              ...               bulk grains rice dried goods
# 49673       45682              ...               bulk grains rice dried goods
# 49674       46889              ...               bulk grains rice dried goods
# 49675       47489              ...               bulk grains rice dried goods
# 49676        1000              ...               bulk dried fruits vegetables
# 49677        5161              ...               bulk dried fruits vegetables
# 49678       10224              ...               bulk dried fruits vegetables
# 49679       10540              ...               bulk dried fruits vegetables
# 49680       14611              ...               bulk dried fruits vegetables
# 49681       14665              ...               bulk dried fruits vegetables
# 49682       19628              ...               bulk dried fruits vegetables
# 49683       22827              ...               bulk dried fruits vegetables
# 49684       28655              ...               bulk dried fruits vegetables
# 49685       30365              ...               bulk dried fruits vegetables
# 49686       38007              ...               bulk dried fruits vegetables
# 49687       48778              ...               bulk dried fruits vegetables
#
# [49688 rows x 4 columns]

# %%
# Append the tokenized column
product_table = pd.merge(enriched_prods[['product_name', 'department', 'aisle', 'department_id','aisle_id']], product_table, left_on="product_name", right_on="Products")
product_table.head()
# Out:
#                                      product_name                        ...                                                               Products_mod
# 0                      Chocolate Sandwich Cookies                        ...                                             [chocolate, sandwich, cookies]
# 1               Nutter Butter Cookie Bites Go-Pak                        ...                                   [nutter, butter, cookie, bites, go, pak]
# 2                           Danish Butter Cookies                        ...                                                  [danish, butter, cookies]
# 3  Gluten Free All Natural Chocolate Chip Cookies                        ...                          [gluten, free, all, natural, chocolate, chip, ...
# 4                    Mini Nilla Wafers Munch Pack                        ...                                         [mini, nilla, wafers, munch, pack]
#
# [5 rows x 7 columns]

# %%
w2vec_model = Word2Vec(list(product_table['Products_mod']), size=20, window=5, min_count=1, workers=4)

# %%
# Create  dictionaries to obtain product vectors

prod_word = dict()
for w in w2vec_model.wv.vocab:
    prod_word[w] = w2vec_model[w]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """

# %%
display(list(prod_word.items())[:2])
# Out:
# [('chocolate',
#   array([-0.7037704 ,  2.9269016 ,  1.4313685 ,  1.3194381 , -0.9869902 ,
#           2.4666147 , -0.29313523, -3.6432633 ,  0.04991385,  0.1246125 ,
#           2.8057313 ,  1.1690453 ,  0.21009387, -2.641713  ,  0.20084678,
#          -0.11150149, -0.17785619, -1.7056086 , -1.7563633 ,  1.5764931 ],
#         dtype=float32)),
#  ('sandwich',
#   array([-0.10577309,  0.43264827,  0.20517507,  0.5205766 , -1.27768   ,
#           1.033573  ,  0.47063234, -1.1926118 , -0.8809756 ,  0.0500845 ,
#           0.5143323 ,  0.44254893, -1.275482  , -1.8803289 ,  0.8199226 ,
#           0.21343723,  0.6112116 , -0.5708859 , -0.9103039 ,  1.4354948 ],
#         dtype=float32))]

# %%
# VECTOR CALCULATION FOR PRODUCTS
# Cycle through each word in the product name to generate the vector.
prods_w2v = dict()
for index, row in product_table.iterrows():
    word_vector = list()
    #print(row['Products_mod'])
    for word in row['Products_mod']:
        word_vector.append(prod_word[word])
    
    prods_w2v[row['Products']] = np.average(word_vector, axis=0)

# %%
display(list(prods_w2v.items())[:2])
# Out:
# [('Chocolate Sandwich Cookies',
#   array([-0.21136063,  1.8709946 ,  0.7193214 ,  1.0028884 , -1.219966  ,
#           1.7773724 ,  0.31743476, -2.5429494 , -0.32189876,  0.37106046,
#           1.7924148 ,  0.66265345, -0.70871663, -2.2408504 ,  0.85238934,
#           0.08909017, -0.11694751, -1.1796118 , -1.2502959 ,  1.4848709 ],
#         dtype=float32)),
#  ('Nutter Butter Cookie Bites Go-Pak',
#   array([-0.4859861 ,  1.0834678 ,  0.3179979 ,  0.44258466, -0.6815359 ,
#           1.0952351 ,  0.1932453 , -1.3168287 , -0.74037933,  0.23711114,
#           0.901165  ,  0.03421742, -0.34427187, -1.0652884 ,  0.56833726,
#           0.13860272,  0.05961088, -0.09044382, -0.8173497 ,  1.0002911 ],
#         dtype=float32))]

# %%
product_table['vectors'] = prods_w2v.values()

# %%
product_table.head()
# Out:
#                                      product_name                        ...                                                                    vectors
# 0                      Chocolate Sandwich Cookies                        ...                          (-0.21136063, 1.8709946, 0.7193214, 1.0028884,...
# 1               Nutter Butter Cookie Bites Go-Pak                        ...                          (-0.4859861, 1.0834678, 0.3179979, 0.44258466,...
# 2                           Danish Butter Cookies                        ...                          (-0.80961174, 1.6220757, 0.96441585, 0.689753,...
# 3  Gluten Free All Natural Chocolate Chip Cookies                        ...                          (-0.3179844, 0.8896972, 0.6882824, 1.1404625, ...
# 4                    Mini Nilla Wafers Munch Pack                        ...                          (-0.105717584, 0.508803, -0.07997906, 0.141530...
#
# [5 rows x 8 columns]
