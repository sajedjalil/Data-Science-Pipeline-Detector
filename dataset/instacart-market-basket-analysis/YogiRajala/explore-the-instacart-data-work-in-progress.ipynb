# %% [markdown]
# Lets take a look at the data provided by Instacart competition

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import numpy.random as rnd
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import matplotlib.pyplot as plt


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
# let's load the data
aisles = pd.read_csv("../input/aisles.csv")
departments = pd.read_csv("../input/aisles.csv")
products = pd.read_csv("../input/products.csv")
orders = pd.read_csv("../input/orders.csv")
or_prod_prior = pd.read_csv("../input/order_products__prior.csv")
or_prod_train = pd.read_csv("../input/order_products__train.csv")

# Let's see how the data looks 
aisles.head()

# %%
departments.head()

# %%
products.head()

# %%
orders.head()

# %%
or_prod_prior.head()

# %%
or_prod_train.head()

# %%
# Lets see counts of different types of eval sets
orders["eval_set"].value_counts()

# %%
# how many different customers are there?
len(np.unique(orders.user_id))

# %%
# let's find how many unique customers are there
len(np.unique(orders["user_id"]))
