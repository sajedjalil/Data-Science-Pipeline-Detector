# %% [markdown]
# <div align='center'><font size="5" color="#00000"><center><h1 style="text-transform: uppercase"> AutoViz </font></div>
# <hr>
# <div align='left'><font size="3" color="#000000">Data Visualisation is one of the powerful tool in Data science. It will be useful for data cleaning, exploring data structure, detecting outliers and unusual groups,finding the pattern, identifying trends, clusters and many more things. There are many packages available in python to visualize the data such as matplotlib, seaborn etc.These tools are helpful in regression,classification and clustering analysis.  </font></div>
# <hr>
# <img style="float: center;"  src="https://autoviz.io/static/core/img/data_on_pad.png" width="800px">
# <hr>
# <div align='left'><font size="3" color="#000000"> In this kernel I will show you how python library AutoViz which can automate the whole process of Data Visualization in just a single line of code. It is generate suitable plots automatically.</font></div>
# <hr>

# %%
# %%capture
# !pip install autoviz
import pandas as pd 
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %%
df = AV.AutoViz('../input/factors-affecting-campus-placement/Placement_Data_Full_Class.csv')

# %%
df = AV.AutoViz('../input/titanic/train.csv', depVar='Survived')

# %% [markdown]
# <div align='left'><font size="4" color="#000000"><h1 style="text-transform: uppercase"><strong>References</strong> </font></div>
# <hr>
#
# <div align='left'><font size="3"><a href="https://github.com/DanRothDataScience/autoviz_test/blob/master/AutoViz_test.ipynb" target="_blank">1. AutoViz</a></div>
# <hr>
#
# <div align='left'><font size="3" color="#000000"> Happy Learning :)</font></div>
