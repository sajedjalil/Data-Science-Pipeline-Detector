# %% [markdown]
# # 1.Import libraries

# %%
# Data wrangLing
import pandas as pd
import numpy as np

# Data Visualistion
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2.Import and read Data

# %% [markdown]
# **Then we are going to store data frames in different python variables**

# %%
train = pd.read_csv('../input/titanic/train.csv')
test = pd.read_csv('../input/titanic/test.csv')
gender = pd.read_csv('../input/titanic/gender_submission.csv')

# %% [markdown]
# **let's have a look at the datasets**

# %%
train.head()

# %%
test.head()

# %%
gender.head()

# %% [markdown]
# # 3.Data types, missing Data and summary

# %%
train.info()
print('_'*40)
test.info()

# %%
# Missing data in traning set
train.isnull().sum().sort_values(ascending = False)

# %%
 # Missing data in test set
test.isnull().sum().sort_values(ascending = False)

# %%
# summary statistics for training set
train.describe()

# %%
# summary statistics for test set
test.describe()

# %%
#value counts of the sex column
train['Sex'].value_counts()

# %%
# mean of survival by sex
train[['Sex','Survived']].groupby('Sex', as_index = False).mean().sort_values(by='Survived',ascending = False)

# %%
sns.barplot(x = 'Sex', y = 'Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by gender')
