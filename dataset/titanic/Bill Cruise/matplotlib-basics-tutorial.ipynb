# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <div
#      style="color: gray;
#             border: 2px solid #d8d8d8;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             border-spacing: 4px;">
#     <b style="margin-left: 30px; font-size: 24px;">Table of Contents</b>
#     <ol style="font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#                color:gray;
#                font-size:18px;
#                font-weight:bold;
#                margin-left: 40px;">
#         <li><a style="color:gray;"href="#introdution">Introduction</a></li>
#         <li><a style="color:gray;"href="#importing-matplotlib">Importing Matplotlib</a></li>
#         <li><a style="color:gray;" href="#basic-plots">Basic plots with Python lists and NumPy arrays</a></li>
#         <li>
#             <a style="color:gray;" href="#plot-fundamentals">Plot Fundamentals</a>
#             <ul>
#                 <li><a style="color:gray;"href="#lines">Lines</a></li>
#                 <li><a style="color:gray;"href="#multiple-plots">Multiple plots</a></li>
#                 <li><a style="color:gray;"href="#markers">Markers</a></li>
#                 <li><a style="color:gray;"href="#plotting-functions">Plotting functions</a></li>
#                 <li><a style="color:gray;"href="#axis-labels">Axis Labels</a></li>
#                 <li><a style="color:gray;"href="#adding-titles">Adding a Title</a></li>
#                 <li><a style="color:gray;"href="#displaying-legends">Displaying a Legend</a></li>
#                 <li><a style="color:gray;"href="#displaying-grid-lines">Adding Grid Lines</a></li>
#                 <li><a style="color:gray;"href="#figure-size">Figure size</a></li>
#             </ul>
#         </li>
#         <li>
#             <a style="color:gray;" href="#plot-types">Plot Types</a>
#             <ul>
#                 <li><a style="color:gray;"href="#bar-plots">Bar plots</a></li>
#                 <li><a style="color:gray;"href="#stacked-bar-plots">Stacked bar plots</a></li>
#                 <li><a style="color:gray;"href="#histograms">Histograms</a></li>
#                 <li><a style="color:gray;"href="#pie-charts">Pie charts</a></li>
#                 <li><a style="color:gray;"href="#scatter-plots">Scatter plots</a></li>
#                 <li><a style="color:gray;"href="#box-plots">Box plots</a></li>
#                 <li><a style="color:gray;"href="#3d-plots">3D plots</a></li>
#             </ul>
#         </li>
#         <li><a style="color:gray;"href="#subplots">Subplots</a></li>
#         <li><a style="color:gray;"href="#text-and-annotations">Text and Annotations</a></li>
#         <li><a style="color:gray;"href="#faq">Frequently Asked Questions</a></li>
# </ol>
# </div>

# %% [markdown]
# <div id="introdution"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Introduction</b>
# </div>
#
# Matplotlib is a comprehensive library for creating data visualizations in Python. This notebook is a compilation of examples showing how to make the most common types of charts in Matplotlib. See [Matplotlib: Visualization with Python](https://matplotlib.org/) for many more examples, tutorials, and the official documentation.

# %% [markdown]
# <div id="importing-matplotlib"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Importing Matplotlib</b>
# </div>

# %%
import matplotlib
import matplotlib.pyplot as plt
print("Matplotlib version:", matplotlib.__version__)

# %% [markdown]
# <div id="basic-plots"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Basic plots with Python lists and NumPy arrays</b>
# </div>
#
# The most basic type of plot you can make is a line chart with data defined as either Python lists or NumPy arrays. As we'll see, the parameters can be any array-like or scalar value.

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 2, 3, 4, 5, 6, 7]

plt.plot(x, y);

# %% [markdown]
# This gives us a very plain line chart with x and y axis scales but no labels. The size and color of the plot line use Matplotlib's default values. Change the color by setting a `color` attribute.

# %%
x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([1, 1, 2, 3, 5, 8, 13])

plt.plot(x, y, color='red');

# %% [markdown]
# <div id="plot-fundamentals"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Plot Fundamentals</b>
# </div>
#
#
# <div id="lines"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Lines</b>
# </div>
#
# Matplotlib makes it very easy to display plots with different line styles.

# %%
y = [2, 5, 9, 13, 18]

plt.plot(y, linestyle='dotted');

# %% [markdown]
# Note that we only provided y values and Matplotlib filled in a set of default values for the x-axis.
#
# There are many different line styles available. For example, you can display a combination of dashes and dots by specifying the line style of `'-.'`. We can also change the line width.

# %%
plt.plot(y, linestyle='-.', linewidth=5);

# %% [markdown]
# You can view `matplotlib.lines.lineStyles` to see what line styles are available.

# %%
matplotlib.lines.lineStyles

# %% [markdown]
# <div id="multiple-plots"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Multiple plots</b>
# </div>
#
# You can display multiple lines on the same plot by calling the `plot` function multiple times.

# %%
y1 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]

plt.plot(y1)
plt.plot(y2);

# %% [markdown]
# You can also pass multiple sets of x and y data points to the `plot` function at once.

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 2, 3, 4, 5]
x2 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]
x3 = [1, 2, 3, 4, 5]
y3 = [2, 4, 6, 8, 10]

plt.plot(x1, y1, x2, y2, x3, y3);

# %% [markdown]
# <div id="markers"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Markers</b>
# </div>
#
# You can also control the markers used to plot each data point.

# %%
y = [2, 5, 9, 13, 18]

plt.plot(y, marker='o');  # That's the lowercase letter 'o'

# %% [markdown]
# There are a lot of different markers to choose from.

# %%
y1 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]

plt.plot(y1, marker='s')  # square marker
plt.plot(y2, marker='D'); # diamond marker

# %% [markdown]
# You can also change the marker size.

# %%
y = [2, 5, 9, 13, 18]

plt.plot(y, marker='o', markersize=12);

# %% [markdown]
# We can also change the marker edge color and face color.

# %%
plt.plot(y, marker='o', markersize=12, markeredgecolor='red', markerfacecolor='yellow');

# %% [markdown]
# You can see all of the different marker styles using `matplotlib.markers.MarkerStyle.markers`, or view all the symbols available at [matplotlib.markers](https://matplotlib.org/stable/api/markers_api.html).

# %% [markdown]
# <div id="plotting-functions"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Plotting functions</b>
# </div>
#
# Since Matplotlib takes any array-like or scalar value as its data parameters, we can use it to plot continuous functions (if we just give it enough data points to plot).

# %%
x = np.linspace(start=-np.pi, stop=np.pi, num=256)
y = np.sin(2*x)

plt.plot(x, y);

# %% [markdown]
# We can also fill colors between two lines on the same plot. In the plot below, notice that the second set of y values is a scalar. This tells Matplotlib to fill the area between the first function and the 0 y-coordinate.

# %%
plt.plot(x, y)
plt.fill_between(x, y1=y, y2=0, alpha=0.1);

# %% [markdown]
# <div id="axis-labels"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Axis Labels</b>
# </div>
#
# We can add axis labels to a chart using the `xlabel` and `ylabel` functions. Let's change our data to plot month abbreviations on the x-axis and some made up sales figures on the y-axis.

# %%
x = ['Jan', 'Feb', 'March', 'Apr', 'May']
y1 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]
y3 = [2, 4, 6, 8, 10]

plt.plot(x, y1, x, y2, x, y3)
plt.xlabel('Month')
plt.ylabel('Sales');

# %% [markdown]
# <div id="adding-titles"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Adding a Title</b>
# </div>
#
# There's also a function to add a title to the whole chart.

# %%
x = ['Jan', 'Feb', 'March', 'Apr', 'May']
y1 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]
y3 = [2, 4, 6, 8, 10]

plt.plot(x, y1, x, y2, x, y3)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales');

# %% [markdown]
# <div id="displaying-legends"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Displaying a Legend</b>
# </div>
#
# Since we have multiple lines on one chart, we should also add a legend. The `legend` function takes a list of labels, and we can also provide a location to control where the legend appears on the chart.

# %%
x = ['Jan', 'Feb', 'March', 'Apr', 'May']
y1 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]
y3 = [2, 4, 6, 8, 10]

plt.plot(x, y1, x, y2, x, y3)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.legend(labels=['Alice', 'Bob', 'Carol'], loc='upper left');

# %% [markdown]
# <div id="displaying-grid-lines"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Adding Grid Lines</b>
# </div>
#
# If you look at the plot above, it can be difficult to estimae the values of the data points on each plot line. Let's add markers and grid lines to make this easier. For this first example, I'll just call `grid(True)` to display grid lines with the default settings.

# %%
x = ['Jan', 'Feb', 'March', 'Apr', 'May']
y1 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]
y3 = [2, 4, 6, 8, 10]

plt.plot(x, y1, x, y2, x, y3, marker='o')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.legend(labels=['Alice', 'Bob', 'Carol'], loc='upper left')
plt.grid(True);

# %% [markdown]
# Refer to the documentation at [`matplotlib.pyplot.grid`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html) to see all of the optional parameters you can pass to control the style of the grid lines. Just to get an idea of what's possible, let's change the color and line thickness, but also the alpha to make the gridlines more transparent.

# %%
x = ['Jan', 'Feb', 'March', 'Apr', 'May']
y1 = [1, 2, 3, 4, 5]
y2 = [2, 5, 9, 13, 18]
y3 = [2, 4, 6, 8, 10]

plt.plot(x, y1, x, y2, x, y3, marker='o')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.legend(labels=['Alice', 'Bob', 'Carol'], loc='upper left')
plt.grid(color='blue', alpha=0.1, linewidth=3);

# %% [markdown]
# <div id="figure-size"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Figure size</b>
# </div>
#
# Up until now all of our charts have been the same default size, but another good way to make your chart more readable is to simply make it bigger. We do that in Matplotlib using the `pyplot.figure` function.

# %%
fig = plt.figure(figsize=(12, 6))

plt.plot(x, y1, x, y2, x, y3, marker='o')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.legend(labels=['Alice', 'Bob', 'Carol'], loc='upper left')
plt.grid(True);

# %% [markdown]
# We'll come back to this again later when we talk about plotting multiple charts in one figure.

# %% [markdown]
# <div id="plot-types"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Plot Types</b>
# </div>
#
# Our basic plots are looking a lot better than when we started, but the made-up data is getting boring. For the next section, let's import some real-world data and look at some of the different plot types you can make using Matplotlib. We'll use the training data from the [Titanic - Machine Learning from Disaster](https://www.kaggle.com/c/titanic/overview) competition.

# %%
titanic_df = pd.read_csv('/kaggle/input/titanic/train.csv')
titanic_df.head()

# %% [markdown]
# <div id="bar-plots"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Bar plots</b>
# </div>
#
# The data for a bar plot is different from the data we've seen up until now. For line charts, we were using numeric data on both the x and y axes. For a bar plot, we need our x-axis data to be a set of labels for the bars, and the y-axis data should be a numeric value that corresponds to the height of each bar.
#
# Let's create data for our first bar plot using the `Embarked` column from the Titanic data set.

# %%
embarked = titanic_df['Embarked'].value_counts()
print(embarked.index) # these will be our bar labels
print(embarked.values) # these will be the heights of the bars

# %% [markdown]
# We create a bar plot using the [`matplotlib.pyplot.bar`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html) function.

# %%
plt.bar(x=embarked.index, height=embarked.values);

# %% [markdown]
# We can also specify a list of colors to apply to each bar.

# %%
plt.bar(x=embarked.index, height=embarked.values, color=['blue', 'green', 'red']);

# %% [markdown]
# We can also create a horizontal bar plot using the `barh` function, but we have to specify the labels on the y-axis the values as bar widths instead of heights.

# %%
plt.barh(y=embarked.index, width=embarked.values, color=['blue', 'green', 'red']);

# %% [markdown]
# <div id="stacked-bar-plots"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Stacked bar plots</b>
# </div>
#
# To create stacked bar plots we can separate the embarked data into two groups for men and women.

# %%
embarked_m = titanic_df[titanic_df['Sex']=='male']['Embarked'].value_counts()
embarked_f = titanic_df[titanic_df['Sex']=='female']['Embarked'].value_counts()
print(embarked_m)
print(embarked_f)

# %% [markdown]
# In order to stack the bars, we plot one set of data normally, then we tell Matplotlib to stack the other on top using the `bottom` parameter. This specifies the y-coordinate of the bars bases.

# %%
plt.bar(x=embarked_m.index, height=embarked_m.values, color='blue')
plt.bar(x=embarked_f.index, height=embarked_f.values, bottom=embarked_m.values, color='red');

# %% [markdown]
# Finally, we can use the same functions that we saw before to provide axis labels, a title, and a plot legend.

# %%
plt.bar(x=embarked_m.index, height=embarked_m.values, color='blue', width=0.75)
plt.bar(x=embarked_f.index, height=embarked_f.values, bottom=embarked_m.values, color='red', width=0.75)

plt.xlabel('Port')
plt.ylabel('Passengers')
plt.title('Port of Embarkation by Sex')
plt.legend(labels=['M', 'F']);

# %% [markdown]
# <div id="histograms"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Histograms</b>
# </div>
#
# We can use Matplotlib's [`hist`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html) function to display a frequency distribution of some variable. Let's show the distribution of the ages of passengers on the Titanic.

# %%
ages = titanic_df['Age']
plt.hist(ages);

# %% [markdown]
# Note that this illustrates the total count (y-axis) of the ages (x-axis) of the passengers separated into 10 bins. We can show a probability density of ages in each bin instead of the total count by changing to a density chart.

# %%
plt.hist(ages, density=True);

# %% [markdown]
# We can also change the number of bins from the default to make the histogram more or less granular, and add titles, labels, and gridlines to make it more readable.

# %%
plt.hist(ages, bins=20)

plt.xlabel('Age')
plt.ylabel('Passengers')
plt.title('Distribution of Passengers Ages')
plt.grid(True);

# %% [markdown]
# From this distribution, we can see that most of the passengers were in the age range of about 20 to 40. We can also see that there were many young children aboard, and relatively few passengers over the age of 70.

# %% [markdown]
# <div id="pie-charts"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Pie charts</b>
# </div>
#
# To make a pie chart, use Matplotlib's [`matplotlib.pyplot.pie`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html) function, which expects a list representing the sizes of each slice. We can use the count of male and female passengers as an example.

# %%
x = titanic_df['Sex'].value_counts()

plt.pie(x);

# %% [markdown]
# Without labels, we can't really understand what even the most basic pie chart means.

# %%
plt.pie(x, labels=['Male', 'Female']);

# %% [markdown]
# That's better, but what if we want the first slice to start at the 12 o'clock position, which is standard? The default seems to be starting at 3 o'clock. We can do that by specifying a `startangle`.

# %%
plt.pie(x, labels=['Male', 'Female'], startangle=90);

# %% [markdown]
# You can separate one or more slices from the rest of the chart using the `explode` parameter.

# %%
plt.pie(x, labels=['Male', 'Female'], startangle=90, explode=[0.1, 0]);

# %% [markdown]
# Finally, we can display the percentage that each slice represents using the `autopct` parameter by setting it to a format specifier.

# %%
plt.pie(x, labels=['Male', 'Female'], startangle=90, autopct='%.1f%%');

# %% [markdown]
# <div id="scatter-plots"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Scatter plots</b>
# </div>
#
# To create scatter plots, use Matplotlib's [`matplotlib.pyplot.scatter`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) function. It expects two lists of values representing x and y coordinates. Let's use the Age and Fare columns from the Titanic data set.

# %%
age = titanic_df['Age']
fare = titanic_df['Fare']

plt.scatter(x=age, y=fare);

# %% [markdown]
# There doesn't seem to be any correlation between the age of passengers aboard the Titanic and the fare they paid for passage.
#
# We can also plot multiple datasets on the same chart.

# %%
age_m = titanic_df[titanic_df['Sex'] == 'male']['Age']
fare_m = titanic_df[titanic_df['Sex'] == 'male']['Fare']
age_f = titanic_df[titanic_df['Sex'] == 'female']['Age']
fare_f = titanic_df[titanic_df['Sex'] == 'female']['Fare']

plt.scatter(x=age_m, y=fare_m)
plt.scatter(x=age_f, y=fare_f)
plt.legend(['male', 'female']);

# %% [markdown]
# Since we have another numeric data column (Pclass), we can use either color or marker size to represent a third axis.

# %%
age = titanic_df['Age']
fare = titanic_df['Fare']
pclass = titanic_df['Pclass']

fig = plt.figure(figsize=(12, 6))
plt.scatter(x=age, y=fare, c=pclass, cmap='RdYlGn')
plt.colorbar(ticks=[1, 2, 3])
plt.xlabel('Age')
plt.ylabel('Fare');

# %% [markdown]
# Note that this time I specificed a `cmap` (colormap) and colorbar instead of using a legend. This tells us that their is a relationship between fare and class. Most of the 1st class passengers paid the higher fares.
#
# Let's try showing the class using the size of each marker.

# %%
fig = plt.figure(figsize=(12, 6))
plt.scatter(x=age, y=fare, s=(pclass*35))
plt.xlabel('Age')
plt.ylabel('Fare');

# %% [markdown]
# If you look closely, you can see that the markers near the bottom of the plot are larger, indicating those passengers were in a higher class then passengers plotted higher up. It's much easier to see this distinction using colors, at least in this case.

# %% [markdown]
# <div id="box-plots"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>Box plots</b>
# </div>
#
# You can create box plots (box-and-whisker plots) in Matplotlab using the [`matplotlib.pyplot.boxplot`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html) function. Box plots are important in statistical analysis because they let you see the distrubution of a data set at a glance, including outliers. Let's look at the age of Titanic passengers again, this time in a box plot.

# %%
age = titanic_df['Age'].dropna() # Drop missing values before plotting or the boxplot will be empty

fig = plt.figure(figsize=(6, 6))
plt.boxplot(age, labels=['Age']);

# %% [markdown]
# We can pick a few key datapoints off the boxplot at a glance. The median age is just under 30, with half of the ages in the 20 to 40 range. The entire distribution of ages is from 0 to 80 years, with a few data points at the high end of the scale considered outliers.

# %% [markdown]
# <div id="3d-plots"
#      style="display:fill;
#             background-color: #999;
#             font-size:140%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 5px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #999;
#             text-align:center;">
# <b>3D plots</b>
# </div>
#
# Earlier we showed how color and marker size can be used as a third dimension in Matplotlib, but you can also plot that data on a third axis by setting the projection to `3d` when calling the `axes` function. That function returns an axis object that we use to create a scatterplot.

# %%
age = titanic_df['Age']
fare = titanic_df['Fare']
pclass = titanic_df['Pclass']

fig = plt.figure(figsize=(9, 9))

ax = plt.axes(projection='3d')
ax.scatter(xs=age, ys=fare, zs=pclass)

ax.set_xlabel('Age')
ax.set_ylabel('Fare')
ax.set_zlabel('Class');

# %% [markdown]
# Like on the 2D chart, we can see that the Fare doesn't vary much by Age in 2nd and 3rd class on Titanic, but it varies quite a bit in 1st class.
#
# Even with classes separated as they are, it's still difficult to see which data points belong to which class when they're all the same color. Just like with a 2D scatter plot, we can set the color for each class to make it easier to tell them apart.

# %%
fig = plt.figure(figsize=(9, 9))

ax = plt.axes(projection='3d')
ax.scatter(xs=age, ys=fare, zs=pclass, c=pclass, cmap='brg')

ax.set_xlabel('Age')
ax.set_ylabel('Fare')
ax.set_zlabel('Class');

# %% [markdown]
# <div id="subplots"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Subplots</b>
# </div>
#
# Many times you'll need to plot multiple charts in one figure. Matplotlib allows you to do this with the [`matplotlib.pyplot.subplots`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html) function, where you specify the number of rows and columns, and it returns a grid of axes. This will make more sense with an example. Let's draw two pie charts from the Titanic dataset in one grid, side-by-side.

# %%
s_vals = titanic_df['Sex'].value_counts()
e_vals = titanic_df['Embarked'].value_counts()

fig, axes = plt.subplots(1, 2) # create a grid with 1 row, 2 columns
fig.set_size_inches(8, 4) # make the figure wide

# Create a pie chart in the first grid slot
axes[0].pie(s_vals, labels=['Male', 'Female'], startangle=90, autopct='%.1f%%')
axes[0].set_title('Sex')

# Create a pie chart in the second grid slot
axes[1].pie(e_vals, labels=['S', 'C', 'Q'], startangle=90, explode=[0, 0.1, 0])
axes[1].set_title('Embarked');

# %% [markdown]
# You don't have to create the same kind of chart in each grid space.

# %%
fig, axes = plt.subplots(1, 3) # create a grid with 1 row, 3 columns
fig.set_size_inches(12, 4) # make the figure wide

# Create a pie chart in the first grid slot
axes[0].pie(s_vals, labels=['Male', 'Female'], startangle=90, autopct='%.1f%%')
axes[0].set_title('Sex')

# Create a box plot in the second grid slot
age = titanic_df['Age'].dropna() # Drop missing values before plotting or the boxplot will be empty
axes[1].boxplot(age, labels=['Age']);

# Create a scatter plot in the third grid slot
age = titanic_df['Age']
fare = titanic_df['Fare']
axes[2].scatter(x=age, y=fare);

# %% [markdown]
# <div id="text-and-annotations"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Text and Annotations</b>
# </div>
#
# Matplotlib allows you to add text and annotations to a plot so that you can label features of your data that you'd like to draw attention to. Let's go back to our earlier example of plotting a function, but this time we'll add a label saying what the function is.

# %%
x = np.linspace(start=-np.pi, stop=np.pi, num=256)
y = np.sin(2*x)

fig = plt.figure(figsize=(8, 5))
plt.plot(x, y)
plt.text(-1.65, 0.5, 'y = sin(2x)', fontsize=14);

# %% [markdown]
# We could also plot and annotate a specific point.

# %%
fig = plt.figure(figsize=(8, 5))
plt.plot(x, y, color='gray')

plt.plot([0], [0], 'o') # plot the point (0, 0)

arrowprops = dict(facecolor='black', shrink=0.1, width=2)
plt.annotate('origin point',        # text of the annotation
             xy=(0, 0),             # where the arrow should point
             xytext=(-1.65, 0.5),   # Where the text should start
             arrowprops=arrowprops, # arrow properties
             fontsize=12            # text font size
            );

# %% [markdown]
# <div id="faq"
#      style="display:fill;
#             background-color: #369;
#             font-size:160%;
#             font-family: 'Clear Sans', 'Helvetica Neue', Arial, sans-serif;
#             letter-spacing: 0.5px;
#             padding: 6px;
#             color: #FFF;
#             border-style: solid;
#             border-color: #369;
#             text-align:center;">
# <b>Frequently Asked Questions</b>
# </div>
#
# Here is a list of the most frequently asked questions specifically about [Matplotlib on Stack Overflow](https://stackoverflow.com/questions/tagged/matplotlib). These are in order of how often duplicate questions are asked.
#
# 1. [How to plot in multiple subplots](https://stackoverflow.com/q/31726643/1288)
# 2. [How do you change the size of figures drawn with Matplotlib?](https://stackoverflow.com/q/332289/1288)
# 3. [Adding value labels on a matplotlib bar chart](https://stackoverflow.com/q/28931224/1288)
# 4. [prevent scientific notation in matplotlib.pyplot](https://stackoverflow.com/q/28371674/1288)
# 5. [Is ticklabel_format broken?](https://stackoverflow.com/q/18209462/1288)
# 6. [How can I change the x axis in matplotlib so there is no white space?](https://stackoverflow.com/q/42045767/1288)
# 7. [Changing the "tick frequency" on x or y axis in matplotlib](https://stackoverflow.com/q/12608788/1288)
# 8. [How to put the legend outside the plot in Matplotlib](https://stackoverflow.com/q/4700614/1288)
# 9. [Annotate bars with values on Pandas bar plots](https://stackoverflow.com/q/25447700/1288)
# 10. [How can I plot separate Pandas DataFrames as subplots?](https://stackoverflow.com/q/22483588/1288)
# 11. [How to have one colorbar for all subplots](https://stackoverflow.com/q/13784201/1288)
# 12. [Matplotlib scatter plot with different text at each data point](https://stackoverflow.com/q/14432557/1288)
# 13. [Make contour of scatter](https://stackoverflow.com/q/18764814/1288)
# 14. [Improve subplot size/spacing with many subplots in matplotlib](https://stackoverflow.com/q/6541123/1288)
# 15. [Is there a way to make a discontinuous axis in Matplotlib?](https://stackoverflow.com/q/5656798/1288)
# 16. [Can I make a multi-color line in matplotlib?](https://stackoverflow.com/q/35372993/1288)
# 17. [Plot a horizontal line using matplotlib](https://stackoverflow.com/q/33382619/1288)
