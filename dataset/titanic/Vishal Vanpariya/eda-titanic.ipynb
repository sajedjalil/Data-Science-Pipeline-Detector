# %% [markdown]
# Hello Everyone,
#
# Here I am going to Explanation and Visualization of data and we will handle data Missing and Feature Scaling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# We have imported some libraries which will help us for data handling and data visualization
# 1. numpy and pandas for math and data oprations
# 2. Seaborn and Matplotlib is a one of the best libraries for data visulization

# %%
#lets import data from csv file

train=pd.read_csv('/kaggle/input/titanic/train.csv')

# %% [markdown]
# we will do all the opration with train data only because in train data we have both input and output data

# %%
train.head()

# %% [markdown]
# Here we have total 11 features as an input(PassengerId,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked) and 1 feature as output(Survived) so let's see all data one by one

# %% [markdown]
# # PassengerID

# %%
#Passengerid is a unique identity of passengers so this does not matter to Survival of a Passenger So, let's drop Passengerid feature
train=train.drop(['PassengerId'],1)
train.head()

# %% [markdown]
# # Pclass

# %%
train['Pclass'].unique()

# %% [markdown]
# Pclass id for define Ticket class. Like Economical class,business class
# 1. class 3 for higher class
# 2. class 2 for midddel class
# 3. class 1 for lowwer class
# So, let's visualize this data

# %%
sns.countplot(x=train['Pclass'])

# %% [markdown]
# here we can see that highest number of passengers travelling in class 3,Lets see relation between Pclass and Survival

# %%
sns.catplot(x='Pclass',y='Survived',data=train,kind='bar')

# %% [markdown]
# As per Barplot, we can say that class 1 passengers mostly likely to survive

# %% [markdown]
# # Name

# %%
#lets see top 5 row data
train['Name'].head()

# %% [markdown]
# as we can see to the dat its look like this does not matter for our model, but it matters lot let's extract some data from it

# %%
#let's extract Titles of Passengers
train['Title']=train['Name'].str.extract('([A-Za-z]+)\.',)

# %%
train['Title'].unique()

# %% [markdown]
# this all are unique titles we got from names

# %%
sns.countplot(y=train['Title'])

# %% [markdown]
# above count plot showing number of title we have in our data

# %%
sns.catplot(y='Title',x='Survived',data=train,kind='bar')

# %% [markdown]
# now we can see some meaningfull of title feature

# %%
#we do not need Name longer so,Let's drop it
train=train.drop(['Name'],1)
train.head()

# %% [markdown]
# # Sex

# %%
sns.countplot(train['Sex'])

# %% [markdown]
# Male is more than female in the Titanic

# %%
sns.catplot(x='Sex',y='Survived',data=train,kind='bar')

# %% [markdown]
# female is more likely to survive

# %%
sns.catplot(x='Sex',y='Survived',data=train,kind='bar',hue='Pclass')

# %% [markdown]
# here we can see that relation of sex-Pclass-Survived

# %% [markdown]
# # Age

# %%
train['Age_Band']=pd.cut(train['Age'],5)

# %%
sns.catplot(y="Age_Band",x='Survived',data=train,kind='bar')

# %% [markdown]
# Here we can see that lowwer age passengers are more likely to survive and higger age likely to not survive

# %%
sns.catplot(y="Age_Band",x='Survived',data=train,kind='bar',hue='Pclass')

# %%
g = sns.FacetGrid(train, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %% [markdown]
# here we can see that how the survival changes with the age

# %%
g = sns.FacetGrid(train, col='Survived',row='Sex')
g.map(plt.hist, 'Age', bins=20)

# %%
g = sns.FacetGrid(train, row='Survived',col='Pclass')
g.map(plt.hist, 'Age', bins=20)

# %%
g = sns.FacetGrid(train, row='Survived',col='Embarked')
g.map(plt.hist, 'Age', bins=20)

# %%
grid = sns.FacetGrid(train, row='Embarked', size=2.2, aspect=1.6)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex')
grid.add_legend()

# %%
train=train.drop(['Age_Band'],1)

# %% [markdown]
# # SibSp/Parch

# %% [markdown]
# * Sibsb:Number of Sibling
# * Parch:Number of Parents

# %% [markdown]
# using this features we can create new fature Family

# %%
train['FamilySize']=train['SibSp']+train['Parch']
train=train.drop(['SibSp','Parch'],1)

# %%
sns.catplot(x='FamilySize',y='Survived',data=train,kind='bar')

# %% [markdown]
# Survival probility as per familysize

# %%
sns.catplot(x='FamilySize',y='Survived',data=train,kind='bar',hue='Sex')

# %%
sns.catplot(x='FamilySize',y='Survived',data=train,kind='bar',hue='Pclass')

# %% [markdown]
# # Ticket

# %% [markdown]
# Ticket is also like Passengerid which does not matter to Survivel of Passengers

# %%
train=train.drop(['Ticket'],1)
train.head()

# %% [markdown]
# # Cabin

# %% [markdown]
# This feature is to hard to find is it usefull for use or not? So, Let's do some oprations and find the meaningfull data

# %%
train['Cabin'].isnull().sum()

# %% [markdown]
# here we can see that lots of data are missing so lets fill "NA"

# %%
train['Cabin']=train['Cabin'].fillna('NA')

# %%
train.Cabin.unique()

# %% [markdown]
# there are lots of unique values are here so, Let's take first character of Cabin

# %%
train['Cabin']=train['Cabin'].astype(str).str[0]
train['Cabin'].unique()

# %%
sns.catplot(x='Cabin',y='Survived',data=train,kind='bar')

# %% [markdown]
# Now it seems like meaningfull data

# %%
sns.catplot(x='Cabin',y='Survived',data=train,col='Sex',kind='bar')

# %%
sns.catplot(x='Cabin',y='Survived',data=train,col='Pclass',kind='bar')

# %%
sns.catplot(x='Cabin',y='Survived',data=train,col='Pclass',row='Sex',kind='bar')

# %% [markdown]
# # Embarked

# %%
print(train['Embarked'].unique())
print(train['Embarked'].isnull().sum())

# %% [markdown]
# there are 2 missing values here, so let's replace it with most frequent value

# %%
train['Embarked']=train['Embarked'].fillna(train['Embarked'].value_counts().index[0])
print(train['Embarked'].unique())

# %%
sns.catplot(x='Embarked',y='Survived',data=train,kind='bar')

# %% [markdown]
# we allready seen plot which contain relation with other features so no need to see here

# %%
train.head()

# %% [markdown]
# Great, We have done all the Features

# %%
corr=train.corr().sort_values(by='Survived',ascending=False).round(2)
plt.subplots(figsize=(8, 6))
sns.heatmap(corr, vmax=.8, square=True);

# %% [markdown]
# Here we can findout relation between features

# %% [markdown]
# more ligher color means more co-related to each other

# %% [markdown]
# # Missing Values

# %%
train.isnull().sum()

# %% [markdown]
# here we have only one feature which have some missing data

# %%
print(train.Pclass.unique())
print(train.Sex.unique())

# %%
for i in ['male','female']:
    for j in [3,1,2]:
        print(i,j)
        temp_dataset=train[(train['Sex']==i) &  (train['Pclass']==j)]['Age'].dropna()
        print(temp_dataset)
        print(str(temp_dataset.median())+"  "+str(i)+"  "+str(j))
        train.loc[(train.Age.isnull()) & (train.Sex==i) & (train.Pclass==j),'Age']=int(temp_dataset.median())

# %%
train.isnull().sum()

# %% [markdown]
# Great, All missing data done

# %%
train.head()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Let's use One-Hot Encoding for Categorical data

# %%
train=pd.get_dummies(columns=['Pclass','Sex','Cabin','Embarked','Title'],data=train)
train.head()

# %% [markdown]
# We can create Band for Age and Fare So, let's create it

# %%
train['Age_Band']=pd.cut(train['Age'],5)
train['Age_Band'].unique()

# %%
train.loc[(train['Age']<=16.136),'Age']=1
train.loc[(train['Age']>16.136) & (train['Age']<=32.102),'Age']=2
train.loc[(train['Age']>32.102) & (train['Age']<=48.068),'Age']=3
train.loc[(train['Age']>48.068) & (train['Age']<=64.034),'Age']=4
train.loc[(train['Age']>64.034) & (train['Age']<=80.),'Age']=5
train['Age'].unique()

# %%
train=train.drop(['Age_Band'],1)

# %%
train['Fare_Band']=pd.cut(train['Fare'],3)
train['Fare_Band'].unique()

# %%
train.loc[(train['Fare']<=170.776),'Fare']=1
train.loc[(train['Fare']>170.776) & (train['Fare']<=314.553),'Fare']=2
train.loc[(train['Fare']>314.553) & (train['Fare']<=513),'Fare']=3
train=train.drop(['Fare_Band'],1)

# %%
train.head()

# %% [markdown]
# Now, Age and Fare also include in Categorical data

# %%
train=pd.get_dummies(columns=['Age','Fare'],data=train)
train.head()

# %% [markdown]
# Greate, We have Done all the PrePrecessing

# %% [markdown]
# Now, You can apply Modeling.

# %% [markdown]
# All the Feedback and Suggestion appreciated, Please Upvote if you find any usefull

# %% [markdown]
# <h1>Check out my other Notebooks</h1><font size='4'>
# <a href="https://www.kaggle.com/vishalvanpariya/top-5-on-leaderboard" target="_blank">House Price</a><br>
# <a href="https://www.kaggle.com/vishalvanpariya/basic-visualization-for-beginners" target="_blank">Basic Visualization</a><br>
# <a href="https://www.kaggle.com/vishalvanpariya/titanic-top-6" target="_blank">Titanic Notebook</a><br>
# <a href="https://www.kaggle.com/vishalvanpariya/nlp-for-beginners" target="_blank">NLP</a><br><font>

# %% [markdown]
# Thank you
