# %% [markdown]
# Hello everyone,
#
# which kind of project would experts recommend for begginers(without knowledge in advanced statistics and data analysis)
#
# # These are famous datasets
#
#
# **with Basic python and statistics knowledge
#
#
# Pima Indians :- https://www.kaggle.com/uciml/pima-indians-diabetes-database
#
# Cardio Goodness fit :- https://www.kaggle.com/saurav9786/cardiogoodfitness
#
# Automobile :- https://www.kaggle.com/toramky/automobile-dataset
#
#
#
#
#
#
# challenge/overview Titanic :- https://www.kaggle.com/c/titanic
#
#
# Customer satisfcation:-https://www.kaggle.com/c/santander-customer-satisfaction
#
# Trip type classification:- https://www.kaggle.com/c/walmart-recruiting-trip-type-classification
#
# Categorize cusine:- https://www.kaggle.com/c/whats-cooking
#
#
#
#
#
# How much did it rain :- https://www.kaggle.com/c/how-much-did-it-rain-ii/overview
#
# Inventory Demand:- https://www.kaggle.com/c/grupo-bimbo-inventory-demand
#
# Property Inspection predictiion:- https://www.kaggle.com/c/liberty-mutual-group-property-inspection-prediction
#
# Restaurant Revenue prediction:- https://www.kaggle.com/c/restaurant-revenue-prediction/data
#
# IMDB Box office Prediction:-https://www.kaggle.com/c/tmdb-box-office-prediction/overview
#
#
#
# I hope it helps in the beginning.
#
#
# # Please upvote if you find this useful.
# #
