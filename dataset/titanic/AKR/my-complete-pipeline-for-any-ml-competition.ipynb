# %% [markdown]
# <a id="0"></a>
# # <p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 60px;">INTRODUCTION</p>
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">Hello everyone, I am a CSE undergrad, currently in 3rd year. In this series of notebooks I will be disclosing my complete pipeline which I have developed with time and I use it in almost every competition.<br><b>What is Pipeline/template?</b> Whenever we participate in a competition we learn new concepts and we want to implement this in our future competitions, so for this we create our own pipeline(ready to use code), with time our pipeline becomes more robust and less manual. I have created my pipeline in quite modular fashion so that we can directly use it where ever we want to use it. This work which you will see in this and following notebooks is not taken from any one source but my own which I build after participating in many competitions and learning. To be frank I am not an expert but whatever I learn I try to learn it complete. I am really thankful to all my ideals( Nischay, Abhishek sir and many more) whoom I look forward and learn.
# <br>
#     <b>Objective:</b> I wanted to store my pipeline in an organized way and want to keep updating it implementing new features with time. Why Titanic Competition?, because this is the first Competition from where I started my journey, I learnt a lot from here and I want to contribute to this competition in my own way. Also since this is not a Time limit competition so I will keep coming back here experimenting new things and adding new features.</p>
#
# <a id="0"></a>
# # <p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 60px;">HOW IT WILL BEGIN?</p>
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;"><b>Our aim is to a create very strong CV. </b>We will start with creating folds. Then we will apply various feature engineering techniques and train several models each will have optimized hyperparameter like Catboost Classifier, GBM, LGBM, etc,. So we will train like 50 different models but don't wory everything will be modular so it won't be tiresome work. Then we will start filtering the models based on their <b>STABILITY</b>, this we will know by looking at the fold predictions. This is very crucial because if a model gives a very good score in one fold and very bad score in another then probably that model is not trustworthy and you would never want your final submission to be depended on that model:). So we will filter models based on their stabilty. But here also everything will be modular so we will automatically get a nice pandas DATAFRAME which will contain each fold AUC score for all the 50 models. To show here is my table from a previous competition. <b>NOTE:- Each and Every code will be made available here.</b></p>

# %% [markdown]
# ![image2.png](attachment:bdacf167-a326-4de3-b021-3f47017c065a.png)

# %% [markdown]
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">This was all <b>Level 1</b> predictioins. Next we will use these predictions to create our <b>Level 2</b> predictions and then we will blend these results to get our final results. This <b>Level 2</b> models will used with their default values of hyperparameter i.e no optimization. This we will do to avoid overfitting. Again our whole work can be shown in a diagram as this:-  </p>

# %% [markdown]
# ![image1 (2).jpg](attachment:247514ed-13bc-4b4d-91f5-56564c461b7d.jpg)
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">This may seem complex but don't worry everything is quite organized and modular. If you complete this notebook series you will definitely be able to score good in tabular competitions, however these ideas can be implemented to non tabular competitions as well.
# <br>
# So without further waiting let's start the Journey..</p>

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 60px;">TABLE OF CONTENTS</p>
#
# * [1. CREATE FOLDS](#1)
#
# * [2. LEVELS](#2)
#    * [2.1 LEVEL1](#2.1)
#    * [2.2 LEVEL2](#2.2)
#
#
# * [5. CONCLUSION](#5)
#
# * [6. END](#6)
#
# <a id="0"></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:5px 5px;">LINKS TO THE NOTEBOOKS<p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 60px;">CREATE FOLDS</p></p>
#     <p style="font-family:newtimeroman;font-size:120%;color:#444160;">In this notebook we have splitted our training dataset into 5 folds, and saved the updated training dataset as <code>TITANIC_Folds.csv</code> to use it later. You can check the notebook to see how it is implemented.</p>
#
# [https://www.kaggle.com/raj401/titanic-create-folds](https://www.kaggle.com/raj401/titanic-create-folds)
#
# <a id=2></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 60px;">LEVELS</p>
#     <p style="font-family:newtimeroman;font-size:120%;color:#444160;">As discussed earlier we will be creating two levels LEVEL1 and LEVEL2. In each level we will create several rounds called as ROUND1, ROUND2, ROUND3...
# <br>Each round will have different set of feature engineering. We will find optimal hyperparameters of all the models in each round using OPTUNA.<br>
#         <i>[<b>Note: </b>You may see there are many notebooks but as I mentioned that is quite modular in nature, so you will see same code is being used at multiple places. This makes our code quite easy to produce as well as manage. For example in Level1 Round1 there are <b>13 notebooks</b> of model optimization. But all are exactly same line by line, just different set of hyperparameters are inserted corresponding to the model we are optimizing.]</i></p>
#
#
#
#
# <a id=2.1></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#FBAB7E;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 20px;">LEVEL1</p>
#
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:FBAB7E;font-family:newtimeroman;color:#444160;font-size:150%;text-align:left;border-radius:20px 20px;">ROUND1</p>
#
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">PREPROCESSING <a href="https://www.kaggle.com/raj401/level1-round1-preprocessing/notebook">https://www.kaggle.com/raj401/level1-round1-preprocessing/notebook</a><br>Features selected for training :- <code>['Pclass','Age','SibSp','Parch','Fare','Sex_male','Embarked_Q','Embarked_S']</code><br>
#     Scaler :- <code>MinMaxScaler()</code><br></p>
#
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">
#     1. Catboost-Classifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-catboost/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-catboost/notebook</a><br>
# 2. XGBRegressor <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-xgbregressor/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-xgbregressor/notebook</a><br>
# 3. LogisticRegression <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-logisticregression/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-logisticregression/notebook</a><br>
# 4. MLPClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-mlpclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-mlpclassifier/notebook</a><br>
# 5. RIDGE <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-ridge/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-ridge/notebook</a><br>
# 6. LASSO <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-lasso/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-lasso/notebook</a><br>
# 7. KNeighborsClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-kneighborsclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-kneighborsclassifier/notebook</a><br>
# 8. DecisionTreeClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-decisiontree-c/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-decisiontree-c/notebook</a><br>
# 9. AdaboostClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-adaboost-classifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-adaboost-classifier/notebook</a><br>
# 10. GBMClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-gbmclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-gbmclassifier/notebook</a><br>
# 11. HBGClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-hgbclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-hgbclassifier/notebook</a><br>
# 12. LGBMClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-lgbmclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-lgbmclassifier/notebook</a><br>
# 13. LGBMRegressor <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round1-lgbmregressor/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round1-lgbmregressor/notebook</a>  </p>
#
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">Make TEST PREDICTIONS and OOF PREDCITIONS for all 13 models of LEVEL1 ROUND1.<br> <a href="https://www.kaggle.com/raj401/titanic-level1-round1/notebook">https://www.kaggle.com/raj401/titanic-level1-round1/notebook</a><br></p>
#
#
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:FBAB7E;font-family:newtimeroman;color:#444160;font-size:150%;text-align:left;border-radius:20px 20px;">ROUND2</p>
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">PREPROCESSING <a href="https://www.kaggle.com/raj401/level1-round2-preprocessing/notebook">https://www.kaggle.com/raj401/level1-round2-preprocessing/notebook</a><br>Features selected for training :- <code>['Pclass','SibSp','Parch','Family_size','IsAlone','Title_ Miss','Title_ Mr','Title_ Mrs','Title_other','Fare_bins','Age_bins','Sex_male','Embarked_Q','Embarked_S']</code><br>
#     Scaler :- <code>RobustScaler()</code><br>  </p>
#
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">
#     1. Catboost-Classifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-catboost/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-catboost/notebook</a><br>
# 2. XGBRegressor <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-xgbregressor/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-xgbregressor/notebook</a><br>
# 3. LogisticRegression <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-logisticregression/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-logisticregression/notebook</a><br>
# 4. MLPClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-mlpclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-mlpclassifier/notebook</a><br>
# 5. RIDGE <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-ridge/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-ridge/notebook</a><br>
# 6. LASSO <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-lasso/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-lasso/notebook</a><br>
# 7. KNeighborsClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-kneighborsclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-kneighborsclassifier/notebook</a><br>
# 8. DecisionTreeClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-decisiontree-c/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-decisiontree-c/notebook</a><br>
# 9. AdaboostClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-adaboost-classifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-adaboost-classifier/notebook</a><br>
# 10. GBMClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-gbmclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-gbmclassifier/notebook</a><br>
# 11. HBGClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-hgbclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-hgbclassifier/notebook</a><br>
# 12. LGBMClassifier <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-lgbmclassifier/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-lgbmclassifier/notebook</a><br>
# 13. LGBMRegressor <a href="https://www.kaggle.com/raj401/titanic-optuna-level1-round2-lgbmregressor/notebook">https://www.kaggle.com/raj401/titanic-optuna-level1-round2-lgbmregressor/notebook</a> </p>
# <br>
#  <p style="font-family:newtimeroman;font-size:120%;color:#444160;">Make TEST PREDICTIONS and OOF PREDCITIONS for all 13 models of LEVEL1 ROUND2.<br> <a href="https://www.kaggle.com/raj401/titanic-level1-round2/notebook">https://www.kaggle.com/raj401/titanic-level1-round2/notebook</a><br></p>
#
#
# <a id=2.2></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#FBAB7E;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 20px;">LEVEL2</p>
#
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:FBAB7E;font-family:newtimeroman;color:#444160;font-size:150%;text-align:left;border-radius:20px 20px;">ROUND1</p>
#
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">PREPROCESSING <a href="https://www.kaggle.com/raj401/level2-round1-preprocessing/notebook">https://www.kaggle.com/raj401/level2-round1-preprocessing/notebook</a><br>Features selected for training :- <code>['Level1_Round2_pred_7','Level1_Round1_pred_6','Level1_Round2_pred_6','Level1_Round1_pred_11','Level1_Round2_pred_9','Level1_Round2_pred_8','Level1_Round2_pred_3','Level1_Round2_pred_12','Level1_Round1_pred_12','Level1_Round2_pred_10','Level1_Round1_pred_8','Level1_Round1_pred_7','Level1_Round1_pred_10','Level1_Round2_pred_11','Level1_Round1_pred_1','Level1_Round1_pred_3','Level1_Round1_pred_9']</code><br>
#     Scaler :- <code>MinMaxScaler()</code><br> </p>
#  <p style="font-family:newtimeroman;font-size:120%;color:#444160;">Make TEST PREDICTIONS and OOF PREDCITIONS for all 13 models of LEVEL2 ROUND1.<br> <a href="https://www.kaggle.com/raj401/titanic-level2-round1/notebook">https://www.kaggle.com/raj401/titanic-level2-round1/notebook</a><br></p>
#
#
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:FBAB7E;font-family:newtimeroman;color:#444160;font-size:150%;text-align:left;border-radius:20px 20px;">ROUND2</p>
#
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">PREPROCESSING <a href="https://www.kaggle.com/raj401/level2-round2-preprocessing/notebook">https://www.kaggle.com/raj401/level2-round2-preprocessing/notebook</a><br>Features selected for training :- <code>['Level1_Round1_pred_11', 'sem', 'Level1_Round1_pred_12', 'Level1_Round2_pred_11', 'Level1_Round2_pred_6', 'median', 'Level1_Round1_pred_1', 'Level1_Round1_pred_7', 'skew', 'Level1_Round2_pred_12', 'max', 'abs_sum', 'Level1_Round2_pred_7', 'Level1_Round1_pred_3', 'avg', 'mad', 'Level1_Round1_pred_9', 'Level1_Round1_pred_10', 'Level1_Round2_pred_3', 'Level1_Round1_pred_6', 'Level1_Round2_pred_9']</code><br>
#     Scaler :- <code>StandardScaler()</code><br> </p>
#  <p style="font-family:newtimeroman;font-size:120%;color:#444160;">Make TEST PREDICTIONS and OOF PREDCITIONS for all 13 models of LEVEL2 ROUND2.<br> <a href="https://www.kaggle.com/raj401/titanic-level2-round2/notebook">https://www.kaggle.com/raj401/titanic-level2-round2/notebook</a><br></p>
#
#
#
# <a id="5"></a>
# <p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 60px;">CONCLUSION</p>
# <p style="font-family:newtimeroman;font-size:120%;color:#444160;">I am currently working on rest of the notebooks. I will put their link here as soon as I complete it. Meanwhile I will also keep updating score of our ensemble so far created. So far we have achieved accuracy of <b><span style="color:#00FF00; font-size:20px">0.78468</span></b> on public Leaderboard. We will further improve our score when we finish our ensemble. I have put a lot of effort in this and I hope this is helpful to you.<br>
# If you like my effort please do <b><span style="color:crimson; font-size:20px">UPVOTE👍</span></b>, it really keeps me motivated.</p>
#
# **<span style="color:#444160;"> Thanks!</span>**
# <a id="6"></a>
# <p style="background-color:#B721FF;font-family:newtimeroman;color:#FFFFFF;font-size:150%;text-align:center;border-radius:20px 60px;">END</p>
#     <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>
